# %%
# %%writefile localSGD.py

import os
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
num_epochs = 150
base_learning_rate = 1e-2
momentum = 0.9
weight_decay = 4e-4
warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std

class LRScheduler(torch.optim.lr_scheduler._LRScheduler):
    def __init__(self, optimizer, base_lr, K, warmup_epochs, total_epochs, verbose=False):
        """
        Args:
            optimizer: SGD
            base_lr: Base learning rate for the reference batch size.
            K: Number of workers.
            warmup_epochs: Number of warmup epochs.
            total_epochs: Total number of epochs.
            verbose: Whether to print LR updates.
        """
        self.base_lr = base_lr
        self.K = K
        self.scaled_lr = base_lr * K
        self.warmup_epochs = warmup_epochs
        self.total_epochs = total_epochs
        self.verbose = verbose
        super(LRScheduler, self).__init__(optimizer)

    def get_lr(self):
        epoch = self.last_epoch
        if epoch < self.warmup_epochs:
            # Linear warmup scaling
            warmup_factor = (epoch + 1) / self.warmup_epochs
            return [warmup_factor * self.scaled_lr for _ in self.optimizer.param_groups]
        else:
            # polynomially decaying learning rate of ηt = η0×(1−t/T)
            if epoch == self.warmup_epochs:
                print(f"Warmup phase completed at epoch {epoch}. Switching to polynomial decay learning rate.")
            return [self.scaled_lr * ( 1 - ( (epoch - self.warmup_epochs) / (self.total_epochs - self.warmup_epochs))) for _ in self.optimizer.param_groups]


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]

# Batch size
batch_size = shard_size // J

# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)


# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [LRScheduler(
    optimizer = optimizer,
    base_lr = base_learning_rate,
    K = K,
    warmup_epochs = warmup_epochs,
    total_epochs = num_epochs,
    verbose = True) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}")

    # Sequentially train each worker to simulate a distributed environment
    for k in range(K):
        shard_loader = DataLoader(shards[k], batch_size=batch_size, shuffle=True)

        nets[k].train()
        correct_train, total_train, train_loss = 0, 0, 0.0
        for images, labels in shard_loader:
            images, labels = images.to(device), labels.to(device)  # Move to device
            optimizers[k].zero_grad()
            outputs = nets[k](images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizers[k].step()
            # Calculate train loss and accuracy
            train_loss += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            total_train += labels.size(0)
            correct_train += predicted.eq(labels).sum().item()
        # Store train loss and accuracy for this worker
        train_loss /= len(shard_loader.dataset)
        train_losses_per_worker[k].append(train_loss)
        train_accuracy = 100. * correct_train / total_train
        train_accuracies_per_worker[k].append(train_accuracy)

    # Perform model synchronization
    with torch.no_grad():
        global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
        for net in nets:
            for global_param, local_param in zip(global_parameters, net.parameters()):
                global_param += local_param
        for global_param in global_parameters:
            global_param /= K
        # Update each worker model with the global parameters
        for net in nets:
            for local_param, global_param in zip(net.parameters(), global_parameters):
                local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        scheduler.step()

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Overwriting localSGD.py

# %%
# %run localSGD.py --k 8 --j 64
# Out:
# Training with K=8, J=64
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.08000
# Epoch 1/150: Test Loss: 4.5869, Test Accuracy: 1.96%
#     Worker 0: Train Loss: 4.6022, Train Accuracy: 1.26%
#     Worker 1: Train Loss: 4.6010, Train Accuracy: 1.26%
#     Worker 2: Train Loss: 4.6015, Train Accuracy: 1.39%
#     Worker 3: Train Loss: 4.5991, Train Accuracy: 1.49%
#     Worker 4: Train Loss: 4.6000, Train Accuracy: 1.47%
#     Worker 5: Train Loss: 4.5977, Train Accuracy: 1.25%
#     Worker 6: Train Loss: 4.6015, Train Accuracy: 1.20%
#     Worker 7: Train Loss: 4.6001, Train Accuracy: 1.41%
# Epoch 2/150: Test Loss: 4.2150, Test Accuracy: 6.10%
#     Worker 0: Train Loss: 4.4762, Train Accuracy: 2.99%
#     Worker 1: Train Loss: 4.4638, Train Accuracy: 2.85%
#     Worker 2: Train Loss: 4.4668, Train Accuracy: 2.93%
#     Worker 3: Train Loss: 4.4669, Train Accuracy: 2.85%
#     Worker 4: Train Loss: 4.4555, Train Accuracy: 3.18%
#     Worker 5: Train Loss: 4.4461, Train Accuracy: 3.14%
#     Worker 6: Train Loss: 4.4674, Train Accuracy: 3.07%
#     Worker 7: Train Loss: 4.4717, Train Accuracy: 3.04%
# Epoch 3/150: Test Loss: 3.9940, Test Accuracy: 9.00%
#     Worker 0: Train Loss: 4.2184, Train Accuracy: 4.83%
#     Worker 1: Train Loss: 4.1995, Train Accuracy: 5.18%
#     Worker 2: Train Loss: 4.1917, Train Accuracy: 5.57%
#     Worker 3: Train Loss: 4.2071, Train Accuracy: 5.58%
#     Worker 4: Train Loss: 4.2092, Train Accuracy: 5.49%
#     Worker 5: Train Loss: 4.1883, Train Accuracy: 5.23%
#     Worker 6: Train Loss: 4.2146, Train Accuracy: 5.06%
#     Worker 7: Train Loss: 4.2061, Train Accuracy: 4.93%
# Epoch 4/150: Test Loss: 3.9771, Test Accuracy: 11.73%
#     Worker 0: Train Loss: 4.1197, Train Accuracy: 6.24%
#     Worker 1: Train Loss: 4.0672, Train Accuracy: 6.66%
#     Worker 2: Train Loss: 4.0669, Train Accuracy: 7.09%
#     Worker 3: Train Loss: 4.1161, Train Accuracy: 6.35%
#     Worker 4: Train Loss: 4.1003, Train Accuracy: 6.40%
#     Worker 5: Train Loss: 4.0871, Train Accuracy: 7.06%
#     Worker 6: Train Loss: 4.1118, Train Accuracy: 6.34%
#     Worker 7: Train Loss: 4.0823, Train Accuracy: 6.66%
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Epoch 5/150: Test Loss: 4.0180, Test Accuracy: 12.49%
#     Worker 0: Train Loss: 4.0996, Train Accuracy: 6.82%
#     Worker 1: Train Loss: 4.0159, Train Accuracy: 7.58%
#     Worker 2: Train Loss: 4.0068, Train Accuracy: 8.62%
#     Worker 3: Train Loss: 4.0656, Train Accuracy: 7.60%
#     Worker 4: Train Loss: 4.0139, Train Accuracy: 7.65%
#     Worker 5: Train Loss: 4.0047, Train Accuracy: 8.02%
#     Worker 6: Train Loss: 4.0324, Train Accuracy: 7.41%
#     Worker 7: Train Loss: 4.0336, Train Accuracy: 7.89%
# Epoch 6/150: Test Loss: 3.9202, Test Accuracy: 14.83%
#     Worker 0: Train Loss: 3.9371, Train Accuracy: 9.49%
#     Worker 1: Train Loss: 3.9574, Train Accuracy: 8.77%
#     Worker 2: Train Loss: 3.9814, Train Accuracy: 8.90%
#     Worker 3: Train Loss: 3.9816, Train Accuracy: 8.66%
#     Worker 4: Train Loss: 3.9388, Train Accuracy: 9.49%
#     Worker 5: Train Loss: 3.9568, Train Accuracy: 9.12%
#     Worker 6: Train Loss: 3.9627, Train Accuracy: 8.58%
#     Worker 7: Train Loss: 3.9793, Train Accuracy: 9.09%
# Epoch 7/150: Test Loss: 3.8236, Test Accuracy: 16.41%
#     Worker 0: Train Loss: 3.8787, Train Accuracy: 10.51%
#     Worker 1: Train Loss: 3.8746, Train Accuracy: 9.42%
#     Worker 2: Train Loss: 3.8817, Train Accuracy: 9.87%
#     Worker 3: Train Loss: 3.8678, Train Accuracy: 10.67%
#     Worker 4: Train Loss: 3.8662, Train Accuracy: 10.82%
#     Worker 5: Train Loss: 3.8858, Train Accuracy: 10.53%
#     Worker 6: Train Loss: 3.9279, Train Accuracy: 9.04%
#     Worker 7: Train Loss: 3.9071, Train Accuracy: 10.03%
# Epoch 8/150: Test Loss: 3.6592, Test Accuracy: 18.60%
#     Worker 0: Train Loss: 3.7896, Train Accuracy: 11.10%
#     Worker 1: Train Loss: 3.8083, Train Accuracy: 11.20%
#     Worker 2: Train Loss: 3.7993, Train Accuracy: 11.89%
#     Worker 3: Train Loss: 3.8339, Train Accuracy: 10.88%
#     Worker 4: Train Loss: 3.7714, Train Accuracy: 11.18%
#     Worker 5: Train Loss: 3.7994, Train Accuracy: 11.46%
#     Worker 6: Train Loss: 3.8107, Train Accuracy: 11.02%
#     Worker 7: Train Loss: 3.8103, Train Accuracy: 11.25%
# Epoch 9/150: Test Loss: 3.5801, Test Accuracy: 19.54%
#     Worker 0: Train Loss: 3.7451, Train Accuracy: 11.94%
#     Worker 1: Train Loss: 3.7719, Train Accuracy: 11.58%
#     Worker 2: Train Loss: 3.7441, Train Accuracy: 12.16%
#     Worker 3: Train Loss: 3.7249, Train Accuracy: 11.89%
#     Worker 4: Train Loss: 3.7035, Train Accuracy: 12.96%
#     Worker 5: Train Loss: 3.7077, Train Accuracy: 12.94%
#     Worker 6: Train Loss: 3.7432, Train Accuracy: 12.13%
#     Worker 7: Train Loss: 3.7487, Train Accuracy: 12.34%
# Epoch 10/150: Test Loss: 3.5125, Test Accuracy: 20.24%
#     Worker 0: Train Loss: 3.6794, Train Accuracy: 12.88%
#     Worker 1: Train Loss: 3.6705, Train Accuracy: 12.61%
#     Worker 2: Train Loss: 3.6904, Train Accuracy: 12.72%
#     Worker 3: Train Loss: 3.6877, Train Accuracy: 12.78%
#     Worker 4: Train Loss: 3.6810, Train Accuracy: 13.06%
#     Worker 5: Train Loss: 3.6460, Train Accuracy: 13.74%
#     Worker 6: Train Loss: 3.6826, Train Accuracy: 12.93%
#     Worker 7: Train Loss: 3.7220, Train Accuracy: 12.72%
# Epoch 11/150: Test Loss: 3.4154, Test Accuracy: 22.07%
#     Worker 0: Train Loss: 3.6388, Train Accuracy: 13.17%
#     Worker 1: Train Loss: 3.6243, Train Accuracy: 13.55%
#     Worker 2: Train Loss: 3.6182, Train Accuracy: 14.99%
#     Worker 3: Train Loss: 3.6499, Train Accuracy: 13.63%
#     Worker 4: Train Loss: 3.5561, Train Accuracy: 14.94%
#     Worker 5: Train Loss: 3.5986, Train Accuracy: 14.75%
#     Worker 6: Train Loss: 3.6170, Train Accuracy: 14.61%
#     Worker 7: Train Loss: 3.6039, Train Accuracy: 14.54%
# Epoch 12/150: Test Loss: 3.3482, Test Accuracy: 23.16%
#     Worker 0: Train Loss: 3.5707, Train Accuracy: 15.06%
#     Worker 1: Train Loss: 3.5778, Train Accuracy: 15.14%
#     Worker 2: Train Loss: 3.5489, Train Accuracy: 15.54%
#     Worker 3: Train Loss: 3.5869, Train Accuracy: 15.14%
#     Worker 4: Train Loss: 3.5364, Train Accuracy: 15.66%
#     Worker 5: Train Loss: 3.5312, Train Accuracy: 15.68%
#     Worker 6: Train Loss: 3.5518, Train Accuracy: 15.20%
#     Worker 7: Train Loss: 3.5514, Train Accuracy: 14.90%
# Epoch 13/150: Test Loss: 3.2930, Test Accuracy: 24.62%
#     Worker 0: Train Loss: 3.5269, Train Accuracy: 16.02%
#     Worker 1: Train Loss: 3.5146, Train Accuracy: 15.49%
#     Worker 2: Train Loss: 3.4826, Train Accuracy: 17.04%
#     Worker 3: Train Loss: 3.5458, Train Accuracy: 15.36%
#     Worker 4: Train Loss: 3.4721, Train Accuracy: 16.67%
#     Worker 5: Train Loss: 3.4800, Train Accuracy: 17.34%
#     Worker 6: Train Loss: 3.5213, Train Accuracy: 15.50%
#     Worker 7: Train Loss: 3.4576, Train Accuracy: 16.40%
# Epoch 14/150: Test Loss: 3.1956, Test Accuracy: 25.85%
#     Worker 0: Train Loss: 3.4632, Train Accuracy: 16.78%
#     Worker 1: Train Loss: 3.4220, Train Accuracy: 17.14%
#     Worker 2: Train Loss: 3.4540, Train Accuracy: 17.89%
#     Worker 3: Train Loss: 3.4884, Train Accuracy: 16.69%
#     Worker 4: Train Loss: 3.4064, Train Accuracy: 17.98%
#     Worker 5: Train Loss: 3.4119, Train Accuracy: 17.87%
#     Worker 6: Train Loss: 3.4565, Train Accuracy: 16.22%
#     Worker 7: Train Loss: 3.4792, Train Accuracy: 16.50%
# Epoch 15/150: Test Loss: 3.1558, Test Accuracy: 27.18%
#     Worker 0: Train Loss: 3.3917, Train Accuracy: 17.81%
#     Worker 1: Train Loss: 3.4244, Train Accuracy: 18.06%
#     Worker 2: Train Loss: 3.4186, Train Accuracy: 18.54%
#     Worker 3: Train Loss: 3.4102, Train Accuracy: 18.43%
#     Worker 4: Train Loss: 3.3808, Train Accuracy: 18.35%
#     Worker 5: Train Loss: 3.3794, Train Accuracy: 18.74%
#     Worker 6: Train Loss: 3.4579, Train Accuracy: 16.58%
#     Worker 7: Train Loss: 3.3851, Train Accuracy: 18.82%
# Epoch 16/150: Test Loss: 3.0691, Test Accuracy: 27.44%
#     Worker 0: Train Loss: 3.3484, Train Accuracy: 18.21%
#     Worker 1: Train Loss: 3.3260, Train Accuracy: 19.31%
#     Worker 2: Train Loss: 3.3321, Train Accuracy: 19.06%
#     Worker 3: Train Loss: 3.3781, Train Accuracy: 18.14%
#     Worker 4: Train Loss: 3.3342, Train Accuracy: 19.15%
#     Worker 5: Train Loss: 3.3287, Train Accuracy: 20.50%
#     Worker 6: Train Loss: 3.3566, Train Accuracy: 18.35%
#     Worker 7: Train Loss: 3.3281, Train Accuracy: 19.71%
# Epoch 17/150: Test Loss: 3.0387, Test Accuracy: 28.54%
#     Worker 0: Train Loss: 3.2885, Train Accuracy: 20.80%
#     Worker 1: Train Loss: 3.3012, Train Accuracy: 18.96%
#     Worker 2: Train Loss: 3.3109, Train Accuracy: 20.13%
#     Worker 3: Train Loss: 3.2868, Train Accuracy: 20.11%
#     Worker 4: Train Loss: 3.2722, Train Accuracy: 19.57%
#     Worker 5: Train Loss: 3.3158, Train Accuracy: 19.81%
#     Worker 6: Train Loss: 3.2826, Train Accuracy: 20.10%
#     Worker 7: Train Loss: 3.3151, Train Accuracy: 19.92%
# Epoch 18/150: Test Loss: 2.9560, Test Accuracy: 29.30%
#     Worker 0: Train Loss: 3.2716, Train Accuracy: 20.86%
#     Worker 1: Train Loss: 3.2183, Train Accuracy: 21.65%
#     Worker 2: Train Loss: 3.2725, Train Accuracy: 20.74%
#     Worker 3: Train Loss: 3.2679, Train Accuracy: 19.50%
#     Worker 4: Train Loss: 3.2125, Train Accuracy: 20.88%
#     Worker 5: Train Loss: 3.2471, Train Accuracy: 21.12%
#     Worker 6: Train Loss: 3.2962, Train Accuracy: 20.10%
#     Worker 7: Train Loss: 3.2403, Train Accuracy: 20.61%
# Epoch 19/150: Test Loss: 2.9251, Test Accuracy: 30.95%
#     Worker 0: Train Loss: 3.2639, Train Accuracy: 21.01%
#     Worker 1: Train Loss: 3.1706, Train Accuracy: 22.24%
#     Worker 2: Train Loss: 3.2505, Train Accuracy: 21.50%
#     Worker 3: Train Loss: 3.2211, Train Accuracy: 20.98%
#     Worker 4: Train Loss: 3.1990, Train Accuracy: 21.20%
#     Worker 5: Train Loss: 3.1812, Train Accuracy: 22.18%
#     Worker 6: Train Loss: 3.2368, Train Accuracy: 20.30%
#     Worker 7: Train Loss: 3.1878, Train Accuracy: 21.58%
# Epoch 20/150: Test Loss: 2.8754, Test Accuracy: 31.08%
#     Worker 0: Train Loss: 3.1929, Train Accuracy: 21.97%
#     Worker 1: Train Loss: 3.1570, Train Accuracy: 23.06%
#     Worker 2: Train Loss: 3.1606, Train Accuracy: 23.22%
#     Worker 3: Train Loss: 3.1885, Train Accuracy: 21.58%
#     Worker 4: Train Loss: 3.1657, Train Accuracy: 22.03%
#     Worker 5: Train Loss: 3.1718, Train Accuracy: 22.42%
#     Worker 6: Train Loss: 3.2121, Train Accuracy: 21.89%
#     Worker 7: Train Loss: 3.1765, Train Accuracy: 22.38%
# Epoch 21/150: Test Loss: 2.8437, Test Accuracy: 31.53%
#     Worker 0: Train Loss: 3.1862, Train Accuracy: 21.41%
#     Worker 1: Train Loss: 3.1526, Train Accuracy: 22.61%
#     Worker 2: Train Loss: 3.1338, Train Accuracy: 23.58%
#     Worker 3: Train Loss: 3.2176, Train Accuracy: 21.97%
#     Worker 4: Train Loss: 3.1432, Train Accuracy: 23.10%
#     Worker 5: Train Loss: 3.1655, Train Accuracy: 22.58%
#     Worker 6: Train Loss: 3.1558, Train Accuracy: 23.22%
#     Worker 7: Train Loss: 3.1738, Train Accuracy: 22.19%
# Epoch 22/150: Test Loss: 2.8149, Test Accuracy: 32.33%
#     Worker 0: Train Loss: 3.0941, Train Accuracy: 23.76%
#     Worker 1: Train Loss: 3.1282, Train Accuracy: 23.09%
#     Worker 2: Train Loss: 3.0873, Train Accuracy: 23.98%
#     Worker 3: Train Loss: 3.1496, Train Accuracy: 22.75%
#     Worker 4: Train Loss: 3.0894, Train Accuracy: 23.65%
#     Worker 5: Train Loss: 3.1000, Train Accuracy: 24.35%
#     Worker 6: Train Loss: 3.1170, Train Accuracy: 23.09%
#     Worker 7: Train Loss: 3.1145, Train Accuracy: 23.87%
# Epoch 23/150: Test Loss: 2.7284, Test Accuracy: 33.61%
#     Worker 0: Train Loss: 3.0528, Train Accuracy: 24.48%
#     Worker 1: Train Loss: 3.0615, Train Accuracy: 24.51%
#     Worker 2: Train Loss: 3.0811, Train Accuracy: 24.50%
#     Worker 3: Train Loss: 3.0973, Train Accuracy: 23.02%
#     Worker 4: Train Loss: 3.0365, Train Accuracy: 24.59%
#     Worker 5: Train Loss: 3.0089, Train Accuracy: 25.98%
#     Worker 6: Train Loss: 3.1186, Train Accuracy: 23.23%
#     Worker 7: Train Loss: 3.1079, Train Accuracy: 23.60%
# Epoch 24/150: Test Loss: 2.7012, Test Accuracy: 34.10%
#     Worker 0: Train Loss: 3.0491, Train Accuracy: 24.66%
#     Worker 1: Train Loss: 3.0111, Train Accuracy: 24.77%
#     Worker 2: Train Loss: 3.0199, Train Accuracy: 24.86%
#     Worker 3: Train Loss: 3.0353, Train Accuracy: 24.61%
#     Worker 4: Train Loss: 2.9908, Train Accuracy: 25.78%
#     Worker 5: Train Loss: 3.0378, Train Accuracy: 24.86%
#     Worker 6: Train Loss: 3.0433, Train Accuracy: 25.02%
#     Worker 7: Train Loss: 3.0373, Train Accuracy: 24.82%
# Epoch 25/150: Test Loss: 2.6850, Test Accuracy: 34.61%
#     Worker 0: Train Loss: 3.0172, Train Accuracy: 24.45%
#     Worker 1: Train Loss: 2.9668, Train Accuracy: 25.86%
#     Worker 2: Train Loss: 3.0051, Train Accuracy: 25.87%
#     Worker 3: Train Loss: 2.9945, Train Accuracy: 26.05%
#     Worker 4: Train Loss: 2.9934, Train Accuracy: 25.63%
#     Worker 5: Train Loss: 2.9663, Train Accuracy: 26.45%
#     Worker 6: Train Loss: 2.9869, Train Accuracy: 25.97%
#     Worker 7: Train Loss: 2.9924, Train Accuracy: 25.47%
# Epoch 26/150: Test Loss: 2.6451, Test Accuracy: 35.13%
#     Worker 0: Train Loss: 2.9763, Train Accuracy: 25.30%
#     Worker 1: Train Loss: 2.9372, Train Accuracy: 27.23%
#     Worker 2: Train Loss: 2.9822, Train Accuracy: 26.34%
#     Worker 3: Train Loss: 2.9987, Train Accuracy: 25.25%
#     Worker 4: Train Loss: 2.9394, Train Accuracy: 27.18%
#     Worker 5: Train Loss: 2.9786, Train Accuracy: 26.48%
#     Worker 6: Train Loss: 2.9827, Train Accuracy: 25.60%
#     Worker 7: Train Loss: 2.9795, Train Accuracy: 25.81%
# Epoch 27/150: Test Loss: 2.6201, Test Accuracy: 35.82%
#     Worker 0: Train Loss: 2.9433, Train Accuracy: 26.46%
#     Worker 1: Train Loss: 2.9232, Train Accuracy: 26.77%
#     Worker 2: Train Loss: 2.9429, Train Accuracy: 26.66%
#     Worker 3: Train Loss: 2.9559, Train Accuracy: 26.38%
#     Worker 4: Train Loss: 2.8975, Train Accuracy: 28.38%
#     Worker 5: Train Loss: 2.9300, Train Accuracy: 27.23%
#     Worker 6: Train Loss: 2.9224, Train Accuracy: 27.02%
#     Worker 7: Train Loss: 2.9230, Train Accuracy: 27.02%
# Epoch 28/150: Test Loss: 2.5732, Test Accuracy: 35.80%
#     Worker 0: Train Loss: 2.8904, Train Accuracy: 28.03%
#     Worker 1: Train Loss: 2.8897, Train Accuracy: 27.18%
#     Worker 2: Train Loss: 2.8787, Train Accuracy: 27.70%
#     Worker 3: Train Loss: 2.9293, Train Accuracy: 27.38%
#     Worker 4: Train Loss: 2.8633, Train Accuracy: 28.42%
#     Worker 5: Train Loss: 2.9017, Train Accuracy: 27.74%
#     Worker 6: Train Loss: 2.9514, Train Accuracy: 27.14%
#     Worker 7: Train Loss: 2.8852, Train Accuracy: 27.81%
# Epoch 29/150: Test Loss: 2.5685, Test Accuracy: 36.63%
#     Worker 0: Train Loss: 2.8558, Train Accuracy: 28.88%
#     Worker 1: Train Loss: 2.8500, Train Accuracy: 27.78%
#     Worker 2: Train Loss: 2.9161, Train Accuracy: 27.36%
#     Worker 3: Train Loss: 2.8797, Train Accuracy: 27.92%
#     Worker 4: Train Loss: 2.8652, Train Accuracy: 28.51%
#     Worker 5: Train Loss: 2.8652, Train Accuracy: 28.27%
#     Worker 6: Train Loss: 2.8930, Train Accuracy: 28.03%
#     Worker 7: Train Loss: 2.8655, Train Accuracy: 28.22%
# Epoch 30/150: Test Loss: 2.5424, Test Accuracy: 37.03%
#     Worker 0: Train Loss: 2.8680, Train Accuracy: 27.63%
#     Worker 1: Train Loss: 2.8052, Train Accuracy: 28.72%
#     Worker 2: Train Loss: 2.8450, Train Accuracy: 28.83%
#     Worker 3: Train Loss: 2.8831, Train Accuracy: 27.98%
#     Worker 4: Train Loss: 2.8557, Train Accuracy: 28.14%
#     Worker 5: Train Loss: 2.8623, Train Accuracy: 27.97%
#     Worker 6: Train Loss: 2.9177, Train Accuracy: 27.68%
#     Worker 7: Train Loss: 2.8922, Train Accuracy: 28.82%
# Epoch 31/150: Test Loss: 2.5081, Test Accuracy: 37.65%
#     Worker 0: Train Loss: 2.8659, Train Accuracy: 28.43%
#     Worker 1: Train Loss: 2.8158, Train Accuracy: 28.90%
#     Worker 2: Train Loss: 2.8608, Train Accuracy: 28.83%
#     Worker 3: Train Loss: 2.8002, Train Accuracy: 29.66%
#     Worker 4: Train Loss: 2.8130, Train Accuracy: 28.99%
#     Worker 5: Train Loss: 2.8061, Train Accuracy: 29.30%
#     Worker 6: Train Loss: 2.8591, Train Accuracy: 28.30%
#     Worker 7: Train Loss: 2.7963, Train Accuracy: 29.39%
# Epoch 32/150: Test Loss: 2.4907, Test Accuracy: 38.54%
#     Worker 0: Train Loss: 2.8149, Train Accuracy: 29.02%
#     Worker 1: Train Loss: 2.7753, Train Accuracy: 30.03%
#     Worker 2: Train Loss: 2.8299, Train Accuracy: 29.25%
#     Worker 3: Train Loss: 2.8087, Train Accuracy: 29.70%
#     Worker 4: Train Loss: 2.7816, Train Accuracy: 29.66%
#     Worker 5: Train Loss: 2.7738, Train Accuracy: 30.61%
#     Worker 6: Train Loss: 2.8075, Train Accuracy: 29.02%
#     Worker 7: Train Loss: 2.8298, Train Accuracy: 29.04%
# Epoch 33/150: Test Loss: 2.4840, Test Accuracy: 39.22%
#     Worker 0: Train Loss: 2.8167, Train Accuracy: 28.80%
#     Worker 1: Train Loss: 2.7575, Train Accuracy: 30.22%
#     Worker 2: Train Loss: 2.7974, Train Accuracy: 29.49%
#     Worker 3: Train Loss: 2.8456, Train Accuracy: 28.72%
#     Worker 4: Train Loss: 2.7722, Train Accuracy: 29.63%
#     Worker 5: Train Loss: 2.7652, Train Accuracy: 30.29%
#     Worker 6: Train Loss: 2.8432, Train Accuracy: 29.20%
#     Worker 7: Train Loss: 2.7763, Train Accuracy: 30.58%
# Epoch 34/150: Test Loss: 2.4345, Test Accuracy: 39.55%
#     Worker 0: Train Loss: 2.7470, Train Accuracy: 30.00%
#     Worker 1: Train Loss: 2.7697, Train Accuracy: 30.43%
#     Worker 2: Train Loss: 2.7672, Train Accuracy: 30.64%
#     Worker 3: Train Loss: 2.7847, Train Accuracy: 30.46%
#     Worker 4: Train Loss: 2.7722, Train Accuracy: 30.08%
#     Worker 5: Train Loss: 2.7366, Train Accuracy: 31.81%
#     Worker 6: Train Loss: 2.7766, Train Accuracy: 29.92%
#     Worker 7: Train Loss: 2.7208, Train Accuracy: 31.46%
# Epoch 35/150: Test Loss: 2.4390, Test Accuracy: 39.89%
#     Worker 0: Train Loss: 2.7592, Train Accuracy: 30.19%
#     Worker 1: Train Loss: 2.7412, Train Accuracy: 31.30%
#     Worker 2: Train Loss: 2.7143, Train Accuracy: 31.58%
#     Worker 3: Train Loss: 2.7339, Train Accuracy: 30.11%
#     Worker 4: Train Loss: 2.7122, Train Accuracy: 31.18%
#     Worker 5: Train Loss: 2.7279, Train Accuracy: 32.14%
#     Worker 6: Train Loss: 2.7750, Train Accuracy: 29.60%
#     Worker 7: Train Loss: 2.7377, Train Accuracy: 30.85%
# Epoch 36/150: Test Loss: 2.4113, Test Accuracy: 39.94%
#     Worker 0: Train Loss: 2.7676, Train Accuracy: 30.26%
#     Worker 1: Train Loss: 2.6833, Train Accuracy: 31.60%
#     Worker 2: Train Loss: 2.7206, Train Accuracy: 31.39%
#     Worker 3: Train Loss: 2.7236, Train Accuracy: 31.14%
#     Worker 4: Train Loss: 2.6755, Train Accuracy: 32.22%
#     Worker 5: Train Loss: 2.7280, Train Accuracy: 31.10%
#     Worker 6: Train Loss: 2.7480, Train Accuracy: 30.74%
#     Worker 7: Train Loss: 2.7083, Train Accuracy: 31.36%
# Epoch 37/150: Test Loss: 2.3596, Test Accuracy: 41.43%
#     Worker 0: Train Loss: 2.7071, Train Accuracy: 31.33%
#     Worker 1: Train Loss: 2.6727, Train Accuracy: 31.55%
#     Worker 2: Train Loss: 2.7049, Train Accuracy: 32.26%
#     Worker 3: Train Loss: 2.7228, Train Accuracy: 30.72%
#     Worker 4: Train Loss: 2.6759, Train Accuracy: 32.43%
#     Worker 5: Train Loss: 2.6685, Train Accuracy: 32.85%
#     Worker 6: Train Loss: 2.6680, Train Accuracy: 31.57%
#     Worker 7: Train Loss: 2.6687, Train Accuracy: 32.43%
# Epoch 38/150: Test Loss: 2.3689, Test Accuracy: 40.80%
#     Worker 0: Train Loss: 2.6325, Train Accuracy: 32.32%
#     Worker 1: Train Loss: 2.6728, Train Accuracy: 31.84%
#     Worker 2: Train Loss: 2.6699, Train Accuracy: 32.64%
#     Worker 3: Train Loss: 2.7169, Train Accuracy: 31.50%
#     Worker 4: Train Loss: 2.6466, Train Accuracy: 33.02%
#     Worker 5: Train Loss: 2.6839, Train Accuracy: 32.03%
#     Worker 6: Train Loss: 2.6953, Train Accuracy: 31.71%
#     Worker 7: Train Loss: 2.6693, Train Accuracy: 32.05%
# Epoch 39/150: Test Loss: 2.3327, Test Accuracy: 41.77%
#     Worker 0: Train Loss: 2.6508, Train Accuracy: 31.94%
#     Worker 1: Train Loss: 2.6548, Train Accuracy: 32.21%
#     Worker 2: Train Loss: 2.6654, Train Accuracy: 32.77%
#     Worker 3: Train Loss: 2.6775, Train Accuracy: 31.89%
#     Worker 4: Train Loss: 2.6137, Train Accuracy: 33.57%
#     Worker 5: Train Loss: 2.6384, Train Accuracy: 32.85%
#     Worker 6: Train Loss: 2.6859, Train Accuracy: 32.11%
#     Worker 7: Train Loss: 2.6527, Train Accuracy: 32.72%
# Epoch 40/150: Test Loss: 2.3267, Test Accuracy: 41.54%
#     Worker 0: Train Loss: 2.6660, Train Accuracy: 32.24%
#     Worker 1: Train Loss: 2.5966, Train Accuracy: 33.01%
#     Worker 2: Train Loss: 2.6073, Train Accuracy: 34.05%
#     Worker 3: Train Loss: 2.6757, Train Accuracy: 32.38%
#     Worker 4: Train Loss: 2.6476, Train Accuracy: 32.70%
#     Worker 5: Train Loss: 2.5966, Train Accuracy: 34.22%
#     Worker 6: Train Loss: 2.6312, Train Accuracy: 32.48%
#     Worker 7: Train Loss: 2.6289, Train Accuracy: 33.31%
# Epoch 41/150: Test Loss: 2.3187, Test Accuracy: 42.21%
#     Worker 0: Train Loss: 2.6212, Train Accuracy: 33.04%
#     Worker 1: Train Loss: 2.5786, Train Accuracy: 33.50%
#     Worker 2: Train Loss: 2.5936, Train Accuracy: 34.37%
#     Worker 3: Train Loss: 2.6167, Train Accuracy: 33.20%
#     Worker 4: Train Loss: 2.5555, Train Accuracy: 34.94%
#     Worker 5: Train Loss: 2.5991, Train Accuracy: 34.18%
#     Worker 6: Train Loss: 2.6058, Train Accuracy: 33.66%
#     Worker 7: Train Loss: 2.6150, Train Accuracy: 33.86%
# Epoch 42/150: Test Loss: 2.3087, Test Accuracy: 41.83%
#     Worker 0: Train Loss: 2.5761, Train Accuracy: 33.79%
#     Worker 1: Train Loss: 2.5370, Train Accuracy: 34.61%
#     Worker 2: Train Loss: 2.5468, Train Accuracy: 34.82%
#     Worker 3: Train Loss: 2.6146, Train Accuracy: 32.91%
#     Worker 4: Train Loss: 2.5459, Train Accuracy: 34.96%
#     Worker 5: Train Loss: 2.5777, Train Accuracy: 34.61%
#     Worker 6: Train Loss: 2.6096, Train Accuracy: 32.98%
#     Worker 7: Train Loss: 2.6539, Train Accuracy: 32.72%
# Epoch 43/150: Test Loss: 2.2819, Test Accuracy: 42.34%
#     Worker 0: Train Loss: 2.5550, Train Accuracy: 34.56%
#     Worker 1: Train Loss: 2.5431, Train Accuracy: 33.86%
#     Worker 2: Train Loss: 2.5539, Train Accuracy: 34.05%
#     Worker 3: Train Loss: 2.6073, Train Accuracy: 32.91%
#     Worker 4: Train Loss: 2.5901, Train Accuracy: 33.66%
#     Worker 5: Train Loss: 2.5526, Train Accuracy: 35.07%
#     Worker 6: Train Loss: 2.5903, Train Accuracy: 33.28%
#     Worker 7: Train Loss: 2.6355, Train Accuracy: 32.27%
# Epoch 44/150: Test Loss: 2.2640, Test Accuracy: 42.81%
#     Worker 0: Train Loss: 2.5472, Train Accuracy: 34.56%
#     Worker 1: Train Loss: 2.5454, Train Accuracy: 34.27%
#     Worker 2: Train Loss: 2.5768, Train Accuracy: 34.54%
#     Worker 3: Train Loss: 2.5557, Train Accuracy: 34.96%
#     Worker 4: Train Loss: 2.5174, Train Accuracy: 35.63%
#     Worker 5: Train Loss: 2.5582, Train Accuracy: 35.22%
#     Worker 6: Train Loss: 2.5526, Train Accuracy: 34.35%
#     Worker 7: Train Loss: 2.5651, Train Accuracy: 34.66%
# Epoch 45/150: Test Loss: 2.2576, Test Accuracy: 42.65%
#     Worker 0: Train Loss: 2.5424, Train Accuracy: 34.56%
#     Worker 1: Train Loss: 2.4984, Train Accuracy: 36.18%
#     Worker 2: Train Loss: 2.5163, Train Accuracy: 35.70%
#     Worker 3: Train Loss: 2.5522, Train Accuracy: 33.57%
#     Worker 4: Train Loss: 2.5017, Train Accuracy: 35.41%
#     Worker 5: Train Loss: 2.5375, Train Accuracy: 35.47%
#     Worker 6: Train Loss: 2.5141, Train Accuracy: 35.62%
#     Worker 7: Train Loss: 2.5232, Train Accuracy: 35.86%
# Epoch 46/150: Test Loss: 2.2361, Test Accuracy: 43.54%
#     Worker 0: Train Loss: 2.5004, Train Accuracy: 35.60%
#     Worker 1: Train Loss: 2.4405, Train Accuracy: 36.91%
#     Worker 2: Train Loss: 2.5127, Train Accuracy: 35.71%
#     Worker 3: Train Loss: 2.5419, Train Accuracy: 34.42%
#     Worker 4: Train Loss: 2.4594, Train Accuracy: 36.64%
#     Worker 5: Train Loss: 2.4965, Train Accuracy: 36.80%
#     Worker 6: Train Loss: 2.5388, Train Accuracy: 34.62%
#     Worker 7: Train Loss: 2.5621, Train Accuracy: 34.30%
# Epoch 47/150: Test Loss: 2.2315, Test Accuracy: 43.49%
#     Worker 0: Train Loss: 2.5471, Train Accuracy: 35.33%
#     Worker 1: Train Loss: 2.4673, Train Accuracy: 35.92%
#     Worker 2: Train Loss: 2.4879, Train Accuracy: 35.73%
#     Worker 3: Train Loss: 2.4952, Train Accuracy: 35.30%
#     Worker 4: Train Loss: 2.4554, Train Accuracy: 36.74%
#     Worker 5: Train Loss: 2.4748, Train Accuracy: 36.10%
#     Worker 6: Train Loss: 2.5179, Train Accuracy: 35.34%
#     Worker 7: Train Loss: 2.5031, Train Accuracy: 35.95%
# Epoch 48/150: Test Loss: 2.2489, Test Accuracy: 42.71%
#     Worker 0: Train Loss: 2.5305, Train Accuracy: 35.14%
#     Worker 1: Train Loss: 2.4483, Train Accuracy: 36.22%
#     Worker 2: Train Loss: 2.4857, Train Accuracy: 36.74%
#     Worker 3: Train Loss: 2.5274, Train Accuracy: 34.35%
#     Worker 4: Train Loss: 2.3884, Train Accuracy: 37.82%
#     Worker 5: Train Loss: 2.4907, Train Accuracy: 36.29%
#     Worker 6: Train Loss: 2.5021, Train Accuracy: 35.38%
#     Worker 7: Train Loss: 2.4879, Train Accuracy: 36.42%
# Epoch 49/150: Test Loss: 2.2153, Test Accuracy: 43.64%
#     Worker 0: Train Loss: 2.4692, Train Accuracy: 35.65%
#     Worker 1: Train Loss: 2.4336, Train Accuracy: 37.90%
#     Worker 2: Train Loss: 2.5220, Train Accuracy: 35.23%
#     Worker 3: Train Loss: 2.4914, Train Accuracy: 36.30%
#     Worker 4: Train Loss: 2.4607, Train Accuracy: 37.01%
#     Worker 5: Train Loss: 2.4351, Train Accuracy: 37.68%
#     Worker 6: Train Loss: 2.4802, Train Accuracy: 35.98%
#     Worker 7: Train Loss: 2.4428, Train Accuracy: 37.02%
# Epoch 50/150: Test Loss: 2.1882, Test Accuracy: 44.33%
#     Worker 0: Train Loss: 2.4830, Train Accuracy: 36.70%
#     Worker 1: Train Loss: 2.4508, Train Accuracy: 36.99%
#     Worker 2: Train Loss: 2.4389, Train Accuracy: 36.64%
#     Worker 3: Train Loss: 2.4927, Train Accuracy: 35.94%
#     Worker 4: Train Loss: 2.3961, Train Accuracy: 38.24%
#     Worker 5: Train Loss: 2.4542, Train Accuracy: 37.74%
#     Worker 6: Train Loss: 2.4087, Train Accuracy: 36.83%
#     Worker 7: Train Loss: 2.4778, Train Accuracy: 35.87%
# Epoch 51/150: Test Loss: 2.1794, Test Accuracy: 45.06%
#     Worker 0: Train Loss: 2.3963, Train Accuracy: 37.95%
#     Worker 1: Train Loss: 2.3855, Train Accuracy: 37.66%
#     Worker 2: Train Loss: 2.4624, Train Accuracy: 37.02%
#     Worker 3: Train Loss: 2.4947, Train Accuracy: 36.30%
#     Worker 4: Train Loss: 2.3884, Train Accuracy: 38.53%
#     Worker 5: Train Loss: 2.4262, Train Accuracy: 37.20%
#     Worker 6: Train Loss: 2.4410, Train Accuracy: 36.56%
#     Worker 7: Train Loss: 2.4808, Train Accuracy: 36.11%
# Epoch 52/150: Test Loss: 2.1704, Test Accuracy: 44.77%
#     Worker 0: Train Loss: 2.4005, Train Accuracy: 37.12%
#     Worker 1: Train Loss: 2.3674, Train Accuracy: 37.76%
#     Worker 2: Train Loss: 2.3845, Train Accuracy: 38.69%
#     Worker 3: Train Loss: 2.4055, Train Accuracy: 37.50%
#     Worker 4: Train Loss: 2.3653, Train Accuracy: 38.85%
#     Worker 5: Train Loss: 2.4079, Train Accuracy: 36.98%
#     Worker 6: Train Loss: 2.4102, Train Accuracy: 37.49%
#     Worker 7: Train Loss: 2.3951, Train Accuracy: 37.07%
# Epoch 53/150: Test Loss: 2.1853, Test Accuracy: 44.31%
#     Worker 0: Train Loss: 2.3898, Train Accuracy: 37.90%
#     Worker 1: Train Loss: 2.3841, Train Accuracy: 37.95%
#     Worker 2: Train Loss: 2.3996, Train Accuracy: 38.83%
#     Worker 3: Train Loss: 2.4131, Train Accuracy: 36.96%
#     Worker 4: Train Loss: 2.3363, Train Accuracy: 39.12%
#     Worker 5: Train Loss: 2.3816, Train Accuracy: 38.00%
#     Worker 6: Train Loss: 2.4500, Train Accuracy: 35.63%
#     Worker 7: Train Loss: 2.4072, Train Accuracy: 37.81%
# Epoch 54/150: Test Loss: 2.1275, Test Accuracy: 45.59%
#     Worker 0: Train Loss: 2.3722, Train Accuracy: 38.77%
#     Worker 1: Train Loss: 2.3255, Train Accuracy: 38.43%
#     Worker 2: Train Loss: 2.3567, Train Accuracy: 38.30%
#     Worker 3: Train Loss: 2.4014, Train Accuracy: 38.32%
#     Worker 4: Train Loss: 2.3617, Train Accuracy: 38.64%
#     Worker 5: Train Loss: 2.3645, Train Accuracy: 38.82%
#     Worker 6: Train Loss: 2.4097, Train Accuracy: 37.44%
#     Worker 7: Train Loss: 2.3559, Train Accuracy: 38.58%
# Epoch 55/150: Test Loss: 2.1343, Test Accuracy: 45.93%
#     Worker 0: Train Loss: 2.3745, Train Accuracy: 38.37%
#     Worker 1: Train Loss: 2.3373, Train Accuracy: 38.45%
#     Worker 2: Train Loss: 2.3378, Train Accuracy: 39.06%
#     Worker 3: Train Loss: 2.3884, Train Accuracy: 37.38%
#     Worker 4: Train Loss: 2.3184, Train Accuracy: 39.84%
#     Worker 5: Train Loss: 2.3672, Train Accuracy: 38.88%
#     Worker 6: Train Loss: 2.3802, Train Accuracy: 38.29%
#     Worker 7: Train Loss: 2.3594, Train Accuracy: 38.29%
# Epoch 56/150: Test Loss: 2.1209, Test Accuracy: 45.55%
#     Worker 0: Train Loss: 2.3381, Train Accuracy: 39.28%
#     Worker 1: Train Loss: 2.3333, Train Accuracy: 39.12%
#     Worker 2: Train Loss: 2.3534, Train Accuracy: 38.83%
#     Worker 3: Train Loss: 2.3433, Train Accuracy: 38.61%
#     Worker 4: Train Loss: 2.3247, Train Accuracy: 39.63%
#     Worker 5: Train Loss: 2.2987, Train Accuracy: 40.53%
#     Worker 6: Train Loss: 2.3832, Train Accuracy: 37.97%
#     Worker 7: Train Loss: 2.3589, Train Accuracy: 39.06%
# Epoch 57/150: Test Loss: 2.1145, Test Accuracy: 45.98%
#     Worker 0: Train Loss: 2.3499, Train Accuracy: 39.44%
#     Worker 1: Train Loss: 2.2703, Train Accuracy: 39.73%
#     Worker 2: Train Loss: 2.2826, Train Accuracy: 40.18%
#     Worker 3: Train Loss: 2.3275, Train Accuracy: 38.83%
#     Worker 4: Train Loss: 2.2796, Train Accuracy: 40.22%
#     Worker 5: Train Loss: 2.3251, Train Accuracy: 39.65%
#     Worker 6: Train Loss: 2.3244, Train Accuracy: 39.65%
#     Worker 7: Train Loss: 2.3229, Train Accuracy: 39.70%
# Epoch 58/150: Test Loss: 2.1018, Test Accuracy: 46.09%
#     Worker 0: Train Loss: 2.3457, Train Accuracy: 38.51%
#     Worker 1: Train Loss: 2.2802, Train Accuracy: 39.14%
#     Worker 2: Train Loss: 2.3420, Train Accuracy: 39.46%
#     Worker 3: Train Loss: 2.2963, Train Accuracy: 39.92%
#     Worker 4: Train Loss: 2.2924, Train Accuracy: 39.60%
#     Worker 5: Train Loss: 2.3259, Train Accuracy: 38.93%
#     Worker 6: Train Loss: 2.3140, Train Accuracy: 38.78%
#     Worker 7: Train Loss: 2.3127, Train Accuracy: 39.50%
# Epoch 59/150: Test Loss: 2.1073, Test Accuracy: 46.05%
#     Worker 0: Train Loss: 2.3093, Train Accuracy: 40.19%
#     Worker 1: Train Loss: 2.2767, Train Accuracy: 40.40%
#     Worker 2: Train Loss: 2.2900, Train Accuracy: 40.54%
#     Worker 3: Train Loss: 2.3215, Train Accuracy: 39.63%
#     Worker 4: Train Loss: 2.2355, Train Accuracy: 41.09%
#     Worker 5: Train Loss: 2.2594, Train Accuracy: 40.88%
#     Worker 6: Train Loss: 2.3292, Train Accuracy: 39.44%
#     Worker 7: Train Loss: 2.2620, Train Accuracy: 40.08%
# Epoch 60/150: Test Loss: 2.0890, Test Accuracy: 46.14%
#     Worker 0: Train Loss: 2.3012, Train Accuracy: 39.46%
#     Worker 1: Train Loss: 2.2670, Train Accuracy: 40.74%
#     Worker 2: Train Loss: 2.2647, Train Accuracy: 40.13%
#     Worker 3: Train Loss: 2.3216, Train Accuracy: 39.17%
#     Worker 4: Train Loss: 2.2425, Train Accuracy: 40.61%
#     Worker 5: Train Loss: 2.2705, Train Accuracy: 40.78%
#     Worker 6: Train Loss: 2.2840, Train Accuracy: 40.32%
#     Worker 7: Train Loss: 2.2781, Train Accuracy: 40.64%
# Epoch 61/150: Test Loss: 2.0918, Test Accuracy: 46.67%
#     Worker 0: Train Loss: 2.3005, Train Accuracy: 39.68%
#     Worker 1: Train Loss: 2.2144, Train Accuracy: 41.36%
#     Worker 2: Train Loss: 2.2871, Train Accuracy: 40.51%
#     Worker 3: Train Loss: 2.2570, Train Accuracy: 40.11%
#     Worker 4: Train Loss: 2.2535, Train Accuracy: 40.53%
#     Worker 5: Train Loss: 2.2290, Train Accuracy: 41.49%
#     Worker 6: Train Loss: 2.2841, Train Accuracy: 41.22%
#     Worker 7: Train Loss: 2.2543, Train Accuracy: 40.51%
# Epoch 62/150: Test Loss: 2.0760, Test Accuracy: 46.71%
#     Worker 0: Train Loss: 2.2752, Train Accuracy: 40.27%
#     Worker 1: Train Loss: 2.2227, Train Accuracy: 41.58%
#     Worker 2: Train Loss: 2.2897, Train Accuracy: 40.83%
#     Worker 3: Train Loss: 2.2992, Train Accuracy: 40.00%
#     Worker 4: Train Loss: 2.1940, Train Accuracy: 42.35%
#     Worker 5: Train Loss: 2.2025, Train Accuracy: 42.30%
#     Worker 6: Train Loss: 2.2708, Train Accuracy: 40.02%
#     Worker 7: Train Loss: 2.2627, Train Accuracy: 40.19%
# Epoch 63/150: Test Loss: 2.0700, Test Accuracy: 46.35%
#     Worker 0: Train Loss: 2.2241, Train Accuracy: 41.55%
#     Worker 1: Train Loss: 2.2074, Train Accuracy: 42.11%
#     Worker 2: Train Loss: 2.2255, Train Accuracy: 41.71%
#     Worker 3: Train Loss: 2.2324, Train Accuracy: 41.47%
#     Worker 4: Train Loss: 2.2374, Train Accuracy: 41.01%
#     Worker 5: Train Loss: 2.2195, Train Accuracy: 41.17%
#     Worker 6: Train Loss: 2.2290, Train Accuracy: 41.33%
#     Worker 7: Train Loss: 2.2413, Train Accuracy: 41.36%
# Epoch 64/150: Test Loss: 2.0652, Test Accuracy: 47.24%
#     Worker 0: Train Loss: 2.2266, Train Accuracy: 41.39%
#     Worker 1: Train Loss: 2.1879, Train Accuracy: 42.02%
#     Worker 2: Train Loss: 2.2210, Train Accuracy: 42.10%
#     Worker 3: Train Loss: 2.2376, Train Accuracy: 40.78%
#     Worker 4: Train Loss: 2.1780, Train Accuracy: 42.80%
#     Worker 5: Train Loss: 2.1890, Train Accuracy: 42.50%
#     Worker 6: Train Loss: 2.2137, Train Accuracy: 41.07%
#     Worker 7: Train Loss: 2.2314, Train Accuracy: 41.34%
# Epoch 65/150: Test Loss: 2.0428, Test Accuracy: 47.44%
#     Worker 0: Train Loss: 2.2227, Train Accuracy: 41.06%
#     Worker 1: Train Loss: 2.2056, Train Accuracy: 42.08%
#     Worker 2: Train Loss: 2.2262, Train Accuracy: 41.60%
#     Worker 3: Train Loss: 2.2257, Train Accuracy: 41.54%
#     Worker 4: Train Loss: 2.1587, Train Accuracy: 42.61%
#     Worker 5: Train Loss: 2.2172, Train Accuracy: 41.63%
#     Worker 6: Train Loss: 2.1975, Train Accuracy: 41.74%
#     Worker 7: Train Loss: 2.2062, Train Accuracy: 42.75%
# Epoch 66/150: Test Loss: 2.0432, Test Accuracy: 47.35%
#     Worker 0: Train Loss: 2.2120, Train Accuracy: 42.13%
#     Worker 1: Train Loss: 2.2246, Train Accuracy: 40.94%
#     Worker 2: Train Loss: 2.2161, Train Accuracy: 41.58%
#     Worker 3: Train Loss: 2.2057, Train Accuracy: 41.57%
#     Worker 4: Train Loss: 2.1416, Train Accuracy: 43.25%
#     Worker 5: Train Loss: 2.1685, Train Accuracy: 42.69%
#     Worker 6: Train Loss: 2.2053, Train Accuracy: 42.26%
#     Worker 7: Train Loss: 2.2035, Train Accuracy: 41.95%
# Epoch 67/150: Test Loss: 2.0318, Test Accuracy: 47.99%
#     Worker 0: Train Loss: 2.1661, Train Accuracy: 41.73%
#     Worker 1: Train Loss: 2.1544, Train Accuracy: 42.40%
#     Worker 2: Train Loss: 2.1855, Train Accuracy: 42.67%
#     Worker 3: Train Loss: 2.1983, Train Accuracy: 41.94%
#     Worker 4: Train Loss: 2.0924, Train Accuracy: 43.78%
#     Worker 5: Train Loss: 2.1574, Train Accuracy: 42.82%
#     Worker 6: Train Loss: 2.1754, Train Accuracy: 42.27%
#     Worker 7: Train Loss: 2.1713, Train Accuracy: 42.38%
# Epoch 68/150: Test Loss: 2.0305, Test Accuracy: 47.81%
#     Worker 0: Train Loss: 2.2045, Train Accuracy: 41.65%
#     Worker 1: Train Loss: 2.1729, Train Accuracy: 42.67%
#     Worker 2: Train Loss: 2.1674, Train Accuracy: 42.82%
#     Worker 3: Train Loss: 2.1803, Train Accuracy: 41.74%
#     Worker 4: Train Loss: 2.0957, Train Accuracy: 43.81%
#     Worker 5: Train Loss: 2.1863, Train Accuracy: 42.90%
#     Worker 6: Train Loss: 2.1726, Train Accuracy: 42.72%
#     Worker 7: Train Loss: 2.1460, Train Accuracy: 43.79%
# Epoch 69/150: Test Loss: 2.0204, Test Accuracy: 47.91%
#     Worker 0: Train Loss: 2.1462, Train Accuracy: 42.72%
#     Worker 1: Train Loss: 2.1144, Train Accuracy: 43.98%
#     Worker 2: Train Loss: 2.1371, Train Accuracy: 43.54%
#     Worker 3: Train Loss: 2.1427, Train Accuracy: 43.26%
#     Worker 4: Train Loss: 2.1061, Train Accuracy: 43.68%
#     Worker 5: Train Loss: 2.1434, Train Accuracy: 43.15%
#     Worker 6: Train Loss: 2.1572, Train Accuracy: 42.59%
#     Worker 7: Train Loss: 2.1069, Train Accuracy: 43.79%
# Epoch 70/150: Test Loss: 2.0103, Test Accuracy: 47.81%
#     Worker 0: Train Loss: 2.1326, Train Accuracy: 43.18%
#     Worker 1: Train Loss: 2.1221, Train Accuracy: 44.42%
#     Worker 2: Train Loss: 2.1095, Train Accuracy: 43.98%
#     Worker 3: Train Loss: 2.1612, Train Accuracy: 42.94%
#     Worker 4: Train Loss: 2.0764, Train Accuracy: 44.78%
#     Worker 5: Train Loss: 2.1150, Train Accuracy: 44.64%
#     Worker 6: Train Loss: 2.1339, Train Accuracy: 43.44%
#     Worker 7: Train Loss: 2.1091, Train Accuracy: 44.29%
# Epoch 71/150: Test Loss: 2.0096, Test Accuracy: 47.96%
#     Worker 0: Train Loss: 2.1353, Train Accuracy: 42.56%
#     Worker 1: Train Loss: 2.1298, Train Accuracy: 43.82%
#     Worker 2: Train Loss: 2.1189, Train Accuracy: 43.46%
#     Worker 3: Train Loss: 2.1385, Train Accuracy: 43.18%
#     Worker 4: Train Loss: 2.0463, Train Accuracy: 44.59%
#     Worker 5: Train Loss: 2.1113, Train Accuracy: 44.30%
#     Worker 6: Train Loss: 2.1437, Train Accuracy: 42.56%
#     Worker 7: Train Loss: 2.1245, Train Accuracy: 43.23%
# Epoch 72/150: Test Loss: 2.0140, Test Accuracy: 48.41%
#     Worker 0: Train Loss: 2.1370, Train Accuracy: 43.41%
#     Worker 1: Train Loss: 2.1194, Train Accuracy: 43.81%
#     Worker 2: Train Loss: 2.0947, Train Accuracy: 44.22%
#     Worker 3: Train Loss: 2.1382, Train Accuracy: 43.74%
#     Worker 4: Train Loss: 2.0931, Train Accuracy: 44.72%
#     Worker 5: Train Loss: 2.0685, Train Accuracy: 45.76%
#     Worker 6: Train Loss: 2.1079, Train Accuracy: 43.70%
#     Worker 7: Train Loss: 2.1121, Train Accuracy: 44.46%
# Epoch 73/150: Test Loss: 2.0021, Test Accuracy: 48.32%
#     Worker 0: Train Loss: 2.1231, Train Accuracy: 43.10%
#     Worker 1: Train Loss: 2.0667, Train Accuracy: 44.05%
#     Worker 2: Train Loss: 2.0890, Train Accuracy: 44.96%
#     Worker 3: Train Loss: 2.1158, Train Accuracy: 44.21%
#     Worker 4: Train Loss: 2.0596, Train Accuracy: 45.10%
#     Worker 5: Train Loss: 2.0797, Train Accuracy: 44.61%
#     Worker 6: Train Loss: 2.1030, Train Accuracy: 43.50%
#     Worker 7: Train Loss: 2.0908, Train Accuracy: 43.84%
# Epoch 74/150: Test Loss: 1.9820, Test Accuracy: 48.61%
#     Worker 0: Train Loss: 2.0675, Train Accuracy: 44.59%
#     Worker 1: Train Loss: 2.0255, Train Accuracy: 46.51%
#     Worker 2: Train Loss: 2.0685, Train Accuracy: 44.30%
#     Worker 3: Train Loss: 2.1087, Train Accuracy: 44.06%
#     Worker 4: Train Loss: 2.0625, Train Accuracy: 43.98%
#     Worker 5: Train Loss: 2.0726, Train Accuracy: 45.15%
#     Worker 6: Train Loss: 2.1140, Train Accuracy: 44.51%
#     Worker 7: Train Loss: 2.0774, Train Accuracy: 43.97%
# Epoch 75/150: Test Loss: 1.9828, Test Accuracy: 48.62%
#     Worker 0: Train Loss: 2.0717, Train Accuracy: 44.83%
#     Worker 1: Train Loss: 2.0626, Train Accuracy: 45.02%
#     Worker 2: Train Loss: 2.0500, Train Accuracy: 46.14%
#     Worker 3: Train Loss: 2.1082, Train Accuracy: 43.50%
#     Worker 4: Train Loss: 2.0055, Train Accuracy: 45.82%
#     Worker 5: Train Loss: 2.0512, Train Accuracy: 45.79%
#     Worker 6: Train Loss: 2.0606, Train Accuracy: 45.04%
#     Worker 7: Train Loss: 2.0134, Train Accuracy: 45.90%
# Epoch 76/150: Test Loss: 1.9707, Test Accuracy: 48.86%
#     Worker 0: Train Loss: 2.0860, Train Accuracy: 43.65%
#     Worker 1: Train Loss: 2.0080, Train Accuracy: 45.74%
#     Worker 2: Train Loss: 2.0769, Train Accuracy: 45.07%
#     Worker 3: Train Loss: 2.0869, Train Accuracy: 44.40%
#     Worker 4: Train Loss: 1.9930, Train Accuracy: 46.38%
#     Worker 5: Train Loss: 2.0406, Train Accuracy: 45.50%
#     Worker 6: Train Loss: 2.0797, Train Accuracy: 44.64%
#     Worker 7: Train Loss: 1.9859, Train Accuracy: 46.61%
# Epoch 77/150: Test Loss: 1.9748, Test Accuracy: 49.06%
#     Worker 0: Train Loss: 2.0584, Train Accuracy: 45.42%
#     Worker 1: Train Loss: 2.0433, Train Accuracy: 45.68%
#     Worker 2: Train Loss: 2.0686, Train Accuracy: 44.98%
#     Worker 3: Train Loss: 2.0344, Train Accuracy: 45.82%
#     Worker 4: Train Loss: 1.9915, Train Accuracy: 46.11%
#     Worker 5: Train Loss: 2.0387, Train Accuracy: 45.25%
#     Worker 6: Train Loss: 2.0519, Train Accuracy: 45.09%
#     Worker 7: Train Loss: 2.0163, Train Accuracy: 46.40%
# Epoch 78/150: Test Loss: 1.9598, Test Accuracy: 49.13%
#     Worker 0: Train Loss: 2.0341, Train Accuracy: 45.12%
#     Worker 1: Train Loss: 1.9912, Train Accuracy: 46.69%
#     Worker 2: Train Loss: 2.0211, Train Accuracy: 45.86%
#     Worker 3: Train Loss: 2.0317, Train Accuracy: 45.81%
#     Worker 4: Train Loss: 1.9970, Train Accuracy: 45.73%
#     Worker 5: Train Loss: 1.9961, Train Accuracy: 46.46%
#     Worker 6: Train Loss: 2.0302, Train Accuracy: 45.62%
#     Worker 7: Train Loss: 2.0428, Train Accuracy: 45.18%
# Epoch 79/150: Test Loss: 1.9577, Test Accuracy: 49.12%
#     Worker 0: Train Loss: 2.0197, Train Accuracy: 44.82%
#     Worker 1: Train Loss: 1.9994, Train Accuracy: 46.69%
#     Worker 2: Train Loss: 1.9890, Train Accuracy: 46.99%
#     Worker 3: Train Loss: 1.9977, Train Accuracy: 46.69%
#     Worker 4: Train Loss: 1.9652, Train Accuracy: 47.06%
#     Worker 5: Train Loss: 2.0092, Train Accuracy: 46.90%
#     Worker 6: Train Loss: 1.9895, Train Accuracy: 46.46%
#     Worker 7: Train Loss: 1.9999, Train Accuracy: 46.35%
# Epoch 80/150: Test Loss: 1.9488, Test Accuracy: 49.49%
#     Worker 0: Train Loss: 1.9966, Train Accuracy: 46.43%
#     Worker 1: Train Loss: 2.0113, Train Accuracy: 45.68%
#     Worker 2: Train Loss: 2.0031, Train Accuracy: 46.24%
#     Worker 3: Train Loss: 2.0029, Train Accuracy: 45.94%
#     Worker 4: Train Loss: 1.9649, Train Accuracy: 47.39%
#     Worker 5: Train Loss: 1.9977, Train Accuracy: 46.94%
#     Worker 6: Train Loss: 2.0149, Train Accuracy: 45.74%
#     Worker 7: Train Loss: 2.0099, Train Accuracy: 46.29%
# Epoch 81/150: Test Loss: 1.9345, Test Accuracy: 49.76%
#     Worker 0: Train Loss: 2.0161, Train Accuracy: 46.11%
#     Worker 1: Train Loss: 1.9688, Train Accuracy: 47.38%
#     Worker 2: Train Loss: 2.0160, Train Accuracy: 46.72%
#     Worker 3: Train Loss: 1.9698, Train Accuracy: 46.13%
#     Worker 4: Train Loss: 1.9408, Train Accuracy: 47.50%
#     Worker 5: Train Loss: 1.9508, Train Accuracy: 48.05%
#     Worker 6: Train Loss: 1.9705, Train Accuracy: 46.38%
#     Worker 7: Train Loss: 1.9611, Train Accuracy: 47.09%
# Epoch 82/150: Test Loss: 1.9388, Test Accuracy: 49.76%
#     Worker 0: Train Loss: 1.9555, Train Accuracy: 47.62%
#     Worker 1: Train Loss: 1.9687, Train Accuracy: 46.56%
#     Worker 2: Train Loss: 1.9881, Train Accuracy: 46.83%
#     Worker 3: Train Loss: 1.9726, Train Accuracy: 46.94%
#     Worker 4: Train Loss: 1.8997, Train Accuracy: 48.43%
#     Worker 5: Train Loss: 1.9210, Train Accuracy: 47.89%
#     Worker 6: Train Loss: 2.0081, Train Accuracy: 46.19%
#     Worker 7: Train Loss: 1.9278, Train Accuracy: 47.18%
# Epoch 83/150: Test Loss: 1.9371, Test Accuracy: 49.91%
#     Worker 0: Train Loss: 1.9921, Train Accuracy: 46.61%
#     Worker 1: Train Loss: 1.9292, Train Accuracy: 47.60%
#     Worker 2: Train Loss: 1.9330, Train Accuracy: 47.50%
#     Worker 3: Train Loss: 1.9555, Train Accuracy: 47.41%
#     Worker 4: Train Loss: 1.9138, Train Accuracy: 48.06%
#     Worker 5: Train Loss: 1.9571, Train Accuracy: 47.07%
#     Worker 6: Train Loss: 1.9821, Train Accuracy: 46.93%
#     Worker 7: Train Loss: 1.9442, Train Accuracy: 47.66%
# Epoch 84/150: Test Loss: 1.9254, Test Accuracy: 50.14%
#     Worker 0: Train Loss: 1.9526, Train Accuracy: 47.26%
#     Worker 1: Train Loss: 1.9432, Train Accuracy: 47.41%
#     Worker 2: Train Loss: 1.9373, Train Accuracy: 47.65%
#     Worker 3: Train Loss: 1.9427, Train Accuracy: 47.28%
#     Worker 4: Train Loss: 1.8959, Train Accuracy: 49.57%
#     Worker 5: Train Loss: 1.9310, Train Accuracy: 48.26%
#     Worker 6: Train Loss: 1.9398, Train Accuracy: 47.52%
#     Worker 7: Train Loss: 1.9643, Train Accuracy: 47.47%
# Epoch 85/150: Test Loss: 1.9316, Test Accuracy: 49.69%
#     Worker 0: Train Loss: 1.9292, Train Accuracy: 47.50%
#     Worker 1: Train Loss: 1.9170, Train Accuracy: 48.18%
#     Worker 2: Train Loss: 1.8751, Train Accuracy: 49.14%
#     Worker 3: Train Loss: 1.8966, Train Accuracy: 48.45%
#     Worker 4: Train Loss: 1.8618, Train Accuracy: 48.78%
#     Worker 5: Train Loss: 1.9357, Train Accuracy: 48.48%
#     Worker 6: Train Loss: 1.9376, Train Accuracy: 47.42%
#     Worker 7: Train Loss: 1.8986, Train Accuracy: 48.56%
# Epoch 86/150: Test Loss: 1.9147, Test Accuracy: 50.11%
#     Worker 0: Train Loss: 1.8967, Train Accuracy: 48.06%
#     Worker 1: Train Loss: 1.8605, Train Accuracy: 49.76%
#     Worker 2: Train Loss: 1.9040, Train Accuracy: 48.61%
#     Worker 3: Train Loss: 1.9311, Train Accuracy: 48.21%
#     Worker 4: Train Loss: 1.8602, Train Accuracy: 49.46%
#     Worker 5: Train Loss: 1.8737, Train Accuracy: 49.06%
#     Worker 6: Train Loss: 1.9384, Train Accuracy: 47.82%
#     Worker 7: Train Loss: 1.9157, Train Accuracy: 48.00%
# Epoch 87/150: Test Loss: 1.9130, Test Accuracy: 50.02%
#     Worker 0: Train Loss: 1.9459, Train Accuracy: 47.63%
#     Worker 1: Train Loss: 1.8595, Train Accuracy: 48.94%
#     Worker 2: Train Loss: 1.8805, Train Accuracy: 48.50%
#     Worker 3: Train Loss: 1.8507, Train Accuracy: 49.71%
#     Worker 4: Train Loss: 1.8408, Train Accuracy: 50.14%
#     Worker 5: Train Loss: 1.8841, Train Accuracy: 48.72%
#     Worker 6: Train Loss: 1.9366, Train Accuracy: 48.06%
#     Worker 7: Train Loss: 1.8960, Train Accuracy: 48.80%
# Epoch 88/150: Test Loss: 1.9184, Test Accuracy: 49.99%
#     Worker 0: Train Loss: 1.9314, Train Accuracy: 47.44%
#     Worker 1: Train Loss: 1.8684, Train Accuracy: 49.33%
#     Worker 2: Train Loss: 1.9112, Train Accuracy: 48.58%
#     Worker 3: Train Loss: 1.8657, Train Accuracy: 49.55%
#     Worker 4: Train Loss: 1.8227, Train Accuracy: 50.29%
#     Worker 5: Train Loss: 1.8671, Train Accuracy: 48.51%
#     Worker 6: Train Loss: 1.9367, Train Accuracy: 47.23%
#     Worker 7: Train Loss: 1.8689, Train Accuracy: 48.86%
# Epoch 89/150: Test Loss: 1.9079, Test Accuracy: 50.43%
#     Worker 0: Train Loss: 1.8682, Train Accuracy: 49.04%
#     Worker 1: Train Loss: 1.8760, Train Accuracy: 48.98%
#     Worker 2: Train Loss: 1.8550, Train Accuracy: 50.26%
#     Worker 3: Train Loss: 1.8579, Train Accuracy: 49.36%
#     Worker 4: Train Loss: 1.8279, Train Accuracy: 50.35%
#     Worker 5: Train Loss: 1.8407, Train Accuracy: 50.10%
#     Worker 6: Train Loss: 1.8942, Train Accuracy: 48.19%
#     Worker 7: Train Loss: 1.8319, Train Accuracy: 49.62%
# Epoch 90/150: Test Loss: 1.9092, Test Accuracy: 50.43%
#     Worker 0: Train Loss: 1.8826, Train Accuracy: 49.44%
#     Worker 1: Train Loss: 1.8689, Train Accuracy: 49.63%
#     Worker 2: Train Loss: 1.8133, Train Accuracy: 50.34%
#     Worker 3: Train Loss: 1.8394, Train Accuracy: 50.02%
#     Worker 4: Train Loss: 1.8178, Train Accuracy: 50.19%
#     Worker 5: Train Loss: 1.8537, Train Accuracy: 49.50%
#     Worker 6: Train Loss: 1.8687, Train Accuracy: 49.62%
#     Worker 7: Train Loss: 1.8886, Train Accuracy: 49.02%
# Epoch 91/150: Test Loss: 1.8994, Test Accuracy: 50.50%
#     Worker 0: Train Loss: 1.8379, Train Accuracy: 50.46%
#     Worker 1: Train Loss: 1.8244, Train Accuracy: 49.82%
#     Worker 2: Train Loss: 1.8482, Train Accuracy: 49.95%
#     Worker 3: Train Loss: 1.8503, Train Accuracy: 49.70%
#     Worker 4: Train Loss: 1.7978, Train Accuracy: 50.70%
#     Worker 5: Train Loss: 1.8253, Train Accuracy: 50.46%
#     Worker 6: Train Loss: 1.8238, Train Accuracy: 49.84%
#     Worker 7: Train Loss: 1.8292, Train Accuracy: 50.85%
# Epoch 92/150: Test Loss: 1.9095, Test Accuracy: 50.08%
#     Worker 0: Train Loss: 1.8551, Train Accuracy: 48.74%
#     Worker 1: Train Loss: 1.8258, Train Accuracy: 50.24%
#     Worker 2: Train Loss: 1.8149, Train Accuracy: 50.88%
#     Worker 3: Train Loss: 1.8529, Train Accuracy: 49.50%
#     Worker 4: Train Loss: 1.8072, Train Accuracy: 50.11%
#     Worker 5: Train Loss: 1.8256, Train Accuracy: 49.81%
#     Worker 6: Train Loss: 1.8912, Train Accuracy: 49.04%
#     Worker 7: Train Loss: 1.8126, Train Accuracy: 50.43%
# Epoch 93/150: Test Loss: 1.8925, Test Accuracy: 50.91%
#     Worker 0: Train Loss: 1.8411, Train Accuracy: 49.17%
#     Worker 1: Train Loss: 1.7808, Train Accuracy: 51.39%
#     Worker 2: Train Loss: 1.8044, Train Accuracy: 51.18%
# ...
#     Worker 6: Train Loss: 1.4698, Train Accuracy: 57.92%
#     Worker 7: Train Loss: 1.4302, Train Accuracy: 59.34%
# Epoch 120/150: Test Loss: 1.8233, Test Accuracy: 52.78%
#     Worker 0: Train Loss: 1.4550, Train Accuracy: 58.40%
#     Worker 1: Train Loss: 1.3976, Train Accuracy: 59.79%
#     Worker 2: Train Loss: 1.4151, Train Accuracy: 60.22%
#     Worker 3: Train Loss: 1.4244, Train Accuracy: 59.14%
#     Worker 4: Train Loss: 1.4283, Train Accuracy: 59.02%
#     Worker 5: Train Loss: 1.4159, Train Accuracy: 59.73%
#     Worker 6: Train Loss: 1.4455, Train Accuracy: 58.72%
#     Worker 7: Train Loss: 1.4215, Train Accuracy: 59.31%
# Epoch 121/150: Test Loss: 1.8116, Test Accuracy: 53.35%
#     Worker 0: Train Loss: 1.4294, Train Accuracy: 59.36%
#     Worker 1: Train Loss: 1.3884, Train Accuracy: 60.38%
#     Worker 2: Train Loss: 1.4136, Train Accuracy: 60.10%
#     Worker 3: Train Loss: 1.3936, Train Accuracy: 60.32%
#     Worker 4: Train Loss: 1.3702, Train Accuracy: 60.93%
#     Worker 5: Train Loss: 1.3830, Train Accuracy: 60.46%
#     Worker 6: Train Loss: 1.4083, Train Accuracy: 60.26%
#     Worker 7: Train Loss: 1.4090, Train Accuracy: 59.82%
# Epoch 122/150: Test Loss: 1.8188, Test Accuracy: 53.11%
#     Worker 0: Train Loss: 1.4064, Train Accuracy: 60.14%
#     Worker 1: Train Loss: 1.3824, Train Accuracy: 60.06%
#     Worker 2: Train Loss: 1.3568, Train Accuracy: 61.42%
#     Worker 3: Train Loss: 1.3642, Train Accuracy: 60.72%
#     Worker 4: Train Loss: 1.3412, Train Accuracy: 61.42%
#     Worker 5: Train Loss: 1.3835, Train Accuracy: 60.99%
#     Worker 6: Train Loss: 1.3809, Train Accuracy: 60.78%
#     Worker 7: Train Loss: 1.3854, Train Accuracy: 60.80%
# Epoch 123/150: Test Loss: 1.8222, Test Accuracy: 52.97%
#     Worker 0: Train Loss: 1.3881, Train Accuracy: 60.53%
#     Worker 1: Train Loss: 1.3421, Train Accuracy: 61.34%
#     Worker 2: Train Loss: 1.3598, Train Accuracy: 62.13%
#     Worker 3: Train Loss: 1.3553, Train Accuracy: 61.36%
#     Worker 4: Train Loss: 1.3397, Train Accuracy: 61.33%
#     Worker 5: Train Loss: 1.3580, Train Accuracy: 61.87%
#     Worker 6: Train Loss: 1.3658, Train Accuracy: 60.48%
#     Worker 7: Train Loss: 1.3667, Train Accuracy: 60.86%
# Epoch 124/150: Test Loss: 1.8175, Test Accuracy: 52.88%
#     Worker 0: Train Loss: 1.3612, Train Accuracy: 61.14%
#     Worker 1: Train Loss: 1.3492, Train Accuracy: 61.52%
#     Worker 2: Train Loss: 1.3333, Train Accuracy: 61.46%
#     Worker 3: Train Loss: 1.3648, Train Accuracy: 61.79%
#     Worker 4: Train Loss: 1.3189, Train Accuracy: 62.54%
#     Worker 5: Train Loss: 1.3559, Train Accuracy: 61.12%
#     Worker 6: Train Loss: 1.3508, Train Accuracy: 61.58%
#     Worker 7: Train Loss: 1.3372, Train Accuracy: 61.63%
# Epoch 125/150: Test Loss: 1.8209, Test Accuracy: 53.45%
#     Worker 0: Train Loss: 1.3369, Train Accuracy: 61.17%
#     Worker 1: Train Loss: 1.3390, Train Accuracy: 61.89%
#     Worker 2: Train Loss: 1.3597, Train Accuracy: 61.02%
#     Worker 3: Train Loss: 1.3573, Train Accuracy: 61.01%
#     Worker 4: Train Loss: 1.3074, Train Accuracy: 62.61%
#     Worker 5: Train Loss: 1.3401, Train Accuracy: 61.57%
#     Worker 6: Train Loss: 1.3601, Train Accuracy: 61.31%
#     Worker 7: Train Loss: 1.3115, Train Accuracy: 62.77%
# Epoch 126/150: Test Loss: 1.8146, Test Accuracy: 53.52%
#     Worker 0: Train Loss: 1.3621, Train Accuracy: 60.88%
#     Worker 1: Train Loss: 1.2967, Train Accuracy: 61.98%
#     Worker 2: Train Loss: 1.3193, Train Accuracy: 62.27%
#     Worker 3: Train Loss: 1.3281, Train Accuracy: 61.41%
#     Worker 4: Train Loss: 1.2991, Train Accuracy: 61.76%
#     Worker 5: Train Loss: 1.3135, Train Accuracy: 62.37%
#     Worker 6: Train Loss: 1.3560, Train Accuracy: 61.44%
#     Worker 7: Train Loss: 1.3059, Train Accuracy: 62.05%
# Epoch 127/150: Test Loss: 1.8312, Test Accuracy: 53.11%
#     Worker 0: Train Loss: 1.3456, Train Accuracy: 61.66%
#     Worker 1: Train Loss: 1.2959, Train Accuracy: 62.59%
#     Worker 2: Train Loss: 1.2923, Train Accuracy: 62.88%
#     Worker 3: Train Loss: 1.3224, Train Accuracy: 62.67%
#     Worker 4: Train Loss: 1.3093, Train Accuracy: 62.13%
#     Worker 5: Train Loss: 1.3255, Train Accuracy: 61.81%
#     Worker 6: Train Loss: 1.3253, Train Accuracy: 62.35%
#     Worker 7: Train Loss: 1.2942, Train Accuracy: 63.20%
# Epoch 128/150: Test Loss: 1.8265, Test Accuracy: 53.32%
#     Worker 0: Train Loss: 1.2828, Train Accuracy: 63.84%
#     Worker 1: Train Loss: 1.2596, Train Accuracy: 64.21%
#     Worker 2: Train Loss: 1.2828, Train Accuracy: 62.91%
#     Worker 3: Train Loss: 1.2971, Train Accuracy: 62.37%
#     Worker 4: Train Loss: 1.2783, Train Accuracy: 63.28%
#     Worker 5: Train Loss: 1.2956, Train Accuracy: 63.36%
#     Worker 6: Train Loss: 1.2838, Train Accuracy: 63.14%
#     Worker 7: Train Loss: 1.2790, Train Accuracy: 63.38%
# Epoch 129/150: Test Loss: 1.8212, Test Accuracy: 53.13%
#     Worker 0: Train Loss: 1.3223, Train Accuracy: 62.03%
#     Worker 1: Train Loss: 1.2750, Train Accuracy: 63.78%
#     Worker 2: Train Loss: 1.2499, Train Accuracy: 64.38%
#     Worker 3: Train Loss: 1.2852, Train Accuracy: 63.09%
#     Worker 4: Train Loss: 1.2694, Train Accuracy: 63.12%
#     Worker 5: Train Loss: 1.3011, Train Accuracy: 62.62%
#     Worker 6: Train Loss: 1.3022, Train Accuracy: 62.22%
#     Worker 7: Train Loss: 1.2719, Train Accuracy: 63.86%
# Epoch 130/150: Test Loss: 1.8170, Test Accuracy: 53.53%
#     Worker 0: Train Loss: 1.2925, Train Accuracy: 63.06%
#     Worker 1: Train Loss: 1.2701, Train Accuracy: 63.65%
#     Worker 2: Train Loss: 1.2617, Train Accuracy: 63.39%
#     Worker 3: Train Loss: 1.2915, Train Accuracy: 63.09%
#     Worker 4: Train Loss: 1.2341, Train Accuracy: 63.82%
#     Worker 5: Train Loss: 1.2565, Train Accuracy: 64.11%
#     Worker 6: Train Loss: 1.2867, Train Accuracy: 62.66%
#     Worker 7: Train Loss: 1.2376, Train Accuracy: 63.78%
# Epoch 131/150: Test Loss: 1.8255, Test Accuracy: 53.38%
#     Worker 0: Train Loss: 1.2398, Train Accuracy: 63.97%
#     Worker 1: Train Loss: 1.2404, Train Accuracy: 64.14%
#     Worker 2: Train Loss: 1.2551, Train Accuracy: 64.34%
#     Worker 3: Train Loss: 1.2587, Train Accuracy: 63.42%
#     Worker 4: Train Loss: 1.2212, Train Accuracy: 65.30%
#     Worker 5: Train Loss: 1.2607, Train Accuracy: 63.86%
#     Worker 6: Train Loss: 1.2857, Train Accuracy: 63.20%
#     Worker 7: Train Loss: 1.2344, Train Accuracy: 64.64%
# Epoch 132/150: Test Loss: 1.8213, Test Accuracy: 53.37%
#     Worker 0: Train Loss: 1.2492, Train Accuracy: 64.10%
#     Worker 1: Train Loss: 1.2332, Train Accuracy: 64.13%
#     Worker 2: Train Loss: 1.2130, Train Accuracy: 65.33%
#     Worker 3: Train Loss: 1.2463, Train Accuracy: 64.19%
#     Worker 4: Train Loss: 1.1944, Train Accuracy: 65.30%
#     Worker 5: Train Loss: 1.2192, Train Accuracy: 64.56%
#     Worker 6: Train Loss: 1.2537, Train Accuracy: 64.37%
#     Worker 7: Train Loss: 1.2444, Train Accuracy: 64.16%
# Epoch 133/150: Test Loss: 1.8193, Test Accuracy: 53.49%
#     Worker 0: Train Loss: 1.2449, Train Accuracy: 64.00%
#     Worker 1: Train Loss: 1.2098, Train Accuracy: 64.86%
#     Worker 2: Train Loss: 1.2241, Train Accuracy: 64.48%
#     Worker 3: Train Loss: 1.2352, Train Accuracy: 63.84%
#     Worker 4: Train Loss: 1.1738, Train Accuracy: 65.92%
#     Worker 5: Train Loss: 1.1936, Train Accuracy: 65.66%
#     Worker 6: Train Loss: 1.2301, Train Accuracy: 64.18%
#     Worker 7: Train Loss: 1.2039, Train Accuracy: 65.65%
# Epoch 134/150: Test Loss: 1.8196, Test Accuracy: 53.63%
#     Worker 0: Train Loss: 1.2080, Train Accuracy: 65.07%
#     Worker 1: Train Loss: 1.2123, Train Accuracy: 64.94%
#     Worker 2: Train Loss: 1.1923, Train Accuracy: 66.03%
#     Worker 3: Train Loss: 1.1990, Train Accuracy: 65.50%
#     Worker 4: Train Loss: 1.1698, Train Accuracy: 66.48%
#     Worker 5: Train Loss: 1.1988, Train Accuracy: 65.23%
#     Worker 6: Train Loss: 1.2160, Train Accuracy: 65.12%
#     Worker 7: Train Loss: 1.1938, Train Accuracy: 65.22%
# Epoch 135/150: Test Loss: 1.8315, Test Accuracy: 53.71%
#     Worker 0: Train Loss: 1.1898, Train Accuracy: 66.06%
#     Worker 1: Train Loss: 1.1841, Train Accuracy: 65.76%
#     Worker 2: Train Loss: 1.2104, Train Accuracy: 65.70%
#     Worker 3: Train Loss: 1.1737, Train Accuracy: 66.06%
#     Worker 4: Train Loss: 1.1328, Train Accuracy: 66.54%
#     Worker 5: Train Loss: 1.1653, Train Accuracy: 66.19%
#     Worker 6: Train Loss: 1.1779, Train Accuracy: 65.46%
#     Worker 7: Train Loss: 1.1931, Train Accuracy: 65.74%
# Epoch 136/150: Test Loss: 1.8314, Test Accuracy: 53.81%
#     Worker 0: Train Loss: 1.1653, Train Accuracy: 65.46%
#     Worker 1: Train Loss: 1.1845, Train Accuracy: 65.86%
#     Worker 2: Train Loss: 1.1716, Train Accuracy: 66.35%
#     Worker 3: Train Loss: 1.1798, Train Accuracy: 65.25%
#     Worker 4: Train Loss: 1.1422, Train Accuracy: 66.80%
#     Worker 5: Train Loss: 1.1752, Train Accuracy: 65.68%
#     Worker 6: Train Loss: 1.1741, Train Accuracy: 65.78%
#     Worker 7: Train Loss: 1.1664, Train Accuracy: 66.26%
# Epoch 137/150: Test Loss: 1.8245, Test Accuracy: 53.71%
#     Worker 0: Train Loss: 1.1689, Train Accuracy: 66.13%
#     Worker 1: Train Loss: 1.1586, Train Accuracy: 66.50%
#     Worker 2: Train Loss: 1.1804, Train Accuracy: 65.94%
#     Worker 3: Train Loss: 1.1585, Train Accuracy: 65.78%
#     Worker 4: Train Loss: 1.1399, Train Accuracy: 66.98%
#     Worker 5: Train Loss: 1.1587, Train Accuracy: 66.77%
#     Worker 6: Train Loss: 1.1838, Train Accuracy: 65.98%
#     Worker 7: Train Loss: 1.1612, Train Accuracy: 66.37%
# Epoch 138/150: Test Loss: 1.8297, Test Accuracy: 53.55%
#     Worker 0: Train Loss: 1.1517, Train Accuracy: 66.90%
#     Worker 1: Train Loss: 1.1223, Train Accuracy: 67.04%
#     Worker 2: Train Loss: 1.1474, Train Accuracy: 66.50%
#     Worker 3: Train Loss: 1.1494, Train Accuracy: 66.70%
#     Worker 4: Train Loss: 1.1105, Train Accuracy: 67.46%
#     Worker 5: Train Loss: 1.1264, Train Accuracy: 67.34%
#     Worker 6: Train Loss: 1.1739, Train Accuracy: 65.73%
#     Worker 7: Train Loss: 1.1326, Train Accuracy: 67.02%
# Epoch 139/150: Test Loss: 1.8367, Test Accuracy: 53.83%
#     Worker 0: Train Loss: 1.1338, Train Accuracy: 67.22%
#     Worker 1: Train Loss: 1.1349, Train Accuracy: 66.51%
#     Worker 2: Train Loss: 1.1388, Train Accuracy: 66.69%
#     Worker 3: Train Loss: 1.1174, Train Accuracy: 67.46%
#     Worker 4: Train Loss: 1.1124, Train Accuracy: 67.97%
#     Worker 5: Train Loss: 1.1345, Train Accuracy: 67.14%
#     Worker 6: Train Loss: 1.1489, Train Accuracy: 66.62%
#     Worker 7: Train Loss: 1.1191, Train Accuracy: 66.98%
# Epoch 140/150: Test Loss: 1.8363, Test Accuracy: 53.88%
#     Worker 0: Train Loss: 1.1419, Train Accuracy: 66.82%
#     Worker 1: Train Loss: 1.1089, Train Accuracy: 67.87%
#     Worker 2: Train Loss: 1.1081, Train Accuracy: 68.45%
#     Worker 3: Train Loss: 1.1083, Train Accuracy: 68.69%
#     Worker 4: Train Loss: 1.0989, Train Accuracy: 67.94%
#     Worker 5: Train Loss: 1.1287, Train Accuracy: 67.65%
#     Worker 6: Train Loss: 1.0985, Train Accuracy: 68.43%
#     Worker 7: Train Loss: 1.1188, Train Accuracy: 67.47%
# Epoch 141/150: Test Loss: 1.8357, Test Accuracy: 54.19%
#     Worker 0: Train Loss: 1.1218, Train Accuracy: 66.98%
#     Worker 1: Train Loss: 1.1051, Train Accuracy: 68.26%
#     Worker 2: Train Loss: 1.1106, Train Accuracy: 68.13%
#     Worker 3: Train Loss: 1.0974, Train Accuracy: 68.08%
#     Worker 4: Train Loss: 1.0885, Train Accuracy: 68.62%
#     Worker 5: Train Loss: 1.1223, Train Accuracy: 67.70%
#     Worker 6: Train Loss: 1.1042, Train Accuracy: 68.10%
#     Worker 7: Train Loss: 1.0839, Train Accuracy: 68.40%
# Epoch 142/150: Test Loss: 1.8410, Test Accuracy: 54.08%
#     Worker 0: Train Loss: 1.1067, Train Accuracy: 67.97%
#     Worker 1: Train Loss: 1.0712, Train Accuracy: 68.26%
#     Worker 2: Train Loss: 1.1060, Train Accuracy: 68.16%
#     Worker 3: Train Loss: 1.0852, Train Accuracy: 68.54%
#     Worker 4: Train Loss: 1.0740, Train Accuracy: 68.78%
#     Worker 5: Train Loss: 1.0859, Train Accuracy: 68.62%
#     Worker 6: Train Loss: 1.0939, Train Accuracy: 67.73%
#     Worker 7: Train Loss: 1.0801, Train Accuracy: 68.85%
# Epoch 143/150: Test Loss: 1.8442, Test Accuracy: 53.95%
#     Worker 0: Train Loss: 1.0940, Train Accuracy: 67.58%
#     Worker 1: Train Loss: 1.0687, Train Accuracy: 68.35%
#     Worker 2: Train Loss: 1.0878, Train Accuracy: 68.50%
#     Worker 3: Train Loss: 1.0587, Train Accuracy: 69.60%
#     Worker 4: Train Loss: 1.0503, Train Accuracy: 68.91%
#     Worker 5: Train Loss: 1.0668, Train Accuracy: 68.85%
#     Worker 6: Train Loss: 1.0948, Train Accuracy: 68.26%
#     Worker 7: Train Loss: 1.0736, Train Accuracy: 68.86%
# Epoch 144/150: Test Loss: 1.8482, Test Accuracy: 54.16%
#     Worker 0: Train Loss: 1.0701, Train Accuracy: 68.29%
#     Worker 1: Train Loss: 1.0748, Train Accuracy: 68.69%
#     Worker 2: Train Loss: 1.0616, Train Accuracy: 69.65%
#     Worker 3: Train Loss: 1.0740, Train Accuracy: 69.20%
#     Worker 4: Train Loss: 1.0372, Train Accuracy: 69.65%
#     Worker 5: Train Loss: 1.0519, Train Accuracy: 69.09%
#     Worker 6: Train Loss: 1.0631, Train Accuracy: 68.83%
#     Worker 7: Train Loss: 1.0583, Train Accuracy: 68.82%
# Epoch 145/150: Test Loss: 1.8479, Test Accuracy: 54.25%
#     Worker 0: Train Loss: 1.0667, Train Accuracy: 69.57%
#     Worker 1: Train Loss: 1.0515, Train Accuracy: 68.96%
#     Worker 2: Train Loss: 1.0668, Train Accuracy: 69.04%
#     Worker 3: Train Loss: 1.0678, Train Accuracy: 68.99%
#     Worker 4: Train Loss: 1.0308, Train Accuracy: 70.48%
#     Worker 5: Train Loss: 1.0491, Train Accuracy: 69.04%
#     Worker 6: Train Loss: 1.0608, Train Accuracy: 69.49%
#     Worker 7: Train Loss: 1.0402, Train Accuracy: 70.27%
# Epoch 146/150: Test Loss: 1.8489, Test Accuracy: 54.13%
#     Worker 0: Train Loss: 1.0450, Train Accuracy: 68.91%
#     Worker 1: Train Loss: 1.0447, Train Accuracy: 69.14%
#     Worker 2: Train Loss: 1.0372, Train Accuracy: 70.06%
#     Worker 3: Train Loss: 1.0382, Train Accuracy: 69.95%
#     Worker 4: Train Loss: 1.0246, Train Accuracy: 70.06%
#     Worker 5: Train Loss: 1.0645, Train Accuracy: 68.94%
#     Worker 6: Train Loss: 1.0727, Train Accuracy: 68.85%
#     Worker 7: Train Loss: 1.0355, Train Accuracy: 70.21%
# Epoch 147/150: Test Loss: 1.8545, Test Accuracy: 54.02%
#     Worker 0: Train Loss: 1.0681, Train Accuracy: 68.77%
#     Worker 1: Train Loss: 1.0421, Train Accuracy: 69.95%
#     Worker 2: Train Loss: 1.0260, Train Accuracy: 70.02%
#     Worker 3: Train Loss: 1.0418, Train Accuracy: 69.52%
#     Worker 4: Train Loss: 1.0091, Train Accuracy: 70.62%
#     Worker 5: Train Loss: 1.0442, Train Accuracy: 69.89%
#     Worker 6: Train Loss: 1.0528, Train Accuracy: 68.99%
#     Worker 7: Train Loss: 1.0305, Train Accuracy: 70.14%
# Epoch 148/150: Test Loss: 1.8544, Test Accuracy: 54.05%
#     Worker 0: Train Loss: 1.0387, Train Accuracy: 69.18%
#     Worker 1: Train Loss: 1.0273, Train Accuracy: 69.92%
#     Worker 2: Train Loss: 1.0310, Train Accuracy: 69.58%
#     Worker 3: Train Loss: 1.0181, Train Accuracy: 70.94%
#     Worker 4: Train Loss: 1.0146, Train Accuracy: 70.26%
#     Worker 5: Train Loss: 1.0291, Train Accuracy: 70.21%
#     Worker 6: Train Loss: 1.0398, Train Accuracy: 69.49%
#     Worker 7: Train Loss: 1.0174, Train Accuracy: 70.38%
# Epoch 149/150: Test Loss: 1.8554, Test Accuracy: 54.10%
#     Worker 0: Train Loss: 1.0334, Train Accuracy: 69.92%
#     Worker 1: Train Loss: 1.0322, Train Accuracy: 69.84%
#     Worker 2: Train Loss: 1.0096, Train Accuracy: 70.51%
#     Worker 3: Train Loss: 1.0070, Train Accuracy: 70.53%
#     Worker 4: Train Loss: 1.0045, Train Accuracy: 70.21%
#     Worker 5: Train Loss: 1.0085, Train Accuracy: 71.17%
#     Worker 6: Train Loss: 1.0309, Train Accuracy: 70.16%
#     Worker 7: Train Loss: 1.0045, Train Accuracy: 70.21%
# Epoch 150/150: Test Loss: 1.8549, Test Accuracy: 54.17%
#     Worker 0: Train Loss: 1.0271, Train Accuracy: 69.82%
#     Worker 1: Train Loss: 1.0199, Train Accuracy: 69.89%
#     Worker 2: Train Loss: 1.0257, Train Accuracy: 70.40%
#     Worker 3: Train Loss: 1.0217, Train Accuracy: 70.30%
#     Worker 4: Train Loss: 0.9943, Train Accuracy: 70.75%
#     Worker 5: Train Loss: 1.0171, Train Accuracy: 71.41%
#     Worker 6: Train Loss: 1.0186, Train Accuracy: 70.05%
#     Worker 7: Train Loss: 1.0180, Train Accuracy: 70.61%
