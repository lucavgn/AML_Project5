# %%
# %%writefile localSGD.py

import os
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
num_epochs = 150
base_learning_rate = 1e-2
momentum = 0.9
weight_decay = 4e-4
warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std

class LRScheduler(torch.optim.lr_scheduler._LRScheduler):
    def __init__(self, optimizer, base_lr, K, warmup_epochs, total_epochs, verbose=False):
        """
        Args:
            optimizer: SGD
            base_lr: Base learning rate for the reference batch size.
            K: Number of workers.
            warmup_epochs: Number of warmup epochs.
            total_epochs: Total number of epochs.
            verbose: Whether to print LR updates.
        """
        self.base_lr = base_lr
        self.K = K
        self.scaled_lr = base_lr * K
        self.warmup_epochs = warmup_epochs
        self.total_epochs = total_epochs
        self.verbose = verbose
        super(LRScheduler, self).__init__(optimizer)

    def get_lr(self):
        epoch = self.last_epoch
        if epoch < self.warmup_epochs:
            # Linear warmup scaling
            warmup_factor = (epoch + 1) / self.warmup_epochs
            return [warmup_factor * self.scaled_lr for _ in self.optimizer.param_groups]
        else:
            # polynomially decaying learning rate of ηt = η0×(1−t/T)
            if epoch == self.warmup_epochs:
                print(f"Warmup phase completed at epoch {epoch}. Switching to polynomial decay learning rate.")
            return [self.scaled_lr * ( 1 - ( (epoch - self.warmup_epochs) / (self.total_epochs - self.warmup_epochs))) for _ in self.optimizer.param_groups]


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]

# Batch size
batch_size = shard_size // J

# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)


# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [LRScheduler(
    optimizer = optimizer,
    base_lr = base_learning_rate,
    K = K,
    warmup_epochs = warmup_epochs,
    total_epochs = num_epochs,
    verbose = True) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}")

    # Sequentially train each worker to simulate a distributed environment
    for k in range(K):
        shard_loader = DataLoader(shards[k], batch_size=batch_size, shuffle=True)

        nets[k].train()
        correct_train, total_train, train_loss = 0, 0, 0.0
        for images, labels in shard_loader:
            images, labels = images.to(device), labels.to(device)  # Move to device
            optimizers[k].zero_grad()
            outputs = nets[k](images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizers[k].step()
            # Calculate train loss and accuracy
            train_loss += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            total_train += labels.size(0)
            correct_train += predicted.eq(labels).sum().item()
        # Store train loss and accuracy for this worker
        train_loss /= len(shard_loader.dataset)
        train_losses_per_worker[k].append(train_loss)
        train_accuracy = 100. * correct_train / total_train
        train_accuracies_per_worker[k].append(train_accuracy)

    # Perform model synchronization
    with torch.no_grad():
        global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
        for net in nets:
            for global_param, local_param in zip(global_parameters, net.parameters()):
                global_param += local_param
        for global_param in global_parameters:
            global_param /= K
        # Update each worker model with the global parameters
        for net in nets:
            for local_param, global_param in zip(net.parameters(), global_parameters):
                local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        scheduler.step()

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 8 --j 16
# Out:
# Training with K=8, J=16
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:12<00:00, 13.0MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.08000
# Epoch 1/150: Test Loss: 4.6038, Test Accuracy: 1.35%
#     Worker 0: Train Loss: 4.6060, Train Accuracy: 1.38%
#     Worker 1: Train Loss: 4.6049, Train Accuracy: 1.26%
#     Worker 2: Train Loss: 4.6053, Train Accuracy: 1.18%
#     Worker 3: Train Loss: 4.6053, Train Accuracy: 1.25%
#     Worker 4: Train Loss: 4.6049, Train Accuracy: 1.42%
#     Worker 5: Train Loss: 4.6042, Train Accuracy: 1.41%
#     Worker 6: Train Loss: 4.6057, Train Accuracy: 1.30%
#     Worker 7: Train Loss: 4.6056, Train Accuracy: 1.14%
# Epoch 2/150: Test Loss: 4.5952, Test Accuracy: 1.68%
#     Worker 0: Train Loss: 4.6017, Train Accuracy: 1.12%
#     Worker 1: Train Loss: 4.6004, Train Accuracy: 1.07%
#     Worker 2: Train Loss: 4.6009, Train Accuracy: 1.25%
#     Worker 3: Train Loss: 4.6006, Train Accuracy: 1.31%
#     Worker 4: Train Loss: 4.6017, Train Accuracy: 1.39%
#     Worker 5: Train Loss: 4.5985, Train Accuracy: 1.52%
#     Worker 6: Train Loss: 4.6013, Train Accuracy: 1.36%
#     Worker 7: Train Loss: 4.6011, Train Accuracy: 1.30%
# Epoch 3/150: Test Loss: 4.5425, Test Accuracy: 1.85%
#     Worker 0: Train Loss: 4.5843, Train Accuracy: 1.71%
#     Worker 1: Train Loss: 4.5813, Train Accuracy: 1.63%
#     Worker 2: Train Loss: 4.5875, Train Accuracy: 1.28%
#     Worker 3: Train Loss: 4.5811, Train Accuracy: 1.79%
#     Worker 4: Train Loss: 4.5844, Train Accuracy: 1.23%
#     Worker 5: Train Loss: 4.5758, Train Accuracy: 1.58%
#     Worker 6: Train Loss: 4.5862, Train Accuracy: 1.52%
#     Worker 7: Train Loss: 4.5817, Train Accuracy: 1.97%
# Epoch 4/150: Test Loss: 4.3304, Test Accuracy: 4.51%
#     Worker 0: Train Loss: 4.5027, Train Accuracy: 2.66%
#     Worker 1: Train Loss: 4.5053, Train Accuracy: 2.69%
#     Worker 2: Train Loss: 4.5028, Train Accuracy: 2.67%
#     Worker 3: Train Loss: 4.5070, Train Accuracy: 2.72%
#     Worker 4: Train Loss: 4.4875, Train Accuracy: 2.67%
#     Worker 5: Train Loss: 4.4945, Train Accuracy: 2.58%
#     Worker 6: Train Loss: 4.5191, Train Accuracy: 2.27%
#     Worker 7: Train Loss: 4.4918, Train Accuracy: 2.06%
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Epoch 5/150: Test Loss: 4.1872, Test Accuracy: 5.86%
#     Worker 0: Train Loss: 4.3573, Train Accuracy: 4.26%
#     Worker 1: Train Loss: 4.3744, Train Accuracy: 3.55%
#     Worker 2: Train Loss: 4.4053, Train Accuracy: 3.87%
#     Worker 3: Train Loss: 4.3940, Train Accuracy: 3.50%
#     Worker 4: Train Loss: 4.3991, Train Accuracy: 3.20%
#     Worker 5: Train Loss: 4.3194, Train Accuracy: 4.19%
#     Worker 6: Train Loss: 4.3268, Train Accuracy: 3.63%
#     Worker 7: Train Loss: 4.3676, Train Accuracy: 3.90%
# Epoch 6/150: Test Loss: 4.1050, Test Accuracy: 8.11%
#     Worker 0: Train Loss: 4.1870, Train Accuracy: 5.18%
#     Worker 1: Train Loss: 4.3385, Train Accuracy: 3.81%
#     Worker 2: Train Loss: 4.2742, Train Accuracy: 4.67%
#     Worker 3: Train Loss: 4.2596, Train Accuracy: 4.34%
#     Worker 4: Train Loss: 4.1728, Train Accuracy: 5.23%
#     Worker 5: Train Loss: 4.2484, Train Accuracy: 4.86%
#     Worker 6: Train Loss: 4.2230, Train Accuracy: 4.88%
#     Worker 7: Train Loss: 4.2570, Train Accuracy: 4.58%
# Epoch 7/150: Test Loss: 4.0178, Test Accuracy: 8.60%
#     Worker 0: Train Loss: 4.2536, Train Accuracy: 5.09%
#     Worker 1: Train Loss: 4.0940, Train Accuracy: 6.59%
#     Worker 2: Train Loss: 4.1356, Train Accuracy: 5.65%
#     Worker 3: Train Loss: 4.1617, Train Accuracy: 5.18%
#     Worker 4: Train Loss: 4.1531, Train Accuracy: 6.56%
#     Worker 5: Train Loss: 4.1720, Train Accuracy: 5.92%
#     Worker 6: Train Loss: 4.1347, Train Accuracy: 5.73%
#     Worker 7: Train Loss: 4.1589, Train Accuracy: 5.87%
# Epoch 8/150: Test Loss: 3.9088, Test Accuracy: 9.81%
#     Worker 0: Train Loss: 4.0422, Train Accuracy: 7.10%
#     Worker 1: Train Loss: 4.2074, Train Accuracy: 4.70%
#     Worker 2: Train Loss: 4.0704, Train Accuracy: 7.02%
#     Worker 3: Train Loss: 4.1029, Train Accuracy: 6.51%
#     Worker 4: Train Loss: 4.0380, Train Accuracy: 6.46%
#     Worker 5: Train Loss: 4.0908, Train Accuracy: 7.28%
#     Worker 6: Train Loss: 4.1119, Train Accuracy: 6.18%
#     Worker 7: Train Loss: 4.0965, Train Accuracy: 6.10%
# Epoch 9/150: Test Loss: 3.8351, Test Accuracy: 11.41%
#     Worker 0: Train Loss: 3.9853, Train Accuracy: 7.52%
#     Worker 1: Train Loss: 4.0225, Train Accuracy: 7.39%
#     Worker 2: Train Loss: 3.9835, Train Accuracy: 7.86%
#     Worker 3: Train Loss: 4.0820, Train Accuracy: 6.13%
#     Worker 4: Train Loss: 4.0140, Train Accuracy: 7.46%
#     Worker 5: Train Loss: 3.9902, Train Accuracy: 7.41%
#     Worker 6: Train Loss: 4.0421, Train Accuracy: 7.22%
#     Worker 7: Train Loss: 4.0128, Train Accuracy: 7.22%
# Epoch 10/150: Test Loss: 3.8527, Test Accuracy: 11.11%
#     Worker 0: Train Loss: 4.0083, Train Accuracy: 7.62%
#     Worker 1: Train Loss: 3.9340, Train Accuracy: 8.46%
#     Worker 2: Train Loss: 3.9442, Train Accuracy: 8.40%
#     Worker 3: Train Loss: 3.9974, Train Accuracy: 8.11%
#     Worker 4: Train Loss: 4.0111, Train Accuracy: 7.98%
#     Worker 5: Train Loss: 4.0135, Train Accuracy: 7.09%
#     Worker 6: Train Loss: 4.0194, Train Accuracy: 8.11%
#     Worker 7: Train Loss: 4.0482, Train Accuracy: 6.67%
# Epoch 11/150: Test Loss: 3.7304, Test Accuracy: 12.92%
#     Worker 0: Train Loss: 3.8967, Train Accuracy: 9.65%
#     Worker 1: Train Loss: 3.9616, Train Accuracy: 7.98%
#     Worker 2: Train Loss: 3.9247, Train Accuracy: 8.34%
#     Worker 3: Train Loss: 3.9091, Train Accuracy: 8.98%
#     Worker 4: Train Loss: 3.9154, Train Accuracy: 8.83%
#     Worker 5: Train Loss: 3.8703, Train Accuracy: 9.44%
#     Worker 6: Train Loss: 3.9532, Train Accuracy: 9.02%
#     Worker 7: Train Loss: 3.9389, Train Accuracy: 8.51%
# Epoch 12/150: Test Loss: 3.7313, Test Accuracy: 13.08%
#     Worker 0: Train Loss: 3.9611, Train Accuracy: 7.89%
#     Worker 1: Train Loss: 3.8955, Train Accuracy: 8.78%
#     Worker 2: Train Loss: 3.9117, Train Accuracy: 10.26%
#     Worker 3: Train Loss: 3.8641, Train Accuracy: 9.47%
#     Worker 4: Train Loss: 3.8591, Train Accuracy: 9.50%
#     Worker 5: Train Loss: 3.8244, Train Accuracy: 10.80%
#     Worker 6: Train Loss: 3.8919, Train Accuracy: 9.22%
#     Worker 7: Train Loss: 3.8837, Train Accuracy: 9.36%
# Epoch 13/150: Test Loss: 3.6681, Test Accuracy: 14.66%
#     Worker 0: Train Loss: 3.9362, Train Accuracy: 8.69%
#     Worker 1: Train Loss: 3.8171, Train Accuracy: 10.48%
#     Worker 2: Train Loss: 3.8223, Train Accuracy: 10.98%
#     Worker 3: Train Loss: 3.8255, Train Accuracy: 10.61%
#     Worker 4: Train Loss: 3.8134, Train Accuracy: 10.51%
#     Worker 5: Train Loss: 3.8376, Train Accuracy: 10.34%
#     Worker 6: Train Loss: 3.9414, Train Accuracy: 8.86%
#     Worker 7: Train Loss: 3.9532, Train Accuracy: 8.88%
# Epoch 14/150: Test Loss: 3.5864, Test Accuracy: 15.98%
#     Worker 0: Train Loss: 3.7344, Train Accuracy: 12.61%
#     Worker 1: Train Loss: 3.7489, Train Accuracy: 11.38%
#     Worker 2: Train Loss: 3.7910, Train Accuracy: 10.70%
#     Worker 3: Train Loss: 3.8970, Train Accuracy: 9.63%
#     Worker 4: Train Loss: 3.7262, Train Accuracy: 11.57%
#     Worker 5: Train Loss: 3.7369, Train Accuracy: 12.70%
#     Worker 6: Train Loss: 3.8667, Train Accuracy: 9.76%
#     Worker 7: Train Loss: 3.8313, Train Accuracy: 10.61%
# Epoch 15/150: Test Loss: 3.5551, Test Accuracy: 16.28%
#     Worker 0: Train Loss: 3.8151, Train Accuracy: 10.48%
#     Worker 1: Train Loss: 3.8330, Train Accuracy: 10.58%
#     Worker 2: Train Loss: 3.7224, Train Accuracy: 12.61%
#     Worker 3: Train Loss: 3.7404, Train Accuracy: 11.94%
#     Worker 4: Train Loss: 3.6867, Train Accuracy: 12.61%
#     Worker 5: Train Loss: 3.8255, Train Accuracy: 10.03%
#     Worker 6: Train Loss: 3.7847, Train Accuracy: 10.10%
#     Worker 7: Train Loss: 3.7657, Train Accuracy: 11.89%
# Epoch 16/150: Test Loss: 3.4966, Test Accuracy: 17.55%
#     Worker 0: Train Loss: 3.6877, Train Accuracy: 11.98%
#     Worker 1: Train Loss: 3.6571, Train Accuracy: 12.82%
#     Worker 2: Train Loss: 3.7454, Train Accuracy: 12.10%
#     Worker 3: Train Loss: 3.8450, Train Accuracy: 10.67%
#     Worker 4: Train Loss: 3.6680, Train Accuracy: 12.59%
#     Worker 5: Train Loss: 3.7078, Train Accuracy: 12.14%
#     Worker 6: Train Loss: 3.6630, Train Accuracy: 13.49%
#     Worker 7: Train Loss: 3.7067, Train Accuracy: 13.73%
# Epoch 17/150: Test Loss: 3.4906, Test Accuracy: 17.65%
#     Worker 0: Train Loss: 3.7901, Train Accuracy: 10.93%
#     Worker 1: Train Loss: 3.7038, Train Accuracy: 11.82%
#     Worker 2: Train Loss: 3.6901, Train Accuracy: 13.12%
#     Worker 3: Train Loss: 3.6958, Train Accuracy: 12.91%
#     Worker 4: Train Loss: 3.6571, Train Accuracy: 12.90%
#     Worker 5: Train Loss: 3.6471, Train Accuracy: 13.46%
#     Worker 6: Train Loss: 3.6516, Train Accuracy: 12.94%
#     Worker 7: Train Loss: 3.7421, Train Accuracy: 12.18%
# Epoch 18/150: Test Loss: 3.4308, Test Accuracy: 18.84%
#     Worker 0: Train Loss: 3.6735, Train Accuracy: 12.77%
#     Worker 1: Train Loss: 3.6170, Train Accuracy: 13.84%
#     Worker 2: Train Loss: 3.6346, Train Accuracy: 14.08%
#     Worker 3: Train Loss: 3.6674, Train Accuracy: 13.41%
#     Worker 4: Train Loss: 3.6007, Train Accuracy: 14.05%
#     Worker 5: Train Loss: 3.6764, Train Accuracy: 13.25%
#     Worker 6: Train Loss: 3.6299, Train Accuracy: 13.41%
#     Worker 7: Train Loss: 3.6680, Train Accuracy: 13.15%
# Epoch 19/150: Test Loss: 3.4150, Test Accuracy: 18.96%
#     Worker 0: Train Loss: 3.5859, Train Accuracy: 14.02%
#     Worker 1: Train Loss: 3.5950, Train Accuracy: 13.57%
#     Worker 2: Train Loss: 3.6412, Train Accuracy: 13.95%
#     Worker 3: Train Loss: 3.5930, Train Accuracy: 14.03%
#     Worker 4: Train Loss: 3.5512, Train Accuracy: 14.86%
#     Worker 5: Train Loss: 3.5996, Train Accuracy: 13.65%
#     Worker 6: Train Loss: 3.7207, Train Accuracy: 12.26%
#     Worker 7: Train Loss: 3.7297, Train Accuracy: 11.90%
# Epoch 20/150: Test Loss: 3.3701, Test Accuracy: 19.30%
#     Worker 0: Train Loss: 3.6745, Train Accuracy: 13.06%
#     Worker 1: Train Loss: 3.6667, Train Accuracy: 12.78%
#     Worker 2: Train Loss: 3.5712, Train Accuracy: 14.94%
#     Worker 3: Train Loss: 3.7004, Train Accuracy: 12.90%
#     Worker 4: Train Loss: 3.6574, Train Accuracy: 13.95%
#     Worker 5: Train Loss: 3.5100, Train Accuracy: 15.54%
#     Worker 6: Train Loss: 3.5733, Train Accuracy: 15.12%
#     Worker 7: Train Loss: 3.5776, Train Accuracy: 14.70%
# Epoch 21/150: Test Loss: 3.3730, Test Accuracy: 20.06%
#     Worker 0: Train Loss: 3.5551, Train Accuracy: 14.30%
#     Worker 1: Train Loss: 3.5133, Train Accuracy: 15.70%
#     Worker 2: Train Loss: 3.6813, Train Accuracy: 13.46%
#     Worker 3: Train Loss: 3.5996, Train Accuracy: 14.18%
#     Worker 4: Train Loss: 3.5319, Train Accuracy: 15.31%
#     Worker 5: Train Loss: 3.5136, Train Accuracy: 15.98%
#     Worker 6: Train Loss: 3.6316, Train Accuracy: 13.30%
#     Worker 7: Train Loss: 3.5878, Train Accuracy: 14.54%
# Epoch 22/150: Test Loss: 3.4133, Test Accuracy: 19.66%
#     Worker 0: Train Loss: 3.5606, Train Accuracy: 15.01%
#     Worker 1: Train Loss: 3.5653, Train Accuracy: 14.21%
#     Worker 2: Train Loss: 3.6456, Train Accuracy: 14.58%
#     Worker 3: Train Loss: 3.6165, Train Accuracy: 14.22%
#     Worker 4: Train Loss: 3.5162, Train Accuracy: 15.39%
#     Worker 5: Train Loss: 3.5237, Train Accuracy: 16.24%
#     Worker 6: Train Loss: 3.6494, Train Accuracy: 13.78%
#     Worker 7: Train Loss: 3.6270, Train Accuracy: 14.66%
# Epoch 23/150: Test Loss: 3.2976, Test Accuracy: 21.40%
#     Worker 0: Train Loss: 3.4913, Train Accuracy: 16.13%
#     Worker 1: Train Loss: 3.5301, Train Accuracy: 15.41%
#     Worker 2: Train Loss: 3.6160, Train Accuracy: 14.03%
#     Worker 3: Train Loss: 3.5583, Train Accuracy: 15.78%
#     Worker 4: Train Loss: 3.5129, Train Accuracy: 16.18%
#     Worker 5: Train Loss: 3.4972, Train Accuracy: 16.10%
#     Worker 6: Train Loss: 3.5433, Train Accuracy: 15.70%
#     Worker 7: Train Loss: 3.5733, Train Accuracy: 15.07%
# Epoch 24/150: Test Loss: 3.3557, Test Accuracy: 20.93%
#     Worker 0: Train Loss: 3.5736, Train Accuracy: 15.50%
#     Worker 1: Train Loss: 3.6350, Train Accuracy: 13.60%
#     Worker 2: Train Loss: 3.4688, Train Accuracy: 16.82%
#     Worker 3: Train Loss: 3.5030, Train Accuracy: 16.03%
#     Worker 4: Train Loss: 3.4828, Train Accuracy: 16.18%
#     Worker 5: Train Loss: 3.4269, Train Accuracy: 17.90%
#     Worker 6: Train Loss: 3.5592, Train Accuracy: 14.96%
#     Worker 7: Train Loss: 3.5308, Train Accuracy: 15.82%
# Epoch 25/150: Test Loss: 3.2462, Test Accuracy: 22.54%
#     Worker 0: Train Loss: 3.4820, Train Accuracy: 15.92%
#     Worker 1: Train Loss: 3.4214, Train Accuracy: 17.44%
#     Worker 2: Train Loss: 3.4523, Train Accuracy: 17.86%
#     Worker 3: Train Loss: 3.4666, Train Accuracy: 16.64%
#     Worker 4: Train Loss: 3.4692, Train Accuracy: 16.66%
#     Worker 5: Train Loss: 3.4934, Train Accuracy: 16.16%
#     Worker 6: Train Loss: 3.5034, Train Accuracy: 15.92%
#     Worker 7: Train Loss: 3.4620, Train Accuracy: 17.02%
# Epoch 26/150: Test Loss: 3.2476, Test Accuracy: 22.17%
#     Worker 0: Train Loss: 3.5291, Train Accuracy: 15.78%
#     Worker 1: Train Loss: 3.4069, Train Accuracy: 17.42%
#     Worker 2: Train Loss: 3.4346, Train Accuracy: 17.44%
#     Worker 3: Train Loss: 3.3737, Train Accuracy: 18.56%
#     Worker 4: Train Loss: 3.4503, Train Accuracy: 16.62%
#     Worker 5: Train Loss: 3.3636, Train Accuracy: 18.56%
#     Worker 6: Train Loss: 3.4977, Train Accuracy: 16.24%
#     Worker 7: Train Loss: 3.3671, Train Accuracy: 18.69%
# Epoch 27/150: Test Loss: 3.2335, Test Accuracy: 22.97%
#     Worker 0: Train Loss: 3.4021, Train Accuracy: 17.84%
#     Worker 1: Train Loss: 3.4371, Train Accuracy: 17.18%
#     Worker 2: Train Loss: 3.4375, Train Accuracy: 17.50%
#     Worker 3: Train Loss: 3.4740, Train Accuracy: 16.43%
#     Worker 4: Train Loss: 3.3587, Train Accuracy: 17.97%
#     Worker 5: Train Loss: 3.4966, Train Accuracy: 16.77%
#     Worker 6: Train Loss: 3.4271, Train Accuracy: 17.28%
#     Worker 7: Train Loss: 3.3948, Train Accuracy: 17.18%
# Epoch 28/150: Test Loss: 3.2176, Test Accuracy: 22.55%
#     Worker 0: Train Loss: 3.4356, Train Accuracy: 17.42%
#     Worker 1: Train Loss: 3.3781, Train Accuracy: 17.58%
#     Worker 2: Train Loss: 3.3466, Train Accuracy: 19.38%
#     Worker 3: Train Loss: 3.4371, Train Accuracy: 17.49%
#     Worker 4: Train Loss: 3.4413, Train Accuracy: 16.88%
#     Worker 5: Train Loss: 3.4079, Train Accuracy: 17.62%
#     Worker 6: Train Loss: 3.4229, Train Accuracy: 17.39%
#     Worker 7: Train Loss: 3.2968, Train Accuracy: 19.25%
# Epoch 29/150: Test Loss: 3.1999, Test Accuracy: 22.78%
#     Worker 0: Train Loss: 3.3550, Train Accuracy: 18.66%
#     Worker 1: Train Loss: 3.2868, Train Accuracy: 19.47%
#     Worker 2: Train Loss: 3.3436, Train Accuracy: 19.41%
#     Worker 3: Train Loss: 3.4472, Train Accuracy: 17.41%
#     Worker 4: Train Loss: 3.3047, Train Accuracy: 19.38%
#     Worker 5: Train Loss: 3.3806, Train Accuracy: 18.83%
#     Worker 6: Train Loss: 3.3627, Train Accuracy: 18.32%
#     Worker 7: Train Loss: 3.6119, Train Accuracy: 14.16%
# Epoch 30/150: Test Loss: 3.0874, Test Accuracy: 25.16%
#     Worker 0: Train Loss: 3.3860, Train Accuracy: 17.68%
#     Worker 1: Train Loss: 3.2733, Train Accuracy: 20.06%
#     Worker 2: Train Loss: 3.3324, Train Accuracy: 19.84%
#     Worker 3: Train Loss: 3.3483, Train Accuracy: 19.30%
#     Worker 4: Train Loss: 3.3009, Train Accuracy: 19.30%
#     Worker 5: Train Loss: 3.2963, Train Accuracy: 20.03%
#     Worker 6: Train Loss: 3.3263, Train Accuracy: 19.23%
#     Worker 7: Train Loss: 3.2804, Train Accuracy: 20.05%
# Epoch 31/150: Test Loss: 3.1526, Test Accuracy: 23.97%
#     Worker 0: Train Loss: 3.3223, Train Accuracy: 18.27%
#     Worker 1: Train Loss: 3.3472, Train Accuracy: 18.16%
#     Worker 2: Train Loss: 3.3337, Train Accuracy: 18.98%
#     Worker 3: Train Loss: 3.5386, Train Accuracy: 15.31%
#     Worker 4: Train Loss: 3.2383, Train Accuracy: 20.21%
#     Worker 5: Train Loss: 3.2369, Train Accuracy: 20.58%
#     Worker 6: Train Loss: 3.2800, Train Accuracy: 20.53%
#     Worker 7: Train Loss: 3.2825, Train Accuracy: 20.18%
# Epoch 32/150: Test Loss: 3.0732, Test Accuracy: 25.88%
#     Worker 0: Train Loss: 3.4052, Train Accuracy: 18.03%
#     Worker 1: Train Loss: 3.1999, Train Accuracy: 21.10%
#     Worker 2: Train Loss: 3.2720, Train Accuracy: 20.70%
#     Worker 3: Train Loss: 3.3059, Train Accuracy: 19.04%
#     Worker 4: Train Loss: 3.2371, Train Accuracy: 20.88%
#     Worker 5: Train Loss: 3.3265, Train Accuracy: 19.47%
#     Worker 6: Train Loss: 3.3157, Train Accuracy: 19.28%
#     Worker 7: Train Loss: 3.2906, Train Accuracy: 19.78%
# Epoch 33/150: Test Loss: 3.0144, Test Accuracy: 26.71%
#     Worker 0: Train Loss: 3.2895, Train Accuracy: 19.65%
#     Worker 1: Train Loss: 3.2171, Train Accuracy: 20.67%
#     Worker 2: Train Loss: 3.2127, Train Accuracy: 21.71%
#     Worker 3: Train Loss: 3.2389, Train Accuracy: 20.80%
#     Worker 4: Train Loss: 3.2098, Train Accuracy: 21.44%
#     Worker 5: Train Loss: 3.2304, Train Accuracy: 21.12%
#     Worker 6: Train Loss: 3.2146, Train Accuracy: 20.70%
#     Worker 7: Train Loss: 3.2094, Train Accuracy: 21.42%
# Epoch 34/150: Test Loss: 3.0183, Test Accuracy: 26.55%
#     Worker 0: Train Loss: 3.1854, Train Accuracy: 21.94%
#     Worker 1: Train Loss: 3.1821, Train Accuracy: 21.86%
#     Worker 2: Train Loss: 3.3083, Train Accuracy: 19.76%
#     Worker 3: Train Loss: 3.1541, Train Accuracy: 21.82%
#     Worker 4: Train Loss: 3.1882, Train Accuracy: 21.22%
#     Worker 5: Train Loss: 3.2265, Train Accuracy: 22.05%
#     Worker 6: Train Loss: 3.3392, Train Accuracy: 18.46%
#     Worker 7: Train Loss: 3.1951, Train Accuracy: 22.13%
# Epoch 35/150: Test Loss: 3.0196, Test Accuracy: 26.66%
#     Worker 0: Train Loss: 3.1808, Train Accuracy: 21.92%
#     Worker 1: Train Loss: 3.1261, Train Accuracy: 22.74%
#     Worker 2: Train Loss: 3.1110, Train Accuracy: 23.20%
#     Worker 3: Train Loss: 3.3427, Train Accuracy: 18.54%
#     Worker 4: Train Loss: 3.1730, Train Accuracy: 21.62%
#     Worker 5: Train Loss: 3.1476, Train Accuracy: 22.82%
#     Worker 6: Train Loss: 3.2867, Train Accuracy: 20.18%
#     Worker 7: Train Loss: 3.2904, Train Accuracy: 19.42%
# Epoch 36/150: Test Loss: 3.0003, Test Accuracy: 26.77%
#     Worker 0: Train Loss: 3.1963, Train Accuracy: 21.44%
#     Worker 1: Train Loss: 3.2191, Train Accuracy: 21.14%
#     Worker 2: Train Loss: 3.3019, Train Accuracy: 20.53%
#     Worker 3: Train Loss: 3.2115, Train Accuracy: 21.90%
#     Worker 4: Train Loss: 3.1913, Train Accuracy: 20.93%
#     Worker 5: Train Loss: 3.1356, Train Accuracy: 22.66%
#     Worker 6: Train Loss: 3.1745, Train Accuracy: 22.02%
#     Worker 7: Train Loss: 3.1833, Train Accuracy: 22.46%
# Epoch 37/150: Test Loss: 2.9981, Test Accuracy: 27.61%
#     Worker 0: Train Loss: 3.3069, Train Accuracy: 19.04%
#     Worker 1: Train Loss: 3.0957, Train Accuracy: 22.51%
#     Worker 2: Train Loss: 3.1458, Train Accuracy: 22.99%
#     Worker 3: Train Loss: 3.4412, Train Accuracy: 17.98%
#     Worker 4: Train Loss: 3.0255, Train Accuracy: 24.88%
#     Worker 5: Train Loss: 3.1201, Train Accuracy: 22.80%
#     Worker 6: Train Loss: 3.1598, Train Accuracy: 22.62%
#     Worker 7: Train Loss: 3.1686, Train Accuracy: 22.21%
# Epoch 38/150: Test Loss: 2.9682, Test Accuracy: 27.95%
#     Worker 0: Train Loss: 3.1153, Train Accuracy: 23.68%
#     Worker 1: Train Loss: 3.0533, Train Accuracy: 23.92%
#     Worker 2: Train Loss: 3.2257, Train Accuracy: 21.84%
#     Worker 3: Train Loss: 3.1586, Train Accuracy: 22.10%
#     Worker 4: Train Loss: 3.2971, Train Accuracy: 20.22%
#     Worker 5: Train Loss: 3.2479, Train Accuracy: 20.10%
#     Worker 6: Train Loss: 3.1430, Train Accuracy: 22.22%
#     Worker 7: Train Loss: 3.1093, Train Accuracy: 23.86%
# Epoch 39/150: Test Loss: 2.9130, Test Accuracy: 28.51%
#     Worker 0: Train Loss: 3.1278, Train Accuracy: 23.44%
#     Worker 1: Train Loss: 3.0999, Train Accuracy: 22.93%
#     Worker 2: Train Loss: 3.1864, Train Accuracy: 22.13%
#     Worker 3: Train Loss: 3.2258, Train Accuracy: 21.41%
#     Worker 4: Train Loss: 3.0181, Train Accuracy: 25.10%
#     Worker 5: Train Loss: 3.0840, Train Accuracy: 23.74%
#     Worker 6: Train Loss: 3.1533, Train Accuracy: 22.59%
#     Worker 7: Train Loss: 3.0993, Train Accuracy: 24.27%
# Epoch 40/150: Test Loss: 2.9347, Test Accuracy: 27.96%
#     Worker 0: Train Loss: 3.1506, Train Accuracy: 22.69%
#     Worker 1: Train Loss: 3.0669, Train Accuracy: 23.44%
#     Worker 2: Train Loss: 3.0756, Train Accuracy: 24.26%
#     Worker 3: Train Loss: 3.2660, Train Accuracy: 20.66%
#     Worker 4: Train Loss: 3.0416, Train Accuracy: 24.53%
#     Worker 5: Train Loss: 3.0501, Train Accuracy: 24.00%
#     Worker 6: Train Loss: 3.0691, Train Accuracy: 23.31%
#     Worker 7: Train Loss: 3.2575, Train Accuracy: 21.14%
# Epoch 41/150: Test Loss: 2.9183, Test Accuracy: 28.98%
#     Worker 0: Train Loss: 3.0890, Train Accuracy: 24.10%
#     Worker 1: Train Loss: 3.0061, Train Accuracy: 25.14%
#     Worker 2: Train Loss: 3.0550, Train Accuracy: 23.89%
#     Worker 3: Train Loss: 3.1274, Train Accuracy: 22.77%
#     Worker 4: Train Loss: 3.0583, Train Accuracy: 24.30%
#     Worker 5: Train Loss: 3.0798, Train Accuracy: 24.50%
#     Worker 6: Train Loss: 3.0557, Train Accuracy: 24.58%
#     Worker 7: Train Loss: 3.2511, Train Accuracy: 21.86%
# Epoch 42/150: Test Loss: 2.9155, Test Accuracy: 29.39%
#     Worker 0: Train Loss: 3.2559, Train Accuracy: 20.74%
#     Worker 1: Train Loss: 3.0729, Train Accuracy: 24.82%
#     Worker 2: Train Loss: 3.1155, Train Accuracy: 23.49%
#     Worker 3: Train Loss: 3.0939, Train Accuracy: 23.78%
#     Worker 4: Train Loss: 2.9879, Train Accuracy: 25.17%
#     Worker 5: Train Loss: 3.0211, Train Accuracy: 24.98%
#     Worker 6: Train Loss: 3.0416, Train Accuracy: 24.38%
#     Worker 7: Train Loss: 3.1470, Train Accuracy: 22.67%
# Epoch 43/150: Test Loss: 2.8780, Test Accuracy: 29.09%
#     Worker 0: Train Loss: 3.0761, Train Accuracy: 24.22%
#     Worker 1: Train Loss: 3.0958, Train Accuracy: 23.57%
#     Worker 2: Train Loss: 3.0277, Train Accuracy: 25.63%
#     Worker 3: Train Loss: 3.0242, Train Accuracy: 24.90%
#     Worker 4: Train Loss: 3.0087, Train Accuracy: 24.86%
#     Worker 5: Train Loss: 3.0791, Train Accuracy: 24.32%
#     Worker 6: Train Loss: 3.0380, Train Accuracy: 24.74%
#     Worker 7: Train Loss: 3.0283, Train Accuracy: 24.51%
# Epoch 44/150: Test Loss: 2.8842, Test Accuracy: 28.65%
#     Worker 0: Train Loss: 2.9885, Train Accuracy: 25.20%
#     Worker 1: Train Loss: 3.0176, Train Accuracy: 25.38%
#     Worker 2: Train Loss: 3.0499, Train Accuracy: 24.72%
#     Worker 3: Train Loss: 3.1606, Train Accuracy: 22.18%
#     Worker 4: Train Loss: 3.0078, Train Accuracy: 25.46%
#     Worker 5: Train Loss: 3.0352, Train Accuracy: 24.72%
#     Worker 6: Train Loss: 3.0612, Train Accuracy: 24.37%
#     Worker 7: Train Loss: 2.9961, Train Accuracy: 25.49%
# Epoch 45/150: Test Loss: 2.8043, Test Accuracy: 30.48%
#     Worker 0: Train Loss: 3.1124, Train Accuracy: 23.17%
#     Worker 1: Train Loss: 2.9606, Train Accuracy: 25.90%
#     Worker 2: Train Loss: 2.9998, Train Accuracy: 25.76%
#     Worker 3: Train Loss: 2.9937, Train Accuracy: 25.20%
#     Worker 4: Train Loss: 3.0112, Train Accuracy: 25.01%
#     Worker 5: Train Loss: 2.9661, Train Accuracy: 26.62%
#     Worker 6: Train Loss: 3.0381, Train Accuracy: 24.61%
#     Worker 7: Train Loss: 3.0348, Train Accuracy: 24.96%
# Epoch 46/150: Test Loss: 2.7994, Test Accuracy: 31.47%
#     Worker 0: Train Loss: 3.0947, Train Accuracy: 23.20%
#     Worker 1: Train Loss: 2.8790, Train Accuracy: 26.96%
#     Worker 2: Train Loss: 2.9437, Train Accuracy: 27.18%
#     Worker 3: Train Loss: 3.0169, Train Accuracy: 24.78%
#     Worker 4: Train Loss: 2.8902, Train Accuracy: 27.07%
#     Worker 5: Train Loss: 3.0246, Train Accuracy: 25.49%
#     Worker 6: Train Loss: 2.9564, Train Accuracy: 25.54%
#     Worker 7: Train Loss: 2.9431, Train Accuracy: 26.70%
# Epoch 47/150: Test Loss: 2.7917, Test Accuracy: 31.27%
#     Worker 0: Train Loss: 3.0086, Train Accuracy: 25.90%
#     Worker 1: Train Loss: 2.9898, Train Accuracy: 25.33%
#     Worker 2: Train Loss: 3.0291, Train Accuracy: 25.94%
#     Worker 3: Train Loss: 2.9907, Train Accuracy: 24.93%
#     Worker 4: Train Loss: 3.0150, Train Accuracy: 25.01%
#     Worker 5: Train Loss: 3.0057, Train Accuracy: 25.14%
#     Worker 6: Train Loss: 2.9667, Train Accuracy: 26.11%
#     Worker 7: Train Loss: 3.0531, Train Accuracy: 24.18%
# Epoch 48/150: Test Loss: 2.7379, Test Accuracy: 31.79%
#     Worker 0: Train Loss: 2.9280, Train Accuracy: 26.99%
#     Worker 1: Train Loss: 2.9445, Train Accuracy: 26.14%
#     Worker 2: Train Loss: 2.8849, Train Accuracy: 28.11%
#     Worker 3: Train Loss: 2.9493, Train Accuracy: 26.34%
#     Worker 4: Train Loss: 2.9892, Train Accuracy: 26.22%
#     Worker 5: Train Loss: 2.9071, Train Accuracy: 27.15%
#     Worker 6: Train Loss: 2.9296, Train Accuracy: 26.54%
#     Worker 7: Train Loss: 2.8420, Train Accuracy: 28.59%
# Epoch 49/150: Test Loss: 2.7395, Test Accuracy: 32.30%
#     Worker 0: Train Loss: 2.8822, Train Accuracy: 28.24%
#     Worker 1: Train Loss: 2.8346, Train Accuracy: 27.95%
#     Worker 2: Train Loss: 2.9935, Train Accuracy: 26.37%
#     Worker 3: Train Loss: 2.9787, Train Accuracy: 26.88%
#     Worker 4: Train Loss: 2.8663, Train Accuracy: 28.75%
#     Worker 5: Train Loss: 3.0069, Train Accuracy: 26.37%
#     Worker 6: Train Loss: 2.9969, Train Accuracy: 25.28%
#     Worker 7: Train Loss: 2.8394, Train Accuracy: 28.51%
# Epoch 50/150: Test Loss: 2.7055, Test Accuracy: 32.71%
#     Worker 0: Train Loss: 3.0475, Train Accuracy: 24.08%
#     Worker 1: Train Loss: 2.8722, Train Accuracy: 27.55%
#     Worker 2: Train Loss: 2.9114, Train Accuracy: 28.00%
#     Worker 3: Train Loss: 2.8804, Train Accuracy: 27.73%
#     Worker 4: Train Loss: 2.7748, Train Accuracy: 29.49%
#     Worker 5: Train Loss: 2.7849, Train Accuracy: 29.87%
#     Worker 6: Train Loss: 2.9801, Train Accuracy: 25.50%
#     Worker 7: Train Loss: 2.8024, Train Accuracy: 29.10%
# Epoch 51/150: Test Loss: 2.6951, Test Accuracy: 32.75%
#     Worker 0: Train Loss: 2.7976, Train Accuracy: 29.28%
#     Worker 1: Train Loss: 2.7760, Train Accuracy: 29.41%
#     Worker 2: Train Loss: 3.0251, Train Accuracy: 25.87%
#     Worker 3: Train Loss: 2.9478, Train Accuracy: 25.90%
#     Worker 4: Train Loss: 2.7900, Train Accuracy: 29.95%
#     Worker 5: Train Loss: 2.9697, Train Accuracy: 26.75%
#     Worker 6: Train Loss: 2.8587, Train Accuracy: 28.21%
#     Worker 7: Train Loss: 2.8929, Train Accuracy: 28.67%
# Epoch 52/150: Test Loss: 2.6780, Test Accuracy: 33.12%
#     Worker 0: Train Loss: 2.8470, Train Accuracy: 28.85%
#     Worker 1: Train Loss: 2.7805, Train Accuracy: 28.88%
#     Worker 2: Train Loss: 2.9247, Train Accuracy: 26.86%
#     Worker 3: Train Loss: 2.9189, Train Accuracy: 26.59%
#     Worker 4: Train Loss: 2.8342, Train Accuracy: 28.11%
#     Worker 5: Train Loss: 2.7831, Train Accuracy: 29.46%
#     Worker 6: Train Loss: 2.9515, Train Accuracy: 26.30%
#     Worker 7: Train Loss: 2.7788, Train Accuracy: 29.97%
# Epoch 53/150: Test Loss: 2.6717, Test Accuracy: 33.50%
#     Worker 0: Train Loss: 2.9184, Train Accuracy: 26.56%
#     Worker 1: Train Loss: 2.8802, Train Accuracy: 28.24%
#     Worker 2: Train Loss: 2.9050, Train Accuracy: 27.73%
#     Worker 3: Train Loss: 2.8275, Train Accuracy: 29.14%
#     Worker 4: Train Loss: 2.8572, Train Accuracy: 29.34%
#     Worker 5: Train Loss: 2.6620, Train Accuracy: 31.70%
#     Worker 6: Train Loss: 2.7650, Train Accuracy: 29.97%
#     Worker 7: Train Loss: 2.7653, Train Accuracy: 30.05%
# Epoch 54/150: Test Loss: 2.6536, Test Accuracy: 34.20%
#     Worker 0: Train Loss: 2.7412, Train Accuracy: 31.22%
#     Worker 1: Train Loss: 2.7784, Train Accuracy: 29.06%
#     Worker 2: Train Loss: 2.8317, Train Accuracy: 29.28%
#     Worker 3: Train Loss: 2.7304, Train Accuracy: 30.05%
#     Worker 4: Train Loss: 2.8062, Train Accuracy: 28.50%
#     Worker 5: Train Loss: 2.8283, Train Accuracy: 29.79%
#     Worker 6: Train Loss: 2.8380, Train Accuracy: 28.35%
#     Worker 7: Train Loss: 2.7324, Train Accuracy: 30.18%
# Epoch 55/150: Test Loss: 2.6090, Test Accuracy: 34.78%
#     Worker 0: Train Loss: 2.7908, Train Accuracy: 29.22%
#     Worker 1: Train Loss: 2.7660, Train Accuracy: 29.65%
#     Worker 2: Train Loss: 2.8238, Train Accuracy: 28.51%
#     Worker 3: Train Loss: 2.8017, Train Accuracy: 29.79%
#     Worker 4: Train Loss: 2.6568, Train Accuracy: 32.34%
#     Worker 5: Train Loss: 2.7470, Train Accuracy: 31.06%
#     Worker 6: Train Loss: 2.7667, Train Accuracy: 29.97%
#     Worker 7: Train Loss: 2.7897, Train Accuracy: 29.95%
# Epoch 56/150: Test Loss: 2.6036, Test Accuracy: 34.52%
#     Worker 0: Train Loss: 2.8655, Train Accuracy: 28.58%
#     Worker 1: Train Loss: 2.6898, Train Accuracy: 30.40%
#     Worker 2: Train Loss: 2.7108, Train Accuracy: 31.50%
#     Worker 3: Train Loss: 2.8941, Train Accuracy: 27.66%
#     Worker 4: Train Loss: 2.7526, Train Accuracy: 30.10%
#     Worker 5: Train Loss: 2.7287, Train Accuracy: 30.90%
#     Worker 6: Train Loss: 2.7221, Train Accuracy: 30.83%
#     Worker 7: Train Loss: 2.8076, Train Accuracy: 29.04%
# Epoch 57/150: Test Loss: 2.5602, Test Accuracy: 34.91%
#     Worker 0: Train Loss: 2.6859, Train Accuracy: 31.84%
#     Worker 1: Train Loss: 2.7356, Train Accuracy: 30.32%
#     Worker 2: Train Loss: 2.7520, Train Accuracy: 30.80%
#     Worker 3: Train Loss: 2.7233, Train Accuracy: 30.14%
#     Worker 4: Train Loss: 2.6706, Train Accuracy: 31.79%
#     Worker 5: Train Loss: 2.6806, Train Accuracy: 31.66%
#     Worker 6: Train Loss: 2.6667, Train Accuracy: 32.34%
#     Worker 7: Train Loss: 2.8640, Train Accuracy: 27.34%
# Epoch 58/150: Test Loss: 2.5701, Test Accuracy: 35.37%
#     Worker 0: Train Loss: 2.7387, Train Accuracy: 30.11%
#     Worker 1: Train Loss: 2.6740, Train Accuracy: 31.42%
#     Worker 2: Train Loss: 2.8126, Train Accuracy: 30.24%
#     Worker 3: Train Loss: 2.7850, Train Accuracy: 29.79%
#     Worker 4: Train Loss: 2.6117, Train Accuracy: 33.02%
#     Worker 5: Train Loss: 2.6823, Train Accuracy: 32.85%
#     Worker 6: Train Loss: 2.7753, Train Accuracy: 29.70%
#     Worker 7: Train Loss: 2.8051, Train Accuracy: 29.12%
# Epoch 59/150: Test Loss: 2.5876, Test Accuracy: 35.08%
#     Worker 0: Train Loss: 2.7553, Train Accuracy: 30.45%
#     Worker 1: Train Loss: 2.6459, Train Accuracy: 32.27%
#     Worker 2: Train Loss: 2.7215, Train Accuracy: 32.06%
#     Worker 3: Train Loss: 2.8287, Train Accuracy: 29.47%
#     Worker 4: Train Loss: 2.6081, Train Accuracy: 33.31%
#     Worker 5: Train Loss: 2.7490, Train Accuracy: 29.95%
#     Worker 6: Train Loss: 2.6866, Train Accuracy: 30.93%
#     Worker 7: Train Loss: 2.7510, Train Accuracy: 30.43%
# Epoch 60/150: Test Loss: 2.5585, Test Accuracy: 35.60%
#     Worker 0: Train Loss: 2.6836, Train Accuracy: 31.68%
#     Worker 1: Train Loss: 2.8365, Train Accuracy: 29.94%
#     Worker 2: Train Loss: 2.6237, Train Accuracy: 33.94%
#     Worker 3: Train Loss: 2.7836, Train Accuracy: 29.60%
#     Worker 4: Train Loss: 2.8301, Train Accuracy: 29.78%
#     Worker 5: Train Loss: 2.7002, Train Accuracy: 31.90%
#     Worker 6: Train Loss: 2.7494, Train Accuracy: 30.08%
#     Worker 7: Train Loss: 2.7569, Train Accuracy: 30.56%
# Epoch 61/150: Test Loss: 2.5720, Test Accuracy: 35.63%
#     Worker 0: Train Loss: 2.7164, Train Accuracy: 31.17%
#     Worker 1: Train Loss: 2.6678, Train Accuracy: 31.95%
#     Worker 2: Train Loss: 2.7036, Train Accuracy: 32.05%
#     Worker 3: Train Loss: 2.7703, Train Accuracy: 29.34%
#     Worker 4: Train Loss: 2.6723, Train Accuracy: 31.58%
#     Worker 5: Train Loss: 2.7497, Train Accuracy: 31.79%
#     Worker 6: Train Loss: 2.7614, Train Accuracy: 30.30%
#     Worker 7: Train Loss: 2.6516, Train Accuracy: 32.32%
# Epoch 62/150: Test Loss: 2.5355, Test Accuracy: 35.89%
#     Worker 0: Train Loss: 2.7465, Train Accuracy: 29.94%
#     Worker 1: Train Loss: 2.6300, Train Accuracy: 32.53%
#     Worker 2: Train Loss: 2.7620, Train Accuracy: 30.11%
#     Worker 3: Train Loss: 2.6910, Train Accuracy: 31.55%
#     Worker 4: Train Loss: 2.6056, Train Accuracy: 33.25%
#     Worker 5: Train Loss: 2.6993, Train Accuracy: 31.57%
#     Worker 6: Train Loss: 2.5769, Train Accuracy: 33.26%
#     Worker 7: Train Loss: 2.6620, Train Accuracy: 31.68%
# Epoch 63/150: Test Loss: 2.5386, Test Accuracy: 35.78%
#     Worker 0: Train Loss: 2.7112, Train Accuracy: 31.52%
#     Worker 1: Train Loss: 2.6109, Train Accuracy: 32.72%
#     Worker 2: Train Loss: 2.7058, Train Accuracy: 31.46%
#     Worker 3: Train Loss: 2.6996, Train Accuracy: 30.78%
#     Worker 4: Train Loss: 2.5657, Train Accuracy: 34.13%
#     Worker 5: Train Loss: 2.5612, Train Accuracy: 33.78%
#     Worker 6: Train Loss: 2.8467, Train Accuracy: 29.06%
#     Worker 7: Train Loss: 2.6445, Train Accuracy: 32.13%
# Epoch 64/150: Test Loss: 2.5066, Test Accuracy: 36.66%
#     Worker 0: Train Loss: 2.6209, Train Accuracy: 32.94%
#     Worker 1: Train Loss: 2.6346, Train Accuracy: 32.21%
#     Worker 2: Train Loss: 2.6476, Train Accuracy: 32.53%
#     Worker 3: Train Loss: 2.7717, Train Accuracy: 29.84%
#     Worker 4: Train Loss: 2.7051, Train Accuracy: 31.06%
#     Worker 5: Train Loss: 2.5961, Train Accuracy: 33.82%
#     Worker 6: Train Loss: 2.6743, Train Accuracy: 31.58%
#     Worker 7: Train Loss: 2.6536, Train Accuracy: 32.30%
# Epoch 65/150: Test Loss: 2.4700, Test Accuracy: 37.22%
#     Worker 0: Train Loss: 2.6759, Train Accuracy: 31.62%
#     Worker 1: Train Loss: 2.7304, Train Accuracy: 30.34%
#     Worker 2: Train Loss: 2.5721, Train Accuracy: 35.02%
#     Worker 3: Train Loss: 2.6374, Train Accuracy: 32.21%
#     Worker 4: Train Loss: 2.5425, Train Accuracy: 34.13%
#     Worker 5: Train Loss: 2.7050, Train Accuracy: 31.42%
#     Worker 6: Train Loss: 2.5376, Train Accuracy: 34.61%
#     Worker 7: Train Loss: 2.5714, Train Accuracy: 34.91%
# Epoch 66/150: Test Loss: 2.4716, Test Accuracy: 37.35%
#     Worker 0: Train Loss: 2.6353, Train Accuracy: 32.94%
#     Worker 1: Train Loss: 2.6783, Train Accuracy: 32.16%
#     Worker 2: Train Loss: 2.6751, Train Accuracy: 32.51%
#     Worker 3: Train Loss: 2.5848, Train Accuracy: 33.86%
#     Worker 4: Train Loss: 2.4646, Train Accuracy: 36.43%
#     Worker 5: Train Loss: 2.5698, Train Accuracy: 34.32%
#     Worker 6: Train Loss: 2.5683, Train Accuracy: 32.93%
#     Worker 7: Train Loss: 2.6522, Train Accuracy: 32.43%
# Epoch 67/150: Test Loss: 2.4584, Test Accuracy: 37.28%
#     Worker 0: Train Loss: 2.5243, Train Accuracy: 35.04%
#     Worker 1: Train Loss: 2.6664, Train Accuracy: 31.41%
#     Worker 2: Train Loss: 2.6344, Train Accuracy: 33.42%
#     Worker 3: Train Loss: 2.7206, Train Accuracy: 31.60%
#     Worker 4: Train Loss: 2.4680, Train Accuracy: 35.86%
#     Worker 5: Train Loss: 2.5126, Train Accuracy: 36.02%
#     Worker 6: Train Loss: 2.6864, Train Accuracy: 31.94%
#     Worker 7: Train Loss: 2.5578, Train Accuracy: 34.02%
# Epoch 68/150: Test Loss: 2.4516, Test Accuracy: 37.54%
#     Worker 0: Train Loss: 2.6410, Train Accuracy: 32.48%
#     Worker 1: Train Loss: 2.6151, Train Accuracy: 33.46%
#     Worker 2: Train Loss: 2.6293, Train Accuracy: 32.85%
#     Worker 3: Train Loss: 2.6263, Train Accuracy: 33.02%
#     Worker 4: Train Loss: 2.5874, Train Accuracy: 33.90%
#     Worker 5: Train Loss: 2.5583, Train Accuracy: 34.77%
#     Worker 6: Train Loss: 2.5671, Train Accuracy: 33.31%
#     Worker 7: Train Loss: 2.5801, Train Accuracy: 34.22%
# Epoch 69/150: Test Loss: 2.4533, Test Accuracy: 38.30%
#     Worker 0: Train Loss: 2.6459, Train Accuracy: 32.70%
#     Worker 1: Train Loss: 2.5153, Train Accuracy: 35.17%
#     Worker 2: Train Loss: 2.5621, Train Accuracy: 34.62%
#     Worker 3: Train Loss: 2.5235, Train Accuracy: 34.85%
#     Worker 4: Train Loss: 2.5377, Train Accuracy: 34.06%
#     Worker 5: Train Loss: 2.6584, Train Accuracy: 32.86%
#     Worker 6: Train Loss: 2.5730, Train Accuracy: 33.76%
#     Worker 7: Train Loss: 2.6370, Train Accuracy: 32.70%
# Epoch 70/150: Test Loss: 2.4270, Test Accuracy: 37.99%
#     Worker 0: Train Loss: 2.5100, Train Accuracy: 35.04%
#     Worker 1: Train Loss: 2.5449, Train Accuracy: 34.27%
#     Worker 2: Train Loss: 2.5872, Train Accuracy: 34.27%
#     Worker 3: Train Loss: 2.5959, Train Accuracy: 34.02%
#     Worker 4: Train Loss: 2.6051, Train Accuracy: 32.75%
#     Worker 5: Train Loss: 2.5118, Train Accuracy: 35.65%
#     Worker 6: Train Loss: 2.5866, Train Accuracy: 33.20%
#     Worker 7: Train Loss: 2.4673, Train Accuracy: 36.06%
# Epoch 71/150: Test Loss: 2.4283, Test Accuracy: 38.35%
#     Worker 0: Train Loss: 2.4891, Train Accuracy: 35.50%
#     Worker 1: Train Loss: 2.4932, Train Accuracy: 35.81%
#     Worker 2: Train Loss: 2.5036, Train Accuracy: 36.11%
#     Worker 3: Train Loss: 2.5149, Train Accuracy: 35.38%
#     Worker 4: Train Loss: 2.4895, Train Accuracy: 35.41%
#     Worker 5: Train Loss: 2.6394, Train Accuracy: 33.09%
#     Worker 6: Train Loss: 2.6192, Train Accuracy: 32.94%
#     Worker 7: Train Loss: 2.5866, Train Accuracy: 34.06%
# Epoch 72/150: Test Loss: 2.3986, Test Accuracy: 38.74%
#     Worker 0: Train Loss: 2.6849, Train Accuracy: 30.74%
#     Worker 1: Train Loss: 2.5376, Train Accuracy: 34.64%
#     Worker 2: Train Loss: 2.5374, Train Accuracy: 35.63%
#     Worker 3: Train Loss: 2.4780, Train Accuracy: 34.99%
#     Worker 4: Train Loss: 2.4549, Train Accuracy: 36.43%
#     Worker 5: Train Loss: 2.5384, Train Accuracy: 35.12%
#     Worker 6: Train Loss: 2.5270, Train Accuracy: 34.78%
#     Worker 7: Train Loss: 2.4781, Train Accuracy: 36.37%
# Epoch 73/150: Test Loss: 2.4141, Test Accuracy: 38.76%
#     Worker 0: Train Loss: 2.5522, Train Accuracy: 34.62%
#     Worker 1: Train Loss: 2.4836, Train Accuracy: 35.46%
#     Worker 2: Train Loss: 2.4417, Train Accuracy: 36.56%
#     Worker 3: Train Loss: 2.4781, Train Accuracy: 35.28%
#     Worker 4: Train Loss: 2.6455, Train Accuracy: 32.78%
#     Worker 5: Train Loss: 2.5622, Train Accuracy: 34.72%
#     Worker 6: Train Loss: 2.5530, Train Accuracy: 33.79%
#     Worker 7: Train Loss: 2.4790, Train Accuracy: 35.55%
# Epoch 74/150: Test Loss: 2.4026, Test Accuracy: 38.85%
#     Worker 0: Train Loss: 2.4970, Train Accuracy: 34.75%
#     Worker 1: Train Loss: 2.3967, Train Accuracy: 38.02%
#     Worker 2: Train Loss: 2.3743, Train Accuracy: 37.73%
#     Worker 3: Train Loss: 2.6749, Train Accuracy: 31.98%
#     Worker 4: Train Loss: 2.4915, Train Accuracy: 35.68%
#     Worker 5: Train Loss: 2.5100, Train Accuracy: 35.36%
#     Worker 6: Train Loss: 2.5934, Train Accuracy: 32.54%
#     Worker 7: Train Loss: 2.4460, Train Accuracy: 36.70%
# Epoch 75/150: Test Loss: 2.3668, Test Accuracy: 39.24%
#     Worker 0: Train Loss: 2.4996, Train Accuracy: 35.90%
#     Worker 1: Train Loss: 2.5477, Train Accuracy: 34.10%
#     Worker 2: Train Loss: 2.4417, Train Accuracy: 36.51%
#     Worker 3: Train Loss: 2.5418, Train Accuracy: 34.11%
#     Worker 4: Train Loss: 2.4208, Train Accuracy: 37.36%
#     Worker 5: Train Loss: 2.4197, Train Accuracy: 37.23%
#     Worker 6: Train Loss: 2.4481, Train Accuracy: 36.45%
#     Worker 7: Train Loss: 2.4563, Train Accuracy: 36.06%
# Epoch 76/150: Test Loss: 2.3566, Test Accuracy: 39.77%
#     Worker 0: Train Loss: 2.4469, Train Accuracy: 36.22%
#     Worker 1: Train Loss: 2.4401, Train Accuracy: 36.18%
#     Worker 2: Train Loss: 2.4550, Train Accuracy: 36.29%
#     Worker 3: Train Loss: 2.5025, Train Accuracy: 35.86%
#     Worker 4: Train Loss: 2.3587, Train Accuracy: 37.55%
#     Worker 5: Train Loss: 2.4202, Train Accuracy: 37.14%
#     Worker 6: Train Loss: 2.5713, Train Accuracy: 33.82%
#     Worker 7: Train Loss: 2.4450, Train Accuracy: 36.62%
# Epoch 77/150: Test Loss: 2.3670, Test Accuracy: 39.45%
#     Worker 0: Train Loss: 2.3512, Train Accuracy: 38.74%
#     Worker 1: Train Loss: 2.4322, Train Accuracy: 37.14%
#     Worker 2: Train Loss: 2.4789, Train Accuracy: 35.84%
#     Worker 3: Train Loss: 2.4366, Train Accuracy: 36.93%
#     Worker 4: Train Loss: 2.5078, Train Accuracy: 35.54%
#     Worker 5: Train Loss: 2.5259, Train Accuracy: 36.18%
#     Worker 6: Train Loss: 2.4671, Train Accuracy: 36.08%
#     Worker 7: Train Loss: 2.4124, Train Accuracy: 37.18%
# Epoch 78/150: Test Loss: 2.3363, Test Accuracy: 40.03%
#     Worker 0: Train Loss: 2.3591, Train Accuracy: 38.59%
#     Worker 1: Train Loss: 2.3803, Train Accuracy: 38.02%
#     Worker 2: Train Loss: 2.4423, Train Accuracy: 37.36%
#     Worker 3: Train Loss: 2.4155, Train Accuracy: 36.67%
#     Worker 4: Train Loss: 2.3787, Train Accuracy: 37.26%
#     Worker 5: Train Loss: 2.4450, Train Accuracy: 36.62%
#     Worker 6: Train Loss: 2.4918, Train Accuracy: 35.28%
#     Worker 7: Train Loss: 2.5079, Train Accuracy: 35.34%
# Epoch 79/150: Test Loss: 2.3278, Test Accuracy: 40.36%
#     Worker 0: Train Loss: 2.3834, Train Accuracy: 37.79%
#     Worker 1: Train Loss: 2.3962, Train Accuracy: 36.80%
#     Worker 2: Train Loss: 2.3936, Train Accuracy: 38.14%
#     Worker 3: Train Loss: 2.4575, Train Accuracy: 36.67%
#     Worker 4: Train Loss: 2.3691, Train Accuracy: 37.78%
#     Worker 5: Train Loss: 2.4846, Train Accuracy: 35.79%
#     Worker 6: Train Loss: 2.4780, Train Accuracy: 35.76%
#     Worker 7: Train Loss: 2.3888, Train Accuracy: 37.86%
# Epoch 80/150: Test Loss: 2.3136, Test Accuracy: 40.48%
#     Worker 0: Train Loss: 2.3312, Train Accuracy: 39.17%
#     Worker 1: Train Loss: 2.3520, Train Accuracy: 38.21%
#     Worker 2: Train Loss: 2.5331, Train Accuracy: 35.14%
#     Worker 3: Train Loss: 2.4472, Train Accuracy: 36.37%
#     Worker 4: Train Loss: 2.2645, Train Accuracy: 39.89%
#     Worker 5: Train Loss: 2.3689, Train Accuracy: 38.83%
#     Worker 6: Train Loss: 2.3836, Train Accuracy: 37.78%
#     Worker 7: Train Loss: 2.4067, Train Accuracy: 37.78%
# Epoch 81/150: Test Loss: 2.2993, Test Accuracy: 41.02%
#     Worker 0: Train Loss: 2.3213, Train Accuracy: 39.46%
#     Worker 1: Train Loss: 2.3833, Train Accuracy: 37.07%
#     Worker 2: Train Loss: 2.3386, Train Accuracy: 39.31%
#     Worker 3: Train Loss: 2.3789, Train Accuracy: 38.22%
#     Worker 4: Train Loss: 2.3359, Train Accuracy: 38.59%
#     Worker 5: Train Loss: 2.2990, Train Accuracy: 39.79%
#     Worker 6: Train Loss: 2.5135, Train Accuracy: 35.66%
#     Worker 7: Train Loss: 2.4187, Train Accuracy: 37.65%
# Epoch 82/150: Test Loss: 2.3056, Test Accuracy: 41.25%
#     Worker 0: Train Loss: 2.3157, Train Accuracy: 39.57%
#     Worker 1: Train Loss: 2.4496, Train Accuracy: 36.08%
#     Worker 2: Train Loss: 2.3628, Train Accuracy: 38.82%
#     Worker 3: Train Loss: 2.3160, Train Accuracy: 39.04%
#     Worker 4: Train Loss: 2.3908, Train Accuracy: 37.74%
#     Worker 5: Train Loss: 2.4011, Train Accuracy: 38.02%
#     Worker 6: Train Loss: 2.3814, Train Accuracy: 37.44%
#     Worker 7: Train Loss: 2.4121, Train Accuracy: 37.82%
# Epoch 83/150: Test Loss: 2.3004, Test Accuracy: 41.40%
#     Worker 0: Train Loss: 2.4584, Train Accuracy: 37.20%
#     Worker 1: Train Loss: 2.2818, Train Accuracy: 40.10%
#     Worker 2: Train Loss: 2.4249, Train Accuracy: 37.22%
#     Worker 3: Train Loss: 2.3994, Train Accuracy: 37.82%
#     Worker 4: Train Loss: 2.4104, Train Accuracy: 36.86%
#     Worker 5: Train Loss: 2.3196, Train Accuracy: 39.01%
#     Worker 6: Train Loss: 2.2955, Train Accuracy: 39.98%
#     Worker 7: Train Loss: 2.4269, Train Accuracy: 37.25%
# Epoch 84/150: Test Loss: 2.2909, Test Accuracy: 41.02%
#     Worker 0: Train Loss: 2.3565, Train Accuracy: 38.67%
#     Worker 1: Train Loss: 2.3596, Train Accuracy: 38.34%
#     Worker 2: Train Loss: 2.2779, Train Accuracy: 40.27%
#     Worker 3: Train Loss: 2.2892, Train Accuracy: 39.71%
#     Worker 4: Train Loss: 2.4212, Train Accuracy: 36.82%
#     Worker 5: Train Loss: 2.3657, Train Accuracy: 38.64%
#     Worker 6: Train Loss: 2.3118, Train Accuracy: 38.56%
#     Worker 7: Train Loss: 2.3458, Train Accuracy: 38.40%
# Epoch 85/150: Test Loss: 2.2760, Test Accuracy: 41.77%
#     Worker 0: Train Loss: 2.2839, Train Accuracy: 40.08%
#     Worker 1: Train Loss: 2.4451, Train Accuracy: 37.60%
#     Worker 2: Train Loss: 2.3523, Train Accuracy: 39.62%
#     Worker 3: Train Loss: 2.4121, Train Accuracy: 36.38%
#     Worker 4: Train Loss: 2.2545, Train Accuracy: 40.75%
#     Worker 5: Train Loss: 2.3214, Train Accuracy: 39.55%
#     Worker 6: Train Loss: 2.3647, Train Accuracy: 38.59%
#     Worker 7: Train Loss: 2.4260, Train Accuracy: 37.31%
# Epoch 86/150: Test Loss: 2.2867, Test Accuracy: 41.28%
#     Worker 0: Train Loss: 2.3275, Train Accuracy: 39.74%
#     Worker 1: Train Loss: 2.2903, Train Accuracy: 39.30%
#     Worker 2: Train Loss: 2.3793, Train Accuracy: 38.27%
#     Worker 3: Train Loss: 2.4801, Train Accuracy: 36.94%
#     Worker 4: Train Loss: 2.2995, Train Accuracy: 39.46%
#     Worker 5: Train Loss: 2.3876, Train Accuracy: 38.26%
#     Worker 6: Train Loss: 2.2867, Train Accuracy: 39.68%
#     Worker 7: Train Loss: 2.3365, Train Accuracy: 39.92%
# Epoch 87/150: Test Loss: 2.2629, Test Accuracy: 41.79%
#     Worker 0: Train Loss: 2.3526, Train Accuracy: 38.42%
#     Worker 1: Train Loss: 2.2199, Train Accuracy: 40.75%
#     Worker 2: Train Loss: 2.4180, Train Accuracy: 37.55%
#     Worker 3: Train Loss: 2.3352, Train Accuracy: 39.22%
#     Worker 4: Train Loss: 2.3136, Train Accuracy: 39.36%
#     Worker 5: Train Loss: 2.3376, Train Accuracy: 39.55%
#     Worker 6: Train Loss: 2.4251, Train Accuracy: 36.98%
#     Worker 7: Train Loss: 2.3055, Train Accuracy: 39.89%
# Epoch 88/150: Test Loss: 2.2772, Test Accuracy: 41.51%
#     Worker 0: Train Loss: 2.3974, Train Accuracy: 37.10%
#     Worker 1: Train Loss: 2.2782, Train Accuracy: 40.35%
#     Worker 2: Train Loss: 2.3015, Train Accuracy: 40.19%
#     Worker 3: Train Loss: 2.3208, Train Accuracy: 39.57%
#     Worker 4: Train Loss: 2.2118, Train Accuracy: 41.28%
#     Worker 5: Train Loss: 2.3058, Train Accuracy: 40.88%
#     Worker 6: Train Loss: 2.3086, Train Accuracy: 38.94%
#     Worker 7: Train Loss: 2.3459, Train Accuracy: 38.80%
# Epoch 89/150: Test Loss: 2.2697, Test Accuracy: 41.52%
#     Worker 0: Train Loss: 2.2942, Train Accuracy: 39.34%
#     Worker 1: Train Loss: 2.2657, Train Accuracy: 39.66%
#     Worker 2: Train Loss: 2.2989, Train Accuracy: 39.70%
#     Worker 3: Train Loss: 2.3020, Train Accuracy: 39.44%
#     Worker 4: Train Loss: 2.3458, Train Accuracy: 38.32%
#     Worker 5: Train Loss: 2.3230, Train Accuracy: 39.02%
#     Worker 6: Train Loss: 2.3493, Train Accuracy: 38.67%
#     Worker 7: Train Loss: 2.2650, Train Accuracy: 40.93%
# Epoch 90/150: Test Loss: 2.2418, Test Accuracy: 42.07%
#     Worker 0: Train Loss: 2.2628, Train Accuracy: 40.69%
#     Worker 1: Train Loss: 2.3124, Train Accuracy: 39.30%
#     Worker 2: Train Loss: 2.3316, Train Accuracy: 39.41%
#     Worker 3: Train Loss: 2.2756, Train Accuracy: 40.34%
#     Worker 4: Train Loss: 2.2485, Train Accuracy: 40.30%
#     Worker 5: Train Loss: 2.2816, Train Accuracy: 40.26%
#     Worker 6: Train Loss: 2.2806, Train Accuracy: 40.13%
#     Worker 7: Train Loss: 2.3569, Train Accuracy: 38.40%
# Epoch 91/150: Test Loss: 2.2366, Test Accuracy: 42.05%
#     Worker 0: Train Loss: 2.2267, Train Accuracy: 41.70%
#     Worker 1: Train Loss: 2.2755, Train Accuracy: 40.19%
#     Worker 2: Train Loss: 2.2560, Train Accuracy: 41.63%
#     Worker 3: Train Loss: 2.3539, Train Accuracy: 38.85%
#     Worker 4: Train Loss: 2.2232, Train Accuracy: 41.31%
#     Worker 5: Train Loss: 2.2300, Train Accuracy: 40.90%
#     Worker 6: Train Loss: 2.2559, Train Accuracy: 40.50%
#     Worker 7: Train Loss: 2.2990, Train Accuracy: 39.73%
# Epoch 92/150: Test Loss: 2.2053, Test Accuracy: 43.12%
#     Worker 0: Train Loss: 2.2017, Train Accuracy: 40.91%
#     Worker 1: Train Loss: 2.2085, Train Accuracy: 41.02%
#     Worker 2: Train Loss: 2.2508, Train Accuracy: 40.77%
#     Worker 3: Train Loss: 2.2158, Train Accuracy: 41.34%
#     Worker 4: Train Loss: 2.1980, Train Accuracy: 41.82%
#     Worker 5: Train Loss: 2.2764, Train Accuracy: 40.88%
#     Worker 6: Train Loss: 2.2325, Train Accuracy: 41.50%
#     Worker 7: Train Loss: 2.1788, Train Accuracy: 42.59%
# Epoch 93/150: Test Loss: 2.2217, Test Accuracy: 42.57%
#     Worker 0: Train Loss: 2.2490, Train Accuracy: 41.31%
# ...
#     Worker 6: Train Loss: 1.9171, Train Accuracy: 47.82%
#     Worker 7: Train Loss: 1.8504, Train Accuracy: 49.14%
# Epoch 120/150: Test Loss: 2.0715, Test Accuracy: 45.75%
#     Worker 0: Train Loss: 2.0020, Train Accuracy: 45.55%
#     Worker 1: Train Loss: 1.9653, Train Accuracy: 47.10%
#     Worker 2: Train Loss: 1.9521, Train Accuracy: 47.87%
#     Worker 3: Train Loss: 1.9703, Train Accuracy: 47.12%
#     Worker 4: Train Loss: 1.8333, Train Accuracy: 50.29%
#     Worker 5: Train Loss: 1.8430, Train Accuracy: 49.68%
#     Worker 6: Train Loss: 1.9774, Train Accuracy: 46.91%
#     Worker 7: Train Loss: 1.9447, Train Accuracy: 47.46%
# Epoch 121/150: Test Loss: 2.0662, Test Accuracy: 45.71%
#     Worker 0: Train Loss: 1.9194, Train Accuracy: 48.59%
#     Worker 1: Train Loss: 1.8780, Train Accuracy: 49.12%
#     Worker 2: Train Loss: 1.9493, Train Accuracy: 47.81%
#     Worker 3: Train Loss: 1.9215, Train Accuracy: 48.34%
#     Worker 4: Train Loss: 1.9445, Train Accuracy: 47.68%
#     Worker 5: Train Loss: 1.9080, Train Accuracy: 48.98%
#     Worker 6: Train Loss: 1.8964, Train Accuracy: 48.99%
#     Worker 7: Train Loss: 1.8901, Train Accuracy: 48.37%
# Epoch 122/150: Test Loss: 2.0594, Test Accuracy: 45.89%
#     Worker 0: Train Loss: 1.8603, Train Accuracy: 49.68%
#     Worker 1: Train Loss: 1.9388, Train Accuracy: 47.62%
#     Worker 2: Train Loss: 1.8779, Train Accuracy: 49.57%
#     Worker 3: Train Loss: 1.8592, Train Accuracy: 49.38%
#     Worker 4: Train Loss: 1.8509, Train Accuracy: 49.39%
#     Worker 5: Train Loss: 1.8486, Train Accuracy: 50.00%
#     Worker 6: Train Loss: 1.9474, Train Accuracy: 48.06%
#     Worker 7: Train Loss: 1.8989, Train Accuracy: 48.74%
# Epoch 123/150: Test Loss: 2.0622, Test Accuracy: 45.90%
#     Worker 0: Train Loss: 1.8920, Train Accuracy: 48.26%
#     Worker 1: Train Loss: 1.9087, Train Accuracy: 48.78%
#     Worker 2: Train Loss: 1.8765, Train Accuracy: 49.55%
#     Worker 3: Train Loss: 1.8775, Train Accuracy: 49.04%
#     Worker 4: Train Loss: 1.7918, Train Accuracy: 51.04%
#     Worker 5: Train Loss: 1.8555, Train Accuracy: 49.81%
#     Worker 6: Train Loss: 1.8645, Train Accuracy: 50.18%
#     Worker 7: Train Loss: 1.8956, Train Accuracy: 48.45%
# Epoch 124/150: Test Loss: 2.0566, Test Accuracy: 46.35%
#     Worker 0: Train Loss: 1.9322, Train Accuracy: 47.39%
#     Worker 1: Train Loss: 1.8210, Train Accuracy: 50.05%
#     Worker 2: Train Loss: 1.8174, Train Accuracy: 50.78%
#     Worker 3: Train Loss: 1.8375, Train Accuracy: 49.22%
#     Worker 4: Train Loss: 1.8654, Train Accuracy: 48.75%
#     Worker 5: Train Loss: 1.8852, Train Accuracy: 49.18%
#     Worker 6: Train Loss: 1.9595, Train Accuracy: 47.47%
#     Worker 7: Train Loss: 1.9341, Train Accuracy: 48.27%
# Epoch 125/150: Test Loss: 2.0574, Test Accuracy: 46.04%
#     Worker 0: Train Loss: 1.8721, Train Accuracy: 49.42%
#     Worker 1: Train Loss: 1.8909, Train Accuracy: 48.75%
#     Worker 2: Train Loss: 1.8586, Train Accuracy: 49.70%
#     Worker 3: Train Loss: 1.9367, Train Accuracy: 46.83%
#     Worker 4: Train Loss: 1.9246, Train Accuracy: 47.95%
#     Worker 5: Train Loss: 1.7850, Train Accuracy: 51.30%
#     Worker 6: Train Loss: 1.8440, Train Accuracy: 48.98%
#     Worker 7: Train Loss: 1.8025, Train Accuracy: 51.02%
# Epoch 126/150: Test Loss: 2.0580, Test Accuracy: 45.97%
#     Worker 0: Train Loss: 1.8568, Train Accuracy: 48.80%
#     Worker 1: Train Loss: 1.8783, Train Accuracy: 48.69%
#     Worker 2: Train Loss: 1.8235, Train Accuracy: 50.80%
#     Worker 3: Train Loss: 1.8806, Train Accuracy: 48.08%
#     Worker 4: Train Loss: 1.8032, Train Accuracy: 50.30%
#     Worker 5: Train Loss: 1.7967, Train Accuracy: 50.24%
#     Worker 6: Train Loss: 1.8364, Train Accuracy: 50.27%
#     Worker 7: Train Loss: 1.8814, Train Accuracy: 48.80%
# Epoch 127/150: Test Loss: 2.0431, Test Accuracy: 46.15%
#     Worker 0: Train Loss: 1.8499, Train Accuracy: 49.87%
#     Worker 1: Train Loss: 1.8313, Train Accuracy: 50.32%
#     Worker 2: Train Loss: 1.8398, Train Accuracy: 49.90%
#     Worker 3: Train Loss: 1.8610, Train Accuracy: 48.74%
#     Worker 4: Train Loss: 1.8106, Train Accuracy: 50.74%
#     Worker 5: Train Loss: 1.8397, Train Accuracy: 49.63%
#     Worker 6: Train Loss: 1.8658, Train Accuracy: 49.46%
#     Worker 7: Train Loss: 1.8517, Train Accuracy: 49.97%
# Epoch 128/150: Test Loss: 2.0568, Test Accuracy: 46.04%
#     Worker 0: Train Loss: 1.8293, Train Accuracy: 49.62%
#     Worker 1: Train Loss: 1.8634, Train Accuracy: 48.78%
#     Worker 2: Train Loss: 1.7980, Train Accuracy: 51.41%
#     Worker 3: Train Loss: 1.8182, Train Accuracy: 49.58%
#     Worker 4: Train Loss: 1.7944, Train Accuracy: 50.54%
#     Worker 5: Train Loss: 1.8586, Train Accuracy: 50.10%
#     Worker 6: Train Loss: 1.9202, Train Accuracy: 48.14%
#     Worker 7: Train Loss: 1.8685, Train Accuracy: 48.61%
# Epoch 129/150: Test Loss: 2.0423, Test Accuracy: 46.12%
#     Worker 0: Train Loss: 1.8993, Train Accuracy: 48.19%
#     Worker 1: Train Loss: 1.8099, Train Accuracy: 50.50%
#     Worker 2: Train Loss: 1.8331, Train Accuracy: 50.00%
#     Worker 3: Train Loss: 1.8076, Train Accuracy: 49.94%
#     Worker 4: Train Loss: 1.7922, Train Accuracy: 51.57%
#     Worker 5: Train Loss: 1.8444, Train Accuracy: 50.59%
#     Worker 6: Train Loss: 1.8473, Train Accuracy: 49.57%
#     Worker 7: Train Loss: 1.8338, Train Accuracy: 50.14%
# Epoch 130/150: Test Loss: 2.0510, Test Accuracy: 46.45%
#     Worker 0: Train Loss: 1.8063, Train Accuracy: 50.98%
#     Worker 1: Train Loss: 1.7972, Train Accuracy: 50.74%
#     Worker 2: Train Loss: 1.7808, Train Accuracy: 51.73%
#     Worker 3: Train Loss: 1.8701, Train Accuracy: 49.68%
#     Worker 4: Train Loss: 1.7871, Train Accuracy: 51.46%
#     Worker 5: Train Loss: 1.8200, Train Accuracy: 50.80%
#     Worker 6: Train Loss: 1.8752, Train Accuracy: 49.20%
#     Worker 7: Train Loss: 1.8127, Train Accuracy: 50.94%
# Epoch 131/150: Test Loss: 2.0355, Test Accuracy: 46.67%
#     Worker 0: Train Loss: 1.8215, Train Accuracy: 49.41%
#     Worker 1: Train Loss: 1.7907, Train Accuracy: 50.11%
#     Worker 2: Train Loss: 1.8097, Train Accuracy: 50.14%
#     Worker 3: Train Loss: 1.9871, Train Accuracy: 46.64%
#     Worker 4: Train Loss: 1.7937, Train Accuracy: 51.09%
#     Worker 5: Train Loss: 1.8382, Train Accuracy: 49.79%
#     Worker 6: Train Loss: 1.8290, Train Accuracy: 50.91%
#     Worker 7: Train Loss: 1.8032, Train Accuracy: 50.50%
# Epoch 132/150: Test Loss: 2.0371, Test Accuracy: 46.82%
#     Worker 0: Train Loss: 1.8379, Train Accuracy: 50.21%
#     Worker 1: Train Loss: 1.7866, Train Accuracy: 51.31%
#     Worker 2: Train Loss: 1.8138, Train Accuracy: 50.18%
#     Worker 3: Train Loss: 1.8187, Train Accuracy: 50.10%
#     Worker 4: Train Loss: 1.8011, Train Accuracy: 50.42%
#     Worker 5: Train Loss: 1.7492, Train Accuracy: 51.94%
#     Worker 6: Train Loss: 1.8345, Train Accuracy: 50.22%
#     Worker 7: Train Loss: 1.7856, Train Accuracy: 51.30%
# Epoch 133/150: Test Loss: 2.0307, Test Accuracy: 46.73%
#     Worker 0: Train Loss: 1.8133, Train Accuracy: 50.61%
#     Worker 1: Train Loss: 1.7697, Train Accuracy: 50.86%
#     Worker 2: Train Loss: 1.7898, Train Accuracy: 51.50%
#     Worker 3: Train Loss: 1.8417, Train Accuracy: 50.08%
#     Worker 4: Train Loss: 1.7272, Train Accuracy: 52.69%
#     Worker 5: Train Loss: 1.7909, Train Accuracy: 50.61%
#     Worker 6: Train Loss: 1.7746, Train Accuracy: 50.91%
#     Worker 7: Train Loss: 1.8387, Train Accuracy: 50.32%
# Epoch 134/150: Test Loss: 2.0296, Test Accuracy: 46.84%
#     Worker 0: Train Loss: 1.8085, Train Accuracy: 50.88%
#     Worker 1: Train Loss: 1.7838, Train Accuracy: 50.90%
#     Worker 2: Train Loss: 1.7061, Train Accuracy: 53.18%
#     Worker 3: Train Loss: 1.7648, Train Accuracy: 51.87%
#     Worker 4: Train Loss: 1.7161, Train Accuracy: 52.82%
#     Worker 5: Train Loss: 1.7654, Train Accuracy: 51.50%
#     Worker 6: Train Loss: 1.7938, Train Accuracy: 51.17%
#     Worker 7: Train Loss: 1.7514, Train Accuracy: 51.55%
# Epoch 135/150: Test Loss: 2.0318, Test Accuracy: 46.95%
#     Worker 0: Train Loss: 1.8120, Train Accuracy: 51.06%
#     Worker 1: Train Loss: 1.7519, Train Accuracy: 52.13%
#     Worker 2: Train Loss: 1.7675, Train Accuracy: 51.55%
#     Worker 3: Train Loss: 1.7735, Train Accuracy: 51.04%
#     Worker 4: Train Loss: 1.7233, Train Accuracy: 52.61%
#     Worker 5: Train Loss: 1.7506, Train Accuracy: 51.82%
#     Worker 6: Train Loss: 1.7735, Train Accuracy: 52.18%
#     Worker 7: Train Loss: 1.7681, Train Accuracy: 51.78%
# Epoch 136/150: Test Loss: 2.0311, Test Accuracy: 46.77%
#     Worker 0: Train Loss: 1.7483, Train Accuracy: 51.97%
#     Worker 1: Train Loss: 1.7288, Train Accuracy: 52.86%
#     Worker 2: Train Loss: 1.7492, Train Accuracy: 52.11%
#     Worker 3: Train Loss: 1.7589, Train Accuracy: 51.68%
#     Worker 4: Train Loss: 1.6998, Train Accuracy: 53.46%
#     Worker 5: Train Loss: 1.7360, Train Accuracy: 52.56%
#     Worker 6: Train Loss: 1.7632, Train Accuracy: 51.46%
#     Worker 7: Train Loss: 1.7415, Train Accuracy: 52.43%
# Epoch 137/150: Test Loss: 2.0249, Test Accuracy: 47.00%
#     Worker 0: Train Loss: 1.7755, Train Accuracy: 51.87%
#     Worker 1: Train Loss: 1.7366, Train Accuracy: 52.19%
#     Worker 2: Train Loss: 1.7395, Train Accuracy: 52.21%
#     Worker 3: Train Loss: 1.7363, Train Accuracy: 51.94%
#     Worker 4: Train Loss: 1.7513, Train Accuracy: 51.49%
#     Worker 5: Train Loss: 1.7505, Train Accuracy: 51.78%
#     Worker 6: Train Loss: 1.7686, Train Accuracy: 51.60%
#     Worker 7: Train Loss: 1.7467, Train Accuracy: 51.97%
# Epoch 138/150: Test Loss: 2.0291, Test Accuracy: 47.13%
#     Worker 0: Train Loss: 1.7190, Train Accuracy: 52.59%
#     Worker 1: Train Loss: 1.7142, Train Accuracy: 52.50%
#     Worker 2: Train Loss: 1.7083, Train Accuracy: 53.26%
#     Worker 3: Train Loss: 1.7526, Train Accuracy: 51.60%
#     Worker 4: Train Loss: 1.7351, Train Accuracy: 52.18%
#     Worker 5: Train Loss: 1.7557, Train Accuracy: 51.98%
#     Worker 6: Train Loss: 1.7663, Train Accuracy: 51.63%
#     Worker 7: Train Loss: 1.7169, Train Accuracy: 52.67%
# Epoch 139/150: Test Loss: 2.0170, Test Accuracy: 47.32%
#     Worker 0: Train Loss: 1.7198, Train Accuracy: 52.69%
#     Worker 1: Train Loss: 1.6945, Train Accuracy: 53.20%
#     Worker 2: Train Loss: 1.7061, Train Accuracy: 53.15%
#     Worker 3: Train Loss: 1.7036, Train Accuracy: 52.75%
#     Worker 4: Train Loss: 1.7027, Train Accuracy: 53.60%
#     Worker 5: Train Loss: 1.7387, Train Accuracy: 51.82%
#     Worker 6: Train Loss: 1.7393, Train Accuracy: 52.91%
#     Worker 7: Train Loss: 1.7872, Train Accuracy: 51.55%
# Epoch 140/150: Test Loss: 2.0187, Test Accuracy: 47.21%
#     Worker 0: Train Loss: 1.7266, Train Accuracy: 52.40%
#     Worker 1: Train Loss: 1.7280, Train Accuracy: 52.21%
#     Worker 2: Train Loss: 1.6885, Train Accuracy: 53.66%
#     Worker 3: Train Loss: 1.7209, Train Accuracy: 53.17%
#     Worker 4: Train Loss: 1.6867, Train Accuracy: 53.58%
#     Worker 5: Train Loss: 1.7239, Train Accuracy: 52.64%
#     Worker 6: Train Loss: 1.7036, Train Accuracy: 53.65%
#     Worker 7: Train Loss: 1.7173, Train Accuracy: 52.75%
# Epoch 141/150: Test Loss: 2.0310, Test Accuracy: 47.02%
#     Worker 0: Train Loss: 1.7225, Train Accuracy: 52.40%
#     Worker 1: Train Loss: 1.7018, Train Accuracy: 52.86%
#     Worker 2: Train Loss: 1.6920, Train Accuracy: 53.01%
#     Worker 3: Train Loss: 1.6963, Train Accuracy: 52.86%
#     Worker 4: Train Loss: 1.6791, Train Accuracy: 54.40%
#     Worker 5: Train Loss: 1.7072, Train Accuracy: 53.66%
#     Worker 6: Train Loss: 1.7642, Train Accuracy: 52.26%
#     Worker 7: Train Loss: 1.6853, Train Accuracy: 54.08%
# Epoch 142/150: Test Loss: 2.0161, Test Accuracy: 47.36%
#     Worker 0: Train Loss: 1.7201, Train Accuracy: 52.85%
#     Worker 1: Train Loss: 1.7288, Train Accuracy: 53.15%
#     Worker 2: Train Loss: 1.6814, Train Accuracy: 53.41%
#     Worker 3: Train Loss: 1.7008, Train Accuracy: 52.90%
#     Worker 4: Train Loss: 1.6894, Train Accuracy: 53.55%
#     Worker 5: Train Loss: 1.7211, Train Accuracy: 53.18%
#     Worker 6: Train Loss: 1.6947, Train Accuracy: 53.74%
#     Worker 7: Train Loss: 1.6994, Train Accuracy: 53.07%
# Epoch 143/150: Test Loss: 2.0159, Test Accuracy: 47.49%
#     Worker 0: Train Loss: 1.7188, Train Accuracy: 52.83%
#     Worker 1: Train Loss: 1.7220, Train Accuracy: 52.38%
#     Worker 2: Train Loss: 1.6636, Train Accuracy: 54.16%
#     Worker 3: Train Loss: 1.6928, Train Accuracy: 53.36%
#     Worker 4: Train Loss: 1.6639, Train Accuracy: 54.32%
#     Worker 5: Train Loss: 1.6713, Train Accuracy: 53.82%
#     Worker 6: Train Loss: 1.7107, Train Accuracy: 53.42%
#     Worker 7: Train Loss: 1.6920, Train Accuracy: 54.05%
# Epoch 144/150: Test Loss: 2.0156, Test Accuracy: 47.46%
#     Worker 0: Train Loss: 1.6731, Train Accuracy: 54.03%
#     Worker 1: Train Loss: 1.6983, Train Accuracy: 53.52%
#     Worker 2: Train Loss: 1.6587, Train Accuracy: 54.38%
#     Worker 3: Train Loss: 1.6881, Train Accuracy: 53.49%
#     Worker 4: Train Loss: 1.6458, Train Accuracy: 54.86%
#     Worker 5: Train Loss: 1.6606, Train Accuracy: 54.62%
#     Worker 6: Train Loss: 1.6895, Train Accuracy: 53.28%
#     Worker 7: Train Loss: 1.6768, Train Accuracy: 53.42%
# Epoch 145/150: Test Loss: 2.0126, Test Accuracy: 47.49%
#     Worker 0: Train Loss: 1.6844, Train Accuracy: 53.52%
#     Worker 1: Train Loss: 1.6758, Train Accuracy: 53.92%
#     Worker 2: Train Loss: 1.6461, Train Accuracy: 54.46%
#     Worker 3: Train Loss: 1.6899, Train Accuracy: 53.54%
#     Worker 4: Train Loss: 1.6664, Train Accuracy: 54.64%
#     Worker 5: Train Loss: 1.6631, Train Accuracy: 53.92%
#     Worker 6: Train Loss: 1.6728, Train Accuracy: 54.48%
#     Worker 7: Train Loss: 1.6682, Train Accuracy: 53.78%
# Epoch 146/150: Test Loss: 2.0113, Test Accuracy: 47.41%
#     Worker 0: Train Loss: 1.6612, Train Accuracy: 54.32%
#     Worker 1: Train Loss: 1.6452, Train Accuracy: 54.38%
#     Worker 2: Train Loss: 1.6388, Train Accuracy: 54.91%
#     Worker 3: Train Loss: 1.6547, Train Accuracy: 54.40%
#     Worker 4: Train Loss: 1.6410, Train Accuracy: 54.90%
#     Worker 5: Train Loss: 1.6685, Train Accuracy: 54.37%
#     Worker 6: Train Loss: 1.6956, Train Accuracy: 53.58%
#     Worker 7: Train Loss: 1.6713, Train Accuracy: 53.55%
# Epoch 147/150: Test Loss: 2.0120, Test Accuracy: 47.53%
#     Worker 0: Train Loss: 1.6722, Train Accuracy: 53.74%
#     Worker 1: Train Loss: 1.6447, Train Accuracy: 54.72%
#     Worker 2: Train Loss: 1.6387, Train Accuracy: 55.41%
#     Worker 3: Train Loss: 1.6739, Train Accuracy: 53.46%
#     Worker 4: Train Loss: 1.6286, Train Accuracy: 54.78%
#     Worker 5: Train Loss: 1.6577, Train Accuracy: 54.77%
#     Worker 6: Train Loss: 1.6785, Train Accuracy: 54.66%
#     Worker 7: Train Loss: 1.6687, Train Accuracy: 53.82%
# Epoch 148/150: Test Loss: 2.0093, Test Accuracy: 47.43%
#     Worker 0: Train Loss: 1.6423, Train Accuracy: 54.66%
#     Worker 1: Train Loss: 1.6494, Train Accuracy: 54.85%
#     Worker 2: Train Loss: 1.6305, Train Accuracy: 54.91%
#     Worker 3: Train Loss: 1.6568, Train Accuracy: 54.00%
#     Worker 4: Train Loss: 1.6373, Train Accuracy: 55.18%
#     Worker 5: Train Loss: 1.6302, Train Accuracy: 54.91%
#     Worker 6: Train Loss: 1.6523, Train Accuracy: 54.64%
#     Worker 7: Train Loss: 1.6567, Train Accuracy: 54.16%
# Epoch 149/150: Test Loss: 2.0086, Test Accuracy: 47.51%
#     Worker 0: Train Loss: 1.6575, Train Accuracy: 54.69%
#     Worker 1: Train Loss: 1.6442, Train Accuracy: 54.80%
#     Worker 2: Train Loss: 1.6318, Train Accuracy: 55.55%
#     Worker 3: Train Loss: 1.6462, Train Accuracy: 54.72%
#     Worker 4: Train Loss: 1.6178, Train Accuracy: 56.00%
#     Worker 5: Train Loss: 1.6420, Train Accuracy: 55.34%
#     Worker 6: Train Loss: 1.6443, Train Accuracy: 54.40%
#     Worker 7: Train Loss: 1.6475, Train Accuracy: 54.62%
# Epoch 150/150: Test Loss: 2.0094, Test Accuracy: 47.53%
#     Worker 0: Train Loss: 1.6633, Train Accuracy: 54.22%
#     Worker 1: Train Loss: 1.6248, Train Accuracy: 55.36%
#     Worker 2: Train Loss: 1.6406, Train Accuracy: 55.92%
#     Worker 3: Train Loss: 1.6419, Train Accuracy: 55.07%
#     Worker 4: Train Loss: 1.6000, Train Accuracy: 56.24%
#     Worker 5: Train Loss: 1.6323, Train Accuracy: 55.23%
#     Worker 6: Train Loss: 1.6515, Train Accuracy: 54.50%
#     Worker 7: Train Loss: 1.6485, Train Accuracy: 54.45%
