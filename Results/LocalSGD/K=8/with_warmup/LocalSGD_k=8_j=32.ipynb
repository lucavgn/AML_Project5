# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs - warmup_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")

    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch):
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            # Perform J local step before synchronization
            for j in range(J):
                try:
                    # Get a batch from the current worker's shard using next()
                    images, labels = next(shard_iterators[k])
                    images, labels = images.to(device), labels.to(device)  # Move to device
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

                except StopIteration:
                    # If the iterator has exhausted the data, restart the iterator
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k]) # Resume from the next batch
                    images, labels = images.to(device), labels.to(device)
                    # Perform optimization step
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        # Perform model synchronization
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            # Update each worker model with the global parameters
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
        else:
            warmup_factor = (epoch + 1) / warmup_epochs
            lr = warmup_factor * learning_rate
            for optimizer in optimizers:
                for param_group in optimizer.param_groups:
                    param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 8 --j 32
# Out:
# Training with K=8, J=32
# Global iteration per epoch: 4
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:04<00:00, 39.2MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00800
# Epoch 1/150: Test Loss: 4.5437, Test Accuracy: 2.74%
#     Worker 0: Train Loss: 4.5945, Train Accuracy: 1.31%
#     Worker 1: Train Loss: 4.5944, Train Accuracy: 1.42%
#     Worker 2: Train Loss: 4.5932, Train Accuracy: 1.76%
#     Worker 3: Train Loss: 4.5924, Train Accuracy: 1.52%
#     Worker 4: Train Loss: 4.5923, Train Accuracy: 1.47%
#     Worker 5: Train Loss: 4.5894, Train Accuracy: 1.49%
#     Worker 6: Train Loss: 4.5917, Train Accuracy: 1.36%
#     Worker 7: Train Loss: 4.5902, Train Accuracy: 1.35%
# Epoch 2/150: Test Loss: 4.4329, Test Accuracy: 4.04%
#     Worker 0: Train Loss: 4.5050, Train Accuracy: 3.61%
#     Worker 1: Train Loss: 4.5031, Train Accuracy: 3.34%
#     Worker 2: Train Loss: 4.5061, Train Accuracy: 3.39%
#     Worker 3: Train Loss: 4.5005, Train Accuracy: 3.13%
#     Worker 4: Train Loss: 4.4991, Train Accuracy: 2.89%
#     Worker 5: Train Loss: 4.4947, Train Accuracy: 2.99%
#     Worker 6: Train Loss: 4.5039, Train Accuracy: 3.27%
#     Worker 7: Train Loss: 4.4989, Train Accuracy: 3.49%
# Epoch 3/150: Test Loss: 4.1771, Test Accuracy: 6.47%
#     Worker 0: Train Loss: 4.3347, Train Accuracy: 4.30%
#     Worker 1: Train Loss: 4.3353, Train Accuracy: 4.49%
#     Worker 2: Train Loss: 4.3269, Train Accuracy: 4.82%
#     Worker 3: Train Loss: 4.3369, Train Accuracy: 4.61%
#     Worker 4: Train Loss: 4.3194, Train Accuracy: 4.81%
#     Worker 5: Train Loss: 4.3130, Train Accuracy: 4.76%
#     Worker 6: Train Loss: 4.3451, Train Accuracy: 4.28%
#     Worker 7: Train Loss: 4.3214, Train Accuracy: 4.72%
# Epoch 4/150: Test Loss: 4.0351, Test Accuracy: 8.05%
#     Worker 0: Train Loss: 4.1738, Train Accuracy: 5.94%
#     Worker 1: Train Loss: 4.1839, Train Accuracy: 5.93%
#     Worker 2: Train Loss: 4.1818, Train Accuracy: 5.56%
#     Worker 3: Train Loss: 4.1927, Train Accuracy: 5.89%
#     Worker 4: Train Loss: 4.1497, Train Accuracy: 6.41%
#     Worker 5: Train Loss: 4.1491, Train Accuracy: 5.78%
#     Worker 6: Train Loss: 4.1718, Train Accuracy: 5.94%
#     Worker 7: Train Loss: 4.1853, Train Accuracy: 5.90%
# Epoch 5/150: Test Loss: 3.9137, Test Accuracy: 10.32%
#     Worker 0: Train Loss: 4.0809, Train Accuracy: 7.16%
#     Worker 1: Train Loss: 4.0792, Train Accuracy: 7.04%
#     Worker 2: Train Loss: 4.0694, Train Accuracy: 7.14%
#     Worker 3: Train Loss: 4.0849, Train Accuracy: 7.15%
#     Worker 4: Train Loss: 4.0568, Train Accuracy: 7.67%
#     Worker 5: Train Loss: 4.0498, Train Accuracy: 7.91%
#     Worker 6: Train Loss: 4.1004, Train Accuracy: 6.39%
#     Worker 7: Train Loss: 4.0782, Train Accuracy: 7.47%
# Epoch 6/150: Test Loss: 3.7880, Test Accuracy: 12.42%
#     Worker 0: Train Loss: 3.9677, Train Accuracy: 9.07%
#     Worker 1: Train Loss: 3.9791, Train Accuracy: 8.30%
#     Worker 2: Train Loss: 3.9677, Train Accuracy: 8.96%
#     Worker 3: Train Loss: 3.9876, Train Accuracy: 8.45%
#     Worker 4: Train Loss: 3.9294, Train Accuracy: 9.60%
#     Worker 5: Train Loss: 3.9292, Train Accuracy: 9.45%
#     Worker 6: Train Loss: 3.9711, Train Accuracy: 8.64%
#     Worker 7: Train Loss: 3.9699, Train Accuracy: 9.09%
# Epoch 7/150: Test Loss: 3.6551, Test Accuracy: 14.99%
#     Worker 0: Train Loss: 3.8540, Train Accuracy: 10.41%
#     Worker 1: Train Loss: 3.8463, Train Accuracy: 10.33%
#     Worker 2: Train Loss: 3.8483, Train Accuracy: 11.21%
#     Worker 3: Train Loss: 3.8535, Train Accuracy: 10.65%
#     Worker 4: Train Loss: 3.7970, Train Accuracy: 10.89%
#     Worker 5: Train Loss: 3.7920, Train Accuracy: 11.82%
#     Worker 6: Train Loss: 3.8477, Train Accuracy: 10.52%
#     Worker 7: Train Loss: 3.8495, Train Accuracy: 11.19%
# Epoch 8/150: Test Loss: 3.5767, Test Accuracy: 15.80%
#     Worker 0: Train Loss: 3.7179, Train Accuracy: 12.30%
#     Worker 1: Train Loss: 3.7516, Train Accuracy: 12.07%
#     Worker 2: Train Loss: 3.7351, Train Accuracy: 12.72%
#     Worker 3: Train Loss: 3.7853, Train Accuracy: 11.32%
#     Worker 4: Train Loss: 3.7177, Train Accuracy: 12.28%
#     Worker 5: Train Loss: 3.6942, Train Accuracy: 12.91%
#     Worker 6: Train Loss: 3.7407, Train Accuracy: 12.20%
#     Worker 7: Train Loss: 3.7492, Train Accuracy: 12.37%
# Epoch 9/150: Test Loss: 3.4729, Test Accuracy: 17.89%
#     Worker 0: Train Loss: 3.6676, Train Accuracy: 13.39%
#     Worker 1: Train Loss: 3.6427, Train Accuracy: 13.60%
#     Worker 2: Train Loss: 3.6511, Train Accuracy: 14.47%
#     Worker 3: Train Loss: 3.6773, Train Accuracy: 12.99%
#     Worker 4: Train Loss: 3.6169, Train Accuracy: 14.08%
#     Worker 5: Train Loss: 3.6117, Train Accuracy: 14.99%
#     Worker 6: Train Loss: 3.6716, Train Accuracy: 13.62%
#     Worker 7: Train Loss: 3.6445, Train Accuracy: 13.71%
# Epoch 10/150: Test Loss: 3.3891, Test Accuracy: 19.55%
#     Worker 0: Train Loss: 3.5762, Train Accuracy: 15.12%
#     Worker 1: Train Loss: 3.5766, Train Accuracy: 14.81%
#     Worker 2: Train Loss: 3.5718, Train Accuracy: 15.50%
#     Worker 3: Train Loss: 3.6157, Train Accuracy: 14.35%
#     Worker 4: Train Loss: 3.5412, Train Accuracy: 15.70%
#     Worker 5: Train Loss: 3.5365, Train Accuracy: 15.95%
#     Worker 6: Train Loss: 3.5843, Train Accuracy: 14.26%
#     Worker 7: Train Loss: 3.5734, Train Accuracy: 15.12%
# Epoch 11/150: Test Loss: 3.3024, Test Accuracy: 21.11%
#     Worker 0: Train Loss: 3.4962, Train Accuracy: 16.12%
#     Worker 1: Train Loss: 3.5002, Train Accuracy: 16.46%
#     Worker 2: Train Loss: 3.4934, Train Accuracy: 17.17%
#     Worker 3: Train Loss: 3.5359, Train Accuracy: 16.14%
#     Worker 4: Train Loss: 3.4852, Train Accuracy: 15.85%
#     Worker 5: Train Loss: 3.4386, Train Accuracy: 17.25%
#     Worker 6: Train Loss: 3.5120, Train Accuracy: 16.32%
#     Worker 7: Train Loss: 3.5099, Train Accuracy: 16.32%
# Epoch 12/150: Test Loss: 3.2454, Test Accuracy: 22.16%
#     Worker 0: Train Loss: 3.4453, Train Accuracy: 17.27%
#     Worker 1: Train Loss: 3.4389, Train Accuracy: 17.65%
#     Worker 2: Train Loss: 3.4088, Train Accuracy: 18.29%
#     Worker 3: Train Loss: 3.4578, Train Accuracy: 16.88%
#     Worker 4: Train Loss: 3.3932, Train Accuracy: 17.59%
#     Worker 5: Train Loss: 3.3878, Train Accuracy: 18.70%
#     Worker 6: Train Loss: 3.4472, Train Accuracy: 17.29%
#     Worker 7: Train Loss: 3.4244, Train Accuracy: 17.49%
# Epoch 13/150: Test Loss: 3.1724, Test Accuracy: 23.64%
#     Worker 0: Train Loss: 3.3712, Train Accuracy: 18.15%
#     Worker 1: Train Loss: 3.3503, Train Accuracy: 19.09%
#     Worker 2: Train Loss: 3.3450, Train Accuracy: 19.29%
#     Worker 3: Train Loss: 3.3759, Train Accuracy: 18.95%
#     Worker 4: Train Loss: 3.3301, Train Accuracy: 19.16%
#     Worker 5: Train Loss: 3.2858, Train Accuracy: 20.27%
#     Worker 6: Train Loss: 3.3889, Train Accuracy: 17.63%
#     Worker 7: Train Loss: 3.3726, Train Accuracy: 18.08%
# Epoch 14/150: Test Loss: 3.0934, Test Accuracy: 24.81%
#     Worker 0: Train Loss: 3.2805, Train Accuracy: 19.62%
#     Worker 1: Train Loss: 3.2789, Train Accuracy: 20.35%
#     Worker 2: Train Loss: 3.2856, Train Accuracy: 20.52%
#     Worker 3: Train Loss: 3.3253, Train Accuracy: 18.89%
#     Worker 4: Train Loss: 3.2645, Train Accuracy: 20.70%
#     Worker 5: Train Loss: 3.2429, Train Accuracy: 21.12%
#     Worker 6: Train Loss: 3.3152, Train Accuracy: 19.48%
#     Worker 7: Train Loss: 3.2930, Train Accuracy: 19.71%
# Epoch 15/150: Test Loss: 3.0334, Test Accuracy: 26.62%
#     Worker 0: Train Loss: 3.2483, Train Accuracy: 20.80%
#     Worker 1: Train Loss: 3.2293, Train Accuracy: 20.51%
#     Worker 2: Train Loss: 3.2216, Train Accuracy: 22.02%
#     Worker 3: Train Loss: 3.2902, Train Accuracy: 19.72%
#     Worker 4: Train Loss: 3.1916, Train Accuracy: 21.31%
#     Worker 5: Train Loss: 3.1965, Train Accuracy: 21.80%
#     Worker 6: Train Loss: 3.2514, Train Accuracy: 20.43%
#     Worker 7: Train Loss: 3.2254, Train Accuracy: 21.53%
# Epoch 16/150: Test Loss: 2.9964, Test Accuracy: 27.23%
#     Worker 0: Train Loss: 3.1847, Train Accuracy: 22.35%
#     Worker 1: Train Loss: 3.1652, Train Accuracy: 21.51%
#     Worker 2: Train Loss: 3.1885, Train Accuracy: 22.61%
#     Worker 3: Train Loss: 3.2190, Train Accuracy: 21.63%
#     Worker 4: Train Loss: 3.1422, Train Accuracy: 22.68%
#     Worker 5: Train Loss: 3.1661, Train Accuracy: 22.79%
#     Worker 6: Train Loss: 3.2032, Train Accuracy: 21.90%
#     Worker 7: Train Loss: 3.1881, Train Accuracy: 22.03%
# Epoch 17/150: Test Loss: 2.9259, Test Accuracy: 28.13%
#     Worker 0: Train Loss: 3.1288, Train Accuracy: 22.46%
#     Worker 1: Train Loss: 3.0969, Train Accuracy: 23.12%
#     Worker 2: Train Loss: 3.1084, Train Accuracy: 23.94%
#     Worker 3: Train Loss: 3.1672, Train Accuracy: 22.41%
#     Worker 4: Train Loss: 3.0735, Train Accuracy: 23.59%
#     Worker 5: Train Loss: 3.0533, Train Accuracy: 24.71%
#     Worker 6: Train Loss: 3.1335, Train Accuracy: 22.29%
#     Worker 7: Train Loss: 3.1124, Train Accuracy: 22.93%
# Epoch 18/150: Test Loss: 2.8775, Test Accuracy: 29.20%
#     Worker 0: Train Loss: 3.0992, Train Accuracy: 23.53%
#     Worker 1: Train Loss: 3.0500, Train Accuracy: 23.86%
#     Worker 2: Train Loss: 3.0628, Train Accuracy: 24.37%
#     Worker 3: Train Loss: 3.1399, Train Accuracy: 22.57%
#     Worker 4: Train Loss: 3.0566, Train Accuracy: 25.04%
#     Worker 5: Train Loss: 3.0144, Train Accuracy: 25.26%
#     Worker 6: Train Loss: 3.1015, Train Accuracy: 22.94%
#     Worker 7: Train Loss: 3.0624, Train Accuracy: 25.14%
# Epoch 19/150: Test Loss: 2.8242, Test Accuracy: 30.18%
#     Worker 0: Train Loss: 3.0354, Train Accuracy: 23.82%
#     Worker 1: Train Loss: 3.0137, Train Accuracy: 24.68%
#     Worker 2: Train Loss: 3.0492, Train Accuracy: 24.53%
#     Worker 3: Train Loss: 3.0481, Train Accuracy: 24.70%
#     Worker 4: Train Loss: 2.9952, Train Accuracy: 25.63%
#     Worker 5: Train Loss: 3.0012, Train Accuracy: 25.62%
#     Worker 6: Train Loss: 3.0691, Train Accuracy: 23.66%
#     Worker 7: Train Loss: 3.0431, Train Accuracy: 24.38%
# Epoch 20/150: Test Loss: 2.7965, Test Accuracy: 30.43%
#     Worker 0: Train Loss: 2.9765, Train Accuracy: 25.37%
#     Worker 1: Train Loss: 2.9614, Train Accuracy: 26.04%
#     Worker 2: Train Loss: 2.9668, Train Accuracy: 26.87%
#     Worker 3: Train Loss: 3.0250, Train Accuracy: 24.90%
#     Worker 4: Train Loss: 2.9599, Train Accuracy: 26.03%
#     Worker 5: Train Loss: 2.9306, Train Accuracy: 26.47%
#     Worker 6: Train Loss: 2.9753, Train Accuracy: 25.45%
#     Worker 7: Train Loss: 2.9613, Train Accuracy: 25.86%
# Epoch 21/150: Test Loss: 2.7478, Test Accuracy: 31.40%
#     Worker 0: Train Loss: 2.9582, Train Accuracy: 26.34%
#     Worker 1: Train Loss: 2.9202, Train Accuracy: 26.99%
#     Worker 2: Train Loss: 2.9458, Train Accuracy: 27.21%
#     Worker 3: Train Loss: 2.9622, Train Accuracy: 25.76%
#     Worker 4: Train Loss: 2.9300, Train Accuracy: 26.21%
#     Worker 5: Train Loss: 2.9118, Train Accuracy: 27.01%
#     Worker 6: Train Loss: 2.9697, Train Accuracy: 25.91%
#     Worker 7: Train Loss: 2.9612, Train Accuracy: 26.49%
# Epoch 22/150: Test Loss: 2.6856, Test Accuracy: 32.74%
#     Worker 0: Train Loss: 2.9037, Train Accuracy: 27.33%
#     Worker 1: Train Loss: 2.8685, Train Accuracy: 27.22%
#     Worker 2: Train Loss: 2.9198, Train Accuracy: 27.29%
#     Worker 3: Train Loss: 2.9151, Train Accuracy: 26.73%
#     Worker 4: Train Loss: 2.8733, Train Accuracy: 27.37%
#     Worker 5: Train Loss: 2.8356, Train Accuracy: 29.20%
#     Worker 6: Train Loss: 2.9177, Train Accuracy: 27.04%
#     Worker 7: Train Loss: 2.8972, Train Accuracy: 27.32%
# Epoch 23/150: Test Loss: 2.6729, Test Accuracy: 32.74%
#     Worker 0: Train Loss: 2.8336, Train Accuracy: 28.89%
#     Worker 1: Train Loss: 2.8182, Train Accuracy: 28.53%
#     Worker 2: Train Loss: 2.8285, Train Accuracy: 28.55%
#     Worker 3: Train Loss: 2.8686, Train Accuracy: 27.16%
#     Worker 4: Train Loss: 2.8243, Train Accuracy: 28.68%
#     Worker 5: Train Loss: 2.8261, Train Accuracy: 29.36%
#     Worker 6: Train Loss: 2.8633, Train Accuracy: 28.23%
#     Worker 7: Train Loss: 2.8441, Train Accuracy: 28.56%
# Epoch 24/150: Test Loss: 2.6190, Test Accuracy: 34.03%
#     Worker 0: Train Loss: 2.8224, Train Accuracy: 28.27%
#     Worker 1: Train Loss: 2.7694, Train Accuracy: 29.50%
#     Worker 2: Train Loss: 2.8016, Train Accuracy: 29.68%
#     Worker 3: Train Loss: 2.8307, Train Accuracy: 28.10%
#     Worker 4: Train Loss: 2.7656, Train Accuracy: 29.61%
#     Worker 5: Train Loss: 2.7725, Train Accuracy: 29.85%
#     Worker 6: Train Loss: 2.8212, Train Accuracy: 28.49%
#     Worker 7: Train Loss: 2.7900, Train Accuracy: 29.99%
# Epoch 25/150: Test Loss: 2.5808, Test Accuracy: 34.97%
#     Worker 0: Train Loss: 2.7905, Train Accuracy: 29.14%
#     Worker 1: Train Loss: 2.7496, Train Accuracy: 29.88%
#     Worker 2: Train Loss: 2.7820, Train Accuracy: 29.34%
#     Worker 3: Train Loss: 2.7642, Train Accuracy: 29.50%
#     Worker 4: Train Loss: 2.7250, Train Accuracy: 30.71%
#     Worker 5: Train Loss: 2.7283, Train Accuracy: 31.29%
#     Worker 6: Train Loss: 2.7750, Train Accuracy: 29.41%
#     Worker 7: Train Loss: 2.7626, Train Accuracy: 30.07%
# Epoch 26/150: Test Loss: 2.5432, Test Accuracy: 35.90%
#     Worker 0: Train Loss: 2.7417, Train Accuracy: 30.69%
#     Worker 1: Train Loss: 2.7110, Train Accuracy: 30.92%
#     Worker 2: Train Loss: 2.7363, Train Accuracy: 30.83%
#     Worker 3: Train Loss: 2.7318, Train Accuracy: 30.38%
#     Worker 4: Train Loss: 2.6999, Train Accuracy: 31.36%
#     Worker 5: Train Loss: 2.6823, Train Accuracy: 32.48%
#     Worker 6: Train Loss: 2.7580, Train Accuracy: 29.46%
#     Worker 7: Train Loss: 2.7319, Train Accuracy: 30.51%
# Epoch 27/150: Test Loss: 2.5099, Test Accuracy: 36.36%
#     Worker 0: Train Loss: 2.6791, Train Accuracy: 31.79%
#     Worker 1: Train Loss: 2.6607, Train Accuracy: 31.35%
#     Worker 2: Train Loss: 2.6714, Train Accuracy: 32.31%
#     Worker 3: Train Loss: 2.7035, Train Accuracy: 31.57%
#     Worker 4: Train Loss: 2.6378, Train Accuracy: 32.41%
#     Worker 5: Train Loss: 2.6724, Train Accuracy: 31.71%
#     Worker 6: Train Loss: 2.6881, Train Accuracy: 31.30%
#     Worker 7: Train Loss: 2.6599, Train Accuracy: 31.93%
# Epoch 28/150: Test Loss: 2.4657, Test Accuracy: 37.29%
#     Worker 0: Train Loss: 2.6664, Train Accuracy: 32.29%
#     Worker 1: Train Loss: 2.6222, Train Accuracy: 32.94%
#     Worker 2: Train Loss: 2.6505, Train Accuracy: 32.34%
#     Worker 3: Train Loss: 2.6695, Train Accuracy: 32.07%
#     Worker 4: Train Loss: 2.6293, Train Accuracy: 32.83%
#     Worker 5: Train Loss: 2.6135, Train Accuracy: 33.18%
#     Worker 6: Train Loss: 2.6570, Train Accuracy: 31.81%
#     Worker 7: Train Loss: 2.6416, Train Accuracy: 32.18%
# Epoch 29/150: Test Loss: 2.4623, Test Accuracy: 37.62%
#     Worker 0: Train Loss: 2.6286, Train Accuracy: 31.49%
#     Worker 1: Train Loss: 2.6247, Train Accuracy: 32.22%
#     Worker 2: Train Loss: 2.6118, Train Accuracy: 33.26%
#     Worker 3: Train Loss: 2.6424, Train Accuracy: 32.33%
#     Worker 4: Train Loss: 2.5812, Train Accuracy: 33.53%
#     Worker 5: Train Loss: 2.5903, Train Accuracy: 34.19%
#     Worker 6: Train Loss: 2.6418, Train Accuracy: 32.40%
#     Worker 7: Train Loss: 2.6087, Train Accuracy: 33.18%
# Epoch 30/150: Test Loss: 2.4209, Test Accuracy: 38.46%
#     Worker 0: Train Loss: 2.5864, Train Accuracy: 33.84%
#     Worker 1: Train Loss: 2.5739, Train Accuracy: 33.63%
#     Worker 2: Train Loss: 2.5898, Train Accuracy: 34.03%
#     Worker 3: Train Loss: 2.5876, Train Accuracy: 33.32%
#     Worker 4: Train Loss: 2.5475, Train Accuracy: 34.97%
#     Worker 5: Train Loss: 2.5577, Train Accuracy: 34.97%
#     Worker 6: Train Loss: 2.5952, Train Accuracy: 33.39%
#     Worker 7: Train Loss: 2.5535, Train Accuracy: 34.60%
# Epoch 31/150: Test Loss: 2.4054, Test Accuracy: 38.84%
#     Worker 0: Train Loss: 2.5554, Train Accuracy: 34.37%
#     Worker 1: Train Loss: 2.5439, Train Accuracy: 34.37%
#     Worker 2: Train Loss: 2.5462, Train Accuracy: 34.88%
#     Worker 3: Train Loss: 2.5733, Train Accuracy: 33.49%
#     Worker 4: Train Loss: 2.5131, Train Accuracy: 35.28%
#     Worker 5: Train Loss: 2.5183, Train Accuracy: 35.45%
#     Worker 6: Train Loss: 2.5752, Train Accuracy: 32.94%
#     Worker 7: Train Loss: 2.5551, Train Accuracy: 33.75%
# Epoch 32/150: Test Loss: 2.3661, Test Accuracy: 39.63%
#     Worker 0: Train Loss: 2.5023, Train Accuracy: 34.88%
#     Worker 1: Train Loss: 2.5201, Train Accuracy: 34.19%
#     Worker 2: Train Loss: 2.5243, Train Accuracy: 34.77%
#     Worker 3: Train Loss: 2.5822, Train Accuracy: 33.97%
#     Worker 4: Train Loss: 2.5083, Train Accuracy: 35.45%
#     Worker 5: Train Loss: 2.4938, Train Accuracy: 36.01%
#     Worker 6: Train Loss: 2.5003, Train Accuracy: 34.59%
#     Worker 7: Train Loss: 2.5075, Train Accuracy: 35.39%
# Epoch 33/150: Test Loss: 2.3375, Test Accuracy: 40.23%
#     Worker 0: Train Loss: 2.5068, Train Accuracy: 35.48%
#     Worker 1: Train Loss: 2.4697, Train Accuracy: 35.58%
#     Worker 2: Train Loss: 2.5011, Train Accuracy: 35.76%
#     Worker 3: Train Loss: 2.4793, Train Accuracy: 35.24%
#     Worker 4: Train Loss: 2.4567, Train Accuracy: 36.49%
#     Worker 5: Train Loss: 2.4669, Train Accuracy: 35.91%
#     Worker 6: Train Loss: 2.5099, Train Accuracy: 34.72%
#     Worker 7: Train Loss: 2.4823, Train Accuracy: 36.32%
# Epoch 34/150: Test Loss: 2.3275, Test Accuracy: 40.49%
#     Worker 0: Train Loss: 2.4799, Train Accuracy: 35.92%
#     Worker 1: Train Loss: 2.4197, Train Accuracy: 36.79%
#     Worker 2: Train Loss: 2.4451, Train Accuracy: 36.79%
#     Worker 3: Train Loss: 2.4866, Train Accuracy: 35.42%
#     Worker 4: Train Loss: 2.4338, Train Accuracy: 36.47%
#     Worker 5: Train Loss: 2.4272, Train Accuracy: 37.36%
#     Worker 6: Train Loss: 2.4822, Train Accuracy: 34.79%
#     Worker 7: Train Loss: 2.5080, Train Accuracy: 35.24%
# Epoch 35/150: Test Loss: 2.3168, Test Accuracy: 40.63%
#     Worker 0: Train Loss: 2.4692, Train Accuracy: 35.95%
#     Worker 1: Train Loss: 2.4231, Train Accuracy: 36.36%
#     Worker 2: Train Loss: 2.4528, Train Accuracy: 36.07%
#     Worker 3: Train Loss: 2.4540, Train Accuracy: 35.53%
#     Worker 4: Train Loss: 2.3940, Train Accuracy: 37.47%
#     Worker 5: Train Loss: 2.4365, Train Accuracy: 37.17%
#     Worker 6: Train Loss: 2.4557, Train Accuracy: 36.16%
#     Worker 7: Train Loss: 2.4141, Train Accuracy: 37.44%
# Epoch 36/150: Test Loss: 2.2916, Test Accuracy: 41.43%
#     Worker 0: Train Loss: 2.4287, Train Accuracy: 37.25%
#     Worker 1: Train Loss: 2.3800, Train Accuracy: 37.14%
#     Worker 2: Train Loss: 2.4233, Train Accuracy: 36.52%
#     Worker 3: Train Loss: 2.4266, Train Accuracy: 36.54%
#     Worker 4: Train Loss: 2.4123, Train Accuracy: 37.15%
#     Worker 5: Train Loss: 2.4001, Train Accuracy: 37.02%
#     Worker 6: Train Loss: 2.4403, Train Accuracy: 36.92%
#     Worker 7: Train Loss: 2.4328, Train Accuracy: 36.35%
# Epoch 37/150: Test Loss: 2.2598, Test Accuracy: 41.57%
#     Worker 0: Train Loss: 2.4071, Train Accuracy: 37.33%
#     Worker 1: Train Loss: 2.3791, Train Accuracy: 37.76%
#     Worker 2: Train Loss: 2.4013, Train Accuracy: 37.47%
#     Worker 3: Train Loss: 2.4297, Train Accuracy: 36.35%
#     Worker 4: Train Loss: 2.3401, Train Accuracy: 38.23%
#     Worker 5: Train Loss: 2.3593, Train Accuracy: 38.70%
#     Worker 6: Train Loss: 2.4063, Train Accuracy: 36.89%
#     Worker 7: Train Loss: 2.3858, Train Accuracy: 37.44%
# Epoch 38/150: Test Loss: 2.2688, Test Accuracy: 41.74%
#     Worker 0: Train Loss: 2.3933, Train Accuracy: 37.45%
#     Worker 1: Train Loss: 2.3366, Train Accuracy: 38.34%
#     Worker 2: Train Loss: 2.3559, Train Accuracy: 38.52%
#     Worker 3: Train Loss: 2.3912, Train Accuracy: 37.54%
#     Worker 4: Train Loss: 2.3487, Train Accuracy: 37.99%
#     Worker 5: Train Loss: 2.3378, Train Accuracy: 39.29%
#     Worker 6: Train Loss: 2.3683, Train Accuracy: 38.38%
#     Worker 7: Train Loss: 2.3860, Train Accuracy: 37.48%
# Epoch 39/150: Test Loss: 2.2428, Test Accuracy: 42.21%
#     Worker 0: Train Loss: 2.3471, Train Accuracy: 38.14%
#     Worker 1: Train Loss: 2.3358, Train Accuracy: 38.05%
#     Worker 2: Train Loss: 2.3365, Train Accuracy: 39.71%
#     Worker 3: Train Loss: 2.3422, Train Accuracy: 38.21%
#     Worker 4: Train Loss: 2.3150, Train Accuracy: 39.51%
#     Worker 5: Train Loss: 2.2951, Train Accuracy: 39.77%
#     Worker 6: Train Loss: 2.3448, Train Accuracy: 37.91%
#     Worker 7: Train Loss: 2.3173, Train Accuracy: 39.71%
# Epoch 40/150: Test Loss: 2.2244, Test Accuracy: 42.24%
#     Worker 0: Train Loss: 2.3277, Train Accuracy: 38.94%
#     Worker 1: Train Loss: 2.3014, Train Accuracy: 39.92%
#     Worker 2: Train Loss: 2.3328, Train Accuracy: 39.13%
#     Worker 3: Train Loss: 2.2873, Train Accuracy: 39.69%
#     Worker 4: Train Loss: 2.2951, Train Accuracy: 39.36%
#     Worker 5: Train Loss: 2.2918, Train Accuracy: 40.29%
#     Worker 6: Train Loss: 2.3281, Train Accuracy: 39.47%
#     Worker 7: Train Loss: 2.3250, Train Accuracy: 38.84%
# Epoch 41/150: Test Loss: 2.2120, Test Accuracy: 42.92%
#     Worker 0: Train Loss: 2.3055, Train Accuracy: 39.56%
#     Worker 1: Train Loss: 2.2756, Train Accuracy: 39.47%
#     Worker 2: Train Loss: 2.2949, Train Accuracy: 39.13%
#     Worker 3: Train Loss: 2.3331, Train Accuracy: 38.90%
#     Worker 4: Train Loss: 2.2653, Train Accuracy: 39.80%
#     Worker 5: Train Loss: 2.2874, Train Accuracy: 40.23%
#     Worker 6: Train Loss: 2.3155, Train Accuracy: 39.39%
#     Worker 7: Train Loss: 2.2936, Train Accuracy: 39.45%
# Epoch 42/150: Test Loss: 2.1903, Test Accuracy: 42.98%
#     Worker 0: Train Loss: 2.2781, Train Accuracy: 39.36%
#     Worker 1: Train Loss: 2.2454, Train Accuracy: 39.85%
#     Worker 2: Train Loss: 2.2829, Train Accuracy: 40.38%
#     Worker 3: Train Loss: 2.2842, Train Accuracy: 39.03%
#     Worker 4: Train Loss: 2.2333, Train Accuracy: 40.75%
#     Worker 5: Train Loss: 2.2722, Train Accuracy: 40.72%
#     Worker 6: Train Loss: 2.2942, Train Accuracy: 39.71%
#     Worker 7: Train Loss: 2.2794, Train Accuracy: 40.42%
# Epoch 43/150: Test Loss: 2.1927, Test Accuracy: 42.93%
#     Worker 0: Train Loss: 2.2455, Train Accuracy: 40.62%
#     Worker 1: Train Loss: 2.2412, Train Accuracy: 39.94%
#     Worker 2: Train Loss: 2.2300, Train Accuracy: 41.56%
#     Worker 3: Train Loss: 2.2444, Train Accuracy: 40.30%
#     Worker 4: Train Loss: 2.2080, Train Accuracy: 41.27%
#     Worker 5: Train Loss: 2.2053, Train Accuracy: 41.79%
#     Worker 6: Train Loss: 2.2460, Train Accuracy: 40.06%
#     Worker 7: Train Loss: 2.2167, Train Accuracy: 41.35%
# Epoch 44/150: Test Loss: 2.1779, Test Accuracy: 43.03%
#     Worker 0: Train Loss: 2.2464, Train Accuracy: 40.43%
#     Worker 1: Train Loss: 2.1747, Train Accuracy: 41.96%
#     Worker 2: Train Loss: 2.2228, Train Accuracy: 41.13%
#     Worker 3: Train Loss: 2.2648, Train Accuracy: 40.72%
#     Worker 4: Train Loss: 2.2239, Train Accuracy: 40.94%
#     Worker 5: Train Loss: 2.1934, Train Accuracy: 42.07%
#     Worker 6: Train Loss: 2.2627, Train Accuracy: 40.91%
#     Worker 7: Train Loss: 2.2616, Train Accuracy: 40.37%
# Epoch 45/150: Test Loss: 2.1545, Test Accuracy: 44.05%
#     Worker 0: Train Loss: 2.2091, Train Accuracy: 41.93%
#     Worker 1: Train Loss: 2.1822, Train Accuracy: 41.69%
#     Worker 2: Train Loss: 2.1940, Train Accuracy: 42.11%
#     Worker 3: Train Loss: 2.2497, Train Accuracy: 41.00%
#     Worker 4: Train Loss: 2.2023, Train Accuracy: 41.69%
#     Worker 5: Train Loss: 2.2019, Train Accuracy: 42.03%
#     Worker 6: Train Loss: 2.2070, Train Accuracy: 41.59%
#     Worker 7: Train Loss: 2.2214, Train Accuracy: 41.27%
# Epoch 46/150: Test Loss: 2.1498, Test Accuracy: 43.90%
#     Worker 0: Train Loss: 2.1911, Train Accuracy: 41.57%
#     Worker 1: Train Loss: 2.1727, Train Accuracy: 42.11%
#     Worker 2: Train Loss: 2.1778, Train Accuracy: 42.16%
#     Worker 3: Train Loss: 2.1888, Train Accuracy: 42.07%
#     Worker 4: Train Loss: 2.1515, Train Accuracy: 42.72%
#     Worker 5: Train Loss: 2.1712, Train Accuracy: 42.70%
#     Worker 6: Train Loss: 2.1932, Train Accuracy: 41.88%
#     Worker 7: Train Loss: 2.1889, Train Accuracy: 42.72%
# Epoch 47/150: Test Loss: 2.1285, Test Accuracy: 44.56%
#     Worker 0: Train Loss: 2.1786, Train Accuracy: 42.18%
#     Worker 1: Train Loss: 2.1243, Train Accuracy: 43.50%
#     Worker 2: Train Loss: 2.1796, Train Accuracy: 42.55%
#     Worker 3: Train Loss: 2.1936, Train Accuracy: 41.42%
#     Worker 4: Train Loss: 2.1332, Train Accuracy: 43.33%
#     Worker 5: Train Loss: 2.1319, Train Accuracy: 43.23%
#     Worker 6: Train Loss: 2.1710, Train Accuracy: 42.36%
#     Worker 7: Train Loss: 2.1607, Train Accuracy: 42.41%
# Epoch 48/150: Test Loss: 2.1209, Test Accuracy: 44.71%
#     Worker 0: Train Loss: 2.1597, Train Accuracy: 42.82%
#     Worker 1: Train Loss: 2.1205, Train Accuracy: 43.01%
#     Worker 2: Train Loss: 2.1648, Train Accuracy: 42.47%
#     Worker 3: Train Loss: 2.1486, Train Accuracy: 42.57%
#     Worker 4: Train Loss: 2.1206, Train Accuracy: 43.29%
#     Worker 5: Train Loss: 2.1437, Train Accuracy: 43.11%
#     Worker 6: Train Loss: 2.1799, Train Accuracy: 42.01%
#     Worker 7: Train Loss: 2.1524, Train Accuracy: 42.20%
# Epoch 49/150: Test Loss: 2.1096, Test Accuracy: 44.78%
#     Worker 0: Train Loss: 2.1203, Train Accuracy: 43.47%
#     Worker 1: Train Loss: 2.1247, Train Accuracy: 43.15%
#     Worker 2: Train Loss: 2.1227, Train Accuracy: 42.87%
#     Worker 3: Train Loss: 2.1586, Train Accuracy: 42.71%
#     Worker 4: Train Loss: 2.0927, Train Accuracy: 44.18%
#     Worker 5: Train Loss: 2.1149, Train Accuracy: 44.01%
#     Worker 6: Train Loss: 2.1480, Train Accuracy: 42.73%
#     Worker 7: Train Loss: 2.1313, Train Accuracy: 43.30%
# Epoch 50/150: Test Loss: 2.1093, Test Accuracy: 45.06%
#     Worker 0: Train Loss: 2.1275, Train Accuracy: 43.60%
#     Worker 1: Train Loss: 2.0757, Train Accuracy: 44.54%
#     Worker 2: Train Loss: 2.0966, Train Accuracy: 43.86%
#     Worker 3: Train Loss: 2.1195, Train Accuracy: 43.35%
#     Worker 4: Train Loss: 2.0867, Train Accuracy: 43.55%
#     Worker 5: Train Loss: 2.1081, Train Accuracy: 43.66%
#     Worker 6: Train Loss: 2.1289, Train Accuracy: 43.39%
#     Worker 7: Train Loss: 2.1034, Train Accuracy: 44.31%
# Epoch 51/150: Test Loss: 2.0972, Test Accuracy: 45.47%
#     Worker 0: Train Loss: 2.1256, Train Accuracy: 43.49%
#     Worker 1: Train Loss: 2.0915, Train Accuracy: 43.30%
#     Worker 2: Train Loss: 2.0845, Train Accuracy: 44.26%
#     Worker 3: Train Loss: 2.1255, Train Accuracy: 43.16%
#     Worker 4: Train Loss: 2.0715, Train Accuracy: 44.38%
#     Worker 5: Train Loss: 2.0931, Train Accuracy: 44.22%
#     Worker 6: Train Loss: 2.1043, Train Accuracy: 44.01%
#     Worker 7: Train Loss: 2.0986, Train Accuracy: 44.30%
# Epoch 52/150: Test Loss: 2.0936, Test Accuracy: 45.38%
#     Worker 0: Train Loss: 2.0886, Train Accuracy: 43.70%
#     Worker 1: Train Loss: 2.0727, Train Accuracy: 44.16%
#     Worker 2: Train Loss: 2.0528, Train Accuracy: 44.83%
#     Worker 3: Train Loss: 2.1014, Train Accuracy: 43.79%
#     Worker 4: Train Loss: 2.0618, Train Accuracy: 44.69%
#     Worker 5: Train Loss: 2.0671, Train Accuracy: 45.01%
#     Worker 6: Train Loss: 2.1145, Train Accuracy: 43.73%
#     Worker 7: Train Loss: 2.0780, Train Accuracy: 43.68%
# Epoch 53/150: Test Loss: 2.0804, Test Accuracy: 45.83%
#     Worker 0: Train Loss: 2.0588, Train Accuracy: 44.05%
#     Worker 1: Train Loss: 2.0096, Train Accuracy: 45.97%
#     Worker 2: Train Loss: 2.0480, Train Accuracy: 45.15%
#     Worker 3: Train Loss: 2.0620, Train Accuracy: 44.70%
#     Worker 4: Train Loss: 2.0234, Train Accuracy: 45.59%
#     Worker 5: Train Loss: 2.0270, Train Accuracy: 45.67%
#     Worker 6: Train Loss: 2.0648, Train Accuracy: 44.48%
#     Worker 7: Train Loss: 2.0409, Train Accuracy: 45.09%
# Epoch 54/150: Test Loss: 2.0907, Test Accuracy: 46.13%
#     Worker 0: Train Loss: 2.0631, Train Accuracy: 44.53%
#     Worker 1: Train Loss: 2.0160, Train Accuracy: 45.68%
#     Worker 2: Train Loss: 2.0153, Train Accuracy: 46.28%
#     Worker 3: Train Loss: 2.0345, Train Accuracy: 45.20%
#     Worker 4: Train Loss: 2.0142, Train Accuracy: 46.22%
#     Worker 5: Train Loss: 2.0380, Train Accuracy: 45.20%
#     Worker 6: Train Loss: 2.0533, Train Accuracy: 45.13%
#     Worker 7: Train Loss: 2.0584, Train Accuracy: 44.54%
# Epoch 55/150: Test Loss: 2.0549, Test Accuracy: 46.64%
#     Worker 0: Train Loss: 2.0419, Train Accuracy: 44.65%
#     Worker 1: Train Loss: 1.9801, Train Accuracy: 46.45%
#     Worker 2: Train Loss: 2.0267, Train Accuracy: 45.64%
#     Worker 3: Train Loss: 2.0199, Train Accuracy: 45.09%
#     Worker 4: Train Loss: 2.0139, Train Accuracy: 45.70%
#     Worker 5: Train Loss: 2.0087, Train Accuracy: 45.74%
#     Worker 6: Train Loss: 2.0210, Train Accuracy: 45.53%
#     Worker 7: Train Loss: 2.0161, Train Accuracy: 45.29%
# Epoch 56/150: Test Loss: 2.0522, Test Accuracy: 46.52%
#     Worker 0: Train Loss: 2.0085, Train Accuracy: 46.58%
#     Worker 1: Train Loss: 1.9699, Train Accuracy: 46.20%
#     Worker 2: Train Loss: 1.9756, Train Accuracy: 46.80%
#     Worker 3: Train Loss: 2.0117, Train Accuracy: 45.79%
#     Worker 4: Train Loss: 1.9816, Train Accuracy: 47.13%
#     Worker 5: Train Loss: 2.0042, Train Accuracy: 46.39%
#     Worker 6: Train Loss: 2.0198, Train Accuracy: 46.01%
#     Worker 7: Train Loss: 1.9930, Train Accuracy: 46.26%
# Epoch 57/150: Test Loss: 2.0418, Test Accuracy: 46.47%
#     Worker 0: Train Loss: 1.9898, Train Accuracy: 45.41%
#     Worker 1: Train Loss: 1.9657, Train Accuracy: 47.07%
#     Worker 2: Train Loss: 2.0072, Train Accuracy: 46.66%
#     Worker 3: Train Loss: 1.9826, Train Accuracy: 45.65%
#     Worker 4: Train Loss: 1.9569, Train Accuracy: 46.84%
#     Worker 5: Train Loss: 2.0080, Train Accuracy: 46.16%
#     Worker 6: Train Loss: 1.9887, Train Accuracy: 46.57%
#     Worker 7: Train Loss: 1.9770, Train Accuracy: 45.91%
# Epoch 58/150: Test Loss: 2.0437, Test Accuracy: 46.78%
#     Worker 0: Train Loss: 1.9712, Train Accuracy: 46.78%
#     Worker 1: Train Loss: 1.9254, Train Accuracy: 47.11%
#     Worker 2: Train Loss: 1.9674, Train Accuracy: 47.43%
#     Worker 3: Train Loss: 1.9894, Train Accuracy: 45.97%
#     Worker 4: Train Loss: 1.9420, Train Accuracy: 47.29%
#     Worker 5: Train Loss: 1.9592, Train Accuracy: 47.59%
#     Worker 6: Train Loss: 1.9892, Train Accuracy: 46.68%
#     Worker 7: Train Loss: 1.9738, Train Accuracy: 46.61%
# Epoch 59/150: Test Loss: 2.0310, Test Accuracy: 46.95%
#     Worker 0: Train Loss: 1.9593, Train Accuracy: 46.08%
#     Worker 1: Train Loss: 1.9299, Train Accuracy: 47.26%
#     Worker 2: Train Loss: 1.9376, Train Accuracy: 47.75%
#     Worker 3: Train Loss: 1.9734, Train Accuracy: 46.21%
#     Worker 4: Train Loss: 1.9220, Train Accuracy: 48.43%
#     Worker 5: Train Loss: 1.9325, Train Accuracy: 47.84%
#     Worker 6: Train Loss: 1.9596, Train Accuracy: 46.47%
#     Worker 7: Train Loss: 1.9448, Train Accuracy: 47.05%
# Epoch 60/150: Test Loss: 2.0349, Test Accuracy: 46.77%
#     Worker 0: Train Loss: 1.9359, Train Accuracy: 47.77%
#     Worker 1: Train Loss: 1.9178, Train Accuracy: 47.16%
#     Worker 2: Train Loss: 1.9089, Train Accuracy: 48.42%
#     Worker 3: Train Loss: 1.9600, Train Accuracy: 46.88%
#     Worker 4: Train Loss: 1.9167, Train Accuracy: 47.77%
#     Worker 5: Train Loss: 1.9617, Train Accuracy: 46.61%
#     Worker 6: Train Loss: 1.9830, Train Accuracy: 46.46%
#     Worker 7: Train Loss: 1.9420, Train Accuracy: 47.21%
# Epoch 61/150: Test Loss: 2.0164, Test Accuracy: 47.19%
#     Worker 0: Train Loss: 1.9590, Train Accuracy: 47.39%
#     Worker 1: Train Loss: 1.8974, Train Accuracy: 48.18%
#     Worker 2: Train Loss: 1.9012, Train Accuracy: 48.57%
#     Worker 3: Train Loss: 1.9400, Train Accuracy: 47.60%
#     Worker 4: Train Loss: 1.9133, Train Accuracy: 47.94%
#     Worker 5: Train Loss: 1.9248, Train Accuracy: 47.91%
#     Worker 6: Train Loss: 1.9577, Train Accuracy: 46.93%
#     Worker 7: Train Loss: 1.9158, Train Accuracy: 47.53%
# Epoch 62/150: Test Loss: 2.0090, Test Accuracy: 47.15%
#     Worker 0: Train Loss: 1.9014, Train Accuracy: 47.98%
#     Worker 1: Train Loss: 1.8871, Train Accuracy: 48.23%
#     Worker 2: Train Loss: 1.9026, Train Accuracy: 47.97%
#     Worker 3: Train Loss: 1.9309, Train Accuracy: 48.26%
#     Worker 4: Train Loss: 1.9049, Train Accuracy: 48.45%
#     Worker 5: Train Loss: 1.8968, Train Accuracy: 48.42%
#     Worker 6: Train Loss: 1.8993, Train Accuracy: 48.30%
#     Worker 7: Train Loss: 1.9115, Train Accuracy: 47.78%
# Epoch 63/150: Test Loss: 1.9993, Test Accuracy: 47.56%
#     Worker 0: Train Loss: 1.8951, Train Accuracy: 48.66%
#     Worker 1: Train Loss: 1.8910, Train Accuracy: 48.16%
#     Worker 2: Train Loss: 1.8726, Train Accuracy: 49.30%
#     Worker 3: Train Loss: 1.8786, Train Accuracy: 48.81%
#     Worker 4: Train Loss: 1.8457, Train Accuracy: 49.66%
#     Worker 5: Train Loss: 1.8649, Train Accuracy: 49.88%
#     Worker 6: Train Loss: 1.8821, Train Accuracy: 49.04%
#     Worker 7: Train Loss: 1.8779, Train Accuracy: 48.34%
# Epoch 64/150: Test Loss: 2.0049, Test Accuracy: 47.72%
#     Worker 0: Train Loss: 1.8931, Train Accuracy: 48.60%
#     Worker 1: Train Loss: 1.8427, Train Accuracy: 49.36%
#     Worker 2: Train Loss: 1.8603, Train Accuracy: 49.62%
#     Worker 3: Train Loss: 1.8797, Train Accuracy: 49.11%
#     Worker 4: Train Loss: 1.8456, Train Accuracy: 49.52%
#     Worker 5: Train Loss: 1.8976, Train Accuracy: 48.04%
#     Worker 6: Train Loss: 1.9160, Train Accuracy: 48.51%
#     Worker 7: Train Loss: 1.8954, Train Accuracy: 47.98%
# Epoch 65/150: Test Loss: 1.9896, Test Accuracy: 47.91%
#     Worker 0: Train Loss: 1.8652, Train Accuracy: 48.84%
#     Worker 1: Train Loss: 1.8474, Train Accuracy: 49.33%
#     Worker 2: Train Loss: 1.8754, Train Accuracy: 48.56%
#     Worker 3: Train Loss: 1.9067, Train Accuracy: 47.91%
#     Worker 4: Train Loss: 1.8271, Train Accuracy: 50.71%
#     Worker 5: Train Loss: 1.8486, Train Accuracy: 49.45%
#     Worker 6: Train Loss: 1.8716, Train Accuracy: 49.22%
#     Worker 7: Train Loss: 1.8671, Train Accuracy: 49.44%
# Epoch 66/150: Test Loss: 1.9890, Test Accuracy: 47.72%
#     Worker 0: Train Loss: 1.8396, Train Accuracy: 49.35%
#     Worker 1: Train Loss: 1.7981, Train Accuracy: 50.09%
#     Worker 2: Train Loss: 1.8079, Train Accuracy: 50.96%
#     Worker 3: Train Loss: 1.8448, Train Accuracy: 49.25%
#     Worker 4: Train Loss: 1.8121, Train Accuracy: 50.66%
#     Worker 5: Train Loss: 1.8339, Train Accuracy: 49.56%
#     Worker 6: Train Loss: 1.8457, Train Accuracy: 49.68%
#     Worker 7: Train Loss: 1.8287, Train Accuracy: 49.59%
# Epoch 67/150: Test Loss: 1.9801, Test Accuracy: 48.29%
#     Worker 0: Train Loss: 1.8134, Train Accuracy: 49.62%
#     Worker 1: Train Loss: 1.8189, Train Accuracy: 50.53%
#     Worker 2: Train Loss: 1.8123, Train Accuracy: 50.81%
#     Worker 3: Train Loss: 1.8244, Train Accuracy: 49.84%
#     Worker 4: Train Loss: 1.7999, Train Accuracy: 50.27%
#     Worker 5: Train Loss: 1.8355, Train Accuracy: 50.31%
#     Worker 6: Train Loss: 1.8441, Train Accuracy: 49.13%
#     Worker 7: Train Loss: 1.8220, Train Accuracy: 50.16%
# Epoch 68/150: Test Loss: 1.9799, Test Accuracy: 48.33%
#     Worker 0: Train Loss: 1.8275, Train Accuracy: 49.27%
#     Worker 1: Train Loss: 1.7950, Train Accuracy: 50.64%
#     Worker 2: Train Loss: 1.8256, Train Accuracy: 50.27%
#     Worker 3: Train Loss: 1.8148, Train Accuracy: 49.80%
#     Worker 4: Train Loss: 1.7928, Train Accuracy: 51.29%
#     Worker 5: Train Loss: 1.7982, Train Accuracy: 50.91%
#     Worker 6: Train Loss: 1.8461, Train Accuracy: 49.28%
#     Worker 7: Train Loss: 1.8128, Train Accuracy: 50.58%
# Epoch 69/150: Test Loss: 1.9756, Test Accuracy: 48.64%
#     Worker 0: Train Loss: 1.7929, Train Accuracy: 50.85%
#     Worker 1: Train Loss: 1.7366, Train Accuracy: 52.10%
#     Worker 2: Train Loss: 1.7900, Train Accuracy: 50.91%
#     Worker 3: Train Loss: 1.8169, Train Accuracy: 50.31%
#     Worker 4: Train Loss: 1.7918, Train Accuracy: 50.56%
#     Worker 5: Train Loss: 1.8050, Train Accuracy: 50.97%
#     Worker 6: Train Loss: 1.8272, Train Accuracy: 49.72%
#     Worker 7: Train Loss: 1.7873, Train Accuracy: 51.23%
# Epoch 70/150: Test Loss: 1.9801, Test Accuracy: 48.47%
#     Worker 0: Train Loss: 1.8049, Train Accuracy: 50.32%
#     Worker 1: Train Loss: 1.7651, Train Accuracy: 51.86%
#     Worker 2: Train Loss: 1.7485, Train Accuracy: 51.68%
#     Worker 3: Train Loss: 1.8033, Train Accuracy: 50.94%
#     Worker 4: Train Loss: 1.7700, Train Accuracy: 51.16%
#     Worker 5: Train Loss: 1.7780, Train Accuracy: 51.31%
#     Worker 6: Train Loss: 1.7853, Train Accuracy: 50.65%
#     Worker 7: Train Loss: 1.7865, Train Accuracy: 50.82%
# Epoch 71/150: Test Loss: 1.9644, Test Accuracy: 49.01%
#     Worker 0: Train Loss: 1.7809, Train Accuracy: 50.69%
#     Worker 1: Train Loss: 1.7635, Train Accuracy: 51.73%
#     Worker 2: Train Loss: 1.7636, Train Accuracy: 51.74%
#     Worker 3: Train Loss: 1.8024, Train Accuracy: 50.75%
#     Worker 4: Train Loss: 1.7644, Train Accuracy: 51.44%
#     Worker 5: Train Loss: 1.7799, Train Accuracy: 51.51%
#     Worker 6: Train Loss: 1.8104, Train Accuracy: 50.78%
#     Worker 7: Train Loss: 1.7635, Train Accuracy: 51.40%
# Epoch 72/150: Test Loss: 1.9670, Test Accuracy: 48.56%
#     Worker 0: Train Loss: 1.7353, Train Accuracy: 51.68%
#     Worker 1: Train Loss: 1.7424, Train Accuracy: 52.18%
#     Worker 2: Train Loss: 1.7635, Train Accuracy: 51.80%
#     Worker 3: Train Loss: 1.7664, Train Accuracy: 51.23%
#     Worker 4: Train Loss: 1.7284, Train Accuracy: 52.32%
#     Worker 5: Train Loss: 1.7420, Train Accuracy: 52.65%
#     Worker 6: Train Loss: 1.7688, Train Accuracy: 51.45%
#     Worker 7: Train Loss: 1.7530, Train Accuracy: 51.26%
# Epoch 73/150: Test Loss: 1.9587, Test Accuracy: 48.82%
#     Worker 0: Train Loss: 1.7519, Train Accuracy: 51.40%
#     Worker 1: Train Loss: 1.7061, Train Accuracy: 53.04%
#     Worker 2: Train Loss: 1.7421, Train Accuracy: 52.08%
#     Worker 3: Train Loss: 1.7649, Train Accuracy: 51.16%
#     Worker 4: Train Loss: 1.7068, Train Accuracy: 53.01%
#     Worker 5: Train Loss: 1.7387, Train Accuracy: 52.11%
#     Worker 6: Train Loss: 1.7399, Train Accuracy: 51.85%
#     Worker 7: Train Loss: 1.7534, Train Accuracy: 51.85%
# Epoch 74/150: Test Loss: 1.9643, Test Accuracy: 48.90%
#     Worker 0: Train Loss: 1.7640, Train Accuracy: 51.35%
#     Worker 1: Train Loss: 1.7048, Train Accuracy: 52.29%
#     Worker 2: Train Loss: 1.7212, Train Accuracy: 52.06%
#     Worker 3: Train Loss: 1.7366, Train Accuracy: 51.98%
#     Worker 4: Train Loss: 1.7109, Train Accuracy: 53.12%
#     Worker 5: Train Loss: 1.7341, Train Accuracy: 52.26%
#     Worker 6: Train Loss: 1.7645, Train Accuracy: 51.60%
#     Worker 7: Train Loss: 1.6981, Train Accuracy: 53.33%
# Epoch 75/150: Test Loss: 1.9593, Test Accuracy: 48.94%
#     Worker 0: Train Loss: 1.7665, Train Accuracy: 51.69%
#     Worker 1: Train Loss: 1.7095, Train Accuracy: 52.79%
#     Worker 2: Train Loss: 1.7122, Train Accuracy: 53.07%
#     Worker 3: Train Loss: 1.7317, Train Accuracy: 52.01%
#     Worker 4: Train Loss: 1.7226, Train Accuracy: 52.41%
#     Worker 5: Train Loss: 1.7116, Train Accuracy: 52.71%
#     Worker 6: Train Loss: 1.7442, Train Accuracy: 51.68%
#     Worker 7: Train Loss: 1.6930, Train Accuracy: 52.86%
# Epoch 76/150: Test Loss: 1.9592, Test Accuracy: 49.02%
#     Worker 0: Train Loss: 1.6810, Train Accuracy: 52.95%
#     Worker 1: Train Loss: 1.6779, Train Accuracy: 53.08%
#     Worker 2: Train Loss: 1.6850, Train Accuracy: 53.40%
#     Worker 3: Train Loss: 1.6976, Train Accuracy: 52.79%
#     Worker 4: Train Loss: 1.6677, Train Accuracy: 53.61%
#     Worker 5: Train Loss: 1.6865, Train Accuracy: 53.84%
#     Worker 6: Train Loss: 1.7198, Train Accuracy: 53.09%
#     Worker 7: Train Loss: 1.6708, Train Accuracy: 53.84%
# Epoch 77/150: Test Loss: 1.9558, Test Accuracy: 49.19%
#     Worker 0: Train Loss: 1.7255, Train Accuracy: 52.80%
#     Worker 1: Train Loss: 1.6777, Train Accuracy: 53.62%
#     Worker 2: Train Loss: 1.6752, Train Accuracy: 54.19%
#     Worker 3: Train Loss: 1.7022, Train Accuracy: 53.04%
#     Worker 4: Train Loss: 1.6637, Train Accuracy: 53.50%
#     Worker 5: Train Loss: 1.6940, Train Accuracy: 53.06%
#     Worker 6: Train Loss: 1.7131, Train Accuracy: 52.94%
#     Worker 7: Train Loss: 1.6626, Train Accuracy: 54.03%
# Epoch 78/150: Test Loss: 1.9515, Test Accuracy: 48.92%
#     Worker 0: Train Loss: 1.6803, Train Accuracy: 53.17%
#     Worker 1: Train Loss: 1.6597, Train Accuracy: 53.86%
#     Worker 2: Train Loss: 1.6428, Train Accuracy: 54.41%
#     Worker 3: Train Loss: 1.6907, Train Accuracy: 52.94%
#     Worker 4: Train Loss: 1.6642, Train Accuracy: 53.66%
#     Worker 5: Train Loss: 1.6862, Train Accuracy: 53.78%
#     Worker 6: Train Loss: 1.6840, Train Accuracy: 53.23%
#     Worker 7: Train Loss: 1.6889, Train Accuracy: 53.16%
# Epoch 79/150: Test Loss: 1.9506, Test Accuracy: 49.37%
#     Worker 0: Train Loss: 1.6876, Train Accuracy: 52.70%
#     Worker 1: Train Loss: 1.6261, Train Accuracy: 54.87%
#     Worker 2: Train Loss: 1.6324, Train Accuracy: 53.95%
#     Worker 3: Train Loss: 1.6797, Train Accuracy: 54.10%
#     Worker 4: Train Loss: 1.6415, Train Accuracy: 54.70%
#     Worker 5: Train Loss: 1.6621, Train Accuracy: 53.73%
#     Worker 6: Train Loss: 1.6454, Train Accuracy: 54.71%
#     Worker 7: Train Loss: 1.6395, Train Accuracy: 54.86%
# Epoch 80/150: Test Loss: 1.9568, Test Accuracy: 49.10%
#     Worker 0: Train Loss: 1.6368, Train Accuracy: 54.65%
#     Worker 1: Train Loss: 1.6362, Train Accuracy: 54.22%
#     Worker 2: Train Loss: 1.6067, Train Accuracy: 55.76%
#     Worker 3: Train Loss: 1.6529, Train Accuracy: 54.26%
#     Worker 4: Train Loss: 1.6399, Train Accuracy: 54.30%
#     Worker 5: Train Loss: 1.6013, Train Accuracy: 55.79%
#     Worker 6: Train Loss: 1.6853, Train Accuracy: 53.37%
#     Worker 7: Train Loss: 1.6445, Train Accuracy: 54.06%
# Epoch 81/150: Test Loss: 1.9430, Test Accuracy: 49.52%
#     Worker 0: Train Loss: 1.6322, Train Accuracy: 54.69%
#     Worker 1: Train Loss: 1.6164, Train Accuracy: 54.92%
#     Worker 2: Train Loss: 1.6305, Train Accuracy: 54.16%
#     Worker 3: Train Loss: 1.6771, Train Accuracy: 53.12%
#     Worker 4: Train Loss: 1.6439, Train Accuracy: 54.72%
#     Worker 5: Train Loss: 1.6684, Train Accuracy: 54.22%
#     Worker 6: Train Loss: 1.6379, Train Accuracy: 54.37%
#     Worker 7: Train Loss: 1.6263, Train Accuracy: 55.08%
# Epoch 82/150: Test Loss: 1.9470, Test Accuracy: 49.63%
#     Worker 0: Train Loss: 1.6195, Train Accuracy: 54.92%
#     Worker 1: Train Loss: 1.6262, Train Accuracy: 54.21%
#     Worker 2: Train Loss: 1.6209, Train Accuracy: 55.29%
#     Worker 3: Train Loss: 1.6264, Train Accuracy: 54.39%
#     Worker 4: Train Loss: 1.5937, Train Accuracy: 55.89%
#     Worker 5: Train Loss: 1.6247, Train Accuracy: 55.88%
#     Worker 6: Train Loss: 1.6591, Train Accuracy: 53.92%
#     Worker 7: Train Loss: 1.6073, Train Accuracy: 55.38%
# Epoch 83/150: Test Loss: 1.9433, Test Accuracy: 49.69%
#     Worker 0: Train Loss: 1.6270, Train Accuracy: 55.06%
#     Worker 1: Train Loss: 1.6251, Train Accuracy: 55.24%
#     Worker 2: Train Loss: 1.5994, Train Accuracy: 55.58%
#     Worker 3: Train Loss: 1.6194, Train Accuracy: 55.18%
#     Worker 4: Train Loss: 1.5909, Train Accuracy: 56.11%
#     Worker 5: Train Loss: 1.6321, Train Accuracy: 55.04%
#     Worker 6: Train Loss: 1.6096, Train Accuracy: 55.26%
#     Worker 7: Train Loss: 1.6101, Train Accuracy: 54.85%
# Epoch 84/150: Test Loss: 1.9447, Test Accuracy: 49.75%
#     Worker 0: Train Loss: 1.6110, Train Accuracy: 55.34%
#     Worker 1: Train Loss: 1.5855, Train Accuracy: 55.47%
#     Worker 2: Train Loss: 1.6013, Train Accuracy: 55.43%
#     Worker 3: Train Loss: 1.6170, Train Accuracy: 54.71%
#     Worker 4: Train Loss: 1.5819, Train Accuracy: 55.91%
#     Worker 5: Train Loss: 1.5915, Train Accuracy: 55.36%
#     Worker 6: Train Loss: 1.6467, Train Accuracy: 54.54%
#     Worker 7: Train Loss: 1.5658, Train Accuracy: 55.80%
# Epoch 85/150: Test Loss: 1.9448, Test Accuracy: 49.80%
#     Worker 0: Train Loss: 1.5996, Train Accuracy: 55.17%
#     Worker 1: Train Loss: 1.5908, Train Accuracy: 55.36%
#     Worker 2: Train Loss: 1.5851, Train Accuracy: 56.12%
#     Worker 3: Train Loss: 1.6168, Train Accuracy: 55.17%
#     Worker 4: Train Loss: 1.5762, Train Accuracy: 55.52%
#     Worker 5: Train Loss: 1.6022, Train Accuracy: 56.10%
#     Worker 6: Train Loss: 1.6333, Train Accuracy: 54.68%
#     Worker 7: Train Loss: 1.5875, Train Accuracy: 56.05%
# Epoch 86/150: Test Loss: 1.9378, Test Accuracy: 49.72%
#     Worker 0: Train Loss: 1.5884, Train Accuracy: 55.59%
#     Worker 1: Train Loss: 1.5609, Train Accuracy: 56.00%
#     Worker 2: Train Loss: 1.5706, Train Accuracy: 56.39%
#     Worker 3: Train Loss: 1.6127, Train Accuracy: 54.75%
#     Worker 4: Train Loss: 1.5635, Train Accuracy: 56.67%
#     Worker 5: Train Loss: 1.5836, Train Accuracy: 56.29%
#     Worker 6: Train Loss: 1.5881, Train Accuracy: 55.52%
#     Worker 7: Train Loss: 1.5843, Train Accuracy: 55.80%
# Epoch 87/150: Test Loss: 1.9334, Test Accuracy: 49.74%
#     Worker 0: Train Loss: 1.5559, Train Accuracy: 55.94%
#     Worker 1: Train Loss: 1.5618, Train Accuracy: 55.97%
#     Worker 2: Train Loss: 1.5641, Train Accuracy: 56.24%
#     Worker 3: Train Loss: 1.5681, Train Accuracy: 56.39%
#     Worker 4: Train Loss: 1.5591, Train Accuracy: 56.41%
#     Worker 5: Train Loss: 1.5842, Train Accuracy: 56.00%
#     Worker 6: Train Loss: 1.5859, Train Accuracy: 55.97%
#     Worker 7: Train Loss: 1.5527, Train Accuracy: 56.60%
# Epoch 88/150: Test Loss: 1.9320, Test Accuracy: 50.02%
#     Worker 0: Train Loss: 1.5697, Train Accuracy: 56.39%
#     Worker 1: Train Loss: 1.5512, Train Accuracy: 57.04%
#     Worker 2: Train Loss: 1.5353, Train Accuracy: 57.54%
#     Worker 3: Train Loss: 1.5693, Train Accuracy: 55.63%
#     Worker 4: Train Loss: 1.5250, Train Accuracy: 57.18%
#     Worker 5: Train Loss: 1.5660, Train Accuracy: 56.56%
#     Worker 6: Train Loss: 1.5690, Train Accuracy: 56.57%
#     Worker 7: Train Loss: 1.5342, Train Accuracy: 57.07%
# Epoch 89/150: Test Loss: 1.9432, Test Accuracy: 49.80%
#     Worker 0: Train Loss: 1.5407, Train Accuracy: 56.71%
#     Worker 1: Train Loss: 1.5261, Train Accuracy: 56.60%
#     Worker 2: Train Loss: 1.5298, Train Accuracy: 57.62%
#     Worker 3: Train Loss: 1.5388, Train Accuracy: 57.02%
#     Worker 4: Train Loss: 1.5161, Train Accuracy: 57.46%
#     Worker 5: Train Loss: 1.5192, Train Accuracy: 57.44%
#     Worker 6: Train Loss: 1.5549, Train Accuracy: 56.00%
#     Worker 7: Train Loss: 1.5202, Train Accuracy: 57.29%
# Epoch 90/150: Test Loss: 1.9394, Test Accuracy: 49.93%
#     Worker 0: Train Loss: 1.5364, Train Accuracy: 56.56%
#     Worker 1: Train Loss: 1.5132, Train Accuracy: 57.42%
#     Worker 2: Train Loss: 1.5027, Train Accuracy: 57.89%
#     Worker 3: Train Loss: 1.5570, Train Accuracy: 56.14%
#     Worker 4: Train Loss: 1.4903, Train Accuracy: 58.08%
#     Worker 5: Train Loss: 1.5537, Train Accuracy: 56.98%
#     Worker 6: Train Loss: 1.5416, Train Accuracy: 57.09%
#     Worker 7: Train Loss: 1.5150, Train Accuracy: 57.50%
# Epoch 91/150: Test Loss: 1.9326, Test Accuracy: 50.10%
#     Worker 0: Train Loss: 1.5223, Train Accuracy: 56.73%
#     Worker 1: Train Loss: 1.4866, Train Accuracy: 58.23%
#     Worker 2: Train Loss: 1.5248, Train Accuracy: 58.10%
#     Worker 3: Train Loss: 1.5385, Train Accuracy: 56.29%
#     Worker 4: Train Loss: 1.5004, Train Accuracy: 57.54%
#     Worker 5: Train Loss: 1.5081, Train Accuracy: 57.81%
#     Worker 6: Train Loss: 1.5429, Train Accuracy: 56.83%
#     Worker 7: Train Loss: 1.5017, Train Accuracy: 57.96%
# Epoch 92/150: Test Loss: 1.9355, Test Accuracy: 49.92%
#     Worker 0: Train Loss: 1.5133, Train Accuracy: 57.60%
#     Worker 1: Train Loss: 1.4809, Train Accuracy: 58.14%
#     Worker 2: Train Loss: 1.4918, Train Accuracy: 57.78%
#     Worker 3: Train Loss: 1.5044, Train Accuracy: 58.12%
#     Worker 4: Train Loss: 1.4796, Train Accuracy: 58.26%
#     Worker 5: Train Loss: 1.5062, Train Accuracy: 58.03%
#     Worker 6: Train Loss: 1.5294, Train Accuracy: 57.38%
#     Worker 7: Train Loss: 1.4940, Train Accuracy: 57.97%
# Epoch 93/150: Test Loss: 1.9371, Test Accuracy: 49.95%
#     Worker 0: Train Loss: 1.4942, Train Accuracy: 57.92%
#     Worker 1: Train Loss: 1.5012, Train Accuracy: 58.07%
#     Worker 2: Train Loss: 1.4757, Train Accuracy: 58.52%
#     Worker 3: Train Loss: 1.4979, Train Accuracy: 57.74%
#     Worker 4: Train Loss: 1.4926, Train Accuracy: 58.04%
#     Worker 5: Train Loss: 1.5201, Train Accuracy: 57.88%
#     Worker 6: Train Loss: 1.4960, Train Accuracy: 58.05%
#     Worker 7: Train Loss: 1.4770, Train Accuracy: 58.45%
# Epoch 94/150: Test Loss: 1.9408, Test Accuracy: 50.32%
#     Worker 0: Train Loss: 1.4841, Train Accuracy: 58.16%
#     Worker 1: Train Loss: 1.4856, Train Accuracy: 58.14%
# ...
#     Worker 6: Train Loss: 1.2976, Train Accuracy: 63.39%
#     Worker 7: Train Loss: 1.2552, Train Accuracy: 64.50%
# Epoch 120/150: Test Loss: 1.9617, Test Accuracy: 50.97%
#     Worker 0: Train Loss: 1.2678, Train Accuracy: 64.17%
#     Worker 1: Train Loss: 1.2505, Train Accuracy: 64.00%
#     Worker 2: Train Loss: 1.2458, Train Accuracy: 64.20%
#     Worker 3: Train Loss: 1.2625, Train Accuracy: 64.19%
#     Worker 4: Train Loss: 1.2659, Train Accuracy: 63.70%
#     Worker 5: Train Loss: 1.2491, Train Accuracy: 64.31%
#     Worker 6: Train Loss: 1.2692, Train Accuracy: 63.86%
#     Worker 7: Train Loss: 1.2155, Train Accuracy: 65.51%
# Epoch 121/150: Test Loss: 1.9560, Test Accuracy: 51.06%
#     Worker 0: Train Loss: 1.2384, Train Accuracy: 64.95%
#     Worker 1: Train Loss: 1.2310, Train Accuracy: 64.97%
#     Worker 2: Train Loss: 1.2272, Train Accuracy: 65.35%
#     Worker 3: Train Loss: 1.2711, Train Accuracy: 63.98%
#     Worker 4: Train Loss: 1.2206, Train Accuracy: 64.97%
#     Worker 5: Train Loss: 1.2617, Train Accuracy: 64.31%
#     Worker 6: Train Loss: 1.2771, Train Accuracy: 64.11%
#     Worker 7: Train Loss: 1.2439, Train Accuracy: 64.35%
# Epoch 122/150: Test Loss: 1.9642, Test Accuracy: 50.72%
#     Worker 0: Train Loss: 1.2566, Train Accuracy: 64.63%
#     Worker 1: Train Loss: 1.2173, Train Accuracy: 64.63%
#     Worker 2: Train Loss: 1.2387, Train Accuracy: 64.70%
#     Worker 3: Train Loss: 1.2725, Train Accuracy: 63.66%
#     Worker 4: Train Loss: 1.2345, Train Accuracy: 64.92%
#     Worker 5: Train Loss: 1.2499, Train Accuracy: 65.01%
#     Worker 6: Train Loss: 1.2774, Train Accuracy: 64.55%
#     Worker 7: Train Loss: 1.2315, Train Accuracy: 64.59%
# Epoch 123/150: Test Loss: 1.9616, Test Accuracy: 50.81%
#     Worker 0: Train Loss: 1.2522, Train Accuracy: 64.22%
#     Worker 1: Train Loss: 1.2455, Train Accuracy: 65.10%
#     Worker 2: Train Loss: 1.2306, Train Accuracy: 65.07%
#     Worker 3: Train Loss: 1.2591, Train Accuracy: 64.28%
#     Worker 4: Train Loss: 1.2233, Train Accuracy: 64.54%
#     Worker 5: Train Loss: 1.2351, Train Accuracy: 64.97%
#     Worker 6: Train Loss: 1.2591, Train Accuracy: 64.09%
#     Worker 7: Train Loss: 1.2512, Train Accuracy: 64.55%
# Epoch 124/150: Test Loss: 1.9599, Test Accuracy: 50.76%
#     Worker 0: Train Loss: 1.2344, Train Accuracy: 64.76%
#     Worker 1: Train Loss: 1.2260, Train Accuracy: 64.91%
#     Worker 2: Train Loss: 1.2321, Train Accuracy: 65.19%
#     Worker 3: Train Loss: 1.2528, Train Accuracy: 64.38%
#     Worker 4: Train Loss: 1.2200, Train Accuracy: 65.42%
#     Worker 5: Train Loss: 1.2487, Train Accuracy: 64.64%
#     Worker 6: Train Loss: 1.2459, Train Accuracy: 64.79%
#     Worker 7: Train Loss: 1.2087, Train Accuracy: 65.34%
# Epoch 125/150: Test Loss: 1.9688, Test Accuracy: 50.68%
#     Worker 0: Train Loss: 1.2096, Train Accuracy: 65.55%
#     Worker 1: Train Loss: 1.2039, Train Accuracy: 65.24%
#     Worker 2: Train Loss: 1.1942, Train Accuracy: 65.94%
#     Worker 3: Train Loss: 1.2339, Train Accuracy: 64.45%
#     Worker 4: Train Loss: 1.2132, Train Accuracy: 65.59%
#     Worker 5: Train Loss: 1.2296, Train Accuracy: 64.99%
#     Worker 6: Train Loss: 1.2391, Train Accuracy: 64.97%
#     Worker 7: Train Loss: 1.2341, Train Accuracy: 64.95%
# Epoch 126/150: Test Loss: 1.9656, Test Accuracy: 50.97%
#     Worker 0: Train Loss: 1.2368, Train Accuracy: 65.23%
#     Worker 1: Train Loss: 1.2153, Train Accuracy: 65.21%
#     Worker 2: Train Loss: 1.2159, Train Accuracy: 65.09%
#     Worker 3: Train Loss: 1.2567, Train Accuracy: 64.38%
#     Worker 4: Train Loss: 1.2107, Train Accuracy: 65.62%
#     Worker 5: Train Loss: 1.2171, Train Accuracy: 65.84%
#     Worker 6: Train Loss: 1.2586, Train Accuracy: 64.65%
#     Worker 7: Train Loss: 1.2022, Train Accuracy: 65.75%
# Epoch 127/150: Test Loss: 1.9692, Test Accuracy: 50.92%
#     Worker 0: Train Loss: 1.2187, Train Accuracy: 65.73%
#     Worker 1: Train Loss: 1.2176, Train Accuracy: 65.52%
#     Worker 2: Train Loss: 1.2039, Train Accuracy: 66.12%
#     Worker 3: Train Loss: 1.2319, Train Accuracy: 64.68%
#     Worker 4: Train Loss: 1.2169, Train Accuracy: 65.20%
#     Worker 5: Train Loss: 1.2378, Train Accuracy: 65.30%
#     Worker 6: Train Loss: 1.2388, Train Accuracy: 64.75%
#     Worker 7: Train Loss: 1.2157, Train Accuracy: 65.13%
# Epoch 128/150: Test Loss: 1.9683, Test Accuracy: 50.92%
#     Worker 0: Train Loss: 1.2181, Train Accuracy: 65.91%
#     Worker 1: Train Loss: 1.2104, Train Accuracy: 65.43%
#     Worker 2: Train Loss: 1.1931, Train Accuracy: 66.22%
#     Worker 3: Train Loss: 1.2230, Train Accuracy: 65.21%
#     Worker 4: Train Loss: 1.1853, Train Accuracy: 65.66%
#     Worker 5: Train Loss: 1.2137, Train Accuracy: 65.86%
#     Worker 6: Train Loss: 1.2407, Train Accuracy: 64.95%
#     Worker 7: Train Loss: 1.1916, Train Accuracy: 65.76%
# Epoch 129/150: Test Loss: 1.9713, Test Accuracy: 50.97%
#     Worker 0: Train Loss: 1.2101, Train Accuracy: 65.89%
#     Worker 1: Train Loss: 1.1925, Train Accuracy: 66.10%
#     Worker 2: Train Loss: 1.1961, Train Accuracy: 66.03%
#     Worker 3: Train Loss: 1.2267, Train Accuracy: 64.94%
#     Worker 4: Train Loss: 1.1936, Train Accuracy: 65.99%
#     Worker 5: Train Loss: 1.2068, Train Accuracy: 66.07%
#     Worker 6: Train Loss: 1.2345, Train Accuracy: 64.65%
#     Worker 7: Train Loss: 1.1918, Train Accuracy: 66.18%
# Epoch 130/150: Test Loss: 1.9705, Test Accuracy: 50.96%
#     Worker 0: Train Loss: 1.1977, Train Accuracy: 65.92%
#     Worker 1: Train Loss: 1.2153, Train Accuracy: 65.57%
#     Worker 2: Train Loss: 1.1969, Train Accuracy: 66.11%
#     Worker 3: Train Loss: 1.2123, Train Accuracy: 65.39%
#     Worker 4: Train Loss: 1.1890, Train Accuracy: 65.80%
#     Worker 5: Train Loss: 1.2260, Train Accuracy: 64.81%
#     Worker 6: Train Loss: 1.2265, Train Accuracy: 65.59%
#     Worker 7: Train Loss: 1.2082, Train Accuracy: 65.65%
# Epoch 131/150: Test Loss: 1.9707, Test Accuracy: 50.90%
#     Worker 0: Train Loss: 1.2159, Train Accuracy: 65.56%
#     Worker 1: Train Loss: 1.1804, Train Accuracy: 65.84%
#     Worker 2: Train Loss: 1.1949, Train Accuracy: 66.07%
#     Worker 3: Train Loss: 1.2065, Train Accuracy: 65.82%
#     Worker 4: Train Loss: 1.2007, Train Accuracy: 66.26%
#     Worker 5: Train Loss: 1.1997, Train Accuracy: 65.72%
#     Worker 6: Train Loss: 1.2410, Train Accuracy: 64.74%
#     Worker 7: Train Loss: 1.1990, Train Accuracy: 65.98%
# Epoch 132/150: Test Loss: 1.9717, Test Accuracy: 50.91%
#     Worker 0: Train Loss: 1.2055, Train Accuracy: 65.51%
#     Worker 1: Train Loss: 1.1846, Train Accuracy: 66.23%
#     Worker 2: Train Loss: 1.1936, Train Accuracy: 66.49%
#     Worker 3: Train Loss: 1.1883, Train Accuracy: 66.39%
#     Worker 4: Train Loss: 1.1754, Train Accuracy: 66.39%
#     Worker 5: Train Loss: 1.2029, Train Accuracy: 66.46%
#     Worker 6: Train Loss: 1.2319, Train Accuracy: 65.34%
#     Worker 7: Train Loss: 1.1816, Train Accuracy: 66.68%
# Epoch 133/150: Test Loss: 1.9733, Test Accuracy: 50.86%
#     Worker 0: Train Loss: 1.2088, Train Accuracy: 64.87%
#     Worker 1: Train Loss: 1.1749, Train Accuracy: 66.87%
#     Worker 2: Train Loss: 1.1688, Train Accuracy: 66.35%
#     Worker 3: Train Loss: 1.2198, Train Accuracy: 65.53%
#     Worker 4: Train Loss: 1.1991, Train Accuracy: 66.44%
#     Worker 5: Train Loss: 1.2116, Train Accuracy: 65.88%
#     Worker 6: Train Loss: 1.2177, Train Accuracy: 65.63%
#     Worker 7: Train Loss: 1.1834, Train Accuracy: 65.96%
# Epoch 134/150: Test Loss: 1.9745, Test Accuracy: 50.83%
#     Worker 0: Train Loss: 1.1813, Train Accuracy: 66.05%
#     Worker 1: Train Loss: 1.1944, Train Accuracy: 65.61%
#     Worker 2: Train Loss: 1.1905, Train Accuracy: 66.43%
#     Worker 3: Train Loss: 1.2160, Train Accuracy: 64.96%
#     Worker 4: Train Loss: 1.1704, Train Accuracy: 66.94%
#     Worker 5: Train Loss: 1.2228, Train Accuracy: 65.81%
#     Worker 6: Train Loss: 1.2205, Train Accuracy: 65.34%
#     Worker 7: Train Loss: 1.1918, Train Accuracy: 65.87%
# Epoch 135/150: Test Loss: 1.9763, Test Accuracy: 50.93%
#     Worker 0: Train Loss: 1.1968, Train Accuracy: 66.07%
#     Worker 1: Train Loss: 1.1746, Train Accuracy: 66.47%
#     Worker 2: Train Loss: 1.1858, Train Accuracy: 66.47%
#     Worker 3: Train Loss: 1.2009, Train Accuracy: 65.90%
#     Worker 4: Train Loss: 1.1795, Train Accuracy: 66.61%
#     Worker 5: Train Loss: 1.2263, Train Accuracy: 66.16%
#     Worker 6: Train Loss: 1.2112, Train Accuracy: 66.06%
#     Worker 7: Train Loss: 1.1822, Train Accuracy: 66.27%
# Epoch 136/150: Test Loss: 1.9748, Test Accuracy: 51.06%
#     Worker 0: Train Loss: 1.2083, Train Accuracy: 65.42%
#     Worker 1: Train Loss: 1.2011, Train Accuracy: 65.46%
#     Worker 2: Train Loss: 1.1735, Train Accuracy: 67.21%
#     Worker 3: Train Loss: 1.1808, Train Accuracy: 66.16%
#     Worker 4: Train Loss: 1.1725, Train Accuracy: 66.40%
#     Worker 5: Train Loss: 1.1905, Train Accuracy: 66.55%
#     Worker 6: Train Loss: 1.2038, Train Accuracy: 65.53%
#     Worker 7: Train Loss: 1.1760, Train Accuracy: 66.39%
# Epoch 137/150: Test Loss: 1.9756, Test Accuracy: 51.02%
#     Worker 0: Train Loss: 1.1907, Train Accuracy: 66.30%
#     Worker 1: Train Loss: 1.1691, Train Accuracy: 66.50%
#     Worker 2: Train Loss: 1.2054, Train Accuracy: 66.06%
#     Worker 3: Train Loss: 1.2201, Train Accuracy: 65.18%
#     Worker 4: Train Loss: 1.1888, Train Accuracy: 66.01%
#     Worker 5: Train Loss: 1.1808, Train Accuracy: 66.65%
#     Worker 6: Train Loss: 1.2181, Train Accuracy: 65.47%
#     Worker 7: Train Loss: 1.1711, Train Accuracy: 66.43%
# Epoch 138/150: Test Loss: 1.9754, Test Accuracy: 50.94%
#     Worker 0: Train Loss: 1.1822, Train Accuracy: 66.14%
#     Worker 1: Train Loss: 1.1875, Train Accuracy: 66.02%
#     Worker 2: Train Loss: 1.1714, Train Accuracy: 66.67%
#     Worker 3: Train Loss: 1.2004, Train Accuracy: 65.67%
#     Worker 4: Train Loss: 1.1981, Train Accuracy: 66.24%
#     Worker 5: Train Loss: 1.1923, Train Accuracy: 66.18%
#     Worker 6: Train Loss: 1.2080, Train Accuracy: 66.05%
#     Worker 7: Train Loss: 1.1794, Train Accuracy: 66.73%
# Epoch 139/150: Test Loss: 1.9747, Test Accuracy: 50.92%
#     Worker 0: Train Loss: 1.1988, Train Accuracy: 66.18%
#     Worker 1: Train Loss: 1.1660, Train Accuracy: 66.06%
#     Worker 2: Train Loss: 1.1732, Train Accuracy: 66.81%
#     Worker 3: Train Loss: 1.2025, Train Accuracy: 65.54%
#     Worker 4: Train Loss: 1.1587, Train Accuracy: 66.56%
#     Worker 5: Train Loss: 1.1853, Train Accuracy: 67.10%
#     Worker 6: Train Loss: 1.2124, Train Accuracy: 65.53%
#     Worker 7: Train Loss: 1.1907, Train Accuracy: 66.05%
# Epoch 140/150: Test Loss: 1.9751, Test Accuracy: 51.07%
#     Worker 0: Train Loss: 1.1759, Train Accuracy: 66.54%
#     Worker 1: Train Loss: 1.1750, Train Accuracy: 66.36%
#     Worker 2: Train Loss: 1.1598, Train Accuracy: 67.18%
#     Worker 3: Train Loss: 1.1916, Train Accuracy: 66.30%
#     Worker 4: Train Loss: 1.1582, Train Accuracy: 67.17%
#     Worker 5: Train Loss: 1.1820, Train Accuracy: 66.78%
#     Worker 6: Train Loss: 1.2199, Train Accuracy: 65.81%
#     Worker 7: Train Loss: 1.1856, Train Accuracy: 66.51%
# Epoch 141/150: Test Loss: 1.9762, Test Accuracy: 50.91%
#     Worker 0: Train Loss: 1.1888, Train Accuracy: 65.86%
#     Worker 1: Train Loss: 1.1646, Train Accuracy: 66.05%
#     Worker 2: Train Loss: 1.1813, Train Accuracy: 66.78%
#     Worker 3: Train Loss: 1.2019, Train Accuracy: 65.48%
#     Worker 4: Train Loss: 1.1897, Train Accuracy: 65.72%
#     Worker 5: Train Loss: 1.1911, Train Accuracy: 66.78%
#     Worker 6: Train Loss: 1.1907, Train Accuracy: 65.86%
#     Worker 7: Train Loss: 1.1676, Train Accuracy: 66.90%
# Epoch 142/150: Test Loss: 1.9760, Test Accuracy: 50.94%
#     Worker 0: Train Loss: 1.1923, Train Accuracy: 65.97%
#     Worker 1: Train Loss: 1.1827, Train Accuracy: 66.21%
#     Worker 2: Train Loss: 1.1901, Train Accuracy: 66.14%
#     Worker 3: Train Loss: 1.1977, Train Accuracy: 65.80%
#     Worker 4: Train Loss: 1.1641, Train Accuracy: 66.74%
#     Worker 5: Train Loss: 1.1752, Train Accuracy: 66.05%
#     Worker 6: Train Loss: 1.2035, Train Accuracy: 65.59%
#     Worker 7: Train Loss: 1.1871, Train Accuracy: 66.28%
# Epoch 143/150: Test Loss: 1.9755, Test Accuracy: 50.92%
#     Worker 0: Train Loss: 1.1859, Train Accuracy: 66.50%
#     Worker 1: Train Loss: 1.1837, Train Accuracy: 65.69%
#     Worker 2: Train Loss: 1.1785, Train Accuracy: 66.23%
#     Worker 3: Train Loss: 1.2123, Train Accuracy: 65.09%
#     Worker 4: Train Loss: 1.1739, Train Accuracy: 66.54%
#     Worker 5: Train Loss: 1.1930, Train Accuracy: 66.40%
#     Worker 6: Train Loss: 1.2151, Train Accuracy: 65.78%
#     Worker 7: Train Loss: 1.1782, Train Accuracy: 66.49%
# Epoch 144/150: Test Loss: 1.9761, Test Accuracy: 50.90%
#     Worker 0: Train Loss: 1.1987, Train Accuracy: 66.18%
#     Worker 1: Train Loss: 1.1663, Train Accuracy: 66.62%
#     Worker 2: Train Loss: 1.1737, Train Accuracy: 66.72%
#     Worker 3: Train Loss: 1.1845, Train Accuracy: 65.93%
#     Worker 4: Train Loss: 1.1840, Train Accuracy: 66.25%
#     Worker 5: Train Loss: 1.1881, Train Accuracy: 66.19%
#     Worker 6: Train Loss: 1.2016, Train Accuracy: 66.03%
#     Worker 7: Train Loss: 1.1721, Train Accuracy: 66.27%
# Epoch 145/150: Test Loss: 1.9760, Test Accuracy: 50.98%
#     Worker 0: Train Loss: 1.1790, Train Accuracy: 66.56%
#     Worker 1: Train Loss: 1.1828, Train Accuracy: 66.39%
#     Worker 2: Train Loss: 1.1712, Train Accuracy: 66.16%
#     Worker 3: Train Loss: 1.2000, Train Accuracy: 65.56%
#     Worker 4: Train Loss: 1.1691, Train Accuracy: 66.51%
#     Worker 5: Train Loss: 1.2131, Train Accuracy: 66.36%
#     Worker 6: Train Loss: 1.1963, Train Accuracy: 66.44%
#     Worker 7: Train Loss: 1.1620, Train Accuracy: 66.83%
# Epoch 146/150: Test Loss: 1.9757, Test Accuracy: 51.02%
#     Worker 0: Train Loss: 1.1814, Train Accuracy: 66.87%
#     Worker 1: Train Loss: 1.1701, Train Accuracy: 66.43%
#     Worker 2: Train Loss: 1.1743, Train Accuracy: 66.68%
#     Worker 3: Train Loss: 1.2001, Train Accuracy: 66.46%
#     Worker 4: Train Loss: 1.1758, Train Accuracy: 66.59%
#     Worker 5: Train Loss: 1.2014, Train Accuracy: 66.08%
#     Worker 6: Train Loss: 1.2247, Train Accuracy: 65.34%
#     Worker 7: Train Loss: 1.1824, Train Accuracy: 66.22%
# Epoch 147/150: Test Loss: 1.9760, Test Accuracy: 51.00%
#     Worker 0: Train Loss: 1.1828, Train Accuracy: 66.74%
#     Worker 1: Train Loss: 1.1668, Train Accuracy: 66.65%
#     Worker 2: Train Loss: 1.1795, Train Accuracy: 66.37%
#     Worker 3: Train Loss: 1.1969, Train Accuracy: 66.18%
#     Worker 4: Train Loss: 1.1590, Train Accuracy: 67.08%
#     Worker 5: Train Loss: 1.1851, Train Accuracy: 66.46%
#     Worker 6: Train Loss: 1.1895, Train Accuracy: 66.61%
#     Worker 7: Train Loss: 1.1880, Train Accuracy: 66.34%
# Epoch 148/150: Test Loss: 1.9758, Test Accuracy: 51.02%
#     Worker 0: Train Loss: 1.1819, Train Accuracy: 66.32%
#     Worker 1: Train Loss: 1.1870, Train Accuracy: 66.49%
#     Worker 2: Train Loss: 1.1845, Train Accuracy: 66.23%
#     Worker 3: Train Loss: 1.1904, Train Accuracy: 65.91%
#     Worker 4: Train Loss: 1.1554, Train Accuracy: 67.26%
#     Worker 5: Train Loss: 1.2067, Train Accuracy: 66.36%
#     Worker 6: Train Loss: 1.2006, Train Accuracy: 66.12%
#     Worker 7: Train Loss: 1.1804, Train Accuracy: 66.33%
# Epoch 149/150: Test Loss: 1.9758, Test Accuracy: 51.04%
#     Worker 0: Train Loss: 1.1871, Train Accuracy: 65.53%
#     Worker 1: Train Loss: 1.1682, Train Accuracy: 66.16%
#     Worker 2: Train Loss: 1.1707, Train Accuracy: 66.99%
#     Worker 3: Train Loss: 1.1865, Train Accuracy: 65.26%
#     Worker 4: Train Loss: 1.1978, Train Accuracy: 65.84%
#     Worker 5: Train Loss: 1.1743, Train Accuracy: 66.30%
#     Worker 6: Train Loss: 1.1959, Train Accuracy: 66.21%
#     Worker 7: Train Loss: 1.1802, Train Accuracy: 65.64%
# Epoch 150/150: Test Loss: 1.9759, Test Accuracy: 51.04%
#     Worker 0: Train Loss: 1.1698, Train Accuracy: 67.07%
#     Worker 1: Train Loss: 1.1656, Train Accuracy: 66.56%
#     Worker 2: Train Loss: 1.1759, Train Accuracy: 66.45%
#     Worker 3: Train Loss: 1.1912, Train Accuracy: 66.10%
#     Worker 4: Train Loss: 1.1742, Train Accuracy: 66.76%
#     Worker 5: Train Loss: 1.1890, Train Accuracy: 66.44%
#     Worker 6: Train Loss: 1.2183, Train Accuracy: 65.86%
#     Worker 7: Train Loss: 1.1772, Train Accuracy: 66.50%
