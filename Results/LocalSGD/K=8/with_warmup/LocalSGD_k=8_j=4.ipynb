# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs - warmup_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")

    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch):
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            # Perform J local step before synchronization
            for j in range(J):
                try:
                    # Get a batch from the current worker's shard using next()
                    images, labels = next(shard_iterators[k])
                    images, labels = images.to(device), labels.to(device)  # Move to device
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

                except StopIteration:
                    # If the iterator has exhausted the data, restart the iterator
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k]) # Resume from the next batch
                    images, labels = images.to(device), labels.to(device)
                    # Perform optimization step
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        # Perform model synchronization
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            # Update each worker model with the global parameters
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
        else:
            warmup_factor = (epoch + 1) / warmup_epochs
            lr = warmup_factor * learning_rate
            for optimizer in optimizers:
                for param_group in optimizer.param_groups:
                    param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Overwriting localSGD.py

# %%
# %run localSGD.py --k 8 --j 4
# Out:
# Training with K=8, J=4
# Global iteration per epoch: 25
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00800
# Epoch 1/150: Test Loss: 4.5771, Test Accuracy: 2.44%
#     Worker 0: Train Loss: 4.5989, Train Accuracy: 1.33%
#     Worker 1: Train Loss: 4.5989, Train Accuracy: 1.29%
#     Worker 2: Train Loss: 4.5990, Train Accuracy: 1.27%
#     Worker 3: Train Loss: 4.5968, Train Accuracy: 1.63%
#     Worker 4: Train Loss: 4.5983, Train Accuracy: 1.21%
#     Worker 5: Train Loss: 4.5959, Train Accuracy: 1.61%
#     Worker 6: Train Loss: 4.5982, Train Accuracy: 1.30%
#     Worker 7: Train Loss: 4.5975, Train Accuracy: 1.29%
# Epoch 2/150: Test Loss: 4.5429, Test Accuracy: 3.25%
#     Worker 0: Train Loss: 4.5682, Train Accuracy: 2.63%
#     Worker 1: Train Loss: 4.5667, Train Accuracy: 2.48%
#     Worker 2: Train Loss: 4.5672, Train Accuracy: 2.32%
#     Worker 3: Train Loss: 4.5653, Train Accuracy: 2.48%
#     Worker 4: Train Loss: 4.5636, Train Accuracy: 2.52%
#     Worker 5: Train Loss: 4.5594, Train Accuracy: 2.45%
#     Worker 6: Train Loss: 4.5666, Train Accuracy: 2.65%
#     Worker 7: Train Loss: 4.5631, Train Accuracy: 2.13%
# Epoch 3/150: Test Loss: 4.3436, Test Accuracy: 4.67%
#     Worker 0: Train Loss: 4.4641, Train Accuracy: 4.25%
#     Worker 1: Train Loss: 4.4683, Train Accuracy: 3.65%
#     Worker 2: Train Loss: 4.4712, Train Accuracy: 3.53%
#     Worker 3: Train Loss: 4.4647, Train Accuracy: 3.59%
#     Worker 4: Train Loss: 4.4587, Train Accuracy: 3.61%
#     Worker 5: Train Loss: 4.4489, Train Accuracy: 3.59%
#     Worker 6: Train Loss: 4.4690, Train Accuracy: 3.59%
#     Worker 7: Train Loss: 4.4625, Train Accuracy: 3.64%
# Epoch 4/150: Test Loss: 4.0976, Test Accuracy: 7.53%
#     Worker 0: Train Loss: 4.2215, Train Accuracy: 6.01%
#     Worker 1: Train Loss: 4.2392, Train Accuracy: 5.30%
#     Worker 2: Train Loss: 4.2322, Train Accuracy: 5.69%
#     Worker 3: Train Loss: 4.2480, Train Accuracy: 5.38%
#     Worker 4: Train Loss: 4.2089, Train Accuracy: 5.55%
#     Worker 5: Train Loss: 4.2065, Train Accuracy: 5.77%
#     Worker 6: Train Loss: 4.2355, Train Accuracy: 5.46%
#     Worker 7: Train Loss: 4.2168, Train Accuracy: 5.63%
# Epoch 5/150: Test Loss: 3.9722, Test Accuracy: 9.47%
#     Worker 0: Train Loss: 4.0800, Train Accuracy: 7.38%
#     Worker 1: Train Loss: 4.0734, Train Accuracy: 7.28%
#     Worker 2: Train Loss: 4.0699, Train Accuracy: 7.54%
#     Worker 3: Train Loss: 4.0912, Train Accuracy: 7.28%
#     Worker 4: Train Loss: 4.0525, Train Accuracy: 8.00%
#     Worker 5: Train Loss: 4.0654, Train Accuracy: 7.57%
#     Worker 6: Train Loss: 4.0920, Train Accuracy: 7.29%
#     Worker 7: Train Loss: 4.0853, Train Accuracy: 7.57%
# Epoch 6/150: Test Loss: 3.8288, Test Accuracy: 11.95%
#     Worker 0: Train Loss: 3.9812, Train Accuracy: 8.95%
#     Worker 1: Train Loss: 3.9847, Train Accuracy: 8.33%
#     Worker 2: Train Loss: 3.9571, Train Accuracy: 9.41%
#     Worker 3: Train Loss: 3.9865, Train Accuracy: 8.80%
#     Worker 4: Train Loss: 3.9404, Train Accuracy: 9.45%
#     Worker 5: Train Loss: 3.9253, Train Accuracy: 9.91%
#     Worker 6: Train Loss: 3.9984, Train Accuracy: 8.67%
#     Worker 7: Train Loss: 3.9716, Train Accuracy: 9.25%
# Epoch 7/150: Test Loss: 3.6815, Test Accuracy: 14.38%
#     Worker 0: Train Loss: 3.8312, Train Accuracy: 10.87%
#     Worker 1: Train Loss: 3.8315, Train Accuracy: 10.80%
#     Worker 2: Train Loss: 3.8315, Train Accuracy: 11.43%
#     Worker 3: Train Loss: 3.8640, Train Accuracy: 10.79%
#     Worker 4: Train Loss: 3.7954, Train Accuracy: 11.30%
#     Worker 5: Train Loss: 3.7922, Train Accuracy: 12.03%
#     Worker 6: Train Loss: 3.8475, Train Accuracy: 10.91%
#     Worker 7: Train Loss: 3.8385, Train Accuracy: 11.52%
# Epoch 8/150: Test Loss: 3.5797, Test Accuracy: 15.74%
#     Worker 0: Train Loss: 3.7140, Train Accuracy: 12.95%
#     Worker 1: Train Loss: 3.7205, Train Accuracy: 12.83%
#     Worker 2: Train Loss: 3.7297, Train Accuracy: 13.23%
#     Worker 3: Train Loss: 3.7463, Train Accuracy: 12.89%
#     Worker 4: Train Loss: 3.6936, Train Accuracy: 13.15%
#     Worker 5: Train Loss: 3.6779, Train Accuracy: 14.22%
#     Worker 6: Train Loss: 3.7197, Train Accuracy: 13.06%
#     Worker 7: Train Loss: 3.7346, Train Accuracy: 12.72%
# Epoch 9/150: Test Loss: 3.5058, Test Accuracy: 17.10%
#     Worker 0: Train Loss: 3.6488, Train Accuracy: 14.25%
#     Worker 1: Train Loss: 3.6244, Train Accuracy: 14.58%
#     Worker 2: Train Loss: 3.6403, Train Accuracy: 14.27%
#     Worker 3: Train Loss: 3.6211, Train Accuracy: 14.89%
#     Worker 4: Train Loss: 3.5943, Train Accuracy: 14.96%
#     Worker 5: Train Loss: 3.5837, Train Accuracy: 16.02%
#     Worker 6: Train Loss: 3.6408, Train Accuracy: 13.92%
#     Worker 7: Train Loss: 3.6264, Train Accuracy: 14.44%
# Epoch 10/150: Test Loss: 3.3991, Test Accuracy: 19.48%
#     Worker 0: Train Loss: 3.5255, Train Accuracy: 16.46%
#     Worker 1: Train Loss: 3.5275, Train Accuracy: 16.09%
#     Worker 2: Train Loss: 3.5410, Train Accuracy: 16.62%
#     Worker 3: Train Loss: 3.5832, Train Accuracy: 15.33%
#     Worker 4: Train Loss: 3.4858, Train Accuracy: 16.81%
#     Worker 5: Train Loss: 3.4745, Train Accuracy: 17.03%
#     Worker 6: Train Loss: 3.5631, Train Accuracy: 15.27%
#     Worker 7: Train Loss: 3.5275, Train Accuracy: 16.13%
# Epoch 11/150: Test Loss: 3.3308, Test Accuracy: 20.58%
#     Worker 0: Train Loss: 3.4698, Train Accuracy: 17.31%
#     Worker 1: Train Loss: 3.4537, Train Accuracy: 17.28%
#     Worker 2: Train Loss: 3.4847, Train Accuracy: 18.00%
#     Worker 3: Train Loss: 3.4726, Train Accuracy: 17.53%
#     Worker 4: Train Loss: 3.4244, Train Accuracy: 17.47%
#     Worker 5: Train Loss: 3.4129, Train Accuracy: 18.33%
#     Worker 6: Train Loss: 3.4732, Train Accuracy: 16.34%
#     Worker 7: Train Loss: 3.4761, Train Accuracy: 17.17%
# Epoch 12/150: Test Loss: 3.2640, Test Accuracy: 21.45%
#     Worker 0: Train Loss: 3.3679, Train Accuracy: 19.18%
#     Worker 1: Train Loss: 3.3764, Train Accuracy: 18.41%
#     Worker 2: Train Loss: 3.3798, Train Accuracy: 19.90%
#     Worker 3: Train Loss: 3.4005, Train Accuracy: 18.11%
#     Worker 4: Train Loss: 3.3602, Train Accuracy: 19.07%
#     Worker 5: Train Loss: 3.3520, Train Accuracy: 19.87%
#     Worker 6: Train Loss: 3.4114, Train Accuracy: 17.97%
#     Worker 7: Train Loss: 3.3780, Train Accuracy: 18.28%
# Epoch 13/150: Test Loss: 3.1887, Test Accuracy: 23.25%
#     Worker 0: Train Loss: 3.3063, Train Accuracy: 19.66%
#     Worker 1: Train Loss: 3.2923, Train Accuracy: 19.72%
#     Worker 2: Train Loss: 3.3436, Train Accuracy: 20.15%
#     Worker 3: Train Loss: 3.3550, Train Accuracy: 19.07%
#     Worker 4: Train Loss: 3.2759, Train Accuracy: 19.96%
#     Worker 5: Train Loss: 3.2637, Train Accuracy: 21.51%
#     Worker 6: Train Loss: 3.3427, Train Accuracy: 19.72%
#     Worker 7: Train Loss: 3.3460, Train Accuracy: 19.50%
# Epoch 14/150: Test Loss: 3.1181, Test Accuracy: 24.81%
#     Worker 0: Train Loss: 3.2629, Train Accuracy: 20.34%
#     Worker 1: Train Loss: 3.2555, Train Accuracy: 20.88%
#     Worker 2: Train Loss: 3.2369, Train Accuracy: 21.70%
#     Worker 3: Train Loss: 3.2555, Train Accuracy: 20.66%
#     Worker 4: Train Loss: 3.2218, Train Accuracy: 21.76%
#     Worker 5: Train Loss: 3.2132, Train Accuracy: 21.57%
#     Worker 6: Train Loss: 3.2759, Train Accuracy: 20.71%
#     Worker 7: Train Loss: 3.2366, Train Accuracy: 20.95%
# Epoch 15/150: Test Loss: 3.1214, Test Accuracy: 24.09%
#     Worker 0: Train Loss: 3.1957, Train Accuracy: 22.45%
#     Worker 1: Train Loss: 3.1965, Train Accuracy: 21.37%
#     Worker 2: Train Loss: 3.2205, Train Accuracy: 22.26%
#     Worker 3: Train Loss: 3.2451, Train Accuracy: 21.20%
#     Worker 4: Train Loss: 3.1821, Train Accuracy: 22.55%
#     Worker 5: Train Loss: 3.1548, Train Accuracy: 23.00%
#     Worker 6: Train Loss: 3.2458, Train Accuracy: 19.80%
#     Worker 7: Train Loss: 3.2074, Train Accuracy: 21.73%
# Epoch 16/150: Test Loss: 3.0042, Test Accuracy: 26.88%
#     Worker 0: Train Loss: 3.1574, Train Accuracy: 22.14%
#     Worker 1: Train Loss: 3.1515, Train Accuracy: 22.78%
#     Worker 2: Train Loss: 3.1686, Train Accuracy: 23.44%
#     Worker 3: Train Loss: 3.1540, Train Accuracy: 21.76%
#     Worker 4: Train Loss: 3.1334, Train Accuracy: 23.68%
#     Worker 5: Train Loss: 3.0909, Train Accuracy: 24.96%
#     Worker 6: Train Loss: 3.1389, Train Accuracy: 22.94%
#     Worker 7: Train Loss: 3.1710, Train Accuracy: 22.50%
# Epoch 17/150: Test Loss: 2.9764, Test Accuracy: 26.93%
#     Worker 0: Train Loss: 3.0847, Train Accuracy: 23.97%
#     Worker 1: Train Loss: 3.0407, Train Accuracy: 24.73%
#     Worker 2: Train Loss: 3.0625, Train Accuracy: 25.31%
#     Worker 3: Train Loss: 3.1003, Train Accuracy: 23.85%
#     Worker 4: Train Loss: 3.0223, Train Accuracy: 25.63%
#     Worker 5: Train Loss: 3.0411, Train Accuracy: 24.41%
#     Worker 6: Train Loss: 3.1134, Train Accuracy: 23.74%
#     Worker 7: Train Loss: 3.0800, Train Accuracy: 24.18%
# Epoch 18/150: Test Loss: 2.9354, Test Accuracy: 28.08%
#     Worker 0: Train Loss: 3.0117, Train Accuracy: 26.07%
#     Worker 1: Train Loss: 3.0288, Train Accuracy: 24.80%
#     Worker 2: Train Loss: 3.0171, Train Accuracy: 26.20%
#     Worker 3: Train Loss: 3.0591, Train Accuracy: 24.40%
#     Worker 4: Train Loss: 3.0118, Train Accuracy: 25.53%
#     Worker 5: Train Loss: 3.0007, Train Accuracy: 25.81%
#     Worker 6: Train Loss: 3.0453, Train Accuracy: 24.77%
#     Worker 7: Train Loss: 3.0022, Train Accuracy: 26.14%
# Epoch 19/150: Test Loss: 2.8498, Test Accuracy: 29.72%
#     Worker 0: Train Loss: 2.9669, Train Accuracy: 25.53%
#     Worker 1: Train Loss: 2.9597, Train Accuracy: 26.67%
#     Worker 2: Train Loss: 2.9927, Train Accuracy: 25.84%
#     Worker 3: Train Loss: 2.9905, Train Accuracy: 25.92%
#     Worker 4: Train Loss: 2.9637, Train Accuracy: 27.03%
#     Worker 5: Train Loss: 2.9216, Train Accuracy: 28.32%
#     Worker 6: Train Loss: 2.9984, Train Accuracy: 25.15%
#     Worker 7: Train Loss: 2.9477, Train Accuracy: 26.84%
# Epoch 20/150: Test Loss: 2.8250, Test Accuracy: 30.13%
#     Worker 0: Train Loss: 2.9309, Train Accuracy: 26.75%
#     Worker 1: Train Loss: 2.8971, Train Accuracy: 26.98%
#     Worker 2: Train Loss: 2.9298, Train Accuracy: 27.83%
#     Worker 3: Train Loss: 2.9328, Train Accuracy: 26.59%
#     Worker 4: Train Loss: 2.8688, Train Accuracy: 28.22%
#     Worker 5: Train Loss: 2.8839, Train Accuracy: 28.94%
#     Worker 6: Train Loss: 2.9408, Train Accuracy: 27.01%
#     Worker 7: Train Loss: 2.9569, Train Accuracy: 26.54%
# Epoch 21/150: Test Loss: 2.7750, Test Accuracy: 30.98%
#     Worker 0: Train Loss: 2.9294, Train Accuracy: 27.39%
#     Worker 1: Train Loss: 2.8429, Train Accuracy: 28.14%
#     Worker 2: Train Loss: 2.8872, Train Accuracy: 28.55%
#     Worker 3: Train Loss: 2.9340, Train Accuracy: 27.34%
#     Worker 4: Train Loss: 2.8547, Train Accuracy: 28.41%
#     Worker 5: Train Loss: 2.8309, Train Accuracy: 29.13%
#     Worker 6: Train Loss: 2.9128, Train Accuracy: 27.38%
#     Worker 7: Train Loss: 2.8842, Train Accuracy: 28.50%
# Epoch 22/150: Test Loss: 2.7047, Test Accuracy: 32.26%
#     Worker 0: Train Loss: 2.8305, Train Accuracy: 29.23%
#     Worker 1: Train Loss: 2.8088, Train Accuracy: 28.76%
#     Worker 2: Train Loss: 2.8480, Train Accuracy: 28.88%
#     Worker 3: Train Loss: 2.8405, Train Accuracy: 27.81%
#     Worker 4: Train Loss: 2.8117, Train Accuracy: 29.76%
#     Worker 5: Train Loss: 2.8240, Train Accuracy: 29.60%
#     Worker 6: Train Loss: 2.8460, Train Accuracy: 28.93%
#     Worker 7: Train Loss: 2.8215, Train Accuracy: 30.46%
# Epoch 23/150: Test Loss: 2.6889, Test Accuracy: 32.79%
#     Worker 0: Train Loss: 2.7731, Train Accuracy: 30.32%
#     Worker 1: Train Loss: 2.7570, Train Accuracy: 30.26%
#     Worker 2: Train Loss: 2.7782, Train Accuracy: 29.95%
#     Worker 3: Train Loss: 2.8281, Train Accuracy: 28.54%
#     Worker 4: Train Loss: 2.7438, Train Accuracy: 31.01%
#     Worker 5: Train Loss: 2.7231, Train Accuracy: 31.19%
#     Worker 6: Train Loss: 2.7976, Train Accuracy: 29.85%
#     Worker 7: Train Loss: 2.7763, Train Accuracy: 29.79%
# Epoch 24/150: Test Loss: 2.6314, Test Accuracy: 34.01%
#     Worker 0: Train Loss: 2.7507, Train Accuracy: 30.12%
#     Worker 1: Train Loss: 2.7364, Train Accuracy: 31.17%
#     Worker 2: Train Loss: 2.7419, Train Accuracy: 31.08%
#     Worker 3: Train Loss: 2.7723, Train Accuracy: 30.07%
#     Worker 4: Train Loss: 2.7241, Train Accuracy: 31.01%
#     Worker 5: Train Loss: 2.7091, Train Accuracy: 31.66%
#     Worker 6: Train Loss: 2.7729, Train Accuracy: 30.34%
#     Worker 7: Train Loss: 2.7233, Train Accuracy: 31.17%
# Epoch 25/150: Test Loss: 2.5877, Test Accuracy: 34.30%
#     Worker 0: Train Loss: 2.7122, Train Accuracy: 31.56%
#     Worker 1: Train Loss: 2.6854, Train Accuracy: 31.22%
#     Worker 2: Train Loss: 2.6903, Train Accuracy: 32.64%
#     Worker 3: Train Loss: 2.7418, Train Accuracy: 29.84%
#     Worker 4: Train Loss: 2.6327, Train Accuracy: 32.72%
#     Worker 5: Train Loss: 2.6504, Train Accuracy: 33.10%
#     Worker 6: Train Loss: 2.7385, Train Accuracy: 30.56%
#     Worker 7: Train Loss: 2.6997, Train Accuracy: 31.26%
# Epoch 26/150: Test Loss: 2.5261, Test Accuracy: 35.74%
#     Worker 0: Train Loss: 2.7017, Train Accuracy: 32.05%
#     Worker 1: Train Loss: 2.6111, Train Accuracy: 33.30%
#     Worker 2: Train Loss: 2.6587, Train Accuracy: 32.80%
#     Worker 3: Train Loss: 2.6559, Train Accuracy: 33.02%
#     Worker 4: Train Loss: 2.6364, Train Accuracy: 32.99%
#     Worker 5: Train Loss: 2.6329, Train Accuracy: 32.99%
#     Worker 6: Train Loss: 2.6741, Train Accuracy: 32.25%
#     Worker 7: Train Loss: 2.6293, Train Accuracy: 32.75%
# Epoch 27/150: Test Loss: 2.5170, Test Accuracy: 36.31%
#     Worker 0: Train Loss: 2.6043, Train Accuracy: 32.60%
#     Worker 1: Train Loss: 2.6021, Train Accuracy: 33.51%
#     Worker 2: Train Loss: 2.6252, Train Accuracy: 33.62%
#     Worker 3: Train Loss: 2.6644, Train Accuracy: 32.57%
#     Worker 4: Train Loss: 2.5785, Train Accuracy: 33.96%
#     Worker 5: Train Loss: 2.5718, Train Accuracy: 35.31%
#     Worker 6: Train Loss: 2.6532, Train Accuracy: 32.77%
#     Worker 7: Train Loss: 2.6111, Train Accuracy: 33.65%
# Epoch 28/150: Test Loss: 2.4945, Test Accuracy: 36.61%
#     Worker 0: Train Loss: 2.6131, Train Accuracy: 33.04%
#     Worker 1: Train Loss: 2.5852, Train Accuracy: 33.98%
#     Worker 2: Train Loss: 2.5880, Train Accuracy: 34.24%
#     Worker 3: Train Loss: 2.6202, Train Accuracy: 33.13%
#     Worker 4: Train Loss: 2.5705, Train Accuracy: 33.91%
#     Worker 5: Train Loss: 2.5573, Train Accuracy: 34.21%
#     Worker 6: Train Loss: 2.5793, Train Accuracy: 33.29%
#     Worker 7: Train Loss: 2.6038, Train Accuracy: 34.04%
# Epoch 29/150: Test Loss: 2.4945, Test Accuracy: 37.01%
#     Worker 0: Train Loss: 2.5499, Train Accuracy: 34.65%
#     Worker 1: Train Loss: 2.5257, Train Accuracy: 35.17%
#     Worker 2: Train Loss: 2.5521, Train Accuracy: 34.49%
#     Worker 3: Train Loss: 2.5522, Train Accuracy: 34.29%
#     Worker 4: Train Loss: 2.5436, Train Accuracy: 34.90%
#     Worker 5: Train Loss: 2.4977, Train Accuracy: 35.92%
#     Worker 6: Train Loss: 2.5653, Train Accuracy: 34.26%
#     Worker 7: Train Loss: 2.5182, Train Accuracy: 35.29%
# Epoch 30/150: Test Loss: 2.4221, Test Accuracy: 37.90%
#     Worker 0: Train Loss: 2.5502, Train Accuracy: 34.62%
#     Worker 1: Train Loss: 2.4803, Train Accuracy: 36.19%
#     Worker 2: Train Loss: 2.5299, Train Accuracy: 35.37%
#     Worker 3: Train Loss: 2.5519, Train Accuracy: 33.87%
#     Worker 4: Train Loss: 2.5218, Train Accuracy: 35.25%
#     Worker 5: Train Loss: 2.4850, Train Accuracy: 36.85%
#     Worker 6: Train Loss: 2.5418, Train Accuracy: 35.65%
#     Worker 7: Train Loss: 2.5264, Train Accuracy: 35.01%
# Epoch 31/150: Test Loss: 2.4069, Test Accuracy: 38.72%
#     Worker 0: Train Loss: 2.4836, Train Accuracy: 36.66%
#     Worker 1: Train Loss: 2.4550, Train Accuracy: 36.99%
#     Worker 2: Train Loss: 2.4653, Train Accuracy: 36.27%
#     Worker 3: Train Loss: 2.5392, Train Accuracy: 34.92%
#     Worker 4: Train Loss: 2.4198, Train Accuracy: 37.05%
#     Worker 5: Train Loss: 2.4209, Train Accuracy: 37.06%
#     Worker 6: Train Loss: 2.4676, Train Accuracy: 35.72%
#     Worker 7: Train Loss: 2.4856, Train Accuracy: 35.94%
# Epoch 32/150: Test Loss: 2.4100, Test Accuracy: 38.13%
#     Worker 0: Train Loss: 2.4685, Train Accuracy: 35.98%
#     Worker 1: Train Loss: 2.4612, Train Accuracy: 36.38%
#     Worker 2: Train Loss: 2.4503, Train Accuracy: 36.16%
#     Worker 3: Train Loss: 2.4654, Train Accuracy: 35.51%
#     Worker 4: Train Loss: 2.4290, Train Accuracy: 36.96%
#     Worker 5: Train Loss: 2.4338, Train Accuracy: 37.39%
#     Worker 6: Train Loss: 2.4800, Train Accuracy: 35.98%
#     Worker 7: Train Loss: 2.4498, Train Accuracy: 35.98%
# Epoch 33/150: Test Loss: 2.3554, Test Accuracy: 39.85%
#     Worker 0: Train Loss: 2.4464, Train Accuracy: 37.06%
#     Worker 1: Train Loss: 2.3889, Train Accuracy: 36.77%
#     Worker 2: Train Loss: 2.4454, Train Accuracy: 36.96%
#     Worker 3: Train Loss: 2.4158, Train Accuracy: 36.67%
#     Worker 4: Train Loss: 2.3698, Train Accuracy: 38.26%
#     Worker 5: Train Loss: 2.3769, Train Accuracy: 38.13%
#     Worker 6: Train Loss: 2.4478, Train Accuracy: 36.78%
#     Worker 7: Train Loss: 2.4135, Train Accuracy: 37.71%
# Epoch 34/150: Test Loss: 2.3483, Test Accuracy: 39.68%
#     Worker 0: Train Loss: 2.4185, Train Accuracy: 37.43%
#     Worker 1: Train Loss: 2.3599, Train Accuracy: 38.30%
#     Worker 2: Train Loss: 2.3690, Train Accuracy: 38.84%
#     Worker 3: Train Loss: 2.4051, Train Accuracy: 37.86%
#     Worker 4: Train Loss: 2.3582, Train Accuracy: 38.57%
#     Worker 5: Train Loss: 2.4114, Train Accuracy: 38.27%
#     Worker 6: Train Loss: 2.3919, Train Accuracy: 37.30%
#     Worker 7: Train Loss: 2.4000, Train Accuracy: 38.16%
# Epoch 35/150: Test Loss: 2.3158, Test Accuracy: 40.28%
#     Worker 0: Train Loss: 2.3662, Train Accuracy: 37.88%
#     Worker 1: Train Loss: 2.3398, Train Accuracy: 39.15%
#     Worker 2: Train Loss: 2.3743, Train Accuracy: 38.43%
#     Worker 3: Train Loss: 2.3991, Train Accuracy: 37.08%
#     Worker 4: Train Loss: 2.3442, Train Accuracy: 39.31%
#     Worker 5: Train Loss: 2.3351, Train Accuracy: 39.10%
#     Worker 6: Train Loss: 2.3866, Train Accuracy: 38.43%
#     Worker 7: Train Loss: 2.3427, Train Accuracy: 39.28%
# Epoch 36/150: Test Loss: 2.3103, Test Accuracy: 40.38%
#     Worker 0: Train Loss: 2.3494, Train Accuracy: 38.55%
#     Worker 1: Train Loss: 2.3182, Train Accuracy: 39.07%
#     Worker 2: Train Loss: 2.3248, Train Accuracy: 38.90%
#     Worker 3: Train Loss: 2.3405, Train Accuracy: 38.24%
#     Worker 4: Train Loss: 2.3433, Train Accuracy: 38.84%
#     Worker 5: Train Loss: 2.3231, Train Accuracy: 39.82%
#     Worker 6: Train Loss: 2.3722, Train Accuracy: 38.19%
#     Worker 7: Train Loss: 2.3365, Train Accuracy: 38.84%
# Epoch 37/150: Test Loss: 2.2713, Test Accuracy: 41.57%
#     Worker 0: Train Loss: 2.3378, Train Accuracy: 38.76%
#     Worker 1: Train Loss: 2.2867, Train Accuracy: 39.98%
#     Worker 2: Train Loss: 2.3202, Train Accuracy: 39.06%
#     Worker 3: Train Loss: 2.3237, Train Accuracy: 39.48%
#     Worker 4: Train Loss: 2.2788, Train Accuracy: 41.16%
#     Worker 5: Train Loss: 2.2766, Train Accuracy: 40.87%
#     Worker 6: Train Loss: 2.3134, Train Accuracy: 39.84%
#     Worker 7: Train Loss: 2.3121, Train Accuracy: 39.29%
# Epoch 38/150: Test Loss: 2.2964, Test Accuracy: 40.63%
#     Worker 0: Train Loss: 2.3150, Train Accuracy: 39.92%
#     Worker 1: Train Loss: 2.2877, Train Accuracy: 40.37%
#     Worker 2: Train Loss: 2.2810, Train Accuracy: 39.87%
#     Worker 3: Train Loss: 2.3386, Train Accuracy: 39.42%
#     Worker 4: Train Loss: 2.2453, Train Accuracy: 41.82%
#     Worker 5: Train Loss: 2.2552, Train Accuracy: 40.62%
#     Worker 6: Train Loss: 2.3208, Train Accuracy: 39.70%
#     Worker 7: Train Loss: 2.2787, Train Accuracy: 40.08%
# Epoch 39/150: Test Loss: 2.2504, Test Accuracy: 42.19%
#     Worker 0: Train Loss: 2.2633, Train Accuracy: 40.62%
#     Worker 1: Train Loss: 2.2378, Train Accuracy: 40.70%
#     Worker 2: Train Loss: 2.2576, Train Accuracy: 40.87%
#     Worker 3: Train Loss: 2.2757, Train Accuracy: 40.00%
#     Worker 4: Train Loss: 2.2231, Train Accuracy: 41.56%
#     Worker 5: Train Loss: 2.2589, Train Accuracy: 41.56%
#     Worker 6: Train Loss: 2.2919, Train Accuracy: 40.50%
#     Worker 7: Train Loss: 2.2584, Train Accuracy: 40.64%
# Epoch 40/150: Test Loss: 2.2345, Test Accuracy: 42.44%
#     Worker 0: Train Loss: 2.2457, Train Accuracy: 40.91%
#     Worker 1: Train Loss: 2.2280, Train Accuracy: 41.14%
#     Worker 2: Train Loss: 2.2302, Train Accuracy: 41.78%
#     Worker 3: Train Loss: 2.2439, Train Accuracy: 40.53%
#     Worker 4: Train Loss: 2.2023, Train Accuracy: 42.24%
#     Worker 5: Train Loss: 2.2187, Train Accuracy: 42.05%
#     Worker 6: Train Loss: 2.2685, Train Accuracy: 40.80%
#     Worker 7: Train Loss: 2.2242, Train Accuracy: 41.67%
# Epoch 41/150: Test Loss: 2.2149, Test Accuracy: 42.51%
#     Worker 0: Train Loss: 2.2530, Train Accuracy: 40.51%
#     Worker 1: Train Loss: 2.1921, Train Accuracy: 41.88%
#     Worker 2: Train Loss: 2.1848, Train Accuracy: 42.33%
#     Worker 3: Train Loss: 2.2339, Train Accuracy: 41.94%
#     Worker 4: Train Loss: 2.1650, Train Accuracy: 42.63%
#     Worker 5: Train Loss: 2.2093, Train Accuracy: 42.08%
#     Worker 6: Train Loss: 2.2014, Train Accuracy: 42.05%
#     Worker 7: Train Loss: 2.2101, Train Accuracy: 41.72%
# Epoch 42/150: Test Loss: 2.2139, Test Accuracy: 42.66%
#     Worker 0: Train Loss: 2.1919, Train Accuracy: 42.02%
#     Worker 1: Train Loss: 2.1739, Train Accuracy: 42.54%
#     Worker 2: Train Loss: 2.1987, Train Accuracy: 41.33%
#     Worker 3: Train Loss: 2.2358, Train Accuracy: 41.06%
#     Worker 4: Train Loss: 2.1865, Train Accuracy: 43.09%
#     Worker 5: Train Loss: 2.1528, Train Accuracy: 44.36%
#     Worker 6: Train Loss: 2.2155, Train Accuracy: 41.74%
#     Worker 7: Train Loss: 2.2018, Train Accuracy: 41.97%
# Epoch 43/150: Test Loss: 2.2026, Test Accuracy: 43.04%
#     Worker 0: Train Loss: 2.1925, Train Accuracy: 42.27%
#     Worker 1: Train Loss: 2.1559, Train Accuracy: 42.71%
#     Worker 2: Train Loss: 2.1588, Train Accuracy: 43.12%
#     Worker 3: Train Loss: 2.1829, Train Accuracy: 42.16%
#     Worker 4: Train Loss: 2.1369, Train Accuracy: 43.18%
#     Worker 5: Train Loss: 2.1356, Train Accuracy: 44.03%
#     Worker 6: Train Loss: 2.1900, Train Accuracy: 43.01%
#     Worker 7: Train Loss: 2.1522, Train Accuracy: 42.77%
# Epoch 44/150: Test Loss: 2.1976, Test Accuracy: 42.70%
#     Worker 0: Train Loss: 2.1547, Train Accuracy: 43.67%
#     Worker 1: Train Loss: 2.1522, Train Accuracy: 43.04%
#     Worker 2: Train Loss: 2.1374, Train Accuracy: 43.96%
#     Worker 3: Train Loss: 2.1819, Train Accuracy: 43.09%
#     Worker 4: Train Loss: 2.1215, Train Accuracy: 43.74%
#     Worker 5: Train Loss: 2.1156, Train Accuracy: 44.56%
#     Worker 6: Train Loss: 2.1473, Train Accuracy: 43.51%
#     Worker 7: Train Loss: 2.1257, Train Accuracy: 43.43%
# Epoch 45/150: Test Loss: 2.1793, Test Accuracy: 43.45%
#     Worker 0: Train Loss: 2.1305, Train Accuracy: 42.76%
#     Worker 1: Train Loss: 2.1085, Train Accuracy: 43.09%
#     Worker 2: Train Loss: 2.1230, Train Accuracy: 43.59%
#     Worker 3: Train Loss: 2.1385, Train Accuracy: 43.04%
#     Worker 4: Train Loss: 2.1258, Train Accuracy: 43.76%
#     Worker 5: Train Loss: 2.1203, Train Accuracy: 44.42%
#     Worker 6: Train Loss: 2.1739, Train Accuracy: 43.37%
#     Worker 7: Train Loss: 2.1367, Train Accuracy: 43.76%
# Epoch 46/150: Test Loss: 2.1820, Test Accuracy: 43.68%
#     Worker 0: Train Loss: 2.1245, Train Accuracy: 43.24%
#     Worker 1: Train Loss: 2.0990, Train Accuracy: 43.92%
#     Worker 2: Train Loss: 2.0916, Train Accuracy: 44.53%
#     Worker 3: Train Loss: 2.1297, Train Accuracy: 42.80%
#     Worker 4: Train Loss: 2.0634, Train Accuracy: 45.28%
#     Worker 5: Train Loss: 2.0714, Train Accuracy: 44.84%
#     Worker 6: Train Loss: 2.1238, Train Accuracy: 43.96%
#     Worker 7: Train Loss: 2.0971, Train Accuracy: 44.54%
# Epoch 47/150: Test Loss: 2.1523, Test Accuracy: 44.47%
#     Worker 0: Train Loss: 2.1078, Train Accuracy: 43.74%
#     Worker 1: Train Loss: 2.0790, Train Accuracy: 44.62%
#     Worker 2: Train Loss: 2.0846, Train Accuracy: 45.20%
#     Worker 3: Train Loss: 2.0976, Train Accuracy: 44.07%
#     Worker 4: Train Loss: 2.0805, Train Accuracy: 44.79%
#     Worker 5: Train Loss: 2.0774, Train Accuracy: 44.59%
#     Worker 6: Train Loss: 2.1085, Train Accuracy: 43.73%
#     Worker 7: Train Loss: 2.0895, Train Accuracy: 44.47%
# Epoch 48/150: Test Loss: 2.1419, Test Accuracy: 44.27%
#     Worker 0: Train Loss: 2.0896, Train Accuracy: 43.89%
#     Worker 1: Train Loss: 2.0609, Train Accuracy: 45.08%
#     Worker 2: Train Loss: 2.0386, Train Accuracy: 44.67%
#     Worker 3: Train Loss: 2.0923, Train Accuracy: 44.40%
#     Worker 4: Train Loss: 2.0391, Train Accuracy: 45.70%
#     Worker 5: Train Loss: 2.0714, Train Accuracy: 45.61%
#     Worker 6: Train Loss: 2.1050, Train Accuracy: 44.34%
#     Worker 7: Train Loss: 2.0704, Train Accuracy: 44.81%
# Epoch 49/150: Test Loss: 2.1293, Test Accuracy: 44.83%
#     Worker 0: Train Loss: 2.0643, Train Accuracy: 44.79%
#     Worker 1: Train Loss: 2.0357, Train Accuracy: 45.37%
#     Worker 2: Train Loss: 2.0458, Train Accuracy: 45.48%
#     Worker 3: Train Loss: 2.0650, Train Accuracy: 44.90%
#     Worker 4: Train Loss: 2.0274, Train Accuracy: 45.28%
#     Worker 5: Train Loss: 2.0229, Train Accuracy: 45.63%
#     Worker 6: Train Loss: 2.0662, Train Accuracy: 44.43%
#     Worker 7: Train Loss: 2.0481, Train Accuracy: 46.02%
# Epoch 50/150: Test Loss: 2.1376, Test Accuracy: 45.03%
#     Worker 0: Train Loss: 2.0388, Train Accuracy: 45.16%
#     Worker 1: Train Loss: 2.0024, Train Accuracy: 46.06%
#     Worker 2: Train Loss: 2.0168, Train Accuracy: 46.28%
#     Worker 3: Train Loss: 2.0458, Train Accuracy: 45.05%
#     Worker 4: Train Loss: 2.0101, Train Accuracy: 45.94%
#     Worker 5: Train Loss: 2.0110, Train Accuracy: 46.25%
#     Worker 6: Train Loss: 2.0470, Train Accuracy: 46.02%
#     Worker 7: Train Loss: 2.0385, Train Accuracy: 45.55%
# Epoch 51/150: Test Loss: 2.1263, Test Accuracy: 45.36%
#     Worker 0: Train Loss: 2.0299, Train Accuracy: 45.17%
#     Worker 1: Train Loss: 2.0134, Train Accuracy: 46.47%
#     Worker 2: Train Loss: 1.9998, Train Accuracy: 46.11%
#     Worker 3: Train Loss: 2.0241, Train Accuracy: 45.74%
#     Worker 4: Train Loss: 1.9855, Train Accuracy: 46.58%
#     Worker 5: Train Loss: 1.9858, Train Accuracy: 47.66%
#     Worker 6: Train Loss: 2.0380, Train Accuracy: 45.50%
#     Worker 7: Train Loss: 2.0068, Train Accuracy: 46.47%
# Epoch 52/150: Test Loss: 2.1131, Test Accuracy: 45.23%
#     Worker 0: Train Loss: 2.0165, Train Accuracy: 45.75%
#     Worker 1: Train Loss: 1.9829, Train Accuracy: 46.47%
#     Worker 2: Train Loss: 1.9881, Train Accuracy: 45.78%
#     Worker 3: Train Loss: 2.0069, Train Accuracy: 46.28%
#     Worker 4: Train Loss: 1.9502, Train Accuracy: 47.63%
#     Worker 5: Train Loss: 1.9714, Train Accuracy: 47.93%
#     Worker 6: Train Loss: 1.9971, Train Accuracy: 46.52%
#     Worker 7: Train Loss: 2.0009, Train Accuracy: 46.21%
# Epoch 53/150: Test Loss: 2.1081, Test Accuracy: 45.33%
#     Worker 0: Train Loss: 1.9932, Train Accuracy: 46.50%
#     Worker 1: Train Loss: 1.9523, Train Accuracy: 47.08%
#     Worker 2: Train Loss: 1.9610, Train Accuracy: 47.51%
#     Worker 3: Train Loss: 1.9974, Train Accuracy: 46.79%
#     Worker 4: Train Loss: 1.9442, Train Accuracy: 47.26%
#     Worker 5: Train Loss: 1.9858, Train Accuracy: 47.57%
#     Worker 6: Train Loss: 1.9990, Train Accuracy: 47.26%
#     Worker 7: Train Loss: 1.9539, Train Accuracy: 47.40%
# Epoch 54/150: Test Loss: 2.0903, Test Accuracy: 45.98%
#     Worker 0: Train Loss: 1.9815, Train Accuracy: 46.61%
#     Worker 1: Train Loss: 1.9686, Train Accuracy: 46.39%
#     Worker 2: Train Loss: 1.9250, Train Accuracy: 48.13%
#     Worker 3: Train Loss: 1.9757, Train Accuracy: 47.13%
#     Worker 4: Train Loss: 1.9230, Train Accuracy: 48.43%
#     Worker 5: Train Loss: 1.9417, Train Accuracy: 48.29%
#     Worker 6: Train Loss: 2.0040, Train Accuracy: 47.12%
#     Worker 7: Train Loss: 1.9505, Train Accuracy: 47.48%
# Epoch 55/150: Test Loss: 2.0851, Test Accuracy: 45.90%
#     Worker 0: Train Loss: 1.9478, Train Accuracy: 47.76%
#     Worker 1: Train Loss: 1.9412, Train Accuracy: 47.52%
#     Worker 2: Train Loss: 1.9326, Train Accuracy: 47.96%
#     Worker 3: Train Loss: 1.9697, Train Accuracy: 46.71%
#     Worker 4: Train Loss: 1.9445, Train Accuracy: 46.93%
#     Worker 5: Train Loss: 1.9216, Train Accuracy: 48.86%
#     Worker 6: Train Loss: 1.9673, Train Accuracy: 47.21%
#     Worker 7: Train Loss: 1.9511, Train Accuracy: 47.88%
# Epoch 56/150: Test Loss: 2.0869, Test Accuracy: 45.47%
#     Worker 0: Train Loss: 1.9234, Train Accuracy: 47.98%
#     Worker 1: Train Loss: 1.9100, Train Accuracy: 48.07%
#     Worker 2: Train Loss: 1.9220, Train Accuracy: 48.17%
#     Worker 3: Train Loss: 1.9619, Train Accuracy: 47.18%
#     Worker 4: Train Loss: 1.9034, Train Accuracy: 49.17%
#     Worker 5: Train Loss: 1.8950, Train Accuracy: 48.78%
#     Worker 6: Train Loss: 1.9506, Train Accuracy: 47.65%
#     Worker 7: Train Loss: 1.9168, Train Accuracy: 48.78%
# Epoch 57/150: Test Loss: 2.0742, Test Accuracy: 46.11%
#     Worker 0: Train Loss: 1.9165, Train Accuracy: 48.21%
#     Worker 1: Train Loss: 1.9117, Train Accuracy: 48.39%
#     Worker 2: Train Loss: 1.8982, Train Accuracy: 49.25%
#     Worker 3: Train Loss: 1.9360, Train Accuracy: 47.88%
#     Worker 4: Train Loss: 1.8944, Train Accuracy: 48.86%
#     Worker 5: Train Loss: 1.9191, Train Accuracy: 47.90%
#     Worker 6: Train Loss: 1.9306, Train Accuracy: 48.49%
#     Worker 7: Train Loss: 1.9056, Train Accuracy: 48.84%
# Epoch 58/150: Test Loss: 2.0781, Test Accuracy: 46.25%
#     Worker 0: Train Loss: 1.8984, Train Accuracy: 48.18%
#     Worker 1: Train Loss: 1.8763, Train Accuracy: 49.20%
#     Worker 2: Train Loss: 1.8873, Train Accuracy: 49.34%
#     Worker 3: Train Loss: 1.9067, Train Accuracy: 48.21%
#     Worker 4: Train Loss: 1.8756, Train Accuracy: 49.09%
#     Worker 5: Train Loss: 1.8859, Train Accuracy: 49.31%
#     Worker 6: Train Loss: 1.9150, Train Accuracy: 48.46%
#     Worker 7: Train Loss: 1.8864, Train Accuracy: 49.31%
# Epoch 59/150: Test Loss: 2.0778, Test Accuracy: 45.80%
#     Worker 0: Train Loss: 1.8886, Train Accuracy: 48.53%
#     Worker 1: Train Loss: 1.8747, Train Accuracy: 48.95%
#     Worker 2: Train Loss: 1.8514, Train Accuracy: 49.59%
#     Worker 3: Train Loss: 1.8740, Train Accuracy: 49.36%
#     Worker 4: Train Loss: 1.8361, Train Accuracy: 49.64%
#     Worker 5: Train Loss: 1.8588, Train Accuracy: 49.76%
#     Worker 6: Train Loss: 1.8844, Train Accuracy: 49.37%
#     Worker 7: Train Loss: 1.8669, Train Accuracy: 49.50%
# Epoch 60/150: Test Loss: 2.0822, Test Accuracy: 46.12%
#     Worker 0: Train Loss: 1.8866, Train Accuracy: 49.53%
#     Worker 1: Train Loss: 1.8399, Train Accuracy: 50.86%
#     Worker 2: Train Loss: 1.8760, Train Accuracy: 49.97%
#     Worker 3: Train Loss: 1.8683, Train Accuracy: 49.53%
#     Worker 4: Train Loss: 1.8349, Train Accuracy: 49.78%
#     Worker 5: Train Loss: 1.8530, Train Accuracy: 50.08%
#     Worker 6: Train Loss: 1.8816, Train Accuracy: 49.44%
#     Worker 7: Train Loss: 1.8640, Train Accuracy: 49.83%
# Epoch 61/150: Test Loss: 2.0475, Test Accuracy: 47.39%
#     Worker 0: Train Loss: 1.8684, Train Accuracy: 49.39%
#     Worker 1: Train Loss: 1.8155, Train Accuracy: 50.67%
#     Worker 2: Train Loss: 1.8096, Train Accuracy: 50.94%
#     Worker 3: Train Loss: 1.8646, Train Accuracy: 49.23%
#     Worker 4: Train Loss: 1.8347, Train Accuracy: 49.86%
#     Worker 5: Train Loss: 1.8535, Train Accuracy: 50.45%
#     Worker 6: Train Loss: 1.8623, Train Accuracy: 50.14%
#     Worker 7: Train Loss: 1.8138, Train Accuracy: 50.89%
# Epoch 62/150: Test Loss: 2.0645, Test Accuracy: 46.69%
#     Worker 0: Train Loss: 1.8191, Train Accuracy: 50.42%
#     Worker 1: Train Loss: 1.7923, Train Accuracy: 50.09%
#     Worker 2: Train Loss: 1.8348, Train Accuracy: 50.67%
#     Worker 3: Train Loss: 1.8476, Train Accuracy: 50.08%
#     Worker 4: Train Loss: 1.8000, Train Accuracy: 50.74%
#     Worker 5: Train Loss: 1.8155, Train Accuracy: 50.74%
#     Worker 6: Train Loss: 1.8442, Train Accuracy: 50.88%
#     Worker 7: Train Loss: 1.8183, Train Accuracy: 50.31%
# Epoch 63/150: Test Loss: 2.0622, Test Accuracy: 46.62%
#     Worker 0: Train Loss: 1.8301, Train Accuracy: 50.09%
#     Worker 1: Train Loss: 1.8135, Train Accuracy: 50.30%
#     Worker 2: Train Loss: 1.8107, Train Accuracy: 50.39%
#     Worker 3: Train Loss: 1.8125, Train Accuracy: 51.00%
#     Worker 4: Train Loss: 1.7622, Train Accuracy: 51.22%
#     Worker 5: Train Loss: 1.8203, Train Accuracy: 49.92%
#     Worker 6: Train Loss: 1.8473, Train Accuracy: 50.13%
#     Worker 7: Train Loss: 1.8207, Train Accuracy: 50.78%
# Epoch 64/150: Test Loss: 2.0546, Test Accuracy: 46.67%
#     Worker 0: Train Loss: 1.8362, Train Accuracy: 49.75%
#     Worker 1: Train Loss: 1.7857, Train Accuracy: 51.16%
#     Worker 2: Train Loss: 1.7821, Train Accuracy: 51.91%
#     Worker 3: Train Loss: 1.8401, Train Accuracy: 49.56%
#     Worker 4: Train Loss: 1.7942, Train Accuracy: 51.35%
#     Worker 5: Train Loss: 1.7838, Train Accuracy: 51.80%
#     Worker 6: Train Loss: 1.8201, Train Accuracy: 50.55%
#     Worker 7: Train Loss: 1.8231, Train Accuracy: 50.77%
# Epoch 65/150: Test Loss: 2.0447, Test Accuracy: 47.08%
#     Worker 0: Train Loss: 1.7751, Train Accuracy: 51.24%
#     Worker 1: Train Loss: 1.7929, Train Accuracy: 50.63%
#     Worker 2: Train Loss: 1.7870, Train Accuracy: 51.55%
#     Worker 3: Train Loss: 1.8064, Train Accuracy: 50.16%
#     Worker 4: Train Loss: 1.8076, Train Accuracy: 51.21%
#     Worker 5: Train Loss: 1.7989, Train Accuracy: 51.19%
#     Worker 6: Train Loss: 1.8168, Train Accuracy: 50.56%
#     Worker 7: Train Loss: 1.7732, Train Accuracy: 52.41%
# Epoch 66/150: Test Loss: 2.0440, Test Accuracy: 47.07%
#     Worker 0: Train Loss: 1.7830, Train Accuracy: 51.36%
#     Worker 1: Train Loss: 1.7562, Train Accuracy: 51.52%
#     Worker 2: Train Loss: 1.7494, Train Accuracy: 52.62%
#     Worker 3: Train Loss: 1.8022, Train Accuracy: 50.99%
#     Worker 4: Train Loss: 1.7114, Train Accuracy: 52.81%
#     Worker 5: Train Loss: 1.7513, Train Accuracy: 52.26%
#     Worker 6: Train Loss: 1.7978, Train Accuracy: 51.51%
#     Worker 7: Train Loss: 1.7787, Train Accuracy: 51.54%
# Epoch 67/150: Test Loss: 2.0433, Test Accuracy: 47.29%
#     Worker 0: Train Loss: 1.7707, Train Accuracy: 51.79%
#     Worker 1: Train Loss: 1.7505, Train Accuracy: 51.27%
#     Worker 2: Train Loss: 1.7942, Train Accuracy: 50.88%
#     Worker 3: Train Loss: 1.7682, Train Accuracy: 51.55%
#     Worker 4: Train Loss: 1.7481, Train Accuracy: 51.93%
#     Worker 5: Train Loss: 1.7438, Train Accuracy: 52.13%
#     Worker 6: Train Loss: 1.7752, Train Accuracy: 51.80%
#     Worker 7: Train Loss: 1.7582, Train Accuracy: 51.87%
# Epoch 68/150: Test Loss: 2.0203, Test Accuracy: 47.43%
#     Worker 0: Train Loss: 1.7607, Train Accuracy: 50.88%
#     Worker 1: Train Loss: 1.7354, Train Accuracy: 52.60%
#     Worker 2: Train Loss: 1.7323, Train Accuracy: 52.45%
#     Worker 3: Train Loss: 1.7805, Train Accuracy: 51.10%
#     Worker 4: Train Loss: 1.7129, Train Accuracy: 52.93%
#     Worker 5: Train Loss: 1.7399, Train Accuracy: 52.32%
#     Worker 6: Train Loss: 1.7813, Train Accuracy: 51.29%
#     Worker 7: Train Loss: 1.7572, Train Accuracy: 52.54%
# Epoch 69/150: Test Loss: 2.0222, Test Accuracy: 47.37%
#     Worker 0: Train Loss: 1.7235, Train Accuracy: 52.52%
#     Worker 1: Train Loss: 1.7051, Train Accuracy: 52.65%
#     Worker 2: Train Loss: 1.6924, Train Accuracy: 54.05%
#     Worker 3: Train Loss: 1.7488, Train Accuracy: 51.69%
#     Worker 4: Train Loss: 1.7195, Train Accuracy: 52.67%
#     Worker 5: Train Loss: 1.7159, Train Accuracy: 53.62%
#     Worker 6: Train Loss: 1.7600, Train Accuracy: 52.01%
#     Worker 7: Train Loss: 1.7156, Train Accuracy: 53.43%
# Epoch 70/150: Test Loss: 2.0151, Test Accuracy: 47.99%
#     Worker 0: Train Loss: 1.7561, Train Accuracy: 52.18%
#     Worker 1: Train Loss: 1.6985, Train Accuracy: 52.73%
#     Worker 2: Train Loss: 1.7084, Train Accuracy: 53.07%
#     Worker 3: Train Loss: 1.7677, Train Accuracy: 51.61%
#     Worker 4: Train Loss: 1.6917, Train Accuracy: 52.48%
#     Worker 5: Train Loss: 1.7251, Train Accuracy: 53.31%
#     Worker 6: Train Loss: 1.7317, Train Accuracy: 53.01%
#     Worker 7: Train Loss: 1.7061, Train Accuracy: 53.21%
# Epoch 71/150: Test Loss: 2.0333, Test Accuracy: 47.35%
#     Worker 0: Train Loss: 1.7063, Train Accuracy: 52.32%
#     Worker 1: Train Loss: 1.6836, Train Accuracy: 52.60%
#     Worker 2: Train Loss: 1.6999, Train Accuracy: 53.81%
#     Worker 3: Train Loss: 1.7325, Train Accuracy: 52.26%
#     Worker 4: Train Loss: 1.6906, Train Accuracy: 53.21%
#     Worker 5: Train Loss: 1.6830, Train Accuracy: 53.94%
#     Worker 6: Train Loss: 1.7370, Train Accuracy: 53.14%
#     Worker 7: Train Loss: 1.7034, Train Accuracy: 54.05%
# Epoch 72/150: Test Loss: 2.0076, Test Accuracy: 47.89%
#     Worker 0: Train Loss: 1.7279, Train Accuracy: 52.81%
#     Worker 1: Train Loss: 1.6705, Train Accuracy: 53.98%
#     Worker 2: Train Loss: 1.6993, Train Accuracy: 53.83%
#     Worker 3: Train Loss: 1.7320, Train Accuracy: 51.99%
#     Worker 4: Train Loss: 1.6764, Train Accuracy: 53.47%
#     Worker 5: Train Loss: 1.6802, Train Accuracy: 53.43%
#     Worker 6: Train Loss: 1.7226, Train Accuracy: 52.32%
#     Worker 7: Train Loss: 1.6946, Train Accuracy: 53.61%
# Epoch 73/150: Test Loss: 2.0086, Test Accuracy: 47.98%
#     Worker 0: Train Loss: 1.6809, Train Accuracy: 53.47%
#     Worker 1: Train Loss: 1.6820, Train Accuracy: 53.79%
#     Worker 2: Train Loss: 1.6539, Train Accuracy: 54.72%
#     Worker 3: Train Loss: 1.6989, Train Accuracy: 53.06%
#     Worker 4: Train Loss: 1.6684, Train Accuracy: 53.95%
#     Worker 5: Train Loss: 1.6656, Train Accuracy: 54.19%
#     Worker 6: Train Loss: 1.7052, Train Accuracy: 52.88%
#     Worker 7: Train Loss: 1.6774, Train Accuracy: 53.54%
# Epoch 74/150: Test Loss: 2.0025, Test Accuracy: 48.03%
#     Worker 0: Train Loss: 1.6838, Train Accuracy: 53.07%
#     Worker 1: Train Loss: 1.6413, Train Accuracy: 54.80%
#     Worker 2: Train Loss: 1.6646, Train Accuracy: 54.83%
#     Worker 3: Train Loss: 1.6700, Train Accuracy: 54.03%
#     Worker 4: Train Loss: 1.6591, Train Accuracy: 54.41%
#     Worker 5: Train Loss: 1.6403, Train Accuracy: 54.55%
#     Worker 6: Train Loss: 1.6841, Train Accuracy: 54.14%
#     Worker 7: Train Loss: 1.6517, Train Accuracy: 54.45%
# Epoch 75/150: Test Loss: 2.0027, Test Accuracy: 48.17%
#     Worker 0: Train Loss: 1.6744, Train Accuracy: 54.03%
#     Worker 1: Train Loss: 1.6458, Train Accuracy: 54.44%
#     Worker 2: Train Loss: 1.6196, Train Accuracy: 55.11%
#     Worker 3: Train Loss: 1.6704, Train Accuracy: 53.36%
#     Worker 4: Train Loss: 1.6279, Train Accuracy: 54.70%
#     Worker 5: Train Loss: 1.6722, Train Accuracy: 54.23%
#     Worker 6: Train Loss: 1.6716, Train Accuracy: 54.30%
#     Worker 7: Train Loss: 1.6421, Train Accuracy: 55.49%
# Epoch 76/150: Test Loss: 2.0070, Test Accuracy: 48.18%
#     Worker 0: Train Loss: 1.6431, Train Accuracy: 54.58%
#     Worker 1: Train Loss: 1.6440, Train Accuracy: 54.20%
#     Worker 2: Train Loss: 1.6305, Train Accuracy: 55.44%
#     Worker 3: Train Loss: 1.6624, Train Accuracy: 53.73%
#     Worker 4: Train Loss: 1.6411, Train Accuracy: 54.39%
#     Worker 5: Train Loss: 1.6421, Train Accuracy: 54.63%
#     Worker 6: Train Loss: 1.6767, Train Accuracy: 54.63%
#     Worker 7: Train Loss: 1.6410, Train Accuracy: 54.97%
# Epoch 77/150: Test Loss: 2.0027, Test Accuracy: 48.43%
#     Worker 0: Train Loss: 1.6693, Train Accuracy: 53.94%
#     Worker 1: Train Loss: 1.6399, Train Accuracy: 55.60%
#     Worker 2: Train Loss: 1.6299, Train Accuracy: 54.94%
#     Worker 3: Train Loss: 1.6461, Train Accuracy: 54.19%
#     Worker 4: Train Loss: 1.6127, Train Accuracy: 55.13%
#     Worker 5: Train Loss: 1.6182, Train Accuracy: 55.71%
#     Worker 6: Train Loss: 1.6782, Train Accuracy: 54.26%
#     Worker 7: Train Loss: 1.6445, Train Accuracy: 54.52%
# Epoch 78/150: Test Loss: 2.0096, Test Accuracy: 48.08%
#     Worker 0: Train Loss: 1.6310, Train Accuracy: 54.33%
#     Worker 1: Train Loss: 1.5757, Train Accuracy: 55.69%
#     Worker 2: Train Loss: 1.6011, Train Accuracy: 56.84%
#     Worker 3: Train Loss: 1.6423, Train Accuracy: 54.94%
#     Worker 4: Train Loss: 1.6150, Train Accuracy: 54.48%
#     Worker 5: Train Loss: 1.6080, Train Accuracy: 56.65%
#     Worker 6: Train Loss: 1.6760, Train Accuracy: 54.19%
#     Worker 7: Train Loss: 1.6316, Train Accuracy: 54.66%
# Epoch 79/150: Test Loss: 1.9934, Test Accuracy: 48.25%
#     Worker 0: Train Loss: 1.6181, Train Accuracy: 54.64%
#     Worker 1: Train Loss: 1.6169, Train Accuracy: 55.10%
#     Worker 2: Train Loss: 1.5966, Train Accuracy: 55.91%
#     Worker 3: Train Loss: 1.6051, Train Accuracy: 55.57%
#     Worker 4: Train Loss: 1.5883, Train Accuracy: 55.35%
#     Worker 5: Train Loss: 1.6131, Train Accuracy: 55.19%
#     Worker 6: Train Loss: 1.6284, Train Accuracy: 55.19%
#     Worker 7: Train Loss: 1.6077, Train Accuracy: 55.33%
# Epoch 80/150: Test Loss: 1.9926, Test Accuracy: 48.49%
#     Worker 0: Train Loss: 1.6056, Train Accuracy: 54.99%
#     Worker 1: Train Loss: 1.5968, Train Accuracy: 55.17%
#     Worker 2: Train Loss: 1.5833, Train Accuracy: 55.46%
#     Worker 3: Train Loss: 1.6006, Train Accuracy: 54.81%
#     Worker 4: Train Loss: 1.5966, Train Accuracy: 55.82%
#     Worker 5: Train Loss: 1.5884, Train Accuracy: 56.93%
#     Worker 6: Train Loss: 1.6413, Train Accuracy: 55.08%
#     Worker 7: Train Loss: 1.5940, Train Accuracy: 56.43%
# Epoch 81/150: Test Loss: 1.9999, Test Accuracy: 48.30%
#     Worker 0: Train Loss: 1.6167, Train Accuracy: 54.31%
#     Worker 1: Train Loss: 1.5450, Train Accuracy: 57.37%
#     Worker 2: Train Loss: 1.5626, Train Accuracy: 56.71%
#     Worker 3: Train Loss: 1.5922, Train Accuracy: 56.15%
#     Worker 4: Train Loss: 1.5416, Train Accuracy: 56.01%
#     Worker 5: Train Loss: 1.5611, Train Accuracy: 56.52%
#     Worker 6: Train Loss: 1.6109, Train Accuracy: 55.39%
#     Worker 7: Train Loss: 1.5962, Train Accuracy: 56.16%
# Epoch 82/150: Test Loss: 2.0051, Test Accuracy: 48.21%
#     Worker 0: Train Loss: 1.5925, Train Accuracy: 55.38%
#     Worker 1: Train Loss: 1.5768, Train Accuracy: 55.39%
#     Worker 2: Train Loss: 1.5623, Train Accuracy: 56.65%
#     Worker 3: Train Loss: 1.5885, Train Accuracy: 55.94%
#     Worker 4: Train Loss: 1.5978, Train Accuracy: 55.58%
#     Worker 5: Train Loss: 1.5807, Train Accuracy: 55.64%
#     Worker 6: Train Loss: 1.6472, Train Accuracy: 55.24%
#     Worker 7: Train Loss: 1.5632, Train Accuracy: 57.13%
# Epoch 83/150: Test Loss: 1.9908, Test Accuracy: 48.79%
#     Worker 0: Train Loss: 1.5660, Train Accuracy: 56.11%
#     Worker 1: Train Loss: 1.5707, Train Accuracy: 56.87%
#     Worker 2: Train Loss: 1.5368, Train Accuracy: 57.29%
#     Worker 3: Train Loss: 1.5855, Train Accuracy: 56.07%
#     Worker 4: Train Loss: 1.5362, Train Accuracy: 56.95%
#     Worker 5: Train Loss: 1.5786, Train Accuracy: 56.82%
#     Worker 6: Train Loss: 1.5766, Train Accuracy: 56.21%
#     Worker 7: Train Loss: 1.5516, Train Accuracy: 56.52%
# Epoch 84/150: Test Loss: 1.9848, Test Accuracy: 48.75%
#     Worker 0: Train Loss: 1.5877, Train Accuracy: 55.63%
#     Worker 1: Train Loss: 1.4992, Train Accuracy: 57.28%
#     Worker 2: Train Loss: 1.5503, Train Accuracy: 57.54%
#     Worker 3: Train Loss: 1.5999, Train Accuracy: 55.72%
#     Worker 4: Train Loss: 1.5517, Train Accuracy: 56.51%
#     Worker 5: Train Loss: 1.5055, Train Accuracy: 58.14%
#     Worker 6: Train Loss: 1.5990, Train Accuracy: 55.28%
#     Worker 7: Train Loss: 1.5603, Train Accuracy: 57.09%
# Epoch 85/150: Test Loss: 1.9946, Test Accuracy: 48.90%
#     Worker 0: Train Loss: 1.5528, Train Accuracy: 56.76%
#     Worker 1: Train Loss: 1.5368, Train Accuracy: 57.23%
#     Worker 2: Train Loss: 1.5518, Train Accuracy: 57.32%
#     Worker 3: Train Loss: 1.5654, Train Accuracy: 56.84%
#     Worker 4: Train Loss: 1.5479, Train Accuracy: 56.29%
#     Worker 5: Train Loss: 1.5353, Train Accuracy: 56.41%
#     Worker 6: Train Loss: 1.5648, Train Accuracy: 56.60%
#     Worker 7: Train Loss: 1.5449, Train Accuracy: 56.91%
# Epoch 86/150: Test Loss: 1.9812, Test Accuracy: 49.29%
#     Worker 0: Train Loss: 1.5421, Train Accuracy: 56.93%
#     Worker 1: Train Loss: 1.5153, Train Accuracy: 56.76%
#     Worker 2: Train Loss: 1.5071, Train Accuracy: 57.57%
#     Worker 3: Train Loss: 1.5206, Train Accuracy: 57.78%
#     Worker 4: Train Loss: 1.5347, Train Accuracy: 57.51%
#     Worker 5: Train Loss: 1.5167, Train Accuracy: 58.11%
#     Worker 6: Train Loss: 1.5689, Train Accuracy: 55.85%
#     Worker 7: Train Loss: 1.5584, Train Accuracy: 56.10%
# Epoch 87/150: Test Loss: 1.9950, Test Accuracy: 48.82%
#     Worker 0: Train Loss: 1.5468, Train Accuracy: 56.40%
#     Worker 1: Train Loss: 1.5152, Train Accuracy: 58.07%
#     Worker 2: Train Loss: 1.5003, Train Accuracy: 58.51%
#     Worker 3: Train Loss: 1.5483, Train Accuracy: 56.68%
#     Worker 4: Train Loss: 1.5171, Train Accuracy: 57.67%
#     Worker 5: Train Loss: 1.5085, Train Accuracy: 58.20%
#     Worker 6: Train Loss: 1.5297, Train Accuracy: 57.37%
#     Worker 7: Train Loss: 1.5263, Train Accuracy: 57.89%
# Epoch 88/150: Test Loss: 1.9852, Test Accuracy: 48.52%
#     Worker 0: Train Loss: 1.5014, Train Accuracy: 57.81%
#     Worker 1: Train Loss: 1.4932, Train Accuracy: 58.00%
#     Worker 2: Train Loss: 1.5019, Train Accuracy: 58.25%
#     Worker 3: Train Loss: 1.5207, Train Accuracy: 57.45%
#     Worker 4: Train Loss: 1.5447, Train Accuracy: 56.74%
#     Worker 5: Train Loss: 1.5072, Train Accuracy: 58.20%
#     Worker 6: Train Loss: 1.5516, Train Accuracy: 57.02%
#     Worker 7: Train Loss: 1.5119, Train Accuracy: 58.15%
# Epoch 89/150: Test Loss: 1.9774, Test Accuracy: 48.54%
#     Worker 0: Train Loss: 1.4997, Train Accuracy: 58.22%
#     Worker 1: Train Loss: 1.4972, Train Accuracy: 57.56%
#     Worker 2: Train Loss: 1.5211, Train Accuracy: 57.26%
#     Worker 3: Train Loss: 1.5071, Train Accuracy: 57.12%
#     Worker 4: Train Loss: 1.4806, Train Accuracy: 59.05%
#     Worker 5: Train Loss: 1.4950, Train Accuracy: 58.59%
#     Worker 6: Train Loss: 1.5333, Train Accuracy: 57.28%
#     Worker 7: Train Loss: 1.5347, Train Accuracy: 57.32%
# Epoch 90/150: Test Loss: 1.9927, Test Accuracy: 48.68%
#     Worker 0: Train Loss: 1.5032, Train Accuracy: 56.93%
#     Worker 1: Train Loss: 1.4616, Train Accuracy: 58.56%
#     Worker 2: Train Loss: 1.4959, Train Accuracy: 58.18%
#     Worker 3: Train Loss: 1.5140, Train Accuracy: 57.24%
#     Worker 4: Train Loss: 1.5025, Train Accuracy: 58.17%
#     Worker 5: Train Loss: 1.4886, Train Accuracy: 58.25%
#     Worker 6: Train Loss: 1.5236, Train Accuracy: 57.89%
#     Worker 7: Train Loss: 1.4974, Train Accuracy: 58.18%
# Epoch 91/150: Test Loss: 1.9855, Test Accuracy: 49.00%
#     Worker 0: Train Loss: 1.4894, Train Accuracy: 57.60%
#     Worker 1: Train Loss: 1.4763, Train Accuracy: 58.23%
#     Worker 2: Train Loss: 1.4565, Train Accuracy: 59.78%
#     Worker 3: Train Loss: 1.5034, Train Accuracy: 57.90%
#     Worker 4: Train Loss: 1.4642, Train Accuracy: 58.51%
#     Worker 5: Train Loss: 1.4933, Train Accuracy: 57.95%
#     Worker 6: Train Loss: 1.5154, Train Accuracy: 57.78%
#     Worker 7: Train Loss: 1.4842, Train Accuracy: 58.48%
# Epoch 92/150: Test Loss: 1.9783, Test Accuracy: 48.86%
#     Worker 0: Train Loss: 1.4853, Train Accuracy: 58.61%
#     Worker 1: Train Loss: 1.4436, Train Accuracy: 59.34%
#     Worker 2: Train Loss: 1.4631, Train Accuracy: 58.97%
#     Worker 3: Train Loss: 1.4858, Train Accuracy: 57.59%
#     Worker 4: Train Loss: 1.4795, Train Accuracy: 58.11%
#     Worker 5: Train Loss: 1.4398, Train Accuracy: 60.11%
#     Worker 6: Train Loss: 1.4933, Train Accuracy: 59.00%
#     Worker 7: Train Loss: 1.4897, Train Accuracy: 58.34%
# Epoch 93/150: Test Loss: 1.9861, Test Accuracy: 48.82%
#     Worker 0: Train Loss: 1.4824, Train Accuracy: 58.62%
#     Worker 1: Train Loss: 1.4575, Train Accuracy: 58.80%
#     Worker 2: Train Loss: 1.4694, Train Accuracy: 59.00%
#     Worker 3: Train Loss: 1.4716, Train Accuracy: 58.83%
#     Worker 4: Train Loss: 1.4641, Train Accuracy: 59.05%
#     Worker 5: Train Loss: 1.4502, Train Accuracy: 59.99%
#     Worker 6: Train Loss: 1.4956, Train Accuracy: 58.06%
#     Worker 7: Train Loss: 1.4627, Train Accuracy: 59.31%
# Epoch 94/150: Test Loss: 1.9908, Test Accuracy: 48.83%
#     Worker 0: Train Loss: 1.4511, Train Accuracy: 59.00%
#     Worker 1: Train Loss: 1.4410, Train Accuracy: 59.03%
#     Worker 2: Train Loss: 1.4266, Train Accuracy: 60.18%
#     Worker 3: Train Loss: 1.4773, Train Accuracy: 58.75%
#     Worker 4: Train Loss: 1.4670, Train Accuracy: 58.58%
# ...
#     Worker 6: Train Loss: 1.3198, Train Accuracy: 62.79%
#     Worker 7: Train Loss: 1.3103, Train Accuracy: 62.92%
# Epoch 120/150: Test Loss: 1.9909, Test Accuracy: 49.74%
#     Worker 0: Train Loss: 1.2783, Train Accuracy: 64.06%
#     Worker 1: Train Loss: 1.2638, Train Accuracy: 63.81%
#     Worker 2: Train Loss: 1.2552, Train Accuracy: 65.30%
#     Worker 3: Train Loss: 1.2831, Train Accuracy: 63.69%
#     Worker 4: Train Loss: 1.2681, Train Accuracy: 63.91%
#     Worker 5: Train Loss: 1.2855, Train Accuracy: 63.41%
#     Worker 6: Train Loss: 1.2642, Train Accuracy: 64.49%
#     Worker 7: Train Loss: 1.2658, Train Accuracy: 64.17%
# Epoch 121/150: Test Loss: 1.9868, Test Accuracy: 49.92%
#     Worker 0: Train Loss: 1.3014, Train Accuracy: 63.37%
#     Worker 1: Train Loss: 1.2549, Train Accuracy: 63.95%
#     Worker 2: Train Loss: 1.2622, Train Accuracy: 64.74%
#     Worker 3: Train Loss: 1.2922, Train Accuracy: 63.92%
#     Worker 4: Train Loss: 1.2723, Train Accuracy: 63.15%
#     Worker 5: Train Loss: 1.2666, Train Accuracy: 64.08%
#     Worker 6: Train Loss: 1.3109, Train Accuracy: 62.48%
#     Worker 7: Train Loss: 1.2946, Train Accuracy: 63.52%
# Epoch 122/150: Test Loss: 1.9915, Test Accuracy: 49.61%
#     Worker 0: Train Loss: 1.2622, Train Accuracy: 63.77%
#     Worker 1: Train Loss: 1.2572, Train Accuracy: 64.11%
#     Worker 2: Train Loss: 1.2801, Train Accuracy: 63.88%
#     Worker 3: Train Loss: 1.2846, Train Accuracy: 63.62%
#     Worker 4: Train Loss: 1.2660, Train Accuracy: 63.94%
#     Worker 5: Train Loss: 1.2660, Train Accuracy: 64.39%
#     Worker 6: Train Loss: 1.2866, Train Accuracy: 62.98%
#     Worker 7: Train Loss: 1.2503, Train Accuracy: 63.50%
# Epoch 123/150: Test Loss: 1.9896, Test Accuracy: 49.79%
#     Worker 0: Train Loss: 1.2521, Train Accuracy: 64.72%
#     Worker 1: Train Loss: 1.2547, Train Accuracy: 64.52%
#     Worker 2: Train Loss: 1.2536, Train Accuracy: 64.93%
#     Worker 3: Train Loss: 1.2850, Train Accuracy: 64.24%
#     Worker 4: Train Loss: 1.2470, Train Accuracy: 64.46%
#     Worker 5: Train Loss: 1.2441, Train Accuracy: 65.08%
#     Worker 6: Train Loss: 1.2780, Train Accuracy: 64.58%
#     Worker 7: Train Loss: 1.2445, Train Accuracy: 65.27%
# Epoch 124/150: Test Loss: 1.9888, Test Accuracy: 49.92%
#     Worker 0: Train Loss: 1.2979, Train Accuracy: 62.70%
#     Worker 1: Train Loss: 1.2563, Train Accuracy: 63.94%
#     Worker 2: Train Loss: 1.2424, Train Accuracy: 64.72%
#     Worker 3: Train Loss: 1.2545, Train Accuracy: 64.93%
#     Worker 4: Train Loss: 1.2697, Train Accuracy: 63.62%
#     Worker 5: Train Loss: 1.2696, Train Accuracy: 63.94%
#     Worker 6: Train Loss: 1.2951, Train Accuracy: 63.11%
#     Worker 7: Train Loss: 1.2732, Train Accuracy: 64.42%
# Epoch 125/150: Test Loss: 1.9918, Test Accuracy: 49.86%
#     Worker 0: Train Loss: 1.2483, Train Accuracy: 64.52%
#     Worker 1: Train Loss: 1.2365, Train Accuracy: 64.52%
#     Worker 2: Train Loss: 1.2424, Train Accuracy: 65.05%
#     Worker 3: Train Loss: 1.2717, Train Accuracy: 63.73%
#     Worker 4: Train Loss: 1.2439, Train Accuracy: 65.18%
#     Worker 5: Train Loss: 1.2372, Train Accuracy: 65.32%
#     Worker 6: Train Loss: 1.3013, Train Accuracy: 63.67%
#     Worker 7: Train Loss: 1.2740, Train Accuracy: 63.56%
# Epoch 126/150: Test Loss: 1.9929, Test Accuracy: 49.76%
#     Worker 0: Train Loss: 1.2616, Train Accuracy: 63.95%
#     Worker 1: Train Loss: 1.2318, Train Accuracy: 64.69%
#     Worker 2: Train Loss: 1.2362, Train Accuracy: 65.68%
#     Worker 3: Train Loss: 1.2832, Train Accuracy: 64.11%
#     Worker 4: Train Loss: 1.2725, Train Accuracy: 64.11%
#     Worker 5: Train Loss: 1.2782, Train Accuracy: 64.13%
#     Worker 6: Train Loss: 1.2817, Train Accuracy: 64.46%
#     Worker 7: Train Loss: 1.2383, Train Accuracy: 64.74%
# Epoch 127/150: Test Loss: 1.9907, Test Accuracy: 49.57%
#     Worker 0: Train Loss: 1.2626, Train Accuracy: 64.27%
#     Worker 1: Train Loss: 1.2341, Train Accuracy: 65.46%
#     Worker 2: Train Loss: 1.2489, Train Accuracy: 64.77%
#     Worker 3: Train Loss: 1.2706, Train Accuracy: 63.33%
#     Worker 4: Train Loss: 1.2367, Train Accuracy: 64.74%
#     Worker 5: Train Loss: 1.2420, Train Accuracy: 64.13%
#     Worker 6: Train Loss: 1.2593, Train Accuracy: 63.67%
#     Worker 7: Train Loss: 1.2560, Train Accuracy: 64.68%
# Epoch 128/150: Test Loss: 1.9965, Test Accuracy: 49.77%
#     Worker 0: Train Loss: 1.2686, Train Accuracy: 63.75%
#     Worker 1: Train Loss: 1.2230, Train Accuracy: 65.15%
#     Worker 2: Train Loss: 1.2139, Train Accuracy: 65.11%
#     Worker 3: Train Loss: 1.2398, Train Accuracy: 64.72%
#     Worker 4: Train Loss: 1.2746, Train Accuracy: 63.84%
#     Worker 5: Train Loss: 1.2398, Train Accuracy: 65.37%
#     Worker 6: Train Loss: 1.2977, Train Accuracy: 64.38%
#     Worker 7: Train Loss: 1.2622, Train Accuracy: 64.41%
# Epoch 129/150: Test Loss: 1.9918, Test Accuracy: 49.73%
#     Worker 0: Train Loss: 1.2484, Train Accuracy: 64.57%
#     Worker 1: Train Loss: 1.2485, Train Accuracy: 64.74%
#     Worker 2: Train Loss: 1.2418, Train Accuracy: 65.80%
#     Worker 3: Train Loss: 1.2755, Train Accuracy: 64.11%
#     Worker 4: Train Loss: 1.2593, Train Accuracy: 64.10%
#     Worker 5: Train Loss: 1.2455, Train Accuracy: 65.27%
#     Worker 6: Train Loss: 1.2946, Train Accuracy: 63.34%
#     Worker 7: Train Loss: 1.2335, Train Accuracy: 65.22%
# Epoch 130/150: Test Loss: 1.9901, Test Accuracy: 50.00%
#     Worker 0: Train Loss: 1.2425, Train Accuracy: 64.88%
#     Worker 1: Train Loss: 1.2039, Train Accuracy: 65.49%
#     Worker 2: Train Loss: 1.2132, Train Accuracy: 66.02%
#     Worker 3: Train Loss: 1.2629, Train Accuracy: 64.25%
#     Worker 4: Train Loss: 1.2271, Train Accuracy: 64.49%
#     Worker 5: Train Loss: 1.2288, Train Accuracy: 65.29%
#     Worker 6: Train Loss: 1.2715, Train Accuracy: 64.13%
#     Worker 7: Train Loss: 1.2408, Train Accuracy: 64.85%
# Epoch 131/150: Test Loss: 1.9927, Test Accuracy: 49.98%
#     Worker 0: Train Loss: 1.2470, Train Accuracy: 64.52%
#     Worker 1: Train Loss: 1.2115, Train Accuracy: 65.98%
#     Worker 2: Train Loss: 1.2427, Train Accuracy: 65.19%
#     Worker 3: Train Loss: 1.2711, Train Accuracy: 64.13%
#     Worker 4: Train Loss: 1.2533, Train Accuracy: 64.25%
#     Worker 5: Train Loss: 1.2430, Train Accuracy: 64.35%
#     Worker 6: Train Loss: 1.2476, Train Accuracy: 64.74%
#     Worker 7: Train Loss: 1.2475, Train Accuracy: 64.47%
# Epoch 132/150: Test Loss: 1.9894, Test Accuracy: 49.94%
#     Worker 0: Train Loss: 1.2498, Train Accuracy: 64.86%
#     Worker 1: Train Loss: 1.2194, Train Accuracy: 65.80%
#     Worker 2: Train Loss: 1.2022, Train Accuracy: 66.24%
#     Worker 3: Train Loss: 1.2222, Train Accuracy: 65.26%
#     Worker 4: Train Loss: 1.2341, Train Accuracy: 64.28%
#     Worker 5: Train Loss: 1.2270, Train Accuracy: 65.98%
#     Worker 6: Train Loss: 1.2675, Train Accuracy: 65.02%
#     Worker 7: Train Loss: 1.2462, Train Accuracy: 65.02%
# Epoch 133/150: Test Loss: 1.9956, Test Accuracy: 49.82%
#     Worker 0: Train Loss: 1.2419, Train Accuracy: 65.21%
#     Worker 1: Train Loss: 1.2311, Train Accuracy: 64.49%
#     Worker 2: Train Loss: 1.2347, Train Accuracy: 65.98%
#     Worker 3: Train Loss: 1.2384, Train Accuracy: 64.69%
#     Worker 4: Train Loss: 1.2526, Train Accuracy: 64.47%
#     Worker 5: Train Loss: 1.2425, Train Accuracy: 64.97%
#     Worker 6: Train Loss: 1.2508, Train Accuracy: 64.31%
#     Worker 7: Train Loss: 1.2251, Train Accuracy: 65.22%
# Epoch 134/150: Test Loss: 1.9938, Test Accuracy: 50.03%
#     Worker 0: Train Loss: 1.2063, Train Accuracy: 65.87%
#     Worker 1: Train Loss: 1.2021, Train Accuracy: 65.96%
#     Worker 2: Train Loss: 1.2371, Train Accuracy: 65.52%
#     Worker 3: Train Loss: 1.2445, Train Accuracy: 64.08%
#     Worker 4: Train Loss: 1.2469, Train Accuracy: 64.79%
#     Worker 5: Train Loss: 1.2175, Train Accuracy: 64.94%
#     Worker 6: Train Loss: 1.2583, Train Accuracy: 64.52%
#     Worker 7: Train Loss: 1.2515, Train Accuracy: 65.10%
# Epoch 135/150: Test Loss: 1.9912, Test Accuracy: 49.99%
#     Worker 0: Train Loss: 1.2531, Train Accuracy: 64.50%
#     Worker 1: Train Loss: 1.2147, Train Accuracy: 65.35%
#     Worker 2: Train Loss: 1.2390, Train Accuracy: 65.19%
#     Worker 3: Train Loss: 1.2489, Train Accuracy: 64.69%
#     Worker 4: Train Loss: 1.2201, Train Accuracy: 65.54%
#     Worker 5: Train Loss: 1.2420, Train Accuracy: 65.00%
#     Worker 6: Train Loss: 1.2629, Train Accuracy: 64.60%
#     Worker 7: Train Loss: 1.2319, Train Accuracy: 64.60%
# Epoch 136/150: Test Loss: 1.9907, Test Accuracy: 50.03%
#     Worker 0: Train Loss: 1.2070, Train Accuracy: 65.79%
#     Worker 1: Train Loss: 1.2134, Train Accuracy: 65.46%
#     Worker 2: Train Loss: 1.2073, Train Accuracy: 65.90%
#     Worker 3: Train Loss: 1.2356, Train Accuracy: 65.10%
#     Worker 4: Train Loss: 1.2159, Train Accuracy: 65.13%
#     Worker 5: Train Loss: 1.2220, Train Accuracy: 65.41%
#     Worker 6: Train Loss: 1.2631, Train Accuracy: 64.38%
#     Worker 7: Train Loss: 1.2400, Train Accuracy: 65.08%
# Epoch 137/150: Test Loss: 1.9941, Test Accuracy: 49.97%
#     Worker 0: Train Loss: 1.2398, Train Accuracy: 64.10%
#     Worker 1: Train Loss: 1.2125, Train Accuracy: 66.04%
#     Worker 2: Train Loss: 1.2469, Train Accuracy: 65.91%
#     Worker 3: Train Loss: 1.2332, Train Accuracy: 65.00%
#     Worker 4: Train Loss: 1.2287, Train Accuracy: 65.05%
#     Worker 5: Train Loss: 1.2232, Train Accuracy: 65.77%
#     Worker 6: Train Loss: 1.2282, Train Accuracy: 64.57%
#     Worker 7: Train Loss: 1.2366, Train Accuracy: 64.60%
# Epoch 138/150: Test Loss: 1.9912, Test Accuracy: 50.09%
#     Worker 0: Train Loss: 1.2220, Train Accuracy: 64.08%
#     Worker 1: Train Loss: 1.1999, Train Accuracy: 65.41%
#     Worker 2: Train Loss: 1.2189, Train Accuracy: 65.60%
#     Worker 3: Train Loss: 1.2392, Train Accuracy: 64.99%
#     Worker 4: Train Loss: 1.2315, Train Accuracy: 64.28%
#     Worker 5: Train Loss: 1.2419, Train Accuracy: 64.27%
#     Worker 6: Train Loss: 1.2443, Train Accuracy: 65.10%
#     Worker 7: Train Loss: 1.2185, Train Accuracy: 66.02%
# Epoch 139/150: Test Loss: 1.9905, Test Accuracy: 50.01%
#     Worker 0: Train Loss: 1.2496, Train Accuracy: 64.31%
#     Worker 1: Train Loss: 1.1963, Train Accuracy: 65.91%
#     Worker 2: Train Loss: 1.2180, Train Accuracy: 66.26%
#     Worker 3: Train Loss: 1.2324, Train Accuracy: 65.37%
#     Worker 4: Train Loss: 1.2197, Train Accuracy: 65.58%
#     Worker 5: Train Loss: 1.2357, Train Accuracy: 65.13%
#     Worker 6: Train Loss: 1.2351, Train Accuracy: 65.41%
#     Worker 7: Train Loss: 1.2384, Train Accuracy: 65.38%
# Epoch 140/150: Test Loss: 1.9908, Test Accuracy: 49.97%
#     Worker 0: Train Loss: 1.2088, Train Accuracy: 65.46%
#     Worker 1: Train Loss: 1.2034, Train Accuracy: 65.74%
#     Worker 2: Train Loss: 1.2028, Train Accuracy: 66.35%
#     Worker 3: Train Loss: 1.2410, Train Accuracy: 64.80%
#     Worker 4: Train Loss: 1.2287, Train Accuracy: 65.02%
#     Worker 5: Train Loss: 1.2008, Train Accuracy: 65.91%
#     Worker 6: Train Loss: 1.2742, Train Accuracy: 64.55%
#     Worker 7: Train Loss: 1.2289, Train Accuracy: 65.87%
# Epoch 141/150: Test Loss: 1.9911, Test Accuracy: 50.10%
#     Worker 0: Train Loss: 1.2219, Train Accuracy: 65.49%
#     Worker 1: Train Loss: 1.1992, Train Accuracy: 66.15%
#     Worker 2: Train Loss: 1.2231, Train Accuracy: 65.10%
#     Worker 3: Train Loss: 1.2327, Train Accuracy: 65.02%
#     Worker 4: Train Loss: 1.2348, Train Accuracy: 64.41%
#     Worker 5: Train Loss: 1.2260, Train Accuracy: 65.68%
#     Worker 6: Train Loss: 1.2448, Train Accuracy: 65.44%
#     Worker 7: Train Loss: 1.2184, Train Accuracy: 65.91%
# Epoch 142/150: Test Loss: 1.9909, Test Accuracy: 49.97%
#     Worker 0: Train Loss: 1.2176, Train Accuracy: 65.44%
#     Worker 1: Train Loss: 1.2151, Train Accuracy: 65.33%
#     Worker 2: Train Loss: 1.2071, Train Accuracy: 65.91%
#     Worker 3: Train Loss: 1.2317, Train Accuracy: 65.41%
#     Worker 4: Train Loss: 1.2035, Train Accuracy: 65.65%
#     Worker 5: Train Loss: 1.2013, Train Accuracy: 65.35%
#     Worker 6: Train Loss: 1.2450, Train Accuracy: 64.99%
#     Worker 7: Train Loss: 1.2273, Train Accuracy: 65.37%
# Epoch 143/150: Test Loss: 1.9906, Test Accuracy: 50.13%
#     Worker 0: Train Loss: 1.2326, Train Accuracy: 64.42%
#     Worker 1: Train Loss: 1.2041, Train Accuracy: 65.77%
#     Worker 2: Train Loss: 1.2241, Train Accuracy: 65.96%
#     Worker 3: Train Loss: 1.2486, Train Accuracy: 64.74%
#     Worker 4: Train Loss: 1.2453, Train Accuracy: 64.82%
#     Worker 5: Train Loss: 1.2214, Train Accuracy: 65.84%
#     Worker 6: Train Loss: 1.2437, Train Accuracy: 64.68%
#     Worker 7: Train Loss: 1.2222, Train Accuracy: 65.40%
# Epoch 144/150: Test Loss: 1.9909, Test Accuracy: 50.09%
#     Worker 0: Train Loss: 1.2286, Train Accuracy: 65.30%
#     Worker 1: Train Loss: 1.2081, Train Accuracy: 65.30%
#     Worker 2: Train Loss: 1.2132, Train Accuracy: 65.38%
#     Worker 3: Train Loss: 1.2259, Train Accuracy: 65.63%
#     Worker 4: Train Loss: 1.2120, Train Accuracy: 65.66%
#     Worker 5: Train Loss: 1.2303, Train Accuracy: 65.63%
#     Worker 6: Train Loss: 1.2269, Train Accuracy: 65.29%
#     Worker 7: Train Loss: 1.2123, Train Accuracy: 65.37%
# Epoch 145/150: Test Loss: 1.9910, Test Accuracy: 50.15%
#     Worker 0: Train Loss: 1.2177, Train Accuracy: 64.94%
#     Worker 1: Train Loss: 1.1894, Train Accuracy: 66.27%
#     Worker 2: Train Loss: 1.2023, Train Accuracy: 66.13%
#     Worker 3: Train Loss: 1.2341, Train Accuracy: 64.71%
#     Worker 4: Train Loss: 1.2247, Train Accuracy: 65.05%
#     Worker 5: Train Loss: 1.2074, Train Accuracy: 66.01%
#     Worker 6: Train Loss: 1.2364, Train Accuracy: 65.21%
#     Worker 7: Train Loss: 1.2192, Train Accuracy: 65.71%
# Epoch 146/150: Test Loss: 1.9911, Test Accuracy: 50.11%
#     Worker 0: Train Loss: 1.2276, Train Accuracy: 65.08%
#     Worker 1: Train Loss: 1.2126, Train Accuracy: 65.54%
#     Worker 2: Train Loss: 1.2049, Train Accuracy: 65.90%
#     Worker 3: Train Loss: 1.2537, Train Accuracy: 65.07%
#     Worker 4: Train Loss: 1.2268, Train Accuracy: 65.49%
#     Worker 5: Train Loss: 1.2077, Train Accuracy: 65.66%
#     Worker 6: Train Loss: 1.2507, Train Accuracy: 64.64%
#     Worker 7: Train Loss: 1.2302, Train Accuracy: 65.05%
# Epoch 147/150: Test Loss: 1.9910, Test Accuracy: 50.13%
#     Worker 0: Train Loss: 1.2237, Train Accuracy: 65.43%
#     Worker 1: Train Loss: 1.1993, Train Accuracy: 65.86%
#     Worker 2: Train Loss: 1.2202, Train Accuracy: 65.39%
#     Worker 3: Train Loss: 1.2139, Train Accuracy: 65.37%
#     Worker 4: Train Loss: 1.2025, Train Accuracy: 65.80%
#     Worker 5: Train Loss: 1.2368, Train Accuracy: 64.88%
#     Worker 6: Train Loss: 1.2499, Train Accuracy: 65.72%
#     Worker 7: Train Loss: 1.2335, Train Accuracy: 66.22%
# Epoch 148/150: Test Loss: 1.9910, Test Accuracy: 50.17%
#     Worker 0: Train Loss: 1.2295, Train Accuracy: 64.60%
#     Worker 1: Train Loss: 1.2082, Train Accuracy: 66.02%
#     Worker 2: Train Loss: 1.2179, Train Accuracy: 65.87%
#     Worker 3: Train Loss: 1.2401, Train Accuracy: 65.40%
#     Worker 4: Train Loss: 1.2175, Train Accuracy: 65.46%
#     Worker 5: Train Loss: 1.2296, Train Accuracy: 65.27%
#     Worker 6: Train Loss: 1.2378, Train Accuracy: 64.60%
#     Worker 7: Train Loss: 1.2110, Train Accuracy: 65.54%
# Epoch 149/150: Test Loss: 1.9909, Test Accuracy: 50.12%
#     Worker 0: Train Loss: 1.2295, Train Accuracy: 65.15%
#     Worker 1: Train Loss: 1.2214, Train Accuracy: 65.51%
#     Worker 2: Train Loss: 1.2159, Train Accuracy: 65.80%
#     Worker 3: Train Loss: 1.2374, Train Accuracy: 64.58%
#     Worker 4: Train Loss: 1.2238, Train Accuracy: 65.46%
#     Worker 5: Train Loss: 1.1922, Train Accuracy: 66.20%
#     Worker 6: Train Loss: 1.2417, Train Accuracy: 64.53%
#     Worker 7: Train Loss: 1.2225, Train Accuracy: 66.04%
# Epoch 150/150: Test Loss: 1.9909, Test Accuracy: 50.13%
#     Worker 0: Train Loss: 1.2181, Train Accuracy: 65.48%
#     Worker 1: Train Loss: 1.1922, Train Accuracy: 66.49%
#     Worker 2: Train Loss: 1.1978, Train Accuracy: 66.38%
#     Worker 3: Train Loss: 1.2244, Train Accuracy: 65.07%
#     Worker 4: Train Loss: 1.2021, Train Accuracy: 66.02%
#     Worker 5: Train Loss: 1.2185, Train Accuracy: 65.57%
#     Worker 6: Train Loss: 1.2401, Train Accuracy: 65.15%
#     Worker 7: Train Loss: 1.2206, Train Accuracy: 64.94%
