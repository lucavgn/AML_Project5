# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs - warmup_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")

    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch):
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            # Perform J local step before synchronization
            for j in range(J):
                try:
                    # Get a batch from the current worker's shard using next()
                    images, labels = next(shard_iterators[k])
                    images, labels = images.to(device), labels.to(device)  # Move to device
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

                except StopIteration:
                    # If the iterator has exhausted the data, restart the iterator
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k]) # Resume from the next batch
                    images, labels = images.to(device), labels.to(device)
                    # Perform optimization step
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        # Perform model synchronization
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            # Update each worker model with the global parameters
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
        else:
            warmup_factor = (epoch + 1) / warmup_epochs
            lr = warmup_factor * learning_rate
            for optimizer in optimizers:
                for param_group in optimizer.param_groups:
                    param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Overwriting localSGD.py

# %%
# %run localSGD.py --k 8 --j 8
# Out:
# Training with K=8, J=8
# Global iteration per epoch: 13
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:13<00:00, 12.9MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00800
# Epoch 1/150: Test Loss: 4.5729, Test Accuracy: 2.49%
#     Worker 0: Train Loss: 4.5979, Train Accuracy: 1.24%
#     Worker 1: Train Loss: 4.5973, Train Accuracy: 1.43%
#     Worker 2: Train Loss: 4.5976, Train Accuracy: 1.31%
#     Worker 3: Train Loss: 4.5968, Train Accuracy: 1.49%
#     Worker 4: Train Loss: 4.5974, Train Accuracy: 1.07%
#     Worker 5: Train Loss: 4.5950, Train Accuracy: 1.70%
#     Worker 6: Train Loss: 4.5975, Train Accuracy: 1.57%
#     Worker 7: Train Loss: 4.5964, Train Accuracy: 1.42%
# Epoch 2/150: Test Loss: 4.5299, Test Accuracy: 3.09%
#     Worker 0: Train Loss: 4.5608, Train Accuracy: 2.67%
#     Worker 1: Train Loss: 4.5602, Train Accuracy: 2.64%
#     Worker 2: Train Loss: 4.5597, Train Accuracy: 2.17%
#     Worker 3: Train Loss: 4.5568, Train Accuracy: 2.28%
#     Worker 4: Train Loss: 4.5560, Train Accuracy: 2.44%
#     Worker 5: Train Loss: 4.5534, Train Accuracy: 2.41%
#     Worker 6: Train Loss: 4.5585, Train Accuracy: 2.38%
#     Worker 7: Train Loss: 4.5558, Train Accuracy: 2.65%
# Epoch 3/150: Test Loss: 4.3060, Test Accuracy: 4.80%
#     Worker 0: Train Loss: 4.4408, Train Accuracy: 4.09%
#     Worker 1: Train Loss: 4.4459, Train Accuracy: 3.53%
#     Worker 2: Train Loss: 4.4411, Train Accuracy: 3.65%
#     Worker 3: Train Loss: 4.4460, Train Accuracy: 3.56%
#     Worker 4: Train Loss: 4.4293, Train Accuracy: 3.77%
#     Worker 5: Train Loss: 4.4222, Train Accuracy: 4.40%
#     Worker 6: Train Loss: 4.4471, Train Accuracy: 3.51%
#     Worker 7: Train Loss: 4.4297, Train Accuracy: 4.16%
# Epoch 4/150: Test Loss: 4.0807, Test Accuracy: 8.06%
#     Worker 0: Train Loss: 4.2228, Train Accuracy: 5.98%
#     Worker 1: Train Loss: 4.2157, Train Accuracy: 5.52%
#     Worker 2: Train Loss: 4.2257, Train Accuracy: 5.34%
#     Worker 3: Train Loss: 4.2274, Train Accuracy: 5.50%
#     Worker 4: Train Loss: 4.2086, Train Accuracy: 5.95%
#     Worker 5: Train Loss: 4.1911, Train Accuracy: 5.77%
#     Worker 6: Train Loss: 4.2284, Train Accuracy: 5.49%
#     Worker 7: Train Loss: 4.2194, Train Accuracy: 5.65%
# Epoch 5/150: Test Loss: 3.9652, Test Accuracy: 9.41%
#     Worker 0: Train Loss: 4.0915, Train Accuracy: 7.15%
#     Worker 1: Train Loss: 4.0998, Train Accuracy: 7.27%
#     Worker 2: Train Loss: 4.0890, Train Accuracy: 7.02%
#     Worker 3: Train Loss: 4.0969, Train Accuracy: 7.19%
#     Worker 4: Train Loss: 4.0601, Train Accuracy: 7.43%
#     Worker 5: Train Loss: 4.0629, Train Accuracy: 7.27%
#     Worker 6: Train Loss: 4.1011, Train Accuracy: 7.51%
#     Worker 7: Train Loss: 4.1114, Train Accuracy: 7.11%
# Epoch 6/150: Test Loss: 3.8234, Test Accuracy: 12.02%
#     Worker 0: Train Loss: 3.9883, Train Accuracy: 8.68%
#     Worker 1: Train Loss: 3.9982, Train Accuracy: 7.73%
#     Worker 2: Train Loss: 3.9905, Train Accuracy: 9.03%
#     Worker 3: Train Loss: 4.0111, Train Accuracy: 8.50%
#     Worker 4: Train Loss: 3.9562, Train Accuracy: 8.85%
#     Worker 5: Train Loss: 3.9493, Train Accuracy: 9.36%
#     Worker 6: Train Loss: 4.0023, Train Accuracy: 7.93%
#     Worker 7: Train Loss: 3.9919, Train Accuracy: 8.43%
# Epoch 7/150: Test Loss: 3.6976, Test Accuracy: 14.36%
#     Worker 0: Train Loss: 3.8651, Train Accuracy: 10.51%
#     Worker 1: Train Loss: 3.8574, Train Accuracy: 10.19%
#     Worker 2: Train Loss: 3.8608, Train Accuracy: 11.28%
#     Worker 3: Train Loss: 3.8788, Train Accuracy: 10.34%
#     Worker 4: Train Loss: 3.8335, Train Accuracy: 10.60%
#     Worker 5: Train Loss: 3.8182, Train Accuracy: 11.82%
#     Worker 6: Train Loss: 3.8870, Train Accuracy: 9.90%
#     Worker 7: Train Loss: 3.8692, Train Accuracy: 10.67%
# Epoch 8/150: Test Loss: 3.6092, Test Accuracy: 15.14%
#     Worker 0: Train Loss: 3.7543, Train Accuracy: 11.98%
#     Worker 1: Train Loss: 3.7725, Train Accuracy: 11.70%
#     Worker 2: Train Loss: 3.7858, Train Accuracy: 11.06%
#     Worker 3: Train Loss: 3.7964, Train Accuracy: 11.64%
#     Worker 4: Train Loss: 3.7272, Train Accuracy: 12.39%
#     Worker 5: Train Loss: 3.7188, Train Accuracy: 13.51%
#     Worker 6: Train Loss: 3.7533, Train Accuracy: 12.12%
#     Worker 7: Train Loss: 3.7696, Train Accuracy: 12.19%
# Epoch 9/150: Test Loss: 3.5138, Test Accuracy: 17.70%
#     Worker 0: Train Loss: 3.6937, Train Accuracy: 13.75%
#     Worker 1: Train Loss: 3.6738, Train Accuracy: 13.45%
#     Worker 2: Train Loss: 3.6468, Train Accuracy: 14.44%
#     Worker 3: Train Loss: 3.7031, Train Accuracy: 13.36%
#     Worker 4: Train Loss: 3.6107, Train Accuracy: 14.32%
#     Worker 5: Train Loss: 3.6166, Train Accuracy: 14.35%
#     Worker 6: Train Loss: 3.7044, Train Accuracy: 13.31%
#     Worker 7: Train Loss: 3.6665, Train Accuracy: 13.82%
# Epoch 10/150: Test Loss: 3.4345, Test Accuracy: 18.67%
#     Worker 0: Train Loss: 3.5776, Train Accuracy: 15.07%
#     Worker 1: Train Loss: 3.5701, Train Accuracy: 15.21%
#     Worker 2: Train Loss: 3.6015, Train Accuracy: 15.45%
#     Worker 3: Train Loss: 3.6007, Train Accuracy: 14.71%
#     Worker 4: Train Loss: 3.5745, Train Accuracy: 14.94%
#     Worker 5: Train Loss: 3.5631, Train Accuracy: 15.68%
#     Worker 6: Train Loss: 3.6009, Train Accuracy: 14.34%
#     Worker 7: Train Loss: 3.5760, Train Accuracy: 15.36%
# Epoch 11/150: Test Loss: 3.3370, Test Accuracy: 20.82%
#     Worker 0: Train Loss: 3.5269, Train Accuracy: 15.96%
#     Worker 1: Train Loss: 3.5090, Train Accuracy: 15.71%
#     Worker 2: Train Loss: 3.5094, Train Accuracy: 16.43%
#     Worker 3: Train Loss: 3.5316, Train Accuracy: 15.22%
#     Worker 4: Train Loss: 3.4737, Train Accuracy: 16.76%
#     Worker 5: Train Loss: 3.4691, Train Accuracy: 17.20%
#     Worker 6: Train Loss: 3.5159, Train Accuracy: 16.13%
#     Worker 7: Train Loss: 3.5288, Train Accuracy: 16.16%
# Epoch 12/150: Test Loss: 3.2973, Test Accuracy: 21.25%
#     Worker 0: Train Loss: 3.4450, Train Accuracy: 17.06%
#     Worker 1: Train Loss: 3.4467, Train Accuracy: 17.40%
#     Worker 2: Train Loss: 3.4358, Train Accuracy: 18.36%
#     Worker 3: Train Loss: 3.4797, Train Accuracy: 16.61%
#     Worker 4: Train Loss: 3.3766, Train Accuracy: 18.63%
#     Worker 5: Train Loss: 3.4242, Train Accuracy: 18.34%
#     Worker 6: Train Loss: 3.4617, Train Accuracy: 16.23%
#     Worker 7: Train Loss: 3.4530, Train Accuracy: 17.32%
# Epoch 13/150: Test Loss: 3.2170, Test Accuracy: 22.75%
#     Worker 0: Train Loss: 3.3695, Train Accuracy: 18.44%
#     Worker 1: Train Loss: 3.3416, Train Accuracy: 18.98%
#     Worker 2: Train Loss: 3.3721, Train Accuracy: 19.25%
#     Worker 3: Train Loss: 3.4021, Train Accuracy: 17.71%
#     Worker 4: Train Loss: 3.3313, Train Accuracy: 19.72%
#     Worker 5: Train Loss: 3.3255, Train Accuracy: 19.40%
#     Worker 6: Train Loss: 3.3842, Train Accuracy: 18.50%
#     Worker 7: Train Loss: 3.3580, Train Accuracy: 19.19%
# Epoch 14/150: Test Loss: 3.1577, Test Accuracy: 23.75%
#     Worker 0: Train Loss: 3.3341, Train Accuracy: 19.28%
#     Worker 1: Train Loss: 3.3070, Train Accuracy: 19.79%
#     Worker 2: Train Loss: 3.2842, Train Accuracy: 21.31%
#     Worker 3: Train Loss: 3.3220, Train Accuracy: 19.35%
#     Worker 4: Train Loss: 3.2791, Train Accuracy: 20.24%
#     Worker 5: Train Loss: 3.2466, Train Accuracy: 21.16%
#     Worker 6: Train Loss: 3.3394, Train Accuracy: 19.20%
#     Worker 7: Train Loss: 3.2992, Train Accuracy: 20.11%
# Epoch 15/150: Test Loss: 3.1203, Test Accuracy: 24.41%
#     Worker 0: Train Loss: 3.2323, Train Accuracy: 21.65%
#     Worker 1: Train Loss: 3.2671, Train Accuracy: 20.24%
#     Worker 2: Train Loss: 3.2565, Train Accuracy: 21.42%
#     Worker 3: Train Loss: 3.2807, Train Accuracy: 20.59%
#     Worker 4: Train Loss: 3.2005, Train Accuracy: 21.19%
#     Worker 5: Train Loss: 3.2132, Train Accuracy: 22.10%
#     Worker 6: Train Loss: 3.2459, Train Accuracy: 20.27%
#     Worker 7: Train Loss: 3.2557, Train Accuracy: 20.73%
# Epoch 16/150: Test Loss: 3.0410, Test Accuracy: 26.20%
#     Worker 0: Train Loss: 3.1795, Train Accuracy: 22.08%
#     Worker 1: Train Loss: 3.1772, Train Accuracy: 22.57%
#     Worker 2: Train Loss: 3.1986, Train Accuracy: 22.34%
#     Worker 3: Train Loss: 3.2008, Train Accuracy: 21.90%
#     Worker 4: Train Loss: 3.1748, Train Accuracy: 22.25%
#     Worker 5: Train Loss: 3.1494, Train Accuracy: 23.06%
#     Worker 6: Train Loss: 3.2325, Train Accuracy: 21.33%
#     Worker 7: Train Loss: 3.1946, Train Accuracy: 21.80%
# Epoch 17/150: Test Loss: 2.9961, Test Accuracy: 26.87%
#     Worker 0: Train Loss: 3.1428, Train Accuracy: 23.47%
#     Worker 1: Train Loss: 3.1232, Train Accuracy: 22.90%
#     Worker 2: Train Loss: 3.1535, Train Accuracy: 23.37%
#     Worker 3: Train Loss: 3.1685, Train Accuracy: 22.47%
#     Worker 4: Train Loss: 3.1168, Train Accuracy: 23.14%
#     Worker 5: Train Loss: 3.0895, Train Accuracy: 24.53%
#     Worker 6: Train Loss: 3.1658, Train Accuracy: 22.49%
#     Worker 7: Train Loss: 3.1422, Train Accuracy: 23.11%
# Epoch 18/150: Test Loss: 2.9603, Test Accuracy: 27.60%
#     Worker 0: Train Loss: 3.0812, Train Accuracy: 23.58%
#     Worker 1: Train Loss: 3.0668, Train Accuracy: 23.86%
#     Worker 2: Train Loss: 3.0725, Train Accuracy: 24.65%
#     Worker 3: Train Loss: 3.1381, Train Accuracy: 22.97%
#     Worker 4: Train Loss: 3.0704, Train Accuracy: 23.83%
#     Worker 5: Train Loss: 3.0467, Train Accuracy: 25.25%
#     Worker 6: Train Loss: 3.1262, Train Accuracy: 23.06%
#     Worker 7: Train Loss: 3.0830, Train Accuracy: 23.97%
# Epoch 19/150: Test Loss: 2.9011, Test Accuracy: 28.41%
#     Worker 0: Train Loss: 3.0737, Train Accuracy: 23.79%
#     Worker 1: Train Loss: 3.0256, Train Accuracy: 24.60%
#     Worker 2: Train Loss: 3.0682, Train Accuracy: 24.57%
#     Worker 3: Train Loss: 3.0660, Train Accuracy: 23.94%
#     Worker 4: Train Loss: 2.9989, Train Accuracy: 25.82%
#     Worker 5: Train Loss: 2.9690, Train Accuracy: 26.70%
#     Worker 6: Train Loss: 3.0633, Train Accuracy: 24.19%
#     Worker 7: Train Loss: 3.0323, Train Accuracy: 24.81%
# Epoch 20/150: Test Loss: 2.8453, Test Accuracy: 29.16%
#     Worker 0: Train Loss: 2.9783, Train Accuracy: 26.44%
#     Worker 1: Train Loss: 2.9874, Train Accuracy: 25.78%
#     Worker 2: Train Loss: 2.9856, Train Accuracy: 25.88%
#     Worker 3: Train Loss: 3.0341, Train Accuracy: 24.90%
#     Worker 4: Train Loss: 2.9714, Train Accuracy: 26.38%
#     Worker 5: Train Loss: 2.9405, Train Accuracy: 28.29%
#     Worker 6: Train Loss: 3.0216, Train Accuracy: 24.62%
#     Worker 7: Train Loss: 2.9838, Train Accuracy: 26.29%
# Epoch 21/150: Test Loss: 2.8084, Test Accuracy: 30.16%
#     Worker 0: Train Loss: 2.9920, Train Accuracy: 25.10%
#     Worker 1: Train Loss: 2.9129, Train Accuracy: 26.92%
#     Worker 2: Train Loss: 2.9532, Train Accuracy: 27.40%
#     Worker 3: Train Loss: 2.9781, Train Accuracy: 26.06%
#     Worker 4: Train Loss: 2.9388, Train Accuracy: 26.91%
#     Worker 5: Train Loss: 2.9143, Train Accuracy: 27.33%
#     Worker 6: Train Loss: 2.9685, Train Accuracy: 25.87%
#     Worker 7: Train Loss: 2.9521, Train Accuracy: 26.44%
# Epoch 22/150: Test Loss: 2.7650, Test Accuracy: 30.55%
#     Worker 0: Train Loss: 2.8916, Train Accuracy: 27.77%
#     Worker 1: Train Loss: 2.8693, Train Accuracy: 27.68%
#     Worker 2: Train Loss: 2.8758, Train Accuracy: 28.63%
#     Worker 3: Train Loss: 2.9577, Train Accuracy: 26.80%
#     Worker 4: Train Loss: 2.8762, Train Accuracy: 27.93%
#     Worker 5: Train Loss: 2.8315, Train Accuracy: 29.54%
#     Worker 6: Train Loss: 2.9410, Train Accuracy: 27.01%
#     Worker 7: Train Loss: 2.9152, Train Accuracy: 27.37%
# Epoch 23/150: Test Loss: 2.7327, Test Accuracy: 31.48%
#     Worker 0: Train Loss: 2.8535, Train Accuracy: 28.07%
#     Worker 1: Train Loss: 2.8484, Train Accuracy: 28.07%
#     Worker 2: Train Loss: 2.8793, Train Accuracy: 28.05%
#     Worker 3: Train Loss: 2.9098, Train Accuracy: 27.40%
#     Worker 4: Train Loss: 2.8200, Train Accuracy: 29.02%
#     Worker 5: Train Loss: 2.8286, Train Accuracy: 29.53%
#     Worker 6: Train Loss: 2.8838, Train Accuracy: 27.93%
#     Worker 7: Train Loss: 2.8254, Train Accuracy: 28.28%
# Epoch 24/150: Test Loss: 2.7023, Test Accuracy: 32.36%
#     Worker 0: Train Loss: 2.8033, Train Accuracy: 29.30%
#     Worker 1: Train Loss: 2.7943, Train Accuracy: 29.21%
#     Worker 2: Train Loss: 2.8186, Train Accuracy: 29.38%
#     Worker 3: Train Loss: 2.8470, Train Accuracy: 27.71%
#     Worker 4: Train Loss: 2.7948, Train Accuracy: 29.53%
#     Worker 5: Train Loss: 2.7785, Train Accuracy: 29.97%
#     Worker 6: Train Loss: 2.8554, Train Accuracy: 28.47%
#     Worker 7: Train Loss: 2.7986, Train Accuracy: 29.53%
# Epoch 25/150: Test Loss: 2.6350, Test Accuracy: 33.35%
#     Worker 0: Train Loss: 2.7942, Train Accuracy: 29.83%
#     Worker 1: Train Loss: 2.7486, Train Accuracy: 29.79%
#     Worker 2: Train Loss: 2.7564, Train Accuracy: 31.23%
#     Worker 3: Train Loss: 2.7822, Train Accuracy: 29.56%
#     Worker 4: Train Loss: 2.7032, Train Accuracy: 31.87%
#     Worker 5: Train Loss: 2.7487, Train Accuracy: 31.35%
#     Worker 6: Train Loss: 2.7591, Train Accuracy: 30.30%
#     Worker 7: Train Loss: 2.7589, Train Accuracy: 30.75%
# Epoch 26/150: Test Loss: 2.6005, Test Accuracy: 34.00%
#     Worker 0: Train Loss: 2.7435, Train Accuracy: 30.31%
#     Worker 1: Train Loss: 2.7391, Train Accuracy: 29.83%
#     Worker 2: Train Loss: 2.7476, Train Accuracy: 31.05%
#     Worker 3: Train Loss: 2.7639, Train Accuracy: 30.19%
#     Worker 4: Train Loss: 2.7082, Train Accuracy: 31.62%
#     Worker 5: Train Loss: 2.6510, Train Accuracy: 31.99%
#     Worker 6: Train Loss: 2.7494, Train Accuracy: 30.37%
#     Worker 7: Train Loss: 2.7134, Train Accuracy: 30.80%
# Epoch 27/150: Test Loss: 2.5746, Test Accuracy: 34.57%
#     Worker 0: Train Loss: 2.6877, Train Accuracy: 32.32%
#     Worker 1: Train Loss: 2.6582, Train Accuracy: 31.61%
#     Worker 2: Train Loss: 2.6801, Train Accuracy: 32.41%
#     Worker 3: Train Loss: 2.6992, Train Accuracy: 31.88%
#     Worker 4: Train Loss: 2.6662, Train Accuracy: 31.76%
#     Worker 5: Train Loss: 2.6946, Train Accuracy: 31.93%
#     Worker 6: Train Loss: 2.7167, Train Accuracy: 30.34%
#     Worker 7: Train Loss: 2.7276, Train Accuracy: 30.65%
# Epoch 28/150: Test Loss: 2.5396, Test Accuracy: 35.64%
#     Worker 0: Train Loss: 2.6569, Train Accuracy: 31.84%
#     Worker 1: Train Loss: 2.6572, Train Accuracy: 31.40%
#     Worker 2: Train Loss: 2.6393, Train Accuracy: 33.24%
#     Worker 3: Train Loss: 2.6575, Train Accuracy: 32.45%
#     Worker 4: Train Loss: 2.6365, Train Accuracy: 32.79%
#     Worker 5: Train Loss: 2.6297, Train Accuracy: 33.87%
#     Worker 6: Train Loss: 2.6716, Train Accuracy: 31.38%
#     Worker 7: Train Loss: 2.6520, Train Accuracy: 32.50%
# Epoch 29/150: Test Loss: 2.4966, Test Accuracy: 36.01%
#     Worker 0: Train Loss: 2.6375, Train Accuracy: 32.42%
#     Worker 1: Train Loss: 2.6057, Train Accuracy: 33.04%
#     Worker 2: Train Loss: 2.6560, Train Accuracy: 32.33%
#     Worker 3: Train Loss: 2.6504, Train Accuracy: 32.26%
#     Worker 4: Train Loss: 2.5700, Train Accuracy: 33.98%
#     Worker 5: Train Loss: 2.5755, Train Accuracy: 34.82%
#     Worker 6: Train Loss: 2.6530, Train Accuracy: 32.41%
#     Worker 7: Train Loss: 2.6339, Train Accuracy: 33.43%
# Epoch 30/150: Test Loss: 2.4802, Test Accuracy: 36.09%
#     Worker 0: Train Loss: 2.6016, Train Accuracy: 33.21%
#     Worker 1: Train Loss: 2.5660, Train Accuracy: 34.55%
#     Worker 2: Train Loss: 2.5709, Train Accuracy: 34.53%
#     Worker 3: Train Loss: 2.6210, Train Accuracy: 32.51%
#     Worker 4: Train Loss: 2.5529, Train Accuracy: 34.04%
#     Worker 5: Train Loss: 2.5566, Train Accuracy: 34.61%
#     Worker 6: Train Loss: 2.6075, Train Accuracy: 33.04%
#     Worker 7: Train Loss: 2.5978, Train Accuracy: 33.04%
# Epoch 31/150: Test Loss: 2.4399, Test Accuracy: 37.19%
#     Worker 0: Train Loss: 2.5582, Train Accuracy: 34.01%
#     Worker 1: Train Loss: 2.5469, Train Accuracy: 34.01%
#     Worker 2: Train Loss: 2.5239, Train Accuracy: 35.39%
#     Worker 3: Train Loss: 2.5432, Train Accuracy: 34.58%
#     Worker 4: Train Loss: 2.5196, Train Accuracy: 35.79%
#     Worker 5: Train Loss: 2.5190, Train Accuracy: 35.42%
#     Worker 6: Train Loss: 2.5680, Train Accuracy: 34.34%
#     Worker 7: Train Loss: 2.5449, Train Accuracy: 34.72%
# Epoch 32/150: Test Loss: 2.4146, Test Accuracy: 37.76%
#     Worker 0: Train Loss: 2.5078, Train Accuracy: 35.54%
#     Worker 1: Train Loss: 2.5034, Train Accuracy: 35.50%
#     Worker 2: Train Loss: 2.5298, Train Accuracy: 35.65%
#     Worker 3: Train Loss: 2.5296, Train Accuracy: 34.34%
#     Worker 4: Train Loss: 2.5002, Train Accuracy: 35.15%
#     Worker 5: Train Loss: 2.4778, Train Accuracy: 36.22%
#     Worker 6: Train Loss: 2.5345, Train Accuracy: 34.20%
#     Worker 7: Train Loss: 2.5342, Train Accuracy: 34.93%
# Epoch 33/150: Test Loss: 2.4008, Test Accuracy: 38.28%
#     Worker 0: Train Loss: 2.5025, Train Accuracy: 35.72%
#     Worker 1: Train Loss: 2.4765, Train Accuracy: 35.75%
#     Worker 2: Train Loss: 2.4861, Train Accuracy: 35.93%
#     Worker 3: Train Loss: 2.5087, Train Accuracy: 35.31%
#     Worker 4: Train Loss: 2.4743, Train Accuracy: 36.28%
#     Worker 5: Train Loss: 2.4748, Train Accuracy: 36.39%
#     Worker 6: Train Loss: 2.5192, Train Accuracy: 35.03%
#     Worker 7: Train Loss: 2.4891, Train Accuracy: 35.53%
# Epoch 34/150: Test Loss: 2.3556, Test Accuracy: 38.75%
#     Worker 0: Train Loss: 2.4741, Train Accuracy: 36.52%
#     Worker 1: Train Loss: 2.4342, Train Accuracy: 36.00%
#     Worker 2: Train Loss: 2.4553, Train Accuracy: 36.15%
#     Worker 3: Train Loss: 2.5039, Train Accuracy: 35.18%
#     Worker 4: Train Loss: 2.4200, Train Accuracy: 36.98%
#     Worker 5: Train Loss: 2.4207, Train Accuracy: 37.14%
#     Worker 6: Train Loss: 2.4812, Train Accuracy: 35.89%
#     Worker 7: Train Loss: 2.4680, Train Accuracy: 36.27%
# Epoch 35/150: Test Loss: 2.3430, Test Accuracy: 39.37%
#     Worker 0: Train Loss: 2.4420, Train Accuracy: 36.42%
#     Worker 1: Train Loss: 2.4207, Train Accuracy: 36.93%
#     Worker 2: Train Loss: 2.4327, Train Accuracy: 37.11%
#     Worker 3: Train Loss: 2.4618, Train Accuracy: 36.31%
#     Worker 4: Train Loss: 2.3875, Train Accuracy: 38.18%
#     Worker 5: Train Loss: 2.4019, Train Accuracy: 38.36%
#     Worker 6: Train Loss: 2.4624, Train Accuracy: 35.95%
#     Worker 7: Train Loss: 2.4570, Train Accuracy: 37.31%
# Epoch 36/150: Test Loss: 2.3177, Test Accuracy: 40.47%
#     Worker 0: Train Loss: 2.4253, Train Accuracy: 36.81%
#     Worker 1: Train Loss: 2.3987, Train Accuracy: 37.40%
#     Worker 2: Train Loss: 2.4258, Train Accuracy: 37.08%
#     Worker 3: Train Loss: 2.4035, Train Accuracy: 37.29%
#     Worker 4: Train Loss: 2.3643, Train Accuracy: 38.38%
#     Worker 5: Train Loss: 2.3815, Train Accuracy: 37.91%
#     Worker 6: Train Loss: 2.4463, Train Accuracy: 36.78%
#     Worker 7: Train Loss: 2.4061, Train Accuracy: 37.31%
# Epoch 37/150: Test Loss: 2.3068, Test Accuracy: 40.63%
#     Worker 0: Train Loss: 2.3908, Train Accuracy: 37.68%
#     Worker 1: Train Loss: 2.3739, Train Accuracy: 37.94%
#     Worker 2: Train Loss: 2.3822, Train Accuracy: 38.85%
#     Worker 3: Train Loss: 2.4189, Train Accuracy: 36.86%
#     Worker 4: Train Loss: 2.3291, Train Accuracy: 39.15%
#     Worker 5: Train Loss: 2.3578, Train Accuracy: 39.04%
#     Worker 6: Train Loss: 2.3951, Train Accuracy: 37.96%
#     Worker 7: Train Loss: 2.3693, Train Accuracy: 39.18%
# Epoch 38/150: Test Loss: 2.2796, Test Accuracy: 41.15%
#     Worker 0: Train Loss: 2.3800, Train Accuracy: 37.65%
#     Worker 1: Train Loss: 2.3285, Train Accuracy: 38.54%
#     Worker 2: Train Loss: 2.3295, Train Accuracy: 39.15%
#     Worker 3: Train Loss: 2.3765, Train Accuracy: 38.18%
#     Worker 4: Train Loss: 2.3392, Train Accuracy: 38.23%
#     Worker 5: Train Loss: 2.3192, Train Accuracy: 39.70%
#     Worker 6: Train Loss: 2.3786, Train Accuracy: 37.93%
#     Worker 7: Train Loss: 2.3311, Train Accuracy: 39.13%
# Epoch 39/150: Test Loss: 2.2941, Test Accuracy: 41.09%
#     Worker 0: Train Loss: 2.3155, Train Accuracy: 38.98%
#     Worker 1: Train Loss: 2.3398, Train Accuracy: 38.75%
#     Worker 2: Train Loss: 2.3349, Train Accuracy: 39.75%
#     Worker 3: Train Loss: 2.3492, Train Accuracy: 38.29%
#     Worker 4: Train Loss: 2.2966, Train Accuracy: 40.13%
#     Worker 5: Train Loss: 2.3215, Train Accuracy: 39.72%
#     Worker 6: Train Loss: 2.3460, Train Accuracy: 38.80%
#     Worker 7: Train Loss: 2.3226, Train Accuracy: 39.12%
# Epoch 40/150: Test Loss: 2.2770, Test Accuracy: 40.91%
#     Worker 0: Train Loss: 2.3536, Train Accuracy: 39.19%
#     Worker 1: Train Loss: 2.2914, Train Accuracy: 39.93%
#     Worker 2: Train Loss: 2.3168, Train Accuracy: 40.02%
#     Worker 3: Train Loss: 2.3151, Train Accuracy: 38.97%
#     Worker 4: Train Loss: 2.2839, Train Accuracy: 41.02%
#     Worker 5: Train Loss: 2.2621, Train Accuracy: 40.07%
#     Worker 6: Train Loss: 2.3240, Train Accuracy: 39.00%
#     Worker 7: Train Loss: 2.3381, Train Accuracy: 38.44%
# Epoch 41/150: Test Loss: 2.2524, Test Accuracy: 42.09%
#     Worker 0: Train Loss: 2.2979, Train Accuracy: 39.43%
#     Worker 1: Train Loss: 2.2833, Train Accuracy: 39.46%
#     Worker 2: Train Loss: 2.2622, Train Accuracy: 40.29%
#     Worker 3: Train Loss: 2.3175, Train Accuracy: 39.00%
#     Worker 4: Train Loss: 2.2466, Train Accuracy: 41.59%
#     Worker 5: Train Loss: 2.2626, Train Accuracy: 40.70%
#     Worker 6: Train Loss: 2.3023, Train Accuracy: 39.90%
#     Worker 7: Train Loss: 2.2832, Train Accuracy: 39.84%
# Epoch 42/150: Test Loss: 2.2270, Test Accuracy: 42.19%
#     Worker 0: Train Loss: 2.2602, Train Accuracy: 40.52%
#     Worker 1: Train Loss: 2.2549, Train Accuracy: 40.62%
#     Worker 2: Train Loss: 2.2815, Train Accuracy: 40.19%
#     Worker 3: Train Loss: 2.2815, Train Accuracy: 39.72%
#     Worker 4: Train Loss: 2.2540, Train Accuracy: 39.99%
#     Worker 5: Train Loss: 2.2215, Train Accuracy: 41.97%
#     Worker 6: Train Loss: 2.2764, Train Accuracy: 40.08%
#     Worker 7: Train Loss: 2.2559, Train Accuracy: 40.82%
# Epoch 43/150: Test Loss: 2.2156, Test Accuracy: 42.42%
#     Worker 0: Train Loss: 2.2719, Train Accuracy: 39.84%
#     Worker 1: Train Loss: 2.2147, Train Accuracy: 41.81%
#     Worker 2: Train Loss: 2.2474, Train Accuracy: 40.62%
#     Worker 3: Train Loss: 2.2479, Train Accuracy: 41.24%
#     Worker 4: Train Loss: 2.1967, Train Accuracy: 41.69%
#     Worker 5: Train Loss: 2.2558, Train Accuracy: 41.02%
#     Worker 6: Train Loss: 2.2514, Train Accuracy: 40.23%
#     Worker 7: Train Loss: 2.2778, Train Accuracy: 40.67%
# Epoch 44/150: Test Loss: 2.2126, Test Accuracy: 42.37%
#     Worker 0: Train Loss: 2.2378, Train Accuracy: 40.82%
#     Worker 1: Train Loss: 2.1970, Train Accuracy: 41.29%
#     Worker 2: Train Loss: 2.2168, Train Accuracy: 41.66%
#     Worker 3: Train Loss: 2.2229, Train Accuracy: 41.38%
#     Worker 4: Train Loss: 2.1685, Train Accuracy: 42.43%
#     Worker 5: Train Loss: 2.2037, Train Accuracy: 42.03%
#     Worker 6: Train Loss: 2.2411, Train Accuracy: 41.60%
#     Worker 7: Train Loss: 2.2316, Train Accuracy: 40.85%
# Epoch 45/150: Test Loss: 2.1945, Test Accuracy: 42.99%
#     Worker 0: Train Loss: 2.2099, Train Accuracy: 41.45%
#     Worker 1: Train Loss: 2.1892, Train Accuracy: 41.29%
#     Worker 2: Train Loss: 2.2147, Train Accuracy: 41.12%
#     Worker 3: Train Loss: 2.2511, Train Accuracy: 40.87%
#     Worker 4: Train Loss: 2.1715, Train Accuracy: 42.98%
#     Worker 5: Train Loss: 2.1987, Train Accuracy: 42.09%
#     Worker 6: Train Loss: 2.1863, Train Accuracy: 42.21%
#     Worker 7: Train Loss: 2.1808, Train Accuracy: 42.46%
# Epoch 46/150: Test Loss: 2.1825, Test Accuracy: 43.20%
#     Worker 0: Train Loss: 2.1723, Train Accuracy: 42.46%
#     Worker 1: Train Loss: 2.1398, Train Accuracy: 42.89%
#     Worker 2: Train Loss: 2.1845, Train Accuracy: 41.94%
#     Worker 3: Train Loss: 2.1766, Train Accuracy: 42.31%
#     Worker 4: Train Loss: 2.1671, Train Accuracy: 42.54%
#     Worker 5: Train Loss: 2.1648, Train Accuracy: 43.38%
#     Worker 6: Train Loss: 2.2219, Train Accuracy: 41.20%
#     Worker 7: Train Loss: 2.2143, Train Accuracy: 41.54%
# Epoch 47/150: Test Loss: 2.1682, Test Accuracy: 43.79%
#     Worker 0: Train Loss: 2.1787, Train Accuracy: 41.60%
#     Worker 1: Train Loss: 2.1527, Train Accuracy: 42.37%
#     Worker 2: Train Loss: 2.1510, Train Accuracy: 43.22%
#     Worker 3: Train Loss: 2.1808, Train Accuracy: 41.78%
#     Worker 4: Train Loss: 2.1174, Train Accuracy: 43.64%
#     Worker 5: Train Loss: 2.1169, Train Accuracy: 44.15%
#     Worker 6: Train Loss: 2.1739, Train Accuracy: 41.81%
#     Worker 7: Train Loss: 2.1639, Train Accuracy: 42.63%
# Epoch 48/150: Test Loss: 2.1675, Test Accuracy: 43.58%
#     Worker 0: Train Loss: 2.1525, Train Accuracy: 42.99%
#     Worker 1: Train Loss: 2.1010, Train Accuracy: 43.94%
#     Worker 2: Train Loss: 2.1429, Train Accuracy: 43.28%
#     Worker 3: Train Loss: 2.1250, Train Accuracy: 43.13%
#     Worker 4: Train Loss: 2.1138, Train Accuracy: 43.77%
#     Worker 5: Train Loss: 2.1370, Train Accuracy: 43.88%
#     Worker 6: Train Loss: 2.1773, Train Accuracy: 42.19%
#     Worker 7: Train Loss: 2.1207, Train Accuracy: 43.55%
# Epoch 49/150: Test Loss: 2.1461, Test Accuracy: 44.39%
#     Worker 0: Train Loss: 2.1164, Train Accuracy: 43.74%
#     Worker 1: Train Loss: 2.1175, Train Accuracy: 43.33%
#     Worker 2: Train Loss: 2.1070, Train Accuracy: 44.36%
#     Worker 3: Train Loss: 2.1377, Train Accuracy: 43.27%
#     Worker 4: Train Loss: 2.0892, Train Accuracy: 44.59%
#     Worker 5: Train Loss: 2.0924, Train Accuracy: 44.57%
#     Worker 6: Train Loss: 2.1437, Train Accuracy: 43.35%
#     Worker 7: Train Loss: 2.1268, Train Accuracy: 43.63%
# Epoch 50/150: Test Loss: 2.1415, Test Accuracy: 44.46%
#     Worker 0: Train Loss: 2.1038, Train Accuracy: 43.76%
#     Worker 1: Train Loss: 2.0540, Train Accuracy: 44.74%
#     Worker 2: Train Loss: 2.0858, Train Accuracy: 44.66%
#     Worker 3: Train Loss: 2.1352, Train Accuracy: 43.26%
#     Worker 4: Train Loss: 2.0876, Train Accuracy: 44.91%
#     Worker 5: Train Loss: 2.0971, Train Accuracy: 44.60%
#     Worker 6: Train Loss: 2.1098, Train Accuracy: 44.14%
#     Worker 7: Train Loss: 2.0948, Train Accuracy: 43.97%
# Epoch 51/150: Test Loss: 2.1355, Test Accuracy: 44.83%
#     Worker 0: Train Loss: 2.0874, Train Accuracy: 43.77%
#     Worker 1: Train Loss: 2.0522, Train Accuracy: 44.42%
#     Worker 2: Train Loss: 2.0864, Train Accuracy: 44.35%
#     Worker 3: Train Loss: 2.1251, Train Accuracy: 43.26%
#     Worker 4: Train Loss: 2.0586, Train Accuracy: 45.27%
#     Worker 5: Train Loss: 2.0507, Train Accuracy: 45.52%
#     Worker 6: Train Loss: 2.0962, Train Accuracy: 43.73%
#     Worker 7: Train Loss: 2.0951, Train Accuracy: 43.94%
# Epoch 52/150: Test Loss: 2.1207, Test Accuracy: 44.72%
#     Worker 0: Train Loss: 2.0608, Train Accuracy: 44.50%
#     Worker 1: Train Loss: 2.0387, Train Accuracy: 45.46%
#     Worker 2: Train Loss: 2.0652, Train Accuracy: 45.13%
#     Worker 3: Train Loss: 2.0723, Train Accuracy: 44.83%
#     Worker 4: Train Loss: 2.0195, Train Accuracy: 45.66%
#     Worker 5: Train Loss: 2.0396, Train Accuracy: 45.61%
#     Worker 6: Train Loss: 2.0725, Train Accuracy: 45.04%
#     Worker 7: Train Loss: 2.0718, Train Accuracy: 44.81%
# Epoch 53/150: Test Loss: 2.1056, Test Accuracy: 45.27%
#     Worker 0: Train Loss: 2.0674, Train Accuracy: 45.31%
#     Worker 1: Train Loss: 2.0307, Train Accuracy: 45.51%
#     Worker 2: Train Loss: 2.0487, Train Accuracy: 45.61%
#     Worker 3: Train Loss: 2.0410, Train Accuracy: 45.16%
#     Worker 4: Train Loss: 2.0188, Train Accuracy: 46.31%
#     Worker 5: Train Loss: 2.0272, Train Accuracy: 45.69%
#     Worker 6: Train Loss: 2.0719, Train Accuracy: 44.80%
#     Worker 7: Train Loss: 2.0650, Train Accuracy: 45.12%
# Epoch 54/150: Test Loss: 2.0987, Test Accuracy: 45.58%
#     Worker 0: Train Loss: 2.0222, Train Accuracy: 45.88%
#     Worker 1: Train Loss: 1.9866, Train Accuracy: 45.25%
#     Worker 2: Train Loss: 2.0143, Train Accuracy: 45.95%
#     Worker 3: Train Loss: 2.0634, Train Accuracy: 44.60%
#     Worker 4: Train Loss: 2.0075, Train Accuracy: 46.37%
#     Worker 5: Train Loss: 2.0012, Train Accuracy: 47.45%
#     Worker 6: Train Loss: 2.0480, Train Accuracy: 45.10%
#     Worker 7: Train Loss: 2.0282, Train Accuracy: 45.72%
# Epoch 55/150: Test Loss: 2.0984, Test Accuracy: 45.06%
#     Worker 0: Train Loss: 2.0404, Train Accuracy: 45.16%
#     Worker 1: Train Loss: 1.9821, Train Accuracy: 46.50%
#     Worker 2: Train Loss: 1.9952, Train Accuracy: 47.12%
#     Worker 3: Train Loss: 2.0104, Train Accuracy: 45.55%
#     Worker 4: Train Loss: 2.0126, Train Accuracy: 45.76%
#     Worker 5: Train Loss: 2.0048, Train Accuracy: 46.83%
#     Worker 6: Train Loss: 2.0131, Train Accuracy: 45.60%
#     Worker 7: Train Loss: 2.0109, Train Accuracy: 46.32%
# Epoch 56/150: Test Loss: 2.0969, Test Accuracy: 45.42%
#     Worker 0: Train Loss: 1.9918, Train Accuracy: 46.05%
#     Worker 1: Train Loss: 1.9611, Train Accuracy: 47.92%
#     Worker 2: Train Loss: 1.9932, Train Accuracy: 46.29%
#     Worker 3: Train Loss: 1.9918, Train Accuracy: 46.25%
#     Worker 4: Train Loss: 1.9285, Train Accuracy: 48.33%
#     Worker 5: Train Loss: 2.0113, Train Accuracy: 46.53%
#     Worker 6: Train Loss: 2.0219, Train Accuracy: 46.40%
#     Worker 7: Train Loss: 1.9713, Train Accuracy: 47.77%
# Epoch 57/150: Test Loss: 2.1003, Test Accuracy: 45.20%
#     Worker 0: Train Loss: 1.9762, Train Accuracy: 47.23%
#     Worker 1: Train Loss: 1.9536, Train Accuracy: 46.61%
#     Worker 2: Train Loss: 1.9551, Train Accuracy: 47.00%
#     Worker 3: Train Loss: 2.0063, Train Accuracy: 46.14%
#     Worker 4: Train Loss: 1.9862, Train Accuracy: 46.77%
#     Worker 5: Train Loss: 1.9904, Train Accuracy: 46.41%
#     Worker 6: Train Loss: 1.9968, Train Accuracy: 47.27%
#     Worker 7: Train Loss: 1.9790, Train Accuracy: 46.40%
# Epoch 58/150: Test Loss: 2.0886, Test Accuracy: 45.08%
#     Worker 0: Train Loss: 1.9621, Train Accuracy: 47.11%
#     Worker 1: Train Loss: 1.9252, Train Accuracy: 47.69%
#     Worker 2: Train Loss: 1.9714, Train Accuracy: 47.24%
#     Worker 3: Train Loss: 1.9544, Train Accuracy: 47.54%
#     Worker 4: Train Loss: 1.9037, Train Accuracy: 48.19%
#     Worker 5: Train Loss: 1.9268, Train Accuracy: 48.03%
#     Worker 6: Train Loss: 1.9931, Train Accuracy: 47.12%
#     Worker 7: Train Loss: 1.9757, Train Accuracy: 47.24%
# Epoch 59/150: Test Loss: 2.0812, Test Accuracy: 46.16%
#     Worker 0: Train Loss: 1.9667, Train Accuracy: 46.64%
#     Worker 1: Train Loss: 1.9187, Train Accuracy: 48.24%
#     Worker 2: Train Loss: 1.9098, Train Accuracy: 48.85%
#     Worker 3: Train Loss: 1.9624, Train Accuracy: 46.71%
#     Worker 4: Train Loss: 1.9350, Train Accuracy: 48.09%
#     Worker 5: Train Loss: 1.8955, Train Accuracy: 49.31%
#     Worker 6: Train Loss: 1.9720, Train Accuracy: 47.35%
#     Worker 7: Train Loss: 1.9310, Train Accuracy: 47.47%
# Epoch 60/150: Test Loss: 2.0833, Test Accuracy: 45.96%
#     Worker 0: Train Loss: 1.9450, Train Accuracy: 47.23%
#     Worker 1: Train Loss: 1.9187, Train Accuracy: 47.20%
#     Worker 2: Train Loss: 1.9338, Train Accuracy: 48.09%
#     Worker 3: Train Loss: 1.9622, Train Accuracy: 46.58%
#     Worker 4: Train Loss: 1.8620, Train Accuracy: 49.44%
#     Worker 5: Train Loss: 1.9290, Train Accuracy: 48.19%
#     Worker 6: Train Loss: 1.9278, Train Accuracy: 48.87%
#     Worker 7: Train Loss: 1.9510, Train Accuracy: 47.63%
# Epoch 61/150: Test Loss: 2.0630, Test Accuracy: 46.10%
#     Worker 0: Train Loss: 1.9068, Train Accuracy: 47.81%
#     Worker 1: Train Loss: 1.8855, Train Accuracy: 48.60%
#     Worker 2: Train Loss: 1.8988, Train Accuracy: 48.54%
#     Worker 3: Train Loss: 1.8958, Train Accuracy: 48.28%
#     Worker 4: Train Loss: 1.8994, Train Accuracy: 48.57%
#     Worker 5: Train Loss: 1.8877, Train Accuracy: 49.26%
#     Worker 6: Train Loss: 1.9548, Train Accuracy: 47.62%
#     Worker 7: Train Loss: 1.9231, Train Accuracy: 47.65%
# Epoch 62/150: Test Loss: 2.0503, Test Accuracy: 46.43%
#     Worker 0: Train Loss: 1.9294, Train Accuracy: 47.71%
#     Worker 1: Train Loss: 1.8667, Train Accuracy: 49.47%
#     Worker 2: Train Loss: 1.8788, Train Accuracy: 48.48%
#     Worker 3: Train Loss: 1.9227, Train Accuracy: 47.84%
#     Worker 4: Train Loss: 1.8839, Train Accuracy: 48.76%
#     Worker 5: Train Loss: 1.9104, Train Accuracy: 48.70%
#     Worker 6: Train Loss: 1.9371, Train Accuracy: 48.78%
#     Worker 7: Train Loss: 1.8775, Train Accuracy: 48.10%
# Epoch 63/150: Test Loss: 2.0445, Test Accuracy: 46.67%
#     Worker 0: Train Loss: 1.9011, Train Accuracy: 48.04%
#     Worker 1: Train Loss: 1.8595, Train Accuracy: 49.38%
#     Worker 2: Train Loss: 1.8746, Train Accuracy: 49.52%
#     Worker 3: Train Loss: 1.8975, Train Accuracy: 48.30%
#     Worker 4: Train Loss: 1.8530, Train Accuracy: 50.00%
#     Worker 5: Train Loss: 1.8695, Train Accuracy: 49.34%
#     Worker 6: Train Loss: 1.8828, Train Accuracy: 49.20%
#     Worker 7: Train Loss: 1.8990, Train Accuracy: 48.45%
# Epoch 64/150: Test Loss: 2.0372, Test Accuracy: 46.88%
#     Worker 0: Train Loss: 1.8645, Train Accuracy: 49.20%
#     Worker 1: Train Loss: 1.8362, Train Accuracy: 50.18%
#     Worker 2: Train Loss: 1.8531, Train Accuracy: 50.39%
#     Worker 3: Train Loss: 1.8670, Train Accuracy: 49.28%
#     Worker 4: Train Loss: 1.8498, Train Accuracy: 49.14%
#     Worker 5: Train Loss: 1.8570, Train Accuracy: 49.80%
#     Worker 6: Train Loss: 1.8977, Train Accuracy: 48.82%
#     Worker 7: Train Loss: 1.8552, Train Accuracy: 49.61%
# Epoch 65/150: Test Loss: 2.0518, Test Accuracy: 46.79%
#     Worker 0: Train Loss: 1.8527, Train Accuracy: 49.88%
#     Worker 1: Train Loss: 1.8330, Train Accuracy: 50.12%
#     Worker 2: Train Loss: 1.8361, Train Accuracy: 49.61%
#     Worker 3: Train Loss: 1.8570, Train Accuracy: 49.41%
#     Worker 4: Train Loss: 1.8279, Train Accuracy: 50.44%
#     Worker 5: Train Loss: 1.8225, Train Accuracy: 50.96%
#     Worker 6: Train Loss: 1.8776, Train Accuracy: 49.32%
#     Worker 7: Train Loss: 1.8677, Train Accuracy: 49.25%
# Epoch 66/150: Test Loss: 2.0314, Test Accuracy: 46.95%
#     Worker 0: Train Loss: 1.8556, Train Accuracy: 49.61%
#     Worker 1: Train Loss: 1.8368, Train Accuracy: 50.05%
#     Worker 2: Train Loss: 1.8407, Train Accuracy: 49.56%
#     Worker 3: Train Loss: 1.8401, Train Accuracy: 49.67%
#     Worker 4: Train Loss: 1.8025, Train Accuracy: 51.03%
#     Worker 5: Train Loss: 1.8270, Train Accuracy: 50.73%
#     Worker 6: Train Loss: 1.8850, Train Accuracy: 49.06%
#     Worker 7: Train Loss: 1.8528, Train Accuracy: 49.68%
# Epoch 67/150: Test Loss: 2.0367, Test Accuracy: 47.36%
#     Worker 0: Train Loss: 1.8207, Train Accuracy: 50.30%
#     Worker 1: Train Loss: 1.8072, Train Accuracy: 50.20%
#     Worker 2: Train Loss: 1.7996, Train Accuracy: 50.81%
#     Worker 3: Train Loss: 1.8388, Train Accuracy: 49.67%
#     Worker 4: Train Loss: 1.8205, Train Accuracy: 50.35%
#     Worker 5: Train Loss: 1.8056, Train Accuracy: 51.36%
#     Worker 6: Train Loss: 1.8478, Train Accuracy: 49.44%
#     Worker 7: Train Loss: 1.8262, Train Accuracy: 50.08%
# Epoch 68/150: Test Loss: 2.0350, Test Accuracy: 47.22%
#     Worker 0: Train Loss: 1.8059, Train Accuracy: 50.72%
#     Worker 1: Train Loss: 1.7869, Train Accuracy: 51.54%
#     Worker 2: Train Loss: 1.8057, Train Accuracy: 50.60%
#     Worker 3: Train Loss: 1.8012, Train Accuracy: 50.20%
#     Worker 4: Train Loss: 1.8041, Train Accuracy: 51.16%
#     Worker 5: Train Loss: 1.8058, Train Accuracy: 51.27%
#     Worker 6: Train Loss: 1.8109, Train Accuracy: 51.03%
#     Worker 7: Train Loss: 1.8118, Train Accuracy: 50.59%
# Epoch 69/150: Test Loss: 2.0321, Test Accuracy: 47.28%
#     Worker 0: Train Loss: 1.8258, Train Accuracy: 49.80%
#     Worker 1: Train Loss: 1.7646, Train Accuracy: 51.03%
#     Worker 2: Train Loss: 1.7909, Train Accuracy: 51.61%
#     Worker 3: Train Loss: 1.8373, Train Accuracy: 49.31%
#     Worker 4: Train Loss: 1.7758, Train Accuracy: 51.88%
#     Worker 5: Train Loss: 1.7773, Train Accuracy: 51.94%
#     Worker 6: Train Loss: 1.8394, Train Accuracy: 50.42%
#     Worker 7: Train Loss: 1.7979, Train Accuracy: 51.16%
# Epoch 70/150: Test Loss: 2.0049, Test Accuracy: 47.77%
#     Worker 0: Train Loss: 1.7808, Train Accuracy: 50.78%
#     Worker 1: Train Loss: 1.7510, Train Accuracy: 51.61%
#     Worker 2: Train Loss: 1.7712, Train Accuracy: 51.84%
#     Worker 3: Train Loss: 1.8275, Train Accuracy: 50.15%
#     Worker 4: Train Loss: 1.7652, Train Accuracy: 51.94%
#     Worker 5: Train Loss: 1.7454, Train Accuracy: 52.17%
#     Worker 6: Train Loss: 1.7990, Train Accuracy: 50.72%
#     Worker 7: Train Loss: 1.7608, Train Accuracy: 51.90%
# Epoch 71/150: Test Loss: 2.0304, Test Accuracy: 47.46%
#     Worker 0: Train Loss: 1.7689, Train Accuracy: 51.03%
#     Worker 1: Train Loss: 1.7505, Train Accuracy: 51.28%
#     Worker 2: Train Loss: 1.7824, Train Accuracy: 51.64%
#     Worker 3: Train Loss: 1.7884, Train Accuracy: 50.44%
#     Worker 4: Train Loss: 1.7547, Train Accuracy: 51.57%
#     Worker 5: Train Loss: 1.7592, Train Accuracy: 52.29%
#     Worker 6: Train Loss: 1.8038, Train Accuracy: 51.13%
#     Worker 7: Train Loss: 1.7357, Train Accuracy: 52.23%
# Epoch 72/150: Test Loss: 2.0057, Test Accuracy: 47.46%
#     Worker 0: Train Loss: 1.7691, Train Accuracy: 51.13%
#     Worker 1: Train Loss: 1.7467, Train Accuracy: 51.85%
#     Worker 2: Train Loss: 1.7410, Train Accuracy: 52.13%
#     Worker 3: Train Loss: 1.7560, Train Accuracy: 51.76%
#     Worker 4: Train Loss: 1.7723, Train Accuracy: 51.61%
#     Worker 5: Train Loss: 1.7359, Train Accuracy: 52.53%
#     Worker 6: Train Loss: 1.8061, Train Accuracy: 50.68%
#     Worker 7: Train Loss: 1.7600, Train Accuracy: 52.11%
# Epoch 73/150: Test Loss: 2.0036, Test Accuracy: 47.86%
#     Worker 0: Train Loss: 1.7504, Train Accuracy: 51.48%
#     Worker 1: Train Loss: 1.7024, Train Accuracy: 52.11%
#     Worker 2: Train Loss: 1.7502, Train Accuracy: 51.85%
#     Worker 3: Train Loss: 1.7449, Train Accuracy: 52.41%
#     Worker 4: Train Loss: 1.6855, Train Accuracy: 53.83%
#     Worker 5: Train Loss: 1.7268, Train Accuracy: 52.94%
#     Worker 6: Train Loss: 1.7609, Train Accuracy: 51.60%
#     Worker 7: Train Loss: 1.7535, Train Accuracy: 52.16%
# Epoch 74/150: Test Loss: 2.0026, Test Accuracy: 47.77%
#     Worker 0: Train Loss: 1.7363, Train Accuracy: 52.25%
#     Worker 1: Train Loss: 1.6912, Train Accuracy: 52.95%
#     Worker 2: Train Loss: 1.7216, Train Accuracy: 52.13%
#     Worker 3: Train Loss: 1.7469, Train Accuracy: 52.68%
#     Worker 4: Train Loss: 1.7094, Train Accuracy: 53.32%
#     Worker 5: Train Loss: 1.7473, Train Accuracy: 52.74%
#     Worker 6: Train Loss: 1.7587, Train Accuracy: 51.54%
#     Worker 7: Train Loss: 1.7263, Train Accuracy: 52.70%
# Epoch 75/150: Test Loss: 2.0127, Test Accuracy: 47.63%
#     Worker 0: Train Loss: 1.7141, Train Accuracy: 52.73%
#     Worker 1: Train Loss: 1.7119, Train Accuracy: 52.19%
#     Worker 2: Train Loss: 1.7659, Train Accuracy: 51.28%
#     Worker 3: Train Loss: 1.7451, Train Accuracy: 51.76%
#     Worker 4: Train Loss: 1.7142, Train Accuracy: 52.79%
#     Worker 5: Train Loss: 1.6806, Train Accuracy: 53.53%
#     Worker 6: Train Loss: 1.7562, Train Accuracy: 51.58%
#     Worker 7: Train Loss: 1.7176, Train Accuracy: 53.01%
# Epoch 76/150: Test Loss: 1.9962, Test Accuracy: 48.01%
#     Worker 0: Train Loss: 1.7219, Train Accuracy: 52.67%
#     Worker 1: Train Loss: 1.6774, Train Accuracy: 53.66%
#     Worker 2: Train Loss: 1.6789, Train Accuracy: 53.62%
#     Worker 3: Train Loss: 1.7043, Train Accuracy: 52.92%
#     Worker 4: Train Loss: 1.6800, Train Accuracy: 54.34%
#     Worker 5: Train Loss: 1.6891, Train Accuracy: 54.36%
#     Worker 6: Train Loss: 1.7544, Train Accuracy: 52.73%
#     Worker 7: Train Loss: 1.6818, Train Accuracy: 52.94%
# Epoch 77/150: Test Loss: 1.9878, Test Accuracy: 48.20%
#     Worker 0: Train Loss: 1.6882, Train Accuracy: 53.18%
#     Worker 1: Train Loss: 1.6793, Train Accuracy: 52.46%
#     Worker 2: Train Loss: 1.6825, Train Accuracy: 53.96%
#     Worker 3: Train Loss: 1.7328, Train Accuracy: 51.94%
#     Worker 4: Train Loss: 1.6834, Train Accuracy: 53.72%
#     Worker 5: Train Loss: 1.6934, Train Accuracy: 53.18%
#     Worker 6: Train Loss: 1.7222, Train Accuracy: 52.86%
#     Worker 7: Train Loss: 1.6805, Train Accuracy: 53.80%
# Epoch 78/150: Test Loss: 2.0012, Test Accuracy: 47.92%
#     Worker 0: Train Loss: 1.6926, Train Accuracy: 52.22%
#     Worker 1: Train Loss: 1.6357, Train Accuracy: 54.54%
#     Worker 2: Train Loss: 1.6737, Train Accuracy: 53.71%
#     Worker 3: Train Loss: 1.6775, Train Accuracy: 52.40%
#     Worker 4: Train Loss: 1.6736, Train Accuracy: 54.19%
#     Worker 5: Train Loss: 1.6749, Train Accuracy: 54.58%
#     Worker 6: Train Loss: 1.7124, Train Accuracy: 52.82%
#     Worker 7: Train Loss: 1.7023, Train Accuracy: 52.94%
# Epoch 79/150: Test Loss: 1.9792, Test Accuracy: 48.26%
#     Worker 0: Train Loss: 1.6731, Train Accuracy: 53.72%
#     Worker 1: Train Loss: 1.6538, Train Accuracy: 53.83%
#     Worker 2: Train Loss: 1.6609, Train Accuracy: 54.10%
#     Worker 3: Train Loss: 1.6986, Train Accuracy: 53.36%
#     Worker 4: Train Loss: 1.6582, Train Accuracy: 54.36%
#     Worker 5: Train Loss: 1.6517, Train Accuracy: 54.87%
#     Worker 6: Train Loss: 1.7173, Train Accuracy: 53.44%
#     Worker 7: Train Loss: 1.6326, Train Accuracy: 53.98%
# Epoch 80/150: Test Loss: 1.9817, Test Accuracy: 48.98%
#     Worker 0: Train Loss: 1.6703, Train Accuracy: 53.96%
#     Worker 1: Train Loss: 1.6279, Train Accuracy: 55.09%
#     Worker 2: Train Loss: 1.6535, Train Accuracy: 54.64%
#     Worker 3: Train Loss: 1.6813, Train Accuracy: 53.33%
#     Worker 4: Train Loss: 1.6199, Train Accuracy: 55.70%
#     Worker 5: Train Loss: 1.6540, Train Accuracy: 54.27%
#     Worker 6: Train Loss: 1.6882, Train Accuracy: 53.56%
#     Worker 7: Train Loss: 1.6729, Train Accuracy: 53.74%
# Epoch 81/150: Test Loss: 1.9924, Test Accuracy: 48.66%
#     Worker 0: Train Loss: 1.6519, Train Accuracy: 53.86%
#     Worker 1: Train Loss: 1.6269, Train Accuracy: 54.96%
#     Worker 2: Train Loss: 1.6505, Train Accuracy: 54.57%
#     Worker 3: Train Loss: 1.6528, Train Accuracy: 54.43%
#     Worker 4: Train Loss: 1.6334, Train Accuracy: 55.19%
#     Worker 5: Train Loss: 1.6280, Train Accuracy: 55.88%
#     Worker 6: Train Loss: 1.6778, Train Accuracy: 53.78%
#     Worker 7: Train Loss: 1.6096, Train Accuracy: 55.09%
# Epoch 82/150: Test Loss: 1.9901, Test Accuracy: 48.67%
#     Worker 0: Train Loss: 1.6172, Train Accuracy: 55.25%
#     Worker 1: Train Loss: 1.6330, Train Accuracy: 53.92%
#     Worker 2: Train Loss: 1.6309, Train Accuracy: 55.29%
#     Worker 3: Train Loss: 1.6538, Train Accuracy: 54.11%
#     Worker 4: Train Loss: 1.6248, Train Accuracy: 55.76%
#     Worker 5: Train Loss: 1.6084, Train Accuracy: 56.03%
#     Worker 6: Train Loss: 1.6600, Train Accuracy: 54.78%
#     Worker 7: Train Loss: 1.6250, Train Accuracy: 55.04%
# Epoch 83/150: Test Loss: 1.9864, Test Accuracy: 48.75%
#     Worker 0: Train Loss: 1.6173, Train Accuracy: 54.49%
#     Worker 1: Train Loss: 1.5637, Train Accuracy: 56.53%
#     Worker 2: Train Loss: 1.6213, Train Accuracy: 55.92%
#     Worker 3: Train Loss: 1.6485, Train Accuracy: 54.76%
#     Worker 4: Train Loss: 1.6036, Train Accuracy: 55.52%
#     Worker 5: Train Loss: 1.6173, Train Accuracy: 56.03%
#     Worker 6: Train Loss: 1.6507, Train Accuracy: 55.34%
#     Worker 7: Train Loss: 1.6185, Train Accuracy: 55.06%
# Epoch 84/150: Test Loss: 1.9872, Test Accuracy: 48.88%
#     Worker 0: Train Loss: 1.6361, Train Accuracy: 55.44%
#     Worker 1: Train Loss: 1.5872, Train Accuracy: 55.44%
#     Worker 2: Train Loss: 1.5876, Train Accuracy: 56.26%
#     Worker 3: Train Loss: 1.6278, Train Accuracy: 55.02%
#     Worker 4: Train Loss: 1.5969, Train Accuracy: 55.14%
#     Worker 5: Train Loss: 1.6144, Train Accuracy: 54.90%
#     Worker 6: Train Loss: 1.6365, Train Accuracy: 54.34%
#     Worker 7: Train Loss: 1.5798, Train Accuracy: 55.70%
# Epoch 85/150: Test Loss: 1.9831, Test Accuracy: 48.54%
#     Worker 0: Train Loss: 1.5749, Train Accuracy: 56.12%
#     Worker 1: Train Loss: 1.5698, Train Accuracy: 55.86%
#     Worker 2: Train Loss: 1.5968, Train Accuracy: 55.41%
#     Worker 3: Train Loss: 1.6106, Train Accuracy: 55.56%
#     Worker 4: Train Loss: 1.5730, Train Accuracy: 56.66%
#     Worker 5: Train Loss: 1.5794, Train Accuracy: 56.84%
#     Worker 6: Train Loss: 1.6264, Train Accuracy: 54.54%
#     Worker 7: Train Loss: 1.6151, Train Accuracy: 54.82%
# Epoch 86/150: Test Loss: 1.9930, Test Accuracy: 48.65%
#     Worker 0: Train Loss: 1.5849, Train Accuracy: 55.32%
#     Worker 1: Train Loss: 1.5556, Train Accuracy: 56.87%
#     Worker 2: Train Loss: 1.5664, Train Accuracy: 56.60%
#     Worker 3: Train Loss: 1.5864, Train Accuracy: 55.35%
#     Worker 4: Train Loss: 1.5745, Train Accuracy: 55.79%
#     Worker 5: Train Loss: 1.5516, Train Accuracy: 57.21%
#     Worker 6: Train Loss: 1.6446, Train Accuracy: 54.37%
#     Worker 7: Train Loss: 1.5798, Train Accuracy: 56.48%
# Epoch 87/150: Test Loss: 1.9918, Test Accuracy: 49.00%
#     Worker 0: Train Loss: 1.5801, Train Accuracy: 55.74%
#     Worker 1: Train Loss: 1.5550, Train Accuracy: 56.26%
#     Worker 2: Train Loss: 1.5740, Train Accuracy: 56.84%
#     Worker 3: Train Loss: 1.5515, Train Accuracy: 56.36%
#     Worker 4: Train Loss: 1.5578, Train Accuracy: 56.98%
#     Worker 5: Train Loss: 1.5859, Train Accuracy: 56.50%
#     Worker 6: Train Loss: 1.6025, Train Accuracy: 55.74%
#     Worker 7: Train Loss: 1.5795, Train Accuracy: 55.98%
# Epoch 88/150: Test Loss: 1.9955, Test Accuracy: 48.64%
#     Worker 0: Train Loss: 1.5767, Train Accuracy: 55.61%
#     Worker 1: Train Loss: 1.5457, Train Accuracy: 56.60%
#     Worker 2: Train Loss: 1.5527, Train Accuracy: 57.07%
#     Worker 3: Train Loss: 1.5498, Train Accuracy: 56.44%
#     Worker 4: Train Loss: 1.5485, Train Accuracy: 56.68%
#     Worker 5: Train Loss: 1.5653, Train Accuracy: 56.48%
#     Worker 6: Train Loss: 1.5773, Train Accuracy: 56.72%
#     Worker 7: Train Loss: 1.5829, Train Accuracy: 55.85%
# Epoch 89/150: Test Loss: 1.9825, Test Accuracy: 48.78%
#     Worker 0: Train Loss: 1.5695, Train Accuracy: 56.53%
#     Worker 1: Train Loss: 1.5746, Train Accuracy: 56.26%
#     Worker 2: Train Loss: 1.5430, Train Accuracy: 57.91%
#     Worker 3: Train Loss: 1.5996, Train Accuracy: 55.11%
#     Worker 4: Train Loss: 1.5285, Train Accuracy: 57.19%
#     Worker 5: Train Loss: 1.5497, Train Accuracy: 57.31%
#     Worker 6: Train Loss: 1.5900, Train Accuracy: 55.98%
#     Worker 7: Train Loss: 1.5355, Train Accuracy: 56.81%
# Epoch 90/150: Test Loss: 1.9787, Test Accuracy: 49.12%
#     Worker 0: Train Loss: 1.5596, Train Accuracy: 56.33%
#     Worker 1: Train Loss: 1.5109, Train Accuracy: 57.73%
#     Worker 2: Train Loss: 1.5584, Train Accuracy: 56.15%
#     Worker 3: Train Loss: 1.5389, Train Accuracy: 57.22%
#     Worker 4: Train Loss: 1.5325, Train Accuracy: 58.00%
#     Worker 5: Train Loss: 1.5282, Train Accuracy: 57.37%
#     Worker 6: Train Loss: 1.6036, Train Accuracy: 55.85%
#     Worker 7: Train Loss: 1.5421, Train Accuracy: 56.59%
# Epoch 91/150: Test Loss: 1.9757, Test Accuracy: 49.24%
#     Worker 0: Train Loss: 1.5259, Train Accuracy: 57.21%
#     Worker 1: Train Loss: 1.5058, Train Accuracy: 57.61%
#     Worker 2: Train Loss: 1.5242, Train Accuracy: 57.67%
#     Worker 3: Train Loss: 1.5555, Train Accuracy: 56.92%
#     Worker 4: Train Loss: 1.5272, Train Accuracy: 57.34%
#     Worker 5: Train Loss: 1.5024, Train Accuracy: 58.77%
#     Worker 6: Train Loss: 1.5497, Train Accuracy: 56.83%
#     Worker 7: Train Loss: 1.5400, Train Accuracy: 56.90%
# Epoch 92/150: Test Loss: 1.9854, Test Accuracy: 49.17%
#     Worker 0: Train Loss: 1.5192, Train Accuracy: 57.57%
#     Worker 1: Train Loss: 1.5070, Train Accuracy: 57.15%
#     Worker 2: Train Loss: 1.5291, Train Accuracy: 57.90%
#     Worker 3: Train Loss: 1.5232, Train Accuracy: 57.07%
#     Worker 4: Train Loss: 1.4928, Train Accuracy: 57.99%
#     Worker 5: Train Loss: 1.5221, Train Accuracy: 57.39%
#     Worker 6: Train Loss: 1.5472, Train Accuracy: 56.75%
#     Worker 7: Train Loss: 1.5030, Train Accuracy: 58.31%
# Epoch 93/150: Test Loss: 1.9817, Test Accuracy: 49.26%
#     Worker 0: Train Loss: 1.4964, Train Accuracy: 57.81%
#     Worker 1: Train Loss: 1.4981, Train Accuracy: 57.66%
#     Worker 2: Train Loss: 1.4942, Train Accuracy: 58.29%
#     Worker 3: Train Loss: 1.5306, Train Accuracy: 57.25%
#     Worker 4: Train Loss: 1.5017, Train Accuracy: 57.43%
#     Worker 5: Train Loss: 1.5173, Train Accuracy: 58.49%
#     Worker 6: Train Loss: 1.5418, Train Accuracy: 56.84%
#     Worker 7: Train Loss: 1.5104, Train Accuracy: 57.96%
# Epoch 94/150: Test Loss: 1.9754, Test Accuracy: 49.45%
#     Worker 0: Train Loss: 1.5068, Train Accuracy: 57.30%
#     Worker 1: Train Loss: 1.4590, Train Accuracy: 58.64%
# ...
#     Worker 6: Train Loss: 1.3501, Train Accuracy: 62.42%
#     Worker 7: Train Loss: 1.2934, Train Accuracy: 63.31%
# Epoch 120/150: Test Loss: 1.9894, Test Accuracy: 50.05%
#     Worker 0: Train Loss: 1.2912, Train Accuracy: 63.45%
#     Worker 1: Train Loss: 1.2676, Train Accuracy: 64.35%
#     Worker 2: Train Loss: 1.3035, Train Accuracy: 63.23%
#     Worker 3: Train Loss: 1.2936, Train Accuracy: 62.96%
#     Worker 4: Train Loss: 1.3009, Train Accuracy: 63.49%
#     Worker 5: Train Loss: 1.2817, Train Accuracy: 64.50%
#     Worker 6: Train Loss: 1.3140, Train Accuracy: 62.99%
#     Worker 7: Train Loss: 1.2948, Train Accuracy: 63.25%
# Epoch 121/150: Test Loss: 1.9854, Test Accuracy: 49.92%
#     Worker 0: Train Loss: 1.2908, Train Accuracy: 63.99%
#     Worker 1: Train Loss: 1.2935, Train Accuracy: 62.71%
#     Worker 2: Train Loss: 1.3085, Train Accuracy: 63.40%
#     Worker 3: Train Loss: 1.3162, Train Accuracy: 63.13%
#     Worker 4: Train Loss: 1.2907, Train Accuracy: 64.00%
#     Worker 5: Train Loss: 1.2829, Train Accuracy: 64.50%
#     Worker 6: Train Loss: 1.3229, Train Accuracy: 62.36%
#     Worker 7: Train Loss: 1.3275, Train Accuracy: 61.83%
# Epoch 122/150: Test Loss: 1.9896, Test Accuracy: 50.02%
#     Worker 0: Train Loss: 1.2836, Train Accuracy: 63.11%
#     Worker 1: Train Loss: 1.2765, Train Accuracy: 63.75%
#     Worker 2: Train Loss: 1.2883, Train Accuracy: 63.79%
#     Worker 3: Train Loss: 1.3020, Train Accuracy: 63.22%
#     Worker 4: Train Loss: 1.2726, Train Accuracy: 63.61%
#     Worker 5: Train Loss: 1.2856, Train Accuracy: 64.11%
#     Worker 6: Train Loss: 1.3133, Train Accuracy: 62.03%
#     Worker 7: Train Loss: 1.3330, Train Accuracy: 62.81%
# Epoch 123/150: Test Loss: 1.9834, Test Accuracy: 50.13%
#     Worker 0: Train Loss: 1.2888, Train Accuracy: 63.31%
#     Worker 1: Train Loss: 1.2801, Train Accuracy: 62.93%
#     Worker 2: Train Loss: 1.2729, Train Accuracy: 64.09%
#     Worker 3: Train Loss: 1.2736, Train Accuracy: 63.67%
#     Worker 4: Train Loss: 1.2933, Train Accuracy: 63.22%
#     Worker 5: Train Loss: 1.2963, Train Accuracy: 63.52%
#     Worker 6: Train Loss: 1.3112, Train Accuracy: 63.37%
#     Worker 7: Train Loss: 1.2797, Train Accuracy: 63.99%
# Epoch 124/150: Test Loss: 1.9866, Test Accuracy: 50.30%
#     Worker 0: Train Loss: 1.2749, Train Accuracy: 63.43%
#     Worker 1: Train Loss: 1.2726, Train Accuracy: 63.64%
#     Worker 2: Train Loss: 1.2636, Train Accuracy: 64.56%
#     Worker 3: Train Loss: 1.3239, Train Accuracy: 62.66%
#     Worker 4: Train Loss: 1.2546, Train Accuracy: 64.53%
#     Worker 5: Train Loss: 1.2687, Train Accuracy: 64.37%
#     Worker 6: Train Loss: 1.3189, Train Accuracy: 62.71%
#     Worker 7: Train Loss: 1.2961, Train Accuracy: 63.43%
# Epoch 125/150: Test Loss: 1.9860, Test Accuracy: 50.15%
#     Worker 0: Train Loss: 1.2824, Train Accuracy: 63.25%
#     Worker 1: Train Loss: 1.2483, Train Accuracy: 64.44%
#     Worker 2: Train Loss: 1.2867, Train Accuracy: 64.59%
#     Worker 3: Train Loss: 1.2788, Train Accuracy: 63.84%
#     Worker 4: Train Loss: 1.2637, Train Accuracy: 64.26%
#     Worker 5: Train Loss: 1.2714, Train Accuracy: 64.27%
#     Worker 6: Train Loss: 1.2991, Train Accuracy: 62.87%
#     Worker 7: Train Loss: 1.2641, Train Accuracy: 64.53%
# Epoch 126/150: Test Loss: 1.9846, Test Accuracy: 50.37%
#     Worker 0: Train Loss: 1.2674, Train Accuracy: 64.06%
#     Worker 1: Train Loss: 1.2305, Train Accuracy: 64.17%
#     Worker 2: Train Loss: 1.2674, Train Accuracy: 64.97%
#     Worker 3: Train Loss: 1.2778, Train Accuracy: 63.55%
#     Worker 4: Train Loss: 1.2487, Train Accuracy: 64.68%
#     Worker 5: Train Loss: 1.2633, Train Accuracy: 65.39%
#     Worker 6: Train Loss: 1.3242, Train Accuracy: 63.16%
#     Worker 7: Train Loss: 1.2751, Train Accuracy: 63.64%
# Epoch 127/150: Test Loss: 1.9860, Test Accuracy: 50.42%
#     Worker 0: Train Loss: 1.2699, Train Accuracy: 64.14%
#     Worker 1: Train Loss: 1.2409, Train Accuracy: 64.85%
#     Worker 2: Train Loss: 1.2411, Train Accuracy: 65.01%
#     Worker 3: Train Loss: 1.2785, Train Accuracy: 63.78%
#     Worker 4: Train Loss: 1.2570, Train Accuracy: 64.98%
#     Worker 5: Train Loss: 1.2693, Train Accuracy: 64.82%
#     Worker 6: Train Loss: 1.3078, Train Accuracy: 62.86%
#     Worker 7: Train Loss: 1.2750, Train Accuracy: 63.49%
# Epoch 128/150: Test Loss: 1.9863, Test Accuracy: 50.20%
#     Worker 0: Train Loss: 1.2616, Train Accuracy: 63.94%
#     Worker 1: Train Loss: 1.2494, Train Accuracy: 64.40%
#     Worker 2: Train Loss: 1.2613, Train Accuracy: 64.55%
#     Worker 3: Train Loss: 1.2637, Train Accuracy: 64.27%
#     Worker 4: Train Loss: 1.2699, Train Accuracy: 64.09%
#     Worker 5: Train Loss: 1.2612, Train Accuracy: 64.58%
#     Worker 6: Train Loss: 1.3117, Train Accuracy: 63.26%
#     Worker 7: Train Loss: 1.2729, Train Accuracy: 63.58%
# Epoch 129/150: Test Loss: 1.9892, Test Accuracy: 50.30%
#     Worker 0: Train Loss: 1.2831, Train Accuracy: 64.09%
#     Worker 1: Train Loss: 1.2500, Train Accuracy: 64.97%
#     Worker 2: Train Loss: 1.2582, Train Accuracy: 64.74%
#     Worker 3: Train Loss: 1.2807, Train Accuracy: 63.84%
#     Worker 4: Train Loss: 1.2435, Train Accuracy: 64.26%
#     Worker 5: Train Loss: 1.2508, Train Accuracy: 64.88%
#     Worker 6: Train Loss: 1.2831, Train Accuracy: 64.08%
#     Worker 7: Train Loss: 1.2553, Train Accuracy: 64.26%
# Epoch 130/150: Test Loss: 1.9875, Test Accuracy: 50.53%
#     Worker 0: Train Loss: 1.2413, Train Accuracy: 65.01%
#     Worker 1: Train Loss: 1.2377, Train Accuracy: 64.77%
#     Worker 2: Train Loss: 1.2368, Train Accuracy: 65.39%
#     Worker 3: Train Loss: 1.2647, Train Accuracy: 64.02%
#     Worker 4: Train Loss: 1.2668, Train Accuracy: 64.47%
#     Worker 5: Train Loss: 1.2529, Train Accuracy: 64.94%
#     Worker 6: Train Loss: 1.2923, Train Accuracy: 63.60%
#     Worker 7: Train Loss: 1.2499, Train Accuracy: 64.77%
# Epoch 131/150: Test Loss: 1.9878, Test Accuracy: 50.25%
#     Worker 0: Train Loss: 1.2572, Train Accuracy: 63.70%
#     Worker 1: Train Loss: 1.2476, Train Accuracy: 64.41%
#     Worker 2: Train Loss: 1.2480, Train Accuracy: 65.12%
#     Worker 3: Train Loss: 1.2487, Train Accuracy: 63.87%
#     Worker 4: Train Loss: 1.2369, Train Accuracy: 65.15%
#     Worker 5: Train Loss: 1.2547, Train Accuracy: 64.82%
#     Worker 6: Train Loss: 1.2822, Train Accuracy: 63.88%
#     Worker 7: Train Loss: 1.2494, Train Accuracy: 63.85%
# Epoch 132/150: Test Loss: 1.9878, Test Accuracy: 50.41%
#     Worker 0: Train Loss: 1.2587, Train Accuracy: 64.27%
#     Worker 1: Train Loss: 1.2269, Train Accuracy: 64.80%
#     Worker 2: Train Loss: 1.2465, Train Accuracy: 65.01%
#     Worker 3: Train Loss: 1.2710, Train Accuracy: 63.85%
#     Worker 4: Train Loss: 1.2523, Train Accuracy: 64.79%
#     Worker 5: Train Loss: 1.2605, Train Accuracy: 64.17%
#     Worker 6: Train Loss: 1.2858, Train Accuracy: 63.88%
#     Worker 7: Train Loss: 1.2440, Train Accuracy: 65.19%
# Epoch 133/150: Test Loss: 1.9891, Test Accuracy: 50.36%
#     Worker 0: Train Loss: 1.2682, Train Accuracy: 63.99%
#     Worker 1: Train Loss: 1.2260, Train Accuracy: 65.18%
#     Worker 2: Train Loss: 1.2481, Train Accuracy: 64.67%
#     Worker 3: Train Loss: 1.2555, Train Accuracy: 64.31%
#     Worker 4: Train Loss: 1.2343, Train Accuracy: 65.12%
#     Worker 5: Train Loss: 1.2474, Train Accuracy: 64.85%
#     Worker 6: Train Loss: 1.2784, Train Accuracy: 63.85%
#     Worker 7: Train Loss: 1.2572, Train Accuracy: 64.43%
# Epoch 134/150: Test Loss: 1.9935, Test Accuracy: 50.35%
#     Worker 0: Train Loss: 1.2494, Train Accuracy: 65.38%
#     Worker 1: Train Loss: 1.2233, Train Accuracy: 64.98%
#     Worker 2: Train Loss: 1.2461, Train Accuracy: 65.15%
#     Worker 3: Train Loss: 1.2629, Train Accuracy: 63.87%
#     Worker 4: Train Loss: 1.2630, Train Accuracy: 64.29%
#     Worker 5: Train Loss: 1.2450, Train Accuracy: 65.57%
#     Worker 6: Train Loss: 1.2874, Train Accuracy: 63.16%
#     Worker 7: Train Loss: 1.2348, Train Accuracy: 65.27%
# Epoch 135/150: Test Loss: 1.9892, Test Accuracy: 50.45%
#     Worker 0: Train Loss: 1.2483, Train Accuracy: 64.06%
#     Worker 1: Train Loss: 1.2352, Train Accuracy: 65.16%
#     Worker 2: Train Loss: 1.2300, Train Accuracy: 66.10%
#     Worker 3: Train Loss: 1.2425, Train Accuracy: 64.55%
#     Worker 4: Train Loss: 1.2395, Train Accuracy: 64.89%
#     Worker 5: Train Loss: 1.2216, Train Accuracy: 65.33%
#     Worker 6: Train Loss: 1.2877, Train Accuracy: 64.11%
#     Worker 7: Train Loss: 1.2437, Train Accuracy: 65.30%
# Epoch 136/150: Test Loss: 1.9890, Test Accuracy: 50.22%
#     Worker 0: Train Loss: 1.2570, Train Accuracy: 64.55%
#     Worker 1: Train Loss: 1.2148, Train Accuracy: 64.89%
#     Worker 2: Train Loss: 1.2503, Train Accuracy: 65.18%
#     Worker 3: Train Loss: 1.2598, Train Accuracy: 64.65%
#     Worker 4: Train Loss: 1.2482, Train Accuracy: 65.03%
#     Worker 5: Train Loss: 1.2611, Train Accuracy: 65.15%
#     Worker 6: Train Loss: 1.2647, Train Accuracy: 64.49%
#     Worker 7: Train Loss: 1.2461, Train Accuracy: 64.58%
# Epoch 137/150: Test Loss: 1.9891, Test Accuracy: 50.39%
#     Worker 0: Train Loss: 1.2438, Train Accuracy: 64.70%
#     Worker 1: Train Loss: 1.2212, Train Accuracy: 65.18%
#     Worker 2: Train Loss: 1.2435, Train Accuracy: 64.41%
#     Worker 3: Train Loss: 1.2385, Train Accuracy: 64.17%
#     Worker 4: Train Loss: 1.2151, Train Accuracy: 65.41%
#     Worker 5: Train Loss: 1.2267, Train Accuracy: 66.11%
#     Worker 6: Train Loss: 1.2975, Train Accuracy: 63.61%
#     Worker 7: Train Loss: 1.2414, Train Accuracy: 64.62%
# Epoch 138/150: Test Loss: 1.9911, Test Accuracy: 50.51%
#     Worker 0: Train Loss: 1.2306, Train Accuracy: 65.16%
#     Worker 1: Train Loss: 1.2030, Train Accuracy: 65.63%
#     Worker 2: Train Loss: 1.1990, Train Accuracy: 66.84%
#     Worker 3: Train Loss: 1.2572, Train Accuracy: 63.99%
#     Worker 4: Train Loss: 1.2382, Train Accuracy: 64.92%
#     Worker 5: Train Loss: 1.2370, Train Accuracy: 65.95%
#     Worker 6: Train Loss: 1.2627, Train Accuracy: 63.90%
#     Worker 7: Train Loss: 1.2445, Train Accuracy: 64.11%
# Epoch 139/150: Test Loss: 1.9897, Test Accuracy: 50.41%
#     Worker 0: Train Loss: 1.2446, Train Accuracy: 64.15%
#     Worker 1: Train Loss: 1.2202, Train Accuracy: 65.13%
#     Worker 2: Train Loss: 1.2298, Train Accuracy: 65.18%
#     Worker 3: Train Loss: 1.2443, Train Accuracy: 64.52%
#     Worker 4: Train Loss: 1.2314, Train Accuracy: 64.55%
#     Worker 5: Train Loss: 1.2284, Train Accuracy: 66.10%
#     Worker 6: Train Loss: 1.2833, Train Accuracy: 63.61%
#     Worker 7: Train Loss: 1.2497, Train Accuracy: 64.98%
# Epoch 140/150: Test Loss: 1.9898, Test Accuracy: 50.30%
#     Worker 0: Train Loss: 1.2295, Train Accuracy: 64.97%
#     Worker 1: Train Loss: 1.2101, Train Accuracy: 66.31%
#     Worker 2: Train Loss: 1.2557, Train Accuracy: 64.65%
#     Worker 3: Train Loss: 1.2383, Train Accuracy: 65.27%
#     Worker 4: Train Loss: 1.2403, Train Accuracy: 64.55%
#     Worker 5: Train Loss: 1.2199, Train Accuracy: 65.99%
#     Worker 6: Train Loss: 1.2558, Train Accuracy: 64.97%
#     Worker 7: Train Loss: 1.2323, Train Accuracy: 65.25%
# Epoch 141/150: Test Loss: 1.9893, Test Accuracy: 50.40%
#     Worker 0: Train Loss: 1.2597, Train Accuracy: 64.23%
#     Worker 1: Train Loss: 1.2266, Train Accuracy: 65.50%
#     Worker 2: Train Loss: 1.2539, Train Accuracy: 64.80%
#     Worker 3: Train Loss: 1.2360, Train Accuracy: 65.09%
#     Worker 4: Train Loss: 1.2294, Train Accuracy: 64.67%
#     Worker 5: Train Loss: 1.2430, Train Accuracy: 64.95%
#     Worker 6: Train Loss: 1.2670, Train Accuracy: 64.62%
#     Worker 7: Train Loss: 1.2677, Train Accuracy: 64.37%
# Epoch 142/150: Test Loss: 1.9904, Test Accuracy: 50.33%
#     Worker 0: Train Loss: 1.2403, Train Accuracy: 64.95%
#     Worker 1: Train Loss: 1.2234, Train Accuracy: 65.10%
#     Worker 2: Train Loss: 1.2161, Train Accuracy: 66.04%
#     Worker 3: Train Loss: 1.2170, Train Accuracy: 65.32%
#     Worker 4: Train Loss: 1.2414, Train Accuracy: 65.21%
#     Worker 5: Train Loss: 1.2310, Train Accuracy: 66.16%
#     Worker 6: Train Loss: 1.2601, Train Accuracy: 64.55%
#     Worker 7: Train Loss: 1.2377, Train Accuracy: 65.33%
# Epoch 143/150: Test Loss: 1.9897, Test Accuracy: 50.42%
#     Worker 0: Train Loss: 1.2222, Train Accuracy: 65.13%
#     Worker 1: Train Loss: 1.2352, Train Accuracy: 64.92%
#     Worker 2: Train Loss: 1.2317, Train Accuracy: 65.36%
#     Worker 3: Train Loss: 1.2663, Train Accuracy: 64.46%
#     Worker 4: Train Loss: 1.2393, Train Accuracy: 65.21%
#     Worker 5: Train Loss: 1.2388, Train Accuracy: 65.07%
#     Worker 6: Train Loss: 1.2708, Train Accuracy: 64.26%
#     Worker 7: Train Loss: 1.2420, Train Accuracy: 65.22%
# Epoch 144/150: Test Loss: 1.9904, Test Accuracy: 50.33%
#     Worker 0: Train Loss: 1.2716, Train Accuracy: 63.02%
#     Worker 1: Train Loss: 1.2141, Train Accuracy: 65.27%
#     Worker 2: Train Loss: 1.2201, Train Accuracy: 65.56%
#     Worker 3: Train Loss: 1.2171, Train Accuracy: 65.60%
#     Worker 4: Train Loss: 1.2245, Train Accuracy: 64.77%
#     Worker 5: Train Loss: 1.2592, Train Accuracy: 64.46%
#     Worker 6: Train Loss: 1.2702, Train Accuracy: 64.18%
#     Worker 7: Train Loss: 1.2362, Train Accuracy: 65.41%
# Epoch 145/150: Test Loss: 1.9907, Test Accuracy: 50.40%
#     Worker 0: Train Loss: 1.2262, Train Accuracy: 64.88%
#     Worker 1: Train Loss: 1.1967, Train Accuracy: 65.92%
#     Worker 2: Train Loss: 1.2369, Train Accuracy: 65.35%
#     Worker 3: Train Loss: 1.2446, Train Accuracy: 64.58%
#     Worker 4: Train Loss: 1.2341, Train Accuracy: 64.86%
#     Worker 5: Train Loss: 1.2321, Train Accuracy: 64.53%
#     Worker 6: Train Loss: 1.2918, Train Accuracy: 63.66%
#     Worker 7: Train Loss: 1.2366, Train Accuracy: 65.42%
# Epoch 146/150: Test Loss: 1.9907, Test Accuracy: 50.32%
#     Worker 0: Train Loss: 1.2195, Train Accuracy: 65.68%
#     Worker 1: Train Loss: 1.2355, Train Accuracy: 64.80%
#     Worker 2: Train Loss: 1.2211, Train Accuracy: 66.23%
#     Worker 3: Train Loss: 1.2394, Train Accuracy: 64.92%
#     Worker 4: Train Loss: 1.2349, Train Accuracy: 64.98%
#     Worker 5: Train Loss: 1.2391, Train Accuracy: 65.06%
#     Worker 6: Train Loss: 1.2813, Train Accuracy: 63.78%
#     Worker 7: Train Loss: 1.2452, Train Accuracy: 64.52%
# Epoch 147/150: Test Loss: 1.9905, Test Accuracy: 50.33%
#     Worker 0: Train Loss: 1.2540, Train Accuracy: 63.57%
#     Worker 1: Train Loss: 1.2277, Train Accuracy: 64.76%
#     Worker 2: Train Loss: 1.2211, Train Accuracy: 65.49%
#     Worker 3: Train Loss: 1.2464, Train Accuracy: 64.53%
#     Worker 4: Train Loss: 1.2307, Train Accuracy: 65.64%
#     Worker 5: Train Loss: 1.2335, Train Accuracy: 65.88%
#     Worker 6: Train Loss: 1.2788, Train Accuracy: 64.16%
#     Worker 7: Train Loss: 1.2455, Train Accuracy: 65.02%
# Epoch 148/150: Test Loss: 1.9904, Test Accuracy: 50.33%
#     Worker 0: Train Loss: 1.2410, Train Accuracy: 65.13%
#     Worker 1: Train Loss: 1.2232, Train Accuracy: 65.00%
#     Worker 2: Train Loss: 1.2271, Train Accuracy: 65.48%
#     Worker 3: Train Loss: 1.2315, Train Accuracy: 64.59%
#     Worker 4: Train Loss: 1.2390, Train Accuracy: 65.24%
#     Worker 5: Train Loss: 1.2365, Train Accuracy: 65.38%
#     Worker 6: Train Loss: 1.2513, Train Accuracy: 64.50%
#     Worker 7: Train Loss: 1.2585, Train Accuracy: 64.09%
# Epoch 149/150: Test Loss: 1.9904, Test Accuracy: 50.33%
#     Worker 0: Train Loss: 1.2269, Train Accuracy: 64.82%
#     Worker 1: Train Loss: 1.2087, Train Accuracy: 65.57%
#     Worker 2: Train Loss: 1.2362, Train Accuracy: 65.32%
#     Worker 3: Train Loss: 1.2346, Train Accuracy: 65.07%
#     Worker 4: Train Loss: 1.2488, Train Accuracy: 64.55%
#     Worker 5: Train Loss: 1.2266, Train Accuracy: 65.22%
#     Worker 6: Train Loss: 1.2544, Train Accuracy: 64.86%
#     Worker 7: Train Loss: 1.2431, Train Accuracy: 65.22%
# Epoch 150/150: Test Loss: 1.9904, Test Accuracy: 50.34%
#     Worker 0: Train Loss: 1.2277, Train Accuracy: 64.86%
#     Worker 1: Train Loss: 1.2166, Train Accuracy: 65.41%
#     Worker 2: Train Loss: 1.2249, Train Accuracy: 65.98%
#     Worker 3: Train Loss: 1.2361, Train Accuracy: 65.22%
#     Worker 4: Train Loss: 1.2158, Train Accuracy: 65.53%
#     Worker 5: Train Loss: 1.2307, Train Accuracy: 65.28%
#     Worker 6: Train Loss: 1.2910, Train Accuracy: 63.54%
#     Worker 7: Train Loss: 1.2444, Train Accuracy: 64.73%
