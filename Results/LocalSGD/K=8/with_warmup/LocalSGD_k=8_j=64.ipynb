# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs - warmup_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")

    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch):
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            # Perform J local step before synchronization
            for j in range(J):
                try:
                    # Get a batch from the current worker's shard using next()
                    images, labels = next(shard_iterators[k])
                    images, labels = images.to(device), labels.to(device)  # Move to device
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

                except StopIteration:
                    # If the iterator has exhausted the data, restart the iterator
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k]) # Resume from the next batch
                    images, labels = images.to(device), labels.to(device)
                    # Perform optimization step
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        # Perform model synchronization
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            # Update each worker model with the global parameters
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
        else:
            warmup_factor = (epoch + 1) / warmup_epochs
            lr = warmup_factor * learning_rate
            for optimizer in optimizers:
                for param_group in optimizer.param_groups:
                    param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 8 --j 64
# Out:
# Training with K=8, J=64
# Global iteration per epoch: 2
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:04<00:00, 40.2MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00800
# Epoch 1/150: Test Loss: 4.5473, Test Accuracy: 2.78%
#     Worker 0: Train Loss: 4.5941, Train Accuracy: 1.57%
#     Worker 1: Train Loss: 4.5934, Train Accuracy: 1.37%
#     Worker 2: Train Loss: 4.5949, Train Accuracy: 1.43%
#     Worker 3: Train Loss: 4.5925, Train Accuracy: 1.16%
#     Worker 4: Train Loss: 4.5927, Train Accuracy: 1.20%
#     Worker 5: Train Loss: 4.5877, Train Accuracy: 1.63%
#     Worker 6: Train Loss: 4.5954, Train Accuracy: 1.52%
#     Worker 7: Train Loss: 4.5903, Train Accuracy: 1.27%
# Epoch 2/150: Test Loss: 4.4377, Test Accuracy: 4.06%
#     Worker 0: Train Loss: 4.5115, Train Accuracy: 3.22%
#     Worker 1: Train Loss: 4.5117, Train Accuracy: 2.97%
#     Worker 2: Train Loss: 4.5080, Train Accuracy: 2.97%
#     Worker 3: Train Loss: 4.5106, Train Accuracy: 3.10%
#     Worker 4: Train Loss: 4.5018, Train Accuracy: 3.13%
#     Worker 5: Train Loss: 4.4949, Train Accuracy: 3.35%
#     Worker 6: Train Loss: 4.5100, Train Accuracy: 3.00%
#     Worker 7: Train Loss: 4.5006, Train Accuracy: 3.08%
# Epoch 3/150: Test Loss: 4.1852, Test Accuracy: 6.04%
#     Worker 0: Train Loss: 4.3360, Train Accuracy: 4.55%
#     Worker 1: Train Loss: 4.3433, Train Accuracy: 4.10%
#     Worker 2: Train Loss: 4.3427, Train Accuracy: 4.48%
#     Worker 3: Train Loss: 4.3456, Train Accuracy: 3.88%
#     Worker 4: Train Loss: 4.3209, Train Accuracy: 4.94%
#     Worker 5: Train Loss: 4.3203, Train Accuracy: 4.50%
#     Worker 6: Train Loss: 4.3399, Train Accuracy: 4.26%
#     Worker 7: Train Loss: 4.3348, Train Accuracy: 4.61%
# Epoch 4/150: Test Loss: 4.0429, Test Accuracy: 8.07%
#     Worker 0: Train Loss: 4.1812, Train Accuracy: 5.88%
#     Worker 1: Train Loss: 4.1890, Train Accuracy: 5.60%
#     Worker 2: Train Loss: 4.1847, Train Accuracy: 5.94%
#     Worker 3: Train Loss: 4.1980, Train Accuracy: 5.79%
#     Worker 4: Train Loss: 4.1708, Train Accuracy: 5.87%
#     Worker 5: Train Loss: 4.1618, Train Accuracy: 5.71%
#     Worker 6: Train Loss: 4.1946, Train Accuracy: 5.49%
#     Worker 7: Train Loss: 4.1907, Train Accuracy: 5.82%
# Epoch 5/150: Test Loss: 3.9248, Test Accuracy: 9.84%
#     Worker 0: Train Loss: 4.0943, Train Accuracy: 6.65%
#     Worker 1: Train Loss: 4.0920, Train Accuracy: 7.09%
#     Worker 2: Train Loss: 4.0981, Train Accuracy: 6.89%
#     Worker 3: Train Loss: 4.1073, Train Accuracy: 6.57%
#     Worker 4: Train Loss: 4.0600, Train Accuracy: 7.29%
#     Worker 5: Train Loss: 4.0753, Train Accuracy: 7.27%
#     Worker 6: Train Loss: 4.1104, Train Accuracy: 6.28%
#     Worker 7: Train Loss: 4.1022, Train Accuracy: 6.95%
# Epoch 6/150: Test Loss: 3.8043, Test Accuracy: 12.01%
#     Worker 0: Train Loss: 3.9906, Train Accuracy: 8.53%
#     Worker 1: Train Loss: 4.0091, Train Accuracy: 7.82%
#     Worker 2: Train Loss: 3.9689, Train Accuracy: 8.94%
#     Worker 3: Train Loss: 4.0044, Train Accuracy: 8.04%
#     Worker 4: Train Loss: 3.9571, Train Accuracy: 8.86%
#     Worker 5: Train Loss: 3.9484, Train Accuracy: 8.63%
#     Worker 6: Train Loss: 3.9889, Train Accuracy: 8.30%
#     Worker 7: Train Loss: 3.9959, Train Accuracy: 8.20%
# Epoch 7/150: Test Loss: 3.6663, Test Accuracy: 14.51%
#     Worker 0: Train Loss: 3.8567, Train Accuracy: 10.58%
#     Worker 1: Train Loss: 3.8667, Train Accuracy: 10.10%
#     Worker 2: Train Loss: 3.8445, Train Accuracy: 10.73%
#     Worker 3: Train Loss: 3.8874, Train Accuracy: 10.24%
#     Worker 4: Train Loss: 3.8248, Train Accuracy: 10.53%
#     Worker 5: Train Loss: 3.8196, Train Accuracy: 10.89%
#     Worker 6: Train Loss: 3.8713, Train Accuracy: 10.19%
#     Worker 7: Train Loss: 3.8742, Train Accuracy: 10.27%
# Epoch 8/150: Test Loss: 3.5823, Test Accuracy: 15.87%
#     Worker 0: Train Loss: 3.7720, Train Accuracy: 11.53%
#     Worker 1: Train Loss: 3.7776, Train Accuracy: 11.15%
#     Worker 2: Train Loss: 3.7684, Train Accuracy: 12.23%
#     Worker 3: Train Loss: 3.8126, Train Accuracy: 10.72%
#     Worker 4: Train Loss: 3.7107, Train Accuracy: 13.00%
#     Worker 5: Train Loss: 3.7291, Train Accuracy: 12.14%
#     Worker 6: Train Loss: 3.7846, Train Accuracy: 11.24%
#     Worker 7: Train Loss: 3.7664, Train Accuracy: 11.92%
# Epoch 9/150: Test Loss: 3.5022, Test Accuracy: 17.65%
#     Worker 0: Train Loss: 3.6911, Train Accuracy: 12.80%
#     Worker 1: Train Loss: 3.6948, Train Accuracy: 12.61%
#     Worker 2: Train Loss: 3.6881, Train Accuracy: 13.15%
#     Worker 3: Train Loss: 3.7175, Train Accuracy: 12.51%
#     Worker 4: Train Loss: 3.6652, Train Accuracy: 13.28%
#     Worker 5: Train Loss: 3.6658, Train Accuracy: 13.29%
#     Worker 6: Train Loss: 3.7137, Train Accuracy: 12.77%
#     Worker 7: Train Loss: 3.6968, Train Accuracy: 12.89%
# Epoch 10/150: Test Loss: 3.4164, Test Accuracy: 18.79%
#     Worker 0: Train Loss: 3.6243, Train Accuracy: 13.59%
#     Worker 1: Train Loss: 3.6107, Train Accuracy: 14.29%
#     Worker 2: Train Loss: 3.6013, Train Accuracy: 15.24%
#     Worker 3: Train Loss: 3.6416, Train Accuracy: 13.75%
#     Worker 4: Train Loss: 3.5592, Train Accuracy: 14.74%
#     Worker 5: Train Loss: 3.5434, Train Accuracy: 15.81%
#     Worker 6: Train Loss: 3.5981, Train Accuracy: 14.32%
#     Worker 7: Train Loss: 3.6160, Train Accuracy: 14.33%
# Epoch 11/150: Test Loss: 3.3300, Test Accuracy: 20.43%
#     Worker 0: Train Loss: 3.5375, Train Accuracy: 14.87%
#     Worker 1: Train Loss: 3.5281, Train Accuracy: 15.47%
#     Worker 2: Train Loss: 3.5120, Train Accuracy: 15.83%
#     Worker 3: Train Loss: 3.5629, Train Accuracy: 15.64%
#     Worker 4: Train Loss: 3.4945, Train Accuracy: 15.96%
#     Worker 5: Train Loss: 3.4965, Train Accuracy: 16.14%
#     Worker 6: Train Loss: 3.5542, Train Accuracy: 14.87%
#     Worker 7: Train Loss: 3.5204, Train Accuracy: 16.46%
# Epoch 12/150: Test Loss: 3.2728, Test Accuracy: 21.82%
#     Worker 0: Train Loss: 3.4796, Train Accuracy: 16.30%
#     Worker 1: Train Loss: 3.4672, Train Accuracy: 16.24%
#     Worker 2: Train Loss: 3.4778, Train Accuracy: 17.07%
#     Worker 3: Train Loss: 3.5246, Train Accuracy: 15.85%
#     Worker 4: Train Loss: 3.4499, Train Accuracy: 16.66%
#     Worker 5: Train Loss: 3.4283, Train Accuracy: 17.25%
#     Worker 6: Train Loss: 3.4718, Train Accuracy: 17.18%
#     Worker 7: Train Loss: 3.4911, Train Accuracy: 16.51%
# Epoch 13/150: Test Loss: 3.2072, Test Accuracy: 22.64%
#     Worker 0: Train Loss: 3.4153, Train Accuracy: 17.10%
#     Worker 1: Train Loss: 3.4013, Train Accuracy: 17.71%
#     Worker 2: Train Loss: 3.4036, Train Accuracy: 18.08%
#     Worker 3: Train Loss: 3.4516, Train Accuracy: 17.25%
#     Worker 4: Train Loss: 3.3705, Train Accuracy: 18.27%
#     Worker 5: Train Loss: 3.3542, Train Accuracy: 18.65%
#     Worker 6: Train Loss: 3.4240, Train Accuracy: 17.45%
#     Worker 7: Train Loss: 3.4055, Train Accuracy: 17.67%
# Epoch 14/150: Test Loss: 3.1433, Test Accuracy: 23.71%
#     Worker 0: Train Loss: 3.3421, Train Accuracy: 19.05%
#     Worker 1: Train Loss: 3.3338, Train Accuracy: 18.65%
#     Worker 2: Train Loss: 3.3304, Train Accuracy: 19.61%
#     Worker 3: Train Loss: 3.3800, Train Accuracy: 18.37%
#     Worker 4: Train Loss: 3.2933, Train Accuracy: 19.76%
#     Worker 5: Train Loss: 3.2930, Train Accuracy: 19.92%
#     Worker 6: Train Loss: 3.3545, Train Accuracy: 18.58%
#     Worker 7: Train Loss: 3.3472, Train Accuracy: 18.54%
# Epoch 15/150: Test Loss: 3.0856, Test Accuracy: 25.12%
#     Worker 0: Train Loss: 3.2927, Train Accuracy: 19.50%
#     Worker 1: Train Loss: 3.2959, Train Accuracy: 19.23%
#     Worker 2: Train Loss: 3.2938, Train Accuracy: 19.79%
#     Worker 3: Train Loss: 3.3163, Train Accuracy: 19.47%
#     Worker 4: Train Loss: 3.2712, Train Accuracy: 20.99%
#     Worker 5: Train Loss: 3.2367, Train Accuracy: 20.76%
#     Worker 6: Train Loss: 3.3075, Train Accuracy: 19.87%
#     Worker 7: Train Loss: 3.2844, Train Accuracy: 19.77%
# Epoch 16/150: Test Loss: 3.0257, Test Accuracy: 26.35%
#     Worker 0: Train Loss: 3.2424, Train Accuracy: 20.77%
#     Worker 1: Train Loss: 3.1950, Train Accuracy: 21.40%
#     Worker 2: Train Loss: 3.2462, Train Accuracy: 20.54%
#     Worker 3: Train Loss: 3.2530, Train Accuracy: 20.40%
#     Worker 4: Train Loss: 3.1979, Train Accuracy: 21.80%
#     Worker 5: Train Loss: 3.1960, Train Accuracy: 22.11%
#     Worker 6: Train Loss: 3.2404, Train Accuracy: 20.92%
#     Worker 7: Train Loss: 3.2234, Train Accuracy: 21.37%
# Epoch 17/150: Test Loss: 2.9661, Test Accuracy: 27.31%
#     Worker 0: Train Loss: 3.1627, Train Accuracy: 22.15%
#     Worker 1: Train Loss: 3.1602, Train Accuracy: 21.38%
#     Worker 2: Train Loss: 3.1859, Train Accuracy: 22.12%
#     Worker 3: Train Loss: 3.1978, Train Accuracy: 21.82%
#     Worker 4: Train Loss: 3.1448, Train Accuracy: 22.02%
#     Worker 5: Train Loss: 3.1361, Train Accuracy: 22.89%
#     Worker 6: Train Loss: 3.2195, Train Accuracy: 20.61%
#     Worker 7: Train Loss: 3.1587, Train Accuracy: 21.94%
# Epoch 18/150: Test Loss: 2.9260, Test Accuracy: 28.31%
#     Worker 0: Train Loss: 3.1347, Train Accuracy: 22.47%
#     Worker 1: Train Loss: 3.1372, Train Accuracy: 22.67%
#     Worker 2: Train Loss: 3.1158, Train Accuracy: 23.75%
#     Worker 3: Train Loss: 3.1763, Train Accuracy: 21.62%
#     Worker 4: Train Loss: 3.1099, Train Accuracy: 23.19%
#     Worker 5: Train Loss: 3.0680, Train Accuracy: 23.73%
#     Worker 6: Train Loss: 3.1483, Train Accuracy: 22.33%
#     Worker 7: Train Loss: 3.1401, Train Accuracy: 22.56%
# Epoch 19/150: Test Loss: 2.8757, Test Accuracy: 28.89%
#     Worker 0: Train Loss: 3.0928, Train Accuracy: 23.13%
#     Worker 1: Train Loss: 3.0442, Train Accuracy: 24.86%
#     Worker 2: Train Loss: 3.0963, Train Accuracy: 23.41%
#     Worker 3: Train Loss: 3.1190, Train Accuracy: 22.85%
#     Worker 4: Train Loss: 3.0555, Train Accuracy: 23.71%
#     Worker 5: Train Loss: 3.0536, Train Accuracy: 24.33%
#     Worker 6: Train Loss: 3.1294, Train Accuracy: 23.18%
#     Worker 7: Train Loss: 3.0573, Train Accuracy: 23.75%
# Epoch 20/150: Test Loss: 2.8188, Test Accuracy: 29.94%
#     Worker 0: Train Loss: 3.0409, Train Accuracy: 24.28%
#     Worker 1: Train Loss: 3.0061, Train Accuracy: 25.29%
#     Worker 2: Train Loss: 3.0185, Train Accuracy: 24.59%
#     Worker 3: Train Loss: 3.0426, Train Accuracy: 24.42%
#     Worker 4: Train Loss: 2.9890, Train Accuracy: 25.74%
#     Worker 5: Train Loss: 3.0099, Train Accuracy: 25.28%
#     Worker 6: Train Loss: 3.0312, Train Accuracy: 24.28%
#     Worker 7: Train Loss: 3.0272, Train Accuracy: 24.79%
# Epoch 21/150: Test Loss: 2.7906, Test Accuracy: 30.50%
#     Worker 0: Train Loss: 2.9874, Train Accuracy: 26.06%
#     Worker 1: Train Loss: 2.9833, Train Accuracy: 25.24%
#     Worker 2: Train Loss: 2.9988, Train Accuracy: 25.24%
#     Worker 3: Train Loss: 3.0232, Train Accuracy: 24.58%
#     Worker 4: Train Loss: 2.9693, Train Accuracy: 26.16%
#     Worker 5: Train Loss: 2.9798, Train Accuracy: 25.25%
#     Worker 6: Train Loss: 3.0253, Train Accuracy: 24.35%
#     Worker 7: Train Loss: 2.9932, Train Accuracy: 25.65%
# Epoch 22/150: Test Loss: 2.7237, Test Accuracy: 31.94%
#     Worker 0: Train Loss: 2.9630, Train Accuracy: 26.19%
#     Worker 1: Train Loss: 2.9068, Train Accuracy: 26.85%
#     Worker 2: Train Loss: 2.9394, Train Accuracy: 26.73%
#     Worker 3: Train Loss: 2.9576, Train Accuracy: 25.75%
#     Worker 4: Train Loss: 2.9090, Train Accuracy: 26.83%
#     Worker 5: Train Loss: 2.8776, Train Accuracy: 28.30%
#     Worker 6: Train Loss: 2.9702, Train Accuracy: 25.61%
#     Worker 7: Train Loss: 2.9478, Train Accuracy: 25.83%
# Epoch 23/150: Test Loss: 2.6759, Test Accuracy: 32.98%
#     Worker 0: Train Loss: 2.8875, Train Accuracy: 27.00%
#     Worker 1: Train Loss: 2.8618, Train Accuracy: 27.69%
#     Worker 2: Train Loss: 2.9009, Train Accuracy: 27.71%
#     Worker 3: Train Loss: 2.9086, Train Accuracy: 27.43%
#     Worker 4: Train Loss: 2.8518, Train Accuracy: 27.60%
#     Worker 5: Train Loss: 2.8384, Train Accuracy: 28.56%
#     Worker 6: Train Loss: 2.9011, Train Accuracy: 27.15%
#     Worker 7: Train Loss: 2.8893, Train Accuracy: 27.22%
# Epoch 24/150: Test Loss: 2.6298, Test Accuracy: 33.68%
#     Worker 0: Train Loss: 2.8487, Train Accuracy: 27.96%
#     Worker 1: Train Loss: 2.8175, Train Accuracy: 28.85%
#     Worker 2: Train Loss: 2.8490, Train Accuracy: 28.25%
#     Worker 3: Train Loss: 2.8640, Train Accuracy: 27.50%
#     Worker 4: Train Loss: 2.8158, Train Accuracy: 28.64%
#     Worker 5: Train Loss: 2.8388, Train Accuracy: 29.05%
#     Worker 6: Train Loss: 2.8555, Train Accuracy: 27.67%
#     Worker 7: Train Loss: 2.8571, Train Accuracy: 27.99%
# Epoch 25/150: Test Loss: 2.6152, Test Accuracy: 33.77%
#     Worker 0: Train Loss: 2.8343, Train Accuracy: 28.47%
#     Worker 1: Train Loss: 2.8067, Train Accuracy: 28.26%
#     Worker 2: Train Loss: 2.8441, Train Accuracy: 28.51%
#     Worker 3: Train Loss: 2.8294, Train Accuracy: 27.93%
#     Worker 4: Train Loss: 2.7724, Train Accuracy: 29.07%
#     Worker 5: Train Loss: 2.7924, Train Accuracy: 29.38%
#     Worker 6: Train Loss: 2.8236, Train Accuracy: 28.07%
#     Worker 7: Train Loss: 2.8285, Train Accuracy: 28.47%
# Epoch 26/150: Test Loss: 2.5805, Test Accuracy: 34.79%
#     Worker 0: Train Loss: 2.7908, Train Accuracy: 29.46%
#     Worker 1: Train Loss: 2.7572, Train Accuracy: 29.14%
#     Worker 2: Train Loss: 2.7856, Train Accuracy: 29.96%
#     Worker 3: Train Loss: 2.7989, Train Accuracy: 29.53%
#     Worker 4: Train Loss: 2.7176, Train Accuracy: 30.32%
#     Worker 5: Train Loss: 2.7380, Train Accuracy: 30.59%
#     Worker 6: Train Loss: 2.7986, Train Accuracy: 28.73%
#     Worker 7: Train Loss: 2.7783, Train Accuracy: 29.61%
# Epoch 27/150: Test Loss: 2.5380, Test Accuracy: 35.89%
#     Worker 0: Train Loss: 2.7473, Train Accuracy: 30.54%
#     Worker 1: Train Loss: 2.7100, Train Accuracy: 30.36%
#     Worker 2: Train Loss: 2.7434, Train Accuracy: 31.22%
#     Worker 3: Train Loss: 2.7679, Train Accuracy: 29.26%
#     Worker 4: Train Loss: 2.6783, Train Accuracy: 31.93%
#     Worker 5: Train Loss: 2.6882, Train Accuracy: 31.50%
#     Worker 6: Train Loss: 2.7618, Train Accuracy: 29.91%
#     Worker 7: Train Loss: 2.7224, Train Accuracy: 31.11%
# Epoch 28/150: Test Loss: 2.5104, Test Accuracy: 36.31%
#     Worker 0: Train Loss: 2.7110, Train Accuracy: 31.76%
#     Worker 1: Train Loss: 2.6851, Train Accuracy: 31.14%
#     Worker 2: Train Loss: 2.7255, Train Accuracy: 30.62%
#     Worker 3: Train Loss: 2.7358, Train Accuracy: 30.47%
#     Worker 4: Train Loss: 2.6614, Train Accuracy: 32.02%
#     Worker 5: Train Loss: 2.6771, Train Accuracy: 31.93%
#     Worker 6: Train Loss: 2.7290, Train Accuracy: 30.21%
#     Worker 7: Train Loss: 2.7060, Train Accuracy: 31.00%
# Epoch 29/150: Test Loss: 2.4977, Test Accuracy: 36.52%
#     Worker 0: Train Loss: 2.6789, Train Accuracy: 31.43%
#     Worker 1: Train Loss: 2.6193, Train Accuracy: 32.89%
#     Worker 2: Train Loss: 2.6481, Train Accuracy: 32.34%
#     Worker 3: Train Loss: 2.6990, Train Accuracy: 31.37%
#     Worker 4: Train Loss: 2.6397, Train Accuracy: 31.87%
#     Worker 5: Train Loss: 2.6579, Train Accuracy: 32.07%
#     Worker 6: Train Loss: 2.6793, Train Accuracy: 31.10%
#     Worker 7: Train Loss: 2.6805, Train Accuracy: 31.42%
# Epoch 30/150: Test Loss: 2.4403, Test Accuracy: 37.76%
#     Worker 0: Train Loss: 2.6292, Train Accuracy: 32.65%
#     Worker 1: Train Loss: 2.6116, Train Accuracy: 32.67%
#     Worker 2: Train Loss: 2.6523, Train Accuracy: 32.19%
#     Worker 3: Train Loss: 2.6539, Train Accuracy: 31.47%
#     Worker 4: Train Loss: 2.5684, Train Accuracy: 33.27%
#     Worker 5: Train Loss: 2.6035, Train Accuracy: 33.05%
#     Worker 6: Train Loss: 2.6387, Train Accuracy: 31.66%
#     Worker 7: Train Loss: 2.6271, Train Accuracy: 32.29%
# Epoch 31/150: Test Loss: 2.4218, Test Accuracy: 38.22%
#     Worker 0: Train Loss: 2.6330, Train Accuracy: 33.02%
#     Worker 1: Train Loss: 2.5843, Train Accuracy: 33.54%
#     Worker 2: Train Loss: 2.5905, Train Accuracy: 33.65%
#     Worker 3: Train Loss: 2.6272, Train Accuracy: 32.68%
#     Worker 4: Train Loss: 2.5547, Train Accuracy: 33.93%
#     Worker 5: Train Loss: 2.5890, Train Accuracy: 34.06%
#     Worker 6: Train Loss: 2.6160, Train Accuracy: 33.35%
#     Worker 7: Train Loss: 2.5800, Train Accuracy: 33.60%
# Epoch 32/150: Test Loss: 2.3995, Test Accuracy: 38.68%
#     Worker 0: Train Loss: 2.6081, Train Accuracy: 32.53%
#     Worker 1: Train Loss: 2.5844, Train Accuracy: 33.19%
#     Worker 2: Train Loss: 2.6041, Train Accuracy: 33.02%
#     Worker 3: Train Loss: 2.5906, Train Accuracy: 33.45%
#     Worker 4: Train Loss: 2.5563, Train Accuracy: 34.37%
#     Worker 5: Train Loss: 2.5698, Train Accuracy: 34.87%
#     Worker 6: Train Loss: 2.5758, Train Accuracy: 33.22%
#     Worker 7: Train Loss: 2.6227, Train Accuracy: 32.69%
# Epoch 33/150: Test Loss: 2.3798, Test Accuracy: 38.37%
#     Worker 0: Train Loss: 2.5611, Train Accuracy: 33.57%
#     Worker 1: Train Loss: 2.5148, Train Accuracy: 34.60%
#     Worker 2: Train Loss: 2.5456, Train Accuracy: 34.77%
#     Worker 3: Train Loss: 2.5409, Train Accuracy: 33.68%
#     Worker 4: Train Loss: 2.4866, Train Accuracy: 35.36%
#     Worker 5: Train Loss: 2.5185, Train Accuracy: 35.48%
#     Worker 6: Train Loss: 2.5590, Train Accuracy: 33.55%
#     Worker 7: Train Loss: 2.5381, Train Accuracy: 35.11%
# Epoch 34/150: Test Loss: 2.3575, Test Accuracy: 39.60%
#     Worker 0: Train Loss: 2.5283, Train Accuracy: 34.19%
#     Worker 1: Train Loss: 2.4909, Train Accuracy: 35.35%
#     Worker 2: Train Loss: 2.5334, Train Accuracy: 35.32%
#     Worker 3: Train Loss: 2.5253, Train Accuracy: 34.49%
#     Worker 4: Train Loss: 2.4892, Train Accuracy: 35.04%
#     Worker 5: Train Loss: 2.4944, Train Accuracy: 35.85%
#     Worker 6: Train Loss: 2.5637, Train Accuracy: 34.00%
#     Worker 7: Train Loss: 2.5444, Train Accuracy: 34.25%
# Epoch 35/150: Test Loss: 2.3643, Test Accuracy: 39.20%
#     Worker 0: Train Loss: 2.5197, Train Accuracy: 34.61%
#     Worker 1: Train Loss: 2.4785, Train Accuracy: 35.31%
#     Worker 2: Train Loss: 2.4933, Train Accuracy: 35.62%
#     Worker 3: Train Loss: 2.5098, Train Accuracy: 34.74%
#     Worker 4: Train Loss: 2.4715, Train Accuracy: 35.86%
#     Worker 5: Train Loss: 2.4759, Train Accuracy: 35.45%
#     Worker 6: Train Loss: 2.4887, Train Accuracy: 35.12%
#     Worker 7: Train Loss: 2.4844, Train Accuracy: 35.83%
# Epoch 36/150: Test Loss: 2.3299, Test Accuracy: 40.37%
#     Worker 0: Train Loss: 2.4895, Train Accuracy: 35.70%
#     Worker 1: Train Loss: 2.4371, Train Accuracy: 36.45%
#     Worker 2: Train Loss: 2.4558, Train Accuracy: 36.45%
#     Worker 3: Train Loss: 2.4846, Train Accuracy: 35.16%
#     Worker 4: Train Loss: 2.4481, Train Accuracy: 36.23%
#     Worker 5: Train Loss: 2.4528, Train Accuracy: 36.72%
#     Worker 6: Train Loss: 2.4780, Train Accuracy: 35.82%
#     Worker 7: Train Loss: 2.4846, Train Accuracy: 36.39%
# Epoch 37/150: Test Loss: 2.3096, Test Accuracy: 40.47%
#     Worker 0: Train Loss: 2.4246, Train Accuracy: 37.10%
#     Worker 1: Train Loss: 2.4185, Train Accuracy: 36.46%
#     Worker 2: Train Loss: 2.4382, Train Accuracy: 36.74%
#     Worker 3: Train Loss: 2.4668, Train Accuracy: 35.42%
#     Worker 4: Train Loss: 2.3870, Train Accuracy: 37.78%
#     Worker 5: Train Loss: 2.4084, Train Accuracy: 37.29%
#     Worker 6: Train Loss: 2.4480, Train Accuracy: 35.70%
#     Worker 7: Train Loss: 2.4261, Train Accuracy: 37.06%
# Epoch 38/150: Test Loss: 2.2913, Test Accuracy: 40.81%
#     Worker 0: Train Loss: 2.4412, Train Accuracy: 36.23%
#     Worker 1: Train Loss: 2.4327, Train Accuracy: 36.49%
#     Worker 2: Train Loss: 2.4511, Train Accuracy: 36.45%
#     Worker 3: Train Loss: 2.4688, Train Accuracy: 35.80%
#     Worker 4: Train Loss: 2.3958, Train Accuracy: 37.16%
#     Worker 5: Train Loss: 2.4084, Train Accuracy: 37.18%
#     Worker 6: Train Loss: 2.4565, Train Accuracy: 36.23%
#     Worker 7: Train Loss: 2.4365, Train Accuracy: 36.39%
# Epoch 39/150: Test Loss: 2.2819, Test Accuracy: 41.63%
#     Worker 0: Train Loss: 2.4106, Train Accuracy: 36.45%
#     Worker 1: Train Loss: 2.3592, Train Accuracy: 38.05%
#     Worker 2: Train Loss: 2.3927, Train Accuracy: 37.81%
#     Worker 3: Train Loss: 2.4331, Train Accuracy: 36.13%
#     Worker 4: Train Loss: 2.3481, Train Accuracy: 37.93%
#     Worker 5: Train Loss: 2.3896, Train Accuracy: 37.92%
#     Worker 6: Train Loss: 2.3911, Train Accuracy: 37.20%
#     Worker 7: Train Loss: 2.4168, Train Accuracy: 36.59%
# Epoch 40/150: Test Loss: 2.2559, Test Accuracy: 41.75%
#     Worker 0: Train Loss: 2.3572, Train Accuracy: 38.01%
#     Worker 1: Train Loss: 2.3301, Train Accuracy: 38.71%
#     Worker 2: Train Loss: 2.3498, Train Accuracy: 38.46%
#     Worker 3: Train Loss: 2.3687, Train Accuracy: 38.19%
#     Worker 4: Train Loss: 2.3316, Train Accuracy: 38.57%
#     Worker 5: Train Loss: 2.3552, Train Accuracy: 38.44%
#     Worker 6: Train Loss: 2.3684, Train Accuracy: 37.85%
#     Worker 7: Train Loss: 2.3617, Train Accuracy: 37.68%
# Epoch 41/150: Test Loss: 2.2402, Test Accuracy: 42.20%
#     Worker 0: Train Loss: 2.3590, Train Accuracy: 38.18%
#     Worker 1: Train Loss: 2.3432, Train Accuracy: 38.02%
#     Worker 2: Train Loss: 2.3648, Train Accuracy: 38.84%
#     Worker 3: Train Loss: 2.3941, Train Accuracy: 37.23%
#     Worker 4: Train Loss: 2.3167, Train Accuracy: 39.22%
#     Worker 5: Train Loss: 2.3479, Train Accuracy: 38.89%
#     Worker 6: Train Loss: 2.4035, Train Accuracy: 38.05%
#     Worker 7: Train Loss: 2.3360, Train Accuracy: 38.54%
# Epoch 42/150: Test Loss: 2.2467, Test Accuracy: 41.98%
#     Worker 0: Train Loss: 2.3409, Train Accuracy: 38.75%
#     Worker 1: Train Loss: 2.3008, Train Accuracy: 39.18%
#     Worker 2: Train Loss: 2.3284, Train Accuracy: 39.31%
#     Worker 3: Train Loss: 2.3506, Train Accuracy: 38.75%
#     Worker 4: Train Loss: 2.2751, Train Accuracy: 39.60%
#     Worker 5: Train Loss: 2.3274, Train Accuracy: 39.27%
#     Worker 6: Train Loss: 2.3732, Train Accuracy: 37.88%
#     Worker 7: Train Loss: 2.3539, Train Accuracy: 38.56%
# Epoch 43/150: Test Loss: 2.2084, Test Accuracy: 42.61%
#     Worker 0: Train Loss: 2.3070, Train Accuracy: 39.00%
#     Worker 1: Train Loss: 2.2627, Train Accuracy: 39.99%
#     Worker 2: Train Loss: 2.2532, Train Accuracy: 41.00%
#     Worker 3: Train Loss: 2.3200, Train Accuracy: 39.10%
#     Worker 4: Train Loss: 2.2661, Train Accuracy: 40.34%
#     Worker 5: Train Loss: 2.2801, Train Accuracy: 40.82%
#     Worker 6: Train Loss: 2.3030, Train Accuracy: 39.46%
#     Worker 7: Train Loss: 2.2692, Train Accuracy: 39.64%
# Epoch 44/150: Test Loss: 2.2031, Test Accuracy: 42.81%
#     Worker 0: Train Loss: 2.2933, Train Accuracy: 39.30%
#     Worker 1: Train Loss: 2.2912, Train Accuracy: 39.67%
#     Worker 2: Train Loss: 2.2961, Train Accuracy: 39.42%
#     Worker 3: Train Loss: 2.3095, Train Accuracy: 39.62%
#     Worker 4: Train Loss: 2.2782, Train Accuracy: 39.63%
#     Worker 5: Train Loss: 2.2406, Train Accuracy: 40.80%
#     Worker 6: Train Loss: 2.3218, Train Accuracy: 39.33%
#     Worker 7: Train Loss: 2.3168, Train Accuracy: 38.74%
# Epoch 45/150: Test Loss: 2.1838, Test Accuracy: 43.24%
#     Worker 0: Train Loss: 2.2611, Train Accuracy: 40.45%
#     Worker 1: Train Loss: 2.2498, Train Accuracy: 39.95%
#     Worker 2: Train Loss: 2.2809, Train Accuracy: 40.51%
#     Worker 3: Train Loss: 2.2984, Train Accuracy: 39.51%
#     Worker 4: Train Loss: 2.2361, Train Accuracy: 40.93%
#     Worker 5: Train Loss: 2.2898, Train Accuracy: 39.84%
#     Worker 6: Train Loss: 2.3063, Train Accuracy: 38.91%
#     Worker 7: Train Loss: 2.3018, Train Accuracy: 39.96%
# Epoch 46/150: Test Loss: 2.1756, Test Accuracy: 43.22%
#     Worker 0: Train Loss: 2.2546, Train Accuracy: 40.13%
#     Worker 1: Train Loss: 2.2298, Train Accuracy: 41.19%
#     Worker 2: Train Loss: 2.2418, Train Accuracy: 40.71%
#     Worker 3: Train Loss: 2.2372, Train Accuracy: 40.45%
#     Worker 4: Train Loss: 2.2063, Train Accuracy: 41.56%
#     Worker 5: Train Loss: 2.2058, Train Accuracy: 42.23%
#     Worker 6: Train Loss: 2.2521, Train Accuracy: 40.75%
#     Worker 7: Train Loss: 2.2539, Train Accuracy: 40.64%
# Epoch 47/150: Test Loss: 2.1615, Test Accuracy: 43.59%
#     Worker 0: Train Loss: 2.2324, Train Accuracy: 40.91%
#     Worker 1: Train Loss: 2.2121, Train Accuracy: 41.42%
#     Worker 2: Train Loss: 2.2407, Train Accuracy: 41.59%
#     Worker 3: Train Loss: 2.2031, Train Accuracy: 41.69%
#     Worker 4: Train Loss: 2.2109, Train Accuracy: 41.22%
#     Worker 5: Train Loss: 2.1912, Train Accuracy: 43.04%
#     Worker 6: Train Loss: 2.2399, Train Accuracy: 40.73%
#     Worker 7: Train Loss: 2.2214, Train Accuracy: 41.25%
# Epoch 48/150: Test Loss: 2.1664, Test Accuracy: 43.42%
#     Worker 0: Train Loss: 2.2339, Train Accuracy: 41.29%
#     Worker 1: Train Loss: 2.2395, Train Accuracy: 40.53%
#     Worker 2: Train Loss: 2.2350, Train Accuracy: 41.20%
#     Worker 3: Train Loss: 2.2222, Train Accuracy: 40.86%
#     Worker 4: Train Loss: 2.1808, Train Accuracy: 41.71%
#     Worker 5: Train Loss: 2.2156, Train Accuracy: 41.80%
#     Worker 6: Train Loss: 2.2600, Train Accuracy: 39.93%
#     Worker 7: Train Loss: 2.2397, Train Accuracy: 40.69%
# Epoch 49/150: Test Loss: 2.1431, Test Accuracy: 44.30%
#     Worker 0: Train Loss: 2.1858, Train Accuracy: 41.67%
#     Worker 1: Train Loss: 2.1549, Train Accuracy: 42.55%
#     Worker 2: Train Loss: 2.1965, Train Accuracy: 41.95%
#     Worker 3: Train Loss: 2.2039, Train Accuracy: 41.83%
#     Worker 4: Train Loss: 2.1669, Train Accuracy: 42.61%
#     Worker 5: Train Loss: 2.1659, Train Accuracy: 42.88%
#     Worker 6: Train Loss: 2.1972, Train Accuracy: 41.07%
#     Worker 7: Train Loss: 2.1837, Train Accuracy: 42.77%
# Epoch 50/150: Test Loss: 2.1227, Test Accuracy: 44.30%
#     Worker 0: Train Loss: 2.1637, Train Accuracy: 42.77%
#     Worker 1: Train Loss: 2.1189, Train Accuracy: 42.94%
#     Worker 2: Train Loss: 2.1491, Train Accuracy: 42.85%
#     Worker 3: Train Loss: 2.1600, Train Accuracy: 42.51%
#     Worker 4: Train Loss: 2.1256, Train Accuracy: 42.74%
#     Worker 5: Train Loss: 2.1625, Train Accuracy: 42.78%
#     Worker 6: Train Loss: 2.1552, Train Accuracy: 42.56%
#     Worker 7: Train Loss: 2.1486, Train Accuracy: 42.23%
# Epoch 51/150: Test Loss: 2.1204, Test Accuracy: 44.75%
#     Worker 0: Train Loss: 2.1881, Train Accuracy: 41.84%
#     Worker 1: Train Loss: 2.1537, Train Accuracy: 42.09%
#     Worker 2: Train Loss: 2.1495, Train Accuracy: 42.85%
#     Worker 3: Train Loss: 2.1700, Train Accuracy: 41.91%
#     Worker 4: Train Loss: 2.1383, Train Accuracy: 43.07%
#     Worker 5: Train Loss: 2.1377, Train Accuracy: 43.13%
#     Worker 6: Train Loss: 2.1893, Train Accuracy: 41.49%
#     Worker 7: Train Loss: 2.1693, Train Accuracy: 41.90%
# Epoch 52/150: Test Loss: 2.1052, Test Accuracy: 44.96%
#     Worker 0: Train Loss: 2.1572, Train Accuracy: 42.83%
#     Worker 1: Train Loss: 2.1210, Train Accuracy: 42.91%
#     Worker 2: Train Loss: 2.1269, Train Accuracy: 43.27%
#     Worker 3: Train Loss: 2.1593, Train Accuracy: 42.71%
#     Worker 4: Train Loss: 2.1266, Train Accuracy: 43.16%
#     Worker 5: Train Loss: 2.1013, Train Accuracy: 44.41%
#     Worker 6: Train Loss: 2.1535, Train Accuracy: 42.14%
#     Worker 7: Train Loss: 2.1562, Train Accuracy: 43.33%
# Epoch 53/150: Test Loss: 2.0966, Test Accuracy: 44.70%
#     Worker 0: Train Loss: 2.1162, Train Accuracy: 43.31%
#     Worker 1: Train Loss: 2.0680, Train Accuracy: 44.78%
#     Worker 2: Train Loss: 2.0975, Train Accuracy: 43.96%
#     Worker 3: Train Loss: 2.1231, Train Accuracy: 43.04%
#     Worker 4: Train Loss: 2.0687, Train Accuracy: 44.51%
#     Worker 5: Train Loss: 2.0848, Train Accuracy: 44.73%
#     Worker 6: Train Loss: 2.1273, Train Accuracy: 43.54%
#     Worker 7: Train Loss: 2.0988, Train Accuracy: 44.19%
# Epoch 54/150: Test Loss: 2.0987, Test Accuracy: 44.97%
#     Worker 0: Train Loss: 2.1113, Train Accuracy: 43.43%
#     Worker 1: Train Loss: 2.0692, Train Accuracy: 44.37%
#     Worker 2: Train Loss: 2.0827, Train Accuracy: 44.14%
#     Worker 3: Train Loss: 2.1166, Train Accuracy: 42.59%
#     Worker 4: Train Loss: 2.0706, Train Accuracy: 44.43%
#     Worker 5: Train Loss: 2.1068, Train Accuracy: 43.95%
#     Worker 6: Train Loss: 2.1476, Train Accuracy: 42.80%
#     Worker 7: Train Loss: 2.1218, Train Accuracy: 43.54%
# Epoch 55/150: Test Loss: 2.0870, Test Accuracy: 45.41%
#     Worker 0: Train Loss: 2.0972, Train Accuracy: 43.56%
#     Worker 1: Train Loss: 2.0767, Train Accuracy: 44.66%
#     Worker 2: Train Loss: 2.0913, Train Accuracy: 44.06%
#     Worker 3: Train Loss: 2.1209, Train Accuracy: 42.99%
#     Worker 4: Train Loss: 2.0619, Train Accuracy: 44.44%
#     Worker 5: Train Loss: 2.0827, Train Accuracy: 44.72%
#     Worker 6: Train Loss: 2.1034, Train Accuracy: 43.29%
#     Worker 7: Train Loss: 2.1033, Train Accuracy: 42.96%
# Epoch 56/150: Test Loss: 2.0757, Test Accuracy: 45.73%
#     Worker 0: Train Loss: 2.0675, Train Accuracy: 44.65%
#     Worker 1: Train Loss: 2.0261, Train Accuracy: 45.51%
#     Worker 2: Train Loss: 2.0549, Train Accuracy: 45.16%
#     Worker 3: Train Loss: 2.0577, Train Accuracy: 44.93%
#     Worker 4: Train Loss: 2.0432, Train Accuracy: 45.40%
#     Worker 5: Train Loss: 2.0110, Train Accuracy: 45.95%
#     Worker 6: Train Loss: 2.0767, Train Accuracy: 44.65%
#     Worker 7: Train Loss: 2.0778, Train Accuracy: 44.65%
# Epoch 57/150: Test Loss: 2.0754, Test Accuracy: 45.88%
#     Worker 0: Train Loss: 2.0766, Train Accuracy: 44.35%
#     Worker 1: Train Loss: 2.0320, Train Accuracy: 45.65%
#     Worker 2: Train Loss: 2.0181, Train Accuracy: 46.18%
#     Worker 3: Train Loss: 2.0712, Train Accuracy: 44.61%
#     Worker 4: Train Loss: 2.0184, Train Accuracy: 45.64%
#     Worker 5: Train Loss: 2.0102, Train Accuracy: 46.27%
#     Worker 6: Train Loss: 2.0724, Train Accuracy: 44.36%
#     Worker 7: Train Loss: 2.0524, Train Accuracy: 45.15%
# Epoch 58/150: Test Loss: 2.0656, Test Accuracy: 45.70%
#     Worker 0: Train Loss: 2.0655, Train Accuracy: 44.11%
#     Worker 1: Train Loss: 2.0058, Train Accuracy: 45.79%
#     Worker 2: Train Loss: 2.0442, Train Accuracy: 44.63%
#     Worker 3: Train Loss: 2.0570, Train Accuracy: 44.21%
#     Worker 4: Train Loss: 2.0070, Train Accuracy: 45.79%
#     Worker 5: Train Loss: 2.0349, Train Accuracy: 45.96%
#     Worker 6: Train Loss: 2.0477, Train Accuracy: 45.24%
#     Worker 7: Train Loss: 2.0449, Train Accuracy: 44.65%
# Epoch 59/150: Test Loss: 2.0455, Test Accuracy: 46.20%
#     Worker 0: Train Loss: 2.0246, Train Accuracy: 45.51%
#     Worker 1: Train Loss: 1.9774, Train Accuracy: 46.39%
#     Worker 2: Train Loss: 1.9888, Train Accuracy: 46.31%
#     Worker 3: Train Loss: 2.0112, Train Accuracy: 46.07%
#     Worker 4: Train Loss: 1.9667, Train Accuracy: 46.83%
#     Worker 5: Train Loss: 1.9679, Train Accuracy: 47.02%
#     Worker 6: Train Loss: 2.0281, Train Accuracy: 45.02%
#     Worker 7: Train Loss: 2.0055, Train Accuracy: 45.61%
# Epoch 60/150: Test Loss: 2.0477, Test Accuracy: 45.80%
#     Worker 0: Train Loss: 1.9853, Train Accuracy: 45.92%
#     Worker 1: Train Loss: 1.9737, Train Accuracy: 46.56%
#     Worker 2: Train Loss: 1.9902, Train Accuracy: 46.41%
#     Worker 3: Train Loss: 1.9788, Train Accuracy: 46.33%
#     Worker 4: Train Loss: 1.9579, Train Accuracy: 46.51%
#     Worker 5: Train Loss: 1.9905, Train Accuracy: 46.43%
#     Worker 6: Train Loss: 2.0251, Train Accuracy: 45.52%
#     Worker 7: Train Loss: 1.9997, Train Accuracy: 45.96%
# Epoch 61/150: Test Loss: 2.0438, Test Accuracy: 46.13%
#     Worker 0: Train Loss: 2.0356, Train Accuracy: 45.21%
#     Worker 1: Train Loss: 1.9646, Train Accuracy: 46.90%
#     Worker 2: Train Loss: 1.9817, Train Accuracy: 46.56%
#     Worker 3: Train Loss: 2.0133, Train Accuracy: 45.25%
#     Worker 4: Train Loss: 1.9722, Train Accuracy: 46.73%
#     Worker 5: Train Loss: 1.9767, Train Accuracy: 46.78%
#     Worker 6: Train Loss: 2.0111, Train Accuracy: 44.77%
#     Worker 7: Train Loss: 1.9954, Train Accuracy: 46.54%
# Epoch 62/150: Test Loss: 2.0308, Test Accuracy: 46.58%
#     Worker 0: Train Loss: 1.9848, Train Accuracy: 46.05%
#     Worker 1: Train Loss: 1.9377, Train Accuracy: 48.02%
#     Worker 2: Train Loss: 1.9430, Train Accuracy: 47.23%
#     Worker 3: Train Loss: 1.9542, Train Accuracy: 46.52%
#     Worker 4: Train Loss: 1.9391, Train Accuracy: 47.82%
#     Worker 5: Train Loss: 1.9673, Train Accuracy: 47.14%
#     Worker 6: Train Loss: 1.9904, Train Accuracy: 46.19%
#     Worker 7: Train Loss: 1.9794, Train Accuracy: 46.68%
# Epoch 63/150: Test Loss: 2.0317, Test Accuracy: 46.77%
#     Worker 0: Train Loss: 1.9551, Train Accuracy: 46.80%
#     Worker 1: Train Loss: 1.9104, Train Accuracy: 47.82%
#     Worker 2: Train Loss: 1.9290, Train Accuracy: 47.74%
#     Worker 3: Train Loss: 1.9547, Train Accuracy: 46.77%
#     Worker 4: Train Loss: 1.8944, Train Accuracy: 48.55%
#     Worker 5: Train Loss: 1.9301, Train Accuracy: 47.70%
#     Worker 6: Train Loss: 1.9294, Train Accuracy: 47.57%
#     Worker 7: Train Loss: 1.9409, Train Accuracy: 48.24%
# Epoch 64/150: Test Loss: 2.0328, Test Accuracy: 46.84%
#     Worker 0: Train Loss: 1.9698, Train Accuracy: 46.59%
#     Worker 1: Train Loss: 1.9140, Train Accuracy: 47.81%
#     Worker 2: Train Loss: 1.9338, Train Accuracy: 47.56%
#     Worker 3: Train Loss: 1.9821, Train Accuracy: 46.62%
#     Worker 4: Train Loss: 1.9340, Train Accuracy: 47.49%
#     Worker 5: Train Loss: 1.9627, Train Accuracy: 47.34%
#     Worker 6: Train Loss: 1.9766, Train Accuracy: 46.74%
#     Worker 7: Train Loss: 1.9563, Train Accuracy: 47.00%
# Epoch 65/150: Test Loss: 2.0126, Test Accuracy: 46.91%
#     Worker 0: Train Loss: 1.9433, Train Accuracy: 46.92%
#     Worker 1: Train Loss: 1.9144, Train Accuracy: 47.85%
#     Worker 2: Train Loss: 1.9209, Train Accuracy: 48.49%
#     Worker 3: Train Loss: 1.9385, Train Accuracy: 47.78%
#     Worker 4: Train Loss: 1.8922, Train Accuracy: 48.49%
#     Worker 5: Train Loss: 1.9032, Train Accuracy: 48.19%
#     Worker 6: Train Loss: 1.9283, Train Accuracy: 48.23%
#     Worker 7: Train Loss: 1.9156, Train Accuracy: 48.03%
# Epoch 66/150: Test Loss: 2.0186, Test Accuracy: 47.03%
#     Worker 0: Train Loss: 1.8927, Train Accuracy: 48.34%
#     Worker 1: Train Loss: 1.8482, Train Accuracy: 49.36%
#     Worker 2: Train Loss: 1.8722, Train Accuracy: 48.98%
#     Worker 3: Train Loss: 1.8833, Train Accuracy: 48.77%
#     Worker 4: Train Loss: 1.8609, Train Accuracy: 48.64%
#     Worker 5: Train Loss: 1.8944, Train Accuracy: 48.82%
#     Worker 6: Train Loss: 1.9128, Train Accuracy: 48.54%
#     Worker 7: Train Loss: 1.9019, Train Accuracy: 48.59%
# Epoch 67/150: Test Loss: 2.0022, Test Accuracy: 47.45%
#     Worker 0: Train Loss: 1.8964, Train Accuracy: 48.27%
#     Worker 1: Train Loss: 1.8720, Train Accuracy: 48.97%
#     Worker 2: Train Loss: 1.8668, Train Accuracy: 48.75%
#     Worker 3: Train Loss: 1.9159, Train Accuracy: 47.77%
#     Worker 4: Train Loss: 1.8971, Train Accuracy: 48.21%
#     Worker 5: Train Loss: 1.8613, Train Accuracy: 49.58%
#     Worker 6: Train Loss: 1.8988, Train Accuracy: 48.49%
#     Worker 7: Train Loss: 1.8813, Train Accuracy: 48.78%
# Epoch 68/150: Test Loss: 1.9935, Test Accuracy: 47.74%
#     Worker 0: Train Loss: 1.9116, Train Accuracy: 47.89%
#     Worker 1: Train Loss: 1.8708, Train Accuracy: 49.23%
#     Worker 2: Train Loss: 1.8674, Train Accuracy: 49.28%
#     Worker 3: Train Loss: 1.8975, Train Accuracy: 48.07%
#     Worker 4: Train Loss: 1.8635, Train Accuracy: 48.91%
#     Worker 5: Train Loss: 1.9106, Train Accuracy: 48.12%
#     Worker 6: Train Loss: 1.9147, Train Accuracy: 47.74%
#     Worker 7: Train Loss: 1.8746, Train Accuracy: 48.74%
# Epoch 69/150: Test Loss: 1.9903, Test Accuracy: 47.63%
#     Worker 0: Train Loss: 1.8684, Train Accuracy: 48.69%
#     Worker 1: Train Loss: 1.7981, Train Accuracy: 50.53%
#     Worker 2: Train Loss: 1.8143, Train Accuracy: 50.01%
#     Worker 3: Train Loss: 1.8683, Train Accuracy: 49.03%
#     Worker 4: Train Loss: 1.8366, Train Accuracy: 49.48%
#     Worker 5: Train Loss: 1.8628, Train Accuracy: 49.64%
#     Worker 6: Train Loss: 1.8662, Train Accuracy: 49.73%
#     Worker 7: Train Loss: 1.8609, Train Accuracy: 49.39%
# Epoch 70/150: Test Loss: 1.9895, Test Accuracy: 47.71%
#     Worker 0: Train Loss: 1.8505, Train Accuracy: 49.45%
#     Worker 1: Train Loss: 1.8365, Train Accuracy: 49.84%
#     Worker 2: Train Loss: 1.8072, Train Accuracy: 50.78%
#     Worker 3: Train Loss: 1.8560, Train Accuracy: 49.38%
#     Worker 4: Train Loss: 1.8049, Train Accuracy: 50.56%
#     Worker 5: Train Loss: 1.8309, Train Accuracy: 50.33%
#     Worker 6: Train Loss: 1.8893, Train Accuracy: 48.92%
#     Worker 7: Train Loss: 1.8541, Train Accuracy: 49.63%
# Epoch 71/150: Test Loss: 1.9885, Test Accuracy: 47.85%
#     Worker 0: Train Loss: 1.8383, Train Accuracy: 49.24%
#     Worker 1: Train Loss: 1.8049, Train Accuracy: 50.10%
#     Worker 2: Train Loss: 1.8448, Train Accuracy: 49.55%
#     Worker 3: Train Loss: 1.8627, Train Accuracy: 49.00%
#     Worker 4: Train Loss: 1.8061, Train Accuracy: 50.34%
#     Worker 5: Train Loss: 1.8162, Train Accuracy: 50.39%
#     Worker 6: Train Loss: 1.8909, Train Accuracy: 48.46%
#     Worker 7: Train Loss: 1.8367, Train Accuracy: 49.96%
# Epoch 72/150: Test Loss: 1.9726, Test Accuracy: 48.26%
#     Worker 0: Train Loss: 1.8039, Train Accuracy: 50.52%
#     Worker 1: Train Loss: 1.7735, Train Accuracy: 51.55%
#     Worker 2: Train Loss: 1.7791, Train Accuracy: 51.96%
#     Worker 3: Train Loss: 1.8192, Train Accuracy: 49.73%
#     Worker 4: Train Loss: 1.7979, Train Accuracy: 50.54%
#     Worker 5: Train Loss: 1.8177, Train Accuracy: 50.71%
#     Worker 6: Train Loss: 1.8385, Train Accuracy: 50.26%
#     Worker 7: Train Loss: 1.8260, Train Accuracy: 50.53%
# Epoch 73/150: Test Loss: 1.9727, Test Accuracy: 47.88%
#     Worker 0: Train Loss: 1.7945, Train Accuracy: 50.43%
#     Worker 1: Train Loss: 1.7520, Train Accuracy: 51.65%
#     Worker 2: Train Loss: 1.7818, Train Accuracy: 50.93%
#     Worker 3: Train Loss: 1.8189, Train Accuracy: 49.63%
#     Worker 4: Train Loss: 1.7825, Train Accuracy: 50.37%
#     Worker 5: Train Loss: 1.7953, Train Accuracy: 51.25%
#     Worker 6: Train Loss: 1.8125, Train Accuracy: 50.45%
#     Worker 7: Train Loss: 1.7968, Train Accuracy: 50.82%
# Epoch 74/150: Test Loss: 1.9644, Test Accuracy: 48.34%
#     Worker 0: Train Loss: 1.8277, Train Accuracy: 50.22%
#     Worker 1: Train Loss: 1.7955, Train Accuracy: 51.08%
#     Worker 2: Train Loss: 1.7833, Train Accuracy: 50.87%
#     Worker 3: Train Loss: 1.8269, Train Accuracy: 50.20%
#     Worker 4: Train Loss: 1.8026, Train Accuracy: 49.76%
#     Worker 5: Train Loss: 1.7834, Train Accuracy: 51.11%
#     Worker 6: Train Loss: 1.8361, Train Accuracy: 50.02%
#     Worker 7: Train Loss: 1.8125, Train Accuracy: 50.93%
# Epoch 75/150: Test Loss: 1.9637, Test Accuracy: 48.11%
#     Worker 0: Train Loss: 1.7944, Train Accuracy: 51.11%
#     Worker 1: Train Loss: 1.7536, Train Accuracy: 51.47%
#     Worker 2: Train Loss: 1.7533, Train Accuracy: 51.84%
#     Worker 3: Train Loss: 1.7661, Train Accuracy: 51.49%
#     Worker 4: Train Loss: 1.7606, Train Accuracy: 51.48%
#     Worker 5: Train Loss: 1.7903, Train Accuracy: 51.31%
#     Worker 6: Train Loss: 1.8033, Train Accuracy: 50.73%
#     Worker 7: Train Loss: 1.7729, Train Accuracy: 51.09%
# Epoch 76/150: Test Loss: 1.9670, Test Accuracy: 48.34%
#     Worker 0: Train Loss: 1.7561, Train Accuracy: 51.91%
#     Worker 1: Train Loss: 1.7284, Train Accuracy: 52.91%
#     Worker 2: Train Loss: 1.7202, Train Accuracy: 52.65%
#     Worker 3: Train Loss: 1.7449, Train Accuracy: 52.09%
#     Worker 4: Train Loss: 1.7368, Train Accuracy: 51.76%
#     Worker 5: Train Loss: 1.7448, Train Accuracy: 52.76%
#     Worker 6: Train Loss: 1.7612, Train Accuracy: 52.09%
#     Worker 7: Train Loss: 1.7494, Train Accuracy: 51.58%
# Epoch 77/150: Test Loss: 1.9663, Test Accuracy: 48.17%
#     Worker 0: Train Loss: 1.7674, Train Accuracy: 51.18%
#     Worker 1: Train Loss: 1.7376, Train Accuracy: 52.03%
#     Worker 2: Train Loss: 1.7373, Train Accuracy: 53.01%
#     Worker 3: Train Loss: 1.7661, Train Accuracy: 50.88%
#     Worker 4: Train Loss: 1.7108, Train Accuracy: 52.74%
#     Worker 5: Train Loss: 1.7806, Train Accuracy: 51.05%
#     Worker 6: Train Loss: 1.7957, Train Accuracy: 50.76%
#     Worker 7: Train Loss: 1.7465, Train Accuracy: 51.90%
# Epoch 78/150: Test Loss: 1.9587, Test Accuracy: 48.42%
#     Worker 0: Train Loss: 1.7344, Train Accuracy: 51.71%
#     Worker 1: Train Loss: 1.6919, Train Accuracy: 53.00%
#     Worker 2: Train Loss: 1.7315, Train Accuracy: 52.40%
#     Worker 3: Train Loss: 1.7694, Train Accuracy: 50.62%
#     Worker 4: Train Loss: 1.7291, Train Accuracy: 51.90%
#     Worker 5: Train Loss: 1.7215, Train Accuracy: 53.44%
#     Worker 6: Train Loss: 1.7744, Train Accuracy: 51.44%
#     Worker 7: Train Loss: 1.7589, Train Accuracy: 51.43%
# Epoch 79/150: Test Loss: 1.9650, Test Accuracy: 48.57%
#     Worker 0: Train Loss: 1.7208, Train Accuracy: 52.25%
#     Worker 1: Train Loss: 1.6958, Train Accuracy: 53.41%
#     Worker 2: Train Loss: 1.7149, Train Accuracy: 52.26%
#     Worker 3: Train Loss: 1.7202, Train Accuracy: 52.85%
#     Worker 4: Train Loss: 1.6949, Train Accuracy: 52.87%
#     Worker 5: Train Loss: 1.7179, Train Accuracy: 52.95%
#     Worker 6: Train Loss: 1.7267, Train Accuracy: 52.52%
#     Worker 7: Train Loss: 1.7054, Train Accuracy: 52.93%
# Epoch 80/150: Test Loss: 1.9483, Test Accuracy: 48.85%
#     Worker 0: Train Loss: 1.7296, Train Accuracy: 52.20%
#     Worker 1: Train Loss: 1.7036, Train Accuracy: 52.90%
#     Worker 2: Train Loss: 1.6920, Train Accuracy: 53.28%
#     Worker 3: Train Loss: 1.7435, Train Accuracy: 51.59%
#     Worker 4: Train Loss: 1.6754, Train Accuracy: 53.27%
#     Worker 5: Train Loss: 1.7030, Train Accuracy: 53.12%
#     Worker 6: Train Loss: 1.7531, Train Accuracy: 51.74%
#     Worker 7: Train Loss: 1.7132, Train Accuracy: 53.23%
# Epoch 81/150: Test Loss: 1.9498, Test Accuracy: 48.88%
#     Worker 0: Train Loss: 1.7126, Train Accuracy: 52.25%
#     Worker 1: Train Loss: 1.6827, Train Accuracy: 53.99%
#     Worker 2: Train Loss: 1.6934, Train Accuracy: 53.54%
#     Worker 3: Train Loss: 1.7138, Train Accuracy: 52.75%
#     Worker 4: Train Loss: 1.6941, Train Accuracy: 52.69%
#     Worker 5: Train Loss: 1.6949, Train Accuracy: 53.21%
#     Worker 6: Train Loss: 1.7171, Train Accuracy: 52.95%
#     Worker 7: Train Loss: 1.6887, Train Accuracy: 53.30%
# Epoch 82/150: Test Loss: 1.9480, Test Accuracy: 49.14%
#     Worker 0: Train Loss: 1.6871, Train Accuracy: 53.19%
#     Worker 1: Train Loss: 1.6554, Train Accuracy: 54.14%
#     Worker 2: Train Loss: 1.6359, Train Accuracy: 54.46%
#     Worker 3: Train Loss: 1.7045, Train Accuracy: 53.14%
#     Worker 4: Train Loss: 1.6437, Train Accuracy: 54.46%
#     Worker 5: Train Loss: 1.6709, Train Accuracy: 54.32%
#     Worker 6: Train Loss: 1.7003, Train Accuracy: 52.57%
#     Worker 7: Train Loss: 1.6658, Train Accuracy: 53.51%
# Epoch 83/150: Test Loss: 1.9458, Test Accuracy: 49.00%
#     Worker 0: Train Loss: 1.6651, Train Accuracy: 53.87%
#     Worker 1: Train Loss: 1.6428, Train Accuracy: 54.17%
#     Worker 2: Train Loss: 1.6709, Train Accuracy: 53.88%
#     Worker 3: Train Loss: 1.6752, Train Accuracy: 54.03%
#     Worker 4: Train Loss: 1.6321, Train Accuracy: 53.98%
#     Worker 5: Train Loss: 1.6697, Train Accuracy: 53.97%
#     Worker 6: Train Loss: 1.6843, Train Accuracy: 53.39%
#     Worker 7: Train Loss: 1.6822, Train Accuracy: 53.39%
# Epoch 84/150: Test Loss: 1.9381, Test Accuracy: 49.04%
#     Worker 0: Train Loss: 1.6721, Train Accuracy: 53.57%
#     Worker 1: Train Loss: 1.6349, Train Accuracy: 54.16%
#     Worker 2: Train Loss: 1.6528, Train Accuracy: 54.10%
#     Worker 3: Train Loss: 1.6715, Train Accuracy: 53.90%
#     Worker 4: Train Loss: 1.6633, Train Accuracy: 54.01%
#     Worker 5: Train Loss: 1.6530, Train Accuracy: 54.59%
#     Worker 6: Train Loss: 1.6975, Train Accuracy: 53.26%
#     Worker 7: Train Loss: 1.6715, Train Accuracy: 53.79%
# Epoch 85/150: Test Loss: 1.9349, Test Accuracy: 49.46%
#     Worker 0: Train Loss: 1.6835, Train Accuracy: 53.11%
#     Worker 1: Train Loss: 1.6143, Train Accuracy: 54.82%
#     Worker 2: Train Loss: 1.6056, Train Accuracy: 55.34%
#     Worker 3: Train Loss: 1.6694, Train Accuracy: 53.61%
#     Worker 4: Train Loss: 1.6325, Train Accuracy: 54.36%
#     Worker 5: Train Loss: 1.6384, Train Accuracy: 55.00%
#     Worker 6: Train Loss: 1.6522, Train Accuracy: 54.49%
#     Worker 7: Train Loss: 1.6346, Train Accuracy: 54.16%
# Epoch 86/150: Test Loss: 1.9383, Test Accuracy: 49.32%
#     Worker 0: Train Loss: 1.6168, Train Accuracy: 54.69%
#     Worker 1: Train Loss: 1.5991, Train Accuracy: 55.85%
#     Worker 2: Train Loss: 1.6323, Train Accuracy: 54.72%
#     Worker 3: Train Loss: 1.6637, Train Accuracy: 54.47%
#     Worker 4: Train Loss: 1.5866, Train Accuracy: 55.73%
#     Worker 5: Train Loss: 1.6129, Train Accuracy: 55.10%
#     Worker 6: Train Loss: 1.6540, Train Accuracy: 54.21%
#     Worker 7: Train Loss: 1.6244, Train Accuracy: 55.18%
# Epoch 87/150: Test Loss: 1.9391, Test Accuracy: 49.45%
#     Worker 0: Train Loss: 1.6376, Train Accuracy: 53.65%
#     Worker 1: Train Loss: 1.5883, Train Accuracy: 55.54%
#     Worker 2: Train Loss: 1.5830, Train Accuracy: 55.92%
#     Worker 3: Train Loss: 1.6294, Train Accuracy: 54.35%
#     Worker 4: Train Loss: 1.6189, Train Accuracy: 54.74%
#     Worker 5: Train Loss: 1.6298, Train Accuracy: 54.88%
#     Worker 6: Train Loss: 1.7084, Train Accuracy: 53.21%
#     Worker 7: Train Loss: 1.6192, Train Accuracy: 55.13%
# Epoch 88/150: Test Loss: 1.9418, Test Accuracy: 49.43%
#     Worker 0: Train Loss: 1.6113, Train Accuracy: 54.93%
#     Worker 1: Train Loss: 1.6070, Train Accuracy: 54.58%
#     Worker 2: Train Loss: 1.5920, Train Accuracy: 56.19%
#     Worker 3: Train Loss: 1.6270, Train Accuracy: 55.30%
#     Worker 4: Train Loss: 1.5761, Train Accuracy: 55.67%
#     Worker 5: Train Loss: 1.6010, Train Accuracy: 55.65%
#     Worker 6: Train Loss: 1.6438, Train Accuracy: 53.77%
#     Worker 7: Train Loss: 1.6295, Train Accuracy: 55.18%
# Epoch 89/150: Test Loss: 1.9385, Test Accuracy: 49.32%
#     Worker 0: Train Loss: 1.5970, Train Accuracy: 55.52%
#     Worker 1: Train Loss: 1.5497, Train Accuracy: 56.75%
#     Worker 2: Train Loss: 1.5411, Train Accuracy: 56.92%
#     Worker 3: Train Loss: 1.5985, Train Accuracy: 55.11%
#     Worker 4: Train Loss: 1.5697, Train Accuracy: 56.63%
#     Worker 5: Train Loss: 1.5795, Train Accuracy: 56.41%
#     Worker 6: Train Loss: 1.6157, Train Accuracy: 55.09%
#     Worker 7: Train Loss: 1.5863, Train Accuracy: 55.85%
# Epoch 90/150: Test Loss: 1.9277, Test Accuracy: 49.65%
#     Worker 0: Train Loss: 1.6236, Train Accuracy: 54.53%
#     Worker 1: Train Loss: 1.5855, Train Accuracy: 55.29%
#     Worker 2: Train Loss: 1.5927, Train Accuracy: 55.69%
#     Worker 3: Train Loss: 1.5923, Train Accuracy: 55.09%
#     Worker 4: Train Loss: 1.5580, Train Accuracy: 56.40%
#     Worker 5: Train Loss: 1.5938, Train Accuracy: 55.37%
#     Worker 6: Train Loss: 1.6213, Train Accuracy: 55.24%
#     Worker 7: Train Loss: 1.5832, Train Accuracy: 55.70%
# Epoch 91/150: Test Loss: 1.9260, Test Accuracy: 49.79%
#     Worker 0: Train Loss: 1.5810, Train Accuracy: 56.01%
#     Worker 1: Train Loss: 1.5388, Train Accuracy: 57.01%
#     Worker 2: Train Loss: 1.5617, Train Accuracy: 55.92%
#     Worker 3: Train Loss: 1.5907, Train Accuracy: 55.40%
#     Worker 4: Train Loss: 1.5808, Train Accuracy: 55.68%
#     Worker 5: Train Loss: 1.5661, Train Accuracy: 56.25%
#     Worker 6: Train Loss: 1.6067, Train Accuracy: 54.99%
#     Worker 7: Train Loss: 1.5847, Train Accuracy: 55.34%
# Epoch 92/150: Test Loss: 1.9315, Test Accuracy: 49.73%
#     Worker 0: Train Loss: 1.5507, Train Accuracy: 56.46%
#     Worker 1: Train Loss: 1.5234, Train Accuracy: 57.06%
#     Worker 2: Train Loss: 1.5323, Train Accuracy: 57.30%
#     Worker 3: Train Loss: 1.5846, Train Accuracy: 55.29%
#     Worker 4: Train Loss: 1.5301, Train Accuracy: 56.79%
#     Worker 5: Train Loss: 1.5328, Train Accuracy: 57.46%
#     Worker 6: Train Loss: 1.5721, Train Accuracy: 56.09%
#     Worker 7: Train Loss: 1.5525, Train Accuracy: 56.82%
# Epoch 93/150: Test Loss: 1.9358, Test Accuracy: 49.95%
#     Worker 0: Train Loss: 1.5670, Train Accuracy: 55.84%
#     Worker 1: Train Loss: 1.5344, Train Accuracy: 57.45%
#     Worker 2: Train Loss: 1.5250, Train Accuracy: 57.92%
#     Worker 3: Train Loss: 1.5810, Train Accuracy: 55.64%
#     Worker 4: Train Loss: 1.5192, Train Accuracy: 57.21%
#     Worker 5: Train Loss: 1.5290, Train Accuracy: 57.04%
#     Worker 6: Train Loss: 1.5585, Train Accuracy: 56.84%
#     Worker 7: Train Loss: 1.5486, Train Accuracy: 56.38%
# Epoch 94/150: Test Loss: 1.9271, Test Accuracy: 49.82%
#     Worker 0: Train Loss: 1.5525, Train Accuracy: 56.55%
#     Worker 1: Train Loss: 1.5337, Train Accuracy: 57.11%
# ...
#     Worker 6: Train Loss: 1.3245, Train Accuracy: 62.37%
#     Worker 7: Train Loss: 1.3079, Train Accuracy: 63.43%
# Epoch 120/150: Test Loss: 1.9396, Test Accuracy: 50.51%
#     Worker 0: Train Loss: 1.3148, Train Accuracy: 62.88%
#     Worker 1: Train Loss: 1.2943, Train Accuracy: 63.02%
#     Worker 2: Train Loss: 1.2629, Train Accuracy: 64.42%
#     Worker 3: Train Loss: 1.3499, Train Accuracy: 61.82%
#     Worker 4: Train Loss: 1.2861, Train Accuracy: 63.73%
#     Worker 5: Train Loss: 1.3084, Train Accuracy: 62.74%
#     Worker 6: Train Loss: 1.3219, Train Accuracy: 62.23%
#     Worker 7: Train Loss: 1.3127, Train Accuracy: 62.89%
# Epoch 121/150: Test Loss: 1.9407, Test Accuracy: 50.63%
#     Worker 0: Train Loss: 1.2992, Train Accuracy: 63.43%
#     Worker 1: Train Loss: 1.2816, Train Accuracy: 63.84%
#     Worker 2: Train Loss: 1.2933, Train Accuracy: 63.84%
#     Worker 3: Train Loss: 1.2994, Train Accuracy: 63.02%
#     Worker 4: Train Loss: 1.2673, Train Accuracy: 63.97%
#     Worker 5: Train Loss: 1.2826, Train Accuracy: 63.87%
#     Worker 6: Train Loss: 1.3274, Train Accuracy: 62.58%
#     Worker 7: Train Loss: 1.3016, Train Accuracy: 63.05%
# Epoch 122/150: Test Loss: 1.9462, Test Accuracy: 50.71%
#     Worker 0: Train Loss: 1.3071, Train Accuracy: 62.37%
#     Worker 1: Train Loss: 1.2589, Train Accuracy: 64.05%
#     Worker 2: Train Loss: 1.2650, Train Accuracy: 64.05%
#     Worker 3: Train Loss: 1.3036, Train Accuracy: 62.83%
#     Worker 4: Train Loss: 1.2752, Train Accuracy: 63.59%
#     Worker 5: Train Loss: 1.2817, Train Accuracy: 64.00%
#     Worker 6: Train Loss: 1.3235, Train Accuracy: 62.42%
#     Worker 7: Train Loss: 1.2973, Train Accuracy: 63.32%
# Epoch 123/150: Test Loss: 1.9429, Test Accuracy: 50.81%
#     Worker 0: Train Loss: 1.3066, Train Accuracy: 62.93%
#     Worker 1: Train Loss: 1.2580, Train Accuracy: 63.59%
#     Worker 2: Train Loss: 1.2724, Train Accuracy: 63.57%
#     Worker 3: Train Loss: 1.3081, Train Accuracy: 62.64%
#     Worker 4: Train Loss: 1.2943, Train Accuracy: 63.45%
#     Worker 5: Train Loss: 1.3059, Train Accuracy: 63.26%
#     Worker 6: Train Loss: 1.3287, Train Accuracy: 62.73%
#     Worker 7: Train Loss: 1.2932, Train Accuracy: 62.96%
# Epoch 124/150: Test Loss: 1.9423, Test Accuracy: 50.76%
#     Worker 0: Train Loss: 1.2857, Train Accuracy: 63.27%
#     Worker 1: Train Loss: 1.2565, Train Accuracy: 64.35%
#     Worker 2: Train Loss: 1.2628, Train Accuracy: 63.65%
#     Worker 3: Train Loss: 1.3005, Train Accuracy: 63.53%
#     Worker 4: Train Loss: 1.2597, Train Accuracy: 64.09%
#     Worker 5: Train Loss: 1.2918, Train Accuracy: 63.51%
#     Worker 6: Train Loss: 1.2947, Train Accuracy: 63.49%
#     Worker 7: Train Loss: 1.2609, Train Accuracy: 63.98%
# Epoch 125/150: Test Loss: 1.9449, Test Accuracy: 50.76%
#     Worker 0: Train Loss: 1.2628, Train Accuracy: 64.92%
#     Worker 1: Train Loss: 1.2455, Train Accuracy: 64.46%
#     Worker 2: Train Loss: 1.2559, Train Accuracy: 64.80%
#     Worker 3: Train Loss: 1.2871, Train Accuracy: 63.52%
#     Worker 4: Train Loss: 1.2570, Train Accuracy: 64.05%
#     Worker 5: Train Loss: 1.2646, Train Accuracy: 64.53%
#     Worker 6: Train Loss: 1.3099, Train Accuracy: 63.16%
#     Worker 7: Train Loss: 1.2700, Train Accuracy: 63.49%
# Epoch 126/150: Test Loss: 1.9489, Test Accuracy: 50.64%
#     Worker 0: Train Loss: 1.2836, Train Accuracy: 63.51%
#     Worker 1: Train Loss: 1.2614, Train Accuracy: 64.44%
#     Worker 2: Train Loss: 1.2538, Train Accuracy: 63.92%
#     Worker 3: Train Loss: 1.2717, Train Accuracy: 64.01%
#     Worker 4: Train Loss: 1.2432, Train Accuracy: 64.22%
#     Worker 5: Train Loss: 1.2561, Train Accuracy: 64.80%
#     Worker 6: Train Loss: 1.2961, Train Accuracy: 63.32%
#     Worker 7: Train Loss: 1.2651, Train Accuracy: 63.64%
# Epoch 127/150: Test Loss: 1.9494, Test Accuracy: 50.83%
#     Worker 0: Train Loss: 1.2984, Train Accuracy: 63.23%
#     Worker 1: Train Loss: 1.2467, Train Accuracy: 64.59%
#     Worker 2: Train Loss: 1.2483, Train Accuracy: 64.63%
#     Worker 3: Train Loss: 1.2940, Train Accuracy: 63.43%
#     Worker 4: Train Loss: 1.2573, Train Accuracy: 64.11%
#     Worker 5: Train Loss: 1.2696, Train Accuracy: 64.22%
#     Worker 6: Train Loss: 1.2948, Train Accuracy: 63.23%
#     Worker 7: Train Loss: 1.2777, Train Accuracy: 63.88%
# Epoch 128/150: Test Loss: 1.9497, Test Accuracy: 50.79%
#     Worker 0: Train Loss: 1.2641, Train Accuracy: 63.81%
#     Worker 1: Train Loss: 1.2257, Train Accuracy: 65.02%
#     Worker 2: Train Loss: 1.2339, Train Accuracy: 65.35%
#     Worker 3: Train Loss: 1.2844, Train Accuracy: 63.62%
#     Worker 4: Train Loss: 1.2375, Train Accuracy: 64.52%
#     Worker 5: Train Loss: 1.2827, Train Accuracy: 63.66%
#     Worker 6: Train Loss: 1.2989, Train Accuracy: 63.12%
#     Worker 7: Train Loss: 1.2614, Train Accuracy: 63.97%
# Epoch 129/150: Test Loss: 1.9518, Test Accuracy: 50.67%
#     Worker 0: Train Loss: 1.2622, Train Accuracy: 63.82%
#     Worker 1: Train Loss: 1.2550, Train Accuracy: 64.71%
#     Worker 2: Train Loss: 1.2229, Train Accuracy: 65.47%
#     Worker 3: Train Loss: 1.2540, Train Accuracy: 64.47%
#     Worker 4: Train Loss: 1.2487, Train Accuracy: 64.64%
#     Worker 5: Train Loss: 1.2634, Train Accuracy: 64.86%
#     Worker 6: Train Loss: 1.2840, Train Accuracy: 63.67%
#     Worker 7: Train Loss: 1.2361, Train Accuracy: 64.68%
# Epoch 130/150: Test Loss: 1.9498, Test Accuracy: 50.75%
#     Worker 0: Train Loss: 1.2584, Train Accuracy: 63.92%
#     Worker 1: Train Loss: 1.2374, Train Accuracy: 64.80%
#     Worker 2: Train Loss: 1.2454, Train Accuracy: 65.09%
#     Worker 3: Train Loss: 1.2714, Train Accuracy: 63.65%
#     Worker 4: Train Loss: 1.2461, Train Accuracy: 64.44%
#     Worker 5: Train Loss: 1.2428, Train Accuracy: 64.53%
#     Worker 6: Train Loss: 1.2682, Train Accuracy: 64.04%
#     Worker 7: Train Loss: 1.2632, Train Accuracy: 63.48%
# Epoch 131/150: Test Loss: 1.9505, Test Accuracy: 50.76%
#     Worker 0: Train Loss: 1.2620, Train Accuracy: 63.08%
#     Worker 1: Train Loss: 1.2396, Train Accuracy: 64.94%
#     Worker 2: Train Loss: 1.2146, Train Accuracy: 65.93%
#     Worker 3: Train Loss: 1.2725, Train Accuracy: 64.36%
#     Worker 4: Train Loss: 1.2261, Train Accuracy: 65.61%
#     Worker 5: Train Loss: 1.2560, Train Accuracy: 64.89%
#     Worker 6: Train Loss: 1.3003, Train Accuracy: 63.14%
#     Worker 7: Train Loss: 1.2564, Train Accuracy: 64.00%
# Epoch 132/150: Test Loss: 1.9516, Test Accuracy: 50.57%
#     Worker 0: Train Loss: 1.2481, Train Accuracy: 63.82%
#     Worker 1: Train Loss: 1.2235, Train Accuracy: 64.98%
#     Worker 2: Train Loss: 1.2281, Train Accuracy: 65.30%
#     Worker 3: Train Loss: 1.2771, Train Accuracy: 63.89%
#     Worker 4: Train Loss: 1.2380, Train Accuracy: 64.82%
#     Worker 5: Train Loss: 1.2746, Train Accuracy: 64.35%
#     Worker 6: Train Loss: 1.2627, Train Accuracy: 64.17%
#     Worker 7: Train Loss: 1.2509, Train Accuracy: 64.54%
# Epoch 133/150: Test Loss: 1.9516, Test Accuracy: 50.72%
#     Worker 0: Train Loss: 1.2468, Train Accuracy: 64.24%
#     Worker 1: Train Loss: 1.2305, Train Accuracy: 65.08%
#     Worker 2: Train Loss: 1.2262, Train Accuracy: 65.36%
#     Worker 3: Train Loss: 1.2633, Train Accuracy: 63.65%
#     Worker 4: Train Loss: 1.2397, Train Accuracy: 65.08%
#     Worker 5: Train Loss: 1.2220, Train Accuracy: 65.79%
#     Worker 6: Train Loss: 1.2868, Train Accuracy: 63.26%
#     Worker 7: Train Loss: 1.2548, Train Accuracy: 64.36%
# Epoch 134/150: Test Loss: 1.9499, Test Accuracy: 50.73%
#     Worker 0: Train Loss: 1.2519, Train Accuracy: 64.05%
#     Worker 1: Train Loss: 1.2209, Train Accuracy: 65.16%
#     Worker 2: Train Loss: 1.2109, Train Accuracy: 65.51%
#     Worker 3: Train Loss: 1.2664, Train Accuracy: 64.31%
#     Worker 4: Train Loss: 1.2135, Train Accuracy: 65.77%
#     Worker 5: Train Loss: 1.2519, Train Accuracy: 65.12%
#     Worker 6: Train Loss: 1.2841, Train Accuracy: 63.67%
#     Worker 7: Train Loss: 1.2669, Train Accuracy: 64.27%
# Epoch 135/150: Test Loss: 1.9510, Test Accuracy: 50.59%
#     Worker 0: Train Loss: 1.2579, Train Accuracy: 63.92%
#     Worker 1: Train Loss: 1.2304, Train Accuracy: 64.85%
#     Worker 2: Train Loss: 1.2226, Train Accuracy: 64.90%
#     Worker 3: Train Loss: 1.2574, Train Accuracy: 64.39%
#     Worker 4: Train Loss: 1.2175, Train Accuracy: 65.32%
#     Worker 5: Train Loss: 1.2462, Train Accuracy: 64.47%
#     Worker 6: Train Loss: 1.2630, Train Accuracy: 64.69%
#     Worker 7: Train Loss: 1.2443, Train Accuracy: 65.10%
# Epoch 136/150: Test Loss: 1.9535, Test Accuracy: 50.64%
#     Worker 0: Train Loss: 1.2558, Train Accuracy: 64.53%
#     Worker 1: Train Loss: 1.2231, Train Accuracy: 65.01%
#     Worker 2: Train Loss: 1.2099, Train Accuracy: 65.57%
#     Worker 3: Train Loss: 1.2522, Train Accuracy: 64.64%
#     Worker 4: Train Loss: 1.2205, Train Accuracy: 64.50%
#     Worker 5: Train Loss: 1.2373, Train Accuracy: 65.02%
#     Worker 6: Train Loss: 1.2838, Train Accuracy: 63.55%
#     Worker 7: Train Loss: 1.2385, Train Accuracy: 65.14%
# Epoch 137/150: Test Loss: 1.9530, Test Accuracy: 50.68%
#     Worker 0: Train Loss: 1.2494, Train Accuracy: 64.48%
#     Worker 1: Train Loss: 1.2230, Train Accuracy: 65.06%
#     Worker 2: Train Loss: 1.2259, Train Accuracy: 64.88%
#     Worker 3: Train Loss: 1.2422, Train Accuracy: 64.79%
#     Worker 4: Train Loss: 1.2211, Train Accuracy: 64.93%
#     Worker 5: Train Loss: 1.2413, Train Accuracy: 65.24%
#     Worker 6: Train Loss: 1.2434, Train Accuracy: 64.61%
#     Worker 7: Train Loss: 1.2367, Train Accuracy: 64.14%
# Epoch 138/150: Test Loss: 1.9538, Test Accuracy: 50.63%
#     Worker 0: Train Loss: 1.2392, Train Accuracy: 64.83%
#     Worker 1: Train Loss: 1.2263, Train Accuracy: 65.03%
#     Worker 2: Train Loss: 1.2202, Train Accuracy: 65.17%
#     Worker 3: Train Loss: 1.2574, Train Accuracy: 64.27%
#     Worker 4: Train Loss: 1.2301, Train Accuracy: 64.81%
#     Worker 5: Train Loss: 1.2222, Train Accuracy: 65.14%
#     Worker 6: Train Loss: 1.2780, Train Accuracy: 63.75%
#     Worker 7: Train Loss: 1.2431, Train Accuracy: 65.07%
# Epoch 139/150: Test Loss: 1.9523, Test Accuracy: 50.67%
#     Worker 0: Train Loss: 1.2531, Train Accuracy: 64.22%
#     Worker 1: Train Loss: 1.2245, Train Accuracy: 65.39%
#     Worker 2: Train Loss: 1.2255, Train Accuracy: 64.97%
#     Worker 3: Train Loss: 1.2341, Train Accuracy: 65.10%
#     Worker 4: Train Loss: 1.2304, Train Accuracy: 64.72%
#     Worker 5: Train Loss: 1.2525, Train Accuracy: 64.44%
#     Worker 6: Train Loss: 1.2880, Train Accuracy: 63.61%
#     Worker 7: Train Loss: 1.2423, Train Accuracy: 64.22%
# Epoch 140/150: Test Loss: 1.9530, Test Accuracy: 50.81%
#     Worker 0: Train Loss: 1.2435, Train Accuracy: 63.73%
#     Worker 1: Train Loss: 1.2059, Train Accuracy: 65.74%
#     Worker 2: Train Loss: 1.2074, Train Accuracy: 65.90%
#     Worker 3: Train Loss: 1.2516, Train Accuracy: 64.55%
#     Worker 4: Train Loss: 1.2108, Train Accuracy: 66.05%
#     Worker 5: Train Loss: 1.2208, Train Accuracy: 65.64%
#     Worker 6: Train Loss: 1.2714, Train Accuracy: 63.60%
#     Worker 7: Train Loss: 1.2400, Train Accuracy: 64.83%
# Epoch 141/150: Test Loss: 1.9531, Test Accuracy: 50.64%
#     Worker 0: Train Loss: 1.2409, Train Accuracy: 64.56%
#     Worker 1: Train Loss: 1.2265, Train Accuracy: 64.69%
#     Worker 2: Train Loss: 1.2108, Train Accuracy: 65.45%
#     Worker 3: Train Loss: 1.2372, Train Accuracy: 65.16%
#     Worker 4: Train Loss: 1.2216, Train Accuracy: 64.89%
#     Worker 5: Train Loss: 1.2443, Train Accuracy: 64.70%
#     Worker 6: Train Loss: 1.2551, Train Accuracy: 64.95%
#     Worker 7: Train Loss: 1.2328, Train Accuracy: 64.02%
# Epoch 142/150: Test Loss: 1.9526, Test Accuracy: 50.56%
#     Worker 0: Train Loss: 1.2459, Train Accuracy: 64.90%
#     Worker 1: Train Loss: 1.2099, Train Accuracy: 65.64%
#     Worker 2: Train Loss: 1.2038, Train Accuracy: 65.94%
#     Worker 3: Train Loss: 1.2568, Train Accuracy: 64.49%
#     Worker 4: Train Loss: 1.2440, Train Accuracy: 64.06%
#     Worker 5: Train Loss: 1.2226, Train Accuracy: 65.12%
#     Worker 6: Train Loss: 1.2617, Train Accuracy: 64.00%
#     Worker 7: Train Loss: 1.2353, Train Accuracy: 65.18%
# Epoch 143/150: Test Loss: 1.9529, Test Accuracy: 50.74%
#     Worker 0: Train Loss: 1.2264, Train Accuracy: 64.58%
#     Worker 1: Train Loss: 1.2190, Train Accuracy: 64.68%
#     Worker 2: Train Loss: 1.2297, Train Accuracy: 65.62%
#     Worker 3: Train Loss: 1.2342, Train Accuracy: 64.71%
#     Worker 4: Train Loss: 1.2123, Train Accuracy: 65.42%
#     Worker 5: Train Loss: 1.2400, Train Accuracy: 64.94%
#     Worker 6: Train Loss: 1.2611, Train Accuracy: 64.20%
#     Worker 7: Train Loss: 1.2524, Train Accuracy: 63.99%
# Epoch 144/150: Test Loss: 1.9530, Test Accuracy: 50.60%
#     Worker 0: Train Loss: 1.2717, Train Accuracy: 63.94%
#     Worker 1: Train Loss: 1.2002, Train Accuracy: 65.78%
#     Worker 2: Train Loss: 1.2208, Train Accuracy: 65.68%
#     Worker 3: Train Loss: 1.2550, Train Accuracy: 63.82%
#     Worker 4: Train Loss: 1.2148, Train Accuracy: 65.76%
#     Worker 5: Train Loss: 1.2354, Train Accuracy: 65.43%
#     Worker 6: Train Loss: 1.2729, Train Accuracy: 63.75%
#     Worker 7: Train Loss: 1.2313, Train Accuracy: 65.06%
# Epoch 145/150: Test Loss: 1.9530, Test Accuracy: 50.65%
#     Worker 0: Train Loss: 1.2370, Train Accuracy: 64.37%
#     Worker 1: Train Loss: 1.2260, Train Accuracy: 64.58%
#     Worker 2: Train Loss: 1.1986, Train Accuracy: 65.90%
#     Worker 3: Train Loss: 1.2521, Train Accuracy: 64.58%
#     Worker 4: Train Loss: 1.2188, Train Accuracy: 64.88%
#     Worker 5: Train Loss: 1.2300, Train Accuracy: 65.34%
#     Worker 6: Train Loss: 1.2520, Train Accuracy: 64.52%
#     Worker 7: Train Loss: 1.2530, Train Accuracy: 64.88%
# Epoch 146/150: Test Loss: 1.9533, Test Accuracy: 50.61%
#     Worker 0: Train Loss: 1.2352, Train Accuracy: 65.23%
#     Worker 1: Train Loss: 1.2301, Train Accuracy: 65.51%
#     Worker 2: Train Loss: 1.2166, Train Accuracy: 65.57%
#     Worker 3: Train Loss: 1.2608, Train Accuracy: 64.15%
#     Worker 4: Train Loss: 1.2218, Train Accuracy: 65.41%
#     Worker 5: Train Loss: 1.2289, Train Accuracy: 65.31%
#     Worker 6: Train Loss: 1.2807, Train Accuracy: 63.86%
#     Worker 7: Train Loss: 1.2309, Train Accuracy: 64.97%
# Epoch 147/150: Test Loss: 1.9534, Test Accuracy: 50.67%
#     Worker 0: Train Loss: 1.2622, Train Accuracy: 63.68%
#     Worker 1: Train Loss: 1.2094, Train Accuracy: 65.35%
#     Worker 2: Train Loss: 1.2165, Train Accuracy: 65.03%
#     Worker 3: Train Loss: 1.2379, Train Accuracy: 64.40%
#     Worker 4: Train Loss: 1.2262, Train Accuracy: 65.00%
#     Worker 5: Train Loss: 1.2257, Train Accuracy: 65.38%
#     Worker 6: Train Loss: 1.2551, Train Accuracy: 64.30%
#     Worker 7: Train Loss: 1.2452, Train Accuracy: 64.53%
# Epoch 148/150: Test Loss: 1.9534, Test Accuracy: 50.68%
#     Worker 0: Train Loss: 1.2472, Train Accuracy: 64.41%
#     Worker 1: Train Loss: 1.2171, Train Accuracy: 65.19%
#     Worker 2: Train Loss: 1.2233, Train Accuracy: 65.34%
#     Worker 3: Train Loss: 1.2493, Train Accuracy: 64.26%
#     Worker 4: Train Loss: 1.2035, Train Accuracy: 66.16%
#     Worker 5: Train Loss: 1.2335, Train Accuracy: 65.30%
#     Worker 6: Train Loss: 1.2674, Train Accuracy: 63.88%
#     Worker 7: Train Loss: 1.2345, Train Accuracy: 64.93%
# Epoch 149/150: Test Loss: 1.9533, Test Accuracy: 50.66%
#     Worker 0: Train Loss: 1.2472, Train Accuracy: 64.33%
#     Worker 1: Train Loss: 1.2146, Train Accuracy: 65.63%
#     Worker 2: Train Loss: 1.2040, Train Accuracy: 65.62%
#     Worker 3: Train Loss: 1.2500, Train Accuracy: 64.50%
#     Worker 4: Train Loss: 1.2242, Train Accuracy: 65.20%
#     Worker 5: Train Loss: 1.2264, Train Accuracy: 65.75%
#     Worker 6: Train Loss: 1.2883, Train Accuracy: 63.81%
#     Worker 7: Train Loss: 1.2276, Train Accuracy: 65.13%
# Epoch 150/150: Test Loss: 1.9533, Test Accuracy: 50.65%
#     Worker 0: Train Loss: 1.2507, Train Accuracy: 64.01%
#     Worker 1: Train Loss: 1.1954, Train Accuracy: 65.68%
#     Worker 2: Train Loss: 1.2084, Train Accuracy: 65.53%
#     Worker 3: Train Loss: 1.2540, Train Accuracy: 64.33%
#     Worker 4: Train Loss: 1.2378, Train Accuracy: 65.06%
#     Worker 5: Train Loss: 1.2373, Train Accuracy: 64.97%
#     Worker 6: Train Loss: 1.2646, Train Accuracy: 63.93%
#     Worker 7: Train Loss: 1.2508, Train Accuracy: 64.43%
