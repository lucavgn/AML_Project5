# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files
import time

total_computation_time = 0
total_communication_time = 0

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
#warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")

    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch):
        computation_start_time = time.time()
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            # Perform J local step before synchronization
            for j in range(J):
                try:
                    # Get a batch from the current worker's shard using next()
                    images, labels = next(shard_iterators[k])
                    images, labels = images.to(device), labels.to(device)  # Move to device
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

                except StopIteration:
                    # If the iterator has exhausted the data, restart the iterator
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k]) # Resume from the next batch
                    images, labels = images.to(device), labels.to(device)
                    # Perform optimization step
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        computation_end_time = time.time()
        total_computation_time += (computation_end_time - computation_start_time)

        communication_start_time = time.time()
        # Perform model synchronization
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            # Update each worker model with the global parameters
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

        communication_end_time = time.time()
        total_communication_time += (communication_end_time - communication_start_time)

    # Update lr for each scheduler
    for scheduler in schedulers:
       # if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
       # else:
        #    warmup_factor = (epoch + 1) / warmup_epochs
          #  lr = warmup_factor * learning_rate
          #  for optimizer in optimizers:
           #     for param_group in optimizer.param_groups:
            #        param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

    print(f"Total Computation Time: {total_computation_time:.2f} seconds")
    print(f"Total Communication Time: {total_communication_time:.2f} seconds")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 8 --j 4
# Out:
# Training with K=8, J=4
# Global iteration per epoch: 25
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:03<00:00, 49.0MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00800
# Epoch 1/150: Test Loss: 4.5772, Test Accuracy: 2.41%
#     Worker 0: Train Loss: 4.5989, Train Accuracy: 1.25%
#     Worker 1: Train Loss: 4.5989, Train Accuracy: 1.29%
#     Worker 2: Train Loss: 4.5990, Train Accuracy: 1.25%
#     Worker 3: Train Loss: 4.5968, Train Accuracy: 1.65%
#     Worker 4: Train Loss: 4.5983, Train Accuracy: 1.19%
#     Worker 5: Train Loss: 4.5959, Train Accuracy: 1.57%
#     Worker 6: Train Loss: 4.5983, Train Accuracy: 1.32%
#     Worker 7: Train Loss: 4.5975, Train Accuracy: 1.32%
# Total Computation Time: 25.29 seconds
# Total Communication Time: 0.08 seconds
# Epoch 2/150: Test Loss: 4.2025, Test Accuracy: 5.40%
#     Worker 0: Train Loss: 4.4405, Train Accuracy: 3.56%
#     Worker 1: Train Loss: 4.4450, Train Accuracy: 3.48%
#     Worker 2: Train Loss: 4.4362, Train Accuracy: 3.83%
#     Worker 3: Train Loss: 4.4456, Train Accuracy: 3.78%
#     Worker 4: Train Loss: 4.4341, Train Accuracy: 3.75%
#     Worker 5: Train Loss: 4.4263, Train Accuracy: 3.61%
#     Worker 6: Train Loss: 4.4467, Train Accuracy: 3.51%
#     Worker 7: Train Loss: 4.4347, Train Accuracy: 3.73%
# Total Computation Time: 49.16 seconds
# Total Communication Time: 0.13 seconds
# Epoch 3/150: Test Loss: 3.9949, Test Accuracy: 9.07%
#     Worker 0: Train Loss: 4.1332, Train Accuracy: 6.69%
#     Worker 1: Train Loss: 4.1401, Train Accuracy: 6.13%
#     Worker 2: Train Loss: 4.1380, Train Accuracy: 6.69%
#     Worker 3: Train Loss: 4.1340, Train Accuracy: 6.57%
#     Worker 4: Train Loss: 4.1137, Train Accuracy: 6.52%
#     Worker 5: Train Loss: 4.1124, Train Accuracy: 6.24%
#     Worker 6: Train Loss: 4.1533, Train Accuracy: 6.27%
#     Worker 7: Train Loss: 4.1517, Train Accuracy: 6.54%
# Total Computation Time: 73.10 seconds
# Total Communication Time: 0.19 seconds
# Epoch 4/150: Test Loss: 3.8557, Test Accuracy: 11.55%
#     Worker 0: Train Loss: 3.9896, Train Accuracy: 9.14%
#     Worker 1: Train Loss: 4.0088, Train Accuracy: 7.92%
#     Worker 2: Train Loss: 3.9826, Train Accuracy: 9.33%
#     Worker 3: Train Loss: 4.0131, Train Accuracy: 8.06%
#     Worker 4: Train Loss: 3.9617, Train Accuracy: 9.22%
#     Worker 5: Train Loss: 3.9611, Train Accuracy: 9.08%
#     Worker 6: Train Loss: 3.9974, Train Accuracy: 8.22%
#     Worker 7: Train Loss: 3.9829, Train Accuracy: 8.97%
# Total Computation Time: 97.51 seconds
# Total Communication Time: 0.23 seconds
# Epoch 5/150: Test Loss: 3.7250, Test Accuracy: 13.64%
#     Worker 0: Train Loss: 3.8609, Train Accuracy: 10.71%
#     Worker 1: Train Loss: 3.8443, Train Accuracy: 10.77%
#     Worker 2: Train Loss: 3.8425, Train Accuracy: 11.05%
#     Worker 3: Train Loss: 3.8791, Train Accuracy: 10.72%
#     Worker 4: Train Loss: 3.8140, Train Accuracy: 11.90%
#     Worker 5: Train Loss: 3.8260, Train Accuracy: 11.62%
#     Worker 6: Train Loss: 3.8568, Train Accuracy: 10.44%
#     Worker 7: Train Loss: 3.8531, Train Accuracy: 11.01%
# Total Computation Time: 121.14 seconds
# Total Communication Time: 0.29 seconds
# Epoch 6/150: Test Loss: 3.6017, Test Accuracy: 16.06%
#     Worker 0: Train Loss: 3.7581, Train Accuracy: 12.61%
#     Worker 1: Train Loss: 3.7546, Train Accuracy: 12.40%
#     Worker 2: Train Loss: 3.7325, Train Accuracy: 13.25%
#     Worker 3: Train Loss: 3.7613, Train Accuracy: 12.01%
#     Worker 4: Train Loss: 3.7036, Train Accuracy: 13.25%
#     Worker 5: Train Loss: 3.6934, Train Accuracy: 14.05%
#     Worker 6: Train Loss: 3.7760, Train Accuracy: 12.01%
#     Worker 7: Train Loss: 3.7405, Train Accuracy: 12.48%
# Total Computation Time: 145.04 seconds
# Total Communication Time: 0.34 seconds
# Epoch 7/150: Test Loss: 3.4992, Test Accuracy: 17.75%
#     Worker 0: Train Loss: 3.6355, Train Accuracy: 13.69%
#     Worker 1: Train Loss: 3.6303, Train Accuracy: 13.81%
#     Worker 2: Train Loss: 3.6491, Train Accuracy: 13.91%
#     Worker 3: Train Loss: 3.6782, Train Accuracy: 13.55%
#     Worker 4: Train Loss: 3.6082, Train Accuracy: 14.71%
#     Worker 5: Train Loss: 3.5981, Train Accuracy: 14.96%
#     Worker 6: Train Loss: 3.6535, Train Accuracy: 13.81%
#     Worker 7: Train Loss: 3.6424, Train Accuracy: 14.58%
# Total Computation Time: 168.61 seconds
# Total Communication Time: 0.39 seconds
# Epoch 8/150: Test Loss: 3.4279, Test Accuracy: 18.72%
#     Worker 0: Train Loss: 3.5499, Train Accuracy: 15.82%
#     Worker 1: Train Loss: 3.5571, Train Accuracy: 15.40%
#     Worker 2: Train Loss: 3.5705, Train Accuracy: 15.98%
#     Worker 3: Train Loss: 3.5855, Train Accuracy: 14.77%
#     Worker 4: Train Loss: 3.5308, Train Accuracy: 15.93%
#     Worker 5: Train Loss: 3.5188, Train Accuracy: 16.89%
#     Worker 6: Train Loss: 3.5600, Train Accuracy: 15.91%
#     Worker 7: Train Loss: 3.5737, Train Accuracy: 15.63%
# Total Computation Time: 192.33 seconds
# Total Communication Time: 0.44 seconds
# Epoch 9/150: Test Loss: 3.3608, Test Accuracy: 19.83%
#     Worker 0: Train Loss: 3.5023, Train Accuracy: 16.32%
#     Worker 1: Train Loss: 3.4732, Train Accuracy: 17.39%
#     Worker 2: Train Loss: 3.4965, Train Accuracy: 16.57%
#     Worker 3: Train Loss: 3.4832, Train Accuracy: 17.39%
#     Worker 4: Train Loss: 3.4545, Train Accuracy: 17.64%
#     Worker 5: Train Loss: 3.4349, Train Accuracy: 18.25%
#     Worker 6: Train Loss: 3.4953, Train Accuracy: 16.35%
#     Worker 7: Train Loss: 3.4853, Train Accuracy: 16.10%
# Total Computation Time: 216.02 seconds
# Total Communication Time: 0.49 seconds
# Epoch 10/150: Test Loss: 3.2773, Test Accuracy: 21.40%
#     Worker 0: Train Loss: 3.3965, Train Accuracy: 18.14%
#     Worker 1: Train Loss: 3.3911, Train Accuracy: 18.55%
#     Worker 2: Train Loss: 3.4147, Train Accuracy: 18.88%
#     Worker 3: Train Loss: 3.4505, Train Accuracy: 17.78%
#     Worker 4: Train Loss: 3.3482, Train Accuracy: 19.57%
#     Worker 5: Train Loss: 3.3391, Train Accuracy: 19.66%
#     Worker 6: Train Loss: 3.4279, Train Accuracy: 17.95%
#     Worker 7: Train Loss: 3.3902, Train Accuracy: 18.92%
# Total Computation Time: 239.62 seconds
# Total Communication Time: 0.54 seconds
# Epoch 11/150: Test Loss: 3.2225, Test Accuracy: 22.44%
#     Worker 0: Train Loss: 3.3417, Train Accuracy: 19.43%
#     Worker 1: Train Loss: 3.3179, Train Accuracy: 19.94%
#     Worker 2: Train Loss: 3.3589, Train Accuracy: 20.12%
#     Worker 3: Train Loss: 3.3436, Train Accuracy: 19.30%
#     Worker 4: Train Loss: 3.2988, Train Accuracy: 20.29%
#     Worker 5: Train Loss: 3.2798, Train Accuracy: 20.40%
#     Worker 6: Train Loss: 3.3446, Train Accuracy: 18.61%
#     Worker 7: Train Loss: 3.3518, Train Accuracy: 19.10%
# Total Computation Time: 263.56 seconds
# Total Communication Time: 0.59 seconds
# Epoch 12/150: Test Loss: 3.1549, Test Accuracy: 23.69%
#     Worker 0: Train Loss: 3.2520, Train Accuracy: 21.24%
#     Worker 1: Train Loss: 3.2537, Train Accuracy: 20.52%
#     Worker 2: Train Loss: 3.2619, Train Accuracy: 21.61%
#     Worker 3: Train Loss: 3.2806, Train Accuracy: 20.34%
#     Worker 4: Train Loss: 3.2399, Train Accuracy: 20.71%
#     Worker 5: Train Loss: 3.2385, Train Accuracy: 21.68%
#     Worker 6: Train Loss: 3.2878, Train Accuracy: 20.38%
#     Worker 7: Train Loss: 3.2563, Train Accuracy: 20.57%
# Total Computation Time: 287.17 seconds
# Total Communication Time: 0.64 seconds
# Epoch 13/150: Test Loss: 3.0808, Test Accuracy: 25.40%
#     Worker 0: Train Loss: 3.1992, Train Accuracy: 21.76%
#     Worker 1: Train Loss: 3.1676, Train Accuracy: 21.93%
#     Worker 2: Train Loss: 3.2273, Train Accuracy: 22.36%
#     Worker 3: Train Loss: 3.2494, Train Accuracy: 20.93%
#     Worker 4: Train Loss: 3.1601, Train Accuracy: 22.45%
#     Worker 5: Train Loss: 3.1448, Train Accuracy: 23.68%
#     Worker 6: Train Loss: 3.2314, Train Accuracy: 21.48%
#     Worker 7: Train Loss: 3.2308, Train Accuracy: 21.31%
# Total Computation Time: 310.96 seconds
# Total Communication Time: 0.69 seconds
# Epoch 14/150: Test Loss: 3.0053, Test Accuracy: 26.74%
#     Worker 0: Train Loss: 3.1554, Train Accuracy: 22.34%
#     Worker 1: Train Loss: 3.1368, Train Accuracy: 23.16%
#     Worker 2: Train Loss: 3.1266, Train Accuracy: 24.15%
#     Worker 3: Train Loss: 3.1457, Train Accuracy: 22.83%
#     Worker 4: Train Loss: 3.1159, Train Accuracy: 23.53%
#     Worker 5: Train Loss: 3.1145, Train Accuracy: 23.71%
#     Worker 6: Train Loss: 3.1593, Train Accuracy: 23.27%
#     Worker 7: Train Loss: 3.1239, Train Accuracy: 23.44%
# Total Computation Time: 334.40 seconds
# Total Communication Time: 0.74 seconds
# Epoch 15/150: Test Loss: 3.0128, Test Accuracy: 26.19%
#     Worker 0: Train Loss: 3.0885, Train Accuracy: 24.85%
#     Worker 1: Train Loss: 3.0851, Train Accuracy: 23.44%
#     Worker 2: Train Loss: 3.1175, Train Accuracy: 24.19%
#     Worker 3: Train Loss: 3.1393, Train Accuracy: 23.44%
#     Worker 4: Train Loss: 3.0739, Train Accuracy: 24.19%
#     Worker 5: Train Loss: 3.0565, Train Accuracy: 24.57%
#     Worker 6: Train Loss: 3.1308, Train Accuracy: 22.77%
#     Worker 7: Train Loss: 3.1003, Train Accuracy: 23.94%
# Total Computation Time: 358.13 seconds
# Total Communication Time: 0.79 seconds
# Epoch 16/150: Test Loss: 2.8987, Test Accuracy: 28.90%
#     Worker 0: Train Loss: 3.0669, Train Accuracy: 23.74%
#     Worker 1: Train Loss: 3.0459, Train Accuracy: 24.44%
#     Worker 2: Train Loss: 3.0729, Train Accuracy: 25.32%
#     Worker 3: Train Loss: 3.0572, Train Accuracy: 24.13%
#     Worker 4: Train Loss: 3.0344, Train Accuracy: 25.79%
#     Worker 5: Train Loss: 3.0017, Train Accuracy: 26.89%
#     Worker 6: Train Loss: 3.0422, Train Accuracy: 24.85%
#     Worker 7: Train Loss: 3.0781, Train Accuracy: 24.55%
# Total Computation Time: 381.72 seconds
# Total Communication Time: 0.85 seconds
# Epoch 17/150: Test Loss: 2.8836, Test Accuracy: 29.01%
#     Worker 0: Train Loss: 2.9938, Train Accuracy: 25.87%
#     Worker 1: Train Loss: 2.9503, Train Accuracy: 26.65%
#     Worker 2: Train Loss: 2.9729, Train Accuracy: 26.56%
#     Worker 3: Train Loss: 3.0060, Train Accuracy: 25.89%
#     Worker 4: Train Loss: 2.9355, Train Accuracy: 27.52%
#     Worker 5: Train Loss: 2.9555, Train Accuracy: 26.37%
#     Worker 6: Train Loss: 3.0134, Train Accuracy: 26.15%
#     Worker 7: Train Loss: 2.9919, Train Accuracy: 25.78%
# Total Computation Time: 405.42 seconds
# Total Communication Time: 0.90 seconds
# Epoch 18/150: Test Loss: 2.8535, Test Accuracy: 29.58%
#     Worker 0: Train Loss: 2.9163, Train Accuracy: 28.07%
#     Worker 1: Train Loss: 2.9367, Train Accuracy: 26.61%
#     Worker 2: Train Loss: 2.9300, Train Accuracy: 27.70%
#     Worker 3: Train Loss: 2.9648, Train Accuracy: 26.29%
#     Worker 4: Train Loss: 2.9283, Train Accuracy: 26.61%
#     Worker 5: Train Loss: 2.9174, Train Accuracy: 27.42%
#     Worker 6: Train Loss: 2.9510, Train Accuracy: 26.78%
#     Worker 7: Train Loss: 2.9119, Train Accuracy: 27.66%
# Total Computation Time: 429.17 seconds
# Total Communication Time: 0.95 seconds
# Epoch 19/150: Test Loss: 2.7609, Test Accuracy: 31.63%
#     Worker 0: Train Loss: 2.8770, Train Accuracy: 27.31%
#     Worker 1: Train Loss: 2.8674, Train Accuracy: 28.41%
#     Worker 2: Train Loss: 2.9140, Train Accuracy: 27.50%
#     Worker 3: Train Loss: 2.9008, Train Accuracy: 27.19%
#     Worker 4: Train Loss: 2.8723, Train Accuracy: 28.58%
#     Worker 5: Train Loss: 2.8321, Train Accuracy: 29.99%
#     Worker 6: Train Loss: 2.9050, Train Accuracy: 27.03%
#     Worker 7: Train Loss: 2.8544, Train Accuracy: 28.52%
# Total Computation Time: 452.79 seconds
# Total Communication Time: 1.00 seconds
# Epoch 20/150: Test Loss: 2.7370, Test Accuracy: 31.64%
#     Worker 0: Train Loss: 2.8431, Train Accuracy: 28.93%
#     Worker 1: Train Loss: 2.8064, Train Accuracy: 28.68%
#     Worker 2: Train Loss: 2.8466, Train Accuracy: 29.41%
#     Worker 3: Train Loss: 2.8366, Train Accuracy: 28.71%
#     Worker 4: Train Loss: 2.7778, Train Accuracy: 29.95%
#     Worker 5: Train Loss: 2.7963, Train Accuracy: 30.64%
#     Worker 6: Train Loss: 2.8434, Train Accuracy: 28.16%
#     Worker 7: Train Loss: 2.8712, Train Accuracy: 28.28%
# Total Computation Time: 476.30 seconds
# Total Communication Time: 1.05 seconds
# Epoch 21/150: Test Loss: 2.6903, Test Accuracy: 32.73%
#     Worker 0: Train Loss: 2.8309, Train Accuracy: 29.23%
#     Worker 1: Train Loss: 2.7496, Train Accuracy: 29.98%
#     Worker 2: Train Loss: 2.7949, Train Accuracy: 30.56%
#     Worker 3: Train Loss: 2.8401, Train Accuracy: 29.24%
#     Worker 4: Train Loss: 2.7640, Train Accuracy: 30.46%
#     Worker 5: Train Loss: 2.7502, Train Accuracy: 30.64%
#     Worker 6: Train Loss: 2.8158, Train Accuracy: 29.27%
#     Worker 7: Train Loss: 2.7970, Train Accuracy: 30.28%
# Total Computation Time: 499.83 seconds
# Total Communication Time: 1.10 seconds
# Epoch 22/150: Test Loss: 2.6177, Test Accuracy: 33.85%
#     Worker 0: Train Loss: 2.7467, Train Accuracy: 30.81%
#     Worker 1: Train Loss: 2.7252, Train Accuracy: 30.97%
#     Worker 2: Train Loss: 2.7698, Train Accuracy: 30.48%
#     Worker 3: Train Loss: 2.7482, Train Accuracy: 29.93%
#     Worker 4: Train Loss: 2.7189, Train Accuracy: 31.61%
#     Worker 5: Train Loss: 2.7397, Train Accuracy: 31.28%
#     Worker 6: Train Loss: 2.7568, Train Accuracy: 30.54%
#     Worker 7: Train Loss: 2.7360, Train Accuracy: 31.39%
# Total Computation Time: 523.08 seconds
# Total Communication Time: 1.15 seconds
# Epoch 23/150: Test Loss: 2.6073, Test Accuracy: 33.99%
#     Worker 0: Train Loss: 2.6948, Train Accuracy: 31.61%
#     Worker 1: Train Loss: 2.6679, Train Accuracy: 31.64%
#     Worker 2: Train Loss: 2.7072, Train Accuracy: 31.23%
#     Worker 3: Train Loss: 2.7366, Train Accuracy: 30.04%
#     Worker 4: Train Loss: 2.6661, Train Accuracy: 32.55%
#     Worker 5: Train Loss: 2.6395, Train Accuracy: 33.10%
#     Worker 6: Train Loss: 2.7079, Train Accuracy: 31.56%
#     Worker 7: Train Loss: 2.7032, Train Accuracy: 31.59%
# Total Computation Time: 546.51 seconds
# Total Communication Time: 1.20 seconds
# Epoch 24/150: Test Loss: 2.5580, Test Accuracy: 35.54%
#     Worker 0: Train Loss: 2.6701, Train Accuracy: 32.20%
#     Worker 1: Train Loss: 2.6576, Train Accuracy: 32.64%
#     Worker 2: Train Loss: 2.6805, Train Accuracy: 32.20%
#     Worker 3: Train Loss: 2.6883, Train Accuracy: 31.53%
#     Worker 4: Train Loss: 2.6420, Train Accuracy: 32.42%
#     Worker 5: Train Loss: 2.6346, Train Accuracy: 32.86%
#     Worker 6: Train Loss: 2.6891, Train Accuracy: 31.45%
#     Worker 7: Train Loss: 2.6435, Train Accuracy: 32.63%
# Total Computation Time: 570.00 seconds
# Total Communication Time: 1.25 seconds
# Epoch 25/150: Test Loss: 2.5202, Test Accuracy: 35.73%
#     Worker 0: Train Loss: 2.6422, Train Accuracy: 32.55%
#     Worker 1: Train Loss: 2.5984, Train Accuracy: 32.52%
#     Worker 2: Train Loss: 2.6273, Train Accuracy: 33.76%
#     Worker 3: Train Loss: 2.6639, Train Accuracy: 31.56%
#     Worker 4: Train Loss: 2.5565, Train Accuracy: 34.98%
#     Worker 5: Train Loss: 2.5864, Train Accuracy: 34.05%
#     Worker 6: Train Loss: 2.6608, Train Accuracy: 32.19%
#     Worker 7: Train Loss: 2.6289, Train Accuracy: 33.10%
# Total Computation Time: 593.39 seconds
# Total Communication Time: 1.31 seconds
# Epoch 26/150: Test Loss: 2.4759, Test Accuracy: 36.69%
#     Worker 0: Train Loss: 2.6280, Train Accuracy: 33.25%
#     Worker 1: Train Loss: 2.5443, Train Accuracy: 34.65%
#     Worker 2: Train Loss: 2.5834, Train Accuracy: 34.31%
#     Worker 3: Train Loss: 2.5827, Train Accuracy: 34.37%
#     Worker 4: Train Loss: 2.5593, Train Accuracy: 34.51%
#     Worker 5: Train Loss: 2.5616, Train Accuracy: 34.85%
#     Worker 6: Train Loss: 2.5962, Train Accuracy: 33.74%
#     Worker 7: Train Loss: 2.5628, Train Accuracy: 34.12%
# Total Computation Time: 616.54 seconds
# Total Communication Time: 1.36 seconds
# Epoch 27/150: Test Loss: 2.4560, Test Accuracy: 37.98%
#     Worker 0: Train Loss: 2.5463, Train Accuracy: 34.01%
#     Worker 1: Train Loss: 2.5403, Train Accuracy: 34.70%
#     Worker 2: Train Loss: 2.5623, Train Accuracy: 34.73%
#     Worker 3: Train Loss: 2.5884, Train Accuracy: 33.91%
#     Worker 4: Train Loss: 2.5139, Train Accuracy: 35.42%
#     Worker 5: Train Loss: 2.5119, Train Accuracy: 36.50%
#     Worker 6: Train Loss: 2.5899, Train Accuracy: 33.93%
#     Worker 7: Train Loss: 2.5442, Train Accuracy: 35.09%
# Total Computation Time: 639.72 seconds
# Total Communication Time: 1.41 seconds
# Epoch 28/150: Test Loss: 2.4531, Test Accuracy: 37.44%
#     Worker 0: Train Loss: 2.5512, Train Accuracy: 33.94%
#     Worker 1: Train Loss: 2.5223, Train Accuracy: 34.82%
#     Worker 2: Train Loss: 2.5314, Train Accuracy: 35.86%
#     Worker 3: Train Loss: 2.5533, Train Accuracy: 34.35%
#     Worker 4: Train Loss: 2.5123, Train Accuracy: 35.32%
#     Worker 5: Train Loss: 2.4939, Train Accuracy: 36.06%
#     Worker 6: Train Loss: 2.5191, Train Accuracy: 35.06%
#     Worker 7: Train Loss: 2.5475, Train Accuracy: 34.96%
# Total Computation Time: 662.94 seconds
# Total Communication Time: 1.46 seconds
# Epoch 29/150: Test Loss: 2.4509, Test Accuracy: 37.53%
#     Worker 0: Train Loss: 2.4894, Train Accuracy: 35.76%
#     Worker 1: Train Loss: 2.4582, Train Accuracy: 36.50%
#     Worker 2: Train Loss: 2.4926, Train Accuracy: 35.53%
#     Worker 3: Train Loss: 2.4875, Train Accuracy: 35.86%
#     Worker 4: Train Loss: 2.4794, Train Accuracy: 36.11%
#     Worker 5: Train Loss: 2.4427, Train Accuracy: 37.03%
#     Worker 6: Train Loss: 2.5008, Train Accuracy: 36.05%
#     Worker 7: Train Loss: 2.4599, Train Accuracy: 36.66%
# Total Computation Time: 686.38 seconds
# Total Communication Time: 1.51 seconds
# Epoch 30/150: Test Loss: 2.3770, Test Accuracy: 39.21%
#     Worker 0: Train Loss: 2.4854, Train Accuracy: 36.14%
#     Worker 1: Train Loss: 2.4287, Train Accuracy: 37.00%
#     Worker 2: Train Loss: 2.4722, Train Accuracy: 36.38%
#     Worker 3: Train Loss: 2.4803, Train Accuracy: 35.23%
#     Worker 4: Train Loss: 2.4597, Train Accuracy: 36.31%
#     Worker 5: Train Loss: 2.4401, Train Accuracy: 37.93%
#     Worker 6: Train Loss: 2.4896, Train Accuracy: 36.30%
#     Worker 7: Train Loss: 2.4678, Train Accuracy: 36.20%
# Total Computation Time: 709.66 seconds
# Total Communication Time: 1.56 seconds
# Epoch 31/150: Test Loss: 2.3655, Test Accuracy: 39.52%
#     Worker 0: Train Loss: 2.4273, Train Accuracy: 37.19%
#     Worker 1: Train Loss: 2.4023, Train Accuracy: 37.85%
#     Worker 2: Train Loss: 2.4160, Train Accuracy: 37.90%
#     Worker 3: Train Loss: 2.4704, Train Accuracy: 36.16%
#     Worker 4: Train Loss: 2.3674, Train Accuracy: 38.07%
#     Worker 5: Train Loss: 2.3665, Train Accuracy: 38.29%
#     Worker 6: Train Loss: 2.4159, Train Accuracy: 36.53%
#     Worker 7: Train Loss: 2.4324, Train Accuracy: 36.99%
# Total Computation Time: 732.98 seconds
# Total Communication Time: 1.61 seconds
# Epoch 32/150: Test Loss: 2.3595, Test Accuracy: 39.02%
#     Worker 0: Train Loss: 2.4137, Train Accuracy: 37.05%
#     Worker 1: Train Loss: 2.4040, Train Accuracy: 37.27%
#     Worker 2: Train Loss: 2.3887, Train Accuracy: 37.32%
#     Worker 3: Train Loss: 2.4206, Train Accuracy: 36.58%
#     Worker 4: Train Loss: 2.3661, Train Accuracy: 38.24%
#     Worker 5: Train Loss: 2.3849, Train Accuracy: 39.06%
#     Worker 6: Train Loss: 2.4309, Train Accuracy: 37.17%
#     Worker 7: Train Loss: 2.3884, Train Accuracy: 36.92%
# Total Computation Time: 755.81 seconds
# Total Communication Time: 1.66 seconds
# Epoch 33/150: Test Loss: 2.3171, Test Accuracy: 40.54%
#     Worker 0: Train Loss: 2.3911, Train Accuracy: 37.99%
#     Worker 1: Train Loss: 2.3466, Train Accuracy: 38.30%
#     Worker 2: Train Loss: 2.3941, Train Accuracy: 38.26%
#     Worker 3: Train Loss: 2.3628, Train Accuracy: 38.38%
#     Worker 4: Train Loss: 2.3249, Train Accuracy: 38.71%
#     Worker 5: Train Loss: 2.3338, Train Accuracy: 39.59%
#     Worker 6: Train Loss: 2.3962, Train Accuracy: 37.19%
#     Worker 7: Train Loss: 2.3717, Train Accuracy: 38.27%
# Total Computation Time: 778.62 seconds
# Total Communication Time: 1.71 seconds
# Epoch 34/150: Test Loss: 2.3119, Test Accuracy: 40.53%
#     Worker 0: Train Loss: 2.3767, Train Accuracy: 38.30%
#     Worker 1: Train Loss: 2.3143, Train Accuracy: 39.84%
#     Worker 2: Train Loss: 2.3181, Train Accuracy: 39.90%
#     Worker 3: Train Loss: 2.3628, Train Accuracy: 38.96%
#     Worker 4: Train Loss: 2.3073, Train Accuracy: 39.59%
#     Worker 5: Train Loss: 2.3734, Train Accuracy: 39.09%
#     Worker 6: Train Loss: 2.3488, Train Accuracy: 38.59%
#     Worker 7: Train Loss: 2.3550, Train Accuracy: 38.81%
# Total Computation Time: 801.88 seconds
# Total Communication Time: 1.76 seconds
# Epoch 35/150: Test Loss: 2.2910, Test Accuracy: 40.86%
#     Worker 0: Train Loss: 2.3193, Train Accuracy: 39.34%
#     Worker 1: Train Loss: 2.3073, Train Accuracy: 39.45%
#     Worker 2: Train Loss: 2.3250, Train Accuracy: 39.68%
#     Worker 3: Train Loss: 2.3539, Train Accuracy: 38.26%
#     Worker 4: Train Loss: 2.2954, Train Accuracy: 40.03%
#     Worker 5: Train Loss: 2.2971, Train Accuracy: 40.15%
#     Worker 6: Train Loss: 2.3417, Train Accuracy: 39.57%
#     Worker 7: Train Loss: 2.3076, Train Accuracy: 39.82%
# Total Computation Time: 825.16 seconds
# Total Communication Time: 1.81 seconds
# Epoch 36/150: Test Loss: 2.2800, Test Accuracy: 41.37%
#     Worker 0: Train Loss: 2.3063, Train Accuracy: 39.46%
#     Worker 1: Train Loss: 2.2708, Train Accuracy: 40.58%
#     Worker 2: Train Loss: 2.2730, Train Accuracy: 40.29%
#     Worker 3: Train Loss: 2.2990, Train Accuracy: 39.31%
#     Worker 4: Train Loss: 2.3053, Train Accuracy: 39.70%
#     Worker 5: Train Loss: 2.2727, Train Accuracy: 41.35%
#     Worker 6: Train Loss: 2.3229, Train Accuracy: 39.42%
#     Worker 7: Train Loss: 2.2982, Train Accuracy: 39.86%
# Total Computation Time: 848.43 seconds
# Total Communication Time: 1.86 seconds
# Epoch 37/150: Test Loss: 2.2471, Test Accuracy: 42.26%
#     Worker 0: Train Loss: 2.3042, Train Accuracy: 39.59%
#     Worker 1: Train Loss: 2.2402, Train Accuracy: 40.77%
#     Worker 2: Train Loss: 2.2794, Train Accuracy: 40.14%
#     Worker 3: Train Loss: 2.2774, Train Accuracy: 40.33%
#     Worker 4: Train Loss: 2.2244, Train Accuracy: 42.25%
#     Worker 5: Train Loss: 2.2301, Train Accuracy: 41.88%
#     Worker 6: Train Loss: 2.2675, Train Accuracy: 41.14%
#     Worker 7: Train Loss: 2.2733, Train Accuracy: 40.55%
# Total Computation Time: 871.63 seconds
# Total Communication Time: 1.91 seconds
# Epoch 38/150: Test Loss: 2.2637, Test Accuracy: 41.74%
#     Worker 0: Train Loss: 2.2616, Train Accuracy: 41.11%
#     Worker 1: Train Loss: 2.2456, Train Accuracy: 41.24%
#     Worker 2: Train Loss: 2.2531, Train Accuracy: 40.50%
#     Worker 3: Train Loss: 2.3051, Train Accuracy: 39.64%
#     Worker 4: Train Loss: 2.2157, Train Accuracy: 42.18%
#     Worker 5: Train Loss: 2.2185, Train Accuracy: 42.35%
#     Worker 6: Train Loss: 2.2813, Train Accuracy: 40.56%
#     Worker 7: Train Loss: 2.2438, Train Accuracy: 40.81%
# Total Computation Time: 894.84 seconds
# Total Communication Time: 1.97 seconds
# Epoch 39/150: Test Loss: 2.2257, Test Accuracy: 42.63%
#     Worker 0: Train Loss: 2.2239, Train Accuracy: 41.63%
#     Worker 1: Train Loss: 2.2055, Train Accuracy: 41.44%
#     Worker 2: Train Loss: 2.2257, Train Accuracy: 41.78%
#     Worker 3: Train Loss: 2.2316, Train Accuracy: 40.47%
#     Worker 4: Train Loss: 2.1904, Train Accuracy: 42.11%
#     Worker 5: Train Loss: 2.2130, Train Accuracy: 42.99%
#     Worker 6: Train Loss: 2.2468, Train Accuracy: 41.08%
#     Worker 7: Train Loss: 2.2291, Train Accuracy: 41.33%
# Total Computation Time: 918.07 seconds
# Total Communication Time: 2.02 seconds
# Epoch 40/150: Test Loss: 2.2110, Test Accuracy: 42.98%
#     Worker 0: Train Loss: 2.2083, Train Accuracy: 41.22%
#     Worker 1: Train Loss: 2.1914, Train Accuracy: 41.85%
#     Worker 2: Train Loss: 2.1963, Train Accuracy: 42.29%
#     Worker 3: Train Loss: 2.1935, Train Accuracy: 42.32%
#     Worker 4: Train Loss: 2.1512, Train Accuracy: 43.65%
#     Worker 5: Train Loss: 2.1819, Train Accuracy: 42.68%
#     Worker 6: Train Loss: 2.2320, Train Accuracy: 41.58%
#     Worker 7: Train Loss: 2.1939, Train Accuracy: 42.38%
# Total Computation Time: 941.28 seconds
# Total Communication Time: 2.07 seconds
# Epoch 41/150: Test Loss: 2.1980, Test Accuracy: 43.14%
#     Worker 0: Train Loss: 2.2056, Train Accuracy: 41.50%
#     Worker 1: Train Loss: 2.1522, Train Accuracy: 42.63%
#     Worker 2: Train Loss: 2.1579, Train Accuracy: 42.60%
#     Worker 3: Train Loss: 2.1964, Train Accuracy: 42.49%
#     Worker 4: Train Loss: 2.1278, Train Accuracy: 43.56%
#     Worker 5: Train Loss: 2.1686, Train Accuracy: 43.57%
#     Worker 6: Train Loss: 2.1717, Train Accuracy: 42.33%
#     Worker 7: Train Loss: 2.1774, Train Accuracy: 41.60%
# Total Computation Time: 964.54 seconds
# Total Communication Time: 2.12 seconds
# Epoch 42/150: Test Loss: 2.1889, Test Accuracy: 43.43%
#     Worker 0: Train Loss: 2.1583, Train Accuracy: 42.76%
#     Worker 1: Train Loss: 2.1376, Train Accuracy: 42.85%
#     Worker 2: Train Loss: 2.1638, Train Accuracy: 42.04%
#     Worker 3: Train Loss: 2.2042, Train Accuracy: 42.04%
#     Worker 4: Train Loss: 2.1477, Train Accuracy: 43.56%
#     Worker 5: Train Loss: 2.1147, Train Accuracy: 45.45%
#     Worker 6: Train Loss: 2.1753, Train Accuracy: 43.02%
#     Worker 7: Train Loss: 2.1650, Train Accuracy: 43.27%
# Total Computation Time: 987.75 seconds
# Total Communication Time: 2.17 seconds
# Epoch 43/150: Test Loss: 2.1784, Test Accuracy: 43.45%
#     Worker 0: Train Loss: 2.1503, Train Accuracy: 43.15%
#     Worker 1: Train Loss: 2.1217, Train Accuracy: 43.45%
#     Worker 2: Train Loss: 2.1173, Train Accuracy: 44.14%
#     Worker 3: Train Loss: 2.1456, Train Accuracy: 43.26%
#     Worker 4: Train Loss: 2.0948, Train Accuracy: 44.23%
#     Worker 5: Train Loss: 2.1043, Train Accuracy: 45.19%
#     Worker 6: Train Loss: 2.1658, Train Accuracy: 43.31%
#     Worker 7: Train Loss: 2.1107, Train Accuracy: 44.07%
# Total Computation Time: 1010.72 seconds
# Total Communication Time: 2.22 seconds
# Epoch 44/150: Test Loss: 2.1820, Test Accuracy: 43.26%
#     Worker 0: Train Loss: 2.1243, Train Accuracy: 44.15%
#     Worker 1: Train Loss: 2.1197, Train Accuracy: 44.14%
#     Worker 2: Train Loss: 2.1158, Train Accuracy: 43.85%
#     Worker 3: Train Loss: 2.1491, Train Accuracy: 43.24%
#     Worker 4: Train Loss: 2.0874, Train Accuracy: 44.75%
#     Worker 5: Train Loss: 2.0881, Train Accuracy: 44.81%
#     Worker 6: Train Loss: 2.1162, Train Accuracy: 44.09%
#     Worker 7: Train Loss: 2.0955, Train Accuracy: 44.53%
# Total Computation Time: 1033.97 seconds
# Total Communication Time: 2.27 seconds
# Epoch 45/150: Test Loss: 2.1694, Test Accuracy: 43.43%
#     Worker 0: Train Loss: 2.1038, Train Accuracy: 43.60%
#     Worker 1: Train Loss: 2.0664, Train Accuracy: 44.34%
#     Worker 2: Train Loss: 2.0870, Train Accuracy: 45.03%
#     Worker 3: Train Loss: 2.1102, Train Accuracy: 43.99%
#     Worker 4: Train Loss: 2.0933, Train Accuracy: 44.32%
#     Worker 5: Train Loss: 2.0828, Train Accuracy: 44.92%
#     Worker 6: Train Loss: 2.1523, Train Accuracy: 43.99%
#     Worker 7: Train Loss: 2.1116, Train Accuracy: 44.18%
# Total Computation Time: 1057.72 seconds
# Total Communication Time: 2.32 seconds
# Epoch 46/150: Test Loss: 2.1562, Test Accuracy: 44.09%
#     Worker 0: Train Loss: 2.1041, Train Accuracy: 43.21%
#     Worker 1: Train Loss: 2.0710, Train Accuracy: 44.75%
#     Worker 2: Train Loss: 2.0740, Train Accuracy: 44.75%
#     Worker 3: Train Loss: 2.0979, Train Accuracy: 43.92%
#     Worker 4: Train Loss: 2.0362, Train Accuracy: 45.80%
#     Worker 5: Train Loss: 2.0374, Train Accuracy: 45.88%
#     Worker 6: Train Loss: 2.1037, Train Accuracy: 43.84%
#     Worker 7: Train Loss: 2.0706, Train Accuracy: 45.34%
# Total Computation Time: 1081.26 seconds
# Total Communication Time: 2.37 seconds
# Epoch 47/150: Test Loss: 2.1411, Test Accuracy: 44.58%
#     Worker 0: Train Loss: 2.0827, Train Accuracy: 44.03%
#     Worker 1: Train Loss: 2.0409, Train Accuracy: 45.09%
#     Worker 2: Train Loss: 2.0374, Train Accuracy: 45.95%
#     Worker 3: Train Loss: 2.0680, Train Accuracy: 45.11%
#     Worker 4: Train Loss: 2.0487, Train Accuracy: 45.09%
#     Worker 5: Train Loss: 2.0504, Train Accuracy: 45.67%
#     Worker 6: Train Loss: 2.0704, Train Accuracy: 44.86%
#     Worker 7: Train Loss: 2.0688, Train Accuracy: 44.87%
# Total Computation Time: 1104.72 seconds
# Total Communication Time: 2.42 seconds
# Epoch 48/150: Test Loss: 2.1159, Test Accuracy: 44.61%
#     Worker 0: Train Loss: 2.0616, Train Accuracy: 44.87%
#     Worker 1: Train Loss: 2.0354, Train Accuracy: 45.52%
#     Worker 2: Train Loss: 2.0170, Train Accuracy: 45.77%
#     Worker 3: Train Loss: 2.0634, Train Accuracy: 44.53%
#     Worker 4: Train Loss: 2.0075, Train Accuracy: 46.99%
#     Worker 5: Train Loss: 2.0446, Train Accuracy: 46.22%
#     Worker 6: Train Loss: 2.0731, Train Accuracy: 44.56%
#     Worker 7: Train Loss: 2.0399, Train Accuracy: 45.78%
# Total Computation Time: 1128.13 seconds
# Total Communication Time: 2.47 seconds
# Epoch 49/150: Test Loss: 2.1164, Test Accuracy: 44.99%
#     Worker 0: Train Loss: 2.0383, Train Accuracy: 45.17%
#     Worker 1: Train Loss: 2.0041, Train Accuracy: 46.48%
#     Worker 2: Train Loss: 2.0204, Train Accuracy: 46.18%
#     Worker 3: Train Loss: 2.0377, Train Accuracy: 45.58%
#     Worker 4: Train Loss: 2.0038, Train Accuracy: 46.93%
#     Worker 5: Train Loss: 2.0092, Train Accuracy: 46.76%
#     Worker 6: Train Loss: 2.0369, Train Accuracy: 46.04%
#     Worker 7: Train Loss: 2.0189, Train Accuracy: 46.16%
# Total Computation Time: 1151.57 seconds
# Total Communication Time: 2.52 seconds
# Epoch 50/150: Test Loss: 2.1162, Test Accuracy: 45.19%
#     Worker 0: Train Loss: 2.0242, Train Accuracy: 45.56%
#     Worker 1: Train Loss: 1.9745, Train Accuracy: 46.36%
#     Worker 2: Train Loss: 1.9977, Train Accuracy: 46.80%
#     Worker 3: Train Loss: 2.0168, Train Accuracy: 46.06%
#     Worker 4: Train Loss: 1.9856, Train Accuracy: 46.58%
#     Worker 5: Train Loss: 1.9890, Train Accuracy: 47.35%
#     Worker 6: Train Loss: 2.0281, Train Accuracy: 46.13%
#     Worker 7: Train Loss: 2.0094, Train Accuracy: 46.33%
# Total Computation Time: 1175.27 seconds
# Total Communication Time: 2.57 seconds
# Epoch 51/150: Test Loss: 2.0989, Test Accuracy: 45.32%
#     Worker 0: Train Loss: 2.0074, Train Accuracy: 46.38%
#     Worker 1: Train Loss: 1.9773, Train Accuracy: 47.26%
#     Worker 2: Train Loss: 1.9764, Train Accuracy: 46.55%
#     Worker 3: Train Loss: 1.9965, Train Accuracy: 46.39%
#     Worker 4: Train Loss: 1.9570, Train Accuracy: 47.63%
#     Worker 5: Train Loss: 1.9669, Train Accuracy: 48.13%
#     Worker 6: Train Loss: 2.0084, Train Accuracy: 46.58%
#     Worker 7: Train Loss: 1.9887, Train Accuracy: 46.58%
# Total Computation Time: 1198.79 seconds
# Total Communication Time: 2.62 seconds
# Epoch 52/150: Test Loss: 2.0925, Test Accuracy: 45.59%
#     Worker 0: Train Loss: 2.0004, Train Accuracy: 46.22%
#     Worker 1: Train Loss: 1.9487, Train Accuracy: 46.83%
#     Worker 2: Train Loss: 1.9649, Train Accuracy: 46.47%
#     Worker 3: Train Loss: 1.9789, Train Accuracy: 47.68%
#     Worker 4: Train Loss: 1.9209, Train Accuracy: 48.28%
#     Worker 5: Train Loss: 1.9461, Train Accuracy: 48.26%
#     Worker 6: Train Loss: 1.9749, Train Accuracy: 46.60%
#     Worker 7: Train Loss: 1.9807, Train Accuracy: 46.68%
# Total Computation Time: 1222.17 seconds
# Total Communication Time: 2.67 seconds
# Epoch 53/150: Test Loss: 2.0925, Test Accuracy: 45.82%
#     Worker 0: Train Loss: 1.9701, Train Accuracy: 47.43%
#     Worker 1: Train Loss: 1.9257, Train Accuracy: 47.46%
#     Worker 2: Train Loss: 1.9422, Train Accuracy: 48.13%
#     Worker 3: Train Loss: 1.9676, Train Accuracy: 47.05%
#     Worker 4: Train Loss: 1.9265, Train Accuracy: 47.76%
#     Worker 5: Train Loss: 1.9541, Train Accuracy: 48.12%
#     Worker 6: Train Loss: 1.9675, Train Accuracy: 47.15%
#     Worker 7: Train Loss: 1.9402, Train Accuracy: 47.99%
# Total Computation Time: 1245.67 seconds
# Total Communication Time: 2.72 seconds
# Epoch 54/150: Test Loss: 2.0795, Test Accuracy: 45.82%
#     Worker 0: Train Loss: 1.9639, Train Accuracy: 47.27%
#     Worker 1: Train Loss: 1.9447, Train Accuracy: 46.99%
#     Worker 2: Train Loss: 1.9001, Train Accuracy: 48.89%
#     Worker 3: Train Loss: 1.9509, Train Accuracy: 47.77%
#     Worker 4: Train Loss: 1.8978, Train Accuracy: 48.98%
#     Worker 5: Train Loss: 1.9242, Train Accuracy: 48.32%
#     Worker 6: Train Loss: 1.9665, Train Accuracy: 47.43%
#     Worker 7: Train Loss: 1.9319, Train Accuracy: 47.40%
# Total Computation Time: 1269.34 seconds
# Total Communication Time: 2.77 seconds
# Epoch 55/150: Test Loss: 2.0698, Test Accuracy: 46.47%
#     Worker 0: Train Loss: 1.9449, Train Accuracy: 47.41%
#     Worker 1: Train Loss: 1.9062, Train Accuracy: 48.32%
#     Worker 2: Train Loss: 1.9052, Train Accuracy: 48.90%
#     Worker 3: Train Loss: 1.9414, Train Accuracy: 47.21%
#     Worker 4: Train Loss: 1.9207, Train Accuracy: 47.87%
#     Worker 5: Train Loss: 1.9003, Train Accuracy: 49.47%
#     Worker 6: Train Loss: 1.9332, Train Accuracy: 47.70%
#     Worker 7: Train Loss: 1.9353, Train Accuracy: 47.88%
# Total Computation Time: 1293.03 seconds
# Total Communication Time: 2.82 seconds
# Epoch 56/150: Test Loss: 2.0758, Test Accuracy: 46.14%
#     Worker 0: Train Loss: 1.8986, Train Accuracy: 48.68%
#     Worker 1: Train Loss: 1.8879, Train Accuracy: 48.29%
#     Worker 2: Train Loss: 1.8934, Train Accuracy: 48.67%
#     Worker 3: Train Loss: 1.9378, Train Accuracy: 47.82%
#     Worker 4: Train Loss: 1.8720, Train Accuracy: 49.76%
#     Worker 5: Train Loss: 1.8790, Train Accuracy: 48.82%
#     Worker 6: Train Loss: 1.9328, Train Accuracy: 47.91%
#     Worker 7: Train Loss: 1.9084, Train Accuracy: 48.65%
# Total Computation Time: 1316.66 seconds
# Total Communication Time: 2.88 seconds
# Epoch 57/150: Test Loss: 2.0603, Test Accuracy: 46.86%
#     Worker 0: Train Loss: 1.8922, Train Accuracy: 48.70%
#     Worker 1: Train Loss: 1.8843, Train Accuracy: 48.76%
#     Worker 2: Train Loss: 1.8782, Train Accuracy: 50.11%
#     Worker 3: Train Loss: 1.9166, Train Accuracy: 47.88%
#     Worker 4: Train Loss: 1.8700, Train Accuracy: 49.59%
#     Worker 5: Train Loss: 1.8959, Train Accuracy: 48.78%
#     Worker 6: Train Loss: 1.8995, Train Accuracy: 49.01%
#     Worker 7: Train Loss: 1.8898, Train Accuracy: 49.40%
# Total Computation Time: 1340.37 seconds
# Total Communication Time: 2.93 seconds
# Epoch 58/150: Test Loss: 2.0654, Test Accuracy: 46.44%
#     Worker 0: Train Loss: 1.8733, Train Accuracy: 48.73%
#     Worker 1: Train Loss: 1.8386, Train Accuracy: 50.39%
#     Worker 2: Train Loss: 1.8634, Train Accuracy: 50.22%
#     Worker 3: Train Loss: 1.8863, Train Accuracy: 49.14%
#     Worker 4: Train Loss: 1.8621, Train Accuracy: 49.73%
#     Worker 5: Train Loss: 1.8698, Train Accuracy: 49.29%
#     Worker 6: Train Loss: 1.8884, Train Accuracy: 48.64%
#     Worker 7: Train Loss: 1.8624, Train Accuracy: 49.14%
# Total Computation Time: 1363.95 seconds
# Total Communication Time: 2.98 seconds
# Epoch 59/150: Test Loss: 2.0547, Test Accuracy: 46.81%
#     Worker 0: Train Loss: 1.8828, Train Accuracy: 48.07%
#     Worker 1: Train Loss: 1.8460, Train Accuracy: 49.29%
#     Worker 2: Train Loss: 1.8311, Train Accuracy: 49.76%
#     Worker 3: Train Loss: 1.8571, Train Accuracy: 49.51%
#     Worker 4: Train Loss: 1.8100, Train Accuracy: 50.91%
#     Worker 5: Train Loss: 1.8329, Train Accuracy: 50.25%
#     Worker 6: Train Loss: 1.8606, Train Accuracy: 49.23%
#     Worker 7: Train Loss: 1.8384, Train Accuracy: 50.19%
# Total Computation Time: 1387.63 seconds
# Total Communication Time: 3.03 seconds
# Epoch 60/150: Test Loss: 2.0644, Test Accuracy: 47.16%
#     Worker 0: Train Loss: 1.8629, Train Accuracy: 49.98%
#     Worker 1: Train Loss: 1.8237, Train Accuracy: 50.96%
#     Worker 2: Train Loss: 1.8620, Train Accuracy: 49.91%
#     Worker 3: Train Loss: 1.8509, Train Accuracy: 50.02%
#     Worker 4: Train Loss: 1.8193, Train Accuracy: 49.95%
#     Worker 5: Train Loss: 1.8458, Train Accuracy: 50.67%
#     Worker 6: Train Loss: 1.8624, Train Accuracy: 49.15%
#     Worker 7: Train Loss: 1.8479, Train Accuracy: 49.80%
# Total Computation Time: 1410.92 seconds
# Total Communication Time: 3.08 seconds
# Epoch 61/150: Test Loss: 2.0335, Test Accuracy: 47.33%
#     Worker 0: Train Loss: 1.8537, Train Accuracy: 49.72%
#     Worker 1: Train Loss: 1.7871, Train Accuracy: 51.41%
#     Worker 2: Train Loss: 1.7986, Train Accuracy: 51.85%
#     Worker 3: Train Loss: 1.8483, Train Accuracy: 49.45%
#     Worker 4: Train Loss: 1.8243, Train Accuracy: 49.92%
#     Worker 5: Train Loss: 1.8362, Train Accuracy: 50.64%
#     Worker 6: Train Loss: 1.8513, Train Accuracy: 50.24%
#     Worker 7: Train Loss: 1.7796, Train Accuracy: 51.58%
# Total Computation Time: 1434.29 seconds
# Total Communication Time: 3.13 seconds
# Epoch 62/150: Test Loss: 2.0535, Test Accuracy: 47.00%
#     Worker 0: Train Loss: 1.8185, Train Accuracy: 50.36%
#     Worker 1: Train Loss: 1.7835, Train Accuracy: 51.19%
#     Worker 2: Train Loss: 1.8175, Train Accuracy: 50.55%
#     Worker 3: Train Loss: 1.8456, Train Accuracy: 50.36%
#     Worker 4: Train Loss: 1.7784, Train Accuracy: 51.43%
#     Worker 5: Train Loss: 1.8075, Train Accuracy: 51.55%
#     Worker 6: Train Loss: 1.8384, Train Accuracy: 51.08%
#     Worker 7: Train Loss: 1.8102, Train Accuracy: 50.03%
# Total Computation Time: 1457.87 seconds
# Total Communication Time: 3.18 seconds
# Epoch 63/150: Test Loss: 2.0296, Test Accuracy: 47.20%
#     Worker 0: Train Loss: 1.8240, Train Accuracy: 50.27%
#     Worker 1: Train Loss: 1.7965, Train Accuracy: 50.14%
#     Worker 2: Train Loss: 1.7825, Train Accuracy: 51.69%
#     Worker 3: Train Loss: 1.7846, Train Accuracy: 51.69%
#     Worker 4: Train Loss: 1.7588, Train Accuracy: 51.07%
#     Worker 5: Train Loss: 1.8021, Train Accuracy: 51.22%
#     Worker 6: Train Loss: 1.8273, Train Accuracy: 50.44%
#     Worker 7: Train Loss: 1.8046, Train Accuracy: 50.91%
# Total Computation Time: 1481.15 seconds
# Total Communication Time: 3.24 seconds
# Epoch 64/150: Test Loss: 2.0445, Test Accuracy: 46.93%
#     Worker 0: Train Loss: 1.8225, Train Accuracy: 50.25%
#     Worker 1: Train Loss: 1.7644, Train Accuracy: 51.58%
#     Worker 2: Train Loss: 1.7589, Train Accuracy: 52.52%
#     Worker 3: Train Loss: 1.8270, Train Accuracy: 49.89%
#     Worker 4: Train Loss: 1.7753, Train Accuracy: 51.98%
#     Worker 5: Train Loss: 1.7591, Train Accuracy: 52.23%
#     Worker 6: Train Loss: 1.8005, Train Accuracy: 50.85%
#     Worker 7: Train Loss: 1.8178, Train Accuracy: 50.86%
# Total Computation Time: 1504.46 seconds
# Total Communication Time: 3.29 seconds
# Epoch 65/150: Test Loss: 2.0283, Test Accuracy: 47.52%
#     Worker 0: Train Loss: 1.7534, Train Accuracy: 52.05%
#     Worker 1: Train Loss: 1.7724, Train Accuracy: 51.18%
#     Worker 2: Train Loss: 1.7733, Train Accuracy: 51.19%
#     Worker 3: Train Loss: 1.7953, Train Accuracy: 50.97%
#     Worker 4: Train Loss: 1.7948, Train Accuracy: 51.29%
#     Worker 5: Train Loss: 1.7953, Train Accuracy: 51.87%
#     Worker 6: Train Loss: 1.7904, Train Accuracy: 51.52%
#     Worker 7: Train Loss: 1.7493, Train Accuracy: 52.37%
# Total Computation Time: 1527.79 seconds
# Total Communication Time: 3.34 seconds
# Epoch 66/150: Test Loss: 2.0231, Test Accuracy: 47.32%
#     Worker 0: Train Loss: 1.7800, Train Accuracy: 51.54%
#     Worker 1: Train Loss: 1.7365, Train Accuracy: 52.67%
#     Worker 2: Train Loss: 1.7408, Train Accuracy: 52.65%
#     Worker 3: Train Loss: 1.7752, Train Accuracy: 51.99%
#     Worker 4: Train Loss: 1.7062, Train Accuracy: 52.90%
#     Worker 5: Train Loss: 1.7387, Train Accuracy: 52.79%
#     Worker 6: Train Loss: 1.7860, Train Accuracy: 50.88%
#     Worker 7: Train Loss: 1.7547, Train Accuracy: 51.77%
# Total Computation Time: 1551.14 seconds
# Total Communication Time: 3.39 seconds
# Epoch 67/150: Test Loss: 2.0420, Test Accuracy: 47.43%
#     Worker 0: Train Loss: 1.7627, Train Accuracy: 51.71%
#     Worker 1: Train Loss: 1.7134, Train Accuracy: 52.16%
#     Worker 2: Train Loss: 1.7804, Train Accuracy: 51.29%
#     Worker 3: Train Loss: 1.7447, Train Accuracy: 52.70%
#     Worker 4: Train Loss: 1.7243, Train Accuracy: 52.78%
#     Worker 5: Train Loss: 1.7262, Train Accuracy: 53.36%
#     Worker 6: Train Loss: 1.7568, Train Accuracy: 51.69%
#     Worker 7: Train Loss: 1.7364, Train Accuracy: 52.79%
# Total Computation Time: 1574.59 seconds
# Total Communication Time: 3.44 seconds
# Epoch 68/150: Test Loss: 2.0074, Test Accuracy: 48.13%
#     Worker 0: Train Loss: 1.7549, Train Accuracy: 51.82%
#     Worker 1: Train Loss: 1.7153, Train Accuracy: 52.70%
#     Worker 2: Train Loss: 1.7219, Train Accuracy: 52.90%
#     Worker 3: Train Loss: 1.7721, Train Accuracy: 51.19%
#     Worker 4: Train Loss: 1.7050, Train Accuracy: 53.15%
#     Worker 5: Train Loss: 1.7080, Train Accuracy: 53.79%
#     Worker 6: Train Loss: 1.7528, Train Accuracy: 52.30%
#     Worker 7: Train Loss: 1.7451, Train Accuracy: 52.16%
# Total Computation Time: 1597.94 seconds
# Total Communication Time: 3.49 seconds
# Epoch 69/150: Test Loss: 2.0116, Test Accuracy: 47.67%
#     Worker 0: Train Loss: 1.7155, Train Accuracy: 53.14%
#     Worker 1: Train Loss: 1.7012, Train Accuracy: 52.88%
#     Worker 2: Train Loss: 1.6837, Train Accuracy: 54.05%
#     Worker 3: Train Loss: 1.7272, Train Accuracy: 52.30%
#     Worker 4: Train Loss: 1.7036, Train Accuracy: 53.26%
#     Worker 5: Train Loss: 1.7115, Train Accuracy: 53.18%
#     Worker 6: Train Loss: 1.7668, Train Accuracy: 50.88%
#     Worker 7: Train Loss: 1.7260, Train Accuracy: 52.88%
# Total Computation Time: 1621.29 seconds
# Total Communication Time: 3.54 seconds
# Epoch 70/150: Test Loss: 2.0147, Test Accuracy: 47.91%
#     Worker 0: Train Loss: 1.7332, Train Accuracy: 52.73%
#     Worker 1: Train Loss: 1.6836, Train Accuracy: 53.21%
#     Worker 2: Train Loss: 1.6916, Train Accuracy: 53.73%
#     Worker 3: Train Loss: 1.7524, Train Accuracy: 52.21%
#     Worker 4: Train Loss: 1.6784, Train Accuracy: 52.85%
#     Worker 5: Train Loss: 1.7045, Train Accuracy: 53.64%
#     Worker 6: Train Loss: 1.7144, Train Accuracy: 53.64%
#     Worker 7: Train Loss: 1.6985, Train Accuracy: 52.99%
# Total Computation Time: 1644.48 seconds
# Total Communication Time: 3.59 seconds
# Epoch 71/150: Test Loss: 2.0201, Test Accuracy: 47.41%
#     Worker 0: Train Loss: 1.6948, Train Accuracy: 52.73%
#     Worker 1: Train Loss: 1.6576, Train Accuracy: 53.70%
#     Worker 2: Train Loss: 1.6964, Train Accuracy: 53.45%
#     Worker 3: Train Loss: 1.7120, Train Accuracy: 52.84%
#     Worker 4: Train Loss: 1.6703, Train Accuracy: 54.20%
#     Worker 5: Train Loss: 1.6667, Train Accuracy: 54.30%
#     Worker 6: Train Loss: 1.7179, Train Accuracy: 53.07%
#     Worker 7: Train Loss: 1.6860, Train Accuracy: 53.83%
# Total Computation Time: 1668.06 seconds
# Total Communication Time: 3.64 seconds
# Epoch 72/150: Test Loss: 1.9903, Test Accuracy: 48.39%
#     Worker 0: Train Loss: 1.7069, Train Accuracy: 53.54%
#     Worker 1: Train Loss: 1.6393, Train Accuracy: 54.55%
#     Worker 2: Train Loss: 1.6851, Train Accuracy: 54.37%
#     Worker 3: Train Loss: 1.7111, Train Accuracy: 52.95%
#     Worker 4: Train Loss: 1.6454, Train Accuracy: 54.63%
#     Worker 5: Train Loss: 1.6668, Train Accuracy: 53.95%
#     Worker 6: Train Loss: 1.7117, Train Accuracy: 53.28%
#     Worker 7: Train Loss: 1.6777, Train Accuracy: 52.99%
# Total Computation Time: 1691.56 seconds
# Total Communication Time: 3.69 seconds
# Epoch 73/150: Test Loss: 1.9826, Test Accuracy: 48.64%
#     Worker 0: Train Loss: 1.6740, Train Accuracy: 53.75%
#     Worker 1: Train Loss: 1.6727, Train Accuracy: 53.40%
#     Worker 2: Train Loss: 1.6460, Train Accuracy: 54.70%
#     Worker 3: Train Loss: 1.6838, Train Accuracy: 53.50%
#     Worker 4: Train Loss: 1.6496, Train Accuracy: 54.26%
#     Worker 5: Train Loss: 1.6571, Train Accuracy: 54.47%
#     Worker 6: Train Loss: 1.6903, Train Accuracy: 53.79%
#     Worker 7: Train Loss: 1.6751, Train Accuracy: 54.06%
# Total Computation Time: 1714.93 seconds
# Total Communication Time: 3.74 seconds
# Epoch 74/150: Test Loss: 2.0027, Test Accuracy: 48.23%
#     Worker 0: Train Loss: 1.6710, Train Accuracy: 53.39%
#     Worker 1: Train Loss: 1.6350, Train Accuracy: 54.64%
#     Worker 2: Train Loss: 1.6464, Train Accuracy: 55.17%
#     Worker 3: Train Loss: 1.6495, Train Accuracy: 54.89%
#     Worker 4: Train Loss: 1.6411, Train Accuracy: 55.22%
#     Worker 5: Train Loss: 1.6352, Train Accuracy: 54.50%
#     Worker 6: Train Loss: 1.6685, Train Accuracy: 54.08%
#     Worker 7: Train Loss: 1.6422, Train Accuracy: 54.42%
# Total Computation Time: 1738.47 seconds
# Total Communication Time: 3.80 seconds
# Epoch 75/150: Test Loss: 1.9912, Test Accuracy: 48.16%
#     Worker 0: Train Loss: 1.6722, Train Accuracy: 54.14%
#     Worker 1: Train Loss: 1.6376, Train Accuracy: 54.36%
#     Worker 2: Train Loss: 1.6197, Train Accuracy: 55.69%
#     Worker 3: Train Loss: 1.6691, Train Accuracy: 53.78%
#     Worker 4: Train Loss: 1.6229, Train Accuracy: 54.42%
#     Worker 5: Train Loss: 1.6585, Train Accuracy: 54.63%
#     Worker 6: Train Loss: 1.6628, Train Accuracy: 54.25%
#     Worker 7: Train Loss: 1.6316, Train Accuracy: 55.88%
# Total Computation Time: 1762.06 seconds
# Total Communication Time: 3.85 seconds
# Epoch 76/150: Test Loss: 2.0001, Test Accuracy: 48.20%
#     Worker 0: Train Loss: 1.6297, Train Accuracy: 54.89%
#     Worker 1: Train Loss: 1.6266, Train Accuracy: 54.78%
#     Worker 2: Train Loss: 1.6237, Train Accuracy: 55.03%
#     Worker 3: Train Loss: 1.6536, Train Accuracy: 54.39%
#     Worker 4: Train Loss: 1.6157, Train Accuracy: 55.30%
#     Worker 5: Train Loss: 1.6333, Train Accuracy: 55.79%
#     Worker 6: Train Loss: 1.6766, Train Accuracy: 53.79%
#     Worker 7: Train Loss: 1.6202, Train Accuracy: 55.24%
# Total Computation Time: 1785.61 seconds
# Total Communication Time: 3.90 seconds
# Epoch 77/150: Test Loss: 2.0049, Test Accuracy: 48.60%
#     Worker 0: Train Loss: 1.6620, Train Accuracy: 54.05%
#     Worker 1: Train Loss: 1.6102, Train Accuracy: 54.89%
#     Worker 2: Train Loss: 1.6084, Train Accuracy: 55.46%
#     Worker 3: Train Loss: 1.6437, Train Accuracy: 54.23%
#     Worker 4: Train Loss: 1.5939, Train Accuracy: 55.21%
#     Worker 5: Train Loss: 1.6113, Train Accuracy: 55.74%
#     Worker 6: Train Loss: 1.6629, Train Accuracy: 53.98%
#     Worker 7: Train Loss: 1.6279, Train Accuracy: 55.53%
# Total Computation Time: 1809.33 seconds
# Total Communication Time: 3.95 seconds
# Epoch 78/150: Test Loss: 2.0013, Test Accuracy: 48.35%
#     Worker 0: Train Loss: 1.6056, Train Accuracy: 55.24%
#     Worker 1: Train Loss: 1.5583, Train Accuracy: 55.85%
#     Worker 2: Train Loss: 1.6008, Train Accuracy: 56.51%
#     Worker 3: Train Loss: 1.6268, Train Accuracy: 54.95%
#     Worker 4: Train Loss: 1.6090, Train Accuracy: 54.75%
#     Worker 5: Train Loss: 1.6153, Train Accuracy: 55.79%
#     Worker 6: Train Loss: 1.6521, Train Accuracy: 55.35%
#     Worker 7: Train Loss: 1.6328, Train Accuracy: 54.78%
# Total Computation Time: 1833.09 seconds
# Total Communication Time: 4.01 seconds
# Epoch 79/150: Test Loss: 1.9840, Test Accuracy: 48.61%
#     Worker 0: Train Loss: 1.6091, Train Accuracy: 55.28%
#     Worker 1: Train Loss: 1.6024, Train Accuracy: 55.49%
#     Worker 2: Train Loss: 1.5901, Train Accuracy: 56.02%
#     Worker 3: Train Loss: 1.5842, Train Accuracy: 56.32%
#     Worker 4: Train Loss: 1.5670, Train Accuracy: 56.04%
#     Worker 5: Train Loss: 1.6116, Train Accuracy: 55.82%
#     Worker 6: Train Loss: 1.6080, Train Accuracy: 56.02%
#     Worker 7: Train Loss: 1.5979, Train Accuracy: 55.71%
# Total Computation Time: 1856.54 seconds
# Total Communication Time: 4.06 seconds
# Epoch 80/150: Test Loss: 1.9819, Test Accuracy: 49.00%
#     Worker 0: Train Loss: 1.6089, Train Accuracy: 54.59%
#     Worker 1: Train Loss: 1.5798, Train Accuracy: 55.80%
#     Worker 2: Train Loss: 1.5863, Train Accuracy: 56.10%
#     Worker 3: Train Loss: 1.5915, Train Accuracy: 55.36%
#     Worker 4: Train Loss: 1.5847, Train Accuracy: 55.69%
#     Worker 5: Train Loss: 1.5861, Train Accuracy: 56.51%
#     Worker 6: Train Loss: 1.6298, Train Accuracy: 54.95%
#     Worker 7: Train Loss: 1.5862, Train Accuracy: 56.59%
# Total Computation Time: 1880.12 seconds
# Total Communication Time: 4.11 seconds
# Epoch 81/150: Test Loss: 1.9866, Test Accuracy: 48.80%
#     Worker 0: Train Loss: 1.6083, Train Accuracy: 55.41%
#     Worker 1: Train Loss: 1.5341, Train Accuracy: 57.48%
#     Worker 2: Train Loss: 1.5667, Train Accuracy: 57.12%
#     Worker 3: Train Loss: 1.5812, Train Accuracy: 56.59%
#     Worker 4: Train Loss: 1.5347, Train Accuracy: 56.54%
#     Worker 5: Train Loss: 1.5532, Train Accuracy: 57.35%
#     Worker 6: Train Loss: 1.5955, Train Accuracy: 55.30%
#     Worker 7: Train Loss: 1.5861, Train Accuracy: 56.38%
# ...
# Total Communication Time: 6.32 seconds
# Epoch 124/150: Test Loss: 1.9765, Test Accuracy: 49.98%
#     Worker 0: Train Loss: 1.2994, Train Accuracy: 63.62%
#     Worker 1: Train Loss: 1.2412, Train Accuracy: 64.33%
#     Worker 2: Train Loss: 1.2628, Train Accuracy: 64.53%
#     Worker 3: Train Loss: 1.2647, Train Accuracy: 63.95%
#     Worker 4: Train Loss: 1.2622, Train Accuracy: 63.86%
#     Worker 5: Train Loss: 1.2655, Train Accuracy: 64.00%
#     Worker 6: Train Loss: 1.2880, Train Accuracy: 63.15%
#     Worker 7: Train Loss: 1.2605, Train Accuracy: 64.68%
# Total Computation Time: 2914.11 seconds
# Total Communication Time: 6.37 seconds
# Epoch 125/150: Test Loss: 1.9731, Test Accuracy: 50.42%
#     Worker 0: Train Loss: 1.2516, Train Accuracy: 64.77%
#     Worker 1: Train Loss: 1.2519, Train Accuracy: 63.52%
#     Worker 2: Train Loss: 1.2555, Train Accuracy: 64.36%
#     Worker 3: Train Loss: 1.2800, Train Accuracy: 63.55%
#     Worker 4: Train Loss: 1.2571, Train Accuracy: 64.30%
#     Worker 5: Train Loss: 1.2364, Train Accuracy: 65.58%
#     Worker 6: Train Loss: 1.3131, Train Accuracy: 63.69%
#     Worker 7: Train Loss: 1.2740, Train Accuracy: 63.14%
# Total Computation Time: 2937.40 seconds
# Total Communication Time: 6.42 seconds
# Epoch 126/150: Test Loss: 1.9745, Test Accuracy: 50.33%
#     Worker 0: Train Loss: 1.2712, Train Accuracy: 63.55%
#     Worker 1: Train Loss: 1.2265, Train Accuracy: 64.63%
#     Worker 2: Train Loss: 1.2331, Train Accuracy: 65.60%
#     Worker 3: Train Loss: 1.2884, Train Accuracy: 63.62%
#     Worker 4: Train Loss: 1.2765, Train Accuracy: 63.97%
#     Worker 5: Train Loss: 1.2804, Train Accuracy: 64.55%
#     Worker 6: Train Loss: 1.2820, Train Accuracy: 64.55%
#     Worker 7: Train Loss: 1.2393, Train Accuracy: 65.44%
# Total Computation Time: 2960.81 seconds
# Total Communication Time: 6.47 seconds
# Epoch 127/150: Test Loss: 1.9738, Test Accuracy: 50.42%
#     Worker 0: Train Loss: 1.2715, Train Accuracy: 63.92%
#     Worker 1: Train Loss: 1.2330, Train Accuracy: 64.60%
#     Worker 2: Train Loss: 1.2410, Train Accuracy: 64.64%
#     Worker 3: Train Loss: 1.2693, Train Accuracy: 63.28%
#     Worker 4: Train Loss: 1.2355, Train Accuracy: 65.05%
#     Worker 5: Train Loss: 1.2488, Train Accuracy: 64.80%
#     Worker 6: Train Loss: 1.2603, Train Accuracy: 63.22%
#     Worker 7: Train Loss: 1.2652, Train Accuracy: 64.71%
# Total Computation Time: 2984.17 seconds
# Total Communication Time: 6.52 seconds
# Epoch 128/150: Test Loss: 1.9767, Test Accuracy: 50.42%
#     Worker 0: Train Loss: 1.2596, Train Accuracy: 64.17%
#     Worker 1: Train Loss: 1.2482, Train Accuracy: 64.41%
#     Worker 2: Train Loss: 1.2248, Train Accuracy: 64.85%
#     Worker 3: Train Loss: 1.2555, Train Accuracy: 64.60%
#     Worker 4: Train Loss: 1.2695, Train Accuracy: 64.57%
#     Worker 5: Train Loss: 1.2543, Train Accuracy: 64.85%
#     Worker 6: Train Loss: 1.2958, Train Accuracy: 63.39%
#     Worker 7: Train Loss: 1.2605, Train Accuracy: 63.97%
# Total Computation Time: 3007.68 seconds
# Total Communication Time: 6.58 seconds
# Epoch 129/150: Test Loss: 1.9749, Test Accuracy: 50.48%
#     Worker 0: Train Loss: 1.2517, Train Accuracy: 64.39%
#     Worker 1: Train Loss: 1.2298, Train Accuracy: 65.22%
#     Worker 2: Train Loss: 1.2404, Train Accuracy: 65.95%
#     Worker 3: Train Loss: 1.2830, Train Accuracy: 63.75%
#     Worker 4: Train Loss: 1.2778, Train Accuracy: 63.80%
#     Worker 5: Train Loss: 1.2595, Train Accuracy: 64.57%
#     Worker 6: Train Loss: 1.3011, Train Accuracy: 63.50%
#     Worker 7: Train Loss: 1.2229, Train Accuracy: 65.85%
# Total Computation Time: 3031.31 seconds
# Total Communication Time: 6.62 seconds
# Epoch 130/150: Test Loss: 1.9773, Test Accuracy: 50.73%
#     Worker 0: Train Loss: 1.2507, Train Accuracy: 64.21%
#     Worker 1: Train Loss: 1.2098, Train Accuracy: 64.89%
#     Worker 2: Train Loss: 1.2349, Train Accuracy: 65.26%
#     Worker 3: Train Loss: 1.2616, Train Accuracy: 64.86%
#     Worker 4: Train Loss: 1.2221, Train Accuracy: 65.43%
#     Worker 5: Train Loss: 1.2287, Train Accuracy: 65.88%
#     Worker 6: Train Loss: 1.2777, Train Accuracy: 63.91%
#     Worker 7: Train Loss: 1.2579, Train Accuracy: 64.50%
# Total Computation Time: 3054.71 seconds
# Total Communication Time: 6.68 seconds
# Epoch 131/150: Test Loss: 1.9772, Test Accuracy: 50.51%
#     Worker 0: Train Loss: 1.2616, Train Accuracy: 64.42%
#     Worker 1: Train Loss: 1.2218, Train Accuracy: 65.16%
#     Worker 2: Train Loss: 1.2482, Train Accuracy: 65.02%
#     Worker 3: Train Loss: 1.2782, Train Accuracy: 63.58%
#     Worker 4: Train Loss: 1.2493, Train Accuracy: 64.80%
#     Worker 5: Train Loss: 1.2563, Train Accuracy: 64.06%
#     Worker 6: Train Loss: 1.2565, Train Accuracy: 65.13%
#     Worker 7: Train Loss: 1.2634, Train Accuracy: 63.94%
# Total Computation Time: 3078.26 seconds
# Total Communication Time: 6.73 seconds
# Epoch 132/150: Test Loss: 1.9720, Test Accuracy: 50.49%
#     Worker 0: Train Loss: 1.2655, Train Accuracy: 64.35%
#     Worker 1: Train Loss: 1.2139, Train Accuracy: 65.54%
#     Worker 2: Train Loss: 1.2077, Train Accuracy: 65.48%
#     Worker 3: Train Loss: 1.2288, Train Accuracy: 65.05%
#     Worker 4: Train Loss: 1.2363, Train Accuracy: 64.60%
#     Worker 5: Train Loss: 1.2258, Train Accuracy: 66.01%
#     Worker 6: Train Loss: 1.2672, Train Accuracy: 64.30%
#     Worker 7: Train Loss: 1.2523, Train Accuracy: 64.97%
# Total Computation Time: 3101.64 seconds
# Total Communication Time: 6.78 seconds
# Epoch 133/150: Test Loss: 1.9762, Test Accuracy: 50.39%
#     Worker 0: Train Loss: 1.2511, Train Accuracy: 65.66%
#     Worker 1: Train Loss: 1.2360, Train Accuracy: 64.66%
#     Worker 2: Train Loss: 1.2383, Train Accuracy: 65.11%
#     Worker 3: Train Loss: 1.2421, Train Accuracy: 65.13%
#     Worker 4: Train Loss: 1.2505, Train Accuracy: 64.46%
#     Worker 5: Train Loss: 1.2571, Train Accuracy: 64.19%
#     Worker 6: Train Loss: 1.2542, Train Accuracy: 64.64%
#     Worker 7: Train Loss: 1.2263, Train Accuracy: 65.26%
# Total Computation Time: 3125.16 seconds
# Total Communication Time: 6.83 seconds
# Epoch 134/150: Test Loss: 1.9770, Test Accuracy: 50.36%
#     Worker 0: Train Loss: 1.2141, Train Accuracy: 65.35%
#     Worker 1: Train Loss: 1.1953, Train Accuracy: 65.73%
#     Worker 2: Train Loss: 1.2293, Train Accuracy: 65.46%
#     Worker 3: Train Loss: 1.2650, Train Accuracy: 64.03%
#     Worker 4: Train Loss: 1.2360, Train Accuracy: 64.69%
#     Worker 5: Train Loss: 1.2257, Train Accuracy: 65.16%
#     Worker 6: Train Loss: 1.2500, Train Accuracy: 64.86%
#     Worker 7: Train Loss: 1.2437, Train Accuracy: 64.97%
# Total Computation Time: 3148.32 seconds
# Total Communication Time: 6.88 seconds
# Epoch 135/150: Test Loss: 1.9735, Test Accuracy: 50.49%
#     Worker 0: Train Loss: 1.2675, Train Accuracy: 63.83%
#     Worker 1: Train Loss: 1.2190, Train Accuracy: 64.99%
#     Worker 2: Train Loss: 1.2448, Train Accuracy: 65.27%
#     Worker 3: Train Loss: 1.2434, Train Accuracy: 64.69%
#     Worker 4: Train Loss: 1.2364, Train Accuracy: 65.13%
#     Worker 5: Train Loss: 1.2421, Train Accuracy: 65.55%
#     Worker 6: Train Loss: 1.2615, Train Accuracy: 64.16%
#     Worker 7: Train Loss: 1.2168, Train Accuracy: 65.48%
# Total Computation Time: 3171.41 seconds
# Total Communication Time: 6.93 seconds
# Epoch 136/150: Test Loss: 1.9731, Test Accuracy: 50.56%
#     Worker 0: Train Loss: 1.2251, Train Accuracy: 65.82%
#     Worker 1: Train Loss: 1.2036, Train Accuracy: 65.48%
#     Worker 2: Train Loss: 1.2077, Train Accuracy: 65.93%
#     Worker 3: Train Loss: 1.2565, Train Accuracy: 64.05%
#     Worker 4: Train Loss: 1.2137, Train Accuracy: 65.62%
#     Worker 5: Train Loss: 1.2245, Train Accuracy: 65.27%
#     Worker 6: Train Loss: 1.2683, Train Accuracy: 64.27%
#     Worker 7: Train Loss: 1.2389, Train Accuracy: 65.21%
# Total Computation Time: 3194.73 seconds
# Total Communication Time: 6.98 seconds
# Epoch 137/150: Test Loss: 1.9743, Test Accuracy: 50.57%
#     Worker 0: Train Loss: 1.2643, Train Accuracy: 64.38%
#     Worker 1: Train Loss: 1.2136, Train Accuracy: 65.98%
#     Worker 2: Train Loss: 1.2551, Train Accuracy: 65.69%
#     Worker 3: Train Loss: 1.2310, Train Accuracy: 65.18%
#     Worker 4: Train Loss: 1.2278, Train Accuracy: 65.05%
#     Worker 5: Train Loss: 1.2337, Train Accuracy: 65.27%
#     Worker 6: Train Loss: 1.2275, Train Accuracy: 65.32%
#     Worker 7: Train Loss: 1.2363, Train Accuracy: 64.88%
# Total Computation Time: 3217.82 seconds
# Total Communication Time: 7.03 seconds
# Epoch 138/150: Test Loss: 1.9749, Test Accuracy: 50.44%
#     Worker 0: Train Loss: 1.2201, Train Accuracy: 65.35%
#     Worker 1: Train Loss: 1.2148, Train Accuracy: 64.72%
#     Worker 2: Train Loss: 1.2033, Train Accuracy: 65.87%
#     Worker 3: Train Loss: 1.2446, Train Accuracy: 65.44%
#     Worker 4: Train Loss: 1.2352, Train Accuracy: 64.86%
#     Worker 5: Train Loss: 1.2405, Train Accuracy: 64.38%
#     Worker 6: Train Loss: 1.2489, Train Accuracy: 64.94%
#     Worker 7: Train Loss: 1.2172, Train Accuracy: 66.04%
# Total Computation Time: 3241.08 seconds
# Total Communication Time: 7.09 seconds
# Epoch 139/150: Test Loss: 1.9748, Test Accuracy: 50.54%
#     Worker 0: Train Loss: 1.2536, Train Accuracy: 64.50%
#     Worker 1: Train Loss: 1.1859, Train Accuracy: 66.10%
#     Worker 2: Train Loss: 1.2086, Train Accuracy: 66.75%
#     Worker 3: Train Loss: 1.2353, Train Accuracy: 65.18%
#     Worker 4: Train Loss: 1.2334, Train Accuracy: 65.55%
#     Worker 5: Train Loss: 1.2499, Train Accuracy: 64.88%
#     Worker 6: Train Loss: 1.2476, Train Accuracy: 65.58%
#     Worker 7: Train Loss: 1.2432, Train Accuracy: 65.44%
# Total Computation Time: 3264.44 seconds
# Total Communication Time: 7.14 seconds
# Epoch 140/150: Test Loss: 1.9743, Test Accuracy: 50.49%
#     Worker 0: Train Loss: 1.2151, Train Accuracy: 65.26%
#     Worker 1: Train Loss: 1.2073, Train Accuracy: 65.84%
#     Worker 2: Train Loss: 1.2076, Train Accuracy: 66.10%
#     Worker 3: Train Loss: 1.2466, Train Accuracy: 64.39%
#     Worker 4: Train Loss: 1.2364, Train Accuracy: 64.97%
#     Worker 5: Train Loss: 1.2153, Train Accuracy: 65.62%
#     Worker 6: Train Loss: 1.2722, Train Accuracy: 63.91%
#     Worker 7: Train Loss: 1.2351, Train Accuracy: 65.73%
# Total Computation Time: 3287.83 seconds
# Total Communication Time: 7.19 seconds
# Epoch 141/150: Test Loss: 1.9739, Test Accuracy: 50.62%
#     Worker 0: Train Loss: 1.2280, Train Accuracy: 64.71%
#     Worker 1: Train Loss: 1.1973, Train Accuracy: 66.29%
#     Worker 2: Train Loss: 1.2176, Train Accuracy: 66.06%
#     Worker 3: Train Loss: 1.2379, Train Accuracy: 65.29%
#     Worker 4: Train Loss: 1.2392, Train Accuracy: 64.36%
#     Worker 5: Train Loss: 1.2308, Train Accuracy: 65.74%
#     Worker 6: Train Loss: 1.2426, Train Accuracy: 65.21%
#     Worker 7: Train Loss: 1.2328, Train Accuracy: 65.29%
# Total Computation Time: 3311.07 seconds
# Total Communication Time: 7.24 seconds
# Epoch 142/150: Test Loss: 1.9749, Test Accuracy: 50.43%
#     Worker 0: Train Loss: 1.2335, Train Accuracy: 64.39%
#     Worker 1: Train Loss: 1.2323, Train Accuracy: 64.77%
#     Worker 2: Train Loss: 1.2099, Train Accuracy: 65.99%
#     Worker 3: Train Loss: 1.2353, Train Accuracy: 64.88%
#     Worker 4: Train Loss: 1.2158, Train Accuracy: 65.29%
#     Worker 5: Train Loss: 1.2118, Train Accuracy: 65.80%
#     Worker 6: Train Loss: 1.2581, Train Accuracy: 64.21%
#     Worker 7: Train Loss: 1.2137, Train Accuracy: 65.96%
# Total Computation Time: 3334.35 seconds
# Total Communication Time: 7.29 seconds
# Epoch 143/150: Test Loss: 1.9739, Test Accuracy: 50.53%
#     Worker 0: Train Loss: 1.2402, Train Accuracy: 65.08%
#     Worker 1: Train Loss: 1.2097, Train Accuracy: 65.88%
#     Worker 2: Train Loss: 1.2345, Train Accuracy: 65.79%
#     Worker 3: Train Loss: 1.2542, Train Accuracy: 64.63%
#     Worker 4: Train Loss: 1.2246, Train Accuracy: 65.43%
#     Worker 5: Train Loss: 1.2271, Train Accuracy: 66.29%
#     Worker 6: Train Loss: 1.2347, Train Accuracy: 64.94%
#     Worker 7: Train Loss: 1.2117, Train Accuracy: 65.95%
# Total Computation Time: 3357.55 seconds
# Total Communication Time: 7.34 seconds
# Epoch 144/150: Test Loss: 1.9738, Test Accuracy: 50.56%
#     Worker 0: Train Loss: 1.2367, Train Accuracy: 65.07%
#     Worker 1: Train Loss: 1.2044, Train Accuracy: 65.43%
#     Worker 2: Train Loss: 1.2110, Train Accuracy: 65.73%
#     Worker 3: Train Loss: 1.2515, Train Accuracy: 65.33%
#     Worker 4: Train Loss: 1.2242, Train Accuracy: 65.40%
#     Worker 5: Train Loss: 1.2262, Train Accuracy: 65.24%
#     Worker 6: Train Loss: 1.2368, Train Accuracy: 65.43%
#     Worker 7: Train Loss: 1.2215, Train Accuracy: 65.04%
# Total Computation Time: 3380.56 seconds
# Total Communication Time: 7.39 seconds
# Epoch 145/150: Test Loss: 1.9742, Test Accuracy: 50.54%
#     Worker 0: Train Loss: 1.2280, Train Accuracy: 64.57%
#     Worker 1: Train Loss: 1.1977, Train Accuracy: 65.62%
#     Worker 2: Train Loss: 1.2079, Train Accuracy: 65.98%
#     Worker 3: Train Loss: 1.2341, Train Accuracy: 65.30%
#     Worker 4: Train Loss: 1.2219, Train Accuracy: 65.32%
#     Worker 5: Train Loss: 1.2149, Train Accuracy: 65.98%
#     Worker 6: Train Loss: 1.2363, Train Accuracy: 65.63%
#     Worker 7: Train Loss: 1.2111, Train Accuracy: 65.77%
# Total Computation Time: 3403.59 seconds
# Total Communication Time: 7.44 seconds
# Epoch 146/150: Test Loss: 1.9742, Test Accuracy: 50.53%
#     Worker 0: Train Loss: 1.2311, Train Accuracy: 65.04%
#     Worker 1: Train Loss: 1.2124, Train Accuracy: 64.82%
#     Worker 2: Train Loss: 1.2149, Train Accuracy: 65.74%
#     Worker 3: Train Loss: 1.2555, Train Accuracy: 64.46%
#     Worker 4: Train Loss: 1.2340, Train Accuracy: 64.88%
#     Worker 5: Train Loss: 1.2213, Train Accuracy: 65.65%
#     Worker 6: Train Loss: 1.2592, Train Accuracy: 64.57%
#     Worker 7: Train Loss: 1.2352, Train Accuracy: 65.30%
# Total Computation Time: 3427.24 seconds
# Total Communication Time: 7.49 seconds
# Epoch 147/150: Test Loss: 1.9741, Test Accuracy: 50.53%
#     Worker 0: Train Loss: 1.2259, Train Accuracy: 64.87%
#     Worker 1: Train Loss: 1.1985, Train Accuracy: 65.86%
#     Worker 2: Train Loss: 1.2254, Train Accuracy: 65.43%
#     Worker 3: Train Loss: 1.2290, Train Accuracy: 65.17%
#     Worker 4: Train Loss: 1.2094, Train Accuracy: 65.53%
#     Worker 5: Train Loss: 1.2379, Train Accuracy: 65.06%
#     Worker 6: Train Loss: 1.2598, Train Accuracy: 64.79%
#     Worker 7: Train Loss: 1.2355, Train Accuracy: 65.39%
# Total Computation Time: 3450.69 seconds
# Total Communication Time: 7.54 seconds
# Epoch 148/150: Test Loss: 1.9740, Test Accuracy: 50.57%
#     Worker 0: Train Loss: 1.2309, Train Accuracy: 65.18%
#     Worker 1: Train Loss: 1.2093, Train Accuracy: 65.71%
#     Worker 2: Train Loss: 1.2153, Train Accuracy: 65.68%
#     Worker 3: Train Loss: 1.2497, Train Accuracy: 64.83%
#     Worker 4: Train Loss: 1.2109, Train Accuracy: 65.85%
#     Worker 5: Train Loss: 1.2327, Train Accuracy: 65.16%
#     Worker 6: Train Loss: 1.2485, Train Accuracy: 64.77%
#     Worker 7: Train Loss: 1.2209, Train Accuracy: 65.40%
# Total Computation Time: 3474.44 seconds
# Total Communication Time: 7.59 seconds
# Epoch 149/150: Test Loss: 1.9740, Test Accuracy: 50.55%
#     Worker 0: Train Loss: 1.2325, Train Accuracy: 65.11%
#     Worker 1: Train Loss: 1.2207, Train Accuracy: 65.35%
#     Worker 2: Train Loss: 1.2154, Train Accuracy: 66.15%
#     Worker 3: Train Loss: 1.2390, Train Accuracy: 64.93%
#     Worker 4: Train Loss: 1.2357, Train Accuracy: 65.79%
#     Worker 5: Train Loss: 1.2056, Train Accuracy: 65.85%
#     Worker 6: Train Loss: 1.2572, Train Accuracy: 64.86%
#     Worker 7: Train Loss: 1.2239, Train Accuracy: 65.91%
# Total Computation Time: 3498.06 seconds
# Total Communication Time: 7.65 seconds
# Epoch 150/150: Test Loss: 1.9740, Test Accuracy: 50.55%
#     Worker 0: Train Loss: 1.2363, Train Accuracy: 65.21%
#     Worker 1: Train Loss: 1.1883, Train Accuracy: 65.76%
#     Worker 2: Train Loss: 1.1957, Train Accuracy: 65.96%
#     Worker 3: Train Loss: 1.2275, Train Accuracy: 65.18%
#     Worker 4: Train Loss: 1.2103, Train Accuracy: 65.15%
#     Worker 5: Train Loss: 1.2178, Train Accuracy: 65.63%
#     Worker 6: Train Loss: 1.2485, Train Accuracy: 64.88%
#     Worker 7: Train Loss: 1.2285, Train Accuracy: 65.26%
# Total Computation Time: 3521.66 seconds
# Total Communication Time: 7.70 seconds
