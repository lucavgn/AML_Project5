# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files
import time

total_computation_time = 0
total_communication_time = 0

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
#warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")

    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch):
        computation_start_time = time.time()
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            # Perform J local step before synchronization
            for j in range(J):
                try:
                    # Get a batch from the current worker's shard using next()
                    images, labels = next(shard_iterators[k])
                    images, labels = images.to(device), labels.to(device)  # Move to device
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

                except StopIteration:
                    # If the iterator has exhausted the data, restart the iterator
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k]) # Resume from the next batch
                    images, labels = images.to(device), labels.to(device)
                    # Perform optimization step
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        computation_end_time = time.time()
        total_computation_time += (computation_end_time - computation_start_time)

        communication_start_time = time.time()
        # Perform model synchronization
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            # Update each worker model with the global parameters
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

        communication_end_time = time.time()
        total_communication_time += (communication_end_time - communication_start_time)

    # Update lr for each scheduler
    for scheduler in schedulers:
       # if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
       # else:
        #    warmup_factor = (epoch + 1) / warmup_epochs
          #  lr = warmup_factor * learning_rate
          #  for optimizer in optimizers:
           #     for param_group in optimizer.param_groups:
            #        param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

    print(f"Total Computation Time: {total_computation_time:.2f} seconds")
    print(f"Total Communication Time: {total_communication_time:.2f} seconds")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 8 --j 64
# Out:
# Training with K=8, J=64
# Global iteration per epoch: 2
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:13<00:00, 12.9MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00800
# Epoch 1/150: Test Loss: 4.5476, Test Accuracy: 2.84%
#     Worker 0: Train Loss: 4.5941, Train Accuracy: 1.57%
#     Worker 1: Train Loss: 4.5935, Train Accuracy: 1.36%
#     Worker 2: Train Loss: 4.5949, Train Accuracy: 1.37%
#     Worker 3: Train Loss: 4.5926, Train Accuracy: 1.16%
#     Worker 4: Train Loss: 4.5926, Train Accuracy: 1.19%
#     Worker 5: Train Loss: 4.5879, Train Accuracy: 1.64%
#     Worker 6: Train Loss: 4.5953, Train Accuracy: 1.59%
#     Worker 7: Train Loss: 4.5903, Train Accuracy: 1.18%
# Total Computation Time: 34.27 seconds
# Total Communication Time: 0.04 seconds
# Epoch 2/150: Test Loss: 4.1606, Test Accuracy: 6.32%
#     Worker 0: Train Loss: 4.3907, Train Accuracy: 3.87%
#     Worker 1: Train Loss: 4.3902, Train Accuracy: 3.49%
#     Worker 2: Train Loss: 4.3765, Train Accuracy: 3.82%
#     Worker 3: Train Loss: 4.3884, Train Accuracy: 3.86%
#     Worker 4: Train Loss: 4.3703, Train Accuracy: 4.30%
#     Worker 5: Train Loss: 4.3665, Train Accuracy: 3.62%
#     Worker 6: Train Loss: 4.3910, Train Accuracy: 3.40%
#     Worker 7: Train Loss: 4.3795, Train Accuracy: 3.46%
# Total Computation Time: 67.19 seconds
# Total Communication Time: 0.05 seconds
# Epoch 3/150: Test Loss: 3.9867, Test Accuracy: 8.72%
#     Worker 0: Train Loss: 4.1423, Train Accuracy: 6.39%
#     Worker 1: Train Loss: 4.1536, Train Accuracy: 6.16%
#     Worker 2: Train Loss: 4.1582, Train Accuracy: 5.79%
#     Worker 3: Train Loss: 4.1596, Train Accuracy: 5.47%
#     Worker 4: Train Loss: 4.1131, Train Accuracy: 6.78%
#     Worker 5: Train Loss: 4.1252, Train Accuracy: 6.14%
#     Worker 6: Train Loss: 4.1574, Train Accuracy: 5.58%
#     Worker 7: Train Loss: 4.1488, Train Accuracy: 6.25%
# Total Computation Time: 100.77 seconds
# Total Communication Time: 0.05 seconds
# Epoch 4/150: Test Loss: 3.8407, Test Accuracy: 11.23%
#     Worker 0: Train Loss: 4.0184, Train Accuracy: 7.94%
#     Worker 1: Train Loss: 4.0344, Train Accuracy: 7.19%
#     Worker 2: Train Loss: 4.0176, Train Accuracy: 8.32%
#     Worker 3: Train Loss: 4.0288, Train Accuracy: 8.01%
#     Worker 4: Train Loss: 3.9901, Train Accuracy: 7.87%
#     Worker 5: Train Loss: 3.9820, Train Accuracy: 8.36%
#     Worker 6: Train Loss: 4.0096, Train Accuracy: 7.81%
#     Worker 7: Train Loss: 4.0202, Train Accuracy: 7.85%
# Total Computation Time: 133.84 seconds
# Total Communication Time: 0.05 seconds
# Epoch 5/150: Test Loss: 3.7196, Test Accuracy: 13.69%
#     Worker 0: Train Loss: 3.9157, Train Accuracy: 9.20%
#     Worker 1: Train Loss: 3.9026, Train Accuracy: 9.33%
#     Worker 2: Train Loss: 3.9104, Train Accuracy: 9.73%
#     Worker 3: Train Loss: 3.9231, Train Accuracy: 9.82%
#     Worker 4: Train Loss: 3.8627, Train Accuracy: 10.24%
#     Worker 5: Train Loss: 3.8730, Train Accuracy: 10.53%
#     Worker 6: Train Loss: 3.9171, Train Accuracy: 9.53%
#     Worker 7: Train Loss: 3.9068, Train Accuracy: 9.57%
# Total Computation Time: 166.78 seconds
# Total Communication Time: 0.06 seconds
# Epoch 6/150: Test Loss: 3.6170, Test Accuracy: 15.25%
#     Worker 0: Train Loss: 3.8003, Train Accuracy: 11.22%
#     Worker 1: Train Loss: 3.8099, Train Accuracy: 10.64%
#     Worker 2: Train Loss: 3.7710, Train Accuracy: 11.88%
#     Worker 3: Train Loss: 3.8217, Train Accuracy: 11.40%
#     Worker 4: Train Loss: 3.7716, Train Accuracy: 11.57%
#     Worker 5: Train Loss: 3.7538, Train Accuracy: 12.31%
#     Worker 6: Train Loss: 3.8022, Train Accuracy: 11.48%
#     Worker 7: Train Loss: 3.8008, Train Accuracy: 10.92%
# Total Computation Time: 200.14 seconds
# Total Communication Time: 0.06 seconds
# Epoch 7/150: Test Loss: 3.5118, Test Accuracy: 16.87%
#     Worker 0: Train Loss: 3.6956, Train Accuracy: 12.74%
#     Worker 1: Train Loss: 3.7018, Train Accuracy: 12.58%
#     Worker 2: Train Loss: 3.6891, Train Accuracy: 13.18%
#     Worker 3: Train Loss: 3.7349, Train Accuracy: 12.42%
#     Worker 4: Train Loss: 3.6638, Train Accuracy: 13.41%
#     Worker 5: Train Loss: 3.6649, Train Accuracy: 13.64%
#     Worker 6: Train Loss: 3.7222, Train Accuracy: 12.37%
#     Worker 7: Train Loss: 3.7251, Train Accuracy: 12.86%
# Total Computation Time: 233.61 seconds
# Total Communication Time: 0.07 seconds
# Epoch 8/150: Test Loss: 3.4412, Test Accuracy: 18.11%
#     Worker 0: Train Loss: 3.6329, Train Accuracy: 13.39%
#     Worker 1: Train Loss: 3.6358, Train Accuracy: 13.62%
#     Worker 2: Train Loss: 3.6203, Train Accuracy: 14.26%
#     Worker 3: Train Loss: 3.6813, Train Accuracy: 12.96%
#     Worker 4: Train Loss: 3.5728, Train Accuracy: 15.07%
#     Worker 5: Train Loss: 3.5851, Train Accuracy: 15.17%
#     Worker 6: Train Loss: 3.6514, Train Accuracy: 13.21%
#     Worker 7: Train Loss: 3.6344, Train Accuracy: 14.01%
# Total Computation Time: 267.03 seconds
# Total Communication Time: 0.07 seconds
# Epoch 9/150: Test Loss: 3.3669, Test Accuracy: 19.87%
#     Worker 0: Train Loss: 3.5602, Train Accuracy: 15.29%
#     Worker 1: Train Loss: 3.5623, Train Accuracy: 14.60%
#     Worker 2: Train Loss: 3.5579, Train Accuracy: 15.04%
#     Worker 3: Train Loss: 3.5908, Train Accuracy: 14.57%
#     Worker 4: Train Loss: 3.5412, Train Accuracy: 15.42%
#     Worker 5: Train Loss: 3.5403, Train Accuracy: 15.48%
#     Worker 6: Train Loss: 3.5949, Train Accuracy: 14.44%
#     Worker 7: Train Loss: 3.5647, Train Accuracy: 14.93%
# Total Computation Time: 300.42 seconds
# Total Communication Time: 0.08 seconds
# Epoch 10/150: Test Loss: 3.2845, Test Accuracy: 21.52%
#     Worker 0: Train Loss: 3.4979, Train Accuracy: 15.70%
#     Worker 1: Train Loss: 3.4751, Train Accuracy: 16.48%
#     Worker 2: Train Loss: 3.4723, Train Accuracy: 16.85%
#     Worker 3: Train Loss: 3.5199, Train Accuracy: 16.16%
#     Worker 4: Train Loss: 3.4403, Train Accuracy: 16.81%
#     Worker 5: Train Loss: 3.4138, Train Accuracy: 17.98%
#     Worker 6: Train Loss: 3.4714, Train Accuracy: 16.36%
#     Worker 7: Train Loss: 3.4871, Train Accuracy: 16.37%
# Total Computation Time: 333.82 seconds
# Total Communication Time: 0.08 seconds
# Epoch 11/150: Test Loss: 3.2087, Test Accuracy: 22.57%
#     Worker 0: Train Loss: 3.4149, Train Accuracy: 17.37%
#     Worker 1: Train Loss: 3.4056, Train Accuracy: 17.77%
#     Worker 2: Train Loss: 3.3944, Train Accuracy: 17.83%
#     Worker 3: Train Loss: 3.4421, Train Accuracy: 17.31%
#     Worker 4: Train Loss: 3.3791, Train Accuracy: 18.04%
#     Worker 5: Train Loss: 3.3755, Train Accuracy: 18.38%
#     Worker 6: Train Loss: 3.4416, Train Accuracy: 17.07%
#     Worker 7: Train Loss: 3.4041, Train Accuracy: 18.05%
# Total Computation Time: 366.98 seconds
# Total Communication Time: 0.08 seconds
# Epoch 12/150: Test Loss: 3.1578, Test Accuracy: 23.65%
#     Worker 0: Train Loss: 3.3773, Train Accuracy: 18.21%
#     Worker 1: Train Loss: 3.3573, Train Accuracy: 18.10%
#     Worker 2: Train Loss: 3.3699, Train Accuracy: 19.09%
#     Worker 3: Train Loss: 3.4164, Train Accuracy: 17.74%
#     Worker 4: Train Loss: 3.3448, Train Accuracy: 18.82%
#     Worker 5: Train Loss: 3.3223, Train Accuracy: 18.96%
#     Worker 6: Train Loss: 3.3600, Train Accuracy: 18.76%
#     Worker 7: Train Loss: 3.3779, Train Accuracy: 18.85%
# Total Computation Time: 399.58 seconds
# Total Communication Time: 0.09 seconds
# Epoch 13/150: Test Loss: 3.1007, Test Accuracy: 24.54%
#     Worker 0: Train Loss: 3.3116, Train Accuracy: 18.87%
#     Worker 1: Train Loss: 3.3048, Train Accuracy: 19.56%
#     Worker 2: Train Loss: 3.3057, Train Accuracy: 19.50%
#     Worker 3: Train Loss: 3.3464, Train Accuracy: 19.07%
#     Worker 4: Train Loss: 3.2639, Train Accuracy: 20.54%
#     Worker 5: Train Loss: 3.2535, Train Accuracy: 20.61%
#     Worker 6: Train Loss: 3.3249, Train Accuracy: 18.92%
#     Worker 7: Train Loss: 3.3082, Train Accuracy: 19.14%
# Total Computation Time: 431.90 seconds
# Total Communication Time: 0.09 seconds
# Epoch 14/150: Test Loss: 3.0393, Test Accuracy: 25.71%
#     Worker 0: Train Loss: 3.2411, Train Accuracy: 20.88%
#     Worker 1: Train Loss: 3.2349, Train Accuracy: 20.43%
#     Worker 2: Train Loss: 3.2256, Train Accuracy: 21.76%
#     Worker 3: Train Loss: 3.2824, Train Accuracy: 19.64%
#     Worker 4: Train Loss: 3.1971, Train Accuracy: 21.85%
#     Worker 5: Train Loss: 3.1964, Train Accuracy: 21.81%
#     Worker 6: Train Loss: 3.2610, Train Accuracy: 20.12%
#     Worker 7: Train Loss: 3.2359, Train Accuracy: 20.72%
# Total Computation Time: 464.51 seconds
# Total Communication Time: 0.10 seconds
# Epoch 15/150: Test Loss: 2.9825, Test Accuracy: 26.98%
#     Worker 0: Train Loss: 3.1956, Train Accuracy: 21.31%
#     Worker 1: Train Loss: 3.1908, Train Accuracy: 21.43%
#     Worker 2: Train Loss: 3.1912, Train Accuracy: 21.92%
#     Worker 3: Train Loss: 3.2229, Train Accuracy: 21.27%
#     Worker 4: Train Loss: 3.1708, Train Accuracy: 22.35%
#     Worker 5: Train Loss: 3.1460, Train Accuracy: 22.20%
#     Worker 6: Train Loss: 3.2097, Train Accuracy: 21.26%
#     Worker 7: Train Loss: 3.1912, Train Accuracy: 21.69%
# Total Computation Time: 497.48 seconds
# Total Communication Time: 0.10 seconds
# Epoch 16/150: Test Loss: 2.9238, Test Accuracy: 28.08%
#     Worker 0: Train Loss: 3.1492, Train Accuracy: 22.25%
#     Worker 1: Train Loss: 3.0994, Train Accuracy: 23.05%
#     Worker 2: Train Loss: 3.1573, Train Accuracy: 22.07%
#     Worker 3: Train Loss: 3.1567, Train Accuracy: 22.13%
#     Worker 4: Train Loss: 3.1088, Train Accuracy: 23.48%
#     Worker 5: Train Loss: 3.1130, Train Accuracy: 23.49%
#     Worker 6: Train Loss: 3.1523, Train Accuracy: 22.44%
#     Worker 7: Train Loss: 3.1226, Train Accuracy: 23.46%
# Total Computation Time: 530.62 seconds
# Total Communication Time: 0.11 seconds
# Epoch 17/150: Test Loss: 2.8700, Test Accuracy: 29.07%
#     Worker 0: Train Loss: 3.0782, Train Accuracy: 23.61%
#     Worker 1: Train Loss: 3.0739, Train Accuracy: 23.45%
#     Worker 2: Train Loss: 3.0924, Train Accuracy: 23.59%
#     Worker 3: Train Loss: 3.1024, Train Accuracy: 23.37%
#     Worker 4: Train Loss: 3.0574, Train Accuracy: 23.69%
#     Worker 5: Train Loss: 3.0445, Train Accuracy: 24.96%
#     Worker 6: Train Loss: 3.1396, Train Accuracy: 22.24%
#     Worker 7: Train Loss: 3.0771, Train Accuracy: 23.50%
# Total Computation Time: 564.09 seconds
# Total Communication Time: 0.11 seconds
# Epoch 18/150: Test Loss: 2.8405, Test Accuracy: 29.74%
#     Worker 0: Train Loss: 3.0515, Train Accuracy: 24.00%
#     Worker 1: Train Loss: 3.0612, Train Accuracy: 23.60%
#     Worker 2: Train Loss: 3.0165, Train Accuracy: 25.46%
#     Worker 3: Train Loss: 3.0852, Train Accuracy: 23.57%
#     Worker 4: Train Loss: 3.0304, Train Accuracy: 25.24%
#     Worker 5: Train Loss: 2.9855, Train Accuracy: 25.72%
#     Worker 6: Train Loss: 3.0633, Train Accuracy: 23.83%
#     Worker 7: Train Loss: 3.0484, Train Accuracy: 24.88%
# Total Computation Time: 596.90 seconds
# Total Communication Time: 0.12 seconds
# Epoch 19/150: Test Loss: 2.7913, Test Accuracy: 30.62%
#     Worker 0: Train Loss: 3.0109, Train Accuracy: 24.79%
#     Worker 1: Train Loss: 2.9587, Train Accuracy: 26.36%
#     Worker 2: Train Loss: 3.0147, Train Accuracy: 25.07%
#     Worker 3: Train Loss: 3.0358, Train Accuracy: 24.33%
#     Worker 4: Train Loss: 2.9748, Train Accuracy: 25.47%
#     Worker 5: Train Loss: 2.9757, Train Accuracy: 25.97%
#     Worker 6: Train Loss: 3.0353, Train Accuracy: 25.03%
#     Worker 7: Train Loss: 2.9778, Train Accuracy: 25.41%
# Total Computation Time: 629.32 seconds
# Total Communication Time: 0.12 seconds
# Epoch 20/150: Test Loss: 2.7381, Test Accuracy: 31.43%
#     Worker 0: Train Loss: 2.9637, Train Accuracy: 25.72%
#     Worker 1: Train Loss: 2.9234, Train Accuracy: 26.76%
#     Worker 2: Train Loss: 2.9398, Train Accuracy: 26.28%
#     Worker 3: Train Loss: 2.9723, Train Accuracy: 26.18%
#     Worker 4: Train Loss: 2.9045, Train Accuracy: 27.80%
#     Worker 5: Train Loss: 2.9345, Train Accuracy: 26.82%
#     Worker 6: Train Loss: 2.9530, Train Accuracy: 25.36%
#     Worker 7: Train Loss: 2.9365, Train Accuracy: 26.67%
# Total Computation Time: 662.65 seconds
# Total Communication Time: 0.12 seconds
# Epoch 21/150: Test Loss: 2.7082, Test Accuracy: 31.80%
#     Worker 0: Train Loss: 2.9100, Train Accuracy: 27.25%
#     Worker 1: Train Loss: 2.9015, Train Accuracy: 26.81%
#     Worker 2: Train Loss: 2.9178, Train Accuracy: 27.36%
#     Worker 3: Train Loss: 2.9368, Train Accuracy: 26.07%
#     Worker 4: Train Loss: 2.8844, Train Accuracy: 26.95%
#     Worker 5: Train Loss: 2.9025, Train Accuracy: 26.76%
#     Worker 6: Train Loss: 2.9429, Train Accuracy: 25.89%
#     Worker 7: Train Loss: 2.9001, Train Accuracy: 27.23%
# Total Computation Time: 696.24 seconds
# Total Communication Time: 0.13 seconds
# Epoch 22/150: Test Loss: 2.6486, Test Accuracy: 33.09%
#     Worker 0: Train Loss: 2.8832, Train Accuracy: 27.83%
#     Worker 1: Train Loss: 2.8212, Train Accuracy: 28.60%
#     Worker 2: Train Loss: 2.8551, Train Accuracy: 28.32%
#     Worker 3: Train Loss: 2.8769, Train Accuracy: 27.55%
#     Worker 4: Train Loss: 2.8292, Train Accuracy: 28.13%
#     Worker 5: Train Loss: 2.8083, Train Accuracy: 29.85%
#     Worker 6: Train Loss: 2.8905, Train Accuracy: 26.93%
#     Worker 7: Train Loss: 2.8669, Train Accuracy: 27.44%
# Total Computation Time: 729.26 seconds
# Total Communication Time: 0.13 seconds
# Epoch 23/150: Test Loss: 2.6113, Test Accuracy: 34.07%
#     Worker 0: Train Loss: 2.8147, Train Accuracy: 28.74%
#     Worker 1: Train Loss: 2.7819, Train Accuracy: 29.28%
#     Worker 2: Train Loss: 2.8160, Train Accuracy: 29.58%
#     Worker 3: Train Loss: 2.8327, Train Accuracy: 28.68%
#     Worker 4: Train Loss: 2.7801, Train Accuracy: 28.98%
#     Worker 5: Train Loss: 2.7761, Train Accuracy: 30.07%
#     Worker 6: Train Loss: 2.8289, Train Accuracy: 28.61%
#     Worker 7: Train Loss: 2.8106, Train Accuracy: 29.14%
# Total Computation Time: 762.00 seconds
# Total Communication Time: 0.14 seconds
# Epoch 24/150: Test Loss: 2.5677, Test Accuracy: 34.52%
#     Worker 0: Train Loss: 2.7752, Train Accuracy: 29.41%
#     Worker 1: Train Loss: 2.7479, Train Accuracy: 30.12%
#     Worker 2: Train Loss: 2.7822, Train Accuracy: 29.67%
#     Worker 3: Train Loss: 2.7973, Train Accuracy: 28.81%
#     Worker 4: Train Loss: 2.7440, Train Accuracy: 29.74%
#     Worker 5: Train Loss: 2.7693, Train Accuracy: 30.24%
#     Worker 6: Train Loss: 2.7786, Train Accuracy: 29.52%
#     Worker 7: Train Loss: 2.7886, Train Accuracy: 29.55%
# Total Computation Time: 794.68 seconds
# Total Communication Time: 0.14 seconds
# Epoch 25/150: Test Loss: 2.5614, Test Accuracy: 34.71%
#     Worker 0: Train Loss: 2.7729, Train Accuracy: 29.74%
#     Worker 1: Train Loss: 2.7412, Train Accuracy: 29.34%
#     Worker 2: Train Loss: 2.7931, Train Accuracy: 29.57%
#     Worker 3: Train Loss: 2.7735, Train Accuracy: 29.41%
#     Worker 4: Train Loss: 2.7126, Train Accuracy: 29.90%
#     Worker 5: Train Loss: 2.7292, Train Accuracy: 30.91%
#     Worker 6: Train Loss: 2.7669, Train Accuracy: 29.53%
#     Worker 7: Train Loss: 2.7673, Train Accuracy: 29.82%
# Total Computation Time: 826.86 seconds
# Total Communication Time: 0.15 seconds
# Epoch 26/150: Test Loss: 2.5233, Test Accuracy: 35.81%
#     Worker 0: Train Loss: 2.7337, Train Accuracy: 30.66%
#     Worker 1: Train Loss: 2.6938, Train Accuracy: 30.65%
#     Worker 2: Train Loss: 2.7282, Train Accuracy: 31.03%
#     Worker 3: Train Loss: 2.7401, Train Accuracy: 30.54%
#     Worker 4: Train Loss: 2.6554, Train Accuracy: 31.62%
#     Worker 5: Train Loss: 2.6752, Train Accuracy: 32.36%
#     Worker 6: Train Loss: 2.7225, Train Accuracy: 30.73%
#     Worker 7: Train Loss: 2.7188, Train Accuracy: 30.64%
# Total Computation Time: 859.17 seconds
# Total Communication Time: 0.15 seconds
# Epoch 27/150: Test Loss: 2.4780, Test Accuracy: 37.15%
#     Worker 0: Train Loss: 2.6902, Train Accuracy: 31.43%
#     Worker 1: Train Loss: 2.6479, Train Accuracy: 31.76%
#     Worker 2: Train Loss: 2.6802, Train Accuracy: 32.04%
#     Worker 3: Train Loss: 2.6998, Train Accuracy: 30.76%
#     Worker 4: Train Loss: 2.6025, Train Accuracy: 33.30%
#     Worker 5: Train Loss: 2.6264, Train Accuracy: 32.98%
#     Worker 6: Train Loss: 2.6906, Train Accuracy: 31.44%
#     Worker 7: Train Loss: 2.6597, Train Accuracy: 31.92%
# Total Computation Time: 892.00 seconds
# Total Communication Time: 0.15 seconds
# Epoch 28/150: Test Loss: 2.4593, Test Accuracy: 37.38%
#     Worker 0: Train Loss: 2.6582, Train Accuracy: 32.77%
#     Worker 1: Train Loss: 2.6299, Train Accuracy: 32.03%
#     Worker 2: Train Loss: 2.6583, Train Accuracy: 32.12%
#     Worker 3: Train Loss: 2.6894, Train Accuracy: 31.81%
#     Worker 4: Train Loss: 2.6039, Train Accuracy: 33.34%
#     Worker 5: Train Loss: 2.6254, Train Accuracy: 33.02%
#     Worker 6: Train Loss: 2.6630, Train Accuracy: 31.77%
#     Worker 7: Train Loss: 2.6449, Train Accuracy: 32.14%
# Total Computation Time: 925.18 seconds
# Total Communication Time: 0.16 seconds
# Epoch 29/150: Test Loss: 2.4485, Test Accuracy: 37.51%
#     Worker 0: Train Loss: 2.6371, Train Accuracy: 32.07%
#     Worker 1: Train Loss: 2.5645, Train Accuracy: 33.93%
#     Worker 2: Train Loss: 2.5961, Train Accuracy: 33.18%
#     Worker 3: Train Loss: 2.6454, Train Accuracy: 32.42%
#     Worker 4: Train Loss: 2.5812, Train Accuracy: 33.23%
#     Worker 5: Train Loss: 2.6053, Train Accuracy: 33.41%
#     Worker 6: Train Loss: 2.6260, Train Accuracy: 32.56%
#     Worker 7: Train Loss: 2.6130, Train Accuracy: 33.11%
# Total Computation Time: 958.09 seconds
# Total Communication Time: 0.16 seconds
# Epoch 30/150: Test Loss: 2.3978, Test Accuracy: 38.72%
#     Worker 0: Train Loss: 2.5793, Train Accuracy: 33.41%
#     Worker 1: Train Loss: 2.5632, Train Accuracy: 33.24%
#     Worker 2: Train Loss: 2.5908, Train Accuracy: 33.19%
#     Worker 3: Train Loss: 2.6008, Train Accuracy: 32.35%
#     Worker 4: Train Loss: 2.5083, Train Accuracy: 34.76%
#     Worker 5: Train Loss: 2.5582, Train Accuracy: 34.98%
#     Worker 6: Train Loss: 2.5886, Train Accuracy: 32.83%
#     Worker 7: Train Loss: 2.5673, Train Accuracy: 33.78%
# Total Computation Time: 990.74 seconds
# Total Communication Time: 0.17 seconds
# Epoch 31/150: Test Loss: 2.3755, Test Accuracy: 39.24%
#     Worker 0: Train Loss: 2.5794, Train Accuracy: 34.22%
#     Worker 1: Train Loss: 2.5346, Train Accuracy: 34.43%
#     Worker 2: Train Loss: 2.5343, Train Accuracy: 34.99%
#     Worker 3: Train Loss: 2.5780, Train Accuracy: 33.38%
#     Worker 4: Train Loss: 2.5139, Train Accuracy: 34.54%
#     Worker 5: Train Loss: 2.5401, Train Accuracy: 35.56%
#     Worker 6: Train Loss: 2.5615, Train Accuracy: 34.01%
#     Worker 7: Train Loss: 2.5300, Train Accuracy: 34.43%
# Total Computation Time: 1023.39 seconds
# Total Communication Time: 0.17 seconds
# Epoch 32/150: Test Loss: 2.3506, Test Accuracy: 39.68%
#     Worker 0: Train Loss: 2.5530, Train Accuracy: 33.94%
#     Worker 1: Train Loss: 2.5394, Train Accuracy: 34.32%
#     Worker 2: Train Loss: 2.5449, Train Accuracy: 34.64%
#     Worker 3: Train Loss: 2.5464, Train Accuracy: 34.25%
#     Worker 4: Train Loss: 2.5008, Train Accuracy: 35.63%
#     Worker 5: Train Loss: 2.5258, Train Accuracy: 35.63%
#     Worker 6: Train Loss: 2.5445, Train Accuracy: 34.09%
#     Worker 7: Train Loss: 2.5639, Train Accuracy: 33.38%
# Total Computation Time: 1055.76 seconds
# Total Communication Time: 0.18 seconds
# Epoch 33/150: Test Loss: 2.3405, Test Accuracy: 39.42%
#     Worker 0: Train Loss: 2.5170, Train Accuracy: 34.67%
#     Worker 1: Train Loss: 2.4662, Train Accuracy: 36.00%
#     Worker 2: Train Loss: 2.5002, Train Accuracy: 35.92%
#     Worker 3: Train Loss: 2.4894, Train Accuracy: 34.56%
#     Worker 4: Train Loss: 2.4296, Train Accuracy: 36.16%
#     Worker 5: Train Loss: 2.4764, Train Accuracy: 36.35%
#     Worker 6: Train Loss: 2.5081, Train Accuracy: 35.30%
#     Worker 7: Train Loss: 2.4809, Train Accuracy: 36.21%
# Total Computation Time: 1089.03 seconds
# Total Communication Time: 0.18 seconds
# Epoch 34/150: Test Loss: 2.3201, Test Accuracy: 40.26%
#     Worker 0: Train Loss: 2.4963, Train Accuracy: 34.90%
#     Worker 1: Train Loss: 2.4463, Train Accuracy: 36.14%
#     Worker 2: Train Loss: 2.4839, Train Accuracy: 36.05%
#     Worker 3: Train Loss: 2.4904, Train Accuracy: 34.96%
#     Worker 4: Train Loss: 2.4465, Train Accuracy: 36.00%
#     Worker 5: Train Loss: 2.4518, Train Accuracy: 36.62%
#     Worker 6: Train Loss: 2.5201, Train Accuracy: 34.94%
#     Worker 7: Train Loss: 2.5001, Train Accuracy: 35.21%
# Total Computation Time: 1122.22 seconds
# Total Communication Time: 0.18 seconds
# Epoch 35/150: Test Loss: 2.3300, Test Accuracy: 39.94%
#     Worker 0: Train Loss: 2.4827, Train Accuracy: 35.81%
#     Worker 1: Train Loss: 2.4356, Train Accuracy: 35.96%
#     Worker 2: Train Loss: 2.4580, Train Accuracy: 36.59%
#     Worker 3: Train Loss: 2.4692, Train Accuracy: 35.99%
#     Worker 4: Train Loss: 2.4315, Train Accuracy: 36.51%
#     Worker 5: Train Loss: 2.4423, Train Accuracy: 36.87%
#     Worker 6: Train Loss: 2.4585, Train Accuracy: 36.13%
#     Worker 7: Train Loss: 2.4386, Train Accuracy: 36.52%
# Total Computation Time: 1155.40 seconds
# Total Communication Time: 0.19 seconds
# Epoch 36/150: Test Loss: 2.2880, Test Accuracy: 41.20%
#     Worker 0: Train Loss: 2.4534, Train Accuracy: 36.83%
#     Worker 1: Train Loss: 2.3893, Train Accuracy: 37.43%
#     Worker 2: Train Loss: 2.4041, Train Accuracy: 37.60%
#     Worker 3: Train Loss: 2.4433, Train Accuracy: 36.38%
#     Worker 4: Train Loss: 2.4036, Train Accuracy: 37.10%
#     Worker 5: Train Loss: 2.4174, Train Accuracy: 37.89%
#     Worker 6: Train Loss: 2.4448, Train Accuracy: 36.77%
#     Worker 7: Train Loss: 2.4394, Train Accuracy: 36.77%
# Total Computation Time: 1188.52 seconds
# Total Communication Time: 0.19 seconds
# Epoch 37/150: Test Loss: 2.2780, Test Accuracy: 40.62%
#     Worker 0: Train Loss: 2.3894, Train Accuracy: 37.70%
#     Worker 1: Train Loss: 2.3692, Train Accuracy: 37.18%
#     Worker 2: Train Loss: 2.3901, Train Accuracy: 37.45%
#     Worker 3: Train Loss: 2.4146, Train Accuracy: 36.84%
#     Worker 4: Train Loss: 2.3542, Train Accuracy: 38.37%
#     Worker 5: Train Loss: 2.3851, Train Accuracy: 38.23%
#     Worker 6: Train Loss: 2.4072, Train Accuracy: 37.44%
#     Worker 7: Train Loss: 2.3901, Train Accuracy: 37.37%
# Total Computation Time: 1221.93 seconds
# Total Communication Time: 0.20 seconds
# Epoch 38/150: Test Loss: 2.2555, Test Accuracy: 41.24%
#     Worker 0: Train Loss: 2.3990, Train Accuracy: 37.06%
#     Worker 1: Train Loss: 2.3751, Train Accuracy: 38.14%
#     Worker 2: Train Loss: 2.4072, Train Accuracy: 37.55%
#     Worker 3: Train Loss: 2.4231, Train Accuracy: 36.66%
#     Worker 4: Train Loss: 2.3521, Train Accuracy: 37.59%
#     Worker 5: Train Loss: 2.3890, Train Accuracy: 37.31%
#     Worker 6: Train Loss: 2.4203, Train Accuracy: 36.89%
#     Worker 7: Train Loss: 2.3918, Train Accuracy: 37.63%
# Total Computation Time: 1254.76 seconds
# Total Communication Time: 0.20 seconds
# Epoch 39/150: Test Loss: 2.2420, Test Accuracy: 41.98%
#     Worker 0: Train Loss: 2.3620, Train Accuracy: 37.61%
#     Worker 1: Train Loss: 2.3125, Train Accuracy: 38.52%
#     Worker 2: Train Loss: 2.3435, Train Accuracy: 38.80%
#     Worker 3: Train Loss: 2.3948, Train Accuracy: 37.67%
#     Worker 4: Train Loss: 2.3095, Train Accuracy: 39.12%
#     Worker 5: Train Loss: 2.3636, Train Accuracy: 38.26%
#     Worker 6: Train Loss: 2.3513, Train Accuracy: 38.30%
#     Worker 7: Train Loss: 2.3742, Train Accuracy: 37.34%
# Total Computation Time: 1287.40 seconds
# Total Communication Time: 0.21 seconds
# Epoch 40/150: Test Loss: 2.2177, Test Accuracy: 42.45%
#     Worker 0: Train Loss: 2.3199, Train Accuracy: 38.77%
#     Worker 1: Train Loss: 2.2933, Train Accuracy: 39.53%
#     Worker 2: Train Loss: 2.3081, Train Accuracy: 39.57%
#     Worker 3: Train Loss: 2.3277, Train Accuracy: 39.49%
#     Worker 4: Train Loss: 2.2815, Train Accuracy: 39.45%
#     Worker 5: Train Loss: 2.3195, Train Accuracy: 39.06%
#     Worker 6: Train Loss: 2.3294, Train Accuracy: 38.93%
#     Worker 7: Train Loss: 2.3192, Train Accuracy: 38.27%
# Total Computation Time: 1320.32 seconds
# Total Communication Time: 0.21 seconds
# Epoch 41/150: Test Loss: 2.2081, Test Accuracy: 42.48%
#     Worker 0: Train Loss: 2.3200, Train Accuracy: 39.24%
#     Worker 1: Train Loss: 2.2985, Train Accuracy: 39.34%
#     Worker 2: Train Loss: 2.3224, Train Accuracy: 39.89%
#     Worker 3: Train Loss: 2.3605, Train Accuracy: 38.08%
#     Worker 4: Train Loss: 2.2679, Train Accuracy: 40.22%
#     Worker 5: Train Loss: 2.3212, Train Accuracy: 39.18%
#     Worker 6: Train Loss: 2.3641, Train Accuracy: 38.46%
#     Worker 7: Train Loss: 2.2791, Train Accuracy: 39.53%
# Total Computation Time: 1353.20 seconds
# Total Communication Time: 0.22 seconds
# Epoch 42/150: Test Loss: 2.2140, Test Accuracy: 42.59%
#     Worker 0: Train Loss: 2.3234, Train Accuracy: 39.17%
#     Worker 1: Train Loss: 2.2595, Train Accuracy: 39.95%
#     Worker 2: Train Loss: 2.2905, Train Accuracy: 40.05%
#     Worker 3: Train Loss: 2.3136, Train Accuracy: 39.17%
#     Worker 4: Train Loss: 2.2546, Train Accuracy: 40.61%
#     Worker 5: Train Loss: 2.2928, Train Accuracy: 39.85%
#     Worker 6: Train Loss: 2.3392, Train Accuracy: 38.40%
#     Worker 7: Train Loss: 2.2996, Train Accuracy: 39.57%
# Total Computation Time: 1386.39 seconds
# Total Communication Time: 0.22 seconds
# Epoch 43/150: Test Loss: 2.1846, Test Accuracy: 42.96%
#     Worker 0: Train Loss: 2.2746, Train Accuracy: 39.99%
#     Worker 1: Train Loss: 2.2291, Train Accuracy: 40.60%
#     Worker 2: Train Loss: 2.2204, Train Accuracy: 41.37%
#     Worker 3: Train Loss: 2.2740, Train Accuracy: 40.13%
#     Worker 4: Train Loss: 2.2391, Train Accuracy: 41.22%
#     Worker 5: Train Loss: 2.2432, Train Accuracy: 41.22%
#     Worker 6: Train Loss: 2.2715, Train Accuracy: 40.48%
#     Worker 7: Train Loss: 2.2299, Train Accuracy: 40.35%
# Total Computation Time: 1419.39 seconds
# Total Communication Time: 0.22 seconds
# Epoch 44/150: Test Loss: 2.1699, Test Accuracy: 43.91%
#     Worker 0: Train Loss: 2.2701, Train Accuracy: 40.64%
#     Worker 1: Train Loss: 2.2555, Train Accuracy: 39.60%
#     Worker 2: Train Loss: 2.2541, Train Accuracy: 40.89%
#     Worker 3: Train Loss: 2.2660, Train Accuracy: 40.71%
#     Worker 4: Train Loss: 2.2458, Train Accuracy: 40.12%
#     Worker 5: Train Loss: 2.2100, Train Accuracy: 41.58%
#     Worker 6: Train Loss: 2.2861, Train Accuracy: 40.40%
#     Worker 7: Train Loss: 2.2756, Train Accuracy: 39.90%
# Total Computation Time: 1451.82 seconds
# Total Communication Time: 0.23 seconds
# Epoch 45/150: Test Loss: 2.1529, Test Accuracy: 43.63%
#     Worker 0: Train Loss: 2.2269, Train Accuracy: 41.27%
#     Worker 1: Train Loss: 2.2025, Train Accuracy: 40.83%
#     Worker 2: Train Loss: 2.2449, Train Accuracy: 40.53%
#     Worker 3: Train Loss: 2.2765, Train Accuracy: 39.73%
#     Worker 4: Train Loss: 2.1919, Train Accuracy: 42.25%
#     Worker 5: Train Loss: 2.2520, Train Accuracy: 40.51%
#     Worker 6: Train Loss: 2.2679, Train Accuracy: 39.90%
#     Worker 7: Train Loss: 2.2685, Train Accuracy: 40.35%
# Total Computation Time: 1484.47 seconds
# Total Communication Time: 0.23 seconds
# Epoch 46/150: Test Loss: 2.1482, Test Accuracy: 43.83%
#     Worker 0: Train Loss: 2.2221, Train Accuracy: 40.76%
#     Worker 1: Train Loss: 2.1991, Train Accuracy: 41.79%
#     Worker 2: Train Loss: 2.1949, Train Accuracy: 42.11%
#     Worker 3: Train Loss: 2.2109, Train Accuracy: 41.68%
#     Worker 4: Train Loss: 2.1845, Train Accuracy: 42.10%
#     Worker 5: Train Loss: 2.1700, Train Accuracy: 43.15%
#     Worker 6: Train Loss: 2.2155, Train Accuracy: 41.31%
#     Worker 7: Train Loss: 2.2098, Train Accuracy: 41.47%
# Total Computation Time: 1517.28 seconds
# Total Communication Time: 0.24 seconds
# Epoch 47/150: Test Loss: 2.1347, Test Accuracy: 44.08%
#     Worker 0: Train Loss: 2.2068, Train Accuracy: 41.24%
#     Worker 1: Train Loss: 2.1696, Train Accuracy: 42.28%
#     Worker 2: Train Loss: 2.1933, Train Accuracy: 42.17%
#     Worker 3: Train Loss: 2.1704, Train Accuracy: 42.19%
#     Worker 4: Train Loss: 2.1810, Train Accuracy: 42.01%
#     Worker 5: Train Loss: 2.1727, Train Accuracy: 42.79%
#     Worker 6: Train Loss: 2.2058, Train Accuracy: 41.37%
#     Worker 7: Train Loss: 2.1871, Train Accuracy: 42.15%
# Total Computation Time: 1550.31 seconds
# Total Communication Time: 0.24 seconds
# Epoch 48/150: Test Loss: 2.1421, Test Accuracy: 44.03%
#     Worker 0: Train Loss: 2.1959, Train Accuracy: 42.12%
#     Worker 1: Train Loss: 2.1858, Train Accuracy: 41.54%
#     Worker 2: Train Loss: 2.2080, Train Accuracy: 41.58%
#     Worker 3: Train Loss: 2.1893, Train Accuracy: 41.29%
#     Worker 4: Train Loss: 2.1489, Train Accuracy: 42.46%
#     Worker 5: Train Loss: 2.1726, Train Accuracy: 42.45%
#     Worker 6: Train Loss: 2.2224, Train Accuracy: 40.95%
#     Worker 7: Train Loss: 2.2065, Train Accuracy: 41.52%
# Total Computation Time: 1583.35 seconds
# Total Communication Time: 0.25 seconds
# Epoch 49/150: Test Loss: 2.1294, Test Accuracy: 44.45%
#     Worker 0: Train Loss: 2.1562, Train Accuracy: 42.19%
#     Worker 1: Train Loss: 2.1340, Train Accuracy: 43.02%
#     Worker 2: Train Loss: 2.1583, Train Accuracy: 42.65%
#     Worker 3: Train Loss: 2.1669, Train Accuracy: 42.40%
#     Worker 4: Train Loss: 2.1365, Train Accuracy: 43.19%
#     Worker 5: Train Loss: 2.1419, Train Accuracy: 43.65%
#     Worker 6: Train Loss: 2.1550, Train Accuracy: 42.69%
#     Worker 7: Train Loss: 2.1418, Train Accuracy: 43.59%
# Total Computation Time: 1615.72 seconds
# Total Communication Time: 0.25 seconds
# Epoch 50/150: Test Loss: 2.0991, Test Accuracy: 45.16%
#     Worker 0: Train Loss: 2.1359, Train Accuracy: 42.82%
#     Worker 1: Train Loss: 2.0919, Train Accuracy: 43.50%
#     Worker 2: Train Loss: 2.1099, Train Accuracy: 44.24%
#     Worker 3: Train Loss: 2.1225, Train Accuracy: 43.34%
#     Worker 4: Train Loss: 2.0810, Train Accuracy: 44.28%
#     Worker 5: Train Loss: 2.1238, Train Accuracy: 44.25%
#     Worker 6: Train Loss: 2.1299, Train Accuracy: 43.44%
#     Worker 7: Train Loss: 2.1082, Train Accuracy: 43.34%
# Total Computation Time: 1648.23 seconds
# Total Communication Time: 0.25 seconds
# Epoch 51/150: Test Loss: 2.0957, Test Accuracy: 45.14%
#     Worker 0: Train Loss: 2.1610, Train Accuracy: 42.35%
#     Worker 1: Train Loss: 2.1094, Train Accuracy: 43.59%
#     Worker 2: Train Loss: 2.1154, Train Accuracy: 44.10%
#     Worker 3: Train Loss: 2.1488, Train Accuracy: 42.57%
#     Worker 4: Train Loss: 2.0931, Train Accuracy: 44.28%
#     Worker 5: Train Loss: 2.1096, Train Accuracy: 43.39%
#     Worker 6: Train Loss: 2.1504, Train Accuracy: 42.09%
#     Worker 7: Train Loss: 2.1294, Train Accuracy: 43.01%
# Total Computation Time: 1680.72 seconds
# Total Communication Time: 0.26 seconds
# Epoch 52/150: Test Loss: 2.0792, Test Accuracy: 45.51%
#     Worker 0: Train Loss: 2.1293, Train Accuracy: 42.82%
#     Worker 1: Train Loss: 2.0955, Train Accuracy: 44.25%
#     Worker 2: Train Loss: 2.1008, Train Accuracy: 43.66%
#     Worker 3: Train Loss: 2.1257, Train Accuracy: 42.90%
#     Worker 4: Train Loss: 2.0891, Train Accuracy: 44.09%
#     Worker 5: Train Loss: 2.0665, Train Accuracy: 44.74%
#     Worker 6: Train Loss: 2.1307, Train Accuracy: 43.00%
#     Worker 7: Train Loss: 2.1054, Train Accuracy: 44.10%
# Total Computation Time: 1713.73 seconds
# Total Communication Time: 0.26 seconds
# Epoch 53/150: Test Loss: 2.0685, Test Accuracy: 45.45%
#     Worker 0: Train Loss: 2.0848, Train Accuracy: 44.22%
#     Worker 1: Train Loss: 2.0556, Train Accuracy: 44.83%
#     Worker 2: Train Loss: 2.0662, Train Accuracy: 44.87%
#     Worker 3: Train Loss: 2.0998, Train Accuracy: 43.67%
#     Worker 4: Train Loss: 2.0425, Train Accuracy: 44.78%
#     Worker 5: Train Loss: 2.0527, Train Accuracy: 44.85%
#     Worker 6: Train Loss: 2.1005, Train Accuracy: 44.05%
#     Worker 7: Train Loss: 2.0659, Train Accuracy: 44.61%
# Total Computation Time: 1746.82 seconds
# Total Communication Time: 0.27 seconds
# Epoch 54/150: Test Loss: 2.0665, Test Accuracy: 45.76%
#     Worker 0: Train Loss: 2.0679, Train Accuracy: 44.33%
#     Worker 1: Train Loss: 2.0444, Train Accuracy: 44.61%
#     Worker 2: Train Loss: 2.0446, Train Accuracy: 45.34%
#     Worker 3: Train Loss: 2.0893, Train Accuracy: 43.37%
#     Worker 4: Train Loss: 2.0454, Train Accuracy: 45.18%
#     Worker 5: Train Loss: 2.0673, Train Accuracy: 45.17%
#     Worker 6: Train Loss: 2.1098, Train Accuracy: 43.54%
#     Worker 7: Train Loss: 2.0734, Train Accuracy: 44.66%
# Total Computation Time: 1780.14 seconds
# Total Communication Time: 0.27 seconds
# Epoch 55/150: Test Loss: 2.0640, Test Accuracy: 45.78%
#     Worker 0: Train Loss: 2.0584, Train Accuracy: 44.35%
#     Worker 1: Train Loss: 2.0424, Train Accuracy: 44.31%
#     Worker 2: Train Loss: 2.0608, Train Accuracy: 44.26%
#     Worker 3: Train Loss: 2.0921, Train Accuracy: 44.43%
#     Worker 4: Train Loss: 2.0148, Train Accuracy: 45.85%
#     Worker 5: Train Loss: 2.0518, Train Accuracy: 45.25%
#     Worker 6: Train Loss: 2.0773, Train Accuracy: 44.59%
#     Worker 7: Train Loss: 2.0585, Train Accuracy: 44.58%
# Total Computation Time: 1812.74 seconds
# Total Communication Time: 0.28 seconds
# Epoch 56/150: Test Loss: 2.0483, Test Accuracy: 46.05%
#     Worker 0: Train Loss: 2.0525, Train Accuracy: 45.25%
#     Worker 1: Train Loss: 1.9827, Train Accuracy: 46.42%
#     Worker 2: Train Loss: 2.0200, Train Accuracy: 45.99%
#     Worker 3: Train Loss: 2.0287, Train Accuracy: 45.89%
#     Worker 4: Train Loss: 2.0274, Train Accuracy: 45.50%
#     Worker 5: Train Loss: 1.9883, Train Accuracy: 46.85%
#     Worker 6: Train Loss: 2.0559, Train Accuracy: 45.07%
#     Worker 7: Train Loss: 2.0325, Train Accuracy: 45.53%
# Total Computation Time: 1844.76 seconds
# Total Communication Time: 0.28 seconds
# Epoch 57/150: Test Loss: 2.0513, Test Accuracy: 46.59%
#     Worker 0: Train Loss: 2.0388, Train Accuracy: 44.76%
#     Worker 1: Train Loss: 1.9999, Train Accuracy: 45.94%
#     Worker 2: Train Loss: 1.9912, Train Accuracy: 47.06%
#     Worker 3: Train Loss: 2.0419, Train Accuracy: 45.19%
#     Worker 4: Train Loss: 1.9989, Train Accuracy: 46.62%
#     Worker 5: Train Loss: 1.9756, Train Accuracy: 47.52%
#     Worker 6: Train Loss: 2.0430, Train Accuracy: 44.87%
#     Worker 7: Train Loss: 2.0120, Train Accuracy: 45.85%
# Total Computation Time: 1877.52 seconds
# Total Communication Time: 0.28 seconds
# Epoch 58/150: Test Loss: 2.0408, Test Accuracy: 46.41%
#     Worker 0: Train Loss: 2.0303, Train Accuracy: 45.20%
#     Worker 1: Train Loss: 1.9755, Train Accuracy: 46.17%
#     Worker 2: Train Loss: 2.0137, Train Accuracy: 45.35%
#     Worker 3: Train Loss: 2.0276, Train Accuracy: 44.92%
#     Worker 4: Train Loss: 1.9715, Train Accuracy: 46.55%
#     Worker 5: Train Loss: 2.0077, Train Accuracy: 46.43%
#     Worker 6: Train Loss: 2.0101, Train Accuracy: 45.81%
#     Worker 7: Train Loss: 1.9949, Train Accuracy: 46.16%
# Total Computation Time: 1910.62 seconds
# Total Communication Time: 0.29 seconds
# Epoch 59/150: Test Loss: 2.0199, Test Accuracy: 46.86%
#     Worker 0: Train Loss: 1.9974, Train Accuracy: 46.11%
#     Worker 1: Train Loss: 1.9476, Train Accuracy: 47.05%
#     Worker 2: Train Loss: 1.9626, Train Accuracy: 46.54%
#     Worker 3: Train Loss: 1.9892, Train Accuracy: 46.28%
#     Worker 4: Train Loss: 1.9400, Train Accuracy: 47.61%
#     Worker 5: Train Loss: 1.9269, Train Accuracy: 48.16%
#     Worker 6: Train Loss: 1.9991, Train Accuracy: 45.43%
#     Worker 7: Train Loss: 1.9684, Train Accuracy: 46.58%
# Total Computation Time: 1943.30 seconds
# Total Communication Time: 0.29 seconds
# Epoch 60/150: Test Loss: 2.0172, Test Accuracy: 46.72%
#     Worker 0: Train Loss: 1.9489, Train Accuracy: 47.09%
#     Worker 1: Train Loss: 1.9461, Train Accuracy: 47.12%
#     Worker 2: Train Loss: 1.9634, Train Accuracy: 46.88%
#     Worker 3: Train Loss: 1.9627, Train Accuracy: 47.29%
#     Worker 4: Train Loss: 1.9395, Train Accuracy: 47.50%
#     Worker 5: Train Loss: 1.9633, Train Accuracy: 46.70%
#     Worker 6: Train Loss: 1.9891, Train Accuracy: 46.22%
#     Worker 7: Train Loss: 1.9613, Train Accuracy: 46.96%
# Total Computation Time: 1976.24 seconds
# Total Communication Time: 0.30 seconds
# Epoch 61/150: Test Loss: 2.0155, Test Accuracy: 46.91%
#     Worker 0: Train Loss: 2.0082, Train Accuracy: 45.62%
#     Worker 1: Train Loss: 1.9366, Train Accuracy: 47.23%
#     Worker 2: Train Loss: 1.9552, Train Accuracy: 47.31%
#     Worker 3: Train Loss: 1.9901, Train Accuracy: 45.96%
#     Worker 4: Train Loss: 1.9365, Train Accuracy: 48.16%
#     Worker 5: Train Loss: 1.9508, Train Accuracy: 47.54%
#     Worker 6: Train Loss: 1.9780, Train Accuracy: 46.24%
#     Worker 7: Train Loss: 1.9669, Train Accuracy: 46.68%
# Total Computation Time: 2007.61 seconds
# Total Communication Time: 0.30 seconds
# Epoch 62/150: Test Loss: 2.0061, Test Accuracy: 47.28%
#     Worker 0: Train Loss: 1.9611, Train Accuracy: 46.99%
#     Worker 1: Train Loss: 1.9069, Train Accuracy: 48.14%
#     Worker 2: Train Loss: 1.9286, Train Accuracy: 47.91%
#     Worker 3: Train Loss: 1.9174, Train Accuracy: 47.82%
#     Worker 4: Train Loss: 1.9061, Train Accuracy: 48.82%
#     Worker 5: Train Loss: 1.9308, Train Accuracy: 48.29%
#     Worker 6: Train Loss: 1.9643, Train Accuracy: 47.09%
#     Worker 7: Train Loss: 1.9295, Train Accuracy: 47.76%
# Total Computation Time: 2039.82 seconds
# Total Communication Time: 0.30 seconds
# Epoch 63/150: Test Loss: 2.0113, Test Accuracy: 47.11%
#     Worker 0: Train Loss: 1.9274, Train Accuracy: 47.70%
#     Worker 1: Train Loss: 1.8874, Train Accuracy: 48.02%
#     Worker 2: Train Loss: 1.8970, Train Accuracy: 48.91%
#     Worker 3: Train Loss: 1.9420, Train Accuracy: 47.30%
#     Worker 4: Train Loss: 1.8721, Train Accuracy: 49.10%
#     Worker 5: Train Loss: 1.9141, Train Accuracy: 48.61%
#     Worker 6: Train Loss: 1.9154, Train Accuracy: 47.97%
#     Worker 7: Train Loss: 1.8958, Train Accuracy: 48.61%
# Total Computation Time: 2071.61 seconds
# Total Communication Time: 0.31 seconds
# Epoch 64/150: Test Loss: 2.0017, Test Accuracy: 47.16%
#     Worker 0: Train Loss: 1.9300, Train Accuracy: 47.12%
#     Worker 1: Train Loss: 1.8820, Train Accuracy: 48.71%
#     Worker 2: Train Loss: 1.9037, Train Accuracy: 49.00%
#     Worker 3: Train Loss: 1.9459, Train Accuracy: 47.20%
#     Worker 4: Train Loss: 1.9019, Train Accuracy: 48.57%
#     Worker 5: Train Loss: 1.9399, Train Accuracy: 47.23%
#     Worker 6: Train Loss: 1.9376, Train Accuracy: 48.25%
#     Worker 7: Train Loss: 1.9260, Train Accuracy: 47.54%
# Total Computation Time: 2103.52 seconds
# Total Communication Time: 0.31 seconds
# Epoch 65/150: Test Loss: 1.9836, Test Accuracy: 47.73%
#     Worker 0: Train Loss: 1.9272, Train Accuracy: 47.77%
#     Worker 1: Train Loss: 1.8930, Train Accuracy: 48.24%
#     Worker 2: Train Loss: 1.8766, Train Accuracy: 49.22%
#     Worker 3: Train Loss: 1.9166, Train Accuracy: 48.46%
#     Worker 4: Train Loss: 1.8709, Train Accuracy: 48.65%
#     Worker 5: Train Loss: 1.8601, Train Accuracy: 49.50%
#     Worker 6: Train Loss: 1.9096, Train Accuracy: 49.16%
#     Worker 7: Train Loss: 1.8921, Train Accuracy: 48.74%
# Total Computation Time: 2135.82 seconds
# Total Communication Time: 0.32 seconds
# Epoch 66/150: Test Loss: 1.9982, Test Accuracy: 47.69%
#     Worker 0: Train Loss: 1.8700, Train Accuracy: 48.93%
#     Worker 1: Train Loss: 1.8354, Train Accuracy: 49.96%
#     Worker 2: Train Loss: 1.8320, Train Accuracy: 49.84%
#     Worker 3: Train Loss: 1.8593, Train Accuracy: 49.14%
#     Worker 4: Train Loss: 1.8337, Train Accuracy: 49.82%
#     Worker 5: Train Loss: 1.8678, Train Accuracy: 49.05%
#     Worker 6: Train Loss: 1.8846, Train Accuracy: 48.61%
#     Worker 7: Train Loss: 1.8804, Train Accuracy: 48.83%
# Total Computation Time: 2168.15 seconds
# Total Communication Time: 0.32 seconds
# Epoch 67/150: Test Loss: 1.9817, Test Accuracy: 47.72%
#     Worker 0: Train Loss: 1.8665, Train Accuracy: 49.22%
#     Worker 1: Train Loss: 1.8574, Train Accuracy: 48.60%
#     Worker 2: Train Loss: 1.8497, Train Accuracy: 49.40%
#     Worker 3: Train Loss: 1.8819, Train Accuracy: 48.37%
#     Worker 4: Train Loss: 1.8480, Train Accuracy: 49.55%
#     Worker 5: Train Loss: 1.8481, Train Accuracy: 50.48%
#     Worker 6: Train Loss: 1.8733, Train Accuracy: 49.46%
#     Worker 7: Train Loss: 1.8442, Train Accuracy: 49.73%
# Total Computation Time: 2200.86 seconds
# Total Communication Time: 0.32 seconds
# Epoch 68/150: Test Loss: 1.9720, Test Accuracy: 48.07%
#     Worker 0: Train Loss: 1.8953, Train Accuracy: 48.19%
#     Worker 1: Train Loss: 1.8526, Train Accuracy: 49.50%
#     Worker 2: Train Loss: 1.8440, Train Accuracy: 49.51%
#     Worker 3: Train Loss: 1.8719, Train Accuracy: 48.69%
#     Worker 4: Train Loss: 1.8495, Train Accuracy: 49.18%
#     Worker 5: Train Loss: 1.8760, Train Accuracy: 49.01%
#     Worker 6: Train Loss: 1.8822, Train Accuracy: 49.25%
#     Worker 7: Train Loss: 1.8360, Train Accuracy: 49.50%
# Total Computation Time: 2233.81 seconds
# Total Communication Time: 0.33 seconds
# Epoch 69/150: Test Loss: 1.9683, Test Accuracy: 48.19%
#     Worker 0: Train Loss: 1.8462, Train Accuracy: 49.82%
#     Worker 1: Train Loss: 1.7916, Train Accuracy: 50.99%
#     Worker 2: Train Loss: 1.7868, Train Accuracy: 51.06%
#     Worker 3: Train Loss: 1.8480, Train Accuracy: 49.36%
#     Worker 4: Train Loss: 1.7986, Train Accuracy: 51.07%
#     Worker 5: Train Loss: 1.8312, Train Accuracy: 50.41%
#     Worker 6: Train Loss: 1.8471, Train Accuracy: 49.80%
#     Worker 7: Train Loss: 1.8166, Train Accuracy: 50.26%
# Total Computation Time: 2267.32 seconds
# Total Communication Time: 0.33 seconds
# Epoch 70/150: Test Loss: 1.9688, Test Accuracy: 48.42%
#     Worker 0: Train Loss: 1.8218, Train Accuracy: 50.29%
#     Worker 1: Train Loss: 1.8134, Train Accuracy: 50.24%
#     Worker 2: Train Loss: 1.7783, Train Accuracy: 51.49%
#     Worker 3: Train Loss: 1.8384, Train Accuracy: 49.95%
#     Worker 4: Train Loss: 1.7896, Train Accuracy: 50.66%
#     Worker 5: Train Loss: 1.8144, Train Accuracy: 50.92%
#     Worker 6: Train Loss: 1.8580, Train Accuracy: 49.74%
#     Worker 7: Train Loss: 1.8210, Train Accuracy: 50.32%
# Total Computation Time: 2301.03 seconds
# Total Communication Time: 0.34 seconds
# Epoch 71/150: Test Loss: 1.9675, Test Accuracy: 48.59%
#     Worker 0: Train Loss: 1.8214, Train Accuracy: 49.90%
#     Worker 1: Train Loss: 1.7785, Train Accuracy: 50.86%
#     Worker 2: Train Loss: 1.8191, Train Accuracy: 50.56%
#     Worker 3: Train Loss: 1.8429, Train Accuracy: 49.63%
#     Worker 4: Train Loss: 1.7781, Train Accuracy: 50.95%
#     Worker 5: Train Loss: 1.8027, Train Accuracy: 50.92%
#     Worker 6: Train Loss: 1.8595, Train Accuracy: 49.08%
#     Worker 7: Train Loss: 1.7922, Train Accuracy: 50.67%
# Total Computation Time: 2334.97 seconds
# Total Communication Time: 0.34 seconds
# Epoch 72/150: Test Loss: 1.9546, Test Accuracy: 48.67%
#     Worker 0: Train Loss: 1.7780, Train Accuracy: 50.98%
#     Worker 1: Train Loss: 1.7590, Train Accuracy: 51.73%
#     Worker 2: Train Loss: 1.7607, Train Accuracy: 52.33%
#     Worker 3: Train Loss: 1.7975, Train Accuracy: 50.28%
#     Worker 4: Train Loss: 1.7693, Train Accuracy: 51.64%
#     Worker 5: Train Loss: 1.7911, Train Accuracy: 51.12%
#     Worker 6: Train Loss: 1.8017, Train Accuracy: 50.81%
#     Worker 7: Train Loss: 1.7922, Train Accuracy: 50.96%
# Total Computation Time: 2368.09 seconds
# Total Communication Time: 0.35 seconds
# Epoch 73/150: Test Loss: 1.9493, Test Accuracy: 48.30%
#     Worker 0: Train Loss: 1.7829, Train Accuracy: 50.47%
#     Worker 1: Train Loss: 1.7418, Train Accuracy: 51.66%
#     Worker 2: Train Loss: 1.7539, Train Accuracy: 51.55%
#     Worker 3: Train Loss: 1.7935, Train Accuracy: 50.29%
#     Worker 4: Train Loss: 1.7529, Train Accuracy: 51.53%
#     Worker 5: Train Loss: 1.7670, Train Accuracy: 51.91%
#     Worker 6: Train Loss: 1.7735, Train Accuracy: 51.38%
#     Worker 7: Train Loss: 1.7580, Train Accuracy: 52.29%
# Total Computation Time: 2401.01 seconds
# Total Communication Time: 0.35 seconds
# Epoch 74/150: Test Loss: 1.9451, Test Accuracy: 48.81%
#     Worker 0: Train Loss: 1.8010, Train Accuracy: 50.65%
#     Worker 1: Train Loss: 1.7752, Train Accuracy: 51.55%
#     Worker 2: Train Loss: 1.7491, Train Accuracy: 51.87%
#     Worker 3: Train Loss: 1.8090, Train Accuracy: 50.29%
#     Worker 4: Train Loss: 1.7672, Train Accuracy: 51.26%
#     Worker 5: Train Loss: 1.7455, Train Accuracy: 52.09%
#     Worker 6: Train Loss: 1.8175, Train Accuracy: 50.73%
#     Worker 7: Train Loss: 1.7747, Train Accuracy: 51.32%
# Total Computation Time: 2434.16 seconds
# Total Communication Time: 0.35 seconds
# Epoch 75/150: Test Loss: 1.9430, Test Accuracy: 48.46%
#     Worker 0: Train Loss: 1.7656, Train Accuracy: 51.42%
#     Worker 1: Train Loss: 1.7193, Train Accuracy: 52.52%
#     Worker 2: Train Loss: 1.7273, Train Accuracy: 52.51%
#     Worker 3: Train Loss: 1.7533, Train Accuracy: 52.06%
#     Worker 4: Train Loss: 1.7176, Train Accuracy: 52.36%
#     Worker 5: Train Loss: 1.7621, Train Accuracy: 51.81%
#     Worker 6: Train Loss: 1.7660, Train Accuracy: 51.63%
#     Worker 7: Train Loss: 1.7300, Train Accuracy: 52.48%
# Total Computation Time: 2467.62 seconds
# Total Communication Time: 0.36 seconds
# Epoch 76/150: Test Loss: 1.9486, Test Accuracy: 48.79%
#     Worker 0: Train Loss: 1.7297, Train Accuracy: 52.48%
#     Worker 1: Train Loss: 1.7150, Train Accuracy: 52.47%
#     Worker 2: Train Loss: 1.7041, Train Accuracy: 52.66%
#     Worker 3: Train Loss: 1.7322, Train Accuracy: 52.81%
#     Worker 4: Train Loss: 1.7077, Train Accuracy: 52.65%
#     Worker 5: Train Loss: 1.7332, Train Accuracy: 52.47%
#     Worker 6: Train Loss: 1.7303, Train Accuracy: 52.30%
#     Worker 7: Train Loss: 1.7201, Train Accuracy: 52.33%
# Total Computation Time: 2500.81 seconds
# Total Communication Time: 0.36 seconds
# Epoch 77/150: Test Loss: 1.9509, Test Accuracy: 48.78%
#     Worker 0: Train Loss: 1.7530, Train Accuracy: 51.91%
#     Worker 1: Train Loss: 1.7205, Train Accuracy: 52.69%
#     Worker 2: Train Loss: 1.6993, Train Accuracy: 52.93%
#     Worker 3: Train Loss: 1.7392, Train Accuracy: 52.31%
#     Worker 4: Train Loss: 1.6903, Train Accuracy: 53.10%
#     Worker 5: Train Loss: 1.7662, Train Accuracy: 51.53%
#     Worker 6: Train Loss: 1.7683, Train Accuracy: 51.68%
#     Worker 7: Train Loss: 1.6960, Train Accuracy: 53.16%
# Total Computation Time: 2534.23 seconds
# Total Communication Time: 0.37 seconds
# Epoch 78/150: Test Loss: 1.9434, Test Accuracy: 49.15%
#     Worker 0: Train Loss: 1.7075, Train Accuracy: 52.37%
#     Worker 1: Train Loss: 1.6756, Train Accuracy: 53.84%
#     Worker 2: Train Loss: 1.7142, Train Accuracy: 52.86%
#     Worker 3: Train Loss: 1.7436, Train Accuracy: 51.74%
#     Worker 4: Train Loss: 1.7026, Train Accuracy: 52.53%
#     Worker 5: Train Loss: 1.7036, Train Accuracy: 53.60%
#     Worker 6: Train Loss: 1.7522, Train Accuracy: 52.06%
#     Worker 7: Train Loss: 1.7200, Train Accuracy: 52.24%
# Total Computation Time: 2567.83 seconds
# Total Communication Time: 0.37 seconds
# Epoch 79/150: Test Loss: 1.9371, Test Accuracy: 49.30%
#     Worker 0: Train Loss: 1.7119, Train Accuracy: 52.30%
#     Worker 1: Train Loss: 1.6852, Train Accuracy: 53.83%
#     Worker 2: Train Loss: 1.6852, Train Accuracy: 53.36%
#     Worker 3: Train Loss: 1.6904, Train Accuracy: 53.08%
#     Worker 4: Train Loss: 1.6749, Train Accuracy: 53.56%
#     Worker 5: Train Loss: 1.6932, Train Accuracy: 53.47%
#     Worker 6: Train Loss: 1.6975, Train Accuracy: 53.04%
#     Worker 7: Train Loss: 1.6732, Train Accuracy: 53.65%
# Total Computation Time: 2600.93 seconds
# Total Communication Time: 0.38 seconds
# Epoch 80/150: Test Loss: 1.9289, Test Accuracy: 49.57%
#     Worker 0: Train Loss: 1.6948, Train Accuracy: 53.35%
#     Worker 1: Train Loss: 1.6858, Train Accuracy: 53.62%
#     Worker 2: Train Loss: 1.6771, Train Accuracy: 53.79%
#     Worker 3: Train Loss: 1.7208, Train Accuracy: 52.31%
#     Worker 4: Train Loss: 1.6488, Train Accuracy: 54.33%
#     Worker 5: Train Loss: 1.6840, Train Accuracy: 53.73%
#     Worker 6: Train Loss: 1.7240, Train Accuracy: 52.79%
#     Worker 7: Train Loss: 1.6778, Train Accuracy: 53.71%
# Total Computation Time: 2633.75 seconds
# Total Communication Time: 0.38 seconds
# Epoch 81/150: Test Loss: 1.9328, Test Accuracy: 49.36%
#     Worker 0: Train Loss: 1.6832, Train Accuracy: 53.71%
#     Worker 1: Train Loss: 1.6487, Train Accuracy: 54.46%
#     Worker 2: Train Loss: 1.6719, Train Accuracy: 53.81%
#     Worker 3: Train Loss: 1.6782, Train Accuracy: 53.65%
#     Worker 4: Train Loss: 1.6833, Train Accuracy: 53.41%
#     Worker 5: Train Loss: 1.6684, Train Accuracy: 54.24%
#     Worker 6: Train Loss: 1.6989, Train Accuracy: 53.18%
#     Worker 7: Train Loss: 1.6682, Train Accuracy: 53.68%
# ...
# Total Communication Time: 0.57 seconds
# Epoch 124/150: Test Loss: 1.9261, Test Accuracy: 51.75%
#     Worker 0: Train Loss: 1.2826, Train Accuracy: 62.82%
#     Worker 1: Train Loss: 1.2732, Train Accuracy: 63.97%
#     Worker 2: Train Loss: 1.2716, Train Accuracy: 64.15%
#     Worker 3: Train Loss: 1.3041, Train Accuracy: 63.26%
#     Worker 4: Train Loss: 1.2473, Train Accuracy: 64.52%
#     Worker 5: Train Loss: 1.2940, Train Accuracy: 63.04%
#     Worker 6: Train Loss: 1.2876, Train Accuracy: 63.17%
#     Worker 7: Train Loss: 1.2549, Train Accuracy: 63.79%
# Total Computation Time: 4082.65 seconds
# Total Communication Time: 0.57 seconds
# Epoch 125/150: Test Loss: 1.9274, Test Accuracy: 51.55%
#     Worker 0: Train Loss: 1.2581, Train Accuracy: 64.41%
#     Worker 1: Train Loss: 1.2386, Train Accuracy: 64.57%
#     Worker 2: Train Loss: 1.2595, Train Accuracy: 64.60%
#     Worker 3: Train Loss: 1.2821, Train Accuracy: 63.61%
#     Worker 4: Train Loss: 1.2431, Train Accuracy: 64.31%
#     Worker 5: Train Loss: 1.2616, Train Accuracy: 63.91%
#     Worker 6: Train Loss: 1.2825, Train Accuracy: 63.73%
#     Worker 7: Train Loss: 1.2536, Train Accuracy: 64.76%
# Total Computation Time: 4116.81 seconds
# Total Communication Time: 0.57 seconds
# Epoch 126/150: Test Loss: 1.9293, Test Accuracy: 51.54%
#     Worker 0: Train Loss: 1.2803, Train Accuracy: 63.38%
#     Worker 1: Train Loss: 1.2659, Train Accuracy: 64.08%
#     Worker 2: Train Loss: 1.2602, Train Accuracy: 64.43%
#     Worker 3: Train Loss: 1.2739, Train Accuracy: 63.88%
#     Worker 4: Train Loss: 1.2424, Train Accuracy: 64.86%
#     Worker 5: Train Loss: 1.2620, Train Accuracy: 64.59%
#     Worker 6: Train Loss: 1.2695, Train Accuracy: 63.86%
#     Worker 7: Train Loss: 1.2573, Train Accuracy: 64.14%
# Total Computation Time: 4150.08 seconds
# Total Communication Time: 0.58 seconds
# Epoch 127/150: Test Loss: 1.9287, Test Accuracy: 51.46%
#     Worker 0: Train Loss: 1.2877, Train Accuracy: 63.19%
#     Worker 1: Train Loss: 1.2557, Train Accuracy: 64.28%
#     Worker 2: Train Loss: 1.2621, Train Accuracy: 64.87%
#     Worker 3: Train Loss: 1.2758, Train Accuracy: 63.97%
#     Worker 4: Train Loss: 1.2389, Train Accuracy: 65.03%
#     Worker 5: Train Loss: 1.2655, Train Accuracy: 64.39%
#     Worker 6: Train Loss: 1.2914, Train Accuracy: 63.34%
#     Worker 7: Train Loss: 1.2560, Train Accuracy: 64.16%
# Total Computation Time: 4183.29 seconds
# Total Communication Time: 0.58 seconds
# Epoch 128/150: Test Loss: 1.9349, Test Accuracy: 51.32%
#     Worker 0: Train Loss: 1.2610, Train Accuracy: 63.82%
#     Worker 1: Train Loss: 1.2439, Train Accuracy: 64.30%
#     Worker 2: Train Loss: 1.2499, Train Accuracy: 64.73%
#     Worker 3: Train Loss: 1.2693, Train Accuracy: 64.19%
#     Worker 4: Train Loss: 1.2378, Train Accuracy: 64.64%
#     Worker 5: Train Loss: 1.2771, Train Accuracy: 63.86%
#     Worker 6: Train Loss: 1.3048, Train Accuracy: 62.67%
#     Worker 7: Train Loss: 1.2485, Train Accuracy: 64.60%
# Total Computation Time: 4216.94 seconds
# Total Communication Time: 0.59 seconds
# Epoch 129/150: Test Loss: 1.9330, Test Accuracy: 51.52%
#     Worker 0: Train Loss: 1.2542, Train Accuracy: 64.31%
#     Worker 1: Train Loss: 1.2576, Train Accuracy: 64.31%
#     Worker 2: Train Loss: 1.2240, Train Accuracy: 65.54%
#     Worker 3: Train Loss: 1.2563, Train Accuracy: 64.17%
#     Worker 4: Train Loss: 1.2432, Train Accuracy: 64.42%
#     Worker 5: Train Loss: 1.2551, Train Accuracy: 64.41%
#     Worker 6: Train Loss: 1.2810, Train Accuracy: 63.75%
#     Worker 7: Train Loss: 1.2360, Train Accuracy: 64.68%
# Total Computation Time: 4250.96 seconds
# Total Communication Time: 0.59 seconds
# Epoch 130/150: Test Loss: 1.9323, Test Accuracy: 51.67%
#     Worker 0: Train Loss: 1.2621, Train Accuracy: 64.17%
#     Worker 1: Train Loss: 1.2452, Train Accuracy: 64.04%
#     Worker 2: Train Loss: 1.2595, Train Accuracy: 64.85%
#     Worker 3: Train Loss: 1.2679, Train Accuracy: 63.45%
#     Worker 4: Train Loss: 1.2364, Train Accuracy: 64.86%
#     Worker 5: Train Loss: 1.2533, Train Accuracy: 64.55%
#     Worker 6: Train Loss: 1.2551, Train Accuracy: 64.35%
#     Worker 7: Train Loss: 1.2649, Train Accuracy: 63.68%
# Total Computation Time: 4284.92 seconds
# Total Communication Time: 0.60 seconds
# Epoch 131/150: Test Loss: 1.9339, Test Accuracy: 51.41%
#     Worker 0: Train Loss: 1.2645, Train Accuracy: 63.54%
#     Worker 1: Train Loss: 1.2466, Train Accuracy: 63.84%
#     Worker 2: Train Loss: 1.2221, Train Accuracy: 65.30%
#     Worker 3: Train Loss: 1.2630, Train Accuracy: 64.13%
#     Worker 4: Train Loss: 1.2231, Train Accuracy: 65.05%
#     Worker 5: Train Loss: 1.2525, Train Accuracy: 64.57%
#     Worker 6: Train Loss: 1.2923, Train Accuracy: 63.06%
#     Worker 7: Train Loss: 1.2521, Train Accuracy: 64.73%
# Total Computation Time: 4318.15 seconds
# Total Communication Time: 0.60 seconds
# Epoch 132/150: Test Loss: 1.9353, Test Accuracy: 51.46%
#     Worker 0: Train Loss: 1.2364, Train Accuracy: 64.60%
#     Worker 1: Train Loss: 1.2257, Train Accuracy: 65.09%
#     Worker 2: Train Loss: 1.2385, Train Accuracy: 64.94%
#     Worker 3: Train Loss: 1.2734, Train Accuracy: 63.90%
#     Worker 4: Train Loss: 1.2122, Train Accuracy: 65.46%
#     Worker 5: Train Loss: 1.2778, Train Accuracy: 63.64%
#     Worker 6: Train Loss: 1.2581, Train Accuracy: 63.93%
#     Worker 7: Train Loss: 1.2229, Train Accuracy: 65.02%
# Total Computation Time: 4351.58 seconds
# Total Communication Time: 0.60 seconds
# Epoch 133/150: Test Loss: 1.9353, Test Accuracy: 51.58%
#     Worker 0: Train Loss: 1.2496, Train Accuracy: 64.28%
#     Worker 1: Train Loss: 1.2400, Train Accuracy: 64.86%
#     Worker 2: Train Loss: 1.2288, Train Accuracy: 65.36%
#     Worker 3: Train Loss: 1.2641, Train Accuracy: 63.99%
#     Worker 4: Train Loss: 1.2294, Train Accuracy: 64.69%
#     Worker 5: Train Loss: 1.2213, Train Accuracy: 65.35%
#     Worker 6: Train Loss: 1.2896, Train Accuracy: 63.88%
#     Worker 7: Train Loss: 1.2419, Train Accuracy: 64.66%
# Total Computation Time: 4385.73 seconds
# Total Communication Time: 0.61 seconds
# Epoch 134/150: Test Loss: 1.9339, Test Accuracy: 51.49%
#     Worker 0: Train Loss: 1.2532, Train Accuracy: 64.14%
#     Worker 1: Train Loss: 1.2216, Train Accuracy: 65.01%
#     Worker 2: Train Loss: 1.2225, Train Accuracy: 65.56%
#     Worker 3: Train Loss: 1.2567, Train Accuracy: 64.20%
#     Worker 4: Train Loss: 1.2203, Train Accuracy: 65.12%
#     Worker 5: Train Loss: 1.2533, Train Accuracy: 65.05%
#     Worker 6: Train Loss: 1.2784, Train Accuracy: 64.05%
#     Worker 7: Train Loss: 1.2471, Train Accuracy: 64.57%
# Total Computation Time: 4420.08 seconds
# Total Communication Time: 0.61 seconds
# Epoch 135/150: Test Loss: 1.9358, Test Accuracy: 51.42%
#     Worker 0: Train Loss: 1.2563, Train Accuracy: 64.04%
#     Worker 1: Train Loss: 1.2377, Train Accuracy: 64.88%
#     Worker 2: Train Loss: 1.2269, Train Accuracy: 65.17%
#     Worker 3: Train Loss: 1.2557, Train Accuracy: 64.31%
#     Worker 4: Train Loss: 1.2108, Train Accuracy: 65.57%
#     Worker 5: Train Loss: 1.2464, Train Accuracy: 64.50%
#     Worker 6: Train Loss: 1.2545, Train Accuracy: 64.14%
#     Worker 7: Train Loss: 1.2347, Train Accuracy: 65.31%
# Total Computation Time: 4454.23 seconds
# Total Communication Time: 0.62 seconds
# Epoch 136/150: Test Loss: 1.9355, Test Accuracy: 51.44%
#     Worker 0: Train Loss: 1.2626, Train Accuracy: 64.24%
#     Worker 1: Train Loss: 1.2316, Train Accuracy: 65.03%
#     Worker 2: Train Loss: 1.2163, Train Accuracy: 66.29%
#     Worker 3: Train Loss: 1.2435, Train Accuracy: 64.53%
#     Worker 4: Train Loss: 1.2132, Train Accuracy: 65.37%
#     Worker 5: Train Loss: 1.2289, Train Accuracy: 65.21%
#     Worker 6: Train Loss: 1.2713, Train Accuracy: 63.76%
#     Worker 7: Train Loss: 1.2325, Train Accuracy: 65.57%
# Total Computation Time: 4487.90 seconds
# Total Communication Time: 0.62 seconds
# Epoch 137/150: Test Loss: 1.9352, Test Accuracy: 51.41%
#     Worker 0: Train Loss: 1.2438, Train Accuracy: 64.97%
#     Worker 1: Train Loss: 1.2327, Train Accuracy: 64.52%
#     Worker 2: Train Loss: 1.2264, Train Accuracy: 64.58%
#     Worker 3: Train Loss: 1.2406, Train Accuracy: 64.77%
#     Worker 4: Train Loss: 1.2179, Train Accuracy: 65.14%
#     Worker 5: Train Loss: 1.2420, Train Accuracy: 65.50%
#     Worker 6: Train Loss: 1.2398, Train Accuracy: 64.65%
#     Worker 7: Train Loss: 1.2273, Train Accuracy: 64.71%
# Total Computation Time: 4521.01 seconds
# Total Communication Time: 0.63 seconds
# Epoch 138/150: Test Loss: 1.9358, Test Accuracy: 51.52%
#     Worker 0: Train Loss: 1.2370, Train Accuracy: 64.83%
#     Worker 1: Train Loss: 1.2205, Train Accuracy: 65.24%
#     Worker 2: Train Loss: 1.2364, Train Accuracy: 64.87%
#     Worker 3: Train Loss: 1.2563, Train Accuracy: 64.35%
#     Worker 4: Train Loss: 1.2145, Train Accuracy: 65.26%
#     Worker 5: Train Loss: 1.2331, Train Accuracy: 65.06%
#     Worker 6: Train Loss: 1.2707, Train Accuracy: 64.13%
#     Worker 7: Train Loss: 1.2434, Train Accuracy: 64.90%
# Total Computation Time: 4554.12 seconds
# Total Communication Time: 0.63 seconds
# Epoch 139/150: Test Loss: 1.9352, Test Accuracy: 51.49%
#     Worker 0: Train Loss: 1.2401, Train Accuracy: 65.06%
#     Worker 1: Train Loss: 1.2316, Train Accuracy: 64.54%
#     Worker 2: Train Loss: 1.2353, Train Accuracy: 65.28%
#     Worker 3: Train Loss: 1.2350, Train Accuracy: 64.82%
#     Worker 4: Train Loss: 1.2327, Train Accuracy: 65.01%
#     Worker 5: Train Loss: 1.2468, Train Accuracy: 64.75%
#     Worker 6: Train Loss: 1.2775, Train Accuracy: 63.88%
#     Worker 7: Train Loss: 1.2352, Train Accuracy: 65.13%
# Total Computation Time: 4586.64 seconds
# Total Communication Time: 0.64 seconds
# Epoch 140/150: Test Loss: 1.9354, Test Accuracy: 51.50%
#     Worker 0: Train Loss: 1.2410, Train Accuracy: 64.70%
#     Worker 1: Train Loss: 1.2115, Train Accuracy: 65.63%
#     Worker 2: Train Loss: 1.2021, Train Accuracy: 66.34%
#     Worker 3: Train Loss: 1.2572, Train Accuracy: 64.32%
#     Worker 4: Train Loss: 1.2031, Train Accuracy: 65.90%
#     Worker 5: Train Loss: 1.2184, Train Accuracy: 65.73%
#     Worker 6: Train Loss: 1.2462, Train Accuracy: 64.48%
#     Worker 7: Train Loss: 1.2423, Train Accuracy: 64.71%
# Total Computation Time: 4619.62 seconds
# Total Communication Time: 0.64 seconds
# Epoch 141/150: Test Loss: 1.9360, Test Accuracy: 51.45%
#     Worker 0: Train Loss: 1.2392, Train Accuracy: 64.24%
#     Worker 1: Train Loss: 1.2391, Train Accuracy: 64.73%
#     Worker 2: Train Loss: 1.2313, Train Accuracy: 65.19%
#     Worker 3: Train Loss: 1.2448, Train Accuracy: 64.94%
#     Worker 4: Train Loss: 1.2062, Train Accuracy: 65.38%
#     Worker 5: Train Loss: 1.2427, Train Accuracy: 64.65%
#     Worker 6: Train Loss: 1.2616, Train Accuracy: 64.36%
#     Worker 7: Train Loss: 1.2168, Train Accuracy: 65.44%
# Total Computation Time: 4653.55 seconds
# Total Communication Time: 0.64 seconds
# Epoch 142/150: Test Loss: 1.9355, Test Accuracy: 51.38%
#     Worker 0: Train Loss: 1.2443, Train Accuracy: 64.77%
#     Worker 1: Train Loss: 1.2138, Train Accuracy: 65.23%
#     Worker 2: Train Loss: 1.2253, Train Accuracy: 65.67%
#     Worker 3: Train Loss: 1.2473, Train Accuracy: 64.44%
#     Worker 4: Train Loss: 1.2292, Train Accuracy: 64.82%
#     Worker 5: Train Loss: 1.2232, Train Accuracy: 65.92%
#     Worker 6: Train Loss: 1.2527, Train Accuracy: 64.57%
#     Worker 7: Train Loss: 1.2414, Train Accuracy: 64.99%
# Total Computation Time: 4688.05 seconds
# Total Communication Time: 0.65 seconds
# Epoch 143/150: Test Loss: 1.9361, Test Accuracy: 51.49%
#     Worker 0: Train Loss: 1.2253, Train Accuracy: 64.93%
#     Worker 1: Train Loss: 1.2203, Train Accuracy: 64.97%
#     Worker 2: Train Loss: 1.2344, Train Accuracy: 66.46%
#     Worker 3: Train Loss: 1.2195, Train Accuracy: 65.67%
#     Worker 4: Train Loss: 1.2038, Train Accuracy: 65.65%
#     Worker 5: Train Loss: 1.2396, Train Accuracy: 65.30%
#     Worker 6: Train Loss: 1.2426, Train Accuracy: 64.42%
#     Worker 7: Train Loss: 1.2411, Train Accuracy: 65.07%
# Total Computation Time: 4721.75 seconds
# Total Communication Time: 0.65 seconds
# Epoch 144/150: Test Loss: 1.9365, Test Accuracy: 51.46%
#     Worker 0: Train Loss: 1.2629, Train Accuracy: 64.08%
#     Worker 1: Train Loss: 1.2078, Train Accuracy: 65.62%
#     Worker 2: Train Loss: 1.2223, Train Accuracy: 65.64%
#     Worker 3: Train Loss: 1.2504, Train Accuracy: 65.02%
#     Worker 4: Train Loss: 1.2181, Train Accuracy: 65.50%
#     Worker 5: Train Loss: 1.2294, Train Accuracy: 65.53%
#     Worker 6: Train Loss: 1.2598, Train Accuracy: 63.94%
#     Worker 7: Train Loss: 1.2305, Train Accuracy: 64.92%
# Total Computation Time: 4754.96 seconds
# Total Communication Time: 0.66 seconds
# Epoch 145/150: Test Loss: 1.9361, Test Accuracy: 51.45%
#     Worker 0: Train Loss: 1.2300, Train Accuracy: 64.63%
#     Worker 1: Train Loss: 1.2268, Train Accuracy: 64.74%
#     Worker 2: Train Loss: 1.2070, Train Accuracy: 65.90%
#     Worker 3: Train Loss: 1.2506, Train Accuracy: 64.97%
#     Worker 4: Train Loss: 1.2088, Train Accuracy: 65.23%
#     Worker 5: Train Loss: 1.2337, Train Accuracy: 65.48%
#     Worker 6: Train Loss: 1.2435, Train Accuracy: 64.72%
#     Worker 7: Train Loss: 1.2411, Train Accuracy: 64.58%
# Total Computation Time: 4787.40 seconds
# Total Communication Time: 0.66 seconds
# Epoch 146/150: Test Loss: 1.9363, Test Accuracy: 51.50%
#     Worker 0: Train Loss: 1.2410, Train Accuracy: 64.88%
#     Worker 1: Train Loss: 1.2434, Train Accuracy: 64.39%
#     Worker 2: Train Loss: 1.2227, Train Accuracy: 65.58%
#     Worker 3: Train Loss: 1.2555, Train Accuracy: 64.46%
#     Worker 4: Train Loss: 1.2206, Train Accuracy: 64.94%
#     Worker 5: Train Loss: 1.2319, Train Accuracy: 65.01%
#     Worker 6: Train Loss: 1.2776, Train Accuracy: 63.98%
#     Worker 7: Train Loss: 1.2362, Train Accuracy: 65.07%
# Total Computation Time: 4819.44 seconds
# Total Communication Time: 0.67 seconds
# Epoch 147/150: Test Loss: 1.9365, Test Accuracy: 51.50%
#     Worker 0: Train Loss: 1.2446, Train Accuracy: 64.86%
#     Worker 1: Train Loss: 1.2141, Train Accuracy: 65.41%
#     Worker 2: Train Loss: 1.2346, Train Accuracy: 64.86%
#     Worker 3: Train Loss: 1.2277, Train Accuracy: 65.56%
#     Worker 4: Train Loss: 1.2172, Train Accuracy: 65.50%
#     Worker 5: Train Loss: 1.2202, Train Accuracy: 65.78%
#     Worker 6: Train Loss: 1.2407, Train Accuracy: 65.44%
#     Worker 7: Train Loss: 1.2271, Train Accuracy: 65.16%
# Total Computation Time: 4853.15 seconds
# Total Communication Time: 0.67 seconds
# Epoch 148/150: Test Loss: 1.9365, Test Accuracy: 51.49%
#     Worker 0: Train Loss: 1.2611, Train Accuracy: 63.93%
#     Worker 1: Train Loss: 1.2311, Train Accuracy: 65.15%
#     Worker 2: Train Loss: 1.2272, Train Accuracy: 65.03%
#     Worker 3: Train Loss: 1.2513, Train Accuracy: 64.52%
#     Worker 4: Train Loss: 1.2123, Train Accuracy: 65.58%
#     Worker 5: Train Loss: 1.2428, Train Accuracy: 64.71%
#     Worker 6: Train Loss: 1.2594, Train Accuracy: 64.24%
#     Worker 7: Train Loss: 1.2382, Train Accuracy: 65.20%
# Total Computation Time: 4886.29 seconds
# Total Communication Time: 0.67 seconds
# Epoch 149/150: Test Loss: 1.9365, Test Accuracy: 51.47%
#     Worker 0: Train Loss: 1.2498, Train Accuracy: 64.35%
#     Worker 1: Train Loss: 1.2299, Train Accuracy: 64.97%
#     Worker 2: Train Loss: 1.2227, Train Accuracy: 65.31%
#     Worker 3: Train Loss: 1.2458, Train Accuracy: 64.41%
#     Worker 4: Train Loss: 1.2162, Train Accuracy: 65.40%
#     Worker 5: Train Loss: 1.2361, Train Accuracy: 65.39%
#     Worker 6: Train Loss: 1.2718, Train Accuracy: 64.12%
#     Worker 7: Train Loss: 1.2096, Train Accuracy: 65.65%
# Total Computation Time: 4919.29 seconds
# Total Communication Time: 0.68 seconds
# Epoch 150/150: Test Loss: 1.9365, Test Accuracy: 51.47%
#     Worker 0: Train Loss: 1.2528, Train Accuracy: 64.19%
#     Worker 1: Train Loss: 1.2009, Train Accuracy: 65.52%
#     Worker 2: Train Loss: 1.2151, Train Accuracy: 65.43%
#     Worker 3: Train Loss: 1.2430, Train Accuracy: 64.75%
#     Worker 4: Train Loss: 1.2280, Train Accuracy: 65.56%
#     Worker 5: Train Loss: 1.2336, Train Accuracy: 65.09%
#     Worker 6: Train Loss: 1.2651, Train Accuracy: 64.20%
#     Worker 7: Train Loss: 1.2381, Train Accuracy: 64.80%
# Total Computation Time: 4953.34 seconds
# Total Communication Time: 0.68 seconds
