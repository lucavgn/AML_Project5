# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs - warmup_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")

    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch):
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            # Perform J local step before synchronization
            for j in range(J):
                try:
                    # Get a batch from the current worker's shard using next()
                    images, labels = next(shard_iterators[k])
                    images, labels = images.to(device), labels.to(device)  # Move to device
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

                except StopIteration:
                    # If the iterator has exhausted the data, restart the iterator
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k]) # Resume from the next batch
                    images, labels = images.to(device), labels.to(device)
                    # Perform optimization step
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        # Perform model synchronization
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            # Update each worker model with the global parameters
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
        else:
            warmup_factor = (epoch + 1) / warmup_epochs
            lr = warmup_factor * learning_rate
            for optimizer in optimizers:
                for param_group in optimizer.param_groups:
                    param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 8 --j 16
# Out:
# Training with K=8, J=16
# Global iteration per epoch: 7
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:13<00:00, 12.8MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00800
# Epoch 1/150: Test Loss: 4.5651, Test Accuracy: 2.43%
#     Worker 0: Train Loss: 4.5974, Train Accuracy: 1.36%
#     Worker 1: Train Loss: 4.5960, Train Accuracy: 1.58%
#     Worker 2: Train Loss: 4.5970, Train Accuracy: 1.36%
#     Worker 3: Train Loss: 4.5946, Train Accuracy: 1.78%
#     Worker 4: Train Loss: 4.5958, Train Accuracy: 1.57%
#     Worker 5: Train Loss: 4.5926, Train Accuracy: 1.65%
#     Worker 6: Train Loss: 4.5967, Train Accuracy: 1.47%
#     Worker 7: Train Loss: 4.5951, Train Accuracy: 1.47%
# Epoch 2/150: Test Loss: 4.5010, Test Accuracy: 3.26%
#     Worker 0: Train Loss: 4.5469, Train Accuracy: 2.83%
#     Worker 1: Train Loss: 4.5435, Train Accuracy: 2.50%
#     Worker 2: Train Loss: 4.5469, Train Accuracy: 2.31%
#     Worker 3: Train Loss: 4.5446, Train Accuracy: 2.60%
#     Worker 4: Train Loss: 4.5399, Train Accuracy: 2.62%
#     Worker 5: Train Loss: 4.5371, Train Accuracy: 3.13%
#     Worker 6: Train Loss: 4.5437, Train Accuracy: 2.78%
#     Worker 7: Train Loss: 4.5380, Train Accuracy: 2.95%
# Epoch 3/150: Test Loss: 4.2420, Test Accuracy: 5.54%
#     Worker 0: Train Loss: 4.3951, Train Accuracy: 4.13%
#     Worker 1: Train Loss: 4.4010, Train Accuracy: 3.74%
#     Worker 2: Train Loss: 4.3966, Train Accuracy: 3.83%
#     Worker 3: Train Loss: 4.3982, Train Accuracy: 3.83%
#     Worker 4: Train Loss: 4.3814, Train Accuracy: 4.18%
#     Worker 5: Train Loss: 4.3822, Train Accuracy: 3.82%
#     Worker 6: Train Loss: 4.3983, Train Accuracy: 3.89%
#     Worker 7: Train Loss: 4.3925, Train Accuracy: 3.85%
# Epoch 4/150: Test Loss: 4.0669, Test Accuracy: 8.21%
#     Worker 0: Train Loss: 4.2039, Train Accuracy: 6.12%
#     Worker 1: Train Loss: 4.2149, Train Accuracy: 5.71%
#     Worker 2: Train Loss: 4.2134, Train Accuracy: 5.56%
#     Worker 3: Train Loss: 4.2254, Train Accuracy: 5.53%
#     Worker 4: Train Loss: 4.1894, Train Accuracy: 6.06%
#     Worker 5: Train Loss: 4.2003, Train Accuracy: 5.04%
#     Worker 6: Train Loss: 4.2197, Train Accuracy: 5.25%
#     Worker 7: Train Loss: 4.2215, Train Accuracy: 5.43%
# Epoch 5/150: Test Loss: 3.9508, Test Accuracy: 9.83%
#     Worker 0: Train Loss: 4.1003, Train Accuracy: 6.62%
#     Worker 1: Train Loss: 4.1039, Train Accuracy: 6.45%
#     Worker 2: Train Loss: 4.0906, Train Accuracy: 7.33%
#     Worker 3: Train Loss: 4.1074, Train Accuracy: 6.98%
#     Worker 4: Train Loss: 4.0544, Train Accuracy: 7.75%
#     Worker 5: Train Loss: 4.0584, Train Accuracy: 7.44%
#     Worker 6: Train Loss: 4.1072, Train Accuracy: 6.70%
#     Worker 7: Train Loss: 4.1063, Train Accuracy: 6.72%
# Epoch 6/150: Test Loss: 3.8230, Test Accuracy: 11.97%
#     Worker 0: Train Loss: 4.0069, Train Accuracy: 8.26%
#     Worker 1: Train Loss: 4.0126, Train Accuracy: 8.20%
#     Worker 2: Train Loss: 4.0039, Train Accuracy: 8.79%
#     Worker 3: Train Loss: 4.0179, Train Accuracy: 7.85%
#     Worker 4: Train Loss: 3.9707, Train Accuracy: 8.40%
#     Worker 5: Train Loss: 3.9755, Train Accuracy: 8.56%
#     Worker 6: Train Loss: 3.9950, Train Accuracy: 8.06%
#     Worker 7: Train Loss: 4.0046, Train Accuracy: 8.44%
# Epoch 7/150: Test Loss: 3.7021, Test Accuracy: 13.82%
#     Worker 0: Train Loss: 3.8718, Train Accuracy: 10.26%
#     Worker 1: Train Loss: 3.8910, Train Accuracy: 9.50%
#     Worker 2: Train Loss: 3.8700, Train Accuracy: 10.58%
#     Worker 3: Train Loss: 3.8946, Train Accuracy: 10.33%
#     Worker 4: Train Loss: 3.8561, Train Accuracy: 10.23%
#     Worker 5: Train Loss: 3.8416, Train Accuracy: 10.70%
#     Worker 6: Train Loss: 3.8981, Train Accuracy: 9.71%
#     Worker 7: Train Loss: 3.8846, Train Accuracy: 10.22%
# Epoch 8/150: Test Loss: 3.5999, Test Accuracy: 15.92%
#     Worker 0: Train Loss: 3.7744, Train Accuracy: 12.01%
#     Worker 1: Train Loss: 3.7797, Train Accuracy: 11.08%
#     Worker 2: Train Loss: 3.7748, Train Accuracy: 12.22%
#     Worker 3: Train Loss: 3.7955, Train Accuracy: 11.18%
#     Worker 4: Train Loss: 3.7250, Train Accuracy: 12.13%
#     Worker 5: Train Loss: 3.7488, Train Accuracy: 12.24%
#     Worker 6: Train Loss: 3.7881, Train Accuracy: 11.52%
#     Worker 7: Train Loss: 3.7716, Train Accuracy: 12.27%
# Epoch 9/150: Test Loss: 3.5306, Test Accuracy: 17.06%
#     Worker 0: Train Loss: 3.6774, Train Accuracy: 13.21%
#     Worker 1: Train Loss: 3.7053, Train Accuracy: 12.41%
#     Worker 2: Train Loss: 3.6733, Train Accuracy: 14.29%
#     Worker 3: Train Loss: 3.7045, Train Accuracy: 12.89%
#     Worker 4: Train Loss: 3.6480, Train Accuracy: 13.85%
#     Worker 5: Train Loss: 3.6370, Train Accuracy: 13.94%
#     Worker 6: Train Loss: 3.6838, Train Accuracy: 13.35%
#     Worker 7: Train Loss: 3.6956, Train Accuracy: 13.31%
# Epoch 10/150: Test Loss: 3.4479, Test Accuracy: 18.42%
#     Worker 0: Train Loss: 3.6363, Train Accuracy: 14.60%
#     Worker 1: Train Loss: 3.5986, Train Accuracy: 14.33%
#     Worker 2: Train Loss: 3.5947, Train Accuracy: 15.55%
#     Worker 3: Train Loss: 3.6388, Train Accuracy: 13.98%
#     Worker 4: Train Loss: 3.5637, Train Accuracy: 15.81%
#     Worker 5: Train Loss: 3.5839, Train Accuracy: 15.18%
#     Worker 6: Train Loss: 3.6375, Train Accuracy: 13.85%
#     Worker 7: Train Loss: 3.5874, Train Accuracy: 15.42%
# Epoch 11/150: Test Loss: 3.3569, Test Accuracy: 20.09%
#     Worker 0: Train Loss: 3.5128, Train Accuracy: 15.55%
#     Worker 1: Train Loss: 3.5256, Train Accuracy: 15.38%
#     Worker 2: Train Loss: 3.5207, Train Accuracy: 16.39%
#     Worker 3: Train Loss: 3.5788, Train Accuracy: 15.31%
#     Worker 4: Train Loss: 3.4927, Train Accuracy: 16.27%
#     Worker 5: Train Loss: 3.4680, Train Accuracy: 17.91%
#     Worker 6: Train Loss: 3.5367, Train Accuracy: 15.24%
#     Worker 7: Train Loss: 3.5434, Train Accuracy: 15.51%
# Epoch 12/150: Test Loss: 3.2924, Test Accuracy: 21.10%
#     Worker 0: Train Loss: 3.4703, Train Accuracy: 16.88%
#     Worker 1: Train Loss: 3.4555, Train Accuracy: 16.78%
#     Worker 2: Train Loss: 3.4719, Train Accuracy: 18.01%
#     Worker 3: Train Loss: 3.5126, Train Accuracy: 16.37%
#     Worker 4: Train Loss: 3.4364, Train Accuracy: 17.32%
#     Worker 5: Train Loss: 3.4272, Train Accuracy: 17.72%
#     Worker 6: Train Loss: 3.4710, Train Accuracy: 16.50%
#     Worker 7: Train Loss: 3.4796, Train Accuracy: 17.41%
# Epoch 13/150: Test Loss: 3.2317, Test Accuracy: 22.06%
#     Worker 0: Train Loss: 3.3916, Train Accuracy: 17.81%
#     Worker 1: Train Loss: 3.3921, Train Accuracy: 17.79%
#     Worker 2: Train Loss: 3.3866, Train Accuracy: 19.17%
#     Worker 3: Train Loss: 3.4176, Train Accuracy: 18.05%
#     Worker 4: Train Loss: 3.3306, Train Accuracy: 19.28%
#     Worker 5: Train Loss: 3.3530, Train Accuracy: 18.99%
#     Worker 6: Train Loss: 3.4144, Train Accuracy: 18.05%
#     Worker 7: Train Loss: 3.3925, Train Accuracy: 18.61%
# Epoch 14/150: Test Loss: 3.1521, Test Accuracy: 23.61%
#     Worker 0: Train Loss: 3.3534, Train Accuracy: 18.39%
#     Worker 1: Train Loss: 3.3311, Train Accuracy: 18.82%
#     Worker 2: Train Loss: 3.3299, Train Accuracy: 19.90%
#     Worker 3: Train Loss: 3.3836, Train Accuracy: 18.94%
#     Worker 4: Train Loss: 3.2892, Train Accuracy: 19.76%
#     Worker 5: Train Loss: 3.2773, Train Accuracy: 20.30%
#     Worker 6: Train Loss: 3.3674, Train Accuracy: 18.85%
#     Worker 7: Train Loss: 3.3379, Train Accuracy: 19.36%
# Epoch 15/150: Test Loss: 3.0900, Test Accuracy: 24.82%
#     Worker 0: Train Loss: 3.2816, Train Accuracy: 19.35%
#     Worker 1: Train Loss: 3.2693, Train Accuracy: 20.04%
#     Worker 2: Train Loss: 3.2650, Train Accuracy: 20.84%
#     Worker 3: Train Loss: 3.2838, Train Accuracy: 20.24%
#     Worker 4: Train Loss: 3.2467, Train Accuracy: 20.70%
#     Worker 5: Train Loss: 3.2359, Train Accuracy: 21.49%
#     Worker 6: Train Loss: 3.2787, Train Accuracy: 20.28%
#     Worker 7: Train Loss: 3.2545, Train Accuracy: 20.89%
# Epoch 16/150: Test Loss: 3.0367, Test Accuracy: 25.87%
#     Worker 0: Train Loss: 3.2226, Train Accuracy: 21.03%
#     Worker 1: Train Loss: 3.1898, Train Accuracy: 21.41%
#     Worker 2: Train Loss: 3.2157, Train Accuracy: 22.07%
#     Worker 3: Train Loss: 3.2343, Train Accuracy: 20.79%
#     Worker 4: Train Loss: 3.1874, Train Accuracy: 21.83%
#     Worker 5: Train Loss: 3.1848, Train Accuracy: 21.98%
#     Worker 6: Train Loss: 3.2496, Train Accuracy: 20.42%
#     Worker 7: Train Loss: 3.2080, Train Accuracy: 21.97%
# Epoch 17/150: Test Loss: 2.9949, Test Accuracy: 26.51%
#     Worker 0: Train Loss: 3.1956, Train Accuracy: 21.37%
#     Worker 1: Train Loss: 3.1450, Train Accuracy: 22.53%
#     Worker 2: Train Loss: 3.1367, Train Accuracy: 23.26%
#     Worker 3: Train Loss: 3.1816, Train Accuracy: 21.34%
#     Worker 4: Train Loss: 3.1327, Train Accuracy: 22.88%
#     Worker 5: Train Loss: 3.1112, Train Accuracy: 23.75%
#     Worker 6: Train Loss: 3.1973, Train Accuracy: 21.20%
#     Worker 7: Train Loss: 3.1825, Train Accuracy: 21.97%
# Epoch 18/150: Test Loss: 2.9379, Test Accuracy: 28.00%
#     Worker 0: Train Loss: 3.1274, Train Accuracy: 23.03%
#     Worker 1: Train Loss: 3.1083, Train Accuracy: 23.34%
#     Worker 2: Train Loss: 3.1202, Train Accuracy: 23.73%
#     Worker 3: Train Loss: 3.1482, Train Accuracy: 22.47%
#     Worker 4: Train Loss: 3.0588, Train Accuracy: 24.11%
#     Worker 5: Train Loss: 3.0880, Train Accuracy: 24.46%
#     Worker 6: Train Loss: 3.1284, Train Accuracy: 23.01%
#     Worker 7: Train Loss: 3.0942, Train Accuracy: 23.65%
# Epoch 19/150: Test Loss: 2.9224, Test Accuracy: 28.24%
#     Worker 0: Train Loss: 3.0651, Train Accuracy: 24.39%
#     Worker 1: Train Loss: 3.0314, Train Accuracy: 24.32%
#     Worker 2: Train Loss: 3.0941, Train Accuracy: 23.94%
#     Worker 3: Train Loss: 3.1177, Train Accuracy: 22.84%
#     Worker 4: Train Loss: 3.0638, Train Accuracy: 23.80%
#     Worker 5: Train Loss: 3.0329, Train Accuracy: 25.47%
#     Worker 6: Train Loss: 3.1128, Train Accuracy: 23.29%
#     Worker 7: Train Loss: 3.0686, Train Accuracy: 23.92%
# Epoch 20/150: Test Loss: 2.8335, Test Accuracy: 29.96%
#     Worker 0: Train Loss: 3.0041, Train Accuracy: 25.30%
#     Worker 1: Train Loss: 3.0183, Train Accuracy: 24.77%
#     Worker 2: Train Loss: 3.0157, Train Accuracy: 26.07%
#     Worker 3: Train Loss: 3.0532, Train Accuracy: 24.18%
#     Worker 4: Train Loss: 2.9824, Train Accuracy: 26.01%
#     Worker 5: Train Loss: 2.9785, Train Accuracy: 25.65%
#     Worker 6: Train Loss: 3.0322, Train Accuracy: 24.66%
#     Worker 7: Train Loss: 3.0176, Train Accuracy: 25.57%
# Epoch 21/150: Test Loss: 2.7903, Test Accuracy: 30.68%
#     Worker 0: Train Loss: 3.0043, Train Accuracy: 25.62%
#     Worker 1: Train Loss: 2.9760, Train Accuracy: 25.21%
#     Worker 2: Train Loss: 2.9645, Train Accuracy: 26.09%
#     Worker 3: Train Loss: 2.9929, Train Accuracy: 25.22%
#     Worker 4: Train Loss: 2.9450, Train Accuracy: 25.67%
#     Worker 5: Train Loss: 2.9121, Train Accuracy: 27.50%
#     Worker 6: Train Loss: 3.0051, Train Accuracy: 25.11%
#     Worker 7: Train Loss: 2.9711, Train Accuracy: 26.40%
# Epoch 22/150: Test Loss: 2.7588, Test Accuracy: 31.51%
#     Worker 0: Train Loss: 2.9393, Train Accuracy: 26.83%
#     Worker 1: Train Loss: 2.8926, Train Accuracy: 26.95%
#     Worker 2: Train Loss: 2.9287, Train Accuracy: 27.37%
#     Worker 3: Train Loss: 2.9652, Train Accuracy: 26.27%
#     Worker 4: Train Loss: 2.9078, Train Accuracy: 27.02%
#     Worker 5: Train Loss: 2.8654, Train Accuracy: 28.79%
#     Worker 6: Train Loss: 2.9498, Train Accuracy: 26.62%
#     Worker 7: Train Loss: 2.9430, Train Accuracy: 26.59%
# Epoch 23/150: Test Loss: 2.7057, Test Accuracy: 32.50%
#     Worker 0: Train Loss: 2.9077, Train Accuracy: 27.36%
#     Worker 1: Train Loss: 2.8859, Train Accuracy: 26.97%
#     Worker 2: Train Loss: 2.8937, Train Accuracy: 28.07%
#     Worker 3: Train Loss: 2.9035, Train Accuracy: 26.80%
#     Worker 4: Train Loss: 2.8450, Train Accuracy: 27.86%
#     Worker 5: Train Loss: 2.8267, Train Accuracy: 29.47%
#     Worker 6: Train Loss: 2.9178, Train Accuracy: 26.87%
#     Worker 7: Train Loss: 2.8823, Train Accuracy: 27.46%
# Epoch 24/150: Test Loss: 2.6898, Test Accuracy: 32.55%
#     Worker 0: Train Loss: 2.8808, Train Accuracy: 27.65%
#     Worker 1: Train Loss: 2.8255, Train Accuracy: 27.71%
#     Worker 2: Train Loss: 2.8185, Train Accuracy: 28.95%
#     Worker 3: Train Loss: 2.8932, Train Accuracy: 26.92%
#     Worker 4: Train Loss: 2.8227, Train Accuracy: 28.41%
#     Worker 5: Train Loss: 2.8194, Train Accuracy: 29.62%
#     Worker 6: Train Loss: 2.8810, Train Accuracy: 27.83%
#     Worker 7: Train Loss: 2.8370, Train Accuracy: 29.00%
# Epoch 25/150: Test Loss: 2.6206, Test Accuracy: 33.85%
#     Worker 0: Train Loss: 2.8125, Train Accuracy: 29.72%
#     Worker 1: Train Loss: 2.8001, Train Accuracy: 28.59%
#     Worker 2: Train Loss: 2.8146, Train Accuracy: 29.32%
#     Worker 3: Train Loss: 2.8122, Train Accuracy: 28.94%
#     Worker 4: Train Loss: 2.7669, Train Accuracy: 29.64%
#     Worker 5: Train Loss: 2.7403, Train Accuracy: 30.91%
#     Worker 6: Train Loss: 2.8100, Train Accuracy: 29.08%
#     Worker 7: Train Loss: 2.8116, Train Accuracy: 29.05%
# Epoch 26/150: Test Loss: 2.6071, Test Accuracy: 34.00%
#     Worker 0: Train Loss: 2.7846, Train Accuracy: 29.39%
#     Worker 1: Train Loss: 2.7608, Train Accuracy: 29.74%
#     Worker 2: Train Loss: 2.7692, Train Accuracy: 29.99%
#     Worker 3: Train Loss: 2.7997, Train Accuracy: 29.57%
#     Worker 4: Train Loss: 2.7327, Train Accuracy: 31.21%
#     Worker 5: Train Loss: 2.7550, Train Accuracy: 30.16%
#     Worker 6: Train Loss: 2.8010, Train Accuracy: 28.86%
#     Worker 7: Train Loss: 2.7481, Train Accuracy: 30.06%
# Epoch 27/150: Test Loss: 2.5557, Test Accuracy: 35.30%
#     Worker 0: Train Loss: 2.7482, Train Accuracy: 30.44%
#     Worker 1: Train Loss: 2.6942, Train Accuracy: 31.50%
#     Worker 2: Train Loss: 2.7126, Train Accuracy: 31.23%
#     Worker 3: Train Loss: 2.7487, Train Accuracy: 29.81%
#     Worker 4: Train Loss: 2.7128, Train Accuracy: 30.77%
#     Worker 5: Train Loss: 2.6916, Train Accuracy: 31.77%
#     Worker 6: Train Loss: 2.7363, Train Accuracy: 31.08%
#     Worker 7: Train Loss: 2.7209, Train Accuracy: 30.39%
# Epoch 28/150: Test Loss: 2.5218, Test Accuracy: 35.46%
#     Worker 0: Train Loss: 2.6887, Train Accuracy: 31.77%
#     Worker 1: Train Loss: 2.6633, Train Accuracy: 31.99%
#     Worker 2: Train Loss: 2.7006, Train Accuracy: 31.33%
#     Worker 3: Train Loss: 2.6990, Train Accuracy: 31.37%
#     Worker 4: Train Loss: 2.6510, Train Accuracy: 31.79%
#     Worker 5: Train Loss: 2.6402, Train Accuracy: 33.30%
#     Worker 6: Train Loss: 2.6973, Train Accuracy: 31.13%
#     Worker 7: Train Loss: 2.6626, Train Accuracy: 31.88%
# Epoch 29/150: Test Loss: 2.4911, Test Accuracy: 36.71%
#     Worker 0: Train Loss: 2.6363, Train Accuracy: 32.33%
#     Worker 1: Train Loss: 2.6446, Train Accuracy: 32.12%
#     Worker 2: Train Loss: 2.6353, Train Accuracy: 32.79%
#     Worker 3: Train Loss: 2.6746, Train Accuracy: 32.40%
#     Worker 4: Train Loss: 2.5832, Train Accuracy: 33.84%
#     Worker 5: Train Loss: 2.6433, Train Accuracy: 33.22%
#     Worker 6: Train Loss: 2.6564, Train Accuracy: 31.79%
#     Worker 7: Train Loss: 2.6334, Train Accuracy: 32.28%
# Epoch 30/150: Test Loss: 2.4678, Test Accuracy: 36.95%
#     Worker 0: Train Loss: 2.6779, Train Accuracy: 31.82%
#     Worker 1: Train Loss: 2.6250, Train Accuracy: 32.98%
#     Worker 2: Train Loss: 2.6255, Train Accuracy: 33.60%
#     Worker 3: Train Loss: 2.6446, Train Accuracy: 32.70%
#     Worker 4: Train Loss: 2.5920, Train Accuracy: 33.38%
#     Worker 5: Train Loss: 2.5540, Train Accuracy: 35.07%
#     Worker 6: Train Loss: 2.6261, Train Accuracy: 32.52%
#     Worker 7: Train Loss: 2.6410, Train Accuracy: 32.73%
# Epoch 31/150: Test Loss: 2.4413, Test Accuracy: 36.88%
#     Worker 0: Train Loss: 2.5971, Train Accuracy: 33.46%
#     Worker 1: Train Loss: 2.5322, Train Accuracy: 34.86%
#     Worker 2: Train Loss: 2.5728, Train Accuracy: 33.19%
#     Worker 3: Train Loss: 2.6018, Train Accuracy: 32.93%
#     Worker 4: Train Loss: 2.5179, Train Accuracy: 34.51%
#     Worker 5: Train Loss: 2.5664, Train Accuracy: 33.49%
#     Worker 6: Train Loss: 2.6211, Train Accuracy: 32.73%
#     Worker 7: Train Loss: 2.5698, Train Accuracy: 33.68%
# Epoch 32/150: Test Loss: 2.4167, Test Accuracy: 37.99%
#     Worker 0: Train Loss: 2.5468, Train Accuracy: 34.13%
#     Worker 1: Train Loss: 2.5297, Train Accuracy: 34.24%
#     Worker 2: Train Loss: 2.5501, Train Accuracy: 33.77%
#     Worker 3: Train Loss: 2.5986, Train Accuracy: 33.10%
#     Worker 4: Train Loss: 2.5094, Train Accuracy: 35.19%
#     Worker 5: Train Loss: 2.5640, Train Accuracy: 34.54%
#     Worker 6: Train Loss: 2.5561, Train Accuracy: 34.31%
#     Worker 7: Train Loss: 2.5529, Train Accuracy: 33.80%
# Epoch 33/150: Test Loss: 2.4043, Test Accuracy: 38.18%
#     Worker 0: Train Loss: 2.5388, Train Accuracy: 35.10%
#     Worker 1: Train Loss: 2.5260, Train Accuracy: 34.79%
#     Worker 2: Train Loss: 2.5229, Train Accuracy: 35.31%
#     Worker 3: Train Loss: 2.5593, Train Accuracy: 32.70%
#     Worker 4: Train Loss: 2.4816, Train Accuracy: 35.61%
#     Worker 5: Train Loss: 2.4810, Train Accuracy: 36.51%
#     Worker 6: Train Loss: 2.5504, Train Accuracy: 34.10%
#     Worker 7: Train Loss: 2.5183, Train Accuracy: 35.24%
# Epoch 34/150: Test Loss: 2.3820, Test Accuracy: 39.29%
#     Worker 0: Train Loss: 2.5145, Train Accuracy: 35.45%
#     Worker 1: Train Loss: 2.4616, Train Accuracy: 36.09%
#     Worker 2: Train Loss: 2.5040, Train Accuracy: 35.04%
#     Worker 3: Train Loss: 2.5298, Train Accuracy: 34.61%
#     Worker 4: Train Loss: 2.4678, Train Accuracy: 36.16%
#     Worker 5: Train Loss: 2.4817, Train Accuracy: 36.43%
#     Worker 6: Train Loss: 2.4848, Train Accuracy: 35.53%
#     Worker 7: Train Loss: 2.5097, Train Accuracy: 35.25%
# Epoch 35/150: Test Loss: 2.3554, Test Accuracy: 39.29%
#     Worker 0: Train Loss: 2.4698, Train Accuracy: 35.46%
#     Worker 1: Train Loss: 2.4781, Train Accuracy: 35.60%
#     Worker 2: Train Loss: 2.4682, Train Accuracy: 36.29%
#     Worker 3: Train Loss: 2.4859, Train Accuracy: 35.50%
#     Worker 4: Train Loss: 2.4600, Train Accuracy: 35.85%
#     Worker 5: Train Loss: 2.4823, Train Accuracy: 35.54%
#     Worker 6: Train Loss: 2.4812, Train Accuracy: 35.71%
#     Worker 7: Train Loss: 2.4678, Train Accuracy: 35.51%
# Epoch 36/150: Test Loss: 2.3213, Test Accuracy: 40.48%
#     Worker 0: Train Loss: 2.4608, Train Accuracy: 36.20%
#     Worker 1: Train Loss: 2.4143, Train Accuracy: 36.83%
#     Worker 2: Train Loss: 2.4401, Train Accuracy: 36.82%
#     Worker 3: Train Loss: 2.4656, Train Accuracy: 36.26%
#     Worker 4: Train Loss: 2.3933, Train Accuracy: 38.04%
#     Worker 5: Train Loss: 2.4486, Train Accuracy: 36.57%
#     Worker 6: Train Loss: 2.4794, Train Accuracy: 36.54%
#     Worker 7: Train Loss: 2.4327, Train Accuracy: 36.79%
# Epoch 37/150: Test Loss: 2.3117, Test Accuracy: 40.57%
#     Worker 0: Train Loss: 2.4259, Train Accuracy: 36.82%
#     Worker 1: Train Loss: 2.4168, Train Accuracy: 36.50%
#     Worker 2: Train Loss: 2.4239, Train Accuracy: 37.11%
#     Worker 3: Train Loss: 2.4353, Train Accuracy: 35.73%
#     Worker 4: Train Loss: 2.3587, Train Accuracy: 38.65%
#     Worker 5: Train Loss: 2.3714, Train Accuracy: 38.55%
#     Worker 6: Train Loss: 2.4204, Train Accuracy: 36.96%
#     Worker 7: Train Loss: 2.4115, Train Accuracy: 37.50%
# Epoch 38/150: Test Loss: 2.3090, Test Accuracy: 40.64%
#     Worker 0: Train Loss: 2.3927, Train Accuracy: 37.71%
#     Worker 1: Train Loss: 2.3184, Train Accuracy: 38.58%
#     Worker 2: Train Loss: 2.4107, Train Accuracy: 37.36%
#     Worker 3: Train Loss: 2.4282, Train Accuracy: 36.61%
#     Worker 4: Train Loss: 2.3722, Train Accuracy: 38.01%
#     Worker 5: Train Loss: 2.3833, Train Accuracy: 38.20%
#     Worker 6: Train Loss: 2.4108, Train Accuracy: 36.69%
#     Worker 7: Train Loss: 2.4005, Train Accuracy: 37.81%
# Epoch 39/150: Test Loss: 2.2737, Test Accuracy: 41.26%
#     Worker 0: Train Loss: 2.3800, Train Accuracy: 38.18%
#     Worker 1: Train Loss: 2.3933, Train Accuracy: 37.01%
#     Worker 2: Train Loss: 2.3713, Train Accuracy: 38.37%
#     Worker 3: Train Loss: 2.4251, Train Accuracy: 36.72%
#     Worker 4: Train Loss: 2.3320, Train Accuracy: 38.97%
#     Worker 5: Train Loss: 2.3422, Train Accuracy: 39.49%
#     Worker 6: Train Loss: 2.3928, Train Accuracy: 36.89%
#     Worker 7: Train Loss: 2.3628, Train Accuracy: 39.06%
# Epoch 40/150: Test Loss: 2.2701, Test Accuracy: 41.57%
#     Worker 0: Train Loss: 2.3862, Train Accuracy: 38.05%
#     Worker 1: Train Loss: 2.3221, Train Accuracy: 38.39%
#     Worker 2: Train Loss: 2.3744, Train Accuracy: 38.71%
#     Worker 3: Train Loss: 2.3782, Train Accuracy: 37.59%
#     Worker 4: Train Loss: 2.3178, Train Accuracy: 38.73%
#     Worker 5: Train Loss: 2.2979, Train Accuracy: 40.18%
#     Worker 6: Train Loss: 2.3354, Train Accuracy: 38.76%
#     Worker 7: Train Loss: 2.3139, Train Accuracy: 39.73%
# Epoch 41/150: Test Loss: 2.2464, Test Accuracy: 41.88%
#     Worker 0: Train Loss: 2.3294, Train Accuracy: 38.96%
#     Worker 1: Train Loss: 2.3115, Train Accuracy: 38.83%
#     Worker 2: Train Loss: 2.3069, Train Accuracy: 39.85%
#     Worker 3: Train Loss: 2.3523, Train Accuracy: 37.43%
#     Worker 4: Train Loss: 2.2995, Train Accuracy: 39.42%
#     Worker 5: Train Loss: 2.2977, Train Accuracy: 40.47%
#     Worker 6: Train Loss: 2.3588, Train Accuracy: 38.68%
#     Worker 7: Train Loss: 2.3173, Train Accuracy: 39.70%
# Epoch 42/150: Test Loss: 2.2367, Test Accuracy: 42.20%
#     Worker 0: Train Loss: 2.3173, Train Accuracy: 39.50%
#     Worker 1: Train Loss: 2.2796, Train Accuracy: 39.71%
#     Worker 2: Train Loss: 2.3269, Train Accuracy: 38.85%
#     Worker 3: Train Loss: 2.3144, Train Accuracy: 39.46%
#     Worker 4: Train Loss: 2.2716, Train Accuracy: 40.06%
#     Worker 5: Train Loss: 2.2922, Train Accuracy: 40.16%
#     Worker 6: Train Loss: 2.3041, Train Accuracy: 39.37%
#     Worker 7: Train Loss: 2.3155, Train Accuracy: 38.88%
# Epoch 43/150: Test Loss: 2.2237, Test Accuracy: 42.35%
#     Worker 0: Train Loss: 2.3070, Train Accuracy: 39.48%
#     Worker 1: Train Loss: 2.2591, Train Accuracy: 40.15%
#     Worker 2: Train Loss: 2.2638, Train Accuracy: 40.55%
#     Worker 3: Train Loss: 2.2833, Train Accuracy: 39.42%
#     Worker 4: Train Loss: 2.2725, Train Accuracy: 40.71%
#     Worker 5: Train Loss: 2.2500, Train Accuracy: 41.09%
#     Worker 6: Train Loss: 2.2941, Train Accuracy: 39.73%
#     Worker 7: Train Loss: 2.2657, Train Accuracy: 40.27%
# Epoch 44/150: Test Loss: 2.2187, Test Accuracy: 42.88%
#     Worker 0: Train Loss: 2.2696, Train Accuracy: 40.13%
#     Worker 1: Train Loss: 2.2097, Train Accuracy: 41.56%
#     Worker 2: Train Loss: 2.2717, Train Accuracy: 40.47%
#     Worker 3: Train Loss: 2.2623, Train Accuracy: 40.60%
#     Worker 4: Train Loss: 2.2023, Train Accuracy: 41.97%
#     Worker 5: Train Loss: 2.2458, Train Accuracy: 40.96%
#     Worker 6: Train Loss: 2.2660, Train Accuracy: 40.96%
#     Worker 7: Train Loss: 2.2544, Train Accuracy: 40.50%
# Epoch 45/150: Test Loss: 2.2018, Test Accuracy: 42.76%
#     Worker 0: Train Loss: 2.2418, Train Accuracy: 40.41%
#     Worker 1: Train Loss: 2.2365, Train Accuracy: 40.89%
#     Worker 2: Train Loss: 2.2350, Train Accuracy: 41.70%
#     Worker 3: Train Loss: 2.2793, Train Accuracy: 40.30%
#     Worker 4: Train Loss: 2.2334, Train Accuracy: 40.71%
#     Worker 5: Train Loss: 2.2027, Train Accuracy: 42.50%
#     Worker 6: Train Loss: 2.2502, Train Accuracy: 40.69%
#     Worker 7: Train Loss: 2.2359, Train Accuracy: 41.24%
# Epoch 46/150: Test Loss: 2.1724, Test Accuracy: 43.70%
#     Worker 0: Train Loss: 2.2300, Train Accuracy: 40.47%
#     Worker 1: Train Loss: 2.2170, Train Accuracy: 40.54%
#     Worker 2: Train Loss: 2.1915, Train Accuracy: 42.57%
#     Worker 3: Train Loss: 2.2496, Train Accuracy: 40.76%
#     Worker 4: Train Loss: 2.1941, Train Accuracy: 41.80%
#     Worker 5: Train Loss: 2.1882, Train Accuracy: 42.64%
#     Worker 6: Train Loss: 2.2560, Train Accuracy: 40.57%
#     Worker 7: Train Loss: 2.1979, Train Accuracy: 41.94%
# Epoch 47/150: Test Loss: 2.1708, Test Accuracy: 43.91%
#     Worker 0: Train Loss: 2.2092, Train Accuracy: 41.31%
#     Worker 1: Train Loss: 2.1802, Train Accuracy: 41.66%
#     Worker 2: Train Loss: 2.1699, Train Accuracy: 41.67%
#     Worker 3: Train Loss: 2.2007, Train Accuracy: 41.28%
#     Worker 4: Train Loss: 2.1505, Train Accuracy: 43.13%
#     Worker 5: Train Loss: 2.1831, Train Accuracy: 42.60%
#     Worker 6: Train Loss: 2.2043, Train Accuracy: 41.90%
#     Worker 7: Train Loss: 2.1987, Train Accuracy: 41.77%
# Epoch 48/150: Test Loss: 2.1584, Test Accuracy: 43.69%
#     Worker 0: Train Loss: 2.1774, Train Accuracy: 42.18%
#     Worker 1: Train Loss: 2.1577, Train Accuracy: 42.36%
#     Worker 2: Train Loss: 2.1492, Train Accuracy: 42.58%
#     Worker 3: Train Loss: 2.1796, Train Accuracy: 42.51%
#     Worker 4: Train Loss: 2.1743, Train Accuracy: 42.29%
#     Worker 5: Train Loss: 2.1520, Train Accuracy: 42.58%
#     Worker 6: Train Loss: 2.2155, Train Accuracy: 41.34%
#     Worker 7: Train Loss: 2.1818, Train Accuracy: 42.42%
# Epoch 49/150: Test Loss: 2.1522, Test Accuracy: 43.99%
#     Worker 0: Train Loss: 2.1719, Train Accuracy: 42.32%
#     Worker 1: Train Loss: 2.1277, Train Accuracy: 43.05%
#     Worker 2: Train Loss: 2.1670, Train Accuracy: 42.49%
#     Worker 3: Train Loss: 2.1948, Train Accuracy: 42.27%
#     Worker 4: Train Loss: 2.1188, Train Accuracy: 43.84%
#     Worker 5: Train Loss: 2.1509, Train Accuracy: 42.80%
#     Worker 6: Train Loss: 2.1671, Train Accuracy: 42.93%
#     Worker 7: Train Loss: 2.1368, Train Accuracy: 42.67%
# Epoch 50/150: Test Loss: 2.1238, Test Accuracy: 44.88%
#     Worker 0: Train Loss: 2.1520, Train Accuracy: 42.74%
#     Worker 1: Train Loss: 2.1195, Train Accuracy: 43.07%
#     Worker 2: Train Loss: 2.1373, Train Accuracy: 43.73%
#     Worker 3: Train Loss: 2.1618, Train Accuracy: 42.56%
#     Worker 4: Train Loss: 2.1151, Train Accuracy: 43.10%
#     Worker 5: Train Loss: 2.1165, Train Accuracy: 44.00%
#     Worker 6: Train Loss: 2.1572, Train Accuracy: 43.12%
#     Worker 7: Train Loss: 2.1504, Train Accuracy: 43.48%
# Epoch 51/150: Test Loss: 2.1302, Test Accuracy: 44.67%
#     Worker 0: Train Loss: 2.1363, Train Accuracy: 42.91%
#     Worker 1: Train Loss: 2.0862, Train Accuracy: 44.44%
#     Worker 2: Train Loss: 2.1224, Train Accuracy: 43.37%
#     Worker 3: Train Loss: 2.1468, Train Accuracy: 42.82%
#     Worker 4: Train Loss: 2.0861, Train Accuracy: 43.94%
#     Worker 5: Train Loss: 2.1053, Train Accuracy: 43.39%
#     Worker 6: Train Loss: 2.1287, Train Accuracy: 43.95%
#     Worker 7: Train Loss: 2.1053, Train Accuracy: 42.89%
# Epoch 52/150: Test Loss: 2.1223, Test Accuracy: 44.56%
#     Worker 0: Train Loss: 2.1028, Train Accuracy: 42.91%
#     Worker 1: Train Loss: 2.0799, Train Accuracy: 44.26%
#     Worker 2: Train Loss: 2.1007, Train Accuracy: 44.21%
#     Worker 3: Train Loss: 2.1425, Train Accuracy: 42.92%
#     Worker 4: Train Loss: 2.1038, Train Accuracy: 43.98%
#     Worker 5: Train Loss: 2.1074, Train Accuracy: 43.79%
#     Worker 6: Train Loss: 2.1021, Train Accuracy: 44.01%
#     Worker 7: Train Loss: 2.1019, Train Accuracy: 43.06%
# Epoch 53/150: Test Loss: 2.1108, Test Accuracy: 45.02%
#     Worker 0: Train Loss: 2.1099, Train Accuracy: 43.25%
#     Worker 1: Train Loss: 2.0384, Train Accuracy: 45.76%
#     Worker 2: Train Loss: 2.0878, Train Accuracy: 44.42%
#     Worker 3: Train Loss: 2.0941, Train Accuracy: 43.77%
#     Worker 4: Train Loss: 2.0612, Train Accuracy: 44.64%
#     Worker 5: Train Loss: 2.0464, Train Accuracy: 45.45%
#     Worker 6: Train Loss: 2.1027, Train Accuracy: 43.93%
#     Worker 7: Train Loss: 2.0701, Train Accuracy: 44.91%
# Epoch 54/150: Test Loss: 2.1013, Test Accuracy: 45.52%
#     Worker 0: Train Loss: 2.0834, Train Accuracy: 43.65%
#     Worker 1: Train Loss: 2.0418, Train Accuracy: 45.19%
#     Worker 2: Train Loss: 2.0499, Train Accuracy: 44.95%
#     Worker 3: Train Loss: 2.1053, Train Accuracy: 43.63%
#     Worker 4: Train Loss: 2.0034, Train Accuracy: 45.63%
#     Worker 5: Train Loss: 2.0838, Train Accuracy: 44.72%
#     Worker 6: Train Loss: 2.0872, Train Accuracy: 43.73%
#     Worker 7: Train Loss: 2.0791, Train Accuracy: 44.35%
# Epoch 55/150: Test Loss: 2.0980, Test Accuracy: 45.69%
#     Worker 0: Train Loss: 2.0594, Train Accuracy: 44.58%
#     Worker 1: Train Loss: 2.0308, Train Accuracy: 44.99%
#     Worker 2: Train Loss: 2.0363, Train Accuracy: 45.98%
#     Worker 3: Train Loss: 2.0718, Train Accuracy: 44.11%
#     Worker 4: Train Loss: 2.0511, Train Accuracy: 44.53%
#     Worker 5: Train Loss: 2.0543, Train Accuracy: 45.24%
#     Worker 6: Train Loss: 2.0603, Train Accuracy: 44.92%
#     Worker 7: Train Loss: 2.0259, Train Accuracy: 45.84%
# Epoch 56/150: Test Loss: 2.0856, Test Accuracy: 45.76%
#     Worker 0: Train Loss: 2.0437, Train Accuracy: 45.07%
#     Worker 1: Train Loss: 1.9987, Train Accuracy: 45.79%
#     Worker 2: Train Loss: 2.0324, Train Accuracy: 44.97%
#     Worker 3: Train Loss: 2.0528, Train Accuracy: 45.61%
#     Worker 4: Train Loss: 2.0134, Train Accuracy: 45.33%
#     Worker 5: Train Loss: 2.0165, Train Accuracy: 46.25%
#     Worker 6: Train Loss: 2.0562, Train Accuracy: 44.95%
#     Worker 7: Train Loss: 2.0198, Train Accuracy: 46.13%
# Epoch 57/150: Test Loss: 2.0871, Test Accuracy: 45.69%
#     Worker 0: Train Loss: 2.0341, Train Accuracy: 45.24%
#     Worker 1: Train Loss: 1.9802, Train Accuracy: 45.63%
#     Worker 2: Train Loss: 2.0068, Train Accuracy: 46.36%
#     Worker 3: Train Loss: 2.0142, Train Accuracy: 45.65%
#     Worker 4: Train Loss: 1.9656, Train Accuracy: 46.59%
#     Worker 5: Train Loss: 1.9872, Train Accuracy: 47.13%
#     Worker 6: Train Loss: 2.0199, Train Accuracy: 45.83%
#     Worker 7: Train Loss: 2.0083, Train Accuracy: 46.19%
# Epoch 58/150: Test Loss: 2.0734, Test Accuracy: 46.15%
#     Worker 0: Train Loss: 1.9937, Train Accuracy: 45.54%
#     Worker 1: Train Loss: 1.9755, Train Accuracy: 46.38%
#     Worker 2: Train Loss: 1.9979, Train Accuracy: 46.38%
#     Worker 3: Train Loss: 2.0188, Train Accuracy: 45.76%
#     Worker 4: Train Loss: 1.9781, Train Accuracy: 46.85%
#     Worker 5: Train Loss: 2.0020, Train Accuracy: 46.73%
#     Worker 6: Train Loss: 2.0218, Train Accuracy: 45.59%
#     Worker 7: Train Loss: 2.0054, Train Accuracy: 46.68%
# Epoch 59/150: Test Loss: 2.0626, Test Accuracy: 46.27%
#     Worker 0: Train Loss: 1.9985, Train Accuracy: 45.80%
#     Worker 1: Train Loss: 1.9604, Train Accuracy: 47.33%
#     Worker 2: Train Loss: 1.9812, Train Accuracy: 46.32%
#     Worker 3: Train Loss: 1.9966, Train Accuracy: 46.36%
#     Worker 4: Train Loss: 1.9745, Train Accuracy: 47.23%
#     Worker 5: Train Loss: 1.9778, Train Accuracy: 47.13%
#     Worker 6: Train Loss: 2.0193, Train Accuracy: 45.80%
#     Worker 7: Train Loss: 1.9928, Train Accuracy: 45.28%
# Epoch 60/150: Test Loss: 2.0659, Test Accuracy: 46.02%
#     Worker 0: Train Loss: 1.9543, Train Accuracy: 47.54%
#     Worker 1: Train Loss: 1.9675, Train Accuracy: 46.29%
#     Worker 2: Train Loss: 1.9615, Train Accuracy: 47.62%
#     Worker 3: Train Loss: 1.9358, Train Accuracy: 47.44%
#     Worker 4: Train Loss: 1.9213, Train Accuracy: 47.98%
#     Worker 5: Train Loss: 1.9450, Train Accuracy: 48.12%
#     Worker 6: Train Loss: 1.9904, Train Accuracy: 46.47%
#     Worker 7: Train Loss: 1.9529, Train Accuracy: 47.51%
# Epoch 61/150: Test Loss: 2.0541, Test Accuracy: 46.92%
#     Worker 0: Train Loss: 1.9836, Train Accuracy: 46.00%
#     Worker 1: Train Loss: 1.9055, Train Accuracy: 47.77%
#     Worker 2: Train Loss: 1.9286, Train Accuracy: 47.75%
#     Worker 3: Train Loss: 1.9515, Train Accuracy: 47.02%
#     Worker 4: Train Loss: 1.9426, Train Accuracy: 47.37%
#     Worker 5: Train Loss: 1.9398, Train Accuracy: 47.87%
#     Worker 6: Train Loss: 1.9727, Train Accuracy: 47.24%
#     Worker 7: Train Loss: 1.9591, Train Accuracy: 46.73%
# Epoch 62/150: Test Loss: 2.0490, Test Accuracy: 46.70%
#     Worker 0: Train Loss: 1.9500, Train Accuracy: 47.17%
#     Worker 1: Train Loss: 1.9217, Train Accuracy: 48.10%
#     Worker 2: Train Loss: 1.9409, Train Accuracy: 47.89%
#     Worker 3: Train Loss: 1.9557, Train Accuracy: 46.98%
#     Worker 4: Train Loss: 1.9375, Train Accuracy: 47.80%
#     Worker 5: Train Loss: 1.9351, Train Accuracy: 48.31%
#     Worker 6: Train Loss: 1.9312, Train Accuracy: 48.04%
#     Worker 7: Train Loss: 1.9288, Train Accuracy: 47.76%
# Epoch 63/150: Test Loss: 2.0460, Test Accuracy: 46.58%
#     Worker 0: Train Loss: 1.9260, Train Accuracy: 47.94%
#     Worker 1: Train Loss: 1.9006, Train Accuracy: 48.15%
#     Worker 2: Train Loss: 1.9067, Train Accuracy: 48.29%
#     Worker 3: Train Loss: 1.9522, Train Accuracy: 47.38%
#     Worker 4: Train Loss: 1.8905, Train Accuracy: 48.86%
#     Worker 5: Train Loss: 1.9453, Train Accuracy: 47.26%
#     Worker 6: Train Loss: 1.9581, Train Accuracy: 46.57%
#     Worker 7: Train Loss: 1.9245, Train Accuracy: 47.53%
# Epoch 64/150: Test Loss: 2.0302, Test Accuracy: 46.86%
#     Worker 0: Train Loss: 1.9152, Train Accuracy: 47.69%
#     Worker 1: Train Loss: 1.8717, Train Accuracy: 48.52%
#     Worker 2: Train Loss: 1.8857, Train Accuracy: 48.50%
#     Worker 3: Train Loss: 1.9329, Train Accuracy: 47.66%
#     Worker 4: Train Loss: 1.9013, Train Accuracy: 47.91%
#     Worker 5: Train Loss: 1.9122, Train Accuracy: 48.54%
#     Worker 6: Train Loss: 1.8844, Train Accuracy: 49.16%
#     Worker 7: Train Loss: 1.9005, Train Accuracy: 48.33%
# Epoch 65/150: Test Loss: 2.0220, Test Accuracy: 47.27%
#     Worker 0: Train Loss: 1.9114, Train Accuracy: 48.01%
#     Worker 1: Train Loss: 1.8708, Train Accuracy: 49.12%
#     Worker 2: Train Loss: 1.8692, Train Accuracy: 49.06%
#     Worker 3: Train Loss: 1.8849, Train Accuracy: 49.05%
#     Worker 4: Train Loss: 1.8603, Train Accuracy: 48.43%
#     Worker 5: Train Loss: 1.8746, Train Accuracy: 49.36%
#     Worker 6: Train Loss: 1.9061, Train Accuracy: 48.53%
#     Worker 7: Train Loss: 1.8901, Train Accuracy: 49.05%
# Epoch 66/150: Test Loss: 2.0225, Test Accuracy: 47.14%
#     Worker 0: Train Loss: 1.8825, Train Accuracy: 48.25%
#     Worker 1: Train Loss: 1.8718, Train Accuracy: 47.62%
#     Worker 2: Train Loss: 1.8678, Train Accuracy: 49.16%
#     Worker 3: Train Loss: 1.8779, Train Accuracy: 48.78%
#     Worker 4: Train Loss: 1.8556, Train Accuracy: 49.26%
#     Worker 5: Train Loss: 1.8566, Train Accuracy: 49.80%
#     Worker 6: Train Loss: 1.9085, Train Accuracy: 48.01%
#     Worker 7: Train Loss: 1.8747, Train Accuracy: 49.06%
# Epoch 67/150: Test Loss: 2.0263, Test Accuracy: 47.04%
#     Worker 0: Train Loss: 1.8830, Train Accuracy: 49.08%
#     Worker 1: Train Loss: 1.8328, Train Accuracy: 49.89%
#     Worker 2: Train Loss: 1.8568, Train Accuracy: 49.90%
#     Worker 3: Train Loss: 1.8659, Train Accuracy: 49.10%
#     Worker 4: Train Loss: 1.8154, Train Accuracy: 50.48%
#     Worker 5: Train Loss: 1.8629, Train Accuracy: 49.71%
#     Worker 6: Train Loss: 1.8860, Train Accuracy: 48.61%
#     Worker 7: Train Loss: 1.8582, Train Accuracy: 49.41%
# Epoch 68/150: Test Loss: 2.0159, Test Accuracy: 47.62%
#     Worker 0: Train Loss: 1.8359, Train Accuracy: 48.87%
#     Worker 1: Train Loss: 1.8002, Train Accuracy: 50.42%
#     Worker 2: Train Loss: 1.8263, Train Accuracy: 50.17%
#     Worker 3: Train Loss: 1.8432, Train Accuracy: 49.43%
#     Worker 4: Train Loss: 1.8605, Train Accuracy: 49.82%
#     Worker 5: Train Loss: 1.8100, Train Accuracy: 50.59%
#     Worker 6: Train Loss: 1.8429, Train Accuracy: 49.71%
#     Worker 7: Train Loss: 1.8300, Train Accuracy: 50.35%
# Epoch 69/150: Test Loss: 2.0058, Test Accuracy: 47.07%
#     Worker 0: Train Loss: 1.8429, Train Accuracy: 49.34%
#     Worker 1: Train Loss: 1.8128, Train Accuracy: 50.50%
#     Worker 2: Train Loss: 1.8430, Train Accuracy: 49.44%
#     Worker 3: Train Loss: 1.8453, Train Accuracy: 49.48%
#     Worker 4: Train Loss: 1.7950, Train Accuracy: 51.15%
#     Worker 5: Train Loss: 1.8333, Train Accuracy: 50.71%
#     Worker 6: Train Loss: 1.8586, Train Accuracy: 49.71%
#     Worker 7: Train Loss: 1.8312, Train Accuracy: 50.27%
# Epoch 70/150: Test Loss: 2.0076, Test Accuracy: 47.67%
#     Worker 0: Train Loss: 1.8292, Train Accuracy: 49.83%
#     Worker 1: Train Loss: 1.7920, Train Accuracy: 51.56%
#     Worker 2: Train Loss: 1.8009, Train Accuracy: 50.90%
#     Worker 3: Train Loss: 1.8363, Train Accuracy: 49.71%
#     Worker 4: Train Loss: 1.7977, Train Accuracy: 50.74%
#     Worker 5: Train Loss: 1.8200, Train Accuracy: 50.62%
#     Worker 6: Train Loss: 1.8336, Train Accuracy: 49.97%
#     Worker 7: Train Loss: 1.8061, Train Accuracy: 50.44%
# Epoch 71/150: Test Loss: 1.9959, Test Accuracy: 47.86%
#     Worker 0: Train Loss: 1.8059, Train Accuracy: 50.14%
#     Worker 1: Train Loss: 1.7843, Train Accuracy: 51.23%
#     Worker 2: Train Loss: 1.7772, Train Accuracy: 51.20%
#     Worker 3: Train Loss: 1.8309, Train Accuracy: 50.74%
#     Worker 4: Train Loss: 1.8076, Train Accuracy: 50.31%
#     Worker 5: Train Loss: 1.8072, Train Accuracy: 50.71%
#     Worker 6: Train Loss: 1.8048, Train Accuracy: 50.56%
#     Worker 7: Train Loss: 1.7898, Train Accuracy: 50.64%
# Epoch 72/150: Test Loss: 1.9957, Test Accuracy: 47.84%
#     Worker 0: Train Loss: 1.8181, Train Accuracy: 51.26%
#     Worker 1: Train Loss: 1.7829, Train Accuracy: 50.87%
#     Worker 2: Train Loss: 1.7801, Train Accuracy: 51.25%
#     Worker 3: Train Loss: 1.8138, Train Accuracy: 50.78%
#     Worker 4: Train Loss: 1.7695, Train Accuracy: 51.72%
#     Worker 5: Train Loss: 1.7798, Train Accuracy: 51.78%
#     Worker 6: Train Loss: 1.8049, Train Accuracy: 50.21%
#     Worker 7: Train Loss: 1.7902, Train Accuracy: 50.56%
# Epoch 73/150: Test Loss: 2.0074, Test Accuracy: 47.90%
#     Worker 0: Train Loss: 1.7866, Train Accuracy: 50.69%
#     Worker 1: Train Loss: 1.7484, Train Accuracy: 52.78%
#     Worker 2: Train Loss: 1.7731, Train Accuracy: 51.78%
#     Worker 3: Train Loss: 1.7856, Train Accuracy: 50.60%
#     Worker 4: Train Loss: 1.7746, Train Accuracy: 50.97%
#     Worker 5: Train Loss: 1.7879, Train Accuracy: 51.30%
#     Worker 6: Train Loss: 1.7855, Train Accuracy: 50.87%
#     Worker 7: Train Loss: 1.7417, Train Accuracy: 51.67%
# Epoch 74/150: Test Loss: 1.9928, Test Accuracy: 47.95%
#     Worker 0: Train Loss: 1.7858, Train Accuracy: 50.38%
#     Worker 1: Train Loss: 1.7452, Train Accuracy: 52.64%
#     Worker 2: Train Loss: 1.7734, Train Accuracy: 51.18%
#     Worker 3: Train Loss: 1.7618, Train Accuracy: 51.55%
#     Worker 4: Train Loss: 1.7556, Train Accuracy: 51.81%
#     Worker 5: Train Loss: 1.7561, Train Accuracy: 52.00%
#     Worker 6: Train Loss: 1.7732, Train Accuracy: 51.82%
#     Worker 7: Train Loss: 1.7674, Train Accuracy: 51.13%
# Epoch 75/150: Test Loss: 1.9898, Test Accuracy: 47.98%
#     Worker 0: Train Loss: 1.7410, Train Accuracy: 51.30%
#     Worker 1: Train Loss: 1.7043, Train Accuracy: 52.95%
#     Worker 2: Train Loss: 1.7499, Train Accuracy: 51.55%
#     Worker 3: Train Loss: 1.7791, Train Accuracy: 51.01%
#     Worker 4: Train Loss: 1.7408, Train Accuracy: 51.99%
#     Worker 5: Train Loss: 1.7339, Train Accuracy: 52.46%
#     Worker 6: Train Loss: 1.7597, Train Accuracy: 52.10%
#     Worker 7: Train Loss: 1.7686, Train Accuracy: 51.11%
# Epoch 76/150: Test Loss: 1.9812, Test Accuracy: 48.39%
#     Worker 0: Train Loss: 1.7438, Train Accuracy: 51.89%
#     Worker 1: Train Loss: 1.6931, Train Accuracy: 52.63%
#     Worker 2: Train Loss: 1.7169, Train Accuracy: 52.88%
#     Worker 3: Train Loss: 1.7516, Train Accuracy: 51.72%
#     Worker 4: Train Loss: 1.7145, Train Accuracy: 52.92%
#     Worker 5: Train Loss: 1.7200, Train Accuracy: 53.34%
#     Worker 6: Train Loss: 1.7530, Train Accuracy: 52.00%
#     Worker 7: Train Loss: 1.7548, Train Accuracy: 51.58%
# Epoch 77/150: Test Loss: 1.9909, Test Accuracy: 48.17%
#     Worker 0: Train Loss: 1.7357, Train Accuracy: 52.62%
#     Worker 1: Train Loss: 1.7225, Train Accuracy: 52.30%
#     Worker 2: Train Loss: 1.7284, Train Accuracy: 52.20%
#     Worker 3: Train Loss: 1.7355, Train Accuracy: 52.19%
#     Worker 4: Train Loss: 1.7097, Train Accuracy: 52.79%
#     Worker 5: Train Loss: 1.7201, Train Accuracy: 53.07%
#     Worker 6: Train Loss: 1.7481, Train Accuracy: 52.22%
#     Worker 7: Train Loss: 1.7383, Train Accuracy: 51.94%
# Epoch 78/150: Test Loss: 1.9783, Test Accuracy: 48.25%
#     Worker 0: Train Loss: 1.7138, Train Accuracy: 52.43%
#     Worker 1: Train Loss: 1.6801, Train Accuracy: 52.88%
#     Worker 2: Train Loss: 1.6986, Train Accuracy: 53.44%
#     Worker 3: Train Loss: 1.7115, Train Accuracy: 52.50%
#     Worker 4: Train Loss: 1.6598, Train Accuracy: 54.07%
#     Worker 5: Train Loss: 1.7039, Train Accuracy: 53.37%
#     Worker 6: Train Loss: 1.7278, Train Accuracy: 53.09%
#     Worker 7: Train Loss: 1.7052, Train Accuracy: 52.78%
# Epoch 79/150: Test Loss: 1.9746, Test Accuracy: 48.73%
#     Worker 0: Train Loss: 1.7106, Train Accuracy: 52.32%
#     Worker 1: Train Loss: 1.6868, Train Accuracy: 53.32%
#     Worker 2: Train Loss: 1.7054, Train Accuracy: 53.15%
#     Worker 3: Train Loss: 1.7325, Train Accuracy: 52.57%
#     Worker 4: Train Loss: 1.7144, Train Accuracy: 52.41%
#     Worker 5: Train Loss: 1.6923, Train Accuracy: 53.83%
#     Worker 6: Train Loss: 1.6989, Train Accuracy: 52.95%
#     Worker 7: Train Loss: 1.6689, Train Accuracy: 53.72%
# Epoch 80/150: Test Loss: 1.9772, Test Accuracy: 48.03%
#     Worker 0: Train Loss: 1.6911, Train Accuracy: 52.97%
#     Worker 1: Train Loss: 1.6550, Train Accuracy: 54.03%
#     Worker 2: Train Loss: 1.6973, Train Accuracy: 53.68%
#     Worker 3: Train Loss: 1.6947, Train Accuracy: 53.09%
#     Worker 4: Train Loss: 1.6789, Train Accuracy: 53.02%
#     Worker 5: Train Loss: 1.6732, Train Accuracy: 54.06%
#     Worker 6: Train Loss: 1.7266, Train Accuracy: 52.59%
#     Worker 7: Train Loss: 1.7013, Train Accuracy: 53.01%
# Epoch 81/150: Test Loss: 1.9724, Test Accuracy: 48.97%
#     Worker 0: Train Loss: 1.6923, Train Accuracy: 53.85%
#     Worker 1: Train Loss: 1.6364, Train Accuracy: 54.70%
#     Worker 2: Train Loss: 1.6642, Train Accuracy: 53.71%
#     Worker 3: Train Loss: 1.7037, Train Accuracy: 53.27%
#     Worker 4: Train Loss: 1.6658, Train Accuracy: 53.95%
#     Worker 5: Train Loss: 1.6960, Train Accuracy: 53.69%
#     Worker 6: Train Loss: 1.7058, Train Accuracy: 53.46%
#     Worker 7: Train Loss: 1.6676, Train Accuracy: 53.89%
# Epoch 82/150: Test Loss: 1.9757, Test Accuracy: 48.23%
#     Worker 0: Train Loss: 1.6764, Train Accuracy: 53.08%
#     Worker 1: Train Loss: 1.6403, Train Accuracy: 54.11%
#     Worker 2: Train Loss: 1.6654, Train Accuracy: 54.17%
#     Worker 3: Train Loss: 1.6444, Train Accuracy: 54.39%
#     Worker 4: Train Loss: 1.6047, Train Accuracy: 55.08%
#     Worker 5: Train Loss: 1.6438, Train Accuracy: 55.15%
#     Worker 6: Train Loss: 1.6999, Train Accuracy: 52.97%
#     Worker 7: Train Loss: 1.6459, Train Accuracy: 54.39%
# Epoch 83/150: Test Loss: 1.9731, Test Accuracy: 48.76%
#     Worker 0: Train Loss: 1.6617, Train Accuracy: 53.75%
#     Worker 1: Train Loss: 1.6093, Train Accuracy: 55.23%
#     Worker 2: Train Loss: 1.6555, Train Accuracy: 54.31%
#     Worker 3: Train Loss: 1.6629, Train Accuracy: 53.40%
#     Worker 4: Train Loss: 1.6530, Train Accuracy: 53.61%
#     Worker 5: Train Loss: 1.6526, Train Accuracy: 54.49%
#     Worker 6: Train Loss: 1.6823, Train Accuracy: 53.68%
#     Worker 7: Train Loss: 1.6441, Train Accuracy: 54.46%
# Epoch 84/150: Test Loss: 1.9730, Test Accuracy: 49.03%
#     Worker 0: Train Loss: 1.6641, Train Accuracy: 53.76%
#     Worker 1: Train Loss: 1.6285, Train Accuracy: 54.52%
#     Worker 2: Train Loss: 1.6379, Train Accuracy: 54.59%
#     Worker 3: Train Loss: 1.6729, Train Accuracy: 53.31%
#     Worker 4: Train Loss: 1.6333, Train Accuracy: 54.60%
#     Worker 5: Train Loss: 1.6194, Train Accuracy: 55.69%
#     Worker 6: Train Loss: 1.6713, Train Accuracy: 54.32%
#     Worker 7: Train Loss: 1.6642, Train Accuracy: 53.61%
# Epoch 85/150: Test Loss: 1.9622, Test Accuracy: 49.07%
#     Worker 0: Train Loss: 1.6252, Train Accuracy: 54.10%
#     Worker 1: Train Loss: 1.6031, Train Accuracy: 55.15%
#     Worker 2: Train Loss: 1.6359, Train Accuracy: 54.67%
#     Worker 3: Train Loss: 1.6624, Train Accuracy: 54.17%
#     Worker 4: Train Loss: 1.6317, Train Accuracy: 54.18%
#     Worker 5: Train Loss: 1.6358, Train Accuracy: 55.12%
#     Worker 6: Train Loss: 1.6492, Train Accuracy: 54.30%
#     Worker 7: Train Loss: 1.6208, Train Accuracy: 54.77%
# Epoch 86/150: Test Loss: 1.9658, Test Accuracy: 48.88%
#     Worker 0: Train Loss: 1.6328, Train Accuracy: 54.42%
#     Worker 1: Train Loss: 1.5965, Train Accuracy: 55.70%
#     Worker 2: Train Loss: 1.6060, Train Accuracy: 55.49%
#     Worker 3: Train Loss: 1.6334, Train Accuracy: 54.90%
#     Worker 4: Train Loss: 1.5929, Train Accuracy: 55.79%
#     Worker 5: Train Loss: 1.6031, Train Accuracy: 55.42%
#     Worker 6: Train Loss: 1.6315, Train Accuracy: 54.56%
#     Worker 7: Train Loss: 1.6146, Train Accuracy: 54.81%
# Epoch 87/150: Test Loss: 1.9618, Test Accuracy: 49.22%
#     Worker 0: Train Loss: 1.6120, Train Accuracy: 55.26%
#     Worker 1: Train Loss: 1.5714, Train Accuracy: 55.51%
#     Worker 2: Train Loss: 1.6007, Train Accuracy: 55.78%
#     Worker 3: Train Loss: 1.6333, Train Accuracy: 54.25%
#     Worker 4: Train Loss: 1.6108, Train Accuracy: 54.56%
#     Worker 5: Train Loss: 1.6011, Train Accuracy: 56.14%
#     Worker 6: Train Loss: 1.6193, Train Accuracy: 55.07%
#     Worker 7: Train Loss: 1.6003, Train Accuracy: 55.57%
# Epoch 88/150: Test Loss: 1.9685, Test Accuracy: 49.57%
#     Worker 0: Train Loss: 1.6119, Train Accuracy: 54.87%
#     Worker 1: Train Loss: 1.5690, Train Accuracy: 55.53%
#     Worker 2: Train Loss: 1.5737, Train Accuracy: 56.51%
#     Worker 3: Train Loss: 1.6180, Train Accuracy: 55.58%
#     Worker 4: Train Loss: 1.5583, Train Accuracy: 56.13%
#     Worker 5: Train Loss: 1.5890, Train Accuracy: 56.14%
#     Worker 6: Train Loss: 1.6240, Train Accuracy: 55.29%
#     Worker 7: Train Loss: 1.5826, Train Accuracy: 54.93%
# Epoch 89/150: Test Loss: 1.9641, Test Accuracy: 49.37%
#     Worker 0: Train Loss: 1.5961, Train Accuracy: 55.58%
#     Worker 1: Train Loss: 1.5416, Train Accuracy: 56.40%
#     Worker 2: Train Loss: 1.5821, Train Accuracy: 55.72%
#     Worker 3: Train Loss: 1.5854, Train Accuracy: 55.25%
#     Worker 4: Train Loss: 1.5690, Train Accuracy: 56.26%
#     Worker 5: Train Loss: 1.5952, Train Accuracy: 56.17%
#     Worker 6: Train Loss: 1.5908, Train Accuracy: 55.82%
#     Worker 7: Train Loss: 1.5802, Train Accuracy: 56.16%
# Epoch 90/150: Test Loss: 1.9625, Test Accuracy: 49.07%
#     Worker 0: Train Loss: 1.5776, Train Accuracy: 55.75%
#     Worker 1: Train Loss: 1.5402, Train Accuracy: 56.27%
#     Worker 2: Train Loss: 1.5590, Train Accuracy: 56.70%
#     Worker 3: Train Loss: 1.6033, Train Accuracy: 54.86%
#     Worker 4: Train Loss: 1.5596, Train Accuracy: 56.65%
#     Worker 5: Train Loss: 1.5659, Train Accuracy: 56.69%
#     Worker 6: Train Loss: 1.6058, Train Accuracy: 55.60%
#     Worker 7: Train Loss: 1.5788, Train Accuracy: 55.71%
# Epoch 91/150: Test Loss: 1.9697, Test Accuracy: 49.32%
#     Worker 0: Train Loss: 1.5929, Train Accuracy: 55.25%
#     Worker 1: Train Loss: 1.5206, Train Accuracy: 57.03%
#     Worker 2: Train Loss: 1.5702, Train Accuracy: 56.67%
#     Worker 3: Train Loss: 1.5588, Train Accuracy: 56.40%
#     Worker 4: Train Loss: 1.5718, Train Accuracy: 56.23%
#     Worker 5: Train Loss: 1.5590, Train Accuracy: 57.29%
#     Worker 6: Train Loss: 1.6040, Train Accuracy: 55.81%
#     Worker 7: Train Loss: 1.5589, Train Accuracy: 56.63%
# Epoch 92/150: Test Loss: 1.9574, Test Accuracy: 49.70%
#     Worker 0: Train Loss: 1.5685, Train Accuracy: 55.61%
#     Worker 1: Train Loss: 1.5247, Train Accuracy: 57.43%
#     Worker 2: Train Loss: 1.5483, Train Accuracy: 56.86%
#     Worker 3: Train Loss: 1.5737, Train Accuracy: 55.82%
#     Worker 4: Train Loss: 1.5456, Train Accuracy: 56.91%
#     Worker 5: Train Loss: 1.5291, Train Accuracy: 57.54%
#     Worker 6: Train Loss: 1.5850, Train Accuracy: 56.26%
#     Worker 7: Train Loss: 1.5413, Train Accuracy: 57.16%
# Epoch 93/150: Test Loss: 1.9575, Test Accuracy: 49.31%
#     Worker 0: Train Loss: 1.5260, Train Accuracy: 57.29%
#     Worker 1: Train Loss: 1.5263, Train Accuracy: 57.16%
#     Worker 2: Train Loss: 1.5239, Train Accuracy: 57.60%
#     Worker 3: Train Loss: 1.5460, Train Accuracy: 56.90%
#     Worker 4: Train Loss: 1.5463, Train Accuracy: 56.70%
#     Worker 5: Train Loss: 1.5374, Train Accuracy: 57.78%
#     Worker 6: Train Loss: 1.5606, Train Accuracy: 56.66%
#     Worker 7: Train Loss: 1.5275, Train Accuracy: 56.80%
# Epoch 94/150: Test Loss: 1.9605, Test Accuracy: 49.47%
#     Worker 0: Train Loss: 1.5387, Train Accuracy: 57.16%
#     Worker 1: Train Loss: 1.5064, Train Accuracy: 57.53%
# ...
#     Worker 6: Train Loss: 1.3645, Train Accuracy: 62.28%
#     Worker 7: Train Loss: 1.3179, Train Accuracy: 62.03%
# Epoch 120/150: Test Loss: 1.9684, Test Accuracy: 50.14%
#     Worker 0: Train Loss: 1.3296, Train Accuracy: 62.15%
#     Worker 1: Train Loss: 1.2946, Train Accuracy: 63.03%
#     Worker 2: Train Loss: 1.2974, Train Accuracy: 62.96%
#     Worker 3: Train Loss: 1.3169, Train Accuracy: 62.76%
#     Worker 4: Train Loss: 1.3027, Train Accuracy: 63.25%
#     Worker 5: Train Loss: 1.3257, Train Accuracy: 63.31%
#     Worker 6: Train Loss: 1.3332, Train Accuracy: 62.22%
#     Worker 7: Train Loss: 1.3211, Train Accuracy: 62.54%
# Epoch 121/150: Test Loss: 1.9681, Test Accuracy: 50.35%
#     Worker 0: Train Loss: 1.3044, Train Accuracy: 63.34%
#     Worker 1: Train Loss: 1.2981, Train Accuracy: 62.83%
#     Worker 2: Train Loss: 1.3045, Train Accuracy: 62.80%
#     Worker 3: Train Loss: 1.3054, Train Accuracy: 62.59%
#     Worker 4: Train Loss: 1.3264, Train Accuracy: 62.76%
#     Worker 5: Train Loss: 1.2953, Train Accuracy: 63.36%
#     Worker 6: Train Loss: 1.3207, Train Accuracy: 62.23%
#     Worker 7: Train Loss: 1.2921, Train Accuracy: 63.24%
# Epoch 122/150: Test Loss: 1.9675, Test Accuracy: 50.38%
#     Worker 0: Train Loss: 1.3157, Train Accuracy: 62.78%
#     Worker 1: Train Loss: 1.2844, Train Accuracy: 63.41%
#     Worker 2: Train Loss: 1.3047, Train Accuracy: 62.99%
#     Worker 3: Train Loss: 1.3102, Train Accuracy: 63.04%
#     Worker 4: Train Loss: 1.2725, Train Accuracy: 63.41%
#     Worker 5: Train Loss: 1.3361, Train Accuracy: 62.51%
#     Worker 6: Train Loss: 1.3442, Train Accuracy: 62.47%
#     Worker 7: Train Loss: 1.3137, Train Accuracy: 62.62%
# Epoch 123/150: Test Loss: 1.9677, Test Accuracy: 50.52%
#     Worker 0: Train Loss: 1.3055, Train Accuracy: 62.51%
#     Worker 1: Train Loss: 1.2908, Train Accuracy: 63.10%
#     Worker 2: Train Loss: 1.3015, Train Accuracy: 63.43%
#     Worker 3: Train Loss: 1.3238, Train Accuracy: 62.44%
#     Worker 4: Train Loss: 1.3004, Train Accuracy: 63.60%
#     Worker 5: Train Loss: 1.2844, Train Accuracy: 63.03%
#     Worker 6: Train Loss: 1.3141, Train Accuracy: 63.36%
#     Worker 7: Train Loss: 1.3154, Train Accuracy: 62.57%
# Epoch 124/150: Test Loss: 1.9724, Test Accuracy: 50.34%
#     Worker 0: Train Loss: 1.3174, Train Accuracy: 62.97%
#     Worker 1: Train Loss: 1.2817, Train Accuracy: 64.12%
#     Worker 2: Train Loss: 1.3061, Train Accuracy: 63.13%
#     Worker 3: Train Loss: 1.2940, Train Accuracy: 63.85%
#     Worker 4: Train Loss: 1.2889, Train Accuracy: 63.94%
#     Worker 5: Train Loss: 1.2932, Train Accuracy: 63.48%
#     Worker 6: Train Loss: 1.3232, Train Accuracy: 63.17%
#     Worker 7: Train Loss: 1.2957, Train Accuracy: 63.31%
# Epoch 125/150: Test Loss: 1.9704, Test Accuracy: 50.46%
#     Worker 0: Train Loss: 1.3193, Train Accuracy: 62.80%
#     Worker 1: Train Loss: 1.2646, Train Accuracy: 64.13%
#     Worker 2: Train Loss: 1.2928, Train Accuracy: 63.38%
#     Worker 3: Train Loss: 1.2950, Train Accuracy: 63.45%
#     Worker 4: Train Loss: 1.3163, Train Accuracy: 62.38%
#     Worker 5: Train Loss: 1.3048, Train Accuracy: 63.07%
#     Worker 6: Train Loss: 1.3194, Train Accuracy: 62.62%
#     Worker 7: Train Loss: 1.2819, Train Accuracy: 63.35%
# Epoch 126/150: Test Loss: 1.9680, Test Accuracy: 50.48%
#     Worker 0: Train Loss: 1.3068, Train Accuracy: 63.48%
#     Worker 1: Train Loss: 1.2649, Train Accuracy: 63.77%
#     Worker 2: Train Loss: 1.2656, Train Accuracy: 64.65%
#     Worker 3: Train Loss: 1.3015, Train Accuracy: 62.69%
#     Worker 4: Train Loss: 1.2730, Train Accuracy: 63.63%
#     Worker 5: Train Loss: 1.2991, Train Accuracy: 64.18%
#     Worker 6: Train Loss: 1.3104, Train Accuracy: 63.21%
#     Worker 7: Train Loss: 1.2845, Train Accuracy: 63.60%
# Epoch 127/150: Test Loss: 1.9688, Test Accuracy: 50.30%
#     Worker 0: Train Loss: 1.2796, Train Accuracy: 63.59%
#     Worker 1: Train Loss: 1.2690, Train Accuracy: 63.69%
#     Worker 2: Train Loss: 1.2722, Train Accuracy: 64.05%
#     Worker 3: Train Loss: 1.3098, Train Accuracy: 62.92%
#     Worker 4: Train Loss: 1.2796, Train Accuracy: 64.36%
#     Worker 5: Train Loss: 1.2901, Train Accuracy: 64.02%
#     Worker 6: Train Loss: 1.3096, Train Accuracy: 63.20%
#     Worker 7: Train Loss: 1.2742, Train Accuracy: 63.42%
# Epoch 128/150: Test Loss: 1.9694, Test Accuracy: 50.61%
#     Worker 0: Train Loss: 1.2803, Train Accuracy: 64.36%
#     Worker 1: Train Loss: 1.2515, Train Accuracy: 64.43%
#     Worker 2: Train Loss: 1.2637, Train Accuracy: 64.57%
#     Worker 3: Train Loss: 1.2880, Train Accuracy: 63.56%
#     Worker 4: Train Loss: 1.2836, Train Accuracy: 63.31%
#     Worker 5: Train Loss: 1.2952, Train Accuracy: 64.48%
#     Worker 6: Train Loss: 1.3110, Train Accuracy: 63.08%
#     Worker 7: Train Loss: 1.2795, Train Accuracy: 63.31%
# Epoch 129/150: Test Loss: 1.9744, Test Accuracy: 50.38%
#     Worker 0: Train Loss: 1.2775, Train Accuracy: 63.14%
#     Worker 1: Train Loss: 1.2526, Train Accuracy: 64.23%
#     Worker 2: Train Loss: 1.2585, Train Accuracy: 63.73%
#     Worker 3: Train Loss: 1.2709, Train Accuracy: 63.67%
#     Worker 4: Train Loss: 1.2480, Train Accuracy: 64.92%
#     Worker 5: Train Loss: 1.2567, Train Accuracy: 64.13%
#     Worker 6: Train Loss: 1.2823, Train Accuracy: 63.91%
#     Worker 7: Train Loss: 1.2466, Train Accuracy: 64.89%
# Epoch 130/150: Test Loss: 1.9703, Test Accuracy: 50.56%
#     Worker 0: Train Loss: 1.2664, Train Accuracy: 64.16%
#     Worker 1: Train Loss: 1.2474, Train Accuracy: 64.29%
#     Worker 2: Train Loss: 1.2793, Train Accuracy: 63.52%
#     Worker 3: Train Loss: 1.2710, Train Accuracy: 63.59%
#     Worker 4: Train Loss: 1.2762, Train Accuracy: 64.01%
#     Worker 5: Train Loss: 1.2808, Train Accuracy: 64.34%
#     Worker 6: Train Loss: 1.3071, Train Accuracy: 62.44%
#     Worker 7: Train Loss: 1.2781, Train Accuracy: 63.78%
# Epoch 131/150: Test Loss: 1.9707, Test Accuracy: 50.61%
#     Worker 0: Train Loss: 1.2786, Train Accuracy: 64.04%
#     Worker 1: Train Loss: 1.2420, Train Accuracy: 64.67%
#     Worker 2: Train Loss: 1.2669, Train Accuracy: 63.94%
#     Worker 3: Train Loss: 1.2899, Train Accuracy: 63.99%
#     Worker 4: Train Loss: 1.2397, Train Accuracy: 64.74%
#     Worker 5: Train Loss: 1.2559, Train Accuracy: 64.67%
#     Worker 6: Train Loss: 1.2873, Train Accuracy: 64.32%
#     Worker 7: Train Loss: 1.2737, Train Accuracy: 63.99%
# Epoch 132/150: Test Loss: 1.9742, Test Accuracy: 50.52%
#     Worker 0: Train Loss: 1.2800, Train Accuracy: 64.19%
#     Worker 1: Train Loss: 1.2382, Train Accuracy: 64.69%
#     Worker 2: Train Loss: 1.2595, Train Accuracy: 63.41%
#     Worker 3: Train Loss: 1.2813, Train Accuracy: 63.60%
#     Worker 4: Train Loss: 1.2679, Train Accuracy: 63.90%
#     Worker 5: Train Loss: 1.2963, Train Accuracy: 63.90%
#     Worker 6: Train Loss: 1.2945, Train Accuracy: 62.41%
#     Worker 7: Train Loss: 1.2486, Train Accuracy: 64.48%
# Epoch 133/150: Test Loss: 1.9722, Test Accuracy: 50.51%
#     Worker 0: Train Loss: 1.2801, Train Accuracy: 63.74%
#     Worker 1: Train Loss: 1.2520, Train Accuracy: 63.95%
#     Worker 2: Train Loss: 1.2530, Train Accuracy: 64.02%
#     Worker 3: Train Loss: 1.2666, Train Accuracy: 64.67%
#     Worker 4: Train Loss: 1.2677, Train Accuracy: 63.83%
#     Worker 5: Train Loss: 1.2618, Train Accuracy: 64.78%
#     Worker 6: Train Loss: 1.2805, Train Accuracy: 63.99%
#     Worker 7: Train Loss: 1.2617, Train Accuracy: 64.22%
# Epoch 134/150: Test Loss: 1.9750, Test Accuracy: 50.35%
#     Worker 0: Train Loss: 1.2727, Train Accuracy: 63.78%
#     Worker 1: Train Loss: 1.2214, Train Accuracy: 64.82%
#     Worker 2: Train Loss: 1.2408, Train Accuracy: 65.10%
#     Worker 3: Train Loss: 1.2732, Train Accuracy: 64.88%
#     Worker 4: Train Loss: 1.2633, Train Accuracy: 63.84%
#     Worker 5: Train Loss: 1.2895, Train Accuracy: 62.93%
#     Worker 6: Train Loss: 1.2678, Train Accuracy: 64.20%
#     Worker 7: Train Loss: 1.2669, Train Accuracy: 64.39%
# Epoch 135/150: Test Loss: 1.9752, Test Accuracy: 50.42%
#     Worker 0: Train Loss: 1.2591, Train Accuracy: 64.51%
#     Worker 1: Train Loss: 1.2550, Train Accuracy: 64.09%
#     Worker 2: Train Loss: 1.2568, Train Accuracy: 64.22%
#     Worker 3: Train Loss: 1.2610, Train Accuracy: 64.13%
#     Worker 4: Train Loss: 1.2687, Train Accuracy: 64.33%
#     Worker 5: Train Loss: 1.2345, Train Accuracy: 65.14%
#     Worker 6: Train Loss: 1.2794, Train Accuracy: 63.73%
#     Worker 7: Train Loss: 1.2509, Train Accuracy: 64.04%
# Epoch 136/150: Test Loss: 1.9757, Test Accuracy: 50.33%
#     Worker 0: Train Loss: 1.2735, Train Accuracy: 63.32%
#     Worker 1: Train Loss: 1.2225, Train Accuracy: 65.03%
#     Worker 2: Train Loss: 1.2472, Train Accuracy: 64.69%
#     Worker 3: Train Loss: 1.2767, Train Accuracy: 63.60%
#     Worker 4: Train Loss: 1.2743, Train Accuracy: 63.91%
#     Worker 5: Train Loss: 1.2552, Train Accuracy: 64.16%
#     Worker 6: Train Loss: 1.2728, Train Accuracy: 64.12%
#     Worker 7: Train Loss: 1.2546, Train Accuracy: 64.04%
# Epoch 137/150: Test Loss: 1.9758, Test Accuracy: 50.41%
#     Worker 0: Train Loss: 1.2752, Train Accuracy: 64.05%
#     Worker 1: Train Loss: 1.2410, Train Accuracy: 64.88%
#     Worker 2: Train Loss: 1.2369, Train Accuracy: 64.95%
#     Worker 3: Train Loss: 1.2593, Train Accuracy: 64.26%
#     Worker 4: Train Loss: 1.2268, Train Accuracy: 64.89%
#     Worker 5: Train Loss: 1.2531, Train Accuracy: 64.64%
#     Worker 6: Train Loss: 1.2671, Train Accuracy: 64.11%
#     Worker 7: Train Loss: 1.2458, Train Accuracy: 63.90%
# Epoch 138/150: Test Loss: 1.9762, Test Accuracy: 50.53%
#     Worker 0: Train Loss: 1.2623, Train Accuracy: 64.13%
#     Worker 1: Train Loss: 1.2474, Train Accuracy: 64.26%
#     Worker 2: Train Loss: 1.2587, Train Accuracy: 64.54%
#     Worker 3: Train Loss: 1.2681, Train Accuracy: 64.72%
#     Worker 4: Train Loss: 1.2533, Train Accuracy: 64.13%
#     Worker 5: Train Loss: 1.2544, Train Accuracy: 64.62%
#     Worker 6: Train Loss: 1.2806, Train Accuracy: 64.53%
#     Worker 7: Train Loss: 1.2436, Train Accuracy: 64.48%
# Epoch 139/150: Test Loss: 1.9752, Test Accuracy: 50.42%
#     Worker 0: Train Loss: 1.2431, Train Accuracy: 64.72%
#     Worker 1: Train Loss: 1.2403, Train Accuracy: 64.50%
#     Worker 2: Train Loss: 1.2518, Train Accuracy: 64.26%
#     Worker 3: Train Loss: 1.2769, Train Accuracy: 63.88%
#     Worker 4: Train Loss: 1.2501, Train Accuracy: 65.39%
#     Worker 5: Train Loss: 1.2516, Train Accuracy: 64.58%
#     Worker 6: Train Loss: 1.2677, Train Accuracy: 64.18%
#     Worker 7: Train Loss: 1.2657, Train Accuracy: 63.67%
# Epoch 140/150: Test Loss: 1.9756, Test Accuracy: 50.45%
#     Worker 0: Train Loss: 1.2705, Train Accuracy: 63.87%
#     Worker 1: Train Loss: 1.2321, Train Accuracy: 64.50%
#     Worker 2: Train Loss: 1.2458, Train Accuracy: 65.19%
#     Worker 3: Train Loss: 1.2673, Train Accuracy: 64.44%
#     Worker 4: Train Loss: 1.2378, Train Accuracy: 65.10%
#     Worker 5: Train Loss: 1.2510, Train Accuracy: 64.60%
#     Worker 6: Train Loss: 1.2596, Train Accuracy: 63.60%
#     Worker 7: Train Loss: 1.2350, Train Accuracy: 64.99%
# Epoch 141/150: Test Loss: 1.9753, Test Accuracy: 50.51%
#     Worker 0: Train Loss: 1.2371, Train Accuracy: 65.06%
#     Worker 1: Train Loss: 1.2316, Train Accuracy: 64.79%
#     Worker 2: Train Loss: 1.2441, Train Accuracy: 64.57%
#     Worker 3: Train Loss: 1.2736, Train Accuracy: 63.71%
#     Worker 4: Train Loss: 1.2319, Train Accuracy: 64.41%
#     Worker 5: Train Loss: 1.2395, Train Accuracy: 65.03%
#     Worker 6: Train Loss: 1.2878, Train Accuracy: 62.71%
#     Worker 7: Train Loss: 1.2307, Train Accuracy: 64.96%
# Epoch 142/150: Test Loss: 1.9754, Test Accuracy: 50.49%
#     Worker 0: Train Loss: 1.2445, Train Accuracy: 64.34%
#     Worker 1: Train Loss: 1.2367, Train Accuracy: 64.64%
#     Worker 2: Train Loss: 1.2403, Train Accuracy: 65.23%
#     Worker 3: Train Loss: 1.2486, Train Accuracy: 64.62%
#     Worker 4: Train Loss: 1.2356, Train Accuracy: 64.90%
#     Worker 5: Train Loss: 1.2512, Train Accuracy: 64.58%
#     Worker 6: Train Loss: 1.2624, Train Accuracy: 64.18%
#     Worker 7: Train Loss: 1.2576, Train Accuracy: 64.37%
# Epoch 143/150: Test Loss: 1.9759, Test Accuracy: 50.44%
#     Worker 0: Train Loss: 1.2704, Train Accuracy: 63.92%
#     Worker 1: Train Loss: 1.2139, Train Accuracy: 64.85%
#     Worker 2: Train Loss: 1.2177, Train Accuracy: 65.56%
#     Worker 3: Train Loss: 1.2527, Train Accuracy: 64.90%
#     Worker 4: Train Loss: 1.2351, Train Accuracy: 65.14%
#     Worker 5: Train Loss: 1.2731, Train Accuracy: 64.53%
#     Worker 6: Train Loss: 1.2620, Train Accuracy: 64.55%
#     Worker 7: Train Loss: 1.2414, Train Accuracy: 63.84%
# Epoch 144/150: Test Loss: 1.9762, Test Accuracy: 50.32%
#     Worker 0: Train Loss: 1.2512, Train Accuracy: 64.19%
#     Worker 1: Train Loss: 1.2452, Train Accuracy: 64.37%
#     Worker 2: Train Loss: 1.2303, Train Accuracy: 65.56%
#     Worker 3: Train Loss: 1.2477, Train Accuracy: 64.41%
#     Worker 4: Train Loss: 1.2371, Train Accuracy: 65.16%
#     Worker 5: Train Loss: 1.2409, Train Accuracy: 65.16%
#     Worker 6: Train Loss: 1.2558, Train Accuracy: 64.29%
#     Worker 7: Train Loss: 1.2402, Train Accuracy: 64.89%
# Epoch 145/150: Test Loss: 1.9756, Test Accuracy: 50.45%
#     Worker 0: Train Loss: 1.2445, Train Accuracy: 65.02%
#     Worker 1: Train Loss: 1.2250, Train Accuracy: 64.51%
#     Worker 2: Train Loss: 1.2326, Train Accuracy: 64.95%
#     Worker 3: Train Loss: 1.2496, Train Accuracy: 64.64%
#     Worker 4: Train Loss: 1.2495, Train Accuracy: 64.53%
#     Worker 5: Train Loss: 1.2659, Train Accuracy: 64.72%
#     Worker 6: Train Loss: 1.2831, Train Accuracy: 64.04%
#     Worker 7: Train Loss: 1.2315, Train Accuracy: 65.02%
# Epoch 146/150: Test Loss: 1.9758, Test Accuracy: 50.43%
#     Worker 0: Train Loss: 1.2546, Train Accuracy: 64.46%
#     Worker 1: Train Loss: 1.2201, Train Accuracy: 65.18%
#     Worker 2: Train Loss: 1.2443, Train Accuracy: 64.72%
#     Worker 3: Train Loss: 1.2522, Train Accuracy: 64.69%
#     Worker 4: Train Loss: 1.2452, Train Accuracy: 64.40%
#     Worker 5: Train Loss: 1.2637, Train Accuracy: 64.90%
#     Worker 6: Train Loss: 1.2571, Train Accuracy: 63.78%
#     Worker 7: Train Loss: 1.2590, Train Accuracy: 64.23%
# Epoch 147/150: Test Loss: 1.9755, Test Accuracy: 50.47%
#     Worker 0: Train Loss: 1.2457, Train Accuracy: 65.05%
#     Worker 1: Train Loss: 1.2255, Train Accuracy: 64.99%
#     Worker 2: Train Loss: 1.2331, Train Accuracy: 64.91%
#     Worker 3: Train Loss: 1.2567, Train Accuracy: 64.94%
#     Worker 4: Train Loss: 1.2374, Train Accuracy: 65.12%
#     Worker 5: Train Loss: 1.2465, Train Accuracy: 65.23%
#     Worker 6: Train Loss: 1.2570, Train Accuracy: 64.02%
#     Worker 7: Train Loss: 1.2497, Train Accuracy: 63.69%
# Epoch 148/150: Test Loss: 1.9756, Test Accuracy: 50.48%
#     Worker 0: Train Loss: 1.2496, Train Accuracy: 64.67%
#     Worker 1: Train Loss: 1.2250, Train Accuracy: 64.90%
#     Worker 2: Train Loss: 1.2407, Train Accuracy: 65.41%
#     Worker 3: Train Loss: 1.2706, Train Accuracy: 63.81%
#     Worker 4: Train Loss: 1.2378, Train Accuracy: 64.50%
#     Worker 5: Train Loss: 1.2407, Train Accuracy: 65.37%
#     Worker 6: Train Loss: 1.2690, Train Accuracy: 64.27%
#     Worker 7: Train Loss: 1.2452, Train Accuracy: 64.29%
# Epoch 149/150: Test Loss: 1.9756, Test Accuracy: 50.46%
#     Worker 0: Train Loss: 1.2545, Train Accuracy: 64.54%
#     Worker 1: Train Loss: 1.2195, Train Accuracy: 65.13%
#     Worker 2: Train Loss: 1.2422, Train Accuracy: 65.34%
#     Worker 3: Train Loss: 1.2274, Train Accuracy: 65.49%
#     Worker 4: Train Loss: 1.2374, Train Accuracy: 64.46%
#     Worker 5: Train Loss: 1.2681, Train Accuracy: 65.06%
#     Worker 6: Train Loss: 1.2703, Train Accuracy: 63.73%
#     Worker 7: Train Loss: 1.2498, Train Accuracy: 64.22%
# Epoch 150/150: Test Loss: 1.9756, Test Accuracy: 50.47%
#     Worker 0: Train Loss: 1.2429, Train Accuracy: 64.71%
#     Worker 1: Train Loss: 1.2517, Train Accuracy: 64.81%
#     Worker 2: Train Loss: 1.2249, Train Accuracy: 65.27%
#     Worker 3: Train Loss: 1.2610, Train Accuracy: 64.81%
#     Worker 4: Train Loss: 1.2306, Train Accuracy: 65.28%
#     Worker 5: Train Loss: 1.2360, Train Accuracy: 64.99%
#     Worker 6: Train Loss: 1.2950, Train Accuracy: 63.91%
#     Worker 7: Train Loss: 1.2271, Train Accuracy: 64.55%
