# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
#warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")

    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch):
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            # Perform J local step before synchronization
            for j in range(J):
                try:
                    # Get a batch from the current worker's shard using next()
                    images, labels = next(shard_iterators[k])
                    images, labels = images.to(device), labels.to(device)  # Move to device
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

                except StopIteration:
                    # If the iterator has exhausted the data, restart the iterator
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k]) # Resume from the next batch
                    images, labels = images.to(device), labels.to(device)
                    # Perform optimization step
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        # Perform model synchronization
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            # Update each worker model with the global parameters
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
       # if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
       # else:
        #    warmup_factor = (epoch + 1) / warmup_epochs
          #  lr = warmup_factor * learning_rate
          #  for optimizer in optimizers:
           #     for param_group in optimizer.param_groups:
            #        param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 8 --j 32
# Out:
# Training with K=8, J=32
# Global iteration per epoch: 4
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00800
# Epoch 1/150: Test Loss: 4.5437, Test Accuracy: 2.64%
#     Worker 0: Train Loss: 4.5945, Train Accuracy: 1.36%
#     Worker 1: Train Loss: 4.5944, Train Accuracy: 1.36%
#     Worker 2: Train Loss: 4.5932, Train Accuracy: 1.74%
#     Worker 3: Train Loss: 4.5924, Train Accuracy: 1.47%
#     Worker 4: Train Loss: 4.5923, Train Accuracy: 1.37%
#     Worker 5: Train Loss: 4.5894, Train Accuracy: 1.49%
#     Worker 6: Train Loss: 4.5917, Train Accuracy: 1.38%
#     Worker 7: Train Loss: 4.5903, Train Accuracy: 1.26%
# Epoch 2/150: Test Loss: 4.1548, Test Accuracy: 6.29%
#     Worker 0: Train Loss: 4.3760, Train Accuracy: 4.08%
#     Worker 1: Train Loss: 4.3730, Train Accuracy: 4.00%
#     Worker 2: Train Loss: 4.3789, Train Accuracy: 4.09%
#     Worker 3: Train Loss: 4.3810, Train Accuracy: 3.55%
#     Worker 4: Train Loss: 4.3682, Train Accuracy: 3.78%
#     Worker 5: Train Loss: 4.3586, Train Accuracy: 3.98%
#     Worker 6: Train Loss: 4.3834, Train Accuracy: 3.66%
#     Worker 7: Train Loss: 4.3781, Train Accuracy: 4.08%
# Epoch 3/150: Test Loss: 3.9725, Test Accuracy: 9.05%
#     Worker 0: Train Loss: 4.1361, Train Accuracy: 6.40%
#     Worker 1: Train Loss: 4.1393, Train Accuracy: 6.24%
#     Worker 2: Train Loss: 4.1265, Train Accuracy: 6.14%
#     Worker 3: Train Loss: 4.1336, Train Accuracy: 6.19%
#     Worker 4: Train Loss: 4.1092, Train Accuracy: 6.54%
#     Worker 5: Train Loss: 4.1086, Train Accuracy: 7.14%
#     Worker 6: Train Loss: 4.1493, Train Accuracy: 5.94%
#     Worker 7: Train Loss: 4.1308, Train Accuracy: 6.16%
# Epoch 4/150: Test Loss: 3.8239, Test Accuracy: 11.84%
#     Worker 0: Train Loss: 3.9996, Train Accuracy: 8.28%
#     Worker 1: Train Loss: 4.0064, Train Accuracy: 7.94%
#     Worker 2: Train Loss: 3.9982, Train Accuracy: 8.17%
#     Worker 3: Train Loss: 4.0178, Train Accuracy: 8.03%
#     Worker 4: Train Loss: 3.9627, Train Accuracy: 8.71%
#     Worker 5: Train Loss: 3.9599, Train Accuracy: 8.70%
#     Worker 6: Train Loss: 3.9931, Train Accuracy: 8.21%
#     Worker 7: Train Loss: 4.0053, Train Accuracy: 8.32%
# Epoch 5/150: Test Loss: 3.6866, Test Accuracy: 14.27%
#     Worker 0: Train Loss: 3.8827, Train Accuracy: 10.12%
#     Worker 1: Train Loss: 3.8758, Train Accuracy: 9.61%
#     Worker 2: Train Loss: 3.8642, Train Accuracy: 10.50%
#     Worker 3: Train Loss: 3.8869, Train Accuracy: 9.82%
#     Worker 4: Train Loss: 3.8310, Train Accuracy: 10.82%
#     Worker 5: Train Loss: 3.8429, Train Accuracy: 11.16%
#     Worker 6: Train Loss: 3.8991, Train Accuracy: 9.60%
#     Worker 7: Train Loss: 3.8700, Train Accuracy: 9.95%
# Epoch 6/150: Test Loss: 3.5952, Test Accuracy: 15.72%
#     Worker 0: Train Loss: 3.7685, Train Accuracy: 11.79%
#     Worker 1: Train Loss: 3.7737, Train Accuracy: 11.40%
#     Worker 2: Train Loss: 3.7751, Train Accuracy: 12.04%
#     Worker 3: Train Loss: 3.8034, Train Accuracy: 11.13%
#     Worker 4: Train Loss: 3.7270, Train Accuracy: 12.74%
#     Worker 5: Train Loss: 3.7221, Train Accuracy: 13.19%
#     Worker 6: Train Loss: 3.7664, Train Accuracy: 11.92%
#     Worker 7: Train Loss: 3.7594, Train Accuracy: 11.95%
# Epoch 7/150: Test Loss: 3.4948, Test Accuracy: 17.21%
#     Worker 0: Train Loss: 3.6899, Train Accuracy: 12.69%
#     Worker 1: Train Loss: 3.6841, Train Accuracy: 12.51%
#     Worker 2: Train Loss: 3.6881, Train Accuracy: 13.60%
#     Worker 3: Train Loss: 3.6950, Train Accuracy: 13.14%
#     Worker 4: Train Loss: 3.6322, Train Accuracy: 13.43%
#     Worker 5: Train Loss: 3.6163, Train Accuracy: 14.76%
#     Worker 6: Train Loss: 3.6976, Train Accuracy: 12.63%
#     Worker 7: Train Loss: 3.6924, Train Accuracy: 13.67%
# Epoch 8/150: Test Loss: 3.4343, Test Accuracy: 18.65%
#     Worker 0: Train Loss: 3.5738, Train Accuracy: 14.20%
#     Worker 1: Train Loss: 3.6093, Train Accuracy: 14.41%
#     Worker 2: Train Loss: 3.5927, Train Accuracy: 14.91%
#     Worker 3: Train Loss: 3.6540, Train Accuracy: 13.75%
#     Worker 4: Train Loss: 3.5707, Train Accuracy: 14.61%
#     Worker 5: Train Loss: 3.5482, Train Accuracy: 15.62%
#     Worker 6: Train Loss: 3.5995, Train Accuracy: 14.61%
#     Worker 7: Train Loss: 3.6181, Train Accuracy: 14.26%
# Epoch 9/150: Test Loss: 3.3328, Test Accuracy: 20.80%
#     Worker 0: Train Loss: 3.5354, Train Accuracy: 15.73%
#     Worker 1: Train Loss: 3.5023, Train Accuracy: 16.14%
#     Worker 2: Train Loss: 3.5180, Train Accuracy: 16.60%
#     Worker 3: Train Loss: 3.5526, Train Accuracy: 15.58%
#     Worker 4: Train Loss: 3.4839, Train Accuracy: 16.51%
#     Worker 5: Train Loss: 3.4742, Train Accuracy: 17.39%
#     Worker 6: Train Loss: 3.5343, Train Accuracy: 15.89%
#     Worker 7: Train Loss: 3.5134, Train Accuracy: 15.92%
# Epoch 10/150: Test Loss: 3.2610, Test Accuracy: 21.90%
#     Worker 0: Train Loss: 3.4516, Train Accuracy: 17.24%
#     Worker 1: Train Loss: 3.4396, Train Accuracy: 16.90%
#     Worker 2: Train Loss: 3.4405, Train Accuracy: 17.89%
#     Worker 3: Train Loss: 3.4971, Train Accuracy: 16.57%
#     Worker 4: Train Loss: 3.4115, Train Accuracy: 17.86%
#     Worker 5: Train Loss: 3.4036, Train Accuracy: 18.24%
#     Worker 6: Train Loss: 3.4625, Train Accuracy: 16.38%
#     Worker 7: Train Loss: 3.4471, Train Accuracy: 17.11%
# Epoch 11/150: Test Loss: 3.1779, Test Accuracy: 23.43%
#     Worker 0: Train Loss: 3.3837, Train Accuracy: 18.21%
#     Worker 1: Train Loss: 3.3714, Train Accuracy: 18.73%
#     Worker 2: Train Loss: 3.3710, Train Accuracy: 19.22%
#     Worker 3: Train Loss: 3.4213, Train Accuracy: 18.04%
#     Worker 4: Train Loss: 3.3551, Train Accuracy: 18.45%
#     Worker 5: Train Loss: 3.3155, Train Accuracy: 19.85%
#     Worker 6: Train Loss: 3.3943, Train Accuracy: 18.29%
#     Worker 7: Train Loss: 3.3800, Train Accuracy: 18.51%
# Epoch 12/150: Test Loss: 3.1293, Test Accuracy: 24.44%
#     Worker 0: Train Loss: 3.3302, Train Accuracy: 19.22%
#     Worker 1: Train Loss: 3.3219, Train Accuracy: 19.61%
#     Worker 2: Train Loss: 3.2928, Train Accuracy: 20.24%
#     Worker 3: Train Loss: 3.3450, Train Accuracy: 18.84%
#     Worker 4: Train Loss: 3.2769, Train Accuracy: 19.60%
#     Worker 5: Train Loss: 3.2756, Train Accuracy: 20.83%
#     Worker 6: Train Loss: 3.3408, Train Accuracy: 19.44%
#     Worker 7: Train Loss: 3.3089, Train Accuracy: 19.55%
# Epoch 13/150: Test Loss: 3.0716, Test Accuracy: 25.36%
#     Worker 0: Train Loss: 3.2575, Train Accuracy: 20.18%
#     Worker 1: Train Loss: 3.2319, Train Accuracy: 21.06%
#     Worker 2: Train Loss: 3.2347, Train Accuracy: 21.82%
#     Worker 3: Train Loss: 3.2750, Train Accuracy: 20.83%
#     Worker 4: Train Loss: 3.2254, Train Accuracy: 21.52%
#     Worker 5: Train Loss: 3.1812, Train Accuracy: 21.87%
#     Worker 6: Train Loss: 3.2770, Train Accuracy: 19.83%
#     Worker 7: Train Loss: 3.2660, Train Accuracy: 19.99%
# Epoch 14/150: Test Loss: 2.9892, Test Accuracy: 27.00%
#     Worker 0: Train Loss: 3.1808, Train Accuracy: 21.87%
#     Worker 1: Train Loss: 3.1652, Train Accuracy: 22.08%
#     Worker 2: Train Loss: 3.1918, Train Accuracy: 22.14%
#     Worker 3: Train Loss: 3.2284, Train Accuracy: 20.81%
#     Worker 4: Train Loss: 3.1665, Train Accuracy: 22.24%
#     Worker 5: Train Loss: 3.1513, Train Accuracy: 23.06%
#     Worker 6: Train Loss: 3.2145, Train Accuracy: 21.34%
#     Worker 7: Train Loss: 3.1932, Train Accuracy: 21.88%
# Epoch 15/150: Test Loss: 2.9313, Test Accuracy: 28.50%
#     Worker 0: Train Loss: 3.1501, Train Accuracy: 22.04%
#     Worker 1: Train Loss: 3.1271, Train Accuracy: 22.71%
#     Worker 2: Train Loss: 3.1215, Train Accuracy: 23.83%
#     Worker 3: Train Loss: 3.1896, Train Accuracy: 21.48%
#     Worker 4: Train Loss: 3.0985, Train Accuracy: 23.51%
#     Worker 5: Train Loss: 3.1011, Train Accuracy: 23.34%
#     Worker 6: Train Loss: 3.1476, Train Accuracy: 22.69%
#     Worker 7: Train Loss: 3.1336, Train Accuracy: 22.86%
# Epoch 16/150: Test Loss: 2.8977, Test Accuracy: 28.88%
#     Worker 0: Train Loss: 3.0936, Train Accuracy: 23.77%
#     Worker 1: Train Loss: 3.0710, Train Accuracy: 23.88%
#     Worker 2: Train Loss: 3.1066, Train Accuracy: 24.06%
#     Worker 3: Train Loss: 3.1327, Train Accuracy: 22.58%
#     Worker 4: Train Loss: 3.0506, Train Accuracy: 24.46%
#     Worker 5: Train Loss: 3.0738, Train Accuracy: 24.26%
#     Worker 6: Train Loss: 3.1083, Train Accuracy: 23.72%
#     Worker 7: Train Loss: 3.0918, Train Accuracy: 23.57%
# Epoch 17/150: Test Loss: 2.8391, Test Accuracy: 29.62%
#     Worker 0: Train Loss: 3.0432, Train Accuracy: 24.20%
#     Worker 1: Train Loss: 3.0022, Train Accuracy: 25.27%
#     Worker 2: Train Loss: 3.0215, Train Accuracy: 25.12%
#     Worker 3: Train Loss: 3.0855, Train Accuracy: 23.71%
#     Worker 4: Train Loss: 2.9810, Train Accuracy: 25.14%
#     Worker 5: Train Loss: 2.9721, Train Accuracy: 26.02%
#     Worker 6: Train Loss: 3.0456, Train Accuracy: 24.34%
#     Worker 7: Train Loss: 3.0239, Train Accuracy: 25.01%
# Epoch 18/150: Test Loss: 2.7933, Test Accuracy: 30.71%
#     Worker 0: Train Loss: 3.0121, Train Accuracy: 24.82%
#     Worker 1: Train Loss: 2.9664, Train Accuracy: 25.52%
#     Worker 2: Train Loss: 2.9756, Train Accuracy: 26.10%
#     Worker 3: Train Loss: 3.0549, Train Accuracy: 24.37%
#     Worker 4: Train Loss: 2.9617, Train Accuracy: 26.32%
#     Worker 5: Train Loss: 2.9358, Train Accuracy: 26.63%
#     Worker 6: Train Loss: 3.0068, Train Accuracy: 24.66%
#     Worker 7: Train Loss: 2.9738, Train Accuracy: 26.51%
# Epoch 19/150: Test Loss: 2.7333, Test Accuracy: 32.02%
#     Worker 0: Train Loss: 2.9444, Train Accuracy: 26.25%
#     Worker 1: Train Loss: 2.9306, Train Accuracy: 26.47%
#     Worker 2: Train Loss: 2.9639, Train Accuracy: 25.94%
#     Worker 3: Train Loss: 2.9658, Train Accuracy: 26.16%
#     Worker 4: Train Loss: 2.9060, Train Accuracy: 27.17%
#     Worker 5: Train Loss: 2.9227, Train Accuracy: 27.09%
#     Worker 6: Train Loss: 2.9874, Train Accuracy: 25.06%
#     Worker 7: Train Loss: 2.9502, Train Accuracy: 26.11%
# Epoch 20/150: Test Loss: 2.7037, Test Accuracy: 32.14%
#     Worker 0: Train Loss: 2.8911, Train Accuracy: 27.04%
#     Worker 1: Train Loss: 2.8673, Train Accuracy: 27.71%
#     Worker 2: Train Loss: 2.8860, Train Accuracy: 28.34%
#     Worker 3: Train Loss: 2.9347, Train Accuracy: 26.77%
#     Worker 4: Train Loss: 2.8789, Train Accuracy: 27.53%
#     Worker 5: Train Loss: 2.8459, Train Accuracy: 28.26%
#     Worker 6: Train Loss: 2.8940, Train Accuracy: 26.87%
#     Worker 7: Train Loss: 2.8695, Train Accuracy: 28.11%
# Epoch 21/150: Test Loss: 2.6614, Test Accuracy: 33.23%
#     Worker 0: Train Loss: 2.8776, Train Accuracy: 28.18%
#     Worker 1: Train Loss: 2.8325, Train Accuracy: 28.00%
#     Worker 2: Train Loss: 2.8528, Train Accuracy: 28.91%
#     Worker 3: Train Loss: 2.8831, Train Accuracy: 27.48%
#     Worker 4: Train Loss: 2.8356, Train Accuracy: 27.89%
#     Worker 5: Train Loss: 2.8418, Train Accuracy: 29.00%
#     Worker 6: Train Loss: 2.8804, Train Accuracy: 27.16%
#     Worker 7: Train Loss: 2.8658, Train Accuracy: 28.40%
# Epoch 22/150: Test Loss: 2.6110, Test Accuracy: 33.87%
#     Worker 0: Train Loss: 2.8253, Train Accuracy: 28.85%
#     Worker 1: Train Loss: 2.7913, Train Accuracy: 28.48%
#     Worker 2: Train Loss: 2.8359, Train Accuracy: 28.98%
#     Worker 3: Train Loss: 2.8323, Train Accuracy: 28.47%
#     Worker 4: Train Loss: 2.7959, Train Accuracy: 29.07%
#     Worker 5: Train Loss: 2.7627, Train Accuracy: 30.43%
#     Worker 6: Train Loss: 2.8272, Train Accuracy: 28.90%
#     Worker 7: Train Loss: 2.8103, Train Accuracy: 29.27%
# Epoch 23/150: Test Loss: 2.5848, Test Accuracy: 34.71%
#     Worker 0: Train Loss: 2.7546, Train Accuracy: 30.41%
#     Worker 1: Train Loss: 2.7338, Train Accuracy: 30.67%
#     Worker 2: Train Loss: 2.7522, Train Accuracy: 30.61%
#     Worker 3: Train Loss: 2.7891, Train Accuracy: 28.78%
#     Worker 4: Train Loss: 2.7416, Train Accuracy: 30.35%
#     Worker 5: Train Loss: 2.7493, Train Accuracy: 30.99%
#     Worker 6: Train Loss: 2.7883, Train Accuracy: 29.88%
#     Worker 7: Train Loss: 2.7721, Train Accuracy: 30.11%
# Epoch 24/150: Test Loss: 2.5550, Test Accuracy: 35.47%
#     Worker 0: Train Loss: 2.7418, Train Accuracy: 30.38%
#     Worker 1: Train Loss: 2.6950, Train Accuracy: 30.35%
#     Worker 2: Train Loss: 2.7326, Train Accuracy: 31.16%
#     Worker 3: Train Loss: 2.7540, Train Accuracy: 29.61%
#     Worker 4: Train Loss: 2.6807, Train Accuracy: 31.24%
#     Worker 5: Train Loss: 2.6988, Train Accuracy: 31.47%
#     Worker 6: Train Loss: 2.7437, Train Accuracy: 29.89%
#     Worker 7: Train Loss: 2.7081, Train Accuracy: 31.69%
# Epoch 25/150: Test Loss: 2.5144, Test Accuracy: 36.43%
#     Worker 0: Train Loss: 2.7187, Train Accuracy: 30.97%
#     Worker 1: Train Loss: 2.6821, Train Accuracy: 31.14%
#     Worker 2: Train Loss: 2.7112, Train Accuracy: 31.19%
#     Worker 3: Train Loss: 2.6964, Train Accuracy: 31.33%
#     Worker 4: Train Loss: 2.6554, Train Accuracy: 31.73%
#     Worker 5: Train Loss: 2.6649, Train Accuracy: 32.90%
#     Worker 6: Train Loss: 2.7004, Train Accuracy: 30.87%
#     Worker 7: Train Loss: 2.6921, Train Accuracy: 31.36%
# Epoch 26/150: Test Loss: 2.4837, Test Accuracy: 36.84%
#     Worker 0: Train Loss: 2.6813, Train Accuracy: 31.55%
#     Worker 1: Train Loss: 2.6513, Train Accuracy: 32.34%
#     Worker 2: Train Loss: 2.6706, Train Accuracy: 32.28%
#     Worker 3: Train Loss: 2.6707, Train Accuracy: 31.21%
#     Worker 4: Train Loss: 2.6312, Train Accuracy: 32.59%
#     Worker 5: Train Loss: 2.6203, Train Accuracy: 33.49%
#     Worker 6: Train Loss: 2.6937, Train Accuracy: 30.78%
#     Worker 7: Train Loss: 2.6687, Train Accuracy: 31.82%
# Epoch 27/150: Test Loss: 2.4638, Test Accuracy: 37.78%
#     Worker 0: Train Loss: 2.6031, Train Accuracy: 33.03%
#     Worker 1: Train Loss: 2.6012, Train Accuracy: 32.65%
#     Worker 2: Train Loss: 2.6035, Train Accuracy: 33.30%
#     Worker 3: Train Loss: 2.6415, Train Accuracy: 32.43%
#     Worker 4: Train Loss: 2.5728, Train Accuracy: 33.87%
#     Worker 5: Train Loss: 2.6163, Train Accuracy: 33.01%
#     Worker 6: Train Loss: 2.6216, Train Accuracy: 32.40%
#     Worker 7: Train Loss: 2.6024, Train Accuracy: 33.09%
# Epoch 28/150: Test Loss: 2.4191, Test Accuracy: 38.36%
#     Worker 0: Train Loss: 2.6029, Train Accuracy: 33.89%
#     Worker 1: Train Loss: 2.5598, Train Accuracy: 34.14%
#     Worker 2: Train Loss: 2.5892, Train Accuracy: 34.01%
#     Worker 3: Train Loss: 2.6060, Train Accuracy: 33.15%
#     Worker 4: Train Loss: 2.5745, Train Accuracy: 33.88%
#     Worker 5: Train Loss: 2.5640, Train Accuracy: 33.79%
#     Worker 6: Train Loss: 2.5977, Train Accuracy: 33.17%
#     Worker 7: Train Loss: 2.5800, Train Accuracy: 33.44%
# Epoch 29/150: Test Loss: 2.4227, Test Accuracy: 38.67%
#     Worker 0: Train Loss: 2.5685, Train Accuracy: 33.29%
#     Worker 1: Train Loss: 2.5651, Train Accuracy: 33.76%
#     Worker 2: Train Loss: 2.5537, Train Accuracy: 34.69%
#     Worker 3: Train Loss: 2.5792, Train Accuracy: 33.79%
#     Worker 4: Train Loss: 2.5262, Train Accuracy: 34.79%
#     Worker 5: Train Loss: 2.5263, Train Accuracy: 35.50%
#     Worker 6: Train Loss: 2.5776, Train Accuracy: 33.54%
#     Worker 7: Train Loss: 2.5506, Train Accuracy: 34.03%
# Epoch 30/150: Test Loss: 2.3882, Test Accuracy: 39.03%
#     Worker 0: Train Loss: 2.5360, Train Accuracy: 34.54%
#     Worker 1: Train Loss: 2.5119, Train Accuracy: 34.84%
#     Worker 2: Train Loss: 2.5168, Train Accuracy: 35.68%
#     Worker 3: Train Loss: 2.5275, Train Accuracy: 34.55%
#     Worker 4: Train Loss: 2.5005, Train Accuracy: 35.55%
#     Worker 5: Train Loss: 2.4969, Train Accuracy: 35.85%
#     Worker 6: Train Loss: 2.5400, Train Accuracy: 34.24%
#     Worker 7: Train Loss: 2.5016, Train Accuracy: 35.64%
# Epoch 31/150: Test Loss: 2.3687, Test Accuracy: 39.41%
#     Worker 0: Train Loss: 2.4998, Train Accuracy: 35.08%
#     Worker 1: Train Loss: 2.4821, Train Accuracy: 35.57%
#     Worker 2: Train Loss: 2.4885, Train Accuracy: 36.01%
#     Worker 3: Train Loss: 2.5244, Train Accuracy: 34.75%
#     Worker 4: Train Loss: 2.4589, Train Accuracy: 36.49%
#     Worker 5: Train Loss: 2.4712, Train Accuracy: 36.54%
#     Worker 6: Train Loss: 2.5234, Train Accuracy: 34.37%
#     Worker 7: Train Loss: 2.4969, Train Accuracy: 35.35%
# Epoch 32/150: Test Loss: 2.3351, Test Accuracy: 40.27%
#     Worker 0: Train Loss: 2.4592, Train Accuracy: 35.75%
#     Worker 1: Train Loss: 2.4639, Train Accuracy: 35.84%
#     Worker 2: Train Loss: 2.4737, Train Accuracy: 35.79%
#     Worker 3: Train Loss: 2.5169, Train Accuracy: 35.39%
#     Worker 4: Train Loss: 2.4565, Train Accuracy: 36.36%
#     Worker 5: Train Loss: 2.4477, Train Accuracy: 36.67%
#     Worker 6: Train Loss: 2.4610, Train Accuracy: 35.70%
#     Worker 7: Train Loss: 2.4582, Train Accuracy: 36.40%
# Epoch 33/150: Test Loss: 2.3015, Test Accuracy: 40.60%
#     Worker 0: Train Loss: 2.4541, Train Accuracy: 36.46%
#     Worker 1: Train Loss: 2.4192, Train Accuracy: 36.48%
#     Worker 2: Train Loss: 2.4575, Train Accuracy: 36.92%
#     Worker 3: Train Loss: 2.4311, Train Accuracy: 35.85%
#     Worker 4: Train Loss: 2.4144, Train Accuracy: 37.09%
#     Worker 5: Train Loss: 2.4230, Train Accuracy: 37.04%
#     Worker 6: Train Loss: 2.4624, Train Accuracy: 36.41%
#     Worker 7: Train Loss: 2.4310, Train Accuracy: 37.16%
# Epoch 34/150: Test Loss: 2.2906, Test Accuracy: 40.78%
#     Worker 0: Train Loss: 2.4332, Train Accuracy: 36.88%
#     Worker 1: Train Loss: 2.3757, Train Accuracy: 37.45%
#     Worker 2: Train Loss: 2.3994, Train Accuracy: 37.32%
#     Worker 3: Train Loss: 2.4395, Train Accuracy: 36.56%
#     Worker 4: Train Loss: 2.3866, Train Accuracy: 36.79%
#     Worker 5: Train Loss: 2.3798, Train Accuracy: 38.34%
#     Worker 6: Train Loss: 2.4407, Train Accuracy: 35.89%
#     Worker 7: Train Loss: 2.4614, Train Accuracy: 35.84%
# Epoch 35/150: Test Loss: 2.2924, Test Accuracy: 40.94%
#     Worker 0: Train Loss: 2.4194, Train Accuracy: 36.78%
#     Worker 1: Train Loss: 2.3767, Train Accuracy: 37.88%
#     Worker 2: Train Loss: 2.4000, Train Accuracy: 37.56%
#     Worker 3: Train Loss: 2.4031, Train Accuracy: 36.68%
#     Worker 4: Train Loss: 2.3491, Train Accuracy: 38.54%
#     Worker 5: Train Loss: 2.3895, Train Accuracy: 38.12%
#     Worker 6: Train Loss: 2.4188, Train Accuracy: 37.14%
#     Worker 7: Train Loss: 2.3670, Train Accuracy: 38.34%
# Epoch 36/150: Test Loss: 2.2637, Test Accuracy: 41.94%
#     Worker 0: Train Loss: 2.3764, Train Accuracy: 38.25%
#     Worker 1: Train Loss: 2.3440, Train Accuracy: 38.02%
#     Worker 2: Train Loss: 2.3801, Train Accuracy: 37.84%
#     Worker 3: Train Loss: 2.3799, Train Accuracy: 37.74%
#     Worker 4: Train Loss: 2.3540, Train Accuracy: 38.37%
#     Worker 5: Train Loss: 2.3509, Train Accuracy: 38.33%
#     Worker 6: Train Loss: 2.3880, Train Accuracy: 38.03%
#     Worker 7: Train Loss: 2.3858, Train Accuracy: 37.98%
# Epoch 37/150: Test Loss: 2.2305, Test Accuracy: 42.21%
#     Worker 0: Train Loss: 2.3630, Train Accuracy: 37.61%
#     Worker 1: Train Loss: 2.3327, Train Accuracy: 38.31%
#     Worker 2: Train Loss: 2.3518, Train Accuracy: 38.48%
#     Worker 3: Train Loss: 2.3785, Train Accuracy: 37.45%
#     Worker 4: Train Loss: 2.2999, Train Accuracy: 39.18%
#     Worker 5: Train Loss: 2.3211, Train Accuracy: 39.60%
#     Worker 6: Train Loss: 2.3611, Train Accuracy: 37.37%
#     Worker 7: Train Loss: 2.3421, Train Accuracy: 38.51%
# Epoch 38/150: Test Loss: 2.2460, Test Accuracy: 41.59%
#     Worker 0: Train Loss: 2.3443, Train Accuracy: 38.53%
#     Worker 1: Train Loss: 2.2944, Train Accuracy: 39.52%
#     Worker 2: Train Loss: 2.3093, Train Accuracy: 39.49%
#     Worker 3: Train Loss: 2.3461, Train Accuracy: 38.42%
#     Worker 4: Train Loss: 2.3008, Train Accuracy: 38.74%
#     Worker 5: Train Loss: 2.3038, Train Accuracy: 40.01%
#     Worker 6: Train Loss: 2.3222, Train Accuracy: 39.13%
#     Worker 7: Train Loss: 2.3373, Train Accuracy: 38.92%
# Epoch 39/150: Test Loss: 2.2173, Test Accuracy: 42.38%
#     Worker 0: Train Loss: 2.3024, Train Accuracy: 39.42%
#     Worker 1: Train Loss: 2.2967, Train Accuracy: 39.20%
#     Worker 2: Train Loss: 2.2943, Train Accuracy: 40.43%
#     Worker 3: Train Loss: 2.3148, Train Accuracy: 39.18%
#     Worker 4: Train Loss: 2.2800, Train Accuracy: 39.52%
#     Worker 5: Train Loss: 2.2602, Train Accuracy: 40.40%
#     Worker 6: Train Loss: 2.3111, Train Accuracy: 38.07%
#     Worker 7: Train Loss: 2.2680, Train Accuracy: 40.20%
# Epoch 40/150: Test Loss: 2.2068, Test Accuracy: 42.58%
#     Worker 0: Train Loss: 2.2857, Train Accuracy: 39.80%
#     Worker 1: Train Loss: 2.2613, Train Accuracy: 40.75%
#     Worker 2: Train Loss: 2.2851, Train Accuracy: 40.29%
#     Worker 3: Train Loss: 2.2429, Train Accuracy: 41.04%
#     Worker 4: Train Loss: 2.2559, Train Accuracy: 40.84%
#     Worker 5: Train Loss: 2.2579, Train Accuracy: 41.05%
#     Worker 6: Train Loss: 2.2955, Train Accuracy: 39.73%
#     Worker 7: Train Loss: 2.2807, Train Accuracy: 40.10%
# Epoch 41/150: Test Loss: 2.1899, Test Accuracy: 43.12%
#     Worker 0: Train Loss: 2.2575, Train Accuracy: 40.53%
#     Worker 1: Train Loss: 2.2325, Train Accuracy: 40.37%
#     Worker 2: Train Loss: 2.2525, Train Accuracy: 40.10%
#     Worker 3: Train Loss: 2.2952, Train Accuracy: 39.60%
#     Worker 4: Train Loss: 2.2147, Train Accuracy: 40.80%
#     Worker 5: Train Loss: 2.2296, Train Accuracy: 41.13%
#     Worker 6: Train Loss: 2.2776, Train Accuracy: 40.50%
#     Worker 7: Train Loss: 2.2406, Train Accuracy: 40.53%
# Epoch 42/150: Test Loss: 2.1716, Test Accuracy: 43.43%
#     Worker 0: Train Loss: 2.2307, Train Accuracy: 40.78%
#     Worker 1: Train Loss: 2.2105, Train Accuracy: 40.89%
#     Worker 2: Train Loss: 2.2451, Train Accuracy: 41.49%
#     Worker 3: Train Loss: 2.2454, Train Accuracy: 40.66%
#     Worker 4: Train Loss: 2.1830, Train Accuracy: 42.24%
#     Worker 5: Train Loss: 2.2361, Train Accuracy: 41.71%
#     Worker 6: Train Loss: 2.2530, Train Accuracy: 40.86%
#     Worker 7: Train Loss: 2.2450, Train Accuracy: 41.10%
# Epoch 43/150: Test Loss: 2.1707, Test Accuracy: 43.17%
#     Worker 0: Train Loss: 2.2037, Train Accuracy: 41.83%
#     Worker 1: Train Loss: 2.2060, Train Accuracy: 41.76%
#     Worker 2: Train Loss: 2.1916, Train Accuracy: 42.26%
#     Worker 3: Train Loss: 2.1997, Train Accuracy: 41.38%
#     Worker 4: Train Loss: 2.1705, Train Accuracy: 42.19%
#     Worker 5: Train Loss: 2.1690, Train Accuracy: 43.09%
#     Worker 6: Train Loss: 2.2129, Train Accuracy: 41.18%
#     Worker 7: Train Loss: 2.1881, Train Accuracy: 41.95%
# Epoch 44/150: Test Loss: 2.1582, Test Accuracy: 44.11%
#     Worker 0: Train Loss: 2.2121, Train Accuracy: 41.00%
#     Worker 1: Train Loss: 2.1489, Train Accuracy: 42.63%
#     Worker 2: Train Loss: 2.1790, Train Accuracy: 42.01%
#     Worker 3: Train Loss: 2.2221, Train Accuracy: 41.48%
#     Worker 4: Train Loss: 2.1761, Train Accuracy: 42.26%
#     Worker 5: Train Loss: 2.1554, Train Accuracy: 43.04%
#     Worker 6: Train Loss: 2.2212, Train Accuracy: 41.08%
#     Worker 7: Train Loss: 2.2153, Train Accuracy: 40.91%
# Epoch 45/150: Test Loss: 2.1485, Test Accuracy: 44.06%
#     Worker 0: Train Loss: 2.1692, Train Accuracy: 42.84%
#     Worker 1: Train Loss: 2.1420, Train Accuracy: 42.42%
#     Worker 2: Train Loss: 2.1609, Train Accuracy: 43.12%
#     Worker 3: Train Loss: 2.2214, Train Accuracy: 41.03%
#     Worker 4: Train Loss: 2.1528, Train Accuracy: 43.34%
#     Worker 5: Train Loss: 2.1625, Train Accuracy: 42.91%
#     Worker 6: Train Loss: 2.1744, Train Accuracy: 42.30%
#     Worker 7: Train Loss: 2.1865, Train Accuracy: 42.41%
# Epoch 46/150: Test Loss: 2.1343, Test Accuracy: 44.23%
#     Worker 0: Train Loss: 2.1632, Train Accuracy: 42.42%
#     Worker 1: Train Loss: 2.1355, Train Accuracy: 43.38%
#     Worker 2: Train Loss: 2.1394, Train Accuracy: 43.54%
#     Worker 3: Train Loss: 2.1612, Train Accuracy: 42.16%
#     Worker 4: Train Loss: 2.1025, Train Accuracy: 43.77%
#     Worker 5: Train Loss: 2.1548, Train Accuracy: 43.27%
#     Worker 6: Train Loss: 2.1502, Train Accuracy: 42.62%
#     Worker 7: Train Loss: 2.1550, Train Accuracy: 43.11%
# Epoch 47/150: Test Loss: 2.1150, Test Accuracy: 44.54%
#     Worker 0: Train Loss: 2.1348, Train Accuracy: 43.01%
#     Worker 1: Train Loss: 2.0872, Train Accuracy: 44.32%
#     Worker 2: Train Loss: 2.1440, Train Accuracy: 43.30%
#     Worker 3: Train Loss: 2.1585, Train Accuracy: 42.31%
#     Worker 4: Train Loss: 2.0911, Train Accuracy: 44.20%
#     Worker 5: Train Loss: 2.1014, Train Accuracy: 44.57%
#     Worker 6: Train Loss: 2.1361, Train Accuracy: 42.94%
#     Worker 7: Train Loss: 2.1220, Train Accuracy: 43.01%
# Epoch 48/150: Test Loss: 2.1093, Test Accuracy: 44.84%
#     Worker 0: Train Loss: 2.1275, Train Accuracy: 43.57%
#     Worker 1: Train Loss: 2.0838, Train Accuracy: 44.09%
#     Worker 2: Train Loss: 2.1356, Train Accuracy: 42.73%
#     Worker 3: Train Loss: 2.1130, Train Accuracy: 43.39%
#     Worker 4: Train Loss: 2.0843, Train Accuracy: 43.79%
#     Worker 5: Train Loss: 2.1013, Train Accuracy: 44.11%
#     Worker 6: Train Loss: 2.1395, Train Accuracy: 42.67%
#     Worker 7: Train Loss: 2.1157, Train Accuracy: 42.96%
# Epoch 49/150: Test Loss: 2.1001, Test Accuracy: 45.02%
#     Worker 0: Train Loss: 2.0959, Train Accuracy: 44.26%
#     Worker 1: Train Loss: 2.0895, Train Accuracy: 43.63%
#     Worker 2: Train Loss: 2.0855, Train Accuracy: 44.61%
#     Worker 3: Train Loss: 2.1283, Train Accuracy: 43.18%
#     Worker 4: Train Loss: 2.0560, Train Accuracy: 45.00%
#     Worker 5: Train Loss: 2.0675, Train Accuracy: 45.12%
#     Worker 6: Train Loss: 2.1044, Train Accuracy: 43.68%
#     Worker 7: Train Loss: 2.0906, Train Accuracy: 43.95%
# Epoch 50/150: Test Loss: 2.0959, Test Accuracy: 45.35%
#     Worker 0: Train Loss: 2.0810, Train Accuracy: 43.88%
#     Worker 1: Train Loss: 2.0436, Train Accuracy: 45.45%
#     Worker 2: Train Loss: 2.0605, Train Accuracy: 44.96%
#     Worker 3: Train Loss: 2.0876, Train Accuracy: 43.64%
#     Worker 4: Train Loss: 2.0520, Train Accuracy: 44.77%
#     Worker 5: Train Loss: 2.0749, Train Accuracy: 44.96%
#     Worker 6: Train Loss: 2.1104, Train Accuracy: 43.72%
#     Worker 7: Train Loss: 2.0693, Train Accuracy: 44.58%
# Epoch 51/150: Test Loss: 2.0858, Test Accuracy: 45.45%
#     Worker 0: Train Loss: 2.0919, Train Accuracy: 44.48%
#     Worker 1: Train Loss: 2.0671, Train Accuracy: 43.99%
#     Worker 2: Train Loss: 2.0591, Train Accuracy: 45.17%
#     Worker 3: Train Loss: 2.0853, Train Accuracy: 43.70%
#     Worker 4: Train Loss: 2.0264, Train Accuracy: 45.86%
#     Worker 5: Train Loss: 2.0570, Train Accuracy: 45.18%
#     Worker 6: Train Loss: 2.0748, Train Accuracy: 44.54%
#     Worker 7: Train Loss: 2.0543, Train Accuracy: 45.20%
# Epoch 52/150: Test Loss: 2.0872, Test Accuracy: 45.73%
#     Worker 0: Train Loss: 2.0475, Train Accuracy: 44.68%
#     Worker 1: Train Loss: 2.0495, Train Accuracy: 44.66%
#     Worker 2: Train Loss: 2.0205, Train Accuracy: 45.85%
#     Worker 3: Train Loss: 2.0606, Train Accuracy: 44.71%
#     Worker 4: Train Loss: 2.0260, Train Accuracy: 45.53%
#     Worker 5: Train Loss: 2.0240, Train Accuracy: 46.57%
#     Worker 6: Train Loss: 2.0769, Train Accuracy: 44.55%
#     Worker 7: Train Loss: 2.0374, Train Accuracy: 45.04%
# Epoch 53/150: Test Loss: 2.0691, Test Accuracy: 46.03%
#     Worker 0: Train Loss: 2.0151, Train Accuracy: 45.24%
#     Worker 1: Train Loss: 1.9660, Train Accuracy: 47.03%
#     Worker 2: Train Loss: 2.0310, Train Accuracy: 45.86%
#     Worker 3: Train Loss: 2.0323, Train Accuracy: 45.58%
#     Worker 4: Train Loss: 1.9758, Train Accuracy: 46.08%
#     Worker 5: Train Loss: 1.9944, Train Accuracy: 46.77%
#     Worker 6: Train Loss: 2.0406, Train Accuracy: 45.67%
#     Worker 7: Train Loss: 2.0037, Train Accuracy: 45.63%
# Epoch 54/150: Test Loss: 2.0711, Test Accuracy: 45.89%
#     Worker 0: Train Loss: 2.0173, Train Accuracy: 45.70%
#     Worker 1: Train Loss: 1.9769, Train Accuracy: 46.51%
#     Worker 2: Train Loss: 1.9830, Train Accuracy: 47.23%
#     Worker 3: Train Loss: 2.0125, Train Accuracy: 45.59%
#     Worker 4: Train Loss: 1.9693, Train Accuracy: 47.20%
#     Worker 5: Train Loss: 1.9983, Train Accuracy: 45.76%
#     Worker 6: Train Loss: 2.0203, Train Accuracy: 45.94%
#     Worker 7: Train Loss: 2.0404, Train Accuracy: 45.30%
# Epoch 55/150: Test Loss: 2.0489, Test Accuracy: 46.58%
#     Worker 0: Train Loss: 2.0122, Train Accuracy: 45.62%
#     Worker 1: Train Loss: 1.9642, Train Accuracy: 47.00%
#     Worker 2: Train Loss: 1.9808, Train Accuracy: 46.61%
#     Worker 3: Train Loss: 1.9910, Train Accuracy: 46.23%
#     Worker 4: Train Loss: 1.9769, Train Accuracy: 47.10%
#     Worker 5: Train Loss: 1.9707, Train Accuracy: 46.72%
#     Worker 6: Train Loss: 1.9866, Train Accuracy: 46.70%
#     Worker 7: Train Loss: 1.9828, Train Accuracy: 46.13%
# Epoch 56/150: Test Loss: 2.0446, Test Accuracy: 46.80%
#     Worker 0: Train Loss: 1.9716, Train Accuracy: 47.31%
#     Worker 1: Train Loss: 1.9470, Train Accuracy: 46.93%
#     Worker 2: Train Loss: 1.9362, Train Accuracy: 48.18%
#     Worker 3: Train Loss: 1.9863, Train Accuracy: 46.64%
#     Worker 4: Train Loss: 1.9554, Train Accuracy: 47.25%
#     Worker 5: Train Loss: 1.9778, Train Accuracy: 47.55%
#     Worker 6: Train Loss: 1.9872, Train Accuracy: 46.32%
#     Worker 7: Train Loss: 1.9731, Train Accuracy: 47.45%
# Epoch 57/150: Test Loss: 2.0377, Test Accuracy: 46.76%
#     Worker 0: Train Loss: 1.9520, Train Accuracy: 46.89%
#     Worker 1: Train Loss: 1.9317, Train Accuracy: 47.88%
#     Worker 2: Train Loss: 1.9664, Train Accuracy: 47.26%
#     Worker 3: Train Loss: 1.9629, Train Accuracy: 46.00%
#     Worker 4: Train Loss: 1.9303, Train Accuracy: 47.31%
#     Worker 5: Train Loss: 1.9628, Train Accuracy: 47.16%
#     Worker 6: Train Loss: 1.9613, Train Accuracy: 47.23%
#     Worker 7: Train Loss: 1.9522, Train Accuracy: 47.33%
# Epoch 58/150: Test Loss: 2.0343, Test Accuracy: 46.88%
#     Worker 0: Train Loss: 1.9239, Train Accuracy: 47.56%
#     Worker 1: Train Loss: 1.8961, Train Accuracy: 47.53%
#     Worker 2: Train Loss: 1.9333, Train Accuracy: 48.09%
#     Worker 3: Train Loss: 1.9626, Train Accuracy: 46.83%
#     Worker 4: Train Loss: 1.8987, Train Accuracy: 48.29%
#     Worker 5: Train Loss: 1.9097, Train Accuracy: 48.76%
#     Worker 6: Train Loss: 1.9567, Train Accuracy: 47.07%
#     Worker 7: Train Loss: 1.9585, Train Accuracy: 47.03%
# Epoch 59/150: Test Loss: 2.0229, Test Accuracy: 47.21%
#     Worker 0: Train Loss: 1.9340, Train Accuracy: 47.15%
#     Worker 1: Train Loss: 1.8940, Train Accuracy: 48.56%
#     Worker 2: Train Loss: 1.9051, Train Accuracy: 48.37%
#     Worker 3: Train Loss: 1.9404, Train Accuracy: 47.31%
#     Worker 4: Train Loss: 1.8925, Train Accuracy: 48.86%
#     Worker 5: Train Loss: 1.9197, Train Accuracy: 48.63%
#     Worker 6: Train Loss: 1.9388, Train Accuracy: 47.21%
#     Worker 7: Train Loss: 1.9320, Train Accuracy: 47.16%
# Epoch 60/150: Test Loss: 2.0252, Test Accuracy: 47.01%
#     Worker 0: Train Loss: 1.9012, Train Accuracy: 48.24%
#     Worker 1: Train Loss: 1.8913, Train Accuracy: 47.72%
#     Worker 2: Train Loss: 1.8930, Train Accuracy: 47.98%
#     Worker 3: Train Loss: 1.9266, Train Accuracy: 48.04%
#     Worker 4: Train Loss: 1.8942, Train Accuracy: 48.25%
#     Worker 5: Train Loss: 1.9225, Train Accuracy: 48.65%
#     Worker 6: Train Loss: 1.9446, Train Accuracy: 46.76%
#     Worker 7: Train Loss: 1.9130, Train Accuracy: 48.03%
# Epoch 61/150: Test Loss: 2.0136, Test Accuracy: 47.02%
#     Worker 0: Train Loss: 1.9177, Train Accuracy: 48.35%
#     Worker 1: Train Loss: 1.8746, Train Accuracy: 48.75%
#     Worker 2: Train Loss: 1.8798, Train Accuracy: 49.44%
#     Worker 3: Train Loss: 1.9152, Train Accuracy: 47.71%
#     Worker 4: Train Loss: 1.8730, Train Accuracy: 49.08%
#     Worker 5: Train Loss: 1.8825, Train Accuracy: 49.52%
#     Worker 6: Train Loss: 1.9196, Train Accuracy: 48.05%
#     Worker 7: Train Loss: 1.8936, Train Accuracy: 48.36%
# Epoch 62/150: Test Loss: 2.0110, Test Accuracy: 47.49%
#     Worker 0: Train Loss: 1.8744, Train Accuracy: 48.90%
#     Worker 1: Train Loss: 1.8566, Train Accuracy: 49.08%
#     Worker 2: Train Loss: 1.8744, Train Accuracy: 49.14%
#     Worker 3: Train Loss: 1.9083, Train Accuracy: 48.48%
#     Worker 4: Train Loss: 1.8677, Train Accuracy: 49.33%
#     Worker 5: Train Loss: 1.8623, Train Accuracy: 49.34%
#     Worker 6: Train Loss: 1.8753, Train Accuracy: 49.39%
#     Worker 7: Train Loss: 1.8807, Train Accuracy: 48.57%
# Epoch 63/150: Test Loss: 2.0003, Test Accuracy: 47.57%
#     Worker 0: Train Loss: 1.8662, Train Accuracy: 48.28%
#     Worker 1: Train Loss: 1.8600, Train Accuracy: 48.42%
#     Worker 2: Train Loss: 1.8592, Train Accuracy: 49.85%
#     Worker 3: Train Loss: 1.8639, Train Accuracy: 49.35%
#     Worker 4: Train Loss: 1.8180, Train Accuracy: 50.02%
#     Worker 5: Train Loss: 1.8445, Train Accuracy: 49.98%
#     Worker 6: Train Loss: 1.8644, Train Accuracy: 49.75%
#     Worker 7: Train Loss: 1.8438, Train Accuracy: 49.28%
# Epoch 64/150: Test Loss: 1.9991, Test Accuracy: 47.80%
#     Worker 0: Train Loss: 1.8680, Train Accuracy: 49.25%
#     Worker 1: Train Loss: 1.8073, Train Accuracy: 50.70%
#     Worker 2: Train Loss: 1.8404, Train Accuracy: 50.18%
#     Worker 3: Train Loss: 1.8763, Train Accuracy: 48.80%
#     Worker 4: Train Loss: 1.8236, Train Accuracy: 50.32%
#     Worker 5: Train Loss: 1.8637, Train Accuracy: 49.52%
#     Worker 6: Train Loss: 1.9047, Train Accuracy: 48.24%
#     Worker 7: Train Loss: 1.8722, Train Accuracy: 48.59%
# Epoch 65/150: Test Loss: 1.9904, Test Accuracy: 48.01%
#     Worker 0: Train Loss: 1.8428, Train Accuracy: 49.57%
#     Worker 1: Train Loss: 1.8174, Train Accuracy: 49.57%
#     Worker 2: Train Loss: 1.8284, Train Accuracy: 50.02%
#     Worker 3: Train Loss: 1.8785, Train Accuracy: 48.14%
#     Worker 4: Train Loss: 1.8119, Train Accuracy: 50.59%
#     Worker 5: Train Loss: 1.8306, Train Accuracy: 50.01%
#     Worker 6: Train Loss: 1.8445, Train Accuracy: 49.65%
#     Worker 7: Train Loss: 1.8384, Train Accuracy: 49.62%
# Epoch 66/150: Test Loss: 2.0006, Test Accuracy: 47.74%
#     Worker 0: Train Loss: 1.8097, Train Accuracy: 49.44%
#     Worker 1: Train Loss: 1.7595, Train Accuracy: 51.07%
#     Worker 2: Train Loss: 1.7854, Train Accuracy: 50.71%
#     Worker 3: Train Loss: 1.8183, Train Accuracy: 49.75%
#     Worker 4: Train Loss: 1.7878, Train Accuracy: 50.99%
#     Worker 5: Train Loss: 1.8022, Train Accuracy: 51.03%
#     Worker 6: Train Loss: 1.8163, Train Accuracy: 49.98%
#     Worker 7: Train Loss: 1.7906, Train Accuracy: 50.21%
# Epoch 67/150: Test Loss: 1.9815, Test Accuracy: 48.42%
#     Worker 0: Train Loss: 1.7926, Train Accuracy: 50.37%
#     Worker 1: Train Loss: 1.8035, Train Accuracy: 50.07%
#     Worker 2: Train Loss: 1.7860, Train Accuracy: 51.24%
#     Worker 3: Train Loss: 1.8039, Train Accuracy: 50.39%
#     Worker 4: Train Loss: 1.7764, Train Accuracy: 51.05%
#     Worker 5: Train Loss: 1.7916, Train Accuracy: 51.40%
#     Worker 6: Train Loss: 1.8202, Train Accuracy: 49.88%
#     Worker 7: Train Loss: 1.7958, Train Accuracy: 50.56%
# Epoch 68/150: Test Loss: 1.9803, Test Accuracy: 48.50%
#     Worker 0: Train Loss: 1.8110, Train Accuracy: 50.72%
#     Worker 1: Train Loss: 1.7565, Train Accuracy: 52.06%
#     Worker 2: Train Loss: 1.8026, Train Accuracy: 50.73%
#     Worker 3: Train Loss: 1.8171, Train Accuracy: 50.37%
#     Worker 4: Train Loss: 1.7658, Train Accuracy: 51.66%
#     Worker 5: Train Loss: 1.7714, Train Accuracy: 51.88%
#     Worker 6: Train Loss: 1.8106, Train Accuracy: 50.48%
#     Worker 7: Train Loss: 1.7774, Train Accuracy: 51.16%
# Epoch 69/150: Test Loss: 1.9806, Test Accuracy: 48.66%
#     Worker 0: Train Loss: 1.7646, Train Accuracy: 51.89%
#     Worker 1: Train Loss: 1.7055, Train Accuracy: 53.76%
#     Worker 2: Train Loss: 1.7672, Train Accuracy: 51.25%
#     Worker 3: Train Loss: 1.7837, Train Accuracy: 50.96%
#     Worker 4: Train Loss: 1.7600, Train Accuracy: 51.60%
#     Worker 5: Train Loss: 1.7611, Train Accuracy: 52.59%
#     Worker 6: Train Loss: 1.7984, Train Accuracy: 50.65%
#     Worker 7: Train Loss: 1.7558, Train Accuracy: 52.06%
# Epoch 70/150: Test Loss: 1.9814, Test Accuracy: 48.32%
#     Worker 0: Train Loss: 1.7730, Train Accuracy: 51.30%
#     Worker 1: Train Loss: 1.7253, Train Accuracy: 52.67%
#     Worker 2: Train Loss: 1.7299, Train Accuracy: 52.74%
#     Worker 3: Train Loss: 1.7880, Train Accuracy: 51.26%
#     Worker 4: Train Loss: 1.7419, Train Accuracy: 51.58%
#     Worker 5: Train Loss: 1.7498, Train Accuracy: 52.15%
#     Worker 6: Train Loss: 1.7625, Train Accuracy: 51.53%
#     Worker 7: Train Loss: 1.7569, Train Accuracy: 52.02%
# Epoch 71/150: Test Loss: 1.9704, Test Accuracy: 48.63%
#     Worker 0: Train Loss: 1.7628, Train Accuracy: 50.87%
#     Worker 1: Train Loss: 1.7370, Train Accuracy: 51.85%
#     Worker 2: Train Loss: 1.7293, Train Accuracy: 52.36%
#     Worker 3: Train Loss: 1.7668, Train Accuracy: 51.65%
#     Worker 4: Train Loss: 1.7437, Train Accuracy: 52.11%
#     Worker 5: Train Loss: 1.7562, Train Accuracy: 52.03%
#     Worker 6: Train Loss: 1.8005, Train Accuracy: 50.51%
#     Worker 7: Train Loss: 1.7369, Train Accuracy: 52.08%
# Epoch 72/150: Test Loss: 1.9698, Test Accuracy: 48.49%
#     Worker 0: Train Loss: 1.7147, Train Accuracy: 52.60%
#     Worker 1: Train Loss: 1.7025, Train Accuracy: 52.72%
#     Worker 2: Train Loss: 1.7238, Train Accuracy: 52.49%
#     Worker 3: Train Loss: 1.7426, Train Accuracy: 52.34%
#     Worker 4: Train Loss: 1.6911, Train Accuracy: 53.40%
#     Worker 5: Train Loss: 1.7191, Train Accuracy: 52.98%
#     Worker 6: Train Loss: 1.7603, Train Accuracy: 51.89%
#     Worker 7: Train Loss: 1.7287, Train Accuracy: 52.21%
# Epoch 73/150: Test Loss: 1.9656, Test Accuracy: 48.78%
#     Worker 0: Train Loss: 1.7381, Train Accuracy: 51.57%
#     Worker 1: Train Loss: 1.6904, Train Accuracy: 53.75%
#     Worker 2: Train Loss: 1.7148, Train Accuracy: 53.35%
#     Worker 3: Train Loss: 1.7422, Train Accuracy: 52.35%
#     Worker 4: Train Loss: 1.6744, Train Accuracy: 53.61%
#     Worker 5: Train Loss: 1.7226, Train Accuracy: 52.71%
#     Worker 6: Train Loss: 1.7211, Train Accuracy: 52.41%
#     Worker 7: Train Loss: 1.7203, Train Accuracy: 52.93%
# Epoch 74/150: Test Loss: 1.9700, Test Accuracy: 48.51%
#     Worker 0: Train Loss: 1.7225, Train Accuracy: 52.20%
#     Worker 1: Train Loss: 1.6858, Train Accuracy: 53.13%
#     Worker 2: Train Loss: 1.6935, Train Accuracy: 53.27%
#     Worker 3: Train Loss: 1.7186, Train Accuracy: 51.88%
#     Worker 4: Train Loss: 1.6846, Train Accuracy: 53.60%
#     Worker 5: Train Loss: 1.6966, Train Accuracy: 53.15%
#     Worker 6: Train Loss: 1.7403, Train Accuracy: 52.22%
#     Worker 7: Train Loss: 1.6826, Train Accuracy: 53.61%
# Epoch 75/150: Test Loss: 1.9641, Test Accuracy: 48.99%
#     Worker 0: Train Loss: 1.7232, Train Accuracy: 52.64%
#     Worker 1: Train Loss: 1.6832, Train Accuracy: 53.21%
#     Worker 2: Train Loss: 1.6987, Train Accuracy: 53.59%
#     Worker 3: Train Loss: 1.7182, Train Accuracy: 52.72%
#     Worker 4: Train Loss: 1.6983, Train Accuracy: 52.73%
#     Worker 5: Train Loss: 1.6830, Train Accuracy: 53.55%
#     Worker 6: Train Loss: 1.7161, Train Accuracy: 52.53%
#     Worker 7: Train Loss: 1.6783, Train Accuracy: 53.18%
# Epoch 76/150: Test Loss: 1.9639, Test Accuracy: 49.03%
#     Worker 0: Train Loss: 1.6634, Train Accuracy: 53.46%
#     Worker 1: Train Loss: 1.6417, Train Accuracy: 54.26%
#     Worker 2: Train Loss: 1.6625, Train Accuracy: 53.88%
#     Worker 3: Train Loss: 1.6794, Train Accuracy: 53.44%
#     Worker 4: Train Loss: 1.6479, Train Accuracy: 54.11%
#     Worker 5: Train Loss: 1.6541, Train Accuracy: 55.19%
#     Worker 6: Train Loss: 1.7031, Train Accuracy: 53.19%
#     Worker 7: Train Loss: 1.6522, Train Accuracy: 54.14%
# Epoch 77/150: Test Loss: 1.9582, Test Accuracy: 49.02%
#     Worker 0: Train Loss: 1.6888, Train Accuracy: 53.75%
#     Worker 1: Train Loss: 1.6449, Train Accuracy: 54.15%
#     Worker 2: Train Loss: 1.6658, Train Accuracy: 53.70%
#     Worker 3: Train Loss: 1.6962, Train Accuracy: 52.77%
#     Worker 4: Train Loss: 1.6507, Train Accuracy: 54.26%
#     Worker 5: Train Loss: 1.6677, Train Accuracy: 54.05%
#     Worker 6: Train Loss: 1.6976, Train Accuracy: 53.60%
#     Worker 7: Train Loss: 1.6520, Train Accuracy: 54.09%
# Epoch 78/150: Test Loss: 1.9571, Test Accuracy: 48.94%
#     Worker 0: Train Loss: 1.6624, Train Accuracy: 54.12%
#     Worker 1: Train Loss: 1.6375, Train Accuracy: 54.52%
#     Worker 2: Train Loss: 1.6227, Train Accuracy: 55.17%
#     Worker 3: Train Loss: 1.6503, Train Accuracy: 53.73%
#     Worker 4: Train Loss: 1.6426, Train Accuracy: 54.05%
#     Worker 5: Train Loss: 1.6694, Train Accuracy: 54.21%
#     Worker 6: Train Loss: 1.6728, Train Accuracy: 53.17%
#     Worker 7: Train Loss: 1.6662, Train Accuracy: 53.88%
# Epoch 79/150: Test Loss: 1.9513, Test Accuracy: 49.62%
#     Worker 0: Train Loss: 1.6685, Train Accuracy: 53.45%
#     Worker 1: Train Loss: 1.6118, Train Accuracy: 55.35%
#     Worker 2: Train Loss: 1.6118, Train Accuracy: 54.95%
#     Worker 3: Train Loss: 1.6550, Train Accuracy: 53.83%
#     Worker 4: Train Loss: 1.6044, Train Accuracy: 55.36%
#     Worker 5: Train Loss: 1.6382, Train Accuracy: 54.68%
#     Worker 6: Train Loss: 1.6328, Train Accuracy: 55.24%
#     Worker 7: Train Loss: 1.6258, Train Accuracy: 55.14%
# Epoch 80/150: Test Loss: 1.9636, Test Accuracy: 48.99%
#     Worker 0: Train Loss: 1.6062, Train Accuracy: 55.36%
#     Worker 1: Train Loss: 1.6199, Train Accuracy: 55.52%
#     Worker 2: Train Loss: 1.5722, Train Accuracy: 56.00%
#     Worker 3: Train Loss: 1.6322, Train Accuracy: 54.64%
#     Worker 4: Train Loss: 1.6031, Train Accuracy: 55.29%
#     Worker 5: Train Loss: 1.5947, Train Accuracy: 56.45%
#     Worker 6: Train Loss: 1.6755, Train Accuracy: 54.10%
#     Worker 7: Train Loss: 1.6318, Train Accuracy: 54.72%
# Epoch 81/150: Test Loss: 1.9553, Test Accuracy: 49.11%
#     Worker 0: Train Loss: 1.6163, Train Accuracy: 54.68%
#     Worker 1: Train Loss: 1.5779, Train Accuracy: 55.84%
#     Worker 2: Train Loss: 1.6029, Train Accuracy: 55.37%
#     Worker 3: Train Loss: 1.6557, Train Accuracy: 53.92%
#     Worker 4: Train Loss: 1.6353, Train Accuracy: 54.53%
#     Worker 5: Train Loss: 1.6289, Train Accuracy: 55.64%
#     Worker 6: Train Loss: 1.6226, Train Accuracy: 54.92%
#     Worker 7: Train Loss: 1.6264, Train Accuracy: 55.23%
# Epoch 82/150: Test Loss: 1.9439, Test Accuracy: 49.88%
#     Worker 0: Train Loss: 1.6015, Train Accuracy: 55.12%
#     Worker 1: Train Loss: 1.5919, Train Accuracy: 55.71%
#     Worker 2: Train Loss: 1.6072, Train Accuracy: 54.86%
#     Worker 3: Train Loss: 1.5981, Train Accuracy: 55.28%
#     Worker 4: Train Loss: 1.5852, Train Accuracy: 56.36%
#     Worker 5: Train Loss: 1.6023, Train Accuracy: 55.95%
#     Worker 6: Train Loss: 1.6359, Train Accuracy: 54.53%
#     Worker 7: Train Loss: 1.5770, Train Accuracy: 56.03%
# Epoch 83/150: Test Loss: 1.9440, Test Accuracy: 49.99%
#     Worker 0: Train Loss: 1.6120, Train Accuracy: 55.69%
#     Worker 1: Train Loss: 1.5951, Train Accuracy: 55.86%
#     Worker 2: Train Loss: 1.5723, Train Accuracy: 56.05%
#     Worker 3: Train Loss: 1.6106, Train Accuracy: 55.53%
#     Worker 4: Train Loss: 1.5748, Train Accuracy: 56.07%
#     Worker 5: Train Loss: 1.5951, Train Accuracy: 55.76%
#     Worker 6: Train Loss: 1.5849, Train Accuracy: 56.33%
#     Worker 7: Train Loss: 1.6086, Train Accuracy: 54.98%
# Epoch 84/150: Test Loss: 1.9483, Test Accuracy: 49.91%
#     Worker 0: Train Loss: 1.5980, Train Accuracy: 55.95%
#     Worker 1: Train Loss: 1.5654, Train Accuracy: 56.71%
#     Worker 2: Train Loss: 1.5793, Train Accuracy: 55.81%
#     Worker 3: Train Loss: 1.6107, Train Accuracy: 54.76%
#     Worker 4: Train Loss: 1.5504, Train Accuracy: 56.60%
#     Worker 5: Train Loss: 1.5677, Train Accuracy: 56.45%
#     Worker 6: Train Loss: 1.6357, Train Accuracy: 54.03%
#     Worker 7: Train Loss: 1.5449, Train Accuracy: 56.08%
# Epoch 85/150: Test Loss: 1.9402, Test Accuracy: 49.96%
#     Worker 0: Train Loss: 1.5819, Train Accuracy: 56.03%
#     Worker 1: Train Loss: 1.5682, Train Accuracy: 56.43%
#     Worker 2: Train Loss: 1.5582, Train Accuracy: 56.89%
#     Worker 3: Train Loss: 1.5759, Train Accuracy: 56.41%
#     Worker 4: Train Loss: 1.5498, Train Accuracy: 56.35%
#     Worker 5: Train Loss: 1.5860, Train Accuracy: 56.33%
#     Worker 6: Train Loss: 1.6069, Train Accuracy: 55.33%
#     Worker 7: Train Loss: 1.5756, Train Accuracy: 55.79%
# Epoch 86/150: Test Loss: 1.9481, Test Accuracy: 50.01%
#     Worker 0: Train Loss: 1.5754, Train Accuracy: 55.91%
#     Worker 1: Train Loss: 1.5301, Train Accuracy: 57.22%
#     Worker 2: Train Loss: 1.5378, Train Accuracy: 56.77%
#     Worker 3: Train Loss: 1.6021, Train Accuracy: 55.07%
#     Worker 4: Train Loss: 1.5434, Train Accuracy: 57.16%
#     Worker 5: Train Loss: 1.5574, Train Accuracy: 56.51%
#     Worker 6: Train Loss: 1.5578, Train Accuracy: 56.35%
#     Worker 7: Train Loss: 1.5671, Train Accuracy: 56.56%
# Epoch 87/150: Test Loss: 1.9372, Test Accuracy: 49.91%
#     Worker 0: Train Loss: 1.5642, Train Accuracy: 56.07%
#     Worker 1: Train Loss: 1.5240, Train Accuracy: 57.34%
#     Worker 2: Train Loss: 1.5457, Train Accuracy: 57.01%
#     Worker 3: Train Loss: 1.5736, Train Accuracy: 56.28%
#     Worker 4: Train Loss: 1.5299, Train Accuracy: 56.76%
#     Worker 5: Train Loss: 1.5558, Train Accuracy: 56.77%
#     Worker 6: Train Loss: 1.5582, Train Accuracy: 57.12%
#     Worker 7: Train Loss: 1.5376, Train Accuracy: 57.18%
# Epoch 88/150: Test Loss: 1.9412, Test Accuracy: 50.10%
#     Worker 0: Train Loss: 1.5475, Train Accuracy: 56.25%
#     Worker 1: Train Loss: 1.5323, Train Accuracy: 57.20%
#     Worker 2: Train Loss: 1.5108, Train Accuracy: 57.64%
#     Worker 3: Train Loss: 1.5414, Train Accuracy: 56.72%
#     Worker 4: Train Loss: 1.5265, Train Accuracy: 56.85%
#     Worker 5: Train Loss: 1.5471, Train Accuracy: 57.12%
#     Worker 6: Train Loss: 1.5524, Train Accuracy: 56.70%
#     Worker 7: Train Loss: 1.5338, Train Accuracy: 57.52%
# Epoch 89/150: Test Loss: 1.9472, Test Accuracy: 49.84%
#     Worker 0: Train Loss: 1.5140, Train Accuracy: 57.20%
#     Worker 1: Train Loss: 1.4813, Train Accuracy: 58.51%
#     Worker 2: Train Loss: 1.5018, Train Accuracy: 58.54%
#     Worker 3: Train Loss: 1.5179, Train Accuracy: 57.39%
#     Worker 4: Train Loss: 1.4943, Train Accuracy: 57.51%
#     Worker 5: Train Loss: 1.5097, Train Accuracy: 57.82%
#     Worker 6: Train Loss: 1.5391, Train Accuracy: 57.14%
#     Worker 7: Train Loss: 1.5042, Train Accuracy: 57.51%
# Epoch 90/150: Test Loss: 1.9511, Test Accuracy: 50.00%
#     Worker 0: Train Loss: 1.5327, Train Accuracy: 57.12%
#     Worker 1: Train Loss: 1.4965, Train Accuracy: 58.35%
#     Worker 2: Train Loss: 1.4928, Train Accuracy: 58.45%
#     Worker 3: Train Loss: 1.5428, Train Accuracy: 57.38%
#     Worker 4: Train Loss: 1.4763, Train Accuracy: 58.45%
#     Worker 5: Train Loss: 1.5303, Train Accuracy: 57.37%
#     Worker 6: Train Loss: 1.5279, Train Accuracy: 57.34%
#     Worker 7: Train Loss: 1.5209, Train Accuracy: 57.55%
# Epoch 91/150: Test Loss: 1.9381, Test Accuracy: 50.04%
#     Worker 0: Train Loss: 1.5050, Train Accuracy: 58.59%
#     Worker 1: Train Loss: 1.4850, Train Accuracy: 58.56%
#     Worker 2: Train Loss: 1.5022, Train Accuracy: 58.49%
#     Worker 3: Train Loss: 1.5360, Train Accuracy: 56.87%
#     Worker 4: Train Loss: 1.4791, Train Accuracy: 58.75%
#     Worker 5: Train Loss: 1.4937, Train Accuracy: 58.07%
#     Worker 6: Train Loss: 1.5263, Train Accuracy: 57.60%
#     Worker 7: Train Loss: 1.4915, Train Accuracy: 58.00%
# Epoch 92/150: Test Loss: 1.9479, Test Accuracy: 49.91%
#     Worker 0: Train Loss: 1.4986, Train Accuracy: 57.57%
#     Worker 1: Train Loss: 1.4586, Train Accuracy: 59.01%
#     Worker 2: Train Loss: 1.4671, Train Accuracy: 58.91%
#     Worker 3: Train Loss: 1.4952, Train Accuracy: 58.26%
#     Worker 4: Train Loss: 1.4602, Train Accuracy: 58.81%
#     Worker 5: Train Loss: 1.4755, Train Accuracy: 59.25%
#     Worker 6: Train Loss: 1.5024, Train Accuracy: 57.74%
#     Worker 7: Train Loss: 1.4942, Train Accuracy: 57.95%
# Epoch 93/150: Test Loss: 1.9425, Test Accuracy: 50.15%
#     Worker 0: Train Loss: 1.4870, Train Accuracy: 57.87%
#     Worker 1: Train Loss: 1.4870, Train Accuracy: 58.15%
#     Worker 2: Train Loss: 1.4509, Train Accuracy: 59.24%
#     Worker 3: Train Loss: 1.4851, Train Accuracy: 58.31%
#     Worker 4: Train Loss: 1.4752, Train Accuracy: 58.96%
#     Worker 5: Train Loss: 1.4998, Train Accuracy: 58.76%
#     Worker 6: Train Loss: 1.4859, Train Accuracy: 58.79%
#     Worker 7: Train Loss: 1.4658, Train Accuracy: 58.30%
# Epoch 94/150: Test Loss: 1.9484, Test Accuracy: 50.27%
#     Worker 0: Train Loss: 1.4788, Train Accuracy: 58.80%
#     Worker 1: Train Loss: 1.4536, Train Accuracy: 59.16%
#     Worker 2: Train Loss: 1.4632, Train Accuracy: 59.05%
#     Worker 3: Train Loss: 1.4899, Train Accuracy: 58.27%
# ...
#     Worker 6: Train Loss: 1.3002, Train Accuracy: 63.40%
#     Worker 7: Train Loss: 1.2495, Train Accuracy: 64.50%
# Epoch 120/150: Test Loss: 1.9661, Test Accuracy: 51.14%
#     Worker 0: Train Loss: 1.2596, Train Accuracy: 63.99%
#     Worker 1: Train Loss: 1.2288, Train Accuracy: 65.02%
#     Worker 2: Train Loss: 1.2203, Train Accuracy: 65.13%
#     Worker 3: Train Loss: 1.2614, Train Accuracy: 63.89%
#     Worker 4: Train Loss: 1.2445, Train Accuracy: 64.82%
#     Worker 5: Train Loss: 1.2545, Train Accuracy: 64.65%
#     Worker 6: Train Loss: 1.2596, Train Accuracy: 63.81%
#     Worker 7: Train Loss: 1.2279, Train Accuracy: 65.14%
# Epoch 121/150: Test Loss: 1.9666, Test Accuracy: 50.88%
#     Worker 0: Train Loss: 1.2254, Train Accuracy: 65.27%
#     Worker 1: Train Loss: 1.2144, Train Accuracy: 65.66%
#     Worker 2: Train Loss: 1.2356, Train Accuracy: 65.28%
#     Worker 3: Train Loss: 1.2720, Train Accuracy: 63.89%
#     Worker 4: Train Loss: 1.1988, Train Accuracy: 65.06%
#     Worker 5: Train Loss: 1.2546, Train Accuracy: 65.17%
#     Worker 6: Train Loss: 1.2686, Train Accuracy: 64.18%
#     Worker 7: Train Loss: 1.2463, Train Accuracy: 64.25%
# Epoch 122/150: Test Loss: 1.9714, Test Accuracy: 51.00%
#     Worker 0: Train Loss: 1.2506, Train Accuracy: 64.37%
#     Worker 1: Train Loss: 1.2107, Train Accuracy: 65.72%
#     Worker 2: Train Loss: 1.2316, Train Accuracy: 65.78%
#     Worker 3: Train Loss: 1.2647, Train Accuracy: 63.93%
#     Worker 4: Train Loss: 1.2192, Train Accuracy: 65.29%
#     Worker 5: Train Loss: 1.2307, Train Accuracy: 65.56%
#     Worker 6: Train Loss: 1.2687, Train Accuracy: 64.88%
#     Worker 7: Train Loss: 1.2339, Train Accuracy: 64.36%
# Epoch 123/150: Test Loss: 1.9693, Test Accuracy: 51.12%
#     Worker 0: Train Loss: 1.2471, Train Accuracy: 64.11%
#     Worker 1: Train Loss: 1.2425, Train Accuracy: 65.25%
#     Worker 2: Train Loss: 1.2217, Train Accuracy: 64.81%
#     Worker 3: Train Loss: 1.2541, Train Accuracy: 64.61%
#     Worker 4: Train Loss: 1.2149, Train Accuracy: 65.35%
#     Worker 5: Train Loss: 1.2264, Train Accuracy: 65.46%
#     Worker 6: Train Loss: 1.2645, Train Accuracy: 63.95%
#     Worker 7: Train Loss: 1.2457, Train Accuracy: 64.15%
# Epoch 124/150: Test Loss: 1.9683, Test Accuracy: 51.07%
#     Worker 0: Train Loss: 1.2344, Train Accuracy: 64.63%
#     Worker 1: Train Loss: 1.2120, Train Accuracy: 65.40%
#     Worker 2: Train Loss: 1.2225, Train Accuracy: 65.21%
#     Worker 3: Train Loss: 1.2371, Train Accuracy: 65.19%
#     Worker 4: Train Loss: 1.2116, Train Accuracy: 65.46%
#     Worker 5: Train Loss: 1.2526, Train Accuracy: 64.88%
#     Worker 6: Train Loss: 1.2386, Train Accuracy: 64.87%
#     Worker 7: Train Loss: 1.2105, Train Accuracy: 65.35%
# Epoch 125/150: Test Loss: 1.9755, Test Accuracy: 50.97%
#     Worker 0: Train Loss: 1.2170, Train Accuracy: 65.45%
#     Worker 1: Train Loss: 1.2074, Train Accuracy: 66.04%
#     Worker 2: Train Loss: 1.1875, Train Accuracy: 66.34%
#     Worker 3: Train Loss: 1.2398, Train Accuracy: 65.03%
#     Worker 4: Train Loss: 1.2029, Train Accuracy: 65.94%
#     Worker 5: Train Loss: 1.2237, Train Accuracy: 65.80%
#     Worker 6: Train Loss: 1.2531, Train Accuracy: 64.62%
#     Worker 7: Train Loss: 1.2315, Train Accuracy: 65.11%
# Epoch 126/150: Test Loss: 1.9738, Test Accuracy: 50.90%
#     Worker 0: Train Loss: 1.2274, Train Accuracy: 65.09%
#     Worker 1: Train Loss: 1.2022, Train Accuracy: 65.96%
#     Worker 2: Train Loss: 1.2101, Train Accuracy: 65.52%
#     Worker 3: Train Loss: 1.2539, Train Accuracy: 63.94%
#     Worker 4: Train Loss: 1.1962, Train Accuracy: 66.14%
#     Worker 5: Train Loss: 1.2154, Train Accuracy: 66.10%
#     Worker 6: Train Loss: 1.2652, Train Accuracy: 64.00%
#     Worker 7: Train Loss: 1.2062, Train Accuracy: 65.23%
# Epoch 127/150: Test Loss: 1.9785, Test Accuracy: 51.33%
#     Worker 0: Train Loss: 1.2210, Train Accuracy: 64.83%
#     Worker 1: Train Loss: 1.2030, Train Accuracy: 65.69%
#     Worker 2: Train Loss: 1.1953, Train Accuracy: 66.10%
#     Worker 3: Train Loss: 1.2348, Train Accuracy: 64.99%
#     Worker 4: Train Loss: 1.2045, Train Accuracy: 65.31%
#     Worker 5: Train Loss: 1.2349, Train Accuracy: 65.04%
#     Worker 6: Train Loss: 1.2407, Train Accuracy: 64.92%
#     Worker 7: Train Loss: 1.2199, Train Accuracy: 65.06%
# Epoch 128/150: Test Loss: 1.9751, Test Accuracy: 51.12%
#     Worker 0: Train Loss: 1.2245, Train Accuracy: 65.48%
#     Worker 1: Train Loss: 1.1918, Train Accuracy: 65.82%
#     Worker 2: Train Loss: 1.1947, Train Accuracy: 66.29%
#     Worker 3: Train Loss: 1.2323, Train Accuracy: 64.97%
#     Worker 4: Train Loss: 1.1753, Train Accuracy: 66.64%
#     Worker 5: Train Loss: 1.2063, Train Accuracy: 66.46%
#     Worker 6: Train Loss: 1.2317, Train Accuracy: 65.01%
#     Worker 7: Train Loss: 1.1940, Train Accuracy: 65.75%
# Epoch 129/150: Test Loss: 1.9796, Test Accuracy: 51.03%
#     Worker 0: Train Loss: 1.2164, Train Accuracy: 65.41%
#     Worker 1: Train Loss: 1.1837, Train Accuracy: 66.17%
#     Worker 2: Train Loss: 1.1929, Train Accuracy: 66.74%
#     Worker 3: Train Loss: 1.2235, Train Accuracy: 64.98%
#     Worker 4: Train Loss: 1.1829, Train Accuracy: 66.24%
#     Worker 5: Train Loss: 1.1987, Train Accuracy: 65.95%
#     Worker 6: Train Loss: 1.2239, Train Accuracy: 64.91%
#     Worker 7: Train Loss: 1.1992, Train Accuracy: 65.52%
# Epoch 130/150: Test Loss: 1.9782, Test Accuracy: 51.12%
#     Worker 0: Train Loss: 1.2081, Train Accuracy: 65.12%
#     Worker 1: Train Loss: 1.1966, Train Accuracy: 66.40%
#     Worker 2: Train Loss: 1.1804, Train Accuracy: 66.27%
#     Worker 3: Train Loss: 1.2259, Train Accuracy: 65.15%
#     Worker 4: Train Loss: 1.1863, Train Accuracy: 66.17%
#     Worker 5: Train Loss: 1.2225, Train Accuracy: 65.01%
#     Worker 6: Train Loss: 1.2191, Train Accuracy: 65.54%
#     Worker 7: Train Loss: 1.2087, Train Accuracy: 65.75%
# Epoch 131/150: Test Loss: 1.9765, Test Accuracy: 50.96%
#     Worker 0: Train Loss: 1.2157, Train Accuracy: 65.38%
#     Worker 1: Train Loss: 1.1765, Train Accuracy: 66.03%
#     Worker 2: Train Loss: 1.1896, Train Accuracy: 66.13%
#     Worker 3: Train Loss: 1.2200, Train Accuracy: 65.40%
#     Worker 4: Train Loss: 1.1828, Train Accuracy: 66.08%
#     Worker 5: Train Loss: 1.1927, Train Accuracy: 66.72%
#     Worker 6: Train Loss: 1.2443, Train Accuracy: 64.11%
#     Worker 7: Train Loss: 1.2008, Train Accuracy: 65.99%
# Epoch 132/150: Test Loss: 1.9785, Test Accuracy: 51.05%
#     Worker 0: Train Loss: 1.2054, Train Accuracy: 66.14%
#     Worker 1: Train Loss: 1.1793, Train Accuracy: 66.38%
#     Worker 2: Train Loss: 1.1953, Train Accuracy: 66.49%
#     Worker 3: Train Loss: 1.2058, Train Accuracy: 65.73%
#     Worker 4: Train Loss: 1.1740, Train Accuracy: 66.40%
#     Worker 5: Train Loss: 1.2051, Train Accuracy: 66.18%
#     Worker 6: Train Loss: 1.2225, Train Accuracy: 65.73%
#     Worker 7: Train Loss: 1.1958, Train Accuracy: 66.07%
# Epoch 133/150: Test Loss: 1.9809, Test Accuracy: 50.95%
#     Worker 0: Train Loss: 1.2008, Train Accuracy: 65.23%
#     Worker 1: Train Loss: 1.1567, Train Accuracy: 68.12%
#     Worker 2: Train Loss: 1.1659, Train Accuracy: 66.98%
#     Worker 3: Train Loss: 1.2257, Train Accuracy: 65.36%
#     Worker 4: Train Loss: 1.1855, Train Accuracy: 66.12%
#     Worker 5: Train Loss: 1.2129, Train Accuracy: 66.03%
#     Worker 6: Train Loss: 1.2116, Train Accuracy: 65.47%
#     Worker 7: Train Loss: 1.1834, Train Accuracy: 66.90%
# Epoch 134/150: Test Loss: 1.9807, Test Accuracy: 51.02%
#     Worker 0: Train Loss: 1.2022, Train Accuracy: 65.75%
#     Worker 1: Train Loss: 1.1840, Train Accuracy: 66.14%
#     Worker 2: Train Loss: 1.1934, Train Accuracy: 66.42%
#     Worker 3: Train Loss: 1.2184, Train Accuracy: 65.12%
#     Worker 4: Train Loss: 1.1611, Train Accuracy: 66.40%
#     Worker 5: Train Loss: 1.2225, Train Accuracy: 65.54%
#     Worker 6: Train Loss: 1.2241, Train Accuracy: 65.41%
#     Worker 7: Train Loss: 1.1992, Train Accuracy: 65.56%
# Epoch 135/150: Test Loss: 1.9825, Test Accuracy: 51.22%
#     Worker 0: Train Loss: 1.2059, Train Accuracy: 66.07%
#     Worker 1: Train Loss: 1.1830, Train Accuracy: 66.47%
#     Worker 2: Train Loss: 1.1893, Train Accuracy: 66.17%
#     Worker 3: Train Loss: 1.2061, Train Accuracy: 66.25%
#     Worker 4: Train Loss: 1.1786, Train Accuracy: 66.51%
#     Worker 5: Train Loss: 1.2284, Train Accuracy: 65.50%
#     Worker 6: Train Loss: 1.2130, Train Accuracy: 65.75%
#     Worker 7: Train Loss: 1.1926, Train Accuracy: 66.33%
# Epoch 136/150: Test Loss: 1.9814, Test Accuracy: 51.03%
#     Worker 0: Train Loss: 1.2159, Train Accuracy: 65.35%
#     Worker 1: Train Loss: 1.1863, Train Accuracy: 65.90%
#     Worker 2: Train Loss: 1.1691, Train Accuracy: 67.33%
#     Worker 3: Train Loss: 1.1902, Train Accuracy: 65.92%
#     Worker 4: Train Loss: 1.1700, Train Accuracy: 66.23%
#     Worker 5: Train Loss: 1.1861, Train Accuracy: 66.50%
#     Worker 6: Train Loss: 1.2069, Train Accuracy: 65.89%
#     Worker 7: Train Loss: 1.1842, Train Accuracy: 66.22%
# Epoch 137/150: Test Loss: 1.9827, Test Accuracy: 51.09%
#     Worker 0: Train Loss: 1.1885, Train Accuracy: 66.32%
#     Worker 1: Train Loss: 1.1726, Train Accuracy: 66.83%
#     Worker 2: Train Loss: 1.2028, Train Accuracy: 66.62%
#     Worker 3: Train Loss: 1.2265, Train Accuracy: 65.39%
#     Worker 4: Train Loss: 1.1903, Train Accuracy: 66.62%
#     Worker 5: Train Loss: 1.1843, Train Accuracy: 66.82%
#     Worker 6: Train Loss: 1.2086, Train Accuracy: 65.74%
#     Worker 7: Train Loss: 1.1845, Train Accuracy: 66.36%
# Epoch 138/150: Test Loss: 1.9818, Test Accuracy: 51.18%
#     Worker 0: Train Loss: 1.1887, Train Accuracy: 65.80%
#     Worker 1: Train Loss: 1.1921, Train Accuracy: 66.25%
#     Worker 2: Train Loss: 1.1728, Train Accuracy: 66.40%
#     Worker 3: Train Loss: 1.2067, Train Accuracy: 65.68%
#     Worker 4: Train Loss: 1.1830, Train Accuracy: 66.13%
#     Worker 5: Train Loss: 1.1909, Train Accuracy: 66.41%
#     Worker 6: Train Loss: 1.2073, Train Accuracy: 66.05%
#     Worker 7: Train Loss: 1.1844, Train Accuracy: 66.45%
# Epoch 139/150: Test Loss: 1.9814, Test Accuracy: 51.16%
#     Worker 0: Train Loss: 1.1981, Train Accuracy: 65.32%
#     Worker 1: Train Loss: 1.1594, Train Accuracy: 66.82%
#     Worker 2: Train Loss: 1.1854, Train Accuracy: 66.50%
#     Worker 3: Train Loss: 1.2040, Train Accuracy: 65.02%
#     Worker 4: Train Loss: 1.1536, Train Accuracy: 66.98%
#     Worker 5: Train Loss: 1.1836, Train Accuracy: 66.88%
#     Worker 6: Train Loss: 1.2160, Train Accuracy: 65.45%
#     Worker 7: Train Loss: 1.1895, Train Accuracy: 66.46%
# Epoch 140/150: Test Loss: 1.9819, Test Accuracy: 51.19%
#     Worker 0: Train Loss: 1.1944, Train Accuracy: 65.83%
#     Worker 1: Train Loss: 1.1607, Train Accuracy: 67.09%
#     Worker 2: Train Loss: 1.1622, Train Accuracy: 67.25%
#     Worker 3: Train Loss: 1.1904, Train Accuracy: 66.18%
#     Worker 4: Train Loss: 1.1609, Train Accuracy: 66.55%
#     Worker 5: Train Loss: 1.1957, Train Accuracy: 66.13%
#     Worker 6: Train Loss: 1.2100, Train Accuracy: 65.74%
#     Worker 7: Train Loss: 1.1874, Train Accuracy: 65.96%
# Epoch 141/150: Test Loss: 1.9831, Test Accuracy: 51.17%
#     Worker 0: Train Loss: 1.1807, Train Accuracy: 65.73%
#     Worker 1: Train Loss: 1.1427, Train Accuracy: 67.59%
#     Worker 2: Train Loss: 1.1883, Train Accuracy: 66.64%
#     Worker 3: Train Loss: 1.2087, Train Accuracy: 65.49%
#     Worker 4: Train Loss: 1.1735, Train Accuracy: 66.16%
#     Worker 5: Train Loss: 1.1903, Train Accuracy: 66.47%
#     Worker 6: Train Loss: 1.2046, Train Accuracy: 65.77%
#     Worker 7: Train Loss: 1.1575, Train Accuracy: 66.52%
# Epoch 142/150: Test Loss: 1.9821, Test Accuracy: 51.23%
#     Worker 0: Train Loss: 1.1994, Train Accuracy: 66.03%
#     Worker 1: Train Loss: 1.1787, Train Accuracy: 66.67%
#     Worker 2: Train Loss: 1.1713, Train Accuracy: 67.53%
#     Worker 3: Train Loss: 1.1909, Train Accuracy: 66.27%
#     Worker 4: Train Loss: 1.1586, Train Accuracy: 66.55%
#     Worker 5: Train Loss: 1.1694, Train Accuracy: 66.36%
#     Worker 6: Train Loss: 1.1957, Train Accuracy: 66.38%
#     Worker 7: Train Loss: 1.1739, Train Accuracy: 66.85%
# Epoch 143/150: Test Loss: 1.9824, Test Accuracy: 51.30%
#     Worker 0: Train Loss: 1.1820, Train Accuracy: 66.36%
#     Worker 1: Train Loss: 1.1702, Train Accuracy: 67.07%
#     Worker 2: Train Loss: 1.1828, Train Accuracy: 66.34%
#     Worker 3: Train Loss: 1.2128, Train Accuracy: 65.53%
#     Worker 4: Train Loss: 1.1648, Train Accuracy: 66.59%
#     Worker 5: Train Loss: 1.1998, Train Accuracy: 65.81%
#     Worker 6: Train Loss: 1.2090, Train Accuracy: 65.81%
#     Worker 7: Train Loss: 1.1820, Train Accuracy: 66.14%
# Epoch 144/150: Test Loss: 1.9828, Test Accuracy: 51.11%
#     Worker 0: Train Loss: 1.1951, Train Accuracy: 65.71%
#     Worker 1: Train Loss: 1.1735, Train Accuracy: 66.45%
#     Worker 2: Train Loss: 1.1672, Train Accuracy: 66.48%
#     Worker 3: Train Loss: 1.1923, Train Accuracy: 66.08%
#     Worker 4: Train Loss: 1.1774, Train Accuracy: 66.37%
#     Worker 5: Train Loss: 1.1857, Train Accuracy: 66.47%
#     Worker 6: Train Loss: 1.2048, Train Accuracy: 66.05%
#     Worker 7: Train Loss: 1.1750, Train Accuracy: 66.58%
# Epoch 145/150: Test Loss: 1.9824, Test Accuracy: 51.21%
#     Worker 0: Train Loss: 1.1846, Train Accuracy: 66.47%
#     Worker 1: Train Loss: 1.1734, Train Accuracy: 67.38%
#     Worker 2: Train Loss: 1.1637, Train Accuracy: 67.15%
#     Worker 3: Train Loss: 1.1988, Train Accuracy: 65.15%
#     Worker 4: Train Loss: 1.1622, Train Accuracy: 67.15%
#     Worker 5: Train Loss: 1.1929, Train Accuracy: 66.70%
#     Worker 6: Train Loss: 1.1964, Train Accuracy: 66.46%
#     Worker 7: Train Loss: 1.1729, Train Accuracy: 66.65%
# Epoch 146/150: Test Loss: 1.9820, Test Accuracy: 51.28%
#     Worker 0: Train Loss: 1.1888, Train Accuracy: 66.14%
#     Worker 1: Train Loss: 1.1715, Train Accuracy: 67.36%
#     Worker 2: Train Loss: 1.1682, Train Accuracy: 66.85%
#     Worker 3: Train Loss: 1.2079, Train Accuracy: 66.07%
#     Worker 4: Train Loss: 1.1605, Train Accuracy: 67.38%
#     Worker 5: Train Loss: 1.2026, Train Accuracy: 66.79%
#     Worker 6: Train Loss: 1.2113, Train Accuracy: 65.95%
#     Worker 7: Train Loss: 1.1803, Train Accuracy: 66.60%
# Epoch 147/150: Test Loss: 1.9824, Test Accuracy: 51.25%
#     Worker 0: Train Loss: 1.1880, Train Accuracy: 66.09%
#     Worker 1: Train Loss: 1.1599, Train Accuracy: 66.56%
#     Worker 2: Train Loss: 1.1779, Train Accuracy: 66.80%
#     Worker 3: Train Loss: 1.1981, Train Accuracy: 65.95%
#     Worker 4: Train Loss: 1.1464, Train Accuracy: 67.80%
#     Worker 5: Train Loss: 1.1807, Train Accuracy: 66.73%
#     Worker 6: Train Loss: 1.1969, Train Accuracy: 66.03%
#     Worker 7: Train Loss: 1.1903, Train Accuracy: 66.27%
# Epoch 148/150: Test Loss: 1.9823, Test Accuracy: 51.28%
#     Worker 0: Train Loss: 1.1859, Train Accuracy: 66.54%
#     Worker 1: Train Loss: 1.1774, Train Accuracy: 66.46%
#     Worker 2: Train Loss: 1.1711, Train Accuracy: 67.31%
#     Worker 3: Train Loss: 1.1969, Train Accuracy: 65.79%
#     Worker 4: Train Loss: 1.1486, Train Accuracy: 66.94%
#     Worker 5: Train Loss: 1.2044, Train Accuracy: 66.33%
#     Worker 6: Train Loss: 1.1979, Train Accuracy: 66.45%
#     Worker 7: Train Loss: 1.1938, Train Accuracy: 65.89%
# Epoch 149/150: Test Loss: 1.9823, Test Accuracy: 51.29%
#     Worker 0: Train Loss: 1.1962, Train Accuracy: 65.79%
#     Worker 1: Train Loss: 1.1473, Train Accuracy: 67.36%
#     Worker 2: Train Loss: 1.1584, Train Accuracy: 67.39%
#     Worker 3: Train Loss: 1.1904, Train Accuracy: 66.19%
#     Worker 4: Train Loss: 1.1778, Train Accuracy: 66.71%
#     Worker 5: Train Loss: 1.1788, Train Accuracy: 65.97%
#     Worker 6: Train Loss: 1.1871, Train Accuracy: 66.62%
#     Worker 7: Train Loss: 1.1809, Train Accuracy: 65.89%
# Epoch 150/150: Test Loss: 1.9824, Test Accuracy: 51.29%
#     Worker 0: Train Loss: 1.1846, Train Accuracy: 66.03%
#     Worker 1: Train Loss: 1.1756, Train Accuracy: 66.32%
#     Worker 2: Train Loss: 1.1704, Train Accuracy: 67.14%
#     Worker 3: Train Loss: 1.1866, Train Accuracy: 65.97%
#     Worker 4: Train Loss: 1.1584, Train Accuracy: 66.66%
#     Worker 5: Train Loss: 1.1837, Train Accuracy: 66.98%
#     Worker 6: Train Loss: 1.2153, Train Accuracy: 65.56%
#     Worker 7: Train Loss: 1.1734, Train Accuracy: 67.07%
