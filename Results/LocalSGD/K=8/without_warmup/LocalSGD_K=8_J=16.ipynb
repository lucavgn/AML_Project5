# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
#warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")

    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch):
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            # Perform J local step before synchronization
            for j in range(J):
                try:
                    # Get a batch from the current worker's shard using next()
                    images, labels = next(shard_iterators[k])
                    images, labels = images.to(device), labels.to(device)  # Move to device
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

                except StopIteration:
                    # If the iterator has exhausted the data, restart the iterator
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k]) # Resume from the next batch
                    images, labels = images.to(device), labels.to(device)
                    # Perform optimization step
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        # Perform model synchronization
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            # Update each worker model with the global parameters
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
       # if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
       # else:
        #    warmup_factor = (epoch + 1) / warmup_epochs
          #  lr = warmup_factor * learning_rate
          #  for optimizer in optimizers:
           #     for param_group in optimizer.param_groups:
            #        param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 8 --j 16
# Out:
# Training with K=8, J=16
# Global iteration per epoch: 7
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:04<00:00, 34.5MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00800
# Epoch 1/150: Test Loss: 4.5652, Test Accuracy: 2.40%
#     Worker 0: Train Loss: 4.5974, Train Accuracy: 1.40%
#     Worker 1: Train Loss: 4.5959, Train Accuracy: 1.55%
#     Worker 2: Train Loss: 4.5971, Train Accuracy: 1.43%
#     Worker 3: Train Loss: 4.5946, Train Accuracy: 1.78%
#     Worker 4: Train Loss: 4.5958, Train Accuracy: 1.47%
#     Worker 5: Train Loss: 4.5927, Train Accuracy: 1.60%
#     Worker 6: Train Loss: 4.5966, Train Accuracy: 1.47%
#     Worker 7: Train Loss: 4.5951, Train Accuracy: 1.41%
# Epoch 2/150: Test Loss: 4.1787, Test Accuracy: 6.42%
#     Worker 0: Train Loss: 4.4167, Train Accuracy: 3.36%
#     Worker 1: Train Loss: 4.4118, Train Accuracy: 3.61%
#     Worker 2: Train Loss: 4.4166, Train Accuracy: 3.62%
#     Worker 3: Train Loss: 4.4213, Train Accuracy: 3.51%
#     Worker 4: Train Loss: 4.4037, Train Accuracy: 3.62%
#     Worker 5: Train Loss: 4.3971, Train Accuracy: 3.50%
#     Worker 6: Train Loss: 4.4130, Train Accuracy: 3.57%
#     Worker 7: Train Loss: 4.4039, Train Accuracy: 3.33%
# Epoch 3/150: Test Loss: 3.9989, Test Accuracy: 8.98%
#     Worker 0: Train Loss: 4.1358, Train Accuracy: 6.56%
#     Worker 1: Train Loss: 4.1647, Train Accuracy: 6.00%
#     Worker 2: Train Loss: 4.1477, Train Accuracy: 6.00%
#     Worker 3: Train Loss: 4.1661, Train Accuracy: 5.70%
#     Worker 4: Train Loss: 4.1198, Train Accuracy: 5.98%
#     Worker 5: Train Loss: 4.1306, Train Accuracy: 6.31%
#     Worker 6: Train Loss: 4.1578, Train Accuracy: 6.06%
#     Worker 7: Train Loss: 4.1600, Train Accuracy: 6.17%
# Epoch 4/150: Test Loss: 3.8630, Test Accuracy: 11.15%
#     Worker 0: Train Loss: 4.0170, Train Accuracy: 8.31%
#     Worker 1: Train Loss: 4.0338, Train Accuracy: 7.77%
#     Worker 2: Train Loss: 4.0262, Train Accuracy: 7.92%
#     Worker 3: Train Loss: 4.0475, Train Accuracy: 7.22%
#     Worker 4: Train Loss: 3.9932, Train Accuracy: 8.37%
#     Worker 5: Train Loss: 4.0065, Train Accuracy: 7.91%
#     Worker 6: Train Loss: 4.0284, Train Accuracy: 7.81%
#     Worker 7: Train Loss: 4.0363, Train Accuracy: 8.09%
# Epoch 5/150: Test Loss: 3.7304, Test Accuracy: 13.96%
#     Worker 0: Train Loss: 3.9153, Train Accuracy: 9.82%
#     Worker 1: Train Loss: 3.9167, Train Accuracy: 8.84%
#     Worker 2: Train Loss: 3.8966, Train Accuracy: 9.92%
#     Worker 3: Train Loss: 3.9158, Train Accuracy: 9.21%
#     Worker 4: Train Loss: 3.8463, Train Accuracy: 10.43%
#     Worker 5: Train Loss: 3.8552, Train Accuracy: 11.11%
#     Worker 6: Train Loss: 3.9125, Train Accuracy: 9.39%
#     Worker 7: Train Loss: 3.8997, Train Accuracy: 10.19%
# Epoch 6/150: Test Loss: 3.6168, Test Accuracy: 15.79%
#     Worker 0: Train Loss: 3.8039, Train Accuracy: 10.87%
#     Worker 1: Train Loss: 3.8104, Train Accuracy: 11.27%
#     Worker 2: Train Loss: 3.8057, Train Accuracy: 11.50%
#     Worker 3: Train Loss: 3.8216, Train Accuracy: 10.79%
#     Worker 4: Train Loss: 3.7578, Train Accuracy: 11.24%
#     Worker 5: Train Loss: 3.7662, Train Accuracy: 12.19%
#     Worker 6: Train Loss: 3.7947, Train Accuracy: 10.87%
#     Worker 7: Train Loss: 3.7901, Train Accuracy: 11.66%
# Epoch 7/150: Test Loss: 3.5385, Test Accuracy: 16.27%
#     Worker 0: Train Loss: 3.7082, Train Accuracy: 12.45%
#     Worker 1: Train Loss: 3.7292, Train Accuracy: 11.95%
#     Worker 2: Train Loss: 3.7027, Train Accuracy: 13.38%
#     Worker 3: Train Loss: 3.7294, Train Accuracy: 12.75%
#     Worker 4: Train Loss: 3.6867, Train Accuracy: 12.48%
#     Worker 5: Train Loss: 3.6667, Train Accuracy: 13.67%
#     Worker 6: Train Loss: 3.7334, Train Accuracy: 12.35%
#     Worker 7: Train Loss: 3.7145, Train Accuracy: 12.56%
# Epoch 8/150: Test Loss: 3.4528, Test Accuracy: 18.56%
#     Worker 0: Train Loss: 3.6276, Train Accuracy: 13.83%
#     Worker 1: Train Loss: 3.6328, Train Accuracy: 13.66%
#     Worker 2: Train Loss: 3.6225, Train Accuracy: 14.55%
#     Worker 3: Train Loss: 3.6564, Train Accuracy: 13.91%
#     Worker 4: Train Loss: 3.5771, Train Accuracy: 14.89%
#     Worker 5: Train Loss: 3.6066, Train Accuracy: 14.86%
#     Worker 6: Train Loss: 3.6470, Train Accuracy: 13.74%
#     Worker 7: Train Loss: 3.6245, Train Accuracy: 14.51%
# Epoch 9/150: Test Loss: 3.4003, Test Accuracy: 19.41%
#     Worker 0: Train Loss: 3.5477, Train Accuracy: 15.25%
#     Worker 1: Train Loss: 3.5696, Train Accuracy: 14.58%
#     Worker 2: Train Loss: 3.5438, Train Accuracy: 16.40%
#     Worker 3: Train Loss: 3.5747, Train Accuracy: 14.96%
#     Worker 4: Train Loss: 3.5071, Train Accuracy: 16.36%
#     Worker 5: Train Loss: 3.4958, Train Accuracy: 16.60%
#     Worker 6: Train Loss: 3.5532, Train Accuracy: 15.17%
#     Worker 7: Train Loss: 3.5612, Train Accuracy: 15.35%
# Epoch 10/150: Test Loss: 3.3181, Test Accuracy: 20.72%
#     Worker 0: Train Loss: 3.5127, Train Accuracy: 16.47%
#     Worker 1: Train Loss: 3.4665, Train Accuracy: 16.48%
#     Worker 2: Train Loss: 3.4675, Train Accuracy: 17.34%
#     Worker 3: Train Loss: 3.5100, Train Accuracy: 15.83%
#     Worker 4: Train Loss: 3.4373, Train Accuracy: 18.12%
#     Worker 5: Train Loss: 3.4575, Train Accuracy: 17.42%
#     Worker 6: Train Loss: 3.5111, Train Accuracy: 16.20%
#     Worker 7: Train Loss: 3.4583, Train Accuracy: 17.44%
# Epoch 11/150: Test Loss: 3.2343, Test Accuracy: 22.38%
#     Worker 0: Train Loss: 3.3923, Train Accuracy: 17.62%
#     Worker 1: Train Loss: 3.3949, Train Accuracy: 17.52%
#     Worker 2: Train Loss: 3.3952, Train Accuracy: 18.46%
#     Worker 3: Train Loss: 3.4533, Train Accuracy: 17.39%
#     Worker 4: Train Loss: 3.3789, Train Accuracy: 18.67%
#     Worker 5: Train Loss: 3.3470, Train Accuracy: 20.04%
#     Worker 6: Train Loss: 3.4248, Train Accuracy: 17.67%
#     Worker 7: Train Loss: 3.4252, Train Accuracy: 17.63%
# Epoch 12/150: Test Loss: 3.1794, Test Accuracy: 23.51%
#     Worker 0: Train Loss: 3.3518, Train Accuracy: 19.24%
#     Worker 1: Train Loss: 3.3342, Train Accuracy: 18.63%
#     Worker 2: Train Loss: 3.3608, Train Accuracy: 20.18%
#     Worker 3: Train Loss: 3.3942, Train Accuracy: 18.46%
#     Worker 4: Train Loss: 3.3268, Train Accuracy: 19.44%
#     Worker 5: Train Loss: 3.3099, Train Accuracy: 20.08%
#     Worker 6: Train Loss: 3.3518, Train Accuracy: 18.68%
#     Worker 7: Train Loss: 3.3660, Train Accuracy: 19.30%
# Epoch 13/150: Test Loss: 3.1081, Test Accuracy: 24.56%
#     Worker 0: Train Loss: 3.2842, Train Accuracy: 19.82%
#     Worker 1: Train Loss: 3.2826, Train Accuracy: 19.77%
#     Worker 2: Train Loss: 3.2699, Train Accuracy: 21.09%
#     Worker 3: Train Loss: 3.3097, Train Accuracy: 19.52%
#     Worker 4: Train Loss: 3.2263, Train Accuracy: 20.95%
#     Worker 5: Train Loss: 3.2399, Train Accuracy: 21.44%
#     Worker 6: Train Loss: 3.2996, Train Accuracy: 20.28%
#     Worker 7: Train Loss: 3.2748, Train Accuracy: 20.68%
# Epoch 14/150: Test Loss: 3.0407, Test Accuracy: 25.58%
#     Worker 0: Train Loss: 3.2425, Train Accuracy: 20.63%
#     Worker 1: Train Loss: 3.2219, Train Accuracy: 20.90%
#     Worker 2: Train Loss: 3.2281, Train Accuracy: 21.38%
#     Worker 3: Train Loss: 3.2871, Train Accuracy: 20.33%
#     Worker 4: Train Loss: 3.1873, Train Accuracy: 21.66%
#     Worker 5: Train Loss: 3.1781, Train Accuracy: 22.15%
#     Worker 6: Train Loss: 3.2776, Train Accuracy: 20.37%
#     Worker 7: Train Loss: 3.2271, Train Accuracy: 21.53%
# Epoch 15/150: Test Loss: 2.9861, Test Accuracy: 26.58%
#     Worker 0: Train Loss: 3.1817, Train Accuracy: 21.58%
#     Worker 1: Train Loss: 3.1661, Train Accuracy: 21.90%
#     Worker 2: Train Loss: 3.1663, Train Accuracy: 22.94%
#     Worker 3: Train Loss: 3.1789, Train Accuracy: 22.14%
#     Worker 4: Train Loss: 3.1421, Train Accuracy: 22.50%
#     Worker 5: Train Loss: 3.1369, Train Accuracy: 23.36%
#     Worker 6: Train Loss: 3.1795, Train Accuracy: 21.80%
#     Worker 7: Train Loss: 3.1489, Train Accuracy: 22.54%
# Epoch 16/150: Test Loss: 2.9307, Test Accuracy: 27.62%
#     Worker 0: Train Loss: 3.1257, Train Accuracy: 22.63%
#     Worker 1: Train Loss: 3.0927, Train Accuracy: 23.05%
#     Worker 2: Train Loss: 3.1203, Train Accuracy: 23.94%
#     Worker 3: Train Loss: 3.1388, Train Accuracy: 22.39%
#     Worker 4: Train Loss: 3.0993, Train Accuracy: 23.12%
#     Worker 5: Train Loss: 3.0943, Train Accuracy: 23.59%
#     Worker 6: Train Loss: 3.1601, Train Accuracy: 22.36%
#     Worker 7: Train Loss: 3.1049, Train Accuracy: 24.20%
# Epoch 17/150: Test Loss: 2.9012, Test Accuracy: 28.33%
#     Worker 0: Train Loss: 3.1000, Train Accuracy: 23.02%
#     Worker 1: Train Loss: 3.0559, Train Accuracy: 24.36%
#     Worker 2: Train Loss: 3.0475, Train Accuracy: 25.15%
#     Worker 3: Train Loss: 3.0973, Train Accuracy: 22.24%
#     Worker 4: Train Loss: 3.0390, Train Accuracy: 24.73%
#     Worker 5: Train Loss: 3.0184, Train Accuracy: 25.64%
#     Worker 6: Train Loss: 3.1088, Train Accuracy: 22.82%
#     Worker 7: Train Loss: 3.0916, Train Accuracy: 23.99%
# Epoch 18/150: Test Loss: 2.8450, Test Accuracy: 29.40%
#     Worker 0: Train Loss: 3.0360, Train Accuracy: 24.22%
#     Worker 1: Train Loss: 3.0149, Train Accuracy: 24.87%
#     Worker 2: Train Loss: 3.0279, Train Accuracy: 25.03%
#     Worker 3: Train Loss: 3.0582, Train Accuracy: 24.27%
#     Worker 4: Train Loss: 2.9706, Train Accuracy: 25.65%
#     Worker 5: Train Loss: 3.0008, Train Accuracy: 26.10%
#     Worker 6: Train Loss: 3.0406, Train Accuracy: 24.83%
#     Worker 7: Train Loss: 3.0133, Train Accuracy: 25.06%
# Epoch 19/150: Test Loss: 2.8137, Test Accuracy: 30.08%
#     Worker 0: Train Loss: 2.9860, Train Accuracy: 26.06%
#     Worker 1: Train Loss: 2.9414, Train Accuracy: 25.52%
#     Worker 2: Train Loss: 3.0061, Train Accuracy: 25.33%
#     Worker 3: Train Loss: 3.0249, Train Accuracy: 24.76%
#     Worker 4: Train Loss: 2.9739, Train Accuracy: 25.34%
#     Worker 5: Train Loss: 2.9520, Train Accuracy: 26.98%
#     Worker 6: Train Loss: 3.0252, Train Accuracy: 24.56%
#     Worker 7: Train Loss: 2.9845, Train Accuracy: 25.62%
# Epoch 20/150: Test Loss: 2.7381, Test Accuracy: 31.58%
#     Worker 0: Train Loss: 2.9263, Train Accuracy: 26.62%
#     Worker 1: Train Loss: 2.9370, Train Accuracy: 25.96%
#     Worker 2: Train Loss: 2.9310, Train Accuracy: 27.34%
#     Worker 3: Train Loss: 2.9687, Train Accuracy: 25.57%
#     Worker 4: Train Loss: 2.8955, Train Accuracy: 27.90%
#     Worker 5: Train Loss: 2.8914, Train Accuracy: 26.95%
#     Worker 6: Train Loss: 2.9485, Train Accuracy: 26.39%
#     Worker 7: Train Loss: 2.9334, Train Accuracy: 27.39%
# Epoch 21/150: Test Loss: 2.6995, Test Accuracy: 32.53%
#     Worker 0: Train Loss: 2.9118, Train Accuracy: 27.98%
#     Worker 1: Train Loss: 2.8886, Train Accuracy: 27.19%
#     Worker 2: Train Loss: 2.8829, Train Accuracy: 27.86%
#     Worker 3: Train Loss: 2.9034, Train Accuracy: 26.53%
#     Worker 4: Train Loss: 2.8513, Train Accuracy: 27.99%
#     Worker 5: Train Loss: 2.8266, Train Accuracy: 29.15%
#     Worker 6: Train Loss: 2.9106, Train Accuracy: 27.25%
#     Worker 7: Train Loss: 2.8844, Train Accuracy: 27.78%
# Epoch 22/150: Test Loss: 2.6572, Test Accuracy: 33.13%
#     Worker 0: Train Loss: 2.8540, Train Accuracy: 28.46%
#     Worker 1: Train Loss: 2.8047, Train Accuracy: 28.49%
#     Worker 2: Train Loss: 2.8327, Train Accuracy: 29.36%
#     Worker 3: Train Loss: 2.8738, Train Accuracy: 28.16%
#     Worker 4: Train Loss: 2.8312, Train Accuracy: 28.65%
#     Worker 5: Train Loss: 2.7726, Train Accuracy: 29.99%
#     Worker 6: Train Loss: 2.8580, Train Accuracy: 28.13%
#     Worker 7: Train Loss: 2.8652, Train Accuracy: 27.93%
# Epoch 23/150: Test Loss: 2.6142, Test Accuracy: 33.79%
#     Worker 0: Train Loss: 2.8311, Train Accuracy: 28.52%
#     Worker 1: Train Loss: 2.8079, Train Accuracy: 29.08%
#     Worker 2: Train Loss: 2.8035, Train Accuracy: 29.88%
#     Worker 3: Train Loss: 2.8210, Train Accuracy: 28.79%
#     Worker 4: Train Loss: 2.7641, Train Accuracy: 29.16%
#     Worker 5: Train Loss: 2.7397, Train Accuracy: 31.00%
#     Worker 6: Train Loss: 2.8305, Train Accuracy: 28.14%
#     Worker 7: Train Loss: 2.7978, Train Accuracy: 29.14%
# Epoch 24/150: Test Loss: 2.6066, Test Accuracy: 34.16%
#     Worker 0: Train Loss: 2.7984, Train Accuracy: 29.54%
#     Worker 1: Train Loss: 2.7445, Train Accuracy: 29.72%
#     Worker 2: Train Loss: 2.7365, Train Accuracy: 30.81%
#     Worker 3: Train Loss: 2.8003, Train Accuracy: 29.28%
#     Worker 4: Train Loss: 2.7469, Train Accuracy: 29.64%
#     Worker 5: Train Loss: 2.7382, Train Accuracy: 30.77%
#     Worker 6: Train Loss: 2.7912, Train Accuracy: 29.97%
#     Worker 7: Train Loss: 2.7568, Train Accuracy: 30.46%
# Epoch 25/150: Test Loss: 2.5440, Test Accuracy: 35.56%
#     Worker 0: Train Loss: 2.7421, Train Accuracy: 30.67%
#     Worker 1: Train Loss: 2.7268, Train Accuracy: 30.49%
#     Worker 2: Train Loss: 2.7268, Train Accuracy: 31.22%
#     Worker 3: Train Loss: 2.7267, Train Accuracy: 30.38%
#     Worker 4: Train Loss: 2.6834, Train Accuracy: 31.21%
#     Worker 5: Train Loss: 2.6608, Train Accuracy: 32.66%
#     Worker 6: Train Loss: 2.7317, Train Accuracy: 30.59%
#     Worker 7: Train Loss: 2.7308, Train Accuracy: 31.04%
# Epoch 26/150: Test Loss: 2.5318, Test Accuracy: 35.74%
#     Worker 0: Train Loss: 2.7128, Train Accuracy: 30.84%
#     Worker 1: Train Loss: 2.6869, Train Accuracy: 31.36%
#     Worker 2: Train Loss: 2.6925, Train Accuracy: 31.78%
#     Worker 3: Train Loss: 2.7214, Train Accuracy: 31.04%
#     Worker 4: Train Loss: 2.6531, Train Accuracy: 32.76%
#     Worker 5: Train Loss: 2.6813, Train Accuracy: 32.30%
#     Worker 6: Train Loss: 2.7282, Train Accuracy: 29.97%
#     Worker 7: Train Loss: 2.6789, Train Accuracy: 31.46%
# Epoch 27/150: Test Loss: 2.4905, Test Accuracy: 36.85%
#     Worker 0: Train Loss: 2.6792, Train Accuracy: 31.85%
#     Worker 1: Train Loss: 2.6156, Train Accuracy: 33.25%
#     Worker 2: Train Loss: 2.6301, Train Accuracy: 32.49%
#     Worker 3: Train Loss: 2.6764, Train Accuracy: 31.23%
#     Worker 4: Train Loss: 2.6401, Train Accuracy: 32.40%
#     Worker 5: Train Loss: 2.6178, Train Accuracy: 33.45%
#     Worker 6: Train Loss: 2.6630, Train Accuracy: 32.58%
#     Worker 7: Train Loss: 2.6518, Train Accuracy: 31.98%
# Epoch 28/150: Test Loss: 2.4612, Test Accuracy: 36.97%
#     Worker 0: Train Loss: 2.6194, Train Accuracy: 32.80%
#     Worker 1: Train Loss: 2.5888, Train Accuracy: 33.25%
#     Worker 2: Train Loss: 2.6324, Train Accuracy: 32.55%
#     Worker 3: Train Loss: 2.6357, Train Accuracy: 33.35%
#     Worker 4: Train Loss: 2.5849, Train Accuracy: 33.44%
#     Worker 5: Train Loss: 2.5735, Train Accuracy: 34.56%
#     Worker 6: Train Loss: 2.6210, Train Accuracy: 32.64%
#     Worker 7: Train Loss: 2.6077, Train Accuracy: 33.14%
# Epoch 29/150: Test Loss: 2.4376, Test Accuracy: 38.02%
#     Worker 0: Train Loss: 2.5696, Train Accuracy: 33.77%
#     Worker 1: Train Loss: 2.5706, Train Accuracy: 33.70%
#     Worker 2: Train Loss: 2.5755, Train Accuracy: 34.33%
#     Worker 3: Train Loss: 2.6096, Train Accuracy: 33.63%
#     Worker 4: Train Loss: 2.5177, Train Accuracy: 35.07%
#     Worker 5: Train Loss: 2.5797, Train Accuracy: 34.13%
#     Worker 6: Train Loss: 2.5815, Train Accuracy: 33.22%
#     Worker 7: Train Loss: 2.5727, Train Accuracy: 33.59%
# Epoch 30/150: Test Loss: 2.4113, Test Accuracy: 38.29%
#     Worker 0: Train Loss: 2.6019, Train Accuracy: 33.10%
#     Worker 1: Train Loss: 2.5636, Train Accuracy: 34.37%
#     Worker 2: Train Loss: 2.5522, Train Accuracy: 34.62%
#     Worker 3: Train Loss: 2.5843, Train Accuracy: 33.14%
#     Worker 4: Train Loss: 2.5246, Train Accuracy: 34.66%
#     Worker 5: Train Loss: 2.4931, Train Accuracy: 36.06%
#     Worker 6: Train Loss: 2.5572, Train Accuracy: 34.40%
#     Worker 7: Train Loss: 2.5869, Train Accuracy: 33.52%
# Epoch 31/150: Test Loss: 2.3964, Test Accuracy: 38.34%
#     Worker 0: Train Loss: 2.5257, Train Accuracy: 34.65%
#     Worker 1: Train Loss: 2.4622, Train Accuracy: 36.72%
#     Worker 2: Train Loss: 2.5203, Train Accuracy: 34.63%
#     Worker 3: Train Loss: 2.5298, Train Accuracy: 34.20%
#     Worker 4: Train Loss: 2.4533, Train Accuracy: 35.85%
#     Worker 5: Train Loss: 2.5053, Train Accuracy: 34.75%
#     Worker 6: Train Loss: 2.5644, Train Accuracy: 33.96%
#     Worker 7: Train Loss: 2.5160, Train Accuracy: 34.75%
# Epoch 32/150: Test Loss: 2.3714, Test Accuracy: 38.91%
#     Worker 0: Train Loss: 2.4841, Train Accuracy: 35.46%
#     Worker 1: Train Loss: 2.4761, Train Accuracy: 35.66%
#     Worker 2: Train Loss: 2.4838, Train Accuracy: 35.24%
#     Worker 3: Train Loss: 2.5301, Train Accuracy: 34.31%
#     Worker 4: Train Loss: 2.4435, Train Accuracy: 36.57%
#     Worker 5: Train Loss: 2.4925, Train Accuracy: 36.03%
#     Worker 6: Train Loss: 2.4890, Train Accuracy: 35.43%
#     Worker 7: Train Loss: 2.5028, Train Accuracy: 35.21%
# Epoch 33/150: Test Loss: 2.3598, Test Accuracy: 39.20%
#     Worker 0: Train Loss: 2.4789, Train Accuracy: 35.73%
#     Worker 1: Train Loss: 2.4686, Train Accuracy: 36.13%
#     Worker 2: Train Loss: 2.4635, Train Accuracy: 36.59%
#     Worker 3: Train Loss: 2.5056, Train Accuracy: 34.19%
#     Worker 4: Train Loss: 2.4208, Train Accuracy: 36.89%
#     Worker 5: Train Loss: 2.4228, Train Accuracy: 37.08%
#     Worker 6: Train Loss: 2.4812, Train Accuracy: 35.74%
#     Worker 7: Train Loss: 2.4720, Train Accuracy: 35.91%
# Epoch 34/150: Test Loss: 2.3352, Test Accuracy: 39.99%
#     Worker 0: Train Loss: 2.4561, Train Accuracy: 36.01%
#     Worker 1: Train Loss: 2.4094, Train Accuracy: 36.52%
#     Worker 2: Train Loss: 2.4493, Train Accuracy: 35.88%
#     Worker 3: Train Loss: 2.4624, Train Accuracy: 36.64%
#     Worker 4: Train Loss: 2.4024, Train Accuracy: 37.81%
#     Worker 5: Train Loss: 2.4209, Train Accuracy: 37.27%
#     Worker 6: Train Loss: 2.4337, Train Accuracy: 36.71%
#     Worker 7: Train Loss: 2.4570, Train Accuracy: 36.36%
# Epoch 35/150: Test Loss: 2.3116, Test Accuracy: 40.57%
#     Worker 0: Train Loss: 2.4178, Train Accuracy: 36.83%
#     Worker 1: Train Loss: 2.4272, Train Accuracy: 36.33%
#     Worker 2: Train Loss: 2.4087, Train Accuracy: 37.86%
#     Worker 3: Train Loss: 2.4286, Train Accuracy: 37.27%
#     Worker 4: Train Loss: 2.4042, Train Accuracy: 36.93%
#     Worker 5: Train Loss: 2.4213, Train Accuracy: 36.78%
#     Worker 6: Train Loss: 2.4243, Train Accuracy: 37.59%
#     Worker 7: Train Loss: 2.4087, Train Accuracy: 36.92%
# Epoch 36/150: Test Loss: 2.2866, Test Accuracy: 41.13%
#     Worker 0: Train Loss: 2.4124, Train Accuracy: 36.99%
#     Worker 1: Train Loss: 2.3585, Train Accuracy: 38.02%
#     Worker 2: Train Loss: 2.3801, Train Accuracy: 37.71%
#     Worker 3: Train Loss: 2.4033, Train Accuracy: 37.46%
#     Worker 4: Train Loss: 2.3418, Train Accuracy: 38.64%
#     Worker 5: Train Loss: 2.3912, Train Accuracy: 37.59%
#     Worker 6: Train Loss: 2.4308, Train Accuracy: 36.87%
#     Worker 7: Train Loss: 2.3804, Train Accuracy: 38.13%
# Epoch 37/150: Test Loss: 2.2724, Test Accuracy: 41.35%
#     Worker 0: Train Loss: 2.3696, Train Accuracy: 38.46%
#     Worker 1: Train Loss: 2.3651, Train Accuracy: 38.11%
#     Worker 2: Train Loss: 2.3629, Train Accuracy: 38.30%
#     Worker 3: Train Loss: 2.3688, Train Accuracy: 37.63%
#     Worker 4: Train Loss: 2.3022, Train Accuracy: 39.62%
#     Worker 5: Train Loss: 2.3194, Train Accuracy: 39.71%
#     Worker 6: Train Loss: 2.3756, Train Accuracy: 37.99%
#     Worker 7: Train Loss: 2.3682, Train Accuracy: 38.34%
# Epoch 38/150: Test Loss: 2.2764, Test Accuracy: 41.33%
#     Worker 0: Train Loss: 2.3373, Train Accuracy: 39.01%
#     Worker 1: Train Loss: 2.2657, Train Accuracy: 40.01%
#     Worker 2: Train Loss: 2.3676, Train Accuracy: 38.29%
#     Worker 3: Train Loss: 2.3669, Train Accuracy: 38.02%
#     Worker 4: Train Loss: 2.3212, Train Accuracy: 38.89%
#     Worker 5: Train Loss: 2.3332, Train Accuracy: 39.01%
#     Worker 6: Train Loss: 2.3522, Train Accuracy: 38.08%
#     Worker 7: Train Loss: 2.3542, Train Accuracy: 38.99%
# Epoch 39/150: Test Loss: 2.2409, Test Accuracy: 41.64%
#     Worker 0: Train Loss: 2.3345, Train Accuracy: 38.90%
#     Worker 1: Train Loss: 2.3414, Train Accuracy: 38.96%
#     Worker 2: Train Loss: 2.3081, Train Accuracy: 39.15%
#     Worker 3: Train Loss: 2.3758, Train Accuracy: 37.66%
#     Worker 4: Train Loss: 2.2768, Train Accuracy: 40.34%
#     Worker 5: Train Loss: 2.2913, Train Accuracy: 40.65%
#     Worker 6: Train Loss: 2.3365, Train Accuracy: 38.51%
#     Worker 7: Train Loss: 2.3119, Train Accuracy: 39.83%
# Epoch 40/150: Test Loss: 2.2394, Test Accuracy: 42.10%
#     Worker 0: Train Loss: 2.3360, Train Accuracy: 38.25%
#     Worker 1: Train Loss: 2.2768, Train Accuracy: 39.69%
#     Worker 2: Train Loss: 2.3292, Train Accuracy: 39.88%
#     Worker 3: Train Loss: 2.3240, Train Accuracy: 39.34%
#     Worker 4: Train Loss: 2.2698, Train Accuracy: 39.98%
#     Worker 5: Train Loss: 2.2545, Train Accuracy: 40.69%
#     Worker 6: Train Loss: 2.2852, Train Accuracy: 39.53%
#     Worker 7: Train Loss: 2.2756, Train Accuracy: 40.29%
# Epoch 41/150: Test Loss: 2.2110, Test Accuracy: 42.71%
#     Worker 0: Train Loss: 2.2677, Train Accuracy: 39.78%
#     Worker 1: Train Loss: 2.2687, Train Accuracy: 39.98%
#     Worker 2: Train Loss: 2.2713, Train Accuracy: 40.50%
#     Worker 3: Train Loss: 2.2879, Train Accuracy: 39.29%
#     Worker 4: Train Loss: 2.2531, Train Accuracy: 39.90%
#     Worker 5: Train Loss: 2.2533, Train Accuracy: 41.44%
#     Worker 6: Train Loss: 2.3200, Train Accuracy: 39.21%
#     Worker 7: Train Loss: 2.2758, Train Accuracy: 40.62%
# Epoch 42/150: Test Loss: 2.2059, Test Accuracy: 42.77%
#     Worker 0: Train Loss: 2.2607, Train Accuracy: 39.95%
#     Worker 1: Train Loss: 2.2348, Train Accuracy: 40.26%
#     Worker 2: Train Loss: 2.2722, Train Accuracy: 39.75%
#     Worker 3: Train Loss: 2.2506, Train Accuracy: 40.64%
#     Worker 4: Train Loss: 2.2287, Train Accuracy: 41.04%
#     Worker 5: Train Loss: 2.2405, Train Accuracy: 40.83%
#     Worker 6: Train Loss: 2.2588, Train Accuracy: 40.30%
#     Worker 7: Train Loss: 2.2658, Train Accuracy: 39.98%
# Epoch 43/150: Test Loss: 2.1889, Test Accuracy: 42.97%
#     Worker 0: Train Loss: 2.2554, Train Accuracy: 40.43%
#     Worker 1: Train Loss: 2.2173, Train Accuracy: 40.62%
#     Worker 2: Train Loss: 2.2187, Train Accuracy: 40.88%
#     Worker 3: Train Loss: 2.2447, Train Accuracy: 40.33%
#     Worker 4: Train Loss: 2.2078, Train Accuracy: 42.16%
#     Worker 5: Train Loss: 2.2107, Train Accuracy: 42.07%
#     Worker 6: Train Loss: 2.2577, Train Accuracy: 40.57%
#     Worker 7: Train Loss: 2.2097, Train Accuracy: 41.32%
# Epoch 44/150: Test Loss: 2.1909, Test Accuracy: 43.32%
#     Worker 0: Train Loss: 2.2229, Train Accuracy: 40.62%
#     Worker 1: Train Loss: 2.1678, Train Accuracy: 42.21%
#     Worker 2: Train Loss: 2.2362, Train Accuracy: 41.03%
#     Worker 3: Train Loss: 2.2066, Train Accuracy: 41.38%
#     Worker 4: Train Loss: 2.1590, Train Accuracy: 42.61%
#     Worker 5: Train Loss: 2.1910, Train Accuracy: 42.01%
#     Worker 6: Train Loss: 2.2253, Train Accuracy: 41.17%
#     Worker 7: Train Loss: 2.2115, Train Accuracy: 42.04%
# Epoch 45/150: Test Loss: 2.1690, Test Accuracy: 43.37%
#     Worker 0: Train Loss: 2.1986, Train Accuracy: 41.63%
#     Worker 1: Train Loss: 2.1845, Train Accuracy: 41.59%
#     Worker 2: Train Loss: 2.1964, Train Accuracy: 42.50%
#     Worker 3: Train Loss: 2.2130, Train Accuracy: 41.28%
#     Worker 4: Train Loss: 2.1831, Train Accuracy: 42.12%
#     Worker 5: Train Loss: 2.1716, Train Accuracy: 42.84%
#     Worker 6: Train Loss: 2.2187, Train Accuracy: 41.34%
#     Worker 7: Train Loss: 2.1943, Train Accuracy: 42.14%
# Epoch 46/150: Test Loss: 2.1513, Test Accuracy: 43.84%
#     Worker 0: Train Loss: 2.1873, Train Accuracy: 41.58%
#     Worker 1: Train Loss: 2.1834, Train Accuracy: 41.48%
#     Worker 2: Train Loss: 2.1519, Train Accuracy: 43.44%
#     Worker 3: Train Loss: 2.2109, Train Accuracy: 41.02%
#     Worker 4: Train Loss: 2.1442, Train Accuracy: 43.32%
#     Worker 5: Train Loss: 2.1490, Train Accuracy: 42.70%
#     Worker 6: Train Loss: 2.2029, Train Accuracy: 41.63%
#     Worker 7: Train Loss: 2.1547, Train Accuracy: 42.84%
# Epoch 47/150: Test Loss: 2.1457, Test Accuracy: 43.84%
#     Worker 0: Train Loss: 2.1696, Train Accuracy: 41.93%
#     Worker 1: Train Loss: 2.1369, Train Accuracy: 42.39%
#     Worker 2: Train Loss: 2.1375, Train Accuracy: 42.79%
#     Worker 3: Train Loss: 2.1441, Train Accuracy: 42.68%
#     Worker 4: Train Loss: 2.1098, Train Accuracy: 43.45%
#     Worker 5: Train Loss: 2.1528, Train Accuracy: 43.24%
#     Worker 6: Train Loss: 2.1673, Train Accuracy: 42.15%
#     Worker 7: Train Loss: 2.1557, Train Accuracy: 42.65%
# Epoch 48/150: Test Loss: 2.1455, Test Accuracy: 44.11%
#     Worker 0: Train Loss: 2.1416, Train Accuracy: 42.81%
#     Worker 1: Train Loss: 2.1069, Train Accuracy: 43.51%
#     Worker 2: Train Loss: 2.1122, Train Accuracy: 43.91%
#     Worker 3: Train Loss: 2.1418, Train Accuracy: 42.88%
#     Worker 4: Train Loss: 2.1197, Train Accuracy: 43.38%
#     Worker 5: Train Loss: 2.1119, Train Accuracy: 43.58%
#     Worker 6: Train Loss: 2.1687, Train Accuracy: 42.15%
#     Worker 7: Train Loss: 2.1623, Train Accuracy: 42.91%
# Epoch 49/150: Test Loss: 2.1345, Test Accuracy: 44.07%
#     Worker 0: Train Loss: 2.1314, Train Accuracy: 43.36%
#     Worker 1: Train Loss: 2.0927, Train Accuracy: 43.33%
#     Worker 2: Train Loss: 2.1264, Train Accuracy: 43.40%
#     Worker 3: Train Loss: 2.1506, Train Accuracy: 42.46%
#     Worker 4: Train Loss: 2.0721, Train Accuracy: 45.03%
#     Worker 5: Train Loss: 2.1024, Train Accuracy: 44.12%
#     Worker 6: Train Loss: 2.1345, Train Accuracy: 43.54%
#     Worker 7: Train Loss: 2.1003, Train Accuracy: 43.70%
# Epoch 50/150: Test Loss: 2.1012, Test Accuracy: 45.28%
#     Worker 0: Train Loss: 2.1037, Train Accuracy: 43.87%
#     Worker 1: Train Loss: 2.0838, Train Accuracy: 44.26%
#     Worker 2: Train Loss: 2.0979, Train Accuracy: 43.67%
#     Worker 3: Train Loss: 2.1109, Train Accuracy: 43.44%
#     Worker 4: Train Loss: 2.0728, Train Accuracy: 44.51%
#     Worker 5: Train Loss: 2.0814, Train Accuracy: 44.71%
#     Worker 6: Train Loss: 2.1232, Train Accuracy: 43.79%
#     Worker 7: Train Loss: 2.1112, Train Accuracy: 43.81%
# Epoch 51/150: Test Loss: 2.1058, Test Accuracy: 45.06%
#     Worker 0: Train Loss: 2.1143, Train Accuracy: 43.38%
#     Worker 1: Train Loss: 2.0564, Train Accuracy: 44.22%
#     Worker 2: Train Loss: 2.0852, Train Accuracy: 44.30%
#     Worker 3: Train Loss: 2.1049, Train Accuracy: 43.46%
#     Worker 4: Train Loss: 2.0472, Train Accuracy: 45.45%
#     Worker 5: Train Loss: 2.0609, Train Accuracy: 44.82%
#     Worker 6: Train Loss: 2.0907, Train Accuracy: 44.71%
#     Worker 7: Train Loss: 2.0667, Train Accuracy: 44.04%
# Epoch 52/150: Test Loss: 2.1077, Test Accuracy: 44.89%
#     Worker 0: Train Loss: 2.0612, Train Accuracy: 43.93%
#     Worker 1: Train Loss: 2.0472, Train Accuracy: 44.60%
#     Worker 2: Train Loss: 2.0592, Train Accuracy: 45.07%
#     Worker 3: Train Loss: 2.0876, Train Accuracy: 44.25%
#     Worker 4: Train Loss: 2.0559, Train Accuracy: 44.44%
#     Worker 5: Train Loss: 2.0724, Train Accuracy: 43.62%
#     Worker 6: Train Loss: 2.0599, Train Accuracy: 44.72%
#     Worker 7: Train Loss: 2.0698, Train Accuracy: 43.59%
# Epoch 53/150: Test Loss: 2.0915, Test Accuracy: 45.44%
#     Worker 0: Train Loss: 2.0654, Train Accuracy: 44.60%
#     Worker 1: Train Loss: 2.0036, Train Accuracy: 45.97%
#     Worker 2: Train Loss: 2.0473, Train Accuracy: 45.90%
#     Worker 3: Train Loss: 2.0485, Train Accuracy: 44.82%
#     Worker 4: Train Loss: 2.0026, Train Accuracy: 45.86%
#     Worker 5: Train Loss: 2.0204, Train Accuracy: 46.73%
#     Worker 6: Train Loss: 2.0656, Train Accuracy: 44.51%
#     Worker 7: Train Loss: 2.0369, Train Accuracy: 45.35%
# Epoch 54/150: Test Loss: 2.0867, Test Accuracy: 45.68%
#     Worker 0: Train Loss: 2.0408, Train Accuracy: 44.46%
#     Worker 1: Train Loss: 2.0076, Train Accuracy: 45.73%
#     Worker 2: Train Loss: 2.0107, Train Accuracy: 46.19%
#     Worker 3: Train Loss: 2.0578, Train Accuracy: 44.64%
#     Worker 4: Train Loss: 1.9698, Train Accuracy: 47.05%
#     Worker 5: Train Loss: 2.0462, Train Accuracy: 45.76%
#     Worker 6: Train Loss: 2.0571, Train Accuracy: 44.54%
#     Worker 7: Train Loss: 2.0337, Train Accuracy: 44.64%
# Epoch 55/150: Test Loss: 2.0831, Test Accuracy: 45.84%
#     Worker 0: Train Loss: 2.0264, Train Accuracy: 45.70%
#     Worker 1: Train Loss: 1.9979, Train Accuracy: 45.90%
#     Worker 2: Train Loss: 1.9928, Train Accuracy: 46.43%
#     Worker 3: Train Loss: 2.0199, Train Accuracy: 45.51%
#     Worker 4: Train Loss: 2.0186, Train Accuracy: 45.75%
#     Worker 5: Train Loss: 2.0236, Train Accuracy: 46.24%
#     Worker 6: Train Loss: 2.0157, Train Accuracy: 45.86%
#     Worker 7: Train Loss: 2.0120, Train Accuracy: 45.90%
# Epoch 56/150: Test Loss: 2.0656, Test Accuracy: 45.59%
#     Worker 0: Train Loss: 2.0070, Train Accuracy: 45.75%
#     Worker 1: Train Loss: 1.9659, Train Accuracy: 46.07%
#     Worker 2: Train Loss: 1.9822, Train Accuracy: 46.14%
#     Worker 3: Train Loss: 2.0132, Train Accuracy: 46.31%
#     Worker 4: Train Loss: 1.9825, Train Accuracy: 46.53%
#     Worker 5: Train Loss: 1.9826, Train Accuracy: 47.35%
#     Worker 6: Train Loss: 2.0196, Train Accuracy: 46.39%
#     Worker 7: Train Loss: 1.9998, Train Accuracy: 46.59%
# Epoch 57/150: Test Loss: 2.0629, Test Accuracy: 46.06%
#     Worker 0: Train Loss: 2.0151, Train Accuracy: 45.82%
#     Worker 1: Train Loss: 1.9512, Train Accuracy: 47.01%
#     Worker 2: Train Loss: 1.9644, Train Accuracy: 46.91%
#     Worker 3: Train Loss: 1.9782, Train Accuracy: 46.54%
#     Worker 4: Train Loss: 1.9344, Train Accuracy: 47.17%
#     Worker 5: Train Loss: 1.9550, Train Accuracy: 48.03%
#     Worker 6: Train Loss: 1.9905, Train Accuracy: 46.64%
#     Worker 7: Train Loss: 1.9755, Train Accuracy: 46.70%
# Epoch 58/150: Test Loss: 2.0588, Test Accuracy: 46.33%
#     Worker 0: Train Loss: 1.9659, Train Accuracy: 46.52%
#     Worker 1: Train Loss: 1.9418, Train Accuracy: 47.08%
#     Worker 2: Train Loss: 1.9620, Train Accuracy: 47.17%
#     Worker 3: Train Loss: 1.9704, Train Accuracy: 47.15%
#     Worker 4: Train Loss: 1.9427, Train Accuracy: 47.77%
#     Worker 5: Train Loss: 1.9733, Train Accuracy: 46.95%
#     Worker 6: Train Loss: 1.9741, Train Accuracy: 46.95%
#     Worker 7: Train Loss: 1.9648, Train Accuracy: 46.87%
# Epoch 59/150: Test Loss: 2.0433, Test Accuracy: 46.58%
#     Worker 0: Train Loss: 1.9680, Train Accuracy: 46.31%
#     Worker 1: Train Loss: 1.9359, Train Accuracy: 47.02%
#     Worker 2: Train Loss: 1.9441, Train Accuracy: 47.50%
#     Worker 3: Train Loss: 1.9671, Train Accuracy: 47.26%
#     Worker 4: Train Loss: 1.9354, Train Accuracy: 47.87%
#     Worker 5: Train Loss: 1.9340, Train Accuracy: 47.34%
#     Worker 6: Train Loss: 1.9916, Train Accuracy: 47.26%
#     Worker 7: Train Loss: 1.9629, Train Accuracy: 46.56%
# Epoch 60/150: Test Loss: 2.0464, Test Accuracy: 46.55%
#     Worker 0: Train Loss: 1.9126, Train Accuracy: 48.18%
#     Worker 1: Train Loss: 1.9238, Train Accuracy: 47.64%
#     Worker 2: Train Loss: 1.9290, Train Accuracy: 47.80%
#     Worker 3: Train Loss: 1.9112, Train Accuracy: 47.64%
#     Worker 4: Train Loss: 1.8849, Train Accuracy: 48.45%
#     Worker 5: Train Loss: 1.9059, Train Accuracy: 48.54%
#     Worker 6: Train Loss: 1.9608, Train Accuracy: 47.33%
#     Worker 7: Train Loss: 1.9192, Train Accuracy: 48.15%
# Epoch 61/150: Test Loss: 2.0396, Test Accuracy: 46.80%
#     Worker 0: Train Loss: 1.9426, Train Accuracy: 46.59%
#     Worker 1: Train Loss: 1.8814, Train Accuracy: 48.50%
#     Worker 2: Train Loss: 1.9038, Train Accuracy: 47.82%
#     Worker 3: Train Loss: 1.9014, Train Accuracy: 48.28%
#     Worker 4: Train Loss: 1.9148, Train Accuracy: 47.97%
#     Worker 5: Train Loss: 1.9020, Train Accuracy: 48.49%
#     Worker 6: Train Loss: 1.9509, Train Accuracy: 47.76%
#     Worker 7: Train Loss: 1.9252, Train Accuracy: 47.94%
# Epoch 62/150: Test Loss: 2.0258, Test Accuracy: 46.89%
#     Worker 0: Train Loss: 1.9169, Train Accuracy: 48.11%
#     Worker 1: Train Loss: 1.8829, Train Accuracy: 49.09%
#     Worker 2: Train Loss: 1.9122, Train Accuracy: 48.45%
#     Worker 3: Train Loss: 1.9062, Train Accuracy: 48.11%
#     Worker 4: Train Loss: 1.8884, Train Accuracy: 48.66%
#     Worker 5: Train Loss: 1.9029, Train Accuracy: 48.73%
#     Worker 6: Train Loss: 1.9066, Train Accuracy: 49.23%
#     Worker 7: Train Loss: 1.8842, Train Accuracy: 48.46%
# Epoch 63/150: Test Loss: 2.0287, Test Accuracy: 47.16%
#     Worker 0: Train Loss: 1.8923, Train Accuracy: 48.13%
#     Worker 1: Train Loss: 1.8675, Train Accuracy: 49.10%
#     Worker 2: Train Loss: 1.8774, Train Accuracy: 48.78%
#     Worker 3: Train Loss: 1.9160, Train Accuracy: 48.64%
#     Worker 4: Train Loss: 1.8505, Train Accuracy: 49.42%
#     Worker 5: Train Loss: 1.9022, Train Accuracy: 48.18%
#     Worker 6: Train Loss: 1.9234, Train Accuracy: 47.61%
#     Worker 7: Train Loss: 1.8934, Train Accuracy: 48.12%
# Epoch 64/150: Test Loss: 2.0180, Test Accuracy: 47.55%
#     Worker 0: Train Loss: 1.8812, Train Accuracy: 48.28%
#     Worker 1: Train Loss: 1.8436, Train Accuracy: 49.57%
#     Worker 2: Train Loss: 1.8533, Train Accuracy: 50.06%
#     Worker 3: Train Loss: 1.8856, Train Accuracy: 48.31%
#     Worker 4: Train Loss: 1.8707, Train Accuracy: 48.68%
#     Worker 5: Train Loss: 1.8596, Train Accuracy: 50.49%
#     Worker 6: Train Loss: 1.8568, Train Accuracy: 49.83%
#     Worker 7: Train Loss: 1.8714, Train Accuracy: 49.87%
# Epoch 65/150: Test Loss: 2.0103, Test Accuracy: 47.34%
#     Worker 0: Train Loss: 1.8760, Train Accuracy: 48.73%
#     Worker 1: Train Loss: 1.8470, Train Accuracy: 49.51%
#     Worker 2: Train Loss: 1.8409, Train Accuracy: 49.72%
#     Worker 3: Train Loss: 1.8493, Train Accuracy: 49.50%
#     Worker 4: Train Loss: 1.8350, Train Accuracy: 50.13%
#     Worker 5: Train Loss: 1.8446, Train Accuracy: 49.79%
#     Worker 6: Train Loss: 1.8784, Train Accuracy: 49.22%
#     Worker 7: Train Loss: 1.8557, Train Accuracy: 49.52%
# Epoch 66/150: Test Loss: 2.0165, Test Accuracy: 47.36%
#     Worker 0: Train Loss: 1.8358, Train Accuracy: 48.88%
#     Worker 1: Train Loss: 1.8474, Train Accuracy: 48.91%
#     Worker 2: Train Loss: 1.8372, Train Accuracy: 50.06%
#     Worker 3: Train Loss: 1.8455, Train Accuracy: 50.24%
#     Worker 4: Train Loss: 1.8228, Train Accuracy: 50.08%
#     Worker 5: Train Loss: 1.8269, Train Accuracy: 50.22%
#     Worker 6: Train Loss: 1.8629, Train Accuracy: 49.30%
#     Worker 7: Train Loss: 1.8412, Train Accuracy: 49.80%
# Epoch 67/150: Test Loss: 2.0140, Test Accuracy: 47.08%
#     Worker 0: Train Loss: 1.8518, Train Accuracy: 49.72%
#     Worker 1: Train Loss: 1.7988, Train Accuracy: 51.02%
#     Worker 2: Train Loss: 1.8240, Train Accuracy: 50.18%
#     Worker 3: Train Loss: 1.8272, Train Accuracy: 50.73%
#     Worker 4: Train Loss: 1.7892, Train Accuracy: 50.59%
#     Worker 5: Train Loss: 1.8263, Train Accuracy: 50.10%
#     Worker 6: Train Loss: 1.8521, Train Accuracy: 49.38%
#     Worker 7: Train Loss: 1.8451, Train Accuracy: 49.52%
# Epoch 68/150: Test Loss: 2.0018, Test Accuracy: 47.65%
#     Worker 0: Train Loss: 1.8229, Train Accuracy: 49.78%
#     Worker 1: Train Loss: 1.7688, Train Accuracy: 50.57%
#     Worker 2: Train Loss: 1.8056, Train Accuracy: 50.39%
#     Worker 3: Train Loss: 1.8102, Train Accuracy: 50.87%
#     Worker 4: Train Loss: 1.8258, Train Accuracy: 50.50%
#     Worker 5: Train Loss: 1.7843, Train Accuracy: 51.04%
#     Worker 6: Train Loss: 1.8093, Train Accuracy: 50.85%
#     Worker 7: Train Loss: 1.8010, Train Accuracy: 50.87%
# Epoch 69/150: Test Loss: 1.9904, Test Accuracy: 47.90%
#     Worker 0: Train Loss: 1.8091, Train Accuracy: 50.59%
#     Worker 1: Train Loss: 1.7994, Train Accuracy: 50.49%
#     Worker 2: Train Loss: 1.8130, Train Accuracy: 50.25%
#     Worker 3: Train Loss: 1.8159, Train Accuracy: 50.45%
#     Worker 4: Train Loss: 1.7608, Train Accuracy: 51.47%
#     Worker 5: Train Loss: 1.7920, Train Accuracy: 51.13%
#     Worker 6: Train Loss: 1.8325, Train Accuracy: 50.32%
#     Worker 7: Train Loss: 1.8022, Train Accuracy: 50.74%
# Epoch 70/150: Test Loss: 2.0001, Test Accuracy: 47.69%
#     Worker 0: Train Loss: 1.8065, Train Accuracy: 50.20%
#     Worker 1: Train Loss: 1.7777, Train Accuracy: 51.75%
#     Worker 2: Train Loss: 1.7750, Train Accuracy: 51.26%
#     Worker 3: Train Loss: 1.8074, Train Accuracy: 50.25%
#     Worker 4: Train Loss: 1.7670, Train Accuracy: 51.68%
#     Worker 5: Train Loss: 1.7864, Train Accuracy: 50.81%
#     Worker 6: Train Loss: 1.8070, Train Accuracy: 51.39%
#     Worker 7: Train Loss: 1.7778, Train Accuracy: 51.46%
# Epoch 71/150: Test Loss: 1.9934, Test Accuracy: 47.98%
#     Worker 0: Train Loss: 1.7824, Train Accuracy: 50.91%
#     Worker 1: Train Loss: 1.7509, Train Accuracy: 51.69%
#     Worker 2: Train Loss: 1.7520, Train Accuracy: 52.06%
#     Worker 3: Train Loss: 1.8075, Train Accuracy: 50.85%
#     Worker 4: Train Loss: 1.7727, Train Accuracy: 51.65%
#     Worker 5: Train Loss: 1.7843, Train Accuracy: 51.12%
#     Worker 6: Train Loss: 1.7723, Train Accuracy: 51.20%
#     Worker 7: Train Loss: 1.7720, Train Accuracy: 50.91%
# Epoch 72/150: Test Loss: 1.9904, Test Accuracy: 48.00%
#     Worker 0: Train Loss: 1.7879, Train Accuracy: 51.37%
#     Worker 1: Train Loss: 1.7510, Train Accuracy: 52.16%
#     Worker 2: Train Loss: 1.7473, Train Accuracy: 52.41%
#     Worker 3: Train Loss: 1.7760, Train Accuracy: 51.19%
#     Worker 4: Train Loss: 1.7494, Train Accuracy: 51.33%
#     Worker 5: Train Loss: 1.7393, Train Accuracy: 52.17%
#     Worker 6: Train Loss: 1.7830, Train Accuracy: 50.94%
#     Worker 7: Train Loss: 1.7567, Train Accuracy: 51.92%
# Epoch 73/150: Test Loss: 1.9972, Test Accuracy: 48.15%
#     Worker 0: Train Loss: 1.7607, Train Accuracy: 51.29%
#     Worker 1: Train Loss: 1.7167, Train Accuracy: 53.18%
#     Worker 2: Train Loss: 1.7419, Train Accuracy: 52.11%
#     Worker 3: Train Loss: 1.7521, Train Accuracy: 51.65%
#     Worker 4: Train Loss: 1.7437, Train Accuracy: 51.69%
#     Worker 5: Train Loss: 1.7671, Train Accuracy: 51.92%
#     Worker 6: Train Loss: 1.7491, Train Accuracy: 52.28%
#     Worker 7: Train Loss: 1.7223, Train Accuracy: 51.85%
# Epoch 74/150: Test Loss: 1.9845, Test Accuracy: 48.50%
#     Worker 0: Train Loss: 1.7546, Train Accuracy: 51.34%
#     Worker 1: Train Loss: 1.7163, Train Accuracy: 53.58%
#     Worker 2: Train Loss: 1.7391, Train Accuracy: 51.83%
#     Worker 3: Train Loss: 1.7474, Train Accuracy: 52.42%
#     Worker 4: Train Loss: 1.7169, Train Accuracy: 52.31%
#     Worker 5: Train Loss: 1.7289, Train Accuracy: 52.34%
#     Worker 6: Train Loss: 1.7550, Train Accuracy: 52.11%
#     Worker 7: Train Loss: 1.7470, Train Accuracy: 51.48%
# Epoch 75/150: Test Loss: 1.9790, Test Accuracy: 48.61%
#     Worker 0: Train Loss: 1.7165, Train Accuracy: 51.90%
#     Worker 1: Train Loss: 1.6802, Train Accuracy: 53.20%
#     Worker 2: Train Loss: 1.7129, Train Accuracy: 52.71%
#     Worker 3: Train Loss: 1.7377, Train Accuracy: 51.58%
#     Worker 4: Train Loss: 1.7101, Train Accuracy: 52.92%
#     Worker 5: Train Loss: 1.7005, Train Accuracy: 53.51%
#     Worker 6: Train Loss: 1.7360, Train Accuracy: 52.42%
#     Worker 7: Train Loss: 1.7371, Train Accuracy: 51.86%
# Epoch 76/150: Test Loss: 1.9707, Test Accuracy: 48.58%
#     Worker 0: Train Loss: 1.7205, Train Accuracy: 52.41%
#     Worker 1: Train Loss: 1.6588, Train Accuracy: 53.89%
#     Worker 2: Train Loss: 1.6890, Train Accuracy: 53.36%
#     Worker 3: Train Loss: 1.7218, Train Accuracy: 52.94%
#     Worker 4: Train Loss: 1.6821, Train Accuracy: 53.54%
#     Worker 5: Train Loss: 1.6904, Train Accuracy: 53.47%
#     Worker 6: Train Loss: 1.7420, Train Accuracy: 51.86%
#     Worker 7: Train Loss: 1.7299, Train Accuracy: 52.80%
# Epoch 77/150: Test Loss: 1.9857, Test Accuracy: 48.28%
#     Worker 0: Train Loss: 1.7155, Train Accuracy: 52.70%
#     Worker 1: Train Loss: 1.6979, Train Accuracy: 52.93%
#     Worker 2: Train Loss: 1.7068, Train Accuracy: 52.50%
#     Worker 3: Train Loss: 1.7038, Train Accuracy: 53.03%
#     Worker 4: Train Loss: 1.6748, Train Accuracy: 53.78%
#     Worker 5: Train Loss: 1.6956, Train Accuracy: 53.82%
#     Worker 6: Train Loss: 1.7158, Train Accuracy: 52.86%
#     Worker 7: Train Loss: 1.7097, Train Accuracy: 52.89%
# Epoch 78/150: Test Loss: 1.9710, Test Accuracy: 48.56%
#     Worker 0: Train Loss: 1.6856, Train Accuracy: 52.78%
#     Worker 1: Train Loss: 1.6610, Train Accuracy: 54.02%
#     Worker 2: Train Loss: 1.6679, Train Accuracy: 53.90%
#     Worker 3: Train Loss: 1.6716, Train Accuracy: 52.90%
#     Worker 4: Train Loss: 1.6425, Train Accuracy: 54.63%
#     Worker 5: Train Loss: 1.6793, Train Accuracy: 53.61%
#     Worker 6: Train Loss: 1.7067, Train Accuracy: 53.78%
#     Worker 7: Train Loss: 1.6867, Train Accuracy: 53.55%
# Epoch 79/150: Test Loss: 1.9770, Test Accuracy: 48.53%
#     Worker 0: Train Loss: 1.6859, Train Accuracy: 53.95%
#     Worker 1: Train Loss: 1.6502, Train Accuracy: 53.82%
#     Worker 2: Train Loss: 1.6690, Train Accuracy: 53.55%
#     Worker 3: Train Loss: 1.6978, Train Accuracy: 53.15%
#     Worker 4: Train Loss: 1.6786, Train Accuracy: 53.16%
#     Worker 5: Train Loss: 1.6697, Train Accuracy: 53.95%
#     Worker 6: Train Loss: 1.6756, Train Accuracy: 53.76%
#     Worker 7: Train Loss: 1.6467, Train Accuracy: 54.16%
# Epoch 80/150: Test Loss: 1.9664, Test Accuracy: 49.30%
#     Worker 0: Train Loss: 1.6470, Train Accuracy: 54.00%
#     Worker 1: Train Loss: 1.6324, Train Accuracy: 54.32%
#     Worker 2: Train Loss: 1.6808, Train Accuracy: 54.37%
#     Worker 3: Train Loss: 1.6684, Train Accuracy: 53.46%
#     Worker 4: Train Loss: 1.6416, Train Accuracy: 54.65%
#     Worker 5: Train Loss: 1.6581, Train Accuracy: 54.42%
#     Worker 6: Train Loss: 1.6978, Train Accuracy: 53.43%
#     Worker 7: Train Loss: 1.6859, Train Accuracy: 53.20%
# Epoch 81/150: Test Loss: 1.9606, Test Accuracy: 49.16%
#     Worker 0: Train Loss: 1.6682, Train Accuracy: 53.74%
#     Worker 1: Train Loss: 1.6143, Train Accuracy: 55.77%
#     Worker 2: Train Loss: 1.6319, Train Accuracy: 54.59%
#     Worker 3: Train Loss: 1.6573, Train Accuracy: 53.72%
#     Worker 4: Train Loss: 1.6227, Train Accuracy: 55.50%
#     Worker 5: Train Loss: 1.6739, Train Accuracy: 53.75%
#     Worker 6: Train Loss: 1.6741, Train Accuracy: 53.58%
#     Worker 7: Train Loss: 1.6354, Train Accuracy: 54.98%
# Epoch 82/150: Test Loss: 1.9667, Test Accuracy: 49.03%
#     Worker 0: Train Loss: 1.6500, Train Accuracy: 53.78%
#     Worker 1: Train Loss: 1.6193, Train Accuracy: 54.63%
#     Worker 2: Train Loss: 1.6481, Train Accuracy: 54.24%
#     Worker 3: Train Loss: 1.6180, Train Accuracy: 55.04%
#     Worker 4: Train Loss: 1.5658, Train Accuracy: 55.98%
#     Worker 5: Train Loss: 1.6216, Train Accuracy: 55.35%
#     Worker 6: Train Loss: 1.6819, Train Accuracy: 53.33%
#     Worker 7: Train Loss: 1.6246, Train Accuracy: 55.28%
# Epoch 83/150: Test Loss: 1.9687, Test Accuracy: 48.97%
#     Worker 0: Train Loss: 1.6319, Train Accuracy: 55.02%
#     Worker 1: Train Loss: 1.5952, Train Accuracy: 55.30%
#     Worker 2: Train Loss: 1.6340, Train Accuracy: 54.98%
#     Worker 3: Train Loss: 1.6377, Train Accuracy: 54.02%
#     Worker 4: Train Loss: 1.6097, Train Accuracy: 55.30%
#     Worker 5: Train Loss: 1.6340, Train Accuracy: 55.36%
#     Worker 6: Train Loss: 1.6540, Train Accuracy: 54.56%
#     Worker 7: Train Loss: 1.6189, Train Accuracy: 54.90%
# Epoch 84/150: Test Loss: 1.9685, Test Accuracy: 48.90%
#     Worker 0: Train Loss: 1.6405, Train Accuracy: 54.66%
#     Worker 1: Train Loss: 1.6030, Train Accuracy: 55.47%
#     Worker 2: Train Loss: 1.6206, Train Accuracy: 54.25%
#     Worker 3: Train Loss: 1.6213, Train Accuracy: 54.83%
#     Worker 4: Train Loss: 1.6080, Train Accuracy: 54.49%
#     Worker 5: Train Loss: 1.5905, Train Accuracy: 55.99%
#     Worker 6: Train Loss: 1.6438, Train Accuracy: 54.80%
#     Worker 7: Train Loss: 1.6464, Train Accuracy: 54.00%
# Epoch 85/150: Test Loss: 1.9608, Test Accuracy: 49.42%
#     Worker 0: Train Loss: 1.6036, Train Accuracy: 54.44%
#     Worker 1: Train Loss: 1.5916, Train Accuracy: 56.05%
#     Worker 2: Train Loss: 1.5970, Train Accuracy: 55.70%
#     Worker 3: Train Loss: 1.6241, Train Accuracy: 55.23%
#     Worker 4: Train Loss: 1.6031, Train Accuracy: 55.02%
#     Worker 5: Train Loss: 1.6035, Train Accuracy: 55.82%
#     Worker 6: Train Loss: 1.6339, Train Accuracy: 55.28%
#     Worker 7: Train Loss: 1.5911, Train Accuracy: 55.88%
# Epoch 86/150: Test Loss: 1.9582, Test Accuracy: 49.83%
#     Worker 0: Train Loss: 1.6058, Train Accuracy: 54.87%
#     Worker 1: Train Loss: 1.5807, Train Accuracy: 56.09%
#     Worker 2: Train Loss: 1.5609, Train Accuracy: 55.89%
#     Worker 3: Train Loss: 1.6044, Train Accuracy: 55.40%
#     Worker 4: Train Loss: 1.5535, Train Accuracy: 57.08%
#     Worker 5: Train Loss: 1.5860, Train Accuracy: 56.69%
#     Worker 6: Train Loss: 1.6198, Train Accuracy: 55.43%
#     Worker 7: Train Loss: 1.5906, Train Accuracy: 55.84%
# Epoch 87/150: Test Loss: 1.9559, Test Accuracy: 49.51%
#     Worker 0: Train Loss: 1.5970, Train Accuracy: 55.57%
#     Worker 1: Train Loss: 1.5616, Train Accuracy: 56.65%
#     Worker 2: Train Loss: 1.5742, Train Accuracy: 56.87%
#     Worker 3: Train Loss: 1.5832, Train Accuracy: 55.43%
#     Worker 4: Train Loss: 1.5864, Train Accuracy: 55.54%
#     Worker 5: Train Loss: 1.5587, Train Accuracy: 56.82%
#     Worker 6: Train Loss: 1.6080, Train Accuracy: 55.78%
#     Worker 7: Train Loss: 1.5699, Train Accuracy: 56.38%
# Epoch 88/150: Test Loss: 1.9561, Test Accuracy: 49.38%
#     Worker 0: Train Loss: 1.5989, Train Accuracy: 55.18%
#     Worker 1: Train Loss: 1.5532, Train Accuracy: 56.00%
#     Worker 2: Train Loss: 1.5503, Train Accuracy: 57.37%
#     Worker 3: Train Loss: 1.5876, Train Accuracy: 55.99%
#     Worker 4: Train Loss: 1.5261, Train Accuracy: 57.05%
#     Worker 5: Train Loss: 1.5726, Train Accuracy: 56.49%
#     Worker 6: Train Loss: 1.6064, Train Accuracy: 55.54%
#     Worker 7: Train Loss: 1.5599, Train Accuracy: 56.13%
# Epoch 89/150: Test Loss: 1.9581, Test Accuracy: 49.62%
#     Worker 0: Train Loss: 1.5791, Train Accuracy: 55.26%
#     Worker 1: Train Loss: 1.5245, Train Accuracy: 56.90%
#     Worker 2: Train Loss: 1.5625, Train Accuracy: 56.49%
#     Worker 3: Train Loss: 1.5451, Train Accuracy: 56.49%
#     Worker 4: Train Loss: 1.5378, Train Accuracy: 57.46%
#     Worker 5: Train Loss: 1.5637, Train Accuracy: 57.14%
#     Worker 6: Train Loss: 1.5715, Train Accuracy: 56.52%
#     Worker 7: Train Loss: 1.5423, Train Accuracy: 56.69%
# Epoch 90/150: Test Loss: 1.9554, Test Accuracy: 49.61%
#     Worker 0: Train Loss: 1.5743, Train Accuracy: 56.58%
#     Worker 1: Train Loss: 1.5169, Train Accuracy: 57.21%
#     Worker 2: Train Loss: 1.5254, Train Accuracy: 57.21%
#     Worker 3: Train Loss: 1.5708, Train Accuracy: 56.12%
#     Worker 4: Train Loss: 1.5287, Train Accuracy: 57.65%
#     Worker 5: Train Loss: 1.5486, Train Accuracy: 56.63%
#     Worker 6: Train Loss: 1.5895, Train Accuracy: 55.43%
#     Worker 7: Train Loss: 1.5469, Train Accuracy: 56.95%
# Epoch 91/150: Test Loss: 1.9643, Test Accuracy: 49.55%
#     Worker 0: Train Loss: 1.5786, Train Accuracy: 55.66%
#     Worker 1: Train Loss: 1.5202, Train Accuracy: 57.65%
#     Worker 2: Train Loss: 1.5356, Train Accuracy: 57.40%
#     Worker 3: Train Loss: 1.5409, Train Accuracy: 56.91%
#     Worker 4: Train Loss: 1.5398, Train Accuracy: 57.22%
#     Worker 5: Train Loss: 1.5249, Train Accuracy: 57.83%
#     Worker 6: Train Loss: 1.5857, Train Accuracy: 55.92%
#     Worker 7: Train Loss: 1.5383, Train Accuracy: 57.45%
# Epoch 92/150: Test Loss: 1.9495, Test Accuracy: 49.79%
#     Worker 0: Train Loss: 1.5345, Train Accuracy: 56.95%
#     Worker 1: Train Loss: 1.5106, Train Accuracy: 57.26%
#     Worker 2: Train Loss: 1.5251, Train Accuracy: 57.84%
#     Worker 3: Train Loss: 1.5356, Train Accuracy: 57.15%
#     Worker 4: Train Loss: 1.5077, Train Accuracy: 58.19%
#     Worker 5: Train Loss: 1.5167, Train Accuracy: 58.06%
#     Worker 6: Train Loss: 1.5666, Train Accuracy: 56.58%
#     Worker 7: Train Loss: 1.5129, Train Accuracy: 58.09%
# Epoch 93/150: Test Loss: 1.9560, Test Accuracy: 49.71%
#     Worker 0: Train Loss: 1.5165, Train Accuracy: 57.42%
#     Worker 1: Train Loss: 1.5057, Train Accuracy: 56.97%
#     Worker 2: Train Loss: 1.4963, Train Accuracy: 57.79%
#     Worker 3: Train Loss: 1.5229, Train Accuracy: 57.11%
#     Worker 4: Train Loss: 1.5056, Train Accuracy: 58.28%
#     Worker 5: Train Loss: 1.5187, Train Accuracy: 57.42%
#     Worker 6: Train Loss: 1.5428, Train Accuracy: 56.72%
#     Worker 7: Train Loss: 1.4979, Train Accuracy: 58.27%
# Epoch 94/150: Test Loss: 1.9507, Test Accuracy: 50.19%
#     Worker 0: Train Loss: 1.5230, Train Accuracy: 57.58%
# ...
#     Worker 6: Train Loss: 1.3428, Train Accuracy: 62.84%
#     Worker 7: Train Loss: 1.3029, Train Accuracy: 63.55%
# Epoch 120/150: Test Loss: 1.9614, Test Accuracy: 50.78%
#     Worker 0: Train Loss: 1.3265, Train Accuracy: 62.54%
#     Worker 1: Train Loss: 1.2959, Train Accuracy: 62.68%
#     Worker 2: Train Loss: 1.2890, Train Accuracy: 63.18%
#     Worker 3: Train Loss: 1.2996, Train Accuracy: 63.34%
#     Worker 4: Train Loss: 1.2677, Train Accuracy: 64.23%
#     Worker 5: Train Loss: 1.3117, Train Accuracy: 63.67%
#     Worker 6: Train Loss: 1.3181, Train Accuracy: 62.59%
#     Worker 7: Train Loss: 1.3130, Train Accuracy: 63.38%
# Epoch 121/150: Test Loss: 1.9619, Test Accuracy: 50.57%
#     Worker 0: Train Loss: 1.3027, Train Accuracy: 63.59%
#     Worker 1: Train Loss: 1.2824, Train Accuracy: 63.04%
#     Worker 2: Train Loss: 1.2887, Train Accuracy: 64.30%
#     Worker 3: Train Loss: 1.2875, Train Accuracy: 62.96%
#     Worker 4: Train Loss: 1.3059, Train Accuracy: 62.96%
#     Worker 5: Train Loss: 1.2683, Train Accuracy: 63.83%
#     Worker 6: Train Loss: 1.3155, Train Accuracy: 63.24%
#     Worker 7: Train Loss: 1.2669, Train Accuracy: 64.71%
# Epoch 122/150: Test Loss: 1.9636, Test Accuracy: 50.63%
#     Worker 0: Train Loss: 1.3176, Train Accuracy: 61.98%
#     Worker 1: Train Loss: 1.2706, Train Accuracy: 63.94%
#     Worker 2: Train Loss: 1.2842, Train Accuracy: 63.32%
#     Worker 3: Train Loss: 1.2971, Train Accuracy: 63.31%
#     Worker 4: Train Loss: 1.2632, Train Accuracy: 63.87%
#     Worker 5: Train Loss: 1.3048, Train Accuracy: 62.85%
#     Worker 6: Train Loss: 1.3287, Train Accuracy: 62.76%
#     Worker 7: Train Loss: 1.2999, Train Accuracy: 62.85%
# Epoch 123/150: Test Loss: 1.9659, Test Accuracy: 50.60%
#     Worker 0: Train Loss: 1.3071, Train Accuracy: 63.52%
#     Worker 1: Train Loss: 1.2722, Train Accuracy: 63.67%
#     Worker 2: Train Loss: 1.2753, Train Accuracy: 64.27%
#     Worker 3: Train Loss: 1.3045, Train Accuracy: 63.21%
#     Worker 4: Train Loss: 1.2688, Train Accuracy: 64.86%
#     Worker 5: Train Loss: 1.2570, Train Accuracy: 64.71%
#     Worker 6: Train Loss: 1.3017, Train Accuracy: 62.97%
#     Worker 7: Train Loss: 1.2870, Train Accuracy: 63.49%
# Epoch 124/150: Test Loss: 1.9670, Test Accuracy: 50.42%
#     Worker 0: Train Loss: 1.3133, Train Accuracy: 63.48%
#     Worker 1: Train Loss: 1.2529, Train Accuracy: 63.91%
#     Worker 2: Train Loss: 1.3000, Train Accuracy: 62.86%
#     Worker 3: Train Loss: 1.2780, Train Accuracy: 64.04%
#     Worker 4: Train Loss: 1.2676, Train Accuracy: 64.30%
#     Worker 5: Train Loss: 1.2643, Train Accuracy: 64.40%
#     Worker 6: Train Loss: 1.3188, Train Accuracy: 62.31%
#     Worker 7: Train Loss: 1.2971, Train Accuracy: 63.10%
# Epoch 125/150: Test Loss: 1.9663, Test Accuracy: 50.62%
#     Worker 0: Train Loss: 1.3235, Train Accuracy: 62.13%
#     Worker 1: Train Loss: 1.2536, Train Accuracy: 63.88%
#     Worker 2: Train Loss: 1.2768, Train Accuracy: 63.92%
#     Worker 3: Train Loss: 1.2740, Train Accuracy: 64.22%
#     Worker 4: Train Loss: 1.2778, Train Accuracy: 63.81%
#     Worker 5: Train Loss: 1.2874, Train Accuracy: 63.80%
#     Worker 6: Train Loss: 1.3126, Train Accuracy: 62.76%
#     Worker 7: Train Loss: 1.2684, Train Accuracy: 63.74%
# Epoch 126/150: Test Loss: 1.9643, Test Accuracy: 50.52%
#     Worker 0: Train Loss: 1.2936, Train Accuracy: 63.36%
#     Worker 1: Train Loss: 1.2728, Train Accuracy: 64.05%
#     Worker 2: Train Loss: 1.2552, Train Accuracy: 64.53%
#     Worker 3: Train Loss: 1.2828, Train Accuracy: 63.91%
#     Worker 4: Train Loss: 1.2506, Train Accuracy: 64.21%
#     Worker 5: Train Loss: 1.2766, Train Accuracy: 63.80%
#     Worker 6: Train Loss: 1.2917, Train Accuracy: 63.46%
#     Worker 7: Train Loss: 1.2714, Train Accuracy: 63.36%
# Epoch 127/150: Test Loss: 1.9639, Test Accuracy: 50.60%
#     Worker 0: Train Loss: 1.2694, Train Accuracy: 64.29%
#     Worker 1: Train Loss: 1.2545, Train Accuracy: 64.58%
#     Worker 2: Train Loss: 1.2599, Train Accuracy: 64.37%
#     Worker 3: Train Loss: 1.2823, Train Accuracy: 64.15%
#     Worker 4: Train Loss: 1.2531, Train Accuracy: 64.54%
#     Worker 5: Train Loss: 1.2685, Train Accuracy: 64.37%
#     Worker 6: Train Loss: 1.3075, Train Accuracy: 63.36%
#     Worker 7: Train Loss: 1.2725, Train Accuracy: 64.60%
# Epoch 128/150: Test Loss: 1.9656, Test Accuracy: 50.72%
#     Worker 0: Train Loss: 1.2717, Train Accuracy: 64.01%
#     Worker 1: Train Loss: 1.2413, Train Accuracy: 63.95%
#     Worker 2: Train Loss: 1.2625, Train Accuracy: 64.22%
#     Worker 3: Train Loss: 1.2689, Train Accuracy: 64.05%
#     Worker 4: Train Loss: 1.2634, Train Accuracy: 64.22%
#     Worker 5: Train Loss: 1.2748, Train Accuracy: 64.69%
#     Worker 6: Train Loss: 1.3058, Train Accuracy: 63.35%
#     Worker 7: Train Loss: 1.2547, Train Accuracy: 64.25%
# Epoch 129/150: Test Loss: 1.9690, Test Accuracy: 50.71%
#     Worker 0: Train Loss: 1.2668, Train Accuracy: 63.73%
#     Worker 1: Train Loss: 1.2362, Train Accuracy: 64.65%
#     Worker 2: Train Loss: 1.2602, Train Accuracy: 64.08%
#     Worker 3: Train Loss: 1.2664, Train Accuracy: 64.20%
#     Worker 4: Train Loss: 1.2418, Train Accuracy: 64.75%
#     Worker 5: Train Loss: 1.2334, Train Accuracy: 65.16%
#     Worker 6: Train Loss: 1.2698, Train Accuracy: 64.32%
#     Worker 7: Train Loss: 1.2284, Train Accuracy: 65.39%
# Epoch 130/150: Test Loss: 1.9671, Test Accuracy: 50.62%
#     Worker 0: Train Loss: 1.2746, Train Accuracy: 64.47%
#     Worker 1: Train Loss: 1.2441, Train Accuracy: 64.51%
#     Worker 2: Train Loss: 1.2542, Train Accuracy: 64.25%
#     Worker 3: Train Loss: 1.2506, Train Accuracy: 65.25%
#     Worker 4: Train Loss: 1.2466, Train Accuracy: 64.69%
#     Worker 5: Train Loss: 1.2683, Train Accuracy: 63.45%
#     Worker 6: Train Loss: 1.2978, Train Accuracy: 62.92%
#     Worker 7: Train Loss: 1.2560, Train Accuracy: 64.83%
# Epoch 131/150: Test Loss: 1.9657, Test Accuracy: 50.70%
#     Worker 0: Train Loss: 1.2745, Train Accuracy: 63.77%
#     Worker 1: Train Loss: 1.2478, Train Accuracy: 64.79%
#     Worker 2: Train Loss: 1.2432, Train Accuracy: 64.58%
#     Worker 3: Train Loss: 1.2647, Train Accuracy: 64.58%
#     Worker 4: Train Loss: 1.2215, Train Accuracy: 65.07%
#     Worker 5: Train Loss: 1.2335, Train Accuracy: 66.05%
#     Worker 6: Train Loss: 1.2798, Train Accuracy: 64.33%
#     Worker 7: Train Loss: 1.2621, Train Accuracy: 63.74%
# Epoch 132/150: Test Loss: 1.9685, Test Accuracy: 50.58%
#     Worker 0: Train Loss: 1.2601, Train Accuracy: 64.26%
#     Worker 1: Train Loss: 1.2300, Train Accuracy: 64.51%
#     Worker 2: Train Loss: 1.2470, Train Accuracy: 64.47%
#     Worker 3: Train Loss: 1.2647, Train Accuracy: 63.77%
#     Worker 4: Train Loss: 1.2354, Train Accuracy: 64.89%
#     Worker 5: Train Loss: 1.2854, Train Accuracy: 64.47%
#     Worker 6: Train Loss: 1.2804, Train Accuracy: 63.20%
#     Worker 7: Train Loss: 1.2349, Train Accuracy: 65.24%
# Epoch 133/150: Test Loss: 1.9692, Test Accuracy: 50.62%
#     Worker 0: Train Loss: 1.2609, Train Accuracy: 63.71%
#     Worker 1: Train Loss: 1.2415, Train Accuracy: 64.80%
#     Worker 2: Train Loss: 1.2363, Train Accuracy: 65.13%
#     Worker 3: Train Loss: 1.2614, Train Accuracy: 64.70%
#     Worker 4: Train Loss: 1.2452, Train Accuracy: 64.44%
#     Worker 5: Train Loss: 1.2405, Train Accuracy: 64.94%
#     Worker 6: Train Loss: 1.2720, Train Accuracy: 64.12%
#     Worker 7: Train Loss: 1.2473, Train Accuracy: 64.53%
# Epoch 134/150: Test Loss: 1.9701, Test Accuracy: 50.50%
#     Worker 0: Train Loss: 1.2593, Train Accuracy: 64.02%
#     Worker 1: Train Loss: 1.2132, Train Accuracy: 65.11%
#     Worker 2: Train Loss: 1.2328, Train Accuracy: 65.10%
#     Worker 3: Train Loss: 1.2621, Train Accuracy: 64.67%
#     Worker 4: Train Loss: 1.2299, Train Accuracy: 65.67%
#     Worker 5: Train Loss: 1.2625, Train Accuracy: 64.60%
#     Worker 6: Train Loss: 1.2731, Train Accuracy: 64.57%
#     Worker 7: Train Loss: 1.2508, Train Accuracy: 64.88%
# Epoch 135/150: Test Loss: 1.9703, Test Accuracy: 50.98%
#     Worker 0: Train Loss: 1.2567, Train Accuracy: 64.46%
#     Worker 1: Train Loss: 1.2330, Train Accuracy: 65.21%
#     Worker 2: Train Loss: 1.2297, Train Accuracy: 64.89%
#     Worker 3: Train Loss: 1.2421, Train Accuracy: 65.20%
#     Worker 4: Train Loss: 1.2466, Train Accuracy: 64.90%
#     Worker 5: Train Loss: 1.2271, Train Accuracy: 65.35%
#     Worker 6: Train Loss: 1.2713, Train Accuracy: 63.92%
#     Worker 7: Train Loss: 1.2484, Train Accuracy: 64.26%
# Epoch 136/150: Test Loss: 1.9708, Test Accuracy: 50.65%
#     Worker 0: Train Loss: 1.2630, Train Accuracy: 64.02%
#     Worker 1: Train Loss: 1.2210, Train Accuracy: 65.10%
#     Worker 2: Train Loss: 1.2370, Train Accuracy: 64.58%
#     Worker 3: Train Loss: 1.2610, Train Accuracy: 64.11%
#     Worker 4: Train Loss: 1.2553, Train Accuracy: 64.62%
#     Worker 5: Train Loss: 1.2185, Train Accuracy: 65.11%
#     Worker 6: Train Loss: 1.2799, Train Accuracy: 63.59%
#     Worker 7: Train Loss: 1.2321, Train Accuracy: 65.46%
# Epoch 137/150: Test Loss: 1.9708, Test Accuracy: 50.64%
#     Worker 0: Train Loss: 1.2654, Train Accuracy: 64.32%
#     Worker 1: Train Loss: 1.2374, Train Accuracy: 64.97%
#     Worker 2: Train Loss: 1.2304, Train Accuracy: 64.96%
#     Worker 3: Train Loss: 1.2333, Train Accuracy: 65.11%
#     Worker 4: Train Loss: 1.2085, Train Accuracy: 65.23%
#     Worker 5: Train Loss: 1.2239, Train Accuracy: 65.73%
#     Worker 6: Train Loss: 1.2534, Train Accuracy: 64.48%
#     Worker 7: Train Loss: 1.2328, Train Accuracy: 64.90%
# Epoch 138/150: Test Loss: 1.9714, Test Accuracy: 50.68%
#     Worker 0: Train Loss: 1.2353, Train Accuracy: 65.06%
#     Worker 1: Train Loss: 1.2257, Train Accuracy: 64.82%
#     Worker 2: Train Loss: 1.2368, Train Accuracy: 65.09%
#     Worker 3: Train Loss: 1.2524, Train Accuracy: 64.68%
#     Worker 4: Train Loss: 1.2380, Train Accuracy: 64.89%
#     Worker 5: Train Loss: 1.2347, Train Accuracy: 64.81%
#     Worker 6: Train Loss: 1.2732, Train Accuracy: 64.57%
#     Worker 7: Train Loss: 1.2216, Train Accuracy: 65.21%
# Epoch 139/150: Test Loss: 1.9703, Test Accuracy: 50.66%
#     Worker 0: Train Loss: 1.2331, Train Accuracy: 65.10%
#     Worker 1: Train Loss: 1.2312, Train Accuracy: 65.16%
#     Worker 2: Train Loss: 1.2325, Train Accuracy: 64.65%
#     Worker 3: Train Loss: 1.2650, Train Accuracy: 64.78%
#     Worker 4: Train Loss: 1.2356, Train Accuracy: 65.53%
#     Worker 5: Train Loss: 1.2367, Train Accuracy: 64.95%
#     Worker 6: Train Loss: 1.2611, Train Accuracy: 63.71%
#     Worker 7: Train Loss: 1.2494, Train Accuracy: 64.36%
# Epoch 140/150: Test Loss: 1.9708, Test Accuracy: 50.69%
#     Worker 0: Train Loss: 1.2659, Train Accuracy: 63.52%
#     Worker 1: Train Loss: 1.2170, Train Accuracy: 65.44%
#     Worker 2: Train Loss: 1.2366, Train Accuracy: 64.88%
#     Worker 3: Train Loss: 1.2429, Train Accuracy: 65.06%
#     Worker 4: Train Loss: 1.2223, Train Accuracy: 65.50%
#     Worker 5: Train Loss: 1.2256, Train Accuracy: 65.48%
#     Worker 6: Train Loss: 1.2568, Train Accuracy: 64.51%
#     Worker 7: Train Loss: 1.2289, Train Accuracy: 65.23%
# Epoch 141/150: Test Loss: 1.9704, Test Accuracy: 50.64%
#     Worker 0: Train Loss: 1.2342, Train Accuracy: 65.38%
#     Worker 1: Train Loss: 1.2423, Train Accuracy: 64.58%
#     Worker 2: Train Loss: 1.2324, Train Accuracy: 64.93%
#     Worker 3: Train Loss: 1.2594, Train Accuracy: 64.64%
#     Worker 4: Train Loss: 1.2173, Train Accuracy: 65.42%
#     Worker 5: Train Loss: 1.2172, Train Accuracy: 65.69%
#     Worker 6: Train Loss: 1.2787, Train Accuracy: 63.92%
#     Worker 7: Train Loss: 1.2278, Train Accuracy: 65.34%
# Epoch 142/150: Test Loss: 1.9710, Test Accuracy: 50.70%
#     Worker 0: Train Loss: 1.2393, Train Accuracy: 64.22%
#     Worker 1: Train Loss: 1.2192, Train Accuracy: 65.16%
#     Worker 2: Train Loss: 1.2272, Train Accuracy: 65.95%
#     Worker 3: Train Loss: 1.2354, Train Accuracy: 64.88%
#     Worker 4: Train Loss: 1.2233, Train Accuracy: 65.66%
#     Worker 5: Train Loss: 1.2391, Train Accuracy: 64.44%
#     Worker 6: Train Loss: 1.2542, Train Accuracy: 64.41%
#     Worker 7: Train Loss: 1.2392, Train Accuracy: 65.00%
# Epoch 143/150: Test Loss: 1.9710, Test Accuracy: 50.72%
#     Worker 0: Train Loss: 1.2531, Train Accuracy: 64.50%
#     Worker 1: Train Loss: 1.2041, Train Accuracy: 65.38%
#     Worker 2: Train Loss: 1.2121, Train Accuracy: 65.62%
#     Worker 3: Train Loss: 1.2481, Train Accuracy: 64.96%
#     Worker 4: Train Loss: 1.1983, Train Accuracy: 65.87%
#     Worker 5: Train Loss: 1.2506, Train Accuracy: 64.53%
#     Worker 6: Train Loss: 1.2563, Train Accuracy: 64.51%
#     Worker 7: Train Loss: 1.2290, Train Accuracy: 64.40%
# Epoch 144/150: Test Loss: 1.9714, Test Accuracy: 50.77%
#     Worker 0: Train Loss: 1.2437, Train Accuracy: 63.99%
#     Worker 1: Train Loss: 1.2391, Train Accuracy: 64.72%
#     Worker 2: Train Loss: 1.2166, Train Accuracy: 65.98%
#     Worker 3: Train Loss: 1.2389, Train Accuracy: 64.86%
#     Worker 4: Train Loss: 1.2139, Train Accuracy: 65.53%
#     Worker 5: Train Loss: 1.2184, Train Accuracy: 65.59%
#     Worker 6: Train Loss: 1.2431, Train Accuracy: 64.72%
#     Worker 7: Train Loss: 1.2113, Train Accuracy: 66.64%
# Epoch 145/150: Test Loss: 1.9708, Test Accuracy: 50.67%
#     Worker 0: Train Loss: 1.2607, Train Accuracy: 64.90%
#     Worker 1: Train Loss: 1.2201, Train Accuracy: 65.66%
#     Worker 2: Train Loss: 1.2193, Train Accuracy: 65.18%
#     Worker 3: Train Loss: 1.2461, Train Accuracy: 64.79%
#     Worker 4: Train Loss: 1.2307, Train Accuracy: 65.74%
#     Worker 5: Train Loss: 1.2324, Train Accuracy: 64.74%
#     Worker 6: Train Loss: 1.2836, Train Accuracy: 64.13%
#     Worker 7: Train Loss: 1.2295, Train Accuracy: 65.23%
# Epoch 146/150: Test Loss: 1.9712, Test Accuracy: 50.69%
#     Worker 0: Train Loss: 1.2355, Train Accuracy: 64.83%
#     Worker 1: Train Loss: 1.2191, Train Accuracy: 64.95%
#     Worker 2: Train Loss: 1.2185, Train Accuracy: 65.67%
#     Worker 3: Train Loss: 1.2349, Train Accuracy: 65.35%
#     Worker 4: Train Loss: 1.2251, Train Accuracy: 65.37%
#     Worker 5: Train Loss: 1.2433, Train Accuracy: 64.74%
#     Worker 6: Train Loss: 1.2472, Train Accuracy: 64.71%
#     Worker 7: Train Loss: 1.2433, Train Accuracy: 64.79%
# Epoch 147/150: Test Loss: 1.9710, Test Accuracy: 50.73%
#     Worker 0: Train Loss: 1.2387, Train Accuracy: 64.74%
#     Worker 1: Train Loss: 1.2156, Train Accuracy: 65.09%
#     Worker 2: Train Loss: 1.2166, Train Accuracy: 65.33%
#     Worker 3: Train Loss: 1.2370, Train Accuracy: 65.17%
#     Worker 4: Train Loss: 1.2258, Train Accuracy: 65.41%
#     Worker 5: Train Loss: 1.2205, Train Accuracy: 65.43%
#     Worker 6: Train Loss: 1.2592, Train Accuracy: 64.21%
#     Worker 7: Train Loss: 1.2395, Train Accuracy: 65.33%
# Epoch 148/150: Test Loss: 1.9709, Test Accuracy: 50.74%
#     Worker 0: Train Loss: 1.2476, Train Accuracy: 65.04%
#     Worker 1: Train Loss: 1.2172, Train Accuracy: 65.49%
#     Worker 2: Train Loss: 1.2327, Train Accuracy: 65.11%
#     Worker 3: Train Loss: 1.2572, Train Accuracy: 64.18%
#     Worker 4: Train Loss: 1.2237, Train Accuracy: 65.90%
#     Worker 5: Train Loss: 1.2282, Train Accuracy: 65.53%
#     Worker 6: Train Loss: 1.2653, Train Accuracy: 64.19%
#     Worker 7: Train Loss: 1.2286, Train Accuracy: 65.06%
# Epoch 149/150: Test Loss: 1.9709, Test Accuracy: 50.74%
#     Worker 0: Train Loss: 1.2508, Train Accuracy: 64.41%
#     Worker 1: Train Loss: 1.2064, Train Accuracy: 66.13%
#     Worker 2: Train Loss: 1.2340, Train Accuracy: 64.34%
#     Worker 3: Train Loss: 1.2171, Train Accuracy: 65.84%
#     Worker 4: Train Loss: 1.2192, Train Accuracy: 65.70%
#     Worker 5: Train Loss: 1.2511, Train Accuracy: 64.99%
#     Worker 6: Train Loss: 1.2661, Train Accuracy: 64.57%
#     Worker 7: Train Loss: 1.2366, Train Accuracy: 65.04%
# Epoch 150/150: Test Loss: 1.9709, Test Accuracy: 50.72%
#     Worker 0: Train Loss: 1.2385, Train Accuracy: 64.86%
#     Worker 1: Train Loss: 1.2427, Train Accuracy: 64.40%
#     Worker 2: Train Loss: 1.2028, Train Accuracy: 65.39%
#     Worker 3: Train Loss: 1.2499, Train Accuracy: 65.06%
#     Worker 4: Train Loss: 1.2167, Train Accuracy: 65.69%
#     Worker 5: Train Loss: 1.2188, Train Accuracy: 65.07%
#     Worker 6: Train Loss: 1.2873, Train Accuracy: 64.12%
#     Worker 7: Train Loss: 1.2076, Train Accuracy: 65.51%
