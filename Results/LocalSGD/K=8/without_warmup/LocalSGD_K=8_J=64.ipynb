# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
#warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")

    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch):
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            # Perform J local step before synchronization
            for j in range(J):
                try:
                    # Get a batch from the current worker's shard using next()
                    images, labels = next(shard_iterators[k])
                    images, labels = images.to(device), labels.to(device)  # Move to device
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

                except StopIteration:
                    # If the iterator has exhausted the data, restart the iterator
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k]) # Resume from the next batch
                    images, labels = images.to(device), labels.to(device)
                    # Perform optimization step
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        # Perform model synchronization
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            # Update each worker model with the global parameters
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
       # if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
       # else:
        #    warmup_factor = (epoch + 1) / warmup_epochs
          #  lr = warmup_factor * learning_rate
          #  for optimizer in optimizers:
           #     for param_group in optimizer.param_groups:
            #        param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 8 --j 64
# Out:
# Training with K=8, J=64
# Global iteration per epoch: 2
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00800
# Epoch 1/150: Test Loss: 4.5480, Test Accuracy: 2.84%
#     Worker 0: Train Loss: 4.5944, Train Accuracy: 1.54%
#     Worker 1: Train Loss: 4.5935, Train Accuracy: 1.24%
#     Worker 2: Train Loss: 4.5950, Train Accuracy: 1.49%
#     Worker 3: Train Loss: 4.5926, Train Accuracy: 1.18%
#     Worker 4: Train Loss: 4.5927, Train Accuracy: 1.19%
#     Worker 5: Train Loss: 4.5878, Train Accuracy: 1.64%
#     Worker 6: Train Loss: 4.5955, Train Accuracy: 1.49%
#     Worker 7: Train Loss: 4.5904, Train Accuracy: 1.27%
# Epoch 2/150: Test Loss: 4.1615, Test Accuracy: 6.19%
#     Worker 0: Train Loss: 4.3911, Train Accuracy: 3.62%
#     Worker 1: Train Loss: 4.3912, Train Accuracy: 3.37%
#     Worker 2: Train Loss: 4.3786, Train Accuracy: 3.79%
#     Worker 3: Train Loss: 4.3894, Train Accuracy: 3.90%
#     Worker 4: Train Loss: 4.3706, Train Accuracy: 4.32%
#     Worker 5: Train Loss: 4.3687, Train Accuracy: 3.55%
#     Worker 6: Train Loss: 4.3920, Train Accuracy: 3.38%
#     Worker 7: Train Loss: 4.3814, Train Accuracy: 3.40%
# Epoch 3/150: Test Loss: 3.9877, Test Accuracy: 8.66%
#     Worker 0: Train Loss: 4.1423, Train Accuracy: 6.52%
#     Worker 1: Train Loss: 4.1541, Train Accuracy: 6.14%
#     Worker 2: Train Loss: 4.1570, Train Accuracy: 5.83%
#     Worker 3: Train Loss: 4.1612, Train Accuracy: 5.50%
#     Worker 4: Train Loss: 4.1134, Train Accuracy: 6.82%
#     Worker 5: Train Loss: 4.1235, Train Accuracy: 6.22%
#     Worker 6: Train Loss: 4.1573, Train Accuracy: 5.64%
#     Worker 7: Train Loss: 4.1496, Train Accuracy: 6.28%
# Epoch 4/150: Test Loss: 3.8378, Test Accuracy: 11.28%
#     Worker 0: Train Loss: 4.0178, Train Accuracy: 7.98%
#     Worker 1: Train Loss: 4.0331, Train Accuracy: 7.43%
#     Worker 2: Train Loss: 4.0175, Train Accuracy: 8.38%
#     Worker 3: Train Loss: 4.0259, Train Accuracy: 7.93%
#     Worker 4: Train Loss: 3.9902, Train Accuracy: 7.97%
#     Worker 5: Train Loss: 3.9801, Train Accuracy: 8.51%
#     Worker 6: Train Loss: 4.0089, Train Accuracy: 7.73%
#     Worker 7: Train Loss: 4.0193, Train Accuracy: 7.84%
# Epoch 5/150: Test Loss: 3.7186, Test Accuracy: 13.70%
#     Worker 0: Train Loss: 3.9131, Train Accuracy: 9.30%
#     Worker 1: Train Loss: 3.9019, Train Accuracy: 9.42%
#     Worker 2: Train Loss: 3.9098, Train Accuracy: 9.57%
#     Worker 3: Train Loss: 3.9227, Train Accuracy: 9.94%
#     Worker 4: Train Loss: 3.8603, Train Accuracy: 10.00%
#     Worker 5: Train Loss: 3.8730, Train Accuracy: 10.40%
#     Worker 6: Train Loss: 3.9164, Train Accuracy: 9.25%
#     Worker 7: Train Loss: 3.9063, Train Accuracy: 9.44%
# Epoch 6/150: Test Loss: 3.6158, Test Accuracy: 15.10%
#     Worker 0: Train Loss: 3.7997, Train Accuracy: 11.19%
#     Worker 1: Train Loss: 3.8112, Train Accuracy: 10.70%
#     Worker 2: Train Loss: 3.7700, Train Accuracy: 11.85%
#     Worker 3: Train Loss: 3.8210, Train Accuracy: 11.49%
#     Worker 4: Train Loss: 3.7686, Train Accuracy: 11.48%
#     Worker 5: Train Loss: 3.7513, Train Accuracy: 12.59%
#     Worker 6: Train Loss: 3.8020, Train Accuracy: 11.33%
#     Worker 7: Train Loss: 3.7991, Train Accuracy: 11.03%
# Epoch 7/150: Test Loss: 3.5102, Test Accuracy: 16.89%
#     Worker 0: Train Loss: 3.6970, Train Accuracy: 12.76%
#     Worker 1: Train Loss: 3.7004, Train Accuracy: 12.71%
#     Worker 2: Train Loss: 3.6897, Train Accuracy: 13.28%
#     Worker 3: Train Loss: 3.7349, Train Accuracy: 12.62%
#     Worker 4: Train Loss: 3.6624, Train Accuracy: 13.12%
#     Worker 5: Train Loss: 3.6600, Train Accuracy: 13.45%
#     Worker 6: Train Loss: 3.7198, Train Accuracy: 12.53%
#     Worker 7: Train Loss: 3.7228, Train Accuracy: 12.85%
# Epoch 8/150: Test Loss: 3.4395, Test Accuracy: 18.25%
#     Worker 0: Train Loss: 3.6328, Train Accuracy: 13.43%
#     Worker 1: Train Loss: 3.6324, Train Accuracy: 14.00%
#     Worker 2: Train Loss: 3.6208, Train Accuracy: 14.24%
#     Worker 3: Train Loss: 3.6817, Train Accuracy: 12.95%
#     Worker 4: Train Loss: 3.5726, Train Accuracy: 15.12%
#     Worker 5: Train Loss: 3.5809, Train Accuracy: 15.08%
#     Worker 6: Train Loss: 3.6499, Train Accuracy: 13.22%
#     Worker 7: Train Loss: 3.6335, Train Accuracy: 13.73%
# Epoch 9/150: Test Loss: 3.3660, Test Accuracy: 20.11%
#     Worker 0: Train Loss: 3.5590, Train Accuracy: 15.35%
#     Worker 1: Train Loss: 3.5612, Train Accuracy: 14.36%
#     Worker 2: Train Loss: 3.5524, Train Accuracy: 15.06%
#     Worker 3: Train Loss: 3.5906, Train Accuracy: 14.49%
#     Worker 4: Train Loss: 3.5428, Train Accuracy: 15.30%
#     Worker 5: Train Loss: 3.5369, Train Accuracy: 15.74%
#     Worker 6: Train Loss: 3.5926, Train Accuracy: 14.47%
#     Worker 7: Train Loss: 3.5657, Train Accuracy: 14.88%
# Epoch 10/150: Test Loss: 3.2838, Test Accuracy: 21.72%
#     Worker 0: Train Loss: 3.4952, Train Accuracy: 15.73%
#     Worker 1: Train Loss: 3.4754, Train Accuracy: 16.54%
#     Worker 2: Train Loss: 3.4690, Train Accuracy: 17.08%
#     Worker 3: Train Loss: 3.5190, Train Accuracy: 16.29%
#     Worker 4: Train Loss: 3.4365, Train Accuracy: 16.85%
#     Worker 5: Train Loss: 3.4142, Train Accuracy: 17.71%
#     Worker 6: Train Loss: 3.4726, Train Accuracy: 16.40%
#     Worker 7: Train Loss: 3.4892, Train Accuracy: 16.21%
# Epoch 11/150: Test Loss: 3.2054, Test Accuracy: 22.59%
#     Worker 0: Train Loss: 3.4154, Train Accuracy: 17.43%
#     Worker 1: Train Loss: 3.4074, Train Accuracy: 17.37%
#     Worker 2: Train Loss: 3.3916, Train Accuracy: 17.82%
#     Worker 3: Train Loss: 3.4402, Train Accuracy: 17.44%
#     Worker 4: Train Loss: 3.3771, Train Accuracy: 17.86%
#     Worker 5: Train Loss: 3.3730, Train Accuracy: 18.38%
#     Worker 6: Train Loss: 3.4364, Train Accuracy: 16.85%
#     Worker 7: Train Loss: 3.4030, Train Accuracy: 17.78%
# Epoch 12/150: Test Loss: 3.1564, Test Accuracy: 23.77%
#     Worker 0: Train Loss: 3.3728, Train Accuracy: 18.24%
#     Worker 1: Train Loss: 3.3512, Train Accuracy: 18.24%
#     Worker 2: Train Loss: 3.3678, Train Accuracy: 18.92%
#     Worker 3: Train Loss: 3.4168, Train Accuracy: 17.50%
#     Worker 4: Train Loss: 3.3455, Train Accuracy: 18.87%
#     Worker 5: Train Loss: 3.3176, Train Accuracy: 19.30%
#     Worker 6: Train Loss: 3.3585, Train Accuracy: 18.80%
#     Worker 7: Train Loss: 3.3750, Train Accuracy: 18.73%
# Epoch 13/150: Test Loss: 3.0969, Test Accuracy: 24.45%
#     Worker 0: Train Loss: 3.3082, Train Accuracy: 18.97%
#     Worker 1: Train Loss: 3.2995, Train Accuracy: 19.85%
#     Worker 2: Train Loss: 3.3003, Train Accuracy: 19.79%
#     Worker 3: Train Loss: 3.3379, Train Accuracy: 19.01%
#     Worker 4: Train Loss: 3.2632, Train Accuracy: 20.51%
#     Worker 5: Train Loss: 3.2545, Train Accuracy: 20.82%
#     Worker 6: Train Loss: 3.3243, Train Accuracy: 19.16%
#     Worker 7: Train Loss: 3.3047, Train Accuracy: 19.35%
# Epoch 14/150: Test Loss: 3.0372, Test Accuracy: 25.68%
#     Worker 0: Train Loss: 3.2385, Train Accuracy: 21.08%
#     Worker 1: Train Loss: 3.2332, Train Accuracy: 20.73%
#     Worker 2: Train Loss: 3.2214, Train Accuracy: 21.81%
#     Worker 3: Train Loss: 3.2791, Train Accuracy: 19.51%
#     Worker 4: Train Loss: 3.1956, Train Accuracy: 21.80%
#     Worker 5: Train Loss: 3.1947, Train Accuracy: 21.83%
#     Worker 6: Train Loss: 3.2590, Train Accuracy: 20.53%
#     Worker 7: Train Loss: 3.2367, Train Accuracy: 20.62%
# Epoch 15/150: Test Loss: 2.9782, Test Accuracy: 26.77%
#     Worker 0: Train Loss: 3.1893, Train Accuracy: 21.30%
#     Worker 1: Train Loss: 3.1879, Train Accuracy: 21.26%
#     Worker 2: Train Loss: 3.1907, Train Accuracy: 21.93%
#     Worker 3: Train Loss: 3.2189, Train Accuracy: 21.18%
#     Worker 4: Train Loss: 3.1724, Train Accuracy: 22.29%
#     Worker 5: Train Loss: 3.1383, Train Accuracy: 22.41%
#     Worker 6: Train Loss: 3.2074, Train Accuracy: 21.57%
#     Worker 7: Train Loss: 3.1858, Train Accuracy: 21.86%
# Epoch 16/150: Test Loss: 2.9206, Test Accuracy: 27.94%
#     Worker 0: Train Loss: 3.1391, Train Accuracy: 22.30%
#     Worker 1: Train Loss: 3.0987, Train Accuracy: 23.17%
#     Worker 2: Train Loss: 3.1586, Train Accuracy: 22.12%
#     Worker 3: Train Loss: 3.1516, Train Accuracy: 22.29%
#     Worker 4: Train Loss: 3.1057, Train Accuracy: 23.21%
#     Worker 5: Train Loss: 3.1129, Train Accuracy: 23.27%
#     Worker 6: Train Loss: 3.1488, Train Accuracy: 22.84%
#     Worker 7: Train Loss: 3.1226, Train Accuracy: 23.71%
# Epoch 17/150: Test Loss: 2.8689, Test Accuracy: 28.89%
#     Worker 0: Train Loss: 3.0740, Train Accuracy: 23.59%
#     Worker 1: Train Loss: 3.0694, Train Accuracy: 23.78%
#     Worker 2: Train Loss: 3.0888, Train Accuracy: 23.66%
#     Worker 3: Train Loss: 3.1008, Train Accuracy: 23.54%
#     Worker 4: Train Loss: 3.0543, Train Accuracy: 23.98%
#     Worker 5: Train Loss: 3.0369, Train Accuracy: 25.01%
#     Worker 6: Train Loss: 3.1291, Train Accuracy: 22.58%
#     Worker 7: Train Loss: 3.0718, Train Accuracy: 23.59%
# Epoch 18/150: Test Loss: 2.8353, Test Accuracy: 29.77%
#     Worker 0: Train Loss: 3.0467, Train Accuracy: 23.92%
#     Worker 1: Train Loss: 3.0547, Train Accuracy: 23.76%
#     Worker 2: Train Loss: 3.0156, Train Accuracy: 25.41%
#     Worker 3: Train Loss: 3.0868, Train Accuracy: 23.33%
#     Worker 4: Train Loss: 3.0244, Train Accuracy: 25.01%
#     Worker 5: Train Loss: 2.9856, Train Accuracy: 25.24%
#     Worker 6: Train Loss: 3.0596, Train Accuracy: 23.56%
#     Worker 7: Train Loss: 3.0423, Train Accuracy: 24.94%
# Epoch 19/150: Test Loss: 2.7862, Test Accuracy: 30.81%
#     Worker 0: Train Loss: 3.0030, Train Accuracy: 25.02%
#     Worker 1: Train Loss: 2.9630, Train Accuracy: 26.23%
#     Worker 2: Train Loss: 3.0109, Train Accuracy: 25.14%
#     Worker 3: Train Loss: 3.0323, Train Accuracy: 24.35%
#     Worker 4: Train Loss: 2.9684, Train Accuracy: 25.62%
#     Worker 5: Train Loss: 2.9636, Train Accuracy: 26.24%
#     Worker 6: Train Loss: 3.0362, Train Accuracy: 24.80%
#     Worker 7: Train Loss: 2.9732, Train Accuracy: 25.47%
# Epoch 20/150: Test Loss: 2.7351, Test Accuracy: 31.36%
#     Worker 0: Train Loss: 2.9525, Train Accuracy: 26.07%
#     Worker 1: Train Loss: 2.9188, Train Accuracy: 26.55%
#     Worker 2: Train Loss: 2.9380, Train Accuracy: 26.20%
#     Worker 3: Train Loss: 2.9678, Train Accuracy: 26.24%
#     Worker 4: Train Loss: 2.8938, Train Accuracy: 27.88%
#     Worker 5: Train Loss: 2.9200, Train Accuracy: 27.36%
#     Worker 6: Train Loss: 2.9435, Train Accuracy: 25.86%
#     Worker 7: Train Loss: 2.9373, Train Accuracy: 26.62%
# Epoch 21/150: Test Loss: 2.7040, Test Accuracy: 31.99%
#     Worker 0: Train Loss: 2.9127, Train Accuracy: 27.43%
#     Worker 1: Train Loss: 2.8966, Train Accuracy: 26.41%
#     Worker 2: Train Loss: 2.9153, Train Accuracy: 26.95%
#     Worker 3: Train Loss: 2.9357, Train Accuracy: 26.13%
#     Worker 4: Train Loss: 2.8813, Train Accuracy: 27.27%
#     Worker 5: Train Loss: 2.9017, Train Accuracy: 26.99%
#     Worker 6: Train Loss: 2.9367, Train Accuracy: 26.13%
#     Worker 7: Train Loss: 2.8999, Train Accuracy: 27.58%
# Epoch 22/150: Test Loss: 2.6430, Test Accuracy: 33.32%
#     Worker 0: Train Loss: 2.8853, Train Accuracy: 27.65%
#     Worker 1: Train Loss: 2.8227, Train Accuracy: 28.42%
#     Worker 2: Train Loss: 2.8566, Train Accuracy: 28.41%
#     Worker 3: Train Loss: 2.8751, Train Accuracy: 27.52%
#     Worker 4: Train Loss: 2.8216, Train Accuracy: 28.36%
#     Worker 5: Train Loss: 2.8039, Train Accuracy: 29.89%
#     Worker 6: Train Loss: 2.8843, Train Accuracy: 27.20%
#     Worker 7: Train Loss: 2.8652, Train Accuracy: 27.43%
# Epoch 23/150: Test Loss: 2.6063, Test Accuracy: 34.22%
#     Worker 0: Train Loss: 2.8125, Train Accuracy: 28.50%
#     Worker 1: Train Loss: 2.7807, Train Accuracy: 29.11%
#     Worker 2: Train Loss: 2.8112, Train Accuracy: 29.36%
#     Worker 3: Train Loss: 2.8270, Train Accuracy: 28.82%
#     Worker 4: Train Loss: 2.7756, Train Accuracy: 29.25%
#     Worker 5: Train Loss: 2.7697, Train Accuracy: 30.35%
#     Worker 6: Train Loss: 2.8182, Train Accuracy: 28.92%
#     Worker 7: Train Loss: 2.8110, Train Accuracy: 29.04%
# Epoch 24/150: Test Loss: 2.5614, Test Accuracy: 34.87%
#     Worker 0: Train Loss: 2.7702, Train Accuracy: 29.41%
#     Worker 1: Train Loss: 2.7481, Train Accuracy: 29.87%
#     Worker 2: Train Loss: 2.7833, Train Accuracy: 29.42%
#     Worker 3: Train Loss: 2.7961, Train Accuracy: 28.85%
#     Worker 4: Train Loss: 2.7407, Train Accuracy: 29.78%
#     Worker 5: Train Loss: 2.7666, Train Accuracy: 30.58%
#     Worker 6: Train Loss: 2.7716, Train Accuracy: 29.88%
#     Worker 7: Train Loss: 2.7751, Train Accuracy: 30.02%
# Epoch 25/150: Test Loss: 2.5531, Test Accuracy: 34.95%
#     Worker 0: Train Loss: 2.7634, Train Accuracy: 30.20%
#     Worker 1: Train Loss: 2.7414, Train Accuracy: 29.93%
#     Worker 2: Train Loss: 2.7806, Train Accuracy: 29.77%
#     Worker 3: Train Loss: 2.7573, Train Accuracy: 29.62%
#     Worker 4: Train Loss: 2.7003, Train Accuracy: 29.95%
#     Worker 5: Train Loss: 2.7241, Train Accuracy: 30.94%
#     Worker 6: Train Loss: 2.7505, Train Accuracy: 29.67%
#     Worker 7: Train Loss: 2.7569, Train Accuracy: 30.15%
# Epoch 26/150: Test Loss: 2.5187, Test Accuracy: 35.86%
#     Worker 0: Train Loss: 2.7204, Train Accuracy: 30.43%
#     Worker 1: Train Loss: 2.6894, Train Accuracy: 30.59%
#     Worker 2: Train Loss: 2.7248, Train Accuracy: 30.70%
#     Worker 3: Train Loss: 2.7386, Train Accuracy: 30.62%
#     Worker 4: Train Loss: 2.6532, Train Accuracy: 31.88%
#     Worker 5: Train Loss: 2.6741, Train Accuracy: 31.96%
#     Worker 6: Train Loss: 2.7279, Train Accuracy: 30.24%
#     Worker 7: Train Loss: 2.7135, Train Accuracy: 30.84%
# Epoch 27/150: Test Loss: 2.4754, Test Accuracy: 36.93%
#     Worker 0: Train Loss: 2.6728, Train Accuracy: 32.14%
#     Worker 1: Train Loss: 2.6363, Train Accuracy: 31.75%
#     Worker 2: Train Loss: 2.6753, Train Accuracy: 31.63%
#     Worker 3: Train Loss: 2.6978, Train Accuracy: 30.73%
#     Worker 4: Train Loss: 2.6148, Train Accuracy: 33.36%
#     Worker 5: Train Loss: 2.6292, Train Accuracy: 32.79%
#     Worker 6: Train Loss: 2.6882, Train Accuracy: 31.82%
#     Worker 7: Train Loss: 2.6525, Train Accuracy: 32.25%
# Epoch 28/150: Test Loss: 2.4550, Test Accuracy: 37.53%
#     Worker 0: Train Loss: 2.6429, Train Accuracy: 33.13%
#     Worker 1: Train Loss: 2.6187, Train Accuracy: 32.20%
#     Worker 2: Train Loss: 2.6526, Train Accuracy: 32.44%
#     Worker 3: Train Loss: 2.6786, Train Accuracy: 32.12%
#     Worker 4: Train Loss: 2.5981, Train Accuracy: 33.55%
#     Worker 5: Train Loss: 2.6221, Train Accuracy: 33.23%
#     Worker 6: Train Loss: 2.6599, Train Accuracy: 31.76%
#     Worker 7: Train Loss: 2.6373, Train Accuracy: 32.29%
# Epoch 29/150: Test Loss: 2.4495, Test Accuracy: 37.33%
#     Worker 0: Train Loss: 2.6225, Train Accuracy: 32.20%
#     Worker 1: Train Loss: 2.5610, Train Accuracy: 33.83%
#     Worker 2: Train Loss: 2.5890, Train Accuracy: 33.55%
#     Worker 3: Train Loss: 2.6343, Train Accuracy: 32.62%
#     Worker 4: Train Loss: 2.5779, Train Accuracy: 32.97%
#     Worker 5: Train Loss: 2.5990, Train Accuracy: 33.75%
#     Worker 6: Train Loss: 2.6209, Train Accuracy: 32.42%
#     Worker 7: Train Loss: 2.6195, Train Accuracy: 32.77%
# Epoch 30/150: Test Loss: 2.3961, Test Accuracy: 38.58%
#     Worker 0: Train Loss: 2.5696, Train Accuracy: 33.49%
#     Worker 1: Train Loss: 2.5573, Train Accuracy: 33.70%
#     Worker 2: Train Loss: 2.5897, Train Accuracy: 33.59%
#     Worker 3: Train Loss: 2.5937, Train Accuracy: 33.06%
#     Worker 4: Train Loss: 2.5060, Train Accuracy: 35.01%
#     Worker 5: Train Loss: 2.5511, Train Accuracy: 34.79%
#     Worker 6: Train Loss: 2.5744, Train Accuracy: 32.99%
#     Worker 7: Train Loss: 2.5619, Train Accuracy: 33.75%
# Epoch 31/150: Test Loss: 2.3749, Test Accuracy: 39.10%
#     Worker 0: Train Loss: 2.5801, Train Accuracy: 33.78%
#     Worker 1: Train Loss: 2.5332, Train Accuracy: 34.32%
#     Worker 2: Train Loss: 2.5297, Train Accuracy: 34.98%
#     Worker 3: Train Loss: 2.5713, Train Accuracy: 33.44%
#     Worker 4: Train Loss: 2.5039, Train Accuracy: 35.13%
#     Worker 5: Train Loss: 2.5322, Train Accuracy: 35.57%
#     Worker 6: Train Loss: 2.5553, Train Accuracy: 33.95%
#     Worker 7: Train Loss: 2.5228, Train Accuracy: 34.55%
# Epoch 32/150: Test Loss: 2.3491, Test Accuracy: 39.79%
#     Worker 0: Train Loss: 2.5564, Train Accuracy: 33.48%
#     Worker 1: Train Loss: 2.5319, Train Accuracy: 34.71%
#     Worker 2: Train Loss: 2.5420, Train Accuracy: 34.90%
#     Worker 3: Train Loss: 2.5411, Train Accuracy: 34.65%
#     Worker 4: Train Loss: 2.5012, Train Accuracy: 35.52%
#     Worker 5: Train Loss: 2.5224, Train Accuracy: 35.73%
#     Worker 6: Train Loss: 2.5260, Train Accuracy: 34.47%
#     Worker 7: Train Loss: 2.5621, Train Accuracy: 33.38%
# Epoch 33/150: Test Loss: 2.3430, Test Accuracy: 39.27%
#     Worker 0: Train Loss: 2.5016, Train Accuracy: 35.42%
#     Worker 1: Train Loss: 2.4530, Train Accuracy: 35.80%
#     Worker 2: Train Loss: 2.4963, Train Accuracy: 36.01%
#     Worker 3: Train Loss: 2.4868, Train Accuracy: 34.81%
#     Worker 4: Train Loss: 2.4294, Train Accuracy: 36.24%
#     Worker 5: Train Loss: 2.4666, Train Accuracy: 36.79%
#     Worker 6: Train Loss: 2.5056, Train Accuracy: 35.21%
#     Worker 7: Train Loss: 2.4883, Train Accuracy: 36.06%
# Epoch 34/150: Test Loss: 2.3187, Test Accuracy: 40.35%
#     Worker 0: Train Loss: 2.4913, Train Accuracy: 34.57%
#     Worker 1: Train Loss: 2.4472, Train Accuracy: 35.73%
#     Worker 2: Train Loss: 2.4803, Train Accuracy: 36.02%
#     Worker 3: Train Loss: 2.4755, Train Accuracy: 35.21%
#     Worker 4: Train Loss: 2.4382, Train Accuracy: 36.12%
#     Worker 5: Train Loss: 2.4532, Train Accuracy: 36.19%
#     Worker 6: Train Loss: 2.5073, Train Accuracy: 35.20%
#     Worker 7: Train Loss: 2.4914, Train Accuracy: 35.37%
# Epoch 35/150: Test Loss: 2.3280, Test Accuracy: 40.06%
#     Worker 0: Train Loss: 2.4829, Train Accuracy: 35.54%
#     Worker 1: Train Loss: 2.4367, Train Accuracy: 36.39%
#     Worker 2: Train Loss: 2.4501, Train Accuracy: 36.61%
#     Worker 3: Train Loss: 2.4612, Train Accuracy: 36.16%
#     Worker 4: Train Loss: 2.4263, Train Accuracy: 36.85%
#     Worker 5: Train Loss: 2.4343, Train Accuracy: 36.66%
#     Worker 6: Train Loss: 2.4462, Train Accuracy: 35.95%
#     Worker 7: Train Loss: 2.4341, Train Accuracy: 37.15%
# Epoch 36/150: Test Loss: 2.2899, Test Accuracy: 41.17%
#     Worker 0: Train Loss: 2.4534, Train Accuracy: 36.12%
#     Worker 1: Train Loss: 2.3902, Train Accuracy: 37.33%
#     Worker 2: Train Loss: 2.4128, Train Accuracy: 37.31%
#     Worker 3: Train Loss: 2.4415, Train Accuracy: 36.71%
#     Worker 4: Train Loss: 2.4068, Train Accuracy: 37.17%
#     Worker 5: Train Loss: 2.4196, Train Accuracy: 37.37%
#     Worker 6: Train Loss: 2.4439, Train Accuracy: 36.94%
#     Worker 7: Train Loss: 2.4334, Train Accuracy: 37.21%
# Epoch 37/150: Test Loss: 2.2759, Test Accuracy: 40.91%
#     Worker 0: Train Loss: 2.3930, Train Accuracy: 37.80%
#     Worker 1: Train Loss: 2.3670, Train Accuracy: 37.47%
#     Worker 2: Train Loss: 2.3940, Train Accuracy: 37.54%
#     Worker 3: Train Loss: 2.4111, Train Accuracy: 36.61%
#     Worker 4: Train Loss: 2.3441, Train Accuracy: 38.48%
#     Worker 5: Train Loss: 2.3783, Train Accuracy: 38.41%
#     Worker 6: Train Loss: 2.4072, Train Accuracy: 36.49%
#     Worker 7: Train Loss: 2.3947, Train Accuracy: 37.56%
# Epoch 38/150: Test Loss: 2.2590, Test Accuracy: 41.41%
#     Worker 0: Train Loss: 2.3959, Train Accuracy: 36.68%
#     Worker 1: Train Loss: 2.3787, Train Accuracy: 37.65%
#     Worker 2: Train Loss: 2.4060, Train Accuracy: 37.69%
#     Worker 3: Train Loss: 2.4260, Train Accuracy: 36.66%
#     Worker 4: Train Loss: 2.3553, Train Accuracy: 37.70%
#     Worker 5: Train Loss: 2.3767, Train Accuracy: 37.47%
#     Worker 6: Train Loss: 2.4073, Train Accuracy: 37.11%
#     Worker 7: Train Loss: 2.3918, Train Accuracy: 37.56%
# Epoch 39/150: Test Loss: 2.2489, Test Accuracy: 41.81%
#     Worker 0: Train Loss: 2.3632, Train Accuracy: 37.69%
#     Worker 1: Train Loss: 2.3029, Train Accuracy: 39.17%
#     Worker 2: Train Loss: 2.3448, Train Accuracy: 38.75%
#     Worker 3: Train Loss: 2.3942, Train Accuracy: 37.39%
#     Worker 4: Train Loss: 2.3114, Train Accuracy: 38.95%
#     Worker 5: Train Loss: 2.3612, Train Accuracy: 38.63%
#     Worker 6: Train Loss: 2.3475, Train Accuracy: 38.10%
#     Worker 7: Train Loss: 2.3756, Train Accuracy: 37.88%
# Epoch 40/150: Test Loss: 2.2222, Test Accuracy: 42.22%
#     Worker 0: Train Loss: 2.3138, Train Accuracy: 39.05%
#     Worker 1: Train Loss: 2.2832, Train Accuracy: 40.43%
#     Worker 2: Train Loss: 2.3097, Train Accuracy: 39.43%
#     Worker 3: Train Loss: 2.3262, Train Accuracy: 38.84%
#     Worker 4: Train Loss: 2.2838, Train Accuracy: 39.97%
#     Worker 5: Train Loss: 2.3144, Train Accuracy: 39.20%
#     Worker 6: Train Loss: 2.3257, Train Accuracy: 38.72%
#     Worker 7: Train Loss: 2.3207, Train Accuracy: 38.49%
# Epoch 41/150: Test Loss: 2.2147, Test Accuracy: 42.66%
#     Worker 0: Train Loss: 2.3162, Train Accuracy: 38.74%
#     Worker 1: Train Loss: 2.2982, Train Accuracy: 39.41%
#     Worker 2: Train Loss: 2.3166, Train Accuracy: 39.69%
#     Worker 3: Train Loss: 2.3559, Train Accuracy: 38.54%
#     Worker 4: Train Loss: 2.2647, Train Accuracy: 40.17%
#     Worker 5: Train Loss: 2.3109, Train Accuracy: 39.27%
#     Worker 6: Train Loss: 2.3519, Train Accuracy: 38.87%
#     Worker 7: Train Loss: 2.2829, Train Accuracy: 39.52%
# Epoch 42/150: Test Loss: 2.2215, Test Accuracy: 42.58%
#     Worker 0: Train Loss: 2.3102, Train Accuracy: 39.78%
#     Worker 1: Train Loss: 2.2550, Train Accuracy: 40.01%
#     Worker 2: Train Loss: 2.2876, Train Accuracy: 40.45%
#     Worker 3: Train Loss: 2.3085, Train Accuracy: 39.51%
#     Worker 4: Train Loss: 2.2403, Train Accuracy: 40.59%
#     Worker 5: Train Loss: 2.2690, Train Accuracy: 40.18%
#     Worker 6: Train Loss: 2.3271, Train Accuracy: 38.74%
#     Worker 7: Train Loss: 2.3072, Train Accuracy: 39.57%
# Epoch 43/150: Test Loss: 2.1856, Test Accuracy: 43.15%
#     Worker 0: Train Loss: 2.2656, Train Accuracy: 39.79%
#     Worker 1: Train Loss: 2.2164, Train Accuracy: 40.92%
#     Worker 2: Train Loss: 2.2230, Train Accuracy: 41.78%
#     Worker 3: Train Loss: 2.2650, Train Accuracy: 40.50%
#     Worker 4: Train Loss: 2.2313, Train Accuracy: 41.09%
#     Worker 5: Train Loss: 2.2303, Train Accuracy: 41.51%
#     Worker 6: Train Loss: 2.2669, Train Accuracy: 40.57%
#     Worker 7: Train Loss: 2.2344, Train Accuracy: 40.71%
# Epoch 44/150: Test Loss: 2.1785, Test Accuracy: 43.46%
#     Worker 0: Train Loss: 2.2563, Train Accuracy: 40.49%
#     Worker 1: Train Loss: 2.2585, Train Accuracy: 40.06%
#     Worker 2: Train Loss: 2.2524, Train Accuracy: 40.65%
#     Worker 3: Train Loss: 2.2670, Train Accuracy: 40.24%
#     Worker 4: Train Loss: 2.2387, Train Accuracy: 39.94%
#     Worker 5: Train Loss: 2.2020, Train Accuracy: 41.64%
#     Worker 6: Train Loss: 2.2819, Train Accuracy: 40.51%
#     Worker 7: Train Loss: 2.2693, Train Accuracy: 39.71%
# Epoch 45/150: Test Loss: 2.1583, Test Accuracy: 43.53%
#     Worker 0: Train Loss: 2.2121, Train Accuracy: 41.16%
#     Worker 1: Train Loss: 2.2066, Train Accuracy: 41.37%
#     Worker 2: Train Loss: 2.2422, Train Accuracy: 40.91%
#     Worker 3: Train Loss: 2.2622, Train Accuracy: 40.23%
#     Worker 4: Train Loss: 2.1954, Train Accuracy: 42.57%
#     Worker 5: Train Loss: 2.2608, Train Accuracy: 40.28%
#     Worker 6: Train Loss: 2.2629, Train Accuracy: 40.77%
#     Worker 7: Train Loss: 2.2715, Train Accuracy: 40.50%
# Epoch 46/150: Test Loss: 2.1465, Test Accuracy: 43.87%
#     Worker 0: Train Loss: 2.2120, Train Accuracy: 41.25%
#     Worker 1: Train Loss: 2.1969, Train Accuracy: 42.13%
#     Worker 2: Train Loss: 2.2079, Train Accuracy: 41.67%
#     Worker 3: Train Loss: 2.2054, Train Accuracy: 42.02%
#     Worker 4: Train Loss: 2.1781, Train Accuracy: 42.02%
#     Worker 5: Train Loss: 2.1667, Train Accuracy: 43.21%
#     Worker 6: Train Loss: 2.2159, Train Accuracy: 41.10%
#     Worker 7: Train Loss: 2.2167, Train Accuracy: 41.40%
# Epoch 47/150: Test Loss: 2.1339, Test Accuracy: 44.44%
#     Worker 0: Train Loss: 2.1908, Train Accuracy: 41.47%
#     Worker 1: Train Loss: 2.1744, Train Accuracy: 42.19%
#     Worker 2: Train Loss: 2.1937, Train Accuracy: 42.18%
#     Worker 3: Train Loss: 2.1680, Train Accuracy: 42.31%
#     Worker 4: Train Loss: 2.1694, Train Accuracy: 42.20%
#     Worker 5: Train Loss: 2.1643, Train Accuracy: 43.05%
#     Worker 6: Train Loss: 2.2158, Train Accuracy: 40.93%
#     Worker 7: Train Loss: 2.1801, Train Accuracy: 42.46%
# Epoch 48/150: Test Loss: 2.1399, Test Accuracy: 44.16%
#     Worker 0: Train Loss: 2.1876, Train Accuracy: 41.88%
#     Worker 1: Train Loss: 2.1823, Train Accuracy: 41.47%
#     Worker 2: Train Loss: 2.2110, Train Accuracy: 41.52%
#     Worker 3: Train Loss: 2.1986, Train Accuracy: 41.18%
#     Worker 4: Train Loss: 2.1396, Train Accuracy: 42.68%
#     Worker 5: Train Loss: 2.1773, Train Accuracy: 43.00%
#     Worker 6: Train Loss: 2.2224, Train Accuracy: 40.60%
#     Worker 7: Train Loss: 2.1953, Train Accuracy: 42.00%
# Epoch 49/150: Test Loss: 2.1265, Test Accuracy: 44.65%
#     Worker 0: Train Loss: 2.1522, Train Accuracy: 42.50%
#     Worker 1: Train Loss: 2.1282, Train Accuracy: 43.24%
#     Worker 2: Train Loss: 2.1574, Train Accuracy: 43.52%
#     Worker 3: Train Loss: 2.1635, Train Accuracy: 42.66%
#     Worker 4: Train Loss: 2.1378, Train Accuracy: 43.41%
#     Worker 5: Train Loss: 2.1338, Train Accuracy: 44.08%
#     Worker 6: Train Loss: 2.1597, Train Accuracy: 42.00%
#     Worker 7: Train Loss: 2.1393, Train Accuracy: 42.80%
# Epoch 50/150: Test Loss: 2.0965, Test Accuracy: 45.03%
#     Worker 0: Train Loss: 2.1322, Train Accuracy: 43.50%
#     Worker 1: Train Loss: 2.0788, Train Accuracy: 44.14%
#     Worker 2: Train Loss: 2.1065, Train Accuracy: 44.15%
#     Worker 3: Train Loss: 2.1256, Train Accuracy: 43.12%
#     Worker 4: Train Loss: 2.0836, Train Accuracy: 43.50%
#     Worker 5: Train Loss: 2.1254, Train Accuracy: 43.79%
#     Worker 6: Train Loss: 2.1282, Train Accuracy: 43.50%
#     Worker 7: Train Loss: 2.1026, Train Accuracy: 43.41%
# Epoch 51/150: Test Loss: 2.1040, Test Accuracy: 44.91%
#     Worker 0: Train Loss: 2.1438, Train Accuracy: 42.51%
#     Worker 1: Train Loss: 2.1098, Train Accuracy: 43.60%
#     Worker 2: Train Loss: 2.1179, Train Accuracy: 43.93%
#     Worker 3: Train Loss: 2.1451, Train Accuracy: 42.41%
#     Worker 4: Train Loss: 2.1079, Train Accuracy: 43.54%
#     Worker 5: Train Loss: 2.1055, Train Accuracy: 43.48%
#     Worker 6: Train Loss: 2.1621, Train Accuracy: 43.04%
#     Worker 7: Train Loss: 2.1212, Train Accuracy: 42.51%
# Epoch 52/150: Test Loss: 2.0805, Test Accuracy: 45.84%
#     Worker 0: Train Loss: 2.1201, Train Accuracy: 43.40%
#     Worker 1: Train Loss: 2.0899, Train Accuracy: 43.98%
#     Worker 2: Train Loss: 2.0992, Train Accuracy: 43.88%
#     Worker 3: Train Loss: 2.1212, Train Accuracy: 43.53%
#     Worker 4: Train Loss: 2.0978, Train Accuracy: 44.17%
#     Worker 5: Train Loss: 2.0631, Train Accuracy: 44.76%
#     Worker 6: Train Loss: 2.1208, Train Accuracy: 43.33%
#     Worker 7: Train Loss: 2.1060, Train Accuracy: 43.95%
# Epoch 53/150: Test Loss: 2.0723, Test Accuracy: 45.51%
#     Worker 0: Train Loss: 2.0749, Train Accuracy: 44.08%
#     Worker 1: Train Loss: 2.0453, Train Accuracy: 45.97%
#     Worker 2: Train Loss: 2.0654, Train Accuracy: 44.86%
#     Worker 3: Train Loss: 2.0973, Train Accuracy: 43.79%
#     Worker 4: Train Loss: 2.0317, Train Accuracy: 45.34%
#     Worker 5: Train Loss: 2.0482, Train Accuracy: 45.51%
#     Worker 6: Train Loss: 2.0964, Train Accuracy: 43.88%
#     Worker 7: Train Loss: 2.0620, Train Accuracy: 44.92%
# Epoch 54/150: Test Loss: 2.0808, Test Accuracy: 45.72%
#     Worker 0: Train Loss: 2.0689, Train Accuracy: 44.17%
#     Worker 1: Train Loss: 2.0493, Train Accuracy: 45.41%
#     Worker 2: Train Loss: 2.0438, Train Accuracy: 45.62%
#     Worker 3: Train Loss: 2.0972, Train Accuracy: 43.26%
#     Worker 4: Train Loss: 2.0345, Train Accuracy: 45.69%
#     Worker 5: Train Loss: 2.0567, Train Accuracy: 45.59%
#     Worker 6: Train Loss: 2.1073, Train Accuracy: 43.45%
#     Worker 7: Train Loss: 2.0908, Train Accuracy: 43.97%
# Epoch 55/150: Test Loss: 2.0707, Test Accuracy: 46.27%
#     Worker 0: Train Loss: 2.0604, Train Accuracy: 44.50%
#     Worker 1: Train Loss: 2.0313, Train Accuracy: 45.03%
#     Worker 2: Train Loss: 2.0535, Train Accuracy: 44.61%
#     Worker 3: Train Loss: 2.0912, Train Accuracy: 43.89%
#     Worker 4: Train Loss: 2.0279, Train Accuracy: 45.73%
#     Worker 5: Train Loss: 2.0457, Train Accuracy: 45.35%
#     Worker 6: Train Loss: 2.0755, Train Accuracy: 44.20%
#     Worker 7: Train Loss: 2.0620, Train Accuracy: 44.38%
# Epoch 56/150: Test Loss: 2.0542, Test Accuracy: 46.32%
#     Worker 0: Train Loss: 2.0321, Train Accuracy: 45.09%
#     Worker 1: Train Loss: 1.9836, Train Accuracy: 46.38%
#     Worker 2: Train Loss: 2.0234, Train Accuracy: 45.96%
#     Worker 3: Train Loss: 2.0186, Train Accuracy: 45.79%
#     Worker 4: Train Loss: 2.0121, Train Accuracy: 46.08%
#     Worker 5: Train Loss: 1.9689, Train Accuracy: 47.28%
#     Worker 6: Train Loss: 2.0489, Train Accuracy: 45.26%
#     Worker 7: Train Loss: 2.0275, Train Accuracy: 45.25%
# Epoch 57/150: Test Loss: 2.0581, Test Accuracy: 46.70%
#     Worker 0: Train Loss: 2.0297, Train Accuracy: 44.98%
#     Worker 1: Train Loss: 1.9950, Train Accuracy: 46.36%
#     Worker 2: Train Loss: 1.9878, Train Accuracy: 46.65%
#     Worker 3: Train Loss: 2.0366, Train Accuracy: 45.58%
#     Worker 4: Train Loss: 1.9920, Train Accuracy: 46.33%
#     Worker 5: Train Loss: 1.9716, Train Accuracy: 47.25%
#     Worker 6: Train Loss: 2.0473, Train Accuracy: 44.69%
#     Worker 7: Train Loss: 2.0132, Train Accuracy: 46.07%
# Epoch 58/150: Test Loss: 2.0504, Test Accuracy: 46.26%
#     Worker 0: Train Loss: 2.0208, Train Accuracy: 45.46%
#     Worker 1: Train Loss: 1.9733, Train Accuracy: 46.12%
#     Worker 2: Train Loss: 2.0136, Train Accuracy: 45.63%
#     Worker 3: Train Loss: 2.0226, Train Accuracy: 45.10%
#     Worker 4: Train Loss: 1.9606, Train Accuracy: 46.88%
#     Worker 5: Train Loss: 2.0006, Train Accuracy: 46.44%
#     Worker 6: Train Loss: 2.0218, Train Accuracy: 45.84%
#     Worker 7: Train Loss: 1.9985, Train Accuracy: 46.00%
# Epoch 59/150: Test Loss: 2.0265, Test Accuracy: 46.93%
#     Worker 0: Train Loss: 1.9887, Train Accuracy: 46.60%
#     Worker 1: Train Loss: 1.9544, Train Accuracy: 47.07%
#     Worker 2: Train Loss: 1.9503, Train Accuracy: 47.41%
#     Worker 3: Train Loss: 1.9924, Train Accuracy: 46.50%
#     Worker 4: Train Loss: 1.9375, Train Accuracy: 47.69%
#     Worker 5: Train Loss: 1.9246, Train Accuracy: 48.04%
#     Worker 6: Train Loss: 1.9840, Train Accuracy: 46.18%
#     Worker 7: Train Loss: 1.9676, Train Accuracy: 46.53%
# Epoch 60/150: Test Loss: 2.0281, Test Accuracy: 46.49%
#     Worker 0: Train Loss: 1.9389, Train Accuracy: 47.12%
#     Worker 1: Train Loss: 1.9479, Train Accuracy: 47.29%
#     Worker 2: Train Loss: 1.9659, Train Accuracy: 46.67%
#     Worker 3: Train Loss: 1.9599, Train Accuracy: 47.41%
#     Worker 4: Train Loss: 1.9381, Train Accuracy: 46.87%
#     Worker 5: Train Loss: 1.9598, Train Accuracy: 47.11%
#     Worker 6: Train Loss: 1.9821, Train Accuracy: 46.85%
#     Worker 7: Train Loss: 1.9604, Train Accuracy: 46.88%
# Epoch 61/150: Test Loss: 2.0218, Test Accuracy: 46.88%
#     Worker 0: Train Loss: 1.9998, Train Accuracy: 45.85%
#     Worker 1: Train Loss: 1.9343, Train Accuracy: 47.29%
#     Worker 2: Train Loss: 1.9476, Train Accuracy: 47.54%
#     Worker 3: Train Loss: 1.9862, Train Accuracy: 46.00%
#     Worker 4: Train Loss: 1.9298, Train Accuracy: 47.94%
#     Worker 5: Train Loss: 1.9444, Train Accuracy: 47.81%
#     Worker 6: Train Loss: 1.9765, Train Accuracy: 45.90%
#     Worker 7: Train Loss: 1.9748, Train Accuracy: 46.76%
# Epoch 62/150: Test Loss: 2.0124, Test Accuracy: 47.12%
#     Worker 0: Train Loss: 1.9523, Train Accuracy: 46.92%
#     Worker 1: Train Loss: 1.9012, Train Accuracy: 48.13%
#     Worker 2: Train Loss: 1.9230, Train Accuracy: 47.82%
#     Worker 3: Train Loss: 1.9288, Train Accuracy: 47.37%
#     Worker 4: Train Loss: 1.9033, Train Accuracy: 49.33%
#     Worker 5: Train Loss: 1.9221, Train Accuracy: 48.12%
#     Worker 6: Train Loss: 1.9569, Train Accuracy: 47.05%
#     Worker 7: Train Loss: 1.9359, Train Accuracy: 47.05%
# Epoch 63/150: Test Loss: 2.0179, Test Accuracy: 47.35%
#     Worker 0: Train Loss: 1.9234, Train Accuracy: 48.00%
#     Worker 1: Train Loss: 1.8739, Train Accuracy: 48.99%
#     Worker 2: Train Loss: 1.8911, Train Accuracy: 48.69%
#     Worker 3: Train Loss: 1.9340, Train Accuracy: 47.15%
#     Worker 4: Train Loss: 1.8634, Train Accuracy: 49.39%
#     Worker 5: Train Loss: 1.9120, Train Accuracy: 47.91%
#     Worker 6: Train Loss: 1.9123, Train Accuracy: 48.28%
#     Worker 7: Train Loss: 1.8952, Train Accuracy: 48.44%
# Epoch 64/150: Test Loss: 2.0149, Test Accuracy: 46.87%
#     Worker 0: Train Loss: 1.9314, Train Accuracy: 47.07%
#     Worker 1: Train Loss: 1.8827, Train Accuracy: 48.91%
#     Worker 2: Train Loss: 1.8978, Train Accuracy: 48.25%
#     Worker 3: Train Loss: 1.9488, Train Accuracy: 47.71%
#     Worker 4: Train Loss: 1.9004, Train Accuracy: 48.54%
#     Worker 5: Train Loss: 1.9209, Train Accuracy: 48.43%
#     Worker 6: Train Loss: 1.9396, Train Accuracy: 47.61%
#     Worker 7: Train Loss: 1.9254, Train Accuracy: 47.29%
# Epoch 65/150: Test Loss: 1.9947, Test Accuracy: 47.20%
#     Worker 0: Train Loss: 1.9303, Train Accuracy: 46.92%
#     Worker 1: Train Loss: 1.8805, Train Accuracy: 48.25%
#     Worker 2: Train Loss: 1.8822, Train Accuracy: 48.85%
#     Worker 3: Train Loss: 1.9248, Train Accuracy: 48.23%
#     Worker 4: Train Loss: 1.8679, Train Accuracy: 48.37%
#     Worker 5: Train Loss: 1.8645, Train Accuracy: 49.36%
#     Worker 6: Train Loss: 1.9032, Train Accuracy: 48.65%
#     Worker 7: Train Loss: 1.8859, Train Accuracy: 48.64%
# Epoch 66/150: Test Loss: 2.0067, Test Accuracy: 47.57%
#     Worker 0: Train Loss: 1.8669, Train Accuracy: 48.97%
#     Worker 1: Train Loss: 1.8396, Train Accuracy: 49.74%
#     Worker 2: Train Loss: 1.8199, Train Accuracy: 49.95%
#     Worker 3: Train Loss: 1.8571, Train Accuracy: 49.13%
#     Worker 4: Train Loss: 1.8260, Train Accuracy: 49.90%
#     Worker 5: Train Loss: 1.8608, Train Accuracy: 49.21%
#     Worker 6: Train Loss: 1.8760, Train Accuracy: 48.88%
#     Worker 7: Train Loss: 1.8733, Train Accuracy: 48.92%
# Epoch 67/150: Test Loss: 1.9864, Test Accuracy: 47.74%
#     Worker 0: Train Loss: 1.8593, Train Accuracy: 49.61%
#     Worker 1: Train Loss: 1.8463, Train Accuracy: 49.41%
#     Worker 2: Train Loss: 1.8538, Train Accuracy: 49.09%
#     Worker 3: Train Loss: 1.8854, Train Accuracy: 48.62%
#     Worker 4: Train Loss: 1.8454, Train Accuracy: 50.09%
#     Worker 5: Train Loss: 1.8354, Train Accuracy: 50.37%
#     Worker 6: Train Loss: 1.8725, Train Accuracy: 49.23%
#     Worker 7: Train Loss: 1.8434, Train Accuracy: 49.40%
# Epoch 68/150: Test Loss: 1.9805, Test Accuracy: 48.08%
#     Worker 0: Train Loss: 1.8763, Train Accuracy: 48.63%
#     Worker 1: Train Loss: 1.8483, Train Accuracy: 49.93%
#     Worker 2: Train Loss: 1.8327, Train Accuracy: 49.72%
#     Worker 3: Train Loss: 1.8627, Train Accuracy: 49.44%
#     Worker 4: Train Loss: 1.8618, Train Accuracy: 49.01%
#     Worker 5: Train Loss: 1.8681, Train Accuracy: 49.72%
#     Worker 6: Train Loss: 1.8868, Train Accuracy: 48.92%
#     Worker 7: Train Loss: 1.8369, Train Accuracy: 49.78%
# Epoch 69/150: Test Loss: 1.9777, Test Accuracy: 48.23%
#     Worker 0: Train Loss: 1.8324, Train Accuracy: 50.05%
#     Worker 1: Train Loss: 1.7778, Train Accuracy: 50.88%
#     Worker 2: Train Loss: 1.7930, Train Accuracy: 51.19%
#     Worker 3: Train Loss: 1.8448, Train Accuracy: 49.75%
#     Worker 4: Train Loss: 1.7919, Train Accuracy: 50.76%
#     Worker 5: Train Loss: 1.8240, Train Accuracy: 50.76%
#     Worker 6: Train Loss: 1.8363, Train Accuracy: 49.86%
#     Worker 7: Train Loss: 1.8267, Train Accuracy: 49.59%
# Epoch 70/150: Test Loss: 1.9801, Test Accuracy: 47.85%
#     Worker 0: Train Loss: 1.8126, Train Accuracy: 50.48%
#     Worker 1: Train Loss: 1.8096, Train Accuracy: 50.20%
#     Worker 2: Train Loss: 1.7753, Train Accuracy: 51.68%
#     Worker 3: Train Loss: 1.8329, Train Accuracy: 49.66%
#     Worker 4: Train Loss: 1.7786, Train Accuracy: 50.98%
#     Worker 5: Train Loss: 1.8071, Train Accuracy: 51.09%
#     Worker 6: Train Loss: 1.8479, Train Accuracy: 49.24%
#     Worker 7: Train Loss: 1.8072, Train Accuracy: 50.70%
# Epoch 71/150: Test Loss: 1.9759, Test Accuracy: 48.20%
#     Worker 0: Train Loss: 1.8186, Train Accuracy: 49.76%
#     Worker 1: Train Loss: 1.7711, Train Accuracy: 50.72%
#     Worker 2: Train Loss: 1.8164, Train Accuracy: 50.12%
#     Worker 3: Train Loss: 1.8327, Train Accuracy: 49.61%
#     Worker 4: Train Loss: 1.7674, Train Accuracy: 50.75%
#     Worker 5: Train Loss: 1.7956, Train Accuracy: 51.26%
#     Worker 6: Train Loss: 1.8706, Train Accuracy: 48.82%
#     Worker 7: Train Loss: 1.7986, Train Accuracy: 50.53%
# Epoch 72/150: Test Loss: 1.9603, Test Accuracy: 48.76%
#     Worker 0: Train Loss: 1.7644, Train Accuracy: 50.96%
#     Worker 1: Train Loss: 1.7601, Train Accuracy: 51.99%
#     Worker 2: Train Loss: 1.7540, Train Accuracy: 52.36%
#     Worker 3: Train Loss: 1.7906, Train Accuracy: 50.95%
#     Worker 4: Train Loss: 1.7543, Train Accuracy: 52.27%
#     Worker 5: Train Loss: 1.7815, Train Accuracy: 51.69%
#     Worker 6: Train Loss: 1.7934, Train Accuracy: 51.55%
#     Worker 7: Train Loss: 1.7811, Train Accuracy: 51.13%
# Epoch 73/150: Test Loss: 1.9591, Test Accuracy: 48.50%
#     Worker 0: Train Loss: 1.7682, Train Accuracy: 50.80%
#     Worker 1: Train Loss: 1.7358, Train Accuracy: 52.31%
#     Worker 2: Train Loss: 1.7568, Train Accuracy: 51.41%
#     Worker 3: Train Loss: 1.7844, Train Accuracy: 50.83%
#     Worker 4: Train Loss: 1.7517, Train Accuracy: 51.46%
#     Worker 5: Train Loss: 1.7663, Train Accuracy: 51.86%
#     Worker 6: Train Loss: 1.7774, Train Accuracy: 51.19%
#     Worker 7: Train Loss: 1.7652, Train Accuracy: 51.27%
# Epoch 74/150: Test Loss: 1.9484, Test Accuracy: 48.89%
#     Worker 0: Train Loss: 1.7866, Train Accuracy: 50.77%
#     Worker 1: Train Loss: 1.7877, Train Accuracy: 51.11%
#     Worker 2: Train Loss: 1.7421, Train Accuracy: 51.95%
#     Worker 3: Train Loss: 1.8099, Train Accuracy: 50.21%
#     Worker 4: Train Loss: 1.7663, Train Accuracy: 51.33%
#     Worker 5: Train Loss: 1.7476, Train Accuracy: 52.20%
#     Worker 6: Train Loss: 1.8158, Train Accuracy: 50.93%
#     Worker 7: Train Loss: 1.7774, Train Accuracy: 51.04%
# Epoch 75/150: Test Loss: 1.9505, Test Accuracy: 48.76%
#     Worker 0: Train Loss: 1.7560, Train Accuracy: 51.48%
#     Worker 1: Train Loss: 1.7292, Train Accuracy: 52.53%
#     Worker 2: Train Loss: 1.7199, Train Accuracy: 52.51%
#     Worker 3: Train Loss: 1.7386, Train Accuracy: 52.46%
#     Worker 4: Train Loss: 1.7194, Train Accuracy: 52.69%
#     Worker 5: Train Loss: 1.7510, Train Accuracy: 52.08%
#     Worker 6: Train Loss: 1.7581, Train Accuracy: 51.92%
#     Worker 7: Train Loss: 1.7413, Train Accuracy: 51.68%
# Epoch 76/150: Test Loss: 1.9522, Test Accuracy: 48.97%
#     Worker 0: Train Loss: 1.7350, Train Accuracy: 52.07%
#     Worker 1: Train Loss: 1.7128, Train Accuracy: 52.66%
#     Worker 2: Train Loss: 1.7000, Train Accuracy: 53.39%
#     Worker 3: Train Loss: 1.7215, Train Accuracy: 52.20%
#     Worker 4: Train Loss: 1.7031, Train Accuracy: 52.86%
#     Worker 5: Train Loss: 1.7101, Train Accuracy: 53.47%
#     Worker 6: Train Loss: 1.7275, Train Accuracy: 52.31%
#     Worker 7: Train Loss: 1.7306, Train Accuracy: 52.44%
# Epoch 77/150: Test Loss: 1.9562, Test Accuracy: 48.70%
#     Worker 0: Train Loss: 1.7488, Train Accuracy: 51.71%
#     Worker 1: Train Loss: 1.7190, Train Accuracy: 52.64%
#     Worker 2: Train Loss: 1.7034, Train Accuracy: 53.37%
#     Worker 3: Train Loss: 1.7391, Train Accuracy: 51.98%
#     Worker 4: Train Loss: 1.6782, Train Accuracy: 53.60%
#     Worker 5: Train Loss: 1.7462, Train Accuracy: 51.85%
#     Worker 6: Train Loss: 1.7636, Train Accuracy: 51.54%
#     Worker 7: Train Loss: 1.7069, Train Accuracy: 52.85%
# Epoch 78/150: Test Loss: 1.9503, Test Accuracy: 49.09%
#     Worker 0: Train Loss: 1.7046, Train Accuracy: 52.55%
#     Worker 1: Train Loss: 1.6649, Train Accuracy: 53.37%
#     Worker 2: Train Loss: 1.7147, Train Accuracy: 53.02%
#     Worker 3: Train Loss: 1.7443, Train Accuracy: 52.22%
#     Worker 4: Train Loss: 1.7065, Train Accuracy: 53.02%
#     Worker 5: Train Loss: 1.6803, Train Accuracy: 54.58%
#     Worker 6: Train Loss: 1.7443, Train Accuracy: 52.35%
#     Worker 7: Train Loss: 1.7216, Train Accuracy: 52.51%
# Epoch 79/150: Test Loss: 1.9482, Test Accuracy: 49.22%
#     Worker 0: Train Loss: 1.6964, Train Accuracy: 52.49%
#     Worker 1: Train Loss: 1.6710, Train Accuracy: 54.15%
#     Worker 2: Train Loss: 1.6895, Train Accuracy: 53.84%
#     Worker 3: Train Loss: 1.6907, Train Accuracy: 53.29%
#     Worker 4: Train Loss: 1.6645, Train Accuracy: 54.20%
#     Worker 5: Train Loss: 1.6812, Train Accuracy: 53.41%
#     Worker 6: Train Loss: 1.7025, Train Accuracy: 53.66%
#     Worker 7: Train Loss: 1.6857, Train Accuracy: 53.71%
# Epoch 80/150: Test Loss: 1.9349, Test Accuracy: 49.69%
#     Worker 0: Train Loss: 1.6856, Train Accuracy: 53.62%
#     Worker 1: Train Loss: 1.6790, Train Accuracy: 53.50%
#     Worker 2: Train Loss: 1.6778, Train Accuracy: 53.57%
#     Worker 3: Train Loss: 1.7173, Train Accuracy: 52.68%
#     Worker 4: Train Loss: 1.6610, Train Accuracy: 54.21%
#     Worker 5: Train Loss: 1.6649, Train Accuracy: 54.64%
#     Worker 6: Train Loss: 1.7277, Train Accuracy: 52.41%
#     Worker 7: Train Loss: 1.6764, Train Accuracy: 53.57%
# Epoch 81/150: Test Loss: 1.9342, Test Accuracy: 49.36%
#     Worker 0: Train Loss: 1.6839, Train Accuracy: 53.59%
#     Worker 1: Train Loss: 1.6467, Train Accuracy: 54.19%
#     Worker 2: Train Loss: 1.6610, Train Accuracy: 53.89%
#     Worker 3: Train Loss: 1.6792, Train Accuracy: 53.16%
#     Worker 4: Train Loss: 1.6793, Train Accuracy: 53.11%
#     Worker 5: Train Loss: 1.6586, Train Accuracy: 54.79%
#     Worker 6: Train Loss: 1.6990, Train Accuracy: 52.93%
#     Worker 7: Train Loss: 1.6689, Train Accuracy: 53.94%
# Epoch 82/150: Test Loss: 1.9389, Test Accuracy: 49.45%
#     Worker 0: Train Loss: 1.6482, Train Accuracy: 54.54%
#     Worker 1: Train Loss: 1.6388, Train Accuracy: 54.57%
#     Worker 2: Train Loss: 1.6202, Train Accuracy: 55.04%
#     Worker 3: Train Loss: 1.6797, Train Accuracy: 53.25%
#     Worker 4: Train Loss: 1.6135, Train Accuracy: 55.06%
#     Worker 5: Train Loss: 1.6202, Train Accuracy: 55.50%
#     Worker 6: Train Loss: 1.6761, Train Accuracy: 53.41%
#     Worker 7: Train Loss: 1.6250, Train Accuracy: 54.42%
# Epoch 83/150: Test Loss: 1.9333, Test Accuracy: 49.48%
#     Worker 0: Train Loss: 1.6374, Train Accuracy: 54.59%
#     Worker 1: Train Loss: 1.6306, Train Accuracy: 54.57%
#     Worker 2: Train Loss: 1.6489, Train Accuracy: 54.35%
#     Worker 3: Train Loss: 1.6668, Train Accuracy: 53.95%
#     Worker 4: Train Loss: 1.6075, Train Accuracy: 54.70%
#     Worker 5: Train Loss: 1.6408, Train Accuracy: 54.42%
#     Worker 6: Train Loss: 1.6626, Train Accuracy: 54.64%
#     Worker 7: Train Loss: 1.6456, Train Accuracy: 54.52%
# Epoch 84/150: Test Loss: 1.9250, Test Accuracy: 49.10%
#     Worker 0: Train Loss: 1.6497, Train Accuracy: 54.17%
#     Worker 1: Train Loss: 1.6131, Train Accuracy: 55.61%
#     Worker 2: Train Loss: 1.6366, Train Accuracy: 54.92%
#     Worker 3: Train Loss: 1.6631, Train Accuracy: 53.48%
#     Worker 4: Train Loss: 1.6293, Train Accuracy: 54.71%
#     Worker 5: Train Loss: 1.6303, Train Accuracy: 55.13%
#     Worker 6: Train Loss: 1.6536, Train Accuracy: 54.53%
#     Worker 7: Train Loss: 1.6242, Train Accuracy: 54.77%
# Epoch 85/150: Test Loss: 1.9243, Test Accuracy: 49.72%
#     Worker 0: Train Loss: 1.6410, Train Accuracy: 53.87%
#     Worker 1: Train Loss: 1.5988, Train Accuracy: 55.07%
#     Worker 2: Train Loss: 1.5866, Train Accuracy: 56.08%
#     Worker 3: Train Loss: 1.6454, Train Accuracy: 54.22%
#     Worker 4: Train Loss: 1.6104, Train Accuracy: 55.25%
#     Worker 5: Train Loss: 1.6015, Train Accuracy: 55.73%
#     Worker 6: Train Loss: 1.6362, Train Accuracy: 54.63%
#     Worker 7: Train Loss: 1.6202, Train Accuracy: 54.23%
# Epoch 86/150: Test Loss: 1.9297, Test Accuracy: 49.86%
#     Worker 0: Train Loss: 1.5974, Train Accuracy: 54.88%
#     Worker 1: Train Loss: 1.5725, Train Accuracy: 56.50%
#     Worker 2: Train Loss: 1.6066, Train Accuracy: 55.37%
#     Worker 3: Train Loss: 1.6437, Train Accuracy: 54.65%
#     Worker 4: Train Loss: 1.5579, Train Accuracy: 56.81%
#     Worker 5: Train Loss: 1.5811, Train Accuracy: 57.06%
#     Worker 6: Train Loss: 1.6355, Train Accuracy: 54.31%
#     Worker 7: Train Loss: 1.5959, Train Accuracy: 55.91%
# Epoch 87/150: Test Loss: 1.9307, Test Accuracy: 49.69%
#     Worker 0: Train Loss: 1.6096, Train Accuracy: 54.69%
#     Worker 1: Train Loss: 1.5849, Train Accuracy: 55.47%
#     Worker 2: Train Loss: 1.5832, Train Accuracy: 56.30%
#     Worker 3: Train Loss: 1.6278, Train Accuracy: 54.87%
#     Worker 4: Train Loss: 1.6004, Train Accuracy: 55.19%
#     Worker 5: Train Loss: 1.6091, Train Accuracy: 55.75%
#     Worker 6: Train Loss: 1.6705, Train Accuracy: 53.56%
#     Worker 7: Train Loss: 1.5782, Train Accuracy: 56.27%
# Epoch 88/150: Test Loss: 1.9311, Test Accuracy: 49.79%
#     Worker 0: Train Loss: 1.5801, Train Accuracy: 56.18%
#     Worker 1: Train Loss: 1.5839, Train Accuracy: 55.50%
#     Worker 2: Train Loss: 1.5804, Train Accuracy: 56.60%
#     Worker 3: Train Loss: 1.6083, Train Accuracy: 55.34%
#     Worker 4: Train Loss: 1.5444, Train Accuracy: 56.57%
#     Worker 5: Train Loss: 1.5677, Train Accuracy: 56.72%
#     Worker 6: Train Loss: 1.6238, Train Accuracy: 54.70%
#     Worker 7: Train Loss: 1.6072, Train Accuracy: 55.10%
# Epoch 89/150: Test Loss: 1.9348, Test Accuracy: 49.97%
#     Worker 0: Train Loss: 1.5656, Train Accuracy: 56.60%
#     Worker 1: Train Loss: 1.5320, Train Accuracy: 57.16%
#     Worker 2: Train Loss: 1.5398, Train Accuracy: 57.12%
#     Worker 3: Train Loss: 1.5736, Train Accuracy: 55.78%
#     Worker 4: Train Loss: 1.5445, Train Accuracy: 56.77%
#     Worker 5: Train Loss: 1.5384, Train Accuracy: 57.18%
#     Worker 6: Train Loss: 1.5907, Train Accuracy: 55.07%
#     Worker 7: Train Loss: 1.5553, Train Accuracy: 56.58%
# Epoch 90/150: Test Loss: 1.9229, Test Accuracy: 49.93%
#     Worker 0: Train Loss: 1.5998, Train Accuracy: 54.61%
#     Worker 1: Train Loss: 1.5742, Train Accuracy: 55.79%
#     Worker 2: Train Loss: 1.5796, Train Accuracy: 56.36%
#     Worker 3: Train Loss: 1.5658, Train Accuracy: 56.18%
#     Worker 4: Train Loss: 1.5459, Train Accuracy: 56.77%
#     Worker 5: Train Loss: 1.5533, Train Accuracy: 56.45%
#     Worker 6: Train Loss: 1.5952, Train Accuracy: 55.26%
#     Worker 7: Train Loss: 1.5550, Train Accuracy: 56.11%
# Epoch 91/150: Test Loss: 1.9143, Test Accuracy: 50.15%
#     Worker 0: Train Loss: 1.5538, Train Accuracy: 56.43%
#     Worker 1: Train Loss: 1.5212, Train Accuracy: 56.95%
#     Worker 2: Train Loss: 1.5474, Train Accuracy: 56.89%
#     Worker 3: Train Loss: 1.5728, Train Accuracy: 56.08%
#     Worker 4: Train Loss: 1.5488, Train Accuracy: 56.82%
#     Worker 5: Train Loss: 1.5420, Train Accuracy: 57.63%
#     Worker 6: Train Loss: 1.5621, Train Accuracy: 56.66%
#     Worker 7: Train Loss: 1.5489, Train Accuracy: 56.27%
# Epoch 92/150: Test Loss: 1.9262, Test Accuracy: 50.12%
#     Worker 0: Train Loss: 1.5385, Train Accuracy: 56.79%
#     Worker 1: Train Loss: 1.5012, Train Accuracy: 57.25%
#     Worker 2: Train Loss: 1.5236, Train Accuracy: 57.38%
#     Worker 3: Train Loss: 1.5685, Train Accuracy: 55.99%
#     Worker 4: Train Loss: 1.5193, Train Accuracy: 57.55%
#     Worker 5: Train Loss: 1.5005, Train Accuracy: 58.63%
#     Worker 6: Train Loss: 1.5425, Train Accuracy: 56.63%
#     Worker 7: Train Loss: 1.5217, Train Accuracy: 57.93%
# Epoch 93/150: Test Loss: 1.9223, Test Accuracy: 50.24%
#     Worker 0: Train Loss: 1.5385, Train Accuracy: 56.73%
#     Worker 1: Train Loss: 1.5388, Train Accuracy: 57.49%
#     Worker 2: Train Loss: 1.5197, Train Accuracy: 57.75%
#     Worker 3: Train Loss: 1.5602, Train Accuracy: 56.71%
#     Worker 4: Train Loss: 1.4884, Train Accuracy: 58.10%
#     Worker 5: Train Loss: 1.5105, Train Accuracy: 57.77%
#     Worker 6: Train Loss: 1.5260, Train Accuracy: 57.34%
#     Worker 7: Train Loss: 1.5197, Train Accuracy: 57.07%
# Epoch 94/150: Test Loss: 1.9217, Test Accuracy: 50.42%
#     Worker 0: Train Loss: 1.5357, Train Accuracy: 56.99%
#     Worker 1: Train Loss: 1.5168, Train Accuracy: 58.08%
#     Worker 2: Train Loss: 1.5167, Train Accuracy: 57.04%
#     Worker 3: Train Loss: 1.5462, Train Accuracy: 56.62%
# ...
#     Worker 6: Train Loss: 1.3049, Train Accuracy: 62.62%
#     Worker 7: Train Loss: 1.2952, Train Accuracy: 63.27%
# Epoch 120/150: Test Loss: 1.9235, Test Accuracy: 51.16%
#     Worker 0: Train Loss: 1.3034, Train Accuracy: 62.73%
#     Worker 1: Train Loss: 1.2962, Train Accuracy: 63.18%
#     Worker 2: Train Loss: 1.2720, Train Accuracy: 64.12%
#     Worker 3: Train Loss: 1.3419, Train Accuracy: 62.11%
#     Worker 4: Train Loss: 1.2698, Train Accuracy: 63.81%
#     Worker 5: Train Loss: 1.3073, Train Accuracy: 63.00%
#     Worker 6: Train Loss: 1.3006, Train Accuracy: 63.15%
#     Worker 7: Train Loss: 1.2975, Train Accuracy: 63.48%
# Epoch 121/150: Test Loss: 1.9248, Test Accuracy: 51.22%
#     Worker 0: Train Loss: 1.2912, Train Accuracy: 63.29%
#     Worker 1: Train Loss: 1.2855, Train Accuracy: 63.78%
#     Worker 2: Train Loss: 1.2889, Train Accuracy: 64.37%
#     Worker 3: Train Loss: 1.2938, Train Accuracy: 63.60%
#     Worker 4: Train Loss: 1.2494, Train Accuracy: 64.18%
#     Worker 5: Train Loss: 1.2768, Train Accuracy: 64.25%
#     Worker 6: Train Loss: 1.3144, Train Accuracy: 62.74%
#     Worker 7: Train Loss: 1.2795, Train Accuracy: 64.40%
# Epoch 122/150: Test Loss: 1.9287, Test Accuracy: 51.15%
#     Worker 0: Train Loss: 1.2995, Train Accuracy: 63.17%
#     Worker 1: Train Loss: 1.2648, Train Accuracy: 63.43%
#     Worker 2: Train Loss: 1.2735, Train Accuracy: 63.97%
#     Worker 3: Train Loss: 1.2873, Train Accuracy: 63.24%
#     Worker 4: Train Loss: 1.2612, Train Accuracy: 64.68%
#     Worker 5: Train Loss: 1.2549, Train Accuracy: 65.25%
#     Worker 6: Train Loss: 1.2999, Train Accuracy: 63.43%
#     Worker 7: Train Loss: 1.2921, Train Accuracy: 63.15%
# Epoch 123/150: Test Loss: 1.9277, Test Accuracy: 51.35%
#     Worker 0: Train Loss: 1.2866, Train Accuracy: 63.30%
#     Worker 1: Train Loss: 1.2591, Train Accuracy: 64.05%
#     Worker 2: Train Loss: 1.2686, Train Accuracy: 64.09%
#     Worker 3: Train Loss: 1.3046, Train Accuracy: 62.89%
#     Worker 4: Train Loss: 1.2744, Train Accuracy: 63.95%
#     Worker 5: Train Loss: 1.2854, Train Accuracy: 64.28%
#     Worker 6: Train Loss: 1.3086, Train Accuracy: 62.33%
#     Worker 7: Train Loss: 1.2955, Train Accuracy: 63.41%
# Epoch 124/150: Test Loss: 1.9268, Test Accuracy: 51.16%
#     Worker 0: Train Loss: 1.2768, Train Accuracy: 63.34%
#     Worker 1: Train Loss: 1.2641, Train Accuracy: 64.14%
#     Worker 2: Train Loss: 1.2696, Train Accuracy: 63.41%
#     Worker 3: Train Loss: 1.2943, Train Accuracy: 63.50%
#     Worker 4: Train Loss: 1.2482, Train Accuracy: 64.44%
#     Worker 5: Train Loss: 1.2802, Train Accuracy: 64.04%
#     Worker 6: Train Loss: 1.2816, Train Accuracy: 63.29%
#     Worker 7: Train Loss: 1.2486, Train Accuracy: 64.74%
# Epoch 125/150: Test Loss: 1.9260, Test Accuracy: 51.13%
#     Worker 0: Train Loss: 1.2624, Train Accuracy: 64.33%
#     Worker 1: Train Loss: 1.2494, Train Accuracy: 64.02%
#     Worker 2: Train Loss: 1.2623, Train Accuracy: 64.06%
#     Worker 3: Train Loss: 1.2831, Train Accuracy: 63.48%
#     Worker 4: Train Loss: 1.2489, Train Accuracy: 64.27%
#     Worker 5: Train Loss: 1.2533, Train Accuracy: 64.26%
#     Worker 6: Train Loss: 1.2861, Train Accuracy: 63.19%
#     Worker 7: Train Loss: 1.2662, Train Accuracy: 64.06%
# Epoch 126/150: Test Loss: 1.9312, Test Accuracy: 51.16%
#     Worker 0: Train Loss: 1.2696, Train Accuracy: 63.02%
#     Worker 1: Train Loss: 1.2586, Train Accuracy: 64.16%
#     Worker 2: Train Loss: 1.2581, Train Accuracy: 64.81%
#     Worker 3: Train Loss: 1.2563, Train Accuracy: 63.99%
#     Worker 4: Train Loss: 1.2432, Train Accuracy: 64.87%
#     Worker 5: Train Loss: 1.2430, Train Accuracy: 65.85%
#     Worker 6: Train Loss: 1.2709, Train Accuracy: 63.65%
#     Worker 7: Train Loss: 1.2650, Train Accuracy: 63.97%
# Epoch 127/150: Test Loss: 1.9300, Test Accuracy: 51.30%
#     Worker 0: Train Loss: 1.2811, Train Accuracy: 63.22%
#     Worker 1: Train Loss: 1.2511, Train Accuracy: 64.44%
#     Worker 2: Train Loss: 1.2490, Train Accuracy: 65.74%
#     Worker 3: Train Loss: 1.2789, Train Accuracy: 63.77%
#     Worker 4: Train Loss: 1.2426, Train Accuracy: 64.50%
#     Worker 5: Train Loss: 1.2578, Train Accuracy: 64.38%
#     Worker 6: Train Loss: 1.2914, Train Accuracy: 63.60%
#     Worker 7: Train Loss: 1.2548, Train Accuracy: 64.38%
# Epoch 128/150: Test Loss: 1.9311, Test Accuracy: 51.29%
#     Worker 0: Train Loss: 1.2542, Train Accuracy: 63.93%
#     Worker 1: Train Loss: 1.2449, Train Accuracy: 64.48%
#     Worker 2: Train Loss: 1.2447, Train Accuracy: 65.44%
#     Worker 3: Train Loss: 1.2727, Train Accuracy: 63.78%
#     Worker 4: Train Loss: 1.2316, Train Accuracy: 64.69%
#     Worker 5: Train Loss: 1.2725, Train Accuracy: 64.04%
#     Worker 6: Train Loss: 1.2911, Train Accuracy: 63.06%
#     Worker 7: Train Loss: 1.2509, Train Accuracy: 64.40%
# Epoch 129/150: Test Loss: 1.9333, Test Accuracy: 51.37%
#     Worker 0: Train Loss: 1.2560, Train Accuracy: 63.64%
#     Worker 1: Train Loss: 1.2613, Train Accuracy: 64.58%
#     Worker 2: Train Loss: 1.2250, Train Accuracy: 65.17%
#     Worker 3: Train Loss: 1.2528, Train Accuracy: 64.98%
#     Worker 4: Train Loss: 1.2326, Train Accuracy: 65.12%
#     Worker 5: Train Loss: 1.2423, Train Accuracy: 65.06%
#     Worker 6: Train Loss: 1.2729, Train Accuracy: 64.53%
#     Worker 7: Train Loss: 1.2410, Train Accuracy: 64.33%
# Epoch 130/150: Test Loss: 1.9291, Test Accuracy: 51.23%
#     Worker 0: Train Loss: 1.2519, Train Accuracy: 64.75%
#     Worker 1: Train Loss: 1.2367, Train Accuracy: 64.92%
#     Worker 2: Train Loss: 1.2463, Train Accuracy: 65.03%
#     Worker 3: Train Loss: 1.2608, Train Accuracy: 63.77%
#     Worker 4: Train Loss: 1.2403, Train Accuracy: 64.70%
#     Worker 5: Train Loss: 1.2267, Train Accuracy: 65.75%
#     Worker 6: Train Loss: 1.2532, Train Accuracy: 64.16%
#     Worker 7: Train Loss: 1.2598, Train Accuracy: 64.08%
# Epoch 131/150: Test Loss: 1.9325, Test Accuracy: 51.39%
#     Worker 0: Train Loss: 1.2551, Train Accuracy: 63.83%
#     Worker 1: Train Loss: 1.2489, Train Accuracy: 64.35%
#     Worker 2: Train Loss: 1.2171, Train Accuracy: 65.33%
#     Worker 3: Train Loss: 1.2626, Train Accuracy: 63.76%
#     Worker 4: Train Loss: 1.2342, Train Accuracy: 64.56%
#     Worker 5: Train Loss: 1.2373, Train Accuracy: 65.12%
#     Worker 6: Train Loss: 1.2873, Train Accuracy: 63.46%
#     Worker 7: Train Loss: 1.2523, Train Accuracy: 65.19%
# Epoch 132/150: Test Loss: 1.9342, Test Accuracy: 51.36%
#     Worker 0: Train Loss: 1.2347, Train Accuracy: 65.40%
#     Worker 1: Train Loss: 1.2278, Train Accuracy: 64.91%
#     Worker 2: Train Loss: 1.2293, Train Accuracy: 65.35%
#     Worker 3: Train Loss: 1.2632, Train Accuracy: 64.39%
#     Worker 4: Train Loss: 1.2238, Train Accuracy: 65.45%
#     Worker 5: Train Loss: 1.2514, Train Accuracy: 65.13%
#     Worker 6: Train Loss: 1.2486, Train Accuracy: 64.71%
#     Worker 7: Train Loss: 1.2242, Train Accuracy: 64.75%
# Epoch 133/150: Test Loss: 1.9348, Test Accuracy: 51.17%
#     Worker 0: Train Loss: 1.2398, Train Accuracy: 64.44%
#     Worker 1: Train Loss: 1.2406, Train Accuracy: 64.86%
#     Worker 2: Train Loss: 1.2221, Train Accuracy: 65.56%
#     Worker 3: Train Loss: 1.2667, Train Accuracy: 63.66%
#     Worker 4: Train Loss: 1.2208, Train Accuracy: 66.06%
#     Worker 5: Train Loss: 1.2076, Train Accuracy: 65.64%
#     Worker 6: Train Loss: 1.2685, Train Accuracy: 64.48%
#     Worker 7: Train Loss: 1.2367, Train Accuracy: 64.72%
# Epoch 134/150: Test Loss: 1.9336, Test Accuracy: 51.28%
#     Worker 0: Train Loss: 1.2472, Train Accuracy: 64.48%
#     Worker 1: Train Loss: 1.2179, Train Accuracy: 64.87%
#     Worker 2: Train Loss: 1.2214, Train Accuracy: 65.81%
#     Worker 3: Train Loss: 1.2438, Train Accuracy: 64.73%
#     Worker 4: Train Loss: 1.2235, Train Accuracy: 65.30%
#     Worker 5: Train Loss: 1.2383, Train Accuracy: 65.66%
#     Worker 6: Train Loss: 1.2779, Train Accuracy: 64.19%
#     Worker 7: Train Loss: 1.2547, Train Accuracy: 64.45%
# Epoch 135/150: Test Loss: 1.9354, Test Accuracy: 51.32%
#     Worker 0: Train Loss: 1.2540, Train Accuracy: 64.39%
#     Worker 1: Train Loss: 1.2452, Train Accuracy: 64.49%
#     Worker 2: Train Loss: 1.2312, Train Accuracy: 65.74%
#     Worker 3: Train Loss: 1.2531, Train Accuracy: 64.63%
#     Worker 4: Train Loss: 1.2123, Train Accuracy: 65.64%
#     Worker 5: Train Loss: 1.2128, Train Accuracy: 65.62%
#     Worker 6: Train Loss: 1.2354, Train Accuracy: 64.53%
#     Worker 7: Train Loss: 1.2369, Train Accuracy: 65.18%
# Epoch 136/150: Test Loss: 1.9358, Test Accuracy: 51.30%
#     Worker 0: Train Loss: 1.2604, Train Accuracy: 64.31%
#     Worker 1: Train Loss: 1.2282, Train Accuracy: 64.75%
#     Worker 2: Train Loss: 1.2140, Train Accuracy: 66.08%
#     Worker 3: Train Loss: 1.2429, Train Accuracy: 65.15%
#     Worker 4: Train Loss: 1.2147, Train Accuracy: 65.07%
#     Worker 5: Train Loss: 1.2181, Train Accuracy: 65.78%
#     Worker 6: Train Loss: 1.2679, Train Accuracy: 63.46%
#     Worker 7: Train Loss: 1.2215, Train Accuracy: 65.67%
# Epoch 137/150: Test Loss: 1.9354, Test Accuracy: 51.28%
#     Worker 0: Train Loss: 1.2389, Train Accuracy: 64.36%
#     Worker 1: Train Loss: 1.2355, Train Accuracy: 64.68%
#     Worker 2: Train Loss: 1.2181, Train Accuracy: 65.37%
#     Worker 3: Train Loss: 1.2345, Train Accuracy: 64.81%
#     Worker 4: Train Loss: 1.2141, Train Accuracy: 65.45%
#     Worker 5: Train Loss: 1.2213, Train Accuracy: 66.22%
#     Worker 6: Train Loss: 1.2279, Train Accuracy: 65.43%
#     Worker 7: Train Loss: 1.2276, Train Accuracy: 65.26%
# Epoch 138/150: Test Loss: 1.9356, Test Accuracy: 51.33%
#     Worker 0: Train Loss: 1.2411, Train Accuracy: 64.49%
#     Worker 1: Train Loss: 1.2163, Train Accuracy: 65.29%
#     Worker 2: Train Loss: 1.2324, Train Accuracy: 65.76%
#     Worker 3: Train Loss: 1.2535, Train Accuracy: 64.73%
#     Worker 4: Train Loss: 1.2267, Train Accuracy: 65.40%
#     Worker 5: Train Loss: 1.2098, Train Accuracy: 65.48%
#     Worker 6: Train Loss: 1.2650, Train Accuracy: 64.06%
#     Worker 7: Train Loss: 1.2323, Train Accuracy: 65.45%
# Epoch 139/150: Test Loss: 1.9337, Test Accuracy: 51.35%
#     Worker 0: Train Loss: 1.2424, Train Accuracy: 64.50%
#     Worker 1: Train Loss: 1.2315, Train Accuracy: 64.94%
#     Worker 2: Train Loss: 1.2321, Train Accuracy: 65.79%
#     Worker 3: Train Loss: 1.2255, Train Accuracy: 64.69%
#     Worker 4: Train Loss: 1.2210, Train Accuracy: 65.52%
#     Worker 5: Train Loss: 1.2373, Train Accuracy: 64.90%
#     Worker 6: Train Loss: 1.2736, Train Accuracy: 63.59%
#     Worker 7: Train Loss: 1.2401, Train Accuracy: 64.96%
# Epoch 140/150: Test Loss: 1.9348, Test Accuracy: 51.32%
#     Worker 0: Train Loss: 1.2442, Train Accuracy: 64.43%
#     Worker 1: Train Loss: 1.2175, Train Accuracy: 65.45%
#     Worker 2: Train Loss: 1.1950, Train Accuracy: 66.47%
#     Worker 3: Train Loss: 1.2520, Train Accuracy: 64.68%
#     Worker 4: Train Loss: 1.2125, Train Accuracy: 65.61%
#     Worker 5: Train Loss: 1.2010, Train Accuracy: 66.46%
#     Worker 6: Train Loss: 1.2437, Train Accuracy: 64.75%
#     Worker 7: Train Loss: 1.2378, Train Accuracy: 65.15%
# Epoch 141/150: Test Loss: 1.9343, Test Accuracy: 51.37%
#     Worker 0: Train Loss: 1.2417, Train Accuracy: 64.85%
#     Worker 1: Train Loss: 1.2335, Train Accuracy: 64.58%
#     Worker 2: Train Loss: 1.2152, Train Accuracy: 65.66%
#     Worker 3: Train Loss: 1.2327, Train Accuracy: 64.87%
#     Worker 4: Train Loss: 1.2080, Train Accuracy: 65.68%
#     Worker 5: Train Loss: 1.2261, Train Accuracy: 64.83%
#     Worker 6: Train Loss: 1.2578, Train Accuracy: 64.46%
#     Worker 7: Train Loss: 1.2158, Train Accuracy: 65.11%
# Epoch 142/150: Test Loss: 1.9344, Test Accuracy: 51.35%
#     Worker 0: Train Loss: 1.2395, Train Accuracy: 64.85%
#     Worker 1: Train Loss: 1.2113, Train Accuracy: 65.19%
#     Worker 2: Train Loss: 1.2150, Train Accuracy: 66.12%
#     Worker 3: Train Loss: 1.2356, Train Accuracy: 64.63%
#     Worker 4: Train Loss: 1.2341, Train Accuracy: 65.10%
#     Worker 5: Train Loss: 1.2012, Train Accuracy: 66.16%
#     Worker 6: Train Loss: 1.2387, Train Accuracy: 65.06%
#     Worker 7: Train Loss: 1.2379, Train Accuracy: 65.39%
# Epoch 143/150: Test Loss: 1.9347, Test Accuracy: 51.38%
#     Worker 0: Train Loss: 1.2226, Train Accuracy: 65.07%
#     Worker 1: Train Loss: 1.2226, Train Accuracy: 64.91%
#     Worker 2: Train Loss: 1.2299, Train Accuracy: 66.06%
#     Worker 3: Train Loss: 1.2265, Train Accuracy: 65.45%
#     Worker 4: Train Loss: 1.1937, Train Accuracy: 66.17%
#     Worker 5: Train Loss: 1.2177, Train Accuracy: 65.54%
#     Worker 6: Train Loss: 1.2425, Train Accuracy: 64.53%
#     Worker 7: Train Loss: 1.2439, Train Accuracy: 64.76%
# Epoch 144/150: Test Loss: 1.9353, Test Accuracy: 51.43%
#     Worker 0: Train Loss: 1.2613, Train Accuracy: 64.20%
#     Worker 1: Train Loss: 1.2043, Train Accuracy: 65.50%
#     Worker 2: Train Loss: 1.2124, Train Accuracy: 65.48%
#     Worker 3: Train Loss: 1.2504, Train Accuracy: 64.56%
#     Worker 4: Train Loss: 1.2129, Train Accuracy: 65.73%
#     Worker 5: Train Loss: 1.2206, Train Accuracy: 66.11%
#     Worker 6: Train Loss: 1.2503, Train Accuracy: 64.84%
#     Worker 7: Train Loss: 1.2243, Train Accuracy: 65.12%
# Epoch 145/150: Test Loss: 1.9350, Test Accuracy: 51.42%
#     Worker 0: Train Loss: 1.2265, Train Accuracy: 64.90%
#     Worker 1: Train Loss: 1.2313, Train Accuracy: 64.85%
#     Worker 2: Train Loss: 1.2071, Train Accuracy: 66.00%
#     Worker 3: Train Loss: 1.2397, Train Accuracy: 64.81%
#     Worker 4: Train Loss: 1.2135, Train Accuracy: 65.64%
#     Worker 5: Train Loss: 1.2148, Train Accuracy: 65.75%
#     Worker 6: Train Loss: 1.2383, Train Accuracy: 65.42%
#     Worker 7: Train Loss: 1.2379, Train Accuracy: 64.65%
# Epoch 146/150: Test Loss: 1.9351, Test Accuracy: 51.31%
#     Worker 0: Train Loss: 1.2330, Train Accuracy: 65.37%
#     Worker 1: Train Loss: 1.2263, Train Accuracy: 65.12%
#     Worker 2: Train Loss: 1.2088, Train Accuracy: 66.05%
#     Worker 3: Train Loss: 1.2525, Train Accuracy: 65.02%
#     Worker 4: Train Loss: 1.2240, Train Accuracy: 65.18%
#     Worker 5: Train Loss: 1.2160, Train Accuracy: 66.19%
#     Worker 6: Train Loss: 1.2750, Train Accuracy: 63.94%
#     Worker 7: Train Loss: 1.2334, Train Accuracy: 65.07%
# Epoch 147/150: Test Loss: 1.9353, Test Accuracy: 51.38%
#     Worker 0: Train Loss: 1.2487, Train Accuracy: 64.48%
#     Worker 1: Train Loss: 1.2069, Train Accuracy: 65.82%
#     Worker 2: Train Loss: 1.2252, Train Accuracy: 65.18%
#     Worker 3: Train Loss: 1.2242, Train Accuracy: 65.35%
#     Worker 4: Train Loss: 1.2170, Train Accuracy: 65.37%
#     Worker 5: Train Loss: 1.2070, Train Accuracy: 65.86%
#     Worker 6: Train Loss: 1.2435, Train Accuracy: 65.14%
#     Worker 7: Train Loss: 1.2292, Train Accuracy: 64.83%
# Epoch 148/150: Test Loss: 1.9354, Test Accuracy: 51.43%
#     Worker 0: Train Loss: 1.2497, Train Accuracy: 64.10%
#     Worker 1: Train Loss: 1.2213, Train Accuracy: 64.92%
#     Worker 2: Train Loss: 1.2292, Train Accuracy: 65.23%
#     Worker 3: Train Loss: 1.2407, Train Accuracy: 64.48%
#     Worker 4: Train Loss: 1.2108, Train Accuracy: 65.59%
#     Worker 5: Train Loss: 1.2296, Train Accuracy: 65.56%
#     Worker 6: Train Loss: 1.2585, Train Accuracy: 64.10%
#     Worker 7: Train Loss: 1.2374, Train Accuracy: 65.46%
# Epoch 149/150: Test Loss: 1.9353, Test Accuracy: 51.48%
#     Worker 0: Train Loss: 1.2455, Train Accuracy: 64.27%
#     Worker 1: Train Loss: 1.2115, Train Accuracy: 65.30%
#     Worker 2: Train Loss: 1.2112, Train Accuracy: 65.58%
#     Worker 3: Train Loss: 1.2382, Train Accuracy: 64.75%
#     Worker 4: Train Loss: 1.2202, Train Accuracy: 65.17%
#     Worker 5: Train Loss: 1.2213, Train Accuracy: 66.29%
#     Worker 6: Train Loss: 1.2725, Train Accuracy: 63.95%
#     Worker 7: Train Loss: 1.2126, Train Accuracy: 65.65%
# Epoch 150/150: Test Loss: 1.9353, Test Accuracy: 51.49%
#     Worker 0: Train Loss: 1.2489, Train Accuracy: 64.27%
#     Worker 1: Train Loss: 1.1984, Train Accuracy: 66.05%
#     Worker 2: Train Loss: 1.2071, Train Accuracy: 66.08%
#     Worker 3: Train Loss: 1.2420, Train Accuracy: 64.49%
#     Worker 4: Train Loss: 1.2271, Train Accuracy: 65.52%
#     Worker 5: Train Loss: 1.2222, Train Accuracy: 65.53%
#     Worker 6: Train Loss: 1.2618, Train Accuracy: 64.61%
#     Worker 7: Train Loss: 1.2372, Train Accuracy: 65.06%
