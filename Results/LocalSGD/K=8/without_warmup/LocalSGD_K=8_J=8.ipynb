# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
#warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")

    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch):
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            # Perform J local step before synchronization
            for j in range(J):
                try:
                    # Get a batch from the current worker's shard using next()
                    images, labels = next(shard_iterators[k])
                    images, labels = images.to(device), labels.to(device)  # Move to device
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

                except StopIteration:
                    # If the iterator has exhausted the data, restart the iterator
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k]) # Resume from the next batch
                    images, labels = images.to(device), labels.to(device)
                    # Perform optimization step
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        # Perform model synchronization
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            # Update each worker model with the global parameters
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
       # if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
       # else:
        #    warmup_factor = (epoch + 1) / warmup_epochs
          #  lr = warmup_factor * learning_rate
          #  for optimizer in optimizers:
           #     for param_group in optimizer.param_groups:
            #        param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 8 --j 8
# Out:
# Training with K=8, J=8
# Global iteration per epoch: 13
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:13<00:00, 12.8MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00800
# Epoch 1/150: Test Loss: 4.5726, Test Accuracy: 2.50%
#     Worker 0: Train Loss: 4.5979, Train Accuracy: 1.28%
#     Worker 1: Train Loss: 4.5973, Train Accuracy: 1.42%
#     Worker 2: Train Loss: 4.5976, Train Accuracy: 1.28%
#     Worker 3: Train Loss: 4.5967, Train Accuracy: 1.49%
#     Worker 4: Train Loss: 4.5974, Train Accuracy: 1.15%
#     Worker 5: Train Loss: 4.5950, Train Accuracy: 1.72%
#     Worker 6: Train Loss: 4.5975, Train Accuracy: 1.51%
#     Worker 7: Train Loss: 4.5964, Train Accuracy: 1.45%
# Epoch 2/150: Test Loss: 4.1879, Test Accuracy: 6.14%
#     Worker 0: Train Loss: 4.4233, Train Accuracy: 3.60%
#     Worker 1: Train Loss: 4.4351, Train Accuracy: 3.92%
#     Worker 2: Train Loss: 4.4302, Train Accuracy: 3.69%
#     Worker 3: Train Loss: 4.4312, Train Accuracy: 3.78%
#     Worker 4: Train Loss: 4.4202, Train Accuracy: 3.57%
#     Worker 5: Train Loss: 4.4138, Train Accuracy: 3.30%
#     Worker 6: Train Loss: 4.4276, Train Accuracy: 3.51%
#     Worker 7: Train Loss: 4.4291, Train Accuracy: 3.41%
# Epoch 3/150: Test Loss: 3.9939, Test Accuracy: 9.14%
#     Worker 0: Train Loss: 4.1409, Train Accuracy: 6.48%
#     Worker 1: Train Loss: 4.1365, Train Accuracy: 6.63%
#     Worker 2: Train Loss: 4.1389, Train Accuracy: 6.27%
#     Worker 3: Train Loss: 4.1683, Train Accuracy: 5.82%
#     Worker 4: Train Loss: 4.1154, Train Accuracy: 6.39%
#     Worker 5: Train Loss: 4.1120, Train Accuracy: 6.71%
#     Worker 6: Train Loss: 4.1684, Train Accuracy: 6.01%
#     Worker 7: Train Loss: 4.1554, Train Accuracy: 6.41%
# Epoch 4/150: Test Loss: 3.8559, Test Accuracy: 11.54%
#     Worker 0: Train Loss: 4.0143, Train Accuracy: 8.65%
#     Worker 1: Train Loss: 4.0085, Train Accuracy: 8.12%
#     Worker 2: Train Loss: 4.0142, Train Accuracy: 8.38%
#     Worker 3: Train Loss: 4.0142, Train Accuracy: 8.49%
#     Worker 4: Train Loss: 3.9881, Train Accuracy: 8.82%
#     Worker 5: Train Loss: 3.9700, Train Accuracy: 8.76%
#     Worker 6: Train Loss: 4.0121, Train Accuracy: 7.67%
#     Worker 7: Train Loss: 4.0205, Train Accuracy: 8.65%
# Epoch 5/150: Test Loss: 3.7335, Test Accuracy: 13.19%
#     Worker 0: Train Loss: 3.8985, Train Accuracy: 9.77%
#     Worker 1: Train Loss: 3.8956, Train Accuracy: 9.80%
#     Worker 2: Train Loss: 3.8932, Train Accuracy: 10.45%
#     Worker 3: Train Loss: 3.8969, Train Accuracy: 9.77%
#     Worker 4: Train Loss: 3.8439, Train Accuracy: 10.64%
#     Worker 5: Train Loss: 3.8396, Train Accuracy: 10.96%
#     Worker 6: Train Loss: 3.8878, Train Accuracy: 10.37%
#     Worker 7: Train Loss: 3.8967, Train Accuracy: 10.25%
# Epoch 6/150: Test Loss: 3.6087, Test Accuracy: 15.88%
#     Worker 0: Train Loss: 3.7867, Train Accuracy: 11.65%
#     Worker 1: Train Loss: 3.7777, Train Accuracy: 11.40%
#     Worker 2: Train Loss: 3.7887, Train Accuracy: 12.18%
#     Worker 3: Train Loss: 3.8041, Train Accuracy: 11.86%
#     Worker 4: Train Loss: 3.7335, Train Accuracy: 12.60%
#     Worker 5: Train Loss: 3.7381, Train Accuracy: 13.39%
#     Worker 6: Train Loss: 3.7948, Train Accuracy: 11.06%
#     Worker 7: Train Loss: 3.7692, Train Accuracy: 12.19%
# Epoch 7/150: Test Loss: 3.5181, Test Accuracy: 17.14%
#     Worker 0: Train Loss: 3.6765, Train Accuracy: 13.30%
#     Worker 1: Train Loss: 3.6667, Train Accuracy: 13.30%
#     Worker 2: Train Loss: 3.6730, Train Accuracy: 14.03%
#     Worker 3: Train Loss: 3.7095, Train Accuracy: 12.78%
#     Worker 4: Train Loss: 3.6518, Train Accuracy: 12.74%
#     Worker 5: Train Loss: 3.6319, Train Accuracy: 14.61%
#     Worker 6: Train Loss: 3.7161, Train Accuracy: 12.95%
#     Worker 7: Train Loss: 3.6893, Train Accuracy: 13.34%
# Epoch 8/150: Test Loss: 3.4657, Test Accuracy: 17.50%
#     Worker 0: Train Loss: 3.6042, Train Accuracy: 14.26%
#     Worker 1: Train Loss: 3.6150, Train Accuracy: 13.69%
#     Worker 2: Train Loss: 3.6315, Train Accuracy: 13.48%
#     Worker 3: Train Loss: 3.6437, Train Accuracy: 14.31%
#     Worker 4: Train Loss: 3.5679, Train Accuracy: 15.65%
#     Worker 5: Train Loss: 3.5591, Train Accuracy: 15.83%
#     Worker 6: Train Loss: 3.6010, Train Accuracy: 14.50%
#     Worker 7: Train Loss: 3.6166, Train Accuracy: 14.67%
# Epoch 9/150: Test Loss: 3.3867, Test Accuracy: 19.45%
#     Worker 0: Train Loss: 3.5513, Train Accuracy: 15.78%
#     Worker 1: Train Loss: 3.5312, Train Accuracy: 16.10%
#     Worker 2: Train Loss: 3.5066, Train Accuracy: 16.84%
#     Worker 3: Train Loss: 3.5703, Train Accuracy: 15.45%
#     Worker 4: Train Loss: 3.4685, Train Accuracy: 17.27%
#     Worker 5: Train Loss: 3.4732, Train Accuracy: 17.06%
#     Worker 6: Train Loss: 3.5665, Train Accuracy: 15.60%
#     Worker 7: Train Loss: 3.5318, Train Accuracy: 16.19%
# Epoch 10/150: Test Loss: 3.3076, Test Accuracy: 21.12%
#     Worker 0: Train Loss: 3.4460, Train Accuracy: 17.64%
#     Worker 1: Train Loss: 3.4314, Train Accuracy: 17.67%
#     Worker 2: Train Loss: 3.4680, Train Accuracy: 17.73%
#     Worker 3: Train Loss: 3.4673, Train Accuracy: 17.05%
#     Worker 4: Train Loss: 3.4404, Train Accuracy: 16.64%
#     Worker 5: Train Loss: 3.4228, Train Accuracy: 18.48%
#     Worker 6: Train Loss: 3.4669, Train Accuracy: 16.40%
#     Worker 7: Train Loss: 3.4443, Train Accuracy: 17.44%
# Epoch 11/150: Test Loss: 3.2199, Test Accuracy: 22.62%
#     Worker 0: Train Loss: 3.4067, Train Accuracy: 18.03%
#     Worker 1: Train Loss: 3.3801, Train Accuracy: 18.33%
#     Worker 2: Train Loss: 3.3870, Train Accuracy: 19.07%
#     Worker 3: Train Loss: 3.4036, Train Accuracy: 17.35%
#     Worker 4: Train Loss: 3.3570, Train Accuracy: 18.84%
#     Worker 5: Train Loss: 3.3371, Train Accuracy: 19.72%
#     Worker 6: Train Loss: 3.3917, Train Accuracy: 18.57%
#     Worker 7: Train Loss: 3.4058, Train Accuracy: 18.13%
# Epoch 12/150: Test Loss: 3.1935, Test Accuracy: 22.98%
#     Worker 0: Train Loss: 3.3243, Train Accuracy: 18.77%
#     Worker 1: Train Loss: 3.3284, Train Accuracy: 19.97%
#     Worker 2: Train Loss: 3.3202, Train Accuracy: 20.02%
#     Worker 3: Train Loss: 3.3684, Train Accuracy: 18.71%
#     Worker 4: Train Loss: 3.2558, Train Accuracy: 21.07%
#     Worker 5: Train Loss: 3.2954, Train Accuracy: 20.55%
#     Worker 6: Train Loss: 3.3500, Train Accuracy: 18.36%
#     Worker 7: Train Loss: 3.3283, Train Accuracy: 19.64%
# Epoch 13/150: Test Loss: 3.1113, Test Accuracy: 24.84%
#     Worker 0: Train Loss: 3.2591, Train Accuracy: 20.56%
#     Worker 1: Train Loss: 3.2233, Train Accuracy: 21.09%
#     Worker 2: Train Loss: 3.2580, Train Accuracy: 21.15%
#     Worker 3: Train Loss: 3.2929, Train Accuracy: 19.82%
#     Worker 4: Train Loss: 3.2195, Train Accuracy: 22.08%
#     Worker 5: Train Loss: 3.2160, Train Accuracy: 21.37%
#     Worker 6: Train Loss: 3.2719, Train Accuracy: 20.56%
#     Worker 7: Train Loss: 3.2462, Train Accuracy: 21.16%
# Epoch 14/150: Test Loss: 3.0479, Test Accuracy: 25.74%
#     Worker 0: Train Loss: 3.2269, Train Accuracy: 21.16%
#     Worker 1: Train Loss: 3.1994, Train Accuracy: 21.57%
#     Worker 2: Train Loss: 3.1799, Train Accuracy: 22.69%
#     Worker 3: Train Loss: 3.2116, Train Accuracy: 21.57%
#     Worker 4: Train Loss: 3.1728, Train Accuracy: 22.48%
#     Worker 5: Train Loss: 3.1379, Train Accuracy: 23.41%
#     Worker 6: Train Loss: 3.2270, Train Accuracy: 21.37%
#     Worker 7: Train Loss: 3.1898, Train Accuracy: 22.14%
# Epoch 15/150: Test Loss: 3.0192, Test Accuracy: 26.45%
#     Worker 0: Train Loss: 3.1318, Train Accuracy: 23.59%
#     Worker 1: Train Loss: 3.1707, Train Accuracy: 21.86%
#     Worker 2: Train Loss: 3.1558, Train Accuracy: 23.39%
#     Worker 3: Train Loss: 3.1819, Train Accuracy: 21.93%
#     Worker 4: Train Loss: 3.1064, Train Accuracy: 22.75%
#     Worker 5: Train Loss: 3.1153, Train Accuracy: 24.07%
#     Worker 6: Train Loss: 3.1527, Train Accuracy: 21.99%
#     Worker 7: Train Loss: 3.1505, Train Accuracy: 22.90%
# Epoch 16/150: Test Loss: 2.9399, Test Accuracy: 27.93%
#     Worker 0: Train Loss: 3.0829, Train Accuracy: 23.70%
#     Worker 1: Train Loss: 3.0729, Train Accuracy: 24.24%
#     Worker 2: Train Loss: 3.1014, Train Accuracy: 23.89%
#     Worker 3: Train Loss: 3.1083, Train Accuracy: 23.45%
#     Worker 4: Train Loss: 3.0728, Train Accuracy: 24.66%
#     Worker 5: Train Loss: 3.0495, Train Accuracy: 25.32%
#     Worker 6: Train Loss: 3.1396, Train Accuracy: 23.18%
#     Worker 7: Train Loss: 3.1019, Train Accuracy: 23.83%
# Epoch 17/150: Test Loss: 2.8941, Test Accuracy: 28.82%
#     Worker 0: Train Loss: 3.0551, Train Accuracy: 25.03%
#     Worker 1: Train Loss: 3.0264, Train Accuracy: 25.12%
#     Worker 2: Train Loss: 3.0624, Train Accuracy: 25.09%
#     Worker 3: Train Loss: 3.0826, Train Accuracy: 23.85%
#     Worker 4: Train Loss: 3.0184, Train Accuracy: 24.74%
#     Worker 5: Train Loss: 3.0004, Train Accuracy: 26.19%
#     Worker 6: Train Loss: 3.0726, Train Accuracy: 23.85%
#     Worker 7: Train Loss: 3.0462, Train Accuracy: 24.92%
# Epoch 18/150: Test Loss: 2.8662, Test Accuracy: 29.16%
#     Worker 0: Train Loss: 2.9915, Train Accuracy: 25.50%
#     Worker 1: Train Loss: 2.9760, Train Accuracy: 25.70%
#     Worker 2: Train Loss: 2.9883, Train Accuracy: 26.18%
#     Worker 3: Train Loss: 3.0386, Train Accuracy: 24.83%
#     Worker 4: Train Loss: 2.9795, Train Accuracy: 25.87%
#     Worker 5: Train Loss: 2.9583, Train Accuracy: 26.76%
#     Worker 6: Train Loss: 3.0405, Train Accuracy: 24.37%
#     Worker 7: Train Loss: 2.9962, Train Accuracy: 25.50%
# Epoch 19/150: Test Loss: 2.8013, Test Accuracy: 30.34%
#     Worker 0: Train Loss: 2.9830, Train Accuracy: 25.63%
#     Worker 1: Train Loss: 2.9376, Train Accuracy: 26.24%
#     Worker 2: Train Loss: 2.9823, Train Accuracy: 26.14%
#     Worker 3: Train Loss: 2.9840, Train Accuracy: 25.55%
#     Worker 4: Train Loss: 2.9128, Train Accuracy: 27.16%
#     Worker 5: Train Loss: 2.8926, Train Accuracy: 27.81%
#     Worker 6: Train Loss: 2.9799, Train Accuracy: 25.81%
#     Worker 7: Train Loss: 2.9502, Train Accuracy: 26.68%
# Epoch 20/150: Test Loss: 2.7526, Test Accuracy: 30.99%
#     Worker 0: Train Loss: 2.8932, Train Accuracy: 27.71%
#     Worker 1: Train Loss: 2.9033, Train Accuracy: 27.10%
#     Worker 2: Train Loss: 2.9026, Train Accuracy: 27.69%
#     Worker 3: Train Loss: 2.9432, Train Accuracy: 26.76%
#     Worker 4: Train Loss: 2.8805, Train Accuracy: 27.86%
#     Worker 5: Train Loss: 2.8568, Train Accuracy: 29.68%
#     Worker 6: Train Loss: 2.9287, Train Accuracy: 26.58%
#     Worker 7: Train Loss: 2.8952, Train Accuracy: 27.57%
# Epoch 21/150: Test Loss: 2.7178, Test Accuracy: 31.96%
#     Worker 0: Train Loss: 2.9046, Train Accuracy: 27.72%
#     Worker 1: Train Loss: 2.8328, Train Accuracy: 29.09%
#     Worker 2: Train Loss: 2.8634, Train Accuracy: 29.02%
#     Worker 3: Train Loss: 2.8891, Train Accuracy: 27.45%
#     Worker 4: Train Loss: 2.8450, Train Accuracy: 29.05%
#     Worker 5: Train Loss: 2.8170, Train Accuracy: 29.47%
#     Worker 6: Train Loss: 2.8732, Train Accuracy: 27.59%
#     Worker 7: Train Loss: 2.8654, Train Accuracy: 28.44%
# Epoch 22/150: Test Loss: 2.6725, Test Accuracy: 32.67%
#     Worker 0: Train Loss: 2.8165, Train Accuracy: 28.75%
#     Worker 1: Train Loss: 2.7743, Train Accuracy: 29.65%
#     Worker 2: Train Loss: 2.7843, Train Accuracy: 30.45%
#     Worker 3: Train Loss: 2.8607, Train Accuracy: 28.34%
#     Worker 4: Train Loss: 2.7837, Train Accuracy: 29.86%
#     Worker 5: Train Loss: 2.7585, Train Accuracy: 30.77%
#     Worker 6: Train Loss: 2.8518, Train Accuracy: 28.05%
#     Worker 7: Train Loss: 2.8216, Train Accuracy: 28.67%
# Epoch 23/150: Test Loss: 2.6351, Test Accuracy: 33.44%
#     Worker 0: Train Loss: 2.7648, Train Accuracy: 29.54%
#     Worker 1: Train Loss: 2.7631, Train Accuracy: 29.97%
#     Worker 2: Train Loss: 2.7947, Train Accuracy: 29.88%
#     Worker 3: Train Loss: 2.8315, Train Accuracy: 28.91%
#     Worker 4: Train Loss: 2.7268, Train Accuracy: 31.23%
#     Worker 5: Train Loss: 2.7452, Train Accuracy: 31.10%
#     Worker 6: Train Loss: 2.7872, Train Accuracy: 29.85%
#     Worker 7: Train Loss: 2.7306, Train Accuracy: 30.45%
# Epoch 24/150: Test Loss: 2.6151, Test Accuracy: 34.25%
#     Worker 0: Train Loss: 2.7186, Train Accuracy: 31.31%
#     Worker 1: Train Loss: 2.7206, Train Accuracy: 30.71%
#     Worker 2: Train Loss: 2.7460, Train Accuracy: 30.75%
#     Worker 3: Train Loss: 2.7665, Train Accuracy: 30.04%
#     Worker 4: Train Loss: 2.7103, Train Accuracy: 31.61%
#     Worker 5: Train Loss: 2.7039, Train Accuracy: 31.52%
#     Worker 6: Train Loss: 2.7771, Train Accuracy: 29.73%
#     Worker 7: Train Loss: 2.7150, Train Accuracy: 31.59%
# Epoch 25/150: Test Loss: 2.5607, Test Accuracy: 34.99%
#     Worker 0: Train Loss: 2.7149, Train Accuracy: 31.01%
#     Worker 1: Train Loss: 2.6742, Train Accuracy: 30.87%
#     Worker 2: Train Loss: 2.6797, Train Accuracy: 33.16%
#     Worker 3: Train Loss: 2.7046, Train Accuracy: 31.10%
#     Worker 4: Train Loss: 2.6285, Train Accuracy: 33.31%
#     Worker 5: Train Loss: 2.6830, Train Accuracy: 32.50%
#     Worker 6: Train Loss: 2.6763, Train Accuracy: 31.79%
#     Worker 7: Train Loss: 2.6853, Train Accuracy: 32.41%
# Epoch 26/150: Test Loss: 2.5353, Test Accuracy: 35.77%
#     Worker 0: Train Loss: 2.6750, Train Accuracy: 31.85%
#     Worker 1: Train Loss: 2.6648, Train Accuracy: 31.75%
#     Worker 2: Train Loss: 2.6794, Train Accuracy: 32.54%
#     Worker 3: Train Loss: 2.6966, Train Accuracy: 31.62%
#     Worker 4: Train Loss: 2.6389, Train Accuracy: 33.00%
#     Worker 5: Train Loss: 2.5863, Train Accuracy: 33.30%
#     Worker 6: Train Loss: 2.6669, Train Accuracy: 32.08%
#     Worker 7: Train Loss: 2.6402, Train Accuracy: 32.42%
# Epoch 27/150: Test Loss: 2.5011, Test Accuracy: 36.52%
#     Worker 0: Train Loss: 2.6314, Train Accuracy: 33.22%
#     Worker 1: Train Loss: 2.5842, Train Accuracy: 33.19%
#     Worker 2: Train Loss: 2.6126, Train Accuracy: 33.90%
#     Worker 3: Train Loss: 2.6294, Train Accuracy: 33.12%
#     Worker 4: Train Loss: 2.5900, Train Accuracy: 33.86%
#     Worker 5: Train Loss: 2.6233, Train Accuracy: 33.21%
#     Worker 6: Train Loss: 2.6503, Train Accuracy: 31.59%
#     Worker 7: Train Loss: 2.6671, Train Accuracy: 32.12%
# Epoch 28/150: Test Loss: 2.4768, Test Accuracy: 36.87%
#     Worker 0: Train Loss: 2.5956, Train Accuracy: 33.55%
#     Worker 1: Train Loss: 2.5938, Train Accuracy: 32.70%
#     Worker 2: Train Loss: 2.5716, Train Accuracy: 34.67%
#     Worker 3: Train Loss: 2.5902, Train Accuracy: 34.05%
#     Worker 4: Train Loss: 2.5673, Train Accuracy: 34.29%
#     Worker 5: Train Loss: 2.5700, Train Accuracy: 34.55%
#     Worker 6: Train Loss: 2.5966, Train Accuracy: 33.22%
#     Worker 7: Train Loss: 2.5951, Train Accuracy: 33.57%
# Epoch 29/150: Test Loss: 2.4375, Test Accuracy: 37.48%
#     Worker 0: Train Loss: 2.5777, Train Accuracy: 33.93%
#     Worker 1: Train Loss: 2.5450, Train Accuracy: 34.59%
#     Worker 2: Train Loss: 2.5901, Train Accuracy: 33.95%
#     Worker 3: Train Loss: 2.5827, Train Accuracy: 33.34%
#     Worker 4: Train Loss: 2.5050, Train Accuracy: 35.73%
#     Worker 5: Train Loss: 2.5185, Train Accuracy: 35.44%
#     Worker 6: Train Loss: 2.5934, Train Accuracy: 33.58%
#     Worker 7: Train Loss: 2.5698, Train Accuracy: 35.00%
# Epoch 30/150: Test Loss: 2.4163, Test Accuracy: 37.78%
#     Worker 0: Train Loss: 2.5437, Train Accuracy: 34.31%
#     Worker 1: Train Loss: 2.5049, Train Accuracy: 35.42%
#     Worker 2: Train Loss: 2.5112, Train Accuracy: 35.59%
#     Worker 3: Train Loss: 2.5647, Train Accuracy: 33.75%
#     Worker 4: Train Loss: 2.4835, Train Accuracy: 35.39%
#     Worker 5: Train Loss: 2.5033, Train Accuracy: 35.82%
#     Worker 6: Train Loss: 2.5472, Train Accuracy: 34.32%
#     Worker 7: Train Loss: 2.5479, Train Accuracy: 34.32%
# Epoch 31/150: Test Loss: 2.3992, Test Accuracy: 38.43%
#     Worker 0: Train Loss: 2.5005, Train Accuracy: 34.97%
#     Worker 1: Train Loss: 2.4908, Train Accuracy: 35.51%
#     Worker 2: Train Loss: 2.4744, Train Accuracy: 36.99%
#     Worker 3: Train Loss: 2.4836, Train Accuracy: 35.83%
#     Worker 4: Train Loss: 2.4549, Train Accuracy: 37.13%
#     Worker 5: Train Loss: 2.4702, Train Accuracy: 36.43%
#     Worker 6: Train Loss: 2.5131, Train Accuracy: 35.26%
#     Worker 7: Train Loss: 2.4892, Train Accuracy: 36.00%
# Epoch 32/150: Test Loss: 2.3701, Test Accuracy: 39.06%
#     Worker 0: Train Loss: 2.4622, Train Accuracy: 36.99%
#     Worker 1: Train Loss: 2.4514, Train Accuracy: 36.30%
#     Worker 2: Train Loss: 2.4814, Train Accuracy: 36.34%
#     Worker 3: Train Loss: 2.4868, Train Accuracy: 35.11%
#     Worker 4: Train Loss: 2.4433, Train Accuracy: 36.25%
#     Worker 5: Train Loss: 2.4275, Train Accuracy: 37.35%
#     Worker 6: Train Loss: 2.4798, Train Accuracy: 35.76%
#     Worker 7: Train Loss: 2.4803, Train Accuracy: 35.66%
# Epoch 33/150: Test Loss: 2.3478, Test Accuracy: 39.45%
#     Worker 0: Train Loss: 2.4542, Train Accuracy: 36.55%
#     Worker 1: Train Loss: 2.4201, Train Accuracy: 36.84%
#     Worker 2: Train Loss: 2.4390, Train Accuracy: 37.22%
#     Worker 3: Train Loss: 2.4555, Train Accuracy: 35.71%
#     Worker 4: Train Loss: 2.4161, Train Accuracy: 37.63%
#     Worker 5: Train Loss: 2.4167, Train Accuracy: 37.84%
#     Worker 6: Train Loss: 2.4675, Train Accuracy: 36.19%
#     Worker 7: Train Loss: 2.4380, Train Accuracy: 36.86%
# Epoch 34/150: Test Loss: 2.3096, Test Accuracy: 40.18%
#     Worker 0: Train Loss: 2.4227, Train Accuracy: 37.16%
#     Worker 1: Train Loss: 2.3752, Train Accuracy: 37.74%
#     Worker 2: Train Loss: 2.4082, Train Accuracy: 37.52%
#     Worker 3: Train Loss: 2.4445, Train Accuracy: 36.86%
#     Worker 4: Train Loss: 2.3700, Train Accuracy: 38.09%
#     Worker 5: Train Loss: 2.3760, Train Accuracy: 38.36%
#     Worker 6: Train Loss: 2.4251, Train Accuracy: 37.22%
#     Worker 7: Train Loss: 2.4200, Train Accuracy: 37.16%
# Epoch 35/150: Test Loss: 2.3008, Test Accuracy: 40.42%
#     Worker 0: Train Loss: 2.3931, Train Accuracy: 37.44%
#     Worker 1: Train Loss: 2.3719, Train Accuracy: 37.81%
#     Worker 2: Train Loss: 2.3902, Train Accuracy: 37.97%
#     Worker 3: Train Loss: 2.4186, Train Accuracy: 37.29%
#     Worker 4: Train Loss: 2.3386, Train Accuracy: 39.15%
#     Worker 5: Train Loss: 2.3549, Train Accuracy: 39.18%
#     Worker 6: Train Loss: 2.4126, Train Accuracy: 37.08%
#     Worker 7: Train Loss: 2.4068, Train Accuracy: 38.53%
# Epoch 36/150: Test Loss: 2.2884, Test Accuracy: 41.08%
#     Worker 0: Train Loss: 2.3801, Train Accuracy: 37.47%
#     Worker 1: Train Loss: 2.3467, Train Accuracy: 37.91%
#     Worker 2: Train Loss: 2.3701, Train Accuracy: 38.17%
#     Worker 3: Train Loss: 2.3515, Train Accuracy: 38.53%
#     Worker 4: Train Loss: 2.3011, Train Accuracy: 39.72%
#     Worker 5: Train Loss: 2.3417, Train Accuracy: 38.74%
#     Worker 6: Train Loss: 2.3986, Train Accuracy: 37.65%
#     Worker 7: Train Loss: 2.3616, Train Accuracy: 38.42%
# Epoch 37/150: Test Loss: 2.2757, Test Accuracy: 41.37%
#     Worker 0: Train Loss: 2.3576, Train Accuracy: 38.86%
#     Worker 1: Train Loss: 2.3213, Train Accuracy: 39.07%
#     Worker 2: Train Loss: 2.3312, Train Accuracy: 40.16%
#     Worker 3: Train Loss: 2.3699, Train Accuracy: 38.15%
#     Worker 4: Train Loss: 2.2858, Train Accuracy: 40.28%
#     Worker 5: Train Loss: 2.3151, Train Accuracy: 40.38%
#     Worker 6: Train Loss: 2.3405, Train Accuracy: 38.97%
#     Worker 7: Train Loss: 2.3218, Train Accuracy: 40.11%
# Epoch 38/150: Test Loss: 2.2464, Test Accuracy: 41.61%
#     Worker 0: Train Loss: 2.3304, Train Accuracy: 38.85%
#     Worker 1: Train Loss: 2.2842, Train Accuracy: 39.39%
#     Worker 2: Train Loss: 2.2815, Train Accuracy: 39.28%
#     Worker 3: Train Loss: 2.3451, Train Accuracy: 39.04%
#     Worker 4: Train Loss: 2.3025, Train Accuracy: 39.79%
#     Worker 5: Train Loss: 2.2753, Train Accuracy: 40.64%
#     Worker 6: Train Loss: 2.3358, Train Accuracy: 38.57%
#     Worker 7: Train Loss: 2.2941, Train Accuracy: 39.43%
# Epoch 39/150: Test Loss: 2.2502, Test Accuracy: 41.98%
#     Worker 0: Train Loss: 2.2752, Train Accuracy: 40.22%
#     Worker 1: Train Loss: 2.2881, Train Accuracy: 39.78%
#     Worker 2: Train Loss: 2.2966, Train Accuracy: 40.35%
#     Worker 3: Train Loss: 2.3092, Train Accuracy: 39.24%
#     Worker 4: Train Loss: 2.2653, Train Accuracy: 40.65%
#     Worker 5: Train Loss: 2.2796, Train Accuracy: 40.14%
#     Worker 6: Train Loss: 2.2969, Train Accuracy: 39.96%
#     Worker 7: Train Loss: 2.2748, Train Accuracy: 40.99%
# Epoch 40/150: Test Loss: 2.2484, Test Accuracy: 41.79%
#     Worker 0: Train Loss: 2.3211, Train Accuracy: 39.84%
#     Worker 1: Train Loss: 2.2390, Train Accuracy: 41.05%
#     Worker 2: Train Loss: 2.2664, Train Accuracy: 40.87%
#     Worker 3: Train Loss: 2.2750, Train Accuracy: 39.67%
#     Worker 4: Train Loss: 2.2293, Train Accuracy: 42.09%
#     Worker 5: Train Loss: 2.2324, Train Accuracy: 41.27%
#     Worker 6: Train Loss: 2.2772, Train Accuracy: 39.96%
#     Worker 7: Train Loss: 2.2997, Train Accuracy: 39.89%
# Epoch 41/150: Test Loss: 2.2188, Test Accuracy: 42.60%
#     Worker 0: Train Loss: 2.2599, Train Accuracy: 40.65%
#     Worker 1: Train Loss: 2.2439, Train Accuracy: 40.14%
#     Worker 2: Train Loss: 2.2251, Train Accuracy: 41.26%
#     Worker 3: Train Loss: 2.2746, Train Accuracy: 39.78%
#     Worker 4: Train Loss: 2.2046, Train Accuracy: 42.09%
#     Worker 5: Train Loss: 2.2323, Train Accuracy: 41.53%
#     Worker 6: Train Loss: 2.2475, Train Accuracy: 41.06%
#     Worker 7: Train Loss: 2.2262, Train Accuracy: 41.75%
# Epoch 42/150: Test Loss: 2.1945, Test Accuracy: 42.63%
#     Worker 0: Train Loss: 2.2184, Train Accuracy: 41.50%
#     Worker 1: Train Loss: 2.2165, Train Accuracy: 41.65%
#     Worker 2: Train Loss: 2.2353, Train Accuracy: 41.12%
#     Worker 3: Train Loss: 2.2211, Train Accuracy: 40.93%
#     Worker 4: Train Loss: 2.2087, Train Accuracy: 40.71%
#     Worker 5: Train Loss: 2.1895, Train Accuracy: 42.10%
#     Worker 6: Train Loss: 2.2370, Train Accuracy: 40.85%
#     Worker 7: Train Loss: 2.2129, Train Accuracy: 41.77%
# Epoch 43/150: Test Loss: 2.1790, Test Accuracy: 43.41%
#     Worker 0: Train Loss: 2.2421, Train Accuracy: 40.05%
#     Worker 1: Train Loss: 2.1784, Train Accuracy: 42.33%
#     Worker 2: Train Loss: 2.2104, Train Accuracy: 41.94%
#     Worker 3: Train Loss: 2.2184, Train Accuracy: 41.15%
#     Worker 4: Train Loss: 2.1586, Train Accuracy: 42.06%
#     Worker 5: Train Loss: 2.2238, Train Accuracy: 42.18%
#     Worker 6: Train Loss: 2.2060, Train Accuracy: 41.42%
#     Worker 7: Train Loss: 2.2509, Train Accuracy: 40.94%
# Epoch 44/150: Test Loss: 2.1872, Test Accuracy: 43.02%
#     Worker 0: Train Loss: 2.2030, Train Accuracy: 41.41%
#     Worker 1: Train Loss: 2.1646, Train Accuracy: 42.24%
#     Worker 2: Train Loss: 2.1817, Train Accuracy: 42.12%
#     Worker 3: Train Loss: 2.1877, Train Accuracy: 42.09%
#     Worker 4: Train Loss: 2.1238, Train Accuracy: 43.10%
#     Worker 5: Train Loss: 2.1775, Train Accuracy: 42.60%
#     Worker 6: Train Loss: 2.1968, Train Accuracy: 42.46%
#     Worker 7: Train Loss: 2.1995, Train Accuracy: 41.98%
# Epoch 45/150: Test Loss: 2.1660, Test Accuracy: 43.43%
#     Worker 0: Train Loss: 2.1797, Train Accuracy: 41.57%
#     Worker 1: Train Loss: 2.1599, Train Accuracy: 42.10%
#     Worker 2: Train Loss: 2.1793, Train Accuracy: 42.15%
#     Worker 3: Train Loss: 2.2215, Train Accuracy: 41.29%
#     Worker 4: Train Loss: 2.1301, Train Accuracy: 43.86%
#     Worker 5: Train Loss: 2.1593, Train Accuracy: 43.19%
#     Worker 6: Train Loss: 2.1436, Train Accuracy: 43.44%
#     Worker 7: Train Loss: 2.1420, Train Accuracy: 43.99%
# Epoch 46/150: Test Loss: 2.1604, Test Accuracy: 43.58%
#     Worker 0: Train Loss: 2.1559, Train Accuracy: 42.15%
#     Worker 1: Train Loss: 2.1181, Train Accuracy: 43.74%
#     Worker 2: Train Loss: 2.1466, Train Accuracy: 43.16%
#     Worker 3: Train Loss: 2.1331, Train Accuracy: 43.44%
#     Worker 4: Train Loss: 2.1253, Train Accuracy: 43.10%
#     Worker 5: Train Loss: 2.1322, Train Accuracy: 43.41%
#     Worker 6: Train Loss: 2.1787, Train Accuracy: 42.39%
#     Worker 7: Train Loss: 2.1745, Train Accuracy: 42.78%
# Epoch 47/150: Test Loss: 2.1477, Test Accuracy: 43.92%
#     Worker 0: Train Loss: 2.1456, Train Accuracy: 43.05%
#     Worker 1: Train Loss: 2.1227, Train Accuracy: 43.83%
#     Worker 2: Train Loss: 2.1158, Train Accuracy: 43.88%
#     Worker 3: Train Loss: 2.1471, Train Accuracy: 42.22%
#     Worker 4: Train Loss: 2.0816, Train Accuracy: 44.32%
#     Worker 5: Train Loss: 2.0794, Train Accuracy: 44.86%
#     Worker 6: Train Loss: 2.1415, Train Accuracy: 43.13%
#     Worker 7: Train Loss: 2.1435, Train Accuracy: 43.07%
# Epoch 48/150: Test Loss: 2.1468, Test Accuracy: 43.96%
#     Worker 0: Train Loss: 2.1281, Train Accuracy: 43.25%
#     Worker 1: Train Loss: 2.0688, Train Accuracy: 43.91%
#     Worker 2: Train Loss: 2.1134, Train Accuracy: 43.52%
#     Worker 3: Train Loss: 2.0933, Train Accuracy: 44.12%
#     Worker 4: Train Loss: 2.0790, Train Accuracy: 44.60%
#     Worker 5: Train Loss: 2.1125, Train Accuracy: 44.05%
#     Worker 6: Train Loss: 2.1335, Train Accuracy: 43.29%
#     Worker 7: Train Loss: 2.0933, Train Accuracy: 44.36%
# Epoch 49/150: Test Loss: 2.1386, Test Accuracy: 44.44%
#     Worker 0: Train Loss: 2.0922, Train Accuracy: 44.22%
#     Worker 1: Train Loss: 2.0751, Train Accuracy: 44.54%
#     Worker 2: Train Loss: 2.0736, Train Accuracy: 44.81%
#     Worker 3: Train Loss: 2.1123, Train Accuracy: 43.45%
#     Worker 4: Train Loss: 2.0482, Train Accuracy: 45.05%
#     Worker 5: Train Loss: 2.0647, Train Accuracy: 44.72%
#     Worker 6: Train Loss: 2.1106, Train Accuracy: 44.49%
#     Worker 7: Train Loss: 2.0962, Train Accuracy: 44.39%
# Epoch 50/150: Test Loss: 2.1275, Test Accuracy: 44.17%
#     Worker 0: Train Loss: 2.0873, Train Accuracy: 44.97%
#     Worker 1: Train Loss: 2.0323, Train Accuracy: 45.69%
#     Worker 2: Train Loss: 2.0486, Train Accuracy: 45.58%
#     Worker 3: Train Loss: 2.1087, Train Accuracy: 43.62%
#     Worker 4: Train Loss: 2.0513, Train Accuracy: 45.15%
#     Worker 5: Train Loss: 2.0725, Train Accuracy: 45.30%
#     Worker 6: Train Loss: 2.0807, Train Accuracy: 44.72%
#     Worker 7: Train Loss: 2.0635, Train Accuracy: 44.68%
# Epoch 51/150: Test Loss: 2.1217, Test Accuracy: 44.86%
#     Worker 0: Train Loss: 2.0670, Train Accuracy: 44.36%
#     Worker 1: Train Loss: 2.0275, Train Accuracy: 45.13%
#     Worker 2: Train Loss: 2.0615, Train Accuracy: 45.46%
#     Worker 3: Train Loss: 2.0846, Train Accuracy: 44.20%
#     Worker 4: Train Loss: 2.0267, Train Accuracy: 45.66%
#     Worker 5: Train Loss: 2.0341, Train Accuracy: 45.63%
#     Worker 6: Train Loss: 2.0559, Train Accuracy: 45.52%
#     Worker 7: Train Loss: 2.0576, Train Accuracy: 45.09%
# Epoch 52/150: Test Loss: 2.1086, Test Accuracy: 44.40%
#     Worker 0: Train Loss: 2.0522, Train Accuracy: 44.83%
#     Worker 1: Train Loss: 2.0219, Train Accuracy: 45.96%
#     Worker 2: Train Loss: 2.0414, Train Accuracy: 45.91%
#     Worker 3: Train Loss: 2.0495, Train Accuracy: 45.43%
#     Worker 4: Train Loss: 1.9815, Train Accuracy: 46.13%
#     Worker 5: Train Loss: 2.0188, Train Accuracy: 46.23%
#     Worker 6: Train Loss: 2.0462, Train Accuracy: 45.48%
#     Worker 7: Train Loss: 2.0433, Train Accuracy: 44.78%
# Epoch 53/150: Test Loss: 2.0903, Test Accuracy: 44.88%
#     Worker 0: Train Loss: 2.0531, Train Accuracy: 45.98%
#     Worker 1: Train Loss: 2.0017, Train Accuracy: 46.35%
#     Worker 2: Train Loss: 2.0155, Train Accuracy: 46.17%
#     Worker 3: Train Loss: 2.0146, Train Accuracy: 45.75%
#     Worker 4: Train Loss: 1.9811, Train Accuracy: 47.44%
#     Worker 5: Train Loss: 2.0122, Train Accuracy: 45.90%
#     Worker 6: Train Loss: 2.0381, Train Accuracy: 45.64%
#     Worker 7: Train Loss: 2.0240, Train Accuracy: 45.98%
# Epoch 54/150: Test Loss: 2.0883, Test Accuracy: 45.69%
#     Worker 0: Train Loss: 1.9968, Train Accuracy: 46.38%
#     Worker 1: Train Loss: 1.9612, Train Accuracy: 46.32%
#     Worker 2: Train Loss: 1.9852, Train Accuracy: 46.49%
#     Worker 3: Train Loss: 2.0304, Train Accuracy: 45.45%
#     Worker 4: Train Loss: 1.9819, Train Accuracy: 46.67%
#     Worker 5: Train Loss: 1.9747, Train Accuracy: 47.65%
#     Worker 6: Train Loss: 2.0223, Train Accuracy: 46.16%
#     Worker 7: Train Loss: 1.9928, Train Accuracy: 46.62%
# Epoch 55/150: Test Loss: 2.0875, Test Accuracy: 45.38%
#     Worker 0: Train Loss: 2.0186, Train Accuracy: 46.10%
#     Worker 1: Train Loss: 1.9516, Train Accuracy: 47.78%
#     Worker 2: Train Loss: 1.9747, Train Accuracy: 47.35%
#     Worker 3: Train Loss: 1.9955, Train Accuracy: 45.93%
#     Worker 4: Train Loss: 1.9720, Train Accuracy: 46.80%
#     Worker 5: Train Loss: 1.9871, Train Accuracy: 47.21%
#     Worker 6: Train Loss: 1.9808, Train Accuracy: 46.22%
#     Worker 7: Train Loss: 1.9843, Train Accuracy: 46.76%
# Epoch 56/150: Test Loss: 2.0800, Test Accuracy: 45.63%
#     Worker 0: Train Loss: 1.9666, Train Accuracy: 46.94%
#     Worker 1: Train Loss: 1.9337, Train Accuracy: 48.06%
#     Worker 2: Train Loss: 1.9634, Train Accuracy: 47.68%
#     Worker 3: Train Loss: 1.9726, Train Accuracy: 46.83%
#     Worker 4: Train Loss: 1.9051, Train Accuracy: 48.06%
#     Worker 5: Train Loss: 1.9883, Train Accuracy: 46.44%
#     Worker 6: Train Loss: 1.9860, Train Accuracy: 47.21%
#     Worker 7: Train Loss: 1.9530, Train Accuracy: 47.60%
# Epoch 57/150: Test Loss: 2.0781, Test Accuracy: 45.34%
#     Worker 0: Train Loss: 1.9747, Train Accuracy: 47.09%
#     Worker 1: Train Loss: 1.9340, Train Accuracy: 47.17%
#     Worker 2: Train Loss: 1.9495, Train Accuracy: 47.66%
#     Worker 3: Train Loss: 1.9815, Train Accuracy: 46.96%
#     Worker 4: Train Loss: 1.9507, Train Accuracy: 47.33%
#     Worker 5: Train Loss: 1.9729, Train Accuracy: 47.30%
#     Worker 6: Train Loss: 1.9705, Train Accuracy: 47.63%
#     Worker 7: Train Loss: 1.9506, Train Accuracy: 46.97%
# Epoch 58/150: Test Loss: 2.0755, Test Accuracy: 45.52%
#     Worker 0: Train Loss: 1.9539, Train Accuracy: 46.71%
#     Worker 1: Train Loss: 1.9067, Train Accuracy: 48.27%
#     Worker 2: Train Loss: 1.9618, Train Accuracy: 47.65%
#     Worker 3: Train Loss: 1.9339, Train Accuracy: 47.66%
#     Worker 4: Train Loss: 1.8727, Train Accuracy: 48.87%
#     Worker 5: Train Loss: 1.9118, Train Accuracy: 49.16%
#     Worker 6: Train Loss: 1.9578, Train Accuracy: 46.96%
#     Worker 7: Train Loss: 1.9496, Train Accuracy: 48.06%
# Epoch 59/150: Test Loss: 2.0627, Test Accuracy: 46.50%
#     Worker 0: Train Loss: 1.9515, Train Accuracy: 46.79%
#     Worker 1: Train Loss: 1.9067, Train Accuracy: 48.27%
#     Worker 2: Train Loss: 1.8970, Train Accuracy: 49.13%
#     Worker 3: Train Loss: 1.9473, Train Accuracy: 47.39%
#     Worker 4: Train Loss: 1.9110, Train Accuracy: 48.28%
#     Worker 5: Train Loss: 1.8792, Train Accuracy: 49.55%
#     Worker 6: Train Loss: 1.9305, Train Accuracy: 48.52%
#     Worker 7: Train Loss: 1.9109, Train Accuracy: 48.33%
# Epoch 60/150: Test Loss: 2.0670, Test Accuracy: 45.70%
#     Worker 0: Train Loss: 1.9363, Train Accuracy: 47.83%
#     Worker 1: Train Loss: 1.8920, Train Accuracy: 48.34%
#     Worker 2: Train Loss: 1.9150, Train Accuracy: 48.18%
#     Worker 3: Train Loss: 1.9405, Train Accuracy: 47.26%
#     Worker 4: Train Loss: 1.8400, Train Accuracy: 49.53%
#     Worker 5: Train Loss: 1.9139, Train Accuracy: 48.39%
#     Worker 6: Train Loss: 1.8939, Train Accuracy: 49.52%
#     Worker 7: Train Loss: 1.9234, Train Accuracy: 48.04%
# Epoch 61/150: Test Loss: 2.0488, Test Accuracy: 45.87%
#     Worker 0: Train Loss: 1.8976, Train Accuracy: 48.85%
#     Worker 1: Train Loss: 1.8616, Train Accuracy: 49.08%
#     Worker 2: Train Loss: 1.8816, Train Accuracy: 49.14%
#     Worker 3: Train Loss: 1.8828, Train Accuracy: 48.97%
#     Worker 4: Train Loss: 1.8774, Train Accuracy: 48.66%
#     Worker 5: Train Loss: 1.8686, Train Accuracy: 49.20%
#     Worker 6: Train Loss: 1.9142, Train Accuracy: 48.60%
#     Worker 7: Train Loss: 1.9047, Train Accuracy: 48.55%
# Epoch 62/150: Test Loss: 2.0355, Test Accuracy: 46.71%
#     Worker 0: Train Loss: 1.9187, Train Accuracy: 48.01%
#     Worker 1: Train Loss: 1.8433, Train Accuracy: 49.95%
#     Worker 2: Train Loss: 1.8595, Train Accuracy: 49.19%
#     Worker 3: Train Loss: 1.9094, Train Accuracy: 48.33%
#     Worker 4: Train Loss: 1.8556, Train Accuracy: 49.77%
#     Worker 5: Train Loss: 1.8858, Train Accuracy: 48.81%
#     Worker 6: Train Loss: 1.9042, Train Accuracy: 49.59%
#     Worker 7: Train Loss: 1.8728, Train Accuracy: 49.10%
# Epoch 63/150: Test Loss: 2.0350, Test Accuracy: 46.77%
#     Worker 0: Train Loss: 1.8881, Train Accuracy: 48.81%
#     Worker 1: Train Loss: 1.8450, Train Accuracy: 49.86%
#     Worker 2: Train Loss: 1.8563, Train Accuracy: 49.35%
#     Worker 3: Train Loss: 1.8792, Train Accuracy: 49.17%
#     Worker 4: Train Loss: 1.8294, Train Accuracy: 49.82%
#     Worker 5: Train Loss: 1.8402, Train Accuracy: 49.91%
#     Worker 6: Train Loss: 1.8413, Train Accuracy: 49.89%
#     Worker 7: Train Loss: 1.8703, Train Accuracy: 49.05%
# Epoch 64/150: Test Loss: 2.0311, Test Accuracy: 46.70%
#     Worker 0: Train Loss: 1.8781, Train Accuracy: 48.61%
#     Worker 1: Train Loss: 1.8220, Train Accuracy: 50.56%
#     Worker 2: Train Loss: 1.8269, Train Accuracy: 50.60%
#     Worker 3: Train Loss: 1.8494, Train Accuracy: 50.06%
#     Worker 4: Train Loss: 1.8374, Train Accuracy: 49.49%
#     Worker 5: Train Loss: 1.8328, Train Accuracy: 50.44%
#     Worker 6: Train Loss: 1.8804, Train Accuracy: 48.46%
#     Worker 7: Train Loss: 1.8435, Train Accuracy: 49.85%
# Epoch 65/150: Test Loss: 2.0300, Test Accuracy: 46.68%
#     Worker 0: Train Loss: 1.8338, Train Accuracy: 50.12%
#     Worker 1: Train Loss: 1.8220, Train Accuracy: 50.20%
#     Worker 2: Train Loss: 1.8320, Train Accuracy: 50.23%
#     Worker 3: Train Loss: 1.8406, Train Accuracy: 49.89%
#     Worker 4: Train Loss: 1.8105, Train Accuracy: 49.91%
#     Worker 5: Train Loss: 1.8091, Train Accuracy: 51.04%
#     Worker 6: Train Loss: 1.8492, Train Accuracy: 50.14%
#     Worker 7: Train Loss: 1.8368, Train Accuracy: 50.33%
# Epoch 66/150: Test Loss: 2.0173, Test Accuracy: 47.56%
#     Worker 0: Train Loss: 1.8572, Train Accuracy: 49.82%
#     Worker 1: Train Loss: 1.8188, Train Accuracy: 50.82%
#     Worker 2: Train Loss: 1.8129, Train Accuracy: 50.11%
#     Worker 3: Train Loss: 1.8292, Train Accuracy: 50.64%
#     Worker 4: Train Loss: 1.7769, Train Accuracy: 51.27%
#     Worker 5: Train Loss: 1.8104, Train Accuracy: 51.18%
#     Worker 6: Train Loss: 1.8440, Train Accuracy: 49.61%
#     Worker 7: Train Loss: 1.8273, Train Accuracy: 50.74%
# Epoch 67/150: Test Loss: 2.0183, Test Accuracy: 46.91%
#     Worker 0: Train Loss: 1.8212, Train Accuracy: 50.47%
#     Worker 1: Train Loss: 1.7787, Train Accuracy: 51.43%
#     Worker 2: Train Loss: 1.7864, Train Accuracy: 51.04%
#     Worker 3: Train Loss: 1.8307, Train Accuracy: 50.30%
#     Worker 4: Train Loss: 1.7943, Train Accuracy: 50.89%
#     Worker 5: Train Loss: 1.7961, Train Accuracy: 51.18%
#     Worker 6: Train Loss: 1.8251, Train Accuracy: 50.62%
#     Worker 7: Train Loss: 1.8059, Train Accuracy: 50.21%
# Epoch 68/150: Test Loss: 2.0193, Test Accuracy: 46.98%
#     Worker 0: Train Loss: 1.7891, Train Accuracy: 50.44%
#     Worker 1: Train Loss: 1.7694, Train Accuracy: 51.46%
#     Worker 2: Train Loss: 1.7824, Train Accuracy: 51.49%
#     Worker 3: Train Loss: 1.7652, Train Accuracy: 51.57%
#     Worker 4: Train Loss: 1.7646, Train Accuracy: 52.02%
#     Worker 5: Train Loss: 1.7993, Train Accuracy: 51.90%
#     Worker 6: Train Loss: 1.7840, Train Accuracy: 51.06%
#     Worker 7: Train Loss: 1.8016, Train Accuracy: 51.01%
# Epoch 69/150: Test Loss: 2.0234, Test Accuracy: 47.66%
#     Worker 0: Train Loss: 1.8188, Train Accuracy: 49.53%
#     Worker 1: Train Loss: 1.7481, Train Accuracy: 51.39%
#     Worker 2: Train Loss: 1.7741, Train Accuracy: 51.97%
#     Worker 3: Train Loss: 1.8183, Train Accuracy: 49.79%
#     Worker 4: Train Loss: 1.7631, Train Accuracy: 51.91%
#     Worker 5: Train Loss: 1.7674, Train Accuracy: 51.72%
#     Worker 6: Train Loss: 1.8244, Train Accuracy: 50.87%
#     Worker 7: Train Loss: 1.7977, Train Accuracy: 51.09%
# Epoch 70/150: Test Loss: 1.9991, Test Accuracy: 47.51%
#     Worker 0: Train Loss: 1.7762, Train Accuracy: 52.14%
#     Worker 1: Train Loss: 1.7439, Train Accuracy: 51.88%
#     Worker 2: Train Loss: 1.7520, Train Accuracy: 51.87%
#     Worker 3: Train Loss: 1.8168, Train Accuracy: 50.65%
#     Worker 4: Train Loss: 1.7427, Train Accuracy: 52.00%
#     Worker 5: Train Loss: 1.7339, Train Accuracy: 52.55%
#     Worker 6: Train Loss: 1.7664, Train Accuracy: 51.48%
#     Worker 7: Train Loss: 1.7530, Train Accuracy: 51.96%
# Epoch 71/150: Test Loss: 2.0223, Test Accuracy: 47.37%
#     Worker 0: Train Loss: 1.7599, Train Accuracy: 51.40%
#     Worker 1: Train Loss: 1.7387, Train Accuracy: 51.42%
#     Worker 2: Train Loss: 1.7564, Train Accuracy: 52.13%
#     Worker 3: Train Loss: 1.7731, Train Accuracy: 51.52%
#     Worker 4: Train Loss: 1.7272, Train Accuracy: 52.31%
#     Worker 5: Train Loss: 1.7433, Train Accuracy: 52.92%
#     Worker 6: Train Loss: 1.7941, Train Accuracy: 51.24%
#     Worker 7: Train Loss: 1.7284, Train Accuracy: 52.85%
# Epoch 72/150: Test Loss: 1.9982, Test Accuracy: 47.51%
#     Worker 0: Train Loss: 1.7813, Train Accuracy: 50.62%
#     Worker 1: Train Loss: 1.7337, Train Accuracy: 52.07%
#     Worker 2: Train Loss: 1.7290, Train Accuracy: 52.47%
#     Worker 3: Train Loss: 1.7297, Train Accuracy: 53.12%
#     Worker 4: Train Loss: 1.7519, Train Accuracy: 51.57%
#     Worker 5: Train Loss: 1.7437, Train Accuracy: 52.25%
#     Worker 6: Train Loss: 1.7617, Train Accuracy: 52.46%
#     Worker 7: Train Loss: 1.7180, Train Accuracy: 53.33%
# Epoch 73/150: Test Loss: 1.9978, Test Accuracy: 47.94%
#     Worker 0: Train Loss: 1.7524, Train Accuracy: 52.00%
#     Worker 1: Train Loss: 1.7084, Train Accuracy: 52.08%
#     Worker 2: Train Loss: 1.7399, Train Accuracy: 52.61%
#     Worker 3: Train Loss: 1.7322, Train Accuracy: 52.49%
#     Worker 4: Train Loss: 1.6710, Train Accuracy: 54.12%
#     Worker 5: Train Loss: 1.7204, Train Accuracy: 52.08%
#     Worker 6: Train Loss: 1.7451, Train Accuracy: 52.25%
#     Worker 7: Train Loss: 1.7323, Train Accuracy: 51.93%
# Epoch 74/150: Test Loss: 1.9913, Test Accuracy: 47.87%
#     Worker 0: Train Loss: 1.7223, Train Accuracy: 52.88%
#     Worker 1: Train Loss: 1.6927, Train Accuracy: 53.41%
#     Worker 2: Train Loss: 1.7176, Train Accuracy: 52.83%
#     Worker 3: Train Loss: 1.7390, Train Accuracy: 52.37%
#     Worker 4: Train Loss: 1.6942, Train Accuracy: 52.97%
#     Worker 5: Train Loss: 1.7352, Train Accuracy: 52.49%
#     Worker 6: Train Loss: 1.7310, Train Accuracy: 52.68%
#     Worker 7: Train Loss: 1.7094, Train Accuracy: 52.31%
# Epoch 75/150: Test Loss: 1.9994, Test Accuracy: 47.63%
#     Worker 0: Train Loss: 1.7197, Train Accuracy: 52.43%
#     Worker 1: Train Loss: 1.7013, Train Accuracy: 52.56%
#     Worker 2: Train Loss: 1.7520, Train Accuracy: 51.52%
#     Worker 3: Train Loss: 1.7394, Train Accuracy: 52.41%
#     Worker 4: Train Loss: 1.6947, Train Accuracy: 53.66%
#     Worker 5: Train Loss: 1.6881, Train Accuracy: 53.98%
#     Worker 6: Train Loss: 1.7379, Train Accuracy: 52.00%
#     Worker 7: Train Loss: 1.6988, Train Accuracy: 53.39%
# Epoch 76/150: Test Loss: 1.9922, Test Accuracy: 47.84%
#     Worker 0: Train Loss: 1.7090, Train Accuracy: 52.55%
#     Worker 1: Train Loss: 1.6597, Train Accuracy: 54.49%
#     Worker 2: Train Loss: 1.6621, Train Accuracy: 54.51%
#     Worker 3: Train Loss: 1.6924, Train Accuracy: 52.82%
#     Worker 4: Train Loss: 1.6610, Train Accuracy: 54.34%
#     Worker 5: Train Loss: 1.6708, Train Accuracy: 54.88%
#     Worker 6: Train Loss: 1.7283, Train Accuracy: 53.44%
#     Worker 7: Train Loss: 1.6662, Train Accuracy: 54.10%
# Epoch 77/150: Test Loss: 1.9829, Test Accuracy: 48.02%
#     Worker 0: Train Loss: 1.7023, Train Accuracy: 53.03%
#     Worker 1: Train Loss: 1.6670, Train Accuracy: 53.60%
#     Worker 2: Train Loss: 1.6775, Train Accuracy: 54.37%
#     Worker 3: Train Loss: 1.7026, Train Accuracy: 53.11%
#     Worker 4: Train Loss: 1.6652, Train Accuracy: 53.32%
#     Worker 5: Train Loss: 1.6842, Train Accuracy: 54.01%
#     Worker 6: Train Loss: 1.6978, Train Accuracy: 53.53%
#     Worker 7: Train Loss: 1.6739, Train Accuracy: 53.56%
# Epoch 78/150: Test Loss: 1.9894, Test Accuracy: 48.02%
#     Worker 0: Train Loss: 1.6922, Train Accuracy: 53.12%
#     Worker 1: Train Loss: 1.6193, Train Accuracy: 55.31%
#     Worker 2: Train Loss: 1.6785, Train Accuracy: 53.57%
#     Worker 3: Train Loss: 1.6686, Train Accuracy: 53.57%
#     Worker 4: Train Loss: 1.6497, Train Accuracy: 54.13%
#     Worker 5: Train Loss: 1.6731, Train Accuracy: 54.18%
#     Worker 6: Train Loss: 1.6932, Train Accuracy: 53.78%
#     Worker 7: Train Loss: 1.6837, Train Accuracy: 53.90%
# Epoch 79/150: Test Loss: 1.9810, Test Accuracy: 48.19%
#     Worker 0: Train Loss: 1.6862, Train Accuracy: 53.53%
#     Worker 1: Train Loss: 1.6381, Train Accuracy: 54.19%
#     Worker 2: Train Loss: 1.6603, Train Accuracy: 54.49%
#     Worker 3: Train Loss: 1.6891, Train Accuracy: 53.36%
#     Worker 4: Train Loss: 1.6542, Train Accuracy: 53.54%
#     Worker 5: Train Loss: 1.6510, Train Accuracy: 55.32%
#     Worker 6: Train Loss: 1.6860, Train Accuracy: 54.01%
#     Worker 7: Train Loss: 1.6076, Train Accuracy: 55.14%
# Epoch 80/150: Test Loss: 1.9767, Test Accuracy: 48.36%
#     Worker 0: Train Loss: 1.6722, Train Accuracy: 54.34%
#     Worker 1: Train Loss: 1.6194, Train Accuracy: 54.93%
#     Worker 2: Train Loss: 1.6539, Train Accuracy: 53.87%
#     Worker 3: Train Loss: 1.6643, Train Accuracy: 53.98%
#     Worker 4: Train Loss: 1.5985, Train Accuracy: 56.23%
#     Worker 5: Train Loss: 1.6491, Train Accuracy: 54.84%
#     Worker 6: Train Loss: 1.6799, Train Accuracy: 53.66%
#     Worker 7: Train Loss: 1.6546, Train Accuracy: 55.14%
# Epoch 81/150: Test Loss: 1.9853, Test Accuracy: 48.39%
#     Worker 0: Train Loss: 1.6549, Train Accuracy: 53.33%
#     Worker 1: Train Loss: 1.6194, Train Accuracy: 55.44%
#     Worker 2: Train Loss: 1.6393, Train Accuracy: 54.91%
#     Worker 3: Train Loss: 1.6471, Train Accuracy: 54.51%
#     Worker 4: Train Loss: 1.6198, Train Accuracy: 55.22%
#     Worker 5: Train Loss: 1.6130, Train Accuracy: 55.53%
#     Worker 6: Train Loss: 1.6575, Train Accuracy: 54.15%
#     Worker 7: Train Loss: 1.5958, Train Accuracy: 55.28%
# Epoch 82/150: Test Loss: 1.9848, Test Accuracy: 48.11%
#     Worker 0: Train Loss: 1.6167, Train Accuracy: 55.44%
#     Worker 1: Train Loss: 1.6289, Train Accuracy: 54.61%
#     Worker 2: Train Loss: 1.6210, Train Accuracy: 55.58%
#     Worker 3: Train Loss: 1.6494, Train Accuracy: 54.96%
#     Worker 4: Train Loss: 1.6111, Train Accuracy: 55.08%
#     Worker 5: Train Loss: 1.6159, Train Accuracy: 55.07%
#     Worker 6: Train Loss: 1.6360, Train Accuracy: 54.96%
#     Worker 7: Train Loss: 1.6166, Train Accuracy: 55.75%
# Epoch 83/150: Test Loss: 1.9767, Test Accuracy: 48.40%
#     Worker 0: Train Loss: 1.6214, Train Accuracy: 54.99%
#     Worker 1: Train Loss: 1.5647, Train Accuracy: 56.72%
#     Worker 2: Train Loss: 1.6136, Train Accuracy: 55.40%
#     Worker 3: Train Loss: 1.6410, Train Accuracy: 54.55%
#     Worker 4: Train Loss: 1.5816, Train Accuracy: 55.52%
#     Worker 5: Train Loss: 1.6028, Train Accuracy: 55.85%
#     Worker 6: Train Loss: 1.6405, Train Accuracy: 55.02%
#     Worker 7: Train Loss: 1.6000, Train Accuracy: 55.98%
# Epoch 84/150: Test Loss: 1.9816, Test Accuracy: 48.76%
#     Worker 0: Train Loss: 1.6547, Train Accuracy: 54.54%
#     Worker 1: Train Loss: 1.5747, Train Accuracy: 56.04%
#     Worker 2: Train Loss: 1.5855, Train Accuracy: 56.75%
#     Worker 3: Train Loss: 1.6080, Train Accuracy: 55.83%
#     Worker 4: Train Loss: 1.5807, Train Accuracy: 56.60%
#     Worker 5: Train Loss: 1.5881, Train Accuracy: 55.64%
#     Worker 6: Train Loss: 1.6107, Train Accuracy: 55.26%
#     Worker 7: Train Loss: 1.5685, Train Accuracy: 56.78%
# Epoch 85/150: Test Loss: 1.9781, Test Accuracy: 48.62%
#     Worker 0: Train Loss: 1.5792, Train Accuracy: 56.42%
#     Worker 1: Train Loss: 1.5717, Train Accuracy: 56.21%
#     Worker 2: Train Loss: 1.5845, Train Accuracy: 55.77%
#     Worker 3: Train Loss: 1.6043, Train Accuracy: 55.32%
#     Worker 4: Train Loss: 1.5598, Train Accuracy: 56.78%
#     Worker 5: Train Loss: 1.5764, Train Accuracy: 56.45%
#     Worker 6: Train Loss: 1.6188, Train Accuracy: 55.44%
#     Worker 7: Train Loss: 1.6063, Train Accuracy: 55.37%
# Epoch 86/150: Test Loss: 1.9907, Test Accuracy: 48.40%
#     Worker 0: Train Loss: 1.5977, Train Accuracy: 55.25%
#     Worker 1: Train Loss: 1.5628, Train Accuracy: 56.38%
#     Worker 2: Train Loss: 1.5719, Train Accuracy: 56.71%
#     Worker 3: Train Loss: 1.5681, Train Accuracy: 57.31%
#     Worker 4: Train Loss: 1.5508, Train Accuracy: 56.50%
#     Worker 5: Train Loss: 1.5534, Train Accuracy: 56.32%
#     Worker 6: Train Loss: 1.6178, Train Accuracy: 55.14%
#     Worker 7: Train Loss: 1.5540, Train Accuracy: 56.95%
# Epoch 87/150: Test Loss: 1.9725, Test Accuracy: 48.75%
#     Worker 0: Train Loss: 1.5916, Train Accuracy: 55.41%
#     Worker 1: Train Loss: 1.5573, Train Accuracy: 55.82%
#     Worker 2: Train Loss: 1.5532, Train Accuracy: 56.98%
#     Worker 3: Train Loss: 1.5495, Train Accuracy: 56.29%
#     Worker 4: Train Loss: 1.5378, Train Accuracy: 56.95%
#     Worker 5: Train Loss: 1.5790, Train Accuracy: 56.56%
#     Worker 6: Train Loss: 1.5817, Train Accuracy: 55.95%
#     Worker 7: Train Loss: 1.5728, Train Accuracy: 56.62%
# Epoch 88/150: Test Loss: 1.9802, Test Accuracy: 48.69%
#     Worker 0: Train Loss: 1.5852, Train Accuracy: 55.20%
#     Worker 1: Train Loss: 1.5229, Train Accuracy: 57.51%
#     Worker 2: Train Loss: 1.5596, Train Accuracy: 57.04%
#     Worker 3: Train Loss: 1.5567, Train Accuracy: 57.07%
#     Worker 4: Train Loss: 1.5257, Train Accuracy: 57.69%
#     Worker 5: Train Loss: 1.5498, Train Accuracy: 57.33%
#     Worker 6: Train Loss: 1.5735, Train Accuracy: 56.10%
#     Worker 7: Train Loss: 1.5722, Train Accuracy: 56.24%
# Epoch 89/150: Test Loss: 1.9741, Test Accuracy: 48.85%
#     Worker 0: Train Loss: 1.5699, Train Accuracy: 56.54%
#     Worker 1: Train Loss: 1.5658, Train Accuracy: 56.07%
#     Worker 2: Train Loss: 1.5330, Train Accuracy: 57.94%
#     Worker 3: Train Loss: 1.5840, Train Accuracy: 55.62%
#     Worker 4: Train Loss: 1.5172, Train Accuracy: 57.05%
#     Worker 5: Train Loss: 1.5444, Train Accuracy: 57.08%
#     Worker 6: Train Loss: 1.5612, Train Accuracy: 57.10%
#     Worker 7: Train Loss: 1.5289, Train Accuracy: 57.04%
# Epoch 90/150: Test Loss: 1.9725, Test Accuracy: 49.06%
#     Worker 0: Train Loss: 1.5628, Train Accuracy: 56.39%
#     Worker 1: Train Loss: 1.5030, Train Accuracy: 57.72%
#     Worker 2: Train Loss: 1.5491, Train Accuracy: 57.08%
#     Worker 3: Train Loss: 1.5217, Train Accuracy: 57.27%
#     Worker 4: Train Loss: 1.5163, Train Accuracy: 58.35%
#     Worker 5: Train Loss: 1.5297, Train Accuracy: 57.93%
#     Worker 6: Train Loss: 1.5735, Train Accuracy: 56.41%
#     Worker 7: Train Loss: 1.5317, Train Accuracy: 56.66%
# Epoch 91/150: Test Loss: 1.9680, Test Accuracy: 49.07%
#     Worker 0: Train Loss: 1.5280, Train Accuracy: 56.84%
#     Worker 1: Train Loss: 1.5029, Train Accuracy: 58.26%
#     Worker 2: Train Loss: 1.5169, Train Accuracy: 58.17%
#     Worker 3: Train Loss: 1.5395, Train Accuracy: 57.28%
#     Worker 4: Train Loss: 1.4981, Train Accuracy: 57.91%
#     Worker 5: Train Loss: 1.4977, Train Accuracy: 58.26%
#     Worker 6: Train Loss: 1.5265, Train Accuracy: 57.34%
#     Worker 7: Train Loss: 1.5344, Train Accuracy: 57.49%
# Epoch 92/150: Test Loss: 1.9804, Test Accuracy: 49.09%
#     Worker 0: Train Loss: 1.5255, Train Accuracy: 57.72%
#     Worker 1: Train Loss: 1.4889, Train Accuracy: 58.56%
#     Worker 2: Train Loss: 1.5257, Train Accuracy: 58.26%
#     Worker 3: Train Loss: 1.5103, Train Accuracy: 57.52%
#     Worker 4: Train Loss: 1.4921, Train Accuracy: 57.85%
#     Worker 5: Train Loss: 1.5283, Train Accuracy: 57.43%
#     Worker 6: Train Loss: 1.5286, Train Accuracy: 58.22%
#     Worker 7: Train Loss: 1.4910, Train Accuracy: 58.15%
# Epoch 93/150: Test Loss: 1.9726, Test Accuracy: 49.15%
#     Worker 0: Train Loss: 1.5142, Train Accuracy: 58.32%
#     Worker 1: Train Loss: 1.4906, Train Accuracy: 58.25%
#     Worker 2: Train Loss: 1.4809, Train Accuracy: 58.70%
#     Worker 3: Train Loss: 1.5198, Train Accuracy: 57.02%
#     Worker 4: Train Loss: 1.4667, Train Accuracy: 58.85%
#     Worker 5: Train Loss: 1.5099, Train Accuracy: 58.29%
#     Worker 6: Train Loss: 1.5253, Train Accuracy: 57.70%
#     Worker 7: Train Loss: 1.5069, Train Accuracy: 58.20%
# Epoch 94/150: Test Loss: 1.9744, Test Accuracy: 49.00%
#     Worker 0: Train Loss: 1.5118, Train Accuracy: 57.51%
# ...
#     Worker 6: Train Loss: 1.3410, Train Accuracy: 62.56%
#     Worker 7: Train Loss: 1.2882, Train Accuracy: 63.33%
# Epoch 120/150: Test Loss: 1.9804, Test Accuracy: 49.91%
#     Worker 0: Train Loss: 1.3107, Train Accuracy: 62.74%
#     Worker 1: Train Loss: 1.2692, Train Accuracy: 63.42%
#     Worker 2: Train Loss: 1.2877, Train Accuracy: 63.70%
#     Worker 3: Train Loss: 1.3057, Train Accuracy: 62.87%
#     Worker 4: Train Loss: 1.2995, Train Accuracy: 62.90%
#     Worker 5: Train Loss: 1.2812, Train Accuracy: 64.61%
#     Worker 6: Train Loss: 1.3233, Train Accuracy: 62.62%
#     Worker 7: Train Loss: 1.2835, Train Accuracy: 63.93%
# Epoch 121/150: Test Loss: 1.9789, Test Accuracy: 49.98%
#     Worker 0: Train Loss: 1.3187, Train Accuracy: 62.87%
#     Worker 1: Train Loss: 1.2992, Train Accuracy: 62.77%
#     Worker 2: Train Loss: 1.3163, Train Accuracy: 63.14%
#     Worker 3: Train Loss: 1.3248, Train Accuracy: 62.92%
#     Worker 4: Train Loss: 1.2929, Train Accuracy: 63.42%
#     Worker 5: Train Loss: 1.2909, Train Accuracy: 63.76%
#     Worker 6: Train Loss: 1.3157, Train Accuracy: 62.62%
#     Worker 7: Train Loss: 1.3124, Train Accuracy: 62.72%
# Epoch 122/150: Test Loss: 1.9813, Test Accuracy: 50.09%
#     Worker 0: Train Loss: 1.2989, Train Accuracy: 63.28%
#     Worker 1: Train Loss: 1.2749, Train Accuracy: 62.92%
#     Worker 2: Train Loss: 1.2943, Train Accuracy: 63.87%
#     Worker 3: Train Loss: 1.3137, Train Accuracy: 63.20%
#     Worker 4: Train Loss: 1.2705, Train Accuracy: 64.23%
#     Worker 5: Train Loss: 1.3024, Train Accuracy: 63.25%
#     Worker 6: Train Loss: 1.3076, Train Accuracy: 63.22%
#     Worker 7: Train Loss: 1.3233, Train Accuracy: 62.71%
# Epoch 123/150: Test Loss: 1.9755, Test Accuracy: 50.24%
#     Worker 0: Train Loss: 1.3129, Train Accuracy: 62.84%
#     Worker 1: Train Loss: 1.2764, Train Accuracy: 62.60%
#     Worker 2: Train Loss: 1.2778, Train Accuracy: 64.52%
#     Worker 3: Train Loss: 1.2914, Train Accuracy: 63.52%
#     Worker 4: Train Loss: 1.2893, Train Accuracy: 63.94%
#     Worker 5: Train Loss: 1.3003, Train Accuracy: 63.55%
#     Worker 6: Train Loss: 1.3016, Train Accuracy: 63.25%
#     Worker 7: Train Loss: 1.2765, Train Accuracy: 63.85%
# Epoch 124/150: Test Loss: 1.9747, Test Accuracy: 49.96%
#     Worker 0: Train Loss: 1.2987, Train Accuracy: 63.33%
#     Worker 1: Train Loss: 1.2822, Train Accuracy: 63.81%
#     Worker 2: Train Loss: 1.2690, Train Accuracy: 64.65%
#     Worker 3: Train Loss: 1.3366, Train Accuracy: 62.74%
#     Worker 4: Train Loss: 1.2533, Train Accuracy: 64.76%
#     Worker 5: Train Loss: 1.2786, Train Accuracy: 63.43%
#     Worker 6: Train Loss: 1.3054, Train Accuracy: 63.42%
#     Worker 7: Train Loss: 1.2869, Train Accuracy: 64.12%
# Epoch 125/150: Test Loss: 1.9775, Test Accuracy: 50.00%
#     Worker 0: Train Loss: 1.3191, Train Accuracy: 62.44%
#     Worker 1: Train Loss: 1.2444, Train Accuracy: 64.83%
#     Worker 2: Train Loss: 1.2883, Train Accuracy: 64.23%
#     Worker 3: Train Loss: 1.2827, Train Accuracy: 64.86%
#     Worker 4: Train Loss: 1.2710, Train Accuracy: 63.70%
#     Worker 5: Train Loss: 1.2816, Train Accuracy: 63.63%
#     Worker 6: Train Loss: 1.2865, Train Accuracy: 63.30%
#     Worker 7: Train Loss: 1.2592, Train Accuracy: 64.44%
# Epoch 126/150: Test Loss: 1.9803, Test Accuracy: 50.13%
#     Worker 0: Train Loss: 1.2870, Train Accuracy: 63.81%
#     Worker 1: Train Loss: 1.2463, Train Accuracy: 64.40%
#     Worker 2: Train Loss: 1.2774, Train Accuracy: 64.34%
#     Worker 3: Train Loss: 1.2780, Train Accuracy: 63.84%
#     Worker 4: Train Loss: 1.2568, Train Accuracy: 64.86%
#     Worker 5: Train Loss: 1.2736, Train Accuracy: 64.38%
#     Worker 6: Train Loss: 1.3272, Train Accuracy: 62.68%
#     Worker 7: Train Loss: 1.2842, Train Accuracy: 64.15%
# Epoch 127/150: Test Loss: 1.9787, Test Accuracy: 49.96%
#     Worker 0: Train Loss: 1.2959, Train Accuracy: 63.49%
#     Worker 1: Train Loss: 1.2454, Train Accuracy: 64.21%
#     Worker 2: Train Loss: 1.2541, Train Accuracy: 64.31%
#     Worker 3: Train Loss: 1.2902, Train Accuracy: 64.00%
#     Worker 4: Train Loss: 1.2668, Train Accuracy: 64.41%
#     Worker 5: Train Loss: 1.2816, Train Accuracy: 64.47%
#     Worker 6: Train Loss: 1.3046, Train Accuracy: 63.55%
#     Worker 7: Train Loss: 1.2719, Train Accuracy: 63.46%
# Epoch 128/150: Test Loss: 1.9784, Test Accuracy: 49.92%
#     Worker 0: Train Loss: 1.2758, Train Accuracy: 63.64%
#     Worker 1: Train Loss: 1.2634, Train Accuracy: 64.06%
#     Worker 2: Train Loss: 1.2594, Train Accuracy: 64.77%
#     Worker 3: Train Loss: 1.2709, Train Accuracy: 64.09%
#     Worker 4: Train Loss: 1.2565, Train Accuracy: 64.40%
#     Worker 5: Train Loss: 1.2693, Train Accuracy: 63.72%
#     Worker 6: Train Loss: 1.2967, Train Accuracy: 64.02%
#     Worker 7: Train Loss: 1.2699, Train Accuracy: 63.85%
# Epoch 129/150: Test Loss: 1.9802, Test Accuracy: 50.04%
#     Worker 0: Train Loss: 1.3104, Train Accuracy: 62.78%
#     Worker 1: Train Loss: 1.2637, Train Accuracy: 64.56%
#     Worker 2: Train Loss: 1.2744, Train Accuracy: 64.27%
#     Worker 3: Train Loss: 1.2768, Train Accuracy: 64.02%
#     Worker 4: Train Loss: 1.2426, Train Accuracy: 64.73%
#     Worker 5: Train Loss: 1.2641, Train Accuracy: 64.34%
#     Worker 6: Train Loss: 1.2771, Train Accuracy: 64.27%
#     Worker 7: Train Loss: 1.2594, Train Accuracy: 64.08%
# Epoch 130/150: Test Loss: 1.9790, Test Accuracy: 50.21%
#     Worker 0: Train Loss: 1.2642, Train Accuracy: 64.38%
#     Worker 1: Train Loss: 1.2386, Train Accuracy: 64.29%
#     Worker 2: Train Loss: 1.2389, Train Accuracy: 65.16%
#     Worker 3: Train Loss: 1.2792, Train Accuracy: 64.53%
#     Worker 4: Train Loss: 1.2611, Train Accuracy: 64.74%
#     Worker 5: Train Loss: 1.2713, Train Accuracy: 64.70%
#     Worker 6: Train Loss: 1.2971, Train Accuracy: 63.45%
#     Worker 7: Train Loss: 1.2611, Train Accuracy: 64.82%
# Epoch 131/150: Test Loss: 1.9822, Test Accuracy: 50.05%
#     Worker 0: Train Loss: 1.2897, Train Accuracy: 63.61%
#     Worker 1: Train Loss: 1.2555, Train Accuracy: 64.47%
#     Worker 2: Train Loss: 1.2552, Train Accuracy: 64.81%
#     Worker 3: Train Loss: 1.2466, Train Accuracy: 64.88%
#     Worker 4: Train Loss: 1.2371, Train Accuracy: 65.28%
#     Worker 5: Train Loss: 1.2671, Train Accuracy: 64.64%
#     Worker 6: Train Loss: 1.2773, Train Accuracy: 63.66%
#     Worker 7: Train Loss: 1.2539, Train Accuracy: 64.50%
# Epoch 132/150: Test Loss: 1.9773, Test Accuracy: 50.22%
#     Worker 0: Train Loss: 1.2691, Train Accuracy: 64.06%
#     Worker 1: Train Loss: 1.2295, Train Accuracy: 64.55%
#     Worker 2: Train Loss: 1.2527, Train Accuracy: 65.01%
#     Worker 3: Train Loss: 1.2947, Train Accuracy: 63.60%
#     Worker 4: Train Loss: 1.2390, Train Accuracy: 64.73%
#     Worker 5: Train Loss: 1.2648, Train Accuracy: 64.76%
#     Worker 6: Train Loss: 1.2770, Train Accuracy: 64.06%
#     Worker 7: Train Loss: 1.2462, Train Accuracy: 64.70%
# Epoch 133/150: Test Loss: 1.9793, Test Accuracy: 50.03%
#     Worker 0: Train Loss: 1.2866, Train Accuracy: 63.96%
#     Worker 1: Train Loss: 1.2423, Train Accuracy: 64.55%
#     Worker 2: Train Loss: 1.2511, Train Accuracy: 64.82%
#     Worker 3: Train Loss: 1.2645, Train Accuracy: 64.61%
#     Worker 4: Train Loss: 1.2357, Train Accuracy: 65.15%
#     Worker 5: Train Loss: 1.2610, Train Accuracy: 64.71%
#     Worker 6: Train Loss: 1.2900, Train Accuracy: 64.55%
#     Worker 7: Train Loss: 1.2632, Train Accuracy: 64.32%
# Epoch 134/150: Test Loss: 1.9832, Test Accuracy: 50.16%
#     Worker 0: Train Loss: 1.2754, Train Accuracy: 63.67%
#     Worker 1: Train Loss: 1.2324, Train Accuracy: 65.22%
#     Worker 2: Train Loss: 1.2645, Train Accuracy: 64.94%
#     Worker 3: Train Loss: 1.2734, Train Accuracy: 63.85%
#     Worker 4: Train Loss: 1.2577, Train Accuracy: 64.71%
#     Worker 5: Train Loss: 1.2592, Train Accuracy: 64.85%
#     Worker 6: Train Loss: 1.2781, Train Accuracy: 63.94%
#     Worker 7: Train Loss: 1.2449, Train Accuracy: 64.65%
# Epoch 135/150: Test Loss: 1.9803, Test Accuracy: 50.07%
#     Worker 0: Train Loss: 1.2564, Train Accuracy: 64.26%
#     Worker 1: Train Loss: 1.2329, Train Accuracy: 65.28%
#     Worker 2: Train Loss: 1.2298, Train Accuracy: 65.18%
#     Worker 3: Train Loss: 1.2582, Train Accuracy: 64.64%
#     Worker 4: Train Loss: 1.2377, Train Accuracy: 65.01%
#     Worker 5: Train Loss: 1.2276, Train Accuracy: 65.98%
#     Worker 6: Train Loss: 1.2710, Train Accuracy: 64.03%
#     Worker 7: Train Loss: 1.2494, Train Accuracy: 64.95%
# Epoch 136/150: Test Loss: 1.9786, Test Accuracy: 50.22%
#     Worker 0: Train Loss: 1.2812, Train Accuracy: 64.35%
#     Worker 1: Train Loss: 1.2152, Train Accuracy: 64.89%
#     Worker 2: Train Loss: 1.2434, Train Accuracy: 65.45%
#     Worker 3: Train Loss: 1.2704, Train Accuracy: 64.77%
#     Worker 4: Train Loss: 1.2447, Train Accuracy: 65.25%
#     Worker 5: Train Loss: 1.2783, Train Accuracy: 64.26%
#     Worker 6: Train Loss: 1.2711, Train Accuracy: 64.02%
#     Worker 7: Train Loss: 1.2558, Train Accuracy: 64.31%
# Epoch 137/150: Test Loss: 1.9798, Test Accuracy: 50.16%
#     Worker 0: Train Loss: 1.2729, Train Accuracy: 63.58%
#     Worker 1: Train Loss: 1.2424, Train Accuracy: 64.58%
#     Worker 2: Train Loss: 1.2633, Train Accuracy: 64.29%
#     Worker 3: Train Loss: 1.2580, Train Accuracy: 64.65%
#     Worker 4: Train Loss: 1.2292, Train Accuracy: 64.79%
#     Worker 5: Train Loss: 1.2440, Train Accuracy: 65.15%
#     Worker 6: Train Loss: 1.2816, Train Accuracy: 64.17%
#     Worker 7: Train Loss: 1.2352, Train Accuracy: 65.28%
# Epoch 138/150: Test Loss: 1.9811, Test Accuracy: 50.08%
#     Worker 0: Train Loss: 1.2529, Train Accuracy: 64.53%
#     Worker 1: Train Loss: 1.2292, Train Accuracy: 64.55%
#     Worker 2: Train Loss: 1.2266, Train Accuracy: 65.87%
#     Worker 3: Train Loss: 1.2711, Train Accuracy: 63.70%
#     Worker 4: Train Loss: 1.2348, Train Accuracy: 65.62%
#     Worker 5: Train Loss: 1.2588, Train Accuracy: 64.62%
#     Worker 6: Train Loss: 1.2655, Train Accuracy: 64.53%
#     Worker 7: Train Loss: 1.2395, Train Accuracy: 64.88%
# Epoch 139/150: Test Loss: 1.9793, Test Accuracy: 50.05%
#     Worker 0: Train Loss: 1.2658, Train Accuracy: 63.93%
#     Worker 1: Train Loss: 1.2250, Train Accuracy: 65.32%
#     Worker 2: Train Loss: 1.2268, Train Accuracy: 65.86%
#     Worker 3: Train Loss: 1.2575, Train Accuracy: 64.23%
#     Worker 4: Train Loss: 1.2314, Train Accuracy: 65.12%
#     Worker 5: Train Loss: 1.2283, Train Accuracy: 65.78%
#     Worker 6: Train Loss: 1.2780, Train Accuracy: 64.21%
#     Worker 7: Train Loss: 1.2428, Train Accuracy: 65.06%
# Epoch 140/150: Test Loss: 1.9807, Test Accuracy: 49.98%
#     Worker 0: Train Loss: 1.2547, Train Accuracy: 64.79%
#     Worker 1: Train Loss: 1.2099, Train Accuracy: 65.78%
#     Worker 2: Train Loss: 1.2551, Train Accuracy: 65.06%
#     Worker 3: Train Loss: 1.2507, Train Accuracy: 65.09%
#     Worker 4: Train Loss: 1.2496, Train Accuracy: 64.97%
#     Worker 5: Train Loss: 1.2283, Train Accuracy: 65.81%
#     Worker 6: Train Loss: 1.2522, Train Accuracy: 64.89%
#     Worker 7: Train Loss: 1.2224, Train Accuracy: 66.02%
# Epoch 141/150: Test Loss: 1.9800, Test Accuracy: 50.18%
#     Worker 0: Train Loss: 1.2885, Train Accuracy: 63.96%
#     Worker 1: Train Loss: 1.2324, Train Accuracy: 65.63%
#     Worker 2: Train Loss: 1.2651, Train Accuracy: 64.68%
#     Worker 3: Train Loss: 1.2446, Train Accuracy: 64.95%
#     Worker 4: Train Loss: 1.2216, Train Accuracy: 65.16%
#     Worker 5: Train Loss: 1.2479, Train Accuracy: 65.07%
#     Worker 6: Train Loss: 1.2799, Train Accuracy: 64.05%
#     Worker 7: Train Loss: 1.2669, Train Accuracy: 64.06%
# Epoch 142/150: Test Loss: 1.9799, Test Accuracy: 49.97%
#     Worker 0: Train Loss: 1.2570, Train Accuracy: 64.53%
#     Worker 1: Train Loss: 1.2135, Train Accuracy: 65.10%
#     Worker 2: Train Loss: 1.2175, Train Accuracy: 65.50%
#     Worker 3: Train Loss: 1.2363, Train Accuracy: 65.18%
#     Worker 4: Train Loss: 1.2334, Train Accuracy: 65.41%
#     Worker 5: Train Loss: 1.2437, Train Accuracy: 65.87%
#     Worker 6: Train Loss: 1.2623, Train Accuracy: 63.94%
#     Worker 7: Train Loss: 1.2413, Train Accuracy: 64.91%
# Epoch 143/150: Test Loss: 1.9797, Test Accuracy: 50.19%
#     Worker 0: Train Loss: 1.2324, Train Accuracy: 64.89%
#     Worker 1: Train Loss: 1.2298, Train Accuracy: 65.59%
#     Worker 2: Train Loss: 1.2432, Train Accuracy: 65.54%
#     Worker 3: Train Loss: 1.2793, Train Accuracy: 64.21%
#     Worker 4: Train Loss: 1.2391, Train Accuracy: 64.67%
#     Worker 5: Train Loss: 1.2493, Train Accuracy: 64.89%
#     Worker 6: Train Loss: 1.2548, Train Accuracy: 64.23%
#     Worker 7: Train Loss: 1.2435, Train Accuracy: 65.00%
# Epoch 144/150: Test Loss: 1.9801, Test Accuracy: 50.05%
#     Worker 0: Train Loss: 1.2883, Train Accuracy: 63.33%
#     Worker 1: Train Loss: 1.2158, Train Accuracy: 65.06%
#     Worker 2: Train Loss: 1.2368, Train Accuracy: 65.35%
#     Worker 3: Train Loss: 1.2403, Train Accuracy: 65.38%
#     Worker 4: Train Loss: 1.2157, Train Accuracy: 66.20%
#     Worker 5: Train Loss: 1.2631, Train Accuracy: 64.50%
#     Worker 6: Train Loss: 1.2823, Train Accuracy: 63.67%
#     Worker 7: Train Loss: 1.2513, Train Accuracy: 65.71%
# Epoch 145/150: Test Loss: 1.9808, Test Accuracy: 50.07%
#     Worker 0: Train Loss: 1.2676, Train Accuracy: 64.20%
#     Worker 1: Train Loss: 1.2051, Train Accuracy: 65.63%
#     Worker 2: Train Loss: 1.2391, Train Accuracy: 65.30%
#     Worker 3: Train Loss: 1.2525, Train Accuracy: 63.99%
#     Worker 4: Train Loss: 1.2348, Train Accuracy: 64.97%
#     Worker 5: Train Loss: 1.2473, Train Accuracy: 64.50%
#     Worker 6: Train Loss: 1.2791, Train Accuracy: 63.96%
#     Worker 7: Train Loss: 1.2284, Train Accuracy: 65.42%
# Epoch 146/150: Test Loss: 1.9809, Test Accuracy: 50.11%
#     Worker 0: Train Loss: 1.2483, Train Accuracy: 65.22%
#     Worker 1: Train Loss: 1.2458, Train Accuracy: 64.56%
#     Worker 2: Train Loss: 1.2287, Train Accuracy: 65.92%
#     Worker 3: Train Loss: 1.2614, Train Accuracy: 64.31%
#     Worker 4: Train Loss: 1.2275, Train Accuracy: 65.27%
#     Worker 5: Train Loss: 1.2476, Train Accuracy: 64.94%
#     Worker 6: Train Loss: 1.2932, Train Accuracy: 63.75%
#     Worker 7: Train Loss: 1.2437, Train Accuracy: 64.23%
# Epoch 147/150: Test Loss: 1.9804, Test Accuracy: 50.14%
#     Worker 0: Train Loss: 1.2685, Train Accuracy: 63.96%
#     Worker 1: Train Loss: 1.2280, Train Accuracy: 65.11%
#     Worker 2: Train Loss: 1.2270, Train Accuracy: 65.12%
#     Worker 3: Train Loss: 1.2461, Train Accuracy: 65.09%
#     Worker 4: Train Loss: 1.2278, Train Accuracy: 65.38%
#     Worker 5: Train Loss: 1.2584, Train Accuracy: 65.00%
#     Worker 6: Train Loss: 1.2737, Train Accuracy: 64.43%
#     Worker 7: Train Loss: 1.2514, Train Accuracy: 64.97%
# Epoch 148/150: Test Loss: 1.9803, Test Accuracy: 50.11%
#     Worker 0: Train Loss: 1.2627, Train Accuracy: 64.88%
#     Worker 1: Train Loss: 1.2234, Train Accuracy: 65.12%
#     Worker 2: Train Loss: 1.2389, Train Accuracy: 66.02%
#     Worker 3: Train Loss: 1.2539, Train Accuracy: 63.96%
#     Worker 4: Train Loss: 1.2198, Train Accuracy: 65.87%
#     Worker 5: Train Loss: 1.2555, Train Accuracy: 65.00%
#     Worker 6: Train Loss: 1.2672, Train Accuracy: 63.79%
#     Worker 7: Train Loss: 1.2526, Train Accuracy: 65.09%
# Epoch 149/150: Test Loss: 1.9803, Test Accuracy: 50.09%
#     Worker 0: Train Loss: 1.2558, Train Accuracy: 64.80%
#     Worker 1: Train Loss: 1.2231, Train Accuracy: 65.06%
#     Worker 2: Train Loss: 1.2422, Train Accuracy: 64.92%
#     Worker 3: Train Loss: 1.2474, Train Accuracy: 64.86%
#     Worker 4: Train Loss: 1.2489, Train Accuracy: 65.39%
#     Worker 5: Train Loss: 1.2354, Train Accuracy: 65.53%
#     Worker 6: Train Loss: 1.2609, Train Accuracy: 65.04%
#     Worker 7: Train Loss: 1.2505, Train Accuracy: 64.91%
# Epoch 150/150: Test Loss: 1.9803, Test Accuracy: 50.10%
#     Worker 0: Train Loss: 1.2562, Train Accuracy: 64.50%
#     Worker 1: Train Loss: 1.2136, Train Accuracy: 65.38%
#     Worker 2: Train Loss: 1.2233, Train Accuracy: 65.95%
#     Worker 3: Train Loss: 1.2418, Train Accuracy: 65.10%
#     Worker 4: Train Loss: 1.2143, Train Accuracy: 65.56%
#     Worker 5: Train Loss: 1.2411, Train Accuracy: 65.47%
#     Worker 6: Train Loss: 1.2867, Train Accuracy: 63.97%
#     Worker 7: Train Loss: 1.2412, Train Accuracy: 64.70%
