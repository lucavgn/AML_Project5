# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
#warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")

    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch):
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            # Perform J local step before synchronization
            for j in range(J):
                try:
                    # Get a batch from the current worker's shard using next()
                    images, labels = next(shard_iterators[k])
                    images, labels = images.to(device), labels.to(device)  # Move to device
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

                except StopIteration:
                    # If the iterator has exhausted the data, restart the iterator
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k]) # Resume from the next batch
                    images, labels = images.to(device), labels.to(device)
                    # Perform optimization step
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        # Perform model synchronization
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            # Update each worker model with the global parameters
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
       # if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
       # else:
        #    warmup_factor = (epoch + 1) / warmup_epochs
          #  lr = warmup_factor * learning_rate
          #  for optimizer in optimizers:
           #     for param_group in optimizer.param_groups:
            #        param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 8 --j 4
# Out:
# Training with K=8, J=4
# Global iteration per epoch: 25
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:41<00:00, 4.07MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00800
# Epoch 1/150: Test Loss: 4.5772, Test Accuracy: 2.41%
#     Worker 0: Train Loss: 4.5989, Train Accuracy: 1.33%
#     Worker 1: Train Loss: 4.5989, Train Accuracy: 1.29%
#     Worker 2: Train Loss: 4.5990, Train Accuracy: 1.25%
#     Worker 3: Train Loss: 4.5968, Train Accuracy: 1.63%
#     Worker 4: Train Loss: 4.5983, Train Accuracy: 1.18%
#     Worker 5: Train Loss: 4.5959, Train Accuracy: 1.61%
#     Worker 6: Train Loss: 4.5983, Train Accuracy: 1.29%
#     Worker 7: Train Loss: 4.5976, Train Accuracy: 1.29%
# Epoch 2/150: Test Loss: 4.2033, Test Accuracy: 5.38%
#     Worker 0: Train Loss: 4.4404, Train Accuracy: 3.53%
#     Worker 1: Train Loss: 4.4450, Train Accuracy: 3.48%
#     Worker 2: Train Loss: 4.4364, Train Accuracy: 3.90%
#     Worker 3: Train Loss: 4.4454, Train Accuracy: 3.87%
#     Worker 4: Train Loss: 4.4346, Train Accuracy: 3.81%
#     Worker 5: Train Loss: 4.4264, Train Accuracy: 3.73%
#     Worker 6: Train Loss: 4.4468, Train Accuracy: 3.61%
#     Worker 7: Train Loss: 4.4347, Train Accuracy: 3.75%
# Epoch 3/150: Test Loss: 3.9950, Test Accuracy: 8.93%
#     Worker 0: Train Loss: 4.1331, Train Accuracy: 6.84%
#     Worker 1: Train Loss: 4.1397, Train Accuracy: 6.27%
#     Worker 2: Train Loss: 4.1383, Train Accuracy: 6.85%
#     Worker 3: Train Loss: 4.1345, Train Accuracy: 6.65%
#     Worker 4: Train Loss: 4.1137, Train Accuracy: 6.52%
#     Worker 5: Train Loss: 4.1118, Train Accuracy: 6.21%
#     Worker 6: Train Loss: 4.1528, Train Accuracy: 6.43%
#     Worker 7: Train Loss: 4.1510, Train Accuracy: 6.57%
# Epoch 4/150: Test Loss: 3.8549, Test Accuracy: 11.56%
#     Worker 0: Train Loss: 3.9901, Train Accuracy: 9.23%
#     Worker 1: Train Loss: 4.0093, Train Accuracy: 7.93%
#     Worker 2: Train Loss: 3.9833, Train Accuracy: 9.17%
#     Worker 3: Train Loss: 4.0131, Train Accuracy: 8.11%
#     Worker 4: Train Loss: 3.9630, Train Accuracy: 9.30%
#     Worker 5: Train Loss: 3.9618, Train Accuracy: 9.00%
#     Worker 6: Train Loss: 3.9984, Train Accuracy: 8.03%
#     Worker 7: Train Loss: 3.9830, Train Accuracy: 8.89%
# Epoch 5/150: Test Loss: 3.7254, Test Accuracy: 13.77%
#     Worker 0: Train Loss: 3.8616, Train Accuracy: 10.69%
#     Worker 1: Train Loss: 3.8453, Train Accuracy: 10.77%
#     Worker 2: Train Loss: 3.8441, Train Accuracy: 10.80%
#     Worker 3: Train Loss: 3.8793, Train Accuracy: 10.72%
#     Worker 4: Train Loss: 3.8158, Train Accuracy: 11.76%
#     Worker 5: Train Loss: 3.8271, Train Accuracy: 11.52%
#     Worker 6: Train Loss: 3.8575, Train Accuracy: 10.58%
#     Worker 7: Train Loss: 3.8550, Train Accuracy: 10.93%
# Epoch 6/150: Test Loss: 3.6036, Test Accuracy: 15.95%
#     Worker 0: Train Loss: 3.7596, Train Accuracy: 12.42%
#     Worker 1: Train Loss: 3.7566, Train Accuracy: 12.25%
#     Worker 2: Train Loss: 3.7354, Train Accuracy: 13.20%
#     Worker 3: Train Loss: 3.7618, Train Accuracy: 12.06%
#     Worker 4: Train Loss: 3.7030, Train Accuracy: 13.14%
#     Worker 5: Train Loss: 3.6940, Train Accuracy: 14.03%
#     Worker 6: Train Loss: 3.7755, Train Accuracy: 12.10%
#     Worker 7: Train Loss: 3.7417, Train Accuracy: 12.31%
# Epoch 7/150: Test Loss: 3.5023, Test Accuracy: 17.40%
#     Worker 0: Train Loss: 3.6359, Train Accuracy: 13.84%
#     Worker 1: Train Loss: 3.6320, Train Accuracy: 13.86%
#     Worker 2: Train Loss: 3.6486, Train Accuracy: 14.25%
#     Worker 3: Train Loss: 3.6782, Train Accuracy: 13.41%
#     Worker 4: Train Loss: 3.6077, Train Accuracy: 14.46%
#     Worker 5: Train Loss: 3.5995, Train Accuracy: 15.05%
#     Worker 6: Train Loss: 3.6559, Train Accuracy: 13.80%
#     Worker 7: Train Loss: 3.6445, Train Accuracy: 14.64%
# Epoch 8/150: Test Loss: 3.4283, Test Accuracy: 18.87%
#     Worker 0: Train Loss: 3.5511, Train Accuracy: 15.55%
#     Worker 1: Train Loss: 3.5582, Train Accuracy: 15.85%
#     Worker 2: Train Loss: 3.5720, Train Accuracy: 16.12%
#     Worker 3: Train Loss: 3.5845, Train Accuracy: 14.83%
#     Worker 4: Train Loss: 3.5301, Train Accuracy: 15.91%
#     Worker 5: Train Loss: 3.5207, Train Accuracy: 16.85%
#     Worker 6: Train Loss: 3.5622, Train Accuracy: 16.15%
#     Worker 7: Train Loss: 3.5762, Train Accuracy: 15.43%
# Epoch 9/150: Test Loss: 3.3623, Test Accuracy: 19.79%
#     Worker 0: Train Loss: 3.5031, Train Accuracy: 16.46%
#     Worker 1: Train Loss: 3.4744, Train Accuracy: 17.40%
#     Worker 2: Train Loss: 3.4960, Train Accuracy: 16.70%
#     Worker 3: Train Loss: 3.4839, Train Accuracy: 17.18%
#     Worker 4: Train Loss: 3.4554, Train Accuracy: 17.18%
#     Worker 5: Train Loss: 3.4350, Train Accuracy: 18.14%
#     Worker 6: Train Loss: 3.4958, Train Accuracy: 16.68%
#     Worker 7: Train Loss: 3.4854, Train Accuracy: 16.46%
# Epoch 10/150: Test Loss: 3.2734, Test Accuracy: 21.58%
#     Worker 0: Train Loss: 3.3944, Train Accuracy: 18.11%
#     Worker 1: Train Loss: 3.3945, Train Accuracy: 18.56%
#     Worker 2: Train Loss: 3.4153, Train Accuracy: 18.83%
#     Worker 3: Train Loss: 3.4507, Train Accuracy: 17.89%
#     Worker 4: Train Loss: 3.3497, Train Accuracy: 19.54%
#     Worker 5: Train Loss: 3.3370, Train Accuracy: 19.69%
#     Worker 6: Train Loss: 3.4277, Train Accuracy: 17.98%
#     Worker 7: Train Loss: 3.3906, Train Accuracy: 18.86%
# Epoch 11/150: Test Loss: 3.2202, Test Accuracy: 22.43%
#     Worker 0: Train Loss: 3.3420, Train Accuracy: 19.72%
#     Worker 1: Train Loss: 3.3223, Train Accuracy: 20.01%
#     Worker 2: Train Loss: 3.3610, Train Accuracy: 20.16%
#     Worker 3: Train Loss: 3.3443, Train Accuracy: 19.14%
#     Worker 4: Train Loss: 3.2969, Train Accuracy: 20.15%
#     Worker 5: Train Loss: 3.2783, Train Accuracy: 20.49%
#     Worker 6: Train Loss: 3.3454, Train Accuracy: 18.30%
#     Worker 7: Train Loss: 3.3503, Train Accuracy: 19.18%
# Epoch 12/150: Test Loss: 3.1525, Test Accuracy: 23.65%
#     Worker 0: Train Loss: 3.2527, Train Accuracy: 20.85%
#     Worker 1: Train Loss: 3.2571, Train Accuracy: 20.52%
#     Worker 2: Train Loss: 3.2652, Train Accuracy: 21.57%
#     Worker 3: Train Loss: 3.2807, Train Accuracy: 19.90%
#     Worker 4: Train Loss: 3.2452, Train Accuracy: 20.92%
#     Worker 5: Train Loss: 3.2389, Train Accuracy: 21.86%
#     Worker 6: Train Loss: 3.2917, Train Accuracy: 20.23%
#     Worker 7: Train Loss: 3.2574, Train Accuracy: 20.43%
# Epoch 13/150: Test Loss: 3.0803, Test Accuracy: 25.43%
#     Worker 0: Train Loss: 3.1991, Train Accuracy: 21.45%
#     Worker 1: Train Loss: 3.1701, Train Accuracy: 21.70%
#     Worker 2: Train Loss: 3.2264, Train Accuracy: 22.11%
#     Worker 3: Train Loss: 3.2502, Train Accuracy: 20.71%
#     Worker 4: Train Loss: 3.1618, Train Accuracy: 22.45%
#     Worker 5: Train Loss: 3.1437, Train Accuracy: 23.94%
#     Worker 6: Train Loss: 3.2334, Train Accuracy: 21.29%
#     Worker 7: Train Loss: 3.2324, Train Accuracy: 21.50%
# Epoch 14/150: Test Loss: 3.0040, Test Accuracy: 26.92%
#     Worker 0: Train Loss: 3.1551, Train Accuracy: 22.62%
#     Worker 1: Train Loss: 3.1394, Train Accuracy: 22.92%
#     Worker 2: Train Loss: 3.1254, Train Accuracy: 24.11%
#     Worker 3: Train Loss: 3.1505, Train Accuracy: 22.78%
#     Worker 4: Train Loss: 3.1186, Train Accuracy: 23.53%
#     Worker 5: Train Loss: 3.1158, Train Accuracy: 23.91%
#     Worker 6: Train Loss: 3.1612, Train Accuracy: 23.46%
#     Worker 7: Train Loss: 3.1240, Train Accuracy: 23.64%
# Epoch 15/150: Test Loss: 3.0187, Test Accuracy: 26.07%
#     Worker 0: Train Loss: 3.0888, Train Accuracy: 24.47%
#     Worker 1: Train Loss: 3.0911, Train Accuracy: 23.71%
#     Worker 2: Train Loss: 3.1181, Train Accuracy: 24.37%
#     Worker 3: Train Loss: 3.1404, Train Accuracy: 23.52%
#     Worker 4: Train Loss: 3.0775, Train Accuracy: 24.62%
#     Worker 5: Train Loss: 3.0560, Train Accuracy: 24.85%
#     Worker 6: Train Loss: 3.1339, Train Accuracy: 22.80%
#     Worker 7: Train Loss: 3.1001, Train Accuracy: 24.13%
# Epoch 16/150: Test Loss: 2.9076, Test Accuracy: 28.42%
#     Worker 0: Train Loss: 3.0661, Train Accuracy: 23.99%
#     Worker 1: Train Loss: 3.0500, Train Accuracy: 24.41%
#     Worker 2: Train Loss: 3.0783, Train Accuracy: 25.10%
#     Worker 3: Train Loss: 3.0581, Train Accuracy: 24.11%
#     Worker 4: Train Loss: 3.0410, Train Accuracy: 25.78%
#     Worker 5: Train Loss: 3.0019, Train Accuracy: 26.67%
#     Worker 6: Train Loss: 3.0423, Train Accuracy: 24.95%
#     Worker 7: Train Loss: 3.0781, Train Accuracy: 24.44%
# Epoch 17/150: Test Loss: 2.8930, Test Accuracy: 28.68%
#     Worker 0: Train Loss: 2.9902, Train Accuracy: 26.12%
#     Worker 1: Train Loss: 2.9523, Train Accuracy: 26.53%
#     Worker 2: Train Loss: 2.9725, Train Accuracy: 26.75%
#     Worker 3: Train Loss: 3.0093, Train Accuracy: 25.90%
#     Worker 4: Train Loss: 2.9329, Train Accuracy: 27.56%
#     Worker 5: Train Loss: 2.9581, Train Accuracy: 26.54%
#     Worker 6: Train Loss: 3.0179, Train Accuracy: 25.51%
#     Worker 7: Train Loss: 2.9911, Train Accuracy: 25.93%
# Epoch 18/150: Test Loss: 2.8521, Test Accuracy: 29.77%
#     Worker 0: Train Loss: 2.9166, Train Accuracy: 28.13%
#     Worker 1: Train Loss: 2.9376, Train Accuracy: 26.62%
#     Worker 2: Train Loss: 2.9314, Train Accuracy: 27.52%
#     Worker 3: Train Loss: 2.9689, Train Accuracy: 26.04%
#     Worker 4: Train Loss: 2.9296, Train Accuracy: 26.75%
#     Worker 5: Train Loss: 2.9188, Train Accuracy: 27.33%
#     Worker 6: Train Loss: 2.9514, Train Accuracy: 26.67%
#     Worker 7: Train Loss: 2.9142, Train Accuracy: 27.70%
# Epoch 19/150: Test Loss: 2.7647, Test Accuracy: 31.45%
#     Worker 0: Train Loss: 2.8867, Train Accuracy: 26.86%
#     Worker 1: Train Loss: 2.8700, Train Accuracy: 28.36%
#     Worker 2: Train Loss: 2.9183, Train Accuracy: 27.56%
#     Worker 3: Train Loss: 2.9062, Train Accuracy: 27.78%
#     Worker 4: Train Loss: 2.8781, Train Accuracy: 28.52%
#     Worker 5: Train Loss: 2.8376, Train Accuracy: 29.70%
#     Worker 6: Train Loss: 2.9096, Train Accuracy: 26.89%
#     Worker 7: Train Loss: 2.8622, Train Accuracy: 28.60%
# Epoch 20/150: Test Loss: 2.7414, Test Accuracy: 31.74%
#     Worker 0: Train Loss: 2.8481, Train Accuracy: 28.69%
#     Worker 1: Train Loss: 2.8099, Train Accuracy: 28.49%
#     Worker 2: Train Loss: 2.8520, Train Accuracy: 29.19%
#     Worker 3: Train Loss: 2.8413, Train Accuracy: 28.61%
#     Worker 4: Train Loss: 2.7799, Train Accuracy: 29.88%
#     Worker 5: Train Loss: 2.8015, Train Accuracy: 30.28%
#     Worker 6: Train Loss: 2.8457, Train Accuracy: 28.46%
#     Worker 7: Train Loss: 2.8749, Train Accuracy: 28.24%
# Epoch 21/150: Test Loss: 2.6986, Test Accuracy: 32.74%
#     Worker 0: Train Loss: 2.8334, Train Accuracy: 29.46%
#     Worker 1: Train Loss: 2.7545, Train Accuracy: 29.98%
#     Worker 2: Train Loss: 2.8019, Train Accuracy: 30.40%
#     Worker 3: Train Loss: 2.8466, Train Accuracy: 29.12%
#     Worker 4: Train Loss: 2.7703, Train Accuracy: 30.13%
#     Worker 5: Train Loss: 2.7495, Train Accuracy: 30.45%
#     Worker 6: Train Loss: 2.8154, Train Accuracy: 29.46%
#     Worker 7: Train Loss: 2.8000, Train Accuracy: 30.35%
# Epoch 22/150: Test Loss: 2.6289, Test Accuracy: 33.84%
#     Worker 0: Train Loss: 2.7508, Train Accuracy: 30.71%
#     Worker 1: Train Loss: 2.7327, Train Accuracy: 30.76%
#     Worker 2: Train Loss: 2.7711, Train Accuracy: 30.50%
#     Worker 3: Train Loss: 2.7515, Train Accuracy: 29.76%
#     Worker 4: Train Loss: 2.7291, Train Accuracy: 31.33%
#     Worker 5: Train Loss: 2.7464, Train Accuracy: 31.36%
#     Worker 6: Train Loss: 2.7599, Train Accuracy: 30.56%
#     Worker 7: Train Loss: 2.7440, Train Accuracy: 31.34%
# Epoch 23/150: Test Loss: 2.6085, Test Accuracy: 34.27%
#     Worker 0: Train Loss: 2.6947, Train Accuracy: 31.19%
#     Worker 1: Train Loss: 2.6759, Train Accuracy: 31.69%
#     Worker 2: Train Loss: 2.7006, Train Accuracy: 31.22%
#     Worker 3: Train Loss: 2.7432, Train Accuracy: 30.39%
#     Worker 4: Train Loss: 2.6693, Train Accuracy: 32.63%
#     Worker 5: Train Loss: 2.6462, Train Accuracy: 32.97%
#     Worker 6: Train Loss: 2.7066, Train Accuracy: 31.44%
#     Worker 7: Train Loss: 2.7013, Train Accuracy: 31.84%
# Epoch 24/150: Test Loss: 2.5678, Test Accuracy: 35.45%
#     Worker 0: Train Loss: 2.6761, Train Accuracy: 32.16%
#     Worker 1: Train Loss: 2.6620, Train Accuracy: 32.46%
#     Worker 2: Train Loss: 2.6771, Train Accuracy: 32.44%
#     Worker 3: Train Loss: 2.6903, Train Accuracy: 31.75%
#     Worker 4: Train Loss: 2.6510, Train Accuracy: 32.11%
#     Worker 5: Train Loss: 2.6442, Train Accuracy: 32.46%
#     Worker 6: Train Loss: 2.6943, Train Accuracy: 31.25%
#     Worker 7: Train Loss: 2.6509, Train Accuracy: 32.24%
# Epoch 25/150: Test Loss: 2.5362, Test Accuracy: 35.64%
#     Worker 0: Train Loss: 2.6499, Train Accuracy: 32.58%
#     Worker 1: Train Loss: 2.6024, Train Accuracy: 32.97%
#     Worker 2: Train Loss: 2.6306, Train Accuracy: 33.66%
#     Worker 3: Train Loss: 2.6741, Train Accuracy: 31.51%
#     Worker 4: Train Loss: 2.5630, Train Accuracy: 34.65%
#     Worker 5: Train Loss: 2.5918, Train Accuracy: 34.37%
#     Worker 6: Train Loss: 2.6647, Train Accuracy: 32.02%
#     Worker 7: Train Loss: 2.6393, Train Accuracy: 32.66%
# Epoch 26/150: Test Loss: 2.4812, Test Accuracy: 36.38%
#     Worker 0: Train Loss: 2.6380, Train Accuracy: 32.47%
#     Worker 1: Train Loss: 2.5474, Train Accuracy: 34.78%
#     Worker 2: Train Loss: 2.5823, Train Accuracy: 34.20%
#     Worker 3: Train Loss: 2.5895, Train Accuracy: 33.91%
#     Worker 4: Train Loss: 2.5648, Train Accuracy: 34.68%
#     Worker 5: Train Loss: 2.5698, Train Accuracy: 34.93%
#     Worker 6: Train Loss: 2.5974, Train Accuracy: 33.54%
#     Worker 7: Train Loss: 2.5689, Train Accuracy: 33.94%
# Epoch 27/150: Test Loss: 2.4721, Test Accuracy: 37.20%
#     Worker 0: Train Loss: 2.5504, Train Accuracy: 34.31%
#     Worker 1: Train Loss: 2.5421, Train Accuracy: 34.76%
#     Worker 2: Train Loss: 2.5634, Train Accuracy: 34.63%
#     Worker 3: Train Loss: 2.5924, Train Accuracy: 34.12%
#     Worker 4: Train Loss: 2.5139, Train Accuracy: 35.43%
#     Worker 5: Train Loss: 2.5165, Train Accuracy: 36.39%
#     Worker 6: Train Loss: 2.5902, Train Accuracy: 34.10%
#     Worker 7: Train Loss: 2.5463, Train Accuracy: 35.00%
# Epoch 28/150: Test Loss: 2.4559, Test Accuracy: 37.13%
#     Worker 0: Train Loss: 2.5564, Train Accuracy: 33.29%
#     Worker 1: Train Loss: 2.5273, Train Accuracy: 35.36%
#     Worker 2: Train Loss: 2.5319, Train Accuracy: 35.37%
#     Worker 3: Train Loss: 2.5506, Train Accuracy: 34.52%
#     Worker 4: Train Loss: 2.5127, Train Accuracy: 35.58%
#     Worker 5: Train Loss: 2.5013, Train Accuracy: 35.78%
#     Worker 6: Train Loss: 2.5185, Train Accuracy: 34.65%
#     Worker 7: Train Loss: 2.5583, Train Accuracy: 34.87%
# Epoch 29/150: Test Loss: 2.4608, Test Accuracy: 37.70%
#     Worker 0: Train Loss: 2.4852, Train Accuracy: 35.87%
#     Worker 1: Train Loss: 2.4714, Train Accuracy: 36.27%
#     Worker 2: Train Loss: 2.4942, Train Accuracy: 35.86%
#     Worker 3: Train Loss: 2.4999, Train Accuracy: 35.62%
#     Worker 4: Train Loss: 2.4860, Train Accuracy: 36.23%
#     Worker 5: Train Loss: 2.4510, Train Accuracy: 36.42%
#     Worker 6: Train Loss: 2.5016, Train Accuracy: 35.26%
#     Worker 7: Train Loss: 2.4703, Train Accuracy: 36.20%
# Epoch 30/150: Test Loss: 2.3884, Test Accuracy: 38.69%
#     Worker 0: Train Loss: 2.4858, Train Accuracy: 35.90%
#     Worker 1: Train Loss: 2.4310, Train Accuracy: 37.13%
#     Worker 2: Train Loss: 2.4777, Train Accuracy: 35.95%
#     Worker 3: Train Loss: 2.4852, Train Accuracy: 35.00%
#     Worker 4: Train Loss: 2.4629, Train Accuracy: 36.20%
#     Worker 5: Train Loss: 2.4427, Train Accuracy: 37.52%
#     Worker 6: Train Loss: 2.4884, Train Accuracy: 36.64%
#     Worker 7: Train Loss: 2.4721, Train Accuracy: 35.90%
# Epoch 31/150: Test Loss: 2.3713, Test Accuracy: 39.29%
#     Worker 0: Train Loss: 2.4325, Train Accuracy: 37.16%
#     Worker 1: Train Loss: 2.4014, Train Accuracy: 38.12%
#     Worker 2: Train Loss: 2.4162, Train Accuracy: 37.55%
#     Worker 3: Train Loss: 2.4761, Train Accuracy: 36.38%
#     Worker 4: Train Loss: 2.3647, Train Accuracy: 38.73%
#     Worker 5: Train Loss: 2.3661, Train Accuracy: 38.55%
#     Worker 6: Train Loss: 2.4145, Train Accuracy: 37.03%
#     Worker 7: Train Loss: 2.4380, Train Accuracy: 36.80%
# Epoch 32/150: Test Loss: 2.3766, Test Accuracy: 38.88%
#     Worker 0: Train Loss: 2.4178, Train Accuracy: 37.35%
#     Worker 1: Train Loss: 2.4072, Train Accuracy: 37.25%
#     Worker 2: Train Loss: 2.4004, Train Accuracy: 36.53%
#     Worker 3: Train Loss: 2.4229, Train Accuracy: 36.55%
#     Worker 4: Train Loss: 2.3720, Train Accuracy: 38.30%
#     Worker 5: Train Loss: 2.3912, Train Accuracy: 38.79%
#     Worker 6: Train Loss: 2.4300, Train Accuracy: 36.89%
#     Worker 7: Train Loss: 2.3967, Train Accuracy: 37.06%
# Epoch 33/150: Test Loss: 2.3241, Test Accuracy: 40.36%
#     Worker 0: Train Loss: 2.3971, Train Accuracy: 38.13%
#     Worker 1: Train Loss: 2.3475, Train Accuracy: 38.27%
#     Worker 2: Train Loss: 2.4002, Train Accuracy: 38.07%
#     Worker 3: Train Loss: 2.3662, Train Accuracy: 38.24%
#     Worker 4: Train Loss: 2.3270, Train Accuracy: 38.73%
#     Worker 5: Train Loss: 2.3410, Train Accuracy: 39.28%
#     Worker 6: Train Loss: 2.4022, Train Accuracy: 37.38%
#     Worker 7: Train Loss: 2.3776, Train Accuracy: 38.48%
# Epoch 34/150: Test Loss: 2.3081, Test Accuracy: 40.36%
#     Worker 0: Train Loss: 2.3799, Train Accuracy: 37.97%
#     Worker 1: Train Loss: 2.3212, Train Accuracy: 39.53%
#     Worker 2: Train Loss: 2.3219, Train Accuracy: 39.71%
#     Worker 3: Train Loss: 2.3589, Train Accuracy: 38.95%
#     Worker 4: Train Loss: 2.3153, Train Accuracy: 39.34%
#     Worker 5: Train Loss: 2.3814, Train Accuracy: 38.82%
#     Worker 6: Train Loss: 2.3528, Train Accuracy: 38.63%
#     Worker 7: Train Loss: 2.3556, Train Accuracy: 38.95%
# Epoch 35/150: Test Loss: 2.2972, Test Accuracy: 40.84%
#     Worker 0: Train Loss: 2.3215, Train Accuracy: 39.35%
#     Worker 1: Train Loss: 2.3024, Train Accuracy: 39.54%
#     Worker 2: Train Loss: 2.3245, Train Accuracy: 39.59%
#     Worker 3: Train Loss: 2.3611, Train Accuracy: 37.71%
#     Worker 4: Train Loss: 2.2999, Train Accuracy: 40.25%
#     Worker 5: Train Loss: 2.3000, Train Accuracy: 39.67%
#     Worker 6: Train Loss: 2.3331, Train Accuracy: 39.46%
#     Worker 7: Train Loss: 2.3144, Train Accuracy: 39.73%
# Epoch 36/150: Test Loss: 2.2849, Test Accuracy: 40.88%
#     Worker 0: Train Loss: 2.3081, Train Accuracy: 39.68%
#     Worker 1: Train Loss: 2.2813, Train Accuracy: 39.79%
#     Worker 2: Train Loss: 2.2840, Train Accuracy: 39.67%
#     Worker 3: Train Loss: 2.2992, Train Accuracy: 39.39%
#     Worker 4: Train Loss: 2.3033, Train Accuracy: 39.65%
#     Worker 5: Train Loss: 2.2777, Train Accuracy: 40.59%
#     Worker 6: Train Loss: 2.3169, Train Accuracy: 39.43%
#     Worker 7: Train Loss: 2.3022, Train Accuracy: 39.93%
# Epoch 37/150: Test Loss: 2.2447, Test Accuracy: 41.84%
#     Worker 0: Train Loss: 2.3028, Train Accuracy: 39.46%
#     Worker 1: Train Loss: 2.2476, Train Accuracy: 40.50%
#     Worker 2: Train Loss: 2.2846, Train Accuracy: 40.59%
#     Worker 3: Train Loss: 2.2771, Train Accuracy: 40.50%
#     Worker 4: Train Loss: 2.2405, Train Accuracy: 41.83%
#     Worker 5: Train Loss: 2.2329, Train Accuracy: 41.83%
#     Worker 6: Train Loss: 2.2692, Train Accuracy: 41.24%
#     Worker 7: Train Loss: 2.2795, Train Accuracy: 40.03%
# Epoch 38/150: Test Loss: 2.2598, Test Accuracy: 41.74%
#     Worker 0: Train Loss: 2.2637, Train Accuracy: 40.40%
#     Worker 1: Train Loss: 2.2364, Train Accuracy: 41.44%
#     Worker 2: Train Loss: 2.2469, Train Accuracy: 41.11%
#     Worker 3: Train Loss: 2.3145, Train Accuracy: 40.12%
#     Worker 4: Train Loss: 2.2055, Train Accuracy: 42.44%
#     Worker 5: Train Loss: 2.2276, Train Accuracy: 41.56%
#     Worker 6: Train Loss: 2.2760, Train Accuracy: 40.39%
#     Worker 7: Train Loss: 2.2530, Train Accuracy: 40.84%
# Epoch 39/150: Test Loss: 2.2266, Test Accuracy: 42.68%
#     Worker 0: Train Loss: 2.2260, Train Accuracy: 41.16%
#     Worker 1: Train Loss: 2.2050, Train Accuracy: 41.61%
#     Worker 2: Train Loss: 2.2292, Train Accuracy: 41.39%
#     Worker 3: Train Loss: 2.2419, Train Accuracy: 40.31%
#     Worker 4: Train Loss: 2.1983, Train Accuracy: 42.02%
#     Worker 5: Train Loss: 2.2184, Train Accuracy: 42.87%
#     Worker 6: Train Loss: 2.2497, Train Accuracy: 41.08%
#     Worker 7: Train Loss: 2.2334, Train Accuracy: 41.49%
# Epoch 40/150: Test Loss: 2.2167, Test Accuracy: 42.51%
#     Worker 0: Train Loss: 2.2015, Train Accuracy: 41.86%
#     Worker 1: Train Loss: 2.1958, Train Accuracy: 41.89%
#     Worker 2: Train Loss: 2.2003, Train Accuracy: 42.33%
#     Worker 3: Train Loss: 2.2042, Train Accuracy: 41.96%
#     Worker 4: Train Loss: 2.1530, Train Accuracy: 43.10%
#     Worker 5: Train Loss: 2.1884, Train Accuracy: 42.72%
#     Worker 6: Train Loss: 2.2290, Train Accuracy: 41.39%
#     Worker 7: Train Loss: 2.2006, Train Accuracy: 42.04%
# Epoch 41/150: Test Loss: 2.1908, Test Accuracy: 43.20%
#     Worker 0: Train Loss: 2.2043, Train Accuracy: 41.69%
#     Worker 1: Train Loss: 2.1515, Train Accuracy: 42.80%
#     Worker 2: Train Loss: 2.1595, Train Accuracy: 42.83%
#     Worker 3: Train Loss: 2.1973, Train Accuracy: 42.49%
#     Worker 4: Train Loss: 2.1259, Train Accuracy: 43.82%
#     Worker 5: Train Loss: 2.1775, Train Accuracy: 42.80%
#     Worker 6: Train Loss: 2.1675, Train Accuracy: 42.47%
#     Worker 7: Train Loss: 2.1853, Train Accuracy: 41.93%
# Epoch 42/150: Test Loss: 2.1924, Test Accuracy: 43.32%
#     Worker 0: Train Loss: 2.1595, Train Accuracy: 43.16%
#     Worker 1: Train Loss: 2.1333, Train Accuracy: 43.09%
#     Worker 2: Train Loss: 2.1685, Train Accuracy: 42.46%
#     Worker 3: Train Loss: 2.2070, Train Accuracy: 41.52%
#     Worker 4: Train Loss: 2.1498, Train Accuracy: 43.23%
#     Worker 5: Train Loss: 2.1204, Train Accuracy: 45.03%
#     Worker 6: Train Loss: 2.1729, Train Accuracy: 43.09%
#     Worker 7: Train Loss: 2.1752, Train Accuracy: 42.96%
# Epoch 43/150: Test Loss: 2.1823, Test Accuracy: 43.63%
#     Worker 0: Train Loss: 2.1526, Train Accuracy: 42.87%
#     Worker 1: Train Loss: 2.1230, Train Accuracy: 43.96%
#     Worker 2: Train Loss: 2.1190, Train Accuracy: 43.78%
#     Worker 3: Train Loss: 2.1419, Train Accuracy: 42.83%
#     Worker 4: Train Loss: 2.1000, Train Accuracy: 44.56%
#     Worker 5: Train Loss: 2.1093, Train Accuracy: 44.76%
#     Worker 6: Train Loss: 2.1588, Train Accuracy: 43.34%
#     Worker 7: Train Loss: 2.1239, Train Accuracy: 43.90%
# Epoch 44/150: Test Loss: 2.1814, Test Accuracy: 43.00%
#     Worker 0: Train Loss: 2.1266, Train Accuracy: 43.78%
#     Worker 1: Train Loss: 2.1243, Train Accuracy: 43.84%
#     Worker 2: Train Loss: 2.1181, Train Accuracy: 43.51%
#     Worker 3: Train Loss: 2.1504, Train Accuracy: 43.89%
#     Worker 4: Train Loss: 2.0932, Train Accuracy: 43.98%
#     Worker 5: Train Loss: 2.0969, Train Accuracy: 44.54%
#     Worker 6: Train Loss: 2.1171, Train Accuracy: 43.98%
#     Worker 7: Train Loss: 2.0986, Train Accuracy: 44.21%
# Epoch 45/150: Test Loss: 2.1585, Test Accuracy: 44.02%
#     Worker 0: Train Loss: 2.1031, Train Accuracy: 43.18%
#     Worker 1: Train Loss: 2.0683, Train Accuracy: 44.79%
#     Worker 2: Train Loss: 2.0939, Train Accuracy: 44.73%
#     Worker 3: Train Loss: 2.1164, Train Accuracy: 43.85%
#     Worker 4: Train Loss: 2.0910, Train Accuracy: 44.61%
#     Worker 5: Train Loss: 2.0960, Train Accuracy: 44.64%
#     Worker 6: Train Loss: 2.1364, Train Accuracy: 44.28%
#     Worker 7: Train Loss: 2.1226, Train Accuracy: 44.06%
# Epoch 46/150: Test Loss: 2.1573, Test Accuracy: 44.38%
#     Worker 0: Train Loss: 2.1022, Train Accuracy: 43.35%
#     Worker 1: Train Loss: 2.0658, Train Accuracy: 45.11%
#     Worker 2: Train Loss: 2.0766, Train Accuracy: 44.54%
#     Worker 3: Train Loss: 2.1045, Train Accuracy: 43.82%
#     Worker 4: Train Loss: 2.0413, Train Accuracy: 45.64%
#     Worker 5: Train Loss: 2.0435, Train Accuracy: 45.69%
#     Worker 6: Train Loss: 2.1017, Train Accuracy: 44.20%
#     Worker 7: Train Loss: 2.0760, Train Accuracy: 44.92%
# Epoch 47/150: Test Loss: 2.1469, Test Accuracy: 44.56%
#     Worker 0: Train Loss: 2.0864, Train Accuracy: 44.36%
#     Worker 1: Train Loss: 2.0344, Train Accuracy: 45.45%
#     Worker 2: Train Loss: 2.0476, Train Accuracy: 45.74%
#     Worker 3: Train Loss: 2.0643, Train Accuracy: 44.92%
#     Worker 4: Train Loss: 2.0480, Train Accuracy: 45.48%
#     Worker 5: Train Loss: 2.0531, Train Accuracy: 45.52%
#     Worker 6: Train Loss: 2.0587, Train Accuracy: 44.72%
#     Worker 7: Train Loss: 2.0740, Train Accuracy: 44.79%
# Epoch 48/150: Test Loss: 2.1247, Test Accuracy: 44.48%
#     Worker 0: Train Loss: 2.0662, Train Accuracy: 44.79%
#     Worker 1: Train Loss: 2.0314, Train Accuracy: 45.39%
#     Worker 2: Train Loss: 2.0183, Train Accuracy: 45.78%
#     Worker 3: Train Loss: 2.0599, Train Accuracy: 44.64%
#     Worker 4: Train Loss: 2.0127, Train Accuracy: 46.64%
#     Worker 5: Train Loss: 2.0437, Train Accuracy: 46.05%
#     Worker 6: Train Loss: 2.0692, Train Accuracy: 44.43%
#     Worker 7: Train Loss: 2.0493, Train Accuracy: 45.80%
# Epoch 49/150: Test Loss: 2.1118, Test Accuracy: 45.31%
#     Worker 0: Train Loss: 2.0389, Train Accuracy: 44.93%
#     Worker 1: Train Loss: 2.0056, Train Accuracy: 46.16%
#     Worker 2: Train Loss: 2.0225, Train Accuracy: 45.59%
#     Worker 3: Train Loss: 2.0436, Train Accuracy: 45.15%
#     Worker 4: Train Loss: 2.0035, Train Accuracy: 46.46%
#     Worker 5: Train Loss: 2.0031, Train Accuracy: 46.37%
#     Worker 6: Train Loss: 2.0379, Train Accuracy: 45.69%
#     Worker 7: Train Loss: 2.0210, Train Accuracy: 46.07%
# Epoch 50/150: Test Loss: 2.1270, Test Accuracy: 44.61%
#     Worker 0: Train Loss: 2.0308, Train Accuracy: 44.97%
#     Worker 1: Train Loss: 1.9732, Train Accuracy: 46.52%
#     Worker 2: Train Loss: 1.9990, Train Accuracy: 46.52%
#     Worker 3: Train Loss: 2.0138, Train Accuracy: 45.72%
#     Worker 4: Train Loss: 1.9888, Train Accuracy: 47.13%
#     Worker 5: Train Loss: 1.9992, Train Accuracy: 46.50%
#     Worker 6: Train Loss: 2.0271, Train Accuracy: 46.22%
#     Worker 7: Train Loss: 2.0079, Train Accuracy: 46.57%
# Epoch 51/150: Test Loss: 2.1031, Test Accuracy: 45.22%
#     Worker 0: Train Loss: 2.0040, Train Accuracy: 46.52%
#     Worker 1: Train Loss: 1.9884, Train Accuracy: 47.30%
#     Worker 2: Train Loss: 1.9775, Train Accuracy: 46.97%
#     Worker 3: Train Loss: 2.0005, Train Accuracy: 46.44%
#     Worker 4: Train Loss: 1.9631, Train Accuracy: 47.24%
#     Worker 5: Train Loss: 1.9721, Train Accuracy: 48.12%
#     Worker 6: Train Loss: 2.0075, Train Accuracy: 46.21%
#     Worker 7: Train Loss: 1.9920, Train Accuracy: 46.80%
# Epoch 52/150: Test Loss: 2.0990, Test Accuracy: 45.35%
#     Worker 0: Train Loss: 2.0073, Train Accuracy: 45.91%
#     Worker 1: Train Loss: 1.9537, Train Accuracy: 47.18%
#     Worker 2: Train Loss: 1.9546, Train Accuracy: 47.02%
#     Worker 3: Train Loss: 1.9803, Train Accuracy: 47.51%
#     Worker 4: Train Loss: 1.9274, Train Accuracy: 48.29%
#     Worker 5: Train Loss: 1.9517, Train Accuracy: 48.10%
#     Worker 6: Train Loss: 1.9711, Train Accuracy: 46.99%
#     Worker 7: Train Loss: 1.9853, Train Accuracy: 47.13%
# Epoch 53/150: Test Loss: 2.0966, Test Accuracy: 45.84%
#     Worker 0: Train Loss: 1.9712, Train Accuracy: 47.13%
#     Worker 1: Train Loss: 1.9330, Train Accuracy: 47.40%
#     Worker 2: Train Loss: 1.9446, Train Accuracy: 47.38%
#     Worker 3: Train Loss: 1.9749, Train Accuracy: 47.22%
#     Worker 4: Train Loss: 1.9336, Train Accuracy: 48.31%
#     Worker 5: Train Loss: 1.9616, Train Accuracy: 48.13%
#     Worker 6: Train Loss: 1.9604, Train Accuracy: 47.54%
#     Worker 7: Train Loss: 1.9356, Train Accuracy: 47.82%
# Epoch 54/150: Test Loss: 2.0757, Test Accuracy: 45.87%
#     Worker 0: Train Loss: 1.9648, Train Accuracy: 46.99%
#     Worker 1: Train Loss: 1.9472, Train Accuracy: 47.12%
#     Worker 2: Train Loss: 1.9074, Train Accuracy: 48.87%
#     Worker 3: Train Loss: 1.9473, Train Accuracy: 47.84%
#     Worker 4: Train Loss: 1.9029, Train Accuracy: 48.78%
#     Worker 5: Train Loss: 1.9303, Train Accuracy: 48.42%
#     Worker 6: Train Loss: 1.9694, Train Accuracy: 47.63%
#     Worker 7: Train Loss: 1.9332, Train Accuracy: 47.51%
# Epoch 55/150: Test Loss: 2.0751, Test Accuracy: 45.94%
#     Worker 0: Train Loss: 1.9364, Train Accuracy: 47.57%
#     Worker 1: Train Loss: 1.9153, Train Accuracy: 48.31%
#     Worker 2: Train Loss: 1.9086, Train Accuracy: 48.68%
#     Worker 3: Train Loss: 1.9491, Train Accuracy: 47.22%
#     Worker 4: Train Loss: 1.9360, Train Accuracy: 47.80%
#     Worker 5: Train Loss: 1.9038, Train Accuracy: 49.42%
#     Worker 6: Train Loss: 1.9320, Train Accuracy: 47.44%
#     Worker 7: Train Loss: 1.9362, Train Accuracy: 47.91%
# Epoch 56/150: Test Loss: 2.0682, Test Accuracy: 46.15%
#     Worker 0: Train Loss: 1.9003, Train Accuracy: 48.26%
#     Worker 1: Train Loss: 1.8807, Train Accuracy: 48.73%
#     Worker 2: Train Loss: 1.9075, Train Accuracy: 48.45%
#     Worker 3: Train Loss: 1.9364, Train Accuracy: 47.26%
#     Worker 4: Train Loss: 1.8822, Train Accuracy: 49.64%
#     Worker 5: Train Loss: 1.8758, Train Accuracy: 48.81%
#     Worker 6: Train Loss: 1.9227, Train Accuracy: 48.64%
#     Worker 7: Train Loss: 1.9073, Train Accuracy: 48.79%
# Epoch 57/150: Test Loss: 2.0621, Test Accuracy: 46.06%
#     Worker 0: Train Loss: 1.8945, Train Accuracy: 48.53%
#     Worker 1: Train Loss: 1.8905, Train Accuracy: 48.97%
#     Worker 2: Train Loss: 1.8927, Train Accuracy: 49.95%
#     Worker 3: Train Loss: 1.9161, Train Accuracy: 48.39%
#     Worker 4: Train Loss: 1.8708, Train Accuracy: 49.61%
#     Worker 5: Train Loss: 1.8952, Train Accuracy: 49.09%
#     Worker 6: Train Loss: 1.8978, Train Accuracy: 48.57%
#     Worker 7: Train Loss: 1.8829, Train Accuracy: 49.34%
# Epoch 58/150: Test Loss: 2.0624, Test Accuracy: 46.75%
#     Worker 0: Train Loss: 1.8671, Train Accuracy: 49.14%
#     Worker 1: Train Loss: 1.8458, Train Accuracy: 50.11%
#     Worker 2: Train Loss: 1.8701, Train Accuracy: 49.92%
#     Worker 3: Train Loss: 1.8827, Train Accuracy: 49.50%
#     Worker 4: Train Loss: 1.8691, Train Accuracy: 49.53%
#     Worker 5: Train Loss: 1.8722, Train Accuracy: 49.45%
#     Worker 6: Train Loss: 1.8842, Train Accuracy: 49.07%
#     Worker 7: Train Loss: 1.8683, Train Accuracy: 49.50%
# Epoch 59/150: Test Loss: 2.0573, Test Accuracy: 46.61%
#     Worker 0: Train Loss: 1.8807, Train Accuracy: 48.32%
#     Worker 1: Train Loss: 1.8521, Train Accuracy: 48.98%
#     Worker 2: Train Loss: 1.8394, Train Accuracy: 50.02%
#     Worker 3: Train Loss: 1.8638, Train Accuracy: 49.25%
#     Worker 4: Train Loss: 1.8173, Train Accuracy: 50.97%
#     Worker 5: Train Loss: 1.8365, Train Accuracy: 50.50%
#     Worker 6: Train Loss: 1.8606, Train Accuracy: 49.31%
#     Worker 7: Train Loss: 1.8361, Train Accuracy: 50.49%
# Epoch 60/150: Test Loss: 2.0782, Test Accuracy: 46.21%
#     Worker 0: Train Loss: 1.8638, Train Accuracy: 50.13%
#     Worker 1: Train Loss: 1.8332, Train Accuracy: 50.96%
#     Worker 2: Train Loss: 1.8709, Train Accuracy: 49.94%
#     Worker 3: Train Loss: 1.8518, Train Accuracy: 49.58%
#     Worker 4: Train Loss: 1.8212, Train Accuracy: 50.16%
#     Worker 5: Train Loss: 1.8515, Train Accuracy: 50.30%
#     Worker 6: Train Loss: 1.8560, Train Accuracy: 49.69%
#     Worker 7: Train Loss: 1.8467, Train Accuracy: 49.50%
# Epoch 61/150: Test Loss: 2.0411, Test Accuracy: 47.08%
#     Worker 0: Train Loss: 1.8493, Train Accuracy: 49.97%
#     Worker 1: Train Loss: 1.7937, Train Accuracy: 51.38%
#     Worker 2: Train Loss: 1.8016, Train Accuracy: 51.19%
#     Worker 3: Train Loss: 1.8525, Train Accuracy: 49.34%
#     Worker 4: Train Loss: 1.8193, Train Accuracy: 49.83%
#     Worker 5: Train Loss: 1.8400, Train Accuracy: 50.75%
#     Worker 6: Train Loss: 1.8406, Train Accuracy: 50.06%
#     Worker 7: Train Loss: 1.7880, Train Accuracy: 50.88%
# Epoch 62/150: Test Loss: 2.0551, Test Accuracy: 46.70%
#     Worker 0: Train Loss: 1.8183, Train Accuracy: 50.09%
#     Worker 1: Train Loss: 1.7857, Train Accuracy: 50.80%
#     Worker 2: Train Loss: 1.8223, Train Accuracy: 49.95%
#     Worker 3: Train Loss: 1.8549, Train Accuracy: 49.84%
#     Worker 4: Train Loss: 1.7880, Train Accuracy: 51.13%
#     Worker 5: Train Loss: 1.8084, Train Accuracy: 51.43%
#     Worker 6: Train Loss: 1.8343, Train Accuracy: 50.93%
#     Worker 7: Train Loss: 1.8015, Train Accuracy: 50.63%
# Epoch 63/150: Test Loss: 2.0420, Test Accuracy: 47.04%
#     Worker 0: Train Loss: 1.8250, Train Accuracy: 50.78%
#     Worker 1: Train Loss: 1.8005, Train Accuracy: 50.02%
#     Worker 2: Train Loss: 1.7835, Train Accuracy: 51.74%
#     Worker 3: Train Loss: 1.8026, Train Accuracy: 50.93%
#     Worker 4: Train Loss: 1.7593, Train Accuracy: 50.89%
#     Worker 5: Train Loss: 1.8102, Train Accuracy: 50.61%
#     Worker 6: Train Loss: 1.8176, Train Accuracy: 50.80%
#     Worker 7: Train Loss: 1.8031, Train Accuracy: 51.13%
# Epoch 64/150: Test Loss: 2.0433, Test Accuracy: 46.88%
#     Worker 0: Train Loss: 1.8227, Train Accuracy: 49.84%
#     Worker 1: Train Loss: 1.7746, Train Accuracy: 51.98%
#     Worker 2: Train Loss: 1.7717, Train Accuracy: 51.87%
#     Worker 3: Train Loss: 1.8334, Train Accuracy: 50.50%
#     Worker 4: Train Loss: 1.7708, Train Accuracy: 51.98%
#     Worker 5: Train Loss: 1.7605, Train Accuracy: 52.35%
#     Worker 6: Train Loss: 1.8079, Train Accuracy: 50.61%
#     Worker 7: Train Loss: 1.8100, Train Accuracy: 50.88%
# Epoch 65/150: Test Loss: 2.0419, Test Accuracy: 47.27%
#     Worker 0: Train Loss: 1.7580, Train Accuracy: 52.04%
#     Worker 1: Train Loss: 1.7683, Train Accuracy: 51.05%
#     Worker 2: Train Loss: 1.7714, Train Accuracy: 51.76%
#     Worker 3: Train Loss: 1.8093, Train Accuracy: 50.36%
#     Worker 4: Train Loss: 1.8021, Train Accuracy: 51.11%
#     Worker 5: Train Loss: 1.7958, Train Accuracy: 51.49%
#     Worker 6: Train Loss: 1.7868, Train Accuracy: 51.38%
#     Worker 7: Train Loss: 1.7473, Train Accuracy: 52.73%
# Epoch 66/150: Test Loss: 2.0268, Test Accuracy: 48.10%
#     Worker 0: Train Loss: 1.7827, Train Accuracy: 51.40%
#     Worker 1: Train Loss: 1.7499, Train Accuracy: 51.54%
#     Worker 2: Train Loss: 1.7430, Train Accuracy: 52.71%
#     Worker 3: Train Loss: 1.7871, Train Accuracy: 51.22%
#     Worker 4: Train Loss: 1.7047, Train Accuracy: 52.90%
#     Worker 5: Train Loss: 1.7415, Train Accuracy: 52.16%
#     Worker 6: Train Loss: 1.7775, Train Accuracy: 51.52%
#     Worker 7: Train Loss: 1.7562, Train Accuracy: 52.27%
# Epoch 67/150: Test Loss: 2.0419, Test Accuracy: 47.30%
#     Worker 0: Train Loss: 1.7527, Train Accuracy: 52.10%
#     Worker 1: Train Loss: 1.7238, Train Accuracy: 52.60%
#     Worker 2: Train Loss: 1.7801, Train Accuracy: 51.76%
#     Worker 3: Train Loss: 1.7579, Train Accuracy: 51.98%
#     Worker 4: Train Loss: 1.7377, Train Accuracy: 52.34%
#     Worker 5: Train Loss: 1.7328, Train Accuracy: 53.01%
#     Worker 6: Train Loss: 1.7574, Train Accuracy: 51.74%
#     Worker 7: Train Loss: 1.7268, Train Accuracy: 52.67%
# Epoch 68/150: Test Loss: 2.0194, Test Accuracy: 47.80%
#     Worker 0: Train Loss: 1.7604, Train Accuracy: 51.44%
#     Worker 1: Train Loss: 1.7226, Train Accuracy: 53.07%
#     Worker 2: Train Loss: 1.7222, Train Accuracy: 52.51%
#     Worker 3: Train Loss: 1.7676, Train Accuracy: 51.33%
#     Worker 4: Train Loss: 1.7052, Train Accuracy: 53.40%
#     Worker 5: Train Loss: 1.7204, Train Accuracy: 53.17%
#     Worker 6: Train Loss: 1.7539, Train Accuracy: 52.65%
#     Worker 7: Train Loss: 1.7444, Train Accuracy: 52.46%
# Epoch 69/150: Test Loss: 2.0150, Test Accuracy: 47.62%
#     Worker 0: Train Loss: 1.7227, Train Accuracy: 52.87%
#     Worker 1: Train Loss: 1.7033, Train Accuracy: 52.57%
#     Worker 2: Train Loss: 1.6782, Train Accuracy: 54.12%
#     Worker 3: Train Loss: 1.7301, Train Accuracy: 51.90%
#     Worker 4: Train Loss: 1.6996, Train Accuracy: 52.63%
#     Worker 5: Train Loss: 1.7128, Train Accuracy: 53.47%
#     Worker 6: Train Loss: 1.7497, Train Accuracy: 51.52%
#     Worker 7: Train Loss: 1.7128, Train Accuracy: 53.40%
# Epoch 70/150: Test Loss: 2.0170, Test Accuracy: 47.87%
#     Worker 0: Train Loss: 1.7464, Train Accuracy: 51.85%
#     Worker 1: Train Loss: 1.6935, Train Accuracy: 53.17%
#     Worker 2: Train Loss: 1.7037, Train Accuracy: 53.39%
#     Worker 3: Train Loss: 1.7581, Train Accuracy: 52.15%
#     Worker 4: Train Loss: 1.6819, Train Accuracy: 53.37%
#     Worker 5: Train Loss: 1.7062, Train Accuracy: 53.98%
#     Worker 6: Train Loss: 1.7127, Train Accuracy: 52.98%
#     Worker 7: Train Loss: 1.7022, Train Accuracy: 53.81%
# Epoch 71/150: Test Loss: 2.0183, Test Accuracy: 47.87%
#     Worker 0: Train Loss: 1.6914, Train Accuracy: 52.95%
#     Worker 1: Train Loss: 1.6634, Train Accuracy: 53.94%
#     Worker 2: Train Loss: 1.7013, Train Accuracy: 53.48%
#     Worker 3: Train Loss: 1.7165, Train Accuracy: 52.63%
#     Worker 4: Train Loss: 1.6695, Train Accuracy: 53.83%
#     Worker 5: Train Loss: 1.6685, Train Accuracy: 54.12%
#     Worker 6: Train Loss: 1.7174, Train Accuracy: 53.72%
#     Worker 7: Train Loss: 1.6945, Train Accuracy: 53.94%
# Epoch 72/150: Test Loss: 2.0045, Test Accuracy: 48.38%
#     Worker 0: Train Loss: 1.7070, Train Accuracy: 53.43%
#     Worker 1: Train Loss: 1.6522, Train Accuracy: 54.61%
#     Worker 2: Train Loss: 1.6908, Train Accuracy: 54.14%
#     Worker 3: Train Loss: 1.7174, Train Accuracy: 53.18%
#     Worker 4: Train Loss: 1.6597, Train Accuracy: 54.25%
#     Worker 5: Train Loss: 1.6709, Train Accuracy: 53.72%
#     Worker 6: Train Loss: 1.7067, Train Accuracy: 53.12%
#     Worker 7: Train Loss: 1.6757, Train Accuracy: 54.01%
# Epoch 73/150: Test Loss: 1.9894, Test Accuracy: 48.71%
#     Worker 0: Train Loss: 1.6761, Train Accuracy: 54.33%
#     Worker 1: Train Loss: 1.6659, Train Accuracy: 54.03%
#     Worker 2: Train Loss: 1.6410, Train Accuracy: 55.85%
#     Worker 3: Train Loss: 1.6850, Train Accuracy: 53.57%
#     Worker 4: Train Loss: 1.6607, Train Accuracy: 54.15%
#     Worker 5: Train Loss: 1.6512, Train Accuracy: 54.33%
#     Worker 6: Train Loss: 1.6928, Train Accuracy: 53.28%
#     Worker 7: Train Loss: 1.6676, Train Accuracy: 54.89%
# Epoch 74/150: Test Loss: 2.0120, Test Accuracy: 48.26%
#     Worker 0: Train Loss: 1.6760, Train Accuracy: 53.20%
#     Worker 1: Train Loss: 1.6315, Train Accuracy: 54.70%
#     Worker 2: Train Loss: 1.6524, Train Accuracy: 54.15%
#     Worker 3: Train Loss: 1.6576, Train Accuracy: 53.59%
#     Worker 4: Train Loss: 1.6437, Train Accuracy: 55.19%
#     Worker 5: Train Loss: 1.6321, Train Accuracy: 54.88%
#     Worker 6: Train Loss: 1.6702, Train Accuracy: 54.20%
#     Worker 7: Train Loss: 1.6417, Train Accuracy: 54.91%
# Epoch 75/150: Test Loss: 2.0041, Test Accuracy: 48.50%
#     Worker 0: Train Loss: 1.6719, Train Accuracy: 53.95%
#     Worker 1: Train Loss: 1.6331, Train Accuracy: 54.50%
#     Worker 2: Train Loss: 1.6135, Train Accuracy: 55.27%
#     Worker 3: Train Loss: 1.6689, Train Accuracy: 53.89%
#     Worker 4: Train Loss: 1.6266, Train Accuracy: 54.52%
#     Worker 5: Train Loss: 1.6664, Train Accuracy: 54.53%
#     Worker 6: Train Loss: 1.6583, Train Accuracy: 53.89%
#     Worker 7: Train Loss: 1.6314, Train Accuracy: 55.97%
# Epoch 76/150: Test Loss: 2.0045, Test Accuracy: 48.57%
#     Worker 0: Train Loss: 1.6247, Train Accuracy: 55.52%
#     Worker 1: Train Loss: 1.6413, Train Accuracy: 54.69%
#     Worker 2: Train Loss: 1.6346, Train Accuracy: 55.06%
#     Worker 3: Train Loss: 1.6540, Train Accuracy: 54.30%
#     Worker 4: Train Loss: 1.6288, Train Accuracy: 55.64%
#     Worker 5: Train Loss: 1.6211, Train Accuracy: 55.79%
#     Worker 6: Train Loss: 1.6719, Train Accuracy: 54.00%
#     Worker 7: Train Loss: 1.6316, Train Accuracy: 55.16%
# Epoch 77/150: Test Loss: 2.0085, Test Accuracy: 48.65%
#     Worker 0: Train Loss: 1.6564, Train Accuracy: 53.94%
#     Worker 1: Train Loss: 1.6189, Train Accuracy: 55.17%
#     Worker 2: Train Loss: 1.6000, Train Accuracy: 55.79%
#     Worker 3: Train Loss: 1.6485, Train Accuracy: 54.08%
#     Worker 4: Train Loss: 1.6004, Train Accuracy: 54.86%
#     Worker 5: Train Loss: 1.6111, Train Accuracy: 55.61%
#     Worker 6: Train Loss: 1.6732, Train Accuracy: 53.53%
#     Worker 7: Train Loss: 1.6332, Train Accuracy: 55.19%
# Epoch 78/150: Test Loss: 1.9958, Test Accuracy: 48.73%
#     Worker 0: Train Loss: 1.6166, Train Accuracy: 54.50%
#     Worker 1: Train Loss: 1.5631, Train Accuracy: 55.91%
#     Worker 2: Train Loss: 1.6008, Train Accuracy: 56.87%
#     Worker 3: Train Loss: 1.6336, Train Accuracy: 54.81%
#     Worker 4: Train Loss: 1.6038, Train Accuracy: 54.97%
#     Worker 5: Train Loss: 1.6048, Train Accuracy: 56.54%
#     Worker 6: Train Loss: 1.6592, Train Accuracy: 54.69%
#     Worker 7: Train Loss: 1.6200, Train Accuracy: 55.80%
# Epoch 79/150: Test Loss: 1.9857, Test Accuracy: 48.61%
#     Worker 0: Train Loss: 1.6143, Train Accuracy: 54.80%
#     Worker 1: Train Loss: 1.5980, Train Accuracy: 55.55%
#     Worker 2: Train Loss: 1.5770, Train Accuracy: 55.93%
#     Worker 3: Train Loss: 1.5952, Train Accuracy: 55.55%
#     Worker 4: Train Loss: 1.5775, Train Accuracy: 56.37%
#     Worker 5: Train Loss: 1.6048, Train Accuracy: 56.04%
#     Worker 6: Train Loss: 1.6140, Train Accuracy: 55.53%
#     Worker 7: Train Loss: 1.5955, Train Accuracy: 55.83%
# Epoch 80/150: Test Loss: 1.9828, Test Accuracy: 49.47%
#     Worker 0: Train Loss: 1.6006, Train Accuracy: 54.84%
#     Worker 1: Train Loss: 1.5683, Train Accuracy: 56.29%
#     Worker 2: Train Loss: 1.5790, Train Accuracy: 56.01%
#     Worker 3: Train Loss: 1.5927, Train Accuracy: 55.28%
#     Worker 4: Train Loss: 1.5901, Train Accuracy: 56.10%
#     Worker 5: Train Loss: 1.5878, Train Accuracy: 56.48%
#     Worker 6: Train Loss: 1.6214, Train Accuracy: 55.03%
#     Worker 7: Train Loss: 1.5783, Train Accuracy: 57.70%
# Epoch 81/150: Test Loss: 1.9998, Test Accuracy: 48.70%
#     Worker 0: Train Loss: 1.6090, Train Accuracy: 54.89%
#     Worker 1: Train Loss: 1.5353, Train Accuracy: 56.49%
#     Worker 2: Train Loss: 1.5607, Train Accuracy: 56.62%
#     Worker 3: Train Loss: 1.5952, Train Accuracy: 55.93%
#     Worker 4: Train Loss: 1.5431, Train Accuracy: 56.48%
#     Worker 5: Train Loss: 1.5485, Train Accuracy: 57.42%
#     Worker 6: Train Loss: 1.5911, Train Accuracy: 55.97%
#     Worker 7: Train Loss: 1.5896, Train Accuracy: 56.76%
# Epoch 82/150: Test Loss: 1.9933, Test Accuracy: 48.36%
#     Worker 0: Train Loss: 1.5815, Train Accuracy: 55.91%
#     Worker 1: Train Loss: 1.5549, Train Accuracy: 56.24%
#     Worker 2: Train Loss: 1.5658, Train Accuracy: 56.82%
#     Worker 3: Train Loss: 1.5800, Train Accuracy: 56.04%
#     Worker 4: Train Loss: 1.5856, Train Accuracy: 56.13%
#     Worker 5: Train Loss: 1.5860, Train Accuracy: 55.75%
#     Worker 6: Train Loss: 1.6248, Train Accuracy: 55.80%
#     Worker 7: Train Loss: 1.5549, Train Accuracy: 56.57%
# Epoch 83/150: Test Loss: 1.9875, Test Accuracy: 48.93%
#     Worker 0: Train Loss: 1.5526, Train Accuracy: 56.63%
#     Worker 1: Train Loss: 1.5543, Train Accuracy: 57.24%
#     Worker 2: Train Loss: 1.5436, Train Accuracy: 57.15%
#     Worker 3: Train Loss: 1.5669, Train Accuracy: 56.21%
#     Worker 4: Train Loss: 1.5202, Train Accuracy: 56.91%
#     Worker 5: Train Loss: 1.5946, Train Accuracy: 56.41%
#     Worker 6: Train Loss: 1.5624, Train Accuracy: 56.27%
#     Worker 7: Train Loss: 1.5486, Train Accuracy: 56.95%
# Epoch 84/150: Test Loss: 1.9846, Test Accuracy: 49.21%
#     Worker 0: Train Loss: 1.5907, Train Accuracy: 56.18%
#     Worker 1: Train Loss: 1.5018, Train Accuracy: 57.21%
#     Worker 2: Train Loss: 1.5406, Train Accuracy: 57.65%
#     Worker 3: Train Loss: 1.5889, Train Accuracy: 55.93%
#     Worker 4: Train Loss: 1.5464, Train Accuracy: 57.02%
#     Worker 5: Train Loss: 1.5048, Train Accuracy: 58.15%
#     Worker 6: Train Loss: 1.5786, Train Accuracy: 56.04%
#     Worker 7: Train Loss: 1.5361, Train Accuracy: 57.65%
# Epoch 85/150: Test Loss: 1.9859, Test Accuracy: 49.20%
#     Worker 0: Train Loss: 1.5517, Train Accuracy: 56.37%
#     Worker 1: Train Loss: 1.5296, Train Accuracy: 58.29%
#     Worker 2: Train Loss: 1.5423, Train Accuracy: 57.81%
#     Worker 3: Train Loss: 1.5523, Train Accuracy: 57.26%
#     Worker 4: Train Loss: 1.5383, Train Accuracy: 56.66%
#     Worker 5: Train Loss: 1.5422, Train Accuracy: 56.51%
#     Worker 6: Train Loss: 1.5529, Train Accuracy: 56.84%
#     Worker 7: Train Loss: 1.5454, Train Accuracy: 56.69%
# Epoch 86/150: Test Loss: 1.9831, Test Accuracy: 49.00%
#     Worker 0: Train Loss: 1.5362, Train Accuracy: 57.12%
#     Worker 1: Train Loss: 1.4959, Train Accuracy: 58.25%
#     Worker 2: Train Loss: 1.5103, Train Accuracy: 57.89%
#     Worker 3: Train Loss: 1.5215, Train Accuracy: 57.76%
#     Worker 4: Train Loss: 1.5287, Train Accuracy: 57.31%
#     Worker 5: Train Loss: 1.5176, Train Accuracy: 58.00%
#     Worker 6: Train Loss: 1.5501, Train Accuracy: 56.63%
#     Worker 7: Train Loss: 1.5506, Train Accuracy: 56.69%
# Epoch 87/150: Test Loss: 1.9883, Test Accuracy: 49.03%
#     Worker 0: Train Loss: 1.5429, Train Accuracy: 57.15%
#     Worker 1: Train Loss: 1.5034, Train Accuracy: 58.26%
#     Worker 2: Train Loss: 1.4974, Train Accuracy: 58.37%
#     Worker 3: Train Loss: 1.5572, Train Accuracy: 56.69%
#     Worker 4: Train Loss: 1.5098, Train Accuracy: 57.59%
#     Worker 5: Train Loss: 1.5217, Train Accuracy: 58.06%
#     Worker 6: Train Loss: 1.5248, Train Accuracy: 57.13%
#     Worker 7: Train Loss: 1.5067, Train Accuracy: 58.39%
# Epoch 88/150: Test Loss: 1.9844, Test Accuracy: 49.15%
#     Worker 0: Train Loss: 1.5028, Train Accuracy: 57.64%
#     Worker 1: Train Loss: 1.4800, Train Accuracy: 58.48%
#     Worker 2: Train Loss: 1.5057, Train Accuracy: 58.25%
#     Worker 3: Train Loss: 1.5070, Train Accuracy: 58.17%
#     Worker 4: Train Loss: 1.5313, Train Accuracy: 56.98%
#     Worker 5: Train Loss: 1.5110, Train Accuracy: 58.31%
#     Worker 6: Train Loss: 1.5561, Train Accuracy: 56.62%
#     Worker 7: Train Loss: 1.5024, Train Accuracy: 58.06%
# Epoch 89/150: Test Loss: 1.9766, Test Accuracy: 49.64%
#     Worker 0: Train Loss: 1.5025, Train Accuracy: 58.09%
#     Worker 1: Train Loss: 1.4793, Train Accuracy: 58.62%
#     Worker 2: Train Loss: 1.5012, Train Accuracy: 58.20%
#     Worker 3: Train Loss: 1.5106, Train Accuracy: 57.35%
#     Worker 4: Train Loss: 1.4729, Train Accuracy: 58.40%
#     Worker 5: Train Loss: 1.4870, Train Accuracy: 58.84%
#     Worker 6: Train Loss: 1.5194, Train Accuracy: 57.73%
#     Worker 7: Train Loss: 1.5188, Train Accuracy: 58.01%
# Epoch 90/150: Test Loss: 1.9883, Test Accuracy: 49.57%
#     Worker 0: Train Loss: 1.5012, Train Accuracy: 57.60%
#     Worker 1: Train Loss: 1.4486, Train Accuracy: 59.34%
#     Worker 2: Train Loss: 1.4866, Train Accuracy: 59.08%
#     Worker 3: Train Loss: 1.5060, Train Accuracy: 57.68%
#     Worker 4: Train Loss: 1.5098, Train Accuracy: 57.92%
#     Worker 5: Train Loss: 1.4911, Train Accuracy: 58.31%
#     Worker 6: Train Loss: 1.5101, Train Accuracy: 57.51%
#     Worker 7: Train Loss: 1.4889, Train Accuracy: 58.26%
# Epoch 91/150: Test Loss: 1.9766, Test Accuracy: 49.58%
#     Worker 0: Train Loss: 1.5019, Train Accuracy: 57.49%
#     Worker 1: Train Loss: 1.4666, Train Accuracy: 59.02%
#     Worker 2: Train Loss: 1.4585, Train Accuracy: 59.80%
#     Worker 3: Train Loss: 1.5070, Train Accuracy: 58.37%
#     Worker 4: Train Loss: 1.4697, Train Accuracy: 58.54%
#     Worker 5: Train Loss: 1.4795, Train Accuracy: 58.83%
#     Worker 6: Train Loss: 1.5025, Train Accuracy: 57.98%
#     Worker 7: Train Loss: 1.4737, Train Accuracy: 58.97%
# Epoch 92/150: Test Loss: 1.9731, Test Accuracy: 49.66%
#     Worker 0: Train Loss: 1.4919, Train Accuracy: 58.11%
#     Worker 1: Train Loss: 1.4391, Train Accuracy: 59.20%
#     Worker 2: Train Loss: 1.4544, Train Accuracy: 59.41%
#     Worker 3: Train Loss: 1.4831, Train Accuracy: 58.22%
#     Worker 4: Train Loss: 1.4668, Train Accuracy: 58.54%
#     Worker 5: Train Loss: 1.4469, Train Accuracy: 59.08%
#     Worker 6: Train Loss: 1.4802, Train Accuracy: 58.31%
#     Worker 7: Train Loss: 1.4688, Train Accuracy: 59.14%
# Epoch 93/150: Test Loss: 1.9799, Test Accuracy: 49.66%
#     Worker 0: Train Loss: 1.4794, Train Accuracy: 58.61%
#     Worker 1: Train Loss: 1.4536, Train Accuracy: 58.94%
#     Worker 2: Train Loss: 1.4666, Train Accuracy: 59.39%
#     Worker 3: Train Loss: 1.4835, Train Accuracy: 58.75%
#     Worker 4: Train Loss: 1.4708, Train Accuracy: 58.94%
#     Worker 5: Train Loss: 1.4416, Train Accuracy: 58.98%
#     Worker 6: Train Loss: 1.4782, Train Accuracy: 58.50%
#     Worker 7: Train Loss: 1.4401, Train Accuracy: 59.99%
# Epoch 94/150: Test Loss: 1.9804, Test Accuracy: 49.68%
#     Worker 0: Train Loss: 1.4490, Train Accuracy: 60.00%
# ...
#     Worker 6: Train Loss: 1.3182, Train Accuracy: 62.98%
#     Worker 7: Train Loss: 1.3077, Train Accuracy: 63.56%
# Epoch 120/150: Test Loss: 1.9801, Test Accuracy: 51.00%
#     Worker 0: Train Loss: 1.2795, Train Accuracy: 63.53%
#     Worker 1: Train Loss: 1.2666, Train Accuracy: 63.91%
#     Worker 2: Train Loss: 1.2732, Train Accuracy: 64.41%
#     Worker 3: Train Loss: 1.3079, Train Accuracy: 63.23%
#     Worker 4: Train Loss: 1.2711, Train Accuracy: 64.27%
#     Worker 5: Train Loss: 1.2974, Train Accuracy: 63.66%
#     Worker 6: Train Loss: 1.2801, Train Accuracy: 63.97%
#     Worker 7: Train Loss: 1.2598, Train Accuracy: 64.91%
# Epoch 121/150: Test Loss: 1.9782, Test Accuracy: 50.93%
#     Worker 0: Train Loss: 1.3107, Train Accuracy: 63.17%
#     Worker 1: Train Loss: 1.2507, Train Accuracy: 64.36%
#     Worker 2: Train Loss: 1.2729, Train Accuracy: 64.11%
#     Worker 3: Train Loss: 1.3023, Train Accuracy: 63.23%
#     Worker 4: Train Loss: 1.2843, Train Accuracy: 63.28%
#     Worker 5: Train Loss: 1.2786, Train Accuracy: 63.91%
#     Worker 6: Train Loss: 1.3043, Train Accuracy: 62.98%
#     Worker 7: Train Loss: 1.3039, Train Accuracy: 63.53%
# Epoch 122/150: Test Loss: 1.9815, Test Accuracy: 50.95%
#     Worker 0: Train Loss: 1.2798, Train Accuracy: 64.38%
#     Worker 1: Train Loss: 1.2608, Train Accuracy: 63.25%
#     Worker 2: Train Loss: 1.2810, Train Accuracy: 64.00%
#     Worker 3: Train Loss: 1.2901, Train Accuracy: 63.23%
#     Worker 4: Train Loss: 1.2752, Train Accuracy: 64.42%
#     Worker 5: Train Loss: 1.2785, Train Accuracy: 64.33%
#     Worker 6: Train Loss: 1.2739, Train Accuracy: 63.91%
#     Worker 7: Train Loss: 1.2489, Train Accuracy: 64.38%
# Epoch 123/150: Test Loss: 1.9816, Test Accuracy: 50.90%
#     Worker 0: Train Loss: 1.2733, Train Accuracy: 64.21%
#     Worker 1: Train Loss: 1.2554, Train Accuracy: 64.11%
#     Worker 2: Train Loss: 1.2488, Train Accuracy: 64.85%
#     Worker 3: Train Loss: 1.3151, Train Accuracy: 62.56%
#     Worker 4: Train Loss: 1.2447, Train Accuracy: 64.53%
#     Worker 5: Train Loss: 1.2535, Train Accuracy: 65.57%
#     Worker 6: Train Loss: 1.2756, Train Accuracy: 63.91%
#     Worker 7: Train Loss: 1.2548, Train Accuracy: 64.96%
# Epoch 124/150: Test Loss: 1.9798, Test Accuracy: 51.30%
#     Worker 0: Train Loss: 1.3113, Train Accuracy: 62.50%
#     Worker 1: Train Loss: 1.2500, Train Accuracy: 64.36%
#     Worker 2: Train Loss: 1.2563, Train Accuracy: 64.64%
#     Worker 3: Train Loss: 1.2682, Train Accuracy: 64.14%
#     Worker 4: Train Loss: 1.2676, Train Accuracy: 63.91%
#     Worker 5: Train Loss: 1.2673, Train Accuracy: 64.16%
#     Worker 6: Train Loss: 1.2972, Train Accuracy: 63.36%
#     Worker 7: Train Loss: 1.2614, Train Accuracy: 65.05%
# Epoch 125/150: Test Loss: 1.9776, Test Accuracy: 50.79%
#     Worker 0: Train Loss: 1.2645, Train Accuracy: 64.94%
#     Worker 1: Train Loss: 1.2581, Train Accuracy: 63.81%
#     Worker 2: Train Loss: 1.2497, Train Accuracy: 64.58%
#     Worker 3: Train Loss: 1.2934, Train Accuracy: 63.04%
#     Worker 4: Train Loss: 1.2593, Train Accuracy: 64.21%
#     Worker 5: Train Loss: 1.2381, Train Accuracy: 65.68%
#     Worker 6: Train Loss: 1.3043, Train Accuracy: 63.42%
#     Worker 7: Train Loss: 1.2818, Train Accuracy: 63.70%
# Epoch 126/150: Test Loss: 1.9817, Test Accuracy: 51.25%
#     Worker 0: Train Loss: 1.2688, Train Accuracy: 64.16%
#     Worker 1: Train Loss: 1.2272, Train Accuracy: 65.02%
#     Worker 2: Train Loss: 1.2394, Train Accuracy: 65.05%
#     Worker 3: Train Loss: 1.2821, Train Accuracy: 64.02%
#     Worker 4: Train Loss: 1.2682, Train Accuracy: 64.08%
#     Worker 5: Train Loss: 1.2765, Train Accuracy: 64.41%
#     Worker 6: Train Loss: 1.2944, Train Accuracy: 63.14%
#     Worker 7: Train Loss: 1.2434, Train Accuracy: 65.91%
# Epoch 127/150: Test Loss: 1.9789, Test Accuracy: 51.33%
#     Worker 0: Train Loss: 1.2738, Train Accuracy: 64.52%
#     Worker 1: Train Loss: 1.2378, Train Accuracy: 64.68%
#     Worker 2: Train Loss: 1.2553, Train Accuracy: 65.04%
#     Worker 3: Train Loss: 1.2765, Train Accuracy: 64.11%
#     Worker 4: Train Loss: 1.2503, Train Accuracy: 64.99%
#     Worker 5: Train Loss: 1.2500, Train Accuracy: 64.85%
#     Worker 6: Train Loss: 1.2552, Train Accuracy: 64.11%
#     Worker 7: Train Loss: 1.2612, Train Accuracy: 64.85%
# Epoch 128/150: Test Loss: 1.9847, Test Accuracy: 50.88%
#     Worker 0: Train Loss: 1.2731, Train Accuracy: 63.55%
#     Worker 1: Train Loss: 1.2319, Train Accuracy: 64.44%
#     Worker 2: Train Loss: 1.2237, Train Accuracy: 65.57%
#     Worker 3: Train Loss: 1.2531, Train Accuracy: 64.52%
#     Worker 4: Train Loss: 1.2626, Train Accuracy: 64.60%
#     Worker 5: Train Loss: 1.2471, Train Accuracy: 64.94%
#     Worker 6: Train Loss: 1.2953, Train Accuracy: 63.45%
#     Worker 7: Train Loss: 1.2656, Train Accuracy: 64.00%
# Epoch 129/150: Test Loss: 1.9803, Test Accuracy: 50.94%
#     Worker 0: Train Loss: 1.2545, Train Accuracy: 64.33%
#     Worker 1: Train Loss: 1.2365, Train Accuracy: 65.65%
#     Worker 2: Train Loss: 1.2589, Train Accuracy: 65.19%
#     Worker 3: Train Loss: 1.2807, Train Accuracy: 63.20%
#     Worker 4: Train Loss: 1.2831, Train Accuracy: 63.69%
#     Worker 5: Train Loss: 1.2616, Train Accuracy: 64.38%
#     Worker 6: Train Loss: 1.3082, Train Accuracy: 63.00%
#     Worker 7: Train Loss: 1.2213, Train Accuracy: 66.06%
# Epoch 130/150: Test Loss: 1.9804, Test Accuracy: 51.15%
#     Worker 0: Train Loss: 1.2548, Train Accuracy: 64.35%
#     Worker 1: Train Loss: 1.2151, Train Accuracy: 65.04%
#     Worker 2: Train Loss: 1.2309, Train Accuracy: 64.80%
#     Worker 3: Train Loss: 1.2731, Train Accuracy: 64.21%
#     Worker 4: Train Loss: 1.2235, Train Accuracy: 65.05%
#     Worker 5: Train Loss: 1.2252, Train Accuracy: 66.10%
#     Worker 6: Train Loss: 1.2693, Train Accuracy: 64.17%
#     Worker 7: Train Loss: 1.2463, Train Accuracy: 64.79%
# Epoch 131/150: Test Loss: 1.9813, Test Accuracy: 51.42%
#     Worker 0: Train Loss: 1.2653, Train Accuracy: 64.36%
#     Worker 1: Train Loss: 1.2224, Train Accuracy: 65.44%
#     Worker 2: Train Loss: 1.2492, Train Accuracy: 64.83%
#     Worker 3: Train Loss: 1.2893, Train Accuracy: 63.19%
#     Worker 4: Train Loss: 1.2520, Train Accuracy: 64.46%
#     Worker 5: Train Loss: 1.2495, Train Accuracy: 64.63%
#     Worker 6: Train Loss: 1.2565, Train Accuracy: 64.19%
#     Worker 7: Train Loss: 1.2579, Train Accuracy: 65.16%
# Epoch 132/150: Test Loss: 1.9773, Test Accuracy: 51.41%
#     Worker 0: Train Loss: 1.2667, Train Accuracy: 64.21%
#     Worker 1: Train Loss: 1.2212, Train Accuracy: 65.43%
#     Worker 2: Train Loss: 1.2134, Train Accuracy: 66.20%
#     Worker 3: Train Loss: 1.2306, Train Accuracy: 65.22%
#     Worker 4: Train Loss: 1.2455, Train Accuracy: 64.89%
#     Worker 5: Train Loss: 1.2297, Train Accuracy: 65.11%
#     Worker 6: Train Loss: 1.2597, Train Accuracy: 64.74%
#     Worker 7: Train Loss: 1.2483, Train Accuracy: 64.71%
# Epoch 133/150: Test Loss: 1.9823, Test Accuracy: 51.21%
#     Worker 0: Train Loss: 1.2602, Train Accuracy: 64.68%
#     Worker 1: Train Loss: 1.2373, Train Accuracy: 65.07%
#     Worker 2: Train Loss: 1.2409, Train Accuracy: 65.08%
#     Worker 3: Train Loss: 1.2560, Train Accuracy: 63.75%
#     Worker 4: Train Loss: 1.2484, Train Accuracy: 64.55%
#     Worker 5: Train Loss: 1.2569, Train Accuracy: 64.61%
#     Worker 6: Train Loss: 1.2580, Train Accuracy: 64.71%
#     Worker 7: Train Loss: 1.2313, Train Accuracy: 64.97%
# Epoch 134/150: Test Loss: 1.9804, Test Accuracy: 50.95%
#     Worker 0: Train Loss: 1.2182, Train Accuracy: 65.80%
#     Worker 1: Train Loss: 1.2074, Train Accuracy: 66.16%
#     Worker 2: Train Loss: 1.2375, Train Accuracy: 64.61%
#     Worker 3: Train Loss: 1.2637, Train Accuracy: 64.57%
#     Worker 4: Train Loss: 1.2406, Train Accuracy: 65.08%
#     Worker 5: Train Loss: 1.2217, Train Accuracy: 65.29%
#     Worker 6: Train Loss: 1.2509, Train Accuracy: 64.94%
#     Worker 7: Train Loss: 1.2380, Train Accuracy: 65.11%
# Epoch 135/150: Test Loss: 1.9771, Test Accuracy: 51.21%
#     Worker 0: Train Loss: 1.2723, Train Accuracy: 63.77%
#     Worker 1: Train Loss: 1.2278, Train Accuracy: 64.89%
#     Worker 2: Train Loss: 1.2557, Train Accuracy: 65.22%
#     Worker 3: Train Loss: 1.2483, Train Accuracy: 65.04%
#     Worker 4: Train Loss: 1.2401, Train Accuracy: 64.97%
#     Worker 5: Train Loss: 1.2376, Train Accuracy: 65.26%
#     Worker 6: Train Loss: 1.2630, Train Accuracy: 64.38%
#     Worker 7: Train Loss: 1.2141, Train Accuracy: 65.38%
# Epoch 136/150: Test Loss: 1.9788, Test Accuracy: 51.33%
#     Worker 0: Train Loss: 1.2303, Train Accuracy: 65.27%
#     Worker 1: Train Loss: 1.2060, Train Accuracy: 65.88%
#     Worker 2: Train Loss: 1.2111, Train Accuracy: 66.42%
#     Worker 3: Train Loss: 1.2569, Train Accuracy: 64.17%
#     Worker 4: Train Loss: 1.2204, Train Accuracy: 65.33%
#     Worker 5: Train Loss: 1.2250, Train Accuracy: 65.26%
#     Worker 6: Train Loss: 1.2703, Train Accuracy: 63.97%
#     Worker 7: Train Loss: 1.2386, Train Accuracy: 65.05%
# Epoch 137/150: Test Loss: 1.9800, Test Accuracy: 51.47%
#     Worker 0: Train Loss: 1.2645, Train Accuracy: 64.00%
#     Worker 1: Train Loss: 1.2213, Train Accuracy: 65.76%
#     Worker 2: Train Loss: 1.2625, Train Accuracy: 65.18%
#     Worker 3: Train Loss: 1.2412, Train Accuracy: 64.83%
#     Worker 4: Train Loss: 1.2251, Train Accuracy: 65.04%
#     Worker 5: Train Loss: 1.2305, Train Accuracy: 65.37%
#     Worker 6: Train Loss: 1.2298, Train Accuracy: 64.50%
#     Worker 7: Train Loss: 1.2317, Train Accuracy: 65.00%
# Epoch 138/150: Test Loss: 1.9795, Test Accuracy: 51.25%
#     Worker 0: Train Loss: 1.2370, Train Accuracy: 64.91%
#     Worker 1: Train Loss: 1.2183, Train Accuracy: 65.48%
#     Worker 2: Train Loss: 1.2033, Train Accuracy: 65.73%
#     Worker 3: Train Loss: 1.2484, Train Accuracy: 64.50%
#     Worker 4: Train Loss: 1.2339, Train Accuracy: 64.75%
#     Worker 5: Train Loss: 1.2385, Train Accuracy: 64.83%
#     Worker 6: Train Loss: 1.2405, Train Accuracy: 64.99%
#     Worker 7: Train Loss: 1.2105, Train Accuracy: 66.02%
# Epoch 139/150: Test Loss: 1.9800, Test Accuracy: 51.22%
#     Worker 0: Train Loss: 1.2577, Train Accuracy: 64.38%
#     Worker 1: Train Loss: 1.2034, Train Accuracy: 65.76%
#     Worker 2: Train Loss: 1.2130, Train Accuracy: 66.68%
#     Worker 3: Train Loss: 1.2418, Train Accuracy: 65.15%
#     Worker 4: Train Loss: 1.2369, Train Accuracy: 64.94%
#     Worker 5: Train Loss: 1.2395, Train Accuracy: 65.41%
#     Worker 6: Train Loss: 1.2420, Train Accuracy: 65.30%
#     Worker 7: Train Loss: 1.2479, Train Accuracy: 65.30%
# Epoch 140/150: Test Loss: 1.9789, Test Accuracy: 51.40%
#     Worker 0: Train Loss: 1.2255, Train Accuracy: 65.88%
#     Worker 1: Train Loss: 1.2104, Train Accuracy: 65.93%
#     Worker 2: Train Loss: 1.2176, Train Accuracy: 65.63%
#     Worker 3: Train Loss: 1.2632, Train Accuracy: 63.99%
#     Worker 4: Train Loss: 1.2371, Train Accuracy: 64.55%
#     Worker 5: Train Loss: 1.2175, Train Accuracy: 65.95%
#     Worker 6: Train Loss: 1.2612, Train Accuracy: 64.61%
#     Worker 7: Train Loss: 1.2322, Train Accuracy: 65.30%
# Epoch 141/150: Test Loss: 1.9792, Test Accuracy: 51.27%
#     Worker 0: Train Loss: 1.2360, Train Accuracy: 65.33%
#     Worker 1: Train Loss: 1.1947, Train Accuracy: 65.69%
#     Worker 2: Train Loss: 1.2309, Train Accuracy: 65.62%
#     Worker 3: Train Loss: 1.2474, Train Accuracy: 64.52%
#     Worker 4: Train Loss: 1.2387, Train Accuracy: 64.72%
#     Worker 5: Train Loss: 1.2248, Train Accuracy: 65.85%
#     Worker 6: Train Loss: 1.2388, Train Accuracy: 65.05%
#     Worker 7: Train Loss: 1.2291, Train Accuracy: 65.51%
# Epoch 142/150: Test Loss: 1.9797, Test Accuracy: 51.31%
#     Worker 0: Train Loss: 1.2416, Train Accuracy: 65.13%
#     Worker 1: Train Loss: 1.2291, Train Accuracy: 65.08%
#     Worker 2: Train Loss: 1.2016, Train Accuracy: 66.12%
#     Worker 3: Train Loss: 1.2416, Train Accuracy: 64.71%
#     Worker 4: Train Loss: 1.2234, Train Accuracy: 65.00%
#     Worker 5: Train Loss: 1.2137, Train Accuracy: 65.98%
#     Worker 6: Train Loss: 1.2498, Train Accuracy: 64.68%
#     Worker 7: Train Loss: 1.2199, Train Accuracy: 65.63%
# Epoch 143/150: Test Loss: 1.9785, Test Accuracy: 51.40%
#     Worker 0: Train Loss: 1.2333, Train Accuracy: 65.29%
#     Worker 1: Train Loss: 1.2073, Train Accuracy: 65.22%
#     Worker 2: Train Loss: 1.2362, Train Accuracy: 65.57%
#     Worker 3: Train Loss: 1.2586, Train Accuracy: 64.89%
#     Worker 4: Train Loss: 1.2380, Train Accuracy: 65.10%
#     Worker 5: Train Loss: 1.2328, Train Accuracy: 65.26%
#     Worker 6: Train Loss: 1.2421, Train Accuracy: 65.07%
#     Worker 7: Train Loss: 1.2114, Train Accuracy: 65.87%
# Epoch 144/150: Test Loss: 1.9791, Test Accuracy: 51.27%
#     Worker 0: Train Loss: 1.2447, Train Accuracy: 65.00%
#     Worker 1: Train Loss: 1.2104, Train Accuracy: 65.32%
#     Worker 2: Train Loss: 1.2162, Train Accuracy: 65.84%
#     Worker 3: Train Loss: 1.2408, Train Accuracy: 65.32%
#     Worker 4: Train Loss: 1.2306, Train Accuracy: 65.41%
#     Worker 5: Train Loss: 1.2345, Train Accuracy: 65.30%
#     Worker 6: Train Loss: 1.2312, Train Accuracy: 65.74%
#     Worker 7: Train Loss: 1.2230, Train Accuracy: 65.41%
# Epoch 145/150: Test Loss: 1.9792, Test Accuracy: 51.25%
#     Worker 0: Train Loss: 1.2406, Train Accuracy: 64.49%
#     Worker 1: Train Loss: 1.1945, Train Accuracy: 66.04%
#     Worker 2: Train Loss: 1.2115, Train Accuracy: 65.84%
#     Worker 3: Train Loss: 1.2468, Train Accuracy: 64.99%
#     Worker 4: Train Loss: 1.2251, Train Accuracy: 65.08%
#     Worker 5: Train Loss: 1.2177, Train Accuracy: 65.85%
#     Worker 6: Train Loss: 1.2274, Train Accuracy: 65.37%
#     Worker 7: Train Loss: 1.2145, Train Accuracy: 65.40%
# Epoch 146/150: Test Loss: 1.9791, Test Accuracy: 51.29%
#     Worker 0: Train Loss: 1.2399, Train Accuracy: 64.60%
#     Worker 1: Train Loss: 1.2170, Train Accuracy: 65.51%
#     Worker 2: Train Loss: 1.2182, Train Accuracy: 65.91%
#     Worker 3: Train Loss: 1.2586, Train Accuracy: 64.22%
#     Worker 4: Train Loss: 1.2349, Train Accuracy: 65.21%
#     Worker 5: Train Loss: 1.2091, Train Accuracy: 65.96%
#     Worker 6: Train Loss: 1.2571, Train Accuracy: 64.33%
#     Worker 7: Train Loss: 1.2379, Train Accuracy: 64.88%
# Epoch 147/150: Test Loss: 1.9791, Test Accuracy: 51.33%
#     Worker 0: Train Loss: 1.2423, Train Accuracy: 64.90%
#     Worker 1: Train Loss: 1.2099, Train Accuracy: 65.84%
#     Worker 2: Train Loss: 1.2318, Train Accuracy: 65.32%
#     Worker 3: Train Loss: 1.2283, Train Accuracy: 64.85%
#     Worker 4: Train Loss: 1.2074, Train Accuracy: 65.69%
#     Worker 5: Train Loss: 1.2373, Train Accuracy: 64.58%
#     Worker 6: Train Loss: 1.2534, Train Accuracy: 64.74%
#     Worker 7: Train Loss: 1.2338, Train Accuracy: 65.45%
# Epoch 148/150: Test Loss: 1.9790, Test Accuracy: 51.31%
#     Worker 0: Train Loss: 1.2366, Train Accuracy: 65.49%
#     Worker 1: Train Loss: 1.2112, Train Accuracy: 65.63%
#     Worker 2: Train Loss: 1.2106, Train Accuracy: 65.93%
#     Worker 3: Train Loss: 1.2554, Train Accuracy: 64.68%
#     Worker 4: Train Loss: 1.2193, Train Accuracy: 65.63%
#     Worker 5: Train Loss: 1.2275, Train Accuracy: 65.29%
#     Worker 6: Train Loss: 1.2389, Train Accuracy: 64.85%
#     Worker 7: Train Loss: 1.2151, Train Accuracy: 65.88%
# Epoch 149/150: Test Loss: 1.9791, Test Accuracy: 51.30%
#     Worker 0: Train Loss: 1.2427, Train Accuracy: 64.52%
#     Worker 1: Train Loss: 1.2164, Train Accuracy: 65.24%
#     Worker 2: Train Loss: 1.2223, Train Accuracy: 65.99%
#     Worker 3: Train Loss: 1.2442, Train Accuracy: 64.79%
#     Worker 4: Train Loss: 1.2356, Train Accuracy: 65.30%
#     Worker 5: Train Loss: 1.2068, Train Accuracy: 65.71%
#     Worker 6: Train Loss: 1.2490, Train Accuracy: 65.07%
#     Worker 7: Train Loss: 1.2240, Train Accuracy: 65.74%
# Epoch 150/150: Test Loss: 1.9791, Test Accuracy: 51.31%
#     Worker 0: Train Loss: 1.2335, Train Accuracy: 65.22%
#     Worker 1: Train Loss: 1.1986, Train Accuracy: 65.82%
#     Worker 2: Train Loss: 1.2061, Train Accuracy: 66.02%
#     Worker 3: Train Loss: 1.2327, Train Accuracy: 65.30%
#     Worker 4: Train Loss: 1.2071, Train Accuracy: 65.32%
#     Worker 5: Train Loss: 1.2316, Train Accuracy: 65.62%
#     Worker 6: Train Loss: 1.2454, Train Accuracy: 64.83%
#     Worker 7: Train Loss: 1.2169, Train Accuracy: 65.40%
