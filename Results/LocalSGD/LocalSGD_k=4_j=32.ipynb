# %%
# %%writefile localSGD.py

import os
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
num_epochs = 150
base_learning_rate = 1e-2
momentum = 0.9
weight_decay = 4e-4
warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std

class LRScheduler(torch.optim.lr_scheduler._LRScheduler):
    def __init__(self, optimizer, base_lr, K, warmup_epochs, total_epochs, verbose=False):
        """
        Args:
            optimizer: SGD
            base_lr: Base learning rate for the reference batch size.
            K: Number of workers.
            warmup_epochs: Number of warmup epochs.
            total_epochs: Total number of epochs.
            verbose: Whether to print LR updates.
        """
        self.base_lr = base_lr
        self.K = K
        self.scaled_lr = base_lr * K
        self.warmup_epochs = warmup_epochs
        self.total_epochs = total_epochs
        self.verbose = verbose
        super(LRScheduler, self).__init__(optimizer)

    def get_lr(self):
        epoch = self.last_epoch
        if epoch < self.warmup_epochs:
            # Linear warmup scaling
            warmup_factor = (epoch + 1) / self.warmup_epochs
            return [warmup_factor * self.scaled_lr for _ in self.optimizer.param_groups]
        else:
            # polynomially decaying learning rate of ηt = η0×(1−t/T)
            if epoch == self.warmup_epochs:
                print(f"Warmup phase completed at epoch {epoch}. Switching to polynomial decay learning rate.")
            return [self.scaled_lr * ( 1 - ( (epoch - self.warmup_epochs) / (self.total_epochs - self.warmup_epochs))) for _ in self.optimizer.param_groups]


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]

# Batch size
batch_size = shard_size // J

# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)


# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [LRScheduler(
    optimizer = optimizer,
    base_lr = base_learning_rate,
    K = K,
    warmup_epochs = warmup_epochs,
    total_epochs = num_epochs,
    verbose = True) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}")

    # Sequentially train each worker to simulate a distributed environment
    for k in range(K):
        shard_loader = DataLoader(shards[k], batch_size=batch_size, shuffle=True)

        nets[k].train()
        correct_train, total_train, train_loss = 0, 0, 0.0
        for images, labels in shard_loader:
            images, labels = images.to(device), labels.to(device)  # Move to device
            optimizers[k].zero_grad()
            outputs = nets[k](images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizers[k].step()
            # Calculate train loss and accuracy
            train_loss += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            total_train += labels.size(0)
            correct_train += predicted.eq(labels).sum().item()
        # Store train loss and accuracy for this worker
        train_loss /= len(shard_loader.dataset)
        train_losses_per_worker[k].append(train_loss)
        train_accuracy = 100. * correct_train / total_train
        train_accuracies_per_worker[k].append(train_accuracy)

    # Perform model synchronization
    with torch.no_grad():
        global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
        for net in nets:
            for global_param, local_param in zip(global_parameters, net.parameters()):
                global_param += local_param
        for global_param in global_parameters:
            global_param /= K
        # Update each worker model with the global parameters
        for net in nets:
            for local_param, global_param in zip(net.parameters(), global_parameters):
                local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        scheduler.step()

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 4 --j 32
# Out:
# Training with K=4, J=32
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:04<00:00, 35.1MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.04000
# Epoch 1/150: Test Loss: 4.6031, Test Accuracy: 1.37%
#     Worker 0: Train Loss: 4.6050, Train Accuracy: 1.34%
#     Worker 1: Train Loss: 4.6051, Train Accuracy: 1.22%
#     Worker 2: Train Loss: 4.6042, Train Accuracy: 1.47%
#     Worker 3: Train Loss: 4.6053, Train Accuracy: 1.10%
# Epoch 2/150: Test Loss: 4.5894, Test Accuracy: 1.96%
#     Worker 0: Train Loss: 4.5992, Train Accuracy: 1.78%
#     Worker 1: Train Loss: 4.5986, Train Accuracy: 1.57%
#     Worker 2: Train Loss: 4.5970, Train Accuracy: 1.44%
#     Worker 3: Train Loss: 4.5991, Train Accuracy: 1.56%
# Epoch 3/150: Test Loss: 4.4570, Test Accuracy: 3.69%
#     Worker 0: Train Loss: 4.5578, Train Accuracy: 2.02%
#     Worker 1: Train Loss: 4.5584, Train Accuracy: 1.96%
#     Worker 2: Train Loss: 4.5496, Train Accuracy: 2.30%
#     Worker 3: Train Loss: 4.5556, Train Accuracy: 2.19%
# Epoch 4/150: Test Loss: 4.1056, Test Accuracy: 7.14%
#     Worker 0: Train Loss: 4.3253, Train Accuracy: 4.58%
#     Worker 1: Train Loss: 4.3389, Train Accuracy: 4.37%
#     Worker 2: Train Loss: 4.3046, Train Accuracy: 4.42%
#     Worker 3: Train Loss: 4.3263, Train Accuracy: 4.34%
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Epoch 5/150: Test Loss: 3.9270, Test Accuracy: 9.02%
#     Worker 0: Train Loss: 4.1009, Train Accuracy: 6.82%
#     Worker 1: Train Loss: 4.1186, Train Accuracy: 6.75%
#     Worker 2: Train Loss: 4.0871, Train Accuracy: 7.00%
#     Worker 3: Train Loss: 4.1549, Train Accuracy: 6.01%
# Epoch 6/150: Test Loss: 3.8118, Test Accuracy: 11.33%
#     Worker 0: Train Loss: 4.0070, Train Accuracy: 7.95%
#     Worker 1: Train Loss: 3.9995, Train Accuracy: 8.53%
#     Worker 2: Train Loss: 3.9411, Train Accuracy: 9.11%
#     Worker 3: Train Loss: 2.5682, Train Accuracy: 33.70%
# Epoch 34/150: Test Loss: 2.3503, Test Accuracy: 39.41%
#     Worker 0: Train Loss: 2.5047, Train Accuracy: 35.26%
#     Worker 1: Train Loss: 2.5128, Train Accuracy: 35.26%
#     Worker 2: Train Loss: 2.5201, Train Accuracy: 35.38%
#     Worker 3: Train Loss: 2.5100, Train Accuracy: 34.86%
# Epoch 35/150: Test Loss: 2.3257, Test Accuracy: 39.87%
#     Worker 0: Train Loss: 2.5089, Train Accuracy: 35.10%
#     Worker 1: Train Loss: 2.5408, Train Accuracy: 34.49%
#     Worker 2: Train Loss: 2.4796, Train Accuracy: 35.80%
#     Worker 3: Train Loss: 2.4684, Train Accuracy: 35.78%
# Epoch 36/150: Test Loss: 2.3922, Test Accuracy: 38.43%
#     Worker 0: Train Loss: 2.5221, Train Accuracy: 35.06%
#     Worker 1: Train Loss: 2.5101, Train Accuracy: 35.08%
#     Worker 2: Train Loss: 2.4567, Train Accuracy: 36.22%
#     Worker 3: Train Loss: 2.5051, Train Accuracy: 35.12%
# Epoch 37/150: Test Loss: 2.3012, Test Accuracy: 40.25%
#     Worker 0: Train Loss: 2.5285, Train Accuracy: 34.61%
#     Worker 1: Train Loss: 2.4574, Train Accuracy: 36.52%
#     Worker 2: Train Loss: 2.4866, Train Accuracy: 36.12%
#     Worker 3: Train Loss: 2.4577, Train Accuracy: 36.24%
# Epoch 38/150: Test Loss: 2.2827, Test Accuracy: 40.11%
#     Worker 0: Train Loss: 2.4658, Train Accuracy: 35.75%
#     Worker 1: Train Loss: 2.4739, Train Accuracy: 35.66%
#     Worker 2: Train Loss: 2.3849, Train Accuracy: 38.06%
#     Worker 3: Train Loss: 2.4415, Train Accuracy: 36.29%
# Epoch 39/150: Test Loss: 2.2703, Test Accuracy: 40.74%
#     Worker 0: Train Loss: 2.4256, Train Accuracy: 36.92%
#     Worker 1: Train Loss: 2.3945, Train Accuracy: 37.59%
#     Worker 2: Train Loss: 2.3875, Train Accuracy: 37.85%
#     Worker 3: Train Loss: 2.4149, Train Accuracy: 36.84%
# Epoch 40/150: Test Loss: 2.2393, Test Accuracy: 41.78%
#     Worker 0: Train Loss: 2.3877, Train Accuracy: 37.46%
#     Worker 1: Train Loss: 2.4234, Train Accuracy: 36.83%
#     Worker 2: Train Loss: 2.3598, Train Accuracy: 38.36%
#     Worker 3: Train Loss: 2.3774, Train Accuracy: 37.82%
# Epoch 41/150: Test Loss: 2.2543, Test Accuracy: 41.11%
#     Worker 0: Train Loss: 2.3633, Train Accuracy: 38.03%
#     Worker 1: Train Loss: 2.3255, Train Accuracy: 38.75%
#     Worker 2: Train Loss: 2.2936, Train Accuracy: 39.84%
#     Worker 3: Train Loss: 2.3707, Train Accuracy: 38.46%
# Epoch 42/150: Test Loss: 2.2158, Test Accuracy: 42.20%
#     Worker 0: Train Loss: 2.3648, Train Accuracy: 37.72%
#     Worker 1: Train Loss: 2.3081, Train Accuracy: 39.38%
#     Worker 2: Train Loss: 2.3395, Train Accuracy: 39.05%
#     Worker 3: Train Loss: 2.3105, Train Accuracy: 39.67%
# Epoch 43/150: Test Loss: 2.2280, Test Accuracy: 42.11%
#     Worker 0: Train Loss: 2.3077, Train Accuracy: 39.03%
#     Worker 1: Train Loss: 2.3148, Train Accuracy: 39.13%
#     Worker 2: Train Loss: 2.3306, Train Accuracy: 38.76%
#     Worker 3: Train Loss: 2.3368, Train Accuracy: 38.73%
# Epoch 44/150: Test Loss: 2.1909, Test Accuracy: 42.98%
#     Worker 0: Train Loss: 2.2852, Train Accuracy: 39.52%
#     Worker 1: Train Loss: 2.3031, Train Accuracy: 39.62%
#     Worker 2: Train Loss: 2.3239, Train Accuracy: 39.10%
#     Worker 3: Train Loss: 2.2642, Train Accuracy: 40.38%
# Epoch 45/150: Test Loss: 2.2035, Test Accuracy: 42.91%
#     Worker 0: Train Loss: 2.3063, Train Accuracy: 38.84%
#     Worker 1: Train Loss: 2.3393, Train Accuracy: 39.05%
#     Worker 2: Train Loss: 2.2217, Train Accuracy: 41.68%
#     Worker 3: Train Loss: 2.3052, Train Accuracy: 39.21%
# Epoch 46/150: Test Loss: 2.1756, Test Accuracy: 42.87%
#     Worker 0: Train Loss: 2.2586, Train Accuracy: 40.64%
#     Worker 1: Train Loss: 2.2819, Train Accuracy: 40.48%
#     Worker 2: Train Loss: 2.2477, Train Accuracy: 40.60%
#     Worker 3: Train Loss: 2.2615, Train Accuracy: 40.34%
# Epoch 47/150: Test Loss: 2.2208, Test Accuracy: 42.77%
#     Worker 0: Train Loss: 2.2429, Train Accuracy: 40.38%
#     Worker 1: Train Loss: 2.2944, Train Accuracy: 39.96%
#     Worker 2: Train Loss: 2.2914, Train Accuracy: 39.78%
#     Worker 3: Train Loss: 2.2780, Train Accuracy: 40.15%
# Epoch 48/150: Test Loss: 2.1467, Test Accuracy: 43.66%
#     Worker 0: Train Loss: 2.2144, Train Accuracy: 41.53%
#     Worker 1: Train Loss: 2.2487, Train Accuracy: 40.72%
#     Worker 2: Train Loss: 2.2929, Train Accuracy: 39.70%
#     Worker 3: Train Loss: 2.2171, Train Accuracy: 41.83%
# Epoch 49/150: Test Loss: 2.1380, Test Accuracy: 44.32%
#     Worker 0: Train Loss: 2.2156, Train Accuracy: 41.28%
#     Worker 1: Train Loss: 2.1912, Train Accuracy: 41.90%
#     Worker 2: Train Loss: 2.1582, Train Accuracy: 42.85%
#     Worker 3: Train Loss: 2.2018, Train Accuracy: 41.71%
# Epoch 50/150: Test Loss: 2.1782, Test Accuracy: 43.35%
#     Worker 0: Train Loss: 2.1701, Train Accuracy: 42.44%
#     Worker 1: Train Loss: 2.2171, Train Accuracy: 40.73%
#     Worker 2: Train Loss: 2.2057, Train Accuracy: 41.81%
#     Worker 3: Train Loss: 2.2970, Train Accuracy: 40.13%
# Epoch 51/150: Test Loss: 2.1343, Test Accuracy: 44.56%
#     Worker 0: Train Loss: 2.1353, Train Accuracy: 42.70%
#     Worker 1: Train Loss: 2.1803, Train Accuracy: 42.03%
#     Worker 2: Train Loss: 2.1977, Train Accuracy: 41.75%
#     Worker 3: Train Loss: 2.1817, Train Accuracy: 42.42%
# Epoch 52/150: Test Loss: 2.0932, Test Accuracy: 45.30%
#     Worker 0: Train Loss: 2.1502, Train Accuracy: 42.60%
#     Worker 1: Train Loss: 2.1839, Train Accuracy: 41.97%
#     Worker 2: Train Loss: 2.1474, Train Accuracy: 42.84%
#     Worker 3: Train Loss: 2.1229, Train Accuracy: 43.87%
# Epoch 53/150: Test Loss: 2.1068, Test Accuracy: 44.73%
#     Worker 0: Train Loss: 2.1556, Train Accuracy: 42.45%
#     Worker 1: Train Loss: 2.1151, Train Accuracy: 43.06%
#     Worker 2: Train Loss: 2.1405, Train Accuracy: 43.00%
#     Worker 3: Train Loss: 2.1150, Train Accuracy: 43.81%
# Epoch 54/150: Test Loss: 2.0975, Test Accuracy: 44.99%
#     Worker 0: Train Loss: 2.1365, Train Accuracy: 42.70%
#     Worker 1: Train Loss: 2.1409, Train Accuracy: 43.38%
#     Worker 2: Train Loss: 2.1420, Train Accuracy: 42.81%
#     Worker 3: Train Loss: 2.0787, Train Accuracy: 44.03%
# Epoch 55/150: Test Loss: 2.0952, Test Accuracy: 45.23%
#     Worker 0: Train Loss: 2.1112, Train Accuracy: 43.20%
#     Worker 1: Train Loss: 2.0960, Train Accuracy: 43.78%
#     Worker 2: Train Loss: 2.1484, Train Accuracy: 42.90%
#     Worker 3: Train Loss: 2.1004, Train Accuracy: 43.81%
# Epoch 56/150: Test Loss: 2.0742, Test Accuracy: 45.48%
#     Worker 0: Train Loss: 2.0609, Train Accuracy: 44.66%
#     Worker 1: Train Loss: 2.0641, Train Accuracy: 44.47%
#     Worker 2: Train Loss: 2.0855, Train Accuracy: 44.30%
#     Worker 3: Train Loss: 2.1172, Train Accuracy: 43.11%
# Epoch 57/150: Test Loss: 2.1074, Test Accuracy: 44.77%
#     Worker 0: Train Loss: 2.0546, Train Accuracy: 44.76%
#     Worker 1: Train Loss: 2.0815, Train Accuracy: 44.12%
#     Worker 2: Train Loss: 2.0620, Train Accuracy: 45.07%
#     Worker 3: Train Loss: 2.0869, Train Accuracy: 43.83%
# Epoch 58/150: Test Loss: 2.0604, Test Accuracy: 45.65%
#     Worker 0: Train Loss: 2.0448, Train Accuracy: 45.25%
#     Worker 1: Train Loss: 2.1943, Train Accuracy: 42.09%
#     Worker 2: Train Loss: 2.0612, Train Accuracy: 45.36%
#     Worker 3: Train Loss: 2.1127, Train Accuracy: 43.53%
# Epoch 59/150: Test Loss: 2.0416, Test Accuracy: 46.74%
#     Worker 0: Train Loss: 2.0309, Train Accuracy: 44.68%
#     Worker 1: Train Loss: 2.0230, Train Accuracy: 45.68%
#     Worker 2: Train Loss: 1.9975, Train Accuracy: 46.17%
#     Worker 3: Train Loss: 2.0275, Train Accuracy: 45.73%
# Epoch 60/150: Test Loss: 2.0390, Test Accuracy: 46.51%
#     Worker 0: Train Loss: 2.0093, Train Accuracy: 45.54%
#     Worker 1: Train Loss: 2.0518, Train Accuracy: 44.92%
#     Worker 2: Train Loss: 2.0353, Train Accuracy: 45.47%
# Epoch 70/150: Test Loss: 1.9913, Test Accuracy: 46.94%
#     Worker 0: Train Loss: 1.8780, Train Accuracy: 48.41%
#     Worker 1: Train Loss: 1.8380, Train Accuracy: 49.82%
#     Worker 2: Train Loss: 1.8743, Train Accuracy: 49.50%
#     Worker 3: Train Loss: 1.8688, Train Accuracy: 48.74%
# Epoch 71/150: Test Loss: 1.9853, Test Accuracy: 47.56%
#     Worker 0: Train Loss: 1.8471, Train Accuracy: 49.09%
#     Worker 1: Train Loss: 1.8689, Train Accuracy: 49.05%
#     Worker 2: Train Loss: 1.8394, Train Accuracy: 49.45%
#     Worker 3: Train Loss: 1.8635, Train Accuracy: 49.22%
# Epoch 72/150: Test Loss: 2.0156, Test Accuracy: 46.85%
#     Worker 0: Train Loss: 1.8288, Train Accuracy: 49.79%
#     Worker 1: Train Loss: 1.8597, Train Accuracy: 49.73%
#     Worker 2: Train Loss: 1.8588, Train Accuracy: 49.07%
#     Worker 3: Train Loss: 1.8545, Train Accuracy: 49.44%
# Epoch 73/150: Test Loss: 1.9691, Test Accuracy: 47.98%
#     Worker 0: Train Loss: 1.8620, Train Accuracy: 48.78%
#     Worker 1: Train Loss: 1.8704, Train Accuracy: 49.19%
#     Worker 2: Train Loss: 1.7913, Train Accuracy: 50.97%
#     Worker 3: Train Loss: 1.9129, Train Accuracy: 48.72%
# Epoch 74/150: Test Loss: 1.9575, Test Accuracy: 48.66%
#     Worker 0: Train Loss: 1.8819, Train Accuracy: 48.58%
#     Worker 1: Train Loss: 1.8322, Train Accuracy: 49.55%
#     Worker 2: Train Loss: 1.9001, Train Accuracy: 48.32%
#     Worker 3: Train Loss: 1.8443, Train Accuracy: 49.39%
# Epoch 75/150: Test Loss: 1.9826, Test Accuracy: 48.10%
#     Worker 0: Train Loss: 1.8661, Train Accuracy: 49.27%
#     Worker 1: Train Loss: 1.8876, Train Accuracy: 48.62%
#     Worker 2: Train Loss: 1.8460, Train Accuracy: 49.67%
#     Worker 3: Train Loss: 1.9289, Train Accuracy: 48.10%
# Epoch 76/150: Test Loss: 1.9707, Test Accuracy: 48.12%
#     Worker 0: Train Loss: 1.8217, Train Accuracy: 49.76%
#     Worker 1: Train Loss: 1.8041, Train Accuracy: 50.57%
#     Worker 2: Train Loss: 1.8251, Train Accuracy: 49.70%
#     Worker 3: Train Loss: 1.8531, Train Accuracy: 49.62%
# Epoch 77/150: Test Loss: 1.9586, Test Accuracy: 48.56%
#     Worker 0: Train Loss: 1.8131, Train Accuracy: 50.24%
#     Worker 1: Train Loss: 1.8298, Train Accuracy: 49.62%
#     Worker 2: Train Loss: 1.7527, Train Accuracy: 52.25%
#     Worker 3: Train Loss: 1.8237, Train Accuracy: 50.16%
# Epoch 78/150: Test Loss: 1.9388, Test Accuracy: 48.76%
#     Worker 0: Train Loss: 1.7841, Train Accuracy: 51.01%
#     Worker 1: Train Loss: 1.7739, Train Accuracy: 51.52%
#     Worker 2: Train Loss: 1.7813, Train Accuracy: 51.01%
#     Worker 3: Train Loss: 1.8181, Train Accuracy: 50.30%
# Epoch 79/150: Test Loss: 1.9759, Test Accuracy: 48.31%
#     Worker 0: Train Loss: 1.7896, Train Accuracy: 50.92%
#     Worker 1: Train Loss: 1.7735, Train Accuracy: 51.66%
#     Worker 2: Train Loss: 1.7381, Train Accuracy: 52.30%
#     Worker 3: Train Loss: 1.8118, Train Accuracy: 50.66%
# Epoch 80/150: Test Loss: 1.9380, Test Accuracy: 49.29%
#     Worker 0: Train Loss: 1.7346, Train Accuracy: 52.03%
#     Worker 1: Train Loss: 1.7587, Train Accuracy: 51.77%
#     Worker 2: Train Loss: 1.7608, Train Accuracy: 51.34%
#     Worker 3: Train Loss: 1.8693, Train Accuracy: 48.99%
# Epoch 81/150: Test Loss: 1.9579, Test Accuracy: 48.56%
#     Worker 0: Train Loss: 1.7146, Train Accuracy: 52.18%
#     Worker 1: Train Loss: 1.7163, Train Accuracy: 52.85%
#     Worker 2: Train Loss: 1.7231, Train Accuracy: 52.77%
#     Worker 3: Train Loss: 1.7345, Train Accuracy: 52.32%
# Epoch 82/150: Test Loss: 1.9279, Test Accuracy: 49.52%
#     Worker 0: Train Loss: 1.7570, Train Accuracy: 51.81%
#     Worker 1: Train Loss: 1.7345, Train Accuracy: 52.17%
#     Worker 2: Train Loss: 1.7061, Train Accuracy: 53.09%
#     Worker 3: Train Loss: 1.7315, Train Accuracy: 51.79%
# Epoch 83/150: Test Loss: 1.9385, Test Accuracy: 49.49%
#     Worker 0: Train Loss: 1.6932, Train Accuracy: 52.58%
#     Worker 1: Train Loss: 1.6731, Train Accuracy: 53.75%
#     Worker 2: Train Loss: 1.7088, Train Accuracy: 52.43%
#     Worker 3: Train Loss: 1.7406, Train Accuracy: 52.24%
# Epoch 84/150: Test Loss: 1.9197, Test Accuracy: 49.73%
#     Worker 0: Train Loss: 1.7367, Train Accuracy: 51.43%
#     Worker 1: Train Loss: 1.6871, Train Accuracy: 53.58%
#     Worker 2: Train Loss: 1.7146, Train Accuracy: 52.48%
#     Worker 3: Train Loss: 1.6897, Train Accuracy: 53.16%
# Epoch 85/150: Test Loss: 1.9259, Test Accuracy: 49.73%
#     Worker 0: Train Loss: 1.6726, Train Accuracy: 53.31%
#     Worker 1: Train Loss: 1.7349, Train Accuracy: 52.12%
#     Worker 2: Train Loss: 1.6870, Train Accuracy: 53.62%
#     Worker 3: Train Loss: 1.6791, Train Accuracy: 53.48%
# Epoch 86/150: Test Loss: 1.9204, Test Accuracy: 49.51%
#     Worker 0: Train Loss: 1.6468, Train Accuracy: 54.22%
#     Worker 1: Train Loss: 1.6786, Train Accuracy: 53.20%
#     Worker 2: Train Loss: 1.6936, Train Accuracy: 53.50%
#     Worker 3: Train Loss: 1.6825, Train Accuracy: 53.52%
# Epoch 87/150: Test Loss: 1.9213, Test Accuracy: 50.16%
#     Worker 0: Train Loss: 1.6834, Train Accuracy: 53.16%
#     Worker 1: Train Loss: 1.6448, Train Accuracy: 54.19%
#     Worker 2: Train Loss: 1.6415, Train Accuracy: 54.47%
#     Worker 3: Train Loss: 1.6452, Train Accuracy: 54.57%
# Epoch 88/150: Test Loss: 1.9142, Test Accuracy: 49.75%
#     Worker 0: Train Loss: 1.7016, Train Accuracy: 52.74%
#     Worker 1: Train Loss: 1.6511, Train Accuracy: 54.46%
#     Worker 2: Train Loss: 1.6720, Train Accuracy: 53.95%
#     Worker 3: Train Loss: 1.7323, Train Accuracy: 52.53%
# Epoch 89/150: Test Loss: 1.9098, Test Accuracy: 50.15%
#     Worker 0: Train Loss: 1.6261, Train Accuracy: 54.37%
#     Worker 1: Train Loss: 1.6196, Train Accuracy: 55.14%
#     Worker 2: Train Loss: 1.6185, Train Accuracy: 55.53%
#     Worker 3: Train Loss: 1.6678, Train Accuracy: 53.40%
# Epoch 90/150: Test Loss: 1.9112, Test Accuracy: 50.15%
#     Worker 0: Train Loss: 1.6045, Train Accuracy: 54.62%
#     Worker 1: Train Loss: 1.6779, Train Accuracy: 53.62%
#     Worker 2: Train Loss: 1.6287, Train Accuracy: 55.11%
#     Worker 3: Train Loss: 1.6147, Train Accuracy: 54.79%
# Epoch 91/150: Test Loss: 1.9020, Test Accuracy: 50.46%
#     Worker 0: Train Loss: 1.6587, Train Accuracy: 53.46%
#     Worker 1: Train Loss: 1.6394, Train Accuracy: 54.43%
#     Worker 2: Train Loss: 1.5909, Train Accuracy: 55.82%
#     Worker 3: Train Loss: 1.6274, Train Accuracy: 54.73%
# Epoch 92/150: Test Loss: 1.9197, Test Accuracy: 49.96%
#     Worker 0: Train Loss: 1.5990, Train Accuracy: 55.26%
#     Worker 1: Train Loss: 1.6127, Train Accuracy: 54.97%
#     Worker 2: Train Loss: 1.5687, Train Accuracy: 56.23%
#     Worker 3: Train Loss: 1.6215, Train Accuracy: 54.86%
# Epoch 93/150: Test Loss: 1.9119, Test Accuracy: 50.17%
#     Worker 0: Train Loss: 1.6037, Train Accuracy: 55.16%
#     Worker 1: Train Loss: 1.7026, Train Accuracy: 52.96%
#     Worker 2: Train Loss: 1.6239, Train Accuracy: 55.33%
#     Worker 3: Train Loss: 1.6378, Train Accuracy: 54.35%
# Epoch 94/150: Test Loss: 1.8956, Test Accuracy: 50.42%
#     Worker 0: Train Loss: 1.5844, Train Accuracy: 55.25%
#     Worker 1: Train Loss: 1.5920, Train Accuracy: 55.98%
#     Worker 2: Train Loss: 1.5712, Train Accuracy: 55.90%
#     Worker 3: Train Loss: 1.5730, Train Accuracy: 56.38%
# Epoch 95/150: Test Loss: 1.9041, Test Accuracy: 50.31%
#     Worker 0: Train Loss: 1.6067, Train Accuracy: 54.77%
#     Worker 1: Train Loss: 1.5799, Train Accuracy: 55.72%
#     Worker 2: Train Loss: 1.5551, Train Accuracy: 56.91%
#     Worker 3: Train Loss: 1.5926, Train Accuracy: 55.56%
# Epoch 96/150: Test Loss: 1.9079, Test Accuracy: 50.63%
#     Worker 0: Train Loss: 1.5969, Train Accuracy: 55.27%
#     Worker 1: Train Loss: 1.5537, Train Accuracy: 57.15%
#     Worker 2: Train Loss: 1.5568, Train Accuracy: 56.60%
#     Worker 3: Train Loss: 1.6232, Train Accuracy: 54.58%
# Epoch 97/150: Test Loss: 1.8980, Test Accuracy: 50.70%
#     Worker 0: Train Loss: 1.5715, Train Accuracy: 55.62%
#     Worker 1: Train Loss: 1.5525, Train Accuracy: 56.19%
#     Worker 2: Train Loss: 1.5423, Train Accuracy: 56.91%
#     Worker 3: Train Loss: 1.6321, Train Accuracy: 54.62%
# Epoch 98/150: Test Loss: 1.8883, Test Accuracy: 50.89%
#     Worker 0: Train Loss: 1.5280, Train Accuracy: 56.75%
#     Worker 1: Train Loss: 1.5694, Train Accuracy: 56.22%
#     Worker 2: Train Loss: 1.5319, Train Accuracy: 57.17%
#     Worker 3: Train Loss: 1.5524, Train Accuracy: 56.30%
# Epoch 99/150: Test Loss: 1.8984, Test Accuracy: 50.72%
#     Worker 0: Train Loss: 1.5297, Train Accuracy: 56.61%
#     Worker 1: Train Loss: 1.5739, Train Accuracy: 56.26%
#     Worker 2: Train Loss: 1.5948, Train Accuracy: 55.35%
#     Worker 3: Train Loss: 1.5500, Train Accuracy: 56.71%
# Epoch 100/150: Test Loss: 1.8973, Test Accuracy: 50.83%
#     Worker 0: Train Loss: 1.5338, Train Accuracy: 56.87%
#     Worker 1: Train Loss: 1.5745, Train Accuracy: 56.18%
#     Worker 2: Train Loss: 1.4900, Train Accuracy: 58.54%
#     Worker 3: Train Loss: 1.5549, Train Accuracy: 55.83%
# Epoch 101/150: Test Loss: 1.8975, Test Accuracy: 50.67%
#     Worker 0: Train Loss: 1.5064, Train Accuracy: 57.49%
#     Worker 1: Train Loss: 1.5357, Train Accuracy: 57.26%
#     Worker 2: Train Loss: 1.5096, Train Accuracy: 58.07%
#     Worker 3: Train Loss: 1.5611, Train Accuracy: 56.40%
# Epoch 102/150: Test Loss: 1.8973, Test Accuracy: 50.77%
#     Worker 0: Train Loss: 1.5261, Train Accuracy: 57.04%
#     Worker 1: Train Loss: 1.5626, Train Accuracy: 56.61%
#     Worker 2: Train Loss: 1.5048, Train Accuracy: 57.93%
#     Worker 3: Train Loss: 1.5366, Train Accuracy: 56.85%
# Epoch 103/150: Test Loss: 1.8858, Test Accuracy: 51.37%
#     Worker 0: Train Loss: 1.4828, Train Accuracy: 58.30%
#     Worker 1: Train Loss: 1.4842, Train Accuracy: 58.06%
#     Worker 2: Train Loss: 1.4877, Train Accuracy: 58.11%
#     Worker 3: Train Loss: 1.5556, Train Accuracy: 56.27%
# Epoch 104/150: Test Loss: 1.8830, Test Accuracy: 51.18%
#     Worker 0: Train Loss: 1.5121, Train Accuracy: 56.96%
#     Worker 1: Train Loss: 1.5414, Train Accuracy: 56.77%
#     Worker 2: Train Loss: 1.5126, Train Accuracy: 57.39%
#     Worker 3: Train Loss: 1.5071, Train Accuracy: 57.74%
# Epoch 105/150: Test Loss: 1.8912, Test Accuracy: 50.95%
#     Worker 0: Train Loss: 1.4796, Train Accuracy: 58.18%
#     Worker 1: Train Loss: 1.4680, Train Accuracy: 58.83%
#     Worker 2: Train Loss: 1.5033, Train Accuracy: 57.11%
#     Worker 3: Train Loss: 1.5334, Train Accuracy: 57.17%
# Epoch 106/150: Test Loss: 1.8825, Test Accuracy: 51.76%
#     Worker 0: Train Loss: 1.4551, Train Accuracy: 58.54%
#     Worker 1: Train Loss: 1.4744, Train Accuracy: 58.34%
#     Worker 2: Train Loss: 1.4847, Train Accuracy: 58.34%
#     Worker 3: Train Loss: 1.5095, Train Accuracy: 57.90%
# Epoch 107/150: Test Loss: 1.8967, Test Accuracy: 50.81%
#     Worker 0: Train Loss: 1.4558, Train Accuracy: 59.10%
#     Worker 1: Train Loss: 1.4441, Train Accuracy: 59.38%
#     Worker 2: Train Loss: 1.4541, Train Accuracy: 59.26%
#     Worker 3: Train Loss: 1.4676, Train Accuracy: 58.96%
# Epoch 108/150: Test Loss: 1.8964, Test Accuracy: 51.08%
#     Worker 0: Train Loss: 1.4445, Train Accuracy: 58.80%
#     Worker 1: Train Loss: 1.4485, Train Accuracy: 59.21%
#     Worker 2: Train Loss: 1.4111, Train Accuracy: 59.90%
#     Worker 3: Train Loss: 1.4940, Train Accuracy: 58.32%
# Epoch 109/150: Test Loss: 1.8777, Test Accuracy: 51.35%
#     Worker 0: Train Loss: 1.4369, Train Accuracy: 58.78%
#     Worker 1: Train Loss: 1.4735, Train Accuracy: 58.24%
#     Worker 2: Train Loss: 1.5055, Train Accuracy: 57.58%
#     Worker 3: Train Loss: 1.4775, Train Accuracy: 58.71%
# Epoch 110/150: Test Loss: 1.8857, Test Accuracy: 51.38%
#     Worker 0: Train Loss: 1.4690, Train Accuracy: 58.20%
#     Worker 1: Train Loss: 1.4525, Train Accuracy: 58.87%
#     Worker 2: Train Loss: 1.4235, Train Accuracy: 60.23%
#     Worker 3: Train Loss: 1.4504, Train Accuracy: 59.32%
# Epoch 111/150: Test Loss: 1.8949, Test Accuracy: 51.43%
#     Worker 0: Train Loss: 1.4174, Train Accuracy: 59.59%
#     Worker 1: Train Loss: 1.4478, Train Accuracy: 59.06%
#     Worker 2: Train Loss: 1.4171, Train Accuracy: 59.91%
#     Worker 3: Train Loss: 1.4260, Train Accuracy: 59.57%
# Epoch 112/150: Test Loss: 1.8830, Test Accuracy: 51.41%
#     Worker 0: Train Loss: 1.4024, Train Accuracy: 60.30%
#     Worker 1: Train Loss: 1.4513, Train Accuracy: 59.42%
#     Worker 2: Train Loss: 1.4266, Train Accuracy: 59.79%
#     Worker 3: Train Loss: 1.4238, Train Accuracy: 60.38%
# Epoch 113/150: Test Loss: 1.8828, Test Accuracy: 51.30%
#     Worker 0: Train Loss: 1.4608, Train Accuracy: 58.68%
#     Worker 1: Train Loss: 1.4173, Train Accuracy: 60.16%
#     Worker 2: Train Loss: 1.4113, Train Accuracy: 59.84%
#     Worker 3: Train Loss: 1.4379, Train Accuracy: 59.01%
# Epoch 114/150: Test Loss: 1.8864, Test Accuracy: 51.57%
#     Worker 0: Train Loss: 1.4146, Train Accuracy: 59.82%
#     Worker 1: Train Loss: 1.4026, Train Accuracy: 60.49%
#     Worker 2: Train Loss: 1.3794, Train Accuracy: 60.64%
#     Worker 3: Train Loss: 1.4197, Train Accuracy: 60.52%
# Epoch 115/150: Test Loss: 1.8862, Test Accuracy: 51.28%
#     Worker 0: Train Loss: 1.3769, Train Accuracy: 60.79%
#     Worker 1: Train Loss: 1.4069, Train Accuracy: 60.22%
#     Worker 2: Train Loss: 1.3686, Train Accuracy: 61.10%
#     Worker 3: Train Loss: 1.3835, Train Accuracy: 60.77%
# Epoch 116/150: Test Loss: 1.8870, Test Accuracy: 51.37%
#     Worker 0: Train Loss: 1.3634, Train Accuracy: 61.30%
#     Worker 1: Train Loss: 1.3541, Train Accuracy: 61.90%
#     Worker 2: Train Loss: 1.3871, Train Accuracy: 60.87%
#     Worker 3: Train Loss: 1.3690, Train Accuracy: 61.32%
# Epoch 117/150: Test Loss: 1.8917, Test Accuracy: 51.85%
#     Worker 0: Train Loss: 1.3853, Train Accuracy: 60.62%
#     Worker 1: Train Loss: 1.4095, Train Accuracy: 59.82%
#     Worker 2: Train Loss: 1.3465, Train Accuracy: 61.47%
#     Worker 3: Train Loss: 1.3891, Train Accuracy: 60.57%
# Epoch 118/150: Test Loss: 1.8856, Test Accuracy: 51.32%
#     Worker 0: Train Loss: 1.3620, Train Accuracy: 61.30%
#     Worker 1: Train Loss: 1.3613, Train Accuracy: 61.32%
#     Worker 2: Train Loss: 1.3511, Train Accuracy: 61.55%
#     Worker 3: Train Loss: 1.3956, Train Accuracy: 60.11%
# Epoch 119/150: Test Loss: 1.8763, Test Accuracy: 52.02%
#     Worker 0: Train Loss: 1.3727, Train Accuracy: 60.94%
#     Worker 1: Train Loss: 1.3648, Train Accuracy: 60.97%
#     Worker 2: Train Loss: 1.3457, Train Accuracy: 61.62%
#     Worker 3: Train Loss: 1.3540, Train Accuracy: 61.34%
# Epoch 120/150: Test Loss: 1.8838, Test Accuracy: 52.04%
#     Worker 0: Train Loss: 1.3336, Train Accuracy: 61.94%
#     Worker 1: Train Loss: 1.3344, Train Accuracy: 62.63%
#     Worker 2: Train Loss: 1.3380, Train Accuracy: 62.04%
#     Worker 3: Train Loss: 1.3471, Train Accuracy: 61.61%
# Epoch 121/150: Test Loss: 1.8903, Test Accuracy: 51.58%
#     Worker 0: Train Loss: 1.3473, Train Accuracy: 61.38%
#     Worker 1: Train Loss: 1.3108, Train Accuracy: 62.71%
#     Worker 2: Train Loss: 1.3096, Train Accuracy: 63.14%
#     Worker 3: Train Loss: 1.3657, Train Accuracy: 61.27%
# Epoch 122/150: Test Loss: 1.8819, Test Accuracy: 51.86%
#     Worker 0: Train Loss: 1.3127, Train Accuracy: 62.47%
#     Worker 1: Train Loss: 1.3815, Train Accuracy: 60.82%
#     Worker 2: Train Loss: 1.3196, Train Accuracy: 62.64%
#     Worker 3: Train Loss: 1.3281, Train Accuracy: 62.34%
# Epoch 123/150: Test Loss: 1.8833, Test Accuracy: 51.83%
#     Worker 0: Train Loss: 1.3117, Train Accuracy: 62.11%
#     Worker 1: Train Loss: 1.3226, Train Accuracy: 62.09%
#     Worker 2: Train Loss: 1.2891, Train Accuracy: 63.47%
#     Worker 3: Train Loss: 1.3202, Train Accuracy: 62.18%
# Epoch 124/150: Test Loss: 1.8878, Test Accuracy: 51.64%
#     Worker 0: Train Loss: 1.2840, Train Accuracy: 62.79%
#     Worker 1: Train Loss: 1.3040, Train Accuracy: 62.70%
#     Worker 2: Train Loss: 1.3086, Train Accuracy: 62.62%
#     Worker 3: Train Loss: 1.3159, Train Accuracy: 62.26%
# Epoch 125/150: Test Loss: 1.8898, Test Accuracy: 51.67%
#     Worker 0: Train Loss: 1.2974, Train Accuracy: 62.74%
#     Worker 1: Train Loss: 1.2948, Train Accuracy: 62.71%
#     Worker 2: Train Loss: 1.2898, Train Accuracy: 63.48%
#     Worker 3: Train Loss: 1.3020, Train Accuracy: 62.09%
# Epoch 126/150: Test Loss: 1.8934, Test Accuracy: 51.83%
#     Worker 0: Train Loss: 1.3216, Train Accuracy: 61.94%
#     Worker 1: Train Loss: 1.3183, Train Accuracy: 62.58%
#     Worker 2: Train Loss: 1.2729, Train Accuracy: 63.88%
#     Worker 3: Train Loss: 1.3109, Train Accuracy: 62.98%
# Epoch 127/150: Test Loss: 1.8939, Test Accuracy: 51.71%
#     Worker 0: Train Loss: 1.2769, Train Accuracy: 63.42%
#     Worker 1: Train Loss: 1.3148, Train Accuracy: 62.45%
#     Worker 2: Train Loss: 1.2773, Train Accuracy: 63.64%
#     Worker 3: Train Loss: 1.2825, Train Accuracy: 63.64%
# Epoch 128/150: Test Loss: 1.8833, Test Accuracy: 52.16%
#     Worker 0: Train Loss: 1.2642, Train Accuracy: 63.67%
#     Worker 1: Train Loss: 1.2958, Train Accuracy: 63.38%
#     Worker 2: Train Loss: 1.2721, Train Accuracy: 63.62%
#     Worker 3: Train Loss: 1.2774, Train Accuracy: 63.31%
# Epoch 129/150: Test Loss: 1.8824, Test Accuracy: 51.82%
#     Worker 0: Train Loss: 1.2813, Train Accuracy: 62.70%
#     Worker 1: Train Loss: 1.2709, Train Accuracy: 63.77%
#     Worker 2: Train Loss: 1.2605, Train Accuracy: 63.99%
#     Worker 3: Train Loss: 1.2924, Train Accuracy: 63.22%
# Epoch 130/150: Test Loss: 1.8847, Test Accuracy: 51.93%
#     Worker 0: Train Loss: 1.2437, Train Accuracy: 64.44%
#     Worker 1: Train Loss: 1.2481, Train Accuracy: 64.67%
#     Worker 2: Train Loss: 1.2547, Train Accuracy: 64.57%
#     Worker 3: Train Loss: 1.2781, Train Accuracy: 63.46%
# Epoch 131/150: Test Loss: 1.8876, Test Accuracy: 51.97%
#     Worker 0: Train Loss: 1.2569, Train Accuracy: 63.98%
#     Worker 1: Train Loss: 1.2459, Train Accuracy: 64.24%
#     Worker 2: Train Loss: 1.2431, Train Accuracy: 64.13%
#     Worker 3: Train Loss: 1.2609, Train Accuracy: 64.15%
# Epoch 132/150: Test Loss: 1.8930, Test Accuracy: 52.25%
#     Worker 0: Train Loss: 1.2147, Train Accuracy: 64.69%
#     Worker 1: Train Loss: 1.2324, Train Accuracy: 64.93%
#     Worker 2: Train Loss: 1.2440, Train Accuracy: 64.26%
#     Worker 3: Train Loss: 1.2424, Train Accuracy: 64.41%
# Epoch 133/150: Test Loss: 1.8935, Test Accuracy: 51.95%
#     Worker 0: Train Loss: 1.2201, Train Accuracy: 65.23%
#     Worker 1: Train Loss: 1.2248, Train Accuracy: 65.42%
#     Worker 2: Train Loss: 1.2400, Train Accuracy: 64.46%
#     Worker 3: Train Loss: 1.2376, Train Accuracy: 64.33%
# Epoch 134/150: Test Loss: 1.8924, Test Accuracy: 52.42%
#     Worker 0: Train Loss: 1.2323, Train Accuracy: 64.85%
#     Worker 1: Train Loss: 1.2224, Train Accuracy: 64.76%
#     Worker 2: Train Loss: 1.2306, Train Accuracy: 64.96%
#     Worker 3: Train Loss: 1.2267, Train Accuracy: 65.00%
# Epoch 135/150: Test Loss: 1.8918, Test Accuracy: 51.91%
#     Worker 0: Train Loss: 1.2235, Train Accuracy: 64.74%
#     Worker 1: Train Loss: 1.2227, Train Accuracy: 65.30%
#     Worker 2: Train Loss: 1.2241, Train Accuracy: 65.02%
#     Worker 3: Train Loss: 1.2126, Train Accuracy: 65.83%
# Epoch 136/150: Test Loss: 1.8956, Test Accuracy: 52.08%
#     Worker 0: Train Loss: 1.1971, Train Accuracy: 65.60%
#     Worker 1: Train Loss: 1.2173, Train Accuracy: 65.08%
#     Worker 2: Train Loss: 1.1971, Train Accuracy: 65.85%
#     Worker 3: Train Loss: 1.2219, Train Accuracy: 65.66%
# Epoch 137/150: Test Loss: 1.8939, Test Accuracy: 52.30%
#     Worker 0: Train Loss: 1.2035, Train Accuracy: 65.79%
#     Worker 1: Train Loss: 1.1889, Train Accuracy: 66.12%
#     Worker 2: Train Loss: 1.1824, Train Accuracy: 66.19%
#     Worker 3: Train Loss: 1.2083, Train Accuracy: 66.02%
# Epoch 138/150: Test Loss: 1.8931, Test Accuracy: 52.13%
#     Worker 0: Train Loss: 1.1877, Train Accuracy: 66.19%
#     Worker 1: Train Loss: 1.1985, Train Accuracy: 65.55%
#     Worker 2: Train Loss: 1.1901, Train Accuracy: 65.94%
#     Worker 3: Train Loss: 1.1999, Train Accuracy: 65.49%
# Epoch 139/150: Test Loss: 1.9005, Test Accuracy: 52.56%
#     Worker 0: Train Loss: 1.1616, Train Accuracy: 66.66%
#     Worker 1: Train Loss: 1.1877, Train Accuracy: 65.97%
#     Worker 2: Train Loss: 1.1836, Train Accuracy: 65.42%
#     Worker 3: Train Loss: 1.2081, Train Accuracy: 65.38%
# Epoch 140/150: Test Loss: 1.9000, Test Accuracy: 52.37%
#     Worker 0: Train Loss: 1.1879, Train Accuracy: 65.72%
#     Worker 1: Train Loss: 1.1771, Train Accuracy: 66.25%
#     Worker 2: Train Loss: 1.1864, Train Accuracy: 66.05%
#     Worker 3: Train Loss: 1.1801, Train Accuracy: 66.17%
# Epoch 141/150: Test Loss: 1.9050, Test Accuracy: 52.21%
#     Worker 0: Train Loss: 1.1731, Train Accuracy: 65.78%
#     Worker 1: Train Loss: 1.1710, Train Accuracy: 66.74%
#     Worker 2: Train Loss: 1.1722, Train Accuracy: 66.44%
#     Worker 3: Train Loss: 1.1824, Train Accuracy: 66.18%
# Epoch 142/150: Test Loss: 1.8973, Test Accuracy: 52.34%
#     Worker 0: Train Loss: 1.1685, Train Accuracy: 66.47%
#     Worker 1: Train Loss: 1.1695, Train Accuracy: 65.95%
#     Worker 2: Train Loss: 1.1718, Train Accuracy: 66.55%
#     Worker 3: Train Loss: 1.1745, Train Accuracy: 66.42%
# Epoch 143/150: Test Loss: 1.9005, Test Accuracy: 52.36%
#     Worker 0: Train Loss: 1.1562, Train Accuracy: 66.49%
#     Worker 1: Train Loss: 1.1658, Train Accuracy: 66.45%
#     Worker 2: Train Loss: 1.1567, Train Accuracy: 66.79%
#     Worker 3: Train Loss: 1.1702, Train Accuracy: 66.37%
# Epoch 144/150: Test Loss: 1.8997, Test Accuracy: 52.17%
#     Worker 0: Train Loss: 1.1388, Train Accuracy: 67.25%
#     Worker 1: Train Loss: 1.1700, Train Accuracy: 66.27%
#     Worker 2: Train Loss: 1.1558, Train Accuracy: 67.05%
#     Worker 3: Train Loss: 1.1557, Train Accuracy: 66.77%
# Epoch 145/150: Test Loss: 1.8990, Test Accuracy: 52.32%
#     Worker 0: Train Loss: 1.1447, Train Accuracy: 67.66%
#     Worker 1: Train Loss: 1.1621, Train Accuracy: 66.80%
#     Worker 2: Train Loss: 1.1429, Train Accuracy: 67.29%
#     Worker 3: Train Loss: 1.1594, Train Accuracy: 66.63%
# Epoch 146/150: Test Loss: 1.8998, Test Accuracy: 52.54%
#     Worker 0: Train Loss: 1.1465, Train Accuracy: 66.98%
#     Worker 1: Train Loss: 1.1508, Train Accuracy: 67.17%
#     Worker 2: Train Loss: 1.1426, Train Accuracy: 67.02%
#     Worker 3: Train Loss: 1.1519, Train Accuracy: 67.22%
# Epoch 147/150: Test Loss: 1.9008, Test Accuracy: 52.45%
#     Worker 0: Train Loss: 1.1300, Train Accuracy: 67.06%
#     Worker 1: Train Loss: 1.1387, Train Accuracy: 67.49%
#     Worker 2: Train Loss: 1.1387, Train Accuracy: 67.10%
#     Worker 3: Train Loss: 1.1600, Train Accuracy: 66.78%
# Epoch 148/150: Test Loss: 1.9025, Test Accuracy: 52.29%
#     Worker 0: Train Loss: 1.1222, Train Accuracy: 67.82%
#     Worker 1: Train Loss: 1.1334, Train Accuracy: 67.61%
#     Worker 2: Train Loss: 1.1163, Train Accuracy: 68.23%
#     Worker 3: Train Loss: 1.1500, Train Accuracy: 66.46%
# Epoch 149/150: Test Loss: 1.9026, Test Accuracy: 52.26%
#     Worker 0: Train Loss: 1.1337, Train Accuracy: 67.20%
#     Worker 1: Train Loss: 1.1322, Train Accuracy: 67.84%
#     Worker 2: Train Loss: 1.1415, Train Accuracy: 67.60%
#     Worker 3: Train Loss: 1.1420, Train Accuracy: 67.42%
# Epoch 150/150: Test Loss: 1.9028, Test Accuracy: 52.20%
#     Worker 0: Train Loss: 1.1274, Train Accuracy: 67.71%
#     Worker 1: Train Loss: 1.1343, Train Accuracy: 67.88%
#     Worker 2: Train Loss: 1.1186, Train Accuracy: 67.98%
#     Worker 3: Train Loss: 1.1334, Train Accuracy: 67.85%
