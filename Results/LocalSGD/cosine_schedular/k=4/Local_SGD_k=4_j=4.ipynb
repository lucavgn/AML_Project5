# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 128
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs - warmup_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")

    for iteration in range(global_iteration_per_epoch):
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            # Perform J local step before synchronization
            for j in range(J):
                try:
                    # Get a batch from the current worker's shard using next()
                    images, labels = next(shard_iterators[k])
                    images, labels = images.to(device), labels.to(device)  # Move to device
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * images.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

                except StopIteration:
                    # If the iterator has exhausted the data, restart the iterator
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k]) # Resume from the next batch
                    images, labels = images.to(device), labels.to(device)
                    # Perform optimization step
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * images.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

            # Store train loss and accuracy for this worker
            train_loss /= total_train
            train_losses_per_worker[k].append(train_loss)
            train_accuracy = 100. * correct_train / total_train
            train_accuracies_per_worker[k].append(train_accuracy)

        # Perform model synchronization
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            # Update each worker model with the global parameters
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
        else:
            warmup_factor = (epoch + 1) / warmup_epochs
            lr = warmup_factor * learning_rate
            for optimizer in optimizers:
                for param_group in optimizer.param_groups:
                    param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 4 --j 4
# Out:
# Training with K=4, J=4
# Global iteration per epoch: 49
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:12<00:00, 13.2MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00400
# Epoch 1/150: Test Loss: 4.5821, Test Accuracy: 3.05%
#     Worker 0: Train Loss: 4.5857, Train Accuracy: 2.99%
#     Worker 1: Train Loss: 4.5763, Train Accuracy: 1.50%
#     Worker 2: Train Loss: 4.5765, Train Accuracy: 4.70%
#     Worker 3: Train Loss: 4.5856, Train Accuracy: 1.71%
# Epoch 2/150: Test Loss: 4.5588, Test Accuracy: 3.27%
#     Worker 0: Train Loss: 4.5639, Train Accuracy: 4.27%
#     Worker 1: Train Loss: 4.5658, Train Accuracy: 2.78%
#     Worker 2: Train Loss: 4.5580, Train Accuracy: 2.78%
#     Worker 3: Train Loss: 4.5595, Train Accuracy: 4.27%
# Epoch 3/150: Test Loss: 4.4041, Test Accuracy: 4.40%
#     Worker 0: Train Loss: 4.4016, Train Accuracy: 5.56%
#     Worker 1: Train Loss: 4.4283, Train Accuracy: 4.27%
#     Worker 2: Train Loss: 4.4356, Train Accuracy: 4.27%
#     Worker 3: Train Loss: 4.4280, Train Accuracy: 3.42%
# Epoch 4/150: Test Loss: 4.0559, Test Accuracy: 8.09%
#     Worker 0: Train Loss: 4.1388, Train Accuracy: 7.26%
#     Worker 1: Train Loss: 4.1829, Train Accuracy: 5.98%
#     Worker 2: Train Loss: 4.0603, Train Accuracy: 7.05%
#     Worker 3: Train Loss: 4.0943, Train Accuracy: 10.47%
# Epoch 5/150: Test Loss: 3.8895, Test Accuracy: 11.20%
#     Worker 0: Train Loss: 3.9215, Train Accuracy: 10.68%
#     Worker 1: Train Loss: 3.9114, Train Accuracy: 11.32%
#     Worker 2: Train Loss: 3.8376, Train Accuracy: 10.68%
#     Worker 3: Train Loss: 3.9502, Train Accuracy: 10.90%
# Epoch 6/150: Test Loss: 3.7409, Test Accuracy: 13.49%
#     Worker 0: Train Loss: 3.8242, Train Accuracy: 11.11%
#     Worker 1: Train Loss: 3.8456, Train Accuracy: 12.18%
#     Worker 2: Train Loss: 3.7796, Train Accuracy: 12.82%
#     Worker 3: Train Loss: 3.8823, Train Accuracy: 9.40%
# Epoch 7/150: Test Loss: 3.6125, Test Accuracy: 15.91%
#     Worker 0: Train Loss: 3.7289, Train Accuracy: 12.61%
#     Worker 1: Train Loss: 3.6638, Train Accuracy: 13.03%
#     Worker 2: Train Loss: 3.6225, Train Accuracy: 14.74%
#     Worker 3: Train Loss: 2.4917, Train Accuracy: 34.62%
# Epoch 26/150: Test Loss: 2.4043, Test Accuracy: 38.27%
#     Worker 0: Train Loss: 2.5093, Train Accuracy: 38.89%
#     Worker 1: Train Loss: 2.3924, Train Accuracy: 39.10%
#     Worker 2: Train Loss: 2.3039, Train Accuracy: 38.25%
#     Worker 3: Train Loss: 2.4053, Train Accuracy: 39.74%
# Epoch 27/150: Test Loss: 2.3584, Test Accuracy: 38.89%
#     Worker 0: Train Loss: 2.2216, Train Accuracy: 42.31%
#     Worker 1: Train Loss: 2.4058, Train Accuracy: 39.53%
#     Worker 2: Train Loss: 2.4143, Train Accuracy: 38.68%
#     Worker 3: Train Loss: 2.4693, Train Accuracy: 33.97%
# Epoch 28/150: Test Loss: 2.3528, Test Accuracy: 39.76%
#     Worker 0: Train Loss: 2.4894, Train Accuracy: 38.68%
#     Worker 1: Train Loss: 2.4336, Train Accuracy: 36.54%
#     Worker 2: Train Loss: 2.3903, Train Accuracy: 38.89%
#     Worker 3: Train Loss: 2.3379, Train Accuracy: 37.18%
# Epoch 29/150: Test Loss: 2.3050, Test Accuracy: 40.69%
#     Worker 0: Train Loss: 2.3453, Train Accuracy: 39.74%
#     Worker 1: Train Loss: 2.3447, Train Accuracy: 39.74%
#     Worker 2: Train Loss: 2.2942, Train Accuracy: 38.89%
#     Worker 3: Train Loss: 2.4056, Train Accuracy: 36.54%
# Epoch 30/150: Test Loss: 2.2845, Test Accuracy: 40.96%
#     Worker 0: Train Loss: 2.4000, Train Accuracy: 36.75%
#     Worker 1: Train Loss: 2.2351, Train Accuracy: 41.67%
#     Worker 2: Train Loss: 2.2816, Train Accuracy: 41.24%
#     Worker 3: Train Loss: 2.2615, Train Accuracy: 40.60%
# Epoch 31/150: Test Loss: 2.2668, Test Accuracy: 41.72%
#     Worker 0: Train Loss: 2.3548, Train Accuracy: 37.61%
#     Worker 1: Train Loss: 2.1849, Train Accuracy: 41.24%
#     Worker 2: Train Loss: 2.3441, Train Accuracy: 39.10%
#     Worker 3: Train Loss: 2.2212, Train Accuracy: 40.81%
# Epoch 32/150: Test Loss: 2.2534, Test Accuracy: 41.56%
#     Worker 0: Train Loss: 2.3253, Train Accuracy: 39.53%
#     Worker 1: Train Loss: 2.1242, Train Accuracy: 45.51%
#     Worker 2: Train Loss: 2.1026, Train Accuracy: 44.87%
#     Worker 3: Train Loss: 2.1743, Train Accuracy: 41.45%
# Epoch 33/150: Test Loss: 2.2396, Test Accuracy: 41.90%
#     Worker 0: Train Loss: 2.1918, Train Accuracy: 43.59%
#     Worker 1: Train Loss: 2.0935, Train Accuracy: 44.87%
#     Worker 2: Train Loss: 2.2313, Train Accuracy: 40.81%
#     Worker 3: Train Loss: 2.2353, Train Accuracy: 40.17%
# Epoch 34/150: Test Loss: 2.2151, Test Accuracy: 42.91%
#     Worker 0: Train Loss: 2.0985, Train Accuracy: 44.02%
#     Worker 1: Train Loss: 2.1076, Train Accuracy: 41.88%
#     Worker 2: Train Loss: 2.1066, Train Accuracy: 46.79%
#     Worker 3: Train Loss: 2.2693, Train Accuracy: 40.38%
# Epoch 35/150: Test Loss: 2.1989, Test Accuracy: 42.96%
#     Worker 0: Train Loss: 2.0955, Train Accuracy: 44.66%
#     Worker 1: Train Loss: 2.2753, Train Accuracy: 39.74%
#     Worker 2: Train Loss: 2.1542, Train Accuracy: 41.67%
#     Worker 3: Train Loss: 2.1428, Train Accuracy: 44.23%
# Epoch 36/150: Test Loss: 2.1843, Test Accuracy: 43.70%
#     Worker 0: Train Loss: 2.2053, Train Accuracy: 43.59%
#     Worker 1: Train Loss: 2.0087, Train Accuracy: 47.65%
#     Worker 2: Train Loss: 2.1137, Train Accuracy: 42.52%
#     Worker 3: Train Loss: 2.0122, Train Accuracy: 47.65%
# Epoch 37/150: Test Loss: 2.1728, Test Accuracy: 43.79%
#     Worker 0: Train Loss: 2.0298, Train Accuracy: 46.37%
#     Worker 1: Train Loss: 1.9698, Train Accuracy: 46.79%
#     Worker 2: Train Loss: 2.0736, Train Accuracy: 47.01%
#     Worker 3: Train Loss: 2.0689, Train Accuracy: 44.87%
# Epoch 38/150: Test Loss: 2.1691, Test Accuracy: 43.91%
#     Worker 0: Train Loss: 2.0062, Train Accuracy: 45.30%
#     Worker 1: Train Loss: 1.9745, Train Accuracy: 48.29%
#     Worker 2: Train Loss: 2.0138, Train Accuracy: 45.09%
#     Worker 3: Train Loss: 2.1157, Train Accuracy: 46.37%
# Epoch 39/150: Test Loss: 2.1586, Test Accuracy: 44.16%
#     Worker 0: Train Loss: 2.1261, Train Accuracy: 42.09%
#     Worker 1: Train Loss: 1.9596, Train Accuracy: 47.86%
#     Worker 2: Train Loss: 2.0859, Train Accuracy: 44.87%
#     Worker 3: Train Loss: 2.1184, Train Accuracy: 45.09%
# Epoch 40/150: Test Loss: 2.1428, Test Accuracy: 44.41%
#     Worker 0: Train Loss: 2.0624, Train Accuracy: 45.30%
#     Worker 1: Train Loss: 1.9145, Train Accuracy: 46.58%
#     Worker 2: Train Loss: 1.9767, Train Accuracy: 47.22%
#     Worker 3: Train Loss: 2.0759, Train Accuracy: 44.02%
# Epoch 41/150: Test Loss: 2.1360, Test Accuracy: 44.62%
#     Worker 0: Train Loss: 2.0168, Train Accuracy: 46.58%
#     Worker 1: Train Loss: 1.9928, Train Accuracy: 47.65%
#     Worker 2: Train Loss: 1.8819, Train Accuracy: 48.93%
#     Worker 3: Train Loss: 2.0460, Train Accuracy: 45.30%
# Epoch 42/150: Test Loss: 2.1200, Test Accuracy: 45.16%
#     Worker 0: Train Loss: 1.8670, Train Accuracy: 52.35%
#     Worker 1: Train Loss: 2.0207, Train Accuracy: 47.01%
#     Worker 2: Train Loss: 2.0261, Train Accuracy: 46.15%
#     Worker 3: Train Loss: 2.0954, Train Accuracy: 45.73%
# Epoch 43/150: Test Loss: 2.1174, Test Accuracy: 45.07%
#     Worker 0: Train Loss: 1.9112, Train Accuracy: 49.15%
#     Worker 1: Train Loss: 1.9446, Train Accuracy: 48.72%
#     Worker 1: Train Loss: 1.4518, Train Accuracy: 58.33%
#     Worker 2: Train Loss: 1.4464, Train Accuracy: 58.76%
#     Worker 3: Train Loss: 1.4955, Train Accuracy: 60.26%
# Epoch 80/150: Test Loss: 1.9823, Test Accuracy: 49.78%
#     Worker 0: Train Loss: 1.4237, Train Accuracy: 59.19%
#     Worker 1: Train Loss: 1.2773, Train Accuracy: 65.81%
#     Worker 2: Train Loss: 1.3544, Train Accuracy: 60.26%
#     Worker 3: Train Loss: 1.4782, Train Accuracy: 58.97%
# Epoch 81/150: Test Loss: 1.9745, Test Accuracy: 49.75%
#     Worker 0: Train Loss: 1.4814, Train Accuracy: 59.62%
#     Worker 1: Train Loss: 1.3440, Train Accuracy: 62.39%
#     Worker 2: Train Loss: 1.4414, Train Accuracy: 60.47%
#     Worker 3: Train Loss: 1.4563, Train Accuracy: 56.84%
# Epoch 82/150: Test Loss: 1.9882, Test Accuracy: 49.91%
#     Worker 0: Train Loss: 1.4580, Train Accuracy: 59.19%
#     Worker 1: Train Loss: 1.4246, Train Accuracy: 58.33%
#     Worker 2: Train Loss: 1.4067, Train Accuracy: 58.97%
#     Worker 3: Train Loss: 1.3085, Train Accuracy: 64.74%
# Epoch 83/150: Test Loss: 1.9804, Test Accuracy: 50.11%
#     Worker 0: Train Loss: 1.4517, Train Accuracy: 58.76%
#     Worker 1: Train Loss: 1.3316, Train Accuracy: 62.82%
#     Worker 2: Train Loss: 1.4289, Train Accuracy: 62.61%
#     Worker 3: Train Loss: 1.2976, Train Accuracy: 64.53%
# Epoch 84/150: Test Loss: 1.9769, Test Accuracy: 50.05%
#     Worker 0: Train Loss: 1.3034, Train Accuracy: 64.10%
#     Worker 1: Train Loss: 1.4351, Train Accuracy: 62.39%
#     Worker 2: Train Loss: 1.3994, Train Accuracy: 60.26%
#     Worker 3: Train Loss: 1.3852, Train Accuracy: 63.03%
# Epoch 85/150: Test Loss: 1.9779, Test Accuracy: 50.59%
#     Worker 0: Train Loss: 1.4264, Train Accuracy: 59.83%
#     Worker 1: Train Loss: 1.3829, Train Accuracy: 61.32%
#     Worker 2: Train Loss: 1.4012, Train Accuracy: 59.40%
#     Worker 3: Train Loss: 1.3060, Train Accuracy: 62.61%
# Epoch 86/150: Test Loss: 1.9723, Test Accuracy: 50.38%
#     Worker 0: Train Loss: 1.4807, Train Accuracy: 58.12%
#     Worker 1: Train Loss: 1.3919, Train Accuracy: 63.25%
#     Worker 2: Train Loss: 1.4243, Train Accuracy: 62.61%
#     Worker 3: Train Loss: 1.3215, Train Accuracy: 65.38%
# Epoch 87/150: Test Loss: 1.9778, Test Accuracy: 50.17%
#     Worker 0: Train Loss: 1.4239, Train Accuracy: 59.19%
#     Worker 1: Train Loss: 1.2669, Train Accuracy: 64.96%
#     Worker 2: Train Loss: 1.4275, Train Accuracy: 60.68%
#     Worker 3: Train Loss: 1.3695, Train Accuracy: 61.97%
# Epoch 88/150: Test Loss: 1.9745, Test Accuracy: 50.68%
#     Worker 0: Train Loss: 1.4916, Train Accuracy: 58.55%
#     Worker 1: Train Loss: 1.3031, Train Accuracy: 62.82%
#     Worker 2: Train Loss: 1.3632, Train Accuracy: 60.04%
#     Worker 3: Train Loss: 1.3165, Train Accuracy: 62.39%
# Epoch 89/150: Test Loss: 1.9956, Test Accuracy: 50.30%
#     Worker 0: Train Loss: 1.2639, Train Accuracy: 63.89%
#     Worker 1: Train Loss: 1.3122, Train Accuracy: 61.75%
#     Worker 2: Train Loss: 1.5345, Train Accuracy: 57.48%
#     Worker 3: Train Loss: 1.2517, Train Accuracy: 65.81%
# Epoch 90/150: Test Loss: 1.9861, Test Accuracy: 50.20%
#     Worker 0: Train Loss: 1.4391, Train Accuracy: 58.55%
#     Worker 1: Train Loss: 1.2778, Train Accuracy: 61.75%
#     Worker 2: Train Loss: 1.3281, Train Accuracy: 63.03%
#     Worker 3: Train Loss: 1.3868, Train Accuracy: 62.39%
# Epoch 91/150: Test Loss: 1.9806, Test Accuracy: 50.25%
#     Worker 0: Train Loss: 1.3419, Train Accuracy: 63.25%
#     Worker 1: Train Loss: 1.3743, Train Accuracy: 63.25%
#     Worker 2: Train Loss: 1.3300, Train Accuracy: 62.18%
#     Worker 3: Train Loss: 1.3109, Train Accuracy: 63.89%
# Epoch 92/150: Test Loss: 1.9986, Test Accuracy: 50.23%
#     Worker 0: Train Loss: 1.3006, Train Accuracy: 62.18%
#     Worker 1: Train Loss: 1.3033, Train Accuracy: 64.10%
#     Worker 2: Train Loss: 1.2016, Train Accuracy: 64.74%
#     Worker 3: Train Loss: 1.4204, Train Accuracy: 62.82%
# Epoch 93/150: Test Loss: 1.9895, Test Accuracy: 50.29%
#     Worker 0: Train Loss: 1.3690, Train Accuracy: 62.39%
#     Worker 1: Train Loss: 1.3220, Train Accuracy: 64.32%
#     Worker 2: Train Loss: 1.3697, Train Accuracy: 59.62%
#     Worker 3: Train Loss: 1.2910, Train Accuracy: 63.89%
# Epoch 94/150: Test Loss: 1.9884, Test Accuracy: 50.80%
#     Worker 0: Train Loss: 1.3492, Train Accuracy: 61.54%
#     Worker 1: Train Loss: 1.2220, Train Accuracy: 64.10%
#     Worker 2: Train Loss: 1.2186, Train Accuracy: 67.74%
#     Worker 3: Train Loss: 1.2015, Train Accuracy: 69.02%
# Epoch 95/150: Test Loss: 1.9824, Test Accuracy: 50.22%
#     Worker 0: Train Loss: 1.3337, Train Accuracy: 64.10%
#     Worker 1: Train Loss: 1.3120, Train Accuracy: 61.11%
#     Worker 2: Train Loss: 1.2732, Train Accuracy: 64.74%
#     Worker 3: Train Loss: 1.3517, Train Accuracy: 61.54%
# Epoch 96/150: Test Loss: 1.9868, Test Accuracy: 50.19%
#     Worker 0: Train Loss: 1.3586, Train Accuracy: 61.32%
#     Worker 1: Train Loss: 1.2771, Train Accuracy: 61.97%
#     Worker 2: Train Loss: 1.3687, Train Accuracy: 60.90%
#     Worker 3: Train Loss: 1.1801, Train Accuracy: 65.81%
# Epoch 97/150: Test Loss: 1.9874, Test Accuracy: 50.16%
#     Worker 0: Train Loss: 1.2806, Train Accuracy: 64.96%
#     Worker 1: Train Loss: 1.2293, Train Accuracy: 65.38%
#     Worker 2: Train Loss: 1.4160, Train Accuracy: 60.68%
#     Worker 3: Train Loss: 1.2716, Train Accuracy: 65.60%
# Epoch 98/150: Test Loss: 1.9815, Test Accuracy: 50.73%
#     Worker 0: Train Loss: 1.3072, Train Accuracy: 63.03%
#     Worker 1: Train Loss: 1.1769, Train Accuracy: 65.17%
#     Worker 2: Train Loss: 1.2569, Train Accuracy: 65.60%
#     Worker 3: Train Loss: 1.3568, Train Accuracy: 60.90%
# Epoch 99/150: Test Loss: 1.9867, Test Accuracy: 50.35%
#     Worker 0: Train Loss: 1.3403, Train Accuracy: 61.97%
#     Worker 1: Train Loss: 1.2044, Train Accuracy: 63.89%
#     Worker 2: Train Loss: 1.2749, Train Accuracy: 61.75%
#     Worker 3: Train Loss: 1.3457, Train Accuracy: 61.54%
# Epoch 100/150: Test Loss: 1.9899, Test Accuracy: 50.75%
#     Worker 0: Train Loss: 1.4153, Train Accuracy: 60.47%
#     Worker 1: Train Loss: 1.2880, Train Accuracy: 65.17%
#     Worker 2: Train Loss: 1.3948, Train Accuracy: 60.26%
#     Worker 3: Train Loss: 1.2192, Train Accuracy: 65.38%
# Epoch 101/150: Test Loss: 2.0000, Test Accuracy: 50.53%
#     Worker 0: Train Loss: 1.2185, Train Accuracy: 63.25%
#     Worker 1: Train Loss: 1.1715, Train Accuracy: 65.17%
#     Worker 2: Train Loss: 1.2831, Train Accuracy: 65.38%
#     Worker 3: Train Loss: 1.2213, Train Accuracy: 66.88%
# Epoch 102/150: Test Loss: 1.9956, Test Accuracy: 50.44%
#     Worker 0: Train Loss: 1.2746, Train Accuracy: 63.03%
#     Worker 1: Train Loss: 1.2224, Train Accuracy: 65.38%
#     Worker 2: Train Loss: 1.1866, Train Accuracy: 65.60%
#     Worker 3: Train Loss: 1.2023, Train Accuracy: 64.10%
# Epoch 103/150: Test Loss: 1.9862, Test Accuracy: 50.81%
#     Worker 0: Train Loss: 1.3146, Train Accuracy: 61.54%
#     Worker 1: Train Loss: 1.2240, Train Accuracy: 65.38%
#     Worker 2: Train Loss: 1.1573, Train Accuracy: 67.09%
#     Worker 3: Train Loss: 1.3026, Train Accuracy: 61.11%
# Epoch 104/150: Test Loss: 1.9960, Test Accuracy: 50.38%
#     Worker 0: Train Loss: 1.2942, Train Accuracy: 63.25%
#     Worker 1: Train Loss: 1.2762, Train Accuracy: 64.74%
#     Worker 2: Train Loss: 1.1859, Train Accuracy: 66.45%
#     Worker 3: Train Loss: 1.2600, Train Accuracy: 64.74%
# Epoch 105/150: Test Loss: 1.9971, Test Accuracy: 50.60%
#     Worker 0: Train Loss: 1.2321, Train Accuracy: 66.03%
#     Worker 1: Train Loss: 1.2504, Train Accuracy: 62.82%
#     Worker 2: Train Loss: 1.2341, Train Accuracy: 65.17%
#     Worker 3: Train Loss: 1.2047, Train Accuracy: 63.25%
# Epoch 106/150: Test Loss: 1.9935, Test Accuracy: 50.77%
#     Worker 0: Train Loss: 1.2365, Train Accuracy: 64.53%
#     Worker 1: Train Loss: 1.1813, Train Accuracy: 68.16%
#     Worker 2: Train Loss: 1.2939, Train Accuracy: 64.53%
#     Worker 3: Train Loss: 1.1826, Train Accuracy: 63.46%
# Epoch 107/150: Test Loss: 1.9986, Test Accuracy: 50.66%
#     Worker 0: Train Loss: 1.1206, Train Accuracy: 67.74%
#     Worker 1: Train Loss: 1.3045, Train Accuracy: 62.39%
#     Worker 2: Train Loss: 1.2738, Train Accuracy: 64.53%
#     Worker 3: Train Loss: 1.2330, Train Accuracy: 65.38%
# Epoch 108/150: Test Loss: 1.9954, Test Accuracy: 50.70%
#     Worker 0: Train Loss: 1.1883, Train Accuracy: 66.24%
#     Worker 1: Train Loss: 1.0828, Train Accuracy: 69.87%
#     Worker 2: Train Loss: 1.1551, Train Accuracy: 68.80%
#     Worker 3: Train Loss: 1.1237, Train Accuracy: 66.45%
# Epoch 109/150: Test Loss: 1.9963, Test Accuracy: 50.68%
#     Worker 0: Train Loss: 1.2411, Train Accuracy: 63.03%
#     Worker 1: Train Loss: 1.2536, Train Accuracy: 64.74%
#     Worker 2: Train Loss: 1.2455, Train Accuracy: 64.32%
#     Worker 3: Train Loss: 1.2186, Train Accuracy: 66.24%
# Epoch 110/150: Test Loss: 2.0033, Test Accuracy: 50.56%
#     Worker 0: Train Loss: 1.2337, Train Accuracy: 63.25%
#     Worker 1: Train Loss: 1.1658, Train Accuracy: 68.80%
#     Worker 2: Train Loss: 1.3874, Train Accuracy: 60.68%
#     Worker 3: Train Loss: 1.2688, Train Accuracy: 63.89%
# Epoch 111/150: Test Loss: 2.0028, Test Accuracy: 50.78%
#     Worker 0: Train Loss: 1.1428, Train Accuracy: 66.24%
#     Worker 1: Train Loss: 1.1233, Train Accuracy: 66.03%
#     Worker 2: Train Loss: 1.2832, Train Accuracy: 61.97%
#     Worker 3: Train Loss: 1.1499, Train Accuracy: 66.24%
# Epoch 112/150: Test Loss: 2.0033, Test Accuracy: 50.68%
#     Worker 0: Train Loss: 1.0933, Train Accuracy: 69.66%
#     Worker 1: Train Loss: 1.2138, Train Accuracy: 67.09%
#     Worker 2: Train Loss: 1.3363, Train Accuracy: 66.88%
#     Worker 3: Train Loss: 1.2320, Train Accuracy: 64.10%
# Epoch 113/150: Test Loss: 2.0151, Test Accuracy: 50.47%
#     Worker 0: Train Loss: 1.0394, Train Accuracy: 69.02%
#     Worker 1: Train Loss: 1.1337, Train Accuracy: 67.52%
#     Worker 2: Train Loss: 1.2055, Train Accuracy: 66.03%
#     Worker 3: Train Loss: 1.3606, Train Accuracy: 62.61%
# Epoch 114/150: Test Loss: 2.0088, Test Accuracy: 50.48%
#     Worker 0: Train Loss: 1.1009, Train Accuracy: 69.23%
#     Worker 1: Train Loss: 1.2163, Train Accuracy: 66.24%
#     Worker 2: Train Loss: 1.1892, Train Accuracy: 67.95%
#     Worker 3: Train Loss: 1.1648, Train Accuracy: 65.17%
# Epoch 115/150: Test Loss: 2.0126, Test Accuracy: 50.64%
#     Worker 0: Train Loss: 1.2265, Train Accuracy: 62.82%
#     Worker 1: Train Loss: 1.0974, Train Accuracy: 68.38%
#     Worker 2: Train Loss: 1.1894, Train Accuracy: 64.10%
#     Worker 3: Train Loss: 1.3524, Train Accuracy: 64.10%
# Epoch 116/150: Test Loss: 2.0067, Test Accuracy: 50.85%
#     Worker 0: Train Loss: 1.1540, Train Accuracy: 65.17%
#     Worker 1: Train Loss: 1.2168, Train Accuracy: 65.60%
#     Worker 2: Train Loss: 1.1808, Train Accuracy: 69.87%
#     Worker 3: Train Loss: 1.1857, Train Accuracy: 67.31%
# Epoch 117/150: Test Loss: 2.0065, Test Accuracy: 50.90%
#     Worker 0: Train Loss: 1.1636, Train Accuracy: 67.74%
#     Worker 1: Train Loss: 1.2314, Train Accuracy: 63.89%
#     Worker 2: Train Loss: 1.0435, Train Accuracy: 71.37%
#     Worker 3: Train Loss: 1.1526, Train Accuracy: 66.88%
# Epoch 118/150: Test Loss: 2.0092, Test Accuracy: 50.63%
#     Worker 0: Train Loss: 1.1329, Train Accuracy: 67.74%
#     Worker 1: Train Loss: 1.2250, Train Accuracy: 65.17%
#     Worker 2: Train Loss: 1.1835, Train Accuracy: 65.17%
#     Worker 3: Train Loss: 1.2236, Train Accuracy: 66.24%
# Epoch 119/150: Test Loss: 2.0129, Test Accuracy: 50.63%
#     Worker 0: Train Loss: 1.2620, Train Accuracy: 67.31%
#     Worker 1: Train Loss: 1.2502, Train Accuracy: 65.81%
#     Worker 2: Train Loss: 1.1898, Train Accuracy: 68.80%
#     Worker 3: Train Loss: 1.2622, Train Accuracy: 63.46%
# Epoch 120/150: Test Loss: 2.0122, Test Accuracy: 50.71%
#     Worker 0: Train Loss: 1.1181, Train Accuracy: 67.74%
#     Worker 1: Train Loss: 1.2264, Train Accuracy: 68.80%
#     Worker 2: Train Loss: 1.1656, Train Accuracy: 68.59%
#     Worker 3: Train Loss: 1.2050, Train Accuracy: 67.31%
# Epoch 121/150: Test Loss: 2.0111, Test Accuracy: 50.54%
#     Worker 0: Train Loss: 1.2470, Train Accuracy: 62.61%
#     Worker 1: Train Loss: 1.0549, Train Accuracy: 69.02%
#     Worker 2: Train Loss: 1.2317, Train Accuracy: 63.46%
#     Worker 3: Train Loss: 1.1637, Train Accuracy: 66.45%
# Epoch 122/150: Test Loss: 2.0132, Test Accuracy: 50.78%
#     Worker 0: Train Loss: 1.2137, Train Accuracy: 67.09%
#     Worker 1: Train Loss: 1.1406, Train Accuracy: 68.38%
#     Worker 2: Train Loss: 1.0383, Train Accuracy: 69.44%
#     Worker 3: Train Loss: 1.1812, Train Accuracy: 66.67%
# Epoch 123/150: Test Loss: 2.0181, Test Accuracy: 50.67%
#     Worker 0: Train Loss: 1.1573, Train Accuracy: 67.95%
#     Worker 1: Train Loss: 1.1733, Train Accuracy: 67.74%
#     Worker 2: Train Loss: 1.2434, Train Accuracy: 64.96%
#     Worker 3: Train Loss: 1.1907, Train Accuracy: 66.67%
# Epoch 124/150: Test Loss: 2.0178, Test Accuracy: 50.80%
#     Worker 0: Train Loss: 1.0511, Train Accuracy: 70.09%
#     Worker 1: Train Loss: 1.1378, Train Accuracy: 67.95%
#     Worker 2: Train Loss: 1.1732, Train Accuracy: 65.38%
#     Worker 3: Train Loss: 1.2005, Train Accuracy: 67.31%
# Epoch 125/150: Test Loss: 2.0129, Test Accuracy: 50.76%
#     Worker 0: Train Loss: 1.1729, Train Accuracy: 67.09%
#     Worker 1: Train Loss: 1.2422, Train Accuracy: 66.45%
#     Worker 2: Train Loss: 1.0832, Train Accuracy: 70.30%
#     Worker 3: Train Loss: 1.2720, Train Accuracy: 65.81%
# Epoch 126/150: Test Loss: 2.0132, Test Accuracy: 50.68%
#     Worker 0: Train Loss: 1.2347, Train Accuracy: 61.75%
#     Worker 1: Train Loss: 1.0884, Train Accuracy: 70.94%
#     Worker 2: Train Loss: 1.0927, Train Accuracy: 71.58%
#     Worker 3: Train Loss: 1.2165, Train Accuracy: 67.74%
# Epoch 127/150: Test Loss: 2.0183, Test Accuracy: 50.77%
#     Worker 0: Train Loss: 1.1866, Train Accuracy: 63.89%
#     Worker 1: Train Loss: 1.2508, Train Accuracy: 64.10%
#     Worker 2: Train Loss: 1.2082, Train Accuracy: 64.53%
#     Worker 3: Train Loss: 1.1745, Train Accuracy: 66.45%
# Epoch 128/150: Test Loss: 2.0140, Test Accuracy: 50.43%
#     Worker 0: Train Loss: 1.1481, Train Accuracy: 66.24%
#     Worker 1: Train Loss: 1.1544, Train Accuracy: 65.60%
#     Worker 2: Train Loss: 1.0277, Train Accuracy: 70.94%
#     Worker 3: Train Loss: 1.0856, Train Accuracy: 70.09%
# Epoch 129/150: Test Loss: 2.0151, Test Accuracy: 50.59%
#     Worker 0: Train Loss: 1.1154, Train Accuracy: 66.88%
#     Worker 1: Train Loss: 1.1372, Train Accuracy: 68.80%
#     Worker 2: Train Loss: 1.1479, Train Accuracy: 67.31%
#     Worker 3: Train Loss: 1.1830, Train Accuracy: 65.38%
# Epoch 130/150: Test Loss: 2.0169, Test Accuracy: 50.90%
#     Worker 0: Train Loss: 1.1881, Train Accuracy: 67.09%
#     Worker 1: Train Loss: 1.0993, Train Accuracy: 69.02%
#     Worker 2: Train Loss: 1.1156, Train Accuracy: 69.87%
#     Worker 3: Train Loss: 1.1370, Train Accuracy: 66.88%
# Epoch 131/150: Test Loss: 2.0153, Test Accuracy: 50.89%
#     Worker 0: Train Loss: 1.1009, Train Accuracy: 66.67%
#     Worker 1: Train Loss: 1.0960, Train Accuracy: 70.09%
#     Worker 2: Train Loss: 1.2775, Train Accuracy: 64.10%
#     Worker 3: Train Loss: 1.1253, Train Accuracy: 68.59%
# Epoch 132/150: Test Loss: 2.0134, Test Accuracy: 50.90%
#     Worker 0: Train Loss: 1.1051, Train Accuracy: 68.80%
#     Worker 1: Train Loss: 1.1748, Train Accuracy: 64.53%
#     Worker 2: Train Loss: 1.1438, Train Accuracy: 66.88%
#     Worker 3: Train Loss: 1.1805, Train Accuracy: 64.32%
# Epoch 133/150: Test Loss: 2.0146, Test Accuracy: 50.92%
#     Worker 0: Train Loss: 1.2133, Train Accuracy: 63.89%
#     Worker 1: Train Loss: 1.1185, Train Accuracy: 71.79%
#     Worker 2: Train Loss: 1.0115, Train Accuracy: 70.73%
#     Worker 3: Train Loss: 1.1073, Train Accuracy: 69.23%
# Epoch 134/150: Test Loss: 2.0161, Test Accuracy: 50.94%
#     Worker 0: Train Loss: 1.0631, Train Accuracy: 70.30%
#     Worker 1: Train Loss: 1.0773, Train Accuracy: 69.23%
#     Worker 2: Train Loss: 1.0275, Train Accuracy: 70.51%
#     Worker 3: Train Loss: 1.0926, Train Accuracy: 68.80%
# Epoch 135/150: Test Loss: 2.0163, Test Accuracy: 50.84%
#     Worker 0: Train Loss: 1.1551, Train Accuracy: 67.31%
#     Worker 1: Train Loss: 1.0424, Train Accuracy: 70.51%
#     Worker 2: Train Loss: 1.0346, Train Accuracy: 73.08%
#     Worker 3: Train Loss: 1.0578, Train Accuracy: 70.30%
# Epoch 136/150: Test Loss: 2.0170, Test Accuracy: 50.84%
#     Worker 0: Train Loss: 1.1177, Train Accuracy: 65.81%
#     Worker 1: Train Loss: 1.0330, Train Accuracy: 70.30%
#     Worker 2: Train Loss: 1.0097, Train Accuracy: 71.79%
#     Worker 3: Train Loss: 1.0314, Train Accuracy: 71.79%
# Epoch 137/150: Test Loss: 2.0179, Test Accuracy: 50.89%
#     Worker 0: Train Loss: 1.2031, Train Accuracy: 67.31%
#     Worker 1: Train Loss: 1.0122, Train Accuracy: 72.22%
#     Worker 2: Train Loss: 1.1189, Train Accuracy: 68.38%
#     Worker 3: Train Loss: 1.1552, Train Accuracy: 67.52%
# Epoch 138/150: Test Loss: 2.0180, Test Accuracy: 50.88%
#     Worker 0: Train Loss: 1.0392, Train Accuracy: 69.44%
#     Worker 1: Train Loss: 1.0878, Train Accuracy: 70.09%
#     Worker 2: Train Loss: 1.1631, Train Accuracy: 67.74%
#     Worker 3: Train Loss: 1.0913, Train Accuracy: 69.02%
# Epoch 139/150: Test Loss: 2.0171, Test Accuracy: 50.89%
#     Worker 0: Train Loss: 0.9484, Train Accuracy: 72.86%
#     Worker 1: Train Loss: 1.0918, Train Accuracy: 69.02%
#     Worker 2: Train Loss: 1.1479, Train Accuracy: 66.24%
#     Worker 3: Train Loss: 1.2657, Train Accuracy: 64.74%
# Epoch 140/150: Test Loss: 2.0171, Test Accuracy: 50.91%
#     Worker 0: Train Loss: 1.0369, Train Accuracy: 69.66%
#     Worker 1: Train Loss: 1.1833, Train Accuracy: 67.52%
#     Worker 2: Train Loss: 1.0809, Train Accuracy: 67.74%
#     Worker 3: Train Loss: 1.0864, Train Accuracy: 69.23%
# Epoch 141/150: Test Loss: 2.0168, Test Accuracy: 50.80%
#     Worker 0: Train Loss: 1.1458, Train Accuracy: 70.30%
#     Worker 1: Train Loss: 1.2142, Train Accuracy: 64.74%
#     Worker 2: Train Loss: 0.9886, Train Accuracy: 71.15%
#     Worker 3: Train Loss: 1.1953, Train Accuracy: 67.74%
# Epoch 142/150: Test Loss: 2.0165, Test Accuracy: 50.90%
#     Worker 0: Train Loss: 1.0637, Train Accuracy: 71.37%
#     Worker 1: Train Loss: 1.1566, Train Accuracy: 65.60%
#     Worker 2: Train Loss: 1.0656, Train Accuracy: 69.23%
#     Worker 3: Train Loss: 1.1246, Train Accuracy: 66.88%
# Epoch 143/150: Test Loss: 2.0175, Test Accuracy: 50.87%
#     Worker 0: Train Loss: 1.1575, Train Accuracy: 65.60%
#     Worker 1: Train Loss: 1.1515, Train Accuracy: 64.96%
#     Worker 2: Train Loss: 1.0131, Train Accuracy: 69.44%
#     Worker 3: Train Loss: 1.0610, Train Accuracy: 68.16%
# Epoch 144/150: Test Loss: 2.0176, Test Accuracy: 50.89%
#     Worker 0: Train Loss: 1.1302, Train Accuracy: 68.16%
#     Worker 1: Train Loss: 1.1343, Train Accuracy: 67.09%
#     Worker 2: Train Loss: 1.0276, Train Accuracy: 69.87%
#     Worker 3: Train Loss: 1.1131, Train Accuracy: 69.02%
# Epoch 145/150: Test Loss: 2.0172, Test Accuracy: 50.84%
#     Worker 0: Train Loss: 1.1004, Train Accuracy: 69.66%
#     Worker 1: Train Loss: 1.1231, Train Accuracy: 68.59%
#     Worker 2: Train Loss: 1.1337, Train Accuracy: 69.44%
#     Worker 3: Train Loss: 1.0967, Train Accuracy: 68.16%
# Epoch 146/150: Test Loss: 2.0169, Test Accuracy: 50.85%
#     Worker 0: Train Loss: 1.1516, Train Accuracy: 66.03%
#     Worker 1: Train Loss: 1.1549, Train Accuracy: 66.67%
#     Worker 2: Train Loss: 1.0415, Train Accuracy: 69.66%
#     Worker 3: Train Loss: 1.1819, Train Accuracy: 67.31%
# Epoch 147/150: Test Loss: 2.0173, Test Accuracy: 50.87%
#     Worker 0: Train Loss: 1.1131, Train Accuracy: 66.45%
#     Worker 1: Train Loss: 1.0953, Train Accuracy: 68.80%
#     Worker 2: Train Loss: 1.0800, Train Accuracy: 70.73%
#     Worker 3: Train Loss: 1.1489, Train Accuracy: 67.09%
# Epoch 148/150: Test Loss: 2.0174, Test Accuracy: 50.90%
#     Worker 0: Train Loss: 1.0591, Train Accuracy: 69.02%
#     Worker 1: Train Loss: 1.0893, Train Accuracy: 68.80%
#     Worker 2: Train Loss: 1.0225, Train Accuracy: 71.79%
#     Worker 3: Train Loss: 1.1186, Train Accuracy: 66.24%
# Epoch 149/150: Test Loss: 2.0175, Test Accuracy: 50.88%
#     Worker 0: Train Loss: 1.1551, Train Accuracy: 67.95%
#     Worker 1: Train Loss: 1.1172, Train Accuracy: 69.44%
#     Worker 2: Train Loss: 1.0542, Train Accuracy: 70.09%
#     Worker 3: Train Loss: 1.1418, Train Accuracy: 69.23%
# Epoch 150/150: Test Loss: 2.0174, Test Accuracy: 50.88%
#     Worker 0: Train Loss: 1.2546, Train Accuracy: 64.32%
#     Worker 1: Train Loss: 1.0627, Train Accuracy: 70.30%
#     Worker 2: Train Loss: 1.0904, Train Accuracy: 69.44%
#     Worker 3: Train Loss: 1.0852, Train Accuracy: 68.59%
