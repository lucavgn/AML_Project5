# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs - warmup_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")

    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch):
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            # Perform J local step before synchronization
            for j in range(J):
                try:
                    # Get a batch from the current worker's shard using next()
                    images, labels = next(shard_iterators[k])
                    images, labels = images.to(device), labels.to(device)  # Move to device
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

                except StopIteration:
                    # If the iterator has exhausted the data, restart the iterator
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k]) # Resume from the next batch
                    images, labels = images.to(device), labels.to(device)
                    # Perform optimization step
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        # Perform model synchronization
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            # Update each worker model with the global parameters
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
        else:
            warmup_factor = (epoch + 1) / warmup_epochs
            lr = warmup_factor * learning_rate
            for optimizer in optimizers:
                for param_group in optimizer.param_groups:
                    param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Overwriting localSGD.py

# %%
# %run localSGD.py --k 4 --j 16
# Out:
# Training with K=4, J=16
# Global iteration per epoch: 13
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00400
# Epoch 1/150: Test Loss: 4.5776, Test Accuracy: 2.84%
#     Worker 0: Train Loss: 4.5980, Train Accuracy: 1.44%
#     Worker 1: Train Loss: 4.5984, Train Accuracy: 1.36%
#     Worker 2: Train Loss: 4.5976, Train Accuracy: 1.49%
#     Worker 3: Train Loss: 4.5986, Train Accuracy: 1.30%
# Epoch 2/150: Test Loss: 4.5460, Test Accuracy: 3.44%
#     Worker 0: Train Loss: 4.5667, Train Accuracy: 2.74%
#     Worker 1: Train Loss: 4.5667, Train Accuracy: 2.76%
#     Worker 2: Train Loss: 4.5632, Train Accuracy: 3.05%
#     Worker 3: Train Loss: 4.5661, Train Accuracy: 3.00%
# Epoch 3/150: Test Loss: 4.3474, Test Accuracy: 4.71%
#     Worker 0: Train Loss: 4.4744, Train Accuracy: 3.58%
#     Worker 1: Train Loss: 4.4781, Train Accuracy: 3.53%
#     Worker 2: Train Loss: 4.4691, Train Accuracy: 3.70%
#     Worker 3: Train Loss: 4.4782, Train Accuracy: 3.54%
# Epoch 4/150: Test Loss: 4.0604, Test Accuracy: 7.89%
#     Worker 0: Train Loss: 4.2239, Train Accuracy: 5.86%
#     Worker 1: Train Loss: 4.2303, Train Accuracy: 5.98%
#     Worker 2: Train Loss: 4.1943, Train Accuracy: 6.20%
#     Worker 3: Train Loss: 4.2272, Train Accuracy: 5.54%
# Epoch 5/150: Test Loss: 3.9127, Test Accuracy: 10.27%
#     Worker 0: Train Loss: 4.0515, Train Accuracy: 7.75%
#     Worker 1: Train Loss: 4.0766, Train Accuracy: 7.55%
#     Worker 2: Train Loss: 4.0381, Train Accuracy: 7.76%
#     Worker 3: Train Loss: 4.0785, Train Accuracy: 7.43%
# Epoch 6/150: Test Loss: 3.7923, Test Accuracy: 12.38%
#     Worker 0: Train Loss: 3.9415, Train Accuracy: 9.52%
#     Worker 1: Train Loss: 3.9341, Train Accuracy: 9.34%
#     Worker 2: Train Loss: 3.9075, Train Accuracy: 10.02%
#     Worker 3: Train Loss: 3.1650, Train Accuracy: 22.59%
# Epoch 16/150: Test Loss: 2.9625, Test Accuracy: 26.67%
#     Worker 0: Train Loss: 3.0837, Train Accuracy: 23.88%
#     Worker 1: Train Loss: 3.1053, Train Accuracy: 23.79%
#     Worker 2: Train Loss: 3.0637, Train Accuracy: 24.49%
#     Worker 3: Train Loss: 3.1063, Train Accuracy: 23.61%
# Epoch 17/150: Test Loss: 2.8840, Test Accuracy: 28.81%
#     Worker 0: Train Loss: 3.0400, Train Accuracy: 24.58%
#     Worker 1: Train Loss: 3.0689, Train Accuracy: 24.46%
#     Worker 2: Train Loss: 3.0151, Train Accuracy: 25.60%
#     Worker 3: Train Loss: 3.0575, Train Accuracy: 24.44%
# Epoch 18/150: Test Loss: 2.8504, Test Accuracy: 29.67%
#     Worker 0: Train Loss: 2.9639, Train Accuracy: 26.39%
#     Worker 1: Train Loss: 3.0214, Train Accuracy: 25.54%
#     Worker 2: Train Loss: 2.9699, Train Accuracy: 26.12%
#     Worker 3: Train Loss: 2.9882, Train Accuracy: 25.95%
# Epoch 19/150: Test Loss: 2.7977, Test Accuracy: 30.60%
#     Worker 0: Train Loss: 2.9541, Train Accuracy: 26.36%
#     Worker 1: Train Loss: 2.9730, Train Accuracy: 26.05%
#     Worker 2: Train Loss: 2.9106, Train Accuracy: 27.46%
#     Worker 3: Train Loss: 2.9603, Train Accuracy: 25.84%
# Epoch 20/150: Test Loss: 2.7618, Test Accuracy: 31.01%
#     Worker 0: Train Loss: 2.9091, Train Accuracy: 27.53%
#     Worker 1: Train Loss: 2.9122, Train Accuracy: 27.83%
#     Worker 2: Train Loss: 2.8702, Train Accuracy: 28.10%
#     Worker 3: Train Loss: 2.9054, Train Accuracy: 27.62%
# Epoch 21/150: Test Loss: 2.7085, Test Accuracy: 31.92%
#     Worker 0: Train Loss: 2.8232, Train Accuracy: 28.78%
#     Worker 1: Train Loss: 2.8755, Train Accuracy: 27.79%
#     Worker 2: Train Loss: 2.8381, Train Accuracy: 28.81%
#     Worker 3: Train Loss: 2.8616, Train Accuracy: 28.39%
# Epoch 22/150: Test Loss: 2.6601, Test Accuracy: 33.32%
#     Worker 0: Train Loss: 2.8197, Train Accuracy: 28.66%
#     Worker 1: Train Loss: 2.8506, Train Accuracy: 28.84%
#     Worker 2: Train Loss: 2.8002, Train Accuracy: 29.44%
#     Worker 3: Train Loss: 2.8178, Train Accuracy: 28.68%
# Epoch 23/150: Test Loss: 2.6636, Test Accuracy: 32.90%
#     Worker 0: Train Loss: 2.7667, Train Accuracy: 30.06%
#     Worker 1: Train Loss: 2.7993, Train Accuracy: 29.95%
#     Worker 2: Train Loss: 2.7356, Train Accuracy: 30.89%
#     Worker 3: Train Loss: 2.7793, Train Accuracy: 29.85%
# Epoch 24/150: Test Loss: 2.5800, Test Accuracy: 34.43%
#     Worker 0: Train Loss: 2.7299, Train Accuracy: 30.90%
#     Worker 1: Train Loss: 2.7296, Train Accuracy: 30.75%
#     Worker 2: Train Loss: 2.7204, Train Accuracy: 31.40%
#     Worker 3: Train Loss: 2.4251, Train Accuracy: 37.22%
# Epoch 34/150: Test Loss: 2.3069, Test Accuracy: 40.25%
#     Worker 0: Train Loss: 2.3762, Train Accuracy: 37.97%
#     Worker 1: Train Loss: 2.3878, Train Accuracy: 37.32%
#     Worker 2: Train Loss: 2.3555, Train Accuracy: 38.70%
#     Worker 3: Train Loss: 2.3901, Train Accuracy: 37.51%
# Epoch 35/150: Test Loss: 2.2985, Test Accuracy: 39.85%
#     Worker 0: Train Loss: 2.3543, Train Accuracy: 38.49%
#     Worker 1: Train Loss: 2.3556, Train Accuracy: 38.62%
#     Worker 2: Train Loss: 2.3559, Train Accuracy: 38.91%
#     Worker 3: Train Loss: 2.3797, Train Accuracy: 38.33%
# Epoch 36/150: Test Loss: 2.2943, Test Accuracy: 40.52%
#     Worker 0: Train Loss: 2.3210, Train Accuracy: 39.20%
#     Worker 1: Train Loss: 2.3477, Train Accuracy: 38.23%
#     Worker 2: Train Loss: 2.3116, Train Accuracy: 39.93%
#     Worker 3: Train Loss: 2.3307, Train Accuracy: 38.80%
# Epoch 37/150: Test Loss: 2.2851, Test Accuracy: 40.95%
#     Worker 0: Train Loss: 2.3091, Train Accuracy: 39.54%
#     Worker 1: Train Loss: 2.3119, Train Accuracy: 39.83%
#     Worker 2: Train Loss: 2.2821, Train Accuracy: 40.53%
#     Worker 3: Train Loss: 2.3050, Train Accuracy: 39.15%
# Epoch 38/150: Test Loss: 2.2407, Test Accuracy: 41.83%
#     Worker 0: Train Loss: 2.2732, Train Accuracy: 40.02%
#     Worker 1: Train Loss: 2.2955, Train Accuracy: 39.77%
#     Worker 2: Train Loss: 2.2518, Train Accuracy: 40.56%
#     Worker 3: Train Loss: 2.2835, Train Accuracy: 40.22%
# Epoch 39/150: Test Loss: 2.2271, Test Accuracy: 41.87%
#     Worker 0: Train Loss: 2.2433, Train Accuracy: 40.75%
#     Worker 1: Train Loss: 2.2661, Train Accuracy: 39.78%
#     Worker 2: Train Loss: 2.2461, Train Accuracy: 41.39%
#     Worker 3: Train Loss: 2.2517, Train Accuracy: 40.71%
# Epoch 40/150: Test Loss: 2.2091, Test Accuracy: 42.33%
#     Worker 0: Train Loss: 2.2429, Train Accuracy: 41.05%
#     Worker 1: Train Loss: 2.2297, Train Accuracy: 41.56%
#     Worker 2: Train Loss: 2.1993, Train Accuracy: 42.09%
#     Worker 3: Train Loss: 2.2437, Train Accuracy: 40.85%
# Epoch 41/150: Test Loss: 2.1868, Test Accuracy: 43.02%
#     Worker 0: Train Loss: 2.2154, Train Accuracy: 41.18%
#     Worker 1: Train Loss: 2.2401, Train Accuracy: 41.17%
#     Worker 2: Train Loss: 2.1997, Train Accuracy: 42.15%
#     Worker 3: Train Loss: 2.2153, Train Accuracy: 41.43%
# Epoch 42/150: Test Loss: 2.1737, Test Accuracy: 43.50%
#     Worker 0: Train Loss: 2.2007, Train Accuracy: 41.72%
#     Worker 1: Train Loss: 2.1899, Train Accuracy: 42.03%
#     Worker 2: Train Loss: 2.1705, Train Accuracy: 42.52%
#     Worker 3: Train Loss: 2.1957, Train Accuracy: 42.36%
# Epoch 43/150: Test Loss: 2.1692, Test Accuracy: 43.47%
#     Worker 0: Train Loss: 2.1580, Train Accuracy: 42.45%
#     Worker 1: Train Loss: 2.1572, Train Accuracy: 42.90%
#     Worker 2: Train Loss: 2.1208, Train Accuracy: 43.84%
#     Worker 3: Train Loss: 2.1652, Train Accuracy: 42.75%
# Epoch 44/150: Test Loss: 2.1549, Test Accuracy: 43.76%
#     Worker 0: Train Loss: 2.1462, Train Accuracy: 42.43%
#     Worker 1: Train Loss: 2.1405, Train Accuracy: 43.39%
#     Worker 2: Train Loss: 2.1530, Train Accuracy: 42.46%
#     Worker 3: Train Loss: 2.1590, Train Accuracy: 42.64%
# Epoch 45/150: Test Loss: 2.1525, Test Accuracy: 44.13%
#     Worker 0: Train Loss: 2.1231, Train Accuracy: 43.40%
#     Worker 1: Train Loss: 2.1129, Train Accuracy: 43.60%
#     Worker 2: Train Loss: 2.0989, Train Accuracy: 44.41%
#     Worker 3: Train Loss: 2.1176, Train Accuracy: 44.05%
# Epoch 46/150: Test Loss: 2.1287, Test Accuracy: 44.87%
#     Worker 0: Train Loss: 2.1182, Train Accuracy: 43.46%
#     Worker 1: Train Loss: 2.1078, Train Accuracy: 43.99%
#     Worker 2: Train Loss: 2.0739, Train Accuracy: 45.02%
#     Worker 3: Train Loss: 2.1135, Train Accuracy: 43.99%
# Epoch 47/150: Test Loss: 2.1335, Test Accuracy: 45.11%
#     Worker 0: Train Loss: 2.0901, Train Accuracy: 44.17%
#     Worker 1: Train Loss: 2.1040, Train Accuracy: 43.71%
#     Worker 2: Train Loss: 2.0674, Train Accuracy: 44.81%
#     Worker 3: Train Loss: 2.0995, Train Accuracy: 44.52%
# Epoch 48/150: Test Loss: 2.1036, Test Accuracy: 45.23%
#     Worker 0: Train Loss: 2.0668, Train Accuracy: 44.72%
#     Worker 1: Train Loss: 2.0652, Train Accuracy: 45.10%
#     Worker 2: Train Loss: 2.0453, Train Accuracy: 45.24%
#     Worker 3: Train Loss: 2.0724, Train Accuracy: 44.48%
# Epoch 49/150: Test Loss: 2.1248, Test Accuracy: 45.07%
#     Worker 0: Train Loss: 2.0436, Train Accuracy: 44.94%
#     Worker 1: Train Loss: 2.0507, Train Accuracy: 45.51%
#     Worker 2: Train Loss: 2.0258, Train Accuracy: 45.77%
#     Worker 3: Train Loss: 2.0531, Train Accuracy: 45.29%
# Epoch 50/150: Test Loss: 2.1118, Test Accuracy: 45.01%
#     Worker 0: Train Loss: 2.0139, Train Accuracy: 45.73%
#     Worker 1: Train Loss: 2.0315, Train Accuracy: 45.73%
#     Worker 2: Train Loss: 2.0110, Train Accuracy: 45.93%
#     Worker 3: Train Loss: 2.0378, Train Accuracy: 45.51%
# Epoch 51/150: Test Loss: 2.0994, Test Accuracy: 45.68%
#     Worker 0: Train Loss: 2.0300, Train Accuracy: 45.48%
#     Worker 1: Train Loss: 2.0339, Train Accuracy: 45.34%
#     Worker 2: Train Loss: 2.0053, Train Accuracy: 46.16%
#     Worker 3: Train Loss: 1.8561, Train Accuracy: 49.40%
# Epoch 61/150: Test Loss: 2.0372, Test Accuracy: 47.60%
#     Worker 0: Train Loss: 1.8483, Train Accuracy: 50.02%
#     Worker 1: Train Loss: 1.8509, Train Accuracy: 49.91%
#     Worker 2: Train Loss: 1.8364, Train Accuracy: 50.08%
#     Worker 3: Train Loss: 1.8553, Train Accuracy: 49.85%
# Epoch 62/150: Test Loss: 2.0197, Test Accuracy: 47.62%
#     Worker 0: Train Loss: 1.8453, Train Accuracy: 49.98%
#     Worker 1: Train Loss: 1.8377, Train Accuracy: 49.74%
#     Worker 2: Train Loss: 1.8444, Train Accuracy: 50.04%
#     Worker 3: Train Loss: 1.8311, Train Accuracy: 50.45%
# Epoch 63/150: Test Loss: 2.0282, Test Accuracy: 47.47%
#     Worker 0: Train Loss: 1.8304, Train Accuracy: 50.21%
#     Worker 1: Train Loss: 1.8175, Train Accuracy: 50.75%
#     Worker 2: Train Loss: 1.7932, Train Accuracy: 51.19%
#     Worker 3: Train Loss: 1.8366, Train Accuracy: 49.89%
# Epoch 64/150: Test Loss: 2.0152, Test Accuracy: 48.15%
#     Worker 0: Train Loss: 1.8154, Train Accuracy: 50.36%
#     Worker 1: Train Loss: 1.8296, Train Accuracy: 50.28%
#     Worker 2: Train Loss: 1.7934, Train Accuracy: 50.81%
#     Worker 3: Train Loss: 1.8066, Train Accuracy: 50.72%
# Epoch 65/150: Test Loss: 2.0103, Test Accuracy: 47.85%
#     Worker 0: Train Loss: 1.7903, Train Accuracy: 51.12%
#     Worker 1: Train Loss: 1.7910, Train Accuracy: 51.33%
#     Worker 2: Train Loss: 1.7684, Train Accuracy: 51.70%
#     Worker 3: Train Loss: 1.7942, Train Accuracy: 51.51%
# Epoch 66/150: Test Loss: 1.9991, Test Accuracy: 48.06%
#     Worker 0: Train Loss: 1.7668, Train Accuracy: 51.43%
#     Worker 1: Train Loss: 1.7893, Train Accuracy: 50.83%
#     Worker 2: Train Loss: 1.7597, Train Accuracy: 52.33%
#     Worker 3: Train Loss: 1.7788, Train Accuracy: 51.42%
# Epoch 67/150: Test Loss: 2.0165, Test Accuracy: 48.37%
#     Worker 0: Train Loss: 1.7550, Train Accuracy: 51.28%
#     Worker 1: Train Loss: 1.7595, Train Accuracy: 52.29%
#     Worker 2: Train Loss: 1.7545, Train Accuracy: 52.08%
#     Worker 3: Train Loss: 1.7632, Train Accuracy: 51.98%
# Epoch 68/150: Test Loss: 1.9987, Test Accuracy: 48.53%
#     Worker 0: Train Loss: 1.7401, Train Accuracy: 51.88%
#     Worker 1: Train Loss: 1.7608, Train Accuracy: 51.66%
#     Worker 2: Train Loss: 1.7484, Train Accuracy: 52.30%
#     Worker 3: Train Loss: 1.7562, Train Accuracy: 51.87%
# Epoch 69/150: Test Loss: 2.0150, Test Accuracy: 48.09%
#     Worker 0: Train Loss: 1.7496, Train Accuracy: 52.25%
#     Worker 1: Train Loss: 1.7381, Train Accuracy: 52.86%
#     Worker 2: Train Loss: 1.7020, Train Accuracy: 52.97%
#     Worker 3: Train Loss: 1.7466, Train Accuracy: 52.09%
# Epoch 70/150: Test Loss: 1.9909, Test Accuracy: 48.67%
#     Worker 0: Train Loss: 1.7190, Train Accuracy: 52.39%
#     Worker 1: Train Loss: 1.7137, Train Accuracy: 52.86%
#     Worker 2: Train Loss: 1.7194, Train Accuracy: 53.04%
#     Worker 3: Train Loss: 1.7482, Train Accuracy: 52.07%
# Epoch 71/150: Test Loss: 1.9869, Test Accuracy: 48.64%
#     Worker 0: Train Loss: 1.7105, Train Accuracy: 52.82%
#     Worker 1: Train Loss: 1.7187, Train Accuracy: 53.35%
#     Worker 2: Train Loss: 1.6915, Train Accuracy: 53.92%
#     Worker 3: Train Loss: 1.7120, Train Accuracy: 53.23%
# Epoch 72/150: Test Loss: 1.9857, Test Accuracy: 49.06%
#     Worker 0: Train Loss: 1.6984, Train Accuracy: 53.11%
#     Worker 1: Train Loss: 1.6959, Train Accuracy: 53.35%
#     Worker 2: Train Loss: 1.7046, Train Accuracy: 52.81%
#     Worker 3: Train Loss: 1.7107, Train Accuracy: 53.14%
# Epoch 73/150: Test Loss: 1.9826, Test Accuracy: 49.23%
#     Worker 0: Train Loss: 1.6840, Train Accuracy: 53.47%
#     Worker 1: Train Loss: 1.6862, Train Accuracy: 53.90%
#     Worker 2: Train Loss: 1.6604, Train Accuracy: 54.37%
#     Worker 3: Train Loss: 1.6922, Train Accuracy: 53.38%
# Epoch 74/150: Test Loss: 1.9917, Test Accuracy: 48.99%
#     Worker 0: Train Loss: 1.6658, Train Accuracy: 53.81%
#     Worker 1: Train Loss: 1.6730, Train Accuracy: 53.48%
#     Worker 2: Train Loss: 1.6533, Train Accuracy: 54.56%
#     Worker 3: Train Loss: 1.6864, Train Accuracy: 53.60%
# Epoch 75/150: Test Loss: 1.9754, Test Accuracy: 49.38%
#     Worker 0: Train Loss: 1.6707, Train Accuracy: 53.68%
#     Worker 1: Train Loss: 1.6923, Train Accuracy: 53.47%
#     Worker 2: Train Loss: 1.6436, Train Accuracy: 54.92%
#     Worker 3: Train Loss: 1.6635, Train Accuracy: 53.97%
# Epoch 76/150: Test Loss: 1.9715, Test Accuracy: 49.30%
#     Worker 0: Train Loss: 1.6253, Train Accuracy: 55.19%
#     Worker 1: Train Loss: 1.6537, Train Accuracy: 54.54%
#     Worker 2: Train Loss: 1.6391, Train Accuracy: 54.73%
#     Worker 3: Train Loss: 1.6456, Train Accuracy: 54.60%
# Epoch 77/150: Test Loss: 1.9669, Test Accuracy: 49.26%
#     Worker 0: Train Loss: 1.6551, Train Accuracy: 53.88%
#     Worker 1: Train Loss: 1.6429, Train Accuracy: 54.19%
#     Worker 2: Train Loss: 1.6172, Train Accuracy: 55.36%
#     Worker 3: Train Loss: 1.6451, Train Accuracy: 54.70%
# Epoch 78/150: Test Loss: 1.9729, Test Accuracy: 49.30%
#     Worker 0: Train Loss: 1.6300, Train Accuracy: 54.61%
#     Worker 1: Train Loss: 1.6094, Train Accuracy: 55.21%
#     Worker 2: Train Loss: 1.6249, Train Accuracy: 55.22%
#     Worker 3: Train Loss: 1.5367, Train Accuracy: 57.43%
# Epoch 88/150: Test Loss: 1.9485, Test Accuracy: 50.78%
#     Worker 0: Train Loss: 1.5169, Train Accuracy: 57.37%
#     Worker 1: Train Loss: 1.5260, Train Accuracy: 57.46%
#     Worker 2: Train Loss: 1.5007, Train Accuracy: 58.86%
#     Worker 3: Train Loss: 1.5203, Train Accuracy: 57.76%
# Epoch 89/150: Test Loss: 1.9502, Test Accuracy: 50.61%
#     Worker 0: Train Loss: 1.5031, Train Accuracy: 57.86%
#     Worker 1: Train Loss: 1.4885, Train Accuracy: 58.71%
#     Worker 2: Train Loss: 1.5026, Train Accuracy: 57.70%
#     Worker 3: Train Loss: 1.5242, Train Accuracy: 57.75%
# Epoch 90/150: Test Loss: 1.9582, Test Accuracy: 50.72%
#     Worker 0: Train Loss: 1.4949, Train Accuracy: 58.16%
#     Worker 1: Train Loss: 1.5046, Train Accuracy: 57.98%
#     Worker 2: Train Loss: 1.4878, Train Accuracy: 58.64%
#     Worker 3: Train Loss: 1.4890, Train Accuracy: 58.74%
# Epoch 91/150: Test Loss: 1.9557, Test Accuracy: 50.51%
#     Worker 0: Train Loss: 1.4943, Train Accuracy: 58.21%
#     Worker 1: Train Loss: 1.4808, Train Accuracy: 58.55%
#     Worker 2: Train Loss: 1.4746, Train Accuracy: 59.06%
#     Worker 3: Train Loss: 1.4953, Train Accuracy: 58.24%
# Epoch 92/150: Test Loss: 1.9589, Test Accuracy: 50.22%
#     Worker 0: Train Loss: 1.4629, Train Accuracy: 59.06%
#     Worker 1: Train Loss: 1.4947, Train Accuracy: 58.53%
#     Worker 2: Train Loss: 1.4763, Train Accuracy: 59.07%
#     Worker 3: Train Loss: 1.4668, Train Accuracy: 58.82%
# Epoch 93/150: Test Loss: 1.9615, Test Accuracy: 50.30%
#     Worker 0: Train Loss: 1.4559, Train Accuracy: 59.01%
#     Worker 1: Train Loss: 1.4667, Train Accuracy: 59.01%
#     Worker 2: Train Loss: 1.4544, Train Accuracy: 59.29%
#     Worker 3: Train Loss: 1.4786, Train Accuracy: 58.93%
# Epoch 94/150: Test Loss: 1.9612, Test Accuracy: 50.67%
#     Worker 0: Train Loss: 1.4490, Train Accuracy: 59.13%
#     Worker 1: Train Loss: 1.4552, Train Accuracy: 59.10%
#     Worker 2: Train Loss: 1.4499, Train Accuracy: 59.24%
#     Worker 3: Train Loss: 1.4617, Train Accuracy: 59.15%
# Epoch 95/150: Test Loss: 1.9569, Test Accuracy: 50.49%
#     Worker 0: Train Loss: 1.4295, Train Accuracy: 59.78%
#     Worker 1: Train Loss: 1.4356, Train Accuracy: 60.04%
#     Worker 2: Train Loss: 1.4443, Train Accuracy: 59.24%
#     Worker 3: Train Loss: 1.4667, Train Accuracy: 59.19%
# Epoch 96/150: Test Loss: 1.9514, Test Accuracy: 50.84%
#     Worker 0: Train Loss: 1.4431, Train Accuracy: 59.31%
#     Worker 1: Train Loss: 1.4663, Train Accuracy: 59.16%
#     Worker 2: Train Loss: 1.4341, Train Accuracy: 59.68%
#     Worker 3: Train Loss: 1.4333, Train Accuracy: 60.12%
# Epoch 97/150: Test Loss: 1.9497, Test Accuracy: 50.98%
#     Worker 0: Train Loss: 1.4226, Train Accuracy: 59.80%
#     Worker 1: Train Loss: 1.4310, Train Accuracy: 59.88%
#     Worker 2: Train Loss: 1.4222, Train Accuracy: 59.92%
#     Worker 3: Train Loss: 1.4064, Train Accuracy: 60.48%
# Epoch 98/150: Test Loss: 1.9514, Test Accuracy: 50.55%
#     Worker 0: Train Loss: 1.4188, Train Accuracy: 59.87%
#     Worker 1: Train Loss: 1.4275, Train Accuracy: 60.01%
#     Worker 2: Train Loss: 1.4020, Train Accuracy: 60.27%
#     Worker 3: Train Loss: 1.4318, Train Accuracy: 59.79%
# Epoch 99/150: Test Loss: 1.9629, Test Accuracy: 50.91%
#     Worker 0: Train Loss: 1.4170, Train Accuracy: 60.05%
#     Worker 1: Train Loss: 1.4066, Train Accuracy: 60.16%
#     Worker 2: Train Loss: 1.4017, Train Accuracy: 60.61%
#     Worker 3: Train Loss: 1.4177, Train Accuracy: 60.64%
# Epoch 100/150: Test Loss: 1.9482, Test Accuracy: 50.76%
#     Worker 0: Train Loss: 1.3923, Train Accuracy: 60.46%
#     Worker 1: Train Loss: 1.3953, Train Accuracy: 60.52%
#     Worker 2: Train Loss: 1.3941, Train Accuracy: 61.25%
#     Worker 3: Train Loss: 1.4076, Train Accuracy: 60.54%
# Epoch 101/150: Test Loss: 1.9593, Test Accuracy: 50.67%
#     Worker 0: Train Loss: 1.3931, Train Accuracy: 60.87%
#     Worker 1: Train Loss: 1.4126, Train Accuracy: 60.37%
#     Worker 2: Train Loss: 1.3775, Train Accuracy: 61.33%
#     Worker 3: Train Loss: 1.4032, Train Accuracy: 60.58%
# Epoch 102/150: Test Loss: 1.9554, Test Accuracy: 50.77%
#     Worker 0: Train Loss: 1.3807, Train Accuracy: 61.02%
#     Worker 1: Train Loss: 1.3884, Train Accuracy: 60.54%
#     Worker 2: Train Loss: 1.3707, Train Accuracy: 61.68%
#     Worker 3: Train Loss: 1.4003, Train Accuracy: 60.87%
# Epoch 103/150: Test Loss: 1.9522, Test Accuracy: 50.75%
#     Worker 0: Train Loss: 1.3763, Train Accuracy: 60.79%
#     Worker 1: Train Loss: 1.3674, Train Accuracy: 61.98%
#     Worker 2: Train Loss: 1.3620, Train Accuracy: 61.01%
#     Worker 3: Train Loss: 1.3890, Train Accuracy: 61.65%
# Epoch 104/150: Test Loss: 1.9613, Test Accuracy: 51.22%
#     Worker 0: Train Loss: 1.3504, Train Accuracy: 61.86%
#     Worker 1: Train Loss: 1.3721, Train Accuracy: 61.08%
#     Worker 2: Train Loss: 1.3663, Train Accuracy: 61.73%
#     Worker 3: Train Loss: 1.3669, Train Accuracy: 61.93%
# Epoch 105/150: Test Loss: 1.9515, Test Accuracy: 51.01%
#     Worker 0: Train Loss: 1.3703, Train Accuracy: 61.02%
#     Worker 1: Train Loss: 1.3516, Train Accuracy: 61.80%
#     Worker 2: Train Loss: 1.3587, Train Accuracy: 61.71%
#     Worker 3: Train Loss: 1.3826, Train Accuracy: 60.84%
# Epoch 106/150: Test Loss: 1.9522, Test Accuracy: 51.05%
#     Worker 0: Train Loss: 1.3526, Train Accuracy: 61.84%
#     Worker 1: Train Loss: 1.3598, Train Accuracy: 62.17%
#     Worker 2: Train Loss: 1.3286, Train Accuracy: 62.33%
#     Worker 3: Train Loss: 1.3677, Train Accuracy: 61.65%
# Epoch 107/150: Test Loss: 1.9614, Test Accuracy: 51.27%
#     Worker 0: Train Loss: 1.3596, Train Accuracy: 61.58%
#     Worker 1: Train Loss: 1.3540, Train Accuracy: 62.09%
#     Worker 2: Train Loss: 1.3412, Train Accuracy: 62.19%
#     Worker 3: Train Loss: 1.3599, Train Accuracy: 61.71%
# Epoch 108/150: Test Loss: 1.9517, Test Accuracy: 50.97%
#     Worker 0: Train Loss: 1.3432, Train Accuracy: 61.92%
#     Worker 1: Train Loss: 1.3462, Train Accuracy: 61.81%
#     Worker 2: Train Loss: 1.3154, Train Accuracy: 62.84%
#     Worker 3: Train Loss: 1.3340, Train Accuracy: 62.65%
# Epoch 109/150: Test Loss: 1.9505, Test Accuracy: 51.23%
#     Worker 0: Train Loss: 1.3331, Train Accuracy: 61.97%
#     Worker 1: Train Loss: 1.3262, Train Accuracy: 62.53%
#     Worker 2: Train Loss: 1.3123, Train Accuracy: 62.97%
#     Worker 3: Train Loss: 1.3586, Train Accuracy: 62.25%
# Epoch 110/150: Test Loss: 1.9514, Test Accuracy: 51.29%
#     Worker 0: Train Loss: 1.3271, Train Accuracy: 62.40%
#     Worker 1: Train Loss: 1.3314, Train Accuracy: 62.41%
#     Worker 2: Train Loss: 1.3247, Train Accuracy: 62.14%
#     Worker 3: Train Loss: 1.3260, Train Accuracy: 62.60%
# Epoch 111/150: Test Loss: 1.9617, Test Accuracy: 51.14%
#     Worker 0: Train Loss: 1.3064, Train Accuracy: 62.33%
#     Worker 1: Train Loss: 1.3179, Train Accuracy: 62.91%
#     Worker 2: Train Loss: 1.2994, Train Accuracy: 62.46%
#     Worker 3: Train Loss: 1.3289, Train Accuracy: 62.28%
# Epoch 112/150: Test Loss: 1.9560, Test Accuracy: 51.46%
#     Worker 0: Train Loss: 1.3188, Train Accuracy: 62.64%
#     Worker 1: Train Loss: 1.3151, Train Accuracy: 62.87%
#     Worker 2: Train Loss: 1.3252, Train Accuracy: 63.05%
#     Worker 3: Train Loss: 1.3166, Train Accuracy: 63.32%
# Epoch 113/150: Test Loss: 1.9575, Test Accuracy: 51.35%
#     Worker 0: Train Loss: 1.3186, Train Accuracy: 62.29%
#     Worker 1: Train Loss: 1.3070, Train Accuracy: 62.81%
#     Worker 2: Train Loss: 1.2919, Train Accuracy: 63.85%
#     Worker 3: Train Loss: 1.3135, Train Accuracy: 63.13%
# Epoch 114/150: Test Loss: 1.9547, Test Accuracy: 51.13%
#     Worker 0: Train Loss: 1.2809, Train Accuracy: 63.26%
#     Worker 1: Train Loss: 1.3061, Train Accuracy: 63.46%
#     Worker 2: Train Loss: 1.2919, Train Accuracy: 63.39%
#     Worker 3: Train Loss: 1.3040, Train Accuracy: 63.68%
# Epoch 115/150: Test Loss: 1.9579, Test Accuracy: 51.27%
#     Worker 0: Train Loss: 1.2793, Train Accuracy: 63.52%
#     Worker 1: Train Loss: 1.2822, Train Accuracy: 63.48%
#     Worker 2: Train Loss: 1.2666, Train Accuracy: 64.01%
#     Worker 3: Train Loss: 1.3025, Train Accuracy: 63.23%
# Epoch 116/150: Test Loss: 1.9605, Test Accuracy: 51.19%
#     Worker 0: Train Loss: 1.2964, Train Accuracy: 62.84%
#     Worker 1: Train Loss: 1.2904, Train Accuracy: 63.57%
#     Worker 2: Train Loss: 1.2866, Train Accuracy: 63.94%
#     Worker 3: Train Loss: 1.2893, Train Accuracy: 63.54%
# Epoch 117/150: Test Loss: 1.9601, Test Accuracy: 51.20%
#     Worker 0: Train Loss: 1.2721, Train Accuracy: 64.30%
#     Worker 1: Train Loss: 1.2814, Train Accuracy: 64.02%
#     Worker 2: Train Loss: 1.2569, Train Accuracy: 64.17%
#     Worker 3: Train Loss: 1.2926, Train Accuracy: 63.57%
# Epoch 118/150: Test Loss: 1.9606, Test Accuracy: 51.53%
#     Worker 0: Train Loss: 1.2817, Train Accuracy: 63.39%
#     Worker 1: Train Loss: 1.2929, Train Accuracy: 63.83%
#     Worker 2: Train Loss: 1.2684, Train Accuracy: 64.36%
#     Worker 3: Train Loss: 1.2816, Train Accuracy: 64.03%
# Epoch 119/150: Test Loss: 1.9594, Test Accuracy: 51.75%
#     Worker 0: Train Loss: 1.2736, Train Accuracy: 64.00%
#     Worker 1: Train Loss: 1.2712, Train Accuracy: 63.85%
#     Worker 2: Train Loss: 1.2566, Train Accuracy: 64.37%
#     Worker 3: Train Loss: 1.2759, Train Accuracy: 63.88%
# Epoch 120/150: Test Loss: 1.9675, Test Accuracy: 51.17%
#     Worker 0: Train Loss: 1.2603, Train Accuracy: 63.72%
#     Worker 1: Train Loss: 1.2565, Train Accuracy: 64.58%
#     Worker 2: Train Loss: 1.2591, Train Accuracy: 64.13%
#     Worker 3: Train Loss: 1.2820, Train Accuracy: 64.01%
# Epoch 121/150: Test Loss: 1.9621, Test Accuracy: 51.25%
#     Worker 0: Train Loss: 1.2605, Train Accuracy: 64.12%
#     Worker 1: Train Loss: 1.2600, Train Accuracy: 64.21%
#     Worker 2: Train Loss: 1.2394, Train Accuracy: 64.70%
#     Worker 3: Train Loss: 1.2442, Train Accuracy: 64.92%
# Epoch 122/150: Test Loss: 1.9615, Test Accuracy: 51.36%
#     Worker 0: Train Loss: 1.2551, Train Accuracy: 63.87%
#     Worker 1: Train Loss: 1.2556, Train Accuracy: 64.93%
#     Worker 2: Train Loss: 1.2599, Train Accuracy: 64.31%
#     Worker 3: Train Loss: 1.2613, Train Accuracy: 64.65%
# Epoch 123/150: Test Loss: 1.9643, Test Accuracy: 51.31%
#     Worker 0: Train Loss: 1.2490, Train Accuracy: 64.58%
#     Worker 1: Train Loss: 1.2395, Train Accuracy: 64.87%
#     Worker 2: Train Loss: 1.2417, Train Accuracy: 64.60%
#     Worker 3: Train Loss: 1.2594, Train Accuracy: 64.46%
# Epoch 124/150: Test Loss: 1.9623, Test Accuracy: 51.39%
#     Worker 0: Train Loss: 1.2463, Train Accuracy: 64.43%
#     Worker 1: Train Loss: 1.2563, Train Accuracy: 64.52%
#     Worker 2: Train Loss: 1.2329, Train Accuracy: 65.04%
#     Worker 3: Train Loss: 1.2702, Train Accuracy: 64.63%
# Epoch 125/150: Test Loss: 1.9664, Test Accuracy: 51.52%
#     Worker 0: Train Loss: 1.2297, Train Accuracy: 65.10%
#     Worker 1: Train Loss: 1.2505, Train Accuracy: 64.88%
#     Worker 2: Train Loss: 1.2355, Train Accuracy: 65.56%
#     Worker 3: Train Loss: 1.2425, Train Accuracy: 64.64%
# Epoch 126/150: Test Loss: 1.9606, Test Accuracy: 51.80%
#     Worker 0: Train Loss: 1.2614, Train Accuracy: 64.17%
#     Worker 1: Train Loss: 1.2395, Train Accuracy: 65.07%
#     Worker 2: Train Loss: 1.2394, Train Accuracy: 65.19%
#     Worker 3: Train Loss: 1.2568, Train Accuracy: 65.25%
# Epoch 127/150: Test Loss: 1.9608, Test Accuracy: 51.64%
#     Worker 0: Train Loss: 1.2234, Train Accuracy: 65.13%
#     Worker 1: Train Loss: 1.2540, Train Accuracy: 64.64%
#     Worker 2: Train Loss: 1.2246, Train Accuracy: 65.38%
#     Worker 3: Train Loss: 1.2377, Train Accuracy: 65.28%
# Epoch 128/150: Test Loss: 1.9629, Test Accuracy: 51.54%
#     Worker 0: Train Loss: 1.2381, Train Accuracy: 64.81%
#     Worker 1: Train Loss: 1.2126, Train Accuracy: 65.52%
#     Worker 2: Train Loss: 1.2154, Train Accuracy: 65.53%
#     Worker 3: Train Loss: 1.2432, Train Accuracy: 64.89%
# Epoch 129/150: Test Loss: 1.9638, Test Accuracy: 51.54%
#     Worker 0: Train Loss: 1.2340, Train Accuracy: 64.82%
#     Worker 1: Train Loss: 1.2303, Train Accuracy: 65.18%
#     Worker 2: Train Loss: 1.2275, Train Accuracy: 65.67%
#     Worker 3: Train Loss: 1.2506, Train Accuracy: 65.01%
# Epoch 130/150: Test Loss: 1.9660, Test Accuracy: 51.97%
#     Worker 0: Train Loss: 1.2228, Train Accuracy: 65.39%
#     Worker 1: Train Loss: 1.2288, Train Accuracy: 65.21%
#     Worker 2: Train Loss: 1.2171, Train Accuracy: 65.75%
#     Worker 3: Train Loss: 1.2297, Train Accuracy: 65.35%
# Epoch 131/150: Test Loss: 1.9647, Test Accuracy: 51.84%
#     Worker 0: Train Loss: 1.2247, Train Accuracy: 64.81%
#     Worker 1: Train Loss: 1.2243, Train Accuracy: 65.76%
#     Worker 2: Train Loss: 1.2169, Train Accuracy: 65.66%
#     Worker 3: Train Loss: 1.2379, Train Accuracy: 65.00%
# Epoch 132/150: Test Loss: 1.9662, Test Accuracy: 51.96%
#     Worker 0: Train Loss: 1.2140, Train Accuracy: 65.35%
#     Worker 1: Train Loss: 1.2107, Train Accuracy: 65.79%
#     Worker 2: Train Loss: 1.2123, Train Accuracy: 65.74%
#     Worker 3: Train Loss: 1.2158, Train Accuracy: 65.98%
# Epoch 133/150: Test Loss: 1.9624, Test Accuracy: 51.79%
#     Worker 0: Train Loss: 1.2281, Train Accuracy: 65.09%
#     Worker 1: Train Loss: 1.2242, Train Accuracy: 65.38%
#     Worker 2: Train Loss: 1.2100, Train Accuracy: 65.50%
#     Worker 3: Train Loss: 1.2226, Train Accuracy: 65.66%
# Epoch 134/150: Test Loss: 1.9639, Test Accuracy: 51.83%
#     Worker 0: Train Loss: 1.2146, Train Accuracy: 65.38%
#     Worker 1: Train Loss: 1.2154, Train Accuracy: 65.99%
#     Worker 2: Train Loss: 1.2177, Train Accuracy: 65.79%
#     Worker 3: Train Loss: 1.2424, Train Accuracy: 65.14%
# Epoch 135/150: Test Loss: 1.9648, Test Accuracy: 51.93%
#     Worker 0: Train Loss: 1.2126, Train Accuracy: 65.47%
#     Worker 1: Train Loss: 1.2040, Train Accuracy: 65.97%
#     Worker 2: Train Loss: 1.1924, Train Accuracy: 66.33%
#     Worker 3: Train Loss: 1.2232, Train Accuracy: 65.47%
# Epoch 136/150: Test Loss: 1.9660, Test Accuracy: 51.74%
#     Worker 0: Train Loss: 1.2142, Train Accuracy: 65.34%
#     Worker 1: Train Loss: 1.2090, Train Accuracy: 65.59%
#     Worker 2: Train Loss: 1.2212, Train Accuracy: 65.53%
#     Worker 3: Train Loss: 1.2022, Train Accuracy: 66.02%
# Epoch 137/150: Test Loss: 1.9635, Test Accuracy: 51.71%
#     Worker 0: Train Loss: 1.1853, Train Accuracy: 66.44%
#     Worker 1: Train Loss: 1.1863, Train Accuracy: 66.01%
#     Worker 2: Train Loss: 1.2132, Train Accuracy: 65.64%
#     Worker 3: Train Loss: 1.2257, Train Accuracy: 65.94%
# Epoch 138/150: Test Loss: 1.9639, Test Accuracy: 51.79%
#     Worker 0: Train Loss: 1.2212, Train Accuracy: 65.10%
#     Worker 1: Train Loss: 1.2194, Train Accuracy: 65.74%
#     Worker 2: Train Loss: 1.1975, Train Accuracy: 66.11%
#     Worker 3: Train Loss: 1.1960, Train Accuracy: 66.31%
# Epoch 139/150: Test Loss: 1.9640, Test Accuracy: 51.98%
#     Worker 0: Train Loss: 1.2107, Train Accuracy: 65.79%
#     Worker 1: Train Loss: 1.1872, Train Accuracy: 66.40%
#     Worker 2: Train Loss: 1.2188, Train Accuracy: 65.77%
#     Worker 3: Train Loss: 1.2047, Train Accuracy: 66.27%
# Epoch 140/150: Test Loss: 1.9629, Test Accuracy: 51.90%
#     Worker 0: Train Loss: 1.2029, Train Accuracy: 65.28%
#     Worker 1: Train Loss: 1.2010, Train Accuracy: 66.31%
#     Worker 2: Train Loss: 1.2062, Train Accuracy: 66.15%
#     Worker 3: Train Loss: 1.2187, Train Accuracy: 65.63%
# Epoch 141/150: Test Loss: 1.9637, Test Accuracy: 51.88%
#     Worker 0: Train Loss: 1.2054, Train Accuracy: 65.47%
#     Worker 1: Train Loss: 1.2056, Train Accuracy: 65.99%
#     Worker 2: Train Loss: 1.1975, Train Accuracy: 66.26%
#     Worker 3: Train Loss: 1.2094, Train Accuracy: 65.95%
# Epoch 142/150: Test Loss: 1.9636, Test Accuracy: 51.92%
#     Worker 0: Train Loss: 1.1942, Train Accuracy: 66.15%
#     Worker 1: Train Loss: 1.1949, Train Accuracy: 66.48%
#     Worker 2: Train Loss: 1.2052, Train Accuracy: 65.66%
#     Worker 3: Train Loss: 1.2168, Train Accuracy: 66.16%
# Epoch 143/150: Test Loss: 1.9630, Test Accuracy: 51.87%
#     Worker 0: Train Loss: 1.2046, Train Accuracy: 65.87%
#     Worker 1: Train Loss: 1.2082, Train Accuracy: 66.04%
#     Worker 2: Train Loss: 1.1870, Train Accuracy: 66.79%
#     Worker 3: Train Loss: 1.2160, Train Accuracy: 65.76%
# Epoch 144/150: Test Loss: 1.9628, Test Accuracy: 51.91%
#     Worker 0: Train Loss: 1.1991, Train Accuracy: 65.78%
#     Worker 1: Train Loss: 1.2036, Train Accuracy: 65.96%
#     Worker 2: Train Loss: 1.2064, Train Accuracy: 65.42%
#     Worker 3: Train Loss: 1.1971, Train Accuracy: 66.21%
# Epoch 145/150: Test Loss: 1.9633, Test Accuracy: 51.94%
#     Worker 0: Train Loss: 1.1919, Train Accuracy: 65.96%
#     Worker 1: Train Loss: 1.1953, Train Accuracy: 66.28%
#     Worker 2: Train Loss: 1.2009, Train Accuracy: 66.60%
#     Worker 3: Train Loss: 1.2109, Train Accuracy: 65.68%
# Epoch 146/150: Test Loss: 1.9632, Test Accuracy: 51.85%
#     Worker 0: Train Loss: 1.2106, Train Accuracy: 65.18%
#     Worker 1: Train Loss: 1.1992, Train Accuracy: 66.11%
#     Worker 2: Train Loss: 1.1946, Train Accuracy: 66.36%
#     Worker 3: Train Loss: 1.2122, Train Accuracy: 65.63%
# Epoch 147/150: Test Loss: 1.9632, Test Accuracy: 51.88%
#     Worker 0: Train Loss: 1.1952, Train Accuracy: 65.75%
#     Worker 1: Train Loss: 1.1952, Train Accuracy: 66.18%
#     Worker 2: Train Loss: 1.1912, Train Accuracy: 66.33%
#     Worker 3: Train Loss: 1.2110, Train Accuracy: 65.69%
# Epoch 148/150: Test Loss: 1.9632, Test Accuracy: 51.91%
#     Worker 0: Train Loss: 1.1921, Train Accuracy: 66.08%
#     Worker 1: Train Loss: 1.2022, Train Accuracy: 66.34%
#     Worker 2: Train Loss: 1.1806, Train Accuracy: 66.45%
#     Worker 3: Train Loss: 1.2032, Train Accuracy: 66.20%
# Epoch 149/150: Test Loss: 1.9633, Test Accuracy: 51.90%
#     Worker 0: Train Loss: 1.2072, Train Accuracy: 65.50%
#     Worker 1: Train Loss: 1.2015, Train Accuracy: 66.00%
#     Worker 2: Train Loss: 1.1929, Train Accuracy: 66.32%
#     Worker 3: Train Loss: 1.2191, Train Accuracy: 65.41%
# Epoch 150/150: Test Loss: 1.9633, Test Accuracy: 51.92%
#     Worker 0: Train Loss: 1.1974, Train Accuracy: 65.46%
#     Worker 1: Train Loss: 1.1961, Train Accuracy: 66.47%
#     Worker 2: Train Loss: 1.1958, Train Accuracy: 66.57%
#     Worker 3: Train Loss: 1.1944, Train Accuracy: 66.01%
