# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 128
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs - warmup_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")

    for iteration in range(global_iteration_per_epoch):
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            # Perform J local step before synchronization
            for j in range(J):
                try:
                    # Get a batch from the current worker's shard using next()
                    images, labels = next(shard_iterators[k])
                    images, labels = images.to(device), labels.to(device)  # Move to device
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * images.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

                except StopIteration:
                    # If the iterator has exhausted the data, restart the iterator
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k]) # Resume from the next batch
                    images, labels = images.to(device), labels.to(device)
                    # Perform optimization step
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * images.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

            # Store train loss and accuracy for this worker
            train_loss /= total_train
            train_losses_per_worker[k].append(train_loss)
            train_accuracy = 100. * correct_train / total_train
            train_accuracies_per_worker[k].append(train_accuracy)

        # Perform model synchronization
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            # Update each worker model with the global parameters
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
        else:
            warmup_factor = (epoch + 1) / warmup_epochs
            lr = warmup_factor * learning_rate
            for optimizer in optimizers:
                for param_group in optimizer.param_groups:
                    param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 4 --j 8
# Out:
# Training with K=4, J=8
# Global iteration per epoch: 25
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:12<00:00, 13.1MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00400
# Epoch 1/150: Test Loss: 4.5808, Test Accuracy: 2.86%
#     Worker 0: Train Loss: 4.5855, Train Accuracy: 2.45%
#     Worker 1: Train Loss: 4.5871, Train Accuracy: 2.14%
#     Worker 2: Train Loss: 4.5790, Train Accuracy: 3.88%
#     Worker 3: Train Loss: 4.5812, Train Accuracy: 1.84%
# Epoch 2/150: Test Loss: 4.5551, Test Accuracy: 3.38%
#     Worker 0: Train Loss: 4.5578, Train Accuracy: 2.25%
#     Worker 1: Train Loss: 4.5592, Train Accuracy: 2.44%
#     Worker 2: Train Loss: 4.5550, Train Accuracy: 4.39%
#     Worker 3: Train Loss: 4.5573, Train Accuracy: 3.03%
# Epoch 3/150: Test Loss: 4.3893, Test Accuracy: 4.78%
#     Worker 0: Train Loss: 4.4071, Train Accuracy: 3.22%
#     Worker 1: Train Loss: 4.3888, Train Accuracy: 5.37%
#     Worker 2: Train Loss: 4.3868, Train Accuracy: 5.18%
#     Worker 3: Train Loss: 4.4167, Train Accuracy: 3.81%
# Epoch 4/150: Test Loss: 4.0531, Test Accuracy: 8.19%
#     Worker 0: Train Loss: 4.0822, Train Accuracy: 7.03%
#     Worker 1: Train Loss: 4.1178, Train Accuracy: 7.23%
#     Worker 2: Train Loss: 4.0767, Train Accuracy: 8.11%
#     Worker 3: Train Loss: 4.1257, Train Accuracy: 8.50%
# Epoch 5/150: Test Loss: 3.8911, Test Accuracy: 11.18%
#     Worker 0: Train Loss: 3.9745, Train Accuracy: 9.77%
#     Worker 1: Train Loss: 3.8837, Train Accuracy: 10.94%
#     Worker 2: Train Loss: 3.9249, Train Accuracy: 9.86%
#     Worker 3: Train Loss: 4.0213, Train Accuracy: 9.08%
# Epoch 6/150: Test Loss: 3.7377, Test Accuracy: 13.66%
#     Worker 0: Train Loss: 3.8598, Train Accuracy: 9.86%
#     Worker 1: Train Loss: 3.8219, Train Accuracy: 12.70%
#     Worker 2: Train Loss: 3.7432, Train Accuracy: 14.75%
#     Worker 3: Train Loss: 3.8284, Train Accuracy: 12.60%
# Epoch 7/150: Test Loss: 3.6050, Test Accuracy: 16.00%
#     Worker 0: Train Loss: 3.7363, Train Accuracy: 12.30%
#     Worker 1: Train Loss: 3.6856, Train Accuracy: 14.06%
#     Worker 2: Train Loss: 3.6999, Train Accuracy: 14.26%
#     Worker 3: Train Loss: 3.7100, Train Accuracy: 12.60%
# Epoch 8/150: Test Loss: 3.4871, Test Accuracy: 18.22%
#     Worker 0: Train Loss: 3.5936, Train Accuracy: 15.43%
#     Worker 1: Train Loss: 3.5135, Train Accuracy: 16.41%
#     Worker 2: Train Loss: 3.4948, Train Accuracy: 17.19%
#     Worker 3: Train Loss: 3.6240, Train Accuracy: 14.55%
# Epoch 9/150: Test Loss: 3.4051, Test Accuracy: 19.18%
#     Worker 0: Train Loss: 3.4158, Train Accuracy: 19.34%
#     Worker 1: Train Loss: 3.5498, Train Accuracy: 17.38%
#     Worker 2: Train Loss: 3.3556, Train Accuracy: 20.41%
#     Worker 3: Train Loss: 3.5432, Train Accuracy: 17.29%
# Epoch 10/150: Test Loss: 3.2966, Test Accuracy: 21.23%
#     Worker 0: Train Loss: 3.4264, Train Accuracy: 18.07%
#     Worker 1: Train Loss: 3.4182, Train Accuracy: 20.31%
#     Worker 2: Train Loss: 3.3046, Train Accuracy: 20.41%
#     Worker 3: Train Loss: 3.4192, Train Accuracy: 18.16%
# Epoch 11/150: Test Loss: 3.1976, Test Accuracy: 23.18%
#     Worker 0: Train Loss: 3.3384, Train Accuracy: 19.92%
#     Worker 1: Train Loss: 3.3252, Train Accuracy: 22.27%
#     Worker 2: Train Loss: 3.1952, Train Accuracy: 21.58%
#     Worker 3: Train Loss: 3.3462, Train Accuracy: 19.14%
# Epoch 12/150: Test Loss: 3.1186, Test Accuracy: 24.51%
#     Worker 0: Train Loss: 3.1920, Train Accuracy: 22.07%
#     Worker 1: Train Loss: 3.2875, Train Accuracy: 20.21%
#     Worker 2: Train Loss: 3.0431, Train Accuracy: 25.59%
#     Worker 3: Train Loss: 3.2668, Train Accuracy: 20.12%
# Epoch 13/150: Test Loss: 3.0326, Test Accuracy: 26.15%
#     Worker 0: Train Loss: 3.0801, Train Accuracy: 25.59%
#     Worker 1: Train Loss: 3.1758, Train Accuracy: 22.66%
#     Worker 2: Train Loss: 3.0866, Train Accuracy: 24.41%
#     Worker 3: Train Loss: 3.1492, Train Accuracy: 23.54%
# Epoch 14/150: Test Loss: 2.9654, Test Accuracy: 27.31%
#     Worker 0: Train Loss: 3.0813, Train Accuracy: 23.83%
#     Worker 1: Train Loss: 3.1015, Train Accuracy: 26.27%
#     Worker 2: Train Loss: 3.0854, Train Accuracy: 24.12%
#     Worker 3: Train Loss: 2.9939, Train Accuracy: 26.17%
# Epoch 15/150: Test Loss: 2.8884, Test Accuracy: 28.97%
#     Worker 0: Train Loss: 3.0076, Train Accuracy: 27.83%
#     Worker 1: Train Loss: 3.0102, Train Accuracy: 25.29%
#     Worker 2: Train Loss: 2.9204, Train Accuracy: 28.03%
#     Worker 3: Train Loss: 3.0478, Train Accuracy: 25.29%
# Epoch 16/150: Test Loss: 2.8166, Test Accuracy: 30.16%
#     Worker 0: Train Loss: 2.9282, Train Accuracy: 28.03%
#     Worker 1: Train Loss: 2.9479, Train Accuracy: 26.86%
#     Worker 2: Train Loss: 2.8580, Train Accuracy: 30.47%
#     Worker 3: Train Loss: 2.4854, Train Accuracy: 36.53%
# Epoch 26/150: Test Loss: 2.3984, Test Accuracy: 38.38%
#     Worker 0: Train Loss: 2.3993, Train Accuracy: 37.86%
#     Worker 1: Train Loss: 2.4395, Train Accuracy: 36.63%
#     Worker 2: Train Loss: 2.4058, Train Accuracy: 37.04%
#     Worker 3: Train Loss: 2.4042, Train Accuracy: 36.94%
# Epoch 27/150: Test Loss: 2.3750, Test Accuracy: 38.70%
#     Worker 0: Train Loss: 2.3925, Train Accuracy: 38.48%
#     Worker 1: Train Loss: 2.4658, Train Accuracy: 37.40%
#     Worker 2: Train Loss: 2.3313, Train Accuracy: 40.82%
#     Worker 3: Train Loss: 2.4488, Train Accuracy: 34.77%
# Epoch 28/150: Test Loss: 2.3349, Test Accuracy: 39.80%
#     Worker 0: Train Loss: 2.3529, Train Accuracy: 40.23%
#     Worker 1: Train Loss: 2.4144, Train Accuracy: 38.38%
#     Worker 2: Train Loss: 2.3243, Train Accuracy: 38.38%
#     Worker 3: Train Loss: 2.3062, Train Accuracy: 39.06%
# Epoch 29/150: Test Loss: 2.3292, Test Accuracy: 40.13%
#     Worker 0: Train Loss: 2.2392, Train Accuracy: 39.65%
#     Worker 1: Train Loss: 2.4046, Train Accuracy: 37.40%
#     Worker 2: Train Loss: 2.2843, Train Accuracy: 41.21%
#     Worker 3: Train Loss: 2.2818, Train Accuracy: 40.72%
# Epoch 30/150: Test Loss: 2.2916, Test Accuracy: 40.76%
#     Worker 0: Train Loss: 2.3312, Train Accuracy: 39.06%
#     Worker 1: Train Loss: 2.2693, Train Accuracy: 41.70%
#     Worker 2: Train Loss: 2.2752, Train Accuracy: 42.97%
#     Worker 3: Train Loss: 2.3246, Train Accuracy: 39.55%
# Epoch 31/150: Test Loss: 2.2825, Test Accuracy: 40.81%
#     Worker 0: Train Loss: 2.2629, Train Accuracy: 40.53%
#     Worker 1: Train Loss: 2.2402, Train Accuracy: 43.46%
#     Worker 2: Train Loss: 2.2985, Train Accuracy: 40.62%
#     Worker 3: Train Loss: 2.2619, Train Accuracy: 40.72%
# Epoch 32/150: Test Loss: 2.2589, Test Accuracy: 41.51%
#     Worker 0: Train Loss: 2.2146, Train Accuracy: 42.48%
#     Worker 1: Train Loss: 2.2107, Train Accuracy: 42.77%
#     Worker 2: Train Loss: 2.2457, Train Accuracy: 42.09%
#     Worker 3: Train Loss: 2.2561, Train Accuracy: 40.14%
# Epoch 33/150: Test Loss: 2.2462, Test Accuracy: 41.48%
#     Worker 0: Train Loss: 2.2945, Train Accuracy: 40.43%
#     Worker 1: Train Loss: 2.2577, Train Accuracy: 41.89%
#     Worker 2: Train Loss: 2.2485, Train Accuracy: 41.02%
#     Worker 3: Train Loss: 2.2794, Train Accuracy: 40.53%
# Epoch 34/150: Test Loss: 2.2238, Test Accuracy: 42.24%
#     Worker 0: Train Loss: 2.2456, Train Accuracy: 41.02%
#     Worker 1: Train Loss: 2.2167, Train Accuracy: 41.70%
#     Worker 2: Train Loss: 2.1901, Train Accuracy: 41.80%
#     Worker 3: Train Loss: 2.2057, Train Accuracy: 40.43%
# Epoch 35/150: Test Loss: 2.2048, Test Accuracy: 42.51%
#     Worker 0: Train Loss: 2.1057, Train Accuracy: 43.46%
#     Worker 1: Train Loss: 2.2558, Train Accuracy: 43.16%
#     Worker 2: Train Loss: 2.1604, Train Accuracy: 43.36%
#     Worker 3: Train Loss: 2.2256, Train Accuracy: 41.02%
# Epoch 36/150: Test Loss: 2.2067, Test Accuracy: 42.29%
#     Worker 0: Train Loss: 2.1881, Train Accuracy: 42.09%
#     Worker 1: Train Loss: 2.1652, Train Accuracy: 43.26%
#     Worker 2: Train Loss: 2.2036, Train Accuracy: 42.58%
#     Worker 3: Train Loss: 2.2580, Train Accuracy: 40.23%
# Epoch 37/150: Test Loss: 2.1858, Test Accuracy: 42.88%
#     Worker 0: Train Loss: 2.0232, Train Accuracy: 45.12%
#     Worker 1: Train Loss: 2.0707, Train Accuracy: 45.80%
#     Worker 2: Train Loss: 2.0847, Train Accuracy: 46.48%
#     Worker 3: Train Loss: 2.1930, Train Accuracy: 41.41%
# Epoch 38/150: Test Loss: 2.1697, Test Accuracy: 43.68%
#     Worker 0: Train Loss: 2.0570, Train Accuracy: 44.43%
#     Worker 1: Train Loss: 2.0941, Train Accuracy: 44.82%
#     Worker 2: Train Loss: 2.1806, Train Accuracy: 41.60%
#     Worker 3: Train Loss: 2.0553, Train Accuracy: 46.09%
# Epoch 39/150: Test Loss: 2.1704, Test Accuracy: 43.14%
#     Worker 0: Train Loss: 2.2052, Train Accuracy: 41.89%
#     Worker 1: Train Loss: 2.0297, Train Accuracy: 44.14%
#     Worker 2: Train Loss: 2.1417, Train Accuracy: 45.51%
#     Worker 3: Train Loss: 2.0726, Train Accuracy: 44.43%
# Epoch 40/150: Test Loss: 2.1371, Test Accuracy: 44.28%
#     Worker 0: Train Loss: 2.1244, Train Accuracy: 45.41%
#     Worker 1: Train Loss: 2.0334, Train Accuracy: 46.48%
#     Worker 2: Train Loss: 1.9722, Train Accuracy: 49.41%
#     Worker 3: Train Loss: 1.9927, Train Accuracy: 45.70%
# Epoch 41/150: Test Loss: 2.1479, Test Accuracy: 44.31%
#     Worker 0: Train Loss: 2.0379, Train Accuracy: 45.70%
#     Worker 1: Train Loss: 1.9836, Train Accuracy: 47.36%
#     Worker 2: Train Loss: 2.0635, Train Accuracy: 46.19%
#     Worker 3: Train Loss: 2.0876, Train Accuracy: 45.21%
# Epoch 42/150: Test Loss: 2.1183, Test Accuracy: 44.71%
#     Worker 0: Train Loss: 2.0107, Train Accuracy: 44.43%
#     Worker 1: Train Loss: 2.0226, Train Accuracy: 46.48%
#     Worker 2: Train Loss: 2.0430, Train Accuracy: 46.39%
#     Worker 3: Train Loss: 2.0613, Train Accuracy: 47.95%
# Epoch 43/150: Test Loss: 2.1140, Test Accuracy: 45.13%
#     Worker 0: Train Loss: 1.9702, Train Accuracy: 48.05%
#     Worker 1: Train Loss: 1.9894, Train Accuracy: 46.00%
#     Worker 1: Train Loss: 1.4946, Train Accuracy: 60.84%
#     Worker 2: Train Loss: 1.4427, Train Accuracy: 59.08%
#     Worker 3: Train Loss: 1.4908, Train Accuracy: 58.30%
# Epoch 80/150: Test Loss: 2.0052, Test Accuracy: 49.72%
#     Worker 0: Train Loss: 1.3948, Train Accuracy: 60.45%
#     Worker 1: Train Loss: 1.4355, Train Accuracy: 60.74%
#     Worker 2: Train Loss: 1.4550, Train Accuracy: 60.45%
#     Worker 3: Train Loss: 1.5153, Train Accuracy: 58.01%
# Epoch 81/150: Test Loss: 1.9849, Test Accuracy: 49.93%
#     Worker 0: Train Loss: 1.5096, Train Accuracy: 58.30%
#     Worker 1: Train Loss: 1.4121, Train Accuracy: 61.13%
#     Worker 2: Train Loss: 1.3820, Train Accuracy: 60.16%
#     Worker 3: Train Loss: 1.4479, Train Accuracy: 59.38%
# Epoch 82/150: Test Loss: 1.9944, Test Accuracy: 50.21%
#     Worker 0: Train Loss: 1.5541, Train Accuracy: 55.37%
#     Worker 1: Train Loss: 1.4168, Train Accuracy: 60.06%
#     Worker 2: Train Loss: 1.3566, Train Accuracy: 60.45%
#     Worker 3: Train Loss: 1.4743, Train Accuracy: 59.67%
# Epoch 83/150: Test Loss: 1.9986, Test Accuracy: 50.03%
#     Worker 0: Train Loss: 1.3745, Train Accuracy: 59.57%
#     Worker 1: Train Loss: 1.4211, Train Accuracy: 59.18%
#     Worker 2: Train Loss: 1.4577, Train Accuracy: 59.86%
#     Worker 3: Train Loss: 1.4388, Train Accuracy: 59.77%
# Epoch 84/150: Test Loss: 1.9838, Test Accuracy: 50.12%
#     Worker 0: Train Loss: 1.4858, Train Accuracy: 56.84%
#     Worker 1: Train Loss: 1.3795, Train Accuracy: 62.79%
#     Worker 2: Train Loss: 1.4370, Train Accuracy: 60.35%
#     Worker 3: Train Loss: 1.4162, Train Accuracy: 60.06%
# Epoch 85/150: Test Loss: 2.0029, Test Accuracy: 50.09%
#     Worker 0: Train Loss: 1.4750, Train Accuracy: 58.98%
#     Worker 1: Train Loss: 1.3306, Train Accuracy: 62.40%
#     Worker 2: Train Loss: 1.2787, Train Accuracy: 66.11%
#     Worker 3: Train Loss: 1.4264, Train Accuracy: 58.01%
# Epoch 86/150: Test Loss: 2.0039, Test Accuracy: 49.48%
#     Worker 0: Train Loss: 1.3295, Train Accuracy: 62.11%
#     Worker 1: Train Loss: 1.3480, Train Accuracy: 62.01%
#     Worker 2: Train Loss: 1.3929, Train Accuracy: 61.91%
#     Worker 3: Train Loss: 1.4477, Train Accuracy: 58.79%
# Epoch 87/150: Test Loss: 1.9902, Test Accuracy: 49.95%
#     Worker 0: Train Loss: 1.3797, Train Accuracy: 61.04%
#     Worker 1: Train Loss: 1.4060, Train Accuracy: 62.40%
#     Worker 2: Train Loss: 1.4094, Train Accuracy: 60.45%
#     Worker 3: Train Loss: 1.3704, Train Accuracy: 62.11%
# Epoch 88/150: Test Loss: 2.0007, Test Accuracy: 50.01%
#     Worker 0: Train Loss: 1.3537, Train Accuracy: 62.30%
#     Worker 1: Train Loss: 1.3680, Train Accuracy: 59.86%
#     Worker 2: Train Loss: 1.3757, Train Accuracy: 62.50%
#     Worker 3: Train Loss: 1.3746, Train Accuracy: 60.16%
# Epoch 89/150: Test Loss: 1.9930, Test Accuracy: 50.20%
#     Worker 0: Train Loss: 1.3071, Train Accuracy: 62.99%
#     Worker 1: Train Loss: 1.2352, Train Accuracy: 65.72%
#     Worker 2: Train Loss: 1.3647, Train Accuracy: 62.11%
#     Worker 3: Train Loss: 1.3918, Train Accuracy: 60.25%
# Epoch 90/150: Test Loss: 1.9814, Test Accuracy: 50.64%
#     Worker 0: Train Loss: 1.3808, Train Accuracy: 61.72%
#     Worker 1: Train Loss: 1.3772, Train Accuracy: 62.30%
#     Worker 2: Train Loss: 1.2973, Train Accuracy: 63.48%
#     Worker 3: Train Loss: 1.3728, Train Accuracy: 62.01%
# Epoch 91/150: Test Loss: 1.9992, Test Accuracy: 50.35%
#     Worker 0: Train Loss: 1.3092, Train Accuracy: 62.60%
#     Worker 1: Train Loss: 1.3431, Train Accuracy: 62.21%
#     Worker 2: Train Loss: 1.4041, Train Accuracy: 59.86%
#     Worker 3: Train Loss: 1.3574, Train Accuracy: 60.64%
# Epoch 92/150: Test Loss: 1.9942, Test Accuracy: 50.37%
#     Worker 0: Train Loss: 1.2221, Train Accuracy: 66.21%
#     Worker 1: Train Loss: 1.3331, Train Accuracy: 61.33%
#     Worker 2: Train Loss: 1.4084, Train Accuracy: 60.94%
#     Worker 3: Train Loss: 1.4135, Train Accuracy: 60.64%
# Epoch 93/150: Test Loss: 1.9922, Test Accuracy: 50.37%
#     Worker 0: Train Loss: 1.3730, Train Accuracy: 61.43%
#     Worker 1: Train Loss: 1.3876, Train Accuracy: 61.23%
#     Worker 2: Train Loss: 1.3379, Train Accuracy: 61.72%
#     Worker 3: Train Loss: 1.3894, Train Accuracy: 60.84%
# Epoch 94/150: Test Loss: 1.9994, Test Accuracy: 50.38%
#     Worker 0: Train Loss: 1.2706, Train Accuracy: 64.36%
#     Worker 1: Train Loss: 1.3387, Train Accuracy: 60.94%
#     Worker 2: Train Loss: 1.3843, Train Accuracy: 60.84%
#     Worker 3: Train Loss: 1.3574, Train Accuracy: 60.74%
# Epoch 95/150: Test Loss: 1.9992, Test Accuracy: 50.23%
#     Worker 0: Train Loss: 1.3491, Train Accuracy: 57.62%
#     Worker 1: Train Loss: 1.3454, Train Accuracy: 59.47%
#     Worker 2: Train Loss: 1.2259, Train Accuracy: 64.65%
#     Worker 3: Train Loss: 1.3263, Train Accuracy: 62.89%
# Epoch 96/150: Test Loss: 1.9977, Test Accuracy: 50.39%
#     Worker 0: Train Loss: 1.4271, Train Accuracy: 59.47%
#     Worker 1: Train Loss: 1.3537, Train Accuracy: 62.21%
#     Worker 2: Train Loss: 1.3465, Train Accuracy: 62.01%
#     Worker 3: Train Loss: 1.4172, Train Accuracy: 59.28%
# Epoch 97/150: Test Loss: 1.9936, Test Accuracy: 50.82%
#     Worker 0: Train Loss: 1.2295, Train Accuracy: 64.16%
#     Worker 1: Train Loss: 1.2714, Train Accuracy: 63.38%
#     Worker 2: Train Loss: 1.3076, Train Accuracy: 61.72%
#     Worker 3: Train Loss: 1.2950, Train Accuracy: 63.67%
# Epoch 98/150: Test Loss: 1.9975, Test Accuracy: 50.72%
#     Worker 0: Train Loss: 1.4156, Train Accuracy: 60.82%
#     Worker 1: Train Loss: 1.2574, Train Accuracy: 64.80%
#     Worker 2: Train Loss: 1.2888, Train Accuracy: 63.57%
#     Worker 3: Train Loss: 1.2982, Train Accuracy: 62.86%
# Epoch 99/150: Test Loss: 2.0028, Test Accuracy: 50.66%
#     Worker 0: Train Loss: 1.2052, Train Accuracy: 65.10%
#     Worker 1: Train Loss: 1.2218, Train Accuracy: 65.20%
#     Worker 2: Train Loss: 1.3167, Train Accuracy: 64.08%
#     Worker 3: Train Loss: 1.3317, Train Accuracy: 64.18%
# Epoch 100/150: Test Loss: 2.0061, Test Accuracy: 50.71%
#     Worker 0: Train Loss: 1.1960, Train Accuracy: 65.43%
#     Worker 1: Train Loss: 1.2388, Train Accuracy: 63.67%
#     Worker 2: Train Loss: 1.1906, Train Accuracy: 65.82%
#     Worker 3: Train Loss: 1.2972, Train Accuracy: 61.82%
# Epoch 101/150: Test Loss: 2.0034, Test Accuracy: 50.91%
#     Worker 0: Train Loss: 1.2938, Train Accuracy: 62.60%
#     Worker 1: Train Loss: 1.2733, Train Accuracy: 64.45%
#     Worker 2: Train Loss: 1.2843, Train Accuracy: 64.55%
#     Worker 3: Train Loss: 1.3121, Train Accuracy: 62.21%
# Epoch 102/150: Test Loss: 2.0099, Test Accuracy: 50.85%
#     Worker 0: Train Loss: 1.2633, Train Accuracy: 62.30%
#     Worker 1: Train Loss: 1.2289, Train Accuracy: 65.62%
#     Worker 2: Train Loss: 1.2028, Train Accuracy: 65.33%
#     Worker 3: Train Loss: 1.2492, Train Accuracy: 66.89%
# Epoch 103/150: Test Loss: 2.0099, Test Accuracy: 50.56%
#     Worker 0: Train Loss: 1.2826, Train Accuracy: 64.75%
#     Worker 1: Train Loss: 1.2677, Train Accuracy: 63.48%
#     Worker 2: Train Loss: 1.2154, Train Accuracy: 66.02%
#     Worker 3: Train Loss: 1.2486, Train Accuracy: 64.55%
# Epoch 104/150: Test Loss: 2.0099, Test Accuracy: 50.81%
#     Worker 0: Train Loss: 1.2525, Train Accuracy: 65.33%
#     Worker 1: Train Loss: 1.2696, Train Accuracy: 64.45%
#     Worker 2: Train Loss: 1.2362, Train Accuracy: 64.45%
#     Worker 3: Train Loss: 1.2122, Train Accuracy: 66.11%
# Epoch 105/150: Test Loss: 2.0068, Test Accuracy: 50.92%
#     Worker 0: Train Loss: 1.3204, Train Accuracy: 63.28%
#     Worker 1: Train Loss: 1.2378, Train Accuracy: 64.84%
#     Worker 2: Train Loss: 1.2600, Train Accuracy: 64.84%
#     Worker 3: Train Loss: 1.2323, Train Accuracy: 64.65%
# Epoch 106/150: Test Loss: 2.0062, Test Accuracy: 50.71%
#     Worker 0: Train Loss: 1.2181, Train Accuracy: 66.31%
#     Worker 1: Train Loss: 1.1659, Train Accuracy: 66.80%
#     Worker 2: Train Loss: 1.2595, Train Accuracy: 64.36%
#     Worker 3: Train Loss: 1.1804, Train Accuracy: 64.84%
# Epoch 107/150: Test Loss: 2.0070, Test Accuracy: 50.81%
#     Worker 0: Train Loss: 1.2997, Train Accuracy: 62.79%
#     Worker 1: Train Loss: 1.2069, Train Accuracy: 65.23%
#     Worker 2: Train Loss: 1.2269, Train Accuracy: 65.33%
#     Worker 3: Train Loss: 1.2486, Train Accuracy: 64.84%
# Epoch 108/150: Test Loss: 2.0260, Test Accuracy: 50.39%
#     Worker 0: Train Loss: 1.2752, Train Accuracy: 63.67%
#     Worker 1: Train Loss: 1.1761, Train Accuracy: 67.58%
#     Worker 2: Train Loss: 1.1837, Train Accuracy: 66.21%
#     Worker 3: Train Loss: 1.1552, Train Accuracy: 67.38%
# Epoch 109/150: Test Loss: 2.0104, Test Accuracy: 50.70%
#     Worker 0: Train Loss: 1.1513, Train Accuracy: 65.82%
#     Worker 1: Train Loss: 1.2949, Train Accuracy: 62.99%
#     Worker 2: Train Loss: 1.1685, Train Accuracy: 66.31%
#     Worker 3: Train Loss: 1.2393, Train Accuracy: 64.65%
# Epoch 110/150: Test Loss: 2.0145, Test Accuracy: 50.74%
#     Worker 0: Train Loss: 1.2468, Train Accuracy: 63.67%
#     Worker 1: Train Loss: 1.1639, Train Accuracy: 64.55%
#     Worker 2: Train Loss: 1.2316, Train Accuracy: 65.43%
#     Worker 3: Train Loss: 1.2755, Train Accuracy: 64.16%
# Epoch 111/150: Test Loss: 2.0157, Test Accuracy: 50.80%
#     Worker 0: Train Loss: 1.1603, Train Accuracy: 66.89%
#     Worker 1: Train Loss: 1.1523, Train Accuracy: 68.75%
#     Worker 2: Train Loss: 1.1783, Train Accuracy: 64.16%
#     Worker 3: Train Loss: 1.2471, Train Accuracy: 65.33%
# Epoch 112/150: Test Loss: 2.0172, Test Accuracy: 50.37%
#     Worker 0: Train Loss: 1.2404, Train Accuracy: 64.75%
#     Worker 1: Train Loss: 1.2473, Train Accuracy: 65.62%
#     Worker 2: Train Loss: 1.1948, Train Accuracy: 65.33%
#     Worker 3: Train Loss: 1.1999, Train Accuracy: 64.75%
# Epoch 113/150: Test Loss: 2.0262, Test Accuracy: 50.61%
#     Worker 0: Train Loss: 1.2272, Train Accuracy: 64.65%
#     Worker 1: Train Loss: 1.1577, Train Accuracy: 66.41%
#     Worker 2: Train Loss: 1.1892, Train Accuracy: 64.36%
#     Worker 3: Train Loss: 1.1826, Train Accuracy: 66.70%
# Epoch 114/150: Test Loss: 2.0178, Test Accuracy: 50.87%
#     Worker 0: Train Loss: 1.1952, Train Accuracy: 66.60%
#     Worker 1: Train Loss: 1.1907, Train Accuracy: 66.99%
#     Worker 2: Train Loss: 1.1187, Train Accuracy: 67.97%
#     Worker 3: Train Loss: 1.1684, Train Accuracy: 66.89%
# Epoch 115/150: Test Loss: 2.0168, Test Accuracy: 50.86%
#     Worker 0: Train Loss: 1.1684, Train Accuracy: 65.92%
#     Worker 1: Train Loss: 1.2226, Train Accuracy: 63.87%
#     Worker 2: Train Loss: 1.2659, Train Accuracy: 66.21%
#     Worker 3: Train Loss: 1.1527, Train Accuracy: 66.02%
# Epoch 116/150: Test Loss: 2.0191, Test Accuracy: 50.80%
#     Worker 0: Train Loss: 1.1132, Train Accuracy: 66.80%
#     Worker 1: Train Loss: 1.0969, Train Accuracy: 69.63%
#     Worker 2: Train Loss: 1.1255, Train Accuracy: 67.68%
#     Worker 3: Train Loss: 1.2078, Train Accuracy: 66.60%
# Epoch 117/150: Test Loss: 2.0256, Test Accuracy: 51.00%
#     Worker 0: Train Loss: 1.2183, Train Accuracy: 63.09%
#     Worker 1: Train Loss: 1.1509, Train Accuracy: 67.58%
#     Worker 2: Train Loss: 1.1248, Train Accuracy: 67.09%
#     Worker 3: Train Loss: 1.1553, Train Accuracy: 66.41%
# Epoch 118/150: Test Loss: 2.0175, Test Accuracy: 51.13%
#     Worker 0: Train Loss: 1.1873, Train Accuracy: 67.19%
#     Worker 1: Train Loss: 1.2160, Train Accuracy: 65.53%
#     Worker 2: Train Loss: 1.1955, Train Accuracy: 66.70%
#     Worker 3: Train Loss: 1.1164, Train Accuracy: 67.29%
# Epoch 119/150: Test Loss: 2.0253, Test Accuracy: 50.82%
#     Worker 0: Train Loss: 1.1397, Train Accuracy: 68.65%
#     Worker 1: Train Loss: 1.1270, Train Accuracy: 68.55%
#     Worker 2: Train Loss: 1.1740, Train Accuracy: 65.82%
#     Worker 3: Train Loss: 1.1694, Train Accuracy: 66.99%
# Epoch 120/150: Test Loss: 2.0216, Test Accuracy: 50.97%
#     Worker 0: Train Loss: 1.1931, Train Accuracy: 66.31%
#     Worker 1: Train Loss: 1.1749, Train Accuracy: 65.92%
#     Worker 2: Train Loss: 1.1582, Train Accuracy: 65.53%
#     Worker 3: Train Loss: 1.1866, Train Accuracy: 66.41%
# Epoch 121/150: Test Loss: 2.0286, Test Accuracy: 51.24%
#     Worker 0: Train Loss: 1.1417, Train Accuracy: 67.29%
#     Worker 1: Train Loss: 1.1756, Train Accuracy: 67.09%
#     Worker 2: Train Loss: 1.1665, Train Accuracy: 68.07%
#     Worker 3: Train Loss: 1.2201, Train Accuracy: 65.72%
# Epoch 122/150: Test Loss: 2.0249, Test Accuracy: 50.94%
#     Worker 0: Train Loss: 1.1385, Train Accuracy: 66.60%
#     Worker 1: Train Loss: 1.1107, Train Accuracy: 68.07%
#     Worker 2: Train Loss: 1.0733, Train Accuracy: 70.21%
#     Worker 3: Train Loss: 1.1976, Train Accuracy: 66.31%
# Epoch 123/150: Test Loss: 2.0253, Test Accuracy: 50.74%
#     Worker 0: Train Loss: 1.1333, Train Accuracy: 67.96%
#     Worker 1: Train Loss: 1.2330, Train Accuracy: 65.20%
#     Worker 2: Train Loss: 1.1230, Train Accuracy: 68.27%
#     Worker 3: Train Loss: 1.1694, Train Accuracy: 67.04%
# Epoch 124/150: Test Loss: 2.0312, Test Accuracy: 50.93%
#     Worker 0: Train Loss: 1.1576, Train Accuracy: 68.06%
#     Worker 1: Train Loss: 1.1412, Train Accuracy: 67.55%
#     Worker 2: Train Loss: 1.1141, Train Accuracy: 66.73%
#     Worker 3: Train Loss: 1.1656, Train Accuracy: 68.16%
# Epoch 125/150: Test Loss: 2.0253, Test Accuracy: 51.02%
#     Worker 0: Train Loss: 1.0691, Train Accuracy: 70.21%
#     Worker 1: Train Loss: 1.0986, Train Accuracy: 69.53%
#     Worker 2: Train Loss: 1.0951, Train Accuracy: 68.55%
#     Worker 3: Train Loss: 1.1172, Train Accuracy: 69.73%
# Epoch 126/150: Test Loss: 2.0303, Test Accuracy: 50.87%
#     Worker 0: Train Loss: 1.1679, Train Accuracy: 67.29%
#     Worker 1: Train Loss: 1.1308, Train Accuracy: 68.46%
#     Worker 2: Train Loss: 1.1288, Train Accuracy: 68.55%
#     Worker 3: Train Loss: 1.1897, Train Accuracy: 66.11%
# Epoch 127/150: Test Loss: 2.0295, Test Accuracy: 51.11%
#     Worker 0: Train Loss: 1.0853, Train Accuracy: 69.92%
#     Worker 1: Train Loss: 1.0901, Train Accuracy: 68.85%
#     Worker 2: Train Loss: 1.1147, Train Accuracy: 68.16%
#     Worker 3: Train Loss: 1.1537, Train Accuracy: 67.38%
# Epoch 128/150: Test Loss: 2.0288, Test Accuracy: 51.08%
#     Worker 0: Train Loss: 1.1747, Train Accuracy: 66.41%
#     Worker 1: Train Loss: 1.1043, Train Accuracy: 67.77%
#     Worker 2: Train Loss: 1.0780, Train Accuracy: 68.36%
#     Worker 3: Train Loss: 1.1494, Train Accuracy: 67.48%
# Epoch 129/150: Test Loss: 2.0324, Test Accuracy: 50.91%
#     Worker 0: Train Loss: 1.1612, Train Accuracy: 67.97%
#     Worker 1: Train Loss: 1.1243, Train Accuracy: 68.95%
#     Worker 2: Train Loss: 1.0602, Train Accuracy: 69.63%
#     Worker 3: Train Loss: 1.0966, Train Accuracy: 68.85%
# Epoch 130/150: Test Loss: 2.0271, Test Accuracy: 50.98%
#     Worker 0: Train Loss: 1.1927, Train Accuracy: 67.48%
#     Worker 1: Train Loss: 1.1517, Train Accuracy: 66.99%
#     Worker 2: Train Loss: 1.1569, Train Accuracy: 67.68%
#     Worker 3: Train Loss: 1.0693, Train Accuracy: 71.19%
# Epoch 131/150: Test Loss: 2.0311, Test Accuracy: 51.00%
#     Worker 0: Train Loss: 1.1216, Train Accuracy: 66.89%
#     Worker 1: Train Loss: 1.0955, Train Accuracy: 68.75%
#     Worker 2: Train Loss: 1.1350, Train Accuracy: 68.85%
#     Worker 3: Train Loss: 1.0587, Train Accuracy: 68.46%
# Epoch 132/150: Test Loss: 2.0307, Test Accuracy: 51.07%
#     Worker 0: Train Loss: 1.0922, Train Accuracy: 68.46%
#     Worker 1: Train Loss: 1.0799, Train Accuracy: 68.85%
#     Worker 2: Train Loss: 1.1135, Train Accuracy: 69.04%
#     Worker 3: Train Loss: 1.0533, Train Accuracy: 69.43%
# Epoch 133/150: Test Loss: 2.0349, Test Accuracy: 50.89%
#     Worker 0: Train Loss: 1.1397, Train Accuracy: 67.58%
#     Worker 1: Train Loss: 1.1185, Train Accuracy: 68.55%
#     Worker 2: Train Loss: 1.1572, Train Accuracy: 67.48%
#     Worker 3: Train Loss: 1.2273, Train Accuracy: 65.14%
# Epoch 134/150: Test Loss: 2.0324, Test Accuracy: 50.92%
#     Worker 0: Train Loss: 1.1133, Train Accuracy: 67.68%
#     Worker 1: Train Loss: 1.1748, Train Accuracy: 65.72%
#     Worker 2: Train Loss: 1.0735, Train Accuracy: 70.61%
#     Worker 3: Train Loss: 1.0832, Train Accuracy: 68.07%
# Epoch 135/150: Test Loss: 2.0357, Test Accuracy: 50.94%
#     Worker 0: Train Loss: 1.1203, Train Accuracy: 67.68%
#     Worker 1: Train Loss: 1.1695, Train Accuracy: 65.82%
#     Worker 2: Train Loss: 1.1469, Train Accuracy: 66.31%
#     Worker 3: Train Loss: 1.0626, Train Accuracy: 69.82%
# Epoch 136/150: Test Loss: 2.0331, Test Accuracy: 51.00%
#     Worker 0: Train Loss: 1.1386, Train Accuracy: 68.07%
#     Worker 1: Train Loss: 1.1323, Train Accuracy: 67.97%
#     Worker 2: Train Loss: 1.0747, Train Accuracy: 69.14%
#     Worker 3: Train Loss: 1.1512, Train Accuracy: 68.55%
# Epoch 137/150: Test Loss: 2.0314, Test Accuracy: 51.09%
#     Worker 0: Train Loss: 1.1232, Train Accuracy: 67.48%
#     Worker 1: Train Loss: 1.0898, Train Accuracy: 69.43%
#     Worker 2: Train Loss: 1.0876, Train Accuracy: 68.26%
#     Worker 3: Train Loss: 1.1049, Train Accuracy: 68.85%
# Epoch 138/150: Test Loss: 2.0327, Test Accuracy: 51.04%
#     Worker 0: Train Loss: 1.1582, Train Accuracy: 67.87%
#     Worker 1: Train Loss: 1.0602, Train Accuracy: 68.75%
#     Worker 2: Train Loss: 1.1418, Train Accuracy: 68.65%
#     Worker 3: Train Loss: 1.1586, Train Accuracy: 67.68%
# Epoch 139/150: Test Loss: 2.0338, Test Accuracy: 50.95%
#     Worker 0: Train Loss: 1.1212, Train Accuracy: 68.55%
#     Worker 1: Train Loss: 1.1133, Train Accuracy: 69.04%
#     Worker 2: Train Loss: 1.2058, Train Accuracy: 64.84%
#     Worker 3: Train Loss: 1.1217, Train Accuracy: 67.38%
# Epoch 140/150: Test Loss: 2.0332, Test Accuracy: 50.97%
#     Worker 0: Train Loss: 1.1215, Train Accuracy: 68.36%
#     Worker 1: Train Loss: 1.1962, Train Accuracy: 66.60%
#     Worker 2: Train Loss: 1.1504, Train Accuracy: 67.87%
#     Worker 3: Train Loss: 1.1663, Train Accuracy: 66.89%
# Epoch 141/150: Test Loss: 2.0322, Test Accuracy: 50.83%
#     Worker 0: Train Loss: 1.1513, Train Accuracy: 66.41%
#     Worker 1: Train Loss: 1.1129, Train Accuracy: 69.92%
#     Worker 2: Train Loss: 1.1375, Train Accuracy: 67.29%
#     Worker 3: Train Loss: 1.1096, Train Accuracy: 68.85%
# Epoch 142/150: Test Loss: 2.0332, Test Accuracy: 50.85%
#     Worker 0: Train Loss: 1.1390, Train Accuracy: 67.09%
#     Worker 1: Train Loss: 1.1851, Train Accuracy: 65.43%
#     Worker 2: Train Loss: 1.0609, Train Accuracy: 69.24%
#     Worker 3: Train Loss: 1.1248, Train Accuracy: 68.07%
# Epoch 143/150: Test Loss: 2.0337, Test Accuracy: 50.91%
#     Worker 0: Train Loss: 1.1945, Train Accuracy: 64.65%
#     Worker 1: Train Loss: 1.1414, Train Accuracy: 67.48%
#     Worker 2: Train Loss: 1.1183, Train Accuracy: 68.07%
#     Worker 3: Train Loss: 1.0543, Train Accuracy: 69.73%
# Epoch 144/150: Test Loss: 2.0328, Test Accuracy: 50.85%
#     Worker 0: Train Loss: 1.1152, Train Accuracy: 69.82%
#     Worker 1: Train Loss: 1.1344, Train Accuracy: 66.60%
#     Worker 2: Train Loss: 1.2038, Train Accuracy: 67.38%
#     Worker 3: Train Loss: 1.1876, Train Accuracy: 65.04%
# Epoch 145/150: Test Loss: 2.0329, Test Accuracy: 50.91%
#     Worker 0: Train Loss: 1.1097, Train Accuracy: 68.65%
#     Worker 1: Train Loss: 1.1175, Train Accuracy: 68.65%
#     Worker 2: Train Loss: 1.0594, Train Accuracy: 69.24%
#     Worker 3: Train Loss: 1.1262, Train Accuracy: 67.68%
# Epoch 146/150: Test Loss: 2.0329, Test Accuracy: 50.86%
#     Worker 0: Train Loss: 1.1159, Train Accuracy: 67.29%
#     Worker 1: Train Loss: 1.1360, Train Accuracy: 69.43%
#     Worker 2: Train Loss: 1.0819, Train Accuracy: 67.97%
#     Worker 3: Train Loss: 1.0974, Train Accuracy: 68.95%
# Epoch 147/150: Test Loss: 2.0330, Test Accuracy: 50.85%
#     Worker 0: Train Loss: 1.1606, Train Accuracy: 67.24%
#     Worker 1: Train Loss: 1.1250, Train Accuracy: 67.86%
#     Worker 2: Train Loss: 1.0425, Train Accuracy: 69.90%
#     Worker 3: Train Loss: 1.0988, Train Accuracy: 67.96%
# Epoch 148/150: Test Loss: 2.0330, Test Accuracy: 50.88%
#     Worker 0: Train Loss: 1.0827, Train Accuracy: 68.67%
#     Worker 1: Train Loss: 1.0403, Train Accuracy: 71.63%
#     Worker 2: Train Loss: 1.1258, Train Accuracy: 68.57%
#     Worker 3: Train Loss: 1.1355, Train Accuracy: 68.78%
# Epoch 149/150: Test Loss: 2.0330, Test Accuracy: 50.90%
#     Worker 0: Train Loss: 1.0731, Train Accuracy: 69.04%
#     Worker 1: Train Loss: 1.0992, Train Accuracy: 68.65%
#     Worker 2: Train Loss: 1.0916, Train Accuracy: 69.34%
#     Worker 3: Train Loss: 1.1242, Train Accuracy: 67.97%
# Epoch 150/150: Test Loss: 2.0330, Test Accuracy: 50.89%
#     Worker 0: Train Loss: 1.1107, Train Accuracy: 68.55%
#     Worker 1: Train Loss: 1.1393, Train Accuracy: 66.89%
#     Worker 2: Train Loss: 1.1114, Train Accuracy: 68.55%
#     Worker 3: Train Loss: 1.1589, Train Accuracy: 67.09%
