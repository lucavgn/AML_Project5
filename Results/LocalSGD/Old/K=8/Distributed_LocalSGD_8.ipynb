# %%
# %%writefile localSGD.py

import os
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
num_epochs = 150
base_learning_rate = 1e-2
momentum = 0.9
weight_decay = 4e-4
warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std

class LRScheduler(torch.optim.lr_scheduler._LRScheduler):
    def __init__(self, optimizer, base_lr, K, warmup_epochs, total_epochs, verbose=False):
        """
        Args:
            optimizer: SGD
            base_lr: Base learning rate for the reference batch size.
            K: Number of workers.
            warmup_epochs: Number of warmup epochs.
            total_epochs: Total number of epochs.
            verbose: Whether to print LR updates.
        """
        self.base_lr = base_lr
        self.K = K
        self.scaled_lr = base_lr * K
        self.warmup_epochs = warmup_epochs
        self.total_epochs = total_epochs
        self.verbose = verbose
        super(LRScheduler, self).__init__(optimizer)

    def get_lr(self):
        epoch = self.last_epoch
        if epoch < self.warmup_epochs:
            # Linear warmup scaling
            warmup_factor = (epoch + 1) / self.warmup_epochs
            return [warmup_factor * self.scaled_lr for _ in self.optimizer.param_groups]
        else:
            # polynomially decaying learning rate of ηt = η0×(1−t/T)
            if epoch == self.warmup_epochs:
                print(f"Warmup phase completed at epoch {epoch}. Switching to polynomial decay learning rate.")
            return [self.scaled_lr * ( 1 - ( (epoch - self.warmup_epochs) / (self.total_epochs - self.warmup_epochs))) for _ in self.optimizer.param_groups]


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]

# Batch size
batch_size = shard_size // J

# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)


# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [LRScheduler(
    optimizer = optimizer,
    base_lr = base_learning_rate,
    K = K,
    warmup_epochs = warmup_epochs,
    total_epochs = num_epochs,
    verbose = True) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}")

    # Sequentially train each worker to simulate a distributed environment
    for k in range(K):
        shard_loader = DataLoader(shards[k], batch_size=batch_size, shuffle=True)

        nets[k].train()
        correct_train, total_train, train_loss = 0, 0, 0.0
        for images, labels in shard_loader:
            images, labels = images.to(device), labels.to(device)  # Move to device
            optimizers[k].zero_grad()
            outputs = nets[k](images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizers[k].step()
            # Calculate train loss and accuracy
            train_loss += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            total_train += labels.size(0)
            correct_train += predicted.eq(labels).sum().item()
        # Store train loss and accuracy for this worker
        train_loss /= len(shard_loader.dataset)
        train_losses_per_worker[k].append(train_loss)
        train_accuracy = 100. * correct_train / total_train
        train_accuracies_per_worker[k].append(train_accuracy)

    # Perform model synchronization
    with torch.no_grad():
        global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
        for net in nets:
            for global_param, local_param in zip(global_parameters, net.parameters()):
                global_param += local_param
        for global_param in global_parameters:
            global_param /= K
        # Update each worker model with the global parameters
        for net in nets:
            for local_param, global_param in zip(net.parameters(), global_parameters):
                local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        scheduler.step()

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 8 --j 8
# Out:
# Training with K=8, J=8
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:04<00:00, 40.9MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.08000
# Epoch 1/150: Test Loss: 4.6052, Test Accuracy: 1.33%
#     Worker 0: Train Loss: 4.6065, Train Accuracy: 1.31%
#     Worker 1: Train Loss: 4.6053, Train Accuracy: 1.22%
#     Worker 2: Train Loss: 4.6057, Train Accuracy: 1.18%
#     Worker 3: Train Loss: 4.6058, Train Accuracy: 1.10%
#     Worker 4: Train Loss: 4.6053, Train Accuracy: 1.44%
#     Worker 5: Train Loss: 4.6048, Train Accuracy: 1.49%
#     Worker 6: Train Loss: 4.6061, Train Accuracy: 1.23%
#     Worker 7: Train Loss: 4.6061, Train Accuracy: 1.17%
# Epoch 2/150: Test Loss: 4.6025, Test Accuracy: 1.34%
#     Worker 0: Train Loss: 4.6051, Train Accuracy: 1.30%
#     Worker 1: Train Loss: 4.6045, Train Accuracy: 0.96%
#     Worker 2: Train Loss: 4.6043, Train Accuracy: 1.07%
#     Worker 3: Train Loss: 4.6037, Train Accuracy: 1.18%
#     Worker 4: Train Loss: 4.6055, Train Accuracy: 1.14%
#     Worker 5: Train Loss: 4.6028, Train Accuracy: 1.14%
#     Worker 6: Train Loss: 4.6053, Train Accuracy: 1.06%
#     Worker 7: Train Loss: 4.6048, Train Accuracy: 0.90%
# Epoch 3/150: Test Loss: 4.5997, Test Accuracy: 1.14%
#     Worker 0: Train Loss: 4.6024, Train Accuracy: 1.10%
#     Worker 1: Train Loss: 4.6039, Train Accuracy: 0.94%
#     Worker 2: Train Loss: 4.6039, Train Accuracy: 1.09%
#     Worker 3: Train Loss: 4.6038, Train Accuracy: 1.01%
#     Worker 4: Train Loss: 4.6048, Train Accuracy: 1.23%
#     Worker 5: Train Loss: 4.6009, Train Accuracy: 1.15%
#     Worker 6: Train Loss: 4.6071, Train Accuracy: 0.90%
#     Worker 7: Train Loss: 4.6022, Train Accuracy: 1.10%
# Epoch 4/150: Test Loss: 4.5973, Test Accuracy: 1.17%
#     Worker 0: Train Loss: 4.6012, Train Accuracy: 1.22%
#     Worker 1: Train Loss: 4.6021, Train Accuracy: 1.28%
#     Worker 2: Train Loss: 4.6054, Train Accuracy: 0.75%
#     Worker 3: Train Loss: 4.6029, Train Accuracy: 1.10%
#     Worker 4: Train Loss: 4.6018, Train Accuracy: 1.20%
#     Worker 5: Train Loss: 4.5996, Train Accuracy: 1.46%
#     Worker 6: Train Loss: 4.6032, Train Accuracy: 0.99%
#     Worker 7: Train Loss: 4.6037, Train Accuracy: 0.98%
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Epoch 5/150: Test Loss: 4.5917, Test Accuracy: 1.58%
#     Worker 0: Train Loss: 4.6107, Train Accuracy: 1.38%
#     Worker 1: Train Loss: 4.5998, Train Accuracy: 1.42%
#     Worker 2: Train Loss: 4.6035, Train Accuracy: 1.01%
#     Worker 3: Train Loss: 4.5978, Train Accuracy: 1.41%
#     Worker 4: Train Loss: 4.6027, Train Accuracy: 0.85%
#     Worker 5: Train Loss: 4.6005, Train Accuracy: 1.33%
#     Worker 6: Train Loss: 4.5967, Train Accuracy: 0.98%
#     Worker 7: Train Loss: 4.5981, Train Accuracy: 1.06%
# Epoch 6/150: Test Loss: 4.5816, Test Accuracy: 1.53%
#     Worker 0: Train Loss: 4.5953, Train Accuracy: 1.66%
#     Worker 1: Train Loss: 4.5956, Train Accuracy: 1.33%
#     Worker 2: Train Loss: 4.5888, Train Accuracy: 1.44%
#     Worker 3: Train Loss: 4.5795, Train Accuracy: 1.70%
#     Worker 4: Train Loss: 4.5947, Train Accuracy: 0.94%
#     Worker 5: Train Loss: 4.5951, Train Accuracy: 1.09%
#     Worker 6: Train Loss: 4.6049, Train Accuracy: 1.25%
#     Worker 7: Train Loss: 4.5944, Train Accuracy: 1.65%
# Epoch 7/150: Test Loss: 4.5849, Test Accuracy: 1.17%
#     Worker 0: Train Loss: 4.5727, Train Accuracy: 1.71%
#     Worker 1: Train Loss: 4.5777, Train Accuracy: 1.42%
#     Worker 2: Train Loss: 4.5913, Train Accuracy: 1.62%
#     Worker 3: Train Loss: 4.7275, Train Accuracy: 1.14%
#     Worker 4: Train Loss: 4.5777, Train Accuracy: 1.62%
#     Worker 5: Train Loss: 4.5787, Train Accuracy: 1.39%
#     Worker 6: Train Loss: 4.5925, Train Accuracy: 1.12%
#     Worker 7: Train Loss: 4.5773, Train Accuracy: 1.54%
# Epoch 8/150: Test Loss: 4.5748, Test Accuracy: 2.06%
#     Worker 0: Train Loss: 4.5785, Train Accuracy: 1.23%
#     Worker 1: Train Loss: 4.5787, Train Accuracy: 1.01%
#     Worker 2: Train Loss: 4.5852, Train Accuracy: 0.94%
#     Worker 3: Train Loss: 4.6002, Train Accuracy: 1.01%
#     Worker 4: Train Loss: 4.5811, Train Accuracy: 1.38%
#     Worker 5: Train Loss: 4.6043, Train Accuracy: 1.14%
#     Worker 6: Train Loss: 4.6026, Train Accuracy: 1.41%
#     Worker 7: Train Loss: 4.5774, Train Accuracy: 1.06%
# Epoch 9/150: Test Loss: 4.5220, Test Accuracy: 2.30%
#     Worker 0: Train Loss: 4.5628, Train Accuracy: 1.55%
#     Worker 1: Train Loss: 4.5575, Train Accuracy: 1.52%
#     Worker 2: Train Loss: 4.5621, Train Accuracy: 1.39%
#     Worker 3: Train Loss: 4.5715, Train Accuracy: 1.74%
#     Worker 4: Train Loss: 4.7439, Train Accuracy: 1.55%
#     Worker 5: Train Loss: 4.5501, Train Accuracy: 2.00%
#     Worker 6: Train Loss: 4.5613, Train Accuracy: 2.19%
#     Worker 7: Train Loss: 4.5674, Train Accuracy: 1.44%
# Epoch 10/150: Test Loss: 4.4635, Test Accuracy: 1.72%
#     Worker 0: Train Loss: 4.5095, Train Accuracy: 2.32%
#     Worker 1: Train Loss: 4.4981, Train Accuracy: 2.53%
#     Worker 2: Train Loss: 4.5082, Train Accuracy: 2.70%
#     Worker 3: Train Loss: 4.5092, Train Accuracy: 2.29%
#     Worker 4: Train Loss: 4.5651, Train Accuracy: 1.31%
#     Worker 5: Train Loss: 4.5467, Train Accuracy: 1.73%
#     Worker 6: Train Loss: 4.5064, Train Accuracy: 1.60%
#     Worker 7: Train Loss: 4.4897, Train Accuracy: 2.67%
# Epoch 11/150: Test Loss: 4.4405, Test Accuracy: 2.98%
#     Worker 0: Train Loss: 4.4530, Train Accuracy: 1.78%
#     Worker 1: Train Loss: 4.4708, Train Accuracy: 2.34%
#     Worker 2: Train Loss: 4.5659, Train Accuracy: 1.62%
#     Worker 3: Train Loss: 4.5603, Train Accuracy: 1.50%
#     Worker 4: Train Loss: 4.4786, Train Accuracy: 2.00%
#     Worker 5: Train Loss: 4.4613, Train Accuracy: 2.00%
#     Worker 6: Train Loss: 4.5080, Train Accuracy: 1.78%
#     Worker 7: Train Loss: 4.4495, Train Accuracy: 2.24%
# Epoch 12/150: Test Loss: 4.5323, Test Accuracy: 0.98%
#     Worker 0: Train Loss: 4.5048, Train Accuracy: 2.06%
#     Worker 1: Train Loss: 4.5667, Train Accuracy: 2.30%
#     Worker 2: Train Loss: 4.4007, Train Accuracy: 2.35%
#     Worker 3: Train Loss: 4.4436, Train Accuracy: 2.58%
#     Worker 4: Train Loss: 4.5743, Train Accuracy: 2.14%
#     Worker 5: Train Loss: 4.3990, Train Accuracy: 2.50%
#     Worker 6: Train Loss: 4.5148, Train Accuracy: 1.46%
#     Worker 7: Train Loss: 4.6956, Train Accuracy: 2.18%
# Epoch 13/150: Test Loss: 4.5636, Test Accuracy: 1.80%
#     Worker 0: Train Loss: 4.5290, Train Accuracy: 1.70%
#     Worker 1: Train Loss: 4.5889, Train Accuracy: 1.10%
#     Worker 2: Train Loss: 4.5195, Train Accuracy: 1.30%
#     Worker 3: Train Loss: 4.5699, Train Accuracy: 1.30%
#     Worker 4: Train Loss: 4.5278, Train Accuracy: 1.33%
#     Worker 5: Train Loss: 4.5955, Train Accuracy: 1.44%
#     Worker 6: Train Loss: 4.5313, Train Accuracy: 1.49%
#     Worker 7: Train Loss: 4.5542, Train Accuracy: 1.55%
# Epoch 14/150: Test Loss: 4.5172, Test Accuracy: 1.82%
#     Worker 0: Train Loss: 4.5270, Train Accuracy: 2.19%
#     Worker 1: Train Loss: 4.5545, Train Accuracy: 1.62%
#     Worker 2: Train Loss: 4.5762, Train Accuracy: 0.93%
#     Worker 3: Train Loss: 4.5366, Train Accuracy: 1.76%
#     Worker 4: Train Loss: 4.5638, Train Accuracy: 1.14%
#     Worker 5: Train Loss: 4.5612, Train Accuracy: 1.26%
#     Worker 6: Train Loss: 4.5908, Train Accuracy: 1.12%
#     Worker 7: Train Loss: 4.5395, Train Accuracy: 1.62%
# Epoch 15/150: Test Loss: 4.3956, Test Accuracy: 2.35%
#     Worker 0: Train Loss: 4.4309, Train Accuracy: 2.46%
#     Worker 1: Train Loss: 4.4798, Train Accuracy: 1.95%
#     Worker 2: Train Loss: 4.4630, Train Accuracy: 2.43%
#     Worker 3: Train Loss: 4.5681, Train Accuracy: 1.39%
#     Worker 4: Train Loss: 4.4640, Train Accuracy: 2.34%
#     Worker 5: Train Loss: 4.4704, Train Accuracy: 1.86%
#     Worker 6: Train Loss: 4.4811, Train Accuracy: 1.92%
#     Worker 7: Train Loss: 4.4891, Train Accuracy: 1.70%
# Epoch 16/150: Test Loss: 4.4428, Test Accuracy: 3.44%
#     Worker 0: Train Loss: 4.3910, Train Accuracy: 3.06%
#     Worker 1: Train Loss: 4.4281, Train Accuracy: 2.00%
#     Worker 2: Train Loss: 4.4216, Train Accuracy: 3.18%
#     Worker 3: Train Loss: 4.4657, Train Accuracy: 2.32%
#     Worker 4: Train Loss: 4.4426, Train Accuracy: 2.40%
#     Worker 5: Train Loss: 4.5085, Train Accuracy: 2.16%
#     Worker 6: Train Loss: 4.4037, Train Accuracy: 3.18%
#     Worker 7: Train Loss: 4.4924, Train Accuracy: 2.82%
# Epoch 17/150: Test Loss: 4.3837, Test Accuracy: 2.88%
#     Worker 0: Train Loss: 4.3710, Train Accuracy: 3.17%
#     Worker 1: Train Loss: 4.4270, Train Accuracy: 2.78%
#     Worker 2: Train Loss: 4.5120, Train Accuracy: 2.35%
#     Worker 3: Train Loss: 4.4885, Train Accuracy: 2.05%
#     Worker 4: Train Loss: 4.4299, Train Accuracy: 2.02%
#     Worker 5: Train Loss: 4.4805, Train Accuracy: 2.26%
#     Worker 6: Train Loss: 4.4364, Train Accuracy: 2.48%
#     Worker 7: Train Loss: 4.5005, Train Accuracy: 1.87%
# Epoch 18/150: Test Loss: 4.3982, Test Accuracy: 2.98%
#     Worker 0: Train Loss: 4.3714, Train Accuracy: 2.48%
#     Worker 1: Train Loss: 4.4921, Train Accuracy: 2.22%
#     Worker 2: Train Loss: 4.3922, Train Accuracy: 2.35%
#     Worker 3: Train Loss: 4.4097, Train Accuracy: 2.29%
#     Worker 4: Train Loss: 4.3723, Train Accuracy: 2.93%
#     Worker 5: Train Loss: 4.4814, Train Accuracy: 2.67%
#     Worker 6: Train Loss: 4.4158, Train Accuracy: 2.43%
#     Worker 7: Train Loss: 4.3941, Train Accuracy: 2.53%
# Epoch 19/150: Test Loss: 4.4976, Test Accuracy: 2.90%
#     Worker 0: Train Loss: 4.5171, Train Accuracy: 2.10%
#     Worker 1: Train Loss: 4.4481, Train Accuracy: 2.19%
#     Worker 2: Train Loss: 4.3934, Train Accuracy: 2.75%
#     Worker 3: Train Loss: 4.4291, Train Accuracy: 2.82%
#     Worker 4: Train Loss: 4.3657, Train Accuracy: 2.58%
#     Worker 5: Train Loss: 4.5457, Train Accuracy: 2.05%
#     Worker 6: Train Loss: 4.5184, Train Accuracy: 2.74%
#     Worker 7: Train Loss: 4.5034, Train Accuracy: 2.40%
# Epoch 20/150: Test Loss: 4.3969, Test Accuracy: 3.19%
#     Worker 0: Train Loss: 4.5124, Train Accuracy: 1.82%
#     Worker 1: Train Loss: 4.4826, Train Accuracy: 2.02%
#     Worker 2: Train Loss: 4.4679, Train Accuracy: 2.32%
#     Worker 3: Train Loss: 4.4790, Train Accuracy: 1.81%
#     Worker 4: Train Loss: 4.4749, Train Accuracy: 2.99%
#     Worker 5: Train Loss: 4.4591, Train Accuracy: 2.24%
#     Worker 6: Train Loss: 4.5008, Train Accuracy: 1.50%
#     Worker 7: Train Loss: 4.4847, Train Accuracy: 1.55%
# Epoch 21/150: Test Loss: 4.3702, Test Accuracy: 3.25%
#     Worker 0: Train Loss: 4.4539, Train Accuracy: 2.53%
#     Worker 1: Train Loss: 4.4217, Train Accuracy: 2.51%
#     Worker 2: Train Loss: 4.7457, Train Accuracy: 2.02%
#     Worker 3: Train Loss: 4.3922, Train Accuracy: 3.36%
#     Worker 4: Train Loss: 4.3999, Train Accuracy: 2.98%
#     Worker 5: Train Loss: 4.3706, Train Accuracy: 3.26%
#     Worker 6: Train Loss: 4.3803, Train Accuracy: 3.12%
#     Worker 7: Train Loss: 4.3725, Train Accuracy: 2.54%
# Epoch 22/150: Test Loss: 4.5064, Test Accuracy: 2.36%
#     Worker 0: Train Loss: 4.4232, Train Accuracy: 2.37%
#     Worker 1: Train Loss: 4.4038, Train Accuracy: 2.21%
#     Worker 2: Train Loss: 4.4210, Train Accuracy: 2.77%
#     Worker 3: Train Loss: 4.3565, Train Accuracy: 3.20%
#     Worker 4: Train Loss: 4.4223, Train Accuracy: 2.35%
#     Worker 5: Train Loss: 4.6692, Train Accuracy: 2.35%
#     Worker 6: Train Loss: 4.3920, Train Accuracy: 2.46%
#     Worker 7: Train Loss: 4.4149, Train Accuracy: 2.62%
# Epoch 23/150: Test Loss: 4.4562, Test Accuracy: 2.47%
#     Worker 0: Train Loss: 4.4827, Train Accuracy: 1.92%
#     Worker 1: Train Loss: 4.4853, Train Accuracy: 1.74%
#     Worker 2: Train Loss: 4.5126, Train Accuracy: 2.14%
#     Worker 3: Train Loss: 4.4828, Train Accuracy: 2.00%
#     Worker 4: Train Loss: 4.5165, Train Accuracy: 2.46%
#     Worker 5: Train Loss: 4.5170, Train Accuracy: 2.50%
#     Worker 6: Train Loss: 4.4826, Train Accuracy: 2.30%
#     Worker 7: Train Loss: 4.5225, Train Accuracy: 2.03%
# Epoch 24/150: Test Loss: 4.4046, Test Accuracy: 3.18%
#     Worker 0: Train Loss: 4.5506, Train Accuracy: 2.08%
#     Worker 1: Train Loss: 4.4266, Train Accuracy: 2.29%
#     Worker 2: Train Loss: 4.4789, Train Accuracy: 2.06%
#     Worker 3: Train Loss: 4.4520, Train Accuracy: 2.30%
#     Worker 4: Train Loss: 4.4273, Train Accuracy: 2.40%
#     Worker 5: Train Loss: 4.4335, Train Accuracy: 2.62%
#     Worker 6: Train Loss: 4.4025, Train Accuracy: 2.70%
#     Worker 7: Train Loss: 4.4448, Train Accuracy: 2.42%
# Epoch 25/150: Test Loss: 4.3594, Test Accuracy: 3.06%
#     Worker 0: Train Loss: 4.3820, Train Accuracy: 2.82%
#     Worker 1: Train Loss: 4.3919, Train Accuracy: 2.91%
#     Worker 2: Train Loss: 4.4083, Train Accuracy: 2.42%
#     Worker 3: Train Loss: 4.3688, Train Accuracy: 2.98%
#     Worker 4: Train Loss: 4.3396, Train Accuracy: 3.82%
#     Worker 5: Train Loss: 4.4639, Train Accuracy: 2.21%
#     Worker 6: Train Loss: 4.3864, Train Accuracy: 2.77%
#     Worker 7: Train Loss: 4.4221, Train Accuracy: 3.09%
# Epoch 26/150: Test Loss: 4.3976, Test Accuracy: 4.28%
#     Worker 0: Train Loss: 4.3485, Train Accuracy: 3.39%
#     Worker 1: Train Loss: 4.5877, Train Accuracy: 1.97%
#     Worker 2: Train Loss: 4.3892, Train Accuracy: 2.93%
#     Worker 3: Train Loss: 4.4112, Train Accuracy: 3.38%
#     Worker 4: Train Loss: 4.3950, Train Accuracy: 2.50%
#     Worker 5: Train Loss: 4.3871, Train Accuracy: 2.38%
#     Worker 6: Train Loss: 4.4689, Train Accuracy: 2.74%
#     Worker 7: Train Loss: 4.3892, Train Accuracy: 2.98%
# Epoch 27/150: Test Loss: 4.2753, Test Accuracy: 4.40%
#     Worker 0: Train Loss: 4.3490, Train Accuracy: 3.92%
#     Worker 1: Train Loss: 4.3889, Train Accuracy: 3.31%
#     Worker 2: Train Loss: 4.3513, Train Accuracy: 3.33%
#     Worker 3: Train Loss: 4.4049, Train Accuracy: 2.88%
#     Worker 4: Train Loss: 4.4299, Train Accuracy: 2.85%
#     Worker 5: Train Loss: 4.3932, Train Accuracy: 3.31%
#     Worker 6: Train Loss: 4.3786, Train Accuracy: 3.65%
#     Worker 7: Train Loss: 4.4283, Train Accuracy: 2.88%
# Epoch 28/150: Test Loss: 4.3433, Test Accuracy: 4.15%
#     Worker 0: Train Loss: 4.3981, Train Accuracy: 3.22%
#     Worker 1: Train Loss: 4.3366, Train Accuracy: 3.04%
#     Worker 2: Train Loss: 4.2705, Train Accuracy: 4.37%
#     Worker 3: Train Loss: 4.3773, Train Accuracy: 2.99%
#     Worker 4: Train Loss: 4.4413, Train Accuracy: 3.17%
#     Worker 5: Train Loss: 4.3489, Train Accuracy: 3.36%
#     Worker 6: Train Loss: 4.3703, Train Accuracy: 3.55%
#     Worker 7: Train Loss: 4.3422, Train Accuracy: 3.54%
# Epoch 29/150: Test Loss: 4.3933, Test Accuracy: 3.16%
#     Worker 0: Train Loss: 4.5583, Train Accuracy: 2.35%
#     Worker 1: Train Loss: 4.3107, Train Accuracy: 4.05%
#     Worker 2: Train Loss: 4.3808, Train Accuracy: 3.20%
#     Worker 3: Train Loss: 4.3470, Train Accuracy: 3.52%
#     Worker 4: Train Loss: 4.3606, Train Accuracy: 3.02%
#     Worker 5: Train Loss: 4.5962, Train Accuracy: 2.80%
#     Worker 6: Train Loss: 4.3678, Train Accuracy: 3.49%
#     Worker 7: Train Loss: 4.5505, Train Accuracy: 2.14%
# Epoch 30/150: Test Loss: 4.3654, Test Accuracy: 4.61%
#     Worker 0: Train Loss: 4.4079, Train Accuracy: 2.58%
#     Worker 1: Train Loss: 4.3525, Train Accuracy: 3.66%
#     Worker 2: Train Loss: 4.4452, Train Accuracy: 3.12%
#     Worker 3: Train Loss: 4.3643, Train Accuracy: 2.99%
#     Worker 4: Train Loss: 4.3117, Train Accuracy: 3.82%
#     Worker 5: Train Loss: 4.6267, Train Accuracy: 1.89%
#     Worker 6: Train Loss: 4.3617, Train Accuracy: 3.42%
#     Worker 7: Train Loss: 4.3693, Train Accuracy: 3.46%
# Epoch 31/150: Test Loss: 4.3389, Test Accuracy: 3.30%
#     Worker 0: Train Loss: 4.3916, Train Accuracy: 3.73%
#     Worker 1: Train Loss: 4.3713, Train Accuracy: 3.74%
#     Worker 2: Train Loss: 4.3544, Train Accuracy: 4.14%
#     Worker 3: Train Loss: 4.4124, Train Accuracy: 3.38%
#     Worker 4: Train Loss: 4.4026, Train Accuracy: 3.47%
#     Worker 5: Train Loss: 4.4591, Train Accuracy: 2.48%
#     Worker 6: Train Loss: 4.4248, Train Accuracy: 2.88%
#     Worker 7: Train Loss: 4.3613, Train Accuracy: 3.41%
# Epoch 32/150: Test Loss: 4.3193, Test Accuracy: 3.84%
#     Worker 0: Train Loss: 4.4347, Train Accuracy: 2.62%
#     Worker 1: Train Loss: 4.2988, Train Accuracy: 3.55%
#     Worker 2: Train Loss: 4.4990, Train Accuracy: 2.99%
#     Worker 3: Train Loss: 4.3434, Train Accuracy: 2.98%
#     Worker 4: Train Loss: 4.2695, Train Accuracy: 4.46%
#     Worker 5: Train Loss: 4.4822, Train Accuracy: 1.89%
#     Worker 6: Train Loss: 4.4141, Train Accuracy: 2.70%
#     Worker 7: Train Loss: 4.3113, Train Accuracy: 3.42%
# Epoch 33/150: Test Loss: 4.3308, Test Accuracy: 3.37%
#     Worker 0: Train Loss: 4.3397, Train Accuracy: 2.70%
#     Worker 1: Train Loss: 4.4420, Train Accuracy: 2.32%
#     Worker 2: Train Loss: 4.3434, Train Accuracy: 3.26%
#     Worker 3: Train Loss: 4.3654, Train Accuracy: 2.94%
#     Worker 4: Train Loss: 4.3489, Train Accuracy: 3.33%
#     Worker 5: Train Loss: 4.3221, Train Accuracy: 3.60%
#     Worker 6: Train Loss: 4.3349, Train Accuracy: 2.98%
#     Worker 7: Train Loss: 4.3291, Train Accuracy: 3.74%
# Epoch 34/150: Test Loss: 4.3332, Test Accuracy: 4.35%
#     Worker 0: Train Loss: 4.4450, Train Accuracy: 2.74%
#     Worker 1: Train Loss: 4.4034, Train Accuracy: 2.96%
#     Worker 2: Train Loss: 4.4181, Train Accuracy: 3.12%
#     Worker 3: Train Loss: 4.3586, Train Accuracy: 3.25%
#     Worker 4: Train Loss: 4.2580, Train Accuracy: 4.03%
#     Worker 5: Train Loss: 4.4479, Train Accuracy: 3.38%
#     Worker 6: Train Loss: 4.2824, Train Accuracy: 3.60%
#     Worker 7: Train Loss: 4.3962, Train Accuracy: 3.33%
# Epoch 35/150: Test Loss: 4.2940, Test Accuracy: 4.32%
#     Worker 0: Train Loss: 4.2820, Train Accuracy: 4.32%
#     Worker 1: Train Loss: 4.3009, Train Accuracy: 3.18%
#     Worker 2: Train Loss: 4.5160, Train Accuracy: 3.39%
#     Worker 3: Train Loss: 4.3757, Train Accuracy: 2.99%
#     Worker 4: Train Loss: 4.3072, Train Accuracy: 4.22%
#     Worker 5: Train Loss: 4.3109, Train Accuracy: 4.34%
#     Worker 6: Train Loss: 4.3668, Train Accuracy: 3.15%
#     Worker 7: Train Loss: 4.3394, Train Accuracy: 4.85%
# Epoch 36/150: Test Loss: 4.3934, Test Accuracy: 3.27%
#     Worker 0: Train Loss: 4.3678, Train Accuracy: 3.20%
#     Worker 1: Train Loss: 4.4431, Train Accuracy: 2.22%
#     Worker 2: Train Loss: 4.2932, Train Accuracy: 3.87%
#     Worker 3: Train Loss: 4.3396, Train Accuracy: 2.80%
#     Worker 4: Train Loss: 4.3417, Train Accuracy: 3.95%
#     Worker 5: Train Loss: 4.3814, Train Accuracy: 3.79%
#     Worker 6: Train Loss: 4.3155, Train Accuracy: 3.49%
#     Worker 7: Train Loss: 4.3159, Train Accuracy: 3.97%
# Epoch 37/150: Test Loss: 4.3692, Test Accuracy: 3.12%
#     Worker 0: Train Loss: 4.3952, Train Accuracy: 3.07%
#     Worker 1: Train Loss: 4.4370, Train Accuracy: 2.88%
#     Worker 2: Train Loss: 4.5862, Train Accuracy: 2.10%
#     Worker 3: Train Loss: 4.4071, Train Accuracy: 3.15%
#     Worker 4: Train Loss: 4.3798, Train Accuracy: 3.70%
#     Worker 5: Train Loss: 4.4009, Train Accuracy: 3.23%
#     Worker 6: Train Loss: 4.3473, Train Accuracy: 3.31%
#     Worker 7: Train Loss: 4.3929, Train Accuracy: 2.62%
# Epoch 38/150: Test Loss: 4.3148, Test Accuracy: 3.59%
#     Worker 0: Train Loss: 4.4063, Train Accuracy: 2.96%
#     Worker 1: Train Loss: 4.3525, Train Accuracy: 3.09%
#     Worker 2: Train Loss: 4.3930, Train Accuracy: 2.70%
#     Worker 3: Train Loss: 4.3337, Train Accuracy: 3.34%
#     Worker 4: Train Loss: 4.3572, Train Accuracy: 3.10%
#     Worker 5: Train Loss: 4.4040, Train Accuracy: 3.26%
#     Worker 6: Train Loss: 4.4764, Train Accuracy: 2.43%
#     Worker 7: Train Loss: 4.3357, Train Accuracy: 2.35%
# Epoch 39/150: Test Loss: 4.3581, Test Accuracy: 3.16%
#     Worker 0: Train Loss: 4.3360, Train Accuracy: 3.65%
#     Worker 1: Train Loss: 4.3163, Train Accuracy: 3.36%
#     Worker 2: Train Loss: 4.3254, Train Accuracy: 3.02%
#     Worker 3: Train Loss: 4.3119, Train Accuracy: 2.82%
#     Worker 4: Train Loss: 4.3347, Train Accuracy: 3.14%
#     Worker 5: Train Loss: 4.4602, Train Accuracy: 1.90%
#     Worker 6: Train Loss: 4.3655, Train Accuracy: 2.88%
#     Worker 7: Train Loss: 4.3365, Train Accuracy: 3.39%
# Epoch 40/150: Test Loss: 4.3667, Test Accuracy: 3.77%
#     Worker 0: Train Loss: 4.4155, Train Accuracy: 2.61%
#     Worker 1: Train Loss: 4.4591, Train Accuracy: 3.30%
#     Worker 2: Train Loss: 4.3815, Train Accuracy: 3.18%
#     Worker 3: Train Loss: 4.4620, Train Accuracy: 2.53%
#     Worker 4: Train Loss: 4.3855, Train Accuracy: 2.69%
#     Worker 5: Train Loss: 4.4091, Train Accuracy: 2.27%
#     Worker 6: Train Loss: 4.3636, Train Accuracy: 2.58%
#     Worker 7: Train Loss: 4.4245, Train Accuracy: 2.93%
# Epoch 41/150: Test Loss: 4.3072, Test Accuracy: 3.14%
#     Worker 0: Train Loss: 4.3426, Train Accuracy: 3.49%
#     Worker 1: Train Loss: 4.3689, Train Accuracy: 3.47%
#     Worker 2: Train Loss: 4.4146, Train Accuracy: 2.03%
#     Worker 3: Train Loss: 4.4169, Train Accuracy: 3.28%
#     Worker 4: Train Loss: 4.3637, Train Accuracy: 3.46%
#     Worker 5: Train Loss: 4.3432, Train Accuracy: 3.30%
#     Worker 6: Train Loss: 4.4380, Train Accuracy: 3.04%
#     Worker 7: Train Loss: 4.3111, Train Accuracy: 3.78%
# Epoch 42/150: Test Loss: 4.2386, Test Accuracy: 5.00%
#     Worker 0: Train Loss: 4.3575, Train Accuracy: 2.54%
#     Worker 1: Train Loss: 4.3919, Train Accuracy: 2.91%
#     Worker 2: Train Loss: 4.3102, Train Accuracy: 3.04%
#     Worker 3: Train Loss: 4.3277, Train Accuracy: 3.01%
#     Worker 4: Train Loss: 4.3003, Train Accuracy: 3.47%
#     Worker 5: Train Loss: 4.2716, Train Accuracy: 3.50%
#     Worker 6: Train Loss: 4.2943, Train Accuracy: 3.42%
#     Worker 7: Train Loss: 4.4179, Train Accuracy: 2.70%
# Epoch 43/150: Test Loss: 4.2327, Test Accuracy: 4.68%
#     Worker 0: Train Loss: 4.2294, Train Accuracy: 4.77%
#     Worker 1: Train Loss: 4.2958, Train Accuracy: 3.71%
#     Worker 2: Train Loss: 4.3280, Train Accuracy: 3.49%
#     Worker 3: Train Loss: 4.3939, Train Accuracy: 3.86%
#     Worker 4: Train Loss: 4.2068, Train Accuracy: 4.93%
#     Worker 5: Train Loss: 4.2615, Train Accuracy: 4.24%
#     Worker 6: Train Loss: 4.2204, Train Accuracy: 5.33%
#     Worker 7: Train Loss: 4.2975, Train Accuracy: 3.66%
# Epoch 44/150: Test Loss: 4.2490, Test Accuracy: 4.27%
#     Worker 0: Train Loss: 4.2500, Train Accuracy: 4.26%
#     Worker 1: Train Loss: 4.3184, Train Accuracy: 3.17%
#     Worker 2: Train Loss: 4.2419, Train Accuracy: 4.24%
#     Worker 3: Train Loss: 4.3058, Train Accuracy: 3.70%
#     Worker 4: Train Loss: 4.2903, Train Accuracy: 3.90%
#     Worker 5: Train Loss: 4.3112, Train Accuracy: 3.17%
#     Worker 6: Train Loss: 4.3745, Train Accuracy: 2.86%
#     Worker 7: Train Loss: 4.3283, Train Accuracy: 3.76%
# Epoch 45/150: Test Loss: 4.2154, Test Accuracy: 5.35%
#     Worker 0: Train Loss: 4.2114, Train Accuracy: 4.30%
#     Worker 1: Train Loss: 4.3099, Train Accuracy: 2.98%
#     Worker 2: Train Loss: 4.2431, Train Accuracy: 3.68%
#     Worker 3: Train Loss: 4.3694, Train Accuracy: 3.98%
#     Worker 4: Train Loss: 4.2682, Train Accuracy: 3.81%
#     Worker 5: Train Loss: 4.3595, Train Accuracy: 2.85%
#     Worker 6: Train Loss: 4.2451, Train Accuracy: 4.16%
#     Worker 7: Train Loss: 4.2412, Train Accuracy: 3.50%
# Epoch 46/150: Test Loss: 4.1911, Test Accuracy: 5.35%
#     Worker 0: Train Loss: 4.2254, Train Accuracy: 4.80%
#     Worker 1: Train Loss: 4.4200, Train Accuracy: 2.85%
#     Worker 2: Train Loss: 4.1895, Train Accuracy: 4.51%
#     Worker 3: Train Loss: 4.2714, Train Accuracy: 4.13%
#     Worker 4: Train Loss: 4.1661, Train Accuracy: 4.91%
#     Worker 5: Train Loss: 4.2092, Train Accuracy: 5.02%
#     Worker 6: Train Loss: 4.2437, Train Accuracy: 4.45%
#     Worker 7: Train Loss: 4.3828, Train Accuracy: 3.82%
# Epoch 47/150: Test Loss: 4.1718, Test Accuracy: 5.95%
#     Worker 0: Train Loss: 4.2285, Train Accuracy: 4.45%
#     Worker 1: Train Loss: 4.2938, Train Accuracy: 2.98%
#     Worker 2: Train Loss: 4.1826, Train Accuracy: 4.91%
#     Worker 3: Train Loss: 4.3494, Train Accuracy: 3.23%
#     Worker 4: Train Loss: 4.2317, Train Accuracy: 4.02%
#     Worker 5: Train Loss: 4.2699, Train Accuracy: 4.99%
#     Worker 6: Train Loss: 4.2396, Train Accuracy: 4.56%
#     Worker 7: Train Loss: 4.2445, Train Accuracy: 4.45%
# Epoch 48/150: Test Loss: 4.1463, Test Accuracy: 6.15%
#     Worker 0: Train Loss: 4.2021, Train Accuracy: 5.22%
#     Worker 1: Train Loss: 4.1829, Train Accuracy: 5.39%
#     Worker 2: Train Loss: 4.3007, Train Accuracy: 4.67%
#     Worker 3: Train Loss: 4.2832, Train Accuracy: 4.66%
#     Worker 4: Train Loss: 4.1194, Train Accuracy: 6.61%
#     Worker 5: Train Loss: 4.3372, Train Accuracy: 4.43%
#     Worker 6: Train Loss: 4.1667, Train Accuracy: 5.25%
#     Worker 7: Train Loss: 4.2984, Train Accuracy: 4.99%
# Epoch 49/150: Test Loss: 4.1042, Test Accuracy: 7.09%
#     Worker 0: Train Loss: 4.2045, Train Accuracy: 5.52%
#     Worker 1: Train Loss: 4.1892, Train Accuracy: 5.26%
#     Worker 2: Train Loss: 4.2114, Train Accuracy: 5.02%
#     Worker 3: Train Loss: 4.1667, Train Accuracy: 5.25%
#     Worker 4: Train Loss: 4.1453, Train Accuracy: 5.57%
#     Worker 5: Train Loss: 4.1344, Train Accuracy: 5.95%
#     Worker 6: Train Loss: 4.1611, Train Accuracy: 4.94%
#     Worker 7: Train Loss: 4.1518, Train Accuracy: 6.40%
# Epoch 50/150: Test Loss: 4.1680, Test Accuracy: 6.85%
#     Worker 0: Train Loss: 4.1597, Train Accuracy: 5.60%
#     Worker 1: Train Loss: 4.3657, Train Accuracy: 4.62%
#     Worker 2: Train Loss: 4.1373, Train Accuracy: 5.50%
#     Worker 3: Train Loss: 4.2876, Train Accuracy: 3.90%
#     Worker 4: Train Loss: 4.1591, Train Accuracy: 5.52%
#     Worker 5: Train Loss: 4.1724, Train Accuracy: 6.46%
#     Worker 6: Train Loss: 4.2321, Train Accuracy: 5.66%
#     Worker 7: Train Loss: 4.4508, Train Accuracy: 4.46%
# Epoch 51/150: Test Loss: 4.1282, Test Accuracy: 6.94%
#     Worker 0: Train Loss: 4.1508, Train Accuracy: 5.87%
#     Worker 1: Train Loss: 4.2321, Train Accuracy: 4.78%
#     Worker 2: Train Loss: 4.1162, Train Accuracy: 6.54%
#     Worker 3: Train Loss: 4.2519, Train Accuracy: 4.69%
#     Worker 4: Train Loss: 4.1494, Train Accuracy: 5.74%
#     Worker 5: Train Loss: 4.3453, Train Accuracy: 5.10%
#     Worker 6: Train Loss: 4.1667, Train Accuracy: 5.65%
#     Worker 7: Train Loss: 4.2657, Train Accuracy: 4.19%
# Epoch 52/150: Test Loss: 4.2717, Test Accuracy: 4.71%
#     Worker 0: Train Loss: 4.1809, Train Accuracy: 5.18%
#     Worker 1: Train Loss: 4.3639, Train Accuracy: 4.03%
#     Worker 2: Train Loss: 4.2515, Train Accuracy: 5.34%
#     Worker 3: Train Loss: 4.1669, Train Accuracy: 5.57%
#     Worker 4: Train Loss: 4.2229, Train Accuracy: 4.56%
#     Worker 5: Train Loss: 4.2971, Train Accuracy: 4.82%
#     Worker 6: Train Loss: 4.3237, Train Accuracy: 4.90%
#     Worker 7: Train Loss: 4.1737, Train Accuracy: 5.38%
# Epoch 53/150: Test Loss: 4.1057, Test Accuracy: 6.89%
#     Worker 0: Train Loss: 4.2803, Train Accuracy: 4.56%
#     Worker 1: Train Loss: 4.2707, Train Accuracy: 4.00%
#     Worker 2: Train Loss: 4.3731, Train Accuracy: 3.90%
#     Worker 3: Train Loss: 4.2669, Train Accuracy: 4.40%
#     Worker 4: Train Loss: 4.2388, Train Accuracy: 4.45%
#     Worker 5: Train Loss: 4.2310, Train Accuracy: 4.86%
#     Worker 6: Train Loss: 4.2464, Train Accuracy: 4.66%
#     Worker 7: Train Loss: 4.2428, Train Accuracy: 4.83%
# Epoch 54/150: Test Loss: 4.1867, Test Accuracy: 5.06%
#     Worker 0: Train Loss: 4.2319, Train Accuracy: 4.82%
#     Worker 1: Train Loss: 4.1960, Train Accuracy: 5.82%
#     Worker 2: Train Loss: 4.1282, Train Accuracy: 6.93%
#     Worker 3: Train Loss: 4.1918, Train Accuracy: 5.39%
#     Worker 4: Train Loss: 4.2328, Train Accuracy: 4.40%
#     Worker 5: Train Loss: 4.2915, Train Accuracy: 5.10%
#     Worker 6: Train Loss: 4.2334, Train Accuracy: 4.59%
#     Worker 7: Train Loss: 4.1590, Train Accuracy: 5.10%
# Epoch 55/150: Test Loss: 4.1241, Test Accuracy: 5.89%
#     Worker 0: Train Loss: 4.2362, Train Accuracy: 4.03%
#     Worker 1: Train Loss: 4.3410, Train Accuracy: 3.60%
#     Worker 2: Train Loss: 4.2716, Train Accuracy: 4.35%
#     Worker 3: Train Loss: 4.2733, Train Accuracy: 4.10%
#     Worker 4: Train Loss: 4.1733, Train Accuracy: 4.75%
#     Worker 5: Train Loss: 4.2750, Train Accuracy: 3.66%
#     Worker 6: Train Loss: 4.3339, Train Accuracy: 3.76%
#     Worker 7: Train Loss: 4.1190, Train Accuracy: 5.68%
# Epoch 56/150: Test Loss: 4.1120, Test Accuracy: 5.92%
#     Worker 0: Train Loss: 4.1910, Train Accuracy: 5.04%
#     Worker 1: Train Loss: 4.1768, Train Accuracy: 4.77%
#     Worker 2: Train Loss: 4.2735, Train Accuracy: 4.56%
#     Worker 3: Train Loss: 4.2428, Train Accuracy: 4.13%
#     Worker 4: Train Loss: 4.0666, Train Accuracy: 5.58%
#     Worker 5: Train Loss: 4.1492, Train Accuracy: 5.17%
#     Worker 6: Train Loss: 4.2477, Train Accuracy: 5.36%
#     Worker 7: Train Loss: 4.2034, Train Accuracy: 5.54%
# Epoch 57/150: Test Loss: 4.1258, Test Accuracy: 6.24%
#     Worker 0: Train Loss: 4.1235, Train Accuracy: 6.11%
#     Worker 1: Train Loss: 4.3147, Train Accuracy: 3.58%
#     Worker 2: Train Loss: 4.2170, Train Accuracy: 4.85%
#     Worker 3: Train Loss: 4.1576, Train Accuracy: 5.18%
#     Worker 4: Train Loss: 4.0879, Train Accuracy: 5.22%
#     Worker 5: Train Loss: 4.2422, Train Accuracy: 4.50%
#     Worker 6: Train Loss: 4.1690, Train Accuracy: 5.28%
#     Worker 7: Train Loss: 4.1675, Train Accuracy: 5.68%
# Epoch 58/150: Test Loss: 4.0574, Test Accuracy: 6.60%
#     Worker 0: Train Loss: 4.2036, Train Accuracy: 4.54%
#     Worker 1: Train Loss: 4.2552, Train Accuracy: 4.72%
#     Worker 2: Train Loss: 4.2250, Train Accuracy: 4.77%
#     Worker 3: Train Loss: 4.2107, Train Accuracy: 4.61%
#     Worker 4: Train Loss: 4.1221, Train Accuracy: 5.55%
#     Worker 5: Train Loss: 4.1478, Train Accuracy: 4.91%
#     Worker 6: Train Loss: 4.1673, Train Accuracy: 5.06%
#     Worker 7: Train Loss: 4.1306, Train Accuracy: 4.94%
# Epoch 59/150: Test Loss: 4.0312, Test Accuracy: 7.15%
#     Worker 0: Train Loss: 4.1404, Train Accuracy: 5.01%
#     Worker 1: Train Loss: 4.2416, Train Accuracy: 4.70%
#     Worker 2: Train Loss: 4.1306, Train Accuracy: 5.70%
#     Worker 3: Train Loss: 4.0739, Train Accuracy: 6.38%
#     Worker 4: Train Loss: 4.0116, Train Accuracy: 6.78%
#     Worker 5: Train Loss: 4.1717, Train Accuracy: 5.73%
#     Worker 6: Train Loss: 4.1718, Train Accuracy: 4.85%
#     Worker 7: Train Loss: 4.0841, Train Accuracy: 5.98%
# Epoch 60/150: Test Loss: 4.0801, Test Accuracy: 6.59%
#     Worker 0: Train Loss: 4.1691, Train Accuracy: 5.50%
#     Worker 1: Train Loss: 4.1117, Train Accuracy: 5.38%
#     Worker 2: Train Loss: 4.1187, Train Accuracy: 6.13%
#     Worker 3: Train Loss: 4.0994, Train Accuracy: 5.78%
#     Worker 4: Train Loss: 4.2109, Train Accuracy: 4.51%
#     Worker 5: Train Loss: 4.0732, Train Accuracy: 5.57%
#     Worker 6: Train Loss: 4.1176, Train Accuracy: 5.66%
#     Worker 7: Train Loss: 4.1830, Train Accuracy: 5.68%
# Epoch 61/150: Test Loss: 4.0393, Test Accuracy: 7.33%
#     Worker 0: Train Loss: 4.1619, Train Accuracy: 6.08%
#     Worker 1: Train Loss: 4.0589, Train Accuracy: 6.45%
#     Worker 2: Train Loss: 4.1879, Train Accuracy: 5.50%
#     Worker 3: Train Loss: 4.2270, Train Accuracy: 4.75%
#     Worker 4: Train Loss: 4.0845, Train Accuracy: 6.48%
#     Worker 5: Train Loss: 4.1125, Train Accuracy: 5.44%
#     Worker 6: Train Loss: 4.1159, Train Accuracy: 5.44%
#     Worker 7: Train Loss: 4.3005, Train Accuracy: 4.53%
# Epoch 62/150: Test Loss: 4.1118, Test Accuracy: 7.05%
#     Worker 0: Train Loss: 4.0447, Train Accuracy: 6.61%
#     Worker 1: Train Loss: 4.2233, Train Accuracy: 5.12%
#     Worker 2: Train Loss: 4.1291, Train Accuracy: 5.50%
#     Worker 3: Train Loss: 4.2450, Train Accuracy: 4.90%
#     Worker 4: Train Loss: 4.1081, Train Accuracy: 5.78%
#     Worker 5: Train Loss: 4.1571, Train Accuracy: 6.69%
#     Worker 6: Train Loss: 4.1078, Train Accuracy: 6.34%
#     Worker 7: Train Loss: 4.0733, Train Accuracy: 7.04%
# Epoch 63/150: Test Loss: 4.1037, Test Accuracy: 6.06%
#     Worker 0: Train Loss: 4.1633, Train Accuracy: 5.50%
#     Worker 1: Train Loss: 4.1725, Train Accuracy: 4.98%
#     Worker 2: Train Loss: 4.1663, Train Accuracy: 5.02%
#     Worker 3: Train Loss: 4.1439, Train Accuracy: 5.47%
#     Worker 4: Train Loss: 4.1689, Train Accuracy: 5.79%
#     Worker 5: Train Loss: 4.1317, Train Accuracy: 5.98%
#     Worker 6: Train Loss: 4.0968, Train Accuracy: 5.92%
#     Worker 7: Train Loss: 4.3300, Train Accuracy: 3.71%
# Epoch 64/150: Test Loss: 4.0410, Test Accuracy: 7.74%
#     Worker 0: Train Loss: 4.1715, Train Accuracy: 4.99%
#     Worker 1: Train Loss: 4.0833, Train Accuracy: 5.76%
#     Worker 2: Train Loss: 4.1133, Train Accuracy: 5.65%
#     Worker 3: Train Loss: 4.0845, Train Accuracy: 6.14%
#     Worker 4: Train Loss: 4.1478, Train Accuracy: 5.10%
#     Worker 5: Train Loss: 4.2126, Train Accuracy: 4.98%
#     Worker 6: Train Loss: 4.2083, Train Accuracy: 4.77%
#     Worker 7: Train Loss: 4.1515, Train Accuracy: 4.88%
# Epoch 65/150: Test Loss: 4.0455, Test Accuracy: 7.07%
#     Worker 0: Train Loss: 4.0883, Train Accuracy: 6.05%
#     Worker 1: Train Loss: 4.2438, Train Accuracy: 5.28%
#     Worker 2: Train Loss: 4.0513, Train Accuracy: 6.99%
#     Worker 3: Train Loss: 4.1003, Train Accuracy: 5.33%
#     Worker 4: Train Loss: 4.0993, Train Accuracy: 6.90%
#     Worker 5: Train Loss: 4.1775, Train Accuracy: 5.55%
#     Worker 6: Train Loss: 4.0606, Train Accuracy: 5.97%
#     Worker 7: Train Loss: 4.1567, Train Accuracy: 5.86%
# Epoch 66/150: Test Loss: 3.9869, Test Accuracy: 8.29%
#     Worker 0: Train Loss: 4.0401, Train Accuracy: 6.38%
#     Worker 1: Train Loss: 4.2485, Train Accuracy: 4.75%
#     Worker 2: Train Loss: 4.0940, Train Accuracy: 5.89%
#     Worker 3: Train Loss: 4.1340, Train Accuracy: 5.81%
#     Worker 4: Train Loss: 4.0711, Train Accuracy: 6.38%
#     Worker 5: Train Loss: 4.0887, Train Accuracy: 5.41%
#     Worker 6: Train Loss: 4.0418, Train Accuracy: 6.78%
#     Worker 7: Train Loss: 4.2432, Train Accuracy: 5.01%
# Epoch 67/150: Test Loss: 4.0001, Test Accuracy: 7.93%
#     Worker 0: Train Loss: 4.1190, Train Accuracy: 6.75%
#     Worker 1: Train Loss: 4.0954, Train Accuracy: 7.38%
#     Worker 2: Train Loss: 4.1038, Train Accuracy: 7.18%
#     Worker 3: Train Loss: 4.3212, Train Accuracy: 5.76%
#     Worker 4: Train Loss: 4.1397, Train Accuracy: 6.03%
#     Worker 5: Train Loss: 4.0185, Train Accuracy: 7.81%
#     Worker 6: Train Loss: 4.0622, Train Accuracy: 6.67%
#     Worker 7: Train Loss: 4.0617, Train Accuracy: 6.51%
# Epoch 68/150: Test Loss: 3.9634, Test Accuracy: 9.07%
#     Worker 0: Train Loss: 4.0579, Train Accuracy: 7.54%
#     Worker 1: Train Loss: 4.1794, Train Accuracy: 5.82%
#     Worker 2: Train Loss: 4.1218, Train Accuracy: 5.84%
#     Worker 3: Train Loss: 4.0847, Train Accuracy: 6.06%
#     Worker 4: Train Loss: 4.0404, Train Accuracy: 7.33%
#     Worker 5: Train Loss: 4.0811, Train Accuracy: 7.25%
#     Worker 6: Train Loss: 4.0606, Train Accuracy: 5.89%
#     Worker 7: Train Loss: 4.0761, Train Accuracy: 7.26%
# Epoch 69/150: Test Loss: 3.9602, Test Accuracy: 8.44%
#     Worker 0: Train Loss: 4.0935, Train Accuracy: 7.06%
#     Worker 1: Train Loss: 4.2245, Train Accuracy: 6.45%
#     Worker 2: Train Loss: 4.0454, Train Accuracy: 6.86%
#     Worker 3: Train Loss: 4.0300, Train Accuracy: 6.78%
#     Worker 4: Train Loss: 3.9932, Train Accuracy: 7.06%
#     Worker 5: Train Loss: 4.2048, Train Accuracy: 7.01%
#     Worker 6: Train Loss: 3.9718, Train Accuracy: 7.70%
#     Worker 7: Train Loss: 4.1144, Train Accuracy: 6.61%
# Epoch 70/150: Test Loss: 3.9258, Test Accuracy: 8.62%
#     Worker 0: Train Loss: 4.0346, Train Accuracy: 7.01%
#     Worker 1: Train Loss: 4.1174, Train Accuracy: 6.62%
#     Worker 2: Train Loss: 4.1345, Train Accuracy: 6.16%
#     Worker 3: Train Loss: 3.9796, Train Accuracy: 8.13%
#     Worker 4: Train Loss: 3.9581, Train Accuracy: 7.54%
#     Worker 5: Train Loss: 3.9862, Train Accuracy: 7.42%
#     Worker 6: Train Loss: 4.0741, Train Accuracy: 6.82%
#     Worker 7: Train Loss: 3.9934, Train Accuracy: 7.38%
# Epoch 71/150: Test Loss: 3.9732, Test Accuracy: 8.13%
#     Worker 0: Train Loss: 4.1167, Train Accuracy: 6.50%
#     Worker 1: Train Loss: 3.9722, Train Accuracy: 7.89%
#     Worker 2: Train Loss: 4.0944, Train Accuracy: 6.75%
#     Worker 3: Train Loss: 3.9748, Train Accuracy: 7.82%
#     Worker 4: Train Loss: 4.0030, Train Accuracy: 7.86%
#     Worker 5: Train Loss: 4.1802, Train Accuracy: 6.42%
#     Worker 6: Train Loss: 4.0287, Train Accuracy: 7.94%
#     Worker 7: Train Loss: 4.0553, Train Accuracy: 6.80%
# Epoch 72/150: Test Loss: 3.9594, Test Accuracy: 8.44%
#     Worker 0: Train Loss: 4.1240, Train Accuracy: 4.86%
#     Worker 1: Train Loss: 4.0957, Train Accuracy: 5.90%
#     Worker 2: Train Loss: 4.1513, Train Accuracy: 6.19%
#     Worker 3: Train Loss: 4.1106, Train Accuracy: 6.34%
#     Worker 4: Train Loss: 3.9500, Train Accuracy: 7.81%
#     Worker 5: Train Loss: 4.0344, Train Accuracy: 7.52%
#     Worker 6: Train Loss: 4.0820, Train Accuracy: 6.59%
#     Worker 7: Train Loss: 4.0835, Train Accuracy: 6.32%
# Epoch 73/150: Test Loss: 3.9732, Test Accuracy: 7.63%
#     Worker 0: Train Loss: 4.0552, Train Accuracy: 6.94%
#     Worker 1: Train Loss: 4.0018, Train Accuracy: 7.20%
#     Worker 2: Train Loss: 4.0048, Train Accuracy: 8.70%
#     Worker 3: Train Loss: 4.1462, Train Accuracy: 5.97%
#     Worker 4: Train Loss: 4.0184, Train Accuracy: 7.60%
#     Worker 5: Train Loss: 4.0311, Train Accuracy: 6.75%
#     Worker 6: Train Loss: 4.0762, Train Accuracy: 6.19%
#     Worker 7: Train Loss: 3.9765, Train Accuracy: 7.17%
# Epoch 74/150: Test Loss: 3.9354, Test Accuracy: 9.11%
#     Worker 0: Train Loss: 4.1098, Train Accuracy: 6.66%
#     Worker 1: Train Loss: 4.0257, Train Accuracy: 7.28%
#     Worker 2: Train Loss: 4.0112, Train Accuracy: 7.73%
#     Worker 3: Train Loss: 4.2044, Train Accuracy: 7.22%
#     Worker 4: Train Loss: 3.9670, Train Accuracy: 8.03%
#     Worker 5: Train Loss: 4.2292, Train Accuracy: 5.26%
#     Worker 6: Train Loss: 4.0266, Train Accuracy: 6.90%
#     Worker 7: Train Loss: 4.0927, Train Accuracy: 6.67%
# Epoch 75/150: Test Loss: 3.9125, Test Accuracy: 9.20%
#     Worker 0: Train Loss: 4.1128, Train Accuracy: 7.52%
#     Worker 1: Train Loss: 4.0073, Train Accuracy: 7.94%
#     Worker 2: Train Loss: 3.9587, Train Accuracy: 8.38%
#     Worker 3: Train Loss: 4.1170, Train Accuracy: 5.31%
#     Worker 4: Train Loss: 4.0663, Train Accuracy: 7.39%
#     Worker 5: Train Loss: 4.0055, Train Accuracy: 7.74%
#     Worker 6: Train Loss: 4.0278, Train Accuracy: 6.83%
#     Worker 7: Train Loss: 4.0193, Train Accuracy: 8.46%
# Epoch 76/150: Test Loss: 3.8988, Test Accuracy: 9.81%
#     Worker 0: Train Loss: 4.0737, Train Accuracy: 6.67%
#     Worker 1: Train Loss: 3.9638, Train Accuracy: 8.16%
#     Worker 2: Train Loss: 3.9742, Train Accuracy: 8.19%
#     Worker 3: Train Loss: 4.1256, Train Accuracy: 6.35%
#     Worker 4: Train Loss: 4.0504, Train Accuracy: 7.76%
#     Worker 5: Train Loss: 3.9654, Train Accuracy: 8.82%
#     Worker 6: Train Loss: 4.0204, Train Accuracy: 7.44%
#     Worker 7: Train Loss: 4.0076, Train Accuracy: 7.47%
# Epoch 77/150: Test Loss: 3.8656, Test Accuracy: 10.44%
#     Worker 0: Train Loss: 4.0697, Train Accuracy: 7.66%
#     Worker 1: Train Loss: 4.0442, Train Accuracy: 6.66%
#     Worker 2: Train Loss: 3.9523, Train Accuracy: 9.95%
#     Worker 3: Train Loss: 4.0421, Train Accuracy: 7.31%
#     Worker 4: Train Loss: 3.9619, Train Accuracy: 8.06%
#     Worker 5: Train Loss: 3.9482, Train Accuracy: 9.04%
#     Worker 6: Train Loss: 4.0067, Train Accuracy: 7.39%
#     Worker 7: Train Loss: 4.0715, Train Accuracy: 6.16%
# Epoch 78/150: Test Loss: 3.8569, Test Accuracy: 10.61%
#     Worker 0: Train Loss: 3.9719, Train Accuracy: 7.92%
#     Worker 1: Train Loss: 3.9323, Train Accuracy: 7.97%
#     Worker 2: Train Loss: 3.9809, Train Accuracy: 9.18%
#     Worker 3: Train Loss: 3.9967, Train Accuracy: 7.54%
#     Worker 4: Train Loss: 4.0069, Train Accuracy: 8.16%
#     Worker 5: Train Loss: 3.9594, Train Accuracy: 9.30%
#     Worker 6: Train Loss: 4.0212, Train Accuracy: 7.33%
#     Worker 7: Train Loss: 3.9119, Train Accuracy: 8.83%
# Epoch 79/150: Test Loss: 3.9518, Test Accuracy: 8.99%
#     Worker 0: Train Loss: 4.0972, Train Accuracy: 7.25%
#     Worker 1: Train Loss: 4.1232, Train Accuracy: 6.16%
#     Worker 2: Train Loss: 4.0545, Train Accuracy: 7.57%
#     Worker 3: Train Loss: 4.1708, Train Accuracy: 6.19%
#     Worker 4: Train Loss: 3.9092, Train Accuracy: 8.86%
#     Worker 5: Train Loss: 3.9645, Train Accuracy: 8.19%
#     Worker 6: Train Loss: 4.1962, Train Accuracy: 6.30%
#     Worker 7: Train Loss: 3.9445, Train Accuracy: 8.21%
# Epoch 80/150: Test Loss: 3.8842, Test Accuracy: 10.06%
#     Worker 0: Train Loss: 3.9278, Train Accuracy: 7.97%
#     Worker 1: Train Loss: 4.0542, Train Accuracy: 5.95%
#     Worker 2: Train Loss: 3.9818, Train Accuracy: 8.11%
#     Worker 3: Train Loss: 4.0406, Train Accuracy: 6.83%
#     Worker 4: Train Loss: 3.9777, Train Accuracy: 7.70%
#     Worker 5: Train Loss: 3.9858, Train Accuracy: 7.44%
#     Worker 6: Train Loss: 4.0307, Train Accuracy: 7.12%
#     Worker 7: Train Loss: 4.0392, Train Accuracy: 8.67%
# Epoch 81/150: Test Loss: 3.9075, Test Accuracy: 9.41%
#     Worker 0: Train Loss: 4.0162, Train Accuracy: 7.33%
#     Worker 1: Train Loss: 4.0199, Train Accuracy: 7.79%
#     Worker 2: Train Loss: 3.9288, Train Accuracy: 8.19%
#     Worker 3: Train Loss: 4.1770, Train Accuracy: 6.26%
#     Worker 4: Train Loss: 4.1395, Train Accuracy: 7.63%
#     Worker 5: Train Loss: 3.8712, Train Accuracy: 9.60%
#     Worker 6: Train Loss: 3.9884, Train Accuracy: 7.89%
#     Worker 7: Train Loss: 3.9808, Train Accuracy: 8.34%
# Epoch 82/150: Test Loss: 3.8387, Test Accuracy: 10.92%
#     Worker 0: Train Loss: 4.1062, Train Accuracy: 6.93%
#     Worker 1: Train Loss: 3.9636, Train Accuracy: 8.00%
#     Worker 2: Train Loss: 4.0451, Train Accuracy: 7.55%
#     Worker 3: Train Loss: 3.9823, Train Accuracy: 8.19%
#     Worker 4: Train Loss: 3.9529, Train Accuracy: 8.86%
#     Worker 5: Train Loss: 3.9192, Train Accuracy: 8.34%
#     Worker 6: Train Loss: 3.9121, Train Accuracy: 8.19%
#     Worker 7: Train Loss: 3.9310, Train Accuracy: 8.10%
# Epoch 83/150: Test Loss: 3.7871, Test Accuracy: 11.65%
#     Worker 0: Train Loss: 3.9962, Train Accuracy: 7.30%
#     Worker 1: Train Loss: 3.8587, Train Accuracy: 9.47%
#     Worker 2: Train Loss: 3.9909, Train Accuracy: 8.70%
#     Worker 3: Train Loss: 3.9707, Train Accuracy: 8.14%
#     Worker 4: Train Loss: 3.8932, Train Accuracy: 10.08%
#     Worker 5: Train Loss: 3.8483, Train Accuracy: 10.34%
#     Worker 6: Train Loss: 3.8815, Train Accuracy: 9.14%
#     Worker 7: Train Loss: 4.0234, Train Accuracy: 7.86%
# Epoch 84/150: Test Loss: 3.8121, Test Accuracy: 12.61%
#     Worker 0: Train Loss: 3.9528, Train Accuracy: 8.51%
#     Worker 1: Train Loss: 3.8945, Train Accuracy: 9.31%
#     Worker 2: Train Loss: 3.9146, Train Accuracy: 9.02%
#     Worker 3: Train Loss: 3.9541, Train Accuracy: 8.70%
#     Worker 4: Train Loss: 3.9659, Train Accuracy: 8.90%
#     Worker 5: Train Loss: 3.9567, Train Accuracy: 10.06%
#     Worker 6: Train Loss: 3.8959, Train Accuracy: 9.20%
#     Worker 7: Train Loss: 3.9612, Train Accuracy: 8.82%
# Epoch 85/150: Test Loss: 3.8504, Test Accuracy: 11.03%
#     Worker 0: Train Loss: 3.9546, Train Accuracy: 8.03%
#     Worker 1: Train Loss: 3.9506, Train Accuracy: 9.78%
#     Worker 2: Train Loss: 4.0097, Train Accuracy: 8.78%
#     Worker 3: Train Loss: 3.9877, Train Accuracy: 8.29%
#     Worker 4: Train Loss: 3.8925, Train Accuracy: 9.18%
#     Worker 5: Train Loss: 4.0038, Train Accuracy: 9.01%
#     Worker 6: Train Loss: 3.9741, Train Accuracy: 8.45%
#     Worker 7: Train Loss: 3.8892, Train Accuracy: 9.31%
# Epoch 86/150: Test Loss: 3.8342, Test Accuracy: 10.85%
#     Worker 0: Train Loss: 3.9178, Train Accuracy: 8.83%
#     Worker 1: Train Loss: 3.9055, Train Accuracy: 9.42%
#     Worker 2: Train Loss: 3.9710, Train Accuracy: 7.84%
#     Worker 3: Train Loss: 4.1975, Train Accuracy: 6.53%
#     Worker 4: Train Loss: 3.8883, Train Accuracy: 9.89%
#     Worker 5: Train Loss: 3.9946, Train Accuracy: 9.09%
#     Worker 6: Train Loss: 3.9756, Train Accuracy: 8.51%
#     Worker 7: Train Loss: 3.9720, Train Accuracy: 8.59%
# Epoch 87/150: Test Loss: 3.7967, Test Accuracy: 11.98%
#     Worker 0: Train Loss: 3.9537, Train Accuracy: 9.18%
#     Worker 1: Train Loss: 4.1516, Train Accuracy: 6.90%
#     Worker 2: Train Loss: 3.8673, Train Accuracy: 9.63%
#     Worker 3: Train Loss: 3.9314, Train Accuracy: 8.99%
#     Worker 4: Train Loss: 3.8896, Train Accuracy: 9.42%
#     Worker 5: Train Loss: 3.9061, Train Accuracy: 9.50%
#     Worker 6: Train Loss: 3.9606, Train Accuracy: 8.13%
#     Worker 7: Train Loss: 4.0650, Train Accuracy: 6.91%
# Epoch 88/150: Test Loss: 3.7919, Test Accuracy: 12.02%
#     Worker 0: Train Loss: 3.9244, Train Accuracy: 9.31%
#     Worker 1: Train Loss: 3.9426, Train Accuracy: 8.78%
#     Worker 2: Train Loss: 3.9462, Train Accuracy: 8.86%
#     Worker 3: Train Loss: 3.8726, Train Accuracy: 9.15%
#     Worker 4: Train Loss: 3.9726, Train Accuracy: 9.15%
#     Worker 5: Train Loss: 3.8881, Train Accuracy: 9.15%
#     Worker 6: Train Loss: 3.9032, Train Accuracy: 8.93%
#     Worker 7: Train Loss: 3.9082, Train Accuracy: 9.12%
# Epoch 89/150: Test Loss: 3.7919, Test Accuracy: 11.02%
#     Worker 0: Train Loss: 3.9220, Train Accuracy: 8.69%
#     Worker 1: Train Loss: 3.8363, Train Accuracy: 10.38%
#     Worker 2: Train Loss: 3.8888, Train Accuracy: 10.50%
#     Worker 3: Train Loss: 3.9790, Train Accuracy: 8.78%
#     Worker 4: Train Loss: 3.8675, Train Accuracy: 9.31%
#     Worker 5: Train Loss: 3.8412, Train Accuracy: 10.69%
#     Worker 6: Train Loss: 3.8865, Train Accuracy: 8.77%
#     Worker 7: Train Loss: 3.9515, Train Accuracy: 8.86%
# Epoch 90/150: Test Loss: 3.7595, Test Accuracy: 12.67%
#     Worker 0: Train Loss: 3.9382, Train Accuracy: 8.91%
#     Worker 1: Train Loss: 3.9095, Train Accuracy: 8.34%
#     Worker 2: Train Loss: 3.8412, Train Accuracy: 10.19%
#     Worker 3: Train Loss: 3.9223, Train Accuracy: 8.45%
#     Worker 4: Train Loss: 3.8757, Train Accuracy: 9.86%
#     Worker 5: Train Loss: 4.0375, Train Accuracy: 8.32%
#     Worker 6: Train Loss: 3.9577, Train Accuracy: 8.05%
#     Worker 7: Train Loss: 3.8792, Train Accuracy: 9.15%
# Epoch 91/150: Test Loss: 3.7377, Test Accuracy: 12.18%
#     Worker 0: Train Loss: 3.8354, Train Accuracy: 9.87%
#     Worker 1: Train Loss: 3.9718, Train Accuracy: 8.80%
#     Worker 2: Train Loss: 3.9790, Train Accuracy: 9.22%
#     Worker 3: Train Loss: 3.8510, Train Accuracy: 10.19%
#     Worker 4: Train Loss: 3.8492, Train Accuracy: 10.13%
#     Worker 5: Train Loss: 3.7907, Train Accuracy: 10.78%
#     Worker 6: Train Loss: 3.8215, Train Accuracy: 10.05%
#     Worker 7: Train Loss: 3.9565, Train Accuracy: 8.86%
# Epoch 92/150: Test Loss: 3.7109, Test Accuracy: 12.09%
#     Worker 0: Train Loss: 3.8349, Train Accuracy: 9.62%
#     Worker 1: Train Loss: 3.8210, Train Accuracy: 10.40%
#     Worker 2: Train Loss: 3.8322, Train Accuracy: 10.78%
#     Worker 3: Train Loss: 3.8597, Train Accuracy: 9.78%
#     Worker 4: Train Loss: 3.7715, Train Accuracy: 10.94%
#     Worker 5: Train Loss: 3.8454, Train Accuracy: 9.70%
#     Worker 6: Train Loss: 3.8876, Train Accuracy: 9.84%
#     Worker 7: Train Loss: 3.8943, Train Accuracy: 9.14%
# Epoch 93/150: Test Loss: 3.7614, Test Accuracy: 12.29%
#     Worker 0: Train Loss: 3.8442, Train Accuracy: 10.08%
#     Worker 1: Train Loss: 3.8957, Train Accuracy: 8.85%
#     Worker 2: Train Loss: 3.8906, Train Accuracy: 8.80%
#     Worker 3: Train Loss: 3.7888, Train Accuracy: 10.96%
#     Worker 4: Train Loss: 3.8738, Train Accuracy: 9.58%
#     Worker 5: Train Loss: 3.7556, Train Accuracy: 10.74%
#     Worker 6: Train Loss: 4.0721, Train Accuracy: 8.88%
#     Worker 7: Train Loss: 3.9153, Train Accuracy: 9.49%
# Epoch 94/150: Test Loss: 3.7471, Test Accuracy: 12.59%
#     Worker 0: Train Loss: 3.8608, Train Accuracy: 9.17%
#     Worker 1: Train Loss: 3.8878, Train Accuracy: 9.31%
#     Worker 2: Train Loss: 3.8378, Train Accuracy: 9.97%
#     Worker 3: Train Loss: 3.8687, Train Accuracy: 10.56%
# ...
#     Worker 6: Train Loss: 3.7318, Train Accuracy: 11.57%
#     Worker 7: Train Loss: 3.6833, Train Accuracy: 12.77%
# Epoch 120/150: Test Loss: 3.5425, Test Accuracy: 15.98%
#     Worker 0: Train Loss: 3.7386, Train Accuracy: 10.86%
#     Worker 1: Train Loss: 3.6587, Train Accuracy: 13.26%
#     Worker 2: Train Loss: 3.7806, Train Accuracy: 12.22%
#     Worker 3: Train Loss: 3.6828, Train Accuracy: 13.25%
#     Worker 4: Train Loss: 3.6770, Train Accuracy: 12.70%
#     Worker 5: Train Loss: 3.5810, Train Accuracy: 14.82%
#     Worker 6: Train Loss: 3.6269, Train Accuracy: 13.52%
#     Worker 7: Train Loss: 3.8675, Train Accuracy: 11.18%
# Epoch 121/150: Test Loss: 3.5483, Test Accuracy: 16.22%
#     Worker 0: Train Loss: 3.6210, Train Accuracy: 14.06%
#     Worker 1: Train Loss: 3.7776, Train Accuracy: 12.56%
#     Worker 2: Train Loss: 3.6948, Train Accuracy: 13.50%
#     Worker 3: Train Loss: 3.6983, Train Accuracy: 12.53%
#     Worker 4: Train Loss: 3.6045, Train Accuracy: 14.64%
#     Worker 5: Train Loss: 3.6790, Train Accuracy: 13.54%
#     Worker 6: Train Loss: 3.6385, Train Accuracy: 13.39%
#     Worker 7: Train Loss: 3.7179, Train Accuracy: 12.08%
# Epoch 122/150: Test Loss: 3.5217, Test Accuracy: 16.18%
#     Worker 0: Train Loss: 3.6124, Train Accuracy: 13.84%
#     Worker 1: Train Loss: 3.7267, Train Accuracy: 12.51%
#     Worker 2: Train Loss: 3.6336, Train Accuracy: 14.19%
#     Worker 3: Train Loss: 3.7676, Train Accuracy: 11.81%
#     Worker 4: Train Loss: 3.5942, Train Accuracy: 14.00%
#     Worker 5: Train Loss: 3.6032, Train Accuracy: 14.24%
#     Worker 6: Train Loss: 3.6217, Train Accuracy: 14.00%
#     Worker 7: Train Loss: 3.6466, Train Accuracy: 13.86%
# Epoch 123/150: Test Loss: 3.5209, Test Accuracy: 16.69%
#     Worker 0: Train Loss: 3.6929, Train Accuracy: 12.64%
#     Worker 1: Train Loss: 3.6420, Train Accuracy: 13.92%
#     Worker 2: Train Loss: 3.6201, Train Accuracy: 14.14%
#     Worker 3: Train Loss: 3.6349, Train Accuracy: 13.87%
#     Worker 4: Train Loss: 3.6348, Train Accuracy: 13.36%
#     Worker 5: Train Loss: 3.5538, Train Accuracy: 14.94%
#     Worker 6: Train Loss: 3.7727, Train Accuracy: 12.26%
#     Worker 7: Train Loss: 3.6374, Train Accuracy: 13.38%
# Epoch 124/150: Test Loss: 3.4999, Test Accuracy: 16.31%
#     Worker 0: Train Loss: 3.6289, Train Accuracy: 13.26%
#     Worker 1: Train Loss: 3.6293, Train Accuracy: 14.37%
#     Worker 2: Train Loss: 3.6992, Train Accuracy: 13.84%
#     Worker 3: Train Loss: 3.6391, Train Accuracy: 13.65%
#     Worker 4: Train Loss: 3.5454, Train Accuracy: 15.34%
#     Worker 5: Train Loss: 3.5376, Train Accuracy: 15.36%
#     Worker 6: Train Loss: 3.6747, Train Accuracy: 13.28%
#     Worker 7: Train Loss: 3.5867, Train Accuracy: 14.30%
# Epoch 125/150: Test Loss: 3.4799, Test Accuracy: 16.89%
#     Worker 0: Train Loss: 3.6182, Train Accuracy: 13.66%
#     Worker 1: Train Loss: 3.5715, Train Accuracy: 14.43%
#     Worker 2: Train Loss: 3.5943, Train Accuracy: 15.01%
#     Worker 3: Train Loss: 3.6769, Train Accuracy: 13.70%
#     Worker 4: Train Loss: 3.5376, Train Accuracy: 15.44%
#     Worker 5: Train Loss: 3.4949, Train Accuracy: 16.27%
#     Worker 6: Train Loss: 3.6077, Train Accuracy: 14.08%
#     Worker 7: Train Loss: 3.5632, Train Accuracy: 14.77%
# Epoch 126/150: Test Loss: 3.4714, Test Accuracy: 17.06%
#     Worker 0: Train Loss: 3.5613, Train Accuracy: 14.13%
#     Worker 1: Train Loss: 3.6267, Train Accuracy: 14.69%
#     Worker 2: Train Loss: 3.6614, Train Accuracy: 13.87%
#     Worker 3: Train Loss: 3.5781, Train Accuracy: 14.34%
#     Worker 4: Train Loss: 3.6390, Train Accuracy: 12.86%
#     Worker 5: Train Loss: 3.5225, Train Accuracy: 15.76%
#     Worker 6: Train Loss: 3.5971, Train Accuracy: 14.88%
#     Worker 7: Train Loss: 3.6074, Train Accuracy: 13.23%
# Epoch 127/150: Test Loss: 3.4690, Test Accuracy: 16.56%
#     Worker 0: Train Loss: 3.6412, Train Accuracy: 14.16%
#     Worker 1: Train Loss: 3.5684, Train Accuracy: 14.98%
#     Worker 2: Train Loss: 3.5784, Train Accuracy: 14.05%
#     Worker 3: Train Loss: 3.6039, Train Accuracy: 13.65%
#     Worker 4: Train Loss: 3.5310, Train Accuracy: 14.85%
#     Worker 5: Train Loss: 3.5357, Train Accuracy: 15.15%
#     Worker 6: Train Loss: 3.6042, Train Accuracy: 13.97%
#     Worker 7: Train Loss: 3.6192, Train Accuracy: 13.71%
# Epoch 128/150: Test Loss: 3.4491, Test Accuracy: 17.47%
#     Worker 0: Train Loss: 3.6368, Train Accuracy: 13.31%
#     Worker 1: Train Loss: 3.6614, Train Accuracy: 13.55%
#     Worker 2: Train Loss: 3.5517, Train Accuracy: 15.41%
#     Worker 3: Train Loss: 3.5518, Train Accuracy: 14.40%
#     Worker 4: Train Loss: 3.5115, Train Accuracy: 15.63%
#     Worker 5: Train Loss: 3.4942, Train Accuracy: 15.98%
#     Worker 6: Train Loss: 3.6296, Train Accuracy: 13.39%
#     Worker 7: Train Loss: 3.5492, Train Accuracy: 15.52%
# Epoch 129/150: Test Loss: 3.5229, Test Accuracy: 16.17%
#     Worker 0: Train Loss: 3.5606, Train Accuracy: 14.61%
#     Worker 1: Train Loss: 3.5610, Train Accuracy: 15.10%
#     Worker 2: Train Loss: 3.7016, Train Accuracy: 12.51%
#     Worker 3: Train Loss: 3.7139, Train Accuracy: 12.50%
#     Worker 4: Train Loss: 3.7635, Train Accuracy: 14.80%
#     Worker 5: Train Loss: 3.4636, Train Accuracy: 16.62%
#     Worker 6: Train Loss: 3.5538, Train Accuracy: 13.95%
#     Worker 7: Train Loss: 3.5512, Train Accuracy: 14.32%
# Epoch 130/150: Test Loss: 3.5178, Test Accuracy: 16.26%
#     Worker 0: Train Loss: 3.5477, Train Accuracy: 14.35%
#     Worker 1: Train Loss: 3.5624, Train Accuracy: 14.64%
#     Worker 2: Train Loss: 3.5847, Train Accuracy: 14.91%
#     Worker 3: Train Loss: 3.6437, Train Accuracy: 13.65%
#     Worker 4: Train Loss: 4.3431, Train Accuracy: 7.55%
#     Worker 5: Train Loss: 3.5709, Train Accuracy: 14.35%
#     Worker 6: Train Loss: 3.6114, Train Accuracy: 14.21%
#     Worker 7: Train Loss: 3.6042, Train Accuracy: 13.60%
# Epoch 131/150: Test Loss: 3.4784, Test Accuracy: 16.83%
#     Worker 0: Train Loss: 3.6750, Train Accuracy: 12.66%
#     Worker 1: Train Loss: 3.5889, Train Accuracy: 14.54%
#     Worker 2: Train Loss: 3.6596, Train Accuracy: 14.62%
#     Worker 3: Train Loss: 3.5748, Train Accuracy: 14.51%
#     Worker 4: Train Loss: 3.6912, Train Accuracy: 13.41%
#     Worker 5: Train Loss: 3.5283, Train Accuracy: 15.12%
#     Worker 6: Train Loss: 3.5842, Train Accuracy: 13.98%
#     Worker 7: Train Loss: 3.5447, Train Accuracy: 15.15%
# Epoch 132/150: Test Loss: 3.4512, Test Accuracy: 17.38%
#     Worker 0: Train Loss: 3.5756, Train Accuracy: 14.86%
#     Worker 1: Train Loss: 3.6107, Train Accuracy: 14.72%
#     Worker 2: Train Loss: 3.5717, Train Accuracy: 15.30%
#     Worker 3: Train Loss: 3.8302, Train Accuracy: 13.01%
#     Worker 4: Train Loss: 3.5589, Train Accuracy: 14.72%
#     Worker 5: Train Loss: 3.5442, Train Accuracy: 14.93%
#     Worker 6: Train Loss: 3.5245, Train Accuracy: 15.76%
#     Worker 7: Train Loss: 3.5408, Train Accuracy: 15.58%
# Epoch 133/150: Test Loss: 3.4372, Test Accuracy: 17.23%
#     Worker 0: Train Loss: 3.6979, Train Accuracy: 13.84%
#     Worker 1: Train Loss: 3.5093, Train Accuracy: 15.31%
#     Worker 2: Train Loss: 3.5680, Train Accuracy: 15.34%
#     Worker 3: Train Loss: 3.6111, Train Accuracy: 14.02%
#     Worker 4: Train Loss: 3.4931, Train Accuracy: 15.79%
#     Worker 5: Train Loss: 3.5292, Train Accuracy: 16.06%
#     Worker 6: Train Loss: 3.5521, Train Accuracy: 14.77%
#     Worker 7: Train Loss: 3.5108, Train Accuracy: 15.81%
# Epoch 134/150: Test Loss: 3.4408, Test Accuracy: 17.28%
#     Worker 0: Train Loss: 3.6041, Train Accuracy: 14.14%
#     Worker 1: Train Loss: 3.5494, Train Accuracy: 14.91%
#     Worker 2: Train Loss: 3.5294, Train Accuracy: 16.35%
#     Worker 3: Train Loss: 3.5491, Train Accuracy: 15.28%
#     Worker 4: Train Loss: 3.4705, Train Accuracy: 16.14%
#     Worker 5: Train Loss: 3.6244, Train Accuracy: 14.82%
#     Worker 6: Train Loss: 3.5397, Train Accuracy: 15.18%
#     Worker 7: Train Loss: 3.6146, Train Accuracy: 14.53%
# Epoch 135/150: Test Loss: 3.4579, Test Accuracy: 17.03%
#     Worker 0: Train Loss: 3.5418, Train Accuracy: 14.66%
#     Worker 1: Train Loss: 3.5905, Train Accuracy: 14.77%
#     Worker 2: Train Loss: 3.5346, Train Accuracy: 15.54%
#     Worker 3: Train Loss: 3.6353, Train Accuracy: 13.70%
#     Worker 4: Train Loss: 3.4908, Train Accuracy: 16.56%
#     Worker 5: Train Loss: 3.5003, Train Accuracy: 16.37%
#     Worker 6: Train Loss: 3.5332, Train Accuracy: 15.04%
#     Worker 7: Train Loss: 3.4954, Train Accuracy: 16.37%
# Epoch 136/150: Test Loss: 3.4251, Test Accuracy: 17.52%
#     Worker 0: Train Loss: 3.5585, Train Accuracy: 14.77%
#     Worker 1: Train Loss: 3.5279, Train Accuracy: 15.06%
#     Worker 2: Train Loss: 3.5140, Train Accuracy: 16.21%
#     Worker 3: Train Loss: 3.5877, Train Accuracy: 14.05%
#     Worker 4: Train Loss: 3.4816, Train Accuracy: 15.62%
#     Worker 5: Train Loss: 3.5074, Train Accuracy: 16.14%
#     Worker 6: Train Loss: 3.6131, Train Accuracy: 14.24%
#     Worker 7: Train Loss: 3.4935, Train Accuracy: 15.74%
# Epoch 137/150: Test Loss: 3.4229, Test Accuracy: 17.60%
#     Worker 0: Train Loss: 3.5024, Train Accuracy: 15.79%
#     Worker 1: Train Loss: 3.4614, Train Accuracy: 16.62%
#     Worker 2: Train Loss: 3.5028, Train Accuracy: 16.32%
#     Worker 3: Train Loss: 3.5321, Train Accuracy: 15.26%
#     Worker 4: Train Loss: 3.5006, Train Accuracy: 16.27%
#     Worker 5: Train Loss: 3.4924, Train Accuracy: 17.15%
#     Worker 6: Train Loss: 3.5211, Train Accuracy: 14.78%
#     Worker 7: Train Loss: 3.5201, Train Accuracy: 15.86%
# Epoch 138/150: Test Loss: 3.4124, Test Accuracy: 17.90%
#     Worker 0: Train Loss: 3.5051, Train Accuracy: 15.36%
#     Worker 1: Train Loss: 3.5043, Train Accuracy: 15.79%
#     Worker 2: Train Loss: 3.4907, Train Accuracy: 16.64%
#     Worker 3: Train Loss: 3.5391, Train Accuracy: 14.83%
#     Worker 4: Train Loss: 3.4861, Train Accuracy: 16.34%
#     Worker 5: Train Loss: 3.4396, Train Accuracy: 17.12%
#     Worker 6: Train Loss: 3.4681, Train Accuracy: 15.98%
#     Worker 7: Train Loss: 3.5128, Train Accuracy: 15.52%
# Epoch 139/150: Test Loss: 3.4017, Test Accuracy: 18.09%
#     Worker 0: Train Loss: 3.4977, Train Accuracy: 15.46%
#     Worker 1: Train Loss: 3.4886, Train Accuracy: 16.34%
#     Worker 2: Train Loss: 3.4755, Train Accuracy: 16.80%
#     Worker 3: Train Loss: 3.4783, Train Accuracy: 16.05%
#     Worker 4: Train Loss: 3.4369, Train Accuracy: 17.49%
#     Worker 5: Train Loss: 3.4441, Train Accuracy: 16.77%
#     Worker 6: Train Loss: 3.4889, Train Accuracy: 15.46%
#     Worker 7: Train Loss: 3.5441, Train Accuracy: 15.12%
# Epoch 140/150: Test Loss: 3.3898, Test Accuracy: 18.03%
#     Worker 0: Train Loss: 3.4940, Train Accuracy: 16.05%
#     Worker 1: Train Loss: 3.4557, Train Accuracy: 16.99%
#     Worker 2: Train Loss: 3.4684, Train Accuracy: 17.41%
#     Worker 3: Train Loss: 3.5277, Train Accuracy: 15.31%
#     Worker 4: Train Loss: 3.4149, Train Accuracy: 16.80%
#     Worker 5: Train Loss: 3.5356, Train Accuracy: 15.68%
#     Worker 6: Train Loss: 3.5153, Train Accuracy: 14.61%
#     Worker 7: Train Loss: 3.4970, Train Accuracy: 15.60%
# Epoch 141/150: Test Loss: 3.3895, Test Accuracy: 18.30%
#     Worker 0: Train Loss: 3.4460, Train Accuracy: 16.38%
#     Worker 1: Train Loss: 3.4648, Train Accuracy: 16.50%
#     Worker 2: Train Loss: 3.4484, Train Accuracy: 17.17%
#     Worker 3: Train Loss: 3.5066, Train Accuracy: 15.39%
#     Worker 4: Train Loss: 3.4128, Train Accuracy: 17.15%
#     Worker 5: Train Loss: 3.4500, Train Accuracy: 17.07%
#     Worker 6: Train Loss: 3.4711, Train Accuracy: 16.16%
#     Worker 7: Train Loss: 3.4842, Train Accuracy: 16.22%
# Epoch 142/150: Test Loss: 3.3816, Test Accuracy: 18.83%
#     Worker 0: Train Loss: 3.4482, Train Accuracy: 16.37%
#     Worker 1: Train Loss: 3.4339, Train Accuracy: 16.86%
#     Worker 2: Train Loss: 3.4585, Train Accuracy: 17.84%
#     Worker 3: Train Loss: 3.4603, Train Accuracy: 16.27%
#     Worker 4: Train Loss: 3.4903, Train Accuracy: 16.24%
#     Worker 5: Train Loss: 3.4245, Train Accuracy: 17.02%
#     Worker 6: Train Loss: 3.4445, Train Accuracy: 16.85%
#     Worker 7: Train Loss: 3.4532, Train Accuracy: 16.24%
# Epoch 143/150: Test Loss: 3.3654, Test Accuracy: 18.93%
#     Worker 0: Train Loss: 3.4498, Train Accuracy: 16.48%
#     Worker 1: Train Loss: 3.4081, Train Accuracy: 17.34%
#     Worker 2: Train Loss: 3.4400, Train Accuracy: 17.66%
#     Worker 3: Train Loss: 3.4641, Train Accuracy: 16.74%
#     Worker 4: Train Loss: 3.4210, Train Accuracy: 17.38%
#     Worker 5: Train Loss: 3.4091, Train Accuracy: 17.76%
#     Worker 6: Train Loss: 3.4329, Train Accuracy: 16.54%
#     Worker 7: Train Loss: 3.4324, Train Accuracy: 16.66%
# Epoch 144/150: Test Loss: 3.3599, Test Accuracy: 18.63%
#     Worker 0: Train Loss: 3.4508, Train Accuracy: 16.43%
#     Worker 1: Train Loss: 3.4057, Train Accuracy: 17.58%
#     Worker 2: Train Loss: 3.4205, Train Accuracy: 17.92%
#     Worker 3: Train Loss: 3.4875, Train Accuracy: 16.66%
#     Worker 4: Train Loss: 3.3794, Train Accuracy: 18.14%
#     Worker 5: Train Loss: 3.3789, Train Accuracy: 18.34%
#     Worker 6: Train Loss: 3.4175, Train Accuracy: 17.44%
#     Worker 7: Train Loss: 3.4985, Train Accuracy: 15.46%
# Epoch 145/150: Test Loss: 3.3656, Test Accuracy: 18.85%
#     Worker 0: Train Loss: 3.4350, Train Accuracy: 16.85%
#     Worker 1: Train Loss: 3.4036, Train Accuracy: 17.47%
#     Worker 2: Train Loss: 3.4333, Train Accuracy: 17.97%
#     Worker 3: Train Loss: 3.4866, Train Accuracy: 16.45%
#     Worker 4: Train Loss: 3.3701, Train Accuracy: 18.11%
#     Worker 5: Train Loss: 3.4102, Train Accuracy: 18.38%
#     Worker 6: Train Loss: 3.4342, Train Accuracy: 16.67%
#     Worker 7: Train Loss: 3.4134, Train Accuracy: 17.23%
# Epoch 146/150: Test Loss: 3.3649, Test Accuracy: 18.98%
#     Worker 0: Train Loss: 3.4453, Train Accuracy: 16.56%
#     Worker 1: Train Loss: 3.3993, Train Accuracy: 17.70%
#     Worker 2: Train Loss: 3.4355, Train Accuracy: 18.08%
#     Worker 3: Train Loss: 3.4507, Train Accuracy: 16.96%
#     Worker 4: Train Loss: 3.3747, Train Accuracy: 18.43%
#     Worker 5: Train Loss: 3.3999, Train Accuracy: 18.08%
#     Worker 6: Train Loss: 3.4284, Train Accuracy: 17.26%
#     Worker 7: Train Loss: 3.4300, Train Accuracy: 16.82%
# Epoch 147/150: Test Loss: 3.3513, Test Accuracy: 19.06%
#     Worker 0: Train Loss: 3.4172, Train Accuracy: 17.23%
#     Worker 1: Train Loss: 3.3934, Train Accuracy: 18.29%
#     Worker 2: Train Loss: 3.4206, Train Accuracy: 17.87%
#     Worker 3: Train Loss: 3.4391, Train Accuracy: 16.96%
#     Worker 4: Train Loss: 3.3695, Train Accuracy: 17.52%
#     Worker 5: Train Loss: 3.3644, Train Accuracy: 18.90%
#     Worker 6: Train Loss: 3.4218, Train Accuracy: 17.70%
#     Worker 7: Train Loss: 3.4047, Train Accuracy: 17.33%
# Epoch 148/150: Test Loss: 3.3440, Test Accuracy: 19.13%
#     Worker 0: Train Loss: 3.4202, Train Accuracy: 17.20%
#     Worker 1: Train Loss: 3.3841, Train Accuracy: 17.66%
#     Worker 2: Train Loss: 3.3971, Train Accuracy: 18.16%
#     Worker 3: Train Loss: 3.4215, Train Accuracy: 17.78%
#     Worker 4: Train Loss: 3.3600, Train Accuracy: 18.85%
#     Worker 5: Train Loss: 3.3606, Train Accuracy: 19.04%
#     Worker 6: Train Loss: 3.3974, Train Accuracy: 17.68%
#     Worker 7: Train Loss: 3.3837, Train Accuracy: 17.79%
# Epoch 149/150: Test Loss: 3.3411, Test Accuracy: 19.20%
#     Worker 0: Train Loss: 3.4051, Train Accuracy: 17.54%
#     Worker 1: Train Loss: 3.3895, Train Accuracy: 18.26%
#     Worker 2: Train Loss: 3.3925, Train Accuracy: 18.00%
#     Worker 3: Train Loss: 3.4057, Train Accuracy: 17.60%
#     Worker 4: Train Loss: 3.3571, Train Accuracy: 18.22%
#     Worker 5: Train Loss: 3.3557, Train Accuracy: 19.17%
#     Worker 6: Train Loss: 3.3954, Train Accuracy: 17.55%
#     Worker 7: Train Loss: 3.3969, Train Accuracy: 17.92%
# Epoch 150/150: Test Loss: 3.3401, Test Accuracy: 19.20%
#     Worker 0: Train Loss: 3.4004, Train Accuracy: 17.31%
#     Worker 1: Train Loss: 3.3773, Train Accuracy: 18.42%
#     Worker 2: Train Loss: 3.4016, Train Accuracy: 17.60%
#     Worker 3: Train Loss: 3.4222, Train Accuracy: 17.31%
#     Worker 4: Train Loss: 3.3531, Train Accuracy: 18.82%
#     Worker 5: Train Loss: 3.3529, Train Accuracy: 19.42%
#     Worker 6: Train Loss: 3.4054, Train Accuracy: 17.10%
#     Worker 7: Train Loss: 3.3877, Train Accuracy: 17.78%
