# %%
# %%writefile localSGD.py

import os
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
num_epochs = 150
base_learning_rate = 1e-2
momentum = 0.9
weight_decay = 4e-4
warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std

class LRScheduler(torch.optim.lr_scheduler._LRScheduler):
    def __init__(self, optimizer, base_lr, K, warmup_epochs, total_epochs, verbose=False):
        """
        Args:
            optimizer: SGD
            base_lr: Base learning rate for the reference batch size.
            K: Number of workers.
            warmup_epochs: Number of warmup epochs.
            total_epochs: Total number of epochs.
            verbose: Whether to print LR updates.
        """
        self.base_lr = base_lr
        self.K = K
        self.scaled_lr = base_lr * K
        self.warmup_epochs = warmup_epochs
        self.total_epochs = total_epochs
        self.verbose = verbose
        super(LRScheduler, self).__init__(optimizer)

    def get_lr(self):
        epoch = self.last_epoch
        if epoch < self.warmup_epochs:
            # Linear warmup scaling
            warmup_factor = (epoch + 1) / self.warmup_epochs
            return [warmup_factor * self.scaled_lr for _ in self.optimizer.param_groups]
        else:
            # polynomially decaying learning rate of ηt = η0×(1−t/T)
            if epoch == self.warmup_epochs:
                print(f"Warmup phase completed at epoch {epoch}. Switching to polynomial decay learning rate.")
            return [self.scaled_lr * ( 1 - ( (epoch - self.warmup_epochs) / (self.total_epochs - self.warmup_epochs))) for _ in self.optimizer.param_groups]


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]

# Batch size
batch_size = shard_size // J

# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)


# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [LRScheduler(
    optimizer = optimizer,
    base_lr = base_learning_rate,
    K = K,
    warmup_epochs = warmup_epochs,
    total_epochs = num_epochs,
    verbose = True) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}")

    # Sequentially train each worker to simulate a distributed environment
    for k in range(K):
        shard_loader = DataLoader(shards[k], batch_size=batch_size, shuffle=True)

        nets[k].train()
        correct_train, total_train, train_loss = 0, 0, 0.0
        for images, labels in shard_loader:
            images, labels = images.to(device), labels.to(device)  # Move to device
            optimizers[k].zero_grad()
            outputs = nets[k](images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizers[k].step()
            # Calculate train loss and accuracy
            train_loss += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            total_train += labels.size(0)
            correct_train += predicted.eq(labels).sum().item()
        # Store train loss and accuracy for this worker
        train_loss /= len(shard_loader.dataset)
        train_losses_per_worker[k].append(train_loss)
        train_accuracy = 100. * correct_train / total_train
        train_accuracies_per_worker[k].append(train_accuracy)

    # Perform model synchronization
    with torch.no_grad():
        global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
        for net in nets:
            for global_param, local_param in zip(global_parameters, net.parameters()):
                global_param += local_param
        for global_param in global_parameters:
            global_param /= K
        # Update each worker model with the global parameters
        for net in nets:
            for local_param, global_param in zip(net.parameters(), global_parameters):
                local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        scheduler.step()

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 8 --j 32
# Out:
# Training with K=8, J=32
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:04<00:00, 38.9MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.08000
# Epoch 1/150: Test Loss: 4.6004, Test Accuracy: 1.32%
#     Worker 0: Train Loss: 4.6050, Train Accuracy: 1.42%
#     Worker 1: Train Loss: 4.6041, Train Accuracy: 1.23%
#     Worker 2: Train Loss: 4.6043, Train Accuracy: 1.12%
#     Worker 3: Train Loss: 4.6038, Train Accuracy: 1.26%
#     Worker 4: Train Loss: 4.6037, Train Accuracy: 1.36%
#     Worker 5: Train Loss: 4.6028, Train Accuracy: 1.46%
#     Worker 6: Train Loss: 4.6046, Train Accuracy: 1.14%
#     Worker 7: Train Loss: 4.6043, Train Accuracy: 1.30%
# Epoch 2/150: Test Loss: 4.5340, Test Accuracy: 2.21%
#     Worker 0: Train Loss: 4.5895, Train Accuracy: 1.50%
#     Worker 1: Train Loss: 4.5832, Train Accuracy: 2.11%
#     Worker 2: Train Loss: 4.5866, Train Accuracy: 1.60%
#     Worker 3: Train Loss: 4.5829, Train Accuracy: 1.57%
#     Worker 4: Train Loss: 4.5848, Train Accuracy: 1.98%
#     Worker 5: Train Loss: 4.5763, Train Accuracy: 1.74%
#     Worker 6: Train Loss: 4.5872, Train Accuracy: 1.65%
#     Worker 7: Train Loss: 4.5821, Train Accuracy: 1.60%
# Epoch 3/150: Test Loss: 4.1909, Test Accuracy: 6.69%
#     Worker 0: Train Loss: 4.4288, Train Accuracy: 3.46%
#     Worker 1: Train Loss: 4.4393, Train Accuracy: 3.22%
#     Worker 2: Train Loss: 4.4345, Train Accuracy: 3.47%
#     Worker 3: Train Loss: 4.4404, Train Accuracy: 2.85%
#     Worker 4: Train Loss: 4.4195, Train Accuracy: 3.31%
#     Worker 5: Train Loss: 4.4001, Train Accuracy: 3.09%
#     Worker 6: Train Loss: 4.4327, Train Accuracy: 3.20%
#     Worker 7: Train Loss: 4.4472, Train Accuracy: 3.10%
# Epoch 4/150: Test Loss: 4.0552, Test Accuracy: 8.06%
#     Worker 0: Train Loss: 4.2050, Train Accuracy: 4.86%
#     Worker 1: Train Loss: 4.2211, Train Accuracy: 5.33%
#     Worker 2: Train Loss: 4.2395, Train Accuracy: 4.78%
#     Worker 3: Train Loss: 4.2618, Train Accuracy: 4.96%
#     Worker 4: Train Loss: 4.1803, Train Accuracy: 5.90%
#     Worker 5: Train Loss: 4.2304, Train Accuracy: 4.96%
#     Worker 6: Train Loss: 4.2502, Train Accuracy: 4.38%
#     Worker 7: Train Loss: 4.2026, Train Accuracy: 5.01%
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Epoch 5/150: Test Loss: 3.9693, Test Accuracy: 9.90%
#     Worker 0: Train Loss: 4.1362, Train Accuracy: 6.00%
#     Worker 1: Train Loss: 4.1266, Train Accuracy: 6.43%
#     Worker 2: Train Loss: 4.0867, Train Accuracy: 7.25%
#     Worker 3: Train Loss: 4.1174, Train Accuracy: 5.95%
#     Worker 4: Train Loss: 4.0883, Train Accuracy: 7.28%
#     Worker 5: Train Loss: 4.1146, Train Accuracy: 6.30%
#     Worker 6: Train Loss: 4.1360, Train Accuracy: 6.32%
#     Worker 7: Train Loss: 4.1742, Train Accuracy: 6.30%
# Epoch 6/150: Test Loss: 3.8601, Test Accuracy: 12.16%
#     Worker 0: Train Loss: 4.0583, Train Accuracy: 6.53%
#     Worker 1: Train Loss: 4.0566, Train Accuracy: 7.26%
#     Worker 2: Train Loss: 4.0370, Train Accuracy: 7.47%
#     Worker 3: Train Loss: 4.0355, Train Accuracy: 7.22%
#     Worker 4: Train Loss: 4.0100, Train Accuracy: 8.16%
#     Worker 5: Train Loss: 3.9872, Train Accuracy: 8.11%
#     Worker 6: Train Loss: 3.9980, Train Accuracy: 7.26%
#     Worker 7: Train Loss: 4.0308, Train Accuracy: 7.52%
# Epoch 7/150: Test Loss: 3.7389, Test Accuracy: 13.64%
#     Worker 0: Train Loss: 3.9838, Train Accuracy: 8.98%
#     Worker 1: Train Loss: 3.9600, Train Accuracy: 8.53%
#     Worker 2: Train Loss: 3.9054, Train Accuracy: 9.63%
#     Worker 3: Train Loss: 3.9284, Train Accuracy: 8.75%
#     Worker 4: Train Loss: 3.9079, Train Accuracy: 9.33%
#     Worker 5: Train Loss: 3.9418, Train Accuracy: 9.20%
#     Worker 6: Train Loss: 3.9039, Train Accuracy: 8.82%
#     Worker 7: Train Loss: 3.9321, Train Accuracy: 8.96%
# Epoch 8/150: Test Loss: 3.6424, Test Accuracy: 15.58%
#     Worker 0: Train Loss: 3.8399, Train Accuracy: 10.32%
#     Worker 1: Train Loss: 3.8724, Train Accuracy: 9.79%
#     Worker 2: Train Loss: 3.8653, Train Accuracy: 10.27%
#     Worker 3: Train Loss: 3.9211, Train Accuracy: 9.23%
#     Worker 4: Train Loss: 3.8286, Train Accuracy: 10.59%
#     Worker 5: Train Loss: 3.8341, Train Accuracy: 10.45%
#     Worker 6: Train Loss: 3.8813, Train Accuracy: 9.55%
#     Worker 7: Train Loss: 3.9013, Train Accuracy: 10.10%
# Epoch 9/150: Test Loss: 3.5862, Test Accuracy: 16.86%
#     Worker 0: Train Loss: 3.7650, Train Accuracy: 11.26%
#     Worker 1: Train Loss: 3.7945, Train Accuracy: 11.15%
#     Worker 2: Train Loss: 3.7815, Train Accuracy: 11.49%
#     Worker 3: Train Loss: 3.8109, Train Accuracy: 10.91%
#     Worker 4: Train Loss: 3.7762, Train Accuracy: 11.09%
#     Worker 5: Train Loss: 3.7600, Train Accuracy: 11.38%
#     Worker 6: Train Loss: 3.7987, Train Accuracy: 10.67%
#     Worker 7: Train Loss: 3.7756, Train Accuracy: 11.87%
# Epoch 10/150: Test Loss: 3.5890, Test Accuracy: 16.92%
#     Worker 0: Train Loss: 3.7986, Train Accuracy: 11.12%
#     Worker 1: Train Loss: 3.7364, Train Accuracy: 11.82%
#     Worker 2: Train Loss: 3.7264, Train Accuracy: 12.34%
#     Worker 3: Train Loss: 3.7472, Train Accuracy: 12.16%
#     Worker 4: Train Loss: 3.6854, Train Accuracy: 12.64%
#     Worker 5: Train Loss: 3.7577, Train Accuracy: 12.05%
#     Worker 6: Train Loss: 3.7781, Train Accuracy: 11.06%
#     Worker 7: Train Loss: 3.7928, Train Accuracy: 11.22%
# Epoch 11/150: Test Loss: 3.4834, Test Accuracy: 18.52%
#     Worker 0: Train Loss: 3.7343, Train Accuracy: 12.13%
#     Worker 1: Train Loss: 3.6664, Train Accuracy: 12.75%
#     Worker 2: Train Loss: 3.6870, Train Accuracy: 12.90%
#     Worker 3: Train Loss: 3.7472, Train Accuracy: 12.18%
#     Worker 4: Train Loss: 3.6425, Train Accuracy: 13.71%
#     Worker 5: Train Loss: 3.6142, Train Accuracy: 14.26%
#     Worker 6: Train Loss: 3.7795, Train Accuracy: 12.13%
#     Worker 7: Train Loss: 3.7002, Train Accuracy: 13.09%
# Epoch 12/150: Test Loss: 3.4597, Test Accuracy: 19.84%
#     Worker 0: Train Loss: 3.6838, Train Accuracy: 12.42%
#     Worker 1: Train Loss: 3.7041, Train Accuracy: 12.27%
#     Worker 2: Train Loss: 3.6133, Train Accuracy: 14.00%
#     Worker 3: Train Loss: 3.6348, Train Accuracy: 13.86%
#     Worker 4: Train Loss: 3.6706, Train Accuracy: 12.94%
#     Worker 5: Train Loss: 3.5701, Train Accuracy: 14.40%
#     Worker 6: Train Loss: 3.6425, Train Accuracy: 13.58%
#     Worker 7: Train Loss: 3.6661, Train Accuracy: 13.33%
# Epoch 13/150: Test Loss: 3.3890, Test Accuracy: 21.00%
#     Worker 0: Train Loss: 3.5900, Train Accuracy: 14.05%
#     Worker 1: Train Loss: 3.5551, Train Accuracy: 15.31%
#     Worker 2: Train Loss: 3.5941, Train Accuracy: 15.42%
#     Worker 3: Train Loss: 3.5787, Train Accuracy: 14.85%
#     Worker 4: Train Loss: 3.6067, Train Accuracy: 14.43%
#     Worker 5: Train Loss: 3.6533, Train Accuracy: 14.10%
#     Worker 6: Train Loss: 3.6692, Train Accuracy: 13.41%
#     Worker 7: Train Loss: 3.6243, Train Accuracy: 13.66%
# Epoch 14/150: Test Loss: 3.2697, Test Accuracy: 22.71%
#     Worker 0: Train Loss: 3.5885, Train Accuracy: 15.10%
#     Worker 1: Train Loss: 3.5062, Train Accuracy: 16.14%
#     Worker 2: Train Loss: 3.5405, Train Accuracy: 15.84%
#     Worker 3: Train Loss: 3.6271, Train Accuracy: 14.21%
#     Worker 4: Train Loss: 3.5170, Train Accuracy: 15.39%
#     Worker 5: Train Loss: 3.4800, Train Accuracy: 16.43%
#     Worker 6: Train Loss: 3.5297, Train Accuracy: 15.46%
#     Worker 7: Train Loss: 3.5374, Train Accuracy: 15.07%
# Epoch 15/150: Test Loss: 3.2585, Test Accuracy: 23.24%
#     Worker 0: Train Loss: 3.4861, Train Accuracy: 16.48%
#     Worker 1: Train Loss: 3.4926, Train Accuracy: 16.00%
#     Worker 2: Train Loss: 3.4687, Train Accuracy: 17.12%
#     Worker 3: Train Loss: 3.5202, Train Accuracy: 15.79%
#     Worker 4: Train Loss: 3.4264, Train Accuracy: 17.02%
#     Worker 5: Train Loss: 3.5491, Train Accuracy: 15.42%
#     Worker 6: Train Loss: 3.5055, Train Accuracy: 15.71%
#     Worker 7: Train Loss: 3.5777, Train Accuracy: 14.80%
# Epoch 16/150: Test Loss: 3.2729, Test Accuracy: 23.11%
#     Worker 0: Train Loss: 3.4625, Train Accuracy: 17.07%
#     Worker 1: Train Loss: 3.4353, Train Accuracy: 17.31%
#     Worker 2: Train Loss: 3.4792, Train Accuracy: 16.29%
#     Worker 3: Train Loss: 3.5409, Train Accuracy: 15.25%
#     Worker 4: Train Loss: 3.3883, Train Accuracy: 17.68%
#     Worker 5: Train Loss: 3.4604, Train Accuracy: 16.59%
#     Worker 6: Train Loss: 3.3919, Train Accuracy: 18.30%
#     Worker 7: Train Loss: 3.4178, Train Accuracy: 17.41%
# Epoch 17/150: Test Loss: 3.2295, Test Accuracy: 24.64%
#     Worker 0: Train Loss: 3.4861, Train Accuracy: 16.18%
#     Worker 1: Train Loss: 3.4462, Train Accuracy: 17.09%
#     Worker 2: Train Loss: 3.3800, Train Accuracy: 18.34%
#     Worker 3: Train Loss: 3.4668, Train Accuracy: 17.07%
#     Worker 4: Train Loss: 3.4065, Train Accuracy: 17.65%
#     Worker 5: Train Loss: 3.3904, Train Accuracy: 17.98%
#     Worker 6: Train Loss: 3.4180, Train Accuracy: 16.45%
#     Worker 7: Train Loss: 3.4078, Train Accuracy: 17.65%
# Epoch 18/150: Test Loss: 3.1837, Test Accuracy: 25.09%
#     Worker 0: Train Loss: 3.4404, Train Accuracy: 17.63%
#     Worker 1: Train Loss: 3.3302, Train Accuracy: 19.30%
#     Worker 2: Train Loss: 3.3693, Train Accuracy: 18.72%
#     Worker 3: Train Loss: 3.4304, Train Accuracy: 17.23%
#     Worker 4: Train Loss: 3.3697, Train Accuracy: 18.74%
#     Worker 5: Train Loss: 3.3954, Train Accuracy: 18.11%
#     Worker 6: Train Loss: 3.3732, Train Accuracy: 17.60%
#     Worker 7: Train Loss: 3.3349, Train Accuracy: 19.34%
# Epoch 19/150: Test Loss: 3.1329, Test Accuracy: 25.43%
#     Worker 0: Train Loss: 3.3263, Train Accuracy: 19.18%
#     Worker 1: Train Loss: 3.3819, Train Accuracy: 17.94%
#     Worker 2: Train Loss: 3.3793, Train Accuracy: 18.42%
#     Worker 3: Train Loss: 3.3132, Train Accuracy: 19.38%
#     Worker 4: Train Loss: 3.3003, Train Accuracy: 19.17%
#     Worker 5: Train Loss: 3.3885, Train Accuracy: 18.66%
#     Worker 6: Train Loss: 3.3842, Train Accuracy: 17.33%
#     Worker 7: Train Loss: 3.3926, Train Accuracy: 17.65%
# Epoch 20/150: Test Loss: 3.0790, Test Accuracy: 26.29%
#     Worker 0: Train Loss: 3.3034, Train Accuracy: 20.13%
#     Worker 1: Train Loss: 3.3139, Train Accuracy: 19.12%
#     Worker 2: Train Loss: 3.3357, Train Accuracy: 19.30%
#     Worker 3: Train Loss: 3.4316, Train Accuracy: 17.09%
#     Worker 4: Train Loss: 3.2772, Train Accuracy: 20.22%
#     Worker 5: Train Loss: 3.2974, Train Accuracy: 19.52%
#     Worker 6: Train Loss: 3.3039, Train Accuracy: 19.58%
#     Worker 7: Train Loss: 3.3010, Train Accuracy: 19.98%
# Epoch 21/150: Test Loss: 3.0205, Test Accuracy: 27.79%
#     Worker 0: Train Loss: 3.2613, Train Accuracy: 19.95%
#     Worker 1: Train Loss: 3.2361, Train Accuracy: 21.09%
#     Worker 2: Train Loss: 3.2475, Train Accuracy: 20.82%
#     Worker 3: Train Loss: 3.2980, Train Accuracy: 18.94%
#     Worker 4: Train Loss: 3.2129, Train Accuracy: 21.22%
#     Worker 5: Train Loss: 3.2292, Train Accuracy: 21.10%
#     Worker 6: Train Loss: 3.3317, Train Accuracy: 19.58%
#     Worker 7: Train Loss: 3.2845, Train Accuracy: 19.90%
# Epoch 22/150: Test Loss: 2.9836, Test Accuracy: 28.36%
#     Worker 0: Train Loss: 3.2122, Train Accuracy: 21.34%
#     Worker 1: Train Loss: 3.2202, Train Accuracy: 20.85%
#     Worker 2: Train Loss: 3.2700, Train Accuracy: 20.24%
#     Worker 3: Train Loss: 3.3486, Train Accuracy: 18.66%
#     Worker 4: Train Loss: 3.1910, Train Accuracy: 21.57%
#     Worker 5: Train Loss: 3.1899, Train Accuracy: 22.58%
#     Worker 6: Train Loss: 3.2674, Train Accuracy: 19.81%
#     Worker 7: Train Loss: 3.2061, Train Accuracy: 21.52%
# Epoch 23/150: Test Loss: 2.9387, Test Accuracy: 29.46%
#     Worker 0: Train Loss: 3.1585, Train Accuracy: 21.58%
#     Worker 1: Train Loss: 3.1407, Train Accuracy: 22.13%
#     Worker 2: Train Loss: 3.2205, Train Accuracy: 21.65%
#     Worker 3: Train Loss: 3.2349, Train Accuracy: 21.63%
#     Worker 4: Train Loss: 3.0780, Train Accuracy: 24.22%
#     Worker 5: Train Loss: 3.1427, Train Accuracy: 22.80%
#     Worker 6: Train Loss: 3.1968, Train Accuracy: 22.29%
#     Worker 7: Train Loss: 3.2582, Train Accuracy: 20.61%
# Epoch 24/150: Test Loss: 2.9143, Test Accuracy: 30.02%
#     Worker 0: Train Loss: 3.1279, Train Accuracy: 22.54%
#     Worker 1: Train Loss: 3.1068, Train Accuracy: 23.42%
#     Worker 2: Train Loss: 3.1607, Train Accuracy: 22.56%
#     Worker 3: Train Loss: 3.1694, Train Accuracy: 21.62%
#     Worker 4: Train Loss: 3.0883, Train Accuracy: 23.33%
#     Worker 5: Train Loss: 3.1109, Train Accuracy: 23.71%
#     Worker 6: Train Loss: 3.1364, Train Accuracy: 22.54%
#     Worker 7: Train Loss: 3.1740, Train Accuracy: 22.27%
# Epoch 25/150: Test Loss: 2.8745, Test Accuracy: 29.86%
#     Worker 0: Train Loss: 3.1288, Train Accuracy: 22.54%
#     Worker 1: Train Loss: 3.0767, Train Accuracy: 23.46%
#     Worker 2: Train Loss: 3.0890, Train Accuracy: 23.79%
#     Worker 3: Train Loss: 3.1928, Train Accuracy: 21.71%
#     Worker 4: Train Loss: 3.0984, Train Accuracy: 23.38%
#     Worker 5: Train Loss: 3.0977, Train Accuracy: 23.54%
#     Worker 6: Train Loss: 3.0802, Train Accuracy: 23.58%
#     Worker 7: Train Loss: 3.0528, Train Accuracy: 24.69%
# Epoch 26/150: Test Loss: 2.8311, Test Accuracy: 31.14%
#     Worker 0: Train Loss: 3.1154, Train Accuracy: 22.94%
#     Worker 1: Train Loss: 3.0102, Train Accuracy: 25.20%
#     Worker 2: Train Loss: 3.0935, Train Accuracy: 23.89%
#     Worker 3: Train Loss: 3.0846, Train Accuracy: 23.57%
#     Worker 4: Train Loss: 3.0681, Train Accuracy: 23.58%
#     Worker 5: Train Loss: 3.0241, Train Accuracy: 25.47%
#     Worker 6: Train Loss: 3.1047, Train Accuracy: 22.85%
#     Worker 7: Train Loss: 3.0392, Train Accuracy: 24.34%
# Epoch 27/150: Test Loss: 2.8008, Test Accuracy: 31.12%
#     Worker 0: Train Loss: 3.0705, Train Accuracy: 24.13%
#     Worker 1: Train Loss: 2.9685, Train Accuracy: 25.25%
#     Worker 2: Train Loss: 3.0342, Train Accuracy: 24.96%
#     Worker 3: Train Loss: 3.1525, Train Accuracy: 22.88%
#     Worker 4: Train Loss: 2.9832, Train Accuracy: 26.38%
#     Worker 5: Train Loss: 3.0384, Train Accuracy: 24.85%
#     Worker 6: Train Loss: 3.0443, Train Accuracy: 24.21%
#     Worker 7: Train Loss: 3.0508, Train Accuracy: 24.38%
# Epoch 28/150: Test Loss: 2.7697, Test Accuracy: 32.22%
#     Worker 0: Train Loss: 3.0155, Train Accuracy: 24.96%
#     Worker 1: Train Loss: 3.0432, Train Accuracy: 24.37%
#     Worker 2: Train Loss: 2.9964, Train Accuracy: 25.65%
#     Worker 3: Train Loss: 3.0319, Train Accuracy: 24.83%
#     Worker 4: Train Loss: 3.0646, Train Accuracy: 23.90%
#     Worker 5: Train Loss: 3.0200, Train Accuracy: 25.22%
#     Worker 6: Train Loss: 3.0594, Train Accuracy: 24.40%
#     Worker 7: Train Loss: 2.9828, Train Accuracy: 26.26%
# Epoch 29/150: Test Loss: 2.7519, Test Accuracy: 32.65%
#     Worker 0: Train Loss: 2.9480, Train Accuracy: 26.19%
#     Worker 1: Train Loss: 2.9911, Train Accuracy: 24.80%
#     Worker 2: Train Loss: 3.0548, Train Accuracy: 24.11%
#     Worker 3: Train Loss: 2.9846, Train Accuracy: 25.52%
#     Worker 4: Train Loss: 2.8896, Train Accuracy: 27.20%
#     Worker 5: Train Loss: 3.0152, Train Accuracy: 25.63%
#     Worker 6: Train Loss: 2.9676, Train Accuracy: 25.89%
#     Worker 7: Train Loss: 3.0745, Train Accuracy: 24.21%
# Epoch 30/150: Test Loss: 2.7502, Test Accuracy: 32.09%
#     Worker 0: Train Loss: 3.0263, Train Accuracy: 25.30%
#     Worker 1: Train Loss: 2.9134, Train Accuracy: 26.74%
#     Worker 2: Train Loss: 3.0904, Train Accuracy: 25.12%
#     Worker 3: Train Loss: 3.0076, Train Accuracy: 26.19%
#     Worker 4: Train Loss: 2.9219, Train Accuracy: 26.67%
#     Worker 5: Train Loss: 3.0506, Train Accuracy: 24.85%
#     Worker 6: Train Loss: 2.9059, Train Accuracy: 26.99%
#     Worker 7: Train Loss: 2.9508, Train Accuracy: 26.62%
# Epoch 31/150: Test Loss: 2.6964, Test Accuracy: 33.39%
#     Worker 0: Train Loss: 3.0030, Train Accuracy: 25.62%
#     Worker 1: Train Loss: 2.9270, Train Accuracy: 26.98%
#     Worker 2: Train Loss: 2.9875, Train Accuracy: 26.40%
#     Worker 3: Train Loss: 3.0402, Train Accuracy: 24.99%
#     Worker 4: Train Loss: 2.9323, Train Accuracy: 25.95%
#     Worker 5: Train Loss: 2.9509, Train Accuracy: 26.16%
#     Worker 6: Train Loss: 2.9121, Train Accuracy: 27.82%
#     Worker 7: Train Loss: 2.8888, Train Accuracy: 27.52%
# Epoch 32/150: Test Loss: 2.6842, Test Accuracy: 34.34%
#     Worker 0: Train Loss: 2.9042, Train Accuracy: 26.86%
#     Worker 1: Train Loss: 2.9197, Train Accuracy: 27.17%
#     Worker 2: Train Loss: 2.9308, Train Accuracy: 26.19%
#     Worker 3: Train Loss: 2.9528, Train Accuracy: 25.42%
#     Worker 4: Train Loss: 2.8161, Train Accuracy: 28.83%
#     Worker 5: Train Loss: 3.0481, Train Accuracy: 25.44%
#     Worker 6: Train Loss: 2.8804, Train Accuracy: 27.62%
#     Worker 7: Train Loss: 2.8949, Train Accuracy: 27.49%
# Epoch 33/150: Test Loss: 2.6429, Test Accuracy: 35.22%
#     Worker 0: Train Loss: 2.8840, Train Accuracy: 27.62%
#     Worker 1: Train Loss: 2.8626, Train Accuracy: 27.90%
#     Worker 2: Train Loss: 2.8880, Train Accuracy: 27.98%
#     Worker 3: Train Loss: 2.8732, Train Accuracy: 27.90%
#     Worker 4: Train Loss: 2.8437, Train Accuracy: 29.10%
#     Worker 5: Train Loss: 2.8856, Train Accuracy: 27.74%
#     Worker 6: Train Loss: 2.9520, Train Accuracy: 25.74%
#     Worker 7: Train Loss: 2.8409, Train Accuracy: 28.26%
# Epoch 34/150: Test Loss: 2.6247, Test Accuracy: 35.28%
#     Worker 0: Train Loss: 2.8334, Train Accuracy: 28.13%
#     Worker 1: Train Loss: 2.8030, Train Accuracy: 28.88%
#     Worker 2: Train Loss: 2.8521, Train Accuracy: 28.42%
#     Worker 3: Train Loss: 2.8430, Train Accuracy: 28.75%
#     Worker 4: Train Loss: 2.8686, Train Accuracy: 27.87%
#     Worker 5: Train Loss: 2.8133, Train Accuracy: 29.68%
#     Worker 6: Train Loss: 2.9764, Train Accuracy: 26.19%
#     Worker 7: Train Loss: 2.8619, Train Accuracy: 28.67%
# Epoch 35/150: Test Loss: 2.6176, Test Accuracy: 35.49%
#     Worker 0: Train Loss: 2.7737, Train Accuracy: 29.87%
#     Worker 1: Train Loss: 2.7670, Train Accuracy: 29.34%
#     Worker 2: Train Loss: 2.8028, Train Accuracy: 29.62%
#     Worker 3: Train Loss: 2.8890, Train Accuracy: 28.18%
#     Worker 4: Train Loss: 2.7906, Train Accuracy: 29.81%
#     Worker 5: Train Loss: 2.8117, Train Accuracy: 29.74%
#     Worker 6: Train Loss: 2.9385, Train Accuracy: 26.72%
#     Worker 7: Train Loss: 2.9002, Train Accuracy: 26.56%
# Epoch 36/150: Test Loss: 2.5675, Test Accuracy: 36.21%
#     Worker 0: Train Loss: 2.7676, Train Accuracy: 29.66%
#     Worker 1: Train Loss: 2.7954, Train Accuracy: 29.30%
#     Worker 2: Train Loss: 2.8572, Train Accuracy: 28.69%
#     Worker 3: Train Loss: 2.8326, Train Accuracy: 28.53%
#     Worker 4: Train Loss: 2.8410, Train Accuracy: 28.45%
#     Worker 5: Train Loss: 2.7401, Train Accuracy: 31.04%
#     Worker 6: Train Loss: 2.8164, Train Accuracy: 28.64%
#     Worker 7: Train Loss: 2.7719, Train Accuracy: 29.82%
# Epoch 37/150: Test Loss: 2.5513, Test Accuracy: 36.89%
#     Worker 0: Train Loss: 2.8504, Train Accuracy: 28.42%
#     Worker 1: Train Loss: 2.7339, Train Accuracy: 29.90%
#     Worker 2: Train Loss: 2.7626, Train Accuracy: 30.69%
#     Worker 3: Train Loss: 2.8530, Train Accuracy: 28.10%
#     Worker 4: Train Loss: 2.6905, Train Accuracy: 30.86%
#     Worker 5: Train Loss: 2.7622, Train Accuracy: 30.56%
#     Worker 6: Train Loss: 2.7770, Train Accuracy: 29.28%
#     Worker 7: Train Loss: 2.7269, Train Accuracy: 31.09%
# Epoch 38/150: Test Loss: 2.5459, Test Accuracy: 36.98%
#     Worker 0: Train Loss: 2.7965, Train Accuracy: 29.50%
#     Worker 1: Train Loss: 2.7322, Train Accuracy: 30.18%
#     Worker 2: Train Loss: 2.7403, Train Accuracy: 30.80%
#     Worker 3: Train Loss: 2.9575, Train Accuracy: 26.88%
#     Worker 4: Train Loss: 2.7318, Train Accuracy: 30.98%
#     Worker 5: Train Loss: 2.8724, Train Accuracy: 28.58%
#     Worker 6: Train Loss: 2.7737, Train Accuracy: 29.52%
#     Worker 7: Train Loss: 2.6846, Train Accuracy: 32.08%
# Epoch 39/150: Test Loss: 2.5064, Test Accuracy: 37.91%
#     Worker 0: Train Loss: 2.7280, Train Accuracy: 30.72%
#     Worker 1: Train Loss: 2.7198, Train Accuracy: 30.83%
#     Worker 2: Train Loss: 2.7907, Train Accuracy: 29.89%
#     Worker 3: Train Loss: 2.7634, Train Accuracy: 29.26%
#     Worker 4: Train Loss: 2.7083, Train Accuracy: 31.17%
#     Worker 5: Train Loss: 2.7684, Train Accuracy: 30.02%
#     Worker 6: Train Loss: 2.8078, Train Accuracy: 29.76%
#     Worker 7: Train Loss: 2.7090, Train Accuracy: 31.70%
# Epoch 40/150: Test Loss: 2.5190, Test Accuracy: 37.46%
#     Worker 0: Train Loss: 2.7708, Train Accuracy: 30.56%
#     Worker 1: Train Loss: 2.7527, Train Accuracy: 30.66%
#     Worker 2: Train Loss: 2.6677, Train Accuracy: 32.32%
#     Worker 3: Train Loss: 2.6870, Train Accuracy: 32.34%
#     Worker 4: Train Loss: 2.6354, Train Accuracy: 32.27%
#     Worker 5: Train Loss: 2.6792, Train Accuracy: 32.11%
#     Worker 6: Train Loss: 2.7325, Train Accuracy: 30.51%
#     Worker 7: Train Loss: 2.7667, Train Accuracy: 30.43%
# Epoch 41/150: Test Loss: 2.4906, Test Accuracy: 37.73%
#     Worker 0: Train Loss: 2.6341, Train Accuracy: 32.66%
#     Worker 1: Train Loss: 2.6419, Train Accuracy: 31.66%
#     Worker 2: Train Loss: 2.6500, Train Accuracy: 33.34%
#     Worker 3: Train Loss: 2.8283, Train Accuracy: 29.20%
#     Worker 4: Train Loss: 2.6993, Train Accuracy: 31.76%
#     Worker 5: Train Loss: 2.6941, Train Accuracy: 31.95%
#     Worker 6: Train Loss: 2.8107, Train Accuracy: 30.18%
#     Worker 7: Train Loss: 2.7220, Train Accuracy: 31.30%
# Epoch 42/150: Test Loss: 2.4995, Test Accuracy: 38.08%
#     Worker 0: Train Loss: 2.7833, Train Accuracy: 29.87%
#     Worker 1: Train Loss: 2.7413, Train Accuracy: 30.43%
#     Worker 2: Train Loss: 2.7157, Train Accuracy: 31.31%
#     Worker 3: Train Loss: 2.6845, Train Accuracy: 31.87%
#     Worker 4: Train Loss: 2.6307, Train Accuracy: 33.38%
#     Worker 5: Train Loss: 2.6403, Train Accuracy: 32.54%
#     Worker 6: Train Loss: 2.7528, Train Accuracy: 30.13%
#     Worker 7: Train Loss: 2.7359, Train Accuracy: 31.18%
# Epoch 43/150: Test Loss: 2.4411, Test Accuracy: 38.45%
#     Worker 0: Train Loss: 2.5941, Train Accuracy: 33.90%
#     Worker 1: Train Loss: 2.6013, Train Accuracy: 32.96%
#     Worker 2: Train Loss: 2.6027, Train Accuracy: 34.06%
#     Worker 3: Train Loss: 2.6480, Train Accuracy: 32.27%
#     Worker 4: Train Loss: 2.6723, Train Accuracy: 32.00%
#     Worker 5: Train Loss: 2.6584, Train Accuracy: 32.59%
#     Worker 6: Train Loss: 2.6797, Train Accuracy: 31.41%
#     Worker 7: Train Loss: 2.6490, Train Accuracy: 31.90%
# Epoch 44/150: Test Loss: 2.4113, Test Accuracy: 39.20%
#     Worker 0: Train Loss: 2.6221, Train Accuracy: 32.61%
#     Worker 1: Train Loss: 2.5739, Train Accuracy: 33.90%
#     Worker 2: Train Loss: 2.6663, Train Accuracy: 32.26%
#     Worker 3: Train Loss: 2.6716, Train Accuracy: 32.16%
#     Worker 4: Train Loss: 2.4879, Train Accuracy: 35.49%
#     Worker 5: Train Loss: 2.6289, Train Accuracy: 33.12%
#     Worker 6: Train Loss: 2.6225, Train Accuracy: 32.48%
#     Worker 7: Train Loss: 2.5929, Train Accuracy: 34.02%
# Epoch 45/150: Test Loss: 2.4058, Test Accuracy: 39.32%
#     Worker 0: Train Loss: 2.6333, Train Accuracy: 32.22%
#     Worker 1: Train Loss: 2.5675, Train Accuracy: 33.86%
#     Worker 2: Train Loss: 2.6716, Train Accuracy: 32.26%
#     Worker 3: Train Loss: 2.6774, Train Accuracy: 31.01%
#     Worker 4: Train Loss: 2.6400, Train Accuracy: 32.88%
#     Worker 5: Train Loss: 2.6357, Train Accuracy: 33.50%
#     Worker 6: Train Loss: 2.5995, Train Accuracy: 34.18%
#     Worker 7: Train Loss: 2.5516, Train Accuracy: 34.42%
# Epoch 46/150: Test Loss: 2.3671, Test Accuracy: 40.12%
#     Worker 0: Train Loss: 2.6273, Train Accuracy: 32.40%
#     Worker 1: Train Loss: 2.5306, Train Accuracy: 34.56%
#     Worker 2: Train Loss: 2.5620, Train Accuracy: 34.45%
#     Worker 3: Train Loss: 2.6677, Train Accuracy: 32.43%
#     Worker 4: Train Loss: 2.5122, Train Accuracy: 35.44%
#     Worker 5: Train Loss: 2.5713, Train Accuracy: 34.64%
#     Worker 6: Train Loss: 2.5517, Train Accuracy: 33.84%
#     Worker 7: Train Loss: 2.5690, Train Accuracy: 33.76%
# Epoch 47/150: Test Loss: 2.3850, Test Accuracy: 40.04%
#     Worker 0: Train Loss: 2.5881, Train Accuracy: 34.06%
#     Worker 1: Train Loss: 2.5622, Train Accuracy: 33.92%
#     Worker 2: Train Loss: 2.6934, Train Accuracy: 31.63%
#     Worker 3: Train Loss: 2.5878, Train Accuracy: 34.22%
#     Worker 4: Train Loss: 2.6263, Train Accuracy: 33.09%
#     Worker 5: Train Loss: 2.5548, Train Accuracy: 34.56%
#     Worker 6: Train Loss: 2.5563, Train Accuracy: 33.94%
#     Worker 7: Train Loss: 2.5944, Train Accuracy: 33.30%
# Epoch 48/150: Test Loss: 2.3476, Test Accuracy: 41.09%
#     Worker 0: Train Loss: 2.5255, Train Accuracy: 35.34%
#     Worker 1: Train Loss: 2.5784, Train Accuracy: 33.04%
#     Worker 2: Train Loss: 2.5419, Train Accuracy: 35.15%
#     Worker 3: Train Loss: 2.5255, Train Accuracy: 34.78%
#     Worker 4: Train Loss: 2.5100, Train Accuracy: 35.25%
#     Worker 5: Train Loss: 2.5499, Train Accuracy: 34.69%
#     Worker 6: Train Loss: 2.5286, Train Accuracy: 34.72%
#     Worker 7: Train Loss: 2.5186, Train Accuracy: 35.62%
# Epoch 49/150: Test Loss: 2.3602, Test Accuracy: 40.53%
#     Worker 0: Train Loss: 2.5969, Train Accuracy: 33.33%
#     Worker 1: Train Loss: 2.4207, Train Accuracy: 36.72%
#     Worker 2: Train Loss: 2.5129, Train Accuracy: 35.06%
#     Worker 3: Train Loss: 2.5866, Train Accuracy: 34.50%
#     Worker 4: Train Loss: 2.4849, Train Accuracy: 35.31%
#     Worker 5: Train Loss: 2.6653, Train Accuracy: 33.49%
#     Worker 6: Train Loss: 2.5618, Train Accuracy: 34.56%
#     Worker 7: Train Loss: 2.5261, Train Accuracy: 35.52%
# Epoch 50/150: Test Loss: 2.3347, Test Accuracy: 40.70%
#     Worker 0: Train Loss: 2.6544, Train Accuracy: 32.48%
#     Worker 1: Train Loss: 2.5750, Train Accuracy: 33.26%
#     Worker 2: Train Loss: 2.5233, Train Accuracy: 35.01%
#     Worker 3: Train Loss: 2.4707, Train Accuracy: 35.68%
#     Worker 4: Train Loss: 2.4449, Train Accuracy: 36.37%
#     Worker 5: Train Loss: 2.4565, Train Accuracy: 36.88%
#     Worker 6: Train Loss: 2.4835, Train Accuracy: 36.19%
#     Worker 7: Train Loss: 2.4785, Train Accuracy: 35.82%
# Epoch 51/150: Test Loss: 2.3330, Test Accuracy: 41.35%
#     Worker 0: Train Loss: 2.4212, Train Accuracy: 37.06%
#     Worker 1: Train Loss: 2.5837, Train Accuracy: 33.38%
#     Worker 2: Train Loss: 2.5166, Train Accuracy: 35.71%
#     Worker 3: Train Loss: 2.6269, Train Accuracy: 32.94%
#     Worker 4: Train Loss: 2.4603, Train Accuracy: 36.58%
#     Worker 5: Train Loss: 2.4294, Train Accuracy: 37.86%
#     Worker 6: Train Loss: 2.5058, Train Accuracy: 35.20%
#     Worker 7: Train Loss: 2.5509, Train Accuracy: 34.80%
# Epoch 52/150: Test Loss: 2.3157, Test Accuracy: 41.37%
#     Worker 0: Train Loss: 2.4961, Train Accuracy: 36.02%
#     Worker 1: Train Loss: 2.6142, Train Accuracy: 33.02%
#     Worker 2: Train Loss: 2.5110, Train Accuracy: 36.08%
#     Worker 3: Train Loss: 2.4888, Train Accuracy: 35.38%
#     Worker 4: Train Loss: 2.4543, Train Accuracy: 36.45%
#     Worker 5: Train Loss: 2.4986, Train Accuracy: 36.30%
#     Worker 6: Train Loss: 2.4823, Train Accuracy: 36.32%
#     Worker 7: Train Loss: 2.4069, Train Accuracy: 37.30%
# Epoch 53/150: Test Loss: 2.3050, Test Accuracy: 41.60%
#     Worker 0: Train Loss: 2.4515, Train Accuracy: 36.08%
#     Worker 1: Train Loss: 2.4777, Train Accuracy: 36.00%
#     Worker 2: Train Loss: 2.4897, Train Accuracy: 36.66%
#     Worker 3: Train Loss: 2.5922, Train Accuracy: 33.57%
#     Worker 4: Train Loss: 2.4103, Train Accuracy: 37.66%
#     Worker 5: Train Loss: 2.3883, Train Accuracy: 37.47%
#     Worker 6: Train Loss: 2.5833, Train Accuracy: 34.43%
#     Worker 7: Train Loss: 2.4730, Train Accuracy: 36.02%
# Epoch 54/150: Test Loss: 2.2676, Test Accuracy: 42.02%
#     Worker 0: Train Loss: 2.4108, Train Accuracy: 37.94%
#     Worker 1: Train Loss: 2.4533, Train Accuracy: 35.41%
#     Worker 2: Train Loss: 2.4719, Train Accuracy: 37.01%
#     Worker 3: Train Loss: 2.4110, Train Accuracy: 37.49%
#     Worker 4: Train Loss: 2.4251, Train Accuracy: 36.69%
#     Worker 5: Train Loss: 2.3700, Train Accuracy: 37.98%
#     Worker 6: Train Loss: 2.4589, Train Accuracy: 35.94%
#     Worker 7: Train Loss: 2.3705, Train Accuracy: 38.26%
# Epoch 55/150: Test Loss: 2.2584, Test Accuracy: 42.75%
#     Worker 0: Train Loss: 2.4596, Train Accuracy: 36.26%
#     Worker 1: Train Loss: 2.4617, Train Accuracy: 35.25%
#     Worker 2: Train Loss: 2.4410, Train Accuracy: 36.43%
#     Worker 3: Train Loss: 2.4673, Train Accuracy: 36.21%
#     Worker 4: Train Loss: 2.4205, Train Accuracy: 36.83%
#     Worker 5: Train Loss: 2.3704, Train Accuracy: 38.93%
#     Worker 6: Train Loss: 2.4676, Train Accuracy: 35.86%
#     Worker 7: Train Loss: 2.4310, Train Accuracy: 36.61%
# Epoch 56/150: Test Loss: 2.2587, Test Accuracy: 42.61%
#     Worker 0: Train Loss: 2.4973, Train Accuracy: 35.26%
#     Worker 1: Train Loss: 2.3715, Train Accuracy: 37.65%
#     Worker 2: Train Loss: 2.3483, Train Accuracy: 38.96%
#     Worker 3: Train Loss: 2.5167, Train Accuracy: 34.77%
#     Worker 4: Train Loss: 2.4528, Train Accuracy: 36.10%
#     Worker 5: Train Loss: 2.4127, Train Accuracy: 37.54%
#     Worker 6: Train Loss: 2.4727, Train Accuracy: 35.92%
#     Worker 7: Train Loss: 2.4146, Train Accuracy: 37.01%
# Epoch 57/150: Test Loss: 2.2251, Test Accuracy: 43.38%
#     Worker 0: Train Loss: 2.3885, Train Accuracy: 37.68%
#     Worker 1: Train Loss: 2.4682, Train Accuracy: 35.92%
#     Worker 2: Train Loss: 2.3578, Train Accuracy: 38.74%
#     Worker 3: Train Loss: 2.3616, Train Accuracy: 37.58%
#     Worker 4: Train Loss: 2.3248, Train Accuracy: 38.70%
#     Worker 5: Train Loss: 2.4111, Train Accuracy: 37.84%
#     Worker 6: Train Loss: 2.3664, Train Accuracy: 39.20%
#     Worker 7: Train Loss: 2.4387, Train Accuracy: 35.87%
# Epoch 58/150: Test Loss: 2.2265, Test Accuracy: 43.30%
#     Worker 0: Train Loss: 2.3712, Train Accuracy: 38.03%
#     Worker 1: Train Loss: 2.3859, Train Accuracy: 37.65%
#     Worker 2: Train Loss: 2.4512, Train Accuracy: 36.61%
#     Worker 3: Train Loss: 2.4325, Train Accuracy: 37.62%
#     Worker 4: Train Loss: 2.4143, Train Accuracy: 36.90%
#     Worker 5: Train Loss: 2.3568, Train Accuracy: 38.88%
#     Worker 6: Train Loss: 2.3448, Train Accuracy: 38.27%
#     Worker 7: Train Loss: 2.3944, Train Accuracy: 37.78%
# Epoch 59/150: Test Loss: 2.2173, Test Accuracy: 43.36%
#     Worker 0: Train Loss: 2.3507, Train Accuracy: 39.01%
#     Worker 1: Train Loss: 2.3265, Train Accuracy: 37.98%
#     Worker 2: Train Loss: 2.3791, Train Accuracy: 38.66%
#     Worker 3: Train Loss: 2.3526, Train Accuracy: 38.77%
#     Worker 4: Train Loss: 2.3082, Train Accuracy: 39.84%
#     Worker 5: Train Loss: 2.4405, Train Accuracy: 37.04%
#     Worker 6: Train Loss: 2.3412, Train Accuracy: 39.10%
#     Worker 7: Train Loss: 2.3090, Train Accuracy: 39.01%
# Epoch 60/150: Test Loss: 2.1862, Test Accuracy: 44.30%
#     Worker 0: Train Loss: 2.2967, Train Accuracy: 39.17%
#     Worker 1: Train Loss: 2.4621, Train Accuracy: 36.51%
#     Worker 2: Train Loss: 2.2935, Train Accuracy: 39.65%
#     Worker 3: Train Loss: 2.3846, Train Accuracy: 36.96%
#     Worker 4: Train Loss: 2.2745, Train Accuracy: 40.21%
#     Worker 5: Train Loss: 2.2925, Train Accuracy: 39.55%
#     Worker 6: Train Loss: 2.3119, Train Accuracy: 39.07%
#     Worker 7: Train Loss: 2.3604, Train Accuracy: 38.83%
# Epoch 61/150: Test Loss: 2.1936, Test Accuracy: 43.68%
#     Worker 0: Train Loss: 2.3829, Train Accuracy: 37.58%
#     Worker 1: Train Loss: 2.2895, Train Accuracy: 39.23%
#     Worker 2: Train Loss: 2.3526, Train Accuracy: 38.66%
#     Worker 3: Train Loss: 2.3317, Train Accuracy: 38.93%
#     Worker 4: Train Loss: 2.3013, Train Accuracy: 39.12%
#     Worker 5: Train Loss: 2.3167, Train Accuracy: 38.46%
#     Worker 6: Train Loss: 2.2875, Train Accuracy: 40.02%
#     Worker 7: Train Loss: 2.4007, Train Accuracy: 37.34%
# Epoch 62/150: Test Loss: 2.1898, Test Accuracy: 44.00%
#     Worker 0: Train Loss: 2.2503, Train Accuracy: 39.97%
#     Worker 1: Train Loss: 2.2355, Train Accuracy: 40.32%
#     Worker 2: Train Loss: 2.2821, Train Accuracy: 39.60%
#     Worker 3: Train Loss: 2.3312, Train Accuracy: 39.87%
#     Worker 4: Train Loss: 2.3028, Train Accuracy: 39.86%
#     Worker 5: Train Loss: 2.2558, Train Accuracy: 40.78%
#     Worker 6: Train Loss: 2.2228, Train Accuracy: 41.12%
#     Worker 7: Train Loss: 2.4906, Train Accuracy: 35.41%
# Epoch 63/150: Test Loss: 2.1791, Test Accuracy: 43.85%
#     Worker 0: Train Loss: 2.3696, Train Accuracy: 38.46%
#     Worker 1: Train Loss: 2.2977, Train Accuracy: 39.44%
#     Worker 2: Train Loss: 2.2958, Train Accuracy: 39.81%
#     Worker 3: Train Loss: 2.3005, Train Accuracy: 38.98%
#     Worker 4: Train Loss: 2.2204, Train Accuracy: 40.26%
#     Worker 5: Train Loss: 2.3639, Train Accuracy: 38.66%
#     Worker 6: Train Loss: 2.2799, Train Accuracy: 40.00%
#     Worker 7: Train Loss: 2.3106, Train Accuracy: 39.30%
# Epoch 64/150: Test Loss: 2.1528, Test Accuracy: 45.13%
#     Worker 0: Train Loss: 2.2601, Train Accuracy: 40.27%
#     Worker 1: Train Loss: 2.2673, Train Accuracy: 40.78%
#     Worker 2: Train Loss: 2.2729, Train Accuracy: 41.14%
#     Worker 3: Train Loss: 2.3521, Train Accuracy: 38.74%
#     Worker 4: Train Loss: 2.2885, Train Accuracy: 39.22%
#     Worker 5: Train Loss: 2.2235, Train Accuracy: 41.36%
#     Worker 6: Train Loss: 2.2333, Train Accuracy: 41.14%
#     Worker 7: Train Loss: 2.3349, Train Accuracy: 38.88%
# Epoch 65/150: Test Loss: 2.1626, Test Accuracy: 44.58%
#     Worker 0: Train Loss: 2.3394, Train Accuracy: 38.48%
#     Worker 1: Train Loss: 2.2656, Train Accuracy: 39.68%
#     Worker 2: Train Loss: 2.1640, Train Accuracy: 42.51%
#     Worker 3: Train Loss: 2.3305, Train Accuracy: 39.36%
#     Worker 4: Train Loss: 2.2761, Train Accuracy: 40.82%
#     Worker 5: Train Loss: 2.4136, Train Accuracy: 37.31%
#     Worker 6: Train Loss: 2.2309, Train Accuracy: 41.28%
#     Worker 7: Train Loss: 2.2168, Train Accuracy: 41.74%
# Epoch 66/150: Test Loss: 2.1598, Test Accuracy: 45.38%
#     Worker 0: Train Loss: 2.3381, Train Accuracy: 39.20%
#     Worker 1: Train Loss: 2.3376, Train Accuracy: 38.50%
#     Worker 2: Train Loss: 2.2760, Train Accuracy: 40.26%
#     Worker 3: Train Loss: 2.3047, Train Accuracy: 38.69%
#     Worker 4: Train Loss: 2.1601, Train Accuracy: 42.80%
#     Worker 5: Train Loss: 2.2731, Train Accuracy: 40.32%
#     Worker 6: Train Loss: 2.2189, Train Accuracy: 41.74%
#     Worker 7: Train Loss: 2.2861, Train Accuracy: 40.03%
# Epoch 67/150: Test Loss: 2.1283, Test Accuracy: 45.26%
#     Worker 0: Train Loss: 2.1768, Train Accuracy: 42.21%
#     Worker 1: Train Loss: 2.2201, Train Accuracy: 40.58%
#     Worker 2: Train Loss: 2.1886, Train Accuracy: 43.22%
#     Worker 3: Train Loss: 2.2163, Train Accuracy: 41.07%
#     Worker 4: Train Loss: 2.1301, Train Accuracy: 43.28%
#     Worker 5: Train Loss: 2.2773, Train Accuracy: 40.29%
#     Worker 6: Train Loss: 2.3823, Train Accuracy: 38.03%
#     Worker 7: Train Loss: 2.2904, Train Accuracy: 39.52%
# Epoch 68/150: Test Loss: 2.1354, Test Accuracy: 45.26%
#     Worker 0: Train Loss: 2.2481, Train Accuracy: 41.02%
#     Worker 1: Train Loss: 2.2306, Train Accuracy: 40.46%
#     Worker 2: Train Loss: 2.3448, Train Accuracy: 39.10%
#     Worker 3: Train Loss: 2.2404, Train Accuracy: 40.72%
#     Worker 4: Train Loss: 2.2729, Train Accuracy: 39.68%
#     Worker 5: Train Loss: 2.1985, Train Accuracy: 43.01%
#     Worker 6: Train Loss: 2.3372, Train Accuracy: 39.34%
#     Worker 7: Train Loss: 2.2577, Train Accuracy: 40.56%
# Epoch 69/150: Test Loss: 2.1291, Test Accuracy: 45.46%
#     Worker 0: Train Loss: 2.2382, Train Accuracy: 41.33%
#     Worker 1: Train Loss: 2.1620, Train Accuracy: 42.05%
#     Worker 2: Train Loss: 2.1474, Train Accuracy: 42.96%
#     Worker 3: Train Loss: 2.2044, Train Accuracy: 41.38%
#     Worker 4: Train Loss: 2.1821, Train Accuracy: 41.79%
#     Worker 5: Train Loss: 2.1730, Train Accuracy: 42.54%
#     Worker 6: Train Loss: 2.2240, Train Accuracy: 41.84%
#     Worker 7: Train Loss: 2.2749, Train Accuracy: 40.40%
# Epoch 70/150: Test Loss: 2.1375, Test Accuracy: 45.23%
#     Worker 0: Train Loss: 2.1431, Train Accuracy: 43.10%
#     Worker 1: Train Loss: 2.2032, Train Accuracy: 41.41%
#     Worker 2: Train Loss: 2.1822, Train Accuracy: 42.42%
#     Worker 3: Train Loss: 2.2325, Train Accuracy: 40.78%
#     Worker 4: Train Loss: 2.2138, Train Accuracy: 41.42%
#     Worker 5: Train Loss: 2.3740, Train Accuracy: 39.06%
#     Worker 6: Train Loss: 2.3303, Train Accuracy: 39.34%
#     Worker 7: Train Loss: 2.1842, Train Accuracy: 42.27%
# Epoch 71/150: Test Loss: 2.1210, Test Accuracy: 45.76%
#     Worker 0: Train Loss: 2.1940, Train Accuracy: 41.76%
#     Worker 1: Train Loss: 2.1111, Train Accuracy: 43.26%
#     Worker 2: Train Loss: 2.2142, Train Accuracy: 42.22%
#     Worker 3: Train Loss: 2.2028, Train Accuracy: 41.57%
#     Worker 4: Train Loss: 2.1398, Train Accuracy: 42.74%
#     Worker 5: Train Loss: 2.2432, Train Accuracy: 41.49%
#     Worker 6: Train Loss: 2.2561, Train Accuracy: 40.72%
#     Worker 7: Train Loss: 2.1443, Train Accuracy: 43.20%
# Epoch 72/150: Test Loss: 2.1006, Test Accuracy: 46.14%
#     Worker 0: Train Loss: 2.3537, Train Accuracy: 39.15%
#     Worker 1: Train Loss: 2.2646, Train Accuracy: 40.83%
#     Worker 2: Train Loss: 2.1640, Train Accuracy: 43.42%
#     Worker 3: Train Loss: 2.1742, Train Accuracy: 42.29%
#     Worker 4: Train Loss: 2.1814, Train Accuracy: 42.11%
#     Worker 5: Train Loss: 2.1117, Train Accuracy: 43.33%
#     Worker 6: Train Loss: 2.2514, Train Accuracy: 40.51%
#     Worker 7: Train Loss: 2.1589, Train Accuracy: 42.26%
# Epoch 73/150: Test Loss: 2.0821, Test Accuracy: 46.15%
#     Worker 0: Train Loss: 2.0920, Train Accuracy: 43.60%
#     Worker 1: Train Loss: 2.1587, Train Accuracy: 41.81%
#     Worker 2: Train Loss: 2.0922, Train Accuracy: 44.16%
#     Worker 3: Train Loss: 2.1144, Train Accuracy: 42.70%
#     Worker 4: Train Loss: 2.1367, Train Accuracy: 43.15%
#     Worker 5: Train Loss: 2.1556, Train Accuracy: 42.74%
#     Worker 6: Train Loss: 2.1697, Train Accuracy: 42.30%
#     Worker 7: Train Loss: 2.1879, Train Accuracy: 40.86%
# Epoch 74/150: Test Loss: 2.0783, Test Accuracy: 46.59%
#     Worker 0: Train Loss: 2.0772, Train Accuracy: 44.08%
#     Worker 1: Train Loss: 2.0890, Train Accuracy: 44.13%
#     Worker 2: Train Loss: 2.0652, Train Accuracy: 44.86%
#     Worker 3: Train Loss: 2.1489, Train Accuracy: 42.83%
#     Worker 4: Train Loss: 2.1010, Train Accuracy: 43.62%
#     Worker 5: Train Loss: 2.1550, Train Accuracy: 42.98%
#     Worker 6: Train Loss: 2.2107, Train Accuracy: 41.01%
#     Worker 7: Train Loss: 2.1527, Train Accuracy: 42.18%
# Epoch 75/150: Test Loss: 2.0719, Test Accuracy: 45.81%
#     Worker 0: Train Loss: 2.1185, Train Accuracy: 42.78%
#     Worker 1: Train Loss: 2.1030, Train Accuracy: 43.87%
#     Worker 2: Train Loss: 2.0365, Train Accuracy: 45.46%
#     Worker 3: Train Loss: 2.1665, Train Accuracy: 42.58%
#     Worker 4: Train Loss: 2.0766, Train Accuracy: 43.95%
#     Worker 5: Train Loss: 2.1307, Train Accuracy: 43.22%
#     Worker 6: Train Loss: 2.1600, Train Accuracy: 42.56%
#     Worker 7: Train Loss: 2.1178, Train Accuracy: 43.65%
# Epoch 76/150: Test Loss: 2.0630, Test Accuracy: 47.03%
#     Worker 0: Train Loss: 2.1780, Train Accuracy: 42.53%
#     Worker 1: Train Loss: 2.1019, Train Accuracy: 44.16%
#     Worker 2: Train Loss: 2.0635, Train Accuracy: 44.46%
#     Worker 3: Train Loss: 2.2825, Train Accuracy: 40.70%
#     Worker 4: Train Loss: 2.0296, Train Accuracy: 45.01%
#     Worker 5: Train Loss: 2.0798, Train Accuracy: 44.21%
#     Worker 6: Train Loss: 2.1415, Train Accuracy: 43.66%
#     Worker 7: Train Loss: 2.0227, Train Accuracy: 45.04%
# Epoch 77/150: Test Loss: 2.0510, Test Accuracy: 46.95%
#     Worker 0: Train Loss: 2.0582, Train Accuracy: 44.54%
#     Worker 1: Train Loss: 2.1025, Train Accuracy: 43.68%
#     Worker 2: Train Loss: 2.1290, Train Accuracy: 43.86%
#     Worker 3: Train Loss: 2.0968, Train Accuracy: 43.68%
#     Worker 4: Train Loss: 2.1094, Train Accuracy: 43.92%
#     Worker 5: Train Loss: 2.1292, Train Accuracy: 44.02%
#     Worker 6: Train Loss: 2.1048, Train Accuracy: 43.68%
#     Worker 7: Train Loss: 2.0389, Train Accuracy: 45.33%
# Epoch 78/150: Test Loss: 2.0518, Test Accuracy: 46.86%
#     Worker 0: Train Loss: 2.0727, Train Accuracy: 44.29%
#     Worker 1: Train Loss: 2.0216, Train Accuracy: 45.60%
#     Worker 2: Train Loss: 2.0486, Train Accuracy: 45.82%
#     Worker 3: Train Loss: 2.0751, Train Accuracy: 43.52%
#     Worker 4: Train Loss: 2.1317, Train Accuracy: 43.36%
#     Worker 5: Train Loss: 2.1282, Train Accuracy: 44.18%
#     Worker 6: Train Loss: 2.0803, Train Accuracy: 43.98%
#     Worker 7: Train Loss: 2.0458, Train Accuracy: 44.78%
# Epoch 79/150: Test Loss: 2.0376, Test Accuracy: 47.08%
#     Worker 0: Train Loss: 2.0334, Train Accuracy: 44.72%
#     Worker 1: Train Loss: 2.0171, Train Accuracy: 45.87%
#     Worker 2: Train Loss: 2.0616, Train Accuracy: 44.78%
#     Worker 3: Train Loss: 2.1286, Train Accuracy: 43.15%
#     Worker 4: Train Loss: 2.0219, Train Accuracy: 45.15%
#     Worker 5: Train Loss: 2.0815, Train Accuracy: 44.40%
#     Worker 6: Train Loss: 2.0459, Train Accuracy: 45.42%
#     Worker 7: Train Loss: 2.0871, Train Accuracy: 44.18%
# Epoch 80/150: Test Loss: 2.0281, Test Accuracy: 47.34%
#     Worker 0: Train Loss: 2.0360, Train Accuracy: 46.34%
#     Worker 1: Train Loss: 1.9934, Train Accuracy: 46.40%
#     Worker 2: Train Loss: 2.1390, Train Accuracy: 44.13%
#     Worker 3: Train Loss: 2.1049, Train Accuracy: 43.54%
#     Worker 4: Train Loss: 2.0216, Train Accuracy: 46.02%
#     Worker 5: Train Loss: 2.0859, Train Accuracy: 44.70%
#     Worker 6: Train Loss: 2.0580, Train Accuracy: 44.72%
#     Worker 7: Train Loss: 1.9595, Train Accuracy: 46.51%
# Epoch 81/150: Test Loss: 2.0194, Test Accuracy: 47.39%
#     Worker 0: Train Loss: 2.0074, Train Accuracy: 45.95%
#     Worker 1: Train Loss: 2.0372, Train Accuracy: 45.44%
#     Worker 2: Train Loss: 1.9466, Train Accuracy: 46.93%
#     Worker 3: Train Loss: 2.0147, Train Accuracy: 46.72%
#     Worker 4: Train Loss: 1.9952, Train Accuracy: 46.42%
#     Worker 5: Train Loss: 1.9744, Train Accuracy: 46.74%
#     Worker 6: Train Loss: 2.0576, Train Accuracy: 44.80%
#     Worker 7: Train Loss: 2.0408, Train Accuracy: 45.39%
# Epoch 82/150: Test Loss: 2.0217, Test Accuracy: 47.66%
#     Worker 0: Train Loss: 1.9788, Train Accuracy: 45.94%
#     Worker 1: Train Loss: 1.9649, Train Accuracy: 46.66%
#     Worker 2: Train Loss: 2.0752, Train Accuracy: 44.98%
#     Worker 3: Train Loss: 2.0215, Train Accuracy: 45.89%
#     Worker 4: Train Loss: 2.0143, Train Accuracy: 45.58%
#     Worker 5: Train Loss: 2.0867, Train Accuracy: 44.77%
#     Worker 6: Train Loss: 2.0111, Train Accuracy: 45.84%
#     Worker 7: Train Loss: 2.0966, Train Accuracy: 43.38%
# Epoch 83/150: Test Loss: 2.0239, Test Accuracy: 47.90%
#     Worker 0: Train Loss: 2.0055, Train Accuracy: 46.13%
#     Worker 1: Train Loss: 2.0040, Train Accuracy: 46.16%
#     Worker 2: Train Loss: 2.0736, Train Accuracy: 44.18%
#     Worker 3: Train Loss: 2.0696, Train Accuracy: 45.28%
#     Worker 4: Train Loss: 1.9763, Train Accuracy: 46.37%
#     Worker 5: Train Loss: 1.9657, Train Accuracy: 46.61%
#     Worker 6: Train Loss: 1.9597, Train Accuracy: 47.06%
#     Worker 7: Train Loss: 1.9934, Train Accuracy: 45.87%
# Epoch 84/150: Test Loss: 2.0256, Test Accuracy: 47.92%
#     Worker 0: Train Loss: 2.0256, Train Accuracy: 45.10%
#     Worker 1: Train Loss: 2.0013, Train Accuracy: 46.61%
#     Worker 2: Train Loss: 1.9696, Train Accuracy: 47.26%
#     Worker 3: Train Loss: 2.0157, Train Accuracy: 45.66%
#     Worker 4: Train Loss: 1.9781, Train Accuracy: 46.70%
#     Worker 5: Train Loss: 2.0664, Train Accuracy: 45.10%
#     Worker 6: Train Loss: 1.9819, Train Accuracy: 47.38%
#     Worker 7: Train Loss: 1.9804, Train Accuracy: 46.74%
# Epoch 85/150: Test Loss: 2.0135, Test Accuracy: 47.81%
#     Worker 0: Train Loss: 1.9305, Train Accuracy: 47.39%
#     Worker 1: Train Loss: 1.9973, Train Accuracy: 46.14%
#     Worker 2: Train Loss: 2.0212, Train Accuracy: 46.45%
#     Worker 3: Train Loss: 2.0378, Train Accuracy: 46.02%
#     Worker 4: Train Loss: 1.9211, Train Accuracy: 47.55%
#     Worker 5: Train Loss: 1.8721, Train Accuracy: 48.62%
#     Worker 6: Train Loss: 2.0267, Train Accuracy: 45.36%
#     Worker 7: Train Loss: 1.9867, Train Accuracy: 46.53%
# Epoch 86/150: Test Loss: 2.0111, Test Accuracy: 47.69%
#     Worker 0: Train Loss: 2.0400, Train Accuracy: 44.82%
#     Worker 1: Train Loss: 1.9017, Train Accuracy: 48.74%
#     Worker 2: Train Loss: 2.0597, Train Accuracy: 45.26%
#     Worker 3: Train Loss: 2.0910, Train Accuracy: 44.96%
#     Worker 4: Train Loss: 1.9924, Train Accuracy: 46.18%
#     Worker 5: Train Loss: 2.0002, Train Accuracy: 46.26%
#     Worker 6: Train Loss: 1.9246, Train Accuracy: 47.02%
#     Worker 7: Train Loss: 1.9285, Train Accuracy: 47.06%
# Epoch 87/150: Test Loss: 2.0021, Test Accuracy: 48.04%
#     Worker 0: Train Loss: 2.0370, Train Accuracy: 45.33%
#     Worker 1: Train Loss: 1.9473, Train Accuracy: 47.09%
#     Worker 2: Train Loss: 1.9682, Train Accuracy: 46.93%
#     Worker 3: Train Loss: 1.9320, Train Accuracy: 47.57%
#     Worker 4: Train Loss: 2.0516, Train Accuracy: 45.34%
#     Worker 5: Train Loss: 1.9551, Train Accuracy: 47.79%
#     Worker 6: Train Loss: 1.9737, Train Accuracy: 46.93%
#     Worker 7: Train Loss: 2.0505, Train Accuracy: 44.90%
# Epoch 88/150: Test Loss: 1.9885, Test Accuracy: 48.52%
#     Worker 0: Train Loss: 1.9441, Train Accuracy: 47.34%
#     Worker 1: Train Loss: 1.8588, Train Accuracy: 49.39%
#     Worker 2: Train Loss: 1.9727, Train Accuracy: 47.10%
#     Worker 3: Train Loss: 2.0069, Train Accuracy: 45.46%
#     Worker 4: Train Loss: 1.9103, Train Accuracy: 47.79%
#     Worker 5: Train Loss: 2.0333, Train Accuracy: 46.38%
#     Worker 6: Train Loss: 1.9952, Train Accuracy: 46.29%
#     Worker 7: Train Loss: 1.9676, Train Accuracy: 46.98%
# Epoch 89/150: Test Loss: 1.9927, Test Accuracy: 48.30%
#     Worker 0: Train Loss: 1.9928, Train Accuracy: 45.97%
#     Worker 1: Train Loss: 1.8915, Train Accuracy: 48.46%
#     Worker 2: Train Loss: 1.9842, Train Accuracy: 46.43%
#     Worker 3: Train Loss: 1.9329, Train Accuracy: 47.70%
#     Worker 4: Train Loss: 1.9386, Train Accuracy: 47.36%
#     Worker 5: Train Loss: 1.9247, Train Accuracy: 47.36%
#     Worker 6: Train Loss: 1.8940, Train Accuracy: 48.46%
#     Worker 7: Train Loss: 1.9997, Train Accuracy: 45.81%
# Epoch 90/150: Test Loss: 1.9858, Test Accuracy: 48.29%
#     Worker 0: Train Loss: 1.9448, Train Accuracy: 47.10%
#     Worker 1: Train Loss: 1.9370, Train Accuracy: 47.55%
#     Worker 2: Train Loss: 2.0151, Train Accuracy: 45.87%
#     Worker 3: Train Loss: 1.9476, Train Accuracy: 46.67%
#     Worker 4: Train Loss: 1.8907, Train Accuracy: 48.34%
#     Worker 5: Train Loss: 1.9187, Train Accuracy: 48.22%
#     Worker 6: Train Loss: 1.9031, Train Accuracy: 48.70%
#     Worker 7: Train Loss: 1.9812, Train Accuracy: 46.67%
# Epoch 91/150: Test Loss: 1.9945, Test Accuracy: 48.24%
#     Worker 0: Train Loss: 1.9152, Train Accuracy: 47.78%
#     Worker 1: Train Loss: 1.9599, Train Accuracy: 47.07%
#     Worker 2: Train Loss: 1.8561, Train Accuracy: 49.26%
#     Worker 3: Train Loss: 2.0448, Train Accuracy: 45.23%
#     Worker 4: Train Loss: 1.8682, Train Accuracy: 48.94%
#     Worker 5: Train Loss: 1.9379, Train Accuracy: 47.79%
#     Worker 6: Train Loss: 1.9371, Train Accuracy: 46.82%
#     Worker 7: Train Loss: 1.9550, Train Accuracy: 47.04%
# Epoch 92/150: Test Loss: 1.9673, Test Accuracy: 48.89%
#     Worker 0: Train Loss: 1.9068, Train Accuracy: 48.72%
#     Worker 1: Train Loss: 1.8228, Train Accuracy: 49.73%
#     Worker 2: Train Loss: 1.8817, Train Accuracy: 49.02%
#     Worker 3: Train Loss: 1.8896, Train Accuracy: 48.45%
#     Worker 4: Train Loss: 1.9209, Train Accuracy: 47.79%
#     Worker 5: Train Loss: 1.9348, Train Accuracy: 47.26%
#     Worker 6: Train Loss: 1.8144, Train Accuracy: 50.08%
#     Worker 7: Train Loss: 1.8842, Train Accuracy: 49.62%
# Epoch 93/150: Test Loss: 1.9571, Test Accuracy: 48.97%
# ...
#     Worker 6: Train Loss: 1.5421, Train Accuracy: 56.80%
#     Worker 7: Train Loss: 1.5118, Train Accuracy: 57.28%
# Epoch 120/150: Test Loss: 1.8869, Test Accuracy: 51.38%
#     Worker 0: Train Loss: 1.5843, Train Accuracy: 56.16%
#     Worker 1: Train Loss: 1.5401, Train Accuracy: 57.04%
#     Worker 2: Train Loss: 1.5419, Train Accuracy: 57.10%
#     Worker 3: Train Loss: 1.5647, Train Accuracy: 55.70%
#     Worker 4: Train Loss: 1.4729, Train Accuracy: 57.87%
#     Worker 5: Train Loss: 1.4847, Train Accuracy: 58.13%
#     Worker 6: Train Loss: 1.5601, Train Accuracy: 56.29%
#     Worker 7: Train Loss: 1.4827, Train Accuracy: 57.86%
# Epoch 121/150: Test Loss: 1.8888, Test Accuracy: 51.18%
#     Worker 0: Train Loss: 1.5403, Train Accuracy: 56.43%
#     Worker 1: Train Loss: 1.4442, Train Accuracy: 59.02%
#     Worker 2: Train Loss: 1.5283, Train Accuracy: 57.49%
#     Worker 3: Train Loss: 1.4872, Train Accuracy: 57.84%
#     Worker 4: Train Loss: 1.4730, Train Accuracy: 58.24%
#     Worker 5: Train Loss: 1.5502, Train Accuracy: 56.11%
#     Worker 6: Train Loss: 1.4933, Train Accuracy: 58.19%
#     Worker 7: Train Loss: 1.5464, Train Accuracy: 55.97%
# Epoch 122/150: Test Loss: 1.8799, Test Accuracy: 51.44%
#     Worker 0: Train Loss: 1.4868, Train Accuracy: 57.57%
#     Worker 1: Train Loss: 1.4829, Train Accuracy: 58.62%
#     Worker 2: Train Loss: 1.4847, Train Accuracy: 58.42%
#     Worker 3: Train Loss: 1.4891, Train Accuracy: 57.86%
#     Worker 4: Train Loss: 1.4664, Train Accuracy: 58.74%
#     Worker 5: Train Loss: 1.4707, Train Accuracy: 58.29%
#     Worker 6: Train Loss: 1.5262, Train Accuracy: 57.71%
#     Worker 7: Train Loss: 1.5159, Train Accuracy: 57.26%
# Epoch 123/150: Test Loss: 1.8866, Test Accuracy: 51.64%
#     Worker 0: Train Loss: 1.5341, Train Accuracy: 57.14%
#     Worker 1: Train Loss: 1.4929, Train Accuracy: 58.46%
#     Worker 2: Train Loss: 1.4574, Train Accuracy: 59.17%
#     Worker 3: Train Loss: 1.4702, Train Accuracy: 58.61%
#     Worker 4: Train Loss: 1.4322, Train Accuracy: 59.07%
#     Worker 5: Train Loss: 1.4725, Train Accuracy: 58.56%
#     Worker 6: Train Loss: 1.4515, Train Accuracy: 59.28%
#     Worker 7: Train Loss: 1.4673, Train Accuracy: 58.21%
# Epoch 124/150: Test Loss: 1.8852, Test Accuracy: 51.59%
#     Worker 0: Train Loss: 1.6390, Train Accuracy: 55.26%
#     Worker 1: Train Loss: 1.4258, Train Accuracy: 59.94%
#     Worker 2: Train Loss: 1.4626, Train Accuracy: 58.99%
#     Worker 3: Train Loss: 1.5254, Train Accuracy: 57.12%
#     Worker 4: Train Loss: 1.5009, Train Accuracy: 58.21%
#     Worker 5: Train Loss: 1.5192, Train Accuracy: 57.89%
#     Worker 6: Train Loss: 1.5578, Train Accuracy: 56.18%
#     Worker 7: Train Loss: 1.5031, Train Accuracy: 57.49%
# Epoch 125/150: Test Loss: 1.8813, Test Accuracy: 51.56%
#     Worker 0: Train Loss: 1.5011, Train Accuracy: 57.36%
#     Worker 1: Train Loss: 1.4727, Train Accuracy: 58.37%
#     Worker 2: Train Loss: 1.4507, Train Accuracy: 59.30%
#     Worker 3: Train Loss: 1.5460, Train Accuracy: 56.34%
#     Worker 4: Train Loss: 1.4789, Train Accuracy: 58.59%
#     Worker 5: Train Loss: 1.4125, Train Accuracy: 60.13%
#     Worker 6: Train Loss: 1.5106, Train Accuracy: 58.00%
#     Worker 7: Train Loss: 1.4362, Train Accuracy: 59.39%
# Epoch 126/150: Test Loss: 1.8879, Test Accuracy: 51.58%
#     Worker 0: Train Loss: 1.4082, Train Accuracy: 59.49%
#     Worker 1: Train Loss: 1.4019, Train Accuracy: 60.91%
#     Worker 2: Train Loss: 1.4156, Train Accuracy: 60.05%
#     Worker 3: Train Loss: 1.4788, Train Accuracy: 58.08%
#     Worker 4: Train Loss: 1.4308, Train Accuracy: 59.39%
#     Worker 5: Train Loss: 1.3947, Train Accuracy: 60.32%
#     Worker 6: Train Loss: 1.4584, Train Accuracy: 59.15%
#     Worker 7: Train Loss: 1.4361, Train Accuracy: 59.63%
# Epoch 127/150: Test Loss: 1.8844, Test Accuracy: 52.07%
#     Worker 0: Train Loss: 1.4273, Train Accuracy: 59.38%
#     Worker 1: Train Loss: 1.4573, Train Accuracy: 58.99%
#     Worker 2: Train Loss: 1.4393, Train Accuracy: 59.58%
#     Worker 3: Train Loss: 1.4500, Train Accuracy: 58.74%
#     Worker 4: Train Loss: 1.4034, Train Accuracy: 60.26%
#     Worker 5: Train Loss: 1.4576, Train Accuracy: 58.93%
#     Worker 6: Train Loss: 1.4197, Train Accuracy: 59.98%
#     Worker 7: Train Loss: 1.4169, Train Accuracy: 59.55%
# Epoch 128/150: Test Loss: 1.8758, Test Accuracy: 52.15%
#     Worker 0: Train Loss: 1.3986, Train Accuracy: 60.16%
#     Worker 1: Train Loss: 1.3960, Train Accuracy: 60.77%
#     Worker 2: Train Loss: 1.3748, Train Accuracy: 61.31%
#     Worker 3: Train Loss: 1.4488, Train Accuracy: 58.21%
#     Worker 4: Train Loss: 1.3910, Train Accuracy: 60.59%
#     Worker 5: Train Loss: 1.4336, Train Accuracy: 59.49%
#     Worker 6: Train Loss: 1.4379, Train Accuracy: 58.69%
#     Worker 7: Train Loss: 1.4416, Train Accuracy: 59.41%
# Epoch 129/150: Test Loss: 1.8804, Test Accuracy: 51.97%
#     Worker 0: Train Loss: 1.4883, Train Accuracy: 58.19%
#     Worker 1: Train Loss: 1.4069, Train Accuracy: 59.87%
#     Worker 2: Train Loss: 1.3801, Train Accuracy: 61.49%
#     Worker 3: Train Loss: 1.4333, Train Accuracy: 58.80%
#     Worker 4: Train Loss: 1.3951, Train Accuracy: 60.69%
#     Worker 5: Train Loss: 1.4442, Train Accuracy: 60.08%
#     Worker 6: Train Loss: 1.4281, Train Accuracy: 60.38%
#     Worker 7: Train Loss: 1.3869, Train Accuracy: 60.38%
# Epoch 130/150: Test Loss: 1.8875, Test Accuracy: 51.91%
#     Worker 0: Train Loss: 1.3837, Train Accuracy: 60.64%
#     Worker 1: Train Loss: 1.3994, Train Accuracy: 59.71%
#     Worker 2: Train Loss: 1.3682, Train Accuracy: 60.91%
#     Worker 3: Train Loss: 1.4289, Train Accuracy: 59.58%
#     Worker 4: Train Loss: 1.3738, Train Accuracy: 61.28%
#     Worker 5: Train Loss: 1.3641, Train Accuracy: 60.67%
#     Worker 6: Train Loss: 1.4435, Train Accuracy: 59.18%
#     Worker 7: Train Loss: 1.4207, Train Accuracy: 59.63%
# Epoch 131/150: Test Loss: 1.8779, Test Accuracy: 52.21%
#     Worker 0: Train Loss: 1.4131, Train Accuracy: 59.60%
#     Worker 1: Train Loss: 1.4111, Train Accuracy: 59.55%
#     Worker 2: Train Loss: 1.4006, Train Accuracy: 60.88%
#     Worker 3: Train Loss: 1.4349, Train Accuracy: 59.22%
#     Worker 4: Train Loss: 1.3512, Train Accuracy: 61.57%
#     Worker 5: Train Loss: 1.3941, Train Accuracy: 60.64%
#     Worker 6: Train Loss: 1.4180, Train Accuracy: 59.60%
#     Worker 7: Train Loss: 1.3615, Train Accuracy: 61.52%
# Epoch 132/150: Test Loss: 1.8826, Test Accuracy: 52.16%
#     Worker 0: Train Loss: 1.4281, Train Accuracy: 60.72%
#     Worker 1: Train Loss: 1.3517, Train Accuracy: 61.92%
#     Worker 2: Train Loss: 1.3326, Train Accuracy: 61.79%
#     Worker 3: Train Loss: 1.4002, Train Accuracy: 60.77%
#     Worker 4: Train Loss: 1.3600, Train Accuracy: 61.07%
#     Worker 5: Train Loss: 1.3356, Train Accuracy: 61.78%
#     Worker 6: Train Loss: 1.3907, Train Accuracy: 60.66%
#     Worker 7: Train Loss: 1.3504, Train Accuracy: 61.86%
# Epoch 133/150: Test Loss: 1.8811, Test Accuracy: 52.07%
#     Worker 0: Train Loss: 1.3477, Train Accuracy: 61.92%
#     Worker 1: Train Loss: 1.3650, Train Accuracy: 61.36%
#     Worker 2: Train Loss: 1.3160, Train Accuracy: 63.15%
#     Worker 3: Train Loss: 1.3925, Train Accuracy: 60.13%
#     Worker 4: Train Loss: 1.3474, Train Accuracy: 61.28%
#     Worker 5: Train Loss: 1.3360, Train Accuracy: 61.97%
#     Worker 6: Train Loss: 1.3672, Train Accuracy: 61.54%
#     Worker 7: Train Loss: 1.3393, Train Accuracy: 61.36%
# Epoch 134/150: Test Loss: 1.8811, Test Accuracy: 52.14%
#     Worker 0: Train Loss: 1.3636, Train Accuracy: 61.30%
#     Worker 1: Train Loss: 1.3525, Train Accuracy: 61.28%
#     Worker 2: Train Loss: 1.2981, Train Accuracy: 62.98%
#     Worker 3: Train Loss: 1.3494, Train Accuracy: 61.63%
#     Worker 4: Train Loss: 1.2921, Train Accuracy: 63.09%
#     Worker 5: Train Loss: 1.3175, Train Accuracy: 62.78%
#     Worker 6: Train Loss: 1.3189, Train Accuracy: 62.08%
#     Worker 7: Train Loss: 1.2985, Train Accuracy: 62.16%
# Epoch 135/150: Test Loss: 1.8789, Test Accuracy: 51.93%
#     Worker 0: Train Loss: 1.3538, Train Accuracy: 61.78%
#     Worker 1: Train Loss: 1.3689, Train Accuracy: 60.99%
#     Worker 2: Train Loss: 1.3413, Train Accuracy: 62.37%
#     Worker 3: Train Loss: 1.3735, Train Accuracy: 60.74%
#     Worker 4: Train Loss: 1.3000, Train Accuracy: 62.90%
#     Worker 5: Train Loss: 1.3280, Train Accuracy: 62.67%
#     Worker 6: Train Loss: 1.3489, Train Accuracy: 61.68%
#     Worker 7: Train Loss: 1.3162, Train Accuracy: 62.90%
# Epoch 136/150: Test Loss: 1.8871, Test Accuracy: 52.34%
#     Worker 0: Train Loss: 1.3108, Train Accuracy: 62.26%
#     Worker 1: Train Loss: 1.2870, Train Accuracy: 63.87%
#     Worker 2: Train Loss: 1.3033, Train Accuracy: 62.59%
#     Worker 3: Train Loss: 1.3040, Train Accuracy: 63.84%
#     Worker 4: Train Loss: 1.3312, Train Accuracy: 61.34%
#     Worker 5: Train Loss: 1.3246, Train Accuracy: 61.81%
#     Worker 6: Train Loss: 1.3016, Train Accuracy: 62.43%
#     Worker 7: Train Loss: 1.3043, Train Accuracy: 62.78%
# Epoch 137/150: Test Loss: 1.8869, Test Accuracy: 52.10%
#     Worker 0: Train Loss: 1.3336, Train Accuracy: 61.22%
#     Worker 1: Train Loss: 1.2860, Train Accuracy: 62.56%
#     Worker 2: Train Loss: 1.2953, Train Accuracy: 63.58%
#     Worker 3: Train Loss: 1.3076, Train Accuracy: 62.35%
#     Worker 4: Train Loss: 1.3116, Train Accuracy: 62.02%
#     Worker 5: Train Loss: 1.3187, Train Accuracy: 62.35%
#     Worker 6: Train Loss: 1.3163, Train Accuracy: 62.34%
#     Worker 7: Train Loss: 1.3579, Train Accuracy: 60.88%
# Epoch 138/150: Test Loss: 1.8896, Test Accuracy: 52.42%
#     Worker 0: Train Loss: 1.2977, Train Accuracy: 63.54%
#     Worker 1: Train Loss: 1.3116, Train Accuracy: 61.89%
#     Worker 2: Train Loss: 1.2579, Train Accuracy: 64.58%
#     Worker 3: Train Loss: 1.3189, Train Accuracy: 62.34%
#     Worker 4: Train Loss: 1.2575, Train Accuracy: 63.97%
#     Worker 5: Train Loss: 1.2897, Train Accuracy: 63.47%
#     Worker 6: Train Loss: 1.3342, Train Accuracy: 61.63%
#     Worker 7: Train Loss: 1.2700, Train Accuracy: 63.44%
# Epoch 139/150: Test Loss: 1.8856, Test Accuracy: 52.41%
#     Worker 0: Train Loss: 1.2765, Train Accuracy: 63.09%
#     Worker 1: Train Loss: 1.2798, Train Accuracy: 63.68%
#     Worker 2: Train Loss: 1.2473, Train Accuracy: 64.78%
#     Worker 3: Train Loss: 1.2926, Train Accuracy: 62.74%
#     Worker 4: Train Loss: 1.2806, Train Accuracy: 63.28%
#     Worker 5: Train Loss: 1.3000, Train Accuracy: 63.10%
#     Worker 6: Train Loss: 1.2827, Train Accuracy: 62.85%
#     Worker 7: Train Loss: 1.2865, Train Accuracy: 63.01%
# Epoch 140/150: Test Loss: 1.8884, Test Accuracy: 52.34%
#     Worker 0: Train Loss: 1.2722, Train Accuracy: 63.41%
#     Worker 1: Train Loss: 1.2783, Train Accuracy: 63.34%
#     Worker 2: Train Loss: 1.2253, Train Accuracy: 65.04%
#     Worker 3: Train Loss: 1.2794, Train Accuracy: 63.23%
#     Worker 4: Train Loss: 1.2431, Train Accuracy: 63.97%
#     Worker 5: Train Loss: 1.2888, Train Accuracy: 63.04%
#     Worker 6: Train Loss: 1.2530, Train Accuracy: 65.02%
#     Worker 7: Train Loss: 1.2709, Train Accuracy: 63.15%
# Epoch 141/150: Test Loss: 1.8882, Test Accuracy: 52.39%
#     Worker 0: Train Loss: 1.2832, Train Accuracy: 63.06%
#     Worker 1: Train Loss: 1.2513, Train Accuracy: 63.97%
#     Worker 2: Train Loss: 1.2401, Train Accuracy: 64.90%
#     Worker 3: Train Loss: 1.2777, Train Accuracy: 63.39%
#     Worker 4: Train Loss: 1.2445, Train Accuracy: 63.74%
#     Worker 5: Train Loss: 1.2807, Train Accuracy: 63.44%
#     Worker 6: Train Loss: 1.3097, Train Accuracy: 63.10%
#     Worker 7: Train Loss: 1.2417, Train Accuracy: 63.98%
# Epoch 142/150: Test Loss: 1.8886, Test Accuracy: 52.42%
#     Worker 0: Train Loss: 1.2698, Train Accuracy: 63.95%
#     Worker 1: Train Loss: 1.2540, Train Accuracy: 64.14%
#     Worker 2: Train Loss: 1.2325, Train Accuracy: 65.57%
#     Worker 3: Train Loss: 1.2469, Train Accuracy: 64.56%
#     Worker 4: Train Loss: 1.2676, Train Accuracy: 63.31%
#     Worker 5: Train Loss: 1.2823, Train Accuracy: 63.02%
#     Worker 6: Train Loss: 1.2595, Train Accuracy: 63.52%
#     Worker 7: Train Loss: 1.2470, Train Accuracy: 64.54%
# Epoch 143/150: Test Loss: 1.8928, Test Accuracy: 52.23%
#     Worker 0: Train Loss: 1.2782, Train Accuracy: 63.25%
#     Worker 1: Train Loss: 1.2550, Train Accuracy: 63.78%
#     Worker 2: Train Loss: 1.2202, Train Accuracy: 65.09%
#     Worker 3: Train Loss: 1.2491, Train Accuracy: 63.46%
#     Worker 4: Train Loss: 1.2165, Train Accuracy: 65.15%
#     Worker 5: Train Loss: 1.2403, Train Accuracy: 64.58%
#     Worker 6: Train Loss: 1.2522, Train Accuracy: 64.19%
#     Worker 7: Train Loss: 1.2454, Train Accuracy: 64.32%
# Epoch 144/150: Test Loss: 1.8950, Test Accuracy: 52.43%
#     Worker 0: Train Loss: 1.2554, Train Accuracy: 64.16%
#     Worker 1: Train Loss: 1.2370, Train Accuracy: 64.03%
#     Worker 2: Train Loss: 1.2049, Train Accuracy: 65.63%
#     Worker 3: Train Loss: 1.2539, Train Accuracy: 63.70%
#     Worker 4: Train Loss: 1.2221, Train Accuracy: 64.85%
#     Worker 5: Train Loss: 1.2330, Train Accuracy: 63.94%
#     Worker 6: Train Loss: 1.2343, Train Accuracy: 63.78%
#     Worker 7: Train Loss: 1.2521, Train Accuracy: 64.16%
# Epoch 145/150: Test Loss: 1.8937, Test Accuracy: 52.21%
#     Worker 0: Train Loss: 1.2433, Train Accuracy: 64.74%
#     Worker 1: Train Loss: 1.2286, Train Accuracy: 64.46%
#     Worker 2: Train Loss: 1.2250, Train Accuracy: 65.63%
#     Worker 3: Train Loss: 1.2623, Train Accuracy: 64.32%
#     Worker 4: Train Loss: 1.2349, Train Accuracy: 64.64%
#     Worker 5: Train Loss: 1.2328, Train Accuracy: 64.90%
#     Worker 6: Train Loss: 1.2248, Train Accuracy: 65.07%
#     Worker 7: Train Loss: 1.2274, Train Accuracy: 64.10%
# Epoch 146/150: Test Loss: 1.8929, Test Accuracy: 52.38%
#     Worker 0: Train Loss: 1.2338, Train Accuracy: 64.64%
#     Worker 1: Train Loss: 1.2097, Train Accuracy: 65.30%
#     Worker 2: Train Loss: 1.2170, Train Accuracy: 65.22%
#     Worker 3: Train Loss: 1.2288, Train Accuracy: 64.99%
#     Worker 4: Train Loss: 1.2145, Train Accuracy: 64.77%
#     Worker 5: Train Loss: 1.2382, Train Accuracy: 64.90%
#     Worker 6: Train Loss: 1.2401, Train Accuracy: 64.43%
#     Worker 7: Train Loss: 1.2108, Train Accuracy: 65.44%
# Epoch 147/150: Test Loss: 1.8936, Test Accuracy: 52.43%
#     Worker 0: Train Loss: 1.2433, Train Accuracy: 64.45%
#     Worker 1: Train Loss: 1.1958, Train Accuracy: 64.74%
#     Worker 2: Train Loss: 1.1841, Train Accuracy: 66.40%
#     Worker 3: Train Loss: 1.2465, Train Accuracy: 64.30%
#     Worker 4: Train Loss: 1.1963, Train Accuracy: 65.90%
#     Worker 5: Train Loss: 1.2181, Train Accuracy: 65.34%
#     Worker 6: Train Loss: 1.2258, Train Accuracy: 64.74%
#     Worker 7: Train Loss: 1.2241, Train Accuracy: 65.12%
# Epoch 148/150: Test Loss: 1.8941, Test Accuracy: 52.40%
#     Worker 0: Train Loss: 1.2139, Train Accuracy: 65.38%
#     Worker 1: Train Loss: 1.1883, Train Accuracy: 65.44%
#     Worker 2: Train Loss: 1.1834, Train Accuracy: 66.29%
#     Worker 3: Train Loss: 1.2214, Train Accuracy: 65.30%
#     Worker 4: Train Loss: 1.2042, Train Accuracy: 65.49%
#     Worker 5: Train Loss: 1.1910, Train Accuracy: 66.42%
#     Worker 6: Train Loss: 1.2098, Train Accuracy: 65.28%
#     Worker 7: Train Loss: 1.1882, Train Accuracy: 65.89%
# Epoch 149/150: Test Loss: 1.8956, Test Accuracy: 52.37%
#     Worker 0: Train Loss: 1.2115, Train Accuracy: 65.20%
#     Worker 1: Train Loss: 1.2158, Train Accuracy: 64.96%
#     Worker 2: Train Loss: 1.1954, Train Accuracy: 65.90%
#     Worker 3: Train Loss: 1.2247, Train Accuracy: 64.67%
#     Worker 4: Train Loss: 1.1975, Train Accuracy: 64.94%
#     Worker 5: Train Loss: 1.2002, Train Accuracy: 65.98%
#     Worker 6: Train Loss: 1.1966, Train Accuracy: 65.52%
#     Worker 7: Train Loss: 1.1851, Train Accuracy: 66.18%
# Epoch 150/150: Test Loss: 1.8962, Test Accuracy: 52.46%
#     Worker 0: Train Loss: 1.2153, Train Accuracy: 65.25%
#     Worker 1: Train Loss: 1.1924, Train Accuracy: 65.46%
#     Worker 2: Train Loss: 1.1838, Train Accuracy: 66.88%
#     Worker 3: Train Loss: 1.2146, Train Accuracy: 65.42%
#     Worker 4: Train Loss: 1.1800, Train Accuracy: 66.05%
#     Worker 5: Train Loss: 1.1966, Train Accuracy: 65.73%
#     Worker 6: Train Loss: 1.2015, Train Accuracy: 65.18%
#     Worker 7: Train Loss: 1.1946, Train Accuracy: 65.57%
