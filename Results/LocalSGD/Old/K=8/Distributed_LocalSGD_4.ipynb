# %%
# %%writefile localSGD.py

import os
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
num_epochs = 150
base_learning_rate = 1e-2
momentum = 0.9
weight_decay = 4e-4
warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std

class LRScheduler(torch.optim.lr_scheduler._LRScheduler):
    def __init__(self, optimizer, base_lr, K, warmup_epochs, total_epochs, verbose=False):
        """
        Args:
            optimizer: SGD
            base_lr: Base learning rate for the reference batch size.
            K: Number of workers.
            warmup_epochs: Number of warmup epochs.
            total_epochs: Total number of epochs.
            verbose: Whether to print LR updates.
        """
        self.base_lr = base_lr
        self.K = K
        self.scaled_lr = base_lr * K
        self.warmup_epochs = warmup_epochs
        self.total_epochs = total_epochs
        self.verbose = verbose
        super(LRScheduler, self).__init__(optimizer)

    def get_lr(self):
        epoch = self.last_epoch
        if epoch < self.warmup_epochs:
            # Linear warmup scaling
            warmup_factor = (epoch + 1) / self.warmup_epochs
            return [warmup_factor * self.scaled_lr for _ in self.optimizer.param_groups]
        else:
            # polynomially decaying learning rate of ηt = η0×(1−t/T)
            if epoch == self.warmup_epochs:
                print(f"Warmup phase completed at epoch {epoch}. Switching to polynomial decay learning rate.")
            return [self.scaled_lr * ( 1 - ( (epoch - self.warmup_epochs) / (self.total_epochs - self.warmup_epochs))) for _ in self.optimizer.param_groups]


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]

# Batch size
batch_size = shard_size // J

# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)


# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [LRScheduler(
    optimizer = optimizer,
    base_lr = base_learning_rate,
    K = K,
    warmup_epochs = warmup_epochs,
    total_epochs = num_epochs,
    verbose = True) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}")

    # Sequentially train each worker to simulate a distributed environment
    for k in range(K):
        shard_loader = DataLoader(shards[k], batch_size=batch_size, shuffle=True)

        nets[k].train()
        correct_train, total_train, train_loss = 0, 0, 0.0
        for images, labels in shard_loader:
            images, labels = images.to(device), labels.to(device)  # Move to device
            optimizers[k].zero_grad()
            outputs = nets[k](images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizers[k].step()
            # Calculate train loss and accuracy
            train_loss += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            total_train += labels.size(0)
            correct_train += predicted.eq(labels).sum().item()
        # Store train loss and accuracy for this worker
        train_loss /= len(shard_loader.dataset)
        train_losses_per_worker[k].append(train_loss)
        train_accuracy = 100. * correct_train / total_train
        train_accuracies_per_worker[k].append(train_accuracy)

    # Perform model synchronization
    with torch.no_grad():
        global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
        for net in nets:
            for global_param, local_param in zip(global_parameters, net.parameters()):
                global_param += local_param
        for global_param in global_parameters:
            global_param /= K
        # Update each worker model with the global parameters
        for net in nets:
            for local_param, global_param in zip(net.parameters(), global_parameters):
                local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        scheduler.step()

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 8 --j 4
# Out:
# Training with K=8, J=4
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:14<00:00, 11.9MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.08000
# Epoch 1/150: Test Loss: 4.6058, Test Accuracy: 1.21%
#     Worker 0: Train Loss: 4.6067, Train Accuracy: 1.28%
#     Worker 1: Train Loss: 4.6055, Train Accuracy: 1.15%
#     Worker 2: Train Loss: 4.6059, Train Accuracy: 1.23%
#     Worker 3: Train Loss: 4.6060, Train Accuracy: 1.12%
#     Worker 4: Train Loss: 4.6054, Train Accuracy: 1.39%
#     Worker 5: Train Loss: 4.6050, Train Accuracy: 1.47%
#     Worker 6: Train Loss: 4.6063, Train Accuracy: 1.30%
#     Worker 7: Train Loss: 4.6063, Train Accuracy: 1.15%
# Epoch 2/150: Test Loss: 4.6043, Test Accuracy: 1.23%
#     Worker 0: Train Loss: 4.6059, Train Accuracy: 1.22%
#     Worker 1: Train Loss: 4.6051, Train Accuracy: 0.91%
#     Worker 2: Train Loss: 4.6053, Train Accuracy: 1.01%
#     Worker 3: Train Loss: 4.6051, Train Accuracy: 1.22%
#     Worker 4: Train Loss: 4.6055, Train Accuracy: 1.30%
#     Worker 5: Train Loss: 4.6042, Train Accuracy: 1.23%
#     Worker 6: Train Loss: 4.6057, Train Accuracy: 1.06%
#     Worker 7: Train Loss: 4.6056, Train Accuracy: 0.99%
# Epoch 3/150: Test Loss: 4.6032, Test Accuracy: 1.08%
#     Worker 0: Train Loss: 4.6049, Train Accuracy: 1.06%
#     Worker 1: Train Loss: 4.6048, Train Accuracy: 1.10%
#     Worker 2: Train Loss: 4.6044, Train Accuracy: 1.01%
#     Worker 3: Train Loss: 4.6044, Train Accuracy: 1.10%
#     Worker 4: Train Loss: 4.6046, Train Accuracy: 1.14%
#     Worker 5: Train Loss: 4.6031, Train Accuracy: 1.26%
#     Worker 6: Train Loss: 4.6058, Train Accuracy: 1.04%
#     Worker 7: Train Loss: 4.6038, Train Accuracy: 1.10%
# Epoch 4/150: Test Loss: 4.6024, Test Accuracy: 0.99%
#     Worker 0: Train Loss: 4.6045, Train Accuracy: 1.07%
#     Worker 1: Train Loss: 4.6037, Train Accuracy: 1.17%
#     Worker 2: Train Loss: 4.6050, Train Accuracy: 0.85%
#     Worker 3: Train Loss: 4.6039, Train Accuracy: 1.41%
#     Worker 4: Train Loss: 4.6035, Train Accuracy: 1.04%
#     Worker 5: Train Loss: 4.6019, Train Accuracy: 1.01%
#     Worker 6: Train Loss: 4.6049, Train Accuracy: 0.99%
#     Worker 7: Train Loss: 4.6045, Train Accuracy: 1.04%
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Epoch 5/150: Test Loss: 4.6005, Test Accuracy: 1.71%
#     Worker 0: Train Loss: 4.6048, Train Accuracy: 1.41%
#     Worker 1: Train Loss: 4.6049, Train Accuracy: 1.09%
#     Worker 2: Train Loss: 4.6237, Train Accuracy: 1.09%
#     Worker 3: Train Loss: 4.6032, Train Accuracy: 1.33%
#     Worker 4: Train Loss: 4.6033, Train Accuracy: 0.83%
#     Worker 5: Train Loss: 4.6012, Train Accuracy: 1.23%
#     Worker 6: Train Loss: 4.6038, Train Accuracy: 0.93%
#     Worker 7: Train Loss: 4.6041, Train Accuracy: 1.17%
# Epoch 6/150: Test Loss: 4.5968, Test Accuracy: 1.32%
#     Worker 0: Train Loss: 4.6008, Train Accuracy: 1.54%
#     Worker 1: Train Loss: 4.6006, Train Accuracy: 1.50%
#     Worker 2: Train Loss: 4.6017, Train Accuracy: 1.46%
#     Worker 3: Train Loss: 4.5984, Train Accuracy: 1.60%
#     Worker 4: Train Loss: 4.6023, Train Accuracy: 1.02%
#     Worker 5: Train Loss: 4.6016, Train Accuracy: 1.34%
#     Worker 6: Train Loss: 4.6034, Train Accuracy: 1.15%
#     Worker 7: Train Loss: 4.5992, Train Accuracy: 1.66%
# Epoch 7/150: Test Loss: 4.5918, Test Accuracy: 1.47%
#     Worker 0: Train Loss: 4.5953, Train Accuracy: 1.44%
#     Worker 1: Train Loss: 4.5967, Train Accuracy: 1.41%
#     Worker 2: Train Loss: 4.5963, Train Accuracy: 1.25%
#     Worker 3: Train Loss: 4.6463, Train Accuracy: 1.09%
#     Worker 4: Train Loss: 4.5987, Train Accuracy: 1.30%
#     Worker 5: Train Loss: 4.5970, Train Accuracy: 1.15%
#     Worker 6: Train Loss: 4.6014, Train Accuracy: 0.99%
#     Worker 7: Train Loss: 4.5950, Train Accuracy: 1.57%
# Epoch 8/150: Test Loss: 4.5858, Test Accuracy: 1.34%
#     Worker 0: Train Loss: 4.5884, Train Accuracy: 1.01%
#     Worker 1: Train Loss: 4.5907, Train Accuracy: 1.47%
#     Worker 2: Train Loss: 4.5998, Train Accuracy: 1.04%
#     Worker 3: Train Loss: 4.5975, Train Accuracy: 1.02%
#     Worker 4: Train Loss: 4.5921, Train Accuracy: 1.73%
#     Worker 5: Train Loss: 4.5915, Train Accuracy: 1.33%
#     Worker 6: Train Loss: 4.5946, Train Accuracy: 1.09%
#     Worker 7: Train Loss: 4.5930, Train Accuracy: 1.26%
# Epoch 9/150: Test Loss: 4.5808, Test Accuracy: 1.11%
#     Worker 0: Train Loss: 4.5888, Train Accuracy: 0.99%
#     Worker 1: Train Loss: 4.5833, Train Accuracy: 1.47%
#     Worker 2: Train Loss: 4.5856, Train Accuracy: 1.49%
#     Worker 3: Train Loss: 4.5878, Train Accuracy: 1.14%
#     Worker 4: Train Loss: 4.7021, Train Accuracy: 1.26%
#     Worker 5: Train Loss: 4.5828, Train Accuracy: 1.44%
#     Worker 6: Train Loss: 4.5899, Train Accuracy: 1.42%
#     Worker 7: Train Loss: 4.5854, Train Accuracy: 1.41%
# Epoch 10/150: Test Loss: 4.5752, Test Accuracy: 1.42%
#     Worker 0: Train Loss: 4.5798, Train Accuracy: 1.30%
#     Worker 1: Train Loss: 4.5736, Train Accuracy: 1.60%
#     Worker 2: Train Loss: 4.7890, Train Accuracy: 1.26%
#     Worker 3: Train Loss: 4.5796, Train Accuracy: 1.12%
#     Worker 4: Train Loss: 4.5950, Train Accuracy: 0.96%
#     Worker 5: Train Loss: 4.5729, Train Accuracy: 1.68%
#     Worker 6: Train Loss: 4.5797, Train Accuracy: 1.38%
#     Worker 7: Train Loss: 4.5782, Train Accuracy: 1.55%
# Epoch 11/150: Test Loss: 4.5766, Test Accuracy: 2.00%
#     Worker 0: Train Loss: 4.5734, Train Accuracy: 1.10%
#     Worker 1: Train Loss: 4.6250, Train Accuracy: 1.38%
#     Worker 2: Train Loss: 4.5938, Train Accuracy: 1.12%
#     Worker 3: Train Loss: 4.5661, Train Accuracy: 1.46%
#     Worker 4: Train Loss: 4.6046, Train Accuracy: 1.17%
#     Worker 5: Train Loss: 4.5681, Train Accuracy: 1.26%
#     Worker 6: Train Loss: 4.5698, Train Accuracy: 1.63%
#     Worker 7: Train Loss: 4.5843, Train Accuracy: 1.38%
# Epoch 12/150: Test Loss: 4.5731, Test Accuracy: 2.02%
#     Worker 0: Train Loss: 4.5904, Train Accuracy: 1.49%
#     Worker 1: Train Loss: 4.5860, Train Accuracy: 1.54%
#     Worker 2: Train Loss: 4.5876, Train Accuracy: 1.39%
#     Worker 3: Train Loss: 4.5602, Train Accuracy: 1.97%
#     Worker 4: Train Loss: 4.5801, Train Accuracy: 2.22%
#     Worker 5: Train Loss: 4.5711, Train Accuracy: 1.65%
#     Worker 6: Train Loss: 4.5888, Train Accuracy: 1.31%
#     Worker 7: Train Loss: 4.5764, Train Accuracy: 1.98%
# Epoch 13/150: Test Loss: 4.5597, Test Accuracy: 1.89%
#     Worker 0: Train Loss: 4.5794, Train Accuracy: 1.54%
#     Worker 1: Train Loss: 4.5754, Train Accuracy: 1.60%
#     Worker 2: Train Loss: 4.5768, Train Accuracy: 1.84%
#     Worker 3: Train Loss: 4.6045, Train Accuracy: 1.25%
#     Worker 4: Train Loss: 4.5715, Train Accuracy: 1.71%
#     Worker 5: Train Loss: 4.5764, Train Accuracy: 2.30%
#     Worker 6: Train Loss: 4.6009, Train Accuracy: 1.31%
#     Worker 7: Train Loss: 4.5668, Train Accuracy: 1.86%
# Epoch 14/150: Test Loss: 4.5469, Test Accuracy: 2.28%
#     Worker 0: Train Loss: 4.5738, Train Accuracy: 1.60%
#     Worker 1: Train Loss: 4.5568, Train Accuracy: 1.55%
#     Worker 2: Train Loss: 4.5604, Train Accuracy: 2.02%
#     Worker 3: Train Loss: 4.6031, Train Accuracy: 1.22%
#     Worker 4: Train Loss: 4.5592, Train Accuracy: 1.79%
#     Worker 5: Train Loss: 4.5570, Train Accuracy: 2.24%
#     Worker 6: Train Loss: 4.5645, Train Accuracy: 1.78%
#     Worker 7: Train Loss: 4.5642, Train Accuracy: 1.54%
# Epoch 15/150: Test Loss: 4.5507, Test Accuracy: 2.36%
#     Worker 0: Train Loss: 4.5640, Train Accuracy: 1.74%
#     Worker 1: Train Loss: 4.5779, Train Accuracy: 1.66%
#     Worker 2: Train Loss: 4.5391, Train Accuracy: 2.21%
#     Worker 3: Train Loss: 4.5829, Train Accuracy: 2.13%
#     Worker 4: Train Loss: 4.5495, Train Accuracy: 2.16%
#     Worker 5: Train Loss: 4.5481, Train Accuracy: 1.44%
#     Worker 6: Train Loss: 4.5545, Train Accuracy: 1.68%
#     Worker 7: Train Loss: 4.5429, Train Accuracy: 1.89%
# Epoch 16/150: Test Loss: 4.5328, Test Accuracy: 2.50%
#     Worker 0: Train Loss: 4.5536, Train Accuracy: 1.73%
#     Worker 1: Train Loss: 4.5709, Train Accuracy: 1.50%
#     Worker 2: Train Loss: 4.5435, Train Accuracy: 2.46%
#     Worker 3: Train Loss: 4.5658, Train Accuracy: 2.46%
#     Worker 4: Train Loss: 4.5421, Train Accuracy: 2.46%
#     Worker 5: Train Loss: 4.5592, Train Accuracy: 1.82%
#     Worker 6: Train Loss: 4.5441, Train Accuracy: 2.08%
#     Worker 7: Train Loss: 4.5608, Train Accuracy: 2.19%
# Epoch 17/150: Test Loss: 4.4811, Test Accuracy: 2.64%
#     Worker 0: Train Loss: 4.5124, Train Accuracy: 2.19%
#     Worker 1: Train Loss: 4.5388, Train Accuracy: 1.34%
#     Worker 2: Train Loss: 4.5217, Train Accuracy: 2.48%
#     Worker 3: Train Loss: 4.5221, Train Accuracy: 2.18%
#     Worker 4: Train Loss: 4.5163, Train Accuracy: 2.37%
#     Worker 5: Train Loss: 4.5219, Train Accuracy: 2.16%
#     Worker 6: Train Loss: 4.5889, Train Accuracy: 1.20%
#     Worker 7: Train Loss: 4.5481, Train Accuracy: 2.13%
# Epoch 18/150: Test Loss: 4.5284, Test Accuracy: 2.88%
#     Worker 0: Train Loss: 4.6288, Train Accuracy: 2.51%
#     Worker 1: Train Loss: 4.4700, Train Accuracy: 2.24%
#     Worker 2: Train Loss: 4.4679, Train Accuracy: 2.98%
#     Worker 3: Train Loss: 4.4861, Train Accuracy: 2.38%
#     Worker 4: Train Loss: 4.4748, Train Accuracy: 2.34%
#     Worker 5: Train Loss: 4.5164, Train Accuracy: 1.89%
#     Worker 6: Train Loss: 4.4925, Train Accuracy: 2.22%
#     Worker 7: Train Loss: 4.4780, Train Accuracy: 2.62%
# Epoch 19/150: Test Loss: 4.5769, Test Accuracy: 1.56%
#     Worker 0: Train Loss: 5.0675, Train Accuracy: 1.66%
#     Worker 1: Train Loss: 4.4931, Train Accuracy: 2.26%
#     Worker 2: Train Loss: 4.4688, Train Accuracy: 3.07%
#     Worker 3: Train Loss: 4.5343, Train Accuracy: 2.21%
#     Worker 4: Train Loss: 4.4883, Train Accuracy: 2.70%
#     Worker 5: Train Loss: 4.6939, Train Accuracy: 2.48%
#     Worker 6: Train Loss: 4.5473, Train Accuracy: 2.64%
#     Worker 7: Train Loss: 4.5359, Train Accuracy: 1.86%
# Epoch 20/150: Test Loss: 4.5866, Test Accuracy: 1.43%
#     Worker 0: Train Loss: 4.6292, Train Accuracy: 1.01%
#     Worker 1: Train Loss: 4.5757, Train Accuracy: 1.50%
#     Worker 2: Train Loss: 4.6780, Train Accuracy: 1.57%
#     Worker 3: Train Loss: 4.6347, Train Accuracy: 1.30%
#     Worker 4: Train Loss: 4.6938, Train Accuracy: 1.31%
#     Worker 5: Train Loss: 4.5787, Train Accuracy: 1.62%
#     Worker 6: Train Loss: 4.6236, Train Accuracy: 0.80%
#     Worker 7: Train Loss: 4.5903, Train Accuracy: 1.22%
# Epoch 21/150: Test Loss: 4.5898, Test Accuracy: 1.28%
#     Worker 0: Train Loss: 4.5923, Train Accuracy: 1.55%
#     Worker 1: Train Loss: 4.5856, Train Accuracy: 1.30%
#     Worker 2: Train Loss: 4.5763, Train Accuracy: 1.23%
#     Worker 3: Train Loss: 4.5886, Train Accuracy: 1.23%
#     Worker 4: Train Loss: 4.5952, Train Accuracy: 1.17%
#     Worker 5: Train Loss: 4.6394, Train Accuracy: 1.30%
#     Worker 6: Train Loss: 4.5916, Train Accuracy: 1.22%
#     Worker 7: Train Loss: 4.5904, Train Accuracy: 1.31%
# Epoch 22/150: Test Loss: 4.5790, Test Accuracy: 1.33%
#     Worker 0: Train Loss: 4.5866, Train Accuracy: 1.39%
#     Worker 1: Train Loss: 4.5850, Train Accuracy: 1.49%
#     Worker 2: Train Loss: 4.5625, Train Accuracy: 1.62%
#     Worker 3: Train Loss: 4.5885, Train Accuracy: 1.34%
#     Worker 4: Train Loss: 4.5912, Train Accuracy: 1.10%
#     Worker 5: Train Loss: 4.5959, Train Accuracy: 1.47%
#     Worker 6: Train Loss: 4.5887, Train Accuracy: 1.31%
#     Worker 7: Train Loss: 4.5895, Train Accuracy: 1.22%
# Epoch 23/150: Test Loss: 4.5491, Test Accuracy: 1.66%
#     Worker 0: Train Loss: 4.5716, Train Accuracy: 1.65%
#     Worker 1: Train Loss: 4.5742, Train Accuracy: 1.68%
#     Worker 2: Train Loss: 4.5615, Train Accuracy: 1.90%
#     Worker 3: Train Loss: 4.5670, Train Accuracy: 1.34%
#     Worker 4: Train Loss: 4.5772, Train Accuracy: 1.30%
#     Worker 5: Train Loss: 4.5774, Train Accuracy: 1.55%
#     Worker 6: Train Loss: 4.5742, Train Accuracy: 1.38%
#     Worker 7: Train Loss: 4.5737, Train Accuracy: 1.22%
# Epoch 24/150: Test Loss: 4.5162, Test Accuracy: 1.83%
#     Worker 0: Train Loss: 4.5339, Train Accuracy: 1.63%
#     Worker 1: Train Loss: 4.5700, Train Accuracy: 1.42%
#     Worker 2: Train Loss: 4.7059, Train Accuracy: 1.33%
#     Worker 3: Train Loss: 4.5651, Train Accuracy: 1.63%
#     Worker 4: Train Loss: 4.5608, Train Accuracy: 1.31%
#     Worker 5: Train Loss: 4.5347, Train Accuracy: 1.62%
#     Worker 6: Train Loss: 4.5573, Train Accuracy: 1.54%
#     Worker 7: Train Loss: 4.5550, Train Accuracy: 1.50%
# Epoch 25/150: Test Loss: 4.4350, Test Accuracy: 3.11%
#     Worker 0: Train Loss: 4.5014, Train Accuracy: 1.70%
#     Worker 1: Train Loss: 4.4941, Train Accuracy: 2.19%
#     Worker 2: Train Loss: 4.5269, Train Accuracy: 2.10%
#     Worker 3: Train Loss: 4.5221, Train Accuracy: 1.81%
#     Worker 4: Train Loss: 4.4869, Train Accuracy: 1.86%
#     Worker 5: Train Loss: 4.4778, Train Accuracy: 2.16%
#     Worker 6: Train Loss: 4.4951, Train Accuracy: 2.29%
#     Worker 7: Train Loss: 4.5463, Train Accuracy: 1.33%
# Epoch 26/150: Test Loss: 4.4281, Test Accuracy: 3.39%
#     Worker 0: Train Loss: 4.4391, Train Accuracy: 2.86%
#     Worker 1: Train Loss: 4.5055, Train Accuracy: 3.02%
#     Worker 2: Train Loss: 4.4399, Train Accuracy: 3.50%
#     Worker 3: Train Loss: 4.4878, Train Accuracy: 2.75%
#     Worker 4: Train Loss: 4.5118, Train Accuracy: 1.71%
#     Worker 5: Train Loss: 4.4655, Train Accuracy: 2.59%
#     Worker 6: Train Loss: 4.5762, Train Accuracy: 2.78%
#     Worker 7: Train Loss: 4.4787, Train Accuracy: 2.58%
# Epoch 27/150: Test Loss: 4.4960, Test Accuracy: 3.02%
#     Worker 0: Train Loss: 4.4448, Train Accuracy: 2.72%
#     Worker 1: Train Loss: 4.5213, Train Accuracy: 1.89%
#     Worker 2: Train Loss: 4.4029, Train Accuracy: 2.77%
#     Worker 3: Train Loss: 4.4586, Train Accuracy: 3.06%
#     Worker 4: Train Loss: 4.6071, Train Accuracy: 2.48%
#     Worker 5: Train Loss: 4.5737, Train Accuracy: 2.34%
#     Worker 6: Train Loss: 4.5211, Train Accuracy: 1.81%
#     Worker 7: Train Loss: 4.4795, Train Accuracy: 2.98%
# Epoch 28/150: Test Loss: 4.4587, Test Accuracy: 2.32%
#     Worker 0: Train Loss: 4.5203, Train Accuracy: 2.38%
#     Worker 1: Train Loss: 4.5208, Train Accuracy: 2.72%
#     Worker 2: Train Loss: 4.4641, Train Accuracy: 3.04%
#     Worker 3: Train Loss: 4.4696, Train Accuracy: 2.85%
#     Worker 4: Train Loss: 4.5337, Train Accuracy: 2.13%
#     Worker 5: Train Loss: 4.4969, Train Accuracy: 2.62%
#     Worker 6: Train Loss: 4.5448, Train Accuracy: 1.89%
#     Worker 7: Train Loss: 4.4913, Train Accuracy: 2.56%
# Epoch 29/150: Test Loss: 4.4511, Test Accuracy: 2.37%
#     Worker 0: Train Loss: 4.6226, Train Accuracy: 2.32%
#     Worker 1: Train Loss: 4.4406, Train Accuracy: 2.08%
#     Worker 2: Train Loss: 4.4399, Train Accuracy: 2.30%
#     Worker 3: Train Loss: 4.5418, Train Accuracy: 2.03%
#     Worker 4: Train Loss: 4.4669, Train Accuracy: 2.62%
#     Worker 5: Train Loss: 4.6364, Train Accuracy: 2.02%
#     Worker 6: Train Loss: 4.4636, Train Accuracy: 2.27%
#     Worker 7: Train Loss: 4.6172, Train Accuracy: 2.35%
# Epoch 30/150: Test Loss: 4.4674, Test Accuracy: 2.89%
#     Worker 0: Train Loss: 4.5953, Train Accuracy: 1.92%
#     Worker 1: Train Loss: 4.4497, Train Accuracy: 2.03%
#     Worker 2: Train Loss: 4.4556, Train Accuracy: 2.35%
#     Worker 3: Train Loss: 4.4673, Train Accuracy: 2.48%
#     Worker 4: Train Loss: 4.4234, Train Accuracy: 2.48%
#     Worker 5: Train Loss: 4.5620, Train Accuracy: 2.16%
#     Worker 6: Train Loss: 4.5419, Train Accuracy: 2.18%
#     Worker 7: Train Loss: 4.4973, Train Accuracy: 2.19%
# Epoch 31/150: Test Loss: 4.4025, Test Accuracy: 3.50%
#     Worker 0: Train Loss: 4.4714, Train Accuracy: 2.18%
#     Worker 1: Train Loss: 4.4518, Train Accuracy: 2.45%
#     Worker 2: Train Loss: 4.4570, Train Accuracy: 2.59%
#     Worker 3: Train Loss: 4.4997, Train Accuracy: 2.42%
#     Worker 4: Train Loss: 4.4210, Train Accuracy: 2.86%
#     Worker 5: Train Loss: 4.5534, Train Accuracy: 2.02%
#     Worker 6: Train Loss: 4.5252, Train Accuracy: 2.19%
#     Worker 7: Train Loss: 4.4557, Train Accuracy: 2.98%
# Epoch 32/150: Test Loss: 4.3995, Test Accuracy: 3.97%
#     Worker 0: Train Loss: 4.3969, Train Accuracy: 3.07%
#     Worker 1: Train Loss: 4.4251, Train Accuracy: 2.72%
#     Worker 2: Train Loss: 4.6410, Train Accuracy: 2.56%
#     Worker 3: Train Loss: 4.4380, Train Accuracy: 2.86%
#     Worker 4: Train Loss: 4.3815, Train Accuracy: 3.09%
#     Worker 5: Train Loss: 4.4717, Train Accuracy: 2.93%
#     Worker 6: Train Loss: 4.4287, Train Accuracy: 3.41%
#     Worker 7: Train Loss: 4.4220, Train Accuracy: 3.04%
# Epoch 33/150: Test Loss: 4.3822, Test Accuracy: 3.83%
#     Worker 0: Train Loss: 4.3594, Train Accuracy: 3.81%
#     Worker 1: Train Loss: 4.5545, Train Accuracy: 2.32%
#     Worker 2: Train Loss: 4.4570, Train Accuracy: 2.54%
#     Worker 3: Train Loss: 4.4073, Train Accuracy: 2.82%
#     Worker 4: Train Loss: 4.7605, Train Accuracy: 2.74%
#     Worker 5: Train Loss: 4.4850, Train Accuracy: 3.14%
#     Worker 6: Train Loss: 4.4106, Train Accuracy: 3.34%
#     Worker 7: Train Loss: 4.4102, Train Accuracy: 2.77%
# Epoch 34/150: Test Loss: 4.4836, Test Accuracy: 2.84%
#     Worker 0: Train Loss: 4.4705, Train Accuracy: 3.20%
#     Worker 1: Train Loss: 4.4996, Train Accuracy: 2.48%
#     Worker 2: Train Loss: 4.4491, Train Accuracy: 3.01%
#     Worker 3: Train Loss: 4.4232, Train Accuracy: 2.72%
#     Worker 4: Train Loss: 4.4625, Train Accuracy: 2.72%
#     Worker 5: Train Loss: 4.6163, Train Accuracy: 2.90%
#     Worker 6: Train Loss: 4.3941, Train Accuracy: 3.28%
#     Worker 7: Train Loss: 4.4556, Train Accuracy: 3.20%
# Epoch 35/150: Test Loss: 4.5450, Test Accuracy: 2.47%
#     Worker 0: Train Loss: 4.4956, Train Accuracy: 3.14%
#     Worker 1: Train Loss: 4.5038, Train Accuracy: 2.46%
#     Worker 2: Train Loss: 4.7073, Train Accuracy: 2.80%
#     Worker 3: Train Loss: 4.5115, Train Accuracy: 2.19%
#     Worker 4: Train Loss: 4.4825, Train Accuracy: 2.75%
#     Worker 5: Train Loss: 4.5994, Train Accuracy: 2.18%
#     Worker 6: Train Loss: 4.4728, Train Accuracy: 2.99%
#     Worker 7: Train Loss: 4.5776, Train Accuracy: 2.29%
# Epoch 36/150: Test Loss: 4.5227, Test Accuracy: 1.47%
#     Worker 0: Train Loss: 4.5578, Train Accuracy: 2.26%
#     Worker 1: Train Loss: 4.5497, Train Accuracy: 2.06%
#     Worker 2: Train Loss: 4.6129, Train Accuracy: 1.97%
#     Worker 3: Train Loss: 4.5449, Train Accuracy: 1.71%
#     Worker 4: Train Loss: 4.5107, Train Accuracy: 2.58%
#     Worker 5: Train Loss: 4.5041, Train Accuracy: 2.56%
#     Worker 6: Train Loss: 4.7684, Train Accuracy: 1.87%
#     Worker 7: Train Loss: 4.5752, Train Accuracy: 1.74%
# Epoch 37/150: Test Loss: 4.5123, Test Accuracy: 2.12%
#     Worker 0: Train Loss: 4.5002, Train Accuracy: 2.29%
#     Worker 1: Train Loss: 4.5222, Train Accuracy: 1.49%
#     Worker 2: Train Loss: 4.8960, Train Accuracy: 1.23%
#     Worker 3: Train Loss: 4.5162, Train Accuracy: 1.73%
#     Worker 4: Train Loss: 4.5309, Train Accuracy: 1.92%
#     Worker 5: Train Loss: 4.6101, Train Accuracy: 1.47%
#     Worker 6: Train Loss: 4.5237, Train Accuracy: 1.70%
#     Worker 7: Train Loss: 4.5368, Train Accuracy: 1.81%
# Epoch 38/150: Test Loss: 4.5300, Test Accuracy: 2.15%
#     Worker 0: Train Loss: 4.7931, Train Accuracy: 2.37%
#     Worker 1: Train Loss: 4.5275, Train Accuracy: 1.78%
#     Worker 2: Train Loss: 4.5515, Train Accuracy: 1.92%
#     Worker 3: Train Loss: 4.5055, Train Accuracy: 2.30%
#     Worker 4: Train Loss: 4.4993, Train Accuracy: 2.03%
#     Worker 5: Train Loss: 4.5586, Train Accuracy: 1.42%
#     Worker 6: Train Loss: 4.5938, Train Accuracy: 1.89%
#     Worker 7: Train Loss: 4.5221, Train Accuracy: 1.97%
# Epoch 39/150: Test Loss: 4.4990, Test Accuracy: 2.04%
#     Worker 0: Train Loss: 4.5673, Train Accuracy: 1.78%
#     Worker 1: Train Loss: 4.5567, Train Accuracy: 1.55%
#     Worker 2: Train Loss: 4.5076, Train Accuracy: 1.81%
#     Worker 3: Train Loss: 4.4916, Train Accuracy: 1.94%
#     Worker 4: Train Loss: 4.4909, Train Accuracy: 1.97%
#     Worker 5: Train Loss: 4.5450, Train Accuracy: 1.74%
#     Worker 6: Train Loss: 4.5532, Train Accuracy: 1.38%
#     Worker 7: Train Loss: 4.5186, Train Accuracy: 1.76%
# Epoch 40/150: Test Loss: 4.4306, Test Accuracy: 2.21%
#     Worker 0: Train Loss: 4.5161, Train Accuracy: 1.82%
#     Worker 1: Train Loss: 4.5189, Train Accuracy: 2.29%
#     Worker 2: Train Loss: 4.4686, Train Accuracy: 1.78%
#     Worker 3: Train Loss: 4.5125, Train Accuracy: 2.00%
#     Worker 4: Train Loss: 4.4991, Train Accuracy: 1.81%
#     Worker 5: Train Loss: 4.4755, Train Accuracy: 2.10%
#     Worker 6: Train Loss: 4.4706, Train Accuracy: 2.11%
#     Worker 7: Train Loss: 4.4800, Train Accuracy: 2.06%
# Epoch 41/150: Test Loss: 4.4418, Test Accuracy: 2.15%
#     Worker 0: Train Loss: 4.4251, Train Accuracy: 2.45%
#     Worker 1: Train Loss: 4.4867, Train Accuracy: 2.27%
#     Worker 2: Train Loss: 4.5059, Train Accuracy: 2.13%
#     Worker 3: Train Loss: 4.4497, Train Accuracy: 2.45%
#     Worker 4: Train Loss: 4.4213, Train Accuracy: 1.90%
#     Worker 5: Train Loss: 4.4351, Train Accuracy: 2.30%
#     Worker 6: Train Loss: 4.5535, Train Accuracy: 1.89%
#     Worker 7: Train Loss: 4.4946, Train Accuracy: 1.71%
# Epoch 42/150: Test Loss: 4.3927, Test Accuracy: 2.43%
#     Worker 0: Train Loss: 4.4353, Train Accuracy: 2.48%
#     Worker 1: Train Loss: 4.4857, Train Accuracy: 2.24%
#     Worker 2: Train Loss: 4.4803, Train Accuracy: 1.86%
#     Worker 3: Train Loss: 4.4378, Train Accuracy: 2.08%
#     Worker 4: Train Loss: 4.4644, Train Accuracy: 2.21%
#     Worker 5: Train Loss: 4.4213, Train Accuracy: 2.66%
#     Worker 6: Train Loss: 4.4666, Train Accuracy: 1.84%
#     Worker 7: Train Loss: 4.4715, Train Accuracy: 1.86%
# Epoch 43/150: Test Loss: 4.3581, Test Accuracy: 2.76%
#     Worker 0: Train Loss: 4.4758, Train Accuracy: 2.66%
#     Worker 1: Train Loss: 4.4186, Train Accuracy: 2.42%
#     Worker 2: Train Loss: 4.3940, Train Accuracy: 2.10%
#     Worker 3: Train Loss: 4.4792, Train Accuracy: 2.11%
#     Worker 4: Train Loss: 4.3894, Train Accuracy: 2.67%
#     Worker 5: Train Loss: 4.4586, Train Accuracy: 2.64%
#     Worker 6: Train Loss: 4.4198, Train Accuracy: 2.50%
#     Worker 7: Train Loss: 4.4327, Train Accuracy: 1.97%
# Epoch 44/150: Test Loss: 4.3618, Test Accuracy: 2.89%
#     Worker 0: Train Loss: 4.3867, Train Accuracy: 2.72%
#     Worker 1: Train Loss: 4.4982, Train Accuracy: 1.94%
#     Worker 2: Train Loss: 4.3633, Train Accuracy: 2.80%
#     Worker 3: Train Loss: 4.3754, Train Accuracy: 2.72%
#     Worker 4: Train Loss: 4.3651, Train Accuracy: 2.48%
#     Worker 5: Train Loss: 4.4188, Train Accuracy: 2.48%
#     Worker 6: Train Loss: 4.3712, Train Accuracy: 3.12%
#     Worker 7: Train Loss: 4.4294, Train Accuracy: 2.19%
# Epoch 45/150: Test Loss: 4.3338, Test Accuracy: 3.17%
#     Worker 0: Train Loss: 4.3489, Train Accuracy: 3.23%
#     Worker 1: Train Loss: 4.4200, Train Accuracy: 2.27%
#     Worker 2: Train Loss: 4.3602, Train Accuracy: 3.04%
#     Worker 3: Train Loss: 4.3809, Train Accuracy: 2.82%
#     Worker 4: Train Loss: 4.4495, Train Accuracy: 2.83%
#     Worker 5: Train Loss: 4.4006, Train Accuracy: 2.59%
#     Worker 6: Train Loss: 4.3753, Train Accuracy: 2.94%
#     Worker 7: Train Loss: 4.4508, Train Accuracy: 2.40%
# Epoch 46/150: Test Loss: 4.3286, Test Accuracy: 3.52%
#     Worker 0: Train Loss: 4.3546, Train Accuracy: 3.28%
#     Worker 1: Train Loss: 4.4444, Train Accuracy: 2.75%
#     Worker 2: Train Loss: 4.3301, Train Accuracy: 3.20%
#     Worker 3: Train Loss: 4.3541, Train Accuracy: 3.46%
#     Worker 4: Train Loss: 4.3652, Train Accuracy: 3.71%
#     Worker 5: Train Loss: 4.4313, Train Accuracy: 2.32%
#     Worker 6: Train Loss: 4.5556, Train Accuracy: 2.98%
#     Worker 7: Train Loss: 4.3715, Train Accuracy: 3.36%
# Epoch 47/150: Test Loss: 4.3014, Test Accuracy: 3.17%
#     Worker 0: Train Loss: 4.3461, Train Accuracy: 3.12%
#     Worker 1: Train Loss: 4.3716, Train Accuracy: 2.83%
#     Worker 2: Train Loss: 4.3045, Train Accuracy: 3.62%
#     Worker 3: Train Loss: 4.4207, Train Accuracy: 3.20%
#     Worker 4: Train Loss: 4.3409, Train Accuracy: 3.36%
#     Worker 5: Train Loss: 4.4177, Train Accuracy: 2.98%
#     Worker 6: Train Loss: 4.4066, Train Accuracy: 2.59%
#     Worker 7: Train Loss: 4.3534, Train Accuracy: 3.20%
# Epoch 48/150: Test Loss: 4.2863, Test Accuracy: 3.08%
#     Worker 0: Train Loss: 4.3037, Train Accuracy: 2.96%
#     Worker 1: Train Loss: 4.3430, Train Accuracy: 2.98%
#     Worker 2: Train Loss: 4.4561, Train Accuracy: 3.17%
#     Worker 3: Train Loss: 4.4081, Train Accuracy: 2.67%
#     Worker 4: Train Loss: 4.4531, Train Accuracy: 2.72%
#     Worker 5: Train Loss: 4.3598, Train Accuracy: 2.48%
#     Worker 6: Train Loss: 4.3549, Train Accuracy: 3.22%
#     Worker 7: Train Loss: 4.4213, Train Accuracy: 2.53%
# Epoch 49/150: Test Loss: 4.2802, Test Accuracy: 3.78%
#     Worker 0: Train Loss: 4.4274, Train Accuracy: 2.62%
#     Worker 1: Train Loss: 4.3749, Train Accuracy: 2.70%
#     Worker 2: Train Loss: 4.3195, Train Accuracy: 3.74%
#     Worker 3: Train Loss: 4.3277, Train Accuracy: 3.46%
#     Worker 4: Train Loss: 4.3387, Train Accuracy: 3.15%
#     Worker 5: Train Loss: 4.2984, Train Accuracy: 3.06%
#     Worker 6: Train Loss: 4.3063, Train Accuracy: 2.83%
#     Worker 7: Train Loss: 4.3340, Train Accuracy: 3.38%
# Epoch 50/150: Test Loss: 4.3644, Test Accuracy: 3.95%
#     Worker 0: Train Loss: 4.4558, Train Accuracy: 3.04%
#     Worker 1: Train Loss: 4.3644, Train Accuracy: 3.01%
#     Worker 2: Train Loss: 4.3658, Train Accuracy: 3.49%
#     Worker 3: Train Loss: 4.3422, Train Accuracy: 2.96%
#     Worker 4: Train Loss: 4.3244, Train Accuracy: 3.74%
#     Worker 5: Train Loss: 4.5112, Train Accuracy: 3.46%
#     Worker 6: Train Loss: 4.4092, Train Accuracy: 3.86%
#     Worker 7: Train Loss: 4.5208, Train Accuracy: 2.80%
# Epoch 51/150: Test Loss: 4.4667, Test Accuracy: 3.02%
#     Worker 0: Train Loss: 4.4047, Train Accuracy: 3.44%
#     Worker 1: Train Loss: 4.3665, Train Accuracy: 3.33%
#     Worker 2: Train Loss: 4.3480, Train Accuracy: 4.16%
#     Worker 3: Train Loss: 4.4370, Train Accuracy: 3.09%
#     Worker 4: Train Loss: 4.3718, Train Accuracy: 3.89%
#     Worker 5: Train Loss: 4.4445, Train Accuracy: 2.85%
#     Worker 6: Train Loss: 4.4032, Train Accuracy: 3.31%
#     Worker 7: Train Loss: 4.4781, Train Accuracy: 2.77%
# Epoch 52/150: Test Loss: 4.4212, Test Accuracy: 3.25%
#     Worker 0: Train Loss: 4.4477, Train Accuracy: 2.46%
#     Worker 1: Train Loss: 4.4548, Train Accuracy: 3.12%
#     Worker 2: Train Loss: 4.4515, Train Accuracy: 3.04%
#     Worker 3: Train Loss: 4.4755, Train Accuracy: 2.30%
#     Worker 4: Train Loss: 4.4515, Train Accuracy: 2.56%
#     Worker 5: Train Loss: 4.5638, Train Accuracy: 2.16%
#     Worker 6: Train Loss: 4.6943, Train Accuracy: 1.79%
#     Worker 7: Train Loss: 4.4880, Train Accuracy: 2.53%
# Epoch 53/150: Test Loss: 4.3939, Test Accuracy: 3.07%
#     Worker 0: Train Loss: 4.4666, Train Accuracy: 2.62%
#     Worker 1: Train Loss: 4.4007, Train Accuracy: 2.94%
#     Worker 2: Train Loss: 4.4409, Train Accuracy: 2.59%
#     Worker 3: Train Loss: 4.4109, Train Accuracy: 2.67%
#     Worker 4: Train Loss: 4.4296, Train Accuracy: 2.56%
#     Worker 5: Train Loss: 4.4287, Train Accuracy: 2.45%
#     Worker 6: Train Loss: 4.4806, Train Accuracy: 2.46%
#     Worker 7: Train Loss: 4.4289, Train Accuracy: 2.77%
# Epoch 54/150: Test Loss: 4.3585, Test Accuracy: 3.31%
#     Worker 0: Train Loss: 4.4273, Train Accuracy: 2.77%
#     Worker 1: Train Loss: 4.4757, Train Accuracy: 2.54%
#     Worker 2: Train Loss: 4.4348, Train Accuracy: 2.27%
#     Worker 3: Train Loss: 4.3938, Train Accuracy: 3.02%
#     Worker 4: Train Loss: 4.4392, Train Accuracy: 2.24%
#     Worker 5: Train Loss: 4.4343, Train Accuracy: 2.42%
#     Worker 6: Train Loss: 4.3948, Train Accuracy: 3.12%
#     Worker 7: Train Loss: 4.4305, Train Accuracy: 2.38%
# Epoch 55/150: Test Loss: 4.3257, Test Accuracy: 3.23%
#     Worker 0: Train Loss: 4.3855, Train Accuracy: 2.82%
#     Worker 1: Train Loss: 4.4181, Train Accuracy: 2.46%
#     Worker 2: Train Loss: 4.3736, Train Accuracy: 3.26%
#     Worker 3: Train Loss: 4.3453, Train Accuracy: 2.99%
#     Worker 4: Train Loss: 4.5716, Train Accuracy: 2.77%
#     Worker 5: Train Loss: 4.4338, Train Accuracy: 2.46%
#     Worker 6: Train Loss: 4.4451, Train Accuracy: 3.31%
#     Worker 7: Train Loss: 4.3995, Train Accuracy: 2.37%
# Epoch 56/150: Test Loss: 4.3436, Test Accuracy: 3.75%
#     Worker 0: Train Loss: 4.4130, Train Accuracy: 2.98%
#     Worker 1: Train Loss: 4.3889, Train Accuracy: 2.88%
#     Worker 2: Train Loss: 4.5055, Train Accuracy: 3.39%
#     Worker 3: Train Loss: 4.4737, Train Accuracy: 2.08%
#     Worker 4: Train Loss: 4.4050, Train Accuracy: 2.72%
#     Worker 5: Train Loss: 4.3371, Train Accuracy: 3.47%
#     Worker 6: Train Loss: 4.4207, Train Accuracy: 2.99%
#     Worker 7: Train Loss: 4.3552, Train Accuracy: 3.12%
# Epoch 57/150: Test Loss: 4.4086, Test Accuracy: 2.98%
#     Worker 0: Train Loss: 4.3652, Train Accuracy: 3.57%
#     Worker 1: Train Loss: 4.4801, Train Accuracy: 1.84%
#     Worker 2: Train Loss: 4.3747, Train Accuracy: 3.65%
#     Worker 3: Train Loss: 4.4167, Train Accuracy: 3.31%
#     Worker 4: Train Loss: 4.4244, Train Accuracy: 2.91%
#     Worker 5: Train Loss: 4.4192, Train Accuracy: 2.96%
#     Worker 6: Train Loss: 4.3405, Train Accuracy: 3.34%
#     Worker 7: Train Loss: 4.3623, Train Accuracy: 3.02%
# Epoch 58/150: Test Loss: 4.3964, Test Accuracy: 2.35%
#     Worker 0: Train Loss: 4.4121, Train Accuracy: 3.02%
#     Worker 1: Train Loss: 4.4480, Train Accuracy: 2.78%
#     Worker 2: Train Loss: 4.4959, Train Accuracy: 2.56%
#     Worker 3: Train Loss: 4.4178, Train Accuracy: 2.35%
#     Worker 4: Train Loss: 4.3945, Train Accuracy: 2.56%
#     Worker 5: Train Loss: 4.4239, Train Accuracy: 2.67%
#     Worker 6: Train Loss: 4.4118, Train Accuracy: 2.74%
#     Worker 7: Train Loss: 4.4122, Train Accuracy: 2.69%
# Epoch 59/150: Test Loss: 4.4256, Test Accuracy: 2.81%
#     Worker 0: Train Loss: 4.3844, Train Accuracy: 2.58%
#     Worker 1: Train Loss: 4.4107, Train Accuracy: 2.45%
#     Worker 2: Train Loss: 4.4908, Train Accuracy: 1.92%
#     Worker 3: Train Loss: 4.4140, Train Accuracy: 2.34%
#     Worker 4: Train Loss: 4.3832, Train Accuracy: 2.62%
#     Worker 5: Train Loss: 4.4534, Train Accuracy: 3.01%
#     Worker 6: Train Loss: 4.5047, Train Accuracy: 2.16%
#     Worker 7: Train Loss: 4.4015, Train Accuracy: 2.56%
# Epoch 60/150: Test Loss: 4.4096, Test Accuracy: 2.82%
#     Worker 0: Train Loss: 4.3895, Train Accuracy: 2.99%
#     Worker 1: Train Loss: 4.4091, Train Accuracy: 2.35%
#     Worker 2: Train Loss: 4.4861, Train Accuracy: 3.17%
#     Worker 3: Train Loss: 4.4386, Train Accuracy: 2.05%
#     Worker 4: Train Loss: 4.4239, Train Accuracy: 2.80%
#     Worker 5: Train Loss: 4.4773, Train Accuracy: 2.48%
#     Worker 6: Train Loss: 4.4611, Train Accuracy: 1.98%
#     Worker 7: Train Loss: 4.4597, Train Accuracy: 1.87%
# Epoch 61/150: Test Loss: 4.3372, Test Accuracy: 2.99%
#     Worker 0: Train Loss: 4.4811, Train Accuracy: 2.94%
#     Worker 1: Train Loss: 4.3841, Train Accuracy: 2.96%
#     Worker 2: Train Loss: 4.4557, Train Accuracy: 2.64%
#     Worker 3: Train Loss: 4.4423, Train Accuracy: 2.10%
#     Worker 4: Train Loss: 4.4109, Train Accuracy: 2.67%
#     Worker 5: Train Loss: 4.4149, Train Accuracy: 2.50%
#     Worker 6: Train Loss: 4.4549, Train Accuracy: 2.40%
#     Worker 7: Train Loss: 4.4123, Train Accuracy: 2.54%
# Epoch 62/150: Test Loss: 4.3452, Test Accuracy: 3.24%
#     Worker 0: Train Loss: 4.3891, Train Accuracy: 2.42%
#     Worker 1: Train Loss: 4.5446, Train Accuracy: 2.62%
#     Worker 2: Train Loss: 4.3997, Train Accuracy: 2.75%
#     Worker 3: Train Loss: 4.4220, Train Accuracy: 2.42%
#     Worker 4: Train Loss: 4.4462, Train Accuracy: 1.98%
#     Worker 5: Train Loss: 4.3276, Train Accuracy: 3.28%
#     Worker 6: Train Loss: 4.4087, Train Accuracy: 2.90%
#     Worker 7: Train Loss: 4.3684, Train Accuracy: 2.77%
# Epoch 63/150: Test Loss: 4.3858, Test Accuracy: 2.51%
#     Worker 0: Train Loss: 4.3486, Train Accuracy: 2.88%
#     Worker 1: Train Loss: 4.3905, Train Accuracy: 2.40%
#     Worker 2: Train Loss: 4.3746, Train Accuracy: 2.53%
#     Worker 3: Train Loss: 4.4067, Train Accuracy: 2.29%
#     Worker 4: Train Loss: 4.3439, Train Accuracy: 2.69%
#     Worker 5: Train Loss: 4.3845, Train Accuracy: 2.72%
#     Worker 6: Train Loss: 4.3634, Train Accuracy: 2.98%
#     Worker 7: Train Loss: 4.4652, Train Accuracy: 2.29%
# Epoch 64/150: Test Loss: 4.3213, Test Accuracy: 2.76%
#     Worker 0: Train Loss: 4.3932, Train Accuracy: 2.56%
#     Worker 1: Train Loss: 4.3748, Train Accuracy: 2.59%
#     Worker 2: Train Loss: 4.3769, Train Accuracy: 2.05%
#     Worker 3: Train Loss: 4.4226, Train Accuracy: 2.22%
#     Worker 4: Train Loss: 4.3671, Train Accuracy: 2.22%
#     Worker 5: Train Loss: 4.6475, Train Accuracy: 1.68%
#     Worker 6: Train Loss: 4.3747, Train Accuracy: 2.26%
#     Worker 7: Train Loss: 4.4343, Train Accuracy: 2.11%
# Epoch 65/150: Test Loss: 4.2611, Test Accuracy: 4.28%
#     Worker 0: Train Loss: 4.3179, Train Accuracy: 3.17%
#     Worker 1: Train Loss: 4.3235, Train Accuracy: 3.25%
#     Worker 2: Train Loss: 4.3147, Train Accuracy: 3.14%
#     Worker 3: Train Loss: 4.3178, Train Accuracy: 3.25%
#     Worker 4: Train Loss: 4.4240, Train Accuracy: 2.27%
#     Worker 5: Train Loss: 4.4561, Train Accuracy: 2.34%
#     Worker 6: Train Loss: 4.3252, Train Accuracy: 2.42%
#     Worker 7: Train Loss: 4.3351, Train Accuracy: 2.67%
# Epoch 66/150: Test Loss: 4.2802, Test Accuracy: 3.71%
#     Worker 0: Train Loss: 4.2603, Train Accuracy: 4.53%
#     Worker 1: Train Loss: 4.4319, Train Accuracy: 3.57%
#     Worker 2: Train Loss: 4.2835, Train Accuracy: 3.94%
#     Worker 3: Train Loss: 4.3606, Train Accuracy: 3.34%
#     Worker 4: Train Loss: 4.2901, Train Accuracy: 4.11%
#     Worker 5: Train Loss: 4.3526, Train Accuracy: 3.06%
#     Worker 6: Train Loss: 4.2672, Train Accuracy: 4.24%
#     Worker 7: Train Loss: 4.4973, Train Accuracy: 3.52%
# Epoch 67/150: Test Loss: 4.2774, Test Accuracy: 3.88%
#     Worker 0: Train Loss: 4.4546, Train Accuracy: 3.47%
#     Worker 1: Train Loss: 4.5008, Train Accuracy: 3.23%
#     Worker 2: Train Loss: 4.2832, Train Accuracy: 3.74%
#     Worker 3: Train Loss: 4.3119, Train Accuracy: 3.73%
#     Worker 4: Train Loss: 4.3064, Train Accuracy: 3.41%
#     Worker 5: Train Loss: 4.2993, Train Accuracy: 3.46%
#     Worker 6: Train Loss: 4.2828, Train Accuracy: 3.41%
#     Worker 7: Train Loss: 4.3568, Train Accuracy: 3.57%
# Epoch 68/150: Test Loss: 4.2691, Test Accuracy: 4.13%
#     Worker 0: Train Loss: 4.3226, Train Accuracy: 3.94%
#     Worker 1: Train Loss: 4.3518, Train Accuracy: 3.09%
#     Worker 2: Train Loss: 4.5599, Train Accuracy: 3.39%
#     Worker 3: Train Loss: 4.3070, Train Accuracy: 3.63%
#     Worker 4: Train Loss: 4.3094, Train Accuracy: 4.03%
#     Worker 5: Train Loss: 4.3088, Train Accuracy: 3.50%
#     Worker 6: Train Loss: 4.2875, Train Accuracy: 3.70%
#     Worker 7: Train Loss: 4.3510, Train Accuracy: 3.14%
# Epoch 69/150: Test Loss: 4.2276, Test Accuracy: 4.34%
#     Worker 0: Train Loss: 4.2818, Train Accuracy: 3.92%
#     Worker 1: Train Loss: 4.3593, Train Accuracy: 3.92%
#     Worker 2: Train Loss: 4.3146, Train Accuracy: 4.06%
#     Worker 3: Train Loss: 4.2808, Train Accuracy: 3.73%
#     Worker 4: Train Loss: 4.3818, Train Accuracy: 2.86%
#     Worker 5: Train Loss: 4.4803, Train Accuracy: 3.73%
#     Worker 6: Train Loss: 4.2622, Train Accuracy: 3.97%
#     Worker 7: Train Loss: 4.2759, Train Accuracy: 4.02%
# Epoch 70/150: Test Loss: 4.2201, Test Accuracy: 5.24%
#     Worker 0: Train Loss: 4.2468, Train Accuracy: 4.34%
#     Worker 1: Train Loss: 4.3026, Train Accuracy: 3.30%
#     Worker 2: Train Loss: 4.3266, Train Accuracy: 3.60%
#     Worker 3: Train Loss: 4.2622, Train Accuracy: 3.73%
#     Worker 4: Train Loss: 4.3087, Train Accuracy: 3.86%
#     Worker 5: Train Loss: 4.3164, Train Accuracy: 4.16%
#     Worker 6: Train Loss: 4.4453, Train Accuracy: 3.78%
#     Worker 7: Train Loss: 4.2993, Train Accuracy: 4.27%
# Epoch 71/150: Test Loss: 4.2543, Test Accuracy: 3.97%
#     Worker 0: Train Loss: 4.2806, Train Accuracy: 4.46%
#     Worker 1: Train Loss: 4.3623, Train Accuracy: 2.88%
#     Worker 2: Train Loss: 4.2436, Train Accuracy: 4.66%
#     Worker 3: Train Loss: 4.2548, Train Accuracy: 4.75%
#     Worker 4: Train Loss: 4.3007, Train Accuracy: 4.03%
#     Worker 5: Train Loss: 4.5470, Train Accuracy: 4.02%
#     Worker 6: Train Loss: 4.3030, Train Accuracy: 4.51%
#     Worker 7: Train Loss: 4.3516, Train Accuracy: 3.44%
# Epoch 72/150: Test Loss: 4.2413, Test Accuracy: 4.23%
#     Worker 0: Train Loss: 4.2969, Train Accuracy: 3.79%
#     Worker 1: Train Loss: 4.3142, Train Accuracy: 3.54%
#     Worker 2: Train Loss: 4.3674, Train Accuracy: 4.21%
#     Worker 3: Train Loss: 4.3879, Train Accuracy: 3.17%
#     Worker 4: Train Loss: 4.2546, Train Accuracy: 4.34%
#     Worker 5: Train Loss: 4.4242, Train Accuracy: 3.10%
#     Worker 6: Train Loss: 4.3074, Train Accuracy: 3.33%
#     Worker 7: Train Loss: 4.3239, Train Accuracy: 3.63%
# Epoch 73/150: Test Loss: 4.2296, Test Accuracy: 3.67%
#     Worker 0: Train Loss: 4.3150, Train Accuracy: 3.76%
#     Worker 1: Train Loss: 4.2623, Train Accuracy: 4.00%
#     Worker 2: Train Loss: 4.2583, Train Accuracy: 4.69%
#     Worker 3: Train Loss: 4.3124, Train Accuracy: 3.26%
#     Worker 4: Train Loss: 4.2441, Train Accuracy: 4.16%
#     Worker 5: Train Loss: 4.3350, Train Accuracy: 3.54%
#     Worker 6: Train Loss: 4.2831, Train Accuracy: 3.33%
#     Worker 7: Train Loss: 4.2867, Train Accuracy: 4.19%
# Epoch 74/150: Test Loss: 4.2023, Test Accuracy: 3.92%
#     Worker 0: Train Loss: 4.4183, Train Accuracy: 3.22%
#     Worker 1: Train Loss: 4.2856, Train Accuracy: 3.62%
#     Worker 2: Train Loss: 4.2820, Train Accuracy: 3.63%
#     Worker 3: Train Loss: 4.2831, Train Accuracy: 3.52%
#     Worker 4: Train Loss: 4.2458, Train Accuracy: 3.76%
#     Worker 5: Train Loss: 4.3832, Train Accuracy: 3.01%
#     Worker 6: Train Loss: 4.2582, Train Accuracy: 3.39%
#     Worker 7: Train Loss: 4.2546, Train Accuracy: 3.50%
# Epoch 75/150: Test Loss: 4.2654, Test Accuracy: 4.48%
#     Worker 0: Train Loss: 4.2759, Train Accuracy: 4.30%
#     Worker 1: Train Loss: 4.2501, Train Accuracy: 4.13%
#     Worker 2: Train Loss: 4.3237, Train Accuracy: 3.38%
#     Worker 3: Train Loss: 4.2497, Train Accuracy: 3.82%
#     Worker 4: Train Loss: 4.2385, Train Accuracy: 3.78%
#     Worker 5: Train Loss: 4.3540, Train Accuracy: 3.17%
#     Worker 6: Train Loss: 4.2334, Train Accuracy: 4.19%
#     Worker 7: Train Loss: 4.2757, Train Accuracy: 4.24%
# Epoch 76/150: Test Loss: 4.3404, Test Accuracy: 3.26%
#     Worker 0: Train Loss: 4.2694, Train Accuracy: 4.32%
#     Worker 1: Train Loss: 4.2658, Train Accuracy: 4.26%
#     Worker 2: Train Loss: 4.4508, Train Accuracy: 4.35%
#     Worker 3: Train Loss: 4.4791, Train Accuracy: 2.99%
#     Worker 4: Train Loss: 4.3789, Train Accuracy: 3.87%
#     Worker 5: Train Loss: 4.3181, Train Accuracy: 3.97%
#     Worker 6: Train Loss: 4.3675, Train Accuracy: 4.18%
#     Worker 7: Train Loss: 4.3492, Train Accuracy: 3.26%
# Epoch 77/150: Test Loss: 4.3945, Test Accuracy: 3.28%
#     Worker 0: Train Loss: 4.5595, Train Accuracy: 2.78%
#     Worker 1: Train Loss: 4.3079, Train Accuracy: 3.39%
#     Worker 2: Train Loss: 4.5694, Train Accuracy: 2.69%
#     Worker 3: Train Loss: 4.3925, Train Accuracy: 2.64%
#     Worker 4: Train Loss: 4.4603, Train Accuracy: 2.91%
#     Worker 5: Train Loss: 4.3694, Train Accuracy: 2.80%
#     Worker 6: Train Loss: 4.3618, Train Accuracy: 2.93%
#     Worker 7: Train Loss: 4.3863, Train Accuracy: 2.72%
# Epoch 78/150: Test Loss: 4.3523, Test Accuracy: 2.83%
#     Worker 0: Train Loss: 4.4277, Train Accuracy: 2.78%
#     Worker 1: Train Loss: 4.3589, Train Accuracy: 3.14%
#     Worker 2: Train Loss: 4.4375, Train Accuracy: 2.85%
#     Worker 3: Train Loss: 4.3894, Train Accuracy: 3.23%
#     Worker 4: Train Loss: 4.4222, Train Accuracy: 2.93%
#     Worker 5: Train Loss: 4.3989, Train Accuracy: 3.07%
#     Worker 6: Train Loss: 4.4373, Train Accuracy: 2.70%
#     Worker 7: Train Loss: 4.3972, Train Accuracy: 3.14%
# Epoch 79/150: Test Loss: 4.3341, Test Accuracy: 2.68%
#     Worker 0: Train Loss: 4.3789, Train Accuracy: 2.37%
#     Worker 1: Train Loss: 4.3558, Train Accuracy: 2.38%
#     Worker 2: Train Loss: 4.3488, Train Accuracy: 2.62%
#     Worker 3: Train Loss: 4.3647, Train Accuracy: 2.45%
#     Worker 4: Train Loss: 4.3440, Train Accuracy: 2.43%
#     Worker 5: Train Loss: 4.3750, Train Accuracy: 2.35%
#     Worker 6: Train Loss: 4.5488, Train Accuracy: 2.30%
#     Worker 7: Train Loss: 4.3516, Train Accuracy: 2.67%
# Epoch 80/150: Test Loss: 4.3128, Test Accuracy: 3.32%
#     Worker 0: Train Loss: 4.3972, Train Accuracy: 1.68%
#     Worker 1: Train Loss: 4.3542, Train Accuracy: 2.86%
#     Worker 2: Train Loss: 4.3298, Train Accuracy: 2.75%
#     Worker 3: Train Loss: 4.3661, Train Accuracy: 2.50%
#     Worker 4: Train Loss: 4.3444, Train Accuracy: 2.29%
#     Worker 5: Train Loss: 4.3299, Train Accuracy: 2.85%
#     Worker 6: Train Loss: 4.4305, Train Accuracy: 2.37%
#     Worker 7: Train Loss: 4.4779, Train Accuracy: 2.74%
# Epoch 81/150: Test Loss: 4.2868, Test Accuracy: 3.50%
#     Worker 0: Train Loss: 4.2951, Train Accuracy: 3.06%
#     Worker 1: Train Loss: 4.3372, Train Accuracy: 2.77%
#     Worker 2: Train Loss: 4.3104, Train Accuracy: 3.15%
#     Worker 3: Train Loss: 4.3369, Train Accuracy: 3.02%
#     Worker 4: Train Loss: 4.4332, Train Accuracy: 2.82%
#     Worker 5: Train Loss: 4.3762, Train Accuracy: 2.78%
#     Worker 6: Train Loss: 4.3338, Train Accuracy: 3.04%
#     Worker 7: Train Loss: 4.3915, Train Accuracy: 2.98%
# Epoch 82/150: Test Loss: 4.2821, Test Accuracy: 3.00%
#     Worker 0: Train Loss: 4.3352, Train Accuracy: 3.12%
#     Worker 1: Train Loss: 4.2962, Train Accuracy: 2.93%
#     Worker 2: Train Loss: 4.4264, Train Accuracy: 3.31%
#     Worker 3: Train Loss: 4.2964, Train Accuracy: 3.68%
#     Worker 4: Train Loss: 4.3266, Train Accuracy: 2.75%
#     Worker 5: Train Loss: 4.3034, Train Accuracy: 3.06%
#     Worker 6: Train Loss: 4.2869, Train Accuracy: 3.36%
#     Worker 7: Train Loss: 4.2974, Train Accuracy: 3.30%
# Epoch 83/150: Test Loss: 4.2455, Test Accuracy: 3.57%
#     Worker 0: Train Loss: 4.3074, Train Accuracy: 3.22%
#     Worker 1: Train Loss: 4.3028, Train Accuracy: 2.83%
#     Worker 2: Train Loss: 4.3255, Train Accuracy: 3.46%
#     Worker 3: Train Loss: 4.3256, Train Accuracy: 3.10%
#     Worker 4: Train Loss: 4.3060, Train Accuracy: 2.80%
#     Worker 5: Train Loss: 4.2714, Train Accuracy: 3.04%
#     Worker 6: Train Loss: 4.2879, Train Accuracy: 3.14%
#     Worker 7: Train Loss: 4.4179, Train Accuracy: 3.26%
# Epoch 84/150: Test Loss: 4.2623, Test Accuracy: 3.56%
#     Worker 0: Train Loss: 4.2690, Train Accuracy: 3.46%
#     Worker 1: Train Loss: 4.2739, Train Accuracy: 3.36%
#     Worker 2: Train Loss: 4.3076, Train Accuracy: 3.14%
#     Worker 3: Train Loss: 4.2980, Train Accuracy: 3.07%
#     Worker 4: Train Loss: 4.4573, Train Accuracy: 3.36%
#     Worker 5: Train Loss: 4.2576, Train Accuracy: 3.44%
#     Worker 6: Train Loss: 4.2425, Train Accuracy: 3.78%
#     Worker 7: Train Loss: 4.3579, Train Accuracy: 3.18%
# Epoch 85/150: Test Loss: 4.2931, Test Accuracy: 3.59%
#     Worker 0: Train Loss: 4.2635, Train Accuracy: 3.20%
#     Worker 1: Train Loss: 4.4449, Train Accuracy: 2.66%
#     Worker 2: Train Loss: 4.3078, Train Accuracy: 3.57%
#     Worker 3: Train Loss: 4.3268, Train Accuracy: 3.02%
#     Worker 4: Train Loss: 4.3267, Train Accuracy: 2.83%
#     Worker 5: Train Loss: 4.2968, Train Accuracy: 3.57%
#     Worker 6: Train Loss: 4.2821, Train Accuracy: 3.54%
#     Worker 7: Train Loss: 4.3025, Train Accuracy: 3.25%
# Epoch 86/150: Test Loss: 4.2785, Test Accuracy: 4.23%
#     Worker 0: Train Loss: 4.3192, Train Accuracy: 3.58%
#     Worker 1: Train Loss: 4.3367, Train Accuracy: 3.33%
#     Worker 2: Train Loss: 4.4099, Train Accuracy: 3.28%
#     Worker 3: Train Loss: 4.3351, Train Accuracy: 3.10%
#     Worker 4: Train Loss: 4.3135, Train Accuracy: 3.09%
#     Worker 5: Train Loss: 4.3425, Train Accuracy: 3.09%
#     Worker 6: Train Loss: 4.4184, Train Accuracy: 3.76%
#     Worker 7: Train Loss: 4.3009, Train Accuracy: 3.41%
# Epoch 87/150: Test Loss: 4.2173, Test Accuracy: 4.42%
#     Worker 0: Train Loss: 4.2742, Train Accuracy: 3.68%
#     Worker 1: Train Loss: 4.3041, Train Accuracy: 3.57%
#     Worker 2: Train Loss: 4.3119, Train Accuracy: 3.86%
#     Worker 3: Train Loss: 4.2914, Train Accuracy: 3.44%
#     Worker 4: Train Loss: 4.2702, Train Accuracy: 3.63%
#     Worker 5: Train Loss: 4.2628, Train Accuracy: 4.37%
#     Worker 6: Train Loss: 4.3232, Train Accuracy: 3.68%
#     Worker 7: Train Loss: 4.3604, Train Accuracy: 3.30%
# Epoch 88/150: Test Loss: 4.1830, Test Accuracy: 5.42%
#     Worker 0: Train Loss: 4.2176, Train Accuracy: 4.46%
#     Worker 1: Train Loss: 4.3663, Train Accuracy: 3.54%
#     Worker 2: Train Loss: 4.2321, Train Accuracy: 4.22%
#     Worker 3: Train Loss: 4.2432, Train Accuracy: 3.97%
#     Worker 4: Train Loss: 4.2514, Train Accuracy: 4.10%
#     Worker 5: Train Loss: 4.2135, Train Accuracy: 3.97%
#     Worker 6: Train Loss: 4.2607, Train Accuracy: 4.05%
#     Worker 7: Train Loss: 4.2279, Train Accuracy: 3.87%
# Epoch 89/150: Test Loss: 4.2378, Test Accuracy: 4.16%
#     Worker 0: Train Loss: 4.2273, Train Accuracy: 4.69%
#     Worker 1: Train Loss: 4.2897, Train Accuracy: 3.34%
#     Worker 2: Train Loss: 4.2684, Train Accuracy: 4.48%
#     Worker 3: Train Loss: 4.3267, Train Accuracy: 3.86%
#     Worker 4: Train Loss: 4.2164, Train Accuracy: 4.62%
#     Worker 5: Train Loss: 4.3169, Train Accuracy: 4.02%
#     Worker 6: Train Loss: 4.2107, Train Accuracy: 4.74%
#     Worker 7: Train Loss: 4.2918, Train Accuracy: 4.88%
# Epoch 90/150: Test Loss: 4.2256, Test Accuracy: 4.03%
#     Worker 0: Train Loss: 4.2528, Train Accuracy: 3.87%
#     Worker 1: Train Loss: 4.2626, Train Accuracy: 3.62%
#     Worker 2: Train Loss: 4.2359, Train Accuracy: 4.35%
#     Worker 3: Train Loss: 4.3040, Train Accuracy: 3.55%
#     Worker 4: Train Loss: 4.2780, Train Accuracy: 3.76%
#     Worker 5: Train Loss: 4.3890, Train Accuracy: 3.09%
#     Worker 6: Train Loss: 4.2711, Train Accuracy: 3.63%
#     Worker 7: Train Loss: 4.3954, Train Accuracy: 4.61%
# Epoch 91/150: Test Loss: 4.1922, Test Accuracy: 4.43%
#     Worker 0: Train Loss: 4.2176, Train Accuracy: 3.70%
#     Worker 1: Train Loss: 4.2528, Train Accuracy: 3.42%
#     Worker 2: Train Loss: 4.2116, Train Accuracy: 4.13%
#     Worker 3: Train Loss: 4.2476, Train Accuracy: 3.71%
#     Worker 4: Train Loss: 4.2541, Train Accuracy: 3.82%
#     Worker 5: Train Loss: 4.2513, Train Accuracy: 3.49%
#     Worker 6: Train Loss: 4.2373, Train Accuracy: 4.29%
#     Worker 7: Train Loss: 4.2738, Train Accuracy: 3.60%
# Epoch 92/150: Test Loss: 4.1506, Test Accuracy: 5.23%
#     Worker 0: Train Loss: 4.2269, Train Accuracy: 4.42%
#     Worker 1: Train Loss: 4.2495, Train Accuracy: 4.21%
#     Worker 2: Train Loss: 4.2124, Train Accuracy: 4.53%
#     Worker 3: Train Loss: 4.4357, Train Accuracy: 3.33%
#     Worker 4: Train Loss: 4.1842, Train Accuracy: 4.34%
#     Worker 5: Train Loss: 4.1941, Train Accuracy: 4.59%
#     Worker 6: Train Loss: 4.2280, Train Accuracy: 4.24%
#     Worker 7: Train Loss: 4.3288, Train Accuracy: 3.60%
# Epoch 93/150: Test Loss: 4.1936, Test Accuracy: 4.63%
#     Worker 0: Train Loss: 4.1824, Train Accuracy: 4.43%
#     Worker 1: Train Loss: 4.2218, Train Accuracy: 4.03%
#     Worker 2: Train Loss: 4.2546, Train Accuracy: 4.13%
#     Worker 3: Train Loss: 4.2177, Train Accuracy: 4.38%
#     Worker 4: Train Loss: 4.2564, Train Accuracy: 3.66%
#     Worker 5: Train Loss: 4.1731, Train Accuracy: 5.34%
#     Worker 6: Train Loss: 4.3751, Train Accuracy: 4.54%
#     Worker 7: Train Loss: 4.2729, Train Accuracy: 4.26%
# Epoch 94/150: Test Loss: 4.1779, Test Accuracy: 5.04%
#     Worker 0: Train Loss: 4.2969, Train Accuracy: 3.65%
#     Worker 1: Train Loss: 4.2177, Train Accuracy: 3.62%
#     Worker 2: Train Loss: 4.2355, Train Accuracy: 4.03%
#     Worker 3: Train Loss: 4.2382, Train Accuracy: 4.06%
#     Worker 4: Train Loss: 4.3275, Train Accuracy: 2.93%
# ...
#     Worker 1: Train Loss: 4.0549, Train Accuracy: 5.94%
#     Worker 2: Train Loss: 4.1088, Train Accuracy: 5.20%
#     Worker 3: Train Loss: 4.1297, Train Accuracy: 5.60%
#     Worker 4: Train Loss: 4.0848, Train Accuracy: 5.74%
#     Worker 5: Train Loss: 4.0741, Train Accuracy: 5.65%
#     Worker 6: Train Loss: 4.1527, Train Accuracy: 5.31%
#     Worker 7: Train Loss: 4.0901, Train Accuracy: 4.91%
# Epoch 120/150: Test Loss: 4.0353, Test Accuracy: 7.35%
#     Worker 0: Train Loss: 4.1107, Train Accuracy: 5.47%
#     Worker 1: Train Loss: 4.0550, Train Accuracy: 6.00%
#     Worker 2: Train Loss: 4.0681, Train Accuracy: 6.21%
#     Worker 3: Train Loss: 4.0872, Train Accuracy: 6.24%
#     Worker 4: Train Loss: 4.1098, Train Accuracy: 5.60%
#     Worker 5: Train Loss: 4.0377, Train Accuracy: 6.24%
#     Worker 6: Train Loss: 4.0785, Train Accuracy: 6.27%
#     Worker 7: Train Loss: 4.1057, Train Accuracy: 5.46%
# Epoch 121/150: Test Loss: 4.0191, Test Accuracy: 7.62%
#     Worker 0: Train Loss: 4.0773, Train Accuracy: 6.21%
#     Worker 1: Train Loss: 4.0796, Train Accuracy: 5.79%
#     Worker 2: Train Loss: 4.0726, Train Accuracy: 6.29%
#     Worker 3: Train Loss: 4.0817, Train Accuracy: 6.38%
#     Worker 4: Train Loss: 4.1366, Train Accuracy: 6.00%
#     Worker 5: Train Loss: 4.1422, Train Accuracy: 5.95%
#     Worker 6: Train Loss: 4.0672, Train Accuracy: 6.16%
#     Worker 7: Train Loss: 4.1065, Train Accuracy: 6.05%
# Epoch 122/150: Test Loss: 4.0706, Test Accuracy: 7.05%
#     Worker 0: Train Loss: 4.0904, Train Accuracy: 5.94%
#     Worker 1: Train Loss: 4.1612, Train Accuracy: 4.85%
#     Worker 2: Train Loss: 4.0535, Train Accuracy: 6.80%
#     Worker 3: Train Loss: 4.1557, Train Accuracy: 5.71%
#     Worker 4: Train Loss: 4.0246, Train Accuracy: 6.80%
#     Worker 5: Train Loss: 4.0627, Train Accuracy: 6.53%
#     Worker 6: Train Loss: 4.0310, Train Accuracy: 6.93%
#     Worker 7: Train Loss: 4.1301, Train Accuracy: 5.31%
# Epoch 123/150: Test Loss: 4.0590, Test Accuracy: 7.43%
#     Worker 0: Train Loss: 4.1326, Train Accuracy: 5.71%
#     Worker 1: Train Loss: 4.2091, Train Accuracy: 4.88%
#     Worker 2: Train Loss: 4.0650, Train Accuracy: 7.06%
#     Worker 3: Train Loss: 4.1675, Train Accuracy: 5.68%
#     Worker 4: Train Loss: 4.1701, Train Accuracy: 5.44%
#     Worker 5: Train Loss: 4.0644, Train Accuracy: 6.85%
#     Worker 6: Train Loss: 4.1132, Train Accuracy: 5.86%
#     Worker 7: Train Loss: 4.1145, Train Accuracy: 6.05%
# Epoch 124/150: Test Loss: 4.0881, Test Accuracy: 7.09%
#     Worker 0: Train Loss: 4.1250, Train Accuracy: 6.43%
#     Worker 1: Train Loss: 4.1472, Train Accuracy: 5.50%
#     Worker 2: Train Loss: 4.1222, Train Accuracy: 6.26%
#     Worker 3: Train Loss: 4.1326, Train Accuracy: 5.92%
#     Worker 4: Train Loss: 4.1140, Train Accuracy: 6.90%
#     Worker 5: Train Loss: 4.0667, Train Accuracy: 7.36%
#     Worker 6: Train Loss: 4.1244, Train Accuracy: 5.47%
#     Worker 7: Train Loss: 4.0917, Train Accuracy: 6.56%
# Epoch 125/150: Test Loss: 4.0797, Test Accuracy: 7.63%
#     Worker 0: Train Loss: 4.1558, Train Accuracy: 5.47%
#     Worker 1: Train Loss: 4.1427, Train Accuracy: 5.84%
#     Worker 2: Train Loss: 4.1430, Train Accuracy: 5.86%
#     Worker 3: Train Loss: 4.1367, Train Accuracy: 5.76%
#     Worker 4: Train Loss: 4.1266, Train Accuracy: 6.21%
#     Worker 5: Train Loss: 4.0866, Train Accuracy: 6.85%
#     Worker 6: Train Loss: 4.1512, Train Accuracy: 6.21%
#     Worker 7: Train Loss: 4.1232, Train Accuracy: 6.11%
# Epoch 126/150: Test Loss: 4.0597, Test Accuracy: 7.94%
#     Worker 0: Train Loss: 4.1212, Train Accuracy: 6.42%
#     Worker 1: Train Loss: 4.1617, Train Accuracy: 6.08%
#     Worker 2: Train Loss: 4.1191, Train Accuracy: 6.58%
#     Worker 3: Train Loss: 4.1250, Train Accuracy: 6.02%
#     Worker 4: Train Loss: 4.1036, Train Accuracy: 7.09%
#     Worker 5: Train Loss: 4.0746, Train Accuracy: 7.25%
#     Worker 6: Train Loss: 4.1568, Train Accuracy: 5.89%
#     Worker 7: Train Loss: 4.1337, Train Accuracy: 6.42%
# Epoch 127/150: Test Loss: 4.0305, Test Accuracy: 8.51%
#     Worker 0: Train Loss: 4.0964, Train Accuracy: 6.91%
#     Worker 1: Train Loss: 4.1059, Train Accuracy: 6.11%
#     Worker 2: Train Loss: 4.0973, Train Accuracy: 6.80%
#     Worker 3: Train Loss: 4.1154, Train Accuracy: 5.87%
#     Worker 4: Train Loss: 4.0832, Train Accuracy: 6.38%
#     Worker 5: Train Loss: 4.0585, Train Accuracy: 7.44%
#     Worker 6: Train Loss: 4.1058, Train Accuracy: 6.78%
#     Worker 7: Train Loss: 4.1090, Train Accuracy: 6.42%
# Epoch 128/150: Test Loss: 4.0250, Test Accuracy: 7.77%
#     Worker 0: Train Loss: 4.0658, Train Accuracy: 6.70%
#     Worker 1: Train Loss: 4.0827, Train Accuracy: 6.43%
#     Worker 2: Train Loss: 4.0623, Train Accuracy: 7.10%
#     Worker 3: Train Loss: 4.0826, Train Accuracy: 6.59%
#     Worker 4: Train Loss: 4.0293, Train Accuracy: 7.73%
#     Worker 5: Train Loss: 4.0271, Train Accuracy: 7.55%
#     Worker 6: Train Loss: 4.0674, Train Accuracy: 7.23%
#     Worker 7: Train Loss: 4.0664, Train Accuracy: 7.33%
# Epoch 129/150: Test Loss: 4.0299, Test Accuracy: 7.91%
#     Worker 0: Train Loss: 4.0722, Train Accuracy: 6.37%
#     Worker 1: Train Loss: 4.0616, Train Accuracy: 6.51%
#     Worker 2: Train Loss: 4.0830, Train Accuracy: 6.54%
#     Worker 3: Train Loss: 4.1204, Train Accuracy: 6.22%
#     Worker 4: Train Loss: 4.1113, Train Accuracy: 6.29%
#     Worker 5: Train Loss: 4.0177, Train Accuracy: 7.62%
#     Worker 6: Train Loss: 4.0542, Train Accuracy: 6.56%
#     Worker 7: Train Loss: 4.0604, Train Accuracy: 6.99%
# Epoch 130/150: Test Loss: 4.0271, Test Accuracy: 7.63%
#     Worker 0: Train Loss: 4.0721, Train Accuracy: 6.58%
#     Worker 1: Train Loss: 4.0689, Train Accuracy: 6.26%
#     Worker 2: Train Loss: 4.0719, Train Accuracy: 6.27%
#     Worker 3: Train Loss: 4.0939, Train Accuracy: 6.19%
#     Worker 4: Train Loss: 4.0612, Train Accuracy: 6.75%
#     Worker 5: Train Loss: 4.0485, Train Accuracy: 6.83%
#     Worker 6: Train Loss: 4.0558, Train Accuracy: 6.96%
#     Worker 7: Train Loss: 4.0703, Train Accuracy: 6.32%
# Epoch 131/150: Test Loss: 4.0136, Test Accuracy: 7.86%
#     Worker 0: Train Loss: 4.0678, Train Accuracy: 6.83%
#     Worker 1: Train Loss: 4.0593, Train Accuracy: 6.75%
#     Worker 2: Train Loss: 4.0748, Train Accuracy: 6.69%
#     Worker 3: Train Loss: 4.0695, Train Accuracy: 6.67%
#     Worker 4: Train Loss: 4.0434, Train Accuracy: 6.99%
#     Worker 5: Train Loss: 4.0222, Train Accuracy: 7.73%
#     Worker 6: Train Loss: 4.0507, Train Accuracy: 6.88%
#     Worker 7: Train Loss: 4.0488, Train Accuracy: 6.91%
# Epoch 132/150: Test Loss: 3.9981, Test Accuracy: 7.86%
#     Worker 0: Train Loss: 4.0513, Train Accuracy: 7.01%
#     Worker 1: Train Loss: 4.0929, Train Accuracy: 6.40%
#     Worker 2: Train Loss: 4.0870, Train Accuracy: 6.82%
#     Worker 3: Train Loss: 4.0976, Train Accuracy: 6.08%
#     Worker 4: Train Loss: 4.0248, Train Accuracy: 7.28%
#     Worker 5: Train Loss: 4.0068, Train Accuracy: 7.46%
#     Worker 6: Train Loss: 4.0407, Train Accuracy: 7.25%
#     Worker 7: Train Loss: 4.0398, Train Accuracy: 6.93%
# Epoch 133/150: Test Loss: 3.9829, Test Accuracy: 7.99%
#     Worker 0: Train Loss: 4.0624, Train Accuracy: 6.45%
#     Worker 1: Train Loss: 4.0317, Train Accuracy: 6.53%
#     Worker 2: Train Loss: 4.0325, Train Accuracy: 7.01%
#     Worker 3: Train Loss: 4.0433, Train Accuracy: 6.93%
#     Worker 4: Train Loss: 3.9977, Train Accuracy: 7.14%
#     Worker 5: Train Loss: 4.0026, Train Accuracy: 7.33%
#     Worker 6: Train Loss: 4.0255, Train Accuracy: 7.01%
#     Worker 7: Train Loss: 4.0311, Train Accuracy: 6.77%
# Epoch 134/150: Test Loss: 3.9921, Test Accuracy: 7.51%
#     Worker 0: Train Loss: 4.0918, Train Accuracy: 5.82%
#     Worker 1: Train Loss: 4.0231, Train Accuracy: 6.56%
#     Worker 2: Train Loss: 4.0378, Train Accuracy: 7.04%
#     Worker 3: Train Loss: 4.0357, Train Accuracy: 6.93%
#     Worker 4: Train Loss: 4.0124, Train Accuracy: 6.94%
#     Worker 5: Train Loss: 4.0297, Train Accuracy: 7.68%
#     Worker 6: Train Loss: 4.0689, Train Accuracy: 6.96%
#     Worker 7: Train Loss: 4.1230, Train Accuracy: 5.95%
# Epoch 135/150: Test Loss: 3.9877, Test Accuracy: 7.85%
#     Worker 0: Train Loss: 4.0447, Train Accuracy: 6.43%
#     Worker 1: Train Loss: 4.0812, Train Accuracy: 5.68%
#     Worker 2: Train Loss: 4.0481, Train Accuracy: 7.02%
#     Worker 3: Train Loss: 4.0610, Train Accuracy: 6.67%
#     Worker 4: Train Loss: 3.9956, Train Accuracy: 7.10%
#     Worker 5: Train Loss: 4.0120, Train Accuracy: 7.20%
#     Worker 6: Train Loss: 4.0642, Train Accuracy: 6.54%
#     Worker 7: Train Loss: 4.0420, Train Accuracy: 6.78%
# Epoch 136/150: Test Loss: 3.9944, Test Accuracy: 7.85%
#     Worker 0: Train Loss: 4.0329, Train Accuracy: 6.96%
#     Worker 1: Train Loss: 4.0378, Train Accuracy: 6.50%
#     Worker 2: Train Loss: 4.0294, Train Accuracy: 6.64%
#     Worker 3: Train Loss: 4.0354, Train Accuracy: 6.26%
#     Worker 4: Train Loss: 3.9900, Train Accuracy: 7.20%
#     Worker 5: Train Loss: 3.9953, Train Accuracy: 7.60%
#     Worker 6: Train Loss: 4.0788, Train Accuracy: 6.03%
#     Worker 7: Train Loss: 4.0200, Train Accuracy: 6.82%
# Epoch 137/150: Test Loss: 3.9831, Test Accuracy: 7.93%
#     Worker 0: Train Loss: 4.0375, Train Accuracy: 6.78%
#     Worker 1: Train Loss: 4.0184, Train Accuracy: 6.94%
#     Worker 2: Train Loss: 4.0236, Train Accuracy: 7.06%
#     Worker 3: Train Loss: 4.0292, Train Accuracy: 6.74%
#     Worker 4: Train Loss: 3.9929, Train Accuracy: 7.46%
#     Worker 5: Train Loss: 3.9920, Train Accuracy: 7.82%
#     Worker 6: Train Loss: 4.0479, Train Accuracy: 7.10%
#     Worker 7: Train Loss: 4.0247, Train Accuracy: 6.83%
# Epoch 138/150: Test Loss: 3.9694, Test Accuracy: 8.27%
#     Worker 0: Train Loss: 4.0234, Train Accuracy: 7.42%
#     Worker 1: Train Loss: 4.0084, Train Accuracy: 7.23%
#     Worker 2: Train Loss: 4.0225, Train Accuracy: 7.23%
#     Worker 3: Train Loss: 4.0151, Train Accuracy: 7.50%
#     Worker 4: Train Loss: 4.0006, Train Accuracy: 7.74%
#     Worker 5: Train Loss: 3.9828, Train Accuracy: 7.60%
#     Worker 6: Train Loss: 4.0127, Train Accuracy: 7.34%
#     Worker 7: Train Loss: 4.0045, Train Accuracy: 7.02%
# Epoch 139/150: Test Loss: 3.9613, Test Accuracy: 8.85%
#     Worker 0: Train Loss: 4.0048, Train Accuracy: 8.37%
#     Worker 1: Train Loss: 4.0013, Train Accuracy: 7.54%
#     Worker 2: Train Loss: 4.0034, Train Accuracy: 7.98%
#     Worker 3: Train Loss: 4.0078, Train Accuracy: 7.12%
#     Worker 4: Train Loss: 3.9767, Train Accuracy: 8.30%
#     Worker 5: Train Loss: 3.9765, Train Accuracy: 8.29%
#     Worker 6: Train Loss: 3.9979, Train Accuracy: 7.78%
#     Worker 7: Train Loss: 4.0045, Train Accuracy: 7.23%
# Epoch 140/150: Test Loss: 3.9494, Test Accuracy: 9.04%
#     Worker 0: Train Loss: 3.9994, Train Accuracy: 7.70%
#     Worker 1: Train Loss: 3.9980, Train Accuracy: 7.86%
#     Worker 2: Train Loss: 3.9984, Train Accuracy: 8.13%
#     Worker 3: Train Loss: 4.0073, Train Accuracy: 7.47%
#     Worker 4: Train Loss: 3.9680, Train Accuracy: 8.27%
#     Worker 5: Train Loss: 3.9706, Train Accuracy: 8.18%
#     Worker 6: Train Loss: 3.9972, Train Accuracy: 7.62%
#     Worker 7: Train Loss: 4.0044, Train Accuracy: 7.55%
# Epoch 141/150: Test Loss: 3.9390, Test Accuracy: 8.92%
#     Worker 0: Train Loss: 3.9903, Train Accuracy: 7.73%
#     Worker 1: Train Loss: 3.9852, Train Accuracy: 8.19%
#     Worker 2: Train Loss: 3.9872, Train Accuracy: 8.13%
#     Worker 3: Train Loss: 4.0055, Train Accuracy: 7.23%
#     Worker 4: Train Loss: 3.9550, Train Accuracy: 7.95%
#     Worker 5: Train Loss: 3.9566, Train Accuracy: 8.02%
#     Worker 6: Train Loss: 3.9836, Train Accuracy: 8.32%
#     Worker 7: Train Loss: 3.9863, Train Accuracy: 7.63%
# Epoch 142/150: Test Loss: 3.9400, Test Accuracy: 8.48%
#     Worker 0: Train Loss: 3.9810, Train Accuracy: 7.52%
#     Worker 1: Train Loss: 3.9843, Train Accuracy: 7.38%
#     Worker 2: Train Loss: 3.9701, Train Accuracy: 8.45%
#     Worker 3: Train Loss: 3.9880, Train Accuracy: 7.23%
#     Worker 4: Train Loss: 3.9458, Train Accuracy: 8.14%
#     Worker 5: Train Loss: 3.9471, Train Accuracy: 8.32%
#     Worker 6: Train Loss: 3.9636, Train Accuracy: 7.94%
#     Worker 7: Train Loss: 3.9867, Train Accuracy: 7.42%
# Epoch 143/150: Test Loss: 3.9376, Test Accuracy: 8.50%
#     Worker 0: Train Loss: 3.9822, Train Accuracy: 7.66%
#     Worker 1: Train Loss: 3.9798, Train Accuracy: 7.50%
#     Worker 2: Train Loss: 3.9819, Train Accuracy: 7.97%
#     Worker 3: Train Loss: 4.0017, Train Accuracy: 7.06%
#     Worker 4: Train Loss: 3.9517, Train Accuracy: 7.66%
#     Worker 5: Train Loss: 3.9471, Train Accuracy: 7.87%
#     Worker 6: Train Loss: 3.9588, Train Accuracy: 7.57%
#     Worker 7: Train Loss: 3.9731, Train Accuracy: 7.76%
# Epoch 144/150: Test Loss: 3.9327, Test Accuracy: 8.67%
#     Worker 0: Train Loss: 3.9769, Train Accuracy: 7.26%
#     Worker 1: Train Loss: 3.9655, Train Accuracy: 7.62%
#     Worker 2: Train Loss: 3.9637, Train Accuracy: 8.22%
#     Worker 3: Train Loss: 4.0025, Train Accuracy: 7.22%
#     Worker 4: Train Loss: 3.9377, Train Accuracy: 8.18%
#     Worker 5: Train Loss: 3.9398, Train Accuracy: 8.26%
#     Worker 6: Train Loss: 3.9574, Train Accuracy: 7.73%
#     Worker 7: Train Loss: 3.9824, Train Accuracy: 7.22%
# Epoch 145/150: Test Loss: 3.9337, Test Accuracy: 8.92%
#     Worker 0: Train Loss: 3.9833, Train Accuracy: 7.42%
#     Worker 1: Train Loss: 3.9658, Train Accuracy: 7.84%
#     Worker 2: Train Loss: 3.9586, Train Accuracy: 8.46%
#     Worker 3: Train Loss: 3.9816, Train Accuracy: 7.55%
#     Worker 4: Train Loss: 3.9340, Train Accuracy: 8.21%
#     Worker 5: Train Loss: 3.9326, Train Accuracy: 8.56%
#     Worker 6: Train Loss: 3.9567, Train Accuracy: 8.05%
#     Worker 7: Train Loss: 3.9690, Train Accuracy: 7.31%
# Epoch 146/150: Test Loss: 3.9368, Test Accuracy: 8.85%
#     Worker 0: Train Loss: 3.9733, Train Accuracy: 7.82%
#     Worker 1: Train Loss: 3.9666, Train Accuracy: 7.79%
#     Worker 2: Train Loss: 3.9720, Train Accuracy: 8.34%
#     Worker 3: Train Loss: 3.9753, Train Accuracy: 7.52%
#     Worker 4: Train Loss: 3.9304, Train Accuracy: 8.14%
#     Worker 5: Train Loss: 3.9379, Train Accuracy: 8.61%
#     Worker 6: Train Loss: 3.9624, Train Accuracy: 7.98%
#     Worker 7: Train Loss: 3.9714, Train Accuracy: 7.84%
# Epoch 147/150: Test Loss: 3.9347, Test Accuracy: 8.80%
#     Worker 0: Train Loss: 3.9733, Train Accuracy: 8.19%
#     Worker 1: Train Loss: 3.9587, Train Accuracy: 8.30%
#     Worker 2: Train Loss: 3.9689, Train Accuracy: 8.24%
#     Worker 3: Train Loss: 3.9778, Train Accuracy: 7.62%
#     Worker 4: Train Loss: 3.9234, Train Accuracy: 8.53%
#     Worker 5: Train Loss: 3.9377, Train Accuracy: 8.42%
#     Worker 6: Train Loss: 3.9513, Train Accuracy: 8.43%
#     Worker 7: Train Loss: 3.9686, Train Accuracy: 7.63%
# Epoch 148/150: Test Loss: 3.9298, Test Accuracy: 8.93%
#     Worker 0: Train Loss: 3.9709, Train Accuracy: 7.54%
#     Worker 1: Train Loss: 3.9588, Train Accuracy: 8.03%
#     Worker 2: Train Loss: 3.9635, Train Accuracy: 8.22%
#     Worker 3: Train Loss: 3.9715, Train Accuracy: 7.89%
#     Worker 4: Train Loss: 3.9293, Train Accuracy: 8.66%
#     Worker 5: Train Loss: 3.9311, Train Accuracy: 8.98%
#     Worker 6: Train Loss: 3.9498, Train Accuracy: 8.00%
#     Worker 7: Train Loss: 3.9554, Train Accuracy: 8.22%
# Epoch 149/150: Test Loss: 3.9280, Test Accuracy: 8.98%
#     Worker 0: Train Loss: 3.9632, Train Accuracy: 7.95%
#     Worker 1: Train Loss: 3.9553, Train Accuracy: 8.40%
#     Worker 2: Train Loss: 3.9574, Train Accuracy: 8.02%
#     Worker 3: Train Loss: 3.9758, Train Accuracy: 7.54%
#     Worker 4: Train Loss: 3.9169, Train Accuracy: 8.45%
#     Worker 5: Train Loss: 3.9301, Train Accuracy: 9.49%
#     Worker 6: Train Loss: 3.9522, Train Accuracy: 8.61%
#     Worker 7: Train Loss: 3.9606, Train Accuracy: 8.13%
# Epoch 150/150: Test Loss: 3.9271, Test Accuracy: 8.95%
#     Worker 0: Train Loss: 3.9646, Train Accuracy: 7.76%
#     Worker 1: Train Loss: 3.9560, Train Accuracy: 8.58%
#     Worker 2: Train Loss: 3.9623, Train Accuracy: 8.45%
#     Worker 3: Train Loss: 3.9707, Train Accuracy: 7.92%
#     Worker 4: Train Loss: 3.9198, Train Accuracy: 8.90%
#     Worker 5: Train Loss: 3.9258, Train Accuracy: 9.02%
#     Worker 6: Train Loss: 3.9546, Train Accuracy: 8.32%
#     Worker 7: Train Loss: 3.9534, Train Accuracy: 7.84%
