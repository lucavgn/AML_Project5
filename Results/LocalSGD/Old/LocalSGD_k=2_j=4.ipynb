# %%
# %%writefile localSGD.py

import os
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
num_epochs = 150
base_learning_rate = 1e-2
momentum = 0.9
weight_decay = 4e-4
warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std

class LRScheduler(torch.optim.lr_scheduler._LRScheduler):
    def __init__(self, optimizer, base_lr, K, warmup_epochs, total_epochs, verbose=False):
        """
        Args:
            optimizer: SGD
            base_lr: Base learning rate for the reference batch size.
            K: Number of workers.
            warmup_epochs: Number of warmup epochs.
            total_epochs: Total number of epochs.
            verbose: Whether to print LR updates.
        """
        self.base_lr = base_lr
        self.K = K
        self.scaled_lr = base_lr * K
        self.warmup_epochs = warmup_epochs
        self.total_epochs = total_epochs
        self.verbose = verbose
        super(LRScheduler, self).__init__(optimizer)

    def get_lr(self):
        epoch = self.last_epoch
        if epoch < self.warmup_epochs:
            # Linear warmup scaling
            warmup_factor = (epoch + 1) / self.warmup_epochs
            return [warmup_factor * self.scaled_lr for _ in self.optimizer.param_groups]
        else:
            # polynomially decaying learning rate of ηt = η0×(1−t/T)
            if epoch == self.warmup_epochs:
                print(f"Warmup phase completed at epoch {epoch}. Switching to polynomial decay learning rate.")
            return [self.scaled_lr * ( 1 - ( (epoch - self.warmup_epochs) / (self.total_epochs - self.warmup_epochs))) for _ in self.optimizer.param_groups]


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]

# Batch size
batch_size = shard_size // J

# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)


# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [LRScheduler(
    optimizer = optimizer,
    base_lr = base_learning_rate,
    K = K,
    warmup_epochs = warmup_epochs,
    total_epochs = num_epochs,
    verbose = True) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}")

    # Sequentially train each worker to simulate a distributed environment
    for k in range(K):
        shard_loader = DataLoader(shards[k], batch_size=batch_size, shuffle=True)

        nets[k].train()
        correct_train, total_train, train_loss = 0, 0, 0.0
        for images, labels in shard_loader:
            images, labels = images.to(device), labels.to(device)  # Move to device
            optimizers[k].zero_grad()
            outputs = nets[k](images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizers[k].step()
            # Calculate train loss and accuracy
            train_loss += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            total_train += labels.size(0)
            correct_train += predicted.eq(labels).sum().item()
        # Store train loss and accuracy for this worker
        train_loss /= len(shard_loader.dataset)
        train_losses_per_worker[k].append(train_loss)
        train_accuracy = 100. * correct_train / total_train
        train_accuracies_per_worker[k].append(train_accuracy)

    # Perform model synchronization
    with torch.no_grad():
        global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
        for net in nets:
            for global_param, local_param in zip(global_parameters, net.parameters()):
                global_param += local_param
        for global_param in global_parameters:
            global_param /= K
        # Update each worker model with the global parameters
        for net in nets:
            for local_param, global_param in zip(net.parameters(), global_parameters):
                local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        scheduler.step()

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Overwriting localSGD.py

# %%
# %run localSGD.py --k 2 --j 4
# Out:
# Training with K=2, J=4
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0
#     Worker 1: Train Loss: 3.5789, Train Accuracy: 16.07%
# Epoch 76/150: Test Loss: 3.5276, Test Accuracy: 17.20%
#     Worker 0: Train Loss: 3.5949, Train Accuracy: 15.75%
#     Worker 1: Train Loss: 3.5718, Train Accuracy: 16.16%
# Epoch 77/150: Test Loss: 3.5209, Test Accuracy: 17.47%
#     Worker 0: Train Loss: 3.5819, Train Accuracy: 16.33%
#     Worker 1: Train Loss: 3.5690, Train Accuracy: 16.28%
# Epoch 78/150: Test Loss: 3.5153, Test Accuracy: 17.63%
#     Worker 0: Train Loss: 3.5726, Train Accuracy: 16.29%
#     Worker 1: Train Loss: 3.5540, Train Accuracy: 16.73%
# Epoch 79/150: Test Loss: 3.5008, Test Accuracy: 17.78%
#     Worker 0: Train Loss: 3.5648, Train Accuracy: 16.48%
#     Worker 1: Train Loss: 3.5406, Train Accuracy: 16.76%
# Epoch 80/150: Test Loss: 3.4985, Test Accuracy: 17.97%
#     Worker 0: Train Loss: 3.5563, Train Accuracy: 16.72%
#     Worker 1: Train Loss: 3.5383, Train Accuracy: 16.90%
# Epoch 81/150: Test Loss: 3.4891, Test Accuracy: 17.90%
#     Worker 0: Train Loss: 3.5564, Train Accuracy: 16.42%
#     Worker 1: Train Loss: 3.5310, Train Accuracy: 17.03%
# Epoch 82/150: Test Loss: 3.4856, Test Accuracy: 18.08%
#     Worker 0: Train Loss: 3.5455, Train Accuracy: 16.75%
#     Worker 1: Train Loss: 3.5279, Train Accuracy: 17.23%
# Epoch 83/150: Test Loss: 3.4714, Test Accuracy: 18.63%
#     Worker 0: Train Loss: 3.5370, Train Accuracy: 16.76%
#     Worker 1: Train Loss: 3.5152, Train Accuracy: 17.29%
# Epoch 84/150: Test Loss: 3.4714, Test Accuracy: 18.74%
#     Worker 0: Train Loss: 3.5285, Train Accuracy: 17.17%
#     Worker 1: Train Loss: 3.5076, Train Accuracy: 17.33%
# Epoch 85/150: Test Loss: 3.4679, Test Accuracy: 18.48%
#     Worker 0: Train Loss: 3.5227, Train Accuracy: 17.18%
#     Worker 1: Train Loss: 3.5030, Train Accuracy: 17.68%
# Epoch 86/150: Test Loss: 3.4560, Test Accuracy: 18.81%
#     Worker 0: Train Loss: 3.5122, Train Accuracy: 17.44%
#     Worker 1: Train Loss: 3.4950, Train Accuracy: 17.60%
# Epoch 87/150: Test Loss: 3.4462, Test Accuracy: 18.82%
#     Worker 0: Train Loss: 3.5149, Train Accuracy: 16.88%
#     Worker 1: Train Loss: 3.4877, Train Accuracy: 17.81%
# Epoch 88/150: Test Loss: 3.4356, Test Accuracy: 19.12%
#     Worker 0: Train Loss: 3.5070, Train Accuracy: 17.40%
#     Worker 1: Train Loss: 3.4853, Train Accuracy: 17.85%
# Epoch 89/150: Test Loss: 3.4401, Test Accuracy: 19.03%
#     Worker 0: Train Loss: 3.5042, Train Accuracy: 17.20%
#     Worker 1: Train Loss: 3.4821, Train Accuracy: 17.83%
# Epoch 90/150: Test Loss: 3.4449, Test Accuracy: 18.90%
#     Worker 0: Train Loss: 3.4938, Train Accuracy: 17.74%
#     Worker 1: Train Loss: 3.4697, Train Accuracy: 17.96%
# Epoch 91/150: Test Loss: 3.4430, Test Accuracy: 18.75%
#     Worker 0: Train Loss: 3.4862, Train Accuracy: 17.76%
#     Worker 1: Train Loss: 3.4686, Train Accuracy: 18.04%
# Epoch 92/150: Test Loss: 3.4244, Test Accuracy: 19.29%
#     Worker 0: Train Loss: 3.4789, Train Accuracy: 17.62%
#     Worker 1: Train Loss: 3.4563, Train Accuracy: 18.18%
# Epoch 93/150: Test Loss: 3.4133, Test Accuracy: 19.47%
#     Worker 0: Train Loss: 3.4742, Train Accuracy: 17.76%
#     Worker 1: Train Loss: 3.4578, Train Accuracy: 18.17%
# Epoch 94/150: Test Loss: 3.4083, Test Accuracy: 19.37%
#     Worker 0: Train Loss: 3.4643, Train Accuracy: 18.20%
#     Worker 1: Train Loss: 3.4442, Train Accuracy: 18.67%
# Epoch 95/150: Test Loss: 3.3964, Test Accuracy: 19.85%
#     Worker 0: Train Loss: 3.4591, Train Accuracy: 18.05%
#     Worker 1: Train Loss: 3.4418, Train Accuracy: 18.53%
# Epoch 96/150: Test Loss: 3.4024, Test Accuracy: 19.66%
#     Worker 0: Train Loss: 3.4545, Train Accuracy: 18.34%
#     Worker 1: Train Loss: 3.4315, Train Accuracy: 18.60%
# Epoch 97/150: Test Loss: 3.3910, Test Accuracy: 19.73%
#     Worker 0: Train Loss: 3.4546, Train Accuracy: 18.44%
#     Worker 1: Train Loss: 3.4307, Train Accuracy: 18.71%
# Epoch 98/150: Test Loss: 3.3915, Test Accuracy: 19.76%
#     Worker 0: Train Loss: 3.4416, Train Accuracy: 18.53%
#     Worker 1: Train Loss: 3.4228, Train Accuracy: 18.88%
# Epoch 99/150: Test Loss: 3.3870, Test Accuracy: 19.81%
#     Worker 0: Train Loss: 3.4372, Train Accuracy: 18.52%
#     Worker 1: Train Loss: 3.4202, Train Accuracy: 19.02%
# Epoch 100/150: Test Loss: 3.3785, Test Accuracy: 20.26%
#     Worker 0: Train Loss: 3.4357, Train Accuracy: 18.38%
#     Worker 1: Train Loss: 3.4135, Train Accuracy: 19.01%
# Epoch 101/150: Test Loss: 3.3768, Test Accuracy: 20.12%
#     Worker 0: Train Loss: 3.4334, Train Accuracy: 18.57%
#     Worker 1: Train Loss: 3.4018, Train Accuracy: 19.38%
# Epoch 102/150: Test Loss: 3.3677, Test Accuracy: 20.26%
#     Worker 0: Train Loss: 3.4248, Train Accuracy: 18.57%
#     Worker 1: Train Loss: 3.4081, Train Accuracy: 19.30%
# Epoch 103/150: Test Loss: 3.3671, Test Accuracy: 20.30%
#     Worker 0: Train Loss: 3.4193, Train Accuracy: 18.84%
#     Worker 1: Train Loss: 3.3903, Train Accuracy: 19.38%
# Epoch 104/150: Test Loss: 3.3619, Test Accuracy: 20.35%
#     Worker 0: Train Loss: 3.4119, Train Accuracy: 19.11%
#     Worker 1: Train Loss: 3.3887, Train Accuracy: 19.56%
# Epoch 105/150: Test Loss: 3.3576, Test Accuracy: 20.26%
#     Worker 0: Train Loss: 3.4089, Train Accuracy: 19.03%
#     Worker 1: Train Loss: 3.3879, Train Accuracy: 19.60%
# Epoch 106/150: Test Loss: 3.3570, Test Accuracy: 20.42%
#     Worker 0: Train Loss: 3.3995, Train Accuracy: 19.18%
#     Worker 1: Train Loss: 3.3833, Train Accuracy: 19.73%
# Epoch 107/150: Test Loss: 3.3540, Test Accuracy: 20.22%
#     Worker 0: Train Loss: 3.4007, Train Accuracy: 19.30%
#     Worker 1: Train Loss: 3.3764, Train Accuracy: 19.81%
# Epoch 108/150: Test Loss: 3.3419, Test Accuracy: 20.62%
#     Worker 0: Train Loss: 3.3901, Train Accuracy: 19.21%
#     Worker 1: Train Loss: 3.3729, Train Accuracy: 19.63%
# Epoch 109/150: Test Loss: 3.3441, Test Accuracy: 20.70%
#     Worker 0: Train Loss: 3.3905, Train Accuracy: 19.51%
#     Worker 1: Train Loss: 3.3740, Train Accuracy: 19.76%
# Epoch 110/150: Test Loss: 3.3384, Test Accuracy: 20.53%
#     Worker 0: Train Loss: 3.3829, Train Accuracy: 19.65%
#     Worker 1: Train Loss: 3.3645, Train Accuracy: 19.55%
# Epoch 111/150: Test Loss: 3.3365, Test Accuracy: 20.69%
#     Worker 0: Train Loss: 3.3792, Train Accuracy: 19.72%
#     Worker 1: Train Loss: 3.3635, Train Accuracy: 19.76%
# Epoch 112/150: Test Loss: 3.3406, Test Accuracy: 20.87%
#     Worker 0: Train Loss: 3.3763, Train Accuracy: 19.50%
#     Worker 1: Train Loss: 3.3595, Train Accuracy: 19.78%
# Epoch 113/150: Test Loss: 3.3273, Test Accuracy: 20.96%
#     Worker 0: Train Loss: 3.3715, Train Accuracy: 19.70%
#     Worker 1: Train Loss: 3.3594, Train Accuracy: 20.06%
# Epoch 114/150: Test Loss: 3.3210, Test Accuracy: 21.04%
#     Worker 0: Train Loss: 3.3700, Train Accuracy: 19.61%
#     Worker 1: Train Loss: 3.3489, Train Accuracy: 20.04%
# Epoch 115/150: Test Loss: 3.3245, Test Accuracy: 20.93%
#     Worker 0: Train Loss: 3.3695, Train Accuracy: 19.84%
#     Worker 1: Train Loss: 3.3479, Train Accuracy: 20.15%
# Epoch 116/150: Test Loss: 3.3229, Test Accuracy: 20.97%
#     Worker 0: Train Loss: 3.3673, Train Accuracy: 19.70%
#     Worker 1: Train Loss: 3.3482, Train Accuracy: 20.39%
# Epoch 117/150: Test Loss: 3.3152, Test Accuracy: 21.20%
#     Worker 0: Train Loss: 3.3580, Train Accuracy: 20.15%
#     Worker 1: Train Loss: 3.3434, Train Accuracy: 20.48%
# Epoch 118/150: Test Loss: 3.3133, Test Accuracy: 20.95%
#     Worker 0: Train Loss: 3.3577, Train Accuracy: 19.84%
#     Worker 1: Train Loss: 3.3415, Train Accuracy: 20.21%
# Epoch 119/150: Test Loss: 3.3107, Test Accuracy: 21.24%
#     Worker 0: Train Loss: 3.3492, Train Accuracy: 20.17%
#     Worker 1: Train Loss: 3.3370, Train Accuracy: 20.29%
# Epoch 120/150: Test Loss: 3.3081, Test Accuracy: 21.47%
#     Worker 0: Train Loss: 3.3508, Train Accuracy: 20.08%
#     Worker 1: Train Loss: 3.3361, Train Accuracy: 20.56%
# Epoch 121/150: Test Loss: 3.2997, Test Accuracy: 21.48%
#     Worker 0: Train Loss: 3.3477, Train Accuracy: 19.91%
#     Worker 1: Train Loss: 3.3256, Train Accuracy: 20.54%
# Epoch 122/150: Test Loss: 3.2992, Test Accuracy: 21.32%
#     Worker 0: Train Loss: 3.3473, Train Accuracy: 20.14%
#     Worker 1: Train Loss: 3.3253, Train Accuracy: 20.85%
# Epoch 123/150: Test Loss: 3.3028, Test Accuracy: 21.26%
#     Worker 0: Train Loss: 3.3418, Train Accuracy: 20.46%
#     Worker 1: Train Loss: 3.3273, Train Accuracy: 20.61%
# Epoch 124/150: Test Loss: 3.2927, Test Accuracy: 21.66%
#     Worker 0: Train Loss: 3.3405, Train Accuracy: 20.41%
#     Worker 1: Train Loss: 3.3252, Train Accuracy: 20.73%
# Epoch 125/150: Test Loss: 3.2987, Test Accuracy: 21.47%
#     Worker 0: Train Loss: 3.3385, Train Accuracy: 20.21%
#     Worker 1: Train Loss: 3.3169, Train Accuracy: 20.64%
# Epoch 126/150: Test Loss: 3.2853, Test Accuracy: 21.83%
#     Worker 0: Train Loss: 3.3299, Train Accuracy: 20.63%
#     Worker 1: Train Loss: 3.3126, Train Accuracy: 20.68%
# Epoch 127/150: Test Loss: 3.2929, Test Accuracy: 21.52%
#     Worker 0: Train Loss: 3.3277, Train Accuracy: 20.46%
#     Worker 1: Train Loss: 3.3139, Train Accuracy: 21.05%
# Epoch 128/150: Test Loss: 3.2834, Test Accuracy: 21.82%
#     Worker 0: Train Loss: 3.3282, Train Accuracy: 20.89%
#     Worker 1: Train Loss: 3.3126, Train Accuracy: 21.26%
# Epoch 129/150: Test Loss: 3.2872, Test Accuracy: 21.55%
#     Worker 0: Train Loss: 3.3271, Train Accuracy: 20.33%
#     Worker 1: Train Loss: 3.3097, Train Accuracy: 21.16%
# Epoch 130/150: Test Loss: 3.2855, Test Accuracy: 21.58%
#     Worker 0: Train Loss: 3.3198, Train Accuracy: 20.52%
#     Worker 1: Train Loss: 3.3076, Train Accuracy: 20.90%
# Epoch 131/150: Test Loss: 3.2765, Test Accuracy: 21.92%
#     Worker 0: Train Loss: 3.3203, Train Accuracy: 20.76%
#     Worker 1: Train Loss: 3.3080, Train Accuracy: 21.24%
# Epoch 132/150: Test Loss: 3.2870, Test Accuracy: 21.72%
#     Worker 0: Train Loss: 3.3257, Train Accuracy: 20.63%
#     Worker 1: Train Loss: 3.3054, Train Accuracy: 21.14%
# Epoch 133/150: Test Loss: 3.2744, Test Accuracy: 21.88%
#     Worker 0: Train Loss: 3.3129, Train Accuracy: 21.06%
#     Worker 1: Train Loss: 3.2945, Train Accuracy: 21.45%
# Epoch 134/150: Test Loss: 3.2780, Test Accuracy: 21.96%
#     Worker 0: Train Loss: 3.3195, Train Accuracy: 20.58%
#     Worker 1: Train Loss: 3.2960, Train Accuracy: 21.23%
# Epoch 135/150: Test Loss: 3.2705, Test Accuracy: 21.93%
#     Worker 0: Train Loss: 3.3128, Train Accuracy: 20.79%
#     Worker 1: Train Loss: 3.2948, Train Accuracy: 21.16%
# Epoch 136/150: Test Loss: 3.2762, Test Accuracy: 21.73%
#     Worker 0: Train Loss: 3.3130, Train Accuracy: 20.58%
#     Worker 1: Train Loss: 3.2882, Train Accuracy: 21.42%
# Epoch 137/150: Test Loss: 3.2704, Test Accuracy: 22.11%
#     Worker 0: Train Loss: 3.3148, Train Accuracy: 20.70%
#     Worker 1: Train Loss: 3.2936, Train Accuracy: 21.67%
# Epoch 138/150: Test Loss: 3.2705, Test Accuracy: 21.96%
#     Worker 0: Train Loss: 3.3105, Train Accuracy: 20.78%
#     Worker 1: Train Loss: 3.2953, Train Accuracy: 21.33%
# Epoch 139/150: Test Loss: 3.2688, Test Accuracy: 21.96%
#     Worker 0: Train Loss: 3.3086, Train Accuracy: 20.93%
#     Worker 1: Train Loss: 3.2899, Train Accuracy: 21.52%
# Epoch 140/150: Test Loss: 3.2707, Test Accuracy: 21.96%
#     Worker 0: Train Loss: 3.3057, Train Accuracy: 20.92%
#     Worker 1: Train Loss: 3.2860, Train Accuracy: 21.42%
# Epoch 141/150: Test Loss: 3.2634, Test Accuracy: 22.13%
#     Worker 0: Train Loss: 3.3034, Train Accuracy: 21.01%
#     Worker 1: Train Loss: 3.2914, Train Accuracy: 21.46%
# Epoch 142/150: Test Loss: 3.2676, Test Accuracy: 21.94%
#     Worker 0: Train Loss: 3.3052, Train Accuracy: 20.94%
#     Worker 1: Train Loss: 3.2842, Train Accuracy: 21.37%
# Epoch 143/150: Test Loss: 3.2669, Test Accuracy: 21.99%
#     Worker 0: Train Loss: 3.3052, Train Accuracy: 21.13%
#     Worker 1: Train Loss: 3.2797, Train Accuracy: 21.75%
# Epoch 144/150: Test Loss: 3.2642, Test Accuracy: 22.02%
#     Worker 0: Train Loss: 3.3048, Train Accuracy: 21.03%
#     Worker 1: Train Loss: 3.2862, Train Accuracy: 21.56%
# Epoch 145/150: Test Loss: 3.2653, Test Accuracy: 21.97%
#     Worker 0: Train Loss: 3.3071, Train Accuracy: 20.83%
#     Worker 1: Train Loss: 3.2855, Train Accuracy: 21.41%
# Epoch 146/150: Test Loss: 3.2644, Test Accuracy: 21.96%
#     Worker 0: Train Loss: 3.3077, Train Accuracy: 20.72%
#     Worker 1: Train Loss: 3.2817, Train Accuracy: 21.42%
# Epoch 147/150: Test Loss: 3.2620, Test Accuracy: 22.07%
#     Worker 0: Train Loss: 3.2984, Train Accuracy: 21.13%
#     Worker 1: Train Loss: 3.2822, Train Accuracy: 21.52%
# Epoch 148/150: Test Loss: 3.2626, Test Accuracy: 22.00%
#     Worker 0: Train Loss: 3.3095, Train Accuracy: 20.76%
#     Worker 1: Train Loss: 3.2803, Train Accuracy: 21.51%
# Epoch 149/150: Test Loss: 3.2631, Test Accuracy: 21.96%
#     Worker 0: Train Loss: 3.3001, Train Accuracy: 20.78%
#     Worker 1: Train Loss: 3.2803, Train Accuracy: 21.59%
# Epoch 150/150: Test Loss: 3.2633, Test Accuracy: 21.96%
#     Worker 0: Train Loss: 3.3025, Train Accuracy: 20.93%
#     Worker 1: Train Loss: 3.2772, Train Accuracy: 21.65%
