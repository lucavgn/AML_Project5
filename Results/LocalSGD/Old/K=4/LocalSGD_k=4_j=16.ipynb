# %%
# %%writefile localSGD.py

import os
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
num_epochs = 150
base_learning_rate = 1e-2
momentum = 0.9
weight_decay = 4e-4
warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std

class LRScheduler(torch.optim.lr_scheduler._LRScheduler):
    def __init__(self, optimizer, base_lr, K, warmup_epochs, total_epochs, verbose=False):
        """
        Args:
            optimizer: SGD
            base_lr: Base learning rate for the reference batch size.
            K: Number of workers.
            warmup_epochs: Number of warmup epochs.
            total_epochs: Total number of epochs.
            verbose: Whether to print LR updates.
        """
        self.base_lr = base_lr
        self.K = K
        self.scaled_lr = base_lr * K
        self.warmup_epochs = warmup_epochs
        self.total_epochs = total_epochs
        self.verbose = verbose
        super(LRScheduler, self).__init__(optimizer)

    def get_lr(self):
        epoch = self.last_epoch
        if epoch < self.warmup_epochs:
            # Linear warmup scaling
            warmup_factor = (epoch + 1) / self.warmup_epochs
            return [warmup_factor * self.scaled_lr for _ in self.optimizer.param_groups]
        else:
            # polynomially decaying learning rate of ηt = η0×(1−t/T)
            if epoch == self.warmup_epochs:
                print(f"Warmup phase completed at epoch {epoch}. Switching to polynomial decay learning rate.")
            return [self.scaled_lr * ( 1 - ( (epoch - self.warmup_epochs) / (self.total_epochs - self.warmup_epochs))) for _ in self.optimizer.param_groups]


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]

# Batch size
batch_size = shard_size // J

# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)


# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [LRScheduler(
    optimizer = optimizer,
    base_lr = base_learning_rate,
    K = K,
    warmup_epochs = warmup_epochs,
    total_epochs = num_epochs,
    verbose = True) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}")

    # Sequentially train each worker to simulate a distributed environment
    for k in range(K):
        shard_loader = DataLoader(shards[k], batch_size=batch_size, shuffle=True)

        nets[k].train()
        correct_train, total_train, train_loss = 0, 0, 0.0
        for images, labels in shard_loader:
            images, labels = images.to(device), labels.to(device)  # Move to device
            optimizers[k].zero_grad()
            outputs = nets[k](images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizers[k].step()
            # Calculate train loss and accuracy
            train_loss += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            total_train += labels.size(0)
            correct_train += predicted.eq(labels).sum().item()
        # Store train loss and accuracy for this worker
        train_loss /= len(shard_loader.dataset)
        train_losses_per_worker[k].append(train_loss)
        train_accuracy = 100. * correct_train / total_train
        train_accuracies_per_worker[k].append(train_accuracy)

    # Perform model synchronization
    with torch.no_grad():
        global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
        for net in nets:
            for global_param, local_param in zip(global_parameters, net.parameters()):
                global_param += local_param
        for global_param in global_parameters:
            global_param /= K
        # Update each worker model with the global parameters
        for net in nets:
            for local_param, global_param in zip(net.parameters(), global_parameters):
                local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        scheduler.step()

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Overwriting localSGD.py

# %%
# %run localSGD.py --k 4 --j 16
# Out:
# Training with K=4, J=16
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.04000
# Epoch 1/150: Test Loss: 4.6049, Test Accuracy: 1.38%
#     Worker 0: Train Loss: 4.6057, Train Accuracy: 1.30%
#     Worker 1: Train Loss: 4.6058, Train Accuracy: 1.22%
#     Worker 2: Train Loss: 4.6049, Train Accuracy: 1.36%
#     Worker 3: Train Loss: 4.6060, Train Accuracy: 1.08%
# Epoch 2/150: Test Loss: 4.6016, Test Accuracy: 1.70%
#     Worker 0: Train Loss: 4.6035, Train Accuracy: 1.18%
#     Worker 1: Train Loss: 4.6041, Train Accuracy: 1.75%
#     Worker 2: Train Loss: 4.6027, Train Accuracy: 1.14%
#     Worker 3: Train Loss: 4.6043, Train Accuracy: 1.05%
# Epoch 3/150: Test Loss: 4.5930, Test Accuracy: 1.50%
#     Worker 0: Train Loss: 4.5997, Train Accuracy: 0.99%
#     Worker 1: Train Loss: 4.5995, Train Accuracy: 1.62%
#     Worker 2: Train Loss: 4.5983, Train Accuracy: 1.04%
#     Worker 3: Train Loss: 4.6008, Train Accuracy: 1.14%
# Epoch 4/150: Test Loss: 4.5630, Test Accuracy: 2.29%
#     Worker 0: Train Loss: 4.5913, Train Accuracy: 1.41%
#     Worker 1: Train Loss: 4.5838, Train Accuracy: 1.40%
#     Worker 2: Train Loss: 4.5837, Train Accuracy: 1.51%
#     Worker 3: Train Loss: 4.5869, Train Accuracy: 1.10%
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Epoch 5/150: Test Loss: 4.4645, Test Accuracy: 3.99%
#     Worker 0: Train Loss: 4.5333, Train Accuracy: 2.64%
#     Worker 1: Train Loss: 4.5440, Train Accuracy: 1.74%
#     Worker 2: Train Loss: 4.5486, Train Accuracy: 1.30%
#     Worker 3: Train Loss: 4.5533, Train Accuracy: 1.61%
# Epoch 6/150: Test Loss: 4.3689, Test Accuracy: 2.52%
#     Worker 0: Train Loss: 4.5161, Train Accuracy: 2.30%
#     Worker 1: Train Loss: 4.5052, Train Accuracy: 1.96%
#     Worker 2: Train Loss: 4.3908, Train Accuracy: 3.27%
#     Worker 3: Train Loss: 4.4495, Train Accuracy: 2.99%
# Epoch 7/150: Test Loss: 4.3055, Test Accuracy: 4.36%
#     Worker 0: Train Loss: 4.4587, Train Accuracy: 3.06%
#     Worker 0: Train Loss: 3.4092, Train Accuracy: 17.30%
#     Worker 1: Train Loss: 3.5558, Train Accuracy: 15.58%
#     Worker 2: Train Loss: 3.4822, Train Accuracy: 16.73%
#     Worker 3: Train Loss: 3.6535, Train Accuracy: 14.89%
# Epoch 44/150: Test Loss: 3.3704, Test Accuracy: 19.34%
#     Worker 0: Train Loss: 3.5811, Train Accuracy: 14.74%
#     Worker 1: Train Loss: 3.7853, Train Accuracy: 12.70%
#     Worker 2: Train Loss: 3.4196, Train Accuracy: 17.52%
#     Worker 3: Train Loss: 3.4331, Train Accuracy: 17.15%
# Epoch 45/150: Test Loss: 3.2669, Test Accuracy: 21.18%
#     Worker 0: Train Loss: 3.4574, Train Accuracy: 16.97%
#     Worker 1: Train Loss: 3.4746, Train Accuracy: 16.46%
#     Worker 2: Train Loss: 3.4020, Train Accuracy: 17.43%
#     Worker 3: Train Loss: 3.5168, Train Accuracy: 16.26%
# Epoch 46/150: Test Loss: 3.2355, Test Accuracy: 22.22%
#     Worker 0: Train Loss: 3.4997, Train Accuracy: 16.18%
#     Worker 1: Train Loss: 3.4236, Train Accuracy: 17.38%
#     Worker 2: Train Loss: 3.3295, Train Accuracy: 18.81%
#     Worker 3: Train Loss: 3.4490, Train Accuracy: 17.51%
# Epoch 47/150: Test Loss: 3.2414, Test Accuracy: 21.86%
#     Worker 0: Train Loss: 3.3766, Train Accuracy: 17.62%
#     Worker 1: Train Loss: 3.3774, Train Accuracy: 18.50%
#     Worker 2: Train Loss: 3.4654, Train Accuracy: 17.17%
#     Worker 3: Train Loss: 3.3556, Train Accuracy: 18.50%
# Epoch 48/150: Test Loss: 3.2156, Test Accuracy: 22.61%
#     Worker 0: Train Loss: 3.3585, Train Accuracy: 18.86%
#     Worker 1: Train Loss: 3.3257, Train Accuracy: 19.50%
#     Worker 2: Train Loss: 3.3962, Train Accuracy: 17.74%
#     Worker 3: Train Loss: 3.4830, Train Accuracy: 16.83%
# Epoch 49/150: Test Loss: 3.3225, Test Accuracy: 21.11%
#     Worker 0: Train Loss: 3.5831, Train Accuracy: 15.74%
#     Worker 1: Train Loss: 3.3270, Train Accuracy: 19.25%
#     Worker 2: Train Loss: 3.6224, Train Accuracy: 15.26%
#     Worker 3: Train Loss: 3.4754, Train Accuracy: 17.54%
# Epoch 50/150: Test Loss: 3.2244, Test Accuracy: 22.22%
#     Worker 0: Train Loss: 3.3835, Train Accuracy: 18.79%
#     Worker 1: Train Loss: 3.4294, Train Accuracy: 18.10%
#     Worker 2: Train Loss: 3.4493, Train Accuracy: 17.14%
#     Worker 3: Train Loss: 3.4060, Train Accuracy: 17.79%
# Epoch 51/150: Test Loss: 3.2076, Test Accuracy: 22.36%
#     Worker 0: Train Loss: 3.3198, Train Accuracy: 19.74%
#     Worker 1: Train Loss: 3.3785, Train Accuracy: 18.78%
#     Worker 2: Train Loss: 3.4504, Train Accuracy: 17.62%
#     Worker 3: Train Loss: 3.3190, Train Accuracy: 19.49%
# Epoch 52/150: Test Loss: 3.2491, Test Accuracy: 21.94%
#     Worker 0: Train Loss: 3.0303, Train Accuracy: 24.27%
#     Worker 1: Train Loss: 3.2423, Train Accuracy: 21.24%
#     Worker 2: Train Loss: 3.0872, Train Accuracy: 23.94%
#     Worker 3: Train Loss: 3.1649, Train Accuracy: 22.49%
# Epoch 71/150: Test Loss: 2.9038, Test Accuracy: 27.95%
#     Worker 0: Train Loss: 3.0589, Train Accuracy: 23.86%
#     Worker 1: Train Loss: 3.0852, Train Accuracy: 23.93%
#     Worker 2: Train Loss: 3.0422, Train Accuracy: 25.12%
#     Worker 3: Train Loss: 3.0400, Train Accuracy: 24.80%
# Epoch 72/150: Test Loss: 2.9255, Test Accuracy: 28.14%
#     Worker 0: Train Loss: 3.0235, Train Accuracy: 25.20%
#     Worker 1: Train Loss: 2.9968, Train Accuracy: 25.68%
#     Worker 2: Train Loss: 2.9888, Train Accuracy: 25.91%
#     Worker 3: Train Loss: 3.0720, Train Accuracy: 24.55%
# Epoch 73/150: Test Loss: 2.9111, Test Accuracy: 28.10%
#     Worker 0: Train Loss: 3.1092, Train Accuracy: 23.49%
#     Worker 1: Train Loss: 3.0527, Train Accuracy: 24.64%
#     Worker 2: Train Loss: 2.9278, Train Accuracy: 26.70%
#     Worker 3: Train Loss: 3.1329, Train Accuracy: 22.76%
# Epoch 74/150: Test Loss: 2.8660, Test Accuracy: 29.06%
#     Worker 0: Train Loss: 2.9662, Train Accuracy: 25.80%
#     Worker 1: Train Loss: 2.9935, Train Accuracy: 26.52%
#     Worker 2: Train Loss: 2.9573, Train Accuracy: 25.78%
#     Worker 3: Train Loss: 3.0807, Train Accuracy: 24.16%
# Epoch 75/150: Test Loss: 2.8832, Test Accuracy: 28.76%
#     Worker 0: Train Loss: 2.9842, Train Accuracy: 25.78%
#     Worker 1: Train Loss: 2.9920, Train Accuracy: 25.67%
#     Worker 2: Train Loss: 2.9051, Train Accuracy: 26.94%
#     Worker 3: Train Loss: 3.1743, Train Accuracy: 22.71%
# Epoch 76/150: Test Loss: 2.9381, Test Accuracy: 28.24%
#     Worker 0: Train Loss: 3.2206, Train Accuracy: 22.62%
#     Worker 1: Train Loss: 3.1202, Train Accuracy: 23.30%
#     Worker 2: Train Loss: 3.0108, Train Accuracy: 25.15%
#     Worker 3: Train Loss: 2.9621, Train Accuracy: 25.90%
# Epoch 77/150: Test Loss: 2.9229, Test Accuracy: 28.15%
#     Worker 0: Train Loss: 3.3252, Train Accuracy: 20.58%
#     Worker 1: Train Loss: 2.9281, Train Accuracy: 27.06%
#     Worker 2: Train Loss: 3.0719, Train Accuracy: 24.02%
#     Worker 3: Train Loss: 2.9934, Train Accuracy: 25.52%
# Epoch 78/150: Test Loss: 2.8559, Test Accuracy: 28.56%
#     Worker 0: Train Loss: 2.9699, Train Accuracy: 25.93%
#     Worker 1: Train Loss: 2.9553, Train Accuracy: 26.36%
#     Worker 2: Train Loss: 2.9916, Train Accuracy: 25.66%
#     Worker 3: Train Loss: 3.0461, Train Accuracy: 24.94%
# Epoch 79/150: Test Loss: 2.8535, Test Accuracy: 29.11%
#     Worker 0: Train Loss: 2.9421, Train Accuracy: 26.42%
#     Worker 1: Train Loss: 3.0526, Train Accuracy: 25.10%
#     Worker 2: Train Loss: 2.9084, Train Accuracy: 26.87%
#     Worker 3: Train Loss: 2.8861, Train Accuracy: 27.57%
# Epoch 80/150: Test Loss: 2.8283, Test Accuracy: 29.45%
#     Worker 0: Train Loss: 2.9198, Train Accuracy: 27.06%
#     Worker 1: Train Loss: 2.9225, Train Accuracy: 27.34%
#     Worker 2: Train Loss: 2.9358, Train Accuracy: 26.51%
#     Worker 3: Train Loss: 3.0698, Train Accuracy: 24.28%
# Epoch 81/150: Test Loss: 2.8638, Test Accuracy: 28.77%
#     Worker 0: Train Loss: 2.9725, Train Accuracy: 26.18%
#     Worker 1: Train Loss: 3.0527, Train Accuracy: 24.88%
#     Worker 2: Train Loss: 2.9851, Train Accuracy: 25.86%
#     Worker 3: Train Loss: 2.9892, Train Accuracy: 25.90%
# Epoch 82/150: Test Loss: 2.8678, Test Accuracy: 28.64%
#     Worker 0: Train Loss: 2.9659, Train Accuracy: 26.42%
#     Worker 1: Train Loss: 2.9200, Train Accuracy: 27.24%
#     Worker 2: Train Loss: 3.1079, Train Accuracy: 23.78%
#     Worker 3: Train Loss: 2.9825, Train Accuracy: 26.22%
# Epoch 83/150: Test Loss: 2.7959, Test Accuracy: 30.17%
#     Worker 0: Train Loss: 2.9064, Train Accuracy: 27.26%
#     Worker 1: Train Loss: 2.9356, Train Accuracy: 26.52%
#     Worker 2: Train Loss: 2.9367, Train Accuracy: 26.53%
#     Worker 3: Train Loss: 2.8832, Train Accuracy: 27.35%
# Epoch 84/150: Test Loss: 2.8502, Test Accuracy: 29.90%
#     Worker 0: Train Loss: 2.9423, Train Accuracy: 26.27%
#     Worker 1: Train Loss: 2.8564, Train Accuracy: 28.33%
#     Worker 2: Train Loss: 2.9752, Train Accuracy: 26.47%
#     Worker 3: Train Loss: 3.0235, Train Accuracy: 25.81%
# Epoch 85/150: Test Loss: 2.7939, Test Accuracy: 30.67%
#     Worker 0: Train Loss: 2.9567, Train Accuracy: 26.91%
#     Worker 1: Train Loss: 2.9190, Train Accuracy: 27.02%
#     Worker 2: Train Loss: 3.0097, Train Accuracy: 26.10%
#     Worker 3: Train Loss: 2.9495, Train Accuracy: 26.45%
# Epoch 86/150: Test Loss: 2.7730, Test Accuracy: 30.82%
#     Worker 0: Train Loss: 2.9317, Train Accuracy: 26.71%
#     Worker 1: Train Loss: 2.9739, Train Accuracy: 26.54%
#     Worker 2: Train Loss: 2.8523, Train Accuracy: 28.34%
#     Worker 3: Train Loss: 2.8913, Train Accuracy: 27.66%
# Epoch 87/150: Test Loss: 2.7967, Test Accuracy: 30.32%
#     Worker 0: Train Loss: 2.8803, Train Accuracy: 27.34%
#     Worker 1: Train Loss: 2.9196, Train Accuracy: 27.22%
#     Worker 2: Train Loss: 2.9351, Train Accuracy: 27.18%
#     Worker 3: Train Loss: 2.9819, Train Accuracy: 26.39%
# Epoch 88/150: Test Loss: 2.7323, Test Accuracy: 31.76%
#     Worker 0: Train Loss: 2.8225, Train Accuracy: 28.94%
#     Worker 1: Train Loss: 2.9600, Train Accuracy: 26.32%
#     Worker 2: Train Loss: 2.8327, Train Accuracy: 29.26%
#     Worker 3: Train Loss: 2.8315, Train Accuracy: 28.17%
# Epoch 89/150: Test Loss: 2.7088, Test Accuracy: 32.07%
#     Worker 0: Train Loss: 2.7220, Train Accuracy: 30.94%
#     Worker 1: Train Loss: 2.7886, Train Accuracy: 29.86%
#     Worker 2: Train Loss: 2.8265, Train Accuracy: 29.82%
#     Worker 3: Train Loss: 2.8654, Train Accuracy: 27.84%
# Epoch 90/150: Test Loss: 2.7238, Test Accuracy: 31.74%
#     Worker 0: Train Loss: 2.8635, Train Accuracy: 27.84%
#     Worker 1: Train Loss: 2.7924, Train Accuracy: 29.80%
#     Worker 2: Train Loss: 2.8013, Train Accuracy: 29.46%
#     Worker 3: Train Loss: 2.7903, Train Accuracy: 29.63%
# Epoch 91/150: Test Loss: 2.7420, Test Accuracy: 32.15%
#     Worker 0: Train Loss: 2.9234, Train Accuracy: 27.62%
#     Worker 1: Train Loss: 2.8475, Train Accuracy: 28.48%
#     Worker 2: Train Loss: 2.9033, Train Accuracy: 27.92%
#     Worker 3: Train Loss: 2.9761, Train Accuracy: 26.10%
# Epoch 92/150: Test Loss: 2.7401, Test Accuracy: 31.60%
#     Worker 0: Train Loss: 2.9729, Train Accuracy: 26.70%
#     Worker 1: Train Loss: 2.7949, Train Accuracy: 29.71%
#     Worker 2: Train Loss: 2.7986, Train Accuracy: 29.70%
#     Worker 3: Train Loss: 2.8361, Train Accuracy: 28.36%
# Epoch 93/150: Test Loss: 2.7114, Test Accuracy: 32.42%
#     Worker 0: Train Loss: 2.7904, Train Accuracy: 29.38%
#     Worker 1: Train Loss: 2.7753, Train Accuracy: 30.07%
#     Worker 2: Train Loss: 2.8476, Train Accuracy: 28.78%
#     Worker 3: Train Loss: 2.7749, Train Accuracy: 29.84%
# Epoch 94/150: Test Loss: 2.7341, Test Accuracy: 31.57%
#     Worker 0: Train Loss: 3.0682, Train Accuracy: 24.41%
#     Worker 1: Train Loss: 2.8069, Train Accuracy: 29.21%
#     Worker 2: Train Loss: 2.7297, Train Accuracy: 31.02%
#     Worker 3: Train Loss: 2.7947, Train Accuracy: 29.42%
# Epoch 95/150: Test Loss: 2.7154, Test Accuracy: 32.41%
#     Worker 0: Train Loss: 2.8477, Train Accuracy: 27.94%
#     Worker 1: Train Loss: 2.8442, Train Accuracy: 28.38%
#     Worker 2: Train Loss: 2.8512, Train Accuracy: 28.78%
#     Worker 3: Train Loss: 2.9094, Train Accuracy: 28.10%
# Epoch 96/150: Test Loss: 2.6744, Test Accuracy: 33.15%
#     Worker 0: Train Loss: 2.8731, Train Accuracy: 28.13%
#     Worker 1: Train Loss: 2.7840, Train Accuracy: 29.89%
#     Worker 2: Train Loss: 2.7607, Train Accuracy: 30.28%
#     Worker 3: Train Loss: 2.9322, Train Accuracy: 27.01%
# Epoch 97/150: Test Loss: 2.6915, Test Accuracy: 32.76%
#     Worker 0: Train Loss: 2.7885, Train Accuracy: 29.99%
#     Worker 1: Train Loss: 2.8706, Train Accuracy: 27.63%
#     Worker 2: Train Loss: 2.7316, Train Accuracy: 30.86%
#     Worker 3: Train Loss: 2.7198, Train Accuracy: 31.12%
# Epoch 98/150: Test Loss: 2.6488, Test Accuracy: 33.19%
#     Worker 0: Train Loss: 2.7076, Train Accuracy: 30.60%
#     Worker 1: Train Loss: 2.8755, Train Accuracy: 28.74%
#     Worker 2: Train Loss: 2.6598, Train Accuracy: 32.71%
#     Worker 3: Train Loss: 2.7072, Train Accuracy: 31.73%
# Epoch 99/150: Test Loss: 2.6221, Test Accuracy: 34.23%
#     Worker 0: Train Loss: 2.6474, Train Accuracy: 32.18%
#     Worker 1: Train Loss: 2.8120, Train Accuracy: 29.06%
#     Worker 2: Train Loss: 2.7162, Train Accuracy: 31.45%
#     Worker 3: Train Loss: 2.6682, Train Accuracy: 31.66%
# Epoch 100/150: Test Loss: 2.6359, Test Accuracy: 33.42%
#     Worker 0: Train Loss: 2.6416, Train Accuracy: 32.30%
#     Worker 1: Train Loss: 2.6651, Train Accuracy: 32.14%
#     Worker 2: Train Loss: 2.6313, Train Accuracy: 32.86%
#     Worker 3: Train Loss: 2.8362, Train Accuracy: 29.33%
# Epoch 101/150: Test Loss: 2.6226, Test Accuracy: 33.40%
#     Worker 0: Train Loss: 2.7247, Train Accuracy: 30.58%
#     Worker 1: Train Loss: 2.7808, Train Accuracy: 29.70%
#     Worker 2: Train Loss: 2.6101, Train Accuracy: 33.55%
#     Worker 3: Train Loss: 2.8103, Train Accuracy: 29.68%
# Epoch 102/150: Test Loss: 2.6325, Test Accuracy: 33.56%
#     Worker 0: Train Loss: 2.6307, Train Accuracy: 32.62%
#     Worker 1: Train Loss: 2.6753, Train Accuracy: 32.06%
#     Worker 2: Train Loss: 2.8045, Train Accuracy: 30.04%
#     Worker 3: Train Loss: 2.6655, Train Accuracy: 32.04%
# Epoch 103/150: Test Loss: 2.6127, Test Accuracy: 34.32%
#     Worker 0: Train Loss: 2.7991, Train Accuracy: 29.33%
#     Worker 1: Train Loss: 2.6400, Train Accuracy: 32.78%
#     Worker 2: Train Loss: 2.6644, Train Accuracy: 32.30%
#     Worker 3: Train Loss: 2.7847, Train Accuracy: 29.50%
# Epoch 104/150: Test Loss: 2.5871, Test Accuracy: 34.95%
#     Worker 0: Train Loss: 2.7005, Train Accuracy: 31.33%
#     Worker 1: Train Loss: 2.6418, Train Accuracy: 32.99%
#     Worker 2: Train Loss: 2.6420, Train Accuracy: 32.12%
#     Worker 3: Train Loss: 2.6939, Train Accuracy: 31.37%
# Epoch 105/150: Test Loss: 2.5832, Test Accuracy: 34.71%
#     Worker 0: Train Loss: 2.7258, Train Accuracy: 30.30%
#     Worker 1: Train Loss: 2.6356, Train Accuracy: 32.53%
#     Worker 2: Train Loss: 2.6550, Train Accuracy: 32.16%
#     Worker 3: Train Loss: 2.6831, Train Accuracy: 31.93%
# Epoch 106/150: Test Loss: 2.5946, Test Accuracy: 34.56%
#     Worker 0: Train Loss: 2.7308, Train Accuracy: 30.41%
#     Worker 1: Train Loss: 2.6550, Train Accuracy: 32.26%
#     Worker 2: Train Loss: 2.6062, Train Accuracy: 33.53%
#     Worker 3: Train Loss: 2.7360, Train Accuracy: 31.16%
# Epoch 107/150: Test Loss: 2.6054, Test Accuracy: 34.46%
#     Worker 0: Train Loss: 2.5917, Train Accuracy: 33.25%
#     Worker 1: Train Loss: 2.6990, Train Accuracy: 31.41%
#     Worker 2: Train Loss: 2.6556, Train Accuracy: 32.32%
#     Worker 3: Train Loss: 2.8607, Train Accuracy: 28.76%
# Epoch 108/150: Test Loss: 2.5801, Test Accuracy: 34.55%
#     Worker 0: Train Loss: 2.5311, Train Accuracy: 34.53%
#     Worker 1: Train Loss: 2.6234, Train Accuracy: 32.44%
#     Worker 2: Train Loss: 2.6180, Train Accuracy: 33.62%
#     Worker 3: Train Loss: 2.6274, Train Accuracy: 32.58%
# Epoch 109/150: Test Loss: 2.5472, Test Accuracy: 35.23%
#     Worker 0: Train Loss: 2.5857, Train Accuracy: 33.87%
#     Worker 1: Train Loss: 2.6487, Train Accuracy: 32.24%
#     Worker 2: Train Loss: 2.5618, Train Accuracy: 34.01%
#     Worker 3: Train Loss: 2.6437, Train Accuracy: 32.47%
# Epoch 110/150: Test Loss: 2.5571, Test Accuracy: 34.98%
#     Worker 0: Train Loss: 2.5279, Train Accuracy: 34.62%
#     Worker 1: Train Loss: 2.6041, Train Accuracy: 33.27%
#     Worker 2: Train Loss: 2.6204, Train Accuracy: 33.44%
#     Worker 3: Train Loss: 2.7286, Train Accuracy: 31.26%
# Epoch 111/150: Test Loss: 2.5300, Test Accuracy: 35.67%
#     Worker 0: Train Loss: 2.6163, Train Accuracy: 33.05%
#     Worker 1: Train Loss: 2.5398, Train Accuracy: 34.62%
#     Worker 2: Train Loss: 2.6038, Train Accuracy: 33.07%
#     Worker 3: Train Loss: 2.5973, Train Accuracy: 32.71%
# Epoch 112/150: Test Loss: 2.5355, Test Accuracy: 35.33%
#     Worker 0: Train Loss: 2.6129, Train Accuracy: 32.59%
#     Worker 1: Train Loss: 2.5600, Train Accuracy: 34.25%
#     Worker 2: Train Loss: 2.6798, Train Accuracy: 32.09%
#     Worker 3: Train Loss: 2.5833, Train Accuracy: 33.90%
# Epoch 113/150: Test Loss: 2.5087, Test Accuracy: 36.16%
#     Worker 0: Train Loss: 2.4946, Train Accuracy: 35.15%
#     Worker 1: Train Loss: 2.5941, Train Accuracy: 33.42%
#     Worker 2: Train Loss: 2.5399, Train Accuracy: 34.40%
#     Worker 3: Train Loss: 2.5841, Train Accuracy: 33.51%
# Epoch 114/150: Test Loss: 2.5076, Test Accuracy: 35.91%
#     Worker 0: Train Loss: 2.5986, Train Accuracy: 33.62%
#     Worker 1: Train Loss: 2.5931, Train Accuracy: 33.69%
#     Worker 2: Train Loss: 2.5252, Train Accuracy: 34.94%
#     Worker 3: Train Loss: 2.6287, Train Accuracy: 32.70%
# Epoch 115/150: Test Loss: 2.5066, Test Accuracy: 36.37%
#     Worker 0: Train Loss: 2.5812, Train Accuracy: 33.14%
#     Worker 1: Train Loss: 2.5983, Train Accuracy: 33.23%
#     Worker 2: Train Loss: 2.5601, Train Accuracy: 34.51%
#     Worker 3: Train Loss: 2.5384, Train Accuracy: 34.57%
# Epoch 116/150: Test Loss: 2.5086, Test Accuracy: 36.35%
#     Worker 0: Train Loss: 2.5148, Train Accuracy: 34.61%
#     Worker 1: Train Loss: 2.5527, Train Accuracy: 34.16%
#     Worker 2: Train Loss: 2.5602, Train Accuracy: 34.42%
#     Worker 3: Train Loss: 2.5345, Train Accuracy: 34.21%
# Epoch 117/150: Test Loss: 2.4950, Test Accuracy: 36.37%
#     Worker 0: Train Loss: 2.5298, Train Accuracy: 34.45%
#     Worker 1: Train Loss: 2.6315, Train Accuracy: 32.49%
#     Worker 2: Train Loss: 2.5216, Train Accuracy: 35.03%
#     Worker 3: Train Loss: 2.5021, Train Accuracy: 34.94%
# Epoch 118/150: Test Loss: 2.5067, Test Accuracy: 36.24%
#     Worker 0: Train Loss: 2.4857, Train Accuracy: 35.16%
#     Worker 1: Train Loss: 2.5151, Train Accuracy: 35.10%
#     Worker 2: Train Loss: 2.6103, Train Accuracy: 33.70%
#     Worker 3: Train Loss: 2.5357, Train Accuracy: 34.34%
# Epoch 119/150: Test Loss: 2.5291, Test Accuracy: 35.62%
#     Worker 0: Train Loss: 2.6254, Train Accuracy: 33.11%
#     Worker 1: Train Loss: 2.5134, Train Accuracy: 35.33%
#     Worker 2: Train Loss: 2.5567, Train Accuracy: 34.45%
#     Worker 3: Train Loss: 2.5320, Train Accuracy: 34.50%
# Epoch 120/150: Test Loss: 2.5293, Test Accuracy: 35.69%
#     Worker 0: Train Loss: 2.7487, Train Accuracy: 30.88%
#     Worker 1: Train Loss: 2.6162, Train Accuracy: 33.18%
#     Worker 2: Train Loss: 2.5771, Train Accuracy: 34.15%
#     Worker 3: Train Loss: 2.5615, Train Accuracy: 33.91%
# Epoch 121/150: Test Loss: 2.4991, Test Accuracy: 36.61%
#     Worker 0: Train Loss: 2.5361, Train Accuracy: 34.37%
#     Worker 1: Train Loss: 2.5232, Train Accuracy: 35.32%
#     Worker 2: Train Loss: 2.5594, Train Accuracy: 34.15%
#     Worker 3: Train Loss: 2.5387, Train Accuracy: 34.94%
# Epoch 122/150: Test Loss: 2.4700, Test Accuracy: 37.02%
#     Worker 0: Train Loss: 2.5849, Train Accuracy: 33.54%
#     Worker 1: Train Loss: 2.5111, Train Accuracy: 34.93%
#     Worker 2: Train Loss: 2.5101, Train Accuracy: 35.47%
#     Worker 3: Train Loss: 2.4848, Train Accuracy: 36.11%
# Epoch 123/150: Test Loss: 2.4542, Test Accuracy: 37.40%
#     Worker 0: Train Loss: 2.6936, Train Accuracy: 31.22%
#     Worker 1: Train Loss: 2.4254, Train Accuracy: 37.18%
#     Worker 2: Train Loss: 2.4204, Train Accuracy: 37.91%
#     Worker 3: Train Loss: 2.4999, Train Accuracy: 35.17%
# Epoch 124/150: Test Loss: 2.4356, Test Accuracy: 38.04%
#     Worker 0: Train Loss: 2.5036, Train Accuracy: 34.88%
#     Worker 1: Train Loss: 2.4972, Train Accuracy: 35.19%
#     Worker 2: Train Loss: 2.4827, Train Accuracy: 35.78%
#     Worker 3: Train Loss: 2.4660, Train Accuracy: 35.94%
# Epoch 125/150: Test Loss: 2.4482, Test Accuracy: 37.50%
#     Worker 0: Train Loss: 2.5407, Train Accuracy: 33.91%
#     Worker 1: Train Loss: 2.4875, Train Accuracy: 35.45%
#     Worker 2: Train Loss: 2.4776, Train Accuracy: 36.14%
#     Worker 3: Train Loss: 2.4349, Train Accuracy: 36.47%
# Epoch 126/150: Test Loss: 2.4359, Test Accuracy: 37.61%
#     Worker 0: Train Loss: 2.4768, Train Accuracy: 35.97%
#     Worker 1: Train Loss: 2.5042, Train Accuracy: 35.67%
#     Worker 2: Train Loss: 2.4693, Train Accuracy: 36.48%
#     Worker 3: Train Loss: 2.4840, Train Accuracy: 35.54%
# Epoch 127/150: Test Loss: 2.4590, Test Accuracy: 37.20%
#     Worker 0: Train Loss: 2.4461, Train Accuracy: 36.09%
#     Worker 1: Train Loss: 2.4806, Train Accuracy: 35.65%
#     Worker 2: Train Loss: 2.4177, Train Accuracy: 36.87%
#     Worker 3: Train Loss: 2.4564, Train Accuracy: 36.26%
# Epoch 128/150: Test Loss: 2.4147, Test Accuracy: 38.19%
#     Worker 0: Train Loss: 2.4571, Train Accuracy: 35.94%
#     Worker 1: Train Loss: 2.4401, Train Accuracy: 36.92%
#     Worker 2: Train Loss: 2.4192, Train Accuracy: 37.53%
#     Worker 3: Train Loss: 2.4330, Train Accuracy: 37.14%
# Epoch 129/150: Test Loss: 2.4283, Test Accuracy: 37.99%
#     Worker 0: Train Loss: 2.4452, Train Accuracy: 36.25%
#     Worker 1: Train Loss: 2.4543, Train Accuracy: 36.96%
#     Worker 2: Train Loss: 2.4118, Train Accuracy: 37.86%
#     Worker 3: Train Loss: 2.4398, Train Accuracy: 36.70%
# Epoch 130/150: Test Loss: 2.4164, Test Accuracy: 38.00%
#     Worker 0: Train Loss: 2.4408, Train Accuracy: 36.66%
#     Worker 1: Train Loss: 2.4359, Train Accuracy: 37.39%
#     Worker 2: Train Loss: 2.4028, Train Accuracy: 37.94%
#     Worker 3: Train Loss: 2.4198, Train Accuracy: 37.02%
# Epoch 131/150: Test Loss: 2.4079, Test Accuracy: 38.31%
#     Worker 0: Train Loss: 2.4300, Train Accuracy: 36.86%
#     Worker 1: Train Loss: 2.4192, Train Accuracy: 37.45%
#     Worker 2: Train Loss: 2.3557, Train Accuracy: 38.87%
#     Worker 3: Train Loss: 2.3888, Train Accuracy: 37.72%
# Epoch 132/150: Test Loss: 2.4150, Test Accuracy: 38.08%
#     Worker 0: Train Loss: 2.4223, Train Accuracy: 36.48%
#     Worker 1: Train Loss: 2.4326, Train Accuracy: 36.96%
#     Worker 2: Train Loss: 2.4569, Train Accuracy: 36.38%
#     Worker 3: Train Loss: 2.4066, Train Accuracy: 37.54%
# Epoch 133/150: Test Loss: 2.3907, Test Accuracy: 38.74%
#     Worker 0: Train Loss: 2.3851, Train Accuracy: 37.20%
#     Worker 1: Train Loss: 2.3982, Train Accuracy: 38.14%
#     Worker 2: Train Loss: 2.3891, Train Accuracy: 38.68%
#     Worker 3: Train Loss: 2.4475, Train Accuracy: 37.10%
# Epoch 134/150: Test Loss: 2.3893, Test Accuracy: 38.56%
#     Worker 0: Train Loss: 2.3976, Train Accuracy: 37.35%
#     Worker 1: Train Loss: 2.3653, Train Accuracy: 38.33%
#     Worker 2: Train Loss: 2.4066, Train Accuracy: 37.80%
#     Worker 3: Train Loss: 2.3822, Train Accuracy: 38.46%
# Epoch 135/150: Test Loss: 2.3870, Test Accuracy: 38.92%
#     Worker 0: Train Loss: 2.4216, Train Accuracy: 36.50%
#     Worker 1: Train Loss: 2.3561, Train Accuracy: 38.69%
#     Worker 2: Train Loss: 2.3915, Train Accuracy: 38.28%
#     Worker 3: Train Loss: 2.3627, Train Accuracy: 38.21%
# Epoch 136/150: Test Loss: 2.3983, Test Accuracy: 38.61%
#     Worker 0: Train Loss: 2.3815, Train Accuracy: 37.54%
#     Worker 1: Train Loss: 2.4387, Train Accuracy: 37.14%
#     Worker 2: Train Loss: 2.3981, Train Accuracy: 38.18%
#     Worker 3: Train Loss: 2.3702, Train Accuracy: 38.14%
# Epoch 137/150: Test Loss: 2.3938, Test Accuracy: 38.68%
#     Worker 0: Train Loss: 2.3542, Train Accuracy: 38.76%
#     Worker 1: Train Loss: 2.3579, Train Accuracy: 38.12%
#     Worker 2: Train Loss: 2.3473, Train Accuracy: 39.38%
#     Worker 3: Train Loss: 2.3665, Train Accuracy: 38.23%
# Epoch 138/150: Test Loss: 2.3842, Test Accuracy: 38.71%
#     Worker 0: Train Loss: 2.3338, Train Accuracy: 39.21%
#     Worker 1: Train Loss: 2.3576, Train Accuracy: 38.62%
#     Worker 2: Train Loss: 2.3335, Train Accuracy: 39.17%
#     Worker 3: Train Loss: 2.3493, Train Accuracy: 38.41%
# Epoch 139/150: Test Loss: 2.3759, Test Accuracy: 39.03%
#     Worker 0: Train Loss: 2.3256, Train Accuracy: 38.78%
#     Worker 1: Train Loss: 2.4053, Train Accuracy: 37.65%
#     Worker 2: Train Loss: 2.3259, Train Accuracy: 39.72%
#     Worker 3: Train Loss: 2.3481, Train Accuracy: 38.57%
# Epoch 140/150: Test Loss: 2.3761, Test Accuracy: 39.00%
#     Worker 0: Train Loss: 2.3142, Train Accuracy: 39.38%
#     Worker 1: Train Loss: 2.3162, Train Accuracy: 39.39%
#     Worker 2: Train Loss: 2.3274, Train Accuracy: 39.51%
#     Worker 3: Train Loss: 2.4028, Train Accuracy: 37.44%
# Epoch 141/150: Test Loss: 2.3816, Test Accuracy: 38.61%
#     Worker 0: Train Loss: 2.3481, Train Accuracy: 38.29%
#     Worker 1: Train Loss: 2.3277, Train Accuracy: 39.03%
#     Worker 2: Train Loss: 2.3139, Train Accuracy: 40.06%
#     Worker 3: Train Loss: 2.3476, Train Accuracy: 38.49%
# Epoch 142/150: Test Loss: 2.3741, Test Accuracy: 38.82%
#     Worker 0: Train Loss: 2.3117, Train Accuracy: 39.25%
#     Worker 1: Train Loss: 2.3588, Train Accuracy: 38.74%
#     Worker 2: Train Loss: 2.3117, Train Accuracy: 39.84%
#     Worker 3: Train Loss: 2.3528, Train Accuracy: 38.62%
# Epoch 143/150: Test Loss: 2.3726, Test Accuracy: 38.79%
#     Worker 0: Train Loss: 2.3100, Train Accuracy: 39.57%
#     Worker 1: Train Loss: 2.3313, Train Accuracy: 39.54%
#     Worker 2: Train Loss: 2.3262, Train Accuracy: 39.46%
#     Worker 3: Train Loss: 2.3534, Train Accuracy: 38.92%
# Epoch 144/150: Test Loss: 2.3595, Test Accuracy: 39.40%
#     Worker 0: Train Loss: 2.2955, Train Accuracy: 39.69%
#     Worker 1: Train Loss: 2.3424, Train Accuracy: 38.57%
#     Worker 2: Train Loss: 2.3003, Train Accuracy: 40.63%
#     Worker 3: Train Loss: 2.3169, Train Accuracy: 39.35%
# Epoch 145/150: Test Loss: 2.3547, Test Accuracy: 39.41%
#     Worker 0: Train Loss: 2.2940, Train Accuracy: 39.76%
#     Worker 1: Train Loss: 2.2880, Train Accuracy: 40.13%
#     Worker 2: Train Loss: 2.2729, Train Accuracy: 40.70%
#     Worker 3: Train Loss: 2.3087, Train Accuracy: 39.11%
# Epoch 146/150: Test Loss: 2.3605, Test Accuracy: 39.26%
#     Worker 0: Train Loss: 2.2836, Train Accuracy: 40.50%
#     Worker 1: Train Loss: 2.3076, Train Accuracy: 39.30%
#     Worker 2: Train Loss: 2.2766, Train Accuracy: 40.72%
#     Worker 3: Train Loss: 2.3062, Train Accuracy: 39.81%
# Epoch 147/150: Test Loss: 2.3495, Test Accuracy: 39.45%
#     Worker 0: Train Loss: 2.2886, Train Accuracy: 39.68%
#     Worker 1: Train Loss: 2.2880, Train Accuracy: 40.02%
#     Worker 2: Train Loss: 2.2653, Train Accuracy: 40.87%
#     Worker 3: Train Loss: 2.2821, Train Accuracy: 40.37%
# Epoch 148/150: Test Loss: 2.3482, Test Accuracy: 39.42%
#     Worker 0: Train Loss: 2.2539, Train Accuracy: 40.19%
#     Worker 1: Train Loss: 2.2922, Train Accuracy: 39.69%
#     Worker 2: Train Loss: 2.2413, Train Accuracy: 41.58%
#     Worker 3: Train Loss: 2.2861, Train Accuracy: 40.26%
# Epoch 149/150: Test Loss: 2.3503, Test Accuracy: 39.48%
#     Worker 0: Train Loss: 2.2634, Train Accuracy: 40.22%
#     Worker 1: Train Loss: 2.2852, Train Accuracy: 40.40%
#     Worker 2: Train Loss: 2.2528, Train Accuracy: 41.21%
#     Worker 3: Train Loss: 2.2760, Train Accuracy: 40.19%
# Epoch 150/150: Test Loss: 2.3494, Test Accuracy: 39.56%
#     Worker 0: Train Loss: 2.2602, Train Accuracy: 40.16%
#     Worker 1: Train Loss: 2.2806, Train Accuracy: 40.28%
#     Worker 2: Train Loss: 2.2395, Train Accuracy: 41.92%
#     Worker 3: Train Loss: 2.2708, Train Accuracy: 40.35%
