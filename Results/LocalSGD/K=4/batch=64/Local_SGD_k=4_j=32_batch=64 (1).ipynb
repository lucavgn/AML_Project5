# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs - warmup_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")

    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch):
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            # Perform J local step before synchronization
            for j in range(J):
                try:
                    # Get a batch from the current worker's shard using next()
                    images, labels = next(shard_iterators[k])
                    images, labels = images.to(device), labels.to(device)  # Move to device
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

                except StopIteration:
                    # If the iterator has exhausted the data, restart the iterator
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k]) # Resume from the next batch
                    images, labels = images.to(device), labels.to(device)
                    # Perform optimization step
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        # Perform model synchronization
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            # Update each worker model with the global parameters
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
        else:
            warmup_factor = (epoch + 1) / warmup_epochs
            lr = warmup_factor * learning_rate
            for optimizer in optimizers:
                for param_group in optimizer.param_groups:
                    param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 4 --j 32
# Out:
# Training with K=4, J=32
# Global iteration per epoch: 7
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:05<00:00, 29.5MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00400
# Epoch 1/150: Test Loss: 4.5715, Test Accuracy: 2.86%
#     Worker 0: Train Loss: 4.5973, Train Accuracy: 1.54%
#     Worker 1: Train Loss: 4.5980, Train Accuracy: 1.41%
#     Worker 2: Train Loss: 4.5963, Train Accuracy: 1.56%
#     Worker 3: Train Loss: 4.5970, Train Accuracy: 1.59%
# Epoch 2/150: Test Loss: 4.5275, Test Accuracy: 3.32%
#     Worker 0: Train Loss: 4.5559, Train Accuracy: 2.53%
#     Worker 1: Train Loss: 4.5539, Train Accuracy: 2.71%
#     Worker 2: Train Loss: 4.5522, Train Accuracy: 2.82%
#     Worker 3: Train Loss: 4.5556, Train Accuracy: 2.78%
# Epoch 3/150: Test Loss: 4.2699, Test Accuracy: 6.08%
#     Worker 0: Train Loss: 4.4347, Train Accuracy: 3.58%
#     Worker 1: Train Loss: 4.4405, Train Accuracy: 3.55%
#     Worker 2: Train Loss: 4.4235, Train Accuracy: 3.71%
#     Worker 3: Train Loss: 4.4356, Train Accuracy: 4.00%
# Epoch 4/150: Test Loss: 4.0417, Test Accuracy: 8.01%
#     Worker 0: Train Loss: 4.1907, Train Accuracy: 6.06%
#     Worker 1: Train Loss: 4.2038, Train Accuracy: 6.09%
#     Worker 2: Train Loss: 4.1702, Train Accuracy: 6.33%
#     Worker 3: Train Loss: 4.1971, Train Accuracy: 6.07%
# Epoch 5/150: Test Loss: 3.8930, Test Accuracy: 10.74%
#     Worker 0: Train Loss: 4.0510, Train Accuracy: 7.91%
#     Worker 1: Train Loss: 4.0660, Train Accuracy: 7.57%
#     Worker 2: Train Loss: 4.0272, Train Accuracy: 7.84%
#     Worker 3: Train Loss: 4.0675, Train Accuracy: 7.52%
# Epoch 6/150: Test Loss: 3.7644, Test Accuracy: 13.23%
#     Worker 0: Train Loss: 3.9341, Train Accuracy: 9.35%
#     Worker 1: Train Loss: 3.9410, Train Accuracy: 9.95%
#     Worker 2: Train Loss: 3.8816, Train Accuracy: 10.45%
#     Worker 3: Train Loss: 3.9317, Train Accuracy: 10.01%
# Epoch 16/150: Test Loss: 2.9234, Test Accuracy: 27.46%
#     Worker 0: Train Loss: 3.0861, Train Accuracy: 23.74%
#     Worker 1: Train Loss: 3.1252, Train Accuracy: 23.01%
#     Worker 2: Train Loss: 3.0486, Train Accuracy: 24.94%
#     Worker 3: Train Loss: 3.0841, Train Accuracy: 23.45%
# Epoch 17/150: Test Loss: 2.8612, Test Accuracy: 29.00%
#     Worker 0: Train Loss: 3.0220, Train Accuracy: 25.24%
#     Worker 1: Train Loss: 3.0447, Train Accuracy: 25.01%
#     Worker 2: Train Loss: 3.0064, Train Accuracy: 25.71%
#     Worker 3: Train Loss: 3.0361, Train Accuracy: 24.75%
# Epoch 18/150: Test Loss: 2.8264, Test Accuracy: 29.85%
#     Worker 0: Train Loss: 2.9817, Train Accuracy: 25.52%
#     Worker 1: Train Loss: 2.9993, Train Accuracy: 25.64%
#     Worker 2: Train Loss: 2.9500, Train Accuracy: 26.48%
#     Worker 3: Train Loss: 3.0085, Train Accuracy: 25.10%
# Epoch 19/150: Test Loss: 2.7664, Test Accuracy: 31.16%
#     Worker 0: Train Loss: 2.9232, Train Accuracy: 27.03%
#     Worker 1: Train Loss: 2.9635, Train Accuracy: 26.40%
#     Worker 2: Train Loss: 2.9052, Train Accuracy: 27.90%
#     Worker 3: Train Loss: 2.9501, Train Accuracy: 26.97%
# Epoch 20/150: Test Loss: 2.7140, Test Accuracy: 32.09%
#     Worker 0: Train Loss: 2.8972, Train Accuracy: 27.72%
#     Worker 1: Train Loss: 2.8865, Train Accuracy: 27.95%
#     Worker 2: Train Loss: 2.8564, Train Accuracy: 28.33%
#     Worker 3: Train Loss: 2.9261, Train Accuracy: 26.68%
# Epoch 21/150: Test Loss: 2.6710, Test Accuracy: 32.37%
#     Worker 0: Train Loss: 2.8309, Train Accuracy: 28.73%
#     Worker 1: Train Loss: 2.8669, Train Accuracy: 27.68%
#     Worker 2: Train Loss: 2.8109, Train Accuracy: 29.27%
#     Worker 3: Train Loss: 2.8447, Train Accuracy: 28.21%
# Epoch 22/150: Test Loss: 2.6223, Test Accuracy: 33.99%
#     Worker 0: Train Loss: 2.7977, Train Accuracy: 29.81%
#     Worker 1: Train Loss: 2.8163, Train Accuracy: 28.94%
#     Worker 2: Train Loss: 2.7632, Train Accuracy: 29.88%
#     Worker 3: Train Loss: 2.8062, Train Accuracy: 29.25%
# Epoch 23/150: Test Loss: 2.6110, Test Accuracy: 33.61%
#     Worker 0: Train Loss: 2.7333, Train Accuracy: 30.65%
#     Worker 1: Train Loss: 2.7629, Train Accuracy: 29.53%
#     Worker 2: Train Loss: 2.7284, Train Accuracy: 31.29%
#     Worker 3: Train Loss: 2.7725, Train Accuracy: 30.06%
# Epoch 24/150: Test Loss: 2.5401, Test Accuracy: 35.04%
#     Worker 0: Train Loss: 2.6858, Train Accuracy: 31.82%
#     Worker 1: Train Loss: 2.7200, Train Accuracy: 31.29%
#     Worker 2: Train Loss: 2.6709, Train Accuracy: 32.42%
#     Worker 3: Train Loss: 2.7105, Train Accuracy: 30.86%
# Epoch 34/150: Test Loss: 2.2812, Test Accuracy: 40.60%
#     Worker 0: Train Loss: 2.3677, Train Accuracy: 38.39%
#     Worker 1: Train Loss: 2.4072, Train Accuracy: 37.76%
#     Worker 2: Train Loss: 2.3447, Train Accuracy: 38.48%
#     Worker 3: Train Loss: 2.3685, Train Accuracy: 38.32%
# Epoch 35/150: Test Loss: 2.2578, Test Accuracy: 41.24%
#     Worker 0: Train Loss: 2.3261, Train Accuracy: 39.10%
#     Worker 1: Train Loss: 2.3491, Train Accuracy: 38.69%
#     Worker 2: Train Loss: 2.3123, Train Accuracy: 39.69%
#     Worker 3: Train Loss: 2.3550, Train Accuracy: 38.21%
# Epoch 36/150: Test Loss: 2.2413, Test Accuracy: 41.90%
#     Worker 0: Train Loss: 2.3168, Train Accuracy: 38.87%
#     Worker 1: Train Loss: 2.3214, Train Accuracy: 39.10%
#     Worker 2: Train Loss: 2.2957, Train Accuracy: 39.77%
#     Worker 3: Train Loss: 2.3140, Train Accuracy: 39.13%
# Epoch 37/150: Test Loss: 2.2083, Test Accuracy: 42.28%
#     Worker 0: Train Loss: 2.2795, Train Accuracy: 39.81%
#     Worker 1: Train Loss: 2.2765, Train Accuracy: 40.34%
#     Worker 2: Train Loss: 2.2682, Train Accuracy: 40.65%
#     Worker 3: Train Loss: 2.2830, Train Accuracy: 39.92%
# Epoch 38/150: Test Loss: 2.2100, Test Accuracy: 42.82%
#     Worker 0: Train Loss: 2.2343, Train Accuracy: 40.83%
#     Worker 1: Train Loss: 2.2628, Train Accuracy: 41.09%
#     Worker 2: Train Loss: 2.2451, Train Accuracy: 41.05%
#     Worker 3: Train Loss: 2.2805, Train Accuracy: 39.94%
# Epoch 39/150: Test Loss: 2.1988, Test Accuracy: 42.92%
#     Worker 0: Train Loss: 2.2337, Train Accuracy: 41.18%
#     Worker 1: Train Loss: 2.2423, Train Accuracy: 41.05%
#     Worker 2: Train Loss: 2.2073, Train Accuracy: 41.88%
#     Worker 3: Train Loss: 2.2518, Train Accuracy: 40.55%
# Epoch 40/150: Test Loss: 2.1880, Test Accuracy: 42.93%
#     Worker 0: Train Loss: 2.2270, Train Accuracy: 41.12%
#     Worker 1: Train Loss: 2.2394, Train Accuracy: 41.60%
#     Worker 2: Train Loss: 2.2076, Train Accuracy: 41.84%
#     Worker 3: Train Loss: 2.2175, Train Accuracy: 41.27%
# Epoch 41/150: Test Loss: 2.1864, Test Accuracy: 43.15%
#     Worker 0: Train Loss: 2.1884, Train Accuracy: 42.16%
#     Worker 1: Train Loss: 2.1970, Train Accuracy: 41.70%
#     Worker 2: Train Loss: 2.1695, Train Accuracy: 42.53%
#     Worker 3: Train Loss: 2.1813, Train Accuracy: 42.44%
# Epoch 42/150: Test Loss: 2.1362, Test Accuracy: 44.31%
#     Worker 0: Train Loss: 2.1718, Train Accuracy: 42.51%
#     Worker 1: Train Loss: 2.1962, Train Accuracy: 42.01%
#     Worker 2: Train Loss: 2.1569, Train Accuracy: 43.19%
#     Worker 3: Train Loss: 2.1825, Train Accuracy: 42.22%
# Epoch 43/150: Test Loss: 2.1456, Test Accuracy: 43.70%
#     Worker 0: Train Loss: 2.1421, Train Accuracy: 42.93%
#     Worker 1: Train Loss: 2.1575, Train Accuracy: 42.79%
#     Worker 2: Train Loss: 2.1309, Train Accuracy: 43.58%
#     Worker 3: Train Loss: 2.1657, Train Accuracy: 42.73%
# Epoch 44/150: Test Loss: 2.1499, Test Accuracy: 44.03%
#     Worker 0: Train Loss: 2.1258, Train Accuracy: 43.31%
#     Worker 1: Train Loss: 2.1448, Train Accuracy: 43.43%
#     Worker 2: Train Loss: 2.1186, Train Accuracy: 44.05%
#     Worker 3: Train Loss: 2.1252, Train Accuracy: 43.76%
# Epoch 45/150: Test Loss: 2.1219, Test Accuracy: 44.42%
#     Worker 0: Train Loss: 2.1119, Train Accuracy: 43.94%
#     Worker 1: Train Loss: 2.1171, Train Accuracy: 44.12%
#     Worker 2: Train Loss: 2.1054, Train Accuracy: 44.15%
#     Worker 3: Train Loss: 2.1003, Train Accuracy: 43.84%
# Epoch 46/150: Test Loss: 2.1227, Test Accuracy: 44.44%
#     Worker 0: Train Loss: 2.0842, Train Accuracy: 43.53%
#     Worker 1: Train Loss: 2.0869, Train Accuracy: 44.07%
#     Worker 2: Train Loss: 2.0658, Train Accuracy: 44.81%
#     Worker 3: Train Loss: 2.0996, Train Accuracy: 43.92%
# Epoch 47/150: Test Loss: 2.0996, Test Accuracy: 45.28%
#     Worker 0: Train Loss: 2.0605, Train Accuracy: 45.07%
#     Worker 1: Train Loss: 2.0747, Train Accuracy: 45.37%
#     Worker 2: Train Loss: 2.0487, Train Accuracy: 44.93%
#     Worker 3: Train Loss: 2.0855, Train Accuracy: 44.28%
# Epoch 48/150: Test Loss: 2.0936, Test Accuracy: 45.06%
#     Worker 0: Train Loss: 2.0459, Train Accuracy: 45.19%
#     Worker 1: Train Loss: 2.0617, Train Accuracy: 45.18%
#     Worker 2: Train Loss: 2.0304, Train Accuracy: 45.98%
#     Worker 3: Train Loss: 2.0535, Train Accuracy: 45.47%
# Epoch 49/150: Test Loss: 2.0674, Test Accuracy: 46.02%
#     Worker 0: Train Loss: 2.0366, Train Accuracy: 44.76%
#     Worker 1: Train Loss: 2.0376, Train Accuracy: 45.72%
#     Worker 2: Train Loss: 2.0421, Train Accuracy: 45.63%
#     Worker 3: Train Loss: 2.0331, Train Accuracy: 45.38%
# Epoch 50/150: Test Loss: 2.0571, Test Accuracy: 45.97%
#     Worker 0: Train Loss: 2.0004, Train Accuracy: 46.24%
#     Worker 1: Train Loss: 2.0007, Train Accuracy: 46.43%
#     Worker 2: Train Loss: 1.9854, Train Accuracy: 46.54%
#     Worker 3: Train Loss: 2.0320, Train Accuracy: 45.47%
# Epoch 51/150: Test Loss: 2.0635, Test Accuracy: 45.68%
#     Worker 0: Train Loss: 1.9916, Train Accuracy: 46.41%
#     Worker 1: Train Loss: 2.0195, Train Accuracy: 46.12%
#     Worker 2: Train Loss: 1.9731, Train Accuracy: 46.73%
#     Worker 3: Train Loss: 1.9880, Train Accuracy: 46.93%
# Epoch 61/150: Test Loss: 2.0003, Test Accuracy: 47.85%
#     Worker 0: Train Loss: 1.8302, Train Accuracy: 50.35%
#     Worker 1: Train Loss: 1.8226, Train Accuracy: 50.71%
#     Worker 2: Train Loss: 1.8107, Train Accuracy: 50.83%
#     Worker 3: Train Loss: 1.8181, Train Accuracy: 50.73%
# Epoch 62/150: Test Loss: 1.9897, Test Accuracy: 47.93%
#     Worker 0: Train Loss: 1.8433, Train Accuracy: 50.10%
#     Worker 1: Train Loss: 1.8126, Train Accuracy: 50.87%
#     Worker 2: Train Loss: 1.7965, Train Accuracy: 51.34%
#     Worker 3: Train Loss: 1.8415, Train Accuracy: 49.85%
# Epoch 63/150: Test Loss: 1.9858, Test Accuracy: 47.77%
#     Worker 0: Train Loss: 1.8002, Train Accuracy: 51.00%
#     Worker 1: Train Loss: 1.8145, Train Accuracy: 50.66%
#     Worker 2: Train Loss: 1.8030, Train Accuracy: 51.04%
#     Worker 3: Train Loss: 1.8231, Train Accuracy: 50.36%
# Epoch 64/150: Test Loss: 1.9877, Test Accuracy: 48.07%
#     Worker 0: Train Loss: 1.7944, Train Accuracy: 51.10%
#     Worker 1: Train Loss: 1.7860, Train Accuracy: 51.36%
#     Worker 2: Train Loss: 1.7727, Train Accuracy: 51.47%
#     Worker 3: Train Loss: 1.7835, Train Accuracy: 51.62%
# Epoch 65/150: Test Loss: 1.9913, Test Accuracy: 48.26%
#     Worker 0: Train Loss: 1.7692, Train Accuracy: 51.42%
#     Worker 1: Train Loss: 1.7778, Train Accuracy: 51.38%
#     Worker 2: Train Loss: 1.7697, Train Accuracy: 51.50%
#     Worker 3: Train Loss: 1.7865, Train Accuracy: 50.98%
# Epoch 66/150: Test Loss: 1.9737, Test Accuracy: 48.31%
#     Worker 0: Train Loss: 1.7701, Train Accuracy: 50.68%
#     Worker 1: Train Loss: 1.7795, Train Accuracy: 51.48%
#     Worker 2: Train Loss: 1.7419, Train Accuracy: 52.19%
#     Worker 3: Train Loss: 1.7696, Train Accuracy: 51.42%
# Epoch 67/150: Test Loss: 1.9758, Test Accuracy: 47.99%
#     Worker 0: Train Loss: 1.7561, Train Accuracy: 51.39%
#     Worker 1: Train Loss: 1.7492, Train Accuracy: 52.27%
#     Worker 2: Train Loss: 1.7484, Train Accuracy: 52.22%
#     Worker 3: Train Loss: 1.7622, Train Accuracy: 52.23%
# Epoch 68/150: Test Loss: 1.9809, Test Accuracy: 48.57%
#     Worker 0: Train Loss: 1.7408, Train Accuracy: 52.18%
#     Worker 1: Train Loss: 1.7363, Train Accuracy: 52.77%
#     Worker 2: Train Loss: 1.7160, Train Accuracy: 52.90%
#     Worker 3: Train Loss: 1.7372, Train Accuracy: 52.90%
# Epoch 69/150: Test Loss: 1.9746, Test Accuracy: 48.40%
#     Worker 0: Train Loss: 1.7225, Train Accuracy: 52.62%
#     Worker 1: Train Loss: 1.7233, Train Accuracy: 52.81%
#     Worker 2: Train Loss: 1.7259, Train Accuracy: 53.12%
#     Worker 3: Train Loss: 1.7281, Train Accuracy: 52.25%
# Epoch 79/150: Test Loss: 1.9450, Test Accuracy: 49.68%
#     Worker 0: Train Loss: 1.5748, Train Accuracy: 55.65%
#     Worker 1: Train Loss: 1.5919, Train Accuracy: 56.02%
#     Worker 2: Train Loss: 1.5836, Train Accuracy: 56.35%
#     Worker 3: Train Loss: 1.6010, Train Accuracy: 56.22%
# Epoch 80/150: Test Loss: 1.9441, Test Accuracy: 50.03%
#     Worker 0: Train Loss: 1.6096, Train Accuracy: 54.74%
#     Worker 1: Train Loss: 1.5849, Train Accuracy: 56.09%
#     Worker 2: Train Loss: 1.5795, Train Accuracy: 56.33%
#     Worker 3: Train Loss: 1.5980, Train Accuracy: 56.00%
# Epoch 81/150: Test Loss: 1.9379, Test Accuracy: 49.81%
#     Worker 0: Train Loss: 1.5831, Train Accuracy: 55.84%
#     Worker 1: Train Loss: 1.5854, Train Accuracy: 55.86%
#     Worker 2: Train Loss: 1.5659, Train Accuracy: 56.58%
#     Worker 3: Train Loss: 1.5775, Train Accuracy: 56.32%
# Epoch 82/150: Test Loss: 1.9487, Test Accuracy: 49.65%
#     Worker 0: Train Loss: 1.5719, Train Accuracy: 56.14%
#     Worker 1: Train Loss: 1.5521, Train Accuracy: 57.05%
#     Worker 2: Train Loss: 1.5373, Train Accuracy: 57.61%
#     Worker 3: Train Loss: 1.5960, Train Accuracy: 55.89%
# Epoch 83/150: Test Loss: 1.9489, Test Accuracy: 49.75%
#     Worker 0: Train Loss: 1.5547, Train Accuracy: 55.98%
#     Worker 1: Train Loss: 1.5461, Train Accuracy: 57.13%
#     Worker 2: Train Loss: 1.5376, Train Accuracy: 57.39%
#     Worker 3: Train Loss: 1.5496, Train Accuracy: 57.03%
# Epoch 84/150: Test Loss: 1.9386, Test Accuracy: 50.02%
#     Worker 0: Train Loss: 1.5365, Train Accuracy: 57.43%
#     Worker 1: Train Loss: 1.5380, Train Accuracy: 57.24%
#     Worker 2: Train Loss: 1.5252, Train Accuracy: 58.03%
#     Worker 3: Train Loss: 1.5440, Train Accuracy: 57.13%
# Epoch 85/150: Test Loss: 1.9367, Test Accuracy: 49.91%
#     Worker 0: Train Loss: 1.5120, Train Accuracy: 57.40%
#     Worker 1: Train Loss: 1.5389, Train Accuracy: 57.12%
#     Worker 2: Train Loss: 1.5207, Train Accuracy: 57.76%
#     Worker 3: Train Loss: 1.5250, Train Accuracy: 57.84%
# Epoch 86/150: Test Loss: 1.9504, Test Accuracy: 50.19%
#     Worker 0: Train Loss: 1.5263, Train Accuracy: 56.88%
#     Worker 1: Train Loss: 1.5144, Train Accuracy: 58.20%
#     Worker 2: Train Loss: 1.5063, Train Accuracy: 58.00%
#     Worker 3: Train Loss: 1.5223, Train Accuracy: 57.86%
# Epoch 87/150: Test Loss: 1.9407, Test Accuracy: 50.20%
#     Worker 0: Train Loss: 1.5256, Train Accuracy: 57.08%
#     Worker 1: Train Loss: 1.5145, Train Accuracy: 57.79%
#     Worker 2: Train Loss: 1.4975, Train Accuracy: 58.78%
#     Worker 3: Train Loss: 1.5157, Train Accuracy: 57.76%
# Epoch 88/150: Test Loss: 1.9434, Test Accuracy: 50.42%
#     Worker 0: Train Loss: 1.4918, Train Accuracy: 58.55%
#     Worker 1: Train Loss: 1.4923, Train Accuracy: 57.98%
#     Worker 2: Train Loss: 1.4912, Train Accuracy: 58.25%
#     Worker 3: Train Loss: 1.5059, Train Accuracy: 57.70%
# Epoch 89/150: Test Loss: 1.9364, Test Accuracy: 50.28%
#     Worker 0: Train Loss: 1.4949, Train Accuracy: 57.66%
#     Worker 1: Train Loss: 1.4918, Train Accuracy: 58.64%
#     Worker 2: Train Loss: 1.4552, Train Accuracy: 59.26%
#     Worker 3: Train Loss: 1.4868, Train Accuracy: 58.82%
# Epoch 90/150: Test Loss: 1.9330, Test Accuracy: 50.29%
#     Worker 0: Train Loss: 1.4815, Train Accuracy: 58.53%
#     Worker 1: Train Loss: 1.4738, Train Accuracy: 58.74%
#     Worker 2: Train Loss: 1.4817, Train Accuracy: 58.54%
#     Worker 3: Train Loss: 1.4823, Train Accuracy: 58.73%
# Epoch 91/150: Test Loss: 1.9297, Test Accuracy: 50.00%
#     Worker 0: Train Loss: 1.4589, Train Accuracy: 58.91%
#     Worker 1: Train Loss: 1.4671, Train Accuracy: 58.70%
#     Worker 2: Train Loss: 1.4576, Train Accuracy: 59.22%
#     Worker 3: Train Loss: 1.4952, Train Accuracy: 58.20%
# Epoch 92/150: Test Loss: 1.9361, Test Accuracy: 50.51%
#     Worker 0: Train Loss: 1.4628, Train Accuracy: 58.31%
#     Worker 1: Train Loss: 1.4695, Train Accuracy: 58.93%
#     Worker 2: Train Loss: 1.4505, Train Accuracy: 59.28%
#     Worker 3: Train Loss: 1.4664, Train Accuracy: 58.55%
# Epoch 93/150: Test Loss: 1.9351, Test Accuracy: 50.74%
#     Worker 0: Train Loss: 1.4275, Train Accuracy: 59.68%
#     Worker 1: Train Loss: 1.4233, Train Accuracy: 59.95%
#     Worker 2: Train Loss: 1.4509, Train Accuracy: 59.14%
#     Worker 3: Train Loss: 1.4479, Train Accuracy: 59.53%
# Epoch 94/150: Test Loss: 1.9338, Test Accuracy: 50.29%
#     Worker 0: Train Loss: 1.4414, Train Accuracy: 59.43%
#     Worker 1: Train Loss: 1.4426, Train Accuracy: 59.78%
#     Worker 2: Train Loss: 1.4298, Train Accuracy: 60.31%
#     Worker 3: Train Loss: 1.4425, Train Accuracy: 59.69%
# Epoch 95/150: Test Loss: 1.9269, Test Accuracy: 50.92%
#     Worker 0: Train Loss: 1.4239, Train Accuracy: 59.75%
#     Worker 1: Train Loss: 1.4439, Train Accuracy: 59.13%
#     Worker 2: Train Loss: 1.4260, Train Accuracy: 60.15%
#     Worker 3: Train Loss: 1.4376, Train Accuracy: 59.87%
# Epoch 96/150: Test Loss: 1.9272, Test Accuracy: 50.76%
#     Worker 0: Train Loss: 1.4159, Train Accuracy: 59.98%
#     Worker 1: Train Loss: 1.3947, Train Accuracy: 61.28%
#     Worker 2: Train Loss: 1.4140, Train Accuracy: 60.40%
#     Worker 3: Train Loss: 1.4208, Train Accuracy: 60.51%
# Epoch 97/150: Test Loss: 1.9291, Test Accuracy: 50.68%
#     Worker 0: Train Loss: 1.4120, Train Accuracy: 59.80%
#     Worker 1: Train Loss: 1.4129, Train Accuracy: 60.31%
#     Worker 2: Train Loss: 1.3928, Train Accuracy: 61.26%
#     Worker 3: Train Loss: 1.4180, Train Accuracy: 60.03%
# Epoch 98/150: Test Loss: 1.9271, Test Accuracy: 51.07%
#     Worker 0: Train Loss: 1.4131, Train Accuracy: 60.11%
#     Worker 1: Train Loss: 1.3932, Train Accuracy: 61.24%
#     Worker 2: Train Loss: 1.4109, Train Accuracy: 60.86%
#     Worker 3: Train Loss: 1.3968, Train Accuracy: 60.84%
# Epoch 99/150: Test Loss: 1.9375, Test Accuracy: 50.72%
#     Worker 0: Train Loss: 1.3903, Train Accuracy: 60.00%
#     Worker 1: Train Loss: 1.3823, Train Accuracy: 60.92%
#     Worker 2: Train Loss: 1.3720, Train Accuracy: 61.54%
#     Worker 3: Train Loss: 1.3956, Train Accuracy: 60.90%
# Epoch 100/150: Test Loss: 1.9388, Test Accuracy: 50.93%
#     Worker 0: Train Loss: 1.3748, Train Accuracy: 61.01%
#     Worker 1: Train Loss: 1.3958, Train Accuracy: 60.85%
#     Worker 2: Train Loss: 1.3771, Train Accuracy: 61.22%
#     Worker 3: Train Loss: 1.3767, Train Accuracy: 61.20%
# Epoch 101/150: Test Loss: 1.9413, Test Accuracy: 51.09%
#     Worker 0: Train Loss: 1.3760, Train Accuracy: 61.34%
#     Worker 1: Train Loss: 1.3768, Train Accuracy: 60.68%
#     Worker 2: Train Loss: 1.3560, Train Accuracy: 61.97%
#     Worker 3: Train Loss: 1.3982, Train Accuracy: 60.79%
# Epoch 102/150: Test Loss: 1.9306, Test Accuracy: 50.97%
#     Worker 0: Train Loss: 1.3783, Train Accuracy: 61.25%
#     Worker 1: Train Loss: 1.3398, Train Accuracy: 61.97%
#     Worker 2: Train Loss: 1.3596, Train Accuracy: 61.58%
#     Worker 3: Train Loss: 1.3651, Train Accuracy: 61.91%
# Epoch 103/150: Test Loss: 1.9361, Test Accuracy: 51.28%
#     Worker 0: Train Loss: 1.3547, Train Accuracy: 61.09%
#     Worker 1: Train Loss: 1.3818, Train Accuracy: 61.59%
#     Worker 2: Train Loss: 1.3458, Train Accuracy: 61.98%
#     Worker 3: Train Loss: 1.3653, Train Accuracy: 61.22%
# Epoch 104/150: Test Loss: 1.9248, Test Accuracy: 51.41%
#     Worker 0: Train Loss: 1.3500, Train Accuracy: 61.77%
#     Worker 1: Train Loss: 1.3433, Train Accuracy: 61.99%
#     Worker 2: Train Loss: 1.3430, Train Accuracy: 61.99%
#     Worker 3: Train Loss: 1.3648, Train Accuracy: 61.36%
# Epoch 105/150: Test Loss: 1.9363, Test Accuracy: 51.32%
#     Worker 0: Train Loss: 1.3417, Train Accuracy: 61.71%
#     Worker 1: Train Loss: 1.3497, Train Accuracy: 62.18%
#     Worker 2: Train Loss: 1.3381, Train Accuracy: 62.27%
#     Worker 3: Train Loss: 1.3421, Train Accuracy: 62.46%
# Epoch 106/150: Test Loss: 1.9250, Test Accuracy: 51.43%
#     Worker 0: Train Loss: 1.3351, Train Accuracy: 62.38%
#     Worker 1: Train Loss: 1.3378, Train Accuracy: 62.25%
#     Worker 2: Train Loss: 1.3364, Train Accuracy: 62.69%
#     Worker 3: Train Loss: 1.3411, Train Accuracy: 62.11%
# Epoch 107/150: Test Loss: 1.9369, Test Accuracy: 51.00%
#     Worker 0: Train Loss: 1.3415, Train Accuracy: 61.78%
#     Worker 1: Train Loss: 1.3273, Train Accuracy: 62.08%
#     Worker 2: Train Loss: 1.3125, Train Accuracy: 63.03%
#     Worker 3: Train Loss: 1.3262, Train Accuracy: 62.63%
# Epoch 108/150: Test Loss: 1.9390, Test Accuracy: 51.32%
#     Worker 0: Train Loss: 1.3233, Train Accuracy: 62.33%
#     Worker 1: Train Loss: 1.2991, Train Accuracy: 63.01%
#     Worker 2: Train Loss: 1.2841, Train Accuracy: 63.55%
#     Worker 3: Train Loss: 1.3373, Train Accuracy: 62.51%
# Epoch 109/150: Test Loss: 1.9409, Test Accuracy: 51.20%
#     Worker 0: Train Loss: 1.3128, Train Accuracy: 62.66%
#     Worker 1: Train Loss: 1.3147, Train Accuracy: 62.87%
#     Worker 2: Train Loss: 1.3247, Train Accuracy: 62.93%
#     Worker 3: Train Loss: 1.3100, Train Accuracy: 62.96%
# Epoch 110/150: Test Loss: 1.9446, Test Accuracy: 51.29%
#     Worker 0: Train Loss: 1.3073, Train Accuracy: 62.97%
#     Worker 1: Train Loss: 1.3144, Train Accuracy: 62.89%
#     Worker 2: Train Loss: 1.2805, Train Accuracy: 63.39%
#     Worker 3: Train Loss: 1.3298, Train Accuracy: 62.24%
# Epoch 111/150: Test Loss: 1.9409, Test Accuracy: 51.56%
#     Worker 0: Train Loss: 1.3120, Train Accuracy: 62.94%
#     Worker 1: Train Loss: 1.2957, Train Accuracy: 63.25%
#     Worker 2: Train Loss: 1.2896, Train Accuracy: 63.51%
#     Worker 3: Train Loss: 1.2982, Train Accuracy: 63.17%
# Epoch 112/150: Test Loss: 1.9353, Test Accuracy: 51.33%
#     Worker 0: Train Loss: 1.2962, Train Accuracy: 62.84%
#     Worker 1: Train Loss: 1.2850, Train Accuracy: 63.53%
#     Worker 2: Train Loss: 1.2805, Train Accuracy: 63.72%
#     Worker 3: Train Loss: 1.2983, Train Accuracy: 63.61%
# Epoch 113/150: Test Loss: 1.9426, Test Accuracy: 51.21%
#     Worker 0: Train Loss: 1.2652, Train Accuracy: 63.87%
#     Worker 1: Train Loss: 1.2828, Train Accuracy: 63.73%
#     Worker 2: Train Loss: 1.2667, Train Accuracy: 64.43%
#     Worker 3: Train Loss: 1.2966, Train Accuracy: 62.95%
# Epoch 114/150: Test Loss: 1.9392, Test Accuracy: 51.48%
#     Worker 0: Train Loss: 1.2847, Train Accuracy: 63.20%
#     Worker 1: Train Loss: 1.2573, Train Accuracy: 64.53%
#     Worker 2: Train Loss: 1.2780, Train Accuracy: 64.04%
#     Worker 3: Train Loss: 1.2786, Train Accuracy: 63.89%
# Epoch 115/150: Test Loss: 1.9488, Test Accuracy: 51.22%
#     Worker 0: Train Loss: 1.2575, Train Accuracy: 63.96%
#     Worker 1: Train Loss: 1.2805, Train Accuracy: 63.46%
#     Worker 2: Train Loss: 1.2753, Train Accuracy: 63.83%
#     Worker 3: Train Loss: 1.2902, Train Accuracy: 63.51%
# Epoch 116/150: Test Loss: 1.9503, Test Accuracy: 50.96%
#     Worker 0: Train Loss: 1.2692, Train Accuracy: 63.62%
#     Worker 1: Train Loss: 1.2621, Train Accuracy: 64.20%
#     Worker 2: Train Loss: 1.2410, Train Accuracy: 65.47%
#     Worker 3: Train Loss: 1.2642, Train Accuracy: 64.47%
# Epoch 117/150: Test Loss: 1.9416, Test Accuracy: 51.43%
#     Worker 0: Train Loss: 1.2817, Train Accuracy: 63.72%
#     Worker 1: Train Loss: 1.2614, Train Accuracy: 64.21%
#     Worker 2: Train Loss: 1.2495, Train Accuracy: 64.90%
#     Worker 3: Train Loss: 1.2845, Train Accuracy: 63.76%
# Epoch 118/150: Test Loss: 1.9475, Test Accuracy: 51.43%
#     Worker 0: Train Loss: 1.2476, Train Accuracy: 64.50%
#     Worker 1: Train Loss: 1.2544, Train Accuracy: 64.22%
#     Worker 2: Train Loss: 1.2359, Train Accuracy: 65.19%
#     Worker 3: Train Loss: 1.2466, Train Accuracy: 65.07%
# Epoch 119/150: Test Loss: 1.9418, Test Accuracy: 51.41%
#     Worker 0: Train Loss: 1.2572, Train Accuracy: 64.18%
#     Worker 1: Train Loss: 1.2319, Train Accuracy: 65.05%
#     Worker 2: Train Loss: 1.2410, Train Accuracy: 65.02%
#     Worker 3: Train Loss: 1.2420, Train Accuracy: 64.62%
# Epoch 120/150: Test Loss: 1.9442, Test Accuracy: 51.47%
#     Worker 0: Train Loss: 1.2454, Train Accuracy: 64.39%
#     Worker 1: Train Loss: 1.2364, Train Accuracy: 64.99%
#     Worker 2: Train Loss: 1.2365, Train Accuracy: 65.46%
#     Worker 3: Train Loss: 1.2548, Train Accuracy: 64.61%
# Epoch 121/150: Test Loss: 1.9463, Test Accuracy: 51.62%
#     Worker 0: Train Loss: 1.2421, Train Accuracy: 64.39%
#     Worker 1: Train Loss: 1.2379, Train Accuracy: 64.95%
#     Worker 2: Train Loss: 1.2089, Train Accuracy: 66.18%
#     Worker 3: Train Loss: 1.2246, Train Accuracy: 65.53%
# Epoch 122/150: Test Loss: 1.9478, Test Accuracy: 51.75%
#     Worker 0: Train Loss: 1.2080, Train Accuracy: 65.57%
#     Worker 1: Train Loss: 1.2209, Train Accuracy: 65.30%
#     Worker 2: Train Loss: 1.2245, Train Accuracy: 65.49%
#     Worker 3: Train Loss: 1.2457, Train Accuracy: 64.91%
# Epoch 123/150: Test Loss: 1.9466, Test Accuracy: 51.43%
#     Worker 0: Train Loss: 1.2501, Train Accuracy: 64.04%
#     Worker 1: Train Loss: 1.2147, Train Accuracy: 65.30%
#     Worker 2: Train Loss: 1.2103, Train Accuracy: 66.05%
#     Worker 3: Train Loss: 1.2339, Train Accuracy: 65.06%
# Epoch 124/150: Test Loss: 1.9501, Test Accuracy: 51.45%
#     Worker 0: Train Loss: 1.2317, Train Accuracy: 64.50%
#     Worker 1: Train Loss: 1.2287, Train Accuracy: 64.99%
#     Worker 2: Train Loss: 1.2212, Train Accuracy: 66.02%
#     Worker 3: Train Loss: 1.2332, Train Accuracy: 65.21%
# Epoch 125/150: Test Loss: 1.9502, Test Accuracy: 51.64%
#     Worker 0: Train Loss: 1.2218, Train Accuracy: 64.92%
#     Worker 1: Train Loss: 1.2152, Train Accuracy: 65.27%
#     Worker 2: Train Loss: 1.2141, Train Accuracy: 65.76%
#     Worker 3: Train Loss: 1.2112, Train Accuracy: 65.69%
# Epoch 126/150: Test Loss: 1.9530, Test Accuracy: 51.48%
#     Worker 0: Train Loss: 1.2168, Train Accuracy: 65.05%
#     Worker 1: Train Loss: 1.2074, Train Accuracy: 65.61%
#     Worker 2: Train Loss: 1.2149, Train Accuracy: 65.83%
#     Worker 3: Train Loss: 1.2155, Train Accuracy: 65.42%
# Epoch 127/150: Test Loss: 1.9518, Test Accuracy: 51.62%
#     Worker 0: Train Loss: 1.2213, Train Accuracy: 65.27%
#     Worker 1: Train Loss: 1.1974, Train Accuracy: 66.20%
#     Worker 2: Train Loss: 1.2132, Train Accuracy: 65.55%
#     Worker 3: Train Loss: 1.2130, Train Accuracy: 65.65%
# Epoch 128/150: Test Loss: 1.9488, Test Accuracy: 51.63%
#     Worker 0: Train Loss: 1.1980, Train Accuracy: 65.99%
#     Worker 1: Train Loss: 1.1965, Train Accuracy: 66.07%
#     Worker 2: Train Loss: 1.2058, Train Accuracy: 66.04%
#     Worker 3: Train Loss: 1.2208, Train Accuracy: 65.37%
# Epoch 129/150: Test Loss: 1.9553, Test Accuracy: 51.50%
#     Worker 0: Train Loss: 1.2175, Train Accuracy: 65.04%
#     Worker 1: Train Loss: 1.1979, Train Accuracy: 65.87%
#     Worker 2: Train Loss: 1.1742, Train Accuracy: 66.60%
#     Worker 3: Train Loss: 1.2032, Train Accuracy: 65.78%
# Epoch 130/150: Test Loss: 1.9515, Test Accuracy: 51.69%
#     Worker 0: Train Loss: 1.2010, Train Accuracy: 65.54%
#     Worker 1: Train Loss: 1.1990, Train Accuracy: 65.99%
#     Worker 2: Train Loss: 1.2009, Train Accuracy: 65.83%
#     Worker 3: Train Loss: 1.2078, Train Accuracy: 65.97%
# Epoch 131/150: Test Loss: 1.9527, Test Accuracy: 51.71%
#     Worker 0: Train Loss: 1.1922, Train Accuracy: 66.29%
#     Worker 1: Train Loss: 1.2040, Train Accuracy: 66.04%
#     Worker 2: Train Loss: 1.1834, Train Accuracy: 66.65%
#     Worker 3: Train Loss: 1.1965, Train Accuracy: 66.11%
# Epoch 132/150: Test Loss: 1.9570, Test Accuracy: 51.45%
#     Worker 0: Train Loss: 1.1950, Train Accuracy: 65.44%
#     Worker 1: Train Loss: 1.1961, Train Accuracy: 66.12%
#     Worker 2: Train Loss: 1.1912, Train Accuracy: 66.53%
#     Worker 3: Train Loss: 1.2091, Train Accuracy: 65.80%
# Epoch 133/150: Test Loss: 1.9525, Test Accuracy: 51.73%
#     Worker 0: Train Loss: 1.1994, Train Accuracy: 65.95%
#     Worker 1: Train Loss: 1.1755, Train Accuracy: 66.57%
#     Worker 2: Train Loss: 1.1853, Train Accuracy: 66.41%
#     Worker 3: Train Loss: 1.1948, Train Accuracy: 66.33%
# Epoch 134/150: Test Loss: 1.9570, Test Accuracy: 51.56%
#     Worker 0: Train Loss: 1.1903, Train Accuracy: 65.81%
#     Worker 1: Train Loss: 1.1749, Train Accuracy: 66.88%
#     Worker 2: Train Loss: 1.1893, Train Accuracy: 66.18%
#     Worker 3: Train Loss: 1.1814, Train Accuracy: 66.40%
# Epoch 135/150: Test Loss: 1.9558, Test Accuracy: 51.51%
#     Worker 0: Train Loss: 1.1776, Train Accuracy: 66.21%
#     Worker 1: Train Loss: 1.1907, Train Accuracy: 66.60%
#     Worker 2: Train Loss: 1.1752, Train Accuracy: 67.11%
#     Worker 3: Train Loss: 1.1977, Train Accuracy: 66.16%
# Epoch 136/150: Test Loss: 1.9557, Test Accuracy: 51.55%
#     Worker 0: Train Loss: 1.1870, Train Accuracy: 65.90%
#     Worker 1: Train Loss: 1.1806, Train Accuracy: 66.20%
#     Worker 2: Train Loss: 1.1823, Train Accuracy: 66.65%
#     Worker 3: Train Loss: 1.1912, Train Accuracy: 65.88%
# Epoch 137/150: Test Loss: 1.9559, Test Accuracy: 51.64%
#     Worker 0: Train Loss: 1.1728, Train Accuracy: 66.14%
#     Worker 1: Train Loss: 1.1902, Train Accuracy: 66.62%
#     Worker 2: Train Loss: 1.1780, Train Accuracy: 66.92%
#     Worker 3: Train Loss: 1.1879, Train Accuracy: 66.86%
# Epoch 138/150: Test Loss: 1.9542, Test Accuracy: 51.74%
#     Worker 0: Train Loss: 1.1839, Train Accuracy: 65.92%
#     Worker 1: Train Loss: 1.1611, Train Accuracy: 66.96%
#     Worker 2: Train Loss: 1.1743, Train Accuracy: 66.98%
#     Worker 3: Train Loss: 1.1914, Train Accuracy: 65.86%
# Epoch 139/150: Test Loss: 1.9557, Test Accuracy: 51.62%
#     Worker 0: Train Loss: 1.1666, Train Accuracy: 66.84%
#     Worker 1: Train Loss: 1.1802, Train Accuracy: 66.32%
#     Worker 2: Train Loss: 1.1770, Train Accuracy: 66.68%
#     Worker 3: Train Loss: 1.1874, Train Accuracy: 66.69%
# Epoch 140/150: Test Loss: 1.9550, Test Accuracy: 51.69%
#     Worker 0: Train Loss: 1.1784, Train Accuracy: 66.20%
#     Worker 1: Train Loss: 1.1684, Train Accuracy: 67.06%
#     Worker 2: Train Loss: 1.1706, Train Accuracy: 67.10%
#     Worker 3: Train Loss: 1.1903, Train Accuracy: 66.42%
# Epoch 141/150: Test Loss: 1.9560, Test Accuracy: 51.61%
#     Worker 0: Train Loss: 1.1651, Train Accuracy: 66.95%
#     Worker 1: Train Loss: 1.1888, Train Accuracy: 65.96%
#     Worker 2: Train Loss: 1.1692, Train Accuracy: 66.99%
#     Worker 3: Train Loss: 1.1825, Train Accuracy: 66.67%
# Epoch 142/150: Test Loss: 1.9579, Test Accuracy: 51.69%
#     Worker 0: Train Loss: 1.1880, Train Accuracy: 65.99%
#     Worker 1: Train Loss: 1.1677, Train Accuracy: 67.09%
#     Worker 2: Train Loss: 1.1611, Train Accuracy: 67.09%
#     Worker 3: Train Loss: 1.1775, Train Accuracy: 66.71%
# Epoch 143/150: Test Loss: 1.9570, Test Accuracy: 51.68%
#     Worker 0: Train Loss: 1.1779, Train Accuracy: 66.09%
#     Worker 1: Train Loss: 1.1586, Train Accuracy: 66.54%
#     Worker 2: Train Loss: 1.1681, Train Accuracy: 67.12%
#     Worker 3: Train Loss: 1.1834, Train Accuracy: 66.44%
# Epoch 144/150: Test Loss: 1.9573, Test Accuracy: 51.69%
#     Worker 0: Train Loss: 1.1627, Train Accuracy: 66.32%
#     Worker 1: Train Loss: 1.1771, Train Accuracy: 66.52%
#     Worker 2: Train Loss: 1.1704, Train Accuracy: 66.73%
#     Worker 3: Train Loss: 1.1633, Train Accuracy: 66.55%
# Epoch 145/150: Test Loss: 1.9565, Test Accuracy: 51.72%
#     Worker 0: Train Loss: 1.1803, Train Accuracy: 66.23%
#     Worker 1: Train Loss: 1.1892, Train Accuracy: 66.02%
#     Worker 2: Train Loss: 1.1638, Train Accuracy: 67.07%
#     Worker 3: Train Loss: 1.1843, Train Accuracy: 66.30%
# Epoch 146/150: Test Loss: 1.9562, Test Accuracy: 51.80%
#     Worker 0: Train Loss: 1.1758, Train Accuracy: 66.34%
#     Worker 1: Train Loss: 1.1619, Train Accuracy: 67.42%
#     Worker 2: Train Loss: 1.1551, Train Accuracy: 67.68%
#     Worker 3: Train Loss: 1.1900, Train Accuracy: 66.92%
# Epoch 147/150: Test Loss: 1.9562, Test Accuracy: 51.73%
#     Worker 0: Train Loss: 1.1719, Train Accuracy: 66.61%
#     Worker 1: Train Loss: 1.1658, Train Accuracy: 67.03%
#     Worker 2: Train Loss: 1.1743, Train Accuracy: 66.77%
#     Worker 3: Train Loss: 1.1820, Train Accuracy: 66.61%
# Epoch 148/150: Test Loss: 1.9563, Test Accuracy: 51.79%
#     Worker 0: Train Loss: 1.1689, Train Accuracy: 66.12%
#     Worker 1: Train Loss: 1.1700, Train Accuracy: 66.70%
#     Worker 2: Train Loss: 1.1718, Train Accuracy: 66.90%
#     Worker 3: Train Loss: 1.1767, Train Accuracy: 66.45%
# Epoch 149/150: Test Loss: 1.9563, Test Accuracy: 51.77%
#     Worker 0: Train Loss: 1.1810, Train Accuracy: 66.26%
#     Worker 1: Train Loss: 1.1879, Train Accuracy: 66.43%
#     Worker 2: Train Loss: 1.1664, Train Accuracy: 67.40%
#     Worker 3: Train Loss: 1.1919, Train Accuracy: 65.66%
# Epoch 150/150: Test Loss: 1.9563, Test Accuracy: 51.78%
#     Worker 0: Train Loss: 1.1767, Train Accuracy: 66.48%
#     Worker 1: Train Loss: 1.1696, Train Accuracy: 66.95%
#     Worker 2: Train Loss: 1.1606, Train Accuracy: 67.42%
#     Worker 3: Train Loss: 1.1795, Train Accuracy: 66.55%
