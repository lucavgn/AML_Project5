# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs - warmup_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")

    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch):
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            # Perform J local step before synchronization
            for j in range(J):
                try:
                    # Get a batch from the current worker's shard using next()
                    images, labels = next(shard_iterators[k])
                    images, labels = images.to(device), labels.to(device)  # Move to device
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

                except StopIteration:
                    # If the iterator has exhausted the data, restart the iterator
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k]) # Resume from the next batch
                    images, labels = images.to(device), labels.to(device)
                    # Perform optimization step
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        # Perform model synchronization
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            # Update each worker model with the global parameters
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
        else:
            warmup_factor = (epoch + 1) / warmup_epochs
            lr = warmup_factor * learning_rate
            for optimizer in optimizers:
                for param_group in optimizer.param_groups:
                    param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 4 --j 4
# Out:
# Training with K=4, J=4
# Global iteration per epoch: 49
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:02<00:00, 67.4MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00400
# Epoch 1/150: Test Loss: 4.5808, Test Accuracy: 3.01%
#     Worker 0: Train Loss: 4.5986, Train Accuracy: 1.50%
#     Worker 1: Train Loss: 4.5997, Train Accuracy: 1.31%
#     Worker 2: Train Loss: 4.5983, Train Accuracy: 1.47%
#     Worker 3: Train Loss: 4.5988, Train Accuracy: 1.37%
# Epoch 2/150: Test Loss: 4.5561, Test Accuracy: 3.38%
#     Worker 0: Train Loss: 4.5721, Train Accuracy: 2.66%
#     Worker 1: Train Loss: 4.5719, Train Accuracy: 2.74%
#     Worker 2: Train Loss: 4.5690, Train Accuracy: 3.14%
#     Worker 3: Train Loss: 4.5720, Train Accuracy: 2.90%
# Epoch 3/150: Test Loss: 4.3982, Test Accuracy: 4.90%
#     Worker 0: Train Loss: 4.5020, Train Accuracy: 3.26%
#     Worker 1: Train Loss: 4.5049, Train Accuracy: 3.38%
#     Worker 2: Train Loss: 4.4917, Train Accuracy: 3.66%
#     Worker 3: Train Loss: 4.5001, Train Accuracy: 3.47%
# Epoch 4/150: Test Loss: 4.0800, Test Accuracy: 8.01%
#     Worker 0: Train Loss: 4.2383, Train Accuracy: 6.19%
#     Worker 1: Train Loss: 4.2454, Train Accuracy: 5.85%
#     Worker 2: Train Loss: 4.2199, Train Accuracy: 6.01%
#     Worker 3: Train Loss: 4.2405, Train Accuracy: 6.12%
# Epoch 5/150: Test Loss: 3.9169, Test Accuracy: 10.43%
#     Worker 0: Train Loss: 4.0542, Train Accuracy: 8.27%
#     Worker 1: Train Loss: 4.0571, Train Accuracy: 7.81%
#     Worker 2: Train Loss: 4.0157, Train Accuracy: 8.44%
#     Worker 3: Train Loss: 4.0550, Train Accuracy: 7.82%
# Epoch 6/150: Test Loss: 3.7708, Test Accuracy: 13.20%
#     Worker 0: Train Loss: 3.9222, Train Accuracy: 10.42%
#     Worker 1: Train Loss: 3.9276, Train Accuracy: 10.06%
#     Worker 2: Train Loss: 3.8795, Train Accuracy: 10.79%
#     Worker 3: Train Loss: 3.9196, Train Accuracy: 10.04%
# Epoch 34/150: Test Loss: 2.2926, Test Accuracy: 40.70%
#     Worker 0: Train Loss: 2.3149, Train Accuracy: 39.70%
#     Worker 1: Train Loss: 2.3341, Train Accuracy: 39.06%
#     Worker 2: Train Loss: 2.3007, Train Accuracy: 40.11%
#     Worker 3: Train Loss: 2.3252, Train Accuracy: 39.16%
# Epoch 35/150: Test Loss: 2.2958, Test Accuracy: 40.20%
#     Worker 0: Train Loss: 2.2804, Train Accuracy: 40.05%
#     Worker 1: Train Loss: 2.3061, Train Accuracy: 39.83%
#     Worker 2: Train Loss: 2.2774, Train Accuracy: 40.32%
#     Worker 3: Train Loss: 2.2981, Train Accuracy: 39.99%
# Epoch 36/150: Test Loss: 2.2460, Test Accuracy: 41.76%
#     Worker 0: Train Loss: 2.2558, Train Accuracy: 41.18%
#     Worker 1: Train Loss: 2.2845, Train Accuracy: 40.07%
#     Worker 2: Train Loss: 2.2349, Train Accuracy: 41.26%
#     Worker 3: Train Loss: 2.2815, Train Accuracy: 40.62%
# Epoch 37/150: Test Loss: 2.2515, Test Accuracy: 41.50%
#     Worker 0: Train Loss: 2.2296, Train Accuracy: 41.50%
#     Worker 1: Train Loss: 2.2580, Train Accuracy: 40.98%
#     Worker 2: Train Loss: 2.2358, Train Accuracy: 41.49%
#     Worker 3: Train Loss: 2.2474, Train Accuracy: 41.17%
# Epoch 38/150: Test Loss: 2.2260, Test Accuracy: 42.22%
#     Worker 0: Train Loss: 2.2154, Train Accuracy: 41.60%
#     Worker 1: Train Loss: 2.2257, Train Accuracy: 41.66%
#     Worker 2: Train Loss: 2.1959, Train Accuracy: 42.10%
#     Worker 3: Train Loss: 2.2201, Train Accuracy: 41.73%
# Epoch 39/150: Test Loss: 2.2286, Test Accuracy: 41.98%
#     Worker 0: Train Loss: 2.1862, Train Accuracy: 42.16%
#     Worker 1: Train Loss: 2.2030, Train Accuracy: 41.64%
#     Worker 2: Train Loss: 2.1724, Train Accuracy: 42.98%
#     Worker 3: Train Loss: 2.2054, Train Accuracy: 41.98%
# Epoch 40/150: Test Loss: 2.2025, Test Accuracy: 42.66%
#     Worker 0: Train Loss: 2.1612, Train Accuracy: 42.70%
#     Worker 1: Train Loss: 2.1802, Train Accuracy: 42.44%
#     Worker 2: Train Loss: 2.1481, Train Accuracy: 43.54%
#     Worker 3: Train Loss: 2.1656, Train Accuracy: 43.07%
# Epoch 41/150: Test Loss: 2.1795, Test Accuracy: 43.17%
#     Worker 0: Train Loss: 2.1393, Train Accuracy: 43.65%
#     Worker 1: Train Loss: 2.1560, Train Accuracy: 43.02%
#     Worker 2: Train Loss: 2.1333, Train Accuracy: 43.36%
#     Worker 3: Train Loss: 2.1703, Train Accuracy: 42.54%
# Epoch 42/150: Test Loss: 2.1707, Test Accuracy: 43.57%
#     Worker 0: Train Loss: 2.1237, Train Accuracy: 43.87%
#     Worker 1: Train Loss: 2.1332, Train Accuracy: 43.37%
#     Worker 2: Train Loss: 2.1084, Train Accuracy: 44.50%
#     Worker 3: Train Loss: 2.1485, Train Accuracy: 43.33%
# Epoch 52/150: Test Loss: 2.0905, Test Accuracy: 45.37%
#     Worker 0: Train Loss: 1.9319, Train Accuracy: 47.78%
#     Worker 1: Train Loss: 1.9380, Train Accuracy: 47.83%
#     Worker 2: Train Loss: 1.9186, Train Accuracy: 48.56%
#     Worker 3: Train Loss: 1.9407, Train Accuracy: 48.08%
# Epoch 53/150: Test Loss: 2.0909, Test Accuracy: 45.57%
#     Worker 0: Train Loss: 1.9219, Train Accuracy: 48.27%
#     Worker 1: Train Loss: 1.9144, Train Accuracy: 48.23%
#     Worker 2: Train Loss: 1.9112, Train Accuracy: 48.70%
#     Worker 3: Train Loss: 1.9220, Train Accuracy: 48.70%
# Epoch 54/150: Test Loss: 2.0715, Test Accuracy: 45.79%
#     Worker 0: Train Loss: 1.9134, Train Accuracy: 48.23%
#     Worker 1: Train Loss: 1.9143, Train Accuracy: 48.81%
#     Worker 2: Train Loss: 1.8941, Train Accuracy: 48.76%
#     Worker 3: Train Loss: 1.9064, Train Accuracy: 48.61%
# Epoch 55/150: Test Loss: 2.0448, Test Accuracy: 47.16%
#     Worker 0: Train Loss: 1.8887, Train Accuracy: 48.91%
#     Worker 1: Train Loss: 1.9003, Train Accuracy: 48.82%
#     Worker 2: Train Loss: 1.8926, Train Accuracy: 49.07%
#     Worker 3: Train Loss: 1.8922, Train Accuracy: 48.90%
# Epoch 56/150: Test Loss: 2.0580, Test Accuracy: 46.66%
#     Worker 0: Train Loss: 1.8770, Train Accuracy: 48.71%
#     Worker 1: Train Loss: 1.8710, Train Accuracy: 49.64%
#     Worker 2: Train Loss: 1.8520, Train Accuracy: 49.94%
#     Worker 3: Train Loss: 1.8801, Train Accuracy: 49.54%
# Epoch 57/150: Test Loss: 2.0402, Test Accuracy: 46.87%
#     Worker 0: Train Loss: 1.8581, Train Accuracy: 49.62%
#     Worker 1: Train Loss: 1.8717, Train Accuracy: 49.16%
#     Worker 2: Train Loss: 1.8318, Train Accuracy: 50.54%
#     Worker 3: Train Loss: 1.8637, Train Accuracy: 49.89%
# Epoch 58/150: Test Loss: 2.0478, Test Accuracy: 46.70%
#     Worker 0: Train Loss: 1.8457, Train Accuracy: 49.86%
#     Worker 1: Train Loss: 1.8502, Train Accuracy: 49.99%
#     Worker 2: Train Loss: 1.8375, Train Accuracy: 50.11%
#     Worker 3: Train Loss: 1.8484, Train Accuracy: 50.18%
# Epoch 59/150: Test Loss: 2.0344, Test Accuracy: 47.07%
#     Worker 0: Train Loss: 1.8290, Train Accuracy: 50.39%
#     Worker 1: Train Loss: 1.8349, Train Accuracy: 50.44%
#     Worker 2: Train Loss: 1.8190, Train Accuracy: 50.92%
#     Worker 3: Train Loss: 1.8356, Train Accuracy: 49.79%
# Epoch 60/150: Test Loss: 2.0420, Test Accuracy: 46.96%
#     Worker 0: Train Loss: 1.7973, Train Accuracy: 51.48%
#     Worker 1: Train Loss: 1.8168, Train Accuracy: 50.82%
#     Worker 2: Train Loss: 1.8055, Train Accuracy: 51.07%
#     Worker 3: Train Loss: 1.8322, Train Accuracy: 50.35%
# Epoch 79/150: Test Loss: 1.9704, Test Accuracy: 49.25%
#     Worker 0: Train Loss: 1.5725, Train Accuracy: 56.04%
#     Worker 1: Train Loss: 1.5639, Train Accuracy: 57.45%
#     Worker 2: Train Loss: 1.5577, Train Accuracy: 56.32%
#     Worker 3: Train Loss: 1.5649, Train Accuracy: 56.43%
# Epoch 80/150: Test Loss: 1.9743, Test Accuracy: 49.11%
#     Worker 0: Train Loss: 1.5679, Train Accuracy: 56.06%
#     Worker 1: Train Loss: 1.5696, Train Accuracy: 56.54%
#     Worker 2: Train Loss: 1.5521, Train Accuracy: 56.93%
#     Worker 3: Train Loss: 1.5721, Train Accuracy: 56.47%
# Epoch 81/150: Test Loss: 1.9776, Test Accuracy: 49.32%
#     Worker 0: Train Loss: 1.5535, Train Accuracy: 56.92%
#     Worker 1: Train Loss: 1.5334, Train Accuracy: 57.54%
#     Worker 2: Train Loss: 1.5490, Train Accuracy: 56.86%
#     Worker 3: Train Loss: 1.5561, Train Accuracy: 56.89%
# Epoch 82/150: Test Loss: 1.9613, Test Accuracy: 50.01%
#     Worker 0: Train Loss: 1.5349, Train Accuracy: 56.86%
#     Worker 1: Train Loss: 1.5337, Train Accuracy: 57.80%
#     Worker 2: Train Loss: 1.5383, Train Accuracy: 56.89%
#     Worker 3: Train Loss: 1.5393, Train Accuracy: 57.10%
# Epoch 83/150: Test Loss: 1.9770, Test Accuracy: 49.41%
#     Worker 0: Train Loss: 1.5166, Train Accuracy: 57.43%
#     Worker 1: Train Loss: 1.5262, Train Accuracy: 57.74%
#     Worker 2: Train Loss: 1.5215, Train Accuracy: 57.82%
#     Worker 3: Train Loss: 1.5440, Train Accuracy: 56.78%
# Epoch 84/150: Test Loss: 1.9701, Test Accuracy: 49.33%
#     Worker 0: Train Loss: 1.5198, Train Accuracy: 57.26%
#     Worker 1: Train Loss: 1.5224, Train Accuracy: 57.74%
#     Worker 2: Train Loss: 1.5123, Train Accuracy: 57.92%
#     Worker 3: Train Loss: 1.5384, Train Accuracy: 57.50%
# Epoch 85/150: Test Loss: 1.9748, Test Accuracy: 49.21%
#     Worker 0: Train Loss: 1.5089, Train Accuracy: 57.56%
#     Worker 1: Train Loss: 1.5152, Train Accuracy: 58.58%
#     Worker 2: Train Loss: 1.5101, Train Accuracy: 58.54%
#     Worker 3: Train Loss: 1.5189, Train Accuracy: 57.41%
# Epoch 86/150: Test Loss: 1.9575, Test Accuracy: 50.37%
#     Worker 0: Train Loss: 1.5042, Train Accuracy: 57.74%
#     Worker 1: Train Loss: 1.5089, Train Accuracy: 57.73%
#     Worker 2: Train Loss: 1.4940, Train Accuracy: 58.08%
#     Worker 3: Train Loss: 1.5050, Train Accuracy: 57.96%
# Epoch 87/150: Test Loss: 1.9721, Test Accuracy: 50.02%
#     Worker 0: Train Loss: 1.4894, Train Accuracy: 58.15%
#     Worker 1: Train Loss: 1.4899, Train Accuracy: 58.41%
#     Worker 2: Train Loss: 1.4817, Train Accuracy: 58.68%
#     Worker 3: Train Loss: 1.5155, Train Accuracy: 57.69%
# Epoch 88/150: Test Loss: 1.9615, Test Accuracy: 49.85%
#     Worker 0: Train Loss: 1.4623, Train Accuracy: 59.22%
#     Worker 1: Train Loss: 1.4905, Train Accuracy: 58.98%
#     Worker 2: Train Loss: 1.4726, Train Accuracy: 58.99%
#     Worker 3: Train Loss: 1.4817, Train Accuracy: 58.53%
# Epoch 89/150: Test Loss: 1.9503, Test Accuracy: 50.14%
#     Worker 0: Train Loss: 1.4683, Train Accuracy: 58.46%
#     Worker 1: Train Loss: 1.4702, Train Accuracy: 59.35%
#     Worker 2: Train Loss: 1.4603, Train Accuracy: 59.68%
#     Worker 3: Train Loss: 1.4751, Train Accuracy: 58.70%
# Epoch 90/150: Test Loss: 1.9549, Test Accuracy: 50.27%
#     Worker 0: Train Loss: 1.4503, Train Accuracy: 58.81%
#     Worker 1: Train Loss: 1.4729, Train Accuracy: 59.49%
#     Worker 2: Train Loss: 1.4668, Train Accuracy: 59.14%
#     Worker 3: Train Loss: 1.4736, Train Accuracy: 59.04%
# Epoch 91/150: Test Loss: 1.9541, Test Accuracy: 49.92%
#     Worker 0: Train Loss: 1.4552, Train Accuracy: 58.81%
#     Worker 1: Train Loss: 1.4549, Train Accuracy: 59.31%
#     Worker 2: Train Loss: 1.4420, Train Accuracy: 59.90%
#     Worker 3: Train Loss: 1.4597, Train Accuracy: 59.06%
# Epoch 92/150: Test Loss: 1.9499, Test Accuracy: 50.43%
#     Worker 0: Train Loss: 1.4538, Train Accuracy: 59.07%
#     Worker 1: Train Loss: 1.4446, Train Accuracy: 59.94%
#     Worker 2: Train Loss: 1.4386, Train Accuracy: 59.55%
#     Worker 3: Train Loss: 1.4543, Train Accuracy: 59.32%
# Epoch 93/150: Test Loss: 1.9550, Test Accuracy: 50.30%
#     Worker 0: Train Loss: 1.4449, Train Accuracy: 59.68%
#     Worker 1: Train Loss: 1.4433, Train Accuracy: 59.70%
#     Worker 2: Train Loss: 1.4194, Train Accuracy: 60.10%
#     Worker 3: Train Loss: 1.4430, Train Accuracy: 59.87%
# Epoch 94/150: Test Loss: 1.9463, Test Accuracy: 50.44%
#     Worker 0: Train Loss: 1.4159, Train Accuracy: 59.68%
#     Worker 1: Train Loss: 1.4128, Train Accuracy: 60.53%
#     Worker 2: Train Loss: 1.4172, Train Accuracy: 60.15%
#     Worker 3: Train Loss: 1.4409, Train Accuracy: 59.66%
# Epoch 95/150: Test Loss: 1.9470, Test Accuracy: 50.67%
#     Worker 0: Train Loss: 1.4154, Train Accuracy: 60.10%
#     Worker 1: Train Loss: 1.4301, Train Accuracy: 60.02%
#     Worker 2: Train Loss: 1.4152, Train Accuracy: 60.12%
#     Worker 3: Train Loss: 1.4163, Train Accuracy: 60.27%
# Epoch 96/150: Test Loss: 1.9491, Test Accuracy: 50.74%
#     Worker 0: Train Loss: 1.4157, Train Accuracy: 60.43%
#     Worker 1: Train Loss: 1.4008, Train Accuracy: 60.90%
#     Worker 2: Train Loss: 1.3930, Train Accuracy: 60.92%
#     Worker 3: Train Loss: 1.4122, Train Accuracy: 60.41%
# Epoch 97/150: Test Loss: 1.9424, Test Accuracy: 50.79%
#     Worker 0: Train Loss: 1.3899, Train Accuracy: 60.30%
#     Worker 1: Train Loss: 1.4114, Train Accuracy: 60.46%
#     Worker 2: Train Loss: 1.3955, Train Accuracy: 60.99%
#     Worker 3: Train Loss: 1.4122, Train Accuracy: 60.80%
# Epoch 98/150: Test Loss: 1.9512, Test Accuracy: 50.73%
#     Worker 0: Train Loss: 1.3893, Train Accuracy: 60.54%
#     Worker 1: Train Loss: 1.3840, Train Accuracy: 61.30%
#     Worker 2: Train Loss: 1.3825, Train Accuracy: 60.90%
#     Worker 3: Train Loss: 1.3974, Train Accuracy: 61.22%
# Epoch 99/150: Test Loss: 1.9513, Test Accuracy: 50.38%
#     Worker 0: Train Loss: 1.3800, Train Accuracy: 60.90%
#     Worker 1: Train Loss: 1.3713, Train Accuracy: 61.82%
#     Worker 2: Train Loss: 1.3913, Train Accuracy: 61.20%
#     Worker 3: Train Loss: 1.3994, Train Accuracy: 60.79%
# Epoch 100/150: Test Loss: 1.9508, Test Accuracy: 50.71%
#     Worker 0: Train Loss: 1.3789, Train Accuracy: 61.08%
#     Worker 1: Train Loss: 1.3799, Train Accuracy: 61.38%
#     Worker 2: Train Loss: 1.3758, Train Accuracy: 61.27%
#     Worker 3: Train Loss: 1.3869, Train Accuracy: 60.81%
# Epoch 101/150: Test Loss: 1.9600, Test Accuracy: 50.57%
#     Worker 0: Train Loss: 1.3634, Train Accuracy: 61.33%
#     Worker 1: Train Loss: 1.3823, Train Accuracy: 61.11%
#     Worker 2: Train Loss: 1.3639, Train Accuracy: 61.79%
#     Worker 3: Train Loss: 1.3709, Train Accuracy: 61.24%
# Epoch 102/150: Test Loss: 1.9419, Test Accuracy: 51.04%
#     Worker 0: Train Loss: 1.3535, Train Accuracy: 61.78%
#     Worker 1: Train Loss: 1.3661, Train Accuracy: 61.64%
#     Worker 2: Train Loss: 1.3428, Train Accuracy: 61.72%
#     Worker 3: Train Loss: 1.3747, Train Accuracy: 61.71%
# Epoch 103/150: Test Loss: 1.9542, Test Accuracy: 50.92%
#     Worker 0: Train Loss: 1.3616, Train Accuracy: 61.47%
#     Worker 1: Train Loss: 1.3495, Train Accuracy: 62.39%
#     Worker 2: Train Loss: 1.3439, Train Accuracy: 62.15%
#     Worker 3: Train Loss: 1.3707, Train Accuracy: 61.24%
# Epoch 104/150: Test Loss: 1.9532, Test Accuracy: 50.87%
#     Worker 0: Train Loss: 1.3419, Train Accuracy: 62.03%
#     Worker 1: Train Loss: 1.3477, Train Accuracy: 62.23%
#     Worker 2: Train Loss: 1.3518, Train Accuracy: 62.38%
#     Worker 3: Train Loss: 1.3564, Train Accuracy: 62.31%
# Epoch 105/150: Test Loss: 1.9515, Test Accuracy: 51.15%
#     Worker 0: Train Loss: 1.3385, Train Accuracy: 61.56%
#     Worker 1: Train Loss: 1.3440, Train Accuracy: 62.51%
#     Worker 2: Train Loss: 1.3440, Train Accuracy: 62.32%
#     Worker 3: Train Loss: 1.3457, Train Accuracy: 62.28%
# Epoch 106/150: Test Loss: 1.9509, Test Accuracy: 50.65%
#     Worker 0: Train Loss: 1.3322, Train Accuracy: 61.81%
#     Worker 1: Train Loss: 1.3244, Train Accuracy: 62.64%
#     Worker 2: Train Loss: 1.3266, Train Accuracy: 62.89%
#     Worker 3: Train Loss: 1.3519, Train Accuracy: 62.06%
# Epoch 107/150: Test Loss: 1.9540, Test Accuracy: 50.69%
#     Worker 0: Train Loss: 1.3192, Train Accuracy: 62.62%
#     Worker 1: Train Loss: 1.3432, Train Accuracy: 62.42%
#     Worker 2: Train Loss: 1.3317, Train Accuracy: 62.76%
#     Worker 3: Train Loss: 1.3382, Train Accuracy: 61.93%
# Epoch 108/150: Test Loss: 1.9532, Test Accuracy: 50.75%
#     Worker 0: Train Loss: 1.3111, Train Accuracy: 62.43%
#     Worker 1: Train Loss: 1.3227, Train Accuracy: 62.57%
#     Worker 2: Train Loss: 1.3055, Train Accuracy: 63.26%
#     Worker 3: Train Loss: 1.3346, Train Accuracy: 62.56%
# Epoch 109/150: Test Loss: 1.9559, Test Accuracy: 51.33%
#     Worker 0: Train Loss: 1.3210, Train Accuracy: 62.76%
#     Worker 1: Train Loss: 1.3130, Train Accuracy: 63.27%
#     Worker 2: Train Loss: 1.3148, Train Accuracy: 62.86%
#     Worker 3: Train Loss: 1.3302, Train Accuracy: 62.17%
# Epoch 110/150: Test Loss: 1.9522, Test Accuracy: 51.04%
#     Worker 0: Train Loss: 1.3034, Train Accuracy: 62.79%
#     Worker 1: Train Loss: 1.3098, Train Accuracy: 63.22%
#     Worker 2: Train Loss: 1.2918, Train Accuracy: 63.64%
#     Worker 3: Train Loss: 1.3173, Train Accuracy: 62.85%
# Epoch 111/150: Test Loss: 1.9555, Test Accuracy: 51.09%
#     Worker 0: Train Loss: 1.3055, Train Accuracy: 63.01%
#     Worker 1: Train Loss: 1.2981, Train Accuracy: 63.33%
#     Worker 2: Train Loss: 1.2894, Train Accuracy: 63.64%
#     Worker 3: Train Loss: 1.3061, Train Accuracy: 62.92%
# Epoch 112/150: Test Loss: 1.9573, Test Accuracy: 51.18%
#     Worker 0: Train Loss: 1.2975, Train Accuracy: 63.04%
#     Worker 1: Train Loss: 1.3044, Train Accuracy: 63.39%
#     Worker 2: Train Loss: 1.2874, Train Accuracy: 64.06%
#     Worker 3: Train Loss: 1.3131, Train Accuracy: 62.88%
# Epoch 113/150: Test Loss: 1.9510, Test Accuracy: 50.96%
#     Worker 0: Train Loss: 1.2864, Train Accuracy: 63.44%
#     Worker 1: Train Loss: 1.2850, Train Accuracy: 63.90%
#     Worker 2: Train Loss: 1.2908, Train Accuracy: 63.65%
#     Worker 3: Train Loss: 1.3101, Train Accuracy: 63.23%
# Epoch 114/150: Test Loss: 1.9495, Test Accuracy: 51.53%
#     Worker 0: Train Loss: 1.2787, Train Accuracy: 63.35%
#     Worker 1: Train Loss: 1.2834, Train Accuracy: 63.71%
#     Worker 2: Train Loss: 1.2913, Train Accuracy: 63.53%
#     Worker 3: Train Loss: 1.2833, Train Accuracy: 63.51%
# Epoch 115/150: Test Loss: 1.9614, Test Accuracy: 51.11%
#     Worker 0: Train Loss: 1.2774, Train Accuracy: 64.02%
#     Worker 1: Train Loss: 1.2850, Train Accuracy: 64.01%
#     Worker 2: Train Loss: 1.2655, Train Accuracy: 64.06%
#     Worker 3: Train Loss: 1.2988, Train Accuracy: 63.00%
# Epoch 116/150: Test Loss: 1.9540, Test Accuracy: 51.46%
#     Worker 0: Train Loss: 1.2687, Train Accuracy: 63.80%
#     Worker 1: Train Loss: 1.2682, Train Accuracy: 63.94%
#     Worker 2: Train Loss: 1.2767, Train Accuracy: 63.89%
#     Worker 3: Train Loss: 1.2837, Train Accuracy: 63.87%
# Epoch 117/150: Test Loss: 1.9519, Test Accuracy: 51.21%
#     Worker 0: Train Loss: 1.2542, Train Accuracy: 64.07%
#     Worker 1: Train Loss: 1.2708, Train Accuracy: 64.34%
#     Worker 2: Train Loss: 1.2842, Train Accuracy: 63.79%
#     Worker 3: Train Loss: 1.2895, Train Accuracy: 63.23%
# Epoch 118/150: Test Loss: 1.9575, Test Accuracy: 51.38%
#     Worker 0: Train Loss: 1.2575, Train Accuracy: 64.26%
#     Worker 1: Train Loss: 1.2723, Train Accuracy: 64.23%
#     Worker 2: Train Loss: 1.2594, Train Accuracy: 64.70%
#     Worker 3: Train Loss: 1.2823, Train Accuracy: 63.98%
# Epoch 119/150: Test Loss: 1.9517, Test Accuracy: 51.51%
#     Worker 0: Train Loss: 1.2543, Train Accuracy: 64.31%
#     Worker 1: Train Loss: 1.2605, Train Accuracy: 64.75%
#     Worker 2: Train Loss: 1.2495, Train Accuracy: 64.71%
#     Worker 3: Train Loss: 1.2735, Train Accuracy: 63.98%
# Epoch 120/150: Test Loss: 1.9485, Test Accuracy: 51.31%
#     Worker 0: Train Loss: 1.2411, Train Accuracy: 64.74%
#     Worker 1: Train Loss: 1.2577, Train Accuracy: 64.32%
#     Worker 2: Train Loss: 1.2645, Train Accuracy: 64.54%
#     Worker 3: Train Loss: 1.2599, Train Accuracy: 64.02%
# Epoch 121/150: Test Loss: 1.9474, Test Accuracy: 51.53%
#     Worker 0: Train Loss: 1.2483, Train Accuracy: 64.20%
#     Worker 1: Train Loss: 1.2545, Train Accuracy: 64.50%
#     Worker 2: Train Loss: 1.2511, Train Accuracy: 64.70%
#     Worker 3: Train Loss: 1.2521, Train Accuracy: 64.56%
# Epoch 122/150: Test Loss: 1.9546, Test Accuracy: 51.44%
#     Worker 0: Train Loss: 1.2312, Train Accuracy: 64.93%
#     Worker 1: Train Loss: 1.2467, Train Accuracy: 64.78%
#     Worker 2: Train Loss: 1.2489, Train Accuracy: 64.51%
#     Worker 3: Train Loss: 1.2619, Train Accuracy: 64.04%
# Epoch 123/150: Test Loss: 1.9493, Test Accuracy: 51.54%
#     Worker 0: Train Loss: 1.2494, Train Accuracy: 64.34%
#     Worker 1: Train Loss: 1.2431, Train Accuracy: 65.12%
#     Worker 2: Train Loss: 1.2371, Train Accuracy: 65.07%
#     Worker 3: Train Loss: 1.2445, Train Accuracy: 65.45%
# Epoch 124/150: Test Loss: 1.9484, Test Accuracy: 51.63%
#     Worker 0: Train Loss: 1.2333, Train Accuracy: 65.23%
#     Worker 1: Train Loss: 1.2314, Train Accuracy: 65.65%
#     Worker 2: Train Loss: 1.2453, Train Accuracy: 64.69%
#     Worker 3: Train Loss: 1.2484, Train Accuracy: 64.98%
# Epoch 125/150: Test Loss: 1.9579, Test Accuracy: 51.52%
#     Worker 0: Train Loss: 1.2285, Train Accuracy: 64.63%
#     Worker 1: Train Loss: 1.2344, Train Accuracy: 65.02%
#     Worker 2: Train Loss: 1.2281, Train Accuracy: 65.38%
#     Worker 3: Train Loss: 1.2477, Train Accuracy: 64.90%
# Epoch 126/150: Test Loss: 1.9494, Test Accuracy: 51.46%
#     Worker 0: Train Loss: 1.2271, Train Accuracy: 65.02%
#     Worker 1: Train Loss: 1.2480, Train Accuracy: 65.10%
#     Worker 2: Train Loss: 1.2368, Train Accuracy: 64.94%
#     Worker 3: Train Loss: 1.2610, Train Accuracy: 64.05%
# Epoch 127/150: Test Loss: 1.9566, Test Accuracy: 51.68%
#     Worker 0: Train Loss: 1.2351, Train Accuracy: 64.77%
#     Worker 1: Train Loss: 1.2308, Train Accuracy: 65.25%
#     Worker 2: Train Loss: 1.2291, Train Accuracy: 65.30%
#     Worker 3: Train Loss: 1.2467, Train Accuracy: 64.68%
# Epoch 128/150: Test Loss: 1.9520, Test Accuracy: 51.45%
#     Worker 0: Train Loss: 1.2250, Train Accuracy: 65.42%
#     Worker 1: Train Loss: 1.2250, Train Accuracy: 65.54%
#     Worker 2: Train Loss: 1.2250, Train Accuracy: 65.41%
#     Worker 3: Train Loss: 1.2423, Train Accuracy: 64.75%
# Epoch 129/150: Test Loss: 1.9483, Test Accuracy: 51.36%
#     Worker 0: Train Loss: 1.2334, Train Accuracy: 65.16%
#     Worker 1: Train Loss: 1.2236, Train Accuracy: 65.50%
#     Worker 2: Train Loss: 1.2249, Train Accuracy: 65.34%
#     Worker 3: Train Loss: 1.2312, Train Accuracy: 65.16%
# Epoch 130/150: Test Loss: 1.9514, Test Accuracy: 51.41%
#     Worker 0: Train Loss: 1.2083, Train Accuracy: 65.60%
#     Worker 1: Train Loss: 1.2201, Train Accuracy: 65.75%
#     Worker 2: Train Loss: 1.2193, Train Accuracy: 65.74%
#     Worker 3: Train Loss: 1.2196, Train Accuracy: 65.46%
# Epoch 131/150: Test Loss: 1.9492, Test Accuracy: 51.59%
#     Worker 0: Train Loss: 1.2178, Train Accuracy: 65.43%
#     Worker 1: Train Loss: 1.2281, Train Accuracy: 65.86%
#     Worker 2: Train Loss: 1.2093, Train Accuracy: 66.22%
#     Worker 3: Train Loss: 1.2504, Train Accuracy: 64.63%
# Epoch 132/150: Test Loss: 1.9482, Test Accuracy: 51.73%
#     Worker 0: Train Loss: 1.2281, Train Accuracy: 65.22%
#     Worker 1: Train Loss: 1.2228, Train Accuracy: 65.31%
#     Worker 2: Train Loss: 1.2113, Train Accuracy: 65.52%
#     Worker 3: Train Loss: 1.2342, Train Accuracy: 65.19%
# Epoch 133/150: Test Loss: 1.9480, Test Accuracy: 51.66%
#     Worker 0: Train Loss: 1.2099, Train Accuracy: 65.76%
#     Worker 1: Train Loss: 1.2105, Train Accuracy: 65.58%
#     Worker 2: Train Loss: 1.2169, Train Accuracy: 65.78%
#     Worker 3: Train Loss: 1.2224, Train Accuracy: 65.49%
# Epoch 134/150: Test Loss: 1.9493, Test Accuracy: 51.82%
#     Worker 0: Train Loss: 1.2105, Train Accuracy: 65.70%
#     Worker 1: Train Loss: 1.2155, Train Accuracy: 66.00%
#     Worker 2: Train Loss: 1.2045, Train Accuracy: 65.93%
#     Worker 3: Train Loss: 1.2250, Train Accuracy: 65.42%
# Epoch 135/150: Test Loss: 1.9483, Test Accuracy: 51.67%
#     Worker 0: Train Loss: 1.2188, Train Accuracy: 65.82%
#     Worker 1: Train Loss: 1.2163, Train Accuracy: 66.35%
#     Worker 2: Train Loss: 1.2059, Train Accuracy: 66.06%
#     Worker 3: Train Loss: 1.2200, Train Accuracy: 65.50%
# Epoch 136/150: Test Loss: 1.9481, Test Accuracy: 51.77%
#     Worker 0: Train Loss: 1.2028, Train Accuracy: 65.82%
#     Worker 1: Train Loss: 1.2196, Train Accuracy: 65.67%
#     Worker 2: Train Loss: 1.2036, Train Accuracy: 66.62%
#     Worker 3: Train Loss: 1.2141, Train Accuracy: 65.87%
# Epoch 137/150: Test Loss: 1.9462, Test Accuracy: 51.67%
#     Worker 0: Train Loss: 1.2237, Train Accuracy: 64.90%
#     Worker 1: Train Loss: 1.2164, Train Accuracy: 65.98%
#     Worker 2: Train Loss: 1.1894, Train Accuracy: 66.47%
#     Worker 3: Train Loss: 1.2248, Train Accuracy: 65.45%
# Epoch 138/150: Test Loss: 1.9463, Test Accuracy: 51.52%
#     Worker 0: Train Loss: 1.2084, Train Accuracy: 65.32%
#     Worker 1: Train Loss: 1.2057, Train Accuracy: 66.35%
#     Worker 2: Train Loss: 1.2115, Train Accuracy: 65.66%
#     Worker 3: Train Loss: 1.2111, Train Accuracy: 65.35%
# Epoch 139/150: Test Loss: 1.9467, Test Accuracy: 51.81%
#     Worker 0: Train Loss: 1.1998, Train Accuracy: 65.82%
#     Worker 1: Train Loss: 1.2040, Train Accuracy: 66.15%
#     Worker 2: Train Loss: 1.2000, Train Accuracy: 65.68%
#     Worker 3: Train Loss: 1.2249, Train Accuracy: 65.72%
# Epoch 140/150: Test Loss: 1.9456, Test Accuracy: 51.77%
#     Worker 0: Train Loss: 1.2015, Train Accuracy: 65.86%
#     Worker 1: Train Loss: 1.2078, Train Accuracy: 66.28%
#     Worker 2: Train Loss: 1.2083, Train Accuracy: 66.11%
#     Worker 3: Train Loss: 1.2118, Train Accuracy: 65.54%
# Epoch 141/150: Test Loss: 1.9474, Test Accuracy: 51.81%
#     Worker 0: Train Loss: 1.2002, Train Accuracy: 66.10%
#     Worker 1: Train Loss: 1.1969, Train Accuracy: 66.64%
#     Worker 2: Train Loss: 1.2002, Train Accuracy: 65.61%
#     Worker 3: Train Loss: 1.2119, Train Accuracy: 65.97%
# Epoch 142/150: Test Loss: 1.9475, Test Accuracy: 51.73%
#     Worker 0: Train Loss: 1.1959, Train Accuracy: 65.86%
#     Worker 1: Train Loss: 1.2010, Train Accuracy: 65.86%
#     Worker 2: Train Loss: 1.1879, Train Accuracy: 66.39%
#     Worker 3: Train Loss: 1.2053, Train Accuracy: 65.90%
# Epoch 143/150: Test Loss: 1.9468, Test Accuracy: 51.64%
#     Worker 0: Train Loss: 1.2060, Train Accuracy: 65.66%
#     Worker 1: Train Loss: 1.1976, Train Accuracy: 66.02%
#     Worker 2: Train Loss: 1.1867, Train Accuracy: 66.38%
#     Worker 3: Train Loss: 1.2106, Train Accuracy: 66.10%
# Epoch 144/150: Test Loss: 1.9475, Test Accuracy: 51.73%
#     Worker 0: Train Loss: 1.2000, Train Accuracy: 65.67%
#     Worker 1: Train Loss: 1.2016, Train Accuracy: 66.44%
#     Worker 2: Train Loss: 1.1976, Train Accuracy: 66.44%
#     Worker 3: Train Loss: 1.2086, Train Accuracy: 65.57%
# Epoch 145/150: Test Loss: 1.9466, Test Accuracy: 51.82%
#     Worker 0: Train Loss: 1.1962, Train Accuracy: 65.56%
#     Worker 1: Train Loss: 1.1954, Train Accuracy: 66.38%
#     Worker 2: Train Loss: 1.1959, Train Accuracy: 65.99%
#     Worker 3: Train Loss: 1.1951, Train Accuracy: 65.86%
# Epoch 146/150: Test Loss: 1.9473, Test Accuracy: 51.75%
#     Worker 0: Train Loss: 1.1837, Train Accuracy: 65.96%
#     Worker 1: Train Loss: 1.1927, Train Accuracy: 66.46%
#     Worker 2: Train Loss: 1.1864, Train Accuracy: 66.69%
#     Worker 3: Train Loss: 1.2078, Train Accuracy: 65.98%
# Epoch 147/150: Test Loss: 1.9469, Test Accuracy: 51.74%
#     Worker 0: Train Loss: 1.2031, Train Accuracy: 65.77%
#     Worker 1: Train Loss: 1.2073, Train Accuracy: 66.17%
#     Worker 2: Train Loss: 1.2120, Train Accuracy: 65.58%
#     Worker 3: Train Loss: 1.2129, Train Accuracy: 66.01%
# Epoch 148/150: Test Loss: 1.9470, Test Accuracy: 51.75%
#     Worker 0: Train Loss: 1.1901, Train Accuracy: 66.27%
#     Worker 1: Train Loss: 1.2051, Train Accuracy: 66.46%
#     Worker 2: Train Loss: 1.1866, Train Accuracy: 66.59%
#     Worker 3: Train Loss: 1.2040, Train Accuracy: 65.87%
# Epoch 149/150: Test Loss: 1.9470, Test Accuracy: 51.78%
#     Worker 0: Train Loss: 1.1845, Train Accuracy: 66.53%
#     Worker 1: Train Loss: 1.1907, Train Accuracy: 66.79%
#     Worker 2: Train Loss: 1.1954, Train Accuracy: 66.20%
#     Worker 3: Train Loss: 1.2018, Train Accuracy: 65.93%
# Epoch 150/150: Test Loss: 1.9470, Test Accuracy: 51.77%
#     Worker 0: Train Loss: 1.2068, Train Accuracy: 65.57%
#     Worker 1: Train Loss: 1.2014, Train Accuracy: 66.12%
#     Worker 2: Train Loss: 1.1861, Train Accuracy: 66.95%
#     Worker 3: Train Loss: 1.2003, Train Accuracy: 65.55%
