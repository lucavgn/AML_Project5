# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs - warmup_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")

    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch):
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            # Perform J local step before synchronization
            for j in range(J):
                try:
                    # Get a batch from the current worker's shard using next()
                    images, labels = next(shard_iterators[k])
                    images, labels = images.to(device), labels.to(device)  # Move to device
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

                except StopIteration:
                    # If the iterator has exhausted the data, restart the iterator
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k]) # Resume from the next batch
                    images, labels = images.to(device), labels.to(device)
                    # Perform optimization step
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        # Perform model synchronization
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            # Update each worker model with the global parameters
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
        else:
            warmup_factor = (epoch + 1) / warmup_epochs
            lr = warmup_factor * learning_rate
            for optimizer in optimizers:
                for param_group in optimizer.param_groups:
                    param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Overwriting localSGD.py

# %%
# %run localSGD.py --k 4 --j 64
# Out:
# Training with K=4, J=64
# Global iteration per epoch: 4
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00400
# Epoch 1/150: Test Loss: 4.5519, Test Accuracy: 3.19%
#     Worker 0: Train Loss: 4.5942, Train Accuracy: 1.51%
#     Worker 1: Train Loss: 4.5939, Train Accuracy: 1.44%
#     Worker 2: Train Loss: 4.5922, Train Accuracy: 1.83%
#     Worker 3: Train Loss: 4.5941, Train Accuracy: 1.53%
# Epoch 2/150: Test Loss: 4.4620, Test Accuracy: 4.03%
#     Worker 0: Train Loss: 4.5204, Train Accuracy: 2.94%
#     Worker 1: Train Loss: 4.5207, Train Accuracy: 3.08%
#     Worker 2: Train Loss: 4.5137, Train Accuracy: 3.21%
#     Worker 3: Train Loss: 4.5184, Train Accuracy: 3.31%
# Epoch 3/150: Test Loss: 4.1441, Test Accuracy: 7.35%
#     Worker 0: Train Loss: 4.3239, Train Accuracy: 4.63%
#     Worker 1: Train Loss: 4.3378, Train Accuracy: 4.62%
#     Worker 2: Train Loss: 4.3086, Train Accuracy: 5.03%
#     Worker 3: Train Loss: 4.3287, Train Accuracy: 4.78%
# Epoch 4/150: Test Loss: 3.9805, Test Accuracy: 9.45%
#     Worker 0: Train Loss: 4.1221, Train Accuracy: 7.05%
#     Worker 1: Train Loss: 4.1332, Train Accuracy: 6.45%
#     Worker 2: Train Loss: 4.1053, Train Accuracy: 6.92%
#     Worker 3: Train Loss: 4.1320, Train Accuracy: 6.93%
# Epoch 5/150: Test Loss: 3.8358, Test Accuracy: 11.89%
#     Worker 0: Train Loss: 4.0166, Train Accuracy: 8.18%
#     Worker 1: Train Loss: 4.0021, Train Accuracy: 8.58%
#     Worker 2: Train Loss: 3.9623, Train Accuracy: 9.31%
#     Worker 3: Train Loss: 4.0158, Train Accuracy: 8.14%
# Epoch 6/150: Test Loss: 3.6914, Test Accuracy: 14.49%
#     Worker 0: Train Loss: 3.8774, Train Accuracy: 10.60%
#     Worker 1: Train Loss: 3.8928, Train Accuracy: 10.55%
#     Worker 2: Train Loss: 3.8534, Train Accuracy: 10.67%
#     Worker 3: Train Loss: 3.8736, Train Accuracy: 10.37%
# Epoch 7/150: Test Loss: 3.5580, Test Accuracy: 16.67%
#     Worker 0: Train Loss: 3.7413, Train Accuracy: 12.11%
#     Worker 1: Train Loss: 2.2941, Train Accuracy: 39.83%
#     Worker 2: Train Loss: 2.2616, Train Accuracy: 40.83%
#     Worker 3: Train Loss: 2.2912, Train Accuracy: 39.46%
# Epoch 35/150: Test Loss: 2.2013, Test Accuracy: 42.77%
#     Worker 0: Train Loss: 2.2621, Train Accuracy: 40.39%
#     Worker 1: Train Loss: 2.2672, Train Accuracy: 40.58%
#     Worker 2: Train Loss: 2.2635, Train Accuracy: 40.86%
#     Worker 3: Train Loss: 2.2892, Train Accuracy: 39.83%
# Epoch 36/150: Test Loss: 2.1778, Test Accuracy: 43.41%
#     Worker 0: Train Loss: 2.2237, Train Accuracy: 41.22%
#     Worker 1: Train Loss: 2.2486, Train Accuracy: 40.56%
#     Worker 2: Train Loss: 2.2214, Train Accuracy: 41.65%
#     Worker 3: Train Loss: 2.2536, Train Accuracy: 40.27%
# Epoch 37/150: Test Loss: 2.1635, Test Accuracy: 43.42%
#     Worker 0: Train Loss: 2.2192, Train Accuracy: 41.38%
#     Worker 1: Train Loss: 2.2239, Train Accuracy: 41.19%
#     Worker 2: Train Loss: 2.2011, Train Accuracy: 42.02%
#     Worker 3: Train Loss: 2.2306, Train Accuracy: 41.14%
# Epoch 38/150: Test Loss: 2.1565, Test Accuracy: 44.00%
#     Worker 0: Train Loss: 2.1985, Train Accuracy: 41.41%
#     Worker 1: Train Loss: 2.2007, Train Accuracy: 41.74%
#     Worker 2: Train Loss: 2.1480, Train Accuracy: 42.69%
#     Worker 3: Train Loss: 2.1923, Train Accuracy: 41.79%
# Epoch 39/150: Test Loss: 2.1484, Test Accuracy: 43.86%
#     Worker 0: Train Loss: 2.1732, Train Accuracy: 42.27%
#     Worker 1: Train Loss: 2.1794, Train Accuracy: 42.63%
#     Worker 2: Train Loss: 2.1475, Train Accuracy: 43.19%
#     Worker 3: Train Loss: 2.1722, Train Accuracy: 42.45%
# Epoch 40/150: Test Loss: 2.1133, Test Accuracy: 44.73%
#     Worker 0: Train Loss: 2.1556, Train Accuracy: 42.18%
#     Worker 1: Train Loss: 2.1255, Train Accuracy: 43.61%
#     Worker 2: Train Loss: 2.1396, Train Accuracy: 43.13%
#     Worker 3: Train Loss: 2.1338, Train Accuracy: 42.97%
# Epoch 41/150: Test Loss: 2.0997, Test Accuracy: 44.99%
#     Worker 0: Train Loss: 2.1141, Train Accuracy: 43.20%
#     Worker 1: Train Loss: 2.1250, Train Accuracy: 43.21%
#     Worker 2: Train Loss: 2.1081, Train Accuracy: 44.09%
#     Worker 3: Train Loss: 2.1173, Train Accuracy: 43.68%
# Epoch 42/150: Test Loss: 2.0916, Test Accuracy: 45.37%
#     Worker 0: Train Loss: 2.1057, Train Accuracy: 43.94%
#     Worker 1: Train Loss: 2.1145, Train Accuracy: 43.76%
#     Worker 2: Train Loss: 2.0706, Train Accuracy: 44.77%
#     Worker 3: Train Loss: 2.1124, Train Accuracy: 43.84%
# Epoch 43/150: Test Loss: 2.0726, Test Accuracy: 45.63%
#     Worker 0: Train Loss: 2.0786, Train Accuracy: 44.40%
#     Worker 1: Train Loss: 1.9087, Train Accuracy: 48.58%
#     Worker 2: Train Loss: 1.8943, Train Accuracy: 48.72%
#     Worker 3: Train Loss: 1.9193, Train Accuracy: 47.71%
# Epoch 53/150: Test Loss: 2.0090, Test Accuracy: 47.40%
#     Worker 0: Train Loss: 1.8847, Train Accuracy: 48.59%
#     Worker 1: Train Loss: 1.8805, Train Accuracy: 48.96%
#     Worker 2: Train Loss: 1.8600, Train Accuracy: 49.44%
#     Worker 3: Train Loss: 1.8960, Train Accuracy: 49.03%
# Epoch 54/150: Test Loss: 2.0062, Test Accuracy: 47.58%
#     Worker 0: Train Loss: 1.8787, Train Accuracy: 49.04%
#     Worker 1: Train Loss: 1.8538, Train Accuracy: 49.60%
#     Worker 2: Train Loss: 1.8411, Train Accuracy: 50.21%
#     Worker 3: Train Loss: 1.8776, Train Accuracy: 49.00%
# Epoch 55/150: Test Loss: 1.9907, Test Accuracy: 47.85%
#     Worker 0: Train Loss: 1.8597, Train Accuracy: 48.97%
#     Worker 1: Train Loss: 1.8576, Train Accuracy: 49.43%
#     Worker 2: Train Loss: 1.8376, Train Accuracy: 49.72%
#     Worker 3: Train Loss: 1.8708, Train Accuracy: 49.50%
# Epoch 56/150: Test Loss: 1.9904, Test Accuracy: 48.02%
#     Worker 0: Train Loss: 1.8320, Train Accuracy: 49.90%
#     Worker 1: Train Loss: 1.8266, Train Accuracy: 50.82%
#     Worker 2: Train Loss: 1.8068, Train Accuracy: 50.86%
#     Worker 3: Train Loss: 1.8356, Train Accuracy: 49.87%
# Epoch 57/150: Test Loss: 1.9701, Test Accuracy: 48.32%
#     Worker 0: Train Loss: 1.8174, Train Accuracy: 49.84%
#     Worker 1: Train Loss: 1.8287, Train Accuracy: 50.34%
#     Worker 2: Train Loss: 1.8038, Train Accuracy: 50.17%
#     Worker 3: Train Loss: 1.8182, Train Accuracy: 50.80%
# Epoch 58/150: Test Loss: 1.9716, Test Accuracy: 48.34%
#     Worker 0: Train Loss: 1.8039, Train Accuracy: 50.09%
#     Worker 1: Train Loss: 1.8028, Train Accuracy: 51.11%
#     Worker 2: Train Loss: 1.8130, Train Accuracy: 51.07%
#     Worker 3: Train Loss: 1.8190, Train Accuracy: 50.42%
# Epoch 59/150: Test Loss: 1.9661, Test Accuracy: 48.93%
#     Worker 0: Train Loss: 1.8045, Train Accuracy: 50.23%
#     Worker 1: Train Loss: 1.7834, Train Accuracy: 51.18%
#     Worker 2: Train Loss: 1.7677, Train Accuracy: 51.63%
#     Worker 3: Train Loss: 1.7946, Train Accuracy: 51.18%
# Epoch 60/150: Test Loss: 1.9660, Test Accuracy: 48.58%
#     Worker 0: Train Loss: 1.7710, Train Accuracy: 51.53%
#     Worker 1: Train Loss: 1.7909, Train Accuracy: 51.11%
#     Worker 2: Train Loss: 1.7628, Train Accuracy: 52.04%
#     Worker 3: Train Loss: 1.7550, Train Accuracy: 52.17%
# Epoch 61/150: Test Loss: 1.9658, Test Accuracy: 48.36%
#     Worker 0: Train Loss: 1.5197, Train Accuracy: 57.11%
#     Worker 1: Train Loss: 1.5106, Train Accuracy: 58.23%
#     Worker 2: Train Loss: 1.5015, Train Accuracy: 58.00%
#     Worker 3: Train Loss: 1.5119, Train Accuracy: 58.09%
# Epoch 80/150: Test Loss: 1.9133, Test Accuracy: 50.59%
#     Worker 0: Train Loss: 1.4973, Train Accuracy: 57.59%
#     Worker 1: Train Loss: 1.4947, Train Accuracy: 58.45%
#     Worker 2: Train Loss: 1.4924, Train Accuracy: 58.08%
#     Worker 3: Train Loss: 1.5157, Train Accuracy: 57.66%
# Epoch 81/150: Test Loss: 1.9097, Test Accuracy: 50.50%
#     Worker 0: Train Loss: 1.5061, Train Accuracy: 57.64%
#     Worker 1: Train Loss: 1.4944, Train Accuracy: 57.96%
#     Worker 2: Train Loss: 1.4815, Train Accuracy: 58.49%
#     Worker 3: Train Loss: 1.5047, Train Accuracy: 57.88%
# Epoch 82/150: Test Loss: 1.9180, Test Accuracy: 50.76%
#     Worker 0: Train Loss: 1.4681, Train Accuracy: 58.61%
#     Worker 1: Train Loss: 1.4757, Train Accuracy: 58.46%
#     Worker 2: Train Loss: 1.4857, Train Accuracy: 58.62%
#     Worker 3: Train Loss: 1.5005, Train Accuracy: 58.14%
# Epoch 83/150: Test Loss: 1.9175, Test Accuracy: 50.39%
#     Worker 0: Train Loss: 1.4730, Train Accuracy: 58.08%
#     Worker 1: Train Loss: 1.4615, Train Accuracy: 58.94%
#     Worker 2: Train Loss: 1.4464, Train Accuracy: 59.82%
#     Worker 3: Train Loss: 1.4815, Train Accuracy: 58.26%
# Epoch 84/150: Test Loss: 1.9042, Test Accuracy: 50.72%
#     Worker 0: Train Loss: 1.4556, Train Accuracy: 58.46%
#     Worker 1: Train Loss: 1.4528, Train Accuracy: 59.18%
#     Worker 2: Train Loss: 1.4438, Train Accuracy: 59.30%
#     Worker 3: Train Loss: 1.4785, Train Accuracy: 58.39%
# Epoch 85/150: Test Loss: 1.9086, Test Accuracy: 50.71%
#     Worker 0: Train Loss: 1.4569, Train Accuracy: 58.90%
#     Worker 1: Train Loss: 1.4512, Train Accuracy: 59.41%
#     Worker 2: Train Loss: 1.4416, Train Accuracy: 59.60%
#     Worker 3: Train Loss: 1.4520, Train Accuracy: 58.96%
# Epoch 86/150: Test Loss: 1.9200, Test Accuracy: 51.10%
#     Worker 0: Train Loss: 1.4322, Train Accuracy: 59.16%
#     Worker 1: Train Loss: 1.4302, Train Accuracy: 59.58%
#     Worker 2: Train Loss: 1.4191, Train Accuracy: 60.72%
#     Worker 3: Train Loss: 1.4428, Train Accuracy: 59.24%
# Epoch 87/150: Test Loss: 1.9095, Test Accuracy: 51.28%
#     Worker 0: Train Loss: 1.4378, Train Accuracy: 59.76%
#     Worker 1: Train Loss: 1.4277, Train Accuracy: 59.82%
#     Worker 2: Train Loss: 1.4287, Train Accuracy: 59.66%
#     Worker 3: Train Loss: 1.4300, Train Accuracy: 59.87%
# Epoch 88/150: Test Loss: 1.9137, Test Accuracy: 51.34%
#     Worker 0: Train Loss: 1.4317, Train Accuracy: 59.02%
#     Worker 1: Train Loss: 1.4258, Train Accuracy: 59.74%
#     Worker 2: Train Loss: 1.4176, Train Accuracy: 60.33%
#     Worker 3: Train Loss: 1.4123, Train Accuracy: 60.49%
# Epoch 89/150: Test Loss: 1.9225, Test Accuracy: 50.76%
#     Worker 0: Train Loss: 1.3991, Train Accuracy: 59.90%
#     Worker 1: Train Loss: 1.3894, Train Accuracy: 60.79%
#     Worker 2: Train Loss: 1.3912, Train Accuracy: 60.80%
#     Worker 3: Train Loss: 1.4128, Train Accuracy: 59.90%
# Epoch 90/150: Test Loss: 1.9047, Test Accuracy: 51.53%
#     Worker 0: Train Loss: 1.3919, Train Accuracy: 60.29%
#     Worker 1: Train Loss: 1.3751, Train Accuracy: 60.84%
#     Worker 2: Train Loss: 1.3806, Train Accuracy: 61.00%
#     Worker 3: Train Loss: 1.3984, Train Accuracy: 60.18%
# Epoch 91/150: Test Loss: 1.9125, Test Accuracy: 50.89%
#     Worker 0: Train Loss: 1.3771, Train Accuracy: 60.58%
#     Worker 1: Train Loss: 1.3851, Train Accuracy: 60.73%
#     Worker 2: Train Loss: 1.3779, Train Accuracy: 61.08%
#     Worker 3: Train Loss: 1.3694, Train Accuracy: 61.27%
# Epoch 92/150: Test Loss: 1.9209, Test Accuracy: 51.10%
#     Worker 0: Train Loss: 1.3810, Train Accuracy: 60.60%
#     Worker 1: Train Loss: 1.3524, Train Accuracy: 61.70%
#     Worker 2: Train Loss: 1.3762, Train Accuracy: 60.94%
#     Worker 3: Train Loss: 1.3778, Train Accuracy: 60.71%
# Epoch 93/150: Test Loss: 1.9189, Test Accuracy: 51.10%
#     Worker 0: Train Loss: 1.3581, Train Accuracy: 61.18%
#     Worker 1: Train Loss: 1.3679, Train Accuracy: 61.35%
#     Worker 2: Train Loss: 1.3521, Train Accuracy: 61.98%
#     Worker 3: Train Loss: 1.3709, Train Accuracy: 61.56%
# Epoch 94/150: Test Loss: 1.9185, Test Accuracy: 51.27%
#     Worker 0: Train Loss: 1.3506, Train Accuracy: 61.21%
#     Worker 1: Train Loss: 1.3671, Train Accuracy: 61.40%
#     Worker 2: Train Loss: 1.3563, Train Accuracy: 61.33%
#     Worker 3: Train Loss: 1.3557, Train Accuracy: 61.25%
# Epoch 95/150: Test Loss: 1.9182, Test Accuracy: 51.22%
#     Worker 0: Train Loss: 1.3292, Train Accuracy: 61.95%
#     Worker 1: Train Loss: 1.3363, Train Accuracy: 62.06%
#     Worker 2: Train Loss: 1.3281, Train Accuracy: 62.30%
#     Worker 3: Train Loss: 1.3495, Train Accuracy: 62.23%
# Epoch 96/150: Test Loss: 1.9187, Test Accuracy: 51.40%
#     Worker 0: Train Loss: 1.3312, Train Accuracy: 62.03%
#     Worker 1: Train Loss: 1.3194, Train Accuracy: 62.47%
#     Worker 2: Train Loss: 1.3174, Train Accuracy: 62.76%
#     Worker 3: Train Loss: 1.3299, Train Accuracy: 62.36%
# Epoch 97/150: Test Loss: 1.9177, Test Accuracy: 51.75%
#     Worker 0: Train Loss: 1.3374, Train Accuracy: 61.63%
#     Worker 1: Train Loss: 1.3228, Train Accuracy: 62.85%
#     Worker 2: Train Loss: 1.3128, Train Accuracy: 62.97%
#     Worker 3: Train Loss: 1.3192, Train Accuracy: 62.34%
# Epoch 98/150: Test Loss: 1.9285, Test Accuracy: 51.35%
#     Worker 0: Train Loss: 1.3082, Train Accuracy: 62.01%
#     Worker 1: Train Loss: 1.3091, Train Accuracy: 62.89%
#     Worker 2: Train Loss: 1.3091, Train Accuracy: 62.54%
#     Worker 3: Train Loss: 1.3181, Train Accuracy: 62.41%
# Epoch 99/150: Test Loss: 1.9266, Test Accuracy: 51.47%
#     Worker 0: Train Loss: 1.3196, Train Accuracy: 62.09%
#     Worker 1: Train Loss: 1.3134, Train Accuracy: 62.78%
#     Worker 2: Train Loss: 1.2989, Train Accuracy: 63.18%
#     Worker 3: Train Loss: 1.3043, Train Accuracy: 62.94%
# Epoch 100/150: Test Loss: 1.9265, Test Accuracy: 51.54%
#     Worker 0: Train Loss: 1.2925, Train Accuracy: 63.31%
#     Worker 1: Train Loss: 1.2867, Train Accuracy: 63.57%
#     Worker 2: Train Loss: 1.2942, Train Accuracy: 63.54%
#     Worker 3: Train Loss: 1.2851, Train Accuracy: 63.41%
# Epoch 101/150: Test Loss: 1.9353, Test Accuracy: 51.50%
#     Worker 0: Train Loss: 1.2898, Train Accuracy: 63.05%
#     Worker 1: Train Loss: 1.2650, Train Accuracy: 63.98%
#     Worker 2: Train Loss: 1.2544, Train Accuracy: 64.14%
#     Worker 3: Train Loss: 1.2909, Train Accuracy: 63.24%
# Epoch 102/150: Test Loss: 1.9380, Test Accuracy: 51.52%
#     Worker 0: Train Loss: 1.2735, Train Accuracy: 63.92%
#     Worker 1: Train Loss: 1.2757, Train Accuracy: 63.92%
#     Worker 2: Train Loss: 1.2586, Train Accuracy: 64.19%
#     Worker 3: Train Loss: 1.2825, Train Accuracy: 63.52%
# Epoch 103/150: Test Loss: 1.9400, Test Accuracy: 51.47%
#     Worker 0: Train Loss: 1.2692, Train Accuracy: 63.73%
#     Worker 1: Train Loss: 1.2733, Train Accuracy: 63.94%
#     Worker 2: Train Loss: 1.2574, Train Accuracy: 64.50%
#     Worker 3: Train Loss: 1.2674, Train Accuracy: 63.92%
# Epoch 104/150: Test Loss: 1.9328, Test Accuracy: 51.93%
#     Worker 0: Train Loss: 1.2574, Train Accuracy: 63.92%
#     Worker 1: Train Loss: 1.2362, Train Accuracy: 64.75%
#     Worker 2: Train Loss: 1.2506, Train Accuracy: 64.77%
#     Worker 3: Train Loss: 1.2619, Train Accuracy: 63.93%
# Epoch 105/150: Test Loss: 1.9427, Test Accuracy: 51.73%
#     Worker 0: Train Loss: 1.2545, Train Accuracy: 64.02%
#     Worker 1: Train Loss: 1.2420, Train Accuracy: 64.97%
#     Worker 2: Train Loss: 1.2667, Train Accuracy: 63.95%
#     Worker 3: Train Loss: 1.2476, Train Accuracy: 64.26%
# Epoch 106/150: Test Loss: 1.9445, Test Accuracy: 51.32%
#     Worker 0: Train Loss: 1.2283, Train Accuracy: 64.91%
#     Worker 1: Train Loss: 1.2359, Train Accuracy: 64.60%
#     Worker 2: Train Loss: 1.2266, Train Accuracy: 65.21%
#     Worker 3: Train Loss: 1.2390, Train Accuracy: 64.79%
# Epoch 107/150: Test Loss: 1.9444, Test Accuracy: 51.43%
#     Worker 0: Train Loss: 1.2405, Train Accuracy: 64.24%
#     Worker 1: Train Loss: 1.2336, Train Accuracy: 64.43%
#     Worker 2: Train Loss: 1.2193, Train Accuracy: 65.22%
#     Worker 3: Train Loss: 1.2317, Train Accuracy: 64.53%
# Epoch 108/150: Test Loss: 1.9493, Test Accuracy: 51.41%
#     Worker 0: Train Loss: 1.2276, Train Accuracy: 64.81%
#     Worker 1: Train Loss: 1.2176, Train Accuracy: 65.45%
#     Worker 2: Train Loss: 1.2163, Train Accuracy: 65.26%
#     Worker 3: Train Loss: 1.2266, Train Accuracy: 65.43%
# Epoch 109/150: Test Loss: 1.9420, Test Accuracy: 51.64%
#     Worker 0: Train Loss: 1.2167, Train Accuracy: 64.79%
#     Worker 1: Train Loss: 1.2046, Train Accuracy: 65.67%
#     Worker 2: Train Loss: 1.2052, Train Accuracy: 65.70%
#     Worker 3: Train Loss: 1.2240, Train Accuracy: 65.30%
# Epoch 110/150: Test Loss: 1.9498, Test Accuracy: 51.60%
#     Worker 0: Train Loss: 1.2186, Train Accuracy: 65.21%
#     Worker 1: Train Loss: 1.1906, Train Accuracy: 66.30%
#     Worker 2: Train Loss: 1.2029, Train Accuracy: 65.95%
#     Worker 3: Train Loss: 1.1997, Train Accuracy: 65.76%
# Epoch 111/150: Test Loss: 1.9480, Test Accuracy: 51.67%
#     Worker 0: Train Loss: 1.2053, Train Accuracy: 65.34%
#     Worker 1: Train Loss: 1.2093, Train Accuracy: 65.15%
#     Worker 2: Train Loss: 1.2036, Train Accuracy: 65.77%
#     Worker 3: Train Loss: 1.2123, Train Accuracy: 65.39%
# Epoch 112/150: Test Loss: 1.9511, Test Accuracy: 51.64%
#     Worker 0: Train Loss: 1.1972, Train Accuracy: 65.57%
#     Worker 1: Train Loss: 1.1913, Train Accuracy: 66.30%
#     Worker 2: Train Loss: 1.1705, Train Accuracy: 66.70%
#     Worker 3: Train Loss: 1.1993, Train Accuracy: 65.70%
# Epoch 113/150: Test Loss: 1.9470, Test Accuracy: 51.53%
#     Worker 0: Train Loss: 1.1868, Train Accuracy: 65.70%
#     Worker 1: Train Loss: 1.1743, Train Accuracy: 66.25%
#     Worker 2: Train Loss: 1.1919, Train Accuracy: 66.02%
#     Worker 3: Train Loss: 1.1840, Train Accuracy: 66.16%
# Epoch 114/150: Test Loss: 1.9526, Test Accuracy: 51.48%
#     Worker 0: Train Loss: 1.2019, Train Accuracy: 65.67%
#     Worker 1: Train Loss: 1.1844, Train Accuracy: 66.33%
#     Worker 2: Train Loss: 1.1667, Train Accuracy: 66.71%
#     Worker 3: Train Loss: 1.1923, Train Accuracy: 66.10%
# Epoch 115/150: Test Loss: 1.9583, Test Accuracy: 51.51%
#     Worker 0: Train Loss: 1.1826, Train Accuracy: 66.14%
#     Worker 1: Train Loss: 1.1656, Train Accuracy: 66.51%
#     Worker 2: Train Loss: 1.1746, Train Accuracy: 66.27%
#     Worker 3: Train Loss: 1.1682, Train Accuracy: 66.76%
# Epoch 116/150: Test Loss: 1.9562, Test Accuracy: 51.55%
#     Worker 0: Train Loss: 1.1636, Train Accuracy: 65.85%
#     Worker 1: Train Loss: 1.1576, Train Accuracy: 66.98%
#     Worker 2: Train Loss: 1.1552, Train Accuracy: 67.03%
#     Worker 3: Train Loss: 1.1689, Train Accuracy: 66.76%
# Epoch 117/150: Test Loss: 1.9526, Test Accuracy: 51.73%
#     Worker 0: Train Loss: 1.1737, Train Accuracy: 65.86%
#     Worker 1: Train Loss: 1.1537, Train Accuracy: 67.14%
#     Worker 2: Train Loss: 1.1610, Train Accuracy: 67.07%
#     Worker 3: Train Loss: 1.1602, Train Accuracy: 66.43%
# Epoch 118/150: Test Loss: 1.9559, Test Accuracy: 51.52%
#     Worker 0: Train Loss: 1.1525, Train Accuracy: 66.83%
#     Worker 1: Train Loss: 1.1464, Train Accuracy: 66.97%
#     Worker 2: Train Loss: 1.1538, Train Accuracy: 66.90%
#     Worker 3: Train Loss: 1.1609, Train Accuracy: 66.54%
# Epoch 119/150: Test Loss: 1.9629, Test Accuracy: 51.44%
#     Worker 0: Train Loss: 1.1515, Train Accuracy: 66.50%
#     Worker 1: Train Loss: 1.1452, Train Accuracy: 67.35%
#     Worker 2: Train Loss: 1.1226, Train Accuracy: 67.93%
#     Worker 3: Train Loss: 1.1437, Train Accuracy: 67.58%
# Epoch 120/150: Test Loss: 1.9600, Test Accuracy: 51.90%
#     Worker 0: Train Loss: 1.1514, Train Accuracy: 66.68%
#     Worker 1: Train Loss: 1.1445, Train Accuracy: 67.58%
#     Worker 2: Train Loss: 1.1570, Train Accuracy: 67.50%
#     Worker 3: Train Loss: 1.1422, Train Accuracy: 67.20%
# Epoch 121/150: Test Loss: 1.9639, Test Accuracy: 51.38%
#     Worker 0: Train Loss: 1.1460, Train Accuracy: 67.01%
#     Worker 1: Train Loss: 1.1318, Train Accuracy: 67.37%
#     Worker 2: Train Loss: 1.1175, Train Accuracy: 67.78%
#     Worker 3: Train Loss: 1.1415, Train Accuracy: 67.50%
# Epoch 122/150: Test Loss: 1.9580, Test Accuracy: 51.71%
#     Worker 0: Train Loss: 1.1359, Train Accuracy: 67.14%
#     Worker 1: Train Loss: 1.1343, Train Accuracy: 67.32%
#     Worker 2: Train Loss: 1.1347, Train Accuracy: 67.48%
#     Worker 3: Train Loss: 1.1334, Train Accuracy: 67.70%
# Epoch 123/150: Test Loss: 1.9620, Test Accuracy: 52.01%
#     Worker 0: Train Loss: 1.1357, Train Accuracy: 67.31%
#     Worker 1: Train Loss: 1.1099, Train Accuracy: 68.51%
#     Worker 2: Train Loss: 1.1232, Train Accuracy: 67.96%
#     Worker 3: Train Loss: 1.1381, Train Accuracy: 67.47%
# Epoch 124/150: Test Loss: 1.9640, Test Accuracy: 51.90%
#     Worker 0: Train Loss: 1.1192, Train Accuracy: 67.64%
#     Worker 1: Train Loss: 1.1292, Train Accuracy: 67.77%
#     Worker 2: Train Loss: 1.1282, Train Accuracy: 67.91%
#     Worker 3: Train Loss: 1.1329, Train Accuracy: 67.54%
# Epoch 125/150: Test Loss: 1.9638, Test Accuracy: 52.06%
#     Worker 0: Train Loss: 1.1128, Train Accuracy: 67.69%
#     Worker 1: Train Loss: 1.1214, Train Accuracy: 68.02%
#     Worker 2: Train Loss: 1.1089, Train Accuracy: 68.37%
#     Worker 3: Train Loss: 1.1326, Train Accuracy: 67.56%
# Epoch 126/150: Test Loss: 1.9643, Test Accuracy: 51.74%
#     Worker 0: Train Loss: 1.1227, Train Accuracy: 67.22%
#     Worker 1: Train Loss: 1.1080, Train Accuracy: 68.35%
#     Worker 2: Train Loss: 1.0975, Train Accuracy: 68.33%
#     Worker 3: Train Loss: 1.1149, Train Accuracy: 68.13%
# Epoch 127/150: Test Loss: 1.9685, Test Accuracy: 51.81%
#     Worker 0: Train Loss: 1.1125, Train Accuracy: 67.99%
#     Worker 1: Train Loss: 1.1110, Train Accuracy: 68.23%
#     Worker 2: Train Loss: 1.1034, Train Accuracy: 68.50%
#     Worker 3: Train Loss: 1.1099, Train Accuracy: 67.99%
# Epoch 128/150: Test Loss: 1.9680, Test Accuracy: 51.87%
#     Worker 0: Train Loss: 1.1016, Train Accuracy: 67.88%
#     Worker 1: Train Loss: 1.0971, Train Accuracy: 68.41%
#     Worker 2: Train Loss: 1.1048, Train Accuracy: 68.63%
#     Worker 3: Train Loss: 1.1023, Train Accuracy: 68.38%
# Epoch 129/150: Test Loss: 1.9667, Test Accuracy: 51.65%
#     Worker 0: Train Loss: 1.1058, Train Accuracy: 67.94%
#     Worker 1: Train Loss: 1.0944, Train Accuracy: 69.07%
#     Worker 2: Train Loss: 1.1019, Train Accuracy: 68.90%
#     Worker 3: Train Loss: 1.1324, Train Accuracy: 67.55%
# Epoch 130/150: Test Loss: 1.9679, Test Accuracy: 51.87%
#     Worker 0: Train Loss: 1.1017, Train Accuracy: 68.26%
#     Worker 1: Train Loss: 1.0844, Train Accuracy: 69.06%
#     Worker 2: Train Loss: 1.0979, Train Accuracy: 68.35%
#     Worker 3: Train Loss: 1.1023, Train Accuracy: 68.16%
# Epoch 131/150: Test Loss: 1.9711, Test Accuracy: 51.73%
#     Worker 0: Train Loss: 1.1046, Train Accuracy: 67.84%
#     Worker 1: Train Loss: 1.1015, Train Accuracy: 68.47%
#     Worker 2: Train Loss: 1.0995, Train Accuracy: 68.99%
#     Worker 3: Train Loss: 1.0973, Train Accuracy: 68.88%
# Epoch 132/150: Test Loss: 1.9696, Test Accuracy: 51.80%
#     Worker 0: Train Loss: 1.0936, Train Accuracy: 68.31%
#     Worker 1: Train Loss: 1.0864, Train Accuracy: 68.98%
#     Worker 2: Train Loss: 1.0923, Train Accuracy: 69.10%
#     Worker 3: Train Loss: 1.0872, Train Accuracy: 68.94%
# Epoch 133/150: Test Loss: 1.9703, Test Accuracy: 52.04%
#     Worker 0: Train Loss: 1.0937, Train Accuracy: 69.03%
#     Worker 1: Train Loss: 1.0727, Train Accuracy: 69.19%
#     Worker 2: Train Loss: 1.0770, Train Accuracy: 69.14%
#     Worker 3: Train Loss: 1.0943, Train Accuracy: 68.66%
# Epoch 134/150: Test Loss: 1.9716, Test Accuracy: 51.78%
#     Worker 0: Train Loss: 1.0966, Train Accuracy: 68.74%
#     Worker 1: Train Loss: 1.0879, Train Accuracy: 69.09%
#     Worker 2: Train Loss: 1.0869, Train Accuracy: 68.53%
#     Worker 3: Train Loss: 1.0834, Train Accuracy: 68.67%
# Epoch 135/150: Test Loss: 1.9729, Test Accuracy: 52.00%
#     Worker 0: Train Loss: 1.0856, Train Accuracy: 68.71%
#     Worker 1: Train Loss: 1.0694, Train Accuracy: 69.57%
#     Worker 2: Train Loss: 1.0873, Train Accuracy: 68.72%
#     Worker 3: Train Loss: 1.0821, Train Accuracy: 69.06%
# Epoch 136/150: Test Loss: 1.9745, Test Accuracy: 51.62%
#     Worker 0: Train Loss: 1.0698, Train Accuracy: 68.76%
#     Worker 1: Train Loss: 1.0815, Train Accuracy: 69.16%
#     Worker 2: Train Loss: 1.0737, Train Accuracy: 69.46%
#     Worker 3: Train Loss: 1.1104, Train Accuracy: 68.38%
# Epoch 137/150: Test Loss: 1.9731, Test Accuracy: 52.01%
#     Worker 0: Train Loss: 1.0890, Train Accuracy: 68.64%
#     Worker 1: Train Loss: 1.0836, Train Accuracy: 69.43%
#     Worker 2: Train Loss: 1.0666, Train Accuracy: 69.88%
#     Worker 3: Train Loss: 1.0650, Train Accuracy: 69.28%
# Epoch 138/150: Test Loss: 1.9722, Test Accuracy: 51.95%
#     Worker 0: Train Loss: 1.0819, Train Accuracy: 68.54%
#     Worker 1: Train Loss: 1.0765, Train Accuracy: 69.38%
#     Worker 2: Train Loss: 1.0796, Train Accuracy: 69.34%
#     Worker 3: Train Loss: 1.0906, Train Accuracy: 69.05%
# Epoch 139/150: Test Loss: 1.9722, Test Accuracy: 51.78%
#     Worker 0: Train Loss: 1.0771, Train Accuracy: 69.00%
#     Worker 1: Train Loss: 1.0751, Train Accuracy: 69.35%
#     Worker 2: Train Loss: 1.0692, Train Accuracy: 69.46%
#     Worker 3: Train Loss: 1.0703, Train Accuracy: 69.27%
# Epoch 140/150: Test Loss: 1.9735, Test Accuracy: 51.79%
#     Worker 0: Train Loss: 1.0829, Train Accuracy: 68.82%
#     Worker 1: Train Loss: 1.0721, Train Accuracy: 69.55%
#     Worker 2: Train Loss: 1.0725, Train Accuracy: 69.25%
#     Worker 3: Train Loss: 1.0801, Train Accuracy: 68.89%
# Epoch 141/150: Test Loss: 1.9737, Test Accuracy: 51.86%
#     Worker 0: Train Loss: 1.0681, Train Accuracy: 69.19%
#     Worker 1: Train Loss: 1.0718, Train Accuracy: 69.37%
#     Worker 2: Train Loss: 1.0711, Train Accuracy: 69.33%
#     Worker 3: Train Loss: 1.0892, Train Accuracy: 68.83%
# Epoch 142/150: Test Loss: 1.9744, Test Accuracy: 51.82%
#     Worker 0: Train Loss: 1.0683, Train Accuracy: 69.43%
#     Worker 1: Train Loss: 1.0569, Train Accuracy: 69.77%
#     Worker 2: Train Loss: 1.0765, Train Accuracy: 69.22%
#     Worker 3: Train Loss: 1.0780, Train Accuracy: 68.99%
# Epoch 143/150: Test Loss: 1.9746, Test Accuracy: 51.74%
#     Worker 0: Train Loss: 1.0765, Train Accuracy: 69.27%
#     Worker 1: Train Loss: 1.0791, Train Accuracy: 69.68%
#     Worker 2: Train Loss: 1.0749, Train Accuracy: 69.40%
#     Worker 3: Train Loss: 1.0643, Train Accuracy: 69.34%
# Epoch 144/150: Test Loss: 1.9750, Test Accuracy: 51.81%
#     Worker 0: Train Loss: 1.0717, Train Accuracy: 69.00%
#     Worker 1: Train Loss: 1.0709, Train Accuracy: 69.00%
#     Worker 2: Train Loss: 1.0666, Train Accuracy: 69.16%
#     Worker 3: Train Loss: 1.0849, Train Accuracy: 69.11%
# Epoch 145/150: Test Loss: 1.9747, Test Accuracy: 51.74%
#     Worker 0: Train Loss: 1.0756, Train Accuracy: 68.84%
#     Worker 1: Train Loss: 1.0556, Train Accuracy: 69.94%
#     Worker 2: Train Loss: 1.0680, Train Accuracy: 69.48%
#     Worker 3: Train Loss: 1.0690, Train Accuracy: 69.19%
# Epoch 146/150: Test Loss: 1.9746, Test Accuracy: 51.91%
#     Worker 0: Train Loss: 1.0769, Train Accuracy: 69.10%
#     Worker 1: Train Loss: 1.0719, Train Accuracy: 69.28%
#     Worker 2: Train Loss: 1.0750, Train Accuracy: 69.20%
#     Worker 3: Train Loss: 1.0911, Train Accuracy: 69.08%
# Epoch 147/150: Test Loss: 1.9743, Test Accuracy: 51.89%
#     Worker 0: Train Loss: 1.0775, Train Accuracy: 68.86%
#     Worker 1: Train Loss: 1.0556, Train Accuracy: 69.43%
#     Worker 2: Train Loss: 1.0646, Train Accuracy: 69.80%
#     Worker 3: Train Loss: 1.0728, Train Accuracy: 69.37%
# Epoch 148/150: Test Loss: 1.9745, Test Accuracy: 51.87%
#     Worker 0: Train Loss: 1.0806, Train Accuracy: 68.90%
#     Worker 1: Train Loss: 1.0707, Train Accuracy: 69.13%
#     Worker 2: Train Loss: 1.0637, Train Accuracy: 69.60%
#     Worker 3: Train Loss: 1.0709, Train Accuracy: 69.51%
# Epoch 149/150: Test Loss: 1.9745, Test Accuracy: 51.86%
#     Worker 0: Train Loss: 1.0672, Train Accuracy: 69.36%
#     Worker 1: Train Loss: 1.0659, Train Accuracy: 69.58%
#     Worker 2: Train Loss: 1.0529, Train Accuracy: 70.15%
#     Worker 3: Train Loss: 1.0811, Train Accuracy: 69.01%
# Epoch 150/150: Test Loss: 1.9745, Test Accuracy: 51.85%
#     Worker 0: Train Loss: 1.0631, Train Accuracy: 69.41%
#     Worker 1: Train Loss: 1.0695, Train Accuracy: 68.87%
#     Worker 2: Train Loss: 1.0744, Train Accuracy: 69.58%
#     Worker 3: Train Loss: 1.0824, Train Accuracy: 69.24%
