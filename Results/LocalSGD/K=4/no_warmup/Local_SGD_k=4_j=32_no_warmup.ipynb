# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs - warmup_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")

    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch):
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            # Perform J local step before synchronization
            for j in range(J):
                try:
                    # Get a batch from the current worker's shard using next()
                    images, labels = next(shard_iterators[k])
                    images, labels = images.to(device), labels.to(device)  # Move to device
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

                except StopIteration:
                    # If the iterator has exhausted the data, restart the iterator
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k]) # Resume from the next batch
                    images, labels = images.to(device), labels.to(device)
                    # Perform optimization step
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        # Perform model synchronization
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            # Update each worker model with the global parameters
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        # if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
        # else:
        #     warmup_factor = (epoch + 1) / warmup_epochs
        #     lr = warmup_factor * learning_rate
        #     for optimizer in optimizers:
        #         for param_group in optimizer.param_groups:
        #             param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 4 --j 32
# Out:
# Training with K=4, J=32
# Global iteration per epoch: 7
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:03<00:00, 49.2MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00400
# Epoch 1/150: Test Loss: 4.5716, Test Accuracy: 2.96%
#     Worker 0: Train Loss: 4.5974, Train Accuracy: 1.59%
#     Worker 1: Train Loss: 4.5980, Train Accuracy: 1.40%
#     Worker 2: Train Loss: 4.5964, Train Accuracy: 1.53%
#     Worker 3: Train Loss: 4.5970, Train Accuracy: 1.58%
# Epoch 2/150: Test Loss: 4.1460, Test Accuracy: 6.83%
#     Worker 0: Train Loss: 4.4147, Train Accuracy: 3.72%
#     Worker 1: Train Loss: 4.4181, Train Accuracy: 3.90%
#     Worker 2: Train Loss: 4.4052, Train Accuracy: 3.66%
#     Worker 3: Train Loss: 4.4171, Train Accuracy: 3.74%
# Epoch 3/150: Test Loss: 3.9467, Test Accuracy: 9.57%
#     Worker 0: Train Loss: 4.1088, Train Accuracy: 6.95%
#     Worker 1: Train Loss: 4.1179, Train Accuracy: 6.72%
#     Worker 2: Train Loss: 4.0831, Train Accuracy: 7.28%
#     Worker 3: Train Loss: 4.1193, Train Accuracy: 7.07%
# Epoch 4/150: Test Loss: 3.7939, Test Accuracy: 12.48%
#     Worker 0: Train Loss: 3.9473, Train Accuracy: 9.50%
#     Worker 1: Train Loss: 3.9669, Train Accuracy: 9.03%
#     Worker 2: Train Loss: 3.9151, Train Accuracy: 9.80%
#     Worker 3: Train Loss: 3.9511, Train Accuracy: 9.20%
# Epoch 5/150: Test Loss: 3.6535, Test Accuracy: 15.14%
#     Worker 0: Train Loss: 3.8273, Train Accuracy: 10.96%
#     Worker 1: Train Loss: 3.8399, Train Accuracy: 10.90%
#     Worker 2: Train Loss: 3.7914, Train Accuracy: 11.76%
#     Worker 3: Train Loss: 3.8374, Train Accuracy: 11.17%
# Epoch 6/150: Test Loss: 3.5482, Test Accuracy: 16.66%
#     Worker 0: Train Loss: 3.7129, Train Accuracy: 12.83%
#     Worker 1: Train Loss: 3.7204, Train Accuracy: 13.11%
#     Worker 2: Train Loss: 3.6576, Train Accuracy: 14.00%
#     Worker 3: Train Loss: 3.7162, Train Accuracy: 12.99%
# Epoch 97/150: Test Loss: 1.9353, Test Accuracy: 50.84%
#     Worker 0: Train Loss: 1.4184, Train Accuracy: 59.52%
#     Worker 1: Train Loss: 1.4238, Train Accuracy: 60.25%
#     Worker 2: Train Loss: 1.4018, Train Accuracy: 61.16%
#     Worker 3: Train Loss: 1.4254, Train Accuracy: 60.15%
# Epoch 98/150: Test Loss: 1.9368, Test Accuracy: 50.59%
#     Worker 0: Train Loss: 1.4157, Train Accuracy: 59.78%
#     Worker 1: Train Loss: 1.4003, Train Accuracy: 60.62%
#     Worker 2: Train Loss: 1.4195, Train Accuracy: 60.66%
#     Worker 3: Train Loss: 1.4062, Train Accuracy: 60.88%
# Epoch 99/150: Test Loss: 1.9392, Test Accuracy: 50.56%
#     Worker 0: Train Loss: 1.3979, Train Accuracy: 60.53%
#     Worker 1: Train Loss: 1.3917, Train Accuracy: 60.78%
#     Worker 2: Train Loss: 1.3855, Train Accuracy: 61.13%
#     Worker 3: Train Loss: 1.4000, Train Accuracy: 60.79%
# Epoch 100/150: Test Loss: 1.9404, Test Accuracy: 50.71%
#     Worker 0: Train Loss: 1.3804, Train Accuracy: 60.87%
#     Worker 1: Train Loss: 1.3981, Train Accuracy: 60.59%
#     Worker 2: Train Loss: 1.3861, Train Accuracy: 61.40%
#     Worker 3: Train Loss: 1.3831, Train Accuracy: 60.71%
# Epoch 101/150: Test Loss: 1.9365, Test Accuracy: 50.90%
#     Worker 0: Train Loss: 1.3920, Train Accuracy: 60.71%
#     Worker 1: Train Loss: 1.3871, Train Accuracy: 60.65%
#     Worker 2: Train Loss: 1.3715, Train Accuracy: 61.23%
#     Worker 3: Train Loss: 1.3995, Train Accuracy: 60.72%
# Epoch 102/150: Test Loss: 1.9355, Test Accuracy: 51.14%
#     Worker 0: Train Loss: 1.3799, Train Accuracy: 60.89%
#     Worker 1: Train Loss: 1.3489, Train Accuracy: 61.94%
#     Worker 2: Train Loss: 1.3722, Train Accuracy: 61.53%
#     Worker 3: Train Loss: 1.3754, Train Accuracy: 61.79%
# Epoch 103/150: Test Loss: 1.9386, Test Accuracy: 51.13%
#     Worker 0: Train Loss: 1.3640, Train Accuracy: 61.06%
#     Worker 1: Train Loss: 1.3969, Train Accuracy: 60.83%
#     Worker 2: Train Loss: 1.3575, Train Accuracy: 62.24%
#     Worker 3: Train Loss: 1.3815, Train Accuracy: 61.03%
# Epoch 104/150: Test Loss: 1.9348, Test Accuracy: 50.97%
#     Worker 0: Train Loss: 1.3565, Train Accuracy: 61.56%
#     Worker 1: Train Loss: 1.3473, Train Accuracy: 61.75%
#     Worker 2: Train Loss: 1.3506, Train Accuracy: 62.14%
#     Worker 3: Train Loss: 1.3714, Train Accuracy: 61.55%
# Epoch 105/150: Test Loss: 1.9448, Test Accuracy: 50.71%
#     Worker 0: Train Loss: 1.3555, Train Accuracy: 61.55%
#     Worker 1: Train Loss: 1.3651, Train Accuracy: 62.21%
#     Worker 2: Train Loss: 1.3518, Train Accuracy: 62.31%
#     Worker 3: Train Loss: 1.3538, Train Accuracy: 62.02%
# Epoch 106/150: Test Loss: 1.9391, Test Accuracy: 50.82%
#     Worker 0: Train Loss: 1.3360, Train Accuracy: 62.12%
#     Worker 1: Train Loss: 1.3388, Train Accuracy: 62.45%
#     Worker 2: Train Loss: 1.3519, Train Accuracy: 62.64%
#     Worker 3: Train Loss: 1.3508, Train Accuracy: 61.83%
# Epoch 107/150: Test Loss: 1.9471, Test Accuracy: 50.78%
#     Worker 0: Train Loss: 1.3430, Train Accuracy: 61.84%
#     Worker 1: Train Loss: 1.3430, Train Accuracy: 62.03%
#     Worker 2: Train Loss: 1.3303, Train Accuracy: 62.78%
#     Worker 3: Train Loss: 1.3430, Train Accuracy: 62.44%
# Epoch 108/150: Test Loss: 1.9448, Test Accuracy: 51.14%
#     Worker 0: Train Loss: 1.3318, Train Accuracy: 62.06%
#     Worker 1: Train Loss: 1.3234, Train Accuracy: 62.67%
#     Worker 2: Train Loss: 1.3009, Train Accuracy: 63.61%
#     Worker 3: Train Loss: 1.3467, Train Accuracy: 61.96%
# Epoch 109/150: Test Loss: 1.9490, Test Accuracy: 51.08%
#     Worker 0: Train Loss: 1.3290, Train Accuracy: 62.14%
#     Worker 1: Train Loss: 1.3319, Train Accuracy: 62.57%
#     Worker 2: Train Loss: 1.3363, Train Accuracy: 62.34%
#     Worker 3: Train Loss: 1.3200, Train Accuracy: 63.12%
# Epoch 110/150: Test Loss: 1.9506, Test Accuracy: 50.95%
#     Worker 0: Train Loss: 1.3162, Train Accuracy: 62.76%
#     Worker 1: Train Loss: 1.3215, Train Accuracy: 63.24%
#     Worker 2: Train Loss: 1.2911, Train Accuracy: 63.36%
#     Worker 3: Train Loss: 1.3483, Train Accuracy: 62.09%
# Epoch 111/150: Test Loss: 1.9492, Test Accuracy: 51.03%
#     Worker 0: Train Loss: 1.3228, Train Accuracy: 62.50%
#     Worker 1: Train Loss: 1.3073, Train Accuracy: 63.13%
#     Worker 2: Train Loss: 1.3136, Train Accuracy: 63.07%
#     Worker 3: Train Loss: 1.3085, Train Accuracy: 63.18%
# Epoch 112/150: Test Loss: 1.9424, Test Accuracy: 51.25%
#     Worker 0: Train Loss: 1.3141, Train Accuracy: 62.73%
#     Worker 1: Train Loss: 1.3055, Train Accuracy: 62.88%
#     Worker 2: Train Loss: 1.3025, Train Accuracy: 63.30%
#     Worker 3: Train Loss: 1.3168, Train Accuracy: 63.27%
# Epoch 113/150: Test Loss: 1.9469, Test Accuracy: 50.79%
#     Worker 0: Train Loss: 1.2841, Train Accuracy: 63.48%
#     Worker 1: Train Loss: 1.2978, Train Accuracy: 63.27%
#     Worker 2: Train Loss: 1.2890, Train Accuracy: 63.48%
#     Worker 3: Train Loss: 1.3166, Train Accuracy: 62.91%
# Epoch 114/150: Test Loss: 1.9472, Test Accuracy: 51.08%
#     Worker 0: Train Loss: 1.3045, Train Accuracy: 63.10%
#     Worker 1: Train Loss: 1.2863, Train Accuracy: 63.62%
#     Worker 2: Train Loss: 1.2941, Train Accuracy: 63.97%
#     Worker 3: Train Loss: 1.2902, Train Accuracy: 63.59%
# Epoch 115/150: Test Loss: 1.9512, Test Accuracy: 51.08%
#     Worker 0: Train Loss: 1.2780, Train Accuracy: 63.83%
#     Worker 1: Train Loss: 1.2964, Train Accuracy: 63.46%
#     Worker 2: Train Loss: 1.2962, Train Accuracy: 63.40%
#     Worker 3: Train Loss: 1.3025, Train Accuracy: 63.36%
# Epoch 116/150: Test Loss: 1.9544, Test Accuracy: 51.03%
#     Worker 0: Train Loss: 1.2896, Train Accuracy: 63.69%
#     Worker 1: Train Loss: 1.2882, Train Accuracy: 63.69%
#     Worker 2: Train Loss: 1.2630, Train Accuracy: 65.02%
#     Worker 3: Train Loss: 1.2776, Train Accuracy: 64.09%
# Epoch 117/150: Test Loss: 1.9490, Test Accuracy: 50.90%
#     Worker 0: Train Loss: 1.2985, Train Accuracy: 63.00%
#     Worker 1: Train Loss: 1.2796, Train Accuracy: 63.84%
#     Worker 2: Train Loss: 1.2740, Train Accuracy: 64.14%
#     Worker 3: Train Loss: 1.2970, Train Accuracy: 63.60%
# Epoch 118/150: Test Loss: 1.9537, Test Accuracy: 51.14%
#     Worker 0: Train Loss: 1.2664, Train Accuracy: 64.17%
#     Worker 1: Train Loss: 1.2801, Train Accuracy: 63.94%
#     Worker 2: Train Loss: 1.2717, Train Accuracy: 64.27%
#     Worker 3: Train Loss: 1.2772, Train Accuracy: 64.08%
# Epoch 119/150: Test Loss: 1.9523, Test Accuracy: 51.27%
#     Worker 0: Train Loss: 1.2733, Train Accuracy: 63.85%
#     Worker 1: Train Loss: 1.2519, Train Accuracy: 64.35%
#     Worker 2: Train Loss: 1.2655, Train Accuracy: 64.30%
#     Worker 3: Train Loss: 1.2620, Train Accuracy: 64.17%
# Epoch 120/150: Test Loss: 1.9517, Test Accuracy: 51.52%
#     Worker 0: Train Loss: 1.2572, Train Accuracy: 64.04%
#     Worker 1: Train Loss: 1.2572, Train Accuracy: 64.16%
#     Worker 2: Train Loss: 1.2597, Train Accuracy: 64.79%
#     Worker 3: Train Loss: 1.2780, Train Accuracy: 63.90%
# Epoch 121/150: Test Loss: 1.9506, Test Accuracy: 51.21%
#     Worker 0: Train Loss: 1.2606, Train Accuracy: 64.12%
#     Worker 1: Train Loss: 1.2562, Train Accuracy: 64.94%
#     Worker 2: Train Loss: 1.2442, Train Accuracy: 65.06%
#     Worker 3: Train Loss: 1.2517, Train Accuracy: 64.55%
# Epoch 122/150: Test Loss: 1.9539, Test Accuracy: 51.32%
#     Worker 0: Train Loss: 1.2442, Train Accuracy: 64.41%
#     Worker 1: Train Loss: 1.2502, Train Accuracy: 64.34%
#     Worker 2: Train Loss: 1.2636, Train Accuracy: 64.39%
#     Worker 3: Train Loss: 1.2776, Train Accuracy: 64.01%
# Epoch 123/150: Test Loss: 1.9540, Test Accuracy: 51.35%
#     Worker 0: Train Loss: 1.2658, Train Accuracy: 63.84%
#     Worker 1: Train Loss: 1.2506, Train Accuracy: 64.46%
#     Worker 2: Train Loss: 1.2435, Train Accuracy: 64.97%
#     Worker 3: Train Loss: 1.2522, Train Accuracy: 64.66%
# Epoch 124/150: Test Loss: 1.9528, Test Accuracy: 51.35%
#     Worker 0: Train Loss: 1.2571, Train Accuracy: 63.99%
#     Worker 1: Train Loss: 1.2467, Train Accuracy: 64.88%
#     Worker 2: Train Loss: 1.2518, Train Accuracy: 64.71%
#     Worker 3: Train Loss: 1.2627, Train Accuracy: 64.73%
# Epoch 125/150: Test Loss: 1.9500, Test Accuracy: 51.45%
#     Worker 0: Train Loss: 1.2512, Train Accuracy: 63.97%
#     Worker 1: Train Loss: 1.2403, Train Accuracy: 65.01%
#     Worker 2: Train Loss: 1.2360, Train Accuracy: 64.92%
#     Worker 3: Train Loss: 1.2380, Train Accuracy: 65.33%
# Epoch 126/150: Test Loss: 1.9531, Test Accuracy: 51.59%
#     Worker 0: Train Loss: 1.2444, Train Accuracy: 64.35%
#     Worker 1: Train Loss: 1.2360, Train Accuracy: 64.92%
#     Worker 2: Train Loss: 1.2445, Train Accuracy: 65.38%
#     Worker 3: Train Loss: 1.2371, Train Accuracy: 64.74%
# Epoch 127/150: Test Loss: 1.9551, Test Accuracy: 51.44%
#     Worker 0: Train Loss: 1.2471, Train Accuracy: 65.02%
#     Worker 1: Train Loss: 1.2278, Train Accuracy: 65.35%
#     Worker 2: Train Loss: 1.2392, Train Accuracy: 65.08%
#     Worker 3: Train Loss: 1.2458, Train Accuracy: 64.99%
# Epoch 128/150: Test Loss: 1.9517, Test Accuracy: 51.64%
#     Worker 0: Train Loss: 1.2353, Train Accuracy: 64.89%
#     Worker 1: Train Loss: 1.2343, Train Accuracy: 65.31%
#     Worker 2: Train Loss: 1.2456, Train Accuracy: 64.80%
#     Worker 3: Train Loss: 1.2540, Train Accuracy: 64.11%
# Epoch 129/150: Test Loss: 1.9533, Test Accuracy: 51.45%
#     Worker 0: Train Loss: 1.2386, Train Accuracy: 64.48%
#     Worker 1: Train Loss: 1.2307, Train Accuracy: 64.90%
#     Worker 2: Train Loss: 1.2208, Train Accuracy: 65.34%
#     Worker 3: Train Loss: 1.2265, Train Accuracy: 65.32%
# Epoch 130/150: Test Loss: 1.9537, Test Accuracy: 51.51%
#     Worker 0: Train Loss: 1.2368, Train Accuracy: 64.81%
#     Worker 1: Train Loss: 1.2351, Train Accuracy: 64.89%
#     Worker 2: Train Loss: 1.2322, Train Accuracy: 65.04%
#     Worker 3: Train Loss: 1.2457, Train Accuracy: 65.03%
# Epoch 131/150: Test Loss: 1.9541, Test Accuracy: 51.54%
#     Worker 0: Train Loss: 1.2263, Train Accuracy: 65.31%
#     Worker 1: Train Loss: 1.2334, Train Accuracy: 64.92%
#     Worker 2: Train Loss: 1.2259, Train Accuracy: 65.65%
#     Worker 3: Train Loss: 1.2331, Train Accuracy: 64.94%
# Epoch 132/150: Test Loss: 1.9549, Test Accuracy: 51.54%
#     Worker 0: Train Loss: 1.2328, Train Accuracy: 64.94%
#     Worker 1: Train Loss: 1.2340, Train Accuracy: 65.61%
#     Worker 2: Train Loss: 1.2237, Train Accuracy: 65.78%
#     Worker 3: Train Loss: 1.2406, Train Accuracy: 65.18%
# Epoch 133/150: Test Loss: 1.9530, Test Accuracy: 51.51%
#     Worker 0: Train Loss: 1.2392, Train Accuracy: 64.68%
#     Worker 1: Train Loss: 1.2158, Train Accuracy: 65.57%
#     Worker 2: Train Loss: 1.2192, Train Accuracy: 65.60%
#     Worker 3: Train Loss: 1.2288, Train Accuracy: 65.67%
# Epoch 134/150: Test Loss: 1.9555, Test Accuracy: 51.46%
#     Worker 0: Train Loss: 1.2287, Train Accuracy: 64.78%
#     Worker 1: Train Loss: 1.2138, Train Accuracy: 65.63%
#     Worker 2: Train Loss: 1.2330, Train Accuracy: 64.96%
#     Worker 3: Train Loss: 1.2273, Train Accuracy: 65.34%
# Epoch 135/150: Test Loss: 1.9552, Test Accuracy: 51.56%
#     Worker 0: Train Loss: 1.2170, Train Accuracy: 65.09%
#     Worker 1: Train Loss: 1.2250, Train Accuracy: 65.20%
#     Worker 2: Train Loss: 1.2128, Train Accuracy: 66.06%
#     Worker 3: Train Loss: 1.2355, Train Accuracy: 65.23%
# Epoch 136/150: Test Loss: 1.9545, Test Accuracy: 51.45%
#     Worker 0: Train Loss: 1.2228, Train Accuracy: 65.02%
#     Worker 1: Train Loss: 1.2240, Train Accuracy: 65.48%
#     Worker 2: Train Loss: 1.2302, Train Accuracy: 65.11%
#     Worker 3: Train Loss: 1.2285, Train Accuracy: 65.06%
# Epoch 137/150: Test Loss: 1.9543, Test Accuracy: 51.42%
#     Worker 0: Train Loss: 1.2123, Train Accuracy: 65.72%
#     Worker 1: Train Loss: 1.2321, Train Accuracy: 65.25%
#     Worker 2: Train Loss: 1.2190, Train Accuracy: 65.69%
#     Worker 3: Train Loss: 1.2308, Train Accuracy: 65.50%
# Epoch 138/150: Test Loss: 1.9543, Test Accuracy: 51.57%
#     Worker 0: Train Loss: 1.2240, Train Accuracy: 65.06%
#     Worker 1: Train Loss: 1.2029, Train Accuracy: 65.82%
#     Worker 2: Train Loss: 1.2142, Train Accuracy: 65.99%
#     Worker 3: Train Loss: 1.2236, Train Accuracy: 65.13%
# Epoch 139/150: Test Loss: 1.9544, Test Accuracy: 51.53%
#     Worker 0: Train Loss: 1.2165, Train Accuracy: 65.41%
#     Worker 1: Train Loss: 1.2269, Train Accuracy: 65.30%
#     Worker 2: Train Loss: 1.2290, Train Accuracy: 64.97%
#     Worker 3: Train Loss: 1.2407, Train Accuracy: 65.23%
# Epoch 140/150: Test Loss: 1.9543, Test Accuracy: 51.51%
#     Worker 0: Train Loss: 1.2194, Train Accuracy: 65.32%
#     Worker 1: Train Loss: 1.2190, Train Accuracy: 65.35%
#     Worker 2: Train Loss: 1.2154, Train Accuracy: 66.00%
#     Worker 3: Train Loss: 1.2313, Train Accuracy: 65.33%
# Epoch 141/150: Test Loss: 1.9545, Test Accuracy: 51.57%
#     Worker 0: Train Loss: 1.2161, Train Accuracy: 65.41%
#     Worker 1: Train Loss: 1.2328, Train Accuracy: 65.27%
#     Worker 2: Train Loss: 1.2175, Train Accuracy: 65.49%
#     Worker 3: Train Loss: 1.2294, Train Accuracy: 65.09%
# Epoch 142/150: Test Loss: 1.9550, Test Accuracy: 51.55%
#     Worker 0: Train Loss: 1.2347, Train Accuracy: 64.59%
#     Worker 1: Train Loss: 1.2153, Train Accuracy: 65.43%
#     Worker 2: Train Loss: 1.2080, Train Accuracy: 65.86%
#     Worker 3: Train Loss: 1.2164, Train Accuracy: 65.48%
# Epoch 143/150: Test Loss: 1.9548, Test Accuracy: 51.59%
#     Worker 0: Train Loss: 1.2251, Train Accuracy: 65.19%
#     Worker 1: Train Loss: 1.2157, Train Accuracy: 65.62%
#     Worker 2: Train Loss: 1.2103, Train Accuracy: 66.13%
#     Worker 3: Train Loss: 1.2159, Train Accuracy: 65.61%
# Epoch 144/150: Test Loss: 1.9548, Test Accuracy: 51.57%
#     Worker 0: Train Loss: 1.2084, Train Accuracy: 65.18%
#     Worker 1: Train Loss: 1.2130, Train Accuracy: 65.33%
#     Worker 2: Train Loss: 1.2164, Train Accuracy: 65.24%
#     Worker 3: Train Loss: 1.2072, Train Accuracy: 65.82%
# Epoch 145/150: Test Loss: 1.9548, Test Accuracy: 51.57%
#     Worker 0: Train Loss: 1.2311, Train Accuracy: 64.78%
#     Worker 1: Train Loss: 1.2367, Train Accuracy: 64.95%
#     Worker 2: Train Loss: 1.2094, Train Accuracy: 65.78%
#     Worker 3: Train Loss: 1.2320, Train Accuracy: 65.25%
# Epoch 146/150: Test Loss: 1.9548, Test Accuracy: 51.57%
#     Worker 0: Train Loss: 1.2186, Train Accuracy: 65.07%
#     Worker 1: Train Loss: 1.2108, Train Accuracy: 65.92%
#     Worker 2: Train Loss: 1.2054, Train Accuracy: 66.28%
#     Worker 3: Train Loss: 1.2338, Train Accuracy: 65.53%
# Epoch 147/150: Test Loss: 1.9548, Test Accuracy: 51.57%
#     Worker 0: Train Loss: 1.2174, Train Accuracy: 65.47%
#     Worker 1: Train Loss: 1.2142, Train Accuracy: 65.71%
#     Worker 2: Train Loss: 1.2224, Train Accuracy: 65.52%
#     Worker 3: Train Loss: 1.2200, Train Accuracy: 65.50%
# Epoch 148/150: Test Loss: 1.9548, Test Accuracy: 51.59%
#     Worker 0: Train Loss: 1.2225, Train Accuracy: 64.85%
#     Worker 1: Train Loss: 1.2225, Train Accuracy: 65.67%
#     Worker 2: Train Loss: 1.2179, Train Accuracy: 65.83%
#     Worker 3: Train Loss: 1.2329, Train Accuracy: 65.06%
# Epoch 149/150: Test Loss: 1.9547, Test Accuracy: 51.63%
#     Worker 0: Train Loss: 1.2173, Train Accuracy: 65.41%
#     Worker 1: Train Loss: 1.2367, Train Accuracy: 65.06%
#     Worker 2: Train Loss: 1.2213, Train Accuracy: 66.18%
#     Worker 3: Train Loss: 1.2328, Train Accuracy: 65.15%
# Epoch 150/150: Test Loss: 1.9547, Test Accuracy: 51.63%
#     Worker 0: Train Loss: 1.2186, Train Accuracy: 65.03%
#     Worker 1: Train Loss: 1.2176, Train Accuracy: 65.72%
#     Worker 2: Train Loss: 1.2078, Train Accuracy: 66.01%
#     Worker 3: Train Loss: 1.2154, Train Accuracy: 65.71%
