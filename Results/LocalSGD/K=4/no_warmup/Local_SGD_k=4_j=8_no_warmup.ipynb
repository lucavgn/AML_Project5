# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs - warmup_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")

    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch):
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            # Perform J local step before synchronization
            for j in range(J):
                try:
                    # Get a batch from the current worker's shard using next()
                    images, labels = next(shard_iterators[k])
                    images, labels = images.to(device), labels.to(device)  # Move to device
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

                except StopIteration:
                    # If the iterator has exhausted the data, restart the iterator
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k]) # Resume from the next batch
                    images, labels = images.to(device), labels.to(device)
                    # Perform optimization step
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        # Perform model synchronization
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            # Update each worker model with the global parameters
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        # if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
        # else:
        #     warmup_factor = (epoch + 1) / warmup_epochs
        #     lr = warmup_factor * learning_rate
        #     for optimizer in optimizers:
        #         for param_group in optimizer.param_groups:
        #             param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Overwriting localSGD.py

# %%
# %run localSGD.py --k 4 --j 8
# Out:
# Training with K=4, J=8
# Global iteration per epoch: 25
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:18<00:00, 9.04MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00400
# Epoch 1/150: Test Loss: 4.5806, Test Accuracy: 2.89%
#     Worker 0: Train Loss: 4.5987, Train Accuracy: 1.42%
#     Worker 1: Train Loss: 4.5999, Train Accuracy: 1.42%
#     Worker 2: Train Loss: 4.5982, Train Accuracy: 1.42%
#     Worker 3: Train Loss: 4.5987, Train Accuracy: 1.46%
# Epoch 2/150: Test Loss: 4.1941, Test Accuracy: 6.21%
#     Worker 0: Train Loss: 4.4556, Train Accuracy: 3.46%
#     Worker 1: Train Loss: 4.4577, Train Accuracy: 3.66%
#     Worker 2: Train Loss: 4.4454, Train Accuracy: 3.61%
#     Worker 3: Train Loss: 4.4496, Train Accuracy: 3.69%
# Epoch 3/150: Test Loss: 3.9521, Test Accuracy: 10.30%
#     Worker 0: Train Loss: 4.1141, Train Accuracy: 7.24%
#     Worker 1: Train Loss: 4.1222, Train Accuracy: 6.46%
#     Worker 2: Train Loss: 4.0840, Train Accuracy: 7.02%
#     Worker 3: Train Loss: 4.1173, Train Accuracy: 7.20%
# Epoch 4/150: Test Loss: 3.8117, Test Accuracy: 12.44%
#     Worker 0: Train Loss: 3.9483, Train Accuracy: 9.74%
#     Worker 1: Train Loss: 3.9589, Train Accuracy: 9.55%
#     Worker 2: Train Loss: 3.9144, Train Accuracy: 10.05%
#     Worker 3: Train Loss: 3.9523, Train Accuracy: 9.41%
# Epoch 5/150: Test Loss: 3.6896, Test Accuracy: 14.11%
#     Worker 0: Train Loss: 3.8326, Train Accuracy: 10.98%
#     Worker 1: Train Loss: 3.8284, Train Accuracy: 11.52%
#     Worker 2: Train Loss: 3.7925, Train Accuracy: 11.57%
#     Worker 3: Train Loss: 3.8268, Train Accuracy: 11.01%
# Epoch 6/150: Test Loss: 3.5885, Test Accuracy: 15.63%
#     Worker 0: Train Loss: 3.7149, Train Accuracy: 13.68%
#     Worker 1: Train Loss: 3.7224, Train Accuracy: 13.20%
#     Worker 2: Train Loss: 3.6642, Train Accuracy: 13.70%
#     Worker 3: Train Loss: 3.7255, Train Accuracy: 13.23%
# Epoch 97/150: Test Loss: 1.9612, Test Accuracy: 50.36%
#     Worker 0: Train Loss: 1.4173, Train Accuracy: 60.25%
#     Worker 1: Train Loss: 1.4067, Train Accuracy: 60.66%
#     Worker 2: Train Loss: 1.4039, Train Accuracy: 60.90%
#     Worker 3: Train Loss: 1.4265, Train Accuracy: 59.87%
# Epoch 98/150: Test Loss: 1.9508, Test Accuracy: 50.75%
#     Worker 0: Train Loss: 1.4183, Train Accuracy: 59.96%
#     Worker 1: Train Loss: 1.4193, Train Accuracy: 60.34%
#     Worker 2: Train Loss: 1.4059, Train Accuracy: 60.82%
#     Worker 3: Train Loss: 1.4093, Train Accuracy: 60.71%
# Epoch 99/150: Test Loss: 1.9555, Test Accuracy: 50.66%
#     Worker 0: Train Loss: 1.4047, Train Accuracy: 60.58%
#     Worker 1: Train Loss: 1.4186, Train Accuracy: 60.25%
#     Worker 2: Train Loss: 1.4150, Train Accuracy: 60.74%
#     Worker 3: Train Loss: 1.4085, Train Accuracy: 60.64%
# Epoch 100/150: Test Loss: 1.9612, Test Accuracy: 50.63%
#     Worker 0: Train Loss: 1.4118, Train Accuracy: 60.07%
#     Worker 1: Train Loss: 1.3942, Train Accuracy: 60.62%
#     Worker 2: Train Loss: 1.4086, Train Accuracy: 60.77%
#     Worker 3: Train Loss: 1.4081, Train Accuracy: 60.36%
# Epoch 101/150: Test Loss: 1.9552, Test Accuracy: 50.74%
#     Worker 0: Train Loss: 1.3872, Train Accuracy: 61.01%
#     Worker 1: Train Loss: 1.4038, Train Accuracy: 60.90%
#     Worker 2: Train Loss: 1.3813, Train Accuracy: 60.79%
#     Worker 3: Train Loss: 1.3984, Train Accuracy: 60.97%
# Epoch 102/150: Test Loss: 1.9577, Test Accuracy: 50.90%
#     Worker 0: Train Loss: 1.3777, Train Accuracy: 61.15%
#     Worker 1: Train Loss: 1.3963, Train Accuracy: 60.62%
#     Worker 2: Train Loss: 1.3915, Train Accuracy: 61.25%
#     Worker 3: Train Loss: 1.3963, Train Accuracy: 61.15%
# Epoch 103/150: Test Loss: 1.9483, Test Accuracy: 50.75%
#     Worker 0: Train Loss: 1.3681, Train Accuracy: 61.21%
#     Worker 1: Train Loss: 1.3713, Train Accuracy: 61.85%
#     Worker 2: Train Loss: 1.3899, Train Accuracy: 61.01%
#     Worker 3: Train Loss: 1.3966, Train Accuracy: 60.93%
# Epoch 104/150: Test Loss: 1.9511, Test Accuracy: 50.71%
#     Worker 0: Train Loss: 1.3696, Train Accuracy: 61.02%
#     Worker 1: Train Loss: 1.3695, Train Accuracy: 61.57%
#     Worker 2: Train Loss: 1.3539, Train Accuracy: 62.17%
#     Worker 3: Train Loss: 1.3684, Train Accuracy: 62.14%
# Epoch 105/150: Test Loss: 1.9525, Test Accuracy: 50.63%
#     Worker 0: Train Loss: 1.3636, Train Accuracy: 61.56%
#     Worker 1: Train Loss: 1.3531, Train Accuracy: 62.76%
#     Worker 2: Train Loss: 1.3649, Train Accuracy: 61.75%
#     Worker 3: Train Loss: 1.3654, Train Accuracy: 61.70%
# Epoch 106/150: Test Loss: 1.9571, Test Accuracy: 50.94%
#     Worker 0: Train Loss: 1.3637, Train Accuracy: 61.37%
#     Worker 1: Train Loss: 1.3596, Train Accuracy: 62.26%
#     Worker 2: Train Loss: 1.3693, Train Accuracy: 61.59%
#     Worker 3: Train Loss: 1.3559, Train Accuracy: 61.78%
# Epoch 107/150: Test Loss: 1.9499, Test Accuracy: 50.92%
#     Worker 0: Train Loss: 1.3461, Train Accuracy: 61.97%
#     Worker 1: Train Loss: 1.3621, Train Accuracy: 62.06%
#     Worker 2: Train Loss: 1.3423, Train Accuracy: 62.40%
#     Worker 3: Train Loss: 1.3657, Train Accuracy: 61.87%
# Epoch 108/150: Test Loss: 1.9555, Test Accuracy: 51.11%
#     Worker 0: Train Loss: 1.3582, Train Accuracy: 61.32%
#     Worker 1: Train Loss: 1.3482, Train Accuracy: 61.96%
#     Worker 2: Train Loss: 1.3385, Train Accuracy: 62.39%
#     Worker 3: Train Loss: 1.3261, Train Accuracy: 62.86%
# Epoch 109/150: Test Loss: 1.9558, Test Accuracy: 50.96%
#     Worker 0: Train Loss: 1.3385, Train Accuracy: 61.91%
#     Worker 1: Train Loss: 1.3185, Train Accuracy: 62.87%
#     Worker 2: Train Loss: 1.3364, Train Accuracy: 63.01%
#     Worker 3: Train Loss: 1.3523, Train Accuracy: 62.04%
# Epoch 110/150: Test Loss: 1.9614, Test Accuracy: 51.00%
#     Worker 0: Train Loss: 1.3136, Train Accuracy: 62.79%
#     Worker 1: Train Loss: 1.3312, Train Accuracy: 63.32%
#     Worker 2: Train Loss: 1.3230, Train Accuracy: 62.83%
#     Worker 3: Train Loss: 1.3421, Train Accuracy: 62.32%
# Epoch 111/150: Test Loss: 1.9550, Test Accuracy: 50.60%
#     Worker 0: Train Loss: 1.3376, Train Accuracy: 61.74%
#     Worker 1: Train Loss: 1.3293, Train Accuracy: 62.91%
#     Worker 2: Train Loss: 1.3218, Train Accuracy: 63.32%
#     Worker 3: Train Loss: 1.3330, Train Accuracy: 62.54%
# Epoch 112/150: Test Loss: 1.9466, Test Accuracy: 51.30%
#     Worker 0: Train Loss: 1.3132, Train Accuracy: 62.72%
#     Worker 1: Train Loss: 1.3349, Train Accuracy: 62.61%
#     Worker 2: Train Loss: 1.3216, Train Accuracy: 62.90%
#     Worker 3: Train Loss: 1.3257, Train Accuracy: 62.68%
# Epoch 113/150: Test Loss: 1.9506, Test Accuracy: 51.34%
#     Worker 0: Train Loss: 1.3178, Train Accuracy: 62.73%
#     Worker 1: Train Loss: 1.3032, Train Accuracy: 63.46%
#     Worker 2: Train Loss: 1.3375, Train Accuracy: 62.21%
#     Worker 3: Train Loss: 1.3205, Train Accuracy: 62.37%
# Epoch 114/150: Test Loss: 1.9527, Test Accuracy: 51.12%
#     Worker 0: Train Loss: 1.3127, Train Accuracy: 62.72%
#     Worker 1: Train Loss: 1.3117, Train Accuracy: 63.17%
#     Worker 2: Train Loss: 1.2976, Train Accuracy: 63.25%
#     Worker 3: Train Loss: 1.3039, Train Accuracy: 63.60%
# Epoch 115/150: Test Loss: 1.9511, Test Accuracy: 51.23%
#     Worker 0: Train Loss: 1.3018, Train Accuracy: 62.96%
#     Worker 1: Train Loss: 1.3371, Train Accuracy: 62.75%
#     Worker 2: Train Loss: 1.3162, Train Accuracy: 63.13%
#     Worker 3: Train Loss: 1.3178, Train Accuracy: 63.23%
# Epoch 116/150: Test Loss: 1.9595, Test Accuracy: 51.10%
#     Worker 0: Train Loss: 1.2958, Train Accuracy: 63.13%
#     Worker 1: Train Loss: 1.3078, Train Accuracy: 63.51%
#     Worker 2: Train Loss: 1.3079, Train Accuracy: 63.00%
#     Worker 3: Train Loss: 1.3192, Train Accuracy: 63.01%
# Epoch 117/150: Test Loss: 1.9523, Test Accuracy: 51.06%
#     Worker 0: Train Loss: 1.2963, Train Accuracy: 63.37%
#     Worker 1: Train Loss: 1.2894, Train Accuracy: 63.55%
#     Worker 2: Train Loss: 1.3226, Train Accuracy: 63.27%
#     Worker 3: Train Loss: 1.2761, Train Accuracy: 64.13%
# Epoch 118/150: Test Loss: 1.9516, Test Accuracy: 51.35%
#     Worker 0: Train Loss: 1.2698, Train Accuracy: 64.07%
#     Worker 1: Train Loss: 1.3120, Train Accuracy: 63.26%
#     Worker 2: Train Loss: 1.2772, Train Accuracy: 64.24%
#     Worker 3: Train Loss: 1.3239, Train Accuracy: 62.72%
# Epoch 119/150: Test Loss: 1.9497, Test Accuracy: 51.45%
#     Worker 0: Train Loss: 1.2888, Train Accuracy: 63.19%
#     Worker 1: Train Loss: 1.3034, Train Accuracy: 63.99%
#     Worker 2: Train Loss: 1.2981, Train Accuracy: 63.55%
#     Worker 3: Train Loss: 1.2921, Train Accuracy: 63.86%
# Epoch 120/150: Test Loss: 1.9523, Test Accuracy: 51.28%
#     Worker 0: Train Loss: 1.2824, Train Accuracy: 63.45%
#     Worker 1: Train Loss: 1.2772, Train Accuracy: 64.13%
#     Worker 2: Train Loss: 1.2917, Train Accuracy: 63.83%
#     Worker 3: Train Loss: 1.2764, Train Accuracy: 64.57%
# Epoch 121/150: Test Loss: 1.9516, Test Accuracy: 51.40%
#     Worker 0: Train Loss: 1.2929, Train Accuracy: 63.59%
#     Worker 1: Train Loss: 1.2705, Train Accuracy: 64.54%
#     Worker 2: Train Loss: 1.2795, Train Accuracy: 63.69%
#     Worker 3: Train Loss: 1.3013, Train Accuracy: 63.55%
# Epoch 122/150: Test Loss: 1.9503, Test Accuracy: 51.68%
#     Worker 0: Train Loss: 1.2712, Train Accuracy: 63.91%
#     Worker 1: Train Loss: 1.2898, Train Accuracy: 64.12%
#     Worker 2: Train Loss: 1.2867, Train Accuracy: 63.67%
#     Worker 3: Train Loss: 1.2768, Train Accuracy: 64.12%
# Epoch 123/150: Test Loss: 1.9578, Test Accuracy: 51.43%
#     Worker 0: Train Loss: 1.2647, Train Accuracy: 63.60%
#     Worker 1: Train Loss: 1.2612, Train Accuracy: 64.71%
#     Worker 2: Train Loss: 1.2669, Train Accuracy: 64.28%
#     Worker 3: Train Loss: 1.2672, Train Accuracy: 64.45%
# Epoch 124/150: Test Loss: 1.9526, Test Accuracy: 51.38%
#     Worker 0: Train Loss: 1.2692, Train Accuracy: 63.99%
#     Worker 1: Train Loss: 1.2842, Train Accuracy: 63.96%
#     Worker 2: Train Loss: 1.2771, Train Accuracy: 64.21%
#     Worker 3: Train Loss: 1.2812, Train Accuracy: 64.21%
# Epoch 125/150: Test Loss: 1.9527, Test Accuracy: 51.37%
#     Worker 0: Train Loss: 1.2649, Train Accuracy: 64.35%
#     Worker 1: Train Loss: 1.2702, Train Accuracy: 64.60%
#     Worker 2: Train Loss: 1.2755, Train Accuracy: 64.23%
#     Worker 3: Train Loss: 1.2641, Train Accuracy: 64.08%
# Epoch 126/150: Test Loss: 1.9494, Test Accuracy: 51.61%
#     Worker 0: Train Loss: 1.2735, Train Accuracy: 63.56%
#     Worker 1: Train Loss: 1.2699, Train Accuracy: 64.32%
#     Worker 2: Train Loss: 1.2912, Train Accuracy: 64.24%
#     Worker 3: Train Loss: 1.2455, Train Accuracy: 65.31%
# Epoch 127/150: Test Loss: 1.9555, Test Accuracy: 51.49%
#     Worker 0: Train Loss: 1.2524, Train Accuracy: 64.42%
#     Worker 1: Train Loss: 1.2565, Train Accuracy: 64.52%
#     Worker 2: Train Loss: 1.2616, Train Accuracy: 64.81%
#     Worker 3: Train Loss: 1.2785, Train Accuracy: 63.79%
# Epoch 128/150: Test Loss: 1.9524, Test Accuracy: 51.51%
#     Worker 0: Train Loss: 1.2633, Train Accuracy: 63.97%
#     Worker 1: Train Loss: 1.2915, Train Accuracy: 64.12%
#     Worker 2: Train Loss: 1.2696, Train Accuracy: 64.31%
#     Worker 3: Train Loss: 1.2628, Train Accuracy: 64.74%
# Epoch 129/150: Test Loss: 1.9537, Test Accuracy: 51.45%
#     Worker 0: Train Loss: 1.2690, Train Accuracy: 64.11%
#     Worker 1: Train Loss: 1.2659, Train Accuracy: 64.24%
#     Worker 2: Train Loss: 1.2717, Train Accuracy: 64.60%
#     Worker 3: Train Loss: 1.2588, Train Accuracy: 64.10%
# Epoch 130/150: Test Loss: 1.9525, Test Accuracy: 51.47%
#     Worker 0: Train Loss: 1.2610, Train Accuracy: 63.96%
#     Worker 1: Train Loss: 1.2544, Train Accuracy: 64.46%
#     Worker 2: Train Loss: 1.2599, Train Accuracy: 64.33%
#     Worker 3: Train Loss: 1.2456, Train Accuracy: 64.97%
# Epoch 131/150: Test Loss: 1.9534, Test Accuracy: 51.61%
#     Worker 0: Train Loss: 1.2415, Train Accuracy: 64.98%
#     Worker 1: Train Loss: 1.2663, Train Accuracy: 64.50%
#     Worker 2: Train Loss: 1.2472, Train Accuracy: 65.19%
#     Worker 3: Train Loss: 1.2660, Train Accuracy: 64.39%
# Epoch 132/150: Test Loss: 1.9547, Test Accuracy: 51.74%
#     Worker 0: Train Loss: 1.2691, Train Accuracy: 64.29%
#     Worker 1: Train Loss: 1.2467, Train Accuracy: 64.74%
#     Worker 2: Train Loss: 1.2713, Train Accuracy: 64.09%
#     Worker 3: Train Loss: 1.2537, Train Accuracy: 64.59%
# Epoch 133/150: Test Loss: 1.9533, Test Accuracy: 51.75%
#     Worker 0: Train Loss: 1.2406, Train Accuracy: 64.83%
#     Worker 1: Train Loss: 1.2608, Train Accuracy: 64.71%
#     Worker 2: Train Loss: 1.2493, Train Accuracy: 64.80%
#     Worker 3: Train Loss: 1.2449, Train Accuracy: 64.93%
# Epoch 134/150: Test Loss: 1.9550, Test Accuracy: 51.45%
#     Worker 0: Train Loss: 1.2291, Train Accuracy: 64.98%
#     Worker 1: Train Loss: 1.2555, Train Accuracy: 64.64%
#     Worker 2: Train Loss: 1.2559, Train Accuracy: 64.36%
#     Worker 3: Train Loss: 1.2571, Train Accuracy: 65.00%
# Epoch 135/150: Test Loss: 1.9523, Test Accuracy: 51.50%
#     Worker 0: Train Loss: 1.2698, Train Accuracy: 64.09%
#     Worker 1: Train Loss: 1.2534, Train Accuracy: 65.41%
#     Worker 2: Train Loss: 1.2563, Train Accuracy: 65.33%
#     Worker 3: Train Loss: 1.2421, Train Accuracy: 64.93%
# Epoch 136/150: Test Loss: 1.9528, Test Accuracy: 51.53%
#     Worker 0: Train Loss: 1.2332, Train Accuracy: 65.00%
#     Worker 1: Train Loss: 1.2443, Train Accuracy: 65.14%
#     Worker 2: Train Loss: 1.2591, Train Accuracy: 64.64%
#     Worker 3: Train Loss: 1.2438, Train Accuracy: 64.85%
# Epoch 137/150: Test Loss: 1.9533, Test Accuracy: 51.64%
#     Worker 0: Train Loss: 1.2482, Train Accuracy: 63.95%
#     Worker 1: Train Loss: 1.2302, Train Accuracy: 65.49%
#     Worker 2: Train Loss: 1.2431, Train Accuracy: 64.76%
#     Worker 3: Train Loss: 1.2422, Train Accuracy: 65.22%
# Epoch 138/150: Test Loss: 1.9527, Test Accuracy: 51.65%
#     Worker 0: Train Loss: 1.2555, Train Accuracy: 64.20%
#     Worker 1: Train Loss: 1.2516, Train Accuracy: 64.88%
#     Worker 2: Train Loss: 1.2401, Train Accuracy: 65.28%
#     Worker 3: Train Loss: 1.2655, Train Accuracy: 64.24%
# Epoch 139/150: Test Loss: 1.9533, Test Accuracy: 51.57%
#     Worker 0: Train Loss: 1.2475, Train Accuracy: 64.86%
#     Worker 1: Train Loss: 1.2478, Train Accuracy: 65.07%
#     Worker 2: Train Loss: 1.2497, Train Accuracy: 64.81%
#     Worker 3: Train Loss: 1.2301, Train Accuracy: 64.92%
# Epoch 140/150: Test Loss: 1.9532, Test Accuracy: 51.66%
#     Worker 0: Train Loss: 1.2494, Train Accuracy: 64.86%
#     Worker 1: Train Loss: 1.2593, Train Accuracy: 64.57%
#     Worker 2: Train Loss: 1.2400, Train Accuracy: 65.16%
#     Worker 3: Train Loss: 1.2427, Train Accuracy: 64.46%
# Epoch 141/150: Test Loss: 1.9530, Test Accuracy: 51.63%
#     Worker 0: Train Loss: 1.2365, Train Accuracy: 64.71%
#     Worker 1: Train Loss: 1.2475, Train Accuracy: 64.96%
#     Worker 2: Train Loss: 1.2431, Train Accuracy: 65.02%
#     Worker 3: Train Loss: 1.2480, Train Accuracy: 64.97%
# Epoch 142/150: Test Loss: 1.9529, Test Accuracy: 51.56%
#     Worker 0: Train Loss: 1.2469, Train Accuracy: 65.09%
#     Worker 1: Train Loss: 1.2385, Train Accuracy: 65.01%
#     Worker 2: Train Loss: 1.2348, Train Accuracy: 65.41%
#     Worker 3: Train Loss: 1.2398, Train Accuracy: 65.05%
# Epoch 143/150: Test Loss: 1.9529, Test Accuracy: 51.58%
#     Worker 0: Train Loss: 1.2356, Train Accuracy: 65.14%
#     Worker 1: Train Loss: 1.2509, Train Accuracy: 64.77%
#     Worker 2: Train Loss: 1.2434, Train Accuracy: 65.01%
#     Worker 3: Train Loss: 1.2452, Train Accuracy: 64.56%
# Epoch 144/150: Test Loss: 1.9528, Test Accuracy: 51.58%
#     Worker 0: Train Loss: 1.2484, Train Accuracy: 64.39%
#     Worker 1: Train Loss: 1.2457, Train Accuracy: 64.97%
#     Worker 2: Train Loss: 1.2458, Train Accuracy: 65.03%
#     Worker 3: Train Loss: 1.2405, Train Accuracy: 65.26%
# Epoch 145/150: Test Loss: 1.9528, Test Accuracy: 51.57%
#     Worker 0: Train Loss: 1.2410, Train Accuracy: 64.89%
#     Worker 1: Train Loss: 1.2386, Train Accuracy: 65.58%
#     Worker 2: Train Loss: 1.2420, Train Accuracy: 65.04%
#     Worker 3: Train Loss: 1.2463, Train Accuracy: 64.89%
# Epoch 146/150: Test Loss: 1.9528, Test Accuracy: 51.57%
#     Worker 0: Train Loss: 1.2365, Train Accuracy: 65.00%
#     Worker 1: Train Loss: 1.2483, Train Accuracy: 64.75%
#     Worker 2: Train Loss: 1.2552, Train Accuracy: 64.98%
#     Worker 3: Train Loss: 1.2377, Train Accuracy: 64.50%
# Epoch 147/150: Test Loss: 1.9528, Test Accuracy: 51.59%
#     Worker 0: Train Loss: 1.2584, Train Accuracy: 64.07%
#     Worker 1: Train Loss: 1.2436, Train Accuracy: 65.23%
#     Worker 2: Train Loss: 1.2522, Train Accuracy: 65.28%
#     Worker 3: Train Loss: 1.2334, Train Accuracy: 65.65%
# Epoch 148/150: Test Loss: 1.9528, Test Accuracy: 51.63%
#     Worker 0: Train Loss: 1.2527, Train Accuracy: 64.69%
#     Worker 1: Train Loss: 1.2524, Train Accuracy: 64.55%
#     Worker 2: Train Loss: 1.2397, Train Accuracy: 65.21%
#     Worker 3: Train Loss: 1.2468, Train Accuracy: 65.17%
# Epoch 149/150: Test Loss: 1.9529, Test Accuracy: 51.59%
#     Worker 0: Train Loss: 1.2431, Train Accuracy: 65.15%
#     Worker 1: Train Loss: 1.2359, Train Accuracy: 65.02%
#     Worker 2: Train Loss: 1.2457, Train Accuracy: 64.74%
#     Worker 3: Train Loss: 1.2497, Train Accuracy: 64.86%
# Epoch 150/150: Test Loss: 1.9530, Test Accuracy: 51.54%
#     Worker 0: Train Loss: 1.2489, Train Accuracy: 64.39%
#     Worker 1: Train Loss: 1.2541, Train Accuracy: 64.78%
#     Worker 2: Train Loss: 1.2504, Train Accuracy: 64.95%
#     Worker 3: Train Loss: 1.2500, Train Accuracy: 64.75%
