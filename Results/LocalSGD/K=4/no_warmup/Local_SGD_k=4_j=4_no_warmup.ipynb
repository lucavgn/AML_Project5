# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs - warmup_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")

    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch):
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            # Perform J local step before synchronization
            for j in range(J):
                try:
                    # Get a batch from the current worker's shard using next()
                    images, labels = next(shard_iterators[k])
                    images, labels = images.to(device), labels.to(device)  # Move to device
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

                except StopIteration:
                    # If the iterator has exhausted the data, restart the iterator
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k]) # Resume from the next batch
                    images, labels = images.to(device), labels.to(device)
                    # Perform optimization step
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        # Perform model synchronization
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            # Update each worker model with the global parameters
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        # if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
        # else:
        #     warmup_factor = (epoch + 1) / warmup_epochs
        #     lr = warmup_factor * learning_rate
        #     for optimizer in optimizers:
        #         for param_group in optimizer.param_groups:
        #             param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 4 --j 4
# Out:
# Training with K=4, J=4
# Global iteration per epoch: 49
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:12<00:00, 13.1MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00400
# Epoch 1/150: Test Loss: 4.5810, Test Accuracy: 2.98%
#     Worker 0: Train Loss: 4.5986, Train Accuracy: 1.51%
#     Worker 1: Train Loss: 4.5997, Train Accuracy: 1.31%
#     Worker 2: Train Loss: 4.5983, Train Accuracy: 1.46%
#     Worker 3: Train Loss: 4.5989, Train Accuracy: 1.39%
# Epoch 2/150: Test Loss: 4.1927, Test Accuracy: 6.30%
#     Worker 0: Train Loss: 4.4597, Train Accuracy: 3.65%
#     Worker 1: Train Loss: 4.4597, Train Accuracy: 3.45%
#     Worker 2: Train Loss: 4.4462, Train Accuracy: 3.84%
#     Worker 3: Train Loss: 4.4549, Train Accuracy: 3.63%
# Epoch 3/150: Test Loss: 3.9470, Test Accuracy: 10.19%
#     Worker 0: Train Loss: 4.1072, Train Accuracy: 6.92%
#     Worker 1: Train Loss: 4.1133, Train Accuracy: 7.14%
#     Worker 2: Train Loss: 4.0737, Train Accuracy: 7.62%
#     Worker 3: Train Loss: 4.1098, Train Accuracy: 7.15%
# Epoch 4/150: Test Loss: 3.8053, Test Accuracy: 12.52%
#     Worker 0: Train Loss: 3.9370, Train Accuracy: 9.57%
#     Worker 1: Train Loss: 3.9361, Train Accuracy: 9.78%
#     Worker 2: Train Loss: 3.8965, Train Accuracy: 10.62%
#     Worker 3: Train Loss: 3.9255, Train Accuracy: 10.26%
# Epoch 5/150: Test Loss: 3.6553, Test Accuracy: 14.97%
#     Worker 0: Train Loss: 3.8123, Train Accuracy: 11.83%
#     Worker 1: Train Loss: 3.8090, Train Accuracy: 11.78%
#     Worker 2: Train Loss: 3.7621, Train Accuracy: 12.76%
#     Worker 3: Train Loss: 3.8008, Train Accuracy: 11.72%
# Epoch 6/150: Test Loss: 3.5536, Test Accuracy: 16.60%
#     Worker 0: Train Loss: 3.6953, Train Accuracy: 13.80%
#     Worker 1: Train Loss: 3.6982, Train Accuracy: 13.86%
#     Worker 2: Train Loss: 3.6495, Train Accuracy: 14.86%
#     Worker 3: Train Loss: 3.6935, Train Accuracy: 13.74%
# Epoch 52/150: Test Loss: 2.0828, Test Accuracy: 45.70%
#     Worker 0: Train Loss: 1.9200, Train Accuracy: 47.67%
#     Worker 1: Train Loss: 1.9198, Train Accuracy: 48.42%
#     Worker 2: Train Loss: 1.9078, Train Accuracy: 49.18%
#     Worker 3: Train Loss: 1.9229, Train Accuracy: 48.34%
# Epoch 53/150: Test Loss: 2.0700, Test Accuracy: 46.08%
#     Worker 0: Train Loss: 1.9100, Train Accuracy: 48.31%
#     Worker 1: Train Loss: 1.9052, Train Accuracy: 48.90%
#     Worker 2: Train Loss: 1.9042, Train Accuracy: 49.02%
#     Worker 3: Train Loss: 1.9088, Train Accuracy: 48.79%
# Epoch 54/150: Test Loss: 2.0825, Test Accuracy: 46.12%
#     Worker 0: Train Loss: 1.8975, Train Accuracy: 48.68%
#     Worker 1: Train Loss: 1.8997, Train Accuracy: 49.20%
#     Worker 2: Train Loss: 1.8909, Train Accuracy: 49.08%
#     Worker 3: Train Loss: 1.8938, Train Accuracy: 49.08%
# Epoch 55/150: Test Loss: 2.0533, Test Accuracy: 46.80%
#     Worker 0: Train Loss: 1.8812, Train Accuracy: 49.09%
#     Worker 1: Train Loss: 1.8839, Train Accuracy: 49.02%
#     Worker 2: Train Loss: 1.8808, Train Accuracy: 49.62%
#     Worker 3: Train Loss: 1.8750, Train Accuracy: 49.31%
# Epoch 56/150: Test Loss: 2.0622, Test Accuracy: 46.91%
#     Worker 0: Train Loss: 1.8665, Train Accuracy: 49.24%
#     Worker 1: Train Loss: 1.8588, Train Accuracy: 49.64%
#     Worker 2: Train Loss: 1.8395, Train Accuracy: 50.17%
#     Worker 3: Train Loss: 1.8581, Train Accuracy: 49.86%
# Epoch 57/150: Test Loss: 2.0360, Test Accuracy: 47.01%
#     Worker 0: Train Loss: 1.8518, Train Accuracy: 49.38%
#     Worker 1: Train Loss: 1.8577, Train Accuracy: 49.58%
#     Worker 2: Train Loss: 1.8208, Train Accuracy: 51.02%
#     Worker 3: Train Loss: 1.8578, Train Accuracy: 49.77%
# Epoch 58/150: Test Loss: 2.0339, Test Accuracy: 47.23%
#     Worker 0: Train Loss: 1.8341, Train Accuracy: 50.24%
#     Worker 1: Train Loss: 1.8376, Train Accuracy: 50.00%
#     Worker 2: Train Loss: 1.8257, Train Accuracy: 50.74%
#     Worker 3: Train Loss: 1.8388, Train Accuracy: 50.63%
# Epoch 59/150: Test Loss: 2.0318, Test Accuracy: 47.07%
#     Worker 0: Train Loss: 1.8176, Train Accuracy: 50.50%
#     Worker 1: Train Loss: 1.8274, Train Accuracy: 50.55%
#     Worker 2: Train Loss: 1.8051, Train Accuracy: 51.38%
#     Worker 3: Train Loss: 1.8227, Train Accuracy: 50.18%
# Epoch 60/150: Test Loss: 2.0498, Test Accuracy: 46.91%
#     Worker 0: Train Loss: 1.8055, Train Accuracy: 51.04%
#     Worker 1: Train Loss: 1.8110, Train Accuracy: 50.98%
#     Worker 2: Train Loss: 1.8003, Train Accuracy: 51.22%
#     Worker 3: Train Loss: 1.8158, Train Accuracy: 50.92%
# Epoch 88/150: Test Loss: 1.9670, Test Accuracy: 49.57%
#     Worker 0: Train Loss: 1.4812, Train Accuracy: 58.35%
#     Worker 1: Train Loss: 1.4985, Train Accuracy: 58.39%
#     Worker 2: Train Loss: 1.4857, Train Accuracy: 58.30%
#     Worker 3: Train Loss: 1.5025, Train Accuracy: 58.54%
# Epoch 89/150: Test Loss: 1.9571, Test Accuracy: 49.89%
#     Worker 0: Train Loss: 1.4805, Train Accuracy: 58.54%
#     Worker 1: Train Loss: 1.4885, Train Accuracy: 58.12%
#     Worker 2: Train Loss: 1.4744, Train Accuracy: 59.30%
#     Worker 3: Train Loss: 1.4981, Train Accuracy: 58.66%
# Epoch 90/150: Test Loss: 1.9659, Test Accuracy: 49.92%
#     Worker 0: Train Loss: 1.4746, Train Accuracy: 58.62%
#     Worker 1: Train Loss: 1.4833, Train Accuracy: 58.94%
#     Worker 2: Train Loss: 1.4783, Train Accuracy: 58.73%
#     Worker 3: Train Loss: 1.4806, Train Accuracy: 58.82%
# Epoch 91/150: Test Loss: 1.9653, Test Accuracy: 49.71%
#     Worker 0: Train Loss: 1.4770, Train Accuracy: 58.46%
#     Worker 1: Train Loss: 1.4675, Train Accuracy: 58.98%
#     Worker 2: Train Loss: 1.4576, Train Accuracy: 59.82%
#     Worker 3: Train Loss: 1.4708, Train Accuracy: 58.79%
# Epoch 92/150: Test Loss: 1.9535, Test Accuracy: 50.33%
#     Worker 0: Train Loss: 1.4751, Train Accuracy: 58.73%
#     Worker 1: Train Loss: 1.4631, Train Accuracy: 59.54%
#     Worker 2: Train Loss: 1.4604, Train Accuracy: 59.60%
#     Worker 3: Train Loss: 1.4731, Train Accuracy: 58.66%
# Epoch 93/150: Test Loss: 1.9522, Test Accuracy: 50.54%
#     Worker 0: Train Loss: 1.4601, Train Accuracy: 59.05%
#     Worker 1: Train Loss: 1.4641, Train Accuracy: 59.57%
#     Worker 2: Train Loss: 1.4402, Train Accuracy: 59.90%
#     Worker 3: Train Loss: 1.4550, Train Accuracy: 59.42%
# Epoch 94/150: Test Loss: 1.9488, Test Accuracy: 50.38%
#     Worker 0: Train Loss: 1.4412, Train Accuracy: 59.46%
#     Worker 1: Train Loss: 1.4385, Train Accuracy: 59.92%
#     Worker 2: Train Loss: 1.4327, Train Accuracy: 60.09%
#     Worker 3: Train Loss: 1.4535, Train Accuracy: 59.53%
# Epoch 95/150: Test Loss: 1.9457, Test Accuracy: 50.55%
#     Worker 0: Train Loss: 1.4423, Train Accuracy: 59.66%
#     Worker 1: Train Loss: 1.4484, Train Accuracy: 59.47%
#     Worker 2: Train Loss: 1.4291, Train Accuracy: 60.22%
#     Worker 3: Train Loss: 1.4310, Train Accuracy: 60.06%
# Epoch 96/150: Test Loss: 1.9479, Test Accuracy: 50.46%
#     Worker 0: Train Loss: 1.4321, Train Accuracy: 59.86%
#     Worker 1: Train Loss: 1.4279, Train Accuracy: 60.33%
#     Worker 2: Train Loss: 1.4092, Train Accuracy: 60.44%
#     Worker 3: Train Loss: 1.4303, Train Accuracy: 59.92%
# Epoch 97/150: Test Loss: 1.9438, Test Accuracy: 50.77%
#     Worker 0: Train Loss: 1.4190, Train Accuracy: 59.96%
#     Worker 1: Train Loss: 1.4326, Train Accuracy: 60.47%
#     Worker 2: Train Loss: 1.4166, Train Accuracy: 60.18%
#     Worker 3: Train Loss: 1.4329, Train Accuracy: 60.44%
# Epoch 98/150: Test Loss: 1.9540, Test Accuracy: 50.36%
#     Worker 0: Train Loss: 1.4170, Train Accuracy: 59.74%
#     Worker 1: Train Loss: 1.4098, Train Accuracy: 60.82%
#     Worker 2: Train Loss: 1.3941, Train Accuracy: 61.12%
#     Worker 3: Train Loss: 1.4140, Train Accuracy: 60.84%
# Epoch 99/150: Test Loss: 1.9513, Test Accuracy: 50.55%
#     Worker 0: Train Loss: 1.4090, Train Accuracy: 60.26%
#     Worker 1: Train Loss: 1.4010, Train Accuracy: 60.69%
#     Worker 2: Train Loss: 1.4168, Train Accuracy: 60.62%
#     Worker 3: Train Loss: 1.4013, Train Accuracy: 60.70%
# Epoch 100/150: Test Loss: 1.9479, Test Accuracy: 50.57%
#     Worker 0: Train Loss: 1.3976, Train Accuracy: 60.86%
#     Worker 1: Train Loss: 1.4037, Train Accuracy: 60.58%
#     Worker 2: Train Loss: 1.4074, Train Accuracy: 60.48%
#     Worker 3: Train Loss: 1.4019, Train Accuracy: 60.59%
# Epoch 101/150: Test Loss: 1.9541, Test Accuracy: 50.51%
#     Worker 0: Train Loss: 1.3980, Train Accuracy: 60.56%
#     Worker 1: Train Loss: 1.4041, Train Accuracy: 60.64%
#     Worker 2: Train Loss: 1.3809, Train Accuracy: 61.22%
#     Worker 3: Train Loss: 1.3893, Train Accuracy: 61.26%
# Epoch 102/150: Test Loss: 1.9385, Test Accuracy: 50.67%
#     Worker 0: Train Loss: 1.3790, Train Accuracy: 60.86%
#     Worker 1: Train Loss: 1.3923, Train Accuracy: 60.87%
#     Worker 2: Train Loss: 1.3714, Train Accuracy: 61.68%
#     Worker 3: Train Loss: 1.3916, Train Accuracy: 61.67%
# Epoch 103/150: Test Loss: 1.9469, Test Accuracy: 50.71%
#     Worker 0: Train Loss: 1.3883, Train Accuracy: 61.03%
#     Worker 1: Train Loss: 1.3750, Train Accuracy: 61.69%
#     Worker 2: Train Loss: 1.3670, Train Accuracy: 61.94%
#     Worker 3: Train Loss: 1.3851, Train Accuracy: 61.55%
# Epoch 104/150: Test Loss: 1.9482, Test Accuracy: 50.70%
#     Worker 0: Train Loss: 1.3679, Train Accuracy: 61.22%
#     Worker 1: Train Loss: 1.3725, Train Accuracy: 61.90%
#     Worker 2: Train Loss: 1.3699, Train Accuracy: 61.71%
#     Worker 3: Train Loss: 1.3814, Train Accuracy: 61.53%
# Epoch 105/150: Test Loss: 1.9517, Test Accuracy: 51.02%
#     Worker 0: Train Loss: 1.3629, Train Accuracy: 61.39%
#     Worker 1: Train Loss: 1.3711, Train Accuracy: 61.62%
#     Worker 2: Train Loss: 1.3702, Train Accuracy: 61.82%
#     Worker 3: Train Loss: 1.3738, Train Accuracy: 61.84%
# Epoch 115/150: Test Loss: 1.9478, Test Accuracy: 50.74%
#     Worker 0: Train Loss: 1.3123, Train Accuracy: 62.93%
#     Worker 1: Train Loss: 1.3249, Train Accuracy: 62.48%
#     Worker 2: Train Loss: 1.3043, Train Accuracy: 63.80%
#     Worker 3: Train Loss: 1.3214, Train Accuracy: 62.98%
# Epoch 116/150: Test Loss: 1.9453, Test Accuracy: 51.00%
#     Worker 0: Train Loss: 1.3099, Train Accuracy: 63.06%
#     Worker 1: Train Loss: 1.3136, Train Accuracy: 62.86%
#     Worker 2: Train Loss: 1.3194, Train Accuracy: 62.88%
#     Worker 3: Train Loss: 1.3148, Train Accuracy: 63.33%
# Epoch 117/150: Test Loss: 1.9442, Test Accuracy: 51.23%
#     Worker 0: Train Loss: 1.3047, Train Accuracy: 62.71%
#     Worker 1: Train Loss: 1.3162, Train Accuracy: 63.08%
#     Worker 2: Train Loss: 1.3136, Train Accuracy: 63.04%
#     Worker 3: Train Loss: 1.3123, Train Accuracy: 63.22%
# Epoch 118/150: Test Loss: 1.9442, Test Accuracy: 50.90%
#     Worker 0: Train Loss: 1.2983, Train Accuracy: 63.01%
#     Worker 1: Train Loss: 1.3240, Train Accuracy: 62.93%
#     Worker 2: Train Loss: 1.2952, Train Accuracy: 63.55%
#     Worker 3: Train Loss: 1.3170, Train Accuracy: 63.38%
# Epoch 119/150: Test Loss: 1.9422, Test Accuracy: 51.05%
#     Worker 0: Train Loss: 1.3040, Train Accuracy: 62.96%
#     Worker 1: Train Loss: 1.3069, Train Accuracy: 63.28%
#     Worker 2: Train Loss: 1.2860, Train Accuracy: 63.71%
#     Worker 3: Train Loss: 1.3057, Train Accuracy: 63.53%
# Epoch 120/150: Test Loss: 1.9377, Test Accuracy: 51.25%
#     Worker 0: Train Loss: 1.2907, Train Accuracy: 63.21%
#     Worker 1: Train Loss: 1.3020, Train Accuracy: 63.46%
#     Worker 2: Train Loss: 1.2957, Train Accuracy: 63.75%
#     Worker 3: Train Loss: 1.3022, Train Accuracy: 63.31%
# Epoch 121/150: Test Loss: 1.9380, Test Accuracy: 51.11%
#     Worker 0: Train Loss: 1.2975, Train Accuracy: 63.18%
#     Worker 1: Train Loss: 1.2923, Train Accuracy: 63.49%
#     Worker 2: Train Loss: 1.2866, Train Accuracy: 64.09%
#     Worker 3: Train Loss: 1.2879, Train Accuracy: 63.82%
# Epoch 122/150: Test Loss: 1.9386, Test Accuracy: 50.98%
#     Worker 0: Train Loss: 1.2750, Train Accuracy: 63.66%
#     Worker 1: Train Loss: 1.2886, Train Accuracy: 64.29%
#     Worker 2: Train Loss: 1.2920, Train Accuracy: 63.18%
#     Worker 3: Train Loss: 1.3005, Train Accuracy: 63.34%
# Epoch 123/150: Test Loss: 1.9400, Test Accuracy: 51.16%
#     Worker 0: Train Loss: 1.2939, Train Accuracy: 63.56%
#     Worker 1: Train Loss: 1.2852, Train Accuracy: 63.90%
#     Worker 2: Train Loss: 1.2719, Train Accuracy: 64.65%
#     Worker 3: Train Loss: 1.2826, Train Accuracy: 63.94%
# Epoch 124/150: Test Loss: 1.9399, Test Accuracy: 51.25%
#     Worker 0: Train Loss: 1.2910, Train Accuracy: 63.54%
#     Worker 1: Train Loss: 1.2754, Train Accuracy: 64.14%
#     Worker 2: Train Loss: 1.2836, Train Accuracy: 63.90%
#     Worker 3: Train Loss: 1.2938, Train Accuracy: 63.64%
# Epoch 125/150: Test Loss: 1.9444, Test Accuracy: 51.12%
#     Worker 0: Train Loss: 1.2758, Train Accuracy: 63.68%
#     Worker 1: Train Loss: 1.2817, Train Accuracy: 64.02%
#     Worker 2: Train Loss: 1.2629, Train Accuracy: 64.46%
#     Worker 3: Train Loss: 1.2814, Train Accuracy: 64.66%
# Epoch 126/150: Test Loss: 1.9366, Test Accuracy: 51.29%
#     Worker 0: Train Loss: 1.2805, Train Accuracy: 63.84%
#     Worker 1: Train Loss: 1.2868, Train Accuracy: 64.11%
#     Worker 2: Train Loss: 1.2716, Train Accuracy: 64.33%
#     Worker 3: Train Loss: 1.2964, Train Accuracy: 63.34%
# Epoch 127/150: Test Loss: 1.9420, Test Accuracy: 51.22%
#     Worker 0: Train Loss: 1.2795, Train Accuracy: 63.65%
#     Worker 1: Train Loss: 1.2745, Train Accuracy: 64.55%
#     Worker 2: Train Loss: 1.2729, Train Accuracy: 64.38%
#     Worker 3: Train Loss: 1.2763, Train Accuracy: 64.34%
# Epoch 128/150: Test Loss: 1.9396, Test Accuracy: 51.20%
#     Worker 0: Train Loss: 1.2661, Train Accuracy: 64.25%
#     Worker 1: Train Loss: 1.2735, Train Accuracy: 63.76%
#     Worker 2: Train Loss: 1.2754, Train Accuracy: 64.24%
#     Worker 3: Train Loss: 1.2845, Train Accuracy: 63.99%
# Epoch 129/150: Test Loss: 1.9418, Test Accuracy: 51.19%
#     Worker 0: Train Loss: 1.2823, Train Accuracy: 63.98%
#     Worker 1: Train Loss: 1.2717, Train Accuracy: 64.34%
#     Worker 2: Train Loss: 1.2705, Train Accuracy: 64.42%
#     Worker 3: Train Loss: 1.2692, Train Accuracy: 64.30%
# Epoch 130/150: Test Loss: 1.9408, Test Accuracy: 51.23%
#     Worker 0: Train Loss: 1.2632, Train Accuracy: 64.35%
#     Worker 1: Train Loss: 1.2675, Train Accuracy: 64.49%
#     Worker 2: Train Loss: 1.2579, Train Accuracy: 64.86%
#     Worker 3: Train Loss: 1.2632, Train Accuracy: 64.85%
# Epoch 131/150: Test Loss: 1.9381, Test Accuracy: 51.29%
#     Worker 0: Train Loss: 1.2670, Train Accuracy: 64.26%
#     Worker 1: Train Loss: 1.2802, Train Accuracy: 64.26%
#     Worker 2: Train Loss: 1.2493, Train Accuracy: 64.87%
#     Worker 3: Train Loss: 1.2964, Train Accuracy: 63.85%
# Epoch 132/150: Test Loss: 1.9381, Test Accuracy: 51.26%
#     Worker 0: Train Loss: 1.2718, Train Accuracy: 64.42%
#     Worker 1: Train Loss: 1.2774, Train Accuracy: 64.33%
#     Worker 2: Train Loss: 1.2581, Train Accuracy: 64.54%
#     Worker 3: Train Loss: 1.2776, Train Accuracy: 64.23%
# Epoch 133/150: Test Loss: 1.9397, Test Accuracy: 51.19%
#     Worker 0: Train Loss: 1.2678, Train Accuracy: 64.22%
#     Worker 1: Train Loss: 1.2640, Train Accuracy: 64.32%
#     Worker 2: Train Loss: 1.2658, Train Accuracy: 64.53%
#     Worker 3: Train Loss: 1.2673, Train Accuracy: 64.72%
# Epoch 134/150: Test Loss: 1.9369, Test Accuracy: 51.44%
#     Worker 0: Train Loss: 1.2679, Train Accuracy: 64.10%
#     Worker 1: Train Loss: 1.2632, Train Accuracy: 64.14%
#     Worker 2: Train Loss: 1.2494, Train Accuracy: 64.79%
#     Worker 3: Train Loss: 1.2731, Train Accuracy: 64.30%
# Epoch 135/150: Test Loss: 1.9362, Test Accuracy: 51.29%
#     Worker 0: Train Loss: 1.2746, Train Accuracy: 64.29%
#     Worker 1: Train Loss: 1.2630, Train Accuracy: 64.85%
#     Worker 2: Train Loss: 1.2526, Train Accuracy: 65.05%
#     Worker 3: Train Loss: 1.2673, Train Accuracy: 64.52%
# Epoch 136/150: Test Loss: 1.9375, Test Accuracy: 51.37%
#     Worker 0: Train Loss: 1.2556, Train Accuracy: 64.80%
#     Worker 1: Train Loss: 1.2709, Train Accuracy: 64.54%
#     Worker 2: Train Loss: 1.2521, Train Accuracy: 64.95%
#     Worker 3: Train Loss: 1.2591, Train Accuracy: 64.64%
# Epoch 137/150: Test Loss: 1.9358, Test Accuracy: 51.33%
#     Worker 0: Train Loss: 1.2749, Train Accuracy: 63.79%
#     Worker 1: Train Loss: 1.2692, Train Accuracy: 64.43%
#     Worker 2: Train Loss: 1.2429, Train Accuracy: 65.41%
#     Worker 3: Train Loss: 1.2807, Train Accuracy: 63.69%
# Epoch 138/150: Test Loss: 1.9366, Test Accuracy: 51.48%
#     Worker 0: Train Loss: 1.2582, Train Accuracy: 64.27%
#     Worker 1: Train Loss: 1.2626, Train Accuracy: 64.53%
#     Worker 2: Train Loss: 1.2595, Train Accuracy: 64.70%
#     Worker 3: Train Loss: 1.2565, Train Accuracy: 64.81%
# Epoch 139/150: Test Loss: 1.9359, Test Accuracy: 51.33%
#     Worker 0: Train Loss: 1.2605, Train Accuracy: 63.75%
#     Worker 1: Train Loss: 1.2680, Train Accuracy: 64.34%
#     Worker 2: Train Loss: 1.2510, Train Accuracy: 64.60%
#     Worker 3: Train Loss: 1.2711, Train Accuracy: 64.51%
# Epoch 140/150: Test Loss: 1.9365, Test Accuracy: 51.36%
#     Worker 0: Train Loss: 1.2578, Train Accuracy: 64.09%
#     Worker 1: Train Loss: 1.2638, Train Accuracy: 64.70%
#     Worker 2: Train Loss: 1.2583, Train Accuracy: 64.76%
#     Worker 3: Train Loss: 1.2594, Train Accuracy: 64.43%
# Epoch 141/150: Test Loss: 1.9368, Test Accuracy: 51.40%
#     Worker 0: Train Loss: 1.2656, Train Accuracy: 63.99%
#     Worker 1: Train Loss: 1.2546, Train Accuracy: 65.26%
#     Worker 2: Train Loss: 1.2569, Train Accuracy: 64.77%
#     Worker 3: Train Loss: 1.2573, Train Accuracy: 64.89%
# Epoch 142/150: Test Loss: 1.9369, Test Accuracy: 51.37%
#     Worker 0: Train Loss: 1.2602, Train Accuracy: 64.33%
#     Worker 1: Train Loss: 1.2519, Train Accuracy: 64.69%
#     Worker 2: Train Loss: 1.2394, Train Accuracy: 65.66%
#     Worker 3: Train Loss: 1.2591, Train Accuracy: 64.86%
# Epoch 143/150: Test Loss: 1.9367, Test Accuracy: 51.35%
#     Worker 0: Train Loss: 1.2605, Train Accuracy: 64.46%
#     Worker 1: Train Loss: 1.2604, Train Accuracy: 64.44%
#     Worker 2: Train Loss: 1.2471, Train Accuracy: 65.02%
#     Worker 3: Train Loss: 1.2624, Train Accuracy: 64.59%
# Epoch 144/150: Test Loss: 1.9368, Test Accuracy: 51.39%
#     Worker 0: Train Loss: 1.2638, Train Accuracy: 63.90%
#     Worker 1: Train Loss: 1.2563, Train Accuracy: 64.78%
#     Worker 2: Train Loss: 1.2485, Train Accuracy: 65.06%
#     Worker 3: Train Loss: 1.2572, Train Accuracy: 64.62%
# Epoch 145/150: Test Loss: 1.9368, Test Accuracy: 51.38%
#     Worker 0: Train Loss: 1.2635, Train Accuracy: 63.94%
#     Worker 1: Train Loss: 1.2531, Train Accuracy: 64.91%
#     Worker 2: Train Loss: 1.2475, Train Accuracy: 64.86%
#     Worker 3: Train Loss: 1.2482, Train Accuracy: 65.03%
# Epoch 146/150: Test Loss: 1.9368, Test Accuracy: 51.38%
#     Worker 0: Train Loss: 1.2469, Train Accuracy: 65.16%
#     Worker 1: Train Loss: 1.2447, Train Accuracy: 65.10%
#     Worker 2: Train Loss: 1.2424, Train Accuracy: 64.91%
#     Worker 3: Train Loss: 1.2588, Train Accuracy: 64.65%
# Epoch 147/150: Test Loss: 1.9368, Test Accuracy: 51.39%
#     Worker 0: Train Loss: 1.2648, Train Accuracy: 64.20%
#     Worker 1: Train Loss: 1.2584, Train Accuracy: 64.73%
#     Worker 2: Train Loss: 1.2696, Train Accuracy: 64.26%
#     Worker 3: Train Loss: 1.2591, Train Accuracy: 64.91%
# Epoch 148/150: Test Loss: 1.9369, Test Accuracy: 51.37%
#     Worker 0: Train Loss: 1.2607, Train Accuracy: 64.19%
#     Worker 1: Train Loss: 1.2617, Train Accuracy: 64.87%
#     Worker 2: Train Loss: 1.2424, Train Accuracy: 65.23%
#     Worker 3: Train Loss: 1.2715, Train Accuracy: 64.30%
# Epoch 149/150: Test Loss: 1.9368, Test Accuracy: 51.34%
#     Worker 0: Train Loss: 1.2510, Train Accuracy: 64.90%
#     Worker 1: Train Loss: 1.2481, Train Accuracy: 64.96%
#     Worker 2: Train Loss: 1.2464, Train Accuracy: 64.74%
#     Worker 3: Train Loss: 1.2541, Train Accuracy: 64.92%
# Epoch 150/150: Test Loss: 1.9373, Test Accuracy: 51.37%
#     Worker 0: Train Loss: 1.2690, Train Accuracy: 64.02%
#     Worker 1: Train Loss: 1.2545, Train Accuracy: 64.66%
#     Worker 2: Train Loss: 1.2447, Train Accuracy: 65.06%
#     Worker 3: Train Loss: 1.2619, Train Accuracy: 64.78%
