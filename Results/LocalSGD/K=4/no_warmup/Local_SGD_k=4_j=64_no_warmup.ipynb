# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs - warmup_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")

    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch):
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            # Perform J local step before synchronization
            for j in range(J):
                try:
                    # Get a batch from the current worker's shard using next()
                    images, labels = next(shard_iterators[k])
                    images, labels = images.to(device), labels.to(device)  # Move to device
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

                except StopIteration:
                    # If the iterator has exhausted the data, restart the iterator
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k]) # Resume from the next batch
                    images, labels = images.to(device), labels.to(device)
                    # Perform optimization step
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        # Perform model synchronization
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            # Update each worker model with the global parameters
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        # if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
        # else:
        #     warmup_factor = (epoch + 1) / warmup_epochs
        #     lr = warmup_factor * learning_rate
        #     for optimizer in optimizers:
        #         for param_group in optimizer.param_groups:
        #             param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Overwriting localSGD.py

# %%
# %run localSGD.py --k 4 --j 64
# Out:
# Training with K=4, J=64
# Global iteration per epoch: 4
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00400
# Epoch 1/150: Test Loss: 4.5516, Test Accuracy: 3.17%
#     Worker 0: Train Loss: 4.5942, Train Accuracy: 1.48%
#     Worker 1: Train Loss: 4.5938, Train Accuracy: 1.46%
#     Worker 2: Train Loss: 4.5921, Train Accuracy: 1.81%
#     Worker 3: Train Loss: 4.5940, Train Accuracy: 1.60%
# Epoch 2/150: Test Loss: 4.0759, Test Accuracy: 7.35%
#     Worker 0: Train Loss: 4.3459, Train Accuracy: 4.35%
#     Worker 1: Train Loss: 4.3459, Train Accuracy: 4.64%
#     Worker 2: Train Loss: 4.3254, Train Accuracy: 4.56%
#     Worker 3: Train Loss: 4.3468, Train Accuracy: 4.31%
# Epoch 3/150: Test Loss: 3.8872, Test Accuracy: 10.51%
#     Worker 0: Train Loss: 4.0515, Train Accuracy: 7.58%
#     Worker 1: Train Loss: 4.0689, Train Accuracy: 7.43%
#     Worker 2: Train Loss: 4.0289, Train Accuracy: 7.75%
#     Worker 3: Train Loss: 4.0591, Train Accuracy: 7.76%
# Epoch 4/150: Test Loss: 3.7135, Test Accuracy: 13.52%
#     Worker 0: Train Loss: 3.8960, Train Accuracy: 9.97%
#     Worker 1: Train Loss: 3.9089, Train Accuracy: 9.80%
#     Worker 2: Train Loss: 3.8634, Train Accuracy: 10.69%
#     Worker 3: Train Loss: 3.9010, Train Accuracy: 9.99%
# Epoch 5/150: Test Loss: 3.5954, Test Accuracy: 15.67%
#     Worker 0: Train Loss: 3.7836, Train Accuracy: 11.62%
#     Worker 1: Train Loss: 3.7695, Train Accuracy: 11.84%
#     Worker 2: Train Loss: 3.7152, Train Accuracy: 13.33%
#     Worker 3: Train Loss: 3.7816, Train Accuracy: 11.44%
# Epoch 6/150: Test Loss: 3.4795, Test Accuracy: 18.07%
#     Worker 0: Train Loss: 3.6546, Train Accuracy: 13.86%
#     Worker 1: Train Loss: 3.6731, Train Accuracy: 13.94%
#     Worker 2: Train Loss: 3.6283, Train Accuracy: 14.13%
#     Worker 3: Train Loss: 3.6588, Train Accuracy: 14.02%
# Epoch 7/150: Test Loss: 3.3674, Test Accuracy: 19.54%
#     Worker 0: Train Loss: 3.5461, Train Accuracy: 15.14%
#     Worker 0: Train Loss: 1.3243, Train Accuracy: 62.07%
#     Worker 1: Train Loss: 1.3284, Train Accuracy: 62.42%
#     Worker 2: Train Loss: 1.3156, Train Accuracy: 62.96%
#     Worker 3: Train Loss: 1.3167, Train Accuracy: 62.59%
# Epoch 98/150: Test Loss: 1.9395, Test Accuracy: 50.93%
#     Worker 0: Train Loss: 1.3044, Train Accuracy: 62.33%
#     Worker 1: Train Loss: 1.3044, Train Accuracy: 63.21%
#     Worker 2: Train Loss: 1.3040, Train Accuracy: 62.56%
#     Worker 3: Train Loss: 1.3227, Train Accuracy: 62.27%
# Epoch 99/150: Test Loss: 1.9384, Test Accuracy: 51.17%
#     Worker 0: Train Loss: 1.3125, Train Accuracy: 62.45%
#     Worker 1: Train Loss: 1.3010, Train Accuracy: 63.35%
#     Worker 2: Train Loss: 1.2966, Train Accuracy: 62.89%
#     Worker 3: Train Loss: 1.3035, Train Accuracy: 63.42%
# Epoch 100/150: Test Loss: 1.9437, Test Accuracy: 51.44%
#     Worker 0: Train Loss: 1.2864, Train Accuracy: 63.26%
#     Worker 1: Train Loss: 1.2969, Train Accuracy: 63.50%
#     Worker 2: Train Loss: 1.2813, Train Accuracy: 63.81%
#     Worker 3: Train Loss: 1.2843, Train Accuracy: 63.35%
# Epoch 101/150: Test Loss: 1.9495, Test Accuracy: 50.93%
#     Worker 0: Train Loss: 1.2934, Train Accuracy: 62.75%
#     Worker 1: Train Loss: 1.2686, Train Accuracy: 63.96%
#     Worker 2: Train Loss: 1.2522, Train Accuracy: 64.27%
#     Worker 3: Train Loss: 1.2965, Train Accuracy: 63.32%
# Epoch 102/150: Test Loss: 1.9576, Test Accuracy: 51.09%
#     Worker 0: Train Loss: 1.2713, Train Accuracy: 63.83%
#     Worker 1: Train Loss: 1.2740, Train Accuracy: 63.92%
#     Worker 2: Train Loss: 1.2627, Train Accuracy: 64.03%
#     Worker 3: Train Loss: 1.2847, Train Accuracy: 63.57%
# Epoch 103/150: Test Loss: 1.9527, Test Accuracy: 51.14%
#     Worker 0: Train Loss: 1.2707, Train Accuracy: 63.58%
#     Worker 1: Train Loss: 1.2789, Train Accuracy: 64.00%
#     Worker 2: Train Loss: 1.2547, Train Accuracy: 64.12%
#     Worker 3: Train Loss: 1.2660, Train Accuracy: 64.08%
# Epoch 104/150: Test Loss: 1.9526, Test Accuracy: 51.42%
#     Worker 0: Train Loss: 1.2574, Train Accuracy: 64.03%
#     Worker 1: Train Loss: 1.2517, Train Accuracy: 64.47%
#     Worker 2: Train Loss: 1.2520, Train Accuracy: 64.71%
#     Worker 3: Train Loss: 1.2672, Train Accuracy: 63.86%
# Epoch 105/150: Test Loss: 1.9559, Test Accuracy: 51.37%
#     Worker 0: Train Loss: 1.2546, Train Accuracy: 63.87%
#     Worker 1: Train Loss: 1.2506, Train Accuracy: 64.45%
#     Worker 2: Train Loss: 1.2565, Train Accuracy: 64.10%
#     Worker 3: Train Loss: 1.2554, Train Accuracy: 64.20%
# Epoch 106/150: Test Loss: 1.9562, Test Accuracy: 51.22%
#     Worker 0: Train Loss: 1.2310, Train Accuracy: 64.52%
#     Worker 1: Train Loss: 1.2398, Train Accuracy: 65.02%
#     Worker 2: Train Loss: 1.2163, Train Accuracy: 65.26%
#     Worker 3: Train Loss: 1.2474, Train Accuracy: 64.52%
# Epoch 107/150: Test Loss: 1.9598, Test Accuracy: 51.35%
#     Worker 0: Train Loss: 1.2431, Train Accuracy: 64.34%
#     Worker 1: Train Loss: 1.2387, Train Accuracy: 64.50%
#     Worker 2: Train Loss: 1.2218, Train Accuracy: 65.06%
#     Worker 3: Train Loss: 1.2379, Train Accuracy: 64.69%
# Epoch 108/150: Test Loss: 1.9655, Test Accuracy: 51.21%
#     Worker 0: Train Loss: 1.2326, Train Accuracy: 64.84%
#     Worker 1: Train Loss: 1.2330, Train Accuracy: 64.70%
#     Worker 2: Train Loss: 1.2175, Train Accuracy: 65.26%
#     Worker 3: Train Loss: 1.2247, Train Accuracy: 65.03%
# Epoch 109/150: Test Loss: 1.9650, Test Accuracy: 50.97%
#     Worker 0: Train Loss: 1.2234, Train Accuracy: 64.71%
#     Worker 1: Train Loss: 1.2228, Train Accuracy: 64.95%
#     Worker 2: Train Loss: 1.2005, Train Accuracy: 66.06%
#     Worker 3: Train Loss: 1.2282, Train Accuracy: 65.29%
# Epoch 110/150: Test Loss: 1.9693, Test Accuracy: 51.01%
#     Worker 0: Train Loss: 1.2173, Train Accuracy: 64.69%
#     Worker 1: Train Loss: 1.2065, Train Accuracy: 65.79%
#     Worker 2: Train Loss: 1.2009, Train Accuracy: 66.02%
#     Worker 3: Train Loss: 1.2167, Train Accuracy: 65.26%
# Epoch 111/150: Test Loss: 1.9619, Test Accuracy: 51.34%
#     Worker 0: Train Loss: 1.2064, Train Accuracy: 65.15%
#     Worker 1: Train Loss: 1.2175, Train Accuracy: 65.50%
#     Worker 2: Train Loss: 1.2158, Train Accuracy: 65.79%
#     Worker 3: Train Loss: 1.2225, Train Accuracy: 65.30%
# Epoch 112/150: Test Loss: 1.9616, Test Accuracy: 51.18%
#     Worker 0: Train Loss: 1.2090, Train Accuracy: 65.00%
#     Worker 1: Train Loss: 1.2064, Train Accuracy: 65.79%
#     Worker 2: Train Loss: 1.1771, Train Accuracy: 66.55%
#     Worker 3: Train Loss: 1.2090, Train Accuracy: 65.59%
# Epoch 113/150: Test Loss: 1.9632, Test Accuracy: 51.24%
#     Worker 0: Train Loss: 1.1961, Train Accuracy: 65.31%
#     Worker 1: Train Loss: 1.1798, Train Accuracy: 66.50%
#     Worker 2: Train Loss: 1.1984, Train Accuracy: 66.18%
#     Worker 3: Train Loss: 1.1871, Train Accuracy: 66.76%
# Epoch 114/150: Test Loss: 1.9633, Test Accuracy: 50.95%
#     Worker 0: Train Loss: 1.2036, Train Accuracy: 65.14%
#     Worker 1: Train Loss: 1.2012, Train Accuracy: 65.52%
#     Worker 2: Train Loss: 1.1696, Train Accuracy: 66.40%
#     Worker 3: Train Loss: 1.1901, Train Accuracy: 66.24%
# Epoch 115/150: Test Loss: 1.9744, Test Accuracy: 51.22%
#     Worker 0: Train Loss: 1.1863, Train Accuracy: 65.75%
#     Worker 1: Train Loss: 1.1759, Train Accuracy: 66.64%
#     Worker 2: Train Loss: 1.1915, Train Accuracy: 65.91%
#     Worker 3: Train Loss: 1.1837, Train Accuracy: 66.08%
# Epoch 116/150: Test Loss: 1.9721, Test Accuracy: 51.35%
#     Worker 0: Train Loss: 1.1752, Train Accuracy: 66.23%
#     Worker 1: Train Loss: 1.1714, Train Accuracy: 66.21%
#     Worker 2: Train Loss: 1.1633, Train Accuracy: 67.13%
#     Worker 3: Train Loss: 1.1911, Train Accuracy: 66.16%
# Epoch 117/150: Test Loss: 1.9641, Test Accuracy: 51.36%
#     Worker 0: Train Loss: 1.1848, Train Accuracy: 65.73%
#     Worker 1: Train Loss: 1.1763, Train Accuracy: 66.65%
#     Worker 2: Train Loss: 1.1704, Train Accuracy: 66.75%
#     Worker 3: Train Loss: 1.1869, Train Accuracy: 66.26%
# Epoch 118/150: Test Loss: 1.9676, Test Accuracy: 51.36%
#     Worker 0: Train Loss: 1.1695, Train Accuracy: 66.48%
#     Worker 1: Train Loss: 1.1685, Train Accuracy: 66.58%
#     Worker 2: Train Loss: 1.1619, Train Accuracy: 66.98%
#     Worker 3: Train Loss: 1.1757, Train Accuracy: 66.34%
# Epoch 119/150: Test Loss: 1.9714, Test Accuracy: 51.07%
#     Worker 0: Train Loss: 1.1626, Train Accuracy: 66.58%
#     Worker 1: Train Loss: 1.1756, Train Accuracy: 66.83%
#     Worker 2: Train Loss: 1.1330, Train Accuracy: 67.72%
#     Worker 3: Train Loss: 1.1548, Train Accuracy: 67.47%
# Epoch 120/150: Test Loss: 1.9709, Test Accuracy: 51.28%
#     Worker 0: Train Loss: 1.1617, Train Accuracy: 66.51%
#     Worker 1: Train Loss: 1.1661, Train Accuracy: 66.79%
#     Worker 2: Train Loss: 1.1715, Train Accuracy: 66.40%
#     Worker 3: Train Loss: 1.1630, Train Accuracy: 66.76%
# Epoch 121/150: Test Loss: 1.9728, Test Accuracy: 51.42%
#     Worker 0: Train Loss: 1.1588, Train Accuracy: 66.87%
#     Worker 1: Train Loss: 1.1633, Train Accuracy: 66.99%
#     Worker 2: Train Loss: 1.1334, Train Accuracy: 67.54%
#     Worker 3: Train Loss: 1.1619, Train Accuracy: 66.99%
# Epoch 122/150: Test Loss: 1.9727, Test Accuracy: 51.17%
#     Worker 0: Train Loss: 1.1605, Train Accuracy: 66.28%
#     Worker 1: Train Loss: 1.1621, Train Accuracy: 66.82%
#     Worker 2: Train Loss: 1.1509, Train Accuracy: 67.14%
#     Worker 3: Train Loss: 1.1496, Train Accuracy: 67.14%
# Epoch 123/150: Test Loss: 1.9743, Test Accuracy: 51.24%
#     Worker 0: Train Loss: 1.1514, Train Accuracy: 66.82%
#     Worker 1: Train Loss: 1.1379, Train Accuracy: 67.82%
#     Worker 2: Train Loss: 1.1408, Train Accuracy: 67.33%
#     Worker 3: Train Loss: 1.1568, Train Accuracy: 67.28%
# Epoch 124/150: Test Loss: 1.9758, Test Accuracy: 51.40%
#     Worker 0: Train Loss: 1.1418, Train Accuracy: 66.94%
#     Worker 1: Train Loss: 1.1583, Train Accuracy: 67.16%
#     Worker 2: Train Loss: 1.1403, Train Accuracy: 67.55%
#     Worker 3: Train Loss: 1.1561, Train Accuracy: 66.97%
# Epoch 125/150: Test Loss: 1.9772, Test Accuracy: 51.24%
#     Worker 0: Train Loss: 1.1264, Train Accuracy: 67.22%
#     Worker 1: Train Loss: 1.1521, Train Accuracy: 67.00%
#     Worker 2: Train Loss: 1.1283, Train Accuracy: 68.26%
#     Worker 3: Train Loss: 1.1438, Train Accuracy: 67.41%
# Epoch 126/150: Test Loss: 1.9766, Test Accuracy: 51.20%
#     Worker 0: Train Loss: 1.1474, Train Accuracy: 66.56%
#     Worker 1: Train Loss: 1.1362, Train Accuracy: 67.68%
#     Worker 2: Train Loss: 1.1235, Train Accuracy: 67.59%
#     Worker 3: Train Loss: 1.1390, Train Accuracy: 67.61%
# Epoch 127/150: Test Loss: 1.9785, Test Accuracy: 51.22%
#     Worker 0: Train Loss: 1.1322, Train Accuracy: 67.32%
#     Worker 1: Train Loss: 1.1483, Train Accuracy: 67.15%
#     Worker 2: Train Loss: 1.1198, Train Accuracy: 67.88%
#     Worker 3: Train Loss: 1.1372, Train Accuracy: 67.25%
# Epoch 128/150: Test Loss: 1.9781, Test Accuracy: 51.29%
#     Worker 0: Train Loss: 1.1328, Train Accuracy: 67.00%
#     Worker 1: Train Loss: 1.1296, Train Accuracy: 67.96%
#     Worker 2: Train Loss: 1.1198, Train Accuracy: 68.16%
#     Worker 3: Train Loss: 1.1249, Train Accuracy: 67.51%
# Epoch 129/150: Test Loss: 1.9768, Test Accuracy: 51.30%
#     Worker 0: Train Loss: 1.1262, Train Accuracy: 67.72%
#     Worker 1: Train Loss: 1.1306, Train Accuracy: 68.05%
#     Worker 2: Train Loss: 1.1192, Train Accuracy: 68.16%
#     Worker 3: Train Loss: 1.1489, Train Accuracy: 67.41%
# Epoch 130/150: Test Loss: 1.9783, Test Accuracy: 51.52%
#     Worker 0: Train Loss: 1.1242, Train Accuracy: 67.82%
#     Worker 1: Train Loss: 1.1240, Train Accuracy: 68.01%
#     Worker 2: Train Loss: 1.1183, Train Accuracy: 68.13%
#     Worker 3: Train Loss: 1.1210, Train Accuracy: 68.29%
# Epoch 131/150: Test Loss: 1.9791, Test Accuracy: 51.26%
#     Worker 0: Train Loss: 1.1274, Train Accuracy: 67.43%
#     Worker 1: Train Loss: 1.1398, Train Accuracy: 67.73%
#     Worker 2: Train Loss: 1.1187, Train Accuracy: 68.32%
#     Worker 3: Train Loss: 1.1375, Train Accuracy: 67.99%
# Epoch 132/150: Test Loss: 1.9811, Test Accuracy: 51.31%
#     Worker 0: Train Loss: 1.1232, Train Accuracy: 67.86%
#     Worker 1: Train Loss: 1.1214, Train Accuracy: 67.99%
#     Worker 2: Train Loss: 1.1184, Train Accuracy: 68.04%
#     Worker 3: Train Loss: 1.1163, Train Accuracy: 68.41%
# Epoch 133/150: Test Loss: 1.9806, Test Accuracy: 51.39%
#     Worker 0: Train Loss: 1.1145, Train Accuracy: 68.07%
#     Worker 1: Train Loss: 1.1176, Train Accuracy: 68.52%
#     Worker 2: Train Loss: 1.1107, Train Accuracy: 68.40%
#     Worker 3: Train Loss: 1.1268, Train Accuracy: 68.23%
# Epoch 134/150: Test Loss: 1.9798, Test Accuracy: 51.38%
#     Worker 0: Train Loss: 1.1256, Train Accuracy: 67.83%
#     Worker 1: Train Loss: 1.1277, Train Accuracy: 67.80%
#     Worker 2: Train Loss: 1.1118, Train Accuracy: 68.33%
#     Worker 3: Train Loss: 1.1118, Train Accuracy: 68.32%
# Epoch 135/150: Test Loss: 1.9823, Test Accuracy: 51.48%
#     Worker 0: Train Loss: 1.1187, Train Accuracy: 67.54%
#     Worker 1: Train Loss: 1.1152, Train Accuracy: 68.26%
#     Worker 2: Train Loss: 1.1209, Train Accuracy: 68.17%
#     Worker 3: Train Loss: 1.1125, Train Accuracy: 68.25%
# Epoch 136/150: Test Loss: 1.9809, Test Accuracy: 51.34%
#     Worker 0: Train Loss: 1.0983, Train Accuracy: 68.00%
#     Worker 1: Train Loss: 1.1261, Train Accuracy: 68.21%
#     Worker 2: Train Loss: 1.1074, Train Accuracy: 68.60%
#     Worker 3: Train Loss: 1.1391, Train Accuracy: 67.37%
# Epoch 137/150: Test Loss: 1.9803, Test Accuracy: 51.35%
#     Worker 0: Train Loss: 1.1227, Train Accuracy: 67.78%
#     Worker 1: Train Loss: 1.1219, Train Accuracy: 68.37%
#     Worker 2: Train Loss: 1.1026, Train Accuracy: 68.88%
#     Worker 3: Train Loss: 1.1025, Train Accuracy: 68.73%
# Epoch 138/150: Test Loss: 1.9808, Test Accuracy: 51.37%
#     Worker 0: Train Loss: 1.1072, Train Accuracy: 68.08%
#     Worker 1: Train Loss: 1.1182, Train Accuracy: 67.78%
#     Worker 2: Train Loss: 1.1185, Train Accuracy: 68.30%
#     Worker 3: Train Loss: 1.1300, Train Accuracy: 68.05%
# Epoch 139/150: Test Loss: 1.9813, Test Accuracy: 51.43%
#     Worker 0: Train Loss: 1.1155, Train Accuracy: 68.36%
#     Worker 1: Train Loss: 1.1153, Train Accuracy: 68.10%
#     Worker 2: Train Loss: 1.0940, Train Accuracy: 68.89%
#     Worker 3: Train Loss: 1.1106, Train Accuracy: 68.78%
# Epoch 140/150: Test Loss: 1.9815, Test Accuracy: 51.44%
#     Worker 0: Train Loss: 1.1202, Train Accuracy: 68.13%
#     Worker 1: Train Loss: 1.1213, Train Accuracy: 68.37%
#     Worker 2: Train Loss: 1.1009, Train Accuracy: 68.54%
#     Worker 3: Train Loss: 1.1182, Train Accuracy: 68.29%
# Epoch 141/150: Test Loss: 1.9813, Test Accuracy: 51.38%
#     Worker 0: Train Loss: 1.1021, Train Accuracy: 68.17%
#     Worker 1: Train Loss: 1.1143, Train Accuracy: 68.11%
#     Worker 2: Train Loss: 1.1078, Train Accuracy: 68.68%
#     Worker 3: Train Loss: 1.1269, Train Accuracy: 68.13%
# Epoch 142/150: Test Loss: 1.9816, Test Accuracy: 51.30%
#     Worker 0: Train Loss: 1.1143, Train Accuracy: 67.86%
#     Worker 1: Train Loss: 1.1097, Train Accuracy: 68.12%
#     Worker 2: Train Loss: 1.1065, Train Accuracy: 68.54%
#     Worker 3: Train Loss: 1.1004, Train Accuracy: 68.71%
# Epoch 143/150: Test Loss: 1.9816, Test Accuracy: 51.32%
#     Worker 0: Train Loss: 1.1115, Train Accuracy: 68.15%
#     Worker 1: Train Loss: 1.1203, Train Accuracy: 68.31%
#     Worker 2: Train Loss: 1.1140, Train Accuracy: 68.56%
#     Worker 3: Train Loss: 1.1099, Train Accuracy: 68.65%
# Epoch 144/150: Test Loss: 1.9816, Test Accuracy: 51.35%
#     Worker 0: Train Loss: 1.1084, Train Accuracy: 68.00%
#     Worker 1: Train Loss: 1.1148, Train Accuracy: 68.28%
#     Worker 2: Train Loss: 1.1043, Train Accuracy: 68.66%
#     Worker 3: Train Loss: 1.1186, Train Accuracy: 68.28%
# Epoch 145/150: Test Loss: 1.9816, Test Accuracy: 51.36%
#     Worker 0: Train Loss: 1.1135, Train Accuracy: 67.77%
#     Worker 1: Train Loss: 1.1091, Train Accuracy: 68.62%
#     Worker 2: Train Loss: 1.1002, Train Accuracy: 68.84%
#     Worker 3: Train Loss: 1.1079, Train Accuracy: 68.20%
# Epoch 146/150: Test Loss: 1.9816, Test Accuracy: 51.36%
#     Worker 0: Train Loss: 1.1184, Train Accuracy: 68.01%
#     Worker 1: Train Loss: 1.1223, Train Accuracy: 67.94%
#     Worker 2: Train Loss: 1.1093, Train Accuracy: 68.57%
#     Worker 3: Train Loss: 1.1290, Train Accuracy: 67.71%
# Epoch 147/150: Test Loss: 1.9817, Test Accuracy: 51.36%
#     Worker 0: Train Loss: 1.1099, Train Accuracy: 67.91%
#     Worker 1: Train Loss: 1.1042, Train Accuracy: 68.41%
#     Worker 2: Train Loss: 1.1051, Train Accuracy: 68.64%
#     Worker 3: Train Loss: 1.1119, Train Accuracy: 68.58%
# Epoch 148/150: Test Loss: 1.9817, Test Accuracy: 51.33%
#     Worker 0: Train Loss: 1.1217, Train Accuracy: 67.63%
#     Worker 1: Train Loss: 1.1188, Train Accuracy: 68.19%
#     Worker 2: Train Loss: 1.0982, Train Accuracy: 68.87%
#     Worker 3: Train Loss: 1.1129, Train Accuracy: 68.56%
# Epoch 149/150: Test Loss: 1.9818, Test Accuracy: 51.36%
#     Worker 0: Train Loss: 1.1139, Train Accuracy: 67.95%
#     Worker 1: Train Loss: 1.1004, Train Accuracy: 68.76%
#     Worker 2: Train Loss: 1.0970, Train Accuracy: 68.94%
#     Worker 3: Train Loss: 1.1242, Train Accuracy: 68.37%
# Epoch 150/150: Test Loss: 1.9820, Test Accuracy: 51.41%
#     Worker 0: Train Loss: 1.0943, Train Accuracy: 68.68%
#     Worker 1: Train Loss: 1.1178, Train Accuracy: 67.93%
#     Worker 2: Train Loss: 1.1060, Train Accuracy: 68.44%
#     Worker 3: Train Loss: 1.1211, Train Accuracy: 68.44%
