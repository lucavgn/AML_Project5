# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs - warmup_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")

    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch):
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            # Perform J local step before synchronization
            for j in range(J):
                try:
                    # Get a batch from the current worker's shard using next()
                    images, labels = next(shard_iterators[k])
                    images, labels = images.to(device), labels.to(device)  # Move to device
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

                except StopIteration:
                    # If the iterator has exhausted the data, restart the iterator
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k]) # Resume from the next batch
                    images, labels = images.to(device), labels.to(device)
                    # Perform optimization step
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        # Perform model synchronization
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            # Update each worker model with the global parameters
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        # if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
        # else:
        #     warmup_factor = (epoch + 1) / warmup_epochs
        #     lr = warmup_factor * learning_rate
        #     for optimizer in optimizers:
        #         for param_group in optimizer.param_groups:
        #             param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Overwriting localSGD.py

# %%
# %run localSGD.py --k 4 --j 16
# Out:
# Training with K=4, J=16
# Global iteration per epoch: 13
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00400
# Epoch 1/150: Test Loss: 4.5778, Test Accuracy: 2.89%
#     Worker 0: Train Loss: 4.5981, Train Accuracy: 1.47%
#     Worker 1: Train Loss: 4.5984, Train Accuracy: 1.40%
#     Worker 2: Train Loss: 4.5976, Train Accuracy: 1.47%
#     Worker 3: Train Loss: 4.5987, Train Accuracy: 1.26%
# Epoch 2/150: Test Loss: 4.1756, Test Accuracy: 6.58%
#     Worker 0: Train Loss: 4.4425, Train Accuracy: 3.46%
#     Worker 1: Train Loss: 4.4444, Train Accuracy: 3.64%
#     Worker 2: Train Loss: 4.4301, Train Accuracy: 3.80%
#     Worker 3: Train Loss: 4.4433, Train Accuracy: 3.87%
# Epoch 3/150: Test Loss: 3.9675, Test Accuracy: 9.24%
#     Worker 0: Train Loss: 4.1137, Train Accuracy: 6.87%
#     Worker 1: Train Loss: 4.1248, Train Accuracy: 6.73%
#     Worker 2: Train Loss: 4.0957, Train Accuracy: 6.96%
#     Worker 3: Train Loss: 4.1225, Train Accuracy: 6.56%
# Epoch 4/150: Test Loss: 3.8255, Test Accuracy: 11.71%
#     Worker 0: Train Loss: 3.9620, Train Accuracy: 9.24%
#     Worker 1: Train Loss: 3.9702, Train Accuracy: 9.07%
#     Worker 2: Train Loss: 3.9151, Train Accuracy: 9.90%
#     Worker 3: Train Loss: 3.9540, Train Accuracy: 8.95%
# Epoch 5/150: Test Loss: 3.6691, Test Accuracy: 14.70%
#     Worker 0: Train Loss: 3.8283, Train Accuracy: 11.27%
#     Worker 1: Train Loss: 3.8434, Train Accuracy: 11.15%
#     Worker 2: Train Loss: 3.7979, Train Accuracy: 11.63%
#     Worker 3: Train Loss: 3.8377, Train Accuracy: 11.07%
# Epoch 6/150: Test Loss: 3.5793, Test Accuracy: 16.11%
#     Worker 0: Train Loss: 3.7241, Train Accuracy: 12.87%
#     Worker 1: Train Loss: 3.7201, Train Accuracy: 13.01%
#     Worker 2: Train Loss: 3.6813, Train Accuracy: 13.59%
#     Worker 3: Train Loss: 3.7206, Train Accuracy: 12.99%
# Epoch 7/150: Test Loss: 3.4679, Test Accuracy: 18.06%
#     Worker 0: Train Loss: 3.6404, Train Accuracy: 14.17%
#     Worker 0: Train Loss: 1.4174, Train Accuracy: 60.69%
#     Worker 1: Train Loss: 1.4228, Train Accuracy: 60.20%
#     Worker 2: Train Loss: 1.4286, Train Accuracy: 59.90%
#     Worker 3: Train Loss: 1.4129, Train Accuracy: 60.58%
# Epoch 98/150: Test Loss: 1.9480, Test Accuracy: 50.52%
#     Worker 0: Train Loss: 1.4204, Train Accuracy: 59.79%
#     Worker 1: Train Loss: 1.4190, Train Accuracy: 60.60%
#     Worker 2: Train Loss: 1.3948, Train Accuracy: 60.67%
#     Worker 3: Train Loss: 1.4381, Train Accuracy: 59.85%
# Epoch 99/150: Test Loss: 1.9584, Test Accuracy: 50.81%
#     Worker 0: Train Loss: 1.4161, Train Accuracy: 60.60%
#     Worker 1: Train Loss: 1.4016, Train Accuracy: 60.75%
#     Worker 2: Train Loss: 1.3975, Train Accuracy: 60.79%
#     Worker 3: Train Loss: 1.4136, Train Accuracy: 60.89%
# Epoch 100/150: Test Loss: 1.9508, Test Accuracy: 50.83%
#     Worker 0: Train Loss: 1.3883, Train Accuracy: 60.49%
#     Worker 1: Train Loss: 1.4018, Train Accuracy: 60.28%
#     Worker 2: Train Loss: 1.3887, Train Accuracy: 61.10%
#     Worker 3: Train Loss: 1.4096, Train Accuracy: 60.38%
# Epoch 101/150: Test Loss: 1.9505, Test Accuracy: 50.75%
#     Worker 0: Train Loss: 1.3996, Train Accuracy: 60.75%
#     Worker 1: Train Loss: 1.4079, Train Accuracy: 60.82%
#     Worker 2: Train Loss: 1.3810, Train Accuracy: 61.09%
#     Worker 3: Train Loss: 1.3962, Train Accuracy: 60.88%
# Epoch 102/150: Test Loss: 1.9518, Test Accuracy: 50.49%
#     Worker 0: Train Loss: 1.3806, Train Accuracy: 60.78%
#     Worker 1: Train Loss: 1.3812, Train Accuracy: 61.24%
#     Worker 2: Train Loss: 1.3797, Train Accuracy: 61.18%
#     Worker 3: Train Loss: 1.3982, Train Accuracy: 60.91%
# Epoch 103/150: Test Loss: 1.9412, Test Accuracy: 50.57%
#     Worker 0: Train Loss: 1.3863, Train Accuracy: 60.91%
#     Worker 1: Train Loss: 1.3590, Train Accuracy: 61.68%
#     Worker 2: Train Loss: 1.3637, Train Accuracy: 61.25%
#     Worker 3: Train Loss: 1.3840, Train Accuracy: 61.46%
# Epoch 104/150: Test Loss: 1.9496, Test Accuracy: 50.81%
#     Worker 0: Train Loss: 1.3541, Train Accuracy: 61.63%
#     Worker 1: Train Loss: 1.3729, Train Accuracy: 61.54%
#     Worker 2: Train Loss: 1.3648, Train Accuracy: 61.77%
#     Worker 3: Train Loss: 1.3774, Train Accuracy: 61.37%
# Epoch 105/150: Test Loss: 1.9491, Test Accuracy: 50.81%
#     Worker 0: Train Loss: 1.3677, Train Accuracy: 61.45%
#     Worker 1: Train Loss: 1.3534, Train Accuracy: 62.10%
#     Worker 2: Train Loss: 1.3654, Train Accuracy: 61.62%
#     Worker 3: Train Loss: 1.3816, Train Accuracy: 61.46%
# Epoch 106/150: Test Loss: 1.9448, Test Accuracy: 50.98%
#     Worker 0: Train Loss: 1.2960, Train Accuracy: 63.54%
#     Worker 1: Train Loss: 1.2906, Train Accuracy: 63.69%
#     Worker 2: Train Loss: 1.2825, Train Accuracy: 63.71%
#     Worker 3: Train Loss: 1.3133, Train Accuracy: 63.33%
# Epoch 116/150: Test Loss: 1.9554, Test Accuracy: 51.15%
#     Worker 0: Train Loss: 1.2954, Train Accuracy: 63.63%
#     Worker 1: Train Loss: 1.3003, Train Accuracy: 63.85%
#     Worker 2: Train Loss: 1.2978, Train Accuracy: 63.39%
#     Worker 3: Train Loss: 1.2975, Train Accuracy: 63.91%
# Epoch 117/150: Test Loss: 1.9547, Test Accuracy: 51.01%
#     Worker 0: Train Loss: 1.2852, Train Accuracy: 63.90%
#     Worker 1: Train Loss: 1.2835, Train Accuracy: 63.87%
#     Worker 2: Train Loss: 1.2751, Train Accuracy: 64.25%
#     Worker 3: Train Loss: 1.3080, Train Accuracy: 63.16%
# Epoch 118/150: Test Loss: 1.9535, Test Accuracy: 51.06%
#     Worker 0: Train Loss: 1.2968, Train Accuracy: 62.81%
#     Worker 1: Train Loss: 1.2967, Train Accuracy: 62.94%
#     Worker 2: Train Loss: 1.2689, Train Accuracy: 64.10%
#     Worker 3: Train Loss: 1.2985, Train Accuracy: 63.75%
# Epoch 119/150: Test Loss: 1.9551, Test Accuracy: 51.25%
#     Worker 0: Train Loss: 1.2858, Train Accuracy: 63.54%
#     Worker 1: Train Loss: 1.2843, Train Accuracy: 63.90%
#     Worker 2: Train Loss: 1.2686, Train Accuracy: 63.91%
#     Worker 3: Train Loss: 1.2913, Train Accuracy: 63.63%
# Epoch 120/150: Test Loss: 1.9549, Test Accuracy: 51.08%
#     Worker 0: Train Loss: 1.2787, Train Accuracy: 63.60%
#     Worker 1: Train Loss: 1.2748, Train Accuracy: 64.03%
#     Worker 2: Train Loss: 1.2730, Train Accuracy: 64.12%
#     Worker 3: Train Loss: 1.2989, Train Accuracy: 64.00%
# Epoch 121/150: Test Loss: 1.9572, Test Accuracy: 51.12%
#     Worker 0: Train Loss: 1.2720, Train Accuracy: 63.75%
#     Worker 1: Train Loss: 1.2759, Train Accuracy: 64.30%
#     Worker 2: Train Loss: 1.2488, Train Accuracy: 64.37%
#     Worker 3: Train Loss: 1.2741, Train Accuracy: 63.87%
# Epoch 122/150: Test Loss: 1.9552, Test Accuracy: 51.20%
#     Worker 0: Train Loss: 1.2660, Train Accuracy: 64.22%
#     Worker 1: Train Loss: 1.2760, Train Accuracy: 64.21%
#     Worker 2: Train Loss: 1.2752, Train Accuracy: 64.38%
#     Worker 3: Train Loss: 1.2689, Train Accuracy: 64.24%
# Epoch 123/150: Test Loss: 1.9572, Test Accuracy: 51.25%
#     Worker 0: Train Loss: 1.2702, Train Accuracy: 64.15%
#     Worker 1: Train Loss: 1.2513, Train Accuracy: 64.88%
#     Worker 2: Train Loss: 1.2583, Train Accuracy: 64.56%
#     Worker 3: Train Loss: 1.2788, Train Accuracy: 64.18%
# Epoch 124/150: Test Loss: 1.9560, Test Accuracy: 51.25%
#     Worker 0: Train Loss: 1.2584, Train Accuracy: 64.86%
#     Worker 1: Train Loss: 1.2779, Train Accuracy: 63.72%
#     Worker 2: Train Loss: 1.2575, Train Accuracy: 64.83%
#     Worker 3: Train Loss: 1.2943, Train Accuracy: 64.38%
# Epoch 125/150: Test Loss: 1.9563, Test Accuracy: 51.35%
#     Worker 0: Train Loss: 1.2427, Train Accuracy: 64.08%
#     Worker 1: Train Loss: 1.2679, Train Accuracy: 64.40%
#     Worker 2: Train Loss: 1.2479, Train Accuracy: 64.86%
#     Worker 3: Train Loss: 1.2577, Train Accuracy: 64.83%
# Epoch 126/150: Test Loss: 1.9530, Test Accuracy: 51.33%
#     Worker 0: Train Loss: 1.2765, Train Accuracy: 63.97%
#     Worker 1: Train Loss: 1.2569, Train Accuracy: 64.32%
#     Worker 2: Train Loss: 1.2463, Train Accuracy: 65.10%
#     Worker 3: Train Loss: 1.2787, Train Accuracy: 64.40%
# Epoch 127/150: Test Loss: 1.9534, Test Accuracy: 51.23%
#     Worker 0: Train Loss: 1.2481, Train Accuracy: 64.26%
#     Worker 1: Train Loss: 1.2638, Train Accuracy: 64.60%
#     Worker 2: Train Loss: 1.2379, Train Accuracy: 65.41%
#     Worker 3: Train Loss: 1.2552, Train Accuracy: 64.75%
# Epoch 128/150: Test Loss: 1.9558, Test Accuracy: 51.28%
#     Worker 0: Train Loss: 1.2566, Train Accuracy: 64.46%
#     Worker 1: Train Loss: 1.2350, Train Accuracy: 64.88%
#     Worker 2: Train Loss: 1.2400, Train Accuracy: 65.24%
#     Worker 3: Train Loss: 1.2730, Train Accuracy: 64.52%
# Epoch 129/150: Test Loss: 1.9541, Test Accuracy: 51.40%
#     Worker 0: Train Loss: 1.2527, Train Accuracy: 64.26%
#     Worker 1: Train Loss: 1.2599, Train Accuracy: 64.40%
#     Worker 2: Train Loss: 1.2442, Train Accuracy: 65.19%
#     Worker 3: Train Loss: 1.2734, Train Accuracy: 64.27%
# Epoch 130/150: Test Loss: 1.9534, Test Accuracy: 51.35%
#     Worker 0: Train Loss: 1.2461, Train Accuracy: 64.70%
#     Worker 1: Train Loss: 1.2459, Train Accuracy: 64.83%
#     Worker 2: Train Loss: 1.2475, Train Accuracy: 64.92%
#     Worker 3: Train Loss: 1.2579, Train Accuracy: 64.26%
# Epoch 131/150: Test Loss: 1.9535, Test Accuracy: 51.43%
#     Worker 0: Train Loss: 1.2467, Train Accuracy: 64.56%
#     Worker 1: Train Loss: 1.2434, Train Accuracy: 65.32%
#     Worker 2: Train Loss: 1.2379, Train Accuracy: 65.15%
#     Worker 3: Train Loss: 1.2529, Train Accuracy: 65.23%
# Epoch 132/150: Test Loss: 1.9545, Test Accuracy: 51.30%
#     Worker 0: Train Loss: 1.2453, Train Accuracy: 65.04%
#     Worker 1: Train Loss: 1.2426, Train Accuracy: 64.67%
#     Worker 2: Train Loss: 1.2379, Train Accuracy: 64.92%
#     Worker 3: Train Loss: 1.2562, Train Accuracy: 64.92%
# Epoch 133/150: Test Loss: 1.9518, Test Accuracy: 51.27%
#     Worker 0: Train Loss: 1.2524, Train Accuracy: 64.38%
#     Worker 1: Train Loss: 1.2469, Train Accuracy: 65.10%
#     Worker 2: Train Loss: 1.2379, Train Accuracy: 65.13%
#     Worker 3: Train Loss: 1.2587, Train Accuracy: 64.46%
# Epoch 134/150: Test Loss: 1.9536, Test Accuracy: 51.46%
#     Worker 0: Train Loss: 1.2417, Train Accuracy: 64.84%
#     Worker 1: Train Loss: 1.2402, Train Accuracy: 65.28%
#     Worker 2: Train Loss: 1.2459, Train Accuracy: 65.01%
#     Worker 3: Train Loss: 1.2769, Train Accuracy: 64.43%
# Epoch 135/150: Test Loss: 1.9548, Test Accuracy: 51.45%
#     Worker 0: Train Loss: 1.2366, Train Accuracy: 65.07%
#     Worker 1: Train Loss: 1.2352, Train Accuracy: 65.50%
#     Worker 2: Train Loss: 1.2200, Train Accuracy: 65.28%
#     Worker 3: Train Loss: 1.2572, Train Accuracy: 64.70%
# Epoch 136/150: Test Loss: 1.9553, Test Accuracy: 51.53%
#     Worker 0: Train Loss: 1.2416, Train Accuracy: 65.08%
#     Worker 1: Train Loss: 1.2353, Train Accuracy: 65.33%
#     Worker 2: Train Loss: 1.2563, Train Accuracy: 64.61%
#     Worker 3: Train Loss: 1.2283, Train Accuracy: 65.77%
# Epoch 137/150: Test Loss: 1.9538, Test Accuracy: 51.52%
#     Worker 0: Train Loss: 1.2181, Train Accuracy: 65.94%
#     Worker 1: Train Loss: 1.2217, Train Accuracy: 64.87%
#     Worker 2: Train Loss: 1.2407, Train Accuracy: 64.93%
#     Worker 3: Train Loss: 1.2592, Train Accuracy: 64.96%
# Epoch 138/150: Test Loss: 1.9535, Test Accuracy: 51.45%
#     Worker 0: Train Loss: 1.2564, Train Accuracy: 64.70%
#     Worker 1: Train Loss: 1.2466, Train Accuracy: 64.65%
#     Worker 2: Train Loss: 1.2246, Train Accuracy: 65.50%
#     Worker 3: Train Loss: 1.2359, Train Accuracy: 65.58%
# Epoch 139/150: Test Loss: 1.9538, Test Accuracy: 51.34%
#     Worker 0: Train Loss: 1.2347, Train Accuracy: 65.23%
#     Worker 1: Train Loss: 1.2282, Train Accuracy: 65.68%
#     Worker 2: Train Loss: 1.2477, Train Accuracy: 64.92%
#     Worker 3: Train Loss: 1.2414, Train Accuracy: 64.70%
# Epoch 140/150: Test Loss: 1.9534, Test Accuracy: 51.43%
#     Worker 0: Train Loss: 1.2320, Train Accuracy: 64.78%
#     Worker 1: Train Loss: 1.2413, Train Accuracy: 65.09%
#     Worker 2: Train Loss: 1.2311, Train Accuracy: 65.25%
#     Worker 3: Train Loss: 1.2430, Train Accuracy: 64.97%
# Epoch 141/150: Test Loss: 1.9537, Test Accuracy: 51.45%
#     Worker 0: Train Loss: 1.2412, Train Accuracy: 64.79%
#     Worker 1: Train Loss: 1.2344, Train Accuracy: 65.62%
#     Worker 2: Train Loss: 1.2307, Train Accuracy: 65.43%
#     Worker 3: Train Loss: 1.2349, Train Accuracy: 65.53%
# Epoch 142/150: Test Loss: 1.9535, Test Accuracy: 51.45%
#     Worker 0: Train Loss: 1.2263, Train Accuracy: 65.22%
#     Worker 1: Train Loss: 1.2253, Train Accuracy: 65.78%
#     Worker 2: Train Loss: 1.2386, Train Accuracy: 64.84%
#     Worker 3: Train Loss: 1.2572, Train Accuracy: 64.60%
# Epoch 143/150: Test Loss: 1.9535, Test Accuracy: 51.49%
#     Worker 0: Train Loss: 1.2310, Train Accuracy: 65.60%
#     Worker 1: Train Loss: 1.2431, Train Accuracy: 65.03%
#     Worker 2: Train Loss: 1.2240, Train Accuracy: 65.68%
#     Worker 3: Train Loss: 1.2590, Train Accuracy: 64.05%
# Epoch 144/150: Test Loss: 1.9535, Test Accuracy: 51.49%
#     Worker 0: Train Loss: 1.2350, Train Accuracy: 65.14%
#     Worker 1: Train Loss: 1.2437, Train Accuracy: 64.70%
#     Worker 2: Train Loss: 1.2337, Train Accuracy: 65.17%
#     Worker 3: Train Loss: 1.2383, Train Accuracy: 65.08%
# Epoch 145/150: Test Loss: 1.9535, Test Accuracy: 51.50%
#     Worker 0: Train Loss: 1.2268, Train Accuracy: 64.41%
#     Worker 1: Train Loss: 1.2359, Train Accuracy: 65.28%
#     Worker 2: Train Loss: 1.2390, Train Accuracy: 65.20%
#     Worker 3: Train Loss: 1.2403, Train Accuracy: 65.22%
# Epoch 146/150: Test Loss: 1.9535, Test Accuracy: 51.50%
#     Worker 0: Train Loss: 1.2351, Train Accuracy: 64.92%
#     Worker 1: Train Loss: 1.2293, Train Accuracy: 65.09%
#     Worker 2: Train Loss: 1.2312, Train Accuracy: 65.21%
#     Worker 3: Train Loss: 1.2581, Train Accuracy: 65.43%
# Epoch 147/150: Test Loss: 1.9535, Test Accuracy: 51.49%
#     Worker 0: Train Loss: 1.2285, Train Accuracy: 65.03%
#     Worker 1: Train Loss: 1.2336, Train Accuracy: 65.34%
#     Worker 2: Train Loss: 1.2291, Train Accuracy: 65.20%
#     Worker 3: Train Loss: 1.2510, Train Accuracy: 64.71%
# Epoch 148/150: Test Loss: 1.9535, Test Accuracy: 51.47%
#     Worker 0: Train Loss: 1.2352, Train Accuracy: 65.22%
#     Worker 1: Train Loss: 1.2292, Train Accuracy: 65.25%
#     Worker 2: Train Loss: 1.2226, Train Accuracy: 65.05%
#     Worker 3: Train Loss: 1.2439, Train Accuracy: 65.15%
# Epoch 149/150: Test Loss: 1.9536, Test Accuracy: 51.52%
#     Worker 0: Train Loss: 1.2416, Train Accuracy: 64.73%
#     Worker 1: Train Loss: 1.2349, Train Accuracy: 65.89%
#     Worker 2: Train Loss: 1.2295, Train Accuracy: 65.02%
#     Worker 3: Train Loss: 1.2469, Train Accuracy: 65.35%
# Epoch 150/150: Test Loss: 1.9534, Test Accuracy: 51.46%
#     Worker 0: Train Loss: 1.2273, Train Accuracy: 64.59%
#     Worker 1: Train Loss: 1.2387, Train Accuracy: 65.22%
#     Worker 2: Train Loss: 1.2351, Train Accuracy: 65.10%
#     Worker 3: Train Loss: 1.2234, Train Accuracy: 65.71%
