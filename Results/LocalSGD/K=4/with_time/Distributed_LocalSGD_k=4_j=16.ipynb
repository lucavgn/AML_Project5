# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files
import time

total_computation_time = 0
total_communication_time = 0

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
#warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")

    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch):
        computation_start_time = time.time()
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            # Perform J local step before synchronization
            for j in range(J):
                try:
                    # Get a batch from the current worker's shard using next()
                    images, labels = next(shard_iterators[k])
                    images, labels = images.to(device), labels.to(device)  # Move to device
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

                except StopIteration:
                    # If the iterator has exhausted the data, restart the iterator
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k]) # Resume from the next batch
                    images, labels = images.to(device), labels.to(device)
                    # Perform optimization step
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        computation_end_time = time.time()
        total_computation_time += (computation_end_time - computation_start_time)

        communication_start_time = time.time()
        # Perform model synchronization
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            # Update each worker model with the global parameters
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

        communication_end_time = time.time()
        total_communication_time += (communication_end_time - communication_start_time)

    # Update lr for each scheduler
    for scheduler in schedulers:
       # if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
       # else:
        #    warmup_factor = (epoch + 1) / warmup_epochs
          #  lr = warmup_factor * learning_rate
          #  for optimizer in optimizers:
           #     for param_group in optimizer.param_groups:
            #        param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

    print(f"Total Computation Time: {total_computation_time:.2f} seconds")
    print(f"Total Communication Time: {total_communication_time:.2f} seconds")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 4 --j 16
# Out:
# Training with K=4, J=16
# Global iteration per epoch: 13
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:12<00:00, 13.2MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00400
# Epoch 1/150: Test Loss: 4.5776, Test Accuracy: 2.89%
#     Worker 0: Train Loss: 4.5980, Train Accuracy: 1.46%
#     Worker 1: Train Loss: 4.5984, Train Accuracy: 1.42%
#     Worker 2: Train Loss: 4.5976, Train Accuracy: 1.48%
#     Worker 3: Train Loss: 4.5986, Train Accuracy: 1.35%
# Total Computation Time: 25.63 seconds
# Total Communication Time: 0.05 seconds
# Epoch 2/150: Test Loss: 4.1753, Test Accuracy: 6.42%
#     Worker 0: Train Loss: 4.4422, Train Accuracy: 3.42%
#     Worker 1: Train Loss: 4.4440, Train Accuracy: 3.63%
#     Worker 2: Train Loss: 4.4299, Train Accuracy: 3.77%
#     Worker 3: Train Loss: 4.4428, Train Accuracy: 3.92%
# Total Computation Time: 51.08 seconds
# Total Communication Time: 0.06 seconds
# Epoch 3/150: Test Loss: 3.9664, Test Accuracy: 9.30%
#     Worker 0: Train Loss: 4.1128, Train Accuracy: 6.85%
#     Worker 1: Train Loss: 4.1236, Train Accuracy: 6.77%
#     Worker 2: Train Loss: 4.0950, Train Accuracy: 6.99%
#     Worker 3: Train Loss: 4.1225, Train Accuracy: 6.68%
# Total Computation Time: 75.93 seconds
# Total Communication Time: 0.08 seconds
# Epoch 4/150: Test Loss: 3.8262, Test Accuracy: 11.66%
#     Worker 0: Train Loss: 3.9616, Train Accuracy: 9.29%
#     Worker 1: Train Loss: 3.9702, Train Accuracy: 9.04%
#     Worker 2: Train Loss: 3.9138, Train Accuracy: 9.92%
#     Worker 3: Train Loss: 3.9542, Train Accuracy: 8.91%
# Total Computation Time: 100.58 seconds
# Total Communication Time: 0.09 seconds
# Epoch 5/150: Test Loss: 3.6718, Test Accuracy: 14.55%
#     Worker 0: Train Loss: 3.8278, Train Accuracy: 11.25%
#     Worker 1: Train Loss: 3.8442, Train Accuracy: 11.16%
#     Worker 2: Train Loss: 3.7981, Train Accuracy: 11.58%
#     Worker 3: Train Loss: 3.8383, Train Accuracy: 11.19%
# Total Computation Time: 125.20 seconds
# Total Communication Time: 0.11 seconds
# Epoch 6/150: Test Loss: 3.5770, Test Accuracy: 15.93%
#     Worker 0: Train Loss: 3.7243, Train Accuracy: 12.87%
#     Worker 1: Train Loss: 3.7203, Train Accuracy: 12.99%
#     Worker 2: Train Loss: 3.6825, Train Accuracy: 13.75%
#     Worker 3: Train Loss: 3.7215, Train Accuracy: 12.95%
# Total Computation Time: 150.10 seconds
# Total Communication Time: 0.13 seconds
# Epoch 7/150: Test Loss: 3.4699, Test Accuracy: 18.10%
#     Worker 0: Train Loss: 3.6413, Train Accuracy: 14.09%
#     Worker 1: Train Loss: 3.6193, Train Accuracy: 15.27%
#     Worker 2: Train Loss: 3.5887, Train Accuracy: 15.26%
#     Worker 3: Train Loss: 3.6236, Train Accuracy: 14.59%
# Total Computation Time: 175.64 seconds
# Total Communication Time: 0.14 seconds
# Epoch 8/150: Test Loss: 3.3799, Test Accuracy: 19.53%
#     Worker 0: Train Loss: 3.5419, Train Accuracy: 15.96%
#     Worker 1: Train Loss: 3.5663, Train Accuracy: 15.55%
#     Worker 2: Train Loss: 3.4832, Train Accuracy: 17.14%
#     Worker 3: Train Loss: 3.5690, Train Accuracy: 15.16%
# Total Computation Time: 200.38 seconds
# Total Communication Time: 0.16 seconds
# Epoch 9/150: Test Loss: 3.2874, Test Accuracy: 21.34%
#     Worker 0: Train Loss: 3.4464, Train Accuracy: 17.12%
#     Worker 1: Train Loss: 3.4639, Train Accuracy: 17.23%
#     Worker 2: Train Loss: 3.4107, Train Accuracy: 18.07%
#     Worker 3: Train Loss: 3.4562, Train Accuracy: 17.32%
# Total Computation Time: 225.13 seconds
# Total Communication Time: 0.17 seconds
# Epoch 10/150: Test Loss: 3.2471, Test Accuracy: 21.92%
#     Worker 0: Train Loss: 3.3611, Train Accuracy: 18.68%
#     Worker 1: Train Loss: 3.3906, Train Accuracy: 18.69%
#     Worker 2: Train Loss: 3.3276, Train Accuracy: 19.79%
#     Worker 3: Train Loss: 3.3911, Train Accuracy: 18.71%
# Total Computation Time: 249.73 seconds
# Total Communication Time: 0.19 seconds
# Epoch 11/150: Test Loss: 3.1714, Test Accuracy: 23.08%
#     Worker 0: Train Loss: 3.3148, Train Accuracy: 19.73%
#     Worker 1: Train Loss: 3.3224, Train Accuracy: 19.68%
#     Worker 2: Train Loss: 3.2570, Train Accuracy: 20.84%
#     Worker 3: Train Loss: 3.3109, Train Accuracy: 20.09%
# Total Computation Time: 274.40 seconds
# Total Communication Time: 0.21 seconds
# Epoch 12/150: Test Loss: 3.0956, Test Accuracy: 25.08%
#     Worker 0: Train Loss: 3.2301, Train Accuracy: 20.36%
#     Worker 1: Train Loss: 3.2441, Train Accuracy: 21.07%
#     Worker 2: Train Loss: 3.1613, Train Accuracy: 22.57%
#     Worker 3: Train Loss: 3.2218, Train Accuracy: 21.09%
# Total Computation Time: 299.02 seconds
# Total Communication Time: 0.22 seconds
# Epoch 13/150: Test Loss: 2.9925, Test Accuracy: 26.67%
#     Worker 0: Train Loss: 3.1691, Train Accuracy: 22.26%
#     Worker 1: Train Loss: 3.1872, Train Accuracy: 22.19%
#     Worker 2: Train Loss: 3.1229, Train Accuracy: 23.10%
#     Worker 3: Train Loss: 3.1899, Train Accuracy: 22.09%
# Total Computation Time: 324.28 seconds
# Total Communication Time: 0.24 seconds
# Epoch 14/150: Test Loss: 2.9395, Test Accuracy: 28.01%
#     Worker 0: Train Loss: 3.0979, Train Accuracy: 23.38%
#     Worker 1: Train Loss: 3.1074, Train Accuracy: 23.55%
#     Worker 2: Train Loss: 3.0624, Train Accuracy: 24.83%
#     Worker 3: Train Loss: 3.1163, Train Accuracy: 23.37%
# Total Computation Time: 349.08 seconds
# Total Communication Time: 0.25 seconds
# Epoch 15/150: Test Loss: 2.8730, Test Accuracy: 28.96%
#     Worker 0: Train Loss: 3.0518, Train Accuracy: 24.37%
#     Worker 1: Train Loss: 3.0836, Train Accuracy: 24.47%
#     Worker 2: Train Loss: 3.0262, Train Accuracy: 24.95%
#     Worker 3: Train Loss: 3.0590, Train Accuracy: 24.69%
# Total Computation Time: 374.10 seconds
# Total Communication Time: 0.27 seconds
# Epoch 16/150: Test Loss: 2.8737, Test Accuracy: 28.96%
#     Worker 0: Train Loss: 2.9885, Train Accuracy: 25.91%
#     Worker 1: Train Loss: 3.0094, Train Accuracy: 25.73%
#     Worker 2: Train Loss: 2.9727, Train Accuracy: 26.18%
#     Worker 3: Train Loss: 3.0155, Train Accuracy: 25.20%
# Total Computation Time: 398.87 seconds
# Total Communication Time: 0.29 seconds
# Epoch 17/150: Test Loss: 2.8029, Test Accuracy: 30.26%
#     Worker 0: Train Loss: 2.9502, Train Accuracy: 26.52%
#     Worker 1: Train Loss: 2.9831, Train Accuracy: 26.18%
#     Worker 2: Train Loss: 2.9351, Train Accuracy: 27.01%
#     Worker 3: Train Loss: 2.9670, Train Accuracy: 25.95%
# Total Computation Time: 423.47 seconds
# Total Communication Time: 0.30 seconds
# Epoch 18/150: Test Loss: 2.7778, Test Accuracy: 30.75%
#     Worker 0: Train Loss: 2.8814, Train Accuracy: 28.05%
#     Worker 1: Train Loss: 2.9384, Train Accuracy: 27.14%
#     Worker 2: Train Loss: 2.8935, Train Accuracy: 27.71%
#     Worker 3: Train Loss: 2.9048, Train Accuracy: 27.56%
# Total Computation Time: 449.11 seconds
# Total Communication Time: 0.32 seconds
# Epoch 19/150: Test Loss: 2.7276, Test Accuracy: 31.61%
#     Worker 0: Train Loss: 2.8736, Train Accuracy: 27.82%
#     Worker 1: Train Loss: 2.8929, Train Accuracy: 27.75%
#     Worker 2: Train Loss: 2.8342, Train Accuracy: 29.10%
#     Worker 3: Train Loss: 2.8839, Train Accuracy: 27.59%
# Total Computation Time: 473.91 seconds
# Total Communication Time: 0.34 seconds
# Epoch 20/150: Test Loss: 2.7022, Test Accuracy: 32.29%
#     Worker 0: Train Loss: 2.8322, Train Accuracy: 28.75%
#     Worker 1: Train Loss: 2.8366, Train Accuracy: 28.91%
#     Worker 2: Train Loss: 2.7994, Train Accuracy: 29.50%
#     Worker 3: Train Loss: 2.8325, Train Accuracy: 29.12%
# Total Computation Time: 498.38 seconds
# Total Communication Time: 0.35 seconds
# Epoch 21/150: Test Loss: 2.6383, Test Accuracy: 33.51%
#     Worker 0: Train Loss: 2.7488, Train Accuracy: 30.15%
#     Worker 1: Train Loss: 2.7991, Train Accuracy: 29.23%
#     Worker 2: Train Loss: 2.7597, Train Accuracy: 30.39%
#     Worker 3: Train Loss: 2.7879, Train Accuracy: 29.68%
# Total Computation Time: 522.87 seconds
# Total Communication Time: 0.37 seconds
# Epoch 22/150: Test Loss: 2.5856, Test Accuracy: 34.65%
#     Worker 0: Train Loss: 2.7386, Train Accuracy: 30.61%
#     Worker 1: Train Loss: 2.7758, Train Accuracy: 29.88%
#     Worker 2: Train Loss: 2.7262, Train Accuracy: 31.13%
#     Worker 3: Train Loss: 2.7430, Train Accuracy: 30.33%
# Total Computation Time: 547.87 seconds
# Total Communication Time: 0.38 seconds
# Epoch 23/150: Test Loss: 2.5971, Test Accuracy: 34.14%
#     Worker 0: Train Loss: 2.6919, Train Accuracy: 31.20%
#     Worker 1: Train Loss: 2.7261, Train Accuracy: 31.30%
#     Worker 2: Train Loss: 2.6617, Train Accuracy: 32.36%
#     Worker 3: Train Loss: 2.7041, Train Accuracy: 31.20%
# Total Computation Time: 573.54 seconds
# Total Communication Time: 0.40 seconds
# Epoch 24/150: Test Loss: 2.5204, Test Accuracy: 35.93%
#     Worker 0: Train Loss: 2.6579, Train Accuracy: 31.97%
#     Worker 1: Train Loss: 2.6608, Train Accuracy: 32.27%
#     Worker 2: Train Loss: 2.6498, Train Accuracy: 32.85%
#     Worker 3: Train Loss: 2.6754, Train Accuracy: 31.78%
# Total Computation Time: 598.51 seconds
# Total Communication Time: 0.42 seconds
# Epoch 25/150: Test Loss: 2.4832, Test Accuracy: 36.76%
#     Worker 0: Train Loss: 2.5969, Train Accuracy: 33.59%
#     Worker 1: Train Loss: 2.6439, Train Accuracy: 32.13%
#     Worker 2: Train Loss: 2.5832, Train Accuracy: 34.41%
#     Worker 3: Train Loss: 2.6033, Train Accuracy: 33.50%
# Total Computation Time: 623.18 seconds
# Total Communication Time: 0.43 seconds
# Epoch 26/150: Test Loss: 2.4623, Test Accuracy: 37.00%
#     Worker 0: Train Loss: 2.5832, Train Accuracy: 33.86%
#     Worker 1: Train Loss: 2.5827, Train Accuracy: 34.13%
#     Worker 2: Train Loss: 2.5630, Train Accuracy: 34.38%
#     Worker 3: Train Loss: 2.5864, Train Accuracy: 33.43%
# Total Computation Time: 648.31 seconds
# Total Communication Time: 0.45 seconds
# Epoch 27/150: Test Loss: 2.4255, Test Accuracy: 38.06%
#     Worker 0: Train Loss: 2.5402, Train Accuracy: 34.65%
#     Worker 1: Train Loss: 2.5553, Train Accuracy: 34.57%
#     Worker 2: Train Loss: 2.5008, Train Accuracy: 35.55%
#     Worker 3: Train Loss: 2.5573, Train Accuracy: 34.53%
# Total Computation Time: 673.20 seconds
# Total Communication Time: 0.46 seconds
# Epoch 28/150: Test Loss: 2.4243, Test Accuracy: 37.25%
#     Worker 0: Train Loss: 2.5217, Train Accuracy: 34.75%
#     Worker 1: Train Loss: 2.5190, Train Accuracy: 35.08%
#     Worker 2: Train Loss: 2.5010, Train Accuracy: 35.55%
#     Worker 3: Train Loss: 2.5028, Train Accuracy: 35.07%
# Total Computation Time: 698.18 seconds
# Total Communication Time: 0.48 seconds
# Epoch 29/150: Test Loss: 2.3772, Test Accuracy: 38.62%
#     Worker 0: Train Loss: 2.4660, Train Accuracy: 36.16%
#     Worker 1: Train Loss: 2.5101, Train Accuracy: 34.96%
#     Worker 2: Train Loss: 2.4505, Train Accuracy: 36.48%
#     Worker 3: Train Loss: 2.4958, Train Accuracy: 35.42%
# Total Computation Time: 724.01 seconds
# Total Communication Time: 0.49 seconds
# Epoch 30/150: Test Loss: 2.3933, Test Accuracy: 38.83%
#     Worker 0: Train Loss: 2.4317, Train Accuracy: 37.01%
#     Worker 1: Train Loss: 2.4635, Train Accuracy: 36.54%
#     Worker 2: Train Loss: 2.4329, Train Accuracy: 37.19%
#     Worker 3: Train Loss: 2.4659, Train Accuracy: 36.02%
# Total Computation Time: 748.92 seconds
# Total Communication Time: 0.51 seconds
# Epoch 31/150: Test Loss: 2.3284, Test Accuracy: 39.65%
#     Worker 0: Train Loss: 2.4233, Train Accuracy: 37.34%
#     Worker 1: Train Loss: 2.4275, Train Accuracy: 36.83%
#     Worker 2: Train Loss: 2.4163, Train Accuracy: 37.41%
#     Worker 3: Train Loss: 2.4265, Train Accuracy: 37.38%
# Total Computation Time: 773.91 seconds
# Total Communication Time: 0.52 seconds
# Epoch 32/150: Test Loss: 2.3235, Test Accuracy: 40.20%
#     Worker 0: Train Loss: 2.3749, Train Accuracy: 38.17%
#     Worker 1: Train Loss: 2.4081, Train Accuracy: 38.05%
#     Worker 2: Train Loss: 2.3675, Train Accuracy: 38.67%
#     Worker 3: Train Loss: 2.4022, Train Accuracy: 37.05%
# Total Computation Time: 798.60 seconds
# Total Communication Time: 0.54 seconds
# Epoch 33/150: Test Loss: 2.2894, Test Accuracy: 40.56%
#     Worker 0: Train Loss: 2.3737, Train Accuracy: 38.01%
#     Worker 1: Train Loss: 2.3758, Train Accuracy: 37.89%
#     Worker 2: Train Loss: 2.3549, Train Accuracy: 38.99%
#     Worker 3: Train Loss: 2.3848, Train Accuracy: 38.14%
# Total Computation Time: 823.34 seconds
# Total Communication Time: 0.55 seconds
# Epoch 34/150: Test Loss: 2.2913, Test Accuracy: 40.55%
#     Worker 0: Train Loss: 2.3326, Train Accuracy: 38.79%
#     Worker 1: Train Loss: 2.3422, Train Accuracy: 38.42%
#     Worker 2: Train Loss: 2.3086, Train Accuracy: 40.11%
#     Worker 3: Train Loss: 2.3476, Train Accuracy: 38.54%
# Total Computation Time: 849.04 seconds
# Total Communication Time: 0.57 seconds
# Epoch 35/150: Test Loss: 2.2803, Test Accuracy: 40.77%
#     Worker 0: Train Loss: 2.3118, Train Accuracy: 39.68%
#     Worker 1: Train Loss: 2.3189, Train Accuracy: 39.24%
#     Worker 2: Train Loss: 2.3134, Train Accuracy: 39.64%
#     Worker 3: Train Loss: 2.3428, Train Accuracy: 39.26%
# Total Computation Time: 873.81 seconds
# Total Communication Time: 0.59 seconds
# Epoch 36/150: Test Loss: 2.2650, Test Accuracy: 41.32%
#     Worker 0: Train Loss: 2.2817, Train Accuracy: 39.98%
#     Worker 1: Train Loss: 2.3090, Train Accuracy: 39.21%
#     Worker 2: Train Loss: 2.2743, Train Accuracy: 40.85%
#     Worker 3: Train Loss: 2.2941, Train Accuracy: 39.81%
# Total Computation Time: 898.35 seconds
# Total Communication Time: 0.60 seconds
# Epoch 37/150: Test Loss: 2.2656, Test Accuracy: 41.29%
#     Worker 0: Train Loss: 2.2707, Train Accuracy: 40.51%
#     Worker 1: Train Loss: 2.2782, Train Accuracy: 40.35%
#     Worker 2: Train Loss: 2.2475, Train Accuracy: 41.10%
#     Worker 3: Train Loss: 2.2696, Train Accuracy: 40.35%
# Total Computation Time: 922.87 seconds
# Total Communication Time: 0.62 seconds
# Epoch 38/150: Test Loss: 2.2363, Test Accuracy: 41.89%
#     Worker 0: Train Loss: 2.2406, Train Accuracy: 40.68%
#     Worker 1: Train Loss: 2.2575, Train Accuracy: 40.66%
#     Worker 2: Train Loss: 2.2108, Train Accuracy: 41.52%
#     Worker 3: Train Loss: 2.2476, Train Accuracy: 41.03%
# Total Computation Time: 947.74 seconds
# Total Communication Time: 0.63 seconds
# Epoch 39/150: Test Loss: 2.2214, Test Accuracy: 42.11%
#     Worker 0: Train Loss: 2.2026, Train Accuracy: 41.42%
#     Worker 1: Train Loss: 2.2282, Train Accuracy: 41.26%
#     Worker 2: Train Loss: 2.2101, Train Accuracy: 42.40%
#     Worker 3: Train Loss: 2.2216, Train Accuracy: 41.30%
# Total Computation Time: 973.29 seconds
# Total Communication Time: 0.65 seconds
# Epoch 40/150: Test Loss: 2.2007, Test Accuracy: 42.71%
#     Worker 0: Train Loss: 2.2030, Train Accuracy: 41.80%
#     Worker 1: Train Loss: 2.1917, Train Accuracy: 42.58%
#     Worker 2: Train Loss: 2.1658, Train Accuracy: 42.98%
#     Worker 3: Train Loss: 2.2069, Train Accuracy: 41.72%
# Total Computation Time: 998.07 seconds
# Total Communication Time: 0.67 seconds
# Epoch 41/150: Test Loss: 2.1796, Test Accuracy: 43.31%
#     Worker 0: Train Loss: 2.1781, Train Accuracy: 41.83%
#     Worker 1: Train Loss: 2.2054, Train Accuracy: 41.91%
#     Worker 2: Train Loss: 2.1725, Train Accuracy: 42.60%
#     Worker 3: Train Loss: 2.1928, Train Accuracy: 41.66%
# Total Computation Time: 1022.49 seconds
# Total Communication Time: 0.68 seconds
# Epoch 42/150: Test Loss: 2.1627, Test Accuracy: 43.85%
#     Worker 0: Train Loss: 2.1717, Train Accuracy: 42.26%
#     Worker 1: Train Loss: 2.1622, Train Accuracy: 42.74%
#     Worker 2: Train Loss: 2.1479, Train Accuracy: 43.34%
#     Worker 3: Train Loss: 2.1650, Train Accuracy: 42.83%
# Total Computation Time: 1046.80 seconds
# Total Communication Time: 0.70 seconds
# Epoch 43/150: Test Loss: 2.1622, Test Accuracy: 43.87%
#     Worker 0: Train Loss: 2.1348, Train Accuracy: 43.22%
#     Worker 1: Train Loss: 2.1227, Train Accuracy: 43.52%
#     Worker 2: Train Loss: 2.0896, Train Accuracy: 44.09%
#     Worker 3: Train Loss: 2.1388, Train Accuracy: 43.58%
# Total Computation Time: 1071.02 seconds
# Total Communication Time: 0.71 seconds
# Epoch 44/150: Test Loss: 2.1434, Test Accuracy: 43.77%
#     Worker 0: Train Loss: 2.1213, Train Accuracy: 43.44%
#     Worker 1: Train Loss: 2.1113, Train Accuracy: 44.05%
#     Worker 2: Train Loss: 2.1283, Train Accuracy: 43.39%
#     Worker 3: Train Loss: 2.1327, Train Accuracy: 43.36%
# Total Computation Time: 1095.34 seconds
# Total Communication Time: 0.73 seconds
# Epoch 45/150: Test Loss: 2.1438, Test Accuracy: 44.26%
#     Worker 0: Train Loss: 2.0979, Train Accuracy: 44.04%
#     Worker 1: Train Loss: 2.0851, Train Accuracy: 44.29%
#     Worker 2: Train Loss: 2.0862, Train Accuracy: 44.42%
#     Worker 3: Train Loss: 2.0898, Train Accuracy: 44.67%
# Total Computation Time: 1121.03 seconds
# Total Communication Time: 0.75 seconds
# Epoch 46/150: Test Loss: 2.1314, Test Accuracy: 44.64%
#     Worker 0: Train Loss: 2.0913, Train Accuracy: 43.97%
#     Worker 1: Train Loss: 2.0814, Train Accuracy: 44.91%
#     Worker 2: Train Loss: 2.0510, Train Accuracy: 45.42%
#     Worker 3: Train Loss: 2.0841, Train Accuracy: 44.37%
# Total Computation Time: 1145.59 seconds
# Total Communication Time: 0.76 seconds
# Epoch 47/150: Test Loss: 2.1257, Test Accuracy: 44.84%
#     Worker 0: Train Loss: 2.0702, Train Accuracy: 44.43%
#     Worker 1: Train Loss: 2.0756, Train Accuracy: 44.29%
#     Worker 2: Train Loss: 2.0419, Train Accuracy: 45.62%
#     Worker 3: Train Loss: 2.0737, Train Accuracy: 44.79%
# Total Computation Time: 1170.16 seconds
# Total Communication Time: 0.78 seconds
# Epoch 48/150: Test Loss: 2.0998, Test Accuracy: 45.19%
#     Worker 0: Train Loss: 2.0400, Train Accuracy: 45.36%
#     Worker 1: Train Loss: 2.0357, Train Accuracy: 45.63%
#     Worker 2: Train Loss: 2.0224, Train Accuracy: 46.30%
#     Worker 3: Train Loss: 2.0498, Train Accuracy: 45.12%
# Total Computation Time: 1194.74 seconds
# Total Communication Time: 0.79 seconds
# Epoch 49/150: Test Loss: 2.1064, Test Accuracy: 45.13%
#     Worker 0: Train Loss: 2.0234, Train Accuracy: 45.21%
#     Worker 1: Train Loss: 2.0163, Train Accuracy: 46.17%
#     Worker 2: Train Loss: 2.0046, Train Accuracy: 46.52%
#     Worker 3: Train Loss: 2.0317, Train Accuracy: 45.93%
# Total Computation Time: 1219.33 seconds
# Total Communication Time: 0.81 seconds
# Epoch 50/150: Test Loss: 2.0957, Test Accuracy: 45.38%
#     Worker 0: Train Loss: 1.9931, Train Accuracy: 46.31%
#     Worker 1: Train Loss: 2.0073, Train Accuracy: 46.39%
#     Worker 2: Train Loss: 1.9954, Train Accuracy: 46.53%
#     Worker 3: Train Loss: 2.0150, Train Accuracy: 45.82%
# Total Computation Time: 1244.30 seconds
# Total Communication Time: 0.83 seconds
# Epoch 51/150: Test Loss: 2.0890, Test Accuracy: 45.38%
#     Worker 0: Train Loss: 2.0017, Train Accuracy: 45.82%
#     Worker 1: Train Loss: 2.0053, Train Accuracy: 46.06%
#     Worker 2: Train Loss: 1.9911, Train Accuracy: 46.40%
#     Worker 3: Train Loss: 1.9989, Train Accuracy: 46.62%
# Total Computation Time: 1268.52 seconds
# Total Communication Time: 0.84 seconds
# Epoch 52/150: Test Loss: 2.0947, Test Accuracy: 45.55%
#     Worker 0: Train Loss: 1.9824, Train Accuracy: 47.02%
#     Worker 1: Train Loss: 1.9669, Train Accuracy: 47.00%
#     Worker 2: Train Loss: 1.9438, Train Accuracy: 47.63%
#     Worker 3: Train Loss: 1.9713, Train Accuracy: 47.35%
# Total Computation Time: 1293.26 seconds
# Total Communication Time: 0.86 seconds
# Epoch 53/150: Test Loss: 2.0828, Test Accuracy: 46.29%
#     Worker 0: Train Loss: 1.9472, Train Accuracy: 47.20%
#     Worker 1: Train Loss: 1.9550, Train Accuracy: 47.02%
#     Worker 2: Train Loss: 1.9400, Train Accuracy: 47.65%
#     Worker 3: Train Loss: 1.9663, Train Accuracy: 46.98%
# Total Computation Time: 1317.77 seconds
# Total Communication Time: 0.88 seconds
# Epoch 54/150: Test Loss: 2.0590, Test Accuracy: 46.10%
#     Worker 0: Train Loss: 1.9423, Train Accuracy: 47.41%
#     Worker 1: Train Loss: 1.9582, Train Accuracy: 47.03%
#     Worker 2: Train Loss: 1.9176, Train Accuracy: 48.61%
#     Worker 3: Train Loss: 1.9511, Train Accuracy: 47.72%
# Total Computation Time: 1342.53 seconds
# Total Communication Time: 0.89 seconds
# Epoch 55/150: Test Loss: 2.0709, Test Accuracy: 46.45%
#     Worker 0: Train Loss: 1.9299, Train Accuracy: 47.68%
#     Worker 1: Train Loss: 1.9323, Train Accuracy: 47.62%
#     Worker 2: Train Loss: 1.8928, Train Accuracy: 48.98%
#     Worker 3: Train Loss: 1.9174, Train Accuracy: 48.44%
# Total Computation Time: 1366.97 seconds
# Total Communication Time: 0.91 seconds
# Epoch 56/150: Test Loss: 2.0492, Test Accuracy: 46.73%
#     Worker 0: Train Loss: 1.9093, Train Accuracy: 48.33%
#     Worker 1: Train Loss: 1.9091, Train Accuracy: 48.58%
#     Worker 2: Train Loss: 1.8973, Train Accuracy: 48.58%
#     Worker 3: Train Loss: 1.9006, Train Accuracy: 48.88%
# Total Computation Time: 1391.24 seconds
# Total Communication Time: 0.92 seconds
# Epoch 57/150: Test Loss: 2.0494, Test Accuracy: 46.57%
#     Worker 0: Train Loss: 1.8882, Train Accuracy: 48.17%
#     Worker 1: Train Loss: 1.9097, Train Accuracy: 48.73%
#     Worker 2: Train Loss: 1.8860, Train Accuracy: 48.97%
#     Worker 3: Train Loss: 1.8984, Train Accuracy: 48.79%
# Total Computation Time: 1415.46 seconds
# Total Communication Time: 0.94 seconds
# Epoch 58/150: Test Loss: 2.0337, Test Accuracy: 47.04%
#     Worker 0: Train Loss: 1.8867, Train Accuracy: 48.74%
#     Worker 1: Train Loss: 1.8534, Train Accuracy: 50.13%
#     Worker 2: Train Loss: 1.8749, Train Accuracy: 49.04%
#     Worker 3: Train Loss: 1.8580, Train Accuracy: 49.36%
# Total Computation Time: 1439.62 seconds
# Total Communication Time: 0.96 seconds
# Epoch 59/150: Test Loss: 2.0320, Test Accuracy: 47.41%
#     Worker 0: Train Loss: 1.8446, Train Accuracy: 49.37%
#     Worker 1: Train Loss: 1.8370, Train Accuracy: 50.72%
#     Worker 2: Train Loss: 1.8399, Train Accuracy: 50.55%
#     Worker 3: Train Loss: 1.8928, Train Accuracy: 49.46%
# Total Computation Time: 1463.87 seconds
# Total Communication Time: 0.97 seconds
# Epoch 60/150: Test Loss: 2.0240, Test Accuracy: 47.49%
#     Worker 0: Train Loss: 1.8524, Train Accuracy: 49.41%
#     Worker 1: Train Loss: 1.8501, Train Accuracy: 49.51%
#     Worker 2: Train Loss: 1.8314, Train Accuracy: 50.06%
#     Worker 3: Train Loss: 1.8370, Train Accuracy: 50.12%
# Total Computation Time: 1488.66 seconds
# Total Communication Time: 0.99 seconds
# Epoch 61/150: Test Loss: 2.0304, Test Accuracy: 47.68%
#     Worker 0: Train Loss: 1.8341, Train Accuracy: 49.77%
#     Worker 1: Train Loss: 1.8365, Train Accuracy: 50.28%
#     Worker 2: Train Loss: 1.8182, Train Accuracy: 50.52%
#     Worker 3: Train Loss: 1.8451, Train Accuracy: 50.11%
# Total Computation Time: 1513.61 seconds
# Total Communication Time: 1.00 seconds
# Epoch 62/150: Test Loss: 2.0030, Test Accuracy: 48.09%
#     Worker 0: Train Loss: 1.8309, Train Accuracy: 50.13%
#     Worker 1: Train Loss: 1.8129, Train Accuracy: 50.47%
#     Worker 2: Train Loss: 1.8248, Train Accuracy: 50.64%
#     Worker 3: Train Loss: 1.8203, Train Accuracy: 50.63%
# Total Computation Time: 1537.89 seconds
# Total Communication Time: 1.02 seconds
# Epoch 63/150: Test Loss: 2.0237, Test Accuracy: 47.67%
#     Worker 0: Train Loss: 1.8150, Train Accuracy: 50.23%
#     Worker 1: Train Loss: 1.8052, Train Accuracy: 50.84%
#     Worker 2: Train Loss: 1.7872, Train Accuracy: 51.27%
#     Worker 3: Train Loss: 1.8127, Train Accuracy: 50.78%
# Total Computation Time: 1562.31 seconds
# Total Communication Time: 1.03 seconds
# Epoch 64/150: Test Loss: 2.0073, Test Accuracy: 48.11%
#     Worker 0: Train Loss: 1.7957, Train Accuracy: 50.95%
#     Worker 1: Train Loss: 1.8125, Train Accuracy: 50.26%
#     Worker 2: Train Loss: 1.7829, Train Accuracy: 51.21%
#     Worker 3: Train Loss: 1.7930, Train Accuracy: 51.27%
# Total Computation Time: 1586.47 seconds
# Total Communication Time: 1.05 seconds
# Epoch 65/150: Test Loss: 1.9998, Test Accuracy: 48.00%
#     Worker 0: Train Loss: 1.7716, Train Accuracy: 51.30%
#     Worker 1: Train Loss: 1.7674, Train Accuracy: 51.74%
#     Worker 2: Train Loss: 1.7646, Train Accuracy: 51.52%
#     Worker 3: Train Loss: 1.7742, Train Accuracy: 51.61%
# Total Computation Time: 1610.56 seconds
# Total Communication Time: 1.07 seconds
# Epoch 66/150: Test Loss: 2.0164, Test Accuracy: 47.81%
#     Worker 0: Train Loss: 1.7558, Train Accuracy: 51.81%
#     Worker 1: Train Loss: 1.7685, Train Accuracy: 51.32%
#     Worker 2: Train Loss: 1.7577, Train Accuracy: 52.02%
#     Worker 3: Train Loss: 1.7591, Train Accuracy: 51.51%
# Total Computation Time: 1635.48 seconds
# Total Communication Time: 1.08 seconds
# Epoch 67/150: Test Loss: 2.0090, Test Accuracy: 47.92%
#     Worker 0: Train Loss: 1.7429, Train Accuracy: 51.83%
#     Worker 1: Train Loss: 1.7458, Train Accuracy: 52.19%
#     Worker 2: Train Loss: 1.7498, Train Accuracy: 52.47%
#     Worker 3: Train Loss: 1.7591, Train Accuracy: 52.46%
# Total Computation Time: 1659.79 seconds
# Total Communication Time: 1.10 seconds
# Epoch 68/150: Test Loss: 1.9961, Test Accuracy: 48.18%
#     Worker 0: Train Loss: 1.7219, Train Accuracy: 52.27%
#     Worker 1: Train Loss: 1.7437, Train Accuracy: 52.19%
#     Worker 2: Train Loss: 1.7364, Train Accuracy: 52.59%
#     Worker 3: Train Loss: 1.7394, Train Accuracy: 52.45%
# Total Computation Time: 1683.86 seconds
# Total Communication Time: 1.11 seconds
# Epoch 69/150: Test Loss: 2.0008, Test Accuracy: 48.43%
#     Worker 0: Train Loss: 1.7329, Train Accuracy: 51.90%
#     Worker 1: Train Loss: 1.7233, Train Accuracy: 52.75%
#     Worker 2: Train Loss: 1.7001, Train Accuracy: 53.50%
#     Worker 3: Train Loss: 1.7193, Train Accuracy: 52.77%
# Total Computation Time: 1708.25 seconds
# Total Communication Time: 1.13 seconds
# Epoch 70/150: Test Loss: 1.9840, Test Accuracy: 48.54%
#     Worker 0: Train Loss: 1.7075, Train Accuracy: 52.73%
#     Worker 1: Train Loss: 1.6939, Train Accuracy: 53.39%
#     Worker 2: Train Loss: 1.7058, Train Accuracy: 53.23%
#     Worker 3: Train Loss: 1.7332, Train Accuracy: 52.39%
# Total Computation Time: 1732.52 seconds
# Total Communication Time: 1.15 seconds
# Epoch 71/150: Test Loss: 1.9760, Test Accuracy: 48.84%
#     Worker 0: Train Loss: 1.7004, Train Accuracy: 52.81%
#     Worker 1: Train Loss: 1.7058, Train Accuracy: 53.48%
#     Worker 2: Train Loss: 1.6828, Train Accuracy: 53.99%
#     Worker 3: Train Loss: 1.7016, Train Accuracy: 53.29%
# Total Computation Time: 1757.15 seconds
# Total Communication Time: 1.16 seconds
# Epoch 72/150: Test Loss: 1.9851, Test Accuracy: 48.81%
#     Worker 0: Train Loss: 1.6838, Train Accuracy: 53.23%
#     Worker 1: Train Loss: 1.6815, Train Accuracy: 54.48%
#     Worker 2: Train Loss: 1.6996, Train Accuracy: 53.14%
#     Worker 3: Train Loss: 1.6970, Train Accuracy: 53.53%
# Total Computation Time: 1781.71 seconds
# Total Communication Time: 1.18 seconds
# Epoch 73/150: Test Loss: 1.9866, Test Accuracy: 48.37%
#     Worker 0: Train Loss: 1.6651, Train Accuracy: 53.72%
#     Worker 1: Train Loss: 1.6698, Train Accuracy: 54.10%
#     Worker 2: Train Loss: 1.6589, Train Accuracy: 54.27%
#     Worker 3: Train Loss: 1.6787, Train Accuracy: 53.67%
# Total Computation Time: 1806.01 seconds
# Total Communication Time: 1.19 seconds
# Epoch 74/150: Test Loss: 1.9794, Test Accuracy: 48.83%
#     Worker 0: Train Loss: 1.6408, Train Accuracy: 54.24%
#     Worker 1: Train Loss: 1.6601, Train Accuracy: 54.17%
#     Worker 2: Train Loss: 1.6498, Train Accuracy: 54.68%
#     Worker 3: Train Loss: 1.6745, Train Accuracy: 53.93%
# Total Computation Time: 1830.50 seconds
# Total Communication Time: 1.21 seconds
# Epoch 75/150: Test Loss: 1.9643, Test Accuracy: 48.99%
#     Worker 0: Train Loss: 1.6692, Train Accuracy: 53.56%
#     Worker 1: Train Loss: 1.6764, Train Accuracy: 54.20%
#     Worker 2: Train Loss: 1.6399, Train Accuracy: 54.38%
#     Worker 3: Train Loss: 1.6485, Train Accuracy: 54.85%
# Total Computation Time: 1854.81 seconds
# Total Communication Time: 1.22 seconds
# Epoch 76/150: Test Loss: 1.9675, Test Accuracy: 48.92%
#     Worker 0: Train Loss: 1.6274, Train Accuracy: 55.03%
#     Worker 1: Train Loss: 1.6305, Train Accuracy: 54.97%
#     Worker 2: Train Loss: 1.6328, Train Accuracy: 54.67%
#     Worker 3: Train Loss: 1.6310, Train Accuracy: 54.79%
# Total Computation Time: 1879.40 seconds
# Total Communication Time: 1.24 seconds
# Epoch 77/150: Test Loss: 1.9642, Test Accuracy: 49.29%
#     Worker 0: Train Loss: 1.6449, Train Accuracy: 54.69%
#     Worker 1: Train Loss: 1.6385, Train Accuracy: 54.23%
#     Worker 2: Train Loss: 1.6118, Train Accuracy: 55.43%
#     Worker 3: Train Loss: 1.6318, Train Accuracy: 55.44%
# Total Computation Time: 1904.34 seconds
# Total Communication Time: 1.26 seconds
# Epoch 78/150: Test Loss: 1.9691, Test Accuracy: 49.15%
#     Worker 0: Train Loss: 1.6106, Train Accuracy: 55.22%
#     Worker 1: Train Loss: 1.6041, Train Accuracy: 55.72%
#     Worker 2: Train Loss: 1.6075, Train Accuracy: 55.67%
#     Worker 3: Train Loss: 1.6393, Train Accuracy: 54.54%
# Total Computation Time: 1928.68 seconds
# Total Communication Time: 1.27 seconds
# Epoch 79/150: Test Loss: 1.9634, Test Accuracy: 49.44%
#     Worker 0: Train Loss: 1.5920, Train Accuracy: 55.04%
#     Worker 1: Train Loss: 1.6144, Train Accuracy: 55.22%
#     Worker 2: Train Loss: 1.5827, Train Accuracy: 56.14%
#     Worker 3: Train Loss: 1.6238, Train Accuracy: 55.87%
# Total Computation Time: 1953.12 seconds
# Total Communication Time: 1.29 seconds
# Epoch 80/150: Test Loss: 1.9442, Test Accuracy: 49.84%
#     Worker 0: Train Loss: 1.5917, Train Accuracy: 55.74%
#     Worker 1: Train Loss: 1.5880, Train Accuracy: 55.80%
#     Worker 2: Train Loss: 1.5875, Train Accuracy: 55.83%
#     Worker 3: Train Loss: 1.5939, Train Accuracy: 55.91%
# Total Computation Time: 1977.45 seconds
# Total Communication Time: 1.31 seconds
# Epoch 81/150: Test Loss: 1.9550, Test Accuracy: 49.42%
#     Worker 0: Train Loss: 1.5797, Train Accuracy: 55.97%
#     Worker 1: Train Loss: 1.5913, Train Accuracy: 55.74%
#     Worker 2: Train Loss: 1.5633, Train Accuracy: 56.49%
#     Worker 3: Train Loss: 1.5894, Train Accuracy: 56.25%
# Total Computation Time: 2001.61 seconds
# Total Communication Time: 1.32 seconds
# Epoch 82/150: Test Loss: 1.9511, Test Accuracy: 49.85%
#     Worker 0: Train Loss: 1.5715, Train Accuracy: 56.13%
#     Worker 1: Train Loss: 1.5677, Train Accuracy: 57.19%
#     Worker 2: Train Loss: 1.5752, Train Accuracy: 56.46%
#     Worker 3: Train Loss: 1.5662, Train Accuracy: 56.52%
# Total Computation Time: 2026.57 seconds
# Total Communication Time: 1.34 seconds
# Epoch 83/150: Test Loss: 1.9545, Test Accuracy: 49.53%
#     Worker 0: Train Loss: 1.5596, Train Accuracy: 56.41%
#     Worker 1: Train Loss: 1.5556, Train Accuracy: 56.70%
#     Worker 2: Train Loss: 1.5608, Train Accuracy: 56.83%
#     Worker 3: Train Loss: 1.5615, Train Accuracy: 56.59%
# Total Computation Time: 2051.27 seconds
# Total Communication Time: 1.35 seconds
# Epoch 84/150: Test Loss: 1.9463, Test Accuracy: 49.65%
#     Worker 0: Train Loss: 1.5677, Train Accuracy: 55.67%
#     Worker 1: Train Loss: 1.5465, Train Accuracy: 56.79%
#     Worker 2: Train Loss: 1.5419, Train Accuracy: 57.44%
#     Worker 3: Train Loss: 1.5630, Train Accuracy: 57.12%
# Total Computation Time: 2075.87 seconds
# Total Communication Time: 1.37 seconds
# Epoch 85/150: Test Loss: 1.9596, Test Accuracy: 50.03%
#     Worker 0: Train Loss: 1.5406, Train Accuracy: 56.79%
#     Worker 1: Train Loss: 1.5484, Train Accuracy: 57.52%
#     Worker 2: Train Loss: 1.5345, Train Accuracy: 57.47%
#     Worker 3: Train Loss: 1.5458, Train Accuracy: 57.16%
# Total Computation Time: 2100.45 seconds
# Total Communication Time: 1.39 seconds
# Epoch 86/150: Test Loss: 1.9496, Test Accuracy: 49.40%
#     Worker 0: Train Loss: 1.5243, Train Accuracy: 57.31%
#     Worker 1: Train Loss: 1.5485, Train Accuracy: 56.99%
#     Worker 2: Train Loss: 1.5219, Train Accuracy: 57.72%
#     Worker 3: Train Loss: 1.5345, Train Accuracy: 57.11%
# Total Computation Time: 2125.11 seconds
# Total Communication Time: 1.40 seconds
# Epoch 87/150: Test Loss: 1.9511, Test Accuracy: 49.69%
#     Worker 0: Train Loss: 1.5291, Train Accuracy: 57.30%
#     Worker 1: Train Loss: 1.5051, Train Accuracy: 58.47%
#     Worker 2: Train Loss: 1.5186, Train Accuracy: 58.05%
#     Worker 3: Train Loss: 1.5287, Train Accuracy: 57.67%
# Total Computation Time: 2150.81 seconds
# Total Communication Time: 1.42 seconds
# Epoch 88/150: Test Loss: 1.9388, Test Accuracy: 50.33%
#     Worker 0: Train Loss: 1.5033, Train Accuracy: 57.75%
#     Worker 1: Train Loss: 1.5181, Train Accuracy: 57.66%
#     Worker 2: Train Loss: 1.5045, Train Accuracy: 58.32%
#     Worker 3: Train Loss: 1.5195, Train Accuracy: 57.50%
# Total Computation Time: 2175.40 seconds
# Total Communication Time: 1.44 seconds
# Epoch 89/150: Test Loss: 1.9381, Test Accuracy: 50.13%
#     Worker 0: Train Loss: 1.4942, Train Accuracy: 57.77%
#     Worker 1: Train Loss: 1.4845, Train Accuracy: 58.37%
#     Worker 2: Train Loss: 1.4972, Train Accuracy: 57.97%
#     Worker 3: Train Loss: 1.5216, Train Accuracy: 57.82%
# Total Computation Time: 2199.61 seconds
# Total Communication Time: 1.45 seconds
# Epoch 90/150: Test Loss: 1.9442, Test Accuracy: 50.29%
#     Worker 0: Train Loss: 1.4840, Train Accuracy: 58.31%
#     Worker 1: Train Loss: 1.4909, Train Accuracy: 58.21%
#     Worker 2: Train Loss: 1.4904, Train Accuracy: 58.22%
#     Worker 3: Train Loss: 1.4931, Train Accuracy: 58.37%
# Total Computation Time: 2223.97 seconds
# Total Communication Time: 1.47 seconds
# Epoch 91/150: Test Loss: 1.9490, Test Accuracy: 49.91%
#     Worker 0: Train Loss: 1.4824, Train Accuracy: 58.34%
#     Worker 1: Train Loss: 1.4823, Train Accuracy: 58.32%
#     Worker 2: Train Loss: 1.4852, Train Accuracy: 58.63%
#     Worker 3: Train Loss: 1.4941, Train Accuracy: 58.31%
# Total Computation Time: 2248.19 seconds
# Total Communication Time: 1.48 seconds
# Epoch 92/150: Test Loss: 1.9519, Test Accuracy: 49.77%
#     Worker 0: Train Loss: 1.4646, Train Accuracy: 58.86%
#     Worker 1: Train Loss: 1.4895, Train Accuracy: 58.37%
#     Worker 2: Train Loss: 1.4805, Train Accuracy: 58.93%
#     Worker 3: Train Loss: 1.4639, Train Accuracy: 58.93%
# Total Computation Time: 2272.43 seconds
# Total Communication Time: 1.50 seconds
# Epoch 93/150: Test Loss: 1.9465, Test Accuracy: 49.92%
#     Worker 0: Train Loss: 1.4629, Train Accuracy: 58.91%
#     Worker 1: Train Loss: 1.4617, Train Accuracy: 58.98%
#     Worker 2: Train Loss: 1.4504, Train Accuracy: 59.29%
#     Worker 3: Train Loss: 1.4694, Train Accuracy: 58.63%
# Total Computation Time: 2296.87 seconds
# Total Communication Time: 1.51 seconds
# Epoch 94/150: Test Loss: 1.9412, Test Accuracy: 50.12%
#     Worker 0: Train Loss: 1.4500, Train Accuracy: 58.95%
#     Worker 1: Train Loss: 1.4594, Train Accuracy: 58.93%
#     Worker 2: Train Loss: 1.4570, Train Accuracy: 59.03%
#     Worker 3: Train Loss: 1.4556, Train Accuracy: 59.67%
# Total Computation Time: 2321.22 seconds
# Total Communication Time: 1.53 seconds
# Epoch 95/150: Test Loss: 1.9545, Test Accuracy: 49.79%
#     Worker 0: Train Loss: 1.4368, Train Accuracy: 59.75%
#     Worker 1: Train Loss: 1.4396, Train Accuracy: 59.39%
#     Worker 2: Train Loss: 1.4454, Train Accuracy: 59.38%
#     Worker 3: Train Loss: 1.4591, Train Accuracy: 59.60%
# Total Computation Time: 2345.60 seconds
# Total Communication Time: 1.55 seconds
# Epoch 96/150: Test Loss: 1.9423, Test Accuracy: 49.93%
#     Worker 0: Train Loss: 1.4381, Train Accuracy: 59.50%
#     Worker 1: Train Loss: 1.4597, Train Accuracy: 59.51%
#     Worker 2: Train Loss: 1.4357, Train Accuracy: 59.27%
#     Worker 3: Train Loss: 1.4341, Train Accuracy: 59.80%
# Total Computation Time: 2370.33 seconds
# Total Communication Time: 1.56 seconds
# Epoch 97/150: Test Loss: 1.9417, Test Accuracy: 50.18%
#     Worker 0: Train Loss: 1.4220, Train Accuracy: 60.13%
#     Worker 1: Train Loss: 1.4263, Train Accuracy: 59.85%
#     Worker 2: Train Loss: 1.4321, Train Accuracy: 59.99%
#     Worker 3: Train Loss: 1.4195, Train Accuracy: 60.55%
# Total Computation Time: 2394.55 seconds
# Total Communication Time: 1.58 seconds
# Epoch 98/150: Test Loss: 1.9405, Test Accuracy: 50.32%
#     Worker 0: Train Loss: 1.4260, Train Accuracy: 59.26%
#     Worker 1: Train Loss: 1.4290, Train Accuracy: 60.32%
#     Worker 2: Train Loss: 1.4076, Train Accuracy: 60.24%
#     Worker 3: Train Loss: 1.4360, Train Accuracy: 59.94%
# Total Computation Time: 2419.36 seconds
# Total Communication Time: 1.59 seconds
# Epoch 99/150: Test Loss: 1.9477, Test Accuracy: 50.90%
#     Worker 0: Train Loss: 1.4199, Train Accuracy: 60.21%
#     Worker 1: Train Loss: 1.4024, Train Accuracy: 60.82%
#     Worker 2: Train Loss: 1.4064, Train Accuracy: 60.49%
#     Worker 3: Train Loss: 1.4224, Train Accuracy: 60.61%
# Total Computation Time: 2443.56 seconds
# Total Communication Time: 1.61 seconds
# Epoch 100/150: Test Loss: 1.9456, Test Accuracy: 50.57%
#     Worker 0: Train Loss: 1.3945, Train Accuracy: 60.32%
#     Worker 1: Train Loss: 1.4007, Train Accuracy: 60.53%
#     Worker 2: Train Loss: 1.3986, Train Accuracy: 61.14%
#     Worker 3: Train Loss: 1.4147, Train Accuracy: 60.51%
# Total Computation Time: 2467.66 seconds
# Total Communication Time: 1.62 seconds
# Epoch 101/150: Test Loss: 1.9487, Test Accuracy: 50.04%
#     Worker 0: Train Loss: 1.4003, Train Accuracy: 60.60%
#     Worker 1: Train Loss: 1.4056, Train Accuracy: 60.21%
#     Worker 2: Train Loss: 1.3871, Train Accuracy: 60.58%
#     Worker 3: Train Loss: 1.3989, Train Accuracy: 60.69%
# Total Computation Time: 2492.02 seconds
# Total Communication Time: 1.64 seconds
# Epoch 102/150: Test Loss: 1.9470, Test Accuracy: 49.98%
#     Worker 0: Train Loss: 1.3866, Train Accuracy: 60.66%
#     Worker 1: Train Loss: 1.3934, Train Accuracy: 60.48%
#     Worker 2: Train Loss: 1.3865, Train Accuracy: 61.00%
#     Worker 3: Train Loss: 1.3976, Train Accuracy: 60.76%
# Total Computation Time: 2516.25 seconds
# Total Communication Time: 1.65 seconds
# Epoch 103/150: Test Loss: 1.9408, Test Accuracy: 50.18%
#     Worker 0: Train Loss: 1.3804, Train Accuracy: 60.82%
#     Worker 1: Train Loss: 1.3601, Train Accuracy: 62.25%
#     Worker 2: Train Loss: 1.3718, Train Accuracy: 60.99%
#     Worker 3: Train Loss: 1.3853, Train Accuracy: 61.54%
# Total Computation Time: 2541.24 seconds
# Total Communication Time: 1.67 seconds
# Epoch 104/150: Test Loss: 1.9510, Test Accuracy: 50.54%
#     Worker 0: Train Loss: 1.3549, Train Accuracy: 61.68%
#     Worker 1: Train Loss: 1.3751, Train Accuracy: 61.41%
#     Worker 2: Train Loss: 1.3656, Train Accuracy: 61.69%
#     Worker 3: Train Loss: 1.3655, Train Accuracy: 61.98%
# Total Computation Time: 2565.53 seconds
# Total Communication Time: 1.69 seconds
# Epoch 105/150: Test Loss: 1.9418, Test Accuracy: 50.53%
#     Worker 0: Train Loss: 1.3779, Train Accuracy: 61.16%
#     Worker 1: Train Loss: 1.3563, Train Accuracy: 61.71%
#     Worker 2: Train Loss: 1.3771, Train Accuracy: 61.09%
#     Worker 3: Train Loss: 1.3878, Train Accuracy: 60.90%
# Total Computation Time: 2589.78 seconds
# Total Communication Time: 1.70 seconds
# Epoch 106/150: Test Loss: 1.9448, Test Accuracy: 50.23%
#     Worker 0: Train Loss: 1.3589, Train Accuracy: 61.38%
#     Worker 1: Train Loss: 1.3545, Train Accuracy: 61.46%
#     Worker 2: Train Loss: 1.3540, Train Accuracy: 61.81%
#     Worker 3: Train Loss: 1.3626, Train Accuracy: 61.54%
# Total Computation Time: 2614.09 seconds
# Total Communication Time: 1.72 seconds
# Epoch 107/150: Test Loss: 1.9541, Test Accuracy: 50.32%
#     Worker 0: Train Loss: 1.3637, Train Accuracy: 61.07%
#     Worker 1: Train Loss: 1.3551, Train Accuracy: 61.47%
#     Worker 2: Train Loss: 1.3560, Train Accuracy: 61.56%
#     Worker 3: Train Loss: 1.3709, Train Accuracy: 61.22%
# Total Computation Time: 2638.52 seconds
# Total Communication Time: 1.73 seconds
# Epoch 108/150: Test Loss: 1.9444, Test Accuracy: 50.74%
#     Worker 0: Train Loss: 1.3533, Train Accuracy: 62.03%
#     Worker 1: Train Loss: 1.3487, Train Accuracy: 61.95%
#     Worker 2: Train Loss: 1.3250, Train Accuracy: 62.84%
#     Worker 3: Train Loss: 1.3359, Train Accuracy: 62.48%
# Total Computation Time: 2663.44 seconds
# Total Communication Time: 1.75 seconds
# Epoch 109/150: Test Loss: 1.9443, Test Accuracy: 50.56%
#     Worker 0: Train Loss: 1.3313, Train Accuracy: 62.66%
#     Worker 1: Train Loss: 1.3281, Train Accuracy: 62.51%
#     Worker 2: Train Loss: 1.3291, Train Accuracy: 62.52%
#     Worker 3: Train Loss: 1.3586, Train Accuracy: 61.84%
# Total Computation Time: 2687.76 seconds
# Total Communication Time: 1.77 seconds
# Epoch 110/150: Test Loss: 1.9459, Test Accuracy: 50.60%
#     Worker 0: Train Loss: 1.3264, Train Accuracy: 62.30%
#     Worker 1: Train Loss: 1.3340, Train Accuracy: 62.62%
#     Worker 2: Train Loss: 1.3376, Train Accuracy: 62.44%
#     Worker 3: Train Loss: 1.3347, Train Accuracy: 62.78%
# Total Computation Time: 2712.02 seconds
# Total Communication Time: 1.78 seconds
# Epoch 111/150: Test Loss: 1.9560, Test Accuracy: 50.71%
#     Worker 0: Train Loss: 1.3114, Train Accuracy: 62.05%
#     Worker 1: Train Loss: 1.3163, Train Accuracy: 63.07%
#     Worker 2: Train Loss: 1.3067, Train Accuracy: 62.81%
#     Worker 3: Train Loss: 1.3423, Train Accuracy: 61.82%
# Total Computation Time: 2736.26 seconds
# Total Communication Time: 1.80 seconds
# Epoch 112/150: Test Loss: 1.9444, Test Accuracy: 50.73%
#     Worker 0: Train Loss: 1.3240, Train Accuracy: 62.66%
#     Worker 1: Train Loss: 1.3211, Train Accuracy: 62.70%
#     Worker 2: Train Loss: 1.3458, Train Accuracy: 62.26%
#     Worker 3: Train Loss: 1.3224, Train Accuracy: 63.18%
# Total Computation Time: 2760.51 seconds
# Total Communication Time: 1.81 seconds
# Epoch 113/150: Test Loss: 1.9508, Test Accuracy: 50.86%
#     Worker 0: Train Loss: 1.3182, Train Accuracy: 62.57%
#     Worker 1: Train Loss: 1.3156, Train Accuracy: 62.29%
#     Worker 2: Train Loss: 1.3020, Train Accuracy: 63.42%
#     Worker 3: Train Loss: 1.3164, Train Accuracy: 63.00%
# Total Computation Time: 2785.40 seconds
# Total Communication Time: 1.83 seconds
# Epoch 114/150: Test Loss: 1.9479, Test Accuracy: 50.90%
#     Worker 0: Train Loss: 1.2954, Train Accuracy: 63.16%
#     Worker 1: Train Loss: 1.3177, Train Accuracy: 63.19%
#     Worker 2: Train Loss: 1.3007, Train Accuracy: 62.91%
#     Worker 3: Train Loss: 1.3054, Train Accuracy: 63.23%
# Total Computation Time: 2809.64 seconds
# Total Communication Time: 1.84 seconds
# Epoch 115/150: Test Loss: 1.9472, Test Accuracy: 50.68%
#     Worker 0: Train Loss: 1.2885, Train Accuracy: 62.77%
#     Worker 1: Train Loss: 1.2847, Train Accuracy: 63.47%
#     Worker 2: Train Loss: 1.2879, Train Accuracy: 63.00%
#     Worker 3: Train Loss: 1.3095, Train Accuracy: 63.09%
# Total Computation Time: 2833.88 seconds
# Total Communication Time: 1.86 seconds
# Epoch 116/150: Test Loss: 1.9553, Test Accuracy: 50.61%
#     Worker 0: Train Loss: 1.3022, Train Accuracy: 62.89%
#     Worker 1: Train Loss: 1.2965, Train Accuracy: 63.34%
#     Worker 2: Train Loss: 1.3015, Train Accuracy: 63.45%
#     Worker 3: Train Loss: 1.2900, Train Accuracy: 63.50%
# Total Computation Time: 2858.46 seconds
# Total Communication Time: 1.87 seconds
# Epoch 117/150: Test Loss: 1.9560, Test Accuracy: 50.53%
#     Worker 0: Train Loss: 1.2749, Train Accuracy: 64.37%
#     Worker 1: Train Loss: 1.2877, Train Accuracy: 63.65%
#     Worker 2: Train Loss: 1.2761, Train Accuracy: 63.83%
#     Worker 3: Train Loss: 1.3003, Train Accuracy: 63.71%
# Total Computation Time: 2882.83 seconds
# Total Communication Time: 1.89 seconds
# Epoch 118/150: Test Loss: 1.9545, Test Accuracy: 50.67%
#     Worker 0: Train Loss: 1.2895, Train Accuracy: 63.17%
#     Worker 1: Train Loss: 1.2952, Train Accuracy: 63.41%
#     Worker 2: Train Loss: 1.2724, Train Accuracy: 64.00%
#     Worker 3: Train Loss: 1.3034, Train Accuracy: 63.23%
# Total Computation Time: 2908.36 seconds
# Total Communication Time: 1.91 seconds
# Epoch 119/150: Test Loss: 1.9550, Test Accuracy: 50.80%
#     Worker 0: Train Loss: 1.2805, Train Accuracy: 63.83%
#     Worker 1: Train Loss: 1.2796, Train Accuracy: 63.72%
#     Worker 2: Train Loss: 1.2659, Train Accuracy: 64.24%
#     Worker 3: Train Loss: 1.2887, Train Accuracy: 63.39%
# Total Computation Time: 2932.83 seconds
# Total Communication Time: 1.92 seconds
# Epoch 120/150: Test Loss: 1.9596, Test Accuracy: 50.77%
#     Worker 0: Train Loss: 1.2673, Train Accuracy: 63.65%
#     Worker 1: Train Loss: 1.2698, Train Accuracy: 64.18%
#     Worker 2: Train Loss: 1.2761, Train Accuracy: 64.24%
#     Worker 3: Train Loss: 1.2854, Train Accuracy: 63.81%
# Total Computation Time: 2957.20 seconds
# Total Communication Time: 1.94 seconds
# Epoch 121/150: Test Loss: 1.9563, Test Accuracy: 50.65%
#     Worker 0: Train Loss: 1.2694, Train Accuracy: 63.79%
#     Worker 1: Train Loss: 1.2737, Train Accuracy: 63.91%
#     Worker 2: Train Loss: 1.2501, Train Accuracy: 64.52%
#     Worker 3: Train Loss: 1.2582, Train Accuracy: 64.21%
# Total Computation Time: 2981.63 seconds
# Total Communication Time: 1.95 seconds
# Epoch 122/150: Test Loss: 1.9598, Test Accuracy: 51.00%
#     Worker 0: Train Loss: 1.2612, Train Accuracy: 64.08%
#     Worker 1: Train Loss: 1.2644, Train Accuracy: 64.55%
#     Worker 2: Train Loss: 1.2747, Train Accuracy: 63.93%
#     Worker 3: Train Loss: 1.2636, Train Accuracy: 64.29%
# Total Computation Time: 3006.09 seconds
# Total Communication Time: 1.97 seconds
# Epoch 123/150: Test Loss: 1.9565, Test Accuracy: 50.77%
#     Worker 0: Train Loss: 1.2658, Train Accuracy: 63.95%
#     Worker 1: Train Loss: 1.2442, Train Accuracy: 64.51%
#     Worker 2: Train Loss: 1.2573, Train Accuracy: 64.61%
#     Worker 3: Train Loss: 1.2714, Train Accuracy: 64.17%
# Total Computation Time: 3031.25 seconds
# Total Communication Time: 1.99 seconds
# Epoch 124/150: Test Loss: 1.9572, Test Accuracy: 50.92%
#     Worker 0: Train Loss: 1.2482, Train Accuracy: 64.53%
#     Worker 1: Train Loss: 1.2702, Train Accuracy: 64.19%
#     Worker 2: Train Loss: 1.2456, Train Accuracy: 64.87%
#     Worker 3: Train Loss: 1.2821, Train Accuracy: 64.36%
# Total Computation Time: 3055.57 seconds
# Total Communication Time: 2.00 seconds
# Epoch 125/150: Test Loss: 1.9601, Test Accuracy: 50.83%
#     Worker 0: Train Loss: 1.2323, Train Accuracy: 64.39%
#     Worker 1: Train Loss: 1.2658, Train Accuracy: 64.00%
#     Worker 2: Train Loss: 1.2467, Train Accuracy: 65.19%
#     Worker 3: Train Loss: 1.2482, Train Accuracy: 64.86%
# Total Computation Time: 3080.12 seconds
# Total Communication Time: 2.02 seconds
# Epoch 126/150: Test Loss: 1.9542, Test Accuracy: 50.87%
#     Worker 0: Train Loss: 1.2761, Train Accuracy: 63.85%
#     Worker 1: Train Loss: 1.2454, Train Accuracy: 64.71%
#     Worker 2: Train Loss: 1.2478, Train Accuracy: 64.86%
#     Worker 3: Train Loss: 1.2630, Train Accuracy: 64.50%
# Total Computation Time: 3105.50 seconds
# Total Communication Time: 2.04 seconds
# Epoch 127/150: Test Loss: 1.9531, Test Accuracy: 50.90%
#     Worker 0: Train Loss: 1.2371, Train Accuracy: 64.64%
#     Worker 1: Train Loss: 1.2625, Train Accuracy: 64.55%
#     Worker 2: Train Loss: 1.2372, Train Accuracy: 65.21%
#     Worker 3: Train Loss: 1.2381, Train Accuracy: 64.98%
# Total Computation Time: 3130.34 seconds
# Total Communication Time: 2.05 seconds
# Epoch 128/150: Test Loss: 1.9580, Test Accuracy: 51.05%
#     Worker 0: Train Loss: 1.2475, Train Accuracy: 64.81%
#     Worker 1: Train Loss: 1.2215, Train Accuracy: 65.28%
#     Worker 2: Train Loss: 1.2294, Train Accuracy: 65.49%
#     Worker 3: Train Loss: 1.2489, Train Accuracy: 64.78%
# Total Computation Time: 3155.97 seconds
# Total Communication Time: 2.07 seconds
# Epoch 129/150: Test Loss: 1.9589, Test Accuracy: 51.07%
#     Worker 0: Train Loss: 1.2452, Train Accuracy: 64.24%
#     Worker 1: Train Loss: 1.2470, Train Accuracy: 64.73%
#     Worker 2: Train Loss: 1.2386, Train Accuracy: 65.39%
#     Worker 3: Train Loss: 1.2619, Train Accuracy: 64.09%
# Total Computation Time: 3180.77 seconds
# Total Communication Time: 2.09 seconds
# Epoch 130/150: Test Loss: 1.9581, Test Accuracy: 51.00%
#     Worker 0: Train Loss: 1.2323, Train Accuracy: 65.13%
#     Worker 1: Train Loss: 1.2328, Train Accuracy: 65.26%
#     Worker 2: Train Loss: 1.2411, Train Accuracy: 65.37%
#     Worker 3: Train Loss: 1.2349, Train Accuracy: 64.95%
# Total Computation Time: 3205.22 seconds
# Total Communication Time: 2.10 seconds
# Epoch 131/150: Test Loss: 1.9568, Test Accuracy: 50.87%
#     Worker 0: Train Loss: 1.2366, Train Accuracy: 65.04%
#     Worker 1: Train Loss: 1.2388, Train Accuracy: 65.15%
#     Worker 2: Train Loss: 1.2387, Train Accuracy: 65.30%
#     Worker 3: Train Loss: 1.2371, Train Accuracy: 65.04%
# Total Computation Time: 3229.94 seconds
# Total Communication Time: 2.12 seconds
# Epoch 132/150: Test Loss: 1.9580, Test Accuracy: 50.86%
#     Worker 0: Train Loss: 1.2289, Train Accuracy: 64.80%
#     Worker 1: Train Loss: 1.2248, Train Accuracy: 64.98%
#     Worker 2: Train Loss: 1.2379, Train Accuracy: 64.69%
#     Worker 3: Train Loss: 1.2372, Train Accuracy: 64.67%
# Total Computation Time: 3254.38 seconds
# Total Communication Time: 2.13 seconds
# Epoch 133/150: Test Loss: 1.9561, Test Accuracy: 50.74%
#     Worker 0: Train Loss: 1.2448, Train Accuracy: 64.31%
#     Worker 1: Train Loss: 1.2375, Train Accuracy: 65.09%
#     Worker 2: Train Loss: 1.2293, Train Accuracy: 65.19%
#     Worker 3: Train Loss: 1.2374, Train Accuracy: 65.16%
# Total Computation Time: 3279.54 seconds
# Total Communication Time: 2.15 seconds
# Epoch 134/150: Test Loss: 1.9579, Test Accuracy: 50.71%
#     Worker 0: Train Loss: 1.2223, Train Accuracy: 65.32%
#     Worker 1: Train Loss: 1.2250, Train Accuracy: 65.54%
#     Worker 2: Train Loss: 1.2330, Train Accuracy: 65.29%
#     Worker 3: Train Loss: 1.2555, Train Accuracy: 64.95%
# Total Computation Time: 3304.09 seconds
# Total Communication Time: 2.17 seconds
# Epoch 135/150: Test Loss: 1.9574, Test Accuracy: 50.89%
#     Worker 0: Train Loss: 1.2242, Train Accuracy: 65.35%
#     Worker 1: Train Loss: 1.2128, Train Accuracy: 66.02%
#     Worker 2: Train Loss: 1.2149, Train Accuracy: 65.47%
#     Worker 3: Train Loss: 1.2391, Train Accuracy: 65.00%
# Total Computation Time: 3328.49 seconds
# Total Communication Time: 2.18 seconds
# Epoch 136/150: Test Loss: 1.9605, Test Accuracy: 51.19%
#     Worker 0: Train Loss: 1.2237, Train Accuracy: 64.95%
#     Worker 1: Train Loss: 1.2213, Train Accuracy: 65.29%
#     Worker 2: Train Loss: 1.2393, Train Accuracy: 65.02%
#     Worker 3: Train Loss: 1.2020, Train Accuracy: 66.03%
# Total Computation Time: 3353.11 seconds
# Total Communication Time: 2.20 seconds
# Epoch 137/150: Test Loss: 1.9578, Test Accuracy: 50.88%
#     Worker 0: Train Loss: 1.2020, Train Accuracy: 65.71%
#     Worker 1: Train Loss: 1.2012, Train Accuracy: 65.80%
#     Worker 2: Train Loss: 1.2377, Train Accuracy: 64.64%
#     Worker 3: Train Loss: 1.2389, Train Accuracy: 65.26%
# Total Computation Time: 3377.84 seconds
# Total Communication Time: 2.22 seconds
# Epoch 138/150: Test Loss: 1.9566, Test Accuracy: 50.90%
#     Worker 0: Train Loss: 1.2352, Train Accuracy: 65.21%
#     Worker 1: Train Loss: 1.2298, Train Accuracy: 64.99%
#     Worker 2: Train Loss: 1.2131, Train Accuracy: 65.65%
#     Worker 3: Train Loss: 1.2050, Train Accuracy: 65.91%
# Total Computation Time: 3403.63 seconds
# Total Communication Time: 2.23 seconds
# Epoch 139/150: Test Loss: 1.9573, Test Accuracy: 51.04%
#     Worker 0: Train Loss: 1.2197, Train Accuracy: 65.66%
#     Worker 1: Train Loss: 1.2052, Train Accuracy: 66.06%
#     Worker 2: Train Loss: 1.2412, Train Accuracy: 65.41%
#     Worker 3: Train Loss: 1.2139, Train Accuracy: 65.53%
# Total Computation Time: 3428.77 seconds
# Total Communication Time: 2.25 seconds
# Epoch 140/150: Test Loss: 1.9579, Test Accuracy: 50.84%
#     Worker 0: Train Loss: 1.2140, Train Accuracy: 65.10%
#     Worker 1: Train Loss: 1.2146, Train Accuracy: 65.70%
#     Worker 2: Train Loss: 1.2193, Train Accuracy: 65.46%
#     Worker 3: Train Loss: 1.2244, Train Accuracy: 65.25%
# Total Computation Time: 3453.79 seconds
# Total Communication Time: 2.26 seconds
# Epoch 141/150: Test Loss: 1.9580, Test Accuracy: 50.86%
#     Worker 0: Train Loss: 1.2196, Train Accuracy: 65.47%
#     Worker 1: Train Loss: 1.2208, Train Accuracy: 65.54%
#     Worker 2: Train Loss: 1.2178, Train Accuracy: 65.42%
#     Worker 3: Train Loss: 1.2124, Train Accuracy: 65.93%
# Total Computation Time: 3479.24 seconds
# Total Communication Time: 2.28 seconds
# Epoch 142/150: Test Loss: 1.9586, Test Accuracy: 50.91%
#     Worker 0: Train Loss: 1.2050, Train Accuracy: 65.64%
#     Worker 1: Train Loss: 1.2002, Train Accuracy: 66.14%
#     Worker 2: Train Loss: 1.2232, Train Accuracy: 65.35%
#     Worker 3: Train Loss: 1.2240, Train Accuracy: 65.65%
# Total Computation Time: 3504.60 seconds
# Total Communication Time: 2.30 seconds
# Epoch 143/150: Test Loss: 1.9580, Test Accuracy: 51.07%
#     Worker 0: Train Loss: 1.2097, Train Accuracy: 66.04%
#     Worker 1: Train Loss: 1.2211, Train Accuracy: 65.29%
#     Worker 2: Train Loss: 1.2089, Train Accuracy: 66.03%
#     Worker 3: Train Loss: 1.2355, Train Accuracy: 64.72%
# Total Computation Time: 3530.46 seconds
# Total Communication Time: 2.31 seconds
# Epoch 144/150: Test Loss: 1.9583, Test Accuracy: 51.02%
#     Worker 0: Train Loss: 1.2175, Train Accuracy: 65.52%
#     Worker 1: Train Loss: 1.2192, Train Accuracy: 65.77%
#     Worker 2: Train Loss: 1.2204, Train Accuracy: 65.26%
#     Worker 3: Train Loss: 1.2091, Train Accuracy: 66.11%
# Total Computation Time: 3555.39 seconds
# Total Communication Time: 2.33 seconds
# Epoch 145/150: Test Loss: 1.9580, Test Accuracy: 50.96%
#     Worker 0: Train Loss: 1.2049, Train Accuracy: 65.46%
#     Worker 1: Train Loss: 1.2119, Train Accuracy: 65.24%
#     Worker 2: Train Loss: 1.2201, Train Accuracy: 66.02%
#     Worker 3: Train Loss: 1.2204, Train Accuracy: 65.66%
# Total Computation Time: 3580.28 seconds
# Total Communication Time: 2.35 seconds
# Epoch 146/150: Test Loss: 1.9579, Test Accuracy: 51.00%
#     Worker 0: Train Loss: 1.2192, Train Accuracy: 65.32%
#     Worker 1: Train Loss: 1.2108, Train Accuracy: 65.52%
#     Worker 2: Train Loss: 1.2091, Train Accuracy: 65.99%
#     Worker 3: Train Loss: 1.2274, Train Accuracy: 65.28%
# Total Computation Time: 3605.24 seconds
# Total Communication Time: 2.36 seconds
# Epoch 147/150: Test Loss: 1.9577, Test Accuracy: 50.98%
#     Worker 0: Train Loss: 1.2074, Train Accuracy: 65.72%
#     Worker 1: Train Loss: 1.2180, Train Accuracy: 65.60%
#     Worker 2: Train Loss: 1.2166, Train Accuracy: 65.69%
#     Worker 3: Train Loss: 1.2317, Train Accuracy: 65.39%
# Total Computation Time: 3630.13 seconds
# Total Communication Time: 2.38 seconds
# Epoch 148/150: Test Loss: 1.9577, Test Accuracy: 50.99%
#     Worker 0: Train Loss: 1.2060, Train Accuracy: 65.65%
#     Worker 1: Train Loss: 1.2094, Train Accuracy: 66.26%
#     Worker 2: Train Loss: 1.2060, Train Accuracy: 65.47%
#     Worker 3: Train Loss: 1.2186, Train Accuracy: 65.87%
# Total Computation Time: 3655.92 seconds
# Total Communication Time: 2.39 seconds
# Epoch 149/150: Test Loss: 1.9577, Test Accuracy: 51.00%
#     Worker 0: Train Loss: 1.2225, Train Accuracy: 64.98%
#     Worker 1: Train Loss: 1.2222, Train Accuracy: 65.47%
#     Worker 2: Train Loss: 1.2158, Train Accuracy: 65.59%
#     Worker 3: Train Loss: 1.2250, Train Accuracy: 65.48%
# Total Computation Time: 3681.01 seconds
# Total Communication Time: 2.41 seconds
# Epoch 150/150: Test Loss: 1.9577, Test Accuracy: 51.01%
#     Worker 0: Train Loss: 1.2028, Train Accuracy: 65.34%
#     Worker 1: Train Loss: 1.2095, Train Accuracy: 65.99%
#     Worker 2: Train Loss: 1.2139, Train Accuracy: 65.23%
#     Worker 3: Train Loss: 1.1955, Train Accuracy: 66.54%
# Total Computation Time: 3706.18 seconds
# Total Communication Time: 2.43 seconds
