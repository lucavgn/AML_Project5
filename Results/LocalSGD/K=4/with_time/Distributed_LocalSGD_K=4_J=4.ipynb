# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files
import time

total_computation_time = 0
total_communication_time = 0

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
#warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")

    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch):
        computation_start_time = time.time()
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            # Perform J local step before synchronization
            for j in range(J):
                try:
                    # Get a batch from the current worker's shard using next()
                    images, labels = next(shard_iterators[k])
                    images, labels = images.to(device), labels.to(device)  # Move to device
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

                except StopIteration:
                    # If the iterator has exhausted the data, restart the iterator
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k]) # Resume from the next batch
                    images, labels = images.to(device), labels.to(device)
                    # Perform optimization step
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        computation_end_time = time.time()
        total_computation_time += (computation_end_time - computation_start_time)

        communication_start_time = time.time()
        # Perform model synchronization
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            # Update each worker model with the global parameters
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

        communication_end_time = time.time()
        total_communication_time += (communication_end_time - communication_start_time)

    # Update lr for each scheduler
    for scheduler in schedulers:
       # if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
       # else:
        #    warmup_factor = (epoch + 1) / warmup_epochs
          #  lr = warmup_factor * learning_rate
          #  for optimizer in optimizers:
           #     for param_group in optimizer.param_groups:
            #        param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

    print(f"Total Computation Time: {total_computation_time:.2f} seconds")
    print(f"Total Communication Time: {total_communication_time:.2f} seconds")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 4 --j 4
# Out:
# Training with K=4, J=4
# Global iteration per epoch: 49
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:04<00:00, 35.3MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00400
# Epoch 1/150: Test Loss: 4.5811, Test Accuracy: 2.90%
#     Worker 0: Train Loss: 4.5986, Train Accuracy: 1.50%
#     Worker 1: Train Loss: 4.5998, Train Accuracy: 1.31%
#     Worker 2: Train Loss: 4.5984, Train Accuracy: 1.47%
#     Worker 3: Train Loss: 4.5989, Train Accuracy: 1.35%
# Total Computation Time: 24.95 seconds
# Total Communication Time: 0.08 seconds
# Epoch 2/150: Test Loss: 4.1933, Test Accuracy: 6.30%
#     Worker 0: Train Loss: 4.4606, Train Accuracy: 3.62%
#     Worker 1: Train Loss: 4.4605, Train Accuracy: 3.50%
#     Worker 2: Train Loss: 4.4472, Train Accuracy: 3.79%
#     Worker 3: Train Loss: 4.4559, Train Accuracy: 3.60%
# Total Computation Time: 49.05 seconds
# Total Communication Time: 0.14 seconds
# Epoch 3/150: Test Loss: 3.9497, Test Accuracy: 9.91%
#     Worker 0: Train Loss: 4.1081, Train Accuracy: 6.87%
#     Worker 1: Train Loss: 4.1141, Train Accuracy: 7.18%
#     Worker 2: Train Loss: 4.0751, Train Accuracy: 7.59%
#     Worker 3: Train Loss: 4.1106, Train Accuracy: 7.29%
# Total Computation Time: 73.92 seconds
# Total Communication Time: 0.21 seconds
# Epoch 4/150: Test Loss: 3.8102, Test Accuracy: 12.31%
#     Worker 0: Train Loss: 3.9405, Train Accuracy: 9.42%
#     Worker 1: Train Loss: 3.9393, Train Accuracy: 9.66%
#     Worker 2: Train Loss: 3.8999, Train Accuracy: 10.58%
#     Worker 3: Train Loss: 3.9289, Train Accuracy: 10.15%
# Total Computation Time: 97.36 seconds
# Total Communication Time: 0.27 seconds
# Epoch 5/150: Test Loss: 3.6578, Test Accuracy: 15.07%
#     Worker 0: Train Loss: 3.8149, Train Accuracy: 11.62%
#     Worker 1: Train Loss: 3.8119, Train Accuracy: 11.78%
#     Worker 2: Train Loss: 3.7650, Train Accuracy: 12.76%
#     Worker 3: Train Loss: 3.8042, Train Accuracy: 11.85%
# Total Computation Time: 120.60 seconds
# Total Communication Time: 0.33 seconds
# Epoch 6/150: Test Loss: 3.5567, Test Accuracy: 16.69%
#     Worker 0: Train Loss: 3.6974, Train Accuracy: 13.76%
#     Worker 1: Train Loss: 3.7011, Train Accuracy: 13.74%
#     Worker 2: Train Loss: 3.6507, Train Accuracy: 14.83%
#     Worker 3: Train Loss: 3.6953, Train Accuracy: 13.62%
# Total Computation Time: 143.94 seconds
# Total Communication Time: 0.39 seconds
# Epoch 7/150: Test Loss: 3.4715, Test Accuracy: 17.90%
#     Worker 0: Train Loss: 3.5916, Train Accuracy: 15.38%
#     Worker 1: Train Loss: 3.6040, Train Accuracy: 15.62%
#     Worker 2: Train Loss: 3.5467, Train Accuracy: 15.94%
#     Worker 3: Train Loss: 3.5956, Train Accuracy: 15.17%
# Total Computation Time: 167.69 seconds
# Total Communication Time: 0.45 seconds
# Epoch 8/150: Test Loss: 3.3816, Test Accuracy: 20.05%
#     Worker 0: Train Loss: 3.5022, Train Accuracy: 16.53%
#     Worker 1: Train Loss: 3.5097, Train Accuracy: 16.76%
#     Worker 2: Train Loss: 3.4566, Train Accuracy: 17.97%
#     Worker 3: Train Loss: 3.5112, Train Accuracy: 16.64%
# Total Computation Time: 191.22 seconds
# Total Communication Time: 0.52 seconds
# Epoch 9/150: Test Loss: 3.3022, Test Accuracy: 21.31%
#     Worker 0: Train Loss: 3.4066, Train Accuracy: 18.34%
#     Worker 1: Train Loss: 3.4167, Train Accuracy: 18.35%
#     Worker 2: Train Loss: 3.3635, Train Accuracy: 19.67%
#     Worker 3: Train Loss: 3.4166, Train Accuracy: 18.16%
# Total Computation Time: 214.37 seconds
# Total Communication Time: 0.58 seconds
# Epoch 10/150: Test Loss: 3.2124, Test Accuracy: 22.53%
#     Worker 0: Train Loss: 3.3191, Train Accuracy: 20.00%
#     Worker 1: Train Loss: 3.3457, Train Accuracy: 19.50%
#     Worker 2: Train Loss: 3.2885, Train Accuracy: 20.85%
#     Worker 3: Train Loss: 3.3523, Train Accuracy: 19.14%
# Total Computation Time: 237.30 seconds
# Total Communication Time: 0.63 seconds
# Epoch 11/150: Test Loss: 3.1300, Test Accuracy: 23.67%
#     Worker 0: Train Loss: 3.2607, Train Accuracy: 20.58%
#     Worker 1: Train Loss: 3.2752, Train Accuracy: 20.79%
#     Worker 2: Train Loss: 3.2188, Train Accuracy: 22.03%
#     Worker 3: Train Loss: 3.2637, Train Accuracy: 21.22%
# Total Computation Time: 260.61 seconds
# Total Communication Time: 0.69 seconds
# Epoch 12/150: Test Loss: 3.0478, Test Accuracy: 25.34%
#     Worker 0: Train Loss: 3.1765, Train Accuracy: 22.02%
#     Worker 1: Train Loss: 3.1930, Train Accuracy: 22.71%
#     Worker 2: Train Loss: 3.1383, Train Accuracy: 23.61%
#     Worker 3: Train Loss: 3.1796, Train Accuracy: 22.22%
# Total Computation Time: 284.12 seconds
# Total Communication Time: 0.75 seconds
# Epoch 13/150: Test Loss: 3.0014, Test Accuracy: 25.98%
#     Worker 0: Train Loss: 3.1148, Train Accuracy: 23.75%
#     Worker 1: Train Loss: 3.1291, Train Accuracy: 23.61%
#     Worker 2: Train Loss: 3.0821, Train Accuracy: 24.35%
#     Worker 3: Train Loss: 3.1239, Train Accuracy: 23.57%
# Total Computation Time: 307.42 seconds
# Total Communication Time: 0.81 seconds
# Epoch 14/150: Test Loss: 2.9367, Test Accuracy: 27.55%
#     Worker 0: Train Loss: 3.0486, Train Accuracy: 24.70%
#     Worker 1: Train Loss: 3.0834, Train Accuracy: 24.62%
#     Worker 2: Train Loss: 3.0103, Train Accuracy: 26.05%
#     Worker 3: Train Loss: 3.0783, Train Accuracy: 24.14%
# Total Computation Time: 330.73 seconds
# Total Communication Time: 0.87 seconds
# Epoch 15/150: Test Loss: 2.8833, Test Accuracy: 28.80%
#     Worker 0: Train Loss: 2.9937, Train Accuracy: 25.90%
#     Worker 1: Train Loss: 3.0338, Train Accuracy: 25.09%
#     Worker 2: Train Loss: 2.9627, Train Accuracy: 26.46%
#     Worker 3: Train Loss: 3.0245, Train Accuracy: 25.56%
# Total Computation Time: 354.20 seconds
# Total Communication Time: 0.93 seconds
# Epoch 16/150: Test Loss: 2.8288, Test Accuracy: 29.84%
#     Worker 0: Train Loss: 2.9423, Train Accuracy: 27.06%
#     Worker 1: Train Loss: 2.9776, Train Accuracy: 26.54%
#     Worker 2: Train Loss: 2.9082, Train Accuracy: 27.23%
#     Worker 3: Train Loss: 2.9663, Train Accuracy: 26.65%
# Total Computation Time: 377.81 seconds
# Total Communication Time: 0.99 seconds
# Epoch 17/150: Test Loss: 2.7724, Test Accuracy: 30.96%
#     Worker 0: Train Loss: 2.9051, Train Accuracy: 27.52%
#     Worker 1: Train Loss: 2.9245, Train Accuracy: 27.60%
#     Worker 2: Train Loss: 2.8666, Train Accuracy: 28.27%
#     Worker 3: Train Loss: 2.9080, Train Accuracy: 27.15%
# Total Computation Time: 401.39 seconds
# Total Communication Time: 1.05 seconds
# Epoch 18/150: Test Loss: 2.7953, Test Accuracy: 30.38%
#     Worker 0: Train Loss: 2.8500, Train Accuracy: 28.67%
#     Worker 1: Train Loss: 2.8836, Train Accuracy: 28.47%
#     Worker 2: Train Loss: 2.8222, Train Accuracy: 29.62%
#     Worker 3: Train Loss: 2.8597, Train Accuracy: 28.45%
# Total Computation Time: 424.83 seconds
# Total Communication Time: 1.10 seconds
# Epoch 19/150: Test Loss: 2.7088, Test Accuracy: 31.82%
#     Worker 0: Train Loss: 2.7948, Train Accuracy: 29.45%
#     Worker 1: Train Loss: 2.8247, Train Accuracy: 29.04%
#     Worker 2: Train Loss: 2.7644, Train Accuracy: 30.74%
#     Worker 3: Train Loss: 2.8118, Train Accuracy: 29.47%
# Total Computation Time: 448.12 seconds
# Total Communication Time: 1.16 seconds
# Epoch 20/150: Test Loss: 2.6355, Test Accuracy: 33.45%
#     Worker 0: Train Loss: 2.7617, Train Accuracy: 30.44%
#     Worker 1: Train Loss: 2.7867, Train Accuracy: 29.70%
#     Worker 2: Train Loss: 2.7346, Train Accuracy: 31.53%
#     Worker 3: Train Loss: 2.7765, Train Accuracy: 29.93%
# Total Computation Time: 471.11 seconds
# Total Communication Time: 1.22 seconds
# Epoch 21/150: Test Loss: 2.5928, Test Accuracy: 34.13%
#     Worker 0: Train Loss: 2.7134, Train Accuracy: 31.13%
#     Worker 1: Train Loss: 2.7332, Train Accuracy: 31.47%
#     Worker 2: Train Loss: 2.6730, Train Accuracy: 32.64%
#     Worker 3: Train Loss: 2.7096, Train Accuracy: 31.07%
# Total Computation Time: 494.64 seconds
# Total Communication Time: 1.28 seconds
# Epoch 22/150: Test Loss: 2.5917, Test Accuracy: 33.85%
#     Worker 0: Train Loss: 2.6639, Train Accuracy: 32.63%
#     Worker 1: Train Loss: 2.6830, Train Accuracy: 32.13%
#     Worker 2: Train Loss: 2.6350, Train Accuracy: 33.14%
#     Worker 3: Train Loss: 2.6829, Train Accuracy: 32.18%
# Total Computation Time: 518.33 seconds
# Total Communication Time: 1.34 seconds
# Epoch 23/150: Test Loss: 2.5289, Test Accuracy: 35.84%
#     Worker 0: Train Loss: 2.6251, Train Accuracy: 32.94%
#     Worker 1: Train Loss: 2.6431, Train Accuracy: 33.04%
#     Worker 2: Train Loss: 2.5954, Train Accuracy: 34.06%
#     Worker 3: Train Loss: 2.6457, Train Accuracy: 32.63%
# Total Computation Time: 542.09 seconds
# Total Communication Time: 1.40 seconds
# Epoch 24/150: Test Loss: 2.4970, Test Accuracy: 35.93%
#     Worker 0: Train Loss: 2.5735, Train Accuracy: 33.97%
#     Worker 1: Train Loss: 2.6029, Train Accuracy: 33.69%
#     Worker 2: Train Loss: 2.5541, Train Accuracy: 34.89%
#     Worker 3: Train Loss: 2.6077, Train Accuracy: 33.65%
# Total Computation Time: 565.57 seconds
# Total Communication Time: 1.46 seconds
# Epoch 25/150: Test Loss: 2.4710, Test Accuracy: 37.38%
#     Worker 0: Train Loss: 2.5622, Train Accuracy: 34.42%
#     Worker 1: Train Loss: 2.5744, Train Accuracy: 34.22%
#     Worker 2: Train Loss: 2.5193, Train Accuracy: 35.02%
#     Worker 3: Train Loss: 2.5550, Train Accuracy: 34.14%
# Total Computation Time: 588.78 seconds
# Total Communication Time: 1.52 seconds
# Epoch 26/150: Test Loss: 2.4264, Test Accuracy: 38.01%
#     Worker 0: Train Loss: 2.5184, Train Accuracy: 35.26%
#     Worker 1: Train Loss: 2.5273, Train Accuracy: 34.98%
#     Worker 2: Train Loss: 2.4918, Train Accuracy: 36.58%
#     Worker 3: Train Loss: 2.5297, Train Accuracy: 35.54%
# Total Computation Time: 612.11 seconds
# Total Communication Time: 1.58 seconds
# Epoch 27/150: Test Loss: 2.3998, Test Accuracy: 38.16%
#     Worker 0: Train Loss: 2.4721, Train Accuracy: 36.52%
#     Worker 1: Train Loss: 2.4948, Train Accuracy: 36.51%
#     Worker 2: Train Loss: 2.4586, Train Accuracy: 37.03%
#     Worker 3: Train Loss: 2.4771, Train Accuracy: 35.54%
# Total Computation Time: 635.23 seconds
# Total Communication Time: 1.64 seconds
# Epoch 28/150: Test Loss: 2.4255, Test Accuracy: 37.52%
#     Worker 0: Train Loss: 2.4468, Train Accuracy: 36.61%
#     Worker 1: Train Loss: 2.4457, Train Accuracy: 37.08%
#     Worker 2: Train Loss: 2.4270, Train Accuracy: 37.55%
#     Worker 3: Train Loss: 2.4562, Train Accuracy: 36.26%
# Total Computation Time: 658.44 seconds
# Total Communication Time: 1.70 seconds
# Epoch 29/150: Test Loss: 2.3806, Test Accuracy: 38.96%
#     Worker 0: Train Loss: 2.4184, Train Accuracy: 37.06%
#     Worker 1: Train Loss: 2.4420, Train Accuracy: 37.07%
#     Worker 2: Train Loss: 2.4039, Train Accuracy: 38.21%
#     Worker 3: Train Loss: 2.4382, Train Accuracy: 36.86%
# Total Computation Time: 681.57 seconds
# Total Communication Time: 1.76 seconds
# Epoch 30/150: Test Loss: 2.3383, Test Accuracy: 39.79%
#     Worker 0: Train Loss: 2.3787, Train Accuracy: 38.35%
#     Worker 1: Train Loss: 2.3999, Train Accuracy: 37.89%
#     Worker 2: Train Loss: 2.3636, Train Accuracy: 38.72%
#     Worker 3: Train Loss: 2.3981, Train Accuracy: 37.96%
# Total Computation Time: 704.44 seconds
# Total Communication Time: 1.82 seconds
# Epoch 31/150: Test Loss: 2.3319, Test Accuracy: 39.78%
#     Worker 0: Train Loss: 2.3463, Train Accuracy: 38.70%
#     Worker 1: Train Loss: 2.3651, Train Accuracy: 39.00%
#     Worker 2: Train Loss: 2.3374, Train Accuracy: 39.62%
#     Worker 3: Train Loss: 2.3599, Train Accuracy: 38.66%
# Total Computation Time: 727.38 seconds
# Total Communication Time: 1.87 seconds
# Epoch 32/150: Test Loss: 2.2870, Test Accuracy: 40.31%
#     Worker 0: Train Loss: 2.3187, Train Accuracy: 39.62%
#     Worker 1: Train Loss: 2.3561, Train Accuracy: 38.88%
#     Worker 2: Train Loss: 2.3114, Train Accuracy: 39.83%
#     Worker 3: Train Loss: 2.3432, Train Accuracy: 39.18%
# Total Computation Time: 750.54 seconds
# Total Communication Time: 1.93 seconds
# Epoch 33/150: Test Loss: 2.2707, Test Accuracy: 41.12%
#     Worker 0: Train Loss: 2.3135, Train Accuracy: 40.08%
#     Worker 1: Train Loss: 2.3206, Train Accuracy: 39.58%
#     Worker 2: Train Loss: 2.2790, Train Accuracy: 40.38%
#     Worker 3: Train Loss: 2.3131, Train Accuracy: 39.46%
# Total Computation Time: 773.74 seconds
# Total Communication Time: 1.99 seconds
# Epoch 34/150: Test Loss: 2.2764, Test Accuracy: 40.88%
#     Worker 0: Train Loss: 2.2761, Train Accuracy: 40.27%
#     Worker 1: Train Loss: 2.3006, Train Accuracy: 39.46%
#     Worker 2: Train Loss: 2.2621, Train Accuracy: 40.99%
#     Worker 3: Train Loss: 2.2889, Train Accuracy: 39.99%
# Total Computation Time: 797.08 seconds
# Total Communication Time: 2.05 seconds
# Epoch 35/150: Test Loss: 2.2509, Test Accuracy: 40.97%
#     Worker 0: Train Loss: 2.2477, Train Accuracy: 41.11%
#     Worker 1: Train Loss: 2.2726, Train Accuracy: 40.51%
#     Worker 2: Train Loss: 2.2432, Train Accuracy: 41.34%
#     Worker 3: Train Loss: 2.2657, Train Accuracy: 40.31%
# Total Computation Time: 820.60 seconds
# Total Communication Time: 2.11 seconds
# Epoch 36/150: Test Loss: 2.2203, Test Accuracy: 42.08%
#     Worker 0: Train Loss: 2.2208, Train Accuracy: 41.61%
#     Worker 1: Train Loss: 2.2432, Train Accuracy: 41.30%
#     Worker 2: Train Loss: 2.1948, Train Accuracy: 42.17%
#     Worker 3: Train Loss: 2.2477, Train Accuracy: 41.58%
# Total Computation Time: 843.80 seconds
# Total Communication Time: 2.17 seconds
# Epoch 37/150: Test Loss: 2.2253, Test Accuracy: 42.38%
#     Worker 0: Train Loss: 2.1983, Train Accuracy: 42.39%
#     Worker 1: Train Loss: 2.2224, Train Accuracy: 41.68%
#     Worker 2: Train Loss: 2.2025, Train Accuracy: 42.01%
#     Worker 3: Train Loss: 2.2172, Train Accuracy: 41.56%
# Total Computation Time: 867.04 seconds
# Total Communication Time: 2.23 seconds
# Epoch 38/150: Test Loss: 2.2060, Test Accuracy: 42.58%
#     Worker 0: Train Loss: 2.1859, Train Accuracy: 42.37%
#     Worker 1: Train Loss: 2.2024, Train Accuracy: 42.14%
#     Worker 2: Train Loss: 2.1647, Train Accuracy: 42.75%
#     Worker 3: Train Loss: 2.1904, Train Accuracy: 42.38%
# Total Computation Time: 890.16 seconds
# Total Communication Time: 2.29 seconds
# Epoch 39/150: Test Loss: 2.2066, Test Accuracy: 42.64%
#     Worker 0: Train Loss: 2.1550, Train Accuracy: 42.90%
#     Worker 1: Train Loss: 2.1755, Train Accuracy: 42.35%
#     Worker 2: Train Loss: 2.1421, Train Accuracy: 43.46%
#     Worker 3: Train Loss: 2.1769, Train Accuracy: 42.39%
# Total Computation Time: 913.30 seconds
# Total Communication Time: 2.35 seconds
# Epoch 40/150: Test Loss: 2.1895, Test Accuracy: 43.12%
#     Worker 0: Train Loss: 2.1266, Train Accuracy: 43.70%
#     Worker 1: Train Loss: 2.1505, Train Accuracy: 43.29%
#     Worker 2: Train Loss: 2.1217, Train Accuracy: 44.26%
#     Worker 3: Train Loss: 2.1356, Train Accuracy: 43.56%
# Total Computation Time: 936.40 seconds
# Total Communication Time: 2.41 seconds
# Epoch 41/150: Test Loss: 2.1697, Test Accuracy: 43.41%
#     Worker 0: Train Loss: 2.1114, Train Accuracy: 44.23%
#     Worker 1: Train Loss: 2.1260, Train Accuracy: 43.76%
#     Worker 2: Train Loss: 2.1076, Train Accuracy: 44.19%
#     Worker 3: Train Loss: 2.1432, Train Accuracy: 43.54%
# Total Computation Time: 959.13 seconds
# Total Communication Time: 2.47 seconds
# Epoch 42/150: Test Loss: 2.1508, Test Accuracy: 43.80%
#     Worker 0: Train Loss: 2.0999, Train Accuracy: 44.14%
#     Worker 1: Train Loss: 2.1013, Train Accuracy: 44.23%
#     Worker 2: Train Loss: 2.0801, Train Accuracy: 44.64%
#     Worker 3: Train Loss: 2.1171, Train Accuracy: 43.94%
# Total Computation Time: 981.88 seconds
# Total Communication Time: 2.53 seconds
# Epoch 43/150: Test Loss: 2.1460, Test Accuracy: 43.97%
#     Worker 0: Train Loss: 2.0815, Train Accuracy: 44.38%
#     Worker 1: Train Loss: 2.0908, Train Accuracy: 44.96%
#     Worker 2: Train Loss: 2.0590, Train Accuracy: 45.55%
#     Worker 3: Train Loss: 2.0921, Train Accuracy: 44.34%
# Total Computation Time: 1004.90 seconds
# Total Communication Time: 2.59 seconds
# Epoch 44/150: Test Loss: 2.1341, Test Accuracy: 44.16%
#     Worker 0: Train Loss: 2.0666, Train Accuracy: 44.74%
#     Worker 1: Train Loss: 2.0567, Train Accuracy: 45.70%
#     Worker 2: Train Loss: 2.0483, Train Accuracy: 45.50%
#     Worker 3: Train Loss: 2.0731, Train Accuracy: 44.87%
# Total Computation Time: 1027.98 seconds
# Total Communication Time: 2.65 seconds
# Epoch 45/150: Test Loss: 2.1183, Test Accuracy: 45.06%
#     Worker 0: Train Loss: 2.0418, Train Accuracy: 45.37%
#     Worker 1: Train Loss: 2.0366, Train Accuracy: 45.92%
#     Worker 2: Train Loss: 2.0384, Train Accuracy: 46.10%
#     Worker 3: Train Loss: 2.0524, Train Accuracy: 45.26%
# Total Computation Time: 1051.12 seconds
# Total Communication Time: 2.71 seconds
# Epoch 46/150: Test Loss: 2.1130, Test Accuracy: 45.22%
#     Worker 0: Train Loss: 2.0189, Train Accuracy: 45.84%
#     Worker 1: Train Loss: 2.0324, Train Accuracy: 46.06%
#     Worker 2: Train Loss: 2.0095, Train Accuracy: 46.26%
#     Worker 3: Train Loss: 2.0227, Train Accuracy: 45.90%
# Total Computation Time: 1074.50 seconds
# Total Communication Time: 2.77 seconds
# Epoch 47/150: Test Loss: 2.1331, Test Accuracy: 44.58%
#     Worker 0: Train Loss: 2.0001, Train Accuracy: 46.23%
#     Worker 1: Train Loss: 2.0190, Train Accuracy: 45.99%
#     Worker 2: Train Loss: 1.9785, Train Accuracy: 47.10%
#     Worker 3: Train Loss: 2.0337, Train Accuracy: 45.71%
# Total Computation Time: 1097.64 seconds
# Total Communication Time: 2.83 seconds
# Epoch 48/150: Test Loss: 2.1192, Test Accuracy: 45.03%
#     Worker 0: Train Loss: 1.9860, Train Accuracy: 46.66%
#     Worker 1: Train Loss: 1.9962, Train Accuracy: 46.95%
#     Worker 2: Train Loss: 1.9799, Train Accuracy: 46.87%
#     Worker 3: Train Loss: 1.9949, Train Accuracy: 46.50%
# Total Computation Time: 1120.74 seconds
# Total Communication Time: 2.89 seconds
# Epoch 49/150: Test Loss: 2.0848, Test Accuracy: 45.12%
#     Worker 0: Train Loss: 1.9636, Train Accuracy: 46.82%
#     Worker 1: Train Loss: 1.9641, Train Accuracy: 47.51%
#     Worker 2: Train Loss: 1.9699, Train Accuracy: 47.29%
#     Worker 3: Train Loss: 1.9731, Train Accuracy: 47.58%
# Total Computation Time: 1143.80 seconds
# Total Communication Time: 2.95 seconds
# Epoch 50/150: Test Loss: 2.1057, Test Accuracy: 44.73%
#     Worker 0: Train Loss: 1.9499, Train Accuracy: 47.09%
#     Worker 1: Train Loss: 1.9604, Train Accuracy: 47.60%
#     Worker 2: Train Loss: 1.9577, Train Accuracy: 47.53%
#     Worker 3: Train Loss: 1.9514, Train Accuracy: 47.37%
# Total Computation Time: 1166.81 seconds
# Total Communication Time: 3.01 seconds
# Epoch 51/150: Test Loss: 2.0832, Test Accuracy: 45.85%
#     Worker 0: Train Loss: 1.9345, Train Accuracy: 47.56%
#     Worker 1: Train Loss: 1.9440, Train Accuracy: 48.06%
#     Worker 2: Train Loss: 1.9298, Train Accuracy: 48.67%
#     Worker 3: Train Loss: 1.9395, Train Accuracy: 47.96%
# Total Computation Time: 1189.93 seconds
# Total Communication Time: 3.07 seconds
# Epoch 52/150: Test Loss: 2.0903, Test Accuracy: 45.25%
#     Worker 0: Train Loss: 1.9208, Train Accuracy: 48.06%
#     Worker 1: Train Loss: 1.9247, Train Accuracy: 47.89%
#     Worker 2: Train Loss: 1.8958, Train Accuracy: 49.28%
#     Worker 3: Train Loss: 1.9234, Train Accuracy: 48.30%
# Total Computation Time: 1213.20 seconds
# Total Communication Time: 3.13 seconds
# Epoch 53/150: Test Loss: 2.0834, Test Accuracy: 45.93%
#     Worker 0: Train Loss: 1.8961, Train Accuracy: 48.64%
#     Worker 1: Train Loss: 1.9075, Train Accuracy: 48.66%
#     Worker 2: Train Loss: 1.8947, Train Accuracy: 49.30%
#     Worker 3: Train Loss: 1.9092, Train Accuracy: 48.63%
# Total Computation Time: 1236.39 seconds
# Total Communication Time: 3.19 seconds
# Epoch 54/150: Test Loss: 2.0862, Test Accuracy: 45.69%
#     Worker 0: Train Loss: 1.8943, Train Accuracy: 49.04%
#     Worker 1: Train Loss: 1.9002, Train Accuracy: 49.13%
#     Worker 2: Train Loss: 1.8853, Train Accuracy: 48.82%
#     Worker 3: Train Loss: 1.8924, Train Accuracy: 49.06%
# Total Computation Time: 1259.35 seconds
# Total Communication Time: 3.25 seconds
# Epoch 55/150: Test Loss: 2.0588, Test Accuracy: 46.33%
#     Worker 0: Train Loss: 1.8796, Train Accuracy: 48.86%
#     Worker 1: Train Loss: 1.8819, Train Accuracy: 49.18%
#     Worker 2: Train Loss: 1.8721, Train Accuracy: 49.36%
#     Worker 3: Train Loss: 1.8812, Train Accuracy: 49.71%
# Total Computation Time: 1282.10 seconds
# Total Communication Time: 3.31 seconds
# Epoch 56/150: Test Loss: 2.0705, Test Accuracy: 46.18%
#     Worker 0: Train Loss: 1.8668, Train Accuracy: 48.82%
#     Worker 1: Train Loss: 1.8593, Train Accuracy: 49.33%
#     Worker 2: Train Loss: 1.8419, Train Accuracy: 50.40%
#     Worker 3: Train Loss: 1.8609, Train Accuracy: 50.01%
# Total Computation Time: 1305.11 seconds
# Total Communication Time: 3.36 seconds
# Epoch 57/150: Test Loss: 2.0426, Test Accuracy: 46.78%
#     Worker 0: Train Loss: 1.8459, Train Accuracy: 49.63%
#     Worker 1: Train Loss: 1.8617, Train Accuracy: 49.70%
#     Worker 2: Train Loss: 1.8238, Train Accuracy: 51.08%
#     Worker 3: Train Loss: 1.8548, Train Accuracy: 49.54%
# Total Computation Time: 1328.21 seconds
# Total Communication Time: 3.42 seconds
# Epoch 58/150: Test Loss: 2.0486, Test Accuracy: 46.67%
#     Worker 0: Train Loss: 1.8296, Train Accuracy: 50.29%
#     Worker 1: Train Loss: 1.8364, Train Accuracy: 50.42%
#     Worker 2: Train Loss: 1.8265, Train Accuracy: 50.55%
#     Worker 3: Train Loss: 1.8339, Train Accuracy: 50.26%
# Total Computation Time: 1351.17 seconds
# Total Communication Time: 3.48 seconds
# Epoch 59/150: Test Loss: 2.0333, Test Accuracy: 46.90%
#     Worker 0: Train Loss: 1.8140, Train Accuracy: 50.49%
#     Worker 1: Train Loss: 1.8211, Train Accuracy: 50.80%
#     Worker 2: Train Loss: 1.8033, Train Accuracy: 51.32%
#     Worker 3: Train Loss: 1.8286, Train Accuracy: 50.10%
# Total Computation Time: 1374.38 seconds
# Total Communication Time: 3.54 seconds
# Epoch 60/150: Test Loss: 2.0423, Test Accuracy: 46.88%
#     Worker 0: Train Loss: 1.7982, Train Accuracy: 50.71%
#     Worker 1: Train Loss: 1.8157, Train Accuracy: 50.94%
#     Worker 2: Train Loss: 1.7956, Train Accuracy: 51.47%
#     Worker 3: Train Loss: 1.8114, Train Accuracy: 50.75%
# Total Computation Time: 1397.38 seconds
# Total Communication Time: 3.60 seconds
# Epoch 61/150: Test Loss: 2.0320, Test Accuracy: 46.75%
#     Worker 0: Train Loss: 1.7787, Train Accuracy: 51.51%
#     Worker 1: Train Loss: 1.7886, Train Accuracy: 51.63%
#     Worker 2: Train Loss: 1.7640, Train Accuracy: 51.76%
#     Worker 3: Train Loss: 1.7891, Train Accuracy: 51.43%
# Total Computation Time: 1420.40 seconds
# Total Communication Time: 3.66 seconds
# Epoch 62/150: Test Loss: 2.0307, Test Accuracy: 47.26%
#     Worker 0: Train Loss: 1.7770, Train Accuracy: 51.80%
#     Worker 1: Train Loss: 1.7703, Train Accuracy: 51.77%
#     Worker 2: Train Loss: 1.7705, Train Accuracy: 51.93%
#     Worker 3: Train Loss: 1.7878, Train Accuracy: 51.73%
# Total Computation Time: 1443.37 seconds
# Total Communication Time: 3.72 seconds
# Epoch 63/150: Test Loss: 2.0269, Test Accuracy: 47.51%
#     Worker 0: Train Loss: 1.7662, Train Accuracy: 51.59%
#     Worker 1: Train Loss: 1.7517, Train Accuracy: 52.19%
#     Worker 2: Train Loss: 1.7495, Train Accuracy: 52.40%
#     Worker 3: Train Loss: 1.7677, Train Accuracy: 52.01%
# Total Computation Time: 1466.38 seconds
# Total Communication Time: 3.78 seconds
# Epoch 64/150: Test Loss: 2.0314, Test Accuracy: 47.45%
#     Worker 0: Train Loss: 1.7385, Train Accuracy: 52.28%
#     Worker 1: Train Loss: 1.7567, Train Accuracy: 52.49%
#     Worker 2: Train Loss: 1.7453, Train Accuracy: 52.53%
#     Worker 3: Train Loss: 1.7469, Train Accuracy: 52.62%
# Total Computation Time: 1489.49 seconds
# Total Communication Time: 3.84 seconds
# Epoch 65/150: Test Loss: 2.0217, Test Accuracy: 47.86%
#     Worker 0: Train Loss: 1.7300, Train Accuracy: 51.94%
#     Worker 1: Train Loss: 1.7347, Train Accuracy: 53.04%
#     Worker 2: Train Loss: 1.7278, Train Accuracy: 52.94%
#     Worker 3: Train Loss: 1.7355, Train Accuracy: 53.29%
# Total Computation Time: 1512.57 seconds
# Total Communication Time: 3.90 seconds
# Epoch 66/150: Test Loss: 2.0187, Test Accuracy: 47.82%
#     Worker 0: Train Loss: 1.7084, Train Accuracy: 52.95%
#     Worker 1: Train Loss: 1.7140, Train Accuracy: 53.26%
#     Worker 2: Train Loss: 1.7032, Train Accuracy: 53.68%
#     Worker 3: Train Loss: 1.7288, Train Accuracy: 52.86%
# Total Computation Time: 1535.71 seconds
# Total Communication Time: 3.95 seconds
# Epoch 67/150: Test Loss: 2.0076, Test Accuracy: 48.19%
#     Worker 0: Train Loss: 1.7030, Train Accuracy: 52.94%
#     Worker 1: Train Loss: 1.7043, Train Accuracy: 53.34%
#     Worker 2: Train Loss: 1.6990, Train Accuracy: 53.66%
#     Worker 3: Train Loss: 1.7248, Train Accuracy: 53.04%
# Total Computation Time: 1558.64 seconds
# Total Communication Time: 4.01 seconds
# Epoch 68/150: Test Loss: 1.9979, Test Accuracy: 48.30%
#     Worker 0: Train Loss: 1.7059, Train Accuracy: 53.11%
#     Worker 1: Train Loss: 1.6976, Train Accuracy: 54.01%
#     Worker 2: Train Loss: 1.6948, Train Accuracy: 53.95%
#     Worker 3: Train Loss: 1.6997, Train Accuracy: 53.23%
# Total Computation Time: 1581.37 seconds
# Total Communication Time: 4.07 seconds
# Epoch 69/150: Test Loss: 2.0205, Test Accuracy: 48.03%
#     Worker 0: Train Loss: 1.6745, Train Accuracy: 53.61%
#     Worker 1: Train Loss: 1.6901, Train Accuracy: 53.76%
#     Worker 2: Train Loss: 1.6789, Train Accuracy: 54.54%
#     Worker 3: Train Loss: 1.6948, Train Accuracy: 53.50%
# Total Computation Time: 1604.26 seconds
# Total Communication Time: 4.13 seconds
# Epoch 70/150: Test Loss: 1.9980, Test Accuracy: 48.27%
#     Worker 0: Train Loss: 1.6753, Train Accuracy: 53.52%
#     Worker 1: Train Loss: 1.6835, Train Accuracy: 53.82%
#     Worker 2: Train Loss: 1.6574, Train Accuracy: 54.60%
#     Worker 3: Train Loss: 1.6802, Train Accuracy: 54.54%
# Total Computation Time: 1627.43 seconds
# Total Communication Time: 4.19 seconds
# Epoch 71/150: Test Loss: 1.9931, Test Accuracy: 48.19%
#     Worker 0: Train Loss: 1.6707, Train Accuracy: 53.90%
#     Worker 1: Train Loss: 1.6665, Train Accuracy: 54.33%
#     Worker 2: Train Loss: 1.6539, Train Accuracy: 54.91%
#     Worker 3: Train Loss: 1.6680, Train Accuracy: 54.25%
# Total Computation Time: 1650.66 seconds
# Total Communication Time: 4.25 seconds
# Epoch 72/150: Test Loss: 1.9839, Test Accuracy: 49.24%
#     Worker 0: Train Loss: 1.6501, Train Accuracy: 54.18%
#     Worker 1: Train Loss: 1.6398, Train Accuracy: 55.10%
#     Worker 2: Train Loss: 1.6462, Train Accuracy: 54.69%
#     Worker 3: Train Loss: 1.6561, Train Accuracy: 54.07%
# Total Computation Time: 1673.85 seconds
# Total Communication Time: 4.31 seconds
# Epoch 73/150: Test Loss: 1.9989, Test Accuracy: 48.62%
#     Worker 0: Train Loss: 1.6279, Train Accuracy: 54.63%
#     Worker 1: Train Loss: 1.6322, Train Accuracy: 55.28%
#     Worker 2: Train Loss: 1.6195, Train Accuracy: 54.94%
#     Worker 3: Train Loss: 1.6431, Train Accuracy: 54.89%
# Total Computation Time: 1697.04 seconds
# Total Communication Time: 4.37 seconds
# Epoch 74/150: Test Loss: 2.0058, Test Accuracy: 48.81%
#     Worker 0: Train Loss: 1.6425, Train Accuracy: 54.10%
#     Worker 1: Train Loss: 1.6252, Train Accuracy: 55.62%
#     Worker 2: Train Loss: 1.6326, Train Accuracy: 54.86%
#     Worker 3: Train Loss: 1.6376, Train Accuracy: 55.00%
# Total Computation Time: 1720.17 seconds
# Total Communication Time: 4.43 seconds
# Epoch 75/150: Test Loss: 2.0007, Test Accuracy: 48.23%
#     Worker 0: Train Loss: 1.6104, Train Accuracy: 55.36%
#     Worker 1: Train Loss: 1.6170, Train Accuracy: 55.65%
#     Worker 2: Train Loss: 1.5918, Train Accuracy: 56.73%
#     Worker 3: Train Loss: 1.6200, Train Accuracy: 55.75%
# Total Computation Time: 1743.39 seconds
# Total Communication Time: 4.49 seconds
# Epoch 76/150: Test Loss: 1.9961, Test Accuracy: 48.90%
#     Worker 0: Train Loss: 1.6079, Train Accuracy: 55.23%
#     Worker 1: Train Loss: 1.6051, Train Accuracy: 55.94%
#     Worker 2: Train Loss: 1.6011, Train Accuracy: 56.51%
#     Worker 3: Train Loss: 1.6047, Train Accuracy: 55.41%
# Total Computation Time: 1766.46 seconds
# Total Communication Time: 4.55 seconds
# Epoch 77/150: Test Loss: 1.9837, Test Accuracy: 49.56%
#     Worker 0: Train Loss: 1.5963, Train Accuracy: 55.10%
#     Worker 1: Train Loss: 1.6006, Train Accuracy: 55.96%
#     Worker 2: Train Loss: 1.5904, Train Accuracy: 56.61%
#     Worker 3: Train Loss: 1.6006, Train Accuracy: 55.58%
# Total Computation Time: 1789.76 seconds
# Total Communication Time: 4.61 seconds
# Epoch 78/150: Test Loss: 2.0271, Test Accuracy: 48.79%
#     Worker 0: Train Loss: 1.5894, Train Accuracy: 55.44%
#     Worker 1: Train Loss: 1.5727, Train Accuracy: 56.31%
#     Worker 2: Train Loss: 1.5736, Train Accuracy: 56.80%
#     Worker 3: Train Loss: 1.5794, Train Accuracy: 56.50%
# Total Computation Time: 1813.12 seconds
# Total Communication Time: 4.67 seconds
# Epoch 79/150: Test Loss: 1.9893, Test Accuracy: 49.47%
#     Worker 0: Train Loss: 1.5761, Train Accuracy: 55.90%
#     Worker 1: Train Loss: 1.5659, Train Accuracy: 56.70%
#     Worker 2: Train Loss: 1.5606, Train Accuracy: 57.26%
#     Worker 3: Train Loss: 1.5607, Train Accuracy: 56.78%
# Total Computation Time: 1836.38 seconds
# Total Communication Time: 4.73 seconds
# Epoch 80/150: Test Loss: 1.9721, Test Accuracy: 49.69%
#     Worker 0: Train Loss: 1.5729, Train Accuracy: 56.31%
#     Worker 1: Train Loss: 1.5659, Train Accuracy: 56.67%
#     Worker 2: Train Loss: 1.5537, Train Accuracy: 57.10%
#     Worker 3: Train Loss: 1.5670, Train Accuracy: 56.53%
# Total Computation Time: 1859.11 seconds
# Total Communication Time: 4.79 seconds
# Epoch 81/150: Test Loss: 1.9865, Test Accuracy: 49.36%
#     Worker 0: Train Loss: 1.5492, Train Accuracy: 56.54%
#     Worker 1: Train Loss: 1.5416, Train Accuracy: 57.55%
#     Worker 2: Train Loss: 1.5432, Train Accuracy: 57.66%
#     Worker 3: Train Loss: 1.5536, Train Accuracy: 57.18%
# Total Computation Time: 1881.76 seconds
# Total Communication Time: 4.85 seconds
# Epoch 82/150: Test Loss: 1.9800, Test Accuracy: 49.74%
#     Worker 0: Train Loss: 1.5397, Train Accuracy: 57.34%
#     Worker 1: Train Loss: 1.5389, Train Accuracy: 57.89%
#     Worker 2: Train Loss: 1.5360, Train Accuracy: 57.18%
#     Worker 3: Train Loss: 1.5348, Train Accuracy: 57.26%
# Total Computation Time: 1904.70 seconds
# Total Communication Time: 4.91 seconds
# Epoch 83/150: Test Loss: 1.9735, Test Accuracy: 49.64%
#     Worker 0: Train Loss: 1.5272, Train Accuracy: 57.30%
#     Worker 1: Train Loss: 1.5271, Train Accuracy: 57.73%
#     Worker 2: Train Loss: 1.5189, Train Accuracy: 57.99%
#     Worker 3: Train Loss: 1.5446, Train Accuracy: 56.96%
# Total Computation Time: 1927.92 seconds
# Total Communication Time: 4.97 seconds
# Epoch 84/150: Test Loss: 1.9795, Test Accuracy: 49.54%
#     Worker 0: Train Loss: 1.5297, Train Accuracy: 57.22%
#     Worker 1: Train Loss: 1.5254, Train Accuracy: 58.02%
#     Worker 2: Train Loss: 1.5115, Train Accuracy: 57.98%
#     Worker 3: Train Loss: 1.5376, Train Accuracy: 57.58%
# Total Computation Time: 1950.98 seconds
# Total Communication Time: 5.03 seconds
# Epoch 85/150: Test Loss: 1.9858, Test Accuracy: 49.22%
#     Worker 0: Train Loss: 1.5107, Train Accuracy: 57.77%
#     Worker 1: Train Loss: 1.5181, Train Accuracy: 58.54%
#     Worker 2: Train Loss: 1.5049, Train Accuracy: 58.65%
#     Worker 3: Train Loss: 1.5239, Train Accuracy: 57.57%
# Total Computation Time: 1974.15 seconds
# Total Communication Time: 5.09 seconds
# Epoch 86/150: Test Loss: 1.9717, Test Accuracy: 49.87%
#     Worker 0: Train Loss: 1.5115, Train Accuracy: 57.64%
#     Worker 1: Train Loss: 1.5124, Train Accuracy: 58.06%
#     Worker 2: Train Loss: 1.4863, Train Accuracy: 58.44%
#     Worker 3: Train Loss: 1.5026, Train Accuracy: 58.18%
# Total Computation Time: 1997.52 seconds
# Total Communication Time: 5.15 seconds
# Epoch 87/150: Test Loss: 1.9740, Test Accuracy: 49.95%
#     Worker 0: Train Loss: 1.4944, Train Accuracy: 57.56%
#     Worker 1: Train Loss: 1.4879, Train Accuracy: 58.57%
#     Worker 2: Train Loss: 1.4903, Train Accuracy: 58.58%
#     Worker 3: Train Loss: 1.5019, Train Accuracy: 58.43%
# Total Computation Time: 2020.90 seconds
# Total Communication Time: 5.21 seconds
# Epoch 88/150: Test Loss: 1.9686, Test Accuracy: 49.74%
#     Worker 0: Train Loss: 1.4732, Train Accuracy: 58.62%
#     Worker 1: Train Loss: 1.4917, Train Accuracy: 58.11%
#     Worker 2: Train Loss: 1.4760, Train Accuracy: 59.04%
#     Worker 3: Train Loss: 1.4906, Train Accuracy: 58.87%
# Total Computation Time: 2044.06 seconds
# Total Communication Time: 5.27 seconds
# Epoch 89/150: Test Loss: 1.9642, Test Accuracy: 50.43%
#     Worker 0: Train Loss: 1.4695, Train Accuracy: 58.66%
#     Worker 1: Train Loss: 1.4820, Train Accuracy: 58.63%
#     Worker 2: Train Loss: 1.4639, Train Accuracy: 59.26%
#     Worker 3: Train Loss: 1.4829, Train Accuracy: 58.75%
# Total Computation Time: 2067.25 seconds
# Total Communication Time: 5.33 seconds
# Epoch 90/150: Test Loss: 1.9657, Test Accuracy: 50.39%
#     Worker 0: Train Loss: 1.4590, Train Accuracy: 59.07%
#     Worker 1: Train Loss: 1.4685, Train Accuracy: 59.09%
#     Worker 2: Train Loss: 1.4663, Train Accuracy: 58.94%
#     Worker 3: Train Loss: 1.4749, Train Accuracy: 59.02%
# Total Computation Time: 2090.24 seconds
# Total Communication Time: 5.39 seconds
# Epoch 91/150: Test Loss: 1.9707, Test Accuracy: 49.82%
#     Worker 0: Train Loss: 1.4614, Train Accuracy: 58.50%
#     Worker 1: Train Loss: 1.4499, Train Accuracy: 59.34%
#     Worker 2: Train Loss: 1.4466, Train Accuracy: 59.39%
#     Worker 3: Train Loss: 1.4610, Train Accuracy: 59.50%
# Total Computation Time: 2113.55 seconds
# Total Communication Time: 5.45 seconds
# Epoch 92/150: Test Loss: 1.9639, Test Accuracy: 49.81%
#     Worker 0: Train Loss: 1.4573, Train Accuracy: 59.46%
#     Worker 1: Train Loss: 1.4542, Train Accuracy: 60.14%
#     Worker 2: Train Loss: 1.4446, Train Accuracy: 59.30%
#     Worker 3: Train Loss: 1.4566, Train Accuracy: 59.04%
# Total Computation Time: 2136.49 seconds
# Total Communication Time: 5.51 seconds
# Epoch 93/150: Test Loss: 1.9741, Test Accuracy: 49.73%
#     Worker 0: Train Loss: 1.4528, Train Accuracy: 59.46%
#     Worker 1: Train Loss: 1.4423, Train Accuracy: 59.40%
#     Worker 2: Train Loss: 1.4309, Train Accuracy: 60.12%
#     Worker 3: Train Loss: 1.4419, Train Accuracy: 59.57%
# Total Computation Time: 2159.25 seconds
# Total Communication Time: 5.57 seconds
# Epoch 94/150: Test Loss: 1.9600, Test Accuracy: 50.39%
#     Worker 0: Train Loss: 1.4331, Train Accuracy: 59.15%
#     Worker 1: Train Loss: 1.4240, Train Accuracy: 60.26%
#     Worker 2: Train Loss: 1.4181, Train Accuracy: 60.54%
#     Worker 3: Train Loss: 1.4458, Train Accuracy: 59.64%
# Total Computation Time: 2182.03 seconds
# Total Communication Time: 5.63 seconds
# Epoch 95/150: Test Loss: 1.9610, Test Accuracy: 50.43%
#     Worker 0: Train Loss: 1.4296, Train Accuracy: 59.76%
#     Worker 1: Train Loss: 1.4333, Train Accuracy: 60.00%
#     Worker 2: Train Loss: 1.4119, Train Accuracy: 60.31%
#     Worker 3: Train Loss: 1.4181, Train Accuracy: 60.34%
# Total Computation Time: 2205.24 seconds
# Total Communication Time: 5.68 seconds
# Epoch 96/150: Test Loss: 1.9637, Test Accuracy: 50.21%
#     Worker 0: Train Loss: 1.4257, Train Accuracy: 59.82%
#     Worker 1: Train Loss: 1.4105, Train Accuracy: 60.61%
#     Worker 2: Train Loss: 1.4028, Train Accuracy: 60.79%
#     Worker 3: Train Loss: 1.4142, Train Accuracy: 60.01%
# Total Computation Time: 2228.44 seconds
# Total Communication Time: 5.74 seconds
# Epoch 97/150: Test Loss: 1.9569, Test Accuracy: 50.46%
#     Worker 0: Train Loss: 1.4102, Train Accuracy: 59.70%
#     Worker 1: Train Loss: 1.4116, Train Accuracy: 60.42%
#     Worker 2: Train Loss: 1.4045, Train Accuracy: 60.66%
#     Worker 3: Train Loss: 1.4145, Train Accuracy: 60.42%
# Total Computation Time: 2251.53 seconds
# Total Communication Time: 5.80 seconds
# Epoch 98/150: Test Loss: 1.9805, Test Accuracy: 50.08%
#     Worker 0: Train Loss: 1.4100, Train Accuracy: 59.98%
#     Worker 1: Train Loss: 1.3889, Train Accuracy: 61.55%
#     Worker 2: Train Loss: 1.3941, Train Accuracy: 60.51%
#     Worker 3: Train Loss: 1.4036, Train Accuracy: 60.70%
# Total Computation Time: 2274.74 seconds
# Total Communication Time: 5.86 seconds
# Epoch 99/150: Test Loss: 1.9642, Test Accuracy: 50.51%
#     Worker 0: Train Loss: 1.3880, Train Accuracy: 60.11%
#     Worker 1: Train Loss: 1.3824, Train Accuracy: 61.72%
#     Worker 2: Train Loss: 1.4081, Train Accuracy: 60.86%
#     Worker 3: Train Loss: 1.3869, Train Accuracy: 61.33%
# Total Computation Time: 2297.75 seconds
# Total Communication Time: 5.92 seconds
# Epoch 100/150: Test Loss: 1.9649, Test Accuracy: 50.01%
#     Worker 0: Train Loss: 1.3851, Train Accuracy: 61.04%
#     Worker 1: Train Loss: 1.3891, Train Accuracy: 61.23%
#     Worker 2: Train Loss: 1.3882, Train Accuracy: 61.27%
#     Worker 3: Train Loss: 1.3860, Train Accuracy: 60.60%
# Total Computation Time: 2320.67 seconds
# Total Communication Time: 5.98 seconds
# Epoch 101/150: Test Loss: 1.9739, Test Accuracy: 50.34%
#     Worker 0: Train Loss: 1.3808, Train Accuracy: 60.63%
#     Worker 1: Train Loss: 1.3890, Train Accuracy: 61.25%
#     Worker 2: Train Loss: 1.3716, Train Accuracy: 61.49%
#     Worker 3: Train Loss: 1.3793, Train Accuracy: 61.53%
# Total Computation Time: 2343.73 seconds
# Total Communication Time: 6.04 seconds
# Epoch 102/150: Test Loss: 1.9627, Test Accuracy: 50.54%
#     Worker 0: Train Loss: 1.3633, Train Accuracy: 61.54%
#     Worker 1: Train Loss: 1.3774, Train Accuracy: 61.37%
#     Worker 2: Train Loss: 1.3538, Train Accuracy: 61.79%
#     Worker 3: Train Loss: 1.3715, Train Accuracy: 61.87%
# Total Computation Time: 2366.73 seconds
# Total Communication Time: 6.09 seconds
# Epoch 103/150: Test Loss: 1.9652, Test Accuracy: 50.27%
#     Worker 0: Train Loss: 1.3708, Train Accuracy: 61.18%
#     Worker 1: Train Loss: 1.3564, Train Accuracy: 62.34%
#     Worker 2: Train Loss: 1.3552, Train Accuracy: 61.83%
#     Worker 3: Train Loss: 1.3672, Train Accuracy: 61.47%
# Total Computation Time: 2389.70 seconds
# Total Communication Time: 6.15 seconds
# Epoch 104/150: Test Loss: 1.9636, Test Accuracy: 50.19%
#     Worker 0: Train Loss: 1.3501, Train Accuracy: 61.83%
#     Worker 1: Train Loss: 1.3621, Train Accuracy: 62.02%
#     Worker 2: Train Loss: 1.3556, Train Accuracy: 62.10%
#     Worker 3: Train Loss: 1.3548, Train Accuracy: 61.47%
# Total Computation Time: 2412.52 seconds
# Total Communication Time: 6.21 seconds
# Epoch 105/150: Test Loss: 1.9715, Test Accuracy: 50.44%
#     Worker 0: Train Loss: 1.3595, Train Accuracy: 61.03%
#     Worker 1: Train Loss: 1.3551, Train Accuracy: 62.33%
#     Worker 2: Train Loss: 1.3532, Train Accuracy: 62.01%
#     Worker 3: Train Loss: 1.3583, Train Accuracy: 62.04%
# Total Computation Time: 2435.48 seconds
# Total Communication Time: 6.27 seconds
# Epoch 106/150: Test Loss: 1.9624, Test Accuracy: 50.66%
#     Worker 0: Train Loss: 1.3445, Train Accuracy: 61.65%
#     Worker 1: Train Loss: 1.3520, Train Accuracy: 62.23%
#     Worker 2: Train Loss: 1.3430, Train Accuracy: 62.02%
#     Worker 3: Train Loss: 1.3555, Train Accuracy: 61.90%
# Total Computation Time: 2458.36 seconds
# Total Communication Time: 6.33 seconds
# Epoch 107/150: Test Loss: 1.9678, Test Accuracy: 51.12%
#     Worker 0: Train Loss: 1.3460, Train Accuracy: 61.60%
#     Worker 1: Train Loss: 1.3532, Train Accuracy: 62.26%
#     Worker 2: Train Loss: 1.3334, Train Accuracy: 62.22%
#     Worker 3: Train Loss: 1.3382, Train Accuracy: 62.61%
# Total Computation Time: 2481.11 seconds
# Total Communication Time: 6.39 seconds
# Epoch 108/150: Test Loss: 1.9685, Test Accuracy: 50.72%
#     Worker 0: Train Loss: 1.3246, Train Accuracy: 62.30%
#     Worker 1: Train Loss: 1.3339, Train Accuracy: 62.35%
#     Worker 2: Train Loss: 1.3107, Train Accuracy: 63.43%
#     Worker 3: Train Loss: 1.3303, Train Accuracy: 62.38%
# Total Computation Time: 2503.65 seconds
# Total Communication Time: 6.45 seconds
# Epoch 109/150: Test Loss: 1.9688, Test Accuracy: 50.65%
#     Worker 0: Train Loss: 1.3407, Train Accuracy: 61.89%
#     Worker 1: Train Loss: 1.3318, Train Accuracy: 62.88%
#     Worker 2: Train Loss: 1.3240, Train Accuracy: 62.35%
#     Worker 3: Train Loss: 1.3354, Train Accuracy: 62.44%
# Total Computation Time: 2526.19 seconds
# Total Communication Time: 6.50 seconds
# Epoch 110/150: Test Loss: 1.9619, Test Accuracy: 50.97%
#     Worker 0: Train Loss: 1.3300, Train Accuracy: 62.24%
#     Worker 1: Train Loss: 1.3161, Train Accuracy: 62.98%
#     Worker 2: Train Loss: 1.3150, Train Accuracy: 63.06%
#     Worker 3: Train Loss: 1.3318, Train Accuracy: 62.20%
# Total Computation Time: 2549.07 seconds
# Total Communication Time: 6.56 seconds
# Epoch 111/150: Test Loss: 1.9697, Test Accuracy: 50.77%
#     Worker 0: Train Loss: 1.3293, Train Accuracy: 62.34%
#     Worker 1: Train Loss: 1.2996, Train Accuracy: 63.54%
#     Worker 2: Train Loss: 1.3071, Train Accuracy: 62.89%
#     Worker 3: Train Loss: 1.3164, Train Accuracy: 62.74%
# Total Computation Time: 2572.05 seconds
# Total Communication Time: 6.62 seconds
# Epoch 112/150: Test Loss: 1.9733, Test Accuracy: 50.74%
#     Worker 0: Train Loss: 1.3157, Train Accuracy: 62.25%
#     Worker 1: Train Loss: 1.3121, Train Accuracy: 63.34%
#     Worker 2: Train Loss: 1.2971, Train Accuracy: 63.78%
#     Worker 3: Train Loss: 1.3075, Train Accuracy: 63.00%
# Total Computation Time: 2595.08 seconds
# Total Communication Time: 6.68 seconds
# Epoch 113/150: Test Loss: 1.9655, Test Accuracy: 50.82%
#     Worker 0: Train Loss: 1.3053, Train Accuracy: 62.70%
#     Worker 1: Train Loss: 1.3036, Train Accuracy: 63.33%
#     Worker 2: Train Loss: 1.2998, Train Accuracy: 63.75%
#     Worker 3: Train Loss: 1.3178, Train Accuracy: 63.21%
# Total Computation Time: 2617.87 seconds
# Total Communication Time: 6.74 seconds
# Epoch 114/150: Test Loss: 1.9586, Test Accuracy: 50.62%
#     Worker 0: Train Loss: 1.2931, Train Accuracy: 62.67%
#     Worker 1: Train Loss: 1.2963, Train Accuracy: 63.39%
#     Worker 2: Train Loss: 1.2956, Train Accuracy: 63.48%
#     Worker 3: Train Loss: 1.3007, Train Accuracy: 63.21%
# Total Computation Time: 2641.01 seconds
# Total Communication Time: 6.80 seconds
# Epoch 115/150: Test Loss: 1.9650, Test Accuracy: 50.87%
#     Worker 0: Train Loss: 1.3038, Train Accuracy: 62.77%
#     Worker 1: Train Loss: 1.2973, Train Accuracy: 63.70%
#     Worker 2: Train Loss: 1.2865, Train Accuracy: 63.88%
#     Worker 3: Train Loss: 1.2976, Train Accuracy: 63.47%
# Total Computation Time: 2664.04 seconds
# Total Communication Time: 6.86 seconds
# Epoch 116/150: Test Loss: 1.9686, Test Accuracy: 51.00%
#     Worker 0: Train Loss: 1.2913, Train Accuracy: 63.06%
#     Worker 1: Train Loss: 1.2830, Train Accuracy: 63.50%
#     Worker 2: Train Loss: 1.2934, Train Accuracy: 63.50%
#     Worker 3: Train Loss: 1.2963, Train Accuracy: 63.73%
# Total Computation Time: 2687.00 seconds
# Total Communication Time: 6.92 seconds
# Epoch 117/150: Test Loss: 1.9684, Test Accuracy: 50.82%
#     Worker 0: Train Loss: 1.2811, Train Accuracy: 62.94%
#     Worker 1: Train Loss: 1.2890, Train Accuracy: 63.66%
#     Worker 2: Train Loss: 1.2883, Train Accuracy: 63.78%
#     Worker 3: Train Loss: 1.2841, Train Accuracy: 63.50%
# Total Computation Time: 2709.93 seconds
# Total Communication Time: 6.98 seconds
# Epoch 118/150: Test Loss: 1.9687, Test Accuracy: 50.95%
#     Worker 0: Train Loss: 1.2894, Train Accuracy: 62.92%
#     Worker 1: Train Loss: 1.2955, Train Accuracy: 63.68%
#     Worker 2: Train Loss: 1.2744, Train Accuracy: 64.27%
#     Worker 3: Train Loss: 1.2863, Train Accuracy: 63.64%
# Total Computation Time: 2732.82 seconds
# Total Communication Time: 7.04 seconds
# Epoch 119/150: Test Loss: 1.9669, Test Accuracy: 50.91%
#     Worker 0: Train Loss: 1.2750, Train Accuracy: 63.92%
#     Worker 1: Train Loss: 1.2753, Train Accuracy: 64.30%
#     Worker 2: Train Loss: 1.2599, Train Accuracy: 64.15%
#     Worker 3: Train Loss: 1.2809, Train Accuracy: 63.73%
# Total Computation Time: 2755.72 seconds
# Total Communication Time: 7.10 seconds
# Epoch 120/150: Test Loss: 1.9613, Test Accuracy: 51.06%
#     Worker 0: Train Loss: 1.2587, Train Accuracy: 63.86%
#     Worker 1: Train Loss: 1.2837, Train Accuracy: 64.18%
#     Worker 2: Train Loss: 1.2732, Train Accuracy: 64.10%
#     Worker 3: Train Loss: 1.2686, Train Accuracy: 64.30%
# Total Computation Time: 2778.79 seconds
# Total Communication Time: 7.16 seconds
# Epoch 121/150: Test Loss: 1.9676, Test Accuracy: 50.97%
#     Worker 0: Train Loss: 1.2718, Train Accuracy: 63.98%
#     Worker 1: Train Loss: 1.2674, Train Accuracy: 64.00%
#     Worker 2: Train Loss: 1.2665, Train Accuracy: 63.96%
#     Worker 3: Train Loss: 1.2671, Train Accuracy: 64.37%
# Total Computation Time: 2801.77 seconds
# Total Communication Time: 7.22 seconds
# Epoch 122/150: Test Loss: 1.9618, Test Accuracy: 51.14%
#     Worker 0: Train Loss: 1.2533, Train Accuracy: 63.90%
#     Worker 1: Train Loss: 1.2627, Train Accuracy: 64.60%
#     Worker 2: Train Loss: 1.2631, Train Accuracy: 64.51%
#     Worker 3: Train Loss: 1.2745, Train Accuracy: 63.93%
# Total Computation Time: 2824.83 seconds
# Total Communication Time: 7.27 seconds
# Epoch 123/150: Test Loss: 1.9656, Test Accuracy: 51.27%
#     Worker 0: Train Loss: 1.2658, Train Accuracy: 63.62%
#     Worker 1: Train Loss: 1.2584, Train Accuracy: 64.96%
#     Worker 2: Train Loss: 1.2477, Train Accuracy: 65.25%
#     Worker 3: Train Loss: 1.2496, Train Accuracy: 64.67%
# Total Computation Time: 2847.55 seconds
# Total Communication Time: 7.33 seconds
# Epoch 124/150: Test Loss: 1.9606, Test Accuracy: 50.84%
#     Worker 0: Train Loss: 1.2569, Train Accuracy: 64.36%
#     Worker 1: Train Loss: 1.2534, Train Accuracy: 64.78%
#     Worker 2: Train Loss: 1.2589, Train Accuracy: 64.10%
#     Worker 3: Train Loss: 1.2607, Train Accuracy: 64.34%
# Total Computation Time: 2870.50 seconds
# Total Communication Time: 7.39 seconds
# Epoch 125/150: Test Loss: 1.9678, Test Accuracy: 51.13%
#     Worker 0: Train Loss: 1.2499, Train Accuracy: 64.22%
#     Worker 1: Train Loss: 1.2551, Train Accuracy: 64.68%
#     Worker 2: Train Loss: 1.2346, Train Accuracy: 65.61%
#     Worker 3: Train Loss: 1.2602, Train Accuracy: 64.49%
# Total Computation Time: 2893.61 seconds
# Total Communication Time: 7.45 seconds
# Epoch 126/150: Test Loss: 1.9629, Test Accuracy: 51.02%
#     Worker 0: Train Loss: 1.2557, Train Accuracy: 64.75%
#     Worker 1: Train Loss: 1.2651, Train Accuracy: 64.49%
#     Worker 2: Train Loss: 1.2516, Train Accuracy: 64.73%
#     Worker 3: Train Loss: 1.2605, Train Accuracy: 64.34%
# Total Computation Time: 2916.68 seconds
# Total Communication Time: 7.51 seconds
# Epoch 127/150: Test Loss: 1.9670, Test Accuracy: 50.97%
#     Worker 0: Train Loss: 1.2601, Train Accuracy: 64.09%
#     Worker 1: Train Loss: 1.2464, Train Accuracy: 64.74%
#     Worker 2: Train Loss: 1.2458, Train Accuracy: 64.71%
#     Worker 3: Train Loss: 1.2471, Train Accuracy: 65.31%
# Total Computation Time: 2939.89 seconds
# Total Communication Time: 7.58 seconds
# Epoch 128/150: Test Loss: 1.9681, Test Accuracy: 50.84%
#     Worker 0: Train Loss: 1.2459, Train Accuracy: 64.57%
#     Worker 1: Train Loss: 1.2459, Train Accuracy: 64.98%
#     Worker 2: Train Loss: 1.2455, Train Accuracy: 64.91%
#     Worker 3: Train Loss: 1.2550, Train Accuracy: 64.62%
# Total Computation Time: 2963.15 seconds
# Total Communication Time: 7.64 seconds
# Epoch 129/150: Test Loss: 1.9679, Test Accuracy: 50.89%
#     Worker 0: Train Loss: 1.2489, Train Accuracy: 64.42%
#     Worker 1: Train Loss: 1.2368, Train Accuracy: 65.14%
#     Worker 2: Train Loss: 1.2467, Train Accuracy: 64.79%
#     Worker 3: Train Loss: 1.2346, Train Accuracy: 65.10%
# Total Computation Time: 2986.45 seconds
# Total Communication Time: 7.70 seconds
# Epoch 130/150: Test Loss: 1.9656, Test Accuracy: 50.94%
#     Worker 0: Train Loss: 1.2400, Train Accuracy: 64.66%
#     Worker 1: Train Loss: 1.2412, Train Accuracy: 65.08%
#     Worker 2: Train Loss: 1.2267, Train Accuracy: 65.46%
#     Worker 3: Train Loss: 1.2335, Train Accuracy: 65.43%
# Total Computation Time: 3009.55 seconds
# Total Communication Time: 7.76 seconds
# Epoch 131/150: Test Loss: 1.9646, Test Accuracy: 50.92%
#     Worker 0: Train Loss: 1.2366, Train Accuracy: 65.11%
#     Worker 1: Train Loss: 1.2475, Train Accuracy: 64.86%
#     Worker 2: Train Loss: 1.2187, Train Accuracy: 66.06%
#     Worker 3: Train Loss: 1.2536, Train Accuracy: 64.68%
# Total Computation Time: 3032.68 seconds
# Total Communication Time: 7.82 seconds
# Epoch 132/150: Test Loss: 1.9636, Test Accuracy: 51.09%
#     Worker 0: Train Loss: 1.2450, Train Accuracy: 64.38%
#     Worker 1: Train Loss: 1.2416, Train Accuracy: 65.06%
#     Worker 2: Train Loss: 1.2183, Train Accuracy: 65.27%
#     Worker 3: Train Loss: 1.2390, Train Accuracy: 65.43%
# Total Computation Time: 3056.92 seconds
# Total Communication Time: 7.89 seconds
# Epoch 133/150: Test Loss: 1.9639, Test Accuracy: 50.98%
#     Worker 0: Train Loss: 1.2369, Train Accuracy: 64.90%
#     Worker 1: Train Loss: 1.2299, Train Accuracy: 65.54%
#     Worker 2: Train Loss: 1.2336, Train Accuracy: 65.41%
#     Worker 3: Train Loss: 1.2295, Train Accuracy: 65.22%
# Total Computation Time: 3081.44 seconds
# Total Communication Time: 7.95 seconds
# Epoch 134/150: Test Loss: 1.9630, Test Accuracy: 51.20%
#     Worker 0: Train Loss: 1.2387, Train Accuracy: 64.85%
#     Worker 1: Train Loss: 1.2242, Train Accuracy: 65.40%
#     Worker 2: Train Loss: 1.2199, Train Accuracy: 65.11%
#     Worker 3: Train Loss: 1.2418, Train Accuracy: 64.74%
# Total Computation Time: 3105.88 seconds
# Total Communication Time: 8.01 seconds
# Epoch 135/150: Test Loss: 1.9603, Test Accuracy: 51.14%
#     Worker 0: Train Loss: 1.2463, Train Accuracy: 64.42%
#     Worker 1: Train Loss: 1.2309, Train Accuracy: 65.76%
#     Worker 2: Train Loss: 1.2251, Train Accuracy: 65.62%
#     Worker 3: Train Loss: 1.2336, Train Accuracy: 64.57%
# Total Computation Time: 3130.49 seconds
# Total Communication Time: 8.07 seconds
# Epoch 136/150: Test Loss: 1.9634, Test Accuracy: 51.13%
#     Worker 0: Train Loss: 1.2309, Train Accuracy: 64.86%
#     Worker 1: Train Loss: 1.2377, Train Accuracy: 64.99%
#     Worker 2: Train Loss: 1.2168, Train Accuracy: 66.01%
#     Worker 3: Train Loss: 1.2130, Train Accuracy: 65.66%
# Total Computation Time: 3154.67 seconds
# Total Communication Time: 8.13 seconds
# Epoch 137/150: Test Loss: 1.9628, Test Accuracy: 51.01%
#     Worker 0: Train Loss: 1.2390, Train Accuracy: 64.25%
#     Worker 1: Train Loss: 1.2329, Train Accuracy: 65.34%
#     Worker 2: Train Loss: 1.2076, Train Accuracy: 66.22%
#     Worker 3: Train Loss: 1.2373, Train Accuracy: 65.38%
# Total Computation Time: 3178.50 seconds
# Total Communication Time: 8.19 seconds
# Epoch 138/150: Test Loss: 1.9619, Test Accuracy: 51.16%
#     Worker 0: Train Loss: 1.2259, Train Accuracy: 65.27%
#     Worker 1: Train Loss: 1.2240, Train Accuracy: 66.01%
#     Worker 2: Train Loss: 1.2260, Train Accuracy: 65.23%
#     Worker 3: Train Loss: 1.2212, Train Accuracy: 65.56%
# Total Computation Time: 3202.68 seconds
# Total Communication Time: 8.25 seconds
# Epoch 139/150: Test Loss: 1.9617, Test Accuracy: 51.20%
#     Worker 0: Train Loss: 1.2304, Train Accuracy: 65.03%
#     Worker 1: Train Loss: 1.2311, Train Accuracy: 65.23%
#     Worker 2: Train Loss: 1.2128, Train Accuracy: 65.52%
#     Worker 3: Train Loss: 1.2382, Train Accuracy: 65.32%
# Total Computation Time: 3226.28 seconds
# Total Communication Time: 8.31 seconds
# Epoch 140/150: Test Loss: 1.9614, Test Accuracy: 51.07%
#     Worker 0: Train Loss: 1.2204, Train Accuracy: 65.14%
#     Worker 1: Train Loss: 1.2267, Train Accuracy: 65.63%
#     Worker 2: Train Loss: 1.2228, Train Accuracy: 65.54%
#     Worker 3: Train Loss: 1.2158, Train Accuracy: 65.54%
# Total Computation Time: 3249.89 seconds
# Total Communication Time: 8.37 seconds
# Epoch 141/150: Test Loss: 1.9609, Test Accuracy: 51.04%
#     Worker 0: Train Loss: 1.2305, Train Accuracy: 65.10%
#     Worker 1: Train Loss: 1.2159, Train Accuracy: 65.93%
#     Worker 2: Train Loss: 1.2186, Train Accuracy: 65.89%
#     Worker 3: Train Loss: 1.2201, Train Accuracy: 65.54%
# Total Computation Time: 3273.23 seconds
# Total Communication Time: 8.43 seconds
# Epoch 142/150: Test Loss: 1.9622, Test Accuracy: 51.15%
#     Worker 0: Train Loss: 1.2271, Train Accuracy: 65.61%
#     Worker 1: Train Loss: 1.2114, Train Accuracy: 65.49%
#     Worker 2: Train Loss: 1.2034, Train Accuracy: 66.17%
#     Worker 3: Train Loss: 1.2204, Train Accuracy: 65.54%
# Total Computation Time: 3296.90 seconds
# Total Communication Time: 8.49 seconds
# Epoch 143/150: Test Loss: 1.9610, Test Accuracy: 51.15%
#     Worker 0: Train Loss: 1.2218, Train Accuracy: 65.19%
#     Worker 1: Train Loss: 1.2184, Train Accuracy: 65.98%
#     Worker 2: Train Loss: 1.2040, Train Accuracy: 66.40%
#     Worker 3: Train Loss: 1.2277, Train Accuracy: 65.17%
# Total Computation Time: 3320.43 seconds
# Total Communication Time: 8.55 seconds
# Epoch 144/150: Test Loss: 1.9621, Test Accuracy: 51.17%
#     Worker 0: Train Loss: 1.2159, Train Accuracy: 65.28%
#     Worker 1: Train Loss: 1.2192, Train Accuracy: 65.69%
#     Worker 2: Train Loss: 1.2185, Train Accuracy: 65.83%
#     Worker 3: Train Loss: 1.2150, Train Accuracy: 65.98%
# Total Computation Time: 3343.81 seconds
# Total Communication Time: 8.61 seconds
# Epoch 145/150: Test Loss: 1.9618, Test Accuracy: 51.06%
#     Worker 0: Train Loss: 1.2278, Train Accuracy: 64.91%
#     Worker 1: Train Loss: 1.2145, Train Accuracy: 65.81%
#     Worker 2: Train Loss: 1.2130, Train Accuracy: 65.74%
#     Worker 3: Train Loss: 1.2111, Train Accuracy: 65.97%
# Total Computation Time: 3366.91 seconds
# Total Communication Time: 8.68 seconds
# Epoch 146/150: Test Loss: 1.9616, Test Accuracy: 51.12%
#     Worker 0: Train Loss: 1.2172, Train Accuracy: 64.98%
#     Worker 1: Train Loss: 1.2136, Train Accuracy: 66.01%
#     Worker 2: Train Loss: 1.1997, Train Accuracy: 66.45%
#     Worker 3: Train Loss: 1.2183, Train Accuracy: 65.93%
# Total Computation Time: 3389.98 seconds
# Total Communication Time: 8.74 seconds
# Epoch 147/150: Test Loss: 1.9618, Test Accuracy: 51.09%
#     Worker 0: Train Loss: 1.2285, Train Accuracy: 65.28%
#     Worker 1: Train Loss: 1.2210, Train Accuracy: 65.86%
#     Worker 2: Train Loss: 1.2244, Train Accuracy: 65.81%
#     Worker 3: Train Loss: 1.2296, Train Accuracy: 65.66%
# Total Computation Time: 3413.02 seconds
# Total Communication Time: 8.80 seconds
# Epoch 148/150: Test Loss: 1.9618, Test Accuracy: 51.05%
#     Worker 0: Train Loss: 1.2165, Train Accuracy: 65.21%
#     Worker 1: Train Loss: 1.2201, Train Accuracy: 66.08%
#     Worker 2: Train Loss: 1.2055, Train Accuracy: 66.18%
#     Worker 3: Train Loss: 1.2224, Train Accuracy: 65.08%
# Total Computation Time: 3436.02 seconds
# Total Communication Time: 8.85 seconds
# Epoch 149/150: Test Loss: 1.9618, Test Accuracy: 51.09%
#     Worker 0: Train Loss: 1.2090, Train Accuracy: 65.50%
#     Worker 1: Train Loss: 1.2075, Train Accuracy: 66.16%
#     Worker 2: Train Loss: 1.2118, Train Accuracy: 65.64%
#     Worker 3: Train Loss: 1.2147, Train Accuracy: 66.16%
# Total Computation Time: 3459.00 seconds
# Total Communication Time: 8.91 seconds
# Epoch 150/150: Test Loss: 1.9618, Test Accuracy: 51.10%
#     Worker 0: Train Loss: 1.2319, Train Accuracy: 64.94%
#     Worker 1: Train Loss: 1.2215, Train Accuracy: 65.77%
#     Worker 2: Train Loss: 1.2048, Train Accuracy: 65.86%
#     Worker 3: Train Loss: 1.2202, Train Accuracy: 65.68%
# Total Computation Time: 3482.01 seconds
# Total Communication Time: 8.97 seconds
