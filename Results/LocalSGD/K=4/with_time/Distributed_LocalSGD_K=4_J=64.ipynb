# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files
import time

total_computation_time = 0
total_communication_time = 0

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
#warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")

    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch):
        computation_start_time = time.time()
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            # Perform J local step before synchronization
            for j in range(J):
                try:
                    # Get a batch from the current worker's shard using next()
                    images, labels = next(shard_iterators[k])
                    images, labels = images.to(device), labels.to(device)  # Move to device
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

                except StopIteration:
                    # If the iterator has exhausted the data, restart the iterator
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k]) # Resume from the next batch
                    images, labels = images.to(device), labels.to(device)
                    # Perform optimization step
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        computation_end_time = time.time()
        total_computation_time += (computation_end_time - computation_start_time)

        communication_start_time = time.time()
        # Perform model synchronization
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            # Update each worker model with the global parameters
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

        communication_end_time = time.time()
        total_communication_time += (communication_end_time - communication_start_time)

    # Update lr for each scheduler
    for scheduler in schedulers:
       # if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
       # else:
        #    warmup_factor = (epoch + 1) / warmup_epochs
          #  lr = warmup_factor * learning_rate
          #  for optimizer in optimizers:
           #     for param_group in optimizer.param_groups:
            #        param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

    print(f"Total Computation Time: {total_computation_time:.2f} seconds")
    print(f"Total Communication Time: {total_communication_time:.2f} seconds")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 4 --j 64
# Out:
# Training with K=4, J=64
# Global iteration per epoch: 4
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:05<00:00, 30.8MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00400
# Epoch 1/150: Test Loss: 4.5518, Test Accuracy: 3.20%
#     Worker 0: Train Loss: 4.5942, Train Accuracy: 1.51%
#     Worker 1: Train Loss: 4.5939, Train Accuracy: 1.36%
#     Worker 2: Train Loss: 4.5922, Train Accuracy: 1.83%
#     Worker 3: Train Loss: 4.5941, Train Accuracy: 1.55%
# Total Computation Time: 31.66 seconds
# Total Communication Time: 0.03 seconds
# Epoch 2/150: Test Loss: 4.0774, Test Accuracy: 7.30%
#     Worker 0: Train Loss: 4.3460, Train Accuracy: 4.28%
#     Worker 1: Train Loss: 4.3462, Train Accuracy: 4.60%
#     Worker 2: Train Loss: 4.3259, Train Accuracy: 4.63%
#     Worker 3: Train Loss: 4.3474, Train Accuracy: 4.38%
# Total Computation Time: 61.23 seconds
# Total Communication Time: 0.04 seconds
# Epoch 3/150: Test Loss: 3.8886, Test Accuracy: 10.51%
#     Worker 0: Train Loss: 4.0529, Train Accuracy: 7.52%
#     Worker 1: Train Loss: 4.0701, Train Accuracy: 7.48%
#     Worker 2: Train Loss: 4.0304, Train Accuracy: 7.75%
#     Worker 3: Train Loss: 4.0608, Train Accuracy: 7.72%
# Total Computation Time: 91.43 seconds
# Total Communication Time: 0.04 seconds
# Epoch 4/150: Test Loss: 3.7153, Test Accuracy: 13.34%
#     Worker 0: Train Loss: 3.8973, Train Accuracy: 9.98%
#     Worker 1: Train Loss: 3.9107, Train Accuracy: 9.77%
#     Worker 2: Train Loss: 3.8658, Train Accuracy: 10.52%
#     Worker 3: Train Loss: 3.9014, Train Accuracy: 10.05%
# Total Computation Time: 121.72 seconds
# Total Communication Time: 0.05 seconds
# Epoch 5/150: Test Loss: 3.5948, Test Accuracy: 15.76%
#     Worker 0: Train Loss: 3.7861, Train Accuracy: 11.66%
#     Worker 1: Train Loss: 3.7708, Train Accuracy: 11.93%
#     Worker 2: Train Loss: 3.7174, Train Accuracy: 13.19%
#     Worker 3: Train Loss: 3.7819, Train Accuracy: 11.48%
# Total Computation Time: 152.25 seconds
# Total Communication Time: 0.05 seconds
# Epoch 6/150: Test Loss: 3.4820, Test Accuracy: 17.97%
#     Worker 0: Train Loss: 3.6581, Train Accuracy: 14.05%
#     Worker 1: Train Loss: 3.6756, Train Accuracy: 13.84%
#     Worker 2: Train Loss: 3.6320, Train Accuracy: 14.00%
#     Worker 3: Train Loss: 3.6601, Train Accuracy: 14.00%
# Total Computation Time: 182.64 seconds
# Total Communication Time: 0.06 seconds
# Epoch 7/150: Test Loss: 3.3686, Test Accuracy: 19.59%
#     Worker 0: Train Loss: 3.5486, Train Accuracy: 15.04%
#     Worker 1: Train Loss: 3.5542, Train Accuracy: 15.75%
#     Worker 2: Train Loss: 3.5172, Train Accuracy: 16.03%
#     Worker 3: Train Loss: 3.5576, Train Accuracy: 15.32%
# Total Computation Time: 213.05 seconds
# Total Communication Time: 0.06 seconds
# Epoch 8/150: Test Loss: 3.2773, Test Accuracy: 21.23%
#     Worker 0: Train Loss: 3.4769, Train Accuracy: 16.77%
#     Worker 1: Train Loss: 3.4700, Train Accuracy: 17.43%
#     Worker 2: Train Loss: 3.4237, Train Accuracy: 17.97%
#     Worker 3: Train Loss: 3.4675, Train Accuracy: 16.96%
# Total Computation Time: 242.77 seconds
# Total Communication Time: 0.07 seconds
# Epoch 9/150: Test Loss: 3.2082, Test Accuracy: 22.65%
#     Worker 0: Train Loss: 3.3746, Train Accuracy: 18.46%
#     Worker 1: Train Loss: 3.4005, Train Accuracy: 18.22%
#     Worker 2: Train Loss: 3.3248, Train Accuracy: 19.59%
#     Worker 3: Train Loss: 3.3890, Train Accuracy: 18.62%
# Total Computation Time: 273.06 seconds
# Total Communication Time: 0.07 seconds
# Epoch 10/150: Test Loss: 3.0874, Test Accuracy: 24.62%
#     Worker 0: Train Loss: 3.2766, Train Accuracy: 19.99%
#     Worker 1: Train Loss: 3.3070, Train Accuracy: 19.77%
#     Worker 2: Train Loss: 3.2336, Train Accuracy: 21.15%
#     Worker 3: Train Loss: 3.3022, Train Accuracy: 20.21%
# Total Computation Time: 303.50 seconds
# Total Communication Time: 0.08 seconds
# Epoch 11/150: Test Loss: 3.0167, Test Accuracy: 26.35%
#     Worker 0: Train Loss: 3.2113, Train Accuracy: 21.08%
#     Worker 1: Train Loss: 3.2244, Train Accuracy: 21.39%
#     Worker 2: Train Loss: 3.1795, Train Accuracy: 21.88%
#     Worker 3: Train Loss: 3.2460, Train Accuracy: 20.81%
# Total Computation Time: 333.16 seconds
# Total Communication Time: 0.08 seconds
# Epoch 12/150: Test Loss: 2.9579, Test Accuracy: 27.02%
#     Worker 0: Train Loss: 3.1533, Train Accuracy: 21.98%
#     Worker 1: Train Loss: 3.1738, Train Accuracy: 22.08%
#     Worker 2: Train Loss: 3.1112, Train Accuracy: 23.30%
#     Worker 3: Train Loss: 3.1508, Train Accuracy: 22.31%
# Total Computation Time: 363.68 seconds
# Total Communication Time: 0.09 seconds
# Epoch 13/150: Test Loss: 2.8933, Test Accuracy: 28.74%
#     Worker 0: Train Loss: 3.0832, Train Accuracy: 23.84%
#     Worker 1: Train Loss: 3.1059, Train Accuracy: 23.88%
#     Worker 2: Train Loss: 3.0610, Train Accuracy: 24.47%
#     Worker 3: Train Loss: 3.0987, Train Accuracy: 23.75%
# Total Computation Time: 393.83 seconds
# Total Communication Time: 0.09 seconds
# Epoch 14/150: Test Loss: 2.8420, Test Accuracy: 29.03%
#     Worker 0: Train Loss: 3.0275, Train Accuracy: 24.62%
#     Worker 1: Train Loss: 3.0406, Train Accuracy: 24.88%
#     Worker 2: Train Loss: 3.0083, Train Accuracy: 25.41%
#     Worker 3: Train Loss: 3.0400, Train Accuracy: 24.77%
# Total Computation Time: 423.50 seconds
# Total Communication Time: 0.10 seconds
# Epoch 15/150: Test Loss: 2.7939, Test Accuracy: 29.66%
#     Worker 0: Train Loss: 2.9815, Train Accuracy: 25.69%
#     Worker 1: Train Loss: 2.9873, Train Accuracy: 26.13%
#     Worker 2: Train Loss: 2.9477, Train Accuracy: 26.62%
#     Worker 3: Train Loss: 2.9956, Train Accuracy: 25.75%
# Total Computation Time: 454.02 seconds
# Total Communication Time: 0.10 seconds
# Epoch 16/150: Test Loss: 2.7415, Test Accuracy: 31.47%
#     Worker 0: Train Loss: 2.9352, Train Accuracy: 26.87%
#     Worker 1: Train Loss: 2.9366, Train Accuracy: 27.16%
#     Worker 2: Train Loss: 2.9052, Train Accuracy: 27.26%
#     Worker 3: Train Loss: 2.9364, Train Accuracy: 26.65%
# Total Computation Time: 484.39 seconds
# Total Communication Time: 0.11 seconds
# Epoch 17/150: Test Loss: 2.7054, Test Accuracy: 32.03%
#     Worker 0: Train Loss: 2.8713, Train Accuracy: 28.08%
#     Worker 1: Train Loss: 2.9036, Train Accuracy: 26.99%
#     Worker 2: Train Loss: 2.8485, Train Accuracy: 28.57%
#     Worker 3: Train Loss: 2.8870, Train Accuracy: 27.57%
# Total Computation Time: 514.33 seconds
# Total Communication Time: 0.11 seconds
# Epoch 18/150: Test Loss: 2.6546, Test Accuracy: 33.19%
#     Worker 0: Train Loss: 2.8327, Train Accuracy: 28.48%
#     Worker 1: Train Loss: 2.8443, Train Accuracy: 28.23%
#     Worker 2: Train Loss: 2.8175, Train Accuracy: 29.02%
#     Worker 3: Train Loss: 2.8372, Train Accuracy: 28.53%
# Total Computation Time: 544.92 seconds
# Total Communication Time: 0.12 seconds
# Epoch 19/150: Test Loss: 2.6361, Test Accuracy: 33.64%
#     Worker 0: Train Loss: 2.7793, Train Accuracy: 29.52%
#     Worker 1: Train Loss: 2.7943, Train Accuracy: 29.36%
#     Worker 2: Train Loss: 2.7609, Train Accuracy: 30.04%
#     Worker 3: Train Loss: 2.7970, Train Accuracy: 29.38%
# Total Computation Time: 575.32 seconds
# Total Communication Time: 0.12 seconds
# Epoch 20/150: Test Loss: 2.5721, Test Accuracy: 35.25%
#     Worker 0: Train Loss: 2.7261, Train Accuracy: 30.74%
#     Worker 1: Train Loss: 2.7517, Train Accuracy: 30.65%
#     Worker 2: Train Loss: 2.7204, Train Accuracy: 31.14%
#     Worker 3: Train Loss: 2.7457, Train Accuracy: 30.23%
# Total Computation Time: 605.15 seconds
# Total Communication Time: 0.13 seconds
# Epoch 21/150: Test Loss: 2.5293, Test Accuracy: 35.63%
#     Worker 0: Train Loss: 2.6616, Train Accuracy: 32.20%
#     Worker 1: Train Loss: 2.6908, Train Accuracy: 31.57%
#     Worker 2: Train Loss: 2.6707, Train Accuracy: 32.09%
#     Worker 3: Train Loss: 2.7008, Train Accuracy: 30.69%
# Total Computation Time: 635.84 seconds
# Total Communication Time: 0.13 seconds
# Epoch 22/150: Test Loss: 2.4811, Test Accuracy: 36.65%
#     Worker 0: Train Loss: 2.6328, Train Accuracy: 31.88%
#     Worker 1: Train Loss: 2.6723, Train Accuracy: 31.87%
#     Worker 2: Train Loss: 2.6243, Train Accuracy: 33.13%
#     Worker 3: Train Loss: 2.6463, Train Accuracy: 32.34%
# Total Computation Time: 665.95 seconds
# Total Communication Time: 0.14 seconds
# Epoch 23/150: Test Loss: 2.4450, Test Accuracy: 37.17%
#     Worker 0: Train Loss: 2.5944, Train Accuracy: 33.54%
#     Worker 1: Train Loss: 2.6295, Train Accuracy: 32.86%
#     Worker 2: Train Loss: 2.5790, Train Accuracy: 34.08%
#     Worker 3: Train Loss: 2.6163, Train Accuracy: 33.17%
# Total Computation Time: 695.80 seconds
# Total Communication Time: 0.14 seconds
# Epoch 24/150: Test Loss: 2.4121, Test Accuracy: 38.32%
#     Worker 0: Train Loss: 2.5519, Train Accuracy: 34.41%
#     Worker 1: Train Loss: 2.5821, Train Accuracy: 33.86%
#     Worker 2: Train Loss: 2.5277, Train Accuracy: 34.70%
#     Worker 3: Train Loss: 2.5677, Train Accuracy: 33.54%
# Total Computation Time: 726.20 seconds
# Total Communication Time: 0.15 seconds
# Epoch 25/150: Test Loss: 2.3918, Test Accuracy: 38.42%
#     Worker 0: Train Loss: 2.5193, Train Accuracy: 34.78%
#     Worker 1: Train Loss: 2.5520, Train Accuracy: 34.72%
#     Worker 2: Train Loss: 2.4964, Train Accuracy: 35.73%
#     Worker 3: Train Loss: 2.5408, Train Accuracy: 34.10%
# Total Computation Time: 756.19 seconds
# Total Communication Time: 0.15 seconds
# Epoch 26/150: Test Loss: 2.3574, Test Accuracy: 39.33%
#     Worker 0: Train Loss: 2.4882, Train Accuracy: 35.70%
#     Worker 1: Train Loss: 2.5164, Train Accuracy: 34.99%
#     Worker 2: Train Loss: 2.4745, Train Accuracy: 36.05%
#     Worker 3: Train Loss: 2.5070, Train Accuracy: 34.65%
# Total Computation Time: 786.39 seconds
# Total Communication Time: 0.16 seconds
# Epoch 27/150: Test Loss: 2.3269, Test Accuracy: 39.92%
#     Worker 0: Train Loss: 2.4467, Train Accuracy: 36.38%
#     Worker 1: Train Loss: 2.4659, Train Accuracy: 36.06%
#     Worker 2: Train Loss: 2.4320, Train Accuracy: 36.51%
#     Worker 3: Train Loss: 2.4474, Train Accuracy: 36.61%
# Total Computation Time: 816.96 seconds
# Total Communication Time: 0.16 seconds
# Epoch 28/150: Test Loss: 2.2953, Test Accuracy: 40.38%
#     Worker 0: Train Loss: 2.4192, Train Accuracy: 36.80%
#     Worker 1: Train Loss: 2.4479, Train Accuracy: 36.76%
#     Worker 2: Train Loss: 2.3957, Train Accuracy: 38.15%
#     Worker 3: Train Loss: 2.4260, Train Accuracy: 36.76%
# Total Computation Time: 847.02 seconds
# Total Communication Time: 0.17 seconds
# Epoch 29/150: Test Loss: 2.3040, Test Accuracy: 39.74%
#     Worker 0: Train Loss: 2.3883, Train Accuracy: 37.64%
#     Worker 1: Train Loss: 2.3981, Train Accuracy: 37.69%
#     Worker 2: Train Loss: 2.3766, Train Accuracy: 37.93%
#     Worker 3: Train Loss: 2.4068, Train Accuracy: 37.22%
# Total Computation Time: 876.61 seconds
# Total Communication Time: 0.17 seconds
# Epoch 30/150: Test Loss: 2.2586, Test Accuracy: 41.84%
#     Worker 0: Train Loss: 2.3673, Train Accuracy: 37.74%
#     Worker 1: Train Loss: 2.3702, Train Accuracy: 38.14%
#     Worker 2: Train Loss: 2.3256, Train Accuracy: 38.74%
#     Worker 3: Train Loss: 2.3725, Train Accuracy: 38.21%
# Total Computation Time: 907.42 seconds
# Total Communication Time: 0.18 seconds
# Epoch 31/150: Test Loss: 2.2347, Test Accuracy: 41.89%
#     Worker 0: Train Loss: 2.3193, Train Accuracy: 39.64%
#     Worker 1: Train Loss: 2.3395, Train Accuracy: 38.65%
#     Worker 2: Train Loss: 2.3169, Train Accuracy: 39.11%
#     Worker 3: Train Loss: 2.3342, Train Accuracy: 38.77%
# Total Computation Time: 937.29 seconds
# Total Communication Time: 0.18 seconds
# Epoch 32/150: Test Loss: 2.2142, Test Accuracy: 42.25%
#     Worker 0: Train Loss: 2.2725, Train Accuracy: 40.45%
#     Worker 1: Train Loss: 2.3113, Train Accuracy: 39.50%
#     Worker 2: Train Loss: 2.2856, Train Accuracy: 40.31%
#     Worker 3: Train Loss: 2.3161, Train Accuracy: 39.38%
# Total Computation Time: 967.02 seconds
# Total Communication Time: 0.19 seconds
# Epoch 33/150: Test Loss: 2.2066, Test Accuracy: 42.52%
#     Worker 0: Train Loss: 2.2844, Train Accuracy: 39.81%
#     Worker 1: Train Loss: 2.2863, Train Accuracy: 40.13%
#     Worker 2: Train Loss: 2.2635, Train Accuracy: 40.59%
#     Worker 3: Train Loss: 2.2863, Train Accuracy: 39.81%
# Total Computation Time: 997.10 seconds
# Total Communication Time: 0.19 seconds
# Epoch 34/150: Test Loss: 2.1984, Test Accuracy: 42.98%
#     Worker 0: Train Loss: 2.2582, Train Accuracy: 40.23%
#     Worker 1: Train Loss: 2.2545, Train Accuracy: 40.78%
#     Worker 2: Train Loss: 2.2222, Train Accuracy: 41.10%
#     Worker 3: Train Loss: 2.2500, Train Accuracy: 40.21%
# Total Computation Time: 1026.75 seconds
# Total Communication Time: 0.20 seconds
# Epoch 35/150: Test Loss: 2.1775, Test Accuracy: 43.23%
#     Worker 0: Train Loss: 2.2217, Train Accuracy: 41.59%
#     Worker 1: Train Loss: 2.2271, Train Accuracy: 41.35%
#     Worker 2: Train Loss: 2.2173, Train Accuracy: 41.71%
#     Worker 3: Train Loss: 2.2485, Train Accuracy: 40.76%
# Total Computation Time: 1056.72 seconds
# Total Communication Time: 0.20 seconds
# Epoch 36/150: Test Loss: 2.1579, Test Accuracy: 43.85%
#     Worker 0: Train Loss: 2.1893, Train Accuracy: 41.62%
#     Worker 1: Train Loss: 2.2113, Train Accuracy: 41.61%
#     Worker 2: Train Loss: 2.1877, Train Accuracy: 42.37%
#     Worker 3: Train Loss: 2.2139, Train Accuracy: 41.61%
# Total Computation Time: 1086.97 seconds
# Total Communication Time: 0.21 seconds
# Epoch 37/150: Test Loss: 2.1491, Test Accuracy: 44.02%
#     Worker 0: Train Loss: 2.1795, Train Accuracy: 42.01%
#     Worker 1: Train Loss: 2.1860, Train Accuracy: 42.34%
#     Worker 2: Train Loss: 2.1614, Train Accuracy: 42.87%
#     Worker 3: Train Loss: 2.1882, Train Accuracy: 42.24%
# Total Computation Time: 1116.81 seconds
# Total Communication Time: 0.21 seconds
# Epoch 38/150: Test Loss: 2.1392, Test Accuracy: 44.17%
#     Worker 0: Train Loss: 2.1688, Train Accuracy: 42.06%
#     Worker 1: Train Loss: 2.1625, Train Accuracy: 42.72%
#     Worker 2: Train Loss: 2.1241, Train Accuracy: 43.47%
#     Worker 3: Train Loss: 2.1614, Train Accuracy: 42.85%
# Total Computation Time: 1147.25 seconds
# Total Communication Time: 0.22 seconds
# Epoch 39/150: Test Loss: 2.1338, Test Accuracy: 43.96%
#     Worker 0: Train Loss: 2.1360, Train Accuracy: 43.17%
#     Worker 1: Train Loss: 2.1466, Train Accuracy: 43.11%
#     Worker 2: Train Loss: 2.1187, Train Accuracy: 43.59%
#     Worker 3: Train Loss: 2.1343, Train Accuracy: 43.24%
# Total Computation Time: 1177.76 seconds
# Total Communication Time: 0.22 seconds
# Epoch 40/150: Test Loss: 2.1010, Test Accuracy: 45.30%
#     Worker 0: Train Loss: 2.1244, Train Accuracy: 43.16%
#     Worker 1: Train Loss: 2.1001, Train Accuracy: 44.48%
#     Worker 2: Train Loss: 2.1047, Train Accuracy: 43.72%
#     Worker 3: Train Loss: 2.1070, Train Accuracy: 43.63%
# Total Computation Time: 1207.09 seconds
# Total Communication Time: 0.23 seconds
# Epoch 41/150: Test Loss: 2.0865, Test Accuracy: 45.50%
#     Worker 0: Train Loss: 2.0838, Train Accuracy: 44.11%
#     Worker 1: Train Loss: 2.0885, Train Accuracy: 44.08%
#     Worker 2: Train Loss: 2.0819, Train Accuracy: 44.45%
#     Worker 3: Train Loss: 2.0865, Train Accuracy: 44.29%
# Total Computation Time: 1237.14 seconds
# Total Communication Time: 0.23 seconds
# Epoch 42/150: Test Loss: 2.0746, Test Accuracy: 45.37%
#     Worker 0: Train Loss: 2.0755, Train Accuracy: 44.50%
#     Worker 1: Train Loss: 2.0831, Train Accuracy: 43.90%
#     Worker 2: Train Loss: 2.0352, Train Accuracy: 45.62%
#     Worker 3: Train Loss: 2.0851, Train Accuracy: 44.59%
# Total Computation Time: 1266.35 seconds
# Total Communication Time: 0.24 seconds
# Epoch 43/150: Test Loss: 2.0677, Test Accuracy: 46.01%
#     Worker 0: Train Loss: 2.0443, Train Accuracy: 44.94%
#     Worker 1: Train Loss: 2.0346, Train Accuracy: 45.85%
#     Worker 2: Train Loss: 2.0357, Train Accuracy: 45.80%
#     Worker 3: Train Loss: 2.0449, Train Accuracy: 45.31%
# Total Computation Time: 1295.85 seconds
# Total Communication Time: 0.24 seconds
# Epoch 44/150: Test Loss: 2.0669, Test Accuracy: 45.86%
#     Worker 0: Train Loss: 2.0269, Train Accuracy: 45.73%
#     Worker 1: Train Loss: 2.0174, Train Accuracy: 45.84%
#     Worker 2: Train Loss: 2.0124, Train Accuracy: 46.18%
#     Worker 3: Train Loss: 2.0423, Train Accuracy: 45.84%
# Total Computation Time: 1325.60 seconds
# Total Communication Time: 0.25 seconds
# Epoch 45/150: Test Loss: 2.0610, Test Accuracy: 46.01%
#     Worker 0: Train Loss: 2.0246, Train Accuracy: 45.20%
#     Worker 1: Train Loss: 2.0353, Train Accuracy: 45.22%
#     Worker 2: Train Loss: 2.0102, Train Accuracy: 46.30%
#     Worker 3: Train Loss: 2.0035, Train Accuracy: 46.87%
# Total Computation Time: 1355.07 seconds
# Total Communication Time: 0.25 seconds
# Epoch 46/150: Test Loss: 2.0589, Test Accuracy: 46.09%
#     Worker 0: Train Loss: 1.9915, Train Accuracy: 46.33%
#     Worker 1: Train Loss: 1.9917, Train Accuracy: 46.59%
#     Worker 2: Train Loss: 1.9590, Train Accuracy: 47.43%
#     Worker 3: Train Loss: 1.9887, Train Accuracy: 46.53%
# Total Computation Time: 1384.73 seconds
# Total Communication Time: 0.26 seconds
# Epoch 47/150: Test Loss: 2.0436, Test Accuracy: 46.25%
#     Worker 0: Train Loss: 1.9726, Train Accuracy: 46.24%
#     Worker 1: Train Loss: 1.9732, Train Accuracy: 46.99%
#     Worker 2: Train Loss: 1.9503, Train Accuracy: 47.55%
#     Worker 3: Train Loss: 1.9720, Train Accuracy: 47.09%
# Total Computation Time: 1413.90 seconds
# Total Communication Time: 0.26 seconds
# Epoch 48/150: Test Loss: 2.0352, Test Accuracy: 46.70%
#     Worker 0: Train Loss: 1.9549, Train Accuracy: 47.25%
#     Worker 1: Train Loss: 1.9386, Train Accuracy: 48.08%
#     Worker 2: Train Loss: 1.9492, Train Accuracy: 47.66%
#     Worker 3: Train Loss: 1.9425, Train Accuracy: 47.78%
# Total Computation Time: 1443.58 seconds
# Total Communication Time: 0.26 seconds
# Epoch 49/150: Test Loss: 2.0325, Test Accuracy: 46.79%
#     Worker 0: Train Loss: 1.9452, Train Accuracy: 47.24%
#     Worker 1: Train Loss: 1.9581, Train Accuracy: 47.73%
#     Worker 2: Train Loss: 1.9170, Train Accuracy: 48.01%
#     Worker 3: Train Loss: 1.9435, Train Accuracy: 47.64%
# Total Computation Time: 1473.32 seconds
# Total Communication Time: 0.27 seconds
# Epoch 50/150: Test Loss: 2.0102, Test Accuracy: 47.13%
#     Worker 0: Train Loss: 1.9139, Train Accuracy: 48.26%
#     Worker 1: Train Loss: 1.9210, Train Accuracy: 47.83%
#     Worker 2: Train Loss: 1.8976, Train Accuracy: 49.04%
#     Worker 3: Train Loss: 1.9121, Train Accuracy: 48.31%
# Total Computation Time: 1502.47 seconds
# Total Communication Time: 0.27 seconds
# Epoch 51/150: Test Loss: 2.0080, Test Accuracy: 47.33%
#     Worker 0: Train Loss: 1.9089, Train Accuracy: 47.71%
#     Worker 1: Train Loss: 1.9216, Train Accuracy: 48.26%
#     Worker 2: Train Loss: 1.8969, Train Accuracy: 48.53%
#     Worker 3: Train Loss: 1.9041, Train Accuracy: 48.35%
# Total Computation Time: 1532.31 seconds
# Total Communication Time: 0.28 seconds
# Epoch 52/150: Test Loss: 1.9994, Test Accuracy: 47.95%
#     Worker 0: Train Loss: 1.8907, Train Accuracy: 48.65%
#     Worker 1: Train Loss: 1.8854, Train Accuracy: 48.90%
#     Worker 2: Train Loss: 1.8809, Train Accuracy: 49.01%
#     Worker 3: Train Loss: 1.8975, Train Accuracy: 48.51%
# Total Computation Time: 1561.50 seconds
# Total Communication Time: 0.28 seconds
# Epoch 53/150: Test Loss: 1.9982, Test Accuracy: 47.54%
#     Worker 0: Train Loss: 1.8659, Train Accuracy: 49.01%
#     Worker 1: Train Loss: 1.8610, Train Accuracy: 49.53%
#     Worker 2: Train Loss: 1.8484, Train Accuracy: 49.63%
#     Worker 3: Train Loss: 1.8665, Train Accuracy: 49.74%
# Total Computation Time: 1590.71 seconds
# Total Communication Time: 0.29 seconds
# Epoch 54/150: Test Loss: 2.0006, Test Accuracy: 47.75%
#     Worker 0: Train Loss: 1.8494, Train Accuracy: 49.49%
#     Worker 1: Train Loss: 1.8394, Train Accuracy: 50.04%
#     Worker 2: Train Loss: 1.8273, Train Accuracy: 50.21%
#     Worker 3: Train Loss: 1.8484, Train Accuracy: 49.30%
# Total Computation Time: 1620.40 seconds
# Total Communication Time: 0.29 seconds
# Epoch 55/150: Test Loss: 1.9898, Test Accuracy: 47.96%
#     Worker 0: Train Loss: 1.8356, Train Accuracy: 49.53%
#     Worker 1: Train Loss: 1.8439, Train Accuracy: 49.82%
#     Worker 2: Train Loss: 1.8147, Train Accuracy: 50.59%
#     Worker 3: Train Loss: 1.8401, Train Accuracy: 50.44%
# Total Computation Time: 1649.64 seconds
# Total Communication Time: 0.30 seconds
# Epoch 56/150: Test Loss: 1.9956, Test Accuracy: 48.34%
#     Worker 0: Train Loss: 1.8102, Train Accuracy: 50.26%
#     Worker 1: Train Loss: 1.8014, Train Accuracy: 50.70%
#     Worker 2: Train Loss: 1.7810, Train Accuracy: 51.27%
#     Worker 3: Train Loss: 1.8037, Train Accuracy: 50.89%
# Total Computation Time: 1679.45 seconds
# Total Communication Time: 0.30 seconds
# Epoch 57/150: Test Loss: 1.9747, Test Accuracy: 48.46%
#     Worker 0: Train Loss: 1.7990, Train Accuracy: 50.38%
#     Worker 1: Train Loss: 1.8034, Train Accuracy: 50.79%
#     Worker 2: Train Loss: 1.7886, Train Accuracy: 50.92%
#     Worker 3: Train Loss: 1.7923, Train Accuracy: 51.36%
# Total Computation Time: 1708.65 seconds
# Total Communication Time: 0.31 seconds
# Epoch 58/150: Test Loss: 1.9692, Test Accuracy: 48.87%
#     Worker 0: Train Loss: 1.7806, Train Accuracy: 50.54%
#     Worker 1: Train Loss: 1.7806, Train Accuracy: 51.38%
#     Worker 2: Train Loss: 1.7881, Train Accuracy: 51.11%
#     Worker 3: Train Loss: 1.7951, Train Accuracy: 50.83%
# Total Computation Time: 1737.90 seconds
# Total Communication Time: 0.31 seconds
# Epoch 59/150: Test Loss: 1.9723, Test Accuracy: 48.71%
#     Worker 0: Train Loss: 1.7829, Train Accuracy: 50.69%
#     Worker 1: Train Loss: 1.7713, Train Accuracy: 51.61%
#     Worker 2: Train Loss: 1.7548, Train Accuracy: 51.76%
#     Worker 3: Train Loss: 1.7701, Train Accuracy: 51.64%
# Total Computation Time: 1767.64 seconds
# Total Communication Time: 0.31 seconds
# Epoch 60/150: Test Loss: 1.9718, Test Accuracy: 48.95%
#     Worker 0: Train Loss: 1.7590, Train Accuracy: 51.60%
#     Worker 1: Train Loss: 1.7651, Train Accuracy: 51.90%
#     Worker 2: Train Loss: 1.7389, Train Accuracy: 52.56%
#     Worker 3: Train Loss: 1.7344, Train Accuracy: 52.86%
# Total Computation Time: 1796.99 seconds
# Total Communication Time: 0.32 seconds
# Epoch 61/150: Test Loss: 1.9664, Test Accuracy: 48.78%
#     Worker 0: Train Loss: 1.7344, Train Accuracy: 51.99%
#     Worker 1: Train Loss: 1.7260, Train Accuracy: 52.78%
#     Worker 2: Train Loss: 1.7179, Train Accuracy: 52.40%
#     Worker 3: Train Loss: 1.7682, Train Accuracy: 51.58%
# Total Computation Time: 1826.62 seconds
# Total Communication Time: 0.32 seconds
# Epoch 62/150: Test Loss: 1.9623, Test Accuracy: 48.94%
#     Worker 0: Train Loss: 1.7432, Train Accuracy: 51.88%
#     Worker 1: Train Loss: 1.7415, Train Accuracy: 52.16%
#     Worker 2: Train Loss: 1.7146, Train Accuracy: 52.78%
#     Worker 3: Train Loss: 1.7355, Train Accuracy: 52.07%
# Total Computation Time: 1855.76 seconds
# Total Communication Time: 0.33 seconds
# Epoch 63/150: Test Loss: 1.9577, Test Accuracy: 49.00%
#     Worker 0: Train Loss: 1.7266, Train Accuracy: 52.18%
#     Worker 1: Train Loss: 1.7109, Train Accuracy: 52.59%
#     Worker 2: Train Loss: 1.7069, Train Accuracy: 53.09%
#     Worker 3: Train Loss: 1.7172, Train Accuracy: 52.96%
# Total Computation Time: 1884.80 seconds
# Total Communication Time: 0.33 seconds
# Epoch 64/150: Test Loss: 1.9552, Test Accuracy: 49.29%
#     Worker 0: Train Loss: 1.7053, Train Accuracy: 52.61%
#     Worker 1: Train Loss: 1.6988, Train Accuracy: 53.22%
#     Worker 2: Train Loss: 1.6983, Train Accuracy: 52.91%
#     Worker 3: Train Loss: 1.6950, Train Accuracy: 53.78%
# Total Computation Time: 1914.64 seconds
# Total Communication Time: 0.34 seconds
# Epoch 65/150: Test Loss: 1.9514, Test Accuracy: 49.56%
#     Worker 0: Train Loss: 1.6938, Train Accuracy: 53.18%
#     Worker 1: Train Loss: 1.6828, Train Accuracy: 53.97%
#     Worker 2: Train Loss: 1.6730, Train Accuracy: 53.91%
#     Worker 3: Train Loss: 1.6939, Train Accuracy: 53.70%
# Total Computation Time: 1943.90 seconds
# Total Communication Time: 0.34 seconds
# Epoch 66/150: Test Loss: 1.9497, Test Accuracy: 49.67%
#     Worker 0: Train Loss: 1.6719, Train Accuracy: 53.71%
#     Worker 1: Train Loss: 1.6728, Train Accuracy: 53.65%
#     Worker 2: Train Loss: 1.6408, Train Accuracy: 54.69%
#     Worker 3: Train Loss: 1.6723, Train Accuracy: 54.23%
# Total Computation Time: 1973.66 seconds
# Total Communication Time: 0.35 seconds
# Epoch 67/150: Test Loss: 1.9474, Test Accuracy: 49.82%
#     Worker 0: Train Loss: 1.6742, Train Accuracy: 53.38%
#     Worker 1: Train Loss: 1.6528, Train Accuracy: 54.63%
#     Worker 2: Train Loss: 1.6383, Train Accuracy: 54.74%
#     Worker 3: Train Loss: 1.6683, Train Accuracy: 53.98%
# Total Computation Time: 2002.85 seconds
# Total Communication Time: 0.35 seconds
# Epoch 68/150: Test Loss: 1.9362, Test Accuracy: 49.55%
#     Worker 0: Train Loss: 1.6354, Train Accuracy: 54.55%
#     Worker 1: Train Loss: 1.6564, Train Accuracy: 54.51%
#     Worker 2: Train Loss: 1.6345, Train Accuracy: 54.74%
#     Worker 3: Train Loss: 1.6492, Train Accuracy: 54.47%
# Total Computation Time: 2032.24 seconds
# Total Communication Time: 0.35 seconds
# Epoch 69/150: Test Loss: 1.9680, Test Accuracy: 49.32%
#     Worker 0: Train Loss: 1.6224, Train Accuracy: 54.68%
#     Worker 1: Train Loss: 1.6204, Train Accuracy: 54.95%
#     Worker 2: Train Loss: 1.6173, Train Accuracy: 54.84%
#     Worker 3: Train Loss: 1.6287, Train Accuracy: 55.17%
# Total Computation Time: 2061.85 seconds
# Total Communication Time: 0.36 seconds
# Epoch 70/150: Test Loss: 1.9642, Test Accuracy: 49.36%
#     Worker 0: Train Loss: 1.6152, Train Accuracy: 54.87%
#     Worker 1: Train Loss: 1.6297, Train Accuracy: 54.89%
#     Worker 2: Train Loss: 1.6073, Train Accuracy: 55.53%
#     Worker 3: Train Loss: 1.6287, Train Accuracy: 54.95%
# Total Computation Time: 2091.07 seconds
# Total Communication Time: 0.37 seconds
# Epoch 71/150: Test Loss: 1.9359, Test Accuracy: 49.66%
#     Worker 0: Train Loss: 1.6234, Train Accuracy: 54.12%
#     Worker 1: Train Loss: 1.5915, Train Accuracy: 55.46%
#     Worker 2: Train Loss: 1.5966, Train Accuracy: 55.61%
#     Worker 3: Train Loss: 1.5900, Train Accuracy: 55.90%
# Total Computation Time: 2120.95 seconds
# Total Communication Time: 0.37 seconds
# Epoch 72/150: Test Loss: 1.9456, Test Accuracy: 49.91%
#     Worker 0: Train Loss: 1.5710, Train Accuracy: 56.01%
#     Worker 1: Train Loss: 1.5973, Train Accuracy: 55.58%
#     Worker 2: Train Loss: 1.5890, Train Accuracy: 55.88%
#     Worker 3: Train Loss: 1.6033, Train Accuracy: 55.88%
# Total Computation Time: 2150.06 seconds
# Total Communication Time: 0.38 seconds
# Epoch 73/150: Test Loss: 1.9430, Test Accuracy: 49.87%
#     Worker 0: Train Loss: 1.5800, Train Accuracy: 55.69%
#     Worker 1: Train Loss: 1.5837, Train Accuracy: 55.80%
#     Worker 2: Train Loss: 1.5494, Train Accuracy: 56.32%
#     Worker 3: Train Loss: 1.5646, Train Accuracy: 56.28%
# Total Computation Time: 2179.26 seconds
# Total Communication Time: 0.38 seconds
# Epoch 74/150: Test Loss: 1.9430, Test Accuracy: 50.17%
#     Worker 0: Train Loss: 1.5592, Train Accuracy: 56.13%
#     Worker 1: Train Loss: 1.5535, Train Accuracy: 56.50%
#     Worker 2: Train Loss: 1.5606, Train Accuracy: 56.48%
#     Worker 3: Train Loss: 1.5900, Train Accuracy: 56.38%
# Total Computation Time: 2209.26 seconds
# Total Communication Time: 0.39 seconds
# Epoch 75/150: Test Loss: 1.9519, Test Accuracy: 49.87%
#     Worker 0: Train Loss: 1.5714, Train Accuracy: 55.93%
#     Worker 1: Train Loss: 1.5668, Train Accuracy: 56.10%
#     Worker 2: Train Loss: 1.5557, Train Accuracy: 56.30%
#     Worker 3: Train Loss: 1.5679, Train Accuracy: 56.41%
# Total Computation Time: 2238.53 seconds
# Total Communication Time: 0.39 seconds
# Epoch 76/150: Test Loss: 1.9431, Test Accuracy: 50.21%
#     Worker 0: Train Loss: 1.5356, Train Accuracy: 56.68%
#     Worker 1: Train Loss: 1.5432, Train Accuracy: 56.74%
#     Worker 2: Train Loss: 1.5341, Train Accuracy: 56.66%
#     Worker 3: Train Loss: 1.5358, Train Accuracy: 57.35%
# Total Computation Time: 2268.21 seconds
# Total Communication Time: 0.39 seconds
# Epoch 77/150: Test Loss: 1.9320, Test Accuracy: 50.35%
#     Worker 0: Train Loss: 1.5485, Train Accuracy: 56.71%
#     Worker 1: Train Loss: 1.5351, Train Accuracy: 57.37%
#     Worker 2: Train Loss: 1.5242, Train Accuracy: 57.78%
#     Worker 3: Train Loss: 1.5181, Train Accuracy: 58.10%
# Total Computation Time: 2299.33 seconds
# Total Communication Time: 0.40 seconds
# Epoch 78/150: Test Loss: 1.9374, Test Accuracy: 49.73%
#     Worker 0: Train Loss: 1.5243, Train Accuracy: 56.95%
#     Worker 1: Train Loss: 1.5060, Train Accuracy: 57.91%
#     Worker 2: Train Loss: 1.5173, Train Accuracy: 57.25%
#     Worker 3: Train Loss: 1.5374, Train Accuracy: 57.00%
# Total Computation Time: 2330.59 seconds
# Total Communication Time: 0.40 seconds
# Epoch 79/150: Test Loss: 1.9464, Test Accuracy: 49.70%
#     Worker 0: Train Loss: 1.5224, Train Accuracy: 57.02%
#     Worker 1: Train Loss: 1.5017, Train Accuracy: 58.28%
#     Worker 2: Train Loss: 1.4885, Train Accuracy: 58.40%
#     Worker 3: Train Loss: 1.4986, Train Accuracy: 58.36%
# Total Computation Time: 2360.22 seconds
# Total Communication Time: 0.41 seconds
# Epoch 80/150: Test Loss: 1.9366, Test Accuracy: 49.75%
#     Worker 0: Train Loss: 1.4839, Train Accuracy: 57.99%
#     Worker 1: Train Loss: 1.4931, Train Accuracy: 58.35%
#     Worker 2: Train Loss: 1.4825, Train Accuracy: 58.12%
#     Worker 3: Train Loss: 1.5046, Train Accuracy: 57.79%
# Total Computation Time: 2389.21 seconds
# Total Communication Time: 0.41 seconds
# Epoch 81/150: Test Loss: 1.9305, Test Accuracy: 50.68%
#     Worker 0: Train Loss: 1.4916, Train Accuracy: 57.82%
#     Worker 1: Train Loss: 1.4905, Train Accuracy: 58.32%
#     Worker 2: Train Loss: 1.4651, Train Accuracy: 58.95%
#     Worker 3: Train Loss: 1.4822, Train Accuracy: 58.54%
# Total Computation Time: 2418.31 seconds
# Total Communication Time: 0.42 seconds
# Epoch 82/150: Test Loss: 1.9400, Test Accuracy: 50.45%
#     Worker 0: Train Loss: 1.4689, Train Accuracy: 58.27%
#     Worker 1: Train Loss: 1.4725, Train Accuracy: 59.08%
#     Worker 2: Train Loss: 1.4749, Train Accuracy: 58.82%
#     Worker 3: Train Loss: 1.4841, Train Accuracy: 58.68%
# Total Computation Time: 2447.98 seconds
# Total Communication Time: 0.42 seconds
# Epoch 83/150: Test Loss: 1.9422, Test Accuracy: 50.44%
#     Worker 0: Train Loss: 1.4682, Train Accuracy: 58.19%
#     Worker 1: Train Loss: 1.4467, Train Accuracy: 59.31%
#     Worker 2: Train Loss: 1.4299, Train Accuracy: 60.14%
#     Worker 3: Train Loss: 1.4708, Train Accuracy: 58.34%
# Total Computation Time: 2477.10 seconds
# Total Communication Time: 0.43 seconds
# Epoch 84/150: Test Loss: 1.9325, Test Accuracy: 50.75%
#     Worker 0: Train Loss: 1.4439, Train Accuracy: 58.99%
#     Worker 1: Train Loss: 1.4497, Train Accuracy: 58.96%
#     Worker 2: Train Loss: 1.4467, Train Accuracy: 58.82%
#     Worker 3: Train Loss: 1.4687, Train Accuracy: 58.61%
# Total Computation Time: 2506.98 seconds
# Total Communication Time: 0.43 seconds
# Epoch 85/150: Test Loss: 1.9301, Test Accuracy: 50.44%
#     Worker 0: Train Loss: 1.4475, Train Accuracy: 58.96%
#     Worker 1: Train Loss: 1.4466, Train Accuracy: 59.53%
#     Worker 2: Train Loss: 1.4294, Train Accuracy: 60.12%
#     Worker 3: Train Loss: 1.4341, Train Accuracy: 59.81%
# Total Computation Time: 2536.19 seconds
# Total Communication Time: 0.44 seconds
# Epoch 86/150: Test Loss: 1.9524, Test Accuracy: 50.13%
#     Worker 0: Train Loss: 1.4242, Train Accuracy: 59.06%
#     Worker 1: Train Loss: 1.4261, Train Accuracy: 60.31%
#     Worker 2: Train Loss: 1.4102, Train Accuracy: 60.61%
#     Worker 3: Train Loss: 1.4345, Train Accuracy: 59.78%
# Total Computation Time: 2565.34 seconds
# Total Communication Time: 0.44 seconds
# Epoch 87/150: Test Loss: 1.9367, Test Accuracy: 50.62%
#     Worker 0: Train Loss: 1.4379, Train Accuracy: 58.94%
#     Worker 1: Train Loss: 1.4182, Train Accuracy: 59.95%
#     Worker 2: Train Loss: 1.4213, Train Accuracy: 60.00%
#     Worker 3: Train Loss: 1.4144, Train Accuracy: 60.04%
# Total Computation Time: 2595.14 seconds
# Total Communication Time: 0.45 seconds
# Epoch 88/150: Test Loss: 1.9504, Test Accuracy: 50.51%
#     Worker 0: Train Loss: 1.4170, Train Accuracy: 59.61%
#     Worker 1: Train Loss: 1.4202, Train Accuracy: 60.07%
#     Worker 2: Train Loss: 1.4115, Train Accuracy: 60.20%
#     Worker 3: Train Loss: 1.4025, Train Accuracy: 60.35%
# Total Computation Time: 2624.32 seconds
# Total Communication Time: 0.45 seconds
# Epoch 89/150: Test Loss: 1.9457, Test Accuracy: 50.74%
#     Worker 0: Train Loss: 1.3982, Train Accuracy: 59.76%
#     Worker 1: Train Loss: 1.3786, Train Accuracy: 61.07%
#     Worker 2: Train Loss: 1.3928, Train Accuracy: 60.56%
#     Worker 3: Train Loss: 1.3946, Train Accuracy: 60.80%
# Total Computation Time: 2653.94 seconds
# Total Communication Time: 0.46 seconds
# Epoch 90/150: Test Loss: 1.9390, Test Accuracy: 50.86%
#     Worker 0: Train Loss: 1.3870, Train Accuracy: 60.33%
#     Worker 1: Train Loss: 1.3896, Train Accuracy: 60.58%
#     Worker 2: Train Loss: 1.3659, Train Accuracy: 61.32%
#     Worker 3: Train Loss: 1.3959, Train Accuracy: 60.57%
# Total Computation Time: 2683.06 seconds
# Total Communication Time: 0.46 seconds
# Epoch 91/150: Test Loss: 1.9439, Test Accuracy: 50.87%
#     Worker 0: Train Loss: 1.3727, Train Accuracy: 61.02%
#     Worker 1: Train Loss: 1.3838, Train Accuracy: 61.23%
#     Worker 2: Train Loss: 1.3643, Train Accuracy: 61.44%
#     Worker 3: Train Loss: 1.3584, Train Accuracy: 61.52%
# Total Computation Time: 2712.40 seconds
# Total Communication Time: 0.46 seconds
# Epoch 92/150: Test Loss: 1.9490, Test Accuracy: 51.18%
#     Worker 0: Train Loss: 1.3818, Train Accuracy: 60.59%
#     Worker 1: Train Loss: 1.3575, Train Accuracy: 61.27%
#     Worker 2: Train Loss: 1.3625, Train Accuracy: 61.28%
#     Worker 3: Train Loss: 1.3646, Train Accuracy: 61.17%
# Total Computation Time: 2741.73 seconds
# Total Communication Time: 0.47 seconds
# Epoch 93/150: Test Loss: 1.9478, Test Accuracy: 51.18%
#     Worker 0: Train Loss: 1.3501, Train Accuracy: 61.57%
#     Worker 1: Train Loss: 1.3653, Train Accuracy: 61.71%
#     Worker 2: Train Loss: 1.3517, Train Accuracy: 61.63%
#     Worker 3: Train Loss: 1.3558, Train Accuracy: 61.87%
# Total Computation Time: 2770.73 seconds
# Total Communication Time: 0.47 seconds
# Epoch 94/150: Test Loss: 1.9461, Test Accuracy: 51.36%
#     Worker 0: Train Loss: 1.3540, Train Accuracy: 61.19%
#     Worker 1: Train Loss: 1.3598, Train Accuracy: 61.83%
#     Worker 2: Train Loss: 1.3461, Train Accuracy: 61.72%
#     Worker 3: Train Loss: 1.3469, Train Accuracy: 61.68%
# Total Computation Time: 2800.61 seconds
# Total Communication Time: 0.48 seconds
# Epoch 95/150: Test Loss: 1.9460, Test Accuracy: 51.06%
#     Worker 0: Train Loss: 1.3313, Train Accuracy: 62.06%
#     Worker 1: Train Loss: 1.3279, Train Accuracy: 62.17%
#     Worker 2: Train Loss: 1.3278, Train Accuracy: 62.32%
#     Worker 3: Train Loss: 1.3384, Train Accuracy: 62.34%
# Total Computation Time: 2829.59 seconds
# Total Communication Time: 0.48 seconds
# Epoch 96/150: Test Loss: 1.9603, Test Accuracy: 50.87%
#     Worker 0: Train Loss: 1.3287, Train Accuracy: 61.90%
#     Worker 1: Train Loss: 1.3127, Train Accuracy: 62.82%
#     Worker 2: Train Loss: 1.3125, Train Accuracy: 62.70%
#     Worker 3: Train Loss: 1.3235, Train Accuracy: 62.29%
# Total Computation Time: 2859.16 seconds
# Total Communication Time: 0.49 seconds
# Epoch 97/150: Test Loss: 1.9447, Test Accuracy: 51.45%
#     Worker 0: Train Loss: 1.3358, Train Accuracy: 61.83%
#     Worker 1: Train Loss: 1.3328, Train Accuracy: 62.16%
#     Worker 2: Train Loss: 1.3066, Train Accuracy: 62.67%
#     Worker 3: Train Loss: 1.3125, Train Accuracy: 62.88%
# Total Computation Time: 2888.39 seconds
# Total Communication Time: 0.49 seconds
# Epoch 98/150: Test Loss: 1.9606, Test Accuracy: 50.86%
#     Worker 0: Train Loss: 1.3079, Train Accuracy: 62.48%
#     Worker 1: Train Loss: 1.3095, Train Accuracy: 62.79%
#     Worker 2: Train Loss: 1.3046, Train Accuracy: 62.85%
#     Worker 3: Train Loss: 1.3128, Train Accuracy: 63.13%
# Total Computation Time: 2917.40 seconds
# Total Communication Time: 0.50 seconds
# Epoch 99/150: Test Loss: 1.9509, Test Accuracy: 51.07%
#     Worker 0: Train Loss: 1.3183, Train Accuracy: 62.44%
#     Worker 1: Train Loss: 1.3147, Train Accuracy: 62.46%
#     Worker 2: Train Loss: 1.2950, Train Accuracy: 63.07%
#     Worker 3: Train Loss: 1.3016, Train Accuracy: 63.29%
# Total Computation Time: 2947.02 seconds
# Total Communication Time: 0.50 seconds
# Epoch 100/150: Test Loss: 1.9583, Test Accuracy: 51.05%
#     Worker 0: Train Loss: 1.2970, Train Accuracy: 63.05%
#     Worker 1: Train Loss: 1.3017, Train Accuracy: 63.14%
#     Worker 2: Train Loss: 1.2885, Train Accuracy: 63.04%
#     Worker 3: Train Loss: 1.2781, Train Accuracy: 63.71%
# Total Computation Time: 2976.02 seconds
# Total Communication Time: 0.51 seconds
# Epoch 101/150: Test Loss: 1.9622, Test Accuracy: 51.08%
#     Worker 0: Train Loss: 1.2926, Train Accuracy: 62.69%
#     Worker 1: Train Loss: 1.2654, Train Accuracy: 63.98%
#     Worker 2: Train Loss: 1.2522, Train Accuracy: 64.23%
#     Worker 3: Train Loss: 1.2858, Train Accuracy: 63.55%
# Total Computation Time: 3005.58 seconds
# Total Communication Time: 0.51 seconds
# Epoch 102/150: Test Loss: 1.9689, Test Accuracy: 50.73%
#     Worker 0: Train Loss: 1.2758, Train Accuracy: 63.54%
#     Worker 1: Train Loss: 1.2856, Train Accuracy: 63.13%
#     Worker 2: Train Loss: 1.2591, Train Accuracy: 63.91%
#     Worker 3: Train Loss: 1.2760, Train Accuracy: 63.48%
# Total Computation Time: 3034.55 seconds
# Total Communication Time: 0.52 seconds
# Epoch 103/150: Test Loss: 1.9682, Test Accuracy: 51.10%
#     Worker 0: Train Loss: 1.2746, Train Accuracy: 63.24%
#     Worker 1: Train Loss: 1.2868, Train Accuracy: 63.33%
#     Worker 2: Train Loss: 1.2501, Train Accuracy: 64.06%
#     Worker 3: Train Loss: 1.2594, Train Accuracy: 64.31%
# Total Computation Time: 3063.47 seconds
# Total Communication Time: 0.52 seconds
# Epoch 104/150: Test Loss: 1.9649, Test Accuracy: 51.29%
#     Worker 0: Train Loss: 1.2567, Train Accuracy: 63.86%
#     Worker 1: Train Loss: 1.2559, Train Accuracy: 64.57%
#     Worker 2: Train Loss: 1.2573, Train Accuracy: 64.39%
#     Worker 3: Train Loss: 1.2535, Train Accuracy: 64.18%
# Total Computation Time: 3093.18 seconds
# Total Communication Time: 0.53 seconds
# Epoch 105/150: Test Loss: 1.9734, Test Accuracy: 51.17%
#     Worker 0: Train Loss: 1.2519, Train Accuracy: 64.22%
#     Worker 1: Train Loss: 1.2455, Train Accuracy: 64.65%
#     Worker 2: Train Loss: 1.2593, Train Accuracy: 64.09%
#     Worker 3: Train Loss: 1.2428, Train Accuracy: 64.55%
# Total Computation Time: 3122.14 seconds
# Total Communication Time: 0.53 seconds
# Epoch 106/150: Test Loss: 1.9653, Test Accuracy: 51.20%
#     Worker 0: Train Loss: 1.2299, Train Accuracy: 64.38%
#     Worker 1: Train Loss: 1.2404, Train Accuracy: 64.76%
#     Worker 2: Train Loss: 1.2183, Train Accuracy: 65.34%
#     Worker 3: Train Loss: 1.2371, Train Accuracy: 64.66%
# Total Computation Time: 3151.76 seconds
# Total Communication Time: 0.54 seconds
# Epoch 107/150: Test Loss: 1.9701, Test Accuracy: 51.31%
#     Worker 0: Train Loss: 1.2424, Train Accuracy: 64.19%
#     Worker 1: Train Loss: 1.2427, Train Accuracy: 64.75%
#     Worker 2: Train Loss: 1.2167, Train Accuracy: 65.19%
#     Worker 3: Train Loss: 1.2271, Train Accuracy: 64.74%
# Total Computation Time: 3180.87 seconds
# Total Communication Time: 0.54 seconds
# Epoch 108/150: Test Loss: 1.9798, Test Accuracy: 51.07%
#     Worker 0: Train Loss: 1.2287, Train Accuracy: 64.54%
#     Worker 1: Train Loss: 1.2300, Train Accuracy: 64.68%
#     Worker 2: Train Loss: 1.2175, Train Accuracy: 65.13%
#     Worker 3: Train Loss: 1.2158, Train Accuracy: 65.91%
# Total Computation Time: 3210.08 seconds
# Total Communication Time: 0.55 seconds
# Epoch 109/150: Test Loss: 1.9752, Test Accuracy: 51.09%
#     Worker 0: Train Loss: 1.2286, Train Accuracy: 64.52%
#     Worker 1: Train Loss: 1.2181, Train Accuracy: 65.05%
#     Worker 2: Train Loss: 1.2017, Train Accuracy: 65.54%
#     Worker 3: Train Loss: 1.2157, Train Accuracy: 65.73%
# Total Computation Time: 3239.30 seconds
# Total Communication Time: 0.55 seconds
# Epoch 110/150: Test Loss: 1.9843, Test Accuracy: 51.29%
#     Worker 0: Train Loss: 1.2127, Train Accuracy: 64.90%
#     Worker 1: Train Loss: 1.2066, Train Accuracy: 65.48%
#     Worker 2: Train Loss: 1.2010, Train Accuracy: 65.91%
#     Worker 3: Train Loss: 1.2036, Train Accuracy: 65.80%
# Total Computation Time: 3268.25 seconds
# Total Communication Time: 0.56 seconds
# Epoch 111/150: Test Loss: 1.9724, Test Accuracy: 51.54%
#     Worker 0: Train Loss: 1.2022, Train Accuracy: 65.26%
#     Worker 1: Train Loss: 1.2124, Train Accuracy: 65.40%
#     Worker 2: Train Loss: 1.2147, Train Accuracy: 65.74%
#     Worker 3: Train Loss: 1.2214, Train Accuracy: 65.38%
# Total Computation Time: 3297.73 seconds
# Total Communication Time: 0.56 seconds
# Epoch 112/150: Test Loss: 1.9787, Test Accuracy: 51.40%
#     Worker 0: Train Loss: 1.2090, Train Accuracy: 65.40%
#     Worker 1: Train Loss: 1.2015, Train Accuracy: 65.62%
#     Worker 2: Train Loss: 1.1728, Train Accuracy: 66.72%
#     Worker 3: Train Loss: 1.1952, Train Accuracy: 65.73%
# Total Computation Time: 3326.72 seconds
# Total Communication Time: 0.57 seconds
# Epoch 113/150: Test Loss: 1.9770, Test Accuracy: 51.36%
#     Worker 0: Train Loss: 1.1942, Train Accuracy: 65.46%
#     Worker 1: Train Loss: 1.1857, Train Accuracy: 66.02%
#     Worker 2: Train Loss: 1.1902, Train Accuracy: 65.82%
#     Worker 3: Train Loss: 1.1821, Train Accuracy: 66.51%
# Total Computation Time: 3356.50 seconds
# Total Communication Time: 0.57 seconds
# Epoch 114/150: Test Loss: 1.9787, Test Accuracy: 51.44%
#     Worker 0: Train Loss: 1.1984, Train Accuracy: 65.66%
#     Worker 1: Train Loss: 1.1948, Train Accuracy: 65.91%
#     Worker 2: Train Loss: 1.1607, Train Accuracy: 66.90%
#     Worker 3: Train Loss: 1.1801, Train Accuracy: 66.49%
# Total Computation Time: 3385.43 seconds
# Total Communication Time: 0.57 seconds
# Epoch 115/150: Test Loss: 1.9910, Test Accuracy: 51.31%
#     Worker 0: Train Loss: 1.1819, Train Accuracy: 65.88%
#     Worker 1: Train Loss: 1.1730, Train Accuracy: 66.38%
#     Worker 2: Train Loss: 1.1776, Train Accuracy: 66.45%
#     Worker 3: Train Loss: 1.1738, Train Accuracy: 66.65%
# Total Computation Time: 3414.44 seconds
# Total Communication Time: 0.58 seconds
# Epoch 116/150: Test Loss: 1.9903, Test Accuracy: 51.47%
#     Worker 0: Train Loss: 1.1691, Train Accuracy: 66.31%
#     Worker 1: Train Loss: 1.1703, Train Accuracy: 67.16%
#     Worker 2: Train Loss: 1.1601, Train Accuracy: 66.79%
#     Worker 3: Train Loss: 1.1681, Train Accuracy: 66.67%
# Total Computation Time: 3443.88 seconds
# Total Communication Time: 0.58 seconds
# Epoch 117/150: Test Loss: 1.9899, Test Accuracy: 51.35%
#     Worker 0: Train Loss: 1.1860, Train Accuracy: 65.89%
#     Worker 1: Train Loss: 1.1773, Train Accuracy: 66.46%
#     Worker 2: Train Loss: 1.1670, Train Accuracy: 66.93%
#     Worker 3: Train Loss: 1.1708, Train Accuracy: 66.60%
# Total Computation Time: 3472.87 seconds
# Total Communication Time: 0.59 seconds
# Epoch 118/150: Test Loss: 1.9891, Test Accuracy: 51.51%
#     Worker 0: Train Loss: 1.1635, Train Accuracy: 66.41%
#     Worker 1: Train Loss: 1.1625, Train Accuracy: 66.83%
#     Worker 2: Train Loss: 1.1488, Train Accuracy: 67.00%
#     Worker 3: Train Loss: 1.1607, Train Accuracy: 66.70%
# Total Computation Time: 3502.37 seconds
# Total Communication Time: 0.59 seconds
# Epoch 119/150: Test Loss: 1.9941, Test Accuracy: 51.49%
#     Worker 0: Train Loss: 1.1541, Train Accuracy: 66.99%
#     Worker 1: Train Loss: 1.1619, Train Accuracy: 67.08%
#     Worker 2: Train Loss: 1.1248, Train Accuracy: 67.89%
#     Worker 3: Train Loss: 1.1458, Train Accuracy: 67.60%
# Total Computation Time: 3531.36 seconds
# Total Communication Time: 0.60 seconds
# Epoch 120/150: Test Loss: 1.9929, Test Accuracy: 51.63%
#     Worker 0: Train Loss: 1.1557, Train Accuracy: 66.68%
#     Worker 1: Train Loss: 1.1581, Train Accuracy: 66.96%
#     Worker 2: Train Loss: 1.1562, Train Accuracy: 67.06%
#     Worker 3: Train Loss: 1.1514, Train Accuracy: 67.07%
# Total Computation Time: 3560.79 seconds
# Total Communication Time: 0.60 seconds
# Epoch 121/150: Test Loss: 1.9937, Test Accuracy: 51.59%
#     Worker 0: Train Loss: 1.1516, Train Accuracy: 66.98%
#     Worker 1: Train Loss: 1.1486, Train Accuracy: 66.60%
#     Worker 2: Train Loss: 1.1257, Train Accuracy: 67.59%
#     Worker 3: Train Loss: 1.1371, Train Accuracy: 67.87%
# Total Computation Time: 3589.83 seconds
# Total Communication Time: 0.61 seconds
# Epoch 122/150: Test Loss: 1.9961, Test Accuracy: 51.11%
#     Worker 0: Train Loss: 1.1509, Train Accuracy: 66.93%
#     Worker 1: Train Loss: 1.1394, Train Accuracy: 67.48%
#     Worker 2: Train Loss: 1.1407, Train Accuracy: 67.26%
#     Worker 3: Train Loss: 1.1306, Train Accuracy: 67.83%
# Total Computation Time: 3618.79 seconds
# Total Communication Time: 0.61 seconds
# Epoch 123/150: Test Loss: 1.9971, Test Accuracy: 51.47%
#     Worker 0: Train Loss: 1.1381, Train Accuracy: 67.48%
#     Worker 1: Train Loss: 1.1343, Train Accuracy: 67.57%
#     Worker 2: Train Loss: 1.1218, Train Accuracy: 67.76%
#     Worker 3: Train Loss: 1.1338, Train Accuracy: 67.90%
# Total Computation Time: 3648.55 seconds
# Total Communication Time: 0.62 seconds
# Epoch 124/150: Test Loss: 1.9983, Test Accuracy: 51.58%
#     Worker 0: Train Loss: 1.1341, Train Accuracy: 66.88%
#     Worker 1: Train Loss: 1.1489, Train Accuracy: 67.06%
#     Worker 2: Train Loss: 1.1306, Train Accuracy: 68.05%
#     Worker 3: Train Loss: 1.1401, Train Accuracy: 67.53%
# Total Computation Time: 3677.47 seconds
# Total Communication Time: 0.62 seconds
# Epoch 125/150: Test Loss: 1.9997, Test Accuracy: 51.41%
#     Worker 0: Train Loss: 1.1161, Train Accuracy: 67.61%
#     Worker 1: Train Loss: 1.1411, Train Accuracy: 67.25%
#     Worker 2: Train Loss: 1.1095, Train Accuracy: 68.41%
#     Worker 3: Train Loss: 1.1402, Train Accuracy: 67.63%
# Total Computation Time: 3706.97 seconds
# Total Communication Time: 0.62 seconds
# Epoch 126/150: Test Loss: 2.0010, Test Accuracy: 51.23%
#     Worker 0: Train Loss: 1.1311, Train Accuracy: 67.28%
#     Worker 1: Train Loss: 1.1239, Train Accuracy: 67.84%
#     Worker 2: Train Loss: 1.1112, Train Accuracy: 67.94%
#     Worker 3: Train Loss: 1.1199, Train Accuracy: 67.94%
# Total Computation Time: 3735.81 seconds
# Total Communication Time: 0.63 seconds
# Epoch 127/150: Test Loss: 2.0037, Test Accuracy: 51.31%
#     Worker 0: Train Loss: 1.1180, Train Accuracy: 67.49%
#     Worker 1: Train Loss: 1.1314, Train Accuracy: 67.74%
#     Worker 2: Train Loss: 1.0999, Train Accuracy: 68.76%
#     Worker 3: Train Loss: 1.1139, Train Accuracy: 68.24%
# Total Computation Time: 3764.92 seconds
# Total Communication Time: 0.63 seconds
# Epoch 128/150: Test Loss: 2.0024, Test Accuracy: 51.39%
#     Worker 0: Train Loss: 1.1052, Train Accuracy: 68.19%
#     Worker 1: Train Loss: 1.1132, Train Accuracy: 68.15%
#     Worker 2: Train Loss: 1.1025, Train Accuracy: 68.85%
#     Worker 3: Train Loss: 1.1005, Train Accuracy: 68.44%
# Total Computation Time: 3794.07 seconds
# Total Communication Time: 0.64 seconds
# Epoch 129/150: Test Loss: 2.0025, Test Accuracy: 51.46%
#     Worker 0: Train Loss: 1.1138, Train Accuracy: 68.07%
#     Worker 1: Train Loss: 1.1071, Train Accuracy: 68.40%
#     Worker 2: Train Loss: 1.1080, Train Accuracy: 68.39%
#     Worker 3: Train Loss: 1.1248, Train Accuracy: 67.55%
# Total Computation Time: 3823.04 seconds
# Total Communication Time: 0.64 seconds
# Epoch 130/150: Test Loss: 2.0043, Test Accuracy: 51.42%
#     Worker 0: Train Loss: 1.1084, Train Accuracy: 68.20%
#     Worker 1: Train Loss: 1.1062, Train Accuracy: 68.73%
#     Worker 2: Train Loss: 1.1049, Train Accuracy: 68.26%
#     Worker 3: Train Loss: 1.1103, Train Accuracy: 68.51%
# Total Computation Time: 3852.57 seconds
# Total Communication Time: 0.65 seconds
# Epoch 131/150: Test Loss: 2.0051, Test Accuracy: 51.38%
#     Worker 0: Train Loss: 1.1121, Train Accuracy: 67.99%
#     Worker 1: Train Loss: 1.1269, Train Accuracy: 67.99%
#     Worker 2: Train Loss: 1.0993, Train Accuracy: 68.96%
#     Worker 3: Train Loss: 1.1107, Train Accuracy: 68.45%
# Total Computation Time: 3881.45 seconds
# Total Communication Time: 0.65 seconds
# Epoch 132/150: Test Loss: 2.0095, Test Accuracy: 51.47%
#     Worker 0: Train Loss: 1.1069, Train Accuracy: 67.93%
#     Worker 1: Train Loss: 1.1063, Train Accuracy: 68.54%
#     Worker 2: Train Loss: 1.0983, Train Accuracy: 68.36%
#     Worker 3: Train Loss: 1.0844, Train Accuracy: 69.00%
# Total Computation Time: 3911.05 seconds
# Total Communication Time: 0.66 seconds
# Epoch 133/150: Test Loss: 2.0082, Test Accuracy: 51.39%
#     Worker 0: Train Loss: 1.0919, Train Accuracy: 68.67%
#     Worker 1: Train Loss: 1.0916, Train Accuracy: 69.28%
#     Worker 2: Train Loss: 1.0858, Train Accuracy: 69.01%
#     Worker 3: Train Loss: 1.1007, Train Accuracy: 68.46%
# Total Computation Time: 3940.40 seconds
# Total Communication Time: 0.66 seconds
# Epoch 134/150: Test Loss: 2.0084, Test Accuracy: 51.48%
#     Worker 0: Train Loss: 1.1048, Train Accuracy: 68.08%
#     Worker 1: Train Loss: 1.1079, Train Accuracy: 68.36%
#     Worker 2: Train Loss: 1.0875, Train Accuracy: 69.02%
#     Worker 3: Train Loss: 1.0834, Train Accuracy: 69.02%
# Total Computation Time: 3969.35 seconds
# Total Communication Time: 0.67 seconds
# Epoch 135/150: Test Loss: 2.0096, Test Accuracy: 51.65%
#     Worker 0: Train Loss: 1.0992, Train Accuracy: 68.57%
#     Worker 1: Train Loss: 1.0936, Train Accuracy: 68.43%
#     Worker 2: Train Loss: 1.0944, Train Accuracy: 68.98%
#     Worker 3: Train Loss: 1.0862, Train Accuracy: 69.14%
# Total Computation Time: 3998.96 seconds
# Total Communication Time: 0.67 seconds
# Epoch 136/150: Test Loss: 2.0086, Test Accuracy: 51.56%
#     Worker 0: Train Loss: 1.0792, Train Accuracy: 68.56%
#     Worker 1: Train Loss: 1.0985, Train Accuracy: 68.94%
#     Worker 2: Train Loss: 1.0825, Train Accuracy: 69.09%
#     Worker 3: Train Loss: 1.1090, Train Accuracy: 68.53%
# Total Computation Time: 4028.04 seconds
# Total Communication Time: 0.68 seconds
# Epoch 137/150: Test Loss: 2.0078, Test Accuracy: 51.58%
#     Worker 0: Train Loss: 1.0967, Train Accuracy: 68.57%
#     Worker 1: Train Loss: 1.0984, Train Accuracy: 69.27%
#     Worker 2: Train Loss: 1.0765, Train Accuracy: 69.56%
#     Worker 3: Train Loss: 1.0770, Train Accuracy: 69.08%
# Total Computation Time: 4057.64 seconds
# Total Communication Time: 0.68 seconds
# Epoch 138/150: Test Loss: 2.0086, Test Accuracy: 51.56%
#     Worker 0: Train Loss: 1.0843, Train Accuracy: 68.91%
#     Worker 1: Train Loss: 1.0951, Train Accuracy: 68.80%
#     Worker 2: Train Loss: 1.0934, Train Accuracy: 68.71%
#     Worker 3: Train Loss: 1.0988, Train Accuracy: 69.12%
# Total Computation Time: 4086.56 seconds
# Total Communication Time: 0.68 seconds
# Epoch 139/150: Test Loss: 2.0089, Test Accuracy: 51.50%
#     Worker 0: Train Loss: 1.1039, Train Accuracy: 68.19%
#     Worker 1: Train Loss: 1.0931, Train Accuracy: 68.73%
#     Worker 2: Train Loss: 1.0769, Train Accuracy: 69.49%
#     Worker 3: Train Loss: 1.0823, Train Accuracy: 69.22%
# Total Computation Time: 4115.60 seconds
# Total Communication Time: 0.69 seconds
# Epoch 140/150: Test Loss: 2.0111, Test Accuracy: 51.50%
#     Worker 0: Train Loss: 1.0919, Train Accuracy: 68.61%
#     Worker 1: Train Loss: 1.0987, Train Accuracy: 68.82%
#     Worker 2: Train Loss: 1.0786, Train Accuracy: 69.15%
#     Worker 3: Train Loss: 1.0875, Train Accuracy: 69.05%
# Total Computation Time: 4144.73 seconds
# Total Communication Time: 0.69 seconds
# Epoch 141/150: Test Loss: 2.0111, Test Accuracy: 51.54%
#     Worker 0: Train Loss: 1.0816, Train Accuracy: 68.73%
#     Worker 1: Train Loss: 1.0854, Train Accuracy: 68.99%
#     Worker 2: Train Loss: 1.0870, Train Accuracy: 68.99%
#     Worker 3: Train Loss: 1.0908, Train Accuracy: 69.20%
# Total Computation Time: 4173.58 seconds
# Total Communication Time: 0.70 seconds
# Epoch 142/150: Test Loss: 2.0120, Test Accuracy: 51.58%
#     Worker 0: Train Loss: 1.0843, Train Accuracy: 68.59%
#     Worker 1: Train Loss: 1.0752, Train Accuracy: 68.78%
#     Worker 2: Train Loss: 1.0762, Train Accuracy: 69.23%
#     Worker 3: Train Loss: 1.0804, Train Accuracy: 69.22%
# Total Computation Time: 4203.17 seconds
# Total Communication Time: 0.70 seconds
# Epoch 143/150: Test Loss: 2.0111, Test Accuracy: 51.53%
#     Worker 0: Train Loss: 1.0982, Train Accuracy: 68.26%
#     Worker 1: Train Loss: 1.1014, Train Accuracy: 68.80%
#     Worker 2: Train Loss: 1.0803, Train Accuracy: 69.46%
#     Worker 3: Train Loss: 1.0714, Train Accuracy: 69.46%
# Total Computation Time: 4232.23 seconds
# Total Communication Time: 0.71 seconds
# Epoch 144/150: Test Loss: 2.0117, Test Accuracy: 51.47%
#     Worker 0: Train Loss: 1.0805, Train Accuracy: 68.99%
#     Worker 1: Train Loss: 1.0923, Train Accuracy: 68.47%
#     Worker 2: Train Loss: 1.0693, Train Accuracy: 69.57%
#     Worker 3: Train Loss: 1.0849, Train Accuracy: 69.27%
# Total Computation Time: 4261.61 seconds
# Total Communication Time: 0.71 seconds
# Epoch 145/150: Test Loss: 2.0112, Test Accuracy: 51.45%
#     Worker 0: Train Loss: 1.0874, Train Accuracy: 68.35%
#     Worker 1: Train Loss: 1.0819, Train Accuracy: 69.19%
#     Worker 2: Train Loss: 1.0749, Train Accuracy: 69.12%
#     Worker 3: Train Loss: 1.0745, Train Accuracy: 69.79%
# Total Computation Time: 4290.58 seconds
# Total Communication Time: 0.72 seconds
# Epoch 146/150: Test Loss: 2.0113, Test Accuracy: 51.47%
#     Worker 0: Train Loss: 1.0945, Train Accuracy: 68.36%
#     Worker 1: Train Loss: 1.0903, Train Accuracy: 69.11%
#     Worker 2: Train Loss: 1.0744, Train Accuracy: 69.52%
#     Worker 3: Train Loss: 1.0905, Train Accuracy: 69.27%
# Total Computation Time: 4319.67 seconds
# Total Communication Time: 0.72 seconds
# Epoch 147/150: Test Loss: 2.0111, Test Accuracy: 51.50%
#     Worker 0: Train Loss: 1.0916, Train Accuracy: 68.67%
#     Worker 1: Train Loss: 1.0800, Train Accuracy: 68.69%
#     Worker 2: Train Loss: 1.0736, Train Accuracy: 69.60%
#     Worker 3: Train Loss: 1.0789, Train Accuracy: 69.35%
# Total Computation Time: 4349.13 seconds
# Total Communication Time: 0.73 seconds
# Epoch 148/150: Test Loss: 2.0114, Test Accuracy: 51.47%
#     Worker 0: Train Loss: 1.0929, Train Accuracy: 68.60%
#     Worker 1: Train Loss: 1.0862, Train Accuracy: 69.17%
#     Worker 2: Train Loss: 1.0709, Train Accuracy: 69.60%
#     Worker 3: Train Loss: 1.0775, Train Accuracy: 69.74%
# Total Computation Time: 4378.12 seconds
# Total Communication Time: 0.73 seconds
# Epoch 149/150: Test Loss: 2.0114, Test Accuracy: 51.46%
#     Worker 0: Train Loss: 1.0780, Train Accuracy: 68.86%
#     Worker 1: Train Loss: 1.0710, Train Accuracy: 69.20%
#     Worker 2: Train Loss: 1.0710, Train Accuracy: 69.36%
#     Worker 3: Train Loss: 1.0886, Train Accuracy: 68.98%
# Total Computation Time: 4407.64 seconds
# Total Communication Time: 0.74 seconds
# Epoch 150/150: Test Loss: 2.0114, Test Accuracy: 51.48%
#     Worker 0: Train Loss: 1.0797, Train Accuracy: 68.94%
#     Worker 1: Train Loss: 1.0895, Train Accuracy: 69.06%
#     Worker 2: Train Loss: 1.0819, Train Accuracy: 69.02%
#     Worker 3: Train Loss: 1.0852, Train Accuracy: 69.33%
# Total Computation Time: 4436.54 seconds
# Total Communication Time: 0.74 seconds
