# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs - warmup_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")

    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch):
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            # Perform J local step before synchronization
            for j in range(J):
                try:
                    # Get a batch from the current worker's shard using next()
                    images, labels = next(shard_iterators[k])
                    images, labels = images.to(device), labels.to(device)  # Move to device
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

                except StopIteration:
                    # If the iterator has exhausted the data, restart the iterator
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k]) # Resume from the next batch
                    images, labels = images.to(device), labels.to(device)
                    # Perform optimization step
                    optimizers[k].zero_grad()
                    outputs = nets[k](images)
                    loss = criterion(outputs, labels)
                    loss.backward()
                    optimizers[k].step()
                    # Calculate train loss and accuracy
                    train_loss += loss.item() * labels.size(0)
                    _, predicted = outputs.max(1)
                    total_train += labels.size(0)
                    correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        # Perform model synchronization
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            # Update each worker model with the global parameters
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
        else:
            warmup_factor = (epoch + 1) / warmup_epochs
            lr = warmup_factor * learning_rate
            for optimizer in optimizers:
                for param_group in optimizer.param_groups:
                    param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Overwriting localSGD.py

# %%
# %run localSGD.py --k 4 --j 8
# Out:
# Training with K=4, J=8
# Global iteration per epoch: 25
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00400
# Epoch 1/150: Test Loss: 4.5804, Test Accuracy: 2.92%
#     Worker 0: Train Loss: 4.5987, Train Accuracy: 1.45%
#     Worker 1: Train Loss: 4.5999, Train Accuracy: 1.39%
#     Worker 2: Train Loss: 4.5982, Train Accuracy: 1.42%
#     Worker 3: Train Loss: 4.5987, Train Accuracy: 1.42%
# Epoch 2/150: Test Loss: 4.5546, Test Accuracy: 3.18%
#     Worker 0: Train Loss: 4.5714, Train Accuracy: 2.65%
#     Worker 1: Train Loss: 4.5713, Train Accuracy: 2.70%
#     Worker 2: Train Loss: 4.5678, Train Accuracy: 2.93%
#     Worker 3: Train Loss: 4.5711, Train Accuracy: 2.79%
# Epoch 3/150: Test Loss: 4.3860, Test Accuracy: 4.11%
#     Worker 0: Train Loss: 4.4958, Train Accuracy: 3.47%
#     Worker 1: Train Loss: 4.4974, Train Accuracy: 3.16%
#     Worker 2: Train Loss: 4.4890, Train Accuracy: 3.49%
#     Worker 3: Train Loss: 4.4966, Train Accuracy: 3.56%
# Epoch 4/150: Test Loss: 4.0725, Test Accuracy: 8.25%
#     Worker 0: Train Loss: 4.2267, Train Accuracy: 5.89%
#     Worker 1: Train Loss: 4.2412, Train Accuracy: 5.79%
#     Worker 2: Train Loss: 4.2151, Train Accuracy: 6.55%
#     Worker 3: Train Loss: 4.2404, Train Accuracy: 5.92%
# Epoch 5/150: Test Loss: 3.9280, Test Accuracy: 9.84%
#     Worker 0: Train Loss: 4.0567, Train Accuracy: 7.94%
#     Worker 1: Train Loss: 4.0617, Train Accuracy: 8.08%
#     Worker 2: Train Loss: 4.0338, Train Accuracy: 7.78%
#     Worker 3: Train Loss: 4.0666, Train Accuracy: 7.86%
# Epoch 6/150: Test Loss: 3.7915, Test Accuracy: 12.38%
#     Worker 0: Train Loss: 3.9313, Train Accuracy: 10.18%
#     Worker 1: Train Loss: 3.9424, Train Accuracy: 9.63%
#     Worker 2: Train Loss: 3.8912, Train Accuracy: 10.18%
#     Worker 3: Train Loss: 3.9482, Train Accuracy: 9.45%
# Epoch 7/150: Test Loss: 3.6687, Test Accuracy: 14.36%
#     Worker 0: Train Loss: 3.8225, Train Accuracy: 11.23%
#     Worker 0: Train Loss: 1.4983, Train Accuracy: 58.03%
#     Worker 1: Train Loss: 1.5096, Train Accuracy: 58.25%
#     Worker 2: Train Loss: 1.5092, Train Accuracy: 58.00%
#     Worker 3: Train Loss: 1.5183, Train Accuracy: 57.46%
# Epoch 89/150: Test Loss: 1.9815, Test Accuracy: 49.78%
#     Worker 0: Train Loss: 1.5091, Train Accuracy: 58.29%
#     Worker 1: Train Loss: 1.5147, Train Accuracy: 57.31%
#     Worker 2: Train Loss: 1.5017, Train Accuracy: 58.46%
#     Worker 3: Train Loss: 1.4959, Train Accuracy: 58.53%
# Epoch 90/150: Test Loss: 1.9829, Test Accuracy: 49.60%
#     Worker 0: Train Loss: 1.4891, Train Accuracy: 58.25%
#     Worker 1: Train Loss: 1.4735, Train Accuracy: 58.64%
#     Worker 2: Train Loss: 1.4507, Train Accuracy: 59.76%
#     Worker 3: Train Loss: 1.5098, Train Accuracy: 57.86%
# Epoch 91/150: Test Loss: 1.9852, Test Accuracy: 50.07%
#     Worker 0: Train Loss: 1.4887, Train Accuracy: 58.15%
#     Worker 1: Train Loss: 1.4918, Train Accuracy: 58.12%
#     Worker 2: Train Loss: 1.4826, Train Accuracy: 58.33%
#     Worker 3: Train Loss: 1.4843, Train Accuracy: 58.73%
# Epoch 92/150: Test Loss: 1.9772, Test Accuracy: 49.64%
#     Worker 0: Train Loss: 1.4869, Train Accuracy: 58.34%
#     Worker 1: Train Loss: 1.5028, Train Accuracy: 58.35%
#     Worker 2: Train Loss: 1.4715, Train Accuracy: 59.38%
#     Worker 3: Train Loss: 1.4859, Train Accuracy: 58.86%
# Epoch 93/150: Test Loss: 1.9762, Test Accuracy: 50.49%
#     Worker 0: Train Loss: 1.4786, Train Accuracy: 58.10%
#     Worker 1: Train Loss: 1.4746, Train Accuracy: 59.42%
#     Worker 2: Train Loss: 1.4633, Train Accuracy: 59.42%
#     Worker 3: Train Loss: 1.4706, Train Accuracy: 58.65%
# Epoch 94/150: Test Loss: 1.9785, Test Accuracy: 50.26%
#     Worker 0: Train Loss: 1.4600, Train Accuracy: 59.10%
#     Worker 1: Train Loss: 1.4662, Train Accuracy: 59.02%
#     Worker 2: Train Loss: 1.4448, Train Accuracy: 59.45%
#     Worker 3: Train Loss: 1.4595, Train Accuracy: 59.16%
# Epoch 95/150: Test Loss: 1.9706, Test Accuracy: 50.59%
#     Worker 0: Train Loss: 1.4482, Train Accuracy: 59.71%
#     Worker 1: Train Loss: 1.4488, Train Accuracy: 59.48%
#     Worker 2: Train Loss: 1.4441, Train Accuracy: 59.78%
#     Worker 3: Train Loss: 1.4415, Train Accuracy: 60.00%
# Epoch 96/150: Test Loss: 1.9779, Test Accuracy: 50.32%
#     Worker 0: Train Loss: 1.4521, Train Accuracy: 58.87%
#     Worker 1: Train Loss: 1.4622, Train Accuracy: 59.64%
#     Worker 2: Train Loss: 1.4349, Train Accuracy: 60.00%
#     Worker 3: Train Loss: 1.4391, Train Accuracy: 59.69%
# Epoch 97/150: Test Loss: 1.9791, Test Accuracy: 50.13%
#     Worker 0: Train Loss: 1.4325, Train Accuracy: 59.90%
#     Worker 1: Train Loss: 1.4274, Train Accuracy: 60.02%
#     Worker 2: Train Loss: 1.4194, Train Accuracy: 60.00%
#     Worker 3: Train Loss: 1.4319, Train Accuracy: 60.26%
# Epoch 98/150: Test Loss: 1.9754, Test Accuracy: 50.33%
#     Worker 0: Train Loss: 1.4293, Train Accuracy: 59.84%
#     Worker 1: Train Loss: 1.4289, Train Accuracy: 59.68%
#     Worker 2: Train Loss: 1.4142, Train Accuracy: 60.74%
#     Worker 3: Train Loss: 1.4226, Train Accuracy: 60.10%
# Epoch 99/150: Test Loss: 1.9758, Test Accuracy: 50.28%
#     Worker 0: Train Loss: 1.4114, Train Accuracy: 60.44%
#     Worker 1: Train Loss: 1.4301, Train Accuracy: 60.09%
#     Worker 2: Train Loss: 1.4191, Train Accuracy: 60.34%
#     Worker 3: Train Loss: 1.4211, Train Accuracy: 60.26%
# Epoch 100/150: Test Loss: 1.9886, Test Accuracy: 50.06%
#     Worker 0: Train Loss: 1.4283, Train Accuracy: 59.65%
#     Worker 1: Train Loss: 1.4041, Train Accuracy: 60.59%
#     Worker 2: Train Loss: 1.4116, Train Accuracy: 60.62%
#     Worker 3: Train Loss: 1.4143, Train Accuracy: 60.43%
# Epoch 101/150: Test Loss: 1.9872, Test Accuracy: 50.88%
#     Worker 0: Train Loss: 1.3985, Train Accuracy: 60.41%
#     Worker 1: Train Loss: 1.4088, Train Accuracy: 60.29%
#     Worker 2: Train Loss: 1.3786, Train Accuracy: 61.19%
#     Worker 3: Train Loss: 1.4013, Train Accuracy: 60.73%
# Epoch 102/150: Test Loss: 1.9827, Test Accuracy: 50.21%
#     Worker 0: Train Loss: 1.3892, Train Accuracy: 60.72%
#     Worker 1: Train Loss: 1.4024, Train Accuracy: 60.79%
#     Worker 2: Train Loss: 1.3885, Train Accuracy: 61.23%
#     Worker 3: Train Loss: 1.4117, Train Accuracy: 60.17%
# Epoch 103/150: Test Loss: 1.9725, Test Accuracy: 50.47%
#     Worker 0: Train Loss: 1.3856, Train Accuracy: 61.11%
#     Worker 1: Train Loss: 1.3766, Train Accuracy: 61.59%
#     Worker 2: Train Loss: 1.3893, Train Accuracy: 60.85%
#     Worker 3: Train Loss: 1.4033, Train Accuracy: 60.43%
# Epoch 104/150: Test Loss: 1.9753, Test Accuracy: 50.49%
#     Worker 0: Train Loss: 1.3886, Train Accuracy: 60.36%
#     Worker 1: Train Loss: 1.3699, Train Accuracy: 61.52%
#     Worker 2: Train Loss: 1.3503, Train Accuracy: 61.96%
#     Worker 3: Train Loss: 1.3777, Train Accuracy: 61.63%
# Epoch 105/150: Test Loss: 1.9702, Test Accuracy: 50.80%
#     Worker 0: Train Loss: 1.3679, Train Accuracy: 61.53%
#     Worker 1: Train Loss: 1.3705, Train Accuracy: 62.25%
#     Worker 2: Train Loss: 1.3614, Train Accuracy: 61.81%
#     Worker 3: Train Loss: 1.3756, Train Accuracy: 61.27%
# Epoch 106/150: Test Loss: 1.9827, Test Accuracy: 50.58%
#     Worker 0: Train Loss: 1.3699, Train Accuracy: 61.93%
#     Worker 1: Train Loss: 1.3635, Train Accuracy: 61.73%
#     Worker 2: Train Loss: 1.3655, Train Accuracy: 61.77%
#     Worker 3: Train Loss: 1.3531, Train Accuracy: 62.10%
# Epoch 107/150: Test Loss: 1.9766, Test Accuracy: 50.27%
#     Worker 0: Train Loss: 1.3573, Train Accuracy: 61.57%
#     Worker 1: Train Loss: 1.3658, Train Accuracy: 61.52%
#     Worker 2: Train Loss: 1.3365, Train Accuracy: 62.18%
#     Worker 3: Train Loss: 1.3703, Train Accuracy: 61.43%
# Epoch 108/150: Test Loss: 1.9789, Test Accuracy: 50.55%
#     Worker 0: Train Loss: 1.3563, Train Accuracy: 61.53%
#     Worker 1: Train Loss: 1.3457, Train Accuracy: 62.30%
#     Worker 2: Train Loss: 1.3389, Train Accuracy: 62.35%
#     Worker 3: Train Loss: 1.3370, Train Accuracy: 62.65%
# Epoch 109/150: Test Loss: 1.9884, Test Accuracy: 50.69%
#     Worker 0: Train Loss: 1.3466, Train Accuracy: 61.88%
#     Worker 1: Train Loss: 1.3177, Train Accuracy: 63.15%
#     Worker 2: Train Loss: 1.3329, Train Accuracy: 62.94%
#     Worker 3: Train Loss: 1.3545, Train Accuracy: 62.04%
# Epoch 110/150: Test Loss: 1.9955, Test Accuracy: 50.71%
#     Worker 0: Train Loss: 1.3120, Train Accuracy: 62.89%
#     Worker 1: Train Loss: 1.3341, Train Accuracy: 62.61%
#     Worker 2: Train Loss: 1.3287, Train Accuracy: 62.70%
#     Worker 3: Train Loss: 1.3457, Train Accuracy: 62.36%
# Epoch 111/150: Test Loss: 1.9912, Test Accuracy: 50.50%
#     Worker 0: Train Loss: 1.3386, Train Accuracy: 61.81%
#     Worker 1: Train Loss: 1.3255, Train Accuracy: 62.77%
#     Worker 2: Train Loss: 1.3179, Train Accuracy: 63.47%
#     Worker 3: Train Loss: 1.3385, Train Accuracy: 62.61%
# Epoch 112/150: Test Loss: 1.9849, Test Accuracy: 50.23%
#     Worker 0: Train Loss: 1.3142, Train Accuracy: 63.16%
#     Worker 1: Train Loss: 1.3304, Train Accuracy: 63.00%
#     Worker 2: Train Loss: 1.3092, Train Accuracy: 63.48%
#     Worker 3: Train Loss: 1.3266, Train Accuracy: 62.66%
# Epoch 113/150: Test Loss: 1.9836, Test Accuracy: 50.61%
#     Worker 0: Train Loss: 1.3238, Train Accuracy: 62.36%
#     Worker 1: Train Loss: 1.3069, Train Accuracy: 63.09%
#     Worker 2: Train Loss: 1.3360, Train Accuracy: 62.53%
#     Worker 3: Train Loss: 1.3224, Train Accuracy: 62.35%
# Epoch 114/150: Test Loss: 1.9843, Test Accuracy: 50.87%
#     Worker 0: Train Loss: 1.3154, Train Accuracy: 62.76%
#     Worker 1: Train Loss: 1.3087, Train Accuracy: 63.41%
#     Worker 2: Train Loss: 1.2934, Train Accuracy: 63.77%
#     Worker 3: Train Loss: 1.2997, Train Accuracy: 63.70%
# Epoch 115/150: Test Loss: 1.9810, Test Accuracy: 50.79%
#     Worker 0: Train Loss: 1.2973, Train Accuracy: 63.29%
#     Worker 1: Train Loss: 1.3356, Train Accuracy: 62.56%
#     Worker 2: Train Loss: 1.3083, Train Accuracy: 63.45%
#     Worker 3: Train Loss: 1.3159, Train Accuracy: 62.94%
# Epoch 116/150: Test Loss: 1.9890, Test Accuracy: 50.67%
#     Worker 0: Train Loss: 1.3014, Train Accuracy: 63.48%
#     Worker 1: Train Loss: 1.3003, Train Accuracy: 63.30%
#     Worker 2: Train Loss: 1.2961, Train Accuracy: 63.34%
#     Worker 3: Train Loss: 1.3239, Train Accuracy: 63.31%
# Epoch 117/150: Test Loss: 1.9758, Test Accuracy: 50.90%
#     Worker 0: Train Loss: 1.2960, Train Accuracy: 63.29%
#     Worker 1: Train Loss: 1.2852, Train Accuracy: 64.21%
#     Worker 2: Train Loss: 1.3090, Train Accuracy: 63.30%
#     Worker 3: Train Loss: 1.2777, Train Accuracy: 63.85%
# Epoch 118/150: Test Loss: 1.9828, Test Accuracy: 50.60%
#     Worker 0: Train Loss: 1.2707, Train Accuracy: 64.21%
#     Worker 1: Train Loss: 1.3074, Train Accuracy: 63.27%
#     Worker 2: Train Loss: 1.2780, Train Accuracy: 63.69%
#     Worker 3: Train Loss: 1.3201, Train Accuracy: 62.94%
# Epoch 119/150: Test Loss: 1.9838, Test Accuracy: 50.63%
#     Worker 0: Train Loss: 1.2915, Train Accuracy: 63.13%
#     Worker 1: Train Loss: 1.2830, Train Accuracy: 64.46%
#     Worker 2: Train Loss: 1.2727, Train Accuracy: 64.29%
#     Worker 3: Train Loss: 1.2821, Train Accuracy: 63.88%
# Epoch 120/150: Test Loss: 1.9856, Test Accuracy: 50.60%
#     Worker 0: Train Loss: 1.2719, Train Accuracy: 64.06%
#     Worker 1: Train Loss: 1.2731, Train Accuracy: 63.98%
#     Worker 2: Train Loss: 1.2798, Train Accuracy: 63.93%
#     Worker 3: Train Loss: 1.2720, Train Accuracy: 64.17%
# Epoch 121/150: Test Loss: 1.9837, Test Accuracy: 50.75%
#     Worker 0: Train Loss: 1.2943, Train Accuracy: 63.67%
#     Worker 1: Train Loss: 1.2590, Train Accuracy: 64.51%
#     Worker 2: Train Loss: 1.2703, Train Accuracy: 64.32%
#     Worker 3: Train Loss: 1.2901, Train Accuracy: 63.77%
# Epoch 122/150: Test Loss: 1.9865, Test Accuracy: 50.69%
#     Worker 0: Train Loss: 1.2675, Train Accuracy: 63.95%
#     Worker 1: Train Loss: 1.2725, Train Accuracy: 63.99%
#     Worker 2: Train Loss: 1.2745, Train Accuracy: 64.05%
#     Worker 3: Train Loss: 1.2703, Train Accuracy: 64.28%
# Epoch 123/150: Test Loss: 1.9916, Test Accuracy: 51.06%
#     Worker 0: Train Loss: 1.2646, Train Accuracy: 64.26%
#     Worker 1: Train Loss: 1.2555, Train Accuracy: 64.78%
#     Worker 2: Train Loss: 1.2590, Train Accuracy: 64.31%
#     Worker 3: Train Loss: 1.2569, Train Accuracy: 64.46%
# Epoch 124/150: Test Loss: 1.9830, Test Accuracy: 50.79%
#     Worker 0: Train Loss: 1.2537, Train Accuracy: 64.31%
#     Worker 1: Train Loss: 1.2686, Train Accuracy: 64.02%
#     Worker 2: Train Loss: 1.2553, Train Accuracy: 64.75%
#     Worker 3: Train Loss: 1.2773, Train Accuracy: 64.13%
# Epoch 125/150: Test Loss: 1.9850, Test Accuracy: 50.97%
#     Worker 0: Train Loss: 1.2472, Train Accuracy: 65.11%
#     Worker 1: Train Loss: 1.2602, Train Accuracy: 64.49%
#     Worker 2: Train Loss: 1.2575, Train Accuracy: 64.34%
#     Worker 3: Train Loss: 1.2608, Train Accuracy: 64.39%
# Epoch 126/150: Test Loss: 1.9824, Test Accuracy: 51.11%
#     Worker 0: Train Loss: 1.2668, Train Accuracy: 63.89%
#     Worker 1: Train Loss: 1.2565, Train Accuracy: 64.73%
#     Worker 2: Train Loss: 1.2756, Train Accuracy: 64.46%
#     Worker 3: Train Loss: 1.2376, Train Accuracy: 64.96%
# Epoch 127/150: Test Loss: 1.9893, Test Accuracy: 51.02%
#     Worker 0: Train Loss: 1.2408, Train Accuracy: 64.94%
#     Worker 1: Train Loss: 1.2373, Train Accuracy: 64.89%
#     Worker 2: Train Loss: 1.2413, Train Accuracy: 65.14%
#     Worker 3: Train Loss: 1.2634, Train Accuracy: 64.03%
# Epoch 128/150: Test Loss: 1.9892, Test Accuracy: 50.75%
#     Worker 0: Train Loss: 1.2559, Train Accuracy: 64.39%
#     Worker 1: Train Loss: 1.2762, Train Accuracy: 64.23%
#     Worker 2: Train Loss: 1.2511, Train Accuracy: 65.04%
#     Worker 3: Train Loss: 1.2501, Train Accuracy: 65.11%
# Epoch 129/150: Test Loss: 1.9860, Test Accuracy: 51.05%
#     Worker 0: Train Loss: 1.2644, Train Accuracy: 63.99%
#     Worker 1: Train Loss: 1.2557, Train Accuracy: 64.93%
#     Worker 2: Train Loss: 1.2571, Train Accuracy: 64.96%
#     Worker 3: Train Loss: 1.2460, Train Accuracy: 64.72%
# Epoch 130/150: Test Loss: 1.9875, Test Accuracy: 51.03%
#     Worker 0: Train Loss: 1.2432, Train Accuracy: 64.88%
#     Worker 1: Train Loss: 1.2440, Train Accuracy: 64.58%
#     Worker 2: Train Loss: 1.2321, Train Accuracy: 65.21%
#     Worker 3: Train Loss: 1.2308, Train Accuracy: 65.65%
# Epoch 131/150: Test Loss: 1.9864, Test Accuracy: 50.77%
#     Worker 0: Train Loss: 1.2381, Train Accuracy: 64.94%
#     Worker 1: Train Loss: 1.2512, Train Accuracy: 64.50%
#     Worker 2: Train Loss: 1.2270, Train Accuracy: 65.52%
#     Worker 3: Train Loss: 1.2498, Train Accuracy: 64.86%
# Epoch 132/150: Test Loss: 1.9869, Test Accuracy: 51.02%
#     Worker 0: Train Loss: 1.2512, Train Accuracy: 64.31%
#     Worker 1: Train Loss: 1.2314, Train Accuracy: 64.68%
#     Worker 2: Train Loss: 1.2470, Train Accuracy: 65.18%
#     Worker 3: Train Loss: 1.2315, Train Accuracy: 65.05%
# Epoch 133/150: Test Loss: 1.9889, Test Accuracy: 51.22%
#     Worker 0: Train Loss: 1.2254, Train Accuracy: 65.31%
#     Worker 1: Train Loss: 1.2421, Train Accuracy: 64.76%
#     Worker 2: Train Loss: 1.2195, Train Accuracy: 65.88%
#     Worker 3: Train Loss: 1.2203, Train Accuracy: 65.82%
# Epoch 134/150: Test Loss: 1.9884, Test Accuracy: 51.09%
#     Worker 0: Train Loss: 1.2067, Train Accuracy: 65.49%
#     Worker 1: Train Loss: 1.2382, Train Accuracy: 64.85%
#     Worker 2: Train Loss: 1.2301, Train Accuracy: 65.39%
#     Worker 3: Train Loss: 1.2409, Train Accuracy: 65.19%
# Epoch 135/150: Test Loss: 1.9879, Test Accuracy: 51.16%
#     Worker 0: Train Loss: 1.2584, Train Accuracy: 64.81%
#     Worker 1: Train Loss: 1.2421, Train Accuracy: 65.07%
#     Worker 2: Train Loss: 1.2335, Train Accuracy: 65.69%
#     Worker 3: Train Loss: 1.2216, Train Accuracy: 65.50%
# Epoch 136/150: Test Loss: 1.9875, Test Accuracy: 51.01%
#     Worker 0: Train Loss: 1.2125, Train Accuracy: 65.46%
#     Worker 1: Train Loss: 1.2198, Train Accuracy: 65.10%
#     Worker 2: Train Loss: 1.2271, Train Accuracy: 65.33%
#     Worker 3: Train Loss: 1.2227, Train Accuracy: 65.33%
# Epoch 137/150: Test Loss: 1.9906, Test Accuracy: 51.34%
#     Worker 0: Train Loss: 1.2307, Train Accuracy: 64.92%
#     Worker 1: Train Loss: 1.2203, Train Accuracy: 65.68%
#     Worker 2: Train Loss: 1.2212, Train Accuracy: 65.80%
#     Worker 3: Train Loss: 1.2169, Train Accuracy: 65.87%
# Epoch 138/150: Test Loss: 1.9883, Test Accuracy: 51.19%
#     Worker 0: Train Loss: 1.2350, Train Accuracy: 65.00%
#     Worker 1: Train Loss: 1.2257, Train Accuracy: 65.17%
#     Worker 2: Train Loss: 1.2142, Train Accuracy: 66.19%
#     Worker 3: Train Loss: 1.2408, Train Accuracy: 65.31%
# Epoch 139/150: Test Loss: 1.9884, Test Accuracy: 51.09%
#     Worker 0: Train Loss: 1.2284, Train Accuracy: 65.04%
#     Worker 1: Train Loss: 1.2263, Train Accuracy: 65.73%
#     Worker 2: Train Loss: 1.2274, Train Accuracy: 65.80%
#     Worker 3: Train Loss: 1.2011, Train Accuracy: 66.07%
# Epoch 140/150: Test Loss: 1.9884, Test Accuracy: 51.17%
#     Worker 0: Train Loss: 1.2149, Train Accuracy: 65.62%
#     Worker 1: Train Loss: 1.2401, Train Accuracy: 64.57%
#     Worker 2: Train Loss: 1.2087, Train Accuracy: 66.18%
#     Worker 3: Train Loss: 1.2238, Train Accuracy: 65.23%
# Epoch 141/150: Test Loss: 1.9885, Test Accuracy: 51.12%
#     Worker 0: Train Loss: 1.2242, Train Accuracy: 65.26%
#     Worker 1: Train Loss: 1.2318, Train Accuracy: 65.19%
#     Worker 2: Train Loss: 1.2107, Train Accuracy: 65.79%
#     Worker 3: Train Loss: 1.2318, Train Accuracy: 65.08%
# Epoch 142/150: Test Loss: 1.9869, Test Accuracy: 51.23%
#     Worker 0: Train Loss: 1.2269, Train Accuracy: 65.60%
#     Worker 1: Train Loss: 1.2247, Train Accuracy: 65.31%
#     Worker 2: Train Loss: 1.2093, Train Accuracy: 65.73%
#     Worker 3: Train Loss: 1.2148, Train Accuracy: 65.63%
# Epoch 143/150: Test Loss: 1.9881, Test Accuracy: 51.10%
#     Worker 0: Train Loss: 1.2112, Train Accuracy: 66.19%
#     Worker 1: Train Loss: 1.2221, Train Accuracy: 65.78%
#     Worker 2: Train Loss: 1.2131, Train Accuracy: 65.89%
#     Worker 3: Train Loss: 1.2250, Train Accuracy: 65.10%
# Epoch 144/150: Test Loss: 1.9875, Test Accuracy: 51.12%
#     Worker 0: Train Loss: 1.2241, Train Accuracy: 64.98%
#     Worker 1: Train Loss: 1.2210, Train Accuracy: 65.76%
#     Worker 2: Train Loss: 1.2204, Train Accuracy: 65.28%
#     Worker 3: Train Loss: 1.2069, Train Accuracy: 65.91%
# Epoch 145/150: Test Loss: 1.9877, Test Accuracy: 51.08%
#     Worker 0: Train Loss: 1.2286, Train Accuracy: 65.44%
#     Worker 1: Train Loss: 1.2231, Train Accuracy: 65.29%
#     Worker 2: Train Loss: 1.2130, Train Accuracy: 66.02%
#     Worker 3: Train Loss: 1.2163, Train Accuracy: 65.95%
# Epoch 146/150: Test Loss: 1.9878, Test Accuracy: 51.13%
#     Worker 0: Train Loss: 1.2195, Train Accuracy: 65.40%
#     Worker 1: Train Loss: 1.2211, Train Accuracy: 65.56%
#     Worker 2: Train Loss: 1.2254, Train Accuracy: 65.88%
#     Worker 3: Train Loss: 1.2179, Train Accuracy: 65.56%
# Epoch 147/150: Test Loss: 1.9876, Test Accuracy: 51.11%
#     Worker 0: Train Loss: 1.2325, Train Accuracy: 65.59%
#     Worker 1: Train Loss: 1.2191, Train Accuracy: 66.02%
#     Worker 2: Train Loss: 1.2221, Train Accuracy: 65.61%
#     Worker 3: Train Loss: 1.2101, Train Accuracy: 66.66%
# Epoch 148/150: Test Loss: 1.9876, Test Accuracy: 51.12%
#     Worker 0: Train Loss: 1.2239, Train Accuracy: 65.22%
#     Worker 1: Train Loss: 1.2192, Train Accuracy: 65.56%
#     Worker 2: Train Loss: 1.2163, Train Accuracy: 65.42%
#     Worker 3: Train Loss: 1.2220, Train Accuracy: 65.41%
# Epoch 149/150: Test Loss: 1.9876, Test Accuracy: 51.09%
#     Worker 0: Train Loss: 1.2168, Train Accuracy: 65.44%
#     Worker 1: Train Loss: 1.2126, Train Accuracy: 65.87%
#     Worker 2: Train Loss: 1.2167, Train Accuracy: 65.50%
#     Worker 3: Train Loss: 1.2160, Train Accuracy: 66.40%
# Epoch 150/150: Test Loss: 1.9876, Test Accuracy: 51.09%
#     Worker 0: Train Loss: 1.2195, Train Accuracy: 65.65%
#     Worker 1: Train Loss: 1.2332, Train Accuracy: 65.24%
#     Worker 2: Train Loss: 1.2241, Train Accuracy: 65.80%
#     Worker 3: Train Loss: 1.2312, Train Accuracy: 65.53%
