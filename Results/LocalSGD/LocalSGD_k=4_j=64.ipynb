# %%
# %%writefile localSGD.py

import os
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
num_epochs = 150
base_learning_rate = 1e-2
momentum = 0.9
weight_decay = 4e-4
warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std

class LRScheduler(torch.optim.lr_scheduler._LRScheduler):
    def __init__(self, optimizer, base_lr, K, warmup_epochs, total_epochs, verbose=False):
        """
        Args:
            optimizer: SGD
            base_lr: Base learning rate for the reference batch size.
            K: Number of workers.
            warmup_epochs: Number of warmup epochs.
            total_epochs: Total number of epochs.
            verbose: Whether to print LR updates.
        """
        self.base_lr = base_lr
        self.K = K
        self.scaled_lr = base_lr * K
        self.warmup_epochs = warmup_epochs
        self.total_epochs = total_epochs
        self.verbose = verbose
        super(LRScheduler, self).__init__(optimizer)

    def get_lr(self):
        epoch = self.last_epoch
        if epoch < self.warmup_epochs:
            # Linear warmup scaling
            warmup_factor = (epoch + 1) / self.warmup_epochs
            return [warmup_factor * self.scaled_lr for _ in self.optimizer.param_groups]
        else:
            # polynomially decaying learning rate of ηt = η0×(1−t/T)
            if epoch == self.warmup_epochs:
                print(f"Warmup phase completed at epoch {epoch}. Switching to polynomial decay learning rate.")
            return [self.scaled_lr * ( 1 - ( (epoch - self.warmup_epochs) / (self.total_epochs - self.warmup_epochs))) for _ in self.optimizer.param_groups]


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]

# Batch size
batch_size = shard_size // J

# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)


# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [LRScheduler(
    optimizer = optimizer,
    base_lr = base_learning_rate,
    K = K,
    warmup_epochs = warmup_epochs,
    total_epochs = num_epochs,
    verbose = True) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}")

    # Sequentially train each worker to simulate a distributed environment
    for k in range(K):
        shard_loader = DataLoader(shards[k], batch_size=batch_size, shuffle=True)

        nets[k].train()
        correct_train, total_train, train_loss = 0, 0, 0.0
        for images, labels in shard_loader:
            images, labels = images.to(device), labels.to(device)  # Move to device
            optimizers[k].zero_grad()
            outputs = nets[k](images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizers[k].step()
            # Calculate train loss and accuracy
            train_loss += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            total_train += labels.size(0)
            correct_train += predicted.eq(labels).sum().item()
        # Store train loss and accuracy for this worker
        train_loss /= len(shard_loader.dataset)
        train_losses_per_worker[k].append(train_loss)
        train_accuracy = 100. * correct_train / total_train
        train_accuracies_per_worker[k].append(train_accuracy)

    # Perform model synchronization
    with torch.no_grad():
        global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
        for net in nets:
            for global_param, local_param in zip(global_parameters, net.parameters()):
                global_param += local_param
        for global_param in global_parameters:
            global_param /= K
        # Update each worker model with the global parameters
        for net in nets:
            for local_param, global_param in zip(net.parameters(), global_parameters):
                local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        scheduler.step()

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Overwriting localSGD.py

# %%
# %run localSGD.py --k 4 --j 64
# Out:
# Training with K=4, J=64
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.04000
# Epoch 1/150: Test Loss: 4.5985, Test Accuracy: 1.36%
#     Worker 0: Train Loss: 4.6036, Train Accuracy: 1.32%
#     Worker 1: Train Loss: 4.6035, Train Accuracy: 1.27%
#     Worker 2: Train Loss: 4.6023, Train Accuracy: 1.45%
#     Worker 3: Train Loss: 4.6037, Train Accuracy: 1.18%
# Epoch 2/150: Test Loss: 4.4381, Test Accuracy: 4.14%
#     Worker 0: Train Loss: 4.5649, Train Accuracy: 2.07%
#     Worker 1: Train Loss: 4.5634, Train Accuracy: 1.72%
#     Worker 2: Train Loss: 4.5528, Train Accuracy: 1.93%
#     Worker 3: Train Loss: 4.5628, Train Accuracy: 2.04%
# Epoch 3/150: Test Loss: 4.0301, Test Accuracy: 8.31%
#     Worker 0: Train Loss: 4.2680, Train Accuracy: 5.22%
#     Worker 1: Train Loss: 4.2645, Train Accuracy: 5.22%
#     Worker 2: Train Loss: 4.2424, Train Accuracy: 5.47%
#     Worker 3: Train Loss: 4.2667, Train Accuracy: 5.08%
# Epoch 4/150: Test Loss: 3.8033, Test Accuracy: 11.84%
#     Worker 0: Train Loss: 4.0442, Train Accuracy: 7.36%
#     Worker 1: Train Loss: 4.0374, Train Accuracy: 7.89%
#     Worker 2: Train Loss: 4.0045, Train Accuracy: 7.98%
#     Worker 3: Train Loss: 4.0457, Train Accuracy: 7.66%
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Epoch 5/150: Test Loss: 3.6601, Test Accuracy: 14.70%
#     Worker 0: Train Loss: 3.8747, Train Accuracy: 9.91%
#     Worker 1: Train Loss: 3.8997, Train Accuracy: 9.75%
#     Worker 2: Train Loss: 3.8466, Train Accuracy: 10.29%
#     Worker 3: Train Loss: 3.8941, Train Accuracy: 9.58%
# Epoch 6/150: Test Loss: 3.4833, Test Accuracy: 17.36%
#     Worker 0: Train Loss: 3.7460, Train Accuracy: 11.63%
#     Worker 1: Train Loss: 3.7269, Train Accuracy: 12.69%
#     Worker 2: Train Loss: 3.7028, Train Accuracy: 12.84%
#     Worker 3: Train Loss: 3.7346, Train Accuracy: 12.10%
# Epoch 7/150: Test Loss: 3.3551, Test Accuracy: 19.74%
#     Worker 0: Train Loss: 3.6246, Train Accuracy: 13.82%
#     Worker 1: Train Loss: 3.6212, Train Accuracy: 14.25%
#     Worker 2: Train Loss: 3.5792, Train Accuracy: 14.41%
#     Worker 3: Train Loss: 3.6227, Train Accuracy: 13.93%
# Epoch 8/150: Test Loss: 3.3104, Test Accuracy: 20.37%
#     Worker 0: Train Loss: 3.4851, Train Accuracy: 16.16%
#     Worker 1: Train Loss: 3.5223, Train Accuracy: 15.54%
#     Worker 2: Train Loss: 3.4814, Train Accuracy: 16.43%
#     Worker 3: Train Loss: 3.5244, Train Accuracy: 15.71%
# Epoch 9/150: Test Loss: 3.1500, Test Accuracy: 23.43%
#     Worker 0: Train Loss: 3.4005, Train Accuracy: 17.22%
#     Worker 1: Train Loss: 3.4162, Train Accuracy: 17.55%
#     Worker 2: Train Loss: 3.4342, Train Accuracy: 17.66%
#     Worker 3: Train Loss: 3.4154, Train Accuracy: 17.79%
# Epoch 10/150: Test Loss: 3.0570, Test Accuracy: 25.03%
#     Worker 0: Train Loss: 3.3350, Train Accuracy: 19.07%
#     Worker 1: Train Loss: 3.3426, Train Accuracy: 18.84%
#     Worker 2: Train Loss: 3.3059, Train Accuracy: 19.44%
#     Worker 3: Train Loss: 3.3128, Train Accuracy: 19.32%
# Epoch 11/150: Test Loss: 2.9978, Test Accuracy: 26.15%
#     Worker 0: Train Loss: 3.2251, Train Accuracy: 20.61%
#     Worker 1: Train Loss: 3.2443, Train Accuracy: 21.10%
#     Worker 2: Train Loss: 3.1959, Train Accuracy: 21.35%
#     Worker 3: Train Loss: 3.2671, Train Accuracy: 19.92%
# Epoch 12/150: Test Loss: 2.8851, Test Accuracy: 28.76%
#     Worker 0: Train Loss: 3.1531, Train Accuracy: 22.26%
#     Worker 1: Train Loss: 3.1890, Train Accuracy: 21.61%
#     Worker 2: Train Loss: 3.1657, Train Accuracy: 22.06%
#     Worker 3: Train Loss: 3.2212, Train Accuracy: 20.67%
# Epoch 13/150: Test Loss: 2.8226, Test Accuracy: 29.45%
#     Worker 0: Train Loss: 3.0961, Train Accuracy: 23.34%
#     Worker 1: Train Loss: 3.1317, Train Accuracy: 22.60%
#     Worker 2: Train Loss: 3.0510, Train Accuracy: 24.34%
#     Worker 3: Train Loss: 3.0921, Train Accuracy: 23.18%
# Epoch 14/150: Test Loss: 2.7395, Test Accuracy: 31.18%
#     Worker 0: Train Loss: 3.0361, Train Accuracy: 24.31%
#     Worker 1: Train Loss: 3.0279, Train Accuracy: 25.06%
#     Worker 2: Train Loss: 3.0029, Train Accuracy: 25.37%
#     Worker 3: Train Loss: 3.0240, Train Accuracy: 24.91%
# Epoch 15/150: Test Loss: 2.6916, Test Accuracy: 32.08%
#     Worker 0: Train Loss: 2.9735, Train Accuracy: 25.85%
#     Worker 1: Train Loss: 2.9700, Train Accuracy: 26.12%
#     Worker 2: Train Loss: 2.9464, Train Accuracy: 26.43%
#     Worker 3: Train Loss: 2.9926, Train Accuracy: 25.52%
# Epoch 16/150: Test Loss: 2.6150, Test Accuracy: 34.18%
#     Worker 0: Train Loss: 2.9090, Train Accuracy: 27.11%
#     Worker 1: Train Loss: 2.9307, Train Accuracy: 26.74%
#     Worker 2: Train Loss: 2.8668, Train Accuracy: 28.14%
#     Worker 3: Train Loss: 2.8943, Train Accuracy: 26.66%
# Epoch 17/150: Test Loss: 2.5847, Test Accuracy: 34.40%
#     Worker 0: Train Loss: 2.8440, Train Accuracy: 28.00%
#     Worker 1: Train Loss: 2.8300, Train Accuracy: 29.06%
#     Worker 2: Train Loss: 2.8282, Train Accuracy: 29.22%
#     Worker 3: Train Loss: 2.8464, Train Accuracy: 28.37%
# Epoch 18/150: Test Loss: 2.5283, Test Accuracy: 36.17%
#     Worker 0: Train Loss: 2.7780, Train Accuracy: 29.27%
#     Worker 1: Train Loss: 2.8258, Train Accuracy: 28.57%
#     Worker 2: Train Loss: 2.7494, Train Accuracy: 30.68%
#     Worker 3: Train Loss: 2.8021, Train Accuracy: 29.15%
# Epoch 19/150: Test Loss: 2.5207, Test Accuracy: 36.29%
#     Worker 0: Train Loss: 2.7466, Train Accuracy: 29.70%
#     Worker 1: Train Loss: 2.7660, Train Accuracy: 30.06%
#     Worker 2: Train Loss: 2.7506, Train Accuracy: 30.04%
#     Worker 3: Train Loss: 2.7498, Train Accuracy: 30.10%
# Epoch 20/150: Test Loss: 2.4298, Test Accuracy: 37.86%
#     Worker 0: Train Loss: 2.7062, Train Accuracy: 30.79%
#     Worker 1: Train Loss: 2.7084, Train Accuracy: 31.05%
#     Worker 2: Train Loss: 2.6819, Train Accuracy: 31.35%
#     Worker 3: Train Loss: 2.6806, Train Accuracy: 31.09%
# Epoch 21/150: Test Loss: 2.4462, Test Accuracy: 37.37%
#     Worker 0: Train Loss: 2.6614, Train Accuracy: 31.94%
#     Worker 1: Train Loss: 2.6423, Train Accuracy: 32.30%
#     Worker 2: Train Loss: 2.6630, Train Accuracy: 32.22%
#     Worker 3: Train Loss: 2.6277, Train Accuracy: 32.70%
# Epoch 22/150: Test Loss: 2.3812, Test Accuracy: 38.94%
#     Worker 0: Train Loss: 2.6533, Train Accuracy: 32.05%
#     Worker 1: Train Loss: 2.6100, Train Accuracy: 32.91%
#     Worker 2: Train Loss: 2.6083, Train Accuracy: 33.20%
#     Worker 3: Train Loss: 2.6061, Train Accuracy: 33.20%
# Epoch 23/150: Test Loss: 2.3751, Test Accuracy: 39.52%
#     Worker 0: Train Loss: 2.5471, Train Accuracy: 34.02%
#     Worker 1: Train Loss: 2.6476, Train Accuracy: 32.39%
#     Worker 2: Train Loss: 2.5616, Train Accuracy: 33.78%
#     Worker 3: Train Loss: 2.6307, Train Accuracy: 32.82%
# Epoch 24/150: Test Loss: 2.3451, Test Accuracy: 39.59%
#     Worker 0: Train Loss: 2.5209, Train Accuracy: 35.26%
#     Worker 1: Train Loss: 2.5629, Train Accuracy: 34.07%
#     Worker 2: Train Loss: 2.5368, Train Accuracy: 34.62%
#     Worker 3: Train Loss: 2.5426, Train Accuracy: 34.53%
# Epoch 25/150: Test Loss: 2.3193, Test Accuracy: 40.26%
#     Worker 0: Train Loss: 2.4853, Train Accuracy: 35.69%
#     Worker 1: Train Loss: 2.5003, Train Accuracy: 35.35%
#     Worker 2: Train Loss: 2.4814, Train Accuracy: 35.67%
#     Worker 3: Train Loss: 2.5302, Train Accuracy: 34.66%
# Epoch 26/150: Test Loss: 2.2809, Test Accuracy: 41.15%
#     Worker 0: Train Loss: 2.4660, Train Accuracy: 35.98%
#     Worker 1: Train Loss: 2.4810, Train Accuracy: 35.62%
#     Worker 2: Train Loss: 2.4983, Train Accuracy: 35.50%
#     Worker 3: Train Loss: 2.4673, Train Accuracy: 36.00%
# Epoch 27/150: Test Loss: 2.2798, Test Accuracy: 40.81%
#     Worker 0: Train Loss: 2.4992, Train Accuracy: 35.36%
#     Worker 1: Train Loss: 2.4626, Train Accuracy: 36.05%
#     Worker 2: Train Loss: 2.4177, Train Accuracy: 36.73%
#     Worker 3: Train Loss: 2.4475, Train Accuracy: 35.92%
# Epoch 28/150: Test Loss: 2.2724, Test Accuracy: 41.46%
#     Worker 0: Train Loss: 2.4254, Train Accuracy: 36.42%
#     Worker 1: Train Loss: 2.4326, Train Accuracy: 36.58%
#     Worker 2: Train Loss: 2.4111, Train Accuracy: 37.30%
#     Worker 3: Train Loss: 2.4228, Train Accuracy: 37.22%
# Epoch 29/150: Test Loss: 2.2279, Test Accuracy: 42.25%
#     Worker 0: Train Loss: 2.3902, Train Accuracy: 37.98%
#     Worker 1: Train Loss: 2.3851, Train Accuracy: 37.47%
#     Worker 2: Train Loss: 2.3555, Train Accuracy: 38.46%
#     Worker 3: Train Loss: 2.4425, Train Accuracy: 36.80%
# Epoch 30/150: Test Loss: 2.2134, Test Accuracy: 42.35%
#     Worker 0: Train Loss: 2.3156, Train Accuracy: 38.70%
#     Worker 1: Train Loss: 2.3964, Train Accuracy: 37.42%
#     Worker 2: Train Loss: 2.3416, Train Accuracy: 39.04%
#     Worker 3: Train Loss: 2.3799, Train Accuracy: 38.27%
# Epoch 31/150: Test Loss: 2.1921, Test Accuracy: 43.07%
#     Worker 0: Train Loss: 2.3290, Train Accuracy: 38.79%
#     Worker 1: Train Loss: 2.3868, Train Accuracy: 37.50%
#     Worker 2: Train Loss: 2.3388, Train Accuracy: 39.19%
#     Worker 3: Train Loss: 2.3436, Train Accuracy: 38.37%
# Epoch 32/150: Test Loss: 2.1939, Test Accuracy: 42.76%
#     Worker 0: Train Loss: 2.3098, Train Accuracy: 39.21%
#     Worker 1: Train Loss: 2.3335, Train Accuracy: 38.56%
#     Worker 2: Train Loss: 2.2960, Train Accuracy: 39.59%
#     Worker 3: Train Loss: 2.3145, Train Accuracy: 39.03%
# Epoch 33/150: Test Loss: 2.1769, Test Accuracy: 43.57%
#     Worker 0: Train Loss: 2.2688, Train Accuracy: 39.46%
#     Worker 1: Train Loss: 2.3214, Train Accuracy: 39.03%
#     Worker 2: Train Loss: 2.2474, Train Accuracy: 40.72%
#     Worker 3: Train Loss: 2.3194, Train Accuracy: 38.91%
# Epoch 34/150: Test Loss: 2.1130, Test Accuracy: 44.68%
#     Worker 0: Train Loss: 2.2169, Train Accuracy: 40.91%
#     Worker 1: Train Loss: 2.2751, Train Accuracy: 40.82%
#     Worker 2: Train Loss: 2.2700, Train Accuracy: 40.66%
#     Worker 3: Train Loss: 2.2588, Train Accuracy: 40.37%
# Epoch 35/150: Test Loss: 2.1119, Test Accuracy: 45.14%
#     Worker 0: Train Loss: 2.1822, Train Accuracy: 41.67%
#     Worker 1: Train Loss: 2.2642, Train Accuracy: 40.27%
#     Worker 2: Train Loss: 2.1855, Train Accuracy: 42.29%
#     Worker 3: Train Loss: 2.2047, Train Accuracy: 41.15%
# Epoch 36/150: Test Loss: 2.1442, Test Accuracy: 44.25%
#     Worker 0: Train Loss: 2.2331, Train Accuracy: 40.83%
#     Worker 1: Train Loss: 2.2310, Train Accuracy: 40.62%
#     Worker 2: Train Loss: 2.1869, Train Accuracy: 41.94%
#     Worker 3: Train Loss: 2.2190, Train Accuracy: 40.90%
# Epoch 37/150: Test Loss: 2.0984, Test Accuracy: 45.55%
#     Worker 0: Train Loss: 2.2194, Train Accuracy: 41.22%
#     Worker 1: Train Loss: 2.1934, Train Accuracy: 42.42%
#     Worker 2: Train Loss: 2.2078, Train Accuracy: 41.50%
#     Worker 3: Train Loss: 2.1940, Train Accuracy: 41.56%
# Epoch 38/150: Test Loss: 2.0697, Test Accuracy: 45.89%
#     Worker 0: Train Loss: 2.1603, Train Accuracy: 42.15%
#     Worker 1: Train Loss: 2.2258, Train Accuracy: 41.42%
#     Worker 2: Train Loss: 2.1359, Train Accuracy: 43.06%
#     Worker 3: Train Loss: 2.1769, Train Accuracy: 42.36%
# Epoch 39/150: Test Loss: 2.0691, Test Accuracy: 46.02%
#     Worker 0: Train Loss: 2.1294, Train Accuracy: 43.09%
#     Worker 1: Train Loss: 2.1775, Train Accuracy: 42.18%
#     Worker 2: Train Loss: 2.1344, Train Accuracy: 43.27%
#     Worker 3: Train Loss: 2.1516, Train Accuracy: 42.33%
# Epoch 40/150: Test Loss: 2.0566, Test Accuracy: 45.80%
#     Worker 0: Train Loss: 2.1092, Train Accuracy: 43.62%
#     Worker 1: Train Loss: 2.1520, Train Accuracy: 42.64%
#     Worker 2: Train Loss: 2.1235, Train Accuracy: 43.38%
#     Worker 3: Train Loss: 2.1417, Train Accuracy: 43.05%
# Epoch 41/150: Test Loss: 2.0487, Test Accuracy: 46.43%
#     Worker 0: Train Loss: 2.1204, Train Accuracy: 42.82%
#     Worker 1: Train Loss: 2.0955, Train Accuracy: 44.29%
#     Worker 2: Train Loss: 2.0690, Train Accuracy: 45.08%
#     Worker 3: Train Loss: 2.1206, Train Accuracy: 42.86%
# Epoch 42/150: Test Loss: 2.0304, Test Accuracy: 47.09%
#     Worker 0: Train Loss: 2.0952, Train Accuracy: 43.94%
#     Worker 1: Train Loss: 2.1003, Train Accuracy: 43.85%
#     Worker 2: Train Loss: 2.0603, Train Accuracy: 44.78%
#     Worker 3: Train Loss: 2.0915, Train Accuracy: 44.31%
# Epoch 43/150: Test Loss: 2.0311, Test Accuracy: 46.74%
#     Worker 0: Train Loss: 2.0404, Train Accuracy: 44.57%
#     Worker 1: Train Loss: 2.1061, Train Accuracy: 43.78%
#     Worker 2: Train Loss: 2.0596, Train Accuracy: 45.22%
#     Worker 3: Train Loss: 2.0742, Train Accuracy: 44.51%
# Epoch 44/150: Test Loss: 2.0207, Test Accuracy: 46.91%
#     Worker 0: Train Loss: 2.0458, Train Accuracy: 44.75%
#     Worker 1: Train Loss: 2.0593, Train Accuracy: 44.98%
#     Worker 2: Train Loss: 2.0419, Train Accuracy: 45.46%
#     Worker 3: Train Loss: 2.0482, Train Accuracy: 45.06%
# Epoch 45/150: Test Loss: 2.0287, Test Accuracy: 46.98%
#     Worker 0: Train Loss: 2.0240, Train Accuracy: 44.91%
#     Worker 1: Train Loss: 2.0135, Train Accuracy: 46.14%
#     Worker 2: Train Loss: 2.0150, Train Accuracy: 45.93%
#     Worker 3: Train Loss: 2.0324, Train Accuracy: 45.38%
# Epoch 46/150: Test Loss: 2.0289, Test Accuracy: 46.82%
#     Worker 0: Train Loss: 1.9993, Train Accuracy: 45.76%
#     Worker 1: Train Loss: 2.0305, Train Accuracy: 45.53%
#     Worker 2: Train Loss: 1.9905, Train Accuracy: 46.43%
#     Worker 3: Train Loss: 1.9924, Train Accuracy: 46.19%
# Epoch 47/150: Test Loss: 1.9900, Test Accuracy: 47.71%
#     Worker 0: Train Loss: 1.9853, Train Accuracy: 45.79%
#     Worker 1: Train Loss: 2.0148, Train Accuracy: 45.58%
#     Worker 2: Train Loss: 2.0006, Train Accuracy: 45.98%
#     Worker 3: Train Loss: 1.9810, Train Accuracy: 46.37%
# Epoch 48/150: Test Loss: 1.9631, Test Accuracy: 48.52%
#     Worker 0: Train Loss: 1.9574, Train Accuracy: 46.62%
#     Worker 1: Train Loss: 2.0030, Train Accuracy: 45.97%
#     Worker 2: Train Loss: 1.9878, Train Accuracy: 46.39%
#     Worker 3: Train Loss: 1.9788, Train Accuracy: 46.92%
# Epoch 49/150: Test Loss: 2.0003, Test Accuracy: 47.30%
#     Worker 0: Train Loss: 1.9628, Train Accuracy: 46.79%
#     Worker 1: Train Loss: 1.9549, Train Accuracy: 46.90%
#     Worker 2: Train Loss: 1.9331, Train Accuracy: 47.34%
#     Worker 3: Train Loss: 1.9426, Train Accuracy: 47.73%
# Epoch 50/150: Test Loss: 1.9857, Test Accuracy: 47.99%
#     Worker 0: Train Loss: 1.9358, Train Accuracy: 47.18%
#     Worker 1: Train Loss: 1.9608, Train Accuracy: 46.33%
#     Worker 2: Train Loss: 1.9207, Train Accuracy: 47.96%
#     Worker 3: Train Loss: 1.9376, Train Accuracy: 47.46%
# Epoch 51/150: Test Loss: 1.9798, Test Accuracy: 48.23%
#     Worker 0: Train Loss: 1.9225, Train Accuracy: 47.70%
#     Worker 1: Train Loss: 1.9503, Train Accuracy: 47.56%
#     Worker 2: Train Loss: 1.9406, Train Accuracy: 47.21%
#     Worker 3: Train Loss: 1.9261, Train Accuracy: 46.94%
# Epoch 52/150: Test Loss: 1.9713, Test Accuracy: 48.22%
#     Worker 0: Train Loss: 1.8928, Train Accuracy: 48.12%
#     Worker 1: Train Loss: 1.8804, Train Accuracy: 48.06%
#     Worker 2: Train Loss: 1.9450, Train Accuracy: 47.33%
#     Worker 3: Train Loss: 1.9056, Train Accuracy: 48.46%
# Epoch 53/150: Test Loss: 1.9752, Test Accuracy: 48.13%
#     Worker 0: Train Loss: 1.8622, Train Accuracy: 48.97%
#     Worker 1: Train Loss: 1.8797, Train Accuracy: 48.78%
#     Worker 2: Train Loss: 1.8627, Train Accuracy: 49.41%
#     Worker 3: Train Loss: 1.9031, Train Accuracy: 47.99%
# Epoch 54/150: Test Loss: 1.9441, Test Accuracy: 49.21%
#     Worker 0: Train Loss: 1.8367, Train Accuracy: 49.10%
#     Worker 1: Train Loss: 1.9066, Train Accuracy: 47.92%
#     Worker 2: Train Loss: 1.8786, Train Accuracy: 49.41%
#     Worker 3: Train Loss: 1.8698, Train Accuracy: 48.92%
# Epoch 55/150: Test Loss: 1.9410, Test Accuracy: 48.70%
#     Worker 0: Train Loss: 1.8412, Train Accuracy: 49.31%
#     Worker 1: Train Loss: 1.8476, Train Accuracy: 49.58%
#     Worker 2: Train Loss: 1.8327, Train Accuracy: 49.42%
#     Worker 3: Train Loss: 1.8413, Train Accuracy: 50.01%
# Epoch 56/150: Test Loss: 1.9314, Test Accuracy: 49.45%
#     Worker 0: Train Loss: 1.8321, Train Accuracy: 49.71%
#     Worker 1: Train Loss: 1.8219, Train Accuracy: 50.12%
#     Worker 2: Train Loss: 1.8225, Train Accuracy: 49.98%
#     Worker 3: Train Loss: 1.8320, Train Accuracy: 49.40%
# Epoch 57/150: Test Loss: 1.9431, Test Accuracy: 48.80%
#     Worker 0: Train Loss: 1.7986, Train Accuracy: 50.68%
#     Worker 1: Train Loss: 1.8562, Train Accuracy: 49.20%
#     Worker 2: Train Loss: 1.8021, Train Accuracy: 50.57%
#     Worker 3: Train Loss: 1.8154, Train Accuracy: 50.22%
# Epoch 58/150: Test Loss: 1.9144, Test Accuracy: 50.12%
#     Worker 0: Train Loss: 1.7835, Train Accuracy: 51.01%
#     Worker 1: Train Loss: 1.7958, Train Accuracy: 50.66%
#     Worker 2: Train Loss: 1.8080, Train Accuracy: 50.94%
#     Worker 3: Train Loss: 1.8502, Train Accuracy: 49.14%
# Epoch 59/150: Test Loss: 1.9174, Test Accuracy: 50.12%
#     Worker 0: Train Loss: 1.7719, Train Accuracy: 50.67%
#     Worker 1: Train Loss: 1.8128, Train Accuracy: 50.81%
#     Worker 2: Train Loss: 1.7564, Train Accuracy: 51.20%
#     Worker 3: Train Loss: 1.8133, Train Accuracy: 50.37%
# Epoch 60/150: Test Loss: 1.9358, Test Accuracy: 49.24%
#     Worker 0: Train Loss: 1.8034, Train Accuracy: 50.38%
#     Worker 1: Train Loss: 1.8059, Train Accuracy: 50.80%
#     Worker 2: Train Loss: 1.7970, Train Accuracy: 50.90%
#     Worker 3: Train Loss: 1.7803, Train Accuracy: 50.82%
# Epoch 61/150: Test Loss: 1.9172, Test Accuracy: 49.67%
#     Worker 0: Train Loss: 1.7889, Train Accuracy: 51.17%
#     Worker 1: Train Loss: 1.7869, Train Accuracy: 50.88%
#     Worker 2: Train Loss: 1.7470, Train Accuracy: 51.38%
#     Worker 3: Train Loss: 1.7820, Train Accuracy: 50.78%
# Epoch 62/150: Test Loss: 1.9032, Test Accuracy: 50.15%
#     Worker 0: Train Loss: 1.7549, Train Accuracy: 51.74%
#     Worker 1: Train Loss: 1.7730, Train Accuracy: 50.82%
#     Worker 2: Train Loss: 1.7409, Train Accuracy: 51.75%
#     Worker 3: Train Loss: 1.7693, Train Accuracy: 51.26%
# Epoch 63/150: Test Loss: 1.9043, Test Accuracy: 50.05%
#     Worker 0: Train Loss: 1.7619, Train Accuracy: 50.97%
#     Worker 1: Train Loss: 1.7299, Train Accuracy: 52.48%
#     Worker 2: Train Loss: 1.7419, Train Accuracy: 52.04%
#     Worker 3: Train Loss: 1.7397, Train Accuracy: 52.03%
# Epoch 64/150: Test Loss: 1.9015, Test Accuracy: 50.52%
#     Worker 0: Train Loss: 1.7047, Train Accuracy: 52.44%
#     Worker 1: Train Loss: 1.7210, Train Accuracy: 52.05%
#     Worker 2: Train Loss: 1.7329, Train Accuracy: 52.26%
#     Worker 3: Train Loss: 1.7243, Train Accuracy: 52.31%
# Epoch 65/150: Test Loss: 1.8946, Test Accuracy: 50.05%
#     Worker 0: Train Loss: 1.6759, Train Accuracy: 53.25%
#     Worker 1: Train Loss: 1.7364, Train Accuracy: 52.57%
#     Worker 2: Train Loss: 1.6841, Train Accuracy: 53.25%
#     Worker 3: Train Loss: 1.7063, Train Accuracy: 52.93%
# Epoch 66/150: Test Loss: 1.8879, Test Accuracy: 51.00%
#     Worker 0: Train Loss: 1.6766, Train Accuracy: 53.24%
#     Worker 1: Train Loss: 1.6883, Train Accuracy: 53.37%
#     Worker 2: Train Loss: 1.6958, Train Accuracy: 52.74%
#     Worker 3: Train Loss: 1.7435, Train Accuracy: 51.78%
# Epoch 67/150: Test Loss: 1.9011, Test Accuracy: 50.14%
#     Worker 0: Train Loss: 1.6908, Train Accuracy: 52.28%
#     Worker 1: Train Loss: 1.6660, Train Accuracy: 54.08%
#     Worker 2: Train Loss: 1.6400, Train Accuracy: 54.69%
#     Worker 3: Train Loss: 1.6960, Train Accuracy: 52.98%
# Epoch 68/150: Test Loss: 1.8879, Test Accuracy: 50.81%
#     Worker 0: Train Loss: 1.7113, Train Accuracy: 52.57%
#     Worker 1: Train Loss: 1.7098, Train Accuracy: 52.81%
#     Worker 2: Train Loss: 1.6237, Train Accuracy: 54.54%
#     Worker 3: Train Loss: 1.6744, Train Accuracy: 53.76%
# Epoch 69/150: Test Loss: 1.9028, Test Accuracy: 50.41%
#     Worker 0: Train Loss: 1.6696, Train Accuracy: 53.67%
#     Worker 1: Train Loss: 1.6852, Train Accuracy: 54.08%
#     Worker 2: Train Loss: 1.6375, Train Accuracy: 54.35%
#     Worker 3: Train Loss: 1.6784, Train Accuracy: 53.22%
# Epoch 70/150: Test Loss: 1.8970, Test Accuracy: 50.66%
#     Worker 0: Train Loss: 1.6668, Train Accuracy: 53.26%
#     Worker 1: Train Loss: 1.6383, Train Accuracy: 53.75%
#     Worker 2: Train Loss: 1.6680, Train Accuracy: 53.91%
#     Worker 3: Train Loss: 1.6254, Train Accuracy: 54.86%
# Epoch 71/150: Test Loss: 1.8985, Test Accuracy: 50.91%
#     Worker 0: Train Loss: 1.6492, Train Accuracy: 54.02%
#     Worker 1: Train Loss: 1.6271, Train Accuracy: 54.75%
#     Worker 2: Train Loss: 1.6149, Train Accuracy: 55.24%
#     Worker 3: Train Loss: 1.6552, Train Accuracy: 54.22%
# Epoch 72/150: Test Loss: 1.9015, Test Accuracy: 50.96%
#     Worker 0: Train Loss: 1.6032, Train Accuracy: 55.13%
#     Worker 1: Train Loss: 1.6352, Train Accuracy: 54.65%
#     Worker 2: Train Loss: 1.6196, Train Accuracy: 54.43%
#     Worker 3: Train Loss: 1.6182, Train Accuracy: 54.52%
# Epoch 73/150: Test Loss: 1.8888, Test Accuracy: 51.24%
#     Worker 0: Train Loss: 1.5826, Train Accuracy: 55.58%
#     Worker 1: Train Loss: 1.6468, Train Accuracy: 54.21%
#     Worker 2: Train Loss: 1.5864, Train Accuracy: 55.66%
#     Worker 3: Train Loss: 1.6121, Train Accuracy: 54.66%
# Epoch 74/150: Test Loss: 1.8906, Test Accuracy: 50.87%
#     Worker 0: Train Loss: 1.6157, Train Accuracy: 54.55%
#     Worker 1: Train Loss: 1.6022, Train Accuracy: 55.10%
#     Worker 2: Train Loss: 1.6065, Train Accuracy: 54.98%
#     Worker 3: Train Loss: 1.6364, Train Accuracy: 54.42%
# Epoch 75/150: Test Loss: 1.8806, Test Accuracy: 51.12%
#     Worker 0: Train Loss: 1.5901, Train Accuracy: 54.94%
#     Worker 1: Train Loss: 1.5839, Train Accuracy: 55.87%
#     Worker 2: Train Loss: 1.5563, Train Accuracy: 56.53%
#     Worker 3: Train Loss: 1.6151, Train Accuracy: 54.79%
# Epoch 76/150: Test Loss: 1.8928, Test Accuracy: 50.51%
#     Worker 0: Train Loss: 1.5885, Train Accuracy: 54.89%
#     Worker 1: Train Loss: 1.5490, Train Accuracy: 56.70%
#     Worker 2: Train Loss: 1.5363, Train Accuracy: 57.06%
#     Worker 3: Train Loss: 1.5719, Train Accuracy: 55.98%
# Epoch 77/150: Test Loss: 1.8899, Test Accuracy: 51.40%
#     Worker 0: Train Loss: 1.5816, Train Accuracy: 55.46%
#     Worker 1: Train Loss: 1.5485, Train Accuracy: 56.18%
#     Worker 2: Train Loss: 1.5793, Train Accuracy: 55.66%
#     Worker 3: Train Loss: 1.5763, Train Accuracy: 55.85%
# Epoch 78/150: Test Loss: 1.8759, Test Accuracy: 51.63%
#     Worker 0: Train Loss: 1.5471, Train Accuracy: 56.14%
#     Worker 1: Train Loss: 1.5471, Train Accuracy: 56.75%
#     Worker 2: Train Loss: 1.5299, Train Accuracy: 56.75%
#     Worker 3: Train Loss: 1.5673, Train Accuracy: 56.19%
# Epoch 79/150: Test Loss: 1.8800, Test Accuracy: 51.53%
#     Worker 0: Train Loss: 1.5322, Train Accuracy: 56.83%
#     Worker 1: Train Loss: 1.5497, Train Accuracy: 57.02%
#     Worker 2: Train Loss: 1.4998, Train Accuracy: 58.02%
#     Worker 3: Train Loss: 1.5478, Train Accuracy: 56.73%
# Epoch 80/150: Test Loss: 1.8961, Test Accuracy: 51.60%
#     Worker 0: Train Loss: 1.5520, Train Accuracy: 55.98%
#     Worker 1: Train Loss: 1.5203, Train Accuracy: 57.66%
#     Worker 2: Train Loss: 1.5183, Train Accuracy: 57.05%
#     Worker 3: Train Loss: 1.5635, Train Accuracy: 56.03%
# Epoch 81/150: Test Loss: 1.8876, Test Accuracy: 51.31%
#     Worker 0: Train Loss: 1.4791, Train Accuracy: 57.67%
#     Worker 1: Train Loss: 1.4988, Train Accuracy: 58.13%
#     Worker 2: Train Loss: 1.4908, Train Accuracy: 58.28%
#     Worker 3: Train Loss: 1.4967, Train Accuracy: 57.59%
# Epoch 82/150: Test Loss: 1.9027, Test Accuracy: 51.15%
#     Worker 0: Train Loss: 1.5046, Train Accuracy: 57.27%
#     Worker 1: Train Loss: 1.4979, Train Accuracy: 58.07%
#     Worker 2: Train Loss: 1.4631, Train Accuracy: 58.50%
#     Worker 3: Train Loss: 1.5128, Train Accuracy: 57.26%
# Epoch 83/150: Test Loss: 1.8832, Test Accuracy: 52.03%
#     Worker 0: Train Loss: 1.4777, Train Accuracy: 57.50%
#     Worker 1: Train Loss: 1.4687, Train Accuracy: 58.59%
#     Worker 2: Train Loss: 1.4867, Train Accuracy: 58.23%
#     Worker 3: Train Loss: 1.4684, Train Accuracy: 58.80%
# Epoch 84/150: Test Loss: 1.8813, Test Accuracy: 51.61%
#     Worker 0: Train Loss: 1.4769, Train Accuracy: 57.30%
#     Worker 1: Train Loss: 1.4508, Train Accuracy: 59.30%
#     Worker 2: Train Loss: 1.4622, Train Accuracy: 58.46%
#     Worker 3: Train Loss: 1.4447, Train Accuracy: 59.02%
# Epoch 85/150: Test Loss: 1.8696, Test Accuracy: 51.63%
#     Worker 0: Train Loss: 1.4569, Train Accuracy: 58.58%
#     Worker 1: Train Loss: 1.4727, Train Accuracy: 58.45%
#     Worker 2: Train Loss: 1.4572, Train Accuracy: 58.63%
#     Worker 3: Train Loss: 1.4508, Train Accuracy: 58.95%
# Epoch 86/150: Test Loss: 1.8842, Test Accuracy: 52.04%
#     Worker 0: Train Loss: 1.4207, Train Accuracy: 59.03%
#     Worker 1: Train Loss: 1.4324, Train Accuracy: 59.32%
#     Worker 2: Train Loss: 1.4427, Train Accuracy: 59.07%
#     Worker 3: Train Loss: 1.4609, Train Accuracy: 58.64%
# Epoch 87/150: Test Loss: 1.8760, Test Accuracy: 52.31%
#     Worker 0: Train Loss: 1.4537, Train Accuracy: 58.25%
#     Worker 1: Train Loss: 1.4379, Train Accuracy: 59.35%
#     Worker 2: Train Loss: 1.4175, Train Accuracy: 59.42%
#     Worker 3: Train Loss: 1.4270, Train Accuracy: 58.98%
# Epoch 88/150: Test Loss: 1.8769, Test Accuracy: 51.89%
#     Worker 0: Train Loss: 1.4092, Train Accuracy: 59.92%
#     Worker 1: Train Loss: 1.4078, Train Accuracy: 59.96%
#     Worker 2: Train Loss: 1.4517, Train Accuracy: 58.88%
#     Worker 3: Train Loss: 1.4223, Train Accuracy: 59.23%
# Epoch 89/150: Test Loss: 1.8629, Test Accuracy: 52.38%
#     Worker 0: Train Loss: 1.4234, Train Accuracy: 59.24%
#     Worker 1: Train Loss: 1.4068, Train Accuracy: 60.34%
#     Worker 2: Train Loss: 1.3951, Train Accuracy: 60.17%
#     Worker 3: Train Loss: 1.4807, Train Accuracy: 58.11%
# Epoch 90/150: Test Loss: 1.8687, Test Accuracy: 52.10%
#     Worker 0: Train Loss: 1.4047, Train Accuracy: 59.90%
#     Worker 1: Train Loss: 1.4163, Train Accuracy: 60.28%
#     Worker 2: Train Loss: 1.3776, Train Accuracy: 60.68%
#     Worker 3: Train Loss: 1.4154, Train Accuracy: 59.36%
# Epoch 91/150: Test Loss: 1.8887, Test Accuracy: 51.89%
#     Worker 0: Train Loss: 1.3883, Train Accuracy: 60.17%
#     Worker 1: Train Loss: 1.3823, Train Accuracy: 60.48%
#     Worker 2: Train Loss: 1.3754, Train Accuracy: 60.77%
#     Worker 3: Train Loss: 1.4258, Train Accuracy: 59.01%
# Epoch 92/150: Test Loss: 1.8825, Test Accuracy: 51.84%
#     Worker 0: Train Loss: 1.3635, Train Accuracy: 61.16%
#     Worker 1: Train Loss: 1.3924, Train Accuracy: 60.58%
#     Worker 2: Train Loss: 1.3842, Train Accuracy: 60.36%
#     Worker 3: Train Loss: 1.4165, Train Accuracy: 59.85%
# Epoch 93/150: Test Loss: 1.8805, Test Accuracy: 52.14%
#     Worker 0: Train Loss: 1.3510, Train Accuracy: 60.82%
#     Worker 1: Train Loss: 1.4008, Train Accuracy: 60.37%
#     Worker 2: Train Loss: 1.3437, Train Accuracy: 61.38%
#     Worker 3: Train Loss: 1.3785, Train Accuracy: 60.43%
# Epoch 94/150: Test Loss: 1.8921, Test Accuracy: 51.51%
#     Worker 0: Train Loss: 1.3765, Train Accuracy: 60.77%
#     Worker 1: Train Loss: 1.3401, Train Accuracy: 62.18%
#     Worker 2: Train Loss: 1.3442, Train Accuracy: 61.29%
#     Worker 3: Train Loss: 1.3809, Train Accuracy: 60.58%
# Epoch 95/150: Test Loss: 1.8896, Test Accuracy: 52.17%
#     Worker 0: Train Loss: 1.3659, Train Accuracy: 61.05%
#     Worker 1: Train Loss: 1.3353, Train Accuracy: 61.88%
#     Worker 2: Train Loss: 1.3461, Train Accuracy: 61.35%
#     Worker 3: Train Loss: 1.3713, Train Accuracy: 60.85%
# Epoch 96/150: Test Loss: 1.8987, Test Accuracy: 51.77%
#     Worker 0: Train Loss: 1.3314, Train Accuracy: 61.59%
#     Worker 1: Train Loss: 1.3025, Train Accuracy: 62.81%
#     Worker 2: Train Loss: 1.3338, Train Accuracy: 61.60%
#     Worker 3: Train Loss: 1.3460, Train Accuracy: 61.06%
# Epoch 97/150: Test Loss: 1.8943, Test Accuracy: 52.31%
#     Worker 0: Train Loss: 1.2983, Train Accuracy: 62.10%
#     Worker 1: Train Loss: 1.3211, Train Accuracy: 62.56%
#     Worker 2: Train Loss: 1.3209, Train Accuracy: 61.96%
#     Worker 3: Train Loss: 1.3468, Train Accuracy: 61.45%
# Epoch 98/150: Test Loss: 1.8963, Test Accuracy: 52.30%
#     Worker 0: Train Loss: 1.3172, Train Accuracy: 61.67%
#     Worker 1: Train Loss: 1.3169, Train Accuracy: 62.50%
#     Worker 2: Train Loss: 1.2963, Train Accuracy: 62.37%
#     Worker 3: Train Loss: 1.3063, Train Accuracy: 62.42%
# Epoch 99/150: Test Loss: 1.8903, Test Accuracy: 52.09%
#     Worker 0: Train Loss: 1.2924, Train Accuracy: 62.53%
#     Worker 1: Train Loss: 1.3324, Train Accuracy: 61.87%
#     Worker 2: Train Loss: 1.2851, Train Accuracy: 62.91%
#     Worker 3: Train Loss: 1.2999, Train Accuracy: 63.20%
# Epoch 100/150: Test Loss: 1.9029, Test Accuracy: 52.42%
#     Worker 0: Train Loss: 1.2794, Train Accuracy: 62.58%
#     Worker 1: Train Loss: 1.2939, Train Accuracy: 62.66%
#     Worker 2: Train Loss: 1.2425, Train Accuracy: 64.10%
#     Worker 3: Train Loss: 1.3098, Train Accuracy: 62.62%
# Epoch 101/150: Test Loss: 1.9017, Test Accuracy: 52.25%
#     Worker 0: Train Loss: 1.3134, Train Accuracy: 62.44%
#     Worker 1: Train Loss: 1.2937, Train Accuracy: 63.22%
#     Worker 2: Train Loss: 1.2366, Train Accuracy: 64.02%
#     Worker 3: Train Loss: 1.2993, Train Accuracy: 62.43%
# Epoch 102/150: Test Loss: 1.8931, Test Accuracy: 51.94%
#     Worker 0: Train Loss: 1.3241, Train Accuracy: 61.78%
#     Worker 1: Train Loss: 1.2841, Train Accuracy: 63.00%
#     Worker 2: Train Loss: 1.2563, Train Accuracy: 63.62%
#     Worker 3: Train Loss: 1.2923, Train Accuracy: 63.02%
# Epoch 103/150: Test Loss: 1.8956, Test Accuracy: 51.88%
#     Worker 0: Train Loss: 1.2666, Train Accuracy: 63.29%
#     Worker 1: Train Loss: 1.2448, Train Accuracy: 64.28%
#     Worker 2: Train Loss: 1.2447, Train Accuracy: 64.26%
#     Worker 3: Train Loss: 1.2642, Train Accuracy: 63.34%
# Epoch 104/150: Test Loss: 1.9020, Test Accuracy: 52.16%
#     Worker 0: Train Loss: 1.2370, Train Accuracy: 63.62%
#     Worker 1: Train Loss: 1.2793, Train Accuracy: 63.14%
#     Worker 2: Train Loss: 1.2143, Train Accuracy: 64.54%
#     Worker 3: Train Loss: 1.2536, Train Accuracy: 63.52%
# Epoch 105/150: Test Loss: 1.8957, Test Accuracy: 52.71%
#     Worker 0: Train Loss: 1.2477, Train Accuracy: 63.66%
#     Worker 1: Train Loss: 1.2284, Train Accuracy: 64.99%
#     Worker 2: Train Loss: 1.2341, Train Accuracy: 64.03%
#     Worker 3: Train Loss: 1.2427, Train Accuracy: 64.07%
# Epoch 106/150: Test Loss: 1.8947, Test Accuracy: 52.47%
#     Worker 0: Train Loss: 1.2196, Train Accuracy: 64.42%
#     Worker 1: Train Loss: 1.2263, Train Accuracy: 65.02%
#     Worker 2: Train Loss: 1.2373, Train Accuracy: 64.02%
#     Worker 3: Train Loss: 1.2488, Train Accuracy: 63.72%
# Epoch 107/150: Test Loss: 1.9181, Test Accuracy: 52.45%
#     Worker 0: Train Loss: 1.1971, Train Accuracy: 64.80%
#     Worker 1: Train Loss: 1.2114, Train Accuracy: 64.73%
#     Worker 2: Train Loss: 1.2065, Train Accuracy: 64.31%
#     Worker 3: Train Loss: 1.2198, Train Accuracy: 64.72%
# Epoch 108/150: Test Loss: 1.9262, Test Accuracy: 52.35%
#     Worker 0: Train Loss: 1.1949, Train Accuracy: 65.40%
#     Worker 1: Train Loss: 1.2142, Train Accuracy: 64.82%
#     Worker 2: Train Loss: 1.1741, Train Accuracy: 65.82%
#     Worker 3: Train Loss: 1.1821, Train Accuracy: 65.30%
# Epoch 109/150: Test Loss: 1.9203, Test Accuracy: 52.63%
#     Worker 0: Train Loss: 1.2135, Train Accuracy: 64.30%
#     Worker 1: Train Loss: 1.2226, Train Accuracy: 65.07%
#     Worker 2: Train Loss: 1.1802, Train Accuracy: 65.28%
#     Worker 3: Train Loss: 1.1975, Train Accuracy: 65.27%
# Epoch 110/150: Test Loss: 1.9345, Test Accuracy: 52.43%
#     Worker 0: Train Loss: 1.2023, Train Accuracy: 64.84%
#     Worker 1: Train Loss: 1.1888, Train Accuracy: 65.72%
#     Worker 2: Train Loss: 1.1593, Train Accuracy: 65.85%
#     Worker 3: Train Loss: 1.1597, Train Accuracy: 66.36%
# Epoch 111/150: Test Loss: 1.9197, Test Accuracy: 52.65%
#     Worker 0: Train Loss: 1.1981, Train Accuracy: 65.25%
#     Worker 1: Train Loss: 1.1589, Train Accuracy: 66.66%
#     Worker 2: Train Loss: 1.1539, Train Accuracy: 66.21%
#     Worker 3: Train Loss: 1.1667, Train Accuracy: 66.23%
# Epoch 112/150: Test Loss: 1.9341, Test Accuracy: 52.91%
#     Worker 0: Train Loss: 1.1319, Train Accuracy: 66.97%
#     Worker 1: Train Loss: 1.1690, Train Accuracy: 65.83%
#     Worker 2: Train Loss: 1.1325, Train Accuracy: 66.77%
#     Worker 3: Train Loss: 1.1444, Train Accuracy: 66.99%
# Epoch 113/150: Test Loss: 1.9280, Test Accuracy: 52.63%
#     Worker 0: Train Loss: 1.1446, Train Accuracy: 66.61%
#     Worker 1: Train Loss: 1.1553, Train Accuracy: 66.22%
#     Worker 2: Train Loss: 1.1659, Train Accuracy: 65.71%
#     Worker 3: Train Loss: 1.1235, Train Accuracy: 67.27%
# Epoch 114/150: Test Loss: 1.9253, Test Accuracy: 52.88%
#     Worker 0: Train Loss: 1.1445, Train Accuracy: 66.64%
#     Worker 1: Train Loss: 1.1346, Train Accuracy: 67.12%
#     Worker 2: Train Loss: 1.1309, Train Accuracy: 66.63%
#     Worker 3: Train Loss: 1.1359, Train Accuracy: 66.48%
# Epoch 115/150: Test Loss: 1.9475, Test Accuracy: 52.61%
#     Worker 0: Train Loss: 1.1375, Train Accuracy: 66.22%
#     Worker 1: Train Loss: 1.1535, Train Accuracy: 66.79%
#     Worker 2: Train Loss: 1.0971, Train Accuracy: 67.93%
#     Worker 3: Train Loss: 1.1403, Train Accuracy: 66.50%
# Epoch 116/150: Test Loss: 1.9446, Test Accuracy: 52.65%
#     Worker 0: Train Loss: 1.1328, Train Accuracy: 67.06%
#     Worker 1: Train Loss: 1.0911, Train Accuracy: 68.52%
#     Worker 2: Train Loss: 1.1012, Train Accuracy: 67.57%
#     Worker 3: Train Loss: 1.0988, Train Accuracy: 67.64%
# Epoch 117/150: Test Loss: 1.9454, Test Accuracy: 52.96%
#     Worker 0: Train Loss: 1.1200, Train Accuracy: 67.26%
#     Worker 1: Train Loss: 1.1306, Train Accuracy: 67.18%
#     Worker 2: Train Loss: 1.0944, Train Accuracy: 68.03%
#     Worker 3: Train Loss: 1.1224, Train Accuracy: 67.23%
# Epoch 118/150: Test Loss: 1.9565, Test Accuracy: 52.57%
#     Worker 0: Train Loss: 1.0786, Train Accuracy: 67.90%
#     Worker 1: Train Loss: 1.0980, Train Accuracy: 68.38%
#     Worker 2: Train Loss: 1.0816, Train Accuracy: 68.40%
#     Worker 3: Train Loss: 1.1190, Train Accuracy: 67.33%
# Epoch 119/150: Test Loss: 1.9483, Test Accuracy: 52.47%
#     Worker 0: Train Loss: 1.0869, Train Accuracy: 68.15%
#     Worker 1: Train Loss: 1.0911, Train Accuracy: 68.15%
#     Worker 2: Train Loss: 1.0611, Train Accuracy: 68.64%
#     Worker 3: Train Loss: 1.0830, Train Accuracy: 68.02%
# Epoch 120/150: Test Loss: 1.9542, Test Accuracy: 52.74%
#     Worker 0: Train Loss: 1.0880, Train Accuracy: 67.90%
#     Worker 1: Train Loss: 1.0584, Train Accuracy: 69.00%
#     Worker 2: Train Loss: 1.0677, Train Accuracy: 68.59%
#     Worker 3: Train Loss: 1.0678, Train Accuracy: 68.45%
# Epoch 121/150: Test Loss: 1.9619, Test Accuracy: 52.54%
#     Worker 0: Train Loss: 1.0789, Train Accuracy: 68.23%
#     Worker 1: Train Loss: 1.0588, Train Accuracy: 68.94%
#     Worker 2: Train Loss: 1.0520, Train Accuracy: 69.44%
#     Worker 3: Train Loss: 1.0656, Train Accuracy: 68.46%
# Epoch 122/150: Test Loss: 1.9638, Test Accuracy: 52.61%
#     Worker 0: Train Loss: 1.0577, Train Accuracy: 68.86%
#     Worker 1: Train Loss: 1.0704, Train Accuracy: 68.73%
#     Worker 2: Train Loss: 1.0324, Train Accuracy: 69.30%
#     Worker 3: Train Loss: 1.0387, Train Accuracy: 68.98%
# Epoch 123/150: Test Loss: 1.9696, Test Accuracy: 52.79%
#     Worker 0: Train Loss: 1.0384, Train Accuracy: 69.24%
#     Worker 1: Train Loss: 1.0437, Train Accuracy: 69.50%
#     Worker 2: Train Loss: 1.0165, Train Accuracy: 70.27%
#     Worker 3: Train Loss: 1.0241, Train Accuracy: 69.74%
# Epoch 124/150: Test Loss: 1.9819, Test Accuracy: 52.59%
#     Worker 0: Train Loss: 1.0347, Train Accuracy: 69.32%
#     Worker 1: Train Loss: 1.0361, Train Accuracy: 70.01%
#     Worker 2: Train Loss: 1.0049, Train Accuracy: 70.43%
#     Worker 3: Train Loss: 1.0092, Train Accuracy: 70.34%
# Epoch 125/150: Test Loss: 1.9878, Test Accuracy: 52.82%
#     Worker 0: Train Loss: 1.0105, Train Accuracy: 69.64%
#     Worker 1: Train Loss: 1.0033, Train Accuracy: 69.98%
#     Worker 2: Train Loss: 1.0075, Train Accuracy: 70.50%
#     Worker 3: Train Loss: 1.0178, Train Accuracy: 70.02%
# Epoch 126/150: Test Loss: 1.9784, Test Accuracy: 52.81%
#     Worker 0: Train Loss: 1.0364, Train Accuracy: 69.64%
#     Worker 1: Train Loss: 1.0232, Train Accuracy: 70.40%
#     Worker 2: Train Loss: 1.0216, Train Accuracy: 69.41%
#     Worker 3: Train Loss: 1.0093, Train Accuracy: 70.54%
# Epoch 127/150: Test Loss: 1.9882, Test Accuracy: 53.06%
#     Worker 0: Train Loss: 1.0056, Train Accuracy: 70.44%
#     Worker 1: Train Loss: 1.0102, Train Accuracy: 70.05%
#     Worker 2: Train Loss: 0.9912, Train Accuracy: 70.36%
#     Worker 3: Train Loss: 1.0236, Train Accuracy: 69.83%
# Epoch 128/150: Test Loss: 1.9820, Test Accuracy: 53.10%
#     Worker 0: Train Loss: 0.9862, Train Accuracy: 71.06%
#     Worker 1: Train Loss: 0.9849, Train Accuracy: 71.13%
#     Worker 2: Train Loss: 0.9719, Train Accuracy: 71.36%
#     Worker 3: Train Loss: 0.9873, Train Accuracy: 70.50%
# Epoch 129/150: Test Loss: 1.9917, Test Accuracy: 52.93%
#     Worker 0: Train Loss: 0.9618, Train Accuracy: 71.48%
#     Worker 1: Train Loss: 0.9728, Train Accuracy: 70.98%
#     Worker 2: Train Loss: 0.9647, Train Accuracy: 71.36%
#     Worker 3: Train Loss: 1.0007, Train Accuracy: 70.46%
# Epoch 130/150: Test Loss: 1.9927, Test Accuracy: 52.85%
#     Worker 0: Train Loss: 0.9598, Train Accuracy: 71.84%
#     Worker 1: Train Loss: 0.9708, Train Accuracy: 71.51%
#     Worker 2: Train Loss: 0.9550, Train Accuracy: 71.43%
#     Worker 3: Train Loss: 0.9628, Train Accuracy: 71.69%
# Epoch 131/150: Test Loss: 1.9946, Test Accuracy: 53.07%
#     Worker 0: Train Loss: 0.9733, Train Accuracy: 71.06%
#     Worker 1: Train Loss: 0.9701, Train Accuracy: 71.74%
#     Worker 2: Train Loss: 0.9360, Train Accuracy: 71.93%
#     Worker 3: Train Loss: 0.9560, Train Accuracy: 72.04%
# Epoch 132/150: Test Loss: 2.0039, Test Accuracy: 53.02%
#     Worker 0: Train Loss: 0.9395, Train Accuracy: 71.92%
#     Worker 1: Train Loss: 0.9419, Train Accuracy: 72.33%
#     Worker 2: Train Loss: 0.9327, Train Accuracy: 72.58%
#     Worker 3: Train Loss: 0.9428, Train Accuracy: 72.25%
# Epoch 133/150: Test Loss: 2.0034, Test Accuracy: 53.14%
#     Worker 0: Train Loss: 0.9383, Train Accuracy: 72.18%
#     Worker 1: Train Loss: 0.9363, Train Accuracy: 72.50%
#     Worker 2: Train Loss: 0.9198, Train Accuracy: 72.86%
#     Worker 3: Train Loss: 0.9513, Train Accuracy: 71.98%
# Epoch 134/150: Test Loss: 2.0085, Test Accuracy: 52.89%
#     Worker 0: Train Loss: 0.9437, Train Accuracy: 72.35%
#     Worker 1: Train Loss: 0.9260, Train Accuracy: 72.75%
#     Worker 2: Train Loss: 0.8989, Train Accuracy: 73.38%
#     Worker 3: Train Loss: 0.9145, Train Accuracy: 72.73%
# Epoch 135/150: Test Loss: 2.0159, Test Accuracy: 53.23%
#     Worker 0: Train Loss: 0.9045, Train Accuracy: 73.44%
#     Worker 1: Train Loss: 0.9239, Train Accuracy: 72.90%
#     Worker 2: Train Loss: 0.9156, Train Accuracy: 72.73%
#     Worker 3: Train Loss: 0.8991, Train Accuracy: 73.53%
# Epoch 136/150: Test Loss: 2.0225, Test Accuracy: 52.87%
#     Worker 0: Train Loss: 0.8977, Train Accuracy: 73.37%
#     Worker 1: Train Loss: 0.9054, Train Accuracy: 72.70%
#     Worker 2: Train Loss: 0.8904, Train Accuracy: 73.79%
#     Worker 3: Train Loss: 0.8911, Train Accuracy: 73.63%
# Epoch 137/150: Test Loss: 2.0304, Test Accuracy: 53.16%
#     Worker 0: Train Loss: 0.9127, Train Accuracy: 72.82%
#     Worker 1: Train Loss: 0.8996, Train Accuracy: 73.71%
#     Worker 2: Train Loss: 0.8795, Train Accuracy: 74.18%
#     Worker 3: Train Loss: 0.9018, Train Accuracy: 73.23%
# Epoch 138/150: Test Loss: 2.0292, Test Accuracy: 53.07%
#     Worker 0: Train Loss: 0.8875, Train Accuracy: 73.89%
#     Worker 1: Train Loss: 0.9012, Train Accuracy: 73.58%
#     Worker 2: Train Loss: 0.8745, Train Accuracy: 73.91%
#     Worker 3: Train Loss: 0.8813, Train Accuracy: 73.64%
# Epoch 139/150: Test Loss: 2.0314, Test Accuracy: 53.26%
#     Worker 0: Train Loss: 0.8676, Train Accuracy: 73.75%
#     Worker 1: Train Loss: 0.8902, Train Accuracy: 73.66%
#     Worker 2: Train Loss: 0.8579, Train Accuracy: 74.66%
#     Worker 3: Train Loss: 0.8816, Train Accuracy: 73.72%
# Epoch 140/150: Test Loss: 2.0308, Test Accuracy: 53.29%
#     Worker 0: Train Loss: 0.8736, Train Accuracy: 74.53%
#     Worker 1: Train Loss: 0.8820, Train Accuracy: 74.26%
#     Worker 2: Train Loss: 0.8799, Train Accuracy: 73.93%
#     Worker 3: Train Loss: 0.8807, Train Accuracy: 73.93%
# Epoch 141/150: Test Loss: 2.0373, Test Accuracy: 53.10%
#     Worker 0: Train Loss: 0.8596, Train Accuracy: 74.46%
#     Worker 1: Train Loss: 0.8552, Train Accuracy: 75.01%
#     Worker 2: Train Loss: 0.8651, Train Accuracy: 74.36%
#     Worker 3: Train Loss: 0.8772, Train Accuracy: 74.50%
# Epoch 142/150: Test Loss: 2.0369, Test Accuracy: 53.36%
#     Worker 0: Train Loss: 0.8549, Train Accuracy: 74.80%
#     Worker 1: Train Loss: 0.8659, Train Accuracy: 74.58%
#     Worker 2: Train Loss: 0.8459, Train Accuracy: 74.83%
#     Worker 3: Train Loss: 0.8616, Train Accuracy: 74.43%
# Epoch 143/150: Test Loss: 2.0395, Test Accuracy: 53.42%
#     Worker 0: Train Loss: 0.8506, Train Accuracy: 74.83%
#     Worker 1: Train Loss: 0.8571, Train Accuracy: 74.78%
#     Worker 2: Train Loss: 0.8270, Train Accuracy: 75.32%
#     Worker 3: Train Loss: 0.8499, Train Accuracy: 74.71%
# Epoch 144/150: Test Loss: 2.0440, Test Accuracy: 53.12%
#     Worker 0: Train Loss: 0.8357, Train Accuracy: 74.86%
#     Worker 1: Train Loss: 0.8531, Train Accuracy: 75.27%
#     Worker 2: Train Loss: 0.8385, Train Accuracy: 75.08%
#     Worker 3: Train Loss: 0.8545, Train Accuracy: 74.49%
# Epoch 145/150: Test Loss: 2.0486, Test Accuracy: 53.42%
#     Worker 0: Train Loss: 0.8340, Train Accuracy: 75.30%
#     Worker 1: Train Loss: 0.8374, Train Accuracy: 75.60%
#     Worker 2: Train Loss: 0.8247, Train Accuracy: 75.80%
#     Worker 3: Train Loss: 0.8281, Train Accuracy: 75.66%
# Epoch 146/150: Test Loss: 2.0472, Test Accuracy: 53.40%
#     Worker 0: Train Loss: 0.8319, Train Accuracy: 75.11%
#     Worker 1: Train Loss: 0.8428, Train Accuracy: 75.31%
#     Worker 2: Train Loss: 0.8123, Train Accuracy: 76.50%
#     Worker 3: Train Loss: 0.8122, Train Accuracy: 75.90%
# Epoch 147/150: Test Loss: 2.0507, Test Accuracy: 53.32%
#     Worker 0: Train Loss: 0.8242, Train Accuracy: 75.54%
#     Worker 1: Train Loss: 0.8225, Train Accuracy: 76.07%
#     Worker 2: Train Loss: 0.8191, Train Accuracy: 75.60%
#     Worker 3: Train Loss: 0.8321, Train Accuracy: 75.56%
# Epoch 148/150: Test Loss: 2.0536, Test Accuracy: 53.42%
#     Worker 0: Train Loss: 0.8169, Train Accuracy: 75.78%
#     Worker 1: Train Loss: 0.8162, Train Accuracy: 76.29%
#     Worker 2: Train Loss: 0.7943, Train Accuracy: 76.41%
#     Worker 3: Train Loss: 0.8376, Train Accuracy: 75.16%
# Epoch 149/150: Test Loss: 2.0557, Test Accuracy: 53.39%
#     Worker 0: Train Loss: 0.8119, Train Accuracy: 76.26%
#     Worker 1: Train Loss: 0.8138, Train Accuracy: 76.10%
#     Worker 2: Train Loss: 0.7997, Train Accuracy: 76.31%
#     Worker 3: Train Loss: 0.8082, Train Accuracy: 75.70%
# Epoch 150/150: Test Loss: 2.0553, Test Accuracy: 53.39%
#     Worker 0: Train Loss: 0.8160, Train Accuracy: 76.02%
#     Worker 1: Train Loss: 0.8270, Train Accuracy: 76.38%
#     Worker 2: Train Loss: 0.7933, Train Accuracy: 77.28%
#     Worker 3: Train Loss: 0.8184, Train Accuracy: 75.82%
