# %%
# %%writefile localSGD.py

import os
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
num_epochs = 150
base_learning_rate = 1e-2
momentum = 0.9
weight_decay = 4e-4
warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std

class LRScheduler(torch.optim.lr_scheduler._LRScheduler):
    def __init__(self, optimizer, base_lr, K, warmup_epochs, total_epochs, verbose=False):
        """
        Args:
            optimizer: SGD
            base_lr: Base learning rate for the reference batch size.
            K: Number of workers.
            warmup_epochs: Number of warmup epochs.
            total_epochs: Total number of epochs.
            verbose: Whether to print LR updates.
        """
        self.base_lr = base_lr
        self.K = K
        self.scaled_lr = base_lr * K
        self.warmup_epochs = warmup_epochs
        self.total_epochs = total_epochs
        self.verbose = verbose
        super(LRScheduler, self).__init__(optimizer)

    def get_lr(self):
        epoch = self.last_epoch
        if epoch < self.warmup_epochs:
            # Linear warmup scaling
            warmup_factor = (epoch + 1) / self.warmup_epochs
            return [warmup_factor * self.scaled_lr for _ in self.optimizer.param_groups]
        else:
            # polynomially decaying learning rate of ηt = η0×(1−t/T)
            if epoch == self.warmup_epochs:
                print(f"Warmup phase completed at epoch {epoch}. Switching to polynomial decay learning rate.")
            return [self.scaled_lr * ( 1 - ( (epoch - self.warmup_epochs) / (self.total_epochs - self.warmup_epochs))) for _ in self.optimizer.param_groups]


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]

# Batch size
batch_size = shard_size // J

# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)


# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [LRScheduler(
    optimizer = optimizer,
    base_lr = base_learning_rate,
    K = K,
    warmup_epochs = warmup_epochs,
    total_epochs = num_epochs,
    verbose = True) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}")

    # Sequentially train each worker to simulate a distributed environment
    for k in range(K):
        shard_loader = DataLoader(shards[k], batch_size=batch_size, shuffle=True)

        nets[k].train()
        correct_train, total_train, train_loss = 0, 0, 0.0
        for images, labels in shard_loader:
            images, labels = images.to(device), labels.to(device)  # Move to device
            optimizers[k].zero_grad()
            outputs = nets[k](images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizers[k].step()
            # Calculate train loss and accuracy
            train_loss += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            total_train += labels.size(0)
            correct_train += predicted.eq(labels).sum().item()
        # Store train loss and accuracy for this worker
        train_loss /= len(shard_loader.dataset)
        train_losses_per_worker[k].append(train_loss)
        train_accuracy = 100. * correct_train / total_train
        train_accuracies_per_worker[k].append(train_accuracy)

    # Perform model synchronization
    with torch.no_grad():
        global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
        for net in nets:
            for global_param, local_param in zip(global_parameters, net.parameters()):
                global_param += local_param
        for global_param in global_parameters:
            global_param /= K
        # Update each worker model with the global parameters
        for net in nets:
            for local_param, global_param in zip(net.parameters(), global_parameters):
                local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        scheduler.step()

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Overwriting localSGD.py

# %%
# %run localSGD.py --k 4 --j 4
# Out:
# Training with K=4, J=4
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.04000
# Epoch 1/150: Test Loss: 4.6061, Test Accuracy: 1.13%
#     Worker 0: Train Loss: 4.6060, Train Accuracy: 1.34%
#     Worker 1: Train Loss: 4.6062, Train Accuracy: 1.24%
#     Worker 2: Train Loss: 4.6052, Train Accuracy: 1.28%
#     Worker 3: Train Loss: 4.6063, Train Accuracy: 1.00%
# Epoch 2/150: Test Loss: 4.6055, Test Accuracy: 1.27%
#     Worker 0: Train Loss: 4.6058, Train Accuracy: 1.45%
#     Worker 1: Train Loss: 4.6059, Train Accuracy: 1.11%
#     Worker 2: Train Loss: 4.6050, Train Accuracy: 1.64%
#     Worker 3: Train Loss: 4.6060, Train Accuracy: 1.19%
# Epoch 3/150: Test Loss: 4.6045, Test Accuracy: 1.34%
#     Worker 0: Train Loss: 4.6052, Train Accuracy: 1.38%
#     Worker 1: Train Loss: 4.6052, Train Accuracy: 1.31%
#     Worker 2: Train Loss: 4.6043, Train Accuracy: 1.38%
#     Worker 3: Train Loss: 4.6053, Train Accuracy: 1.19%
# Epoch 4/150: Test Loss: 4.6031, Test Accuracy: 1.40%
#     Worker 0: Train Loss: 4.6042, Train Accuracy: 1.44%
#     Worker 1: Train Loss: 4.6041, Train Accuracy: 1.35%
#     Worker 2: Train Loss: 4.6032, Train Accuracy: 1.56%
#     Worker 3: Train Loss: 4.6041, Train Accuracy: 1.26%
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Epoch 5/150: Test Loss: 4.6011, Test Accuracy: 1.41%
#     Worker 0: Train Loss: 4.6026, Train Accuracy: 1.32%
#     Worker 1: Train Loss: 4.6025, Train Accuracy: 1.35%
#     Worker 2: Train Loss: 4.6017, Train Accuracy: 1.66%
#     Worker 3: Train Loss: 4.6027, Train Accuracy: 1.22%
# Epoch 6/150: Test Loss: 4.5986, Test Accuracy: 1.33%
#     Worker 0: Train Loss: 4.6007, Train Accuracy: 1.37%
#     Worker 1: Train Loss: 4.6005, Train Accuracy: 1.38%
#     Worker 2: Train Loss: 4.5995, Train Accuracy: 1.54%
#     Worker 3: Train Loss: 4.6007, Train Accuracy: 1.38%
# Epoch 7/150: Test Loss: 4.5952, Test Accuracy: 1.43%
#     Worker 0: Train Loss: 4.5982, Train Accuracy: 1.53%
#     Worker 0: Train Loss: 3.5822, Train Accuracy: 15.66%
#     Worker 1: Train Loss: 3.5828, Train Accuracy: 15.86%
#     Worker 2: Train Loss: 3.5105, Train Accuracy: 17.46%
#     Worker 3: Train Loss: 3.5726, Train Accuracy: 16.18%
# Epoch 44/150: Test Loss: 3.4620, Test Accuracy: 18.59%
#     Worker 0: Train Loss: 3.5555, Train Accuracy: 16.50%
#     Worker 1: Train Loss: 3.5675, Train Accuracy: 16.12%
#     Worker 2: Train Loss: 3.4831, Train Accuracy: 17.51%
#     Worker 3: Train Loss: 3.5609, Train Accuracy: 16.02%
# Epoch 45/150: Test Loss: 3.4512, Test Accuracy: 18.61%
#     Worker 0: Train Loss: 3.5233, Train Accuracy: 16.55%
#     Worker 1: Train Loss: 3.5669, Train Accuracy: 16.18%
#     Worker 2: Train Loss: 3.4797, Train Accuracy: 17.88%
#     Worker 3: Train Loss: 3.5359, Train Accuracy: 16.44%
# Epoch 46/150: Test Loss: 3.4425, Test Accuracy: 18.74%
#     Worker 0: Train Loss: 3.4950, Train Accuracy: 16.78%
#     Worker 1: Train Loss: 3.5417, Train Accuracy: 16.99%
#     Worker 2: Train Loss: 3.4605, Train Accuracy: 17.59%
#     Worker 3: Train Loss: 3.5132, Train Accuracy: 16.96%
# Epoch 47/150: Test Loss: 3.4292, Test Accuracy: 19.37%
#     Worker 0: Train Loss: 3.4906, Train Accuracy: 16.97%
#     Worker 1: Train Loss: 3.5067, Train Accuracy: 17.60%
#     Worker 2: Train Loss: 3.4527, Train Accuracy: 18.42%
#     Worker 3: Train Loss: 3.5095, Train Accuracy: 16.74%
# Epoch 48/150: Test Loss: 3.4188, Test Accuracy: 19.29%
#     Worker 0: Train Loss: 3.4722, Train Accuracy: 17.46%
#     Worker 1: Train Loss: 3.4916, Train Accuracy: 17.43%
#     Worker 2: Train Loss: 3.4520, Train Accuracy: 18.02%
#     Worker 3: Train Loss: 3.4954, Train Accuracy: 16.87%
# Epoch 49/150: Test Loss: 3.3913, Test Accuracy: 19.79%
#     Worker 0: Train Loss: 3.4740, Train Accuracy: 17.48%
#     Worker 1: Train Loss: 3.5052, Train Accuracy: 16.93%
#     Worker 2: Train Loss: 3.4637, Train Accuracy: 17.74%
#     Worker 3: Train Loss: 3.4631, Train Accuracy: 17.57%
# Epoch 50/150: Test Loss: 3.3820, Test Accuracy: 20.05%
#     Worker 0: Train Loss: 3.4570, Train Accuracy: 17.28%
#     Worker 1: Train Loss: 3.4714, Train Accuracy: 17.53%
#     Worker 2: Train Loss: 3.4604, Train Accuracy: 17.80%
#     Worker 3: Train Loss: 3.4603, Train Accuracy: 17.82%
# Epoch 51/150: Test Loss: 3.3660, Test Accuracy: 20.42%
#     Worker 0: Train Loss: 3.4614, Train Accuracy: 17.62%
#     Worker 1: Train Loss: 3.4584, Train Accuracy: 17.74%
#     Worker 2: Train Loss: 3.4377, Train Accuracy: 18.66%
#     Worker 3: Train Loss: 3.4502, Train Accuracy: 17.94%
# Epoch 52/150: Test Loss: 3.3547, Test Accuracy: 20.70%
#     Worker 0: Train Loss: 3.1060, Train Accuracy: 24.14%
#     Worker 1: Train Loss: 3.1525, Train Accuracy: 23.50%
#     Worker 2: Train Loss: 3.1174, Train Accuracy: 24.11%
#     Worker 3: Train Loss: 3.1384, Train Accuracy: 23.37%
# Epoch 80/150: Test Loss: 3.0355, Test Accuracy: 26.39%
#     Worker 0: Train Loss: 3.1161, Train Accuracy: 23.83%
#     Worker 1: Train Loss: 3.1183, Train Accuracy: 24.35%
#     Worker 2: Train Loss: 3.0662, Train Accuracy: 25.03%
#     Worker 3: Train Loss: 3.1159, Train Accuracy: 23.76%
# Epoch 81/150: Test Loss: 3.0218, Test Accuracy: 26.74%
#     Worker 0: Train Loss: 3.1004, Train Accuracy: 23.96%
#     Worker 1: Train Loss: 3.1163, Train Accuracy: 24.39%
#     Worker 2: Train Loss: 3.0667, Train Accuracy: 25.02%
#     Worker 3: Train Loss: 3.1139, Train Accuracy: 23.79%
# Epoch 82/150: Test Loss: 3.0229, Test Accuracy: 26.47%
#     Worker 0: Train Loss: 3.0963, Train Accuracy: 24.53%
#     Worker 1: Train Loss: 3.1080, Train Accuracy: 24.68%
#     Worker 2: Train Loss: 3.0410, Train Accuracy: 25.62%
#     Worker 3: Train Loss: 3.1246, Train Accuracy: 24.18%
# Epoch 83/150: Test Loss: 3.0309, Test Accuracy: 26.44%
#     Worker 0: Train Loss: 3.0705, Train Accuracy: 24.77%
#     Worker 1: Train Loss: 3.0950, Train Accuracy: 24.64%
#     Worker 2: Train Loss: 3.0392, Train Accuracy: 25.32%
#     Worker 3: Train Loss: 3.1503, Train Accuracy: 23.50%
# Epoch 84/150: Test Loss: 3.0289, Test Accuracy: 26.54%
#     Worker 0: Train Loss: 3.0387, Train Accuracy: 25.94%
#     Worker 1: Train Loss: 3.0757, Train Accuracy: 25.01%
#     Worker 2: Train Loss: 3.0342, Train Accuracy: 25.99%
#     Worker 3: Train Loss: 3.1646, Train Accuracy: 22.82%
# Epoch 85/150: Test Loss: 3.0345, Test Accuracy: 26.40%
#     Worker 0: Train Loss: 3.0453, Train Accuracy: 25.38%
#     Worker 1: Train Loss: 3.0763, Train Accuracy: 24.92%
#     Worker 2: Train Loss: 3.0208, Train Accuracy: 25.96%
#     Worker 3: Train Loss: 3.1308, Train Accuracy: 23.34%
# Epoch 86/150: Test Loss: 3.0188, Test Accuracy: 26.61%
#     Worker 0: Train Loss: 3.0388, Train Accuracy: 24.90%
#     Worker 1: Train Loss: 3.0574, Train Accuracy: 25.43%
#     Worker 2: Train Loss: 3.0243, Train Accuracy: 26.11%
#     Worker 3: Train Loss: 3.0955, Train Accuracy: 24.49%
# Epoch 87/150: Test Loss: 3.0018, Test Accuracy: 27.05%
#     Worker 0: Train Loss: 3.0306, Train Accuracy: 25.39%
#     Worker 1: Train Loss: 3.0658, Train Accuracy: 25.50%
#     Worker 2: Train Loss: 3.0113, Train Accuracy: 26.46%
#     Worker 3: Train Loss: 3.0612, Train Accuracy: 25.05%
# Epoch 88/150: Test Loss: 2.9867, Test Accuracy: 27.37%
#     Worker 0: Train Loss: 3.0220, Train Accuracy: 25.90%
#     Worker 1: Train Loss: 3.0557, Train Accuracy: 25.41%
#     Worker 2: Train Loss: 3.0107, Train Accuracy: 26.41%
#     Worker 3: Train Loss: 3.0505, Train Accuracy: 24.89%
# Epoch 89/150: Test Loss: 2.9614, Test Accuracy: 28.05%
#     Worker 0: Train Loss: 3.0201, Train Accuracy: 25.42%
#     Worker 1: Train Loss: 3.0400, Train Accuracy: 26.25%
#     Worker 2: Train Loss: 3.0011, Train Accuracy: 26.34%
#     Worker 3: Train Loss: 3.0544, Train Accuracy: 25.49%
# Epoch 90/150: Test Loss: 2.9707, Test Accuracy: 27.80%
#     Worker 0: Train Loss: 3.0270, Train Accuracy: 25.91%
#     Worker 1: Train Loss: 3.0357, Train Accuracy: 26.14%
#     Worker 2: Train Loss: 2.9933, Train Accuracy: 26.94%
#     Worker 3: Train Loss: 3.0318, Train Accuracy: 25.25%
# Epoch 91/150: Test Loss: 2.9639, Test Accuracy: 27.70%
#     Worker 0: Train Loss: 3.0228, Train Accuracy: 26.02%
#     Worker 1: Train Loss: 3.0316, Train Accuracy: 25.73%
#     Worker 2: Train Loss: 2.9926, Train Accuracy: 26.74%
#     Worker 3: Train Loss: 3.0406, Train Accuracy: 25.70%
# Epoch 92/150: Test Loss: 2.9471, Test Accuracy: 28.24%
#     Worker 0: Train Loss: 2.9947, Train Accuracy: 26.34%
#     Worker 1: Train Loss: 3.0272, Train Accuracy: 25.96%
#     Worker 2: Train Loss: 3.0117, Train Accuracy: 26.37%
#     Worker 3: Train Loss: 3.0435, Train Accuracy: 25.38%
# Epoch 93/150: Test Loss: 2.9401, Test Accuracy: 28.38%
#     Worker 0: Train Loss: 2.9861, Train Accuracy: 26.08%
#     Worker 1: Train Loss: 3.0242, Train Accuracy: 25.82%
#     Worker 2: Train Loss: 2.9827, Train Accuracy: 26.72%
#     Worker 3: Train Loss: 3.0339, Train Accuracy: 25.39%
# Epoch 94/150: Test Loss: 2.9483, Test Accuracy: 28.04%
#     Worker 0: Train Loss: 2.9904, Train Accuracy: 26.20%
#     Worker 1: Train Loss: 3.0136, Train Accuracy: 26.15%
#     Worker 2: Train Loss: 3.0002, Train Accuracy: 26.17%
#     Worker 3: Train Loss: 3.0279, Train Accuracy: 25.89%
# Epoch 95/150: Test Loss: 2.9348, Test Accuracy: 28.43%
#     Worker 0: Train Loss: 2.9896, Train Accuracy: 26.57%
#     Worker 1: Train Loss: 3.0096, Train Accuracy: 26.55%
#     Worker 2: Train Loss: 2.9882, Train Accuracy: 26.82%
#     Worker 3: Train Loss: 3.0168, Train Accuracy: 26.20%
# Epoch 96/150: Test Loss: 2.9256, Test Accuracy: 28.52%
#     Worker 0: Train Loss: 2.9704, Train Accuracy: 26.67%
#     Worker 1: Train Loss: 3.0065, Train Accuracy: 26.45%
#     Worker 2: Train Loss: 2.9551, Train Accuracy: 27.48%
#     Worker 3: Train Loss: 2.9832, Train Accuracy: 26.53%
# Epoch 97/150: Test Loss: 2.9221, Test Accuracy: 28.63%
#     Worker 0: Train Loss: 2.9618, Train Accuracy: 26.97%
#     Worker 1: Train Loss: 3.0058, Train Accuracy: 26.14%
#     Worker 2: Train Loss: 2.9371, Train Accuracy: 27.35%
#     Worker 3: Train Loss: 2.9714, Train Accuracy: 27.06%
# Epoch 98/150: Test Loss: 2.9250, Test Accuracy: 28.35%
#     Worker 0: Train Loss: 2.9467, Train Accuracy: 27.74%
#     Worker 1: Train Loss: 3.0104, Train Accuracy: 26.06%
#     Worker 2: Train Loss: 2.9361, Train Accuracy: 27.85%
#     Worker 3: Train Loss: 2.9691, Train Accuracy: 26.86%
# Epoch 99/150: Test Loss: 2.9088, Test Accuracy: 28.87%
#     Worker 0: Train Loss: 2.9437, Train Accuracy: 27.34%
#     Worker 1: Train Loss: 2.9861, Train Accuracy: 26.59%
#     Worker 2: Train Loss: 2.9321, Train Accuracy: 28.01%
#     Worker 3: Train Loss: 2.9648, Train Accuracy: 26.98%
# Epoch 100/150: Test Loss: 2.9134, Test Accuracy: 28.47%
#     Worker 0: Train Loss: 2.9354, Train Accuracy: 27.20%
#     Worker 1: Train Loss: 3.0197, Train Accuracy: 26.30%
#     Worker 2: Train Loss: 2.9114, Train Accuracy: 28.25%
#     Worker 3: Train Loss: 2.9519, Train Accuracy: 26.90%
# Epoch 101/150: Test Loss: 2.9006, Test Accuracy: 29.15%
#     Worker 0: Train Loss: 2.9361, Train Accuracy: 27.27%
#     Worker 1: Train Loss: 2.9899, Train Accuracy: 26.65%
#     Worker 2: Train Loss: 2.9100, Train Accuracy: 28.22%
#     Worker 3: Train Loss: 2.9524, Train Accuracy: 27.24%
# Epoch 102/150: Test Loss: 2.8907, Test Accuracy: 29.22%
#     Worker 0: Train Loss: 2.9177, Train Accuracy: 27.45%
#     Worker 1: Train Loss: 2.9697, Train Accuracy: 26.89%
#     Worker 2: Train Loss: 2.9063, Train Accuracy: 28.70%
#     Worker 3: Train Loss: 2.9510, Train Accuracy: 27.42%
# Epoch 103/150: Test Loss: 2.8858, Test Accuracy: 29.12%
#     Worker 0: Train Loss: 2.9140, Train Accuracy: 27.86%
#     Worker 1: Train Loss: 2.9786, Train Accuracy: 27.25%
#     Worker 2: Train Loss: 2.8966, Train Accuracy: 28.53%
#     Worker 3: Train Loss: 2.9474, Train Accuracy: 27.37%
# Epoch 104/150: Test Loss: 2.8773, Test Accuracy: 29.24%
#     Worker 0: Train Loss: 2.9210, Train Accuracy: 27.66%
#     Worker 1: Train Loss: 2.9570, Train Accuracy: 27.90%
#     Worker 2: Train Loss: 2.8906, Train Accuracy: 28.39%
#     Worker 3: Train Loss: 2.9363, Train Accuracy: 27.58%
# Epoch 105/150: Test Loss: 2.8659, Test Accuracy: 29.57%
#     Worker 0: Train Loss: 2.9004, Train Accuracy: 28.52%
#     Worker 1: Train Loss: 2.9374, Train Accuracy: 27.74%
#     Worker 2: Train Loss: 2.8860, Train Accuracy: 28.58%
#     Worker 3: Train Loss: 2.9553, Train Accuracy: 27.05%
# Epoch 106/150: Test Loss: 2.8603, Test Accuracy: 29.67%
#     Worker 0: Train Loss: 2.9161, Train Accuracy: 27.92%
#     Worker 1: Train Loss: 2.9395, Train Accuracy: 27.91%
#     Worker 2: Train Loss: 2.8790, Train Accuracy: 28.76%
#     Worker 3: Train Loss: 2.9411, Train Accuracy: 27.67%
# Epoch 107/150: Test Loss: 2.8549, Test Accuracy: 29.75%
#     Worker 0: Train Loss: 2.9114, Train Accuracy: 27.97%
#     Worker 1: Train Loss: 2.9334, Train Accuracy: 27.67%
#     Worker 2: Train Loss: 2.8729, Train Accuracy: 28.98%
#     Worker 3: Train Loss: 2.9454, Train Accuracy: 27.27%
# Epoch 108/150: Test Loss: 2.8463, Test Accuracy: 30.15%
#     Worker 0: Train Loss: 2.9025, Train Accuracy: 28.40%
#     Worker 1: Train Loss: 2.9224, Train Accuracy: 28.28%
#     Worker 2: Train Loss: 2.8755, Train Accuracy: 29.02%
#     Worker 3: Train Loss: 2.9183, Train Accuracy: 27.64%
# Epoch 109/150: Test Loss: 2.8465, Test Accuracy: 29.92%
#     Worker 0: Train Loss: 2.8952, Train Accuracy: 28.33%
#     Worker 1: Train Loss: 2.9085, Train Accuracy: 28.22%
#     Worker 2: Train Loss: 2.8551, Train Accuracy: 29.50%
#     Worker 3: Train Loss: 2.9049, Train Accuracy: 28.22%
# Epoch 110/150: Test Loss: 2.8471, Test Accuracy: 29.76%
#     Worker 0: Train Loss: 2.9068, Train Accuracy: 27.86%
#     Worker 1: Train Loss: 2.9019, Train Accuracy: 28.38%
#     Worker 2: Train Loss: 2.8588, Train Accuracy: 29.66%
#     Worker 3: Train Loss: 2.8850, Train Accuracy: 28.58%
# Epoch 111/150: Test Loss: 2.8445, Test Accuracy: 30.07%
#     Worker 0: Train Loss: 2.8946, Train Accuracy: 28.12%
#     Worker 1: Train Loss: 2.9006, Train Accuracy: 28.73%
#     Worker 2: Train Loss: 2.8563, Train Accuracy: 29.45%
#     Worker 3: Train Loss: 2.8976, Train Accuracy: 28.38%
# Epoch 112/150: Test Loss: 2.8291, Test Accuracy: 30.29%
#     Worker 0: Train Loss: 2.8732, Train Accuracy: 28.65%
#     Worker 1: Train Loss: 2.9120, Train Accuracy: 28.35%
#     Worker 2: Train Loss: 2.8451, Train Accuracy: 29.83%
#     Worker 3: Train Loss: 2.8953, Train Accuracy: 28.32%
# Epoch 113/150: Test Loss: 2.8409, Test Accuracy: 29.90%
#     Worker 0: Train Loss: 2.8632, Train Accuracy: 29.19%
#     Worker 1: Train Loss: 2.9094, Train Accuracy: 28.42%
#     Worker 2: Train Loss: 2.8435, Train Accuracy: 29.56%
#     Worker 3: Train Loss: 2.9015, Train Accuracy: 28.27%
# Epoch 114/150: Test Loss: 2.8296, Test Accuracy: 30.34%
#     Worker 0: Train Loss: 2.8582, Train Accuracy: 29.09%
#     Worker 1: Train Loss: 2.8989, Train Accuracy: 28.65%
#     Worker 2: Train Loss: 2.8306, Train Accuracy: 29.52%
#     Worker 3: Train Loss: 2.8801, Train Accuracy: 28.83%
# Epoch 115/150: Test Loss: 2.8253, Test Accuracy: 30.37%
#     Worker 0: Train Loss: 2.8673, Train Accuracy: 28.64%
#     Worker 1: Train Loss: 2.8981, Train Accuracy: 28.97%
#     Worker 2: Train Loss: 2.8291, Train Accuracy: 30.13%
#     Worker 3: Train Loss: 2.8752, Train Accuracy: 29.09%
# Epoch 116/150: Test Loss: 2.8240, Test Accuracy: 30.26%
#     Worker 0: Train Loss: 2.8570, Train Accuracy: 29.03%
#     Worker 1: Train Loss: 2.8905, Train Accuracy: 28.97%
#     Worker 2: Train Loss: 2.8294, Train Accuracy: 30.02%
#     Worker 3: Train Loss: 2.8774, Train Accuracy: 28.81%
# Epoch 117/150: Test Loss: 2.8200, Test Accuracy: 30.59%
#     Worker 0: Train Loss: 2.8426, Train Accuracy: 29.42%
#     Worker 1: Train Loss: 2.8732, Train Accuracy: 29.02%
#     Worker 2: Train Loss: 2.8270, Train Accuracy: 29.65%
#     Worker 3: Train Loss: 2.8604, Train Accuracy: 29.16%
# Epoch 118/150: Test Loss: 2.8119, Test Accuracy: 30.74%
#     Worker 0: Train Loss: 2.8449, Train Accuracy: 29.06%
#     Worker 1: Train Loss: 2.8644, Train Accuracy: 29.47%
#     Worker 2: Train Loss: 2.8248, Train Accuracy: 30.08%
#     Worker 3: Train Loss: 2.8696, Train Accuracy: 28.74%
# Epoch 119/150: Test Loss: 2.8119, Test Accuracy: 31.10%
#     Worker 0: Train Loss: 2.8340, Train Accuracy: 29.46%
#     Worker 1: Train Loss: 2.8632, Train Accuracy: 29.28%
#     Worker 2: Train Loss: 2.8166, Train Accuracy: 29.86%
#     Worker 3: Train Loss: 2.8581, Train Accuracy: 29.16%
# Epoch 120/150: Test Loss: 2.8092, Test Accuracy: 30.56%
#     Worker 0: Train Loss: 2.8311, Train Accuracy: 29.46%
#     Worker 1: Train Loss: 2.8606, Train Accuracy: 29.42%
#     Worker 2: Train Loss: 2.8130, Train Accuracy: 30.14%
#     Worker 3: Train Loss: 2.8658, Train Accuracy: 28.81%
# Epoch 121/150: Test Loss: 2.8025, Test Accuracy: 30.88%
#     Worker 0: Train Loss: 2.8312, Train Accuracy: 29.47%
#     Worker 1: Train Loss: 2.8530, Train Accuracy: 30.10%
#     Worker 2: Train Loss: 2.8098, Train Accuracy: 30.50%
#     Worker 3: Train Loss: 2.8573, Train Accuracy: 29.03%
# Epoch 122/150: Test Loss: 2.7962, Test Accuracy: 30.89%
#     Worker 0: Train Loss: 2.8305, Train Accuracy: 29.86%
#     Worker 1: Train Loss: 2.8439, Train Accuracy: 29.67%
#     Worker 2: Train Loss: 2.8019, Train Accuracy: 29.78%
#     Worker 3: Train Loss: 2.8417, Train Accuracy: 29.36%
# Epoch 123/150: Test Loss: 2.8039, Test Accuracy: 30.66%
#     Worker 0: Train Loss: 2.8217, Train Accuracy: 29.75%
#     Worker 1: Train Loss: 2.8437, Train Accuracy: 29.60%
#     Worker 2: Train Loss: 2.8121, Train Accuracy: 30.62%
#     Worker 3: Train Loss: 2.8463, Train Accuracy: 29.35%
# Epoch 124/150: Test Loss: 2.7931, Test Accuracy: 30.88%
#     Worker 0: Train Loss: 2.8163, Train Accuracy: 29.81%
#     Worker 1: Train Loss: 2.8625, Train Accuracy: 28.95%
#     Worker 2: Train Loss: 2.8010, Train Accuracy: 30.40%
#     Worker 3: Train Loss: 2.8342, Train Accuracy: 29.14%
# Epoch 125/150: Test Loss: 2.7933, Test Accuracy: 30.93%
#     Worker 0: Train Loss: 2.8116, Train Accuracy: 29.88%
#     Worker 1: Train Loss: 2.8467, Train Accuracy: 29.65%
#     Worker 2: Train Loss: 2.8000, Train Accuracy: 30.52%
#     Worker 3: Train Loss: 2.8360, Train Accuracy: 29.26%
# Epoch 126/150: Test Loss: 2.7897, Test Accuracy: 31.13%
#     Worker 0: Train Loss: 2.8135, Train Accuracy: 29.34%
#     Worker 1: Train Loss: 2.8390, Train Accuracy: 29.57%
#     Worker 2: Train Loss: 2.8075, Train Accuracy: 30.14%
#     Worker 3: Train Loss: 2.8355, Train Accuracy: 29.73%
# Epoch 127/150: Test Loss: 2.7885, Test Accuracy: 30.87%
#     Worker 0: Train Loss: 2.8079, Train Accuracy: 29.84%
#     Worker 1: Train Loss: 2.8424, Train Accuracy: 29.63%
#     Worker 2: Train Loss: 2.7872, Train Accuracy: 31.09%
#     Worker 3: Train Loss: 2.8234, Train Accuracy: 29.77%
# Epoch 128/150: Test Loss: 2.7788, Test Accuracy: 31.32%
#     Worker 0: Train Loss: 2.8087, Train Accuracy: 30.14%
#     Worker 1: Train Loss: 2.8326, Train Accuracy: 29.79%
#     Worker 2: Train Loss: 2.7912, Train Accuracy: 30.49%
#     Worker 3: Train Loss: 2.8367, Train Accuracy: 29.60%
# Epoch 129/150: Test Loss: 2.7764, Test Accuracy: 31.40%
#     Worker 0: Train Loss: 2.8164, Train Accuracy: 29.98%
#     Worker 1: Train Loss: 2.8339, Train Accuracy: 29.94%
#     Worker 2: Train Loss: 2.7840, Train Accuracy: 30.90%
#     Worker 3: Train Loss: 2.8200, Train Accuracy: 29.94%
# Epoch 130/150: Test Loss: 2.7740, Test Accuracy: 31.38%
#     Worker 0: Train Loss: 2.8010, Train Accuracy: 30.22%
#     Worker 1: Train Loss: 2.8352, Train Accuracy: 30.02%
#     Worker 2: Train Loss: 2.7844, Train Accuracy: 30.93%
#     Worker 3: Train Loss: 2.8251, Train Accuracy: 30.02%
# Epoch 131/150: Test Loss: 2.7753, Test Accuracy: 31.37%
#     Worker 0: Train Loss: 2.7942, Train Accuracy: 30.30%
#     Worker 1: Train Loss: 2.8269, Train Accuracy: 29.97%
#     Worker 2: Train Loss: 2.7840, Train Accuracy: 30.62%
#     Worker 3: Train Loss: 2.8143, Train Accuracy: 30.17%
# Epoch 132/150: Test Loss: 2.7738, Test Accuracy: 31.24%
#     Worker 0: Train Loss: 2.7900, Train Accuracy: 30.43%
#     Worker 1: Train Loss: 2.8308, Train Accuracy: 30.06%
#     Worker 2: Train Loss: 2.7774, Train Accuracy: 30.74%
#     Worker 3: Train Loss: 2.8169, Train Accuracy: 29.50%
# Epoch 133/150: Test Loss: 2.7721, Test Accuracy: 31.46%
#     Worker 0: Train Loss: 2.7814, Train Accuracy: 30.54%
#     Worker 1: Train Loss: 2.8143, Train Accuracy: 30.24%
#     Worker 2: Train Loss: 2.7769, Train Accuracy: 30.90%
#     Worker 3: Train Loss: 2.8132, Train Accuracy: 30.32%
# Epoch 134/150: Test Loss: 2.7640, Test Accuracy: 31.41%
#     Worker 0: Train Loss: 2.7826, Train Accuracy: 30.50%
#     Worker 1: Train Loss: 2.8164, Train Accuracy: 30.54%
#     Worker 2: Train Loss: 2.7752, Train Accuracy: 31.10%
#     Worker 3: Train Loss: 2.8152, Train Accuracy: 30.72%
# Epoch 135/150: Test Loss: 2.7710, Test Accuracy: 31.42%
#     Worker 0: Train Loss: 2.7799, Train Accuracy: 30.64%
#     Worker 1: Train Loss: 2.8254, Train Accuracy: 30.22%
#     Worker 2: Train Loss: 2.7819, Train Accuracy: 31.17%
#     Worker 3: Train Loss: 2.8152, Train Accuracy: 29.96%
# Epoch 136/150: Test Loss: 2.7655, Test Accuracy: 31.64%
#     Worker 0: Train Loss: 2.7906, Train Accuracy: 30.13%
#     Worker 1: Train Loss: 2.7972, Train Accuracy: 30.73%
#     Worker 2: Train Loss: 2.7678, Train Accuracy: 31.58%
#     Worker 3: Train Loss: 2.7999, Train Accuracy: 30.42%
# Epoch 137/150: Test Loss: 2.7591, Test Accuracy: 31.69%
#     Worker 0: Train Loss: 2.7809, Train Accuracy: 31.05%
#     Worker 1: Train Loss: 2.8113, Train Accuracy: 30.65%
#     Worker 2: Train Loss: 2.7730, Train Accuracy: 31.34%
#     Worker 3: Train Loss: 2.8130, Train Accuracy: 30.24%
# Epoch 138/150: Test Loss: 2.7674, Test Accuracy: 31.50%
#     Worker 0: Train Loss: 2.7745, Train Accuracy: 30.74%
#     Worker 1: Train Loss: 2.8183, Train Accuracy: 30.04%
#     Worker 2: Train Loss: 2.7662, Train Accuracy: 31.67%
#     Worker 3: Train Loss: 2.8040, Train Accuracy: 30.24%
# Epoch 139/150: Test Loss: 2.7570, Test Accuracy: 31.87%
#     Worker 0: Train Loss: 2.7755, Train Accuracy: 30.46%
#     Worker 1: Train Loss: 2.8119, Train Accuracy: 30.32%
#     Worker 2: Train Loss: 2.7644, Train Accuracy: 31.85%
#     Worker 3: Train Loss: 2.7984, Train Accuracy: 30.22%
# Epoch 140/150: Test Loss: 2.7629, Test Accuracy: 31.64%
#     Worker 0: Train Loss: 2.7698, Train Accuracy: 30.89%
#     Worker 1: Train Loss: 2.8085, Train Accuracy: 30.28%
#     Worker 2: Train Loss: 2.7554, Train Accuracy: 31.85%
#     Worker 3: Train Loss: 2.8036, Train Accuracy: 30.10%
# Epoch 141/150: Test Loss: 2.7556, Test Accuracy: 31.84%
#     Worker 0: Train Loss: 2.7714, Train Accuracy: 30.98%
#     Worker 1: Train Loss: 2.8035, Train Accuracy: 30.60%
#     Worker 2: Train Loss: 2.7567, Train Accuracy: 31.40%
#     Worker 3: Train Loss: 2.8019, Train Accuracy: 30.30%
# Epoch 142/150: Test Loss: 2.7578, Test Accuracy: 31.78%
#     Worker 0: Train Loss: 2.7775, Train Accuracy: 30.50%
#     Worker 1: Train Loss: 2.7990, Train Accuracy: 30.54%
#     Worker 2: Train Loss: 2.7641, Train Accuracy: 31.51%
#     Worker 3: Train Loss: 2.7931, Train Accuracy: 30.47%
# Epoch 143/150: Test Loss: 2.7571, Test Accuracy: 31.81%
#     Worker 0: Train Loss: 2.7641, Train Accuracy: 31.20%
#     Worker 1: Train Loss: 2.8069, Train Accuracy: 30.34%
#     Worker 2: Train Loss: 2.7570, Train Accuracy: 31.34%
#     Worker 3: Train Loss: 2.8031, Train Accuracy: 29.80%
# Epoch 144/150: Test Loss: 2.7550, Test Accuracy: 31.85%
#     Worker 0: Train Loss: 2.7625, Train Accuracy: 31.12%
#     Worker 1: Train Loss: 2.8030, Train Accuracy: 30.38%
#     Worker 2: Train Loss: 2.7562, Train Accuracy: 31.75%
#     Worker 3: Train Loss: 2.7999, Train Accuracy: 30.43%
# Epoch 145/150: Test Loss: 2.7531, Test Accuracy: 31.85%
#     Worker 0: Train Loss: 2.7725, Train Accuracy: 30.68%
#     Worker 1: Train Loss: 2.7967, Train Accuracy: 30.53%
#     Worker 2: Train Loss: 2.7445, Train Accuracy: 31.65%
#     Worker 3: Train Loss: 2.7961, Train Accuracy: 30.77%
# Epoch 146/150: Test Loss: 2.7535, Test Accuracy: 31.92%
#     Worker 0: Train Loss: 2.7692, Train Accuracy: 30.82%
#     Worker 1: Train Loss: 2.8031, Train Accuracy: 30.35%
#     Worker 2: Train Loss: 2.7527, Train Accuracy: 31.65%
#     Worker 3: Train Loss: 2.8031, Train Accuracy: 30.50%
# Epoch 147/150: Test Loss: 2.7530, Test Accuracy: 31.84%
#     Worker 0: Train Loss: 2.7687, Train Accuracy: 31.24%
#     Worker 1: Train Loss: 2.7938, Train Accuracy: 30.99%
#     Worker 2: Train Loss: 2.7587, Train Accuracy: 31.38%
#     Worker 3: Train Loss: 2.7919, Train Accuracy: 30.45%
# Epoch 148/150: Test Loss: 2.7532, Test Accuracy: 31.72%
#     Worker 0: Train Loss: 2.7627, Train Accuracy: 30.88%
#     Worker 1: Train Loss: 2.7979, Train Accuracy: 30.37%
#     Worker 2: Train Loss: 2.7528, Train Accuracy: 31.82%
#     Worker 3: Train Loss: 2.7955, Train Accuracy: 30.70%
# Epoch 149/150: Test Loss: 2.7531, Test Accuracy: 31.71%
#     Worker 0: Train Loss: 2.7635, Train Accuracy: 30.80%
#     Worker 1: Train Loss: 2.8009, Train Accuracy: 30.36%
#     Worker 2: Train Loss: 2.7583, Train Accuracy: 31.70%
#     Worker 3: Train Loss: 2.7874, Train Accuracy: 30.56%
# Epoch 150/150: Test Loss: 2.7526, Test Accuracy: 31.81%
#     Worker 0: Train Loss: 2.7687, Train Accuracy: 30.51%
#     Worker 1: Train Loss: 2.8088, Train Accuracy: 30.92%
#     Worker 2: Train Loss: 2.7491, Train Accuracy: 31.45%
#     Worker 3: Train Loss: 2.7950, Train Accuracy: 30.47%
