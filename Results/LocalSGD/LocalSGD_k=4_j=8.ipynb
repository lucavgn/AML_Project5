# %%
# %%writefile localSGD.py

import os
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
num_epochs = 150
base_learning_rate = 1e-2
momentum = 0.9
weight_decay = 4e-4
warmup_epochs = 5

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std

class LRScheduler(torch.optim.lr_scheduler._LRScheduler):
    def __init__(self, optimizer, base_lr, K, warmup_epochs, total_epochs, verbose=False):
        """
        Args:
            optimizer: SGD
            base_lr: Base learning rate for the reference batch size.
            K: Number of workers.
            warmup_epochs: Number of warmup epochs.
            total_epochs: Total number of epochs.
            verbose: Whether to print LR updates.
        """
        self.base_lr = base_lr
        self.K = K
        self.scaled_lr = base_lr * K
        self.warmup_epochs = warmup_epochs
        self.total_epochs = total_epochs
        self.verbose = verbose
        super(LRScheduler, self).__init__(optimizer)

    def get_lr(self):
        epoch = self.last_epoch
        if epoch < self.warmup_epochs:
            # Linear warmup scaling
            warmup_factor = (epoch + 1) / self.warmup_epochs
            return [warmup_factor * self.scaled_lr for _ in self.optimizer.param_groups]
        else:
            # polynomially decaying learning rate of ηt = η0×(1−t/T)
            if epoch == self.warmup_epochs:
                print(f"Warmup phase completed at epoch {epoch}. Switching to polynomial decay learning rate.")
            return [self.scaled_lr * ( 1 - ( (epoch - self.warmup_epochs) / (self.total_epochs - self.warmup_epochs))) for _ in self.optimizer.param_groups]


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]

# Batch size
batch_size = shard_size // J

# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)


# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [LRScheduler(
    optimizer = optimizer,
    base_lr = base_learning_rate,
    K = K,
    warmup_epochs = warmup_epochs,
    total_epochs = num_epochs,
    verbose = True) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}")

    # Sequentially train each worker to simulate a distributed environment
    for k in range(K):
        shard_loader = DataLoader(shards[k], batch_size=batch_size, shuffle=True)

        nets[k].train()
        correct_train, total_train, train_loss = 0, 0, 0.0
        for images, labels in shard_loader:
            images, labels = images.to(device), labels.to(device)  # Move to device
            optimizers[k].zero_grad()
            outputs = nets[k](images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizers[k].step()
            # Calculate train loss and accuracy
            train_loss += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            total_train += labels.size(0)
            correct_train += predicted.eq(labels).sum().item()
        # Store train loss and accuracy for this worker
        train_loss /= len(shard_loader.dataset)
        train_losses_per_worker[k].append(train_loss)
        train_accuracy = 100. * correct_train / total_train
        train_accuracies_per_worker[k].append(train_accuracy)

    # Perform model synchronization
    with torch.no_grad():
        global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]  # Start with the first worker
        for net in nets:
            for global_param, local_param in zip(global_parameters, net.parameters()):
                global_param += local_param
        for global_param in global_parameters:
            global_param /= K
        # Update each worker model with the global parameters
        for net in nets:
            for local_param, global_param in zip(net.parameters(), global_parameters):
                local_param.data.copy_(global_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        scheduler.step()

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Overwriting localSGD.py

# %%
# %run localSGD.py --k 4 --j 8
# Out:
# Training with K=4, J=8
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.04000
# Epoch 1/150: Test Loss: 4.6057, Test Accuracy: 1.19%
#     Worker 0: Train Loss: 4.6060, Train Accuracy: 1.34%
#     Worker 1: Train Loss: 4.6061, Train Accuracy: 1.23%
#     Worker 2: Train Loss: 4.6051, Train Accuracy: 1.28%
#     Worker 3: Train Loss: 4.6062, Train Accuracy: 1.03%
# Epoch 2/150: Test Loss: 4.6044, Test Accuracy: 1.57%
#     Worker 0: Train Loss: 4.6050, Train Accuracy: 1.32%
#     Worker 1: Train Loss: 4.6056, Train Accuracy: 1.46%
#     Worker 2: Train Loss: 4.6043, Train Accuracy: 1.26%
#     Worker 3: Train Loss: 4.6056, Train Accuracy: 1.05%
# Epoch 3/150: Test Loss: 4.6021, Test Accuracy: 1.75%
#     Worker 0: Train Loss: 4.6039, Train Accuracy: 1.05%
#     Worker 1: Train Loss: 4.6040, Train Accuracy: 1.54%
#     Worker 2: Train Loss: 4.6030, Train Accuracy: 1.24%
#     Worker 3: Train Loss: 4.6045, Train Accuracy: 1.20%
# Epoch 4/150: Test Loss: 4.5980, Test Accuracy: 1.57%
#     Worker 0: Train Loss: 4.6014, Train Accuracy: 1.51%
#     Worker 1: Train Loss: 4.6010, Train Accuracy: 1.66%
#     Worker 2: Train Loss: 4.5999, Train Accuracy: 1.29%
#     Worker 3: Train Loss: 4.6025, Train Accuracy: 0.82%
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Warmup phase completed at epoch 5. Switching to polynomial decay learning rate.
# Epoch 5/150: Test Loss: 4.5900, Test Accuracy: 2.13%
#     Worker 0: Train Loss: 4.5971, Train Accuracy: 1.71%
#     Worker 1: Train Loss: 4.5968, Train Accuracy: 1.34%
#     Worker 2: Train Loss: 4.5974, Train Accuracy: 1.00%
#     Worker 3: Train Loss: 4.5991, Train Accuracy: 1.19%
# Epoch 6/150: Test Loss: 4.5749, Test Accuracy: 2.40%
#     Worker 0: Train Loss: 4.5886, Train Accuracy: 2.18%
#     Worker 1: Train Loss: 4.5882, Train Accuracy: 1.97%
#     Worker 2: Train Loss: 4.5889, Train Accuracy: 1.64%
#     Worker 3: Train Loss: 4.5903, Train Accuracy: 1.28%
# Epoch 7/150: Test Loss: 4.5373, Test Accuracy: 2.67%
#     Worker 0: Train Loss: 4.5722, Train Accuracy: 1.23%
#     Worker 0: Train Loss: 3.5167, Train Accuracy: 16.07%
#     Worker 1: Train Loss: 3.5882, Train Accuracy: 15.20%
#     Worker 2: Train Loss: 3.4253, Train Accuracy: 17.71%
#     Worker 3: Train Loss: 3.4584, Train Accuracy: 17.45%
# Epoch 80/150: Test Loss: 3.3287, Test Accuracy: 19.82%
#     Worker 0: Train Loss: 3.4580, Train Accuracy: 16.71%
#     Worker 1: Train Loss: 3.4935, Train Accuracy: 16.36%
#     Worker 2: Train Loss: 3.5083, Train Accuracy: 15.92%
#     Worker 3: Train Loss: 3.4685, Train Accuracy: 16.60%
# Epoch 81/150: Test Loss: 3.3775, Test Accuracy: 19.35%
#     Worker 0: Train Loss: 3.4780, Train Accuracy: 16.49%
#     Worker 1: Train Loss: 3.6041, Train Accuracy: 14.48%
#     Worker 2: Train Loss: 3.4965, Train Accuracy: 17.11%
#     Worker 3: Train Loss: 3.5249, Train Accuracy: 16.16%
# Epoch 82/150: Test Loss: 3.3724, Test Accuracy: 18.23%
#     Worker 0: Train Loss: 3.4982, Train Accuracy: 16.06%
#     Worker 1: Train Loss: 3.5153, Train Accuracy: 16.35%
#     Worker 2: Train Loss: 3.4864, Train Accuracy: 16.71%
#     Worker 3: Train Loss: 3.4983, Train Accuracy: 16.37%
# Epoch 83/150: Test Loss: 3.3125, Test Accuracy: 20.16%
#     Worker 0: Train Loss: 3.5109, Train Accuracy: 15.94%
#     Worker 1: Train Loss: 3.5066, Train Accuracy: 16.25%
#     Worker 2: Train Loss: 3.4267, Train Accuracy: 16.90%
#     Worker 3: Train Loss: 3.4409, Train Accuracy: 16.98%
# Epoch 84/150: Test Loss: 3.3352, Test Accuracy: 19.58%
#     Worker 0: Train Loss: 3.4598, Train Accuracy: 16.74%
#     Worker 1: Train Loss: 3.4538, Train Accuracy: 17.06%
#     Worker 2: Train Loss: 3.4297, Train Accuracy: 17.46%
#     Worker 3: Train Loss: 3.4449, Train Accuracy: 16.54%
# Epoch 85/150: Test Loss: 3.3146, Test Accuracy: 20.59%
#     Worker 0: Train Loss: 3.4934, Train Accuracy: 15.53%
#     Worker 1: Train Loss: 3.4205, Train Accuracy: 17.34%
#     Worker 2: Train Loss: 3.4890, Train Accuracy: 16.83%
#     Worker 3: Train Loss: 3.5137, Train Accuracy: 16.02%
# Epoch 86/150: Test Loss: 3.2927, Test Accuracy: 20.49%
#     Worker 0: Train Loss: 3.4136, Train Accuracy: 16.83%
#     Worker 1: Train Loss: 3.4400, Train Accuracy: 17.53%
#     Worker 2: Train Loss: 3.4189, Train Accuracy: 16.82%
#     Worker 3: Train Loss: 3.3921, Train Accuracy: 19.02%
# Epoch 87/150: Test Loss: 3.3191, Test Accuracy: 20.41%
#     Worker 0: Train Loss: 3.3971, Train Accuracy: 17.06%
#     Worker 1: Train Loss: 3.4718, Train Accuracy: 17.05%
#     Worker 2: Train Loss: 3.4037, Train Accuracy: 17.58%
#     Worker 3: Train Loss: 3.4116, Train Accuracy: 17.64%
# Epoch 88/150: Test Loss: 3.2980, Test Accuracy: 20.63%
#     Worker 0: Train Loss: 3.4320, Train Accuracy: 16.34%
#     Worker 1: Train Loss: 3.4967, Train Accuracy: 16.37%
#     Worker 2: Train Loss: 3.3906, Train Accuracy: 17.94%
#     Worker 3: Train Loss: 3.4079, Train Accuracy: 17.46%
# Epoch 89/150: Test Loss: 3.3291, Test Accuracy: 19.45%
#     Worker 0: Train Loss: 3.4005, Train Accuracy: 17.82%
#     Worker 1: Train Loss: 3.4648, Train Accuracy: 17.47%
#     Worker 2: Train Loss: 3.4640, Train Accuracy: 17.93%
#     Worker 3: Train Loss: 3.4236, Train Accuracy: 17.10%
# Epoch 90/150: Test Loss: 3.2757, Test Accuracy: 20.78%
#     Worker 0: Train Loss: 3.4206, Train Accuracy: 17.56%
#     Worker 1: Train Loss: 3.4608, Train Accuracy: 17.45%
#     Worker 2: Train Loss: 3.4060, Train Accuracy: 17.35%
#     Worker 3: Train Loss: 3.4262, Train Accuracy: 17.63%
# Epoch 91/150: Test Loss: 3.2712, Test Accuracy: 20.69%
#     Worker 0: Train Loss: 3.3536, Train Accuracy: 18.51%
#     Worker 1: Train Loss: 3.4085, Train Accuracy: 17.87%
#     Worker 2: Train Loss: 3.3918, Train Accuracy: 18.26%
#     Worker 3: Train Loss: 3.3987, Train Accuracy: 18.39%
# Epoch 92/150: Test Loss: 3.3331, Test Accuracy: 20.25%
#     Worker 0: Train Loss: 3.5106, Train Accuracy: 16.05%
#     Worker 1: Train Loss: 3.4327, Train Accuracy: 18.22%
#     Worker 2: Train Loss: 3.3725, Train Accuracy: 18.41%
#     Worker 3: Train Loss: 3.4593, Train Accuracy: 17.06%
# Epoch 93/150: Test Loss: 3.2554, Test Accuracy: 20.70%
#     Worker 0: Train Loss: 3.3798, Train Accuracy: 17.91%
#     Worker 1: Train Loss: 3.4562, Train Accuracy: 17.43%
#     Worker 2: Train Loss: 3.4356, Train Accuracy: 17.61%
#     Worker 3: Train Loss: 3.4018, Train Accuracy: 17.98%
# Epoch 94/150: Test Loss: 3.2710, Test Accuracy: 21.06%
#     Worker 0: Train Loss: 3.4225, Train Accuracy: 16.94%
#     Worker 1: Train Loss: 3.3796, Train Accuracy: 18.15%
#     Worker 2: Train Loss: 3.3097, Train Accuracy: 19.51%
#     Worker 3: Train Loss: 3.3419, Train Accuracy: 19.03%
# Epoch 95/150: Test Loss: 3.2419, Test Accuracy: 21.70%
#     Worker 0: Train Loss: 3.3711, Train Accuracy: 17.53%
#     Worker 1: Train Loss: 3.3959, Train Accuracy: 18.61%
#     Worker 2: Train Loss: 3.4049, Train Accuracy: 18.89%
#     Worker 3: Train Loss: 3.4293, Train Accuracy: 17.22%
# Epoch 96/150: Test Loss: 3.2297, Test Accuracy: 22.02%
#     Worker 0: Train Loss: 3.4372, Train Accuracy: 17.25%
#     Worker 1: Train Loss: 3.3960, Train Accuracy: 18.47%
#     Worker 2: Train Loss: 3.3504, Train Accuracy: 18.58%
#     Worker 3: Train Loss: 3.3869, Train Accuracy: 18.19%
# Epoch 97/150: Test Loss: 3.2534, Test Accuracy: 21.85%
#     Worker 0: Train Loss: 3.3655, Train Accuracy: 18.10%
#     Worker 1: Train Loss: 3.3828, Train Accuracy: 18.86%
#     Worker 2: Train Loss: 3.2955, Train Accuracy: 19.98%
#     Worker 3: Train Loss: 3.3760, Train Accuracy: 19.14%
# Epoch 98/150: Test Loss: 3.2184, Test Accuracy: 21.88%
#     Worker 0: Train Loss: 3.3127, Train Accuracy: 19.71%
#     Worker 1: Train Loss: 3.4131, Train Accuracy: 17.81%
#     Worker 2: Train Loss: 3.3096, Train Accuracy: 19.82%
#     Worker 3: Train Loss: 3.3193, Train Accuracy: 19.44%
# Epoch 99/150: Test Loss: 3.2239, Test Accuracy: 21.92%
#     Worker 0: Train Loss: 3.3464, Train Accuracy: 18.74%
#     Worker 1: Train Loss: 3.6102, Train Accuracy: 15.67%
#     Worker 2: Train Loss: 3.3385, Train Accuracy: 19.46%
#     Worker 3: Train Loss: 3.3386, Train Accuracy: 18.70%
# Epoch 100/150: Test Loss: 3.2567, Test Accuracy: 21.63%
#     Worker 0: Train Loss: 3.4255, Train Accuracy: 17.70%
#     Worker 1: Train Loss: 3.3234, Train Accuracy: 19.80%
#     Worker 2: Train Loss: 3.3468, Train Accuracy: 19.30%
#     Worker 3: Train Loss: 3.3869, Train Accuracy: 18.74%
# Epoch 101/150: Test Loss: 3.2083, Test Accuracy: 22.16%
#     Worker 0: Train Loss: 3.3208, Train Accuracy: 18.65%
#     Worker 1: Train Loss: 3.3742, Train Accuracy: 18.54%
#     Worker 2: Train Loss: 3.2985, Train Accuracy: 19.84%
#     Worker 3: Train Loss: 3.3747, Train Accuracy: 18.23%
# Epoch 102/150: Test Loss: 3.2398, Test Accuracy: 21.43%
#     Worker 0: Train Loss: 3.3007, Train Accuracy: 18.90%
#     Worker 1: Train Loss: 3.3090, Train Accuracy: 19.37%
#     Worker 2: Train Loss: 3.2992, Train Accuracy: 19.58%
#     Worker 3: Train Loss: 3.3378, Train Accuracy: 19.19%
# Epoch 103/150: Test Loss: 3.2000, Test Accuracy: 22.25%
#     Worker 0: Train Loss: 3.2806, Train Accuracy: 19.90%
#     Worker 1: Train Loss: 3.3588, Train Accuracy: 19.23%
#     Worker 2: Train Loss: 3.3243, Train Accuracy: 19.58%
#     Worker 3: Train Loss: 3.3813, Train Accuracy: 17.89%
# Epoch 104/150: Test Loss: 3.1580, Test Accuracy: 22.96%
#     Worker 0: Train Loss: 3.3013, Train Accuracy: 19.02%
#     Worker 1: Train Loss: 3.2965, Train Accuracy: 20.27%
#     Worker 2: Train Loss: 3.2584, Train Accuracy: 19.88%
#     Worker 3: Train Loss: 3.2878, Train Accuracy: 19.93%
# Epoch 105/150: Test Loss: 3.1971, Test Accuracy: 22.30%
#     Worker 0: Train Loss: 3.2818, Train Accuracy: 19.66%
#     Worker 1: Train Loss: 3.2580, Train Accuracy: 20.52%
#     Worker 2: Train Loss: 3.3238, Train Accuracy: 19.70%
#     Worker 3: Train Loss: 3.2877, Train Accuracy: 20.18%
# Epoch 106/150: Test Loss: 3.1347, Test Accuracy: 23.42%
#     Worker 0: Train Loss: 3.2659, Train Accuracy: 20.18%
#     Worker 1: Train Loss: 3.3198, Train Accuracy: 19.70%
#     Worker 2: Train Loss: 3.2644, Train Accuracy: 20.38%
#     Worker 3: Train Loss: 3.2214, Train Accuracy: 21.44%
# Epoch 107/150: Test Loss: 3.1800, Test Accuracy: 23.08%
#     Worker 0: Train Loss: 3.2131, Train Accuracy: 20.94%
#     Worker 1: Train Loss: 3.3086, Train Accuracy: 19.92%
#     Worker 2: Train Loss: 3.2320, Train Accuracy: 20.64%
#     Worker 3: Train Loss: 3.2465, Train Accuracy: 20.83%
# Epoch 108/150: Test Loss: 3.1271, Test Accuracy: 23.70%
#     Worker 0: Train Loss: 3.1861, Train Accuracy: 21.36%
#     Worker 1: Train Loss: 3.2250, Train Accuracy: 21.06%
#     Worker 2: Train Loss: 3.2482, Train Accuracy: 20.90%
#     Worker 3: Train Loss: 3.3013, Train Accuracy: 19.75%
# Epoch 109/150: Test Loss: 3.1469, Test Accuracy: 23.29%
#     Worker 0: Train Loss: 3.1874, Train Accuracy: 21.32%
#     Worker 1: Train Loss: 3.2905, Train Accuracy: 20.38%
#     Worker 2: Train Loss: 3.2028, Train Accuracy: 21.76%
#     Worker 3: Train Loss: 3.2675, Train Accuracy: 20.04%
# Epoch 110/150: Test Loss: 3.1314, Test Accuracy: 23.24%
#     Worker 0: Train Loss: 3.2411, Train Accuracy: 20.86%
#     Worker 1: Train Loss: 3.2555, Train Accuracy: 20.53%
#     Worker 2: Train Loss: 3.2361, Train Accuracy: 21.34%
#     Worker 3: Train Loss: 3.2332, Train Accuracy: 20.70%
# Epoch 111/150: Test Loss: 3.1303, Test Accuracy: 23.82%
#     Worker 0: Train Loss: 3.2282, Train Accuracy: 20.79%
#     Worker 1: Train Loss: 3.2047, Train Accuracy: 21.43%
#     Worker 2: Train Loss: 3.2217, Train Accuracy: 20.86%
#     Worker 3: Train Loss: 3.2951, Train Accuracy: 19.92%
# Epoch 112/150: Test Loss: 3.1363, Test Accuracy: 23.56%
#     Worker 0: Train Loss: 3.2243, Train Accuracy: 21.01%
#     Worker 1: Train Loss: 3.2136, Train Accuracy: 21.63%
#     Worker 2: Train Loss: 3.2803, Train Accuracy: 20.67%
#     Worker 3: Train Loss: 3.2277, Train Accuracy: 20.78%
# Epoch 113/150: Test Loss: 3.1047, Test Accuracy: 24.13%
#     Worker 0: Train Loss: 3.2572, Train Accuracy: 20.13%
#     Worker 1: Train Loss: 3.2731, Train Accuracy: 20.53%
#     Worker 2: Train Loss: 3.1761, Train Accuracy: 21.79%
#     Worker 3: Train Loss: 3.1964, Train Accuracy: 21.94%
# Epoch 114/150: Test Loss: 3.1206, Test Accuracy: 23.51%
#     Worker 0: Train Loss: 3.2189, Train Accuracy: 21.30%
#     Worker 1: Train Loss: 3.2613, Train Accuracy: 20.42%
#     Worker 2: Train Loss: 3.1291, Train Accuracy: 22.57%
#     Worker 3: Train Loss: 3.1878, Train Accuracy: 21.69%
# Epoch 115/150: Test Loss: 3.0956, Test Accuracy: 24.32%
#     Worker 0: Train Loss: 3.2073, Train Accuracy: 20.95%
#     Worker 1: Train Loss: 3.2091, Train Accuracy: 21.50%
#     Worker 2: Train Loss: 3.1087, Train Accuracy: 23.51%
#     Worker 3: Train Loss: 3.1801, Train Accuracy: 22.22%
# Epoch 116/150: Test Loss: 3.0708, Test Accuracy: 24.97%
#     Worker 0: Train Loss: 3.2244, Train Accuracy: 21.42%
#     Worker 1: Train Loss: 3.2080, Train Accuracy: 21.41%
#     Worker 2: Train Loss: 3.1145, Train Accuracy: 23.63%
#     Worker 3: Train Loss: 3.1417, Train Accuracy: 22.73%
# Epoch 117/150: Test Loss: 3.0728, Test Accuracy: 24.62%
#     Worker 0: Train Loss: 3.1969, Train Accuracy: 21.63%
#     Worker 1: Train Loss: 3.1652, Train Accuracy: 21.92%
#     Worker 2: Train Loss: 3.1252, Train Accuracy: 23.04%
#     Worker 3: Train Loss: 3.1340, Train Accuracy: 22.18%
# Epoch 118/150: Test Loss: 3.0585, Test Accuracy: 25.13%
#     Worker 0: Train Loss: 3.1224, Train Accuracy: 22.77%
#     Worker 1: Train Loss: 3.1517, Train Accuracy: 22.14%
#     Worker 2: Train Loss: 3.1576, Train Accuracy: 22.52%
#     Worker 3: Train Loss: 3.1291, Train Accuracy: 23.18%
# Epoch 119/150: Test Loss: 3.0856, Test Accuracy: 24.78%
#     Worker 0: Train Loss: 3.1900, Train Accuracy: 21.66%
#     Worker 1: Train Loss: 3.1760, Train Accuracy: 22.14%
#     Worker 2: Train Loss: 3.1434, Train Accuracy: 22.76%
#     Worker 3: Train Loss: 3.1609, Train Accuracy: 22.09%
# Epoch 120/150: Test Loss: 3.0960, Test Accuracy: 25.01%
#     Worker 0: Train Loss: 3.2092, Train Accuracy: 21.09%
#     Worker 1: Train Loss: 3.2004, Train Accuracy: 21.69%
#     Worker 2: Train Loss: 3.1884, Train Accuracy: 22.26%
#     Worker 3: Train Loss: 3.1752, Train Accuracy: 22.29%
# Epoch 121/150: Test Loss: 3.0712, Test Accuracy: 24.84%
#     Worker 0: Train Loss: 3.1740, Train Accuracy: 22.07%
#     Worker 1: Train Loss: 3.1926, Train Accuracy: 22.54%
#     Worker 2: Train Loss: 3.1080, Train Accuracy: 23.74%
#     Worker 3: Train Loss: 3.1859, Train Accuracy: 21.48%
# Epoch 122/150: Test Loss: 3.0507, Test Accuracy: 25.46%
#     Worker 0: Train Loss: 3.2319, Train Accuracy: 21.37%
#     Worker 1: Train Loss: 3.1360, Train Accuracy: 22.94%
#     Worker 2: Train Loss: 3.0965, Train Accuracy: 23.38%
#     Worker 3: Train Loss: 3.1319, Train Accuracy: 22.30%
# Epoch 123/150: Test Loss: 3.0589, Test Accuracy: 25.60%
#     Worker 0: Train Loss: 3.1937, Train Accuracy: 20.96%
#     Worker 1: Train Loss: 3.0978, Train Accuracy: 23.82%
#     Worker 2: Train Loss: 3.0945, Train Accuracy: 23.62%
#     Worker 3: Train Loss: 3.1459, Train Accuracy: 22.51%
# Epoch 124/150: Test Loss: 3.0431, Test Accuracy: 25.56%
#     Worker 0: Train Loss: 3.1201, Train Accuracy: 22.62%
#     Worker 1: Train Loss: 3.1181, Train Accuracy: 23.82%
#     Worker 2: Train Loss: 3.1119, Train Accuracy: 23.60%
#     Worker 3: Train Loss: 3.1677, Train Accuracy: 22.58%
# Epoch 125/150: Test Loss: 3.0809, Test Accuracy: 24.78%
#     Worker 0: Train Loss: 3.1102, Train Accuracy: 22.57%
#     Worker 1: Train Loss: 3.1632, Train Accuracy: 23.10%
#     Worker 2: Train Loss: 3.1134, Train Accuracy: 23.54%
#     Worker 3: Train Loss: 3.1257, Train Accuracy: 22.69%
# Epoch 126/150: Test Loss: 3.0246, Test Accuracy: 25.89%
#     Worker 0: Train Loss: 3.1335, Train Accuracy: 22.86%
#     Worker 1: Train Loss: 3.1613, Train Accuracy: 22.76%
#     Worker 2: Train Loss: 3.1097, Train Accuracy: 23.34%
#     Worker 3: Train Loss: 3.1068, Train Accuracy: 23.74%
# Epoch 127/150: Test Loss: 3.0798, Test Accuracy: 25.48%
#     Worker 0: Train Loss: 3.1160, Train Accuracy: 22.70%
#     Worker 1: Train Loss: 3.1199, Train Accuracy: 23.90%
#     Worker 2: Train Loss: 3.2466, Train Accuracy: 21.22%
#     Worker 3: Train Loss: 3.0998, Train Accuracy: 23.58%
# Epoch 128/150: Test Loss: 3.0341, Test Accuracy: 25.82%
#     Worker 0: Train Loss: 3.1601, Train Accuracy: 22.19%
#     Worker 1: Train Loss: 3.1018, Train Accuracy: 23.61%
#     Worker 2: Train Loss: 3.1235, Train Accuracy: 23.10%
#     Worker 3: Train Loss: 3.1149, Train Accuracy: 23.69%
# Epoch 129/150: Test Loss: 3.0326, Test Accuracy: 25.67%
#     Worker 0: Train Loss: 3.1140, Train Accuracy: 23.08%
#     Worker 1: Train Loss: 3.1356, Train Accuracy: 22.99%
#     Worker 2: Train Loss: 3.0546, Train Accuracy: 24.10%
#     Worker 3: Train Loss: 3.0935, Train Accuracy: 24.05%
# Epoch 130/150: Test Loss: 3.0226, Test Accuracy: 25.89%
#     Worker 0: Train Loss: 3.0821, Train Accuracy: 23.40%
#     Worker 1: Train Loss: 3.1165, Train Accuracy: 23.72%
#     Worker 2: Train Loss: 3.0889, Train Accuracy: 24.01%
#     Worker 3: Train Loss: 3.1232, Train Accuracy: 23.26%
# Epoch 131/150: Test Loss: 3.0162, Test Accuracy: 26.16%
#     Worker 0: Train Loss: 3.1489, Train Accuracy: 22.14%
#     Worker 1: Train Loss: 3.0905, Train Accuracy: 23.97%
#     Worker 2: Train Loss: 3.0442, Train Accuracy: 24.38%
#     Worker 3: Train Loss: 3.0731, Train Accuracy: 24.21%
# Epoch 132/150: Test Loss: 3.0109, Test Accuracy: 25.76%
#     Worker 0: Train Loss: 3.0779, Train Accuracy: 23.50%
#     Worker 1: Train Loss: 3.1250, Train Accuracy: 23.26%
#     Worker 2: Train Loss: 3.0644, Train Accuracy: 24.82%
#     Worker 3: Train Loss: 3.0517, Train Accuracy: 24.94%
# Epoch 133/150: Test Loss: 3.0147, Test Accuracy: 25.99%
#     Worker 0: Train Loss: 3.0732, Train Accuracy: 23.45%
#     Worker 1: Train Loss: 3.1075, Train Accuracy: 23.64%
#     Worker 2: Train Loss: 3.0290, Train Accuracy: 25.10%
#     Worker 3: Train Loss: 3.0908, Train Accuracy: 23.82%
# Epoch 134/150: Test Loss: 2.9837, Test Accuracy: 26.76%
#     Worker 0: Train Loss: 3.0636, Train Accuracy: 24.05%
#     Worker 1: Train Loss: 3.0558, Train Accuracy: 24.40%
#     Worker 2: Train Loss: 3.0301, Train Accuracy: 24.74%
#     Worker 3: Train Loss: 3.0393, Train Accuracy: 25.31%
# Epoch 135/150: Test Loss: 2.9823, Test Accuracy: 26.87%
#     Worker 0: Train Loss: 3.0888, Train Accuracy: 23.70%
#     Worker 1: Train Loss: 3.0578, Train Accuracy: 24.68%
#     Worker 2: Train Loss: 3.0224, Train Accuracy: 25.22%
#     Worker 3: Train Loss: 3.0672, Train Accuracy: 24.07%
# Epoch 136/150: Test Loss: 2.9887, Test Accuracy: 26.60%
#     Worker 0: Train Loss: 3.0360, Train Accuracy: 23.97%
#     Worker 1: Train Loss: 3.0658, Train Accuracy: 24.21%
#     Worker 2: Train Loss: 3.0203, Train Accuracy: 25.42%
#     Worker 3: Train Loss: 3.0647, Train Accuracy: 24.50%
# Epoch 137/150: Test Loss: 2.9896, Test Accuracy: 26.55%
#     Worker 0: Train Loss: 3.1093, Train Accuracy: 23.62%
#     Worker 1: Train Loss: 3.0670, Train Accuracy: 24.38%
#     Worker 2: Train Loss: 3.0115, Train Accuracy: 25.34%
#     Worker 3: Train Loss: 3.0305, Train Accuracy: 24.87%
# Epoch 138/150: Test Loss: 2.9832, Test Accuracy: 26.64%
#     Worker 0: Train Loss: 3.0470, Train Accuracy: 24.19%
#     Worker 1: Train Loss: 3.0420, Train Accuracy: 24.62%
#     Worker 2: Train Loss: 2.9896, Train Accuracy: 26.07%
#     Worker 3: Train Loss: 3.0357, Train Accuracy: 24.71%
# Epoch 139/150: Test Loss: 2.9818, Test Accuracy: 26.70%
#     Worker 0: Train Loss: 3.0334, Train Accuracy: 24.75%
#     Worker 1: Train Loss: 3.0418, Train Accuracy: 24.82%
#     Worker 2: Train Loss: 2.9948, Train Accuracy: 26.23%
#     Worker 3: Train Loss: 3.0318, Train Accuracy: 24.71%
# Epoch 140/150: Test Loss: 2.9595, Test Accuracy: 27.23%
#     Worker 0: Train Loss: 3.0727, Train Accuracy: 23.89%
#     Worker 1: Train Loss: 3.0227, Train Accuracy: 25.21%
#     Worker 2: Train Loss: 2.9754, Train Accuracy: 26.62%
#     Worker 3: Train Loss: 3.0162, Train Accuracy: 25.08%
# Epoch 141/150: Test Loss: 2.9779, Test Accuracy: 26.91%
#     Worker 0: Train Loss: 3.0151, Train Accuracy: 24.72%
#     Worker 1: Train Loss: 3.0375, Train Accuracy: 24.96%
#     Worker 2: Train Loss: 2.9629, Train Accuracy: 26.78%
#     Worker 3: Train Loss: 3.0221, Train Accuracy: 25.38%
# Epoch 142/150: Test Loss: 2.9713, Test Accuracy: 26.88%
#     Worker 0: Train Loss: 3.0085, Train Accuracy: 25.02%
#     Worker 1: Train Loss: 3.0354, Train Accuracy: 25.32%
#     Worker 2: Train Loss: 2.9711, Train Accuracy: 26.22%
#     Worker 3: Train Loss: 3.0139, Train Accuracy: 26.06%
# Epoch 143/150: Test Loss: 2.9765, Test Accuracy: 27.06%
#     Worker 0: Train Loss: 2.9887, Train Accuracy: 25.47%
#     Worker 1: Train Loss: 3.0174, Train Accuracy: 25.32%
#     Worker 2: Train Loss: 2.9703, Train Accuracy: 25.95%
#     Worker 3: Train Loss: 3.0122, Train Accuracy: 25.37%
# Epoch 144/150: Test Loss: 2.9573, Test Accuracy: 27.40%
#     Worker 0: Train Loss: 2.9778, Train Accuracy: 25.54%
#     Worker 1: Train Loss: 3.0104, Train Accuracy: 25.49%
#     Worker 2: Train Loss: 2.9619, Train Accuracy: 27.01%
#     Worker 3: Train Loss: 3.0135, Train Accuracy: 25.68%
# Epoch 145/150: Test Loss: 2.9531, Test Accuracy: 27.35%
#     Worker 0: Train Loss: 2.9887, Train Accuracy: 25.54%
#     Worker 1: Train Loss: 2.9933, Train Accuracy: 25.76%
#     Worker 2: Train Loss: 2.9401, Train Accuracy: 26.86%
#     Worker 3: Train Loss: 2.9912, Train Accuracy: 25.71%
# Epoch 146/150: Test Loss: 2.9567, Test Accuracy: 27.24%
#     Worker 0: Train Loss: 2.9622, Train Accuracy: 25.82%
#     Worker 1: Train Loss: 2.9991, Train Accuracy: 25.70%
#     Worker 2: Train Loss: 2.9435, Train Accuracy: 27.30%
#     Worker 3: Train Loss: 2.9888, Train Accuracy: 26.06%
# Epoch 147/150: Test Loss: 2.9534, Test Accuracy: 27.42%
#     Worker 0: Train Loss: 2.9684, Train Accuracy: 25.83%
#     Worker 1: Train Loss: 2.9886, Train Accuracy: 26.10%
#     Worker 2: Train Loss: 2.9489, Train Accuracy: 26.94%
#     Worker 3: Train Loss: 2.9845, Train Accuracy: 26.02%
# Epoch 148/150: Test Loss: 2.9469, Test Accuracy: 27.62%
#     Worker 0: Train Loss: 2.9523, Train Accuracy: 25.86%
#     Worker 1: Train Loss: 2.9794, Train Accuracy: 25.63%
#     Worker 2: Train Loss: 2.9373, Train Accuracy: 27.21%
#     Worker 3: Train Loss: 2.9803, Train Accuracy: 26.36%
# Epoch 149/150: Test Loss: 2.9405, Test Accuracy: 27.77%
#     Worker 0: Train Loss: 2.9536, Train Accuracy: 26.10%
#     Worker 1: Train Loss: 2.9887, Train Accuracy: 25.75%
#     Worker 2: Train Loss: 2.9363, Train Accuracy: 27.17%
#     Worker 3: Train Loss: 2.9746, Train Accuracy: 25.82%
# Epoch 150/150: Test Loss: 2.9394, Test Accuracy: 27.75%
#     Worker 0: Train Loss: 2.9583, Train Accuracy: 25.94%
#     Worker 1: Train Loss: 2.9867, Train Accuracy: 25.92%
#     Worker 2: Train Loss: 2.9279, Train Accuracy: 27.69%
#     Worker 3: Train Loss: 2.9673, Train Accuracy: 26.64%
