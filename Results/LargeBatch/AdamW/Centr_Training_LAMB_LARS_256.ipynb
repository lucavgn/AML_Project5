# %%
# %%writefile large_batch_training.py

import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split
from google.colab import files

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std

# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Initialize model
net = LeNet5().to(device)

# Optimizer Subclasses
class LARS(optim.Optimizer):
    def __init__(self, params, lr, momentum=0.9, weight_decay=0, trust_coefficient=0.001):
        # Initialize the optimizer with the learning rate, momentum, weight decay, and trust coefficient
        defaults = dict(lr=lr, momentum=momentum, weight_decay=weight_decay, trust_coefficient=trust_coefficient)
        super(LARS, self).__init__(params, defaults)

    def step(self, closure=None):
        loss = None
        if closure is not None:
            # If a closure is provided, evaluate it (commonly used for re-evaluating loss)
            loss = closure()
        for group in self.param_groups:
            for p in group['params']:
                if p.grad is None:
                   # Skip parameters that have no gradient
                    continue
                grad = p.grad.data # Get the gradient of the parameter
                # Retrieve or initialize the optimizer's internal state
                state = self.state[p]
                if len(state) == 0:
                    state['momentum_buffer'] = torch.clone(grad).detach()
                # Apply weight decay directly to the gradient
                if group['weight_decay'] != 0:
                    grad.add_(p.data, alpha=group['weight_decay'])
                # Compute the norms of the parameter and its gradient
                param_norm = torch.norm(p.data)
                grad_norm = torch.norm(grad)
                # Compute local learning rate based on the trust coefficient and norms
                if param_norm > 0 and grad_norm > 0:
                    local_lr = group['trust_coefficient'] * param_norm / (grad_norm + 1e-8)
                    grad = grad.mul(local_lr) # Scale the gradient with the local learning rate
                # Update the momentum buffer
                momentum_buffer = state['momentum_buffer']
                momentum_buffer.mul_(group['momentum']).add_(grad) #Momentum update
                state['momentum_buffer'] = momentum_buffer
                # Update the parameter
                p.data.add_(-group['lr'], momentum_buffer) # Gradient descent step with learning rate
        return loss

class LAMB(optim.Optimizer):
    def __init__(self, params, lr, weight_decay=0, betas=(0.9, 0.999), eps=1e-8):
        # Initialize the optimizer with learning rate, weight decay, betas for moment updates, and epsilon for stability
        defaults = dict(lr=lr, weight_decay=weight_decay, betas=betas, eps=eps)
        super(LAMB, self).__init__(params, defaults)

    def step(self, closure=None):
        loss = None
        if closure is not None:
            # If a closure is provided, evaluate it
            loss = closure()
        for group in self.param_groups:
            for p in group['params']:
                if p.grad is None:
                    # Skip parameters that have no gradient
                    continue
                grad = p.grad.data # Get the gradient of the parameter
                # Retrieve or initialize the optimizer's internal state
                state = self.state[p]
                # Initialize state
                if len(state) == 0:
                    # Initialize the state (step counter, first moment, second moment)
                    state['step'] = 0
                    state['exp_avg'] = torch.zeros_like(p.data) # First moment (mean of gradients)
                    state['exp_avg_sq'] = torch.zeros_like(p.data) # Second moment (mean of squared gradients)
                exp_avg = state['exp_avg']
                exp_avg_sq = state['exp_avg_sq']
                beta1, beta2 = group['betas']  # Coefficients for moment updates
                state['step'] += 1 # Increment step count
                step = state['step']
                # Decay the first and second moment running average coefficients
                # Update first and second moments
                exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1) # Exponential moving average of gradients
                exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1 - beta2) # Exponential moving average of squared gradients
                # Correct bias in the first and second moments
                bias_correction1 = 1 - beta1 ** step
                bias_correction2 = 1 - beta2 ** step
                corrected_exp_avg = exp_avg / bias_correction1
                corrected_exp_avg_sq = exp_avg_sq / bias_correction2
                # Compute the denominator for scaling the update
                denom = corrected_exp_avg_sq.sqrt().add_(group['eps']) # Stability epsilon
                # Compute the step update
                update = corrected_exp_avg / denom
                # Apply weight decay directly to the parameters
                if group['weight_decay'] != 0:
                    update.add_(p.data, alpha=group['weight_decay'])
                # Compute the trust ratio (norm of parameters vs norm of update)
                param_norm = torch.norm(p.data)
                update_norm = torch.norm(update)
                trust_ratio = 1.0  # Default trust ratio
                if param_norm > 0 and update_norm > 0:
                    trust_ratio = param_norm / update_norm
                # Update the parameters
                p.data.add_(-group['lr'] * trust_ratio, update)
        return loss

class SqrtLRScheduler(torch.optim.lr_scheduler._LRScheduler):
    def __init__(self, optimizer, base_lr, batch_size, warmup_epochs, total_epochs, reference_batch_size, verbose=True):
        """
        Args:
            optimizer: PyTorch optimizer (e.g., Adam, LAMB, LARS).
            base_lr: Base learning rate for the reference batch size.
            batch_size: Current batch size.
            warmup_epochs: Number of warmup epochs.
            total_epochs: Total number of epochs.
            reference_batch_size: Batch size for which the base_lr is defined.
            verbose: Whether to print LR updates.
        """
        self.base_lr = base_lr
        self.batch_size = batch_size
        self.scaled_lr = base_lr * (batch_size / reference_batch_size) ** 0.5
        self.warmup_epochs = warmup_epochs
        self.total_epochs = total_epochs
        self.verbose = verbose
        super(SqrtLRScheduler, self).__init__(optimizer)

    def get_lr(self):
        epoch = self.last_epoch
        if epoch < self.warmup_epochs:
            # Linear warmup scaling
            warmup_factor = (epoch + 1) / self.warmup_epochs
            lr = [warmup_factor * self.scaled_lr for _ in self.optimizer.param_groups]
            print(f"Epoch {epoch + 1}: Learning Rate: {lr}")
            return [warmup_factor * self.scaled_lr for _ in self.optimizer.param_groups]
        else:
            # Constant LR after warmup
            if epoch == self.warmup_epochs:
                print(f"Warmup phase completed at epoch {epoch}. Switching to constant learning rate.")

            lr = [self.scaled_lr for _ in self.optimizer.param_groups]
            print(f"Epoch {epoch + 1}: Learning Rate: {lr}")

            return [self.scaled_lr for _ in self.optimizer.param_groups]

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Large-Batch Optimizers')
parser.add_argument('--optimizer', type=str, default='SGDM', choices=['SGDM', 'AdamW', 'LARS', 'LAMB'],
                    help='Choose optimizer')
parser.add_argument('--batch-size', type=int, default=128, help='Batch size')
parser.add_argument('--momentum', type=float, default=0.9, help='Momentum for SGDM and LARS')
parser.add_argument('--weight-decay', type=float, default=1e-5, help='Weight decay')
parser.add_argument('--b1', type=float, default=0.9, help='Beta1 for AdamW')
parser.add_argument('--b2', type=float, default=0.999, help='Beta2 for AdamW')
parser.add_argument('--trust-coefficient', type=float, default=0.001, help='Trust coefficient for LARS')
parser.add_argument('--epochs', type=int, default=150, help='Number of epochs')
parser.add_argument('--warmup-epochs', type=int, default=5, help='Number of epochs')
args = parser.parse_args()


torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomHorizontalFlip(),
  # transforms.RandomRotation(15),
  transforms.RandomCrop(32, padding=4),
  # transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
  transforms.RandomPerspective(distortion_scale=0.2, p=0.5),
  transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.2),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

val_transform = transforms.Compose([
    transforms.ToTensor(), # Convert into tensor
    transforms.Normalize(mean, std)  # Normalization
])

test_transform = transforms.Compose([
    transforms.CenterCrop(24),
    transforms.Pad(4),
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)
valset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=val_transform)
indices = torch.randperm(len(trainset))
val_size = int(0.2*len(trainset))
trainset = torch.utils.data.Subset(trainset, indices[:-val_size])
valset = torch.utils.data.Subset(valset, indices[-val_size:])

trainloader = torch.utils.data.DataLoader(trainset, batch_size=args.batch_size, shuffle=True, num_workers=2)
valloader = torch.utils.data.DataLoader(valset, batch_size=args.batch_size, shuffle=False, num_workers=2)

testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=args.batch_size, shuffle=False, num_workers=2)


# Fixed parameter from paper [18] to calculate the square root LR scaling value
# base_lr = 5 / (2**3 * 10**3)
# reference_batch_size = 512
#scaled_lr = base_lr * (args.batch_size / reference_batch_size) ** 0.5

# Mapping optimizers
if args.optimizer == 'SGDM':
    base_lr = 1e-2
    reference_batch_size = 64
    scaled_lr = base_lr * (args.batch_size / reference_batch_size) ** 0.5
    optimizer = optim.SGD(net.parameters(), lr=scaled_lr, momentum=args.momentum, weight_decay=args.weight_decay)
elif args.optimizer == 'AdamW':
    base_lr = 5e-4
    reference_batch_size = 64
    scaled_lr = base_lr * (args.batch_size / reference_batch_size) ** 0.5
    optimizer = optim.AdamW(net.parameters(), lr=scaled_lr, betas=(args.b1, args.b2), weight_decay=args.weight_decay)
elif args.optimizer == 'LARS':
    base_lr = 5 / (2**3 * 10**3) # to define
    reference_batch_size = 512
    scaled_lr = base_lr * (args.batch_size / reference_batch_size) ** 0.5
    optimizer = LARS(net.parameters(), lr=scaled_lr, momentum=args.momentum, weight_decay=args.weight_decay, trust_coefficient=args.trust_coefficient)
elif args.optimizer == 'LAMB':
    base_lr = 5 / (2**3 * 10**3) # to define
    reference_batch_size = 512
    scaled_lr = base_lr * (args.batch_size / reference_batch_size) ** 0.5
    optimizer = LAMB(net.parameters(), lr=scaled_lr, weight_decay=args.weight_decay)

criterion = nn.CrossEntropyLoss()

# scheduler should be e square root LR scaling rule and linear-epoch warmup scheduling to automatically adjust learning rate
scheduler = SqrtLRScheduler(
    optimizer = optimizer,
    base_lr = base_lr,
    batch_size = args.batch_size,
    warmup_epochs = args.warmup_epochs,
    total_epochs = args.epochs,
    reference_batch_size = reference_batch_size,
    verbose = True)

# Training Function
def train_model(optimizer, scheduler, model, criterion, trainloader, valloader , testloader, device, epochs, save_checkpoint_interval=10):
    train_losses, val_losses, test_losses = [], [], []
    train_accuracies, val_accuracies, test_accuracies = [], [], []
    for epoch in range(epochs):
        model.train()
        running_loss, correct_train, total_train = 0.0, 0, 0
        for inputs, labels in trainloader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            _, predicted = outputs.max(1)
            total_train += labels.size(0)
            correct_train += predicted.eq(labels).sum().item()
        train_loss = running_loss / len(trainloader)
        train_accuracy = 100. * correct_train / total_train
        train_losses.append(train_loss)
        train_accuracies.append(train_accuracy)

        # Validation
        model.eval()
        correct_val, total_val, val_loss = 0, 0, 0.0
        with torch.no_grad():
            for inputs, labels in valloader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = outputs.max(1)
                total_val += labels.size(0)
                correct_val += predicted.eq(labels).sum().item()
        val_loss /= len(valloader)
        val_losses.append(val_loss)
        val_accuracy = 100. * correct_val / total_val
        val_accuracies.append(val_accuracy)

        '''
        # Early Stopping
        if val_loss < best_val_loss:
          best_val_loss = val_loss
          epochs_no_improve = 0
        else:
          epochs_no_improve += 1

        if epochs_no_improve == patience:
          print("Early stopping!")
          break
        '''

        # Test
        correct_test, total_test, test_loss = 0, 0, 0.0
        with torch.no_grad():
            for inputs, labels in testloader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                test_loss += loss.item()
                _, predicted = outputs.max(1)
                total_test += labels.size(0)
                correct_test += predicted.eq(labels).sum().item()
        test_loss /= len(testloader)
        test_losses.append(test_loss)
        test_accuracy = 100. * correct_test / total_test
        test_accuracies.append(test_accuracy)

        scheduler.step()

        # Checkpointing
        if (epoch + 1) % save_checkpoint_interval == 0:
            checkpoint_filename = f'checkpoint_epoch_{epoch + 1}.pth'
            checkpoint = {
                'epoch': epoch + 1,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'scheduler_state_dict': scheduler.state_dict(),
                'loss': loss.item(),
            }
            checkpoint_path = os.path.join('./', checkpoint_filename)
            torch.save(checkpoint, checkpoint_path)
            print(f'Checkpoint saved at epoch {epoch + 1}: {checkpoint_path}')

            # Download the checkpoint
            files.download(checkpoint_filename)

        print(f'Epoch {epoch+1}/{epochs}, Train Acc: {train_accuracy:.2f}%, Val Acc: {val_accuracy:.2f}%, Test Acc: {test_accuracy:.2f}%')
        print(f'Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, Test Loss: {test_loss:.4f}')

    return train_losses, val_losses, test_losses, train_accuracies, val_accuracies, test_accuracies

# Train the model
print(f"--- Train with {args.optimizer} ---")
train_loss, val_loss, test_loss, train_acc, val_acc, test_acc = train_model(optimizer, scheduler, net, criterion, trainloader, valloader, testloader, device, args.epochs)

# Save model
torch.save(net.state_dict(), f'net_{args.optimizer}.pth')

# Plot results
# Plot Training Loss
plt.figure(figsize=(6, 4))
plt.plot(train_loss, label='Train Loss')
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss.png')
plt.show()

# Plot Training Accuracy
plt.figure(figsize=(6, 4))
plt.plot(train_acc, label='Train Accuracy')
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy.png')
plt.show()

# Plot Validation Loss
plt.figure(figsize=(6, 4))
plt.plot(val_loss, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('val_loss.png')
plt.show()

# Plot Validation Accuracy
plt.figure(figsize=(6, 4))
plt.plot(val_acc, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('val_accuracy.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_loss, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_acc, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Overwriting large_batch_training.py

# %%
# %run large_batch_training.py --optimizer SGDM --batch-size 128 --weight-decay 4e-4
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# --- Train with SGDM ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /content/large_batch_training.py in <module>
#     385 # Train the model
#     386 print(f"--- Train with {args.optimizer} ---")
# --> 387 train_loss, val_loss, test_loss, train_acc, val_acc, test_acc = train_model(optimizer, scheduler, net, criterion, trainloader, valloader, testloader, device, args.epochs)
#     388
#     389 # Save model
#
# /content/large_batch_training.py in train_model(optimizer, scheduler, model, criterion, trainloader, valloader, testloader, device, epochs, save_checkpoint_interval)
#     297         model.train()
#     298         running_loss, correct_train, total_train = 0.0, 0, 0
# --> 299         for inputs, labels in trainloader:
#     300             inputs, labels = inputs.to(device), labels.to(device)
#     301             optimizer.zero_grad()
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     699                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700                 self._reset()  # type: ignore[call-arg]
# --> 701             data = self._next_data()
#     702             self._num_yielded += 1
#     703             if (
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1446
#    1447             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1448             idx, data = self._get_data()
#    1449             self._tasks_outstanding -= 1
#    1450             if self._dataset_kind == _DatasetKind.Iterable:
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1410         else:
#    1411             while True:
# -> 1412                 success, data = self._try_get_data()
#    1413                 if success:
#    1414                     return data
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#    1241         #   (bool: whether successfully get data, any: data if successful else None)
#    1242         try:
# -> 1243             data = self._data_queue.get(timeout=timeout)
#    1244             return (True, data)
#    1245         except Exception as e:
#
# /usr/lib/python3.10/multiprocessing/queues.py in get(self, block, timeout)
#     111                 if block:
#     112                     timeout = deadline - time.monotonic()
# --> 113                     if not self._poll(timeout):
#     114                         raise Empty
#     115                 elif not self._poll():
#
# /usr/lib/python3.10/multiprocessing/connection.py in poll(self, timeout)
#     255         self._check_closed()
#     256         self._check_readable()
# --> 257         return self._poll(timeout)
#     258
#     259     def __enter__(self):
#
# /usr/lib/python3.10/multiprocessing/connection.py in _poll(self, timeout)
#     422
#     423     def _poll(self, timeout):
# --> 424         r = wait([self], timeout)
#     425         return bool(r)
#     426
#
# /usr/lib/python3.10/multiprocessing/connection.py in wait(object_list, timeout)
#     929
#     930             while True:
# --> 931                 ready = selector.select(timeout)
#     932                 if ready:
#     933                     return [key.fileobj for (key, events) in ready]
#
# /usr/lib/python3.10/selectors.py in select(self, timeout)
#     414         ready = []
#     415         try:
# --> 416             fd_event_list = self._selector.poll(timeout)
#     417         except InterruptedError:
#     418             return ready
#
# KeyboardInterrupt:

# %%
# %run large_batch_training.py --optimizer AdamW --batch-size 256 --weight-decay 1e-2
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1: Learning Rate: [0.0002]
# --- Train with AdamW ---
# Epoch 2: Learning Rate: [0.0004]
# Epoch 1/150, Train Acc: 4.27%, Val Acc: 8.90%, Test Acc: 7.81%
# Epoch 1/150, Train Loss: 4.3640, Val Loss: 4.0292, Test Loss: 4.0850
# Epoch 3: Learning Rate: [0.0006]
# Epoch 2/150, Train Acc: 9.06%, Val Acc: 15.15%, Test Acc: 11.52%
# Epoch 2/150, Train Loss: 4.0028, Val Loss: 3.6926, Test Loss: 3.8072
# Epoch 4: Learning Rate: [0.0008]
# Epoch 3/150, Train Acc: 12.83%, Val Acc: 16.67%, Test Acc: 16.00%
# Epoch 3/150, Train Loss: 3.7575, Val Loss: 3.5314, Test Loss: 3.5728
# Epoch 5: Learning Rate: [0.001]
# Epoch 4/150, Train Acc: 15.73%, Val Acc: 20.22%, Test Acc: 17.14%
# Epoch 4/150, Train Loss: 3.5675, Val Loss: 3.3370, Test Loss: 3.4673
# Warmup phase completed at epoch 5. Switching to constant learning rate.
# Epoch 6: Learning Rate: [0.001]
# Epoch 45/150, Train Acc: 48.04%, Val Acc: 44.72%, Test Acc: 37.68%
# Epoch 45/150, Train Loss: 1.9301, Val Loss: 2.1419, Test Loss: 2.5585
# Epoch 47: Learning Rate: [0.001]
# Epoch 46/150, Train Acc: 48.00%, Val Acc: 46.24%, Test Acc: 39.75%
# Epoch 46/150, Train Loss: 1.9291, Val Loss: 2.1062, Test Loss: 2.4213
# Epoch 48: Learning Rate: [0.001]
# Epoch 47/150, Train Acc: 48.67%, Val Acc: 45.61%, Test Acc: 39.64%
# Epoch 47/150, Train Loss: 1.9115, Val Loss: 2.1270, Test Loss: 2.4264
# Epoch 49: Learning Rate: [0.001]
# Epoch 48/150, Train Acc: 49.07%, Val Acc: 46.21%, Test Acc: 40.11%
# Epoch 48/150, Train Loss: 1.8896, Val Loss: 2.0938, Test Loss: 2.3780
# Epoch 50: Learning Rate: [0.001]
# Epoch 49/150, Train Acc: 48.88%, Val Acc: 46.36%, Test Acc: 40.26%
# Epoch 49/150, Train Loss: 1.8956, Val Loss: 2.1300, Test Loss: 2.4624
# Epoch 51: Learning Rate: [0.001]
# Checkpoint saved at epoch 50: ./checkpoint_epoch_50.pth
# Epoch 50/150, Train Acc: 49.08%, Val Acc: 45.68%, Test Acc: 39.36%
# Epoch 50/150, Train Loss: 1.8753, Val Loss: 2.1308, Test Loss: 2.4337
# Epoch 52: Learning Rate: [0.001]
# Epoch 51/150, Train Acc: 48.88%, Val Acc: 45.77%, Test Acc: 39.04%
# Epoch 51/150, Train Loss: 1.8756, Val Loss: 2.1002, Test Loss: 2.4545
# Epoch 53: Learning Rate: [0.001]
# Epoch 52/150, Train Acc: 49.22%, Val Acc: 46.11%, Test Acc: 40.34%
# Epoch 52/150, Train Loss: 1.8730, Val Loss: 2.1225, Test Loss: 2.3955
# Epoch 54: Learning Rate: [0.001]
# Epoch 53/150, Train Acc: 50.08%, Val Acc: 46.05%, Test Acc: 38.76%
# Epoch 53/150, Train Loss: 1.8450, Val Loss: 2.1367, Test Loss: 2.4539
# Epoch 55: Learning Rate: [0.001]
# Epoch 54/150, Train Acc: 49.97%, Val Acc: 46.52%, Test Acc: 39.24%
# Epoch 54/150, Train Loss: 1.8446, Val Loss: 2.0922, Test Loss: 2.4712
# Epoch 56: Learning Rate: [0.001]
# Epoch 55/150, Train Acc: 49.69%, Val Acc: 46.35%, Test Acc: 40.70%
# Epoch 55/150, Train Loss: 1.8432, Val Loss: 2.0758, Test Loss: 2.3742
# Epoch 57: Learning Rate: [0.001]
# Epoch 56/150, Train Acc: 50.40%, Val Acc: 46.68%, Test Acc: 40.93%
# Epoch 56/150, Train Loss: 1.8200, Val Loss: 2.0863, Test Loss: 2.3737
# Epoch 58: Learning Rate: [0.001]
# Epoch 57/150, Train Acc: 50.48%, Val Acc: 46.67%, Test Acc: 40.69%
# Epoch 57/150, Train Loss: 1.8242, Val Loss: 2.0934, Test Loss: 2.3967
# Epoch 59: Learning Rate: [0.001]
# Epoch 58/150, Train Acc: 50.66%, Val Acc: 47.27%, Test Acc: 40.66%
# Epoch 73: Learning Rate: [0.001]
# Epoch 72/150, Train Acc: 52.67%, Val Acc: 47.24%, Test Acc: 39.76%
# Epoch 72/150, Train Loss: 1.7232, Val Loss: 2.1503, Test Loss: 2.5059
# Epoch 74: Learning Rate: [0.001]
# Epoch 73/150, Train Acc: 52.46%, Val Acc: 47.46%, Test Acc: 40.38%
# Epoch 73/150, Train Loss: 1.7298, Val Loss: 2.0916, Test Loss: 2.4022
# Epoch 75: Learning Rate: [0.001]
# Epoch 74/150, Train Acc: 52.78%, Val Acc: 47.67%, Test Acc: 40.73%
# Epoch 74/150, Train Loss: 1.7174, Val Loss: 2.0777, Test Loss: 2.4317
# Epoch 76: Learning Rate: [0.001]
# Epoch 75/150, Train Acc: 53.14%, Val Acc: 47.33%, Test Acc: 40.94%
# Epoch 75/150, Train Loss: 1.7105, Val Loss: 2.0838, Test Loss: 2.3940
# Epoch 77: Learning Rate: [0.001]
# Epoch 76/150, Train Acc: 53.18%, Val Acc: 47.01%, Test Acc: 40.79%
# Epoch 76/150, Train Loss: 1.7055, Val Loss: 2.1152, Test Loss: 2.4008
# Epoch 78: Learning Rate: [0.001]
# Epoch 77/150, Train Acc: 53.29%, Val Acc: 47.48%, Test Acc: 41.12%
# Epoch 77/150, Train Loss: 1.7048, Val Loss: 2.0789, Test Loss: 2.4058
# Epoch 79: Learning Rate: [0.001]
# Epoch 78/150, Train Acc: 53.49%, Val Acc: 46.87%, Test Acc: 41.49%
# Epoch 78/150, Train Loss: 1.6915, Val Loss: 2.1217, Test Loss: 2.3822
# Epoch 80: Learning Rate: [0.001]
# Epoch 79/150, Train Acc: 53.12%, Val Acc: 47.35%, Test Acc: 41.38%
# Epoch 79/150, Train Loss: 1.7107, Val Loss: 2.1180, Test Loss: 2.4130
# Epoch 81: Learning Rate: [0.001]
# Checkpoint saved at epoch 80: ./checkpoint_epoch_80.pth
# Epoch 80/150, Train Acc: 53.55%, Val Acc: 47.83%, Test Acc: 40.50%
# Epoch 80/150, Train Loss: 1.6855, Val Loss: 2.0816, Test Loss: 2.4130
# Epoch 82: Learning Rate: [0.001]
# Epoch 81/150, Train Acc: 53.49%, Val Acc: 47.85%, Test Acc: 41.77%
# Epoch 81/150, Train Loss: 1.6872, Val Loss: 2.0826, Test Loss: 2.3572
# Epoch 83: Learning Rate: [0.001]
# Epoch 82/150, Train Acc: 53.60%, Val Acc: 47.54%, Test Acc: 41.83%
# Epoch 82/150, Train Loss: 1.6832, Val Loss: 2.0884, Test Loss: 2.3632
# Epoch 84: Learning Rate: [0.001]
# Epoch 83/150, Train Acc: 53.73%, Val Acc: 47.63%, Test Acc: 41.79%
# Epoch 83/150, Train Loss: 1.6812, Val Loss: 2.1243, Test Loss: 2.3905
# Epoch 85: Learning Rate: [0.001]
# Epoch 84/150, Train Acc: 53.88%, Val Acc: 46.71%, Test Acc: 39.39%
# Epoch 84/150, Train Loss: 1.6742, Val Loss: 2.1738, Test Loss: 2.5352
# Epoch 86: Learning Rate: [0.001]
# Epoch 85/150, Train Acc: 53.77%, Val Acc: 47.12%, Test Acc: 41.46%
# Epoch 85/150, Train Loss: 1.6775, Val Loss: 2.1373, Test Loss: 2.3874
# Epoch 87: Learning Rate: [0.001]
# Epoch 86/150, Train Acc: 53.96%, Val Acc: 47.62%, Test Acc: 41.27%
# Epoch 86/150, Train Loss: 1.6599, Val Loss: 2.1219, Test Loss: 2.4160
# Epoch 88: Learning Rate: [0.001]
# Epoch 87/150, Train Acc: 53.92%, Val Acc: 48.04%, Test Acc: 42.12%
# Epoch 87/150, Train Loss: 1.6690, Val Loss: 2.0933, Test Loss: 2.3522
# Epoch 89: Learning Rate: [0.001]
# Epoch 88/150, Train Acc: 54.16%, Val Acc: 47.37%, Test Acc: 41.14%
# Epoch 88/150, Train Loss: 1.6626, Val Loss: 2.1290, Test Loss: 2.4265
# Epoch 90: Learning Rate: [0.001]
# Epoch 89/150, Train Acc: 54.38%, Val Acc: 47.74%, Test Acc: 40.89%
# Epoch 89/150, Train Loss: 1.6538, Val Loss: 2.0929, Test Loss: 2.4276
# Epoch 91: Learning Rate: [0.001]
# Checkpoint saved at epoch 90: ./checkpoint_epoch_90.pth
# Epoch 90/150, Train Acc: 54.09%, Val Acc: 47.89%, Test Acc: 41.55%
# Epoch 90/150, Train Loss: 1.6604, Val Loss: 2.0981, Test Loss: 2.4066
# Epoch 92: Learning Rate: [0.001]
# Epoch 91/150, Train Acc: 54.83%, Val Acc: 47.12%, Test Acc: 40.74%
# Epoch 91/150, Train Loss: 1.6317, Val Loss: 2.1312, Test Loss: 2.4215
# Epoch 93: Learning Rate: [0.001]
# Epoch 92/150, Train Acc: 54.46%, Val Acc: 47.49%, Test Acc: 40.50%
# Epoch 92/150, Train Loss: 1.6375, Val Loss: 2.1305, Test Loss: 2.4486
# Epoch 94: Learning Rate: [0.001]
# Epoch 93/150, Train Acc: 53.82%, Val Acc: 48.28%, Test Acc: 41.99%
# Epoch 93/150, Train Loss: 1.6662, Val Loss: 2.0741, Test Loss: 2.3783
# Epoch 95: Learning Rate: [0.001]
# Epoch 94/150, Train Acc: 54.48%, Val Acc: 47.63%, Test Acc: 41.09%
# Epoch 94/150, Train Loss: 1.6420, Val Loss: 2.1125, Test Loss: 2.3881
# Epoch 96: Learning Rate: [0.001]
# Epoch 95/150, Train Acc: 54.82%, Val Acc: 47.43%, Test Acc: 40.54%
# Epoch 95/150, Train Loss: 1.6338, Val Loss: 2.1706, Test Loss: 2.5008
# Epoch 97: Learning Rate: [0.001]
# Epoch 96/150, Train Acc: 54.71%, Val Acc: 47.59%, Test Acc: 41.18%
# Epoch 96/150, Train Loss: 1.6345, Val Loss: 2.1153, Test Loss: 2.4013
# Epoch 98: Learning Rate: [0.001]
# Epoch 97/150, Train Acc: 54.84%, Val Acc: 47.45%, Test Acc: 40.51%
# Epoch 97/150, Train Loss: 1.6300, Val Loss: 2.1297, Test Loss: 2.4132
# Epoch 99: Learning Rate: [0.001]
# Epoch 98/150, Train Acc: 55.42%, Val Acc: 47.30%, Test Acc: 40.44%
# Epoch 98/150, Train Loss: 1.6188, Val Loss: 2.1383, Test Loss: 2.4302
# Epoch 100: Learning Rate: [0.001]
# Epoch 99/150, Train Acc: 55.26%, Val Acc: 48.02%, Test Acc: 40.90%
# Epoch 99/150, Train Loss: 1.6203, Val Loss: 2.1516, Test Loss: 2.4878
# Epoch 101: Learning Rate: [0.001]
# Checkpoint saved at epoch 100: ./checkpoint_epoch_100.pth
# Epoch 100/150, Train Acc: 55.06%, Val Acc: 47.61%, Test Acc: 40.80%
# Epoch 100/150, Train Loss: 1.6176, Val Loss: 2.1386, Test Loss: 2.4387
# Epoch 102: Learning Rate: [0.001]
# Epoch 101/150, Train Acc: 55.26%, Val Acc: 47.56%, Test Acc: 40.57%
# Epoch 101/150, Train Loss: 1.6094, Val Loss: 2.1521, Test Loss: 2.4774
# Epoch 103: Learning Rate: [0.001]
# Epoch 102/150, Train Acc: 55.36%, Val Acc: 47.69%, Test Acc: 41.33%
# Epoch 102/150, Train Loss: 1.6063, Val Loss: 2.1453, Test Loss: 2.4373
# Epoch 104: Learning Rate: [0.001]
# Epoch 103/150, Train Acc: 55.38%, Val Acc: 47.29%, Test Acc: 41.14%
# Epoch 103/150, Train Loss: 1.6076, Val Loss: 2.1601, Test Loss: 2.4437
# Epoch 105: Learning Rate: [0.001]
# Epoch 104/150, Train Acc: 55.18%, Val Acc: 48.05%, Test Acc: 42.11%
# Epoch 104/150, Train Loss: 1.6106, Val Loss: 2.1163, Test Loss: 2.3939
# Epoch 106: Learning Rate: [0.001]
# Epoch 105/150, Train Acc: 55.56%, Val Acc: 48.42%, Test Acc: 40.49%
# Epoch 105/150, Train Loss: 1.6004, Val Loss: 2.1202, Test Loss: 2.5007
# Epoch 107: Learning Rate: [0.001]
# Epoch 106/150, Train Acc: 55.34%, Val Acc: 48.20%, Test Acc: 42.11%
# Epoch 106/150, Train Loss: 1.6029, Val Loss: 2.1384, Test Loss: 2.4021
# Epoch 108: Learning Rate: [0.001]
# Epoch 107/150, Train Acc: 55.50%, Val Acc: 48.49%, Test Acc: 41.70%
# Epoch 107/150, Train Loss: 1.5968, Val Loss: 2.1315, Test Loss: 2.4448
# Epoch 109: Learning Rate: [0.001]
# Epoch 108/150, Train Acc: 55.62%, Val Acc: 48.46%, Test Acc: 41.00%
# Epoch 108/150, Train Loss: 1.5910, Val Loss: 2.1421, Test Loss: 2.4333
# Epoch 110: Learning Rate: [0.001]
# Epoch 109/150, Train Acc: 55.59%, Val Acc: 47.64%, Test Acc: 41.25%
# Epoch 109/150, Train Loss: 1.5884, Val Loss: 2.1032, Test Loss: 2.4164
# Epoch 111: Learning Rate: [0.001]
# Checkpoint saved at epoch 110: ./checkpoint_epoch_110.pth
# Epoch 110/150, Train Acc: 56.27%, Val Acc: 48.09%, Test Acc: 40.65%
# Epoch 110/150, Train Loss: 1.5831, Val Loss: 2.1375, Test Loss: 2.4843
# Epoch 112: Learning Rate: [0.001]
# Epoch 111/150, Train Acc: 56.02%, Val Acc: 48.02%, Test Acc: 42.18%
# Epoch 111/150, Train Loss: 1.5795, Val Loss: 2.1505, Test Loss: 2.3871
# Epoch 113: Learning Rate: [0.001]
# Epoch 112/150, Train Acc: 55.84%, Val Acc: 48.30%, Test Acc: 41.56%
# Epoch 112/150, Train Loss: 1.5902, Val Loss: 2.1684, Test Loss: 2.4480
# Epoch 114: Learning Rate: [0.001]
# Epoch 113/150, Train Acc: 56.40%, Val Acc: 47.86%, Test Acc: 40.89%
# Epoch 113/150, Train Loss: 1.5705, Val Loss: 2.1619, Test Loss: 2.4688
# Epoch 115: Learning Rate: [0.001]
# Epoch 114/150, Train Acc: 55.86%, Val Acc: 48.21%, Test Acc: 41.08%
# Epoch 114/150, Train Loss: 1.5842, Val Loss: 2.1486, Test Loss: 2.4690
# Epoch 116: Learning Rate: [0.001]
# Epoch 115/150, Train Acc: 56.21%, Val Acc: 47.71%, Test Acc: 41.36%
# Epoch 115/150, Train Loss: 1.5591, Val Loss: 2.1899, Test Loss: 2.4419
# Epoch 117: Learning Rate: [0.001]
# Epoch 116/150, Train Acc: 56.63%, Val Acc: 48.98%, Test Acc: 40.97%
# Epoch 116/150, Train Loss: 1.5557, Val Loss: 2.1612, Test Loss: 2.4507
# Epoch 118: Learning Rate: [0.001]
# Epoch 117/150, Train Acc: 56.01%, Val Acc: 47.35%, Test Acc: 40.70%
# Epoch 117/150, Train Loss: 1.5762, Val Loss: 2.1493, Test Loss: 2.4750
# Epoch 119: Learning Rate: [0.001]
# Epoch 118/150, Train Acc: 56.29%, Val Acc: 48.65%, Test Acc: 41.91%
# Epoch 118/150, Train Loss: 1.5662, Val Loss: 2.1074, Test Loss: 2.3899
# Epoch 120: Learning Rate: [0.001]
# Epoch 119/150, Train Acc: 56.58%, Val Acc: 47.80%, Test Acc: 41.36%
# Epoch 119/150, Train Loss: 1.5636, Val Loss: 2.1913, Test Loss: 2.4470
# Epoch 121: Learning Rate: [0.001]
# Checkpoint saved at epoch 120: ./checkpoint_epoch_120.pth
# Epoch 120/150, Train Acc: 56.55%, Val Acc: 48.12%, Test Acc: 42.35%
# Epoch 120/150, Train Loss: 1.5574, Val Loss: 2.1235, Test Loss: 2.3836
# Epoch 122: Learning Rate: [0.001]
# Epoch 121/150, Train Acc: 56.91%, Val Acc: 48.14%, Test Acc: 40.99%
# Epoch 121/150, Train Loss: 1.5348, Val Loss: 2.1383, Test Loss: 2.4198
# Epoch 123: Learning Rate: [0.001]
# Epoch 122/150, Train Acc: 56.82%, Val Acc: 48.43%, Test Acc: 40.97%
# Epoch 122/150, Train Loss: 1.5461, Val Loss: 2.1358, Test Loss: 2.4670
# Epoch 124: Learning Rate: [0.001]
# Epoch 123/150, Train Acc: 56.47%, Val Acc: 47.69%, Test Acc: 41.21%
# Epoch 123/150, Train Loss: 1.5554, Val Loss: 2.1569, Test Loss: 2.4169
# Epoch 125: Learning Rate: [0.001]
# Epoch 124/150, Train Acc: 56.97%, Val Acc: 47.88%, Test Acc: 40.48%
# Epoch 124/150, Train Loss: 1.5458, Val Loss: 2.1458, Test Loss: 2.4844
# Epoch 126: Learning Rate: [0.001]
# Epoch 125/150, Train Acc: 56.17%, Val Acc: 48.15%, Test Acc: 41.33%
# Epoch 125/150, Train Loss: 1.5703, Val Loss: 2.1759, Test Loss: 2.4386
# Epoch 127: Learning Rate: [0.001]
# Epoch 126/150, Train Acc: 56.44%, Val Acc: 48.38%, Test Acc: 41.44%
# Epoch 126/150, Train Loss: 1.5466, Val Loss: 2.1341, Test Loss: 2.4108
# Epoch 128: Learning Rate: [0.001]
# Epoch 127/150, Train Acc: 57.28%, Val Acc: 48.31%, Test Acc: 41.20%
# Epoch 127/150, Train Loss: 1.5334, Val Loss: 2.1448, Test Loss: 2.4142
# Epoch 129: Learning Rate: [0.001]
# Epoch 128/150, Train Acc: 56.79%, Val Acc: 48.09%, Test Acc: 41.11%
# Epoch 128/150, Train Loss: 1.5451, Val Loss: 2.1482, Test Loss: 2.4546
# Epoch 130: Learning Rate: [0.001]
# Epoch 129/150, Train Acc: 56.98%, Val Acc: 48.43%, Test Acc: 41.71%
# Epoch 129/150, Train Loss: 1.5392, Val Loss: 2.1280, Test Loss: 2.4347
# Epoch 131: Learning Rate: [0.001]
# Checkpoint saved at epoch 130: ./checkpoint_epoch_130.pth
# Epoch 130/150, Train Acc: 56.97%, Val Acc: 48.45%, Test Acc: 41.67%
# Epoch 130/150, Train Loss: 1.5198, Val Loss: 2.1580, Test Loss: 2.4522
# Epoch 132: Learning Rate: [0.001]
# Epoch 131/150, Train Acc: 57.01%, Val Acc: 47.87%, Test Acc: 41.77%
# Epoch 131/150, Train Loss: 1.5331, Val Loss: 2.1785, Test Loss: 2.4057
# Epoch 133: Learning Rate: [0.001]
# Epoch 132/150, Train Acc: 57.69%, Val Acc: 48.07%, Test Acc: 42.36%
# Epoch 132/150, Train Loss: 1.5268, Val Loss: 2.1247, Test Loss: 2.4102
# Epoch 134: Learning Rate: [0.001]
# Epoch 133/150, Train Acc: 57.16%, Val Acc: 48.75%, Test Acc: 41.92%
# Epoch 133/150, Train Loss: 1.5210, Val Loss: 2.1482, Test Loss: 2.4475
# Epoch 135: Learning Rate: [0.001]
# Epoch 134/150, Train Acc: 57.53%, Val Acc: 48.81%, Test Acc: 41.86%
# Epoch 134/150, Train Loss: 1.5134, Val Loss: 2.0967, Test Loss: 2.3965
# Epoch 136: Learning Rate: [0.001]
# Epoch 135/150, Train Acc: 57.17%, Val Acc: 47.88%, Test Acc: 41.35%
# Epoch 135/150, Train Loss: 1.5272, Val Loss: 2.1306, Test Loss: 2.3970
# Epoch 137: Learning Rate: [0.001]
# Epoch 136/150, Train Acc: 57.34%, Val Acc: 48.42%, Test Acc: 42.01%
# Epoch 136/150, Train Loss: 1.5200, Val Loss: 2.1406, Test Loss: 2.4178
# Epoch 138: Learning Rate: [0.001]
# Epoch 137/150, Train Acc: 57.41%, Val Acc: 48.81%, Test Acc: 41.10%
# Epoch 137/150, Train Loss: 1.5210, Val Loss: 2.1627, Test Loss: 2.4817
# Epoch 139: Learning Rate: [0.001]
# Epoch 138/150, Train Acc: 57.54%, Val Acc: 48.40%, Test Acc: 42.63%
# Epoch 138/150, Train Loss: 1.5063, Val Loss: 2.1472, Test Loss: 2.4237
# Epoch 140: Learning Rate: [0.001]
# Epoch 139/150, Train Acc: 57.82%, Val Acc: 48.78%, Test Acc: 40.54%
# Epoch 139/150, Train Loss: 1.5038, Val Loss: 2.1647, Test Loss: 2.5409
# Epoch 141: Learning Rate: [0.001]
# Checkpoint saved at epoch 140: ./checkpoint_epoch_140.pth
# Epoch 140/150, Train Acc: 57.64%, Val Acc: 48.23%, Test Acc: 41.31%
# Epoch 140/150, Train Loss: 1.5145, Val Loss: 2.1910, Test Loss: 2.4377
# Epoch 142: Learning Rate: [0.001]
# Epoch 141/150, Train Acc: 57.76%, Val Acc: 47.60%, Test Acc: 41.52%
# Epoch 141/150, Train Loss: 1.5111, Val Loss: 2.1676, Test Loss: 2.4356
# Epoch 143: Learning Rate: [0.001]
# Epoch 142/150, Train Acc: 58.04%, Val Acc: 48.26%, Test Acc: 41.16%
# Epoch 142/150, Train Loss: 1.4979, Val Loss: 2.1374, Test Loss: 2.4674
# Epoch 144: Learning Rate: [0.001]
# Epoch 143/150, Train Acc: 57.69%, Val Acc: 47.73%, Test Acc: 41.38%
# Epoch 143/150, Train Loss: 1.5036, Val Loss: 2.1757, Test Loss: 2.4625
# Epoch 145: Learning Rate: [0.001]
# Epoch 144/150, Train Acc: 57.75%, Val Acc: 47.94%, Test Acc: 40.09%
# Epoch 144/150, Train Loss: 1.5065, Val Loss: 2.1832, Test Loss: 2.4939
# Epoch 146: Learning Rate: [0.001]
# Epoch 145/150, Train Acc: 57.56%, Val Acc: 48.40%, Test Acc: 42.35%
# Epoch 145/150, Train Loss: 1.5066, Val Loss: 2.1045, Test Loss: 2.3643
# Epoch 147: Learning Rate: [0.001]
# Epoch 146/150, Train Acc: 58.47%, Val Acc: 48.67%, Test Acc: 40.61%
# Epoch 146/150, Train Loss: 1.4873, Val Loss: 2.1932, Test Loss: 2.5545
# Epoch 148: Learning Rate: [0.001]
# Epoch 147/150, Train Acc: 58.06%, Val Acc: 47.94%, Test Acc: 40.74%
# Epoch 147/150, Train Loss: 1.5008, Val Loss: 2.1952, Test Loss: 2.4936
# Epoch 149: Learning Rate: [0.001]
# Epoch 148/150, Train Acc: 58.32%, Val Acc: 48.19%, Test Acc: 41.86%
# Epoch 148/150, Train Loss: 1.4844, Val Loss: 2.1466, Test Loss: 2.4198
# Epoch 150: Learning Rate: [0.001]
# Epoch 149/150, Train Acc: 58.02%, Val Acc: 48.20%, Test Acc: 42.02%
# Epoch 149/150, Train Loss: 1.4929, Val Loss: 2.1836, Test Loss: 2.4320
# Epoch 151: Learning Rate: [0.001]
# Checkpoint saved at epoch 150: ./checkpoint_epoch_150.pth
# Epoch 150/150, Train Acc: 57.97%, Val Acc: 48.40%, Test Acc: 41.64%
# Epoch 150/150, Train Loss: 1.4883, Val Loss: 2.1608, Test Loss: 2.4393

# %%
# %run large_batch_training.py --optimizer LARS --batch-size 128 --weight-decay 4e-4
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# --- Train with LARS ---

# %%
# %run large_batch_training.py --optimizer LAMB --batch-size 128 --weight-decay 1e-2
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# --- Train with LAMB ---
