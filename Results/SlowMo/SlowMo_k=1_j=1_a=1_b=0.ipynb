# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
# Alpha slow learning rate a=1 best
# Beta slow momentum
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
#warmup_epochs = 5

alpha = 1.0  # Slow learning rate scaling factor
beta = 0  # Slow momentum factor

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate for each k: {learning_rate:.5f}")
#lr_warmup=learning_rate
# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]


with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs) for optimizer in optimizers]

u_buffer = [torch.zeros_like(param) for param in nets[0].parameters()]  # Momentum buffer

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")
    #if epoch < warmup_epochs: #lr for buffer update during warmup
            #w_factor = (epoch + 1) / warmup_epochs
            #lr_warmup = w_factor * learning_rate
    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch): #outer loop

        #x(t,0)
        iter_params = [torch.zeros_like(param) for param in nets[0].parameters()]
        for param, g_param in zip(iter_params, nets[0].parameters()):
                    param.data.copy_(g_param)
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0

            # Perform J local step before synchronization
            for j in range(J): #inner loop
                      try:
                          # Get a batch from the current worker's shard using next()
                          images, labels = next(shard_iterators[k])
                          images, labels = images.to(device), labels.to(device)  # Move to device
                          optimizers[k].zero_grad()
                          outputs = nets[k](images)
                          loss = criterion(outputs, labels)
                          loss.backward()
                          optimizers[k].step()
                          # Calculate train loss and accuracy
                          train_loss += loss.item() * labels.size(0)
                          _, predicted = outputs.max(1)
                          total_train += labels.size(0)
                          correct_train += predicted.eq(labels).sum().item()

                      except StopIteration:
                          # If the iterator has exhausted the data, restart the iterator
                          shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                          images, labels = next(shard_iterators[k]) # Resume from the next batch
                          images, labels = images.to(device), labels.to(device)
                          # Perform optimization step
                          optimizers[k].zero_grad()
                          outputs = nets[k](images)
                          loss = criterion(outputs, labels)
                          loss.backward()
                          optimizers[k].step()
                          # Calculate train loss and accuracy
                          train_loss += loss.item() * labels.size(0)
                          _, predicted = outputs.max(1)
                          total_train += labels.size(0)
                          correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train


         # Synchronization (SLOWMO Algothm 1 - paper 21)
        with torch.no_grad():
            global_params = [torch.zeros_like(param) for param in nets[0].parameters()]
            #x(t, tau)
            for net in nets:
                for global_param, local_param in zip(global_params, net.parameters()):
                    global_param += local_param
            for global_param in global_params:
                global_param /= K

            for param, g_param, u_param in zip(iter_params, global_params, u_buffer):
                #if epoch < warmup_epochs:
                  #  u_param.mul_(beta).add_((param - g_param) / lr_warmup)
                 #   g_param.sub_(alpha * lr_warmup * u_param)

                #else: #Sync after warmup
                    #print(f"{optimizers[0].param_groups[0]['lr']}  {optimizers[1].param_groups[0]['lr']}")
                    lr_sched = optimizers[0].param_groups[0]['lr'] #optimizer lr
                    u_param.mul_(beta).add_((param - g_param) / lr_sched)
                    #g_param.sub_(alpha * lr_sched * u_param)
                    g_param.copy_(param - alpha * lr_sched * u_param)

            for net in nets:
                for param, g_param in zip(net.parameters(), global_params):
                    param.data.copy_(g_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        #if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
        #else:
         #   warmup_factor = (epoch + 1) / warmup_epochs
          #  lr = warmup_factor * learning_rate
           # for optimizer in optimizers:
            #    for param_group in optimizer.param_groups:
             #       param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 1 --j 1
# Out:
# Training with K=1, J=1
# Global iteration per epoch: 782
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:03<00:00, 45.8MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate for each k: 0.00100
# Epoch 1/150: Test Loss: 4.5694, Test Accuracy: 2.04%
#     Worker 0: Train Loss: 4.5956, Train Accuracy: 1.37%
# Epoch 2/150: Test Loss: 4.1203, Test Accuracy: 7.20%
#     Worker 0: Train Loss: 4.4004, Train Accuracy: 4.01%
# Epoch 3/150: Test Loss: 3.8978, Test Accuracy: 10.12%
#     Worker 0: Train Loss: 4.0309, Train Accuracy: 8.50%
# Epoch 4/150: Test Loss: 3.7662, Test Accuracy: 12.52%
#     Worker 0: Train Loss: 3.8655, Train Accuracy: 11.04%
# Epoch 5/150: Test Loss: 3.6326, Test Accuracy: 14.76%
#     Worker 0: Train Loss: 3.7430, Train Accuracy: 13.06%
# Epoch 6/150: Test Loss: 3.5277, Test Accuracy: 16.43%
#     Worker 0: Train Loss: 3.6272, Train Accuracy: 14.71%
# Epoch 7/150: Test Loss: 3.4326, Test Accuracy: 18.58%
#     Worker 0: Train Loss: 3.5207, Train Accuracy: 16.71%
# Epoch 8/150: Test Loss: 3.3168, Test Accuracy: 20.23%
#     Worker 0: Train Loss: 3.4107, Train Accuracy: 18.47%
# Epoch 9/150: Test Loss: 3.2795, Test Accuracy: 21.14%
#     Worker 0: Train Loss: 3.3081, Train Accuracy: 20.30%
# Epoch 10/150: Test Loss: 3.1602, Test Accuracy: 23.16%
#     Worker 0: Train Loss: 3.2301, Train Accuracy: 21.76%
# Epoch 11/150: Test Loss: 3.0678, Test Accuracy: 25.14%
#     Worker 0: Train Loss: 3.1578, Train Accuracy: 23.07%
# Epoch 12/150: Test Loss: 2.9743, Test Accuracy: 26.71%
#     Worker 0: Train Loss: 3.0829, Train Accuracy: 24.32%
# Epoch 13/150: Test Loss: 2.9215, Test Accuracy: 27.91%
#     Worker 0: Train Loss: 3.0248, Train Accuracy: 25.17%
# Epoch 14/150: Test Loss: 2.8490, Test Accuracy: 29.17%
#     Worker 0: Train Loss: 2.9647, Train Accuracy: 26.52%
# Epoch 15/150: Test Loss: 2.8114, Test Accuracy: 30.53%
#     Worker 0: Train Loss: 2.9057, Train Accuracy: 27.61%
# Epoch 16/150: Test Loss: 2.7321, Test Accuracy: 31.35%
#     Worker 0: Train Loss: 2.8468, Train Accuracy: 28.86%
# Epoch 17/150: Test Loss: 2.7010, Test Accuracy: 31.62%
#     Worker 0: Train Loss: 2.7820, Train Accuracy: 29.94%
# Epoch 18/150: Test Loss: 2.6927, Test Accuracy: 31.97%
#     Worker 0: Train Loss: 2.7315, Train Accuracy: 31.18%
# Epoch 19/150: Test Loss: 2.5664, Test Accuracy: 34.77%
#     Worker 0: Train Loss: 2.6768, Train Accuracy: 32.17%
# Epoch 20/150: Test Loss: 2.5525, Test Accuracy: 34.59%
#     Worker 0: Train Loss: 2.6296, Train Accuracy: 33.16%
# Epoch 21/150: Test Loss: 2.5292, Test Accuracy: 35.63%
#     Worker 0: Train Loss: 2.5916, Train Accuracy: 33.89%
# Epoch 22/150: Test Loss: 2.4617, Test Accuracy: 36.93%
#     Worker 0: Train Loss: 2.5468, Train Accuracy: 34.86%
# Epoch 23/150: Test Loss: 2.4445, Test Accuracy: 37.25%
#     Worker 0: Train Loss: 2.5094, Train Accuracy: 35.66%
# Epoch 24/150: Test Loss: 2.4510, Test Accuracy: 37.27%
#     Worker 0: Train Loss: 2.4724, Train Accuracy: 36.33%
# Epoch 25/150: Test Loss: 2.3591, Test Accuracy: 39.45%
#     Worker 0: Train Loss: 2.4462, Train Accuracy: 36.67%
# Epoch 26/150: Test Loss: 2.3602, Test Accuracy: 39.10%
#     Worker 0: Train Loss: 2.4095, Train Accuracy: 37.47%
# Epoch 27/150: Test Loss: 2.3255, Test Accuracy: 40.00%
#     Worker 0: Train Loss: 2.3759, Train Accuracy: 38.20%
# Epoch 28/150: Test Loss: 2.3180, Test Accuracy: 39.81%
#     Worker 0: Train Loss: 2.3486, Train Accuracy: 38.78%
# Epoch 29/150: Test Loss: 2.2870, Test Accuracy: 40.61%
#     Worker 0: Train Loss: 2.3195, Train Accuracy: 39.56%
# Epoch 30/150: Test Loss: 2.2692, Test Accuracy: 41.06%
#     Worker 0: Train Loss: 2.2885, Train Accuracy: 40.16%
# Epoch 31/150: Test Loss: 2.2733, Test Accuracy: 41.00%
#     Worker 0: Train Loss: 2.2676, Train Accuracy: 40.59%
# Epoch 32/150: Test Loss: 2.2639, Test Accuracy: 41.03%
#     Worker 0: Train Loss: 2.2368, Train Accuracy: 41.26%
# Epoch 33/150: Test Loss: 2.2363, Test Accuracy: 41.33%
#     Worker 0: Train Loss: 2.2218, Train Accuracy: 41.69%
# Epoch 34/150: Test Loss: 2.2069, Test Accuracy: 42.90%
#     Worker 0: Train Loss: 2.1925, Train Accuracy: 41.72%
# Epoch 35/150: Test Loss: 2.2054, Test Accuracy: 42.73%
#     Worker 0: Train Loss: 2.1722, Train Accuracy: 42.61%
# Epoch 36/150: Test Loss: 2.1756, Test Accuracy: 43.46%
#     Worker 0: Train Loss: 2.1550, Train Accuracy: 42.95%
# Epoch 37/150: Test Loss: 2.1782, Test Accuracy: 42.95%
#     Worker 0: Train Loss: 2.1228, Train Accuracy: 43.63%
# Epoch 38/150: Test Loss: 2.1818, Test Accuracy: 43.10%
#     Worker 0: Train Loss: 2.1042, Train Accuracy: 44.00%
# Epoch 39/150: Test Loss: 2.1526, Test Accuracy: 43.47%
#     Worker 0: Train Loss: 2.0831, Train Accuracy: 44.71%
# Epoch 40/150: Test Loss: 2.1376, Test Accuracy: 43.99%
#     Worker 0: Train Loss: 2.0620, Train Accuracy: 45.04%
# Epoch 41/150: Test Loss: 2.1517, Test Accuracy: 44.08%
#     Worker 0: Train Loss: 2.0439, Train Accuracy: 45.57%
# Epoch 42/150: Test Loss: 2.1298, Test Accuracy: 44.13%
#     Worker 0: Train Loss: 2.0307, Train Accuracy: 45.91%
# Epoch 43/150: Test Loss: 2.1016, Test Accuracy: 44.72%
#     Worker 0: Train Loss: 2.0080, Train Accuracy: 46.13%
# Epoch 44/150: Test Loss: 2.0891, Test Accuracy: 45.28%
#     Worker 0: Train Loss: 1.9913, Train Accuracy: 46.53%
# Epoch 45/150: Test Loss: 2.0922, Test Accuracy: 45.20%
#     Worker 0: Train Loss: 1.9735, Train Accuracy: 47.13%
# Epoch 46/150: Test Loss: 2.0699, Test Accuracy: 45.43%
#     Worker 0: Train Loss: 1.9553, Train Accuracy: 47.29%
# Epoch 47/150: Test Loss: 2.0648, Test Accuracy: 46.05%
#     Worker 0: Train Loss: 1.9329, Train Accuracy: 47.87%
# Epoch 48/150: Test Loss: 2.0535, Test Accuracy: 46.14%
#     Worker 0: Train Loss: 1.9153, Train Accuracy: 48.34%
# Epoch 49/150: Test Loss: 2.0611, Test Accuracy: 46.17%
#     Worker 0: Train Loss: 1.9022, Train Accuracy: 48.68%
# Epoch 50/150: Test Loss: 2.0740, Test Accuracy: 45.96%
#     Worker 0: Train Loss: 1.8847, Train Accuracy: 49.38%
# Epoch 51/150: Test Loss: 2.0371, Test Accuracy: 46.78%
#     Worker 0: Train Loss: 1.8660, Train Accuracy: 49.35%
# Epoch 52/150: Test Loss: 2.0291, Test Accuracy: 46.82%
#     Worker 0: Train Loss: 1.8572, Train Accuracy: 49.65%
# Epoch 53/150: Test Loss: 2.0307, Test Accuracy: 47.08%
#     Worker 0: Train Loss: 1.8328, Train Accuracy: 50.26%
# Epoch 54/150: Test Loss: 2.0201, Test Accuracy: 47.03%
#     Worker 0: Train Loss: 1.8178, Train Accuracy: 50.50%
# Epoch 55/150: Test Loss: 2.0352, Test Accuracy: 47.21%
#     Worker 0: Train Loss: 1.8078, Train Accuracy: 51.00%
# Epoch 56/150: Test Loss: 2.0333, Test Accuracy: 46.45%
#     Worker 0: Train Loss: 1.7964, Train Accuracy: 51.06%
# Epoch 57/150: Test Loss: 1.9965, Test Accuracy: 47.57%
#     Worker 0: Train Loss: 1.7841, Train Accuracy: 51.40%
# Epoch 58/150: Test Loss: 1.9946, Test Accuracy: 47.59%
#     Worker 0: Train Loss: 1.7739, Train Accuracy: 51.36%
# Epoch 59/150: Test Loss: 2.0211, Test Accuracy: 47.38%
#     Worker 0: Train Loss: 1.7494, Train Accuracy: 52.28%
# Epoch 60/150: Test Loss: 2.0187, Test Accuracy: 47.43%
#     Worker 0: Train Loss: 1.7370, Train Accuracy: 52.19%
# Epoch 61/150: Test Loss: 1.9867, Test Accuracy: 47.85%
#     Worker 0: Train Loss: 1.7257, Train Accuracy: 52.81%
# Epoch 62/150: Test Loss: 1.9966, Test Accuracy: 48.01%
#     Worker 0: Train Loss: 1.7107, Train Accuracy: 53.08%
# Epoch 63/150: Test Loss: 2.0082, Test Accuracy: 47.68%
#     Worker 0: Train Loss: 1.6968, Train Accuracy: 53.60%
# Epoch 64/150: Test Loss: 1.9862, Test Accuracy: 48.27%
#     Worker 0: Train Loss: 1.6891, Train Accuracy: 53.50%
# Epoch 65/150: Test Loss: 1.9786, Test Accuracy: 48.57%
#     Worker 0: Train Loss: 1.6749, Train Accuracy: 53.88%
# Epoch 66/150: Test Loss: 1.9921, Test Accuracy: 48.13%
#     Worker 0: Train Loss: 1.6667, Train Accuracy: 54.05%
# Epoch 67/150: Test Loss: 1.9746, Test Accuracy: 48.45%
#     Worker 0: Train Loss: 1.6489, Train Accuracy: 54.45%
# Epoch 68/150: Test Loss: 1.9817, Test Accuracy: 48.52%
#     Worker 0: Train Loss: 1.6411, Train Accuracy: 54.76%
# Epoch 69/150: Test Loss: 1.9593, Test Accuracy: 48.84%
#     Worker 0: Train Loss: 1.6303, Train Accuracy: 54.94%
# Epoch 70/150: Test Loss: 1.9686, Test Accuracy: 49.05%
#     Worker 0: Train Loss: 1.6170, Train Accuracy: 55.39%
# Epoch 71/150: Test Loss: 1.9606, Test Accuracy: 49.47%
#     Worker 0: Train Loss: 1.6057, Train Accuracy: 55.39%
# Epoch 72/150: Test Loss: 1.9449, Test Accuracy: 49.64%
#     Worker 0: Train Loss: 1.5924, Train Accuracy: 55.82%
# Epoch 73/150: Test Loss: 1.9671, Test Accuracy: 49.75%
#     Worker 0: Train Loss: 1.5822, Train Accuracy: 56.07%
# Epoch 74/150: Test Loss: 1.9609, Test Accuracy: 49.44%
#     Worker 0: Train Loss: 1.5640, Train Accuracy: 56.54%
# Epoch 75/150: Test Loss: 1.9461, Test Accuracy: 49.71%
#     Worker 0: Train Loss: 1.5656, Train Accuracy: 56.52%
# Epoch 76/150: Test Loss: 1.9651, Test Accuracy: 48.91%
#     Worker 0: Train Loss: 1.5471, Train Accuracy: 57.04%
# Epoch 77/150: Test Loss: 1.9456, Test Accuracy: 49.72%
#     Worker 0: Train Loss: 1.5379, Train Accuracy: 57.30%
# Epoch 78/150: Test Loss: 1.9636, Test Accuracy: 49.52%
#     Worker 0: Train Loss: 1.5302, Train Accuracy: 57.43%
# Epoch 79/150: Test Loss: 1.9535, Test Accuracy: 49.42%
#     Worker 0: Train Loss: 1.5276, Train Accuracy: 57.56%
# Epoch 80/150: Test Loss: 1.9449, Test Accuracy: 49.52%
#     Worker 0: Train Loss: 1.5178, Train Accuracy: 57.61%
# Epoch 81/150: Test Loss: 1.9527, Test Accuracy: 49.68%
#     Worker 0: Train Loss: 1.5004, Train Accuracy: 58.26%
# Epoch 82/150: Test Loss: 1.9433, Test Accuracy: 49.49%
#     Worker 0: Train Loss: 1.4892, Train Accuracy: 58.51%
# Epoch 83/150: Test Loss: 1.9379, Test Accuracy: 50.64%
#     Worker 0: Train Loss: 1.4798, Train Accuracy: 58.57%
# Epoch 84/150: Test Loss: 1.9494, Test Accuracy: 49.71%
#     Worker 0: Train Loss: 1.4698, Train Accuracy: 58.92%
# Epoch 85/150: Test Loss: 1.9425, Test Accuracy: 50.09%
#     Worker 0: Train Loss: 1.4614, Train Accuracy: 59.05%
# Epoch 86/150: Test Loss: 1.9414, Test Accuracy: 50.44%
#     Worker 0: Train Loss: 1.4597, Train Accuracy: 59.19%
# Epoch 87/150: Test Loss: 1.9322, Test Accuracy: 50.77%
#     Worker 0: Train Loss: 1.4472, Train Accuracy: 59.42%
# Epoch 88/150: Test Loss: 1.9363, Test Accuracy: 50.29%
#     Worker 0: Train Loss: 1.4430, Train Accuracy: 59.40%
# Epoch 89/150: Test Loss: 1.9397, Test Accuracy: 50.19%
#     Worker 0: Train Loss: 1.4301, Train Accuracy: 60.15%
# Epoch 90/150: Test Loss: 1.9315, Test Accuracy: 50.19%
#     Worker 0: Train Loss: 1.4257, Train Accuracy: 60.04%
# Epoch 91/150: Test Loss: 1.9387, Test Accuracy: 50.57%
#     Worker 0: Train Loss: 1.4119, Train Accuracy: 60.33%
# Epoch 92/150: Test Loss: 1.9422, Test Accuracy: 50.54%
#     Worker 0: Train Loss: 1.4024, Train Accuracy: 60.52%
# Epoch 93/150: Test Loss: 1.9380, Test Accuracy: 50.59%
#     Worker 0: Train Loss: 1.3936, Train Accuracy: 60.83%
# Epoch 94/150: Test Loss: 1.9575, Test Accuracy: 50.36%
#     Worker 0: Train Loss: 1.3890, Train Accuracy: 60.88%
# Epoch 95/150: Test Loss: 1.9552, Test Accuracy: 50.13%
#     Worker 0: Train Loss: 1.3767, Train Accuracy: 61.52%
# Epoch 96/150: Test Loss: 1.9337, Test Accuracy: 50.54%
#     Worker 0: Train Loss: 1.3725, Train Accuracy: 61.23%
# Epoch 97/150: Test Loss: 1.9355, Test Accuracy: 50.86%
#     Worker 0: Train Loss: 1.3616, Train Accuracy: 61.52%
# Epoch 98/150: Test Loss: 1.9314, Test Accuracy: 50.80%
#     Worker 0: Train Loss: 1.3561, Train Accuracy: 61.76%
# Epoch 99/150: Test Loss: 1.9328, Test Accuracy: 50.88%
#     Worker 0: Train Loss: 1.3525, Train Accuracy: 61.79%
# Epoch 100/150: Test Loss: 1.9396, Test Accuracy: 50.82%
#     Worker 0: Train Loss: 1.3449, Train Accuracy: 62.19%
# Epoch 101/150: Test Loss: 1.9432, Test Accuracy: 50.72%
#     Worker 0: Train Loss: 1.3405, Train Accuracy: 61.99%
# Epoch 102/150: Test Loss: 1.9282, Test Accuracy: 51.06%
#     Worker 0: Train Loss: 1.3323, Train Accuracy: 62.47%
# Epoch 103/150: Test Loss: 1.9386, Test Accuracy: 50.59%
#     Worker 0: Train Loss: 1.3185, Train Accuracy: 62.65%
# Epoch 104/150: Test Loss: 1.9414, Test Accuracy: 51.10%
#     Worker 0: Train Loss: 1.3189, Train Accuracy: 62.60%
# Epoch 105/150: Test Loss: 1.9392, Test Accuracy: 51.13%
#     Worker 0: Train Loss: 1.3181, Train Accuracy: 62.76%
# Epoch 106/150: Test Loss: 1.9411, Test Accuracy: 50.97%
#     Worker 0: Train Loss: 1.3040, Train Accuracy: 63.25%
# Epoch 107/150: Test Loss: 1.9294, Test Accuracy: 51.51%
#     Worker 0: Train Loss: 1.3067, Train Accuracy: 62.98%
# Epoch 108/150: Test Loss: 1.9415, Test Accuracy: 51.03%
#     Worker 0: Train Loss: 1.2936, Train Accuracy: 63.36%
# Epoch 109/150: Test Loss: 1.9339, Test Accuracy: 51.24%
#     Worker 0: Train Loss: 1.2905, Train Accuracy: 63.45%
# Epoch 110/150: Test Loss: 1.9343, Test Accuracy: 51.28%
#     Worker 0: Train Loss: 1.2838, Train Accuracy: 63.80%
# Epoch 111/150: Test Loss: 1.9363, Test Accuracy: 51.20%
#     Worker 0: Train Loss: 1.2770, Train Accuracy: 63.86%
# Epoch 112/150: Test Loss: 1.9313, Test Accuracy: 51.45%
#     Worker 0: Train Loss: 1.2708, Train Accuracy: 63.88%
# Epoch 113/150: Test Loss: 1.9401, Test Accuracy: 51.11%
#     Worker 0: Train Loss: 1.2669, Train Accuracy: 64.20%
# Epoch 114/150: Test Loss: 1.9402, Test Accuracy: 51.38%
#     Worker 0: Train Loss: 1.2629, Train Accuracy: 64.32%
# Epoch 115/150: Test Loss: 1.9376, Test Accuracy: 51.51%
#     Worker 0: Train Loss: 1.2561, Train Accuracy: 64.34%
# Epoch 116/150: Test Loss: 1.9419, Test Accuracy: 51.23%
#     Worker 0: Train Loss: 1.2516, Train Accuracy: 64.62%
# Epoch 117/150: Test Loss: 1.9355, Test Accuracy: 51.42%
#     Worker 0: Train Loss: 1.2502, Train Accuracy: 64.49%
# Epoch 118/150: Test Loss: 1.9398, Test Accuracy: 51.66%
#     Worker 0: Train Loss: 1.2490, Train Accuracy: 64.72%
# Epoch 119/150: Test Loss: 1.9404, Test Accuracy: 51.42%
#     Worker 0: Train Loss: 1.2395, Train Accuracy: 64.53%
# Epoch 120/150: Test Loss: 1.9439, Test Accuracy: 51.64%
#     Worker 0: Train Loss: 1.2345, Train Accuracy: 65.06%
# Epoch 121/150: Test Loss: 1.9381, Test Accuracy: 51.29%
#     Worker 0: Train Loss: 1.2390, Train Accuracy: 64.83%
# Epoch 122/150: Test Loss: 1.9343, Test Accuracy: 51.76%
#     Worker 0: Train Loss: 1.2331, Train Accuracy: 64.98%
# Epoch 123/150: Test Loss: 1.9412, Test Accuracy: 51.97%
#     Worker 0: Train Loss: 1.2241, Train Accuracy: 65.36%
# Epoch 124/150: Test Loss: 1.9385, Test Accuracy: 51.81%
#     Worker 0: Train Loss: 1.2221, Train Accuracy: 65.39%
# Epoch 125/150: Test Loss: 1.9344, Test Accuracy: 51.79%
#     Worker 0: Train Loss: 1.2141, Train Accuracy: 65.68%
# Epoch 126/150: Test Loss: 1.9402, Test Accuracy: 51.76%
#     Worker 0: Train Loss: 1.2191, Train Accuracy: 65.68%
# Epoch 127/150: Test Loss: 1.9379, Test Accuracy: 51.86%
#     Worker 0: Train Loss: 1.2125, Train Accuracy: 65.91%
# Epoch 128/150: Test Loss: 1.9387, Test Accuracy: 51.74%
#     Worker 0: Train Loss: 1.2041, Train Accuracy: 65.97%
# Epoch 129/150: Test Loss: 1.9433, Test Accuracy: 51.58%
#     Worker 0: Train Loss: 1.2043, Train Accuracy: 66.09%
# Epoch 130/150: Test Loss: 1.9359, Test Accuracy: 51.87%
#     Worker 0: Train Loss: 1.1994, Train Accuracy: 66.09%
# Epoch 131/150: Test Loss: 1.9382, Test Accuracy: 51.90%
#     Worker 0: Train Loss: 1.1963, Train Accuracy: 65.89%
# Epoch 132/150: Test Loss: 1.9389, Test Accuracy: 51.68%
#     Worker 0: Train Loss: 1.2007, Train Accuracy: 65.87%
# Epoch 133/150: Test Loss: 1.9374, Test Accuracy: 51.83%
#     Worker 0: Train Loss: 1.1967, Train Accuracy: 66.25%
# Epoch 134/150: Test Loss: 1.9400, Test Accuracy: 51.84%
#     Worker 0: Train Loss: 1.1943, Train Accuracy: 66.06%
# Epoch 135/150: Test Loss: 1.9381, Test Accuracy: 51.84%
#     Worker 0: Train Loss: 1.1909, Train Accuracy: 66.26%
# Epoch 136/150: Test Loss: 1.9376, Test Accuracy: 51.70%
#     Worker 0: Train Loss: 1.1883, Train Accuracy: 66.55%
# Epoch 137/150: Test Loss: 1.9396, Test Accuracy: 51.78%
#     Worker 0: Train Loss: 1.1878, Train Accuracy: 66.41%
# Epoch 138/150: Test Loss: 1.9393, Test Accuracy: 51.83%
#     Worker 0: Train Loss: 1.1953, Train Accuracy: 66.01%
# Epoch 139/150: Test Loss: 1.9380, Test Accuracy: 51.83%
#     Worker 0: Train Loss: 1.1900, Train Accuracy: 66.23%
# Epoch 140/150: Test Loss: 1.9377, Test Accuracy: 51.77%
#     Worker 0: Train Loss: 1.1846, Train Accuracy: 66.43%
# Epoch 141/150: Test Loss: 1.9375, Test Accuracy: 51.77%
#     Worker 0: Train Loss: 1.1831, Train Accuracy: 66.39%
# Epoch 142/150: Test Loss: 1.9385, Test Accuracy: 51.73%
#     Worker 0: Train Loss: 1.1825, Train Accuracy: 66.46%
# Epoch 143/150: Test Loss: 1.9376, Test Accuracy: 51.69%
#     Worker 0: Train Loss: 1.1817, Train Accuracy: 66.45%
# Epoch 144/150: Test Loss: 1.9378, Test Accuracy: 51.73%
#     Worker 0: Train Loss: 1.1834, Train Accuracy: 66.55%
# Epoch 145/150: Test Loss: 1.9374, Test Accuracy: 51.77%
#     Worker 0: Train Loss: 1.1816, Train Accuracy: 66.46%
# Epoch 146/150: Test Loss: 1.9378, Test Accuracy: 51.76%
#     Worker 0: Train Loss: 1.1759, Train Accuracy: 66.59%
# Epoch 147/150: Test Loss: 1.9378, Test Accuracy: 51.74%
#     Worker 0: Train Loss: 1.1819, Train Accuracy: 66.51%
# Epoch 148/150: Test Loss: 1.9379, Test Accuracy: 51.78%
#     Worker 0: Train Loss: 1.1749, Train Accuracy: 66.67%
# Epoch 149/150: Test Loss: 1.9379, Test Accuracy: 51.80%
#     Worker 0: Train Loss: 1.1806, Train Accuracy: 66.55%
# Epoch 150/150: Test Loss: 1.9379, Test Accuracy: 51.80%
#     Worker 0: Train Loss: 1.1825, Train Accuracy: 66.57%
