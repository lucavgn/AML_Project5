# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
# Alpha slow learning rate a=1 best
# Beta slow momentum
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
#warmup_epochs = 5

alpha = 0.75  # Slow learning rate scaling factor
beta = 0.2  # Slow momentum factor

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate for each k: {learning_rate:.5f}")
#lr_warmup=learning_rate
# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]


with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs) for optimizer in optimizers]

u_buffer = [torch.zeros_like(param) for param in nets[0].parameters()]  # Momentum buffer

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")
    #if epoch < warmup_epochs: #lr for buffer update during warmup
            #w_factor = (epoch + 1) / warmup_epochs
            #lr_warmup = w_factor * learning_rate
    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch): #outer loop

        #x(t,0)
        iter_params = [torch.zeros_like(param) for param in nets[0].parameters()]
        for param, g_param in zip(iter_params, nets[0].parameters()):
                    param.data.copy_(g_param)
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0

            # Perform J local step before synchronization
            for j in range(J): #inner loop
                      try:
                          # Get a batch from the current worker's shard using next()
                          images, labels = next(shard_iterators[k])
                          images, labels = images.to(device), labels.to(device)  # Move to device
                          optimizers[k].zero_grad()
                          outputs = nets[k](images)
                          loss = criterion(outputs, labels)
                          loss.backward()
                          optimizers[k].step()
                          # Calculate train loss and accuracy
                          train_loss += loss.item() * labels.size(0)
                          _, predicted = outputs.max(1)
                          total_train += labels.size(0)
                          correct_train += predicted.eq(labels).sum().item()

                      except StopIteration:
                          # If the iterator has exhausted the data, restart the iterator
                          shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                          images, labels = next(shard_iterators[k]) # Resume from the next batch
                          images, labels = images.to(device), labels.to(device)
                          # Perform optimization step
                          optimizers[k].zero_grad()
                          outputs = nets[k](images)
                          loss = criterion(outputs, labels)
                          loss.backward()
                          optimizers[k].step()
                          # Calculate train loss and accuracy
                          train_loss += loss.item() * labels.size(0)
                          _, predicted = outputs.max(1)
                          total_train += labels.size(0)
                          correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train


         # Synchronization (SLOWMO Algothm 1 - paper 21)
        with torch.no_grad():
            global_params = [torch.zeros_like(param) for param in nets[0].parameters()]
            #x(t, tau)
            for net in nets:
                for global_param, local_param in zip(global_params, net.parameters()):
                    global_param += local_param
            for global_param in global_params:
                global_param /= K

            for param, g_param, u_param in zip(iter_params, global_params, u_buffer):
                #if epoch < warmup_epochs:
                  #  u_param.mul_(beta).add_((param - g_param) / lr_warmup)
                 #   g_param.sub_(alpha * lr_warmup * u_param)

                #else: #Sync after warmup
                    #print(f"{optimizers[0].param_groups[0]['lr']}  {optimizers[1].param_groups[0]['lr']}")
                    lr_sched = optimizers[0].param_groups[0]['lr'] #optimizer lr
                    u_param.mul_(beta).add_((param - g_param) / lr_sched)
                    #g_param.sub_(alpha * lr_sched * u_param)
                    g_param.copy_(param - alpha * lr_sched * u_param)

            for net in nets:
                for param, g_param in zip(net.parameters(), global_params):
                    param.data.copy_(g_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        #if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
        #else:
         #   warmup_factor = (epoch + 1) / warmup_epochs
          #  lr = warmup_factor * learning_rate
           # for optimizer in optimizers:
            #    for param_group in optimizer.param_groups:
             #       param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Overwriting localSGD.py

# %%
# %run localSGD.py --k 4 --j 16
# Out:
# Training with K=4, J=16
# Global iteration per epoch: 13
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
#
#     Worker 1: Train Loss: 1.4767, Train Accuracy: 58.81%
#     Worker 2: Train Loss: 1.4503, Train Accuracy: 59.35%
#     Worker 3: Train Loss: 1.4856, Train Accuracy: 58.82%
# Epoch 99/150: Test Loss: 1.9589, Test Accuracy: 50.48%
#     Worker 0: Train Loss: 1.4703, Train Accuracy: 58.98%
#     Worker 1: Train Loss: 1.4538, Train Accuracy: 59.15%
#     Worker 2: Train Loss: 1.4533, Train Accuracy: 59.20%
#     Worker 3: Train Loss: 1.4707, Train Accuracy: 59.38%
# Epoch 100/150: Test Loss: 1.9541, Test Accuracy: 50.59%
#     Worker 0: Train Loss: 1.4417, Train Accuracy: 59.02%
#     Worker 1: Train Loss: 1.4487, Train Accuracy: 59.21%
#     Worker 2: Train Loss: 1.4395, Train Accuracy: 59.97%
#     Worker 3: Train Loss: 1.4641, Train Accuracy: 59.02%
# Epoch 101/150: Test Loss: 1.9546, Test Accuracy: 50.28%
#     Worker 0: Train Loss: 1.4459, Train Accuracy: 59.54%
#     Worker 1: Train Loss: 1.4568, Train Accuracy: 59.09%
#     Worker 2: Train Loss: 1.4397, Train Accuracy: 59.31%
#     Worker 3: Train Loss: 1.4476, Train Accuracy: 59.81%
# Epoch 102/150: Test Loss: 1.9552, Test Accuracy: 50.27%
#     Worker 0: Train Loss: 1.4351, Train Accuracy: 59.41%
#     Worker 1: Train Loss: 1.4324, Train Accuracy: 60.04%
#     Worker 2: Train Loss: 1.4260, Train Accuracy: 60.11%
#     Worker 3: Train Loss: 1.4567, Train Accuracy: 59.54%
# Epoch 103/150: Test Loss: 1.9449, Test Accuracy: 50.30%
#     Worker 0: Train Loss: 1.4320, Train Accuracy: 60.02%
#     Worker 1: Train Loss: 1.4090, Train Accuracy: 60.33%
#     Worker 2: Train Loss: 1.4265, Train Accuracy: 59.60%
#     Worker 3: Train Loss: 1.4376, Train Accuracy: 60.64%
# Epoch 104/150: Test Loss: 1.9565, Test Accuracy: 50.56%
#     Worker 0: Train Loss: 1.4012, Train Accuracy: 60.38%
#     Worker 1: Train Loss: 1.4280, Train Accuracy: 60.06%
#     Worker 2: Train Loss: 1.4174, Train Accuracy: 60.18%
#     Worker 3: Train Loss: 1.4254, Train Accuracy: 60.42%
# Epoch 105/150: Test Loss: 1.9469, Test Accuracy: 50.62%
#     Worker 0: Train Loss: 1.4261, Train Accuracy: 59.90%
#     Worker 1: Train Loss: 1.4037, Train Accuracy: 60.95%
#     Worker 2: Train Loss: 1.4159, Train Accuracy: 60.51%
#     Worker 3: Train Loss: 1.4325, Train Accuracy: 59.84%
# Epoch 106/150: Test Loss: 1.9413, Test Accuracy: 50.54%
#     Worker 0: Train Loss: 1.3996, Train Accuracy: 60.85%
#     Worker 1: Train Loss: 1.4084, Train Accuracy: 60.89%
#     Worker 2: Train Loss: 1.3974, Train Accuracy: 61.51%
#     Worker 3: Train Loss: 1.4169, Train Accuracy: 60.50%
# Epoch 107/150: Test Loss: 1.9552, Test Accuracy: 50.29%
#     Worker 0: Train Loss: 1.4122, Train Accuracy: 59.67%
#     Worker 1: Train Loss: 1.4138, Train Accuracy: 60.27%
#     Worker 2: Train Loss: 1.4006, Train Accuracy: 60.86%
#     Worker 3: Train Loss: 1.4167, Train Accuracy: 60.31%
# Epoch 108/150: Test Loss: 1.9498, Test Accuracy: 50.61%
#     Worker 0: Train Loss: 1.3964, Train Accuracy: 60.99%
#     Worker 1: Train Loss: 1.3945, Train Accuracy: 60.76%
#     Worker 2: Train Loss: 1.3800, Train Accuracy: 61.60%
#     Worker 3: Train Loss: 1.3938, Train Accuracy: 60.83%
# Epoch 109/150: Test Loss: 1.9450, Test Accuracy: 50.82%
#     Worker 0: Train Loss: 1.3785, Train Accuracy: 61.52%
#     Worker 1: Train Loss: 1.3810, Train Accuracy: 61.04%
#     Worker 2: Train Loss: 1.3666, Train Accuracy: 61.58%
#     Worker 3: Train Loss: 1.4173, Train Accuracy: 60.54%
# Epoch 110/150: Test Loss: 1.9512, Test Accuracy: 50.51%
#     Worker 0: Train Loss: 1.3841, Train Accuracy: 60.88%
#     Worker 1: Train Loss: 1.3853, Train Accuracy: 61.12%
#     Worker 2: Train Loss: 1.3800, Train Accuracy: 61.28%
#     Worker 3: Train Loss: 1.3873, Train Accuracy: 61.40%
# Epoch 111/150: Test Loss: 1.9578, Test Accuracy: 50.49%
#     Worker 0: Train Loss: 1.3575, Train Accuracy: 61.35%
#     Worker 1: Train Loss: 1.3755, Train Accuracy: 61.28%
#     Worker 2: Train Loss: 1.3583, Train Accuracy: 61.39%
#     Worker 3: Train Loss: 1.3903, Train Accuracy: 60.76%
# Epoch 112/150: Test Loss: 1.9504, Test Accuracy: 50.68%
#     Worker 0: Train Loss: 1.3718, Train Accuracy: 61.45%
#     Worker 1: Train Loss: 1.3632, Train Accuracy: 61.12%
#     Worker 2: Train Loss: 1.3827, Train Accuracy: 61.15%
#     Worker 3: Train Loss: 1.3723, Train Accuracy: 62.41%
# Epoch 113/150: Test Loss: 1.9535, Test Accuracy: 50.75%
#     Worker 0: Train Loss: 1.3763, Train Accuracy: 61.34%
#     Worker 1: Train Loss: 1.3650, Train Accuracy: 61.33%
#     Worker 2: Train Loss: 1.3463, Train Accuracy: 61.84%
#     Worker 3: Train Loss: 1.3614, Train Accuracy: 61.91%
# Epoch 114/150: Test Loss: 1.9515, Test Accuracy: 50.46%
#     Worker 0: Train Loss: 1.3465, Train Accuracy: 62.12%
#     Worker 1: Train Loss: 1.3612, Train Accuracy: 61.80%
#     Worker 2: Train Loss: 1.3474, Train Accuracy: 62.20%
#     Worker 3: Train Loss: 1.3619, Train Accuracy: 61.41%
# Epoch 115/150: Test Loss: 1.9536, Test Accuracy: 50.68%
#     Worker 0: Train Loss: 1.3359, Train Accuracy: 62.23%
#     Worker 1: Train Loss: 1.3366, Train Accuracy: 62.14%
#     Worker 2: Train Loss: 1.3364, Train Accuracy: 62.35%
#     Worker 3: Train Loss: 1.3581, Train Accuracy: 61.66%
# Epoch 116/150: Test Loss: 1.9560, Test Accuracy: 50.54%
#     Worker 0: Train Loss: 1.3503, Train Accuracy: 61.67%
#     Worker 1: Train Loss: 1.3483, Train Accuracy: 62.20%
#     Worker 2: Train Loss: 1.3510, Train Accuracy: 62.58%
#     Worker 3: Train Loss: 1.3456, Train Accuracy: 62.20%
# Epoch 117/150: Test Loss: 1.9574, Test Accuracy: 50.45%
#     Worker 0: Train Loss: 1.3338, Train Accuracy: 62.35%
#     Worker 1: Train Loss: 1.3282, Train Accuracy: 62.79%
#     Worker 2: Train Loss: 1.3256, Train Accuracy: 62.60%
#     Worker 3: Train Loss: 1.3517, Train Accuracy: 62.25%
# Epoch 118/150: Test Loss: 1.9550, Test Accuracy: 50.94%
#     Worker 0: Train Loss: 1.3414, Train Accuracy: 61.85%
#     Worker 1: Train Loss: 1.3481, Train Accuracy: 62.15%
#     Worker 2: Train Loss: 1.3255, Train Accuracy: 62.87%
#     Worker 3: Train Loss: 1.3476, Train Accuracy: 62.54%
# Epoch 119/150: Test Loss: 1.9527, Test Accuracy: 50.88%
#     Worker 0: Train Loss: 1.3364, Train Accuracy: 62.52%
#     Worker 1: Train Loss: 1.3341, Train Accuracy: 62.61%
#     Worker 2: Train Loss: 1.3228, Train Accuracy: 62.91%
#     Worker 3: Train Loss: 1.3371, Train Accuracy: 62.41%
# Epoch 120/150: Test Loss: 1.9530, Test Accuracy: 50.70%
#     Worker 0: Train Loss: 1.3130, Train Accuracy: 62.72%
#     Worker 1: Train Loss: 1.3221, Train Accuracy: 62.55%
#     Worker 2: Train Loss: 1.3219, Train Accuracy: 63.12%
#     Worker 3: Train Loss: 1.3408, Train Accuracy: 62.84%
# Epoch 121/150: Test Loss: 1.9549, Test Accuracy: 50.65%
#     Worker 0: Train Loss: 1.3112, Train Accuracy: 62.76%
#     Worker 1: Train Loss: 1.3208, Train Accuracy: 62.60%
#     Worker 2: Train Loss: 1.3032, Train Accuracy: 63.15%
#     Worker 3: Train Loss: 1.3118, Train Accuracy: 62.81%
# Epoch 122/150: Test Loss: 1.9545, Test Accuracy: 50.61%
#     Worker 0: Train Loss: 1.3119, Train Accuracy: 63.04%
#     Worker 1: Train Loss: 1.3172, Train Accuracy: 62.97%
#     Worker 2: Train Loss: 1.3252, Train Accuracy: 62.85%
#     Worker 3: Train Loss: 1.3169, Train Accuracy: 63.28%
# Epoch 123/150: Test Loss: 1.9573, Test Accuracy: 50.69%
#     Worker 0: Train Loss: 1.3115, Train Accuracy: 63.02%
#     Worker 1: Train Loss: 1.2921, Train Accuracy: 63.62%
#     Worker 2: Train Loss: 1.3002, Train Accuracy: 63.42%
#     Worker 3: Train Loss: 1.3222, Train Accuracy: 63.17%
# Epoch 124/150: Test Loss: 1.9539, Test Accuracy: 50.63%
#     Worker 0: Train Loss: 1.2939, Train Accuracy: 63.33%
#     Worker 1: Train Loss: 1.3198, Train Accuracy: 62.66%
#     Worker 2: Train Loss: 1.3054, Train Accuracy: 63.38%
#     Worker 3: Train Loss: 1.3367, Train Accuracy: 62.85%
# Epoch 125/150: Test Loss: 1.9575, Test Accuracy: 50.98%
#     Worker 0: Train Loss: 1.2832, Train Accuracy: 63.24%
#     Worker 1: Train Loss: 1.3093, Train Accuracy: 62.90%
#     Worker 2: Train Loss: 1.2920, Train Accuracy: 63.51%
#     Worker 3: Train Loss: 1.3008, Train Accuracy: 63.66%
# Epoch 126/150: Test Loss: 1.9525, Test Accuracy: 50.89%
#     Worker 0: Train Loss: 1.3224, Train Accuracy: 62.60%
#     Worker 1: Train Loss: 1.2997, Train Accuracy: 62.85%
#     Worker 2: Train Loss: 1.2944, Train Accuracy: 63.44%
#     Worker 3: Train Loss: 1.3267, Train Accuracy: 62.82%
# Epoch 127/150: Test Loss: 1.9539, Test Accuracy: 51.09%
#     Worker 0: Train Loss: 1.2856, Train Accuracy: 63.53%
#     Worker 1: Train Loss: 1.3117, Train Accuracy: 63.39%
#     Worker 2: Train Loss: 1.2888, Train Accuracy: 64.13%
#     Worker 3: Train Loss: 1.2935, Train Accuracy: 63.66%
# Epoch 128/150: Test Loss: 1.9545, Test Accuracy: 50.94%
#     Worker 0: Train Loss: 1.2968, Train Accuracy: 63.59%
#     Worker 1: Train Loss: 1.2766, Train Accuracy: 64.04%
#     Worker 2: Train Loss: 1.2781, Train Accuracy: 63.90%
#     Worker 3: Train Loss: 1.3058, Train Accuracy: 63.43%
# Epoch 129/150: Test Loss: 1.9556, Test Accuracy: 50.97%
#     Worker 0: Train Loss: 1.2945, Train Accuracy: 63.14%
#     Worker 1: Train Loss: 1.3029, Train Accuracy: 63.37%
#     Worker 2: Train Loss: 1.2894, Train Accuracy: 64.24%
#     Worker 3: Train Loss: 1.3078, Train Accuracy: 63.11%
# Epoch 130/150: Test Loss: 1.9540, Test Accuracy: 50.96%
#     Worker 0: Train Loss: 1.2918, Train Accuracy: 63.43%
#     Worker 1: Train Loss: 1.2823, Train Accuracy: 63.60%
#     Worker 2: Train Loss: 1.2893, Train Accuracy: 63.99%
#     Worker 3: Train Loss: 1.2951, Train Accuracy: 63.75%
# Epoch 131/150: Test Loss: 1.9543, Test Accuracy: 51.06%
#     Worker 0: Train Loss: 1.2880, Train Accuracy: 63.60%
#     Worker 1: Train Loss: 1.2818, Train Accuracy: 63.92%
#     Worker 2: Train Loss: 1.2792, Train Accuracy: 64.35%
#     Worker 3: Train Loss: 1.2959, Train Accuracy: 63.90%
# Epoch 132/150: Test Loss: 1.9558, Test Accuracy: 50.99%
#     Worker 0: Train Loss: 1.2790, Train Accuracy: 63.88%
#     Worker 1: Train Loss: 1.2762, Train Accuracy: 64.06%
#     Worker 2: Train Loss: 1.2819, Train Accuracy: 63.94%
#     Worker 3: Train Loss: 1.2874, Train Accuracy: 63.67%
# Epoch 133/150: Test Loss: 1.9539, Test Accuracy: 50.90%
#     Worker 0: Train Loss: 1.2927, Train Accuracy: 63.38%
#     Worker 1: Train Loss: 1.2825, Train Accuracy: 64.04%
#     Worker 2: Train Loss: 1.2760, Train Accuracy: 63.97%
#     Worker 3: Train Loss: 1.2919, Train Accuracy: 63.62%
# Epoch 134/150: Test Loss: 1.9555, Test Accuracy: 51.03%
#     Worker 0: Train Loss: 1.2779, Train Accuracy: 63.85%
#     Worker 1: Train Loss: 1.2817, Train Accuracy: 64.11%
#     Worker 2: Train Loss: 1.2809, Train Accuracy: 64.58%
#     Worker 3: Train Loss: 1.3134, Train Accuracy: 63.80%
# Epoch 135/150: Test Loss: 1.9553, Test Accuracy: 51.02%
#     Worker 0: Train Loss: 1.2763, Train Accuracy: 64.15%
#     Worker 1: Train Loss: 1.2674, Train Accuracy: 64.29%
#     Worker 2: Train Loss: 1.2622, Train Accuracy: 64.43%
#     Worker 3: Train Loss: 1.2947, Train Accuracy: 63.33%
# Epoch 136/150: Test Loss: 1.9562, Test Accuracy: 50.98%
#     Worker 0: Train Loss: 1.2827, Train Accuracy: 63.90%
#     Worker 1: Train Loss: 1.2790, Train Accuracy: 64.18%
#     Worker 2: Train Loss: 1.2895, Train Accuracy: 63.54%
#     Worker 3: Train Loss: 1.2661, Train Accuracy: 64.40%
# Epoch 137/150: Test Loss: 1.9531, Test Accuracy: 50.95%
#     Worker 0: Train Loss: 1.2537, Train Accuracy: 64.62%
#     Worker 1: Train Loss: 1.2502, Train Accuracy: 64.52%
#     Worker 2: Train Loss: 1.2888, Train Accuracy: 63.66%
#     Worker 3: Train Loss: 1.2849, Train Accuracy: 64.43%
# Epoch 138/150: Test Loss: 1.9534, Test Accuracy: 51.14%
#     Worker 0: Train Loss: 1.2826, Train Accuracy: 64.28%
#     Worker 1: Train Loss: 1.2832, Train Accuracy: 64.06%
#     Worker 2: Train Loss: 1.2565, Train Accuracy: 64.36%
#     Worker 3: Train Loss: 1.2591, Train Accuracy: 65.28%
# Epoch 139/150: Test Loss: 1.9545, Test Accuracy: 50.98%
#     Worker 0: Train Loss: 1.2745, Train Accuracy: 64.08%
#     Worker 1: Train Loss: 1.2526, Train Accuracy: 64.86%
#     Worker 2: Train Loss: 1.2888, Train Accuracy: 63.77%
#     Worker 3: Train Loss: 1.2773, Train Accuracy: 64.12%
# Epoch 140/150: Test Loss: 1.9549, Test Accuracy: 51.12%
#     Worker 0: Train Loss: 1.2609, Train Accuracy: 64.06%
#     Worker 1: Train Loss: 1.2680, Train Accuracy: 64.18%
#     Worker 2: Train Loss: 1.2667, Train Accuracy: 64.58%
#     Worker 3: Train Loss: 1.2745, Train Accuracy: 63.72%
# Epoch 141/150: Test Loss: 1.9539, Test Accuracy: 50.97%
#     Worker 0: Train Loss: 1.2755, Train Accuracy: 64.24%
#     Worker 1: Train Loss: 1.2665, Train Accuracy: 64.91%
#     Worker 2: Train Loss: 1.2669, Train Accuracy: 64.02%
#     Worker 3: Train Loss: 1.2706, Train Accuracy: 64.38%
# Epoch 142/150: Test Loss: 1.9542, Test Accuracy: 50.97%
#     Worker 0: Train Loss: 1.2623, Train Accuracy: 64.15%
#     Worker 1: Train Loss: 1.2530, Train Accuracy: 64.83%
#     Worker 2: Train Loss: 1.2757, Train Accuracy: 64.07%
#     Worker 3: Train Loss: 1.2821, Train Accuracy: 64.27%
# Epoch 143/150: Test Loss: 1.9535, Test Accuracy: 51.10%
#     Worker 0: Train Loss: 1.2619, Train Accuracy: 64.41%
#     Worker 1: Train Loss: 1.2804, Train Accuracy: 63.79%
#     Worker 2: Train Loss: 1.2589, Train Accuracy: 64.72%
#     Worker 3: Train Loss: 1.2907, Train Accuracy: 63.48%
# Epoch 144/150: Test Loss: 1.9537, Test Accuracy: 51.08%
#     Worker 0: Train Loss: 1.2678, Train Accuracy: 64.01%
#     Worker 1: Train Loss: 1.2731, Train Accuracy: 63.97%
#     Worker 2: Train Loss: 1.2703, Train Accuracy: 63.80%
#     Worker 3: Train Loss: 1.2673, Train Accuracy: 64.61%
# Epoch 145/150: Test Loss: 1.9535, Test Accuracy: 51.05%
#     Worker 0: Train Loss: 1.2604, Train Accuracy: 64.11%
#     Worker 1: Train Loss: 1.2640, Train Accuracy: 63.97%
#     Worker 2: Train Loss: 1.2776, Train Accuracy: 64.31%
#     Worker 3: Train Loss: 1.2734, Train Accuracy: 63.71%
# Epoch 146/150: Test Loss: 1.9537, Test Accuracy: 51.09%
#     Worker 0: Train Loss: 1.2710, Train Accuracy: 63.72%
#     Worker 1: Train Loss: 1.2624, Train Accuracy: 64.10%
#     Worker 2: Train Loss: 1.2521, Train Accuracy: 65.33%
#     Worker 3: Train Loss: 1.2831, Train Accuracy: 64.08%
# Epoch 147/150: Test Loss: 1.9538, Test Accuracy: 51.04%
#     Worker 0: Train Loss: 1.2575, Train Accuracy: 64.28%
#     Worker 1: Train Loss: 1.2625, Train Accuracy: 64.47%
#     Worker 2: Train Loss: 1.2622, Train Accuracy: 64.55%
#     Worker 3: Train Loss: 1.2773, Train Accuracy: 63.94%
# Epoch 148/150: Test Loss: 1.9537, Test Accuracy: 51.05%
#     Worker 0: Train Loss: 1.2604, Train Accuracy: 64.43%
#     Worker 1: Train Loss: 1.2672, Train Accuracy: 64.33%
#     Worker 2: Train Loss: 1.2568, Train Accuracy: 64.29%
#     Worker 3: Train Loss: 1.2759, Train Accuracy: 64.43%
# Epoch 149/150: Test Loss: 1.9537, Test Accuracy: 51.07%
#     Worker 0: Train Loss: 1.2769, Train Accuracy: 63.57%
#     Worker 1: Train Loss: 1.2641, Train Accuracy: 64.24%
#     Worker 2: Train Loss: 1.2595, Train Accuracy: 64.32%
#     Worker 3: Train Loss: 1.2793, Train Accuracy: 64.19%
# Epoch 150/150: Test Loss: 1.9537, Test Accuracy: 51.06%
#     Worker 0: Train Loss: 1.2632, Train Accuracy: 64.12%
#     Worker 1: Train Loss: 1.2585, Train Accuracy: 64.52%
#     Worker 2: Train Loss: 1.2569, Train Accuracy: 64.50%
#     Worker 3: Train Loss: 1.2512, Train Accuracy: 65.23%
