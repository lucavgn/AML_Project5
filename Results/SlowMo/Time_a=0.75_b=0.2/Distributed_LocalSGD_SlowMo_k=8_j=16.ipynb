# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files
import time

total_computation_time = 0
total_communication_time = 0

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
# Alpha slow learning rate a=1 best
# Beta slow momentum
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
#warmup_epochs = 5

alpha = 0.75  # Slow learning rate scaling factor
beta = 0.2  # Slow momentum factor

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate for each k: {learning_rate:.5f}")
#lr_warmup=learning_rate
# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]


with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs) for optimizer in optimizers]

u_buffer = [torch.zeros_like(param) for param in nets[0].parameters()]  # Momentum buffer

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")
    #if epoch < warmup_epochs: #lr for buffer update during warmup
            #w_factor = (epoch + 1) / warmup_epochs
            #lr_warmup = w_factor * learning_rate
    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch): #outer loop
        computation_start_time = time.time()
        #x(t,0)
        iter_params = [torch.zeros_like(param) for param in nets[0].parameters()]
        for param, g_param in zip(iter_params, nets[0].parameters()):
                    param.data.copy_(g_param)
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0

            # Perform J local step before synchronization
            for j in range(J): #inner loop
                      try:
                          # Get a batch from the current worker's shard using next()
                          images, labels = next(shard_iterators[k])
                          images, labels = images.to(device), labels.to(device)  # Move to device
                          optimizers[k].zero_grad()
                          outputs = nets[k](images)
                          loss = criterion(outputs, labels)
                          loss.backward()
                          optimizers[k].step()
                          # Calculate train loss and accuracy
                          train_loss += loss.item() * labels.size(0)
                          _, predicted = outputs.max(1)
                          total_train += labels.size(0)
                          correct_train += predicted.eq(labels).sum().item()

                      except StopIteration:
                          # If the iterator has exhausted the data, restart the iterator
                          shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                          images, labels = next(shard_iterators[k]) # Resume from the next batch
                          images, labels = images.to(device), labels.to(device)
                          # Perform optimization step
                          optimizers[k].zero_grad()
                          outputs = nets[k](images)
                          loss = criterion(outputs, labels)
                          loss.backward()
                          optimizers[k].step()
                          # Calculate train loss and accuracy
                          train_loss += loss.item() * labels.size(0)
                          _, predicted = outputs.max(1)
                          total_train += labels.size(0)
                          correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        computation_end_time = time.time()
        total_computation_time += (computation_end_time - computation_start_time)

        communication_start_time = time.time()
          # Synchronization (SLOWMO Algothm 1 - paper 21)
        with torch.no_grad():
            global_params = [torch.zeros_like(param) for param in nets[0].parameters()]
            #x(t, tau)
            for net in nets:
                for global_param, local_param in zip(global_params, net.parameters()):
                    global_param += local_param
            for global_param in global_params:
                global_param /= K

            for param, g_param, u_param in zip(iter_params, global_params, u_buffer):
                #if epoch < warmup_epochs:
                  #  u_param.mul_(beta).add_((param - g_param) / lr_warmup)
                 #   g_param.sub_(alpha * lr_warmup * u_param)

                #else: #Sync after warmup
                    #print(f"{optimizers[0].param_groups[0]['lr']}  {optimizers[1].param_groups[0]['lr']}")
                    lr_sched = optimizers[0].param_groups[0]['lr'] #optimizer lr
                    u_param.mul_(beta).add_((param - g_param) / lr_sched)
                    #g_param.sub_(alpha * lr_sched * u_param)
                    g_param.copy_(param - alpha * lr_sched * u_param)

            for net in nets:
                for param, g_param in zip(net.parameters(), global_params):
                    param.data.copy_(g_param)

        communication_end_time = time.time()
        total_communication_time += (communication_end_time - communication_start_time)

    # Update lr for each scheduler
    for scheduler in schedulers:
        #if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
        #else:
         #   warmup_factor = (epoch + 1) / warmup_epochs
          #  lr = warmup_factor * learning_rate
           # for optimizer in optimizers:
            #    for param_group in optimizer.param_groups:
             #       param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

    print(f"Total Computation Time: {total_computation_time:.2f} seconds")
    print(f"Total Communication Time: {total_communication_time:.2f} seconds")


# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 8 --j 16
# Out:
# Training with K=8, J=16
# Global iteration per epoch: 7
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:04<00:00, 42.0MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate for each k: 0.00800
# Epoch 1/150: Test Loss: 4.5772, Test Accuracy: 2.10%
#     Worker 0: Train Loss: 4.5992, Train Accuracy: 1.20%
#     Worker 1: Train Loss: 4.5980, Train Accuracy: 1.55%
#     Worker 2: Train Loss: 4.5989, Train Accuracy: 1.27%
#     Worker 3: Train Loss: 4.5968, Train Accuracy: 1.67%
#     Worker 4: Train Loss: 4.5981, Train Accuracy: 1.33%
#     Worker 5: Train Loss: 4.5951, Train Accuracy: 1.55%
#     Worker 6: Train Loss: 4.5985, Train Accuracy: 1.44%
#     Worker 7: Train Loss: 4.5973, Train Accuracy: 1.40%
# Total Computation Time: 27.26 seconds
# Total Communication Time: 0.08 seconds
# Epoch 2/150: Test Loss: 4.2277, Test Accuracy: 6.16%
#     Worker 0: Train Loss: 4.4635, Train Accuracy: 3.26%
#     Worker 1: Train Loss: 4.4595, Train Accuracy: 3.09%
#     Worker 2: Train Loss: 4.4646, Train Accuracy: 3.18%
#     Worker 3: Train Loss: 4.4654, Train Accuracy: 3.25%
#     Worker 4: Train Loss: 4.4518, Train Accuracy: 3.01%
#     Worker 5: Train Loss: 4.4442, Train Accuracy: 3.36%
#     Worker 6: Train Loss: 4.4577, Train Accuracy: 3.62%
#     Worker 7: Train Loss: 4.4484, Train Accuracy: 3.33%
# Total Computation Time: 54.08 seconds
# Total Communication Time: 0.10 seconds
# Epoch 3/150: Test Loss: 4.0289, Test Accuracy: 8.55%
#     Worker 0: Train Loss: 4.1699, Train Accuracy: 6.26%
#     Worker 1: Train Loss: 4.1991, Train Accuracy: 5.36%
#     Worker 2: Train Loss: 4.1812, Train Accuracy: 5.67%
#     Worker 3: Train Loss: 4.1979, Train Accuracy: 5.33%
#     Worker 4: Train Loss: 4.1567, Train Accuracy: 5.65%
#     Worker 5: Train Loss: 4.1673, Train Accuracy: 5.99%
#     Worker 6: Train Loss: 4.1943, Train Accuracy: 5.92%
#     Worker 7: Train Loss: 4.1927, Train Accuracy: 5.96%
# Total Computation Time: 80.41 seconds
# Total Communication Time: 0.12 seconds
# Epoch 4/150: Test Loss: 3.9042, Test Accuracy: 10.30%
#     Worker 0: Train Loss: 4.0500, Train Accuracy: 7.89%
#     Worker 1: Train Loss: 4.0656, Train Accuracy: 7.35%
#     Worker 2: Train Loss: 4.0565, Train Accuracy: 7.71%
#     Worker 3: Train Loss: 4.0772, Train Accuracy: 7.14%
#     Worker 4: Train Loss: 4.0261, Train Accuracy: 8.07%
#     Worker 5: Train Loss: 4.0419, Train Accuracy: 7.18%
#     Worker 6: Train Loss: 4.0617, Train Accuracy: 7.49%
#     Worker 7: Train Loss: 4.0700, Train Accuracy: 7.60%
# Total Computation Time: 106.55 seconds
# Total Communication Time: 0.14 seconds
# Epoch 5/150: Test Loss: 3.7726, Test Accuracy: 13.34%
#     Worker 0: Train Loss: 3.9539, Train Accuracy: 9.08%
#     Worker 1: Train Loss: 3.9560, Train Accuracy: 8.37%
#     Worker 2: Train Loss: 3.9356, Train Accuracy: 9.56%
#     Worker 3: Train Loss: 3.9515, Train Accuracy: 8.55%
#     Worker 4: Train Loss: 3.8877, Train Accuracy: 10.03%
#     Worker 5: Train Loss: 3.8955, Train Accuracy: 10.66%
#     Worker 6: Train Loss: 3.9514, Train Accuracy: 8.49%
#     Worker 7: Train Loss: 3.9398, Train Accuracy: 9.57%
# Total Computation Time: 133.02 seconds
# Total Communication Time: 0.16 seconds
# Epoch 6/150: Test Loss: 3.6587, Test Accuracy: 15.27%
#     Worker 0: Train Loss: 3.8437, Train Accuracy: 9.98%
#     Worker 1: Train Loss: 3.8494, Train Accuracy: 10.66%
#     Worker 2: Train Loss: 3.8454, Train Accuracy: 10.97%
#     Worker 3: Train Loss: 3.8575, Train Accuracy: 10.55%
#     Worker 4: Train Loss: 3.7946, Train Accuracy: 10.79%
#     Worker 5: Train Loss: 3.8050, Train Accuracy: 11.61%
#     Worker 6: Train Loss: 3.8328, Train Accuracy: 10.12%
#     Worker 7: Train Loss: 3.8297, Train Accuracy: 11.21%
# Total Computation Time: 160.73 seconds
# Total Communication Time: 0.19 seconds
# Epoch 7/150: Test Loss: 3.5743, Test Accuracy: 16.16%
#     Worker 0: Train Loss: 3.7406, Train Accuracy: 11.92%
#     Worker 1: Train Loss: 3.7643, Train Accuracy: 11.51%
#     Worker 2: Train Loss: 3.7393, Train Accuracy: 12.97%
#     Worker 3: Train Loss: 3.7640, Train Accuracy: 12.45%
#     Worker 4: Train Loss: 3.7206, Train Accuracy: 12.25%
#     Worker 5: Train Loss: 3.7042, Train Accuracy: 13.10%
#     Worker 6: Train Loss: 3.7694, Train Accuracy: 11.89%
#     Worker 7: Train Loss: 3.7505, Train Accuracy: 11.93%
# Total Computation Time: 189.66 seconds
# Total Communication Time: 0.20 seconds
# Epoch 8/150: Test Loss: 3.4866, Test Accuracy: 18.01%
#     Worker 0: Train Loss: 3.6657, Train Accuracy: 13.60%
#     Worker 1: Train Loss: 3.6739, Train Accuracy: 13.08%
#     Worker 2: Train Loss: 3.6592, Train Accuracy: 13.97%
#     Worker 3: Train Loss: 3.6924, Train Accuracy: 13.08%
#     Worker 4: Train Loss: 3.6167, Train Accuracy: 14.34%
#     Worker 5: Train Loss: 3.6408, Train Accuracy: 14.30%
#     Worker 6: Train Loss: 3.6837, Train Accuracy: 13.42%
#     Worker 7: Train Loss: 3.6632, Train Accuracy: 13.57%
# Total Computation Time: 216.30 seconds
# Total Communication Time: 0.22 seconds
# Epoch 9/150: Test Loss: 3.4221, Test Accuracy: 19.42%
#     Worker 0: Train Loss: 3.5864, Train Accuracy: 14.76%
#     Worker 1: Train Loss: 3.6071, Train Accuracy: 14.04%
#     Worker 2: Train Loss: 3.5837, Train Accuracy: 15.66%
#     Worker 3: Train Loss: 3.6151, Train Accuracy: 14.29%
#     Worker 4: Train Loss: 3.5498, Train Accuracy: 15.55%
#     Worker 5: Train Loss: 3.5386, Train Accuracy: 15.88%
#     Worker 6: Train Loss: 3.5912, Train Accuracy: 14.57%
#     Worker 7: Train Loss: 3.6014, Train Accuracy: 14.79%
# Total Computation Time: 242.51 seconds
# Total Communication Time: 0.24 seconds
# Epoch 10/150: Test Loss: 3.3585, Test Accuracy: 20.17%
#     Worker 0: Train Loss: 3.5541, Train Accuracy: 15.88%
#     Worker 1: Train Loss: 3.5110, Train Accuracy: 15.94%
#     Worker 2: Train Loss: 3.5109, Train Accuracy: 17.00%
#     Worker 3: Train Loss: 3.5551, Train Accuracy: 15.07%
#     Worker 4: Train Loss: 3.4806, Train Accuracy: 17.34%
#     Worker 5: Train Loss: 3.4986, Train Accuracy: 16.65%
#     Worker 6: Train Loss: 3.5554, Train Accuracy: 15.63%
#     Worker 7: Train Loss: 3.5029, Train Accuracy: 16.69%
# Total Computation Time: 268.57 seconds
# Total Communication Time: 0.27 seconds
# Epoch 11/150: Test Loss: 3.2768, Test Accuracy: 21.77%
#     Worker 0: Train Loss: 3.4382, Train Accuracy: 16.88%
#     Worker 1: Train Loss: 3.4449, Train Accuracy: 16.79%
#     Worker 2: Train Loss: 3.4418, Train Accuracy: 17.95%
#     Worker 3: Train Loss: 3.5000, Train Accuracy: 16.47%
#     Worker 4: Train Loss: 3.4221, Train Accuracy: 18.14%
#     Worker 5: Train Loss: 3.3893, Train Accuracy: 19.06%
#     Worker 6: Train Loss: 3.4632, Train Accuracy: 17.13%
#     Worker 7: Train Loss: 3.4666, Train Accuracy: 17.17%
# Total Computation Time: 295.37 seconds
# Total Communication Time: 0.28 seconds
# Epoch 12/150: Test Loss: 3.2231, Test Accuracy: 22.71%
#     Worker 0: Train Loss: 3.3977, Train Accuracy: 18.68%
#     Worker 1: Train Loss: 3.3849, Train Accuracy: 17.81%
#     Worker 2: Train Loss: 3.4050, Train Accuracy: 19.28%
#     Worker 3: Train Loss: 3.4442, Train Accuracy: 17.51%
#     Worker 4: Train Loss: 3.3697, Train Accuracy: 18.81%
#     Worker 5: Train Loss: 3.3570, Train Accuracy: 19.13%
#     Worker 6: Train Loss: 3.3993, Train Accuracy: 17.80%
#     Worker 7: Train Loss: 3.4109, Train Accuracy: 18.37%
# Total Computation Time: 321.44 seconds
# Total Communication Time: 0.31 seconds
# Epoch 13/150: Test Loss: 3.1586, Test Accuracy: 23.73%
#     Worker 0: Train Loss: 3.3278, Train Accuracy: 18.99%
#     Worker 1: Train Loss: 3.3317, Train Accuracy: 19.13%
#     Worker 2: Train Loss: 3.3187, Train Accuracy: 20.22%
#     Worker 3: Train Loss: 3.3515, Train Accuracy: 18.74%
#     Worker 4: Train Loss: 3.2675, Train Accuracy: 20.43%
#     Worker 5: Train Loss: 3.2879, Train Accuracy: 20.11%
#     Worker 6: Train Loss: 3.3463, Train Accuracy: 19.05%
#     Worker 7: Train Loss: 3.3213, Train Accuracy: 19.69%
# Total Computation Time: 348.22 seconds
# Total Communication Time: 0.33 seconds
# Epoch 14/150: Test Loss: 3.1037, Test Accuracy: 24.64%
#     Worker 0: Train Loss: 3.2900, Train Accuracy: 19.60%
#     Worker 1: Train Loss: 3.2728, Train Accuracy: 19.86%
#     Worker 2: Train Loss: 3.2718, Train Accuracy: 20.94%
#     Worker 3: Train Loss: 3.3238, Train Accuracy: 19.78%
#     Worker 4: Train Loss: 3.2361, Train Accuracy: 20.65%
#     Worker 5: Train Loss: 3.2215, Train Accuracy: 21.15%
#     Worker 6: Train Loss: 3.3218, Train Accuracy: 19.75%
#     Worker 7: Train Loss: 3.2786, Train Accuracy: 20.30%
# Total Computation Time: 373.99 seconds
# Total Communication Time: 0.35 seconds
# Epoch 15/150: Test Loss: 3.0383, Test Accuracy: 25.64%
#     Worker 0: Train Loss: 3.2320, Train Accuracy: 20.46%
#     Worker 1: Train Loss: 3.2168, Train Accuracy: 21.19%
#     Worker 2: Train Loss: 3.2131, Train Accuracy: 22.05%
#     Worker 3: Train Loss: 3.2276, Train Accuracy: 21.37%
#     Worker 4: Train Loss: 3.1884, Train Accuracy: 21.73%
#     Worker 5: Train Loss: 3.1864, Train Accuracy: 22.19%
#     Worker 6: Train Loss: 3.2287, Train Accuracy: 20.91%
#     Worker 7: Train Loss: 3.1993, Train Accuracy: 21.56%
# Total Computation Time: 400.19 seconds
# Total Communication Time: 0.37 seconds
# Epoch 16/150: Test Loss: 2.9878, Test Accuracy: 26.96%
#     Worker 0: Train Loss: 3.1694, Train Accuracy: 21.91%
#     Worker 1: Train Loss: 3.1439, Train Accuracy: 22.22%
#     Worker 2: Train Loss: 3.1680, Train Accuracy: 23.08%
#     Worker 3: Train Loss: 3.1846, Train Accuracy: 21.68%
#     Worker 4: Train Loss: 3.1451, Train Accuracy: 22.07%
#     Worker 5: Train Loss: 3.1437, Train Accuracy: 22.60%
#     Worker 6: Train Loss: 3.2006, Train Accuracy: 21.80%
#     Worker 7: Train Loss: 3.1587, Train Accuracy: 22.74%
# Total Computation Time: 426.15 seconds
# Total Communication Time: 0.39 seconds
# Epoch 17/150: Test Loss: 2.9395, Test Accuracy: 27.80%
#     Worker 0: Train Loss: 3.1501, Train Accuracy: 22.54%
#     Worker 1: Train Loss: 3.1078, Train Accuracy: 23.55%
#     Worker 2: Train Loss: 3.0998, Train Accuracy: 23.64%
#     Worker 3: Train Loss: 3.1428, Train Accuracy: 21.90%
#     Worker 4: Train Loss: 3.0878, Train Accuracy: 23.92%
#     Worker 5: Train Loss: 3.0680, Train Accuracy: 24.98%
#     Worker 6: Train Loss: 3.1555, Train Accuracy: 22.01%
#     Worker 7: Train Loss: 3.1438, Train Accuracy: 22.87%
# Total Computation Time: 452.11 seconds
# Total Communication Time: 0.41 seconds
# Epoch 18/150: Test Loss: 2.8912, Test Accuracy: 28.89%
#     Worker 0: Train Loss: 3.0882, Train Accuracy: 23.22%
#     Worker 1: Train Loss: 3.0634, Train Accuracy: 24.17%
#     Worker 2: Train Loss: 3.0783, Train Accuracy: 24.36%
#     Worker 3: Train Loss: 3.1074, Train Accuracy: 23.33%
#     Worker 4: Train Loss: 3.0160, Train Accuracy: 24.59%
#     Worker 5: Train Loss: 3.0528, Train Accuracy: 24.94%
#     Worker 6: Train Loss: 3.0920, Train Accuracy: 24.08%
#     Worker 7: Train Loss: 3.0599, Train Accuracy: 24.41%
# Total Computation Time: 479.20 seconds
# Total Communication Time: 0.43 seconds
# Epoch 19/150: Test Loss: 2.8719, Test Accuracy: 29.21%
#     Worker 0: Train Loss: 3.0334, Train Accuracy: 25.02%
#     Worker 1: Train Loss: 2.9928, Train Accuracy: 24.92%
#     Worker 2: Train Loss: 3.0547, Train Accuracy: 24.80%
#     Worker 3: Train Loss: 3.0751, Train Accuracy: 23.69%
#     Worker 4: Train Loss: 3.0178, Train Accuracy: 24.78%
#     Worker 5: Train Loss: 2.9988, Train Accuracy: 26.14%
#     Worker 6: Train Loss: 3.0747, Train Accuracy: 23.99%
#     Worker 7: Train Loss: 3.0334, Train Accuracy: 24.74%
# Total Computation Time: 506.65 seconds
# Total Communication Time: 0.45 seconds
# Epoch 20/150: Test Loss: 2.8056, Test Accuracy: 30.45%
#     Worker 0: Train Loss: 2.9776, Train Accuracy: 25.44%
#     Worker 1: Train Loss: 2.9933, Train Accuracy: 25.06%
#     Worker 2: Train Loss: 2.9853, Train Accuracy: 26.21%
#     Worker 3: Train Loss: 3.0194, Train Accuracy: 24.67%
#     Worker 4: Train Loss: 2.9553, Train Accuracy: 26.48%
#     Worker 5: Train Loss: 2.9428, Train Accuracy: 26.38%
#     Worker 6: Train Loss: 3.0024, Train Accuracy: 24.91%
#     Worker 7: Train Loss: 2.9913, Train Accuracy: 25.99%
# Total Computation Time: 532.86 seconds
# Total Communication Time: 0.47 seconds
# Epoch 21/150: Test Loss: 2.7591, Test Accuracy: 31.38%
#     Worker 0: Train Loss: 2.9750, Train Accuracy: 26.56%
#     Worker 1: Train Loss: 2.9478, Train Accuracy: 26.17%
#     Worker 2: Train Loss: 2.9434, Train Accuracy: 27.05%
#     Worker 3: Train Loss: 2.9635, Train Accuracy: 25.69%
#     Worker 4: Train Loss: 2.9190, Train Accuracy: 26.24%
#     Worker 5: Train Loss: 2.8838, Train Accuracy: 27.85%
#     Worker 6: Train Loss: 2.9722, Train Accuracy: 25.93%
#     Worker 7: Train Loss: 2.9489, Train Accuracy: 26.68%
# Total Computation Time: 559.45 seconds
# Total Communication Time: 0.49 seconds
# Epoch 22/150: Test Loss: 2.7207, Test Accuracy: 32.06%
#     Worker 0: Train Loss: 2.9107, Train Accuracy: 27.08%
#     Worker 1: Train Loss: 2.8654, Train Accuracy: 27.48%
#     Worker 2: Train Loss: 2.8943, Train Accuracy: 27.90%
#     Worker 3: Train Loss: 2.9354, Train Accuracy: 26.80%
#     Worker 4: Train Loss: 2.8793, Train Accuracy: 27.47%
#     Worker 5: Train Loss: 2.8405, Train Accuracy: 28.90%
#     Worker 6: Train Loss: 2.9161, Train Accuracy: 27.26%
#     Worker 7: Train Loss: 2.9194, Train Accuracy: 27.37%
# Total Computation Time: 586.96 seconds
# Total Communication Time: 0.51 seconds
# Epoch 23/150: Test Loss: 2.6756, Test Accuracy: 32.97%
#     Worker 0: Train Loss: 2.8934, Train Accuracy: 27.61%
#     Worker 1: Train Loss: 2.8619, Train Accuracy: 27.62%
#     Worker 2: Train Loss: 2.8669, Train Accuracy: 28.87%
#     Worker 3: Train Loss: 2.8735, Train Accuracy: 27.61%
#     Worker 4: Train Loss: 2.8146, Train Accuracy: 28.60%
#     Worker 5: Train Loss: 2.8024, Train Accuracy: 29.82%
#     Worker 6: Train Loss: 2.8945, Train Accuracy: 27.19%
#     Worker 7: Train Loss: 2.8536, Train Accuracy: 27.74%
# Total Computation Time: 613.32 seconds
# Total Communication Time: 0.53 seconds
# Epoch 24/150: Test Loss: 2.6505, Test Accuracy: 33.24%
#     Worker 0: Train Loss: 2.8608, Train Accuracy: 28.13%
#     Worker 1: Train Loss: 2.8002, Train Accuracy: 28.66%
#     Worker 2: Train Loss: 2.7949, Train Accuracy: 29.79%
#     Worker 3: Train Loss: 2.8694, Train Accuracy: 27.75%
#     Worker 4: Train Loss: 2.8007, Train Accuracy: 28.59%
#     Worker 5: Train Loss: 2.7930, Train Accuracy: 29.65%
#     Worker 6: Train Loss: 2.8600, Train Accuracy: 28.27%
#     Worker 7: Train Loss: 2.8179, Train Accuracy: 29.26%
# Total Computation Time: 639.57 seconds
# Total Communication Time: 0.55 seconds
# Epoch 25/150: Test Loss: 2.5977, Test Accuracy: 34.31%
#     Worker 0: Train Loss: 2.7916, Train Accuracy: 30.03%
#     Worker 1: Train Loss: 2.7719, Train Accuracy: 29.61%
#     Worker 2: Train Loss: 2.7901, Train Accuracy: 30.37%
#     Worker 3: Train Loss: 2.7832, Train Accuracy: 29.04%
#     Worker 4: Train Loss: 2.7471, Train Accuracy: 29.65%
#     Worker 5: Train Loss: 2.7242, Train Accuracy: 31.47%
#     Worker 6: Train Loss: 2.7922, Train Accuracy: 29.47%
#     Worker 7: Train Loss: 2.7939, Train Accuracy: 29.43%
# Total Computation Time: 666.75 seconds
# Total Communication Time: 0.57 seconds
# Epoch 26/150: Test Loss: 2.5831, Test Accuracy: 35.02%
#     Worker 0: Train Loss: 2.7679, Train Accuracy: 29.81%
#     Worker 1: Train Loss: 2.7387, Train Accuracy: 30.56%
#     Worker 2: Train Loss: 2.7529, Train Accuracy: 30.23%
#     Worker 3: Train Loss: 2.7810, Train Accuracy: 29.78%
#     Worker 4: Train Loss: 2.7079, Train Accuracy: 31.30%
#     Worker 5: Train Loss: 2.7349, Train Accuracy: 31.02%
#     Worker 6: Train Loss: 2.7879, Train Accuracy: 28.93%
#     Worker 7: Train Loss: 2.7392, Train Accuracy: 30.58%
# Total Computation Time: 693.18 seconds
# Total Communication Time: 0.59 seconds
# Epoch 27/150: Test Loss: 2.5373, Test Accuracy: 35.89%
#     Worker 0: Train Loss: 2.7409, Train Accuracy: 30.51%
#     Worker 1: Train Loss: 2.6850, Train Accuracy: 31.99%
#     Worker 2: Train Loss: 2.6883, Train Accuracy: 32.00%
#     Worker 3: Train Loss: 2.7337, Train Accuracy: 30.49%
#     Worker 4: Train Loss: 2.6957, Train Accuracy: 31.26%
#     Worker 5: Train Loss: 2.6708, Train Accuracy: 32.13%
#     Worker 6: Train Loss: 2.7306, Train Accuracy: 31.37%
#     Worker 7: Train Loss: 2.7051, Train Accuracy: 30.91%
# Total Computation Time: 719.18 seconds
# Total Communication Time: 0.61 seconds
# Epoch 28/150: Test Loss: 2.5093, Test Accuracy: 35.99%
#     Worker 0: Train Loss: 2.6803, Train Accuracy: 32.06%
#     Worker 1: Train Loss: 2.6495, Train Accuracy: 32.00%
#     Worker 2: Train Loss: 2.6985, Train Accuracy: 31.40%
#     Worker 3: Train Loss: 2.6878, Train Accuracy: 31.57%
#     Worker 4: Train Loss: 2.6380, Train Accuracy: 32.06%
#     Worker 5: Train Loss: 2.6267, Train Accuracy: 33.35%
#     Worker 6: Train Loss: 2.6782, Train Accuracy: 31.29%
#     Worker 7: Train Loss: 2.6639, Train Accuracy: 32.03%
# Total Computation Time: 745.35 seconds
# Total Communication Time: 0.63 seconds
# Epoch 29/150: Test Loss: 2.4837, Test Accuracy: 36.77%
#     Worker 0: Train Loss: 2.6242, Train Accuracy: 32.77%
#     Worker 1: Train Loss: 2.6349, Train Accuracy: 32.28%
#     Worker 2: Train Loss: 2.6309, Train Accuracy: 32.47%
#     Worker 3: Train Loss: 2.6735, Train Accuracy: 32.13%
#     Worker 4: Train Loss: 2.5725, Train Accuracy: 33.84%
#     Worker 5: Train Loss: 2.6362, Train Accuracy: 33.14%
#     Worker 6: Train Loss: 2.6471, Train Accuracy: 31.81%
#     Worker 7: Train Loss: 2.6272, Train Accuracy: 32.54%
# Total Computation Time: 771.39 seconds
# Total Communication Time: 0.65 seconds
# Epoch 30/150: Test Loss: 2.4598, Test Accuracy: 37.37%
#     Worker 0: Train Loss: 2.6664, Train Accuracy: 31.93%
#     Worker 1: Train Loss: 2.6195, Train Accuracy: 32.70%
#     Worker 2: Train Loss: 2.6142, Train Accuracy: 33.26%
#     Worker 3: Train Loss: 2.6414, Train Accuracy: 32.38%
#     Worker 4: Train Loss: 2.5812, Train Accuracy: 33.61%
#     Worker 5: Train Loss: 2.5449, Train Accuracy: 35.05%
#     Worker 6: Train Loss: 2.6266, Train Accuracy: 32.97%
#     Worker 7: Train Loss: 2.6410, Train Accuracy: 32.70%
# Total Computation Time: 797.44 seconds
# Total Communication Time: 0.67 seconds
# Epoch 31/150: Test Loss: 2.4320, Test Accuracy: 37.49%
#     Worker 0: Train Loss: 2.5881, Train Accuracy: 33.01%
#     Worker 1: Train Loss: 2.5298, Train Accuracy: 34.79%
#     Worker 2: Train Loss: 2.5722, Train Accuracy: 33.53%
#     Worker 3: Train Loss: 2.5952, Train Accuracy: 32.51%
#     Worker 4: Train Loss: 2.5179, Train Accuracy: 34.98%
#     Worker 5: Train Loss: 2.5546, Train Accuracy: 34.14%
#     Worker 6: Train Loss: 2.6175, Train Accuracy: 32.49%
#     Worker 7: Train Loss: 2.5773, Train Accuracy: 33.64%
# Total Computation Time: 823.79 seconds
# Total Communication Time: 0.69 seconds
# Epoch 32/150: Test Loss: 2.4105, Test Accuracy: 38.26%
#     Worker 0: Train Loss: 2.5400, Train Accuracy: 34.58%
#     Worker 1: Train Loss: 2.5256, Train Accuracy: 34.40%
#     Worker 2: Train Loss: 2.5504, Train Accuracy: 33.84%
#     Worker 3: Train Loss: 2.5957, Train Accuracy: 32.79%
#     Worker 4: Train Loss: 2.5096, Train Accuracy: 34.93%
#     Worker 5: Train Loss: 2.5490, Train Accuracy: 35.19%
#     Worker 6: Train Loss: 2.5483, Train Accuracy: 34.55%
#     Worker 7: Train Loss: 2.5528, Train Accuracy: 34.34%
# Total Computation Time: 850.19 seconds
# Total Communication Time: 0.71 seconds
# Epoch 33/150: Test Loss: 2.3909, Test Accuracy: 38.57%
#     Worker 0: Train Loss: 2.5354, Train Accuracy: 34.76%
#     Worker 1: Train Loss: 2.5202, Train Accuracy: 34.73%
#     Worker 2: Train Loss: 2.5185, Train Accuracy: 35.54%
#     Worker 3: Train Loss: 2.5632, Train Accuracy: 32.79%
#     Worker 4: Train Loss: 2.4807, Train Accuracy: 35.77%
#     Worker 5: Train Loss: 2.4707, Train Accuracy: 36.71%
#     Worker 6: Train Loss: 2.5421, Train Accuracy: 34.26%
#     Worker 7: Train Loss: 2.5174, Train Accuracy: 35.15%
# Total Computation Time: 876.59 seconds
# Total Communication Time: 0.73 seconds
# Epoch 34/150: Test Loss: 2.3742, Test Accuracy: 39.02%
#     Worker 0: Train Loss: 2.5175, Train Accuracy: 35.10%
#     Worker 1: Train Loss: 2.4675, Train Accuracy: 35.87%
#     Worker 2: Train Loss: 2.5115, Train Accuracy: 34.73%
#     Worker 3: Train Loss: 2.5223, Train Accuracy: 35.08%
#     Worker 4: Train Loss: 2.4626, Train Accuracy: 36.41%
#     Worker 5: Train Loss: 2.4776, Train Accuracy: 36.44%
#     Worker 6: Train Loss: 2.4866, Train Accuracy: 35.67%
#     Worker 7: Train Loss: 2.5083, Train Accuracy: 35.31%
# Total Computation Time: 902.62 seconds
# Total Communication Time: 0.75 seconds
# Epoch 35/150: Test Loss: 2.3478, Test Accuracy: 39.55%
#     Worker 0: Train Loss: 2.4737, Train Accuracy: 35.99%
#     Worker 1: Train Loss: 2.4788, Train Accuracy: 35.58%
#     Worker 2: Train Loss: 2.4687, Train Accuracy: 36.36%
#     Worker 3: Train Loss: 2.4903, Train Accuracy: 35.85%
#     Worker 4: Train Loss: 2.4607, Train Accuracy: 35.68%
#     Worker 5: Train Loss: 2.4809, Train Accuracy: 35.72%
#     Worker 6: Train Loss: 2.4760, Train Accuracy: 36.75%
#     Worker 7: Train Loss: 2.4681, Train Accuracy: 35.67%
# Total Computation Time: 928.77 seconds
# Total Communication Time: 0.77 seconds
# Epoch 36/150: Test Loss: 2.3287, Test Accuracy: 39.76%
#     Worker 0: Train Loss: 2.4615, Train Accuracy: 36.02%
#     Worker 1: Train Loss: 2.4101, Train Accuracy: 36.47%
#     Worker 2: Train Loss: 2.4457, Train Accuracy: 36.50%
#     Worker 3: Train Loss: 2.4618, Train Accuracy: 36.38%
#     Worker 4: Train Loss: 2.3983, Train Accuracy: 37.66%
#     Worker 5: Train Loss: 2.4481, Train Accuracy: 36.31%
#     Worker 6: Train Loss: 2.4755, Train Accuracy: 36.08%
#     Worker 7: Train Loss: 2.4316, Train Accuracy: 37.06%
# Total Computation Time: 955.04 seconds
# Total Communication Time: 0.79 seconds
# Epoch 37/150: Test Loss: 2.3111, Test Accuracy: 40.52%
#     Worker 0: Train Loss: 2.4260, Train Accuracy: 37.06%
#     Worker 1: Train Loss: 2.4160, Train Accuracy: 36.59%
#     Worker 2: Train Loss: 2.4314, Train Accuracy: 36.97%
#     Worker 3: Train Loss: 2.4350, Train Accuracy: 36.59%
#     Worker 4: Train Loss: 2.3609, Train Accuracy: 38.66%
#     Worker 5: Train Loss: 2.3619, Train Accuracy: 38.80%
#     Worker 6: Train Loss: 2.4349, Train Accuracy: 36.73%
#     Worker 7: Train Loss: 2.4214, Train Accuracy: 36.85%
# Total Computation Time: 981.56 seconds
# Total Communication Time: 0.81 seconds
# Epoch 38/150: Test Loss: 2.3000, Test Accuracy: 40.62%
#     Worker 0: Train Loss: 2.3906, Train Accuracy: 37.69%
#     Worker 1: Train Loss: 2.3254, Train Accuracy: 39.14%
#     Worker 2: Train Loss: 2.4166, Train Accuracy: 37.77%
#     Worker 3: Train Loss: 2.4270, Train Accuracy: 36.50%
#     Worker 4: Train Loss: 2.3732, Train Accuracy: 38.06%
#     Worker 5: Train Loss: 2.3803, Train Accuracy: 37.41%
#     Worker 6: Train Loss: 2.4123, Train Accuracy: 37.17%
#     Worker 7: Train Loss: 2.4105, Train Accuracy: 37.25%
# Total Computation Time: 1008.32 seconds
# Total Communication Time: 0.83 seconds
# Epoch 39/150: Test Loss: 2.2741, Test Accuracy: 40.87%
#     Worker 0: Train Loss: 2.3891, Train Accuracy: 37.81%
#     Worker 1: Train Loss: 2.3959, Train Accuracy: 37.62%
#     Worker 2: Train Loss: 2.3632, Train Accuracy: 37.92%
#     Worker 3: Train Loss: 2.4307, Train Accuracy: 36.54%
#     Worker 4: Train Loss: 2.3392, Train Accuracy: 39.11%
#     Worker 5: Train Loss: 2.3423, Train Accuracy: 39.49%
#     Worker 6: Train Loss: 2.3953, Train Accuracy: 36.94%
#     Worker 7: Train Loss: 2.3721, Train Accuracy: 38.69%
# Total Computation Time: 1034.71 seconds
# Total Communication Time: 0.85 seconds
# Epoch 40/150: Test Loss: 2.2680, Test Accuracy: 41.24%
#     Worker 0: Train Loss: 2.3895, Train Accuracy: 37.52%
#     Worker 1: Train Loss: 2.3366, Train Accuracy: 38.40%
#     Worker 2: Train Loss: 2.3840, Train Accuracy: 38.32%
#     Worker 3: Train Loss: 2.3819, Train Accuracy: 37.87%
#     Worker 4: Train Loss: 2.3122, Train Accuracy: 39.20%
#     Worker 5: Train Loss: 2.2999, Train Accuracy: 39.87%
#     Worker 6: Train Loss: 2.3314, Train Accuracy: 38.41%
#     Worker 7: Train Loss: 2.3308, Train Accuracy: 38.64%
# Total Computation Time: 1060.76 seconds
# Total Communication Time: 0.87 seconds
# Epoch 41/150: Test Loss: 2.2501, Test Accuracy: 41.91%
#     Worker 0: Train Loss: 2.3194, Train Accuracy: 38.71%
#     Worker 1: Train Loss: 2.3240, Train Accuracy: 38.78%
#     Worker 2: Train Loss: 2.3240, Train Accuracy: 39.35%
#     Worker 3: Train Loss: 2.3537, Train Accuracy: 38.33%
#     Worker 4: Train Loss: 2.3054, Train Accuracy: 39.31%
#     Worker 5: Train Loss: 2.3040, Train Accuracy: 39.99%
#     Worker 6: Train Loss: 2.3693, Train Accuracy: 38.06%
#     Worker 7: Train Loss: 2.3309, Train Accuracy: 39.41%
# Total Computation Time: 1086.55 seconds
# Total Communication Time: 0.89 seconds
# Epoch 42/150: Test Loss: 2.2408, Test Accuracy: 42.21%
#     Worker 0: Train Loss: 2.3163, Train Accuracy: 39.04%
#     Worker 1: Train Loss: 2.2920, Train Accuracy: 38.98%
#     Worker 2: Train Loss: 2.3290, Train Accuracy: 38.80%
#     Worker 3: Train Loss: 2.3146, Train Accuracy: 39.19%
#     Worker 4: Train Loss: 2.2843, Train Accuracy: 39.92%
#     Worker 5: Train Loss: 2.3093, Train Accuracy: 39.87%
#     Worker 6: Train Loss: 2.3195, Train Accuracy: 38.70%
#     Worker 7: Train Loss: 2.3155, Train Accuracy: 38.98%
# Total Computation Time: 1112.59 seconds
# Total Communication Time: 0.91 seconds
# Epoch 43/150: Test Loss: 2.2182, Test Accuracy: 42.49%
#     Worker 0: Train Loss: 2.3188, Train Accuracy: 39.21%
#     Worker 1: Train Loss: 2.2644, Train Accuracy: 39.94%
#     Worker 2: Train Loss: 2.2736, Train Accuracy: 40.11%
#     Worker 3: Train Loss: 2.2974, Train Accuracy: 39.32%
#     Worker 4: Train Loss: 2.2632, Train Accuracy: 40.34%
#     Worker 5: Train Loss: 2.2592, Train Accuracy: 40.83%
#     Worker 6: Train Loss: 2.3117, Train Accuracy: 39.35%
#     Worker 7: Train Loss: 2.2631, Train Accuracy: 40.32%
# Total Computation Time: 1138.53 seconds
# Total Communication Time: 0.93 seconds
# Epoch 44/150: Test Loss: 2.2071, Test Accuracy: 42.84%
#     Worker 0: Train Loss: 2.2755, Train Accuracy: 40.23%
#     Worker 1: Train Loss: 2.2276, Train Accuracy: 40.34%
#     Worker 2: Train Loss: 2.2795, Train Accuracy: 40.15%
#     Worker 3: Train Loss: 2.2728, Train Accuracy: 39.92%
#     Worker 4: Train Loss: 2.2025, Train Accuracy: 42.04%
#     Worker 5: Train Loss: 2.2419, Train Accuracy: 41.20%
#     Worker 6: Train Loss: 2.2801, Train Accuracy: 39.90%
#     Worker 7: Train Loss: 2.2745, Train Accuracy: 40.27%
# Total Computation Time: 1165.26 seconds
# Total Communication Time: 0.95 seconds
# Epoch 45/150: Test Loss: 2.1919, Test Accuracy: 42.70%
#     Worker 0: Train Loss: 2.2467, Train Accuracy: 40.12%
#     Worker 1: Train Loss: 2.2445, Train Accuracy: 40.88%
#     Worker 2: Train Loss: 2.2478, Train Accuracy: 41.97%
#     Worker 3: Train Loss: 2.2876, Train Accuracy: 39.78%
#     Worker 4: Train Loss: 2.2338, Train Accuracy: 40.89%
#     Worker 5: Train Loss: 2.2101, Train Accuracy: 42.15%
#     Worker 6: Train Loss: 2.2632, Train Accuracy: 40.68%
#     Worker 7: Train Loss: 2.2489, Train Accuracy: 40.95%
# Total Computation Time: 1191.91 seconds
# Total Communication Time: 0.97 seconds
# Epoch 46/150: Test Loss: 2.1766, Test Accuracy: 43.20%
#     Worker 0: Train Loss: 2.2332, Train Accuracy: 39.91%
#     Worker 1: Train Loss: 2.2307, Train Accuracy: 40.51%
#     Worker 2: Train Loss: 2.2066, Train Accuracy: 41.74%
#     Worker 3: Train Loss: 2.2653, Train Accuracy: 40.01%
#     Worker 4: Train Loss: 2.1959, Train Accuracy: 41.51%
#     Worker 5: Train Loss: 2.2055, Train Accuracy: 42.02%
#     Worker 6: Train Loss: 2.2556, Train Accuracy: 39.98%
#     Worker 7: Train Loss: 2.2196, Train Accuracy: 41.79%
# Total Computation Time: 1217.98 seconds
# Total Communication Time: 0.99 seconds
# Epoch 47/150: Test Loss: 2.1725, Test Accuracy: 43.33%
#     Worker 0: Train Loss: 2.2192, Train Accuracy: 41.07%
#     Worker 1: Train Loss: 2.1840, Train Accuracy: 41.74%
#     Worker 2: Train Loss: 2.1896, Train Accuracy: 41.49%
#     Worker 3: Train Loss: 2.2042, Train Accuracy: 41.10%
#     Worker 4: Train Loss: 2.1566, Train Accuracy: 42.71%
#     Worker 5: Train Loss: 2.1965, Train Accuracy: 42.32%
#     Worker 6: Train Loss: 2.2159, Train Accuracy: 41.62%
#     Worker 7: Train Loss: 2.2159, Train Accuracy: 41.62%
# Total Computation Time: 1244.09 seconds
# Total Communication Time: 1.01 seconds
# Epoch 48/150: Test Loss: 2.1589, Test Accuracy: 43.40%
#     Worker 0: Train Loss: 2.1972, Train Accuracy: 41.94%
#     Worker 1: Train Loss: 2.1773, Train Accuracy: 42.15%
#     Worker 2: Train Loss: 2.1697, Train Accuracy: 42.58%
#     Worker 3: Train Loss: 2.1997, Train Accuracy: 41.73%
#     Worker 4: Train Loss: 2.1687, Train Accuracy: 42.72%
#     Worker 5: Train Loss: 2.1647, Train Accuracy: 42.61%
#     Worker 6: Train Loss: 2.2231, Train Accuracy: 40.75%
#     Worker 7: Train Loss: 2.2013, Train Accuracy: 41.67%
# Total Computation Time: 1270.63 seconds
# Total Communication Time: 1.03 seconds
# Epoch 49/150: Test Loss: 2.1437, Test Accuracy: 44.09%
#     Worker 0: Train Loss: 2.1791, Train Accuracy: 42.27%
#     Worker 1: Train Loss: 2.1451, Train Accuracy: 42.38%
#     Worker 2: Train Loss: 2.1815, Train Accuracy: 41.73%
#     Worker 3: Train Loss: 2.1998, Train Accuracy: 41.65%
#     Worker 4: Train Loss: 2.1292, Train Accuracy: 42.98%
#     Worker 5: Train Loss: 2.1506, Train Accuracy: 42.70%
#     Worker 6: Train Loss: 2.1901, Train Accuracy: 42.50%
#     Worker 7: Train Loss: 2.1465, Train Accuracy: 42.66%
# Total Computation Time: 1296.69 seconds
# Total Communication Time: 1.05 seconds
# Epoch 50/150: Test Loss: 2.1369, Test Accuracy: 44.66%
#     Worker 0: Train Loss: 2.1591, Train Accuracy: 42.00%
#     Worker 1: Train Loss: 2.1434, Train Accuracy: 42.79%
#     Worker 2: Train Loss: 2.1578, Train Accuracy: 42.71%
#     Worker 3: Train Loss: 2.1753, Train Accuracy: 42.14%
#     Worker 4: Train Loss: 2.1182, Train Accuracy: 42.77%
#     Worker 5: Train Loss: 2.1301, Train Accuracy: 44.07%
#     Worker 6: Train Loss: 2.1739, Train Accuracy: 42.09%
#     Worker 7: Train Loss: 2.1635, Train Accuracy: 42.96%
# Total Computation Time: 1323.46 seconds
# Total Communication Time: 1.07 seconds
# Epoch 51/150: Test Loss: 2.1265, Test Accuracy: 44.45%
#     Worker 0: Train Loss: 2.1537, Train Accuracy: 42.56%
#     Worker 1: Train Loss: 2.1028, Train Accuracy: 43.52%
#     Worker 2: Train Loss: 2.1400, Train Accuracy: 43.42%
#     Worker 3: Train Loss: 2.1633, Train Accuracy: 42.11%
#     Worker 4: Train Loss: 2.1058, Train Accuracy: 43.95%
#     Worker 5: Train Loss: 2.1273, Train Accuracy: 43.17%
#     Worker 6: Train Loss: 2.1338, Train Accuracy: 43.69%
#     Worker 7: Train Loss: 2.1201, Train Accuracy: 42.81%
# Total Computation Time: 1350.11 seconds
# Total Communication Time: 1.09 seconds
# Epoch 52/150: Test Loss: 2.1200, Test Accuracy: 44.62%
#     Worker 0: Train Loss: 2.1088, Train Accuracy: 43.03%
#     Worker 1: Train Loss: 2.1040, Train Accuracy: 44.00%
#     Worker 2: Train Loss: 2.1139, Train Accuracy: 43.74%
#     Worker 3: Train Loss: 2.1606, Train Accuracy: 42.11%
#     Worker 4: Train Loss: 2.1107, Train Accuracy: 43.31%
#     Worker 5: Train Loss: 2.1156, Train Accuracy: 42.84%
#     Worker 6: Train Loss: 2.1193, Train Accuracy: 43.59%
#     Worker 7: Train Loss: 2.1209, Train Accuracy: 42.40%
# Total Computation Time: 1376.40 seconds
# Total Communication Time: 1.11 seconds
# Epoch 53/150: Test Loss: 2.1174, Test Accuracy: 45.03%
#     Worker 0: Train Loss: 2.1255, Train Accuracy: 43.06%
#     Worker 1: Train Loss: 2.0524, Train Accuracy: 45.26%
#     Worker 2: Train Loss: 2.1023, Train Accuracy: 44.39%
#     Worker 3: Train Loss: 2.1040, Train Accuracy: 44.00%
#     Worker 4: Train Loss: 2.0606, Train Accuracy: 44.72%
#     Worker 5: Train Loss: 2.0711, Train Accuracy: 44.82%
#     Worker 6: Train Loss: 2.1163, Train Accuracy: 43.72%
#     Worker 7: Train Loss: 2.0918, Train Accuracy: 43.76%
# Total Computation Time: 1402.59 seconds
# Total Communication Time: 1.13 seconds
# Epoch 54/150: Test Loss: 2.1118, Test Accuracy: 44.96%
#     Worker 0: Train Loss: 2.1041, Train Accuracy: 42.93%
#     Worker 1: Train Loss: 2.0679, Train Accuracy: 44.71%
#     Worker 2: Train Loss: 2.0631, Train Accuracy: 44.78%
#     Worker 3: Train Loss: 2.1208, Train Accuracy: 43.46%
#     Worker 4: Train Loss: 2.0270, Train Accuracy: 45.28%
#     Worker 5: Train Loss: 2.0907, Train Accuracy: 44.98%
#     Worker 6: Train Loss: 2.1061, Train Accuracy: 43.20%
#     Worker 7: Train Loss: 2.0992, Train Accuracy: 43.52%
# Total Computation Time: 1429.43 seconds
# Total Communication Time: 1.15 seconds
# Epoch 55/150: Test Loss: 2.1039, Test Accuracy: 45.28%
#     Worker 0: Train Loss: 2.0739, Train Accuracy: 44.42%
#     Worker 1: Train Loss: 2.0570, Train Accuracy: 44.91%
#     Worker 2: Train Loss: 2.0575, Train Accuracy: 45.68%
#     Worker 3: Train Loss: 2.0854, Train Accuracy: 43.80%
#     Worker 4: Train Loss: 2.0582, Train Accuracy: 45.00%
#     Worker 5: Train Loss: 2.0645, Train Accuracy: 44.79%
#     Worker 6: Train Loss: 2.0700, Train Accuracy: 44.33%
#     Worker 7: Train Loss: 2.0651, Train Accuracy: 44.74%
# Total Computation Time: 1455.48 seconds
# Total Communication Time: 1.17 seconds
# Epoch 56/150: Test Loss: 2.0902, Test Accuracy: 45.46%
#     Worker 0: Train Loss: 2.0512, Train Accuracy: 44.64%
#     Worker 1: Train Loss: 2.0275, Train Accuracy: 45.00%
#     Worker 2: Train Loss: 2.0431, Train Accuracy: 44.58%
#     Worker 3: Train Loss: 2.0671, Train Accuracy: 44.41%
#     Worker 4: Train Loss: 2.0283, Train Accuracy: 45.20%
#     Worker 5: Train Loss: 2.0308, Train Accuracy: 45.97%
#     Worker 6: Train Loss: 2.0711, Train Accuracy: 44.89%
#     Worker 7: Train Loss: 2.0419, Train Accuracy: 45.49%
# Total Computation Time: 1481.53 seconds
# Total Communication Time: 1.19 seconds
# Epoch 57/150: Test Loss: 2.0880, Test Accuracy: 45.44%
#     Worker 0: Train Loss: 2.0615, Train Accuracy: 45.35%
#     Worker 1: Train Loss: 2.0079, Train Accuracy: 45.61%
#     Worker 2: Train Loss: 2.0247, Train Accuracy: 46.10%
#     Worker 3: Train Loss: 2.0458, Train Accuracy: 45.16%
#     Worker 4: Train Loss: 1.9934, Train Accuracy: 46.07%
#     Worker 5: Train Loss: 2.0037, Train Accuracy: 46.17%
#     Worker 6: Train Loss: 2.0467, Train Accuracy: 45.26%
#     Worker 7: Train Loss: 2.0314, Train Accuracy: 45.09%
# Total Computation Time: 1509.12 seconds
# Total Communication Time: 1.21 seconds
# Epoch 58/150: Test Loss: 2.0741, Test Accuracy: 45.86%
#     Worker 0: Train Loss: 2.0113, Train Accuracy: 45.13%
#     Worker 1: Train Loss: 1.9969, Train Accuracy: 45.80%
#     Worker 2: Train Loss: 2.0244, Train Accuracy: 45.47%
#     Worker 3: Train Loss: 2.0349, Train Accuracy: 45.47%
#     Worker 4: Train Loss: 1.9890, Train Accuracy: 46.88%
#     Worker 5: Train Loss: 2.0289, Train Accuracy: 45.89%
#     Worker 6: Train Loss: 2.0299, Train Accuracy: 45.20%
#     Worker 7: Train Loss: 2.0253, Train Accuracy: 45.63%
# Total Computation Time: 1535.60 seconds
# Total Communication Time: 1.22 seconds
# Epoch 59/150: Test Loss: 2.0679, Test Accuracy: 45.86%
#     Worker 0: Train Loss: 2.0117, Train Accuracy: 45.20%
#     Worker 1: Train Loss: 1.9841, Train Accuracy: 46.24%
#     Worker 2: Train Loss: 2.0093, Train Accuracy: 45.79%
#     Worker 3: Train Loss: 2.0225, Train Accuracy: 46.01%
#     Worker 4: Train Loss: 1.9889, Train Accuracy: 47.09%
#     Worker 5: Train Loss: 1.9855, Train Accuracy: 46.46%
#     Worker 6: Train Loss: 2.0461, Train Accuracy: 45.30%
#     Worker 7: Train Loss: 2.0233, Train Accuracy: 45.10%
# Total Computation Time: 1561.99 seconds
# Total Communication Time: 1.25 seconds
# Epoch 60/150: Test Loss: 2.0627, Test Accuracy: 46.14%
#     Worker 0: Train Loss: 1.9777, Train Accuracy: 46.84%
#     Worker 1: Train Loss: 1.9711, Train Accuracy: 46.10%
#     Worker 2: Train Loss: 1.9836, Train Accuracy: 46.91%
#     Worker 3: Train Loss: 1.9652, Train Accuracy: 46.12%
#     Worker 4: Train Loss: 1.9381, Train Accuracy: 46.80%
#     Worker 5: Train Loss: 1.9544, Train Accuracy: 47.51%
#     Worker 6: Train Loss: 2.0133, Train Accuracy: 45.34%
#     Worker 7: Train Loss: 1.9794, Train Accuracy: 47.05%
# Total Computation Time: 1588.36 seconds
# Total Communication Time: 1.27 seconds
# Epoch 61/150: Test Loss: 2.0571, Test Accuracy: 46.10%
#     Worker 0: Train Loss: 1.9957, Train Accuracy: 46.45%
#     Worker 1: Train Loss: 1.9310, Train Accuracy: 47.27%
#     Worker 2: Train Loss: 1.9449, Train Accuracy: 47.57%
#     Worker 3: Train Loss: 1.9625, Train Accuracy: 46.68%
#     Worker 4: Train Loss: 1.9560, Train Accuracy: 47.08%
#     Worker 5: Train Loss: 1.9425, Train Accuracy: 48.00%
#     Worker 6: Train Loss: 2.0075, Train Accuracy: 46.35%
#     Worker 7: Train Loss: 1.9831, Train Accuracy: 46.45%
# Total Computation Time: 1614.44 seconds
# Total Communication Time: 1.29 seconds
# Epoch 62/150: Test Loss: 2.0433, Test Accuracy: 46.78%
#     Worker 0: Train Loss: 1.9643, Train Accuracy: 46.95%
#     Worker 1: Train Loss: 1.9335, Train Accuracy: 48.14%
#     Worker 2: Train Loss: 1.9692, Train Accuracy: 47.13%
#     Worker 3: Train Loss: 1.9702, Train Accuracy: 46.45%
#     Worker 4: Train Loss: 1.9348, Train Accuracy: 47.48%
#     Worker 5: Train Loss: 1.9456, Train Accuracy: 47.57%
#     Worker 6: Train Loss: 1.9583, Train Accuracy: 47.52%
#     Worker 7: Train Loss: 1.9499, Train Accuracy: 46.80%
# Total Computation Time: 1640.65 seconds
# Total Communication Time: 1.31 seconds
# Epoch 63/150: Test Loss: 2.0452, Test Accuracy: 46.51%
#     Worker 0: Train Loss: 1.9413, Train Accuracy: 46.80%
#     Worker 1: Train Loss: 1.9243, Train Accuracy: 48.67%
#     Worker 2: Train Loss: 1.9330, Train Accuracy: 47.94%
#     Worker 3: Train Loss: 1.9725, Train Accuracy: 46.57%
#     Worker 4: Train Loss: 1.8970, Train Accuracy: 48.47%
#     Worker 5: Train Loss: 1.9521, Train Accuracy: 47.05%
#     Worker 6: Train Loss: 1.9876, Train Accuracy: 46.45%
#     Worker 7: Train Loss: 1.9535, Train Accuracy: 46.32%
# Total Computation Time: 1667.62 seconds
# Total Communication Time: 1.33 seconds
# Epoch 64/150: Test Loss: 2.0368, Test Accuracy: 47.06%
#     Worker 0: Train Loss: 1.9301, Train Accuracy: 47.59%
#     Worker 1: Train Loss: 1.8837, Train Accuracy: 48.50%
#     Worker 2: Train Loss: 1.9147, Train Accuracy: 48.26%
#     Worker 3: Train Loss: 1.9530, Train Accuracy: 46.53%
#     Worker 4: Train Loss: 1.9135, Train Accuracy: 47.59%
#     Worker 5: Train Loss: 1.9139, Train Accuracy: 49.08%
#     Worker 6: Train Loss: 1.9184, Train Accuracy: 48.63%
#     Worker 7: Train Loss: 1.9338, Train Accuracy: 48.36%
# Total Computation Time: 1693.67 seconds
# Total Communication Time: 1.35 seconds
# Epoch 65/150: Test Loss: 2.0281, Test Accuracy: 46.87%
#     Worker 0: Train Loss: 1.9247, Train Accuracy: 47.86%
#     Worker 1: Train Loss: 1.8987, Train Accuracy: 48.26%
#     Worker 2: Train Loss: 1.9022, Train Accuracy: 48.32%
#     Worker 3: Train Loss: 1.9092, Train Accuracy: 48.45%
#     Worker 4: Train Loss: 1.8674, Train Accuracy: 48.68%
#     Worker 5: Train Loss: 1.8948, Train Accuracy: 48.84%
#     Worker 6: Train Loss: 1.9361, Train Accuracy: 47.65%
#     Worker 7: Train Loss: 1.9286, Train Accuracy: 47.82%
# Total Computation Time: 1719.83 seconds
# Total Communication Time: 1.37 seconds
# Epoch 66/150: Test Loss: 2.0348, Test Accuracy: 47.06%
#     Worker 0: Train Loss: 1.9014, Train Accuracy: 48.32%
#     Worker 1: Train Loss: 1.8851, Train Accuracy: 47.97%
#     Worker 2: Train Loss: 1.8921, Train Accuracy: 48.99%
#     Worker 3: Train Loss: 1.9141, Train Accuracy: 48.11%
#     Worker 4: Train Loss: 1.8854, Train Accuracy: 49.13%
#     Worker 5: Train Loss: 1.8740, Train Accuracy: 49.48%
#     Worker 6: Train Loss: 1.9188, Train Accuracy: 48.18%
#     Worker 7: Train Loss: 1.8956, Train Accuracy: 48.80%
# Total Computation Time: 1746.03 seconds
# Total Communication Time: 1.39 seconds
# Epoch 67/150: Test Loss: 2.0276, Test Accuracy: 46.91%
#     Worker 0: Train Loss: 1.9098, Train Accuracy: 48.38%
#     Worker 1: Train Loss: 1.8474, Train Accuracy: 49.68%
#     Worker 2: Train Loss: 1.8795, Train Accuracy: 49.24%
#     Worker 3: Train Loss: 1.8824, Train Accuracy: 49.73%
#     Worker 4: Train Loss: 1.8402, Train Accuracy: 49.92%
#     Worker 5: Train Loss: 1.8784, Train Accuracy: 49.26%
#     Worker 6: Train Loss: 1.9070, Train Accuracy: 48.28%
#     Worker 7: Train Loss: 1.8906, Train Accuracy: 48.21%
# Total Computation Time: 1772.14 seconds
# Total Communication Time: 1.41 seconds
# Epoch 68/150: Test Loss: 2.0145, Test Accuracy: 47.46%
#     Worker 0: Train Loss: 1.8749, Train Accuracy: 48.85%
#     Worker 1: Train Loss: 1.8224, Train Accuracy: 49.47%
#     Worker 2: Train Loss: 1.8670, Train Accuracy: 49.06%
#     Worker 3: Train Loss: 1.8774, Train Accuracy: 49.66%
#     Worker 4: Train Loss: 1.8770, Train Accuracy: 49.09%
#     Worker 5: Train Loss: 1.8254, Train Accuracy: 50.95%
#     Worker 6: Train Loss: 1.8661, Train Accuracy: 49.57%
#     Worker 7: Train Loss: 1.8542, Train Accuracy: 49.57%
# Total Computation Time: 1798.20 seconds
# Total Communication Time: 1.43 seconds
# Epoch 69/150: Test Loss: 2.0117, Test Accuracy: 47.20%
#     Worker 0: Train Loss: 1.8645, Train Accuracy: 49.41%
#     Worker 1: Train Loss: 1.8560, Train Accuracy: 49.57%
#     Worker 2: Train Loss: 1.8701, Train Accuracy: 48.52%
#     Worker 3: Train Loss: 1.8814, Train Accuracy: 48.64%
#     Worker 4: Train Loss: 1.8048, Train Accuracy: 50.45%
#     Worker 5: Train Loss: 1.8526, Train Accuracy: 49.58%
#     Worker 6: Train Loss: 1.8930, Train Accuracy: 48.52%
#     Worker 7: Train Loss: 1.8785, Train Accuracy: 48.64%
# Total Computation Time: 1825.16 seconds
# Total Communication Time: 1.45 seconds
# Epoch 70/150: Test Loss: 2.0107, Test Accuracy: 47.98%
#     Worker 0: Train Loss: 1.8478, Train Accuracy: 49.47%
#     Worker 1: Train Loss: 1.8350, Train Accuracy: 50.46%
#     Worker 2: Train Loss: 1.8267, Train Accuracy: 50.42%
#     Worker 3: Train Loss: 1.8664, Train Accuracy: 49.00%
#     Worker 4: Train Loss: 1.8117, Train Accuracy: 50.36%
#     Worker 5: Train Loss: 1.8427, Train Accuracy: 49.96%
#     Worker 6: Train Loss: 1.8652, Train Accuracy: 49.35%
#     Worker 7: Train Loss: 1.8398, Train Accuracy: 49.92%
# Total Computation Time: 1851.20 seconds
# Total Communication Time: 1.47 seconds
# Epoch 71/150: Test Loss: 2.0072, Test Accuracy: 47.67%
#     Worker 0: Train Loss: 1.8298, Train Accuracy: 49.96%
#     Worker 1: Train Loss: 1.7951, Train Accuracy: 51.09%
#     Worker 2: Train Loss: 1.8114, Train Accuracy: 50.85%
#     Worker 3: Train Loss: 1.8697, Train Accuracy: 49.83%
#     Worker 4: Train Loss: 1.8147, Train Accuracy: 50.98%
#     Worker 5: Train Loss: 1.8294, Train Accuracy: 49.85%
#     Worker 6: Train Loss: 1.8332, Train Accuracy: 49.96%
#     Worker 7: Train Loss: 1.8224, Train Accuracy: 50.41%
# Total Computation Time: 1877.22 seconds
# Total Communication Time: 1.49 seconds
# Epoch 72/150: Test Loss: 1.9979, Test Accuracy: 47.85%
#     Worker 0: Train Loss: 1.8539, Train Accuracy: 49.80%
#     Worker 1: Train Loss: 1.8084, Train Accuracy: 50.83%
#     Worker 2: Train Loss: 1.8083, Train Accuracy: 50.80%
#     Worker 3: Train Loss: 1.8441, Train Accuracy: 50.11%
#     Worker 4: Train Loss: 1.7968, Train Accuracy: 50.78%
#     Worker 5: Train Loss: 1.7932, Train Accuracy: 51.19%
#     Worker 6: Train Loss: 1.8276, Train Accuracy: 50.55%
#     Worker 7: Train Loss: 1.8334, Train Accuracy: 50.50%
# Total Computation Time: 1903.20 seconds
# Total Communication Time: 1.51 seconds
# Epoch 73/150: Test Loss: 2.0056, Test Accuracy: 47.94%
#     Worker 0: Train Loss: 1.8010, Train Accuracy: 50.22%
#     Worker 1: Train Loss: 1.7701, Train Accuracy: 51.76%
#     Worker 2: Train Loss: 1.7985, Train Accuracy: 50.74%
#     Worker 3: Train Loss: 1.8129, Train Accuracy: 50.21%
#     Worker 4: Train Loss: 1.7902, Train Accuracy: 51.04%
#     Worker 5: Train Loss: 1.8167, Train Accuracy: 50.01%
#     Worker 6: Train Loss: 1.8082, Train Accuracy: 50.98%
#     Worker 7: Train Loss: 1.7710, Train Accuracy: 50.73%
# Total Computation Time: 1929.45 seconds
# Total Communication Time: 1.53 seconds
# Epoch 74/150: Test Loss: 1.9950, Test Accuracy: 48.08%
#     Worker 0: Train Loss: 1.8064, Train Accuracy: 50.13%
#     Worker 1: Train Loss: 1.7750, Train Accuracy: 51.67%
#     Worker 2: Train Loss: 1.7940, Train Accuracy: 51.34%
#     Worker 3: Train Loss: 1.8027, Train Accuracy: 50.73%
#     Worker 4: Train Loss: 1.7716, Train Accuracy: 51.72%
#     Worker 5: Train Loss: 1.7768, Train Accuracy: 51.78%
#     Worker 6: Train Loss: 1.8090, Train Accuracy: 50.87%
#     Worker 7: Train Loss: 1.7934, Train Accuracy: 50.77%
# Total Computation Time: 1955.57 seconds
# Total Communication Time: 1.55 seconds
# Epoch 75/150: Test Loss: 1.9855, Test Accuracy: 48.43%
#     Worker 0: Train Loss: 1.7715, Train Accuracy: 50.92%
#     Worker 1: Train Loss: 1.7379, Train Accuracy: 51.62%
#     Worker 2: Train Loss: 1.7773, Train Accuracy: 50.97%
#     Worker 3: Train Loss: 1.8121, Train Accuracy: 50.35%
#     Worker 4: Train Loss: 1.7447, Train Accuracy: 51.83%
#     Worker 5: Train Loss: 1.7606, Train Accuracy: 51.83%
#     Worker 6: Train Loss: 1.7886, Train Accuracy: 51.85%
#     Worker 7: Train Loss: 1.7984, Train Accuracy: 50.88%
# Total Computation Time: 1981.88 seconds
# Total Communication Time: 1.57 seconds
# Epoch 76/150: Test Loss: 1.9819, Test Accuracy: 48.57%
#     Worker 0: Train Loss: 1.7707, Train Accuracy: 51.13%
#     Worker 1: Train Loss: 1.7161, Train Accuracy: 52.57%
#     Worker 2: Train Loss: 1.7559, Train Accuracy: 51.90%
#     Worker 3: Train Loss: 1.7862, Train Accuracy: 51.51%
#     Worker 4: Train Loss: 1.7384, Train Accuracy: 52.28%
#     Worker 5: Train Loss: 1.7369, Train Accuracy: 52.53%
#     Worker 6: Train Loss: 1.7950, Train Accuracy: 50.88%
#     Worker 7: Train Loss: 1.7802, Train Accuracy: 51.41%
# Total Computation Time: 2007.90 seconds
# Total Communication Time: 1.59 seconds
# Epoch 77/150: Test Loss: 1.9922, Test Accuracy: 48.19%
#     Worker 0: Train Loss: 1.7581, Train Accuracy: 52.22%
#     Worker 1: Train Loss: 1.7501, Train Accuracy: 51.57%
#     Worker 2: Train Loss: 1.7452, Train Accuracy: 51.67%
#     Worker 3: Train Loss: 1.7678, Train Accuracy: 51.56%
#     Worker 4: Train Loss: 1.7230, Train Accuracy: 52.68%
#     Worker 5: Train Loss: 1.7487, Train Accuracy: 51.87%
#     Worker 6: Train Loss: 1.7853, Train Accuracy: 50.80%
#     Worker 7: Train Loss: 1.7722, Train Accuracy: 51.15%
# Total Computation Time: 2033.75 seconds
# Total Communication Time: 1.61 seconds
# Epoch 78/150: Test Loss: 1.9848, Test Accuracy: 48.53%
#     Worker 0: Train Loss: 1.7418, Train Accuracy: 51.68%
#     Worker 1: Train Loss: 1.7113, Train Accuracy: 53.27%
#     Worker 2: Train Loss: 1.7295, Train Accuracy: 52.63%
#     Worker 3: Train Loss: 1.7342, Train Accuracy: 52.28%
#     Worker 4: Train Loss: 1.6957, Train Accuracy: 53.53%
#     Worker 5: Train Loss: 1.7332, Train Accuracy: 52.88%
#     Worker 6: Train Loss: 1.7624, Train Accuracy: 52.42%
#     Worker 7: Train Loss: 1.7310, Train Accuracy: 52.41%
# Total Computation Time: 2059.63 seconds
# Total Communication Time: 1.63 seconds
# Epoch 79/150: Test Loss: 1.9847, Test Accuracy: 48.64%
#     Worker 0: Train Loss: 1.7303, Train Accuracy: 51.90%
#     Worker 1: Train Loss: 1.6964, Train Accuracy: 53.13%
#     Worker 2: Train Loss: 1.7321, Train Accuracy: 52.36%
#     Worker 3: Train Loss: 1.7666, Train Accuracy: 51.33%
#     Worker 4: Train Loss: 1.7207, Train Accuracy: 52.66%
#     Worker 5: Train Loss: 1.7283, Train Accuracy: 52.55%
#     Worker 6: Train Loss: 1.7296, Train Accuracy: 52.43%
#     Worker 7: Train Loss: 1.6986, Train Accuracy: 52.91%
# Total Computation Time: 2085.45 seconds
# Total Communication Time: 1.65 seconds
# Epoch 80/150: Test Loss: 1.9732, Test Accuracy: 48.89%
#     Worker 0: Train Loss: 1.7134, Train Accuracy: 52.60%
#     Worker 1: Train Loss: 1.6892, Train Accuracy: 53.37%
#     Worker 2: Train Loss: 1.7302, Train Accuracy: 53.01%
#     Worker 3: Train Loss: 1.7353, Train Accuracy: 52.52%
#     Worker 4: Train Loss: 1.6995, Train Accuracy: 53.15%
#     Worker 5: Train Loss: 1.7029, Train Accuracy: 53.48%
#     Worker 6: Train Loss: 1.7542, Train Accuracy: 51.60%
#     Worker 7: Train Loss: 1.7388, Train Accuracy: 51.81%
# Total Computation Time: 2111.41 seconds
# Total Communication Time: 1.68 seconds
# Epoch 81/150: Test Loss: 1.9735, Test Accuracy: 48.93%
#     Worker 0: Train Loss: 1.7298, Train Accuracy: 51.92%
#     Worker 1: Train Loss: 1.6662, Train Accuracy: 54.41%
#     Worker 2: Train Loss: 1.6830, Train Accuracy: 53.74%
#     Worker 3: Train Loss: 1.7116, Train Accuracy: 52.42%
#     Worker 4: Train Loss: 1.6805, Train Accuracy: 54.20%
#     Worker 5: Train Loss: 1.7267, Train Accuracy: 53.02%
#     Worker 6: Train Loss: 1.7292, Train Accuracy: 52.55%
#     Worker 7: Train Loss: 1.7032, Train Accuracy: 53.47%
# ...
# Total Communication Time: 2.53 seconds
# Epoch 124/150: Test Loss: 1.9652, Test Accuracy: 50.45%
#     Worker 0: Train Loss: 1.3740, Train Accuracy: 61.43%
#     Worker 1: Train Loss: 1.3177, Train Accuracy: 62.99%
#     Worker 2: Train Loss: 1.3522, Train Accuracy: 62.30%
#     Worker 3: Train Loss: 1.3437, Train Accuracy: 62.38%
#     Worker 4: Train Loss: 1.3253, Train Accuracy: 63.04%
#     Worker 5: Train Loss: 1.3301, Train Accuracy: 62.73%
#     Worker 6: Train Loss: 1.3742, Train Accuracy: 61.96%
#     Worker 7: Train Loss: 1.3686, Train Accuracy: 61.53%
# Total Computation Time: 3264.08 seconds
# Total Communication Time: 2.55 seconds
# Epoch 125/150: Test Loss: 1.9621, Test Accuracy: 50.59%
#     Worker 0: Train Loss: 1.3577, Train Accuracy: 62.23%
#     Worker 1: Train Loss: 1.3119, Train Accuracy: 62.82%
#     Worker 2: Train Loss: 1.3343, Train Accuracy: 62.09%
#     Worker 3: Train Loss: 1.3503, Train Accuracy: 62.23%
#     Worker 4: Train Loss: 1.3349, Train Accuracy: 62.27%
#     Worker 5: Train Loss: 1.3385, Train Accuracy: 62.48%
#     Worker 6: Train Loss: 1.3634, Train Accuracy: 61.81%
#     Worker 7: Train Loss: 1.3387, Train Accuracy: 61.99%
# Total Computation Time: 3290.43 seconds
# Total Communication Time: 2.57 seconds
# Epoch 126/150: Test Loss: 1.9606, Test Accuracy: 50.51%
#     Worker 0: Train Loss: 1.3612, Train Accuracy: 61.64%
#     Worker 1: Train Loss: 1.3268, Train Accuracy: 62.44%
#     Worker 2: Train Loss: 1.3167, Train Accuracy: 62.63%
#     Worker 3: Train Loss: 1.3467, Train Accuracy: 62.54%
#     Worker 4: Train Loss: 1.3095, Train Accuracy: 62.21%
#     Worker 5: Train Loss: 1.3518, Train Accuracy: 62.07%
#     Worker 6: Train Loss: 1.3658, Train Accuracy: 62.17%
#     Worker 7: Train Loss: 1.3455, Train Accuracy: 61.81%
# Total Computation Time: 3317.12 seconds
# Total Communication Time: 2.59 seconds
# Epoch 127/150: Test Loss: 1.9590, Test Accuracy: 50.59%
#     Worker 0: Train Loss: 1.3360, Train Accuracy: 62.01%
#     Worker 1: Train Loss: 1.3178, Train Accuracy: 62.87%
#     Worker 2: Train Loss: 1.3183, Train Accuracy: 63.08%
#     Worker 3: Train Loss: 1.3561, Train Accuracy: 61.61%
#     Worker 4: Train Loss: 1.3062, Train Accuracy: 63.11%
#     Worker 5: Train Loss: 1.3483, Train Accuracy: 62.31%
#     Worker 6: Train Loss: 1.3595, Train Accuracy: 61.82%
#     Worker 7: Train Loss: 1.3366, Train Accuracy: 62.47%
# Total Computation Time: 3343.07 seconds
# Total Communication Time: 2.61 seconds
# Epoch 128/150: Test Loss: 1.9622, Test Accuracy: 50.66%
#     Worker 0: Train Loss: 1.3191, Train Accuracy: 63.28%
#     Worker 1: Train Loss: 1.3129, Train Accuracy: 62.41%
#     Worker 2: Train Loss: 1.3309, Train Accuracy: 62.54%
#     Worker 3: Train Loss: 1.3356, Train Accuracy: 62.34%
#     Worker 4: Train Loss: 1.3151, Train Accuracy: 63.42%
#     Worker 5: Train Loss: 1.3345, Train Accuracy: 62.82%
#     Worker 6: Train Loss: 1.3663, Train Accuracy: 61.46%
#     Worker 7: Train Loss: 1.3385, Train Accuracy: 61.80%
# Total Computation Time: 3369.31 seconds
# Total Communication Time: 2.63 seconds
# Epoch 129/150: Test Loss: 1.9629, Test Accuracy: 50.62%
#     Worker 0: Train Loss: 1.3168, Train Accuracy: 62.75%
#     Worker 1: Train Loss: 1.2931, Train Accuracy: 62.79%
#     Worker 2: Train Loss: 1.3194, Train Accuracy: 62.55%
#     Worker 3: Train Loss: 1.3330, Train Accuracy: 62.02%
#     Worker 4: Train Loss: 1.2907, Train Accuracy: 63.77%
#     Worker 5: Train Loss: 1.3006, Train Accuracy: 63.49%
#     Worker 6: Train Loss: 1.3389, Train Accuracy: 63.00%
#     Worker 7: Train Loss: 1.2928, Train Accuracy: 63.06%
# Total Computation Time: 3395.58 seconds
# Total Communication Time: 2.65 seconds
# Epoch 130/150: Test Loss: 1.9636, Test Accuracy: 50.56%
#     Worker 0: Train Loss: 1.3333, Train Accuracy: 62.20%
#     Worker 1: Train Loss: 1.3045, Train Accuracy: 63.43%
#     Worker 2: Train Loss: 1.3163, Train Accuracy: 62.68%
#     Worker 3: Train Loss: 1.3161, Train Accuracy: 62.73%
#     Worker 4: Train Loss: 1.2989, Train Accuracy: 63.88%
#     Worker 5: Train Loss: 1.3383, Train Accuracy: 62.51%
#     Worker 6: Train Loss: 1.3630, Train Accuracy: 61.35%
#     Worker 7: Train Loss: 1.3173, Train Accuracy: 62.38%
# Total Computation Time: 3422.66 seconds
# Total Communication Time: 2.67 seconds
# Epoch 131/150: Test Loss: 1.9632, Test Accuracy: 50.70%
#     Worker 0: Train Loss: 1.3298, Train Accuracy: 62.41%
#     Worker 1: Train Loss: 1.3079, Train Accuracy: 62.69%
#     Worker 2: Train Loss: 1.3236, Train Accuracy: 62.62%
#     Worker 3: Train Loss: 1.3294, Train Accuracy: 62.80%
#     Worker 4: Train Loss: 1.2784, Train Accuracy: 64.02%
#     Worker 5: Train Loss: 1.3028, Train Accuracy: 64.04%
#     Worker 6: Train Loss: 1.3472, Train Accuracy: 62.58%
#     Worker 7: Train Loss: 1.3379, Train Accuracy: 62.27%
# Total Computation Time: 3449.26 seconds
# Total Communication Time: 2.69 seconds
# Epoch 132/150: Test Loss: 1.9629, Test Accuracy: 50.53%
#     Worker 0: Train Loss: 1.3222, Train Accuracy: 62.45%
#     Worker 1: Train Loss: 1.2964, Train Accuracy: 63.00%
#     Worker 2: Train Loss: 1.3097, Train Accuracy: 62.72%
#     Worker 3: Train Loss: 1.3336, Train Accuracy: 61.96%
#     Worker 4: Train Loss: 1.3022, Train Accuracy: 63.10%
#     Worker 5: Train Loss: 1.3503, Train Accuracy: 62.83%
#     Worker 6: Train Loss: 1.3392, Train Accuracy: 62.34%
#     Worker 7: Train Loss: 1.3029, Train Accuracy: 63.24%
# Total Computation Time: 3475.15 seconds
# Total Communication Time: 2.71 seconds
# Epoch 133/150: Test Loss: 1.9633, Test Accuracy: 50.47%
#     Worker 0: Train Loss: 1.3274, Train Accuracy: 62.59%
#     Worker 1: Train Loss: 1.3104, Train Accuracy: 63.43%
#     Worker 2: Train Loss: 1.2984, Train Accuracy: 63.00%
#     Worker 3: Train Loss: 1.3197, Train Accuracy: 62.86%
#     Worker 4: Train Loss: 1.2946, Train Accuracy: 63.49%
#     Worker 5: Train Loss: 1.3118, Train Accuracy: 62.97%
#     Worker 6: Train Loss: 1.3393, Train Accuracy: 62.49%
#     Worker 7: Train Loss: 1.3298, Train Accuracy: 62.06%
# Total Computation Time: 3501.09 seconds
# Total Communication Time: 2.73 seconds
# Epoch 134/150: Test Loss: 1.9650, Test Accuracy: 50.70%
#     Worker 0: Train Loss: 1.3250, Train Accuracy: 62.62%
#     Worker 1: Train Loss: 1.2750, Train Accuracy: 63.50%
#     Worker 2: Train Loss: 1.2842, Train Accuracy: 64.01%
#     Worker 3: Train Loss: 1.3192, Train Accuracy: 63.08%
#     Worker 4: Train Loss: 1.3017, Train Accuracy: 63.21%
#     Worker 5: Train Loss: 1.3371, Train Accuracy: 62.36%
#     Worker 6: Train Loss: 1.3317, Train Accuracy: 63.28%
#     Worker 7: Train Loss: 1.3228, Train Accuracy: 62.40%
# Total Computation Time: 3527.17 seconds
# Total Communication Time: 2.75 seconds
# Epoch 135/150: Test Loss: 1.9652, Test Accuracy: 50.57%
#     Worker 0: Train Loss: 1.3155, Train Accuracy: 63.41%
#     Worker 1: Train Loss: 1.2987, Train Accuracy: 63.08%
#     Worker 2: Train Loss: 1.3057, Train Accuracy: 62.22%
#     Worker 3: Train Loss: 1.3116, Train Accuracy: 63.80%
#     Worker 4: Train Loss: 1.2929, Train Accuracy: 64.22%
#     Worker 5: Train Loss: 1.2968, Train Accuracy: 63.38%
#     Worker 6: Train Loss: 1.3380, Train Accuracy: 62.23%
#     Worker 7: Train Loss: 1.3037, Train Accuracy: 62.68%
# Total Computation Time: 3553.02 seconds
# Total Communication Time: 2.77 seconds
# Epoch 136/150: Test Loss: 1.9642, Test Accuracy: 50.52%
#     Worker 0: Train Loss: 1.3166, Train Accuracy: 62.55%
#     Worker 1: Train Loss: 1.2857, Train Accuracy: 63.71%
#     Worker 2: Train Loss: 1.2972, Train Accuracy: 64.09%
#     Worker 3: Train Loss: 1.3316, Train Accuracy: 62.38%
#     Worker 4: Train Loss: 1.2969, Train Accuracy: 62.78%
#     Worker 5: Train Loss: 1.2965, Train Accuracy: 63.22%
#     Worker 6: Train Loss: 1.3421, Train Accuracy: 61.95%
#     Worker 7: Train Loss: 1.3145, Train Accuracy: 62.99%
# Total Computation Time: 3579.97 seconds
# Total Communication Time: 2.80 seconds
# Epoch 137/150: Test Loss: 1.9665, Test Accuracy: 50.72%
#     Worker 0: Train Loss: 1.3309, Train Accuracy: 61.99%
#     Worker 1: Train Loss: 1.2967, Train Accuracy: 63.50%
#     Worker 2: Train Loss: 1.2999, Train Accuracy: 63.29%
#     Worker 3: Train Loss: 1.3067, Train Accuracy: 63.36%
#     Worker 4: Train Loss: 1.2711, Train Accuracy: 63.95%
#     Worker 5: Train Loss: 1.3000, Train Accuracy: 63.56%
#     Worker 6: Train Loss: 1.3171, Train Accuracy: 63.03%
#     Worker 7: Train Loss: 1.3033, Train Accuracy: 63.18%
# Total Computation Time: 3606.16 seconds
# Total Communication Time: 2.82 seconds
# Epoch 138/150: Test Loss: 1.9659, Test Accuracy: 50.66%
#     Worker 0: Train Loss: 1.3053, Train Accuracy: 63.10%
#     Worker 1: Train Loss: 1.2917, Train Accuracy: 63.78%
#     Worker 2: Train Loss: 1.2935, Train Accuracy: 63.52%
#     Worker 3: Train Loss: 1.3310, Train Accuracy: 62.97%
#     Worker 4: Train Loss: 1.2913, Train Accuracy: 63.43%
#     Worker 5: Train Loss: 1.3056, Train Accuracy: 63.99%
#     Worker 6: Train Loss: 1.3319, Train Accuracy: 63.62%
#     Worker 7: Train Loss: 1.2992, Train Accuracy: 63.04%
# Total Computation Time: 3632.20 seconds
# Total Communication Time: 2.84 seconds
# Epoch 139/150: Test Loss: 1.9645, Test Accuracy: 50.56%
#     Worker 0: Train Loss: 1.2940, Train Accuracy: 63.74%
#     Worker 1: Train Loss: 1.2923, Train Accuracy: 64.12%
#     Worker 2: Train Loss: 1.2971, Train Accuracy: 63.63%
#     Worker 3: Train Loss: 1.3328, Train Accuracy: 62.24%
#     Worker 4: Train Loss: 1.2865, Train Accuracy: 63.63%
#     Worker 5: Train Loss: 1.3005, Train Accuracy: 63.62%
#     Worker 6: Train Loss: 1.3337, Train Accuracy: 62.47%
#     Worker 7: Train Loss: 1.3182, Train Accuracy: 63.27%
# Total Computation Time: 3657.99 seconds
# Total Communication Time: 2.85 seconds
# Epoch 140/150: Test Loss: 1.9650, Test Accuracy: 50.49%
#     Worker 0: Train Loss: 1.3122, Train Accuracy: 62.62%
#     Worker 1: Train Loss: 1.2787, Train Accuracy: 63.56%
#     Worker 2: Train Loss: 1.3023, Train Accuracy: 63.22%
#     Worker 3: Train Loss: 1.3299, Train Accuracy: 61.72%
#     Worker 4: Train Loss: 1.2848, Train Accuracy: 63.49%
#     Worker 5: Train Loss: 1.3017, Train Accuracy: 63.50%
#     Worker 6: Train Loss: 1.3196, Train Accuracy: 62.72%
#     Worker 7: Train Loss: 1.2989, Train Accuracy: 62.91%
# Total Computation Time: 3683.71 seconds
# Total Communication Time: 2.87 seconds
# Epoch 141/150: Test Loss: 1.9650, Test Accuracy: 50.48%
#     Worker 0: Train Loss: 1.3044, Train Accuracy: 62.90%
#     Worker 1: Train Loss: 1.2854, Train Accuracy: 63.74%
#     Worker 2: Train Loss: 1.2885, Train Accuracy: 63.60%
#     Worker 3: Train Loss: 1.3318, Train Accuracy: 62.40%
#     Worker 4: Train Loss: 1.2693, Train Accuracy: 63.83%
#     Worker 5: Train Loss: 1.2768, Train Accuracy: 64.04%
#     Worker 6: Train Loss: 1.3437, Train Accuracy: 62.59%
#     Worker 7: Train Loss: 1.2977, Train Accuracy: 63.10%
# Total Computation Time: 3709.40 seconds
# Total Communication Time: 2.89 seconds
# Epoch 142/150: Test Loss: 1.9648, Test Accuracy: 50.55%
#     Worker 0: Train Loss: 1.2973, Train Accuracy: 63.20%
#     Worker 1: Train Loss: 1.2964, Train Accuracy: 63.08%
#     Worker 2: Train Loss: 1.2990, Train Accuracy: 63.90%
#     Worker 3: Train Loss: 1.3116, Train Accuracy: 62.64%
#     Worker 4: Train Loss: 1.2826, Train Accuracy: 64.01%
#     Worker 5: Train Loss: 1.3041, Train Accuracy: 63.08%
#     Worker 6: Train Loss: 1.3208, Train Accuracy: 62.80%
#     Worker 7: Train Loss: 1.3031, Train Accuracy: 63.17%
# Total Computation Time: 3735.93 seconds
# Total Communication Time: 2.91 seconds
# Epoch 143/150: Test Loss: 1.9652, Test Accuracy: 50.50%
#     Worker 0: Train Loss: 1.3138, Train Accuracy: 63.15%
#     Worker 1: Train Loss: 1.2671, Train Accuracy: 64.37%
#     Worker 2: Train Loss: 1.2739, Train Accuracy: 63.81%
#     Worker 3: Train Loss: 1.3155, Train Accuracy: 63.25%
#     Worker 4: Train Loss: 1.2621, Train Accuracy: 64.22%
#     Worker 5: Train Loss: 1.3078, Train Accuracy: 63.53%
#     Worker 6: Train Loss: 1.3226, Train Accuracy: 63.31%
#     Worker 7: Train Loss: 1.2999, Train Accuracy: 62.65%
# Total Computation Time: 3761.69 seconds
# Total Communication Time: 2.93 seconds
# Epoch 144/150: Test Loss: 1.9655, Test Accuracy: 50.60%
#     Worker 0: Train Loss: 1.2961, Train Accuracy: 62.87%
#     Worker 1: Train Loss: 1.3096, Train Accuracy: 63.29%
#     Worker 2: Train Loss: 1.2821, Train Accuracy: 64.18%
#     Worker 3: Train Loss: 1.3168, Train Accuracy: 63.17%
#     Worker 4: Train Loss: 1.2740, Train Accuracy: 64.47%
#     Worker 5: Train Loss: 1.2861, Train Accuracy: 64.08%
#     Worker 6: Train Loss: 1.3065, Train Accuracy: 63.34%
#     Worker 7: Train Loss: 1.2938, Train Accuracy: 63.64%
# Total Computation Time: 3787.65 seconds
# Total Communication Time: 2.95 seconds
# Epoch 145/150: Test Loss: 1.9651, Test Accuracy: 50.57%
#     Worker 0: Train Loss: 1.3193, Train Accuracy: 62.99%
#     Worker 1: Train Loss: 1.2814, Train Accuracy: 63.97%
#     Worker 2: Train Loss: 1.2770, Train Accuracy: 64.62%
#     Worker 3: Train Loss: 1.3114, Train Accuracy: 63.04%
#     Worker 4: Train Loss: 1.2890, Train Accuracy: 63.90%
#     Worker 5: Train Loss: 1.3023, Train Accuracy: 63.74%
#     Worker 6: Train Loss: 1.3486, Train Accuracy: 63.11%
#     Worker 7: Train Loss: 1.2940, Train Accuracy: 63.81%
# Total Computation Time: 3813.67 seconds
# Total Communication Time: 2.97 seconds
# Epoch 146/150: Test Loss: 1.9655, Test Accuracy: 50.51%
#     Worker 0: Train Loss: 1.2983, Train Accuracy: 63.63%
#     Worker 1: Train Loss: 1.2727, Train Accuracy: 63.74%
#     Worker 2: Train Loss: 1.2815, Train Accuracy: 63.74%
#     Worker 3: Train Loss: 1.3117, Train Accuracy: 62.92%
#     Worker 4: Train Loss: 1.2803, Train Accuracy: 64.09%
#     Worker 5: Train Loss: 1.3088, Train Accuracy: 63.21%
#     Worker 6: Train Loss: 1.3066, Train Accuracy: 63.03%
#     Worker 7: Train Loss: 1.3168, Train Accuracy: 62.47%
# Total Computation Time: 3839.59 seconds
# Total Communication Time: 2.99 seconds
# Epoch 147/150: Test Loss: 1.9654, Test Accuracy: 50.52%
#     Worker 0: Train Loss: 1.3018, Train Accuracy: 63.03%
#     Worker 1: Train Loss: 1.2851, Train Accuracy: 63.83%
#     Worker 2: Train Loss: 1.2726, Train Accuracy: 63.97%
#     Worker 3: Train Loss: 1.3162, Train Accuracy: 63.29%
#     Worker 4: Train Loss: 1.2802, Train Accuracy: 63.66%
#     Worker 5: Train Loss: 1.2946, Train Accuracy: 63.87%
#     Worker 6: Train Loss: 1.3121, Train Accuracy: 63.48%
#     Worker 7: Train Loss: 1.3043, Train Accuracy: 63.22%
# Total Computation Time: 3865.56 seconds
# Total Communication Time: 3.01 seconds
# Epoch 148/150: Test Loss: 1.9654, Test Accuracy: 50.54%
#     Worker 0: Train Loss: 1.3088, Train Accuracy: 62.97%
#     Worker 1: Train Loss: 1.2858, Train Accuracy: 63.36%
#     Worker 2: Train Loss: 1.2899, Train Accuracy: 63.83%
#     Worker 3: Train Loss: 1.3280, Train Accuracy: 62.57%
#     Worker 4: Train Loss: 1.2823, Train Accuracy: 63.90%
#     Worker 5: Train Loss: 1.2817, Train Accuracy: 65.00%
#     Worker 6: Train Loss: 1.3279, Train Accuracy: 62.92%
#     Worker 7: Train Loss: 1.3038, Train Accuracy: 62.59%
# Total Computation Time: 3892.16 seconds
# Total Communication Time: 3.03 seconds
# Epoch 149/150: Test Loss: 1.9653, Test Accuracy: 50.51%
#     Worker 0: Train Loss: 1.3060, Train Accuracy: 62.72%
#     Worker 1: Train Loss: 1.2772, Train Accuracy: 63.98%
#     Worker 2: Train Loss: 1.2859, Train Accuracy: 63.60%
#     Worker 3: Train Loss: 1.2985, Train Accuracy: 63.27%
#     Worker 4: Train Loss: 1.2802, Train Accuracy: 63.63%
#     Worker 5: Train Loss: 1.3201, Train Accuracy: 63.49%
#     Worker 6: Train Loss: 1.3265, Train Accuracy: 63.11%
#     Worker 7: Train Loss: 1.3043, Train Accuracy: 63.48%
# Total Computation Time: 3918.08 seconds
# Total Communication Time: 3.05 seconds
# Epoch 150/150: Test Loss: 1.9653, Test Accuracy: 50.53%
#     Worker 0: Train Loss: 1.3073, Train Accuracy: 62.92%
#     Worker 1: Train Loss: 1.3055, Train Accuracy: 63.34%
#     Worker 2: Train Loss: 1.2773, Train Accuracy: 63.62%
#     Worker 3: Train Loss: 1.3250, Train Accuracy: 62.52%
#     Worker 4: Train Loss: 1.2698, Train Accuracy: 64.04%
#     Worker 5: Train Loss: 1.2886, Train Accuracy: 63.45%
#     Worker 6: Train Loss: 1.3473, Train Accuracy: 62.22%
#     Worker 7: Train Loss: 1.2755, Train Accuracy: 63.43%
# Total Computation Time: 3944.41 seconds
# Total Communication Time: 3.07 seconds
