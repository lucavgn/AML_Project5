# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files
import time

total_computation_time = 0
total_communication_time = 0

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
# Alpha slow learning rate a=1 best
# Beta slow momentum
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
#warmup_epochs = 5

alpha = 0.75  # Slow learning rate scaling factor
beta = 0.2  # Slow momentum factor

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate for each k: {learning_rate:.5f}")
#lr_warmup=learning_rate
# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]


with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs) for optimizer in optimizers]

u_buffer = [torch.zeros_like(param) for param in nets[0].parameters()]  # Momentum buffer

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")
    #if epoch < warmup_epochs: #lr for buffer update during warmup
            #w_factor = (epoch + 1) / warmup_epochs
            #lr_warmup = w_factor * learning_rate
    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch): #outer loop
        computation_start_time = time.time()
        #x(t,0)
        iter_params = [torch.zeros_like(param) for param in nets[0].parameters()]
        for param, g_param in zip(iter_params, nets[0].parameters()):
                    param.data.copy_(g_param)
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0

            # Perform J local step before synchronization
            for j in range(J): #inner loop
                      try:
                          # Get a batch from the current worker's shard using next()
                          images, labels = next(shard_iterators[k])
                          images, labels = images.to(device), labels.to(device)  # Move to device
                          optimizers[k].zero_grad()
                          outputs = nets[k](images)
                          loss = criterion(outputs, labels)
                          loss.backward()
                          optimizers[k].step()
                          # Calculate train loss and accuracy
                          train_loss += loss.item() * labels.size(0)
                          _, predicted = outputs.max(1)
                          total_train += labels.size(0)
                          correct_train += predicted.eq(labels).sum().item()

                      except StopIteration:
                          # If the iterator has exhausted the data, restart the iterator
                          shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                          images, labels = next(shard_iterators[k]) # Resume from the next batch
                          images, labels = images.to(device), labels.to(device)
                          # Perform optimization step
                          optimizers[k].zero_grad()
                          outputs = nets[k](images)
                          loss = criterion(outputs, labels)
                          loss.backward()
                          optimizers[k].step()
                          # Calculate train loss and accuracy
                          train_loss += loss.item() * labels.size(0)
                          _, predicted = outputs.max(1)
                          total_train += labels.size(0)
                          correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        computation_end_time = time.time()
        total_computation_time += (computation_end_time - computation_start_time)

        communication_start_time = time.time()
          # Synchronization (SLOWMO Algothm 1 - paper 21)
        with torch.no_grad():
            global_params = [torch.zeros_like(param) for param in nets[0].parameters()]
            #x(t, tau)
            for net in nets:
                for global_param, local_param in zip(global_params, net.parameters()):
                    global_param += local_param
            for global_param in global_params:
                global_param /= K

            for param, g_param, u_param in zip(iter_params, global_params, u_buffer):
                #if epoch < warmup_epochs:
                  #  u_param.mul_(beta).add_((param - g_param) / lr_warmup)
                 #   g_param.sub_(alpha * lr_warmup * u_param)

                #else: #Sync after warmup
                    #print(f"{optimizers[0].param_groups[0]['lr']}  {optimizers[1].param_groups[0]['lr']}")
                    lr_sched = optimizers[0].param_groups[0]['lr'] #optimizer lr
                    u_param.mul_(beta).add_((param - g_param) / lr_sched)
                    #g_param.sub_(alpha * lr_sched * u_param)
                    g_param.copy_(param - alpha * lr_sched * u_param)

            for net in nets:
                for param, g_param in zip(net.parameters(), global_params):
                    param.data.copy_(g_param)

        communication_end_time = time.time()
        total_communication_time += (communication_end_time - communication_start_time)

    # Update lr for each scheduler
    for scheduler in schedulers:
        #if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
        #else:
         #   warmup_factor = (epoch + 1) / warmup_epochs
          #  lr = warmup_factor * learning_rate
           # for optimizer in optimizers:
            #    for param_group in optimizer.param_groups:
             #       param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

    print(f"Total Computation Time: {total_computation_time:.2f} seconds")
    print(f"Total Communication Time: {total_communication_time:.2f} seconds")


# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 4 --j 64
# Out:
# Training with K=4, J=64
# Global iteration per epoch: 4
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:18<00:00, 9.24MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate for each k: 0.00400
# Epoch 1/150: Test Loss: 4.5736, Test Accuracy: 3.02%
#     Worker 0: Train Loss: 4.5974, Train Accuracy: 1.41%
#     Worker 1: Train Loss: 4.5974, Train Accuracy: 1.28%
#     Worker 2: Train Loss: 4.5959, Train Accuracy: 1.68%
#     Worker 3: Train Loss: 4.5973, Train Accuracy: 1.44%
# Total Computation Time: 33.33 seconds
# Total Communication Time: 0.07 seconds
# Epoch 2/150: Test Loss: 4.1439, Test Accuracy: 6.98%
#     Worker 0: Train Loss: 4.4156, Train Accuracy: 3.58%
#     Worker 1: Train Loss: 4.4159, Train Accuracy: 3.95%
#     Worker 2: Train Loss: 4.3997, Train Accuracy: 4.18%
#     Worker 3: Train Loss: 4.4139, Train Accuracy: 4.08%
# Total Computation Time: 66.65 seconds
# Total Communication Time: 0.08 seconds
# Epoch 3/150: Test Loss: 3.9318, Test Accuracy: 9.67%
#     Worker 0: Train Loss: 4.1028, Train Accuracy: 6.93%
#     Worker 1: Train Loss: 4.1217, Train Accuracy: 6.79%
#     Worker 2: Train Loss: 4.0853, Train Accuracy: 7.04%
#     Worker 3: Train Loss: 4.1144, Train Accuracy: 6.98%
# Total Computation Time: 99.36 seconds
# Total Communication Time: 0.09 seconds
# Epoch 4/150: Test Loss: 3.7739, Test Accuracy: 12.62%
#     Worker 0: Train Loss: 3.9446, Train Accuracy: 9.31%
#     Worker 1: Train Loss: 3.9598, Train Accuracy: 8.91%
#     Worker 2: Train Loss: 3.9196, Train Accuracy: 9.81%
#     Worker 3: Train Loss: 3.9501, Train Accuracy: 9.38%
# Total Computation Time: 131.48 seconds
# Total Communication Time: 0.09 seconds
# Epoch 5/150: Test Loss: 3.6421, Test Accuracy: 14.79%
#     Worker 0: Train Loss: 3.8371, Train Accuracy: 10.78%
#     Worker 1: Train Loss: 3.8224, Train Accuracy: 11.19%
#     Worker 2: Train Loss: 3.7710, Train Accuracy: 12.42%
#     Worker 3: Train Loss: 3.8353, Train Accuracy: 10.69%
# Total Computation Time: 164.09 seconds
# Total Communication Time: 0.10 seconds
# Epoch 6/150: Test Loss: 3.5337, Test Accuracy: 17.08%
#     Worker 0: Train Loss: 3.7093, Train Accuracy: 12.92%
#     Worker 1: Train Loss: 3.7274, Train Accuracy: 13.07%
#     Worker 2: Train Loss: 3.6838, Train Accuracy: 13.42%
#     Worker 3: Train Loss: 3.7115, Train Accuracy: 13.25%
# Total Computation Time: 196.67 seconds
# Total Communication Time: 0.11 seconds
# Epoch 7/150: Test Loss: 3.4300, Test Accuracy: 18.66%
#     Worker 0: Train Loss: 3.6044, Train Accuracy: 14.27%
#     Worker 1: Train Loss: 3.6078, Train Accuracy: 14.86%
#     Worker 2: Train Loss: 3.5732, Train Accuracy: 14.99%
#     Worker 3: Train Loss: 3.6144, Train Accuracy: 14.30%
# Total Computation Time: 229.25 seconds
# Total Communication Time: 0.12 seconds
# Epoch 8/150: Test Loss: 3.3365, Test Accuracy: 20.32%
#     Worker 0: Train Loss: 3.5382, Train Accuracy: 15.59%
#     Worker 1: Train Loss: 3.5271, Train Accuracy: 16.26%
#     Worker 2: Train Loss: 3.4816, Train Accuracy: 17.07%
#     Worker 3: Train Loss: 3.5263, Train Accuracy: 16.08%
# Total Computation Time: 262.22 seconds
# Total Communication Time: 0.13 seconds
# Epoch 9/150: Test Loss: 3.2820, Test Accuracy: 21.31%
#     Worker 0: Train Loss: 3.4397, Train Accuracy: 17.32%
#     Worker 1: Train Loss: 3.4614, Train Accuracy: 17.37%
#     Worker 2: Train Loss: 3.3866, Train Accuracy: 18.46%
#     Worker 3: Train Loss: 3.4522, Train Accuracy: 17.30%
# Total Computation Time: 294.18 seconds
# Total Communication Time: 0.14 seconds
# Epoch 10/150: Test Loss: 3.1580, Test Accuracy: 23.54%
#     Worker 0: Train Loss: 3.3450, Train Accuracy: 18.80%
#     Worker 1: Train Loss: 3.3686, Train Accuracy: 18.51%
#     Worker 2: Train Loss: 3.2958, Train Accuracy: 19.94%
#     Worker 3: Train Loss: 3.3615, Train Accuracy: 19.15%
# Total Computation Time: 326.61 seconds
# Total Communication Time: 0.15 seconds
# Epoch 11/150: Test Loss: 3.0809, Test Accuracy: 25.20%
#     Worker 0: Train Loss: 3.2761, Train Accuracy: 20.19%
#     Worker 1: Train Loss: 3.2835, Train Accuracy: 20.39%
#     Worker 2: Train Loss: 3.2404, Train Accuracy: 20.91%
#     Worker 3: Train Loss: 3.3064, Train Accuracy: 19.79%
# Total Computation Time: 359.30 seconds
# Total Communication Time: 0.15 seconds
# Epoch 12/150: Test Loss: 3.0109, Test Accuracy: 26.02%
#     Worker 0: Train Loss: 3.2157, Train Accuracy: 20.68%
#     Worker 1: Train Loss: 3.2357, Train Accuracy: 20.83%
#     Worker 2: Train Loss: 3.1676, Train Accuracy: 22.17%
#     Worker 3: Train Loss: 3.2109, Train Accuracy: 21.32%
# Total Computation Time: 391.67 seconds
# Total Communication Time: 0.16 seconds
# Epoch 13/150: Test Loss: 2.9439, Test Accuracy: 27.64%
#     Worker 0: Train Loss: 3.1423, Train Accuracy: 22.69%
#     Worker 1: Train Loss: 3.1646, Train Accuracy: 23.04%
#     Worker 2: Train Loss: 3.1198, Train Accuracy: 23.34%
#     Worker 3: Train Loss: 3.1562, Train Accuracy: 22.89%
# Total Computation Time: 424.82 seconds
# Total Communication Time: 0.17 seconds
# Epoch 14/150: Test Loss: 2.8898, Test Accuracy: 28.66%
#     Worker 0: Train Loss: 3.0864, Train Accuracy: 23.34%
#     Worker 1: Train Loss: 3.0994, Train Accuracy: 23.50%
#     Worker 2: Train Loss: 3.0586, Train Accuracy: 23.95%
#     Worker 3: Train Loss: 3.1032, Train Accuracy: 23.59%
# Total Computation Time: 456.60 seconds
# Total Communication Time: 0.18 seconds
# Epoch 15/150: Test Loss: 2.8422, Test Accuracy: 29.41%
#     Worker 0: Train Loss: 3.0412, Train Accuracy: 24.52%
#     Worker 1: Train Loss: 3.0463, Train Accuracy: 24.82%
#     Worker 2: Train Loss: 3.0014, Train Accuracy: 25.42%
#     Worker 3: Train Loss: 3.0503, Train Accuracy: 24.81%
# Total Computation Time: 488.54 seconds
# Total Communication Time: 0.19 seconds
# Epoch 16/150: Test Loss: 2.7924, Test Accuracy: 30.72%
#     Worker 0: Train Loss: 2.9963, Train Accuracy: 25.47%
#     Worker 1: Train Loss: 2.9987, Train Accuracy: 25.66%
#     Worker 2: Train Loss: 2.9625, Train Accuracy: 26.38%
#     Worker 3: Train Loss: 2.9962, Train Accuracy: 25.39%
# Total Computation Time: 521.12 seconds
# Total Communication Time: 0.19 seconds
# Epoch 17/150: Test Loss: 2.7517, Test Accuracy: 31.05%
#     Worker 0: Train Loss: 2.9335, Train Accuracy: 26.76%
#     Worker 1: Train Loss: 2.9649, Train Accuracy: 25.87%
#     Worker 2: Train Loss: 2.9035, Train Accuracy: 27.23%
#     Worker 3: Train Loss: 2.9472, Train Accuracy: 26.55%
# Total Computation Time: 553.60 seconds
# Total Communication Time: 0.20 seconds
# Epoch 18/150: Test Loss: 2.7046, Test Accuracy: 32.16%
#     Worker 0: Train Loss: 2.8968, Train Accuracy: 27.24%
#     Worker 1: Train Loss: 2.9033, Train Accuracy: 27.07%
#     Worker 2: Train Loss: 2.8797, Train Accuracy: 27.86%
#     Worker 3: Train Loss: 2.9045, Train Accuracy: 27.36%
# Total Computation Time: 585.98 seconds
# Total Communication Time: 0.21 seconds
# Epoch 19/150: Test Loss: 2.6804, Test Accuracy: 32.83%
#     Worker 0: Train Loss: 2.8509, Train Accuracy: 28.27%
#     Worker 1: Train Loss: 2.8600, Train Accuracy: 28.40%
#     Worker 2: Train Loss: 2.8217, Train Accuracy: 29.07%
#     Worker 3: Train Loss: 2.8603, Train Accuracy: 28.07%
# Total Computation Time: 618.19 seconds
# Total Communication Time: 0.22 seconds
# Epoch 20/150: Test Loss: 2.6313, Test Accuracy: 34.31%
#     Worker 0: Train Loss: 2.7931, Train Accuracy: 29.41%
#     Worker 1: Train Loss: 2.8234, Train Accuracy: 29.15%
#     Worker 2: Train Loss: 2.7820, Train Accuracy: 29.76%
#     Worker 3: Train Loss: 2.8141, Train Accuracy: 29.34%
# Total Computation Time: 650.02 seconds
# Total Communication Time: 0.23 seconds
# Epoch 21/150: Test Loss: 2.5900, Test Accuracy: 34.39%
#     Worker 0: Train Loss: 2.7302, Train Accuracy: 30.86%
#     Worker 1: Train Loss: 2.7597, Train Accuracy: 30.15%
#     Worker 2: Train Loss: 2.7398, Train Accuracy: 30.61%
#     Worker 3: Train Loss: 2.7674, Train Accuracy: 29.49%
# Total Computation Time: 682.38 seconds
# Total Communication Time: 0.24 seconds
# Epoch 22/150: Test Loss: 2.5276, Test Accuracy: 35.73%
#     Worker 0: Train Loss: 2.7043, Train Accuracy: 30.42%
#     Worker 1: Train Loss: 2.7366, Train Accuracy: 30.78%
#     Worker 2: Train Loss: 2.6875, Train Accuracy: 31.73%
#     Worker 3: Train Loss: 2.7112, Train Accuracy: 30.89%
# Total Computation Time: 714.61 seconds
# Total Communication Time: 0.24 seconds
# Epoch 23/150: Test Loss: 2.4913, Test Accuracy: 36.55%
#     Worker 0: Train Loss: 2.6608, Train Accuracy: 31.92%
#     Worker 1: Train Loss: 2.6959, Train Accuracy: 31.66%
#     Worker 2: Train Loss: 2.6435, Train Accuracy: 32.40%
#     Worker 3: Train Loss: 2.6835, Train Accuracy: 32.04%
# Total Computation Time: 746.43 seconds
# Total Communication Time: 0.25 seconds
# Epoch 24/150: Test Loss: 2.4649, Test Accuracy: 37.04%
#     Worker 0: Train Loss: 2.6135, Train Accuracy: 32.85%
#     Worker 1: Train Loss: 2.6454, Train Accuracy: 32.29%
#     Worker 2: Train Loss: 2.5917, Train Accuracy: 33.38%
#     Worker 3: Train Loss: 2.6353, Train Accuracy: 32.45%
# Total Computation Time: 778.35 seconds
# Total Communication Time: 0.26 seconds
# Epoch 25/150: Test Loss: 2.4314, Test Accuracy: 37.81%
#     Worker 0: Train Loss: 2.5857, Train Accuracy: 33.24%
#     Worker 1: Train Loss: 2.6123, Train Accuracy: 33.25%
#     Worker 2: Train Loss: 2.5569, Train Accuracy: 34.16%
#     Worker 3: Train Loss: 2.6075, Train Accuracy: 33.08%
# Total Computation Time: 809.64 seconds
# Total Communication Time: 0.27 seconds
# Epoch 26/150: Test Loss: 2.4067, Test Accuracy: 38.16%
#     Worker 0: Train Loss: 2.5527, Train Accuracy: 34.28%
#     Worker 1: Train Loss: 2.5794, Train Accuracy: 33.69%
#     Worker 2: Train Loss: 2.5315, Train Accuracy: 34.84%
#     Worker 3: Train Loss: 2.5649, Train Accuracy: 33.45%
# Total Computation Time: 841.68 seconds
# Total Communication Time: 0.28 seconds
# Epoch 27/150: Test Loss: 2.3703, Test Accuracy: 39.21%
#     Worker 0: Train Loss: 2.5033, Train Accuracy: 35.18%
#     Worker 1: Train Loss: 2.5293, Train Accuracy: 34.82%
#     Worker 2: Train Loss: 2.4919, Train Accuracy: 35.28%
#     Worker 3: Train Loss: 2.5094, Train Accuracy: 35.22%
# Total Computation Time: 873.69 seconds
# Total Communication Time: 0.28 seconds
# Epoch 28/150: Test Loss: 2.3412, Test Accuracy: 39.49%
#     Worker 0: Train Loss: 2.4763, Train Accuracy: 35.54%
#     Worker 1: Train Loss: 2.5000, Train Accuracy: 35.61%
#     Worker 2: Train Loss: 2.4541, Train Accuracy: 36.46%
#     Worker 3: Train Loss: 2.4913, Train Accuracy: 35.79%
# Total Computation Time: 905.24 seconds
# Total Communication Time: 0.29 seconds
# Epoch 29/150: Test Loss: 2.3339, Test Accuracy: 39.55%
#     Worker 0: Train Loss: 2.4488, Train Accuracy: 36.47%
#     Worker 1: Train Loss: 2.4556, Train Accuracy: 36.41%
#     Worker 2: Train Loss: 2.4332, Train Accuracy: 36.97%
#     Worker 3: Train Loss: 2.4681, Train Accuracy: 36.18%
# Total Computation Time: 937.28 seconds
# Total Communication Time: 0.30 seconds
# Epoch 30/150: Test Loss: 2.2962, Test Accuracy: 40.61%
#     Worker 0: Train Loss: 2.4210, Train Accuracy: 36.76%
#     Worker 1: Train Loss: 2.4283, Train Accuracy: 37.13%
#     Worker 2: Train Loss: 2.3821, Train Accuracy: 37.91%
#     Worker 3: Train Loss: 2.4312, Train Accuracy: 36.84%
# Total Computation Time: 968.90 seconds
# Total Communication Time: 0.31 seconds
# Epoch 31/150: Test Loss: 2.2653, Test Accuracy: 41.29%
#     Worker 0: Train Loss: 2.3810, Train Accuracy: 38.18%
#     Worker 1: Train Loss: 2.3947, Train Accuracy: 37.33%
#     Worker 2: Train Loss: 2.3741, Train Accuracy: 38.27%
#     Worker 3: Train Loss: 2.3946, Train Accuracy: 37.21%
# Total Computation Time: 1001.13 seconds
# Total Communication Time: 0.32 seconds
# Epoch 32/150: Test Loss: 2.2493, Test Accuracy: 41.34%
#     Worker 0: Train Loss: 2.3278, Train Accuracy: 38.82%
#     Worker 1: Train Loss: 2.3628, Train Accuracy: 38.64%
#     Worker 2: Train Loss: 2.3397, Train Accuracy: 39.14%
#     Worker 3: Train Loss: 2.3732, Train Accuracy: 38.04%
# Total Computation Time: 1033.00 seconds
# Total Communication Time: 0.32 seconds
# Epoch 33/150: Test Loss: 2.2348, Test Accuracy: 41.87%
#     Worker 0: Train Loss: 2.3455, Train Accuracy: 38.66%
#     Worker 1: Train Loss: 2.3482, Train Accuracy: 38.81%
#     Worker 2: Train Loss: 2.3158, Train Accuracy: 39.32%
#     Worker 3: Train Loss: 2.3427, Train Accuracy: 39.03%
# Total Computation Time: 1064.44 seconds
# Total Communication Time: 0.33 seconds
# Epoch 34/150: Test Loss: 2.2245, Test Accuracy: 42.19%
#     Worker 0: Train Loss: 2.3106, Train Accuracy: 38.89%
#     Worker 1: Train Loss: 2.3093, Train Accuracy: 39.75%
#     Worker 2: Train Loss: 2.2746, Train Accuracy: 40.31%
#     Worker 3: Train Loss: 2.3080, Train Accuracy: 39.19%
# Total Computation Time: 1096.86 seconds
# Total Communication Time: 0.34 seconds
# Epoch 35/150: Test Loss: 2.1997, Test Accuracy: 42.69%
#     Worker 0: Train Loss: 2.2794, Train Accuracy: 40.28%
#     Worker 1: Train Loss: 2.2773, Train Accuracy: 40.50%
#     Worker 2: Train Loss: 2.2734, Train Accuracy: 40.40%
#     Worker 3: Train Loss: 2.3124, Train Accuracy: 39.57%
# Total Computation Time: 1129.11 seconds
# Total Communication Time: 0.35 seconds
# Epoch 36/150: Test Loss: 2.1853, Test Accuracy: 43.15%
#     Worker 0: Train Loss: 2.2508, Train Accuracy: 40.57%
#     Worker 1: Train Loss: 2.2662, Train Accuracy: 40.35%
#     Worker 2: Train Loss: 2.2368, Train Accuracy: 41.00%
#     Worker 3: Train Loss: 2.2684, Train Accuracy: 40.10%
# Total Computation Time: 1160.96 seconds
# Total Communication Time: 0.36 seconds
# Epoch 37/150: Test Loss: 2.1732, Test Accuracy: 43.74%
#     Worker 0: Train Loss: 2.2343, Train Accuracy: 40.91%
#     Worker 1: Train Loss: 2.2364, Train Accuracy: 41.06%
#     Worker 2: Train Loss: 2.2220, Train Accuracy: 41.56%
#     Worker 3: Train Loss: 2.2442, Train Accuracy: 41.15%
# Total Computation Time: 1192.46 seconds
# Total Communication Time: 0.36 seconds
# Epoch 38/150: Test Loss: 2.1585, Test Accuracy: 43.86%
#     Worker 0: Train Loss: 2.2216, Train Accuracy: 40.86%
#     Worker 1: Train Loss: 2.2108, Train Accuracy: 41.64%
#     Worker 2: Train Loss: 2.1714, Train Accuracy: 42.33%
#     Worker 3: Train Loss: 2.2098, Train Accuracy: 41.35%
# Total Computation Time: 1223.89 seconds
# Total Communication Time: 0.37 seconds
# Epoch 39/150: Test Loss: 2.1487, Test Accuracy: 43.45%
#     Worker 0: Train Loss: 2.1897, Train Accuracy: 42.03%
#     Worker 1: Train Loss: 2.1959, Train Accuracy: 42.08%
#     Worker 2: Train Loss: 2.1676, Train Accuracy: 42.64%
#     Worker 3: Train Loss: 2.1934, Train Accuracy: 42.09%
# Total Computation Time: 1256.55 seconds
# Total Communication Time: 0.38 seconds
# Epoch 40/150: Test Loss: 2.1203, Test Accuracy: 44.56%
#     Worker 0: Train Loss: 2.1721, Train Accuracy: 42.02%
#     Worker 1: Train Loss: 2.1482, Train Accuracy: 43.41%
#     Worker 2: Train Loss: 2.1492, Train Accuracy: 43.02%
#     Worker 3: Train Loss: 2.1628, Train Accuracy: 42.35%
# Total Computation Time: 1288.73 seconds
# Total Communication Time: 0.39 seconds
# Epoch 41/150: Test Loss: 2.1060, Test Accuracy: 45.10%
#     Worker 0: Train Loss: 2.1347, Train Accuracy: 43.21%
#     Worker 1: Train Loss: 2.1429, Train Accuracy: 42.96%
#     Worker 2: Train Loss: 2.1256, Train Accuracy: 43.58%
#     Worker 3: Train Loss: 2.1374, Train Accuracy: 43.31%
# Total Computation Time: 1320.35 seconds
# Total Communication Time: 0.40 seconds
# Epoch 42/150: Test Loss: 2.0970, Test Accuracy: 45.04%
#     Worker 0: Train Loss: 2.1235, Train Accuracy: 43.56%
#     Worker 1: Train Loss: 2.1317, Train Accuracy: 43.56%
#     Worker 2: Train Loss: 2.0882, Train Accuracy: 44.41%
#     Worker 3: Train Loss: 2.1405, Train Accuracy: 43.59%
# Total Computation Time: 1351.57 seconds
# Total Communication Time: 0.40 seconds
# Epoch 43/150: Test Loss: 2.0841, Test Accuracy: 45.73%
#     Worker 0: Train Loss: 2.0958, Train Accuracy: 43.89%
#     Worker 1: Train Loss: 2.0814, Train Accuracy: 44.71%
#     Worker 2: Train Loss: 2.0796, Train Accuracy: 45.01%
#     Worker 3: Train Loss: 2.1059, Train Accuracy: 43.60%
# Total Computation Time: 1383.28 seconds
# Total Communication Time: 0.41 seconds
# Epoch 44/150: Test Loss: 2.0809, Test Accuracy: 45.70%
#     Worker 0: Train Loss: 2.0696, Train Accuracy: 44.78%
#     Worker 1: Train Loss: 2.0650, Train Accuracy: 44.85%
#     Worker 2: Train Loss: 2.0522, Train Accuracy: 45.66%
#     Worker 3: Train Loss: 2.0979, Train Accuracy: 44.39%
# Total Computation Time: 1415.07 seconds
# Total Communication Time: 0.42 seconds
# Epoch 45/150: Test Loss: 2.0767, Test Accuracy: 45.93%
#     Worker 0: Train Loss: 2.0656, Train Accuracy: 44.14%
#     Worker 1: Train Loss: 2.0793, Train Accuracy: 44.71%
#     Worker 2: Train Loss: 2.0537, Train Accuracy: 45.52%
#     Worker 3: Train Loss: 2.0600, Train Accuracy: 45.39%
# Total Computation Time: 1447.44 seconds
# Total Communication Time: 0.43 seconds
# Epoch 46/150: Test Loss: 2.0682, Test Accuracy: 46.04%
#     Worker 0: Train Loss: 2.0380, Train Accuracy: 45.27%
#     Worker 1: Train Loss: 2.0376, Train Accuracy: 45.85%
#     Worker 2: Train Loss: 2.0121, Train Accuracy: 46.04%
#     Worker 3: Train Loss: 2.0379, Train Accuracy: 45.66%
# Total Computation Time: 1478.71 seconds
# Total Communication Time: 0.44 seconds
# Epoch 47/150: Test Loss: 2.0613, Test Accuracy: 46.11%
#     Worker 0: Train Loss: 2.0195, Train Accuracy: 45.53%
#     Worker 1: Train Loss: 2.0196, Train Accuracy: 45.83%
#     Worker 2: Train Loss: 2.0009, Train Accuracy: 46.52%
#     Worker 3: Train Loss: 2.0260, Train Accuracy: 45.87%
# Total Computation Time: 1510.55 seconds
# Total Communication Time: 0.45 seconds
# Epoch 48/150: Test Loss: 2.0475, Test Accuracy: 46.17%
#     Worker 0: Train Loss: 2.0088, Train Accuracy: 45.65%
#     Worker 1: Train Loss: 1.9916, Train Accuracy: 46.60%
#     Worker 2: Train Loss: 1.9931, Train Accuracy: 46.60%
#     Worker 3: Train Loss: 1.9963, Train Accuracy: 46.74%
# Total Computation Time: 1542.64 seconds
# Total Communication Time: 0.45 seconds
# Epoch 49/150: Test Loss: 2.0432, Test Accuracy: 46.74%
#     Worker 0: Train Loss: 1.9877, Train Accuracy: 46.03%
#     Worker 1: Train Loss: 2.0077, Train Accuracy: 46.35%
#     Worker 2: Train Loss: 1.9607, Train Accuracy: 47.27%
#     Worker 3: Train Loss: 1.9956, Train Accuracy: 46.20%
# Total Computation Time: 1574.27 seconds
# Total Communication Time: 0.46 seconds
# Epoch 50/150: Test Loss: 2.0260, Test Accuracy: 46.95%
#     Worker 0: Train Loss: 1.9659, Train Accuracy: 46.91%
#     Worker 1: Train Loss: 1.9733, Train Accuracy: 46.71%
#     Worker 2: Train Loss: 1.9505, Train Accuracy: 47.41%
#     Worker 3: Train Loss: 1.9675, Train Accuracy: 47.12%
# Total Computation Time: 1606.08 seconds
# Total Communication Time: 0.47 seconds
# Epoch 51/150: Test Loss: 2.0213, Test Accuracy: 47.22%
#     Worker 0: Train Loss: 1.9606, Train Accuracy: 46.31%
#     Worker 1: Train Loss: 1.9721, Train Accuracy: 46.79%
#     Worker 2: Train Loss: 1.9466, Train Accuracy: 47.42%
#     Worker 3: Train Loss: 1.9634, Train Accuracy: 47.00%
# Total Computation Time: 1638.01 seconds
# Total Communication Time: 0.48 seconds
# Epoch 52/150: Test Loss: 2.0107, Test Accuracy: 47.82%
#     Worker 0: Train Loss: 1.9431, Train Accuracy: 47.50%
#     Worker 1: Train Loss: 1.9290, Train Accuracy: 47.84%
#     Worker 2: Train Loss: 1.9222, Train Accuracy: 48.15%
#     Worker 3: Train Loss: 1.9488, Train Accuracy: 47.43%
# Total Computation Time: 1670.19 seconds
# Total Communication Time: 0.49 seconds
# Epoch 53/150: Test Loss: 2.0112, Test Accuracy: 47.68%
#     Worker 0: Train Loss: 1.9070, Train Accuracy: 48.46%
#     Worker 1: Train Loss: 1.9094, Train Accuracy: 48.36%
#     Worker 2: Train Loss: 1.8916, Train Accuracy: 49.18%
#     Worker 3: Train Loss: 1.9322, Train Accuracy: 47.66%
# Total Computation Time: 1702.23 seconds
# Total Communication Time: 0.49 seconds
# Epoch 54/150: Test Loss: 2.0067, Test Accuracy: 47.94%
#     Worker 0: Train Loss: 1.8983, Train Accuracy: 48.18%
#     Worker 1: Train Loss: 1.8873, Train Accuracy: 49.08%
#     Worker 2: Train Loss: 1.8729, Train Accuracy: 49.59%
#     Worker 3: Train Loss: 1.8982, Train Accuracy: 48.36%
# Total Computation Time: 1733.86 seconds
# Total Communication Time: 0.50 seconds
# Epoch 55/150: Test Loss: 1.9926, Test Accuracy: 48.04%
#     Worker 0: Train Loss: 1.8852, Train Accuracy: 48.59%
#     Worker 1: Train Loss: 1.8913, Train Accuracy: 48.80%
#     Worker 2: Train Loss: 1.8660, Train Accuracy: 49.57%
#     Worker 3: Train Loss: 1.9023, Train Accuracy: 49.05%
# Total Computation Time: 1766.14 seconds
# Total Communication Time: 0.51 seconds
# Epoch 56/150: Test Loss: 1.9939, Test Accuracy: 48.11%
#     Worker 0: Train Loss: 1.8628, Train Accuracy: 48.94%
#     Worker 1: Train Loss: 1.8535, Train Accuracy: 49.86%
#     Worker 2: Train Loss: 1.8294, Train Accuracy: 50.21%
#     Worker 3: Train Loss: 1.8659, Train Accuracy: 49.59%
# Total Computation Time: 1798.26 seconds
# Total Communication Time: 0.52 seconds
# Epoch 57/150: Test Loss: 1.9886, Test Accuracy: 48.04%
#     Worker 0: Train Loss: 1.8427, Train Accuracy: 49.45%
#     Worker 1: Train Loss: 1.8589, Train Accuracy: 49.63%
#     Worker 2: Train Loss: 1.8387, Train Accuracy: 50.04%
#     Worker 3: Train Loss: 1.8547, Train Accuracy: 50.18%
# Total Computation Time: 1830.42 seconds
# Total Communication Time: 0.53 seconds
# Epoch 58/150: Test Loss: 1.9816, Test Accuracy: 48.68%
#     Worker 0: Train Loss: 1.8283, Train Accuracy: 49.77%
#     Worker 1: Train Loss: 1.8271, Train Accuracy: 50.56%
#     Worker 2: Train Loss: 1.8468, Train Accuracy: 50.10%
#     Worker 3: Train Loss: 1.8499, Train Accuracy: 49.36%
# Total Computation Time: 1862.83 seconds
# Total Communication Time: 0.54 seconds
# Epoch 59/150: Test Loss: 1.9755, Test Accuracy: 48.57%
#     Worker 0: Train Loss: 1.8346, Train Accuracy: 49.64%
#     Worker 1: Train Loss: 1.8182, Train Accuracy: 50.34%
#     Worker 2: Train Loss: 1.8073, Train Accuracy: 50.84%
#     Worker 3: Train Loss: 1.8279, Train Accuracy: 50.84%
# Total Computation Time: 1895.59 seconds
# Total Communication Time: 0.55 seconds
# Epoch 60/150: Test Loss: 1.9783, Test Accuracy: 48.34%
#     Worker 0: Train Loss: 1.8023, Train Accuracy: 50.72%
#     Worker 1: Train Loss: 1.8144, Train Accuracy: 50.74%
#     Worker 2: Train Loss: 1.7949, Train Accuracy: 50.91%
#     Worker 3: Train Loss: 1.7932, Train Accuracy: 51.76%
# Total Computation Time: 1928.98 seconds
# Total Communication Time: 0.56 seconds
# Epoch 61/150: Test Loss: 1.9688, Test Accuracy: 49.00%
#     Worker 0: Train Loss: 1.7783, Train Accuracy: 50.40%
#     Worker 1: Train Loss: 1.7727, Train Accuracy: 51.74%
#     Worker 2: Train Loss: 1.7641, Train Accuracy: 51.42%
#     Worker 3: Train Loss: 1.8238, Train Accuracy: 50.35%
# Total Computation Time: 1961.36 seconds
# Total Communication Time: 0.56 seconds
# Epoch 62/150: Test Loss: 1.9658, Test Accuracy: 48.98%
#     Worker 0: Train Loss: 1.7876, Train Accuracy: 50.62%
#     Worker 1: Train Loss: 1.7885, Train Accuracy: 51.02%
#     Worker 2: Train Loss: 1.7647, Train Accuracy: 51.74%
#     Worker 3: Train Loss: 1.7893, Train Accuracy: 50.91%
# Total Computation Time: 1993.79 seconds
# Total Communication Time: 0.57 seconds
# Epoch 63/150: Test Loss: 1.9640, Test Accuracy: 48.76%
#     Worker 0: Train Loss: 1.7827, Train Accuracy: 50.79%
#     Worker 1: Train Loss: 1.7630, Train Accuracy: 51.55%
#     Worker 2: Train Loss: 1.7550, Train Accuracy: 51.99%
#     Worker 3: Train Loss: 1.7692, Train Accuracy: 51.73%
# Total Computation Time: 2025.81 seconds
# Total Communication Time: 0.58 seconds
# Epoch 64/150: Test Loss: 1.9526, Test Accuracy: 49.23%
#     Worker 0: Train Loss: 1.7560, Train Accuracy: 51.62%
#     Worker 1: Train Loss: 1.7339, Train Accuracy: 52.61%
#     Worker 2: Train Loss: 1.7492, Train Accuracy: 52.18%
#     Worker 3: Train Loss: 1.7527, Train Accuracy: 51.96%
# Total Computation Time: 2057.37 seconds
# Total Communication Time: 0.59 seconds
# Epoch 65/150: Test Loss: 1.9545, Test Accuracy: 49.43%
#     Worker 0: Train Loss: 1.7367, Train Accuracy: 52.06%
#     Worker 1: Train Loss: 1.7307, Train Accuracy: 52.80%
#     Worker 2: Train Loss: 1.7224, Train Accuracy: 52.85%
#     Worker 3: Train Loss: 1.7489, Train Accuracy: 52.04%
# Total Computation Time: 2089.75 seconds
# Total Communication Time: 0.60 seconds
# Epoch 66/150: Test Loss: 1.9460, Test Accuracy: 49.40%
#     Worker 0: Train Loss: 1.7249, Train Accuracy: 52.26%
#     Worker 1: Train Loss: 1.7159, Train Accuracy: 52.87%
#     Worker 2: Train Loss: 1.6983, Train Accuracy: 53.52%
#     Worker 3: Train Loss: 1.7237, Train Accuracy: 53.02%
# Total Computation Time: 2121.91 seconds
# Total Communication Time: 0.60 seconds
# Epoch 67/150: Test Loss: 1.9440, Test Accuracy: 49.72%
#     Worker 0: Train Loss: 1.7195, Train Accuracy: 51.90%
#     Worker 1: Train Loss: 1.6986, Train Accuracy: 53.29%
#     Worker 2: Train Loss: 1.6847, Train Accuracy: 53.62%
#     Worker 3: Train Loss: 1.7224, Train Accuracy: 53.03%
# Total Computation Time: 2154.25 seconds
# Total Communication Time: 0.61 seconds
# Epoch 68/150: Test Loss: 1.9450, Test Accuracy: 49.38%
#     Worker 0: Train Loss: 1.6762, Train Accuracy: 53.57%
#     Worker 1: Train Loss: 1.7011, Train Accuracy: 53.33%
#     Worker 2: Train Loss: 1.6890, Train Accuracy: 53.60%
#     Worker 3: Train Loss: 1.7028, Train Accuracy: 53.34%
# Total Computation Time: 2186.13 seconds
# Total Communication Time: 0.62 seconds
# Epoch 69/150: Test Loss: 1.9562, Test Accuracy: 49.31%
#     Worker 0: Train Loss: 1.6706, Train Accuracy: 53.44%
#     Worker 1: Train Loss: 1.6698, Train Accuracy: 54.11%
#     Worker 2: Train Loss: 1.6636, Train Accuracy: 54.22%
#     Worker 3: Train Loss: 1.6778, Train Accuracy: 54.20%
# Total Computation Time: 2218.06 seconds
# Total Communication Time: 0.63 seconds
# Epoch 70/150: Test Loss: 1.9435, Test Accuracy: 49.62%
#     Worker 0: Train Loss: 1.6676, Train Accuracy: 53.56%
#     Worker 1: Train Loss: 1.6658, Train Accuracy: 54.21%
#     Worker 2: Train Loss: 1.6583, Train Accuracy: 54.28%
#     Worker 3: Train Loss: 1.6842, Train Accuracy: 54.02%
# Total Computation Time: 2250.29 seconds
# Total Communication Time: 0.64 seconds
# Epoch 71/150: Test Loss: 1.9354, Test Accuracy: 49.90%
#     Worker 0: Train Loss: 1.6629, Train Accuracy: 53.31%
#     Worker 1: Train Loss: 1.6410, Train Accuracy: 54.60%
#     Worker 2: Train Loss: 1.6474, Train Accuracy: 54.76%
#     Worker 3: Train Loss: 1.6480, Train Accuracy: 54.85%
# Total Computation Time: 2282.69 seconds
# Total Communication Time: 0.65 seconds
# Epoch 72/150: Test Loss: 1.9367, Test Accuracy: 49.96%
#     Worker 0: Train Loss: 1.6284, Train Accuracy: 54.51%
#     Worker 1: Train Loss: 1.6540, Train Accuracy: 54.39%
#     Worker 2: Train Loss: 1.6383, Train Accuracy: 54.92%
#     Worker 3: Train Loss: 1.6542, Train Accuracy: 54.53%
# Total Computation Time: 2314.96 seconds
# Total Communication Time: 0.66 seconds
# Epoch 73/150: Test Loss: 1.9347, Test Accuracy: 50.02%
#     Worker 0: Train Loss: 1.6245, Train Accuracy: 54.72%
#     Worker 1: Train Loss: 1.6323, Train Accuracy: 54.57%
#     Worker 2: Train Loss: 1.5980, Train Accuracy: 55.49%
#     Worker 3: Train Loss: 1.6208, Train Accuracy: 55.32%
# Total Computation Time: 2347.42 seconds
# Total Communication Time: 0.66 seconds
# Epoch 74/150: Test Loss: 1.9320, Test Accuracy: 50.22%
#     Worker 0: Train Loss: 1.6057, Train Accuracy: 55.13%
#     Worker 1: Train Loss: 1.5978, Train Accuracy: 55.58%
#     Worker 2: Train Loss: 1.6124, Train Accuracy: 55.25%
#     Worker 3: Train Loss: 1.6406, Train Accuracy: 54.54%
# Total Computation Time: 2379.07 seconds
# Total Communication Time: 0.67 seconds
# Epoch 75/150: Test Loss: 1.9326, Test Accuracy: 50.43%
#     Worker 0: Train Loss: 1.6185, Train Accuracy: 54.87%
#     Worker 1: Train Loss: 1.6171, Train Accuracy: 55.07%
#     Worker 2: Train Loss: 1.6112, Train Accuracy: 55.02%
#     Worker 3: Train Loss: 1.6245, Train Accuracy: 55.00%
# Total Computation Time: 2410.46 seconds
# Total Communication Time: 0.68 seconds
# Epoch 76/150: Test Loss: 1.9293, Test Accuracy: 50.43%
#     Worker 0: Train Loss: 1.5883, Train Accuracy: 55.41%
#     Worker 1: Train Loss: 1.5901, Train Accuracy: 55.62%
#     Worker 2: Train Loss: 1.5876, Train Accuracy: 55.87%
#     Worker 3: Train Loss: 1.6009, Train Accuracy: 55.42%
# Total Computation Time: 2443.03 seconds
# Total Communication Time: 0.69 seconds
# Epoch 77/150: Test Loss: 1.9309, Test Accuracy: 50.16%
#     Worker 0: Train Loss: 1.5943, Train Accuracy: 55.53%
#     Worker 1: Train Loss: 1.5759, Train Accuracy: 56.10%
#     Worker 2: Train Loss: 1.5792, Train Accuracy: 56.21%
#     Worker 3: Train Loss: 1.5770, Train Accuracy: 56.74%
# Total Computation Time: 2475.17 seconds
# Total Communication Time: 0.70 seconds
# Epoch 78/150: Test Loss: 1.9322, Test Accuracy: 50.53%
#     Worker 0: Train Loss: 1.5867, Train Accuracy: 55.78%
#     Worker 1: Train Loss: 1.5590, Train Accuracy: 56.70%
#     Worker 2: Train Loss: 1.5729, Train Accuracy: 56.19%
#     Worker 3: Train Loss: 1.5967, Train Accuracy: 55.80%
# Total Computation Time: 2506.92 seconds
# Total Communication Time: 0.70 seconds
# Epoch 79/150: Test Loss: 1.9377, Test Accuracy: 50.26%
#     Worker 0: Train Loss: 1.5695, Train Accuracy: 55.85%
#     Worker 1: Train Loss: 1.5449, Train Accuracy: 57.03%
#     Worker 2: Train Loss: 1.5492, Train Accuracy: 57.17%
#     Worker 3: Train Loss: 1.5584, Train Accuracy: 56.56%
# Total Computation Time: 2538.13 seconds
# Total Communication Time: 0.71 seconds
# Epoch 80/150: Test Loss: 1.9207, Test Accuracy: 50.75%
#     Worker 0: Train Loss: 1.5336, Train Accuracy: 56.79%
#     Worker 1: Train Loss: 1.5427, Train Accuracy: 57.31%
#     Worker 2: Train Loss: 1.5305, Train Accuracy: 56.98%
#     Worker 3: Train Loss: 1.5614, Train Accuracy: 56.84%
# Total Computation Time: 2569.94 seconds
# Total Communication Time: 0.72 seconds
# Epoch 81/150: Test Loss: 1.9225, Test Accuracy: 50.33%
#     Worker 0: Train Loss: 1.5404, Train Accuracy: 56.81%
#     Worker 1: Train Loss: 1.5403, Train Accuracy: 57.32%
#     Worker 2: Train Loss: 1.5223, Train Accuracy: 57.67%
#     Worker 3: Train Loss: 1.5511, Train Accuracy: 56.70%
# Total Computation Time: 2603.01 seconds
# Total Communication Time: 0.73 seconds
# Epoch 82/150: Test Loss: 1.9288, Test Accuracy: 50.52%
#     Worker 0: Train Loss: 1.5154, Train Accuracy: 57.23%
#     Worker 1: Train Loss: 1.5177, Train Accuracy: 57.43%
#     Worker 2: Train Loss: 1.5233, Train Accuracy: 57.64%
#     Worker 3: Train Loss: 1.5369, Train Accuracy: 57.66%
# Total Computation Time: 2634.51 seconds
# Total Communication Time: 0.74 seconds
# Epoch 83/150: Test Loss: 1.9207, Test Accuracy: 50.82%
#     Worker 0: Train Loss: 1.5088, Train Accuracy: 57.18%
#     Worker 1: Train Loss: 1.5055, Train Accuracy: 57.67%
#     Worker 2: Train Loss: 1.4885, Train Accuracy: 58.55%
#     Worker 3: Train Loss: 1.5303, Train Accuracy: 56.75%
# Total Computation Time: 2665.94 seconds
# Total Communication Time: 0.75 seconds
# Epoch 84/150: Test Loss: 1.9178, Test Accuracy: 50.49%
#     Worker 0: Train Loss: 1.4878, Train Accuracy: 58.13%
#     Worker 1: Train Loss: 1.4884, Train Accuracy: 58.18%
#     Worker 2: Train Loss: 1.4985, Train Accuracy: 57.86%
#     Worker 3: Train Loss: 1.5136, Train Accuracy: 57.53%
# Total Computation Time: 2698.17 seconds
# Total Communication Time: 0.75 seconds
# Epoch 85/150: Test Loss: 1.9149, Test Accuracy: 50.60%
#     Worker 0: Train Loss: 1.5028, Train Accuracy: 57.78%
#     Worker 1: Train Loss: 1.4950, Train Accuracy: 57.96%
#     Worker 2: Train Loss: 1.4829, Train Accuracy: 58.79%
#     Worker 3: Train Loss: 1.5048, Train Accuracy: 57.91%
# Total Computation Time: 2730.49 seconds
# Total Communication Time: 0.76 seconds
# Epoch 86/150: Test Loss: 1.9294, Test Accuracy: 50.80%
#     Worker 0: Train Loss: 1.4725, Train Accuracy: 58.24%
#     Worker 1: Train Loss: 1.4786, Train Accuracy: 58.89%
#     Worker 2: Train Loss: 1.4696, Train Accuracy: 59.41%
#     Worker 3: Train Loss: 1.4902, Train Accuracy: 58.32%
# Total Computation Time: 2763.66 seconds
# Total Communication Time: 0.77 seconds
# Epoch 87/150: Test Loss: 1.9193, Test Accuracy: 50.87%
#     Worker 0: Train Loss: 1.4895, Train Accuracy: 58.18%
#     Worker 1: Train Loss: 1.4760, Train Accuracy: 58.81%
#     Worker 2: Train Loss: 1.4628, Train Accuracy: 58.98%
#     Worker 3: Train Loss: 1.4702, Train Accuracy: 59.01%
# Total Computation Time: 2795.38 seconds
# Total Communication Time: 0.78 seconds
# Epoch 88/150: Test Loss: 1.9270, Test Accuracy: 50.71%
#     Worker 0: Train Loss: 1.4705, Train Accuracy: 58.82%
#     Worker 1: Train Loss: 1.4640, Train Accuracy: 59.36%
#     Worker 2: Train Loss: 1.4638, Train Accuracy: 59.56%
#     Worker 3: Train Loss: 1.4689, Train Accuracy: 59.07%
# Total Computation Time: 2827.01 seconds
# Total Communication Time: 0.79 seconds
# Epoch 89/150: Test Loss: 1.9278, Test Accuracy: 51.14%
#     Worker 0: Train Loss: 1.4452, Train Accuracy: 58.91%
#     Worker 1: Train Loss: 1.4323, Train Accuracy: 59.82%
#     Worker 2: Train Loss: 1.4396, Train Accuracy: 59.51%
#     Worker 3: Train Loss: 1.4487, Train Accuracy: 59.99%
# Total Computation Time: 2859.19 seconds
# Total Communication Time: 0.80 seconds
# Epoch 90/150: Test Loss: 1.9228, Test Accuracy: 50.89%
#     Worker 0: Train Loss: 1.4349, Train Accuracy: 59.39%
#     Worker 1: Train Loss: 1.4296, Train Accuracy: 59.59%
#     Worker 2: Train Loss: 1.4223, Train Accuracy: 60.58%
#     Worker 3: Train Loss: 1.4497, Train Accuracy: 59.22%
# Total Computation Time: 2891.37 seconds
# Total Communication Time: 0.80 seconds
# Epoch 91/150: Test Loss: 1.9281, Test Accuracy: 50.70%
#     Worker 0: Train Loss: 1.4185, Train Accuracy: 59.44%
#     Worker 1: Train Loss: 1.4374, Train Accuracy: 59.82%
#     Worker 2: Train Loss: 1.4172, Train Accuracy: 60.32%
#     Worker 3: Train Loss: 1.4290, Train Accuracy: 59.83%
# Total Computation Time: 2923.56 seconds
# Total Communication Time: 0.81 seconds
# Epoch 92/150: Test Loss: 1.9272, Test Accuracy: 51.20%
#     Worker 0: Train Loss: 1.4362, Train Accuracy: 59.43%
#     Worker 1: Train Loss: 1.3994, Train Accuracy: 60.60%
#     Worker 2: Train Loss: 1.4134, Train Accuracy: 60.29%
#     Worker 3: Train Loss: 1.4222, Train Accuracy: 59.89%
# Total Computation Time: 2955.04 seconds
# Total Communication Time: 0.82 seconds
# Epoch 93/150: Test Loss: 1.9290, Test Accuracy: 50.75%
#     Worker 0: Train Loss: 1.4069, Train Accuracy: 60.21%
#     Worker 1: Train Loss: 1.4118, Train Accuracy: 60.40%
#     Worker 2: Train Loss: 1.4032, Train Accuracy: 60.41%
#     Worker 3: Train Loss: 1.4257, Train Accuracy: 60.50%
# Total Computation Time: 2986.81 seconds
# Total Communication Time: 0.83 seconds
# Epoch 94/150: Test Loss: 1.9238, Test Accuracy: 51.34%
#     Worker 0: Train Loss: 1.3972, Train Accuracy: 60.09%
#     Worker 1: Train Loss: 1.4115, Train Accuracy: 60.21%
#     Worker 2: Train Loss: 1.4058, Train Accuracy: 60.54%
#     Worker 3: Train Loss: 1.4094, Train Accuracy: 60.07%
# Total Computation Time: 3018.78 seconds
# Total Communication Time: 0.84 seconds
# Epoch 95/150: Test Loss: 1.9286, Test Accuracy: 51.07%
#     Worker 0: Train Loss: 1.3802, Train Accuracy: 60.74%
#     Worker 1: Train Loss: 1.3755, Train Accuracy: 60.97%
#     Worker 2: Train Loss: 1.3717, Train Accuracy: 61.27%
#     Worker 3: Train Loss: 1.4002, Train Accuracy: 60.87%
# Total Computation Time: 3050.48 seconds
# Total Communication Time: 0.84 seconds
# Epoch 96/150: Test Loss: 1.9293, Test Accuracy: 50.99%
#     Worker 0: Train Loss: 1.3742, Train Accuracy: 61.24%
#     Worker 1: Train Loss: 1.3648, Train Accuracy: 61.44%
#     Worker 2: Train Loss: 1.3649, Train Accuracy: 61.26%
#     Worker 3: Train Loss: 1.3827, Train Accuracy: 60.85%
# Total Computation Time: 3082.53 seconds
# Total Communication Time: 0.85 seconds
# Epoch 97/150: Test Loss: 1.9252, Test Accuracy: 51.25%
#     Worker 0: Train Loss: 1.3861, Train Accuracy: 60.44%
#     Worker 1: Train Loss: 1.3852, Train Accuracy: 61.03%
#     Worker 2: Train Loss: 1.3613, Train Accuracy: 61.56%
#     Worker 3: Train Loss: 1.3693, Train Accuracy: 61.27%
# Total Computation Time: 3114.17 seconds
# Total Communication Time: 0.86 seconds
# Epoch 98/150: Test Loss: 1.9337, Test Accuracy: 50.97%
#     Worker 0: Train Loss: 1.3565, Train Accuracy: 60.76%
#     Worker 1: Train Loss: 1.3590, Train Accuracy: 61.62%
#     Worker 2: Train Loss: 1.3554, Train Accuracy: 61.64%
#     Worker 3: Train Loss: 1.3831, Train Accuracy: 60.95%
# Total Computation Time: 3146.68 seconds
# Total Communication Time: 0.87 seconds
# Epoch 99/150: Test Loss: 1.9299, Test Accuracy: 51.25%
#     Worker 0: Train Loss: 1.3648, Train Accuracy: 61.19%
#     Worker 1: Train Loss: 1.3611, Train Accuracy: 61.70%
#     Worker 2: Train Loss: 1.3460, Train Accuracy: 62.19%
#     Worker 3: Train Loss: 1.3607, Train Accuracy: 62.23%
# Total Computation Time: 3179.15 seconds
# Total Communication Time: 0.88 seconds
# Epoch 100/150: Test Loss: 1.9382, Test Accuracy: 51.21%
#     Worker 0: Train Loss: 1.3396, Train Accuracy: 61.85%
#     Worker 1: Train Loss: 1.3442, Train Accuracy: 62.08%
#     Worker 2: Train Loss: 1.3369, Train Accuracy: 62.58%
#     Worker 3: Train Loss: 1.3392, Train Accuracy: 62.31%
# Total Computation Time: 3211.16 seconds
# Total Communication Time: 0.89 seconds
# Epoch 101/150: Test Loss: 1.9360, Test Accuracy: 51.07%
#     Worker 0: Train Loss: 1.3439, Train Accuracy: 61.90%
#     Worker 1: Train Loss: 1.3152, Train Accuracy: 62.81%
#     Worker 2: Train Loss: 1.3195, Train Accuracy: 62.73%
#     Worker 3: Train Loss: 1.3546, Train Accuracy: 62.07%
# Total Computation Time: 3243.43 seconds
# Total Communication Time: 0.89 seconds
# Epoch 102/150: Test Loss: 1.9415, Test Accuracy: 51.20%
#     Worker 0: Train Loss: 1.3194, Train Accuracy: 62.21%
#     Worker 1: Train Loss: 1.3263, Train Accuracy: 62.34%
#     Worker 2: Train Loss: 1.3152, Train Accuracy: 62.62%
#     Worker 3: Train Loss: 1.3351, Train Accuracy: 62.26%
# Total Computation Time: 3275.22 seconds
# Total Communication Time: 0.90 seconds
# Epoch 103/150: Test Loss: 1.9393, Test Accuracy: 51.39%
#     Worker 0: Train Loss: 1.3286, Train Accuracy: 61.93%
#     Worker 1: Train Loss: 1.3250, Train Accuracy: 62.67%
#     Worker 2: Train Loss: 1.3107, Train Accuracy: 62.69%
#     Worker 3: Train Loss: 1.3188, Train Accuracy: 62.56%
# Total Computation Time: 3307.42 seconds
# Total Communication Time: 0.91 seconds
# Epoch 104/150: Test Loss: 1.9421, Test Accuracy: 51.43%
#     Worker 0: Train Loss: 1.3077, Train Accuracy: 62.48%
#     Worker 1: Train Loss: 1.2956, Train Accuracy: 62.97%
#     Worker 2: Train Loss: 1.2984, Train Accuracy: 63.22%
#     Worker 3: Train Loss: 1.3242, Train Accuracy: 62.41%
# Total Computation Time: 3339.35 seconds
# Total Communication Time: 0.92 seconds
# Epoch 105/150: Test Loss: 1.9437, Test Accuracy: 51.50%
#     Worker 0: Train Loss: 1.3000, Train Accuracy: 62.81%
#     Worker 1: Train Loss: 1.3037, Train Accuracy: 63.27%
#     Worker 2: Train Loss: 1.3181, Train Accuracy: 62.51%
#     Worker 3: Train Loss: 1.3090, Train Accuracy: 62.52%
# Total Computation Time: 3370.81 seconds
# Total Communication Time: 0.93 seconds
# Epoch 106/150: Test Loss: 1.9482, Test Accuracy: 51.48%
#     Worker 0: Train Loss: 1.2825, Train Accuracy: 63.30%
#     Worker 1: Train Loss: 1.2874, Train Accuracy: 63.29%
#     Worker 2: Train Loss: 1.2720, Train Accuracy: 63.82%
#     Worker 3: Train Loss: 1.2887, Train Accuracy: 62.97%
# Total Computation Time: 3403.03 seconds
# Total Communication Time: 0.93 seconds
# Epoch 107/150: Test Loss: 1.9418, Test Accuracy: 51.48%
#     Worker 0: Train Loss: 1.2975, Train Accuracy: 62.83%
#     Worker 1: Train Loss: 1.2913, Train Accuracy: 63.62%
#     Worker 2: Train Loss: 1.2828, Train Accuracy: 63.46%
#     Worker 3: Train Loss: 1.2922, Train Accuracy: 63.23%
# Total Computation Time: 3435.35 seconds
# Total Communication Time: 0.94 seconds
# Epoch 108/150: Test Loss: 1.9507, Test Accuracy: 51.62%
#     Worker 0: Train Loss: 1.2865, Train Accuracy: 63.29%
#     Worker 1: Train Loss: 1.2709, Train Accuracy: 63.89%
#     Worker 2: Train Loss: 1.2743, Train Accuracy: 64.02%
#     Worker 3: Train Loss: 1.2805, Train Accuracy: 63.56%
# Total Computation Time: 3467.79 seconds
# Total Communication Time: 0.95 seconds
# Epoch 109/150: Test Loss: 1.9504, Test Accuracy: 51.66%
#     Worker 0: Train Loss: 1.2856, Train Accuracy: 63.12%
#     Worker 1: Train Loss: 1.2640, Train Accuracy: 64.11%
#     Worker 2: Train Loss: 1.2664, Train Accuracy: 63.99%
#     Worker 3: Train Loss: 1.2807, Train Accuracy: 63.86%
# Total Computation Time: 3499.86 seconds
# Total Communication Time: 0.96 seconds
# Epoch 110/150: Test Loss: 1.9533, Test Accuracy: 51.33%
#     Worker 0: Train Loss: 1.2710, Train Accuracy: 63.81%
#     Worker 1: Train Loss: 1.2527, Train Accuracy: 64.29%
#     Worker 2: Train Loss: 1.2522, Train Accuracy: 64.77%
#     Worker 3: Train Loss: 1.2658, Train Accuracy: 64.24%
# Total Computation Time: 3531.28 seconds
# Total Communication Time: 0.97 seconds
# Epoch 111/150: Test Loss: 1.9501, Test Accuracy: 51.48%
#     Worker 0: Train Loss: 1.2598, Train Accuracy: 63.48%
#     Worker 1: Train Loss: 1.2578, Train Accuracy: 64.50%
#     Worker 2: Train Loss: 1.2678, Train Accuracy: 64.17%
#     Worker 3: Train Loss: 1.2803, Train Accuracy: 64.05%
# Total Computation Time: 3563.62 seconds
# Total Communication Time: 0.97 seconds
# Epoch 112/150: Test Loss: 1.9494, Test Accuracy: 51.65%
#     Worker 0: Train Loss: 1.2534, Train Accuracy: 64.46%
#     Worker 1: Train Loss: 1.2484, Train Accuracy: 64.75%
#     Worker 2: Train Loss: 1.2332, Train Accuracy: 64.79%
#     Worker 3: Train Loss: 1.2688, Train Accuracy: 64.45%
# Total Computation Time: 3595.63 seconds
# Total Communication Time: 0.98 seconds
# Epoch 113/150: Test Loss: 1.9515, Test Accuracy: 51.48%
#     Worker 0: Train Loss: 1.2469, Train Accuracy: 63.93%
#     Worker 1: Train Loss: 1.2325, Train Accuracy: 64.82%
#     Worker 2: Train Loss: 1.2502, Train Accuracy: 64.57%
#     Worker 3: Train Loss: 1.2430, Train Accuracy: 64.40%
# Total Computation Time: 3627.72 seconds
# Total Communication Time: 0.99 seconds
# Epoch 114/150: Test Loss: 1.9496, Test Accuracy: 51.64%
#     Worker 0: Train Loss: 1.2620, Train Accuracy: 64.05%
#     Worker 1: Train Loss: 1.2461, Train Accuracy: 64.74%
#     Worker 2: Train Loss: 1.2200, Train Accuracy: 65.45%
#     Worker 3: Train Loss: 1.2402, Train Accuracy: 65.18%
# Total Computation Time: 3659.48 seconds
# Total Communication Time: 1.00 seconds
# Epoch 115/150: Test Loss: 1.9604, Test Accuracy: 51.65%
#     Worker 0: Train Loss: 1.2443, Train Accuracy: 64.04%
#     Worker 1: Train Loss: 1.2268, Train Accuracy: 64.83%
#     Worker 2: Train Loss: 1.2384, Train Accuracy: 64.84%
#     Worker 3: Train Loss: 1.2348, Train Accuracy: 65.02%
# Total Computation Time: 3690.71 seconds
# Total Communication Time: 1.01 seconds
# Epoch 116/150: Test Loss: 1.9571, Test Accuracy: 51.23%
#     Worker 0: Train Loss: 1.2279, Train Accuracy: 65.13%
#     Worker 1: Train Loss: 1.2230, Train Accuracy: 65.38%
#     Worker 2: Train Loss: 1.2109, Train Accuracy: 65.58%
#     Worker 3: Train Loss: 1.2405, Train Accuracy: 64.57%
# Total Computation Time: 3723.28 seconds
# Total Communication Time: 1.01 seconds
# Epoch 117/150: Test Loss: 1.9564, Test Accuracy: 51.41%
#     Worker 0: Train Loss: 1.2293, Train Accuracy: 64.62%
#     Worker 1: Train Loss: 1.2207, Train Accuracy: 65.09%
#     Worker 2: Train Loss: 1.2183, Train Accuracy: 65.45%
#     Worker 3: Train Loss: 1.2368, Train Accuracy: 65.09%
# Total Computation Time: 3755.32 seconds
# Total Communication Time: 1.02 seconds
# Epoch 118/150: Test Loss: 1.9569, Test Accuracy: 51.56%
#     Worker 0: Train Loss: 1.2212, Train Accuracy: 65.05%
#     Worker 1: Train Loss: 1.2093, Train Accuracy: 65.21%
#     Worker 2: Train Loss: 1.2163, Train Accuracy: 65.63%
#     Worker 3: Train Loss: 1.2233, Train Accuracy: 64.89%
# Total Computation Time: 3787.33 seconds
# Total Communication Time: 1.03 seconds
# Epoch 119/150: Test Loss: 1.9669, Test Accuracy: 51.27%
#     Worker 0: Train Loss: 1.2162, Train Accuracy: 64.80%
#     Worker 1: Train Loss: 1.2157, Train Accuracy: 65.67%
#     Worker 2: Train Loss: 1.1811, Train Accuracy: 66.52%
#     Worker 3: Train Loss: 1.2048, Train Accuracy: 66.06%
# Total Computation Time: 3818.97 seconds
# Total Communication Time: 1.04 seconds
# Epoch 120/150: Test Loss: 1.9600, Test Accuracy: 51.67%
#     Worker 0: Train Loss: 1.2128, Train Accuracy: 65.11%
#     Worker 1: Train Loss: 1.2069, Train Accuracy: 66.21%
#     Worker 2: Train Loss: 1.2224, Train Accuracy: 65.38%
#     Worker 3: Train Loss: 1.2099, Train Accuracy: 65.48%
# Total Computation Time: 3851.59 seconds
# Total Communication Time: 1.05 seconds
# Epoch 121/150: Test Loss: 1.9638, Test Accuracy: 51.56%
#     Worker 0: Train Loss: 1.2135, Train Accuracy: 65.44%
#     Worker 1: Train Loss: 1.2025, Train Accuracy: 65.88%
#     Worker 2: Train Loss: 1.1825, Train Accuracy: 66.40%
#     Worker 3: Train Loss: 1.1936, Train Accuracy: 65.80%
# Total Computation Time: 3883.79 seconds
# Total Communication Time: 1.05 seconds
# Epoch 122/150: Test Loss: 1.9654, Test Accuracy: 51.42%
#     Worker 0: Train Loss: 1.2134, Train Accuracy: 65.06%
#     Worker 1: Train Loss: 1.1924, Train Accuracy: 66.11%
#     Worker 2: Train Loss: 1.1990, Train Accuracy: 65.74%
#     Worker 3: Train Loss: 1.1959, Train Accuracy: 65.85%
# Total Computation Time: 3915.95 seconds
# Total Communication Time: 1.06 seconds
# Epoch 123/150: Test Loss: 1.9621, Test Accuracy: 51.50%
#     Worker 0: Train Loss: 1.2005, Train Accuracy: 65.43%
#     Worker 1: Train Loss: 1.1725, Train Accuracy: 67.06%
#     Worker 2: Train Loss: 1.1865, Train Accuracy: 66.27%
#     Worker 3: Train Loss: 1.1953, Train Accuracy: 65.86%
# Total Computation Time: 3947.70 seconds
# Total Communication Time: 1.07 seconds
# Epoch 124/150: Test Loss: 1.9643, Test Accuracy: 51.49%
#     Worker 0: Train Loss: 1.1886, Train Accuracy: 65.65%
#     Worker 1: Train Loss: 1.1953, Train Accuracy: 65.82%
#     Worker 2: Train Loss: 1.1893, Train Accuracy: 66.35%
#     Worker 3: Train Loss: 1.2059, Train Accuracy: 65.80%
# Total Computation Time: 3979.44 seconds
# Total Communication Time: 1.08 seconds
# Epoch 125/150: Test Loss: 1.9663, Test Accuracy: 51.56%
#     Worker 0: Train Loss: 1.1669, Train Accuracy: 66.64%
#     Worker 1: Train Loss: 1.1858, Train Accuracy: 66.38%
#     Worker 2: Train Loss: 1.1712, Train Accuracy: 66.78%
#     Worker 3: Train Loss: 1.1915, Train Accuracy: 66.07%
# Total Computation Time: 4011.99 seconds
# Total Communication Time: 1.09 seconds
# Epoch 126/150: Test Loss: 1.9692, Test Accuracy: 51.53%
#     Worker 0: Train Loss: 1.1909, Train Accuracy: 65.80%
#     Worker 1: Train Loss: 1.1753, Train Accuracy: 66.62%
#     Worker 2: Train Loss: 1.1661, Train Accuracy: 66.80%
#     Worker 3: Train Loss: 1.1863, Train Accuracy: 66.46%
# Total Computation Time: 4044.20 seconds
# Total Communication Time: 1.09 seconds
# Epoch 127/150: Test Loss: 1.9691, Test Accuracy: 51.71%
#     Worker 0: Train Loss: 1.1682, Train Accuracy: 66.69%
#     Worker 1: Train Loss: 1.1778, Train Accuracy: 66.60%
#     Worker 2: Train Loss: 1.1607, Train Accuracy: 67.02%
#     Worker 3: Train Loss: 1.1789, Train Accuracy: 66.38%
# Total Computation Time: 4076.48 seconds
# Total Communication Time: 1.10 seconds
# Epoch 128/150: Test Loss: 1.9684, Test Accuracy: 51.66%
#     Worker 0: Train Loss: 1.1649, Train Accuracy: 66.40%
#     Worker 1: Train Loss: 1.1685, Train Accuracy: 66.59%
#     Worker 2: Train Loss: 1.1706, Train Accuracy: 66.63%
#     Worker 3: Train Loss: 1.1609, Train Accuracy: 67.05%
# Total Computation Time: 4108.23 seconds
# Total Communication Time: 1.11 seconds
# Epoch 129/150: Test Loss: 1.9686, Test Accuracy: 51.43%
#     Worker 0: Train Loss: 1.1702, Train Accuracy: 66.35%
#     Worker 1: Train Loss: 1.1619, Train Accuracy: 66.88%
#     Worker 2: Train Loss: 1.1733, Train Accuracy: 66.76%
#     Worker 3: Train Loss: 1.1939, Train Accuracy: 66.08%
# Total Computation Time: 4139.53 seconds
# Total Communication Time: 1.12 seconds
# Epoch 130/150: Test Loss: 1.9704, Test Accuracy: 51.67%
#     Worker 0: Train Loss: 1.1634, Train Accuracy: 66.76%
#     Worker 1: Train Loss: 1.1527, Train Accuracy: 67.45%
#     Worker 2: Train Loss: 1.1548, Train Accuracy: 67.04%
#     Worker 3: Train Loss: 1.1701, Train Accuracy: 66.70%
# Total Computation Time: 4172.57 seconds
# Total Communication Time: 1.13 seconds
# Epoch 131/150: Test Loss: 1.9704, Test Accuracy: 51.61%
#     Worker 0: Train Loss: 1.1827, Train Accuracy: 66.05%
#     Worker 1: Train Loss: 1.1668, Train Accuracy: 66.83%
#     Worker 2: Train Loss: 1.1584, Train Accuracy: 67.18%
#     Worker 3: Train Loss: 1.1722, Train Accuracy: 66.85%
# Total Computation Time: 4204.86 seconds
# Total Communication Time: 1.14 seconds
# Epoch 132/150: Test Loss: 1.9733, Test Accuracy: 51.46%
#     Worker 0: Train Loss: 1.1771, Train Accuracy: 66.04%
#     Worker 1: Train Loss: 1.1519, Train Accuracy: 67.01%
#     Worker 2: Train Loss: 1.1610, Train Accuracy: 67.00%
#     Worker 3: Train Loss: 1.1609, Train Accuracy: 66.99%
# Total Computation Time: 4237.12 seconds
# Total Communication Time: 1.14 seconds
# Epoch 133/150: Test Loss: 1.9736, Test Accuracy: 51.56%
#     Worker 0: Train Loss: 1.1550, Train Accuracy: 67.41%
#     Worker 1: Train Loss: 1.1563, Train Accuracy: 67.06%
#     Worker 2: Train Loss: 1.1488, Train Accuracy: 67.09%
#     Worker 3: Train Loss: 1.1625, Train Accuracy: 66.98%
# Total Computation Time: 4268.67 seconds
# Total Communication Time: 1.15 seconds
# Epoch 134/150: Test Loss: 1.9747, Test Accuracy: 51.61%
#     Worker 0: Train Loss: 1.1702, Train Accuracy: 66.34%
#     Worker 1: Train Loss: 1.1536, Train Accuracy: 67.24%
#     Worker 2: Train Loss: 1.1506, Train Accuracy: 67.08%
#     Worker 3: Train Loss: 1.1546, Train Accuracy: 67.13%
# Total Computation Time: 4300.20 seconds
# Total Communication Time: 1.16 seconds
# Epoch 135/150: Test Loss: 1.9754, Test Accuracy: 51.66%
#     Worker 0: Train Loss: 1.1566, Train Accuracy: 66.98%
#     Worker 1: Train Loss: 1.1413, Train Accuracy: 67.11%
#     Worker 2: Train Loss: 1.1524, Train Accuracy: 66.98%
#     Worker 3: Train Loss: 1.1541, Train Accuracy: 67.54%
# Total Computation Time: 4333.19 seconds
# Total Communication Time: 1.17 seconds
# Epoch 136/150: Test Loss: 1.9765, Test Accuracy: 51.62%
#     Worker 0: Train Loss: 1.1332, Train Accuracy: 66.88%
#     Worker 1: Train Loss: 1.1506, Train Accuracy: 67.76%
#     Worker 2: Train Loss: 1.1392, Train Accuracy: 67.47%
#     Worker 3: Train Loss: 1.1766, Train Accuracy: 66.72%
# Total Computation Time: 4365.12 seconds
# Total Communication Time: 1.18 seconds
# Epoch 137/150: Test Loss: 1.9747, Test Accuracy: 51.62%
#     Worker 0: Train Loss: 1.1620, Train Accuracy: 66.57%
#     Worker 1: Train Loss: 1.1457, Train Accuracy: 67.73%
#     Worker 2: Train Loss: 1.1404, Train Accuracy: 67.71%
#     Worker 3: Train Loss: 1.1416, Train Accuracy: 67.61%
# Total Computation Time: 4396.62 seconds
# Total Communication Time: 1.19 seconds
# Epoch 138/150: Test Loss: 1.9753, Test Accuracy: 51.63%
#     Worker 0: Train Loss: 1.1388, Train Accuracy: 66.99%
#     Worker 1: Train Loss: 1.1502, Train Accuracy: 67.28%
#     Worker 2: Train Loss: 1.1491, Train Accuracy: 67.67%
#     Worker 3: Train Loss: 1.1565, Train Accuracy: 66.92%
# Total Computation Time: 4427.98 seconds
# Total Communication Time: 1.20 seconds
# Epoch 139/150: Test Loss: 1.9756, Test Accuracy: 51.59%
#     Worker 0: Train Loss: 1.1542, Train Accuracy: 66.92%
#     Worker 1: Train Loss: 1.1400, Train Accuracy: 67.63%
#     Worker 2: Train Loss: 1.1310, Train Accuracy: 68.26%
#     Worker 3: Train Loss: 1.1495, Train Accuracy: 67.52%
# Total Computation Time: 4460.15 seconds
# Total Communication Time: 1.20 seconds
# Epoch 140/150: Test Loss: 1.9767, Test Accuracy: 51.50%
#     Worker 0: Train Loss: 1.1559, Train Accuracy: 66.93%
#     Worker 1: Train Loss: 1.1452, Train Accuracy: 67.61%
#     Worker 2: Train Loss: 1.1426, Train Accuracy: 67.17%
#     Worker 3: Train Loss: 1.1540, Train Accuracy: 67.33%
# Total Computation Time: 4493.39 seconds
# Total Communication Time: 1.21 seconds
# Epoch 141/150: Test Loss: 1.9767, Test Accuracy: 51.69%
#     Worker 0: Train Loss: 1.1426, Train Accuracy: 67.13%
#     Worker 1: Train Loss: 1.1432, Train Accuracy: 67.65%
#     Worker 2: Train Loss: 1.1400, Train Accuracy: 67.73%
#     Worker 3: Train Loss: 1.1601, Train Accuracy: 66.96%
# Total Computation Time: 4525.40 seconds
# Total Communication Time: 1.22 seconds
# Epoch 142/150: Test Loss: 1.9772, Test Accuracy: 51.61%
#     Worker 0: Train Loss: 1.1443, Train Accuracy: 67.18%
#     Worker 1: Train Loss: 1.1302, Train Accuracy: 67.83%
#     Worker 2: Train Loss: 1.1437, Train Accuracy: 67.39%
#     Worker 3: Train Loss: 1.1459, Train Accuracy: 67.48%
# Total Computation Time: 4556.53 seconds
# Total Communication Time: 1.23 seconds
# Epoch 143/150: Test Loss: 1.9775, Test Accuracy: 51.62%
#     Worker 0: Train Loss: 1.1469, Train Accuracy: 67.25%
#     Worker 1: Train Loss: 1.1473, Train Accuracy: 67.49%
#     Worker 2: Train Loss: 1.1400, Train Accuracy: 67.60%
#     Worker 3: Train Loss: 1.1401, Train Accuracy: 67.10%
# Total Computation Time: 4587.83 seconds
# Total Communication Time: 1.24 seconds
# Epoch 144/150: Test Loss: 1.9773, Test Accuracy: 51.55%
#     Worker 0: Train Loss: 1.1444, Train Accuracy: 67.35%
#     Worker 1: Train Loss: 1.1352, Train Accuracy: 67.62%
#     Worker 2: Train Loss: 1.1349, Train Accuracy: 67.54%
#     Worker 3: Train Loss: 1.1501, Train Accuracy: 67.29%
# Total Computation Time: 4619.57 seconds
# Total Communication Time: 1.24 seconds
# Epoch 145/150: Test Loss: 1.9775, Test Accuracy: 51.67%
#     Worker 0: Train Loss: 1.1452, Train Accuracy: 67.15%
#     Worker 1: Train Loss: 1.1343, Train Accuracy: 67.96%
#     Worker 2: Train Loss: 1.1290, Train Accuracy: 67.94%
#     Worker 3: Train Loss: 1.1396, Train Accuracy: 67.28%
# Total Computation Time: 4652.08 seconds
# Total Communication Time: 1.25 seconds
# Epoch 146/150: Test Loss: 1.9775, Test Accuracy: 51.65%
#     Worker 0: Train Loss: 1.1473, Train Accuracy: 67.28%
#     Worker 1: Train Loss: 1.1441, Train Accuracy: 67.47%
#     Worker 2: Train Loss: 1.1364, Train Accuracy: 67.96%
#     Worker 3: Train Loss: 1.1603, Train Accuracy: 67.19%
# Total Computation Time: 4683.28 seconds
# Total Communication Time: 1.26 seconds
# Epoch 147/150: Test Loss: 1.9774, Test Accuracy: 51.58%
#     Worker 0: Train Loss: 1.1473, Train Accuracy: 67.15%
#     Worker 1: Train Loss: 1.1189, Train Accuracy: 68.11%
#     Worker 2: Train Loss: 1.1310, Train Accuracy: 67.76%
#     Worker 3: Train Loss: 1.1428, Train Accuracy: 67.46%
# Total Computation Time: 4714.04 seconds
# Total Communication Time: 1.27 seconds
# Epoch 148/150: Test Loss: 1.9774, Test Accuracy: 51.58%
#     Worker 0: Train Loss: 1.1470, Train Accuracy: 66.96%
#     Worker 1: Train Loss: 1.1426, Train Accuracy: 67.16%
#     Worker 2: Train Loss: 1.1278, Train Accuracy: 67.93%
#     Worker 3: Train Loss: 1.1546, Train Accuracy: 67.38%
# Total Computation Time: 4745.88 seconds
# Total Communication Time: 1.28 seconds
# Epoch 149/150: Test Loss: 1.9774, Test Accuracy: 51.57%
#     Worker 0: Train Loss: 1.1343, Train Accuracy: 67.59%
#     Worker 1: Train Loss: 1.1275, Train Accuracy: 68.02%
#     Worker 2: Train Loss: 1.1313, Train Accuracy: 67.83%
#     Worker 3: Train Loss: 1.1478, Train Accuracy: 67.74%
# Total Computation Time: 4779.78 seconds
# Total Communication Time: 1.29 seconds
# Epoch 150/150: Test Loss: 1.9774, Test Accuracy: 51.57%
#     Worker 0: Train Loss: 1.1241, Train Accuracy: 67.72%
#     Worker 1: Train Loss: 1.1366, Train Accuracy: 67.49%
#     Worker 2: Train Loss: 1.1380, Train Accuracy: 67.53%
#     Worker 3: Train Loss: 1.1550, Train Accuracy: 67.22%
# Total Computation Time: 4812.32 seconds
# Total Communication Time: 1.29 seconds
