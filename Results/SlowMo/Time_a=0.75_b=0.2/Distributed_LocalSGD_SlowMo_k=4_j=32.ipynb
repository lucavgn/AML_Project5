# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files
import time

total_computation_time = 0
total_communication_time = 0

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
# Alpha slow learning rate a=1 best
# Beta slow momentum
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
#warmup_epochs = 5

alpha = 1.0  # Slow learning rate scaling factor
beta = 0  # Slow momentum factor

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate for each k: {learning_rate:.5f}")
#lr_warmup=learning_rate
# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]


with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs) for optimizer in optimizers]

u_buffer = [torch.zeros_like(param) for param in nets[0].parameters()]  # Momentum buffer

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")
    #if epoch < warmup_epochs: #lr for buffer update during warmup
            #w_factor = (epoch + 1) / warmup_epochs
            #lr_warmup = w_factor * learning_rate
    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch): #outer loop
        computation_start_time = time.time()
        #x(t,0)
        iter_params = [torch.zeros_like(param) for param in nets[0].parameters()]
        for param, g_param in zip(iter_params, nets[0].parameters()):
                    param.data.copy_(g_param)
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0

            # Perform J local step before synchronization
            for j in range(J): #inner loop
                      try:
                          # Get a batch from the current worker's shard using next()
                          images, labels = next(shard_iterators[k])
                          images, labels = images.to(device), labels.to(device)  # Move to device
                          optimizers[k].zero_grad()
                          outputs = nets[k](images)
                          loss = criterion(outputs, labels)
                          loss.backward()
                          optimizers[k].step()
                          # Calculate train loss and accuracy
                          train_loss += loss.item() * labels.size(0)
                          _, predicted = outputs.max(1)
                          total_train += labels.size(0)
                          correct_train += predicted.eq(labels).sum().item()

                      except StopIteration:
                          # If the iterator has exhausted the data, restart the iterator
                          shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                          images, labels = next(shard_iterators[k]) # Resume from the next batch
                          images, labels = images.to(device), labels.to(device)
                          # Perform optimization step
                          optimizers[k].zero_grad()
                          outputs = nets[k](images)
                          loss = criterion(outputs, labels)
                          loss.backward()
                          optimizers[k].step()
                          # Calculate train loss and accuracy
                          train_loss += loss.item() * labels.size(0)
                          _, predicted = outputs.max(1)
                          total_train += labels.size(0)
                          correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        computation_end_time = time.time()
        total_computation_time += (computation_end_time - computation_start_time)

        communication_start_time = time.time()
          # Synchronization (SLOWMO Algothm 1 - paper 21)
        with torch.no_grad():
            global_params = [torch.zeros_like(param) for param in nets[0].parameters()]
            #x(t, tau)
            for net in nets:
                for global_param, local_param in zip(global_params, net.parameters()):
                    global_param += local_param
            for global_param in global_params:
                global_param /= K

            for param, g_param, u_param in zip(iter_params, global_params, u_buffer):
                #if epoch < warmup_epochs:
                  #  u_param.mul_(beta).add_((param - g_param) / lr_warmup)
                 #   g_param.sub_(alpha * lr_warmup * u_param)

                #else: #Sync after warmup
                    #print(f"{optimizers[0].param_groups[0]['lr']}  {optimizers[1].param_groups[0]['lr']}")
                    lr_sched = optimizers[0].param_groups[0]['lr'] #optimizer lr
                    u_param.mul_(beta).add_((param - g_param) / lr_sched)
                    #g_param.sub_(alpha * lr_sched * u_param)
                    g_param.copy_(param - alpha * lr_sched * u_param)

            for net in nets:
                for param, g_param in zip(net.parameters(), global_params):
                    param.data.copy_(g_param)

        communication_end_time = time.time()
        total_communication_time += (communication_end_time - communication_start_time)

    # Update lr for each scheduler
    for scheduler in schedulers:
        #if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
        #else:
         #   warmup_factor = (epoch + 1) / warmup_epochs
          #  lr = warmup_factor * learning_rate
           # for optimizer in optimizers:
            #    for param_group in optimizer.param_groups:
             #       param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

    print(f"Total Computation Time: {total_computation_time:.2f} seconds")
    print(f"Total Communication Time: {total_communication_time:.2f} seconds")


# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 4 --j 32
# Out:
# Training with K=4, J=32
# Global iteration per epoch: 7
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate for each k: 0.00400
# Epoch 1/150: Test Loss: 4.5718, Test Accuracy: 2.86%
#     Worker 0: Train Loss: 4.5974, Train Accuracy: 1.53%
#     Worker 1: Train Loss: 4.5980, Train Accuracy: 1.39%
#     Worker 2: Train Loss: 4.5964, Train Accuracy: 1.57%
#     Worker 3: Train Loss: 4.5971, Train Accuracy: 1.59%
# Total Computation Time: 26.24 seconds
# Total Communication Time: 0.02 seconds
# Epoch 2/150: Test Loss: 4.1463, Test Accuracy: 6.79%
#     Worker 0: Train Loss: 4.4149, Train Accuracy: 3.80%
#     Worker 1: Train Loss: 4.4184, Train Accuracy: 3.91%
#     Worker 2: Train Loss: 4.4051, Train Accuracy: 3.68%
#     Worker 3: Train Loss: 4.4172, Train Accuracy: 3.60%
# Total Computation Time: 52.33 seconds
# Total Communication Time: 0.03 seconds
# Epoch 3/150: Test Loss: 3.9478, Test Accuracy: 9.54%
#     Worker 0: Train Loss: 4.1094, Train Accuracy: 7.05%
#     Worker 1: Train Loss: 4.1175, Train Accuracy: 6.68%
#     Worker 2: Train Loss: 4.0834, Train Accuracy: 7.15%
#     Worker 3: Train Loss: 4.1194, Train Accuracy: 6.89%
# Total Computation Time: 78.57 seconds
# Total Communication Time: 0.04 seconds
# Epoch 4/150: Test Loss: 3.7933, Test Accuracy: 12.65%
#     Worker 0: Train Loss: 3.9484, Train Accuracy: 9.37%
#     Worker 1: Train Loss: 3.9652, Train Accuracy: 9.07%
#     Worker 2: Train Loss: 3.9154, Train Accuracy: 9.68%
#     Worker 3: Train Loss: 3.9505, Train Accuracy: 9.26%
# Total Computation Time: 106.10 seconds
# Total Communication Time: 0.06 seconds
# Epoch 5/150: Test Loss: 3.6554, Test Accuracy: 15.03%
#     Worker 0: Train Loss: 3.8289, Train Accuracy: 11.05%
#     Worker 1: Train Loss: 3.8421, Train Accuracy: 10.86%
#     Worker 2: Train Loss: 3.7926, Train Accuracy: 11.82%
#     Worker 3: Train Loss: 3.8372, Train Accuracy: 11.27%
# Total Computation Time: 133.80 seconds
# Total Communication Time: 0.07 seconds
# Epoch 6/150: Test Loss: 3.5495, Test Accuracy: 16.65%
#     Worker 0: Train Loss: 3.7131, Train Accuracy: 12.73%
#     Worker 1: Train Loss: 3.7210, Train Accuracy: 12.97%
#     Worker 2: Train Loss: 3.6593, Train Accuracy: 13.99%
#     Worker 3: Train Loss: 3.7172, Train Accuracy: 13.14%
# Total Computation Time: 161.36 seconds
# Total Communication Time: 0.09 seconds
# Epoch 7/150: Test Loss: 3.4631, Test Accuracy: 18.20%
#     Worker 0: Train Loss: 3.6159, Train Accuracy: 14.43%
#     Worker 1: Train Loss: 3.6258, Train Accuracy: 14.51%
#     Worker 2: Train Loss: 3.5891, Train Accuracy: 14.94%
#     Worker 3: Train Loss: 3.6235, Train Accuracy: 14.55%
# Total Computation Time: 188.27 seconds
# Total Communication Time: 0.10 seconds
# Epoch 8/150: Test Loss: 3.3635, Test Accuracy: 19.30%
#     Worker 0: Train Loss: 3.5353, Train Accuracy: 15.99%
#     Worker 1: Train Loss: 3.5378, Train Accuracy: 16.24%
#     Worker 2: Train Loss: 3.4877, Train Accuracy: 16.97%
#     Worker 3: Train Loss: 3.5373, Train Accuracy: 16.30%
# Total Computation Time: 215.26 seconds
# Total Communication Time: 0.12 seconds
# Epoch 9/150: Test Loss: 3.2750, Test Accuracy: 21.71%
#     Worker 0: Train Loss: 3.4488, Train Accuracy: 17.09%
#     Worker 1: Train Loss: 3.4438, Train Accuracy: 17.98%
#     Worker 2: Train Loss: 3.4153, Train Accuracy: 18.18%
#     Worker 3: Train Loss: 3.4536, Train Accuracy: 17.12%
# Total Computation Time: 242.65 seconds
# Total Communication Time: 0.13 seconds
# Epoch 10/150: Test Loss: 3.1925, Test Accuracy: 23.18%
#     Worker 0: Train Loss: 3.3739, Train Accuracy: 18.60%
#     Worker 1: Train Loss: 3.3771, Train Accuracy: 18.94%
#     Worker 2: Train Loss: 3.3178, Train Accuracy: 19.83%
#     Worker 3: Train Loss: 3.3850, Train Accuracy: 18.40%
# Total Computation Time: 269.46 seconds
# Total Communication Time: 0.14 seconds
# Epoch 11/150: Test Loss: 3.1092, Test Accuracy: 24.55%
#     Worker 0: Train Loss: 3.2827, Train Accuracy: 19.99%
#     Worker 1: Train Loss: 3.3059, Train Accuracy: 20.50%
#     Worker 2: Train Loss: 3.2299, Train Accuracy: 21.40%
#     Worker 3: Train Loss: 3.3098, Train Accuracy: 20.02%
# Total Computation Time: 296.42 seconds
# Total Communication Time: 0.16 seconds
# Epoch 12/150: Test Loss: 3.0319, Test Accuracy: 26.11%
#     Worker 0: Train Loss: 3.2266, Train Accuracy: 21.47%
#     Worker 1: Train Loss: 3.2329, Train Accuracy: 21.10%
#     Worker 2: Train Loss: 3.1933, Train Accuracy: 21.89%
#     Worker 3: Train Loss: 3.2208, Train Accuracy: 21.45%
# Total Computation Time: 323.66 seconds
# Total Communication Time: 0.17 seconds
# Epoch 13/150: Test Loss: 2.9995, Test Accuracy: 26.47%
#     Worker 0: Train Loss: 3.1504, Train Accuracy: 22.45%
#     Worker 1: Train Loss: 3.1770, Train Accuracy: 22.24%
#     Worker 2: Train Loss: 3.1202, Train Accuracy: 23.31%
#     Worker 3: Train Loss: 3.1705, Train Accuracy: 22.24%
# Total Computation Time: 350.67 seconds
# Total Communication Time: 0.18 seconds
# Epoch 14/150: Test Loss: 2.9148, Test Accuracy: 28.26%
#     Worker 0: Train Loss: 3.1044, Train Accuracy: 23.10%
#     Worker 1: Train Loss: 3.1124, Train Accuracy: 23.45%
#     Worker 2: Train Loss: 3.0660, Train Accuracy: 24.12%
#     Worker 3: Train Loss: 3.1063, Train Accuracy: 23.06%
# Total Computation Time: 377.40 seconds
# Total Communication Time: 0.20 seconds
# Epoch 15/150: Test Loss: 2.8645, Test Accuracy: 28.93%
#     Worker 0: Train Loss: 3.0426, Train Accuracy: 24.80%
#     Worker 1: Train Loss: 3.0559, Train Accuracy: 24.81%
#     Worker 2: Train Loss: 3.0078, Train Accuracy: 25.29%
#     Worker 3: Train Loss: 3.0692, Train Accuracy: 24.20%
# Total Computation Time: 405.17 seconds
# Total Communication Time: 0.21 seconds
# Epoch 16/150: Test Loss: 2.8310, Test Accuracy: 29.57%
#     Worker 0: Train Loss: 2.9922, Train Accuracy: 25.51%
#     Worker 1: Train Loss: 3.0275, Train Accuracy: 24.90%
#     Worker 2: Train Loss: 2.9584, Train Accuracy: 26.66%
#     Worker 3: Train Loss: 2.9903, Train Accuracy: 25.17%
# Total Computation Time: 431.83 seconds
# Total Communication Time: 0.23 seconds
# Epoch 17/150: Test Loss: 2.7759, Test Accuracy: 30.65%
#     Worker 0: Train Loss: 2.9323, Train Accuracy: 26.93%
#     Worker 1: Train Loss: 2.9522, Train Accuracy: 26.57%
#     Worker 2: Train Loss: 2.9251, Train Accuracy: 27.04%
#     Worker 3: Train Loss: 2.9467, Train Accuracy: 26.60%
# Total Computation Time: 458.80 seconds
# Total Communication Time: 0.24 seconds
# Epoch 18/150: Test Loss: 2.7556, Test Accuracy: 31.35%
#     Worker 0: Train Loss: 2.8914, Train Accuracy: 27.31%
#     Worker 1: Train Loss: 2.9129, Train Accuracy: 27.26%
#     Worker 2: Train Loss: 2.8703, Train Accuracy: 28.16%
#     Worker 3: Train Loss: 2.9251, Train Accuracy: 26.57%
# Total Computation Time: 485.72 seconds
# Total Communication Time: 0.26 seconds
# Epoch 19/150: Test Loss: 2.6890, Test Accuracy: 32.86%
#     Worker 0: Train Loss: 2.8422, Train Accuracy: 28.71%
#     Worker 1: Train Loss: 2.8854, Train Accuracy: 27.74%
#     Worker 2: Train Loss: 2.8294, Train Accuracy: 29.18%
#     Worker 3: Train Loss: 2.8627, Train Accuracy: 28.67%
# Total Computation Time: 512.56 seconds
# Total Communication Time: 0.27 seconds
# Epoch 20/150: Test Loss: 2.6414, Test Accuracy: 33.22%
#     Worker 0: Train Loss: 2.8123, Train Accuracy: 29.04%
#     Worker 1: Train Loss: 2.8076, Train Accuracy: 29.24%
#     Worker 2: Train Loss: 2.7827, Train Accuracy: 30.11%
#     Worker 3: Train Loss: 2.8486, Train Accuracy: 28.06%
# Total Computation Time: 539.80 seconds
# Total Communication Time: 0.28 seconds
# Epoch 21/150: Test Loss: 2.6063, Test Accuracy: 33.75%
#     Worker 0: Train Loss: 2.7549, Train Accuracy: 30.14%
#     Worker 1: Train Loss: 2.7852, Train Accuracy: 29.72%
#     Worker 2: Train Loss: 2.7332, Train Accuracy: 30.88%
#     Worker 3: Train Loss: 2.7685, Train Accuracy: 29.58%
# Total Computation Time: 567.21 seconds
# Total Communication Time: 0.30 seconds
# Epoch 22/150: Test Loss: 2.5507, Test Accuracy: 34.92%
#     Worker 0: Train Loss: 2.7225, Train Accuracy: 31.07%
#     Worker 1: Train Loss: 2.7379, Train Accuracy: 30.70%
#     Worker 2: Train Loss: 2.6906, Train Accuracy: 31.38%
#     Worker 3: Train Loss: 2.7259, Train Accuracy: 30.71%
# Total Computation Time: 594.27 seconds
# Total Communication Time: 0.31 seconds
# Epoch 23/150: Test Loss: 2.5405, Test Accuracy: 35.18%
#     Worker 0: Train Loss: 2.6657, Train Accuracy: 32.03%
#     Worker 1: Train Loss: 2.6864, Train Accuracy: 31.44%
#     Worker 2: Train Loss: 2.6587, Train Accuracy: 32.56%
#     Worker 3: Train Loss: 2.6992, Train Accuracy: 31.68%
# Total Computation Time: 620.99 seconds
# Total Communication Time: 0.33 seconds
# Epoch 24/150: Test Loss: 2.4863, Test Accuracy: 36.08%
#     Worker 0: Train Loss: 2.6218, Train Accuracy: 33.19%
#     Worker 1: Train Loss: 2.6572, Train Accuracy: 32.59%
#     Worker 2: Train Loss: 2.6007, Train Accuracy: 33.83%
#     Worker 3: Train Loss: 2.6395, Train Accuracy: 32.59%
# Total Computation Time: 647.98 seconds
# Total Communication Time: 0.34 seconds
# Epoch 25/150: Test Loss: 2.4621, Test Accuracy: 36.64%
#     Worker 0: Train Loss: 2.5940, Train Accuracy: 33.21%
#     Worker 1: Train Loss: 2.6161, Train Accuracy: 33.27%
#     Worker 2: Train Loss: 2.5854, Train Accuracy: 33.52%
#     Worker 3: Train Loss: 2.5950, Train Accuracy: 33.03%
# Total Computation Time: 675.45 seconds
# Total Communication Time: 0.35 seconds
# Epoch 26/150: Test Loss: 2.4193, Test Accuracy: 37.53%
#     Worker 0: Train Loss: 2.5526, Train Accuracy: 34.59%
#     Worker 1: Train Loss: 2.5856, Train Accuracy: 33.13%
#     Worker 2: Train Loss: 2.5328, Train Accuracy: 34.86%
#     Worker 3: Train Loss: 2.5871, Train Accuracy: 33.39%
# Total Computation Time: 703.55 seconds
# Total Communication Time: 0.37 seconds
# Epoch 27/150: Test Loss: 2.4082, Test Accuracy: 37.88%
#     Worker 0: Train Loss: 2.5379, Train Accuracy: 34.54%
#     Worker 1: Train Loss: 2.5342, Train Accuracy: 35.12%
#     Worker 2: Train Loss: 2.5225, Train Accuracy: 35.45%
#     Worker 3: Train Loss: 2.5544, Train Accuracy: 34.40%
# Total Computation Time: 730.28 seconds
# Total Communication Time: 0.38 seconds
# Epoch 28/150: Test Loss: 2.3766, Test Accuracy: 38.49%
#     Worker 0: Train Loss: 2.4976, Train Accuracy: 35.33%
#     Worker 1: Train Loss: 2.5151, Train Accuracy: 35.11%
#     Worker 2: Train Loss: 2.4802, Train Accuracy: 35.70%
#     Worker 3: Train Loss: 2.4981, Train Accuracy: 35.12%
# Total Computation Time: 757.22 seconds
# Total Communication Time: 0.39 seconds
# Epoch 29/150: Test Loss: 2.3599, Test Accuracy: 38.89%
#     Worker 0: Train Loss: 2.4655, Train Accuracy: 36.06%
#     Worker 1: Train Loss: 2.4786, Train Accuracy: 36.13%
#     Worker 2: Train Loss: 2.4551, Train Accuracy: 36.63%
#     Worker 3: Train Loss: 2.4764, Train Accuracy: 35.74%
# Total Computation Time: 784.07 seconds
# Total Communication Time: 0.41 seconds
# Epoch 30/150: Test Loss: 2.3236, Test Accuracy: 39.67%
#     Worker 0: Train Loss: 2.4487, Train Accuracy: 36.08%
#     Worker 1: Train Loss: 2.4177, Train Accuracy: 37.28%
#     Worker 2: Train Loss: 2.4189, Train Accuracy: 37.10%
#     Worker 3: Train Loss: 2.4548, Train Accuracy: 36.95%
# Total Computation Time: 811.14 seconds
# Total Communication Time: 0.43 seconds
# Epoch 31/150: Test Loss: 2.2929, Test Accuracy: 40.39%
#     Worker 0: Train Loss: 2.4097, Train Accuracy: 36.55%
#     Worker 1: Train Loss: 2.4170, Train Accuracy: 37.29%
#     Worker 2: Train Loss: 2.3828, Train Accuracy: 38.11%
#     Worker 3: Train Loss: 2.4173, Train Accuracy: 37.33%
# Total Computation Time: 838.09 seconds
# Total Communication Time: 0.44 seconds
# Epoch 32/150: Test Loss: 2.2910, Test Accuracy: 40.89%
#     Worker 0: Train Loss: 2.3861, Train Accuracy: 37.36%
#     Worker 1: Train Loss: 2.3817, Train Accuracy: 38.12%
#     Worker 2: Train Loss: 2.3528, Train Accuracy: 39.06%
#     Worker 3: Train Loss: 2.3859, Train Accuracy: 37.78%
# Total Computation Time: 865.93 seconds
# Total Communication Time: 0.46 seconds
# Epoch 33/150: Test Loss: 2.2684, Test Accuracy: 41.25%
#     Worker 0: Train Loss: 2.3418, Train Accuracy: 38.74%
#     Worker 1: Train Loss: 2.3593, Train Accuracy: 38.60%
#     Worker 2: Train Loss: 2.3409, Train Accuracy: 38.86%
#     Worker 3: Train Loss: 2.3699, Train Accuracy: 38.04%
# Total Computation Time: 893.38 seconds
# Total Communication Time: 0.47 seconds
# Epoch 34/150: Test Loss: 2.2595, Test Accuracy: 41.17%
#     Worker 0: Train Loss: 2.3359, Train Accuracy: 38.76%
#     Worker 1: Train Loss: 2.3608, Train Accuracy: 38.40%
#     Worker 2: Train Loss: 2.3171, Train Accuracy: 39.02%
#     Worker 3: Train Loss: 2.3368, Train Accuracy: 38.98%
# Total Computation Time: 920.26 seconds
# Total Communication Time: 0.48 seconds
# Epoch 35/150: Test Loss: 2.2382, Test Accuracy: 41.63%
#     Worker 0: Train Loss: 2.2895, Train Accuracy: 39.83%
#     Worker 1: Train Loss: 2.3121, Train Accuracy: 39.51%
#     Worker 2: Train Loss: 2.2822, Train Accuracy: 40.44%
#     Worker 3: Train Loss: 2.3215, Train Accuracy: 39.13%
# Total Computation Time: 947.01 seconds
# Total Communication Time: 0.50 seconds
# Epoch 36/150: Test Loss: 2.2207, Test Accuracy: 42.37%
#     Worker 0: Train Loss: 2.2819, Train Accuracy: 39.74%
#     Worker 1: Train Loss: 2.2796, Train Accuracy: 40.10%
#     Worker 2: Train Loss: 2.2744, Train Accuracy: 40.46%
#     Worker 3: Train Loss: 2.2856, Train Accuracy: 39.55%
# Total Computation Time: 974.28 seconds
# Total Communication Time: 0.51 seconds
# Epoch 37/150: Test Loss: 2.1939, Test Accuracy: 42.75%
#     Worker 0: Train Loss: 2.2552, Train Accuracy: 40.21%
#     Worker 1: Train Loss: 2.2449, Train Accuracy: 41.26%
#     Worker 2: Train Loss: 2.2380, Train Accuracy: 40.98%
#     Worker 3: Train Loss: 2.2514, Train Accuracy: 40.37%
# Total Computation Time: 1002.05 seconds
# Total Communication Time: 0.53 seconds
# Epoch 38/150: Test Loss: 2.1841, Test Accuracy: 43.14%
#     Worker 0: Train Loss: 2.2086, Train Accuracy: 41.46%
#     Worker 1: Train Loss: 2.2312, Train Accuracy: 41.32%
#     Worker 2: Train Loss: 2.2135, Train Accuracy: 41.83%
#     Worker 3: Train Loss: 2.2541, Train Accuracy: 40.54%
# Total Computation Time: 1029.13 seconds
# Total Communication Time: 0.54 seconds
# Epoch 39/150: Test Loss: 2.1834, Test Accuracy: 43.48%
#     Worker 0: Train Loss: 2.2011, Train Accuracy: 41.83%
#     Worker 1: Train Loss: 2.2186, Train Accuracy: 41.91%
#     Worker 2: Train Loss: 2.1830, Train Accuracy: 42.63%
#     Worker 3: Train Loss: 2.2297, Train Accuracy: 41.35%
# Total Computation Time: 1056.09 seconds
# Total Communication Time: 0.56 seconds
# Epoch 40/150: Test Loss: 2.1814, Test Accuracy: 43.37%
#     Worker 0: Train Loss: 2.2004, Train Accuracy: 41.71%
#     Worker 1: Train Loss: 2.2052, Train Accuracy: 42.32%
#     Worker 2: Train Loss: 2.1810, Train Accuracy: 42.50%
#     Worker 3: Train Loss: 2.1944, Train Accuracy: 41.56%
# Total Computation Time: 1083.04 seconds
# Total Communication Time: 0.57 seconds
# Epoch 41/150: Test Loss: 2.1754, Test Accuracy: 43.49%
#     Worker 0: Train Loss: 2.1645, Train Accuracy: 43.15%
#     Worker 1: Train Loss: 2.1739, Train Accuracy: 42.37%
#     Worker 2: Train Loss: 2.1343, Train Accuracy: 43.39%
#     Worker 3: Train Loss: 2.1655, Train Accuracy: 42.65%
# Total Computation Time: 1110.51 seconds
# Total Communication Time: 0.59 seconds
# Epoch 42/150: Test Loss: 2.1258, Test Accuracy: 44.29%
#     Worker 0: Train Loss: 2.1456, Train Accuracy: 43.04%
#     Worker 1: Train Loss: 2.1707, Train Accuracy: 42.60%
#     Worker 2: Train Loss: 2.1332, Train Accuracy: 43.50%
#     Worker 3: Train Loss: 2.1583, Train Accuracy: 42.89%
# Total Computation Time: 1137.54 seconds
# Total Communication Time: 0.60 seconds
# Epoch 43/150: Test Loss: 2.1348, Test Accuracy: 44.13%
#     Worker 0: Train Loss: 2.1135, Train Accuracy: 43.23%
#     Worker 1: Train Loss: 2.1279, Train Accuracy: 43.56%
#     Worker 2: Train Loss: 2.1110, Train Accuracy: 43.94%
#     Worker 3: Train Loss: 2.1409, Train Accuracy: 43.20%
# Total Computation Time: 1165.30 seconds
# Total Communication Time: 0.62 seconds
# Epoch 44/150: Test Loss: 2.1469, Test Accuracy: 43.58%
#     Worker 0: Train Loss: 2.1048, Train Accuracy: 43.93%
#     Worker 1: Train Loss: 2.1271, Train Accuracy: 43.90%
#     Worker 2: Train Loss: 2.1064, Train Accuracy: 44.22%
#     Worker 3: Train Loss: 2.1103, Train Accuracy: 44.20%
# Total Computation Time: 1192.47 seconds
# Total Communication Time: 0.63 seconds
# Epoch 45/150: Test Loss: 2.1150, Test Accuracy: 44.74%
#     Worker 0: Train Loss: 2.0885, Train Accuracy: 44.42%
#     Worker 1: Train Loss: 2.0892, Train Accuracy: 44.28%
#     Worker 2: Train Loss: 2.0812, Train Accuracy: 44.86%
#     Worker 3: Train Loss: 2.0822, Train Accuracy: 44.49%
# Total Computation Time: 1219.09 seconds
# Total Communication Time: 0.65 seconds
# Epoch 46/150: Test Loss: 2.1171, Test Accuracy: 44.51%
#     Worker 0: Train Loss: 2.0582, Train Accuracy: 44.28%
#     Worker 1: Train Loss: 2.0702, Train Accuracy: 44.72%
#     Worker 2: Train Loss: 2.0463, Train Accuracy: 45.13%
#     Worker 3: Train Loss: 2.0855, Train Accuracy: 44.40%
# Total Computation Time: 1245.91 seconds
# Total Communication Time: 0.66 seconds
# Epoch 47/150: Test Loss: 2.0862, Test Accuracy: 45.20%
#     Worker 0: Train Loss: 2.0379, Train Accuracy: 45.12%
#     Worker 1: Train Loss: 2.0508, Train Accuracy: 45.45%
#     Worker 2: Train Loss: 2.0307, Train Accuracy: 45.47%
#     Worker 3: Train Loss: 2.0686, Train Accuracy: 44.37%
# Total Computation Time: 1272.62 seconds
# Total Communication Time: 0.67 seconds
# Epoch 48/150: Test Loss: 2.0807, Test Accuracy: 45.73%
#     Worker 0: Train Loss: 2.0317, Train Accuracy: 45.02%
#     Worker 1: Train Loss: 2.0426, Train Accuracy: 45.53%
#     Worker 2: Train Loss: 2.0062, Train Accuracy: 46.41%
#     Worker 3: Train Loss: 2.0438, Train Accuracy: 45.47%
# Total Computation Time: 1299.97 seconds
# Total Communication Time: 0.69 seconds
# Epoch 49/150: Test Loss: 2.0592, Test Accuracy: 46.32%
#     Worker 0: Train Loss: 2.0196, Train Accuracy: 45.77%
#     Worker 1: Train Loss: 2.0190, Train Accuracy: 46.41%
#     Worker 2: Train Loss: 2.0213, Train Accuracy: 46.05%
#     Worker 3: Train Loss: 2.0094, Train Accuracy: 46.24%
# Total Computation Time: 1326.94 seconds
# Total Communication Time: 0.70 seconds
# Epoch 50/150: Test Loss: 2.0495, Test Accuracy: 46.19%
#     Worker 0: Train Loss: 1.9849, Train Accuracy: 46.54%
#     Worker 1: Train Loss: 1.9803, Train Accuracy: 46.84%
#     Worker 2: Train Loss: 1.9607, Train Accuracy: 47.71%
#     Worker 3: Train Loss: 2.0147, Train Accuracy: 45.78%
# Total Computation Time: 1353.56 seconds
# Total Communication Time: 0.71 seconds
# Epoch 51/150: Test Loss: 2.0600, Test Accuracy: 45.89%
#     Worker 0: Train Loss: 1.9787, Train Accuracy: 46.88%
#     Worker 1: Train Loss: 1.9968, Train Accuracy: 46.48%
#     Worker 2: Train Loss: 1.9535, Train Accuracy: 47.29%
#     Worker 3: Train Loss: 1.9744, Train Accuracy: 47.33%
# Total Computation Time: 1380.00 seconds
# Total Communication Time: 0.73 seconds
# Epoch 52/150: Test Loss: 2.0384, Test Accuracy: 46.81%
#     Worker 0: Train Loss: 1.9631, Train Accuracy: 47.12%
#     Worker 1: Train Loss: 1.9491, Train Accuracy: 47.55%
#     Worker 2: Train Loss: 1.9560, Train Accuracy: 47.64%
#     Worker 3: Train Loss: 1.9709, Train Accuracy: 46.88%
# Total Computation Time: 1407.13 seconds
# Total Communication Time: 0.74 seconds
# Epoch 53/150: Test Loss: 2.0371, Test Accuracy: 46.64%
#     Worker 0: Train Loss: 1.9444, Train Accuracy: 47.58%
#     Worker 1: Train Loss: 1.9779, Train Accuracy: 47.12%
#     Worker 2: Train Loss: 1.9352, Train Accuracy: 47.86%
#     Worker 3: Train Loss: 1.9513, Train Accuracy: 47.69%
# Total Computation Time: 1434.14 seconds
# Total Communication Time: 0.76 seconds
# Epoch 54/150: Test Loss: 2.0295, Test Accuracy: 47.00%
#     Worker 0: Train Loss: 1.9363, Train Accuracy: 47.45%
#     Worker 1: Train Loss: 1.9209, Train Accuracy: 48.45%
#     Worker 2: Train Loss: 1.9072, Train Accuracy: 48.61%
#     Worker 3: Train Loss: 1.9442, Train Accuracy: 47.16%
# Total Computation Time: 1461.69 seconds
# Total Communication Time: 0.77 seconds
# Epoch 55/150: Test Loss: 2.0169, Test Accuracy: 47.11%
#     Worker 0: Train Loss: 1.9177, Train Accuracy: 47.66%
#     Worker 1: Train Loss: 1.9282, Train Accuracy: 48.04%
#     Worker 2: Train Loss: 1.9205, Train Accuracy: 48.56%
#     Worker 3: Train Loss: 1.9565, Train Accuracy: 47.35%
# Total Computation Time: 1488.25 seconds
# Total Communication Time: 0.79 seconds
# Epoch 56/150: Test Loss: 2.0381, Test Accuracy: 46.83%
#     Worker 0: Train Loss: 1.8904, Train Accuracy: 48.43%
#     Worker 1: Train Loss: 1.9051, Train Accuracy: 48.41%
#     Worker 2: Train Loss: 1.8770, Train Accuracy: 49.65%
#     Worker 3: Train Loss: 1.9092, Train Accuracy: 48.45%
# Total Computation Time: 1515.11 seconds
# Total Communication Time: 0.80 seconds
# Epoch 57/150: Test Loss: 2.0294, Test Accuracy: 46.99%
#     Worker 0: Train Loss: 1.8939, Train Accuracy: 48.59%
#     Worker 1: Train Loss: 1.8907, Train Accuracy: 49.29%
#     Worker 2: Train Loss: 1.8617, Train Accuracy: 49.59%
#     Worker 3: Train Loss: 1.8825, Train Accuracy: 48.89%
# Total Computation Time: 1542.20 seconds
# Total Communication Time: 0.81 seconds
# Epoch 58/150: Test Loss: 2.0047, Test Accuracy: 47.79%
#     Worker 0: Train Loss: 1.8741, Train Accuracy: 48.91%
#     Worker 1: Train Loss: 1.8657, Train Accuracy: 49.66%
#     Worker 2: Train Loss: 1.8369, Train Accuracy: 50.15%
#     Worker 3: Train Loss: 1.8658, Train Accuracy: 49.68%
# Total Computation Time: 1568.73 seconds
# Total Communication Time: 0.83 seconds
# Epoch 59/150: Test Loss: 2.0147, Test Accuracy: 47.50%
#     Worker 0: Train Loss: 1.8500, Train Accuracy: 49.59%
#     Worker 1: Train Loss: 1.8526, Train Accuracy: 49.31%
#     Worker 2: Train Loss: 1.8506, Train Accuracy: 49.87%
#     Worker 3: Train Loss: 1.8535, Train Accuracy: 49.84%
# Total Computation Time: 1596.06 seconds
# Total Communication Time: 0.84 seconds
# Epoch 60/150: Test Loss: 1.9974, Test Accuracy: 48.06%
#     Worker 0: Train Loss: 1.8343, Train Accuracy: 49.69%
#     Worker 1: Train Loss: 1.8462, Train Accuracy: 50.31%
#     Worker 2: Train Loss: 1.8315, Train Accuracy: 50.12%
#     Worker 3: Train Loss: 1.8413, Train Accuracy: 49.98%
# Total Computation Time: 1622.63 seconds
# Total Communication Time: 0.86 seconds
# Epoch 61/150: Test Loss: 1.9946, Test Accuracy: 47.96%
#     Worker 0: Train Loss: 1.8243, Train Accuracy: 50.35%
#     Worker 1: Train Loss: 1.8141, Train Accuracy: 50.40%
#     Worker 2: Train Loss: 1.7961, Train Accuracy: 50.99%
#     Worker 3: Train Loss: 1.8096, Train Accuracy: 50.55%
# Total Computation Time: 1649.35 seconds
# Total Communication Time: 0.87 seconds
# Epoch 62/150: Test Loss: 1.9970, Test Accuracy: 47.98%
#     Worker 0: Train Loss: 1.8293, Train Accuracy: 50.25%
#     Worker 1: Train Loss: 1.8017, Train Accuracy: 50.69%
#     Worker 2: Train Loss: 1.7869, Train Accuracy: 51.20%
#     Worker 3: Train Loss: 1.8309, Train Accuracy: 50.08%
# Total Computation Time: 1676.37 seconds
# Total Communication Time: 0.88 seconds
# Epoch 63/150: Test Loss: 1.9946, Test Accuracy: 47.99%
#     Worker 0: Train Loss: 1.7954, Train Accuracy: 51.26%
#     Worker 1: Train Loss: 1.8011, Train Accuracy: 50.89%
#     Worker 2: Train Loss: 1.7876, Train Accuracy: 51.68%
#     Worker 3: Train Loss: 1.8131, Train Accuracy: 50.51%
# Total Computation Time: 1703.13 seconds
# Total Communication Time: 0.90 seconds
# Epoch 64/150: Test Loss: 1.9921, Test Accuracy: 48.37%
#     Worker 0: Train Loss: 1.7793, Train Accuracy: 51.57%
#     Worker 1: Train Loss: 1.7766, Train Accuracy: 51.87%
#     Worker 2: Train Loss: 1.7615, Train Accuracy: 51.92%
#     Worker 3: Train Loss: 1.7751, Train Accuracy: 51.67%
# Total Computation Time: 1730.91 seconds
# Total Communication Time: 0.91 seconds
# Epoch 65/150: Test Loss: 1.9906, Test Accuracy: 48.37%
#     Worker 0: Train Loss: 1.7598, Train Accuracy: 51.59%
#     Worker 1: Train Loss: 1.7687, Train Accuracy: 51.63%
#     Worker 2: Train Loss: 1.7565, Train Accuracy: 51.95%
#     Worker 3: Train Loss: 1.7889, Train Accuracy: 50.79%
# Total Computation Time: 1757.99 seconds
# Total Communication Time: 0.93 seconds
# Epoch 66/150: Test Loss: 1.9836, Test Accuracy: 48.55%
#     Worker 0: Train Loss: 1.7628, Train Accuracy: 51.06%
#     Worker 1: Train Loss: 1.7630, Train Accuracy: 52.02%
#     Worker 2: Train Loss: 1.7309, Train Accuracy: 52.48%
#     Worker 3: Train Loss: 1.7651, Train Accuracy: 51.47%
# Total Computation Time: 1784.87 seconds
# Total Communication Time: 0.94 seconds
# Epoch 67/150: Test Loss: 1.9734, Test Accuracy: 48.87%
#     Worker 0: Train Loss: 1.7402, Train Accuracy: 51.89%
#     Worker 1: Train Loss: 1.7425, Train Accuracy: 52.24%
#     Worker 2: Train Loss: 1.7333, Train Accuracy: 52.53%
#     Worker 3: Train Loss: 1.7521, Train Accuracy: 52.55%
# Total Computation Time: 1812.10 seconds
# Total Communication Time: 0.95 seconds
# Epoch 68/150: Test Loss: 1.9806, Test Accuracy: 48.89%
#     Worker 0: Train Loss: 1.7269, Train Accuracy: 52.33%
#     Worker 1: Train Loss: 1.7287, Train Accuracy: 52.61%
#     Worker 2: Train Loss: 1.7110, Train Accuracy: 52.90%
#     Worker 3: Train Loss: 1.7365, Train Accuracy: 52.61%
# Total Computation Time: 1839.88 seconds
# Total Communication Time: 0.97 seconds
# Epoch 69/150: Test Loss: 1.9690, Test Accuracy: 48.86%
#     Worker 0: Train Loss: 1.7043, Train Accuracy: 52.97%
#     Worker 1: Train Loss: 1.7227, Train Accuracy: 52.81%
#     Worker 2: Train Loss: 1.7095, Train Accuracy: 53.34%
#     Worker 3: Train Loss: 1.7231, Train Accuracy: 52.25%
# Total Computation Time: 1867.21 seconds
# Total Communication Time: 0.98 seconds
# Epoch 70/150: Test Loss: 1.9690, Test Accuracy: 48.97%
#     Worker 0: Train Loss: 1.7023, Train Accuracy: 52.86%
#     Worker 1: Train Loss: 1.7118, Train Accuracy: 53.23%
#     Worker 2: Train Loss: 1.6994, Train Accuracy: 53.35%
#     Worker 3: Train Loss: 1.7199, Train Accuracy: 53.21%
# Total Computation Time: 1894.82 seconds
# Total Communication Time: 1.00 seconds
# Epoch 71/150: Test Loss: 1.9594, Test Accuracy: 49.23%
#     Worker 0: Train Loss: 1.6998, Train Accuracy: 53.07%
#     Worker 1: Train Loss: 1.6916, Train Accuracy: 53.79%
#     Worker 2: Train Loss: 1.6772, Train Accuracy: 54.16%
#     Worker 3: Train Loss: 1.6917, Train Accuracy: 53.43%
# Total Computation Time: 1921.80 seconds
# Total Communication Time: 1.01 seconds
# Epoch 72/150: Test Loss: 1.9591, Test Accuracy: 49.30%
#     Worker 0: Train Loss: 1.6673, Train Accuracy: 54.07%
#     Worker 1: Train Loss: 1.6810, Train Accuracy: 53.87%
#     Worker 2: Train Loss: 1.6786, Train Accuracy: 53.82%
#     Worker 3: Train Loss: 1.6909, Train Accuracy: 53.41%
# Total Computation Time: 1949.35 seconds
# Total Communication Time: 1.03 seconds
# Epoch 73/150: Test Loss: 1.9662, Test Accuracy: 49.11%
#     Worker 0: Train Loss: 1.6479, Train Accuracy: 54.13%
#     Worker 1: Train Loss: 1.6714, Train Accuracy: 54.28%
#     Worker 2: Train Loss: 1.6318, Train Accuracy: 54.60%
#     Worker 3: Train Loss: 1.6745, Train Accuracy: 54.18%
# Total Computation Time: 1976.02 seconds
# Total Communication Time: 1.04 seconds
# Epoch 74/150: Test Loss: 1.9588, Test Accuracy: 49.32%
#     Worker 0: Train Loss: 1.6619, Train Accuracy: 53.85%
#     Worker 1: Train Loss: 1.6625, Train Accuracy: 54.27%
#     Worker 2: Train Loss: 1.6463, Train Accuracy: 54.86%
#     Worker 3: Train Loss: 1.6665, Train Accuracy: 53.82%
# Total Computation Time: 2002.76 seconds
# Total Communication Time: 1.05 seconds
# Epoch 75/150: Test Loss: 1.9478, Test Accuracy: 49.54%
#     Worker 0: Train Loss: 1.6391, Train Accuracy: 54.45%
#     Worker 1: Train Loss: 1.6473, Train Accuracy: 54.73%
#     Worker 2: Train Loss: 1.6231, Train Accuracy: 54.62%
#     Worker 3: Train Loss: 1.6447, Train Accuracy: 54.61%
# Total Computation Time: 2030.27 seconds
# Total Communication Time: 1.07 seconds
# Epoch 76/150: Test Loss: 1.9407, Test Accuracy: 49.88%
#     Worker 0: Train Loss: 1.6384, Train Accuracy: 54.70%
#     Worker 1: Train Loss: 1.6384, Train Accuracy: 54.81%
#     Worker 2: Train Loss: 1.6165, Train Accuracy: 55.07%
#     Worker 3: Train Loss: 1.6295, Train Accuracy: 54.62%
# Total Computation Time: 2056.86 seconds
# Total Communication Time: 1.08 seconds
# Epoch 77/150: Test Loss: 1.9549, Test Accuracy: 49.19%
#     Worker 0: Train Loss: 1.6087, Train Accuracy: 55.36%
#     Worker 1: Train Loss: 1.6155, Train Accuracy: 55.69%
#     Worker 2: Train Loss: 1.6073, Train Accuracy: 55.36%
#     Worker 3: Train Loss: 1.6320, Train Accuracy: 55.13%
# Total Computation Time: 2083.93 seconds
# Total Communication Time: 1.10 seconds
# Epoch 78/150: Test Loss: 1.9500, Test Accuracy: 49.83%
#     Worker 0: Train Loss: 1.5868, Train Accuracy: 55.91%
#     Worker 1: Train Loss: 1.6065, Train Accuracy: 55.79%
#     Worker 2: Train Loss: 1.5906, Train Accuracy: 56.56%
#     Worker 3: Train Loss: 1.5966, Train Accuracy: 55.60%
# Total Computation Time: 2110.75 seconds
# Total Communication Time: 1.11 seconds
# Epoch 79/150: Test Loss: 1.9469, Test Accuracy: 49.90%
#     Worker 0: Train Loss: 1.5643, Train Accuracy: 55.91%
#     Worker 1: Train Loss: 1.6000, Train Accuracy: 56.15%
#     Worker 2: Train Loss: 1.5882, Train Accuracy: 55.69%
#     Worker 3: Train Loss: 1.5978, Train Accuracy: 55.98%
# Total Computation Time: 2137.69 seconds
# Total Communication Time: 1.12 seconds
# Epoch 80/150: Test Loss: 1.9465, Test Accuracy: 50.16%
#     Worker 0: Train Loss: 1.5983, Train Accuracy: 55.63%
#     Worker 1: Train Loss: 1.5834, Train Accuracy: 56.21%
#     Worker 2: Train Loss: 1.5760, Train Accuracy: 55.93%
#     Worker 3: Train Loss: 1.5865, Train Accuracy: 56.29%
# Total Computation Time: 2165.41 seconds
# Total Communication Time: 1.14 seconds
# Epoch 81/150: Test Loss: 1.9475, Test Accuracy: 50.10%
#     Worker 0: Train Loss: 1.5688, Train Accuracy: 55.97%
#     Worker 1: Train Loss: 1.5783, Train Accuracy: 56.45%
#     Worker 2: Train Loss: 1.5679, Train Accuracy: 56.38%
#     Worker 3: Train Loss: 1.5776, Train Accuracy: 56.10%
# Total Computation Time: 2192.06 seconds
# Total Communication Time: 1.16 seconds
# Epoch 82/150: Test Loss: 1.9436, Test Accuracy: 49.98%
#     Worker 0: Train Loss: 1.5582, Train Accuracy: 56.39%
#     Worker 1: Train Loss: 1.5483, Train Accuracy: 57.02%
#     Worker 2: Train Loss: 1.5410, Train Accuracy: 57.30%
#     Worker 3: Train Loss: 1.5980, Train Accuracy: 55.56%
# Total Computation Time: 2218.94 seconds
# Total Communication Time: 1.17 seconds
# Epoch 83/150: Test Loss: 1.9409, Test Accuracy: 50.27%
#     Worker 0: Train Loss: 1.5535, Train Accuracy: 56.58%
#     Worker 1: Train Loss: 1.5517, Train Accuracy: 57.43%
#     Worker 2: Train Loss: 1.5371, Train Accuracy: 57.06%
#     Worker 3: Train Loss: 1.5439, Train Accuracy: 56.77%
# Total Computation Time: 2245.76 seconds
# Total Communication Time: 1.18 seconds
# Epoch 84/150: Test Loss: 1.9455, Test Accuracy: 49.85%
#     Worker 0: Train Loss: 1.5264, Train Accuracy: 57.48%
#     Worker 1: Train Loss: 1.5323, Train Accuracy: 57.52%
#     Worker 2: Train Loss: 1.5309, Train Accuracy: 57.43%
#     Worker 3: Train Loss: 1.5432, Train Accuracy: 56.86%
# Total Computation Time: 2272.56 seconds
# Total Communication Time: 1.20 seconds
# Epoch 85/150: Test Loss: 1.9423, Test Accuracy: 50.21%
#     Worker 0: Train Loss: 1.5140, Train Accuracy: 57.65%
#     Worker 1: Train Loss: 1.5218, Train Accuracy: 57.45%
#     Worker 2: Train Loss: 1.5147, Train Accuracy: 58.14%
#     Worker 3: Train Loss: 1.5258, Train Accuracy: 57.99%
# Total Computation Time: 2299.86 seconds
# Total Communication Time: 1.21 seconds
# Epoch 86/150: Test Loss: 1.9467, Test Accuracy: 50.32%
#     Worker 0: Train Loss: 1.5233, Train Accuracy: 57.40%
#     Worker 1: Train Loss: 1.5043, Train Accuracy: 57.95%
#     Worker 2: Train Loss: 1.5022, Train Accuracy: 58.28%
#     Worker 3: Train Loss: 1.5304, Train Accuracy: 57.70%
# Total Computation Time: 2327.76 seconds
# Total Communication Time: 1.23 seconds
# Epoch 87/150: Test Loss: 1.9415, Test Accuracy: 50.43%
#     Worker 0: Train Loss: 1.5232, Train Accuracy: 57.17%
#     Worker 1: Train Loss: 1.5175, Train Accuracy: 57.93%
#     Worker 2: Train Loss: 1.4948, Train Accuracy: 58.54%
#     Worker 3: Train Loss: 1.5136, Train Accuracy: 58.05%
# Total Computation Time: 2355.02 seconds
# Total Communication Time: 1.24 seconds
# Epoch 88/150: Test Loss: 1.9432, Test Accuracy: 50.27%
#     Worker 0: Train Loss: 1.4901, Train Accuracy: 58.35%
#     Worker 1: Train Loss: 1.4975, Train Accuracy: 58.47%
#     Worker 2: Train Loss: 1.4854, Train Accuracy: 58.90%
#     Worker 3: Train Loss: 1.5065, Train Accuracy: 57.84%
# Total Computation Time: 2382.12 seconds
# Total Communication Time: 1.26 seconds
# Epoch 89/150: Test Loss: 1.9396, Test Accuracy: 50.40%
#     Worker 0: Train Loss: 1.4858, Train Accuracy: 58.12%
#     Worker 1: Train Loss: 1.4914, Train Accuracy: 58.70%
#     Worker 2: Train Loss: 1.4536, Train Accuracy: 59.43%
#     Worker 3: Train Loss: 1.4893, Train Accuracy: 58.93%
# Total Computation Time: 2409.46 seconds
# Total Communication Time: 1.27 seconds
# Epoch 90/150: Test Loss: 1.9403, Test Accuracy: 50.85%
#     Worker 0: Train Loss: 1.4922, Train Accuracy: 58.15%
#     Worker 1: Train Loss: 1.4835, Train Accuracy: 58.45%
#     Worker 2: Train Loss: 1.4792, Train Accuracy: 58.74%
#     Worker 3: Train Loss: 1.4904, Train Accuracy: 58.06%
# Total Computation Time: 2437.11 seconds
# Total Communication Time: 1.28 seconds
# Epoch 91/150: Test Loss: 1.9432, Test Accuracy: 50.23%
#     Worker 0: Train Loss: 1.4564, Train Accuracy: 59.34%
#     Worker 1: Train Loss: 1.4746, Train Accuracy: 58.67%
#     Worker 2: Train Loss: 1.4568, Train Accuracy: 59.20%
#     Worker 3: Train Loss: 1.4895, Train Accuracy: 58.46%
# Total Computation Time: 2464.59 seconds
# Total Communication Time: 1.30 seconds
# Epoch 92/150: Test Loss: 1.9399, Test Accuracy: 50.66%
#     Worker 0: Train Loss: 1.4578, Train Accuracy: 58.79%
#     Worker 1: Train Loss: 1.4744, Train Accuracy: 59.12%
#     Worker 2: Train Loss: 1.4612, Train Accuracy: 59.05%
#     Worker 3: Train Loss: 1.4608, Train Accuracy: 58.98%
# Total Computation Time: 2491.40 seconds
# Total Communication Time: 1.31 seconds
# Epoch 93/150: Test Loss: 1.9444, Test Accuracy: 50.68%
#     Worker 0: Train Loss: 1.4295, Train Accuracy: 59.57%
#     Worker 1: Train Loss: 1.4265, Train Accuracy: 59.82%
#     Worker 2: Train Loss: 1.4551, Train Accuracy: 58.44%
#     Worker 3: Train Loss: 1.4458, Train Accuracy: 59.45%
# Total Computation Time: 2518.66 seconds
# Total Communication Time: 1.33 seconds
# Epoch 94/150: Test Loss: 1.9452, Test Accuracy: 50.44%
#     Worker 0: Train Loss: 1.4490, Train Accuracy: 59.33%
#     Worker 1: Train Loss: 1.4515, Train Accuracy: 59.49%
#     Worker 2: Train Loss: 1.4358, Train Accuracy: 59.87%
#     Worker 3: Train Loss: 1.4512, Train Accuracy: 59.36%
# Total Computation Time: 2545.49 seconds
# Total Communication Time: 1.34 seconds
# Epoch 95/150: Test Loss: 1.9358, Test Accuracy: 51.18%
#     Worker 0: Train Loss: 1.4298, Train Accuracy: 59.73%
#     Worker 1: Train Loss: 1.4531, Train Accuracy: 59.28%
#     Worker 2: Train Loss: 1.4319, Train Accuracy: 60.12%
#     Worker 3: Train Loss: 1.4335, Train Accuracy: 59.77%
# Total Computation Time: 2572.93 seconds
# Total Communication Time: 1.35 seconds
# Epoch 96/150: Test Loss: 1.9298, Test Accuracy: 50.70%
#     Worker 0: Train Loss: 1.4221, Train Accuracy: 59.92%
#     Worker 1: Train Loss: 1.4091, Train Accuracy: 60.49%
#     Worker 2: Train Loss: 1.4176, Train Accuracy: 60.19%
#     Worker 3: Train Loss: 1.4282, Train Accuracy: 59.51%
# Total Computation Time: 2600.11 seconds
# Total Communication Time: 1.37 seconds
# Epoch 97/150: Test Loss: 1.9341, Test Accuracy: 50.69%
#     Worker 0: Train Loss: 1.4152, Train Accuracy: 59.86%
#     Worker 1: Train Loss: 1.4235, Train Accuracy: 60.22%
#     Worker 2: Train Loss: 1.4065, Train Accuracy: 60.68%
#     Worker 3: Train Loss: 1.4236, Train Accuracy: 59.76%
# Total Computation Time: 2626.70 seconds
# Total Communication Time: 1.38 seconds
# Epoch 98/150: Test Loss: 1.9331, Test Accuracy: 51.12%
#     Worker 0: Train Loss: 1.4151, Train Accuracy: 60.04%
#     Worker 1: Train Loss: 1.4058, Train Accuracy: 60.54%
#     Worker 2: Train Loss: 1.4106, Train Accuracy: 60.36%
#     Worker 3: Train Loss: 1.4065, Train Accuracy: 60.60%
# Total Computation Time: 2654.43 seconds
# Total Communication Time: 1.40 seconds
# Epoch 99/150: Test Loss: 1.9457, Test Accuracy: 50.66%
#     Worker 0: Train Loss: 1.4007, Train Accuracy: 60.26%
#     Worker 1: Train Loss: 1.3936, Train Accuracy: 60.71%
#     Worker 2: Train Loss: 1.3828, Train Accuracy: 60.91%
#     Worker 3: Train Loss: 1.3958, Train Accuracy: 60.54%
# Total Computation Time: 2681.56 seconds
# Total Communication Time: 1.41 seconds
# Epoch 100/150: Test Loss: 1.9426, Test Accuracy: 50.98%
#     Worker 0: Train Loss: 1.3800, Train Accuracy: 60.39%
#     Worker 1: Train Loss: 1.4056, Train Accuracy: 60.43%
#     Worker 2: Train Loss: 1.3757, Train Accuracy: 60.92%
#     Worker 3: Train Loss: 1.3794, Train Accuracy: 61.29%
# Total Computation Time: 2708.79 seconds
# Total Communication Time: 1.43 seconds
# Epoch 101/150: Test Loss: 1.9422, Test Accuracy: 50.93%
#     Worker 0: Train Loss: 1.3901, Train Accuracy: 60.48%
#     Worker 1: Train Loss: 1.3997, Train Accuracy: 60.49%
#     Worker 2: Train Loss: 1.3690, Train Accuracy: 61.45%
#     Worker 3: Train Loss: 1.3935, Train Accuracy: 60.57%
# Total Computation Time: 2736.32 seconds
# Total Communication Time: 1.44 seconds
# Epoch 102/150: Test Loss: 1.9370, Test Accuracy: 51.22%
#     Worker 0: Train Loss: 1.3804, Train Accuracy: 61.06%
#     Worker 1: Train Loss: 1.3412, Train Accuracy: 61.99%
#     Worker 2: Train Loss: 1.3698, Train Accuracy: 61.46%
#     Worker 3: Train Loss: 1.3675, Train Accuracy: 61.59%
# Total Computation Time: 2763.71 seconds
# Total Communication Time: 1.45 seconds
# Epoch 103/150: Test Loss: 1.9399, Test Accuracy: 51.16%
#     Worker 0: Train Loss: 1.3612, Train Accuracy: 61.38%
#     Worker 1: Train Loss: 1.4043, Train Accuracy: 61.05%
#     Worker 2: Train Loss: 1.3462, Train Accuracy: 62.51%
#     Worker 3: Train Loss: 1.3818, Train Accuracy: 60.57%
# Total Computation Time: 2790.90 seconds
# Total Communication Time: 1.47 seconds
# Epoch 104/150: Test Loss: 1.9383, Test Accuracy: 50.89%
#     Worker 0: Train Loss: 1.3547, Train Accuracy: 61.66%
#     Worker 1: Train Loss: 1.3446, Train Accuracy: 61.80%
#     Worker 2: Train Loss: 1.3411, Train Accuracy: 62.01%
#     Worker 3: Train Loss: 1.3644, Train Accuracy: 61.96%
# Total Computation Time: 2817.78 seconds
# Total Communication Time: 1.48 seconds
# Epoch 105/150: Test Loss: 1.9469, Test Accuracy: 51.05%
#     Worker 0: Train Loss: 1.3495, Train Accuracy: 61.63%
#     Worker 1: Train Loss: 1.3648, Train Accuracy: 62.05%
#     Worker 2: Train Loss: 1.3448, Train Accuracy: 62.15%
#     Worker 3: Train Loss: 1.3452, Train Accuracy: 62.22%
# Total Computation Time: 2844.80 seconds
# Total Communication Time: 1.50 seconds
# Epoch 106/150: Test Loss: 1.9438, Test Accuracy: 51.20%
#     Worker 0: Train Loss: 1.3450, Train Accuracy: 62.22%
#     Worker 1: Train Loss: 1.3344, Train Accuracy: 62.66%
#     Worker 2: Train Loss: 1.3442, Train Accuracy: 62.13%
#     Worker 3: Train Loss: 1.3478, Train Accuracy: 62.08%
# Total Computation Time: 2871.45 seconds
# Total Communication Time: 1.51 seconds
# Epoch 107/150: Test Loss: 1.9451, Test Accuracy: 50.77%
#     Worker 0: Train Loss: 1.3417, Train Accuracy: 61.73%
#     Worker 1: Train Loss: 1.3477, Train Accuracy: 62.29%
#     Worker 2: Train Loss: 1.3211, Train Accuracy: 62.58%
#     Worker 3: Train Loss: 1.3338, Train Accuracy: 62.28%
# Total Computation Time: 2899.18 seconds
# Total Communication Time: 1.52 seconds
# Epoch 108/150: Test Loss: 1.9440, Test Accuracy: 51.15%
#     Worker 0: Train Loss: 1.3306, Train Accuracy: 62.24%
#     Worker 1: Train Loss: 1.3183, Train Accuracy: 62.55%
#     Worker 2: Train Loss: 1.2949, Train Accuracy: 63.28%
#     Worker 3: Train Loss: 1.3428, Train Accuracy: 62.34%
# Total Computation Time: 2926.46 seconds
# Total Communication Time: 1.54 seconds
# Epoch 109/150: Test Loss: 1.9460, Test Accuracy: 51.07%
#     Worker 0: Train Loss: 1.3179, Train Accuracy: 62.43%
#     Worker 1: Train Loss: 1.3310, Train Accuracy: 62.51%
#     Worker 2: Train Loss: 1.3280, Train Accuracy: 62.81%
#     Worker 3: Train Loss: 1.3123, Train Accuracy: 63.36%
# Total Computation Time: 2953.52 seconds
# Total Communication Time: 1.56 seconds
# Epoch 110/150: Test Loss: 1.9449, Test Accuracy: 51.41%
#     Worker 0: Train Loss: 1.3117, Train Accuracy: 63.11%
#     Worker 1: Train Loss: 1.3269, Train Accuracy: 62.58%
#     Worker 2: Train Loss: 1.2819, Train Accuracy: 63.58%
#     Worker 3: Train Loss: 1.3389, Train Accuracy: 62.26%
# Total Computation Time: 2981.40 seconds
# Total Communication Time: 1.57 seconds
# Epoch 111/150: Test Loss: 1.9481, Test Accuracy: 51.40%
#     Worker 0: Train Loss: 1.3120, Train Accuracy: 63.07%
#     Worker 1: Train Loss: 1.3059, Train Accuracy: 63.09%
#     Worker 2: Train Loss: 1.3081, Train Accuracy: 62.86%
#     Worker 3: Train Loss: 1.3000, Train Accuracy: 63.76%
# Total Computation Time: 3008.19 seconds
# Total Communication Time: 1.58 seconds
# Epoch 112/150: Test Loss: 1.9438, Test Accuracy: 51.48%
#     Worker 0: Train Loss: 1.2992, Train Accuracy: 63.01%
#     Worker 1: Train Loss: 1.2996, Train Accuracy: 63.31%
#     Worker 2: Train Loss: 1.2936, Train Accuracy: 63.45%
#     Worker 3: Train Loss: 1.3105, Train Accuracy: 63.32%
# Total Computation Time: 3035.85 seconds
# Total Communication Time: 1.60 seconds
# Epoch 113/150: Test Loss: 1.9493, Test Accuracy: 50.98%
#     Worker 0: Train Loss: 1.2733, Train Accuracy: 63.69%
#     Worker 1: Train Loss: 1.2924, Train Accuracy: 63.50%
#     Worker 2: Train Loss: 1.2757, Train Accuracy: 64.07%
#     Worker 3: Train Loss: 1.3018, Train Accuracy: 63.26%
# Total Computation Time: 3063.09 seconds
# Total Communication Time: 1.61 seconds
# Epoch 114/150: Test Loss: 1.9483, Test Accuracy: 51.36%
#     Worker 0: Train Loss: 1.2948, Train Accuracy: 63.41%
#     Worker 1: Train Loss: 1.2790, Train Accuracy: 63.99%
#     Worker 2: Train Loss: 1.2885, Train Accuracy: 63.89%
#     Worker 3: Train Loss: 1.2793, Train Accuracy: 63.88%
# Total Computation Time: 3090.20 seconds
# Total Communication Time: 1.62 seconds
# Epoch 115/150: Test Loss: 1.9525, Test Accuracy: 51.19%
#     Worker 0: Train Loss: 1.2730, Train Accuracy: 63.62%
#     Worker 1: Train Loss: 1.2872, Train Accuracy: 63.87%
#     Worker 2: Train Loss: 1.2926, Train Accuracy: 63.28%
#     Worker 3: Train Loss: 1.2969, Train Accuracy: 63.67%
# Total Computation Time: 3117.75 seconds
# Total Communication Time: 1.64 seconds
# Epoch 116/150: Test Loss: 1.9565, Test Accuracy: 51.10%
#     Worker 0: Train Loss: 1.2773, Train Accuracy: 64.16%
#     Worker 1: Train Loss: 1.2748, Train Accuracy: 64.08%
#     Worker 2: Train Loss: 1.2470, Train Accuracy: 64.78%
#     Worker 3: Train Loss: 1.2624, Train Accuracy: 64.04%
# Total Computation Time: 3145.28 seconds
# Total Communication Time: 1.65 seconds
# Epoch 117/150: Test Loss: 1.9490, Test Accuracy: 51.51%
#     Worker 0: Train Loss: 1.2886, Train Accuracy: 63.46%
#     Worker 1: Train Loss: 1.2784, Train Accuracy: 63.76%
#     Worker 2: Train Loss: 1.2587, Train Accuracy: 64.38%
#     Worker 3: Train Loss: 1.2851, Train Accuracy: 63.60%
# Total Computation Time: 3173.39 seconds
# Total Communication Time: 1.67 seconds
# Epoch 118/150: Test Loss: 1.9549, Test Accuracy: 51.29%
#     Worker 0: Train Loss: 1.2562, Train Accuracy: 64.30%
#     Worker 1: Train Loss: 1.2742, Train Accuracy: 64.20%
#     Worker 2: Train Loss: 1.2550, Train Accuracy: 64.32%
#     Worker 3: Train Loss: 1.2636, Train Accuracy: 64.47%
# Total Computation Time: 3200.35 seconds
# Total Communication Time: 1.68 seconds
# Epoch 119/150: Test Loss: 1.9526, Test Accuracy: 51.50%
#     Worker 0: Train Loss: 1.2671, Train Accuracy: 63.85%
#     Worker 1: Train Loss: 1.2501, Train Accuracy: 64.52%
#     Worker 2: Train Loss: 1.2518, Train Accuracy: 64.28%
#     Worker 3: Train Loss: 1.2461, Train Accuracy: 64.54%
# Total Computation Time: 3227.31 seconds
# Total Communication Time: 1.70 seconds
# Epoch 120/150: Test Loss: 1.9541, Test Accuracy: 51.38%
#     Worker 0: Train Loss: 1.2485, Train Accuracy: 64.28%
#     Worker 1: Train Loss: 1.2456, Train Accuracy: 64.26%
#     Worker 2: Train Loss: 1.2449, Train Accuracy: 64.88%
#     Worker 3: Train Loss: 1.2583, Train Accuracy: 64.48%
# Total Computation Time: 3254.97 seconds
# Total Communication Time: 1.71 seconds
# Epoch 121/150: Test Loss: 1.9538, Test Accuracy: 51.42%
#     Worker 0: Train Loss: 1.2469, Train Accuracy: 64.50%
#     Worker 1: Train Loss: 1.2482, Train Accuracy: 64.32%
#     Worker 2: Train Loss: 1.2369, Train Accuracy: 64.84%
#     Worker 3: Train Loss: 1.2434, Train Accuracy: 65.02%
# Total Computation Time: 3281.82 seconds
# Total Communication Time: 1.72 seconds
# Epoch 122/150: Test Loss: 1.9572, Test Accuracy: 51.46%
#     Worker 0: Train Loss: 1.2285, Train Accuracy: 65.15%
#     Worker 1: Train Loss: 1.2479, Train Accuracy: 64.58%
#     Worker 2: Train Loss: 1.2427, Train Accuracy: 64.81%
#     Worker 3: Train Loss: 1.2596, Train Accuracy: 64.59%
# Total Computation Time: 3309.75 seconds
# Total Communication Time: 1.74 seconds
# Epoch 123/150: Test Loss: 1.9552, Test Accuracy: 51.35%
#     Worker 0: Train Loss: 1.2517, Train Accuracy: 64.08%
#     Worker 1: Train Loss: 1.2409, Train Accuracy: 64.79%
#     Worker 2: Train Loss: 1.2293, Train Accuracy: 65.25%
#     Worker 3: Train Loss: 1.2379, Train Accuracy: 64.79%
# Total Computation Time: 3336.84 seconds
# Total Communication Time: 1.76 seconds
# Epoch 124/150: Test Loss: 1.9599, Test Accuracy: 51.38%
#     Worker 0: Train Loss: 1.2462, Train Accuracy: 64.56%
#     Worker 1: Train Loss: 1.2457, Train Accuracy: 64.76%
#     Worker 2: Train Loss: 1.2342, Train Accuracy: 64.83%
#     Worker 3: Train Loss: 1.2434, Train Accuracy: 65.06%
# Total Computation Time: 3363.86 seconds
# Total Communication Time: 1.77 seconds
# Epoch 125/150: Test Loss: 1.9540, Test Accuracy: 51.41%
#     Worker 0: Train Loss: 1.2314, Train Accuracy: 64.91%
#     Worker 1: Train Loss: 1.2352, Train Accuracy: 65.13%
#     Worker 2: Train Loss: 1.2207, Train Accuracy: 65.08%
#     Worker 3: Train Loss: 1.2233, Train Accuracy: 65.48%
# Total Computation Time: 3391.36 seconds
# Total Communication Time: 1.78 seconds
# Epoch 126/150: Test Loss: 1.9588, Test Accuracy: 51.31%
#     Worker 0: Train Loss: 1.2273, Train Accuracy: 65.23%
#     Worker 1: Train Loss: 1.2281, Train Accuracy: 65.36%
#     Worker 2: Train Loss: 1.2234, Train Accuracy: 65.37%
#     Worker 3: Train Loss: 1.2268, Train Accuracy: 65.44%
# Total Computation Time: 3417.98 seconds
# Total Communication Time: 1.80 seconds
# Epoch 127/150: Test Loss: 1.9588, Test Accuracy: 51.45%
#     Worker 0: Train Loss: 1.2257, Train Accuracy: 65.62%
#     Worker 1: Train Loss: 1.2167, Train Accuracy: 65.51%
#     Worker 2: Train Loss: 1.2229, Train Accuracy: 65.50%
#     Worker 3: Train Loss: 1.2207, Train Accuracy: 65.44%
# Total Computation Time: 3445.34 seconds
# Total Communication Time: 1.81 seconds
# Epoch 128/150: Test Loss: 1.9564, Test Accuracy: 51.57%
#     Worker 0: Train Loss: 1.2165, Train Accuracy: 65.67%
#     Worker 1: Train Loss: 1.2239, Train Accuracy: 65.19%
#     Worker 2: Train Loss: 1.2223, Train Accuracy: 65.21%
#     Worker 3: Train Loss: 1.2345, Train Accuracy: 64.95%
# Total Computation Time: 3472.07 seconds
# Total Communication Time: 1.83 seconds
# Epoch 129/150: Test Loss: 1.9628, Test Accuracy: 51.46%
#     Worker 0: Train Loss: 1.2266, Train Accuracy: 64.51%
#     Worker 1: Train Loss: 1.2154, Train Accuracy: 65.39%
#     Worker 2: Train Loss: 1.1983, Train Accuracy: 65.86%
#     Worker 3: Train Loss: 1.2081, Train Accuracy: 66.53%
# Total Computation Time: 3498.31 seconds
# Total Communication Time: 1.84 seconds
# Epoch 130/150: Test Loss: 1.9582, Test Accuracy: 51.54%
#     Worker 0: Train Loss: 1.2137, Train Accuracy: 65.49%
#     Worker 1: Train Loss: 1.2183, Train Accuracy: 65.53%
#     Worker 2: Train Loss: 1.2101, Train Accuracy: 65.83%
#     Worker 3: Train Loss: 1.2220, Train Accuracy: 65.65%
# Total Computation Time: 3525.90 seconds
# Total Communication Time: 1.85 seconds
# Epoch 131/150: Test Loss: 1.9599, Test Accuracy: 51.56%
#     Worker 0: Train Loss: 1.2113, Train Accuracy: 65.77%
#     Worker 1: Train Loss: 1.2270, Train Accuracy: 65.51%
#     Worker 2: Train Loss: 1.1981, Train Accuracy: 66.49%
#     Worker 3: Train Loss: 1.2107, Train Accuracy: 65.77%
# Total Computation Time: 3552.69 seconds
# Total Communication Time: 1.87 seconds
# Epoch 132/150: Test Loss: 1.9596, Test Accuracy: 51.63%
#     Worker 0: Train Loss: 1.2062, Train Accuracy: 65.39%
#     Worker 1: Train Loss: 1.2176, Train Accuracy: 65.51%
#     Worker 2: Train Loss: 1.1992, Train Accuracy: 66.02%
#     Worker 3: Train Loss: 1.2189, Train Accuracy: 65.75%
# Total Computation Time: 3579.93 seconds
# Total Communication Time: 1.88 seconds
# Epoch 133/150: Test Loss: 1.9587, Test Accuracy: 51.51%
#     Worker 0: Train Loss: 1.2144, Train Accuracy: 65.74%
#     Worker 1: Train Loss: 1.2029, Train Accuracy: 66.00%
#     Worker 2: Train Loss: 1.1893, Train Accuracy: 66.02%
#     Worker 3: Train Loss: 1.2108, Train Accuracy: 65.82%
# Total Computation Time: 3606.72 seconds
# Total Communication Time: 1.90 seconds
# Epoch 134/150: Test Loss: 1.9631, Test Accuracy: 51.73%
#     Worker 0: Train Loss: 1.2122, Train Accuracy: 65.30%
#     Worker 1: Train Loss: 1.2046, Train Accuracy: 65.84%
#     Worker 2: Train Loss: 1.2090, Train Accuracy: 65.51%
#     Worker 3: Train Loss: 1.1983, Train Accuracy: 65.83%
# Total Computation Time: 3633.46 seconds
# Total Communication Time: 1.91 seconds
# Epoch 135/150: Test Loss: 1.9624, Test Accuracy: 51.62%
#     Worker 0: Train Loss: 1.2015, Train Accuracy: 65.72%
#     Worker 1: Train Loss: 1.2037, Train Accuracy: 66.39%
#     Worker 2: Train Loss: 1.1901, Train Accuracy: 66.59%
#     Worker 3: Train Loss: 1.2128, Train Accuracy: 66.11%
# Total Computation Time: 3660.44 seconds
# Total Communication Time: 1.92 seconds
# Epoch 136/150: Test Loss: 1.9611, Test Accuracy: 51.55%
#     Worker 0: Train Loss: 1.2062, Train Accuracy: 65.40%
#     Worker 1: Train Loss: 1.2004, Train Accuracy: 66.02%
#     Worker 2: Train Loss: 1.2056, Train Accuracy: 66.17%
#     Worker 3: Train Loss: 1.2025, Train Accuracy: 65.76%
# Total Computation Time: 3687.49 seconds
# Total Communication Time: 1.94 seconds
# Epoch 137/150: Test Loss: 1.9606, Test Accuracy: 51.61%
#     Worker 0: Train Loss: 1.1881, Train Accuracy: 65.95%
#     Worker 1: Train Loss: 1.2107, Train Accuracy: 66.02%
#     Worker 2: Train Loss: 1.1939, Train Accuracy: 66.06%
#     Worker 3: Train Loss: 1.1986, Train Accuracy: 66.61%
# Total Computation Time: 3715.07 seconds
# Total Communication Time: 1.95 seconds
# Epoch 138/150: Test Loss: 1.9607, Test Accuracy: 51.57%
#     Worker 0: Train Loss: 1.2048, Train Accuracy: 65.88%
#     Worker 1: Train Loss: 1.1836, Train Accuracy: 66.24%
#     Worker 2: Train Loss: 1.1940, Train Accuracy: 66.37%
#     Worker 3: Train Loss: 1.1974, Train Accuracy: 66.25%
# Total Computation Time: 3742.51 seconds
# Total Communication Time: 1.96 seconds
# Epoch 139/150: Test Loss: 1.9609, Test Accuracy: 51.69%
#     Worker 0: Train Loss: 1.1869, Train Accuracy: 66.18%
#     Worker 1: Train Loss: 1.2020, Train Accuracy: 65.92%
#     Worker 2: Train Loss: 1.1959, Train Accuracy: 66.49%
#     Worker 3: Train Loss: 1.2041, Train Accuracy: 66.14%
# Total Computation Time: 3769.70 seconds
# Total Communication Time: 1.98 seconds
# Epoch 140/150: Test Loss: 1.9607, Test Accuracy: 51.63%
#     Worker 0: Train Loss: 1.1968, Train Accuracy: 65.77%
#     Worker 1: Train Loss: 1.1966, Train Accuracy: 65.99%
#     Worker 2: Train Loss: 1.1826, Train Accuracy: 66.23%
#     Worker 3: Train Loss: 1.1997, Train Accuracy: 66.25%
# Total Computation Time: 3796.65 seconds
# Total Communication Time: 2.00 seconds
# Epoch 141/150: Test Loss: 1.9617, Test Accuracy: 51.61%
#     Worker 0: Train Loss: 1.1884, Train Accuracy: 66.14%
#     Worker 1: Train Loss: 1.2157, Train Accuracy: 65.42%
#     Worker 2: Train Loss: 1.1839, Train Accuracy: 66.34%
#     Worker 3: Train Loss: 1.2000, Train Accuracy: 65.99%
# Total Computation Time: 3823.77 seconds
# Total Communication Time: 2.01 seconds
# Epoch 142/150: Test Loss: 1.9625, Test Accuracy: 51.60%
#     Worker 0: Train Loss: 1.2062, Train Accuracy: 65.10%
#     Worker 1: Train Loss: 1.1917, Train Accuracy: 66.28%
#     Worker 2: Train Loss: 1.1848, Train Accuracy: 66.30%
#     Worker 3: Train Loss: 1.1804, Train Accuracy: 66.70%
# Total Computation Time: 3851.50 seconds
# Total Communication Time: 2.02 seconds
# Epoch 143/150: Test Loss: 1.9617, Test Accuracy: 51.62%
#     Worker 0: Train Loss: 1.1913, Train Accuracy: 66.24%
#     Worker 1: Train Loss: 1.1845, Train Accuracy: 66.50%
#     Worker 2: Train Loss: 1.1813, Train Accuracy: 67.00%
#     Worker 3: Train Loss: 1.1987, Train Accuracy: 66.20%
# Total Computation Time: 3878.96 seconds
# Total Communication Time: 2.04 seconds
# Epoch 144/150: Test Loss: 1.9618, Test Accuracy: 51.67%
#     Worker 0: Train Loss: 1.1795, Train Accuracy: 66.06%
#     Worker 1: Train Loss: 1.1894, Train Accuracy: 66.25%
#     Worker 2: Train Loss: 1.1913, Train Accuracy: 65.76%
#     Worker 3: Train Loss: 1.1822, Train Accuracy: 66.78%
# Total Computation Time: 3906.03 seconds
# Total Communication Time: 2.05 seconds
# Epoch 145/150: Test Loss: 1.9614, Test Accuracy: 51.60%
#     Worker 0: Train Loss: 1.2057, Train Accuracy: 65.61%
#     Worker 1: Train Loss: 1.2054, Train Accuracy: 65.88%
#     Worker 2: Train Loss: 1.1752, Train Accuracy: 66.48%
#     Worker 3: Train Loss: 1.2003, Train Accuracy: 66.04%
# Total Computation Time: 3933.24 seconds
# Total Communication Time: 2.07 seconds
# Epoch 146/150: Test Loss: 1.9612, Test Accuracy: 51.65%
#     Worker 0: Train Loss: 1.1927, Train Accuracy: 65.95%
#     Worker 1: Train Loss: 1.1830, Train Accuracy: 66.76%
#     Worker 2: Train Loss: 1.1734, Train Accuracy: 66.80%
#     Worker 3: Train Loss: 1.2032, Train Accuracy: 65.93%
# Total Computation Time: 3960.12 seconds
# Total Communication Time: 2.08 seconds
# Epoch 147/150: Test Loss: 1.9614, Test Accuracy: 51.63%
#     Worker 0: Train Loss: 1.1848, Train Accuracy: 66.03%
#     Worker 1: Train Loss: 1.1833, Train Accuracy: 66.52%
#     Worker 2: Train Loss: 1.1861, Train Accuracy: 65.85%
#     Worker 3: Train Loss: 1.1883, Train Accuracy: 66.63%
# Total Computation Time: 3987.72 seconds
# Total Communication Time: 2.10 seconds
# Epoch 148/150: Test Loss: 1.9614, Test Accuracy: 51.66%
#     Worker 0: Train Loss: 1.1922, Train Accuracy: 65.74%
#     Worker 1: Train Loss: 1.1993, Train Accuracy: 65.87%
#     Worker 2: Train Loss: 1.1871, Train Accuracy: 66.20%
#     Worker 3: Train Loss: 1.1979, Train Accuracy: 66.18%
# Total Computation Time: 4015.03 seconds
# Total Communication Time: 2.11 seconds
# Epoch 149/150: Test Loss: 1.9614, Test Accuracy: 51.67%
#     Worker 0: Train Loss: 1.1920, Train Accuracy: 66.27%
#     Worker 1: Train Loss: 1.2129, Train Accuracy: 65.93%
#     Worker 2: Train Loss: 1.1883, Train Accuracy: 66.76%
#     Worker 3: Train Loss: 1.2015, Train Accuracy: 65.68%
# Total Computation Time: 4041.61 seconds
# Total Communication Time: 2.12 seconds
# Epoch 150/150: Test Loss: 1.9614, Test Accuracy: 51.66%
#     Worker 0: Train Loss: 1.1901, Train Accuracy: 65.79%
#     Worker 1: Train Loss: 1.1907, Train Accuracy: 66.42%
#     Worker 2: Train Loss: 1.1738, Train Accuracy: 66.69%
#     Worker 3: Train Loss: 1.1788, Train Accuracy: 66.81%
# Total Computation Time: 4068.13 seconds
# Total Communication Time: 2.14 seconds
