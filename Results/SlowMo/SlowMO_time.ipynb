# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files
import time

total_computation_time = 0
total_communication_time = 0

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
# Alpha slow learning rate a=1 best
# Beta slow momentum
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
#warmup_epochs = 5

alpha = 0.75 # Slow learning rate scaling factor
beta = 0.2  # Slow momentum factor

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate for each k: {learning_rate:.5f}")
#lr_warmup=learning_rate
# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]


with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs) for optimizer in optimizers]

u_buffer = [torch.zeros_like(param) for param in nets[0].parameters()]  # Momentum buffer

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")
    #if epoch < warmup_epochs: #lr for buffer update during warmup
            #w_factor = (epoch + 1) / warmup_epochs
            #lr_warmup = w_factor * learning_rate
    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch): #outer loop
        computation_start_time = time.time()
        #x(t,0)
        iter_params = [torch.zeros_like(param) for param in nets[0].parameters()]
        for param, g_param in zip(iter_params, nets[0].parameters()):
                    param.data.copy_(g_param)
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0

            # Perform J local step before synchronization
            for j in range(J): #inner loop
                      try:
                          # Get a batch from the current worker's shard using next()
                          images, labels = next(shard_iterators[k])
                          images, labels = images.to(device), labels.to(device)  # Move to device
                          optimizers[k].zero_grad()
                          outputs = nets[k](images)
                          loss = criterion(outputs, labels)
                          loss.backward()
                          optimizers[k].step()
                          # Calculate train loss and accuracy
                          train_loss += loss.item() * labels.size(0)
                          _, predicted = outputs.max(1)
                          total_train += labels.size(0)
                          correct_train += predicted.eq(labels).sum().item()

                      except StopIteration:
                          # If the iterator has exhausted the data, restart the iterator
                          shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                          images, labels = next(shard_iterators[k]) # Resume from the next batch
                          images, labels = images.to(device), labels.to(device)
                          # Perform optimization step
                          optimizers[k].zero_grad()
                          outputs = nets[k](images)
                          loss = criterion(outputs, labels)
                          loss.backward()
                          optimizers[k].step()
                          # Calculate train loss and accuracy
                          train_loss += loss.item() * labels.size(0)
                          _, predicted = outputs.max(1)
                          total_train += labels.size(0)
                          correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        computation_end_time = time.time()
        total_computation_time += (computation_end_time - computation_start_time)

        communication_start_time = time.time()
          # Synchronization (SLOWMO Algothm 1 - paper 21)
        with torch.no_grad():
            global_params = [torch.zeros_like(param) for param in nets[0].parameters()]
            #x(t, tau)
            for net in nets:
                for global_param, local_param in zip(global_params, net.parameters()):
                    global_param += local_param
            for global_param in global_params:
                global_param /= K

            for param, g_param, u_param in zip(iter_params, global_params, u_buffer):
                #if epoch < warmup_epochs:
                  #  u_param.mul_(beta).add_((param - g_param) / lr_warmup)
                 #   g_param.sub_(alpha * lr_warmup * u_param)

                #else: #Sync after warmup
                    #print(f"{optimizers[0].param_groups[0]['lr']}  {optimizers[1].param_groups[0]['lr']}")
                    lr_sched = optimizers[0].param_groups[0]['lr'] #optimizer lr
                    u_param.mul_(beta).add_((param - g_param) / lr_sched)
                    #g_param.sub_(alpha * lr_sched * u_param)
                    g_param.copy_(param - alpha * lr_sched * u_param)

            for net in nets:
                for param, g_param in zip(net.parameters(), global_params):
                    param.data.copy_(g_param)

        communication_end_time = time.time()
        total_communication_time += (communication_end_time - communication_start_time)

    # Update lr for each scheduler
    for scheduler in schedulers:
        #if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
        #else:
         #   warmup_factor = (epoch + 1) / warmup_epochs
          #  lr = warmup_factor * learning_rate
           # for optimizer in optimizers:
            #    for param_group in optimizer.param_groups:
             #       param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

    print(f"Total Computation Time: {total_computation_time:.2f} seconds")
    print(f"Total Communication Time: {total_communication_time:.2f} seconds")


# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 4 --j 16
# Out:
# Training with K=4, J=16
# Global iteration per epoch: 13
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
#     Worker 0: Train Loss: 1.8769, Train Accuracy: 49.05%
#     Worker 1: Train Loss: 1.8743, Train Accuracy: 48.68%
#     Worker 2: Train Loss: 1.8451, Train Accuracy: 50.05%
#     Worker 3: Train Loss: 1.8877, Train Accuracy: 49.01%
# Total Computation Time: 1539.16 seconds
# Total Communication Time: 1.65 seconds
# Epoch 62/150: Test Loss: 2.0115, Test Accuracy: 47.60%
#     Worker 0: Train Loss: 1.8800, Train Accuracy: 48.82%
#     Worker 1: Train Loss: 1.8454, Train Accuracy: 49.95%
#     Worker 2: Train Loss: 1.8724, Train Accuracy: 49.31%
#     Worker 3: Train Loss: 1.8551, Train Accuracy: 50.22%
# Total Computation Time: 1564.21 seconds
# Total Communication Time: 1.68 seconds
# Epoch 63/150: Test Loss: 2.0166, Test Accuracy: 47.81%
#     Worker 0: Train Loss: 1.8494, Train Accuracy: 49.79%
#     Worker 1: Train Loss: 1.8404, Train Accuracy: 50.15%
#     Worker 2: Train Loss: 1.8281, Train Accuracy: 50.27%
#     Worker 3: Train Loss: 1.8628, Train Accuracy: 49.57%
# Total Computation Time: 1589.40 seconds
# Total Communication Time: 1.70 seconds
# Epoch 64/150: Test Loss: 2.0141, Test Accuracy: 48.07%
#     Worker 0: Train Loss: 1.8334, Train Accuracy: 50.29%
#     Worker 1: Train Loss: 1.8587, Train Accuracy: 49.73%
#     Worker 2: Train Loss: 1.8154, Train Accuracy: 50.84%
#     Worker 3: Train Loss: 1.8361, Train Accuracy: 50.25%
# Total Computation Time: 1614.75 seconds
# Total Communication Time: 1.73 seconds
# Epoch 65/150: Test Loss: 2.0081, Test Accuracy: 47.61%
#     Worker 0: Train Loss: 1.8136, Train Accuracy: 50.41%
#     Worker 1: Train Loss: 1.8040, Train Accuracy: 50.54%
#     Worker 2: Train Loss: 1.7989, Train Accuracy: 50.84%
#     Worker 3: Train Loss: 1.8200, Train Accuracy: 50.85%
# Total Computation Time: 1639.78 seconds
# Total Communication Time: 1.76 seconds
# Epoch 66/150: Test Loss: 2.0050, Test Accuracy: 47.83%
#     Worker 0: Train Loss: 1.8006, Train Accuracy: 50.33%
#     Worker 1: Train Loss: 1.8066, Train Accuracy: 50.53%
#     Worker 2: Train Loss: 1.7974, Train Accuracy: 50.90%
#     Worker 3: Train Loss: 1.8036, Train Accuracy: 51.22%
# Total Computation Time: 1664.68 seconds
# Total Communication Time: 1.78 seconds
# Epoch 67/150: Test Loss: 2.0021, Test Accuracy: 47.92%
#     Worker 0: Train Loss: 1.7895, Train Accuracy: 50.98%
#     Worker 1: Train Loss: 1.7893, Train Accuracy: 51.14%
#     Worker 2: Train Loss: 1.7893, Train Accuracy: 51.57%
#     Worker 3: Train Loss: 1.7967, Train Accuracy: 51.68%
# Total Computation Time: 1689.85 seconds
# Total Communication Time: 1.81 seconds
# Epoch 68/150: Test Loss: 1.9885, Test Accuracy: 48.17%
#     Worker 0: Train Loss: 1.7666, Train Accuracy: 51.18%
#     Worker 1: Train Loss: 1.7814, Train Accuracy: 51.01%
#     Worker 2: Train Loss: 1.7686, Train Accuracy: 51.87%
#     Worker 3: Train Loss: 1.4721, Train Accuracy: 59.41%
# Total Computation Time: 2470.04 seconds
# Total Communication Time: 2.63 seconds
# Epoch 99/150: Test Loss: 1.9460, Test Accuracy: 50.39%
#     Worker 0: Train Loss: 1.4640, Train Accuracy: 59.50%
#     Worker 1: Train Loss: 1.4457, Train Accuracy: 59.44%
#     Worker 2: Train Loss: 1.4501, Train Accuracy: 59.89%
#     Worker 3: Train Loss: 1.4622, Train Accuracy: 59.56%
# Total Computation Time: 2495.21 seconds
# Total Communication Time: 2.65 seconds
# Epoch 100/150: Test Loss: 1.9391, Test Accuracy: 51.19%
#     Worker 0: Train Loss: 1.4388, Train Accuracy: 59.38%
#     Worker 1: Train Loss: 1.4389, Train Accuracy: 59.58%
#     Worker 2: Train Loss: 1.4288, Train Accuracy: 59.96%
#     Worker 3: Train Loss: 1.4633, Train Accuracy: 59.45%
# Total Computation Time: 2520.24 seconds
# Total Communication Time: 2.68 seconds
# Epoch 101/150: Test Loss: 1.9447, Test Accuracy: 50.45%
#     Worker 0: Train Loss: 1.4401, Train Accuracy: 59.04%
#     Worker 1: Train Loss: 1.4469, Train Accuracy: 59.38%
#     Worker 2: Train Loss: 1.4309, Train Accuracy: 59.92%
#     Worker 3: Train Loss: 1.4451, Train Accuracy: 59.60%
# Total Computation Time: 2545.87 seconds
# Total Communication Time: 2.71 seconds
# Epoch 102/150: Test Loss: 1.9460, Test Accuracy: 50.79%
#     Worker 0: Train Loss: 1.4297, Train Accuracy: 59.28%
#     Worker 1: Train Loss: 1.4245, Train Accuracy: 59.88%
#     Worker 2: Train Loss: 1.4187, Train Accuracy: 60.45%
#     Worker 3: Train Loss: 1.4414, Train Accuracy: 60.02%
# Total Computation Time: 2571.03 seconds
# Total Communication Time: 2.73 seconds
# Epoch 103/150: Test Loss: 1.9381, Test Accuracy: 50.80%
#     Worker 0: Train Loss: 1.4278, Train Accuracy: 60.21%
#     Worker 1: Train Loss: 1.4063, Train Accuracy: 60.91%
#     Worker 2: Train Loss: 1.4093, Train Accuracy: 60.23%
#     Worker 3: Train Loss: 1.4358, Train Accuracy: 60.38%
# Total Computation Time: 2596.04 seconds
# Total Communication Time: 2.76 seconds
# Epoch 104/150: Test Loss: 1.9461, Test Accuracy: 50.85%
#     Worker 0: Train Loss: 1.3959, Train Accuracy: 60.49%
#     Worker 1: Train Loss: 1.4205, Train Accuracy: 60.43%
#     Worker 2: Train Loss: 1.4103, Train Accuracy: 60.57%
#     Worker 3: Train Loss: 1.4131, Train Accuracy: 60.60%
# Total Computation Time: 2621.13 seconds
# Total Communication Time: 2.78 seconds
# Epoch 105/150: Test Loss: 1.9403, Test Accuracy: 50.77%
#     Worker 0: Train Loss: 1.4160, Train Accuracy: 59.92%
#     Worker 1: Train Loss: 1.3977, Train Accuracy: 60.91%
#     Worker 2: Train Loss: 1.4077, Train Accuracy: 60.54%
#     Worker 3: Train Loss: 1.4303, Train Accuracy: 60.26%
# Total Computation Time: 2646.36 seconds
# Total Communication Time: 2.81 seconds
# Epoch 106/150: Test Loss: 1.9390, Test Accuracy: 50.93%
#     Worker 0: Train Loss: 1.3969, Train Accuracy: 60.62%
#     Worker 1: Train Loss: 1.4037, Train Accuracy: 60.73%
#     Worker 2: Train Loss: 1.3823, Train Accuracy: 61.92%
#     Worker 3: Train Loss: 1.4075, Train Accuracy: 60.91%
# Total Computation Time: 2671.43 seconds
# Total Communication Time: 2.84 seconds
# Epoch 107/150: Test Loss: 1.9480, Test Accuracy: 50.42%
#     Worker 0: Train Loss: 1.4117, Train Accuracy: 59.74%
#     Worker 1: Train Loss: 1.3986, Train Accuracy: 61.06%
#     Worker 2: Train Loss: 1.3954, Train Accuracy: 60.91%
#     Worker 3: Train Loss: 1.4072, Train Accuracy: 61.25%
# Total Computation Time: 2696.40 seconds
# Total Communication Time: 2.87 seconds
# Epoch 108/150: Test Loss: 1.9404, Test Accuracy: 50.82%
#     Worker 0: Train Loss: 1.3856, Train Accuracy: 60.36%
#     Worker 1: Train Loss: 1.3875, Train Accuracy: 61.28%
#     Worker 2: Train Loss: 1.3692, Train Accuracy: 61.84%
#     Worker 3: Train Loss: 1.3922, Train Accuracy: 61.25%
# Total Computation Time: 2721.40 seconds
# Total Communication Time: 2.89 seconds
# Epoch 109/150: Test Loss: 1.9411, Test Accuracy: 50.94%
#     Worker 0: Train Loss: 1.3757, Train Accuracy: 61.16%
#     Worker 1: Train Loss: 1.3729, Train Accuracy: 61.37%
#     Worker 2: Train Loss: 1.3573, Train Accuracy: 61.56%
#     Worker 3: Train Loss: 1.4024, Train Accuracy: 60.85%
# Total Computation Time: 2746.41 seconds
# Total Communication Time: 2.91 seconds
# Epoch 110/150: Test Loss: 1.9418, Test Accuracy: 51.09%
#     Worker 0: Train Loss: 1.3770, Train Accuracy: 61.23%
#     Worker 1: Train Loss: 1.3801, Train Accuracy: 61.49%
#     Worker 2: Train Loss: 1.3707, Train Accuracy: 61.69%
#     Worker 3: Train Loss: 1.3900, Train Accuracy: 61.42%
# Total Computation Time: 2771.57 seconds
# Total Communication Time: 2.94 seconds
# Epoch 111/150: Test Loss: 1.9461, Test Accuracy: 50.85%
#     Worker 0: Train Loss: 1.3567, Train Accuracy: 61.27%
#     Worker 1: Train Loss: 1.3618, Train Accuracy: 61.86%
#     Worker 2: Train Loss: 1.3508, Train Accuracy: 61.47%
#     Worker 3: Train Loss: 1.3831, Train Accuracy: 60.81%
# Total Computation Time: 2796.60 seconds
# Total Communication Time: 2.97 seconds
# Epoch 112/150: Test Loss: 1.9398, Test Accuracy: 50.86%
#     Worker 0: Train Loss: 1.3702, Train Accuracy: 61.32%
#     Worker 1: Train Loss: 1.3588, Train Accuracy: 61.62%
#     Worker 2: Train Loss: 1.3778, Train Accuracy: 61.26%
#     Worker 3: Train Loss: 1.3627, Train Accuracy: 62.22%
# Total Computation Time: 2821.55 seconds
# Total Communication Time: 2.99 seconds
# Epoch 113/150: Test Loss: 1.9426, Test Accuracy: 51.06%
#     Worker 0: Train Loss: 1.3640, Train Accuracy: 61.26%
#     Worker 1: Train Loss: 1.3551, Train Accuracy: 61.56%
# Epoch 121/150: Test Loss: 1.9458, Test Accuracy: 51.35%
#     Worker 0: Train Loss: 1.3046, Train Accuracy: 62.83%
#     Worker 1: Train Loss: 1.3174, Train Accuracy: 62.93%
#     Worker 2: Train Loss: 1.2938, Train Accuracy: 63.47%
#     Worker 3: Train Loss: 1.3101, Train Accuracy: 62.96%
# Total Computation Time: 3045.69 seconds
# Total Communication Time: 3.22 seconds
# Epoch 122/150: Test Loss: 1.9488, Test Accuracy: 51.15%
#     Worker 0: Train Loss: 1.2978, Train Accuracy: 63.26%
#     Worker 1: Train Loss: 1.3125, Train Accuracy: 63.33%
#     Worker 2: Train Loss: 1.3152, Train Accuracy: 63.05%
#     Worker 3: Train Loss: 1.3054, Train Accuracy: 63.41%
# Total Computation Time: 3070.45 seconds
# Total Communication Time: 3.25 seconds
# Epoch 123/150: Test Loss: 1.9513, Test Accuracy: 51.28%
#     Worker 0: Train Loss: 1.3046, Train Accuracy: 63.27%
#     Worker 1: Train Loss: 1.2884, Train Accuracy: 63.72%
#     Worker 2: Train Loss: 1.2944, Train Accuracy: 63.63%
#     Worker 3: Train Loss: 1.3207, Train Accuracy: 63.17%
# Total Computation Time: 3095.30 seconds
# Total Communication Time: 3.28 seconds
# Epoch 124/150: Test Loss: 1.9492, Test Accuracy: 51.19%
#     Worker 0: Train Loss: 1.2906, Train Accuracy: 63.23%
#     Worker 1: Train Loss: 1.3156, Train Accuracy: 63.05%
#     Worker 2: Train Loss: 1.2986, Train Accuracy: 63.29%
#     Worker 3: Train Loss: 1.3301, Train Accuracy: 63.31%
# Total Computation Time: 3120.01 seconds
# Total Communication Time: 3.30 seconds
# Epoch 125/150: Test Loss: 1.9489, Test Accuracy: 51.22%
#     Worker 0: Train Loss: 1.2806, Train Accuracy: 63.66%
#     Worker 1: Train Loss: 1.3132, Train Accuracy: 63.09%
#     Worker 2: Train Loss: 1.2901, Train Accuracy: 63.81%
#     Worker 3: Train Loss: 1.2905, Train Accuracy: 64.00%
# Total Computation Time: 3144.85 seconds
# Total Communication Time: 3.33 seconds
# Epoch 126/150: Test Loss: 1.9445, Test Accuracy: 51.44%
#     Worker 0: Train Loss: 1.3087, Train Accuracy: 63.24%
#     Worker 1: Train Loss: 1.2901, Train Accuracy: 63.41%
#     Worker 2: Train Loss: 1.2881, Train Accuracy: 63.88%
#     Worker 3: Train Loss: 1.3154, Train Accuracy: 63.42%
# Total Computation Time: 3169.65 seconds
# Total Communication Time: 3.36 seconds
# Epoch 127/150: Test Loss: 1.9439, Test Accuracy: 51.33%
#     Worker 0: Train Loss: 1.2763, Train Accuracy: 63.89%
#     Worker 1: Train Loss: 1.3053, Train Accuracy: 63.30%
#     Worker 2: Train Loss: 1.2777, Train Accuracy: 63.85%
#     Worker 3: Train Loss: 1.2920, Train Accuracy: 63.75%
# Total Computation Time: 3194.45 seconds
# Total Communication Time: 3.38 seconds
# Epoch 128/150: Test Loss: 1.9471, Test Accuracy: 51.49%
#     Worker 0: Train Loss: 1.2952, Train Accuracy: 63.54%
#     Worker 1: Train Loss: 1.2678, Train Accuracy: 64.10%
#     Worker 2: Train Loss: 1.2688, Train Accuracy: 64.11%
#     Worker 3: Train Loss: 1.2981, Train Accuracy: 63.53%
# Total Computation Time: 3219.53 seconds
# Total Communication Time: 3.41 seconds
# Epoch 129/150: Test Loss: 1.9474, Test Accuracy: 51.19%
#     Worker 0: Train Loss: 1.2852, Train Accuracy: 63.44%
#     Worker 1: Train Loss: 1.2954, Train Accuracy: 63.60%
#     Worker 2: Train Loss: 1.2822, Train Accuracy: 64.09%
#     Worker 3: Train Loss: 1.3118, Train Accuracy: 63.10%
# Total Computation Time: 3244.38 seconds
# Total Communication Time: 3.44 seconds
# Epoch 130/150: Test Loss: 1.9479, Test Accuracy: 51.21%
#     Worker 0: Train Loss: 1.2777, Train Accuracy: 63.60%
#     Worker 1: Train Loss: 1.2750, Train Accuracy: 63.82%
#     Worker 2: Train Loss: 1.2822, Train Accuracy: 64.28%
#     Worker 3: Train Loss: 1.2915, Train Accuracy: 63.69%
# Total Computation Time: 3269.13 seconds
# Total Communication Time: 3.46 seconds
# Epoch 131/150: Test Loss: 1.9475, Test Accuracy: 51.45%
#     Worker 0: Train Loss: 1.2782, Train Accuracy: 63.36%
#     Worker 1: Train Loss: 1.2786, Train Accuracy: 63.97%
#     Worker 2: Train Loss: 1.2774, Train Accuracy: 64.28%
#     Worker 3: Train Loss: 1.2875, Train Accuracy: 64.04%
# Total Computation Time: 3293.98 seconds
# Total Communication Time: 3.49 seconds
# Epoch 132/150: Test Loss: 1.9475, Test Accuracy: 51.42%
#     Worker 0: Train Loss: 1.2737, Train Accuracy: 63.33%
#     Worker 1: Train Loss: 1.2750, Train Accuracy: 64.08%
#     Worker 2: Train Loss: 1.2760, Train Accuracy: 64.16%
#     Worker 3: Train Loss: 1.2802, Train Accuracy: 64.41%
# Total Computation Time: 3318.73 seconds
# Total Communication Time: 3.51 seconds
# Epoch 133/150: Test Loss: 1.9469, Test Accuracy: 51.48%
#     Worker 0: Train Loss: 1.2853, Train Accuracy: 63.96%
#     Worker 1: Train Loss: 1.2834, Train Accuracy: 63.93%
#     Worker 2: Train Loss: 1.2685, Train Accuracy: 64.03%
#     Worker 3: Train Loss: 1.2924, Train Accuracy: 63.88%
# Total Computation Time: 3343.57 seconds
# Total Communication Time: 3.54 seconds
# Epoch 134/150: Test Loss: 1.9483, Test Accuracy: 51.42%
#     Worker 0: Train Loss: 1.2686, Train Accuracy: 63.91%
#     Worker 1: Train Loss: 1.2723, Train Accuracy: 64.64%
#     Worker 2: Train Loss: 1.2723, Train Accuracy: 64.25%
#     Worker 3: Train Loss: 1.3062, Train Accuracy: 63.82%
# Total Computation Time: 3368.39 seconds
# Total Communication Time: 3.57 seconds
# Epoch 135/150: Test Loss: 1.9487, Test Accuracy: 51.28%
#     Worker 0: Train Loss: 1.2691, Train Accuracy: 64.24%
#     Worker 1: Train Loss: 1.2556, Train Accuracy: 64.87%
#     Worker 2: Train Loss: 1.2550, Train Accuracy: 64.57%
#     Worker 3: Train Loss: 1.2850, Train Accuracy: 64.09%
# Total Computation Time: 3393.05 seconds
# Total Communication Time: 3.59 seconds
# Epoch 136/150: Test Loss: 1.9484, Test Accuracy: 51.44%
#     Worker 0: Train Loss: 1.2732, Train Accuracy: 63.74%
#     Worker 1: Train Loss: 1.2670, Train Accuracy: 64.57%
#     Worker 2: Train Loss: 1.2805, Train Accuracy: 63.63%
#     Worker 3: Train Loss: 1.2583, Train Accuracy: 64.34%
# Total Computation Time: 3417.77 seconds
# Total Communication Time: 3.62 seconds
# Epoch 137/150: Test Loss: 1.9464, Test Accuracy: 51.42%
#     Worker 0: Train Loss: 1.2508, Train Accuracy: 64.57%
#     Worker 1: Train Loss: 1.2472, Train Accuracy: 64.16%
#     Worker 2: Train Loss: 1.2736, Train Accuracy: 63.57%
#     Worker 3: Train Loss: 1.2765, Train Accuracy: 64.24%
# Total Computation Time: 3442.56 seconds
# Total Communication Time: 3.65 seconds
# Epoch 138/150: Test Loss: 1.9470, Test Accuracy: 51.39%
#     Worker 0: Train Loss: 1.2745, Train Accuracy: 63.88%
#     Worker 1: Train Loss: 1.2747, Train Accuracy: 64.60%
#     Worker 2: Train Loss: 1.2563, Train Accuracy: 64.70%
#     Worker 3: Train Loss: 1.2592, Train Accuracy: 64.82%
# Total Computation Time: 3467.29 seconds
# Total Communication Time: 3.67 seconds
# Epoch 139/150: Test Loss: 1.9464, Test Accuracy: 51.38%
#     Worker 0: Train Loss: 1.2653, Train Accuracy: 63.83%
#     Worker 1: Train Loss: 1.2537, Train Accuracy: 64.76%
#     Worker 2: Train Loss: 1.2827, Train Accuracy: 63.89%
#     Worker 3: Train Loss: 1.2590, Train Accuracy: 64.59%
# Total Computation Time: 3492.15 seconds
# Total Communication Time: 3.70 seconds
# Epoch 140/150: Test Loss: 1.9467, Test Accuracy: 51.59%
#     Worker 0: Train Loss: 1.2558, Train Accuracy: 63.80%
#     Worker 1: Train Loss: 1.2603, Train Accuracy: 64.39%
#     Worker 2: Train Loss: 1.2597, Train Accuracy: 64.40%
#     Worker 3: Train Loss: 1.2683, Train Accuracy: 64.15%
# Total Computation Time: 3516.89 seconds
# Total Communication Time: 3.73 seconds
# Epoch 141/150: Test Loss: 1.9473, Test Accuracy: 51.36%
#     Worker 0: Train Loss: 1.2625, Train Accuracy: 64.27%
#     Worker 1: Train Loss: 1.2615, Train Accuracy: 65.01%
#     Worker 2: Train Loss: 1.2558, Train Accuracy: 64.70%
#     Worker 3: Train Loss: 1.2631, Train Accuracy: 64.65%
# Total Computation Time: 3541.62 seconds
# Total Communication Time: 3.76 seconds
# Epoch 142/150: Test Loss: 1.9476, Test Accuracy: 51.39%
#     Worker 0: Train Loss: 1.2550, Train Accuracy: 64.04%
#     Worker 1: Train Loss: 1.2418, Train Accuracy: 64.92%
#     Worker 2: Train Loss: 1.2672, Train Accuracy: 64.18%
#     Worker 3: Train Loss: 1.2717, Train Accuracy: 64.36%
# Total Computation Time: 3566.46 seconds
# Total Communication Time: 3.78 seconds
# Epoch 143/150: Test Loss: 1.9469, Test Accuracy: 51.37%
#     Worker 0: Train Loss: 1.2557, Train Accuracy: 64.46%
#     Worker 1: Train Loss: 1.2706, Train Accuracy: 64.22%
#     Worker 2: Train Loss: 1.2458, Train Accuracy: 65.73%
#     Worker 3: Train Loss: 1.2821, Train Accuracy: 63.91%
# Total Computation Time: 3591.42 seconds
# Total Communication Time: 3.81 seconds
# Epoch 144/150: Test Loss: 1.9470, Test Accuracy: 51.39%
#     Worker 0: Train Loss: 1.2588, Train Accuracy: 63.85%
#     Worker 1: Train Loss: 1.2718, Train Accuracy: 64.53%
#     Worker 2: Train Loss: 1.2612, Train Accuracy: 64.29%
#     Worker 3: Train Loss: 1.2564, Train Accuracy: 64.73%
# Total Computation Time: 3616.24 seconds
# Total Communication Time: 3.83 seconds
# Epoch 145/150: Test Loss: 1.9468, Test Accuracy: 51.42%
#     Worker 0: Train Loss: 1.2511, Train Accuracy: 64.29%
#     Worker 1: Train Loss: 1.2542, Train Accuracy: 64.67%
#     Worker 2: Train Loss: 1.2682, Train Accuracy: 64.43%
#     Worker 3: Train Loss: 1.2635, Train Accuracy: 64.19%
# Total Computation Time: 3641.02 seconds
# Total Communication Time: 3.86 seconds
# Epoch 146/150: Test Loss: 1.9470, Test Accuracy: 51.41%
#     Worker 0: Train Loss: 1.2654, Train Accuracy: 64.16%
#     Worker 1: Train Loss: 1.2549, Train Accuracy: 64.72%
#     Worker 2: Train Loss: 1.2480, Train Accuracy: 65.13%
#     Worker 3: Train Loss: 1.2769, Train Accuracy: 64.42%
# Total Computation Time: 3665.89 seconds
# Total Communication Time: 3.89 seconds
# Epoch 147/150: Test Loss: 1.9471, Test Accuracy: 51.40%
#     Worker 0: Train Loss: 1.2512, Train Accuracy: 64.50%
#     Worker 1: Train Loss: 1.2526, Train Accuracy: 64.62%
#     Worker 2: Train Loss: 1.2539, Train Accuracy: 64.83%
#     Worker 3: Train Loss: 1.2680, Train Accuracy: 63.72%
# Total Computation Time: 3690.57 seconds
# Total Communication Time: 3.91 seconds
# Epoch 148/150: Test Loss: 1.9469, Test Accuracy: 51.42%
#     Worker 0: Train Loss: 1.2579, Train Accuracy: 64.13%
#     Worker 1: Train Loss: 1.2556, Train Accuracy: 64.72%
#     Worker 2: Train Loss: 1.2459, Train Accuracy: 64.56%
#     Worker 3: Train Loss: 1.2677, Train Accuracy: 64.57%
# Total Computation Time: 3715.43 seconds
# Total Communication Time: 3.94 seconds
# Epoch 149/150: Test Loss: 1.9470, Test Accuracy: 51.44%
#     Worker 0: Train Loss: 1.2663, Train Accuracy: 63.40%
#     Worker 1: Train Loss: 1.2541, Train Accuracy: 64.58%
#     Worker 2: Train Loss: 1.2563, Train Accuracy: 64.71%
#     Worker 3: Train Loss: 1.2771, Train Accuracy: 64.21%
# Total Computation Time: 3740.27 seconds
# Total Communication Time: 3.96 seconds
# Epoch 150/150: Test Loss: 1.9470, Test Accuracy: 51.45%
#     Worker 0: Train Loss: 1.2543, Train Accuracy: 63.99%
#     Worker 1: Train Loss: 1.2557, Train Accuracy: 64.61%
#     Worker 2: Train Loss: 1.2575, Train Accuracy: 64.24%
#     Worker 3: Train Loss: 1.2507, Train Accuracy: 65.16%
# Total Computation Time: 3765.07 seconds
# Total Communication Time: 3.99 seconds
