# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
# Alpha slow learning rate a=1 best
# Beta slow momentum
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
#warmup_epochs = 5

alpha = 0.8  # Slow learning rate scaling factor
beta = 0.4  # Slow momentum factor

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate for each k: {learning_rate:.5f}")
#lr_warmup=learning_rate
# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]


with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs) for optimizer in optimizers]

u_buffer = [torch.zeros_like(param) for param in nets[0].parameters()]  # Momentum buffer

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")
    #if epoch < warmup_epochs: #lr for buffer update during warmup
            #w_factor = (epoch + 1) / warmup_epochs
            #lr_warmup = w_factor * learning_rate
    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch): #outer loop

        #x(t,0)
        iter_params = [torch.zeros_like(param) for param in nets[0].parameters()]
        for param, g_param in zip(iter_params, nets[0].parameters()):
                    param.data.copy_(g_param)
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0

            # Perform J local step before synchronization
            for j in range(J): #inner loop
                      try:
                          # Get a batch from the current worker's shard using next()
                          images, labels = next(shard_iterators[k])
                          images, labels = images.to(device), labels.to(device)  # Move to device
                          optimizers[k].zero_grad()
                          outputs = nets[k](images)
                          loss = criterion(outputs, labels)
                          loss.backward()
                          optimizers[k].step()
                          # Calculate train loss and accuracy
                          train_loss += loss.item() * labels.size(0)
                          _, predicted = outputs.max(1)
                          total_train += labels.size(0)
                          correct_train += predicted.eq(labels).sum().item()

                      except StopIteration:
                          # If the iterator has exhausted the data, restart the iterator
                          shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                          images, labels = next(shard_iterators[k]) # Resume from the next batch
                          images, labels = images.to(device), labels.to(device)
                          # Perform optimization step
                          optimizers[k].zero_grad()
                          outputs = nets[k](images)
                          loss = criterion(outputs, labels)
                          loss.backward()
                          optimizers[k].step()
                          # Calculate train loss and accuracy
                          train_loss += loss.item() * labels.size(0)
                          _, predicted = outputs.max(1)
                          total_train += labels.size(0)
                          correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train


         # Synchronization (SLOWMO Algothm 1 - paper 21)
        with torch.no_grad():
            global_params = [torch.zeros_like(param) for param in nets[0].parameters()]
            #x(t, tau)
            for net in nets:
                for global_param, local_param in zip(global_params, net.parameters()):
                    global_param += local_param
            for global_param in global_params:
                global_param /= K

            for param, g_param, u_param in zip(iter_params, global_params, u_buffer):
                #if epoch < warmup_epochs:
                  #  u_param.mul_(beta).add_((param - g_param) / lr_warmup)
                 #   g_param.sub_(alpha * lr_warmup * u_param)

                #else: #Sync after warmup
                    #print(f"{optimizers[0].param_groups[0]['lr']}  {optimizers[1].param_groups[0]['lr']}")
                    lr_sched = optimizers[0].param_groups[0]['lr'] #optimizer lr
                    u_param.mul_(beta).add_((param - g_param) / lr_sched)
                    #g_param.sub_(alpha * lr_sched * u_param)
                    g_param.copy_(param - alpha * lr_sched * u_param)

            for net in nets:
                for param, g_param in zip(net.parameters(), global_params):
                    param.data.copy_(g_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        #if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
        #else:
         #   warmup_factor = (epoch + 1) / warmup_epochs
          #  lr = warmup_factor * learning_rate
           # for optimizer in optimizers:
            #    for param_group in optimizer.param_groups:
             #       param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 4 --j 16
# Out:
# Training with K=4, J=16
# Global iteration per epoch: 13
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:04<00:00, 34.7MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate for each k: 0.00400
# Epoch 1/150: Test Loss: 4.5636, Test Accuracy: 3.15%
#     Worker 0: Train Loss: 4.5959, Train Accuracy: 1.50%
#     Worker 1: Train Loss: 4.5960, Train Accuracy: 1.44%
#     Worker 2: Train Loss: 4.5953, Train Accuracy: 1.48%
#     Worker 3: Train Loss: 4.5967, Train Accuracy: 1.43%
# Epoch 2/150: Test Loss: 4.0839, Test Accuracy: 7.77%
#     Worker 0: Train Loss: 4.3715, Train Accuracy: 4.01%
#     Worker 1: Train Loss: 4.3765, Train Accuracy: 4.20%
#     Worker 2: Train Loss: 4.3571, Train Accuracy: 4.58%
#     Worker 3: Train Loss: 4.3725, Train Accuracy: 4.48%
# Epoch 3/150: Test Loss: 3.8701, Test Accuracy: 10.98%
#     Worker 0: Train Loss: 4.0399, Train Accuracy: 7.79%
#     Worker 1: Train Loss: 4.0485, Train Accuracy: 7.57%
#     Worker 2: Train Loss: 4.0166, Train Accuracy: 8.15%
#     Worker 3: Train Loss: 4.0470, Train Accuracy: 7.48%
# Epoch 4/150: Test Loss: 3.7249, Test Accuracy: 13.46%
#     Worker 0: Train Loss: 3.8714, Train Accuracy: 10.45%
#     Worker 1: Train Loss: 3.8794, Train Accuracy: 10.60%
#     Worker 2: Train Loss: 3.8215, Train Accuracy: 11.49%
#     Worker 3: Train Loss: 3.8635, Train Accuracy: 10.52%
# Epoch 5/150: Test Loss: 3.5502, Test Accuracy: 16.89%
#     Worker 0: Train Loss: 3.7207, Train Accuracy: 12.93%
#     Worker 1: Train Loss: 3.7359, Train Accuracy: 13.05%
#     Worker 2: Train Loss: 3.6866, Train Accuracy: 13.50%
#     Worker 3: Train Loss: 3.7233, Train Accuracy: 13.34%
# Epoch 6/150: Test Loss: 3.4367, Test Accuracy: 18.33%
#     Worker 0: Train Loss: 3.5950, Train Accuracy: 14.81%
#     Worker 1: Train Loss: 3.5976, Train Accuracy: 15.19%
#     Worker 2: Train Loss: 3.5524, Train Accuracy: 15.69%
#     Worker 3: Train Loss: 3.5987, Train Accuracy: 14.97%
# Epoch 7/150: Test Loss: 3.3237, Test Accuracy: 20.48%
#     Worker 0: Train Loss: 3.4945, Train Accuracy: 16.81%
#     Worker 1: Train Loss: 3.4836, Train Accuracy: 17.30%
#     Worker 2: Train Loss: 3.4420, Train Accuracy: 17.71%
#     Worker 3: Train Loss: 3.4798, Train Accuracy: 17.13%
# Epoch 8/150: Test Loss: 3.2015, Test Accuracy: 22.89%
#     Worker 0: Train Loss: 3.3830, Train Accuracy: 18.52%
#     Worker 1: Train Loss: 3.4111, Train Accuracy: 18.04%
#     Worker 2: Train Loss: 3.3268, Train Accuracy: 19.94%
#     Worker 3: Train Loss: 3.4155, Train Accuracy: 17.70%
# Epoch 9/150: Test Loss: 3.1135, Test Accuracy: 24.72%
#     Worker 0: Train Loss: 3.2674, Train Accuracy: 20.39%
#     Worker 1: Train Loss: 3.2995, Train Accuracy: 19.98%
#     Worker 2: Train Loss: 3.2406, Train Accuracy: 21.12%
#     Worker 3: Train Loss: 3.2882, Train Accuracy: 20.00%
#     Worker 3: Train Loss: 1.4633, Train Accuracy: 59.23%
# Epoch 72/150: Test Loss: 1.9482, Test Accuracy: 50.66%
#     Worker 0: Train Loss: 1.4578, Train Accuracy: 59.01%
#     Worker 1: Train Loss: 1.4647, Train Accuracy: 59.40%
#     Worker 2: Train Loss: 1.4569, Train Accuracy: 58.85%
#     Worker 3: Train Loss: 1.4601, Train Accuracy: 59.20%
# Epoch 73/150: Test Loss: 1.9391, Test Accuracy: 50.47%
#     Worker 0: Train Loss: 1.4375, Train Accuracy: 59.50%
#     Worker 1: Train Loss: 1.4478, Train Accuracy: 59.10%
#     Worker 2: Train Loss: 1.4198, Train Accuracy: 59.75%
#     Worker 3: Train Loss: 1.4433, Train Accuracy: 59.32%
# Epoch 74/150: Test Loss: 1.9573, Test Accuracy: 50.14%
#     Worker 0: Train Loss: 1.4016, Train Accuracy: 60.15%
#     Worker 1: Train Loss: 1.4252, Train Accuracy: 59.44%
#     Worker 2: Train Loss: 1.4215, Train Accuracy: 59.75%
#     Worker 3: Train Loss: 1.4391, Train Accuracy: 59.95%
# Epoch 75/150: Test Loss: 1.9382, Test Accuracy: 50.73%
#     Worker 0: Train Loss: 1.4386, Train Accuracy: 58.80%
#     Worker 1: Train Loss: 1.4428, Train Accuracy: 59.33%
#     Worker 2: Train Loss: 1.4090, Train Accuracy: 60.42%
#     Worker 3: Train Loss: 1.4060, Train Accuracy: 60.66%
# Epoch 76/150: Test Loss: 1.9408, Test Accuracy: 50.56%
#     Worker 0: Train Loss: 1.3956, Train Accuracy: 60.36%
#     Worker 1: Train Loss: 1.4012, Train Accuracy: 60.57%
#     Worker 2: Train Loss: 1.4064, Train Accuracy: 60.51%
#     Worker 3: Train Loss: 1.4028, Train Accuracy: 60.10%
# Epoch 77/150: Test Loss: 1.9478, Test Accuracy: 50.72%
#     Worker 0: Train Loss: 1.4050, Train Accuracy: 60.02%
#     Worker 1: Train Loss: 1.4039, Train Accuracy: 60.37%
#     Worker 2: Train Loss: 1.3802, Train Accuracy: 60.58%
#     Worker 3: Train Loss: 1.3970, Train Accuracy: 60.11%
# Epoch 78/150: Test Loss: 1.9506, Test Accuracy: 50.75%
#     Worker 0: Train Loss: 1.3868, Train Accuracy: 60.39%
#     Worker 1: Train Loss: 1.3688, Train Accuracy: 60.82%
#     Worker 2: Train Loss: 1.3767, Train Accuracy: 61.46%
#     Worker 3: Train Loss: 1.4076, Train Accuracy: 60.65%
# Epoch 79/150: Test Loss: 1.9451, Test Accuracy: 51.31%
#     Worker 0: Train Loss: 1.3637, Train Accuracy: 60.91%
#     Worker 1: Train Loss: 1.3762, Train Accuracy: 60.96%
#     Worker 2: Train Loss: 1.3480, Train Accuracy: 61.62%
#     Worker 3: Train Loss: 1.3796, Train Accuracy: 61.34%
# Epoch 80/150: Test Loss: 1.9300, Test Accuracy: 51.45%
#     Worker 0: Train Loss: 1.3535, Train Accuracy: 61.53%
#     Worker 1: Train Loss: 1.3561, Train Accuracy: 61.80%
#     Worker 1: Train Loss: 1.2506, Train Accuracy: 64.13%
#     Worker 2: Train Loss: 1.2552, Train Accuracy: 64.28%
#     Worker 3: Train Loss: 1.2694, Train Accuracy: 64.08%
# Epoch 90/150: Test Loss: 1.9667, Test Accuracy: 51.20%
#     Worker 0: Train Loss: 1.2593, Train Accuracy: 64.30%
#     Worker 1: Train Loss: 1.2618, Train Accuracy: 63.79%
#     Worker 2: Train Loss: 1.2509, Train Accuracy: 64.37%
#     Worker 3: Train Loss: 1.2569, Train Accuracy: 64.66%
# Epoch 91/150: Test Loss: 1.9708, Test Accuracy: 50.98%
#     Worker 0: Train Loss: 1.2528, Train Accuracy: 64.50%
#     Worker 1: Train Loss: 1.2483, Train Accuracy: 64.06%
#     Worker 2: Train Loss: 1.2373, Train Accuracy: 64.55%
#     Worker 3: Train Loss: 1.2470, Train Accuracy: 64.46%
# Epoch 92/150: Test Loss: 1.9706, Test Accuracy: 51.34%
#     Worker 0: Train Loss: 1.2334, Train Accuracy: 64.49%
#     Worker 1: Train Loss: 1.2539, Train Accuracy: 63.87%
#     Worker 2: Train Loss: 1.2483, Train Accuracy: 64.07%
#     Worker 3: Train Loss: 1.2207, Train Accuracy: 64.92%
# Epoch 93/150: Test Loss: 1.9622, Test Accuracy: 51.40%
#     Worker 0: Train Loss: 1.2190, Train Accuracy: 64.86%
#     Worker 1: Train Loss: 1.2277, Train Accuracy: 65.07%
#     Worker 2: Train Loss: 1.2081, Train Accuracy: 65.05%
#     Worker 3: Train Loss: 1.2371, Train Accuracy: 64.46%
# Epoch 94/150: Test Loss: 1.9804, Test Accuracy: 51.32%
#     Worker 0: Train Loss: 1.2089, Train Accuracy: 64.92%
#     Worker 1: Train Loss: 1.2096, Train Accuracy: 65.20%
#     Worker 2: Train Loss: 1.2110, Train Accuracy: 64.69%
#     Worker 3: Train Loss: 1.2119, Train Accuracy: 65.56%
# Epoch 95/150: Test Loss: 1.9771, Test Accuracy: 50.97%
#     Worker 0: Train Loss: 1.1900, Train Accuracy: 65.86%
#     Worker 1: Train Loss: 1.2057, Train Accuracy: 65.66%
#     Worker 2: Train Loss: 1.2111, Train Accuracy: 65.64%
#     Worker 3: Train Loss: 1.2162, Train Accuracy: 65.53%
# Epoch 96/150: Test Loss: 1.9805, Test Accuracy: 51.67%
#     Worker 0: Train Loss: 1.2042, Train Accuracy: 65.10%
#     Worker 1: Train Loss: 1.2189, Train Accuracy: 65.18%
#     Worker 2: Train Loss: 1.1813, Train Accuracy: 65.88%
#     Worker 3: Train Loss: 1.1904, Train Accuracy: 66.32%
# Epoch 97/150: Test Loss: 1.9708, Test Accuracy: 51.73%
#     Worker 0: Train Loss: 1.1880, Train Accuracy: 65.57%
#     Worker 1: Train Loss: 1.1841, Train Accuracy: 65.96%
#     Worker 2: Train Loss: 1.1899, Train Accuracy: 65.93%
#     Worker 3: Train Loss: 1.1784, Train Accuracy: 66.37%
# Epoch 98/150: Test Loss: 1.9748, Test Accuracy: 51.65%
# Epoch 107/150: Test Loss: 2.0011, Test Accuracy: 51.41%
#     Worker 0: Train Loss: 1.1191, Train Accuracy: 67.46%
#     Worker 1: Train Loss: 1.1190, Train Accuracy: 67.85%
#     Worker 2: Train Loss: 1.1138, Train Accuracy: 68.04%
#     Worker 3: Train Loss: 1.1172, Train Accuracy: 67.50%
# Epoch 108/150: Test Loss: 1.9874, Test Accuracy: 51.64%
#     Worker 0: Train Loss: 1.1035, Train Accuracy: 67.83%
#     Worker 1: Train Loss: 1.1047, Train Accuracy: 68.03%
#     Worker 2: Train Loss: 1.0865, Train Accuracy: 68.71%
#     Worker 3: Train Loss: 1.0916, Train Accuracy: 68.30%
# Epoch 109/150: Test Loss: 1.9927, Test Accuracy: 52.16%
#     Worker 0: Train Loss: 1.0840, Train Accuracy: 68.31%
#     Worker 1: Train Loss: 1.0909, Train Accuracy: 68.52%
#     Worker 2: Train Loss: 1.0824, Train Accuracy: 68.31%
#     Worker 3: Train Loss: 1.1096, Train Accuracy: 68.41%
# Epoch 110/150: Test Loss: 1.9976, Test Accuracy: 52.19%
#     Worker 0: Train Loss: 1.0864, Train Accuracy: 68.33%
#     Worker 1: Train Loss: 1.0964, Train Accuracy: 68.38%
#     Worker 2: Train Loss: 1.0852, Train Accuracy: 69.05%
#     Worker 3: Train Loss: 1.0970, Train Accuracy: 68.52%
# Epoch 111/150: Test Loss: 2.0190, Test Accuracy: 51.71%
#     Worker 0: Train Loss: 1.0628, Train Accuracy: 68.95%
#     Worker 1: Train Loss: 1.0814, Train Accuracy: 68.74%
#     Worker 2: Train Loss: 1.0609, Train Accuracy: 69.15%
#     Worker 3: Train Loss: 1.0853, Train Accuracy: 68.83%
# Epoch 112/150: Test Loss: 1.9998, Test Accuracy: 52.11%
#     Worker 0: Train Loss: 1.0696, Train Accuracy: 68.65%
#     Worker 1: Train Loss: 1.0778, Train Accuracy: 68.68%
#     Worker 2: Train Loss: 1.0852, Train Accuracy: 68.83%
#     Worker 3: Train Loss: 1.0764, Train Accuracy: 69.19%
# Epoch 113/150: Test Loss: 2.0006, Test Accuracy: 51.79%
#     Worker 0: Train Loss: 1.0709, Train Accuracy: 68.60%
#     Worker 1: Train Loss: 1.0692, Train Accuracy: 68.98%
#     Worker 2: Train Loss: 1.0610, Train Accuracy: 69.14%
#     Worker 3: Train Loss: 1.0662, Train Accuracy: 69.48%
# Epoch 114/150: Test Loss: 2.0083, Test Accuracy: 51.80%
#     Worker 0: Train Loss: 1.0543, Train Accuracy: 69.05%
#     Worker 1: Train Loss: 1.0726, Train Accuracy: 69.09%
#     Worker 2: Train Loss: 1.0566, Train Accuracy: 69.88%
#     Worker 3: Train Loss: 1.0584, Train Accuracy: 69.54%
# Epoch 115/150: Test Loss: 2.0058, Test Accuracy: 52.06%
#     Worker 0: Train Loss: 1.0480, Train Accuracy: 68.78%
#     Worker 1: Train Loss: 1.0401, Train Accuracy: 69.67%
#     Worker 2: Train Loss: 1.0458, Train Accuracy: 70.02%
#     Worker 3: Train Loss: 1.0472, Train Accuracy: 69.93%
# Epoch 116/150: Test Loss: 2.0131, Test Accuracy: 52.20%
#     Worker 0: Train Loss: 1.0511, Train Accuracy: 69.40%
#     Worker 1: Train Loss: 1.0491, Train Accuracy: 69.63%
#     Worker 2: Train Loss: 1.0401, Train Accuracy: 70.33%
#     Worker 3: Train Loss: 1.0446, Train Accuracy: 69.76%
# Epoch 117/150: Test Loss: 2.0070, Test Accuracy: 51.81%
#     Worker 0: Train Loss: 1.0337, Train Accuracy: 70.27%
#     Worker 1: Train Loss: 1.0330, Train Accuracy: 70.00%
#     Worker 2: Train Loss: 1.0273, Train Accuracy: 70.15%
#     Worker 3: Train Loss: 1.0556, Train Accuracy: 69.51%
# Epoch 118/150: Test Loss: 2.0157, Test Accuracy: 52.21%
#     Worker 0: Train Loss: 1.0359, Train Accuracy: 69.50%
#     Worker 1: Train Loss: 1.0411, Train Accuracy: 69.48%
#     Worker 2: Train Loss: 1.0249, Train Accuracy: 70.62%
#     Worker 3: Train Loss: 1.0462, Train Accuracy: 69.91%
# Epoch 119/150: Test Loss: 2.0194, Test Accuracy: 52.24%
#     Worker 0: Train Loss: 1.0235, Train Accuracy: 70.12%
#     Worker 1: Train Loss: 1.0253, Train Accuracy: 70.29%
#     Worker 2: Train Loss: 1.0221, Train Accuracy: 70.49%
#     Worker 3: Train Loss: 1.0264, Train Accuracy: 70.13%
# Epoch 120/150: Test Loss: 2.0160, Test Accuracy: 52.23%
#     Worker 0: Train Loss: 1.0289, Train Accuracy: 70.15%
#     Worker 1: Train Loss: 1.0250, Train Accuracy: 70.34%
#     Worker 2: Train Loss: 1.0244, Train Accuracy: 70.49%
#     Worker 3: Train Loss: 1.0309, Train Accuracy: 70.73%
# Epoch 121/150: Test Loss: 2.0181, Test Accuracy: 51.89%
#     Worker 0: Train Loss: 1.0210, Train Accuracy: 70.06%
#     Worker 1: Train Loss: 1.0206, Train Accuracy: 70.30%
#     Worker 2: Train Loss: 0.9996, Train Accuracy: 70.77%
#     Worker 3: Train Loss: 1.0091, Train Accuracy: 70.96%
# Epoch 122/150: Test Loss: 2.0209, Test Accuracy: 51.98%
#     Worker 0: Train Loss: 1.0105, Train Accuracy: 71.02%
#     Worker 1: Train Loss: 1.0150, Train Accuracy: 70.84%
#     Worker 2: Train Loss: 1.0266, Train Accuracy: 70.19%
#     Worker 3: Train Loss: 1.0062, Train Accuracy: 70.86%
# Epoch 123/150: Test Loss: 2.0246, Test Accuracy: 51.94%
#     Worker 0: Train Loss: 1.0236, Train Accuracy: 70.48%
#     Worker 1: Train Loss: 1.0110, Train Accuracy: 70.91%
#     Worker 2: Train Loss: 1.0083, Train Accuracy: 70.99%
#     Worker 3: Train Loss: 1.0219, Train Accuracy: 70.44%
# Epoch 124/150: Test Loss: 2.0238, Test Accuracy: 52.12%
#     Worker 0: Train Loss: 0.9944, Train Accuracy: 71.34%
#     Worker 1: Train Loss: 1.0138, Train Accuracy: 70.21%
#     Worker 1: Train Loss: 0.9817, Train Accuracy: 71.59%
#     Worker 2: Train Loss: 0.9798, Train Accuracy: 71.64%
#     Worker 3: Train Loss: 0.9742, Train Accuracy: 71.84%
# Epoch 134/150: Test Loss: 2.0316, Test Accuracy: 52.25%
#     Worker 0: Train Loss: 0.9750, Train Accuracy: 71.61%
#     Worker 1: Train Loss: 0.9649, Train Accuracy: 72.09%
#     Worker 2: Train Loss: 0.9657, Train Accuracy: 72.60%
#     Worker 3: Train Loss: 0.9877, Train Accuracy: 71.65%
# Epoch 135/150: Test Loss: 2.0334, Test Accuracy: 52.51%
#     Worker 0: Train Loss: 0.9716, Train Accuracy: 71.56%
#     Worker 1: Train Loss: 0.9724, Train Accuracy: 72.12%
#     Worker 2: Train Loss: 0.9522, Train Accuracy: 72.39%
#     Worker 3: Train Loss: 0.9781, Train Accuracy: 71.93%
# Epoch 136/150: Test Loss: 2.0348, Test Accuracy: 52.28%
#     Worker 0: Train Loss: 0.9801, Train Accuracy: 71.31%
#     Worker 1: Train Loss: 0.9690, Train Accuracy: 71.77%
#     Worker 2: Train Loss: 0.9835, Train Accuracy: 71.71%
#     Worker 3: Train Loss: 0.9546, Train Accuracy: 72.21%
# Epoch 137/150: Test Loss: 2.0325, Test Accuracy: 52.17%
#     Worker 0: Train Loss: 0.9475, Train Accuracy: 72.66%
#     Worker 1: Train Loss: 0.9552, Train Accuracy: 71.89%
#     Worker 2: Train Loss: 0.9833, Train Accuracy: 71.92%
#     Worker 3: Train Loss: 0.9782, Train Accuracy: 71.99%
# Epoch 138/150: Test Loss: 2.0330, Test Accuracy: 52.29%
#     Worker 0: Train Loss: 0.9765, Train Accuracy: 71.43%
#     Worker 1: Train Loss: 0.9773, Train Accuracy: 71.71%
#     Worker 2: Train Loss: 0.9554, Train Accuracy: 72.84%
#     Worker 3: Train Loss: 0.9516, Train Accuracy: 72.55%
# Epoch 139/150: Test Loss: 2.0304, Test Accuracy: 52.18%
#     Worker 0: Train Loss: 0.9616, Train Accuracy: 72.05%
#     Worker 1: Train Loss: 0.9504, Train Accuracy: 72.57%
#     Worker 2: Train Loss: 0.9776, Train Accuracy: 71.80%
#     Worker 3: Train Loss: 0.9671, Train Accuracy: 72.23%
# Epoch 140/150: Test Loss: 2.0310, Test Accuracy: 52.18%
#     Worker 0: Train Loss: 0.9540, Train Accuracy: 71.98%
#     Worker 1: Train Loss: 0.9631, Train Accuracy: 71.90%
#     Worker 2: Train Loss: 0.9648, Train Accuracy: 72.31%
#     Worker 3: Train Loss: 0.9596, Train Accuracy: 72.34%
# Epoch 141/150: Test Loss: 2.0330, Test Accuracy: 52.32%
#     Worker 0: Train Loss: 0.9744, Train Accuracy: 71.65%
#     Worker 1: Train Loss: 0.9635, Train Accuracy: 72.22%
#     Worker 2: Train Loss: 0.9657, Train Accuracy: 72.17%
#     Worker 3: Train Loss: 0.9617, Train Accuracy: 72.56%
# Epoch 142/150: Test Loss: 2.0330, Test Accuracy: 52.29%
#     Worker 0: Train Loss: 0.9575, Train Accuracy: 71.91%
#     Worker 1: Train Loss: 0.9509, Train Accuracy: 72.29%
#     Worker 2: Train Loss: 0.9629, Train Accuracy: 72.35%
#     Worker 3: Train Loss: 0.9707, Train Accuracy: 72.25%
# Epoch 143/150: Test Loss: 2.0321, Test Accuracy: 52.14%
#     Worker 0: Train Loss: 0.9582, Train Accuracy: 72.41%
#     Worker 1: Train Loss: 0.9696, Train Accuracy: 72.27%
#     Worker 2: Train Loss: 0.9531, Train Accuracy: 72.59%
#     Worker 3: Train Loss: 0.9753, Train Accuracy: 71.75%
# Epoch 144/150: Test Loss: 2.0327, Test Accuracy: 52.27%
#     Worker 0: Train Loss: 0.9620, Train Accuracy: 71.83%
#     Worker 1: Train Loss: 0.9686, Train Accuracy: 71.93%
#     Worker 2: Train Loss: 0.9643, Train Accuracy: 72.40%
#     Worker 3: Train Loss: 0.9554, Train Accuracy: 72.33%
# Epoch 145/150: Test Loss: 2.0333, Test Accuracy: 52.24%
#     Worker 0: Train Loss: 0.9492, Train Accuracy: 72.28%
#     Worker 1: Train Loss: 0.9574, Train Accuracy: 72.57%
#     Worker 2: Train Loss: 0.9664, Train Accuracy: 72.18%
#     Worker 3: Train Loss: 0.9658, Train Accuracy: 71.96%
# Epoch 146/150: Test Loss: 2.0330, Test Accuracy: 52.23%
#     Worker 0: Train Loss: 0.9643, Train Accuracy: 71.62%
#     Worker 1: Train Loss: 0.9555, Train Accuracy: 72.15%
#     Worker 2: Train Loss: 0.9507, Train Accuracy: 72.83%
#     Worker 3: Train Loss: 0.9646, Train Accuracy: 72.26%
# Epoch 147/150: Test Loss: 2.0334, Test Accuracy: 52.29%
#     Worker 0: Train Loss: 0.9501, Train Accuracy: 72.47%
#     Worker 1: Train Loss: 0.9547, Train Accuracy: 72.22%
#     Worker 2: Train Loss: 0.9472, Train Accuracy: 72.84%
#     Worker 3: Train Loss: 0.9564, Train Accuracy: 72.45%
# Epoch 148/150: Test Loss: 2.0334, Test Accuracy: 52.24%
#     Worker 0: Train Loss: 0.9535, Train Accuracy: 72.11%
#     Worker 1: Train Loss: 0.9601, Train Accuracy: 72.55%
#     Worker 2: Train Loss: 0.9504, Train Accuracy: 72.51%
#     Worker 3: Train Loss: 0.9636, Train Accuracy: 72.38%
# Epoch 149/150: Test Loss: 2.0333, Test Accuracy: 52.25%
#     Worker 0: Train Loss: 0.9677, Train Accuracy: 71.80%
#     Worker 1: Train Loss: 0.9595, Train Accuracy: 72.08%
#     Worker 2: Train Loss: 0.9512, Train Accuracy: 72.60%
#     Worker 3: Train Loss: 0.9593, Train Accuracy: 72.61%
# Epoch 150/150: Test Loss: 2.0334, Test Accuracy: 52.24%
#     Worker 0: Train Loss: 0.9605, Train Accuracy: 71.61%
#     Worker 1: Train Loss: 0.9526, Train Accuracy: 72.35%
#     Worker 2: Train Loss: 0.9548, Train Accuracy: 72.54%
#     Worker 3: Train Loss: 0.9365, Train Accuracy: 73.09%
