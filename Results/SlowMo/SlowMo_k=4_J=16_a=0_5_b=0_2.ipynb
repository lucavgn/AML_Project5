# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
# Alpha slow learning rate a=1 best
# Beta slow momentum
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
#warmup_epochs = 5

alpha = 0.5  # Slow learning rate scaling factor
beta = 0.2  # Slow momentum factor

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate for each k: {learning_rate:.5f}")
#lr_warmup=learning_rate
# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]


with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs) for optimizer in optimizers]

u_buffer = [torch.zeros_like(param) for param in nets[0].parameters()]  # Momentum buffer

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")
    #if epoch < warmup_epochs: #lr for buffer update during warmup
            #w_factor = (epoch + 1) / warmup_epochs
            #lr_warmup = w_factor * learning_rate
    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch): #outer loop

        #x(t,0)
        iter_params = [torch.zeros_like(param) for param in nets[0].parameters()]
        for param, g_param in zip(iter_params, nets[0].parameters()):
                    param.data.copy_(g_param)
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0

            # Perform J local step before synchronization
            for j in range(J): #inner loop
                      try:
                          # Get a batch from the current worker's shard using next()
                          images, labels = next(shard_iterators[k])
                          images, labels = images.to(device), labels.to(device)  # Move to device
                          optimizers[k].zero_grad()
                          outputs = nets[k](images)
                          loss = criterion(outputs, labels)
                          loss.backward()
                          optimizers[k].step()
                          # Calculate train loss and accuracy
                          train_loss += loss.item() * labels.size(0)
                          _, predicted = outputs.max(1)
                          total_train += labels.size(0)
                          correct_train += predicted.eq(labels).sum().item()

                      except StopIteration:
                          # If the iterator has exhausted the data, restart the iterator
                          shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                          images, labels = next(shard_iterators[k]) # Resume from the next batch
                          images, labels = images.to(device), labels.to(device)
                          # Perform optimization step
                          optimizers[k].zero_grad()
                          outputs = nets[k](images)
                          loss = criterion(outputs, labels)
                          loss.backward()
                          optimizers[k].step()
                          # Calculate train loss and accuracy
                          train_loss += loss.item() * labels.size(0)
                          _, predicted = outputs.max(1)
                          total_train += labels.size(0)
                          correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train


         # Synchronization (SLOWMO Algothm 1 - paper 21)
        with torch.no_grad():
            global_params = [torch.zeros_like(param) for param in nets[0].parameters()]
            #x(t, tau)
            for net in nets:
                for global_param, local_param in zip(global_params, net.parameters()):
                    global_param += local_param
            for global_param in global_params:
                global_param /= K

            for param, g_param, u_param in zip(iter_params, global_params, u_buffer):
                #if epoch < warmup_epochs:
                  #  u_param.mul_(beta).add_((param - g_param) / lr_warmup)
                 #   g_param.sub_(alpha * lr_warmup * u_param)

                #else: #Sync after warmup
                    #print(f"{optimizers[0].param_groups[0]['lr']}  {optimizers[1].param_groups[0]['lr']}")
                    lr_sched = optimizers[0].param_groups[0]['lr'] #optimizer lr
                    u_param.mul_(beta).add_((param - g_param) / lr_sched)
                    #g_param.sub_(alpha * lr_sched * u_param)
                    g_param.copy_(param - alpha * lr_sched * u_param)

            for net in nets:
                for param, g_param in zip(net.parameters(), global_params):
                    param.data.copy_(g_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        #if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
        #else:
         #   warmup_factor = (epoch + 1) / warmup_epochs
          #  lr = warmup_factor * learning_rate
           # for optimizer in optimizers:
            #    for param_group in optimizer.param_groups:
             #       param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 4 --j 16
# Out:
# Training with K=4, J=16
# Global iteration per epoch: 13
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# Epoch 63/150: Test Loss: 2.1858, Test Accuracy: 43.47%
#     Worker 0: Train Loss: 2.1799, Train Accuracy: 42.58%
#     Worker 1: Train Loss: 2.1871, Train Accuracy: 42.61%
#     Worker 2: Train Loss: 2.1558, Train Accuracy: 43.28%
#     Worker 3: Train Loss: 2.1968, Train Accuracy: 42.12%
# Epoch 64/150: Test Loss: 2.1770, Test Accuracy: 43.47%
#     Worker 0: Train Loss: 2.1647, Train Accuracy: 42.89%
#     Worker 1: Train Loss: 2.1860, Train Accuracy: 42.50%
#     Worker 2: Train Loss: 2.1508, Train Accuracy: 43.28%
#     Worker 3: Train Loss: 2.1701, Train Accuracy: 42.67%
# Epoch 65/150: Test Loss: 2.1715, Test Accuracy: 43.49%
#     Worker 0: Train Loss: 2.1479, Train Accuracy: 43.03%
#     Worker 1: Train Loss: 2.1401, Train Accuracy: 43.53%
#     Worker 2: Train Loss: 2.1278, Train Accuracy: 43.95%
#     Worker 3: Train Loss: 2.1513, Train Accuracy: 42.99%
# Epoch 66/150: Test Loss: 2.1592, Test Accuracy: 43.90%
#     Worker 0: Train Loss: 2.1370, Train Accuracy: 43.80%
#     Worker 1: Train Loss: 2.1420, Train Accuracy: 43.29%
#     Worker 2: Train Loss: 2.1144, Train Accuracy: 43.78%
#     Worker 3: Train Loss: 2.1427, Train Accuracy: 43.43%
# Epoch 67/150: Test Loss: 2.1573, Test Accuracy: 43.39%
#     Worker 0: Train Loss: 2.1316, Train Accuracy: 43.33%
#     Worker 1: Train Loss: 2.1327, Train Accuracy: 43.90%
#     Worker 2: Train Loss: 2.1141, Train Accuracy: 44.41%
#     Worker 3: Train Loss: 2.1363, Train Accuracy: 43.61%
# Epoch 68/150: Test Loss: 2.1584, Test Accuracy: 43.75%
#     Worker 0: Train Loss: 2.1086, Train Accuracy: 43.47%
#     Worker 1: Train Loss: 2.1249, Train Accuracy: 43.67%
#     Worker 2: Train Loss: 2.1002, Train Accuracy: 44.17%
#     Worker 3: Train Loss: 2.1310, Train Accuracy: 43.18%
# Epoch 69/150: Test Loss: 2.1516, Test Accuracy: 43.73%
#     Worker 0: Train Loss: 2.1156, Train Accuracy: 43.54%
#     Worker 1: Train Loss: 2.1065, Train Accuracy: 44.35%
#     Worker 2: Train Loss: 2.0640, Train Accuracy: 44.69%
#     Worker 3: Train Loss: 2.1130, Train Accuracy: 43.74%
# Epoch 70/150: Test Loss: 2.1394, Test Accuracy: 44.07%
#     Worker 0: Train Loss: 2.0925, Train Accuracy: 44.26%
#     Worker 1: Train Loss: 2.0758, Train Accuracy: 44.87%
#     Worker 2: Train Loss: 2.0753, Train Accuracy: 45.25%
#     Worker 3: Train Loss: 2.1165, Train Accuracy: 43.82%
# Epoch 71/150: Test Loss: 2.1354, Test Accuracy: 44.07%
#     Worker 0: Train Loss: 2.0866, Train Accuracy: 44.32%
#     Worker 1: Train Loss: 2.1035, Train Accuracy: 44.48%
#     Worker 2: Train Loss: 2.0497, Train Accuracy: 45.77%
#     Worker 2: Train Loss: 1.9787, Train Accuracy: 46.75%
#     Worker 3: Train Loss: 1.9861, Train Accuracy: 47.02%
# Epoch 81/150: Test Loss: 2.0869, Test Accuracy: 45.63%
#     Worker 0: Train Loss: 1.9791, Train Accuracy: 47.20%
#     Worker 1: Train Loss: 1.9875, Train Accuracy: 47.03%
#     Worker 2: Train Loss: 1.9497, Train Accuracy: 48.04%
#     Worker 3: Train Loss: 1.9740, Train Accuracy: 47.62%
# Epoch 82/150: Test Loss: 2.0833, Test Accuracy: 45.42%
#     Worker 0: Train Loss: 1.9692, Train Accuracy: 47.53%
#     Worker 1: Train Loss: 1.9659, Train Accuracy: 47.32%
#     Worker 2: Train Loss: 1.9593, Train Accuracy: 48.14%
#     Worker 3: Train Loss: 1.9617, Train Accuracy: 47.53%
# Epoch 83/150: Test Loss: 2.0776, Test Accuracy: 45.76%
#     Worker 0: Train Loss: 1.9555, Train Accuracy: 47.28%
#     Worker 1: Train Loss: 1.9505, Train Accuracy: 48.05%
#     Worker 2: Train Loss: 1.9381, Train Accuracy: 48.34%
#     Worker 3: Train Loss: 1.9715, Train Accuracy: 47.02%
# Epoch 84/150: Test Loss: 2.0770, Test Accuracy: 46.25%
#     Worker 0: Train Loss: 1.9530, Train Accuracy: 47.32%
#     Worker 1: Train Loss: 1.9398, Train Accuracy: 47.66%
#     Worker 2: Train Loss: 1.9293, Train Accuracy: 48.54%
#     Worker 3: Train Loss: 1.9495, Train Accuracy: 47.82%
# Epoch 85/150: Test Loss: 2.0791, Test Accuracy: 46.13%
#     Worker 0: Train Loss: 1.9383, Train Accuracy: 47.65%
#     Worker 1: Train Loss: 1.9350, Train Accuracy: 47.92%
#     Worker 2: Train Loss: 1.9169, Train Accuracy: 49.19%
#     Worker 3: Train Loss: 1.9282, Train Accuracy: 48.18%
# Epoch 86/150: Test Loss: 2.0672, Test Accuracy: 46.10%
#     Worker 0: Train Loss: 1.9192, Train Accuracy: 48.27%
#     Worker 1: Train Loss: 1.9469, Train Accuracy: 47.77%
#     Worker 2: Train Loss: 1.9076, Train Accuracy: 49.24%
#     Worker 3: Train Loss: 1.9290, Train Accuracy: 48.52%
# Epoch 87/150: Test Loss: 2.0677, Test Accuracy: 45.97%
#     Worker 0: Train Loss: 1.9283, Train Accuracy: 48.18%
#     Worker 1: Train Loss: 1.9063, Train Accuracy: 48.81%
#     Worker 2: Train Loss: 1.9042, Train Accuracy: 48.88%
#     Worker 3: Train Loss: 1.9374, Train Accuracy: 48.25%
# Epoch 88/150: Test Loss: 2.0652, Test Accuracy: 46.24%
#     Worker 0: Train Loss: 1.9027, Train Accuracy: 48.62%
#     Worker 1: Train Loss: 1.9301, Train Accuracy: 48.25%
#     Worker 2: Train Loss: 1.8923, Train Accuracy: 49.62%
#     Worker 3: Train Loss: 1.9098, Train Accuracy: 48.51%
# Epoch 89/150: Test Loss: 2.0611, Test Accuracy: 46.46%
#     Worker 0: Train Loss: 1.8975, Train Accuracy: 48.43%
#     Worker 1: Train Loss: 1.8855, Train Accuracy: 49.71%
#     Worker 2: Train Loss: 1.8912, Train Accuracy: 49.17%
#     Worker 3: Train Loss: 1.9105, Train Accuracy: 49.15%
# Epoch 90/150: Test Loss: 2.0675, Test Accuracy: 46.52%
#     Worker 0: Train Loss: 1.8958, Train Accuracy: 49.22%
#     Worker 1: Train Loss: 1.8975, Train Accuracy: 48.86%
#     Worker 2: Train Loss: 1.8831, Train Accuracy: 49.74%
#     Worker 3: Train Loss: 1.9010, Train Accuracy: 48.90%
# Epoch 91/150: Test Loss: 2.0556, Test Accuracy: 46.71%
#     Worker 0: Train Loss: 1.8917, Train Accuracy: 49.07%
#     Worker 1: Train Loss: 1.8795, Train Accuracy: 48.98%
#     Worker 2: Train Loss: 1.8833, Train Accuracy: 49.21%
#     Worker 3: Train Loss: 1.8915, Train Accuracy: 48.95%
# Epoch 92/150: Test Loss: 2.0525, Test Accuracy: 46.96%
#     Worker 0: Train Loss: 1.8663, Train Accuracy: 49.74%
#     Worker 1: Train Loss: 1.8937, Train Accuracy: 48.84%
#     Worker 2: Train Loss: 1.8769, Train Accuracy: 50.23%
#     Worker 3: Train Loss: 1.8658, Train Accuracy: 49.37%
# Epoch 93/150: Test Loss: 2.0551, Test Accuracy: 46.58%
#     Worker 0: Train Loss: 1.8542, Train Accuracy: 49.62%
#     Worker 1: Train Loss: 1.8622, Train Accuracy: 49.81%
#     Worker 2: Train Loss: 1.8395, Train Accuracy: 50.40%
#     Worker 3: Train Loss: 1.8733, Train Accuracy: 49.97%
# Epoch 94/150: Test Loss: 2.0521, Test Accuracy: 46.79%
#     Worker 0: Train Loss: 1.8534, Train Accuracy: 49.86%
#     Worker 1: Train Loss: 1.8691, Train Accuracy: 49.34%
#     Worker 2: Train Loss: 1.8423, Train Accuracy: 49.78%
#     Worker 3: Train Loss: 1.8700, Train Accuracy: 49.29%
# Epoch 95/150: Test Loss: 2.0545, Test Accuracy: 46.69%
#     Worker 0: Train Loss: 1.8266, Train Accuracy: 50.72%
#     Worker 1: Train Loss: 1.8515, Train Accuracy: 50.36%
#     Worker 2: Train Loss: 1.8398, Train Accuracy: 50.20%
#     Worker 3: Train Loss: 1.8658, Train Accuracy: 49.77%
# Epoch 96/150: Test Loss: 2.0448, Test Accuracy: 46.75%
#     Worker 0: Train Loss: 1.8412, Train Accuracy: 49.75%
#     Worker 1: Train Loss: 1.8625, Train Accuracy: 50.18%
#     Worker 2: Train Loss: 1.8253, Train Accuracy: 50.51%
#     Worker 3: Train Loss: 1.8436, Train Accuracy: 49.92%
# Epoch 97/150: Test Loss: 2.0447, Test Accuracy: 46.77%
#     Worker 0: Train Loss: 1.8340, Train Accuracy: 50.56%
#     Worker 1: Train Loss: 1.8384, Train Accuracy: 50.28%
#     Worker 2: Train Loss: 1.8192, Train Accuracy: 51.30%
#     Worker 3: Train Loss: 1.8160, Train Accuracy: 50.74%
# Epoch 98/150: Test Loss: 2.0403, Test Accuracy: 47.18%
#     Worker 0: Train Loss: 1.8230, Train Accuracy: 50.24%
#     Worker 1: Train Loss: 1.8376, Train Accuracy: 50.54%
#     Worker 2: Train Loss: 1.8093, Train Accuracy: 51.23%
#     Worker 3: Train Loss: 1.8403, Train Accuracy: 50.08%
# Epoch 99/150: Test Loss: 2.0403, Test Accuracy: 46.83%
#     Worker 0: Train Loss: 1.8356, Train Accuracy: 50.62%
#     Worker 1: Train Loss: 1.8146, Train Accuracy: 50.80%
#     Worker 2: Train Loss: 1.8013, Train Accuracy: 51.91%
#     Worker 3: Train Loss: 1.8268, Train Accuracy: 50.82%
# Epoch 100/150: Test Loss: 2.0421, Test Accuracy: 47.21%
#     Worker 0: Train Loss: 1.8011, Train Accuracy: 51.25%
#     Worker 1: Train Loss: 1.8114, Train Accuracy: 50.75%
#     Worker 2: Train Loss: 1.7886, Train Accuracy: 51.88%
#     Worker 3: Train Loss: 1.8348, Train Accuracy: 50.54%
# Epoch 101/150: Test Loss: 2.0340, Test Accuracy: 47.18%
#     Worker 0: Train Loss: 1.8039, Train Accuracy: 51.09%
#     Worker 1: Train Loss: 1.8211, Train Accuracy: 50.62%
#     Worker 2: Train Loss: 1.7917, Train Accuracy: 51.13%
#     Worker 3: Train Loss: 1.8040, Train Accuracy: 50.96%
# Epoch 102/150: Test Loss: 2.0348, Test Accuracy: 47.30%
#     Worker 0: Train Loss: 1.7871, Train Accuracy: 51.69%
#     Worker 1: Train Loss: 1.8010, Train Accuracy: 51.27%
#     Worker 2: Train Loss: 1.7772, Train Accuracy: 52.35%
#     Worker 3: Train Loss: 1.8157, Train Accuracy: 51.08%
# Epoch 103/150: Test Loss: 2.0301, Test Accuracy: 47.41%
#     Worker 0: Train Loss: 1.7935, Train Accuracy: 51.10%
#     Worker 1: Train Loss: 1.7770, Train Accuracy: 51.94%
#     Worker 2: Train Loss: 1.7847, Train Accuracy: 51.54%
#     Worker 3: Train Loss: 1.7990, Train Accuracy: 51.39%
# Epoch 104/150: Test Loss: 2.0326, Test Accuracy: 47.30%
#     Worker 0: Train Loss: 1.7714, Train Accuracy: 51.95%
#     Worker 1: Train Loss: 1.7956, Train Accuracy: 51.51%
#     Worker 2: Train Loss: 1.7800, Train Accuracy: 51.82%
#     Worker 3: Train Loss: 1.7853, Train Accuracy: 52.24%
# Epoch 105/150: Test Loss: 2.0287, Test Accuracy: 47.43%
#     Worker 0: Train Loss: 1.7950, Train Accuracy: 51.66%
#     Worker 1: Train Loss: 1.7765, Train Accuracy: 52.07%
#     Worker 2: Train Loss: 1.7679, Train Accuracy: 52.45%
#     Worker 3: Train Loss: 1.8057, Train Accuracy: 50.66%
# Epoch 106/150: Test Loss: 2.0287, Test Accuracy: 47.25%
#     Worker 0: Train Loss: 1.7599, Train Accuracy: 52.10%
#     Worker 1: Train Loss: 1.7751, Train Accuracy: 52.08%
#     Worker 2: Train Loss: 1.7492, Train Accuracy: 52.83%
#     Worker 3: Train Loss: 1.7733, Train Accuracy: 51.85%
#     Worker 3: Train Loss: 1.7361, Train Accuracy: 52.81%
# Epoch 116/150: Test Loss: 2.0180, Test Accuracy: 47.86%
#     Worker 0: Train Loss: 1.7239, Train Accuracy: 52.86%
#     Worker 1: Train Loss: 1.7184, Train Accuracy: 53.15%
#     Worker 2: Train Loss: 1.7155, Train Accuracy: 53.45%
#     Worker 3: Train Loss: 1.7225, Train Accuracy: 53.13%
# Epoch 117/150: Test Loss: 2.0160, Test Accuracy: 47.76%
#     Worker 0: Train Loss: 1.7104, Train Accuracy: 53.20%
#     Worker 1: Train Loss: 1.7010, Train Accuracy: 54.14%
#     Worker 2: Train Loss: 1.6916, Train Accuracy: 54.09%
#     Worker 3: Train Loss: 1.7269, Train Accuracy: 53.60%
# Epoch 118/150: Test Loss: 2.0171, Test Accuracy: 47.95%
#     Worker 0: Train Loss: 1.7153, Train Accuracy: 52.97%
#     Worker 1: Train Loss: 1.7278, Train Accuracy: 53.09%
#     Worker 2: Train Loss: 1.6900, Train Accuracy: 54.34%
#     Worker 3: Train Loss: 1.7179, Train Accuracy: 53.68%
# Epoch 119/150: Test Loss: 2.0171, Test Accuracy: 48.20%
#     Worker 0: Train Loss: 1.7069, Train Accuracy: 53.61%
#     Worker 1: Train Loss: 1.7077, Train Accuracy: 53.56%
#     Worker 2: Train Loss: 1.6896, Train Accuracy: 54.33%
#     Worker 3: Train Loss: 1.7180, Train Accuracy: 53.46%
# Epoch 120/150: Test Loss: 2.0144, Test Accuracy: 48.19%
#     Worker 0: Train Loss: 1.6933, Train Accuracy: 53.60%
#     Worker 1: Train Loss: 1.7076, Train Accuracy: 53.45%
#     Worker 2: Train Loss: 1.6954, Train Accuracy: 54.45%
#     Worker 3: Train Loss: 1.7172, Train Accuracy: 53.92%
# Epoch 121/150: Test Loss: 2.0161, Test Accuracy: 48.19%
#     Worker 0: Train Loss: 1.6867, Train Accuracy: 53.39%
#     Worker 1: Train Loss: 1.6929, Train Accuracy: 54.23%
#     Worker 2: Train Loss: 1.6657, Train Accuracy: 54.85%
#     Worker 3: Train Loss: 1.6837, Train Accuracy: 53.82%
# Epoch 122/150: Test Loss: 2.0164, Test Accuracy: 48.11%
#     Worker 0: Train Loss: 1.6902, Train Accuracy: 53.77%
#     Worker 1: Train Loss: 1.7001, Train Accuracy: 54.30%
#     Worker 2: Train Loss: 1.6925, Train Accuracy: 53.97%
#     Worker 3: Train Loss: 1.6944, Train Accuracy: 54.45%
# Epoch 123/150: Test Loss: 2.0134, Test Accuracy: 48.48%
#     Worker 0: Train Loss: 1.6851, Train Accuracy: 54.30%
#     Worker 1: Train Loss: 1.6793, Train Accuracy: 54.43%
#     Worker 2: Train Loss: 1.6755, Train Accuracy: 55.03%
#     Worker 3: Train Loss: 1.7034, Train Accuracy: 53.99%
# Epoch 124/150: Test Loss: 2.0149, Test Accuracy: 48.17%
#     Worker 0: Train Loss: 1.6762, Train Accuracy: 53.86%
#     Worker 1: Train Loss: 1.6993, Train Accuracy: 53.94%
#     Worker 2: Train Loss: 1.6712, Train Accuracy: 54.53%
#     Worker 3: Train Loss: 1.7167, Train Accuracy: 53.70%
# Epoch 125/150: Test Loss: 2.0146, Test Accuracy: 48.15%
#     Worker 0: Train Loss: 1.6667, Train Accuracy: 54.21%
#     Worker 1: Train Loss: 1.6850, Train Accuracy: 53.96%
#     Worker 2: Train Loss: 1.6704, Train Accuracy: 54.74%
#     Worker 3: Train Loss: 1.6847, Train Accuracy: 53.98%
# Epoch 126/150: Test Loss: 2.0125, Test Accuracy: 48.13%
#     Worker 0: Train Loss: 1.6950, Train Accuracy: 54.12%
#     Worker 1: Train Loss: 1.6776, Train Accuracy: 54.08%
#     Worker 2: Train Loss: 1.6614, Train Accuracy: 54.88%
#     Worker 3: Train Loss: 1.7042, Train Accuracy: 53.79%
# Epoch 127/150: Test Loss: 2.0119, Test Accuracy: 48.29%
#     Worker 0: Train Loss: 1.6674, Train Accuracy: 54.56%
#     Worker 1: Train Loss: 1.6928, Train Accuracy: 53.84%
#     Worker 2: Train Loss: 1.6664, Train Accuracy: 55.19%
#     Worker 3: Train Loss: 1.6733, Train Accuracy: 54.63%
# Epoch 128/150: Test Loss: 2.0131, Test Accuracy: 48.25%
#     Worker 0: Train Loss: 1.6775, Train Accuracy: 53.88%
#     Worker 1: Train Loss: 1.6493, Train Accuracy: 54.99%
#     Worker 2: Train Loss: 1.6509, Train Accuracy: 54.90%
#     Worker 3: Train Loss: 1.6830, Train Accuracy: 54.39%
# Epoch 129/150: Test Loss: 2.0136, Test Accuracy: 48.40%
#     Worker 0: Train Loss: 1.6763, Train Accuracy: 53.62%
#     Worker 1: Train Loss: 1.6879, Train Accuracy: 53.97%
#     Worker 2: Train Loss: 1.6595, Train Accuracy: 55.03%
#     Worker 3: Train Loss: 1.6896, Train Accuracy: 54.54%
# Epoch 130/150: Test Loss: 2.0120, Test Accuracy: 48.23%
#     Worker 0: Train Loss: 1.6588, Train Accuracy: 54.74%
#     Worker 1: Train Loss: 1.6674, Train Accuracy: 54.53%
#     Worker 2: Train Loss: 1.6568, Train Accuracy: 55.60%
#     Worker 3: Train Loss: 1.6797, Train Accuracy: 54.21%
# Epoch 131/150: Test Loss: 2.0106, Test Accuracy: 48.28%
#     Worker 0: Train Loss: 1.6750, Train Accuracy: 53.83%
#     Worker 1: Train Loss: 1.6705, Train Accuracy: 54.11%
#     Worker 2: Train Loss: 1.6572, Train Accuracy: 55.63%
#     Worker 3: Train Loss: 1.6825, Train Accuracy: 54.43%
# Epoch 132/150: Test Loss: 2.0106, Test Accuracy: 48.61%
#     Worker 0: Train Loss: 1.6608, Train Accuracy: 54.11%
#     Worker 1: Train Loss: 1.6640, Train Accuracy: 54.55%
#     Worker 2: Train Loss: 1.6488, Train Accuracy: 55.43%
#     Worker 3: Train Loss: 1.6683, Train Accuracy: 54.94%
# Epoch 133/150: Test Loss: 2.0097, Test Accuracy: 48.38%
#     Worker 0: Train Loss: 1.6658, Train Accuracy: 54.29%
#     Worker 1: Train Loss: 1.6669, Train Accuracy: 54.77%
#     Worker 2: Train Loss: 1.6430, Train Accuracy: 55.79%
#     Worker 3: Train Loss: 1.6788, Train Accuracy: 54.59%
# Epoch 134/150: Test Loss: 2.0108, Test Accuracy: 48.25%
#     Worker 0: Train Loss: 1.6585, Train Accuracy: 54.41%
#     Worker 1: Train Loss: 1.6701, Train Accuracy: 54.95%
#     Worker 2: Train Loss: 1.6514, Train Accuracy: 55.53%
#     Worker 3: Train Loss: 1.6902, Train Accuracy: 54.15%
# Epoch 135/150: Test Loss: 2.0106, Test Accuracy: 48.30%
#     Worker 0: Train Loss: 1.6557, Train Accuracy: 54.89%
#     Worker 1: Train Loss: 1.6531, Train Accuracy: 55.08%
#     Worker 2: Train Loss: 1.6362, Train Accuracy: 55.70%
#     Worker 3: Train Loss: 1.6836, Train Accuracy: 54.50%
# Epoch 136/150: Test Loss: 2.0100, Test Accuracy: 48.54%
#     Worker 0: Train Loss: 1.6585, Train Accuracy: 54.64%
#     Worker 1: Train Loss: 1.6573, Train Accuracy: 54.46%
#     Worker 2: Train Loss: 1.6600, Train Accuracy: 55.04%
#     Worker 3: Train Loss: 1.6393, Train Accuracy: 55.33%
# Epoch 137/150: Test Loss: 2.0103, Test Accuracy: 48.34%
#     Worker 0: Train Loss: 1.6375, Train Accuracy: 55.07%
#     Worker 1: Train Loss: 1.6402, Train Accuracy: 55.24%
#     Worker 2: Train Loss: 1.6580, Train Accuracy: 55.19%
#     Worker 3: Train Loss: 1.6713, Train Accuracy: 54.79%
# Epoch 138/150: Test Loss: 2.0095, Test Accuracy: 48.54%
#     Worker 0: Train Loss: 1.6718, Train Accuracy: 54.44%
#     Worker 1: Train Loss: 1.6585, Train Accuracy: 55.27%
#     Worker 2: Train Loss: 1.6303, Train Accuracy: 55.80%
#     Worker 3: Train Loss: 1.6415, Train Accuracy: 55.12%
# Epoch 139/150: Test Loss: 2.0095, Test Accuracy: 48.39%
#     Worker 0: Train Loss: 1.6596, Train Accuracy: 54.70%
#     Worker 1: Train Loss: 1.6431, Train Accuracy: 55.37%
#     Worker 2: Train Loss: 1.6606, Train Accuracy: 55.58%
#     Worker 3: Train Loss: 1.6550, Train Accuracy: 55.19%
# Epoch 140/150: Test Loss: 2.0104, Test Accuracy: 48.45%
#     Worker 0: Train Loss: 1.6439, Train Accuracy: 55.03%
#     Worker 1: Train Loss: 1.6540, Train Accuracy: 54.99%
#     Worker 2: Train Loss: 1.6421, Train Accuracy: 55.34%
#     Worker 3: Train Loss: 1.6685, Train Accuracy: 54.20%
# Epoch 141/150: Test Loss: 2.0102, Test Accuracy: 48.51%
#     Worker 0: Train Loss: 1.6543, Train Accuracy: 55.05%
#     Worker 1: Train Loss: 1.6562, Train Accuracy: 55.26%
#     Worker 2: Train Loss: 1.6346, Train Accuracy: 55.50%
#     Worker 3: Train Loss: 1.6496, Train Accuracy: 55.27%
# Epoch 142/150: Test Loss: 2.0099, Test Accuracy: 48.44%
