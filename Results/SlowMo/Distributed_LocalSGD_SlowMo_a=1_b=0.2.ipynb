# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
# Alpha slow learning rate a=1 best
# Beta slow momentum
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
#warmup_epochs = 5

alpha = 1.0  # Slow learning rate scaling factor
beta = 0.2  # Slow momentum factor

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate for each k: {learning_rate:.5f}")
#lr_warmup=learning_rate
# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]


with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs) for optimizer in optimizers]

u_buffer = [torch.zeros_like(param) for param in nets[0].parameters()]  # Momentum buffer

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")
    #if epoch < warmup_epochs: #lr for buffer update during warmup
            #w_factor = (epoch + 1) / warmup_epochs
            #lr_warmup = w_factor * learning_rate
    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch): #outer loop

        #x(t,0)
        iter_params = [torch.zeros_like(param) for param in nets[0].parameters()]
        for param, g_param in zip(iter_params, nets[0].parameters()):
                    param.data.copy_(g_param)
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0

            # Perform J local step before synchronization
            for j in range(J): #inner loop
                      try:
                          # Get a batch from the current worker's shard using next()
                          images, labels = next(shard_iterators[k])
                          images, labels = images.to(device), labels.to(device)  # Move to device
                          optimizers[k].zero_grad()
                          outputs = nets[k](images)
                          loss = criterion(outputs, labels)
                          loss.backward()
                          optimizers[k].step()
                          # Calculate train loss and accuracy
                          train_loss += loss.item() * labels.size(0)
                          _, predicted = outputs.max(1)
                          total_train += labels.size(0)
                          correct_train += predicted.eq(labels).sum().item()

                      except StopIteration:
                          # If the iterator has exhausted the data, restart the iterator
                          shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                          images, labels = next(shard_iterators[k]) # Resume from the next batch
                          images, labels = images.to(device), labels.to(device)
                          # Perform optimization step
                          optimizers[k].zero_grad()
                          outputs = nets[k](images)
                          loss = criterion(outputs, labels)
                          loss.backward()
                          optimizers[k].step()
                          # Calculate train loss and accuracy
                          train_loss += loss.item() * labels.size(0)
                          _, predicted = outputs.max(1)
                          total_train += labels.size(0)
                          correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train


         # Synchronization (SLOWMO Algothm 1 - paper 21)
        with torch.no_grad():
            global_params = [torch.zeros_like(param) for param in nets[0].parameters()]
            #x(t, tau)
            for net in nets:
                for global_param, local_param in zip(global_params, net.parameters()):
                    global_param += local_param
            for global_param in global_params:
                global_param /= K

            for param, g_param, u_param in zip(iter_params, global_params, u_buffer):
                #if epoch < warmup_epochs:
                  #  u_param.mul_(beta).add_((param - g_param) / lr_warmup)
                 #   g_param.sub_(alpha * lr_warmup * u_param)

                #else: #Sync after warmup
                    #print(f"{optimizers[0].param_groups[0]['lr']}  {optimizers[1].param_groups[0]['lr']}")
                    lr_sched = optimizers[0].param_groups[0]['lr'] #optimizer lr
                    u_param.mul_(beta).add_((param - g_param) / lr_sched)
                    #g_param.sub_(alpha * lr_sched * u_param)
                    g_param.copy_(param - alpha * lr_sched * u_param)

            for net in nets:
                for param, g_param in zip(net.parameters(), global_params):
                    param.data.copy_(g_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        #if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
        #else:
         #   warmup_factor = (epoch + 1) / warmup_epochs
          #  lr = warmup_factor * learning_rate
           # for optimizer in optimizers:
            #    for param_group in optimizer.param_groups:
             #       param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 4 --j 12
# Out:
# Training with K=4, J=12
# Global iteration per epoch: 17
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:18<00:00, 9.00MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate for each k: 0.00400
# Epoch 1/150: Test Loss: 4.5635, Test Accuracy: 2.62%
#     Worker 0: Train Loss: 4.5961, Train Accuracy: 1.40%
#     Worker 1: Train Loss: 4.5967, Train Accuracy: 1.23%
#     Worker 2: Train Loss: 4.5952, Train Accuracy: 1.47%
#     Worker 3: Train Loss: 4.5951, Train Accuracy: 1.42%
# Epoch 2/150: Test Loss: 4.0838, Test Accuracy: 8.10%
#     Worker 0: Train Loss: 4.3612, Train Accuracy: 4.24%
#     Worker 1: Train Loss: 4.3694, Train Accuracy: 4.35%
#     Worker 2: Train Loss: 4.3431, Train Accuracy: 4.63%
#     Worker 3: Train Loss: 4.3700, Train Accuracy: 4.30%
# Epoch 3/150: Test Loss: 3.8775, Test Accuracy: 11.25%
#     Worker 0: Train Loss: 4.0537, Train Accuracy: 7.79%
#     Worker 1: Train Loss: 4.0527, Train Accuracy: 7.72%
#     Worker 2: Train Loss: 4.0149, Train Accuracy: 8.08%
#     Worker 3: Train Loss: 4.0429, Train Accuracy: 7.95%
# Epoch 4/150: Test Loss: 3.7200, Test Accuracy: 13.82%
#     Worker 0: Train Loss: 3.8728, Train Accuracy: 10.61%
#     Worker 1: Train Loss: 3.8813, Train Accuracy: 10.60%
#     Worker 2: Train Loss: 3.8445, Train Accuracy: 10.83%
#     Worker 3: Train Loss: 3.8774, Train Accuracy: 10.33%
# Epoch 5/150: Test Loss: 3.5763, Test Accuracy: 16.53%
#     Worker 0: Train Loss: 3.7427, Train Accuracy: 12.60%
#     Worker 1: Train Loss: 3.7458, Train Accuracy: 12.62%
#     Worker 2: Train Loss: 3.7031, Train Accuracy: 13.28%
#     Worker 3: Train Loss: 3.7422, Train Accuracy: 12.43%
# Epoch 6/150: Test Loss: 3.4589, Test Accuracy: 18.23%
#     Worker 0: Train Loss: 3.6236, Train Accuracy: 14.39%
#     Worker 1: Train Loss: 3.6218, Train Accuracy: 14.76%
#     Worker 2: Train Loss: 3.5787, Train Accuracy: 15.29%
#     Worker 3: Train Loss: 3.6308, Train Accuracy: 15.00%
# Epoch 7/150: Test Loss: 3.3608, Test Accuracy: 20.08%
#     Worker 0: Train Loss: 3.5272, Train Accuracy: 15.86%
#     Worker 1: Train Loss: 3.5141, Train Accuracy: 16.35%
#     Worker 2: Train Loss: 3.4685, Train Accuracy: 17.04%
#     Worker 3: Train Loss: 3.5195, Train Accuracy: 16.40%
# Epoch 8/150: Test Loss: 3.2479, Test Accuracy: 22.37%
#     Worker 0: Train Loss: 3.4044, Train Accuracy: 18.21%
#     Worker 1: Train Loss: 3.4042, Train Accuracy: 18.41%
#     Worker 2: Train Loss: 3.3664, Train Accuracy: 19.41%
#     Worker 3: Train Loss: 3.4055, Train Accuracy: 18.11%
# Epoch 9/150: Test Loss: 3.1571, Test Accuracy: 23.89%
#     Worker 0: Train Loss: 3.3323, Train Accuracy: 19.15%
#     Worker 1: Train Loss: 3.3383, Train Accuracy: 19.61%
#     Worker 2: Train Loss: 3.2744, Train Accuracy: 20.36%
#     Worker 3: Train Loss: 3.3338, Train Accuracy: 19.48%
#     Worker 2: Train Loss: 2.3424, Train Accuracy: 39.01%
#     Worker 3: Train Loss: 2.3664, Train Accuracy: 38.35%
# Epoch 28/150: Test Loss: 2.2818, Test Accuracy: 40.36%
#     Worker 0: Train Loss: 2.3235, Train Accuracy: 39.06%
#     Worker 1: Train Loss: 2.3206, Train Accuracy: 39.22%
#     Worker 2: Train Loss: 2.3164, Train Accuracy: 39.61%
#     Worker 3: Train Loss: 2.3248, Train Accuracy: 38.95%
# Epoch 29/150: Test Loss: 2.2573, Test Accuracy: 41.21%
#     Worker 0: Train Loss: 2.3109, Train Accuracy: 39.02%
#     Worker 1: Train Loss: 2.2981, Train Accuracy: 40.13%
#     Worker 2: Train Loss: 2.2861, Train Accuracy: 40.54%
#     Worker 3: Train Loss: 2.3232, Train Accuracy: 39.20%
# Epoch 30/150: Test Loss: 2.2388, Test Accuracy: 41.84%
#     Worker 0: Train Loss: 2.2689, Train Accuracy: 40.36%
#     Worker 1: Train Loss: 2.2833, Train Accuracy: 40.40%
#     Worker 2: Train Loss: 2.2429, Train Accuracy: 41.10%
#     Worker 3: Train Loss: 2.2724, Train Accuracy: 39.92%
# Epoch 31/150: Test Loss: 2.2011, Test Accuracy: 42.45%
#     Worker 0: Train Loss: 2.2406, Train Accuracy: 41.12%
#     Worker 1: Train Loss: 2.2629, Train Accuracy: 40.89%
#     Worker 2: Train Loss: 2.2072, Train Accuracy: 42.21%
#     Worker 3: Train Loss: 2.2487, Train Accuracy: 40.39%
# Epoch 32/150: Test Loss: 2.1859, Test Accuracy: 43.32%
#     Worker 0: Train Loss: 2.2052, Train Accuracy: 42.22%
#     Worker 1: Train Loss: 2.1927, Train Accuracy: 41.93%
#     Worker 2: Train Loss: 2.2072, Train Accuracy: 42.16%
#     Worker 3: Train Loss: 2.1893, Train Accuracy: 42.40%
# Epoch 33/150: Test Loss: 2.1839, Test Accuracy: 43.68%
#     Worker 0: Train Loss: 2.1779, Train Accuracy: 41.90%
#     Worker 1: Train Loss: 2.2073, Train Accuracy: 41.88%
#     Worker 2: Train Loss: 2.1596, Train Accuracy: 42.80%
#     Worker 3: Train Loss: 2.1985, Train Accuracy: 42.31%
# Epoch 34/150: Test Loss: 2.1797, Test Accuracy: 43.58%
#     Worker 0: Train Loss: 2.1548, Train Accuracy: 42.51%
#     Worker 1: Train Loss: 2.1638, Train Accuracy: 42.68%
#     Worker 2: Train Loss: 2.1476, Train Accuracy: 43.80%
#     Worker 3: Train Loss: 2.1569, Train Accuracy: 43.05%
# Epoch 35/150: Test Loss: 2.1545, Test Accuracy: 44.11%
#     Worker 0: Train Loss: 2.1334, Train Accuracy: 43.39%
#     Worker 1: Train Loss: 2.1198, Train Accuracy: 43.84%
#     Worker 2: Train Loss: 2.1073, Train Accuracy: 44.38%
#     Worker 3: Train Loss: 2.1460, Train Accuracy: 42.71%
# Epoch 36/150: Test Loss: 2.1419, Test Accuracy: 44.23%
#     Worker 0: Train Loss: 2.1150, Train Accuracy: 43.81%
#     Worker 1: Train Loss: 1.9037, Train Accuracy: 48.82%
#     Worker 2: Train Loss: 1.9026, Train Accuracy: 48.75%
#     Worker 3: Train Loss: 1.9215, Train Accuracy: 48.08%
# Epoch 46/150: Test Loss: 2.0365, Test Accuracy: 46.30%
#     Worker 0: Train Loss: 1.9100, Train Accuracy: 48.07%
#     Worker 1: Train Loss: 1.8978, Train Accuracy: 48.70%
#     Worker 2: Train Loss: 1.9018, Train Accuracy: 49.07%
#     Worker 3: Train Loss: 1.9189, Train Accuracy: 48.29%
# Epoch 47/150: Test Loss: 2.0272, Test Accuracy: 47.11%
#     Worker 0: Train Loss: 1.8865, Train Accuracy: 48.77%
#     Worker 1: Train Loss: 1.8917, Train Accuracy: 49.12%
#     Worker 2: Train Loss: 1.8856, Train Accuracy: 48.82%
#     Worker 3: Train Loss: 1.8750, Train Accuracy: 49.29%
# Epoch 48/150: Test Loss: 2.0296, Test Accuracy: 46.89%
#     Worker 0: Train Loss: 1.8681, Train Accuracy: 49.32%
#     Worker 1: Train Loss: 1.8729, Train Accuracy: 49.19%
#     Worker 2: Train Loss: 1.8402, Train Accuracy: 50.12%
#     Worker 3: Train Loss: 1.8785, Train Accuracy: 48.50%
# Epoch 49/150: Test Loss: 2.0221, Test Accuracy: 47.05%
#     Worker 0: Train Loss: 1.8491, Train Accuracy: 49.75%
#     Worker 1: Train Loss: 1.8396, Train Accuracy: 50.41%
#     Worker 2: Train Loss: 1.8340, Train Accuracy: 50.14%
#     Worker 3: Train Loss: 1.8613, Train Accuracy: 49.66%
# Epoch 50/150: Test Loss: 2.0289, Test Accuracy: 47.03%
#     Worker 0: Train Loss: 1.8401, Train Accuracy: 49.26%
#     Worker 1: Train Loss: 1.8262, Train Accuracy: 50.25%
#     Worker 2: Train Loss: 1.8202, Train Accuracy: 50.89%
#     Worker 3: Train Loss: 1.8419, Train Accuracy: 50.18%
# Epoch 51/150: Test Loss: 2.0000, Test Accuracy: 47.53%
#     Worker 0: Train Loss: 1.8127, Train Accuracy: 50.30%
#     Worker 1: Train Loss: 1.8214, Train Accuracy: 50.39%
#     Worker 2: Train Loss: 1.8014, Train Accuracy: 51.06%
#     Worker 3: Train Loss: 1.8002, Train Accuracy: 50.36%
# Epoch 52/150: Test Loss: 2.0036, Test Accuracy: 47.79%
#     Worker 0: Train Loss: 1.8018, Train Accuracy: 50.45%
#     Worker 1: Train Loss: 1.7808, Train Accuracy: 51.67%
#     Worker 2: Train Loss: 1.7828, Train Accuracy: 51.54%
#     Worker 3: Train Loss: 1.8115, Train Accuracy: 50.92%
# Epoch 53/150: Test Loss: 2.0219, Test Accuracy: 47.49%
#     Worker 0: Train Loss: 1.7724, Train Accuracy: 51.29%
#     Worker 1: Train Loss: 1.7864, Train Accuracy: 50.96%
#     Worker 2: Train Loss: 1.7638, Train Accuracy: 51.99%
#     Worker 3: Train Loss: 1.7685, Train Accuracy: 51.74%
# Epoch 54/150: Test Loss: 2.0035, Test Accuracy: 48.04%
#     Worker 3: Train Loss: 1.5435, Train Accuracy: 56.46%
# Epoch 72/150: Test Loss: 1.9594, Test Accuracy: 49.62%
#     Worker 0: Train Loss: 1.5210, Train Accuracy: 57.32%
#     Worker 1: Train Loss: 1.5004, Train Accuracy: 57.91%
#     Worker 2: Train Loss: 1.5143, Train Accuracy: 57.35%
#     Worker 3: Train Loss: 1.5096, Train Accuracy: 58.09%
# Epoch 73/150: Test Loss: 1.9506, Test Accuracy: 50.17%
#     Worker 0: Train Loss: 1.5208, Train Accuracy: 57.28%
#     Worker 1: Train Loss: 1.5044, Train Accuracy: 57.55%
#     Worker 2: Train Loss: 1.4770, Train Accuracy: 58.83%
#     Worker 3: Train Loss: 1.5106, Train Accuracy: 57.47%
# Epoch 74/150: Test Loss: 1.9579, Test Accuracy: 49.86%
#     Worker 0: Train Loss: 1.4928, Train Accuracy: 57.90%
#     Worker 1: Train Loss: 1.4937, Train Accuracy: 58.35%
#     Worker 2: Train Loss: 1.4827, Train Accuracy: 58.75%
#     Worker 3: Train Loss: 1.5045, Train Accuracy: 57.82%
# Epoch 75/150: Test Loss: 1.9556, Test Accuracy: 50.18%
#     Worker 0: Train Loss: 1.4690, Train Accuracy: 58.32%
#     Worker 1: Train Loss: 1.4720, Train Accuracy: 58.95%
#     Worker 2: Train Loss: 1.4651, Train Accuracy: 58.83%
#     Worker 3: Train Loss: 1.4824, Train Accuracy: 58.21%
# Epoch 76/150: Test Loss: 1.9677, Test Accuracy: 49.63%
#     Worker 0: Train Loss: 1.4646, Train Accuracy: 58.58%
#     Worker 1: Train Loss: 1.4756, Train Accuracy: 58.68%
#     Worker 2: Train Loss: 1.4599, Train Accuracy: 59.49%
#     Worker 3: Train Loss: 1.4616, Train Accuracy: 58.89%
# Epoch 77/150: Test Loss: 1.9525, Test Accuracy: 50.32%
#     Worker 0: Train Loss: 1.4496, Train Accuracy: 58.77%
#     Worker 1: Train Loss: 1.4661, Train Accuracy: 59.00%
#     Worker 2: Train Loss: 1.4427, Train Accuracy: 59.78%
#     Worker 3: Train Loss: 1.4575, Train Accuracy: 58.61%
# Epoch 78/150: Test Loss: 1.9534, Test Accuracy: 50.52%
#     Worker 0: Train Loss: 1.4302, Train Accuracy: 59.51%
#     Worker 1: Train Loss: 1.4331, Train Accuracy: 59.57%
#     Worker 2: Train Loss: 1.4352, Train Accuracy: 60.04%
#     Worker 3: Train Loss: 1.4297, Train Accuracy: 59.61%
# Epoch 79/150: Test Loss: 1.9544, Test Accuracy: 50.40%
#     Worker 0: Train Loss: 1.4266, Train Accuracy: 59.84%
#     Worker 1: Train Loss: 1.4257, Train Accuracy: 60.18%
#     Worker 2: Train Loss: 1.4186, Train Accuracy: 60.46%
#     Worker 3: Train Loss: 1.4429, Train Accuracy: 59.05%
# Epoch 80/150: Test Loss: 1.9522, Test Accuracy: 50.61%
#     Worker 0: Train Loss: 1.4199, Train Accuracy: 59.66%
#     Worker 1: Train Loss: 1.4099, Train Accuracy: 60.50%
#     Worker 2: Train Loss: 1.4206, Train Accuracy: 60.09%
#     Worker 3: Train Loss: 1.4253, Train Accuracy: 60.08%
# Epoch 81/150: Test Loss: 1.9545, Test Accuracy: 50.52%
#     Worker 0: Train Loss: 1.4014, Train Accuracy: 60.35%
#     Worker 1: Train Loss: 1.4093, Train Accuracy: 59.84%
#     Worker 2: Train Loss: 1.4026, Train Accuracy: 60.02%
#     Worker 3: Train Loss: 1.4338, Train Accuracy: 59.22%
# Epoch 82/150: Test Loss: 1.9608, Test Accuracy: 50.29%
#     Worker 0: Train Loss: 1.4075, Train Accuracy: 60.01%
#     Worker 1: Train Loss: 1.3856, Train Accuracy: 61.25%
#     Worker 2: Train Loss: 1.4002, Train Accuracy: 60.09%
#     Worker 3: Train Loss: 1.3966, Train Accuracy: 60.77%
# Epoch 83/150: Test Loss: 1.9435, Test Accuracy: 50.63%
#     Worker 0: Train Loss: 1.4102, Train Accuracy: 60.32%
#     Worker 1: Train Loss: 1.3883, Train Accuracy: 60.67%
#     Worker 2: Train Loss: 1.3878, Train Accuracy: 60.51%
#     Worker 3: Train Loss: 1.4112, Train Accuracy: 60.29%
# Epoch 84/150: Test Loss: 1.9643, Test Accuracy: 50.32%
#     Worker 0: Train Loss: 1.3848, Train Accuracy: 60.57%
#     Worker 1: Train Loss: 1.3705, Train Accuracy: 61.27%
#     Worker 2: Train Loss: 1.3535, Train Accuracy: 61.61%
#     Worker 3: Train Loss: 1.3752, Train Accuracy: 60.89%
# Epoch 85/150: Test Loss: 1.9573, Test Accuracy: 50.40%
#     Worker 0: Train Loss: 1.3678, Train Accuracy: 60.72%
#     Worker 1: Train Loss: 1.3446, Train Accuracy: 61.76%
#     Worker 2: Train Loss: 1.3689, Train Accuracy: 61.80%
#     Worker 3: Train Loss: 1.3737, Train Accuracy: 60.77%
# Epoch 86/150: Test Loss: 1.9641, Test Accuracy: 50.23%
#     Worker 0: Train Loss: 1.3478, Train Accuracy: 61.52%
#     Worker 1: Train Loss: 1.3570, Train Accuracy: 61.93%
#     Worker 2: Train Loss: 1.3705, Train Accuracy: 61.60%
#     Worker 3: Train Loss: 1.3509, Train Accuracy: 61.74%
# Epoch 87/150: Test Loss: 1.9630, Test Accuracy: 50.37%
#     Worker 0: Train Loss: 1.3360, Train Accuracy: 61.78%
#     Worker 1: Train Loss: 1.3465, Train Accuracy: 61.84%
#     Worker 2: Train Loss: 1.3391, Train Accuracy: 62.12%
#     Worker 3: Train Loss: 1.3555, Train Accuracy: 61.34%
# Epoch 88/150: Test Loss: 1.9623, Test Accuracy: 50.81%
#     Worker 0: Train Loss: 1.3458, Train Accuracy: 61.06%
#     Worker 1: Train Loss: 1.3351, Train Accuracy: 62.20%
#     Worker 2: Train Loss: 1.3260, Train Accuracy: 62.59%
#     Worker 3: Train Loss: 1.3282, Train Accuracy: 61.86%
# Epoch 89/150: Test Loss: 1.9724, Test Accuracy: 50.32%
#     Worker 0: Train Loss: 1.3207, Train Accuracy: 61.77%
#     Worker 0: Train Loss: 1.2396, Train Accuracy: 64.57%
#     Worker 1: Train Loss: 1.2422, Train Accuracy: 64.57%
#     Worker 2: Train Loss: 1.2428, Train Accuracy: 64.73%
#     Worker 3: Train Loss: 1.2428, Train Accuracy: 64.23%
# Epoch 99/150: Test Loss: 1.9810, Test Accuracy: 50.90%
#     Worker 0: Train Loss: 1.2257, Train Accuracy: 64.96%
#     Worker 1: Train Loss: 1.2316, Train Accuracy: 65.33%
#     Worker 2: Train Loss: 1.2340, Train Accuracy: 64.48%
#     Worker 3: Train Loss: 1.2502, Train Accuracy: 64.17%
# Epoch 100/150: Test Loss: 1.9721, Test Accuracy: 51.05%
#     Worker 0: Train Loss: 1.2160, Train Accuracy: 64.79%
#     Worker 1: Train Loss: 1.2219, Train Accuracy: 65.13%
#     Worker 2: Train Loss: 1.2261, Train Accuracy: 64.50%
#     Worker 3: Train Loss: 1.2303, Train Accuracy: 64.46%
# Epoch 101/150: Test Loss: 1.9745, Test Accuracy: 50.97%
#     Worker 0: Train Loss: 1.2237, Train Accuracy: 64.50%
#     Worker 1: Train Loss: 1.2238, Train Accuracy: 65.29%
#     Worker 2: Train Loss: 1.2174, Train Accuracy: 65.49%
#     Worker 3: Train Loss: 1.2185, Train Accuracy: 64.86%
# Epoch 102/150: Test Loss: 1.9808, Test Accuracy: 51.61%
#     Worker 0: Train Loss: 1.2047, Train Accuracy: 64.84%
#     Worker 1: Train Loss: 1.2045, Train Accuracy: 65.56%
#     Worker 2: Train Loss: 1.2098, Train Accuracy: 65.43%
#     Worker 3: Train Loss: 1.2110, Train Accuracy: 65.55%
# Epoch 103/150: Test Loss: 1.9852, Test Accuracy: 50.91%
#     Worker 0: Train Loss: 1.2099, Train Accuracy: 64.94%
#     Worker 1: Train Loss: 1.2156, Train Accuracy: 65.64%
#     Worker 2: Train Loss: 1.2013, Train Accuracy: 65.74%
#     Worker 3: Train Loss: 1.1939, Train Accuracy: 65.16%
# Epoch 104/150: Test Loss: 1.9848, Test Accuracy: 50.97%
#     Worker 0: Train Loss: 1.1845, Train Accuracy: 65.93%
#     Worker 1: Train Loss: 1.1844, Train Accuracy: 65.95%
#     Worker 2: Train Loss: 1.1990, Train Accuracy: 65.38%
#     Worker 3: Train Loss: 1.1908, Train Accuracy: 65.80%
# Epoch 105/150: Test Loss: 1.9898, Test Accuracy: 51.15%
#     Worker 0: Train Loss: 1.1759, Train Accuracy: 66.16%
#     Worker 1: Train Loss: 1.1908, Train Accuracy: 65.86%
#     Worker 2: Train Loss: 1.1759, Train Accuracy: 66.57%
#     Worker 3: Train Loss: 1.1807, Train Accuracy: 65.85%
# Epoch 106/150: Test Loss: 1.9847, Test Accuracy: 51.09%
#     Worker 0: Train Loss: 1.1917, Train Accuracy: 65.82%
#     Worker 1: Train Loss: 1.1887, Train Accuracy: 65.75%
#     Worker 2: Train Loss: 1.1663, Train Accuracy: 66.43%
#     Worker 3: Train Loss: 1.1743, Train Accuracy: 66.25%
# Epoch 107/150: Test Loss: 1.9879, Test Accuracy: 50.94%
#     Worker 0: Train Loss: 1.1789, Train Accuracy: 65.95%
#     Worker 1: Train Loss: 1.1694, Train Accuracy: 66.78%
#     Worker 2: Train Loss: 1.1594, Train Accuracy: 66.85%
#     Worker 3: Train Loss: 1.1648, Train Accuracy: 67.05%
# Epoch 108/150: Test Loss: 1.9939, Test Accuracy: 51.06%
#     Worker 0: Train Loss: 1.1444, Train Accuracy: 66.88%
#     Worker 1: Train Loss: 1.1479, Train Accuracy: 67.30%
#     Worker 2: Train Loss: 1.1800, Train Accuracy: 66.05%
#     Worker 3: Train Loss: 1.1688, Train Accuracy: 66.20%
# Epoch 109/150: Test Loss: 1.9970, Test Accuracy: 51.29%
#     Worker 0: Train Loss: 1.1455, Train Accuracy: 66.83%
#     Worker 1: Train Loss: 1.1537, Train Accuracy: 67.13%
#     Worker 2: Train Loss: 1.1592, Train Accuracy: 66.76%
#     Worker 3: Train Loss: 1.1548, Train Accuracy: 66.53%
# Epoch 110/150: Test Loss: 1.9934, Test Accuracy: 51.18%
#     Worker 0: Train Loss: 1.1500, Train Accuracy: 66.66%
#     Worker 1: Train Loss: 1.1421, Train Accuracy: 67.41%
#     Worker 2: Train Loss: 1.1405, Train Accuracy: 66.46%
#     Worker 3: Train Loss: 1.1598, Train Accuracy: 66.46%
# Epoch 111/150: Test Loss: 1.9987, Test Accuracy: 51.37%
#     Worker 0: Train Loss: 1.1273, Train Accuracy: 67.45%
#     Worker 1: Train Loss: 1.1358, Train Accuracy: 67.18%
#     Worker 2: Train Loss: 1.1566, Train Accuracy: 66.66%
#     Worker 3: Train Loss: 1.1459, Train Accuracy: 66.96%
# Epoch 112/150: Test Loss: 1.9982, Test Accuracy: 51.01%
#     Worker 0: Train Loss: 1.1509, Train Accuracy: 66.66%
#     Worker 1: Train Loss: 1.1379, Train Accuracy: 67.53%
#     Worker 2: Train Loss: 1.1446, Train Accuracy: 66.89%
#     Worker 3: Train Loss: 1.1545, Train Accuracy: 66.97%
# Epoch 113/150: Test Loss: 1.9947, Test Accuracy: 51.01%
#     Worker 0: Train Loss: 1.1067, Train Accuracy: 68.51%
#     Worker 1: Train Loss: 1.1441, Train Accuracy: 67.05%
#     Worker 2: Train Loss: 1.1345, Train Accuracy: 67.28%
#     Worker 3: Train Loss: 1.1291, Train Accuracy: 67.08%
# Epoch 114/150: Test Loss: 2.0024, Test Accuracy: 50.94%
#     Worker 0: Train Loss: 1.1417, Train Accuracy: 66.43%
#     Worker 1: Train Loss: 1.1305, Train Accuracy: 67.78%
#     Worker 2: Train Loss: 1.1270, Train Accuracy: 67.33%
#     Worker 3: Train Loss: 1.1240, Train Accuracy: 67.73%
# Epoch 115/150: Test Loss: 2.0011, Test Accuracy: 51.45%
#     Worker 0: Train Loss: 1.1094, Train Accuracy: 68.08%
#     Worker 1: Train Loss: 1.1169, Train Accuracy: 68.01%
#     Worker 2: Train Loss: 1.1196, Train Accuracy: 67.84%
#     Worker 3: Train Loss: 1.1483, Train Accuracy: 67.02%
# Epoch 116/150: Test Loss: 2.0087, Test Accuracy: 51.04%
#     Worker 0: Train Loss: 1.1219, Train Accuracy: 67.15%
#     Worker 1: Train Loss: 1.1216, Train Accuracy: 68.48%
#     Worker 2: Train Loss: 1.1174, Train Accuracy: 67.81%
#     Worker 3: Train Loss: 1.0975, Train Accuracy: 68.37%
# Epoch 117/150: Test Loss: 2.0026, Test Accuracy: 51.17%
#     Worker 0: Train Loss: 1.1098, Train Accuracy: 67.76%
#     Worker 1: Train Loss: 1.0960, Train Accuracy: 68.39%
#     Worker 2: Train Loss: 1.1082, Train Accuracy: 67.88%
#     Worker 3: Train Loss: 1.1076, Train Accuracy: 67.68%
# Epoch 118/150: Test Loss: 2.0018, Test Accuracy: 51.45%
#     Worker 0: Train Loss: 1.1081, Train Accuracy: 68.00%
#     Worker 1: Train Loss: 1.1046, Train Accuracy: 68.33%
#     Worker 2: Train Loss: 1.1042, Train Accuracy: 67.97%
#     Worker 3: Train Loss: 1.1143, Train Accuracy: 68.05%
# Epoch 119/150: Test Loss: 2.0017, Test Accuracy: 51.54%
#     Worker 0: Train Loss: 1.0963, Train Accuracy: 68.12%
#     Worker 1: Train Loss: 1.1027, Train Accuracy: 68.19%
#     Worker 2: Train Loss: 1.0940, Train Accuracy: 68.51%
#     Worker 3: Train Loss: 1.1078, Train Accuracy: 68.39%
# Epoch 120/150: Test Loss: 2.0033, Test Accuracy: 51.39%
#     Worker 0: Train Loss: 1.0745, Train Accuracy: 69.25%
#     Worker 1: Train Loss: 1.0829, Train Accuracy: 68.87%
#     Worker 2: Train Loss: 1.0926, Train Accuracy: 68.46%
#     Worker 3: Train Loss: 1.0948, Train Accuracy: 68.83%
# Epoch 121/150: Test Loss: 2.0041, Test Accuracy: 51.10%
#     Worker 0: Train Loss: 1.0712, Train Accuracy: 68.81%
#     Worker 1: Train Loss: 1.0751, Train Accuracy: 69.14%
#     Worker 2: Train Loss: 1.0900, Train Accuracy: 68.75%
#     Worker 3: Train Loss: 1.1020, Train Accuracy: 68.38%
# Epoch 122/150: Test Loss: 2.0071, Test Accuracy: 51.30%
#     Worker 0: Train Loss: 1.0885, Train Accuracy: 68.82%
#     Worker 1: Train Loss: 1.0822, Train Accuracy: 69.44%
#     Worker 2: Train Loss: 1.0987, Train Accuracy: 68.17%
#     Worker 3: Train Loss: 1.0907, Train Accuracy: 68.70%
# Epoch 123/150: Test Loss: 2.0155, Test Accuracy: 51.20%
#     Worker 0: Train Loss: 1.0738, Train Accuracy: 68.82%
#     Worker 1: Train Loss: 1.0782, Train Accuracy: 69.44%
#     Worker 2: Train Loss: 1.0702, Train Accuracy: 68.90%
#     Worker 3: Train Loss: 1.0888, Train Accuracy: 68.65%
# Epoch 124/150: Test Loss: 2.0206, Test Accuracy: 51.51%
#     Worker 0: Train Loss: 1.0772, Train Accuracy: 69.23%
#     Worker 1: Train Loss: 1.0703, Train Accuracy: 69.47%
#     Worker 2: Train Loss: 1.0791, Train Accuracy: 68.71%
#     Worker 3: Train Loss: 1.0884, Train Accuracy: 68.57%
# Epoch 125/150: Test Loss: 2.0117, Test Accuracy: 51.43%
#     Worker 0: Train Loss: 1.0724, Train Accuracy: 68.44%
#     Worker 1: Train Loss: 1.0632, Train Accuracy: 69.62%
#     Worker 2: Train Loss: 1.0854, Train Accuracy: 68.74%
#     Worker 3: Train Loss: 1.0708, Train Accuracy: 69.14%
# Epoch 126/150: Test Loss: 2.0165, Test Accuracy: 51.16%
#     Worker 0: Train Loss: 1.0708, Train Accuracy: 69.11%
#     Worker 1: Train Loss: 1.0687, Train Accuracy: 69.43%
#     Worker 2: Train Loss: 1.0579, Train Accuracy: 69.61%
#     Worker 3: Train Loss: 1.0651, Train Accuracy: 69.34%
# Epoch 127/150: Test Loss: 2.0140, Test Accuracy: 51.13%
#     Worker 0: Train Loss: 1.0589, Train Accuracy: 69.57%
#     Worker 1: Train Loss: 1.0625, Train Accuracy: 69.54%
#     Worker 2: Train Loss: 1.0640, Train Accuracy: 69.27%
#     Worker 3: Train Loss: 1.0706, Train Accuracy: 68.76%
# Epoch 128/150: Test Loss: 2.0119, Test Accuracy: 51.29%
#     Worker 0: Train Loss: 1.0587, Train Accuracy: 69.25%
#     Worker 1: Train Loss: 1.0542, Train Accuracy: 70.11%
#     Worker 2: Train Loss: 1.0624, Train Accuracy: 68.90%
#     Worker 3: Train Loss: 1.0774, Train Accuracy: 69.37%
# Epoch 129/150: Test Loss: 2.0143, Test Accuracy: 51.22%
#     Worker 0: Train Loss: 1.0668, Train Accuracy: 68.97%
#     Worker 1: Train Loss: 1.0500, Train Accuracy: 69.16%
#     Worker 2: Train Loss: 1.0763, Train Accuracy: 69.07%
#     Worker 3: Train Loss: 1.0589, Train Accuracy: 69.28%
# Epoch 130/150: Test Loss: 2.0129, Test Accuracy: 51.20%
#     Worker 0: Train Loss: 1.0502, Train Accuracy: 69.60%
#     Worker 1: Train Loss: 1.0374, Train Accuracy: 70.51%
#     Worker 2: Train Loss: 1.0470, Train Accuracy: 69.36%
#     Worker 3: Train Loss: 1.0794, Train Accuracy: 69.31%
# Epoch 131/150: Test Loss: 2.0138, Test Accuracy: 51.25%
#     Worker 0: Train Loss: 1.0575, Train Accuracy: 69.46%
#     Worker 1: Train Loss: 1.0499, Train Accuracy: 69.80%
#     Worker 2: Train Loss: 1.0540, Train Accuracy: 69.48%
#     Worker 3: Train Loss: 1.0522, Train Accuracy: 69.98%
# Epoch 132/150: Test Loss: 2.0148, Test Accuracy: 51.36%
#     Worker 0: Train Loss: 1.0578, Train Accuracy: 69.45%
#     Worker 1: Train Loss: 1.0607, Train Accuracy: 69.76%
#     Worker 2: Train Loss: 1.0543, Train Accuracy: 69.51%
#     Worker 3: Train Loss: 1.0444, Train Accuracy: 69.49%
# Epoch 133/150: Test Loss: 2.0149, Test Accuracy: 51.37%
#     Worker 0: Train Loss: 1.0267, Train Accuracy: 70.20%
#     Worker 1: Train Loss: 1.0461, Train Accuracy: 70.23%
#     Worker 2: Train Loss: 1.0434, Train Accuracy: 69.84%
#     Worker 3: Train Loss: 1.0417, Train Accuracy: 70.18%
# Epoch 134/150: Test Loss: 2.0220, Test Accuracy: 51.14%
#     Worker 0: Train Loss: 1.0549, Train Accuracy: 69.50%
#     Worker 1: Train Loss: 1.0560, Train Accuracy: 69.91%
#     Worker 2: Train Loss: 1.0440, Train Accuracy: 70.00%
#     Worker 3: Train Loss: 1.0841, Train Accuracy: 68.84%
# Epoch 135/150: Test Loss: 2.0149, Test Accuracy: 51.26%
#     Worker 0: Train Loss: 1.0467, Train Accuracy: 69.79%
#     Worker 1: Train Loss: 1.0493, Train Accuracy: 70.16%
#     Worker 2: Train Loss: 1.0540, Train Accuracy: 69.60%
#     Worker 3: Train Loss: 1.0426, Train Accuracy: 70.07%
# Epoch 136/150: Test Loss: 2.0158, Test Accuracy: 51.30%
#     Worker 0: Train Loss: 1.0327, Train Accuracy: 69.85%
#     Worker 1: Train Loss: 1.0439, Train Accuracy: 70.10%
#     Worker 2: Train Loss: 1.0319, Train Accuracy: 70.14%
#     Worker 3: Train Loss: 1.0406, Train Accuracy: 70.53%
# Epoch 137/150: Test Loss: 2.0187, Test Accuracy: 51.62%
#     Worker 0: Train Loss: 1.0366, Train Accuracy: 70.47%
#     Worker 1: Train Loss: 1.0344, Train Accuracy: 70.27%
#     Worker 2: Train Loss: 1.0438, Train Accuracy: 69.54%
#     Worker 3: Train Loss: 1.0473, Train Accuracy: 69.70%
# Epoch 138/150: Test Loss: 2.0164, Test Accuracy: 51.60%
#     Worker 0: Train Loss: 1.0502, Train Accuracy: 69.57%
#     Worker 1: Train Loss: 1.0448, Train Accuracy: 70.07%
#     Worker 2: Train Loss: 1.0273, Train Accuracy: 70.26%
#     Worker 3: Train Loss: 1.0318, Train Accuracy: 70.34%
# Epoch 139/150: Test Loss: 2.0175, Test Accuracy: 51.53%
#     Worker 0: Train Loss: 1.0216, Train Accuracy: 70.22%
#     Worker 1: Train Loss: 1.0362, Train Accuracy: 70.10%
#     Worker 2: Train Loss: 1.0377, Train Accuracy: 69.97%
#     Worker 3: Train Loss: 1.0513, Train Accuracy: 69.63%
# Epoch 140/150: Test Loss: 2.0160, Test Accuracy: 51.64%
#     Worker 0: Train Loss: 1.0218, Train Accuracy: 70.90%
#     Worker 1: Train Loss: 1.0431, Train Accuracy: 70.63%
#     Worker 2: Train Loss: 1.0157, Train Accuracy: 70.46%
#     Worker 3: Train Loss: 1.0418, Train Accuracy: 70.31%
# Epoch 141/150: Test Loss: 2.0166, Test Accuracy: 51.44%
#     Worker 0: Train Loss: 1.0246, Train Accuracy: 70.67%
#     Worker 1: Train Loss: 1.0352, Train Accuracy: 70.42%
#     Worker 2: Train Loss: 1.0311, Train Accuracy: 69.83%
#     Worker 3: Train Loss: 1.0266, Train Accuracy: 70.14%
# Epoch 142/150: Test Loss: 2.0161, Test Accuracy: 51.43%
#     Worker 0: Train Loss: 1.0294, Train Accuracy: 69.98%
#     Worker 1: Train Loss: 1.0353, Train Accuracy: 70.35%
#     Worker 2: Train Loss: 1.0380, Train Accuracy: 70.41%
#     Worker 3: Train Loss: 1.0439, Train Accuracy: 69.99%
# Epoch 143/150: Test Loss: 2.0159, Test Accuracy: 51.51%
#     Worker 0: Train Loss: 1.0425, Train Accuracy: 69.87%
#     Worker 1: Train Loss: 1.0358, Train Accuracy: 70.34%
#     Worker 2: Train Loss: 1.0232, Train Accuracy: 70.43%
#     Worker 3: Train Loss: 1.0472, Train Accuracy: 70.21%
# Epoch 144/150: Test Loss: 2.0177, Test Accuracy: 51.48%
#     Worker 0: Train Loss: 1.0340, Train Accuracy: 69.82%
#     Worker 1: Train Loss: 1.0382, Train Accuracy: 70.20%
#     Worker 2: Train Loss: 1.0221, Train Accuracy: 70.06%
#     Worker 3: Train Loss: 1.0301, Train Accuracy: 70.30%
# Epoch 145/150: Test Loss: 2.0177, Test Accuracy: 51.42%
#     Worker 0: Train Loss: 1.0250, Train Accuracy: 70.10%
#     Worker 1: Train Loss: 1.0515, Train Accuracy: 70.00%
#     Worker 2: Train Loss: 1.0426, Train Accuracy: 69.89%
#     Worker 3: Train Loss: 1.0391, Train Accuracy: 70.47%
# Epoch 146/150: Test Loss: 2.0172, Test Accuracy: 51.39%
#     Worker 0: Train Loss: 1.0190, Train Accuracy: 70.37%
#     Worker 1: Train Loss: 1.0396, Train Accuracy: 69.85%
#     Worker 2: Train Loss: 1.0346, Train Accuracy: 70.45%
#     Worker 3: Train Loss: 1.0315, Train Accuracy: 70.14%
# Epoch 147/150: Test Loss: 2.0174, Test Accuracy: 51.46%
#     Worker 0: Train Loss: 1.0241, Train Accuracy: 70.18%
#     Worker 1: Train Loss: 1.0229, Train Accuracy: 71.08%
#     Worker 2: Train Loss: 1.0309, Train Accuracy: 69.79%
#     Worker 3: Train Loss: 1.0412, Train Accuracy: 69.95%
# Epoch 148/150: Test Loss: 2.0173, Test Accuracy: 51.41%
#     Worker 0: Train Loss: 1.0369, Train Accuracy: 69.77%
#     Worker 1: Train Loss: 1.0283, Train Accuracy: 70.14%
#     Worker 2: Train Loss: 1.0380, Train Accuracy: 70.09%
#     Worker 3: Train Loss: 1.0373, Train Accuracy: 70.24%
# Epoch 149/150: Test Loss: 2.0173, Test Accuracy: 51.41%
#     Worker 0: Train Loss: 1.0376, Train Accuracy: 70.15%
#     Worker 1: Train Loss: 1.0352, Train Accuracy: 70.03%
#     Worker 2: Train Loss: 1.0449, Train Accuracy: 70.05%
#     Worker 3: Train Loss: 1.0258, Train Accuracy: 70.30%
# Epoch 150/150: Test Loss: 2.0173, Test Accuracy: 51.40%
#     Worker 0: Train Loss: 1.0241, Train Accuracy: 70.61%
#     Worker 1: Train Loss: 1.0325, Train Accuracy: 70.61%
#     Worker 2: Train Loss: 1.0249, Train Accuracy: 70.33%
#     Worker 3: Train Loss: 1.0257, Train Accuracy: 70.87%
