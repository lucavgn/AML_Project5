# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
# Alpha slow learning rate a=1 best
# Beta slow momentum
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
#warmup_epochs = 5

alpha = 0.8  # Slow learning rate scaling factor
beta = 0.2  # Slow momentum factor

def compute_mean_std(dataset):
    """Compute the mean and std of CIFAR-100 dataset.

    Args:
        dataset: A dataset derived from `torch.utils.data.Dataset`,
                 such as `cifar100_training_dataset` or `cifar100_test_dataset`.

    Returns:
        A tuple containing (mean, std) for the entire dataset.
    """

    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate for each k: {learning_rate:.5f}")
#lr_warmup=learning_rate
# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]


with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs) for optimizer in optimizers]

u_buffer = [torch.zeros_like(param) for param in nets[0].parameters()]  # Momentum buffer

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Training loop
for epoch in range(num_epochs):
    # print(f"Epoch {epoch + 1}/{num_epochs}:")
    #if epoch < warmup_epochs: #lr for buffer update during warmup
            #w_factor = (epoch + 1) / warmup_epochs
            #lr_warmup = w_factor * learning_rate
    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]
    for iteration in range(global_iteration_per_epoch): #outer loop

        #x(t,0)
        iter_params = [torch.zeros_like(param) for param in nets[0].parameters()]
        for param, g_param in zip(iter_params, nets[0].parameters()):
                    param.data.copy_(g_param)
        # Sequentially train each worker to simulate a distributed environment
        for k in range(K):

            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0

            # Perform J local step before synchronization
            for j in range(J): #inner loop
                      try:
                          # Get a batch from the current worker's shard using next()
                          images, labels = next(shard_iterators[k])
                          images, labels = images.to(device), labels.to(device)  # Move to device
                          optimizers[k].zero_grad()
                          outputs = nets[k](images)
                          loss = criterion(outputs, labels)
                          loss.backward()
                          optimizers[k].step()
                          # Calculate train loss and accuracy
                          train_loss += loss.item() * labels.size(0)
                          _, predicted = outputs.max(1)
                          total_train += labels.size(0)
                          correct_train += predicted.eq(labels).sum().item()

                      except StopIteration:
                          # If the iterator has exhausted the data, restart the iterator
                          shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                          images, labels = next(shard_iterators[k]) # Resume from the next batch
                          images, labels = images.to(device), labels.to(device)
                          # Perform optimization step
                          optimizers[k].zero_grad()
                          outputs = nets[k](images)
                          loss = criterion(outputs, labels)
                          loss.backward()
                          optimizers[k].step()
                          # Calculate train loss and accuracy
                          train_loss += loss.item() * labels.size(0)
                          _, predicted = outputs.max(1)
                          total_train += labels.size(0)
                          correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train


         # Synchronization (SLOWMO Algothm 1 - paper 21)
        with torch.no_grad():
            global_params = [torch.zeros_like(param) for param in nets[0].parameters()]
            #x(t, tau)
            for net in nets:
                for global_param, local_param in zip(global_params, net.parameters()):
                    global_param += local_param
            for global_param in global_params:
                global_param /= K

            for param, g_param, u_param in zip(iter_params, global_params, u_buffer):
                #if epoch < warmup_epochs:
                  #  u_param.mul_(beta).add_((param - g_param) / lr_warmup)
                 #   g_param.sub_(alpha * lr_warmup * u_param)

                #else: #Sync after warmup
                    #print(f"{optimizers[0].param_groups[0]['lr']}  {optimizers[1].param_groups[0]['lr']}")
                    lr_sched = optimizers[0].param_groups[0]['lr'] #optimizer lr
                    u_param.mul_(beta).add_((param - g_param) / lr_sched)
                    #g_param.sub_(alpha * lr_sched * u_param)
                    g_param.copy_(param - alpha * lr_sched * u_param)

            for net in nets:
                for param, g_param in zip(net.parameters(), global_params):
                    param.data.copy_(g_param)

    # Update lr for each scheduler
    for scheduler in schedulers:
        #if epoch >= warmup_epochs:
            scheduler.step()  # Trigger cosine decay
        #else:
         #   warmup_factor = (epoch + 1) / warmup_epochs
          #  lr = warmup_factor * learning_rate
           # for optimizer in optimizers:
            #    for param_group in optimizer.param_groups:
             #       param_group['lr'] = lr
        # print(f"Learning rate at epoch {epoch + 1}: {scheduler.get_lr()[0]:.5f}")

    # Final Evaluation on Test Set
    global_model = nets[0] # all models are synchronized
    global_model.eval()
    # Test
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()
    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

# Plot results
# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Overwriting localSGD.py

# %%
              # %run localSGD.py --k 4 --j 16
# Out:
# Training with K=4, J=16
# Global iteration per epoch: 13
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
#
#     Worker 3: Train Loss: 2.2842, Train Accuracy: 40.10%
# Epoch 37/150: Test Loss: 2.2448, Test Accuracy: 42.10%
#     Worker 0: Train Loss: 2.2599, Train Accuracy: 40.59%
#     Worker 1: Train Loss: 2.2685, Train Accuracy: 40.53%
#     Worker 2: Train Loss: 2.2410, Train Accuracy: 41.30%
#     Worker 3: Train Loss: 2.2602, Train Accuracy: 40.56%
# Epoch 38/150: Test Loss: 2.2172, Test Accuracy: 42.43%
#     Worker 0: Train Loss: 2.2319, Train Accuracy: 41.20%
#     Worker 1: Train Loss: 2.2450, Train Accuracy: 40.68%
#     Worker 2: Train Loss: 2.2044, Train Accuracy: 41.89%
#     Worker 3: Train Loss: 2.2458, Train Accuracy: 41.35%
# Epoch 39/150: Test Loss: 2.2042, Test Accuracy: 42.72%
#     Worker 0: Train Loss: 2.1940, Train Accuracy: 41.71%
#     Worker 1: Train Loss: 2.2159, Train Accuracy: 41.60%
#     Worker 2: Train Loss: 2.2046, Train Accuracy: 42.49%
#     Worker 3: Train Loss: 2.2189, Train Accuracy: 41.36%
# Epoch 40/150: Test Loss: 2.1966, Test Accuracy: 42.61%
#     Worker 0: Train Loss: 2.1949, Train Accuracy: 42.12%
#     Worker 1: Train Loss: 2.1902, Train Accuracy: 42.26%
#     Worker 2: Train Loss: 2.1605, Train Accuracy: 42.81%
#     Worker 3: Train Loss: 2.2001, Train Accuracy: 41.78%
# Epoch 41/150: Test Loss: 2.1713, Test Accuracy: 43.75%
#     Worker 0: Train Loss: 2.1695, Train Accuracy: 42.35%
#     Worker 1: Train Loss: 2.1984, Train Accuracy: 42.18%
#     Worker 2: Train Loss: 2.1616, Train Accuracy: 43.41%
#     Worker 3: Train Loss: 2.1767, Train Accuracy: 42.17%
# Epoch 42/150: Test Loss: 2.1551, Test Accuracy: 44.09%
#     Worker 0: Train Loss: 2.1646, Train Accuracy: 42.65%
#     Worker 1: Train Loss: 2.1546, Train Accuracy: 42.62%
#     Worker 2: Train Loss: 2.1446, Train Accuracy: 43.14%
#     Worker 3: Train Loss: 2.1627, Train Accuracy: 42.97%
# Epoch 43/150: Test Loss: 2.1497, Test Accuracy: 44.71%
#     Worker 0: Train Loss: 2.1227, Train Accuracy: 43.62%
#     Worker 1: Train Loss: 2.1129, Train Accuracy: 44.17%
#     Worker 2: Train Loss: 2.0777, Train Accuracy: 45.06%
#     Worker 3: Train Loss: 2.1326, Train Accuracy: 43.71%
# Epoch 44/150: Test Loss: 2.1379, Test Accuracy: 44.43%
#     Worker 0: Train Loss: 2.1119, Train Accuracy: 43.92%
#     Worker 1: Train Loss: 2.0948, Train Accuracy: 44.33%
#     Worker 2: Train Loss: 2.1312, Train Accuracy: 43.47%
#     Worker 3: Train Loss: 2.1264, Train Accuracy: 43.81%
# Epoch 45/150: Test Loss: 2.1347, Test Accuracy: 44.76%
#     Worker 0: Train Loss: 2.0903, Train Accuracy: 43.77%
#     Worker 1: Train Loss: 2.0753, Train Accuracy: 44.25%
#     Worker 2: Train Loss: 1.4815, Train Accuracy: 58.57%
#     Worker 3: Train Loss: 1.5056, Train Accuracy: 58.58%
# Epoch 90/150: Test Loss: 1.9482, Test Accuracy: 50.53%
#     Worker 0: Train Loss: 1.4787, Train Accuracy: 58.55%
#     Worker 1: Train Loss: 1.4819, Train Accuracy: 58.37%
#     Worker 2: Train Loss: 1.4773, Train Accuracy: 59.23%
#     Worker 3: Train Loss: 1.4855, Train Accuracy: 58.59%
# Epoch 91/150: Test Loss: 1.9491, Test Accuracy: 50.45%
#     Worker 0: Train Loss: 1.4796, Train Accuracy: 58.58%
#     Worker 1: Train Loss: 1.4660, Train Accuracy: 58.67%
#     Worker 2: Train Loss: 1.4666, Train Accuracy: 59.05%
#     Worker 3: Train Loss: 1.4798, Train Accuracy: 58.70%
# Epoch 92/150: Test Loss: 1.9546, Test Accuracy: 50.09%
#     Worker 0: Train Loss: 1.4516, Train Accuracy: 59.34%
#     Worker 1: Train Loss: 1.4706, Train Accuracy: 58.86%
#     Worker 2: Train Loss: 1.4649, Train Accuracy: 59.37%
#     Worker 3: Train Loss: 1.4574, Train Accuracy: 59.13%
# Epoch 93/150: Test Loss: 1.9449, Test Accuracy: 50.53%
#     Worker 0: Train Loss: 1.4527, Train Accuracy: 58.97%
#     Worker 1: Train Loss: 1.4330, Train Accuracy: 59.58%
#     Worker 2: Train Loss: 1.4385, Train Accuracy: 60.08%
#     Worker 3: Train Loss: 1.4570, Train Accuracy: 59.34%
# Epoch 94/150: Test Loss: 1.9501, Test Accuracy: 50.41%
#     Worker 0: Train Loss: 1.4367, Train Accuracy: 59.25%
#     Worker 1: Train Loss: 1.4412, Train Accuracy: 59.28%
#     Worker 2: Train Loss: 1.4392, Train Accuracy: 59.26%
#     Worker 3: Train Loss: 1.4502, Train Accuracy: 59.85%
# Epoch 95/150: Test Loss: 1.9493, Test Accuracy: 50.58%
#     Worker 0: Train Loss: 1.4231, Train Accuracy: 60.21%
#     Worker 1: Train Loss: 1.4335, Train Accuracy: 59.87%
#     Worker 2: Train Loss: 1.4348, Train Accuracy: 59.46%
#     Worker 3: Train Loss: 1.4448, Train Accuracy: 59.75%
# Epoch 96/150: Test Loss: 1.9483, Test Accuracy: 50.39%
#     Worker 0: Train Loss: 1.4370, Train Accuracy: 59.77%
#     Worker 1: Train Loss: 1.4417, Train Accuracy: 60.11%
#     Worker 2: Train Loss: 1.4203, Train Accuracy: 60.02%
#     Worker 3: Train Loss: 1.4191, Train Accuracy: 59.99%
# Epoch 97/150: Test Loss: 1.9438, Test Accuracy: 50.39%
#     Worker 0: Train Loss: 1.4141, Train Accuracy: 60.48%
#     Worker 1: Train Loss: 1.4067, Train Accuracy: 60.71%
#     Worker 2: Train Loss: 1.4118, Train Accuracy: 60.56%
#     Worker 3: Train Loss: 1.4101, Train Accuracy: 60.73%
# Epoch 98/150: Test Loss: 1.9435, Test Accuracy: 50.68%
#     Worker 0: Train Loss: 1.4208, Train Accuracy: 59.75%
#     Worker 1: Train Loss: 1.4108, Train Accuracy: 60.66%
#     Worker 2: Train Loss: 1.3910, Train Accuracy: 60.65%
#     Worker 3: Train Loss: 1.4172, Train Accuracy: 60.72%
# Epoch 99/150: Test Loss: 1.9515, Test Accuracy: 50.81%
#     Worker 0: Train Loss: 1.4109, Train Accuracy: 60.50%
#     Worker 1: Train Loss: 1.3846, Train Accuracy: 60.88%
#     Worker 2: Train Loss: 1.3890, Train Accuracy: 61.12%
#     Worker 3: Train Loss: 1.4082, Train Accuracy: 60.84%
# Epoch 100/150: Test Loss: 1.9514, Test Accuracy: 50.78%
#     Worker 0: Train Loss: 1.3793, Train Accuracy: 60.74%
#     Worker 1: Train Loss: 1.3875, Train Accuracy: 60.73%
#     Worker 2: Train Loss: 1.3775, Train Accuracy: 61.38%
#     Worker 3: Train Loss: 1.3960, Train Accuracy: 61.06%
# Epoch 101/150: Test Loss: 1.9522, Test Accuracy: 51.05%
#     Worker 0: Train Loss: 1.3895, Train Accuracy: 60.73%
#     Worker 1: Train Loss: 1.3947, Train Accuracy: 60.55%
#     Worker 2: Train Loss: 1.3751, Train Accuracy: 61.06%
#     Worker 3: Train Loss: 1.3913, Train Accuracy: 60.77%
# Epoch 102/150: Test Loss: 1.9506, Test Accuracy: 50.64%
#     Worker 0: Train Loss: 1.3722, Train Accuracy: 61.24%
#     Worker 1: Train Loss: 1.3702, Train Accuracy: 61.21%
#     Worker 2: Train Loss: 1.3736, Train Accuracy: 61.31%
#     Worker 3: Train Loss: 1.3858, Train Accuracy: 61.21%
# Epoch 103/150: Test Loss: 1.9393, Test Accuracy: 50.75%
#     Worker 0: Train Loss: 1.3740, Train Accuracy: 61.00%
#     Worker 1: Train Loss: 1.3541, Train Accuracy: 61.70%
#     Worker 2: Train Loss: 1.3616, Train Accuracy: 61.58%
#     Worker 3: Train Loss: 1.3737, Train Accuracy: 61.72%
# Epoch 104/150: Test Loss: 1.9495, Test Accuracy: 51.06%
#     Worker 0: Train Loss: 1.3436, Train Accuracy: 62.06%
#     Worker 1: Train Loss: 1.3561, Train Accuracy: 61.52%
#     Worker 2: Train Loss: 1.3611, Train Accuracy: 61.45%
#     Worker 3: Train Loss: 1.3531, Train Accuracy: 62.19%
# Epoch 105/150: Test Loss: 1.9465, Test Accuracy: 50.80%
#     Worker 0: Train Loss: 1.3716, Train Accuracy: 61.38%
#     Worker 1: Train Loss: 1.3460, Train Accuracy: 62.16%
#     Worker 2: Train Loss: 1.3546, Train Accuracy: 62.07%
#     Worker 3: Train Loss: 1.3674, Train Accuracy: 61.89%
# Epoch 106/150: Test Loss: 1.9435, Test Accuracy: 51.03%
#     Worker 0: Train Loss: 1.3400, Train Accuracy: 62.14%
#     Worker 1: Train Loss: 1.3413, Train Accuracy: 61.98%
#     Worker 2: Train Loss: 1.3330, Train Accuracy: 62.78%
#     Worker 3: Train Loss: 1.3538, Train Accuracy: 62.06%
# Epoch 107/150: Test Loss: 1.9530, Test Accuracy: 50.66%
#     Worker 0: Train Loss: 1.3551, Train Accuracy: 61.37%
#     Worker 1: Train Loss: 1.3450, Train Accuracy: 61.88%
#     Worker 2: Train Loss: 1.3396, Train Accuracy: 62.14%
#     Worker 3: Train Loss: 1.3488, Train Accuracy: 61.97%
# Epoch 108/150: Test Loss: 1.9417, Test Accuracy: 50.93%
#     Worker 0: Train Loss: 1.3417, Train Accuracy: 62.07%
#     Worker 1: Train Loss: 1.3319, Train Accuracy: 62.56%
#     Worker 2: Train Loss: 1.3154, Train Accuracy: 63.11%
#     Worker 3: Train Loss: 1.3317, Train Accuracy: 62.62%
# Epoch 109/150: Test Loss: 1.9467, Test Accuracy: 50.88%
#     Worker 0: Train Loss: 1.3201, Train Accuracy: 62.70%
#     Worker 1: Train Loss: 1.3186, Train Accuracy: 62.47%
#     Worker 2: Train Loss: 1.3089, Train Accuracy: 62.93%
#     Worker 3: Train Loss: 1.3521, Train Accuracy: 62.03%
# Epoch 110/150: Test Loss: 1.9467, Test Accuracy: 51.14%
#     Worker 0: Train Loss: 1.3267, Train Accuracy: 62.32%
#     Worker 1: Train Loss: 1.3208, Train Accuracy: 62.56%
#     Worker 2: Train Loss: 1.3185, Train Accuracy: 63.06%
#     Worker 3: Train Loss: 1.3245, Train Accuracy: 62.84%
# Epoch 111/150: Test Loss: 1.9545, Test Accuracy: 51.24%
#     Worker 0: Train Loss: 1.3013, Train Accuracy: 62.84%
#     Worker 1: Train Loss: 1.3035, Train Accuracy: 63.14%
#     Worker 2: Train Loss: 1.2974, Train Accuracy: 63.17%
#     Worker 3: Train Loss: 1.3276, Train Accuracy: 62.25%
# Epoch 112/150: Test Loss: 1.9473, Test Accuracy: 51.21%
#     Worker 0: Train Loss: 1.3249, Train Accuracy: 62.53%
#     Worker 1: Train Loss: 1.3035, Train Accuracy: 62.93%
#     Worker 2: Train Loss: 1.3176, Train Accuracy: 62.86%
#     Worker 3: Train Loss: 1.3085, Train Accuracy: 63.72%
# Epoch 113/150: Test Loss: 1.9497, Test Accuracy: 51.30%
#     Worker 0: Train Loss: 1.3145, Train Accuracy: 62.65%
#     Worker 1: Train Loss: 1.3028, Train Accuracy: 62.46%
#     Worker 2: Train Loss: 1.2937, Train Accuracy: 63.57%
#     Worker 3: Train Loss: 1.2969, Train Accuracy: 63.39%
# Epoch 114/150: Test Loss: 1.9485, Test Accuracy: 51.23%
#     Worker 0: Train Loss: 1.2851, Train Accuracy: 63.30%
#     Worker 1: Train Loss: 1.2963, Train Accuracy: 63.31%
#     Worker 2: Train Loss: 1.2857, Train Accuracy: 63.74%
#     Worker 3: Train Loss: 1.2946, Train Accuracy: 63.39%
# Epoch 115/150: Test Loss: 1.9483, Test Accuracy: 51.24%
#     Worker 0: Train Loss: 1.2830, Train Accuracy: 63.51%
#     Worker 1: Train Loss: 1.2704, Train Accuracy: 64.16%
#     Worker 2: Train Loss: 1.2725, Train Accuracy: 64.21%
#     Worker 3: Train Loss: 1.2893, Train Accuracy: 64.02%
# Epoch 116/150: Test Loss: 1.9504, Test Accuracy: 51.04%
#     Worker 0: Train Loss: 1.2850, Train Accuracy: 63.05%
#     Worker 1: Train Loss: 1.2879, Train Accuracy: 63.66%
#     Worker 2: Train Loss: 1.2844, Train Accuracy: 63.94%
#     Worker 3: Train Loss: 1.2788, Train Accuracy: 64.18%
# Epoch 117/150: Test Loss: 1.9507, Test Accuracy: 51.13%
#     Worker 0: Train Loss: 1.2767, Train Accuracy: 64.33%
#     Worker 1: Train Loss: 1.2722, Train Accuracy: 63.98%
#     Worker 2: Train Loss: 1.2618, Train Accuracy: 64.23%
#     Worker 3: Train Loss: 1.2839, Train Accuracy: 63.90%
# Epoch 118/150: Test Loss: 1.9563, Test Accuracy: 51.12%
#     Worker 0: Train Loss: 1.2849, Train Accuracy: 63.24%
#     Worker 1: Train Loss: 1.2842, Train Accuracy: 63.26%
#     Worker 2: Train Loss: 1.2646, Train Accuracy: 64.72%
#     Worker 3: Train Loss: 1.2752, Train Accuracy: 63.84%
# Epoch 119/150: Test Loss: 1.9548, Test Accuracy: 51.17%
#     Worker 0: Train Loss: 1.2776, Train Accuracy: 63.70%
#     Worker 1: Train Loss: 1.2674, Train Accuracy: 63.83%
#     Worker 2: Train Loss: 1.2548, Train Accuracy: 64.78%
#     Worker 3: Train Loss: 1.2794, Train Accuracy: 63.56%
# Epoch 120/150: Test Loss: 1.9536, Test Accuracy: 51.45%
#     Worker 0: Train Loss: 1.2582, Train Accuracy: 64.08%
#     Worker 1: Train Loss: 1.2549, Train Accuracy: 64.64%
#     Worker 2: Train Loss: 1.2622, Train Accuracy: 64.43%
#     Worker 3: Train Loss: 1.2821, Train Accuracy: 64.03%
# Epoch 121/150: Test Loss: 1.9554, Test Accuracy: 51.41%
#     Worker 0: Train Loss: 1.2600, Train Accuracy: 64.38%
#     Worker 1: Train Loss: 1.2562, Train Accuracy: 64.02%
#     Worker 2: Train Loss: 1.2416, Train Accuracy: 64.80%
#     Worker 3: Train Loss: 1.2457, Train Accuracy: 65.09%
# Epoch 122/150: Test Loss: 1.9571, Test Accuracy: 51.28%
#     Worker 0: Train Loss: 1.2481, Train Accuracy: 64.49%
#     Worker 1: Train Loss: 1.2512, Train Accuracy: 64.73%
#     Worker 2: Train Loss: 1.2617, Train Accuracy: 64.10%
#     Worker 3: Train Loss: 1.2484, Train Accuracy: 64.94%
# Epoch 123/150: Test Loss: 1.9581, Test Accuracy: 51.29%
#     Worker 0: Train Loss: 1.2587, Train Accuracy: 64.21%
#     Worker 1: Train Loss: 1.2269, Train Accuracy: 65.34%
#     Worker 2: Train Loss: 1.2438, Train Accuracy: 65.12%
#     Worker 3: Train Loss: 1.2645, Train Accuracy: 64.63%
# Epoch 124/150: Test Loss: 1.9574, Test Accuracy: 51.25%
#     Worker 0: Train Loss: 1.2380, Train Accuracy: 64.98%
#     Worker 1: Train Loss: 1.2547, Train Accuracy: 64.06%
#     Worker 2: Train Loss: 1.2365, Train Accuracy: 65.65%
#     Worker 3: Train Loss: 1.2678, Train Accuracy: 64.58%
# Epoch 125/150: Test Loss: 1.9596, Test Accuracy: 51.39%
#     Worker 0: Train Loss: 1.2258, Train Accuracy: 64.94%
#     Worker 1: Train Loss: 1.2469, Train Accuracy: 64.61%
#     Worker 2: Train Loss: 1.2302, Train Accuracy: 65.41%
#     Worker 3: Train Loss: 1.2335, Train Accuracy: 65.23%
# Epoch 126/150: Test Loss: 1.9558, Test Accuracy: 51.29%
#     Worker 0: Train Loss: 1.2623, Train Accuracy: 64.46%
#     Worker 1: Train Loss: 1.2308, Train Accuracy: 64.87%
#     Worker 2: Train Loss: 1.2253, Train Accuracy: 65.17%
#     Worker 3: Train Loss: 1.2588, Train Accuracy: 64.78%
# Epoch 127/150: Test Loss: 1.9550, Test Accuracy: 51.10%
#     Worker 0: Train Loss: 1.2294, Train Accuracy: 64.74%
#     Worker 1: Train Loss: 1.2516, Train Accuracy: 64.53%
#     Worker 2: Train Loss: 1.2248, Train Accuracy: 65.80%
#     Worker 3: Train Loss: 1.2243, Train Accuracy: 65.36%
# Epoch 128/150: Test Loss: 1.9589, Test Accuracy: 51.47%
#     Worker 0: Train Loss: 1.2466, Train Accuracy: 64.67%
#     Worker 1: Train Loss: 1.2122, Train Accuracy: 65.71%
#     Worker 2: Train Loss: 1.2150, Train Accuracy: 65.41%
#     Worker 3: Train Loss: 1.2414, Train Accuracy: 65.03%
# Epoch 129/150: Test Loss: 1.9591, Test Accuracy: 51.65%
#     Worker 0: Train Loss: 1.2341, Train Accuracy: 64.77%
#     Worker 1: Train Loss: 1.2357, Train Accuracy: 65.08%
#     Worker 2: Train Loss: 1.2182, Train Accuracy: 66.02%
#     Worker 3: Train Loss: 1.2527, Train Accuracy: 64.99%
# Epoch 130/150: Test Loss: 1.9591, Test Accuracy: 51.54%
#     Worker 0: Train Loss: 1.2241, Train Accuracy: 65.11%
#     Worker 1: Train Loss: 1.2189, Train Accuracy: 65.16%
#     Worker 2: Train Loss: 1.2300, Train Accuracy: 65.88%
#     Worker 3: Train Loss: 1.2257, Train Accuracy: 65.49%
# Epoch 131/150: Test Loss: 1.9586, Test Accuracy: 51.39%
#     Worker 0: Train Loss: 1.2254, Train Accuracy: 65.09%
#     Worker 1: Train Loss: 1.2176, Train Accuracy: 65.37%
#     Worker 2: Train Loss: 1.2188, Train Accuracy: 66.02%
#     Worker 3: Train Loss: 1.2203, Train Accuracy: 65.74%
# Epoch 132/150: Test Loss: 1.9591, Test Accuracy: 51.32%
#     Worker 0: Train Loss: 1.2256, Train Accuracy: 64.92%
#     Worker 1: Train Loss: 1.2113, Train Accuracy: 65.19%
#     Worker 2: Train Loss: 1.2158, Train Accuracy: 65.85%
#     Worker 3: Train Loss: 1.2245, Train Accuracy: 65.60%
# Epoch 133/150: Test Loss: 1.9561, Test Accuracy: 51.39%
#     Worker 0: Train Loss: 1.2359, Train Accuracy: 64.87%
#     Worker 1: Train Loss: 1.2241, Train Accuracy: 65.03%
#     Worker 2: Train Loss: 1.2172, Train Accuracy: 66.14%
#     Worker 3: Train Loss: 1.2288, Train Accuracy: 65.53%
# Epoch 134/150: Test Loss: 1.9578, Test Accuracy: 51.54%
#     Worker 0: Train Loss: 1.2196, Train Accuracy: 65.53%
#     Worker 1: Train Loss: 1.2095, Train Accuracy: 66.14%
#     Worker 2: Train Loss: 1.2190, Train Accuracy: 66.02%
#     Worker 3: Train Loss: 1.2436, Train Accuracy: 64.94%
# Epoch 135/150: Test Loss: 1.9585, Test Accuracy: 51.32%
#     Worker 0: Train Loss: 1.2152, Train Accuracy: 65.52%
#     Worker 1: Train Loss: 1.2006, Train Accuracy: 66.35%
#     Worker 2: Train Loss: 1.1963, Train Accuracy: 66.11%
#     Worker 3: Train Loss: 1.2280, Train Accuracy: 65.29%
# Epoch 136/150: Test Loss: 1.9583, Test Accuracy: 51.49%
#     Worker 0: Train Loss: 1.2204, Train Accuracy: 65.38%
#     Worker 1: Train Loss: 1.2090, Train Accuracy: 65.44%
#     Worker 2: Train Loss: 1.2272, Train Accuracy: 65.32%
#     Worker 3: Train Loss: 1.1990, Train Accuracy: 65.95%
# Epoch 137/150: Test Loss: 1.9563, Test Accuracy: 51.45%
#     Worker 0: Train Loss: 1.1974, Train Accuracy: 65.77%
#     Worker 1: Train Loss: 1.1890, Train Accuracy: 65.90%
#     Worker 2: Train Loss: 1.2172, Train Accuracy: 65.28%
#     Worker 3: Train Loss: 1.2276, Train Accuracy: 65.31%
# Epoch 138/150: Test Loss: 1.9579, Test Accuracy: 51.46%
#     Worker 0: Train Loss: 1.2275, Train Accuracy: 65.10%
#     Worker 1: Train Loss: 1.2117, Train Accuracy: 65.66%
#     Worker 2: Train Loss: 1.1969, Train Accuracy: 66.23%
#     Worker 3: Train Loss: 1.1941, Train Accuracy: 66.47%
# Epoch 139/150: Test Loss: 1.9567, Test Accuracy: 51.54%
#     Worker 0: Train Loss: 1.2192, Train Accuracy: 65.39%
#     Worker 1: Train Loss: 1.1894, Train Accuracy: 66.29%
#     Worker 2: Train Loss: 1.2194, Train Accuracy: 65.64%
#     Worker 3: Train Loss: 1.2042, Train Accuracy: 65.82%
# Epoch 140/150: Test Loss: 1.9566, Test Accuracy: 51.37%
#     Worker 0: Train Loss: 1.2068, Train Accuracy: 65.26%
#     Worker 1: Train Loss: 1.2014, Train Accuracy: 66.16%
#     Worker 2: Train Loss: 1.2050, Train Accuracy: 66.08%
#     Worker 3: Train Loss: 1.2129, Train Accuracy: 65.54%
# Epoch 141/150: Test Loss: 1.9571, Test Accuracy: 51.43%
#     Worker 0: Train Loss: 1.2165, Train Accuracy: 65.47%
#     Worker 1: Train Loss: 1.2011, Train Accuracy: 66.52%
#     Worker 2: Train Loss: 1.2026, Train Accuracy: 66.11%
#     Worker 3: Train Loss: 1.2018, Train Accuracy: 66.35%
# Epoch 142/150: Test Loss: 1.9575, Test Accuracy: 51.55%
#     Worker 0: Train Loss: 1.2015, Train Accuracy: 65.93%
#     Worker 1: Train Loss: 1.1906, Train Accuracy: 66.20%
#     Worker 2: Train Loss: 1.2067, Train Accuracy: 66.00%
#     Worker 3: Train Loss: 1.2166, Train Accuracy: 65.59%
# Epoch 143/150: Test Loss: 1.9567, Test Accuracy: 51.53%
#     Worker 0: Train Loss: 1.1988, Train Accuracy: 66.37%
#     Worker 1: Train Loss: 1.2129, Train Accuracy: 65.69%
#     Worker 2: Train Loss: 1.1915, Train Accuracy: 66.53%
#     Worker 3: Train Loss: 1.2228, Train Accuracy: 65.43%
# Epoch 144/150: Test Loss: 1.9569, Test Accuracy: 51.37%
#     Worker 0: Train Loss: 1.2118, Train Accuracy: 65.48%
#     Worker 1: Train Loss: 1.2019, Train Accuracy: 66.14%
#     Worker 2: Train Loss: 1.2041, Train Accuracy: 65.85%
#     Worker 3: Train Loss: 1.1994, Train Accuracy: 66.10%
# Epoch 145/150: Test Loss: 1.9566, Test Accuracy: 51.42%
#     Worker 0: Train Loss: 1.1941, Train Accuracy: 65.57%
#     Worker 1: Train Loss: 1.1965, Train Accuracy: 66.09%
#     Worker 2: Train Loss: 1.2105, Train Accuracy: 66.29%
#     Worker 3: Train Loss: 1.2087, Train Accuracy: 65.74%
# Epoch 146/150: Test Loss: 1.9563, Test Accuracy: 51.51%
#     Worker 0: Train Loss: 1.2125, Train Accuracy: 65.22%
#     Worker 1: Train Loss: 1.1912, Train Accuracy: 66.24%
#     Worker 2: Train Loss: 1.1880, Train Accuracy: 66.53%
#     Worker 3: Train Loss: 1.2174, Train Accuracy: 65.59%
# Epoch 147/150: Test Loss: 1.9564, Test Accuracy: 51.45%
#     Worker 0: Train Loss: 1.2000, Train Accuracy: 65.41%
#     Worker 1: Train Loss: 1.2019, Train Accuracy: 66.01%
#     Worker 2: Train Loss: 1.2031, Train Accuracy: 66.58%
#     Worker 3: Train Loss: 1.2203, Train Accuracy: 65.10%
# Epoch 148/150: Test Loss: 1.9564, Test Accuracy: 51.49%
#     Worker 0: Train Loss: 1.2014, Train Accuracy: 65.65%
#     Worker 1: Train Loss: 1.1950, Train Accuracy: 66.78%
#     Worker 2: Train Loss: 1.1923, Train Accuracy: 66.34%
#     Worker 3: Train Loss: 1.2098, Train Accuracy: 66.21%
# Epoch 149/150: Test Loss: 1.9564, Test Accuracy: 51.50%
#     Worker 0: Train Loss: 1.2174, Train Accuracy: 65.41%
#     Worker 1: Train Loss: 1.1983, Train Accuracy: 66.11%
#     Worker 2: Train Loss: 1.1976, Train Accuracy: 66.16%
#     Worker 3: Train Loss: 1.2082, Train Accuracy: 65.88%
# Epoch 150/150: Test Loss: 1.9564, Test Accuracy: 51.50%
#     Worker 0: Train Loss: 1.2056, Train Accuracy: 65.21%
#     Worker 1: Train Loss: 1.1930, Train Accuracy: 66.20%
#     Worker 2: Train Loss: 1.2021, Train Accuracy: 66.01%
#     Worker 3: Train Loss: 1.1848, Train Accuracy: 66.94%
