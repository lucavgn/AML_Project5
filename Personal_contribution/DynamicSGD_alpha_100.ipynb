# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files
import torch.nn.functional as F
import time

total_computation_time = 0
total_communication_time = 0

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
iteration_per_epoch = 782 # number of local step performed in one epoch
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
#warmup_epochs = 5

def compute_mean_std(dataset):
    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

#global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
#global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
#print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Compute gradient magnitude and variance
def compute_gradient_stats(nets, optimizers):
    # Get gradients from each worker
    gradients = []
    for net, optimizer in zip(nets, optimizers):
        grad_vector = []
        for param in net.parameters():
            if param.grad is not None:
                grad_vector.append(param.grad.view(-1))
        grad_vector = torch.cat(grad_vector)  # Flatten all gradients into a vector
        gradients.append(grad_vector)

    # Compute average gradient (g_t)
    avg_gradient = torch.stack(gradients).mean(dim=0)

    # Compute squared norms of individual gradients
    squared_norms = [torch.norm(g).item() ** 2 for g in gradients]

    # Compute squared norm of the average gradient
    avg_squared_norm = torch.norm(avg_gradient).item() ** 2

    # Compute gradient variance (sigma_t^2) using the provided formula
    sigma_t_squared = (sum(squared_norms) / (K - 1)) - (K / (K - 1)) * avg_squared_norm

    # Compute gradient magnitude (G_t) using the provided formula
    G_t = avg_squared_norm - (1 / K) * sigma_t_squared

    return G_t, sigma_t_squared


# Update H dynamically based on gradient stats
def update_H(G_t, sigma_t_squared, H_min, H_max, alpha, epsilon):
    H_t = min(H_max, max(H_min, alpha * G_t / (sigma_t_squared + epsilon)))
    #H_t = min(H_t, H_max)  # Ensure H_t doesn't exceed H_max
    return int(H_t)  # Ensure H_t is an integer

# Training loop
# Hyperparameters for dynamic adjustment
H_min, H_max = 4, 64  # Minimum and maximum allowed local steps
alpha, epsilon = 100, 1e-6  # Scaling factor and small constant

H_t = J  # Initialize H_t with the default J value


for epoch in range(num_epochs):
    #print(f"Epoch {epoch + 1}/{num_epochs}:")
    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]

    iteration_per_epoch = 782
    iteration = 0 # Number of global iteration performed
    while iteration_per_epoch > 0:
        computation_start_time = time.time()
        # Train each worker for H_t steps
        for k in range(K):
            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            for _ in range(H_t):  # Perform H_t local steps
                try:
                    images, labels = next(shard_iterators[k])
                except StopIteration:
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k])
                images, labels = images.to(device), labels.to(device)

                optimizers[k].zero_grad()
                outputs = nets[k](images)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizers[k].step()

                # Calculate train loss and accuracy
                train_loss += loss.item() * labels.size(0)
                _, predicted = outputs.max(1)
                total_train += labels.size(0)
                correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        computation_end_time = time.time()
        total_computation_time += (computation_end_time - computation_start_time)

        communication_start_time = time.time()
        # Synchronize models
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

        communication_end_time = time.time()
        total_communication_time += (communication_end_time - communication_start_time)

        # update tot_num_local_step and number of global iteration
        iteration_per_epoch -= (H_t * K)
        iteration += 1
        # Compute gradient stats and update H_t
        G_t, sigma_t_squared = compute_gradient_stats(nets, optimizers)
        H_t = update_H(G_t, sigma_t_squared, H_min, H_max, alpha, epsilon)
        print(f"Epoch {epoch+1}, Iteration {iteration}: H_t = {H_t}, G_t = {G_t:.4f}, σ_t^2 = {sigma_t_squared:.4f}")

    # Store training metrics for all workers after each epoch
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

    # Update learning rate
    for scheduler in schedulers:
        scheduler.step()

    # Evaluate on test set
    global_model = nets[0]
    global_model.eval()
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()

    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)
    print(f"Epoch {epoch + 1}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")

    print(f"Total Computation Time: {total_computation_time:.2f} seconds")
    print(f"Total Communication Time: {total_communication_time:.2f} seconds")



# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 4 --j 32
# Out:
# Training with K=4, J=32
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:18<00:00, 9.03MB/s]
# Output streaming troncato alle ultime 5000 righe.
# Epoch 58, Iteration 6: H_t = 4, G_t = 0.9364, σ_t^2 = 80.2601
# Epoch 58, Iteration 7: H_t = 7, G_t = 5.4228, σ_t^2 = 71.4616
# Epoch 58, Iteration 8: H_t = 4, G_t = -0.0212, σ_t^2 = 83.3541
# Epoch 58, Iteration 9: H_t = 4, G_t = 1.0343, σ_t^2 = 69.7332
# Epoch 58, Iteration 10: H_t = 6, G_t = 5.4172, σ_t^2 = 78.8218
# Epoch 58, Iteration 11: H_t = 4, G_t = 3.4486, σ_t^2 = 77.7757
# Epoch 58, Iteration 12: H_t = 4, G_t = 1.4369, σ_t^2 = 65.0984
# Epoch 58, Iteration 13: H_t = 4, G_t = 1.0444, σ_t^2 = 83.0435
# Epoch 58, Iteration 14: H_t = 4, G_t = 2.0911, σ_t^2 = 71.6532
# Epoch 58, Iteration 15: H_t = 4, G_t = -0.1714, σ_t^2 = 64.5482
# Epoch 58, Iteration 16: H_t = 4, G_t = 1.9304, σ_t^2 = 67.6144
# Epoch 58, Iteration 17: H_t = 4, G_t = 0.3849, σ_t^2 = 70.5027
# Epoch 58, Iteration 18: H_t = 4, G_t = 0.2598, σ_t^2 = 76.0775
# Epoch 58, Iteration 19: H_t = 4, G_t = 1.3137, σ_t^2 = 71.8335
# Epoch 58, Iteration 20: H_t = 4, G_t = -0.7951, σ_t^2 = 73.9497
# Epoch 58, Iteration 21: H_t = 4, G_t = -0.7703, σ_t^2 = 74.8651
# Epoch 58, Iteration 22: H_t = 4, G_t = 1.3672, σ_t^2 = 74.9210
# Epoch 58, Iteration 23: H_t = 4, G_t = -0.0016, σ_t^2 = 72.4905
# Epoch 58, Iteration 24: H_t = 4, G_t = -0.8707, σ_t^2 = 85.9267
# Epoch 58, Iteration 25: H_t = 4, G_t = 2.0084, σ_t^2 = 70.3121
# Epoch 58, Iteration 26: H_t = 4, G_t = -1.1281, σ_t^2 = 76.6544
# Epoch 58, Iteration 27: H_t = 4, G_t = -2.4085, σ_t^2 = 78.7152
# Epoch 58, Iteration 28: H_t = 4, G_t = -2.3844, σ_t^2 = 81.6735
# Epoch 58, Iteration 29: H_t = 4, G_t = 3.3162, σ_t^2 = 74.4561
# Epoch 58, Iteration 30: H_t = 4, G_t = -1.3809, σ_t^2 = 84.2265
# Epoch 58, Iteration 31: H_t = 4, G_t = 1.7029, σ_t^2 = 88.9457
# Epoch 58, Iteration 32: H_t = 4, G_t = -1.2164, σ_t^2 = 81.1758
# Epoch 58, Iteration 33: H_t = 4, G_t = -0.4645, σ_t^2 = 70.6015
# Epoch 58, Iteration 34: H_t = 4, G_t = -0.2561, σ_t^2 = 70.9759
# Epoch 58, Iteration 35: H_t = 4, G_t = -0.1941, σ_t^2 = 74.6765
# Epoch 58, Iteration 36: H_t = 4, G_t = -0.2154, σ_t^2 = 85.4284
# Epoch 58, Iteration 37: H_t = 4, G_t = 1.1050, σ_t^2 = 72.7866
# Epoch 58, Iteration 38: H_t = 4, G_t = 0.1772, σ_t^2 = 75.9419
# Epoch 58, Iteration 39: H_t = 4, G_t = 0.5642, σ_t^2 = 78.0626
# Epoch 58, Iteration 40: H_t = 9, G_t = 6.0449, σ_t^2 = 64.9138
# Epoch 58, Iteration 41: H_t = 4, G_t = 2.8700, σ_t^2 = 77.6138
# Epoch 58, Iteration 42: H_t = 7, G_t = 6.1000, σ_t^2 = 79.4042
# Epoch 58, Iteration 43: H_t = 4, G_t = 0.4382, σ_t^2 = 79.6649
# Epoch 58, Iteration 44: H_t = 8, G_t = 5.8102, σ_t^2 = 70.0786
#     Worker 0: Train Loss: 1.8364, Train Accuracy: 50.28%
#     Worker 1: Train Loss: 1.8519, Train Accuracy: 50.07%
#     Worker 2: Train Loss: 1.8227, Train Accuracy: 51.03%
#     Worker 3: Train Loss: 1.8402, Train Accuracy: 49.67%
# Epoch 58: Test Loss: 2.0609, Test Accuracy: 46.74%
# Total Computation Time: 1400.29 seconds
# Total Communication Time: 2.65 seconds
# Epoch 59, Iteration 1: H_t = 5, G_t = 4.2077, σ_t^2 = 79.5650
# Epoch 59, Iteration 2: H_t = 4, G_t = 2.3819, σ_t^2 = 74.1574
# Epoch 59, Iteration 3: H_t = 5, G_t = 3.3557, σ_t^2 = 65.9981
# Epoch 59, Iteration 4: H_t = 4, G_t = -0.3220, σ_t^2 = 72.4012
# Epoch 59, Iteration 5: H_t = 4, G_t = -0.6680, σ_t^2 = 69.6456
# Epoch 59, Iteration 6: H_t = 4, G_t = -2.9250, σ_t^2 = 70.2588
# Epoch 59, Iteration 7: H_t = 6, G_t = 4.3992, σ_t^2 = 65.7241
# Epoch 59, Iteration 8: H_t = 6, G_t = 5.3592, σ_t^2 = 87.9615
# Epoch 59, Iteration 9: H_t = 4, G_t = 0.7813, σ_t^2 = 72.1081
# Epoch 59, Iteration 10: H_t = 9, G_t = 6.5339, σ_t^2 = 72.2557
# Epoch 59, Iteration 11: H_t = 4, G_t = -1.7027, σ_t^2 = 91.3703
# Epoch 59, Iteration 12: H_t = 4, G_t = 2.1625, σ_t^2 = 57.3284
# Epoch 59, Iteration 13: H_t = 4, G_t = 2.0062, σ_t^2 = 65.0349
# Epoch 59, Iteration 14: H_t = 4, G_t = 2.8047, σ_t^2 = 77.1238
# Epoch 59, Iteration 15: H_t = 4, G_t = 2.8415, σ_t^2 = 77.2673
# Epoch 59, Iteration 16: H_t = 4, G_t = -3.1107, σ_t^2 = 87.7383
# Epoch 59, Iteration 17: H_t = 4, G_t = 0.5842, σ_t^2 = 69.3668
# Epoch 59, Iteration 18: H_t = 8, G_t = 5.3425, σ_t^2 = 64.8128
# Epoch 59, Iteration 19: H_t = 4, G_t = -0.9638, σ_t^2 = 83.8008
# Epoch 59, Iteration 20: H_t = 4, G_t = 3.0293, σ_t^2 = 78.4148
# Epoch 59, Iteration 21: H_t = 4, G_t = -1.6948, σ_t^2 = 69.4389
# Epoch 59, Iteration 22: H_t = 4, G_t = 0.0865, σ_t^2 = 61.0236
# Epoch 59, Iteration 23: H_t = 4, G_t = -1.0407, σ_t^2 = 64.7635
# Epoch 59, Iteration 24: H_t = 4, G_t = 1.7814, σ_t^2 = 68.7812
# Epoch 59, Iteration 25: H_t = 4, G_t = 2.4116, σ_t^2 = 64.7359
# Epoch 59, Iteration 26: H_t = 4, G_t = -0.7210, σ_t^2 = 76.4769
# Epoch 59, Iteration 27: H_t = 4, G_t = 2.8356, σ_t^2 = 70.6124
# Epoch 59, Iteration 28: H_t = 4, G_t = 0.4661, σ_t^2 = 77.6809
# Epoch 59, Iteration 29: H_t = 4, G_t = -1.9722, σ_t^2 = 78.9740
# Epoch 59, Iteration 30: H_t = 4, G_t = -3.3052, σ_t^2 = 81.3836
# Epoch 59, Iteration 31: H_t = 4, G_t = 0.5136, σ_t^2 = 86.3597
# Epoch 59, Iteration 32: H_t = 4, G_t = 2.9635, σ_t^2 = 70.2222
# Epoch 59, Iteration 33: H_t = 7, G_t = 4.7564, σ_t^2 = 67.5489
# Epoch 59, Iteration 34: H_t = 4, G_t = -1.2043, σ_t^2 = 82.9588
# Epoch 59, Iteration 35: H_t = 4, G_t = 0.2700, σ_t^2 = 71.1865
# Epoch 59, Iteration 36: H_t = 4, G_t = 2.8583, σ_t^2 = 79.4478
# Epoch 59, Iteration 37: H_t = 4, G_t = 1.0984, σ_t^2 = 66.7651
# Epoch 59, Iteration 38: H_t = 4, G_t = -1.4118, σ_t^2 = 89.1499
# Epoch 59, Iteration 39: H_t = 4, G_t = -0.1374, σ_t^2 = 80.8830
# Epoch 59, Iteration 40: H_t = 4, G_t = -1.1656, σ_t^2 = 73.4370
# Epoch 59, Iteration 41: H_t = 4, G_t = 1.4869, σ_t^2 = 66.5621
# Epoch 59, Iteration 42: H_t = 6, G_t = 5.7410, σ_t^2 = 86.9585
# Epoch 59, Iteration 43: H_t = 4, G_t = 3.5996, σ_t^2 = 79.4106
#     Worker 0: Train Loss: 1.8223, Train Accuracy: 50.55%
#     Worker 1: Train Loss: 1.8150, Train Accuracy: 50.78%
#     Worker 2: Train Loss: 1.8171, Train Accuracy: 51.00%
#     Worker 3: Train Loss: 1.8286, Train Accuracy: 49.98%
# Epoch 59: Test Loss: 2.0359, Test Accuracy: 46.80%
# Total Computation Time: 1424.43 seconds
# Total Communication Time: 2.70 seconds
# Epoch 60, Iteration 1: H_t = 4, G_t = 1.3778, σ_t^2 = 94.1352
# Epoch 60, Iteration 2: H_t = 4, G_t = 0.7034, σ_t^2 = 71.2391
# Epoch 60, Iteration 3: H_t = 4, G_t = 2.6760, σ_t^2 = 80.2987
# Epoch 60, Iteration 4: H_t = 4, G_t = -0.3882, σ_t^2 = 64.3705
# Epoch 60, Iteration 5: H_t = 4, G_t = 0.7547, σ_t^2 = 72.3947
# Epoch 60, Iteration 6: H_t = 4, G_t = 0.3632, σ_t^2 = 80.2091
# Epoch 60, Iteration 7: H_t = 7, G_t = 6.3249, σ_t^2 = 79.6189
# Epoch 60, Iteration 8: H_t = 4, G_t = -1.2369, σ_t^2 = 90.8923
# Epoch 60, Iteration 9: H_t = 4, G_t = -0.7792, σ_t^2 = 77.0478
# Epoch 60, Iteration 10: H_t = 4, G_t = 3.8947, σ_t^2 = 81.5249
# Epoch 60, Iteration 11: H_t = 4, G_t = 2.9230, σ_t^2 = 75.5571
# Epoch 60, Iteration 12: H_t = 4, G_t = 3.2388, σ_t^2 = 165.1370
# Epoch 60, Iteration 13: H_t = 6, G_t = 4.4094, σ_t^2 = 70.7334
# Epoch 60, Iteration 14: H_t = 4, G_t = -1.8155, σ_t^2 = 81.3729
# Epoch 60, Iteration 15: H_t = 4, G_t = 2.3090, σ_t^2 = 69.1310
# Epoch 60, Iteration 16: H_t = 4, G_t = 1.9764, σ_t^2 = 71.6521
# Epoch 60, Iteration 17: H_t = 4, G_t = 1.1729, σ_t^2 = 69.7136
# Epoch 60, Iteration 18: H_t = 4, G_t = -2.0110, σ_t^2 = 72.0618
# Epoch 60, Iteration 19: H_t = 4, G_t = 0.0989, σ_t^2 = 74.7896
# Epoch 60, Iteration 20: H_t = 4, G_t = 2.6210, σ_t^2 = 61.3380
# Epoch 60, Iteration 21: H_t = 4, G_t = -1.0827, σ_t^2 = 75.6838
# Epoch 60, Iteration 22: H_t = 4, G_t = 2.5130, σ_t^2 = 78.4017
# Epoch 60, Iteration 23: H_t = 4, G_t = -0.0563, σ_t^2 = 78.8754
# Epoch 60, Iteration 24: H_t = 4, G_t = 1.1569, σ_t^2 = 72.9650
# Epoch 60, Iteration 25: H_t = 4, G_t = 3.0198, σ_t^2 = 79.0159
# Epoch 60, Iteration 26: H_t = 4, G_t = 3.0276, σ_t^2 = 86.7586
# Epoch 60, Iteration 27: H_t = 4, G_t = 1.4118, σ_t^2 = 83.9450
# Epoch 60, Iteration 28: H_t = 6, G_t = 4.6629, σ_t^2 = 75.5910
# Epoch 60, Iteration 29: H_t = 4, G_t = 0.7095, σ_t^2 = 70.6608
# Epoch 60, Iteration 30: H_t = 4, G_t = -1.1467, σ_t^2 = 102.0284
# Epoch 60, Iteration 31: H_t = 4, G_t = 2.9861, σ_t^2 = 80.2553
# Epoch 60, Iteration 32: H_t = 4, G_t = 1.7711, σ_t^2 = 76.4106
# Epoch 60, Iteration 33: H_t = 4, G_t = 3.5436, σ_t^2 = 71.5221
# Epoch 60, Iteration 34: H_t = 4, G_t = 2.3921, σ_t^2 = 68.9549
# Epoch 60, Iteration 35: H_t = 4, G_t = 2.1083, σ_t^2 = 75.3165
# Epoch 60, Iteration 36: H_t = 4, G_t = 0.7260, σ_t^2 = 77.1267
# Epoch 60, Iteration 37: H_t = 4, G_t = 3.3889, σ_t^2 = 88.0622
# Epoch 60, Iteration 38: H_t = 4, G_t = -0.7451, σ_t^2 = 80.5745
# Epoch 60, Iteration 39: H_t = 4, G_t = -1.0804, σ_t^2 = 82.1785
# Epoch 60, Iteration 40: H_t = 7, G_t = 6.4844, σ_t^2 = 86.7280
# Epoch 60, Iteration 41: H_t = 4, G_t = 2.6169, σ_t^2 = 84.5228
# Epoch 60, Iteration 42: H_t = 6, G_t = 5.0477, σ_t^2 = 80.6001
# Epoch 60, Iteration 43: H_t = 4, G_t = 2.7488, σ_t^2 = 90.7714
# Epoch 60, Iteration 44: H_t = 4, G_t = -0.7651, σ_t^2 = 83.6482
# Epoch 60, Iteration 45: H_t = 5, G_t = 4.2861, σ_t^2 = 75.9762
# Epoch 60, Iteration 46: H_t = 4, G_t = -1.1993, σ_t^2 = 95.6910
#     Worker 0: Train Loss: 1.7991, Train Accuracy: 50.62%
#     Worker 1: Train Loss: 1.7974, Train Accuracy: 51.66%
#     Worker 2: Train Loss: 1.7899, Train Accuracy: 51.46%
#     Worker 3: Train Loss: 1.8150, Train Accuracy: 50.76%
# Epoch 60: Test Loss: 2.0456, Test Accuracy: 46.94%
# Total Computation Time: 1448.52 seconds
# Total Communication Time: 2.75 seconds
# Epoch 61, Iteration 1: H_t = 4, G_t = 1.3676, σ_t^2 = 74.5686
# Epoch 61, Iteration 2: H_t = 4, G_t = 0.4279, σ_t^2 = 75.2047
# Epoch 61, Iteration 3: H_t = 4, G_t = 2.4655, σ_t^2 = 66.2342
# Epoch 61, Iteration 4: H_t = 4, G_t = 3.0735, σ_t^2 = 77.9027
# Epoch 61, Iteration 5: H_t = 4, G_t = 2.4613, σ_t^2 = 83.4459
# Epoch 61, Iteration 6: H_t = 4, G_t = 2.8745, σ_t^2 = 81.6099
# Epoch 61, Iteration 7: H_t = 5, G_t = 3.7303, σ_t^2 = 70.9765
# Epoch 61, Iteration 8: H_t = 7, G_t = 5.4864, σ_t^2 = 77.6060
# Epoch 61, Iteration 9: H_t = 4, G_t = 1.1601, σ_t^2 = 86.7784
# Epoch 61, Iteration 10: H_t = 4, G_t = 0.3714, σ_t^2 = 72.2332
# Epoch 61, Iteration 11: H_t = 4, G_t = 0.3520, σ_t^2 = 79.0691
# Epoch 61, Iteration 12: H_t = 4, G_t = 0.5899, σ_t^2 = 71.3110
# Epoch 61, Iteration 13: H_t = 4, G_t = 1.3878, σ_t^2 = 69.0675
# Epoch 61, Iteration 14: H_t = 4, G_t = 0.6160, σ_t^2 = 84.6066
# Epoch 61, Iteration 15: H_t = 4, G_t = 0.0784, σ_t^2 = 77.0829
# Epoch 61, Iteration 16: H_t = 4, G_t = 0.5905, σ_t^2 = 86.6806
# Epoch 61, Iteration 17: H_t = 4, G_t = -0.5124, σ_t^2 = 87.9788
# Epoch 61, Iteration 18: H_t = 4, G_t = 0.3389, σ_t^2 = 74.8123
# Epoch 61, Iteration 19: H_t = 4, G_t = -0.3329, σ_t^2 = 81.0144
# Epoch 61, Iteration 20: H_t = 4, G_t = 1.2776, σ_t^2 = 75.9173
# Epoch 61, Iteration 21: H_t = 4, G_t = -0.7122, σ_t^2 = 71.9642
# Epoch 61, Iteration 22: H_t = 4, G_t = 2.4537, σ_t^2 = 79.5574
# Epoch 61, Iteration 23: H_t = 4, G_t = 2.2320, σ_t^2 = 72.3293
# Epoch 61, Iteration 24: H_t = 4, G_t = 1.5583, σ_t^2 = 84.6096
# Epoch 61, Iteration 25: H_t = 4, G_t = -4.2029, σ_t^2 = 86.5998
# Epoch 61, Iteration 26: H_t = 4, G_t = -0.0905, σ_t^2 = 82.8020
# Epoch 61, Iteration 27: H_t = 4, G_t = 0.9542, σ_t^2 = 85.5280
# Epoch 61, Iteration 28: H_t = 6, G_t = 4.8995, σ_t^2 = 79.7265
# Epoch 61, Iteration 29: H_t = 4, G_t = 2.7458, σ_t^2 = 90.9155
# Epoch 61, Iteration 30: H_t = 4, G_t = -0.9432, σ_t^2 = 87.2643
# Epoch 61, Iteration 31: H_t = 4, G_t = -0.2065, σ_t^2 = 69.9233
# Epoch 61, Iteration 32: H_t = 5, G_t = 4.1507, σ_t^2 = 73.8039
# Epoch 61, Iteration 33: H_t = 4, G_t = 4.4635, σ_t^2 = 95.5408
# Epoch 61, Iteration 34: H_t = 4, G_t = -2.0052, σ_t^2 = 87.1288
# Epoch 61, Iteration 35: H_t = 7, G_t = 5.2587, σ_t^2 = 75.0976
# Epoch 61, Iteration 36: H_t = 4, G_t = -0.2479, σ_t^2 = 92.4402
# Epoch 61, Iteration 37: H_t = 4, G_t = 2.7666, σ_t^2 = 83.0632
# Epoch 61, Iteration 38: H_t = 4, G_t = 2.6093, σ_t^2 = 70.1085
# Epoch 61, Iteration 39: H_t = 6, G_t = 4.1267, σ_t^2 = 65.7418
# Epoch 61, Iteration 40: H_t = 7, G_t = 5.3747, σ_t^2 = 74.8014
# Epoch 61, Iteration 41: H_t = 7, G_t = 4.3612, σ_t^2 = 61.7857
# Epoch 61, Iteration 42: H_t = 4, G_t = 2.2956, σ_t^2 = 80.4485
# Epoch 61, Iteration 43: H_t = 4, G_t = 1.0490, σ_t^2 = 86.1528
# Epoch 61, Iteration 44: H_t = 5, G_t = 4.0549, σ_t^2 = 79.9691
# Epoch 61, Iteration 45: H_t = 8, G_t = 6.8532, σ_t^2 = 76.4855
#     Worker 0: Train Loss: 1.7837, Train Accuracy: 51.54%
#     Worker 1: Train Loss: 1.7890, Train Accuracy: 51.21%
#     Worker 2: Train Loss: 1.7768, Train Accuracy: 51.57%
#     Worker 3: Train Loss: 1.7988, Train Accuracy: 50.98%
# Epoch 61: Test Loss: 2.0399, Test Accuracy: 46.83%
# Total Computation Time: 1472.90 seconds
# Total Communication Time: 2.81 seconds
# Epoch 62, Iteration 1: H_t = 6, G_t = 5.6111, σ_t^2 = 80.1644
# Epoch 62, Iteration 2: H_t = 4, G_t = -2.0509, σ_t^2 = 78.2564
# Epoch 62, Iteration 3: H_t = 4, G_t = 0.0673, σ_t^2 = 86.0835
# Epoch 62, Iteration 4: H_t = 4, G_t = -0.6097, σ_t^2 = 71.7801
# Epoch 62, Iteration 5: H_t = 4, G_t = -3.1608, σ_t^2 = 85.3986
# Epoch 62, Iteration 6: H_t = 6, G_t = 5.6364, σ_t^2 = 85.9504
# Epoch 62, Iteration 7: H_t = 4, G_t = -0.8239, σ_t^2 = 89.4631
# Epoch 62, Iteration 8: H_t = 6, G_t = 4.0900, σ_t^2 = 67.1887
# Epoch 62, Iteration 9: H_t = 4, G_t = 2.9449, σ_t^2 = 78.3301
# Epoch 62, Iteration 10: H_t = 4, G_t = 2.7327, σ_t^2 = 87.2286
# Epoch 62, Iteration 11: H_t = 4, G_t = 2.7273, σ_t^2 = 80.0080
# Epoch 62, Iteration 12: H_t = 4, G_t = 3.5778, σ_t^2 = 78.1995
# Epoch 62, Iteration 13: H_t = 4, G_t = 0.8046, σ_t^2 = 73.0447
# Epoch 62, Iteration 14: H_t = 6, G_t = 4.5426, σ_t^2 = 75.0094
# Epoch 62, Iteration 15: H_t = 4, G_t = 2.1470, σ_t^2 = 89.7076
# Epoch 62, Iteration 16: H_t = 4, G_t = 1.1774, σ_t^2 = 68.8867
# Epoch 62, Iteration 17: H_t = 4, G_t = -0.4381, σ_t^2 = 84.0367
# Epoch 62, Iteration 18: H_t = 4, G_t = -1.9828, σ_t^2 = 81.4896
# Epoch 62, Iteration 19: H_t = 4, G_t = -2.5912, σ_t^2 = 89.0813
# Epoch 62, Iteration 20: H_t = 4, G_t = -1.7758, σ_t^2 = 84.7977
# Epoch 62, Iteration 21: H_t = 4, G_t = -3.8082, σ_t^2 = 88.0235
# Epoch 62, Iteration 22: H_t = 4, G_t = -1.2452, σ_t^2 = 74.6204
# Epoch 62, Iteration 23: H_t = 4, G_t = 2.9686, σ_t^2 = 76.6923
# Epoch 62, Iteration 24: H_t = 6, G_t = 4.8200, σ_t^2 = 71.4123
# Epoch 62, Iteration 25: H_t = 4, G_t = -2.0487, σ_t^2 = 89.5129
# Epoch 62, Iteration 26: H_t = 4, G_t = -1.3878, σ_t^2 = 75.6737
# Epoch 62, Iteration 27: H_t = 4, G_t = 1.5985, σ_t^2 = 78.0827
# Epoch 62, Iteration 28: H_t = 4, G_t = -0.6943, σ_t^2 = 103.2471
# Epoch 62, Iteration 29: H_t = 4, G_t = 3.3052, σ_t^2 = 77.3566
# Epoch 62, Iteration 30: H_t = 4, G_t = -0.4218, σ_t^2 = 79.0053
# Epoch 62, Iteration 31: H_t = 6, G_t = 4.6699, σ_t^2 = 76.6374
# Epoch 62, Iteration 32: H_t = 4, G_t = 1.5594, σ_t^2 = 90.6134
# Epoch 62, Iteration 33: H_t = 4, G_t = 1.2173, σ_t^2 = 82.4439
# Epoch 62, Iteration 34: H_t = 4, G_t = 0.5766, σ_t^2 = 78.6321
# Epoch 62, Iteration 35: H_t = 4, G_t = -0.0040, σ_t^2 = 86.8992
# Epoch 62, Iteration 36: H_t = 4, G_t = 1.6527, σ_t^2 = 83.2860
# Epoch 62, Iteration 37: H_t = 11, G_t = 9.0687, σ_t^2 = 79.8014
# Epoch 62, Iteration 38: H_t = 4, G_t = -0.3506, σ_t^2 = 85.6159
# Epoch 62, Iteration 39: H_t = 4, G_t = -2.8428, σ_t^2 = 85.6096
# Epoch 62, Iteration 40: H_t = 6, G_t = 5.3865, σ_t^2 = 77.2280
# Epoch 62, Iteration 41: H_t = 4, G_t = -0.5843, σ_t^2 = 93.4715
# Epoch 62, Iteration 42: H_t = 6, G_t = 4.7788, σ_t^2 = 75.6236
# Epoch 62, Iteration 43: H_t = 4, G_t = 1.1030, σ_t^2 = 80.8872
#     Worker 0: Train Loss: 1.7694, Train Accuracy: 51.73%
#     Worker 1: Train Loss: 1.7739, Train Accuracy: 51.78%
#     Worker 2: Train Loss: 1.7711, Train Accuracy: 51.95%
#     Worker 3: Train Loss: 1.7683, Train Accuracy: 52.12%
# Epoch 62: Test Loss: 2.0249, Test Accuracy: 47.85%
# Total Computation Time: 1497.24 seconds
# Total Communication Time: 2.86 seconds
# Epoch 63, Iteration 1: H_t = 6, G_t = 5.4618, σ_t^2 = 79.1843
# Epoch 63, Iteration 2: H_t = 4, G_t = -0.9012, σ_t^2 = 87.6159
# Epoch 63, Iteration 3: H_t = 6, G_t = 4.1600, σ_t^2 = 68.0123
# Epoch 63, Iteration 4: H_t = 4, G_t = -1.5870, σ_t^2 = 79.2951
# Epoch 63, Iteration 5: H_t = 4, G_t = -1.7665, σ_t^2 = 84.6441
# Epoch 63, Iteration 6: H_t = 14, G_t = 10.8411, σ_t^2 = 74.5876
# Epoch 63, Iteration 7: H_t = 4, G_t = 0.1209, σ_t^2 = 86.0332
# Epoch 63, Iteration 8: H_t = 4, G_t = -2.5847, σ_t^2 = 82.1834
# Epoch 63, Iteration 9: H_t = 4, G_t = 2.3779, σ_t^2 = 72.0862
# Epoch 63, Iteration 10: H_t = 7, G_t = 5.3982, σ_t^2 = 73.8293
# Epoch 63, Iteration 11: H_t = 4, G_t = 0.4042, σ_t^2 = 88.0210
# Epoch 63, Iteration 12: H_t = 4, G_t = -2.8606, σ_t^2 = 86.0279
# Epoch 63, Iteration 13: H_t = 4, G_t = 1.7827, σ_t^2 = 75.7246
# Epoch 63, Iteration 14: H_t = 4, G_t = 2.2506, σ_t^2 = 62.0246
# Epoch 63, Iteration 15: H_t = 4, G_t = 1.0166, σ_t^2 = 85.7069
# Epoch 63, Iteration 16: H_t = 6, G_t = 4.8580, σ_t^2 = 80.3093
# Epoch 63, Iteration 17: H_t = 5, G_t = 4.1572, σ_t^2 = 79.9660
# Epoch 63, Iteration 18: H_t = 4, G_t = -6.2699, σ_t^2 = 106.1519
# Epoch 63, Iteration 19: H_t = 4, G_t = -1.7447, σ_t^2 = 85.3740
# Epoch 63, Iteration 20: H_t = 4, G_t = 2.9656, σ_t^2 = 80.0320
# Epoch 63, Iteration 21: H_t = 4, G_t = -1.6493, σ_t^2 = 91.5776
# Epoch 63, Iteration 22: H_t = 4, G_t = 1.9731, σ_t^2 = 69.7298
# Epoch 63, Iteration 23: H_t = 10, G_t = 7.5976, σ_t^2 = 70.3289
# Epoch 63, Iteration 24: H_t = 4, G_t = -0.2546, σ_t^2 = 78.0431
# Epoch 63, Iteration 25: H_t = 4, G_t = -0.7521, σ_t^2 = 73.6819
# Epoch 63, Iteration 26: H_t = 4, G_t = 0.3232, σ_t^2 = 79.6975
# Epoch 63, Iteration 27: H_t = 4, G_t = 0.3156, σ_t^2 = 74.5024
# Epoch 63, Iteration 28: H_t = 4, G_t = 0.0810, σ_t^2 = 77.8539
# Epoch 63, Iteration 29: H_t = 4, G_t = 2.9997, σ_t^2 = 71.7950
# Epoch 63, Iteration 30: H_t = 4, G_t = 1.1370, σ_t^2 = 75.3121
# Epoch 63, Iteration 31: H_t = 5, G_t = 4.0272, σ_t^2 = 77.9579
# Epoch 63, Iteration 32: H_t = 4, G_t = 2.5182, σ_t^2 = 87.7048
# Epoch 63, Iteration 33: H_t = 4, G_t = 2.1141, σ_t^2 = 74.9917
# Epoch 63, Iteration 34: H_t = 6, G_t = 4.6628, σ_t^2 = 77.4452
# Epoch 63, Iteration 35: H_t = 4, G_t = 3.7583, σ_t^2 = 92.4215
# Epoch 63, Iteration 36: H_t = 4, G_t = -1.0838, σ_t^2 = 84.8062
# Epoch 63, Iteration 37: H_t = 4, G_t = 1.5129, σ_t^2 = 84.8711
# Epoch 63, Iteration 38: H_t = 8, G_t = 5.9157, σ_t^2 = 68.9353
# Epoch 63, Iteration 39: H_t = 4, G_t = -0.1487, σ_t^2 = 89.9196
# Epoch 63, Iteration 40: H_t = 4, G_t = 2.8273, σ_t^2 = 66.0933
# Epoch 63, Iteration 41: H_t = 4, G_t = 1.0353, σ_t^2 = 88.7852
#     Worker 0: Train Loss: 1.7854, Train Accuracy: 51.71%
#     Worker 1: Train Loss: 1.7903, Train Accuracy: 51.61%
#     Worker 2: Train Loss: 1.7590, Train Accuracy: 51.96%
#     Worker 3: Train Loss: 1.7841, Train Accuracy: 51.12%
# Epoch 63: Test Loss: 2.0328, Test Accuracy: 46.75%
# Total Computation Time: 1521.36 seconds
# Total Communication Time: 2.91 seconds
# Epoch 64, Iteration 1: H_t = 6, G_t = 4.8764, σ_t^2 = 71.7291
# Epoch 64, Iteration 2: H_t = 4, G_t = 2.6255, σ_t^2 = 78.5698
# Epoch 64, Iteration 3: H_t = 4, G_t = 0.4279, σ_t^2 = 75.1475
# Epoch 64, Iteration 4: H_t = 4, G_t = 0.0718, σ_t^2 = 73.2774
# Epoch 64, Iteration 5: H_t = 4, G_t = -1.1716, σ_t^2 = 72.9934
# Epoch 64, Iteration 6: H_t = 4, G_t = -1.1618, σ_t^2 = 83.7245
# Epoch 64, Iteration 7: H_t = 4, G_t = 1.7609, σ_t^2 = 69.2431
# Epoch 64, Iteration 8: H_t = 4, G_t = 3.2675, σ_t^2 = 79.8683
# Epoch 64, Iteration 9: H_t = 4, G_t = 1.0149, σ_t^2 = 91.6017
# Epoch 64, Iteration 10: H_t = 4, G_t = 1.0346, σ_t^2 = 68.7866
# Epoch 64, Iteration 11: H_t = 4, G_t = -2.3300, σ_t^2 = 85.6495
# Epoch 64, Iteration 12: H_t = 4, G_t = -0.1820, σ_t^2 = 73.2982
# Epoch 64, Iteration 13: H_t = 5, G_t = 4.0682, σ_t^2 = 70.5334
# Epoch 64, Iteration 14: H_t = 4, G_t = -0.5661, σ_t^2 = 82.0370
# Epoch 64, Iteration 15: H_t = 4, G_t = -1.9949, σ_t^2 = 94.0976
# Epoch 64, Iteration 16: H_t = 4, G_t = 0.9133, σ_t^2 = 79.4379
# Epoch 64, Iteration 17: H_t = 4, G_t = 2.4277, σ_t^2 = 69.4779
# Epoch 64, Iteration 18: H_t = 4, G_t = -2.1385, σ_t^2 = 82.2788
# Epoch 64, Iteration 19: H_t = 4, G_t = -2.5843, σ_t^2 = 75.9572
# Epoch 64, Iteration 20: H_t = 4, G_t = -2.0964, σ_t^2 = 92.3688
# Epoch 64, Iteration 21: H_t = 4, G_t = 0.3474, σ_t^2 = 94.1088
# Epoch 64, Iteration 22: H_t = 4, G_t = 2.8695, σ_t^2 = 76.3054
# Epoch 64, Iteration 23: H_t = 4, G_t = 1.1847, σ_t^2 = 69.4420
# Epoch 64, Iteration 24: H_t = 4, G_t = 0.3510, σ_t^2 = 83.4095
# Epoch 64, Iteration 25: H_t = 4, G_t = -2.2093, σ_t^2 = 84.2032
# Epoch 64, Iteration 26: H_t = 9, G_t = 7.2773, σ_t^2 = 78.8942
# Epoch 64, Iteration 27: H_t = 4, G_t = -0.6079, σ_t^2 = 86.5235
# Epoch 64, Iteration 28: H_t = 4, G_t = -0.6708, σ_t^2 = 74.3287
# Epoch 64, Iteration 29: H_t = 7, G_t = 5.6594, σ_t^2 = 77.0557
# Epoch 64, Iteration 30: H_t = 4, G_t = 1.3526, σ_t^2 = 92.9556
# Epoch 64, Iteration 31: H_t = 4, G_t = 1.4891, σ_t^2 = 81.6592
# Epoch 64, Iteration 32: H_t = 4, G_t = 2.4707, σ_t^2 = 75.9745
# Epoch 64, Iteration 33: H_t = 4, G_t = 1.6289, σ_t^2 = 88.0199
# Epoch 64, Iteration 34: H_t = 4, G_t = -0.5337, σ_t^2 = 91.8556
# Epoch 64, Iteration 35: H_t = 5, G_t = 5.4302, σ_t^2 = 94.1058
# Epoch 64, Iteration 36: H_t = 4, G_t = 3.6702, σ_t^2 = 78.8933
# Epoch 64, Iteration 37: H_t = 4, G_t = 1.0710, σ_t^2 = 68.2835
# Epoch 64, Iteration 38: H_t = 4, G_t = -0.3878, σ_t^2 = 87.0956
# Epoch 64, Iteration 39: H_t = 4, G_t = -1.9169, σ_t^2 = 81.6049
# Epoch 64, Iteration 40: H_t = 4, G_t = 2.4487, σ_t^2 = 82.5351
# Epoch 64, Iteration 41: H_t = 4, G_t = 3.4220, σ_t^2 = 94.4103
# Epoch 64, Iteration 42: H_t = 4, G_t = -1.9600, σ_t^2 = 95.2501
# Epoch 64, Iteration 43: H_t = 8, G_t = 6.9301, σ_t^2 = 82.2856
# Epoch 64, Iteration 44: H_t = 4, G_t = 0.1883, σ_t^2 = 91.5035
# Epoch 64, Iteration 45: H_t = 12, G_t = 10.9390, σ_t^2 = 91.1070
#     Worker 0: Train Loss: 1.7467, Train Accuracy: 52.52%
#     Worker 1: Train Loss: 1.7354, Train Accuracy: 52.90%
#     Worker 2: Train Loss: 1.7608, Train Accuracy: 52.33%
#     Worker 3: Train Loss: 1.7412, Train Accuracy: 52.68%
# Epoch 64: Test Loss: 2.0178, Test Accuracy: 47.83%
# Total Computation Time: 1545.54 seconds
# Total Communication Time: 2.96 seconds
# Epoch 65, Iteration 1: H_t = 4, G_t = 1.2536, σ_t^2 = 86.3964
# Epoch 65, Iteration 2: H_t = 4, G_t = 2.2334, σ_t^2 = 81.4418
# Epoch 65, Iteration 3: H_t = 4, G_t = 3.0055, σ_t^2 = 67.4200
# Epoch 65, Iteration 4: H_t = 4, G_t = 2.9486, σ_t^2 = 71.9566
# Epoch 65, Iteration 5: H_t = 4, G_t = 0.9252, σ_t^2 = 91.6105
# Epoch 65, Iteration 6: H_t = 4, G_t = -0.2308, σ_t^2 = 84.2107
# Epoch 65, Iteration 7: H_t = 4, G_t = 3.0342, σ_t^2 = 87.2287
# Epoch 65, Iteration 8: H_t = 4, G_t = -2.6135, σ_t^2 = 83.6534
# Epoch 65, Iteration 9: H_t = 4, G_t = 1.4249, σ_t^2 = 85.8875
# Epoch 65, Iteration 10: H_t = 4, G_t = -1.0513, σ_t^2 = 80.5621
# Epoch 65, Iteration 11: H_t = 5, G_t = 4.8460, σ_t^2 = 88.2030
# Epoch 65, Iteration 12: H_t = 4, G_t = 2.5252, σ_t^2 = 81.8834
# Epoch 65, Iteration 13: H_t = 4, G_t = -3.1286, σ_t^2 = 98.7259
# Epoch 65, Iteration 14: H_t = 8, G_t = 6.1358, σ_t^2 = 72.6637
# Epoch 65, Iteration 15: H_t = 4, G_t = 0.9533, σ_t^2 = 93.1732
# Epoch 65, Iteration 16: H_t = 4, G_t = 0.3487, σ_t^2 = 81.3564
# Epoch 65, Iteration 17: H_t = 4, G_t = -0.4227, σ_t^2 = 68.3213
# Epoch 65, Iteration 18: H_t = 4, G_t = -0.0082, σ_t^2 = 80.4553
# Epoch 65, Iteration 19: H_t = 4, G_t = -1.0378, σ_t^2 = 82.5550
# Epoch 65, Iteration 20: H_t = 6, G_t = 5.1216, σ_t^2 = 84.2532
# Epoch 65, Iteration 21: H_t = 4, G_t = 1.5611, σ_t^2 = 85.4129
# Epoch 65, Iteration 22: H_t = 8, G_t = 8.0611, σ_t^2 = 90.4823
# Epoch 65, Iteration 23: H_t = 6, G_t = 6.5059, σ_t^2 = 94.0446
# Epoch 65, Iteration 24: H_t = 4, G_t = 4.0199, σ_t^2 = 81.7719
# Epoch 65, Iteration 25: H_t = 4, G_t = 1.7228, σ_t^2 = 87.8458
# Epoch 65, Iteration 26: H_t = 4, G_t = -0.4991, σ_t^2 = 87.9544
# Epoch 65, Iteration 27: H_t = 4, G_t = 0.2276, σ_t^2 = 76.8500
# Epoch 65, Iteration 28: H_t = 5, G_t = 3.8044, σ_t^2 = 73.7566
# Epoch 65, Iteration 29: H_t = 6, G_t = 5.1730, σ_t^2 = 79.6746
# Epoch 65, Iteration 30: H_t = 5, G_t = 4.3175, σ_t^2 = 78.6144
# Epoch 65, Iteration 31: H_t = 4, G_t = -0.1463, σ_t^2 = 79.6020
# Epoch 65, Iteration 32: H_t = 4, G_t = 3.6978, σ_t^2 = 91.6039
# Epoch 65, Iteration 33: H_t = 6, G_t = 5.5496, σ_t^2 = 83.8498
# Epoch 65, Iteration 34: H_t = 5, G_t = 4.9795, σ_t^2 = 86.2821
# Epoch 65, Iteration 35: H_t = 4, G_t = -1.5696, σ_t^2 = 91.9405
# Epoch 65, Iteration 36: H_t = 4, G_t = -4.1656, σ_t^2 = 92.4057
# Epoch 65, Iteration 37: H_t = 8, G_t = 6.6728, σ_t^2 = 76.7702
# Epoch 65, Iteration 38: H_t = 4, G_t = -2.1520, σ_t^2 = 92.5211
# Epoch 65, Iteration 39: H_t = 4, G_t = 0.4806, σ_t^2 = 86.4992
# Epoch 65, Iteration 40: H_t = 4, G_t = -3.5855, σ_t^2 = 88.3268
# Epoch 65, Iteration 41: H_t = 4, G_t = 3.1993, σ_t^2 = 64.4280
#     Worker 0: Train Loss: 1.7538, Train Accuracy: 51.78%
#     Worker 1: Train Loss: 1.7480, Train Accuracy: 52.50%
#     Worker 2: Train Loss: 1.7445, Train Accuracy: 52.62%
#     Worker 3: Train Loss: 1.7414, Train Accuracy: 52.59%
# Epoch 65: Test Loss: 2.0089, Test Accuracy: 47.99%
# Total Computation Time: 1570.02 seconds
# Total Communication Time: 3.01 seconds
# Epoch 66, Iteration 1: H_t = 4, G_t = -0.9420, σ_t^2 = 83.2644
# Epoch 66, Iteration 2: H_t = 4, G_t = -1.0929, σ_t^2 = 84.0796
# Epoch 66, Iteration 3: H_t = 4, G_t = -0.8136, σ_t^2 = 78.6561
# Epoch 66, Iteration 4: H_t = 5, G_t = 4.4880, σ_t^2 = 80.1766
# Epoch 66, Iteration 5: H_t = 4, G_t = -3.1162, σ_t^2 = 82.6538
# Epoch 66, Iteration 6: H_t = 4, G_t = 1.0564, σ_t^2 = 85.5672
# Epoch 66, Iteration 7: H_t = 4, G_t = -1.6136, σ_t^2 = 84.8642
# Epoch 66, Iteration 8: H_t = 5, G_t = 4.8457, σ_t^2 = 83.2646
# Epoch 66, Iteration 9: H_t = 5, G_t = 3.9417, σ_t^2 = 76.2681
# Epoch 66, Iteration 10: H_t = 4, G_t = -3.8071, σ_t^2 = 258.2438
# Epoch 66, Iteration 11: H_t = 4, G_t = 0.9604, σ_t^2 = 80.2149
# Epoch 66, Iteration 12: H_t = 4, G_t = 2.3206, σ_t^2 = 73.4435
# Epoch 66, Iteration 13: H_t = 4, G_t = 0.7497, σ_t^2 = 83.8516
# Epoch 66, Iteration 14: H_t = 4, G_t = -0.4560, σ_t^2 = 93.3655
# Epoch 66, Iteration 15: H_t = 4, G_t = 3.6183, σ_t^2 = 93.2066
# Epoch 66, Iteration 16: H_t = 4, G_t = 1.0590, σ_t^2 = 85.3156
# Epoch 66, Iteration 17: H_t = 4, G_t = 1.2934, σ_t^2 = 83.8528
# Epoch 66, Iteration 18: H_t = 4, G_t = -0.3885, σ_t^2 = 78.7670
# Epoch 66, Iteration 19: H_t = 4, G_t = 0.4414, σ_t^2 = 75.0061
# Epoch 66, Iteration 20: H_t = 4, G_t = 1.9326, σ_t^2 = 84.1727
# Epoch 66, Iteration 21: H_t = 4, G_t = 3.9322, σ_t^2 = 83.9948
# Epoch 66, Iteration 22: H_t = 7, G_t = 7.5208, σ_t^2 = 100.7735
# Epoch 66, Iteration 23: H_t = 7, G_t = 6.5477, σ_t^2 = 84.0718
# Epoch 66, Iteration 24: H_t = 4, G_t = -0.7006, σ_t^2 = 81.5527
# Epoch 66, Iteration 25: H_t = 4, G_t = 2.7308, σ_t^2 = 81.7794
# Epoch 66, Iteration 26: H_t = 4, G_t = 2.3273, σ_t^2 = 79.1026
# Epoch 66, Iteration 27: H_t = 4, G_t = 1.7098, σ_t^2 = 70.9772
# Epoch 66, Iteration 28: H_t = 4, G_t = -0.4572, σ_t^2 = 71.7696
# Epoch 66, Iteration 29: H_t = 4, G_t = 3.0076, σ_t^2 = 72.8973
# Epoch 66, Iteration 30: H_t = 4, G_t = -2.1795, σ_t^2 = 73.8712
# Epoch 66, Iteration 31: H_t = 4, G_t = -1.2478, σ_t^2 = 93.1077
# Epoch 66, Iteration 32: H_t = 4, G_t = 1.5973, σ_t^2 = 81.4410
# Epoch 66, Iteration 33: H_t = 6, G_t = 4.7606, σ_t^2 = 74.0368
# Epoch 66, Iteration 34: H_t = 4, G_t = 1.1074, σ_t^2 = 80.3509
# Epoch 66, Iteration 35: H_t = 6, G_t = 4.5009, σ_t^2 = 64.5472
# Epoch 66, Iteration 36: H_t = 4, G_t = 2.7743, σ_t^2 = 79.1777
# Epoch 66, Iteration 37: H_t = 4, G_t = 3.4325, σ_t^2 = 78.1238
# Epoch 66, Iteration 38: H_t = 4, G_t = 1.5454, σ_t^2 = 71.4639
# Epoch 66, Iteration 39: H_t = 4, G_t = 2.1252, σ_t^2 = 75.2529
# Epoch 66, Iteration 40: H_t = 4, G_t = 3.6731, σ_t^2 = 83.3390
# Epoch 66, Iteration 41: H_t = 6, G_t = 4.7291, σ_t^2 = 78.1898
# Epoch 66, Iteration 42: H_t = 4, G_t = 1.5876, σ_t^2 = 76.4202
# Epoch 66, Iteration 43: H_t = 6, G_t = 5.3490, σ_t^2 = 80.2014
# Epoch 66, Iteration 44: H_t = 4, G_t = 1.3640, σ_t^2 = 82.4113
# Epoch 66, Iteration 45: H_t = 14, G_t = 12.4471, σ_t^2 = 86.2445
#     Worker 0: Train Loss: 1.7304, Train Accuracy: 52.48%
#     Worker 1: Train Loss: 1.7131, Train Accuracy: 53.40%
#     Worker 2: Train Loss: 1.6979, Train Accuracy: 53.31%
#     Worker 3: Train Loss: 1.7356, Train Accuracy: 52.95%
# Epoch 66: Test Loss: 2.0110, Test Accuracy: 47.87%
# Total Computation Time: 1594.97 seconds
# Total Communication Time: 3.07 seconds
# Epoch 67, Iteration 1: H_t = 4, G_t = -0.7891, σ_t^2 = 88.5122
# Epoch 67, Iteration 2: H_t = 6, G_t = 6.2566, σ_t^2 = 95.9271
# Epoch 67, Iteration 3: H_t = 7, G_t = 7.5931, σ_t^2 = 98.5331
# Epoch 67, Iteration 4: H_t = 6, G_t = 5.0595, σ_t^2 = 78.6352
# Epoch 67, Iteration 5: H_t = 4, G_t = -1.0826, σ_t^2 = 82.0096
# Epoch 67, Iteration 6: H_t = 4, G_t = 0.0029, σ_t^2 = 78.4014
# Epoch 67, Iteration 7: H_t = 5, G_t = 3.9292, σ_t^2 = 72.8463
# Epoch 67, Iteration 8: H_t = 4, G_t = 0.0052, σ_t^2 = 71.3965
# Epoch 67, Iteration 9: H_t = 4, G_t = 2.8449, σ_t^2 = 77.8130
# Epoch 67, Iteration 10: H_t = 4, G_t = -0.5600, σ_t^2 = 74.7006
# Epoch 67, Iteration 11: H_t = 4, G_t = -1.3034, σ_t^2 = 77.3835
# Epoch 67, Iteration 12: H_t = 6, G_t = 5.2555, σ_t^2 = 77.9474
# Epoch 67, Iteration 13: H_t = 6, G_t = 5.1299, σ_t^2 = 80.0283
# Epoch 67, Iteration 14: H_t = 4, G_t = 1.8516, σ_t^2 = 85.2839
# Epoch 67, Iteration 15: H_t = 4, G_t = 3.2959, σ_t^2 = 81.6806
# Epoch 67, Iteration 16: H_t = 4, G_t = 2.2307, σ_t^2 = 81.4469
# Epoch 67, Iteration 17: H_t = 4, G_t = 3.0334, σ_t^2 = 88.2107
# Epoch 67, Iteration 18: H_t = 4, G_t = 2.1247, σ_t^2 = 85.8876
# Epoch 67, Iteration 19: H_t = 4, G_t = -0.0728, σ_t^2 = 85.9898
# Epoch 67, Iteration 20: H_t = 6, G_t = 6.0136, σ_t^2 = 86.5718
# Epoch 67, Iteration 21: H_t = 4, G_t = -0.5982, σ_t^2 = 80.1314
# Epoch 67, Iteration 22: H_t = 4, G_t = 1.0396, σ_t^2 = 77.8594
# Epoch 67, Iteration 23: H_t = 4, G_t = 0.5425, σ_t^2 = 73.8129
# Epoch 67, Iteration 24: H_t = 4, G_t = -0.9809, σ_t^2 = 94.3221
# Epoch 67, Iteration 25: H_t = 4, G_t = -1.3080, σ_t^2 = 94.0707
# Epoch 67, Iteration 26: H_t = 4, G_t = 2.0601, σ_t^2 = 75.9102
# Epoch 67, Iteration 27: H_t = 4, G_t = 3.8167, σ_t^2 = 77.4622
# Epoch 67, Iteration 28: H_t = 4, G_t = 1.0138, σ_t^2 = 95.2950
# Epoch 67, Iteration 29: H_t = 4, G_t = 1.4131, σ_t^2 = 73.6476
# Epoch 67, Iteration 30: H_t = 4, G_t = 2.5944, σ_t^2 = 82.6941
# Epoch 67, Iteration 31: H_t = 4, G_t = -3.7446, σ_t^2 = 86.3619
# Epoch 67, Iteration 32: H_t = 4, G_t = -0.7182, σ_t^2 = 82.7057
# Epoch 67, Iteration 33: H_t = 4, G_t = 1.5215, σ_t^2 = 71.8038
# Epoch 67, Iteration 34: H_t = 5, G_t = 3.9301, σ_t^2 = 71.1373
# Epoch 67, Iteration 35: H_t = 4, G_t = 0.1987, σ_t^2 = 89.7898
# Epoch 67, Iteration 36: H_t = 4, G_t = 0.3391, σ_t^2 = 82.5612
# Epoch 67, Iteration 37: H_t = 4, G_t = 3.7262, σ_t^2 = 83.9815
# Epoch 67, Iteration 38: H_t = 4, G_t = 2.4589, σ_t^2 = 84.6653
# Epoch 67, Iteration 39: H_t = 4, G_t = 0.1784, σ_t^2 = 81.9721
# Epoch 67, Iteration 40: H_t = 4, G_t = -0.1139, σ_t^2 = 80.0460
# Epoch 67, Iteration 41: H_t = 4, G_t = 2.5700, σ_t^2 = 82.6717
# Epoch 67, Iteration 42: H_t = 4, G_t = 1.2344, σ_t^2 = 84.8993
# Epoch 67, Iteration 43: H_t = 4, G_t = 1.9760, σ_t^2 = 83.0571
#     Worker 0: Train Loss: 1.7169, Train Accuracy: 53.02%
#     Worker 1: Train Loss: 1.7130, Train Accuracy: 52.94%
#     Worker 2: Train Loss: 1.7034, Train Accuracy: 53.02%
#     Worker 3: Train Loss: 1.7239, Train Accuracy: 52.54%
# Epoch 67: Test Loss: 2.0024, Test Accuracy: 48.27%
# Total Computation Time: 1619.30 seconds
# Total Communication Time: 3.12 seconds
# Epoch 68, Iteration 1: H_t = 4, G_t = -4.0626, σ_t^2 = 89.3735
# Epoch 68, Iteration 2: H_t = 6, G_t = 5.5745, σ_t^2 = 85.7615
# Epoch 68, Iteration 3: H_t = 4, G_t = 2.1421, σ_t^2 = 93.1962
# Epoch 68, Iteration 4: H_t = 11, G_t = 11.5012, σ_t^2 = 99.3862
# Epoch 68, Iteration 5: H_t = 4, G_t = 2.9747, σ_t^2 = 96.7090
# Epoch 68, Iteration 6: H_t = 4, G_t = 1.3884, σ_t^2 = 89.9805
# Epoch 68, Iteration 7: H_t = 4, G_t = -1.3010, σ_t^2 = 79.1506
# Epoch 68, Iteration 8: H_t = 4, G_t = 1.3297, σ_t^2 = 277.9697
# Epoch 68, Iteration 9: H_t = 4, G_t = 2.0417, σ_t^2 = 71.8336
# Epoch 68, Iteration 10: H_t = 5, G_t = 4.1202, σ_t^2 = 81.7864
# Epoch 68, Iteration 11: H_t = 4, G_t = 0.6862, σ_t^2 = 76.0656
# Epoch 68, Iteration 12: H_t = 4, G_t = -1.2409, σ_t^2 = 85.0080
# Epoch 68, Iteration 13: H_t = 4, G_t = -2.6945, σ_t^2 = 86.1688
# Epoch 68, Iteration 14: H_t = 4, G_t = 1.0800, σ_t^2 = 85.1316
# Epoch 68, Iteration 15: H_t = 9, G_t = 6.8126, σ_t^2 = 74.6213
# Epoch 68, Iteration 16: H_t = 4, G_t = 1.3420, σ_t^2 = 81.2635
# Epoch 68, Iteration 17: H_t = 4, G_t = 0.7983, σ_t^2 = 77.1186
# Epoch 68, Iteration 18: H_t = 4, G_t = -3.1282, σ_t^2 = 79.6480
# Epoch 68, Iteration 19: H_t = 4, G_t = 2.1974, σ_t^2 = 77.3301
# Epoch 68, Iteration 20: H_t = 4, G_t = 1.8709, σ_t^2 = 92.5023
# Epoch 68, Iteration 21: H_t = 4, G_t = 1.5943, σ_t^2 = 67.4315
# Epoch 68, Iteration 22: H_t = 4, G_t = 2.2317, σ_t^2 = 82.0675
# Epoch 68, Iteration 23: H_t = 4, G_t = 2.6646, σ_t^2 = 87.4196
# Epoch 68, Iteration 24: H_t = 4, G_t = 2.1118, σ_t^2 = 89.1701
# Epoch 68, Iteration 25: H_t = 4, G_t = 1.1782, σ_t^2 = 82.2465
# Epoch 68, Iteration 26: H_t = 4, G_t = -0.1675, σ_t^2 = 84.7789
# Epoch 68, Iteration 27: H_t = 4, G_t = 0.0697, σ_t^2 = 84.9260
# Epoch 68, Iteration 28: H_t = 4, G_t = 2.9815, σ_t^2 = 85.4787
# Epoch 68, Iteration 29: H_t = 4, G_t = 3.2509, σ_t^2 = 81.1586
# Epoch 68, Iteration 30: H_t = 4, G_t = -0.0646, σ_t^2 = 95.2380
# Epoch 68, Iteration 31: H_t = 4, G_t = -0.3577, σ_t^2 = 91.8213
# Epoch 68, Iteration 32: H_t = 5, G_t = 4.0526, σ_t^2 = 70.2097
# Epoch 68, Iteration 33: H_t = 10, G_t = 8.9293, σ_t^2 = 81.7631
# Epoch 68, Iteration 34: H_t = 4, G_t = 2.7925, σ_t^2 = 90.1164
# Epoch 68, Iteration 35: H_t = 4, G_t = 1.4694, σ_t^2 = 83.2528
# Epoch 68, Iteration 36: H_t = 4, G_t = 2.3785, σ_t^2 = 80.1246
# Epoch 68, Iteration 37: H_t = 4, G_t = 2.1088, σ_t^2 = 84.2222
# Epoch 68, Iteration 38: H_t = 4, G_t = 2.5278, σ_t^2 = 70.4061
# Epoch 68, Iteration 39: H_t = 4, G_t = 2.7393, σ_t^2 = 84.6438
# Epoch 68, Iteration 40: H_t = 4, G_t = 1.6027, σ_t^2 = 85.4171
# Epoch 68, Iteration 41: H_t = 4, G_t = 0.1850, σ_t^2 = 82.7234
# Epoch 68, Iteration 42: H_t = 4, G_t = 0.9339, σ_t^2 = 80.2281
# Epoch 68, Iteration 43: H_t = 6, G_t = 5.1074, σ_t^2 = 75.5340
# Epoch 68, Iteration 44: H_t = 4, G_t = 1.9833, σ_t^2 = 92.6284
#     Worker 0: Train Loss: 1.7076, Train Accuracy: 53.07%
#     Worker 1: Train Loss: 1.7062, Train Accuracy: 53.32%
#     Worker 2: Train Loss: 1.7162, Train Accuracy: 53.01%
#     Worker 3: Train Loss: 1.6928, Train Accuracy: 53.44%
# Epoch 68: Test Loss: 2.0068, Test Accuracy: 48.09%
# Total Computation Time: 1643.81 seconds
# Total Communication Time: 3.17 seconds
# Epoch 69, Iteration 1: H_t = 4, G_t = 0.2245, σ_t^2 = 76.8314
# Epoch 69, Iteration 2: H_t = 4, G_t = -3.5476, σ_t^2 = 88.7591
# Epoch 69, Iteration 3: H_t = 6, G_t = 5.6701, σ_t^2 = 90.0597
# Epoch 69, Iteration 4: H_t = 4, G_t = -0.6388, σ_t^2 = 98.9595
# Epoch 69, Iteration 5: H_t = 4, G_t = -2.7332, σ_t^2 = 88.1771
# Epoch 69, Iteration 6: H_t = 4, G_t = 2.6347, σ_t^2 = 74.3705
# Epoch 69, Iteration 7: H_t = 4, G_t = 2.5853, σ_t^2 = 83.0435
# Epoch 69, Iteration 8: H_t = 4, G_t = 2.0972, σ_t^2 = 89.8550
# Epoch 69, Iteration 9: H_t = 4, G_t = -0.2002, σ_t^2 = 72.7623
# Epoch 69, Iteration 10: H_t = 4, G_t = 0.8338, σ_t^2 = 83.2312
# Epoch 69, Iteration 11: H_t = 5, G_t = 4.6358, σ_t^2 = 83.9917
# Epoch 69, Iteration 12: H_t = 4, G_t = 3.1327, σ_t^2 = 80.9133
# Epoch 69, Iteration 13: H_t = 4, G_t = -0.2294, σ_t^2 = 84.4720
# Epoch 69, Iteration 14: H_t = 6, G_t = 5.2362, σ_t^2 = 78.0711
# Epoch 69, Iteration 15: H_t = 4, G_t = -2.1626, σ_t^2 = 92.5125
# Epoch 69, Iteration 16: H_t = 4, G_t = 1.2624, σ_t^2 = 92.2063
# Epoch 69, Iteration 17: H_t = 4, G_t = -0.5201, σ_t^2 = 91.9694
# Epoch 69, Iteration 18: H_t = 4, G_t = 3.2267, σ_t^2 = 92.0351
# Epoch 69, Iteration 19: H_t = 4, G_t = 3.1239, σ_t^2 = 80.8859
# Epoch 69, Iteration 20: H_t = 11, G_t = 10.5263, σ_t^2 = 87.9930
# Epoch 69, Iteration 21: H_t = 4, G_t = 3.9504, σ_t^2 = 83.1227
# Epoch 69, Iteration 22: H_t = 4, G_t = -1.2634, σ_t^2 = 85.2290
# Epoch 69, Iteration 23: H_t = 4, G_t = 0.6840, σ_t^2 = 81.4991
# Epoch 69, Iteration 24: H_t = 5, G_t = 4.7465, σ_t^2 = 86.0379
# Epoch 69, Iteration 25: H_t = 4, G_t = -1.8521, σ_t^2 = 78.4434
# Epoch 69, Iteration 26: H_t = 4, G_t = 3.3651, σ_t^2 = 86.0028
# Epoch 69, Iteration 27: H_t = 7, G_t = 5.7700, σ_t^2 = 79.3162
# Epoch 69, Iteration 28: H_t = 4, G_t = -2.6331, σ_t^2 = 84.1342
# Epoch 69, Iteration 29: H_t = 4, G_t = 3.1654, σ_t^2 = 69.5833
# Epoch 69, Iteration 30: H_t = 4, G_t = 0.7377, σ_t^2 = 90.5646
# Epoch 69, Iteration 31: H_t = 10, G_t = 8.6152, σ_t^2 = 80.5655
# Epoch 69, Iteration 32: H_t = 4, G_t = -1.3937, σ_t^2 = 93.9772
# Epoch 69, Iteration 33: H_t = 4, G_t = 2.6128, σ_t^2 = 86.0112
# Epoch 69, Iteration 34: H_t = 4, G_t = 1.6397, σ_t^2 = 83.5368
# Epoch 69, Iteration 35: H_t = 4, G_t = -0.2135, σ_t^2 = 89.4562
# Epoch 69, Iteration 36: H_t = 4, G_t = 3.3858, σ_t^2 = 90.4259
# Epoch 69, Iteration 37: H_t = 4, G_t = 2.9123, σ_t^2 = 78.6036
# Epoch 69, Iteration 38: H_t = 4, G_t = 0.5306, σ_t^2 = 81.5393
# Epoch 69, Iteration 39: H_t = 4, G_t = 0.9901, σ_t^2 = 88.0490
# Epoch 69, Iteration 40: H_t = 4, G_t = 3.9115, σ_t^2 = 85.2104
# Epoch 69, Iteration 41: H_t = 9, G_t = 7.6980, σ_t^2 = 81.8469
# Epoch 69, Iteration 42: H_t = 4, G_t = -2.0711, σ_t^2 = 92.2154
# Epoch 69, Iteration 43: H_t = 4, G_t = -0.2189, σ_t^2 = 90.9849
#     Worker 0: Train Loss: 1.6957, Train Accuracy: 52.87%
#     Worker 1: Train Loss: 1.6908, Train Accuracy: 53.89%
#     Worker 2: Train Loss: 1.6855, Train Accuracy: 53.73%
#     Worker 3: Train Loss: 1.6965, Train Accuracy: 53.24%
# Epoch 69: Test Loss: 1.9929, Test Accuracy: 48.25%
# Total Computation Time: 1667.75 seconds
# Total Communication Time: 3.22 seconds
# Epoch 70, Iteration 1: H_t = 5, G_t = 4.1340, σ_t^2 = 73.6102
# Epoch 70, Iteration 2: H_t = 4, G_t = -1.7164, σ_t^2 = 93.8183
# Epoch 70, Iteration 3: H_t = 4, G_t = -0.5057, σ_t^2 = 85.3123
# Epoch 70, Iteration 4: H_t = 4, G_t = 0.8011, σ_t^2 = 68.4910
# Epoch 70, Iteration 5: H_t = 6, G_t = 5.2949, σ_t^2 = 80.1315
# Epoch 70, Iteration 6: H_t = 7, G_t = 5.9708, σ_t^2 = 77.5371
# Epoch 70, Iteration 7: H_t = 4, G_t = -2.9298, σ_t^2 = 260.4587
# Epoch 70, Iteration 8: H_t = 5, G_t = 4.8240, σ_t^2 = 85.6029
# Epoch 70, Iteration 9: H_t = 4, G_t = 2.1315, σ_t^2 = 94.1217
# Epoch 70, Iteration 10: H_t = 4, G_t = -0.2146, σ_t^2 = 91.7310
# Epoch 70, Iteration 11: H_t = 4, G_t = 0.1812, σ_t^2 = 79.4284
# Epoch 70, Iteration 12: H_t = 4, G_t = 1.7939, σ_t^2 = 75.8217
# Epoch 70, Iteration 13: H_t = 4, G_t = 2.4800, σ_t^2 = 76.3682
# Epoch 70, Iteration 14: H_t = 7, G_t = 7.4087, σ_t^2 = 97.6151
# Epoch 70, Iteration 15: H_t = 4, G_t = -1.3671, σ_t^2 = 85.4527
# Epoch 70, Iteration 16: H_t = 4, G_t = -1.3349, σ_t^2 = 89.0838
# Epoch 70, Iteration 17: H_t = 4, G_t = 3.6335, σ_t^2 = 93.0271
# Epoch 70, Iteration 18: H_t = 4, G_t = 1.6667, σ_t^2 = 82.5640
# Epoch 70, Iteration 19: H_t = 4, G_t = 3.1392, σ_t^2 = 84.4154
# Epoch 70, Iteration 20: H_t = 4, G_t = 3.1892, σ_t^2 = 85.5484
# Epoch 70, Iteration 21: H_t = 4, G_t = 1.1311, σ_t^2 = 84.4178
# Epoch 70, Iteration 22: H_t = 4, G_t = 3.9330, σ_t^2 = 93.0913
# Epoch 70, Iteration 23: H_t = 4, G_t = 2.5337, σ_t^2 = 85.5838
# Epoch 70, Iteration 24: H_t = 6, G_t = 6.1134, σ_t^2 = 95.6797
# Epoch 70, Iteration 25: H_t = 4, G_t = 0.9666, σ_t^2 = 92.8680
# Epoch 70, Iteration 26: H_t = 4, G_t = 0.5512, σ_t^2 = 78.4728
# Epoch 70, Iteration 27: H_t = 4, G_t = 0.5801, σ_t^2 = 78.1598
# Epoch 70, Iteration 28: H_t = 13, G_t = 9.9994, σ_t^2 = 74.1308
# Epoch 70, Iteration 29: H_t = 4, G_t = 1.9273, σ_t^2 = 93.5811
# Epoch 70, Iteration 30: H_t = 8, G_t = 6.8416, σ_t^2 = 83.9915
# Epoch 70, Iteration 31: H_t = 5, G_t = 5.2194, σ_t^2 = 95.4821
# Epoch 70, Iteration 32: H_t = 4, G_t = 2.9497, σ_t^2 = 82.5627
# Epoch 70, Iteration 33: H_t = 4, G_t = 0.4791, σ_t^2 = 79.9691
# Epoch 70, Iteration 34: H_t = 4, G_t = 1.3537, σ_t^2 = 78.8054
# Epoch 70, Iteration 35: H_t = 4, G_t = 3.4480, σ_t^2 = 83.7237
# Epoch 70, Iteration 36: H_t = 4, G_t = -0.8147, σ_t^2 = 78.7733
# Epoch 70, Iteration 37: H_t = 4, G_t = 0.3788, σ_t^2 = 72.9836
# Epoch 70, Iteration 38: H_t = 4, G_t = 2.7198, σ_t^2 = 85.8685
# Epoch 70, Iteration 39: H_t = 5, G_t = 4.0594, σ_t^2 = 81.0629
# Epoch 70, Iteration 40: H_t = 4, G_t = -0.1388, σ_t^2 = 91.0894
# Epoch 70, Iteration 41: H_t = 4, G_t = -1.0735, σ_t^2 = 94.9646
# Epoch 70, Iteration 42: H_t = 4, G_t = 3.8593, σ_t^2 = 83.2249
# Epoch 70, Iteration 43: H_t = 4, G_t = 3.3275, σ_t^2 = 95.6199
#     Worker 0: Train Loss: 1.6847, Train Accuracy: 53.66%
#     Worker 1: Train Loss: 1.6920, Train Accuracy: 53.51%
#     Worker 2: Train Loss: 1.6880, Train Accuracy: 53.81%
#     Worker 3: Train Loss: 1.6881, Train Accuracy: 54.22%
# Epoch 70: Test Loss: 2.0006, Test Accuracy: 48.62%
# Total Computation Time: 1691.65 seconds
# Total Communication Time: 3.27 seconds
# Epoch 71, Iteration 1: H_t = 4, G_t = 4.1082, σ_t^2 = 91.4951
# Epoch 71, Iteration 2: H_t = 4, G_t = 0.6363, σ_t^2 = 97.8206
# Epoch 71, Iteration 3: H_t = 6, G_t = 5.0270, σ_t^2 = 82.8819
# Epoch 71, Iteration 4: H_t = 4, G_t = -2.0331, σ_t^2 = 97.3464
# Epoch 71, Iteration 5: H_t = 4, G_t = 0.3572, σ_t^2 = 85.8829
# Epoch 71, Iteration 6: H_t = 4, G_t = 2.1676, σ_t^2 = 85.5809
# Epoch 71, Iteration 7: H_t = 4, G_t = -0.9886, σ_t^2 = 86.4883
# Epoch 71, Iteration 8: H_t = 4, G_t = 0.7106, σ_t^2 = 78.3554
# Epoch 71, Iteration 9: H_t = 4, G_t = 1.5724, σ_t^2 = 64.3527
# Epoch 71, Iteration 10: H_t = 4, G_t = 3.1354, σ_t^2 = 81.6366
# Epoch 71, Iteration 11: H_t = 4, G_t = -1.4917, σ_t^2 = 87.1825
# Epoch 71, Iteration 12: H_t = 7, G_t = 6.9235, σ_t^2 = 87.0286
# Epoch 71, Iteration 13: H_t = 4, G_t = 0.3629, σ_t^2 = 102.6255
# Epoch 71, Iteration 14: H_t = 4, G_t = -2.2690, σ_t^2 = 99.9027
# Epoch 71, Iteration 15: H_t = 11, G_t = 10.1895, σ_t^2 = 91.3401
# Epoch 71, Iteration 16: H_t = 4, G_t = -0.4606, σ_t^2 = 80.8296
# Epoch 71, Iteration 17: H_t = 4, G_t = 2.5148, σ_t^2 = 83.0629
# Epoch 71, Iteration 18: H_t = 6, G_t = 5.8038, σ_t^2 = 86.9832
# Epoch 71, Iteration 19: H_t = 4, G_t = 3.0810, σ_t^2 = 69.8747
# Epoch 71, Iteration 20: H_t = 4, G_t = 0.8842, σ_t^2 = 75.4053
# Epoch 71, Iteration 21: H_t = 4, G_t = -0.1389, σ_t^2 = 83.6418
# Epoch 71, Iteration 22: H_t = 4, G_t = 2.3325, σ_t^2 = 73.5641
# Epoch 71, Iteration 23: H_t = 6, G_t = 5.2724, σ_t^2 = 80.7582
# Epoch 71, Iteration 24: H_t = 4, G_t = -1.7042, σ_t^2 = 85.6928
# Epoch 71, Iteration 25: H_t = 4, G_t = 0.4021, σ_t^2 = 74.6006
# Epoch 71, Iteration 26: H_t = 4, G_t = 0.2199, σ_t^2 = 80.0775
# Epoch 71, Iteration 27: H_t = 4, G_t = 1.9413, σ_t^2 = 87.5853
# Epoch 71, Iteration 28: H_t = 4, G_t = 2.1670, σ_t^2 = 88.7852
# Epoch 71, Iteration 29: H_t = 4, G_t = 0.2611, σ_t^2 = 92.1608
# Epoch 71, Iteration 30: H_t = 5, G_t = 4.8231, σ_t^2 = 95.6445
# Epoch 71, Iteration 31: H_t = 7, G_t = 5.3188, σ_t^2 = 69.3551
# Epoch 71, Iteration 32: H_t = 4, G_t = 1.5605, σ_t^2 = 90.9350
# Epoch 71, Iteration 33: H_t = 4, G_t = 2.4067, σ_t^2 = 89.1128
# Epoch 71, Iteration 34: H_t = 4, G_t = 0.9583, σ_t^2 = 90.5449
# Epoch 71, Iteration 35: H_t = 8, G_t = 7.0904, σ_t^2 = 86.7445
# Epoch 71, Iteration 36: H_t = 4, G_t = 0.8635, σ_t^2 = 99.3647
# Epoch 71, Iteration 37: H_t = 4, G_t = 3.3760, σ_t^2 = 88.6843
# Epoch 71, Iteration 38: H_t = 4, G_t = 3.9080, σ_t^2 = 81.1762
# Epoch 71, Iteration 39: H_t = 4, G_t = -0.9670, σ_t^2 = 85.9748
# Epoch 71, Iteration 40: H_t = 4, G_t = 3.4739, σ_t^2 = 87.2810
# Epoch 71, Iteration 41: H_t = 4, G_t = 2.8491, σ_t^2 = 85.8054
# Epoch 71, Iteration 42: H_t = 8, G_t = 6.5913, σ_t^2 = 73.6404
# Epoch 71, Iteration 43: H_t = 4, G_t = 3.2421, σ_t^2 = 87.8120
#     Worker 0: Train Loss: 1.6653, Train Accuracy: 54.11%
#     Worker 1: Train Loss: 1.6622, Train Accuracy: 54.37%
#     Worker 2: Train Loss: 1.6647, Train Accuracy: 54.63%
#     Worker 3: Train Loss: 1.6833, Train Accuracy: 53.94%
# Epoch 71: Test Loss: 2.0078, Test Accuracy: 48.37%
# Total Computation Time: 1715.74 seconds
# Total Communication Time: 3.32 seconds
# Epoch 72, Iteration 1: H_t = 4, G_t = 3.9741, σ_t^2 = 85.8213
# Epoch 72, Iteration 2: H_t = 4, G_t = 1.7782, σ_t^2 = 87.1752
# Epoch 72, Iteration 3: H_t = 4, G_t = -1.7081, σ_t^2 = 83.8703
# Epoch 72, Iteration 4: H_t = 4, G_t = 0.7911, σ_t^2 = 84.5012
# Epoch 72, Iteration 5: H_t = 5, G_t = 4.3479, σ_t^2 = 73.8232
# Epoch 72, Iteration 6: H_t = 4, G_t = 0.8401, σ_t^2 = 96.1380
# Epoch 72, Iteration 7: H_t = 4, G_t = 3.1767, σ_t^2 = 95.4998
# Epoch 72, Iteration 8: H_t = 5, G_t = 4.9352, σ_t^2 = 86.7593
# Epoch 72, Iteration 9: H_t = 4, G_t = -1.2240, σ_t^2 = 85.7715
# Epoch 72, Iteration 10: H_t = 4, G_t = 0.8656, σ_t^2 = 80.4803
# Epoch 72, Iteration 11: H_t = 4, G_t = -0.4466, σ_t^2 = 86.6781
# Epoch 72, Iteration 12: H_t = 4, G_t = -1.0822, σ_t^2 = 95.5668
# Epoch 72, Iteration 13: H_t = 4, G_t = -0.7082, σ_t^2 = 96.8280
# Epoch 72, Iteration 14: H_t = 5, G_t = 5.0273, σ_t^2 = 87.5206
# Epoch 72, Iteration 15: H_t = 4, G_t = 3.7483, σ_t^2 = 83.6301
# Epoch 72, Iteration 16: H_t = 4, G_t = 0.8885, σ_t^2 = 96.7300
# Epoch 72, Iteration 17: H_t = 4, G_t = 0.5838, σ_t^2 = 86.1495
# Epoch 72, Iteration 18: H_t = 4, G_t = 0.3829, σ_t^2 = 84.5375
# Epoch 72, Iteration 19: H_t = 5, G_t = 4.3766, σ_t^2 = 87.0550
# Epoch 72, Iteration 20: H_t = 4, G_t = -0.3965, σ_t^2 = 79.0814
# Epoch 72, Iteration 21: H_t = 4, G_t = 0.5117, σ_t^2 = 82.0884
# Epoch 72, Iteration 22: H_t = 4, G_t = 0.8597, σ_t^2 = 84.8217
# Epoch 72, Iteration 23: H_t = 4, G_t = 2.1468, σ_t^2 = 84.2211
# Epoch 72, Iteration 24: H_t = 4, G_t = 0.8274, σ_t^2 = 78.7296
# Epoch 72, Iteration 25: H_t = 4, G_t = -2.8114, σ_t^2 = 92.2806
# Epoch 72, Iteration 26: H_t = 4, G_t = -0.2376, σ_t^2 = 90.4707
# Epoch 72, Iteration 27: H_t = 4, G_t = 2.1745, σ_t^2 = 76.9693
# Epoch 72, Iteration 28: H_t = 4, G_t = 1.6561, σ_t^2 = 69.4888
# Epoch 72, Iteration 29: H_t = 4, G_t = -2.6405, σ_t^2 = 82.0814
# Epoch 72, Iteration 30: H_t = 4, G_t = 0.1870, σ_t^2 = 83.8375
# Epoch 72, Iteration 31: H_t = 4, G_t = 0.8380, σ_t^2 = 96.6092
# Epoch 72, Iteration 32: H_t = 4, G_t = -0.0225, σ_t^2 = 86.0194
# Epoch 72, Iteration 33: H_t = 4, G_t = 2.6693, σ_t^2 = 102.4055
# Epoch 72, Iteration 34: H_t = 4, G_t = 0.4409, σ_t^2 = 92.2938
# Epoch 72, Iteration 35: H_t = 5, G_t = 4.2472, σ_t^2 = 83.0578
# Epoch 72, Iteration 36: H_t = 6, G_t = 5.6048, σ_t^2 = 86.6646
# Epoch 72, Iteration 37: H_t = 4, G_t = 1.6029, σ_t^2 = 90.9423
# Epoch 72, Iteration 38: H_t = 4, G_t = 3.9032, σ_t^2 = 93.2368
# Epoch 72, Iteration 39: H_t = 4, G_t = 2.7698, σ_t^2 = 75.3372
# Epoch 72, Iteration 40: H_t = 4, G_t = 0.1207, σ_t^2 = 88.3978
# Epoch 72, Iteration 41: H_t = 4, G_t = 1.0953, σ_t^2 = 80.3678
# Epoch 72, Iteration 42: H_t = 4, G_t = 1.4547, σ_t^2 = 91.9726
# Epoch 72, Iteration 43: H_t = 4, G_t = 3.4597, σ_t^2 = 75.4383
# Epoch 72, Iteration 44: H_t = 4, G_t = -1.8578, σ_t^2 = 108.5203
# Epoch 72, Iteration 45: H_t = 4, G_t = -1.4986, σ_t^2 = 81.8405
# Epoch 72, Iteration 46: H_t = 4, G_t = 2.8092, σ_t^2 = 84.4616
# Epoch 72, Iteration 47: H_t = 4, G_t = -1.0733, σ_t^2 = 102.7571
# Epoch 72, Iteration 48: H_t = 6, G_t = 5.2030, σ_t^2 = 80.2070
#     Worker 0: Train Loss: 1.6515, Train Accuracy: 54.08%
#     Worker 1: Train Loss: 1.6540, Train Accuracy: 54.68%
#     Worker 2: Train Loss: 1.6481, Train Accuracy: 54.77%
#     Worker 3: Train Loss: 1.6454, Train Accuracy: 55.03%
# Epoch 72: Test Loss: 2.0027, Test Accuracy: 48.38%
# Total Computation Time: 1739.79 seconds
# Total Communication Time: 3.38 seconds
# Epoch 73, Iteration 1: H_t = 4, G_t = -1.5007, σ_t^2 = 91.6720
# Epoch 73, Iteration 2: H_t = 4, G_t = -0.0416, σ_t^2 = 91.2503
# Epoch 73, Iteration 3: H_t = 4, G_t = 0.4538, σ_t^2 = 90.6931
# Epoch 73, Iteration 4: H_t = 4, G_t = -0.2242, σ_t^2 = 94.9632
# Epoch 73, Iteration 5: H_t = 4, G_t = 3.7810, σ_t^2 = 78.1707
# Epoch 73, Iteration 6: H_t = 10, G_t = 9.6762, σ_t^2 = 88.5015
# Epoch 73, Iteration 7: H_t = 4, G_t = -1.2720, σ_t^2 = 117.2415
# Epoch 73, Iteration 8: H_t = 4, G_t = -0.6716, σ_t^2 = 93.8980
# Epoch 73, Iteration 9: H_t = 5, G_t = 3.4104, σ_t^2 = 67.4975
# Epoch 73, Iteration 10: H_t = 4, G_t = 1.7173, σ_t^2 = 86.4132
# Epoch 73, Iteration 11: H_t = 4, G_t = -0.9629, σ_t^2 = 89.0439
# Epoch 73, Iteration 12: H_t = 4, G_t = 3.9904, σ_t^2 = 94.0407
# Epoch 73, Iteration 13: H_t = 4, G_t = -0.4938, σ_t^2 = 100.5670
# Epoch 73, Iteration 14: H_t = 5, G_t = 5.1337, σ_t^2 = 93.0333
# Epoch 73, Iteration 15: H_t = 4, G_t = 2.6280, σ_t^2 = 74.4472
# Epoch 73, Iteration 16: H_t = 4, G_t = 1.8915, σ_t^2 = 89.3778
# Epoch 73, Iteration 17: H_t = 7, G_t = 6.7363, σ_t^2 = 91.4272
# Epoch 73, Iteration 18: H_t = 4, G_t = 0.8838, σ_t^2 = 102.4037
# Epoch 73, Iteration 19: H_t = 4, G_t = 0.4826, σ_t^2 = 93.0165
# ...
# Epoch 146, Iteration 29: H_t = 4, G_t = -0.4161, σ_t^2 = 110.1114
# Epoch 146, Iteration 30: H_t = 4, G_t = 0.6460, σ_t^2 = 129.7534
# Epoch 146, Iteration 31: H_t = 4, G_t = 6.0640, σ_t^2 = 132.1485
# Epoch 146, Iteration 32: H_t = 4, G_t = 0.5785, σ_t^2 = 131.0518
# Epoch 146, Iteration 33: H_t = 4, G_t = -0.3863, σ_t^2 = 117.4420
# Epoch 146, Iteration 34: H_t = 4, G_t = -2.5288, σ_t^2 = 129.5448
# Epoch 146, Iteration 35: H_t = 4, G_t = 2.1481, σ_t^2 = 121.7837
# Epoch 146, Iteration 36: H_t = 4, G_t = 1.1946, σ_t^2 = 131.0704
# Epoch 146, Iteration 37: H_t = 4, G_t = -0.8083, σ_t^2 = 120.0652
# Epoch 146, Iteration 38: H_t = 4, G_t = 3.5833, σ_t^2 = 122.4171
# Epoch 146, Iteration 39: H_t = 4, G_t = 2.1569, σ_t^2 = 118.4249
# Epoch 146, Iteration 40: H_t = 4, G_t = 0.1236, σ_t^2 = 145.7270
# Epoch 146, Iteration 41: H_t = 4, G_t = -0.4939, σ_t^2 = 138.9926
# Epoch 146, Iteration 42: H_t = 4, G_t = -0.8511, σ_t^2 = 134.8861
# Epoch 146, Iteration 43: H_t = 4, G_t = 4.4010, σ_t^2 = 127.2509
# Epoch 146, Iteration 44: H_t = 4, G_t = 0.5861, σ_t^2 = 129.8864
# Epoch 146, Iteration 45: H_t = 4, G_t = 0.9317, σ_t^2 = 121.4954
# Epoch 146, Iteration 46: H_t = 4, G_t = 0.1099, σ_t^2 = 139.5270
# Epoch 146, Iteration 47: H_t = 4, G_t = -1.9891, σ_t^2 = 145.5713
# Epoch 146, Iteration 48: H_t = 4, G_t = 3.8399, σ_t^2 = 111.8511
# Epoch 146, Iteration 49: H_t = 4, G_t = -0.5037, σ_t^2 = 117.5913
#     Worker 0: Train Loss: 1.2165, Train Accuracy: 65.32%
#     Worker 1: Train Loss: 1.2198, Train Accuracy: 65.75%
#     Worker 2: Train Loss: 1.2242, Train Accuracy: 65.74%
#     Worker 3: Train Loss: 1.2273, Train Accuracy: 65.38%
# Epoch 146: Test Loss: 1.9664, Test Accuracy: 50.95%
# Total Computation Time: 3478.20 seconds
# Total Communication Time: 7.41 seconds
# Epoch 147, Iteration 1: H_t = 4, G_t = 1.8329, σ_t^2 = 136.7259
# Epoch 147, Iteration 2: H_t = 4, G_t = -2.5669, σ_t^2 = 129.2818
# Epoch 147, Iteration 3: H_t = 4, G_t = -2.6407, σ_t^2 = 124.1520
# Epoch 147, Iteration 4: H_t = 4, G_t = -0.6900, σ_t^2 = 121.2917
# Epoch 147, Iteration 5: H_t = 4, G_t = 1.9754, σ_t^2 = 125.3526
# Epoch 147, Iteration 6: H_t = 4, G_t = -4.7610, σ_t^2 = 125.5918
# Epoch 147, Iteration 7: H_t = 4, G_t = -0.7095, σ_t^2 = 119.7706
# Epoch 147, Iteration 8: H_t = 4, G_t = -3.0060, σ_t^2 = 116.7286
# Epoch 147, Iteration 9: H_t = 4, G_t = 3.7428, σ_t^2 = 131.8897
# Epoch 147, Iteration 10: H_t = 4, G_t = -1.6990, σ_t^2 = 129.8547
# Epoch 147, Iteration 11: H_t = 4, G_t = 3.1851, σ_t^2 = 115.7511
# Epoch 147, Iteration 12: H_t = 4, G_t = -1.7059, σ_t^2 = 131.3837
# Epoch 147, Iteration 13: H_t = 4, G_t = 0.0312, σ_t^2 = 113.7812
# Epoch 147, Iteration 14: H_t = 4, G_t = -0.4598, σ_t^2 = 144.3679
# Epoch 147, Iteration 15: H_t = 4, G_t = -0.5040, σ_t^2 = 127.9653
# Epoch 147, Iteration 16: H_t = 4, G_t = -2.3370, σ_t^2 = 129.5873
# Epoch 147, Iteration 17: H_t = 5, G_t = 6.1294, σ_t^2 = 121.9019
# Epoch 147, Iteration 18: H_t = 4, G_t = 2.6533, σ_t^2 = 126.0284
# Epoch 147, Iteration 19: H_t = 4, G_t = -1.5337, σ_t^2 = 136.8799
# Epoch 147, Iteration 20: H_t = 4, G_t = 0.8209, σ_t^2 = 112.7124
# Epoch 147, Iteration 21: H_t = 4, G_t = 1.7670, σ_t^2 = 127.8437
# Epoch 147, Iteration 22: H_t = 4, G_t = -4.6305, σ_t^2 = 118.1652
# Epoch 147, Iteration 23: H_t = 4, G_t = -0.9992, σ_t^2 = 120.0088
# Epoch 147, Iteration 24: H_t = 4, G_t = 3.5377, σ_t^2 = 131.2795
# Epoch 147, Iteration 25: H_t = 4, G_t = -4.8810, σ_t^2 = 127.0079
# Epoch 147, Iteration 26: H_t = 4, G_t = -1.1568, σ_t^2 = 132.0085
# Epoch 147, Iteration 27: H_t = 4, G_t = -2.0356, σ_t^2 = 129.3273
# Epoch 147, Iteration 28: H_t = 5, G_t = 5.4573, σ_t^2 = 99.8466
# Epoch 147, Iteration 29: H_t = 4, G_t = 2.6426, σ_t^2 = 127.1994
# Epoch 147, Iteration 30: H_t = 4, G_t = 3.0060, σ_t^2 = 125.9530
# Epoch 147, Iteration 31: H_t = 4, G_t = 2.3600, σ_t^2 = 136.3751
# Epoch 147, Iteration 32: H_t = 4, G_t = -2.7594, σ_t^2 = 124.3901
# Epoch 147, Iteration 33: H_t = 4, G_t = -0.6693, σ_t^2 = 125.5226
# Epoch 147, Iteration 34: H_t = 4, G_t = 0.8964, σ_t^2 = 120.9524
# Epoch 147, Iteration 35: H_t = 4, G_t = -1.7512, σ_t^2 = 137.8534
# Epoch 147, Iteration 36: H_t = 4, G_t = 3.1299, σ_t^2 = 126.2774
# Epoch 147, Iteration 37: H_t = 4, G_t = -2.0496, σ_t^2 = 125.1087
# Epoch 147, Iteration 38: H_t = 4, G_t = -0.5531, σ_t^2 = 129.6706
# Epoch 147, Iteration 39: H_t = 4, G_t = -0.1932, σ_t^2 = 121.5856
# Epoch 147, Iteration 40: H_t = 4, G_t = -1.3118, σ_t^2 = 113.5950
# Epoch 147, Iteration 41: H_t = 4, G_t = -1.6910, σ_t^2 = 126.9206
# Epoch 147, Iteration 42: H_t = 4, G_t = -4.4242, σ_t^2 = 108.1394
# Epoch 147, Iteration 43: H_t = 4, G_t = 0.5293, σ_t^2 = 120.0470
# Epoch 147, Iteration 44: H_t = 4, G_t = -1.6571, σ_t^2 = 130.8143
# Epoch 147, Iteration 45: H_t = 4, G_t = 3.4881, σ_t^2 = 124.0391
# Epoch 147, Iteration 46: H_t = 4, G_t = -0.3933, σ_t^2 = 109.4941
# Epoch 147, Iteration 47: H_t = 4, G_t = 0.7855, σ_t^2 = 108.3205
# Epoch 147, Iteration 48: H_t = 4, G_t = -0.8951, σ_t^2 = 117.6562
# Epoch 147, Iteration 49: H_t = 4, G_t = -2.6155, σ_t^2 = 143.0776
#     Worker 0: Train Loss: 1.2221, Train Accuracy: 65.42%
#     Worker 1: Train Loss: 1.2048, Train Accuracy: 65.99%
#     Worker 2: Train Loss: 1.2379, Train Accuracy: 65.02%
#     Worker 3: Train Loss: 1.2086, Train Accuracy: 66.07%
# Epoch 147: Test Loss: 1.9666, Test Accuracy: 51.05%
# Total Computation Time: 3502.11 seconds
# Total Communication Time: 7.46 seconds
# Epoch 148, Iteration 1: H_t = 4, G_t = -0.9693, σ_t^2 = 125.7894
# Epoch 148, Iteration 2: H_t = 4, G_t = 0.8800, σ_t^2 = 147.3449
# Epoch 148, Iteration 3: H_t = 4, G_t = -5.4214, σ_t^2 = 134.1140
# Epoch 148, Iteration 4: H_t = 4, G_t = 3.3001, σ_t^2 = 134.0202
# Epoch 148, Iteration 5: H_t = 4, G_t = 1.5311, σ_t^2 = 121.4148
# Epoch 148, Iteration 6: H_t = 4, G_t = 3.2006, σ_t^2 = 143.1642
# Epoch 148, Iteration 7: H_t = 4, G_t = 0.0796, σ_t^2 = 135.6569
# Epoch 148, Iteration 8: H_t = 4, G_t = 0.2415, σ_t^2 = 116.6230
# Epoch 148, Iteration 9: H_t = 4, G_t = 1.5801, σ_t^2 = 131.9939
# Epoch 148, Iteration 10: H_t = 4, G_t = -0.7878, σ_t^2 = 121.7771
# Epoch 148, Iteration 11: H_t = 4, G_t = 0.2383, σ_t^2 = 131.5479
# Epoch 148, Iteration 12: H_t = 4, G_t = -4.6159, σ_t^2 = 141.9833
# Epoch 148, Iteration 13: H_t = 4, G_t = 0.4740, σ_t^2 = 110.0626
# Epoch 148, Iteration 14: H_t = 4, G_t = -3.2836, σ_t^2 = 127.7573
# Epoch 148, Iteration 15: H_t = 4, G_t = -0.7287, σ_t^2 = 131.6253
# Epoch 148, Iteration 16: H_t = 4, G_t = -1.9555, σ_t^2 = 124.7069
# Epoch 148, Iteration 17: H_t = 4, G_t = -0.3070, σ_t^2 = 128.8885
# Epoch 148, Iteration 18: H_t = 4, G_t = 0.4776, σ_t^2 = 125.4195
# Epoch 148, Iteration 19: H_t = 4, G_t = 2.9806, σ_t^2 = 130.9379
# Epoch 148, Iteration 20: H_t = 4, G_t = 3.5999, σ_t^2 = 133.8509
# Epoch 148, Iteration 21: H_t = 4, G_t = 3.7492, σ_t^2 = 117.7085
# Epoch 148, Iteration 22: H_t = 4, G_t = 0.9231, σ_t^2 = 123.7119
# Epoch 148, Iteration 23: H_t = 4, G_t = 2.7293, σ_t^2 = 115.5726
# Epoch 148, Iteration 24: H_t = 4, G_t = -3.2360, σ_t^2 = 131.8586
# Epoch 148, Iteration 25: H_t = 4, G_t = -4.8784, σ_t^2 = 145.2035
# Epoch 148, Iteration 26: H_t = 4, G_t = 20.6643, σ_t^2 = 417.7153
# Epoch 148, Iteration 27: H_t = 4, G_t = 4.1812, σ_t^2 = 114.4687
# Epoch 148, Iteration 28: H_t = 4, G_t = -0.7671, σ_t^2 = 120.1568
# Epoch 148, Iteration 29: H_t = 4, G_t = 2.8912, σ_t^2 = 130.9260
# Epoch 148, Iteration 30: H_t = 4, G_t = 0.9780, σ_t^2 = 106.5212
# Epoch 148, Iteration 31: H_t = 4, G_t = -3.0015, σ_t^2 = 125.4646
# Epoch 148, Iteration 32: H_t = 4, G_t = 6.1086, σ_t^2 = 140.8346
# Epoch 148, Iteration 33: H_t = 4, G_t = -1.7882, σ_t^2 = 118.5629
# Epoch 148, Iteration 34: H_t = 4, G_t = -0.8108, σ_t^2 = 138.6414
# Epoch 148, Iteration 35: H_t = 4, G_t = -7.7434, σ_t^2 = 154.5731
# Epoch 148, Iteration 36: H_t = 4, G_t = -2.7987, σ_t^2 = 124.7847
# Epoch 148, Iteration 37: H_t = 4, G_t = 0.9491, σ_t^2 = 123.5873
# Epoch 148, Iteration 38: H_t = 4, G_t = -5.3042, σ_t^2 = 134.1375
# Epoch 148, Iteration 39: H_t = 4, G_t = 0.5652, σ_t^2 = 120.8469
# Epoch 148, Iteration 40: H_t = 4, G_t = -2.0297, σ_t^2 = 146.0696
# Epoch 148, Iteration 41: H_t = 4, G_t = -2.4053, σ_t^2 = 143.3469
# Epoch 148, Iteration 42: H_t = 4, G_t = 2.3656, σ_t^2 = 119.4850
# Epoch 148, Iteration 43: H_t = 4, G_t = 1.5967, σ_t^2 = 123.1864
# Epoch 148, Iteration 44: H_t = 4, G_t = -1.3186, σ_t^2 = 122.8038
# Epoch 148, Iteration 45: H_t = 4, G_t = -2.9349, σ_t^2 = 106.0094
# Epoch 148, Iteration 46: H_t = 4, G_t = 0.4184, σ_t^2 = 142.0360
# Epoch 148, Iteration 47: H_t = 4, G_t = 3.4820, σ_t^2 = 110.5285
# Epoch 148, Iteration 48: H_t = 4, G_t = 0.2616, σ_t^2 = 122.1177
# Epoch 148, Iteration 49: H_t = 4, G_t = -1.2005, σ_t^2 = 115.8729
#     Worker 0: Train Loss: 1.2264, Train Accuracy: 65.42%
#     Worker 1: Train Loss: 1.2087, Train Accuracy: 65.70%
#     Worker 2: Train Loss: 1.1974, Train Accuracy: 65.91%
#     Worker 3: Train Loss: 1.2381, Train Accuracy: 64.74%
# Epoch 148: Test Loss: 1.9664, Test Accuracy: 51.06%
# Total Computation Time: 3525.91 seconds
# Total Communication Time: 7.52 seconds
# Epoch 149, Iteration 1: H_t = 4, G_t = 2.2665, σ_t^2 = 149.5665
# Epoch 149, Iteration 2: H_t = 4, G_t = 3.4151, σ_t^2 = 126.6855
# Epoch 149, Iteration 3: H_t = 4, G_t = -2.7355, σ_t^2 = 131.1273
# Epoch 149, Iteration 4: H_t = 5, G_t = 5.7592, σ_t^2 = 109.7865
# Epoch 149, Iteration 5: H_t = 4, G_t = 3.8166, σ_t^2 = 128.1249
# Epoch 149, Iteration 6: H_t = 4, G_t = 1.0249, σ_t^2 = 122.9626
# Epoch 149, Iteration 7: H_t = 4, G_t = 3.0737, σ_t^2 = 122.9112
# Epoch 149, Iteration 8: H_t = 4, G_t = -1.1619, σ_t^2 = 119.7378
# Epoch 149, Iteration 9: H_t = 4, G_t = 1.8353, σ_t^2 = 121.4204
# Epoch 149, Iteration 10: H_t = 6, G_t = 8.7906, σ_t^2 = 126.3433
# Epoch 149, Iteration 11: H_t = 4, G_t = -2.9968, σ_t^2 = 136.7682
# Epoch 149, Iteration 12: H_t = 4, G_t = -2.8625, σ_t^2 = 134.7814
# Epoch 149, Iteration 13: H_t = 4, G_t = -1.4780, σ_t^2 = 143.8717
# Epoch 149, Iteration 14: H_t = 4, G_t = 1.1122, σ_t^2 = 120.4917
# Epoch 149, Iteration 15: H_t = 4, G_t = -3.6190, σ_t^2 = 124.0807
# Epoch 149, Iteration 16: H_t = 4, G_t = 0.1154, σ_t^2 = 134.3138
# Epoch 149, Iteration 17: H_t = 4, G_t = -1.1064, σ_t^2 = 128.1435
# Epoch 149, Iteration 18: H_t = 4, G_t = -2.6123, σ_t^2 = 143.2737
# Epoch 149, Iteration 19: H_t = 4, G_t = -1.4665, σ_t^2 = 120.4691
# Epoch 149, Iteration 20: H_t = 4, G_t = 0.5166, σ_t^2 = 123.7036
# Epoch 149, Iteration 21: H_t = 4, G_t = 1.0924, σ_t^2 = 110.1807
# Epoch 149, Iteration 22: H_t = 4, G_t = -3.4826, σ_t^2 = 134.9181
# Epoch 149, Iteration 23: H_t = 4, G_t = 0.2880, σ_t^2 = 119.1145
# Epoch 149, Iteration 24: H_t = 4, G_t = 0.8603, σ_t^2 = 125.9433
# Epoch 149, Iteration 25: H_t = 4, G_t = -2.3442, σ_t^2 = 124.2674
# Epoch 149, Iteration 26: H_t = 4, G_t = 0.2591, σ_t^2 = 120.6676
# Epoch 149, Iteration 27: H_t = 4, G_t = -3.0102, σ_t^2 = 150.3332
# Epoch 149, Iteration 28: H_t = 4, G_t = -1.2122, σ_t^2 = 126.6190
# Epoch 149, Iteration 29: H_t = 4, G_t = 2.9627, σ_t^2 = 115.6082
# Epoch 149, Iteration 30: H_t = 4, G_t = -3.8669, σ_t^2 = 111.0517
# Epoch 149, Iteration 31: H_t = 4, G_t = -0.1529, σ_t^2 = 129.4573
# Epoch 149, Iteration 32: H_t = 4, G_t = -0.4048, σ_t^2 = 126.1199
# Epoch 149, Iteration 33: H_t = 4, G_t = 2.1327, σ_t^2 = 144.0832
# Epoch 149, Iteration 34: H_t = 4, G_t = 0.6547, σ_t^2 = 123.1656
# Epoch 149, Iteration 35: H_t = 4, G_t = -2.7667, σ_t^2 = 135.1435
# Epoch 149, Iteration 36: H_t = 4, G_t = 0.1400, σ_t^2 = 119.6504
# Epoch 149, Iteration 37: H_t = 4, G_t = -2.2098, σ_t^2 = 121.9129
# Epoch 149, Iteration 38: H_t = 4, G_t = -3.7499, σ_t^2 = 137.5284
# Epoch 149, Iteration 39: H_t = 4, G_t = 0.0202, σ_t^2 = 113.1512
# Epoch 149, Iteration 40: H_t = 4, G_t = 0.8786, σ_t^2 = 117.3448
# Epoch 149, Iteration 41: H_t = 4, G_t = 1.4463, σ_t^2 = 107.2055
# Epoch 149, Iteration 42: H_t = 4, G_t = 0.2722, σ_t^2 = 122.2854
# Epoch 149, Iteration 43: H_t = 4, G_t = -2.1452, σ_t^2 = 129.7772
# Epoch 149, Iteration 44: H_t = 4, G_t = -1.2936, σ_t^2 = 140.7760
# Epoch 149, Iteration 45: H_t = 4, G_t = 0.0182, σ_t^2 = 109.0810
# Epoch 149, Iteration 46: H_t = 4, G_t = -3.1946, σ_t^2 = 122.3021
# Epoch 149, Iteration 47: H_t = 4, G_t = 0.8972, σ_t^2 = 104.0256
# Epoch 149, Iteration 48: H_t = 4, G_t = 4.6322, σ_t^2 = 117.8148
# Epoch 149, Iteration 49: H_t = 4, G_t = -1.9151, σ_t^2 = 143.9819
#     Worker 0: Train Loss: 1.2218, Train Accuracy: 65.56%
#     Worker 1: Train Loss: 1.2162, Train Accuracy: 65.40%
#     Worker 2: Train Loss: 1.2018, Train Accuracy: 66.15%
#     Worker 3: Train Loss: 1.2223, Train Accuracy: 65.68%
# Epoch 149: Test Loss: 1.9665, Test Accuracy: 51.01%
# Total Computation Time: 3549.64 seconds
# Total Communication Time: 7.58 seconds
# Epoch 150, Iteration 1: H_t = 4, G_t = 0.5156, σ_t^2 = 126.8429
# Epoch 150, Iteration 2: H_t = 4, G_t = 0.8706, σ_t^2 = 108.3154
# Epoch 150, Iteration 3: H_t = 4, G_t = -4.3345, σ_t^2 = 146.8587
# Epoch 150, Iteration 4: H_t = 4, G_t = -1.8742, σ_t^2 = 128.0537
# Epoch 150, Iteration 5: H_t = 4, G_t = 1.0425, σ_t^2 = 120.0599
# Epoch 150, Iteration 6: H_t = 4, G_t = -0.0546, σ_t^2 = 127.6370
# Epoch 150, Iteration 7: H_t = 4, G_t = 4.5548, σ_t^2 = 128.5516
# Epoch 150, Iteration 8: H_t = 4, G_t = -3.6691, σ_t^2 = 128.5262
# Epoch 150, Iteration 9: H_t = 4, G_t = 0.5365, σ_t^2 = 145.4725
# Epoch 150, Iteration 10: H_t = 4, G_t = -0.4855, σ_t^2 = 147.8830
# Epoch 150, Iteration 11: H_t = 4, G_t = -1.6806, σ_t^2 = 112.1481
# Epoch 150, Iteration 12: H_t = 4, G_t = -1.0724, σ_t^2 = 112.0309
# Epoch 150, Iteration 13: H_t = 4, G_t = -4.0156, σ_t^2 = 143.7258
# Epoch 150, Iteration 14: H_t = 4, G_t = -0.2636, σ_t^2 = 138.1953
# Epoch 150, Iteration 15: H_t = 4, G_t = 2.1986, σ_t^2 = 121.8721
# Epoch 150, Iteration 16: H_t = 4, G_t = -2.3126, σ_t^2 = 116.8584
# Epoch 150, Iteration 17: H_t = 4, G_t = 0.0166, σ_t^2 = 135.4866
# Epoch 150, Iteration 18: H_t = 4, G_t = 1.5209, σ_t^2 = 132.2978
# Epoch 150, Iteration 19: H_t = 4, G_t = -1.2004, σ_t^2 = 137.5222
# Epoch 150, Iteration 20: H_t = 4, G_t = 0.6280, σ_t^2 = 139.3599
# Epoch 150, Iteration 21: H_t = 4, G_t = -2.4860, σ_t^2 = 131.0402
# Epoch 150, Iteration 22: H_t = 4, G_t = -0.9207, σ_t^2 = 120.2615
# Epoch 150, Iteration 23: H_t = 4, G_t = -3.7302, σ_t^2 = 147.8168
# Epoch 150, Iteration 24: H_t = 4, G_t = -0.6983, σ_t^2 = 144.3703
# Epoch 150, Iteration 25: H_t = 4, G_t = -2.6822, σ_t^2 = 123.0364
# Epoch 150, Iteration 26: H_t = 4, G_t = 3.9339, σ_t^2 = 125.1984
# Epoch 150, Iteration 27: H_t = 4, G_t = 2.4117, σ_t^2 = 112.9513
# Epoch 150, Iteration 28: H_t = 4, G_t = 1.3016, σ_t^2 = 115.7474
# Epoch 150, Iteration 29: H_t = 4, G_t = -4.8040, σ_t^2 = 123.6573
# Epoch 150, Iteration 30: H_t = 4, G_t = -1.3594, σ_t^2 = 125.9651
# Epoch 150, Iteration 31: H_t = 4, G_t = 0.9858, σ_t^2 = 124.3825
# Epoch 150, Iteration 32: H_t = 4, G_t = 5.5943, σ_t^2 = 132.4340
# Epoch 150, Iteration 33: H_t = 4, G_t = 2.0188, σ_t^2 = 112.5927
# Epoch 150, Iteration 34: H_t = 4, G_t = 1.5994, σ_t^2 = 120.6029
# Epoch 150, Iteration 35: H_t = 4, G_t = -0.0742, σ_t^2 = 133.9159
# Epoch 150, Iteration 36: H_t = 4, G_t = -2.6012, σ_t^2 = 146.5316
# Epoch 150, Iteration 37: H_t = 4, G_t = -2.9782, σ_t^2 = 129.3098
# Epoch 150, Iteration 38: H_t = 4, G_t = 1.4074, σ_t^2 = 139.8999
# Epoch 150, Iteration 39: H_t = 4, G_t = 1.4770, σ_t^2 = 120.7409
# Epoch 150, Iteration 40: H_t = 4, G_t = 0.2377, σ_t^2 = 148.8044
# Epoch 150, Iteration 41: H_t = 4, G_t = -2.3252, σ_t^2 = 120.1073
# Epoch 150, Iteration 42: H_t = 4, G_t = 2.1458, σ_t^2 = 126.3266
# Epoch 150, Iteration 43: H_t = 4, G_t = 0.3624, σ_t^2 = 130.0744
# Epoch 150, Iteration 44: H_t = 4, G_t = 2.5362, σ_t^2 = 141.3272
# Epoch 150, Iteration 45: H_t = 4, G_t = 1.8402, σ_t^2 = 132.8725
# Epoch 150, Iteration 46: H_t = 4, G_t = -2.1105, σ_t^2 = 135.3810
# Epoch 150, Iteration 47: H_t = 4, G_t = 1.2206, σ_t^2 = 109.6388
# Epoch 150, Iteration 48: H_t = 4, G_t = -1.0697, σ_t^2 = 127.5260
# Epoch 150, Iteration 49: H_t = 5, G_t = 7.3629, σ_t^2 = 124.1124
#     Worker 0: Train Loss: 1.2529, Train Accuracy: 64.53%
#     Worker 1: Train Loss: 1.2387, Train Accuracy: 65.19%
#     Worker 2: Train Loss: 1.2215, Train Accuracy: 65.53%
#     Worker 3: Train Loss: 1.2220, Train Accuracy: 65.78%
# Epoch 150: Test Loss: 1.9665, Test Accuracy: 51.02%
# Total Computation Time: 3572.42 seconds
# Total Communication Time: 7.64 seconds
