# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files
import torch.nn.functional as F
import time

total_computation_time = 0
total_communication_time = 0

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
iteration_per_epoch = 782 # number of local step performed in one epoch
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
#warmup_epochs = 5

def compute_mean_std(dataset):
    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

#global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
#global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
#print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Compute gradient magnitude and variance
def compute_gradient_stats(nets, optimizers):
    # Get gradients from each worker
    gradients = []
    for net, optimizer in zip(nets, optimizers):
        grad_vector = []
        for param in net.parameters():
            if param.grad is not None:
                grad_vector.append(param.grad.view(-1))
        grad_vector = torch.cat(grad_vector)  # Flatten all gradients into a vector
        gradients.append(grad_vector)

    # Compute average gradient (g_t)
    avg_gradient = torch.stack(gradients).mean(dim=0)

    # Compute squared norms of individual gradients
    squared_norms = [torch.norm(g).item() ** 2 for g in gradients]

    # Compute squared norm of the average gradient
    avg_squared_norm = torch.norm(avg_gradient).item() ** 2

    # Compute gradient variance (sigma_t^2) using the provided formula
    sigma_t_squared = (sum(squared_norms) / (K - 1)) - (K / (K - 1)) * avg_squared_norm

    # Compute gradient magnitude (G_t) using the provided formula
    G_t = avg_squared_norm - (1 / K) * sigma_t_squared

    return G_t, sigma_t_squared


# Update H dynamically based on gradient stats
def update_H(G_t, sigma_t_squared, H_min, H_max, alpha, epsilon):
    H_t = min(H_max, max(H_min, alpha * G_t / (sigma_t_squared + epsilon)))
    #H_t = min(H_t, H_max)  # Ensure H_t doesn't exceed H_max
    return int(H_t)  # Ensure H_t is an integer

# Training loop
# Hyperparameters for dynamic adjustment
H_min, H_max = 4, 64  # Minimum and maximum allowed local steps
alpha, epsilon = 1000, 1e-6  # Scaling factor and small constant

H_t = J  # Initialize H_t with the default J value


for epoch in range(num_epochs):
    #print(f"Epoch {epoch + 1}/{num_epochs}:")
    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]

    iteration_per_epoch = 782
    iteration = 0 # Number of global iteration performed
    while iteration_per_epoch > 0:
        computation_start_time = time.time()
        # Train each worker for H_t steps
        for k in range(K):
            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            for _ in range(H_t):  # Perform H_t local steps
                try:
                    images, labels = next(shard_iterators[k])
                except StopIteration:
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k])
                images, labels = images.to(device), labels.to(device)

                optimizers[k].zero_grad()
                outputs = nets[k](images)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizers[k].step()

                # Calculate train loss and accuracy
                train_loss += loss.item() * labels.size(0)
                _, predicted = outputs.max(1)
                total_train += labels.size(0)
                correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        computation_end_time = time.time()
        total_computation_time += (computation_end_time - computation_start_time)

        communication_start_time = time.time()
        # Synchronize models
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

        communication_end_time = time.time()
        total_communication_time += (communication_end_time - communication_start_time)

        # update tot_num_local_step and number of global iteration
        iteration_per_epoch -= (H_t * K)
        iteration += 1
        # Compute gradient stats and update H_t
        G_t, sigma_t_squared = compute_gradient_stats(nets, optimizers)
        H_t = update_H(G_t, sigma_t_squared, H_min, H_max, alpha, epsilon)
        print(f"Epoch {epoch+1}, Iteration {iteration}: H_t = {H_t}, G_t = {G_t:.4f}, σ_t^2 = {sigma_t_squared:.4f}")

    # Store training metrics for all workers after each epoch
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

    # Update learning rate
    for scheduler in schedulers:
        scheduler.step()

    # Evaluate on test set
    global_model = nets[0]
    global_model.eval()
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()

    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)
    print(f"Epoch {epoch + 1}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")

    print(f"Total Computation Time: {total_computation_time:.2f} seconds")
    print(f"Total Communication Time: {total_communication_time:.2f} seconds")



# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 4 --j 32
# Out:
# Training with K=4, J=32
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:03<00:00, 43.1MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00400
# Epoch 1, Iteration 1: H_t = 50, G_t = 0.0064, σ_t^2 = 0.1270
# Epoch 1, Iteration 2: H_t = 49, G_t = 0.0061, σ_t^2 = 0.1235
# Epoch 1, Iteration 3: H_t = 50, G_t = 0.0090, σ_t^2 = 0.1785
# Epoch 1, Iteration 4: H_t = 64, G_t = 0.0305, σ_t^2 = 0.2999
# Epoch 1, Iteration 5: H_t = 10, G_t = 0.0084, σ_t^2 = 0.7748
#     Worker 0: Train Loss: 4.5949, Train Accuracy: 1.53%
#     Worker 1: Train Loss: 4.5951, Train Accuracy: 1.64%
#     Worker 2: Train Loss: 4.5932, Train Accuracy: 1.87%
#     Worker 3: Train Loss: 4.5951, Train Accuracy: 1.58%
# Epoch 1: Test Loss: 4.5587, Test Accuracy: 2.79%
# Total Computation Time: 30.96 seconds
# Total Communication Time: 0.04 seconds
# Epoch 2, Iteration 1: H_t = 64, G_t = 0.0681, σ_t^2 = 0.7533
# Epoch 2, Iteration 2: H_t = 9, G_t = 0.0299, σ_t^2 = 3.2048
# Epoch 2, Iteration 3: H_t = 4, G_t = -0.0102, σ_t^2 = 3.0577
# Epoch 2, Iteration 4: H_t = 4, G_t = -0.0773, σ_t^2 = 3.6914
# Epoch 2, Iteration 5: H_t = 64, G_t = 0.2470, σ_t^2 = 3.6618
# Epoch 2, Iteration 6: H_t = 4, G_t = -0.4405, σ_t^2 = 8.4294
# Epoch 2, Iteration 7: H_t = 9, G_t = 0.0637, σ_t^2 = 7.0721
# Epoch 2, Iteration 8: H_t = 4, G_t = -0.0502, σ_t^2 = 9.5302
# Epoch 2, Iteration 9: H_t = 25, G_t = 0.2454, σ_t^2 = 9.6070
# Epoch 2, Iteration 10: H_t = 4, G_t = -0.3309, σ_t^2 = 12.9874
#     Worker 0: Train Loss: 4.3993, Train Accuracy: 3.86%
#     Worker 1: Train Loss: 4.4148, Train Accuracy: 3.54%
#     Worker 2: Train Loss: 4.3939, Train Accuracy: 3.89%
#     Worker 3: Train Loss: 4.4067, Train Accuracy: 4.00%
# Epoch 2: Test Loss: 4.1457, Test Accuracy: 6.83%
# Total Computation Time: 55.40 seconds
# Total Communication Time: 0.05 seconds
# Epoch 3, Iteration 1: H_t = 4, G_t = -0.3425, σ_t^2 = 10.4924
# Epoch 3, Iteration 2: H_t = 45, G_t = 0.4506, σ_t^2 = 9.8801
# Epoch 3, Iteration 3: H_t = 30, G_t = 0.2958, σ_t^2 = 9.7798
# Epoch 3, Iteration 4: H_t = 4, G_t = -0.3296, σ_t^2 = 10.3417
# Epoch 3, Iteration 5: H_t = 4, G_t = -0.5353, σ_t^2 = 11.7299
# Epoch 3, Iteration 6: H_t = 64, G_t = 1.0986, σ_t^2 = 8.2871
# Epoch 3, Iteration 7: H_t = 4, G_t = -0.2796, σ_t^2 = 9.9427
# Epoch 3, Iteration 8: H_t = 4, G_t = -0.0589, σ_t^2 = 9.7406
# Epoch 3, Iteration 9: H_t = 64, G_t = 1.4241, σ_t^2 = 9.5428
# Epoch 3, Iteration 10: H_t = 5, G_t = 0.0552, σ_t^2 = 10.3765
#     Worker 0: Train Loss: 4.1310, Train Accuracy: 6.56%
#     Worker 1: Train Loss: 4.1205, Train Accuracy: 7.08%
#     Worker 2: Train Loss: 4.0912, Train Accuracy: 7.10%
#     Worker 3: Train Loss: 4.1230, Train Accuracy: 6.71%
# Epoch 3: Test Loss: 3.9415, Test Accuracy: 9.33%
# Total Computation Time: 82.39 seconds
# Total Communication Time: 0.06 seconds
# Epoch 4, Iteration 1: H_t = 47, G_t = 0.5026, σ_t^2 = 10.5894
# Epoch 4, Iteration 2: H_t = 64, G_t = 0.7407, σ_t^2 = 11.1517
# Epoch 4, Iteration 3: H_t = 14, G_t = 0.2004, σ_t^2 = 13.9249
# Epoch 4, Iteration 4: H_t = 37, G_t = 0.5163, σ_t^2 = 13.8386
# Epoch 4, Iteration 5: H_t = 4, G_t = -0.9044, σ_t^2 = 14.9484
# Epoch 4, Iteration 6: H_t = 4, G_t = 0.0582, σ_t^2 = 12.6171
# Epoch 4, Iteration 7: H_t = 4, G_t = -0.7174, σ_t^2 = 13.1050
# Epoch 4, Iteration 8: H_t = 4, G_t = -0.2062, σ_t^2 = 12.9189
# Epoch 4, Iteration 9: H_t = 64, G_t = 1.3595, σ_t^2 = 13.6650
# Epoch 4, Iteration 10: H_t = 4, G_t = -0.2038, σ_t^2 = 13.9416
#     Worker 0: Train Loss: 3.9548, Train Accuracy: 9.28%
#     Worker 1: Train Loss: 3.9500, Train Accuracy: 9.24%
#     Worker 2: Train Loss: 3.9176, Train Accuracy: 9.55%
#     Worker 3: Train Loss: 3.9481, Train Accuracy: 9.46%
# Epoch 4: Test Loss: 3.7868, Test Accuracy: 12.50%
# Total Computation Time: 112.29 seconds
# Total Communication Time: 0.08 seconds
# Epoch 5, Iteration 1: H_t = 4, G_t = -0.2671, σ_t^2 = 11.9727
# Epoch 5, Iteration 2: H_t = 64, G_t = 1.5045, σ_t^2 = 11.0538
# Epoch 5, Iteration 3: H_t = 22, G_t = 0.2985, σ_t^2 = 13.5243
# Epoch 5, Iteration 4: H_t = 4, G_t = -0.1152, σ_t^2 = 16.2677
# Epoch 5, Iteration 5: H_t = 28, G_t = 0.4193, σ_t^2 = 14.6379
# Epoch 5, Iteration 6: H_t = 4, G_t = -0.8742, σ_t^2 = 14.5282
# Epoch 5, Iteration 7: H_t = 4, G_t = -0.1036, σ_t^2 = 13.5925
# Epoch 5, Iteration 8: H_t = 15, G_t = 0.1815, σ_t^2 = 11.7134
# Epoch 5, Iteration 9: H_t = 14, G_t = 0.2534, σ_t^2 = 17.0146
# Epoch 5, Iteration 10: H_t = 57, G_t = 0.8698, σ_t^2 = 15.0033
# Epoch 5, Iteration 11: H_t = 4, G_t = -0.8370, σ_t^2 = 15.8310
#     Worker 0: Train Loss: 3.8279, Train Accuracy: 11.31%
#     Worker 1: Train Loss: 3.8228, Train Accuracy: 11.43%
#     Worker 2: Train Loss: 3.7713, Train Accuracy: 12.03%
#     Worker 3: Train Loss: 3.8210, Train Accuracy: 11.35%
# Epoch 5: Test Loss: 3.6625, Test Accuracy: 14.84%
# Total Computation Time: 138.74 seconds
# Total Communication Time: 0.09 seconds
# Epoch 6, Iteration 1: H_t = 13, G_t = 0.1907, σ_t^2 = 13.7002
# Epoch 6, Iteration 2: H_t = 25, G_t = 0.4355, σ_t^2 = 17.3361
# Epoch 6, Iteration 3: H_t = 4, G_t = -0.6373, σ_t^2 = 18.0006
# Epoch 6, Iteration 4: H_t = 64, G_t = 2.2044, σ_t^2 = 15.9598
# Epoch 6, Iteration 5: H_t = 23, G_t = 0.3414, σ_t^2 = 14.4164
# Epoch 6, Iteration 6: H_t = 4, G_t = -1.2380, σ_t^2 = 19.3149
# Epoch 6, Iteration 7: H_t = 64, G_t = 3.2609, σ_t^2 = 15.6949
# Epoch 6, Iteration 8: H_t = 4, G_t = -0.1571, σ_t^2 = 13.9230
#     Worker 0: Train Loss: 3.7159, Train Accuracy: 12.72%
#     Worker 1: Train Loss: 3.7362, Train Accuracy: 12.77%
#     Worker 2: Train Loss: 3.6824, Train Accuracy: 14.03%
#     Worker 3: Train Loss: 3.7242, Train Accuracy: 13.09%
# Epoch 6: Test Loss: 3.5481, Test Accuracy: 16.66%
# Total Computation Time: 162.99 seconds
# Total Communication Time: 0.10 seconds
# Epoch 7, Iteration 1: H_t = 49, G_t = 0.7258, σ_t^2 = 14.5241
# Epoch 7, Iteration 2: H_t = 4, G_t = -0.7037, σ_t^2 = 16.1634
# Epoch 7, Iteration 3: H_t = 10, G_t = 0.1428, σ_t^2 = 13.8288
# Epoch 7, Iteration 4: H_t = 4, G_t = 0.0132, σ_t^2 = 17.0168
# Epoch 7, Iteration 5: H_t = 5, G_t = 0.0853, σ_t^2 = 15.4918
# Epoch 7, Iteration 6: H_t = 4, G_t = -0.6351, σ_t^2 = 20.0700
# Epoch 7, Iteration 7: H_t = 38, G_t = 0.8518, σ_t^2 = 21.9235
# Epoch 7, Iteration 8: H_t = 4, G_t = 0.0521, σ_t^2 = 17.3734
# Epoch 7, Iteration 9: H_t = 4, G_t = -0.2058, σ_t^2 = 16.3897
# Epoch 7, Iteration 10: H_t = 4, G_t = -0.4377, σ_t^2 = 16.7354
# Epoch 7, Iteration 11: H_t = 24, G_t = 0.4738, σ_t^2 = 18.9998
# Epoch 7, Iteration 12: H_t = 4, G_t = -0.4253, σ_t^2 = 18.5503
# Epoch 7, Iteration 13: H_t = 4, G_t = -1.4952, σ_t^2 = 21.2706
# Epoch 7, Iteration 14: H_t = 4, G_t = -0.8293, σ_t^2 = 18.5082
# Epoch 7, Iteration 15: H_t = 37, G_t = 0.7368, σ_t^2 = 19.4026
# Epoch 7, Iteration 16: H_t = 4, G_t = -0.1519, σ_t^2 = 17.2090
#     Worker 0: Train Loss: 3.6192, Train Accuracy: 14.19%
#     Worker 1: Train Loss: 3.6101, Train Accuracy: 14.82%
#     Worker 2: Train Loss: 3.5639, Train Accuracy: 15.52%
#     Worker 3: Train Loss: 3.6251, Train Accuracy: 14.52%
# Epoch 7: Test Loss: 3.4630, Test Accuracy: 18.00%
# Total Computation Time: 187.20 seconds
# Total Communication Time: 0.12 seconds
# Epoch 8, Iteration 1: H_t = 14, G_t = 0.2532, σ_t^2 = 17.8902
# Epoch 8, Iteration 2: H_t = 25, G_t = 0.4332, σ_t^2 = 16.8988
# Epoch 8, Iteration 3: H_t = 4, G_t = -0.3250, σ_t^2 = 19.8562
# Epoch 8, Iteration 4: H_t = 4, G_t = -0.4142, σ_t^2 = 17.1714
# Epoch 8, Iteration 5: H_t = 4, G_t = -0.3184, σ_t^2 = 19.9558
# Epoch 8, Iteration 6: H_t = 22, G_t = 0.4751, σ_t^2 = 20.8214
# Epoch 8, Iteration 7: H_t = 20, G_t = 0.4938, σ_t^2 = 23.9329
# Epoch 8, Iteration 8: H_t = 13, G_t = 0.2594, σ_t^2 = 18.5785
# Epoch 8, Iteration 9: H_t = 4, G_t = -0.8096, σ_t^2 = 21.3383
# Epoch 8, Iteration 10: H_t = 4, G_t = -1.2062, σ_t^2 = 21.5912
# Epoch 8, Iteration 11: H_t = 4, G_t = -0.9036, σ_t^2 = 19.0721
# Epoch 8, Iteration 12: H_t = 39, G_t = 0.6811, σ_t^2 = 17.3864
# Epoch 8, Iteration 13: H_t = 18, G_t = 0.3696, σ_t^2 = 20.2092
# Epoch 8, Iteration 14: H_t = 4, G_t = -0.9647, σ_t^2 = 23.6481
# Epoch 8, Iteration 15: H_t = 4, G_t = -0.2808, σ_t^2 = 19.2410
# Epoch 8, Iteration 16: H_t = 64, G_t = 1.9061, σ_t^2 = 22.2442
# Epoch 8, Iteration 17: H_t = 4, G_t = -0.2145, σ_t^2 = 21.1981
#     Worker 0: Train Loss: 3.5194, Train Accuracy: 15.95%
#     Worker 1: Train Loss: 3.5356, Train Accuracy: 16.01%
#     Worker 2: Train Loss: 3.4767, Train Accuracy: 17.47%
#     Worker 3: Train Loss: 3.5414, Train Accuracy: 15.96%
# Epoch 8: Test Loss: 3.3656, Test Accuracy: 19.64%
# Total Computation Time: 216.95 seconds
# Total Communication Time: 0.14 seconds
# Epoch 9, Iteration 1: H_t = 31, G_t = 0.5936, σ_t^2 = 18.8814
# Epoch 9, Iteration 2: H_t = 64, G_t = 1.4950, σ_t^2 = 23.0791
# Epoch 9, Iteration 3: H_t = 4, G_t = -1.4415, σ_t^2 = 21.8669
# Epoch 9, Iteration 4: H_t = 33, G_t = 0.5795, σ_t^2 = 17.4009
# Epoch 9, Iteration 5: H_t = 4, G_t = -0.3198, σ_t^2 = 22.9877
# Epoch 9, Iteration 6: H_t = 4, G_t = -0.7272, σ_t^2 = 19.1845
# Epoch 9, Iteration 7: H_t = 48, G_t = 0.9206, σ_t^2 = 18.8870
# Epoch 9, Iteration 8: H_t = 11, G_t = 0.2970, σ_t^2 = 25.0420
# Epoch 9, Iteration 9: H_t = 4, G_t = -0.2988, σ_t^2 = 26.4677
#     Worker 0: Train Loss: 3.4291, Train Accuracy: 17.42%
#     Worker 1: Train Loss: 3.4613, Train Accuracy: 17.25%
#     Worker 2: Train Loss: 3.4209, Train Accuracy: 17.94%
#     Worker 3: Train Loss: 3.4739, Train Accuracy: 17.12%
# Epoch 9: Test Loss: 3.2768, Test Accuracy: 21.47%
# Total Computation Time: 241.30 seconds
# Total Communication Time: 0.15 seconds
# Epoch 10, Iteration 1: H_t = 4, G_t = -0.3596, σ_t^2 = 19.6126
# Epoch 10, Iteration 2: H_t = 4, G_t = -0.0760, σ_t^2 = 22.2612
# Epoch 10, Iteration 3: H_t = 64, G_t = 4.4742, σ_t^2 = 22.3240
# Epoch 10, Iteration 4: H_t = 8, G_t = 0.1978, σ_t^2 = 22.3088
# Epoch 10, Iteration 5: H_t = 15, G_t = 0.3242, σ_t^2 = 21.5777
# Epoch 10, Iteration 6: H_t = 5, G_t = 0.1186, σ_t^2 = 21.6040
# Epoch 10, Iteration 7: H_t = 30, G_t = 0.5853, σ_t^2 = 19.1503
# Epoch 10, Iteration 8: H_t = 4, G_t = -1.7246, σ_t^2 = 27.4957
# Epoch 10, Iteration 9: H_t = 4, G_t = -0.9875, σ_t^2 = 20.0574
# Epoch 10, Iteration 10: H_t = 46, G_t = 0.9416, σ_t^2 = 20.4312
# Epoch 10, Iteration 11: H_t = 4, G_t = -1.0878, σ_t^2 = 28.6239
# Epoch 10, Iteration 12: H_t = 64, G_t = 2.3645, σ_t^2 = 20.9084
# Epoch 10, Iteration 13: H_t = 4, G_t = -0.8918, σ_t^2 = 25.6106
#     Worker 0: Train Loss: 3.3726, Train Accuracy: 18.07%
#     Worker 1: Train Loss: 3.3708, Train Accuracy: 19.04%
#     Worker 2: Train Loss: 3.3253, Train Accuracy: 19.55%
#     Worker 3: Train Loss: 3.3817, Train Accuracy: 18.59%
# Epoch 10: Test Loss: 3.1964, Test Accuracy: 23.29%
# Total Computation Time: 271.62 seconds
# Total Communication Time: 0.17 seconds
# Epoch 11, Iteration 1: H_t = 4, G_t = -0.8596, σ_t^2 = 22.7938
# Epoch 11, Iteration 2: H_t = 64, G_t = 1.3887, σ_t^2 = 17.6160
# Epoch 11, Iteration 3: H_t = 4, G_t = -0.3912, σ_t^2 = 21.0397
# Epoch 11, Iteration 4: H_t = 4, G_t = 0.0101, σ_t^2 = 21.5157
# Epoch 11, Iteration 5: H_t = 64, G_t = 1.6076, σ_t^2 = 19.6993
# Epoch 11, Iteration 6: H_t = 4, G_t = -0.2694, σ_t^2 = 20.4084
# Epoch 11, Iteration 7: H_t = 41, G_t = 0.8498, σ_t^2 = 20.5962
# Epoch 11, Iteration 8: H_t = 4, G_t = -0.9903, σ_t^2 = 21.1319
# Epoch 11, Iteration 9: H_t = 64, G_t = 1.7248, σ_t^2 = 22.1165
# Epoch 11, Iteration 10: H_t = 42, G_t = 0.9792, σ_t^2 = 22.9315
#     Worker 0: Train Loss: 3.2773, Train Accuracy: 19.83%
#     Worker 1: Train Loss: 3.3137, Train Accuracy: 19.98%
#     Worker 2: Train Loss: 3.2447, Train Accuracy: 20.39%
#     Worker 3: Train Loss: 3.3007, Train Accuracy: 19.65%
# Epoch 11: Test Loss: 3.0997, Test Accuracy: 24.99%
# Total Computation Time: 302.15 seconds
# Total Communication Time: 0.18 seconds
# Epoch 12, Iteration 1: H_t = 4, G_t = -1.8452, σ_t^2 = 28.8359
# Epoch 12, Iteration 2: H_t = 4, G_t = -0.1704, σ_t^2 = 31.3924
# Epoch 12, Iteration 3: H_t = 20, G_t = 0.4900, σ_t^2 = 23.5807
# Epoch 12, Iteration 4: H_t = 4, G_t = 0.0387, σ_t^2 = 25.6482
# Epoch 12, Iteration 5: H_t = 14, G_t = 0.3649, σ_t^2 = 25.1607
# Epoch 12, Iteration 6: H_t = 4, G_t = -0.5775, σ_t^2 = 29.7870
# Epoch 12, Iteration 7: H_t = 4, G_t = -0.7698, σ_t^2 = 31.4106
# Epoch 12, Iteration 8: H_t = 64, G_t = 1.9461, σ_t^2 = 28.4610
# Epoch 12, Iteration 9: H_t = 64, G_t = 1.6117, σ_t^2 = 24.7516
# Epoch 12, Iteration 10: H_t = 4, G_t = -1.3215, σ_t^2 = 27.3578
#     Worker 0: Train Loss: 3.2138, Train Accuracy: 21.18%
#     Worker 1: Train Loss: 3.2397, Train Accuracy: 21.06%
#     Worker 2: Train Loss: 3.1630, Train Accuracy: 22.53%
#     Worker 3: Train Loss: 3.2100, Train Accuracy: 21.70%
# Epoch 12: Test Loss: 3.0134, Test Accuracy: 26.60%
# Total Computation Time: 328.49 seconds
# Total Communication Time: 0.19 seconds
# Epoch 13, Iteration 1: H_t = 4, G_t = -1.2850, σ_t^2 = 24.3037
# Epoch 13, Iteration 2: H_t = 4, G_t = -1.3755, σ_t^2 = 26.7305
# Epoch 13, Iteration 3: H_t = 64, G_t = 1.4959, σ_t^2 = 22.8207
# Epoch 13, Iteration 4: H_t = 32, G_t = 0.8157, σ_t^2 = 24.8810
# Epoch 13, Iteration 5: H_t = 4, G_t = -0.3490, σ_t^2 = 24.8255
# Epoch 13, Iteration 6: H_t = 58, G_t = 1.1910, σ_t^2 = 20.5196
# Epoch 13, Iteration 7: H_t = 4, G_t = -1.2809, σ_t^2 = 25.6395
# Epoch 13, Iteration 8: H_t = 4, G_t = -0.4913, σ_t^2 = 24.7656
# Epoch 13, Iteration 9: H_t = 32, G_t = 0.9930, σ_t^2 = 30.9369
# Epoch 13, Iteration 10: H_t = 45, G_t = 1.1509, σ_t^2 = 25.5241
#     Worker 0: Train Loss: 3.1502, Train Accuracy: 22.42%
#     Worker 1: Train Loss: 3.1688, Train Accuracy: 22.42%
#     Worker 2: Train Loss: 3.1122, Train Accuracy: 23.69%
#     Worker 3: Train Loss: 3.1692, Train Accuracy: 22.33%
# Epoch 13: Test Loss: 2.9776, Test Accuracy: 27.02%
# Total Computation Time: 353.88 seconds
# Total Communication Time: 0.20 seconds
# Epoch 14, Iteration 1: H_t = 4, G_t = -1.2922, σ_t^2 = 27.4766
# Epoch 14, Iteration 2: H_t = 64, G_t = 2.7605, σ_t^2 = 19.7442
# Epoch 14, Iteration 3: H_t = 4, G_t = -2.3193, σ_t^2 = 37.5920
# Epoch 14, Iteration 4: H_t = 64, G_t = 2.0692, σ_t^2 = 30.8872
# Epoch 14, Iteration 5: H_t = 8, G_t = 0.2569, σ_t^2 = 29.0679
# Epoch 14, Iteration 6: H_t = 4, G_t = -0.5825, σ_t^2 = 26.9861
# Epoch 14, Iteration 7: H_t = 4, G_t = -0.6644, σ_t^2 = 28.0660
# Epoch 14, Iteration 8: H_t = 4, G_t = -0.1401, σ_t^2 = 24.1527
#     Worker 0: Train Loss: 3.0939, Train Accuracy: 23.42%
#     Worker 1: Train Loss: 3.1233, Train Accuracy: 22.99%
#     Worker 2: Train Loss: 3.0779, Train Accuracy: 23.69%
#     Worker 3: Train Loss: 3.1216, Train Accuracy: 23.22%
# Epoch 14: Test Loss: 2.9187, Test Accuracy: 28.15%
# Total Computation Time: 377.24 seconds
# Total Communication Time: 0.21 seconds
# Epoch 15, Iteration 1: H_t = 11, G_t = 0.2508, σ_t^2 = 22.0581
# Epoch 15, Iteration 2: H_t = 4, G_t = -1.0002, σ_t^2 = 37.6538
# Epoch 15, Iteration 3: H_t = 64, G_t = 1.6918, σ_t^2 = 24.7452
# Epoch 15, Iteration 4: H_t = 4, G_t = -1.7233, σ_t^2 = 30.1177
# Epoch 15, Iteration 5: H_t = 4, G_t = -1.2206, σ_t^2 = 29.1493
# Epoch 15, Iteration 6: H_t = 59, G_t = 1.2969, σ_t^2 = 21.7945
# Epoch 15, Iteration 7: H_t = 46, G_t = 1.1704, σ_t^2 = 24.9364
# Epoch 15, Iteration 8: H_t = 64, G_t = 4.4136, σ_t^2 = 27.1169
#     Worker 0: Train Loss: 3.0581, Train Accuracy: 24.19%
#     Worker 1: Train Loss: 3.0791, Train Accuracy: 23.77%
#     Worker 2: Train Loss: 3.0096, Train Accuracy: 25.33%
#     Worker 3: Train Loss: 3.0719, Train Accuracy: 23.94%
# Epoch 15: Test Loss: 2.8976, Test Accuracy: 28.31%
# Total Computation Time: 399.96 seconds
# Total Communication Time: 0.22 seconds
# Epoch 16, Iteration 1: H_t = 4, G_t = -0.5360, σ_t^2 = 28.2215
# Epoch 16, Iteration 2: H_t = 19, G_t = 0.5284, σ_t^2 = 27.2386
# Epoch 16, Iteration 3: H_t = 44, G_t = 1.0908, σ_t^2 = 24.6311
# Epoch 16, Iteration 4: H_t = 47, G_t = 1.2716, σ_t^2 = 26.5478
# Epoch 16, Iteration 5: H_t = 4, G_t = -0.7378, σ_t^2 = 31.0905
# Epoch 16, Iteration 6: H_t = 8, G_t = 0.2402, σ_t^2 = 28.3940
# Epoch 16, Iteration 7: H_t = 4, G_t = -1.8539, σ_t^2 = 27.7257
# Epoch 16, Iteration 8: H_t = 4, G_t = 0.3413, σ_t^2 = 86.2662
# Epoch 16, Iteration 9: H_t = 64, G_t = 2.4461, σ_t^2 = 30.8095
#     Worker 0: Train Loss: 3.0300, Train Accuracy: 24.74%
#     Worker 1: Train Loss: 3.0326, Train Accuracy: 25.10%
#     Worker 2: Train Loss: 2.9845, Train Accuracy: 25.47%
#     Worker 3: Train Loss: 3.0393, Train Accuracy: 24.72%
# Epoch 16: Test Loss: 2.8316, Test Accuracy: 29.24%
# Total Computation Time: 423.02 seconds
# Total Communication Time: 0.23 seconds
# Epoch 17, Iteration 1: H_t = 4, G_t = -1.7713, σ_t^2 = 28.9852
# Epoch 17, Iteration 2: H_t = 4, G_t = -0.2722, σ_t^2 = 25.6345
# Epoch 17, Iteration 3: H_t = 50, G_t = 1.2234, σ_t^2 = 24.3756
# Epoch 17, Iteration 4: H_t = 4, G_t = -1.9507, σ_t^2 = 32.6824
# Epoch 17, Iteration 5: H_t = 4, G_t = -0.5888, σ_t^2 = 28.4701
# Epoch 17, Iteration 6: H_t = 4, G_t = 0.0967, σ_t^2 = 26.2548
# Epoch 17, Iteration 7: H_t = 4, G_t = -0.7919, σ_t^2 = 27.1776
# Epoch 17, Iteration 8: H_t = 64, G_t = 4.4870, σ_t^2 = 28.5061
# Epoch 17, Iteration 9: H_t = 21, G_t = 0.5689, σ_t^2 = 26.1979
#     Worker 0: Train Loss: 2.9636, Train Accuracy: 26.04%
#     Worker 1: Train Loss: 3.0013, Train Accuracy: 25.32%
#     Worker 2: Train Loss: 2.9463, Train Accuracy: 26.79%
#     Worker 3: Train Loss: 2.9847, Train Accuracy: 25.61%
# Epoch 17: Test Loss: 2.7946, Test Accuracy: 30.25%
# Total Computation Time: 446.62 seconds
# Total Communication Time: 0.24 seconds
# Epoch 18, Iteration 1: H_t = 39, G_t = 1.0937, σ_t^2 = 27.8317
# Epoch 18, Iteration 2: H_t = 30, G_t = 0.8566, σ_t^2 = 28.1118
# Epoch 18, Iteration 3: H_t = 47, G_t = 1.2554, σ_t^2 = 26.2606
# Epoch 18, Iteration 4: H_t = 4, G_t = -1.0629, σ_t^2 = 37.8726
# Epoch 18, Iteration 5: H_t = 4, G_t = -0.4337, σ_t^2 = 25.4782
# Epoch 18, Iteration 6: H_t = 4, G_t = -0.7039, σ_t^2 = 26.6064
# Epoch 18, Iteration 7: H_t = 24, G_t = 0.7081, σ_t^2 = 28.7369
# Epoch 18, Iteration 8: H_t = 4, G_t = -1.3492, σ_t^2 = 30.9691
# Epoch 18, Iteration 9: H_t = 4, G_t = -0.6614, σ_t^2 = 31.8781
# Epoch 18, Iteration 10: H_t = 12, G_t = 0.3753, σ_t^2 = 30.2926
# Epoch 18, Iteration 11: H_t = 4, G_t = -1.1449, σ_t^2 = 46.0517
# Epoch 18, Iteration 12: H_t = 19, G_t = 0.6660, σ_t^2 = 33.5598
#     Worker 0: Train Loss: 2.9095, Train Accuracy: 26.82%
#     Worker 1: Train Loss: 2.9455, Train Accuracy: 26.68%
#     Worker 2: Train Loss: 2.8884, Train Accuracy: 28.04%
#     Worker 3: Train Loss: 2.9252, Train Accuracy: 27.07%
# Epoch 18: Test Loss: 2.7630, Test Accuracy: 31.10%
# Total Computation Time: 469.83 seconds
# Total Communication Time: 0.26 seconds
# Epoch 19, Iteration 1: H_t = 27, G_t = 1.0900, σ_t^2 = 39.6966
# Epoch 19, Iteration 2: H_t = 64, G_t = 2.1792, σ_t^2 = 27.8363
# Epoch 19, Iteration 3: H_t = 4, G_t = -0.3641, σ_t^2 = 32.7033
# Epoch 19, Iteration 4: H_t = 4, G_t = -0.4419, σ_t^2 = 30.0850
# Epoch 19, Iteration 5: H_t = 63, G_t = 1.6289, σ_t^2 = 25.6093
# Epoch 19, Iteration 6: H_t = 35, G_t = 0.9785, σ_t^2 = 27.8329
# Epoch 19, Iteration 7: H_t = 4, G_t = -0.1696, σ_t^2 = 25.8279
#     Worker 0: Train Loss: 2.8739, Train Accuracy: 27.71%
#     Worker 1: Train Loss: 2.9149, Train Accuracy: 27.08%
#     Worker 2: Train Loss: 2.8594, Train Accuracy: 28.35%
#     Worker 3: Train Loss: 2.9156, Train Accuracy: 27.22%
# Epoch 19: Test Loss: 2.7339, Test Accuracy: 32.01%
# Total Computation Time: 495.60 seconds
# Total Communication Time: 0.27 seconds
# Epoch 20, Iteration 1: H_t = 36, G_t = 1.1136, σ_t^2 = 30.6986
# Epoch 20, Iteration 2: H_t = 4, G_t = -0.8655, σ_t^2 = 30.5836
# Epoch 20, Iteration 3: H_t = 64, G_t = 2.5233, σ_t^2 = 23.1857
# Epoch 20, Iteration 4: H_t = 24, G_t = 0.8824, σ_t^2 = 36.3431
# Epoch 20, Iteration 5: H_t = 44, G_t = 1.7840, σ_t^2 = 39.8964
# Epoch 20, Iteration 6: H_t = 12, G_t = 0.3379, σ_t^2 = 26.9812
# Epoch 20, Iteration 7: H_t = 4, G_t = -2.1660, σ_t^2 = 34.0670
# Epoch 20, Iteration 8: H_t = 64, G_t = 2.2540, σ_t^2 = 26.6729
# Epoch 20, Iteration 9: H_t = 6, G_t = 0.1951, σ_t^2 = 32.2834
#     Worker 0: Train Loss: 2.8385, Train Accuracy: 28.57%
#     Worker 1: Train Loss: 2.8699, Train Accuracy: 28.08%
#     Worker 2: Train Loss: 2.8199, Train Accuracy: 28.51%
#     Worker 3: Train Loss: 2.8485, Train Accuracy: 28.44%
# Epoch 20: Test Loss: 2.6857, Test Accuracy: 32.17%
# Total Computation Time: 526.27 seconds
# Total Communication Time: 0.28 seconds
# Epoch 21, Iteration 1: H_t = 5, G_t = 0.1454, σ_t^2 = 25.2700
# Epoch 21, Iteration 2: H_t = 40, G_t = 1.3290, σ_t^2 = 32.9517
# Epoch 21, Iteration 3: H_t = 41, G_t = 1.5075, σ_t^2 = 36.5133
# Epoch 21, Iteration 4: H_t = 4, G_t = -0.2815, σ_t^2 = 26.5955
# Epoch 21, Iteration 5: H_t = 31, G_t = 0.9751, σ_t^2 = 31.0909
# Epoch 21, Iteration 6: H_t = 4, G_t = -2.8247, σ_t^2 = 37.2383
# Epoch 21, Iteration 7: H_t = 64, G_t = 1.8535, σ_t^2 = 26.4899
# Epoch 21, Iteration 8: H_t = 4, G_t = -0.3688, σ_t^2 = 37.3864
# Epoch 21, Iteration 9: H_t = 4, G_t = -0.6096, σ_t^2 = 33.4072
#     Worker 0: Train Loss: 2.7628, Train Accuracy: 29.90%
#     Worker 1: Train Loss: 2.8002, Train Accuracy: 29.62%
#     Worker 2: Train Loss: 2.7573, Train Accuracy: 30.28%
#     Worker 3: Train Loss: 2.8062, Train Accuracy: 29.15%
# Epoch 21: Test Loss: 2.6375, Test Accuracy: 33.70%
# Total Computation Time: 549.65 seconds
# Total Communication Time: 0.29 seconds
# Epoch 22, Iteration 1: H_t = 64, G_t = 1.6927, σ_t^2 = 24.6688
# Epoch 22, Iteration 2: H_t = 4, G_t = -0.5138, σ_t^2 = 32.7742
# Epoch 22, Iteration 3: H_t = 64, G_t = 2.7430, σ_t^2 = 35.6973
# Epoch 22, Iteration 4: H_t = 5, G_t = 0.1690, σ_t^2 = 32.3722
# Epoch 22, Iteration 5: H_t = 4, G_t = -0.1403, σ_t^2 = 34.0420
# Epoch 22, Iteration 6: H_t = 32, G_t = 1.1929, σ_t^2 = 36.5511
# Epoch 22, Iteration 7: H_t = 10, G_t = 0.4182, σ_t^2 = 38.2493
# Epoch 22, Iteration 8: H_t = 64, G_t = 5.2951, σ_t^2 = 33.3233
# Epoch 22, Iteration 9: H_t = 29, G_t = 0.9052, σ_t^2 = 30.3476
#     Worker 0: Train Loss: 2.7528, Train Accuracy: 30.26%
#     Worker 1: Train Loss: 2.7872, Train Accuracy: 29.50%
#     Worker 2: Train Loss: 2.7267, Train Accuracy: 30.92%
#     Worker 3: Train Loss: 2.7557, Train Accuracy: 30.47%
# Epoch 22: Test Loss: 2.5937, Test Accuracy: 34.61%
# Total Computation Time: 579.06 seconds
# Total Communication Time: 0.30 seconds
# Epoch 23, Iteration 1: H_t = 4, G_t = -3.0674, σ_t^2 = 49.5306
# Epoch 23, Iteration 2: H_t = 4, G_t = -2.6894, σ_t^2 = 36.8343
# Epoch 23, Iteration 3: H_t = 4, G_t = -1.0112, σ_t^2 = 30.4923
# Epoch 23, Iteration 4: H_t = 59, G_t = 1.7327, σ_t^2 = 29.2801
# Epoch 23, Iteration 5: H_t = 4, G_t = -0.1115, σ_t^2 = 38.7374
# Epoch 23, Iteration 6: H_t = 4, G_t = -1.2545, σ_t^2 = 34.9926
# Epoch 23, Iteration 7: H_t = 4, G_t = -1.3691, σ_t^2 = 37.0360
# Epoch 23, Iteration 8: H_t = 64, G_t = 2.4547, σ_t^2 = 32.5321
# Epoch 23, Iteration 9: H_t = 20, G_t = 0.7033, σ_t^2 = 33.6069
# Epoch 23, Iteration 10: H_t = 64, G_t = 2.1283, σ_t^2 = 30.4346
#     Worker 0: Train Loss: 2.6965, Train Accuracy: 31.43%
#     Worker 1: Train Loss: 2.7228, Train Accuracy: 30.98%
#     Worker 2: Train Loss: 2.6761, Train Accuracy: 31.38%
#     Worker 3: Train Loss: 2.7214, Train Accuracy: 30.66%
# Epoch 23: Test Loss: 2.5502, Test Accuracy: 34.84%
# Total Computation Time: 601.66 seconds
# Total Communication Time: 0.31 seconds
# Epoch 24, Iteration 1: H_t = 4, G_t = -1.8548, σ_t^2 = 40.2931
# Epoch 24, Iteration 2: H_t = 39, G_t = 1.3983, σ_t^2 = 35.7855
# Epoch 24, Iteration 3: H_t = 34, G_t = 0.9629, σ_t^2 = 28.1219
# Epoch 24, Iteration 4: H_t = 4, G_t = -2.9603, σ_t^2 = 41.2100
# Epoch 24, Iteration 5: H_t = 22, G_t = 0.7353, σ_t^2 = 32.5500
# Epoch 24, Iteration 6: H_t = 4, G_t = -1.9197, σ_t^2 = 46.9161
# Epoch 24, Iteration 7: H_t = 64, G_t = 3.3853, σ_t^2 = 36.3126
# Epoch 24, Iteration 8: H_t = 52, G_t = 1.9431, σ_t^2 = 37.2258
#     Worker 0: Train Loss: 2.6674, Train Accuracy: 31.99%
#     Worker 1: Train Loss: 2.6880, Train Accuracy: 31.20%
#     Worker 2: Train Loss: 2.6558, Train Accuracy: 32.23%
#     Worker 3: Train Loss: 2.6676, Train Accuracy: 31.98%
# Epoch 24: Test Loss: 2.5109, Test Accuracy: 36.17%
# Total Computation Time: 629.30 seconds
# Total Communication Time: 0.32 seconds
# Epoch 25, Iteration 1: H_t = 17, G_t = 0.5942, σ_t^2 = 33.6138
# Epoch 25, Iteration 2: H_t = 4, G_t = -0.4513, σ_t^2 = 38.3241
# Epoch 25, Iteration 3: H_t = 64, G_t = 3.1286, σ_t^2 = 29.0178
# Epoch 25, Iteration 4: H_t = 39, G_t = 1.5541, σ_t^2 = 39.7985
# Epoch 25, Iteration 5: H_t = 4, G_t = -2.1204, σ_t^2 = 39.0978
# Epoch 25, Iteration 6: H_t = 4, G_t = -0.4178, σ_t^2 = 33.1092
# Epoch 25, Iteration 7: H_t = 48, G_t = 1.4336, σ_t^2 = 29.5292
# Epoch 25, Iteration 8: H_t = 19, G_t = 0.6766, σ_t^2 = 34.8145
#     Worker 0: Train Loss: 2.6234, Train Accuracy: 33.07%
#     Worker 1: Train Loss: 2.6479, Train Accuracy: 32.47%
#     Worker 2: Train Loss: 2.6076, Train Accuracy: 33.53%
#     Worker 3: Train Loss: 2.6267, Train Accuracy: 33.01%
# Epoch 25: Test Loss: 2.4710, Test Accuracy: 36.81%
# Total Computation Time: 656.85 seconds
# Total Communication Time: 0.33 seconds
# Epoch 26, Iteration 1: H_t = 4, G_t = 0.0879, σ_t^2 = 38.0462
# Epoch 26, Iteration 2: H_t = 64, G_t = 2.9621, σ_t^2 = 25.7170
# Epoch 26, Iteration 3: H_t = 48, G_t = 1.7038, σ_t^2 = 34.8586
# Epoch 26, Iteration 4: H_t = 4, G_t = -0.3010, σ_t^2 = 37.5642
# Epoch 26, Iteration 5: H_t = 4, G_t = -0.3212, σ_t^2 = 35.8823
# Epoch 26, Iteration 6: H_t = 18, G_t = 0.5231, σ_t^2 = 28.0627
# Epoch 26, Iteration 7: H_t = 14, G_t = 0.4965, σ_t^2 = 33.4672
# Epoch 26, Iteration 8: H_t = 4, G_t = -1.7227, σ_t^2 = 45.6021
# Epoch 26, Iteration 9: H_t = 4, G_t = -3.1357, σ_t^2 = 40.9520
# Epoch 26, Iteration 10: H_t = 4, G_t = -0.8214, σ_t^2 = 36.7089
# Epoch 26, Iteration 11: H_t = 4, G_t = -4.2529, σ_t^2 = 47.5372
# Epoch 26, Iteration 12: H_t = 31, G_t = 1.1329, σ_t^2 = 35.5575
# Epoch 26, Iteration 13: H_t = 4, G_t = -0.6803, σ_t^2 = 31.6149
#     Worker 0: Train Loss: 2.5767, Train Accuracy: 33.53%
#     Worker 1: Train Loss: 2.5876, Train Accuracy: 33.67%
#     Worker 2: Train Loss: 2.5471, Train Accuracy: 34.82%
#     Worker 3: Train Loss: 2.5786, Train Accuracy: 33.41%
# Epoch 26: Test Loss: 2.4406, Test Accuracy: 37.09%
# Total Computation Time: 683.96 seconds
# Total Communication Time: 0.35 seconds
# Epoch 27, Iteration 1: H_t = 4, G_t = -0.2329, σ_t^2 = 38.3434
# Epoch 27, Iteration 2: H_t = 4, G_t = -1.4258, σ_t^2 = 39.7923
# Epoch 27, Iteration 3: H_t = 4, G_t = 0.1162, σ_t^2 = 32.2410
# Epoch 27, Iteration 4: H_t = 44, G_t = 1.7770, σ_t^2 = 39.7933
# Epoch 27, Iteration 5: H_t = 4, G_t = -1.6488, σ_t^2 = 38.7831
# Epoch 27, Iteration 6: H_t = 4, G_t = -1.0353, σ_t^2 = 40.4885
# Epoch 27, Iteration 7: H_t = 19, G_t = 0.6332, σ_t^2 = 32.3190
# Epoch 27, Iteration 8: H_t = 34, G_t = 1.4524, σ_t^2 = 41.6344
# Epoch 27, Iteration 9: H_t = 4, G_t = -0.7669, σ_t^2 = 35.7835
# Epoch 27, Iteration 10: H_t = 8, G_t = 0.2607, σ_t^2 = 29.5028
# Epoch 27, Iteration 11: H_t = 64, G_t = 4.3908, σ_t^2 = 42.6305
# Epoch 27, Iteration 12: H_t = 4, G_t = -2.9916, σ_t^2 = 41.5720
#     Worker 0: Train Loss: 2.5314, Train Accuracy: 34.75%
#     Worker 1: Train Loss: 2.5483, Train Accuracy: 34.33%
#     Worker 2: Train Loss: 2.5183, Train Accuracy: 34.49%
#     Worker 3: Train Loss: 2.5488, Train Accuracy: 34.30%
# Epoch 27: Test Loss: 2.4106, Test Accuracy: 37.85%
# Total Computation Time: 707.72 seconds
# Total Communication Time: 0.37 seconds
# Epoch 28, Iteration 1: H_t = 51, G_t = 1.6432, σ_t^2 = 32.1107
# Epoch 28, Iteration 2: H_t = 4, G_t = -1.8883, σ_t^2 = 36.7970
# Epoch 28, Iteration 3: H_t = 4, G_t = -0.7552, σ_t^2 = 34.8818
# Epoch 28, Iteration 4: H_t = 4, G_t = -1.6472, σ_t^2 = 34.0684
# Epoch 28, Iteration 5: H_t = 4, G_t = -0.5420, σ_t^2 = 37.7573
# Epoch 28, Iteration 6: H_t = 6, G_t = 0.2500, σ_t^2 = 36.0615
# Epoch 28, Iteration 7: H_t = 12, G_t = 0.5729, σ_t^2 = 45.9017
# Epoch 28, Iteration 8: H_t = 4, G_t = -1.0389, σ_t^2 = 48.7101
# Epoch 28, Iteration 9: H_t = 4, G_t = -1.3168, σ_t^2 = 40.7548
# Epoch 28, Iteration 10: H_t = 64, G_t = 3.9398, σ_t^2 = 35.5874
# Epoch 28, Iteration 11: H_t = 4, G_t = -0.7898, σ_t^2 = 38.2280
# Epoch 28, Iteration 12: H_t = 30, G_t = 1.0898, σ_t^2 = 35.9415
# Epoch 28, Iteration 13: H_t = 42, G_t = 1.7280, σ_t^2 = 41.0717
# Epoch 28, Iteration 14: H_t = 4, G_t = -1.2911, σ_t^2 = 39.4982
#     Worker 0: Train Loss: 2.5213, Train Accuracy: 34.73%
#     Worker 1: Train Loss: 2.5262, Train Accuracy: 34.78%
#     Worker 2: Train Loss: 2.4890, Train Accuracy: 36.15%
#     Worker 3: Train Loss: 2.5218, Train Accuracy: 34.89%
# Epoch 28: Test Loss: 2.3900, Test Accuracy: 38.52%
# Total Computation Time: 735.99 seconds
# Total Communication Time: 0.38 seconds
# Epoch 29, Iteration 1: H_t = 43, G_t = 1.4102, σ_t^2 = 32.1783
# Epoch 29, Iteration 2: H_t = 64, G_t = 3.1232, σ_t^2 = 48.5979
# Epoch 29, Iteration 3: H_t = 64, G_t = 3.8252, σ_t^2 = 39.3291
# Epoch 29, Iteration 4: H_t = 4, G_t = -1.3015, σ_t^2 = 41.5745
# Epoch 29, Iteration 5: H_t = 64, G_t = 2.2170, σ_t^2 = 33.1717
# Epoch 29, Iteration 6: H_t = 64, G_t = 2.8781, σ_t^2 = 38.5937
#     Worker 0: Train Loss: 2.4868, Train Accuracy: 35.05%
#     Worker 1: Train Loss: 2.5188, Train Accuracy: 35.43%
#     Worker 2: Train Loss: 2.4758, Train Accuracy: 36.11%
#     Worker 3: Train Loss: 2.5137, Train Accuracy: 34.56%
# Epoch 29: Test Loss: 2.3942, Test Accuracy: 38.10%
# Total Computation Time: 765.45 seconds
# Total Communication Time: 0.39 seconds
# Epoch 30, Iteration 1: H_t = 4, G_t = 0.1838, σ_t^2 = 36.9408
# Epoch 30, Iteration 2: H_t = 15, G_t = 0.5502, σ_t^2 = 34.7624
# Epoch 30, Iteration 3: H_t = 64, G_t = 6.2102, σ_t^2 = 39.5760
# Epoch 30, Iteration 4: H_t = 4, G_t = -0.8389, σ_t^2 = 40.3614
# Epoch 30, Iteration 5: H_t = 4, G_t = -0.4415, σ_t^2 = 36.8246
# Epoch 30, Iteration 6: H_t = 64, G_t = 2.3240, σ_t^2 = 33.0703
# Epoch 30, Iteration 7: H_t = 4, G_t = -1.4977, σ_t^2 = 36.4050
#     Worker 0: Train Loss: 2.4463, Train Accuracy: 36.34%
#     Worker 1: Train Loss: 2.4774, Train Accuracy: 35.81%
#     Worker 2: Train Loss: 2.4481, Train Accuracy: 36.57%
#     Worker 3: Train Loss: 2.4658, Train Accuracy: 35.66%
# Epoch 30: Test Loss: 2.3468, Test Accuracy: 39.52%
# Total Computation Time: 791.82 seconds
# Total Communication Time: 0.40 seconds
# Epoch 31, Iteration 1: H_t = 4, G_t = -0.3777, σ_t^2 = 37.6342
# Epoch 31, Iteration 2: H_t = 4, G_t = 0.0314, σ_t^2 = 34.3172
# Epoch 31, Iteration 3: H_t = 57, G_t = 2.1280, σ_t^2 = 37.2114
# Epoch 31, Iteration 4: H_t = 53, G_t = 1.9046, σ_t^2 = 35.6074
# Epoch 31, Iteration 5: H_t = 15, G_t = 0.4687, σ_t^2 = 29.4750
# Epoch 31, Iteration 6: H_t = 4, G_t = -1.2331, σ_t^2 = 39.5418
# Epoch 31, Iteration 7: H_t = 19, G_t = 0.7117, σ_t^2 = 37.2431
# Epoch 31, Iteration 8: H_t = 58, G_t = 2.4975, σ_t^2 = 42.6405
# Epoch 31, Iteration 9: H_t = 9, G_t = 0.4710, σ_t^2 = 47.5799
#     Worker 0: Train Loss: 2.4180, Train Accuracy: 37.18%
#     Worker 1: Train Loss: 2.4456, Train Accuracy: 36.22%
#     Worker 2: Train Loss: 2.4138, Train Accuracy: 37.18%
#     Worker 3: Train Loss: 2.4463, Train Accuracy: 36.19%
# Epoch 31: Test Loss: 2.3243, Test Accuracy: 39.80%
# Total Computation Time: 818.12 seconds
# Total Communication Time: 0.41 seconds
# Epoch 32, Iteration 1: H_t = 4, G_t = -0.1268, σ_t^2 = 35.8468
# Epoch 32, Iteration 2: H_t = 4, G_t = -0.9548, σ_t^2 = 45.3544
# Epoch 32, Iteration 3: H_t = 34, G_t = 1.2058, σ_t^2 = 34.7154
# Epoch 32, Iteration 4: H_t = 4, G_t = -1.5330, σ_t^2 = 39.3500
# Epoch 32, Iteration 5: H_t = 4, G_t = -1.1897, σ_t^2 = 36.9325
# Epoch 32, Iteration 6: H_t = 15, G_t = 0.5510, σ_t^2 = 34.6985
# Epoch 32, Iteration 7: H_t = 4, G_t = -1.9217, σ_t^2 = 50.4802
# Epoch 32, Iteration 8: H_t = 61, G_t = 2.9351, σ_t^2 = 48.0434
# Epoch 32, Iteration 9: H_t = 4, G_t = -2.9362, σ_t^2 = 50.9174
# Epoch 32, Iteration 10: H_t = 4, G_t = -1.8288, σ_t^2 = 45.1150
# Epoch 32, Iteration 11: H_t = 4, G_t = -0.4817, σ_t^2 = 32.9783
# Epoch 32, Iteration 12: H_t = 64, G_t = 3.1642, σ_t^2 = 38.5657
# Epoch 32, Iteration 13: H_t = 35, G_t = 1.5321, σ_t^2 = 43.0162
#     Worker 0: Train Loss: 2.3846, Train Accuracy: 37.56%
#     Worker 1: Train Loss: 2.3974, Train Accuracy: 37.76%
#     Worker 2: Train Loss: 2.3744, Train Accuracy: 38.44%
#     Worker 3: Train Loss: 2.4046, Train Accuracy: 37.55%
# Epoch 32: Test Loss: 2.3139, Test Accuracy: 39.57%
# Total Computation Time: 844.28 seconds
# Total Communication Time: 0.42 seconds
# Epoch 33, Iteration 1: H_t = 4, G_t = -0.6815, σ_t^2 = 38.1532
# Epoch 33, Iteration 2: H_t = 43, G_t = 1.9067, σ_t^2 = 44.0647
# Epoch 33, Iteration 3: H_t = 4, G_t = 0.0313, σ_t^2 = 46.5067
# Epoch 33, Iteration 4: H_t = 57, G_t = 1.9811, σ_t^2 = 34.5831
# Epoch 33, Iteration 5: H_t = 43, G_t = 1.5824, σ_t^2 = 36.7133
# Epoch 33, Iteration 6: H_t = 4, G_t = -1.4980, σ_t^2 = 38.2497
# Epoch 33, Iteration 7: H_t = 18, G_t = 0.6132, σ_t^2 = 33.4498
# Epoch 33, Iteration 8: H_t = 45, G_t = 1.9358, σ_t^2 = 42.9122
#     Worker 0: Train Loss: 2.3674, Train Accuracy: 38.17%
#     Worker 1: Train Loss: 2.3859, Train Accuracy: 37.94%
#     Worker 2: Train Loss: 2.3669, Train Accuracy: 38.34%
#     Worker 3: Train Loss: 2.3688, Train Accuracy: 38.18%
# Epoch 33: Test Loss: 2.2694, Test Accuracy: 41.04%
# Total Computation Time: 869.39 seconds
# Total Communication Time: 0.44 seconds
# Epoch 34, Iteration 1: H_t = 4, G_t = -0.2785, σ_t^2 = 45.5654
# Epoch 34, Iteration 2: H_t = 27, G_t = 1.1685, σ_t^2 = 42.4314
# Epoch 34, Iteration 3: H_t = 4, G_t = -0.5059, σ_t^2 = 39.5106
# Epoch 34, Iteration 4: H_t = 64, G_t = 2.6053, σ_t^2 = 35.3590
# Epoch 34, Iteration 5: H_t = 4, G_t = -1.1370, σ_t^2 = 44.2111
# Epoch 34, Iteration 6: H_t = 37, G_t = 1.4354, σ_t^2 = 38.0970
# Epoch 34, Iteration 7: H_t = 4, G_t = -1.2921, σ_t^2 = 38.8771
# Epoch 34, Iteration 8: H_t = 4, G_t = -0.1115, σ_t^2 = 39.2371
# Epoch 34, Iteration 9: H_t = 64, G_t = 2.7323, σ_t^2 = 35.5922
# Epoch 34, Iteration 10: H_t = 64, G_t = 3.0486, σ_t^2 = 38.0425
#     Worker 0: Train Loss: 2.3428, Train Accuracy: 38.59%
#     Worker 1: Train Loss: 2.3641, Train Accuracy: 38.34%
#     Worker 2: Train Loss: 2.3159, Train Accuracy: 39.46%
#     Worker 3: Train Loss: 2.3697, Train Accuracy: 38.03%
# Epoch 34: Test Loss: 2.2471, Test Accuracy: 41.40%
# Total Computation Time: 900.78 seconds
# Total Communication Time: 0.45 seconds
# Epoch 35, Iteration 1: H_t = 12, G_t = 0.4764, σ_t^2 = 39.0787
# Epoch 35, Iteration 2: H_t = 27, G_t = 1.0318, σ_t^2 = 37.2068
# Epoch 35, Iteration 3: H_t = 4, G_t = -2.8841, σ_t^2 = 50.0469
# Epoch 35, Iteration 4: H_t = 4, G_t = -0.1489, σ_t^2 = 41.3474
# Epoch 35, Iteration 5: H_t = 52, G_t = 1.8352, σ_t^2 = 35.0075
# Epoch 35, Iteration 6: H_t = 4, G_t = -3.7751, σ_t^2 = 50.6666
# Epoch 35, Iteration 7: H_t = 4, G_t = -0.7660, σ_t^2 = 35.8024
# Epoch 35, Iteration 8: H_t = 44, G_t = 1.6030, σ_t^2 = 35.7078
# Epoch 35, Iteration 9: H_t = 16, G_t = 0.7734, σ_t^2 = 45.6149
#     Worker 0: Train Loss: 2.3202, Train Accuracy: 39.21%
#     Worker 1: Train Loss: 2.3383, Train Accuracy: 39.17%
#     Worker 2: Train Loss: 2.2900, Train Accuracy: 40.09%
#     Worker 3: Train Loss: 2.3489, Train Accuracy: 38.73%
# Epoch 35: Test Loss: 2.2358, Test Accuracy: 41.82%
# Total Computation Time: 926.55 seconds
# Total Communication Time: 0.46 seconds
# Epoch 36, Iteration 1: H_t = 4, G_t = -2.2938, σ_t^2 = 43.2262
# Epoch 36, Iteration 2: H_t = 4, G_t = -1.7127, σ_t^2 = 42.1681
# Epoch 36, Iteration 3: H_t = 4, G_t = -1.2586, σ_t^2 = 43.4403
# Epoch 36, Iteration 4: H_t = 30, G_t = 1.0550, σ_t^2 = 35.0943
# Epoch 36, Iteration 5: H_t = 15, G_t = 0.7652, σ_t^2 = 48.9007
# Epoch 36, Iteration 6: H_t = 4, G_t = 0.1948, σ_t^2 = 45.1210
# Epoch 36, Iteration 7: H_t = 4, G_t = -0.8742, σ_t^2 = 45.2662
# Epoch 36, Iteration 8: H_t = 64, G_t = 4.1704, σ_t^2 = 46.8359
# Epoch 36, Iteration 9: H_t = 4, G_t = -0.6015, σ_t^2 = 41.7860
# Epoch 36, Iteration 10: H_t = 23, G_t = 0.8008, σ_t^2 = 34.2559
# Epoch 36, Iteration 11: H_t = 40, G_t = 1.7932, σ_t^2 = 43.9090
# Epoch 36, Iteration 12: H_t = 18, G_t = 0.9837, σ_t^2 = 51.8664
#     Worker 0: Train Loss: 2.2823, Train Accuracy: 39.55%
#     Worker 1: Train Loss: 2.2767, Train Accuracy: 40.35%
#     Worker 2: Train Loss: 2.2574, Train Accuracy: 41.34%
#     Worker 3: Train Loss: 2.2873, Train Accuracy: 39.92%
# Epoch 36: Test Loss: 2.2306, Test Accuracy: 41.40%
# Total Computation Time: 952.32 seconds
# Total Communication Time: 0.47 seconds
# Epoch 37, Iteration 1: H_t = 4, G_t = -0.5502, σ_t^2 = 38.7813
# Epoch 37, Iteration 2: H_t = 64, G_t = 3.6757, σ_t^2 = 35.1738
# Epoch 37, Iteration 3: H_t = 4, G_t = -0.9605, σ_t^2 = 41.9659
# Epoch 37, Iteration 4: H_t = 19, G_t = 0.7263, σ_t^2 = 37.2265
# Epoch 37, Iteration 5: H_t = 4, G_t = 0.1624, σ_t^2 = 42.1241
# Epoch 37, Iteration 6: H_t = 7, G_t = 0.2920, σ_t^2 = 36.7570
# Epoch 37, Iteration 7: H_t = 27, G_t = 1.0882, σ_t^2 = 40.2746
# Epoch 37, Iteration 8: H_t = 13, G_t = 0.7298, σ_t^2 = 52.7682
# Epoch 37, Iteration 9: H_t = 4, G_t = -0.7804, σ_t^2 = 42.7069
# Epoch 37, Iteration 10: H_t = 4, G_t = -0.4934, σ_t^2 = 41.7681
# Epoch 37, Iteration 11: H_t = 4, G_t = 0.0860, σ_t^2 = 43.5247
# Epoch 37, Iteration 12: H_t = 4, G_t = -0.6516, σ_t^2 = 42.7411
# Epoch 37, Iteration 13: H_t = 4, G_t = 0.0403, σ_t^2 = 41.2794
# Epoch 37, Iteration 14: H_t = 50, G_t = 2.3000, σ_t^2 = 45.9558
# Epoch 37, Iteration 15: H_t = 4, G_t = -0.0179, σ_t^2 = 49.5835
#     Worker 0: Train Loss: 2.2564, Train Accuracy: 40.43%
#     Worker 1: Train Loss: 2.2648, Train Accuracy: 40.15%
#     Worker 2: Train Loss: 2.2413, Train Accuracy: 41.36%
#     Worker 3: Train Loss: 2.2579, Train Accuracy: 40.67%
# Epoch 37: Test Loss: 2.2000, Test Accuracy: 42.49%
# Total Computation Time: 979.75 seconds
# Total Communication Time: 0.49 seconds
# Epoch 38, Iteration 1: H_t = 4, G_t = -0.6657, σ_t^2 = 40.4345
# Epoch 38, Iteration 2: H_t = 4, G_t = -0.5019, σ_t^2 = 37.9554
# Epoch 38, Iteration 3: H_t = 4, G_t = -0.3761, σ_t^2 = 38.3421
# Epoch 38, Iteration 4: H_t = 20, G_t = 0.8198, σ_t^2 = 39.3088
# Epoch 38, Iteration 5: H_t = 4, G_t = -1.7026, σ_t^2 = 53.6172
# Epoch 38, Iteration 6: H_t = 4, G_t = -0.7714, σ_t^2 = 39.8838
# Epoch 38, Iteration 7: H_t = 64, G_t = 6.7313, σ_t^2 = 41.0665
# Epoch 38, Iteration 8: H_t = 4, G_t = -1.2337, σ_t^2 = 48.4566
# Epoch 38, Iteration 9: H_t = 53, G_t = 2.1694, σ_t^2 = 40.7283
# Epoch 38, Iteration 10: H_t = 4, G_t = -0.2560, σ_t^2 = 52.0134
# Epoch 38, Iteration 11: H_t = 4, G_t = -0.2208, σ_t^2 = 38.2144
# Epoch 38, Iteration 12: H_t = 4, G_t = -0.2693, σ_t^2 = 42.5191
# Epoch 38, Iteration 13: H_t = 43, G_t = 1.8025, σ_t^2 = 41.5942
# Epoch 38, Iteration 14: H_t = 14, G_t = 0.7288, σ_t^2 = 48.6221
#     Worker 0: Train Loss: 2.2233, Train Accuracy: 41.18%
#     Worker 1: Train Loss: 2.2590, Train Accuracy: 40.71%
#     Worker 2: Train Loss: 2.2160, Train Accuracy: 41.81%
#     Worker 3: Train Loss: 2.2557, Train Accuracy: 40.68%
# Epoch 38: Test Loss: 2.1861, Test Accuracy: 42.59%
# Total Computation Time: 1006.05 seconds
# Total Communication Time: 0.51 seconds
# Epoch 39, Iteration 1: H_t = 38, G_t = 1.5436, σ_t^2 = 40.0767
# Epoch 39, Iteration 2: H_t = 22, G_t = 0.8826, σ_t^2 = 39.9103
# Epoch 39, Iteration 3: H_t = 39, G_t = 1.8512, σ_t^2 = 47.4172
# Epoch 39, Iteration 4: H_t = 4, G_t = -1.1234, σ_t^2 = 41.2025
# Epoch 39, Iteration 5: H_t = 27, G_t = 1.0113, σ_t^2 = 36.3032
# Epoch 39, Iteration 6: H_t = 4, G_t = -2.1349, σ_t^2 = 46.6431
# Epoch 39, Iteration 7: H_t = 4, G_t = -1.8388, σ_t^2 = 49.3806
# Epoch 39, Iteration 8: H_t = 57, G_t = 2.3696, σ_t^2 = 40.9899
# Epoch 39, Iteration 9: H_t = 4, G_t = -1.9442, σ_t^2 = 51.3965
#     Worker 0: Train Loss: 2.2094, Train Accuracy: 41.30%
#     Worker 1: Train Loss: 2.2227, Train Accuracy: 41.46%
#     Worker 2: Train Loss: 2.2135, Train Accuracy: 41.40%
#     Worker 3: Train Loss: 2.2350, Train Accuracy: 40.99%
# Epoch 39: Test Loss: 2.1696, Test Accuracy: 43.26%
# Total Computation Time: 1031.24 seconds
# Total Communication Time: 0.52 seconds
# Epoch 40, Iteration 1: H_t = 4, G_t = -0.3637, σ_t^2 = 43.4135
# Epoch 40, Iteration 2: H_t = 44, G_t = 1.8489, σ_t^2 = 42.0010
# Epoch 40, Iteration 3: H_t = 10, G_t = 0.4875, σ_t^2 = 45.6848
# Epoch 40, Iteration 4: H_t = 4, G_t = -2.7353, σ_t^2 = 53.0822
# Epoch 40, Iteration 5: H_t = 60, G_t = 2.5168, σ_t^2 = 41.4522
# Epoch 40, Iteration 6: H_t = 44, G_t = 1.9245, σ_t^2 = 43.1942
# Epoch 40, Iteration 7: H_t = 4, G_t = -1.4190, σ_t^2 = 54.0788
# Epoch 40, Iteration 8: H_t = 4, G_t = -0.7154, σ_t^2 = 45.4456
# Epoch 40, Iteration 9: H_t = 10, G_t = 0.4652, σ_t^2 = 44.5083
# Epoch 40, Iteration 10: H_t = 41, G_t = 1.7565, σ_t^2 = 42.4751
# Epoch 40, Iteration 11: H_t = 36, G_t = 1.7069, σ_t^2 = 46.8352
#     Worker 0: Train Loss: 2.2009, Train Accuracy: 41.50%
#     Worker 1: Train Loss: 2.2023, Train Accuracy: 41.95%
#     Worker 2: Train Loss: 2.1746, Train Accuracy: 42.51%
#     Worker 3: Train Loss: 2.2151, Train Accuracy: 41.67%
# Epoch 40: Test Loss: 2.1585, Test Accuracy: 43.38%
# Total Computation Time: 1058.32 seconds
# Total Communication Time: 0.53 seconds
# Epoch 41, Iteration 1: H_t = 4, G_t = -0.1686, σ_t^2 = 46.7369
# Epoch 41, Iteration 2: H_t = 4, G_t = -0.2567, σ_t^2 = 36.5416
# Epoch 41, Iteration 3: H_t = 4, G_t = -0.5009, σ_t^2 = 41.6790
# Epoch 41, Iteration 4: H_t = 64, G_t = 3.9914, σ_t^2 = 40.5582
# Epoch 41, Iteration 5: H_t = 18, G_t = 0.9033, σ_t^2 = 48.2368
# Epoch 41, Iteration 6: H_t = 4, G_t = -1.4773, σ_t^2 = 44.2159
# Epoch 41, Iteration 7: H_t = 26, G_t = 1.0730, σ_t^2 = 39.9150
# Epoch 41, Iteration 8: H_t = 4, G_t = -0.7582, σ_t^2 = 49.2010
# Epoch 41, Iteration 9: H_t = 4, G_t = -0.9387, σ_t^2 = 57.7953
# Epoch 41, Iteration 10: H_t = 56, G_t = 2.5560, σ_t^2 = 45.6135
# Epoch 41, Iteration 11: H_t = 17, G_t = 0.8889, σ_t^2 = 50.5248
#     Worker 0: Train Loss: 2.1760, Train Accuracy: 42.50%
#     Worker 1: Train Loss: 2.1761, Train Accuracy: 42.00%
#     Worker 2: Train Loss: 2.1664, Train Accuracy: 42.68%
#     Worker 3: Train Loss: 2.1977, Train Accuracy: 42.25%
# Epoch 41: Test Loss: 2.1504, Test Accuracy: 43.69%
# Total Computation Time: 1085.24 seconds
# Total Communication Time: 0.55 seconds
# Epoch 42, Iteration 1: H_t = 31, G_t = 1.5340, σ_t^2 = 48.3804
# Epoch 42, Iteration 2: H_t = 4, G_t = -1.4552, σ_t^2 = 47.6164
# Epoch 42, Iteration 3: H_t = 35, G_t = 1.3594, σ_t^2 = 38.4428
# Epoch 42, Iteration 4: H_t = 34, G_t = 1.4525, σ_t^2 = 42.6251
# Epoch 42, Iteration 5: H_t = 4, G_t = -0.1266, σ_t^2 = 45.3966
# Epoch 42, Iteration 6: H_t = 61, G_t = 2.2843, σ_t^2 = 36.9946
# Epoch 42, Iteration 7: H_t = 4, G_t = -0.2749, σ_t^2 = 39.3182
# Epoch 42, Iteration 8: H_t = 4, G_t = -0.1282, σ_t^2 = 45.5757
# Epoch 42, Iteration 9: H_t = 10, G_t = 0.4563, σ_t^2 = 41.5717
# Epoch 42, Iteration 10: H_t = 18, G_t = 0.7740, σ_t^2 = 41.0789
#     Worker 0: Train Loss: 2.1635, Train Accuracy: 42.34%
#     Worker 1: Train Loss: 2.1601, Train Accuracy: 42.58%
#     Worker 2: Train Loss: 2.1268, Train Accuracy: 43.44%
#     Worker 3: Train Loss: 2.1484, Train Accuracy: 43.11%
# Epoch 42: Test Loss: 2.1355, Test Accuracy: 43.99%
# Total Computation Time: 1109.71 seconds
# Total Communication Time: 0.56 seconds
# Epoch 43, Iteration 1: H_t = 64, G_t = 3.0494, σ_t^2 = 43.4428
# Epoch 43, Iteration 2: H_t = 41, G_t = 2.0333, σ_t^2 = 49.0880
# Epoch 43, Iteration 3: H_t = 24, G_t = 1.0573, σ_t^2 = 43.1144
# Epoch 43, Iteration 4: H_t = 4, G_t = -0.7285, σ_t^2 = 43.0286
# Epoch 43, Iteration 5: H_t = 29, G_t = 1.2922, σ_t^2 = 43.1356
# Epoch 43, Iteration 6: H_t = 13, G_t = 0.6444, σ_t^2 = 47.1348
# Epoch 43, Iteration 7: H_t = 4, G_t = 0.2551, σ_t^2 = 52.3499
# Epoch 43, Iteration 8: H_t = 27, G_t = 1.1268, σ_t^2 = 41.4374
#     Worker 0: Train Loss: 2.1175, Train Accuracy: 43.51%
#     Worker 1: Train Loss: 2.1413, Train Accuracy: 43.51%
#     Worker 2: Train Loss: 2.1243, Train Accuracy: 43.77%
#     Worker 3: Train Loss: 2.1458, Train Accuracy: 42.41%
# Epoch 43: Test Loss: 2.1250, Test Accuracy: 44.41%
# Total Computation Time: 1133.83 seconds
# Total Communication Time: 0.57 seconds
# Epoch 44, Iteration 1: H_t = 14, G_t = 0.8113, σ_t^2 = 55.8459
# Epoch 44, Iteration 2: H_t = 5, G_t = 0.2844, σ_t^2 = 56.1907
# Epoch 44, Iteration 3: H_t = 4, G_t = -1.7441, σ_t^2 = 54.9769
# Epoch 44, Iteration 4: H_t = 4, G_t = -0.5925, σ_t^2 = 44.1060
# Epoch 44, Iteration 5: H_t = 14, G_t = 0.6812, σ_t^2 = 47.1444
# Epoch 44, Iteration 6: H_t = 4, G_t = 0.1600, σ_t^2 = 43.6393
# Epoch 44, Iteration 7: H_t = 4, G_t = 0.1858, σ_t^2 = 44.7839
# Epoch 44, Iteration 8: H_t = 37, G_t = 1.7380, σ_t^2 = 46.2316
# Epoch 44, Iteration 9: H_t = 4, G_t = -1.9725, σ_t^2 = 46.8022
# Epoch 44, Iteration 10: H_t = 14, G_t = 0.6046, σ_t^2 = 41.4531
# Epoch 44, Iteration 11: H_t = 4, G_t = -0.0050, σ_t^2 = 54.0536
# Epoch 44, Iteration 12: H_t = 12, G_t = 0.5497, σ_t^2 = 44.8680
# Epoch 44, Iteration 13: H_t = 39, G_t = 1.9062, σ_t^2 = 48.8204
# Epoch 44, Iteration 14: H_t = 23, G_t = 1.1357, σ_t^2 = 47.7274
# Epoch 44, Iteration 15: H_t = 4, G_t = -1.8189, σ_t^2 = 50.0133
#     Worker 0: Train Loss: 2.0981, Train Accuracy: 44.00%
#     Worker 1: Train Loss: 2.0880, Train Accuracy: 43.88%
#     Worker 2: Train Loss: 2.0785, Train Accuracy: 44.77%
#     Worker 3: Train Loss: 2.1065, Train Accuracy: 44.00%
# Epoch 44: Test Loss: 2.1013, Test Accuracy: 45.02%
# Total Computation Time: 1158.89 seconds
# Total Communication Time: 0.59 seconds
# Epoch 45, Iteration 1: H_t = 4, G_t = -0.6019, σ_t^2 = 46.5359
# Epoch 45, Iteration 2: H_t = 40, G_t = 1.7440, σ_t^2 = 43.3821
# Epoch 45, Iteration 3: H_t = 6, G_t = 0.3492, σ_t^2 = 50.9017
# Epoch 45, Iteration 4: H_t = 4, G_t = -1.3412, σ_t^2 = 48.9552
# Epoch 45, Iteration 5: H_t = 4, G_t = 0.0740, σ_t^2 = 46.2309
# Epoch 45, Iteration 6: H_t = 33, G_t = 1.3247, σ_t^2 = 39.9975
# Epoch 45, Iteration 7: H_t = 4, G_t = -2.1840, σ_t^2 = 47.7491
# Epoch 45, Iteration 8: H_t = 20, G_t = 0.9753, σ_t^2 = 46.7449
# Epoch 45, Iteration 9: H_t = 46, G_t = 4.0186, σ_t^2 = 86.8655
# Epoch 45, Iteration 10: H_t = 33, G_t = 1.6760, σ_t^2 = 50.5717
# Epoch 45, Iteration 11: H_t = 33, G_t = 1.8031, σ_t^2 = 53.2580
#     Worker 0: Train Loss: 2.0844, Train Accuracy: 44.09%
#     Worker 1: Train Loss: 2.0793, Train Accuracy: 44.50%
#     Worker 2: Train Loss: 2.0938, Train Accuracy: 44.35%
#     Worker 3: Train Loss: 2.1215, Train Accuracy: 43.63%
# Epoch 45: Test Loss: 2.1036, Test Accuracy: 44.64%
# Total Computation Time: 1182.39 seconds
# Total Communication Time: 0.60 seconds
# Epoch 46, Iteration 1: H_t = 6, G_t = 0.4045, σ_t^2 = 57.9364
# Epoch 46, Iteration 2: H_t = 4, G_t = -0.7514, σ_t^2 = 47.9644
# Epoch 46, Iteration 3: H_t = 64, G_t = 5.2243, σ_t^2 = 44.0468
# Epoch 46, Iteration 4: H_t = 4, G_t = 0.0071, σ_t^2 = 50.4943
# Epoch 46, Iteration 5: H_t = 7, G_t = 0.3333, σ_t^2 = 46.9556
# Epoch 46, Iteration 6: H_t = 4, G_t = -1.0660, σ_t^2 = 51.3601
# Epoch 46, Iteration 7: H_t = 4, G_t = -0.5725, σ_t^2 = 44.5716
# Epoch 46, Iteration 8: H_t = 64, G_t = 3.4879, σ_t^2 = 45.6709
# Epoch 46, Iteration 9: H_t = 4, G_t = -0.7874, σ_t^2 = 51.4087
# Epoch 46, Iteration 10: H_t = 63, G_t = 2.6732, σ_t^2 = 42.1301
# Epoch 46, Iteration 11: H_t = 4, G_t = -0.0006, σ_t^2 = 44.8299
#     Worker 0: Train Loss: 2.0867, Train Accuracy: 44.20%
#     Worker 1: Train Loss: 2.1196, Train Accuracy: 43.57%
#     Worker 2: Train Loss: 2.0649, Train Accuracy: 44.93%
#     Worker 3: Train Loss: 2.1082, Train Accuracy: 44.21%
# Epoch 46: Test Loss: 2.1081, Test Accuracy: 44.76%
# Total Computation Time: 1213.12 seconds
# Total Communication Time: 0.62 seconds
# Epoch 47, Iteration 1: H_t = 4, G_t = -1.3709, σ_t^2 = 44.6076
# Epoch 47, Iteration 2: H_t = 46, G_t = 1.9718, σ_t^2 = 42.6301
# Epoch 47, Iteration 3: H_t = 4, G_t = -1.3279, σ_t^2 = 46.5206
# Epoch 47, Iteration 4: H_t = 64, G_t = 2.7308, σ_t^2 = 35.0577
# Epoch 47, Iteration 5: H_t = 4, G_t = -0.2338, σ_t^2 = 47.5582
# Epoch 47, Iteration 6: H_t = 4, G_t = -1.2384, σ_t^2 = 45.3211
# Epoch 47, Iteration 7: H_t = 8, G_t = 0.3570, σ_t^2 = 44.4432
# Epoch 47, Iteration 8: H_t = 13, G_t = 0.7010, σ_t^2 = 51.2722
# Epoch 47, Iteration 9: H_t = 4, G_t = -0.5333, σ_t^2 = 51.0669
# Epoch 47, Iteration 10: H_t = 5, G_t = 0.2398, σ_t^2 = 41.7641
# Epoch 47, Iteration 11: H_t = 4, G_t = -0.4440, σ_t^2 = 56.1615
# Epoch 47, Iteration 12: H_t = 28, G_t = 1.4783, σ_t^2 = 52.4545
# Epoch 47, Iteration 13: H_t = 4, G_t = -0.8205, σ_t^2 = 47.6481
# Epoch 47, Iteration 14: H_t = 9, G_t = 0.4088, σ_t^2 = 45.2566
#     Worker 0: Train Loss: 2.0524, Train Accuracy: 44.50%
#     Worker 1: Train Loss: 2.0692, Train Accuracy: 44.62%
#     Worker 2: Train Loss: 2.0335, Train Accuracy: 45.55%
#     Worker 3: Train Loss: 2.0552, Train Accuracy: 45.46%
# Epoch 47: Test Loss: 2.0815, Test Accuracy: 45.82%
# Total Computation Time: 1236.26 seconds
# Total Communication Time: 0.63 seconds
# Epoch 48, Iteration 1: H_t = 9, G_t = 0.4614, σ_t^2 = 49.7076
# Epoch 48, Iteration 2: H_t = 45, G_t = 2.2098, σ_t^2 = 48.0979
# Epoch 48, Iteration 3: H_t = 4, G_t = -0.7947, σ_t^2 = 43.5515
# Epoch 48, Iteration 4: H_t = 4, G_t = -1.3921, σ_t^2 = 55.5097
# ...
# Epoch 141, Iteration 23: H_t = 4, G_t = -4.9902, σ_t^2 = 102.4990
# Epoch 141, Iteration 24: H_t = 4, G_t = -1.8935, σ_t^2 = 101.8799
# Epoch 141, Iteration 25: H_t = 14, G_t = 1.6640, σ_t^2 = 112.5484
# Epoch 141, Iteration 26: H_t = 31, G_t = 3.0576, σ_t^2 = 96.9852
#     Worker 0: Train Loss: 1.2095, Train Accuracy: 65.22%
#     Worker 1: Train Loss: 1.2334, Train Accuracy: 64.96%
#     Worker 2: Train Loss: 1.2147, Train Accuracy: 65.58%
#     Worker 3: Train Loss: 1.2345, Train Accuracy: 65.05%
# Epoch 141: Test Loss: 1.9261, Test Accuracy: 51.65%
# Total Computation Time: 3553.02 seconds
# Total Communication Time: 2.47 seconds
# Epoch 142, Iteration 1: H_t = 4, G_t = -0.1613, σ_t^2 = 107.6015
# Epoch 142, Iteration 2: H_t = 13, G_t = 1.2487, σ_t^2 = 93.2263
# Epoch 142, Iteration 3: H_t = 4, G_t = -1.5008, σ_t^2 = 106.5867
# Epoch 142, Iteration 4: H_t = 4, G_t = -2.6138, σ_t^2 = 104.9401
# Epoch 142, Iteration 5: H_t = 4, G_t = -0.9247, σ_t^2 = 96.3786
# Epoch 142, Iteration 6: H_t = 16, G_t = 1.6244, σ_t^2 = 97.3780
# Epoch 142, Iteration 7: H_t = 4, G_t = 0.0503, σ_t^2 = 116.2420
# Epoch 142, Iteration 8: H_t = 4, G_t = 0.2939, σ_t^2 = 89.6530
# Epoch 142, Iteration 9: H_t = 40, G_t = 3.9681, σ_t^2 = 97.4826
# Epoch 142, Iteration 10: H_t = 4, G_t = -0.2753, σ_t^2 = 112.5569
# Epoch 142, Iteration 11: H_t = 4, G_t = -2.4087, σ_t^2 = 112.5672
# Epoch 142, Iteration 12: H_t = 4, G_t = -0.5870, σ_t^2 = 104.5064
# Epoch 142, Iteration 13: H_t = 20, G_t = 1.9278, σ_t^2 = 95.9199
# Epoch 142, Iteration 14: H_t = 4, G_t = 0.4573, σ_t^2 = 98.6341
# Epoch 142, Iteration 15: H_t = 16, G_t = 1.7813, σ_t^2 = 108.3294
# Epoch 142, Iteration 16: H_t = 21, G_t = 2.3292, σ_t^2 = 107.4776
# Epoch 142, Iteration 17: H_t = 11, G_t = 1.2036, σ_t^2 = 108.6645
#     Worker 0: Train Loss: 1.2448, Train Accuracy: 64.47%
#     Worker 1: Train Loss: 1.2348, Train Accuracy: 65.30%
#     Worker 2: Train Loss: 1.2042, Train Accuracy: 66.24%
#     Worker 3: Train Loss: 1.2353, Train Accuracy: 65.15%
# Epoch 142: Test Loss: 1.9262, Test Accuracy: 51.82%
# Total Computation Time: 3576.02 seconds
# Total Communication Time: 2.49 seconds
# Epoch 143, Iteration 1: H_t = 4, G_t = -4.2013, σ_t^2 = 108.8357
# Epoch 143, Iteration 2: H_t = 4, G_t = -0.4915, σ_t^2 = 115.8664
# Epoch 143, Iteration 3: H_t = 4, G_t = -2.4764, σ_t^2 = 98.0076
# Epoch 143, Iteration 4: H_t = 4, G_t = -1.5953, σ_t^2 = 88.8179
# Epoch 143, Iteration 5: H_t = 9, G_t = 0.8866, σ_t^2 = 91.8044
# Epoch 143, Iteration 6: H_t = 4, G_t = -0.5529, σ_t^2 = 86.8605
# Epoch 143, Iteration 7: H_t = 4, G_t = -3.5302, σ_t^2 = 119.6213
# Epoch 143, Iteration 8: H_t = 20, G_t = 2.1288, σ_t^2 = 104.5930
# Epoch 143, Iteration 9: H_t = 4, G_t = -2.5424, σ_t^2 = 96.4293
# Epoch 143, Iteration 10: H_t = 9, G_t = 0.7621, σ_t^2 = 82.4696
# Epoch 143, Iteration 11: H_t = 4, G_t = 0.0543, σ_t^2 = 94.9801
# Epoch 143, Iteration 12: H_t = 4, G_t = -0.4729, σ_t^2 = 100.4776
# Epoch 143, Iteration 13: H_t = 46, G_t = 4.6456, σ_t^2 = 100.6209
# Epoch 143, Iteration 14: H_t = 4, G_t = -2.0854, σ_t^2 = 96.4208
# Epoch 143, Iteration 15: H_t = 4, G_t = -0.1973, σ_t^2 = 101.5909
# Epoch 143, Iteration 16: H_t = 4, G_t = -3.0479, σ_t^2 = 101.2407
# Epoch 143, Iteration 17: H_t = 12, G_t = 1.2846, σ_t^2 = 104.3372
# Epoch 143, Iteration 18: H_t = 4, G_t = -0.3574, σ_t^2 = 98.7149
# Epoch 143, Iteration 19: H_t = 4, G_t = -0.2770, σ_t^2 = 85.2885
# Epoch 143, Iteration 20: H_t = 4, G_t = -0.7212, σ_t^2 = 91.8895
# Epoch 143, Iteration 21: H_t = 4, G_t = -0.6703, σ_t^2 = 85.3201
# Epoch 143, Iteration 22: H_t = 4, G_t = -0.5676, σ_t^2 = 83.8310
# Epoch 143, Iteration 23: H_t = 4, G_t = -2.4444, σ_t^2 = 102.1975
# Epoch 143, Iteration 24: H_t = 28, G_t = 2.7995, σ_t^2 = 98.1714
# Epoch 143, Iteration 25: H_t = 4, G_t = -1.3495, σ_t^2 = 93.0031
#     Worker 0: Train Loss: 1.2078, Train Accuracy: 65.45%
#     Worker 1: Train Loss: 1.2200, Train Accuracy: 65.73%
#     Worker 2: Train Loss: 1.2087, Train Accuracy: 65.53%
#     Worker 3: Train Loss: 1.2238, Train Accuracy: 65.30%
# Epoch 143: Test Loss: 1.9253, Test Accuracy: 51.75%
# Total Computation Time: 3600.10 seconds
# Total Communication Time: 2.52 seconds
# Epoch 144, Iteration 1: H_t = 16, G_t = 1.6164, σ_t^2 = 99.3463
# Epoch 144, Iteration 2: H_t = 4, G_t = -2.2340, σ_t^2 = 107.1355
# Epoch 144, Iteration 3: H_t = 4, G_t = -2.6570, σ_t^2 = 113.0582
# Epoch 144, Iteration 4: H_t = 11, G_t = 0.9740, σ_t^2 = 87.9677
# Epoch 144, Iteration 5: H_t = 4, G_t = -3.0167, σ_t^2 = 100.2692
# Epoch 144, Iteration 6: H_t = 7, G_t = 0.7563, σ_t^2 = 97.5002
# Epoch 144, Iteration 7: H_t = 11, G_t = 1.1563, σ_t^2 = 97.1813
# Epoch 144, Iteration 8: H_t = 6, G_t = 0.5531, σ_t^2 = 90.1513
# Epoch 144, Iteration 9: H_t = 19, G_t = 1.8391, σ_t^2 = 93.8677
# Epoch 144, Iteration 10: H_t = 30, G_t = 2.6642, σ_t^2 = 87.5265
# Epoch 144, Iteration 11: H_t = 4, G_t = -1.4918, σ_t^2 = 104.8319
# Epoch 144, Iteration 12: H_t = 4, G_t = -1.7235, σ_t^2 = 106.2699
# Epoch 144, Iteration 13: H_t = 5, G_t = 0.5312, σ_t^2 = 91.6545
# Epoch 144, Iteration 14: H_t = 4, G_t = -1.8917, σ_t^2 = 104.9826
# Epoch 144, Iteration 15: H_t = 4, G_t = -2.2678, σ_t^2 = 96.3029
# Epoch 144, Iteration 16: H_t = 43, G_t = 4.8031, σ_t^2 = 110.8255
# Epoch 144, Iteration 17: H_t = 4, G_t = -0.8649, σ_t^2 = 91.2757
# Epoch 144, Iteration 18: H_t = 9, G_t = 0.8982, σ_t^2 = 97.2554
# Epoch 144, Iteration 19: H_t = 4, G_t = -1.3545, σ_t^2 = 98.3599
# Epoch 144, Iteration 20: H_t = 4, G_t = -1.4657, σ_t^2 = 91.1662
#     Worker 0: Train Loss: 1.2208, Train Accuracy: 65.03%
#     Worker 1: Train Loss: 1.2014, Train Accuracy: 66.02%
#     Worker 2: Train Loss: 1.2245, Train Accuracy: 65.54%
#     Worker 3: Train Loss: 1.2333, Train Accuracy: 65.64%
# Epoch 144: Test Loss: 1.9257, Test Accuracy: 51.74%
# Total Computation Time: 3622.92 seconds
# Total Communication Time: 2.55 seconds
# Epoch 145, Iteration 1: H_t = 4, G_t = -1.1506, σ_t^2 = 96.2369
# Epoch 145, Iteration 2: H_t = 36, G_t = 3.2722, σ_t^2 = 90.5745
# Epoch 145, Iteration 3: H_t = 11, G_t = 1.1417, σ_t^2 = 96.9208
# Epoch 145, Iteration 4: H_t = 4, G_t = -2.9615, σ_t^2 = 98.6350
# Epoch 145, Iteration 5: H_t = 21, G_t = 2.0869, σ_t^2 = 98.1659
# Epoch 145, Iteration 6: H_t = 16, G_t = 1.3830, σ_t^2 = 85.3036
# Epoch 145, Iteration 7: H_t = 18, G_t = 1.7330, σ_t^2 = 95.1180
# Epoch 145, Iteration 8: H_t = 6, G_t = 0.6012, σ_t^2 = 90.2978
# Epoch 145, Iteration 9: H_t = 4, G_t = -1.0796, σ_t^2 = 99.2919
# Epoch 145, Iteration 10: H_t = 26, G_t = 2.2081, σ_t^2 = 84.1682
# Epoch 145, Iteration 11: H_t = 4, G_t = -0.9765, σ_t^2 = 103.8339
# Epoch 145, Iteration 12: H_t = 4, G_t = -1.1983, σ_t^2 = 111.6321
# Epoch 145, Iteration 13: H_t = 19, G_t = 1.9107, σ_t^2 = 98.2869
# Epoch 145, Iteration 14: H_t = 5, G_t = 0.5683, σ_t^2 = 96.1201
# Epoch 145, Iteration 15: H_t = 9, G_t = 0.8728, σ_t^2 = 89.4947
# Epoch 145, Iteration 16: H_t = 4, G_t = -4.2116, σ_t^2 = 111.6622
# Epoch 145, Iteration 17: H_t = 12, G_t = 1.0982, σ_t^2 = 88.0898
# Epoch 145, Iteration 18: H_t = 4, G_t = -3.6999, σ_t^2 = 98.4752
#     Worker 0: Train Loss: 1.2300, Train Accuracy: 65.25%
#     Worker 1: Train Loss: 1.2206, Train Accuracy: 65.65%
#     Worker 2: Train Loss: 1.2033, Train Accuracy: 65.87%
#     Worker 3: Train Loss: 1.2108, Train Accuracy: 66.04%
# Epoch 145: Test Loss: 1.9259, Test Accuracy: 51.78%
# Total Computation Time: 3647.02 seconds
# Total Communication Time: 2.57 seconds
# Epoch 146, Iteration 1: H_t = 4, G_t = -5.9962, σ_t^2 = 128.5745
# Epoch 146, Iteration 2: H_t = 12, G_t = 1.0294, σ_t^2 = 80.7787
# Epoch 146, Iteration 3: H_t = 15, G_t = 1.5403, σ_t^2 = 99.4453
# Epoch 146, Iteration 4: H_t = 33, G_t = 2.8129, σ_t^2 = 83.1776
# Epoch 146, Iteration 5: H_t = 4, G_t = -1.7319, σ_t^2 = 104.9546
# Epoch 146, Iteration 6: H_t = 4, G_t = -2.2558, σ_t^2 = 95.8033
# Epoch 146, Iteration 7: H_t = 9, G_t = 0.9747, σ_t^2 = 97.6438
# Epoch 146, Iteration 8: H_t = 4, G_t = -1.2720, σ_t^2 = 89.0359
# Epoch 146, Iteration 9: H_t = 4, G_t = 0.4209, σ_t^2 = 116.6033
# Epoch 146, Iteration 10: H_t = 4, G_t = -0.9536, σ_t^2 = 89.0114
# Epoch 146, Iteration 11: H_t = 4, G_t = -0.2368, σ_t^2 = 94.5251
# Epoch 146, Iteration 12: H_t = 12, G_t = 1.3252, σ_t^2 = 109.1309
# Epoch 146, Iteration 13: H_t = 44, G_t = 4.4726, σ_t^2 = 99.8459
# Epoch 146, Iteration 14: H_t = 4, G_t = -1.6728, σ_t^2 = 87.4057
# Epoch 146, Iteration 15: H_t = 4, G_t = -2.2456, σ_t^2 = 92.5580
# Epoch 146, Iteration 16: H_t = 4, G_t = -0.6681, σ_t^2 = 110.5496
# Epoch 146, Iteration 17: H_t = 4, G_t = -1.4369, σ_t^2 = 98.4436
# Epoch 146, Iteration 18: H_t = 4, G_t = -0.7692, σ_t^2 = 99.6211
# Epoch 146, Iteration 19: H_t = 4, G_t = -1.1572, σ_t^2 = 112.1359
# Epoch 146, Iteration 20: H_t = 5, G_t = 0.6007, σ_t^2 = 112.5967
# Epoch 146, Iteration 21: H_t = 4, G_t = -0.1714, σ_t^2 = 96.8939
# Epoch 146, Iteration 22: H_t = 4, G_t = -2.0332, σ_t^2 = 96.8880
# Epoch 146, Iteration 23: H_t = 4, G_t = -1.6249, σ_t^2 = 106.6663
# Epoch 146, Iteration 24: H_t = 4, G_t = -0.5263, σ_t^2 = 104.5783
#     Worker 0: Train Loss: 1.2094, Train Accuracy: 65.03%
#     Worker 1: Train Loss: 1.2219, Train Accuracy: 65.54%
#     Worker 2: Train Loss: 1.2223, Train Accuracy: 65.71%
#     Worker 3: Train Loss: 1.2313, Train Accuracy: 65.09%
# Epoch 146: Test Loss: 1.9258, Test Accuracy: 51.72%
# Total Computation Time: 3670.16 seconds
# Total Communication Time: 2.60 seconds
# Epoch 147, Iteration 1: H_t = 4, G_t = 0.2646, σ_t^2 = 90.7942
# Epoch 147, Iteration 2: H_t = 4, G_t = -2.6447, σ_t^2 = 102.2835
# Epoch 147, Iteration 3: H_t = 4, G_t = -2.3821, σ_t^2 = 94.9662
# Epoch 147, Iteration 4: H_t = 4, G_t = -0.7363, σ_t^2 = 91.6871
# Epoch 147, Iteration 5: H_t = 7, G_t = 0.6977, σ_t^2 = 97.6754
# Epoch 147, Iteration 6: H_t = 31, G_t = 2.6485, σ_t^2 = 85.0320
# Epoch 147, Iteration 7: H_t = 4, G_t = -1.6775, σ_t^2 = 94.4498
# Epoch 147, Iteration 8: H_t = 4, G_t = -0.0167, σ_t^2 = 98.5989
# Epoch 147, Iteration 9: H_t = 24, G_t = 2.3670, σ_t^2 = 96.7485
# Epoch 147, Iteration 10: H_t = 8, G_t = 0.9605, σ_t^2 = 113.4095
# Epoch 147, Iteration 11: H_t = 4, G_t = -0.9292, σ_t^2 = 104.5758
# Epoch 147, Iteration 12: H_t = 4, G_t = -0.9667, σ_t^2 = 106.5416
# Epoch 147, Iteration 13: H_t = 4, G_t = 0.1723, σ_t^2 = 91.7875
# Epoch 147, Iteration 14: H_t = 4, G_t = -1.4290, σ_t^2 = 94.3776
# Epoch 147, Iteration 15: H_t = 16, G_t = 1.8124, σ_t^2 = 109.4574
# Epoch 147, Iteration 16: H_t = 49, G_t = 4.5588, σ_t^2 = 92.4892
# Epoch 147, Iteration 17: H_t = 4, G_t = -2.0699, σ_t^2 = 113.6122
# Epoch 147, Iteration 18: H_t = 4, G_t = 0.5308, σ_t^2 = 107.8839
# Epoch 147, Iteration 19: H_t = 4, G_t = -0.6578, σ_t^2 = 102.2897
# Epoch 147, Iteration 20: H_t = 4, G_t = 0.0325, σ_t^2 = 94.3789
# Epoch 147, Iteration 21: H_t = 4, G_t = -2.9724, σ_t^2 = 99.2213
# Epoch 147, Iteration 22: H_t = 4, G_t = 0.3154, σ_t^2 = 96.2569
#     Worker 0: Train Loss: 1.2188, Train Accuracy: 65.37%
#     Worker 1: Train Loss: 1.1982, Train Accuracy: 66.21%
#     Worker 2: Train Loss: 1.2006, Train Accuracy: 65.49%
#     Worker 3: Train Loss: 1.2208, Train Accuracy: 65.32%
# Epoch 147: Test Loss: 1.9258, Test Accuracy: 51.75%
# Total Computation Time: 3693.24 seconds
# Total Communication Time: 2.62 seconds
# Epoch 148, Iteration 1: H_t = 17, G_t = 1.7347, σ_t^2 = 101.5782
# Epoch 148, Iteration 2: H_t = 4, G_t = -2.5856, σ_t^2 = 95.9155
# Epoch 148, Iteration 3: H_t = 4, G_t = -3.4934, σ_t^2 = 100.5059
# Epoch 148, Iteration 4: H_t = 4, G_t = -1.5307, σ_t^2 = 107.8578
# Epoch 148, Iteration 5: H_t = 4, G_t = 0.1709, σ_t^2 = 82.1305
# Epoch 148, Iteration 6: H_t = 4, G_t = -0.1386, σ_t^2 = 91.7631
# Epoch 148, Iteration 7: H_t = 4, G_t = -1.5451, σ_t^2 = 91.7774
# Epoch 148, Iteration 8: H_t = 34, G_t = 4.3186, σ_t^2 = 126.4919
# Epoch 148, Iteration 9: H_t = 7, G_t = 0.7526, σ_t^2 = 97.0708
# Epoch 148, Iteration 10: H_t = 7, G_t = 0.6319, σ_t^2 = 88.1074
# Epoch 148, Iteration 11: H_t = 4, G_t = -1.3082, σ_t^2 = 94.0122
# Epoch 148, Iteration 12: H_t = 14, G_t = 1.4268, σ_t^2 = 99.7983
# Epoch 148, Iteration 13: H_t = 4, G_t = -1.6291, σ_t^2 = 99.7944
# Epoch 148, Iteration 14: H_t = 4, G_t = -2.8686, σ_t^2 = 109.0623
# Epoch 148, Iteration 15: H_t = 4, G_t = -1.1452, σ_t^2 = 97.1961
# Epoch 148, Iteration 16: H_t = 4, G_t = 0.2254, σ_t^2 = 98.9502
# Epoch 148, Iteration 17: H_t = 4, G_t = -0.9656, σ_t^2 = 102.2134
# Epoch 148, Iteration 18: H_t = 17, G_t = 1.7964, σ_t^2 = 101.3952
# Epoch 148, Iteration 19: H_t = 27, G_t = 2.3708, σ_t^2 = 85.9618
# Epoch 148, Iteration 20: H_t = 4, G_t = -0.0351, σ_t^2 = 96.9255
# Epoch 148, Iteration 21: H_t = 17, G_t = 1.5516, σ_t^2 = 89.4035
# Epoch 148, Iteration 22: H_t = 31, G_t = 2.6503, σ_t^2 = 82.9928
#     Worker 0: Train Loss: 1.2222, Train Accuracy: 65.34%
#     Worker 1: Train Loss: 1.2185, Train Accuracy: 65.63%
#     Worker 2: Train Loss: 1.1954, Train Accuracy: 66.19%
#     Worker 3: Train Loss: 1.2340, Train Accuracy: 65.36%
# Epoch 148: Test Loss: 1.9258, Test Accuracy: 51.78%
# Total Computation Time: 3716.04 seconds
# Total Communication Time: 2.65 seconds
# Epoch 149, Iteration 1: H_t = 28, G_t = 3.1850, σ_t^2 = 112.9899
# Epoch 149, Iteration 2: H_t = 9, G_t = 0.8142, σ_t^2 = 89.5977
# Epoch 149, Iteration 3: H_t = 4, G_t = -0.0443, σ_t^2 = 87.4137
# Epoch 149, Iteration 4: H_t = 24, G_t = 2.2312, σ_t^2 = 92.5115
# Epoch 149, Iteration 5: H_t = 4, G_t = -0.3482, σ_t^2 = 95.3966
# Epoch 149, Iteration 6: H_t = 33, G_t = 3.5608, σ_t^2 = 105.4696
# Epoch 149, Iteration 7: H_t = 4, G_t = -1.6245, σ_t^2 = 102.4602
# Epoch 149, Iteration 8: H_t = 4, G_t = -0.4908, σ_t^2 = 101.1926
# Epoch 149, Iteration 9: H_t = 4, G_t = 0.1935, σ_t^2 = 107.4364
# Epoch 149, Iteration 10: H_t = 4, G_t = 0.1771, σ_t^2 = 98.3960
# Epoch 149, Iteration 11: H_t = 28, G_t = 2.7653, σ_t^2 = 98.3905
# Epoch 149, Iteration 12: H_t = 4, G_t = -2.0809, σ_t^2 = 100.4047
# Epoch 149, Iteration 13: H_t = 19, G_t = 2.0642, σ_t^2 = 103.9506
# Epoch 149, Iteration 14: H_t = 4, G_t = 0.1426, σ_t^2 = 94.7157
#     Worker 0: Train Loss: 1.2234, Train Accuracy: 64.98%
#     Worker 1: Train Loss: 1.2197, Train Accuracy: 65.66%
#     Worker 2: Train Loss: 1.2163, Train Accuracy: 66.20%
#     Worker 3: Train Loss: 1.2117, Train Accuracy: 65.47%
# Epoch 149: Test Loss: 1.9258, Test Accuracy: 51.76%
# Total Computation Time: 3739.16 seconds
# Total Communication Time: 2.67 seconds
# Epoch 150, Iteration 1: H_t = 4, G_t = 0.1543, σ_t^2 = 97.0824
# Epoch 150, Iteration 2: H_t = 4, G_t = 0.3509, σ_t^2 = 98.9600
# Epoch 150, Iteration 3: H_t = 15, G_t = 1.4749, σ_t^2 = 92.8365
# Epoch 150, Iteration 4: H_t = 33, G_t = 3.1359, σ_t^2 = 94.4755
# Epoch 150, Iteration 5: H_t = 22, G_t = 2.1877, σ_t^2 = 97.3547
# Epoch 150, Iteration 6: H_t = 4, G_t = 0.4028, σ_t^2 = 101.3589
# Epoch 150, Iteration 7: H_t = 4, G_t = 0.3309, σ_t^2 = 100.9474
# Epoch 150, Iteration 8: H_t = 4, G_t = -0.6740, σ_t^2 = 109.5432
# Epoch 150, Iteration 9: H_t = 4, G_t = -1.2001, σ_t^2 = 92.9100
# Epoch 150, Iteration 10: H_t = 4, G_t = -0.9930, σ_t^2 = 108.9878
# Epoch 150, Iteration 11: H_t = 4, G_t = 0.3317, σ_t^2 = 101.7061
# Epoch 150, Iteration 12: H_t = 10, G_t = 0.8958, σ_t^2 = 88.0427
# Epoch 150, Iteration 13: H_t = 4, G_t = -1.7652, σ_t^2 = 95.3727
# Epoch 150, Iteration 14: H_t = 4, G_t = -4.5253, σ_t^2 = 97.3319
# Epoch 150, Iteration 15: H_t = 4, G_t = -1.2843, σ_t^2 = 102.4311
# Epoch 150, Iteration 16: H_t = 4, G_t = -0.4681, σ_t^2 = 86.2799
# Epoch 150, Iteration 17: H_t = 4, G_t = -2.0018, σ_t^2 = 101.6921
# Epoch 150, Iteration 18: H_t = 4, G_t = -2.4785, σ_t^2 = 102.2390
# Epoch 150, Iteration 19: H_t = 15, G_t = 1.4460, σ_t^2 = 92.3119
# Epoch 150, Iteration 20: H_t = 4, G_t = -1.5916, σ_t^2 = 89.0766
# Epoch 150, Iteration 21: H_t = 4, G_t = -0.1027, σ_t^2 = 93.0018
# Epoch 150, Iteration 22: H_t = 4, G_t = -0.7123, σ_t^2 = 108.3939
# Epoch 150, Iteration 23: H_t = 4, G_t = -3.1045, σ_t^2 = 103.5196
# Epoch 150, Iteration 24: H_t = 42, G_t = 4.4881, σ_t^2 = 105.3165
# Epoch 150, Iteration 25: H_t = 4, G_t = -1.4220, σ_t^2 = 98.6465
#     Worker 0: Train Loss: 1.2166, Train Accuracy: 65.20%
#     Worker 1: Train Loss: 1.2152, Train Accuracy: 65.64%
#     Worker 2: Train Loss: 1.2069, Train Accuracy: 65.83%
#     Worker 3: Train Loss: 1.2203, Train Accuracy: 65.48%
# Epoch 150: Test Loss: 1.9258, Test Accuracy: 51.76%
# Total Computation Time: 3764.15 seconds
# Total Communication Time: 2.70 seconds
