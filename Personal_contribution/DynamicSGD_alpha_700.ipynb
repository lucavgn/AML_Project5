# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files
import torch.nn.functional as F
import time

total_computation_time = 0
total_communication_time = 0

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
iteration_per_epoch = 782 # number of local step performed in one epoch
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
#warmup_epochs = 5

def compute_mean_std(dataset):
    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

#global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
#global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
#print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Compute gradient magnitude and variance
def compute_gradient_stats(nets, optimizers):
    # Get gradients from each worker
    gradients = []
    for net, optimizer in zip(nets, optimizers):
        grad_vector = []
        for param in net.parameters():
            if param.grad is not None:
                grad_vector.append(param.grad.view(-1))
        grad_vector = torch.cat(grad_vector)  # Flatten all gradients into a vector
        gradients.append(grad_vector)

    # Compute average gradient (g_t)
    avg_gradient = torch.stack(gradients).mean(dim=0)

    # Compute squared norms of individual gradients
    squared_norms = [torch.norm(g).item() ** 2 for g in gradients]

    # Compute squared norm of the average gradient
    avg_squared_norm = torch.norm(avg_gradient).item() ** 2

    # Compute gradient variance (sigma_t^2) using the provided formula
    sigma_t_squared = (sum(squared_norms) / (K - 1)) - (K / (K - 1)) * avg_squared_norm

    # Compute gradient magnitude (G_t) using the provided formula
    G_t = avg_squared_norm - (1 / K) * sigma_t_squared

    return G_t, sigma_t_squared


# Update H dynamically based on gradient stats
def update_H(G_t, sigma_t_squared, H_min, H_max, alpha, epsilon):
    H_t = min(H_max, max(H_min, alpha * G_t / (sigma_t_squared + epsilon)))
    #H_t = min(H_t, H_max)  # Ensure H_t doesn't exceed H_max
    return int(H_t)  # Ensure H_t is an integer

# Training loop
# Hyperparameters for dynamic adjustment
H_min, H_max = 4, 64  # Minimum and maximum allowed local steps
alpha, epsilon = 700, 1e-6  # Scaling factor and small constant

H_t = J  # Initialize H_t with the default J value


for epoch in range(num_epochs):
    #print(f"Epoch {epoch + 1}/{num_epochs}:")
    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]

    iteration_per_epoch = 782
    iteration = 0 # Number of global iteration performed
    while iteration_per_epoch > 0:
        computation_start_time = time.time()
        # Train each worker for H_t steps
        for k in range(K):
            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            for _ in range(H_t):  # Perform H_t local steps
                try:
                    images, labels = next(shard_iterators[k])
                except StopIteration:
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k])
                images, labels = images.to(device), labels.to(device)

                optimizers[k].zero_grad()
                outputs = nets[k](images)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizers[k].step()

                # Calculate train loss and accuracy
                train_loss += loss.item() * labels.size(0)
                _, predicted = outputs.max(1)
                total_train += labels.size(0)
                correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        computation_end_time = time.time()
        total_computation_time += (computation_end_time - computation_start_time)

        communication_start_time = time.time()
        # Synchronize models
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

        communication_end_time = time.time()
        total_communication_time += (communication_end_time - communication_start_time)

        # update tot_num_local_step and number of global iteration
        iteration_per_epoch -= (H_t * K)
        iteration += 1
        # Compute gradient stats and update H_t
        G_t, sigma_t_squared = compute_gradient_stats(nets, optimizers)
        H_t = update_H(G_t, sigma_t_squared, H_min, H_max, alpha, epsilon)
        print(f"Epoch {epoch+1}, Iteration {iteration}: H_t = {H_t}, G_t = {G_t:.4f}, σ_t^2 = {sigma_t_squared:.4f}")

    # Store training metrics for all workers after each epoch
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

    # Update learning rate
    for scheduler in schedulers:
        scheduler.step()

    # Evaluate on test set
    global_model = nets[0]
    global_model.eval()
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()

    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)
    print(f"Epoch {epoch + 1}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")

    print(f"Total Computation Time: {total_computation_time:.2f} seconds")
    print(f"Total Communication Time: {total_communication_time:.2f} seconds")



# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 4 --j 32
# Out:
# Training with K=4, J=32
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:14<00:00, 12.1MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00400
# Epoch 1, Iteration 1: H_t = 37, G_t = 0.0068, σ_t^2 = 0.1266
# Epoch 1, Iteration 2: H_t = 24, G_t = 0.0042, σ_t^2 = 0.1219
# Epoch 1, Iteration 3: H_t = 4, G_t = -0.0023, σ_t^2 = 0.1391
# Epoch 1, Iteration 4: H_t = 4, G_t = -0.0045, σ_t^2 = 0.1416
# Epoch 1, Iteration 5: H_t = 64, G_t = 0.0146, σ_t^2 = 0.1349
# Epoch 1, Iteration 6: H_t = 22, G_t = 0.0080, σ_t^2 = 0.2549
# Epoch 1, Iteration 7: H_t = 4, G_t = -0.0059, σ_t^2 = 0.3217
# Epoch 1, Iteration 8: H_t = 4, G_t = -0.0100, σ_t^2 = 0.3984
# Epoch 1, Iteration 9: H_t = 4, G_t = 0.0018, σ_t^2 = 0.3638
# Epoch 1, Iteration 10: H_t = 16, G_t = 0.0087, σ_t^2 = 0.3778
#     Worker 0: Train Loss: 4.5993, Train Accuracy: 1.36%
#     Worker 1: Train Loss: 4.6000, Train Accuracy: 1.39%
#     Worker 2: Train Loss: 4.5986, Train Accuracy: 1.47%
#     Worker 3: Train Loss: 4.5993, Train Accuracy: 1.41%
# Epoch 1: Test Loss: 4.5822, Test Accuracy: 2.74%
# Total Computation Time: 25.97 seconds
# Total Communication Time: 0.04 seconds
# Epoch 2, Iteration 1: H_t = 17, G_t = 0.0123, σ_t^2 = 0.4886
# Epoch 2, Iteration 2: H_t = 15, G_t = 0.0142, σ_t^2 = 0.6533
# Epoch 2, Iteration 3: H_t = 20, G_t = 0.0234, σ_t^2 = 0.8115
# Epoch 2, Iteration 4: H_t = 35, G_t = 0.0596, σ_t^2 = 1.1648
# Epoch 2, Iteration 5: H_t = 4, G_t = 0.0012, σ_t^2 = 2.4057
# Epoch 2, Iteration 6: H_t = 63, G_t = 0.2211, σ_t^2 = 2.4353
# Epoch 2, Iteration 7: H_t = 4, G_t = -0.2989, σ_t^2 = 7.6997
# Epoch 2, Iteration 8: H_t = 4, G_t = -0.1700, σ_t^2 = 8.0719
# Epoch 2, Iteration 9: H_t = 36, G_t = 0.3610, σ_t^2 = 6.9910
# Epoch 2, Iteration 10: H_t = 28, G_t = 0.3050, σ_t^2 = 7.5524
#     Worker 0: Train Loss: 4.4598, Train Accuracy: 3.28%
#     Worker 1: Train Loss: 4.4686, Train Accuracy: 3.32%
#     Worker 2: Train Loss: 4.4469, Train Accuracy: 3.71%
#     Worker 3: Train Loss: 4.4613, Train Accuracy: 3.26%
# Epoch 2: Test Loss: 4.2063, Test Accuracy: 6.45%
# Total Computation Time: 51.80 seconds
# Total Communication Time: 0.05 seconds
# Epoch 3, Iteration 1: H_t = 31, G_t = 0.4359, σ_t^2 = 9.7051
# Epoch 3, Iteration 2: H_t = 4, G_t = -0.3714, σ_t^2 = 10.1771
# Epoch 3, Iteration 3: H_t = 19, G_t = 0.2320, σ_t^2 = 8.2864
# Epoch 3, Iteration 4: H_t = 33, G_t = 0.4597, σ_t^2 = 9.5629
# Epoch 3, Iteration 5: H_t = 4, G_t = -0.1694, σ_t^2 = 10.7020
# Epoch 3, Iteration 6: H_t = 44, G_t = 0.6515, σ_t^2 = 10.2731
# Epoch 3, Iteration 7: H_t = 16, G_t = 0.2301, σ_t^2 = 10.0668
# Epoch 3, Iteration 8: H_t = 59, G_t = 0.8008, σ_t^2 = 9.4402
# Epoch 3, Iteration 9: H_t = 9, G_t = 0.1343, σ_t^2 = 9.8094
#     Worker 0: Train Loss: 4.1309, Train Accuracy: 6.37%
#     Worker 1: Train Loss: 4.1314, Train Accuracy: 6.87%
#     Worker 2: Train Loss: 4.1151, Train Accuracy: 6.65%
#     Worker 3: Train Loss: 4.1415, Train Accuracy: 6.72%
# Epoch 3: Test Loss: 3.9565, Test Accuracy: 9.56%
# Total Computation Time: 80.50 seconds
# Total Communication Time: 0.06 seconds
# Epoch 4, Iteration 1: H_t = 32, G_t = 0.4413, σ_t^2 = 9.5717
# Epoch 4, Iteration 2: H_t = 19, G_t = 0.3440, σ_t^2 = 12.4266
# Epoch 4, Iteration 3: H_t = 9, G_t = 0.1995, σ_t^2 = 15.2603
# Epoch 4, Iteration 4: H_t = 4, G_t = -0.0559, σ_t^2 = 11.5386
# Epoch 4, Iteration 5: H_t = 27, G_t = 0.4728, σ_t^2 = 11.8869
# Epoch 4, Iteration 6: H_t = 4, G_t = -0.1347, σ_t^2 = 11.4952
# Epoch 4, Iteration 7: H_t = 27, G_t = 0.3999, σ_t^2 = 10.3597
# Epoch 4, Iteration 8: H_t = 4, G_t = -1.0041, σ_t^2 = 15.2856
# Epoch 4, Iteration 9: H_t = 4, G_t = -0.1213, σ_t^2 = 11.9699
# Epoch 4, Iteration 10: H_t = 44, G_t = 0.7733, σ_t^2 = 12.2436
# Epoch 4, Iteration 11: H_t = 4, G_t = -0.2624, σ_t^2 = 14.5970
# Epoch 4, Iteration 12: H_t = 4, G_t = -0.1282, σ_t^2 = 12.1673
# Epoch 4, Iteration 13: H_t = 4, G_t = -0.1357, σ_t^2 = 12.6747
# Epoch 4, Iteration 14: H_t = 4, G_t = 0.0012, σ_t^2 = 13.0025
# Epoch 4, Iteration 15: H_t = 4, G_t = -0.0735, σ_t^2 = 13.9407
#     Worker 0: Train Loss: 3.9674, Train Accuracy: 8.93%
#     Worker 1: Train Loss: 3.9685, Train Accuracy: 9.16%
#     Worker 2: Train Loss: 3.9264, Train Accuracy: 9.60%
#     Worker 3: Train Loss: 3.9575, Train Accuracy: 9.03%
# Epoch 4: Test Loss: 3.8009, Test Accuracy: 12.51%
# Total Computation Time: 104.63 seconds
# Total Communication Time: 0.08 seconds
# Epoch 5, Iteration 1: H_t = 4, G_t = -0.9337, σ_t^2 = 16.1770
# Epoch 5, Iteration 2: H_t = 4, G_t = 0.0778, σ_t^2 = 15.5473
# Epoch 5, Iteration 3: H_t = 34, G_t = 0.8660, σ_t^2 = 17.4075
# Epoch 5, Iteration 4: H_t = 4, G_t = -0.4055, σ_t^2 = 13.9256
# Epoch 5, Iteration 5: H_t = 64, G_t = 1.3647, σ_t^2 = 12.2709
# Epoch 5, Iteration 6: H_t = 25, G_t = 0.4611, σ_t^2 = 12.6947
# Epoch 5, Iteration 7: H_t = 4, G_t = 0.0663, σ_t^2 = 16.3982
# Epoch 5, Iteration 8: H_t = 34, G_t = 0.6167, σ_t^2 = 12.5782
# Epoch 5, Iteration 9: H_t = 4, G_t = -0.2198, σ_t^2 = 13.2188
# Epoch 5, Iteration 10: H_t = 4, G_t = -0.1985, σ_t^2 = 15.1380
# Epoch 5, Iteration 11: H_t = 64, G_t = 1.5329, σ_t^2 = 12.9781
# Epoch 5, Iteration 12: H_t = 4, G_t = -0.8357, σ_t^2 = 14.9505
#     Worker 0: Train Loss: 3.8514, Train Accuracy: 10.57%
#     Worker 1: Train Loss: 3.8502, Train Accuracy: 10.56%
#     Worker 2: Train Loss: 3.8145, Train Accuracy: 11.58%
#     Worker 3: Train Loss: 3.8476, Train Accuracy: 10.73%
# Epoch 5: Test Loss: 3.6762, Test Accuracy: 14.53%
# Total Computation Time: 134.77 seconds
# Total Communication Time: 0.10 seconds
# Epoch 6, Iteration 1: H_t = 4, G_t = 0.0398, σ_t^2 = 12.4273
# Epoch 6, Iteration 2: H_t = 4, G_t = -0.3629, σ_t^2 = 13.8880
# Epoch 6, Iteration 3: H_t = 64, G_t = 1.7258, σ_t^2 = 15.5240
# Epoch 6, Iteration 4: H_t = 4, G_t = -0.1397, σ_t^2 = 15.8209
# Epoch 6, Iteration 5: H_t = 4, G_t = -0.0815, σ_t^2 = 13.7113
# Epoch 6, Iteration 6: H_t = 7, G_t = 0.1431, σ_t^2 = 12.9958
# Epoch 6, Iteration 7: H_t = 5, G_t = 0.1400, σ_t^2 = 17.9487
# Epoch 6, Iteration 8: H_t = 10, G_t = 0.2593, σ_t^2 = 18.0859
# Epoch 6, Iteration 9: H_t = 24, G_t = 0.6870, σ_t^2 = 19.4284
# Epoch 6, Iteration 10: H_t = 4, G_t = -0.2420, σ_t^2 = 18.9744
# Epoch 6, Iteration 11: H_t = 64, G_t = 1.6053, σ_t^2 = 13.9640
# Epoch 6, Iteration 12: H_t = 4, G_t = -0.3771, σ_t^2 = 15.2454
#     Worker 0: Train Loss: 3.7351, Train Accuracy: 12.39%
#     Worker 1: Train Loss: 3.7348, Train Accuracy: 12.88%
#     Worker 2: Train Loss: 3.6787, Train Accuracy: 13.56%
#     Worker 3: Train Loss: 3.7394, Train Accuracy: 12.67%
# Epoch 6: Test Loss: 3.5673, Test Accuracy: 16.21%
# Total Computation Time: 159.08 seconds
# Total Communication Time: 0.11 seconds
# Epoch 7, Iteration 1: H_t = 21, G_t = 0.4582, σ_t^2 = 14.9377
# Epoch 7, Iteration 2: H_t = 64, G_t = 2.1690, σ_t^2 = 17.0632
# Epoch 7, Iteration 3: H_t = 4, G_t = -0.7893, σ_t^2 = 16.6541
# Epoch 7, Iteration 4: H_t = 4, G_t = -0.9532, σ_t^2 = 17.9414
# Epoch 7, Iteration 5: H_t = 47, G_t = 0.9712, σ_t^2 = 14.3984
# Epoch 7, Iteration 6: H_t = 4, G_t = -0.7274, σ_t^2 = 18.9416
# Epoch 7, Iteration 7: H_t = 4, G_t = 0.0161, σ_t^2 = 15.4255
# Epoch 7, Iteration 8: H_t = 21, G_t = 0.5331, σ_t^2 = 17.3567
# Epoch 7, Iteration 9: H_t = 54, G_t = 1.5480, σ_t^2 = 19.7558
# Epoch 7, Iteration 10: H_t = 20, G_t = 0.4010, σ_t^2 = 13.4203
#     Worker 0: Train Loss: 3.6483, Train Accuracy: 13.88%
#     Worker 1: Train Loss: 3.6519, Train Accuracy: 14.07%
#     Worker 2: Train Loss: 3.6000, Train Accuracy: 14.82%
#     Worker 3: Train Loss: 3.6576, Train Accuracy: 13.89%
# Epoch 7: Test Loss: 3.4824, Test Accuracy: 17.86%
# Total Computation Time: 186.38 seconds
# Total Communication Time: 0.12 seconds
# Epoch 8, Iteration 1: H_t = 4, G_t = -0.5665, σ_t^2 = 21.2133
# Epoch 8, Iteration 2: H_t = 18, G_t = 0.4905, σ_t^2 = 18.2588
# Epoch 8, Iteration 3: H_t = 4, G_t = -0.4638, σ_t^2 = 22.6454
# Epoch 8, Iteration 4: H_t = 4, G_t = -1.2320, σ_t^2 = 19.4769
# Epoch 8, Iteration 5: H_t = 4, G_t = 0.0288, σ_t^2 = 15.8981
# Epoch 8, Iteration 6: H_t = 38, G_t = 0.8972, σ_t^2 = 16.4081
# Epoch 8, Iteration 7: H_t = 4, G_t = -0.2850, σ_t^2 = 20.6284
# Epoch 8, Iteration 8: H_t = 37, G_t = 0.8728, σ_t^2 = 16.2791
# Epoch 8, Iteration 9: H_t = 4, G_t = -0.2952, σ_t^2 = 20.2432
# Epoch 8, Iteration 10: H_t = 64, G_t = 1.8465, σ_t^2 = 18.3426
# Epoch 8, Iteration 11: H_t = 4, G_t = -1.5005, σ_t^2 = 22.4399
#     Worker 0: Train Loss: 3.5617, Train Accuracy: 15.27%
#     Worker 1: Train Loss: 3.5629, Train Accuracy: 16.05%
#     Worker 2: Train Loss: 3.5111, Train Accuracy: 16.54%
#     Worker 3: Train Loss: 3.5636, Train Accuracy: 15.59%
# Epoch 8: Test Loss: 3.4016, Test Accuracy: 19.71%
# Total Computation Time: 210.65 seconds
# Total Communication Time: 0.14 seconds
# Epoch 9, Iteration 1: H_t = 4, G_t = -0.5328, σ_t^2 = 20.5301
# Epoch 9, Iteration 2: H_t = 4, G_t = 0.0214, σ_t^2 = 17.4550
# Epoch 9, Iteration 3: H_t = 49, G_t = 1.3466, σ_t^2 = 18.9188
# Epoch 9, Iteration 4: H_t = 4, G_t = -0.0018, σ_t^2 = 21.1979
# Epoch 9, Iteration 5: H_t = 4, G_t = -0.9549, σ_t^2 = 20.8972
# Epoch 9, Iteration 6: H_t = 64, G_t = 3.7568, σ_t^2 = 18.1107
# Epoch 9, Iteration 7: H_t = 4, G_t = -0.4562, σ_t^2 = 21.2045
# Epoch 9, Iteration 8: H_t = 4, G_t = -0.3845, σ_t^2 = 23.6120
# Epoch 9, Iteration 9: H_t = 16, G_t = 0.3849, σ_t^2 = 16.2108
# Epoch 9, Iteration 10: H_t = 4, G_t = -1.6049, σ_t^2 = 25.7078
# Epoch 9, Iteration 11: H_t = 4, G_t = -0.2291, σ_t^2 = 18.1791
# Epoch 9, Iteration 12: H_t = 4, G_t = 0.1198, σ_t^2 = 18.5192
# Epoch 9, Iteration 13: H_t = 46, G_t = 1.1670, σ_t^2 = 17.6289
# Epoch 9, Iteration 14: H_t = 4, G_t = -1.2186, σ_t^2 = 26.8640
#     Worker 0: Train Loss: 3.4751, Train Accuracy: 16.86%
#     Worker 1: Train Loss: 3.4776, Train Accuracy: 16.98%
#     Worker 2: Train Loss: 3.4153, Train Accuracy: 17.91%
#     Worker 3: Train Loss: 3.4752, Train Accuracy: 17.18%
# Epoch 9: Test Loss: 3.2975, Test Accuracy: 20.94%
# Total Computation Time: 236.72 seconds
# Total Communication Time: 0.15 seconds
# Epoch 10, Iteration 1: H_t = 4, G_t = -1.1627, σ_t^2 = 23.0508
# Epoch 10, Iteration 2: H_t = 4, G_t = -0.0063, σ_t^2 = 20.6862
# Epoch 10, Iteration 3: H_t = 12, G_t = 0.3851, σ_t^2 = 21.5728
# Epoch 10, Iteration 4: H_t = 28, G_t = 0.9721, σ_t^2 = 23.9805
# Epoch 10, Iteration 5: H_t = 4, G_t = -0.6960, σ_t^2 = 23.4835
# Epoch 10, Iteration 6: H_t = 4, G_t = -1.5012, σ_t^2 = 23.2248
# Epoch 10, Iteration 7: H_t = 23, G_t = 0.7220, σ_t^2 = 21.1676
# Epoch 10, Iteration 8: H_t = 34, G_t = 1.0154, σ_t^2 = 20.5899
# Epoch 10, Iteration 9: H_t = 4, G_t = -1.4289, σ_t^2 = 22.4818
# Epoch 10, Iteration 10: H_t = 4, G_t = -0.4045, σ_t^2 = 22.6101
# Epoch 10, Iteration 11: H_t = 52, G_t = 1.6112, σ_t^2 = 21.4099
# Epoch 10, Iteration 12: H_t = 38, G_t = 1.1850, σ_t^2 = 21.2803
# Epoch 10, Iteration 13: H_t = 4, G_t = -1.5614, σ_t^2 = 24.3248
#     Worker 0: Train Loss: 3.3812, Train Accuracy: 18.37%
#     Worker 1: Train Loss: 3.3905, Train Accuracy: 18.49%
#     Worker 2: Train Loss: 3.3462, Train Accuracy: 19.23%
#     Worker 3: Train Loss: 3.3980, Train Accuracy: 18.39%
# Epoch 10: Test Loss: 3.2222, Test Accuracy: 22.87%
# Total Computation Time: 262.74 seconds
# Total Communication Time: 0.17 seconds
# Epoch 11, Iteration 1: H_t = 24, G_t = 0.7007, σ_t^2 = 19.9846
# Epoch 11, Iteration 2: H_t = 4, G_t = -0.8682, σ_t^2 = 23.4879
# Epoch 11, Iteration 3: H_t = 4, G_t = -0.1720, σ_t^2 = 27.3156
# Epoch 11, Iteration 4: H_t = 4, G_t = -0.2574, σ_t^2 = 23.4376
# Epoch 11, Iteration 5: H_t = 19, G_t = 0.6879, σ_t^2 = 25.0434
# Epoch 11, Iteration 6: H_t = 4, G_t = -0.8870, σ_t^2 = 26.6084
# Epoch 11, Iteration 7: H_t = 4, G_t = -1.8571, σ_t^2 = 27.8541
# Epoch 11, Iteration 8: H_t = 64, G_t = 5.1906, σ_t^2 = 21.4476
# Epoch 11, Iteration 9: H_t = 4, G_t = -0.2955, σ_t^2 = 24.5925
# Epoch 11, Iteration 10: H_t = 4, G_t = -0.9390, σ_t^2 = 23.8803
# Epoch 11, Iteration 11: H_t = 4, G_t = -0.6321, σ_t^2 = 24.0872
# Epoch 11, Iteration 12: H_t = 64, G_t = 2.3968, σ_t^2 = 21.8308
# Epoch 11, Iteration 13: H_t = 7, G_t = 0.2600, σ_t^2 = 25.1253
#     Worker 0: Train Loss: 3.3156, Train Accuracy: 18.88%
#     Worker 1: Train Loss: 3.3231, Train Accuracy: 19.41%
#     Worker 2: Train Loss: 3.2729, Train Accuracy: 20.57%
#     Worker 3: Train Loss: 3.3211, Train Accuracy: 19.47%
# Epoch 11: Test Loss: 3.1524, Test Accuracy: 23.86%
# Total Computation Time: 287.48 seconds
# Total Communication Time: 0.19 seconds
# Epoch 12, Iteration 1: H_t = 4, G_t = -2.2441, σ_t^2 = 29.3097
# Epoch 12, Iteration 2: H_t = 4, G_t = 0.0021, σ_t^2 = 27.6486
# Epoch 12, Iteration 3: H_t = 58, G_t = 2.2964, σ_t^2 = 27.5214
# Epoch 12, Iteration 4: H_t = 4, G_t = -0.3971, σ_t^2 = 27.7398
# Epoch 12, Iteration 5: H_t = 4, G_t = -2.3001, σ_t^2 = 28.7413
# Epoch 12, Iteration 6: H_t = 4, G_t = -0.5863, σ_t^2 = 27.2724
# Epoch 12, Iteration 7: H_t = 6, G_t = 0.2043, σ_t^2 = 23.4550
# Epoch 12, Iteration 8: H_t = 24, G_t = 0.9529, σ_t^2 = 27.7587
# Epoch 12, Iteration 9: H_t = 64, G_t = 2.3774, σ_t^2 = 24.3566
# Epoch 12, Iteration 10: H_t = 4, G_t = -1.1614, σ_t^2 = 29.1664
# Epoch 12, Iteration 11: H_t = 4, G_t = -1.1645, σ_t^2 = 24.6366
# Epoch 12, Iteration 12: H_t = 63, G_t = 2.2262, σ_t^2 = 24.5939
# Epoch 12, Iteration 13: H_t = 4, G_t = -0.2543, σ_t^2 = 21.9891
#     Worker 0: Train Loss: 3.2495, Train Accuracy: 20.61%
#     Worker 1: Train Loss: 3.2721, Train Accuracy: 20.64%
#     Worker 2: Train Loss: 3.2055, Train Accuracy: 22.04%
#     Worker 3: Train Loss: 3.2480, Train Accuracy: 20.98%
# Epoch 12: Test Loss: 3.0726, Test Accuracy: 24.85%
# Total Computation Time: 317.68 seconds
# Total Communication Time: 0.20 seconds
# Epoch 13, Iteration 1: H_t = 4, G_t = 0.1475, σ_t^2 = 27.1454
# Epoch 13, Iteration 2: H_t = 64, G_t = 2.3020, σ_t^2 = 19.8841
# Epoch 13, Iteration 3: H_t = 17, G_t = 0.6688, σ_t^2 = 26.3156
# Epoch 13, Iteration 4: H_t = 4, G_t = -0.1286, σ_t^2 = 25.5609
# Epoch 13, Iteration 5: H_t = 64, G_t = 7.2045, σ_t^2 = 28.0228
# Epoch 13, Iteration 6: H_t = 51, G_t = 1.8682, σ_t^2 = 25.4475
# Epoch 13, Iteration 7: H_t = 24, G_t = 0.8825, σ_t^2 = 24.8958
#     Worker 0: Train Loss: 3.1633, Train Accuracy: 22.08%
#     Worker 1: Train Loss: 3.1922, Train Accuracy: 22.47%
#     Worker 2: Train Loss: 3.1628, Train Accuracy: 22.48%
#     Worker 3: Train Loss: 3.1854, Train Accuracy: 22.27%
# Epoch 13: Test Loss: 2.9881, Test Accuracy: 26.93%
# Total Computation Time: 342.71 seconds
# Total Communication Time: 0.21 seconds
# Epoch 14, Iteration 1: H_t = 4, G_t = -0.1367, σ_t^2 = 24.9077
# Epoch 14, Iteration 2: H_t = 18, G_t = 0.7030, σ_t^2 = 27.2692
# Epoch 14, Iteration 3: H_t = 4, G_t = -1.1378, σ_t^2 = 26.3292
# Epoch 14, Iteration 4: H_t = 4, G_t = -1.9633, σ_t^2 = 29.9737
# Epoch 14, Iteration 5: H_t = 39, G_t = 1.5898, σ_t^2 = 27.9444
# Epoch 14, Iteration 6: H_t = 4, G_t = -0.8340, σ_t^2 = 25.3432
# Epoch 14, Iteration 7: H_t = 4, G_t = -0.2764, σ_t^2 = 22.9356
# Epoch 14, Iteration 8: H_t = 19, G_t = 0.8176, σ_t^2 = 29.3044
# Epoch 14, Iteration 9: H_t = 4, G_t = 0.0554, σ_t^2 = 89.9585
# Epoch 14, Iteration 10: H_t = 4, G_t = -1.1565, σ_t^2 = 35.2620
# Epoch 14, Iteration 11: H_t = 4, G_t = -0.3467, σ_t^2 = 25.0308
# Epoch 14, Iteration 12: H_t = 4, G_t = -0.4295, σ_t^2 = 28.8367
# Epoch 14, Iteration 13: H_t = 4, G_t = -0.2028, σ_t^2 = 23.6722
# Epoch 14, Iteration 14: H_t = 4, G_t = -0.1091, σ_t^2 = 30.2072
# Epoch 14, Iteration 15: H_t = 47, G_t = 2.3623, σ_t^2 = 34.9300
# Epoch 14, Iteration 16: H_t = 19, G_t = 0.7704, σ_t^2 = 27.3678
# Epoch 14, Iteration 17: H_t = 4, G_t = -1.2670, σ_t^2 = 30.4785
#     Worker 0: Train Loss: 3.1095, Train Accuracy: 23.74%
#     Worker 1: Train Loss: 3.1280, Train Accuracy: 23.31%
#     Worker 2: Train Loss: 3.0542, Train Accuracy: 24.63%
#     Worker 3: Train Loss: 3.1381, Train Accuracy: 22.87%
# Epoch 14: Test Loss: 2.9251, Test Accuracy: 28.01%
# Total Computation Time: 368.09 seconds
# Total Communication Time: 0.23 seconds
# Epoch 15, Iteration 1: H_t = 4, G_t = -0.3950, σ_t^2 = 28.9750
# Epoch 15, Iteration 2: H_t = 6, G_t = 0.2220, σ_t^2 = 22.4755
# Epoch 15, Iteration 3: H_t = 15, G_t = 0.6024, σ_t^2 = 28.0294
# Epoch 15, Iteration 4: H_t = 4, G_t = -2.9525, σ_t^2 = 39.0696
# Epoch 15, Iteration 5: H_t = 4, G_t = 0.0052, σ_t^2 = 28.8423
# Epoch 15, Iteration 6: H_t = 4, G_t = -1.3746, σ_t^2 = 28.9451
# Epoch 15, Iteration 7: H_t = 4, G_t = -0.3465, σ_t^2 = 25.2796
# Epoch 15, Iteration 8: H_t = 19, G_t = 0.8214, σ_t^2 = 29.3799
# Epoch 15, Iteration 9: H_t = 64, G_t = 2.7623, σ_t^2 = 25.2852
# Epoch 15, Iteration 10: H_t = 4, G_t = -0.8360, σ_t^2 = 24.8072
# Epoch 15, Iteration 11: H_t = 16, G_t = 0.6282, σ_t^2 = 27.0641
# Epoch 15, Iteration 12: H_t = 4, G_t = -1.6755, σ_t^2 = 36.6282
# Epoch 15, Iteration 13: H_t = 17, G_t = 0.7259, σ_t^2 = 29.0203
# Epoch 15, Iteration 14: H_t = 52, G_t = 2.6195, σ_t^2 = 34.7124
# Epoch 15, Iteration 15: H_t = 4, G_t = -0.4893, σ_t^2 = 33.2378
#     Worker 0: Train Loss: 3.0506, Train Accuracy: 24.12%
#     Worker 1: Train Loss: 3.0793, Train Accuracy: 23.96%
#     Worker 2: Train Loss: 3.0258, Train Accuracy: 25.18%
#     Worker 3: Train Loss: 3.0459, Train Accuracy: 24.72%
# Epoch 15: Test Loss: 2.8916, Test Accuracy: 28.84%
# Total Computation Time: 394.63 seconds
# Total Communication Time: 0.25 seconds
# Epoch 16, Iteration 1: H_t = 4, G_t = -0.2301, σ_t^2 = 25.1388
# Epoch 16, Iteration 2: H_t = 9, G_t = 0.3299, σ_t^2 = 23.5556
# Epoch 16, Iteration 3: H_t = 4, G_t = -0.5972, σ_t^2 = 30.1206
# Epoch 16, Iteration 4: H_t = 4, G_t = -0.5146, σ_t^2 = 32.0370
# Epoch 16, Iteration 5: H_t = 12, G_t = 0.5570, σ_t^2 = 31.6104
# Epoch 16, Iteration 6: H_t = 4, G_t = -0.6032, σ_t^2 = 36.9559
# Epoch 16, Iteration 7: H_t = 4, G_t = -0.3806, σ_t^2 = 28.6629
# Epoch 16, Iteration 8: H_t = 4, G_t = -0.0854, σ_t^2 = 31.2477
# Epoch 16, Iteration 9: H_t = 4, G_t = -0.4116, σ_t^2 = 35.9608
# Epoch 16, Iteration 10: H_t = 4, G_t = -1.2997, σ_t^2 = 33.4814
# Epoch 16, Iteration 11: H_t = 4, G_t = -1.4919, σ_t^2 = 34.1717
# Epoch 16, Iteration 12: H_t = 47, G_t = 1.9871, σ_t^2 = 29.3746
# Epoch 16, Iteration 13: H_t = 17, G_t = 0.6784, σ_t^2 = 27.6397
# Epoch 16, Iteration 14: H_t = 36, G_t = 1.7265, σ_t^2 = 32.8179
# Epoch 16, Iteration 15: H_t = 30, G_t = 1.4396, σ_t^2 = 33.0155
# Epoch 16, Iteration 16: H_t = 4, G_t = -0.8364, σ_t^2 = 36.0044
# Epoch 16, Iteration 17: H_t = 4, G_t = -1.2361, σ_t^2 = 29.4046
# Epoch 16, Iteration 18: H_t = 4, G_t = -0.2970, σ_t^2 = 26.7399
#     Worker 0: Train Loss: 3.0028, Train Accuracy: 25.58%
#     Worker 1: Train Loss: 3.0088, Train Accuracy: 25.76%
#     Worker 2: Train Loss: 2.9619, Train Accuracy: 26.44%
#     Worker 3: Train Loss: 3.0157, Train Accuracy: 25.09%
# Epoch 16: Test Loss: 2.8349, Test Accuracy: 29.65%
# Total Computation Time: 418.59 seconds
# Total Communication Time: 0.27 seconds
# Epoch 17, Iteration 1: H_t = 4, G_t = -0.2560, σ_t^2 = 28.9172
# Epoch 17, Iteration 2: H_t = 18, G_t = 0.6994, σ_t^2 = 26.7460
# Epoch 17, Iteration 3: H_t = 4, G_t = -1.7994, σ_t^2 = 33.9797
# Epoch 17, Iteration 4: H_t = 53, G_t = 2.5801, σ_t^2 = 33.8651
# Epoch 17, Iteration 5: H_t = 29, G_t = 1.1577, σ_t^2 = 27.4643
# Epoch 17, Iteration 6: H_t = 12, G_t = 0.5471, σ_t^2 = 30.5900
# Epoch 17, Iteration 7: H_t = 4, G_t = -1.9511, σ_t^2 = 34.7955
# Epoch 17, Iteration 8: H_t = 30, G_t = 1.3870, σ_t^2 = 31.6452
# Epoch 17, Iteration 9: H_t = 4, G_t = -0.2681, σ_t^2 = 30.3756
# Epoch 17, Iteration 10: H_t = 4, G_t = -1.5073, σ_t^2 = 32.9652
# Epoch 17, Iteration 11: H_t = 4, G_t = -1.2665, σ_t^2 = 30.3913
# Epoch 17, Iteration 12: H_t = 19, G_t = 0.9352, σ_t^2 = 33.1894
# Epoch 17, Iteration 13: H_t = 47, G_t = 2.3765, σ_t^2 = 34.9557
# Epoch 17, Iteration 14: H_t = 4, G_t = -1.0428, σ_t^2 = 30.1792
#     Worker 0: Train Loss: 2.9542, Train Accuracy: 26.30%
#     Worker 1: Train Loss: 2.9851, Train Accuracy: 26.18%
#     Worker 2: Train Loss: 2.9307, Train Accuracy: 27.31%
#     Worker 3: Train Loss: 2.9672, Train Accuracy: 26.39%
# Epoch 17: Test Loss: 2.8173, Test Accuracy: 29.59%
# Total Computation Time: 446.94 seconds
# Total Communication Time: 0.28 seconds
# Epoch 18, Iteration 1: H_t = 10, G_t = 0.4351, σ_t^2 = 28.4992
# Epoch 18, Iteration 2: H_t = 4, G_t = -0.8557, σ_t^2 = 31.7999
# Epoch 18, Iteration 3: H_t = 4, G_t = 0.2148, σ_t^2 = 33.7524
# Epoch 18, Iteration 4: H_t = 42, G_t = 1.8058, σ_t^2 = 29.6656
# Epoch 18, Iteration 5: H_t = 4, G_t = -1.7095, σ_t^2 = 33.4040
# Epoch 18, Iteration 6: H_t = 4, G_t = -0.2822, σ_t^2 = 30.4344
# Epoch 18, Iteration 7: H_t = 4, G_t = -0.9077, σ_t^2 = 28.1258
# Epoch 18, Iteration 8: H_t = 50, G_t = 2.0664, σ_t^2 = 28.8539
# Epoch 18, Iteration 9: H_t = 4, G_t = -2.9692, σ_t^2 = 38.6006
# Epoch 18, Iteration 10: H_t = 11, G_t = 0.5206, σ_t^2 = 32.5914
# Epoch 18, Iteration 11: H_t = 4, G_t = -0.8611, σ_t^2 = 32.6946
# Epoch 18, Iteration 12: H_t = 4, G_t = -0.6310, σ_t^2 = 35.3460
# Epoch 18, Iteration 13: H_t = 31, G_t = 1.1605, σ_t^2 = 25.5401
# Epoch 18, Iteration 14: H_t = 4, G_t = -0.2182, σ_t^2 = 33.3959
# Epoch 18, Iteration 15: H_t = 4, G_t = -0.1307, σ_t^2 = 27.9885
# Epoch 18, Iteration 16: H_t = 13, G_t = 0.4946, σ_t^2 = 26.4503
# Epoch 18, Iteration 17: H_t = 4, G_t = -2.0943, σ_t^2 = 37.0692
#     Worker 0: Train Loss: 2.9197, Train Accuracy: 26.94%
#     Worker 1: Train Loss: 2.9078, Train Accuracy: 27.02%
#     Worker 2: Train Loss: 2.8664, Train Accuracy: 28.21%
#     Worker 3: Train Loss: 2.9279, Train Accuracy: 27.22%
# Epoch 18: Test Loss: 2.7600, Test Accuracy: 30.84%
# Total Computation Time: 471.21 seconds
# Total Communication Time: 0.31 seconds
# Epoch 19, Iteration 1: H_t = 7, G_t = 0.3360, σ_t^2 = 29.8827
# Epoch 19, Iteration 2: H_t = 10, G_t = 0.4658, σ_t^2 = 30.5328
# Epoch 19, Iteration 3: H_t = 25, G_t = 1.1780, σ_t^2 = 32.7137
# Epoch 19, Iteration 4: H_t = 37, G_t = 2.0286, σ_t^2 = 38.3539
# Epoch 19, Iteration 5: H_t = 4, G_t = -0.2478, σ_t^2 = 29.0456
# Epoch 19, Iteration 6: H_t = 7, G_t = 0.2932, σ_t^2 = 27.5843
# Epoch 19, Iteration 7: H_t = 4, G_t = -0.9806, σ_t^2 = 36.3232
# Epoch 19, Iteration 8: H_t = 8, G_t = 0.3795, σ_t^2 = 31.2162
# Epoch 19, Iteration 9: H_t = 33, G_t = 1.7135, σ_t^2 = 35.6201
# Epoch 19, Iteration 10: H_t = 4, G_t = 0.0768, σ_t^2 = 43.5478
# Epoch 19, Iteration 11: H_t = 4, G_t = -1.8833, σ_t^2 = 39.3769
# Epoch 19, Iteration 12: H_t = 34, G_t = 1.4430, σ_t^2 = 29.3074
# Epoch 19, Iteration 13: H_t = 4, G_t = -1.7316, σ_t^2 = 40.1642
# Epoch 19, Iteration 14: H_t = 4, G_t = -1.6493, σ_t^2 = 32.7185
# Epoch 19, Iteration 15: H_t = 4, G_t = -1.5974, σ_t^2 = 38.7559
# Epoch 19, Iteration 16: H_t = 4, G_t = -0.3985, σ_t^2 = 34.2146
# Epoch 19, Iteration 17: H_t = 4, G_t = -0.9674, σ_t^2 = 35.6005
#     Worker 0: Train Loss: 2.8506, Train Accuracy: 28.87%
#     Worker 1: Train Loss: 2.8658, Train Accuracy: 27.76%
#     Worker 2: Train Loss: 2.8353, Train Accuracy: 28.58%
#     Worker 3: Train Loss: 2.8674, Train Accuracy: 28.08%
# Epoch 19: Test Loss: 2.7207, Test Accuracy: 31.93%
# Total Computation Time: 495.05 seconds
# Total Communication Time: 0.33 seconds
# Epoch 20, Iteration 1: H_t = 46, G_t = 2.0482, σ_t^2 = 30.8445
# Epoch 20, Iteration 2: H_t = 45, G_t = 2.0178, σ_t^2 = 31.0260
# Epoch 20, Iteration 3: H_t = 37, G_t = 1.5882, σ_t^2 = 29.4745
# Epoch 20, Iteration 4: H_t = 48, G_t = 2.2795, σ_t^2 = 32.9953
# Epoch 20, Iteration 5: H_t = 4, G_t = -0.3235, σ_t^2 = 29.9214
# Epoch 20, Iteration 6: H_t = 4, G_t = -1.2474, σ_t^2 = 30.6875
# Epoch 20, Iteration 7: H_t = 4, G_t = -0.9053, σ_t^2 = 34.2994
# Epoch 20, Iteration 8: H_t = 7, G_t = 0.3937, σ_t^2 = 36.6245
# Epoch 20, Iteration 9: H_t = 4, G_t = -0.3474, σ_t^2 = 38.6977
#     Worker 0: Train Loss: 2.8407, Train Accuracy: 28.11%
#     Worker 1: Train Loss: 2.8677, Train Accuracy: 28.53%
#     Worker 2: Train Loss: 2.8223, Train Accuracy: 29.25%
#     Worker 3: Train Loss: 2.8435, Train Accuracy: 28.23%
# Epoch 20: Test Loss: 2.6576, Test Accuracy: 33.17%
# Total Computation Time: 519.00 seconds
# Total Communication Time: 0.34 seconds
# Epoch 21, Iteration 1: H_t = 4, G_t = -1.1475, σ_t^2 = 40.7107
# Epoch 21, Iteration 2: H_t = 64, G_t = 4.9812, σ_t^2 = 42.1073
# Epoch 21, Iteration 3: H_t = 30, G_t = 1.3235, σ_t^2 = 30.5050
# Epoch 21, Iteration 4: H_t = 4, G_t = 0.1085, σ_t^2 = 34.1640
# Epoch 21, Iteration 5: H_t = 5, G_t = 0.3089, σ_t^2 = 38.3524
# Epoch 21, Iteration 6: H_t = 64, G_t = 3.0306, σ_t^2 = 30.6434
# Epoch 21, Iteration 7: H_t = 4, G_t = -0.3343, σ_t^2 = 40.2378
# Epoch 21, Iteration 8: H_t = 4, G_t = -0.4908, σ_t^2 = 33.6606
# Epoch 21, Iteration 9: H_t = 7, G_t = 0.2882, σ_t^2 = 28.7158
# Epoch 21, Iteration 10: H_t = 4, G_t = 0.2107, σ_t^2 = 37.7898
# Epoch 21, Iteration 11: H_t = 25, G_t = 1.2971, σ_t^2 = 35.9275
# Epoch 21, Iteration 12: H_t = 4, G_t = -0.0336, σ_t^2 = 50.6972
#     Worker 0: Train Loss: 2.7876, Train Accuracy: 29.84%
#     Worker 1: Train Loss: 2.8020, Train Accuracy: 29.56%
#     Worker 2: Train Loss: 2.7776, Train Accuracy: 30.14%
#     Worker 3: Train Loss: 2.7994, Train Accuracy: 29.54%
# Epoch 21: Test Loss: 2.6419, Test Accuracy: 33.44%
# Total Computation Time: 545.23 seconds
# Total Communication Time: 0.35 seconds
# Epoch 22, Iteration 1: H_t = 31, G_t = 1.4774, σ_t^2 = 32.5522
# Epoch 22, Iteration 2: H_t = 4, G_t = -0.0509, σ_t^2 = 42.8301
# Epoch 22, Iteration 3: H_t = 4, G_t = -1.3616, σ_t^2 = 35.7746
# Epoch 22, Iteration 4: H_t = 22, G_t = 1.0214, σ_t^2 = 31.4271
# Epoch 22, Iteration 5: H_t = 4, G_t = -1.0708, σ_t^2 = 34.3699
# Epoch 22, Iteration 6: H_t = 4, G_t = -1.4859, σ_t^2 = 35.0368
# Epoch 22, Iteration 7: H_t = 4, G_t = -1.4454, σ_t^2 = 38.2545
# Epoch 22, Iteration 8: H_t = 42, G_t = 1.8256, σ_t^2 = 29.9737
# Epoch 22, Iteration 9: H_t = 50, G_t = 2.1220, σ_t^2 = 29.6461
# Epoch 22, Iteration 10: H_t = 4, G_t = -1.3765, σ_t^2 = 34.8194
# Epoch 22, Iteration 11: H_t = 16, G_t = 0.7781, σ_t^2 = 32.7420
# Epoch 22, Iteration 12: H_t = 4, G_t = -1.1710, σ_t^2 = 35.6594
# Epoch 22, Iteration 13: H_t = 39, G_t = 1.8344, σ_t^2 = 32.1055
# Epoch 22, Iteration 14: H_t = 64, G_t = 3.8647, σ_t^2 = 36.1853
#     Worker 0: Train Loss: 2.7375, Train Accuracy: 30.49%
#     Worker 1: Train Loss: 2.7681, Train Accuracy: 29.63%
#     Worker 2: Train Loss: 2.7209, Train Accuracy: 30.96%
#     Worker 3: Train Loss: 2.7636, Train Accuracy: 29.84%
# Epoch 22: Test Loss: 2.5961, Test Accuracy: 34.52%
# Total Computation Time: 573.34 seconds
# Total Communication Time: 0.37 seconds
# Epoch 23, Iteration 1: H_t = 4, G_t = 0.0142, σ_t^2 = 32.7606
# Epoch 23, Iteration 2: H_t = 4, G_t = 0.0519, σ_t^2 = 28.5719
# Epoch 23, Iteration 3: H_t = 64, G_t = 3.0629, σ_t^2 = 29.0493
# Epoch 23, Iteration 4: H_t = 15, G_t = 0.8552, σ_t^2 = 39.0124
# Epoch 23, Iteration 5: H_t = 49, G_t = 2.3152, σ_t^2 = 32.6676
# Epoch 23, Iteration 6: H_t = 4, G_t = -2.2941, σ_t^2 = 44.2303
#     Worker 0: Train Loss: 2.7083, Train Accuracy: 30.74%
#     Worker 1: Train Loss: 2.7410, Train Accuracy: 30.80%
#     Worker 2: Train Loss: 2.7013, Train Accuracy: 31.39%
#     Worker 3: Train Loss: 2.7302, Train Accuracy: 30.08%
# Epoch 23: Test Loss: 2.5484, Test Accuracy: 35.51%
# Total Computation Time: 597.51 seconds
# Total Communication Time: 0.37 seconds
# Epoch 24, Iteration 1: H_t = 16, G_t = 0.8007, σ_t^2 = 34.8146
# Epoch 24, Iteration 2: H_t = 4, G_t = -0.9096, σ_t^2 = 43.9525
# Epoch 24, Iteration 3: H_t = 4, G_t = -0.4954, σ_t^2 = 35.4355
# Epoch 24, Iteration 4: H_t = 8, G_t = 0.4159, σ_t^2 = 34.4212
# Epoch 24, Iteration 5: H_t = 13, G_t = 0.7177, σ_t^2 = 37.8926
# Epoch 24, Iteration 6: H_t = 27, G_t = 1.5166, σ_t^2 = 38.8861
# Epoch 24, Iteration 7: H_t = 4, G_t = -0.4942, σ_t^2 = 35.7044
# Epoch 24, Iteration 8: H_t = 4, G_t = -0.4962, σ_t^2 = 35.5723
# Epoch 24, Iteration 9: H_t = 64, G_t = 4.1859, σ_t^2 = 34.1076
# Epoch 24, Iteration 10: H_t = 13, G_t = 0.6624, σ_t^2 = 34.3953
# Epoch 24, Iteration 11: H_t = 15, G_t = 0.7404, σ_t^2 = 33.1514
# Epoch 24, Iteration 12: H_t = 4, G_t = 0.2490, σ_t^2 = 47.4346
# Epoch 24, Iteration 13: H_t = 4, G_t = -1.6977, σ_t^2 = 38.2395
# Epoch 24, Iteration 14: H_t = 30, G_t = 1.3203, σ_t^2 = 30.2198
# Epoch 24, Iteration 15: H_t = 4, G_t = -0.9945, σ_t^2 = 41.1967
#     Worker 0: Train Loss: 2.6411, Train Accuracy: 32.11%
#     Worker 1: Train Loss: 2.6822, Train Accuracy: 31.70%
#     Worker 2: Train Loss: 2.6466, Train Accuracy: 32.91%
#     Worker 3: Train Loss: 2.6521, Train Accuracy: 32.26%
# Epoch 24: Test Loss: 2.5087, Test Accuracy: 35.85%
# Total Computation Time: 623.15 seconds
# Total Communication Time: 0.39 seconds
# Epoch 25, Iteration 1: H_t = 4, G_t = -1.6355, σ_t^2 = 35.2520
# Epoch 25, Iteration 2: H_t = 28, G_t = 1.2368, σ_t^2 = 30.8378
# Epoch 25, Iteration 3: H_t = 4, G_t = -1.4564, σ_t^2 = 39.1092
# Epoch 25, Iteration 4: H_t = 4, G_t = -1.1398, σ_t^2 = 51.2788
# Epoch 25, Iteration 5: H_t = 9, G_t = 0.6436, σ_t^2 = 48.6549
# Epoch 25, Iteration 6: H_t = 4, G_t = -2.6858, σ_t^2 = 39.9257
# Epoch 25, Iteration 7: H_t = 30, G_t = 1.6464, σ_t^2 = 37.4811
# Epoch 25, Iteration 8: H_t = 4, G_t = -1.2016, σ_t^2 = 48.5522
# Epoch 25, Iteration 9: H_t = 25, G_t = 1.3535, σ_t^2 = 36.7968
# Epoch 25, Iteration 10: H_t = 4, G_t = -0.1593, σ_t^2 = 46.5233
# Epoch 25, Iteration 11: H_t = 4, G_t = -0.0940, σ_t^2 = 35.8837
# Epoch 25, Iteration 12: H_t = 64, G_t = 5.4553, σ_t^2 = 33.6779
# Epoch 25, Iteration 13: H_t = 4, G_t = -1.0484, σ_t^2 = 36.6412
# Epoch 25, Iteration 14: H_t = 4, G_t = 0.1625, σ_t^2 = 34.1575
# Epoch 25, Iteration 15: H_t = 24, G_t = 1.0755, σ_t^2 = 30.8897
#     Worker 0: Train Loss: 2.6046, Train Accuracy: 33.06%
#     Worker 1: Train Loss: 2.5992, Train Accuracy: 33.19%
#     Worker 2: Train Loss: 2.5762, Train Accuracy: 33.88%
#     Worker 3: Train Loss: 2.6290, Train Accuracy: 32.93%
# Epoch 25: Test Loss: 2.4799, Test Accuracy: 36.63%
# Total Computation Time: 646.73 seconds
# Total Communication Time: 0.41 seconds
# Epoch 26, Iteration 1: H_t = 4, G_t = -0.5170, σ_t^2 = 35.5935
# Epoch 26, Iteration 2: H_t = 29, G_t = 1.3850, σ_t^2 = 32.8817
# Epoch 26, Iteration 3: H_t = 4, G_t = -0.9399, σ_t^2 = 36.5162
# Epoch 26, Iteration 4: H_t = 4, G_t = -0.8955, σ_t^2 = 36.8929
# Epoch 26, Iteration 5: H_t = 4, G_t = -0.5088, σ_t^2 = 37.4347
# Epoch 26, Iteration 6: H_t = 37, G_t = 1.7706, σ_t^2 = 32.9709
# Epoch 26, Iteration 7: H_t = 4, G_t = -0.3312, σ_t^2 = 34.6337
# Epoch 26, Iteration 8: H_t = 17, G_t = 0.8837, σ_t^2 = 34.4444
# Epoch 26, Iteration 9: H_t = 4, G_t = -1.4766, σ_t^2 = 41.1648
# Epoch 26, Iteration 10: H_t = 4, G_t = -0.0993, σ_t^2 = 35.2449
# Epoch 26, Iteration 11: H_t = 33, G_t = 1.9890, σ_t^2 = 41.4780
# Epoch 26, Iteration 12: H_t = 4, G_t = 0.0258, σ_t^2 = 34.9655
# Epoch 26, Iteration 13: H_t = 4, G_t = 0.1864, σ_t^2 = 40.8068
# Epoch 26, Iteration 14: H_t = 36, G_t = 1.6846, σ_t^2 = 32.3778
# Epoch 26, Iteration 15: H_t = 51, G_t = 3.1031, σ_t^2 = 41.9757
#     Worker 0: Train Loss: 2.5694, Train Accuracy: 33.52%
#     Worker 1: Train Loss: 2.5683, Train Accuracy: 34.00%
#     Worker 2: Train Loss: 2.5611, Train Accuracy: 34.71%
#     Worker 3: Train Loss: 2.5755, Train Accuracy: 33.57%
# Epoch 26: Test Loss: 2.4526, Test Accuracy: 36.95%
# Total Computation Time: 672.28 seconds
# Total Communication Time: 0.43 seconds
# Epoch 27, Iteration 1: H_t = 4, G_t = -1.5083, σ_t^2 = 36.3923
# Epoch 27, Iteration 2: H_t = 19, G_t = 0.9069, σ_t^2 = 32.2416
# Epoch 27, Iteration 3: H_t = 26, G_t = 1.3573, σ_t^2 = 35.2443
# Epoch 27, Iteration 4: H_t = 4, G_t = 0.0448, σ_t^2 = 37.3006
# Epoch 27, Iteration 5: H_t = 4, G_t = -0.5273, σ_t^2 = 33.6496
# Epoch 27, Iteration 6: H_t = 24, G_t = 1.2588, σ_t^2 = 35.7327
# Epoch 27, Iteration 7: H_t = 25, G_t = 1.4339, σ_t^2 = 39.6558
# Epoch 27, Iteration 8: H_t = 4, G_t = -2.8633, σ_t^2 = 41.7524
# Epoch 27, Iteration 9: H_t = 4, G_t = -0.5697, σ_t^2 = 40.5200
# Epoch 27, Iteration 10: H_t = 4, G_t = 0.2438, σ_t^2 = 40.1353
# Epoch 27, Iteration 11: H_t = 45, G_t = 2.4466, σ_t^2 = 37.4853
# Epoch 27, Iteration 12: H_t = 4, G_t = -0.5679, σ_t^2 = 38.7717
#     Worker 0: Train Loss: 2.5542, Train Accuracy: 33.64%
#     Worker 1: Train Loss: 2.5965, Train Accuracy: 33.28%
#     Worker 2: Train Loss: 2.5323, Train Accuracy: 35.04%
#     Worker 3: Train Loss: 2.5819, Train Accuracy: 33.64%
# Epoch 27: Test Loss: 2.4266, Test Accuracy: 38.17%
# Total Computation Time: 697.91 seconds
# Total Communication Time: 0.44 seconds
# Epoch 28, Iteration 1: H_t = 4, G_t = -0.2670, σ_t^2 = 31.5005
# Epoch 28, Iteration 2: H_t = 6, G_t = 0.3039, σ_t^2 = 35.3550
# Epoch 28, Iteration 3: H_t = 64, G_t = 3.3323, σ_t^2 = 35.8998
# Epoch 28, Iteration 4: H_t = 4, G_t = -0.0190, σ_t^2 = 42.5677
# Epoch 28, Iteration 5: H_t = 37, G_t = 1.6898, σ_t^2 = 31.5145
# Epoch 28, Iteration 6: H_t = 4, G_t = -1.9567, σ_t^2 = 48.4473
# Epoch 28, Iteration 7: H_t = 4, G_t = 0.1511, σ_t^2 = 33.8253
# Epoch 28, Iteration 8: H_t = 64, G_t = 3.4475, σ_t^2 = 35.3480
# Epoch 28, Iteration 9: H_t = 4, G_t = -0.4243, σ_t^2 = 37.5318
# Epoch 28, Iteration 10: H_t = 50, G_t = 2.4139, σ_t^2 = 33.3428
# Epoch 28, Iteration 11: H_t = 4, G_t = -1.6476, σ_t^2 = 42.4171
#     Worker 0: Train Loss: 2.5345, Train Accuracy: 34.25%
#     Worker 1: Train Loss: 2.5655, Train Accuracy: 33.77%
#     Worker 2: Train Loss: 2.5271, Train Accuracy: 35.12%
#     Worker 3: Train Loss: 2.5414, Train Accuracy: 34.91%
# Epoch 28: Test Loss: 2.3937, Test Accuracy: 38.30%
# Total Computation Time: 727.07 seconds
# Total Communication Time: 0.45 seconds
# Epoch 29, Iteration 1: H_t = 4, G_t = -1.9073, σ_t^2 = 41.3177
# Epoch 29, Iteration 2: H_t = 9, G_t = 0.4680, σ_t^2 = 35.6776
# Epoch 29, Iteration 3: H_t = 6, G_t = 0.2986, σ_t^2 = 32.0389
# Epoch 29, Iteration 4: H_t = 4, G_t = -0.5999, σ_t^2 = 37.8034
# Epoch 29, Iteration 5: H_t = 42, G_t = 2.4628, σ_t^2 = 40.8375
# Epoch 29, Iteration 6: H_t = 4, G_t = -0.8361, σ_t^2 = 42.9597
# Epoch 29, Iteration 7: H_t = 64, G_t = 6.2834, σ_t^2 = 32.0898
# Epoch 29, Iteration 8: H_t = 4, G_t = 0.3062, σ_t^2 = 46.9578
# Epoch 29, Iteration 9: H_t = 21, G_t = 1.0586, σ_t^2 = 34.0630
# Epoch 29, Iteration 10: H_t = 4, G_t = -2.2581, σ_t^2 = 46.7377
# Epoch 29, Iteration 11: H_t = 4, G_t = 0.0138, σ_t^2 = 35.7805
# Epoch 29, Iteration 12: H_t = 4, G_t = 0.0831, σ_t^2 = 34.0025
# Epoch 29, Iteration 13: H_t = 4, G_t = -0.6115, σ_t^2 = 38.4522
# Epoch 29, Iteration 14: H_t = 19, G_t = 1.0778, σ_t^2 = 37.9897
# Epoch 29, Iteration 15: H_t = 4, G_t = -1.0568, σ_t^2 = 39.4650
#     Worker 0: Train Loss: 2.4672, Train Accuracy: 36.28%
#     Worker 1: Train Loss: 2.4685, Train Accuracy: 36.25%
#     Worker 2: Train Loss: 2.4498, Train Accuracy: 36.68%
#     Worker 3: Train Loss: 2.4832, Train Accuracy: 35.16%
# Epoch 29: Test Loss: 2.3670, Test Accuracy: 39.16%
# Total Computation Time: 750.50 seconds
# Total Communication Time: 0.47 seconds
# Epoch 30, Iteration 1: H_t = 4, G_t = -0.4047, σ_t^2 = 58.2603
# Epoch 30, Iteration 2: H_t = 64, G_t = 5.1704, σ_t^2 = 37.2347
# Epoch 30, Iteration 3: H_t = 4, G_t = -2.2894, σ_t^2 = 45.3370
# Epoch 30, Iteration 4: H_t = 64, G_t = 3.7772, σ_t^2 = 36.0694
# Epoch 30, Iteration 5: H_t = 4, G_t = -1.6726, σ_t^2 = 45.9001
# Epoch 30, Iteration 6: H_t = 16, G_t = 0.9436, σ_t^2 = 39.2097
# Epoch 30, Iteration 7: H_t = 4, G_t = -0.5810, σ_t^2 = 42.3245
# Epoch 30, Iteration 8: H_t = 12, G_t = 0.7138, σ_t^2 = 39.7993
# Epoch 30, Iteration 9: H_t = 4, G_t = -0.8946, σ_t^2 = 39.7179
# Epoch 30, Iteration 10: H_t = 4, G_t = -1.2562, σ_t^2 = 44.2884
# Epoch 30, Iteration 11: H_t = 4, G_t = -0.4641, σ_t^2 = 34.5868
# Epoch 30, Iteration 12: H_t = 4, G_t = 0.1651, σ_t^2 = 36.8273
# Epoch 30, Iteration 13: H_t = 36, G_t = 2.0749, σ_t^2 = 40.0524
# Epoch 30, Iteration 14: H_t = 4, G_t = -3.3975, σ_t^2 = 56.4192
#     Worker 0: Train Loss: 2.4367, Train Accuracy: 36.67%
#     Worker 1: Train Loss: 2.4709, Train Accuracy: 36.29%
#     Worker 2: Train Loss: 2.4463, Train Accuracy: 37.27%
#     Worker 3: Train Loss: 2.4739, Train Accuracy: 36.70%
# Epoch 30: Test Loss: 2.3469, Test Accuracy: 39.36%
# Total Computation Time: 777.77 seconds
# Total Communication Time: 0.49 seconds
# Epoch 31, Iteration 1: H_t = 64, G_t = 3.0602, σ_t^2 = 32.2882
# Epoch 31, Iteration 2: H_t = 4, G_t = -0.8134, σ_t^2 = 40.4802
# Epoch 31, Iteration 3: H_t = 8, G_t = 0.3936, σ_t^2 = 32.6820
# Epoch 31, Iteration 4: H_t = 64, G_t = 4.0992, σ_t^2 = 38.3156
# Epoch 31, Iteration 5: H_t = 4, G_t = -1.3003, σ_t^2 = 54.6109
# Epoch 31, Iteration 6: H_t = 4, G_t = -0.4480, σ_t^2 = 34.0810
# Epoch 31, Iteration 7: H_t = 4, G_t = -0.5368, σ_t^2 = 37.1072
# Epoch 31, Iteration 8: H_t = 4, G_t = -0.2769, σ_t^2 = 33.9374
# Epoch 31, Iteration 9: H_t = 20, G_t = 1.0092, σ_t^2 = 34.6612
# Epoch 31, Iteration 10: H_t = 4, G_t = -2.3696, σ_t^2 = 52.1265
# Epoch 31, Iteration 11: H_t = 4, G_t = -1.4870, σ_t^2 = 52.3382
# Epoch 31, Iteration 12: H_t = 21, G_t = 1.1360, σ_t^2 = 37.2090
# Epoch 31, Iteration 13: H_t = 64, G_t = 6.2460, σ_t^2 = 39.8479
#     Worker 0: Train Loss: 2.4230, Train Accuracy: 37.14%
#     Worker 1: Train Loss: 2.4552, Train Accuracy: 36.28%
#     Worker 2: Train Loss: 2.4156, Train Accuracy: 37.47%
#     Worker 3: Train Loss: 2.4206, Train Accuracy: 36.72%
# Epoch 31: Test Loss: 2.3321, Test Accuracy: 39.86%
# Total Computation Time: 802.70 seconds
# Total Communication Time: 0.51 seconds
# Epoch 32, Iteration 1: H_t = 4, G_t = -1.0542, σ_t^2 = 39.0450
# Epoch 32, Iteration 2: H_t = 64, G_t = 3.7127, σ_t^2 = 34.7383
# Epoch 32, Iteration 3: H_t = 23, G_t = 1.1564, σ_t^2 = 33.9226
# Epoch 32, Iteration 4: H_t = 4, G_t = -2.1697, σ_t^2 = 43.0034
# Epoch 32, Iteration 5: H_t = 7, G_t = 0.4289, σ_t^2 = 38.5096
# Epoch 32, Iteration 6: H_t = 4, G_t = -0.5523, σ_t^2 = 39.7243
# Epoch 32, Iteration 7: H_t = 4, G_t = -1.2271, σ_t^2 = 40.2745
# Epoch 32, Iteration 8: H_t = 4, G_t = -0.2062, σ_t^2 = 38.8442
# Epoch 32, Iteration 9: H_t = 4, G_t = -1.5346, σ_t^2 = 40.2416
# Epoch 32, Iteration 10: H_t = 4, G_t = -0.0541, σ_t^2 = 36.7347
# Epoch 32, Iteration 11: H_t = 35, G_t = 1.7740, σ_t^2 = 34.9347
# Epoch 32, Iteration 12: H_t = 4, G_t = -1.7837, σ_t^2 = 44.5816
#     Worker 0: Train Loss: 2.4085, Train Accuracy: 37.27%
#     Worker 1: Train Loss: 2.4127, Train Accuracy: 37.19%
#     Worker 2: Train Loss: 2.3745, Train Accuracy: 38.33%
#     Worker 3: Train Loss: 2.3975, Train Accuracy: 37.46%
# Epoch 32: Test Loss: 2.3043, Test Accuracy: 40.01%
# Total Computation Time: 829.06 seconds
# Total Communication Time: 0.52 seconds
# Epoch 33, Iteration 1: H_t = 28, G_t = 1.5640, σ_t^2 = 38.6923
# Epoch 33, Iteration 2: H_t = 4, G_t = -0.2270, σ_t^2 = 41.1289
# Epoch 33, Iteration 3: H_t = 22, G_t = 1.2969, σ_t^2 = 41.2304
# Epoch 33, Iteration 4: H_t = 64, G_t = 6.5852, σ_t^2 = 40.7963
# Epoch 33, Iteration 5: H_t = 4, G_t = -0.2859, σ_t^2 = 42.2848
# Epoch 33, Iteration 6: H_t = 4, G_t = -0.4123, σ_t^2 = 41.7857
# Epoch 33, Iteration 7: H_t = 4, G_t = -2.1553, σ_t^2 = 43.8111
# Epoch 33, Iteration 8: H_t = 12, G_t = 0.6563, σ_t^2 = 36.0731
# Epoch 33, Iteration 9: H_t = 24, G_t = 1.7022, σ_t^2 = 48.8340
# Epoch 33, Iteration 10: H_t = 4, G_t = -0.2947, σ_t^2 = 49.4106
# Epoch 33, Iteration 11: H_t = 4, G_t = -1.0613, σ_t^2 = 39.4278
# Epoch 33, Iteration 12: H_t = 4, G_t = -1.1941, σ_t^2 = 40.8259
# Epoch 33, Iteration 13: H_t = 59, G_t = 3.3146, σ_t^2 = 38.9660
# Epoch 33, Iteration 14: H_t = 4, G_t = -1.8393, σ_t^2 = 42.5513
#     Worker 0: Train Loss: 2.3666, Train Accuracy: 38.08%
#     Worker 1: Train Loss: 2.3951, Train Accuracy: 37.87%
#     Worker 2: Train Loss: 2.3477, Train Accuracy: 38.55%
#     Worker 3: Train Loss: 2.3799, Train Accuracy: 37.36%
# Epoch 33: Test Loss: 2.2844, Test Accuracy: 40.54%
# Total Computation Time: 857.71 seconds
# Total Communication Time: 0.54 seconds
# Epoch 34, Iteration 1: H_t = 64, G_t = 6.3196, σ_t^2 = 41.4235
# Epoch 34, Iteration 2: H_t = 4, G_t = -1.0721, σ_t^2 = 40.3069
# Epoch 34, Iteration 3: H_t = 64, G_t = 4.3161, σ_t^2 = 41.7126
# Epoch 34, Iteration 4: H_t = 4, G_t = -1.3570, σ_t^2 = 44.3031
# Epoch 34, Iteration 5: H_t = 4, G_t = -1.6339, σ_t^2 = 38.8082
# Epoch 34, Iteration 6: H_t = 4, G_t = 0.1785, σ_t^2 = 36.5311
# Epoch 34, Iteration 7: H_t = 4, G_t = -1.2764, σ_t^2 = 43.8698
# Epoch 34, Iteration 8: H_t = 20, G_t = 1.2513, σ_t^2 = 42.8454
# Epoch 34, Iteration 9: H_t = 38, G_t = 2.1314, σ_t^2 = 39.0860
# Epoch 34, Iteration 10: H_t = 4, G_t = -1.8759, σ_t^2 = 44.1211
#     Worker 0: Train Loss: 2.3711, Train Accuracy: 38.15%
#     Worker 1: Train Loss: 2.3488, Train Accuracy: 38.71%
#     Worker 2: Train Loss: 2.3565, Train Accuracy: 38.62%
#     Worker 3: Train Loss: 2.3730, Train Accuracy: 37.94%
# Epoch 34: Test Loss: 2.2651, Test Accuracy: 41.31%
# Total Computation Time: 882.66 seconds
# Total Communication Time: 0.55 seconds
# Epoch 35, Iteration 1: H_t = 11, G_t = 0.5746, σ_t^2 = 34.5228
# Epoch 35, Iteration 2: H_t = 13, G_t = 0.8425, σ_t^2 = 42.5804
# Epoch 35, Iteration 3: H_t = 4, G_t = -0.5493, σ_t^2 = 57.9639
# Epoch 35, Iteration 4: H_t = 4, G_t = -0.5745, σ_t^2 = 45.3576
# Epoch 35, Iteration 5: H_t = 17, G_t = 0.9516, σ_t^2 = 38.8794
# Epoch 35, Iteration 6: H_t = 64, G_t = 3.6203, σ_t^2 = 39.0154
# Epoch 35, Iteration 7: H_t = 10, G_t = 0.6529, σ_t^2 = 43.2557
# Epoch 35, Iteration 8: H_t = 4, G_t = -1.4530, σ_t^2 = 124.1155
# Epoch 35, Iteration 9: H_t = 4, G_t = -3.0184, σ_t^2 = 50.3838
# Epoch 35, Iteration 10: H_t = 44, G_t = 2.4300, σ_t^2 = 38.0703
# Epoch 35, Iteration 11: H_t = 7, G_t = 0.4311, σ_t^2 = 38.1130
# Epoch 35, Iteration 12: H_t = 4, G_t = -1.6052, σ_t^2 = 43.8292
# Epoch 35, Iteration 13: H_t = 9, G_t = 0.4495, σ_t^2 = 33.6178
# Epoch 35, Iteration 14: H_t = 4, G_t = -1.5059, σ_t^2 = 47.7724
#     Worker 0: Train Loss: 2.3188, Train Accuracy: 39.23%
#     Worker 1: Train Loss: 2.3242, Train Accuracy: 39.16%
#     Worker 2: Train Loss: 2.3143, Train Accuracy: 40.10%
#     Worker 3: Train Loss: 2.3086, Train Accuracy: 39.37%
# Epoch 35: Test Loss: 2.2394, Test Accuracy: 41.96%
# Total Computation Time: 906.27 seconds
# Total Communication Time: 0.57 seconds
# Epoch 36, Iteration 1: H_t = 4, G_t = -0.8212, σ_t^2 = 40.8558
# Epoch 36, Iteration 2: H_t = 52, G_t = 2.9340, σ_t^2 = 39.2588
# Epoch 36, Iteration 3: H_t = 4, G_t = -2.5262, σ_t^2 = 50.4105
# Epoch 36, Iteration 4: H_t = 21, G_t = 1.2226, σ_t^2 = 38.9463
# Epoch 36, Iteration 5: H_t = 4, G_t = -1.1874, σ_t^2 = 47.3263
# Epoch 36, Iteration 6: H_t = 4, G_t = 0.1914, σ_t^2 = 37.2767
# Epoch 36, Iteration 7: H_t = 24, G_t = 1.2039, σ_t^2 = 34.4693
# Epoch 36, Iteration 8: H_t = 4, G_t = -0.4617, σ_t^2 = 44.3525
# Epoch 36, Iteration 9: H_t = 4, G_t = -0.5115, σ_t^2 = 43.6587
# Epoch 36, Iteration 10: H_t = 4, G_t = -0.6981, σ_t^2 = 40.8334
# Epoch 36, Iteration 11: H_t = 27, G_t = 2.0222, σ_t^2 = 51.3133
# Epoch 36, Iteration 12: H_t = 4, G_t = -0.3923, σ_t^2 = 53.3789
# Epoch 36, Iteration 13: H_t = 5, G_t = 0.3636, σ_t^2 = 44.2417
# Epoch 36, Iteration 14: H_t = 4, G_t = -0.1894, σ_t^2 = 39.1984
# Epoch 36, Iteration 15: H_t = 4, G_t = -0.9495, σ_t^2 = 43.7138
# Epoch 36, Iteration 16: H_t = 28, G_t = 1.5163, σ_t^2 = 37.0758
# Epoch 36, Iteration 17: H_t = 4, G_t = -1.8578, σ_t^2 = 53.2108
#     Worker 0: Train Loss: 2.2635, Train Accuracy: 40.65%
#     Worker 1: Train Loss: 2.2817, Train Accuracy: 40.22%
#     Worker 2: Train Loss: 2.2568, Train Accuracy: 41.08%
#     Worker 3: Train Loss: 2.2842, Train Accuracy: 40.18%
# Epoch 36: Test Loss: 2.2290, Test Accuracy: 41.90%
# Total Computation Time: 929.99 seconds
# Total Communication Time: 0.59 seconds
# Epoch 37, Iteration 1: H_t = 22, G_t = 1.3594, σ_t^2 = 43.2541
# Epoch 37, Iteration 2: H_t = 12, G_t = 0.7572, σ_t^2 = 41.1971
# Epoch 37, Iteration 3: H_t = 4, G_t = -0.8511, σ_t^2 = 47.4282
# Epoch 37, Iteration 4: H_t = 27, G_t = 1.7829, σ_t^2 = 44.6423
# Epoch 37, Iteration 5: H_t = 15, G_t = 1.2536, σ_t^2 = 57.3030
# Epoch 37, Iteration 6: H_t = 14, G_t = 0.8852, σ_t^2 = 43.0243
# Epoch 37, Iteration 7: H_t = 4, G_t = -0.7470, σ_t^2 = 46.2433
# Epoch 37, Iteration 8: H_t = 10, G_t = 0.6140, σ_t^2 = 39.2978
# Epoch 37, Iteration 9: H_t = 4, G_t = -0.3686, σ_t^2 = 46.9115
# Epoch 37, Iteration 10: H_t = 11, G_t = 0.7116, σ_t^2 = 44.1751
# Epoch 37, Iteration 11: H_t = 26, G_t = 2.0985, σ_t^2 = 55.5706
# Epoch 37, Iteration 12: H_t = 4, G_t = -0.7703, σ_t^2 = 46.3589
# Epoch 37, Iteration 13: H_t = 4, G_t = -0.3990, σ_t^2 = 38.7932
# Epoch 37, Iteration 14: H_t = 7, G_t = 0.4805, σ_t^2 = 43.5460
# Epoch 37, Iteration 15: H_t = 24, G_t = 1.5961, σ_t^2 = 46.3761
# Epoch 37, Iteration 16: H_t = 11, G_t = 0.8450, σ_t^2 = 49.3294
# Epoch 37, Iteration 17: H_t = 4, G_t = -0.8665, σ_t^2 = 42.0615
#     Worker 0: Train Loss: 2.2450, Train Accuracy: 40.24%
#     Worker 1: Train Loss: 2.2553, Train Accuracy: 40.62%
#     Worker 2: Train Loss: 2.2165, Train Accuracy: 41.81%
#     Worker 3: Train Loss: 2.2722, Train Accuracy: 40.49%
# Epoch 37: Test Loss: 2.2161, Test Accuracy: 42.22%
# Total Computation Time: 954.29 seconds
# Total Communication Time: 0.61 seconds
# Epoch 38, Iteration 1: H_t = 4, G_t = 0.2500, σ_t^2 = 48.8410
# Epoch 38, Iteration 2: H_t = 17, G_t = 1.0673, σ_t^2 = 41.5290
# Epoch 38, Iteration 3: H_t = 30, G_t = 2.1624, σ_t^2 = 49.1439
# Epoch 38, Iteration 4: H_t = 4, G_t = -0.3497, σ_t^2 = 43.8742
# Epoch 38, Iteration 5: H_t = 10, G_t = 0.5438, σ_t^2 = 36.6953
# Epoch 38, Iteration 6: H_t = 12, G_t = 0.7529, σ_t^2 = 43.8561
# Epoch 38, Iteration 7: H_t = 48, G_t = 3.3413, σ_t^2 = 47.8861
# Epoch 38, Iteration 8: H_t = 12, G_t = 0.8078, σ_t^2 = 43.5557
# Epoch 38, Iteration 9: H_t = 12, G_t = 0.7205, σ_t^2 = 41.2952
# Epoch 38, Iteration 10: H_t = 4, G_t = -0.5485, σ_t^2 = 56.9010
# Epoch 38, Iteration 11: H_t = 4, G_t = 0.0554, σ_t^2 = 45.4479
# Epoch 38, Iteration 12: H_t = 20, G_t = 1.3940, σ_t^2 = 46.9406
# Epoch 38, Iteration 13: H_t = 4, G_t = -1.1715, σ_t^2 = 52.5637
# Epoch 38, Iteration 14: H_t = 37, G_t = 2.8854, σ_t^2 = 54.0230
# Epoch 38, Iteration 15: H_t = 4, G_t = -1.1951, σ_t^2 = 46.2966
#     Worker 0: Train Loss: 2.2408, Train Accuracy: 41.75%
#     Worker 1: Train Loss: 2.2311, Train Accuracy: 41.20%
#     Worker 2: Train Loss: 2.2175, Train Accuracy: 41.79%
#     Worker 3: Train Loss: 2.2456, Train Accuracy: 40.55%
# Epoch 38: Test Loss: 2.1948, Test Accuracy: 43.13%
# Total Computation Time: 980.94 seconds
# Total Communication Time: 0.63 seconds
# Epoch 39, Iteration 1: H_t = 4, G_t = -0.0098, σ_t^2 = 45.4873
# Epoch 39, Iteration 2: H_t = 4, G_t = -1.0470, σ_t^2 = 44.4090
# Epoch 39, Iteration 3: H_t = 37, G_t = 2.0702, σ_t^2 = 38.4656
# Epoch 39, Iteration 4: H_t = 4, G_t = -0.1852, σ_t^2 = 46.6900
# Epoch 39, Iteration 5: H_t = 9, G_t = 0.5331, σ_t^2 = 40.5324
# Epoch 39, Iteration 6: H_t = 4, G_t = -0.3119, σ_t^2 = 45.3265
# Epoch 39, Iteration 7: H_t = 4, G_t = -0.1475, σ_t^2 = 50.2903
# Epoch 39, Iteration 8: H_t = 13, G_t = 0.8154, σ_t^2 = 41.8991
# Epoch 39, Iteration 9: H_t = 4, G_t = -1.1313, σ_t^2 = 48.3160
# Epoch 39, Iteration 10: H_t = 64, G_t = 4.9607, σ_t^2 = 45.9179
# Epoch 39, Iteration 11: H_t = 4, G_t = -1.0765, σ_t^2 = 48.8019
# Epoch 39, Iteration 12: H_t = 4, G_t = 0.2127, σ_t^2 = 44.9568
# Epoch 39, Iteration 13: H_t = 40, G_t = 2.2625, σ_t^2 = 39.0945
# Epoch 39, Iteration 14: H_t = 58, G_t = 3.6082, σ_t^2 = 43.0740
#     Worker 0: Train Loss: 2.2262, Train Accuracy: 40.68%
#     Worker 1: Train Loss: 2.2397, Train Accuracy: 41.24%
#     Worker 2: Train Loss: 2.2160, Train Accuracy: 41.85%
#     Worker 3: Train Loss: 2.2364, Train Accuracy: 40.37%
# Epoch 39: Test Loss: 2.2046, Test Accuracy: 42.24%
# Total Computation Time: 1004.95 seconds
# Total Communication Time: 0.64 seconds
# Epoch 40, Iteration 1: H_t = 4, G_t = -0.3386, σ_t^2 = 49.7166
# Epoch 40, Iteration 2: H_t = 9, G_t = 0.5463, σ_t^2 = 39.1553
# Epoch 40, Iteration 3: H_t = 4, G_t = -0.8509, σ_t^2 = 41.1826
# Epoch 40, Iteration 4: H_t = 10, G_t = 0.6199, σ_t^2 = 40.9138
# Epoch 40, Iteration 5: H_t = 16, G_t = 1.0670, σ_t^2 = 46.2297
# Epoch 40, Iteration 6: H_t = 4, G_t = 0.1979, σ_t^2 = 50.5159
# Epoch 40, Iteration 7: H_t = 4, G_t = -0.1356, σ_t^2 = 47.5787
# Epoch 40, Iteration 8: H_t = 4, G_t = -0.3345, σ_t^2 = 49.5219
# Epoch 40, Iteration 9: H_t = 64, G_t = 4.5449, σ_t^2 = 41.0803
# Epoch 40, Iteration 10: H_t = 20, G_t = 1.2773, σ_t^2 = 43.5768
# Epoch 40, Iteration 11: H_t = 4, G_t = -2.6277, σ_t^2 = 53.1305
#     Worker 0: Train Loss: 2.2228, Train Accuracy: 41.20%
#     Worker 1: Train Loss: 2.2081, Train Accuracy: 40.98%
#     Worker 2: Train Loss: 2.2198, Train Accuracy: 41.85%
#     Worker 3: Train Loss: 2.1931, Train Accuracy: 42.10%
# Epoch 40: Test Loss: 2.1736, Test Accuracy: 42.99%
# Total Computation Time: 1028.84 seconds
# Total Communication Time: 0.65 seconds
# Epoch 41, Iteration 1: H_t = 4, G_t = -0.0058, σ_t^2 = 45.7117
# Epoch 41, Iteration 2: H_t = 31, G_t = 1.6769, σ_t^2 = 37.0086
# Epoch 41, Iteration 3: H_t = 11, G_t = 0.7725, σ_t^2 = 46.0476
# Epoch 41, Iteration 4: H_t = 4, G_t = -2.3374, σ_t^2 = 52.0499
# Epoch 41, Iteration 5: H_t = 4, G_t = -1.0342, σ_t^2 = 49.2963
# Epoch 41, Iteration 6: H_t = 7, G_t = 0.4924, σ_t^2 = 44.9379
# Epoch 41, Iteration 7: H_t = 4, G_t = -1.5029, σ_t^2 = 50.0471
# Epoch 41, Iteration 8: H_t = 18, G_t = 1.3006, σ_t^2 = 50.2686
# ...
#     Worker 1: Train Loss: 1.2223, Train Accuracy: 65.83%
#     Worker 2: Train Loss: 1.1995, Train Accuracy: 66.04%
#     Worker 3: Train Loss: 1.2190, Train Accuracy: 65.47%
# Epoch 143: Test Loss: 1.9488, Test Accuracy: 51.29%
# Total Computation Time: 3558.80 seconds
# Total Communication Time: 3.09 seconds
# Epoch 144, Iteration 1: H_t = 4, G_t = -1.8874, σ_t^2 = 105.1278
# Epoch 144, Iteration 2: H_t = 6, G_t = 0.9243, σ_t^2 = 96.8607
# Epoch 144, Iteration 3: H_t = 4, G_t = -0.6106, σ_t^2 = 98.3090
# Epoch 144, Iteration 4: H_t = 4, G_t = -1.8924, σ_t^2 = 106.2721
# Epoch 144, Iteration 5: H_t = 4, G_t = -1.5325, σ_t^2 = 107.5409
# Epoch 144, Iteration 6: H_t = 22, G_t = 2.9847, σ_t^2 = 91.5857
# Epoch 144, Iteration 7: H_t = 10, G_t = 1.5805, σ_t^2 = 101.8412
# Epoch 144, Iteration 8: H_t = 4, G_t = -2.9692, σ_t^2 = 108.3731
# Epoch 144, Iteration 9: H_t = 4, G_t = -0.9081, σ_t^2 = 93.9899
# Epoch 144, Iteration 10: H_t = 7, G_t = 1.2398, σ_t^2 = 111.2887
# Epoch 144, Iteration 11: H_t = 4, G_t = -0.2151, σ_t^2 = 92.1234
# Epoch 144, Iteration 12: H_t = 21, G_t = 2.8657, σ_t^2 = 95.2176
# Epoch 144, Iteration 13: H_t = 4, G_t = -0.0943, σ_t^2 = 93.3972
# Epoch 144, Iteration 14: H_t = 13, G_t = 1.9505, σ_t^2 = 100.5694
# Epoch 144, Iteration 15: H_t = 4, G_t = -0.1648, σ_t^2 = 103.8255
# Epoch 144, Iteration 16: H_t = 4, G_t = -1.8476, σ_t^2 = 100.5431
# Epoch 144, Iteration 17: H_t = 10, G_t = 1.4288, σ_t^2 = 95.6829
# Epoch 144, Iteration 18: H_t = 6, G_t = 0.8878, σ_t^2 = 100.2730
# Epoch 144, Iteration 19: H_t = 5, G_t = 0.8826, σ_t^2 = 108.8610
# Epoch 144, Iteration 20: H_t = 14, G_t = 1.8856, σ_t^2 = 90.0613
# Epoch 144, Iteration 21: H_t = 4, G_t = -2.7823, σ_t^2 = 124.7634
# Epoch 144, Iteration 22: H_t = 4, G_t = -1.6353, σ_t^2 = 103.1720
# Epoch 144, Iteration 23: H_t = 4, G_t = -2.3573, σ_t^2 = 109.2895
# Epoch 144, Iteration 24: H_t = 4, G_t = -0.5357, σ_t^2 = 106.3554
# Epoch 144, Iteration 25: H_t = 4, G_t = -0.2764, σ_t^2 = 97.9947
# Epoch 144, Iteration 26: H_t = 4, G_t = -1.8149, σ_t^2 = 102.8058
# Epoch 144, Iteration 27: H_t = 7, G_t = 0.9838, σ_t^2 = 92.7447
# Epoch 144, Iteration 28: H_t = 4, G_t = -1.0404, σ_t^2 = 107.5310
# Epoch 144, Iteration 29: H_t = 4, G_t = -0.9765, σ_t^2 = 106.8206
# Epoch 144, Iteration 30: H_t = 4, G_t = -1.5356, σ_t^2 = 102.7199
#     Worker 0: Train Loss: 1.2211, Train Accuracy: 64.96%
#     Worker 1: Train Loss: 1.2222, Train Accuracy: 65.69%
#     Worker 2: Train Loss: 1.2097, Train Accuracy: 66.73%
#     Worker 3: Train Loss: 1.2403, Train Accuracy: 65.15%
# Epoch 144: Test Loss: 1.9487, Test Accuracy: 51.30%
# Total Computation Time: 3582.41 seconds
# Total Communication Time: 3.13 seconds
# Epoch 145, Iteration 1: H_t = 4, G_t = -2.4622, σ_t^2 = 110.3498
# Epoch 145, Iteration 2: H_t = 4, G_t = 0.2655, σ_t^2 = 95.8176
# Epoch 145, Iteration 3: H_t = 4, G_t = 0.1858, σ_t^2 = 99.1971
# Epoch 145, Iteration 4: H_t = 53, G_t = 7.4573, σ_t^2 = 97.3759
# Epoch 145, Iteration 5: H_t = 20, G_t = 2.7616, σ_t^2 = 92.0919
# Epoch 145, Iteration 6: H_t = 31, G_t = 4.4699, σ_t^2 = 99.8556
# Epoch 145, Iteration 7: H_t = 4, G_t = -0.7132, σ_t^2 = 106.1110
# Epoch 145, Iteration 8: H_t = 4, G_t = 0.4905, σ_t^2 = 105.0655
# Epoch 145, Iteration 9: H_t = 10, G_t = 1.3902, σ_t^2 = 96.9440
# Epoch 145, Iteration 10: H_t = 4, G_t = -3.4426, σ_t^2 = 106.8748
# Epoch 145, Iteration 11: H_t = 10, G_t = 1.4576, σ_t^2 = 97.7926
# Epoch 145, Iteration 12: H_t = 7, G_t = 1.3381, σ_t^2 = 119.8422
# Epoch 145, Iteration 13: H_t = 4, G_t = 0.4552, σ_t^2 = 105.6109
# Epoch 145, Iteration 14: H_t = 4, G_t = -0.6377, σ_t^2 = 116.9608
# Epoch 145, Iteration 15: H_t = 16, G_t = 2.1908, σ_t^2 = 92.3948
# Epoch 145, Iteration 16: H_t = 7, G_t = 1.2682, σ_t^2 = 114.6329
# Epoch 145, Iteration 17: H_t = 13, G_t = 1.8248, σ_t^2 = 94.5107
# Epoch 145, Iteration 18: H_t = 4, G_t = -3.2162, σ_t^2 = 111.2902
#     Worker 0: Train Loss: 1.2214, Train Accuracy: 65.13%
#     Worker 1: Train Loss: 1.2196, Train Accuracy: 65.45%
#     Worker 2: Train Loss: 1.2271, Train Accuracy: 65.42%
#     Worker 3: Train Loss: 1.2280, Train Accuracy: 65.17%
# Epoch 145: Test Loss: 1.9490, Test Accuracy: 51.21%
# Total Computation Time: 3606.67 seconds
# Total Communication Time: 3.15 seconds
# Epoch 146, Iteration 1: H_t = 4, G_t = -4.8519, σ_t^2 = 110.2931
# Epoch 146, Iteration 2: H_t = 4, G_t = -12.6214, σ_t^2 = 398.7050
# Epoch 146, Iteration 3: H_t = 4, G_t = -3.0197, σ_t^2 = 95.6239
# Epoch 146, Iteration 4: H_t = 5, G_t = 0.8395, σ_t^2 = 113.5827
# Epoch 146, Iteration 5: H_t = 4, G_t = -0.6289, σ_t^2 = 99.4465
# Epoch 146, Iteration 6: H_t = 17, G_t = 2.4540, σ_t^2 = 100.9952
# Epoch 146, Iteration 7: H_t = 4, G_t = -0.7112, σ_t^2 = 92.1001
# Epoch 146, Iteration 8: H_t = 16, G_t = 2.2113, σ_t^2 = 94.5725
# Epoch 146, Iteration 9: H_t = 4, G_t = -1.3950, σ_t^2 = 132.5748
# Epoch 146, Iteration 10: H_t = 4, G_t = -1.3666, σ_t^2 = 95.9282
# Epoch 146, Iteration 11: H_t = 4, G_t = -1.5588, σ_t^2 = 106.9855
# Epoch 146, Iteration 12: H_t = 7, G_t = 0.9990, σ_t^2 = 98.0727
# Epoch 146, Iteration 13: H_t = 4, G_t = -1.0532, σ_t^2 = 101.1196
# Epoch 146, Iteration 14: H_t = 4, G_t = -0.0067, σ_t^2 = 97.4199
# Epoch 146, Iteration 15: H_t = 4, G_t = -0.5102, σ_t^2 = 101.4002
# Epoch 146, Iteration 16: H_t = 12, G_t = 1.5932, σ_t^2 = 89.6938
# Epoch 146, Iteration 17: H_t = 4, G_t = -0.2546, σ_t^2 = 106.4558
# Epoch 146, Iteration 18: H_t = 14, G_t = 2.1517, σ_t^2 = 105.9708
# Epoch 146, Iteration 19: H_t = 9, G_t = 1.4602, σ_t^2 = 103.2062
# Epoch 146, Iteration 20: H_t = 4, G_t = -0.2696, σ_t^2 = 114.0768
# Epoch 146, Iteration 21: H_t = 10, G_t = 1.4587, σ_t^2 = 96.6868
# Epoch 146, Iteration 22: H_t = 4, G_t = -0.2228, σ_t^2 = 102.4623
# Epoch 146, Iteration 23: H_t = 4, G_t = -2.6193, σ_t^2 = 104.9474
# Epoch 146, Iteration 24: H_t = 4, G_t = 0.5438, σ_t^2 = 92.1525
# Epoch 146, Iteration 25: H_t = 4, G_t = 0.2248, σ_t^2 = 97.1076
# Epoch 146, Iteration 26: H_t = 7, G_t = 1.0908, σ_t^2 = 101.4799
# Epoch 146, Iteration 27: H_t = 4, G_t = -0.6318, σ_t^2 = 92.8842
# Epoch 146, Iteration 28: H_t = 4, G_t = -1.9933, σ_t^2 = 99.5403
# Epoch 146, Iteration 29: H_t = 21, G_t = 3.0290, σ_t^2 = 97.8802
# Epoch 146, Iteration 30: H_t = 5, G_t = 0.7573, σ_t^2 = 100.5766
#     Worker 0: Train Loss: 1.2226, Train Accuracy: 65.38%
#     Worker 1: Train Loss: 1.2170, Train Accuracy: 65.57%
#     Worker 2: Train Loss: 1.2099, Train Accuracy: 65.21%
#     Worker 3: Train Loss: 1.2258, Train Accuracy: 65.13%
# Epoch 146: Test Loss: 1.9490, Test Accuracy: 51.26%
# Total Computation Time: 3630.00 seconds
# Total Communication Time: 3.19 seconds
# Epoch 147, Iteration 1: H_t = 10, G_t = 1.4384, σ_t^2 = 93.4715
# Epoch 147, Iteration 2: H_t = 4, G_t = -2.7243, σ_t^2 = 100.1671
# Epoch 147, Iteration 3: H_t = 4, G_t = -3.2976, σ_t^2 = 100.4265
# Epoch 147, Iteration 4: H_t = 15, G_t = 2.1228, σ_t^2 = 97.9394
# Epoch 147, Iteration 5: H_t = 4, G_t = -0.1145, σ_t^2 = 108.3810
# Epoch 147, Iteration 6: H_t = 4, G_t = -1.6101, σ_t^2 = 114.0354
# Epoch 147, Iteration 7: H_t = 4, G_t = -2.4772, σ_t^2 = 110.5629
# Epoch 147, Iteration 8: H_t = 4, G_t = -0.9895, σ_t^2 = 99.1769
# Epoch 147, Iteration 9: H_t = 10, G_t = 1.6309, σ_t^2 = 108.0220
# Epoch 147, Iteration 10: H_t = 4, G_t = -2.6704, σ_t^2 = 92.3985
# Epoch 147, Iteration 11: H_t = 4, G_t = -1.3905, σ_t^2 = 88.6249
# Epoch 147, Iteration 12: H_t = 4, G_t = -1.5939, σ_t^2 = 113.0519
# Epoch 147, Iteration 13: H_t = 9, G_t = 1.4615, σ_t^2 = 108.0371
# Epoch 147, Iteration 14: H_t = 4, G_t = -2.2055, σ_t^2 = 97.6260
# Epoch 147, Iteration 15: H_t = 19, G_t = 2.8054, σ_t^2 = 102.2123
# Epoch 147, Iteration 16: H_t = 12, G_t = 1.9855, σ_t^2 = 109.0528
# Epoch 147, Iteration 17: H_t = 15, G_t = 1.8355, σ_t^2 = 85.3577
# Epoch 147, Iteration 18: H_t = 4, G_t = -1.6408, σ_t^2 = 113.2970
# Epoch 147, Iteration 19: H_t = 4, G_t = -1.2035, σ_t^2 = 95.0708
# Epoch 147, Iteration 20: H_t = 18, G_t = 2.1728, σ_t^2 = 83.5357
# Epoch 147, Iteration 21: H_t = 4, G_t = -4.2020, σ_t^2 = 109.7298
# Epoch 147, Iteration 22: H_t = 4, G_t = -0.6852, σ_t^2 = 91.5357
# Epoch 147, Iteration 23: H_t = 4, G_t = 0.7014, σ_t^2 = 104.4096
# Epoch 147, Iteration 24: H_t = 4, G_t = -1.0010, σ_t^2 = 116.2715
# Epoch 147, Iteration 25: H_t = 24, G_t = 3.4322, σ_t^2 = 99.0919
# Epoch 147, Iteration 26: H_t = 4, G_t = -4.4323, σ_t^2 = 114.3291
#     Worker 0: Train Loss: 1.2188, Train Accuracy: 64.91%
#     Worker 1: Train Loss: 1.2229, Train Accuracy: 65.29%
#     Worker 2: Train Loss: 1.2201, Train Accuracy: 65.71%
#     Worker 3: Train Loss: 1.2147, Train Accuracy: 65.68%
# Epoch 147: Test Loss: 1.9490, Test Accuracy: 51.23%
# Total Computation Time: 3653.78 seconds
# Total Communication Time: 3.21 seconds
# Epoch 148, Iteration 1: H_t = 4, G_t = 0.7018, σ_t^2 = 103.9680
# Epoch 148, Iteration 2: H_t = 4, G_t = -1.8054, σ_t^2 = 93.1686
# Epoch 148, Iteration 3: H_t = 4, G_t = -2.0306, σ_t^2 = 94.4599
# Epoch 148, Iteration 4: H_t = 14, G_t = 1.7941, σ_t^2 = 88.0463
# Epoch 148, Iteration 5: H_t = 7, G_t = 1.1016, σ_t^2 = 100.1375
# Epoch 148, Iteration 6: H_t = 7, G_t = 1.0855, σ_t^2 = 99.1070
# Epoch 148, Iteration 7: H_t = 4, G_t = -1.6663, σ_t^2 = 102.3693
# Epoch 148, Iteration 8: H_t = 4, G_t = -1.1945, σ_t^2 = 93.4531
# Epoch 148, Iteration 9: H_t = 4, G_t = -1.7430, σ_t^2 = 113.5837
# Epoch 148, Iteration 10: H_t = 4, G_t = 0.0421, σ_t^2 = 104.6520
# Epoch 148, Iteration 11: H_t = 4, G_t = -1.6375, σ_t^2 = 105.6522
# Epoch 148, Iteration 12: H_t = 13, G_t = 1.9863, σ_t^2 = 104.2792
# Epoch 148, Iteration 13: H_t = 5, G_t = 0.8878, σ_t^2 = 105.3036
# Epoch 148, Iteration 14: H_t = 4, G_t = -1.3390, σ_t^2 = 99.0753
# Epoch 148, Iteration 15: H_t = 4, G_t = 0.6592, σ_t^2 = 108.4332
# Epoch 148, Iteration 16: H_t = 19, G_t = 2.3396, σ_t^2 = 83.0514
# Epoch 148, Iteration 17: H_t = 4, G_t = -3.2345, σ_t^2 = 97.3877
# Epoch 148, Iteration 18: H_t = 28, G_t = 3.5617, σ_t^2 = 88.4532
# Epoch 148, Iteration 19: H_t = 4, G_t = 0.0681, σ_t^2 = 102.0457
# Epoch 148, Iteration 20: H_t = 4, G_t = -1.1639, σ_t^2 = 100.5955
# Epoch 148, Iteration 21: H_t = 15, G_t = 2.5307, σ_t^2 = 113.3316
# Epoch 148, Iteration 22: H_t = 12, G_t = 1.8847, σ_t^2 = 105.6235
# Epoch 148, Iteration 23: H_t = 4, G_t = -1.1706, σ_t^2 = 114.7606
# Epoch 148, Iteration 24: H_t = 4, G_t = -0.0661, σ_t^2 = 104.9789
# Epoch 148, Iteration 25: H_t = 8, G_t = 1.3939, σ_t^2 = 111.6472
# Epoch 148, Iteration 26: H_t = 17, G_t = 2.9742, σ_t^2 = 117.4564
# Epoch 148, Iteration 27: H_t = 13, G_t = 1.9727, σ_t^2 = 99.6974
#     Worker 0: Train Loss: 1.2285, Train Accuracy: 64.92%
#     Worker 1: Train Loss: 1.2194, Train Accuracy: 65.74%
#     Worker 2: Train Loss: 1.2051, Train Accuracy: 66.22%
#     Worker 3: Train Loss: 1.2325, Train Accuracy: 65.15%
# Epoch 148: Test Loss: 1.9490, Test Accuracy: 51.21%
# Total Computation Time: 3678.46 seconds
# Total Communication Time: 3.25 seconds
# Epoch 149, Iteration 1: H_t = 4, G_t = 0.0155, σ_t^2 = 104.0726
# Epoch 149, Iteration 2: H_t = 4, G_t = -2.8222, σ_t^2 = 107.8991
# Epoch 149, Iteration 3: H_t = 10, G_t = 1.5825, σ_t^2 = 106.1834
# Epoch 149, Iteration 4: H_t = 4, G_t = -0.1559, σ_t^2 = 98.9980
# Epoch 149, Iteration 5: H_t = 4, G_t = -1.0465, σ_t^2 = 90.2406
# Epoch 149, Iteration 6: H_t = 4, G_t = -0.4634, σ_t^2 = 98.1000
# Epoch 149, Iteration 7: H_t = 4, G_t = -0.1137, σ_t^2 = 90.5323
# Epoch 149, Iteration 8: H_t = 5, G_t = 0.7198, σ_t^2 = 96.7965
# Epoch 149, Iteration 9: H_t = 21, G_t = 3.2532, σ_t^2 = 106.5558
# Epoch 149, Iteration 10: H_t = 4, G_t = -2.2466, σ_t^2 = 104.1445
# Epoch 149, Iteration 11: H_t = 4, G_t = -0.2969, σ_t^2 = 100.6263
# Epoch 149, Iteration 12: H_t = 4, G_t = -0.3469, σ_t^2 = 100.4333
# Epoch 149, Iteration 13: H_t = 6, G_t = 0.9200, σ_t^2 = 106.6928
# Epoch 149, Iteration 14: H_t = 4, G_t = -2.7424, σ_t^2 = 95.6522
# Epoch 149, Iteration 15: H_t = 4, G_t = 0.2105, σ_t^2 = 95.3159
# Epoch 149, Iteration 16: H_t = 4, G_t = -0.1809, σ_t^2 = 99.3470
# Epoch 149, Iteration 17: H_t = 4, G_t = 0.5568, σ_t^2 = 102.9173
# Epoch 149, Iteration 18: H_t = 4, G_t = 0.0773, σ_t^2 = 104.6313
# Epoch 149, Iteration 19: H_t = 5, G_t = 0.8218, σ_t^2 = 112.7346
# Epoch 149, Iteration 20: H_t = 4, G_t = -1.1491, σ_t^2 = 96.8218
# Epoch 149, Iteration 21: H_t = 4, G_t = -0.6358, σ_t^2 = 98.3304
# Epoch 149, Iteration 22: H_t = 4, G_t = -2.3702, σ_t^2 = 98.4881
# Epoch 149, Iteration 23: H_t = 4, G_t = -1.2017, σ_t^2 = 105.2276
# Epoch 149, Iteration 24: H_t = 4, G_t = -0.9176, σ_t^2 = 97.0956
# Epoch 149, Iteration 25: H_t = 6, G_t = 0.8711, σ_t^2 = 94.8442
# Epoch 149, Iteration 26: H_t = 7, G_t = 1.0983, σ_t^2 = 101.6128
# Epoch 149, Iteration 27: H_t = 10, G_t = 1.5155, σ_t^2 = 105.3399
# Epoch 149, Iteration 28: H_t = 4, G_t = -0.4223, σ_t^2 = 98.4492
# Epoch 149, Iteration 29: H_t = 4, G_t = -0.6113, σ_t^2 = 102.7409
# Epoch 149, Iteration 30: H_t = 4, G_t = -0.5307, σ_t^2 = 99.6241
# Epoch 149, Iteration 31: H_t = 4, G_t = -1.9247, σ_t^2 = 108.4554
# Epoch 149, Iteration 32: H_t = 4, G_t = -1.2780, σ_t^2 = 107.8372
# Epoch 149, Iteration 33: H_t = 4, G_t = -0.5013, σ_t^2 = 95.0746
# Epoch 149, Iteration 34: H_t = 4, G_t = -1.7774, σ_t^2 = 105.6903
# Epoch 149, Iteration 35: H_t = 4, G_t = 0.1028, σ_t^2 = 82.7585
# Epoch 149, Iteration 36: H_t = 4, G_t = -1.6489, σ_t^2 = 105.3460
# Epoch 149, Iteration 37: H_t = 4, G_t = -0.7793, σ_t^2 = 85.8481
# Epoch 149, Iteration 38: H_t = 6, G_t = 0.8828, σ_t^2 = 102.8829
#     Worker 0: Train Loss: 1.2087, Train Accuracy: 65.63%
#     Worker 1: Train Loss: 1.2191, Train Accuracy: 65.46%
#     Worker 2: Train Loss: 1.2145, Train Accuracy: 65.64%
#     Worker 3: Train Loss: 1.2268, Train Accuracy: 65.43%
# Epoch 149: Test Loss: 1.9490, Test Accuracy: 51.19%
# Total Computation Time: 3702.24 seconds
# Total Communication Time: 3.29 seconds
# Epoch 150, Iteration 1: H_t = 4, G_t = -1.9927, σ_t^2 = 106.5130
# Epoch 150, Iteration 2: H_t = 4, G_t = -1.9496, σ_t^2 = 106.3005
# Epoch 150, Iteration 3: H_t = 20, G_t = 2.7803, σ_t^2 = 97.1977
# Epoch 150, Iteration 4: H_t = 4, G_t = -0.8291, σ_t^2 = 111.3720
# Epoch 150, Iteration 5: H_t = 4, G_t = -2.3163, σ_t^2 = 107.9674
# Epoch 150, Iteration 6: H_t = 4, G_t = -2.3636, σ_t^2 = 106.7454
# Epoch 150, Iteration 7: H_t = 4, G_t = -0.4480, σ_t^2 = 86.6784
# Epoch 150, Iteration 8: H_t = 4, G_t = -1.4185, σ_t^2 = 116.6952
# Epoch 150, Iteration 9: H_t = 8, G_t = 1.0506, σ_t^2 = 84.3324
# Epoch 150, Iteration 10: H_t = 4, G_t = -1.9859, σ_t^2 = 91.3441
# Epoch 150, Iteration 11: H_t = 4, G_t = 0.5825, σ_t^2 = 98.0138
# Epoch 150, Iteration 12: H_t = 4, G_t = -2.7363, σ_t^2 = 118.9628
# Epoch 150, Iteration 13: H_t = 4, G_t = -3.0006, σ_t^2 = 99.7555
# Epoch 150, Iteration 14: H_t = 4, G_t = -4.8269, σ_t^2 = 106.5093
# Epoch 150, Iteration 15: H_t = 11, G_t = 1.4818, σ_t^2 = 93.0462
# Epoch 150, Iteration 16: H_t = 4, G_t = -1.9801, σ_t^2 = 101.7982
# Epoch 150, Iteration 17: H_t = 12, G_t = 1.8923, σ_t^2 = 107.7341
# Epoch 150, Iteration 18: H_t = 4, G_t = 0.0619, σ_t^2 = 97.0368
# Epoch 150, Iteration 19: H_t = 13, G_t = 2.5379, σ_t^2 = 129.5777
# Epoch 150, Iteration 20: H_t = 4, G_t = -1.0719, σ_t^2 = 104.2358
# Epoch 150, Iteration 21: H_t = 4, G_t = -2.0351, σ_t^2 = 95.4969
# Epoch 150, Iteration 22: H_t = 13, G_t = 2.0471, σ_t^2 = 107.0991
# Epoch 150, Iteration 23: H_t = 4, G_t = -1.0219, σ_t^2 = 102.1174
# Epoch 150, Iteration 24: H_t = 4, G_t = -0.1026, σ_t^2 = 105.0226
# Epoch 150, Iteration 25: H_t = 13, G_t = 1.9600, σ_t^2 = 102.6860
# Epoch 150, Iteration 26: H_t = 5, G_t = 0.8431, σ_t^2 = 117.4060
# Epoch 150, Iteration 27: H_t = 4, G_t = -0.8064, σ_t^2 = 103.2400
# Epoch 150, Iteration 28: H_t = 4, G_t = 0.1834, σ_t^2 = 104.6258
# Epoch 150, Iteration 29: H_t = 4, G_t = -2.1702, σ_t^2 = 326.4493
# Epoch 150, Iteration 30: H_t = 4, G_t = 0.6091, σ_t^2 = 99.6018
# Epoch 150, Iteration 31: H_t = 4, G_t = -1.8270, σ_t^2 = 114.7431
# Epoch 150, Iteration 32: H_t = 4, G_t = -1.1368, σ_t^2 = 106.0302
# Epoch 150, Iteration 33: H_t = 28, G_t = 4.1260, σ_t^2 = 100.8849
#     Worker 0: Train Loss: 1.2218, Train Accuracy: 65.13%
#     Worker 1: Train Loss: 1.2209, Train Accuracy: 65.59%
#     Worker 2: Train Loss: 1.2104, Train Accuracy: 65.83%
#     Worker 3: Train Loss: 1.2149, Train Accuracy: 65.64%
# Epoch 150: Test Loss: 1.9490, Test Accuracy: 51.19%
# Total Computation Time: 3725.85 seconds
# Total Communication Time: 3.33 seconds
