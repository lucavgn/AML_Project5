# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files
import torch.nn.functional as F

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
global_iteration_per_epoch = 782 # to be divided by K*J
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
#warmup_epochs = 5

def compute_mean_std(dataset):
    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Compute gradient magnitude and variance
def compute_gradient_stats(nets, optimizers):
    # Get gradients from each worker
    gradients = []
    for net, optimizer in zip(nets, optimizers):
        grad_vector = []
        for param in net.parameters():
            if param.grad is not None:
                grad_vector.append(param.grad.view(-1))
        grad_vector = torch.cat(grad_vector)  # Flatten all gradients into a vector
        gradients.append(grad_vector)
    
    # Compute average gradient (g_t)
    avg_gradient = torch.stack(gradients).mean(dim=0)

    # Compute squared norms of individual gradients
    squared_norms = [torch.norm(g).item() ** 2 for g in gradients]

    # Compute squared norm of the average gradient
    avg_squared_norm = torch.norm(avg_gradient).item() ** 2

    # Compute gradient variance (sigma_t^2) using the provided formula
    sigma_t_squared = (sum(squared_norms) / (K - 1)) - (K / (K - 1)) * avg_squared_norm

    # Compute gradient magnitude (G_t) using the provided formula
    G_t = avg_squared_norm - (1 / K) * sigma_t_squared

    return G_t, sigma_t_squared


# Update H dynamically based on gradient stats
def update_H(G_t, sigma_t_squared, H_min, H_max, alpha, epsilon):
    H_t = min(H_max, max(H_min, alpha * G_t / (sigma_t_squared + epsilon)))
    H_t = min(H_t, H_max)  # Ensure H_t doesn't exceed H_max
    return int(H_t)  # Ensure H_t is an integer

# Training loop
# Hyperparameters for dynamic adjustment
H_min, H_max = 1, 16  # Minimum and maximum allowed local steps
alpha, epsilon = 15.0, 1e-6  # Scaling factor and small constant

H_t = J  # Initialize H_t with the default J value

for epoch in range(num_epochs):
    #print(f"Epoch {epoch + 1}/{num_epochs}:")
    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]

    for iteration in range(global_iteration_per_epoch):
        # Train each worker for H_t steps
        for k in range(K):
            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            for _ in range(H_t):  # Perform H_t local steps
                try:
                    images, labels = next(shard_iterators[k])
                except StopIteration:
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k])
                images, labels = images.to(device), labels.to(device)

                optimizers[k].zero_grad()
                outputs = nets[k](images)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizers[k].step()

                # Calculate train loss and accuracy
                train_loss += loss.item() * labels.size(0)
                _, predicted = outputs.max(1)
                total_train += labels.size(0)
                correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        # Synchronize models
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

        # Compute gradient stats and update H_t
        G_t, sigma_t_squared = compute_gradient_stats(nets, optimizers)
        H_t = update_H(G_t, sigma_t_squared, H_min, H_max, alpha, epsilon)
         print(f"Epoch {epoch+1}, Iteration {iteration+1}: H_t = {H_t}, G_t = {G_t:.4f}, σ_t^2 = {sigma_t_squared:.4f}")
    
    # Store training metrics for all workers after each epoch
    for k in range(K):
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(accuracy)
        print(f"    Worker {k}: Train Loss: {train_loss_for_iteration[k]:.4f}, Train Accuracy: {accuracy:.2f}%")


    # Update learning rate
    for scheduler in schedulers:
        scheduler.step()

    # Evaluate on test set
    global_model = nets[0]
    global_model.eval()
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()

    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)
    print(f"Epoch {epoch + 1}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")





# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Overwriting localSGD.py

# %%
# %run localSGD.py --k 4 --j 8
# Out:
# Training with K=4, J=8
# Global iteration per epoch: 25
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00400
# Epoch 1/150:
#     Worker 0: Train Loss: 4.6039, Train Accuracy: 0.87%
#     Worker 1: Train Loss: 4.6058, Train Accuracy: 0.92%
#     Worker 2: Train Loss: 4.6031, Train Accuracy: 0.87%
#     Worker 3: Train Loss: 4.6044, Train Accuracy: 0.73%
# Epoch 1: Test Loss: 4.6008, Test Accuracy: 1.14%
# Epoch 2/150:
#     Worker 0: Train Loss: 4.5959, Train Accuracy: 1.84%
#     Worker 1: Train Loss: 4.5953, Train Accuracy: 1.94%
#     Worker 2: Train Loss: 4.5961, Train Accuracy: 1.60%
#     Worker 3: Train Loss: 4.5960, Train Accuracy: 1.87%
# Epoch 2: Test Loss: 4.5862, Test Accuracy: 3.02%
# Epoch 3/150:
#     Worker 0: Train Loss: 4.5627, Train Accuracy: 2.74%
#     Worker 1: Train Loss: 4.5621, Train Accuracy: 2.31%
#     Worker 2: Train Loss: 4.5571, Train Accuracy: 2.82%
#     Worker 3: Train Loss: 4.5630, Train Accuracy: 3.23%
# Epoch 3: Test Loss: 4.5120, Test Accuracy: 3.65%
# Epoch 4/150:
#     Worker 0: Train Loss: 4.4244, Train Accuracy: 3.82%
#     Worker 1: Train Loss: 4.4286, Train Accuracy: 4.14%
#     Worker 2: Train Loss: 4.4079, Train Accuracy: 4.45%
#     Worker 3: Train Loss: 4.4223, Train Accuracy: 4.29%
# Epoch 4: Test Loss: 4.2673, Test Accuracy: 6.18%
# Epoch 5/150:
#     Worker 0: Train Loss: 4.1956, Train Accuracy: 6.30%
#     Worker 1: Train Loss: 4.2124, Train Accuracy: 6.49%
#     Worker 2: Train Loss: 4.1794, Train Accuracy: 6.67%
#     Worker 3: Train Loss: 4.2087, Train Accuracy: 5.87%
# Epoch 5: Test Loss: 4.0873, Test Accuracy: 7.36%
# Epoch 6/150:
#     Worker 0: Train Loss: 4.1013, Train Accuracy: 6.99%
#     Worker 1: Train Loss: 4.1015, Train Accuracy: 7.24%
#     Worker 2: Train Loss: 4.0548, Train Accuracy: 7.32%
#     Worker 3: Train Loss: 4.0887, Train Accuracy: 7.81%
# Epoch 6: Test Loss: 3.9899, Test Accuracy: 9.23%
# Epoch 7/150:
#     Worker 0: Train Loss: 3.9853, Train Accuracy: 8.50%
#     Worker 1: Train Loss: 4.0042, Train Accuracy: 8.43%
#     Worker 2: Train Loss: 3.9620, Train Accuracy: 8.98%
#     Worker 3: Train Loss: 4.0212, Train Accuracy: 8.75%
# Epoch 7: Test Loss: 3.9006, Test Accuracy: 10.76%
# Epoch 8/150:
#     Worker 0: Train Loss: 3.9292, Train Accuracy: 9.49%
#     Worker 1: Train Loss: 3.9282, Train Accuracy: 10.36%
#     Worker 2: Train Loss: 3.8897, Train Accuracy: 10.31%
#     Worker 3: Train Loss: 3.9188, Train Accuracy: 9.82%
# Epoch 8: Test Loss: 3.8238, Test Accuracy: 11.95%
# Epoch 9/150:
#     Worker 0: Train Loss: 3.8742, Train Accuracy: 11.08%
#     Worker 1: Train Loss: 3.8726, Train Accuracy: 10.62%
#     Worker 2: Train Loss: 3.8306, Train Accuracy: 11.35%
#     Worker 3: Train Loss: 3.8647, Train Accuracy: 10.32%
# Epoch 9: Test Loss: 3.7873, Test Accuracy: 12.33%
# Epoch 10/150:
#     Worker 0: Train Loss: 3.8312, Train Accuracy: 11.45%
#     Worker 1: Train Loss: 3.8076, Train Accuracy: 12.73%
#     Worker 2: Train Loss: 3.7845, Train Accuracy: 12.14%
#     Worker 3: Train Loss: 3.8196, Train Accuracy: 11.45%
# Epoch 10: Test Loss: 3.7085, Test Accuracy: 14.31%
# Epoch 11/150:
#     Worker 0: Train Loss: 3.7947, Train Accuracy: 12.07%
#     Worker 1: Train Loss: 3.7862, Train Accuracy: 12.44%
#     Worker 2: Train Loss: 3.7021, Train Accuracy: 13.34%
#     Worker 3: Train Loss: 3.7734, Train Accuracy: 12.51%
# Epoch 11: Test Loss: 3.6673, Test Accuracy: 14.75%
# Epoch 12/150:
#     Worker 0: Train Loss: 3.6973, Train Accuracy: 13.15%
#     Worker 1: Train Loss: 3.6924, Train Accuracy: 14.06%
#     Worker 2: Train Loss: 3.6788, Train Accuracy: 13.83%
#     Worker 3: Train Loss: 3.7232, Train Accuracy: 13.46%
# Epoch 12: Test Loss: 3.6251, Test Accuracy: 14.83%
# Epoch 13/150:
#     Worker 0: Train Loss: 3.6504, Train Accuracy: 14.45%
#     Worker 1: Train Loss: 3.6769, Train Accuracy: 13.46%
#     Worker 2: Train Loss: 3.6150, Train Accuracy: 15.44%
#     Worker 3: Train Loss: 3.6398, Train Accuracy: 14.52%
# Epoch 13: Test Loss: 3.5529, Test Accuracy: 16.69%
# Epoch 14/150:
#     Worker 0: Train Loss: 3.5915, Train Accuracy: 15.33%
#     Worker 1: Train Loss: 3.6156, Train Accuracy: 15.06%
#     Worker 2: Train Loss: 3.5419, Train Accuracy: 16.35%
#     Worker 3: Train Loss: 3.6089, Train Accuracy: 14.59%
# Epoch 14: Test Loss: 3.5051, Test Accuracy: 17.09%
# Epoch 15/150:
#     Worker 0: Train Loss: 3.5812, Train Accuracy: 15.74%
#     Worker 1: Train Loss: 3.5675, Train Accuracy: 16.22%
#     Worker 2: Train Loss: 3.5344, Train Accuracy: 16.47%
#     Worker 3: Train Loss: 3.5992, Train Accuracy: 15.52%
# Epoch 15: Test Loss: 3.4580, Test Accuracy: 18.55%
# Epoch 16/150:
#     Worker 0: Train Loss: 3.5245, Train Accuracy: 16.08%
#     Worker 1: Train Loss: 3.5452, Train Accuracy: 16.13%
#     Worker 2: Train Loss: 3.4875, Train Accuracy: 17.22%
#     Worker 3: Train Loss: 3.5375, Train Accuracy: 16.02%
# Epoch 16: Test Loss: 3.4366, Test Accuracy: 18.90%
# Epoch 17/150:
#     Worker 0: Train Loss: 3.4982, Train Accuracy: 16.13%
#     Worker 1: Train Loss: 3.5027, Train Accuracy: 16.97%
#     Worker 2: Train Loss: 3.4040, Train Accuracy: 19.07%
#     Worker 3: Train Loss: 3.4994, Train Accuracy: 16.51%
# Epoch 17: Test Loss: 3.3699, Test Accuracy: 19.91%
# Epoch 18/150:
#     Worker 0: Train Loss: 3.4079, Train Accuracy: 17.45%
#     Worker 1: Train Loss: 3.4400, Train Accuracy: 17.91%
#     Worker 2: Train Loss: 3.3980, Train Accuracy: 19.09%
#     Worker 3: Train Loss: 3.4365, Train Accuracy: 17.90%
# Epoch 18: Test Loss: 3.3232, Test Accuracy: 20.68%
# Epoch 19/150:
#     Worker 0: Train Loss: 3.4194, Train Accuracy: 18.48%
#     Worker 1: Train Loss: 3.4056, Train Accuracy: 19.21%
#     Worker 2: Train Loss: 3.3459, Train Accuracy: 19.70%
#     Worker 3: Train Loss: 3.4221, Train Accuracy: 18.20%
# Epoch 19: Test Loss: 3.3064, Test Accuracy: 21.23%
# Epoch 20/150:
#     Worker 0: Train Loss: 3.3592, Train Accuracy: 18.65%
#     Worker 1: Train Loss: 3.3629, Train Accuracy: 19.58%
#     Worker 2: Train Loss: 3.3040, Train Accuracy: 20.21%
#     Worker 3: Train Loss: 3.3504, Train Accuracy: 19.50%
# Epoch 20: Test Loss: 3.2690, Test Accuracy: 21.64%
# Epoch 21/150:
#     Worker 0: Train Loss: 3.3218, Train Accuracy: 20.07%
#     Worker 1: Train Loss: 3.3182, Train Accuracy: 20.05%
#     Worker 2: Train Loss: 3.2755, Train Accuracy: 21.16%
#     Worker 3: Train Loss: 3.3291, Train Accuracy: 20.05%
# Epoch 21: Test Loss: 3.2065, Test Accuracy: 22.28%
# Epoch 22/150:
#     Worker 0: Train Loss: 3.2545, Train Accuracy: 20.96%
#     Worker 1: Train Loss: 3.2866, Train Accuracy: 20.46%
#     Worker 2: Train Loss: 3.2570, Train Accuracy: 20.84%
#     Worker 3: Train Loss: 3.2877, Train Accuracy: 20.41%
# Epoch 22: Test Loss: 3.1694, Test Accuracy: 23.21%
# Epoch 23/150:
#     Worker 0: Train Loss: 3.2545, Train Accuracy: 20.43%
#     Worker 1: Train Loss: 3.2394, Train Accuracy: 21.41%
#     Worker 2: Train Loss: 3.1861, Train Accuracy: 22.39%
#     Worker 3: Train Loss: 3.2502, Train Accuracy: 21.24%
# Epoch 23: Test Loss: 3.1409, Test Accuracy: 24.34%
# Epoch 24/150:
#     Worker 0: Train Loss: 3.1759, Train Accuracy: 21.72%
#     Worker 1: Train Loss: 3.1967, Train Accuracy: 22.98%
#     Worker 2: Train Loss: 3.1267, Train Accuracy: 23.11%
#     Worker 3: Train Loss: 3.1849, Train Accuracy: 21.96%
# Epoch 24: Test Loss: 3.1006, Test Accuracy: 24.82%
# Epoch 25/150:
#     Worker 0: Train Loss: 3.1647, Train Accuracy: 22.58%
#     Worker 1: Train Loss: 3.1824, Train Accuracy: 22.43%
#     Worker 2: Train Loss: 3.1270, Train Accuracy: 23.08%
#     Worker 3: Train Loss: 3.1542, Train Accuracy: 22.94%
# Epoch 25: Test Loss: 3.0497, Test Accuracy: 25.23%
# Epoch 26/150:
#     Worker 0: Train Loss: 3.1506, Train Accuracy: 22.37%
#     Worker 1: Train Loss: 3.1507, Train Accuracy: 22.61%
#     Worker 2: Train Loss: 3.0981, Train Accuracy: 24.80%
#     Worker 3: Train Loss: 3.1542, Train Accuracy: 22.84%
# Epoch 26: Test Loss: 3.0188, Test Accuracy: 25.93%
# Epoch 27/150:
#     Worker 0: Train Loss: 3.0888, Train Accuracy: 24.21%
#     Worker 1: Train Loss: 3.1542, Train Accuracy: 23.16%
#     Worker 2: Train Loss: 3.0731, Train Accuracy: 24.40%
#     Worker 3: Train Loss: 3.1360, Train Accuracy: 22.89%
# Epoch 27: Test Loss: 2.9931, Test Accuracy: 26.20%
# Epoch 28/150:
#     Worker 0: Train Loss: 3.1037, Train Accuracy: 23.68%
#     Worker 1: Train Loss: 3.1116, Train Accuracy: 24.40%
#     Worker 2: Train Loss: 3.0596, Train Accuracy: 25.17%
#     Worker 3: Train Loss: 3.0582, Train Accuracy: 24.40%
# Epoch 28: Test Loss: 2.9621, Test Accuracy: 26.81%
# Epoch 29/150:
#     Worker 0: Train Loss: 3.0285, Train Accuracy: 25.55%
#     Worker 1: Train Loss: 3.0715, Train Accuracy: 24.29%
#     Worker 2: Train Loss: 2.9996, Train Accuracy: 26.88%
#     Worker 3: Train Loss: 3.0760, Train Accuracy: 24.75%
# Epoch 29: Test Loss: 2.9178, Test Accuracy: 28.28%
# Epoch 30/150:
#     Worker 0: Train Loss: 3.0077, Train Accuracy: 25.74%
#     Worker 1: Train Loss: 3.0215, Train Accuracy: 25.69%
#     Worker 2: Train Loss: 2.9701, Train Accuracy: 26.93%
#     Worker 3: Train Loss: 3.0549, Train Accuracy: 25.05%
# Epoch 30: Test Loss: 2.9261, Test Accuracy: 27.99%
# Epoch 31/150:
#     Worker 0: Train Loss: 2.9988, Train Accuracy: 25.96%
#     Worker 1: Train Loss: 3.0405, Train Accuracy: 25.16%
#     Worker 2: Train Loss: 2.9800, Train Accuracy: 26.39%
#     Worker 3: Train Loss: 3.0178, Train Accuracy: 25.82%
# Epoch 31: Test Loss: 2.8767, Test Accuracy: 28.53%
# Epoch 32/150:
#     Worker 0: Train Loss: 2.9702, Train Accuracy: 26.35%
#     Worker 1: Train Loss: 2.9861, Train Accuracy: 26.16%
#     Worker 2: Train Loss: 2.9250, Train Accuracy: 27.47%
#     Worker 3: Train Loss: 2.9402, Train Accuracy: 27.06%
# Epoch 32: Test Loss: 2.8651, Test Accuracy: 29.35%
# Epoch 33/150:
#     Worker 0: Train Loss: 2.9481, Train Accuracy: 26.30%
#     Worker 1: Train Loss: 2.9752, Train Accuracy: 25.97%
#     Worker 2: Train Loss: 2.9160, Train Accuracy: 28.37%
#     Worker 3: Train Loss: 2.9688, Train Accuracy: 26.42%
# Epoch 33: Test Loss: 2.8170, Test Accuracy: 29.65%
# Epoch 34/150:
#     Worker 0: Train Loss: 2.9002, Train Accuracy: 27.68%
#     Worker 1: Train Loss: 2.9110, Train Accuracy: 27.51%
#     Worker 2: Train Loss: 2.8864, Train Accuracy: 28.01%
#     Worker 3: Train Loss: 2.9468, Train Accuracy: 27.04%
# Epoch 34: Test Loss: 2.8088, Test Accuracy: 29.97%
# Epoch 35/150:
#     Worker 0: Train Loss: 2.9197, Train Accuracy: 27.72%
#     Worker 1: Train Loss: 2.9490, Train Accuracy: 27.19%
#     Worker 2: Train Loss: 2.8875, Train Accuracy: 27.97%
#     Worker 3: Train Loss: 2.9014, Train Accuracy: 27.20%
# Epoch 35: Test Loss: 2.7997, Test Accuracy: 30.12%
# Epoch 36/150:
#     Worker 0: Train Loss: 2.8620, Train Accuracy: 27.93%
#     Worker 1: Train Loss: 2.8689, Train Accuracy: 28.69%
#     Worker 2: Train Loss: 2.8382, Train Accuracy: 29.82%
#     Worker 3: Train Loss: 2.9084, Train Accuracy: 27.35%
# Epoch 36: Test Loss: 2.7585, Test Accuracy: 31.21%
# Epoch 37/150:
#     Worker 0: Train Loss: 2.8297, Train Accuracy: 28.64%
#     Worker 1: Train Loss: 2.9046, Train Accuracy: 27.99%
#     Worker 2: Train Loss: 2.8337, Train Accuracy: 29.43%
#     Worker 3: Train Loss: 2.8525, Train Accuracy: 28.81%
# Epoch 37: Test Loss: 2.7395, Test Accuracy: 31.24%
# Epoch 38/150:
#     Worker 0: Train Loss: 2.8401, Train Accuracy: 28.27%
#     Worker 1: Train Loss: 2.8618, Train Accuracy: 27.90%
#     Worker 2: Train Loss: 2.8309, Train Accuracy: 28.93%
#     Worker 3: Train Loss: 2.8651, Train Accuracy: 28.60%
# Epoch 38: Test Loss: 2.7412, Test Accuracy: 31.79%
# Epoch 39/150:
#     Worker 0: Train Loss: 2.8065, Train Accuracy: 29.69%
#     Worker 1: Train Loss: 2.8368, Train Accuracy: 29.36%
#     Worker 2: Train Loss: 2.7655, Train Accuracy: 29.90%
#     Worker 3: Train Loss: 2.7914, Train Accuracy: 29.72%
# Epoch 39: Test Loss: 2.7189, Test Accuracy: 32.22%
# Epoch 40/150:
#     Worker 0: Train Loss: 2.7897, Train Accuracy: 30.30%
#     Worker 1: Train Loss: 2.8199, Train Accuracy: 29.14%
#     Worker 2: Train Loss: 2.7785, Train Accuracy: 30.24%
#     Worker 3: Train Loss: 2.7835, Train Accuracy: 29.64%
# Epoch 40: Test Loss: 2.6831, Test Accuracy: 32.12%
# Epoch 41/150:
#     Worker 0: Train Loss: 2.7480, Train Accuracy: 30.82%
#     Worker 1: Train Loss: 2.7736, Train Accuracy: 30.32%
#     Worker 2: Train Loss: 2.7523, Train Accuracy: 31.53%
#     Worker 3: Train Loss: 2.7790, Train Accuracy: 29.57%
# Epoch 41: Test Loss: 2.6844, Test Accuracy: 32.64%
# Epoch 42/150:
#     Worker 0: Train Loss: 2.7408, Train Accuracy: 30.64%
#     Worker 1: Train Loss: 2.8005, Train Accuracy: 29.72%
#     Worker 2: Train Loss: 2.7003, Train Accuracy: 32.18%
#     Worker 3: Train Loss: 2.7617, Train Accuracy: 30.55%
# Epoch 42: Test Loss: 2.6364, Test Accuracy: 33.63%
# Epoch 43/150:
#     Worker 0: Train Loss: 2.7193, Train Accuracy: 31.51%
#     Worker 1: Train Loss: 2.7503, Train Accuracy: 31.35%
#     Worker 2: Train Loss: 2.7070, Train Accuracy: 32.20%
#     Worker 3: Train Loss: 2.7640, Train Accuracy: 30.65%
# Epoch 43: Test Loss: 2.6444, Test Accuracy: 33.05%
# Epoch 44/150:
#     Worker 0: Train Loss: 2.7214, Train Accuracy: 31.05%
#     Worker 1: Train Loss: 2.7444, Train Accuracy: 30.46%
#     Worker 2: Train Loss: 2.6695, Train Accuracy: 32.83%
#     Worker 3: Train Loss: 2.7102, Train Accuracy: 31.11%
# Epoch 44: Test Loss: 2.6103, Test Accuracy: 34.12%
# Epoch 45/150:
#     Worker 0: Train Loss: 2.6813, Train Accuracy: 31.87%
#     Worker 1: Train Loss: 2.7059, Train Accuracy: 31.78%
#     Worker 2: Train Loss: 2.6423, Train Accuracy: 33.14%
#     Worker 3: Train Loss: 2.6859, Train Accuracy: 32.76%
# Epoch 45: Test Loss: 2.5974, Test Accuracy: 34.04%
# Epoch 46/150:
#     Worker 0: Train Loss: 2.6409, Train Accuracy: 32.39%
#     Worker 1: Train Loss: 2.6879, Train Accuracy: 31.92%
#     Worker 2: Train Loss: 2.6339, Train Accuracy: 33.46%
#     Worker 3: Train Loss: 2.6501, Train Accuracy: 32.59%
# Epoch 46: Test Loss: 2.5617, Test Accuracy: 35.10%
# Epoch 47/150:
#     Worker 0: Train Loss: 2.6331, Train Accuracy: 32.81%
#     Worker 1: Train Loss: 2.6527, Train Accuracy: 32.47%
#     Worker 2: Train Loss: 2.6001, Train Accuracy: 34.13%
#     Worker 3: Train Loss: 2.6382, Train Accuracy: 32.89%
# Epoch 47: Test Loss: 2.5303, Test Accuracy: 35.23%
# Epoch 48/150:
#     Worker 0: Train Loss: 2.5945, Train Accuracy: 34.19%
#     Worker 1: Train Loss: 2.6151, Train Accuracy: 33.32%
#     Worker 2: Train Loss: 2.5922, Train Accuracy: 33.63%
#     Worker 3: Train Loss: 2.6328, Train Accuracy: 32.47%
# Epoch 48: Test Loss: 2.5294, Test Accuracy: 35.74%
# Epoch 49/150:
#     Worker 0: Train Loss: 2.6062, Train Accuracy: 33.55%
#     Worker 1: Train Loss: 2.6283, Train Accuracy: 33.17%
#     Worker 2: Train Loss: 2.5789, Train Accuracy: 34.63%
#     Worker 3: Train Loss: 2.6090, Train Accuracy: 33.65%
# Epoch 49: Test Loss: 2.5221, Test Accuracy: 35.92%
# Epoch 50/150:
#     Worker 0: Train Loss: 2.5938, Train Accuracy: 33.86%
#     Worker 1: Train Loss: 2.5967, Train Accuracy: 33.93%
#     Worker 2: Train Loss: 2.5481, Train Accuracy: 34.05%
#     Worker 3: Train Loss: 2.5841, Train Accuracy: 33.92%
# Epoch 50: Test Loss: 2.5223, Test Accuracy: 35.63%
# Epoch 51/150:
#     Worker 0: Train Loss: 2.5629, Train Accuracy: 34.43%
#     Worker 1: Train Loss: 2.5425, Train Accuracy: 35.03%
#     Worker 2: Train Loss: 2.5447, Train Accuracy: 35.51%
#     Worker 3: Train Loss: 2.5391, Train Accuracy: 35.01%
# Epoch 51: Test Loss: 2.4987, Test Accuracy: 36.32%
# Epoch 52/150:
#     Worker 0: Train Loss: 2.5518, Train Accuracy: 34.93%
#     Worker 1: Train Loss: 2.5883, Train Accuracy: 34.69%
#     Worker 2: Train Loss: 2.5466, Train Accuracy: 34.62%
#     Worker 3: Train Loss: 2.6003, Train Accuracy: 33.66%
# Epoch 52: Test Loss: 2.4761, Test Accuracy: 37.08%
# Epoch 53/150:
#     Worker 0: Train Loss: 2.5248, Train Accuracy: 34.77%
#     Worker 1: Train Loss: 2.5438, Train Accuracy: 35.41%
#     Worker 2: Train Loss: 2.5299, Train Accuracy: 34.79%
#     Worker 3: Train Loss: 2.5304, Train Accuracy: 35.34%
# Epoch 53: Test Loss: 2.4518, Test Accuracy: 37.73%
# Epoch 54/150:
#     Worker 0: Train Loss: 2.5327, Train Accuracy: 34.96%
#     Worker 1: Train Loss: 2.5560, Train Accuracy: 34.47%
#     Worker 2: Train Loss: 2.4515, Train Accuracy: 36.45%
#     Worker 3: Train Loss: 2.5303, Train Accuracy: 35.65%
# Epoch 54: Test Loss: 2.4861, Test Accuracy: 36.29%
# Epoch 55/150:
#     Worker 0: Train Loss: 2.4994, Train Accuracy: 35.86%
#     Worker 1: Train Loss: 2.5235, Train Accuracy: 36.24%
#     Worker 2: Train Loss: 2.5022, Train Accuracy: 36.33%
#     Worker 3: Train Loss: 2.5143, Train Accuracy: 35.05%
# Epoch 55: Test Loss: 2.4345, Test Accuracy: 37.30%
# Epoch 56/150:
#     Worker 0: Train Loss: 2.5031, Train Accuracy: 36.17%
#     Worker 1: Train Loss: 2.5426, Train Accuracy: 35.58%
#     Worker 2: Train Loss: 2.4812, Train Accuracy: 36.84%
#     Worker 3: Train Loss: 2.5249, Train Accuracy: 35.50%
# Epoch 56: Test Loss: 2.4467, Test Accuracy: 37.32%
# Epoch 57/150:
#     Worker 0: Train Loss: 2.4763, Train Accuracy: 36.05%
#     Worker 1: Train Loss: 2.4706, Train Accuracy: 36.60%
#     Worker 2: Train Loss: 2.4646, Train Accuracy: 36.64%
#     Worker 3: Train Loss: 2.4843, Train Accuracy: 35.52%
# Epoch 57: Test Loss: 2.4308, Test Accuracy: 37.96%
# Epoch 58/150:
#     Worker 0: Train Loss: 2.4745, Train Accuracy: 36.74%
#     Worker 1: Train Loss: 2.5205, Train Accuracy: 35.08%
#     Worker 2: Train Loss: 2.4577, Train Accuracy: 37.66%
#     Worker 3: Train Loss: 2.4749, Train Accuracy: 35.61%
# Epoch 58: Test Loss: 2.4055, Test Accuracy: 38.57%
# Epoch 59/150:
#     Worker 0: Train Loss: 2.4741, Train Accuracy: 36.38%
#     Worker 1: Train Loss: 2.4682, Train Accuracy: 36.87%
#     Worker 2: Train Loss: 2.4086, Train Accuracy: 37.77%
#     Worker 3: Train Loss: 2.4641, Train Accuracy: 37.19%
# Epoch 59: Test Loss: 2.3871, Test Accuracy: 38.39%
# Epoch 60/150:
#     Worker 0: Train Loss: 2.3978, Train Accuracy: 38.13%
#     Worker 1: Train Loss: 2.4226, Train Accuracy: 37.80%
#     Worker 2: Train Loss: 2.3984, Train Accuracy: 38.22%
#     Worker 3: Train Loss: 2.4507, Train Accuracy: 36.51%
# Epoch 60: Test Loss: 2.4092, Test Accuracy: 38.23%
# Epoch 61/150:
#     Worker 0: Train Loss: 2.4526, Train Accuracy: 36.37%
#     Worker 1: Train Loss: 2.4592, Train Accuracy: 36.53%
#     Worker 2: Train Loss: 2.4114, Train Accuracy: 37.53%
#     Worker 3: Train Loss: 2.4262, Train Accuracy: 37.15%
# Epoch 61: Test Loss: 2.4123, Test Accuracy: 38.11%
# Epoch 62/150:
#     Worker 0: Train Loss: 2.4125, Train Accuracy: 37.98%
#     Worker 1: Train Loss: 2.4116, Train Accuracy: 36.99%
#     Worker 2: Train Loss: 2.3586, Train Accuracy: 38.96%
#     Worker 3: Train Loss: 2.4403, Train Accuracy: 36.71%
# Epoch 62: Test Loss: 2.3706, Test Accuracy: 39.03%
# Epoch 63/150:
#     Worker 0: Train Loss: 2.4018, Train Accuracy: 38.33%
#     Worker 1: Train Loss: 2.4230, Train Accuracy: 37.60%
#     Worker 2: Train Loss: 2.3741, Train Accuracy: 39.14%
#     Worker 3: Train Loss: 2.4175, Train Accuracy: 37.64%
# Epoch 63: Test Loss: 2.3501, Test Accuracy: 39.18%
# Epoch 64/150:
#     Worker 0: Train Loss: 2.3714, Train Accuracy: 37.96%
#     Worker 1: Train Loss: 2.3961, Train Accuracy: 37.68%
#     Worker 2: Train Loss: 2.3756, Train Accuracy: 39.29%
#     Worker 3: Train Loss: 2.3606, Train Accuracy: 38.00%
# Epoch 64: Test Loss: 2.3701, Test Accuracy: 38.58%
# Epoch 65/150:
#     Worker 0: Train Loss: 2.3609, Train Accuracy: 38.75%
#     Worker 1: Train Loss: 2.3630, Train Accuracy: 38.17%
#     Worker 2: Train Loss: 2.3522, Train Accuracy: 38.88%
#     Worker 3: Train Loss: 2.4005, Train Accuracy: 38.03%
# Epoch 65: Test Loss: 2.3593, Test Accuracy: 39.26%
# Epoch 66/150:
#     Worker 0: Train Loss: 2.3474, Train Accuracy: 39.21%
#     Worker 1: Train Loss: 2.3619, Train Accuracy: 38.81%
#     Worker 2: Train Loss: 2.3490, Train Accuracy: 39.52%
#     Worker 3: Train Loss: 2.3783, Train Accuracy: 37.71%
# Epoch 66: Test Loss: 2.3468, Test Accuracy: 39.46%
# Epoch 67/150:
#     Worker 0: Train Loss: 2.3493, Train Accuracy: 39.15%
#     Worker 1: Train Loss: 2.3587, Train Accuracy: 37.68%
#     Worker 2: Train Loss: 2.3478, Train Accuracy: 39.21%
#     Worker 3: Train Loss: 2.3605, Train Accuracy: 38.62%
# Epoch 67: Test Loss: 2.3428, Test Accuracy: 39.53%
# Epoch 68/150:
#     Worker 0: Train Loss: 2.3356, Train Accuracy: 39.58%
#     Worker 1: Train Loss: 2.3413, Train Accuracy: 38.24%
#     Worker 2: Train Loss: 2.2979, Train Accuracy: 40.57%
#     Worker 3: Train Loss: 2.3186, Train Accuracy: 38.82%
# Epoch 68: Test Loss: 2.3198, Test Accuracy: 40.12%
# Epoch 69/150:
#     Worker 0: Train Loss: 2.3025, Train Accuracy: 40.10%
#     Worker 1: Train Loss: 2.3382, Train Accuracy: 39.35%
#     Worker 2: Train Loss: 2.3025, Train Accuracy: 41.15%
#     Worker 3: Train Loss: 2.3527, Train Accuracy: 38.45%
# Epoch 69: Test Loss: 2.3007, Test Accuracy: 40.33%
# Epoch 70/150:
#     Worker 0: Train Loss: 2.2977, Train Accuracy: 40.23%
#     Worker 1: Train Loss: 2.3512, Train Accuracy: 39.21%
#     Worker 2: Train Loss: 2.2941, Train Accuracy: 40.77%
#     Worker 3: Train Loss: 2.3491, Train Accuracy: 38.75%
# Epoch 70: Test Loss: 2.3001, Test Accuracy: 40.17%
# Epoch 71/150:
#     Worker 0: Train Loss: 2.3070, Train Accuracy: 39.81%
#     Worker 1: Train Loss: 2.3042, Train Accuracy: 39.35%
#     Worker 2: Train Loss: 2.2735, Train Accuracy: 40.64%
#     Worker 3: Train Loss: 2.3097, Train Accuracy: 39.65%
# Epoch 71: Test Loss: 2.2846, Test Accuracy: 40.92%
# Epoch 72/150:
#     Worker 0: Train Loss: 2.2795, Train Accuracy: 40.18%
#     Worker 1: Train Loss: 2.2748, Train Accuracy: 40.07%
#     Worker 2: Train Loss: 2.2402, Train Accuracy: 41.68%
#     Worker 3: Train Loss: 2.2849, Train Accuracy: 40.04%
# Epoch 72: Test Loss: 2.3041, Test Accuracy: 40.52%
# Epoch 73/150:
#     Worker 0: Train Loss: 2.2618, Train Accuracy: 41.82%
#     Worker 1: Train Loss: 2.2887, Train Accuracy: 40.07%
#     Worker 2: Train Loss: 2.2761, Train Accuracy: 41.14%
#     Worker 3: Train Loss: 2.2808, Train Accuracy: 40.02%
# Epoch 73: Test Loss: 2.2730, Test Accuracy: 41.51%
# Epoch 74/150:
#     Worker 0: Train Loss: 2.2558, Train Accuracy: 41.45%
#     Worker 1: Train Loss: 2.3164, Train Accuracy: 38.89%
#     Worker 2: Train Loss: 2.2386, Train Accuracy: 41.70%
#     Worker 3: Train Loss: 2.2824, Train Accuracy: 40.35%
# Epoch 74: Test Loss: 2.2962, Test Accuracy: 40.83%
# Epoch 75/150:
#     Worker 0: Train Loss: 2.2542, Train Accuracy: 41.16%
#     Worker 1: Train Loss: 2.2554, Train Accuracy: 40.76%
#     Worker 2: Train Loss: 2.2287, Train Accuracy: 42.57%
#     Worker 3: Train Loss: 2.2244, Train Accuracy: 41.89%
# Epoch 75: Test Loss: 2.2930, Test Accuracy: 40.49%
# Epoch 76/150:
#     Worker 0: Train Loss: 2.2420, Train Accuracy: 40.23%
#     Worker 1: Train Loss: 2.2935, Train Accuracy: 40.64%
#     Worker 2: Train Loss: 2.2154, Train Accuracy: 41.82%
#     Worker 3: Train Loss: 2.2551, Train Accuracy: 41.05%
# Epoch 76: Test Loss: 2.2541, Test Accuracy: 41.71%
# Epoch 77/150:
#     Worker 0: Train Loss: 2.2319, Train Accuracy: 41.96%
#     Worker 1: Train Loss: 2.2283, Train Accuracy: 41.93%
#     Worker 2: Train Loss: 2.2260, Train Accuracy: 42.09%
#     Worker 3: Train Loss: 2.2366, Train Accuracy: 41.29%
# Epoch 77: Test Loss: 2.2728, Test Accuracy: 41.14%
# Epoch 78/150:
#     Worker 0: Train Loss: 2.2493, Train Accuracy: 40.50%
#     Worker 1: Train Loss: 2.2049, Train Accuracy: 41.56%
#     Worker 2: Train Loss: 2.2268, Train Accuracy: 42.16%
#     Worker 3: Train Loss: 2.2064, Train Accuracy: 41.55%
# Epoch 78: Test Loss: 2.2705, Test Accuracy: 41.27%
# Epoch 79/150:
#     Worker 0: Train Loss: 2.2021, Train Accuracy: 41.96%
#     Worker 1: Train Loss: 2.2339, Train Accuracy: 42.17%
#     Worker 2: Train Loss: 2.2211, Train Accuracy: 41.86%
#     Worker 3: Train Loss: 2.2105, Train Accuracy: 42.10%
# Epoch 79: Test Loss: 2.2384, Test Accuracy: 42.33%
# Epoch 80/150:
#     Worker 0: Train Loss: 2.1757, Train Accuracy: 42.92%
#     Worker 1: Train Loss: 2.1988, Train Accuracy: 42.52%
#     Worker 2: Train Loss: 2.1386, Train Accuracy: 43.85%
#     Worker 3: Train Loss: 2.2232, Train Accuracy: 42.52%
# Epoch 80: Test Loss: 2.2545, Test Accuracy: 41.98%
# Epoch 81/150:
#     Worker 0: Train Loss: 2.2435, Train Accuracy: 41.11%
#     Worker 1: Train Loss: 2.2055, Train Accuracy: 42.10%
#     Worker 2: Train Loss: 2.1870, Train Accuracy: 42.91%
#     Worker 3: Train Loss: 2.1999, Train Accuracy: 41.63%
# Epoch 81: Test Loss: 2.2225, Test Accuracy: 42.23%
# Epoch 82/150:
#     Worker 0: Train Loss: 2.1933, Train Accuracy: 41.98%
#     Worker 1: Train Loss: 2.2155, Train Accuracy: 41.58%
#     Worker 2: Train Loss: 2.1722, Train Accuracy: 43.86%
#     Worker 3: Train Loss: 2.2260, Train Accuracy: 41.76%
# Epoch 82: Test Loss: 2.2187, Test Accuracy: 42.24%
# Epoch 83/150:
#     Worker 0: Train Loss: 2.1952, Train Accuracy: 42.47%
#     Worker 1: Train Loss: 2.2028, Train Accuracy: 41.92%
#     Worker 2: Train Loss: 2.1505, Train Accuracy: 43.22%
#     Worker 3: Train Loss: 2.2097, Train Accuracy: 41.61%
# Epoch 83: Test Loss: 2.2252, Test Accuracy: 42.50%
# Epoch 84/150:
#     Worker 0: Train Loss: 2.1593, Train Accuracy: 42.64%
#     Worker 1: Train Loss: 2.1769, Train Accuracy: 42.75%
#     Worker 2: Train Loss: 2.1660, Train Accuracy: 43.95%
#     Worker 3: Train Loss: 2.1482, Train Accuracy: 43.61%
# Epoch 84: Test Loss: 2.2240, Test Accuracy: 42.14%
# Epoch 85/150:
#     Worker 0: Train Loss: 2.1706, Train Accuracy: 43.32%
#     Worker 1: Train Loss: 2.1721, Train Accuracy: 43.03%
#     Worker 2: Train Loss: 2.1508, Train Accuracy: 43.52%
#     Worker 3: Train Loss: 2.1674, Train Accuracy: 42.86%
# Epoch 85: Test Loss: 2.2226, Test Accuracy: 42.27%
# Epoch 86/150:
#     Worker 0: Train Loss: 2.1735, Train Accuracy: 42.10%
#     Worker 1: Train Loss: 2.1881, Train Accuracy: 42.66%
#     Worker 2: Train Loss: 2.1404, Train Accuracy: 43.43%
#     Worker 3: Train Loss: 2.2108, Train Accuracy: 41.64%
# Epoch 86: Test Loss: 2.2117, Test Accuracy: 42.77%
# Epoch 87/150:
#     Worker 0: Train Loss: 2.1793, Train Accuracy: 42.71%
#     Worker 1: Train Loss: 2.1529, Train Accuracy: 43.73%
#     Worker 2: Train Loss: 2.1120, Train Accuracy: 45.28%
#     Worker 3: Train Loss: 2.0996, Train Accuracy: 43.70%
# Epoch 87: Test Loss: 2.2108, Test Accuracy: 42.73%
# Epoch 88/150:
#     Worker 0: Train Loss: 2.1584, Train Accuracy: 43.42%
#     Worker 1: Train Loss: 2.1830, Train Accuracy: 43.20%
#     Worker 2: Train Loss: 2.1529, Train Accuracy: 43.15%
#     Worker 3: Train Loss: 2.1849, Train Accuracy: 42.53%
# Epoch 88: Test Loss: 2.2036, Test Accuracy: 43.22%
# Epoch 89/150:
#     Worker 0: Train Loss: 2.1174, Train Accuracy: 43.52%
#     Worker 1: Train Loss: 2.1187, Train Accuracy: 43.82%
#     Worker 2: Train Loss: 2.0974, Train Accuracy: 44.85%
#     Worker 3: Train Loss: 2.1100, Train Accuracy: 44.85%
# Epoch 89: Test Loss: 2.1897, Test Accuracy: 42.98%
# Epoch 90/150:
#     Worker 0: Train Loss: 2.1160, Train Accuracy: 44.00%
#     Worker 1: Train Loss: 2.1187, Train Accuracy: 44.22%
#     Worker 2: Train Loss: 2.1276, Train Accuracy: 43.97%
#     Worker 3: Train Loss: 2.1405, Train Accuracy: 43.41%
# Epoch 90: Test Loss: 2.1939, Test Accuracy: 42.96%
# Epoch 91/150:
#     Worker 0: Train Loss: 2.1196, Train Accuracy: 42.79%
#     Worker 1: Train Loss: 2.0971, Train Accuracy: 44.46%
#     Worker 2: Train Loss: 2.0905, Train Accuracy: 45.05%
#     Worker 3: Train Loss: 2.1651, Train Accuracy: 43.31%
# Epoch 91: Test Loss: 2.1993, Test Accuracy: 42.93%
# Epoch 92/150:
#     Worker 0: Train Loss: 2.1189, Train Accuracy: 43.98%
#     Worker 1: Train Loss: 2.1482, Train Accuracy: 43.86%
#     Worker 2: Train Loss: 2.1060, Train Accuracy: 44.94%
#     Worker 3: Train Loss: 2.1155, Train Accuracy: 44.38%
# Epoch 92: Test Loss: 2.1913, Test Accuracy: 43.16%
# Epoch 93/150:
#     Worker 0: Train Loss: 2.1001, Train Accuracy: 44.52%
#     Worker 1: Train Loss: 2.0980, Train Accuracy: 44.54%
#     Worker 2: Train Loss: 2.0831, Train Accuracy: 45.01%
#     Worker 3: Train Loss: 2.1137, Train Accuracy: 44.09%
# Epoch 93: Test Loss: 2.1891, Test Accuracy: 43.33%
# Epoch 94/150:
#     Worker 0: Train Loss: 2.0776, Train Accuracy: 44.38%
#     Worker 1: Train Loss: 2.1118, Train Accuracy: 44.43%
#     Worker 2: Train Loss: 2.0910, Train Accuracy: 45.83%
#     Worker 3: Train Loss: 2.1319, Train Accuracy: 43.70%
# Epoch 94: Test Loss: 2.1762, Test Accuracy: 43.88%
# Epoch 95/150:
#     Worker 0: Train Loss: 2.1068, Train Accuracy: 43.77%
#     Worker 1: Train Loss: 2.0896, Train Accuracy: 44.86%
#     Worker 2: Train Loss: 2.0429, Train Accuracy: 45.58%
#     Worker 3: Train Loss: 2.1002, Train Accuracy: 44.89%
# Epoch 95: Test Loss: 2.1723, Test Accuracy: 43.69%
# Epoch 96/150:
#     Worker 0: Train Loss: 2.0754, Train Accuracy: 44.84%
#     Worker 1: Train Loss: 2.1102, Train Accuracy: 43.72%
#     Worker 2: Train Loss: 2.0968, Train Accuracy: 44.41%
#     Worker 3: Train Loss: 2.1000, Train Accuracy: 44.39%
# Epoch 96: Test Loss: 2.1794, Test Accuracy: 43.70%
# Epoch 97/150:
#     Worker 0: Train Loss: 2.0729, Train Accuracy: 44.51%
#     Worker 1: Train Loss: 2.0834, Train Accuracy: 45.38%
#     Worker 2: Train Loss: 2.0774, Train Accuracy: 45.09%
#     Worker 3: Train Loss: 2.0538, Train Accuracy: 45.82%
# Epoch 97: Test Loss: 2.1622, Test Accuracy: 43.88%
# Epoch 98/150:
#     Worker 0: Train Loss: 2.0916, Train Accuracy: 44.66%
#     Worker 1: Train Loss: 2.0795, Train Accuracy: 44.88%
#     Worker 2: Train Loss: 2.0792, Train Accuracy: 45.14%
#     Worker 3: Train Loss: 2.0724, Train Accuracy: 45.28%
# Epoch 98: Test Loss: 2.1749, Test Accuracy: 43.58%
# Epoch 99/150:
#     Worker 0: Train Loss: 2.0918, Train Accuracy: 44.12%
#     Worker 1: Train Loss: 2.1055, Train Accuracy: 45.17%
#     Worker 2: Train Loss: 2.0857, Train Accuracy: 44.52%
#     Worker 3: Train Loss: 2.0622, Train Accuracy: 45.38%
# Epoch 99: Test Loss: 2.1604, Test Accuracy: 43.88%
# Epoch 100/150:
#     Worker 0: Train Loss: 2.0595, Train Accuracy: 44.82%
#     Worker 1: Train Loss: 2.0562, Train Accuracy: 44.93%
#     Worker 2: Train Loss: 1.9910, Train Accuracy: 47.82%
#     Worker 3: Train Loss: 2.0744, Train Accuracy: 45.00%
# Epoch 100: Test Loss: 2.1522, Test Accuracy: 44.45%
# Epoch 101/150:
#     Worker 0: Train Loss: 2.0441, Train Accuracy: 45.15%
#     Worker 1: Train Loss: 2.0310, Train Accuracy: 45.53%
#     Worker 2: Train Loss: 1.9970, Train Accuracy: 46.94%
#     Worker 3: Train Loss: 2.0459, Train Accuracy: 45.07%
# Epoch 101: Test Loss: 2.1593, Test Accuracy: 44.34%
# Epoch 102/150:
#     Worker 0: Train Loss: 2.0739, Train Accuracy: 44.44%
#     Worker 1: Train Loss: 2.1097, Train Accuracy: 43.87%
#     Worker 2: Train Loss: 2.0310, Train Accuracy: 45.62%
#     Worker 3: Train Loss: 2.0575, Train Accuracy: 45.54%
# Epoch 102: Test Loss: 2.1446, Test Accuracy: 44.47%
# Epoch 103/150:
#     Worker 0: Train Loss: 2.0260, Train Accuracy: 45.78%
#     Worker 1: Train Loss: 2.0119, Train Accuracy: 46.51%
#     Worker 2: Train Loss: 2.0413, Train Accuracy: 45.50%
#     Worker 3: Train Loss: 2.0388, Train Accuracy: 45.55%
# Epoch 103: Test Loss: 2.1453, Test Accuracy: 44.45%
# Epoch 104/150:
#     Worker 0: Train Loss: 2.0380, Train Accuracy: 45.45%
#     Worker 1: Train Loss: 2.0246, Train Accuracy: 46.79%
#     Worker 2: Train Loss: 2.0206, Train Accuracy: 46.93%
#     Worker 3: Train Loss: 2.0384, Train Accuracy: 46.00%
# Epoch 104: Test Loss: 2.1455, Test Accuracy: 44.23%
# Epoch 105/150:
#     Worker 0: Train Loss: 2.0418, Train Accuracy: 46.46%
#     Worker 1: Train Loss: 2.0837, Train Accuracy: 45.17%
#     Worker 2: Train Loss: 2.0432, Train Accuracy: 46.39%
#     Worker 3: Train Loss: 2.0731, Train Accuracy: 45.09%
# Epoch 105: Test Loss: 2.1330, Test Accuracy: 44.75%
# Epoch 106/150:
#     Worker 0: Train Loss: 2.0151, Train Accuracy: 45.78%
#     Worker 1: Train Loss: 2.0311, Train Accuracy: 45.92%
#     Worker 2: Train Loss: 2.0053, Train Accuracy: 46.77%
#     Worker 3: Train Loss: 2.0091, Train Accuracy: 46.64%
# Epoch 106: Test Loss: 2.1390, Test Accuracy: 44.46%
# Epoch 107/150:
#     Worker 0: Train Loss: 2.0316, Train Accuracy: 45.70%
#     Worker 1: Train Loss: 2.0322, Train Accuracy: 46.68%
#     Worker 2: Train Loss: 2.0072, Train Accuracy: 47.01%
#     Worker 3: Train Loss: 2.0460, Train Accuracy: 46.18%
# Epoch 107: Test Loss: 2.1418, Test Accuracy: 44.32%
# Epoch 108/150:
#     Worker 0: Train Loss: 1.9891, Train Accuracy: 46.86%
#     Worker 1: Train Loss: 2.0016, Train Accuracy: 46.74%
#     Worker 2: Train Loss: 2.0181, Train Accuracy: 46.15%
#     Worker 3: Train Loss: 2.0261, Train Accuracy: 46.44%
# Epoch 108: Test Loss: 2.1342, Test Accuracy: 44.84%
# Epoch 109/150:
#     Worker 0: Train Loss: 2.0603, Train Accuracy: 44.61%
#     Worker 1: Train Loss: 2.0454, Train Accuracy: 46.57%
#     Worker 2: Train Loss: 1.9687, Train Accuracy: 47.94%
#     Worker 3: Train Loss: 2.0315, Train Accuracy: 45.48%
# Epoch 109: Test Loss: 2.1333, Test Accuracy: 44.30%
# Epoch 110/150:
#     Worker 0: Train Loss: 2.0089, Train Accuracy: 45.99%
#     Worker 1: Train Loss: 1.9928, Train Accuracy: 47.18%
#     Worker 2: Train Loss: 1.9853, Train Accuracy: 47.46%
#     Worker 3: Train Loss: 1.9953, Train Accuracy: 46.79%
# Epoch 110: Test Loss: 2.1296, Test Accuracy: 44.63%
# Epoch 111/150:
#     Worker 0: Train Loss: 1.9831, Train Accuracy: 47.31%
#     Worker 1: Train Loss: 2.0332, Train Accuracy: 46.48%
#     Worker 2: Train Loss: 1.9924, Train Accuracy: 47.36%
#     Worker 3: Train Loss: 2.0002, Train Accuracy: 46.28%
# Epoch 111: Test Loss: 2.1272, Test Accuracy: 44.95%
# Epoch 112/150:
#     Worker 0: Train Loss: 2.0004, Train Accuracy: 46.09%
#     Worker 1: Train Loss: 2.0101, Train Accuracy: 46.36%
#     Worker 2: Train Loss: 1.9798, Train Accuracy: 47.88%
#     Worker 3: Train Loss: 2.0356, Train Accuracy: 46.24%
# Epoch 112: Test Loss: 2.1255, Test Accuracy: 44.72%
# Epoch 113/150:
#     Worker 0: Train Loss: 1.9782, Train Accuracy: 47.09%
#     Worker 1: Train Loss: 1.9818, Train Accuracy: 47.58%
#     Worker 2: Train Loss: 2.0017, Train Accuracy: 46.68%
#     Worker 3: Train Loss: 2.0031, Train Accuracy: 46.69%
# Epoch 113: Test Loss: 2.1273, Test Accuracy: 44.75%
# Epoch 114/150:
#     Worker 0: Train Loss: 2.0339, Train Accuracy: 46.76%
#     Worker 1: Train Loss: 1.9825, Train Accuracy: 47.40%
#     Worker 2: Train Loss: 1.9622, Train Accuracy: 48.67%
#     Worker 3: Train Loss: 1.9584, Train Accuracy: 48.00%
# Epoch 114: Test Loss: 2.1240, Test Accuracy: 44.77%
# Epoch 115/150:
#     Worker 0: Train Loss: 2.0044, Train Accuracy: 46.61%
#     Worker 1: Train Loss: 1.9941, Train Accuracy: 46.71%
#     Worker 2: Train Loss: 1.9856, Train Accuracy: 47.14%
#     Worker 3: Train Loss: 2.0223, Train Accuracy: 47.01%
# Epoch 115: Test Loss: 2.1229, Test Accuracy: 45.22%
# Epoch 116/150:
#     Worker 0: Train Loss: 1.9475, Train Accuracy: 47.79%
#     Worker 1: Train Loss: 2.0187, Train Accuracy: 47.56%
#     Worker 2: Train Loss: 1.9576, Train Accuracy: 48.46%
#     Worker 3: Train Loss: 1.9969, Train Accuracy: 46.49%
# Epoch 116: Test Loss: 2.1183, Test Accuracy: 44.99%
# Epoch 117/150:
#     Worker 0: Train Loss: 1.9981, Train Accuracy: 46.28%
#     Worker 1: Train Loss: 1.9795, Train Accuracy: 47.47%
#     Worker 2: Train Loss: 1.9614, Train Accuracy: 47.41%
#     Worker 3: Train Loss: 1.9750, Train Accuracy: 47.41%
# Epoch 117: Test Loss: 2.1152, Test Accuracy: 44.90%
# Epoch 118/150:
#     Worker 0: Train Loss: 1.9706, Train Accuracy: 46.78%
#     Worker 1: Train Loss: 1.9892, Train Accuracy: 47.03%
#     Worker 2: Train Loss: 1.9626, Train Accuracy: 48.60%
#     Worker 3: Train Loss: 2.0058, Train Accuracy: 46.56%
# Epoch 118: Test Loss: 2.1143, Test Accuracy: 45.20%
# Epoch 119/150:
#     Worker 0: Train Loss: 1.9586, Train Accuracy: 47.41%
#     Worker 1: Train Loss: 1.9866, Train Accuracy: 46.97%
#     Worker 2: Train Loss: 1.9657, Train Accuracy: 47.85%
#     Worker 3: Train Loss: 1.9916, Train Accuracy: 47.08%
# Epoch 119: Test Loss: 2.1133, Test Accuracy: 45.19%
# Epoch 120/150:
#     Worker 0: Train Loss: 1.9707, Train Accuracy: 47.67%
#     Worker 1: Train Loss: 1.9656, Train Accuracy: 47.30%
#     Worker 2: Train Loss: 1.9458, Train Accuracy: 48.58%
#     Worker 3: Train Loss: 1.9722, Train Accuracy: 47.62%
# Epoch 120: Test Loss: 2.1094, Test Accuracy: 45.24%
# Epoch 121/150:
#     Worker 0: Train Loss: 1.9682, Train Accuracy: 47.24%
#     Worker 1: Train Loss: 1.9501, Train Accuracy: 48.28%
#     Worker 2: Train Loss: 1.9614, Train Accuracy: 47.52%
#     Worker 3: Train Loss: 1.9775, Train Accuracy: 47.15%
# Epoch 121: Test Loss: 2.1137, Test Accuracy: 45.31%
# Epoch 122/150:
#     Worker 0: Train Loss: 1.9624, Train Accuracy: 47.27%
#     Worker 1: Train Loss: 1.9860, Train Accuracy: 47.52%
#     Worker 2: Train Loss: 1.9606, Train Accuracy: 48.04%
#     Worker 3: Train Loss: 1.9921, Train Accuracy: 47.01%
# Epoch 122: Test Loss: 2.1071, Test Accuracy: 45.43%
# Epoch 123/150:
#     Worker 0: Train Loss: 1.9341, Train Accuracy: 48.27%
#     Worker 1: Train Loss: 1.9495, Train Accuracy: 48.35%
#     Worker 2: Train Loss: 1.9043, Train Accuracy: 50.11%
#     Worker 3: Train Loss: 1.9932, Train Accuracy: 47.45%
# Epoch 123: Test Loss: 2.1034, Test Accuracy: 45.48%
# Epoch 124/150:
#     Worker 0: Train Loss: 1.9768, Train Accuracy: 47.18%
#     Worker 1: Train Loss: 1.9797, Train Accuracy: 46.46%
#     Worker 2: Train Loss: 1.9365, Train Accuracy: 49.36%
#     Worker 3: Train Loss: 1.9547, Train Accuracy: 47.61%
# Epoch 124: Test Loss: 2.1069, Test Accuracy: 45.77%
# Epoch 125/150:
#     Worker 0: Train Loss: 1.9432, Train Accuracy: 47.97%
#     Worker 1: Train Loss: 1.9967, Train Accuracy: 48.08%
#     Worker 2: Train Loss: 1.9655, Train Accuracy: 47.45%
#     Worker 3: Train Loss: 1.9692, Train Accuracy: 47.16%
# Epoch 125: Test Loss: 2.1024, Test Accuracy: 45.49%
# Epoch 126/150:
#     Worker 0: Train Loss: 1.9748, Train Accuracy: 47.12%
#     Worker 1: Train Loss: 1.9232, Train Accuracy: 47.73%
#     Worker 2: Train Loss: 1.9404, Train Accuracy: 48.92%
#     Worker 3: Train Loss: 1.9297, Train Accuracy: 48.95%
# Epoch 126: Test Loss: 2.1069, Test Accuracy: 45.41%
# Epoch 127/150:
#     Worker 0: Train Loss: 1.9344, Train Accuracy: 48.24%
#     Worker 1: Train Loss: 1.9677, Train Accuracy: 47.89%
#     Worker 2: Train Loss: 1.9084, Train Accuracy: 49.44%
#     Worker 3: Train Loss: 1.9554, Train Accuracy: 48.66%
# Epoch 127: Test Loss: 2.1016, Test Accuracy: 45.81%
# Epoch 128/150:
#     Worker 0: Train Loss: 1.9594, Train Accuracy: 47.49%
#     Worker 1: Train Loss: 1.9494, Train Accuracy: 48.72%
#     Worker 2: Train Loss: 1.9333, Train Accuracy: 49.17%
#     Worker 3: Train Loss: 1.9434, Train Accuracy: 47.93%
# Epoch 128: Test Loss: 2.1019, Test Accuracy: 45.62%
# Epoch 129/150:
#     Worker 0: Train Loss: 1.9342, Train Accuracy: 48.62%
#     Worker 1: Train Loss: 1.9511, Train Accuracy: 47.84%
#     Worker 2: Train Loss: 1.9509, Train Accuracy: 48.18%
#     Worker 3: Train Loss: 1.9675, Train Accuracy: 47.41%
# Epoch 129: Test Loss: 2.0992, Test Accuracy: 45.64%
# Epoch 130/150:
#     Worker 0: Train Loss: 1.9262, Train Accuracy: 48.20%
#     Worker 1: Train Loss: 1.9648, Train Accuracy: 47.61%
#     Worker 2: Train Loss: 1.9414, Train Accuracy: 48.29%
#     Worker 3: Train Loss: 1.9480, Train Accuracy: 47.95%
# Epoch 130: Test Loss: 2.0967, Test Accuracy: 45.51%
# Epoch 131/150:
#     Worker 0: Train Loss: 1.9723, Train Accuracy: 47.72%
#     Worker 1: Train Loss: 1.9620, Train Accuracy: 48.31%
#     Worker 2: Train Loss: 1.9233, Train Accuracy: 49.47%
#     Worker 3: Train Loss: 1.9297, Train Accuracy: 48.68%
# Epoch 131: Test Loss: 2.0998, Test Accuracy: 45.64%
# Epoch 132/150:
#     Worker 0: Train Loss: 1.9496, Train Accuracy: 47.57%
#     Worker 1: Train Loss: 1.9467, Train Accuracy: 48.15%
#     Worker 2: Train Loss: 1.9267, Train Accuracy: 49.14%
#     Worker 3: Train Loss: 1.9174, Train Accuracy: 48.74%
# Epoch 132: Test Loss: 2.0945, Test Accuracy: 45.77%
# Epoch 133/150:
#     Worker 0: Train Loss: 1.9446, Train Accuracy: 48.48%
#     Worker 1: Train Loss: 1.9310, Train Accuracy: 48.34%
#     Worker 2: Train Loss: 1.8995, Train Accuracy: 49.71%
#     Worker 3: Train Loss: 1.9432, Train Accuracy: 47.83%
# Epoch 133: Test Loss: 2.1002, Test Accuracy: 45.70%
# Epoch 134/150:
#     Worker 0: Train Loss: 1.9366, Train Accuracy: 48.33%
#     Worker 1: Train Loss: 1.9787, Train Accuracy: 47.77%
#     Worker 2: Train Loss: 1.9382, Train Accuracy: 48.20%
#     Worker 3: Train Loss: 1.9899, Train Accuracy: 48.25%
# Epoch 134: Test Loss: 2.0950, Test Accuracy: 45.68%
# Epoch 135/150:
#     Worker 0: Train Loss: 1.9152, Train Accuracy: 49.22%
#     Worker 1: Train Loss: 1.9210, Train Accuracy: 48.35%
#     Worker 2: Train Loss: 1.9479, Train Accuracy: 48.81%
#     Worker 3: Train Loss: 1.9275, Train Accuracy: 48.23%
# Epoch 135: Test Loss: 2.0990, Test Accuracy: 45.65%
# Epoch 136/150:
#     Worker 0: Train Loss: 1.9646, Train Accuracy: 47.67%
#     Worker 1: Train Loss: 1.9544, Train Accuracy: 48.18%
#     Worker 2: Train Loss: 1.8986, Train Accuracy: 48.93%
#     Worker 3: Train Loss: 1.9653, Train Accuracy: 48.12%
# Epoch 136: Test Loss: 2.0972, Test Accuracy: 45.69%
# Epoch 137/150:
#     Worker 0: Train Loss: 1.9368, Train Accuracy: 47.85%
#     Worker 1: Train Loss: 1.9309, Train Accuracy: 48.79%
#     Worker 2: Train Loss: 1.9114, Train Accuracy: 49.34%
#     Worker 3: Train Loss: 1.9308, Train Accuracy: 47.67%
# Epoch 137: Test Loss: 2.0959, Test Accuracy: 45.75%
# Epoch 138/150:
#     Worker 0: Train Loss: 1.9263, Train Accuracy: 48.98%
#     Worker 1: Train Loss: 1.9325, Train Accuracy: 48.87%
#     Worker 2: Train Loss: 1.9283, Train Accuracy: 49.10%
#     Worker 3: Train Loss: 1.9755, Train Accuracy: 47.62%
# Epoch 138: Test Loss: 2.0946, Test Accuracy: 45.74%
# Epoch 139/150:
#     Worker 0: Train Loss: 1.9402, Train Accuracy: 47.12%
#     Worker 1: Train Loss: 1.9279, Train Accuracy: 48.58%
#     Worker 2: Train Loss: 1.8981, Train Accuracy: 48.79%
#     Worker 3: Train Loss: 1.8899, Train Accuracy: 49.88%
# Epoch 139: Test Loss: 2.0952, Test Accuracy: 45.69%
# Epoch 140/150:
#     Worker 0: Train Loss: 1.9394, Train Accuracy: 48.48%
#     Worker 1: Train Loss: 1.9441, Train Accuracy: 48.19%
#     Worker 2: Train Loss: 1.9110, Train Accuracy: 49.47%
#     Worker 3: Train Loss: 1.9311, Train Accuracy: 48.31%
# Epoch 140: Test Loss: 2.0935, Test Accuracy: 45.78%
# Epoch 141/150:
#     Worker 0: Train Loss: 1.9205, Train Accuracy: 48.49%
#     Worker 1: Train Loss: 1.9436, Train Accuracy: 48.04%
#     Worker 2: Train Loss: 1.9020, Train Accuracy: 48.56%
#     Worker 3: Train Loss: 1.9651, Train Accuracy: 47.45%
# Epoch 141: Test Loss: 2.0934, Test Accuracy: 45.55%
# Epoch 142/150:
#     Worker 0: Train Loss: 1.9350, Train Accuracy: 48.37%
#     Worker 1: Train Loss: 1.9351, Train Accuracy: 48.97%
#     Worker 2: Train Loss: 1.9205, Train Accuracy: 49.05%
#     Worker 3: Train Loss: 1.9527, Train Accuracy: 48.17%
# Epoch 142: Test Loss: 2.0932, Test Accuracy: 45.61%
# Epoch 143/150:
#     Worker 0: Train Loss: 1.9254, Train Accuracy: 48.42%
#     Worker 1: Train Loss: 1.9015, Train Accuracy: 48.44%
#     Worker 2: Train Loss: 1.9161, Train Accuracy: 49.84%
#     Worker 3: Train Loss: 1.9365, Train Accuracy: 48.67%
# Epoch 143: Test Loss: 2.0929, Test Accuracy: 45.72%
# Epoch 144/150:
#     Worker 0: Train Loss: 1.9307, Train Accuracy: 48.69%
#     Worker 1: Train Loss: 1.9925, Train Accuracy: 47.64%
#     Worker 2: Train Loss: 1.9116, Train Accuracy: 48.79%
#     Worker 3: Train Loss: 1.9359, Train Accuracy: 47.88%
# Epoch 144: Test Loss: 2.0931, Test Accuracy: 45.67%
# Epoch 145/150:
#     Worker 0: Train Loss: 1.9460, Train Accuracy: 47.98%
#     Worker 1: Train Loss: 1.9068, Train Accuracy: 49.31%
#     Worker 2: Train Loss: 1.9255, Train Accuracy: 48.84%
#     Worker 3: Train Loss: 1.9222, Train Accuracy: 49.12%
# Epoch 145: Test Loss: 2.0931, Test Accuracy: 45.63%
# Epoch 146/150:
#     Worker 0: Train Loss: 1.8965, Train Accuracy: 48.30%
#     Worker 1: Train Loss: 1.9309, Train Accuracy: 48.64%
#     Worker 2: Train Loss: 1.9038, Train Accuracy: 48.56%
#     Worker 3: Train Loss: 1.9384, Train Accuracy: 47.92%
# Epoch 146: Test Loss: 2.0929, Test Accuracy: 45.64%
# Epoch 147/150:
#     Worker 0: Train Loss: 1.9507, Train Accuracy: 47.53%
#     Worker 1: Train Loss: 1.9447, Train Accuracy: 48.60%
#     Worker 2: Train Loss: 1.9451, Train Accuracy: 48.85%
#     Worker 3: Train Loss: 1.9346, Train Accuracy: 48.50%
# Epoch 147: Test Loss: 2.0931, Test Accuracy: 45.59%
# Epoch 148/150:
#     Worker 0: Train Loss: 1.9193, Train Accuracy: 48.53%
#     Worker 1: Train Loss: 1.9100, Train Accuracy: 48.59%
#     Worker 2: Train Loss: 1.8769, Train Accuracy: 50.02%
#     Worker 3: Train Loss: 1.9440, Train Accuracy: 48.11%
# Epoch 148: Test Loss: 2.0931, Test Accuracy: 45.64%
# Epoch 149/150:
#     Worker 0: Train Loss: 1.9360, Train Accuracy: 47.75%
#     Worker 1: Train Loss: 1.9404, Train Accuracy: 48.80%
#     Worker 2: Train Loss: 1.9343, Train Accuracy: 48.60%
#     Worker 3: Train Loss: 1.9461, Train Accuracy: 48.23%
# Epoch 149: Test Loss: 2.0930, Test Accuracy: 45.61%
# Epoch 150/150:
#     Worker 0: Train Loss: 1.9193, Train Accuracy: 48.82%
#     Worker 1: Train Loss: 1.9510, Train Accuracy: 48.48%
#     Worker 2: Train Loss: 1.9041, Train Accuracy: 49.44%
#     Worker 3: Train Loss: 1.8773, Train Accuracy: 49.88%
# Epoch 150: Test Loss: 2.0930, Test Accuracy: 45.60%
