# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files
import torch.nn.functional as F

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
iteration_per_epoch = 782 # number of local step performed in one epoch
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
#warmup_epochs = 5

def compute_mean_std(dataset):
    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

#global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
#global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
#print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Compute gradient magnitude and variance
def compute_gradient_stats(nets, optimizers):
    # Get gradients from each worker
    gradients = []
    for net, optimizer in zip(nets, optimizers):
        grad_vector = []
        for param in net.parameters():
            if param.grad is not None:
                grad_vector.append(param.grad.view(-1))
        grad_vector = torch.cat(grad_vector)  # Flatten all gradients into a vector
        gradients.append(grad_vector)

    # Compute average gradient (g_t)
    avg_gradient = torch.stack(gradients).mean(dim=0)

    # Compute squared norms of individual gradients
    squared_norms = [torch.norm(g).item() ** 2 for g in gradients]

    # Compute squared norm of the average gradient
    avg_squared_norm = torch.norm(avg_gradient).item() ** 2

    # Compute gradient variance (sigma_t^2) using the provided formula
    sigma_t_squared = (sum(squared_norms) / (K - 1)) - (K / (K - 1)) * avg_squared_norm

    # Compute gradient magnitude (G_t) using the provided formula
    G_t = avg_squared_norm - (1 / K) * sigma_t_squared

    return G_t, sigma_t_squared


# Update H dynamically based on gradient stats
def update_H(G_t, sigma_t_squared, H_min, H_max, alpha, epsilon):
    H_t = min(H_max, max(H_min, alpha * G_t / (sigma_t_squared + epsilon)))
    #H_t = min(H_t, H_max)  # Ensure H_t doesn't exceed H_max
    return int(H_t)  # Ensure H_t is an integer

# Training loop
# Hyperparameters for dynamic adjustment
H_min, H_max = 4, 64  # Minimum and maximum allowed local steps
alpha, epsilon = 300, 1e-6  # Scaling factor and small constant

H_t = J  # Initialize H_t with the default J value


for epoch in range(num_epochs):
    #print(f"Epoch {epoch + 1}/{num_epochs}:")
    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]

    iteration_per_epoch = 782
    iteration = 0 # Number of global iteration performed
    while iteration_per_epoch > 0:
        # Train each worker for H_t steps
        for k in range(K):
            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            for _ in range(H_t):  # Perform H_t local steps
                try:
                    images, labels = next(shard_iterators[k])
                except StopIteration:
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k])
                images, labels = images.to(device), labels.to(device)

                optimizers[k].zero_grad()
                outputs = nets[k](images)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizers[k].step()

                # Calculate train loss and accuracy
                train_loss += loss.item() * labels.size(0)
                _, predicted = outputs.max(1)
                total_train += labels.size(0)
                correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        # Synchronize models
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

        # update tot_num_local_step and number of global iteration
        iteration_per_epoch -= (H_t * K)
        iteration += 1
        # Compute gradient stats and update H_t
        G_t, sigma_t_squared = compute_gradient_stats(nets, optimizers)
        H_t = update_H(G_t, sigma_t_squared, H_min, H_max, alpha, epsilon)
        print(f"Epoch {epoch+1}, Iteration {iteration}: H_t = {H_t}, G_t = {G_t:.4f}, σ_t^2 = {sigma_t_squared:.4f}")

    # Store training metrics for all workers after each epoch
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

    # Update learning rate
    for scheduler in schedulers:
        scheduler.step()

    # Evaluate on test set
    global_model = nets[0]
    global_model.eval()
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()

    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)
    print(f"Epoch {epoch + 1}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")



# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Overwriting localSGD.py

# %%
# %run localSGD.py --k 4 --j 32
# Out:
# Training with K=4, J=32
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00400
# Epoch 1, Iteration 1: H_t = 17, G_t = 0.0072, σ_t^2 = 0.1248
# Epoch 1, Iteration 2: H_t = 4, G_t = -0.0021, σ_t^2 = 0.1254
# Epoch 1, Iteration 3: H_t = 4, G_t = 0.0005, σ_t^2 = 0.1201
# Epoch 1, Iteration 4: H_t = 4, G_t = 0.0016, σ_t^2 = 0.1230
# Epoch 1, Iteration 5: H_t = 4, G_t = -0.0010, σ_t^2 = 0.1282
# Epoch 1, Iteration 6: H_t = 15, G_t = 0.0060, σ_t^2 = 0.1174
# Epoch 1, Iteration 7: H_t = 15, G_t = 0.0066, σ_t^2 = 0.1240
# Epoch 1, Iteration 8: H_t = 4, G_t = 0.0020, σ_t^2 = 0.1281
# Epoch 1, Iteration 9: H_t = 4, G_t = -0.0015, σ_t^2 = 0.1340
# Epoch 1, Iteration 10: H_t = 4, G_t = -0.0042, σ_t^2 = 0.1462
# Epoch 1, Iteration 11: H_t = 4, G_t = 0.0023, σ_t^2 = 0.1467
# Epoch 1, Iteration 12: H_t = 22, G_t = 0.0101, σ_t^2 = 0.1379
# Epoch 1, Iteration 13: H_t = 19, G_t = 0.0110, σ_t^2 = 0.1700
# Epoch 1, Iteration 14: H_t = 4, G_t = -0.0003, σ_t^2 = 0.2027
# Epoch 1, Iteration 15: H_t = 4, G_t = -0.0014, σ_t^2 = 0.2665
# Epoch 1, Iteration 16: H_t = 23, G_t = 0.0181, σ_t^2 = 0.2336
# Epoch 1, Iteration 17: H_t = 6, G_t = 0.0071, σ_t^2 = 0.3208
# Epoch 1, Iteration 18: H_t = 4, G_t = -0.0068, σ_t^2 = 0.3305
# Epoch 1, Iteration 19: H_t = 16, G_t = 0.0188, σ_t^2 = 0.3356
# Epoch 1, Iteration 20: H_t = 23, G_t = 0.0310, σ_t^2 = 0.3937
#     Worker 0: Train Loss: 4.5984, Train Accuracy: 1.54%
#     Worker 1: Train Loss: 4.5993, Train Accuracy: 1.26%
#     Worker 2: Train Loss: 4.5977, Train Accuracy: 1.61%
#     Worker 3: Train Loss: 4.5982, Train Accuracy: 1.51%
# Epoch 1: Test Loss: 4.5779, Test Accuracy: 2.62%
# Epoch 2, Iteration 1: H_t = 4, G_t = 0.0016, σ_t^2 = 0.6137
# Epoch 2, Iteration 2: H_t = 26, G_t = 0.0607, σ_t^2 = 0.6895
# Epoch 2, Iteration 3: H_t = 28, G_t = 0.0970, σ_t^2 = 1.0388
# Epoch 2, Iteration 4: H_t = 4, G_t = -0.0280, σ_t^2 = 1.8808
# Epoch 2, Iteration 5: H_t = 10, G_t = 0.0645, σ_t^2 = 1.8646
# Epoch 2, Iteration 6: H_t = 32, G_t = 0.2241, σ_t^2 = 2.0862
# Epoch 2, Iteration 7: H_t = 4, G_t = -0.0473, σ_t^2 = 4.1673
# Epoch 2, Iteration 8: H_t = 8, G_t = 0.1291, σ_t^2 = 4.6295
# Epoch 2, Iteration 9: H_t = 10, G_t = 0.1914, σ_t^2 = 5.4679
# Epoch 2, Iteration 10: H_t = 4, G_t = -0.1400, σ_t^2 = 7.1058
# Epoch 2, Iteration 11: H_t = 22, G_t = 0.5176, σ_t^2 = 6.8755
# Epoch 2, Iteration 12: H_t = 4, G_t = -0.3035, σ_t^2 = 9.5531
# Epoch 2, Iteration 13: H_t = 17, G_t = 0.4525, σ_t^2 = 7.6921
# Epoch 2, Iteration 14: H_t = 4, G_t = -0.7602, σ_t^2 = 12.2098
#     Worker 0: Train Loss: 4.4578, Train Accuracy: 3.62%
#     Worker 1: Train Loss: 4.4606, Train Accuracy: 3.49%
#     Worker 2: Train Loss: 4.4409, Train Accuracy: 3.70%
#     Worker 3: Train Loss: 4.4630, Train Accuracy: 3.24%
# Epoch 2: Test Loss: 4.2069, Test Accuracy: 6.98%
# Epoch 3, Iteration 1: H_t = 9, G_t = 0.2943, σ_t^2 = 9.7633
# Epoch 3, Iteration 2: H_t = 4, G_t = -0.1356, σ_t^2 = 12.3825
# Epoch 3, Iteration 3: H_t = 4, G_t = 0.1191, σ_t^2 = 13.0965
# Epoch 3, Iteration 4: H_t = 4, G_t = 0.1117, σ_t^2 = 13.0807
# Epoch 3, Iteration 5: H_t = 4, G_t = 0.1127, σ_t^2 = 14.1633
# Epoch 3, Iteration 6: H_t = 4, G_t = -0.5857, σ_t^2 = 16.3322
# Epoch 3, Iteration 7: H_t = 16, G_t = 0.7591, σ_t^2 = 13.7812
# Epoch 3, Iteration 8: H_t = 11, G_t = 0.6011, σ_t^2 = 16.0263
# Epoch 3, Iteration 9: H_t = 12, G_t = 0.6932, σ_t^2 = 16.7625
# Epoch 3, Iteration 10: H_t = 4, G_t = -1.3916, σ_t^2 = 16.1229
# Epoch 3, Iteration 11: H_t = 15, G_t = 0.6854, σ_t^2 = 13.3080
# Epoch 3, Iteration 12: H_t = 4, G_t = -0.0278, σ_t^2 = 15.7442
# Epoch 3, Iteration 13: H_t = 14, G_t = 0.5896, σ_t^2 = 11.8231
# Epoch 3, Iteration 14: H_t = 4, G_t = -0.6326, σ_t^2 = 15.0585
# Epoch 3, Iteration 15: H_t = 4, G_t = -0.3183, σ_t^2 = 14.8109
# Epoch 3, Iteration 16: H_t = 5, G_t = 0.2063, σ_t^2 = 11.0813
# Epoch 3, Iteration 17: H_t = 4, G_t = -0.0374, σ_t^2 = 13.4610
# Epoch 3, Iteration 18: H_t = 21, G_t = 0.9807, σ_t^2 = 13.6611
# Epoch 3, Iteration 19: H_t = 60, G_t = 2.3486, σ_t^2 = 11.5865
# Epoch 3, Iteration 20: H_t = 12, G_t = 0.5469, σ_t^2 = 12.9528
#     Worker 0: Train Loss: 4.1328, Train Accuracy: 6.75%
#     Worker 1: Train Loss: 4.1376, Train Accuracy: 6.63%
#     Worker 2: Train Loss: 4.1032, Train Accuracy: 7.11%
#     Worker 3: Train Loss: 4.1343, Train Accuracy: 6.60%
# Epoch 3: Test Loss: 3.9846, Test Accuracy: 9.38%
# Epoch 4, Iteration 1: H_t = 4, G_t = -0.6284, σ_t^2 = 14.8002
# Epoch 4, Iteration 2: H_t = 4, G_t = 0.0522, σ_t^2 = 14.0685
# Epoch 4, Iteration 3: H_t = 22, G_t = 0.8305, σ_t^2 = 11.2671
# Epoch 4, Iteration 4: H_t = 4, G_t = -0.2923, σ_t^2 = 12.0816
# Epoch 4, Iteration 5: H_t = 4, G_t = -0.0725, σ_t^2 = 12.0113
# Epoch 4, Iteration 6: H_t = 4, G_t = 0.1406, σ_t^2 = 11.6624
# Epoch 4, Iteration 7: H_t = 19, G_t = 0.7349, σ_t^2 = 11.2782
# Epoch 4, Iteration 8: H_t = 7, G_t = 0.4474, σ_t^2 = 17.2039
# Epoch 4, Iteration 9: H_t = 4, G_t = -0.1951, σ_t^2 = 14.7590
# Epoch 4, Iteration 10: H_t = 4, G_t = 0.1866, σ_t^2 = 12.1128
# Epoch 4, Iteration 11: H_t = 4, G_t = 0.1798, σ_t^2 = 13.1588
# Epoch 4, Iteration 12: H_t = 4, G_t = 0.1358, σ_t^2 = 14.1151
# Epoch 4, Iteration 13: H_t = 4, G_t = 0.1588, σ_t^2 = 15.6003
# Epoch 4, Iteration 14: H_t = 4, G_t = 0.0608, σ_t^2 = 15.2693
# Epoch 4, Iteration 15: H_t = 4, G_t = -0.4132, σ_t^2 = 17.9944
# Epoch 4, Iteration 16: H_t = 4, G_t = 0.0958, σ_t^2 = 17.4359
# Epoch 4, Iteration 17: H_t = 4, G_t = -0.3884, σ_t^2 = 15.6044
# Epoch 4, Iteration 18: H_t = 5, G_t = 0.2542, σ_t^2 = 14.5971
# Epoch 4, Iteration 19: H_t = 9, G_t = 0.5057, σ_t^2 = 16.5421
# Epoch 4, Iteration 20: H_t = 4, G_t = -0.0455, σ_t^2 = 15.2208
# Epoch 4, Iteration 21: H_t = 4, G_t = -0.0846, σ_t^2 = 18.9771
# Epoch 4, Iteration 22: H_t = 12, G_t = 0.6356, σ_t^2 = 15.0189
# Epoch 4, Iteration 23: H_t = 4, G_t = -0.4356, σ_t^2 = 17.9951
# Epoch 4, Iteration 24: H_t = 15, G_t = 0.8314, σ_t^2 = 16.5583
# Epoch 4, Iteration 25: H_t = 4, G_t = -0.3087, σ_t^2 = 16.2958
# Epoch 4, Iteration 26: H_t = 4, G_t = -0.4509, σ_t^2 = 17.5007
# Epoch 4, Iteration 27: H_t = 4, G_t = -0.6376, σ_t^2 = 15.5891
# Epoch 4, Iteration 28: H_t = 4, G_t = -0.3816, σ_t^2 = 15.8515
# Epoch 4, Iteration 29: H_t = 25, G_t = 1.3188, σ_t^2 = 15.8086
# Epoch 4, Iteration 30: H_t = 20, G_t = 0.9655, σ_t^2 = 13.8415
#     Worker 0: Train Loss: 3.9566, Train Accuracy: 9.27%
#     Worker 1: Train Loss: 3.9685, Train Accuracy: 9.20%
#     Worker 2: Train Loss: 3.9300, Train Accuracy: 9.67%
#     Worker 3: Train Loss: 3.9593, Train Accuracy: 9.29%
# Epoch 4: Test Loss: 3.8234, Test Accuracy: 12.23%
# Epoch 5, Iteration 1: H_t = 4, G_t = 0.2424, σ_t^2 = 19.2248
# Epoch 5, Iteration 2: H_t = 4, G_t = -0.9297, σ_t^2 = 15.8979
# Epoch 5, Iteration 3: H_t = 4, G_t = 0.1827, σ_t^2 = 13.9827
# Epoch 5, Iteration 4: H_t = 12, G_t = 0.6256, σ_t^2 = 14.7139
# Epoch 5, Iteration 5: H_t = 43, G_t = 2.6068, σ_t^2 = 17.9938
# Epoch 5, Iteration 6: H_t = 4, G_t = -0.2455, σ_t^2 = 13.0990
# Epoch 5, Iteration 7: H_t = 31, G_t = 1.3055, σ_t^2 = 12.5542
# Epoch 5, Iteration 8: H_t = 4, G_t = 0.0814, σ_t^2 = 15.4024
# Epoch 5, Iteration 9: H_t = 6, G_t = 0.3188, σ_t^2 = 15.3808
# Epoch 5, Iteration 10: H_t = 4, G_t = 0.2282, σ_t^2 = 13.8218
# Epoch 5, Iteration 11: H_t = 4, G_t = -0.2352, σ_t^2 = 14.3213
# Epoch 5, Iteration 12: H_t = 10, G_t = 0.5082, σ_t^2 = 14.5310
# Epoch 5, Iteration 13: H_t = 12, G_t = 0.7986, σ_t^2 = 19.7152
# Epoch 5, Iteration 14: H_t = 4, G_t = 0.2388, σ_t^2 = 16.8302
# Epoch 5, Iteration 15: H_t = 8, G_t = 0.4873, σ_t^2 = 16.7305
# Epoch 5, Iteration 16: H_t = 12, G_t = 0.7040, σ_t^2 = 17.2510
# Epoch 5, Iteration 17: H_t = 5, G_t = 0.2784, σ_t^2 = 15.3690
# Epoch 5, Iteration 18: H_t = 12, G_t = 0.5943, σ_t^2 = 14.3457
# Epoch 5, Iteration 19: H_t = 4, G_t = 0.0326, σ_t^2 = 23.5771
#     Worker 0: Train Loss: 3.8461, Train Accuracy: 11.07%
#     Worker 1: Train Loss: 3.8509, Train Accuracy: 11.14%
#     Worker 2: Train Loss: 3.8124, Train Accuracy: 11.67%
#     Worker 3: Train Loss: 3.8395, Train Accuracy: 10.99%
# Epoch 5: Test Loss: 3.6771, Test Accuracy: 15.00%
# Epoch 6, Iteration 1: H_t = 24, G_t = 1.3454, σ_t^2 = 16.3454
# Epoch 6, Iteration 2: H_t = 4, G_t = -1.4511, σ_t^2 = 20.1469
# Epoch 6, Iteration 3: H_t = 4, G_t = -0.2650, σ_t^2 = 15.6222
# Epoch 6, Iteration 4: H_t = 23, G_t = 1.1790, σ_t^2 = 14.8246
# Epoch 6, Iteration 5: H_t = 29, G_t = 1.6353, σ_t^2 = 16.4694
# Epoch 6, Iteration 6: H_t = 4, G_t = 0.0370, σ_t^2 = 14.8349
# Epoch 6, Iteration 7: H_t = 64, G_t = 3.0930, σ_t^2 = 13.6637
# Epoch 6, Iteration 8: H_t = 4, G_t = -0.1365, σ_t^2 = 17.5840
# Epoch 6, Iteration 9: H_t = 4, G_t = -0.6334, σ_t^2 = 17.7179
# Epoch 6, Iteration 10: H_t = 17, G_t = 0.7953, σ_t^2 = 14.0261
# Epoch 6, Iteration 11: H_t = 22, G_t = 1.5853, σ_t^2 = 21.4105
# Epoch 6, Iteration 12: H_t = 4, G_t = -0.1110, σ_t^2 = 17.8284
#     Worker 0: Train Loss: 3.7604, Train Accuracy: 12.22%
#     Worker 1: Train Loss: 3.7501, Train Accuracy: 12.96%
#     Worker 2: Train Loss: 3.7099, Train Accuracy: 13.18%
#     Worker 3: Train Loss: 3.7515, Train Accuracy: 12.72%
# Epoch 6: Test Loss: 3.5850, Test Accuracy: 15.71%
# Epoch 7, Iteration 1: H_t = 29, G_t = 1.4974, σ_t^2 = 14.9961
# Epoch 7, Iteration 2: H_t = 23, G_t = 1.3482, σ_t^2 = 17.2607
# Epoch 7, Iteration 3: H_t = 12, G_t = 0.7009, σ_t^2 = 16.3147
# Epoch 7, Iteration 4: H_t = 4, G_t = -0.3852, σ_t^2 = 19.7868
# Epoch 7, Iteration 5: H_t = 4, G_t = -0.2202, σ_t^2 = 17.5363
# Epoch 7, Iteration 6: H_t = 64, G_t = 4.3920, σ_t^2 = 19.9938
# Epoch 7, Iteration 7: H_t = 9, G_t = 0.4902, σ_t^2 = 15.4227
# Epoch 7, Iteration 8: H_t = 4, G_t = -0.9785, σ_t^2 = 22.2549
# Epoch 7, Iteration 9: H_t = 4, G_t = -0.0285, σ_t^2 = 18.3743
# Epoch 7, Iteration 10: H_t = 4, G_t = -0.5234, σ_t^2 = 18.2387
# Epoch 7, Iteration 11: H_t = 4, G_t = -0.5143, σ_t^2 = 19.5717
# Epoch 7, Iteration 12: H_t = 4, G_t = 0.1382, σ_t^2 = 19.7168
# Epoch 7, Iteration 13: H_t = 8, G_t = 0.5273, σ_t^2 = 17.6122
# Epoch 7, Iteration 14: H_t = 12, G_t = 0.9185, σ_t^2 = 22.2533
# Epoch 7, Iteration 15: H_t = 41, G_t = 2.9337, σ_t^2 = 21.4449
# Epoch 7, Iteration 16: H_t = 4, G_t = -0.7138, σ_t^2 = 19.9484
#     Worker 0: Train Loss: 3.6615, Train Accuracy: 13.82%
#     Worker 1: Train Loss: 3.6498, Train Accuracy: 14.44%
#     Worker 2: Train Loss: 3.6105, Train Accuracy: 14.98%
#     Worker 3: Train Loss: 3.6585, Train Accuracy: 13.94%
# Epoch 7: Test Loss: 3.4983, Test Accuracy: 17.60%
# Epoch 8, Iteration 1: H_t = 14, G_t = 0.7898, σ_t^2 = 16.2173
# Epoch 8, Iteration 2: H_t = 4, G_t = -0.8568, σ_t^2 = 21.5845
# Epoch 8, Iteration 3: H_t = 21, G_t = 1.4649, σ_t^2 = 20.3091
# Epoch 8, Iteration 4: H_t = 4, G_t = -0.4255, σ_t^2 = 24.1833
# Epoch 8, Iteration 5: H_t = 4, G_t = -0.0673, σ_t^2 = 20.5647
# Epoch 8, Iteration 6: H_t = 6, G_t = 0.4456, σ_t^2 = 19.3860
# Epoch 8, Iteration 7: H_t = 4, G_t = 0.2508, σ_t^2 = 21.6397
# Epoch 8, Iteration 8: H_t = 14, G_t = 0.9742, σ_t^2 = 19.9438
# Epoch 8, Iteration 9: H_t = 4, G_t = -2.2696, σ_t^2 = 22.8318
# Epoch 8, Iteration 10: H_t = 4, G_t = -0.3555, σ_t^2 = 21.9167
# Epoch 8, Iteration 11: H_t = 4, G_t = -0.2706, σ_t^2 = 18.4993
# Epoch 8, Iteration 12: H_t = 4, G_t = 0.1091, σ_t^2 = 20.6156
# Epoch 8, Iteration 13: H_t = 4, G_t = -0.5636, σ_t^2 = 23.0111
# Epoch 8, Iteration 14: H_t = 26, G_t = 1.9237, σ_t^2 = 21.9167
# Epoch 8, Iteration 15: H_t = 4, G_t = 0.1484, σ_t^2 = 20.2760
# Epoch 8, Iteration 16: H_t = 4, G_t = -0.0291, σ_t^2 = 18.0315
# Epoch 8, Iteration 17: H_t = 5, G_t = 0.2862, σ_t^2 = 16.3700
# Epoch 8, Iteration 18: H_t = 6, G_t = 0.4613, σ_t^2 = 20.7237
# Epoch 8, Iteration 19: H_t = 28, G_t = 1.8607, σ_t^2 = 19.6808
# Epoch 8, Iteration 20: H_t = 4, G_t = 0.3543, σ_t^2 = 21.4825
# Epoch 8, Iteration 21: H_t = 4, G_t = -1.3935, σ_t^2 = 20.8423
# Epoch 8, Iteration 22: H_t = 4, G_t = -0.2485, σ_t^2 = 18.3791
# Epoch 8, Iteration 23: H_t = 35, G_t = 2.2526, σ_t^2 = 19.1790
# Epoch 8, Iteration 24: H_t = 4, G_t = -0.2301, σ_t^2 = 23.6666
#     Worker 0: Train Loss: 3.5304, Train Accuracy: 15.54%
#     Worker 1: Train Loss: 3.5478, Train Accuracy: 15.74%
#     Worker 2: Train Loss: 3.4920, Train Accuracy: 17.07%
#     Worker 3: Train Loss: 3.5306, Train Accuracy: 16.29%
# Epoch 8: Test Loss: 3.3873, Test Accuracy: 19.28%
# Epoch 9, Iteration 1: H_t = 4, G_t = -0.1576, σ_t^2 = 17.0618
# Epoch 9, Iteration 2: H_t = 16, G_t = 1.1218, σ_t^2 = 20.2040
# Epoch 9, Iteration 3: H_t = 5, G_t = 0.4659, σ_t^2 = 23.6756
# Epoch 9, Iteration 4: H_t = 4, G_t = -1.6938, σ_t^2 = 27.4398
# Epoch 9, Iteration 5: H_t = 4, G_t = -1.2642, σ_t^2 = 24.0538
# Epoch 9, Iteration 6: H_t = 4, G_t = -0.2264, σ_t^2 = 21.6886
# Epoch 9, Iteration 7: H_t = 18, G_t = 1.5906, σ_t^2 = 25.8813
# Epoch 9, Iteration 8: H_t = 5, G_t = 0.4246, σ_t^2 = 21.6171
# Epoch 9, Iteration 9: H_t = 8, G_t = 0.5469, σ_t^2 = 19.7396
# Epoch 9, Iteration 10: H_t = 20, G_t = 1.5971, σ_t^2 = 23.8810
# Epoch 9, Iteration 11: H_t = 4, G_t = -1.4811, σ_t^2 = 23.6126
# Epoch 9, Iteration 12: H_t = 4, G_t = -1.2892, σ_t^2 = 22.2513
# Epoch 9, Iteration 13: H_t = 4, G_t = -0.2206, σ_t^2 = 22.3424
# Epoch 9, Iteration 14: H_t = 21, G_t = 1.4201, σ_t^2 = 19.5222
# Epoch 9, Iteration 15: H_t = 4, G_t = 0.2682, σ_t^2 = 22.8953
# Epoch 9, Iteration 16: H_t = 19, G_t = 1.2211, σ_t^2 = 18.5801
# Epoch 9, Iteration 17: H_t = 4, G_t = -2.6113, σ_t^2 = 31.0940
# Epoch 9, Iteration 18: H_t = 4, G_t = -0.2811, σ_t^2 = 23.7836
# Epoch 9, Iteration 19: H_t = 4, G_t = -0.0465, σ_t^2 = 22.1951
# Epoch 9, Iteration 20: H_t = 4, G_t = 0.0566, σ_t^2 = 18.9584
# Epoch 9, Iteration 21: H_t = 32, G_t = 2.1883, σ_t^2 = 20.3787
# Epoch 9, Iteration 22: H_t = 24, G_t = 1.7861, σ_t^2 = 22.1419
#     Worker 0: Train Loss: 3.4633, Train Accuracy: 16.90%
#     Worker 1: Train Loss: 3.4728, Train Accuracy: 16.96%
#     Worker 2: Train Loss: 3.4057, Train Accuracy: 18.05%
#     Worker 3: Train Loss: 3.4595, Train Accuracy: 17.28%
# Epoch 9: Test Loss: 3.3161, Test Accuracy: 20.53%
# Epoch 10, Iteration 1: H_t = 4, G_t = -0.7375, σ_t^2 = 32.8737
# Epoch 10, Iteration 2: H_t = 4, G_t = -0.4007, σ_t^2 = 29.1992
# Epoch 10, Iteration 3: H_t = 34, G_t = 2.3215, σ_t^2 = 20.3169
# Epoch 10, Iteration 4: H_t = 4, G_t = -1.1145, σ_t^2 = 20.5748
# Epoch 10, Iteration 5: H_t = 4, G_t = -0.3570, σ_t^2 = 20.0544
# Epoch 10, Iteration 6: H_t = 4, G_t = -0.2197, σ_t^2 = 18.8067
# Epoch 10, Iteration 7: H_t = 4, G_t = -0.0782, σ_t^2 = 20.4035
# Epoch 10, Iteration 8: H_t = 13, G_t = 0.9954, σ_t^2 = 22.2141
# Epoch 10, Iteration 9: H_t = 4, G_t = -1.2784, σ_t^2 = 29.0310
# Epoch 10, Iteration 10: H_t = 4, G_t = -1.1831, σ_t^2 = 24.8274
# Epoch 10, Iteration 11: H_t = 4, G_t = -0.4489, σ_t^2 = 24.0901
# Epoch 10, Iteration 12: H_t = 27, G_t = 2.1021, σ_t^2 = 23.2258
# Epoch 10, Iteration 13: H_t = 4, G_t = -0.5628, σ_t^2 = 30.6175
# Epoch 10, Iteration 14: H_t = 4, G_t = -0.8463, σ_t^2 = 24.7261
# Epoch 10, Iteration 15: H_t = 4, G_t = -0.2516, σ_t^2 = 24.5064
# Epoch 10, Iteration 16: H_t = 31, G_t = 2.5856, σ_t^2 = 24.6110
# Epoch 10, Iteration 17: H_t = 4, G_t = -1.3662, σ_t^2 = 28.1416
# Epoch 10, Iteration 18: H_t = 4, G_t = 0.0394, σ_t^2 = 19.5678
# Epoch 10, Iteration 19: H_t = 4, G_t = -0.2951, σ_t^2 = 23.2376
# Epoch 10, Iteration 20: H_t = 21, G_t = 1.4408, σ_t^2 = 20.1700
# Epoch 10, Iteration 21: H_t = 4, G_t = -0.5183, σ_t^2 = 24.5291
#     Worker 0: Train Loss: 3.3710, Train Accuracy: 18.61%
#     Worker 1: Train Loss: 3.3873, Train Accuracy: 18.52%
#     Worker 2: Train Loss: 3.3414, Train Accuracy: 19.39%
#     Worker 3: Train Loss: 3.3965, Train Accuracy: 18.21%
# Epoch 10: Test Loss: 3.2299, Test Accuracy: 21.99%
# Epoch 11, Iteration 1: H_t = 4, G_t = 0.2627, σ_t^2 = 32.8803
# Epoch 11, Iteration 2: H_t = 5, G_t = 0.4668, σ_t^2 = 25.9376
# Epoch 11, Iteration 3: H_t = 4, G_t = -0.2627, σ_t^2 = 24.5510
# Epoch 11, Iteration 4: H_t = 4, G_t = -0.7024, σ_t^2 = 24.7821
# Epoch 11, Iteration 5: H_t = 42, G_t = 3.7535, σ_t^2 = 26.3328
# Epoch 11, Iteration 6: H_t = 5, G_t = 0.3676, σ_t^2 = 19.0067
# Epoch 11, Iteration 7: H_t = 4, G_t = -0.8758, σ_t^2 = 21.3677
# Epoch 11, Iteration 8: H_t = 11, G_t = 1.0192, σ_t^2 = 26.0728
# Epoch 11, Iteration 9: H_t = 4, G_t = -1.7939, σ_t^2 = 31.1289
# Epoch 11, Iteration 10: H_t = 16, G_t = 1.3104, σ_t^2 = 24.4821
# Epoch 11, Iteration 11: H_t = 4, G_t = 0.1177, σ_t^2 = 24.9042
# Epoch 11, Iteration 12: H_t = 4, G_t = -1.6127, σ_t^2 = 33.4615
# Epoch 11, Iteration 13: H_t = 18, G_t = 1.6651, σ_t^2 = 26.5464
# Epoch 11, Iteration 14: H_t = 17, G_t = 1.5144, σ_t^2 = 25.6524
# Epoch 11, Iteration 15: H_t = 32, G_t = 2.8608, σ_t^2 = 26.3633
# Epoch 11, Iteration 16: H_t = 4, G_t = -0.0788, σ_t^2 = 22.8147
# Epoch 11, Iteration 17: H_t = 4, G_t = -0.1488, σ_t^2 = 22.1465
# Epoch 11, Iteration 18: H_t = 4, G_t = -0.9663, σ_t^2 = 25.1665
# Epoch 11, Iteration 19: H_t = 4, G_t = 0.1331, σ_t^2 = 25.2615
# Epoch 11, Iteration 20: H_t = 4, G_t = -1.4404, σ_t^2 = 36.2497
# Epoch 11, Iteration 21: H_t = 11, G_t = 0.9172, σ_t^2 = 23.4910
#     Worker 0: Train Loss: 3.3089, Train Accuracy: 19.61%
#     Worker 1: Train Loss: 3.3215, Train Accuracy: 19.71%
#     Worker 2: Train Loss: 3.2575, Train Accuracy: 21.02%
#     Worker 3: Train Loss: 3.3071, Train Accuracy: 19.88%
# Epoch 11: Test Loss: 3.1240, Test Accuracy: 24.46%
# Epoch 12, Iteration 1: H_t = 37, G_t = 4.0140, σ_t^2 = 32.5312
# Epoch 12, Iteration 2: H_t = 18, G_t = 2.0908, σ_t^2 = 33.6314
# Epoch 12, Iteration 3: H_t = 4, G_t = -1.1203, σ_t^2 = 27.9093
# Epoch 12, Iteration 4: H_t = 63, G_t = 5.4781, σ_t^2 = 25.8252
# Epoch 12, Iteration 5: H_t = 4, G_t = -1.5197, σ_t^2 = 27.6647
# Epoch 12, Iteration 6: H_t = 4, G_t = -1.0872, σ_t^2 = 29.9115
# Epoch 12, Iteration 7: H_t = 6, G_t = 0.5075, σ_t^2 = 23.3487
# Epoch 12, Iteration 8: H_t = 4, G_t = -0.3820, σ_t^2 = 29.4339
# Epoch 12, Iteration 9: H_t = 4, G_t = -0.2863, σ_t^2 = 27.5097
# Epoch 12, Iteration 10: H_t = 4, G_t = -2.5286, σ_t^2 = 35.9901
# Epoch 12, Iteration 11: H_t = 4, G_t = 0.3232, σ_t^2 = 27.4995
# Epoch 12, Iteration 12: H_t = 4, G_t = -0.0868, σ_t^2 = 27.8817
# Epoch 12, Iteration 13: H_t = 4, G_t = -1.4768, σ_t^2 = 36.2407
# Epoch 12, Iteration 14: H_t = 14, G_t = 1.5837, σ_t^2 = 31.7068
# Epoch 12, Iteration 15: H_t = 64, G_t = 8.4330, σ_t^2 = 25.3609
# Epoch 12, Iteration 16: H_t = 4, G_t = -0.9628, σ_t^2 = 28.0254
#     Worker 0: Train Loss: 3.2523, Train Accuracy: 20.49%
#     Worker 1: Train Loss: 3.2682, Train Accuracy: 20.63%
#     Worker 2: Train Loss: 3.2174, Train Accuracy: 21.51%
#     Worker 3: Train Loss: 3.2664, Train Accuracy: 20.57%
# Epoch 12: Test Loss: 3.0594, Test Accuracy: 25.54%
# Epoch 13, Iteration 1: H_t = 25, G_t = 2.1794, σ_t^2 = 25.3483
# Epoch 13, Iteration 2: H_t = 17, G_t = 1.7440, σ_t^2 = 29.4752
# Epoch 13, Iteration 3: H_t = 11, G_t = 0.9243, σ_t^2 = 24.7394
# Epoch 13, Iteration 4: H_t = 34, G_t = 2.9549, σ_t^2 = 25.7950
# Epoch 13, Iteration 5: H_t = 10, G_t = 0.9114, σ_t^2 = 25.9624
# Epoch 13, Iteration 6: H_t = 4, G_t = -0.0436, σ_t^2 = 29.2423
# Epoch 13, Iteration 7: H_t = 4, G_t = -3.3811, σ_t^2 = 38.8829
# Epoch 13, Iteration 8: H_t = 16, G_t = 1.2863, σ_t^2 = 22.7484
# Epoch 13, Iteration 9: H_t = 21, G_t = 1.9867, σ_t^2 = 28.1451
# Epoch 13, Iteration 10: H_t = 16, G_t = 1.2379, σ_t^2 = 22.4108
# Epoch 13, Iteration 11: H_t = 4, G_t = -0.2738, σ_t^2 = 29.5648
# Epoch 13, Iteration 12: H_t = 4, G_t = -1.2606, σ_t^2 = 28.9382
# Epoch 13, Iteration 13: H_t = 13, G_t = 1.2472, σ_t^2 = 27.3835
# Epoch 13, Iteration 14: H_t = 17, G_t = 1.7135, σ_t^2 = 28.9496
# Epoch 13, Iteration 15: H_t = 4, G_t = -2.1389, σ_t^2 = 36.1240
#     Worker 0: Train Loss: 3.1821, Train Accuracy: 22.14%
#     Worker 1: Train Loss: 3.2006, Train Accuracy: 22.19%
#     Worker 2: Train Loss: 3.1271, Train Accuracy: 22.98%
#     Worker 3: Train Loss: 3.1615, Train Accuracy: 23.05%
# Epoch 13: Test Loss: 2.9969, Test Accuracy: 26.31%
# Epoch 14, Iteration 1: H_t = 16, G_t = 1.7934, σ_t^2 = 31.7780
# Epoch 14, Iteration 2: H_t = 4, G_t = -2.5423, σ_t^2 = 44.2360
# Epoch 14, Iteration 3: H_t = 4, G_t = -0.8453, σ_t^2 = 36.3415
# Epoch 14, Iteration 4: H_t = 17, G_t = 1.6036, σ_t^2 = 26.7454
# Epoch 14, Iteration 5: H_t = 4, G_t = 0.1535, σ_t^2 = 29.6062
# Epoch 14, Iteration 6: H_t = 4, G_t = -0.1576, σ_t^2 = 31.9157
# Epoch 14, Iteration 7: H_t = 4, G_t = -2.1726, σ_t^2 = 33.5235
# Epoch 14, Iteration 8: H_t = 8, G_t = 0.9683, σ_t^2 = 34.2926
# Epoch 14, Iteration 9: H_t = 34, G_t = 4.2621, σ_t^2 = 37.4347
# Epoch 14, Iteration 10: H_t = 4, G_t = 0.2035, σ_t^2 = 33.1213
# Epoch 14, Iteration 11: H_t = 17, G_t = 1.3894, σ_t^2 = 23.7118
# Epoch 14, Iteration 12: H_t = 4, G_t = 0.5219, σ_t^2 = 32.5924
# Epoch 14, Iteration 13: H_t = 50, G_t = 4.7867, σ_t^2 = 28.5860
# Epoch 14, Iteration 14: H_t = 4, G_t = 0.0365, σ_t^2 = 32.1245
# Epoch 14, Iteration 15: H_t = 4, G_t = -1.2170, σ_t^2 = 27.7799
# Epoch 14, Iteration 16: H_t = 5, G_t = 0.4731, σ_t^2 = 24.1736
# Epoch 14, Iteration 17: H_t = 4, G_t = -1.6092, σ_t^2 = 34.2620
# Epoch 14, Iteration 18: H_t = 4, G_t = -1.4088, σ_t^2 = 28.4280
# Epoch 14, Iteration 19: H_t = 4, G_t = -2.2931, σ_t^2 = 35.5173
# Epoch 14, Iteration 20: H_t = 4, G_t = 0.1672, σ_t^2 = 33.4545
#     Worker 0: Train Loss: 3.0824, Train Accuracy: 23.67%
#     Worker 1: Train Loss: 3.1462, Train Accuracy: 23.15%
#     Worker 2: Train Loss: 3.0575, Train Accuracy: 24.42%
#     Worker 3: Train Loss: 3.1138, Train Accuracy: 23.08%
# Epoch 14: Test Loss: 2.9547, Test Accuracy: 27.29%
# Epoch 15, Iteration 1: H_t = 4, G_t = -0.0959, σ_t^2 = 29.2646
# Epoch 15, Iteration 2: H_t = 9, G_t = 0.8604, σ_t^2 = 27.6608
# Epoch 15, Iteration 3: H_t = 4, G_t = -1.4093, σ_t^2 = 33.2504
# Epoch 15, Iteration 4: H_t = 4, G_t = -1.5407, σ_t^2 = 37.6872
# Epoch 15, Iteration 5: H_t = 4, G_t = -2.6124, σ_t^2 = 47.2620
# Epoch 15, Iteration 6: H_t = 8, G_t = 0.9438, σ_t^2 = 34.7518
# Epoch 15, Iteration 7: H_t = 4, G_t = -0.5061, σ_t^2 = 37.3601
# Epoch 15, Iteration 8: H_t = 15, G_t = 1.6540, σ_t^2 = 31.1220
# Epoch 15, Iteration 9: H_t = 4, G_t = -1.1095, σ_t^2 = 32.7145
# Epoch 15, Iteration 10: H_t = 7, G_t = 0.7518, σ_t^2 = 31.7889
# Epoch 15, Iteration 11: H_t = 4, G_t = -0.0055, σ_t^2 = 36.1654
# Epoch 15, Iteration 12: H_t = 4, G_t = 0.6238, σ_t^2 = 37.5560
# Epoch 15, Iteration 13: H_t = 13, G_t = 1.4446, σ_t^2 = 31.6147
# Epoch 15, Iteration 14: H_t = 4, G_t = -1.5665, σ_t^2 = 35.1650
# Epoch 15, Iteration 15: H_t = 4, G_t = -0.8844, σ_t^2 = 39.2217
# Epoch 15, Iteration 16: H_t = 4, G_t = -0.0597, σ_t^2 = 32.2154
# Epoch 15, Iteration 17: H_t = 8, G_t = 0.8914, σ_t^2 = 31.7862
# Epoch 15, Iteration 18: H_t = 20, G_t = 2.3764, σ_t^2 = 34.9509
# Epoch 15, Iteration 19: H_t = 5, G_t = 0.5802, σ_t^2 = 34.6420
# Epoch 15, Iteration 20: H_t = 4, G_t = -1.8660, σ_t^2 = 41.0591
# Epoch 15, Iteration 21: H_t = 4, G_t = 0.2503, σ_t^2 = 31.8672
# Epoch 15, Iteration 22: H_t = 8, G_t = 0.8425, σ_t^2 = 28.4751
# Epoch 15, Iteration 23: H_t = 6, G_t = 0.7291, σ_t^2 = 31.8090
# Epoch 15, Iteration 24: H_t = 4, G_t = -0.6366, σ_t^2 = 34.1185
# Epoch 15, Iteration 25: H_t = 4, G_t = 0.2343, σ_t^2 = 28.3919
# Epoch 15, Iteration 26: H_t = 4, G_t = -0.8616, σ_t^2 = 32.4530
# Epoch 15, Iteration 27: H_t = 5, G_t = 0.6100, σ_t^2 = 32.8849
# Epoch 15, Iteration 28: H_t = 4, G_t = -0.5050, σ_t^2 = 30.0386
# Epoch 15, Iteration 29: H_t = 7, G_t = 0.9942, σ_t^2 = 37.7197
# Epoch 15, Iteration 30: H_t = 4, G_t = 0.5648, σ_t^2 = 46.5464
# Epoch 15, Iteration 31: H_t = 18, G_t = 1.8019, σ_t^2 = 29.6384
# Epoch 15, Iteration 32: H_t = 4, G_t = -1.9798, σ_t^2 = 46.3833
#     Worker 0: Train Loss: 3.0107, Train Accuracy: 25.11%
#     Worker 1: Train Loss: 3.0402, Train Accuracy: 25.17%
#     Worker 2: Train Loss: 2.9977, Train Accuracy: 25.72%
#     Worker 3: Train Loss: 3.0366, Train Accuracy: 25.08%
# Epoch 15: Test Loss: 2.9008, Test Accuracy: 28.29%
# Epoch 16, Iteration 1: H_t = 4, G_t = -1.7623, σ_t^2 = 41.0887
# Epoch 16, Iteration 2: H_t = 4, G_t = -2.4119, σ_t^2 = 40.0576
# Epoch 16, Iteration 3: H_t = 4, G_t = -0.7844, σ_t^2 = 31.5990
# Epoch 16, Iteration 4: H_t = 4, G_t = -1.7690, σ_t^2 = 36.6975
# Epoch 16, Iteration 5: H_t = 12, G_t = 1.0657, σ_t^2 = 25.8793
# Epoch 16, Iteration 6: H_t = 4, G_t = -0.7196, σ_t^2 = 32.0425
# Epoch 16, Iteration 7: H_t = 4, G_t = -1.1365, σ_t^2 = 39.6501
# Epoch 16, Iteration 8: H_t = 4, G_t = -2.4828, σ_t^2 = 34.1307
# Epoch 16, Iteration 9: H_t = 4, G_t = -0.7401, σ_t^2 = 33.4350
# Epoch 16, Iteration 10: H_t = 4, G_t = 0.5112, σ_t^2 = 33.3537
# Epoch 16, Iteration 11: H_t = 4, G_t = -1.0534, σ_t^2 = 37.6566
# Epoch 16, Iteration 12: H_t = 4, G_t = -0.2582, σ_t^2 = 39.6222
# Epoch 16, Iteration 13: H_t = 18, G_t = 2.3662, σ_t^2 = 38.2688
# Epoch 16, Iteration 14: H_t = 8, G_t = 0.9360, σ_t^2 = 32.1092
# Epoch 16, Iteration 15: H_t = 4, G_t = -0.8597, σ_t^2 = 34.7476
# Epoch 16, Iteration 16: H_t = 4, G_t = -1.9038, σ_t^2 = 33.9887
# Epoch 16, Iteration 17: H_t = 4, G_t = -0.8443, σ_t^2 = 31.0573
# Epoch 16, Iteration 18: H_t = 51, G_t = 5.7456, σ_t^2 = 33.5205
# Epoch 16, Iteration 19: H_t = 4, G_t = -0.5384, σ_t^2 = 45.3499
# Epoch 16, Iteration 20: H_t = 4, G_t = 0.1658, σ_t^2 = 25.1086
# Epoch 16, Iteration 21: H_t = 4, G_t = 0.4685, σ_t^2 = 31.7845
# Epoch 16, Iteration 22: H_t = 19, G_t = 1.9031, σ_t^2 = 29.5235
# Epoch 16, Iteration 23: H_t = 4, G_t = -1.0132, σ_t^2 = 32.4050
# Epoch 16, Iteration 24: H_t = 4, G_t = -0.4564, σ_t^2 = 28.9211
# Epoch 16, Iteration 25: H_t = 26, G_t = 2.4323, σ_t^2 = 27.6408
# Epoch 16, Iteration 26: H_t = 4, G_t = -0.8334, σ_t^2 = 40.2323
#     Worker 0: Train Loss: 2.9918, Train Accuracy: 25.84%
#     Worker 1: Train Loss: 3.0174, Train Accuracy: 25.13%
#     Worker 2: Train Loss: 2.9788, Train Accuracy: 25.85%
#     Worker 3: Train Loss: 3.0068, Train Accuracy: 25.05%
# Epoch 16: Test Loss: 2.8464, Test Accuracy: 29.51%
# Epoch 17, Iteration 1: H_t = 4, G_t = 0.3529, σ_t^2 = 30.1659
# Epoch 17, Iteration 2: H_t = 4, G_t = -1.2357, σ_t^2 = 30.4380
# Epoch 17, Iteration 3: H_t = 12, G_t = 1.2641, σ_t^2 = 29.7871
# Epoch 17, Iteration 4: H_t = 4, G_t = -0.9970, σ_t^2 = 40.6498
# Epoch 17, Iteration 5: H_t = 4, G_t = -3.0385, σ_t^2 = 40.1829
# Epoch 17, Iteration 6: H_t = 4, G_t = -1.7706, σ_t^2 = 34.2123
# Epoch 17, Iteration 7: H_t = 13, G_t = 1.2760, σ_t^2 = 27.8803
# Epoch 17, Iteration 8: H_t = 23, G_t = 2.7100, σ_t^2 = 33.9048
# Epoch 17, Iteration 9: H_t = 4, G_t = 0.4281, σ_t^2 = 29.1559
# Epoch 17, Iteration 10: H_t = 7, G_t = 0.9254, σ_t^2 = 37.2155
# Epoch 17, Iteration 11: H_t = 4, G_t = 0.0813, σ_t^2 = 33.6614
# Epoch 17, Iteration 12: H_t = 18, G_t = 1.9786, σ_t^2 = 32.5916
# Epoch 17, Iteration 13: H_t = 10, G_t = 1.0845, σ_t^2 = 31.0166
# Epoch 17, Iteration 14: H_t = 4, G_t = -0.5352, σ_t^2 = 41.4313
# Epoch 17, Iteration 15: H_t = 4, G_t = -0.9873, σ_t^2 = 30.5784
# Epoch 17, Iteration 16: H_t = 4, G_t = 0.5702, σ_t^2 = 37.5282
# Epoch 17, Iteration 17: H_t = 26, G_t = 2.9957, σ_t^2 = 34.4550
# Epoch 17, Iteration 18: H_t = 10, G_t = 1.0757, σ_t^2 = 31.7409
# Epoch 17, Iteration 19: H_t = 11, G_t = 1.0477, σ_t^2 = 28.1184
# Epoch 17, Iteration 20: H_t = 4, G_t = 0.0417, σ_t^2 = 35.1431
# Epoch 17, Iteration 21: H_t = 15, G_t = 1.7530, σ_t^2 = 34.8823
# Epoch 17, Iteration 22: H_t = 4, G_t = -0.7324, σ_t^2 = 43.1353
# Epoch 17, Iteration 23: H_t = 16, G_t = 1.5790, σ_t^2 = 28.8579
#     Worker 0: Train Loss: 2.9453, Train Accuracy: 26.37%
#     Worker 1: Train Loss: 2.9620, Train Accuracy: 26.41%
#     Worker 2: Train Loss: 2.9035, Train Accuracy: 27.87%
#     Worker 3: Train Loss: 2.9427, Train Accuracy: 26.62%
# Epoch 17: Test Loss: 2.7970, Test Accuracy: 30.19%
# Epoch 18, Iteration 1: H_t = 34, G_t = 3.4236, σ_t^2 = 30.1054
# Epoch 18, Iteration 2: H_t = 14, G_t = 1.5324, σ_t^2 = 30.9421
# Epoch 18, Iteration 3: H_t = 23, G_t = 2.5055, σ_t^2 = 31.6756
# Epoch 18, Iteration 4: H_t = 9, G_t = 1.0783, σ_t^2 = 34.2343
# Epoch 18, Iteration 5: H_t = 4, G_t = 0.3370, σ_t^2 = 34.4560
# Epoch 18, Iteration 6: H_t = 39, G_t = 3.8700, σ_t^2 = 29.6665
# Epoch 18, Iteration 7: H_t = 4, G_t = -1.4639, σ_t^2 = 40.8589
# Epoch 18, Iteration 8: H_t = 4, G_t = -1.1221, σ_t^2 = 32.5414
# Epoch 18, Iteration 9: H_t = 6, G_t = 0.6770, σ_t^2 = 32.0722
# Epoch 18, Iteration 10: H_t = 6, G_t = 0.8050, σ_t^2 = 34.6905
# Epoch 18, Iteration 11: H_t = 4, G_t = -4.0712, σ_t^2 = 52.4766
# Epoch 18, Iteration 12: H_t = 4, G_t = -0.4196, σ_t^2 = 38.3309
# Epoch 18, Iteration 13: H_t = 4, G_t = -0.6902, σ_t^2 = 37.5360
# Epoch 18, Iteration 14: H_t = 13, G_t = 1.9673, σ_t^2 = 43.8388
# Epoch 18, Iteration 15: H_t = 4, G_t = 0.5337, σ_t^2 = 43.3326
# Epoch 18, Iteration 16: H_t = 4, G_t = -3.8579, σ_t^2 = 46.8559
# Epoch 18, Iteration 17: H_t = 4, G_t = -0.3178, σ_t^2 = 37.8017
# Epoch 18, Iteration 18: H_t = 64, G_t = 6.9407, σ_t^2 = 31.0225
#     Worker 0: Train Loss: 2.9148, Train Accuracy: 27.00%
#     Worker 1: Train Loss: 2.9420, Train Accuracy: 26.98%
#     Worker 2: Train Loss: 2.8803, Train Accuracy: 28.32%
#     Worker 3: Train Loss: 2.9170, Train Accuracy: 27.26%
# Epoch 18: Test Loss: 2.7515, Test Accuracy: 31.01%
# Epoch 19, Iteration 1: H_t = 47, G_t = 4.3281, σ_t^2 = 27.6251
# Epoch 19, Iteration 2: H_t = 10, G_t = 1.2531, σ_t^2 = 36.9159
# Epoch 19, Iteration 3: H_t = 14, G_t = 1.4619, σ_t^2 = 30.1052
# Epoch 19, Iteration 4: H_t = 4, G_t = -6.0364, σ_t^2 = 52.0921
# Epoch 19, Iteration 5: H_t = 4, G_t = -1.8083, σ_t^2 = 35.8152
# Epoch 19, Iteration 6: H_t = 9, G_t = 1.0134, σ_t^2 = 31.6518
# Epoch 19, Iteration 7: H_t = 9, G_t = 1.2257, σ_t^2 = 39.0849
# Epoch 19, Iteration 8: H_t = 4, G_t = -1.4387, σ_t^2 = 40.1813
# Epoch 19, Iteration 9: H_t = 4, G_t = -1.9323, σ_t^2 = 38.5482
# Epoch 19, Iteration 10: H_t = 4, G_t = -0.0203, σ_t^2 = 35.4840
# Epoch 19, Iteration 11: H_t = 34, G_t = 3.9291, σ_t^2 = 34.0875
# Epoch 19, Iteration 12: H_t = 4, G_t = -0.9956, σ_t^2 = 34.5343
#     Worker 0: Train Loss: 2.8876, Train Accuracy: 27.62%
#     Worker 1: Train Loss: 2.9068, Train Accuracy: 27.62%
#     Worker 2: Train Loss: 2.8611, Train Accuracy: 28.64%
#     Worker 3: Train Loss: 2.9081, Train Accuracy: 28.00%
# Epoch 19: Test Loss: 2.7262, Test Accuracy: 31.49%
# Epoch 20, Iteration 1: H_t = 6, G_t = 0.6587, σ_t^2 = 30.5747
# Epoch 20, Iteration 2: H_t = 22, G_t = 2.3745, σ_t^2 = 31.4343
# Epoch 20, Iteration 3: H_t = 4, G_t = -0.3836, σ_t^2 = 41.6000
# Epoch 20, Iteration 4: H_t = 10, G_t = 1.1650, σ_t^2 = 32.2385
# Epoch 20, Iteration 5: H_t = 18, G_t = 2.6765, σ_t^2 = 42.4926
# Epoch 20, Iteration 6: H_t = 11, G_t = 1.3953, σ_t^2 = 36.3465
# Epoch 20, Iteration 7: H_t = 4, G_t = 0.0828, σ_t^2 = 33.9337
# Epoch 20, Iteration 8: H_t = 4, G_t = -0.0809, σ_t^2 = 37.0207
# Epoch 20, Iteration 9: H_t = 4, G_t = -0.8489, σ_t^2 = 33.6839
# Epoch 20, Iteration 10: H_t = 10, G_t = 1.1191, σ_t^2 = 32.2122
# Epoch 20, Iteration 11: H_t = 4, G_t = -2.0099, σ_t^2 = 42.5189
# Epoch 20, Iteration 12: H_t = 4, G_t = -0.5706, σ_t^2 = 37.1988
# Epoch 20, Iteration 13: H_t = 9, G_t = 1.1351, σ_t^2 = 35.6178
# Epoch 20, Iteration 14: H_t = 4, G_t = -1.6264, σ_t^2 = 44.2327
# Epoch 20, Iteration 15: H_t = 4, G_t = 0.2108, σ_t^2 = 38.4769
# Epoch 20, Iteration 16: H_t = 22, G_t = 2.1719, σ_t^2 = 28.3415
# Epoch 20, Iteration 17: H_t = 18, G_t = 2.6117, σ_t^2 = 41.5905
# Epoch 20, Iteration 18: H_t = 8, G_t = 0.9590, σ_t^2 = 34.5176
# Epoch 20, Iteration 19: H_t = 4, G_t = 0.0535, σ_t^2 = 31.6485
# Epoch 20, Iteration 20: H_t = 4, G_t = -0.3226, σ_t^2 = 38.7567
# Epoch 20, Iteration 21: H_t = 16, G_t = 1.8194, σ_t^2 = 33.4662
# Epoch 20, Iteration 22: H_t = 4, G_t = -3.5570, σ_t^2 = 50.6854
# Epoch 20, Iteration 23: H_t = 4, G_t = -0.5508, σ_t^2 = 36.0332
#     Worker 0: Train Loss: 2.8023, Train Accuracy: 29.16%
#     Worker 1: Train Loss: 2.8344, Train Accuracy: 28.69%
#     Worker 2: Train Loss: 2.7725, Train Accuracy: 30.32%
#     Worker 3: Train Loss: 2.7946, Train Accuracy: 29.64%
# Epoch 20: Test Loss: 2.6710, Test Accuracy: 32.44%
# Epoch 21, Iteration 1: H_t = 13, G_t = 1.5246, σ_t^2 = 34.1855
# Epoch 21, Iteration 2: H_t = 7, G_t = 0.9773, σ_t^2 = 40.2069
# Epoch 21, Iteration 3: H_t = 4, G_t = -0.0648, σ_t^2 = 33.3300
# Epoch 21, Iteration 4: H_t = 4, G_t = -0.3002, σ_t^2 = 36.2762
# Epoch 21, Iteration 5: H_t = 13, G_t = 1.5519, σ_t^2 = 34.9953
# Epoch 21, Iteration 6: H_t = 4, G_t = -2.2393, σ_t^2 = 44.7400
# Epoch 21, Iteration 7: H_t = 4, G_t = -1.5822, σ_t^2 = 41.1139
# Epoch 21, Iteration 8: H_t = 4, G_t = -0.0050, σ_t^2 = 42.0974
# Epoch 21, Iteration 9: H_t = 6, G_t = 0.8648, σ_t^2 = 40.6353
# Epoch 21, Iteration 10: H_t = 4, G_t = -0.3437, σ_t^2 = 42.1178
# Epoch 21, Iteration 11: H_t = 4, G_t = -2.5726, σ_t^2 = 47.5887
# Epoch 21, Iteration 12: H_t = 20, G_t = 2.5580, σ_t^2 = 37.2809
# Epoch 21, Iteration 13: H_t = 4, G_t = -0.1603, σ_t^2 = 39.4209
# Epoch 21, Iteration 14: H_t = 25, G_t = 2.5801, σ_t^2 = 30.1267
# Epoch 21, Iteration 15: H_t = 4, G_t = 0.1037, σ_t^2 = 41.3696
# Epoch 21, Iteration 16: H_t = 4, G_t = 0.2043, σ_t^2 = 33.1800
# Epoch 21, Iteration 17: H_t = 4, G_t = -0.4132, σ_t^2 = 29.9694
# Epoch 21, Iteration 18: H_t = 23, G_t = 2.8167, σ_t^2 = 36.6551
# Epoch 21, Iteration 19: H_t = 9, G_t = 1.1939, σ_t^2 = 36.9937
# Epoch 21, Iteration 20: H_t = 4, G_t = -0.2398, σ_t^2 = 39.6825
# Epoch 21, Iteration 21: H_t = 4, G_t = 0.2831, σ_t^2 = 39.1103
# Epoch 21, Iteration 22: H_t = 4, G_t = -0.5847, σ_t^2 = 40.4489
# Epoch 21, Iteration 23: H_t = 4, G_t = 0.3651, σ_t^2 = 37.5501
# Epoch 21, Iteration 24: H_t = 29, G_t = 3.6090, σ_t^2 = 36.5196
# Epoch 21, Iteration 25: H_t = 4, G_t = 0.4771, σ_t^2 = 44.7755
#     Worker 0: Train Loss: 2.7574, Train Accuracy: 30.45%
#     Worker 1: Train Loss: 2.7714, Train Accuracy: 29.97%
#     Worker 2: Train Loss: 2.7421, Train Accuracy: 31.19%
#     Worker 3: Train Loss: 2.7909, Train Accuracy: 29.94%
# Epoch 21: Test Loss: 2.6481, Test Accuracy: 33.17%
# Epoch 22, Iteration 1: H_t = 22, G_t = 2.8010, σ_t^2 = 37.3469
# Epoch 22, Iteration 2: H_t = 12, G_t = 1.4748, σ_t^2 = 34.8299
# Epoch 22, Iteration 3: H_t = 4, G_t = -1.8396, σ_t^2 = 42.6504
# Epoch 22, Iteration 4: H_t = 4, G_t = -1.3416, σ_t^2 = 45.3431
# Epoch 22, Iteration 5: H_t = 4, G_t = -0.4294, σ_t^2 = 39.7655
# Epoch 22, Iteration 6: H_t = 4, G_t = -1.3733, σ_t^2 = 38.0547
# Epoch 22, Iteration 7: H_t = 28, G_t = 3.4777, σ_t^2 = 36.0606
# Epoch 22, Iteration 8: H_t = 5, G_t = 0.6735, σ_t^2 = 39.5421
# Epoch 22, Iteration 9: H_t = 6, G_t = 0.7133, σ_t^2 = 32.8017
# Epoch 22, Iteration 10: H_t = 31, G_t = 4.2625, σ_t^2 = 40.0963
# Epoch 22, Iteration 11: H_t = 5, G_t = 0.7045, σ_t^2 = 41.9714
# Epoch 22, Iteration 12: H_t = 27, G_t = 3.0942, σ_t^2 = 34.0115
# Epoch 22, Iteration 13: H_t = 4, G_t = 0.4271, σ_t^2 = 41.5478
# Epoch 22, Iteration 14: H_t = 4, G_t = 0.2284, σ_t^2 = 41.1271
# Epoch 22, Iteration 15: H_t = 4, G_t = -1.3233, σ_t^2 = 40.0467
# Epoch 22, Iteration 16: H_t = 34, G_t = 4.0095, σ_t^2 = 34.4011
# Epoch 22, Iteration 17: H_t = 4, G_t = -0.2120, σ_t^2 = 43.9568
#     Worker 0: Train Loss: 2.7399, Train Accuracy: 30.14%
#     Worker 1: Train Loss: 2.7792, Train Accuracy: 29.84%
#     Worker 2: Train Loss: 2.7413, Train Accuracy: 30.56%
#     Worker 3: Train Loss: 2.7496, Train Accuracy: 30.83%
# Epoch 22: Test Loss: 2.5834, Test Accuracy: 33.94%
# Epoch 23, Iteration 1: H_t = 27, G_t = 3.2768, σ_t^2 = 36.2251
# Epoch 23, Iteration 2: H_t = 23, G_t = 2.6570, σ_t^2 = 34.1777
# Epoch 23, Iteration 3: H_t = 4, G_t = -1.0424, σ_t^2 = 44.1860
# Epoch 23, Iteration 4: H_t = 15, G_t = 1.7176, σ_t^2 = 33.5201
# Epoch 23, Iteration 5: H_t = 4, G_t = 0.3242, σ_t^2 = 41.0845
# Epoch 23, Iteration 6: H_t = 29, G_t = 3.5915, σ_t^2 = 36.7299
# Epoch 23, Iteration 7: H_t = 4, G_t = -0.1465, σ_t^2 = 43.8439
# Epoch 23, Iteration 8: H_t = 4, G_t = -0.7676, σ_t^2 = 40.0366
# Epoch 23, Iteration 9: H_t = 31, G_t = 3.7472, σ_t^2 = 35.1853
# Epoch 23, Iteration 10: H_t = 13, G_t = 1.6740, σ_t^2 = 37.8724
# Epoch 23, Iteration 11: H_t = 4, G_t = -3.3033, σ_t^2 = 41.6925
# Epoch 23, Iteration 12: H_t = 14, G_t = 2.2608, σ_t^2 = 47.8869
# Epoch 23, Iteration 13: H_t = 4, G_t = -0.4683, σ_t^2 = 47.2920
# Epoch 23, Iteration 14: H_t = 4, G_t = -0.0918, σ_t^2 = 36.1677
# Epoch 23, Iteration 15: H_t = 42, G_t = 5.2711, σ_t^2 = 36.8218
# Epoch 23, Iteration 16: H_t = 4, G_t = -2.6143, σ_t^2 = 43.7285
#     Worker 0: Train Loss: 2.7061, Train Accuracy: 31.69%
#     Worker 1: Train Loss: 2.7300, Train Accuracy: 30.35%
#     Worker 2: Train Loss: 2.6666, Train Accuracy: 32.19%
#     Worker 3: Train Loss: 2.7084, Train Accuracy: 31.48%
# Epoch 23: Test Loss: 2.5780, Test Accuracy: 34.62%
# Epoch 24, Iteration 1: H_t = 4, G_t = 0.1393, σ_t^2 = 38.0760
# Epoch 24, Iteration 2: H_t = 21, G_t = 2.8691, σ_t^2 = 39.8850
# Epoch 24, Iteration 3: H_t = 9, G_t = 1.4454, σ_t^2 = 44.3223
# Epoch 24, Iteration 4: H_t = 4, G_t = 0.1480, σ_t^2 = 34.3294
# Epoch 24, Iteration 5: H_t = 27, G_t = 4.0389, σ_t^2 = 44.6239
# Epoch 24, Iteration 6: H_t = 16, G_t = 2.1735, σ_t^2 = 39.1704
# Epoch 24, Iteration 7: H_t = 14, G_t = 1.9755, σ_t^2 = 40.0398
# Epoch 24, Iteration 8: H_t = 8, G_t = 1.1838, σ_t^2 = 42.8697
# Epoch 24, Iteration 9: H_t = 4, G_t = -1.4303, σ_t^2 = 46.8966
# Epoch 24, Iteration 10: H_t = 4, G_t = -0.7725, σ_t^2 = 35.8451
# Epoch 24, Iteration 11: H_t = 35, G_t = 4.0269, σ_t^2 = 34.1656
# Epoch 24, Iteration 12: H_t = 5, G_t = 0.5595, σ_t^2 = 32.9819
# Epoch 24, Iteration 13: H_t = 4, G_t = -0.4643, σ_t^2 = 40.3296
# Epoch 24, Iteration 14: H_t = 4, G_t = -0.4545, σ_t^2 = 50.6349
# Epoch 24, Iteration 15: H_t = 12, G_t = 1.9035, σ_t^2 = 44.3849
# Epoch 24, Iteration 16: H_t = 4, G_t = -1.6757, σ_t^2 = 47.1210
# Epoch 24, Iteration 17: H_t = 4, G_t = -0.5472, σ_t^2 = 37.9658
# Epoch 24, Iteration 18: H_t = 8, G_t = 1.0319, σ_t^2 = 35.1774
# Epoch 24, Iteration 19: H_t = 4, G_t = -0.2302, σ_t^2 = 44.1651
# Epoch 24, Iteration 20: H_t = 4, G_t = -0.7145, σ_t^2 = 50.4707
# Epoch 24, Iteration 21: H_t = 4, G_t = 0.4140, σ_t^2 = 42.5080
#     Worker 0: Train Loss: 2.6412, Train Accuracy: 32.39%
#     Worker 1: Train Loss: 2.6539, Train Accuracy: 32.31%
#     Worker 2: Train Loss: 2.6269, Train Accuracy: 33.03%
#     Worker 3: Train Loss: 2.6537, Train Accuracy: 32.56%
# Epoch 24: Test Loss: 2.5135, Test Accuracy: 35.75%
# Epoch 25, Iteration 1: H_t = 50, G_t = 8.1426, σ_t^2 = 48.5555
# Epoch 25, Iteration 2: H_t = 4, G_t = 0.3137, σ_t^2 = 37.4837
# Epoch 25, Iteration 3: H_t = 4, G_t = -0.2146, σ_t^2 = 36.3785
# Epoch 25, Iteration 4: H_t = 29, G_t = 3.1691, σ_t^2 = 32.6753
# Epoch 25, Iteration 5: H_t = 4, G_t = -0.6843, σ_t^2 = 40.4793
# Epoch 25, Iteration 6: H_t = 12, G_t = 1.5244, σ_t^2 = 35.9042
# Epoch 25, Iteration 7: H_t = 21, G_t = 3.1785, σ_t^2 = 44.6410
# Epoch 25, Iteration 8: H_t = 4, G_t = -1.9041, σ_t^2 = 40.1815
# Epoch 25, Iteration 9: H_t = 14, G_t = 1.7496, σ_t^2 = 36.7502
# Epoch 25, Iteration 10: H_t = 4, G_t = -2.2134, σ_t^2 = 42.0911
# Epoch 25, Iteration 11: H_t = 4, G_t = -0.1864, σ_t^2 = 44.4702
# Epoch 25, Iteration 12: H_t = 11, G_t = 1.8062, σ_t^2 = 48.9070
# Epoch 25, Iteration 13: H_t = 4, G_t = -0.7939, σ_t^2 = 51.9742
# Epoch 25, Iteration 14: H_t = 25, G_t = 3.8837, σ_t^2 = 45.5825
# Epoch 25, Iteration 15: H_t = 4, G_t = -1.1180, σ_t^2 = 41.9602
# Epoch 25, Iteration 16: H_t = 16, G_t = 2.0210, σ_t^2 = 35.8317
#     Worker 0: Train Loss: 2.6267, Train Accuracy: 32.27%
#     Worker 1: Train Loss: 2.6552, Train Accuracy: 32.13%
#     Worker 2: Train Loss: 2.5925, Train Accuracy: 33.96%
#     Worker 3: Train Loss: 2.6327, Train Accuracy: 32.55%
# Epoch 25: Test Loss: 2.4813, Test Accuracy: 36.51%
# Epoch 26, Iteration 1: H_t = 4, G_t = -0.0037, σ_t^2 = 41.4813
# Epoch 26, Iteration 2: H_t = 9, G_t = 1.1424, σ_t^2 = 37.2557
# Epoch 26, Iteration 3: H_t = 4, G_t = -0.2061, σ_t^2 = 43.1258
# Epoch 26, Iteration 4: H_t = 4, G_t = -1.5979, σ_t^2 = 46.1485
# Epoch 26, Iteration 5: H_t = 10, G_t = 1.4158, σ_t^2 = 41.5636
# Epoch 26, Iteration 6: H_t = 4, G_t = -0.5299, σ_t^2 = 43.3539
# Epoch 26, Iteration 7: H_t = 4, G_t = -0.1460, σ_t^2 = 41.4317
# Epoch 26, Iteration 8: H_t = 4, G_t = 0.4208, σ_t^2 = 35.8707
# Epoch 26, Iteration 9: H_t = 15, G_t = 2.0720, σ_t^2 = 41.4098
# Epoch 26, Iteration 10: H_t = 4, G_t = -1.6896, σ_t^2 = 50.6260
# Epoch 26, Iteration 11: H_t = 4, G_t = 0.5495, σ_t^2 = 39.2903
# Epoch 26, Iteration 12: H_t = 14, G_t = 1.8406, σ_t^2 = 39.1706
# Epoch 26, Iteration 13: H_t = 23, G_t = 3.3257, σ_t^2 = 41.5943
# Epoch 26, Iteration 14: H_t = 4, G_t = -1.9748, σ_t^2 = 49.3799
# Epoch 26, Iteration 15: H_t = 32, G_t = 4.1298, σ_t^2 = 37.9139
# Epoch 26, Iteration 16: H_t = 6, G_t = 0.9221, σ_t^2 = 40.4134
# Epoch 26, Iteration 17: H_t = 4, G_t = -0.1015, σ_t^2 = 32.6582
# Epoch 26, Iteration 18: H_t = 4, G_t = -1.0444, σ_t^2 = 47.5694
# Epoch 26, Iteration 19: H_t = 41, G_t = 4.5340, σ_t^2 = 32.9736
# Epoch 26, Iteration 20: H_t = 4, G_t = -0.6490, σ_t^2 = 47.8942
#     Worker 0: Train Loss: 2.5872, Train Accuracy: 33.90%
#     Worker 1: Train Loss: 2.5949, Train Accuracy: 33.64%
#     Worker 2: Train Loss: 2.5481, Train Accuracy: 34.75%
#     Worker 3: Train Loss: 2.5823, Train Accuracy: 33.67%
# Epoch 26: Test Loss: 2.4650, Test Accuracy: 36.85%
# Epoch 27, Iteration 1: H_t = 4, G_t = -0.0755, σ_t^2 = 43.2784
# Epoch 27, Iteration 2: H_t = 4, G_t = 0.3624, σ_t^2 = 34.9502
# Epoch 27, Iteration 3: H_t = 57, G_t = 6.2322, σ_t^2 = 32.7910
# Epoch 27, Iteration 4: H_t = 4, G_t = -0.5726, σ_t^2 = 40.2561
# Epoch 27, Iteration 5: H_t = 6, G_t = 0.7899, σ_t^2 = 36.6323
# Epoch 27, Iteration 6: H_t = 16, G_t = 1.8368, σ_t^2 = 34.2909
# Epoch 27, Iteration 7: H_t = 4, G_t = -0.8262, σ_t^2 = 43.2580
# Epoch 27, Iteration 8: H_t = 4, G_t = -1.2384, σ_t^2 = 38.1007
# Epoch 27, Iteration 9: H_t = 14, G_t = 1.6039, σ_t^2 = 32.8815
# Epoch 27, Iteration 10: H_t = 4, G_t = -2.7935, σ_t^2 = 50.9786
# Epoch 27, Iteration 11: H_t = 4, G_t = 0.3145, σ_t^2 = 49.9427
# Epoch 27, Iteration 12: H_t = 4, G_t = -1.6513, σ_t^2 = 43.3188
# Epoch 27, Iteration 13: H_t = 4, G_t = -1.5793, σ_t^2 = 42.5116
# Epoch 27, Iteration 14: H_t = 4, G_t = -0.4863, σ_t^2 = 39.1916
# Epoch 27, Iteration 15: H_t = 21, G_t = 3.0621, σ_t^2 = 42.1302
# Epoch 27, Iteration 16: H_t = 9, G_t = 1.5164, σ_t^2 = 48.5694
# Epoch 27, Iteration 17: H_t = 4, G_t = 0.5970, σ_t^2 = 39.9657
# Epoch 27, Iteration 18: H_t = 4, G_t = 0.1357, σ_t^2 = 44.5581
# Epoch 27, Iteration 19: H_t = 4, G_t = -2.3454, σ_t^2 = 46.5617
# Epoch 27, Iteration 20: H_t = 8, G_t = 1.1507, σ_t^2 = 43.1269
# Epoch 27, Iteration 21: H_t = 4, G_t = -0.4705, σ_t^2 = 43.6214
# Epoch 27, Iteration 22: H_t = 22, G_t = 3.0940, σ_t^2 = 41.5781
# Epoch 27, Iteration 23: H_t = 4, G_t = -1.0210, σ_t^2 = 52.5703
#     Worker 0: Train Loss: 2.5386, Train Accuracy: 34.35%
#     Worker 1: Train Loss: 2.5237, Train Accuracy: 35.20%
#     Worker 2: Train Loss: 2.5239, Train Accuracy: 35.81%
#     Worker 3: Train Loss: 2.5411, Train Accuracy: 34.38%
# Epoch 27: Test Loss: 2.4437, Test Accuracy: 37.40%
# Epoch 28, Iteration 1: H_t = 38, G_t = 4.6175, σ_t^2 = 35.6589
# Epoch 28, Iteration 2: H_t = 4, G_t = -0.3441, σ_t^2 = 44.5899
# Epoch 28, Iteration 3: H_t = 4, G_t = -2.6846, σ_t^2 = 43.7556
# Epoch 28, Iteration 4: H_t = 17, G_t = 2.1933, σ_t^2 = 38.6523
# Epoch 28, Iteration 5: H_t = 4, G_t = -2.5190, σ_t^2 = 47.9546
# Epoch 28, Iteration 6: H_t = 10, G_t = 1.2023, σ_t^2 = 35.7633
# Epoch 28, Iteration 7: H_t = 4, G_t = -4.0471, σ_t^2 = 64.3302
# Epoch 28, Iteration 8: H_t = 4, G_t = -0.7357, σ_t^2 = 110.1560
# Epoch 28, Iteration 9: H_t = 4, G_t = -3.3271, σ_t^2 = 53.9596
# Epoch 28, Iteration 10: H_t = 4, G_t = -0.2648, σ_t^2 = 46.0762
# Epoch 28, Iteration 11: H_t = 12, G_t = 1.6869, σ_t^2 = 42.0610
# Epoch 28, Iteration 12: H_t = 4, G_t = 0.1965, σ_t^2 = 43.3633
# Epoch 28, Iteration 13: H_t = 5, G_t = 0.9231, σ_t^2 = 50.6774
# Epoch 28, Iteration 14: H_t = 19, G_t = 3.2050, σ_t^2 = 49.9288
# Epoch 28, Iteration 15: H_t = 21, G_t = 3.2021, σ_t^2 = 45.4662
# Epoch 28, Iteration 16: H_t = 17, G_t = 2.5242, σ_t^2 = 42.7106
# Epoch 28, Iteration 17: H_t = 4, G_t = -0.4182, σ_t^2 = 54.7821
# Epoch 28, Iteration 18: H_t = 4, G_t = 0.2541, σ_t^2 = 40.2859
# Epoch 28, Iteration 19: H_t = 37, G_t = 5.2900, σ_t^2 = 42.5128
# Epoch 28, Iteration 20: H_t = 4, G_t = -0.6056, σ_t^2 = 46.7194
#     Worker 0: Train Loss: 2.5096, Train Accuracy: 35.26%
#     Worker 1: Train Loss: 2.5437, Train Accuracy: 34.08%
#     Worker 2: Train Loss: 2.4688, Train Accuracy: 36.15%
#     Worker 3: Train Loss: 2.5491, Train Accuracy: 34.68%
# Epoch 28: Test Loss: 2.4103, Test Accuracy: 38.00%
# Epoch 29, Iteration 1: H_t = 11, G_t = 1.4594, σ_t^2 = 37.3074
# Epoch 29, Iteration 2: H_t = 4, G_t = -0.0429, σ_t^2 = 41.6168
# Epoch 29, Iteration 3: H_t = 4, G_t = -0.7455, σ_t^2 = 44.2315
# Epoch 29, Iteration 4: H_t = 9, G_t = 1.2310, σ_t^2 = 36.9954
# Epoch 29, Iteration 5: H_t = 38, G_t = 6.2451, σ_t^2 = 48.4016
# Epoch 29, Iteration 6: H_t = 4, G_t = -1.0109, σ_t^2 = 42.0403
# Epoch 29, Iteration 7: H_t = 4, G_t = -0.2450, σ_t^2 = 46.3941
# Epoch 29, Iteration 8: H_t = 4, G_t = -1.3126, σ_t^2 = 43.0931
# Epoch 29, Iteration 9: H_t = 13, G_t = 1.5765, σ_t^2 = 35.4491
# Epoch 29, Iteration 10: H_t = 23, G_t = 3.7137, σ_t^2 = 47.1455
# Epoch 29, Iteration 11: H_t = 4, G_t = 0.0052, σ_t^2 = 47.7157
# Epoch 29, Iteration 12: H_t = 20, G_t = 2.6226, σ_t^2 = 38.9632
# Epoch 29, Iteration 13: H_t = 9, G_t = 1.4322, σ_t^2 = 47.2672
# Epoch 29, Iteration 14: H_t = 4, G_t = -0.5787, σ_t^2 = 46.3454
# Epoch 29, Iteration 15: H_t = 20, G_t = 2.7464, σ_t^2 = 39.2838
# Epoch 29, Iteration 16: H_t = 12, G_t = 1.9817, σ_t^2 = 47.1087
# Epoch 29, Iteration 17: H_t = 4, G_t = -0.4252, σ_t^2 = 43.8227
# Epoch 29, Iteration 18: H_t = 14, G_t = 2.3147, σ_t^2 = 49.2722
# Epoch 29, Iteration 19: H_t = 4, G_t = -1.2316, σ_t^2 = 48.8358
#     Worker 0: Train Loss: 2.4640, Train Accuracy: 35.74%
#     Worker 1: Train Loss: 2.4842, Train Accuracy: 35.68%
#     Worker 2: Train Loss: 2.4591, Train Accuracy: 36.88%
#     Worker 3: Train Loss: 2.4656, Train Accuracy: 36.25%
# Epoch 29: Test Loss: 2.3679, Test Accuracy: 38.81%
# Epoch 30, Iteration 1: H_t = 4, G_t = -0.5096, σ_t^2 = 44.5501
# Epoch 30, Iteration 2: H_t = 26, G_t = 3.7583, σ_t^2 = 42.1052
# Epoch 30, Iteration 3: H_t = 4, G_t = -0.3369, σ_t^2 = 40.7010
# Epoch 30, Iteration 4: H_t = 4, G_t = -0.8754, σ_t^2 = 44.5160
# Epoch 30, Iteration 5: H_t = 4, G_t = -1.5645, σ_t^2 = 42.9182
# Epoch 30, Iteration 6: H_t = 4, G_t = -0.0113, σ_t^2 = 37.6102
# Epoch 30, Iteration 7: H_t = 16, G_t = 1.9222, σ_t^2 = 35.5476
# Epoch 30, Iteration 8: H_t = 4, G_t = -0.1600, σ_t^2 = 48.4648
# Epoch 30, Iteration 9: H_t = 4, G_t = -0.8125, σ_t^2 = 46.9301
# Epoch 30, Iteration 10: H_t = 8, G_t = 1.2229, σ_t^2 = 42.0476
# Epoch 30, Iteration 11: H_t = 13, G_t = 2.0533, σ_t^2 = 45.3738
# Epoch 30, Iteration 12: H_t = 34, G_t = 5.1091, σ_t^2 = 44.7886
# Epoch 30, Iteration 13: H_t = 4, G_t = 0.0821, σ_t^2 = 41.8707
# Epoch 30, Iteration 14: H_t = 15, G_t = 2.1347, σ_t^2 = 40.8639
# Epoch 30, Iteration 15: H_t = 4, G_t = -1.1817, σ_t^2 = 41.8312
# Epoch 30, Iteration 16: H_t = 4, G_t = -1.5488, σ_t^2 = 46.0439
# Epoch 30, Iteration 17: H_t = 5, G_t = 0.9062, σ_t^2 = 46.7917
# Epoch 30, Iteration 18: H_t = 11, G_t = 1.9178, σ_t^2 = 48.7130
# Epoch 30, Iteration 19: H_t = 9, G_t = 1.6353, σ_t^2 = 50.2750
# Epoch 30, Iteration 20: H_t = 7, G_t = 1.2451, σ_t^2 = 47.5792
# Epoch 30, Iteration 21: H_t = 4, G_t = -2.1974, σ_t^2 = 48.1495
# Epoch 30, Iteration 22: H_t = 14, G_t = 2.2056, σ_t^2 = 46.1814
# Epoch 30, Iteration 23: H_t = 4, G_t = -2.2301, σ_t^2 = 51.7026
#     Worker 0: Train Loss: 2.4331, Train Accuracy: 37.43%
#     Worker 1: Train Loss: 2.4581, Train Accuracy: 36.38%
#     Worker 2: Train Loss: 2.4127, Train Accuracy: 37.39%
#     Worker 3: Train Loss: 2.4496, Train Accuracy: 36.99%
# Epoch 30: Test Loss: 2.3464, Test Accuracy: 39.34%
# Epoch 31, Iteration 1: H_t = 4, G_t = 0.5022, σ_t^2 = 47.9347
# Epoch 31, Iteration 2: H_t = 4, G_t = -0.9998, σ_t^2 = 51.1145
# Epoch 31, Iteration 3: H_t = 6, G_t = 0.8944, σ_t^2 = 43.8803
# Epoch 31, Iteration 4: H_t = 4, G_t = -1.9771, σ_t^2 = 46.4180
# Epoch 31, Iteration 5: H_t = 4, G_t = -0.2137, σ_t^2 = 51.4568
# Epoch 31, Iteration 6: H_t = 4, G_t = 0.2274, σ_t^2 = 58.6140
# Epoch 31, Iteration 7: H_t = 11, G_t = 1.8788, σ_t^2 = 49.5831
# Epoch 31, Iteration 8: H_t = 4, G_t = 0.7848, σ_t^2 = 49.1523
# Epoch 31, Iteration 9: H_t = 4, G_t = -3.5056, σ_t^2 = 57.5098
# Epoch 31, Iteration 10: H_t = 21, G_t = 2.8775, σ_t^2 = 40.1522
# Epoch 31, Iteration 11: H_t = 4, G_t = -0.3685, σ_t^2 = 53.6829
# Epoch 31, Iteration 12: H_t = 8, G_t = 1.0739, σ_t^2 = 39.9373
# Epoch 31, Iteration 13: H_t = 4, G_t = -1.8845, σ_t^2 = 44.5383
# Epoch 31, Iteration 14: H_t = 4, G_t = -1.1810, σ_t^2 = 49.5879
# Epoch 31, Iteration 15: H_t = 12, G_t = 1.7233, σ_t^2 = 42.1307
# Epoch 31, Iteration 16: H_t = 4, G_t = -2.9139, σ_t^2 = 53.6998
# Epoch 31, Iteration 17: H_t = 4, G_t = -3.6700, σ_t^2 = 55.8973
# Epoch 31, Iteration 18: H_t = 25, G_t = 3.4619, σ_t^2 = 40.6095
# Epoch 31, Iteration 19: H_t = 35, G_t = 5.9405, σ_t^2 = 49.8625
# Epoch 31, Iteration 20: H_t = 4, G_t = 0.2146, σ_t^2 = 49.8675
# Epoch 31, Iteration 21: H_t = 20, G_t = 2.4158, σ_t^2 = 35.7410
# Epoch 31, Iteration 22: H_t = 4, G_t = -0.6878, σ_t^2 = 52.3944
# Epoch 31, Iteration 23: H_t = 7, G_t = 1.0524, σ_t^2 = 44.0767
# ...
#     Worker 0: Train Loss: 1.5358, Train Accuracy: 56.94%
#     Worker 1: Train Loss: 1.5549, Train Accuracy: 57.22%
#     Worker 2: Train Loss: 1.5480, Train Accuracy: 57.12%
#     Worker 3: Train Loss: 1.5324, Train Accuracy: 57.91%
# Epoch 83: Test Loss: 1.9543, Test Accuracy: 49.15%
# Epoch 84, Iteration 1: H_t = 5, G_t = 1.6113, σ_t^2 = 82.6325
# Epoch 84, Iteration 2: H_t = 7, G_t = 2.3892, σ_t^2 = 90.7757
# Epoch 84, Iteration 3: H_t = 4, G_t = -4.2911, σ_t^2 = 95.5969
# Epoch 84, Iteration 4: H_t = 26, G_t = 7.1778, σ_t^2 = 82.4484
# Epoch 84, Iteration 5: H_t = 4, G_t = 0.4914, σ_t^2 = 91.4795
# Epoch 84, Iteration 6: H_t = 4, G_t = 0.7176, σ_t^2 = 85.3659
# Epoch 84, Iteration 7: H_t = 12, G_t = 3.5852, σ_t^2 = 83.9804
# Epoch 84, Iteration 8: H_t = 6, G_t = 1.8532, σ_t^2 = 86.1797
# Epoch 84, Iteration 9: H_t = 4, G_t = 0.8941, σ_t^2 = 89.8930
# Epoch 84, Iteration 10: H_t = 4, G_t = 0.1864, σ_t^2 = 81.5516
# Epoch 84, Iteration 11: H_t = 4, G_t = 0.4953, σ_t^2 = 76.8274
# Epoch 84, Iteration 12: H_t = 9, G_t = 3.0246, σ_t^2 = 91.1221
# Epoch 84, Iteration 13: H_t = 4, G_t = -1.4888, σ_t^2 = 97.0167
# Epoch 84, Iteration 14: H_t = 4, G_t = -0.7537, σ_t^2 = 80.8684
# Epoch 84, Iteration 15: H_t = 4, G_t = 0.8287, σ_t^2 = 77.6241
# Epoch 84, Iteration 16: H_t = 4, G_t = -0.2645, σ_t^2 = 75.1772
# Epoch 84, Iteration 17: H_t = 11, G_t = 3.3184, σ_t^2 = 83.2500
# Epoch 84, Iteration 18: H_t = 5, G_t = 1.5547, σ_t^2 = 89.4772
# Epoch 84, Iteration 19: H_t = 4, G_t = 1.1110, σ_t^2 = 94.1082
# Epoch 84, Iteration 20: H_t = 24, G_t = 5.8684, σ_t^2 = 73.1978
# Epoch 84, Iteration 21: H_t = 4, G_t = -1.4260, σ_t^2 = 95.8376
# Epoch 84, Iteration 22: H_t = 4, G_t = -2.4453, σ_t^2 = 75.3610
# Epoch 84, Iteration 23: H_t = 4, G_t = 0.1312, σ_t^2 = 77.5761
# Epoch 84, Iteration 24: H_t = 4, G_t = 0.4137, σ_t^2 = 79.5123
# Epoch 84, Iteration 25: H_t = 4, G_t = -1.8303, σ_t^2 = 87.5107
# Epoch 84, Iteration 26: H_t = 4, G_t = -0.4352, σ_t^2 = 86.6595
# Epoch 84, Iteration 27: H_t = 18, G_t = 5.2847, σ_t^2 = 87.2665
# Epoch 84, Iteration 28: H_t = 4, G_t = 0.5482, σ_t^2 = 82.0182
# Epoch 84, Iteration 29: H_t = 4, G_t = 0.5208, σ_t^2 = 72.4764
#     Worker 0: Train Loss: 1.5549, Train Accuracy: 56.18%
#     Worker 1: Train Loss: 1.5632, Train Accuracy: 56.29%
#     Worker 2: Train Loss: 1.5478, Train Accuracy: 57.27%
#     Worker 3: Train Loss: 1.5375, Train Accuracy: 57.34%
# Epoch 84: Test Loss: 1.9579, Test Accuracy: 49.69%
# Epoch 85, Iteration 1: H_t = 7, G_t = 1.7206, σ_t^2 = 66.9998
# Epoch 85, Iteration 2: H_t = 4, G_t = -2.5351, σ_t^2 = 96.7718
# Epoch 85, Iteration 3: H_t = 4, G_t = 0.4187, σ_t^2 = 77.7896
# Epoch 85, Iteration 4: H_t = 4, G_t = -0.2055, σ_t^2 = 93.0509
# Epoch 85, Iteration 5: H_t = 4, G_t = 0.5956, σ_t^2 = 77.7346
# Epoch 85, Iteration 6: H_t = 4, G_t = -2.5764, σ_t^2 = 79.3750
# Epoch 85, Iteration 7: H_t = 4, G_t = -1.6434, σ_t^2 = 76.2858
# Epoch 85, Iteration 8: H_t = 4, G_t = 1.2121, σ_t^2 = 82.1692
# Epoch 85, Iteration 9: H_t = 4, G_t = 1.0481, σ_t^2 = 85.3614
# Epoch 85, Iteration 10: H_t = 4, G_t = 0.4966, σ_t^2 = 79.6618
# Epoch 85, Iteration 11: H_t = 4, G_t = 1.0950, σ_t^2 = 82.7786
# Epoch 85, Iteration 12: H_t = 11, G_t = 3.2288, σ_t^2 = 81.3662
# Epoch 85, Iteration 13: H_t = 4, G_t = 0.6254, σ_t^2 = 87.9988
# Epoch 85, Iteration 14: H_t = 12, G_t = 2.8733, σ_t^2 = 70.2437
# Epoch 85, Iteration 15: H_t = 4, G_t = -0.5787, σ_t^2 = 98.9507
# Epoch 85, Iteration 16: H_t = 4, G_t = 0.0057, σ_t^2 = 79.9697
# Epoch 85, Iteration 17: H_t = 12, G_t = 3.3662, σ_t^2 = 77.9699
# Epoch 85, Iteration 18: H_t = 4, G_t = -0.1945, σ_t^2 = 102.2949
# Epoch 85, Iteration 19: H_t = 8, G_t = 2.2333, σ_t^2 = 82.2608
# Epoch 85, Iteration 20: H_t = 4, G_t = -1.2929, σ_t^2 = 93.3797
# Epoch 85, Iteration 21: H_t = 4, G_t = 0.5595, σ_t^2 = 88.8862
# Epoch 85, Iteration 22: H_t = 4, G_t = 0.9039, σ_t^2 = 72.5909
# Epoch 85, Iteration 23: H_t = 5, G_t = 1.5889, σ_t^2 = 85.3775
# Epoch 85, Iteration 24: H_t = 4, G_t = 0.6307, σ_t^2 = 78.5536
# Epoch 85, Iteration 25: H_t = 4, G_t = 0.2660, σ_t^2 = 83.2700
# Epoch 85, Iteration 26: H_t = 8, G_t = 2.4413, σ_t^2 = 87.9934
# Epoch 85, Iteration 27: H_t = 12, G_t = 4.0032, σ_t^2 = 95.3119
# Epoch 85, Iteration 28: H_t = 12, G_t = 4.0202, σ_t^2 = 96.6323
# Epoch 85, Iteration 29: H_t = 4, G_t = -0.3542, σ_t^2 = 84.8768
# Epoch 85, Iteration 30: H_t = 4, G_t = 0.0434, σ_t^2 = 87.3638
# Epoch 85, Iteration 31: H_t = 6, G_t = 1.6516, σ_t^2 = 76.4472
# Epoch 85, Iteration 32: H_t = 8, G_t = 6.5160, σ_t^2 = 219.4522
# Epoch 85, Iteration 33: H_t = 8, G_t = 2.7497, σ_t^2 = 96.8037
# Epoch 85, Iteration 34: H_t = 4, G_t = 0.3534, σ_t^2 = 88.5497
#     Worker 0: Train Loss: 1.5227, Train Accuracy: 57.05%
#     Worker 1: Train Loss: 1.5265, Train Accuracy: 57.70%
#     Worker 2: Train Loss: 1.5270, Train Accuracy: 58.03%
#     Worker 3: Train Loss: 1.5350, Train Accuracy: 57.35%
# Epoch 85: Test Loss: 1.9598, Test Accuracy: 49.61%
# Epoch 86, Iteration 1: H_t = 5, G_t = 1.5874, σ_t^2 = 85.2827
# Epoch 86, Iteration 2: H_t = 4, G_t = -3.4309, σ_t^2 = 93.3745
# Epoch 86, Iteration 3: H_t = 12, G_t = 3.6341, σ_t^2 = 89.6700
# Epoch 86, Iteration 4: H_t = 7, G_t = 2.0936, σ_t^2 = 86.9950
# Epoch 86, Iteration 5: H_t = 4, G_t = 0.7287, σ_t^2 = 91.0404
# Epoch 86, Iteration 6: H_t = 4, G_t = 0.3457, σ_t^2 = 74.4599
# Epoch 86, Iteration 7: H_t = 7, G_t = 1.8282, σ_t^2 = 78.3237
# Epoch 86, Iteration 8: H_t = 14, G_t = 4.0027, σ_t^2 = 81.7624
# Epoch 86, Iteration 9: H_t = 4, G_t = 0.1039, σ_t^2 = 97.7613
# Epoch 86, Iteration 10: H_t = 4, G_t = 0.4471, σ_t^2 = 82.4617
# Epoch 86, Iteration 11: H_t = 14, G_t = 3.8006, σ_t^2 = 80.9161
# Epoch 86, Iteration 12: H_t = 4, G_t = 0.4812, σ_t^2 = 85.2604
# Epoch 86, Iteration 13: H_t = 5, G_t = 1.7086, σ_t^2 = 91.9150
# Epoch 86, Iteration 14: H_t = 4, G_t = -0.5349, σ_t^2 = 87.5999
# Epoch 86, Iteration 15: H_t = 4, G_t = 0.9721, σ_t^2 = 80.1671
# Epoch 86, Iteration 16: H_t = 4, G_t = 0.5057, σ_t^2 = 74.8187
# Epoch 86, Iteration 17: H_t = 6, G_t = 1.7253, σ_t^2 = 80.3421
# Epoch 86, Iteration 18: H_t = 18, G_t = 6.3363, σ_t^2 = 105.3753
# Epoch 86, Iteration 19: H_t = 4, G_t = 1.2594, σ_t^2 = 90.8260
# Epoch 86, Iteration 20: H_t = 4, G_t = -0.3863, σ_t^2 = 82.2905
# Epoch 86, Iteration 21: H_t = 4, G_t = -0.8477, σ_t^2 = 94.7776
# Epoch 86, Iteration 22: H_t = 21, G_t = 5.7343, σ_t^2 = 81.8994
# Epoch 86, Iteration 23: H_t = 4, G_t = 0.3144, σ_t^2 = 94.4628
# Epoch 86, Iteration 24: H_t = 15, G_t = 4.1237, σ_t^2 = 81.0922
# Epoch 86, Iteration 25: H_t = 4, G_t = -6.5541, σ_t^2 = 229.8862
# Epoch 86, Iteration 26: H_t = 4, G_t = 0.5580, σ_t^2 = 78.3042
# Epoch 86, Iteration 27: H_t = 6, G_t = 1.5897, σ_t^2 = 68.5933
# Epoch 86, Iteration 28: H_t = 4, G_t = 1.1997, σ_t^2 = 75.0962
# Epoch 86, Iteration 29: H_t = 6, G_t = 1.8000, σ_t^2 = 77.6170
#     Worker 0: Train Loss: 1.5159, Train Accuracy: 57.35%
#     Worker 1: Train Loss: 1.5265, Train Accuracy: 57.01%
#     Worker 2: Train Loss: 1.5266, Train Accuracy: 57.75%
#     Worker 3: Train Loss: 1.5193, Train Accuracy: 57.95%
# Epoch 86: Test Loss: 1.9662, Test Accuracy: 49.55%
# Epoch 87, Iteration 1: H_t = 4, G_t = -0.2460, σ_t^2 = 76.2182
# Epoch 87, Iteration 2: H_t = 4, G_t = 1.0601, σ_t^2 = 88.8449
# Epoch 87, Iteration 3: H_t = 6, G_t = 1.7802, σ_t^2 = 81.4019
# Epoch 87, Iteration 4: H_t = 4, G_t = 1.3362, σ_t^2 = 94.9936
# Epoch 87, Iteration 5: H_t = 4, G_t = -0.1693, σ_t^2 = 79.7382
# Epoch 87, Iteration 6: H_t = 4, G_t = 1.0588, σ_t^2 = 75.5979
# Epoch 87, Iteration 7: H_t = 16, G_t = 4.8048, σ_t^2 = 85.8381
# Epoch 87, Iteration 8: H_t = 4, G_t = 0.0074, σ_t^2 = 95.8916
# Epoch 87, Iteration 9: H_t = 4, G_t = 1.2353, σ_t^2 = 86.4926
# Epoch 87, Iteration 10: H_t = 9, G_t = 2.7300, σ_t^2 = 82.0996
# Epoch 87, Iteration 11: H_t = 4, G_t = 0.7873, σ_t^2 = 88.2593
# Epoch 87, Iteration 12: H_t = 4, G_t = -0.7677, σ_t^2 = 96.2018
# Epoch 87, Iteration 13: H_t = 4, G_t = -3.6507, σ_t^2 = 97.0625
# Epoch 87, Iteration 14: H_t = 26, G_t = 8.4427, σ_t^2 = 93.9218
# Epoch 87, Iteration 15: H_t = 4, G_t = 1.3000, σ_t^2 = 90.2688
# Epoch 87, Iteration 16: H_t = 4, G_t = 0.0089, σ_t^2 = 89.2516
# Epoch 87, Iteration 17: H_t = 4, G_t = -1.5643, σ_t^2 = 98.6365
# Epoch 87, Iteration 18: H_t = 6, G_t = 1.8836, σ_t^2 = 83.0158
# Epoch 87, Iteration 19: H_t = 10, G_t = 2.8546, σ_t^2 = 81.8540
# Epoch 87, Iteration 20: H_t = 4, G_t = -2.8591, σ_t^2 = 98.2189
# Epoch 87, Iteration 21: H_t = 4, G_t = -2.5840, σ_t^2 = 82.4744
# Epoch 87, Iteration 22: H_t = 22, G_t = 6.1851, σ_t^2 = 83.4098
# Epoch 87, Iteration 23: H_t = 4, G_t = -1.2342, σ_t^2 = 97.2667
# Epoch 87, Iteration 24: H_t = 4, G_t = 0.2633, σ_t^2 = 91.9136
# Epoch 87, Iteration 25: H_t = 13, G_t = 3.7289, σ_t^2 = 83.4224
# Epoch 87, Iteration 26: H_t = 4, G_t = -0.4625, σ_t^2 = 86.8200
# Epoch 87, Iteration 27: H_t = 5, G_t = 1.4418, σ_t^2 = 78.1826
# Epoch 87, Iteration 28: H_t = 4, G_t = -1.3475, σ_t^2 = 84.1997
# Epoch 87, Iteration 29: H_t = 6, G_t = 1.6566, σ_t^2 = 81.6521
# Epoch 87, Iteration 30: H_t = 4, G_t = 0.6890, σ_t^2 = 88.0237
#     Worker 0: Train Loss: 1.5029, Train Accuracy: 58.20%
#     Worker 1: Train Loss: 1.5291, Train Accuracy: 57.59%
#     Worker 2: Train Loss: 1.5056, Train Accuracy: 57.99%
#     Worker 3: Train Loss: 1.5314, Train Accuracy: 57.62%
# Epoch 87: Test Loss: 1.9513, Test Accuracy: 49.74%
# Epoch 88, Iteration 1: H_t = 4, G_t = 0.4161, σ_t^2 = 78.6799
# Epoch 88, Iteration 2: H_t = 13, G_t = 3.4659, σ_t^2 = 78.6267
# Epoch 88, Iteration 3: H_t = 4, G_t = 1.3519, σ_t^2 = 102.4079
# Epoch 88, Iteration 4: H_t = 4, G_t = 0.4542, σ_t^2 = 87.8472
# Epoch 88, Iteration 5: H_t = 9, G_t = 2.6227, σ_t^2 = 85.5674
# Epoch 88, Iteration 6: H_t = 7, G_t = 1.8633, σ_t^2 = 73.6953
# Epoch 88, Iteration 7: H_t = 4, G_t = -0.0825, σ_t^2 = 82.7654
# Epoch 88, Iteration 8: H_t = 4, G_t = 1.2249, σ_t^2 = 85.7671
# Epoch 88, Iteration 9: H_t = 10, G_t = 3.0004, σ_t^2 = 82.1939
# Epoch 88, Iteration 10: H_t = 8, G_t = 2.6040, σ_t^2 = 90.0881
# Epoch 88, Iteration 11: H_t = 4, G_t = -2.2327, σ_t^2 = 99.6151
# Epoch 88, Iteration 12: H_t = 4, G_t = 0.7699, σ_t^2 = 79.2440
# Epoch 88, Iteration 13: H_t = 4, G_t = -0.9474, σ_t^2 = 77.0298
# Epoch 88, Iteration 14: H_t = 9, G_t = 3.1979, σ_t^2 = 96.4585
# Epoch 88, Iteration 15: H_t = 4, G_t = 1.0505, σ_t^2 = 105.5599
# Epoch 88, Iteration 16: H_t = 4, G_t = -0.7349, σ_t^2 = 87.3621
# Epoch 88, Iteration 17: H_t = 18, G_t = 5.4185, σ_t^2 = 89.1689
# Epoch 88, Iteration 18: H_t = 4, G_t = -1.9704, σ_t^2 = 95.8605
# Epoch 88, Iteration 19: H_t = 4, G_t = -0.1591, σ_t^2 = 95.7612
# Epoch 88, Iteration 20: H_t = 4, G_t = 0.6907, σ_t^2 = 84.3598
# Epoch 88, Iteration 21: H_t = 6, G_t = 1.5822, σ_t^2 = 71.6329
# Epoch 88, Iteration 22: H_t = 4, G_t = -1.6740, σ_t^2 = 108.8088
# Epoch 88, Iteration 23: H_t = 4, G_t = -0.7621, σ_t^2 = 82.3133
# Epoch 88, Iteration 24: H_t = 4, G_t = 0.8183, σ_t^2 = 91.1366
# Epoch 88, Iteration 25: H_t = 4, G_t = 0.1029, σ_t^2 = 83.5713
# Epoch 88, Iteration 26: H_t = 4, G_t = 1.2251, σ_t^2 = 82.0770
# Epoch 88, Iteration 27: H_t = 4, G_t = -3.4689, σ_t^2 = 86.4165
# Epoch 88, Iteration 28: H_t = 4, G_t = 1.4614, σ_t^2 = 96.2793
# Epoch 88, Iteration 29: H_t = 9, G_t = 2.8751, σ_t^2 = 90.5451
# Epoch 88, Iteration 30: H_t = 4, G_t = -2.4198, σ_t^2 = 283.3494
# Epoch 88, Iteration 31: H_t = 4, G_t = -1.5025, σ_t^2 = 86.1446
# Epoch 88, Iteration 32: H_t = 26, G_t = 6.8151, σ_t^2 = 78.5330
# Epoch 88, Iteration 33: H_t = 4, G_t = -5.0883, σ_t^2 = 97.0254
#     Worker 0: Train Loss: 1.4934, Train Accuracy: 58.10%
#     Worker 1: Train Loss: 1.5004, Train Accuracy: 57.90%
#     Worker 2: Train Loss: 1.5042, Train Accuracy: 58.51%
#     Worker 3: Train Loss: 1.5019, Train Accuracy: 58.38%
# Epoch 88: Test Loss: 1.9540, Test Accuracy: 49.90%
# Epoch 89, Iteration 1: H_t = 4, G_t = -1.3986, σ_t^2 = 85.3786
# Epoch 89, Iteration 2: H_t = 5, G_t = 1.4062, σ_t^2 = 72.1011
# Epoch 89, Iteration 3: H_t = 18, G_t = 5.2006, σ_t^2 = 84.2072
# Epoch 89, Iteration 4: H_t = 8, G_t = 2.3986, σ_t^2 = 89.2472
# Epoch 89, Iteration 5: H_t = 4, G_t = -0.7985, σ_t^2 = 77.8851
# Epoch 89, Iteration 6: H_t = 4, G_t = 0.1949, σ_t^2 = 84.6511
# Epoch 89, Iteration 7: H_t = 7, G_t = 2.1020, σ_t^2 = 88.5225
# Epoch 89, Iteration 8: H_t = 4, G_t = 0.2669, σ_t^2 = 93.8021
# Epoch 89, Iteration 9: H_t = 4, G_t = 0.4447, σ_t^2 = 81.0120
# Epoch 89, Iteration 10: H_t = 9, G_t = 2.2179, σ_t^2 = 71.5444
# Epoch 89, Iteration 11: H_t = 12, G_t = 4.3257, σ_t^2 = 100.3256
# Epoch 89, Iteration 12: H_t = 4, G_t = -0.4002, σ_t^2 = 88.1990
# Epoch 89, Iteration 13: H_t = 4, G_t = -1.8594, σ_t^2 = 92.7218
# Epoch 89, Iteration 14: H_t = 4, G_t = 1.1075, σ_t^2 = 93.6404
# Epoch 89, Iteration 15: H_t = 7, G_t = 2.1967, σ_t^2 = 90.4102
# Epoch 89, Iteration 16: H_t = 4, G_t = 0.5599, σ_t^2 = 84.6901
# Epoch 89, Iteration 17: H_t = 6, G_t = 1.9132, σ_t^2 = 84.1593
# Epoch 89, Iteration 18: H_t = 11, G_t = 3.5205, σ_t^2 = 93.6976
# Epoch 89, Iteration 19: H_t = 4, G_t = -0.8063, σ_t^2 = 100.4644
# Epoch 89, Iteration 20: H_t = 4, G_t = -4.2371, σ_t^2 = 105.2139
# Epoch 89, Iteration 21: H_t = 4, G_t = -0.6461, σ_t^2 = 98.2529
# Epoch 89, Iteration 22: H_t = 11, G_t = 3.3177, σ_t^2 = 88.2429
# Epoch 89, Iteration 23: H_t = 4, G_t = -3.9922, σ_t^2 = 108.2561
# Epoch 89, Iteration 24: H_t = 4, G_t = 1.2080, σ_t^2 = 87.6274
# Epoch 89, Iteration 25: H_t = 7, G_t = 2.1207, σ_t^2 = 83.0530
# Epoch 89, Iteration 26: H_t = 4, G_t = 0.1435, σ_t^2 = 88.8195
# Epoch 89, Iteration 27: H_t = 4, G_t = -1.0153, σ_t^2 = 94.5177
# Epoch 89, Iteration 28: H_t = 4, G_t = 0.5502, σ_t^2 = 89.5390
# Epoch 89, Iteration 29: H_t = 14, G_t = 4.0376, σ_t^2 = 85.0759
# Epoch 89, Iteration 30: H_t = 13, G_t = 3.8238, σ_t^2 = 87.6625
# Epoch 89, Iteration 31: H_t = 4, G_t = 1.4481, σ_t^2 = 88.3353
#     Worker 0: Train Loss: 1.4949, Train Accuracy: 58.04%
#     Worker 1: Train Loss: 1.5076, Train Accuracy: 57.93%
#     Worker 2: Train Loss: 1.4911, Train Accuracy: 58.46%
#     Worker 3: Train Loss: 1.5045, Train Accuracy: 58.33%
# Epoch 89: Test Loss: 1.9736, Test Accuracy: 49.30%
# Epoch 90, Iteration 1: H_t = 4, G_t = -0.2214, σ_t^2 = 99.8783
# Epoch 90, Iteration 2: H_t = 20, G_t = 5.1383, σ_t^2 = 75.7861
# Epoch 90, Iteration 3: H_t = 4, G_t = 1.3256, σ_t^2 = 97.8226
# Epoch 90, Iteration 4: H_t = 6, G_t = 1.8261, σ_t^2 = 86.8181
# Epoch 90, Iteration 5: H_t = 12, G_t = 3.8532, σ_t^2 = 92.9263
# Epoch 90, Iteration 6: H_t = 4, G_t = -2.5572, σ_t^2 = 102.0442
# Epoch 90, Iteration 7: H_t = 14, G_t = 3.5628, σ_t^2 = 75.1365
# Epoch 90, Iteration 8: H_t = 4, G_t = -0.2441, σ_t^2 = 94.4357
# Epoch 90, Iteration 9: H_t = 7, G_t = 2.4141, σ_t^2 = 93.9855
# Epoch 90, Iteration 10: H_t = 4, G_t = 1.4999, σ_t^2 = 94.9873
# Epoch 90, Iteration 11: H_t = 13, G_t = 3.4149, σ_t^2 = 73.7879
# Epoch 90, Iteration 12: H_t = 7, G_t = 2.4538, σ_t^2 = 96.0888
# Epoch 90, Iteration 13: H_t = 4, G_t = -1.6792, σ_t^2 = 90.8478
# Epoch 90, Iteration 14: H_t = 4, G_t = 0.1448, σ_t^2 = 93.9814
# Epoch 90, Iteration 15: H_t = 4, G_t = 0.3260, σ_t^2 = 96.8129
# Epoch 90, Iteration 16: H_t = 4, G_t = -0.7818, σ_t^2 = 87.6347
# Epoch 90, Iteration 17: H_t = 4, G_t = 0.6136, σ_t^2 = 85.9749
# Epoch 90, Iteration 18: H_t = 4, G_t = 0.0537, σ_t^2 = 84.2009
# Epoch 90, Iteration 19: H_t = 6, G_t = 2.1423, σ_t^2 = 97.5108
# Epoch 90, Iteration 20: H_t = 7, G_t = 2.5201, σ_t^2 = 101.6720
# Epoch 90, Iteration 21: H_t = 4, G_t = -0.5197, σ_t^2 = 93.2788
# Epoch 90, Iteration 22: H_t = 14, G_t = 3.8919, σ_t^2 = 80.3517
# Epoch 90, Iteration 23: H_t = 4, G_t = -1.1569, σ_t^2 = 251.2858
# Epoch 90, Iteration 24: H_t = 4, G_t = -0.8647, σ_t^2 = 83.2745
# Epoch 90, Iteration 25: H_t = 6, G_t = 2.0789, σ_t^2 = 92.1545
# Epoch 90, Iteration 26: H_t = 4, G_t = -1.7443, σ_t^2 = 107.2712
# Epoch 90, Iteration 27: H_t = 6, G_t = 1.6341, σ_t^2 = 79.0572
# Epoch 90, Iteration 28: H_t = 7, G_t = 2.2012, σ_t^2 = 87.5462
# Epoch 90, Iteration 29: H_t = 4, G_t = -2.8703, σ_t^2 = 98.4065
# Epoch 90, Iteration 30: H_t = 4, G_t = 0.5231, σ_t^2 = 95.0128
# Epoch 90, Iteration 31: H_t = 4, G_t = 0.0177, σ_t^2 = 86.8115
#     Worker 0: Train Loss: 1.4733, Train Accuracy: 58.09%
#     Worker 1: Train Loss: 1.4919, Train Accuracy: 58.48%
#     Worker 2: Train Loss: 1.4674, Train Accuracy: 58.99%
#     Worker 3: Train Loss: 1.4734, Train Accuracy: 58.96%
# Epoch 90: Test Loss: 1.9660, Test Accuracy: 49.71%
