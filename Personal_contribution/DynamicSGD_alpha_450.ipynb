# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files
import torch.nn.functional as F

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
iteration_per_epoch = 782 # number of local step performed in one epoch
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
#warmup_epochs = 5

def compute_mean_std(dataset):
    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

#global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
#global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
#print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Compute gradient magnitude and variance
def compute_gradient_stats(nets, optimizers):
    # Get gradients from each worker
    gradients = []
    for net, optimizer in zip(nets, optimizers):
        grad_vector = []
        for param in net.parameters():
            if param.grad is not None:
                grad_vector.append(param.grad.view(-1))
        grad_vector = torch.cat(grad_vector)  # Flatten all gradients into a vector
        gradients.append(grad_vector)

    # Compute average gradient (g_t)
    avg_gradient = torch.stack(gradients).mean(dim=0)

    # Compute squared norms of individual gradients
    squared_norms = [torch.norm(g).item() ** 2 for g in gradients]

    # Compute squared norm of the average gradient
    avg_squared_norm = torch.norm(avg_gradient).item() ** 2

    # Compute gradient variance (sigma_t^2) using the provided formula
    sigma_t_squared = (sum(squared_norms) / (K - 1)) - (K / (K - 1)) * avg_squared_norm

    # Compute gradient magnitude (G_t) using the provided formula
    G_t = avg_squared_norm - (1 / K) * sigma_t_squared

    return G_t, sigma_t_squared


# Update H dynamically based on gradient stats
def update_H(G_t, sigma_t_squared, H_min, H_max, alpha, epsilon):
    H_t = min(H_max, max(H_min, alpha * G_t / (sigma_t_squared + epsilon)))
    #H_t = min(H_t, H_max)  # Ensure H_t doesn't exceed H_max
    return int(H_t)  # Ensure H_t is an integer

# Training loop
# Hyperparameters for dynamic adjustment
H_min, H_max = 4, 64  # Minimum and maximum allowed local steps
alpha, epsilon = 450, 1e-6  # Scaling factor and small constant

H_t = J  # Initialize H_t with the default J value


for epoch in range(num_epochs):
    #print(f"Epoch {epoch + 1}/{num_epochs}:")
    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]

    iteration_per_epoch = 782
    iteration = 0 # Number of global iteration performed
    while iteration_per_epoch > 0:
        # Train each worker for H_t steps
        for k in range(K):
            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            for _ in range(H_t):  # Perform H_t local steps
                try:
                    images, labels = next(shard_iterators[k])
                except StopIteration:
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k])
                images, labels = images.to(device), labels.to(device)

                optimizers[k].zero_grad()
                outputs = nets[k](images)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizers[k].step()

                # Calculate train loss and accuracy
                train_loss += loss.item() * labels.size(0)
                _, predicted = outputs.max(1)
                total_train += labels.size(0)
                correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        # Synchronize models
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

        # update tot_num_local_step and number of global iteration
        iteration_per_epoch -= (H_t * K)
        iteration += 1
        # Compute gradient stats and update H_t
        G_t, sigma_t_squared = compute_gradient_stats(nets, optimizers)
        H_t = update_H(G_t, sigma_t_squared, H_min, H_max, alpha, epsilon)
        # print(f"Epoch {epoch+1}, Iteration {iteration}: H_t = {H_t}, G_t = {G_t:.4f}, σ_t^2 = {sigma_t_squared:.4f}")

    # Store training metrics for all workers after each epoch
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

    # Update learning rate
    for scheduler in schedulers:
        scheduler.step()

    # Evaluate on test set
    global_model = nets[0]
    global_model.eval()
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()

    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)
    print(f"Epoch {epoch + 1}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")



# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 4 --j 32
# Out:
# Training with K=4, J=32
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:03<00:00, 49.6MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00400
#     Worker 0: Train Loss: 4.5995, Train Accuracy: 1.35%
#     Worker 1: Train Loss: 4.6001, Train Accuracy: 1.29%
#     Worker 2: Train Loss: 4.5987, Train Accuracy: 1.52%
#     Worker 3: Train Loss: 4.5992, Train Accuracy: 1.49%
# Epoch 1: Test Loss: 4.5825, Test Accuracy: 2.65%
#     Worker 0: Train Loss: 4.4783, Train Accuracy: 3.32%
#     Worker 1: Train Loss: 4.4772, Train Accuracy: 3.32%
#     Worker 2: Train Loss: 4.4637, Train Accuracy: 3.28%
#     Worker 3: Train Loss: 4.4705, Train Accuracy: 3.59%
# Epoch 2: Test Loss: 4.2202, Test Accuracy: 6.10%
#     Worker 0: Train Loss: 4.1311, Train Accuracy: 6.92%
#     Worker 1: Train Loss: 4.1407, Train Accuracy: 6.76%
#     Worker 2: Train Loss: 4.1141, Train Accuracy: 6.81%
#     Worker 3: Train Loss: 4.1434, Train Accuracy: 6.79%
# Epoch 3: Test Loss: 3.9774, Test Accuracy: 9.03%
#     Worker 0: Train Loss: 3.9727, Train Accuracy: 9.14%
#     Worker 1: Train Loss: 3.9803, Train Accuracy: 9.12%
#     Worker 2: Train Loss: 3.9404, Train Accuracy: 9.34%
#     Worker 3: Train Loss: 3.9752, Train Accuracy: 8.77%
# Epoch 4: Test Loss: 3.8077, Test Accuracy: 12.64%
#     Worker 0: Train Loss: 3.8508, Train Accuracy: 10.80%
#     Worker 1: Train Loss: 3.8646, Train Accuracy: 11.32%
#     Worker 2: Train Loss: 3.8085, Train Accuracy: 11.08%
#     Worker 3: Train Loss: 3.8566, Train Accuracy: 11.00%
# Epoch 5: Test Loss: 3.6917, Test Accuracy: 14.18%
#     Worker 0: Train Loss: 3.7489, Train Accuracy: 12.22%
#     Worker 1: Train Loss: 3.7552, Train Accuracy: 12.55%
#     Worker 2: Train Loss: 3.7124, Train Accuracy: 13.27%
#     Worker 3: Train Loss: 3.7428, Train Accuracy: 12.60%
# Epoch 6: Test Loss: 3.5912, Test Accuracy: 16.22%
#     Worker 0: Train Loss: 3.6491, Train Accuracy: 13.96%
#     Worker 1: Train Loss: 3.6456, Train Accuracy: 14.23%
#     Worker 2: Train Loss: 3.5892, Train Accuracy: 15.60%
#     Worker 3: Train Loss: 3.6448, Train Accuracy: 14.21%
# Epoch 7: Test Loss: 3.4802, Test Accuracy: 17.66%
#     Worker 0: Train Loss: 3.5329, Train Accuracy: 15.76%
#     Worker 1: Train Loss: 3.5599, Train Accuracy: 15.85%
#     Worker 2: Train Loss: 3.4811, Train Accuracy: 16.93%
#     Worker 3: Train Loss: 3.5426, Train Accuracy: 16.16%
# Epoch 8: Test Loss: 3.3969, Test Accuracy: 18.94%
#     Worker 0: Train Loss: 3.4968, Train Accuracy: 16.44%
#     Worker 1: Train Loss: 3.5050, Train Accuracy: 17.05%
#     Worker 2: Train Loss: 3.4536, Train Accuracy: 17.70%
#     Worker 3: Train Loss: 3.4872, Train Accuracy: 17.03%
#     Worker 2: Train Loss: 2.2560, Train Accuracy: 41.11%
#     Worker 3: Train Loss: 2.2717, Train Accuracy: 40.11%
# Epoch 36: Test Loss: 2.2308, Test Accuracy: 42.08%
#     Worker 0: Train Loss: 2.2437, Train Accuracy: 40.97%
#     Worker 1: Train Loss: 2.2751, Train Accuracy: 40.43%
#     Worker 2: Train Loss: 2.2476, Train Accuracy: 40.59%
#     Worker 3: Train Loss: 2.2827, Train Accuracy: 40.18%
# Epoch 37: Test Loss: 2.2150, Test Accuracy: 42.67%
#     Worker 0: Train Loss: 2.2127, Train Accuracy: 41.51%
#     Worker 1: Train Loss: 2.2094, Train Accuracy: 41.88%
#     Worker 2: Train Loss: 2.2012, Train Accuracy: 42.26%
#     Worker 3: Train Loss: 2.2391, Train Accuracy: 41.05%
# Epoch 38: Test Loss: 2.1917, Test Accuracy: 42.81%
#     Worker 0: Train Loss: 2.2251, Train Accuracy: 41.05%
#     Worker 1: Train Loss: 2.2325, Train Accuracy: 41.25%
#     Worker 2: Train Loss: 2.2104, Train Accuracy: 41.47%
#     Worker 3: Train Loss: 2.2349, Train Accuracy: 41.13%
# Epoch 39: Test Loss: 2.1815, Test Accuracy: 42.92%
#     Worker 0: Train Loss: 2.1856, Train Accuracy: 42.16%
#     Worker 1: Train Loss: 2.2050, Train Accuracy: 41.89%
#     Worker 2: Train Loss: 2.1949, Train Accuracy: 42.11%
#     Worker 3: Train Loss: 2.2206, Train Accuracy: 41.47%
# Epoch 40: Test Loss: 2.1707, Test Accuracy: 43.68%
#     Worker 0: Train Loss: 2.1750, Train Accuracy: 42.58%
#     Worker 1: Train Loss: 2.1836, Train Accuracy: 42.53%
#     Worker 2: Train Loss: 2.1512, Train Accuracy: 42.90%
#     Worker 3: Train Loss: 2.1804, Train Accuracy: 42.63%
# Epoch 41: Test Loss: 2.1709, Test Accuracy: 43.26%
#     Worker 0: Train Loss: 2.1223, Train Accuracy: 43.40%
#     Worker 1: Train Loss: 2.1400, Train Accuracy: 43.69%
#     Worker 2: Train Loss: 2.1203, Train Accuracy: 44.11%
#     Worker 3: Train Loss: 2.1296, Train Accuracy: 43.94%
# Epoch 42: Test Loss: 2.1555, Test Accuracy: 43.49%
#     Worker 0: Train Loss: 2.1229, Train Accuracy: 43.25%
#     Worker 1: Train Loss: 2.1302, Train Accuracy: 43.63%
#     Worker 2: Train Loss: 2.0951, Train Accuracy: 44.96%
#     Worker 3: Train Loss: 2.1261, Train Accuracy: 43.65%
# Epoch 43: Test Loss: 2.1414, Test Accuracy: 43.81%
#     Worker 0: Train Loss: 2.0964, Train Accuracy: 44.33%
#     Worker 1: Train Loss: 2.1104, Train Accuracy: 43.77%
#     Worker 2: Train Loss: 2.0697, Train Accuracy: 45.08%
#     Worker 3: Train Loss: 2.1155, Train Accuracy: 44.24%
# Epoch 44: Test Loss: 2.1242, Test Accuracy: 44.86%
#     Worker 0: Train Loss: 2.0939, Train Accuracy: 44.07%
#     Worker 0: Train Loss: 1.4056, Train Accuracy: 60.44%
#     Worker 1: Train Loss: 1.4317, Train Accuracy: 59.61%
#     Worker 2: Train Loss: 1.4111, Train Accuracy: 60.59%
#     Worker 3: Train Loss: 1.4170, Train Accuracy: 60.06%
# Epoch 98: Test Loss: 1.9589, Test Accuracy: 50.47%
#     Worker 0: Train Loss: 1.3999, Train Accuracy: 60.62%
#     Worker 1: Train Loss: 1.3984, Train Accuracy: 61.27%
#     Worker 2: Train Loss: 1.3958, Train Accuracy: 60.62%
#     Worker 3: Train Loss: 1.4043, Train Accuracy: 60.49%
# Epoch 99: Test Loss: 1.9535, Test Accuracy: 50.71%
#     Worker 0: Train Loss: 1.4277, Train Accuracy: 59.74%
#     Worker 1: Train Loss: 1.4397, Train Accuracy: 59.60%
#     Worker 2: Train Loss: 1.4084, Train Accuracy: 60.42%
#     Worker 3: Train Loss: 1.4335, Train Accuracy: 59.70%
# Epoch 100: Test Loss: 1.9567, Test Accuracy: 50.31%
#     Worker 0: Train Loss: 1.4037, Train Accuracy: 60.30%
#     Worker 1: Train Loss: 1.4105, Train Accuracy: 60.51%
#     Worker 2: Train Loss: 1.3931, Train Accuracy: 61.17%
#     Worker 3: Train Loss: 1.4127, Train Accuracy: 60.38%
# Epoch 101: Test Loss: 1.9551, Test Accuracy: 50.19%
#     Worker 0: Train Loss: 1.3816, Train Accuracy: 60.40%
#     Worker 1: Train Loss: 1.3985, Train Accuracy: 60.87%
#     Worker 2: Train Loss: 1.3899, Train Accuracy: 60.69%
#     Worker 3: Train Loss: 1.4002, Train Accuracy: 60.48%
# Epoch 102: Test Loss: 1.9636, Test Accuracy: 50.44%
#     Worker 0: Train Loss: 1.3945, Train Accuracy: 60.78%
#     Worker 1: Train Loss: 1.3854, Train Accuracy: 61.13%
#     Worker 2: Train Loss: 1.3872, Train Accuracy: 60.68%
#     Worker 3: Train Loss: 1.3997, Train Accuracy: 60.37%
# Epoch 103: Test Loss: 1.9629, Test Accuracy: 50.47%
#     Worker 0: Train Loss: 1.3731, Train Accuracy: 60.90%
#     Worker 1: Train Loss: 1.4007, Train Accuracy: 61.11%
#     Worker 2: Train Loss: 1.3624, Train Accuracy: 61.53%
#     Worker 3: Train Loss: 1.3853, Train Accuracy: 60.97%
# Epoch 104: Test Loss: 1.9637, Test Accuracy: 50.67%
#     Worker 0: Train Loss: 1.3667, Train Accuracy: 61.01%
#     Worker 1: Train Loss: 1.3722, Train Accuracy: 62.19%
#     Worker 2: Train Loss: 1.3541, Train Accuracy: 62.13%
#     Worker 3: Train Loss: 1.3612, Train Accuracy: 61.12%
# Epoch 105: Test Loss: 1.9749, Test Accuracy: 50.04%
#     Worker 0: Train Loss: 1.3732, Train Accuracy: 61.01%
#     Worker 1: Train Loss: 1.3683, Train Accuracy: 61.47%
#     Worker 2: Train Loss: 1.3569, Train Accuracy: 61.88%
#     Worker 3: Train Loss: 1.3689, Train Accuracy: 61.75%
# Epoch 115: Test Loss: 1.9632, Test Accuracy: 50.78%
#     Worker 0: Train Loss: 1.3086, Train Accuracy: 62.41%
#     Worker 1: Train Loss: 1.3083, Train Accuracy: 63.17%
#     Worker 2: Train Loss: 1.2897, Train Accuracy: 63.75%
#     Worker 3: Train Loss: 1.3031, Train Accuracy: 63.50%
# Epoch 116: Test Loss: 1.9650, Test Accuracy: 50.71%
#     Worker 0: Train Loss: 1.2777, Train Accuracy: 63.53%
#     Worker 1: Train Loss: 1.3085, Train Accuracy: 63.34%
#     Worker 2: Train Loss: 1.2975, Train Accuracy: 63.51%
#     Worker 3: Train Loss: 1.3109, Train Accuracy: 62.86%
# Epoch 117: Test Loss: 1.9687, Test Accuracy: 50.80%
#     Worker 0: Train Loss: 1.2872, Train Accuracy: 63.39%
#     Worker 1: Train Loss: 1.3059, Train Accuracy: 63.22%
#     Worker 2: Train Loss: 1.2819, Train Accuracy: 63.90%
#     Worker 3: Train Loss: 1.2827, Train Accuracy: 63.70%
# Epoch 118: Test Loss: 1.9651, Test Accuracy: 50.88%
#     Worker 0: Train Loss: 1.2908, Train Accuracy: 62.97%
#     Worker 1: Train Loss: 1.2997, Train Accuracy: 63.37%
#     Worker 2: Train Loss: 1.2935, Train Accuracy: 63.38%
#     Worker 3: Train Loss: 1.3048, Train Accuracy: 63.45%
# Epoch 119: Test Loss: 1.9672, Test Accuracy: 51.05%
#     Worker 0: Train Loss: 1.2886, Train Accuracy: 63.13%
#     Worker 1: Train Loss: 1.2880, Train Accuracy: 64.26%
#     Worker 2: Train Loss: 1.2625, Train Accuracy: 64.32%
#     Worker 3: Train Loss: 1.2659, Train Accuracy: 64.21%
# Epoch 120: Test Loss: 1.9709, Test Accuracy: 50.58%
#     Worker 0: Train Loss: 1.2787, Train Accuracy: 63.33%
#     Worker 1: Train Loss: 1.2872, Train Accuracy: 63.65%
#     Worker 2: Train Loss: 1.2951, Train Accuracy: 63.57%
#     Worker 3: Train Loss: 1.2859, Train Accuracy: 63.83%
# Epoch 121: Test Loss: 1.9670, Test Accuracy: 50.96%
#     Worker 0: Train Loss: 1.2899, Train Accuracy: 63.66%
#     Worker 1: Train Loss: 1.3087, Train Accuracy: 63.84%
#     Worker 2: Train Loss: 1.2687, Train Accuracy: 64.28%
#     Worker 3: Train Loss: 1.2855, Train Accuracy: 63.53%
# Epoch 122: Test Loss: 1.9656, Test Accuracy: 50.47%
#     Worker 0: Train Loss: 1.2731, Train Accuracy: 64.50%
#     Worker 1: Train Loss: 1.2739, Train Accuracy: 63.85%
#     Worker 2: Train Loss: 1.2825, Train Accuracy: 64.14%
#     Worker 3: Train Loss: 1.2709, Train Accuracy: 64.25%
# Epoch 123: Test Loss: 1.9671, Test Accuracy: 50.95%
#     Worker 0: Train Loss: 1.2628, Train Accuracy: 64.12%
#     Worker 1: Train Loss: 1.2774, Train Accuracy: 63.81%
#     Worker 2: Train Loss: 1.2417, Train Accuracy: 65.04%
#     Worker 3: Train Loss: 1.2610, Train Accuracy: 64.30%
# Epoch 124: Test Loss: 1.9701, Test Accuracy: 50.98%
#     Worker 0: Train Loss: 1.2594, Train Accuracy: 64.39%
#     Worker 1: Train Loss: 1.2597, Train Accuracy: 64.48%
#     Worker 2: Train Loss: 1.2683, Train Accuracy: 64.12%
#     Worker 3: Train Loss: 1.2764, Train Accuracy: 63.87%
# Epoch 125: Test Loss: 1.9664, Test Accuracy: 51.04%
#     Worker 0: Train Loss: 1.2650, Train Accuracy: 63.86%
#     Worker 1: Train Loss: 1.2629, Train Accuracy: 64.35%
#     Worker 2: Train Loss: 1.2595, Train Accuracy: 64.75%
#     Worker 3: Train Loss: 1.2733, Train Accuracy: 64.28%
# Epoch 126: Test Loss: 1.9680, Test Accuracy: 50.85%
#     Worker 0: Train Loss: 1.2491, Train Accuracy: 64.44%
#     Worker 1: Train Loss: 1.2793, Train Accuracy: 64.28%
#     Worker 2: Train Loss: 1.2415, Train Accuracy: 65.07%
#     Worker 3: Train Loss: 1.2693, Train Accuracy: 64.18%
# Epoch 127: Test Loss: 1.9686, Test Accuracy: 51.01%
#     Worker 0: Train Loss: 1.2481, Train Accuracy: 64.73%
#     Worker 1: Train Loss: 1.2502, Train Accuracy: 64.59%
#     Worker 2: Train Loss: 1.2453, Train Accuracy: 64.81%
#     Worker 3: Train Loss: 1.2701, Train Accuracy: 64.55%
# Epoch 128: Test Loss: 1.9689, Test Accuracy: 51.01%
#     Worker 0: Train Loss: 1.2496, Train Accuracy: 64.78%
#     Worker 1: Train Loss: 1.2609, Train Accuracy: 64.81%
#     Worker 2: Train Loss: 1.2460, Train Accuracy: 64.76%
#     Worker 3: Train Loss: 1.2623, Train Accuracy: 64.36%
# Epoch 129: Test Loss: 1.9668, Test Accuracy: 50.87%
#     Worker 0: Train Loss: 1.2333, Train Accuracy: 65.00%
#     Worker 1: Train Loss: 1.2399, Train Accuracy: 64.86%
#     Worker 2: Train Loss: 1.2466, Train Accuracy: 64.90%
#     Worker 3: Train Loss: 1.2533, Train Accuracy: 64.38%
# Epoch 130: Test Loss: 1.9730, Test Accuracy: 51.19%
#     Worker 0: Train Loss: 1.2375, Train Accuracy: 64.65%
#     Worker 1: Train Loss: 1.2569, Train Accuracy: 64.50%
#     Worker 2: Train Loss: 1.2408, Train Accuracy: 65.02%
#     Worker 3: Train Loss: 1.2506, Train Accuracy: 64.90%
# Epoch 131: Test Loss: 1.9700, Test Accuracy: 50.93%
#     Worker 0: Train Loss: 1.2348, Train Accuracy: 65.01%
#     Worker 1: Train Loss: 1.2526, Train Accuracy: 65.00%
#     Worker 2: Train Loss: 1.2329, Train Accuracy: 65.50%
#     Worker 3: Train Loss: 1.2560, Train Accuracy: 64.70%
# Epoch 132: Test Loss: 1.9686, Test Accuracy: 51.13%
#     Worker 0: Train Loss: 1.2400, Train Accuracy: 64.36%
#     Worker 1: Train Loss: 1.2462, Train Accuracy: 65.03%
#     Worker 2: Train Loss: 1.2384, Train Accuracy: 65.28%
#     Worker 3: Train Loss: 1.2440, Train Accuracy: 65.03%
# Epoch 133: Test Loss: 1.9692, Test Accuracy: 50.90%
#     Worker 0: Train Loss: 1.2302, Train Accuracy: 65.16%
#     Worker 1: Train Loss: 1.2352, Train Accuracy: 65.11%
#     Worker 2: Train Loss: 1.2193, Train Accuracy: 65.65%
#     Worker 3: Train Loss: 1.2396, Train Accuracy: 65.35%
# Epoch 134: Test Loss: 1.9733, Test Accuracy: 50.85%
#     Worker 0: Train Loss: 1.2592, Train Accuracy: 64.52%
#     Worker 1: Train Loss: 1.2488, Train Accuracy: 64.84%
#     Worker 2: Train Loss: 1.2356, Train Accuracy: 65.16%
#     Worker 3: Train Loss: 1.2400, Train Accuracy: 64.70%
# Epoch 135: Test Loss: 1.9694, Test Accuracy: 50.94%
#     Worker 0: Train Loss: 1.2208, Train Accuracy: 65.21%
#     Worker 1: Train Loss: 1.2419, Train Accuracy: 65.38%
#     Worker 2: Train Loss: 1.2198, Train Accuracy: 65.63%
#     Worker 3: Train Loss: 1.2438, Train Accuracy: 64.96%
# Epoch 136: Test Loss: 1.9706, Test Accuracy: 50.99%
#     Worker 0: Train Loss: 1.2255, Train Accuracy: 64.97%
#     Worker 1: Train Loss: 1.2288, Train Accuracy: 65.19%
#     Worker 2: Train Loss: 1.2413, Train Accuracy: 65.16%
#     Worker 3: Train Loss: 1.2343, Train Accuracy: 65.06%
# Epoch 137: Test Loss: 1.9699, Test Accuracy: 51.18%
#     Worker 0: Train Loss: 1.2221, Train Accuracy: 65.09%
#     Worker 1: Train Loss: 1.2189, Train Accuracy: 65.90%
#     Worker 2: Train Loss: 1.2117, Train Accuracy: 65.80%
#     Worker 3: Train Loss: 1.2492, Train Accuracy: 64.79%
# Epoch 138: Test Loss: 1.9704, Test Accuracy: 51.16%
#     Worker 0: Train Loss: 1.2364, Train Accuracy: 64.92%
#     Worker 1: Train Loss: 1.2534, Train Accuracy: 64.64%
#     Worker 2: Train Loss: 1.2287, Train Accuracy: 64.98%
#     Worker 3: Train Loss: 1.2344, Train Accuracy: 64.81%
# Epoch 139: Test Loss: 1.9685, Test Accuracy: 50.95%
#     Worker 0: Train Loss: 1.2213, Train Accuracy: 65.36%
#     Worker 1: Train Loss: 1.2290, Train Accuracy: 65.63%
#     Worker 2: Train Loss: 1.2163, Train Accuracy: 65.72%
#     Worker 3: Train Loss: 1.2413, Train Accuracy: 64.92%
# Epoch 140: Test Loss: 1.9705, Test Accuracy: 51.04%
#     Worker 0: Train Loss: 1.2331, Train Accuracy: 64.86%
#     Worker 1: Train Loss: 1.2299, Train Accuracy: 65.36%
#     Worker 2: Train Loss: 1.2311, Train Accuracy: 65.14%
#     Worker 3: Train Loss: 1.2292, Train Accuracy: 65.40%
# Epoch 141: Test Loss: 1.9698, Test Accuracy: 50.95%
#     Worker 0: Train Loss: 1.2309, Train Accuracy: 64.55%
#     Worker 1: Train Loss: 1.2341, Train Accuracy: 65.49%
#     Worker 2: Train Loss: 1.2006, Train Accuracy: 66.38%
#     Worker 3: Train Loss: 1.2351, Train Accuracy: 65.48%
# Epoch 142: Test Loss: 1.9694, Test Accuracy: 50.98%
#     Worker 0: Train Loss: 1.2225, Train Accuracy: 64.70%
#     Worker 1: Train Loss: 1.2257, Train Accuracy: 65.71%
#     Worker 2: Train Loss: 1.2401, Train Accuracy: 64.73%
#     Worker 3: Train Loss: 1.2293, Train Accuracy: 64.97%
# Epoch 143: Test Loss: 1.9696, Test Accuracy: 50.98%
#     Worker 0: Train Loss: 1.2489, Train Accuracy: 64.47%
#     Worker 1: Train Loss: 1.2157, Train Accuracy: 66.07%
#     Worker 2: Train Loss: 1.2191, Train Accuracy: 65.77%
#     Worker 3: Train Loss: 1.2322, Train Accuracy: 65.00%
# Epoch 144: Test Loss: 1.9694, Test Accuracy: 50.90%
#     Worker 0: Train Loss: 1.2267, Train Accuracy: 65.24%
#     Worker 1: Train Loss: 1.2394, Train Accuracy: 65.49%
#     Worker 2: Train Loss: 1.2256, Train Accuracy: 65.65%
#     Worker 3: Train Loss: 1.2343, Train Accuracy: 64.85%
# Epoch 145: Test Loss: 1.9690, Test Accuracy: 50.99%
#     Worker 0: Train Loss: 1.2269, Train Accuracy: 65.18%
#     Worker 1: Train Loss: 1.2390, Train Accuracy: 65.31%
#     Worker 2: Train Loss: 1.2092, Train Accuracy: 65.99%
#     Worker 3: Train Loss: 1.2466, Train Accuracy: 65.32%
# Epoch 146: Test Loss: 1.9687, Test Accuracy: 50.95%
#     Worker 0: Train Loss: 1.2134, Train Accuracy: 65.69%
#     Worker 1: Train Loss: 1.2478, Train Accuracy: 64.42%
#     Worker 2: Train Loss: 1.2164, Train Accuracy: 65.53%
#     Worker 3: Train Loss: 1.2384, Train Accuracy: 65.10%
# Epoch 147: Test Loss: 1.9686, Test Accuracy: 50.94%
#     Worker 0: Train Loss: 1.2199, Train Accuracy: 65.16%
#     Worker 1: Train Loss: 1.2249, Train Accuracy: 65.81%
#     Worker 2: Train Loss: 1.2222, Train Accuracy: 65.29%
#     Worker 3: Train Loss: 1.2214, Train Accuracy: 65.41%
# Epoch 148: Test Loss: 1.9685, Test Accuracy: 50.90%
#     Worker 0: Train Loss: 1.2275, Train Accuracy: 65.43%
#     Worker 1: Train Loss: 1.2317, Train Accuracy: 65.07%
#     Worker 2: Train Loss: 1.2105, Train Accuracy: 65.84%
#     Worker 3: Train Loss: 1.2145, Train Accuracy: 65.63%
# Epoch 149: Test Loss: 1.9685, Test Accuracy: 50.93%
#     Worker 0: Train Loss: 1.2154, Train Accuracy: 64.87%
#     Worker 1: Train Loss: 1.2418, Train Accuracy: 65.28%
#     Worker 2: Train Loss: 1.2270, Train Accuracy: 65.15%
#     Worker 3: Train Loss: 1.2446, Train Accuracy: 65.29%
# Epoch 150: Test Loss: 1.9685, Test Accuracy: 50.93%
