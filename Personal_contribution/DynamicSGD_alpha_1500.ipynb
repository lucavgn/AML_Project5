# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files
import torch.nn.functional as F
import time

total_computation_time = 0
total_communication_time = 0

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
iteration_per_epoch = 782 # number of local step performed in one epoch
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
#warmup_epochs = 5

def compute_mean_std(dataset):
    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

#global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
#global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
#print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Compute gradient magnitude and variance
def compute_gradient_stats(nets, optimizers):
    # Get gradients from each worker
    gradients = []
    for net, optimizer in zip(nets, optimizers):
        grad_vector = []
        for param in net.parameters():
            if param.grad is not None:
                grad_vector.append(param.grad.view(-1))
        grad_vector = torch.cat(grad_vector)  # Flatten all gradients into a vector
        gradients.append(grad_vector)

    # Compute average gradient (g_t)
    avg_gradient = torch.stack(gradients).mean(dim=0)

    # Compute squared norms of individual gradients
    squared_norms = [torch.norm(g).item() ** 2 for g in gradients]

    # Compute squared norm of the average gradient
    avg_squared_norm = torch.norm(avg_gradient).item() ** 2

    # Compute gradient variance (sigma_t^2) using the provided formula
    sigma_t_squared = (sum(squared_norms) / (K - 1)) - (K / (K - 1)) * avg_squared_norm

    # Compute gradient magnitude (G_t) using the provided formula
    G_t = avg_squared_norm - (1 / K) * sigma_t_squared

    return G_t, sigma_t_squared


# Update H dynamically based on gradient stats
def update_H(G_t, sigma_t_squared, H_min, H_max, alpha, epsilon):
    H_t = min(H_max, max(H_min, alpha * G_t / (sigma_t_squared + epsilon)))
    #H_t = min(H_t, H_max)  # Ensure H_t doesn't exceed H_max
    return int(H_t)  # Ensure H_t is an integer

# Training loop
# Hyperparameters for dynamic adjustment
H_min, H_max = 4, 64  # Minimum and maximum allowed local steps
alpha, epsilon = 1500, 1e-6  # Scaling factor and small constant

H_t = J  # Initialize H_t with the default J value


for epoch in range(num_epochs):
    #print(f"Epoch {epoch + 1}/{num_epochs}:")
    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]

    iteration_per_epoch = 782
    iteration = 0 # Number of global iteration performed
    while iteration_per_epoch > 0:
        computation_start_time = time.time()
        # Train each worker for H_t steps
        for k in range(K):
            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            for _ in range(H_t):  # Perform H_t local steps
                try:
                    images, labels = next(shard_iterators[k])
                except StopIteration:
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k])
                images, labels = images.to(device), labels.to(device)

                optimizers[k].zero_grad()
                outputs = nets[k](images)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizers[k].step()

                # Calculate train loss and accuracy
                train_loss += loss.item() * labels.size(0)
                _, predicted = outputs.max(1)
                total_train += labels.size(0)
                correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        computation_end_time = time.time()
        total_computation_time += (computation_end_time - computation_start_time)

        communication_start_time = time.time()
        # Synchronize models
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

        communication_end_time = time.time()
        total_communication_time += (communication_end_time - communication_start_time)

        # update tot_num_local_step and number of global iteration
        iteration_per_epoch -= (H_t * K)
        iteration += 1
        # Compute gradient stats and update H_t
        G_t, sigma_t_squared = compute_gradient_stats(nets, optimizers)
        H_t = update_H(G_t, sigma_t_squared, H_min, H_max, alpha, epsilon)
        print(f"Epoch {epoch+1}, Iteration {iteration}: H_t = {H_t}, G_t = {G_t:.4f}, σ_t^2 = {sigma_t_squared:.4f}")

    # Store training metrics for all workers after each epoch
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

    # Update learning rate
    for scheduler in schedulers:
        scheduler.step()

    # Evaluate on test set
    global_model = nets[0]
    global_model.eval()
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()

    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)
    print(f"Epoch {epoch + 1}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")

    print(f"Total Computation Time: {total_computation_time:.2f} seconds")
    print(f"Total Communication Time: {total_communication_time:.2f} seconds")



# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Writing localSGD.py

# %%
# %run localSGD.py --k 4 --j 32
# Out:
# Training with K=4, J=32
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:18<00:00, 9.15MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00400
# Epoch 1, Iteration 1: H_t = 64, G_t = 0.0069, σ_t^2 = 0.1261
# Epoch 1, Iteration 2: H_t = 4, G_t = 0.0002, σ_t^2 = 0.1476
# Epoch 1, Iteration 3: H_t = 64, G_t = 0.0062, σ_t^2 = 0.1289
# Epoch 1, Iteration 4: H_t = 55, G_t = 0.0077, σ_t^2 = 0.2072
# Epoch 1, Iteration 5: H_t = 62, G_t = 0.0200, σ_t^2 = 0.4780
#     Worker 0: Train Loss: 4.5981, Train Accuracy: 1.50%
#     Worker 1: Train Loss: 4.5984, Train Accuracy: 1.59%
#     Worker 2: Train Loss: 4.5966, Train Accuracy: 1.77%
#     Worker 3: Train Loss: 4.5980, Train Accuracy: 1.60%
# Epoch 1: Test Loss: 4.5747, Test Accuracy: 2.50%
# Total Computation Time: 27.25 seconds
# Total Communication Time: 0.04 seconds
# Epoch 2, Iteration 1: H_t = 54, G_t = 0.0494, σ_t^2 = 1.3624
# Epoch 2, Iteration 2: H_t = 60, G_t = 0.1492, σ_t^2 = 3.7064
# Epoch 2, Iteration 3: H_t = 4, G_t = -0.2580, σ_t^2 = 7.9855
# Epoch 2, Iteration 4: H_t = 32, G_t = 0.1822, σ_t^2 = 8.2988
# Epoch 2, Iteration 5: H_t = 28, G_t = 0.1974, σ_t^2 = 10.4663
#     Worker 0: Train Loss: 4.4371, Train Accuracy: 3.48%
#     Worker 1: Train Loss: 4.4409, Train Accuracy: 3.68%
#     Worker 2: Train Loss: 4.4212, Train Accuracy: 3.68%
#     Worker 3: Train Loss: 4.4405, Train Accuracy: 3.40%
# Epoch 2: Test Loss: 4.1660, Test Accuracy: 6.78%
# Total Computation Time: 53.19 seconds
# Total Communication Time: 0.04 seconds
# Epoch 3, Iteration 1: H_t = 32, G_t = 0.2743, σ_t^2 = 12.7156
# Epoch 3, Iteration 2: H_t = 4, G_t = -0.1093, σ_t^2 = 10.9103
# Epoch 3, Iteration 3: H_t = 60, G_t = 0.3828, σ_t^2 = 9.5159
# Epoch 3, Iteration 4: H_t = 64, G_t = 0.7078, σ_t^2 = 11.7178
# Epoch 3, Iteration 5: H_t = 4, G_t = -0.2923, σ_t^2 = 9.5476
# Epoch 3, Iteration 6: H_t = 64, G_t = 0.4564, σ_t^2 = 8.6209
# Epoch 3, Iteration 7: H_t = 24, G_t = 0.1520, σ_t^2 = 9.1187
#     Worker 0: Train Loss: 4.1151, Train Accuracy: 6.82%
#     Worker 1: Train Loss: 4.1225, Train Accuracy: 6.91%
#     Worker 2: Train Loss: 4.0965, Train Accuracy: 7.29%
#     Worker 3: Train Loss: 4.1118, Train Accuracy: 6.60%
# Epoch 3: Test Loss: 3.9304, Test Accuracy: 10.36%
# Total Computation Time: 83.86 seconds
# Total Communication Time: 0.05 seconds
# Epoch 4, Iteration 1: H_t = 4, G_t = -0.3753, σ_t^2 = 11.5922
# Epoch 4, Iteration 2: H_t = 64, G_t = 0.6620, σ_t^2 = 9.1139
# Epoch 4, Iteration 3: H_t = 4, G_t = -0.7312, σ_t^2 = 12.6172
# Epoch 4, Iteration 4: H_t = 64, G_t = 1.0379, σ_t^2 = 9.8959
# Epoch 4, Iteration 5: H_t = 4, G_t = -0.7271, σ_t^2 = 12.3898
# Epoch 4, Iteration 6: H_t = 60, G_t = 0.4210, σ_t^2 = 10.4800
# Epoch 4, Iteration 7: H_t = 64, G_t = 0.8830, σ_t^2 = 11.2934
#     Worker 0: Train Loss: 3.9452, Train Accuracy: 9.21%
#     Worker 1: Train Loss: 3.9563, Train Accuracy: 9.28%
#     Worker 2: Train Loss: 3.9161, Train Accuracy: 9.81%
#     Worker 3: Train Loss: 3.9603, Train Accuracy: 9.24%
# Epoch 4: Test Loss: 3.7867, Test Accuracy: 13.17%
# Total Computation Time: 110.43 seconds
# Total Communication Time: 0.06 seconds
# Epoch 5, Iteration 1: H_t = 4, G_t = -0.0183, σ_t^2 = 13.1195
# Epoch 5, Iteration 2: H_t = 4, G_t = -0.2334, σ_t^2 = 12.5293
# Epoch 5, Iteration 3: H_t = 44, G_t = 0.3420, σ_t^2 = 11.6182
# Epoch 5, Iteration 4: H_t = 4, G_t = -0.4166, σ_t^2 = 13.1225
# Epoch 5, Iteration 5: H_t = 64, G_t = 0.5259, σ_t^2 = 10.7753
# Epoch 5, Iteration 6: H_t = 4, G_t = -0.0966, σ_t^2 = 14.0058
# Epoch 5, Iteration 7: H_t = 4, G_t = -0.3325, σ_t^2 = 11.6182
# Epoch 5, Iteration 8: H_t = 64, G_t = 0.9707, σ_t^2 = 13.7218
# Epoch 5, Iteration 9: H_t = 57, G_t = 0.5262, σ_t^2 = 13.8413
#     Worker 0: Train Loss: 3.8216, Train Accuracy: 11.13%
#     Worker 1: Train Loss: 3.8232, Train Accuracy: 11.48%
#     Worker 2: Train Loss: 3.7755, Train Accuracy: 12.14%
#     Worker 3: Train Loss: 3.8209, Train Accuracy: 11.73%
# Epoch 5: Test Loss: 3.6461, Test Accuracy: 15.13%
# Total Computation Time: 141.01 seconds
# Total Communication Time: 0.07 seconds
# Epoch 6, Iteration 1: H_t = 22, G_t = 0.2326, σ_t^2 = 15.3869
# Epoch 6, Iteration 2: H_t = 64, G_t = 1.7412, σ_t^2 = 14.3990
# Epoch 6, Iteration 3: H_t = 4, G_t = -0.1226, σ_t^2 = 13.6736
# Epoch 6, Iteration 4: H_t = 4, G_t = -0.9572, σ_t^2 = 14.5336
# Epoch 6, Iteration 5: H_t = 4, G_t = -0.0888, σ_t^2 = 12.9860
# Epoch 6, Iteration 6: H_t = 64, G_t = 1.2565, σ_t^2 = 16.9149
# Epoch 6, Iteration 7: H_t = 4, G_t = -0.4757, σ_t^2 = 13.6324
#     Worker 0: Train Loss: 3.7070, Train Accuracy: 12.77%
#     Worker 1: Train Loss: 3.7164, Train Accuracy: 13.15%
#     Worker 2: Train Loss: 3.6574, Train Accuracy: 14.22%
#     Worker 3: Train Loss: 3.7168, Train Accuracy: 12.84%
# Epoch 6: Test Loss: 3.5404, Test Accuracy: 16.62%
# Total Computation Time: 166.91 seconds
# Total Communication Time: 0.08 seconds
# Epoch 7, Iteration 1: H_t = 64, G_t = 0.9582, σ_t^2 = 14.7343
# Epoch 7, Iteration 2: H_t = 4, G_t = -0.2119, σ_t^2 = 19.5558
# Epoch 7, Iteration 3: H_t = 10, G_t = 0.1094, σ_t^2 = 16.2510
# Epoch 7, Iteration 4: H_t = 4, G_t = -1.2484, σ_t^2 = 21.4282
# Epoch 7, Iteration 5: H_t = 61, G_t = 0.7594, σ_t^2 = 18.5885
# Epoch 7, Iteration 6: H_t = 32, G_t = 0.3361, σ_t^2 = 15.4670
# Epoch 7, Iteration 7: H_t = 59, G_t = 0.7440, σ_t^2 = 18.7595
# Epoch 7, Iteration 8: H_t = 48, G_t = 0.6103, σ_t^2 = 18.7830
#     Worker 0: Train Loss: 3.6150, Train Accuracy: 14.56%
#     Worker 1: Train Loss: 3.6251, Train Accuracy: 14.52%
#     Worker 2: Train Loss: 3.5663, Train Accuracy: 15.17%
#     Worker 3: Train Loss: 3.6186, Train Accuracy: 14.75%
# Epoch 7: Test Loss: 3.4344, Test Accuracy: 19.50%
# Total Computation Time: 195.54 seconds
# Total Communication Time: 0.09 seconds
# Epoch 8, Iteration 1: H_t = 13, G_t = 0.1583, σ_t^2 = 17.2179
# Epoch 8, Iteration 2: H_t = 30, G_t = 0.3511, σ_t^2 = 17.1505
# Epoch 8, Iteration 3: H_t = 64, G_t = 2.3821, σ_t^2 = 19.5684
# Epoch 8, Iteration 4: H_t = 4, G_t = -0.1141, σ_t^2 = 19.2529
# Epoch 8, Iteration 5: H_t = 64, G_t = 4.2388, σ_t^2 = 13.6246
# Epoch 8, Iteration 6: H_t = 35, G_t = 0.4099, σ_t^2 = 17.4348
#     Worker 0: Train Loss: 3.5268, Train Accuracy: 15.71%
#     Worker 1: Train Loss: 3.5416, Train Accuracy: 16.00%
#     Worker 2: Train Loss: 3.5074, Train Accuracy: 16.83%
#     Worker 3: Train Loss: 3.5331, Train Accuracy: 15.91%
# Epoch 8: Test Loss: 3.3586, Test Accuracy: 20.45%
# Total Computation Time: 221.97 seconds
# Total Communication Time: 0.10 seconds
# Epoch 9, Iteration 1: H_t = 4, G_t = -1.4668, σ_t^2 = 22.9923
# Epoch 9, Iteration 2: H_t = 31, G_t = 0.3384, σ_t^2 = 16.2480
# Epoch 9, Iteration 3: H_t = 4, G_t = -0.6313, σ_t^2 = 19.7455
# Epoch 9, Iteration 4: H_t = 4, G_t = -0.9269, σ_t^2 = 17.0291
# Epoch 9, Iteration 5: H_t = 4, G_t = 0.0554, σ_t^2 = 22.6650
# Epoch 9, Iteration 6: H_t = 14, G_t = 0.1562, σ_t^2 = 15.7005
# Epoch 9, Iteration 7: H_t = 14, G_t = 0.2207, σ_t^2 = 22.4842
# Epoch 9, Iteration 8: H_t = 4, G_t = -0.5892, σ_t^2 = 19.3977
# Epoch 9, Iteration 9: H_t = 4, G_t = -1.1044, σ_t^2 = 28.6374
# Epoch 9, Iteration 10: H_t = 39, G_t = 0.4900, σ_t^2 = 18.6929
# Epoch 9, Iteration 11: H_t = 4, G_t = -0.5352, σ_t^2 = 21.2239
# Epoch 9, Iteration 12: H_t = 4, G_t = -0.5748, σ_t^2 = 18.6692
# Epoch 9, Iteration 13: H_t = 6, G_t = 0.0875, σ_t^2 = 20.3092
# Epoch 9, Iteration 14: H_t = 27, G_t = 0.3996, σ_t^2 = 21.9859
# Epoch 9, Iteration 15: H_t = 56, G_t = 0.7817, σ_t^2 = 20.7832
#     Worker 0: Train Loss: 3.3954, Train Accuracy: 17.97%
#     Worker 1: Train Loss: 3.4168, Train Accuracy: 18.47%
#     Worker 2: Train Loss: 3.3653, Train Accuracy: 19.03%
#     Worker 3: Train Loss: 3.4426, Train Accuracy: 17.71%
# Epoch 9: Test Loss: 3.2844, Test Accuracy: 21.37%
# Total Computation Time: 245.50 seconds
# Total Communication Time: 0.12 seconds
# Epoch 10, Iteration 1: H_t = 4, G_t = -0.2418, σ_t^2 = 22.8528
# Epoch 10, Iteration 2: H_t = 30, G_t = 0.4984, σ_t^2 = 24.4370
# Epoch 10, Iteration 3: H_t = 55, G_t = 0.9891, σ_t^2 = 26.8303
# Epoch 10, Iteration 4: H_t = 4, G_t = -0.4893, σ_t^2 = 24.7700
# Epoch 10, Iteration 5: H_t = 4, G_t = -0.5947, σ_t^2 = 25.4450
# Epoch 10, Iteration 6: H_t = 6, G_t = 0.1075, σ_t^2 = 23.6771
# Epoch 10, Iteration 7: H_t = 4, G_t = -0.5910, σ_t^2 = 26.1259
# Epoch 10, Iteration 8: H_t = 64, G_t = 1.8989, σ_t^2 = 24.1447
# Epoch 10, Iteration 9: H_t = 64, G_t = 1.8438, σ_t^2 = 21.7201
#     Worker 0: Train Loss: 3.3810, Train Accuracy: 18.03%
#     Worker 1: Train Loss: 3.3778, Train Accuracy: 18.75%
#     Worker 2: Train Loss: 3.3142, Train Accuracy: 19.64%
#     Worker 3: Train Loss: 3.3705, Train Accuracy: 18.42%
# Epoch 10: Test Loss: 3.1853, Test Accuracy: 23.06%
# Total Computation Time: 272.16 seconds
# Total Communication Time: 0.13 seconds
# Epoch 11, Iteration 1: H_t = 4, G_t = -0.2816, σ_t^2 = 22.5501
# Epoch 11, Iteration 2: H_t = 17, G_t = 0.2679, σ_t^2 = 22.9271
# Epoch 11, Iteration 3: H_t = 52, G_t = 0.9211, σ_t^2 = 26.5463
# Epoch 11, Iteration 4: H_t = 4, G_t = -0.1249, σ_t^2 = 20.9001
# Epoch 11, Iteration 5: H_t = 4, G_t = -0.7716, σ_t^2 = 22.5119
# Epoch 11, Iteration 6: H_t = 64, G_t = 2.5126, σ_t^2 = 21.0583
# Epoch 11, Iteration 7: H_t = 45, G_t = 0.7350, σ_t^2 = 24.3133
#     Worker 0: Train Loss: 3.3008, Train Accuracy: 19.78%
#     Worker 1: Train Loss: 3.3146, Train Accuracy: 20.01%
#     Worker 2: Train Loss: 3.2487, Train Accuracy: 20.75%
#     Worker 3: Train Loss: 3.3167, Train Accuracy: 19.93%
# Epoch 11: Test Loss: 3.1281, Test Accuracy: 23.88%
# Total Computation Time: 296.95 seconds
# Total Communication Time: 0.14 seconds
# Epoch 12, Iteration 1: H_t = 4, G_t = -0.9188, σ_t^2 = 23.9322
# Epoch 12, Iteration 2: H_t = 4, G_t = -1.1301, σ_t^2 = 24.4820
# Epoch 12, Iteration 3: H_t = 64, G_t = 2.0866, σ_t^2 = 20.5104
# Epoch 12, Iteration 4: H_t = 64, G_t = 2.9635, σ_t^2 = 24.8816
# Epoch 12, Iteration 5: H_t = 4, G_t = 0.0140, σ_t^2 = 26.7115
# Epoch 12, Iteration 6: H_t = 64, G_t = 1.4641, σ_t^2 = 21.3517
# Epoch 12, Iteration 7: H_t = 4, G_t = -0.3297, σ_t^2 = 21.8446
#     Worker 0: Train Loss: 3.2318, Train Accuracy: 20.51%
#     Worker 1: Train Loss: 3.2392, Train Accuracy: 20.72%
#     Worker 2: Train Loss: 3.1762, Train Accuracy: 22.11%
#     Worker 3: Train Loss: 3.2506, Train Accuracy: 20.60%
# Epoch 12: Test Loss: 3.0420, Test Accuracy: 26.03%
# Total Computation Time: 326.38 seconds
# Total Communication Time: 0.14 seconds
# Epoch 13, Iteration 1: H_t = 25, G_t = 0.4619, σ_t^2 = 26.6781
# Epoch 13, Iteration 2: H_t = 4, G_t = -0.8632, σ_t^2 = 34.6821
# Epoch 13, Iteration 3: H_t = 4, G_t = -0.2174, σ_t^2 = 23.7620
# Epoch 13, Iteration 4: H_t = 64, G_t = 1.4274, σ_t^2 = 25.2663
# Epoch 13, Iteration 5: H_t = 4, G_t = -0.2032, σ_t^2 = 28.1029
# Epoch 13, Iteration 6: H_t = 24, G_t = 0.3807, σ_t^2 = 23.2796
# Epoch 13, Iteration 7: H_t = 4, G_t = -0.0063, σ_t^2 = 30.2073
# Epoch 13, Iteration 8: H_t = 4, G_t = -0.2733, σ_t^2 = 26.9904
# Epoch 13, Iteration 9: H_t = 4, G_t = -0.7509, σ_t^2 = 24.7845
# Epoch 13, Iteration 10: H_t = 4, G_t = -0.3751, σ_t^2 = 28.4268
# Epoch 13, Iteration 11: H_t = 64, G_t = 2.4488, σ_t^2 = 25.1542
# Epoch 13, Iteration 12: H_t = 64, G_t = 1.9678, σ_t^2 = 23.3801
#     Worker 0: Train Loss: 3.1406, Train Accuracy: 22.48%
#     Worker 1: Train Loss: 3.1761, Train Accuracy: 22.45%
#     Worker 2: Train Loss: 3.1136, Train Accuracy: 23.36%
#     Worker 3: Train Loss: 3.1647, Train Accuracy: 22.55%
# Epoch 13: Test Loss: 2.9901, Test Accuracy: 26.44%
# Total Computation Time: 351.39 seconds
# Total Communication Time: 0.16 seconds
# Epoch 14, Iteration 1: H_t = 4, G_t = -0.0619, σ_t^2 = 27.2105
# Epoch 14, Iteration 2: H_t = 4, G_t = -1.4919, σ_t^2 = 25.7670
# Epoch 14, Iteration 3: H_t = 64, G_t = 1.7796, σ_t^2 = 24.4074
# Epoch 14, Iteration 4: H_t = 25, G_t = 0.4268, σ_t^2 = 24.9844
# Epoch 14, Iteration 5: H_t = 64, G_t = 1.6143, σ_t^2 = 22.9478
# Epoch 14, Iteration 6: H_t = 4, G_t = 0.0443, σ_t^2 = 26.5811
#     Worker 0: Train Loss: 3.1045, Train Accuracy: 23.11%
#     Worker 1: Train Loss: 3.1213, Train Accuracy: 23.54%
#     Worker 2: Train Loss: 3.0901, Train Accuracy: 23.57%
#     Worker 3: Train Loss: 3.1154, Train Accuracy: 23.11%
# Epoch 14: Test Loss: 2.9279, Test Accuracy: 27.97%
# Total Computation Time: 377.99 seconds
# Total Communication Time: 0.17 seconds
# Epoch 15, Iteration 1: H_t = 9, G_t = 0.1618, σ_t^2 = 24.6248
# Epoch 15, Iteration 2: H_t = 30, G_t = 0.5177, σ_t^2 = 25.1985
# Epoch 15, Iteration 3: H_t = 44, G_t = 0.9031, σ_t^2 = 30.2717
# Epoch 15, Iteration 4: H_t = 4, G_t = -2.2161, σ_t^2 = 30.8280
# Epoch 15, Iteration 5: H_t = 4, G_t = -0.1931, σ_t^2 = 27.7566
# Epoch 15, Iteration 6: H_t = 16, G_t = 0.2936, σ_t^2 = 26.0647
# Epoch 15, Iteration 7: H_t = 64, G_t = 4.4336, σ_t^2 = 33.6363
# Epoch 15, Iteration 8: H_t = 4, G_t = -1.6033, σ_t^2 = 32.9708
# Epoch 15, Iteration 9: H_t = 4, G_t = -0.1329, σ_t^2 = 25.6786
# Epoch 15, Iteration 10: H_t = 4, G_t = -0.8765, σ_t^2 = 28.6528
# Epoch 15, Iteration 11: H_t = 4, G_t = -1.0915, σ_t^2 = 30.0456
# Epoch 15, Iteration 12: H_t = 9, G_t = 0.1982, σ_t^2 = 32.4551
# Epoch 15, Iteration 13: H_t = 4, G_t = -0.3377, σ_t^2 = 32.7210
#     Worker 0: Train Loss: 3.0408, Train Accuracy: 24.69%
#     Worker 1: Train Loss: 3.0673, Train Accuracy: 23.84%
#     Worker 2: Train Loss: 2.9901, Train Accuracy: 25.85%
#     Worker 3: Train Loss: 3.0533, Train Accuracy: 24.44%
# Epoch 15: Test Loss: 2.8754, Test Accuracy: 28.62%
# Total Computation Time: 401.86 seconds
# Total Communication Time: 0.18 seconds
# Epoch 16, Iteration 1: H_t = 4, G_t = 0.0777, σ_t^2 = 27.5450
# Epoch 16, Iteration 2: H_t = 64, G_t = 2.9275, σ_t^2 = 29.1285
# Epoch 16, Iteration 3: H_t = 4, G_t = -0.8454, σ_t^2 = 36.7381
# Epoch 16, Iteration 4: H_t = 4, G_t = -1.8176, σ_t^2 = 28.9143
# Epoch 16, Iteration 5: H_t = 9, G_t = 0.1345, σ_t^2 = 21.2274
# Epoch 16, Iteration 6: H_t = 4, G_t = 0.0944, σ_t^2 = 33.6712
# Epoch 16, Iteration 7: H_t = 4, G_t = -2.0959, σ_t^2 = 38.3123
# Epoch 16, Iteration 8: H_t = 15, G_t = 0.3003, σ_t^2 = 29.8080
# Epoch 16, Iteration 9: H_t = 43, G_t = 0.8714, σ_t^2 = 29.8979
# Epoch 16, Iteration 10: H_t = 63, G_t = 1.1564, σ_t^2 = 27.3213
# Epoch 16, Iteration 11: H_t = 4, G_t = -1.7527, σ_t^2 = 31.3735
#     Worker 0: Train Loss: 2.9971, Train Accuracy: 25.28%
#     Worker 1: Train Loss: 3.0211, Train Accuracy: 25.08%
#     Worker 2: Train Loss: 2.9667, Train Accuracy: 25.85%
#     Worker 3: Train Loss: 3.0128, Train Accuracy: 25.47%
# Epoch 16: Test Loss: 2.8170, Test Accuracy: 29.88%
# Total Computation Time: 427.70 seconds
# Total Communication Time: 0.19 seconds
# Epoch 17, Iteration 1: H_t = 14, G_t = 0.2735, σ_t^2 = 28.0113
# Epoch 17, Iteration 2: H_t = 4, G_t = -0.1257, σ_t^2 = 34.0695
# Epoch 17, Iteration 3: H_t = 4, G_t = -1.3893, σ_t^2 = 35.5611
# Epoch 17, Iteration 4: H_t = 4, G_t = -0.8442, σ_t^2 = 32.4498
# Epoch 17, Iteration 5: H_t = 15, G_t = 0.3746, σ_t^2 = 36.7035
# Epoch 17, Iteration 6: H_t = 64, G_t = 1.8529, σ_t^2 = 25.5198
# Epoch 17, Iteration 7: H_t = 38, G_t = 0.7716, σ_t^2 = 29.7706
# Epoch 17, Iteration 8: H_t = 7, G_t = 0.1450, σ_t^2 = 30.1025
# Epoch 17, Iteration 9: H_t = 8, G_t = 0.1496, σ_t^2 = 27.2046
# Epoch 17, Iteration 10: H_t = 4, G_t = -2.1728, σ_t^2 = 35.3878
# Epoch 17, Iteration 11: H_t = 4, G_t = -0.9437, σ_t^2 = 33.2561
# Epoch 17, Iteration 12: H_t = 4, G_t = 0.0029, σ_t^2 = 30.8492
# Epoch 17, Iteration 13: H_t = 4, G_t = -1.8553, σ_t^2 = 39.4797
# Epoch 17, Iteration 14: H_t = 64, G_t = 2.0926, σ_t^2 = 35.8308
# Epoch 17, Iteration 15: H_t = 28, G_t = 0.5971, σ_t^2 = 30.8902
#     Worker 0: Train Loss: 2.9277, Train Accuracy: 26.59%
#     Worker 1: Train Loss: 2.9672, Train Accuracy: 26.35%
#     Worker 2: Train Loss: 2.9169, Train Accuracy: 27.42%
#     Worker 3: Train Loss: 2.9487, Train Accuracy: 26.57%
# Epoch 17: Test Loss: 2.7845, Test Accuracy: 30.27%
# Total Computation Time: 456.77 seconds
# Total Communication Time: 0.21 seconds
# Epoch 18, Iteration 1: H_t = 4, G_t = -0.6876, σ_t^2 = 36.9580
# Epoch 18, Iteration 2: H_t = 4, G_t = -1.4767, σ_t^2 = 32.1120
# Epoch 18, Iteration 3: H_t = 44, G_t = 0.9353, σ_t^2 = 31.8186
# Epoch 18, Iteration 4: H_t = 50, G_t = 0.9529, σ_t^2 = 28.3822
# Epoch 18, Iteration 5: H_t = 64, G_t = 5.4535, σ_t^2 = 30.3797
# Epoch 18, Iteration 6: H_t = 4, G_t = -2.3104, σ_t^2 = 36.5967
# Epoch 18, Iteration 7: H_t = 64, G_t = 1.3806, σ_t^2 = 27.2970
#     Worker 0: Train Loss: 2.9100, Train Accuracy: 27.43%
#     Worker 1: Train Loss: 2.9190, Train Accuracy: 27.15%
#     Worker 2: Train Loss: 2.9024, Train Accuracy: 27.12%
#     Worker 3: Train Loss: 2.9103, Train Accuracy: 27.11%
# Epoch 18: Test Loss: 2.7812, Test Accuracy: 29.94%
# Total Computation Time: 480.51 seconds
# Total Communication Time: 0.22 seconds
# Epoch 19, Iteration 1: H_t = 15, G_t = 0.2644, σ_t^2 = 26.3178
# Epoch 19, Iteration 2: H_t = 4, G_t = -1.3550, σ_t^2 = 31.1935
# Epoch 19, Iteration 3: H_t = 4, G_t = -0.1013, σ_t^2 = 26.1032
# Epoch 19, Iteration 4: H_t = 46, G_t = 0.9511, σ_t^2 = 30.4500
# Epoch 19, Iteration 5: H_t = 51, G_t = 0.9768, σ_t^2 = 28.4070
# Epoch 19, Iteration 6: H_t = 59, G_t = 1.5533, σ_t^2 = 39.1253
# Epoch 19, Iteration 7: H_t = 64, G_t = 2.4007, σ_t^2 = 27.4371
#     Worker 0: Train Loss: 2.8647, Train Accuracy: 28.17%
#     Worker 1: Train Loss: 2.9133, Train Accuracy: 27.02%
#     Worker 2: Train Loss: 2.8586, Train Accuracy: 28.10%
#     Worker 3: Train Loss: 2.8822, Train Accuracy: 27.75%
# Epoch 19: Test Loss: 2.7024, Test Accuracy: 31.94%
# Total Computation Time: 509.31 seconds
# Total Communication Time: 0.23 seconds
# Epoch 20, Iteration 1: H_t = 4, G_t = -1.4371, σ_t^2 = 33.2510
# Epoch 20, Iteration 2: H_t = 64, G_t = 1.1457, σ_t^2 = 25.6182
# Epoch 20, Iteration 3: H_t = 4, G_t = -0.2438, σ_t^2 = 35.1389
# Epoch 20, Iteration 4: H_t = 64, G_t = 1.8882, σ_t^2 = 27.0264
# Epoch 20, Iteration 5: H_t = 4, G_t = -2.9937, σ_t^2 = 47.7480
#     Worker 0: Train Loss: 2.8534, Train Accuracy: 27.89%
#     Worker 1: Train Loss: 2.8425, Train Accuracy: 28.47%
#     Worker 2: Train Loss: 2.8198, Train Accuracy: 28.97%
#     Worker 3: Train Loss: 2.8520, Train Accuracy: 28.18%
# Epoch 20: Test Loss: 2.6574, Test Accuracy: 33.08%
# Total Computation Time: 532.98 seconds
# Total Communication Time: 0.24 seconds
# Epoch 21, Iteration 1: H_t = 64, G_t = 2.1428, σ_t^2 = 24.9113
# Epoch 21, Iteration 2: H_t = 9, G_t = 0.2331, σ_t^2 = 36.0569
# Epoch 21, Iteration 3: H_t = 28, G_t = 0.5396, σ_t^2 = 28.5115
# Epoch 21, Iteration 4: H_t = 4, G_t = -0.8404, σ_t^2 = 35.1641
# Epoch 21, Iteration 5: H_t = 4, G_t = -2.6989, σ_t^2 = 39.2941
# Epoch 21, Iteration 6: H_t = 6, G_t = 0.1332, σ_t^2 = 30.9004
# Epoch 21, Iteration 7: H_t = 4, G_t = -0.8534, σ_t^2 = 35.8488
# Epoch 21, Iteration 8: H_t = 4, G_t = -1.4477, σ_t^2 = 45.0434
# Epoch 21, Iteration 9: H_t = 32, G_t = 0.7123, σ_t^2 = 32.6168
# Epoch 21, Iteration 10: H_t = 5, G_t = 0.1318, σ_t^2 = 34.1915
# Epoch 21, Iteration 11: H_t = 64, G_t = 1.3321, σ_t^2 = 27.0033
# Epoch 21, Iteration 12: H_t = 4, G_t = -0.7621, σ_t^2 = 37.6896
#     Worker 0: Train Loss: 2.7488, Train Accuracy: 30.20%
#     Worker 1: Train Loss: 2.7937, Train Accuracy: 29.43%
#     Worker 2: Train Loss: 2.7624, Train Accuracy: 30.02%
#     Worker 3: Train Loss: 2.7701, Train Accuracy: 29.86%
# Epoch 21: Test Loss: 2.6244, Test Accuracy: 34.24%
# Total Computation Time: 559.98 seconds
# Total Communication Time: 0.25 seconds
# Epoch 22, Iteration 1: H_t = 64, G_t = 1.8095, σ_t^2 = 26.2761
# Epoch 22, Iteration 2: H_t = 4, G_t = -1.0162, σ_t^2 = 36.8984
# Epoch 22, Iteration 3: H_t = 64, G_t = 1.5231, σ_t^2 = 31.3401
# Epoch 22, Iteration 4: H_t = 4, G_t = -0.8832, σ_t^2 = 33.7735
# Epoch 22, Iteration 5: H_t = 4, G_t = -0.0530, σ_t^2 = 28.4334
# Epoch 22, Iteration 6: H_t = 4, G_t = -1.1809, σ_t^2 = 29.6246
# Epoch 22, Iteration 7: H_t = 64, G_t = 2.4794, σ_t^2 = 31.8082
# Epoch 22, Iteration 8: H_t = 21, G_t = 0.4833, σ_t^2 = 33.5712
#     Worker 0: Train Loss: 2.7318, Train Accuracy: 30.51%
#     Worker 1: Train Loss: 2.7704, Train Accuracy: 29.93%
#     Worker 2: Train Loss: 2.7130, Train Accuracy: 31.75%
#     Worker 3: Train Loss: 2.7508, Train Accuracy: 29.72%
# Epoch 22: Test Loss: 2.5733, Test Accuracy: 34.88%
# Total Computation Time: 585.12 seconds
# Total Communication Time: 0.26 seconds
# Epoch 23, Iteration 1: H_t = 4, G_t = -0.5910, σ_t^2 = 36.3644
# Epoch 23, Iteration 2: H_t = 36, G_t = 0.6864, σ_t^2 = 28.0439
# Epoch 23, Iteration 3: H_t = 4, G_t = -2.5935, σ_t^2 = 39.3921
# Epoch 23, Iteration 4: H_t = 4, G_t = -0.1732, σ_t^2 = 35.4969
# Epoch 23, Iteration 5: H_t = 64, G_t = 3.5498, σ_t^2 = 30.5802
# Epoch 23, Iteration 6: H_t = 45, G_t = 0.9596, σ_t^2 = 31.4303
# Epoch 23, Iteration 7: H_t = 17, G_t = 0.3533, σ_t^2 = 31.0565
# Epoch 23, Iteration 8: H_t = 64, G_t = 3.4907, σ_t^2 = 35.8629
# Epoch 23, Iteration 9: H_t = 4, G_t = -2.3184, σ_t^2 = 36.5975
#     Worker 0: Train Loss: 2.6632, Train Accuracy: 31.91%
#     Worker 1: Train Loss: 2.7013, Train Accuracy: 31.33%
#     Worker 2: Train Loss: 2.6571, Train Accuracy: 32.01%
#     Worker 3: Train Loss: 2.6939, Train Accuracy: 31.35%
# Epoch 23: Test Loss: 2.5280, Test Accuracy: 35.78%
# Total Computation Time: 616.29 seconds
# Total Communication Time: 0.27 seconds
# Epoch 24, Iteration 1: H_t = 4, G_t = -0.5561, σ_t^2 = 38.2999
# Epoch 24, Iteration 2: H_t = 59, G_t = 1.3482, σ_t^2 = 33.7970
# Epoch 24, Iteration 3: H_t = 4, G_t = -1.6676, σ_t^2 = 37.0620
# Epoch 24, Iteration 4: H_t = 4, G_t = -0.6571, σ_t^2 = 31.6743
# Epoch 24, Iteration 5: H_t = 4, G_t = 0.0599, σ_t^2 = 30.5761
# Epoch 24, Iteration 6: H_t = 4, G_t = -0.9949, σ_t^2 = 34.3153
# Epoch 24, Iteration 7: H_t = 64, G_t = 2.9760, σ_t^2 = 31.1221
# Epoch 24, Iteration 8: H_t = 4, G_t = -1.6269, σ_t^2 = 37.5054
# Epoch 24, Iteration 9: H_t = 64, G_t = 1.2371, σ_t^2 = 26.9081
# Epoch 24, Iteration 10: H_t = 39, G_t = 0.8385, σ_t^2 = 31.5204
#     Worker 0: Train Loss: 2.6475, Train Accuracy: 32.11%
#     Worker 1: Train Loss: 2.6739, Train Accuracy: 32.10%
#     Worker 2: Train Loss: 2.6332, Train Accuracy: 32.79%
#     Worker 3: Train Loss: 2.6489, Train Accuracy: 32.41%
# Epoch 24: Test Loss: 2.5003, Test Accuracy: 36.62%
# Total Computation Time: 641.81 seconds
# Total Communication Time: 0.28 seconds
# Epoch 25, Iteration 1: H_t = 4, G_t = -1.1581, σ_t^2 = 33.8997
# Epoch 25, Iteration 2: H_t = 64, G_t = 2.7201, σ_t^2 = 26.7662
# Epoch 25, Iteration 3: H_t = 4, G_t = -1.1570, σ_t^2 = 37.6614
# Epoch 25, Iteration 4: H_t = 64, G_t = 2.5748, σ_t^2 = 35.7086
# Epoch 25, Iteration 5: H_t = 4, G_t = -0.3324, σ_t^2 = 35.3565
# Epoch 25, Iteration 6: H_t = 4, G_t = -0.2272, σ_t^2 = 30.5269
# Epoch 25, Iteration 7: H_t = 4, G_t = -1.5466, σ_t^2 = 32.3648
# Epoch 25, Iteration 8: H_t = 51, G_t = 1.1838, σ_t^2 = 34.3967
# Epoch 25, Iteration 9: H_t = 4, G_t = -0.6491, σ_t^2 = 39.0556
#     Worker 0: Train Loss: 2.5929, Train Accuracy: 32.91%
#     Worker 1: Train Loss: 2.6295, Train Accuracy: 32.78%
#     Worker 2: Train Loss: 2.5888, Train Accuracy: 34.24%
#     Worker 3: Train Loss: 2.6360, Train Accuracy: 31.96%
# Epoch 25: Test Loss: 2.4618, Test Accuracy: 36.75%
# Total Computation Time: 670.69 seconds
# Total Communication Time: 0.30 seconds
# Epoch 26, Iteration 1: H_t = 4, G_t = -1.2411, σ_t^2 = 36.1906
# Epoch 26, Iteration 2: H_t = 25, G_t = 0.5134, σ_t^2 = 30.3740
# Epoch 26, Iteration 3: H_t = 4, G_t = -0.0777, σ_t^2 = 42.9605
# Epoch 26, Iteration 4: H_t = 4, G_t = -0.6689, σ_t^2 = 39.3554
# Epoch 26, Iteration 5: H_t = 9, G_t = 0.2143, σ_t^2 = 32.1717
# Epoch 26, Iteration 6: H_t = 64, G_t = 1.8557, σ_t^2 = 34.1608
# Epoch 26, Iteration 7: H_t = 4, G_t = -1.7466, σ_t^2 = 37.5290
# Epoch 26, Iteration 8: H_t = 64, G_t = 1.9920, σ_t^2 = 34.0105
# Epoch 26, Iteration 9: H_t = 64, G_t = 1.7124, σ_t^2 = 32.2966
# Epoch 26, Iteration 10: H_t = 43, G_t = 1.1535, σ_t^2 = 40.1079
#     Worker 0: Train Loss: 2.5778, Train Accuracy: 33.22%
#     Worker 1: Train Loss: 2.6087, Train Accuracy: 33.08%
#     Worker 2: Train Loss: 2.5447, Train Accuracy: 34.68%
#     Worker 3: Train Loss: 2.5971, Train Accuracy: 33.18%
# Epoch 26: Test Loss: 2.4368, Test Accuracy: 37.26%
# Total Computation Time: 699.71 seconds
# Total Communication Time: 0.31 seconds
# Epoch 27, Iteration 1: H_t = 4, G_t = -0.6142, σ_t^2 = 38.6427
# Epoch 27, Iteration 2: H_t = 58, G_t = 1.1381, σ_t^2 = 29.3242
# Epoch 27, Iteration 3: H_t = 4, G_t = -0.2024, σ_t^2 = 38.7692
# Epoch 27, Iteration 4: H_t = 64, G_t = 1.3512, σ_t^2 = 27.6261
# Epoch 27, Iteration 5: H_t = 4, G_t = -0.1389, σ_t^2 = 36.1767
# Epoch 27, Iteration 6: H_t = 64, G_t = 3.4433, σ_t^2 = 35.0418
# Epoch 27, Iteration 7: H_t = 18, G_t = 0.4250, σ_t^2 = 34.8073
#     Worker 0: Train Loss: 2.5354, Train Accuracy: 34.76%
#     Worker 1: Train Loss: 2.5479, Train Accuracy: 35.10%
#     Worker 2: Train Loss: 2.5389, Train Accuracy: 34.74%
#     Worker 3: Train Loss: 2.5539, Train Accuracy: 34.14%
# Epoch 27: Test Loss: 2.3964, Test Accuracy: 37.93%
# Total Computation Time: 728.60 seconds
# Total Communication Time: 0.32 seconds
# Epoch 28, Iteration 1: H_t = 64, G_t = 1.7225, σ_t^2 = 34.7080
# Epoch 28, Iteration 2: H_t = 51, G_t = 1.2713, σ_t^2 = 37.2224
# Epoch 28, Iteration 3: H_t = 4, G_t = -1.7045, σ_t^2 = 49.3101
# Epoch 28, Iteration 4: H_t = 4, G_t = -0.2910, σ_t^2 = 33.3281
# Epoch 28, Iteration 5: H_t = 64, G_t = 4.2552, σ_t^2 = 32.1825
# Epoch 28, Iteration 6: H_t = 4, G_t = -0.7544, σ_t^2 = 40.2610
#     Worker 0: Train Loss: 2.5119, Train Accuracy: 34.91%
#     Worker 1: Train Loss: 2.5161, Train Accuracy: 35.36%
#     Worker 2: Train Loss: 2.4848, Train Accuracy: 35.83%
#     Worker 3: Train Loss: 2.5195, Train Accuracy: 34.61%
# Epoch 28: Test Loss: 2.3886, Test Accuracy: 38.50%
# Total Computation Time: 752.96 seconds
# Total Communication Time: 0.32 seconds
# Epoch 29, Iteration 1: H_t = 13, G_t = 0.3414, σ_t^2 = 37.8619
# Epoch 29, Iteration 2: H_t = 4, G_t = -1.3683, σ_t^2 = 41.5738
# Epoch 29, Iteration 3: H_t = 4, G_t = -0.1680, σ_t^2 = 45.1336
# Epoch 29, Iteration 4: H_t = 64, G_t = 2.7360, σ_t^2 = 37.6548
# Epoch 29, Iteration 5: H_t = 64, G_t = 3.8478, σ_t^2 = 34.4241
# Epoch 29, Iteration 6: H_t = 4, G_t = -1.9260, σ_t^2 = 36.4792
# Epoch 29, Iteration 7: H_t = 5, G_t = 0.1103, σ_t^2 = 32.3575
# Epoch 29, Iteration 8: H_t = 4, G_t = -0.5330, σ_t^2 = 38.8866
# Epoch 29, Iteration 9: H_t = 64, G_t = 2.4553, σ_t^2 = 32.4751
# Epoch 29, Iteration 10: H_t = 4, G_t = 0.0757, σ_t^2 = 42.1987
#     Worker 0: Train Loss: 2.4694, Train Accuracy: 35.63%
#     Worker 1: Train Loss: 2.5000, Train Accuracy: 35.47%
#     Worker 2: Train Loss: 2.4620, Train Accuracy: 36.54%
#     Worker 3: Train Loss: 2.4893, Train Accuracy: 35.64%
# Epoch 29: Test Loss: 2.3550, Test Accuracy: 38.93%
# Total Computation Time: 779.93 seconds
# Total Communication Time: 0.33 seconds
# Epoch 30, Iteration 1: H_t = 64, G_t = 1.7700, σ_t^2 = 31.6802
# Epoch 30, Iteration 2: H_t = 4, G_t = -1.5065, σ_t^2 = 39.2965
# Epoch 30, Iteration 3: H_t = 4, G_t = -0.7052, σ_t^2 = 35.2186
# Epoch 30, Iteration 4: H_t = 10, G_t = 0.2773, σ_t^2 = 38.5890
# Epoch 30, Iteration 5: H_t = 4, G_t = -1.6988, σ_t^2 = 48.1910
# Epoch 30, Iteration 6: H_t = 38, G_t = 0.9539, σ_t^2 = 37.1126
# Epoch 30, Iteration 7: H_t = 4, G_t = -0.5896, σ_t^2 = 42.6463
# Epoch 30, Iteration 8: H_t = 4, G_t = -1.1787, σ_t^2 = 38.4122
# Epoch 30, Iteration 9: H_t = 64, G_t = 1.4822, σ_t^2 = 33.4876
# Epoch 30, Iteration 10: H_t = 4, G_t = -0.5571, σ_t^2 = 40.9744
#     Worker 0: Train Loss: 2.4357, Train Accuracy: 36.93%
#     Worker 1: Train Loss: 2.4561, Train Accuracy: 36.45%
#     Worker 2: Train Loss: 2.4138, Train Accuracy: 37.14%
#     Worker 3: Train Loss: 2.4669, Train Accuracy: 36.42%
# Epoch 30: Test Loss: 2.3338, Test Accuracy: 39.64%
# Total Computation Time: 803.04 seconds
# Total Communication Time: 0.35 seconds
# Epoch 31, Iteration 1: H_t = 4, G_t = -2.0945, σ_t^2 = 42.2426
# Epoch 31, Iteration 2: H_t = 4, G_t = -1.6064, σ_t^2 = 36.4415
# Epoch 31, Iteration 3: H_t = 4, G_t = -1.0594, σ_t^2 = 39.6125
# Epoch 31, Iteration 4: H_t = 4, G_t = -0.6829, σ_t^2 = 40.1342
# Epoch 31, Iteration 5: H_t = 4, G_t = -0.7495, σ_t^2 = 32.9103
# Epoch 31, Iteration 6: H_t = 4, G_t = -1.4158, σ_t^2 = 45.8477
# Epoch 31, Iteration 7: H_t = 4, G_t = -1.0861, σ_t^2 = 47.6113
# Epoch 31, Iteration 8: H_t = 42, G_t = 1.2747, σ_t^2 = 45.4451
# Epoch 31, Iteration 9: H_t = 4, G_t = -0.7857, σ_t^2 = 40.5380
# Epoch 31, Iteration 10: H_t = 4, G_t = -0.7605, σ_t^2 = 37.5133
# Epoch 31, Iteration 11: H_t = 33, G_t = 0.7983, σ_t^2 = 35.9256
# Epoch 31, Iteration 12: H_t = 4, G_t = 0.0326, σ_t^2 = 41.1773
# Epoch 31, Iteration 13: H_t = 35, G_t = 0.7360, σ_t^2 = 31.4056
# Epoch 31, Iteration 14: H_t = 16, G_t = 0.3652, σ_t^2 = 33.9100
# Epoch 31, Iteration 15: H_t = 4, G_t = -0.4307, σ_t^2 = 43.3930
# Epoch 31, Iteration 16: H_t = 5, G_t = 0.1523, σ_t^2 = 40.7447
# Epoch 31, Iteration 17: H_t = 64, G_t = 1.5487, σ_t^2 = 35.0473
# Epoch 31, Iteration 18: H_t = 4, G_t = 0.0212, σ_t^2 = 43.7424
#     Worker 0: Train Loss: 2.3994, Train Accuracy: 37.68%
#     Worker 1: Train Loss: 2.4085, Train Accuracy: 37.25%
#     Worker 2: Train Loss: 2.3726, Train Accuracy: 38.40%
#     Worker 3: Train Loss: 2.4321, Train Accuracy: 36.77%
# Epoch 31: Test Loss: 2.3228, Test Accuracy: 39.72%
# Total Computation Time: 831.37 seconds
# Total Communication Time: 0.37 seconds
# Epoch 32, Iteration 1: H_t = 48, G_t = 1.1271, σ_t^2 = 35.1365
# Epoch 32, Iteration 2: H_t = 4, G_t = -0.9544, σ_t^2 = 50.6161
# Epoch 32, Iteration 3: H_t = 64, G_t = 3.3050, σ_t^2 = 35.3637
# Epoch 32, Iteration 4: H_t = 64, G_t = 3.4193, σ_t^2 = 38.6088
# Epoch 32, Iteration 5: H_t = 4, G_t = -0.7452, σ_t^2 = 36.0858
# Epoch 32, Iteration 6: H_t = 21, G_t = 0.4834, σ_t^2 = 33.9790
# Epoch 32, Iteration 7: H_t = 4, G_t = -0.3998, σ_t^2 = 39.9035
#     Worker 0: Train Loss: 2.3917, Train Accuracy: 37.47%
#     Worker 1: Train Loss: 2.4234, Train Accuracy: 37.01%
#     Worker 2: Train Loss: 2.3790, Train Accuracy: 38.39%
#     Worker 3: Train Loss: 2.3697, Train Accuracy: 37.44%
# Epoch 32: Test Loss: 2.2800, Test Accuracy: 40.58%
# Total Computation Time: 856.01 seconds
# Total Communication Time: 0.38 seconds
# Epoch 33, Iteration 1: H_t = 64, G_t = 2.0657, σ_t^2 = 35.6174
# Epoch 33, Iteration 2: H_t = 4, G_t = -1.2222, σ_t^2 = 35.8858
# Epoch 33, Iteration 3: H_t = 4, G_t = -0.2104, σ_t^2 = 37.6072
# Epoch 33, Iteration 4: H_t = 4, G_t = -0.0553, σ_t^2 = 34.5614
# Epoch 33, Iteration 5: H_t = 24, G_t = 0.5967, σ_t^2 = 36.1650
# Epoch 33, Iteration 6: H_t = 64, G_t = 2.5028, σ_t^2 = 40.7502
# Epoch 33, Iteration 7: H_t = 4, G_t = -0.4876, σ_t^2 = 36.4685
# Epoch 33, Iteration 8: H_t = 30, G_t = 0.7481, σ_t^2 = 36.8280
# Epoch 33, Iteration 9: H_t = 4, G_t = -1.8948, σ_t^2 = 45.2455
#     Worker 0: Train Loss: 2.3488, Train Accuracy: 38.52%
#     Worker 1: Train Loss: 2.3582, Train Accuracy: 38.44%
#     Worker 2: Train Loss: 2.3445, Train Accuracy: 39.08%
#     Worker 3: Train Loss: 2.3711, Train Accuracy: 37.95%
# Epoch 33: Test Loss: 2.2689, Test Accuracy: 41.22%
# Total Computation Time: 880.22 seconds
# Total Communication Time: 0.39 seconds
# Epoch 34, Iteration 1: H_t = 64, G_t = 2.9638, σ_t^2 = 33.5674
# Epoch 34, Iteration 2: H_t = 5, G_t = 0.1311, σ_t^2 = 38.0942
# Epoch 34, Iteration 3: H_t = 4, G_t = -1.6351, σ_t^2 = 45.1345
# Epoch 34, Iteration 4: H_t = 61, G_t = 1.4277, σ_t^2 = 34.5532
# Epoch 34, Iteration 5: H_t = 4, G_t = -1.6587, σ_t^2 = 39.4226
# Epoch 34, Iteration 6: H_t = 57, G_t = 1.4027, σ_t^2 = 36.6176
# Epoch 34, Iteration 7: H_t = 4, G_t = -1.6105, σ_t^2 = 49.0174
#     Worker 0: Train Loss: 2.3529, Train Accuracy: 38.39%
#     Worker 1: Train Loss: 2.3643, Train Accuracy: 37.71%
#     Worker 2: Train Loss: 2.3219, Train Accuracy: 39.47%
#     Worker 3: Train Loss: 2.3448, Train Accuracy: 38.61%
# Epoch 34: Test Loss: 2.2470, Test Accuracy: 41.69%
# Total Computation Time: 904.49 seconds
# Total Communication Time: 0.40 seconds
# Epoch 35, Iteration 1: H_t = 4, G_t = -0.6814, σ_t^2 = 39.3729
# Epoch 35, Iteration 2: H_t = 64, G_t = 1.8348, σ_t^2 = 39.1945
# Epoch 35, Iteration 3: H_t = 4, G_t = -0.6181, σ_t^2 = 46.2958
# Epoch 35, Iteration 4: H_t = 4, G_t = -0.5384, σ_t^2 = 37.2343
# Epoch 35, Iteration 5: H_t = 4, G_t = -0.0744, σ_t^2 = 35.5469
# Epoch 35, Iteration 6: H_t = 36, G_t = 0.8994, σ_t^2 = 36.6540
# Epoch 35, Iteration 7: H_t = 4, G_t = -0.2616, σ_t^2 = 45.2536
# Epoch 35, Iteration 8: H_t = 56, G_t = 1.3589, σ_t^2 = 36.1719
# Epoch 35, Iteration 9: H_t = 4, G_t = -0.5331, σ_t^2 = 40.6571
# Epoch 35, Iteration 10: H_t = 64, G_t = 3.3974, σ_t^2 = 35.5571
# Epoch 35, Iteration 11: H_t = 4, G_t = -2.2313, σ_t^2 = 133.2012
#     Worker 0: Train Loss: 2.3088, Train Accuracy: 39.45%
#     Worker 1: Train Loss: 2.3405, Train Accuracy: 38.72%
#     Worker 2: Train Loss: 2.3100, Train Accuracy: 39.64%
#     Worker 3: Train Loss: 2.3514, Train Accuracy: 38.21%
# Epoch 35: Test Loss: 2.2323, Test Accuracy: 42.11%
# Total Computation Time: 934.04 seconds
# Total Communication Time: 0.41 seconds
# Epoch 36, Iteration 1: H_t = 12, G_t = 0.3586, σ_t^2 = 41.4593
# Epoch 36, Iteration 2: H_t = 19, G_t = 0.5071, σ_t^2 = 38.2023
# Epoch 36, Iteration 3: H_t = 4, G_t = -0.6247, σ_t^2 = 45.9438
# Epoch 36, Iteration 4: H_t = 13, G_t = 0.4207, σ_t^2 = 46.0744
# Epoch 36, Iteration 5: H_t = 4, G_t = -0.5360, σ_t^2 = 45.7158
# Epoch 36, Iteration 6: H_t = 4, G_t = -0.3324, σ_t^2 = 35.8815
# Epoch 36, Iteration 7: H_t = 4, G_t = -0.8420, σ_t^2 = 42.2304
# Epoch 36, Iteration 8: H_t = 64, G_t = 2.7001, σ_t^2 = 44.1584
# Epoch 36, Iteration 9: H_t = 4, G_t = -1.8728, σ_t^2 = 41.4485
# Epoch 36, Iteration 10: H_t = 64, G_t = 2.7665, σ_t^2 = 32.6907
# Epoch 36, Iteration 11: H_t = 4, G_t = -1.5261, σ_t^2 = 127.2387
#     Worker 0: Train Loss: 2.2762, Train Accuracy: 40.22%
#     Worker 1: Train Loss: 2.2953, Train Accuracy: 39.50%
#     Worker 2: Train Loss: 2.2443, Train Accuracy: 41.07%
#     Worker 3: Train Loss: 2.2837, Train Accuracy: 39.80%
# Epoch 36: Test Loss: 2.2379, Test Accuracy: 42.39%
# Total Computation Time: 957.23 seconds
# Total Communication Time: 0.42 seconds
# Epoch 37, Iteration 1: H_t = 7, G_t = 0.2165, σ_t^2 = 42.5838
# Epoch 37, Iteration 2: H_t = 64, G_t = 2.8863, σ_t^2 = 43.1325
# Epoch 37, Iteration 3: H_t = 4, G_t = -0.4254, σ_t^2 = 43.3260
# Epoch 37, Iteration 4: H_t = 10, G_t = 0.2220, σ_t^2 = 32.7218
# Epoch 37, Iteration 5: H_t = 25, G_t = 0.7002, σ_t^2 = 40.4766
# Epoch 37, Iteration 6: H_t = 4, G_t = -1.9658, σ_t^2 = 41.1446
# Epoch 37, Iteration 7: H_t = 64, G_t = 1.9370, σ_t^2 = 38.3676
# Epoch 37, Iteration 8: H_t = 4, G_t = -1.5002, σ_t^2 = 46.7158
# Epoch 37, Iteration 9: H_t = 64, G_t = 2.0209, σ_t^2 = 34.0728
# Epoch 37, Iteration 10: H_t = 4, G_t = -1.4151, σ_t^2 = 47.8132
#     Worker 0: Train Loss: 2.2613, Train Accuracy: 40.56%
#     Worker 1: Train Loss: 2.2849, Train Accuracy: 40.05%
#     Worker 2: Train Loss: 2.2415, Train Accuracy: 41.21%
#     Worker 3: Train Loss: 2.2752, Train Accuracy: 39.91%
# Epoch 37: Test Loss: 2.2194, Test Accuracy: 42.02%
# Total Computation Time: 987.44 seconds
# Total Communication Time: 0.44 seconds
# Epoch 38, Iteration 1: H_t = 10, G_t = 0.2434, σ_t^2 = 34.7911
# Epoch 38, Iteration 2: H_t = 4, G_t = -1.6161, σ_t^2 = 44.3498
# Epoch 38, Iteration 3: H_t = 38, G_t = 1.0483, σ_t^2 = 40.7502
# Epoch 38, Iteration 4: H_t = 4, G_t = -0.5843, σ_t^2 = 38.9951
# Epoch 38, Iteration 5: H_t = 27, G_t = 0.6843, σ_t^2 = 37.1466
# Epoch 38, Iteration 6: H_t = 64, G_t = 2.3807, σ_t^2 = 46.8250
# Epoch 38, Iteration 7: H_t = 4, G_t = -0.6875, σ_t^2 = 44.5020
# Epoch 38, Iteration 8: H_t = 43, G_t = 1.0179, σ_t^2 = 35.0622
# Epoch 38, Iteration 9: H_t = 32, G_t = 0.9145, σ_t^2 = 41.8726
#     Worker 0: Train Loss: 2.2429, Train Accuracy: 40.71%
#     Worker 1: Train Loss: 2.2261, Train Accuracy: 41.13%
#     Worker 2: Train Loss: 2.2017, Train Accuracy: 42.14%
#     Worker 3: Train Loss: 2.2337, Train Accuracy: 40.58%
# Epoch 38: Test Loss: 2.1957, Test Accuracy: 42.85%
# Total Computation Time: 1011.11 seconds
# Total Communication Time: 0.45 seconds
# Epoch 39, Iteration 1: H_t = 58, G_t = 1.5691, σ_t^2 = 40.5786
# Epoch 39, Iteration 2: H_t = 4, G_t = -0.1108, σ_t^2 = 44.1126
# Epoch 39, Iteration 3: H_t = 64, G_t = 2.3207, σ_t^2 = 38.9844
# Epoch 39, Iteration 4: H_t = 4, G_t = -0.5430, σ_t^2 = 40.4334
# Epoch 39, Iteration 5: H_t = 29, G_t = 0.8097, σ_t^2 = 41.6400
# Epoch 39, Iteration 6: H_t = 18, G_t = 0.4889, σ_t^2 = 40.6338
# Epoch 39, Iteration 7: H_t = 64, G_t = 2.4300, σ_t^2 = 47.9186
#     Worker 0: Train Loss: 2.2028, Train Accuracy: 41.48%
#     Worker 1: Train Loss: 2.2395, Train Accuracy: 40.80%
#     Worker 2: Train Loss: 2.2109, Train Accuracy: 41.93%
#     Worker 3: Train Loss: 2.2301, Train Accuracy: 41.43%
# Epoch 39: Test Loss: 2.1757, Test Accuracy: 42.84%
# Total Computation Time: 1035.86 seconds
# Total Communication Time: 0.46 seconds
# Epoch 40, Iteration 1: H_t = 43, G_t = 1.1524, σ_t^2 = 39.2959
# Epoch 40, Iteration 2: H_t = 4, G_t = -0.5129, σ_t^2 = 45.4073
# Epoch 40, Iteration 3: H_t = 25, G_t = 0.5512, σ_t^2 = 32.4222
# Epoch 40, Iteration 4: H_t = 36, G_t = 1.0050, σ_t^2 = 41.6691
# Epoch 40, Iteration 5: H_t = 4, G_t = 0.0246, σ_t^2 = 46.8873
# Epoch 40, Iteration 6: H_t = 4, G_t = -2.5699, σ_t^2 = 45.8970
# Epoch 40, Iteration 7: H_t = 4, G_t = -0.2909, σ_t^2 = 38.5204
# Epoch 40, Iteration 8: H_t = 27, G_t = 0.7982, σ_t^2 = 43.9494
# Epoch 40, Iteration 9: H_t = 4, G_t = 0.0295, σ_t^2 = 40.0292
#     Worker 0: Train Loss: 2.2311, Train Accuracy: 41.08%
#     Worker 1: Train Loss: 2.1788, Train Accuracy: 42.20%
#     Worker 2: Train Loss: 2.1769, Train Accuracy: 42.51%
#     Worker 3: Train Loss: 2.2094, Train Accuracy: 41.43%
# Epoch 40: Test Loss: 2.1596, Test Accuracy: 43.48%
# Total Computation Time: 1060.89 seconds
# Total Communication Time: 0.47 seconds
# Epoch 41, Iteration 1: H_t = 12, G_t = 0.3394, σ_t^2 = 41.9608
# Epoch 41, Iteration 2: H_t = 31, G_t = 0.8895, σ_t^2 = 42.6037
# Epoch 41, Iteration 3: H_t = 22, G_t = 0.7082, σ_t^2 = 46.4384
# Epoch 41, Iteration 4: H_t = 4, G_t = -2.2848, σ_t^2 = 50.0554
# Epoch 41, Iteration 5: H_t = 18, G_t = 0.5699, σ_t^2 = 45.3702
# Epoch 41, Iteration 6: H_t = 22, G_t = 0.6766, σ_t^2 = 44.4924
# Epoch 41, Iteration 7: H_t = 4, G_t = -0.9354, σ_t^2 = 49.9652
# Epoch 41, Iteration 8: H_t = 4, G_t = -2.2669, σ_t^2 = 47.2022
# Epoch 41, Iteration 9: H_t = 4, G_t = -0.5919, σ_t^2 = 40.7952
# Epoch 41, Iteration 10: H_t = 64, G_t = 2.2178, σ_t^2 = 46.0334
# Epoch 41, Iteration 11: H_t = 4, G_t = -2.4886, σ_t^2 = 49.3420
# Epoch 41, Iteration 12: H_t = 4, G_t = -1.1009, σ_t^2 = 44.9909
# Epoch 41, Iteration 13: H_t = 4, G_t = 0.0868, σ_t^2 = 34.9887
#     Worker 0: Train Loss: 2.1194, Train Accuracy: 43.16%
#     Worker 1: Train Loss: 2.1938, Train Accuracy: 42.52%
#     Worker 2: Train Loss: 2.1379, Train Accuracy: 43.52%
#     Worker 3: Train Loss: 2.1697, Train Accuracy: 42.62%
# Epoch 41: Test Loss: 2.1537, Test Accuracy: 43.91%
# Total Computation Time: 1083.89 seconds
# Total Communication Time: 0.48 seconds
# Epoch 42, Iteration 1: H_t = 4, G_t = -1.3115, σ_t^2 = 43.0926
# Epoch 42, Iteration 2: H_t = 4, G_t = -0.2082, σ_t^2 = 40.4851
# Epoch 42, Iteration 3: H_t = 29, G_t = 0.9347, σ_t^2 = 48.0765
# Epoch 42, Iteration 4: H_t = 59, G_t = 1.8972, σ_t^2 = 47.9119
# Epoch 42, Iteration 5: H_t = 4, G_t = -1.6199, σ_t^2 = 50.9572
# Epoch 42, Iteration 6: H_t = 4, G_t = -0.9338, σ_t^2 = 47.5158
# Epoch 42, Iteration 7: H_t = 4, G_t = -0.3880, σ_t^2 = 35.8171
# Epoch 42, Iteration 8: H_t = 55, G_t = 1.6030, σ_t^2 = 43.1737
# Epoch 42, Iteration 9: H_t = 4, G_t = -1.7430, σ_t^2 = 45.0131
# Epoch 42, Iteration 10: H_t = 4, G_t = 0.0504, σ_t^2 = 46.7546
# Epoch 42, Iteration 11: H_t = 11, G_t = 0.3293, σ_t^2 = 41.2656
# Epoch 42, Iteration 12: H_t = 52, G_t = 1.7488, σ_t^2 = 50.0587
# Epoch 42, Iteration 13: H_t = 4, G_t = -1.1332, σ_t^2 = 49.3762
#     Worker 0: Train Loss: 2.1720, Train Accuracy: 41.81%
#     Worker 1: Train Loss: 2.1457, Train Accuracy: 42.88%
#     Worker 2: Train Loss: 2.1460, Train Accuracy: 43.19%
#     Worker 3: Train Loss: 2.1818, Train Accuracy: 41.96%
# Epoch 42: Test Loss: 2.1397, Test Accuracy: 43.69%
# Total Computation Time: 1111.91 seconds
# Total Communication Time: 0.50 seconds
# Epoch 43, Iteration 1: H_t = 64, G_t = 1.5784, σ_t^2 = 35.6547
# Epoch 43, Iteration 2: H_t = 4, G_t = -0.9184, σ_t^2 = 42.8436
# Epoch 43, Iteration 3: H_t = 4, G_t = -0.5764, σ_t^2 = 43.1710
# Epoch 43, Iteration 4: H_t = 4, G_t = 0.0085, σ_t^2 = 36.9541
# Epoch 43, Iteration 5: H_t = 49, G_t = 1.1808, σ_t^2 = 35.9600
# Epoch 43, Iteration 6: H_t = 4, G_t = -0.3259, σ_t^2 = 51.7619
# Epoch 43, Iteration 7: H_t = 18, G_t = 0.5700, σ_t^2 = 45.2124
# Epoch 43, Iteration 8: H_t = 9, G_t = 0.2654, σ_t^2 = 42.4949
# Epoch 43, Iteration 9: H_t = 53, G_t = 1.3752, σ_t^2 = 38.7602
# Epoch 43, Iteration 10: H_t = 4, G_t = -1.2798, σ_t^2 = 50.7137
#     Worker 0: Train Loss: 2.1353, Train Accuracy: 43.24%
#     Worker 1: Train Loss: 2.1382, Train Accuracy: 43.80%
#     Worker 2: Train Loss: 2.1295, Train Accuracy: 43.77%
#     Worker 3: Train Loss: 2.1504, Train Accuracy: 43.19%
# Epoch 43: Test Loss: 2.1369, Test Accuracy: 44.21%
# Total Computation Time: 1137.24 seconds
# Total Communication Time: 0.51 seconds
# Epoch 44, Iteration 1: H_t = 46, G_t = 1.0546, σ_t^2 = 34.0319
# Epoch 44, Iteration 2: H_t = 11, G_t = 0.3278, σ_t^2 = 42.5759
# Epoch 44, Iteration 3: H_t = 42, G_t = 1.3554, σ_t^2 = 47.4277
# Epoch 44, Iteration 4: H_t = 4, G_t = -1.2900, σ_t^2 = 57.0822
# Epoch 44, Iteration 5: H_t = 64, G_t = 1.7461, σ_t^2 = 39.5224
# Epoch 44, Iteration 6: H_t = 4, G_t = -1.6461, σ_t^2 = 46.9790
# Epoch 44, Iteration 7: H_t = 30, G_t = 0.8995, σ_t^2 = 44.3288
# Epoch 44, Iteration 8: H_t = 23, G_t = 0.6989, σ_t^2 = 45.4590
#     Worker 0: Train Loss: 2.1325, Train Accuracy: 43.13%
#     Worker 1: Train Loss: 2.1369, Train Accuracy: 43.40%
#     Worker 2: Train Loss: 2.1069, Train Accuracy: 44.19%
#     Worker 3: Train Loss: 2.1209, Train Accuracy: 43.53%
# Epoch 44: Test Loss: 2.1101, Test Accuracy: 44.68%
# Total Computation Time: 1161.61 seconds
# Total Communication Time: 0.52 seconds
# Epoch 45, Iteration 1: H_t = 54, G_t = 1.5969, σ_t^2 = 44.2048
# Epoch 45, Iteration 2: H_t = 4, G_t = -0.0826, σ_t^2 = 46.1286
# Epoch 45, Iteration 3: H_t = 64, G_t = 1.6748, σ_t^2 = 35.2619
# Epoch 45, Iteration 4: H_t = 4, G_t = -0.5059, σ_t^2 = 45.1699
# Epoch 45, Iteration 5: H_t = 11, G_t = 0.2953, σ_t^2 = 40.0736
# Epoch 45, Iteration 6: H_t = 4, G_t = -0.5577, σ_t^2 = 49.2653
# Epoch 45, Iteration 7: H_t = 33, G_t = 1.0293, σ_t^2 = 46.0494
# Epoch 45, Iteration 8: H_t = 15, G_t = 0.5439, σ_t^2 = 52.9647
#     Worker 0: Train Loss: 2.0933, Train Accuracy: 44.08%
#     Worker 1: Train Loss: 2.0953, Train Accuracy: 43.90%
#     Worker 2: Train Loss: 2.0842, Train Accuracy: 45.11%
#     Worker 3: Train Loss: 2.0911, Train Accuracy: 44.69%
# Epoch 45: Test Loss: 2.1167, Test Accuracy: 44.55%
# Total Computation Time: 1185.13 seconds
# Total Communication Time: 0.53 seconds
# Epoch 46, Iteration 1: H_t = 45, G_t = 1.5303, σ_t^2 = 50.7456
# Epoch 46, Iteration 2: H_t = 24, G_t = 0.6837, σ_t^2 = 41.5478
# Epoch 46, Iteration 3: H_t = 64, G_t = 3.8347, σ_t^2 = 42.2407
# Epoch 46, Iteration 4: H_t = 28, G_t = 0.8183, σ_t^2 = 42.6548
# Epoch 46, Iteration 5: H_t = 48, G_t = 1.2042, σ_t^2 = 37.3680
# Epoch 46, Iteration 6: H_t = 4, G_t = -0.3896, σ_t^2 = 43.9299
#     Worker 0: Train Loss: 2.0845, Train Accuracy: 44.48%
#     Worker 1: Train Loss: 2.0932, Train Accuracy: 44.29%
#     Worker 2: Train Loss: 2.0891, Train Accuracy: 44.73%
#     Worker 3: Train Loss: 2.0925, Train Accuracy: 44.34%
# Epoch 46: Test Loss: 2.0933, Test Accuracy: 45.47%
# Total Computation Time: 1211.73 seconds
# Total Communication Time: 0.54 seconds
# Epoch 47, Iteration 1: H_t = 4, G_t = -1.0133, σ_t^2 = 46.2622
# Epoch 47, Iteration 2: H_t = 4, G_t = -0.1944, σ_t^2 = 41.7852
# Epoch 47, Iteration 3: H_t = 37, G_t = 1.1539, σ_t^2 = 45.5690
# Epoch 47, Iteration 4: H_t = 10, G_t = 0.3584, σ_t^2 = 51.9617
# Epoch 47, Iteration 5: H_t = 4, G_t = -1.2704, σ_t^2 = 55.1662
# Epoch 47, Iteration 6: H_t = 33, G_t = 1.1281, σ_t^2 = 51.2209
# Epoch 47, Iteration 7: H_t = 6, G_t = 0.2654, σ_t^2 = 57.0724
# Epoch 47, Iteration 8: H_t = 4, G_t = -2.0720, σ_t^2 = 50.4552
# Epoch 47, Iteration 9: H_t = 39, G_t = 1.0517, σ_t^2 = 40.3569
# Epoch 47, Iteration 10: H_t = 4, G_t = -1.5116, σ_t^2 = 53.2802
# Epoch 47, Iteration 11: H_t = 64, G_t = 2.7546, σ_t^2 = 43.9217
# Epoch 47, Iteration 12: H_t = 44, G_t = 1.6313, σ_t^2 = 54.5038
#     Worker 0: Train Loss: 2.0501, Train Accuracy: 45.08%
#     Worker 1: Train Loss: 2.0518, Train Accuracy: 45.15%
#     Worker 2: Train Loss: 2.0594, Train Accuracy: 44.94%
#     Worker 3: Train Loss: 2.0697, Train Accuracy: 44.68%
# Epoch 47: Test Loss: 2.0993, Test Accuracy: 45.12%
# Total Computation Time: 1237.14 seconds
# Total Communication Time: 0.55 seconds
# Epoch 48, Iteration 1: H_t = 4, G_t = -2.0818, σ_t^2 = 50.6970
# Epoch 48, Iteration 2: H_t = 4, G_t = -0.1641, σ_t^2 = 42.2432
# Epoch 48, Iteration 3: H_t = 4, G_t = -0.1257, σ_t^2 = 49.2893
# Epoch 48, Iteration 4: H_t = 4, G_t = -1.9053, σ_t^2 = 47.1623
# Epoch 48, Iteration 5: H_t = 64, G_t = 2.7917, σ_t^2 = 40.0181
# Epoch 48, Iteration 6: H_t = 62, G_t = 1.7955, σ_t^2 = 43.0705
# Epoch 48, Iteration 7: H_t = 4, G_t = -0.4150, σ_t^2 = 50.8581
# Epoch 48, Iteration 8: H_t = 24, G_t = 0.7507, σ_t^2 = 46.6590
# Epoch 48, Iteration 9: H_t = 4, G_t = -0.3293, σ_t^2 = 49.0137
#     Worker 0: Train Loss: 2.0572, Train Accuracy: 44.93%
#     Worker 1: Train Loss: 2.0608, Train Accuracy: 45.26%
#     Worker 2: Train Loss: 2.0382, Train Accuracy: 45.66%
#     Worker 3: Train Loss: 2.0619, Train Accuracy: 44.57%
# Epoch 48: Test Loss: 2.0872, Test Accuracy: 45.07%
# Total Computation Time: 1262.81 seconds
# Total Communication Time: 0.56 seconds
# Epoch 49, Iteration 1: H_t = 4, G_t = -1.2590, σ_t^2 = 44.9659
# Epoch 49, Iteration 2: H_t = 64, G_t = 2.9230, σ_t^2 = 45.4544
# Epoch 49, Iteration 3: H_t = 34, G_t = 0.9565, σ_t^2 = 41.1291
# Epoch 49, Iteration 4: H_t = 4, G_t = -1.0492, σ_t^2 = 48.2005
# Epoch 49, Iteration 5: H_t = 37, G_t = 1.1564, σ_t^2 = 46.4348
# Epoch 49, Iteration 6: H_t = 4, G_t = -0.4500, σ_t^2 = 46.4281
# Epoch 49, Iteration 7: H_t = 4, G_t = -2.6139, σ_t^2 = 47.3811
# Epoch 49, Iteration 8: H_t = 38, G_t = 1.1512, σ_t^2 = 44.4506
# Epoch 49, Iteration 9: H_t = 43, G_t = 1.4195, σ_t^2 = 48.8630
# Epoch 49, Iteration 10: H_t = 4, G_t = 0.0843, σ_t^2 = 45.8169
#     Worker 0: Train Loss: 2.0237, Train Accuracy: 45.64%
#     Worker 1: Train Loss: 2.0269, Train Accuracy: 45.66%
#     Worker 2: Train Loss: 2.0171, Train Accuracy: 46.30%
#     Worker 3: Train Loss: 2.0214, Train Accuracy: 45.74%
# Epoch 49: Test Loss: 2.0744, Test Accuracy: 44.92%
# Total Computation Time: 1290.98 seconds
# Total Communication Time: 0.57 seconds
# Epoch 50, Iteration 1: H_t = 22, G_t = 0.6285, σ_t^2 = 41.8176
# Epoch 50, Iteration 2: H_t = 4, G_t = -2.2779, σ_t^2 = 53.2842
# Epoch 50, Iteration 3: H_t = 4, G_t = -0.6761, σ_t^2 = 51.2445
# Epoch 50, Iteration 4: H_t = 4, G_t = -0.8125, σ_t^2 = 42.5811
# Epoch 50, Iteration 5: H_t = 31, G_t = 0.9272, σ_t^2 = 43.9666
# Epoch 50, Iteration 6: H_t = 48, G_t = 1.6069, σ_t^2 = 49.4222
# Epoch 50, Iteration 7: H_t = 4, G_t = -2.7047, σ_t^2 = 60.1252
# Epoch 50, Iteration 8: H_t = 4, G_t = -1.3555, σ_t^2 = 49.6167
# Epoch 50, Iteration 9: H_t = 64, G_t = 2.7678, σ_t^2 = 43.1583
# Epoch 50, Iteration 10: H_t = 4, G_t = -1.1730, σ_t^2 = 50.8463
# Epoch 50, Iteration 11: H_t = 24, G_t = 0.7031, σ_t^2 = 43.5717
# Epoch 50, Iteration 12: H_t = 17, G_t = 0.5216, σ_t^2 = 45.3360
#     Worker 0: Train Loss: 1.9887, Train Accuracy: 46.21%
#     Worker 1: Train Loss: 2.0112, Train Accuracy: 45.59%
#     Worker 2: Train Loss: 1.9877, Train Accuracy: 46.51%
#     Worker 3: Train Loss: 2.0199, Train Accuracy: 45.59%
# Epoch 50: Test Loss: 2.0725, Test Accuracy: 45.52%
# Total Computation Time: 1316.96 seconds
# Total Communication Time: 0.59 seconds
# Epoch 51, Iteration 1: H_t = 43, G_t = 1.5648, σ_t^2 = 53.3476
# Epoch 51, Iteration 2: H_t = 4, G_t = -0.5940, σ_t^2 = 49.5458
# Epoch 51, Iteration 3: H_t = 4, G_t = -0.0893, σ_t^2 = 44.2659
# Epoch 51, Iteration 4: H_t = 4, G_t = -0.1949, σ_t^2 = 47.2535
# Epoch 51, Iteration 5: H_t = 64, G_t = 3.1328, σ_t^2 = 50.9993
# Epoch 51, Iteration 6: H_t = 4, G_t = -1.9322, σ_t^2 = 51.3169
# Epoch 51, Iteration 7: H_t = 4, G_t = -0.6095, σ_t^2 = 44.8403
# Epoch 51, Iteration 8: H_t = 19, G_t = 0.5858, σ_t^2 = 45.5339
# Epoch 51, Iteration 9: H_t = 64, G_t = 3.7967, σ_t^2 = 61.3881
# Epoch 51, Iteration 10: H_t = 4, G_t = -1.8148, σ_t^2 = 51.8086
#     Worker 0: Train Loss: 1.9748, Train Accuracy: 46.29%
#     Worker 1: Train Loss: 1.9999, Train Accuracy: 46.67%
#     Worker 2: Train Loss: 1.9813, Train Accuracy: 47.16%
#     Worker 3: Train Loss: 2.0095, Train Accuracy: 45.77%
# Epoch 51: Test Loss: 2.0515, Test Accuracy: 46.12%
# Total Computation Time: 1344.57 seconds
# Total Communication Time: 0.60 seconds
# ...
#     Worker 1: Train Loss: 1.2293, Train Accuracy: 65.33%
#     Worker 2: Train Loss: 1.2211, Train Accuracy: 65.66%
#     Worker 3: Train Loss: 1.2325, Train Accuracy: 64.76%
# Epoch 140: Test Loss: 1.9578, Test Accuracy: 51.00%
# Total Computation Time: 3592.66 seconds
# Total Communication Time: 2.02 seconds
# Epoch 141, Iteration 1: H_t = 4, G_t = -0.4304, σ_t^2 = 99.6888
# Epoch 141, Iteration 2: H_t = 34, G_t = 2.2427, σ_t^2 = 97.2411
# Epoch 141, Iteration 3: H_t = 4, G_t = -1.0222, σ_t^2 = 101.8257
# Epoch 141, Iteration 4: H_t = 4, G_t = -1.4230, σ_t^2 = 97.6230
# Epoch 141, Iteration 5: H_t = 4, G_t = -2.6075, σ_t^2 = 95.4834
# Epoch 141, Iteration 6: H_t = 7, G_t = 0.5246, σ_t^2 = 98.9736
# Epoch 141, Iteration 7: H_t = 4, G_t = -0.2871, σ_t^2 = 88.8781
# Epoch 141, Iteration 8: H_t = 4, G_t = -0.0796, σ_t^2 = 94.8239
# Epoch 141, Iteration 9: H_t = 4, G_t = -3.1736, σ_t^2 = 108.0400
# Epoch 141, Iteration 10: H_t = 4, G_t = -0.2498, σ_t^2 = 101.9943
# Epoch 141, Iteration 11: H_t = 9, G_t = 0.5884, σ_t^2 = 90.6487
# Epoch 141, Iteration 12: H_t = 4, G_t = -1.0532, σ_t^2 = 99.7470
# Epoch 141, Iteration 13: H_t = 12, G_t = 0.7512, σ_t^2 = 90.3026
# Epoch 141, Iteration 14: H_t = 10, G_t = 0.5689, σ_t^2 = 77.7454
# Epoch 141, Iteration 15: H_t = 4, G_t = -0.6633, σ_t^2 = 102.6805
# Epoch 141, Iteration 16: H_t = 4, G_t = -1.2838, σ_t^2 = 82.0285
# Epoch 141, Iteration 17: H_t = 52, G_t = 3.6443, σ_t^2 = 104.6420
# Epoch 141, Iteration 18: H_t = 4, G_t = 0.2310, σ_t^2 = 79.9862
# Epoch 141, Iteration 19: H_t = 4, G_t = -2.8877, σ_t^2 = 97.3524
# Epoch 141, Iteration 20: H_t = 45, G_t = 2.9611, σ_t^2 = 98.4357
# Epoch 141, Iteration 21: H_t = 4, G_t = -1.2675, σ_t^2 = 107.0309
#     Worker 0: Train Loss: 1.2178, Train Accuracy: 65.46%
#     Worker 1: Train Loss: 1.2282, Train Accuracy: 65.65%
#     Worker 2: Train Loss: 1.2184, Train Accuracy: 65.89%
#     Worker 3: Train Loss: 1.2275, Train Accuracy: 65.10%
# Epoch 141: Test Loss: 1.9575, Test Accuracy: 50.95%
# Total Computation Time: 3619.09 seconds
# Total Communication Time: 2.05 seconds
# Epoch 142, Iteration 1: H_t = 4, G_t = -0.0412, σ_t^2 = 85.1676
# Epoch 142, Iteration 2: H_t = 4, G_t = -0.3599, σ_t^2 = 93.4347
# Epoch 142, Iteration 3: H_t = 9, G_t = 0.5638, σ_t^2 = 88.4079
# Epoch 142, Iteration 4: H_t = 4, G_t = -2.4240, σ_t^2 = 106.5967
# Epoch 142, Iteration 5: H_t = 4, G_t = -1.3820, σ_t^2 = 101.3405
# Epoch 142, Iteration 6: H_t = 4, G_t = -0.3727, σ_t^2 = 86.2604
# Epoch 142, Iteration 7: H_t = 19, G_t = 1.1921, σ_t^2 = 91.7139
# Epoch 142, Iteration 8: H_t = 10, G_t = 0.6383, σ_t^2 = 88.7872
# Epoch 142, Iteration 9: H_t = 4, G_t = 0.0253, σ_t^2 = 102.4804
# Epoch 142, Iteration 10: H_t = 15, G_t = 0.9706, σ_t^2 = 93.4359
# Epoch 142, Iteration 11: H_t = 4, G_t = -3.1423, σ_t^2 = 107.0669
# Epoch 142, Iteration 12: H_t = 30, G_t = 1.8492, σ_t^2 = 91.5703
# Epoch 142, Iteration 13: H_t = 18, G_t = 1.2083, σ_t^2 = 98.7792
# Epoch 142, Iteration 14: H_t = 4, G_t = -1.2210, σ_t^2 = 84.3955
# Epoch 142, Iteration 15: H_t = 10, G_t = 0.5606, σ_t^2 = 78.8117
# Epoch 142, Iteration 16: H_t = 4, G_t = 0.1969, σ_t^2 = 103.6799
# Epoch 142, Iteration 17: H_t = 4, G_t = -1.8273, σ_t^2 = 95.7304
# Epoch 142, Iteration 18: H_t = 4, G_t = -0.6550, σ_t^2 = 98.9705
# Epoch 142, Iteration 19: H_t = 5, G_t = 0.3475, σ_t^2 = 89.6945
# Epoch 142, Iteration 20: H_t = 4, G_t = -1.8808, σ_t^2 = 97.9074
# Epoch 142, Iteration 21: H_t = 4, G_t = -1.6330, σ_t^2 = 109.3070
# Epoch 142, Iteration 22: H_t = 13, G_t = 0.8360, σ_t^2 = 92.6067
# Epoch 142, Iteration 23: H_t = 15, G_t = 1.2026, σ_t^2 = 115.5729
# Epoch 142, Iteration 24: H_t = 4, G_t = -1.8968, σ_t^2 = 103.7645
#     Worker 0: Train Loss: 1.2242, Train Accuracy: 65.29%
#     Worker 1: Train Loss: 1.2254, Train Accuracy: 65.51%
#     Worker 2: Train Loss: 1.1911, Train Accuracy: 66.94%
#     Worker 3: Train Loss: 1.2277, Train Accuracy: 65.29%
# Epoch 142: Test Loss: 1.9568, Test Accuracy: 51.01%
# Total Computation Time: 3642.77 seconds
# Total Communication Time: 2.08 seconds
# Epoch 143, Iteration 1: H_t = 15, G_t = 1.0004, σ_t^2 = 94.8661
# Epoch 143, Iteration 2: H_t = 39, G_t = 2.4895, σ_t^2 = 94.2990
# Epoch 143, Iteration 3: H_t = 4, G_t = -0.8819, σ_t^2 = 90.7369
# Epoch 143, Iteration 4: H_t = 4, G_t = -0.2747, σ_t^2 = 100.2814
# Epoch 143, Iteration 5: H_t = 24, G_t = 1.5541, σ_t^2 = 94.6207
# Epoch 143, Iteration 6: H_t = 4, G_t = -0.2885, σ_t^2 = 104.3484
# Epoch 143, Iteration 7: H_t = 4, G_t = -0.5645, σ_t^2 = 95.4065
# Epoch 143, Iteration 8: H_t = 6, G_t = 0.5072, σ_t^2 = 110.0800
# Epoch 143, Iteration 9: H_t = 4, G_t = -0.0076, σ_t^2 = 101.8678
# Epoch 143, Iteration 10: H_t = 4, G_t = -0.0414, σ_t^2 = 101.1226
# Epoch 143, Iteration 11: H_t = 4, G_t = -0.8392, σ_t^2 = 95.4720
# Epoch 143, Iteration 12: H_t = 10, G_t = 0.5737, σ_t^2 = 85.8079
# Epoch 143, Iteration 13: H_t = 4, G_t = 0.2296, σ_t^2 = 95.9902
# Epoch 143, Iteration 14: H_t = 5, G_t = 0.3243, σ_t^2 = 93.0232
# Epoch 143, Iteration 15: H_t = 28, G_t = 1.6342, σ_t^2 = 86.8167
# Epoch 143, Iteration 16: H_t = 22, G_t = 1.5925, σ_t^2 = 104.0148
# Epoch 143, Iteration 17: H_t = 4, G_t = -0.4725, σ_t^2 = 87.6803
# Epoch 143, Iteration 18: H_t = 4, G_t = 0.0728, σ_t^2 = 114.0138
# Epoch 143, Iteration 19: H_t = 4, G_t = -3.1783, σ_t^2 = 99.2263
# Epoch 143, Iteration 20: H_t = 4, G_t = -2.2589, σ_t^2 = 107.4529
#     Worker 0: Train Loss: 1.2159, Train Accuracy: 65.03%
#     Worker 1: Train Loss: 1.2145, Train Accuracy: 65.94%
#     Worker 2: Train Loss: 1.2186, Train Accuracy: 65.95%
#     Worker 3: Train Loss: 1.2319, Train Accuracy: 65.31%
# Epoch 143: Test Loss: 1.9573, Test Accuracy: 51.01%
# Total Computation Time: 3666.06 seconds
# Total Communication Time: 2.10 seconds
# Epoch 144, Iteration 1: H_t = 64, G_t = 5.4012, σ_t^2 = 76.6063
# Epoch 144, Iteration 2: H_t = 4, G_t = -3.1553, σ_t^2 = 115.2948
# Epoch 144, Iteration 3: H_t = 6, G_t = 0.4479, σ_t^2 = 100.3246
# Epoch 144, Iteration 4: H_t = 33, G_t = 2.2218, σ_t^2 = 100.6377
# Epoch 144, Iteration 5: H_t = 4, G_t = -0.5737, σ_t^2 = 104.7670
# Epoch 144, Iteration 6: H_t = 15, G_t = 1.1520, σ_t^2 = 114.0886
# Epoch 144, Iteration 7: H_t = 28, G_t = 1.8170, σ_t^2 = 96.8282
# Epoch 144, Iteration 8: H_t = 12, G_t = 0.7567, σ_t^2 = 92.8433
# Epoch 144, Iteration 9: H_t = 4, G_t = -1.6437, σ_t^2 = 94.7895
# Epoch 144, Iteration 10: H_t = 4, G_t = -1.3722, σ_t^2 = 104.1564
# Epoch 144, Iteration 11: H_t = 43, G_t = 2.8510, σ_t^2 = 98.6560
# Epoch 144, Iteration 12: H_t = 18, G_t = 1.2616, σ_t^2 = 103.8655
#     Worker 0: Train Loss: 1.2166, Train Accuracy: 65.25%
#     Worker 1: Train Loss: 1.2208, Train Accuracy: 65.90%
#     Worker 2: Train Loss: 1.2053, Train Accuracy: 65.91%
#     Worker 3: Train Loss: 1.2127, Train Accuracy: 65.54%
# Epoch 144: Test Loss: 1.9570, Test Accuracy: 51.01%
# Total Computation Time: 3691.97 seconds
# Total Communication Time: 2.12 seconds
# Epoch 145, Iteration 1: H_t = 4, G_t = -1.3521, σ_t^2 = 107.5716
# Epoch 145, Iteration 2: H_t = 39, G_t = 2.1503, σ_t^2 = 82.1095
# Epoch 145, Iteration 3: H_t = 4, G_t = 0.0454, σ_t^2 = 105.0433
# Epoch 145, Iteration 4: H_t = 7, G_t = 0.4534, σ_t^2 = 94.7014
# Epoch 145, Iteration 5: H_t = 62, G_t = 3.5274, σ_t^2 = 85.2334
# Epoch 145, Iteration 6: H_t = 4, G_t = 0.1251, σ_t^2 = 100.5328
# Epoch 145, Iteration 7: H_t = 62, G_t = 4.0495, σ_t^2 = 97.7303
# Epoch 145, Iteration 8: H_t = 4, G_t = -3.4473, σ_t^2 = 105.0446
#     Worker 0: Train Loss: 1.2178, Train Accuracy: 65.53%
#     Worker 1: Train Loss: 1.2105, Train Accuracy: 65.80%
#     Worker 2: Train Loss: 1.2077, Train Accuracy: 66.24%
#     Worker 3: Train Loss: 1.2344, Train Accuracy: 65.24%
# Epoch 145: Test Loss: 1.9575, Test Accuracy: 51.06%
# Total Computation Time: 3715.52 seconds
# Total Communication Time: 2.13 seconds
# Epoch 146, Iteration 1: H_t = 4, G_t = -1.9053, σ_t^2 = 98.9715
# Epoch 146, Iteration 2: H_t = 4, G_t = 0.1869, σ_t^2 = 87.2722
# Epoch 146, Iteration 3: H_t = 4, G_t = 0.1097, σ_t^2 = 87.7769
# Epoch 146, Iteration 4: H_t = 16, G_t = 1.2118, σ_t^2 = 110.5601
# Epoch 146, Iteration 5: H_t = 4, G_t = -1.0201, σ_t^2 = 91.4117
# Epoch 146, Iteration 6: H_t = 4, G_t = -1.2331, σ_t^2 = 95.7427
# Epoch 146, Iteration 7: H_t = 4, G_t = -3.8375, σ_t^2 = 116.5749
# Epoch 146, Iteration 8: H_t = 4, G_t = -0.9942, σ_t^2 = 107.5571
# Epoch 146, Iteration 9: H_t = 13, G_t = 0.7734, σ_t^2 = 86.6860
# Epoch 146, Iteration 10: H_t = 4, G_t = -3.3640, σ_t^2 = 100.6009
# Epoch 146, Iteration 11: H_t = 4, G_t = -1.0172, σ_t^2 = 86.6357
# Epoch 146, Iteration 12: H_t = 4, G_t = -2.7374, σ_t^2 = 99.5386
# Epoch 146, Iteration 13: H_t = 4, G_t = -0.5626, σ_t^2 = 108.2821
# Epoch 146, Iteration 14: H_t = 4, G_t = -0.6513, σ_t^2 = 102.7145
# Epoch 146, Iteration 15: H_t = 4, G_t = -0.1766, σ_t^2 = 116.1396
# Epoch 146, Iteration 16: H_t = 4, G_t = -0.5354, σ_t^2 = 96.5039
# Epoch 146, Iteration 17: H_t = 9, G_t = 0.5348, σ_t^2 = 86.2873
# Epoch 146, Iteration 18: H_t = 4, G_t = -2.6308, σ_t^2 = 93.2522
# Epoch 146, Iteration 19: H_t = 4, G_t = -1.7559, σ_t^2 = 110.6261
# Epoch 146, Iteration 20: H_t = 4, G_t = -0.5509, σ_t^2 = 80.8120
# Epoch 146, Iteration 21: H_t = 4, G_t = -2.2238, σ_t^2 = 98.1286
# Epoch 146, Iteration 22: H_t = 4, G_t = -0.0928, σ_t^2 = 115.8664
# Epoch 146, Iteration 23: H_t = 46, G_t = 2.8164, σ_t^2 = 90.8312
# Epoch 146, Iteration 24: H_t = 22, G_t = 1.5391, σ_t^2 = 102.2162
# Epoch 146, Iteration 25: H_t = 52, G_t = 3.2175, σ_t^2 = 92.7902
# Epoch 146, Iteration 26: H_t = 4, G_t = -0.3523, σ_t^2 = 89.1222
#     Worker 0: Train Loss: 1.2265, Train Accuracy: 64.89%
#     Worker 1: Train Loss: 1.2323, Train Accuracy: 65.57%
#     Worker 2: Train Loss: 1.2048, Train Accuracy: 65.76%
#     Worker 3: Train Loss: 1.2242, Train Accuracy: 65.29%
# Epoch 146: Test Loss: 1.9580, Test Accuracy: 51.04%
# Total Computation Time: 3743.93 seconds
# Total Communication Time: 2.16 seconds
# Epoch 147, Iteration 1: H_t = 4, G_t = 0.2469, σ_t^2 = 104.0745
# Epoch 147, Iteration 2: H_t = 4, G_t = -2.5103, σ_t^2 = 99.2339
# Epoch 147, Iteration 3: H_t = 4, G_t = -2.4880, σ_t^2 = 102.6413
# Epoch 147, Iteration 4: H_t = 4, G_t = 0.2815, σ_t^2 = 103.7294
# Epoch 147, Iteration 5: H_t = 4, G_t = -0.7596, σ_t^2 = 101.8684
# Epoch 147, Iteration 6: H_t = 4, G_t = -0.2082, σ_t^2 = 92.1052
# Epoch 147, Iteration 7: H_t = 4, G_t = -0.6182, σ_t^2 = 96.5484
# Epoch 147, Iteration 8: H_t = 4, G_t = -3.7119, σ_t^2 = 111.1025
# Epoch 147, Iteration 9: H_t = 4, G_t = -1.2408, σ_t^2 = 97.9411
# Epoch 147, Iteration 10: H_t = 4, G_t = -0.4707, σ_t^2 = 101.2221
# Epoch 147, Iteration 11: H_t = 11, G_t = 0.7214, σ_t^2 = 93.2973
# Epoch 147, Iteration 12: H_t = 4, G_t = -1.6806, σ_t^2 = 85.9600
# Epoch 147, Iteration 13: H_t = 4, G_t = -0.1712, σ_t^2 = 97.5138
# Epoch 147, Iteration 14: H_t = 14, G_t = 0.8276, σ_t^2 = 84.1998
# Epoch 147, Iteration 15: H_t = 4, G_t = -1.0866, σ_t^2 = 104.1342
# Epoch 147, Iteration 16: H_t = 4, G_t = -1.5987, σ_t^2 = 101.8429
# Epoch 147, Iteration 17: H_t = 4, G_t = -1.5542, σ_t^2 = 97.5274
# Epoch 147, Iteration 18: H_t = 4, G_t = -1.4995, σ_t^2 = 104.4506
# Epoch 147, Iteration 19: H_t = 4, G_t = -0.5364, σ_t^2 = 79.1651
# Epoch 147, Iteration 20: H_t = 38, G_t = 2.1215, σ_t^2 = 82.6735
# Epoch 147, Iteration 21: H_t = 4, G_t = 0.2879, σ_t^2 = 96.7142
# Epoch 147, Iteration 22: H_t = 63, G_t = 3.6817, σ_t^2 = 86.8223
# Epoch 147, Iteration 23: H_t = 4, G_t = -1.3987, σ_t^2 = 93.0514
#     Worker 0: Train Loss: 1.2114, Train Accuracy: 65.46%
#     Worker 1: Train Loss: 1.2110, Train Accuracy: 65.87%
#     Worker 2: Train Loss: 1.2092, Train Accuracy: 65.86%
#     Worker 3: Train Loss: 1.2343, Train Accuracy: 64.96%
# Epoch 147: Test Loss: 1.9579, Test Accuracy: 51.06%
# Total Computation Time: 3767.63 seconds
# Total Communication Time: 2.18 seconds
# Epoch 148, Iteration 1: H_t = 25, G_t = 1.4601, σ_t^2 = 87.1708
# Epoch 148, Iteration 2: H_t = 4, G_t = -3.3444, σ_t^2 = 84.8878
# Epoch 148, Iteration 3: H_t = 4, G_t = -0.6895, σ_t^2 = 89.6950
# Epoch 148, Iteration 4: H_t = 4, G_t = -0.3857, σ_t^2 = 102.4971
# Epoch 148, Iteration 5: H_t = 4, G_t = -1.4613, σ_t^2 = 111.1670
# Epoch 148, Iteration 6: H_t = 4, G_t = 0.0876, σ_t^2 = 94.3405
# Epoch 148, Iteration 7: H_t = 14, G_t = 0.8666, σ_t^2 = 87.7772
# Epoch 148, Iteration 8: H_t = 4, G_t = -0.5716, σ_t^2 = 89.6267
# Epoch 148, Iteration 9: H_t = 4, G_t = -0.5155, σ_t^2 = 101.1912
# Epoch 148, Iteration 10: H_t = 4, G_t = -0.8552, σ_t^2 = 90.1019
# Epoch 148, Iteration 11: H_t = 4, G_t = 0.0812, σ_t^2 = 106.1748
# Epoch 148, Iteration 12: H_t = 4, G_t = -0.8191, σ_t^2 = 102.0157
# Epoch 148, Iteration 13: H_t = 4, G_t = -1.9677, σ_t^2 = 84.2702
# Epoch 148, Iteration 14: H_t = 4, G_t = -1.2443, σ_t^2 = 93.7734
# Epoch 148, Iteration 15: H_t = 4, G_t = 0.1670, σ_t^2 = 101.7169
# Epoch 148, Iteration 16: H_t = 41, G_t = 2.5667, σ_t^2 = 92.7094
# Epoch 148, Iteration 17: H_t = 4, G_t = -1.6760, σ_t^2 = 110.7555
# Epoch 148, Iteration 18: H_t = 22, G_t = 1.2975, σ_t^2 = 85.1720
# Epoch 148, Iteration 19: H_t = 4, G_t = -2.0400, σ_t^2 = 97.2595
# Epoch 148, Iteration 20: H_t = 15, G_t = 0.9887, σ_t^2 = 92.9457
# Epoch 148, Iteration 21: H_t = 4, G_t = -2.8125, σ_t^2 = 108.2938
# Epoch 148, Iteration 22: H_t = 31, G_t = 1.7463, σ_t^2 = 83.5855
# Epoch 148, Iteration 23: H_t = 22, G_t = 1.4653, σ_t^2 = 96.5659
#     Worker 0: Train Loss: 1.2439, Train Accuracy: 65.00%
#     Worker 1: Train Loss: 1.2110, Train Accuracy: 65.81%
#     Worker 2: Train Loss: 1.2031, Train Accuracy: 66.08%
#     Worker 3: Train Loss: 1.2162, Train Accuracy: 65.49%
# Epoch 148: Test Loss: 1.9577, Test Accuracy: 51.08%
# Total Computation Time: 3792.90 seconds
# Total Communication Time: 2.21 seconds
# Epoch 149, Iteration 1: H_t = 4, G_t = -0.8333, σ_t^2 = 106.2341
# Epoch 149, Iteration 2: H_t = 11, G_t = 0.6665, σ_t^2 = 90.3056
# Epoch 149, Iteration 3: H_t = 29, G_t = 1.5028, σ_t^2 = 76.3609
# Epoch 149, Iteration 4: H_t = 27, G_t = 1.6663, σ_t^2 = 91.9561
# Epoch 149, Iteration 5: H_t = 38, G_t = 2.1303, σ_t^2 = 83.0063
# Epoch 149, Iteration 6: H_t = 4, G_t = -2.4459, σ_t^2 = 93.0976
# Epoch 149, Iteration 7: H_t = 4, G_t = -0.7564, σ_t^2 = 86.3904
# Epoch 149, Iteration 8: H_t = 64, G_t = 6.9667, σ_t^2 = 86.6560
# Epoch 149, Iteration 9: H_t = 4, G_t = 0.0507, σ_t^2 = 94.6180
#     Worker 0: Train Loss: 1.1917, Train Accuracy: 66.54%
#     Worker 1: Train Loss: 1.2210, Train Accuracy: 65.63%
#     Worker 2: Train Loss: 1.2352, Train Accuracy: 65.27%
#     Worker 3: Train Loss: 1.2261, Train Accuracy: 65.11%
# Epoch 149: Test Loss: 1.9577, Test Accuracy: 51.05%
# Total Computation Time: 3816.45 seconds
# Total Communication Time: 2.22 seconds
# Epoch 150, Iteration 1: H_t = 4, G_t = -0.9562, σ_t^2 = 85.7878
# Epoch 150, Iteration 2: H_t = 4, G_t = -0.0514, σ_t^2 = 102.4779
# Epoch 150, Iteration 3: H_t = 27, G_t = 1.6388, σ_t^2 = 88.9467
# Epoch 150, Iteration 4: H_t = 16, G_t = 1.0091, σ_t^2 = 93.3087
# Epoch 150, Iteration 5: H_t = 4, G_t = -0.9284, σ_t^2 = 118.2739
# Epoch 150, Iteration 6: H_t = 4, G_t = -0.5258, σ_t^2 = 87.0253
# Epoch 150, Iteration 7: H_t = 26, G_t = 1.7500, σ_t^2 = 97.8665
# Epoch 150, Iteration 8: H_t = 7, G_t = 0.4205, σ_t^2 = 88.5364
# Epoch 150, Iteration 9: H_t = 19, G_t = 1.2032, σ_t^2 = 92.5890
# Epoch 150, Iteration 10: H_t = 4, G_t = -3.2218, σ_t^2 = 118.0603
# Epoch 150, Iteration 11: H_t = 4, G_t = -3.5876, σ_t^2 = 94.9432
# Epoch 150, Iteration 12: H_t = 8, G_t = 0.5395, σ_t^2 = 100.5725
# Epoch 150, Iteration 13: H_t = 4, G_t = -0.0203, σ_t^2 = 97.8106
# Epoch 150, Iteration 14: H_t = 4, G_t = -1.6312, σ_t^2 = 90.8949
# Epoch 150, Iteration 15: H_t = 11, G_t = 0.8104, σ_t^2 = 107.3335
# Epoch 150, Iteration 16: H_t = 4, G_t = -0.2312, σ_t^2 = 103.5000
# Epoch 150, Iteration 17: H_t = 13, G_t = 0.8560, σ_t^2 = 93.1001
# Epoch 150, Iteration 18: H_t = 9, G_t = 0.5905, σ_t^2 = 95.1007
# Epoch 150, Iteration 19: H_t = 4, G_t = -0.3320, σ_t^2 = 88.2970
# Epoch 150, Iteration 20: H_t = 50, G_t = 3.1734, σ_t^2 = 93.5986
# Epoch 150, Iteration 21: H_t = 4, G_t = -0.7278, σ_t^2 = 92.1534
#     Worker 0: Train Loss: 1.2247, Train Accuracy: 65.02%
#     Worker 1: Train Loss: 1.2275, Train Accuracy: 65.59%
#     Worker 2: Train Loss: 1.1992, Train Accuracy: 66.11%
#     Worker 3: Train Loss: 1.2279, Train Accuracy: 64.90%
# Epoch 150: Test Loss: 1.9577, Test Accuracy: 51.07%
# Total Computation Time: 3844.46 seconds
# Total Communication Time: 2.25 seconds
