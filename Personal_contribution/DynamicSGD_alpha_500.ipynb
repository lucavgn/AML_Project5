# %% [markdown]
# <a href="https://colab.research.google.com/github/lucavgn/AML_Project5/blob/main/Personal_contribution/DynamicSGD_alpha_500.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files
import torch.nn.functional as F
import time

total_computation_time = 0
total_communication_time = 0

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
iteration_per_epoch = 782 # number of local step performed in one epoch
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
#warmup_epochs = 5

def compute_mean_std(dataset):
    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

#global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
#global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
#print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Compute gradient magnitude and variance
def compute_gradient_stats(nets, optimizers):
    # Get gradients from each worker
    gradients = []
    for net, optimizer in zip(nets, optimizers):
        grad_vector = []
        for param in net.parameters():
            if param.grad is not None:
                grad_vector.append(param.grad.view(-1))
        grad_vector = torch.cat(grad_vector)  # Flatten all gradients into a vector
        gradients.append(grad_vector)

    # Compute average gradient (g_t)
    avg_gradient = torch.stack(gradients).mean(dim=0)

    # Compute squared norms of individual gradients
    squared_norms = [torch.norm(g).item() ** 2 for g in gradients]

    # Compute squared norm of the average gradient
    avg_squared_norm = torch.norm(avg_gradient).item() ** 2

    # Compute gradient variance (sigma_t^2) using the provided formula
    sigma_t_squared = (sum(squared_norms) / (K - 1)) - (K / (K - 1)) * avg_squared_norm

    # Compute gradient magnitude (G_t) using the provided formula
    G_t = avg_squared_norm - (1 / K) * sigma_t_squared

    return G_t, sigma_t_squared


# Update H dynamically based on gradient stats
def update_H(G_t, sigma_t_squared, H_min, H_max, alpha, epsilon):
    H_t = min(H_max, max(H_min, alpha * G_t / (sigma_t_squared + epsilon)))
    #H_t = min(H_t, H_max)  # Ensure H_t doesn't exceed H_max
    return int(H_t)  # Ensure H_t is an integer

# Training loop
# Hyperparameters for dynamic adjustment
H_min, H_max = 4, 64  # Minimum and maximum allowed local steps
alpha, epsilon = 500, 1e-6  # Scaling factor and small constant

H_t = J  # Initialize H_t with the default J value


for epoch in range(num_epochs):
    #print(f"Epoch {epoch + 1}/{num_epochs}:")
    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]

    iteration_per_epoch = 782
    iteration = 0 # Number of global iteration performed
    while iteration_per_epoch > 0:
        computation_start_time = time.time()
        # Train each worker for H_t steps
        for k in range(K):
            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            for _ in range(H_t):  # Perform H_t local steps
                try:
                    images, labels = next(shard_iterators[k])
                except StopIteration:
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k])
                images, labels = images.to(device), labels.to(device)

                optimizers[k].zero_grad()
                outputs = nets[k](images)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizers[k].step()

                # Calculate train loss and accuracy
                train_loss += loss.item() * labels.size(0)
                _, predicted = outputs.max(1)
                total_train += labels.size(0)
                correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        computation_end_time = time.time()
        total_computation_time += (computation_end_time - computation_start_time)

        communication_start_time = time.time()
        # Synchronize models
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

        communication_end_time = time.time()
        total_communication_time += (communication_end_time - communication_start_time)

        # update tot_num_local_step and number of global iteration
        iteration_per_epoch -= (H_t * K)
        iteration += 1
        # Compute gradient stats and update H_t
        G_t, sigma_t_squared = compute_gradient_stats(nets, optimizers)
        H_t = update_H(G_t, sigma_t_squared, H_min, H_max, alpha, epsilon)
        print(f"Epoch {epoch+1}, Iteration {iteration}: H_t = {H_t}, G_t = {G_t:.4f}, σ_t^2 = {sigma_t_squared:.4f}")

    # Store training metrics for all workers after each epoch
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

    # Update learning rate
    for scheduler in schedulers:
        scheduler.step()

    # Evaluate on test set
    global_model = nets[0]
    global_model.eval()
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()

    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)
    print(f"Epoch {epoch + 1}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")

    print(f"Total Computation Time: {total_computation_time:.2f} seconds")
    print(f"Total Communication Time: {total_communication_time:.2f} seconds")



# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Overwriting localSGD.py

# %%
# %run localSGD.py --k 4 --j 32
# Out:
# Training with K=4, J=32
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00400
# Epoch 1, Iteration 1: H_t = 28, G_t = 0.0073, σ_t^2 = 0.1257
# Epoch 1, Iteration 2: H_t = 4, G_t = -0.0010, σ_t^2 = 0.1208
# Epoch 1, Iteration 3: H_t = 6, G_t = 0.0015, σ_t^2 = 0.1136
# Epoch 1, Iteration 4: H_t = 17, G_t = 0.0047, σ_t^2 = 0.1333
# Epoch 1, Iteration 5: H_t = 25, G_t = 0.0064, σ_t^2 = 0.1225
# Epoch 1, Iteration 6: H_t = 4, G_t = -0.0051, σ_t^2 = 0.1425
# Epoch 1, Iteration 7: H_t = 23, G_t = 0.0065, σ_t^2 = 0.1391
# Epoch 1, Iteration 8: H_t = 4, G_t = 0.0002, σ_t^2 = 0.1876
# Epoch 1, Iteration 9: H_t = 15, G_t = 0.0062, σ_t^2 = 0.2053
# Epoch 1, Iteration 10: H_t = 14, G_t = 0.0065, σ_t^2 = 0.2300
# Epoch 1, Iteration 11: H_t = 11, G_t = 0.0061, σ_t^2 = 0.2759
# Epoch 1, Iteration 12: H_t = 18, G_t = 0.0118, σ_t^2 = 0.3220
# Epoch 1, Iteration 13: H_t = 43, G_t = 0.0314, σ_t^2 = 0.3591
#     Worker 0: Train Loss: 4.5991, Train Accuracy: 1.41%
#     Worker 1: Train Loss: 4.5998, Train Accuracy: 1.37%
#     Worker 2: Train Loss: 4.5982, Train Accuracy: 1.67%
#     Worker 3: Train Loss: 4.5990, Train Accuracy: 1.62%
# Epoch 1: Test Loss: 4.5809, Test Accuracy: 2.91%
# Total Computation Time: 23.86 seconds
# Total Communication Time: 0.01 seconds
# Epoch 2, Iteration 1: H_t = 8, G_t = 0.0143, σ_t^2 = 0.8002
# Epoch 2, Iteration 2: H_t = 6, G_t = 0.0114, σ_t^2 = 0.9473
# Epoch 2, Iteration 3: H_t = 26, G_t = 0.0504, σ_t^2 = 0.9624
# Epoch 2, Iteration 4: H_t = 42, G_t = 0.1369, σ_t^2 = 1.6132
# Epoch 2, Iteration 5: H_t = 41, G_t = 0.2284, σ_t^2 = 2.7495
# Epoch 2, Iteration 6: H_t = 14, G_t = 0.1659, σ_t^2 = 5.6945
# Epoch 2, Iteration 7: H_t = 4, G_t = -0.0103, σ_t^2 = 6.7765
# Epoch 2, Iteration 8: H_t = 4, G_t = -0.1358, σ_t^2 = 8.5107
# Epoch 2, Iteration 9: H_t = 6, G_t = 0.1122, σ_t^2 = 8.7486
# Epoch 2, Iteration 10: H_t = 4, G_t = -0.3968, σ_t^2 = 10.8100
# Epoch 2, Iteration 11: H_t = 8, G_t = 0.1685, σ_t^2 = 10.5293
#     Worker 0: Train Loss: 4.4697, Train Accuracy: 3.36%
#     Worker 1: Train Loss: 4.4716, Train Accuracy: 3.37%
#     Worker 2: Train Loss: 4.4600, Train Accuracy: 3.30%
#     Worker 3: Train Loss: 4.4702, Train Accuracy: 3.51%
# Epoch 2: Test Loss: 4.2209, Test Accuracy: 5.82%
# Total Computation Time: 47.49 seconds
# Total Communication Time: 0.03 seconds
# Epoch 3, Iteration 1: H_t = 14, G_t = 0.4118, σ_t^2 = 13.8570
# Epoch 3, Iteration 2: H_t = 28, G_t = 0.7563, σ_t^2 = 13.3396
# Epoch 3, Iteration 3: H_t = 4, G_t = -0.3314, σ_t^2 = 9.4127
# Epoch 3, Iteration 4: H_t = 41, G_t = 0.7608, σ_t^2 = 9.2216
# Epoch 3, Iteration 5: H_t = 4, G_t = 0.0528, σ_t^2 = 9.7142
# Epoch 3, Iteration 6: H_t = 21, G_t = 0.4369, σ_t^2 = 10.2877
# Epoch 3, Iteration 7: H_t = 4, G_t = -0.1291, σ_t^2 = 12.0756
# Epoch 3, Iteration 8: H_t = 4, G_t = 0.1042, σ_t^2 = 13.2375
# Epoch 3, Iteration 9: H_t = 64, G_t = 1.6409, σ_t^2 = 10.6652
# Epoch 3, Iteration 10: H_t = 11, G_t = 0.2262, σ_t^2 = 9.8527
# Epoch 3, Iteration 11: H_t = 4, G_t = -0.0927, σ_t^2 = 11.0009
#     Worker 0: Train Loss: 4.1555, Train Accuracy: 6.11%
#     Worker 1: Train Loss: 4.1596, Train Accuracy: 5.99%
#     Worker 2: Train Loss: 4.1321, Train Accuracy: 6.51%
#     Worker 3: Train Loss: 4.1623, Train Accuracy: 6.48%
# Epoch 3: Test Loss: 3.9825, Test Accuracy: 8.92%
# Total Computation Time: 71.71 seconds
# Total Communication Time: 0.04 seconds
# Epoch 4, Iteration 1: H_t = 4, G_t = -0.7793, σ_t^2 = 13.6729
# Epoch 4, Iteration 2: H_t = 11, G_t = 0.2942, σ_t^2 = 12.2640
# Epoch 4, Iteration 3: H_t = 4, G_t = -0.6084, σ_t^2 = 16.0320
# Epoch 4, Iteration 4: H_t = 4, G_t = -0.6384, σ_t^2 = 14.1387
# Epoch 4, Iteration 5: H_t = 9, G_t = 0.2403, σ_t^2 = 12.1068
# Epoch 4, Iteration 6: H_t = 4, G_t = -0.5390, σ_t^2 = 12.8855
# Epoch 4, Iteration 7: H_t = 46, G_t = 1.1608, σ_t^2 = 12.3834
# Epoch 4, Iteration 8: H_t = 7, G_t = 0.1639, σ_t^2 = 10.7816
# Epoch 4, Iteration 9: H_t = 4, G_t = -0.9838, σ_t^2 = 14.3694
# Epoch 4, Iteration 10: H_t = 25, G_t = 0.5886, σ_t^2 = 11.4035
# Epoch 4, Iteration 11: H_t = 4, G_t = -0.1016, σ_t^2 = 12.9521
# Epoch 4, Iteration 12: H_t = 16, G_t = 0.4084, σ_t^2 = 12.2153
# Epoch 4, Iteration 13: H_t = 14, G_t = 0.4736, σ_t^2 = 16.8875
# Epoch 4, Iteration 14: H_t = 25, G_t = 0.6963, σ_t^2 = 13.4213
# Epoch 4, Iteration 15: H_t = 4, G_t = -1.1675, σ_t^2 = 18.8547
# Epoch 4, Iteration 16: H_t = 4, G_t = -0.9479, σ_t^2 = 13.7528
# Epoch 4, Iteration 17: H_t = 15, G_t = 0.4415, σ_t^2 = 13.8557
# Epoch 4, Iteration 18: H_t = 4, G_t = -0.0370, σ_t^2 = 15.5470
#     Worker 0: Train Loss: 3.9803, Train Accuracy: 8.92%
#     Worker 1: Train Loss: 3.9853, Train Accuracy: 8.65%
#     Worker 2: Train Loss: 3.9425, Train Accuracy: 9.60%
#     Worker 3: Train Loss: 3.9831, Train Accuracy: 8.93%
# Epoch 4: Test Loss: 3.8178, Test Accuracy: 12.02%
# Total Computation Time: 96.13 seconds
# Total Communication Time: 0.06 seconds
# Epoch 5, Iteration 1: H_t = 18, G_t = 0.4967, σ_t^2 = 13.5938
# Epoch 5, Iteration 2: H_t = 4, G_t = 0.0824, σ_t^2 = 16.7784
# Epoch 5, Iteration 3: H_t = 27, G_t = 0.6965, σ_t^2 = 12.6808
# Epoch 5, Iteration 4: H_t = 23, G_t = 0.7935, σ_t^2 = 16.6329
# Epoch 5, Iteration 5: H_t = 4, G_t = -0.1614, σ_t^2 = 15.5280
# Epoch 5, Iteration 6: H_t = 4, G_t = -0.0588, σ_t^2 = 14.1660
# Epoch 5, Iteration 7: H_t = 4, G_t = -0.5498, σ_t^2 = 13.6188
# Epoch 5, Iteration 8: H_t = 4, G_t = -0.1220, σ_t^2 = 15.7377
# Epoch 5, Iteration 9: H_t = 16, G_t = 0.4968, σ_t^2 = 14.6874
# Epoch 5, Iteration 10: H_t = 44, G_t = 1.4821, σ_t^2 = 16.7069
# Epoch 5, Iteration 11: H_t = 4, G_t = -0.1837, σ_t^2 = 14.1358
# Epoch 5, Iteration 12: H_t = 4, G_t = -0.0051, σ_t^2 = 16.5081
# Epoch 5, Iteration 13: H_t = 6, G_t = 0.2006, σ_t^2 = 15.3274
# Epoch 5, Iteration 14: H_t = 21, G_t = 0.6183, σ_t^2 = 14.3528
# Epoch 5, Iteration 15: H_t = 4, G_t = -0.8464, σ_t^2 = 18.2228
# Epoch 5, Iteration 16: H_t = 4, G_t = -0.2623, σ_t^2 = 14.0088
# Epoch 5, Iteration 17: H_t = 4, G_t = -0.0587, σ_t^2 = 15.4943
# Epoch 5, Iteration 18: H_t = 4, G_t = -0.0420, σ_t^2 = 14.2009
#     Worker 0: Train Loss: 3.8602, Train Accuracy: 10.57%
#     Worker 1: Train Loss: 3.8706, Train Accuracy: 10.83%
#     Worker 2: Train Loss: 3.8145, Train Accuracy: 11.64%
#     Worker 3: Train Loss: 3.8520, Train Accuracy: 11.12%
# Epoch 5: Test Loss: 3.6984, Test Accuracy: 13.99%
# Total Computation Time: 119.95 seconds
# Total Communication Time: 0.08 seconds
# Epoch 6, Iteration 1: H_t = 4, G_t = -1.1922, σ_t^2 = 19.8736
# Epoch 6, Iteration 2: H_t = 17, G_t = 0.6858, σ_t^2 = 19.6206
# Epoch 6, Iteration 3: H_t = 21, G_t = 0.7921, σ_t^2 = 18.6920
# Epoch 6, Iteration 4: H_t = 64, G_t = 3.0412, σ_t^2 = 16.2996
# Epoch 6, Iteration 5: H_t = 4, G_t = -0.2958, σ_t^2 = 14.9076
# Epoch 6, Iteration 6: H_t = 4, G_t = -0.4596, σ_t^2 = 14.1006
# Epoch 6, Iteration 7: H_t = 4, G_t = -0.5600, σ_t^2 = 16.4644
# Epoch 6, Iteration 8: H_t = 4, G_t = -0.3139, σ_t^2 = 15.7720
# Epoch 6, Iteration 9: H_t = 64, G_t = 2.9249, σ_t^2 = 14.7603
# Epoch 6, Iteration 10: H_t = 20, G_t = 0.6281, σ_t^2 = 15.3785
# Epoch 6, Iteration 11: H_t = 7, G_t = 0.2539, σ_t^2 = 17.7952
#     Worker 0: Train Loss: 3.7664, Train Accuracy: 11.94%
#     Worker 1: Train Loss: 3.7641, Train Accuracy: 12.23%
#     Worker 2: Train Loss: 3.7301, Train Accuracy: 12.96%
#     Worker 3: Train Loss: 3.7766, Train Accuracy: 12.31%
# Epoch 6: Test Loss: 3.5890, Test Accuracy: 16.31%
# Total Computation Time: 145.18 seconds
# Total Communication Time: 0.10 seconds
# Epoch 7, Iteration 1: H_t = 4, G_t = -0.3252, σ_t^2 = 16.8258
# Epoch 7, Iteration 2: H_t = 4, G_t = -0.8893, σ_t^2 = 18.0927
# Epoch 7, Iteration 3: H_t = 27, G_t = 0.8714, σ_t^2 = 15.5734
# Epoch 7, Iteration 4: H_t = 32, G_t = 1.0195, σ_t^2 = 15.9247
# Epoch 7, Iteration 5: H_t = 4, G_t = -0.9732, σ_t^2 = 17.5624
# Epoch 7, Iteration 6: H_t = 20, G_t = 0.5761, σ_t^2 = 13.7266
# Epoch 7, Iteration 7: H_t = 21, G_t = 0.6345, σ_t^2 = 14.7660
# Epoch 7, Iteration 8: H_t = 4, G_t = 0.0729, σ_t^2 = 17.8825
# Epoch 7, Iteration 9: H_t = 4, G_t = -0.5675, σ_t^2 = 17.6199
# Epoch 7, Iteration 10: H_t = 4, G_t = -0.0106, σ_t^2 = 15.6665
# Epoch 7, Iteration 11: H_t = 55, G_t = 2.0196, σ_t^2 = 18.3546
# Epoch 7, Iteration 12: H_t = 16, G_t = 0.4878, σ_t^2 = 14.7249
# Epoch 7, Iteration 13: H_t = 4, G_t = 0.0168, σ_t^2 = 19.7080
#     Worker 0: Train Loss: 3.6759, Train Accuracy: 13.62%
#     Worker 1: Train Loss: 3.6708, Train Accuracy: 13.57%
#     Worker 2: Train Loss: 3.6290, Train Accuracy: 14.51%
#     Worker 3: Train Loss: 3.6826, Train Accuracy: 13.89%
# Epoch 7: Test Loss: 3.5110, Test Accuracy: 17.56%
# Total Computation Time: 169.29 seconds
# Total Communication Time: 0.11 seconds
# Epoch 8, Iteration 1: H_t = 21, G_t = 0.7982, σ_t^2 = 18.3828
# Epoch 8, Iteration 2: H_t = 64, G_t = 2.8207, σ_t^2 = 21.9766
# Epoch 8, Iteration 3: H_t = 4, G_t = -0.6524, σ_t^2 = 17.9247
# Epoch 8, Iteration 4: H_t = 10, G_t = 0.2909, σ_t^2 = 14.4551
# Epoch 8, Iteration 5: H_t = 4, G_t = -0.1620, σ_t^2 = 18.4440
# Epoch 8, Iteration 6: H_t = 6, G_t = 0.2141, σ_t^2 = 16.6915
# Epoch 8, Iteration 7: H_t = 30, G_t = 1.0896, σ_t^2 = 17.7701
# Epoch 8, Iteration 8: H_t = 6, G_t = 0.2898, σ_t^2 = 23.7575
# Epoch 8, Iteration 9: H_t = 8, G_t = 0.3160, σ_t^2 = 19.4263
# Epoch 8, Iteration 10: H_t = 12, G_t = 0.4919, σ_t^2 = 20.2876
# Epoch 8, Iteration 11: H_t = 5, G_t = 0.2307, σ_t^2 = 21.5873
# Epoch 8, Iteration 12: H_t = 22, G_t = 0.9782, σ_t^2 = 22.1907
# Epoch 8, Iteration 13: H_t = 4, G_t = -0.4393, σ_t^2 = 22.5899
#     Worker 0: Train Loss: 3.5639, Train Accuracy: 15.19%
#     Worker 1: Train Loss: 3.5872, Train Accuracy: 15.27%
#     Worker 2: Train Loss: 3.5358, Train Accuracy: 16.18%
#     Worker 3: Train Loss: 3.5690, Train Accuracy: 15.58%
# Epoch 8: Test Loss: 3.4236, Test Accuracy: 18.22%
# Total Computation Time: 192.69 seconds
# Total Communication Time: 0.13 seconds
# Epoch 9, Iteration 1: H_t = 4, G_t = -0.7903, σ_t^2 = 21.5634
# Epoch 9, Iteration 2: H_t = 15, G_t = 0.6081, σ_t^2 = 20.1990
# Epoch 9, Iteration 3: H_t = 4, G_t = -0.8326, σ_t^2 = 28.3051
# Epoch 9, Iteration 4: H_t = 16, G_t = 0.7229, σ_t^2 = 21.9214
# Epoch 9, Iteration 5: H_t = 4, G_t = -1.7783, σ_t^2 = 25.7042
# Epoch 9, Iteration 6: H_t = 4, G_t = -0.7593, σ_t^2 = 22.0577
# Epoch 9, Iteration 7: H_t = 17, G_t = 0.6278, σ_t^2 = 17.9677
# Epoch 9, Iteration 8: H_t = 4, G_t = -1.1467, σ_t^2 = 21.3314
# Epoch 9, Iteration 9: H_t = 4, G_t = -1.1891, σ_t^2 = 23.1623
# Epoch 9, Iteration 10: H_t = 4, G_t = -0.0843, σ_t^2 = 23.9188
# Epoch 9, Iteration 11: H_t = 19, G_t = 0.8789, σ_t^2 = 22.0485
# Epoch 9, Iteration 12: H_t = 4, G_t = -0.8942, σ_t^2 = 23.3898
# Epoch 9, Iteration 13: H_t = 6, G_t = 0.2663, σ_t^2 = 20.4168
# Epoch 9, Iteration 14: H_t = 12, G_t = 0.4944, σ_t^2 = 19.9121
# Epoch 9, Iteration 15: H_t = 19, G_t = 0.8904, σ_t^2 = 22.2914
# Epoch 9, Iteration 16: H_t = 4, G_t = -0.0635, σ_t^2 = 24.1748
# Epoch 9, Iteration 17: H_t = 4, G_t = -0.8837, σ_t^2 = 22.4668
# Epoch 9, Iteration 18: H_t = 10, G_t = 0.5594, σ_t^2 = 25.5286
# Epoch 9, Iteration 19: H_t = 4, G_t = 0.2721, σ_t^2 = 27.9688
# Epoch 9, Iteration 20: H_t = 4, G_t = -0.4014, σ_t^2 = 22.0253
# Epoch 9, Iteration 21: H_t = 29, G_t = 1.5543, σ_t^2 = 25.9177
# Epoch 9, Iteration 22: H_t = 16, G_t = 0.7735, σ_t^2 = 23.6072
# Epoch 9, Iteration 23: H_t = 4, G_t = -0.2578, σ_t^2 = 20.9283
#     Worker 0: Train Loss: 3.4915, Train Accuracy: 16.37%
#     Worker 1: Train Loss: 3.4893, Train Accuracy: 17.14%
#     Worker 2: Train Loss: 3.4195, Train Accuracy: 18.34%
#     Worker 3: Train Loss: 3.4988, Train Accuracy: 17.06%
# Epoch 9: Test Loss: 3.3374, Test Accuracy: 19.94%
# Total Computation Time: 217.86 seconds
# Total Communication Time: 0.15 seconds
# Epoch 10, Iteration 1: H_t = 11, G_t = 0.4946, σ_t^2 = 22.1039
# Epoch 10, Iteration 2: H_t = 22, G_t = 1.1952, σ_t^2 = 27.1065
# Epoch 10, Iteration 3: H_t = 4, G_t = -0.3110, σ_t^2 = 22.9484
# Epoch 10, Iteration 4: H_t = 19, G_t = 0.7689, σ_t^2 = 19.8882
# Epoch 10, Iteration 5: H_t = 22, G_t = 1.0436, σ_t^2 = 23.0351
# Epoch 10, Iteration 6: H_t = 4, G_t = -0.9922, σ_t^2 = 25.5111
# Epoch 10, Iteration 7: H_t = 4, G_t = -0.1508, σ_t^2 = 22.9526
# Epoch 10, Iteration 8: H_t = 4, G_t = -0.3325, σ_t^2 = 25.4346
# Epoch 10, Iteration 9: H_t = 27, G_t = 1.0821, σ_t^2 = 19.7013
# Epoch 10, Iteration 10: H_t = 4, G_t = -0.0389, σ_t^2 = 23.2041
# Epoch 10, Iteration 11: H_t = 4, G_t = 0.1077, σ_t^2 = 20.6505
# Epoch 10, Iteration 12: H_t = 23, G_t = 1.0335, σ_t^2 = 22.2567
# Epoch 10, Iteration 13: H_t = 52, G_t = 2.8367, σ_t^2 = 27.0086
# Epoch 10, Iteration 14: H_t = 4, G_t = 0.1084, σ_t^2 = 18.8834
#     Worker 0: Train Loss: 3.4016, Train Accuracy: 18.28%
#     Worker 1: Train Loss: 3.4389, Train Accuracy: 17.73%
#     Worker 2: Train Loss: 3.3622, Train Accuracy: 18.45%
#     Worker 3: Train Loss: 3.4220, Train Accuracy: 17.96%
# Epoch 10: Test Loss: 3.2786, Test Accuracy: 21.00%
# Total Computation Time: 241.96 seconds
# Total Communication Time: 0.17 seconds
# Epoch 11, Iteration 1: H_t = 4, G_t = -1.4307, σ_t^2 = 23.6227
# Epoch 11, Iteration 2: H_t = 4, G_t = -0.5629, σ_t^2 = 19.0859
# Epoch 11, Iteration 3: H_t = 10, G_t = 0.3979, σ_t^2 = 18.7900
# Epoch 11, Iteration 4: H_t = 17, G_t = 0.7281, σ_t^2 = 20.7564
# Epoch 11, Iteration 5: H_t = 4, G_t = -1.0192, σ_t^2 = 27.6347
# Epoch 11, Iteration 6: H_t = 5, G_t = 0.2242, σ_t^2 = 21.4077
# Epoch 11, Iteration 7: H_t = 4, G_t = 0.1414, σ_t^2 = 25.4753
# Epoch 11, Iteration 8: H_t = 64, G_t = 3.5979, σ_t^2 = 27.5807
# Epoch 11, Iteration 9: H_t = 4, G_t = -0.8695, σ_t^2 = 30.2129
# Epoch 11, Iteration 10: H_t = 4, G_t = -0.9683, σ_t^2 = 27.4107
# Epoch 11, Iteration 11: H_t = 12, G_t = 0.4709, σ_t^2 = 18.8712
# Epoch 11, Iteration 12: H_t = 28, G_t = 1.2987, σ_t^2 = 22.5616
# Epoch 11, Iteration 13: H_t = 4, G_t = 0.0421, σ_t^2 = 26.7884
# Epoch 11, Iteration 14: H_t = 21, G_t = 1.0286, σ_t^2 = 23.7685
# Epoch 11, Iteration 15: H_t = 4, G_t = -1.8070, σ_t^2 = 32.9123
# Epoch 11, Iteration 16: H_t = 4, G_t = -0.2694, σ_t^2 = 25.8292
# Epoch 11, Iteration 17: H_t = 28, G_t = 1.6566, σ_t^2 = 28.9852
#     Worker 0: Train Loss: 3.3301, Train Accuracy: 19.55%
#     Worker 1: Train Loss: 3.3453, Train Accuracy: 19.23%
#     Worker 2: Train Loss: 3.2822, Train Accuracy: 20.38%
#     Worker 3: Train Loss: 3.3392, Train Accuracy: 19.39%
# Epoch 11: Test Loss: 3.1894, Test Accuracy: 22.89%
# Total Computation Time: 265.03 seconds
# Total Communication Time: 0.19 seconds
# Epoch 12, Iteration 1: H_t = 10, G_t = 0.5590, σ_t^2 = 27.7038
# Epoch 12, Iteration 2: H_t = 27, G_t = 1.4359, σ_t^2 = 26.0674
# Epoch 12, Iteration 3: H_t = 4, G_t = -2.0393, σ_t^2 = 31.5868
# Epoch 12, Iteration 4: H_t = 4, G_t = -1.4450, σ_t^2 = 31.5360
# Epoch 12, Iteration 5: H_t = 40, G_t = 2.0008, σ_t^2 = 24.4784
# Epoch 12, Iteration 6: H_t = 4, G_t = -0.0124, σ_t^2 = 24.9481
# Epoch 12, Iteration 7: H_t = 4, G_t = -0.8753, σ_t^2 = 27.3744
# Epoch 12, Iteration 8: H_t = 64, G_t = 3.1838, σ_t^2 = 20.5879
# Epoch 12, Iteration 9: H_t = 4, G_t = -1.3272, σ_t^2 = 27.4408
# Epoch 12, Iteration 10: H_t = 4, G_t = -0.5012, σ_t^2 = 27.4336
# Epoch 12, Iteration 11: H_t = 16, G_t = 0.7705, σ_t^2 = 24.0495
# Epoch 12, Iteration 12: H_t = 37, G_t = 2.1193, σ_t^2 = 27.9774
#     Worker 0: Train Loss: 3.2747, Train Accuracy: 19.79%
#     Worker 1: Train Loss: 3.2926, Train Accuracy: 20.06%
#     Worker 2: Train Loss: 3.2475, Train Accuracy: 21.10%
#     Worker 3: Train Loss: 3.3009, Train Accuracy: 19.71%
# Epoch 12: Test Loss: 3.0912, Test Accuracy: 24.95%
# Total Computation Time: 289.56 seconds
# Total Communication Time: 0.20 seconds
# Epoch 13, Iteration 1: H_t = 64, G_t = 5.3669, σ_t^2 = 22.0235
# Epoch 13, Iteration 2: H_t = 4, G_t = -2.1372, σ_t^2 = 30.3712
# Epoch 13, Iteration 3: H_t = 30, G_t = 1.2894, σ_t^2 = 20.9411
# Epoch 13, Iteration 4: H_t = 4, G_t = 0.1067, σ_t^2 = 27.0366
# Epoch 13, Iteration 5: H_t = 17, G_t = 0.9456, σ_t^2 = 27.4063
# Epoch 13, Iteration 6: H_t = 20, G_t = 1.1908, σ_t^2 = 28.6947
# Epoch 13, Iteration 7: H_t = 25, G_t = 1.2982, σ_t^2 = 25.7695
# Epoch 13, Iteration 8: H_t = 23, G_t = 1.2225, σ_t^2 = 26.4633
#     Worker 0: Train Loss: 3.1991, Train Accuracy: 21.93%
#     Worker 1: Train Loss: 3.2499, Train Accuracy: 20.91%
#     Worker 2: Train Loss: 3.1774, Train Accuracy: 22.30%
#     Worker 3: Train Loss: 3.2227, Train Accuracy: 21.43%
# Epoch 13: Test Loss: 3.0543, Test Accuracy: 25.76%
# Total Computation Time: 313.21 seconds
# Total Communication Time: 0.21 seconds
# Epoch 14, Iteration 1: H_t = 6, G_t = 0.3396, σ_t^2 = 27.0714
# Epoch 14, Iteration 2: H_t = 4, G_t = -1.7272, σ_t^2 = 31.3002
# Epoch 14, Iteration 3: H_t = 8, G_t = 0.4882, σ_t^2 = 27.5622
# Epoch 14, Iteration 4: H_t = 20, G_t = 1.0479, σ_t^2 = 25.8754
# Epoch 14, Iteration 5: H_t = 4, G_t = -1.0854, σ_t^2 = 35.4338
# Epoch 14, Iteration 6: H_t = 46, G_t = 2.6082, σ_t^2 = 28.1787
# Epoch 14, Iteration 7: H_t = 4, G_t = -1.3240, σ_t^2 = 36.2551
# Epoch 14, Iteration 8: H_t = 4, G_t = -0.3705, σ_t^2 = 29.4311
# Epoch 14, Iteration 9: H_t = 4, G_t = 0.1977, σ_t^2 = 24.9388
# Epoch 14, Iteration 10: H_t = 4, G_t = 0.2379, σ_t^2 = 30.5077
# Epoch 14, Iteration 11: H_t = 47, G_t = 2.4969, σ_t^2 = 26.2347
# Epoch 14, Iteration 12: H_t = 4, G_t = -0.3615, σ_t^2 = 28.2272
# Epoch 14, Iteration 13: H_t = 4, G_t = -0.0586, σ_t^2 = 23.7799
# Epoch 14, Iteration 14: H_t = 4, G_t = -0.6037, σ_t^2 = 25.0685
# Epoch 14, Iteration 15: H_t = 4, G_t = -1.2418, σ_t^2 = 27.0129
# Epoch 14, Iteration 16: H_t = 4, G_t = -2.0801, σ_t^2 = 33.9610
# Epoch 14, Iteration 17: H_t = 4, G_t = -0.5837, σ_t^2 = 26.7104
# Epoch 14, Iteration 18: H_t = 4, G_t = -1.4224, σ_t^2 = 35.8494
#     Worker 0: Train Loss: 3.1570, Train Accuracy: 22.20%
#     Worker 1: Train Loss: 3.1790, Train Accuracy: 21.98%
#     Worker 2: Train Loss: 3.0912, Train Accuracy: 23.88%
#     Worker 3: Train Loss: 3.1453, Train Accuracy: 22.81%
# Epoch 14: Test Loss: 2.9536, Test Accuracy: 27.30%
# Total Computation Time: 336.72 seconds
# Total Communication Time: 0.23 seconds
# Epoch 15, Iteration 1: H_t = 26, G_t = 1.5087, σ_t^2 = 28.0951
# Epoch 15, Iteration 2: H_t = 4, G_t = -2.0477, σ_t^2 = 30.9381
# Epoch 15, Iteration 3: H_t = 4, G_t = -2.8253, σ_t^2 = 34.9321
# Epoch 15, Iteration 4: H_t = 4, G_t = -1.0215, σ_t^2 = 33.6292
# Epoch 15, Iteration 5: H_t = 4, G_t = 0.0617, σ_t^2 = 33.7733
# Epoch 15, Iteration 6: H_t = 4, G_t = 0.0104, σ_t^2 = 29.6095
# Epoch 15, Iteration 7: H_t = 64, G_t = 5.0502, σ_t^2 = 28.3682
# Epoch 15, Iteration 8: H_t = 64, G_t = 6.0904, σ_t^2 = 27.0883
# Epoch 15, Iteration 9: H_t = 35, G_t = 1.7620, σ_t^2 = 24.6768
# Epoch 15, Iteration 10: H_t = 21, G_t = 1.2182, σ_t^2 = 27.9365
#     Worker 0: Train Loss: 3.1069, Train Accuracy: 23.26%
#     Worker 1: Train Loss: 3.1167, Train Accuracy: 23.39%
#     Worker 2: Train Loss: 3.0889, Train Accuracy: 23.63%
#     Worker 3: Train Loss: 3.1270, Train Accuracy: 23.84%
# Epoch 15: Test Loss: 2.9273, Test Accuracy: 27.89%
# Total Computation Time: 362.08 seconds
# Total Communication Time: 0.24 seconds
# Epoch 16, Iteration 1: H_t = 4, G_t = -1.3172, σ_t^2 = 35.5988
# Epoch 16, Iteration 2: H_t = 4, G_t = -0.9390, σ_t^2 = 30.8885
# Epoch 16, Iteration 3: H_t = 23, G_t = 1.2586, σ_t^2 = 27.0638
# Epoch 16, Iteration 4: H_t = 60, G_t = 3.5695, σ_t^2 = 29.6033
# Epoch 16, Iteration 5: H_t = 4, G_t = -2.1592, σ_t^2 = 35.8929
# Epoch 16, Iteration 6: H_t = 4, G_t = 0.0202, σ_t^2 = 24.8914
# Epoch 16, Iteration 7: H_t = 60, G_t = 3.3948, σ_t^2 = 27.9489
# Epoch 16, Iteration 8: H_t = 10, G_t = 0.7028, σ_t^2 = 34.3072
# Epoch 16, Iteration 9: H_t = 26, G_t = 1.5939, σ_t^2 = 30.3536
# Epoch 16, Iteration 10: H_t = 4, G_t = -0.4995, σ_t^2 = 30.6297
#     Worker 0: Train Loss: 3.0530, Train Accuracy: 24.17%
#     Worker 1: Train Loss: 3.0794, Train Accuracy: 24.38%
#     Worker 2: Train Loss: 3.0084, Train Accuracy: 25.54%
#     Worker 3: Train Loss: 3.0685, Train Accuracy: 24.60%
# Epoch 16: Test Loss: 2.8642, Test Accuracy: 29.21%
# Total Computation Time: 387.71 seconds
# Total Communication Time: 0.26 seconds
# Epoch 17, Iteration 1: H_t = 38, G_t = 2.0729, σ_t^2 = 26.8294
# Epoch 17, Iteration 2: H_t = 4, G_t = -0.4113, σ_t^2 = 31.8420
# Epoch 17, Iteration 3: H_t = 11, G_t = 0.5952, σ_t^2 = 26.0180
# Epoch 17, Iteration 4: H_t = 60, G_t = 3.7797, σ_t^2 = 31.0031
# Epoch 17, Iteration 5: H_t = 4, G_t = 0.0750, σ_t^2 = 24.4651
# Epoch 17, Iteration 6: H_t = 44, G_t = 2.3773, σ_t^2 = 26.5454
# Epoch 17, Iteration 7: H_t = 4, G_t = 0.1116, σ_t^2 = 30.7543
# Epoch 17, Iteration 8: H_t = 4, G_t = -0.1031, σ_t^2 = 31.8850
# Epoch 17, Iteration 9: H_t = 19, G_t = 1.3352, σ_t^2 = 33.6859
# Epoch 17, Iteration 10: H_t = 4, G_t = -0.9966, σ_t^2 = 35.8654
# Epoch 17, Iteration 11: H_t = 19, G_t = 0.9979, σ_t^2 = 25.3137
#     Worker 0: Train Loss: 3.0058, Train Accuracy: 25.52%
#     Worker 1: Train Loss: 3.0195, Train Accuracy: 25.10%
#     Worker 2: Train Loss: 2.9589, Train Accuracy: 26.92%
#     Worker 3: Train Loss: 3.0149, Train Accuracy: 25.14%
# Epoch 17: Test Loss: 2.8159, Test Accuracy: 30.19%
# Total Computation Time: 411.02 seconds
# Total Communication Time: 0.27 seconds
# Epoch 18, Iteration 1: H_t = 4, G_t = -1.2985, σ_t^2 = 32.8698
# Epoch 18, Iteration 2: H_t = 28, G_t = 1.6746, σ_t^2 = 29.8863
# Epoch 18, Iteration 3: H_t = 4, G_t = -0.6255, σ_t^2 = 31.0225
# Epoch 18, Iteration 4: H_t = 4, G_t = -1.0805, σ_t^2 = 28.9873
# Epoch 18, Iteration 5: H_t = 4, G_t = 0.1897, σ_t^2 = 29.7191
# Epoch 18, Iteration 6: H_t = 14, G_t = 0.8224, σ_t^2 = 28.8758
# Epoch 18, Iteration 7: H_t = 5, G_t = 0.3852, σ_t^2 = 35.0459
# Epoch 18, Iteration 8: H_t = 4, G_t = -1.1895, σ_t^2 = 35.7920
# Epoch 18, Iteration 9: H_t = 36, G_t = 2.4161, σ_t^2 = 32.8981
# Epoch 18, Iteration 10: H_t = 4, G_t = -3.3368, σ_t^2 = 41.6390
# Epoch 18, Iteration 11: H_t = 4, G_t = -0.7948, σ_t^2 = 31.8878
# Epoch 18, Iteration 12: H_t = 14, G_t = 0.8426, σ_t^2 = 29.7107
# Epoch 18, Iteration 13: H_t = 4, G_t = -1.0233, σ_t^2 = 36.8808
# Epoch 18, Iteration 14: H_t = 4, G_t = -0.6976, σ_t^2 = 40.2349
# Epoch 18, Iteration 15: H_t = 19, G_t = 1.4831, σ_t^2 = 38.9006
# Epoch 18, Iteration 16: H_t = 4, G_t = -1.0996, σ_t^2 = 33.9482
# Epoch 18, Iteration 17: H_t = 56, G_t = 3.6841, σ_t^2 = 32.5298
# Epoch 18, Iteration 18: H_t = 4, G_t = -2.0338, σ_t^2 = 39.4400
#     Worker 0: Train Loss: 2.9420, Train Accuracy: 26.15%
#     Worker 1: Train Loss: 2.9682, Train Accuracy: 26.19%
#     Worker 2: Train Loss: 2.9282, Train Accuracy: 26.95%
#     Worker 3: Train Loss: 2.9515, Train Accuracy: 26.64%
# Epoch 18: Test Loss: 2.7798, Test Accuracy: 30.40%
# Total Computation Time: 438.69 seconds
# Total Communication Time: 0.29 seconds
# Epoch 19, Iteration 1: H_t = 44, G_t = 2.6626, σ_t^2 = 30.0930
# Epoch 19, Iteration 2: H_t = 8, G_t = 0.5133, σ_t^2 = 31.1103
# Epoch 19, Iteration 3: H_t = 4, G_t = -2.4338, σ_t^2 = 31.7368
# Epoch 19, Iteration 4: H_t = 34, G_t = 2.1218, σ_t^2 = 30.3430
# Epoch 19, Iteration 5: H_t = 4, G_t = -0.9489, σ_t^2 = 29.1220
# Epoch 19, Iteration 6: H_t = 4, G_t = -1.0577, σ_t^2 = 27.3845
# Epoch 19, Iteration 7: H_t = 32, G_t = 1.9088, σ_t^2 = 29.1878
# Epoch 19, Iteration 8: H_t = 4, G_t = -0.8380, σ_t^2 = 32.5147
# Epoch 19, Iteration 9: H_t = 4, G_t = -1.6058, σ_t^2 = 32.5844
# Epoch 19, Iteration 10: H_t = 4, G_t = -0.3170, σ_t^2 = 29.7969
# Epoch 19, Iteration 11: H_t = 4, G_t = -1.2414, σ_t^2 = 32.0205
# Epoch 19, Iteration 12: H_t = 4, G_t = -0.6926, σ_t^2 = 35.9974
# Epoch 19, Iteration 13: H_t = 14, G_t = 0.9890, σ_t^2 = 33.8868
# Epoch 19, Iteration 14: H_t = 16, G_t = 1.4394, σ_t^2 = 42.9699
# Epoch 19, Iteration 15: H_t = 4, G_t = -1.4034, σ_t^2 = 36.0324
# Epoch 19, Iteration 16: H_t = 64, G_t = 4.5528, σ_t^2 = 30.8858
# Epoch 19, Iteration 17: H_t = 4, G_t = 0.0050, σ_t^2 = 30.1068
#     Worker 0: Train Loss: 2.9017, Train Accuracy: 27.35%
#     Worker 1: Train Loss: 2.9151, Train Accuracy: 27.51%
#     Worker 2: Train Loss: 2.8743, Train Accuracy: 28.09%
#     Worker 3: Train Loss: 2.9140, Train Accuracy: 27.02%
# Epoch 19: Test Loss: 2.7292, Test Accuracy: 31.31%
# Total Computation Time: 468.66 seconds
# Total Communication Time: 0.31 seconds
# Epoch 20, Iteration 1: H_t = 4, G_t = -0.0598, σ_t^2 = 29.1114
# Epoch 20, Iteration 2: H_t = 16, G_t = 0.8422, σ_t^2 = 24.7719
# Epoch 20, Iteration 3: H_t = 55, G_t = 3.8990, σ_t^2 = 34.8453
# Epoch 20, Iteration 4: H_t = 30, G_t = 2.1959, σ_t^2 = 35.8900
# Epoch 20, Iteration 5: H_t = 4, G_t = -1.8257, σ_t^2 = 39.8555
# Epoch 20, Iteration 6: H_t = 4, G_t = -2.6257, σ_t^2 = 42.2129
# Epoch 20, Iteration 7: H_t = 4, G_t = -1.0639, σ_t^2 = 30.3241
# Epoch 20, Iteration 8: H_t = 4, G_t = 0.2364, σ_t^2 = 30.9681
# Epoch 20, Iteration 9: H_t = 4, G_t = 0.1568, σ_t^2 = 32.8350
# Epoch 20, Iteration 10: H_t = 26, G_t = 1.8722, σ_t^2 = 35.3824
# Epoch 20, Iteration 11: H_t = 10, G_t = 0.6503, σ_t^2 = 30.9639
# Epoch 20, Iteration 12: H_t = 4, G_t = -2.0284, σ_t^2 = 32.8665
# Epoch 20, Iteration 13: H_t = 4, G_t = 0.2876, σ_t^2 = 39.1702
# Epoch 20, Iteration 14: H_t = 15, G_t = 1.1413, σ_t^2 = 37.6290
# Epoch 20, Iteration 15: H_t = 4, G_t = -1.5678, σ_t^2 = 36.8035
# Epoch 20, Iteration 16: H_t = 7, G_t = 0.4513, σ_t^2 = 31.8081
# Epoch 20, Iteration 17: H_t = 4, G_t = -1.6226, σ_t^2 = 38.5660
#     Worker 0: Train Loss: 2.8343, Train Accuracy: 29.07%
#     Worker 1: Train Loss: 2.8506, Train Accuracy: 28.54%
#     Worker 2: Train Loss: 2.8291, Train Accuracy: 29.11%
#     Worker 3: Train Loss: 2.8508, Train Accuracy: 28.65%
# Epoch 20: Test Loss: 2.6731, Test Accuracy: 32.55%
# Total Computation Time: 492.23 seconds
# Total Communication Time: 0.33 seconds
# Epoch 21, Iteration 1: H_t = 64, G_t = 6.6794, σ_t^2 = 29.0481
# Epoch 21, Iteration 2: H_t = 4, G_t = -0.5771, σ_t^2 = 34.1238
# Epoch 21, Iteration 3: H_t = 4, G_t = -2.1351, σ_t^2 = 33.4624
# Epoch 21, Iteration 4: H_t = 13, G_t = 0.7372, σ_t^2 = 26.5400
# Epoch 21, Iteration 5: H_t = 4, G_t = -1.2746, σ_t^2 = 42.2333
# Epoch 21, Iteration 6: H_t = 4, G_t = -4.7572, σ_t^2 = 49.5323
# Epoch 21, Iteration 7: H_t = 18, G_t = 1.2529, σ_t^2 = 33.8857
# Epoch 21, Iteration 8: H_t = 4, G_t = -0.3527, σ_t^2 = 35.4241
# Epoch 21, Iteration 9: H_t = 4, G_t = -2.1761, σ_t^2 = 35.8131
# Epoch 21, Iteration 10: H_t = 4, G_t = -0.9136, σ_t^2 = 38.8514
# Epoch 21, Iteration 11: H_t = 4, G_t = -0.7287, σ_t^2 = 35.1392
# Epoch 21, Iteration 12: H_t = 13, G_t = 0.8442, σ_t^2 = 30.2275
# Epoch 21, Iteration 13: H_t = 4, G_t = -2.2925, σ_t^2 = 44.2168
# Epoch 21, Iteration 14: H_t = 4, G_t = -2.1644, σ_t^2 = 40.2898
# Epoch 21, Iteration 15: H_t = 17, G_t = 1.1735, σ_t^2 = 32.6438
# Epoch 21, Iteration 16: H_t = 7, G_t = 0.6317, σ_t^2 = 43.3200
# Epoch 21, Iteration 17: H_t = 4, G_t = 0.0124, σ_t^2 = 34.6299
# Epoch 21, Iteration 18: H_t = 4, G_t = -0.7537, σ_t^2 = 45.5281
# Epoch 21, Iteration 19: H_t = 43, G_t = 2.7425, σ_t^2 = 31.6496
# Epoch 21, Iteration 20: H_t = 15, G_t = 1.0671, σ_t^2 = 34.1132
#     Worker 0: Train Loss: 2.7898, Train Accuracy: 29.29%
#     Worker 1: Train Loss: 2.8154, Train Accuracy: 29.05%
#     Worker 2: Train Loss: 2.7688, Train Accuracy: 30.16%
#     Worker 3: Train Loss: 2.8163, Train Accuracy: 29.18%
# Epoch 21: Test Loss: 2.6664, Test Accuracy: 32.77%
# Total Computation Time: 519.21 seconds
# Total Communication Time: 0.35 seconds
# Epoch 22, Iteration 1: H_t = 31, G_t = 2.2352, σ_t^2 = 35.2496
# Epoch 22, Iteration 2: H_t = 4, G_t = -0.7484, σ_t^2 = 36.8017
# Epoch 22, Iteration 3: H_t = 4, G_t = -1.4365, σ_t^2 = 38.8740
# Epoch 22, Iteration 4: H_t = 4, G_t = -1.2636, σ_t^2 = 34.4868
# Epoch 22, Iteration 5: H_t = 4, G_t = -1.1685, σ_t^2 = 36.1044
# Epoch 22, Iteration 6: H_t = 4, G_t = 0.2332, σ_t^2 = 28.3006
# Epoch 22, Iteration 7: H_t = 6, G_t = 0.4467, σ_t^2 = 36.8699
# Epoch 22, Iteration 8: H_t = 4, G_t = -0.8970, σ_t^2 = 41.6360
# Epoch 22, Iteration 9: H_t = 27, G_t = 2.1512, σ_t^2 = 39.0081
# Epoch 22, Iteration 10: H_t = 43, G_t = 3.2963, σ_t^2 = 37.7295
# Epoch 22, Iteration 11: H_t = 4, G_t = -0.6290, σ_t^2 = 38.0924
# Epoch 22, Iteration 12: H_t = 4, G_t = -0.1910, σ_t^2 = 37.7935
# Epoch 22, Iteration 13: H_t = 20, G_t = 1.2137, σ_t^2 = 28.9782
# Epoch 22, Iteration 14: H_t = 23, G_t = 1.7829, σ_t^2 = 38.5188
# Epoch 22, Iteration 15: H_t = 36, G_t = 2.6364, σ_t^2 = 36.5947
#     Worker 0: Train Loss: 2.7424, Train Accuracy: 30.15%
#     Worker 1: Train Loss: 2.7672, Train Accuracy: 29.68%
#     Worker 2: Train Loss: 2.7247, Train Accuracy: 30.81%
#     Worker 3: Train Loss: 2.7439, Train Accuracy: 30.16%
# Epoch 22: Test Loss: 2.6078, Test Accuracy: 34.20%
# Total Computation Time: 542.62 seconds
# Total Communication Time: 0.37 seconds
# Epoch 23, Iteration 1: H_t = 4, G_t = -2.2308, σ_t^2 = 39.3927
# Epoch 23, Iteration 2: H_t = 4, G_t = -0.7876, σ_t^2 = 35.2836
# Epoch 23, Iteration 3: H_t = 4, G_t = 0.1201, σ_t^2 = 30.9744
# Epoch 23, Iteration 4: H_t = 20, G_t = 1.3667, σ_t^2 = 33.5189
# Epoch 23, Iteration 5: H_t = 4, G_t = -0.0802, σ_t^2 = 35.7710
# Epoch 23, Iteration 6: H_t = 23, G_t = 1.3997, σ_t^2 = 29.6626
# Epoch 23, Iteration 7: H_t = 4, G_t = -0.8585, σ_t^2 = 34.7558
# Epoch 23, Iteration 8: H_t = 4, G_t = -0.9154, σ_t^2 = 38.0458
# Epoch 23, Iteration 9: H_t = 4, G_t = -2.1248, σ_t^2 = 40.4168
# Epoch 23, Iteration 10: H_t = 21, G_t = 1.4201, σ_t^2 = 32.3367
# Epoch 23, Iteration 11: H_t = 19, G_t = 1.3812, σ_t^2 = 36.3284
# Epoch 23, Iteration 12: H_t = 4, G_t = -1.6634, σ_t^2 = 36.0004
# Epoch 23, Iteration 13: H_t = 4, G_t = -4.5405, σ_t^2 = 42.0216
# Epoch 23, Iteration 14: H_t = 58, G_t = 4.3745, σ_t^2 = 37.0742
# Epoch 23, Iteration 15: H_t = 4, G_t = -0.6539, σ_t^2 = 35.9155
#     Worker 0: Train Loss: 2.7182, Train Accuracy: 31.03%
#     Worker 1: Train Loss: 2.7575, Train Accuracy: 30.34%
#     Worker 2: Train Loss: 2.6978, Train Accuracy: 31.73%
#     Worker 3: Train Loss: 2.7287, Train Accuracy: 30.34%
# Epoch 23: Test Loss: 2.5592, Test Accuracy: 35.02%
# Total Computation Time: 567.96 seconds
# Total Communication Time: 0.39 seconds
# Epoch 24, Iteration 1: H_t = 4, G_t = -2.2071, σ_t^2 = 34.9507
# Epoch 24, Iteration 2: H_t = 4, G_t = -0.4202, σ_t^2 = 30.8921
# Epoch 24, Iteration 3: H_t = 25, G_t = 1.6708, σ_t^2 = 32.3904
# Epoch 24, Iteration 4: H_t = 4, G_t = -4.1947, σ_t^2 = 50.8555
# Epoch 24, Iteration 5: H_t = 50, G_t = 2.8082, σ_t^2 = 27.8397
# Epoch 24, Iteration 6: H_t = 4, G_t = -1.5378, σ_t^2 = 33.3736
# Epoch 24, Iteration 7: H_t = 4, G_t = -2.5254, σ_t^2 = 40.0007
# Epoch 24, Iteration 8: H_t = 36, G_t = 2.3508, σ_t^2 = 32.1134
# Epoch 24, Iteration 9: H_t = 4, G_t = -1.4870, σ_t^2 = 44.2829
# Epoch 24, Iteration 10: H_t = 8, G_t = 0.5093, σ_t^2 = 28.7329
# Epoch 24, Iteration 11: H_t = 4, G_t = 0.0180, σ_t^2 = 33.6841
# Epoch 24, Iteration 12: H_t = 38, G_t = 2.6041, σ_t^2 = 33.5258
# Epoch 24, Iteration 13: H_t = 4, G_t = -1.2177, σ_t^2 = 40.4543
# Epoch 24, Iteration 14: H_t = 7, G_t = 0.5723, σ_t^2 = 39.7233
# Epoch 24, Iteration 15: H_t = 31, G_t = 2.2546, σ_t^2 = 35.3136
#     Worker 0: Train Loss: 2.6561, Train Accuracy: 32.28%
#     Worker 1: Train Loss: 2.7099, Train Accuracy: 31.30%
#     Worker 2: Train Loss: 2.6423, Train Accuracy: 33.02%
#     Worker 3: Train Loss: 2.6879, Train Accuracy: 31.38%
# Epoch 24: Test Loss: 2.5233, Test Accuracy: 35.98%
# Total Computation Time: 591.65 seconds
# Total Communication Time: 0.41 seconds
# Epoch 25, Iteration 1: H_t = 6, G_t = 0.4874, σ_t^2 = 34.8690
# Epoch 25, Iteration 2: H_t = 4, G_t = -3.5730, σ_t^2 = 43.3452
# Epoch 25, Iteration 3: H_t = 4, G_t = -3.2995, σ_t^2 = 48.9909
# Epoch 25, Iteration 4: H_t = 41, G_t = 2.9138, σ_t^2 = 35.3777
# Epoch 25, Iteration 5: H_t = 4, G_t = -2.4309, σ_t^2 = 44.8646
# Epoch 25, Iteration 6: H_t = 64, G_t = 4.0732, σ_t^2 = 30.6491
# Epoch 25, Iteration 7: H_t = 16, G_t = 1.1175, σ_t^2 = 33.4264
# Epoch 25, Iteration 8: H_t = 4, G_t = -1.3082, σ_t^2 = 44.9790
# Epoch 25, Iteration 9: H_t = 11, G_t = 0.8564, σ_t^2 = 37.0360
# Epoch 25, Iteration 10: H_t = 25, G_t = 1.8537, σ_t^2 = 35.9326
# Epoch 25, Iteration 11: H_t = 4, G_t = -2.6546, σ_t^2 = 48.2492
#     Worker 0: Train Loss: 2.6406, Train Accuracy: 32.27%
#     Worker 1: Train Loss: 2.6572, Train Accuracy: 32.18%
#     Worker 2: Train Loss: 2.6113, Train Accuracy: 33.57%
#     Worker 3: Train Loss: 2.6382, Train Accuracy: 32.82%
# Epoch 25: Test Loss: 2.4932, Test Accuracy: 35.76%
# Total Computation Time: 616.54 seconds
# Total Communication Time: 0.42 seconds
# Epoch 26, Iteration 1: H_t = 4, G_t = -2.9421, σ_t^2 = 42.7248
# Epoch 26, Iteration 2: H_t = 4, G_t = -1.1834, σ_t^2 = 39.9804
# Epoch 26, Iteration 3: H_t = 31, G_t = 2.3887, σ_t^2 = 37.8044
# Epoch 26, Iteration 4: H_t = 4, G_t = 0.2649, σ_t^2 = 36.8116
# Epoch 26, Iteration 5: H_t = 10, G_t = 0.8573, σ_t^2 = 39.9191
# Epoch 26, Iteration 6: H_t = 4, G_t = 0.1777, σ_t^2 = 38.8579
# Epoch 26, Iteration 7: H_t = 40, G_t = 3.6123, σ_t^2 = 44.1635
# Epoch 26, Iteration 8: H_t = 26, G_t = 1.9249, σ_t^2 = 35.8809
# Epoch 26, Iteration 9: H_t = 9, G_t = 0.7034, σ_t^2 = 38.2541
# Epoch 26, Iteration 10: H_t = 6, G_t = 0.4928, σ_t^2 = 40.1951
# Epoch 26, Iteration 11: H_t = 4, G_t = 0.1246, σ_t^2 = 36.7266
# Epoch 26, Iteration 12: H_t = 4, G_t = -2.0763, σ_t^2 = 42.2744
# Epoch 26, Iteration 13: H_t = 17, G_t = 1.1796, σ_t^2 = 34.6392
# Epoch 26, Iteration 14: H_t = 4, G_t = -0.3102, σ_t^2 = 46.9110
# Epoch 26, Iteration 15: H_t = 32, G_t = 2.6202, σ_t^2 = 40.7639
# Epoch 26, Iteration 16: H_t = 64, G_t = 6.9485, σ_t^2 = 41.7161
#     Worker 0: Train Loss: 2.6030, Train Accuracy: 33.31%
#     Worker 1: Train Loss: 2.5807, Train Accuracy: 33.97%
#     Worker 2: Train Loss: 2.5781, Train Accuracy: 34.01%
#     Worker 3: Train Loss: 2.5907, Train Accuracy: 33.47%
# Epoch 26: Test Loss: 2.4895, Test Accuracy: 36.59%
# Total Computation Time: 640.49 seconds
# Total Communication Time: 0.44 seconds
# Epoch 27, Iteration 1: H_t = 6, G_t = 0.4434, σ_t^2 = 32.5708
# Epoch 27, Iteration 2: H_t = 4, G_t = 0.1130, σ_t^2 = 37.6756
# Epoch 27, Iteration 3: H_t = 28, G_t = 2.2457, σ_t^2 = 39.4002
# Epoch 27, Iteration 4: H_t = 4, G_t = -1.9334, σ_t^2 = 41.5043
# Epoch 27, Iteration 5: H_t = 4, G_t = -0.6735, σ_t^2 = 38.2154
# Epoch 27, Iteration 6: H_t = 4, G_t = -1.0009, σ_t^2 = 38.8317
# Epoch 27, Iteration 7: H_t = 4, G_t = -0.7482, σ_t^2 = 35.7735
# Epoch 27, Iteration 8: H_t = 36, G_t = 2.6581, σ_t^2 = 36.6631
# Epoch 27, Iteration 9: H_t = 19, G_t = 1.7434, σ_t^2 = 45.7482
# Epoch 27, Iteration 10: H_t = 4, G_t = 0.0557, σ_t^2 = 41.7713
# Epoch 27, Iteration 11: H_t = 4, G_t = -1.6836, σ_t^2 = 37.7470
# Epoch 27, Iteration 12: H_t = 12, G_t = 0.8599, σ_t^2 = 33.3946
# Epoch 27, Iteration 13: H_t = 25, G_t = 2.0489, σ_t^2 = 40.1133
# Epoch 27, Iteration 14: H_t = 4, G_t = -4.9840, σ_t^2 = 55.3355
#     Worker 0: Train Loss: 2.5636, Train Accuracy: 34.26%
#     Worker 1: Train Loss: 2.5802, Train Accuracy: 33.47%
#     Worker 2: Train Loss: 2.5556, Train Accuracy: 34.61%
#     Worker 3: Train Loss: 2.6015, Train Accuracy: 33.56%
# Epoch 27: Test Loss: 2.4340, Test Accuracy: 37.87%
# Total Computation Time: 666.11 seconds
# Total Communication Time: 0.45 seconds
# Epoch 28, Iteration 1: H_t = 13, G_t = 1.0692, σ_t^2 = 38.2625
# Epoch 28, Iteration 2: H_t = 14, G_t = 1.4137, σ_t^2 = 47.8298
# Epoch 28, Iteration 3: H_t = 4, G_t = -0.9183, σ_t^2 = 39.7651
# Epoch 28, Iteration 4: H_t = 43, G_t = 3.6351, σ_t^2 = 41.4192
# Epoch 28, Iteration 5: H_t = 4, G_t = -1.1037, σ_t^2 = 36.0948
# Epoch 28, Iteration 6: H_t = 21, G_t = 1.4595, σ_t^2 = 34.5778
# Epoch 28, Iteration 7: H_t = 4, G_t = -0.8239, σ_t^2 = 43.1550
# Epoch 28, Iteration 8: H_t = 4, G_t = 0.1734, σ_t^2 = 42.5197
# Epoch 28, Iteration 9: H_t = 38, G_t = 2.5298, σ_t^2 = 33.0801
# Epoch 28, Iteration 10: H_t = 4, G_t = -0.0522, σ_t^2 = 41.6286
# Epoch 28, Iteration 11: H_t = 4, G_t = 0.0550, σ_t^2 = 36.6360
# Epoch 28, Iteration 12: H_t = 4, G_t = -0.7834, σ_t^2 = 37.7334
# Epoch 28, Iteration 13: H_t = 4, G_t = -1.6858, σ_t^2 = 42.2962
# Epoch 28, Iteration 14: H_t = 4, G_t = 0.2912, σ_t^2 = 36.8655
# Epoch 28, Iteration 15: H_t = 18, G_t = 1.3981, σ_t^2 = 38.1154
# Epoch 28, Iteration 16: H_t = 4, G_t = -1.7481, σ_t^2 = 45.9243
# Epoch 28, Iteration 17: H_t = 15, G_t = 1.3209, σ_t^2 = 42.6865
# Epoch 28, Iteration 18: H_t = 4, G_t = -1.3710, σ_t^2 = 51.8409
#     Worker 0: Train Loss: 2.5178, Train Accuracy: 35.37%
#     Worker 1: Train Loss: 2.5425, Train Accuracy: 34.89%
#     Worker 2: Train Loss: 2.4651, Train Accuracy: 36.48%
#     Worker 3: Train Loss: 2.5215, Train Accuracy: 34.63%
# Epoch 28: Test Loss: 2.4154, Test Accuracy: 37.84%
# Total Computation Time: 690.42 seconds
# Total Communication Time: 0.47 seconds
# Epoch 29, Iteration 1: H_t = 14, G_t = 1.4524, σ_t^2 = 50.3070
# Epoch 29, Iteration 2: H_t = 37, G_t = 3.0350, σ_t^2 = 40.7433
# Epoch 29, Iteration 3: H_t = 4, G_t = -0.9840, σ_t^2 = 39.7803
# Epoch 29, Iteration 4: H_t = 4, G_t = -0.0165, σ_t^2 = 45.5800
# Epoch 29, Iteration 5: H_t = 4, G_t = -0.3131, σ_t^2 = 39.7439
# Epoch 29, Iteration 6: H_t = 12, G_t = 1.1010, σ_t^2 = 42.7800
# Epoch 29, Iteration 7: H_t = 4, G_t = -2.4341, σ_t^2 = 48.3712
# Epoch 29, Iteration 8: H_t = 38, G_t = 2.9122, σ_t^2 = 37.4976
# Epoch 29, Iteration 9: H_t = 16, G_t = 1.5380, σ_t^2 = 47.6503
# Epoch 29, Iteration 10: H_t = 9, G_t = 0.7356, σ_t^2 = 40.0795
# Epoch 29, Iteration 11: H_t = 4, G_t = -0.0993, σ_t^2 = 45.1548
# Epoch 29, Iteration 12: H_t = 34, G_t = 2.0937, σ_t^2 = 30.2555
# Epoch 29, Iteration 13: H_t = 4, G_t = -1.8338, σ_t^2 = 43.9308
# Epoch 29, Iteration 14: H_t = 4, G_t = -0.6654, σ_t^2 = 35.7557
# Epoch 29, Iteration 15: H_t = 4, G_t = 0.1643, σ_t^2 = 36.5030
# Epoch 29, Iteration 16: H_t = 53, G_t = 4.0048, σ_t^2 = 37.1870
#     Worker 0: Train Loss: 2.4914, Train Accuracy: 35.42%
#     Worker 1: Train Loss: 2.5077, Train Accuracy: 35.53%
#     Worker 2: Train Loss: 2.4888, Train Accuracy: 35.61%
#     Worker 3: Train Loss: 2.5031, Train Accuracy: 35.54%
# Epoch 29: Test Loss: 2.3824, Test Accuracy: 38.70%
# Total Computation Time: 713.28 seconds
# Total Communication Time: 0.49 seconds
# Epoch 30, Iteration 1: H_t = 4, G_t = -0.7459, σ_t^2 = 37.8621
# Epoch 30, Iteration 2: H_t = 6, G_t = 0.4543, σ_t^2 = 36.5517
# Epoch 30, Iteration 3: H_t = 4, G_t = -0.3453, σ_t^2 = 43.6069
# Epoch 30, Iteration 4: H_t = 21, G_t = 1.9270, σ_t^2 = 44.8320
# Epoch 30, Iteration 5: H_t = 60, G_t = 4.6734, σ_t^2 = 38.3836
# Epoch 30, Iteration 6: H_t = 4, G_t = 0.0736, σ_t^2 = 38.5716
# Epoch 30, Iteration 7: H_t = 12, G_t = 0.9611, σ_t^2 = 38.7073
# Epoch 30, Iteration 8: H_t = 4, G_t = -0.4457, σ_t^2 = 44.0309
# Epoch 30, Iteration 9: H_t = 59, G_t = 4.6232, σ_t^2 = 38.7494
# Epoch 30, Iteration 10: H_t = 13, G_t = 1.0692, σ_t^2 = 38.8296
#     Worker 0: Train Loss: 2.4918, Train Accuracy: 35.31%
#     Worker 1: Train Loss: 2.5310, Train Accuracy: 34.60%
#     Worker 2: Train Loss: 2.4736, Train Accuracy: 35.98%
#     Worker 3: Train Loss: 2.5152, Train Accuracy: 35.45%
# Epoch 30: Test Loss: 2.3784, Test Accuracy: 38.71%
# Total Computation Time: 740.03 seconds
# Total Communication Time: 0.50 seconds
# Epoch 31, Iteration 1: H_t = 4, G_t = -1.7903, σ_t^2 = 40.9423
# Epoch 31, Iteration 2: H_t = 4, G_t = -0.4147, σ_t^2 = 39.6796
# Epoch 31, Iteration 3: H_t = 4, G_t = -0.8949, σ_t^2 = 39.9230
# Epoch 31, Iteration 4: H_t = 8, G_t = 0.6973, σ_t^2 = 42.8151
# Epoch 31, Iteration 5: H_t = 18, G_t = 1.5018, σ_t^2 = 39.5701
# Epoch 31, Iteration 6: H_t = 4, G_t = -0.8744, σ_t^2 = 39.4757
# Epoch 31, Iteration 7: H_t = 7, G_t = 0.6455, σ_t^2 = 42.4847
# Epoch 31, Iteration 8: H_t = 17, G_t = 1.4766, σ_t^2 = 41.9058
# Epoch 31, Iteration 9: H_t = 4, G_t = 0.0536, σ_t^2 = 40.7247
# Epoch 31, Iteration 10: H_t = 4, G_t = -0.5830, σ_t^2 = 44.1045
# Epoch 31, Iteration 11: H_t = 13, G_t = 1.4358, σ_t^2 = 53.1422
# Epoch 31, Iteration 12: H_t = 8, G_t = 0.7179, σ_t^2 = 43.5755
# Epoch 31, Iteration 13: H_t = 9, G_t = 0.9102, σ_t^2 = 48.7543
# Epoch 31, Iteration 14: H_t = 4, G_t = -0.6982, σ_t^2 = 38.4611
# Epoch 31, Iteration 15: H_t = 8, G_t = 0.7685, σ_t^2 = 44.3388
# Epoch 31, Iteration 16: H_t = 10, G_t = 0.9318, σ_t^2 = 44.2712
# Epoch 31, Iteration 17: H_t = 17, G_t = 1.8098, σ_t^2 = 50.5928
# Epoch 31, Iteration 18: H_t = 8, G_t = 0.8063, σ_t^2 = 46.2482
# Epoch 31, Iteration 19: H_t = 12, G_t = 1.2854, σ_t^2 = 50.1556
# Epoch 31, Iteration 20: H_t = 5, G_t = 0.6550, σ_t^2 = 55.8102
# Epoch 31, Iteration 21: H_t = 21, G_t = 1.7992, σ_t^2 = 42.0368
# Epoch 31, Iteration 22: H_t = 37, G_t = 2.5904, σ_t^2 = 34.7476
#     Worker 0: Train Loss: 2.4163, Train Accuracy: 37.06%
#     Worker 1: Train Loss: 2.4116, Train Accuracy: 37.05%
#     Worker 2: Train Loss: 2.3826, Train Accuracy: 37.58%
#     Worker 3: Train Loss: 2.4083, Train Accuracy: 37.43%
# Epoch 31: Test Loss: 2.3456, Test Accuracy: 39.70%
# Total Computation Time: 763.77 seconds
# Total Communication Time: 0.53 seconds
# Epoch 32, Iteration 1: H_t = 39, G_t = 3.5474, σ_t^2 = 44.3663
# Epoch 32, Iteration 2: H_t = 4, G_t = -1.4729, σ_t^2 = 51.5214
# Epoch 32, Iteration 3: H_t = 4, G_t = 0.3548, σ_t^2 = 36.6958
# Epoch 32, Iteration 4: H_t = 54, G_t = 5.6101, σ_t^2 = 51.6748
# Epoch 32, Iteration 5: H_t = 4, G_t = -0.9571, σ_t^2 = 39.7969
# Epoch 32, Iteration 6: H_t = 4, G_t = -1.1597, σ_t^2 = 41.1819
# Epoch 32, Iteration 7: H_t = 4, G_t = -1.2785, σ_t^2 = 39.2209
# Epoch 32, Iteration 8: H_t = 59, G_t = 4.4884, σ_t^2 = 37.6371
# Epoch 32, Iteration 9: H_t = 4, G_t = -0.9236, σ_t^2 = 49.0488
#     Worker 0: Train Loss: 2.4421, Train Accuracy: 36.81%
#     Worker 1: Train Loss: 2.4382, Train Accuracy: 36.54%
#     Worker 2: Train Loss: 2.4307, Train Accuracy: 36.93%
#     Worker 3: Train Loss: 2.4384, Train Accuracy: 36.77%
# Epoch 32: Test Loss: 2.3180, Test Accuracy: 39.98%
# Total Computation Time: 788.25 seconds
# Total Communication Time: 0.54 seconds
# Epoch 33, Iteration 1: H_t = 4, G_t = 0.1162, σ_t^2 = 36.7738
# Epoch 33, Iteration 2: H_t = 53, G_t = 3.3617, σ_t^2 = 31.5236
# Epoch 33, Iteration 3: H_t = 4, G_t = -1.7175, σ_t^2 = 38.4811
# Epoch 33, Iteration 4: H_t = 19, G_t = 1.7763, σ_t^2 = 44.4274
# Epoch 33, Iteration 5: H_t = 16, G_t = 1.4148, σ_t^2 = 42.0316
# Epoch 33, Iteration 6: H_t = 4, G_t = -1.0726, σ_t^2 = 44.6648
# Epoch 33, Iteration 7: H_t = 4, G_t = -0.3512, σ_t^2 = 48.0588
# Epoch 33, Iteration 8: H_t = 25, G_t = 2.3893, σ_t^2 = 47.1936
# Epoch 33, Iteration 9: H_t = 4, G_t = -0.8552, σ_t^2 = 46.1055
# Epoch 33, Iteration 10: H_t = 4, G_t = -1.8793, σ_t^2 = 52.4223
# Epoch 33, Iteration 11: H_t = 4, G_t = -1.2517, σ_t^2 = 43.3330
# Epoch 33, Iteration 12: H_t = 7, G_t = 0.6669, σ_t^2 = 44.4390
# Epoch 33, Iteration 13: H_t = 37, G_t = 2.9336, σ_t^2 = 39.1002
# Epoch 33, Iteration 14: H_t = 4, G_t = 0.2339, σ_t^2 = 38.9099
# Epoch 33, Iteration 15: H_t = 4, G_t = -0.8412, σ_t^2 = 42.8478
# Epoch 33, Iteration 16: H_t = 47, G_t = 3.4451, σ_t^2 = 36.5340
#     Worker 0: Train Loss: 2.3776, Train Accuracy: 37.78%
#     Worker 1: Train Loss: 2.3902, Train Accuracy: 38.24%
#     Worker 2: Train Loss: 2.3585, Train Accuracy: 38.71%
#     Worker 3: Train Loss: 2.3895, Train Accuracy: 37.54%
# Epoch 33: Test Loss: 2.2942, Test Accuracy: 40.22%
# Total Computation Time: 811.43 seconds
# Total Communication Time: 0.56 seconds
# Epoch 34, Iteration 1: H_t = 4, G_t = 0.0653, σ_t^2 = 40.1616
# Epoch 34, Iteration 2: H_t = 4, G_t = -1.1882, σ_t^2 = 37.8862
# Epoch 34, Iteration 3: H_t = 17, G_t = 1.5977, σ_t^2 = 45.6874
# Epoch 34, Iteration 4: H_t = 4, G_t = -0.5360, σ_t^2 = 49.1943
# Epoch 34, Iteration 5: H_t = 4, G_t = -0.9727, σ_t^2 = 45.9545
# Epoch 34, Iteration 6: H_t = 57, G_t = 4.7270, σ_t^2 = 41.2215
# Epoch 34, Iteration 7: H_t = 4, G_t = -0.1356, σ_t^2 = 39.8520
# Epoch 34, Iteration 8: H_t = 7, G_t = 0.4935, σ_t^2 = 33.7845
# Epoch 34, Iteration 9: H_t = 30, G_t = 2.5334, σ_t^2 = 41.3015
# Epoch 34, Iteration 10: H_t = 4, G_t = 0.1870, σ_t^2 = 40.7580
# Epoch 34, Iteration 11: H_t = 16, G_t = 1.5160, σ_t^2 = 47.1643
# Epoch 34, Iteration 12: H_t = 47, G_t = 4.0569, σ_t^2 = 42.3148
#     Worker 0: Train Loss: 2.3732, Train Accuracy: 38.45%
#     Worker 1: Train Loss: 2.3745, Train Accuracy: 38.29%
#     Worker 2: Train Loss: 2.3461, Train Accuracy: 38.64%
#     Worker 3: Train Loss: 2.3766, Train Accuracy: 37.66%
# Epoch 34: Test Loss: 2.2771, Test Accuracy: 40.92%
# Total Computation Time: 834.67 seconds
# Total Communication Time: 0.57 seconds
# Epoch 35, Iteration 1: H_t = 4, G_t = -0.3908, σ_t^2 = 37.7053
# Epoch 35, Iteration 2: H_t = 14, G_t = 1.2010, σ_t^2 = 42.6039
# Epoch 35, Iteration 3: H_t = 4, G_t = -0.3261, σ_t^2 = 47.2240
# Epoch 35, Iteration 4: H_t = 4, G_t = -1.2450, σ_t^2 = 43.6918
# Epoch 35, Iteration 5: H_t = 4, G_t = 0.2301, σ_t^2 = 48.7652
# Epoch 35, Iteration 6: H_t = 5, G_t = 0.4337, σ_t^2 = 36.8438
# Epoch 35, Iteration 7: H_t = 4, G_t = -0.8873, σ_t^2 = 48.0454
# Epoch 35, Iteration 8: H_t = 41, G_t = 3.5800, σ_t^2 = 43.5881
# Epoch 35, Iteration 9: H_t = 7, G_t = 0.6328, σ_t^2 = 43.5380
# Epoch 35, Iteration 10: H_t = 4, G_t = -1.1948, σ_t^2 = 44.1084
# Epoch 35, Iteration 11: H_t = 64, G_t = 7.4011, σ_t^2 = 36.5953
# Epoch 35, Iteration 12: H_t = 4, G_t = -0.9931, σ_t^2 = 42.2260
#     Worker 0: Train Loss: 2.3570, Train Accuracy: 38.51%
#     Worker 1: Train Loss: 2.3786, Train Accuracy: 37.92%
#     Worker 2: Train Loss: 2.3405, Train Accuracy: 39.43%
#     Worker 3: Train Loss: 2.3605, Train Accuracy: 38.33%
# Epoch 35: Test Loss: 2.2558, Test Accuracy: 41.27%
# Total Computation Time: 858.49 seconds
# Total Communication Time: 0.59 seconds
# Epoch 36, Iteration 1: H_t = 5, G_t = 0.4570, σ_t^2 = 42.8253
# Epoch 36, Iteration 2: H_t = 10, G_t = 0.7550, σ_t^2 = 37.1344
# Epoch 36, Iteration 3: H_t = 8, G_t = 0.7735, σ_t^2 = 46.1924
# Epoch 36, Iteration 4: H_t = 4, G_t = -2.2430, σ_t^2 = 52.4231
# Epoch 36, Iteration 5: H_t = 17, G_t = 1.5129, σ_t^2 = 42.6921
# Epoch 36, Iteration 6: H_t = 19, G_t = 1.7190, σ_t^2 = 43.1867
# Epoch 36, Iteration 7: H_t = 4, G_t = -0.0115, σ_t^2 = 47.9325
# Epoch 36, Iteration 8: H_t = 4, G_t = 0.2339, σ_t^2 = 41.2927
# Epoch 36, Iteration 9: H_t = 37, G_t = 3.0882, σ_t^2 = 41.5482
# Epoch 36, Iteration 10: H_t = 4, G_t = -1.5987, σ_t^2 = 45.5271
# Epoch 36, Iteration 11: H_t = 4, G_t = 0.3645, σ_t^2 = 40.9598
# Epoch 36, Iteration 12: H_t = 25, G_t = 1.8097, σ_t^2 = 35.4525
# Epoch 36, Iteration 13: H_t = 4, G_t = -0.4559, σ_t^2 = 43.9406
# Epoch 36, Iteration 14: H_t = 4, G_t = -0.2742, σ_t^2 = 44.9666
# Epoch 36, Iteration 15: H_t = 4, G_t = -0.3331, σ_t^2 = 36.9807
# Epoch 36, Iteration 16: H_t = 4, G_t = 0.4598, σ_t^2 = 49.0570
# Epoch 36, Iteration 17: H_t = 31, G_t = 2.4622, σ_t^2 = 39.2817
# Epoch 36, Iteration 18: H_t = 4, G_t = -0.5496, σ_t^2 = 42.4399
# Epoch 36, Iteration 19: H_t = 5, G_t = 0.4461, σ_t^2 = 37.9621
#     Worker 0: Train Loss: 2.2895, Train Accuracy: 39.74%
#     Worker 1: Train Loss: 2.3159, Train Accuracy: 39.31%
#     Worker 2: Train Loss: 2.2834, Train Accuracy: 39.80%
#     Worker 3: Train Loss: 2.3024, Train Accuracy: 39.40%
# Epoch 36: Test Loss: 2.2364, Test Accuracy: 41.65%
# Total Computation Time: 881.50 seconds
# Total Communication Time: 0.61 seconds
# Epoch 37, Iteration 1: H_t = 4, G_t = -0.4845, σ_t^2 = 47.6923
# Epoch 37, Iteration 2: H_t = 4, G_t = -2.2795, σ_t^2 = 52.2231
# Epoch 37, Iteration 3: H_t = 38, G_t = 3.0653, σ_t^2 = 39.6275
# Epoch 37, Iteration 4: H_t = 4, G_t = -1.2800, σ_t^2 = 45.3519
# Epoch 37, Iteration 5: H_t = 12, G_t = 1.0953, σ_t^2 = 45.3567
# Epoch 37, Iteration 6: H_t = 18, G_t = 1.4938, σ_t^2 = 41.1742
# Epoch 37, Iteration 7: H_t = 4, G_t = -1.5864, σ_t^2 = 49.1294
# Epoch 37, Iteration 8: H_t = 8, G_t = 0.7127, σ_t^2 = 42.4574
# Epoch 37, Iteration 9: H_t = 4, G_t = -0.4364, σ_t^2 = 43.8611
# Epoch 37, Iteration 10: H_t = 4, G_t = -0.5102, σ_t^2 = 45.1067
# Epoch 37, Iteration 11: H_t = 4, G_t = -1.0061, σ_t^2 = 47.3432
# Epoch 37, Iteration 12: H_t = 4, G_t = 0.3657, σ_t^2 = 46.6378
# Epoch 37, Iteration 13: H_t = 5, G_t = 0.5793, σ_t^2 = 52.2536
# Epoch 37, Iteration 14: H_t = 50, G_t = 4.4314, σ_t^2 = 44.1360
# Epoch 37, Iteration 15: H_t = 18, G_t = 1.4389, σ_t^2 = 39.3785
# Epoch 37, Iteration 16: H_t = 35, G_t = 3.4162, σ_t^2 = 48.7639
# Epoch 37, Iteration 17: H_t = 4, G_t = -0.4310, σ_t^2 = 53.0187
#     Worker 0: Train Loss: 2.2909, Train Accuracy: 39.72%
#     Worker 1: Train Loss: 2.2835, Train Accuracy: 40.39%
#     Worker 2: Train Loss: 2.2557, Train Accuracy: 41.06%
#     Worker 3: Train Loss: 2.3056, Train Accuracy: 39.84%
# Epoch 37: Test Loss: 2.2729, Test Accuracy: 40.86%
# Total Computation Time: 907.57 seconds
# Total Communication Time: 0.63 seconds
# Epoch 38, Iteration 1: H_t = 11, G_t = 1.0033, σ_t^2 = 42.3936
# Epoch 38, Iteration 2: H_t = 4, G_t = -1.0022, σ_t^2 = 53.1210
# Epoch 38, Iteration 3: H_t = 5, G_t = 0.4701, σ_t^2 = 45.8102
# Epoch 38, Iteration 4: H_t = 43, G_t = 3.6192, σ_t^2 = 41.6683
# Epoch 38, Iteration 5: H_t = 4, G_t = -0.5866, σ_t^2 = 61.8457
# Epoch 38, Iteration 6: H_t = 8, G_t = 0.6296, σ_t^2 = 39.1001
# Epoch 38, Iteration 7: H_t = 4, G_t = 0.3498, σ_t^2 = 45.1251
# Epoch 38, Iteration 8: H_t = 4, G_t = -0.4557, σ_t^2 = 39.9098
# Epoch 38, Iteration 9: H_t = 4, G_t = -0.2811, σ_t^2 = 41.6778
# Epoch 38, Iteration 10: H_t = 40, G_t = 3.8488, σ_t^2 = 47.0386
# ...
# Epoch 144, Iteration 26: H_t = 4, G_t = -1.3191, σ_t^2 = 105.9083
# Epoch 144, Iteration 27: H_t = 11, G_t = 2.3481, σ_t^2 = 105.4892
# Epoch 144, Iteration 28: H_t = 4, G_t = -2.4814, σ_t^2 = 107.7675
# Epoch 144, Iteration 29: H_t = 4, G_t = -1.4435, σ_t^2 = 118.5452
# Epoch 144, Iteration 30: H_t = 4, G_t = -2.7080, σ_t^2 = 124.9831
# Epoch 144, Iteration 31: H_t = 4, G_t = 0.2507, σ_t^2 = 94.9248
# Epoch 144, Iteration 32: H_t = 4, G_t = -2.1442, σ_t^2 = 107.8856
# Epoch 144, Iteration 33: H_t = 4, G_t = 1.2139, σ_t^2 = 129.1114
# Epoch 144, Iteration 34: H_t = 4, G_t = 0.2042, σ_t^2 = 118.6280
# Epoch 144, Iteration 35: H_t = 4, G_t = -1.9625, σ_t^2 = 91.5668
# Epoch 144, Iteration 36: H_t = 4, G_t = 0.3797, σ_t^2 = 106.2587
# Epoch 144, Iteration 37: H_t = 4, G_t = -0.9198, σ_t^2 = 100.5077
# Epoch 144, Iteration 38: H_t = 4, G_t = -0.4843, σ_t^2 = 98.1707
# Epoch 144, Iteration 39: H_t = 4, G_t = 0.5626, σ_t^2 = 115.2758
# Epoch 144, Iteration 40: H_t = 4, G_t = -0.5286, σ_t^2 = 115.1673
# Epoch 144, Iteration 41: H_t = 4, G_t = -1.6576, σ_t^2 = 104.3811
# Epoch 144, Iteration 42: H_t = 4, G_t = -0.9125, σ_t^2 = 95.3574
# Epoch 144, Iteration 43: H_t = 4, G_t = -1.5476, σ_t^2 = 113.7837
# Epoch 144, Iteration 44: H_t = 4, G_t = -1.5016, σ_t^2 = 102.8411
# Epoch 144, Iteration 45: H_t = 4, G_t = -2.5201, σ_t^2 = 98.3987
# Epoch 144, Iteration 46: H_t = 4, G_t = -1.5661, σ_t^2 = 101.2090
#     Worker 0: Train Loss: 1.2402, Train Accuracy: 64.48%
#     Worker 1: Train Loss: 1.2240, Train Accuracy: 65.53%
#     Worker 2: Train Loss: 1.2147, Train Accuracy: 65.97%
#     Worker 3: Train Loss: 1.2460, Train Accuracy: 65.15%
# Epoch 144: Test Loss: 1.9585, Test Accuracy: 51.29%
# Total Computation Time: 3439.24 seconds
# Total Communication Time: 3.53 seconds
# Epoch 145, Iteration 1: H_t = 4, G_t = -2.7781, σ_t^2 = 124.4533
# Epoch 145, Iteration 2: H_t = 4, G_t = 0.5050, σ_t^2 = 106.2838
# Epoch 145, Iteration 3: H_t = 9, G_t = 2.1625, σ_t^2 = 108.1561
# Epoch 145, Iteration 4: H_t = 5, G_t = 1.1766, σ_t^2 = 112.7377
# Epoch 145, Iteration 5: H_t = 4, G_t = -1.6738, σ_t^2 = 108.3704
# Epoch 145, Iteration 6: H_t = 22, G_t = 4.3813, σ_t^2 = 98.3477
# Epoch 145, Iteration 7: H_t = 4, G_t = -0.7976, σ_t^2 = 120.0589
# Epoch 145, Iteration 8: H_t = 4, G_t = -1.1756, σ_t^2 = 110.9652
# Epoch 145, Iteration 9: H_t = 4, G_t = -1.4469, σ_t^2 = 120.2360
# Epoch 145, Iteration 10: H_t = 9, G_t = 1.8844, σ_t^2 = 98.5195
# Epoch 145, Iteration 11: H_t = 4, G_t = 0.9089, σ_t^2 = 111.1893
# Epoch 145, Iteration 12: H_t = 4, G_t = -1.7799, σ_t^2 = 97.6940
# Epoch 145, Iteration 13: H_t = 10, G_t = 2.3398, σ_t^2 = 109.8898
# Epoch 145, Iteration 14: H_t = 4, G_t = 0.6598, σ_t^2 = 102.9044
# Epoch 145, Iteration 15: H_t = 18, G_t = 4.1310, σ_t^2 = 111.2952
# Epoch 145, Iteration 16: H_t = 4, G_t = -1.1367, σ_t^2 = 114.9281
# Epoch 145, Iteration 17: H_t = 6, G_t = 1.4197, σ_t^2 = 105.8844
# Epoch 145, Iteration 18: H_t = 4, G_t = 0.1091, σ_t^2 = 106.3142
# Epoch 145, Iteration 19: H_t = 4, G_t = 0.4498, σ_t^2 = 101.1759
# Epoch 145, Iteration 20: H_t = 4, G_t = -1.5470, σ_t^2 = 98.7756
# Epoch 145, Iteration 21: H_t = 7, G_t = 1.6650, σ_t^2 = 108.3335
# Epoch 145, Iteration 22: H_t = 15, G_t = 3.3789, σ_t^2 = 110.0489
# Epoch 145, Iteration 23: H_t = 4, G_t = -2.5717, σ_t^2 = 106.4397
# Epoch 145, Iteration 24: H_t = 4, G_t = -1.0125, σ_t^2 = 102.0821
# Epoch 145, Iteration 25: H_t = 7, G_t = 1.4744, σ_t^2 = 103.8854
# Epoch 145, Iteration 26: H_t = 4, G_t = -2.1603, σ_t^2 = 137.6710
# Epoch 145, Iteration 27: H_t = 4, G_t = -2.4779, σ_t^2 = 120.1485
# Epoch 145, Iteration 28: H_t = 4, G_t = -0.8080, σ_t^2 = 110.0079
# Epoch 145, Iteration 29: H_t = 4, G_t = 0.6673, σ_t^2 = 104.5824
# Epoch 145, Iteration 30: H_t = 4, G_t = -0.9790, σ_t^2 = 111.0187
# Epoch 145, Iteration 31: H_t = 4, G_t = -1.2466, σ_t^2 = 95.7831
# Epoch 145, Iteration 32: H_t = 4, G_t = 0.6835, σ_t^2 = 92.7508
#     Worker 0: Train Loss: 1.2287, Train Accuracy: 65.36%
#     Worker 1: Train Loss: 1.2302, Train Accuracy: 65.54%
#     Worker 2: Train Loss: 1.2252, Train Accuracy: 65.62%
#     Worker 3: Train Loss: 1.2499, Train Accuracy: 64.80%
# Epoch 145: Test Loss: 1.9583, Test Accuracy: 51.31%
# Total Computation Time: 3461.91 seconds
# Total Communication Time: 3.57 seconds
# Epoch 146, Iteration 1: H_t = 4, G_t = -1.1741, σ_t^2 = 100.5910
# Epoch 146, Iteration 2: H_t = 21, G_t = 4.1196, σ_t^2 = 95.7149
# Epoch 146, Iteration 3: H_t = 11, G_t = 2.2576, σ_t^2 = 95.8808
# Epoch 146, Iteration 4: H_t = 4, G_t = -0.8614, σ_t^2 = 109.3809
# Epoch 146, Iteration 5: H_t = 11, G_t = 2.3788, σ_t^2 = 99.2422
# Epoch 146, Iteration 6: H_t = 4, G_t = -0.6253, σ_t^2 = 107.7104
# Epoch 146, Iteration 7: H_t = 9, G_t = 1.7009, σ_t^2 = 86.8971
# Epoch 146, Iteration 8: H_t = 13, G_t = 2.5768, σ_t^2 = 93.4650
# Epoch 146, Iteration 9: H_t = 4, G_t = -0.2805, σ_t^2 = 99.1665
# Epoch 146, Iteration 10: H_t = 4, G_t = -0.8211, σ_t^2 = 108.7146
# Epoch 146, Iteration 11: H_t = 5, G_t = 1.1526, σ_t^2 = 98.0000
# Epoch 146, Iteration 12: H_t = 5, G_t = 1.1357, σ_t^2 = 103.0891
# Epoch 146, Iteration 13: H_t = 4, G_t = 0.7747, σ_t^2 = 118.4308
# Epoch 146, Iteration 14: H_t = 4, G_t = -4.2378, σ_t^2 = 123.3416
# Epoch 146, Iteration 15: H_t = 18, G_t = 4.1184, σ_t^2 = 111.9599
# Epoch 146, Iteration 16: H_t = 4, G_t = -1.0205, σ_t^2 = 105.4031
# Epoch 146, Iteration 17: H_t = 4, G_t = -4.6493, σ_t^2 = 126.4946
# Epoch 146, Iteration 18: H_t = 21, G_t = 4.2189, σ_t^2 = 97.5590
# Epoch 146, Iteration 19: H_t = 4, G_t = -1.3949, σ_t^2 = 111.5648
# Epoch 146, Iteration 20: H_t = 4, G_t = -1.4357, σ_t^2 = 116.5354
# Epoch 146, Iteration 21: H_t = 4, G_t = 0.7287, σ_t^2 = 106.9801
# Epoch 146, Iteration 22: H_t = 11, G_t = 2.3418, σ_t^2 = 103.3926
# Epoch 146, Iteration 23: H_t = 6, G_t = 1.3717, σ_t^2 = 109.8216
# Epoch 146, Iteration 24: H_t = 4, G_t = -1.5070, σ_t^2 = 102.4966
# Epoch 146, Iteration 25: H_t = 4, G_t = -2.2261, σ_t^2 = 101.1801
# Epoch 146, Iteration 26: H_t = 4, G_t = -0.3083, σ_t^2 = 115.6567
# Epoch 146, Iteration 27: H_t = 4, G_t = -0.9121, σ_t^2 = 95.3281
# Epoch 146, Iteration 28: H_t = 4, G_t = 0.9155, σ_t^2 = 106.4965
#     Worker 0: Train Loss: 1.2491, Train Accuracy: 64.99%
#     Worker 1: Train Loss: 1.2391, Train Accuracy: 65.06%
#     Worker 2: Train Loss: 1.2284, Train Accuracy: 65.77%
#     Worker 3: Train Loss: 1.2279, Train Accuracy: 66.00%
# Epoch 146: Test Loss: 1.9582, Test Accuracy: 51.14%
# Total Computation Time: 3484.81 seconds
# Total Communication Time: 3.60 seconds
# Epoch 147, Iteration 1: H_t = 16, G_t = 3.1717, σ_t^2 = 93.3418
# Epoch 147, Iteration 2: H_t = 4, G_t = 0.2755, σ_t^2 = 112.0848
# Epoch 147, Iteration 3: H_t = 26, G_t = 6.6717, σ_t^2 = 125.1002
# Epoch 147, Iteration 4: H_t = 4, G_t = 0.0357, σ_t^2 = 113.3432
# Epoch 147, Iteration 5: H_t = 4, G_t = -3.9788, σ_t^2 = 110.8605
# Epoch 147, Iteration 6: H_t = 27, G_t = 6.4958, σ_t^2 = 117.8941
# Epoch 147, Iteration 7: H_t = 21, G_t = 4.6879, σ_t^2 = 106.8330
# Epoch 147, Iteration 8: H_t = 13, G_t = 3.0653, σ_t^2 = 113.6715
# Epoch 147, Iteration 9: H_t = 8, G_t = 1.8522, σ_t^2 = 104.3868
# Epoch 147, Iteration 10: H_t = 4, G_t = 0.1740, σ_t^2 = 107.4116
# Epoch 147, Iteration 11: H_t = 4, G_t = -2.0671, σ_t^2 = 108.4147
# Epoch 147, Iteration 12: H_t = 4, G_t = 0.0906, σ_t^2 = 109.0133
# Epoch 147, Iteration 13: H_t = 4, G_t = -1.0085, σ_t^2 = 109.5053
# Epoch 147, Iteration 14: H_t = 10, G_t = 2.0525, σ_t^2 = 99.1385
# Epoch 147, Iteration 15: H_t = 4, G_t = -2.6666, σ_t^2 = 124.8334
# Epoch 147, Iteration 16: H_t = 4, G_t = -1.1804, σ_t^2 = 108.9898
# Epoch 147, Iteration 17: H_t = 4, G_t = -1.3870, σ_t^2 = 96.4187
# Epoch 147, Iteration 18: H_t = 4, G_t = -1.3625, σ_t^2 = 120.9685
# Epoch 147, Iteration 19: H_t = 4, G_t = -1.9493, σ_t^2 = 102.6325
# Epoch 147, Iteration 20: H_t = 4, G_t = -0.4279, σ_t^2 = 101.3182
# Epoch 147, Iteration 21: H_t = 4, G_t = -2.6846, σ_t^2 = 97.9577
# Epoch 147, Iteration 22: H_t = 24, G_t = 5.1553, σ_t^2 = 106.4369
# Epoch 147, Iteration 23: H_t = 4, G_t = -1.6370, σ_t^2 = 118.1421
#     Worker 0: Train Loss: 1.2365, Train Accuracy: 64.25%
#     Worker 1: Train Loss: 1.2327, Train Accuracy: 65.43%
#     Worker 2: Train Loss: 1.2318, Train Accuracy: 65.63%
#     Worker 3: Train Loss: 1.2507, Train Accuracy: 64.85%
# Epoch 147: Test Loss: 1.9583, Test Accuracy: 51.25%
# Total Computation Time: 3508.51 seconds
# Total Communication Time: 3.62 seconds
# Epoch 148, Iteration 1: H_t = 4, G_t = 0.2862, σ_t^2 = 103.4450
# Epoch 148, Iteration 2: H_t = 4, G_t = -2.2377, σ_t^2 = 110.1842
# Epoch 148, Iteration 3: H_t = 4, G_t = 0.5282, σ_t^2 = 101.3858
# Epoch 148, Iteration 4: H_t = 7, G_t = 1.5412, σ_t^2 = 96.6272
# Epoch 148, Iteration 5: H_t = 4, G_t = -4.2285, σ_t^2 = 108.7609
# Epoch 148, Iteration 6: H_t = 4, G_t = -1.0068, σ_t^2 = 102.7962
# Epoch 148, Iteration 7: H_t = 4, G_t = -0.5809, σ_t^2 = 104.0476
# Epoch 148, Iteration 8: H_t = 4, G_t = 0.3124, σ_t^2 = 90.7009
# Epoch 148, Iteration 9: H_t = 17, G_t = 3.3336, σ_t^2 = 94.2377
# Epoch 148, Iteration 10: H_t = 4, G_t = -1.2150, σ_t^2 = 112.8056
# Epoch 148, Iteration 11: H_t = 4, G_t = -0.0987, σ_t^2 = 113.9658
# Epoch 148, Iteration 12: H_t = 4, G_t = -3.2394, σ_t^2 = 101.5733
# Epoch 148, Iteration 13: H_t = 4, G_t = 0.1711, σ_t^2 = 92.4565
# Epoch 148, Iteration 14: H_t = 4, G_t = -1.2625, σ_t^2 = 105.5028
# Epoch 148, Iteration 15: H_t = 6, G_t = 1.5946, σ_t^2 = 125.1397
# Epoch 148, Iteration 16: H_t = 4, G_t = 0.3248, σ_t^2 = 100.4983
# Epoch 148, Iteration 17: H_t = 4, G_t = -1.7796, σ_t^2 = 104.4646
# Epoch 148, Iteration 18: H_t = 4, G_t = -1.1031, σ_t^2 = 113.6861
# Epoch 148, Iteration 19: H_t = 12, G_t = 2.9067, σ_t^2 = 120.1826
# Epoch 148, Iteration 20: H_t = 4, G_t = -3.4633, σ_t^2 = 112.2804
# Epoch 148, Iteration 21: H_t = 4, G_t = -2.4305, σ_t^2 = 105.2209
# Epoch 148, Iteration 22: H_t = 8, G_t = 1.9871, σ_t^2 = 113.1493
# Epoch 148, Iteration 23: H_t = 4, G_t = -2.2074, σ_t^2 = 105.1531
# Epoch 148, Iteration 24: H_t = 5, G_t = 1.2588, σ_t^2 = 108.4391
# Epoch 148, Iteration 25: H_t = 4, G_t = -0.0070, σ_t^2 = 102.1522
# Epoch 148, Iteration 26: H_t = 4, G_t = -3.4467, σ_t^2 = 122.4719
# Epoch 148, Iteration 27: H_t = 4, G_t = 0.1481, σ_t^2 = 88.4935
# Epoch 148, Iteration 28: H_t = 4, G_t = -2.5663, σ_t^2 = 121.7473
# Epoch 148, Iteration 29: H_t = 4, G_t = -2.6899, σ_t^2 = 111.8671
# Epoch 148, Iteration 30: H_t = 4, G_t = 0.9385, σ_t^2 = 96.4099
# Epoch 148, Iteration 31: H_t = 4, G_t = -0.7006, σ_t^2 = 98.1046
# Epoch 148, Iteration 32: H_t = 4, G_t = -1.8653, σ_t^2 = 101.5096
# Epoch 148, Iteration 33: H_t = 4, G_t = -2.2114, σ_t^2 = 116.3448
# Epoch 148, Iteration 34: H_t = 5, G_t = 1.3337, σ_t^2 = 115.4233
# Epoch 148, Iteration 35: H_t = 7, G_t = 1.4758, σ_t^2 = 103.2069
# Epoch 148, Iteration 36: H_t = 4, G_t = 0.0610, σ_t^2 = 108.0006
# Epoch 148, Iteration 37: H_t = 16, G_t = 3.3052, σ_t^2 = 101.3943
# Epoch 148, Iteration 38: H_t = 11, G_t = 2.3229, σ_t^2 = 104.6606
#     Worker 0: Train Loss: 1.2420, Train Accuracy: 64.43%
#     Worker 1: Train Loss: 1.2313, Train Accuracy: 65.88%
#     Worker 2: Train Loss: 1.2251, Train Accuracy: 65.49%
#     Worker 3: Train Loss: 1.2329, Train Accuracy: 65.54%
# Epoch 148: Test Loss: 1.9584, Test Accuracy: 51.23%
# Total Computation Time: 3531.46 seconds
# Total Communication Time: 3.67 seconds
# Epoch 149, Iteration 1: H_t = 4, G_t = -0.0397, σ_t^2 = 104.0682
# Epoch 149, Iteration 2: H_t = 4, G_t = 1.0561, σ_t^2 = 109.1378
# Epoch 149, Iteration 3: H_t = 6, G_t = 1.3970, σ_t^2 = 113.3352
# Epoch 149, Iteration 4: H_t = 4, G_t = -0.1599, σ_t^2 = 108.7035
# Epoch 149, Iteration 5: H_t = 4, G_t = -2.4176, σ_t^2 = 100.9568
# Epoch 149, Iteration 6: H_t = 27, G_t = 5.5578, σ_t^2 = 100.8393
# Epoch 149, Iteration 7: H_t = 4, G_t = -2.0801, σ_t^2 = 114.2204
# Epoch 149, Iteration 8: H_t = 5, G_t = 1.1174, σ_t^2 = 95.6452
# Epoch 149, Iteration 9: H_t = 4, G_t = 0.4597, σ_t^2 = 101.6158
# Epoch 149, Iteration 10: H_t = 11, G_t = 2.2168, σ_t^2 = 100.6780
# Epoch 149, Iteration 11: H_t = 4, G_t = -1.2838, σ_t^2 = 95.8329
# Epoch 149, Iteration 12: H_t = 4, G_t = 0.2973, σ_t^2 = 107.5539
# Epoch 149, Iteration 13: H_t = 4, G_t = -4.3777, σ_t^2 = 122.1894
# Epoch 149, Iteration 14: H_t = 4, G_t = 0.6186, σ_t^2 = 106.5384
# Epoch 149, Iteration 15: H_t = 4, G_t = -1.7345, σ_t^2 = 112.1918
# Epoch 149, Iteration 16: H_t = 10, G_t = 2.4804, σ_t^2 = 116.6158
# Epoch 149, Iteration 17: H_t = 4, G_t = -1.5995, σ_t^2 = 110.8559
# Epoch 149, Iteration 18: H_t = 4, G_t = -1.8009, σ_t^2 = 104.5704
# Epoch 149, Iteration 19: H_t = 4, G_t = 0.9838, σ_t^2 = 112.4883
# Epoch 149, Iteration 20: H_t = 7, G_t = 1.5306, σ_t^2 = 104.1029
# Epoch 149, Iteration 21: H_t = 4, G_t = 0.0753, σ_t^2 = 97.3077
# Epoch 149, Iteration 22: H_t = 4, G_t = -3.5469, σ_t^2 = 100.4614
# Epoch 149, Iteration 23: H_t = 4, G_t = -1.6927, σ_t^2 = 128.5719
# Epoch 149, Iteration 24: H_t = 6, G_t = 1.3328, σ_t^2 = 103.1952
# Epoch 149, Iteration 25: H_t = 4, G_t = 0.4342, σ_t^2 = 110.2167
# Epoch 149, Iteration 26: H_t = 4, G_t = -1.5857, σ_t^2 = 107.5313
# Epoch 149, Iteration 27: H_t = 4, G_t = -1.7534, σ_t^2 = 88.9043
# Epoch 149, Iteration 28: H_t = 4, G_t = -0.4937, σ_t^2 = 117.4585
# Epoch 149, Iteration 29: H_t = 4, G_t = -0.7558, σ_t^2 = 110.6525
# Epoch 149, Iteration 30: H_t = 5, G_t = 1.2880, σ_t^2 = 108.3355
# Epoch 149, Iteration 31: H_t = 7, G_t = 1.5883, σ_t^2 = 101.1313
# Epoch 149, Iteration 32: H_t = 4, G_t = -0.7223, σ_t^2 = 91.9105
# Epoch 149, Iteration 33: H_t = 4, G_t = 1.0641, σ_t^2 = 106.6944
# Epoch 149, Iteration 34: H_t = 4, G_t = -2.2104, σ_t^2 = 108.4217
# Epoch 149, Iteration 35: H_t = 5, G_t = 1.2206, σ_t^2 = 103.6821
# Epoch 149, Iteration 36: H_t = 4, G_t = 0.1241, σ_t^2 = 108.9007
#     Worker 0: Train Loss: 1.2388, Train Accuracy: 64.73%
#     Worker 1: Train Loss: 1.2384, Train Accuracy: 65.27%
#     Worker 2: Train Loss: 1.2186, Train Accuracy: 65.49%
#     Worker 3: Train Loss: 1.2396, Train Accuracy: 65.25%
# Epoch 149: Test Loss: 1.9584, Test Accuracy: 51.27%
# Total Computation Time: 3554.74 seconds
# Total Communication Time: 3.71 seconds
# Epoch 150, Iteration 1: H_t = 4, G_t = -3.4043, σ_t^2 = 122.5386
# Epoch 150, Iteration 2: H_t = 14, G_t = 2.8756, σ_t^2 = 99.1927
# Epoch 150, Iteration 3: H_t = 4, G_t = -3.3843, σ_t^2 = 103.0353
# Epoch 150, Iteration 4: H_t = 14, G_t = 3.0079, σ_t^2 = 105.8348
# Epoch 150, Iteration 5: H_t = 4, G_t = -0.2080, σ_t^2 = 91.5557
# Epoch 150, Iteration 6: H_t = 4, G_t = -1.7868, σ_t^2 = 93.9571
# Epoch 150, Iteration 7: H_t = 4, G_t = -0.5996, σ_t^2 = 108.7159
# Epoch 150, Iteration 8: H_t = 4, G_t = -0.1197, σ_t^2 = 101.4089
# Epoch 150, Iteration 9: H_t = 4, G_t = -0.7530, σ_t^2 = 100.7726
# Epoch 150, Iteration 10: H_t = 4, G_t = 0.5653, σ_t^2 = 100.1902
# Epoch 150, Iteration 11: H_t = 4, G_t = -0.0442, σ_t^2 = 110.0441
# Epoch 150, Iteration 12: H_t = 4, G_t = -0.7504, σ_t^2 = 118.3904
# Epoch 150, Iteration 13: H_t = 4, G_t = -1.3636, σ_t^2 = 108.1497
# Epoch 150, Iteration 14: H_t = 20, G_t = 3.8716, σ_t^2 = 95.3711
# Epoch 150, Iteration 15: H_t = 4, G_t = 0.4258, σ_t^2 = 119.3040
# Epoch 150, Iteration 16: H_t = 4, G_t = -0.7702, σ_t^2 = 112.2753
# Epoch 150, Iteration 17: H_t = 10, G_t = 1.9808, σ_t^2 = 91.4265
# Epoch 150, Iteration 18: H_t = 4, G_t = -1.4835, σ_t^2 = 110.8064
# Epoch 150, Iteration 19: H_t = 15, G_t = 3.0446, σ_t^2 = 96.6662
# Epoch 150, Iteration 20: H_t = 16, G_t = 3.4403, σ_t^2 = 106.6526
# Epoch 150, Iteration 21: H_t = 8, G_t = 1.9291, σ_t^2 = 108.5903
# Epoch 150, Iteration 22: H_t = 4, G_t = -2.1478, σ_t^2 = 100.4865
# Epoch 150, Iteration 23: H_t = 8, G_t = 1.7164, σ_t^2 = 100.7021
# Epoch 150, Iteration 24: H_t = 4, G_t = -0.4554, σ_t^2 = 105.2853
# Epoch 150, Iteration 25: H_t = 8, G_t = 1.8249, σ_t^2 = 110.7374
# Epoch 150, Iteration 26: H_t = 4, G_t = -2.1763, σ_t^2 = 105.9656
# Epoch 150, Iteration 27: H_t = 14, G_t = 2.7782, σ_t^2 = 97.3347
# Epoch 150, Iteration 28: H_t = 4, G_t = -0.4308, σ_t^2 = 110.5173
#     Worker 0: Train Loss: 1.2284, Train Accuracy: 65.30%
#     Worker 1: Train Loss: 1.2177, Train Accuracy: 65.46%
#     Worker 2: Train Loss: 1.2125, Train Accuracy: 65.98%
#     Worker 3: Train Loss: 1.2340, Train Accuracy: 65.31%
# Epoch 150: Test Loss: 1.9584, Test Accuracy: 51.26%
# Total Computation Time: 3577.99 seconds
# Total Communication Time: 3.74 seconds
