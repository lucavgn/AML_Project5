# %%
# %%writefile localSGD.py

import os
import math
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import argparse
from torch.utils.data import random_split, Subset, DataLoader
from google.colab import files
import torch.nn.functional as F
import time

total_computation_time = 0
total_communication_time = 0

# Define hyperparameters
# K_values = [2, 4, 8]
# J_values = [4, 8, 16, 32, 64]
iteration_per_epoch = 782 # number of local step performed in one epoch
num_epochs = 150
batch_size = 64
base_learning_rate = 1e-3
momentum = 0.9
weight_decay = 4e-4
#warmup_epochs = 5

def compute_mean_std(dataset):
    # Extract images and labels
    data_r = np.stack([np.array(dataset[i][0])[:, :, 0] for i in range(len(dataset))])
    data_g = np.stack([np.array(dataset[i][0])[:, :, 1] for i in range(len(dataset))])
    data_b = np.stack([np.array(dataset[i][0])[:, :, 2] for i in range(len(dataset))])

    # Compute mean and std
    mean = np.mean(data_r), np.mean(data_g), np.mean(data_b)
    std = np.std(data_r), np.std(data_g), np.std(data_b)

    return mean, std


# Define LeNet-5 architecture
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 5)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 64, 5)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.relu3 = nn.ReLU()
        self.fc2 = nn.Linear(384, 192)
        self.relu4 = nn.ReLU()
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        x = x.view(-1, 64 * 5 * 5)
        x = self.relu3(self.fc1(x))
        x = self.relu4(self.fc2(x))
        x = self.fc3(x)
        return x

# Command-line arguments
parser = argparse.ArgumentParser(description='Train with Local SGD')
parser.add_argument('--k', type=int, default=2, help='choose a K value for local SGD: [2, 4, 8]')
parser.add_argument('--j', type=int, default=4, help='choose a J value for local SGD: [4, 8, 16, 32, 64]')
args = parser.parse_args()
K = args.k
J = args.j
print(f"Training with K={K}, J={J}")

#global_iteration_per_epoch = math.ceil(global_iteration_per_epoch / (K * J)) * (K * J)
#global_iteration_per_epoch = global_iteration_per_epoch // (K * J)
#print(f"Global iteration per epoch: {global_iteration_per_epoch}")


# Device setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

torch.manual_seed(42) # Set the seed for reproducibility
torch.cuda.manual_seed_all(42) # Set the seed for reproducibility on GPU

# use the same mean and std to add consistency to all datasets
data = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transforms.ToTensor())
mean, std = compute_mean_std(data)

# Load and split CIFAR-100 dataset
train_transform = transforms.Compose([
  transforms.RandomCrop(32, padding=4),
  transforms.RandomHorizontalFlip(),
  transforms.ToTensor(),
  transforms.Normalize(mean, std)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to PyTorch tensor
    transforms.Normalize(mean, std)
])

trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=train_transform)

# Shard the training set
shard_size = len(trainset) // K
shards = [Subset(trainset, range(i * shard_size, (i + 1) * shard_size)) for i in range(K)]
# After creating the DataLoader for each worker, create an iterator
shard_iterators = [iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True)) for k in range(K)]


# Test set
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# Scale the learning rate by k
learning_rate = base_learning_rate * K
print(f"Base learning rate: {learning_rate:.5f}")

# Initialize local models, optimizers and scheduler
nets = [LeNet5().to(device) for _ in range(K)]

with torch.no_grad():
    for net in nets[1:]:  # Skip nets[0] because it's the reference model
        for param_target, param_source in zip(net.parameters(), nets[0].parameters()):
            param_target.data.copy_(param_source.data)

optimizers = [optim.SGD(net.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay) for net in nets]
schedulers = [optim.lr_scheduler.CosineAnnealingLR(optimizer=optimizer, T_max=num_epochs) for optimizer in optimizers]

criterion = nn.CrossEntropyLoss()

# Initialize storage for train losses and accuracies for each worker
train_losses_per_worker = [[] for _ in range(K)]
train_accuracies_per_worker = [[] for _ in range(K)]

# Initialize test losses and accuracies for test set
test_losses = []
test_accuracies = []

# Compute gradient magnitude and variance
def compute_gradient_stats(nets, optimizers):
    # Get gradients from each worker
    gradients = []
    for net, optimizer in zip(nets, optimizers):
        grad_vector = []
        for param in net.parameters():
            if param.grad is not None:
                grad_vector.append(param.grad.view(-1))
        grad_vector = torch.cat(grad_vector)  # Flatten all gradients into a vector
        gradients.append(grad_vector)

    # Compute average gradient (g_t)
    avg_gradient = torch.stack(gradients).mean(dim=0)

    # Compute squared norms of individual gradients
    squared_norms = [torch.norm(g).item() ** 2 for g in gradients]

    # Compute squared norm of the average gradient
    avg_squared_norm = torch.norm(avg_gradient).item() ** 2

    # Compute gradient variance (sigma_t^2) using the provided formula
    sigma_t_squared = (sum(squared_norms) / (K - 1)) - (K / (K - 1)) * avg_squared_norm

    # Compute gradient magnitude (G_t) using the provided formula
    G_t = avg_squared_norm - (1 / K) * sigma_t_squared

    return G_t, sigma_t_squared


# Update H dynamically based on gradient stats
def update_H(G_t, sigma_t_squared, H_min, H_max, alpha, epsilon):
    H_t = min(H_max, max(H_min, alpha * G_t / (sigma_t_squared + epsilon)))
    #H_t = min(H_t, H_max)  # Ensure H_t doesn't exceed H_max
    return int(H_t)  # Ensure H_t is an integer

# Training loop
# Hyperparameters for dynamic adjustment
H_min, H_max = 4, 64  # Minimum and maximum allowed local steps
alpha, epsilon = 3000, 1e-6  # Scaling factor and small constant

H_t = J  # Initialize H_t with the default J value


for epoch in range(num_epochs):
    #print(f"Epoch {epoch + 1}/{num_epochs}:")
    train_loss_for_iteration = [0.0 for _ in range(K)]
    correct_train_for_iteration = [0 for _ in range(K)]
    total_train_for_iteration = [0 for _ in range(K)]

    iteration_per_epoch = 782
    iteration = 0 # Number of global iteration performed
    while iteration_per_epoch > 0:
        computation_start_time = time.time()
        # Train each worker for H_t steps
        for k in range(K):
            nets[k].train()
            correct_train, total_train, train_loss = 0, 0, 0.0
            for _ in range(H_t):  # Perform H_t local steps
                try:
                    images, labels = next(shard_iterators[k])
                except StopIteration:
                    shard_iterators[k] = iter(DataLoader(shards[k], batch_size=batch_size, shuffle=True))
                    images, labels = next(shard_iterators[k])
                images, labels = images.to(device), labels.to(device)

                optimizers[k].zero_grad()
                outputs = nets[k](images)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizers[k].step()

                # Calculate train loss and accuracy
                train_loss += loss.item() * labels.size(0)
                _, predicted = outputs.max(1)
                total_train += labels.size(0)
                correct_train += predicted.eq(labels).sum().item()

            train_loss_for_iteration[k] += train_loss
            correct_train_for_iteration[k] += correct_train
            total_train_for_iteration[k] += total_train

        computation_end_time = time.time()
        total_computation_time += (computation_end_time - computation_start_time)

        communication_start_time = time.time()
        # Synchronize models
        with torch.no_grad():
            global_parameters = [torch.zeros_like(param) for param in nets[0].parameters()]
            for net in nets:
                for global_param, local_param in zip(global_parameters, net.parameters()):
                    global_param += local_param
            for global_param in global_parameters:
                global_param /= K
            for net in nets:
                for local_param, global_param in zip(net.parameters(), global_parameters):
                    local_param.data.copy_(global_param)

        communication_end_time = time.time()
        total_communication_time += (communication_end_time - communication_start_time)

        # update tot_num_local_step and number of global iteration
        iteration_per_epoch -= (H_t * K)
        iteration += 1
        # Compute gradient stats and update H_t
        G_t, sigma_t_squared = compute_gradient_stats(nets, optimizers)
        H_t = update_H(G_t, sigma_t_squared, H_min, H_max, alpha, epsilon)
        print(f"Epoch {epoch+1}, Iteration {iteration}: H_t = {H_t}, G_t = {G_t:.4f}, σ_t^2 = {sigma_t_squared:.4f}")

    # Store training metrics for all workers after each epoch
    for k in range(K):
        # Store train loss and accuracy for this worker
        train_loss_for_iteration[k] /= total_train_for_iteration[k]
        train_losses_per_worker[k].append(train_loss_for_iteration[k])
        tot_accuracy = 100. * correct_train_for_iteration[k] / total_train_for_iteration[k]
        train_accuracies_per_worker[k].append(tot_accuracy)
        print(f"    Worker {k}: Train Loss: {train_losses_per_worker[k][-1]:.4f}, Train Accuracy: {train_accuracies_per_worker[k][-1]:.2f}%")

    # Update learning rate
    for scheduler in schedulers:
        scheduler.step()

    # Evaluate on test set
    global_model = nets[0]
    global_model.eval()
    correct_test, total_test, test_loss = 0, 0, 0.0
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total_test += labels.size(0)
            correct_test += predicted.eq(labels).sum().item()

    test_loss /= len(testloader)
    test_losses.append(test_loss)
    test_accuracy = 100. * correct_test / total_test
    test_accuracies.append(test_accuracy)
    print(f"Epoch {epoch + 1}: Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")

    print(f"Total Computation Time: {total_computation_time:.2f} seconds")
    print(f"Total Communication Time: {total_communication_time:.2f} seconds")



# Plot Train Loss for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_losses_per_worker[k], label=f'Worker {k} Train Loss')
plt.title('Train Loss per Worker')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('train_loss_per_worker.png')
plt.show()

# Plot Train Accuracy for Each Worker
plt.figure(figsize=(8, 6))
for k in range(K):
    plt.plot(train_accuracies_per_worker[k], label=f'Worker {k} Train Accuracy')
plt.title('Train Accuracy per Worker')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('train_accuracy_per_worker.png')
plt.show()

# Plot Test Loss
plt.figure(figsize=(6, 4))
plt.plot(test_losses, label='Test Loss')
plt.title('Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('test_loss.png')
plt.show()

# Plot Test Accuracy
plt.figure(figsize=(6, 4))
plt.plot(test_accuracies, label='Test Accuracy')
plt.title('Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.tight_layout()
plt.savefig('test_accuracy.png')
plt.show()
# Out:
# Overwriting localSGD.py

# %%
# %run localSGD.py --k 4 --j 32
# Out:
# Training with K=4, J=32
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Base learning rate: 0.00400
# Epoch 1, Iteration 1: H_t = 64, G_t = 0.0070, σ_t^2 = 0.1254
# Epoch 1, Iteration 2: H_t = 7, G_t = 0.0004, σ_t^2 = 0.1446
# Epoch 1, Iteration 3: H_t = 4, G_t = -0.0040, σ_t^2 = 0.1467
# Epoch 1, Iteration 4: H_t = 60, G_t = 0.0029, σ_t^2 = 0.1462
# Epoch 1, Iteration 5: H_t = 4, G_t = -0.0028, σ_t^2 = 0.2595
# Epoch 1, Iteration 6: H_t = 64, G_t = 0.0125, σ_t^2 = 0.2142
# Epoch 1, Iteration 7: H_t = 64, G_t = 0.0286, σ_t^2 = 0.5696
#     Worker 0: Train Loss: 4.5965, Train Accuracy: 1.45%
#     Worker 1: Train Loss: 4.5972, Train Accuracy: 1.51%
#     Worker 2: Train Loss: 4.5938, Train Accuracy: 1.81%
#     Worker 3: Train Loss: 4.5965, Train Accuracy: 1.52%
# Epoch 1: Test Loss: 4.5653, Test Accuracy: 3.00%
# Total Computation Time: 27.77 seconds
# Total Communication Time: 0.01 seconds
# Epoch 2, Iteration 1: H_t = 4, G_t = -0.0198, σ_t^2 = 2.2432
# Epoch 2, Iteration 2: H_t = 25, G_t = 0.0182, σ_t^2 = 2.1633
# Epoch 2, Iteration 3: H_t = 4, G_t = -0.0850, σ_t^2 = 3.4706
# Epoch 2, Iteration 4: H_t = 64, G_t = 0.3119, σ_t^2 = 3.2600
# Epoch 2, Iteration 5: H_t = 4, G_t = -0.1149, σ_t^2 = 6.9266
# Epoch 2, Iteration 6: H_t = 64, G_t = 0.1362, σ_t^2 = 6.2177
# Epoch 2, Iteration 7: H_t = 4, G_t = -0.0830, σ_t^2 = 10.1280
#     Worker 0: Train Loss: 4.4024, Train Accuracy: 3.90%
#     Worker 1: Train Loss: 4.3991, Train Accuracy: 3.96%
#     Worker 2: Train Loss: 4.3889, Train Accuracy: 4.11%
#     Worker 3: Train Loss: 4.3967, Train Accuracy: 4.11%
# Epoch 2: Test Loss: 4.1341, Test Accuracy: 6.52%
# Total Computation Time: 54.33 seconds
# Total Communication Time: 0.02 seconds
# Epoch 3, Iteration 1: H_t = 12, G_t = 0.0411, σ_t^2 = 10.0137
# Epoch 3, Iteration 2: H_t = 64, G_t = 0.7148, σ_t^2 = 10.1472
# Epoch 3, Iteration 3: H_t = 4, G_t = 0.0154, σ_t^2 = 10.6087
# Epoch 3, Iteration 4: H_t = 18, G_t = 0.0612, σ_t^2 = 9.9957
# Epoch 3, Iteration 5: H_t = 37, G_t = 0.1482, σ_t^2 = 11.7993
# Epoch 3, Iteration 6: H_t = 4, G_t = -0.0859, σ_t^2 = 9.2749
# Epoch 3, Iteration 7: H_t = 28, G_t = 0.0934, σ_t^2 = 9.7569
# Epoch 3, Iteration 8: H_t = 35, G_t = 0.1361, σ_t^2 = 11.6461
# Epoch 3, Iteration 9: H_t = 64, G_t = 0.6257, σ_t^2 = 9.8308
#     Worker 0: Train Loss: 4.1008, Train Accuracy: 6.95%
#     Worker 1: Train Loss: 4.1113, Train Accuracy: 6.67%
#     Worker 2: Train Loss: 4.0782, Train Accuracy: 7.14%
#     Worker 3: Train Loss: 4.1067, Train Accuracy: 6.94%
# Epoch 3: Test Loss: 3.9497, Test Accuracy: 9.54%
# Total Computation Time: 78.40 seconds
# Total Communication Time: 0.03 seconds
# Epoch 4, Iteration 1: H_t = 15, G_t = 0.0606, σ_t^2 = 11.9433
# Epoch 4, Iteration 2: H_t = 64, G_t = 0.8940, σ_t^2 = 11.5167
# Epoch 4, Iteration 3: H_t = 64, G_t = 0.6072, σ_t^2 = 13.7381
# Epoch 4, Iteration 4: H_t = 64, G_t = 0.4119, σ_t^2 = 11.2324
#     Worker 0: Train Loss: 3.9670, Train Accuracy: 9.11%
#     Worker 1: Train Loss: 3.9849, Train Accuracy: 8.51%
#     Worker 2: Train Loss: 3.9229, Train Accuracy: 9.50%
#     Worker 3: Train Loss: 3.9584, Train Accuracy: 9.18%
# Epoch 4: Test Loss: 3.8032, Test Accuracy: 12.27%
# Total Computation Time: 102.49 seconds
# Total Communication Time: 0.03 seconds
# Epoch 5, Iteration 1: H_t = 4, G_t = -0.5026, σ_t^2 = 11.1566
# Epoch 5, Iteration 2: H_t = 4, G_t = -0.0499, σ_t^2 = 12.8972
# Epoch 5, Iteration 3: H_t = 26, G_t = 0.1117, σ_t^2 = 12.8849
# Epoch 5, Iteration 4: H_t = 4, G_t = -0.1933, σ_t^2 = 15.5444
# Epoch 5, Iteration 5: H_t = 4, G_t = -0.2432, σ_t^2 = 14.2853
# Epoch 5, Iteration 6: H_t = 64, G_t = 0.9529, σ_t^2 = 13.1674
# Epoch 5, Iteration 7: H_t = 64, G_t = 0.5415, σ_t^2 = 11.9876
# Epoch 5, Iteration 8: H_t = 31, G_t = 0.1252, σ_t^2 = 11.9583
#     Worker 0: Train Loss: 3.8546, Train Accuracy: 10.33%
#     Worker 1: Train Loss: 3.8424, Train Accuracy: 10.90%
#     Worker 2: Train Loss: 3.8201, Train Accuracy: 11.65%
#     Worker 3: Train Loss: 3.8545, Train Accuracy: 11.06%
# Epoch 5: Test Loss: 3.6687, Test Accuracy: 14.61%
# Total Computation Time: 129.98 seconds
# Total Communication Time: 0.04 seconds
# Epoch 6, Iteration 1: H_t = 64, G_t = 0.8074, σ_t^2 = 12.1661
# Epoch 6, Iteration 2: H_t = 64, G_t = 1.0580, σ_t^2 = 15.3604
# Epoch 6, Iteration 3: H_t = 4, G_t = -0.9899, σ_t^2 = 15.7000
# Epoch 6, Iteration 4: H_t = 64, G_t = 1.0317, σ_t^2 = 12.2895
# Epoch 6, Iteration 5: H_t = 64, G_t = 1.0148, σ_t^2 = 14.3223
#     Worker 0: Train Loss: 3.7277, Train Accuracy: 12.41%
#     Worker 1: Train Loss: 3.7414, Train Accuracy: 12.52%
#     Worker 2: Train Loss: 3.6724, Train Accuracy: 13.63%
#     Worker 3: Train Loss: 3.7291, Train Accuracy: 13.08%
# Epoch 6: Test Loss: 3.5618, Test Accuracy: 16.51%
# Total Computation Time: 156.36 seconds
# Total Communication Time: 0.05 seconds
# Epoch 7, Iteration 1: H_t = 64, G_t = 2.6497, σ_t^2 = 15.3708
# Epoch 7, Iteration 2: H_t = 21, G_t = 0.1354, σ_t^2 = 18.6613
# Epoch 7, Iteration 3: H_t = 64, G_t = 0.7091, σ_t^2 = 16.4511
# Epoch 7, Iteration 4: H_t = 26, G_t = 0.1405, σ_t^2 = 15.8302
#     Worker 0: Train Loss: 3.6460, Train Accuracy: 13.59%
#     Worker 1: Train Loss: 3.6507, Train Accuracy: 13.84%
#     Worker 2: Train Loss: 3.6112, Train Accuracy: 14.85%
#     Worker 3: Train Loss: 3.6534, Train Accuracy: 14.04%
# Epoch 7: Test Loss: 3.4645, Test Accuracy: 18.42%
# Total Computation Time: 182.40 seconds
# Total Communication Time: 0.05 seconds
# Epoch 8, Iteration 1: H_t = 4, G_t = -0.3450, σ_t^2 = 16.8959
# Epoch 8, Iteration 2: H_t = 64, G_t = 0.6452, σ_t^2 = 17.5744
# Epoch 8, Iteration 3: H_t = 4, G_t = -0.3263, σ_t^2 = 19.4427
# Epoch 8, Iteration 4: H_t = 4, G_t = -0.2431, σ_t^2 = 17.4517
# Epoch 8, Iteration 5: H_t = 4, G_t = -0.2145, σ_t^2 = 18.4440
# Epoch 8, Iteration 6: H_t = 64, G_t = 2.7341, σ_t^2 = 15.0793
# Epoch 8, Iteration 7: H_t = 26, G_t = 0.1566, σ_t^2 = 17.8109
# Epoch 8, Iteration 8: H_t = 4, G_t = -0.6796, σ_t^2 = 20.5774
#     Worker 0: Train Loss: 3.5497, Train Accuracy: 15.06%
#     Worker 1: Train Loss: 3.5571, Train Accuracy: 15.73%
#     Worker 2: Train Loss: 3.5066, Train Accuracy: 16.10%
#     Worker 3: Train Loss: 3.5408, Train Accuracy: 15.99%
# Epoch 8: Test Loss: 3.3957, Test Accuracy: 19.13%
# Total Computation Time: 205.21 seconds
# Total Communication Time: 0.06 seconds
# Epoch 9, Iteration 1: H_t = 49, G_t = 0.2909, σ_t^2 = 17.5071
# Epoch 9, Iteration 2: H_t = 64, G_t = 0.6564, σ_t^2 = 18.1051
# Epoch 9, Iteration 3: H_t = 4, G_t = -0.1118, σ_t^2 = 21.1600
# Epoch 9, Iteration 4: H_t = 64, G_t = 1.2379, σ_t^2 = 19.5480
# Epoch 9, Iteration 5: H_t = 64, G_t = 0.5726, σ_t^2 = 16.9290
# Epoch 9, Iteration 6: H_t = 26, G_t = 0.1410, σ_t^2 = 15.9339
#     Worker 0: Train Loss: 3.4767, Train Accuracy: 16.29%
#     Worker 1: Train Loss: 3.4806, Train Accuracy: 17.25%
#     Worker 2: Train Loss: 3.4235, Train Accuracy: 17.81%
#     Worker 3: Train Loss: 3.4851, Train Accuracy: 16.76%
# Epoch 9: Test Loss: 3.3014, Test Accuracy: 21.12%
# Total Computation Time: 234.44 seconds
# Total Communication Time: 0.07 seconds
# Epoch 10, Iteration 1: H_t = 64, G_t = 1.6062, σ_t^2 = 21.9729
# Epoch 10, Iteration 2: H_t = 33, G_t = 0.2116, σ_t^2 = 18.8967
# Epoch 10, Iteration 3: H_t = 4, G_t = -0.2589, σ_t^2 = 21.2654
# Epoch 10, Iteration 4: H_t = 64, G_t = 0.5532, σ_t^2 = 20.3355
# Epoch 10, Iteration 5: H_t = 6, G_t = 0.0426, σ_t^2 = 20.6970
# Epoch 10, Iteration 6: H_t = 4, G_t = -0.2553, σ_t^2 = 21.6748
#     Worker 0: Train Loss: 3.3808, Train Accuracy: 18.61%
#     Worker 1: Train Loss: 3.3845, Train Accuracy: 18.53%
#     Worker 2: Train Loss: 3.3499, Train Accuracy: 19.18%
#     Worker 3: Train Loss: 3.3936, Train Accuracy: 18.32%
# Epoch 10: Test Loss: 3.2043, Test Accuracy: 22.84%
# Total Computation Time: 258.21 seconds
# Total Communication Time: 0.08 seconds
# Epoch 11, Iteration 1: H_t = 4, G_t = -0.5414, σ_t^2 = 23.2826
# Epoch 11, Iteration 2: H_t = 64, G_t = 0.8093, σ_t^2 = 19.4980
# Epoch 11, Iteration 3: H_t = 4, G_t = -0.4284, σ_t^2 = 22.7433
# Epoch 11, Iteration 4: H_t = 64, G_t = 1.2654, σ_t^2 = 17.9349
# Epoch 11, Iteration 5: H_t = 64, G_t = 0.9005, σ_t^2 = 19.5592
# Epoch 11, Iteration 6: H_t = 64, G_t = 1.2344, σ_t^2 = 24.9097
#     Worker 0: Train Loss: 3.3392, Train Accuracy: 19.34%
#     Worker 1: Train Loss: 3.3416, Train Accuracy: 19.21%
#     Worker 2: Train Loss: 3.2686, Train Accuracy: 20.27%
#     Worker 3: Train Loss: 3.3507, Train Accuracy: 18.99%
# Epoch 11: Test Loss: 3.1682, Test Accuracy: 22.96%
# Total Computation Time: 282.20 seconds
# Total Communication Time: 0.08 seconds
# Epoch 12, Iteration 1: H_t = 4, G_t = -0.0404, σ_t^2 = 22.9406
# Epoch 12, Iteration 2: H_t = 64, G_t = 0.6380, σ_t^2 = 21.0041
# Epoch 12, Iteration 3: H_t = 64, G_t = 0.5372, σ_t^2 = 25.0852
# Epoch 12, Iteration 4: H_t = 4, G_t = -0.9151, σ_t^2 = 23.8274
#     Worker 0: Train Loss: 3.2517, Train Accuracy: 20.36%
#     Worker 1: Train Loss: 3.2710, Train Accuracy: 20.94%
#     Worker 2: Train Loss: 3.2317, Train Accuracy: 20.96%
#     Worker 3: Train Loss: 3.2673, Train Accuracy: 20.58%
# Epoch 12: Test Loss: 3.0741, Test Accuracy: 25.39%
# Total Computation Time: 305.21 seconds
# Total Communication Time: 0.09 seconds
# Epoch 13, Iteration 1: H_t = 64, G_t = 0.4388, σ_t^2 = 19.9995
# Epoch 13, Iteration 2: H_t = 46, G_t = 0.3714, σ_t^2 = 24.1515
# Epoch 13, Iteration 3: H_t = 4, G_t = -1.9648, σ_t^2 = 27.3606
# Epoch 13, Iteration 4: H_t = 4, G_t = -1.4131, σ_t^2 = 27.5987
# Epoch 13, Iteration 5: H_t = 64, G_t = 1.1127, σ_t^2 = 22.4000
# Epoch 13, Iteration 6: H_t = 4, G_t = -0.6257, σ_t^2 = 22.4107
# Epoch 13, Iteration 7: H_t = 4, G_t = -0.5259, σ_t^2 = 21.8839
# Epoch 13, Iteration 8: H_t = 64, G_t = 0.7601, σ_t^2 = 19.6015
# Epoch 13, Iteration 9: H_t = 64, G_t = 1.7084, σ_t^2 = 20.6633
#     Worker 0: Train Loss: 3.1802, Train Accuracy: 22.06%
#     Worker 1: Train Loss: 3.2122, Train Accuracy: 21.86%
#     Worker 2: Train Loss: 3.1539, Train Accuracy: 22.67%
#     Worker 3: Train Loss: 3.2094, Train Accuracy: 21.59%
# Epoch 13: Test Loss: 3.0284, Test Accuracy: 25.72%
# Total Computation Time: 335.75 seconds
# Total Communication Time: 0.10 seconds
# Epoch 14, Iteration 1: H_t = 4, G_t = -1.2256, σ_t^2 = 32.1656
# Epoch 14, Iteration 2: H_t = 4, G_t = -3.2406, σ_t^2 = 33.2362
# Epoch 14, Iteration 3: H_t = 4, G_t = -1.0467, σ_t^2 = 29.7335
# Epoch 14, Iteration 4: H_t = 64, G_t = 0.6327, σ_t^2 = 25.6327
# Epoch 14, Iteration 5: H_t = 4, G_t = -1.4215, σ_t^2 = 26.9974
# Epoch 14, Iteration 6: H_t = 21, G_t = 0.1935, σ_t^2 = 26.7495
# Epoch 14, Iteration 7: H_t = 64, G_t = 0.6601, σ_t^2 = 27.0769
# Epoch 14, Iteration 8: H_t = 4, G_t = -0.7753, σ_t^2 = 25.1170
#     Worker 0: Train Loss: 3.1186, Train Accuracy: 22.83%
#     Worker 1: Train Loss: 3.1517, Train Accuracy: 22.56%
#     Worker 2: Train Loss: 3.0785, Train Accuracy: 23.62%
#     Worker 3: Train Loss: 3.1397, Train Accuracy: 22.43%
# Epoch 14: Test Loss: 2.9322, Test Accuracy: 28.22%
# Total Computation Time: 362.68 seconds
# Total Communication Time: 0.11 seconds
# Epoch 15, Iteration 1: H_t = 4, G_t = -0.3751, σ_t^2 = 21.4543
# Epoch 15, Iteration 2: H_t = 4, G_t = -0.7827, σ_t^2 = 24.5240
# Epoch 15, Iteration 3: H_t = 64, G_t = 1.7031, σ_t^2 = 26.9995
# Epoch 15, Iteration 4: H_t = 4, G_t = -1.3111, σ_t^2 = 26.2717
# Epoch 15, Iteration 5: H_t = 41, G_t = 0.3134, σ_t^2 = 22.6888
# Epoch 15, Iteration 6: H_t = 64, G_t = 1.5850, σ_t^2 = 23.6705
# Epoch 15, Iteration 7: H_t = 4, G_t = -1.9638, σ_t^2 = 31.4626
# Epoch 15, Iteration 8: H_t = 34, G_t = 0.2674, σ_t^2 = 23.0343
# Epoch 15, Iteration 9: H_t = 4, G_t = -0.1464, σ_t^2 = 28.0278
#     Worker 0: Train Loss: 3.0527, Train Accuracy: 24.15%
#     Worker 1: Train Loss: 3.0995, Train Accuracy: 23.82%
#     Worker 2: Train Loss: 3.0367, Train Accuracy: 25.04%
#     Worker 3: Train Loss: 3.0786, Train Accuracy: 24.19%
# Epoch 15: Test Loss: 2.8994, Test Accuracy: 28.19%
# Total Computation Time: 389.35 seconds
# Total Communication Time: 0.12 seconds
# Epoch 16, Iteration 1: H_t = 4, G_t = -2.3301, σ_t^2 = 29.3073
# Epoch 16, Iteration 2: H_t = 21, G_t = 0.1755, σ_t^2 = 24.1945
# Epoch 16, Iteration 3: H_t = 4, G_t = -0.7106, σ_t^2 = 84.1720
# Epoch 16, Iteration 4: H_t = 64, G_t = 0.8148, σ_t^2 = 28.4831
# Epoch 16, Iteration 5: H_t = 64, G_t = 3.1347, σ_t^2 = 20.9126
# Epoch 16, Iteration 6: H_t = 4, G_t = -0.1890, σ_t^2 = 30.3877
# Epoch 16, Iteration 7: H_t = 64, G_t = 1.3502, σ_t^2 = 24.4570
# Epoch 16, Iteration 8: H_t = 4, G_t = -0.6289, σ_t^2 = 30.0256
#     Worker 0: Train Loss: 3.0310, Train Accuracy: 24.51%
#     Worker 1: Train Loss: 3.0550, Train Accuracy: 24.02%
#     Worker 2: Train Loss: 2.9990, Train Accuracy: 25.70%
#     Worker 3: Train Loss: 3.0227, Train Accuracy: 24.98%
# Epoch 16: Test Loss: 2.8383, Test Accuracy: 29.35%
# Total Computation Time: 416.07 seconds
# Total Communication Time: 0.13 seconds
# Epoch 17, Iteration 1: H_t = 4, G_t = -0.5147, σ_t^2 = 25.5536
# Epoch 17, Iteration 2: H_t = 4, G_t = -0.4711, σ_t^2 = 27.0345
# Epoch 17, Iteration 3: H_t = 64, G_t = 1.2179, σ_t^2 = 32.3942
# Epoch 17, Iteration 4: H_t = 4, G_t = -1.4042, σ_t^2 = 28.1487
# Epoch 17, Iteration 5: H_t = 4, G_t = -2.1549, σ_t^2 = 26.5095
# Epoch 17, Iteration 6: H_t = 4, G_t = -1.0372, σ_t^2 = 25.0347
# Epoch 17, Iteration 7: H_t = 4, G_t = -0.9326, σ_t^2 = 28.8687
# Epoch 17, Iteration 8: H_t = 35, G_t = 0.4512, σ_t^2 = 38.6219
# Epoch 17, Iteration 9: H_t = 16, G_t = 0.1353, σ_t^2 = 24.4962
# Epoch 17, Iteration 10: H_t = 4, G_t = -0.1906, σ_t^2 = 31.7850
# Epoch 17, Iteration 11: H_t = 4, G_t = -0.0335, σ_t^2 = 26.7769
# Epoch 17, Iteration 12: H_t = 4, G_t = -0.1586, σ_t^2 = 27.3680
# Epoch 17, Iteration 13: H_t = 4, G_t = -0.1536, σ_t^2 = 30.1556
# Epoch 17, Iteration 14: H_t = 4, G_t = -0.0633, σ_t^2 = 29.4587
# Epoch 17, Iteration 15: H_t = 64, G_t = 0.6520, σ_t^2 = 28.9157
# Epoch 17, Iteration 16: H_t = 64, G_t = 0.8817, σ_t^2 = 32.1257
#     Worker 0: Train Loss: 2.9639, Train Accuracy: 26.24%
#     Worker 1: Train Loss: 2.9699, Train Accuracy: 26.58%
#     Worker 2: Train Loss: 2.9309, Train Accuracy: 27.02%
#     Worker 3: Train Loss: 2.9607, Train Accuracy: 26.07%
# Epoch 17: Test Loss: 2.7860, Test Accuracy: 30.52%
# Total Computation Time: 442.52 seconds
# Total Communication Time: 0.15 seconds
# Epoch 18, Iteration 1: H_t = 64, G_t = 1.8635, σ_t^2 = 27.9578
# Epoch 18, Iteration 2: H_t = 64, G_t = 0.8277, σ_t^2 = 30.6284
# Epoch 18, Iteration 3: H_t = 64, G_t = 2.2648, σ_t^2 = 25.3374
# Epoch 18, Iteration 4: H_t = 64, G_t = 1.7929, σ_t^2 = 31.7193
#     Worker 0: Train Loss: 2.9087, Train Accuracy: 27.07%
#     Worker 1: Train Loss: 2.9572, Train Accuracy: 26.27%
#     Worker 2: Train Loss: 2.8906, Train Accuracy: 27.61%
#     Worker 3: Train Loss: 2.9370, Train Accuracy: 26.60%
# Epoch 18: Test Loss: 2.7339, Test Accuracy: 31.59%
# Total Computation Time: 472.70 seconds
# Total Communication Time: 0.15 seconds
# Epoch 19, Iteration 1: H_t = 4, G_t = -1.0164, σ_t^2 = 34.0825
# Epoch 19, Iteration 2: H_t = 4, G_t = -1.6890, σ_t^2 = 30.9065
# Epoch 19, Iteration 3: H_t = 4, G_t = -0.9166, σ_t^2 = 30.8516
# Epoch 19, Iteration 4: H_t = 64, G_t = 2.3024, σ_t^2 = 23.7242
# Epoch 19, Iteration 5: H_t = 64, G_t = 1.0071, σ_t^2 = 30.8881
# Epoch 19, Iteration 6: H_t = 64, G_t = 6.1156, σ_t^2 = 35.8011
#     Worker 0: Train Loss: 2.8639, Train Accuracy: 28.04%
#     Worker 1: Train Loss: 2.8906, Train Accuracy: 27.37%
#     Worker 2: Train Loss: 2.8723, Train Accuracy: 28.03%
#     Worker 3: Train Loss: 2.8984, Train Accuracy: 27.21%
# Epoch 19: Test Loss: 2.7160, Test Accuracy: 31.73%
# Total Computation Time: 496.60 seconds
# Total Communication Time: 0.16 seconds
# Epoch 20, Iteration 1: H_t = 64, G_t = 1.2139, σ_t^2 = 27.5015
# Epoch 20, Iteration 2: H_t = 11, G_t = 0.1307, σ_t^2 = 33.5264
# Epoch 20, Iteration 3: H_t = 4, G_t = -0.4422, σ_t^2 = 36.4354
# Epoch 20, Iteration 4: H_t = 4, G_t = -0.4915, σ_t^2 = 26.0756
# Epoch 20, Iteration 5: H_t = 64, G_t = 2.9208, σ_t^2 = 28.9294
# Epoch 20, Iteration 6: H_t = 12, G_t = 0.1321, σ_t^2 = 30.8131
#     Worker 0: Train Loss: 2.8378, Train Accuracy: 28.76%
#     Worker 1: Train Loss: 2.8613, Train Accuracy: 28.37%
#     Worker 2: Train Loss: 2.8183, Train Accuracy: 29.41%
#     Worker 3: Train Loss: 2.8174, Train Accuracy: 28.71%
# Epoch 20: Test Loss: 2.6807, Test Accuracy: 32.59%
# Total Computation Time: 521.25 seconds
# Total Communication Time: 0.17 seconds
# Epoch 21, Iteration 1: H_t = 64, G_t = 0.7985, σ_t^2 = 32.4596
# Epoch 21, Iteration 2: H_t = 64, G_t = 2.4072, σ_t^2 = 30.9564
# Epoch 21, Iteration 3: H_t = 4, G_t = -0.5345, σ_t^2 = 29.7541
# Epoch 21, Iteration 4: H_t = 64, G_t = 0.9231, σ_t^2 = 26.7443
# Epoch 21, Iteration 5: H_t = 64, G_t = 0.7263, σ_t^2 = 31.0667
#     Worker 0: Train Loss: 2.7877, Train Accuracy: 29.65%
#     Worker 1: Train Loss: 2.8080, Train Accuracy: 29.51%
#     Worker 2: Train Loss: 2.7687, Train Accuracy: 30.07%
#     Worker 3: Train Loss: 2.8118, Train Accuracy: 29.30%
# Epoch 21: Test Loss: 2.6249, Test Accuracy: 34.12%
# Total Computation Time: 545.44 seconds
# Total Communication Time: 0.17 seconds
# Epoch 22, Iteration 1: H_t = 4, G_t = -2.1321, σ_t^2 = 34.2475
# Epoch 22, Iteration 2: H_t = 64, G_t = 1.3537, σ_t^2 = 34.6275
# Epoch 22, Iteration 3: H_t = 64, G_t = 2.2045, σ_t^2 = 31.4996
# Epoch 22, Iteration 4: H_t = 4, G_t = -2.6206, σ_t^2 = 32.7866
#     Worker 0: Train Loss: 2.7511, Train Accuracy: 30.27%
#     Worker 1: Train Loss: 2.7739, Train Accuracy: 29.47%
#     Worker 2: Train Loss: 2.7179, Train Accuracy: 31.14%
#     Worker 3: Train Loss: 2.7609, Train Accuracy: 30.08%
# Epoch 22: Test Loss: 2.5852, Test Accuracy: 34.57%
# Total Computation Time: 568.84 seconds
# Total Communication Time: 0.18 seconds
# Epoch 23, Iteration 1: H_t = 64, G_t = 0.9481, σ_t^2 = 27.4408
# Epoch 23, Iteration 2: H_t = 18, G_t = 0.2282, σ_t^2 = 36.4160
# Epoch 23, Iteration 3: H_t = 4, G_t = -1.3724, σ_t^2 = 38.3167
# Epoch 23, Iteration 4: H_t = 64, G_t = 0.7609, σ_t^2 = 35.6072
# Epoch 23, Iteration 5: H_t = 4, G_t = -0.1817, σ_t^2 = 27.9869
# Epoch 23, Iteration 6: H_t = 64, G_t = 0.9093, σ_t^2 = 28.3079
# Epoch 23, Iteration 7: H_t = 64, G_t = 1.3318, σ_t^2 = 39.4337
#     Worker 0: Train Loss: 2.6970, Train Accuracy: 31.18%
#     Worker 1: Train Loss: 2.7261, Train Accuracy: 30.51%
#     Worker 2: Train Loss: 2.6867, Train Accuracy: 31.54%
#     Worker 3: Train Loss: 2.7419, Train Accuracy: 30.56%
# Epoch 23: Test Loss: 2.5363, Test Accuracy: 35.37%
# Total Computation Time: 594.53 seconds
# Total Communication Time: 0.19 seconds
# Epoch 24, Iteration 1: H_t = 4, G_t = 0.0057, σ_t^2 = 28.8755
# Epoch 24, Iteration 2: H_t = 19, G_t = 0.2155, σ_t^2 = 32.6184
# Epoch 24, Iteration 3: H_t = 64, G_t = 1.6969, σ_t^2 = 39.3896
# Epoch 24, Iteration 4: H_t = 47, G_t = 0.6043, σ_t^2 = 38.3367
# Epoch 24, Iteration 5: H_t = 4, G_t = -0.3549, σ_t^2 = 39.6911
#     Worker 0: Train Loss: 2.6669, Train Accuracy: 31.75%
#     Worker 1: Train Loss: 2.6806, Train Accuracy: 32.02%
#     Worker 2: Train Loss: 2.6540, Train Accuracy: 32.92%
#     Worker 3: Train Loss: 2.6710, Train Accuracy: 31.56%
# Epoch 24: Test Loss: 2.5202, Test Accuracy: 35.99%
# Total Computation Time: 617.45 seconds
# Total Communication Time: 0.19 seconds
# Epoch 25, Iteration 1: H_t = 4, G_t = -1.6538, σ_t^2 = 38.6546
# Epoch 25, Iteration 2: H_t = 4, G_t = -0.6882, σ_t^2 = 28.1902
# Epoch 25, Iteration 3: H_t = 4, G_t = -0.2726, σ_t^2 = 33.3046
# Epoch 25, Iteration 4: H_t = 64, G_t = 2.3150, σ_t^2 = 42.0322
# Epoch 25, Iteration 5: H_t = 4, G_t = -1.2764, σ_t^2 = 37.9324
# Epoch 25, Iteration 6: H_t = 64, G_t = 1.7181, σ_t^2 = 32.5950
# Epoch 25, Iteration 7: H_t = 40, G_t = 0.4083, σ_t^2 = 30.0995
# Epoch 25, Iteration 8: H_t = 64, G_t = 1.6989, σ_t^2 = 34.7118
# Epoch 25, Iteration 9: H_t = 4, G_t = -0.4272, σ_t^2 = 36.6787
#     Worker 0: Train Loss: 2.6240, Train Accuracy: 32.93%
#     Worker 1: Train Loss: 2.6297, Train Accuracy: 32.98%
#     Worker 2: Train Loss: 2.6088, Train Accuracy: 33.81%
#     Worker 3: Train Loss: 2.6367, Train Accuracy: 32.38%
# Epoch 25: Test Loss: 2.4719, Test Accuracy: 36.85%
# Total Computation Time: 646.89 seconds
# Total Communication Time: 0.20 seconds
# Epoch 26, Iteration 1: H_t = 4, G_t = -0.9651, σ_t^2 = 31.5622
# Epoch 26, Iteration 2: H_t = 64, G_t = 2.1987, σ_t^2 = 31.4162
# Epoch 26, Iteration 3: H_t = 4, G_t = -1.4765, σ_t^2 = 43.5568
# Epoch 26, Iteration 4: H_t = 64, G_t = 3.2965, σ_t^2 = 31.0704
# Epoch 26, Iteration 5: H_t = 4, G_t = -0.3679, σ_t^2 = 42.4143
# Epoch 26, Iteration 6: H_t = 4, G_t = -1.4518, σ_t^2 = 29.7290
# Epoch 26, Iteration 7: H_t = 4, G_t = -0.4924, σ_t^2 = 35.9415
# Epoch 26, Iteration 8: H_t = 61, G_t = 0.7414, σ_t^2 = 36.0376
# Epoch 26, Iteration 9: H_t = 4, G_t = -1.7729, σ_t^2 = 41.6293
#     Worker 0: Train Loss: 2.5648, Train Accuracy: 33.88%
#     Worker 1: Train Loss: 2.6051, Train Accuracy: 33.19%
#     Worker 2: Train Loss: 2.5546, Train Accuracy: 34.44%
#     Worker 3: Train Loss: 2.5869, Train Accuracy: 33.90%
# Epoch 26: Test Loss: 2.4410, Test Accuracy: 37.49%
# Total Computation Time: 671.68 seconds
# Total Communication Time: 0.21 seconds
# Epoch 27, Iteration 1: H_t = 4, G_t = -1.4042, σ_t^2 = 35.6846
# Epoch 27, Iteration 2: H_t = 64, G_t = 0.9212, σ_t^2 = 35.2313
# Epoch 27, Iteration 3: H_t = 64, G_t = 1.0516, σ_t^2 = 34.2446
# Epoch 27, Iteration 4: H_t = 4, G_t = -0.4960, σ_t^2 = 34.2024
# Epoch 27, Iteration 5: H_t = 4, G_t = -1.0642, σ_t^2 = 43.0758
# Epoch 27, Iteration 6: H_t = 4, G_t = -0.0352, σ_t^2 = 34.8673
# Epoch 27, Iteration 7: H_t = 6, G_t = 0.0807, σ_t^2 = 35.2023
# Epoch 27, Iteration 8: H_t = 17, G_t = 0.1871, σ_t^2 = 32.0065
# Epoch 27, Iteration 9: H_t = 4, G_t = -1.2360, σ_t^2 = 46.2626
# Epoch 27, Iteration 10: H_t = 4, G_t = 0.0581, σ_t^2 = 43.5698
# Epoch 27, Iteration 11: H_t = 43, G_t = 0.5012, σ_t^2 = 34.4461
# Epoch 27, Iteration 12: H_t = 64, G_t = 5.7642, σ_t^2 = 43.7454
#     Worker 0: Train Loss: 2.5400, Train Accuracy: 34.35%
#     Worker 1: Train Loss: 2.5634, Train Accuracy: 34.36%
#     Worker 2: Train Loss: 2.5322, Train Accuracy: 35.29%
#     Worker 3: Train Loss: 2.5633, Train Accuracy: 33.93%
# Epoch 27: Test Loss: 2.4036, Test Accuracy: 38.19%
# Total Computation Time: 697.39 seconds
# Total Communication Time: 0.23 seconds
# Epoch 28, Iteration 1: H_t = 34, G_t = 0.3838, σ_t^2 = 33.8037
# Epoch 28, Iteration 2: H_t = 4, G_t = -0.6738, σ_t^2 = 38.8276
# Epoch 28, Iteration 3: H_t = 64, G_t = 1.3581, σ_t^2 = 32.3976
# Epoch 28, Iteration 4: H_t = 4, G_t = -0.9773, σ_t^2 = 42.3468
# Epoch 28, Iteration 5: H_t = 20, G_t = 0.2086, σ_t^2 = 31.1278
# Epoch 28, Iteration 6: H_t = 64, G_t = 4.8029, σ_t^2 = 33.1207
# Epoch 28, Iteration 7: H_t = 64, G_t = 1.5021, σ_t^2 = 35.0773
#     Worker 0: Train Loss: 2.5088, Train Accuracy: 35.34%
#     Worker 1: Train Loss: 2.5374, Train Accuracy: 34.59%
#     Worker 2: Train Loss: 2.5203, Train Accuracy: 35.09%
#     Worker 3: Train Loss: 2.5465, Train Accuracy: 34.52%
# Epoch 28: Test Loss: 2.3747, Test Accuracy: 38.95%
# Total Computation Time: 727.18 seconds
# Total Communication Time: 0.23 seconds
# Epoch 29, Iteration 1: H_t = 4, G_t = -1.9590, σ_t^2 = 38.8250
# Epoch 29, Iteration 2: H_t = 4, G_t = -0.7100, σ_t^2 = 29.8369
# Epoch 29, Iteration 3: H_t = 4, G_t = -0.8564, σ_t^2 = 32.9575
# Epoch 29, Iteration 4: H_t = 64, G_t = 0.6676, σ_t^2 = 27.3154
# Epoch 29, Iteration 5: H_t = 4, G_t = -0.2104, σ_t^2 = 37.4322
# Epoch 29, Iteration 6: H_t = 4, G_t = -1.2128, σ_t^2 = 33.0433
# Epoch 29, Iteration 7: H_t = 64, G_t = 3.2379, σ_t^2 = 32.8144
# Epoch 29, Iteration 8: H_t = 4, G_t = -3.1103, σ_t^2 = 47.5940
#     Worker 0: Train Loss: 2.4902, Train Accuracy: 35.49%
#     Worker 1: Train Loss: 2.4958, Train Accuracy: 35.43%
#     Worker 2: Train Loss: 2.4568, Train Accuracy: 36.52%
#     Worker 3: Train Loss: 2.4940, Train Accuracy: 35.88%
# Epoch 29: Test Loss: 2.3526, Test Accuracy: 39.04%
# Total Computation Time: 752.64 seconds
# Total Communication Time: 0.25 seconds
# Epoch 30, Iteration 1: H_t = 4, G_t = -1.3570, σ_t^2 = 35.4962
# Epoch 30, Iteration 2: H_t = 64, G_t = 0.8912, σ_t^2 = 30.0600
# Epoch 30, Iteration 3: H_t = 4, G_t = -1.0134, σ_t^2 = 35.8070
# Epoch 30, Iteration 4: H_t = 9, G_t = 0.1060, σ_t^2 = 33.3202
# Epoch 30, Iteration 5: H_t = 64, G_t = 2.2787, σ_t^2 = 35.6962
# Epoch 30, Iteration 6: H_t = 4, G_t = 0.0529, σ_t^2 = 45.9049
# Epoch 30, Iteration 7: H_t = 4, G_t = -1.4021, σ_t^2 = 39.7354
# Epoch 30, Iteration 8: H_t = 64, G_t = 3.1731, σ_t^2 = 36.6517
# Epoch 30, Iteration 9: H_t = 55, G_t = 0.5946, σ_t^2 = 31.9896
#     Worker 0: Train Loss: 2.4507, Train Accuracy: 36.24%
#     Worker 1: Train Loss: 2.4748, Train Accuracy: 36.18%
#     Worker 2: Train Loss: 2.4597, Train Accuracy: 36.63%
#     Worker 3: Train Loss: 2.4819, Train Accuracy: 35.50%
# Epoch 30: Test Loss: 2.3278, Test Accuracy: 40.09%
# Total Computation Time: 778.24 seconds
# Total Communication Time: 0.26 seconds
# Epoch 31, Iteration 1: H_t = 64, G_t = 1.1790, σ_t^2 = 39.3543
# Epoch 31, Iteration 2: H_t = 64, G_t = 2.0018, σ_t^2 = 35.8478
# Epoch 31, Iteration 3: H_t = 64, G_t = 1.9202, σ_t^2 = 35.4394
# Epoch 31, Iteration 4: H_t = 17, G_t = 0.2449, σ_t^2 = 42.6331
#     Worker 0: Train Loss: 2.4214, Train Accuracy: 36.89%
#     Worker 1: Train Loss: 2.4545, Train Accuracy: 36.00%
#     Worker 2: Train Loss: 2.4251, Train Accuracy: 37.24%
#     Worker 3: Train Loss: 2.4664, Train Accuracy: 35.67%
# Epoch 31: Test Loss: 2.3228, Test Accuracy: 39.79%
# Total Computation Time: 807.44 seconds
# Total Communication Time: 0.26 seconds
# Epoch 32, Iteration 1: H_t = 4, G_t = -1.0111, σ_t^2 = 42.8889
# Epoch 32, Iteration 2: H_t = 64, G_t = 3.5926, σ_t^2 = 31.4908
# Epoch 32, Iteration 3: H_t = 64, G_t = 1.6661, σ_t^2 = 37.6663
# Epoch 32, Iteration 4: H_t = 4, G_t = -2.0912, σ_t^2 = 40.0636
# Epoch 32, Iteration 5: H_t = 64, G_t = 1.6468, σ_t^2 = 32.8157
# Epoch 32, Iteration 6: H_t = 54, G_t = 0.6193, σ_t^2 = 33.8632
#     Worker 0: Train Loss: 2.4065, Train Accuracy: 36.90%
#     Worker 1: Train Loss: 2.4143, Train Accuracy: 37.27%
#     Worker 2: Train Loss: 2.3787, Train Accuracy: 38.22%
#     Worker 3: Train Loss: 2.4079, Train Accuracy: 37.36%
# Epoch 32: Test Loss: 2.2957, Test Accuracy: 40.31%
# Total Computation Time: 833.06 seconds
# Total Communication Time: 0.27 seconds
# Epoch 33, Iteration 1: H_t = 64, G_t = 0.9572, σ_t^2 = 37.1750
# Epoch 33, Iteration 2: H_t = 64, G_t = 3.0646, σ_t^2 = 35.8179
# Epoch 33, Iteration 3: H_t = 4, G_t = -1.3193, σ_t^2 = 46.1990
# Epoch 33, Iteration 4: H_t = 63, G_t = 0.7226, σ_t^2 = 33.9432
# Epoch 33, Iteration 5: H_t = 20, G_t = 0.2616, σ_t^2 = 38.1378
#     Worker 0: Train Loss: 2.3559, Train Accuracy: 38.28%
#     Worker 1: Train Loss: 2.3917, Train Accuracy: 37.64%
#     Worker 2: Train Loss: 2.3708, Train Accuracy: 37.89%
#     Worker 3: Train Loss: 2.3932, Train Accuracy: 37.31%
# Epoch 33: Test Loss: 2.2672, Test Accuracy: 41.25%
# Total Computation Time: 862.71 seconds
# Total Communication Time: 0.28 seconds
# Epoch 34, Iteration 1: H_t = 4, G_t = -2.8298, σ_t^2 = 42.5935
# Epoch 34, Iteration 2: H_t = 4, G_t = -0.8702, σ_t^2 = 34.9239
# Epoch 34, Iteration 3: H_t = 9, G_t = 0.1166, σ_t^2 = 37.0586
# Epoch 34, Iteration 4: H_t = 4, G_t = -0.9865, σ_t^2 = 44.2281
# Epoch 34, Iteration 5: H_t = 48, G_t = 0.6298, σ_t^2 = 38.6501
# Epoch 34, Iteration 6: H_t = 4, G_t = -0.5757, σ_t^2 = 39.0938
# Epoch 34, Iteration 7: H_t = 4, G_t = 0.0106, σ_t^2 = 38.5759
# Epoch 34, Iteration 8: H_t = 30, G_t = 0.3510, σ_t^2 = 34.7424
# Epoch 34, Iteration 9: H_t = 64, G_t = 2.0253, σ_t^2 = 43.6803
# Epoch 34, Iteration 10: H_t = 64, G_t = 1.4294, σ_t^2 = 35.0565
# Epoch 34, Iteration 11: H_t = 47, G_t = 0.7007, σ_t^2 = 44.3564
#     Worker 0: Train Loss: 2.3399, Train Accuracy: 38.51%
#     Worker 1: Train Loss: 2.3492, Train Accuracy: 38.68%
#     Worker 2: Train Loss: 2.3120, Train Accuracy: 40.11%
#     Worker 3: Train Loss: 2.3536, Train Accuracy: 37.89%
# Epoch 34: Test Loss: 2.2496, Test Accuracy: 41.65%
# Total Computation Time: 892.47 seconds
# Total Communication Time: 0.29 seconds
# Epoch 35, Iteration 1: H_t = 64, G_t = 1.6507, σ_t^2 = 38.1690
# Epoch 35, Iteration 2: H_t = 4, G_t = -1.8661, σ_t^2 = 40.2409
# Epoch 35, Iteration 3: H_t = 28, G_t = 0.3042, σ_t^2 = 32.3767
# Epoch 35, Iteration 4: H_t = 64, G_t = 0.9516, σ_t^2 = 38.7541
# Epoch 35, Iteration 5: H_t = 19, G_t = 0.2514, σ_t^2 = 38.4434
#     Worker 0: Train Loss: 2.3230, Train Accuracy: 39.06%
#     Worker 1: Train Loss: 2.3388, Train Accuracy: 38.82%
#     Worker 2: Train Loss: 2.3089, Train Accuracy: 39.34%
#     Worker 3: Train Loss: 2.3335, Train Accuracy: 39.10%
# Epoch 35: Test Loss: 2.2347, Test Accuracy: 41.95%
# Total Computation Time: 916.47 seconds
# Total Communication Time: 0.30 seconds
# Epoch 36, Iteration 1: H_t = 64, G_t = 1.4521, σ_t^2 = 38.0595
# Epoch 36, Iteration 2: H_t = 4, G_t = -1.1086, σ_t^2 = 46.9581
# Epoch 36, Iteration 3: H_t = 4, G_t = -0.1043, σ_t^2 = 37.1969
# Epoch 36, Iteration 4: H_t = 20, G_t = 0.2425, σ_t^2 = 36.1681
# Epoch 36, Iteration 5: H_t = 4, G_t = -1.5262, σ_t^2 = 47.9596
# Epoch 36, Iteration 6: H_t = 64, G_t = 2.0739, σ_t^2 = 41.0713
# Epoch 36, Iteration 7: H_t = 4, G_t = -0.8175, σ_t^2 = 40.3167
# Epoch 36, Iteration 8: H_t = 4, G_t = -0.9558, σ_t^2 = 36.0164
# Epoch 36, Iteration 9: H_t = 4, G_t = 0.0147, σ_t^2 = 35.2164
# Epoch 36, Iteration 10: H_t = 55, G_t = 0.6583, σ_t^2 = 35.8564
# Epoch 36, Iteration 11: H_t = 64, G_t = 1.4286, σ_t^2 = 40.7156
#     Worker 0: Train Loss: 2.2772, Train Accuracy: 39.88%
#     Worker 1: Train Loss: 2.2791, Train Accuracy: 40.54%
#     Worker 2: Train Loss: 2.2763, Train Accuracy: 40.12%
#     Worker 3: Train Loss: 2.2870, Train Accuracy: 39.97%
# Epoch 36: Test Loss: 2.2288, Test Accuracy: 41.93%
# Total Computation Time: 945.67 seconds
# Total Communication Time: 0.31 seconds
# Epoch 37, Iteration 1: H_t = 42, G_t = 0.5631, σ_t^2 = 40.0537
# Epoch 37, Iteration 2: H_t = 44, G_t = 0.7147, σ_t^2 = 47.9681
# Epoch 37, Iteration 3: H_t = 4, G_t = -0.2607, σ_t^2 = 44.2915
# Epoch 37, Iteration 4: H_t = 64, G_t = 1.3117, σ_t^2 = 33.4588
# Epoch 37, Iteration 5: H_t = 4, G_t = -0.9579, σ_t^2 = 48.0917
#     Worker 0: Train Loss: 2.2623, Train Accuracy: 40.56%
#     Worker 1: Train Loss: 2.2823, Train Accuracy: 39.96%
#     Worker 2: Train Loss: 2.2512, Train Accuracy: 40.65%
#     Worker 3: Train Loss: 2.2632, Train Accuracy: 40.47%
# Epoch 37: Test Loss: 2.2037, Test Accuracy: 42.41%
# Total Computation Time: 971.16 seconds
# Total Communication Time: 0.32 seconds
# Epoch 38, Iteration 1: H_t = 4, G_t = -2.1235, σ_t^2 = 38.7908
# Epoch 38, Iteration 2: H_t = 64, G_t = 1.9222, σ_t^2 = 32.7014
# Epoch 38, Iteration 3: H_t = 4, G_t = -0.8584, σ_t^2 = 45.1441
# Epoch 38, Iteration 4: H_t = 25, G_t = 0.3048, σ_t^2 = 36.1134
# Epoch 38, Iteration 5: H_t = 4, G_t = -1.0352, σ_t^2 = 45.2632
# Epoch 38, Iteration 6: H_t = 64, G_t = 2.9167, σ_t^2 = 44.4946
# Epoch 38, Iteration 7: H_t = 4, G_t = -1.2788, σ_t^2 = 48.6883
# Epoch 38, Iteration 8: H_t = 45, G_t = 0.6509, σ_t^2 = 42.5050
# Epoch 38, Iteration 9: H_t = 32, G_t = 0.4816, σ_t^2 = 44.9047
#     Worker 0: Train Loss: 2.2477, Train Accuracy: 40.44%
#     Worker 1: Train Loss: 2.2402, Train Accuracy: 40.84%
#     Worker 2: Train Loss: 2.2111, Train Accuracy: 41.91%
#     Worker 3: Train Loss: 2.2594, Train Accuracy: 40.52%
# Epoch 38: Test Loss: 2.1892, Test Accuracy: 43.17%
# Total Computation Time: 997.22 seconds
# Total Communication Time: 0.33 seconds
# Epoch 39, Iteration 1: H_t = 4, G_t = -1.2278, σ_t^2 = 43.1678
# Epoch 39, Iteration 2: H_t = 4, G_t = -0.9671, σ_t^2 = 44.1517
# Epoch 39, Iteration 3: H_t = 64, G_t = 2.7979, σ_t^2 = 38.3056
# Epoch 39, Iteration 4: H_t = 20, G_t = 0.2673, σ_t^2 = 39.3286
# Epoch 39, Iteration 5: H_t = 21, G_t = 0.2847, σ_t^2 = 40.6332
# Epoch 39, Iteration 6: H_t = 4, G_t = -1.2055, σ_t^2 = 48.1005
# Epoch 39, Iteration 7: H_t = 15, G_t = 0.2162, σ_t^2 = 42.2520
# Epoch 39, Iteration 8: H_t = 64, G_t = 1.6934, σ_t^2 = 50.3695
# Epoch 39, Iteration 9: H_t = 24, G_t = 0.3327, σ_t^2 = 41.2633
#     Worker 0: Train Loss: 2.2076, Train Accuracy: 41.69%
#     Worker 1: Train Loss: 2.2214, Train Accuracy: 41.13%
#     Worker 2: Train Loss: 2.1920, Train Accuracy: 42.36%
#     Worker 3: Train Loss: 2.2172, Train Accuracy: 41.46%
# Epoch 39: Test Loss: 2.1707, Test Accuracy: 43.18%
# Total Computation Time: 1024.16 seconds
# Total Communication Time: 0.34 seconds
# Epoch 40, Iteration 1: H_t = 4, G_t = -3.4034, σ_t^2 = 56.5956
# Epoch 40, Iteration 2: H_t = 38, G_t = 0.5942, σ_t^2 = 45.7321
# Epoch 40, Iteration 3: H_t = 4, G_t = -0.8201, σ_t^2 = 47.0815
# Epoch 40, Iteration 4: H_t = 47, G_t = 0.5551, σ_t^2 = 35.3567
# Epoch 40, Iteration 5: H_t = 6, G_t = 0.1084, σ_t^2 = 46.9757
# Epoch 40, Iteration 6: H_t = 4, G_t = -1.6144, σ_t^2 = 41.3439
# Epoch 40, Iteration 7: H_t = 4, G_t = -0.8942, σ_t^2 = 38.2355
# Epoch 40, Iteration 8: H_t = 4, G_t = -0.1501, σ_t^2 = 41.2489
# Epoch 40, Iteration 9: H_t = 64, G_t = 1.0267, σ_t^2 = 40.5912
# Epoch 40, Iteration 10: H_t = 4, G_t = -0.2421, σ_t^2 = 49.0667
#     Worker 0: Train Loss: 2.1943, Train Accuracy: 41.81%
#     Worker 1: Train Loss: 2.1934, Train Accuracy: 41.83%
#     Worker 2: Train Loss: 2.2135, Train Accuracy: 42.22%
#     Worker 3: Train Loss: 2.1903, Train Accuracy: 42.62%
# Epoch 40: Test Loss: 2.1493, Test Accuracy: 43.86%
# Total Computation Time: 1047.63 seconds
# Total Communication Time: 0.35 seconds
# Epoch 41, Iteration 1: H_t = 64, G_t = 1.4357, σ_t^2 = 34.5032
# Epoch 41, Iteration 2: H_t = 4, G_t = 0.0316, σ_t^2 = 42.6402
# Epoch 41, Iteration 3: H_t = 4, G_t = -0.6622, σ_t^2 = 47.2525
# Epoch 41, Iteration 4: H_t = 64, G_t = 2.4212, σ_t^2 = 38.0605
# Epoch 41, Iteration 5: H_t = 4, G_t = -0.4193, σ_t^2 = 41.2694
# Epoch 41, Iteration 6: H_t = 4, G_t = -0.5123, σ_t^2 = 38.3683
# Epoch 41, Iteration 7: H_t = 64, G_t = 1.8081, σ_t^2 = 39.9461
# Epoch 41, Iteration 8: H_t = 64, G_t = 1.0891, σ_t^2 = 44.3031
#     Worker 0: Train Loss: 2.1836, Train Accuracy: 41.82%
#     Worker 1: Train Loss: 2.2178, Train Accuracy: 41.23%
#     Worker 2: Train Loss: 2.1640, Train Accuracy: 42.99%
#     Worker 3: Train Loss: 2.1965, Train Accuracy: 41.64%
# Epoch 41: Test Loss: 2.1533, Test Accuracy: 43.50%
# Total Computation Time: 1072.51 seconds
# Total Communication Time: 0.36 seconds
# Epoch 42, Iteration 1: H_t = 4, G_t = -0.3107, σ_t^2 = 42.7980
# Epoch 42, Iteration 2: H_t = 4, G_t = -0.2843, σ_t^2 = 38.3997
# Epoch 42, Iteration 3: H_t = 4, G_t = -0.4876, σ_t^2 = 38.0757
# Epoch 42, Iteration 4: H_t = 10, G_t = 0.1417, σ_t^2 = 41.1488
# Epoch 42, Iteration 5: H_t = 60, G_t = 0.9479, σ_t^2 = 46.9875
# Epoch 42, Iteration 6: H_t = 4, G_t = -1.3486, σ_t^2 = 47.6797
# Epoch 42, Iteration 7: H_t = 4, G_t = -1.1252, σ_t^2 = 42.7328
# Epoch 42, Iteration 8: H_t = 64, G_t = 2.4155, σ_t^2 = 41.4581
# Epoch 42, Iteration 9: H_t = 64, G_t = 1.0432, σ_t^2 = 46.0859
#     Worker 0: Train Loss: 2.1582, Train Accuracy: 42.29%
#     Worker 1: Train Loss: 2.1848, Train Accuracy: 42.01%
#     Worker 2: Train Loss: 2.1452, Train Accuracy: 43.08%
#     Worker 3: Train Loss: 2.1754, Train Accuracy: 42.11%
# Epoch 42: Test Loss: 2.1405, Test Accuracy: 44.08%
# Total Computation Time: 1098.21 seconds
# Total Communication Time: 0.37 seconds
# Epoch 43, Iteration 1: H_t = 64, G_t = 2.6720, σ_t^2 = 43.9906
# Epoch 43, Iteration 2: H_t = 14, G_t = 0.2170, σ_t^2 = 44.5932
# Epoch 43, Iteration 3: H_t = 4, G_t = -1.7365, σ_t^2 = 47.9852
# Epoch 43, Iteration 4: H_t = 4, G_t = -0.8866, σ_t^2 = 45.2497
# Epoch 43, Iteration 5: H_t = 64, G_t = 1.5391, σ_t^2 = 40.2439
# Epoch 43, Iteration 6: H_t = 4, G_t = -2.5720, σ_t^2 = 49.2444
#     Worker 0: Train Loss: 2.1712, Train Accuracy: 42.21%
#     Worker 1: Train Loss: 2.1542, Train Accuracy: 43.11%
#     Worker 2: Train Loss: 2.1497, Train Accuracy: 43.14%
#     Worker 3: Train Loss: 2.1919, Train Accuracy: 42.54%
# Epoch 43: Test Loss: 2.1195, Test Accuracy: 44.83%
# Total Computation Time: 1123.88 seconds
# Total Communication Time: 0.38 seconds
# Epoch 44, Iteration 1: H_t = 34, G_t = 0.4375, σ_t^2 = 37.8685
# Epoch 44, Iteration 2: H_t = 4, G_t = -2.0799, σ_t^2 = 44.8242
# Epoch 44, Iteration 3: H_t = 60, G_t = 0.9541, σ_t^2 = 47.2298
# Epoch 44, Iteration 4: H_t = 4, G_t = -0.1367, σ_t^2 = 40.2676
# Epoch 44, Iteration 5: H_t = 20, G_t = 0.2898, σ_t^2 = 42.4077
# Epoch 44, Iteration 6: H_t = 4, G_t = -0.6273, σ_t^2 = 47.2676
# Epoch 44, Iteration 7: H_t = 64, G_t = 0.9997, σ_t^2 = 43.0803
# Epoch 44, Iteration 8: H_t = 64, G_t = 1.4384, σ_t^2 = 49.7731
# Epoch 44, Iteration 9: H_t = 4, G_t = -1.8670, σ_t^2 = 49.3414
#     Worker 0: Train Loss: 2.1252, Train Accuracy: 43.54%
#     Worker 1: Train Loss: 2.1152, Train Accuracy: 44.01%
#     Worker 2: Train Loss: 2.0867, Train Accuracy: 44.19%
#     Worker 3: Train Loss: 2.1393, Train Accuracy: 42.92%
# Epoch 44: Test Loss: 2.1124, Test Accuracy: 44.77%
# Total Computation Time: 1153.77 seconds
# Total Communication Time: 0.39 seconds
# Epoch 45, Iteration 1: H_t = 23, G_t = 0.3098, σ_t^2 = 40.1408
# Epoch 45, Iteration 2: H_t = 14, G_t = 0.2253, σ_t^2 = 46.3936
# Epoch 45, Iteration 3: H_t = 64, G_t = 1.1661, σ_t^2 = 47.9537
# Epoch 45, Iteration 4: H_t = 64, G_t = 1.5567, σ_t^2 = 45.6098
# Epoch 45, Iteration 5: H_t = 4, G_t = -2.1437, σ_t^2 = 46.9438
# Epoch 45, Iteration 6: H_t = 4, G_t = -0.0977, σ_t^2 = 40.1884
# Epoch 45, Iteration 7: H_t = 10, G_t = 0.1341, σ_t^2 = 40.0798
# Epoch 45, Iteration 8: H_t = 4, G_t = -0.4877, σ_t^2 = 46.2449
# Epoch 45, Iteration 9: H_t = 4, G_t = -0.3916, σ_t^2 = 42.6892
# Epoch 45, Iteration 10: H_t = 4, G_t = -0.2296, σ_t^2 = 47.7932
# Epoch 45, Iteration 11: H_t = 64, G_t = 1.1867, σ_t^2 = 49.4989
#     Worker 0: Train Loss: 2.0795, Train Accuracy: 44.30%
#     Worker 1: Train Loss: 2.1076, Train Accuracy: 44.04%
#     Worker 2: Train Loss: 2.0746, Train Accuracy: 45.11%
#     Worker 3: Train Loss: 2.1062, Train Accuracy: 43.74%
# Epoch 45: Test Loss: 2.1057, Test Accuracy: 44.88%
# Total Computation Time: 1176.69 seconds
# Total Communication Time: 0.40 seconds
# Epoch 46, Iteration 1: H_t = 64, G_t = 1.3494, σ_t^2 = 43.4173
# Epoch 46, Iteration 2: H_t = 64, G_t = 1.1402, σ_t^2 = 43.0505
# Epoch 46, Iteration 3: H_t = 55, G_t = 0.9052, σ_t^2 = 48.8812
# Epoch 46, Iteration 4: H_t = 21, G_t = 0.3099, σ_t^2 = 44.0907
#     Worker 0: Train Loss: 2.1017, Train Accuracy: 43.96%
#     Worker 1: Train Loss: 2.0883, Train Accuracy: 44.24%
#     Worker 2: Train Loss: 2.0734, Train Accuracy: 44.46%
#     Worker 3: Train Loss: 2.1147, Train Accuracy: 43.50%
# Epoch 46: Test Loss: 2.1046, Test Accuracy: 44.61%
# Total Computation Time: 1205.33 seconds
# Total Communication Time: 0.40 seconds
# Epoch 47, Iteration 1: H_t = 4, G_t = -0.0554, σ_t^2 = 51.4688
# Epoch 47, Iteration 2: H_t = 4, G_t = -0.2231, σ_t^2 = 41.8012
# Epoch 47, Iteration 3: H_t = 64, G_t = 0.9623, σ_t^2 = 38.5018
# Epoch 47, Iteration 4: H_t = 64, G_t = 1.8620, σ_t^2 = 46.7383
# Epoch 47, Iteration 5: H_t = 4, G_t = -0.9449, σ_t^2 = 56.4432
# Epoch 47, Iteration 6: H_t = 46, G_t = 0.6857, σ_t^2 = 44.5761
# Epoch 47, Iteration 7: H_t = 4, G_t = -1.8549, σ_t^2 = 55.0076
#     Worker 0: Train Loss: 2.0832, Train Accuracy: 44.18%
#     Worker 1: Train Loss: 2.0837, Train Accuracy: 43.81%
#     Worker 2: Train Loss: 2.0573, Train Accuracy: 45.14%
#     Worker 3: Train Loss: 2.0846, Train Accuracy: 44.26%
# Epoch 47: Test Loss: 2.0981, Test Accuracy: 45.17%
# Total Computation Time: 1229.51 seconds
# Total Communication Time: 0.41 seconds
# Epoch 48, Iteration 1: H_t = 4, G_t = -0.4502, σ_t^2 = 42.4695
# Epoch 48, Iteration 2: H_t = 4, G_t = -0.2069, σ_t^2 = 40.3572
# Epoch 48, Iteration 3: H_t = 64, G_t = 1.3894, σ_t^2 = 42.6808
# Epoch 48, Iteration 4: H_t = 40, G_t = 0.6031, σ_t^2 = 44.5388
# Epoch 48, Iteration 5: H_t = 33, G_t = 0.5133, σ_t^2 = 45.4073
# Epoch 48, Iteration 6: H_t = 64, G_t = 1.1082, σ_t^2 = 49.5333
# Epoch 48, Iteration 7: H_t = 4, G_t = -1.7747, σ_t^2 = 54.6319
#     Worker 0: Train Loss: 2.0689, Train Accuracy: 44.12%
#     Worker 1: Train Loss: 2.0386, Train Accuracy: 45.74%
#     Worker 2: Train Loss: 2.0356, Train Accuracy: 45.08%
#     Worker 3: Train Loss: 2.0533, Train Accuracy: 44.98%
# Epoch 48: Test Loss: 2.0798, Test Accuracy: 45.39%
# Total Computation Time: 1254.25 seconds
# Total Communication Time: 0.42 seconds
# Epoch 49, Iteration 1: H_t = 4, G_t = -0.2034, σ_t^2 = 41.4798
# Epoch 49, Iteration 2: H_t = 64, G_t = 1.4155, σ_t^2 = 42.7709
# Epoch 49, Iteration 3: H_t = 4, G_t = -1.8735, σ_t^2 = 47.6772
# Epoch 49, Iteration 4: H_t = 44, G_t = 0.7041, σ_t^2 = 47.2203
# Epoch 49, Iteration 5: H_t = 4, G_t = -0.5174, σ_t^2 = 43.5945
# Epoch 49, Iteration 6: H_t = 22, G_t = 0.3794, σ_t^2 = 49.9924
# Epoch 49, Iteration 7: H_t = 30, G_t = 0.4569, σ_t^2 = 45.2559
# Epoch 49, Iteration 8: H_t = 4, G_t = -3.8170, σ_t^2 = 57.1819
# Epoch 49, Iteration 9: H_t = 8, G_t = 0.1294, σ_t^2 = 46.1948
# Epoch 49, Iteration 10: H_t = 34, G_t = 0.5635, σ_t^2 = 48.3864
# Epoch 49, Iteration 11: H_t = 4, G_t = -0.1846, σ_t^2 = 52.5365
#     Worker 0: Train Loss: 2.0036, Train Accuracy: 46.31%
#     Worker 1: Train Loss: 2.0097, Train Accuracy: 46.57%
#     Worker 2: Train Loss: 1.9931, Train Accuracy: 46.66%
#     Worker 3: Train Loss: 2.0442, Train Accuracy: 45.50%
# Epoch 49: Test Loss: 2.0703, Test Accuracy: 46.18%
# Total Computation Time: 1280.22 seconds
# Total Communication Time: 0.43 seconds
# Epoch 50, Iteration 1: H_t = 4, G_t = -0.4910, σ_t^2 = 44.4218
# Epoch 50, Iteration 2: H_t = 64, G_t = 4.1776, σ_t^2 = 43.8583
# Epoch 50, Iteration 3: H_t = 4, G_t = -1.1653, σ_t^2 = 47.1203
# Epoch 50, Iteration 4: H_t = 44, G_t = 0.6269, σ_t^2 = 42.2668
# Epoch 50, Iteration 5: H_t = 46, G_t = 0.7957, σ_t^2 = 51.6115
# Epoch 50, Iteration 6: H_t = 4, G_t = -0.7136, σ_t^2 = 45.6088
# Epoch 50, Iteration 7: H_t = 4, G_t = -0.8173, σ_t^2 = 39.9291
# Epoch 50, Iteration 8: H_t = 64, G_t = 4.2580, σ_t^2 = 46.8496
# Epoch 50, Iteration 9: H_t = 25, G_t = 0.4016, σ_t^2 = 47.0610
#     Worker 0: Train Loss: 2.0102, Train Accuracy: 45.96%
#     Worker 1: Train Loss: 2.0248, Train Accuracy: 46.09%
#     Worker 2: Train Loss: 2.0083, Train Accuracy: 46.19%
#     Worker 3: Train Loss: 2.0147, Train Accuracy: 45.82%
# Epoch 50: Test Loss: 2.0581, Test Accuracy: 45.74%
# Total Computation Time: 1308.80 seconds
# Total Communication Time: 0.45 seconds
# Epoch 51, Iteration 1: H_t = 64, G_t = 3.1293, σ_t^2 = 50.8513
# Epoch 51, Iteration 2: H_t = 51, G_t = 1.0023, σ_t^2 = 58.9115
# Epoch 51, Iteration 3: H_t = 64, G_t = 1.1510, σ_t^2 = 52.9881
# Epoch 51, Iteration 4: H_t = 64, G_t = 2.1285, σ_t^2 = 52.3124
#     Worker 0: Train Loss: 2.0264, Train Accuracy: 45.10%
#     Worker 1: Train Loss: 2.0052, Train Accuracy: 46.13%
#     Worker 2: Train Loss: 1.9854, Train Accuracy: 46.71%
#     Worker 3: Train Loss: 2.0239, Train Accuracy: 45.77%
# Epoch 51: Test Loss: 2.0497, Test Accuracy: 46.24%
# Total Computation Time: 1332.81 seconds
# Total Communication Time: 0.45 seconds
# Epoch 52, Iteration 1: H_t = 4, G_t = -0.6329, σ_t^2 = 45.0834
# Epoch 52, Iteration 2: H_t = 64, G_t = 0.9803, σ_t^2 = 45.0528
# Epoch 52, Iteration 3: H_t = 4, G_t = -2.6511, σ_t^2 = 53.5374
# Epoch 52, Iteration 4: H_t = 64, G_t = 2.8449, σ_t^2 = 44.5805
# Epoch 52, Iteration 5: H_t = 64, G_t = 1.5275, σ_t^2 = 52.5708
#     Worker 0: Train Loss: 1.9805, Train Accuracy: 46.50%
#     Worker 1: Train Loss: 2.0020, Train Accuracy: 46.59%
#     Worker 2: Train Loss: 1.9731, Train Accuracy: 46.70%
#     Worker 3: Train Loss: 2.0045, Train Accuracy: 46.17%
# Epoch 52: Test Loss: 2.0490, Test Accuracy: 46.67%
# Total Computation Time: 1355.96 seconds
# Total Communication Time: 0.46 seconds
# Epoch 53, Iteration 1: H_t = 48, G_t = 0.7370, σ_t^2 = 45.4501
# Epoch 53, Iteration 2: H_t = 19, G_t = 0.3239, σ_t^2 = 50.3344
# Epoch 53, Iteration 3: H_t = 4, G_t = -1.3733, σ_t^2 = 50.4783
# Epoch 53, Iteration 4: H_t = 4, G_t = 0.0073, σ_t^2 = 51.2019
# Epoch 53, Iteration 5: H_t = 64, G_t = 3.8841, σ_t^2 = 42.7596
# Epoch 53, Iteration 6: H_t = 4, G_t = -0.4726, σ_t^2 = 48.0096
#     Worker 0: Train Loss: 1.9707, Train Accuracy: 46.68%
#     Worker 1: Train Loss: 1.9910, Train Accuracy: 46.25%
#     Worker 2: Train Loss: 1.9438, Train Accuracy: 47.75%
#     Worker 3: Train Loss: 1.9964, Train Accuracy: 46.51%
# Epoch 53: Test Loss: 2.0313, Test Accuracy: 46.61%
# Total Computation Time: 1379.56 seconds
# Total Communication Time: 0.46 seconds
# Epoch 54, Iteration 1: H_t = 4, G_t = 0.0273, σ_t^2 = 41.8636
# Epoch 54, Iteration 2: H_t = 64, G_t = 0.9312, σ_t^2 = 40.9817
# Epoch 54, Iteration 3: H_t = 64, G_t = 1.1889, σ_t^2 = 53.3672
# Epoch 54, Iteration 4: H_t = 4, G_t = -2.4445, σ_t^2 = 58.8803
# Epoch 54, Iteration 5: H_t = 4, G_t = -0.3799, σ_t^2 = 45.4031
# Epoch 54, Iteration 6: H_t = 4, G_t = -0.9099, σ_t^2 = 51.2121
# Epoch 54, Iteration 7: H_t = 4, G_t = -0.3703, σ_t^2 = 50.3583
# Epoch 54, Iteration 8: H_t = 64, G_t = 3.7398, σ_t^2 = 47.8471
# Epoch 54, Iteration 9: H_t = 4, G_t = -1.4242, σ_t^2 = 53.2097
#     Worker 0: Train Loss: 1.9545, Train Accuracy: 47.40%
#     Worker 1: Train Loss: 1.9515, Train Accuracy: 47.68%
#     Worker 2: Train Loss: 1.9406, Train Accuracy: 47.58%
#     Worker 3: Train Loss: 1.9726, Train Accuracy: 46.99%
# Epoch 54: Test Loss: 2.0301, Test Accuracy: 46.62%
# Total Computation Time: 1404.69 seconds
# Total Communication Time: 0.47 seconds
# Epoch 55, Iteration 1: H_t = 64, G_t = 4.8489, σ_t^2 = 45.8779
# Epoch 55, Iteration 2: H_t = 43, G_t = 0.8247, σ_t^2 = 57.3040
# Epoch 55, Iteration 3: H_t = 64, G_t = 1.2578, σ_t^2 = 45.9207
# Epoch 55, Iteration 4: H_t = 4, G_t = -1.2739, σ_t^2 = 47.2065
# Epoch 55, Iteration 5: H_t = 64, G_t = 1.2011, σ_t^2 = 44.1982
# Epoch 55, Iteration 6: H_t = 64, G_t = 3.7862, σ_t^2 = 48.9494
#     Worker 0: Train Loss: 1.9301, Train Accuracy: 47.85%
#     Worker 1: Train Loss: 1.9309, Train Accuracy: 48.04%
#     Worker 2: Train Loss: 1.9252, Train Accuracy: 48.21%
#     Worker 3: Train Loss: 1.9449, Train Accuracy: 47.52%
# Epoch 55: Test Loss: 2.0262, Test Accuracy: 47.21%
# Total Computation Time: 1432.82 seconds
# Total Communication Time: 0.48 seconds
# Epoch 56, Iteration 1: H_t = 4, G_t = -2.2494, σ_t^2 = 54.2732
# Epoch 56, Iteration 2: H_t = 4, G_t = -0.0014, σ_t^2 = 52.3316
# Epoch 56, Iteration 3: H_t = 36, G_t = 0.5443, σ_t^2 = 45.3273
# Epoch 56, Iteration 4: H_t = 16, G_t = 0.3290, σ_t^2 = 58.0649
# Epoch 56, Iteration 5: H_t = 64, G_t = 1.8084, σ_t^2 = 58.4668
# Epoch 56, Iteration 6: H_t = 4, G_t = -1.0514, σ_t^2 = 70.3028
# Epoch 56, Iteration 7: H_t = 6, G_t = 0.1315, σ_t^2 = 56.5923
# Epoch 56, Iteration 8: H_t = 21, G_t = 0.3507, σ_t^2 = 49.7684
#     Worker 0: Train Loss: 1.9279, Train Accuracy: 47.80%
#     Worker 1: Train Loss: 1.9076, Train Accuracy: 48.48%
#     Worker 2: Train Loss: 1.9033, Train Accuracy: 48.66%
#     Worker 3: Train Loss: 1.9257, Train Accuracy: 48.29%
# Epoch 56: Test Loss: 2.0145, Test Accuracy: 47.44%
# Total Computation Time: 1455.86 seconds
# Total Communication Time: 0.49 seconds
# Epoch 57, Iteration 1: H_t = 23, G_t = 0.3862, σ_t^2 = 48.7944
# Epoch 57, Iteration 2: H_t = 4, G_t = 0.0381, σ_t^2 = 52.7727
# Epoch 57, Iteration 3: H_t = 64, G_t = 1.4437, σ_t^2 = 46.7565
# Epoch 57, Iteration 4: H_t = 4, G_t = -0.8202, σ_t^2 = 54.7601
# Epoch 57, Iteration 5: H_t = 64, G_t = 2.2431, σ_t^2 = 46.0954
# Epoch 57, Iteration 6: H_t = 4, G_t = -1.1317, σ_t^2 = 50.7096
# Epoch 57, Iteration 7: H_t = 64, G_t = 1.3780, σ_t^2 = 55.7646
# Epoch 57, Iteration 8: H_t = 4, G_t = -1.8269, σ_t^2 = 55.5159
#     Worker 0: Train Loss: 1.9049, Train Accuracy: 47.75%
#     Worker 1: Train Loss: 1.9295, Train Accuracy: 48.44%
#     Worker 2: Train Loss: 1.8801, Train Accuracy: 48.91%
#     Worker 3: Train Loss: 1.9095, Train Accuracy: 48.56%
# Epoch 57: Test Loss: 2.0172, Test Accuracy: 46.93%
# Total Computation Time: 1485.70 seconds
# Total Communication Time: 0.50 seconds
# Epoch 58, Iteration 1: H_t = 4, G_t = -1.2364, σ_t^2 = 48.6784
# Epoch 58, Iteration 2: H_t = 64, G_t = 1.6322, σ_t^2 = 47.9091
# Epoch 58, Iteration 3: H_t = 64, G_t = 1.2655, σ_t^2 = 50.1399
# Epoch 58, Iteration 4: H_t = 4, G_t = -1.1831, σ_t^2 = 66.3330
# Epoch 58, Iteration 5: H_t = 64, G_t = 0.9663, σ_t^2 = 41.5715
# Epoch 58, Iteration 6: H_t = 17, G_t = 0.3221, σ_t^2 = 56.8049
#     Worker 0: Train Loss: 1.8781, Train Accuracy: 49.11%
#     Worker 1: Train Loss: 1.8888, Train Accuracy: 49.11%
#     Worker 2: Train Loss: 1.8927, Train Accuracy: 48.36%
#     Worker 3: Train Loss: 1.9152, Train Accuracy: 48.25%
# Epoch 58: Test Loss: 2.0049, Test Accuracy: 47.42%
# Total Computation Time: 1509.55 seconds
# Total Communication Time: 0.51 seconds
# Epoch 59, Iteration 1: H_t = 39, G_t = 0.7165, σ_t^2 = 54.7837
# Epoch 59, Iteration 2: H_t = 4, G_t = -2.0688, σ_t^2 = 57.9935
# Epoch 59, Iteration 3: H_t = 4, G_t = -0.0674, σ_t^2 = 50.2410
# Epoch 59, Iteration 4: H_t = 4, G_t = -2.2917, σ_t^2 = 66.1519
# Epoch 59, Iteration 5: H_t = 64, G_t = 1.4640, σ_t^2 = 47.3543
# Epoch 59, Iteration 6: H_t = 4, G_t = -1.7470, σ_t^2 = 65.3813
# Epoch 59, Iteration 7: H_t = 4, G_t = -0.1871, σ_t^2 = 47.2492
# Epoch 59, Iteration 8: H_t = 64, G_t = 2.4255, σ_t^2 = 53.6167
# ...
#     Worker 2: Train Loss: 1.2353, Train Accuracy: 65.01%
#     Worker 3: Train Loss: 1.2277, Train Accuracy: 65.07%
# Epoch 136: Test Loss: 1.9402, Test Accuracy: 51.18%
# Total Computation Time: 3553.66 seconds
# Total Communication Time: 1.36 seconds
# Epoch 137, Iteration 1: H_t = 64, G_t = 2.3373, σ_t^2 = 97.6567
# Epoch 137, Iteration 2: H_t = 64, G_t = 2.0285, σ_t^2 = 91.3773
# Epoch 137, Iteration 3: H_t = 4, G_t = -1.1122, σ_t^2 = 95.6161
# Epoch 137, Iteration 4: H_t = 18, G_t = 0.4949, σ_t^2 = 80.4326
# Epoch 137, Iteration 5: H_t = 4, G_t = -1.0715, σ_t^2 = 98.5498
# Epoch 137, Iteration 6: H_t = 64, G_t = 5.9239, σ_t^2 = 90.8414
# Epoch 137, Iteration 7: H_t = 4, G_t = -0.5547, σ_t^2 = 105.2817
#     Worker 0: Train Loss: 1.2344, Train Accuracy: 64.81%
#     Worker 1: Train Loss: 1.2180, Train Accuracy: 65.74%
#     Worker 2: Train Loss: 1.2139, Train Accuracy: 65.58%
#     Worker 3: Train Loss: 1.2056, Train Accuracy: 65.74%
# Epoch 137: Test Loss: 1.9412, Test Accuracy: 50.92%
# Total Computation Time: 3580.54 seconds
# Total Communication Time: 1.36 seconds
# Epoch 138, Iteration 1: H_t = 8, G_t = 0.2409, σ_t^2 = 86.5640
# Epoch 138, Iteration 2: H_t = 64, G_t = 2.2894, σ_t^2 = 95.8182
# Epoch 138, Iteration 3: H_t = 53, G_t = 1.9005, σ_t^2 = 106.3694
# Epoch 138, Iteration 4: H_t = 64, G_t = 2.2723, σ_t^2 = 89.2344
# Epoch 138, Iteration 5: H_t = 17, G_t = 0.5096, σ_t^2 = 85.6508
# Epoch 138, Iteration 6: H_t = 4, G_t = -2.3778, σ_t^2 = 97.8295
#     Worker 0: Train Loss: 1.1973, Train Accuracy: 66.18%
#     Worker 1: Train Loss: 1.2082, Train Accuracy: 66.29%
#     Worker 2: Train Loss: 1.1938, Train Accuracy: 66.31%
#     Worker 3: Train Loss: 1.2062, Train Accuracy: 65.78%
# Epoch 138: Test Loss: 1.9430, Test Accuracy: 51.10%
# Total Computation Time: 3605.14 seconds
# Total Communication Time: 1.37 seconds
# Epoch 139, Iteration 1: H_t = 51, G_t = 1.5939, σ_t^2 = 92.5147
# Epoch 139, Iteration 2: H_t = 21, G_t = 0.5861, σ_t^2 = 82.8885
# Epoch 139, Iteration 3: H_t = 4, G_t = -3.7088, σ_t^2 = 106.7190
# Epoch 139, Iteration 4: H_t = 4, G_t = -0.6648, σ_t^2 = 95.2288
# Epoch 139, Iteration 5: H_t = 4, G_t = -0.0651, σ_t^2 = 85.9745
# Epoch 139, Iteration 6: H_t = 4, G_t = -2.4466, σ_t^2 = 91.7631
# Epoch 139, Iteration 7: H_t = 4, G_t = -0.7242, σ_t^2 = 94.5867
# Epoch 139, Iteration 8: H_t = 4, G_t = -0.8866, σ_t^2 = 77.4819
# Epoch 139, Iteration 9: H_t = 4, G_t = -0.0998, σ_t^2 = 88.1033
# Epoch 139, Iteration 10: H_t = 46, G_t = 1.4297, σ_t^2 = 92.1795
# Epoch 139, Iteration 11: H_t = 4, G_t = -0.6153, σ_t^2 = 97.4657
# Epoch 139, Iteration 12: H_t = 4, G_t = -1.9058, σ_t^2 = 111.7766
# Epoch 139, Iteration 13: H_t = 64, G_t = 3.6656, σ_t^2 = 93.8074
# Epoch 139, Iteration 14: H_t = 4, G_t = -2.3580, σ_t^2 = 108.1757
#     Worker 0: Train Loss: 1.2371, Train Accuracy: 64.88%
#     Worker 1: Train Loss: 1.2019, Train Accuracy: 66.09%
#     Worker 2: Train Loss: 1.2071, Train Accuracy: 66.12%
#     Worker 3: Train Loss: 1.2244, Train Accuracy: 65.09%
# Epoch 139: Test Loss: 1.9430, Test Accuracy: 50.96%
# Total Computation Time: 3631.04 seconds
# Total Communication Time: 1.39 seconds
# Epoch 140, Iteration 1: H_t = 29, G_t = 0.8856, σ_t^2 = 90.6351
# Epoch 140, Iteration 2: H_t = 64, G_t = 3.8722, σ_t^2 = 89.9193
# Epoch 140, Iteration 3: H_t = 4, G_t = -0.9097, σ_t^2 = 91.4649
# Epoch 140, Iteration 4: H_t = 4, G_t = -0.2202, σ_t^2 = 93.5002
# Epoch 140, Iteration 5: H_t = 4, G_t = -0.0995, σ_t^2 = 95.8209
# Epoch 140, Iteration 6: H_t = 8, G_t = 0.2853, σ_t^2 = 97.0943
# Epoch 140, Iteration 7: H_t = 35, G_t = 1.0960, σ_t^2 = 91.9963
# Epoch 140, Iteration 8: H_t = 4, G_t = -1.9356, σ_t^2 = 79.2058
# Epoch 140, Iteration 9: H_t = 4, G_t = -0.0819, σ_t^2 = 82.2458
# Epoch 140, Iteration 10: H_t = 24, G_t = 0.8182, σ_t^2 = 100.4787
# Epoch 140, Iteration 11: H_t = 4, G_t = -1.4699, σ_t^2 = 91.9226
# Epoch 140, Iteration 12: H_t = 9, G_t = 0.2605, σ_t^2 = 82.6110
# Epoch 140, Iteration 13: H_t = 30, G_t = 0.9850, σ_t^2 = 97.1298
#     Worker 0: Train Loss: 1.2302, Train Accuracy: 64.79%
#     Worker 1: Train Loss: 1.1982, Train Accuracy: 65.91%
#     Worker 2: Train Loss: 1.2103, Train Accuracy: 66.15%
#     Worker 3: Train Loss: 1.2158, Train Accuracy: 65.60%
# Epoch 140: Test Loss: 1.9434, Test Accuracy: 50.91%
# Total Computation Time: 3654.25 seconds
# Total Communication Time: 1.40 seconds
# Epoch 141, Iteration 1: H_t = 4, G_t = -0.8963, σ_t^2 = 94.7463
# Epoch 141, Iteration 2: H_t = 4, G_t = -0.2755, σ_t^2 = 92.4907
# Epoch 141, Iteration 3: H_t = 4, G_t = 0.1338, σ_t^2 = 85.9674
# Epoch 141, Iteration 4: H_t = 4, G_t = -0.8876, σ_t^2 = 81.9649
# Epoch 141, Iteration 5: H_t = 4, G_t = -1.2625, σ_t^2 = 93.4812
# Epoch 141, Iteration 6: H_t = 26, G_t = 0.7782, σ_t^2 = 87.8645
# Epoch 141, Iteration 7: H_t = 4, G_t = -1.8301, σ_t^2 = 100.9437
# Epoch 141, Iteration 8: H_t = 4, G_t = -0.1994, σ_t^2 = 92.7235
# Epoch 141, Iteration 9: H_t = 25, G_t = 0.8162, σ_t^2 = 94.3955
# Epoch 141, Iteration 10: H_t = 4, G_t = -1.0379, σ_t^2 = 100.9833
# Epoch 141, Iteration 11: H_t = 4, G_t = -3.3563, σ_t^2 = 92.1737
# Epoch 141, Iteration 12: H_t = 4, G_t = -0.2975, σ_t^2 = 83.2907
# Epoch 141, Iteration 13: H_t = 31, G_t = 1.1061, σ_t^2 = 104.9046
# Epoch 141, Iteration 14: H_t = 4, G_t = -1.9673, σ_t^2 = 107.8706
# Epoch 141, Iteration 15: H_t = 4, G_t = -2.1084, σ_t^2 = 90.4258
# Epoch 141, Iteration 16: H_t = 4, G_t = -3.1411, σ_t^2 = 92.5098
# Epoch 141, Iteration 17: H_t = 64, G_t = 2.2316, σ_t^2 = 87.4143
# Epoch 141, Iteration 18: H_t = 4, G_t = -0.5991, σ_t^2 = 101.2601
#     Worker 0: Train Loss: 1.2111, Train Accuracy: 65.71%
#     Worker 1: Train Loss: 1.2047, Train Accuracy: 66.26%
#     Worker 2: Train Loss: 1.1984, Train Accuracy: 66.56%
#     Worker 3: Train Loss: 1.2197, Train Accuracy: 65.95%
# Epoch 141: Test Loss: 1.9429, Test Accuracy: 51.02%
# Total Computation Time: 3681.30 seconds
# Total Communication Time: 1.42 seconds
# Epoch 142, Iteration 1: H_t = 9, G_t = 0.8967, σ_t^2 = 273.2671
# Epoch 142, Iteration 2: H_t = 4, G_t = -0.3626, σ_t^2 = 86.7132
# Epoch 142, Iteration 3: H_t = 4, G_t = -0.6699, σ_t^2 = 110.1463
# Epoch 142, Iteration 4: H_t = 44, G_t = 1.5923, σ_t^2 = 106.5174
# Epoch 142, Iteration 5: H_t = 4, G_t = 0.1162, σ_t^2 = 78.4980
# Epoch 142, Iteration 6: H_t = 4, G_t = -1.5213, σ_t^2 = 94.7895
# Epoch 142, Iteration 7: H_t = 64, G_t = 2.8495, σ_t^2 = 84.2845
# Epoch 142, Iteration 8: H_t = 4, G_t = -0.2580, σ_t^2 = 108.0992
# Epoch 142, Iteration 9: H_t = 4, G_t = 0.0453, σ_t^2 = 81.5027
# Epoch 142, Iteration 10: H_t = 4, G_t = -1.2197, σ_t^2 = 104.3545
# Epoch 142, Iteration 11: H_t = 4, G_t = -0.1423, σ_t^2 = 94.7817
# Epoch 142, Iteration 12: H_t = 4, G_t = -1.4000, σ_t^2 = 112.8287
# Epoch 142, Iteration 13: H_t = 47, G_t = 1.7241, σ_t^2 = 109.2117
# Epoch 142, Iteration 14: H_t = 37, G_t = 1.2010, σ_t^2 = 95.4874
#     Worker 0: Train Loss: 1.2165, Train Accuracy: 65.41%
#     Worker 1: Train Loss: 1.1971, Train Accuracy: 66.48%
#     Worker 2: Train Loss: 1.1940, Train Accuracy: 66.56%
#     Worker 3: Train Loss: 1.2106, Train Accuracy: 65.80%
# Epoch 142: Test Loss: 1.9426, Test Accuracy: 51.01%
# Total Computation Time: 3705.23 seconds
# Total Communication Time: 1.44 seconds
# Epoch 143, Iteration 1: H_t = 55, G_t = 1.7139, σ_t^2 = 93.0691
# Epoch 143, Iteration 2: H_t = 4, G_t = -1.4676, σ_t^2 = 85.4328
# Epoch 143, Iteration 3: H_t = 64, G_t = 2.1958, σ_t^2 = 95.4983
# Epoch 143, Iteration 4: H_t = 64, G_t = 1.8819, σ_t^2 = 85.9015
# Epoch 143, Iteration 5: H_t = 17, G_t = 0.5616, σ_t^2 = 97.4247
#     Worker 0: Train Loss: 1.2029, Train Accuracy: 65.62%
#     Worker 1: Train Loss: 1.2036, Train Accuracy: 65.90%
#     Worker 2: Train Loss: 1.1988, Train Accuracy: 66.46%
#     Worker 3: Train Loss: 1.2294, Train Accuracy: 65.71%
# Epoch 143: Test Loss: 1.9430, Test Accuracy: 50.99%
# Total Computation Time: 3731.93 seconds
# Total Communication Time: 1.45 seconds
# Epoch 144, Iteration 1: H_t = 4, G_t = -0.0188, σ_t^2 = 96.6498
# Epoch 144, Iteration 2: H_t = 4, G_t = -1.1452, σ_t^2 = 100.7614
# Epoch 144, Iteration 3: H_t = 4, G_t = -0.5399, σ_t^2 = 96.4964
# Epoch 144, Iteration 4: H_t = 22, G_t = 0.6771, σ_t^2 = 91.7407
# Epoch 144, Iteration 5: H_t = 4, G_t = -0.3686, σ_t^2 = 88.4685
# Epoch 144, Iteration 6: H_t = 64, G_t = 3.2674, σ_t^2 = 102.5167
# Epoch 144, Iteration 7: H_t = 4, G_t = -1.9919, σ_t^2 = 91.3571
# Epoch 144, Iteration 8: H_t = 64, G_t = 3.5337, σ_t^2 = 95.2960
# Epoch 144, Iteration 9: H_t = 4, G_t = -1.7322, σ_t^2 = 97.4168
# Epoch 144, Iteration 10: H_t = 25, G_t = 0.8025, σ_t^2 = 95.4192
# Epoch 144, Iteration 11: H_t = 35, G_t = 1.0232, σ_t^2 = 85.6362
#     Worker 0: Train Loss: 1.2000, Train Accuracy: 66.15%
#     Worker 1: Train Loss: 1.1990, Train Accuracy: 66.31%
#     Worker 2: Train Loss: 1.1940, Train Accuracy: 65.97%
#     Worker 3: Train Loss: 1.2066, Train Accuracy: 65.62%
# Epoch 144: Test Loss: 1.9433, Test Accuracy: 51.03%
# Total Computation Time: 3757.25 seconds
# Total Communication Time: 1.46 seconds
# Epoch 145, Iteration 1: H_t = 4, G_t = -0.8525, σ_t^2 = 95.3222
# Epoch 145, Iteration 2: H_t = 4, G_t = -3.3539, σ_t^2 = 95.7892
# Epoch 145, Iteration 3: H_t = 4, G_t = -1.4085, σ_t^2 = 91.3072
# Epoch 145, Iteration 4: H_t = 55, G_t = 1.9029, σ_t^2 = 103.6786
# Epoch 145, Iteration 5: H_t = 4, G_t = -1.7441, σ_t^2 = 101.9898
# Epoch 145, Iteration 6: H_t = 4, G_t = -1.2902, σ_t^2 = 93.4098
# Epoch 145, Iteration 7: H_t = 4, G_t = 0.1049, σ_t^2 = 86.1924
# Epoch 145, Iteration 8: H_t = 4, G_t = -0.1632, σ_t^2 = 115.5283
# Epoch 145, Iteration 9: H_t = 4, G_t = -2.5100, σ_t^2 = 100.6257
# Epoch 145, Iteration 10: H_t = 4, G_t = -0.8188, σ_t^2 = 105.6920
# Epoch 145, Iteration 11: H_t = 4, G_t = -0.0092, σ_t^2 = 82.8397
# Epoch 145, Iteration 12: H_t = 4, G_t = -2.4258, σ_t^2 = 90.0373
# Epoch 145, Iteration 13: H_t = 4, G_t = -1.5671, σ_t^2 = 99.8011
# Epoch 145, Iteration 14: H_t = 4, G_t = -0.1064, σ_t^2 = 101.9069
# Epoch 145, Iteration 15: H_t = 4, G_t = -0.5232, σ_t^2 = 107.6901
# Epoch 145, Iteration 16: H_t = 4, G_t = -1.0253, σ_t^2 = 93.5206
# Epoch 145, Iteration 17: H_t = 54, G_t = 1.7719, σ_t^2 = 97.5668
# Epoch 145, Iteration 18: H_t = 64, G_t = 5.7687, σ_t^2 = 96.4728
#     Worker 0: Train Loss: 1.2278, Train Accuracy: 65.38%
#     Worker 1: Train Loss: 1.1996, Train Accuracy: 66.15%
#     Worker 2: Train Loss: 1.2067, Train Accuracy: 66.34%
#     Worker 3: Train Loss: 1.2234, Train Accuracy: 65.17%
# Epoch 145: Test Loss: 1.9433, Test Accuracy: 51.09%
# Total Computation Time: 3781.21 seconds
# Total Communication Time: 1.48 seconds
# Epoch 146, Iteration 1: H_t = 4, G_t = -0.9093, σ_t^2 = 88.2119
# Epoch 146, Iteration 2: H_t = 17, G_t = 0.5531, σ_t^2 = 95.2894
# Epoch 146, Iteration 3: H_t = 17, G_t = 0.5635, σ_t^2 = 99.0906
# Epoch 146, Iteration 4: H_t = 4, G_t = -2.1259, σ_t^2 = 102.5445
# Epoch 146, Iteration 5: H_t = 47, G_t = 1.5049, σ_t^2 = 94.1180
# Epoch 146, Iteration 6: H_t = 4, G_t = -3.0704, σ_t^2 = 100.5088
# Epoch 146, Iteration 7: H_t = 42, G_t = 1.2779, σ_t^2 = 89.9234
# Epoch 146, Iteration 8: H_t = 4, G_t = -1.5423, σ_t^2 = 96.1518
#     Worker 0: Train Loss: 1.1948, Train Accuracy: 65.72%
#     Worker 1: Train Loss: 1.2041, Train Accuracy: 65.99%
#     Worker 2: Train Loss: 1.2096, Train Accuracy: 65.95%
#     Worker 3: Train Loss: 1.2323, Train Accuracy: 65.24%
# Epoch 146: Test Loss: 1.9430, Test Accuracy: 50.97%
# Total Computation Time: 3804.37 seconds
# Total Communication Time: 1.49 seconds
# Epoch 147, Iteration 1: H_t = 4, G_t = -0.7782, σ_t^2 = 100.8653
# Epoch 147, Iteration 2: H_t = 59, G_t = 1.9464, σ_t^2 = 98.2240
# Epoch 147, Iteration 3: H_t = 32, G_t = 1.0198, σ_t^2 = 95.3966
# Epoch 147, Iteration 4: H_t = 4, G_t = -0.6912, σ_t^2 = 96.3962
# Epoch 147, Iteration 5: H_t = 4, G_t = -0.4220, σ_t^2 = 100.1179
# Epoch 147, Iteration 6: H_t = 64, G_t = 3.8881, σ_t^2 = 85.4196
# Epoch 147, Iteration 7: H_t = 4, G_t = -0.0419, σ_t^2 = 87.9679
# Epoch 147, Iteration 8: H_t = 38, G_t = 1.3928, σ_t^2 = 107.2984
# Epoch 147, Iteration 9: H_t = 4, G_t = -0.6378, σ_t^2 = 96.7885
#     Worker 0: Train Loss: 1.2203, Train Accuracy: 65.68%
#     Worker 1: Train Loss: 1.1928, Train Accuracy: 66.38%
#     Worker 2: Train Loss: 1.1916, Train Accuracy: 66.26%
#     Worker 3: Train Loss: 1.1982, Train Accuracy: 65.79%
# Epoch 147: Test Loss: 1.9429, Test Accuracy: 51.07%
# Total Computation Time: 3829.22 seconds
# Total Communication Time: 1.50 seconds
# Epoch 148, Iteration 1: H_t = 4, G_t = -2.2282, σ_t^2 = 101.9322
# Epoch 148, Iteration 2: H_t = 5, G_t = 0.1687, σ_t^2 = 87.2420
# Epoch 148, Iteration 3: H_t = 4, G_t = -0.6393, σ_t^2 = 94.6357
# Epoch 148, Iteration 4: H_t = 4, G_t = -0.9589, σ_t^2 = 100.2488
# Epoch 148, Iteration 5: H_t = 4, G_t = -0.0727, σ_t^2 = 85.6945
# Epoch 148, Iteration 6: H_t = 34, G_t = 1.0800, σ_t^2 = 95.1765
# Epoch 148, Iteration 7: H_t = 4, G_t = -1.8992, σ_t^2 = 116.9115
# Epoch 148, Iteration 8: H_t = 39, G_t = 1.1238, σ_t^2 = 84.9361
# Epoch 148, Iteration 9: H_t = 4, G_t = -0.4676, σ_t^2 = 97.7009
# Epoch 148, Iteration 10: H_t = 4, G_t = -3.0275, σ_t^2 = 105.5747
# Epoch 148, Iteration 11: H_t = 4, G_t = -0.7955, σ_t^2 = 98.3264
# Epoch 148, Iteration 12: H_t = 4, G_t = -2.8027, σ_t^2 = 123.6337
# Epoch 148, Iteration 13: H_t = 64, G_t = 1.9448, σ_t^2 = 89.6828
# Epoch 148, Iteration 14: H_t = 33, G_t = 1.0638, σ_t^2 = 95.1050
# Epoch 148, Iteration 15: H_t = 4, G_t = -1.1441, σ_t^2 = 98.7676
#     Worker 0: Train Loss: 1.2322, Train Accuracy: 64.97%
#     Worker 1: Train Loss: 1.2169, Train Accuracy: 65.82%
#     Worker 2: Train Loss: 1.2074, Train Accuracy: 66.26%
#     Worker 3: Train Loss: 1.2198, Train Accuracy: 65.94%
# Epoch 148: Test Loss: 1.9430, Test Accuracy: 51.12%
# Total Computation Time: 3854.60 seconds
# Total Communication Time: 1.52 seconds
# Epoch 149, Iteration 1: H_t = 18, G_t = 0.6026, σ_t^2 = 96.8856
# Epoch 149, Iteration 2: H_t = 4, G_t = -0.5380, σ_t^2 = 88.7596
# Epoch 149, Iteration 3: H_t = 26, G_t = 0.8501, σ_t^2 = 95.0171
# Epoch 149, Iteration 4: H_t = 4, G_t = -1.6696, σ_t^2 = 94.2766
# Epoch 149, Iteration 5: H_t = 4, G_t = -0.1849, σ_t^2 = 81.2622
# Epoch 149, Iteration 6: H_t = 4, G_t = -3.6245, σ_t^2 = 95.7045
# Epoch 149, Iteration 7: H_t = 4, G_t = -2.0786, σ_t^2 = 107.5675
# Epoch 149, Iteration 8: H_t = 4, G_t = -0.5227, σ_t^2 = 87.4477
# Epoch 149, Iteration 9: H_t = 53, G_t = 1.6083, σ_t^2 = 89.4461
# Epoch 149, Iteration 10: H_t = 13, G_t = 0.4396, σ_t^2 = 94.2771
# Epoch 149, Iteration 11: H_t = 4, G_t = -2.2193, σ_t^2 = 98.4811
# Epoch 149, Iteration 12: H_t = 14, G_t = 0.5069, σ_t^2 = 105.2301
# Epoch 149, Iteration 13: H_t = 29, G_t = 0.8796, σ_t^2 = 88.2646
# Epoch 149, Iteration 14: H_t = 36, G_t = 1.2822, σ_t^2 = 104.8563
# Epoch 149, Iteration 15: H_t = 4, G_t = -0.9119, σ_t^2 = 78.9288
#     Worker 0: Train Loss: 1.2043, Train Accuracy: 65.47%
#     Worker 1: Train Loss: 1.2085, Train Accuracy: 66.17%
#     Worker 2: Train Loss: 1.1881, Train Accuracy: 66.82%
#     Worker 3: Train Loss: 1.2202, Train Accuracy: 65.52%
# Epoch 149: Test Loss: 1.9430, Test Accuracy: 51.08%
# Total Computation Time: 3880.63 seconds
# Total Communication Time: 1.54 seconds
# Epoch 150, Iteration 1: H_t = 13, G_t = 0.4419, σ_t^2 = 95.8844
# Epoch 150, Iteration 2: H_t = 4, G_t = -1.4114, σ_t^2 = 90.4582
# Epoch 150, Iteration 3: H_t = 4, G_t = -1.8280, σ_t^2 = 93.8041
# Epoch 150, Iteration 4: H_t = 53, G_t = 1.5210, σ_t^2 = 84.5670
# Epoch 150, Iteration 5: H_t = 10, G_t = 0.3282, σ_t^2 = 94.1312
# Epoch 150, Iteration 6: H_t = 12, G_t = 0.3541, σ_t^2 = 86.5487
# Epoch 150, Iteration 7: H_t = 27, G_t = 0.8310, σ_t^2 = 90.6694
# Epoch 150, Iteration 8: H_t = 4, G_t = -2.1015, σ_t^2 = 92.7636
# Epoch 150, Iteration 9: H_t = 35, G_t = 1.2437, σ_t^2 = 105.9275
# Epoch 150, Iteration 10: H_t = 13, G_t = 0.4256, σ_t^2 = 92.5760
# Epoch 150, Iteration 11: H_t = 4, G_t = -1.0183, σ_t^2 = 105.2067
# Epoch 150, Iteration 12: H_t = 64, G_t = 2.3697, σ_t^2 = 88.6077
# Epoch 150, Iteration 13: H_t = 28, G_t = 0.9561, σ_t^2 = 101.1032
#     Worker 0: Train Loss: 1.2237, Train Accuracy: 65.41%
#     Worker 1: Train Loss: 1.2008, Train Accuracy: 66.34%
#     Worker 2: Train Loss: 1.2065, Train Accuracy: 66.18%
#     Worker 3: Train Loss: 1.2174, Train Accuracy: 66.11%
# Epoch 150: Test Loss: 1.9430, Test Accuracy: 51.07%
# Total Computation Time: 3910.57 seconds
# Total Communication Time: 1.55 seconds
